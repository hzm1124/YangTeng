# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

from openpyxl import load_workbook
import requests
from io import BytesIO
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter
import time

# = = = = = = = = = = = = = = = = = =

wb = load_workbook('./crawler.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        index_src = column
    elif ws.cell(1, column).value == 'Pic':
        index_pic = column
        
print('Src索引：' + str(index_src))
print('Pic索引：' + str(index_pic))
print()

work = Queue()
for row in range(2, ws.max_row+1):
    work.put_nowait(row)

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818',
           'https': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818'}
    
# = = = = = = = = = = = = = = = = = =

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        
        src = ws.cell(row, index_src).value
        
        status = 'error'
        for _ in range(31):
            if src == None or src == '':
                break
                
            try:
                pic = Image(BytesIO(requests.get(src, proxies=proxies).content))
                
                # = = = = = = = = = = = = = = = = = =
                
                if pic.width >= pic.height:
                    pic.height = 50.0 / pic.width * pic.height
                    pic.width = 50.0
                else:
                    pic.width = 50.0 / pic.height * pic.width
                    pic.height = 50.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                status = 'ok'
                ws.add_image(pic, get_column_letter(index_pic) + str(row))
            
                break
            
            except:
                time.sleep(3)
                continue
                
        # = = = = = = = = = = = = = = = = = =
        
        if src != None and src != '':
            print(src +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

wb.save('./crawler-pic.xlsx')
print()
print('搞定')
# Out:
# Src索引：10
# Pic索引：7
#
# https://static.dormanproducts.com/images/product/icon/264-5117-007.JPG  <->  [ok] - 剩余数量：82
# https://static.dormanproducts.com/images/product/icon/264-5116-007.JPG  <->  [ok] - 剩余数量：81
# https://static.dormanproducts.com/images/product/icon/264-5119-007.JPG  <->  [ok] - 剩余数量：80
# https://static.dormanproducts.com/images/product/icon/264-495-007.JPG  <->  [ok] - 剩余数量：79
# https://static.dormanproducts.com/images/product/icon/263-157-007.JPG  <->  [ok] - 剩余数量：78
# https://static.dormanproducts.com/images/product/icon/264-511-007.JPG  <->  [ok] - 剩余数量：77
# https://static.dormanproducts.com/images/product/icon/264-496-007.JPG  <->  [ok] - 剩余数量：76
# https://static.dormanproducts.com/images/product/icon/264-497-007.JPG  <->  [ok] - 剩余数量：75
# https://static.dormanproducts.com/images/product/icon/264-602-007.JPG  <->  [ok] - 剩余数量：74
# https://static.dormanproducts.com/images/product/icon/263-230-003.JPG  <->  [ok] - 剩余数量：73
# https://static.dormanproducts.com/images/product/icon/264-517-007.JPG  <->  [ok] - 剩余数量：72
# https://static.dormanproducts.com/images/product/icon/264-744-007.JPG  <->  [ok] - 剩余数量：71
# https://static.dormanproducts.com/images/product/icon/264-603-007.JPG  <->  [ok] - 剩余数量：70
# https://static.dormanproducts.com/images/product/icon/264-762-007.JPG  <->  [ok] - 剩余数量：69
# https://static.dormanproducts.com/images/product/icon/263-161-007.JPG  <->  [ok] - 剩余数量：68
# https://static.dormanproducts.com/images/product/icon/264-761-007.JPG  <->  [ok] - 剩余数量：67
# https://static.dormanproducts.com/images/product/icon/264-764-007.JPG  <->  [ok] - 剩余数量：66
# https://static.dormanproducts.com/images/product/icon/264-490-007.JPG  <->  [ok] - 剩余数量：65
# https://static.dormanproducts.com/images/product/icon/264-769-007.JPG  <->  [ok] - 剩余数量：64
# https://static.dormanproducts.com/images/product/icon/264-771-007.JPG  <->  [ok] - 剩余数量：63
# https://static.dormanproducts.com/images/product/icon/264-772-007.JPG  <->  [ok] - 剩余数量：62
# https://static.dormanproducts.com/images/product/icon/264-518-007.JPG  <->  [ok] - 剩余数量：61
# https://static.dormanproducts.com/images/product/icon/264-773-007.JPG  <->  [ok] - 剩余数量：60
# https://static.dormanproducts.com/images/product/icon/264-491-007.JPG  <->  [ok] - 剩余数量：59
# https://static.dormanproducts.com/images/product/icon/264-780-007.JPG  <->  [ok] - 剩余数量：58
# https://static.dormanproducts.com/images/product/icon/264-778-007.JPG  <->  [ok] - 剩余数量：57
# https://static.dormanproducts.com/images/product/icon/264-779-007.JPG  <->  [ok] - 剩余数量：56
# https://static.dormanproducts.com/images/product/icon/264-759-007.JPG  <->  [ok] - 剩余数量：55
# https://static.dormanproducts.com/images/product/icon/264-767-007.JPG  <->  [ok] - 剩余数量：54
# https://static.dormanproducts.com/images/product/icon/264-904-007.JPG  <->  [ok] - 剩余数量：53
# https://static.dormanproducts.com/images/product/icon/264-776-007.JPG  <->  [ok] - 剩余数量：52
# https://static.dormanproducts.com/images/product/icon/264-781-007.JPG  <->  [ok] - 剩余数量：51
# https://static.dormanproducts.com/images/product/icon/264-909-007.JPG  <->  [ok] - 剩余数量：50
# https://static.dormanproducts.com/images/product/icon/264-912-007.JPG  <->  [ok] - 剩余数量：49
# https://static.dormanproducts.com/images/product/icon/264-905-007.JPG  <->  [ok] - 剩余数量：48
# https://static.dormanproducts.com/images/product/icon/264-914-007.JPG  <->  [ok] - 剩余数量：47
# https://static.dormanproducts.com/images/product/icon/264-918-007.JPG  <->  [ok] - 剩余数量：46
# https://static.dormanproducts.com/images/product/icon/264-908-007.JPG  <->  [ok] - 剩余数量：45
# https://static.dormanproducts.com/images/product/icon/264-770-007.JPG  <->  [ok] - 剩余数量：44
# https://static.dormanproducts.com/images/product/icon/264-915-007.JPG  <->  [ok] - 剩余数量：43
# https://static.dormanproducts.com/images/product/icon/264-929-007.JPG  <->  [ok] - 剩余数量：42
# https://static.dormanproducts.com/images/product/icon/264-925-007.JPG  <->  [ok] - 剩余数量：41
# https://static.dormanproducts.com/images/product/icon/264-930-007.JPG  <->  [ok] - 剩余数量：40
# https://static.dormanproducts.com/images/product/icon/264-5118-007.JPG  <->  [ok] - 剩余数量：39
# https://static.dormanproducts.com/images/product/icon/264-492-007.JPG  <->  [ok] - 剩余数量：38
# https://static.dormanproducts.com/images/product/icon/264-932-007.JPG  <->  [ok] - 剩余数量：37
# https://static.dormanproducts.com/images/product/icon/264-763-007.JPG  <->  [ok] - 剩余数量：36
# https://static.dormanproducts.com/images/product/icon/264-916-007.JPG  <->  [ok] - 剩余数量：35
# https://static.dormanproducts.com/images/product/icon/264-919-007.JPG  <->  [ok] - 剩余数量：34
# https://static.dormanproducts.com/images/product/icon/264-935-007.JPG  <->  [ok] - 剩余数量：33
# https://static.dormanproducts.com/images/product/icon/264-938-007.JPG  <->  [ok] - 剩余数量：32
# https://static.dormanproducts.com/images/product/icon/264-937-007.JPG  <->  [ok] - 剩余数量：31
# https://static.dormanproducts.com/images/product/icon/264-947-007.JPG  <->  [ok] - 剩余数量：30
# https://static.dormanproducts.com/images/product/icon/264-907-007.JPG  <->  [ok] - 剩余数量：29
# https://static.dormanproducts.com/images/product/icon/264-964-007.JPG  <->  [ok] - 剩余数量：28
# https://static.dormanproducts.com/images/product/icon/264-949-007.JPG  <->  [ok] - 剩余数量：27
# https://static.dormanproducts.com/images/product/icon/264-969-007.JPG  <->  [ok] - 剩余数量：26
# https://static.dormanproducts.com/images/product/icon/264-936-007.JPG  <->  [ok] - 剩余数量：25
# https://static.dormanproducts.com/images/product/icon/264-967-007.JPG  <->  [ok] - 剩余数量：24
# https://static.dormanproducts.com/images/product/icon/264-950-007.JPG  <->  [ok] - 剩余数量：23
# https://static.dormanproducts.com/images/product/icon/264-920-007.JPG  <->  [ok] - 剩余数量：22
# https://static.dormanproducts.com/images/product/icon/264-970-007.JPG  <->  [ok] - 剩余数量：21
# https://static.dormanproducts.com/images/product/icon/264-948-007.JPG  <->  [ok] - 剩余数量：20
# https://static.dormanproducts.com/images/product/icon/263-158-007.JPG  <->  [ok] - 剩余数量：19
# https://static.dormanproducts.com/images/product/icon/264-960-007.JPG  <->  [ok] - 剩余数量：18
# https://static.dormanproducts.com/images/product/icon/264-976-007.JPG  <->  [ok] - 剩余数量：17
# https://static.dormanproducts.com/images/product/icon/263-160-007.JPG  <->  [ok] - 剩余数量：16
# https://static.dormanproducts.com/images/product/icon/264-975-007.JPG  <->  [ok] - 剩余数量：15
# https://static.dormanproducts.com/images/product/icon/264-977-007.JPG  <->  [ok] - 剩余数量：14
# https://static.dormanproducts.com/images/product/icon/264-971-007.JPG  <->  [ok] - 剩余数量：13
# https://static.dormanproducts.com/images/product/icon/264-965-007.JPG  <->  [ok] - 剩余数量：12
# https://static.dormanproducts.com/images/product/icon/264-979-007.JPG  <->  [ok] - 剩余数量：11
# https://static.dormanproducts.com/images/product/icon/264-982-007.JPG  <->  [ok] - 剩余数量：10
# https://static.dormanproducts.com/images/product/icon/264-983-007.JPG  <->  [ok] - 剩余数量：9
# https://static.dormanproducts.com/images/product/icon/264-985-007.JPG  <->  [ok] - 剩余数量：8
# https://static.dormanproducts.com/images/product/icon/264-986-007.JPG  <->  [ok] - 剩余数量：7
# https://static.dormanproducts.com/images/product/icon/264-987-007.JPG  <->  [ok] - 剩余数量：6
# https://static.dormanproducts.com/images/product/icon/264-973-007.JPG  <->  [ok] - 剩余数量：5
# https://static.dormanproducts.com/images/product/icon/264-774-007.JPG  <->  [ok] - 剩余数量：4
# https://static.dormanproducts.com/images/product/icon/264-988-007.JPG  <->  [ok] - 剩余数量：3
# https://static.dormanproducts.com/images/product/icon/264-988-007.JPG  <->  [ok] - 剩余数量：2
# https://static.dormanproducts.com/images/product/icon/264-966-007.JPG  <->  [ok] - 剩余数量：1
# https://static.dormanproducts.com/images/product/icon/264-972-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-968-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-974-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-989-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-995-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-993-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-999-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-996-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-994-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-997-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-978-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/60264990-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-748-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/917-026-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-984-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-992-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-933-001.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-760-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-939-007.JPG  <->  [ok] - 剩余数量：0
# https://static.dormanproducts.com/images/product/icon/264-928-007.JPG  <->  [ok] - 剩余数量：0
#
# 搞定
