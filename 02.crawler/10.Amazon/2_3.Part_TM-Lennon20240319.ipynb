# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 100/100 [00:00<00:00, 340.28it/s]
#      序号        ASIN                                              Title  \
# 0     1  B0CF56YD1C  XtremeAmazing AC A/C Compressor Clutch Assembl...
# 1     2  B0C7BMYGJJ  ApplianPar AC Compressor Clutch kit for Ford E...
# 2     3  B0BCWDNSVC  XtremeAmazing AC Compressor Clutch Assembly Ki...
# 3     4  B0CJY51879  A-Premium AC Compressor Clutch Compatible with...
# 4     5  B0CH185YP9  A-Premium A/C Compressor Clutch Compatible wit...
# ..  ...         ...                                                ...
# 95   96  B07JB91JL7  SCITOO CO 29006C AC Clutch for T-oyota Matrix ...
# 96   97  B09283FQN1  CoolTech A/C Compressor Clutch Kit Fit: 2013-2...
# 97   98  B08RC3C3LF  Qiilu Transmission Clutch Actuator, Clutch Con...
# 98   99  B081H4MG99  FKG AC Compressor Clutch Assembly Repair Kit C...
# 99  100  B09282GCD7  CoolTech AC Compressor Clutch Kit Coil Pulley ...
#
#      Price                                              About Pic  \
# 0   $41.15  1. Compatible with Nissan Versa 1.6 Liter Engi...
# 1   $44.99  1. Fit for Ford E150 1989-1996, E250 1990-1996...
# 2   $44.74  1. Replaces part number: 38810-RNA-A01, 38810R...
# 3   $49.99  1. [Vehicle Fitment]: Compatible with Acura IL...
# 4   $45.99  1. [Vehicle Fitment]: Compatible with Honda Ci...
# ..     ...                                                ...  ..
# 95  $39.91  1. ☃Air Conditioning Compressor Clutch Fitment...
# 96  $49.99  1. Warranty Period: 3 Months Warranty, Warrant...
# 97  $59.10  1. [ OEM ] --- A direct replacement for the ol...
# 98  $47.97  1. Compatibility: Air Conditioning Compressor ...
# 99  $59.99  1. Compressor Fitment: Will only fit original ...
#
#                                                   Url  \
# 0   https://www.amazon.com/XtremeAmazing-Compresso...
# 1   https://www.amazon.com/ApplianPar-Compressor-C...
# 2   https://www.amazon.com/XtremeAmazing-Compresso...
# 3   https://www.amazon.com/Premium-Compressor-Comp...
# 4   https://www.amazon.com/Premium-Compressor-Clut...
# ..                                                ...
# 95  https://www.amazon.com/SCITOO-Compatible-29006...
# 96  https://www.amazon.com/CoolTech-Compressor-Clu...
# 97  https://www.amazon.com/Qiilu-Transmission-Actu...
# 98  https://www.amazon.com/Compressor-BP4S61K00-CC...
# 99  https://www.amazon.com/CoolTech-Compressor-Clu...
#
#                                                   Src          manufacturer  \
# 0   https://m.media-amazon.com/images/I/61InkhNH+g...        ‎XtremeAmazing
# 1   https://m.media-amazon.com/images/I/718Od0AuOY...           ‎ApplianPar
# 2   https://m.media-amazon.com/images/I/618XmW0Wcr...        ‎XtremeAmazing
# 3   https://m.media-amazon.com/images/I/7140H16K8W...  ‎PremiumpartsWhosale
# 4   https://m.media-amazon.com/images/I/71+GhBcOAn...  ‎PremiumpartsWhosale
# ..                                                ...                   ...
# 95  https://m.media-amazon.com/images/I/61Xfn9fcmP...               ‎SCITOO
# 96  https://m.media-amazon.com/images/I/71fSSr-eZZ...             ‎CoolTech
# 97  https://m.media-amazon.com/images/I/61H4G1N9Ai...
# 98  https://m.media-amazon.com/images/I/61CQw8A7-j...                  ‎FKG
# 99  https://m.media-amazon.com/images/I/41RZd9TZtj...             ‎CoolTech
#
#              brand  ...                               model  \
# 0   ‎XtremeAmazing  ...
# 1      ‎ApplianPar  ...                      ‎F7LZ-19703-AA
# 2   ‎XtremeAmazing  ...  ‎AC Compressor Clutch Assembly Kit
# 3       ‎A-Premium  ...
# 4       ‎A-Premium  ...
# ..             ...  ...                                 ...
# 95         ‎SCITOO  ...        ‎A/C Compressors with clutch
# 96       ‎CoolTech  ...                                ‎MKZ
# 97                  ...
# 98            ‎FKG  ...
# 99       ‎CoolTech  ...                               ‎1500
#
#           item model number   exterior is discontinued by manufacturer  \
# 0
# 1            ‎F7LZ-19703-AA     ‎other
# 2            ‎38810-RNA-A01  ‎Machined
# 3
# 4
# ..                      ...        ...                             ...
# 95  ‎104180-5206-1734234341     ‎steel
# 96                    ‎1723    ‎Smooth
# 97
# 98                ‎ACC-0017
# 99                    ‎1909    ‎Smooth
#
#    country of origin                                    oem part number  \
# 0
# 1             ‎China
# 2             ‎China
# 3                     ‎CO4920AC, CO 4920AC, 38800RZYA010M2, 38800RZY...
# 4                     ‎CO4918AC, 98555, 97555, 38810RNAA01, 38810RNAA02
# ..               ...                                                ...
# 95                                                           ‎CO 27000C
# 96
# 97
# 98
# 99
#
#           product dimensions position  \
# 0
# 1
# 2
# 3
# 4
# ..                       ...      ...
# 95  ‎6.3 x 6.1 x 2.17 inches
# 96
# 97
# 98
# 99
#
#                                      special features voltage
# 0
# 1
# 2
# 3
# 4
# ..                                                ...     ...
# 95  ‎Compressor Clutches operational stable, A/C C...
# 96
# 97
# 98
# 99
#
# [100 rows x 26 columns]
