# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import json

# %%
with open('./make.txt', 'r', encoding='UTF-8') as f:
    df = pd.DataFrame(json.loads(f.read()))
    
df.to_excel('./1.make.xlsx', index=False)

df
# Out:
#         Tab_Label  No.        Make  \
# 0    Part Catalog    1      ABARTH
# 1    Part Catalog    2          AC
# 2    Part Catalog    3       ACURA
# 3    Part Catalog    4  ALFA ROMEO
# 4    Part Catalog    5      ALLARD
# ..            ...  ...         ...
# 263  Part Catalog  264   WORKHORSE
# 264  Part Catalog  265  YELLOW CAB
# 265  Part Catalog  266        YUGO
# 266  Part Catalog  267       ZACUA
# 267  Part Catalog  268     ZUNDAPP
#
#                                                 Url
# 0        https://www.rockauto.com/en/catalog/abarth
# 1            https://www.rockauto.com/en/catalog/ac
# 2         https://www.rockauto.com/en/catalog/acura
# 3    https://www.rockauto.com/en/catalog/alfa+romeo
# 4        https://www.rockauto.com/en/catalog/allard
# ..                                              ...
# 263   https://www.rockauto.com/en/catalog/workhorse
# 264  https://www.rockauto.com/en/catalog/yellow+cab
# 265        https://www.rockauto.com/en/catalog/yugo
# 266       https://www.rockauto.com/en/catalog/zacua
# 267     https://www.rockauto.com/en/catalog/zundapp
#
# [268 rows x 4 columns]
