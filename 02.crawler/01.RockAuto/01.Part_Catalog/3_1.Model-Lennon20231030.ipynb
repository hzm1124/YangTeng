# %%
import pandas as pd

# %%
df = pd.read_excel('./2.year.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_make = df['Make'].tolist()
list_year = df['Year'].tolist()

print('总数量：' + str(len(list_year)))
list_year
# Out:
# 总数量：1454
# ['2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2022',
#  '2021',
#  '2020',
#  '2018',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2009',
#  '2008',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2012',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2018',
#  '2017',
#  '2016',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2018',
#  '2017',
#  '2008',
#  '2007',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2014',
#  '2011',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2024',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2023',
#  '2022',
#  '2021',
#  '2005',
#  '2004',
#  '2003',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  ...]

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from urllib.parse import quote
import requests
import json

# %%
i = 0

make = list_make[0]
year = list_year[0]

data = 'func=navnode_fetch&payload=' + quote('{"jsn":{"tab":"catalog","make":"') + make.replace(' ', '+') + quote('","year":"') + year + quote('","nodetype":"year"}}') + '&api_json_request=1&sctchecked=1&scbeenloaded=true&curCartGroupID='

resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                     data=data,
                     headers={'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8'}).text

resp = json.loads(resp)

resp
# Out:
# {'html_fill_sections': {'navchildren[]': '<div class="ranavnode" id="nav[__GIP__1__]"><input type="hidden" autocomplete="off" id="jsn[__GIP__1__]" value="{&quot;groupindex&quot;:&quot;__GIP__1__&quot;,&quot;tab&quot;:&quot;catalog&quot;,&quot;idepth&quot;:1,&quot;make&quot;:&quot;ACURA&quot;,&quot;year&quot;:&quot;2024&quot;,&quot;model&quot;:&quot;INTEGRA&quot;,&quot;nodetype&quot;:&quot;model&quot;,&quot;jsdata&quot;:{&quot;markets&quot;:[{&quot;c&quot;:&quot;US&quot;},{&quot;c&quot;:&quot;CA&quot;},{&quot;c&quot;:&quot;MX&quot;}],&quot;mktlist&quot;:&quot;US,CA,MX&quot;,&quot;Show&quot;:1}}" /><input type="hidden" autocomplete="off" name="navnodeunique[catalog-acura-2024-integra]" id="navnodeunique[catalog-acura-2024-integra]" value="__GIP__1__" /><div id="nav_o[__GIP__1__]" class="ranavouter"><div class="inner"><table class="tbl"  cellpadding="0" cellspacing="0"><tr><td class="niconspace nvlineicon"></td><td class="niconspace ncollapsedicon" id="navicon[__GIP__1__]"><a href="/en/catalog/acura,2024,integra" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__1__&quot;); return false;" tabindex="-1"><img src="/Images/1pxtransparent.png" alt="Toggle"></a></td><td class="nlabel" ><a class="navlabellink nvoffset nnormal" href="/en/catalog/acura,2024,integra" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__1__&quot;); return false;" id="navhref[__GIP__1__]">INTEGRA</a></td><td class="rc nflags"><a class="sprite desktopflags us" style="margin-left: 3px;" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][US]" onclick="RA.StopBubble(event); return FAQpopup(this)" aria-label="the USA flag"></a><a class="sprite desktopflags ca" style="margin-left: 3px;" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][CA]" onclick="RA.StopBubble(event); return FAQpopup(this)" aria-label="Canada flag"></a><a class="sprite desktopflags mx" style="margin-left: 3px;" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][MX]" onclick="RA.StopBubble(event); return FAQpopup(this)" aria-label="Mexico flag"></a></td></tr></table></div></div><div class="nchildren ra-hide" id="navchildren[__GIP__1__]" ></div></div><div class="ranavnode" id="nav[__GIP__2__]"><input type="hidden" autocomplete="off" id="jsn[__GIP__2__]" value="{&quot;groupindex&quot;:&quot;__GIP__2__&quot;,&quot;tab&quot;:&quot;catalog&quot;,&quot;idepth&quot;:1,&quot;make&quot;:&quot;ACURA&quot;,&quot;year&quot;:&quot;2024&quot;,&quot;model&quot;:&quot;MDX&quot;,&quot;nodetype&quot;:&quot;model&quot;,&quot;jsdata&quot;:{&quot;markets&quot;:[{&quot;c&quot;:&quot;US&quot;},{&quot;c&quot;:&quot;CA&quot;},{&quot;c&quot;:&quot;MX&quot;}],&quot;mktlist&quot;:&quot;US,CA,MX&quot;,&quot;Show&quot;:1}}" /><input type="hidden" autocomplete="off" name="navnodeunique[catalog-acura-2024-mdx]" id="navnodeunique[catalog-acura-2024-mdx]" value="__GIP__2__" /><div id="nav_o[__GIP__2__]" class="ranavouter"><div class="inner"><table class="tbl"  cellpadding="0" cellspacing="0"><tr><td class="niconspace nvlineicon"></td><td class="niconspace ncollapsedicon" id="navicon[__GIP__2__]"><a href="/en/catalog/acura,2024,mdx" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__2__&quot;); return false;" tabindex="-1"><img src="/Images/1pxtransparent.png" alt="Toggle"></a></td><td class="nlabel" ><a class="navlabellink nvoffset nnormal" href="/en/catalog/acura,2024,mdx" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__2__&quot;); return false;" id="navhref[__GIP__2__]">MDX</a></td><td class="rc nflags"><a class="sprite desktopflags us" style="margin-left: 3px;" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__2__][US]" onclick="RA.StopBubble(event); return FAQpopup(this)" aria-label="the USA flag"></a><a class="sprite desktopflags ca" style="margin-left: 3px;" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__2__][CA]" onclick="RA.StopBubble(event); return FAQpopup(this)" aria-label="Canada flag"></a><a class="sprite desktopflags mx" style="margin-left: 3px;" href="/help/?pag ...
#  'jsn': {'tab': 'catalog',
#   'make': 'ACURA',
#   'year': '2024',
#   'nodetype': 'year',
#   'idepth': 0},
#  'collected_javascript': '/**UQ:731589A9**/\nwindow.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\\/0bbOhvn7P3rkFbL80\\/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDJ3DAD\\/oIoMxoM8tHV9xkwJ+4eiMOsTswgyLnMusZO8k=";\n'}

# %%
from bs4 import BeautifulSoup

# %%
html = resp['html_fill_sections']['navchildren[]']

soup = BeautifulSoup(html, 'lxml')

with open('./model.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="ranavnode" id="nav[__GIP__1__]">
#    <input autocomplete="off" id="jsn[__GIP__1__]" type="hidden" value='{"groupindex":"__GIP__1__","tab":"catalog","idepth":1,"make":"ACURA","year":"2024","model":"INTEGRA","nodetype":"model","jsdata":{"markets":[{"c":"US"},{"c":"CA"},{"c":"MX"}],"mktlist":"US,CA,MX","Show":1}}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-acura-2024-integra]" name="navnodeunique[catalog-acura-2024-integra]" type="hidden" value="__GIP__1__"/>
#    <div class="ranavouter" id="nav_o[__GIP__1__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__1__]">
#         <a href="/en/catalog/acura,2024,integra" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__1__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/acura,2024,integra" id="navhref[__GIP__1__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__1__"); return false;'>
#          INTEGRA
#         </a>
#        </td>
#        <td class="rc nflags">
#         <a aria-label="the USA flag" class="sprite desktopflags us" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][US]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#         <a aria-label="Canada flag" class="sprite desktopflags ca" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][CA]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#         <a aria-label="Mexico flag" class="sprite desktopflags mx" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__1__][MX]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__1__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__2__]">
#    <input autocomplete="off" id="jsn[__GIP__2__]" type="hidden" value='{"groupindex":"__GIP__2__","tab":"catalog","idepth":1,"make":"ACURA","year":"2024","model":"MDX","nodetype":"model","jsdata":{"markets":[{"c":"US"},{"c":"CA"},{"c":"MX"}],"mktlist":"US,CA,MX","Show":1}}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-acura-2024-mdx]" name="navnodeunique[catalog-acura-2024-mdx]" type="hidden" value="__GIP__2__"/>
#    <div class="ranavouter" id="nav_o[__GIP__2__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__2__]">
#         <a href="/en/catalog/acura,2024,mdx" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__2__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/acura,2024,mdx" id="navhref[__GIP__2__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__2__"); return false;'>
#          MDX
#         </a>
#        </td>
#        <td class="rc nflags">
#         <a aria-label="the USA flag" class="sprite desktopflags us" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__2__][US]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#         <a aria-label="Canada flag" class="sprite desktopflags ca" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__2__][CA]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#         <a aria-label="Mexico flag" class="sprite desktopflags mx" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__2__][MX]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__2__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__3__]">
#    <input autocomplete="off" id="jsn[__GIP__3__]" type="hidden" value='{"groupindex":"__GIP__3__","tab":"catalog","idepth":1,"make":"ACURA","year":"2024","model":"RDX","nodetype":"model","jsdata":{"markets":[{"c":"US"},{"c":"CA"}],"mktlist":"US,CA","Show":1}}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-acura-2024-rdx]" name="navnodeunique[catalog-acura-2024-rdx]" type="hidden" value="__GIP__3__"/>
#    <div class="ranavouter" id="nav_o[__GIP__3__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__3__]">
#         <a href="/en/catalog/acura,2024,rdx" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__3__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/acura,2024,rdx" id="navhref[__GIP__3__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__3__"); return false;'>
#          RDX
#         </a>
#        </td>
#        <td class="rc nflags">
#         <a aria-label="the USA flag" class="sprite desktopflags us" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__3__][US]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#         <a aria-label="Canada flag" class="sprite desktopflags ca" href="/help/?page=1#WHATDOTHE" id="flags[__GIP__3__][CA]" onclick="RA.StopBubble(event); return FAQpopup(this)" style="margin-left: 3px;">
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__3__]">
#    </div>
#   </div>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_model = html.xpath('//td[@class="nlabel"]/a/text()')

list_model
# Out:
# ['INTEGRA', 'MDX', 'RDX']

# %%
list_url = html.xpath('//td[@class="niconspace ncollapsedicon"]/a/@href')

list_url = ['https://www.rockauto.com'+_ for _ in list_url]

list_url
# Out:
# ['https://www.rockauto.com/en/catalog/acura,2024,integra',
#  'https://www.rockauto.com/en/catalog/acura,2024,mdx',
#  'https://www.rockauto.com/en/catalog/acura,2024,rdx']

# %%
df_temp = pd.DataFrame({'status': 'ok',
                        'Make': make,
                        'Year': year,
                        'Model': list_model,
                        'Url': list_url})

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status   Make  Year    Model  \
# 0     ok  ACURA  2024  INTEGRA
# 1     ok  ACURA  2024      MDX
# 2     ok  ACURA  2024      RDX
#
#                                                  Url
# 0  https://www.rockauto.com/en/catalog/acura,2024...
# 1  https://www.rockauto.com/en/catalog/acura,2024...
# 2  https://www.rockauto.com/en/catalog/acura,2024...
