# %%
param_date = '20240706'

# %%
import pandas as pd

input_ = pd.read_excel(f'./{param_date}/8.url_1.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_[['Url']].drop_duplicates(['Url'],
                                         keep='first',
                                         ignore_index=True)
input_ = input_.sort_values(by=['Url'],
                            ascending=[True],
                            ignore_index=True)
input_['No'] = [i+1 for i in range(len(input_))]

input_.to_excel(f'./{param_date}/9.url.xlsx', index=False)

input_
# Out:
#                                                      Url  SKU No
# 0      https://www.dormanproducts.com/p-10000-520-389...       1
# 1      https://www.dormanproducts.com/p-100000-937-50...       2
# 2      https://www.dormanproducts.com/p-100001-937-68...       3
# 3      https://www.dormanproducts.com/p-100002-937-69...       4
# 4      https://www.dormanproducts.com/p-100005-c66129...       5
# ...                                                  ...     ...
# 97279  https://www.dormanproducts.com/p-9999-520-375....   97280
# 97280  https://www.dormanproducts.com/p-99991-933-104...   97281
# 97281  https://www.dormanproducts.com/p-99997-c661294...   97282
# 97282  https://www.dormanproducts.com/p-99998-c661330...   97283
# 97283  https://www.dormanproducts.com/p-99999-604-873...   97284
#
# [97284 rows x 2 columns]
