# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./detail.xlsx', header=0)
list_vehicle_url = df_menu['vehicle_url'].to_list()

print('总数量：' + str(len(list_vehicle_url)))
list_vehicle_url
# Out:
# 总数量：18
# ['https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=64949&PartType=Engine%20Valve%20Cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
df = pd.DataFrame(columns=['vehicle_url',
                           'Vehicle',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [vehicle_url, Vehicle, status]
# Index: []

# %%
import requests

# %%
i = 0

resp = requests.get(list_vehicle_url[i]).text

resp
# Out:
# '\r\n\r\n<html>\r\n<head><title>\r\n\tDetailed Applications\r\n</title><link type="text/css" rel="stylesheet" href="/content/bootstrap.min.css?d=20160316" /><link id="linkrbcss" type="text/css" rel="stylesheet" href="/content/style.css?d=20220208" /><script>var __uzdbm_1 = "8cc4aced-d4a0-4112-af40-e99b9c3b6ba6";var __uzdbm_2 = "OTRhM2QyNzktYnUydi00ODk1LWI3MzgtNDczZjUwMDA2NzhjJDIyMS4yMDkuMTkwLjE3";var __uzdbm_3 = "";var __uzdbm_4 = "false";</script> <script>(function(w, d, e, u, c, g, a, b){ w["SSJSConnectorObj"] = {ss_cid : c, domain_info: "auto"}; a = d.createElement(e); a.async = true; a.src = u; b = d.getElementsByTagName(e)[0]; b.parentNode.insertBefore(a, b); })(window,document,"script","https://cdn.perfdrive.com/aperture/aperture.js","bu2x","ssConf");</script></head>\r\n<body>\r\n    <form name="form1" method="post" action="./itemdetailapp.aspx?ProductID=64949&amp;PartType=Engine+Valve+Cover" id="form1">\r\n<input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />\r\n\r\n<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="9ADCAD4B" />\r\n        <div>\r\n\t<table class="table table-hover table-dorman table-striped detail-app-table" cellspacing="0" border="0" id="gvDetailApps">\r\n\t\t<thead>\r\n\t\t\t<tr>\r\n\t\t\t\t<th scope="col">Year</th><th scope="col">Make</th><th scope="col">Model</th><th scope="col">Configuration</th><th scope="col">Positions</th><th scope="col">Application Notes</th>\r\n\t\t\t</tr>\r\n\t\t</thead><tbody>\r\n\t\t\t<tr class="detail-app-row">\r\n\t\t\t\t<td width="5%">\r\n                        2006\r\n                    </td><td width="13%">\r\n                        Jeep\r\n                    </td><td width="17%">\r\n                        TJ\r\n                    </td><td width="21%">\r\n                        L6 242 4.0L\r\n                    </td><td width="17%">\r\n                        \r\n                    </td><td width="27%">\r\n                        \r\n                    </td>\r\n\t\t\t</tr><tr class="detail-app-row">\r\n\t\t\t\t<td width="5%">\r\n                        2006\r\n                    </td><td width="13%">\r\n                        Jeep\r\n                    </td><td width="17%">\r\n                        Wrangler\r\n                    </td><td width="21%">\r\n                        L6 242 4.0L\r\n                    </td><td width="17%">\r\n                        \r\n                    </td><td width="27%">\r\n                        \r\n                    </td>\r\n\t\t\t</tr><tr class="detail-app-row">\r\n\t\t\t\t<td width="5%">\r\n                        2005\r\n                    </td><td width="13%">\r\n                        Jeep\r\n                    </td><td width="17%">\r\n                        TJ\r\n                    </td><td width="21%">\r\n                        L6 242 4.0L\r\n                    </td><td width="17%">\r\n                        \r\n                    </td><td width="27%">\r\n                        \r\n                    </td>\r\n\t\t\t</tr><tr class="detail-app-row">\r\n\t\t\t\t<td width="5%">\r\n                        2005\r\n                    </td><td width="13%">\r\n                        Jeep\r\n                    </td><td width="17%">\r\n                        Wrangler\r\n                    </td><td width="21%">\r\n                        L6 242 4.0L\r\n                    </td><td width="17%">\r\n                        \r\n                    </td><td width="27%">\r\n                        \r\n                    </td>\r\n\t\t\t</tr><tr class="detail-app-row">\r\n\t\t\t\t<td width="5%">\r\n                        2004\r\n                    </td><td width="13%">\r\n                        Jeep\r\n                    </td><td width="17%">\r\n                        Grand Cherokee\r\n                    </td><td width="21%">\r\n                        L6 242 4.0L\r\n                    </td><td width="17%">\r\n                        \r\n                  ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Detailed Applications
#   </title>
#   <link href="/content/bootstrap.min.css?d=20160316" rel="stylesheet" type="text/css"/>
#   <link href="/content/style.css?d=20220208" id="linkrbcss" rel="stylesheet" type="text/css"/>
#   <script>
#    var __uzdbm_1 = "8cc4aced-d4a0-4112-af40-e99b9c3b6ba6";var __uzdbm_2 = "OTRhM2QyNzktYnUydi00ODk1LWI3MzgtNDczZjUwMDA2NzhjJDIyMS4yMDkuMTkwLjE3";var __uzdbm_3 = "";var __uzdbm_4 = "false";
#   </script>
#   <script>
#    (function(w, d, e, u, c, g, a, b){ w["SSJSConnectorObj"] = {ss_cid : c, domain_info: "auto"}; a = d.createElement(e); a.async = true; a.src = u; b = d.getElementsByTagName(e)[0]; b.parentNode.insertBefore(a, b); })(window,document,"script","https://cdn.perfdrive.com/aperture/aperture.js","bu2x","ssConf");
#   </script>
#  </head>
#  <body>
#   <form action="./itemdetailapp.aspx?ProductID=64949&amp;PartType=Engine+Valve+Cover" id="form1" method="post" name="form1">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="9ADCAD4B"/>
#    <div>
#     <table border="0" cellspacing="0" class="table table-hover table-dorman table-striped detail-app-table" id="gvDetailApps">
#      <thead>
#       <tr>
#        <th scope="col">
#         Year
#        </th>
#        <th scope="col">
#         Make
#        </th>
#        <th scope="col">
#         Model
#        </th>
#        <th scope="col">
#         Configuration
#        </th>
#        <th scope="col">
#         Positions
#        </th>
#        <th scope="col">
#         Application Notes
#        </th>
#       </tr>
#      </thead>
#      <tbody>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2006
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2006
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2005
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2005
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2004
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2004
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2004
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2003
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2003
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2003
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2002
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2002
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2002
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2001
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2001
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2001
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2001
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2000
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2000
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2000
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         2000
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1999
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1999
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1999
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1999
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1998
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1998
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1998
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1998
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1997
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1997
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1997
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         TJ
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1997
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Wrangler
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1996
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1996
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1995
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1995
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#       <tr class="detail-app-row">
#        <td width="5%">
#         1994
#        </td>
#        <td width="13%">
#         Jeep
#        </td>
#        <td width="17%">
#         Grand Cherokee
#        </td>
#        <td width="21%">
#         L6 242 4.0L
#        </td>
#        <td width="17%">
#        </td>
#        <td width="27%">
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <div class="detail-app-pager">
#    </div>
#    <div class="detail-app-bottomspacing">
#     <br/>
#    </div>
#    <div id="iframe_bottom">
#    </div>
#    <script src="/scripts/jquery.min.js?d=20190905" type="text/javascript">
#    </script>
#    <script src="/scripts/jquery.floatThead.min.js?d=20190905" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     $('#gvDetailApps').floatThead({
#                 position: 'fixed'
#             });
#    </script>
#   </form>
#  </body>
# </html>

# %%
with open('./vehicle.html', 'w', encoding='utf-8') as file:
    file.write(str(soup))

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_row = html.xpath('//tr[@class="detail-app-row"]')

list_row
# Out:
# [<Element tr at 0x106f33ac0>,
#  <Element tr at 0x1211925c0>,
#  <Element tr at 0x121192080>,
#  <Element tr at 0x121191fc0>,
#  <Element tr at 0x121192680>,
#  <Element tr at 0x1211927c0>,
#  <Element tr at 0x121192600>,
#  <Element tr at 0x121192580>,
#  <Element tr at 0x121192900>,
#  <Element tr at 0x121192400>,
#  <Element tr at 0x121192780>,
#  <Element tr at 0x121192880>,
#  <Element tr at 0x121192980>,
#  <Element tr at 0x121192a40>,
#  <Element tr at 0x121192a80>,
#  <Element tr at 0x121192b40>,
#  <Element tr at 0x121192840>,
#  <Element tr at 0x121192ac0>,
#  <Element tr at 0x121192c40>,
#  <Element tr at 0x121192c00>,
#  <Element tr at 0x1211926c0>,
#  <Element tr at 0x1211928c0>,
#  <Element tr at 0x121192e00>,
#  <Element tr at 0x121192d80>,
#  <Element tr at 0x121192f00>,
#  <Element tr at 0x121192f40>,
#  <Element tr at 0x121192e40>,
#  <Element tr at 0x1211930c0>,
#  <Element tr at 0x121192d40>,
#  <Element tr at 0x121193140>,
#  <Element tr at 0x121192e80>,
#  <Element tr at 0x1211931c0>,
#  <Element tr at 0x121193080>,
#  <Element tr at 0x121192fc0>,
#  <Element tr at 0x121193240>,
#  <Element tr at 0x121193340>,
#  <Element tr at 0x1211933c0>,
#  <Element tr at 0x121192dc0>]

# %%
dict_vehicle = {}
for row in list_row:
    make = row.xpath('./td[2]/text()')[0].strip()
    model = row.xpath('./td[3]/text()')[0].strip()
    year = row.xpath('./td[1]/text()')[0].strip()
    
    if make not in dict_vehicle:
        dict_vehicle[make] = {model: [year]}
    else:
        if model not in dict_vehicle[make]:
            dict_vehicle[make][model] = [year]
        else:
            dict_vehicle[make][model].append(year)
            
list_vehicle = []
for make in dict_vehicle:
    for model in dict_vehicle[make]:
        list_vehicle.append(make + ' ' + model + ' ' + min(dict_vehicle[make][model]) + '-' + max(dict_vehicle[make][model]))

vehicle = '\n'.join(list_vehicle)

print(vehicle)
# Out:
# Jeep TJ 1997-2006
# Jeep Wrangler 1997-2006
# Jeep Grand Cherokee 1994-2004
# Jeep Cherokee 1995-2001

# %%
df_temp = pd.DataFrame([{'vehicle_url': list_vehicle_url[i],
                         'Vehicle': vehicle,
                         'status': 'ok'}])

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#                                          vehicle_url  \
# 0  https://www.dormanproducts.com/itemdetailapp.a...
#
#                                              Vehicle status
# 0  Jeep TJ 1997-2006\nJeep Wrangler 1997-2006\nJe...     ok
