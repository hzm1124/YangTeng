# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./2.menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        for b in range(666):
            try:
                import requests

                import sys
                sys.path.append('../../00.Tools')
                from crawler_configuration import get_proxy

                if input_.loc[a, 'Market'] == 'US':
                    url = f'''https://www.ebay.com/itm/{input_.loc[a, 'Item Number']}?_ul=US&_stpos=91710&orig_cvip=true'''
                elif input_.loc[a, 'Market'] == 'DE':
                    url = f'''https://www.ebay.de/itm/{input_.loc[a, 'Item Number']}?_ul=DE&_stpos=10115&orig_cvip=true'''
                elif input_.loc[a, 'Market'] == 'UK':
                    url = f'''https://www.ebay.co.uk/itm/{input_.loc[a, 'Item Number']}?_ul=GB&_stpos=BS81QU&orig_cvip=true'''
                elif input_.loc[a, 'Market'] == 'AU':
                    url = f'''https://www.ebay.com.au/itm/{input_.loc[a, 'Item Number']}?_ul=AU&_stpos=2019&orig_cvip=true'''

                resp = requests.get(url,
                                    proxies=get_proxy(),
                                    timeout=(10, 10)).text

                # = = = = = = = = = = = = = = =

                import json

                json_ = json.loads(resp.split('$MC=(window.$MC||[]).concat(')[1].split(']}]})</script>')[0].strip() + ']}]}')

                # = = = = = = = = = = = = = = =

                market = json_['o']['g']['marketplaceId'].strip()
                country = json_['o']['g']['country'].strip()
                language = json_['o']['g']['language'].strip()
                locale = json_['o']['g']['locale'].strip()
                item_number = json_['o']['g']['itemId'].strip()

                # = = = = = = = = = = = = = = =

                if input_.loc[a, 'Market'] == 'US':
                    if item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-US' or country != 'US' or language != 'en' or locale != 'en-US':
                        continue
                if input_.loc[a, 'Market'] == 'DE':
                    if item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-DE' or country != 'DE' or language != 'de' or locale != 'de-DE':
                        continue
                if input_.loc[a, 'Market'] == 'UK':
                    if item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-GB' or country != 'GB' or language != 'en' or locale != 'en-GB':
                        continue
                if input_.loc[a, 'Market'] == 'AU':
                    if item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-AU' or country != 'AU' or language != 'en' or locale != 'en-AU':
                        continue

                # = = = = = = = = = = = = = = =

                list_compatibility = json_['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['pagination']['pages'] if 'COMPATIBILITY_TABLE' in json_['o']['w'][0][2]['model']['modules'] else []

                dict_compatibility = {'market': input_.loc[a, 'Market'],
                                      'page': int(list_compatibility[-1]['text'].strip()),
                                      'data': {'scopedContext': {'catalogDetails': {'categoryId': list_compatibility[-1]['action']['params']['categoryId'],
                                                                                    'itemId': list_compatibility[-1]['action']['params']['itemId'],
                                                                                    'marketplaceId': list_compatibility[-1]['action']['params']['marketplaceId'],
                                                                                    'sellerName': list_compatibility[-1]['action']['params']['sellerName']}}}} if list_compatibility else ''

                # = = = = = = = = = = = = = = =

                dict_specific = {}
                dict_item = json_['o']['w'][0][2]['model']['modules']['ABOUT_THIS_ITEM']['sections']['features']['dataItems']
                for i, (key, value) in zip(range(len(dict_item.items())), dict_item.items()):
                    dict_specific[str(i)] = {value['labels'][0]['textSpans'][0]['text'].strip(): value['values'][0]['textualDisplays'][0]['textSpans'][0]['text'].strip() if 'textualDisplays' in value['values'][0] else value['values'][0]['textSpans'][0]['text'].strip()}

                # = = = = = = = = = = = = = = =

                description_url = json_['o']['w'][0][2]['model']['modules']['ITEM_DESCRIPTION_MIN_VIEW_MODULE']['sections'][0]['action']['URL'].strip()

                # = = = = = = = = = = = = = = =

                title = json_['o']['w'][0][2]['model']['modules']['TITLE']['mainTitle']['textSpans'][0]['text'].strip()

                # = = = = = = = = = = = = = = =

                subtitle = json_['o']['w'][0][2]['model']['modules']['TITLE']['subTitle']['textSpans'][0]['text'].strip() if 'subTitle' in json_['o']['w'][0][2]['model']['modules']['TITLE'] else ''

                # = = = = = = = = = = = = = = =

                price = json_['o']['w'][0][2]['model']['modules']['BUY_BOX']['binModel']['price']['textSpans'][0]['text'].strip()

                # = = = = = = = = = = = = = = =

                available, sold = '', ''
                list_quantity = json_['o']['w'][0][2]['model']['modules']['QUANTITY']['availabilitySignal']['textSpans'] if 'QUANTITY' in json_['o']['w'][0][2]['model']['modules'] else []
                for quantity in list_quantity:
                    if input_.loc[a, 'Market'] in ['US', 'UK', 'AU']:
                        if 'available' in quantity['text']:
                            available = quantity['text'].strip()
                        elif 'sold' in quantity['text']:
                            sold = quantity['text'].strip()
                    elif input_.loc[a, 'Market'] == 'DE':
                        if 'verfügbar' in quantity['text']:
                            available = quantity['text'].strip()
                        elif 'verkauft' in quantity['text']:
                            sold = quantity['text'].strip()

                # = = = = = = = = = = = = = = =

                dict_src = {}
                list_media = json_['o']['w'][0][2]['model']['modules']['PICTURE']['mediaList'] if 'mediaList' in json_['o']['w'][0][2]['model']['modules']['PICTURE'] else []
                for i, media in zip(range(len(list_media)), list_media):
                    dict_src[str(i)] = media['image']['originalImg']['URL'].strip()

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                                         'Item Number': input_.loc[a, 'Item Number'],
                                         'Title': title,
                                         'Subtitle': subtitle,
                                         'Price': price,
                                         'Available': available,
                                         'Sold': sold,
                                         'Vehicle W/o Engine': '',
                                         'Vehicle W/ Engine': '',
                                         'Picture': '',
                                         'Url': url,
                                         'Description Url': description_url,
                                         'Json_Compatibility': json.dumps(dict_compatibility),
                                         'Json_Src': json.dumps(dict_src),
                                         'Json_Specific': json.dumps(dict_specific)}])

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'

                # = = = = = = = = = = = = = = =

                break
            except:
                continue

        # = = = = = = = = = = = = = = =

        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'Market': input_.loc[a, 'Market'],
                                     'Page': input_.loc[a, 'Page'],
                                     'Page Url': input_.loc[a, 'Page Url'],
                                     'No': input_.loc[a, 'No'],
                                     'Item Number': input_.loc[a, 'Item Number']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b+1:3d}] - {input_.loc[a, 'No']}.{input_.loc[a, 'Item Number']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(12):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./3.item-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel(f'./item_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：461
#
# [状态：ok，尝试次数：  1] - 6.224123951753
# [剩余数量：449] - [当前时间：19:26:00]
#
# [状态：ok，尝试次数：  1] - 5.226014609107
# [剩余数量：448] - [当前时间：19:26:00]
#
# [状态：ok，尝试次数：  1] - 12.325695359858
# [剩余数量：447] - [当前时间：19:26:00]
#
# [状态：ok，尝试次数：  1] - 11.325521299154
# [剩余数量：446] - [当前时间：19:26:00]
#
# [状态：ok，尝试次数：  1] - 4.226014609106
# [剩余数量：445] - [当前时间：19:26:00]
#
# [状态：ok，尝试次数：  1] - 2.325960692580
# [剩余数量：444] - [当前时间：19:26:01]
#
# [状态：ok，尝试次数：  1] - 9.325886285768
# [剩余数量：443] - [当前时间：19:26:01]
#
# [状态：ok，尝试次数：  1] - 8.226014610355
# [剩余数量：442] - [当前时间：19:26:01]
#
# [状态：ok，尝试次数：  1] - 1.325960692572
# [剩余数量：441] - [当前时间：19:26:01]
#
# [状态：ok，尝试次数：  1] - 15.325695359947
# [剩余数量：440] - [当前时间：19:26:02]
#
# [状态：ok，尝试次数：  1] - 7.326022100254
# [剩余数量：439] - [当前时间：19:26:02]
#
# [状态：ok，尝试次数：  1] - 14.225619720199
# [剩余数量：438] - [当前时间：19:26:02]
#
# [状态：ok，尝试次数：  1] - 16.325508483885
# [剩余数量：437] - [当前时间：19:26:02]
#
# [状态：ok，尝试次数：  1] - 18.325252521028
# [剩余数量：436] - [当前时间：19:26:03]
#
# [状态：ok，尝试次数：  1] - 21.224069870372
# [剩余数量：435] - [当前时间：19:26:03]
#
# [状态：ok，尝试次数：  1] - 17.325508483888
# [剩余数量：434] - [当前时间：19:26:03]
#
# [状态：ok，尝试次数：  1] - 19.325252524584
# [剩余数量：433] - [当前时间：19:26:04]
#
# [状态：ok，尝试次数：  1] - 22.324195058826
# [剩余数量：432] - [当前时间：19:26:04]
#
# [状态：ok，尝试次数：  1] - 23.224041913100
# [剩余数量：431] - [当前时间：19:26:04]
#
# [状态：ok，尝试次数：  1] - 13.325695359869
# [剩余数量：430] - [当前时间：19:26:04]
#
# [状态：ok，尝试次数：  1] - 27.225394115168
# [剩余数量：429] - [当前时间：19:26:05]
#
# [状态：ok，尝试次数：  1] - 24.224049578763
# [剩余数量：428] - [当前时间：19:26:05]
#
# [状态：ok，尝试次数：  1] - 28.225394115179
# [剩余数量：427] - [当前时间：19:26:06]
#
# [状态：ok，尝试次数：  1] - 25.324202399989
# [剩余数量：426] - [当前时间：19:26:06]
#
# [状态：ok，尝试次数：  1] - 30.324182049924
# [剩余数量：425] - [当前时间：19:26:06]
#
# [状态：ok，尝试次数：  1] - 29.325767053463
# [剩余数量：424] - [当前时间：19:26:07]
#
# [状态：ok，尝试次数：  1] - 31.324182049935
# [剩余数量：423] - [当前时间：19:26:07]
#
# [状态：ok，尝试次数：  1] - 33.224027829701
# [剩余数量：422] - [当前时间：19:26:07]
#
# [状态：ok，尝试次数：  1] - 32.324182051100
# [剩余数量：421] - [当前时间：19:26:07]
#
# [状态：ok，尝试次数：  1] - 26.325521280411
# [剩余数量：420] - [当前时间：19:26:08]
#
# [状态：ok，尝试次数：  1] - 35.224043002797
# [剩余数量：419] - [当前时间：19:26:08]
#
# [状态：ok，尝试次数：  1] - 36.224043002815
# [剩余数量：418] - [当前时间：19:26:08]
#
# [状态：ok，尝试次数：  1] - 37.225394115007
# [剩余数量：417] - [当前时间：19:26:08]
#
# [状态：ok，尝试次数：  1] - 40.324106995935
# [剩余数量：416] - [当前时间：19:26:09]
#
# [状态：ok，尝试次数：  1] - 39.225394115357
# [剩余数量：415] - [当前时间：19:26:09]
#
# [状态：ok，尝试次数：  1] - 44.325268687550
# [剩余数量：414] - [当前时间：19:26:09]
#
# [状态：ok，尝试次数：  1] - 42.325268687549
# [剩余数量：413] - [当前时间：19:26:10]
#
# [状态：ok，尝试次数：  1] - 43.225074422489
# [剩余数量：412] - [当前时间：19:26:10]
#
# [状态：ok，尝试次数：  1] - 38.225394115014
# [剩余数量：411] - [当前时间：19:26:11]
#
# [状态：ok，尝试次数：  4] - 10.325886285771
# [剩余数量：410] - [当前时间：19:26:11]
#
# [状态：ok，尝试次数：  1] - 48.325268687619
# [剩余数量：409] - [当前时间：19:26:11]
#
# [状态：ok，尝试次数：  1] - 41.224325133748
# [剩余数量：408] - [当前时间：19:26:12]
#
# [状态：ok，尝试次数：  1] - 47.225074422529
# [剩余数量：407] - [当前时间：19:26:12]
#
# [状态：ok，尝试次数：  1] - 45.325268687552
# [剩余数量：406] - [当前时间：19:26:12]
#
# [状态：ok，尝试次数：  1] - 49.325268687627
# [剩余数量：405] - [当前时间：19:26:12]
#
# [状态：ok，尝试次数：  1] - 50.325268687635
# [剩余数量：404] - [当前时间：19:26:12]
#
# [状态：ok，尝试次数：  1] - 52.325573260090
# [剩余数量：403] - [当前时间：19:26:13]
#
# [状态：ok，尝试次数：  1] - 51.225074422531
# [剩余数量：402] - [当前时间：19:26:14]
#
# [状态：ok，尝试次数：  1] - 53.225478622705
# [剩余数量：401] - [当前时间：19:26:14]
#
# [状态：ok，尝试次数：  1] - 58.324107301518
# [剩余数量：400] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 57.324107301486
# [剩余数量：399] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 54.325573261556
# [剩余数量：398] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 55.226011442387
# [剩余数量：397] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 56.226011442390
# [剩余数量：396] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 59.223959439513
# [剩余数量：395] - [当前时间：19:26:15]
#
# [状态：ok，尝试次数：  1] - 46.325268687554
# [剩余数量：394] - [当前时间：19:26:16]
#
# [状态：ok，尝试次数：  1] - 66.225718150746
# [剩余数量：393] - [当前时间：19:26:17]
#
# [状态：ok，尝试次数：  1] - 67.225718150749
# [剩余数量：392] - [当前时间：19:26:17]
#
# [状态：ok，尝试次数：  1] - 64.324225028769
# [剩余数量：391] - [当前时间：19:26:17]
#
# [状态：ok，尝试次数：  1] - 65.325521293994
# [剩余数量：390] - [当前时间：19:26:18]
#
# [状态：ok，尝试次数：  1] - 62.324117892592
# [剩余数量：389] - [当前时间：19:26:18]
#
# [状态：ok，尝试次数：  1] - 68.225718150751
# [剩余数量：388] - [当前时间：19:26:18]
#
# [状态：ok，尝试次数：  1] - 63.224074504928
# [剩余数量：387] - [当前时间：19:26:19]
#
# [状态：ok，尝试次数：  1] - 61.223959441529
# [剩余数量：386] - [当前时间：19:26:19]
#
# [状态：ok，尝试次数：  1] - 70.223959463739
# [剩余数量：385] - [当前时间：19:26:19]
#
# [状态：ok，尝试次数：  1] - 73.324123102780
# [剩余数量：384] - [当前时间：19:26:19]
#
# [状态：ok，尝试次数：  1] - 69.325767053458
# [剩余数量：383] - [当前时间：19:26:20]
#
# [状态：ok，尝试次数：  1] - 74.325573256682
# [剩余数量：382] - [当前时间：19:26:20]
#
# [状态：ok，尝试次数：  1] - 3.225616819852
# [剩余数量：381] - [当前时间：19:26:20]
#
# [状态：ok，尝试次数：  1] - 76.225478616529
# [剩余数量：380] - [当前时间：19:26:22]
#
# [状态：ok，尝试次数：  1] - 75.225478616528
# [剩余数量：379] - [当前时间：19:26:22]
#
# [状态：ok，尝试次数：  1] - 77.225478616530
# [剩余数量：378] - [当前时间：19:26:22]
#
# [状态：ok，尝试次数：  1] - 71.324117919622
# [剩余数量：377] - [当前时间：19:26:22]
#
# [状态：ok，尝试次数：  1] - 81.325573256721
# [剩余数量：376] - [当前时间：19:26:23]
#
# [状态：ok，尝试次数：  1] - 79.225478616551
# [剩余数量：375] - [当前时间：19:26:23]
#
# [状态：ok，尝试次数：  1] - 78.325573256683
# [剩余数量：374] - [当前时间：19:26:23]
#
# [状态：ok，尝试次数：  1] - 80.225478616554
# [剩余数量：373] - [当前时间：19:26:24]
#
# [状态：ok，尝试次数：  1] - 82.225478616555
# [剩余数量：372] - [当前时间：19:26:24]
#
# [状态：ok，尝试次数：  1] - 84.225478616579
# [剩余数量：371] - [当前时间：19:26:24]
#
# [状态：ok，尝试次数：  1] - 87.223957575394
# [剩余数量：370] - [当前时间：19:26:25]
#
# [状态：ok，尝试次数：  1] - 83.325573256732
# [剩余数量：369] - [当前时间：19:26:25]
#
# [状态：ok，尝试次数：  5] - 60.324117891310
# [剩余数量：368] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 85.325573256779
# [剩余数量：367] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 91.223957583645
# [剩余数量：366] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 86.223957575363
# [剩余数量：365] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 72.223964576553
# [剩余数量：364] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 90.223957575709
# [剩余数量：363] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 88.223957575431
# [剩余数量：362] - [当前时间：19:26:26]
#
# [状态：ok，尝试次数：  1] - 89.223957575626
# [剩余数量：361] - [当前时间：19:26:27]
#
# [状态：ok，尝试次数：  1] - 94.324182049948
# [剩余数量：360] - [当前时间：19:26:27]
#
# [状态：ok，尝试次数：  1] - 96.324182060890
# [剩余数量：359] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  1] - 98.225457373976
# [剩余数量：358] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  2] - 34.224027842661
# [剩余数量：357] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  1] - 99.325690597646
# [剩余数量：356] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  1] - 93.325436982898
# [剩余数量：355] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  1] - 92.225266403247
# [剩余数量：354] - [当前时间：19:26:28]
#
# [状态：ok，尝试次数：  1] - 100.225614547007
# [剩余数量：353] - [当前时间：19:26:29]
#
# [状态：ok，尝试次数：  1] - 97.325557183981
# [剩余数量：352] - [当前时间：19:26:29]
#
# [状态：ok，尝试次数：  1] - 101.324220759611
# [剩余数量：351] - [当前时间：19:26:29]
#
# [状态：ok，尝试次数：  1] - 104.324182059362
# [剩余数量：350] - [当前时间：19:26:30]
#
# [状态：ok，尝试次数：  1] - 103.326183918989
# [剩余数量：349] - [当前时间：19:26:30]
#
# [状态：ok，尝试次数：  1] - 102.326183918987
# [剩余数量：348] - [当前时间：19:26:30]
#
# [状态：ok，尝试次数：  1] - 107.225478310320
# [剩余数量：347] - [当前时间：19:26:30]
#
# [状态：ok，尝试次数：  1] - 105.325521288514
# [剩余数量：346] - [当前时间：19:26:31]
#
# [状态：ok，尝试次数：  8] - 109.324201031081
# [剩余数量：345] - [当前时间：19:26:32]
#
# [状态：ok，尝试次数：  1] - 110.325360503300
# [剩余数量：344] - [当前时间：19:26:32]
#
# [状态：ok，尝试次数：  5] - 95.324182051119
# [剩余数量：343] - [当前时间：19:26:32]
#
# [状态：ok，尝试次数：  3] - 114.225870715378
# [剩余数量：342] - [当前时间：19:26:32]
#
# [状态：ok，尝试次数：  9] - 113.225394141615
# [剩余数量：341] - [当前时间：19:26:33]
#
# [状态：ok，尝试次数： 10] - 115.225870715380
# [剩余数量：340] - [当前时间：19:26:33]
#
# [状态：ok，尝试次数：  1] - 111.224027833284
# [剩余数量：339] - [当前时间：19:26:34]
#
# [状态：ok，尝试次数：  2] - 20.224069870340
# [剩余数量：338] - [当前时间：19:26:34]
#
# [状态：ok，尝试次数：  1] - 119.223957569210
# [剩余数量：337] - [当前时间：19:26:34]
#
# [状态：ok，尝试次数：  3] - 121.224160260327
# [剩余数量：336] - [当前时间：19:26:34]
#
# [状态：ok，尝试次数： 10] - 106.324464979934
# [剩余数量：335] - [当前时间：19:26:34]
#
# [状态：ok，尝试次数： 14] - 118.324115471988
# [剩余数量：334] - [当前时间：19:26:35]
#
# [状态：ok，尝试次数：  2] - 116.223950397513
# [剩余数量：333] - [当前时间：19:26:35]
#
# [状态：ok，尝试次数：  1] - 108.324201030966
# [剩余数量：332] - [当前时间：19:26:35]
#
# [状态：ok，尝试次数： 16] - 122.324298723369
# [剩余数量：331] - [当前时间：19:26:36]
#
# [状态：ok，尝试次数：  6] - 123.224160260401
# [剩余数量：330] - [当前时间：19:26:36]
#
# [状态：ok，尝试次数：  2] - 125.224160260539
# [剩余数量：329] - [当前时间：19:26:36]
#
# [状态：ok，尝试次数：  1] - 124.224160260504
# [剩余数量：328] - [当前时间：19:26:37]
#
# [状态：ok，尝试次数： 12] - 126.324298723510
# [剩余数量：327] - [当前时间：19:26:37]
#
# [状态：ok，尝试次数：  6] - 112.325521284786
# [剩余数量：326] - [当前时间：19:26:37]
#
# [状态：ok，尝试次数： 11] - 117.324114208323
# [剩余数量：325] - [当前时间：19:26:38]
#
# [状态：ok，尝试次数： 15] - 128.224160260846
# [剩余数量：324] - [当前时间：19:26:38]
#
# [状态：ok，尝试次数：  1] - 130.223956589279
# [剩余数量：323] - [当前时间：19:26:38]
#
# [状态：ok，尝试次数：  1] - 131.223956598016
# [剩余数量：322] - [当前时间：19:26:38]
#
# [状态：ok，尝试次数：  2] - 134.224135246084
# [剩余数量：321] - [当前时间：19:26:38]
#
# [状态：ok，尝试次数： 24] - 127.324298723555
# [剩余数量：320] - [当前时间：19:26:39]
#
# [状态：ok，尝试次数：  4] - 129.324114206543
# [剩余数量：319] - [当前时间：19:26:40]
#
# [状态：ok，尝试次数： 20] - 132.223956598024
# [剩余数量：318] - [当前时间：19:26:40]
#
# [状态：ok，尝试次数： 12] - 133.224135243214
# [剩余数量：317] - [当前时间：19:26:40]
#
# [状态：ok，尝试次数：  3] - 140.324220759633
# [剩余数量：316] - [当前时间：19:26:40]
#
# [状态：ok，尝试次数： 18] - 136.324274889090
# [剩余数量：315] - [当前时间：19:26:40]
#
# [状态：ok，尝试次数： 37] - 120.224027833297
# [剩余数量：314] - [当前时间：19:26:41]
#
# [状态：ok，尝试次数： 22] - 135.324274889037
# [剩余数量：313] - [当前时间：19:26:41]
#
# [状态：ok，尝试次数： 15] - 142.324115485064
# [剩余数量：312] - [当前时间：19:26:41]
#
# [状态：ok，尝试次数： 37] - 137.324274890460
# [剩余数量：311] - [当前时间：19:26:42]
#
# [状态：ok，尝试次数：  3] - 147.324102262618
# [剩余数量：310] - [当前时间：19:26:43]
#
# [状态：ok，尝试次数：  7] - 143.324115485086
# [剩余数量：309] - [当前时间：19:26:43]
#
# [状态：ok，尝试次数： 15] - 144.324115485105
# [剩余数量：308] - [当前时间：19:26:43]
#
# [状态：ok，尝试次数： 14] - 141.324115485040
# [剩余数量：307] - [当前时间：19:26:43]
#
# [状态：ok，尝试次数：  7] - 149.324102262631
# [剩余数量：306] - [当前时间：19:26:43]
#
# [状态：ok，尝试次数： 56] - 138.324599081324
# [剩余数量：305] - [当前时间：19:26:44]
#
# [状态：ok，尝试次数： 14] - 150.324114195099
# [剩余数量：304] - [当前时间：19:26:45]
#
# [状态：ok，尝试次数： 12] - 152.223956577915
# [剩余数量：303] - [当前时间：19:26:45]
#
# [状态：ok，尝试次数：  6] - 151.223956577902
# [剩余数量：302] - [当前时间：19:26:45]
#
# [状态：ok，尝试次数：  8] - 146.223945212805
# [剩余数量：301] - [当前时间：19:26:45]
#
# [状态：ok，尝试次数：  2] - 155.223945197352
# [剩余数量：300] - [当前时间：19:26:45]
#
# [状态：ok，尝试次数： 18] - 154.324102250246
# [剩余数量：299] - [当前时间：19:26:46]
#
# [状态：ok，尝试次数： 15] - 148.223945212826
# [剩余数量：298] - [当前时间：19:26:46]
#
# [状态：ok，尝试次数： 18] - 153.324114195144
# [剩余数量：297] - [当前时间：19:26:46]
#
# [状态：ok，尝试次数：  7] - 157.325692747786
# [剩余数量：296] - [当前时间：19:26:46]
#
# [状态：ok，尝试次数： 18] - 160.324298723523
# [剩余数量：295] - [当前时间：19:26:48]
#
# [状态：ok，尝试次数：  4] - 158.225394160356
# [剩余数量：294] - [当前时间：19:26:48]
#
# [状态：ok，尝试次数：  5] - 163.324102238190
# [剩余数量：293] - [当前时间：19:26:48]
#
# [状态：ok，尝试次数：  2] - 145.224657528175
# [剩余数量：292] - [当前时间：19:26:48]
#
# [状态：ok，尝试次数：  5] - 161.224160260792
# [剩余数量：291] - [当前时间：19:26:49]
#
# [状态：ok，尝试次数： 13] - 164.324107213364
# [剩余数量：290] - [当前时间：19:26:49]
#
# [状态：ok，尝试次数： 32] - 159.225395312130
# [剩余数量：289] - [当前时间：19:26:49]
#
# [状态：ok，尝试次数：  6] - 166.324114214674
# [剩余数量：288] - [当前时间：19:26:49]
#
# [状态：ok，尝试次数：  8] - 169.324102312699
# [剩余数量：287] - [当前时间：19:26:51]
#
# [状态：ok，尝试次数： 14] - 173.223945185500
# [剩余数量：286] - [当前时间：19:26:52]
#
# [状态：ok，尝试次数： 22] - 168.324102312681
# [剩余数量：285] - [当前时间：19:26:52]
#
# [状态：ok，尝试次数： 68] - 156.325692747785
# [剩余数量：284] - [当前时间：19:26:53]
#
# [状态：ok，尝试次数：  9] - 171.223945269723
# [剩余数量：283] - [当前时间：19:26:54]
#
# [状态：ok，尝试次数： 32] - 175.325521282707
# [剩余数量：282] - [当前时间：19:26:55]
#
# [状态：ok，尝试次数： 76] - 170.324102312705
# [剩余数量：281] - [当前时间：19:26:55]
#
# [状态：ok，尝试次数： 48] - 165.223950302420
# [剩余数量：280] - [当前时间：19:26:55]
#
# [状态：ok，尝试次数：  4] - 177.223945154954
# [剩余数量：279] - [当前时间：19:26:55]
#
# [状态：ok，尝试次数：  7] - 176.324599081296
# [剩余数量：278] - [当前时间：19:26:56]
#
# [状态：ok，尝试次数：  2] - 183.324107082985
# [剩余数量：277] - [当前时间：19:26:57]
#
# [状态：ok，尝试次数：  9] - 181.325521896192
# [剩余数量：276] - [当前时间：19:26:58]
#
# [状态：ok，尝试次数：  1] - 184.223950203204
# [剩余数量：275] - [当前时间：19:26:58]
#
# [状态：ok，尝试次数： 12] - 178.324102215745
# [剩余数量：274] - [当前时间：19:26:58]
#
# [状态：ok，尝试次数： 27] - 180.223956593632
# [剩余数量：273] - [当前时间：19:26:59]
#
# [状态：ok，尝试次数： 10] - 162.324102238049
# [剩余数量：272] - [当前时间：19:27:00]
#
# [状态：ok，尝试次数： 40] - 174.224027835921
# [剩余数量：271] - [当前时间：19:27:00]
#
# [状态：ok，尝试次数：  7] - 185.324107082997
# [剩余数量：270] - [当前时间：19:27:01]
#
# [状态：ok，尝试次数： 12] - 187.324107083119
# [剩余数量：269] - [当前时间：19:27:01]
#
# [状态：ok，尝试次数： 20] - 182.223950203186
# [剩余数量：268] - [当前时间：19:27:01]
#
# [状态：ok，尝试次数： 13] - 188.223950203406
# [剩余数量：267] - [当前时间：19:27:02]
#
# [状态：ok，尝试次数： 19] - 172.223945270621
# [剩余数量：266] - [当前时间：19:27:02]
#
# [状态：ok，尝试次数：  3] - 189.324107083152
# [剩余数量：265] - [当前时间：19:27:02]
#
# [状态：ok，尝试次数： 14] - 190.325692053049
# [剩余数量：264] - [当前时间：19:27:03]
#
# [状态：ok，尝试次数：  7] - 186.223950203233
# [剩余数量：263] - [当前时间：19:27:03]
#
# [状态：ok，尝试次数：  2] - 193.224009419043
# [剩余数量：262] - [当前时间：19:27:04]
#
# [状态：ok，尝试次数：  6] - 197.324117894686
# [剩余数量：261] - [当前时间：19:27:05]
#
# [状态：ok，尝试次数： 10] - 194.224183905400
# [剩余数量：260] - [当前时间：19:27:05]
#
# [状态：ok，尝试次数： 16] - 195.224183905451
# [剩余数量：259] - [当前时间：19:27:06]
#
# [状态：ok，尝试次数：  1] - 192.224009419026
# [剩余数量：258] - [当前时间：19:27:06]
#
# [状态：ok，尝试次数：  2] - 201.225549636533
# [剩余数量：257] - [当前时间：19:27:08]
#
# [状态：ok，尝试次数：  2] - 199.325549422131
# [剩余数量：256] - [当前时间：19:27:08]
#
# [状态：ok，尝试次数：  1] - 200.324182057321
# [剩余数量：255] - [当前时间：19:27:08]
#
# [状态：ok，尝试次数： 38] - 191.225616133534
# [剩余数量：254] - [当前时间：19:27:09]
#
# [状态：ok，尝试次数：  1] - 204.223956586097
# [剩余数量：253] - [当前时间：19:27:09]
#
# [状态：ok，尝试次数：  1] - 205.324114203171
# [剩余数量：252] - [当前时间：19:27:09]
#
# [状态：ok，尝试次数：  2] - 202.225402064713
# [剩余数量：251] - [当前时间：19:27:10]
#
# [状态：ok，尝试次数：  4] - 196.223959442542
# [剩余数量：250] - [当前时间：19:27:11]
#
# [状态：ok，尝试次数： 12] - 206.324107044602
# [剩余数量：249] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数：  3] - 207.223950165041
# [剩余数量：248] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数：  7] - 210.324107044713
# [剩余数量：247] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数： 21] - 179.225478621394
# [剩余数量：246] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数： 18] - 167.223945269608
# [剩余数量：245] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数：  1] - 209.223950165027
# [剩余数量：244] - [当前时间：19:27:12]
#
# [状态：ok，尝试次数： 11] - 211.223950166091
# [剩余数量：243] - [当前时间：19:27:13]
#
# [状态：ok，尝试次数：  4] - 213.223956581097
# [剩余数量：242] - [当前时间：19:27:13]
#
# [状态：ok，尝试次数： 11] - 208.223950165068
# [剩余数量：241] - [当前时间：19:27:14]
#
# [状态：ok，尝试次数： 19] - 214.223956581118
# [剩余数量：240] - [当前时间：19:27:14]
#
# [状态：ok，尝试次数：  5] - 215.223950171327
# [剩余数量：239] - [当前时间：19:27:14]
#
# [状态：ok，尝试次数：  4] - 216.223950171350
# [剩余数量：238] - [当前时间：19:27:14]
#
# [状态：ok，尝试次数：  7] - 212.324114197614
# [剩余数量：237] - [当前时间：19:27:15]
#
# [状态：ok，尝试次数：  9] - 217.223950171397
# [剩余数量：236] - [当前时间：19:27:16]
#
# [状态：ok，尝试次数： 15] - 220.324530294721
# [剩余数量：235] - [当前时间：19:27:17]
#
# [状态：ok，尝试次数： 28] - 218.223950171425
# [剩余数量：234] - [当前时间：19:27:18]
#
# [状态：ok，尝试次数： 15] - 222.224165814856
# [剩余数量：233] - [当前时间：19:27:18]
#
# [状态：ok，尝试次数：  9] - 221.224164710888
# [剩余数量：232] - [当前时间：19:27:19]
#
# [状态：ok，尝试次数： 28] - 219.224393285563
# [剩余数量：231] - [当前时间：19:27:19]
#
# [状态：ok，尝试次数： 42] - 225.226095785909
# [剩余数量：230] - [当前时间：19:27:19]
#
# [状态：ok，尝试次数： 45] - 198.225446465325
# [剩余数量：229] - [当前时间：19:27:20]
#
# [状态：ok，尝试次数：  2] - 231.226095786079
# [剩余数量：228] - [当前时间：19:27:20]
#
# [状态：ok，尝试次数：  9] - 224.324304225948
# [剩余数量：227] - [当前时间：19:27:20]
#
# [状态：ok，尝试次数： 10] - 226.326091670834
# [剩余数量：226] - [当前时间：19:27:21]
#
# [状态：ok，尝试次数：  9] - 227.226095785908
# [剩余数量：225] - [当前时间：19:27:22]
#
# [状态：ok，尝试次数： 59] - 203.225083645441
# [剩余数量：224] - [当前时间：19:27:22]
#
# [状态：ok，尝试次数：  4] - 228.226095786005
# [剩余数量：223] - [当前时间：19:27:22]
#
# [状态：ok，尝试次数： 34] - 223.324304225441
# [剩余数量：222] - [当前时间：19:27:22]
#
# [状态：ok，尝试次数：  3] - 234.226095786184
# [剩余数量：221] - [当前时间：19:27:22]
#
# [状态：ok，尝试次数： 17] - 230.226095786074
# [剩余数量：220] - [当前时间：19:27:23]
#
# [状态：ok，尝试次数：  4] - 233.326091670945
# [剩余数量：219] - [当前时间：19:27:23]
#
# [状态：ok，尝试次数：  7] - 236.226095786309
# [剩余数量：218] - [当前时间：19:27:24]
#
# [状态：ok，尝试次数： 15] - 229.226095786008
# [剩余数量：217] - [当前时间：19:27:25]
#
# [状态：ok，尝试次数：  4] - 232.326091670937
# [剩余数量：216] - [当前时间：19:27:25]
#
# [状态：ok，尝试次数：  7] - 241.324107195907
# [剩余数量：215] - [当前时间：19:27:25]
#
# [状态：ok，尝试次数： 12] - 238.326091671069
# [剩余数量：214] - [当前时间：19:27:25]
#
# [状态：ok，尝试次数： 28] - 240.324303334887
# [剩余数量：213] - [当前时间：19:27:25]
#
# [状态：ok，尝试次数：  3] - 248.224164566314
# [剩余数量：212] - [当前时间：19:27:27]
#
# [状态：ok，尝试次数：  2] - 245.324303311327
# [剩余数量：211] - [当前时间：19:27:27]
#
# [状态：ok，尝试次数： 17] - 239.324303334788
# [剩余数量：210] - [当前时间：19:27:28]
#
# [状态：ok，尝试次数： 20] - 242.324107195928
# [剩余数量：209] - [当前时间：19:27:28]
#
# [状态：ok，尝试次数：  4] - 247.324110522843
# [剩余数量：208] - [当前时间：19:27:28]
#
# [状态：ok，尝试次数： 11] - 237.326091671068
# [剩余数量：207] - [当前时间：19:27:28]
#
# [状态：ok，尝试次数：  1] - 244.224165049067
# [剩余数量：206] - [当前时间：19:27:28]
#
# [状态：ok，尝试次数： 23] - 246.223953157096
# [剩余数量：205] - [当前时间：19:27:29]
#
# [状态：ok，尝试次数： 10] - 249.224164638582
# [剩余数量：204] - [当前时间：19:27:29]
#
# [状态：ok，尝试次数：  3] - 253.324304196239
# [剩余数量：203] - [当前时间：19:27:29]
#
# [状态：ok，尝试次数：  2] - 252.324304172391
# [剩余数量：202] - [当前时间：19:27:29]
#
# [状态：ok，尝试次数：  2] - 250.224164997369
# [剩余数量：201] - [当前时间：19:27:30]
#
# [状态：ok，尝试次数：  2] - 255.324304196802
# [剩余数量：200] - [当前时间：19:27:30]
#
# [状态：ok，尝试次数：  1] - 254.224165790441
# [剩余数量：199] - [当前时间：19:27:30]
#
# [状态：ok，尝试次数：  4] - 256.224165791369
# [剩余数量：198] - [当前时间：19:27:31]
#
# [状态：ok，尝试次数：  8] - 258.224164584311
# [剩余数量：197] - [当前时间：19:27:31]
#
# [状态：ok，尝试次数： 11] - 259.225083882443
# [剩余数量：196] - [当前时间：19:27:32]
#
# [状态：ok，尝试次数： 11] - 262.224164686297
# [剩余数量：195] - [当前时间：19:27:32]
#
# [状态：ok，尝试次数：  7] - 257.224164584241
# [剩余数量：194] - [当前时间：19:27:33]
#
# [状态：ok，尝试次数：  2] - 261.325277551333
# [剩余数量：193] - [当前时间：19:27:33]
#
# [状态：ok，尝试次数：  8] - 251.224165765335
# [剩余数量：192] - [当前时间：19:27:33]
#
# [状态：ok，尝试次数：  2] - 265.224328969129
# [剩余数量：191] - [当前时间：19:27:33]
#
# [状态：ok，尝试次数：  2] - 263.324303219131
# [剩余数量：190] - [当前时间：19:27:34]
#
# [状态：ok，尝试次数：  5] - 267.225083645562
# [剩余数量：189] - [当前时间：19:27:36]
#
# [状态：ok，尝试次数：  2] - 243.324303218916
# [剩余数量：188] - [当前时间：19:27:36]
#
# [状态：ok，尝试次数：  6] - 271.324302582382
# [剩余数量：187] - [当前时间：19:27:37]
#
# [状态：ok，尝试次数： 12] - 260.325277551332
# [剩余数量：186] - [当前时间：19:27:38]
#
# [状态：ok，尝试次数：  9] - 272.324304225326
# [剩余数量：185] - [当前时间：19:27:38]
#
# [状态：ok，尝试次数：  3] - 274.224165814902
# [剩余数量：184] - [当前时间：19:27:39]
#
# [状态：ok，尝试次数：  2] - 277.324304226307
# [剩余数量：183] - [当前时间：19:27:40]
#
# [状态：ok，尝试次数： 29] - 139.324220759625
# [剩余数量：182] - [当前时间：19:27:40]
#
# [状态：ok，尝试次数： 11] - 276.324304226126
# [剩余数量：181] - [当前时间：19:27:40]
#
# [状态：ok，尝试次数：  1] - 275.224165815073
# [剩余数量：180] - [当前时间：19:27:40]
#
# [状态：ok，尝试次数： 10] - 266.225083645148
# [剩余数量：179] - [当前时间：19:27:41]
#
# [状态：ok，尝试次数：  1] - 279.223989720341
# [剩余数量：178] - [当前时间：19:27:41]
#
# [状态：ok，尝试次数：  9] - 273.324304225487
# [剩余数量：177] - [当前时间：19:27:42]
#
# [状态：ok，尝试次数：  1] - 280.224164566368
# [剩余数量：176] - [当前时间：19:27:42]
#
# [状态：ok，尝试次数：  1] - 278.324146981828
# [剩余数量：175] - [当前时间：19:27:42]
#
# [状态：ok，尝试次数：  1] - 281.324593730449
# [剩余数量：174] - [当前时间：19:27:42]
#
# [状态：ok，尝试次数：  3] - 264.224162439236
# [剩余数量：173] - [当前时间：19:27:42]
#
# [状态：ok，尝试次数：  1] - 282.324593731272
# [剩余数量：172] - [当前时间：19:27:43]
#
# [状态：ok，尝试次数：  3] - 289.325277392495
# [剩余数量：171] - [当前时间：19:27:44]
#
# [状态：ok，尝试次数：  1] - 287.225083645189
# [剩余数量：170] - [当前时间：19:27:44]
#
# [状态：ok，尝试次数：  1] - 283.224441325859
# [剩余数量：169] - [当前时间：19:27:44]
#
# [状态：ok，尝试次数：  1] - 285.324593736835
# [剩余数量：168] - [当前时间：19:27:45]
#
# [状态：ok，尝试次数： 10] - 286.224441331358
# [剩余数量：167] - [当前时间：19:27:45]
#
# [状态：ok，尝试次数：  1] - 284.224441325865
# [剩余数量：166] - [当前时间：19:27:45]
#
# [状态：ok，尝试次数：  1] - 290.225083874681
# [剩余数量：165] - [当前时间：19:27:45]
#
# [状态：ok，尝试次数：  6] - 288.325277392141
# [剩余数量：164] - [当前时间：19:27:46]
#
# [状态：ok，尝试次数： 10] - 291.225083874682
# [剩余数量：163] - [当前时间：19:27:46]
#
# [状态：ok，尝试次数：  1] - 292.325277548556
# [剩余数量：162] - [当前时间：19:27:47]
#
# [状态：ok，尝试次数： 25] - 268.324304339264
# [剩余数量：161] - [当前时间：19:27:48]
#
# [状态：ok，尝试次数： 22] - 294.225083884292
# [剩余数量：160] - [当前时间：19:27:48]
#
# [状态：ok，尝试次数： 16] - 297.324303334894
# [剩余数量：159] - [当前时间：19:27:49]
#
# [状态：ok，尝试次数： 16] - 298.324303335387
# [剩余数量：158] - [当前时间：19:27:49]
#
# [状态：ok，尝试次数： 45] - 235.226095786257
# [剩余数量：157] - [当前时间：19:27:49]
#
# [状态：ok，尝试次数： 14] - 269.324304339268
# [剩余数量：156] - [当前时间：19:27:49]
#
# [状态：ok，尝试次数：  9] - 300.325158620719
# [剩余数量：155] - [当前时间：19:27:49]
#
# [状态：ok，尝试次数： 16] - 270.324302604808
# [剩余数量：154] - [当前时间：19:27:50]
#
# [状态：ok，尝试次数：  6] - 302.224950873510
# [剩余数量：153] - [当前时间：19:27:50]
#
# [状态：ok，尝试次数： 40] - 299.224950868868
# [剩余数量：152] - [当前时间：19:27:51]
#
# [状态：ok，尝试次数： 12] - 303.325694986183
# [剩余数量：151] - [当前时间：19:27:52]
#
# [状态：ok，尝试次数： 22] - 305.224164574636
# [剩余数量：150] - [当前时间：19:27:52]
#
# [状态：ok，尝试次数：  2] - 309.224546805712
# [剩余数量：149] - [当前时间：19:27:52]
#
# [状态：ok，尝试次数：  1] - 308.324727152354
# [剩余数量：148] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：  2] - 307.324184657431
# [剩余数量：147] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数： 11] - 293.225083884285
# [剩余数量：146] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：  2] - 310.223989708015
# [剩余数量：145] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：  7] - 315.324302704041
# [剩余数量：144] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：  2] - 311.225550829688
# [剩余数量：143] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：  2] - 314.325928072071
# [剩余数量：142] - [当前时间：19:27:56]
#
# [状态：ok，尝试次数：  7] - 316.324302704051
# [剩余数量：141] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：  5] - 318.223989721994
# [剩余数量：140] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：  9] - 317.324146993754
# [剩余数量：139] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：  3] - 320.224164694541
# [剩余数量：138] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：  5] - 321.324303309714
# [剩余数量：137] - [当前时间：19:27:59]
#
# [状态：ok，尝试次数：  2] - 322.224165049320
# [剩余数量：136] - [当前时间：19:28:00]
#
# [状态：ok，尝试次数：  2] - 323.324303310440
# [剩余数量：135] - [当前时间：19:28:01]
#
# [状态：ok，尝试次数：  3] - 296.324303334789
# [剩余数量：134] - [当前时间：19:28:01]
#
# [状态：ok，尝试次数：  8] - 324.224165049372
# [剩余数量：133] - [当前时间：19:28:02]
#
# [状态：ok，尝试次数：  2] - 326.324146993783
# [剩余数量：132] - [当前时间：19:28:02]
#
# [状态：ok，尝试次数： 16] - 319.224164694534
# [剩余数量：131] - [当前时间：19:28:03]
#
# [状态：ok，尝试次数：  4] - 306.224164628181
# [剩余数量：130] - [当前时间：19:28:03]
#
# [状态：ok，尝试次数： 11] - 325.223989720379
# [剩余数量：129] - [当前时间：19:28:04]
#
# [状态：ok，尝试次数：  4] - 330.324146995253
# [剩余数量：128] - [当前时间：19:28:05]
#
# [状态：ok，尝试次数： 58] - 301.325158623161
# [剩余数量：127] - [当前时间：19:28:05]
#
# [状态：ok，尝试次数：  7] - 328.223989721911
# [剩余数量：126] - [当前时间：19:28:05]
#
# [状态：ok，尝试次数：  1] - 332.325643382194
# [剩余数量：125] - [当前时间：19:28:05]
#
# [状态：ok，尝试次数：  2] - 312.324146993657
# [剩余数量：124] - [当前时间：19:28:06]
#
# [状态：ok，尝试次数：  4] - 295.324303334751
# [剩余数量：123] - [当前时间：19:28:06]
#
# [状态：ok，尝试次数：  5] - 331.223989721995
# [剩余数量：122] - [当前时间：19:28:06]
#
# [状态：ok，尝试次数：  1] - 334.225563359545
# [剩余数量：121] - [当前时间：19:28:07]
#
# [状态：ok，尝试次数：  4] - 337.325643382230
# [剩余数量：120] - [当前时间：19:28:07]
#
# [状态：ok，尝试次数： 16] - 329.223989721931
# [剩余数量：119] - [当前时间：19:28:08]
#
# [状态：ok，尝试次数：  4] - 340.326052178972
# [剩余数量：118] - [当前时间：19:28:09]
#
# [状态：ok，尝试次数：  3] - 327.324146994013
# [剩余数量：117] - [当前时间：19:28:09]
#
# [状态：ok，尝试次数：  8] - 333.225563359541
# [剩余数量：116] - [当前时间：19:28:09]
#
# [状态：ok，尝试次数： 37] - 336.325643382225
# [剩余数量：115] - [当前时间：19:28:09]
#
# [状态：ok，尝试次数： 42] - 338.225563359651
# [剩余数量：114] - [当前时间：19:28:11]
#
# [状态：ok，尝试次数：  2] - 345.224164633473
# [剩余数量：113] - [当前时间：19:28:11]
#
# [状态：ok，尝试次数： 43] - 304.224162439204
# [剩余数量：112] - [当前时间：19:28:12]
#
# [状态：ok，尝试次数：  4] - 347.324303219010
# [剩余数量：111] - [当前时间：19:28:12]
#
# [状态：ok，尝试次数： 15] - 346.224164633642
# [剩余数量：110] - [当前时间：19:28:13]
#
# [状态：ok，尝试次数： 26] - 344.224162435755
# [剩余数量：109] - [当前时间：19:28:13]
#
# [状态：ok，尝试次数： 20] - 335.225563359591
# [剩余数量：108] - [当前时间：19:28:14]
#
# [状态：ok，尝试次数： 51] - 313.225915998135
# [剩余数量：107] - [当前时间：19:28:14]
#
# [状态：ok，尝试次数：  2] - 351.324943311738
# [剩余数量：106] - [当前时间：19:28:14]
#
# [状态：ok，尝试次数： 11] - 348.224165006126
# [剩余数量：105] - [当前时间：19:28:15]
#
# [状态：ok，尝试次数：  7] - 352.324302568457
# [剩余数量：104] - [当前时间：19:28:15]
#
# [状态：ok，尝试次数：  1] - 354.225549636524
# [剩余数量：103] - [当前时间：19:28:16]
#
# [状态：ok，尝试次数： 54] - 342.224162422786
# [剩余数量：102] - [当前时间：19:28:16]
#
# [状态：ok，尝试次数：  4] - 353.224164590063
# [剩余数量：101] - [当前时间：19:28:16]
#
# [状态：ok，尝试次数： 25] - 341.326052178973
# [剩余数量：100] - [当前时间：19:28:18]
#
# [状态：ok，尝试次数：  5] - 357.223989720111
# [剩余数量：99] - [当前时间：19:28:19]
#
# [状态：ok，尝试次数： 17] - 356.324146993441
# [剩余数量：98] - [当前时间：19:28:19]
#
# [状态：ok，尝试次数：  6] - 339.325643382276
# [剩余数量：97] - [当前时间：19:28:19]
#
# [状态：ok，尝试次数： 20] - 355.225550829686
# [剩余数量：96] - [当前时间：19:28:19]
#
# [状态：ok，尝试次数： 23] - 360.223989722022
# [剩余数量：95] - [当前时间：19:28:21]
#
# [状态：ok，尝试次数：  1] - 365.225812008314
# [剩余数量：94] - [当前时间：19:28:21]
#
# [状态：ok，尝试次数： 10] - 359.223989721944
# [剩余数量：93] - [当前时间：19:28:21]
#
# [状态：ok，尝试次数：  3] - 362.225893462945
# [剩余数量：92] - [当前时间：19:28:21]
#
# [状态：ok，尝试次数：  7] - 358.223989720118
# [剩余数量：91] - [当前时间：19:28:21]
#
# [状态：ok，尝试次数：  2] - 366.325843816199
# [剩余数量：90] - [当前时间：19:28:22]
#
# [状态：ok，尝试次数：  7] - 364.324184657492
# [剩余数量：89] - [当前时间：19:28:22]
#
# [状态：ok，尝试次数： 30] - 343.324300841620
# [剩余数量：88] - [当前时间：19:28:22]
#
# [状态：ok，尝试次数：  3] - 363.224030760982
# [剩余数量：87] - [当前时间：19:28:23]
#
# [状态：ok，尝试次数： 26] - 361.224441334887
# [剩余数量：86] - [当前时间：19:28:23]
#
# [状态：ok，尝试次数：  2] - 367.324302581746
# [剩余数量：85] - [当前时间：19:28:23]
#
# [状态：ok，尝试次数： 12] - 370.224164638561
# [剩余数量：84] - [当前时间：19:28:24]
#
# [状态：ok，尝试次数：  8] - 369.324302607988
# [剩余数量：83] - [当前时间：19:28:24]
#
# [状态：ok，尝试次数： 13] - 371.324303186657
# [剩余数量：82] - [当前时间：19:28:25]
#
# [状态：ok，尝试次数：  2] - 376.324184641546
# [剩余数量：81] - [当前时间：19:28:25]
#
# [状态：ok，尝试次数：  3] - 372.224164997597
# [剩余数量：80] - [当前时间：19:28:25]
#
# [状态：ok，尝试次数：  5] - 377.324300823299
# [剩余数量：79] - [当前时间：19:28:26]
#
# [状态：ok，尝试次数： 10] - 368.324302581755
# [剩余数量：78] - [当前时间：19:28:27]
#
# [状态：ok，尝试次数： 31] - 374.324184641510
# [剩余数量：77] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数： 30] - 375.324184641519
# [剩余数量：76] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数： 18] - 349.223989720146
# [剩余数量：75] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数： 16] - 379.225083645147
# [剩余数量：74] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数：  8] - 380.225083645311
# [剩余数量：73] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数：  4] - 381.224164566236
# [剩余数量：72] - [当前时间：19:28:28]
#
# [状态：ok，尝试次数： 11] - 373.324184640755
# [剩余数量：71] - [当前时间：19:28:29]
#
# [状态：ok，尝试次数：  1] - 382.224164566597
# [剩余数量：70] - [当前时间：19:28:29]
#
# [状态：ok，尝试次数： 12] - 378.324300823319
# [剩余数量：69] - [当前时间：19:28:29]
#
# [状态：ok，尝试次数： 12] - 383.224165006133
# [剩余数量：68] - [当前时间：19:28:30]
#
# [状态：ok，尝试次数： 23] - 350.223989722041
# [剩余数量：67] - [当前时间：19:28:30]
#
# [状态：ok，尝试次数：  1] - 384.324303220181
# [剩余数量：66] - [当前时间：19:28:30]
#
# [状态：ok，尝试次数：  2] - 387.326021087630
# [剩余数量：65] - [当前时间：19:28:30]
#
# [状态：ok，尝试次数：  1] - 386.226013631464
# [剩余数量：64] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数： 11] - 388.224165765375
# [剩余数量：63] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数：  5] - 389.224165765434
# [剩余数量：62] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数： 16] - 390.224165773650
# [剩余数量：61] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数：  1] - 385.326021087569
# [剩余数量：60] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数：  3] - 391.224165773820
# [剩余数量：59] - [当前时间：19:28:32]
#
# [状态：ok，尝试次数：  1] - 394.224165790304
# [剩余数量：58] - [当前时间：19:28:33]
#
# [状态：ok，尝试次数：  9] - 392.224165790243
# [剩余数量：57] - [当前时间：19:28:33]
#
# [状态：ok，尝试次数： 13] - 396.224165791032
# [剩余数量：56] - [当前时间：19:28:33]
#
# [状态：ok，尝试次数：  9] - 395.224165791028
# [剩余数量：55] - [当前时间：19:28:33]
#
# [状态：ok，尝试次数：  1] - 393.224165790288
# [剩余数量：54] - [当前时间：19:28:34]
#
# [状态：ok，尝试次数：  1] - 404.223989721924
# [剩余数量：53] - [当前时间：19:28:35]
#
# [状态：ok，尝试次数：  4] - 399.324304197237
# [剩余数量：52] - [当前时间：19:28:35]
#
# [状态：ok，尝试次数：  4] - 400.325632464069
# [剩余数量：51] - [当前时间：19:28:35]
#
# [状态：ok，尝试次数：  7] - 403.324146993435
# [剩余数量：50] - [当前时间：19:28:36]
#
# [状态：ok，尝试次数：  7] - 406.324593738304
# [剩余数量：49] - [当前时间：19:28:36]
#
# [状态：ok，尝试次数： 13] - 407.225563359592
# [剩余数量：48] - [当前时间：19:28:36]
#
# [状态：ok，尝试次数： 24] - 398.224165791121
# [剩余数量：47] - [当前时间：19:28:37]
#
# [状态：ok，尝试次数：  2] - 401.225550829692
# [剩余数量：46] - [当前时间：19:28:37]
#
# [状态：ok，尝试次数： 38] - 402.325632464091
# [剩余数量：45] - [当前时间：19:28:37]
#
# [状态：ok，尝试次数： 51] - 397.224165791075
# [剩余数量：44] - [当前时间：19:28:37]
#
# [状态：ok，尝试次数： 27] - 408.225563359656
# [剩余数量：43] - [当前时间：19:28:38]
#
# [状态：ok，尝试次数：  6] - 412.226002644551
# [剩余数量：42] - [当前时间：19:28:38]
#
# [状态：ok，尝试次数：  5] - 409.226002644496
# [剩余数量：41] - [当前时间：19:28:38]
#
# [状态：ok，尝试次数：  5] - 411.226002644547
# [剩余数量：40] - [当前时间：19:28:39]
#
# [状态：ok，尝试次数： 22] - 415.324300841637
# [剩余数量：39] - [当前时间：19:28:40]
#
# [状态：ok，尝试次数： 35] - 405.324593735812
# [剩余数量：38] - [当前时间：19:28:40]
#
# [状态：ok，尝试次数： 18] - 414.224162422751
# [剩余数量：37] - [当前时间：19:28:40]
#
# [状态：ok，尝试次数：  6] - 417.224164566363
# [剩余数量：36] - [当前时间：19:28:41]
#
# [状态：ok，尝试次数： 36] - 416.224162439200
# [剩余数量：35] - [当前时间：19:28:41]
#
# [状态：ok，尝试次数：  4] - 413.324300829919
# [剩余数量：34] - [当前时间：19:28:41]
#
# [状态：ok，尝试次数：  5] - 419.324302564509
# [剩余数量：33] - [当前时间：19:28:42]
#
# [状态：ok，尝试次数：  1] - 424.325165670164
# [剩余数量：32] - [当前时间：19:28:42]
#
# [状态：ok，尝试次数： 10] - 423.325165669890
# [剩余数量：31] - [当前时间：19:28:43]
#
# [状态：ok，尝试次数： 19] - 418.224164566396
# [剩余数量：30] - [当前时间：19:28:43]
#
# [状态：ok，尝试次数：  5] - 422.324302564622
# [剩余数量：29] - [当前时间：19:28:43]
#
# [状态：ok，尝试次数：  9] - 420.324302564528
# [剩余数量：28] - [当前时间：19:28:43]
#
# [状态：ok，尝试次数： 18] - 421.324302564601
# [剩余数量：27] - [当前时间：19:28:44]
#
# [状态：ok，尝试次数：  4] - 430.224415210751
# [剩余数量：26] - [当前时间：19:28:44]
#
# [状态：ok，尝试次数：  9] - 428.324559541994
# [剩余数量：25] - [当前时间：19:28:44]
#
# [状态：ok，尝试次数： 10] - 427.224441324420
# [剩余数量：24] - [当前时间：19:28:45]
#
# [状态：ok，尝试次数：  1] - 429.324559542342
# [剩余数量：23] - [当前时间：19:28:45]
#
# [状态：ok，尝试次数：  4] - 431.224415211085
# [剩余数量：22] - [当前时间：19:28:46]
#
# [状态：ok，尝试次数：  8] - 435.224348399333
# [剩余数量：21] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数：  4] - 434.324184663284
# [剩余数量：20] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数：  3] - 433.224164628188
# [剩余数量：19] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数：  5] - 432.224164628174
# [剩余数量：18] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数：  2] - 437.324483099369
# [剩余数量：17] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数：  3] - 425.224959361521
# [剩余数量：16] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数： 27] - 410.326009616460
# [剩余数量：15] - [当前时间：19:28:47]
#
# [状态：ok，尝试次数： 17] - 438.224348407500
# [剩余数量：14] - [当前时间：19:28:48]
#
# [状态：ok，尝试次数：  1] - 446.324146997330
# [剩余数量：13] - [当前时间：19:28:49]
#
# [状态：ok，尝试次数：  4] - 440.324184649704
# [剩余数量：12] - [当前时间：19:28:49]
#
# [状态：ok，尝试次数： 23] - 439.324483099556
# [剩余数量：11] - [当前时间：19:28:49]
#
# [状态：ok，尝试次数：  2] - 444.324146997283
# [剩余数量：10] - [当前时间：19:28:49]
#
# [状态：ok，尝试次数：  2] - 441.223989723809
# [剩余数量：9] - [当前时间：19:28:50]
#
# [状态：ok，尝试次数： 25] - 445.223989723905
# [剩余数量：8] - [当前时间：19:28:50]
#
# [状态：ok，尝试次数： 13] - 447.223989723988
# [剩余数量：7] - [当前时间：19:28:51]
#
# [状态：ok，尝试次数： 11] - 448.224441329442
# [剩余数量：6] - [当前时间：19:28:51]
#
# [状态：ok，尝试次数： 42] - 442.223989723840
# [剩余数量：5] - [当前时间：19:28:51]
#
# [状态：ok，尝试次数：  7] - 452.324602810332
# [剩余数量：4] - [当前时间：19:28:52]
#
# [状态：ok，尝试次数： 36] - 443.223989723861
# [剩余数量：3] - [当前时间：19:28:52]
#
# [状态：ok，尝试次数： 28] - 450.224448723269
# [剩余数量：2] - [当前时间：19:28:53]
#
# [状态：ok，尝试次数：  1] - 456.224030767401
# [剩余数量：1] - [当前时间：19:28:53]
#
# [状态：ok，尝试次数： 33] - 454.324220978203
# [剩余数量：0] - [当前时间：19:28:55]
#
# [状态：ok，尝试次数： 58] - 449.224030746906
# [剩余数量：0] - [当前时间：19:28:55]
#
# [状态：ok，尝试次数： 11] - 458.324184663257
# [剩余数量：0] - [当前时间：19:28:56]
#
# [状态：ok，尝试次数：  2] - 460.324184659149
# [剩余数量：0] - [当前时间：19:28:56]
#
# [状态：ok，尝试次数：  7] - 461.224030762701
# [剩余数量：0] - [当前时间：19:28:56]
#
# [状态：ok，尝试次数： 10] - 436.224348399747
# [剩余数量：0] - [当前时间：19:28:57]
#
# [状态：ok，尝试次数： 44] - 457.224030767402
# [剩余数量：0] - [当前时间：19:28:57]
#
# [状态：ok，尝试次数： 51] - 455.324632488554
# [剩余数量：0] - [当前时间：19:28:58]
#
# [状态：ok，尝试次数： 21] - 459.325492805263
# [剩余数量：0] - [当前时间：19:28:59]
#
# [状态：ok，尝试次数： 11] - 451.324602797489
# [剩余数量：0] - [当前时间：19:29:01]
#
# [状态：ok，尝试次数： 34] - 453.324602810684
# [剩余数量：0] - [当前时间：19:29:04]
#
# [状态：ok，尝试次数： 14] - 426.224959361533
# [剩余数量：0] - [当前时间：19:29:06]
#
# 输出ing...
#
# Done ~
