# %%
item_number = '256756876675'

item_number
# Out:
# '256756876675'

# %%
from fabric import Connection

# %%
conn = Connection(host='152.32.150.9',
                  user='root',
                  connect_kwargs={'password': 'deepseek110@'})

conn.run(f'cd /home/Lennon/lennon_env/code/scrapy/scrapy_03_eBay_Compatibility && /home/Lennon/lennon_env/bin/python -m scrapy crawl eBay -a item_number="{item_number}" && /home/Lennon/lennon_env/bin/python Step04Format.py')
# Out:
# *  = = =  *  = = =  *  = = =  Log  = = =  *  = = =  *  = = =
# item_number
#
# 256756876675
# *  = = =  *  = = =  *  = = =  * *  = = =  *  = = =  *  = = =
#
# *  = = =  *  = = =  *  = = =  Log  = = =  *  = = =  *  = = =
# vehicle_wo_engine
#
# Audi A3 2007-2014
# Volkswagen Beetle 2005-2014
# Volkswagen CC 2009-2014
# Volkswagen GTI 2006-2014
# Volkswagen Golf 2005-2013
# Volkswagen Jetta 2005-2014
# Volkswagen Passat 2007-2015
# Volkswagen Rabbit 2006-2009
# Volkswagen Tiguan 2009-2015
# *  = = =  *  = = =  *  = = =  * *  = = =  *  = = =  *  = = =
#
# *  = = =  *  = = =  *  = = =  Log  = = =  *  = = =  *  = = =
# vehicle_w_engine
#
# Audi A3 2007-2011 2.0L 1984CC 121Cu. In. l4 GAS DOHC Naturally Aspirated
# Audi A3 2007-2013 2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged
# Audi A3 2008-2013 1.4L 1390CC 85Cu. In. l4 GAS DOHC Turbocharged
# Audi A3 2008-2014 1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged
# Audi A3 2010-2013 2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged
# ...
