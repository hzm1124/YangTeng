# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230822.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate,
                   sheet_name='附_1统计源（含新品、清仓、新品成长）',
                   header=3,
                   usecols=[2, 3, 5, 11, 12])

df
# Out:
#                  MRP SKU  目标\n周销  Level   在库   在途
# 0      USTCV17215HIE-2-C   28.84   TOP1  123  340
# 1           USTBC40007-C   38.00   TOP1  248  338
# 2         USBDA04108-2-C   24.85   TOP1  126  168
# 3           USET87039H-C   19.57   TOP1  118  101
# 4           USGSM3570T-C   20.47  TOP10  240   40
# ...                  ...     ...    ...  ...  ...
# 56520  USWSP65508B1-2-YC    1.00     普通    0   10
# 56521  USWSP54521B1-4-YC    1.00  TOP20    0   10
# 56522  USWSP54717B1-4-YC    1.00     普通    0   10
# 56523  USWSP54717B1-2-YC    0.50     普通    0    6
# 56524       USACC11756-C    1.50  TOP10    0   19
#
# [56525 rows x 5 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU',
                                                                   'Level',
                                                                   '目标\n周销',
                                                                   '在途']]

df
# Out:
#             MRP SKU  Level  目标\n周销  在途
# 10      USOC19109-C  TOP20    2.14   0
# 26       USFSU17500  TOP20   12.60   0
# 202     USHB90685-C  TOP20    3.55   0
# 990     USDS36727-C  TOP10    3.47   0
# 1741   USALT11508-C  TOP20    0.63   0
# ...             ...    ...     ...  ..
# 52670   USDS76746-C  TOP10    2.04   0
# 53085  USACC29043-C  TOP10    4.25   0
# 53087  USACC29136-C  TOP20    3.82   0
# 53217  USACC29103-C  TOP10    5.60   0
# 53250  USCAK54524LR  TOP20    0.82   0
#
# [79 rows x 4 columns]

# %%
df = df.sort_values(by=['Level', 'MRP SKU'], ascending=[True, True])

df
# Out:
#              MRP SKU  Level  目标\n周销  在途
# 7993    USACC98315-C   TOP1    1.76   0
# 34779   USCON32370-C   TOP1    6.80   0
# 37837   USPBB27358-C   TOP1    1.49   0
# 22458   USPSR221014G   TOP1    2.62   0
# 53085   USACC29043-C  TOP10    4.25   0
# ...              ...    ...     ...  ..
# 39564      USSS00004  TOP20    0.00   0
# 1743    USSTR30639-C  TOP20    1.70   0
# 35499  USSTR66760B-C  TOP20    3.40   0
# 32826  USWHN11094-20  TOP20    2.12   0
# 32893  USWHN11288-12  TOP20    0.10   0
#
# [79 rows x 4 columns]

# %%
import datetime

# %%
writer = pd.ExcelWriter('Lennon_筛选好的断货SKU_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.xlsx')
df.to_excel(writer, index=False)
writer.close()
