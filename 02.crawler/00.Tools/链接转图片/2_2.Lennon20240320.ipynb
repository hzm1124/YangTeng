# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from openpyxl import load_workbook
from openpyxl.utils import get_column_letter

# = = = = = = = = = = = = = = =

wb = load_workbook('./part.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        column_src = column
    elif ws.cell(1, column).value == 'Pic':
        column_pic = column
        
print('总数量：' + str(ws.max_row-1))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

from io import BytesIO
from PIL import Image

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(1, ws.max_row):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global ws
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                if ws.cell(a+1, column_src).value == None or ws.cell(a+1, column_src).value == '':
                    crawler_status = 'ok'
                    break
                    
                # = = = = = = = = = = = = = = =
                
                src = ws.cell(a+1, column_src).value

                pic = Image.open(BytesIO(requests.get(src,
                                                          headers=UA.get_User_Agent_Requests(),
                                                          proxies=Proxy.get_Proxy_Requests()).content)).convert('RGB')

                # = = = = = = = = = = = = = = =
                
                pic.save('./pic/' + str(a) + '.png', 'png')
                
                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + src +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
         
        # = = = = = = = = = = = = = = =

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(12):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('Done ~')
# Out:
# 总数量：100
#
# [ok] - https://m.media-amazon.com/images/I/611j7eYXbuL._AC_SX450_.jpg
# [尝试次数：1] - [剩余数量：88] - [当前时间：09:42:23]
#
# [ok] - https://m.media-amazon.com/images/I/71+GhBcOAnL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：87] - [当前时间：09:42:23]
#
# [ok] - https://m.media-amazon.com/images/I/7140H16K8WL._AC_SY450_.jpg
# [尝试次数：1] - [剩余数量：86] - [当前时间：09:42:23]
#
# [ok] - https://m.media-amazon.com/images/I/718Od0AuOYL._AC_SY450_.jpg
# [尝试次数：3] - [剩余数量：85] - [当前时间：09:42:24]
#
# [ok] - https://m.media-amazon.com/images/I/71gRdrdGJ7L._AC_SY450_.jpg
# [尝试次数：3] - [剩余数量：84] - [当前时间：09:42:25]
#
# [ok] - https://m.media-amazon.com/images/I/71IRM+4bOhL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：83] - [当前时间：09:42:25]
#
# [ok] - https://m.media-amazon.com/images/I/61fNgo5ydEL._AC_SY450_.jpg
# [尝试次数：7] - [剩余数量：82] - [当前时间：09:42:26]
#
# [ok] - https://m.media-amazon.com/images/I/81DZgXXDjNL.__AC_SY300_SX300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：81] - [当前时间：09:42:26]
#
# [ok] - https://m.media-amazon.com/images/I/71YZI7Fze5L._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：80] - [当前时间：09:42:26]
#
# [ok] - https://m.media-amazon.com/images/I/61kT4ZdKSGL._AC_SY450_.jpg
# [尝试次数：7] - [剩余数量：79] - [当前时间：09:42:26]
#
# [ok] - https://m.media-amazon.com/images/I/618XmW0WcrL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：78] - [当前时间：09:42:26]
#
# [ok] - https://m.media-amazon.com/images/I/71bwY2zSy4L._AC_SY450_.jpg
# [尝试次数：8] - [剩余数量：77] - [当前时间：09:42:27]
#
# [ok] - https://m.media-amazon.com/images/I/71ZkhGfPSHL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：12] - [剩余数量：76] - [当前时间：09:42:27]
#
# [ok] - https://m.media-amazon.com/images/I/71KagRpn4gL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：75] - [当前时间：09:42:27]
#
# [ok] - https://m.media-amazon.com/images/I/61boVeAVgAS._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：74] - [当前时间：09:42:28]
#
# [ok] - https://m.media-amazon.com/images/I/71G9tbahFNL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：11] - [剩余数量：73] - [当前时间：09:42:28]
#
# [ok] - https://m.media-amazon.com/images/I/61WudW7aloL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：3] - [剩余数量：72] - [当前时间：09:42:28]
#
# [ok] - https://m.media-amazon.com/images/I/51NWf8BYpHS._AC_SY450_.jpg
# [尝试次数：1] - [剩余数量：71] - [当前时间：09:42:29]
#
# [ok] - https://m.media-amazon.com/images/I/71FtRDyVpgL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：70] - [当前时间：09:42:29]
#
# [ok] - https://m.media-amazon.com/images/I/71BOQps72iL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：3] - [剩余数量：69] - [当前时间：09:42:30]
#
# [ok] - https://m.media-amazon.com/images/I/61EjuvtKajL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：5] - [剩余数量：68] - [当前时间：09:42:30]
#
# [ok] - https://m.media-amazon.com/images/I/61a3+Pwp3KL._AC_SY450_.jpg
# [尝试次数：1] - [剩余数量：67] - [当前时间：09:42:30]
#
# [ok] - https://m.media-amazon.com/images/I/61oNmMpeDhL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：66] - [当前时间：09:42:30]
#
# [ok] - https://m.media-amazon.com/images/I/71VmGNFAWWL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：10] - [剩余数量：65] - [当前时间：09:42:31]
#
# [ok] - https://m.media-amazon.com/images/I/51cc9T6MrCL._AC_SY606_.jpg
# [尝试次数：5] - [剩余数量：64] - [当前时间：09:42:32]
#
# [ok] - https://m.media-amazon.com/images/I/71ZZgMEhIxL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：5] - [剩余数量：63] - [当前时间：09:42:32]
#
# [ok] - https://m.media-amazon.com/images/I/71ngfIcXq2L.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：18] - [剩余数量：62] - [当前时间：09:42:33]
#
# [ok] - https://m.media-amazon.com/images/I/61KzewmhS0S._AC_SY450_.jpg
# [尝试次数：10] - [剩余数量：61] - [当前时间：09:42:33]
#
# [ok] - https://m.media-amazon.com/images/I/61KjcwPmaFL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：60] - [当前时间：09:42:34]
#
# [ok] - https://m.media-amazon.com/images/I/61SlIcpiFiL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：59] - [当前时间：09:42:34]
#
# [ok] - https://m.media-amazon.com/images/I/61-6DsuC-3L._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：58] - [当前时间：09:42:34]
#
# [ok] - https://m.media-amazon.com/images/I/715uIDlCPIL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：10] - [剩余数量：57] - [当前时间：09:42:35]
#
# [ok] - https://m.media-amazon.com/images/I/71-dqG1l2yL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：5] - [剩余数量：56] - [当前时间：09:42:35]
#
# [ok] - https://m.media-amazon.com/images/I/51cc9T6MrCL._AC_SY606_.jpg
# [尝试次数：23] - [剩余数量：55] - [当前时间：09:42:36]
#
# [ok] - https://m.media-amazon.com/images/I/51NGASy3DKL._AC_SY450_.jpg
# [尝试次数：3] - [剩余数量：54] - [当前时间：09:42:36]
#
# [ok] - https://m.media-amazon.com/images/I/71jPJB4EDGL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：18] - [剩余数量：53] - [当前时间：09:42:36]
#
# [ok] - https://m.media-amazon.com/images/I/61Vl9rV9-1L.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：13] - [剩余数量：52] - [当前时间：09:42:36]
#
# [ok] - https://m.media-amazon.com/images/I/71jEnHtU+xL._AC_SY300_SX300_.jpg
# [尝试次数：4] - [剩余数量：51] - [当前时间：09:42:37]
#
# [ok] - https://m.media-amazon.com/images/I/61YaS2xKWVL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：4] - [剩余数量：50] - [当前时间：09:42:37]
#
# [ok] - https://m.media-amazon.com/images/I/717n936LC-L._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：49] - [当前时间：09:42:37]
#
# [ok] - https://m.media-amazon.com/images/I/61gxLD3dYiL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：48] - [当前时间：09:42:39]
#
# [ok] - https://m.media-amazon.com/images/I/417JJgYzZgL._AC_SX450_.jpg
# [尝试次数：4] - [剩余数量：47] - [当前时间：09:42:39]
#
# [ok] - https://m.media-amazon.com/images/I/91v854ngJWL._AC_SX466_.jpg
# [尝试次数：4] - [剩余数量：46] - [当前时间：09:42:39]
#
# [ok] - https://m.media-amazon.com/images/I/61kpreVGDXL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：45] - [当前时间：09:42:40]
#
# [ok] - https://m.media-amazon.com/images/I/81SEuIIx8hL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：44] - [当前时间：09:42:40]
#
# [ok] - https://m.media-amazon.com/images/I/71quaxz3peS.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：16] - [剩余数量：43] - [当前时间：09:42:40]
#
# [ok] - https://m.media-amazon.com/images/I/61tkUj8ZdAL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：42] - [当前时间：09:42:40]
#
# [ok] - https://m.media-amazon.com/images/I/6159KNMSGOL._AC_SY450_.jpg
# [尝试次数：9] - [剩余数量：41] - [当前时间：09:42:41]
#
# [ok] - https://m.media-amazon.com/images/I/71vul4ZW5ZL._AC_SX450_.jpg
# [尝试次数：2] - [剩余数量：40] - [当前时间：09:42:41]
#
# [ok] - https://m.media-amazon.com/images/I/71gk1YXc+zL._AC_SY300_SX300_.jpg
# [尝试次数：15] - [剩余数量：39] - [当前时间：09:42:42]
#
# [ok] - https://m.media-amazon.com/images/I/81uK8uIUQbL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：38] - [当前时间：09:42:42]
#
# [ok] - https://m.media-amazon.com/images/I/717ijrhoQxL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：37] - [当前时间：09:42:42]
#
# [ok] - https://m.media-amazon.com/images/I/71IxXnvZIkL._AC_SY450_.jpg
# [尝试次数：8] - [剩余数量：36] - [当前时间：09:42:43]
#
# [ok] - https://m.media-amazon.com/images/I/81W2hr1SOLL._AC_SX466_.jpg
# [尝试次数：5] - [剩余数量：35] - [当前时间：09:42:43]
#
# [ok] - https://m.media-amazon.com/images/I/615V1kbZJJS._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：34] - [当前时间：09:42:44]
#
# [ok] - https://m.media-amazon.com/images/I/611gAq6AL6L._AC_SY450_.jpg
# [尝试次数：1] - [剩余数量：33] - [当前时间：09:42:44]
#
# [ok] - https://m.media-amazon.com/images/I/61uYmVwsjFL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：32] - [当前时间：09:42:45]
#
# [ok] - https://m.media-amazon.com/images/I/61vFpJSE5-L.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：31] - [当前时间：09:42:45]
#
# [ok] - https://m.media-amazon.com/images/I/61Ig3CASFZL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：9] - [剩余数量：30] - [当前时间：09:42:45]
#
# [ok] - https://m.media-amazon.com/images/I/61RkJhImi0L._AC_SY450_PIbundle-3,TopRight,0,0_SH20_.jpg
# [尝试次数：5] - [剩余数量：29] - [当前时间：09:42:45]
#
# [ok] - https://m.media-amazon.com/images/I/71QxDgeyzWL._AC_SY450_.jpg
# [尝试次数：11] - [剩余数量：28] - [当前时间：09:42:45]
#
# [ok] - https://m.media-amazon.com/images/I/51llFOl4vYL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：13] - [剩余数量：27] - [当前时间：09:42:46]
#
# [ok] - https://m.media-amazon.com/images/I/712FWl16+ZL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：26] - [当前时间：09:42:47]
#
# [ok] - https://m.media-amazon.com/images/I/61Qd1cl-dNL._AC_SX450_.jpg
# [尝试次数：1] - [剩余数量：25] - [当前时间：09:42:47]
#
# [ok] - https://m.media-amazon.com/images/I/71fyNlpKXIL._AC_SY450_.jpg
# [尝试次数：5] - [剩余数量：24] - [当前时间：09:42:48]
#
# [ok] - https://m.media-amazon.com/images/I/41aU3GGFDeL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：23] - [当前时间：09:42:48]
#
# [ok] - https://m.media-amazon.com/images/I/61MhjXPwjKL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：22] - [当前时间：09:42:48]
#
# [ok] - https://m.media-amazon.com/images/I/61w+WsdwlZL._AC_SY450_.jpg
# [尝试次数：8] - [剩余数量：21] - [当前时间：09:42:49]
#
# [ok] - https://m.media-amazon.com/images/I/61MqRrEFu-L._AC_SY450_PIbundle-3,TopRight,0,0_SH20_.jpg
# [尝试次数：10] - [剩余数量：20] - [当前时间：09:42:49]
#
# [ok] - https://m.media-amazon.com/images/I/71SBevXafZL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：19] - [当前时间：09:42:49]
#
# [ok] - https://m.media-amazon.com/images/I/71tHMY1o+HL._AC_SY450_.jpg
# [尝试次数：2] - [剩余数量：18] - [当前时间：09:42:49]
# [ok] - https://m.media-amazon.com/images/I/61TFCrcAFCL._AC_SX450_.jpg
# [尝试次数：5] - [剩余数量：17] - [当前时间：09:42:50]
#
# [ok] - https://m.media-amazon.com/images/I/719QWouUnPL._AC_SY450_.jpg
# [尝试次数：10] - [剩余数量：16] - [当前时间：09:42:50]
#
# [ok] - https://m.media-amazon.com/images/I/71uH2d-omRL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：6] - [剩余数量：15] - [当前时间：09:42:50]
#
# [ok] - https://m.media-amazon.com/images/I/71lH17OMfIL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：14] - [当前时间：09:42:50]
#
# [ok] - https://m.media-amazon.com/images/I/41ZEGSdP9EL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：13] - [当前时间：09:42:51]
#
# [ok] - https://m.media-amazon.com/images/I/61VH9GuZ9tL._AC_SY450_.jpg
# [尝试次数：4] - [剩余数量：12] - [当前时间：09:42:52]
#
# [ok] - https://m.media-amazon.com/images/I/51ljzlz2H4L.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：11] - [当前时间：09:42:52]
#
# [ok] - https://m.media-amazon.com/images/I/615930QZioL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：10] - [当前时间：09:42:52]
#
# [ok] - https://m.media-amazon.com/images/I/51VRU85ACjL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：9] - [当前时间：09:42:54]
#
# [ok] - https://m.media-amazon.com/images/I/71fykS1LhSL._AC_SY450_.jpg
# [尝试次数：11] - [剩余数量：8] - [当前时间：09:42:54]
#
# [ok] - https://m.media-amazon.com/images/I/61sYpNHH0AL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：7] - [当前时间：09:42:54]
#
# [ok] - https://m.media-amazon.com/images/I/417JJgYzZgL.__AC_SY300_SX300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：6] - [当前时间：09:42:55]
#
# [ok] - https://m.media-amazon.com/images/I/61+mYdaxzqL._AC_SY300_SX300_.jpg
# [尝试次数：3] - [剩余数量：5] - [当前时间：09:42:55]
#
# [ok] - https://m.media-amazon.com/images/I/41BY+2lPxrL._AC_SX450_.jpg
# [尝试次数：11] - [剩余数量：4] - [当前时间：09:42:55]
#
# [ok] - https://m.media-amazon.com/images/I/617kARLpPvL._AC_SY450_.jpg
# [尝试次数：1] - [剩余数量：3] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/71TQktVd4mL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：2] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/61WOmU5BDKL._AC_SY450_.jpg
# [尝试次数：4] - [剩余数量：1] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/61C3m6mwgSL._AC_SY450_.jpg
# [尝试次数：18] - [剩余数量：0] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/61Xfn9fcmPL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：1] - [剩余数量：0] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/61InkhNH+gL._AC_SY450_.jpg
# [尝试次数：11] - [剩余数量：0] - [当前时间：09:42:56]
#
# [ok] - https://m.media-amazon.com/images/I/61H4G1N9AiL._SX385_.jpg
# [尝试次数：1] - [剩余数量：0] - [当前时间：09:42:57]
#
# [ok] - https://m.media-amazon.com/images/I/71fSSr-eZZL._AC_SX450_.jpg
# [尝试次数：3] - [剩余数量：0] - [当前时间：09:42:58]
#
# [ok] - https://m.media-amazon.com/images/I/41RZd9TZtjL._AC_SX450_.jpg
# [尝试次数：6] - [剩余数量：0] - [当前时间：09:42:59]
#
# [ok] - https://m.media-amazon.com/images/I/61CQw8A7-jL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：2] - [剩余数量：0] - [当前时间：09:42:59]
#
# [ok] - https://m.media-amazon.com/images/I/71qS012XYvL._AC_SY450_.jpg
# [尝试次数：10] - [剩余数量：0] - [当前时间：09:43:00]
#
# [ok] - https://m.media-amazon.com/images/I/41BY+2lPxrL._AC_SX450_.jpg
# [尝试次数：2] - [剩余数量：0] - [当前时间：09:43:05]
#
# [ok] - https://m.media-amazon.com/images/I/61GCUL7p3sS.__AC_SX300_SY300_QL70_FMwebp_.jpg
# [尝试次数：10] - [剩余数量：0] - [当前时间：09:43:05]
#
# [ok] - https://m.media-amazon.com/images/I/815-+KAVVDL._AC_SX450_.jpg
# [尝试次数：22] - [剩余数量：0] - [当前时间：09:43:06]
#
# [ok] - https://m.media-amazon.com/images/I/71H-pMP+PEL._AC_SY450_.jpg
# [尝试次数：3] - [剩余数量：0] - [当前时间：09:43:10]
#
# Done ~
