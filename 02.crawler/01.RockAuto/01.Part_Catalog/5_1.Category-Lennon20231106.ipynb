# %%
param_make = 'ALFA ROMEO'

# %%
import pandas as pd

# %%
df = pd.read_excel('./' + param_make + '/4.engine.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_make = df['Make'].tolist()
list_year = df['Year'].tolist()
list_model = df['Model'].tolist()
list_engine = df['Engine'].tolist()
list_car_code = df['Car_Code'].tolist()

print('总数量：' + str(len(list_engine)))
list_engine
# Out:
# 总数量：80
# ['GIULIA',
#  'GIULIA',
#  'STELVIO',
#  'STELVIO',
#  'TONALE',
#  'GIULIA',
#  'GIULIA',
#  'STELVIO',
#  'STELVIO',
#  'GIULIA',
#  'GIULIA',
#  'STELVIO',
#  'STELVIO',
#  'GIULIA',
#  'GIULIA',
#  'GIULIETTA',
#  'STELVIO',
#  'STELVIO',
#  '4C',
#  'GIULIA',
#  'GIULIA',
#  'GIULIETTA',
#  'STELVIO',
#  'STELVIO',
#  '4C',
#  'GIULIA',
#  'GIULIA',
#  'GIULIETTA',
#  'MITO',
#  'STELVIO',
#  'STELVIO',
#  '4C',
#  'GIULIA',
#  'GIULIA',
#  'GIULIETTA',
#  'MITO',
#  'STELVIO',
#  'STELVIO',
#  '4C',
#  'GIULIA',
#  'GIULIA',
#  'GIULIETTA',
#  'MITO',
#  'STELVIO',
#  '4C',
#  'GIULIETTA',
#  'MITO',
#  '4C',
#  'GIULIETTA',
#  'MITO',
#  'GIULIETTA',
#  'GIULIETTA',
#  'MITO',
#  '159',
#  '159',
#  'GIULIETTA',
#  'MITO',
#  '159',
#  '8C',
#  'BRERA',
#  'GT',
#  'SPIDER',
#  '147',
#  '159',
#  'BRERA',
#  'GT',
#  'GT',
#  'SPIDER',
#  '147',
#  '147',
#  '147',
#  '156',
#  '147',
#  '166',
#  'GTV',
#  'SPIDER',
#  '147',
#  '156',
#  '166',
#  'SPORTWAGON']

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from urllib.parse import quote
import requests
import json

# %%
i = 0

make = list_make[0]
year = list_year[0]
model = list_model[0]
engine = list_engine[0]
car_code = list_car_code[0]

data = 'func=navnode_fetch&payload=' + quote('{"jsn":{"tab":"catalog","make":"') + make.replace(' ', '+') + quote('","year":"') + year + quote('","model":"') + model.replace('+', '%2B').replace(' ', '+').replace('&', '%26').replace('/', '%2F') + quote('","engine":"') + engine.replace(' ', '+').replace('/', '%2F') + quote('","carcode":"') + car_code + quote('","nodetype":"carcode"}}') + '&api_json_request=1&sctchecked=1&scbeenloaded=true&curCartGroupID='

resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                     data=data,
                     headers={'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8'}).text

resp = json.loads(resp)

resp
# Out:
# {'html_fill_sections': {'navchildren[]': '<div class="ranavnode" id="nav[__GIP__1__]"><input type="hidden" autocomplete="off" id="jsn[__GIP__1__]" value="{&quot;groupindex&quot;:&quot;__GIP__1__&quot;,&quot;tab&quot;:&quot;catalog&quot;,&quot;idepth&quot;:1,&quot;make&quot;:&quot;ALFA ROMEO&quot;,&quot;year&quot;:&quot;2024&quot;,&quot;model&quot;:&quot;GIULIA&quot;,&quot;carcode&quot;:&quot;3454627&quot;,&quot;engine&quot;:&quot;2.0L L4 Turbocharged&quot;,&quot;groupname&quot;:&quot;Brake &amp; Wheel Hub&quot;,&quot;nodetype&quot;:&quot;groupname&quot;}" /><input type="hidden" autocomplete="off" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-brake &amp; wheel hub]" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-brake &amp; wheel hub]" value="__GIP__1__" /><div id="nav_o[__GIP__1__]" class="ranavouter"><div class="inner"><table class="tbl"  cellpadding="0" cellspacing="0"><tr><td class="niconspace nvlineicon"></td><td class="niconspace ncollapsedicon" id="navicon[__GIP__1__]"><a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,brake+&amp;+wheel+hub" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__1__&quot;); return false;" tabindex="-1"><img src="/Images/1pxtransparent.png" alt="Toggle"></a></td><td class="nlabel" ><a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,brake+&amp;+wheel+hub" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__1__&quot;); return false;" id="navhref[__GIP__1__]">Brake &amp; Wheel Hub</a></td></tr></table></div></div><div class="nchildren ra-hide" id="navchildren[__GIP__1__]" ></div></div><div class="ranavnode" id="nav[__GIP__2__]"><input type="hidden" autocomplete="off" id="jsn[__GIP__2__]" value="{&quot;groupindex&quot;:&quot;__GIP__2__&quot;,&quot;tab&quot;:&quot;catalog&quot;,&quot;idepth&quot;:1,&quot;make&quot;:&quot;ALFA ROMEO&quot;,&quot;year&quot;:&quot;2024&quot;,&quot;model&quot;:&quot;GIULIA&quot;,&quot;carcode&quot;:&quot;3454627&quot;,&quot;engine&quot;:&quot;2.0L L4 Turbocharged&quot;,&quot;groupname&quot;:&quot;Cooling System&quot;,&quot;nodetype&quot;:&quot;groupname&quot;}" /><input type="hidden" autocomplete="off" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-cooling system]" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-cooling system]" value="__GIP__2__" /><div id="nav_o[__GIP__2__]" class="ranavouter"><div class="inner"><table class="tbl"  cellpadding="0" cellspacing="0"><tr><td class="niconspace nvlineicon"></td><td class="niconspace ncollapsedicon" id="navicon[__GIP__2__]"><a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,cooling+system" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__2__&quot;); return false;" tabindex="-1"><img src="/Images/1pxtransparent.png" alt="Toggle"></a></td><td class="nlabel" ><a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,cooling+system" onclick="cataloglite.LinkIntercept_ToggleNavNode(&quot;__GIP__2__&quot;); return false;" id="navhref[__GIP__2__]">Cooling System</a></td></tr></table></div></div><div class="nchildren ra-hide" id="navchildren[__GIP__2__]" ></div></div><div class="ranavnode" id="nav[__GIP__3__]"><input type="hidden" autocomplete="off" id="jsn[__GIP__3__]" value="{&quot;groupindex&quot;:&quot;__GIP__3__&quot;,&quot;tab&quot;:&quot;catalog&quot;,&quot;idepth&quot;:1,&quot;make&quot;:&quot;ALFA ROMEO&quot;,&quot;year&quot;:&quot;2024&quot;,&quot;model&quot;:&quot;GIULIA&quot;,&quot;carcode&quot;:&quot;3454627&quot;,&quot;engine&quot;:&quot;2.0L L4 Turbocharged&quot;,&quot;groupname&quot;:&quot;Drivetrain&quot;,&quot;nodetype&quot;:&quot;groupname&quot;}" /><input type="hidden" autocomplete="off" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-drivetrain]" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-drivetrain]" value="__GIP__3__" /><div id="nav_o[__GIP__3__]" class= ...
#  'jsn': {'tab': 'catalog',
#   'make': 'ALFA ROMEO',
#   'year': '2024',
#   'model': 'GIULIA',
#   'engine': '2.0L L4 Turbocharged',
#   'carcode': '3454627',
#   'nodetype': 'carcode',
#   'idepth': 0},
#  'collected_javascript': '/**UQ:3A4E6F52**/\nwindow.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\\/0bbOhvn7P3rkFbL80\\/4ONrpMMyyMoTAzqUtg75DXjLFbtL0RWwG2TIS5g0HjN+BEpbJggwRicfW87qYxCroJDOCFdvb3koFH0TxTw3x1dhhkAt5X2BC4uQjV0O+ZAzrDRwa55fw4rmoTrJZpDA=";\n'}

# %%
from bs4 import BeautifulSoup

# %%
html = resp['html_fill_sections']['navchildren[]']

soup = BeautifulSoup(html, 'lxml')

with open('./category.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="ranavnode" id="nav[__GIP__1__]">
#    <input autocomplete="off" id="jsn[__GIP__1__]" type="hidden" value='{"groupindex":"__GIP__1__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Brake &amp; Wheel Hub","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-brake &amp; wheel hub]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-brake &amp; wheel hub]" type="hidden" value="__GIP__1__"/>
#    <div class="ranavouter" id="nav_o[__GIP__1__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__1__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,brake+&amp;+wheel+hub" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__1__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,brake+&amp;+wheel+hub" id="navhref[__GIP__1__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__1__"); return false;'>
#          Brake &amp; Wheel Hub
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__1__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__2__]">
#    <input autocomplete="off" id="jsn[__GIP__2__]" type="hidden" value='{"groupindex":"__GIP__2__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Cooling System","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-cooling system]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-cooling system]" type="hidden" value="__GIP__2__"/>
#    <div class="ranavouter" id="nav_o[__GIP__2__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__2__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,cooling+system" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__2__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,cooling+system" id="navhref[__GIP__2__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__2__"); return false;'>
#          Cooling System
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__2__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__3__]">
#    <input autocomplete="off" id="jsn[__GIP__3__]" type="hidden" value='{"groupindex":"__GIP__3__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Drivetrain","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-drivetrain]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-drivetrain]" type="hidden" value="__GIP__3__"/>
#    <div class="ranavouter" id="nav_o[__GIP__3__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__3__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,drivetrain" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__3__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,drivetrain" id="navhref[__GIP__3__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__3__"); return false;'>
#          Drivetrain
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__3__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__4__]">
#    <input autocomplete="off" id="jsn[__GIP__4__]" type="hidden" value='{"groupindex":"__GIP__4__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Engine","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-engine]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-engine]" type="hidden" value="__GIP__4__"/>
#    <div class="ranavouter" id="nav_o[__GIP__4__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__4__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,engine" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__4__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,engine" id="navhref[__GIP__4__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__4__"); return false;'>
#          Engine
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__4__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__5__]">
#    <input autocomplete="off" id="jsn[__GIP__5__]" type="hidden" value='{"groupindex":"__GIP__5__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Fuel &amp; Air","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-fuel &amp; air]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-fuel &amp; air]" type="hidden" value="__GIP__5__"/>
#    <div class="ranavouter" id="nav_o[__GIP__5__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__5__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,fuel+&amp;+air" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__5__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,fuel+&amp;+air" id="navhref[__GIP__5__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__5__"); return false;'>
#          Fuel &amp; Air
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__5__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__6__]">
#    <input autocomplete="off" id="jsn[__GIP__6__]" type="hidden" value='{"groupindex":"__GIP__6__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Heat &amp; Air Conditioning","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-heat &amp; air conditioning]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-heat &amp; air conditioning]" type="hidden" value="__GIP__6__"/>
#    <div class="ranavouter" id="nav_o[__GIP__6__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__6__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,heat+&amp;+air+conditioning" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__6__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,heat+&amp;+air+conditioning" id="navhref[__GIP__6__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__6__"); return false;'>
#          Heat &amp; Air Conditioning
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__6__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__7__]">
#    <input autocomplete="off" id="jsn[__GIP__7__]" type="hidden" value='{"groupindex":"__GIP__7__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Ignition","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-ignition]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-ignition]" type="hidden" value="__GIP__7__"/>
#    <div class="ranavouter" id="nav_o[__GIP__7__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__7__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,ignition" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__7__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,ignition" id="navhref[__GIP__7__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__7__"); return false;'>
#          Ignition
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__7__]">
#    </div>
#   </div>
#   <div class="ranavnode" id="nav[__GIP__8__]">
#    <input autocomplete="off" id="jsn[__GIP__8__]" type="hidden" value='{"groupindex":"__GIP__8__","tab":"catalog","idepth":1,"make":"ALFA ROMEO","year":"2024","model":"GIULIA","carcode":"3454627","engine":"2.0L L4 Turbocharged","groupname":"Transmission-Automatic","nodetype":"groupname"}'/>
#    <input autocomplete="off" id="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-transmission-automatic]" name="navnodeunique[catalog-alfa romeo-2024-giulia-3454627-transmission-automatic]" type="hidden" value="__GIP__8__"/>
#    <div class="ranavouter" id="nav_o[__GIP__8__]">
#     <div class="inner">
#      <table cellpadding="0" cellspacing="0" class="tbl">
#       <tr>
#        <td class="niconspace nvlineicon">
#        </td>
#        <td class="niconspace ncollapsedicon" id="navicon[__GIP__8__]">
#         <a href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,transmission-automatic" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__8__"); return false;' tabindex="-1">
#          <img alt="Toggle" src="/Images/1pxtransparent.png"/>
#         </a>
#        </td>
#        <td class="nlabel">
#         <a class="navlabellink nvoffset nnormal" href="/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,transmission-automatic" id="navhref[__GIP__8__]" onclick='cataloglite.LinkIntercept_ToggleNavNode("__GIP__8__"); return false;'>
#          Transmission-Automatic
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#    <div class="nchildren ra-hide" id="navchildren[__GIP__8__]">
#    </div>
#   </div>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_category = html.xpath('//td[@class="nlabel"]/a/text()')

list_category
# Out:
# ['2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.3L L4 ELECTRIC/GAS Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '2.9L V6 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '2.0L L4 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.8L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.7L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '2.2L L4',
#  '3.2L V6',
#  '1.8L L4 Turbocharged',
#  '1.4L L4 Turbocharged',
#  '2.2L L4',
#  '4.7L V8',
#  '3.2L V6',
#  '2.0L L4',
#  '3.2L V6',
#  '2.0L L4',
#  '2.2L L4',
#  '3.2L V6',
#  '2.0L L4',
#  '3.2L V6',
#  '3.2L V6',
#  '2.0L L4',
#  '2.0L L4',
#  '2.0L L4',
#  '2.0L L4',
#  '2.0L L4',
#  '3.0L V6',
#  '3.0L V6',
#  '3.0L V6',
#  '2.0L L4',
#  '2.0L L4',
#  '3.0L V6',
#  '2.0L L4']

# %%
list_url = html.xpath('//td[@class="niconspace ncollapsedicon"]/a/@href')

list_category_code = [_.split(',')[-1] for _ in list_url]

list_category_code
# Out:
# ['brake+&+wheel+hub',
#  'cooling+system',
#  'drivetrain',
#  'engine',
#  'fuel+&+air',
#  'heat+&+air+conditioning',
#  'ignition',
#  'transmission-automatic']

# %%
list_url = ['https://www.rockauto.com'+_ for _ in list_url]

list_url
# Out:
# ['https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,brake+&+wheel+hub',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,cooling+system',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,drivetrain',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,engine',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,fuel+&+air',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,heat+&+air+conditioning',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,ignition',
#  'https://www.rockauto.com/en/catalog/alfa+romeo,2024,giulia,2.0l+l4+turbocharged,3454627,transmission-automatic']

# %%
df_temp = pd.DataFrame({'status': 'ok',
                        'Make': make,
                        'Year': year,
                        'Model': model,
                        'Engine': engine,
                        'Car_Code': car_code,
                        'Category': list_category,
                        'Category_Code': list_category_code,
                        'Url': list_url})

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status        Make  Year   Model                Engine  Carcode  \
# 0     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 1     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 2     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 3     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 4     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 5     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 6     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
# 7     ok  ALFA ROMEO  2024  GIULIA  2.0L L4 Turbocharged  3454627
#
#                   Category            Category_Code  \
# 0        Brake & Wheel Hub        brake+&+wheel+hub
# 1           Cooling System           cooling+system
# 2               Drivetrain               drivetrain
# 3                   Engine                   engine
# 4               Fuel & Air               fuel+&+air
# 5  Heat & Air Conditioning  heat+&+air+conditioning
# 6                 Ignition                 ignition
# 7   Transmission-Automatic   transmission-automatic
#
#                                                  Url
# 0  https://www.rockauto.com/en/catalog/alfa+romeo...
# 1  https://www.rockauto.com/en/catalog/alfa+romeo...
# 2  https://www.rockauto.com/en/catalog/alfa+romeo...
# 3  https://www.rockauto.com/en/catalog/alfa+romeo...
# 4  https://www.rockauto.com/en/catalog/alfa+romeo...
# 5  https://www.rockauto.com/en/catalog/alfa+romeo...
# 6  https://www.rockauto.com/en/catalog/alfa+romeo...
# 7  https://www.rockauto.com/en/catalog/alfa+romeo...
