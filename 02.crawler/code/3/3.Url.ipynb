# %%
dict_ = {'no': 1,
 'item_number': '256756876675'}

dict_
# Out:
# {'no': 1, 'item_number': '256756876675'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(f'''https://www.ebay.com/itm/{dict_['item_number']}?_ul=US&_stpos=91710&orig_cvip=true''',
                        headers=generate_header(**{'Accept-Language': 'en'}),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
import json

# %%
try:
    json.loads(response.text.split('$MC=(window.$MC||[]).concat(')[1].split(')</script>')[0])
except Exception as e:
    print(e)

# %%
dict_2 = json.loads(response.text.split('$MC=(window.$MC||[]).concat(')[1].split(')</script>')[0])

dict_2
# Out:
# {'o': {'g': {'popcornBiddingContent': {'education': {'title': 'Extended bidding',
#      'body': [{'title': 'This auction may extend',
#        'text': 'This gives everyone a fair chance to win.'},
#       {'title': 'Bids in the last 2 minutes add time',
#        'text': 'Time left in the auction resets to 2 minutes with each bid.'},
#       {'title': 'The highest bid wins',
#        'text': 'Time runs out once all bidding stops.'}],
#      'closeA11yText': 'Close dialog'},
#     'section': {'preWindowTitle': 'This auction may extend',
#      'postWindowTitle': 'Each bid now adds more time',
#      'a11yText': 'Information',
#      'preWindowBodyText': 'Bids in the last 2 minutes add more time.',
#      'postWindowBodyText': 'New bids reset the time left to 2 minutes.',
#      'link': 'Learn more'}},
#    'enableEbayLiveBanner': False,
#    'VINODE_FULL_HEIGHT': {'enableFullHeight': False},
#    'a11yText': {'a11yMaximizeText': 'Minimize Drawer',
# ...

# %%
dict_2['o']['g']['itemId'].strip() != dict_['item_number']
# Out:
# False

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text, 'html5lib')

with open('./3.url.html', 'w', encoding='utf-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!--M#s0-->
# <!--M^s0-23 s0 23-->
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>
#   <link href="//p.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//q.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>
#   <link href="//reco.ebay.com" rel="dns-prefetch"/>
#   <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#   <link href="//rover.ebay.com" rel="dns-prefetch"/>
#   <link href="//i.ebayimg.cn" rel="dns-prefetch"/>
#   <link href="//ir.ebaystatic.cn" rel="dns-prefetch"/>
#   <link crossorigin="" href="//i.ebayimg.cn" rel="preconnect"/>
# ...

# %%
from parsel import Selector

# %%
selector = Selector(text=str(soup))

selector
# Out:
# <Selector query=None data='<html lang="en"><head><link href="//t...'>

# %%
list_url = sorted(dict.fromkeys([url.strip() for url in selector.xpath('//link[@rel="alternate" and @hreflang="x-default"]/@href').getall()]))

list_url
# Out:
# ['https://www.ebay.com/itm/256756876675']

# %%
not list_url
# Out:
# False

# %%
from urllib.parse import urlsplit

# %%
tuple_ = urlsplit(list_url[0])

tuple_
# Out:
# SplitResult(scheme='https', netloc='www.ebay.com', path='/itm/256756876675', query='', fragment='')

# %%
if tuple_.netloc == 'www.ebay.com':
    dict_query, market, country, language, locale = {'_ul': 'US',
                                                     '_stpos': '91710',
                                                     'orig_cvip': 'true'}, 'EBAY-US', 'US', 'en', 'en-US'
elif tuple_.netloc == 'www.ebay.de':
    dict_query, market, country, language, locale = {'_ul': 'DE',
                                                     '_stpos': '10115',
                                                     'orig_cvip': 'true'}, 'EBAY-DE', 'DE', 'de', 'de-DE'
elif tuple_.netloc == 'www.ebay.co.uk':
    dict_query, market, country, language, locale = {'_ul': 'GB',
                                                     '_stpos': 'BS81QU',
                                                     'orig_cvip': 'true'}, 'EBAY-GB', 'GB', 'en', 'en-GB'
elif tuple_.netloc == 'www.ebay.com.au':
    dict_query, market, country, language, locale = {'_ul': 'AU',
                                                     '_stpos': '2019',
                                                     'orig_cvip': 'true'}, 'EBAY-AU', 'AU', 'en', 'en-AU'
elif tuple_.netloc == 'www.ebay.ca':
    dict_query, market, country, language, locale = {'_ul': 'CA',
                                                     '_stpos': 'M5S2E8',
                                                     'orig_cvip': 'true'}, 'EBAY-ENCA', 'CA', 'en', 'en-CA'
elif tuple_.netloc == 'www.ebay.fr':
    dict_query, market, country, language, locale = {'_ul': 'FR',
                                                     '_stpos': '75001',
                                                     'orig_cvip': 'true'}, 'EBAY-FR', 'FR', 'fr', 'fr-FR'
elif tuple_.netloc == 'www.ebay.it':
    dict_query, market, country, language, locale = {'_ul': 'IT',
                                                     '_stpos': '00184',
                                                     'orig_cvip': 'true'}, 'EBAY-IT', 'IT', 'it', 'it-IT'
elif tuple_.netloc == 'www.ebay.ie':
    dict_query, market, country, language, locale = {'_ul': 'IE',
                                                     '_stpos': 'D01F5P2',
                                                     'orig_cvip': 'true'}, 'EBAY-IE', 'IE', 'en', 'en-IE'
elif tuple_.netloc == 'www.ebay.es':
    dict_query, market, country, language, locale = {'_ul': 'ES',
                                                     '_stpos': '28001',
                                                     'orig_cvip': 'true'}, 'EBAY-ES', 'ES', 'es', 'es-ES'
elif tuple_.netloc == 'www.ebay.at':
    dict_query, market, country, language, locale = {'_ul': 'AT',
                                                     '_stpos': '1010',
                                                     'orig_cvip': 'true'}, 'EBAY-AT', 'AT', 'de', 'de-AT'
elif tuple_.netloc == 'www.befr.ebay.be':
    dict_query, market, country, language, locale = {'_ul': 'BE',
                                                     '_stpos': '1000',
                                                     'orig_cvip': 'true'}, 'EBAY-FRBE', 'BE', 'fr', 'fr-BE'

dict_query, market, country, language, locale
# Out:
# ({'_ul': 'US', '_stpos': '91710', 'orig_cvip': 'true'},
#  'EBAY-US',
#  'US',
#  'en',
#  'en-US')

# %%
from urllib.parse import urlunsplit
from urllib.parse import urlencode

# %%
url = urlunsplit(('https', tuple_.netloc, tuple_.path, urlencode(dict_query), ''))

url
# Out:
# 'https://www.ebay.com/itm/256756876675?_ul=US&_stpos=91710&orig_cvip=true'

# %%
{'no': dict_['no'],
 'item_number': dict_['item_number'],
 'default_no': 1,
 'join_indn': f'''{dict_['item_number']};{1}''',
 'market': market,
 'country': country,
 'language': language,
 'locale': locale,
 'url': url}
# Out:
# {'no': 1,
#  'item_number': '256756876675',
#  'default_no': 1,
#  'join_indn': '256756876675;1',
#  'market': 'EBAY-US',
#  'country': 'US',
#  'language': 'en',
#  'locale': 'en-US',
#  'url': 'https://www.ebay.com/itm/256756876675?_ul=US&_stpos=91710&orig_cvip=true'}
