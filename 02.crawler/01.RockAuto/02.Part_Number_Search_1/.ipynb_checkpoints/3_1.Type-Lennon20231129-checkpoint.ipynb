# %%
import pandas as pd

# %%
df = pd.read_excel('./category.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_manufacturer = df['Manufacturer'].tolist()
list_manufacturer_number = df['Manufacturer_No.'].tolist()
list_category = df['Category'].tolist()
list_category_code = df['Category_Code'].tolist()
list_category_number = df['Category_No.'].tolist()

print('总数量：' + str(len(list_category)))
list_category
# Out:
# 总数量：2454
# ['Body & Lamp Assembly',
#  'Interior',
#  'Body & Lamp Assembly',
#  'Engine',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Interior',
#  'Steering',
#  'Interior',
#  'Fuel & Air',
#  'Ignition',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Heat & Air Conditioning',
#  'Body & Lamp Assembly',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Fuel & Air',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Engine',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Heat & Air Conditioning',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Cooling System',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Fuel & Air',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Engine',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Steering',
#  'Transmission-Manual',
#  'Engine',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Interior',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Engine',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Wiper & Washer',
#  'Exhaust & Emission',
#  'Exhaust & Emission',
#  'Garage Equipment',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Exhaust & Emission',
#  'Steering',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Wheel',
#  'Belt Drive',
#  'Suspension',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Apparel & Gifts',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Steering',
#  'Fuel & Air',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Steering',
#  'Suspension',
#  'Engine',
#  'Fuel & Air',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Transmission-Automatic',
#  'Electrical-Connector',
#  'Fuel & Air',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Steering',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Wheel',
#  'Drivetrain',
#  'Steering',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Heat & Air Conditioning',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Wheel',
#  'Body & Lamp Assembly',
#  'Ignition',
#  'Garage Equipment',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Engine',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Engine',
#  'Steering',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Electrical',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Wheel',
#  'Literature',
#  'Brake & Wheel Hub',
#  'Wheel',
#  'Engine',
#  'Steering',
#  'Suspension',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Wheel',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Exhaust & Emission',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Suspension',
#  'Transmission-Automatic',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Cooling System',
#  'Exhaust & Emission',
#  'Ignition',
#  'Heat & Air Conditioning',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Electrical-Bulb & Socket',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Ignition',
#  'Wiper & Washer',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Exhaust & Emission',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Engine',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Engine',
#  'Wiper & Washer',
#  'Electrical',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Electrical',
#  'Heat & Air Conditioning',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Interior',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Wiper & Washer',
#  'Engine',
#  'Cooling System',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Interior',
#  'Wheel',
#  'Engine',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical-Connector',
#  'Exhaust & Emission',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Interior',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Literature',
#  'Exhaust & Emission',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Wiper & Washer',
#  'Suspension',
#  'Drivetrain',
#  'Engine',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Exhaust & Emission',
#  'Body & Lamp Assembly',
#  'Fuel & Air',
#  'Interior',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Wheel',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Cooling System',
#  'Literature',
#  'Fuel & Air',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Wheel',
#  'Drivetrain',
#  'Body & Lamp Assembly',
#  'Engine',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Transmission-Automatic',
#  'Exhaust & Emission',
#  'Ignition',
#  'Ignition',
#  'Cooling System',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Engine',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Hardware',
#  'Hoses/Lines & Clamps',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Electrical-Bulb & Socket',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Ignition',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Steering',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Garage Equipment',
#  'Hardware',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Engine',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Heat & Air Conditioning',
#  'Electrical',
#  'Transmission-Manual',
#  'Electrical',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Drivetrain',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Steering',
#  'Suspension',
#  'Ignition',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Ignition',
#  'Interior',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Ignition',
#  'Transmission-Automatic',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Suspension',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Steering',
#  'Suspension',
#  'Belt Drive',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Heat & Air Conditioning',
#  'Transmission-Manual',
#  'Electrical',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Steering',
#  'Suspension',
#  'Cooling System',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Body & Lamp Assembly',
#  'Electrical-Bulb & Socket',
#  'Brake & Wheel Hub',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Body & Lamp Assembly',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical-Connector',
#  'Engine',
#  'Fuel & Air',
#  'Body & Lamp Assembly',
#  'Belt Drive',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Interior',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Suspension',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Engine',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Engine',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Steering',
#  'Transmission-Automatic',
#  'Literature',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Ignition',
#  'Interior',
#  'Wiper & Washer',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  ...]

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import json

# %%
import sys
sys.path.append('../../../00.module')
import UA
import Proxy

i = 0

manufacturer = list_manufacturer[i]
manufacturer_number = int(list_manufacturer_number[i])
category = list_category[i]
category_code = list_category_code[i]
category_number = int(list_category_number[i])

data = 'func=partsearchgetparttypessdd&mfr=' + manufacturer.replace('+', '%2B').replace(' ', '+').replace('&', '%26').replace('/', '%2F').replace(',', '%2C').replace('Ö', '%C3%96').replace('Ü', '%C3%9C') + '&pg=' + category.replace(' ', '+').replace('&', '%26').replace('/', '%2F') + '&id=partsearch_007&api_json_request=1&sctchecked=1&scbeenloaded=true&curCartGroupID='

ua = UA.get_User_Agent_Requests()
ua['Content-Type'] = 'application/x-www-form-urlencoded; charset=UTF-8'

resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                     data=data,
                     headers=ua,
                     proxies=Proxy.get_Proxy_Requests()).text

resp = json.loads(resp)

resp
# Out:
# {'html_replace_sections': {'ddrepl[parttype_partsearch_007][container]': '<span id="ddrepl[parttype_partsearch_007][container]" class="ra-vertical-dropdown-replacement-c"><select id="parttype_partsearch_007" name="partsearch[parttype][partsearch_007]" onchange = "" tabindex="0" autocomplete = "none"><option value=""  selected >All</option><option value="1263"  >Cargo Bag</option><option value="1000410"  >Cargo Carrier</option><option value="1104"  >Roof Rack</option><option value="1152"  >Sunroof Wind Deflector</option><option value="1427"  >Tailgate</option></select></span>'},
#  'collected_javascript': '/**UQ:B1DF5706**/\nwindow.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\\/0bbOhvn7P3rkFbL80\\/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDJ3DAD\\/oIoMwhZ07QTaxq3iaRPgEv6J\\/6hNEGq1ntp7o=";\n'}

# %%
from bs4 import BeautifulSoup

# %%
html = resp['html_replace_sections']['ddrepl[parttype_partsearch_007][container]']

soup = BeautifulSoup(html, 'lxml')

with open('./type.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <span class="ra-vertical-dropdown-replacement-c" id="ddrepl[parttype_partsearch_007][container]">
#    <select autocomplete="none" id="parttype_partsearch_007" name="partsearch[parttype][partsearch_007]" onchange="" tabindex="0">
#     <option selected="" value="">
#      All
#     </option>
#     <option value="1263">
#      Cargo Bag
#     </option>
#     <option value="1000410">
#      Cargo Carrier
#     </option>
#     <option value="1104">
#      Roof Rack
#     </option>
#     <option value="1152">
#      Sunroof Wind Deflector
#     </option>
#     <option value="1427">
#      Tailgate
#     </option>
#    </select>
#   </span>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_type = html.xpath('//select[@id="parttype_partsearch_007"]/option/text()')

list_type
# Out:
# ['All',
#  'Cargo Bag',
#  'Cargo Carrier',
#  'Roof Rack',
#  'Sunroof Wind Deflector',
#  'Tailgate']

# %%
list_type_code = html.xpath('//select[@id="parttype_partsearch_007"]/option/@value')

list_type_code
# Out:
# ['', '1263', '1000410', '1104', '1152', '1427']

# %%
df_temp = pd.DataFrame({'status': 'ok',
                        'Manufacturer_No.': manufacturer_number,
                        'Manufacturer': manufacturer,
                        'Category_No.': category_number,
                        'Category': category,
                        'Category_Code': category_code,
                        'Type_No.': [_+1 for _ in range(len(list_type)-1)],
                        'Type': list_type[1:],
                        'Type_Code': list_type_code[1:]})

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status Manufacturer_No. Manufacturer Category_No.              Category  \
# 0     ok                1           3D            1  Body & Lamp Assembly
# 1     ok                1           3D            1  Body & Lamp Assembly
# 2     ok                1           3D            1  Body & Lamp Assembly
# 3     ok                1           3D            1  Body & Lamp Assembly
# 4     ok                1           3D            1  Body & Lamp Assembly
#
#           Category_Code  Type_No.                    Type Type_Code
# 0  Body & Lamp Assembly         1               Cargo Bag      1263
# 1  Body & Lamp Assembly         2           Cargo Carrier   1000410
# 2  Body & Lamp Assembly         3               Roof Rack      1104
# 3  Body & Lamp Assembly         4  Sunroof Wind Deflector      1152
# 4  Body & Lamp Assembly         5                Tailgate      1427
