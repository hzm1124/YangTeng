# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./menu.xlsx', header=0)
list_info = df_menu['Info'].to_list()

print('总数量：' + str(len(list_info)))
list_info
# Out:
# 总数量：482
# ['https://www.rockauto.com/en/moreinfo.php?pk=816991',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3771312',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1001943',
#  'https://www.rockauto.com/en/moreinfo.php?pk=881733',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40816',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40817',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40819',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40820',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1005840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40821',
#  'https://www.rockauto.com/en/moreinfo.php?pk=950845',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40822',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1006100',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40823',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40825',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40826',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2415544',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40828',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40829',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40831',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40835',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40838',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40842',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40843',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443089',
#  'https://www.rockauto.com/en/moreinfo.php?pk=445207',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443670',
#  'https://www.rockauto.com/en/moreinfo.php?pk=320210',
#  'https://www.rockauto.com/en/moreinfo.php?pk=320211',
#  'https://www.rockauto.com/en/moreinfo.php?pk=446026',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2417022',
#  'https://www.rockauto.com/en/moreinfo.php?pk=444661',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443512',
#  'https://www.rockauto.com/en/moreinfo.php?pk=445796',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2415148',
#  'https://www.rockauto.com/en/moreinfo.php?pk=444260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=442657',
#  'https://www.rockauto.com/en/moreinfo.php?pk=445253',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443121',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443760',
#  'https://www.rockauto.com/en/moreinfo.php?pk=446243',
#  'https://www.rockauto.com/en/moreinfo.php?pk=444155',
#  'https://www.rockauto.com/en/moreinfo.php?pk=446251',
#  'https://www.rockauto.com/en/moreinfo.php?pk=445109',
#  'https://www.rockauto.com/en/moreinfo.php?pk=443139',
#  'https://www.rockauto.com/en/moreinfo.php?pk=445508',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10462080',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663944',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663945',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663946',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663947',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663948',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663949',
#  'https://www.rockauto.com/en/moreinfo.php?pk=663950',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817159',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817418',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817237',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3788424',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817719',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817713',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817446',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817303',
#  'https://www.rockauto.com/en/moreinfo.php?pk=816724',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817906',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817610',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817176',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817455',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817198',
#  'https://www.rockauto.com/en/moreinfo.php?pk=817063',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002348',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002723',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1003056',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40849',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002497',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002021',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1003035',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40851',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002401',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1002600',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2417050',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354229',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354781',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353730',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354278',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40852',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354744',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353363',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352844',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354471',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353888',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40853',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354919',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353231',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1320312',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354434',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354682',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352706',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354664',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354137',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353601',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3774444',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353375',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352920',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354888',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353293',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1514634',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1321218',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353501',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354114',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354346',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513758',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352870',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1515356',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352596',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1514946',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513540',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1515070',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513368',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354739',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1320763',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1352941',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354693',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1514072',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354043',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1353419',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1515814',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1354232',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513886',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40858',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513566',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1515878',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3785688',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1515648',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1514508',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1513270',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3789270',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775002',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3772764',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3776844',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782679',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3777639',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4633659',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3770862',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782325',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3771768',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5676945',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40862',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3769137',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3776907',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779958',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3772218',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779889',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775155',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3786264',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778899',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782304',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3788490',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779826',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3787002',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3768615',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40864',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3784593',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775188',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3784632',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3776709',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3781425',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3773622',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3772167',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782769',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3788487',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3786948',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3783579',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3769875',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3785859',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775524',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3768951',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10534060',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778257',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3773745',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3783147',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3781293',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40867',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782385',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3777342',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3780663',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3774429',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10462084',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3768450',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782313',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3783777',
#  'https://www.rockauto.com/en/moreinfo.php?pk=950815',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3772809',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3768603',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778725',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3786768',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6439755',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40869',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778170',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3787419',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3774003',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3783222',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775203',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3769626',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3774369',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3788451',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3788916',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3781647',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779751',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775470',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40871',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3772290',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3776790',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3785061',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3784404',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3789123',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40872',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3774315',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3771840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3780195',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3775332',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3783849',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779100',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3789585',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3769944',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778554',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3779829',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3778182',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3785319',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3777351',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3781044',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3769974',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3786924',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3785301',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3782109',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3781635',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4633167',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4632186',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40876',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4632960',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4632216',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414223',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414232',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414235',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414238',
#  'https://www.rockauto.com/en/moreinfo.php?pk=951178',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414241',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414244',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414247',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414250',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414253',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414259',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5676951',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5724771',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5676954',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414265',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5676957',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414271',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414274',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5414277',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5676960',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6086856',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6086859',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6086862',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6505551',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6505554',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6995204',
#  'https://www.rockauto.com/en/moreinfo.php?pk=6995212',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40879',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7497180',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386772',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7988092',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148520',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7988096',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7988100',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148524',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148528',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7988104',
#  'https://www.rockauto.com/en/moreinfo.php?pk=7988108',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386776',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607200',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972280',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768756',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40882',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768760',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486224',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486228',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148544',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148548',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14052305',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479844',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486232',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148568',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148572',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721228',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148576',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148580',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607204',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721232',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486236',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479848',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148584',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148588',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486240',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972284',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148596',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40886',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972288',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768764',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148608',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479856',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40887',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148612',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479860',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721248',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148628',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148632',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972292',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148636',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768776',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768784',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40889',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148640',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148644',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768788',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386788',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386792',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386796',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148648',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148652',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479864',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148656',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40891',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972296',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148660',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386804',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148664',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148668',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148672',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40892',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479868',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148684',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8479872',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8148692',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8386808',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607216',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607220',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607224',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607228',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607232',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607236',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607240',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607248',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768796',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40895',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607264',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607268',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40896',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768804',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607276',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607284',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607288',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607292',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768808',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768812',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607296',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607300',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40897',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875756',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607316',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8607324',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40898',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972304',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768820',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768832',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768836',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40899',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768844',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768848',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768860',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8768864',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875768',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875772',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875776',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40900',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875780',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875788',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972308',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875796',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486264',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875800',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875808',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875820',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40903',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875828',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875832',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875840',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972312',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875856',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8875860',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40904',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972316',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486268',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972320',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972324',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972328',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972332',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486272',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972336',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972340',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972348',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972352',
#  'https://www.rockauto.com/en/moreinfo.php?pk=8972360',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9486284',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40906',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721268',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087304',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087308',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087312',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40907',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087316',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9721276',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208800',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208804',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40908',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087328',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342345',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10087332',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40909',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208812',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208816',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208820',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208836',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10208844',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342349',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342353',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342357',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10959660',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342361',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342365',
#  'https://www.rockauto.com/en/moreinfo.php?pk=11342369',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958153',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640525',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958157',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958161',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958165',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958169',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958173',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640533',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640537',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14052309',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14052313',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640541',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14052317',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14052321',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640553',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640561',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958177',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958181',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13958185',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14640565',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14872733',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14872737',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40916',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40917',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40921',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40922',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2413210',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40923',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40924',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2413576',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40930',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40931',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40932',
#  'https://www.rockauto.com/en/moreinfo.php?pk=40933']

# %%
list_url = df_menu['Url'].to_list()

list_url
# Out:
# ['https://www.rockauto.com/en/parts/standard+motor+products,ALS100,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,ALS1807,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,PC513,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,PC514,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC10,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC100,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC102,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC103,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC103T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC104,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC104T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC105,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC105T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC106,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC108,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC109,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC109T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC110,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC111,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC113,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC117,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC12,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC121,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC123,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC124,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC125,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC126,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC127,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC129,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC130,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC131,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC131T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC133,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC134,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC136,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC136T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC137,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC142,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC143,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC144,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC146,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC147,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC148,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC149,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC150,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC151,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC153,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC153T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC154,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC156,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC157,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC158,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC159,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC160,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC161,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC162,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC163,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC167,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC168,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC168T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC169,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC171,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC172,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC173,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC174,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC175,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC176,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC177,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC180,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC182,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC183,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC187,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC188,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC189,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC19,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC193,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC198,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC199,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC20,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC200,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC201,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC202,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC204,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC205,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC208,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC209,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC21,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC210,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC212,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC213,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC214,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC215,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC22,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC224,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC225,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC226,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC229,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC230,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC232,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC233,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC234,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC235,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC236,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC237,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC238,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC239,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC240,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC241,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC242,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC244,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC245,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC247,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC249,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC251,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC254,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC255,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC256,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC257,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC260,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC261,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC262,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC263,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC265,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC267,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC271,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC274,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC275,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC276,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC277,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC279,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC28,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC281,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC284,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC288,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC289,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC292,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC293,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC294,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC296,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC297,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC300,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC303,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC305,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC306,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC307,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC315,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC317,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC318,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC32,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC320,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC324,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC325,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC326,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC327,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC329,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC330,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC331,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC333,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC335,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC336,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC337,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC339,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC34,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC340,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC341,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC345,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC346,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC347,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC348,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC349,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC350,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC352,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC353,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC354,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC357,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC358,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC359,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC360,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC360T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC361,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC366,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC368,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC369,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC37,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC370,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC372,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC373,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC374,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC374T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC377,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC378,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC379,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC37T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC381,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC382,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC386,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC387,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC389,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC39,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC390,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC394,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC395,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC396,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC398,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC399,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC401,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC402,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC403,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC404,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC405,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC406,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC41,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC411,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC413,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC414,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC415,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC417,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC42,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC420,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC421,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC422,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC425,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC426,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC427,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC429,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC433,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC435,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC438,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC439,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC440,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC441,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC442,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC443,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC445,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC450,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC454,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC455,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC458,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC459,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC46,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC460,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC461,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC463,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC467,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC468,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC469,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC46T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC470,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC471,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC472,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC473,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC474,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC476,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC477,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC478,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC479,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC481,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC482,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC484,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC485,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC486,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC487,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC489,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC490,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC491,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC493,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC494,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC495,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC498,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC5,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC500,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC501,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC502,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC503,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC504,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC505,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC506,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC507,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC508,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC510,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC513,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC515,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC516,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC517,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC518,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC52,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC521,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC522,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC523,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC524,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC525,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC529,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC532,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC533,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC534,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC535,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC536,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC538,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC539,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC541,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC544,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC545,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC546,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC548,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC552,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC554,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC555,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC556,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC56,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC560,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC561,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC568,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC569,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC57,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC570,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC577,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC579,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC580,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC582,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC584,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC585,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC586,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC587,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC589,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC59,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC590,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC591,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC592,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC593,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC594,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC595,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC596,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC597,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC598,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC599,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC60,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC601,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC602,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC603,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC607,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC608,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC609,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC61,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC612,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC613,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC615,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC616,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC622,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC628,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC630,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC631,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC632,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC633,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC634,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC635,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC637,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC638,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC64,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC641,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC642,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC644,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC647,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC65,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC650,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC651,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC653,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC654,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC655,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC656,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC657,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC658,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC659,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC66,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC664,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC666,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC669,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC67,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC671,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC673,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC677,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC678,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC679,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC68,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC680,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC681,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC684,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC686,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC687,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC688,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC689,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC69,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC690,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC692,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC693,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC695,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC696,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC697,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC705,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC708,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC71,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC710,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC711,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC713,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC714,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC718,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC719,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC72,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC722,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC723,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC724,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC725,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC726,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC727,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC728,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC730,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC731,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC733,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC734,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC736,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC738,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC74,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC740,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC743,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC747,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC748,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC749,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC75,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC750,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC753,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC754,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC755,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC76,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC760,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC761,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC763,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC77,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC771,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC772,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC774,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC779,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC782,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC790,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC791,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC792,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC793,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC794,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC796,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC797,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC798,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC799,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC801,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC802,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC803,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC804,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC805,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC806,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC807,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC808,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC809,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC810,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC811,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC814,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC815,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC817,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC818,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC819,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC820,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC821,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC824,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC827,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC83,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC84,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC88,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC89,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC89T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC9,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC90,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC90T,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC96,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC97,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC98,speed+sensor,10634',
#  'https://www.rockauto.com/en/parts/standard+motor+products,SC99,speed+sensor,10634']

# %%
df = pd.DataFrame(columns=['Info',
                           'Alternate Inventory Number',
                           'OEM / Interchange Numbers',
                           'Src',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [Info, Alternate Inventory Number, OEM / Interchange Numbers, Src, status]
# Index: []

# %%
from urllib.parse import quote

# %%
i = 0

url = 'https://www.rockauto.com/en/moreinfo.php?pk=' + list_info[i].split('?')[1].split('pk=')[1].split('&')[0] + '&pt=' + list_url[i].split(',')[-1]

url
# Out:
# 'https://www.rockauto.com/en/moreinfo.php?pk=816991&pt=10634'

# %%
import requests

# %%
resp = requests.get(url).text

resp
# Out:
# '<!DOCTYPE HTML>\n<html class="no-js REPLACEHTMLCLASS" onclick="" lang="en">\n<head>\n<meta name="robots" content="all">\n<meta http-equiv="Content-Security-Policy" content="script-src \'self\' \'unsafe-inline\' \'unsafe-eval\' *.rockauto.com; base-uri \'self\' *.rockauto.com; ">\n<link rel="stylesheet" type="text/css" href="/jslib/combined/css/desktopmoreinfo.css?1686813859">\n\n<script>\nif(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};\n_getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=\n0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};\n\n</script>\n\n<script src="/jslib/combined/js/desktopcatalogmain.js?1686813859"></script>\n\n<script src="/catalog/moreinfo-min.js?1686813859"></script>\n\n<link rel="stylesheet" type="text/css" href="/catalog/moreinfo-min.css?1686813859">\n<title>More Information for STANDARD MOTOR PRODUCTS ALS100</title>\n<link rel="canonical" href="https://www.rockauto.com/en/moreinfo.php?pk=816991"/>\n<link rel="alternate" href="https://www.rockauto.com/en/moreinfo.php?pk=816991" hreflang="en" />\n<link rel="alternate" href="https://www.rockauto.com/es/moreinfo.php?pk=816991" hreflang="es" />\n<link rel="alternate" href="https://www.rockauto.com/de/moreinfo.php?pk=816991" hreflang="de" />\n<link rel="alternate" href="https://www.rockauto.com/fr/moreinfo.php?pk=816991" hreflang="fr" />\n</head>\n<body onLoad="ResizePiclookup();" class="mi-body">\n<div id="mi_everything">\n<div>\n<div style="float:left; margin-right:1em;"><a href="https://www.standardbrand.com/en" target="_blank"><img style="max-height:100px;" src="/logos/SMPLogo.png" alt="STANDARD MOTOR PRODUCTS" border="0"></a></div>\n<div style="float:left;"><img style="max-height:100px;" src="/logos/StandardLogo.png" alt="STANDARD MOTOR PRODUCTS" border="0"></div>\n<div style="float:right;">\n<table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">\n<tr>\n<td style="text-align: center">\n<a href="/" onclick="AddSerializedCookieDataToHref(this);"><img src="/Images/logoNoLine.png" class="ralogo" border="0" alt="Go to RockAuto Home Page"></a>\n</td>\n</tr>\n</table>\n</div>\n<div style="font-size:.9em;"></div>\n<div style="clear:both;"></div>\n</div>\n<div class="bdytext hide-for-inline-mobile">\n<div style="float: left; padding-right: 20px;">\n<div style="padding-bottom:.4em;">More Information for STANDARD MOTOR PRODUCTS ALS100</div>\n<div style="padding-bottom:.4em;"></div>\n<input type="button" id="mi_continue_shopping_btn" class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" style="padding-top: 5px; padding-bottom: 5px; background-position: left cent ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="no-js REPLACEHTMLCLASS" lang="en" onclick="">
#  <head>
#   <meta content="all" name="robots"/>
#   <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' *.rockauto.com; base-uri 'self' *.rockauto.com; " http-equiv="Content-Security-Policy"/>
#   <link href="/jslib/combined/css/desktopmoreinfo.css?1686813859" rel="stylesheet" type="text/css"/>
#   <script>
#    if(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};
# _getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=
# 0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};
#   </script>
#   <script src="/jslib/combined/js/desktopcatalogmain.js?1686813859">
#   </script>
#   <script src="/catalog/moreinfo-min.js?1686813859">
#   </script>
#   <link href="/catalog/moreinfo-min.css?1686813859" rel="stylesheet" type="text/css"/>
#   <title>
#    More Information for STANDARD MOTOR PRODUCTS ALS100
#   </title>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=816991" rel="canonical"/>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=816991" hreflang="en" rel="alternate"/>
#   <link href="https://www.rockauto.com/es/moreinfo.php?pk=816991" hreflang="es" rel="alternate"/>
#   <link href="https://www.rockauto.com/de/moreinfo.php?pk=816991" hreflang="de" rel="alternate"/>
#   <link href="https://www.rockauto.com/fr/moreinfo.php?pk=816991" hreflang="fr" rel="alternate"/>
#  </head>
#  <body class="mi-body" onload="ResizePiclookup();">
#   <div id="mi_everything">
#    <div>
#     <div style="float:left; margin-right:1em;">
#      <a href="https://www.standardbrand.com/en" target="_blank">
#       <img alt="STANDARD MOTOR PRODUCTS" border="0" src="/logos/SMPLogo.png" style="max-height:100px;"/>
#      </a>
#     </div>
#     <div style="float:left;">
#      <img alt="STANDARD MOTOR PRODUCTS" border="0" src="/logos/StandardLogo.png" style="max-height:100px;"/>
#     </div>
#     <div style="float:right;">
#      <table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">
#       <tr>
#        <td style="text-align: center">
#         <a href="/" onclick="AddSerializedCookieDataToHref(this);">
#          <img alt="Go to RockAuto Home Page" border="0" class="ralogo" src="/Images/logoNoLine.png"/>
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div style="font-size:.9em;">
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <div class="bdytext hide-for-inline-mobile">
#     <div style="float: left; padding-right: 20px;">
#      <div style="padding-bottom:.4em;">
#       More Information for STANDARD MOTOR PRODUCTS ALS100
#      </div>
#      <div style="padding-bottom:.4em;">
#      </div>
#      <input class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" id="mi_continue_shopping_btn" onclick="if(HasOpener()) window.close(); else window.location='/?mfr=STANDARD+MOTOR+PRODUCTS&amp;partnum=ALS100';" style="padding-top: 5px; padding-bottom: 5px; background-position: left center;" title="Back to the RockAuto Catalog" type="button" value="Continue Shopping"/>
#      <div class="show-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('mi_continue_shopping_btn')" style="display: inline-block; font-size: 13px;">
#       <img alt="" class="la-btn-v" src="/Images/mobile/left_arrow_white.png" style="height: 1em; margin-right: .25em;"/>
#       <span class="la-btn-v">
#        Continue Shopping
#       </span>
#      </div>
#     </div>
#     <div class="buybox show-if-js" style="float: right;">
#      <section aria-label="Add to Cart">
#       <table border="0" cellpadding="0" cellspacing="0" id="frmlistings[1]">
#        <tbody class="listing-inner" id="mibuybox" style="">
#         <tr>
#          <td class="buybox-inner-content">
#           <span style="float: right;">
#           </span>
#           <div>
#           </div>
#           <div class="listing-text-row-moreinfo-truck">
#            <b>
#             <span class="listing-final-manufacturer">
#              STANDARD MOTOR PRODUCTS
#             </span>
#            </b>
#            <span alt="Buyer's Guide" class="listing-final-partnumber as-link-if-js" id="vew_partnumber[1]" onclick='if (cataloglite.IsMobileAndNotExpanded("1")) { return; } cataloglite.ShowBuyersGuidePopup("1");' title="Buyer's Guide">
#             ALS100
#            </span>
#            <span class="truck ra-hide remove-for-print mouseover" name="vew_whtruckicon[1][0-0-0-1]" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', &quot;Could ship from same location as parts in cart&quot;, null, this); RA.StopBubble(event); return false;" title="Could ship from same location as parts in cart">
#            </span>
#           </div>
#           <div class="listing-text-row buybox-rebate">
#           </div>
#           <div>
#           </div>
#          </td>
#          <td class="buybox-inner-content">
#           <div class="listing-quantity-adjustment ib remove-for-print show-if-js" id="frmlistings[1]">
#            <input autocomplete="off" id="listingoptkeytomultiple[1]" type="hidden" value='{"0-0-0-1":"1"}'/>
#            <input autocomplete="off" id="listingoptkeytolinenumber[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoqtyincart[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoalternateid[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <table class="tblz di tbl-input-button-attached" id="listingquantitytable[1]">
#             <tr>
#              <td class="td-button-left" style="text-align: right;">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", -1);' style="border-top-left-radius: 4px; border-bottom-left-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_down_white.png"/>
#               </div>
#              </td>
#              <td class="td-input">
#               <label for="raquantity[1]" style="display:none;">
#                Quantity
#               </label>
#               <input aria-label="Quantity" autocapitalize="off" autocomplete="off" autocorrect="off" class="input-quantity ib" data-autofill="block" id="raquantity[1]" maxlength="5" name="raquantity[1]" onchange='cataloglite.ListingQuantityUpdate("1");' onkeypress='return RA.InterceptEnter(event, function(){RA.ByName("raquantity[1]")[0].blur()});' spellcheck="false" style="text-align: center; width: 2em; padding-left: 0;" type="text" value="1"/>
#              </td>
#              <td class="td-button-right">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", 1);' style="border-top-right-radius: 4px; border-bottom-right-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_up_white.png"/>
#               </div>
#              </td>
#             </tr>
#            </table>
#            <input autocomplete="off" id="optionchoice[1]" name="optionchoice[1]" type="hidden" value="0-0-0-1"/>
#            <input autocomplete="off" id="listing_data_essential[1]" name="listing_data_essential[1]" type="hidden" value='{"groupindex":"1","carcode":null,"parttype":"10634","partkey":"816991","opts":{"0-0-0-1":{"warehouse":"27530","whpartnum":"STD ALS100","optionlist":"0","paramcode":"0","notekey":"0","multiple":"1"}}}'/>
#            <input autocomplete="off" id="listing_data_supplemental[1]" type="hidden" value='{"partnumber":"ALS100","catalogname":"STANDARD MOTOR PRODUCTS","belongstolisting":"1","markets":null,"sortgroup":null,"sortgrouptext":null,"paramdesc":null}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="lst_shipwhlist[1][0-0-0-1]" type="hidden" value='{"23220":0,"44056":1,"11385":2,"90746":3,"93722":4,"85011":5,"72901":6,"80011":7,"6405":8,"23842":9,"27105":10,"85042":11,"92829":12,"90660":13,"95677":14,"20723":15,"83714":16,"98059":17,"85281":18,"97124":19,"8854":20,"10462":21,"11570":22,"95815":23,"85015":24,"23844":25,"14608":26,"33013":27,"92407":28,"44132":29,"30073":30,"72114":31,"64121":32,"14228":33,"11377":34,"60524":35}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][0-0-0-1]" type="hidden" value="true"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnnotifyoos[1][0-0-0-1]" type="hidden" value="null"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][0-0-0-1]" type="hidden" value="true"/>
#           </div>
#          </td>
#          <td class="listing-float-box-cell-shared listing-float-box-cell-more-padding" colspan="4" id="listingtd[1][price]" style="height: 1px; text-align: center;">
#           <span class="" id="dprice[1][td]">
#            <span class="ra-formatted-amount listing-price listing-amount-bold">
#             <span id="dprice[1][v]">
#              $18.36
#             </span>
#            </span>
#           </span>
#           <div class="none" style="font-size:.8em;">
#            Price
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][core]" style="height: 1px; text-align: center;">
#           <span class="" id="dcore[1][td]">
#            <span class="ra-formatted-amount listing-core">
#             <a class="" href="/help/?page=2#CORE" id="dcore[1][color]" onclick="return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#              <span id="dcore[1][v]">
#               $0.00
#              </span>
#             </a>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Core
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][total]" style="height: 1px; text-align: center;">
#           <span class="listing-amount-bold" id="dtotal[1][td]">
#            <span class="ra-formatted-amount listing-total">
#             <span id="dtotal[1][v]">
#              $18.36
#             </span>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Total
#           </div>
#          </td>
#          <td class="buybox-inner-content" style="white-space:nowrap; padding-right:.5em;">
#           <div class="catalog-listing-buttons-wrapper ib" style="min-width:105px;">
#            <div class="vew_btnaddtocart remove-for-print" id="vew_btnaddtocart[1]">
#             <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-hotgreen" id="addpart[1]" name="addpart[1]" onclick="showLoading(); RA.SubscribeOnce('cartevent', 'callback_complete', function () { AddPartToCart_cb(); }); cataloglite.Cart.AddPartToCart(&quot;1&quot;); return false;" type="submit" value="Add to Cart &gt;"/>
#             <a class="show-if-js ra-btn ra-btn-color-hotgreen ra-btn-size-normal ra-btn-add-part" href="#" onclick="RA.Click('addpart[1]'); return false;" style="display: inline-block;">
#              <span class="la-btn-v">
#               Add to Cart
#              </span>
#              <img alt="" class="la-btn-v" src="/Images/mobile/right_arrow_white.png" style="height: 1em; margin-left: .25em;"/>
#             </a>
#            </div>
#            <div class="vew_btnpartincart remove-for-print ra-hide" id="vew_btnpartincart[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-part-in-cart" name="addpart[1]" onclick="cataloglite.Cart.ShowPartAlreadyInCart(1); return false;" type="submit" value="Part In Cart"/>
#            </div>
#            <div class="vew_btnnotifyoos remove-for-print ra-hide show-if-js" id="vew_btnnotifyoos[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" onclick='cataloglite.GetAvailabilityAlertForOOSPart("1");' type="button" value="Notify Me When Available"/>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#           <div class="listing-text-row">
#           </div>
#           <div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </section>
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <table class="bdytext" style="width: 100%; border: none;">
#     <tr>
#      <td style="width: 525px; " valign="top">
#       <div style="">
#        <table cellpadding="8" cellspacing="0" style="border: 1px solid #dcdcdc;">
#         <tr align="center">
#          <td colspan="3" style="width: 500px;">
#           <section aria-label="Image of part">
#            <img alt="Zoom Lens" id="zoomlens" onmousemove="MouseMoveZoom(null, event);" onmouseout="MouseOutOfLens(null, event);" onmouseover="MouseOverLens(null, event);" src="/catalog/images/transpurple100.png" style="position: absolute: width: 100px; height: 100px; display: none; border: 1px solid white; z-index: 10;"/>
#            <div class="">
#             <table class="tblz listing-image-table" id="listing_image_table[1]" style=" width: 100%;">
#              <tr>
#               <td class="listing-image-table-centercol">
#                <div class="" id="inlineimgpositionancestor[1]" style=" position: relative; z-index: 1; width: 100%;">
#                 <div class="listing-inlineimg_container" id="inlineimg_container[1]" style="z-index: 1; text-align: center; background: #FFFFFF; width: 100%;">
#                  <div class="listing-inline-image-popup-widget-title ra-hide" id="inlineimg_containertitle[1]" onmousedown='cataloglite.ImagePopupTitleMouseDown("1")'>
#                   <div style="text-align: center; ">
#                    <span style="padding: 0 2em 0 2em;">
#                     STANDARD MOTOR PRODUCTS ALS100
#                    </span>
#                    <span style="position: absolute; right: 5px;">
#                     <img alt="close" onclick='cataloglite.Listing_InlineImagePopupInPlace("1")' src="/catalog/images/close12_1.gif" style="cursor: pointer; display: block;"/>
#                    </span>
#                   </div>
#                  </div>
#                  <div class="img-topper-container" id="inlineimg_topper[1]">
#                   <table class="tblz w100">
#                    <tr>
#                     <td class="pinched" style="vertical-align: top;">
#                      <div style="text-align: left; padding-right: .25em;">
#                       <span id="inlineimg_left_big[1]">
#                        <img alt="&lt;" class="listing-image-prevnext-image-moreinfo remove-for-print show-if-js" id="inlineimgprevious[1]" onclick='cataloglite.Listing_InlineImageManualScroll("1", -1, false, false)' src="/catalog/images/prevIMGbig.png" style=" margin: .1em;" title="Previous Image"/>
#                       </span>
#                      </div>
#                      <div class="listing-image-counter">
#                       <div class="inner" id="imagecounterdisplay[1]">
#                       </div>
#                      </div>
#                     </td>
#                     <td style="vertical-align: top;">
#                      <div id="pointtozoom" style="text-align:center; font-size: 11px; color: blue; white-space: nowrap; visibility: hidden;">
#                       Point to Zoom
#                      </div>
#                      <div class="img-carousel-titlephrase" id="imgcarouseltitlephrase[1]">
#                      </div>
#                      <div class="ra-hide" id="inlineimg_container360menu[1]" onmouseout='cataloglite.Listing_360ImageStartAutomatic("1");' onmouseover='cataloglite.Listing_360ImagesStopAutomatic("1");' style="padding: .25em; margin-bottom: .5em;">
#                       <div class="ra-bar-slider-bar-c">
#                        <div class="ra-bar-slider-bar" id="inlineimg_sliderbar[1]" onmousedown='cataloglite.ImageSliderMouseDown("1", event);' ontouchstart='cataloglite.ImageSliderMouseDown("1", event);'>
#                         <span class="ra-bar-slider-slider" id="inlineimg_slider[1]">
#                         </span>
#                        </div>
#                       </div>
#                      </div>
#                     </td>
#                     <td class="pinched" style="vertical-align: top; text-align: right;">
#                      <div style="padding-left: .25em;">
#                       <span id="inlineimg_right_big[1]">
#                        <img alt="&gt;" class="listing-image-prevnext-image-moreinfo show-if-js remove-for-print" id="inlineimgnext[1]" name="inlnimgnextbtn" onclick='cataloglite.Listing_InlineImageManualScroll("1", 1, false, false)' src="/catalog/images/nextIMGbig.png" style=" margin: .1em;" title="Next Image"/>
#                       </span>
#                      </div>
#                     </td>
#                    </tr>
#                   </table>
#                  </div>
#                  <div class="inlineimg_containersizer" id="inlineimg_containersizer[1]" style="">
#                   <img alt="Part image" class="listing-inline-image listing-inline-image-moreinfo" id="inlineimg[1]" onmousemove='ShowZoomLens("1", event); MouseMoveZoom("1", event);' onmouseout='MouseOutOfImage("1", event);' onmouseover='MouseOverImage("1", event);' src="/info/154/ALS100_Front.jpg"/>
#                  </div>
#                 </div>
#                </div>
#               </td>
#              </tr>
#             </table>
#             <input autocomplete="off" id="jsninlineimg[1]" type="hidden" value='{"Size":"Popup","SlotIndex":0,"Slots":[{"Type":"Single","ImageData":{"Thumb":"\/info\/154\/ALS100_Front__ra_m.jpg","Popup":"\/info\/154\/ALS100_Front.jpg","Full":"\/info\/154\/ALS100_Front.jpg"},"TitlePhrase":null,"ParamCode":"0"},{"Type":"Single","ImageData":{"Thumb":"\/info\/154\/ALS100_Back__ra_m.jpg","Popup":"\/info\/154\/ALS100_Back.jpg","Full":"\/info\/154\/ALS100_Back.jpg"},"TitlePhrase":null,"ParamCode":"0"},{"Type":"Single","ImageData":{"Thumb":"\/info\/154\/ALS100_Bottom__ra_m.jpg","Popup":"\/info\/154\/ALS100_Bottom.jpg","Full":"\/info\/154\/ALS100_Bottom.jpg"},"TitlePhrase":null,"ParamCode":"0"},{"Type":"Single","ImageData":{"Thumb":"\/info\/154\/ALS100_Connector__ra_m.jpg","Popup":"\/info\/154\/ALS100_Connector.jpg","Full":"\/info\/154\/ALS100_Connector.jpg"},"TitlePhrase":null,"ParamCode":"0"},{"Type":"Single","ImageData":{"Thumb":"\/info\/154\/ALS100_Other__ra_m.jpg","Popup":"\/info\/154\/ALS100_Other.jpg","Full":"\/info\/154\/ALS100_Other.jpg"},"TitlePhrase":null,"ParamCode":"0"}],"IsMoreInfoPageImageBox":1}'/>
#            </div>
#            <script>
#             last_group_index = "1";
#            </script>
#            <script>
#             setInterval(function () {if (!document.getElementById("pointtozoom")) { return; } document.getElementById("pointtozoom").style.visibility = (IsCurrentImageZoomable(null) ? "visible" : "hidden");}, 250);
#            </script>
#            <script>
#             setTimeout(function () {if (!document.getElementById("pointtozoom")) { return; } cataloglite.Listing_InlineImageManualScroll("1", 0);}, 250);
#            </script>
#           </section>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#        <table class="disclaimer" width="100%">
#         <tr>
#          <td valign="top">
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#        <section aria-label="STANDARD MOTOR PRODUCTS ALS100 Specifications">
#         <table class="moreinfotable" style="width: 500px; margin-left:5px;">
#          <tr>
#           <th colspan="2">
#            STANDARD MOTOR PRODUCTS ALS100 Specifications
#           </th>
#          </tr>
#          <tr>
#           <td>
#            Connector Gender
#           </td>
#           <td>
#            Female
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Connector Quantity
#           </td>
#           <td>
#            3
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Connector Shape
#           </td>
#           <td>
#            Rectangular
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Harness Length - Inches
#           </td>
#           <td>
#            4
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Harness Length - mm
#           </td>
#           <td>
#            101.6 mm
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Mounting Location
#           </td>
#           <td>
#            Spindle
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Number of Bolt Holes
#           </td>
#           <td>
#            1
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Terminal Gender
#           </td>
#           <td>
#            Male Female
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Terminal Quantity
#           </td>
#           <td>
#            6
#           </td>
#          </tr>
#          <tr>
#           <td>
#            Terminal Type
#           </td>
#           <td>
#            Blade
#           </td>
#          </tr>
#         </table>
#        </section>
#       </div>
#      </td>
#      <td valign="top">
#       <div style="position: absolute; background: white;">
#        <img alt="" id="zoomedimage" onmousedown="HideZoomLens(event);" src="/catalog/images/clear100.png" style="display: none; border: 1px solid #777777;"/>
#       </div>
#      </td>
#      <td valign="top">
#       <table border="0" cellspacing="5" class="bdydesc">
#        <tr>
#         <td>
#          <section aria-label="Part Description">
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#        <tr>
#         <td>
#          <section aria-label="More Information for STANDARD MOTOR PRODUCTS ALS100">
#           Standard® is the premier professional engine management brand in the automotive aftermarket today. Standard leads the way in advanced automotive technology with more than 40,000 products for complete vehicle coverage.
#           <br/>
#           <br/>
#           <strong>
#            Features &amp; Benefits:
#           </strong>
#           <ul>
#            <li>
#             External and internal nitrile rubber oil seal provides secure fit for leak-proof operation
#            </li>
#            <li>
#             High-temperature insulated copper windings ensure longevity in extreme conditions
#            </li>
#            <li>
#             High-performance magnetic circuit design provides reliable output signal during all vehicle conditions
#            </li>
#            <li>
#             Undergoes 100% end-of-line testing for proper signal amplitude and frequency
#            </li>
#           </ul>
#           <div class="mil-spacer">
#           </div>
#           <div style="font-weight: bold; font-size: 1.1em; border-bottom: 2px solid #383838; color:#000000; text-align: left; padding-bottom: 2px;
# ">
#            <img alt="" src="/Images/MoreInfo/bulb.png" style="width:25px;padding-right:5px;vertical-align:middle;"/>
#            Symptoms of a Failing Speed Sensor vs. ABS Wheel Speed Sensor
#           </div>
#           <p>
#            Some vehicles may use the same part for both a Speed Sensor and an ABS Wheel Speed Sensor, while others may use two different parts. These parts serve different systems of the vehicle and may fail for different reasons - it is important to replace the proper sensor to fix the underlying issue.
#           </p>
#           <style>
#            .roundedTable
# 	{
# 		border-radius: 6px 6px 6px 6px;
# 		border: 1px solid rgb(192, 192, 192);
# 		border-spacing: 0;
# 		width:350px;
#  font-size:11px;
#
#  display: inline-block;
# 	}
#
# 	.roundedTable tr:first-child td:first-child
# 	{
# 		border-top-left-radius: 5px;
# 	}
#
# 	.roundedTable tr:first-child td:last-child
# 	{
# 		border-top-right-radius: 5px;
# 	}
#
# 	.roundedTable tr:last-child td:first-child
# 	{
# 		border-bottom-left-radius: 5px;
# 	}
#
# 	.roundedTable tr:last-child td:last-child
# 	{
# 		border-bottom-right-radius: 5px;
# 	}
#
#
# 	.roundedTable tr:first-child td:first-child
# 	{
# 		background-color: rgb(97, 98, 144);
# 		color: white;
#  text-align: center;
#  border-bottom: 5px solid rgb(255, 255, 190);
#  font-size: 11px;
#  width: 350px;
# 	}
#  .roundedTable tr:last-child td:last-child
# 	{
# 		background-color: rgb(250, 250, 250);
#  height: 120px;
# 	}
#           </style>
#           <table class="roundedTable">
#            <tbody style="color:rgb(56, 56, 56)">
#             <tr>
#              <td style="padding: 5px 5px 5px 5px;">
#               <b>
#                SPEED SENSOR
#                <br/>
#               </b>
#              </td>
#             </tr>
#             <tr>
#              <td style="padding: 5px 5px 5px 5px;">
#               <p>
#                The Speed Sensor(s) measure rotational speed of the transmission shafts. Common failure symptoms include:
#               </p>
#               <ul>
#                <li>
#                 Erratic Speedometer Behavior
#                </li>
#                <li>
#                 Harsh or Improper Shifting
#                </li>
#                <li>
#                 Loss of Cruise Control
#                </li>
#                <li>
#                 Surging or Hesitation
#                </li>
#                <li>
#                 Check Engine Light On
#                </li>
#               </ul>
#               <span style="float:right; color:grey;">
#                Located in 'Electrical'
#               </span>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#           <table class="roundedTable">
#            <tbody style="color:rgb(56, 56, 56)">
#             <tr>
#              <td style="padding: 5px 5px 5px 5px;">
#               <b>
#                ABS WHEEL SPEED SENSOR
#               </b>
#              </td>
#             </tr>
#             <tr>
#              <td style="padding: 5px 5px 5px 5px;">
#               <p>
#                The Anti-Lock Brake System (ABS) sensor monitors wheel speed. Common failure symptoms include:
#               </p>
#               <ul>
#                <li>
#                 ABS Light On
#                </li>
#                <li>
#                 Brake Pulsing
#                </li>
#                <li>
#                 No / Erratic Traction or Stability Control
#                </li>
#                <li>
#                 No / Erratic ABS Operation
#                </li>
#                <li>
#                 Braking Without Pedal Contact
#                </li>
#               </ul>
#               <span style="float:right; color:grey;">
#                Located in 'Brake &amp; Wheel Hub'
#               </span>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#           <div class="mil-spacer">
#           </div>
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#        <tr>
#         <td>
#          <section aria-label="Alternate/OEM Part Number(s)">
#           OEM / Interchange Numbers: 05014787AA, 5014787AA, 5014787AB, 5016133AA, 56028187AB, 56028187AC, 56028229AA, ALS101
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="warranty">
#        <tr>
#         <td>
#          <br/>
#          <section aria-label="Warranty Information">
#           Warranty Information:36 Months / 36,000 Miles
#           <a href="/genImages/154/Standard_AllLines_Warranty.pdf" target="_blank">
#            Warranty Details
#           </a>
#          </section>
#         </td>
#        </tr>
#       </table>
#       <p class="bdytext hide-for-inline-mobile">
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <script>
#    /**UQ:51242513**/
# PK_ADDINGPARTTOCART = "Adding Part to Cart";
# PK_ADDTOLIST = "Add to My List";
# PK_ADJUSTQUANTITY = "Adjust Quantity";
# PK_BIGGER = "Bigger";
# PK_CALCTAXTOTAL = "Calculating Tax & Total";
# PK_CALCULATESHIPPING = "Calculate Shipping";
# PK_CANCEL = "Cancel";
# PK_CART = "Cart";
# PK_CARTNAME = "Cart Name";
# PK_CARTNOTIFICATION = "Notification";
# PK_CONFIRMCLEARCART = "Are you sure you want to clear this cart?";
# PK_ENTERNEWQUANTITY = "Enter a new quantity:";
# PK_GETTINGSHIPQUOTES = "Calculating Shipping Cost";
# PK_HELP = "Help";
# PK_IMAGEDOESNOTREPRESENT = "Image does not represent KEY__PARAMDESC selected in catalog";
# PK_INVALIDID = "Invalid ID. Please be sure you have entered a valid Email Address.";
# PK_LOADING = "Loading RockAuto Catalog";
# PK_LOADINGPAYPAL = "<h3>Connecting to PayPal<\/h3>If you continue to see this message after a short period of time, please close this window to return to the RockAuto website.";
# PK_LOADINGPLAIN = "Loading";
# PK_LOOKINGUPADDRESS = "Looking up Address";
# PK_MULTIPLEMATCHESPLZREFINE = "Multiple matches found. Please refine search.";
# PK_MYADDRESSES = "My Addresses";
# PK_NO = "No";
# PK_NOMATCHESFOUND = "No Matches Found";
# PK_NOPARTSFNDINMARKET = "No Parts Found for Selected Market(s)";
# PK_NUM_LISTINGS_HIDDEN = "Reset (KEY__NUM listings hidden) <img src=\"\/catalog\/images\/whiteX.png\" style=\"height:.9em;\" alt=\"\">";
# PK_OK = "OK";
# PK_PART = "Part";
# PK_PARTALREADYINCART = "This part is already in the cart. Please update the quantity in the cart to reflect the quantity you want.";
# PK_PLEASE = "Please";
# PK_PLEASEENTERPASSWORD = "Please enter your password";
# PK_REMOVE = "Remove";
# PK_RENAME = "Rename";
# PK_RENAMECART = "Rename Cart";
# PK_SMALLER = "Smaller";
# PK_SUBSCRIBETORSS = "Subscribe to RSS feed to be notified when new parts are added for this car";
# PK_THISVEHICLEISSAVEDTOLIST = "This vehicle is saved to your list.";
# PK_UPDATINGADDRESS = "Updating Address Information";
# PK_UPDATINGCART = "Updating Cart";
# PK_XLISTINGREMOVE = "KEY__NUM listing removed";
# PK_XLISTINGSREMOVE = "KEY__NUM listings removed";
# PK_YES = "Yes";
# window.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\/0bbOhvn7P3rkFbL80\/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDJ3DAD\/oIoMxqIlP9N2seepz\/c5kQwxdc9NYRBNXVPXn3PmG+TqJmrbpfYC\/jvYdu";
#   </script>
#  </body>
# </html>

# %%
with open('./detail.html', 'w', encoding='utf-8') as file:
    file.write(str(soup))

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

dict_oe = {'alternate_inventory_number': '', 'oem_interchange_number': ''}
list_oe = []
list_section = html.xpath('//section[@aria-label="Alternate/OEM Part Number(s)"]')
for section in list_section:
    list_oe.append(''.join(section.xpath('./descendant-or-self::*/text()')))

list_oe
# Out:
# ['OEM / Interchange Numbers: 05014787AA, 5014787AA, 5014787AB, 5016133AA, 56028187AB, 56028187AC, 56028229AA, ALS101']

# %%
for oe in list_oe:
    if '{Alternate Inventory Numbers: ' in oe:
        dict_oe['alternate_inventory_number'] = oe.replace('{Alternate Inventory Numbers: ', '').replace('}', '').replace(', ', ';')
    elif 'OEM / Interchange Numbers: ' in oe:
        dict_oe['oem_interchange_number'] = oe.replace('OEM / Interchange Numbers: ', '').replace(', ', ';')

dict_oe
# Out:
# {'alternate_inventory_number': '',
#  'oem_interchange_number': '05014787AA;5014787AA;5014787AB;5016133AA;56028187AB;56028187AC;56028229AA;ALS101'}

# %%
list_src = html.xpath('//img[@alt="Part image"]/@src')
if len(list_src) == 0:
    src = ''
else:
    src = 'https://www.rockauto.com' + list_src[0]

src
# Out:
# 'https://www.rockauto.com/info/154/ALS100_Front.jpg'

# %%
df_temp = pd.DataFrame([{'Info': list_info[i],
                         'Alternate Inventory Number': dict_oe['alternate_inventory_number'],
                         'OEM / Interchange Numbers': dict_oe['oem_interchange_number'],
                         'Src': src,
                         'status': 'ok'}])

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#                                                 Info  \
# 0  https://www.rockauto.com/en/moreinfo.php?pk=81...
#
#   Alternate Inventory Number  \
# 0
#
#                            OEM / Interchange Numbers  \
# 0  05014787AA;5014787AA;5014787AB;5016133AA;56028...
#
#                                                  Src status
# 0  https://www.rockauto.com/info/154/ALS100_Front...     ok
