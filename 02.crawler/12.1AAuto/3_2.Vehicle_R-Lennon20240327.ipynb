# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./part.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                resp = requests.get('https://www.1aauto.com/catalog/product/fit?skuId=' + input_.loc[a, 'Product_Id'] + '&pathName=' + input_.loc[a, 'Url'].replace('https://www.1aauto.com', '').replace('/', '%2F'),
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                html = etree.HTML(str(soup))
                
                # = = = = = = = = = = = = = = =
                
                list_tr = html.xpath('//tr[@class="sortable_row filter-field"]')

                # = = = = = = = = = = = = = = =
                
                dict_vehicle = {}
                for tr in list_tr:
                    make = tr.xpath('./td[2]/text()')[0].strip()
                    model = tr.xpath('./td[3]/text()')[0].strip()
                    year_start = int(tr.xpath('./td[1]/text()')[0].split('-')[0].strip())
                    year_end = int(tr.xpath('./td[1]/text()')[0].split('-')[-1].strip())

                    if make not in dict_vehicle:
                        dict_vehicle[make] = {model: [year_start, year_end]}
                    else:
                        if model not in dict_vehicle[make]:
                            dict_vehicle[make][model] = [year_start, year_end]
                        else:
                            dict_vehicle[make][model].append(year_start)
                            dict_vehicle[make][model].append(year_end)

                    dict_vehicle[make][model] = list(set(dict_vehicle[make][model]))
                    dict_vehicle[make][model].sort()
                
                # = = = = = = = = = = = = = = =
                
                list_vehicle = []
                for make in dict_vehicle:
                    for model in dict_vehicle[make]:
                        year_max = max(dict_vehicle[make][model])
                        year_min = min(dict_vehicle[make][model])
                        if year_max == year_min:
                            list_vehicle.append(make + ' ' + model + ' ' + str(year_min))
                        else:
                            list_vehicle.append(make + ' ' + model + ' ' + str(year_min) + '-' + str(year_max))

                vehicle = '\n'.join(list_vehicle)
                
                # = = = = = = = = = = = = = = =
                                
                oe = ';'.join(sorted(list(set([oe.strip() for oe in html.xpath('//table[@id="interchange-codes-table"]/tbody/tr/td[2]/text()')]))))

                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'Product_Id': input_.loc[a, 'Product_Id'],
                                         'Vehicle': vehicle,
                                         'OE': oe}])

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
                
                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'Product_Id': input_.loc[a, 'Product_Id'],
                                     'Url': input_.loc[a, 'Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Product_Id'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['Product_Id'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./vehicle-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['Product_Id'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./vehicle_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：500
#
# [ok] - 1152841
# [尝试次数：1] - [剩余数量：490] - [当前时间：16:34:21]
#
# [ok] - 1152833
# [尝试次数：1] - [剩余数量：489] - [当前时间：16:34:21]
#
# [ok] - 1176157
# [尝试次数：1] - [剩余数量：488] - [当前时间：16:34:21]
#
# [ok] - 1188171
# [尝试次数：1] - [剩余数量：487] - [当前时间：16:34:21]
#
# [ok] - 1152832
# [尝试次数：1] - [剩余数量：486] - [当前时间：16:34:21]
#
# [ok] - 1152814
# [尝试次数：1] - [剩余数量：485] - [当前时间：16:34:21]
#
# [ok] - 1176156
# [尝试次数：1] - [剩余数量：484] - [当前时间：16:34:21]
#
# [ok] - 1188545
# [尝试次数：1] - [剩余数量：483] - [当前时间：16:34:21]
#
# [ok] - 1161722
# [尝试次数：1] - [剩余数量：482] - [当前时间：16:34:22]
#
# [ok] - 1161803
# [尝试次数：1] - [剩余数量：481] - [当前时间：16:34:22]
#
# [ok] - 1161786
# [尝试次数：1] - [剩余数量：480] - [当前时间：16:34:23]
#
# [ok] - 1188405
# [尝试次数：1] - [剩余数量：479] - [当前时间：16:34:23]
#
# [ok] - 1161852
# [尝试次数：1] - [剩余数量：478] - [当前时间：16:34:23]
#
# [ok] - 1176393
# [尝试次数：1] - [剩余数量：477] - [当前时间：16:34:23]
#
# [ok] - 1188153
# [尝试次数：1] - [剩余数量：476] - [当前时间：16:34:23]
#
# [ok] - 1161801
# [尝试次数：1] - [剩余数量：475] - [当前时间：16:34:23]
#
# [ok] - 1169650
# [尝试次数：1] - [剩余数量：474] - [当前时间：16:34:23]
#
# [ok] - 1176372
# [尝试次数：1] - [剩余数量：473] - [当前时间：16:34:24]
#
# [ok] - 1209175
# [尝试次数：1] - [剩余数量：472] - [当前时间：16:34:24]
#
# [ok] - 1162036
# [尝试次数：1] - [剩余数量：471] - [当前时间：16:34:24]
#
# [ok] - 1209094
# [尝试次数：1] - [剩余数量：470] - [当前时间：16:34:24]
#
# [ok] - 1188568
# [尝试次数：1] - [剩余数量：469] - [当前时间：16:34:25]
#
# [ok] - 1142927
# [尝试次数：1] - [剩余数量：468] - [当前时间：16:34:25]
#
# [ok] - 1176345
# [尝试次数：1] - [剩余数量：467] - [当前时间：16:34:25]
#
# [ok] - 1188559
# [尝试次数：1] - [剩余数量：466] - [当前时间：16:34:25]
#
# [ok] - 1162037
# [尝试次数：1] - [剩余数量：465] - [当前时间：16:34:26]
#
# [ok] - 1177888
# [尝试次数：1] - [剩余数量：464] - [当前时间：16:34:26]
#
# [ok] - 1220822
# [尝试次数：1] - [剩余数量：463] - [当前时间：16:34:26]
#
# [ok] - 1188180
# [尝试次数：1] - [剩余数量：462] - [当前时间：16:34:26]
#
# [ok] - 1195906
# [尝试次数：1] - [剩余数量：461] - [当前时间：16:34:27]
#
# [ok] - 1176378
# [尝试次数：3] - [剩余数量：460] - [当前时间：16:34:28]
#
# [ok] - 1152825
# [尝试次数：1] - [剩余数量：459] - [当前时间：16:34:28]
#
# [ok] - 1188149
# [尝试次数：4] - [剩余数量：458] - [当前时间：16:34:28]
#
# [ok] - 1188163
# [尝试次数：5] - [剩余数量：457] - [当前时间：16:34:29]
#
# [ok] - 1103323
# [尝试次数：2] - [剩余数量：456] - [当前时间：16:34:30]
#
# [ok] - 1118489
# [尝试次数：1] - [剩余数量：455] - [当前时间：16:34:30]
#
# [ok] - 1188756
# [尝试次数：10] - [剩余数量：454] - [当前时间：16:34:30]
#
# [ok] - 1209145
# [尝试次数：3] - [剩余数量：453] - [当前时间：16:34:30]
#
# [ok] - 1176574
# [尝试次数：1] - [剩余数量：452] - [当前时间：16:34:31]
#
# [ok] - 1209111
# [尝试次数：8] - [剩余数量：451] - [当前时间：16:34:31]
#
# [ok] - 1195865
# [尝试次数：3] - [剩余数量：450] - [当前时间：16:34:32]
#
# [ok] - 1169707
# [尝试次数：1] - [剩余数量：449] - [当前时间：16:34:33]
#
# [ok] - 1161802
# [尝试次数：9] - [剩余数量：448] - [当前时间：16:34:34]
#
# [ok] - 1169765
# [尝试次数：8] - [剩余数量：447] - [当前时间：16:34:35]
#
# [ok] - 1152840
# [尝试次数：5] - [剩余数量：446] - [当前时间：16:34:35]
#
# [ok] - 1176141
# [尝试次数：11] - [剩余数量：445] - [当前时间：16:34:35]
#
# [ok] - 1188263
# [尝试次数：1] - [剩余数量：444] - [当前时间：16:34:36]
#
# [ok] - 1209101
# [尝试次数：2] - [剩余数量：443] - [当前时间：16:34:36]
#
# [ok] - 1176648
# [尝试次数：6] - [剩余数量：442] - [当前时间：16:34:36]
#
# [ok] - 1188271
# [尝试次数：2] - [剩余数量：441] - [当前时间：16:34:37]
#
# [ok] - 1188386
# [尝试次数：1] - [剩余数量：440] - [当前时间：16:34:37]
#
# [ok] - 1209029
# [尝试次数：1] - [剩余数量：439] - [当前时间：16:34:38]
#
# [ok] - 1188264
# [尝试次数：6] - [剩余数量：438] - [当前时间：16:34:38]
#
# [ok] - 1188404
# [尝试次数：1] - [剩余数量：437] - [当前时间：16:34:38]
#
# [ok] - 1177843
# [尝试次数：7] - [剩余数量：436] - [当前时间：16:34:39]
#
# [ok] - 1170987
# [尝试次数：3] - [剩余数量：435] - [当前时间：16:34:40]
#
# [ok] - 1076475
# [尝试次数：9] - [剩余数量：434] - [当前时间：16:34:40]
#
# [ok] - 1152844
# [尝试次数：3] - [剩余数量：433] - [当前时间：16:34:40]
#
# [ok] - 1199392
# [尝试次数：4] - [剩余数量：432] - [当前时间：16:34:40]
#
# [ok] - 1188601
# [尝试次数：3] - [剩余数量：431] - [当前时间：16:34:40]
#
# [ok] - 1188154
# [尝试次数：3] - [剩余数量：430] - [当前时间：16:34:41]
#
# [ok] - 1209050
# [尝试次数：3] - [剩余数量：429] - [当前时间：16:34:42]
#
# [ok] - 1209102
# [尝试次数：3] - [剩余数量：428] - [当前时间：16:34:42]
#
# [ok] - 1209156
# [尝试次数：1] - [剩余数量：427] - [当前时间：16:34:43]
#
# [ok] - 1176409
# [尝试次数：3] - [剩余数量：426] - [当前时间：16:34:44]
#
# [ok] - 1209135
# [尝试次数：2] - [剩余数量：425] - [当前时间：16:34:45]
#
# [ok] - 1176543
# [尝试次数：4] - [剩余数量：424] - [当前时间：16:34:46]
#
# [ok] - 1169612
# [尝试次数：6] - [剩余数量：423] - [当前时间：16:34:46]
#
# [ok] - 1176623
# [尝试次数：3] - [剩余数量：422] - [当前时间：16:34:46]
#
# [ok] - 1209149
# [尝试次数：27] - [剩余数量：421] - [当前时间：16:34:46]
#
# [ok] - 1209110
# [尝试次数：1] - [剩余数量：420] - [当前时间：16:34:47]
#
# [ok] - 1178003
# [尝试次数：12] - [剩余数量：419] - [当前时间：16:34:47]
#
# [ok] - 1188295
# [尝试次数：1] - [剩余数量：418] - [当前时间：16:34:47]
#
# [ok] - 1188156
# [尝试次数：10] - [剩余数量：417] - [当前时间：16:34:47]
#
# [ok] - 1188542
# [尝试次数：3] - [剩余数量：416] - [当前时间：16:34:48]
#
# [ok] - 1209098
# [尝试次数：1] - [剩余数量：415] - [当前时间：16:34:48]
#
# [ok] - 1209121
# [尝试次数：1] - [剩余数量：414] - [当前时间：16:34:48]
#
# [ok] - 1113755
# [尝试次数：1] - [剩余数量：413] - [当前时间：16:34:49]
#
# [ok] - 1209139
# [尝试次数：3] - [剩余数量：412] - [当前时间：16:34:50]
#
# [ok] - 1209161
# [尝试次数：4] - [剩余数量：411] - [当前时间：16:34:50]
#
# [ok] - 1188151
# [尝试次数：2] - [剩余数量：410] - [当前时间：16:34:51]
#
# [ok] - 1188178
# [尝试次数：3] - [剩余数量：409] - [当前时间：16:34:52]
#
# [ok] - 1162032
# [尝试次数：1] - [剩余数量：408] - [当前时间：16:34:52]
#
# [ok] - 1080873
# [尝试次数：5] - [剩余数量：407] - [当前时间：16:34:52]
#
# [ok] - 1188373
# [尝试次数：14] - [剩余数量：406] - [当前时间：16:34:54]
#
# [ok] - 1178186
# [尝试次数：5] - [剩余数量：405] - [当前时间：16:34:55]
#
# [ok] - 1162035
# [尝试次数：7] - [剩余数量：404] - [当前时间：16:34:55]
#
# [ok] - 1188505
# [尝试次数：4] - [剩余数量：403] - [当前时间：16:34:55]
#
# [ok] - 1176510
# [尝试次数：7] - [剩余数量：402] - [当前时间：16:34:55]
#
# [ok] - 1152843
# [尝试次数：1] - [剩余数量：401] - [当前时间：16:34:56]
#
# [ok] - 1176391
# [尝试次数：6] - [剩余数量：400] - [当前时间：16:34:56]
#
# [ok] - 1152822
# [尝试次数：4] - [剩余数量：399] - [当前时间：16:34:56]
#
# [ok] - 1188187
# [尝试次数：1] - [剩余数量：398] - [当前时间：16:34:56]
#
# [ok] - 1188548
# [尝试次数：3] - [剩余数量：397] - [当前时间：16:34:57]
#
# [ok] - 1209099
# [尝试次数：1] - [剩余数量：396] - [当前时间：16:34:58]
#
# [ok] - 1152831
# [尝试次数：6] - [剩余数量：395] - [当前时间：16:34:58]
#
# [ok] - 1209097
# [尝试次数：11] - [剩余数量：394] - [当前时间：16:34:58]
#
# [ok] - 1209169
# [尝试次数：1] - [剩余数量：393] - [当前时间：16:34:58]
#
# [ok] - 1169685
# [尝试次数：28] - [剩余数量：392] - [当前时间：16:34:59]
#
# [ok] - 1188136
# [尝试次数：6] - [剩余数量：391] - [当前时间：16:35:01]
#
# [ok] - 1176387
# [尝试次数：4] - [剩余数量：390] - [当前时间：16:35:01]
#
# [ok] - 1176120
# [尝试次数：3] - [剩余数量：389] - [当前时间：16:35:02]
#
# [ok] - 1209095
# [尝试次数：3] - [剩余数量：388] - [当前时间：16:35:03]
#
# [ok] - 1094803
# [尝试次数：3] - [剩余数量：387] - [当前时间：16:35:03]
#
# [ok] - 1176181
# [尝试次数：1] - [剩余数量：386] - [当前时间：16:35:04]
#
# [ok] - 1137355
# [尝试次数：32] - [剩余数量：385] - [当前时间：16:35:05]
#
# [ok] - 1176379
# [尝试次数：6] - [剩余数量：384] - [当前时间：16:35:06]
#
# [ok] - 1169767
# [尝试次数：4] - [剩余数量：383] - [当前时间：16:35:07]
#
# [ok] - 1169709
# [尝试次数：4] - [剩余数量：382] - [当前时间：16:35:08]
#
# [ok] - 1209146
# [尝试次数：13] - [剩余数量：381] - [当前时间：16:35:08]
#
# [ok] - 1152815
# [尝试次数：1] - [剩余数量：380] - [当前时间：16:35:09]
#
# [ok] - 1176135
# [尝试次数：5] - [剩余数量：379] - [当前时间：16:35:11]
#
# [ok] - 1152835
# [尝试次数：4] - [剩余数量：378] - [当前时间：16:35:11]
#
# [ok] - 1161800
# [尝试次数：6] - [剩余数量：377] - [当前时间：16:35:11]
#
# [ok] - 1188181
# [尝试次数：1] - [剩余数量：376] - [当前时间：16:35:12]
#
# [ok] - 1209084
# [尝试次数：1] - [剩余数量：375] - [当前时间：16:35:12]
#
# [ok] - 1188553
# [尝试次数：8] - [剩余数量：374] - [当前时间：16:35:13]
#
# [ok] - 1176375
# [尝试次数：20] - [剩余数量：373] - [当前时间：16:35:14]
#
# [ok] - 1209123
# [尝试次数：7] - [剩余数量：372] - [当前时间：16:35:15]
#
# [ok] - 1209107
# [尝试次数：3] - [剩余数量：371] - [当前时间：16:35:16]
#
# [ok] - 1209103
# [尝试次数：1] - [剩余数量：370] - [当前时间：16:35:17]
#
# [ok] - 1193905
# [尝试次数：1] - [剩余数量：369] - [当前时间：16:35:17]
#
# [ok] - 1105596
# [尝试次数：3] - [剩余数量：368] - [当前时间：16:35:17]
#
# [ok] - 1152847
# [尝试次数：11] - [剩余数量：367] - [当前时间：16:35:17]
#
# [ok] - 1195903
# [尝试次数：5] - [剩余数量：366] - [当前时间：16:35:18]
#
# [ok] - 1209106
# [尝试次数：3] - [剩余数量：365] - [当前时间：16:35:18]
#
# [ok] - 1161796
# [尝试次数：2] - [剩余数量：364] - [当前时间：16:35:18]
#
# [ok] - 1153277
# [尝试次数：3] - [剩余数量：363] - [当前时间：16:35:19]
#
# [ok] - 1176620
# [尝试次数：2] - [剩余数量：362] - [当前时间：16:35:19]
#
# [ok] - 1161743
# [尝试次数：4] - [剩余数量：361] - [当前时间：16:35:19]
#
# [ok] - 1176544
# [尝试次数：5] - [剩余数量：360] - [当前时间：16:35:20]
#
# [ok] - 1176645
# [尝试次数：3] - [剩余数量：359] - [当前时间：16:35:20]
#
# [ok] - 1178287
# [尝试次数：8] - [剩余数量：358] - [当前时间：16:35:20]
#
# [ok] - 1176155
# [尝试次数：4] - [剩余数量：357] - [当前时间：16:35:21]
#
# [ok] - 1178375
# [尝试次数：4] - [剩余数量：356] - [当前时间：16:35:21]
#
# [ok] - 1169779
# [尝试次数：2] - [剩余数量：355] - [当前时间：16:35:21]
#
# [ok] - 1169784
# [尝试次数：2] - [剩余数量：354] - [当前时间：16:35:22]
#
# [ok] - 1161742
# [尝试次数：3] - [剩余数量：353] - [当前时间：16:35:22]
#
# [ok] - 1169629
# [尝试次数：4] - [剩余数量：352] - [当前时间：16:35:24]
#
# [ok] - 1188540
# [尝试次数：1] - [剩余数量：351] - [当前时间：16:35:24]
#
# [ok] - 1188269
# [尝试次数：3] - [剩余数量：350] - [当前时间：16:35:24]
#
# [ok] - 1177026
# [尝试次数：5] - [剩余数量：349] - [当前时间：16:35:26]
#
# [ok] - 1178215
# [尝试次数：4] - [剩余数量：348] - [当前时间：16:35:26]
#
# [ok] - 1209031
# [尝试次数：3] - [剩余数量：347] - [当前时间：16:35:26]
#
# [ok] - 1209047
# [尝试次数：1] - [剩余数量：346] - [当前时间：16:35:27]
#
# [ok] - 1209129
# [尝试次数：1] - [剩余数量：345] - [当前时间：16:35:27]
# [ok] - 1209134
# [尝试次数：2] - [剩余数量：344] - [当前时间：16:35:28]
#
# [ok] - 1188157
# [尝试次数：1] - [剩余数量：343] - [当前时间：16:35:29]
#
# [ok] - 1161928
# [尝试次数：3] - [剩余数量：342] - [当前时间：16:35:29]
#
# [ok] - 1176392
# [尝试次数：1] - [剩余数量：341] - [当前时间：16:35:29]
#
# [ok] - 1188523
# [尝试次数：1] - [剩余数量：340] - [当前时间：16:35:30]
#
# [ok] - 1188400
# [尝试次数：2] - [剩余数量：339] - [当前时间：16:35:30]
#
# [ok] - 1103329
# [尝试次数：1] - [剩余数量：338] - [当前时间：16:35:31]
#
# [ok] - 1121177
# [尝试次数：1] - [剩余数量：337] - [当前时间：16:35:31]
#
# [ok] - 1081412
# [尝试次数：1] - [剩余数量：336] - [当前时间：16:35:31]
#
# [ok] - 1171080
# [尝试次数：1] - [剩余数量：335] - [当前时间：16:35:31]
#
# [ok] - 1209108
# [尝试次数：4] - [剩余数量：334] - [当前时间：16:35:31]
#
# [ok] - 1161787
# [尝试次数：1] - [剩余数量：333] - [当前时间：16:35:32]
#
# [ok] - 1162033
# [尝试次数：1] - [剩余数量：332] - [当前时间：16:35:32]
#
# [ok] - 1176509
# [尝试次数：1] - [剩余数量：331] - [当前时间：16:35:33]
#
# [ok] - 1176183
# [尝试次数：2] - [剩余数量：330] - [当前时间：16:35:33]
#
# [ok] - 1161720
# [尝试次数：1] - [剩余数量：329] - [当前时间：16:35:33]
#
# [ok] - 1178187
# [尝试次数：1] - [剩余数量：328] - [当前时间：16:35:34]
#
# [ok] - 1178225
# [尝试次数：1] - [剩余数量：327] - [当前时间：16:35:34]
#
# [ok] - 1178072
# [尝试次数：3] - [剩余数量：326] - [当前时间：16:35:34]
#
# [ok] - 1177887
# [尝试次数：4] - [剩余数量：325] - [当前时间：16:35:35]
#
# [ok] - 1152820
# [尝试次数：1] - [剩余数量：324] - [当前时间：16:35:36]
#
# [ok] - 1169778
# [尝试次数：3] - [剩余数量：323] - [当前时间：16:35:36]
#
# [ok] - 1169661
# [尝试次数：4] - [剩余数量：322] - [当前时间：16:35:36]
#
# [ok] - 1152821
# [尝试次数：1] - [剩余数量：321] - [当前时间：16:35:36]
#
# [ok] - 1152826
# [尝试次数：1] - [剩余数量：320] - [当前时间：16:35:37]
#
# [ok] - 1152842
# [尝试次数：1] - [剩余数量：319] - [当前时间：16:35:37]
#
# [ok] - 1152848
# [尝试次数：1] - [剩余数量：318] - [当前时间：16:35:37]
#
# [ok] - 1152837
# [尝试次数：1] - [剩余数量：317] - [当前时间：16:35:38]
#
# [ok] - 1188398
# [尝试次数：1] - [剩余数量：316] - [当前时间：16:35:38]
#
# [ok] - 1188406
# [尝试次数：1] - [剩余数量：315] - [当前时间：16:35:38]
#
# [ok] - 1176188
# [尝试次数：6] - [剩余数量：314] - [当前时间：16:35:39]
#
# [ok] - 1188539
# [尝试次数：2] - [剩余数量：313] - [当前时间：16:35:39]
#
# [ok] - 1188564
# [尝试次数：1] - [剩余数量：312] - [当前时间：16:35:39]
#
# [ok] - 1188228
# [尝试次数：1] - [剩余数量：311] - [当前时间：16:35:40]
#
# [ok] - 1188265
# [尝试次数：1] - [剩余数量：310] - [当前时间：16:35:40]
#
# [ok] - 1188266
# [尝试次数：1] - [剩余数量：309] - [当前时间：16:35:41]
#
# [ok] - 1140834
# [尝试次数：7] - [剩余数量：308] - [当前时间：16:35:41]
#
# [ok] - 1188612
# [尝试次数：2] - [剩余数量：307] - [当前时间：16:35:41]
#
# [ok] - 1188757
# [尝试次数：2] - [剩余数量：306] - [当前时间：16:35:42]
#
# [ok] - 1188760
# [尝试次数：1] - [剩余数量：305] - [当前时间：16:35:42]
#
# [ok] - 1209131
# [尝试次数：3] - [剩余数量：304] - [当前时间：16:35:43]
#
# [ok] - 1209140
# [尝试次数：1] - [剩余数量：303] - [当前时间：16:35:43]
#
# [ok] - 1209141
# [尝试次数：1] - [剩余数量：302] - [当前时间：16:35:43]
#
# [ok] - 1209142
# [尝试次数：1] - [剩余数量：301] - [当前时间：16:35:44]
#
# [ok] - 1209143
# [尝试次数：2] - [剩余数量：300] - [当前时间：16:35:44]
#
# [ok] - 1209154
# [尝试次数：1] - [剩余数量：299] - [当前时间：16:35:44]
#
# [ok] - 1081407
# [尝试次数：1] - [剩余数量：298] - [当前时间：16:35:45]
#
# [ok] - 1140877
# [尝试次数：2] - [剩余数量：297] - [当前时间：16:35:45]
#
# [ok] - 1209163
# [尝试次数：2] - [剩余数量：296] - [当前时间：16:35:46]
#
# [ok] - 1140902
# [尝试次数：1] - [剩余数量：295] - [当前时间：16:35:46]
#
# [ok] - 1140835
# [尝试次数：1] - [剩余数量：294] - [当前时间：16:35:47]
#
# [ok] - 1188530
# [尝试次数：2] - [剩余数量：293] - [当前时间：16:35:47]
#
# [ok] - 1188554
# [尝试次数：12] - [剩余数量：292] - [当前时间：16:35:47]
#
# [ok] - 1209025
# [尝试次数：16] - [剩余数量：291] - [当前时间：16:35:47]
#
# [ok] - 1188492
# [尝试次数：3] - [剩余数量：290] - [当前时间：16:35:48]
#
# [ok] - 1140847
# [尝试次数：5] - [剩余数量：289] - [当前时间：16:35:48]
#
# [ok] - 1166649
# [尝试次数：2] - [剩余数量：288] - [当前时间：16:35:49]
#
# [ok] - 1188300
# [尝试次数：2] - [剩余数量：287] - [当前时间：16:35:49]
#
# [ok] - 1206251
# [尝试次数：3] - [剩余数量：286] - [当前时间：16:35:49]
#
# [ok] - 1194369
# [尝试次数：2] - [剩余数量：285] - [当前时间：16:35:50]
#
# [ok] - 1129741
# [尝试次数：3] - [剩余数量：284] - [当前时间：16:35:50]
#
# [ok] - 1206244
# [尝试次数：8] - [剩余数量：283] - [当前时间：16:35:51]
#
# [ok] - 1116409
# [尝试次数：2] - [剩余数量：282] - [当前时间：16:35:51]
#
# [ok] - 1161368
# [尝试次数：4] - [剩余数量：281] - [当前时间：16:35:51]
#
# [ok] - 1176619
# [尝试次数：1] - [剩余数量：280] - [当前时间：16:35:51]
#
# [ok] - 1161741
# [尝试次数：3] - [剩余数量：279] - [当前时间：16:35:52]
#
# [ok] - 1178182
# [尝试次数：1] - [剩余数量：278] - [当前时间：16:35:52]
#
# [ok] - 1176182
# [尝试次数：2] - [剩余数量：277] - [当前时间：16:35:53]
#
# [ok] - 1178218
# [尝试次数：4] - [剩余数量：276] - [当前时间：16:35:54]
#
# [ok] - 1169611
# [尝试次数：2] - [剩余数量：275] - [当前时间：16:35:54]
#
# [ok] - 1169780
# [尝试次数：2] - [剩余数量：274] - [当前时间：16:35:56]
#
# [ok] - 1097913
# [尝试次数：5] - [剩余数量：273] - [当前时间：16:35:56]
#
# [ok] - 1169609
# [尝试次数：4] - [剩余数量：272] - [当前时间：16:35:56]
#
# [ok] - 1161718
# [尝试次数：4] - [剩余数量：271] - [当前时间：16:35:56]
#
# [ok] - 1172154
# [尝试次数：5] - [剩余数量：270] - [当前时间：16:35:56]
#
# [ok] - 1169756
# [尝试次数：1] - [剩余数量：269] - [当前时间：16:35:57]
#
# [ok] - 1152849
# [尝试次数：2] - [剩余数量：268] - [当前时间：16:35:58]
#
# [ok] - 1181462
# [尝试次数：5] - [剩余数量：267] - [当前时间：16:35:59]
#
# [ok] - 1188376
# [尝试次数：1] - [剩余数量：266] - [当前时间：16:35:59]
#
# [ok] - 1188371
# [尝试次数：4] - [剩余数量：265] - [当前时间：16:35:59]
#
# [ok] - 1188278
# [尝试次数：1] - [剩余数量：264] - [当前时间：16:36:00]
#
# [ok] - 1177720
# [尝试次数：3] - [剩余数量：263] - [当前时间：16:36:01]
#
# [ok] - 1188608
# [尝试次数：1] - [剩余数量：262] - [当前时间：16:36:01]
#
# [ok] - 1188188
# [尝试次数：2] - [剩余数量：261] - [当前时间：16:36:02]
#
# [ok] - 1188150
# [尝试次数：2] - [剩余数量：260] - [当前时间：16:36:02]
#
# [ok] - 1188755
# [尝试次数：2] - [剩余数量：259] - [当前时间：16:36:02]
#
# [ok] - 1216243
# [尝试次数：1] - [剩余数量：258] - [当前时间：16:36:03]
#
# [ok] - 1152819
# [尝试次数：3] - [剩余数量：257] - [当前时间：16:36:03]
#
# [ok] - 1188175
# [尝试次数：2] - [剩余数量：256] - [当前时间：16:36:03]
#
# [ok] - 1209048
# [尝试次数：1] - [剩余数量：255] - [当前时间：16:36:04]
#
# [ok] - 1209089
# [尝试次数：2] - [剩余数量：254] - [当前时间：16:36:04]
#
# [ok] - 1209085
# [尝试次数：1] - [剩余数量：253] - [当前时间：16:36:05]
#
# [ok] - 1169652
# [尝试次数：10] - [剩余数量：252] - [当前时间：16:36:05]
#
# [ok] - 1209124
# [尝试次数：2] - [剩余数量：251] - [当前时间：16:36:05]
#
# [ok] - 1211816
# [尝试次数：6] - [剩余数量：250] - [当前时间：16:36:05]
#
# [ok] - 1209125
# [尝试次数：1] - [剩余数量：249] - [当前时间：16:36:05]
#
# [ok] - 1209104
# [尝试次数：1] - [剩余数量：248] - [当前时间：16:36:06]
#
# [ok] - 1209151
# [尝试次数：2] - [剩余数量：247] - [当前时间：16:36:06]
#
# [ok] - 1209133
# [尝试次数：3] - [剩余数量：246] - [当前时间：16:36:06]
#
# [ok] - 1150458
# [尝试次数：1] - [剩余数量：245] - [当前时间：16:36:07]
#
# [ok] - 1018188
# [尝试次数：3] - [剩余数量：244] - [当前时间：16:36:07]
#
# [ok] - 1150701
# [尝试次数：3] - [剩余数量：243] - [当前时间：16:36:08]
#
# [ok] - 1180909
# [尝试次数：4] - [剩余数量：242] - [当前时间：16:36:08]
#
# [ok] - 1140892
# [尝试次数：2] - [剩余数量：241] - [当前时间：16:36:09]
#
# [ok] - 1140854
# [尝试次数：1] - [剩余数量：240] - [当前时间：16:36:09]
#
# [ok] - 1140882
# [尝试次数：5] - [剩余数量：239] - [当前时间：16:36:10]
#
# [ok] - 1140844
# [尝试次数：3] - [剩余数量：238] - [当前时间：16:36:10]
#
# [ok] - 1161929
# [尝试次数：2] - [剩余数量：237] - [当前时间：16:36:10]
#
# [ok] - 1161706
# [尝试次数：2] - [剩余数量：236] - [当前时间：16:36:11]
#
# [ok] - 1176536
# [尝试次数：1] - [剩余数量：235] - [当前时间：16:36:11]
#
# [ok] - 1176640
# [尝试次数：1] - [剩余数量：234] - [当前时间：16:36:12]
#
# [ok] - 1169695
# [尝试次数：3] - [剩余数量：233] - [当前时间：16:36:13]
#
# [ok] - 1140832
# [尝试次数：3] - [剩余数量：232] - [当前时间：16:36:13]
#
# [ok] - 1188332
# [尝试次数：3] - [剩余数量：231] - [当前时间：16:36:13]
#
# [ok] - 1188345
# [尝试次数：1] - [剩余数量：230] - [当前时间：16:36:14]
#
# [ok] - 1188020
# [尝试次数：2] - [剩余数量：229] - [当前时间：16:36:14]
#
# [ok] - 1188372
# [尝试次数：10] - [剩余数量：228] - [当前时间：16:36:14]
#
# [ok] - 1206345
# [尝试次数：1] - [剩余数量：227] - [当前时间：16:36:15]
#
# [ok] - 1209100
# [尝试次数：9] - [剩余数量：226] - [当前时间：16:36:15]
#
# [ok] - 1206378
# [尝试次数：1] - [剩余数量：225] - [当前时间：16:36:16]
#
# [ok] - 1143192
# [尝试次数：1] - [剩余数量：224] - [当前时间：16:36:16]
#
# [ok] - 1151342
# [尝试次数：1] - [剩余数量：223] - [当前时间：16:36:17]
#
# [ok] - 1143241
# [尝试次数：2] - [剩余数量：222] - [当前时间：16:36:17]
#
# [ok] - 1129377
# [尝试次数：1] - [剩余数量：221] - [当前时间：16:36:18]
#
# [ok] - 1114802
# [尝试次数：1] - [剩余数量：220] - [当前时间：16:36:18]
#
# [ok] - 1139624
# [尝试次数：2] - [剩余数量：219] - [当前时间：16:36:18]
#
# [ok] - 1161704
# [尝试次数：1] - [剩余数量：218] - [当前时间：16:36:18]
#
# [ok] - 1103368
# [尝试次数：1] - [剩余数量：217] - [当前时间：16:36:19]
#
# [ok] - 1206324
# [尝试次数：5] - [剩余数量：216] - [当前时间：16:36:19]
#
# [ok] - 1161785
# [尝试次数：2] - [剩余数量：215] - [当前时间：16:36:20]
#
# [ok] - 1176388
# [尝试次数：1] - [剩余数量：214] - [当前时间：16:36:20]
#
# [ok] - 1162034
# [尝试次数：4] - [剩余数量：213] - [当前时间：16:36:22]
#
# [ok] - 1185703
# [尝试次数：12] - [剩余数量：212] - [当前时间：16:36:22]
#
# [ok] - 1176573
# [尝试次数：2] - [剩余数量：211] - [当前时间：16:36:22]
#
# [ok] - 1178184
# [尝试次数：3] - [剩余数量：210] - [当前时间：16:36:23]
#
# [ok] - 1178030
# [尝试次数：1] - [剩余数量：209] - [当前时间：16:36:23]
#
# [ok] - 1161721
# [尝试次数：3] - [剩余数量：208] - [当前时间：16:36:24]
#
# [ok] - 1176179
# [尝试次数：1] - [剩余数量：207] - [当前时间：16:36:24]
#
# [ok] - 1177785
# [尝试次数：1] - [剩余数量：206] - [当前时间：16:36:24]
#
# [ok] - 1177851
# [尝试次数：1] - [剩余数量：205] - [当前时间：16:36:24]
#
# [ok] - 1169807
# [尝试次数：1] - [剩余数量：204] - [当前时间：16:36:25]
#
# [ok] - 1169704
# [尝试次数：1] - [剩余数量：203] - [当前时间：16:36:25]
#
# [ok] - 1152816
# [尝试次数：1] - [剩余数量：202] - [当前时间：16:36:26]
#
# [ok] - 1169651
# [尝试次数：4] - [剩余数量：201] - [当前时间：16:36:26]
#
# [ok] - 1169631
# [尝试次数：3] - [剩余数量：200] - [当前时间：16:36:27]
#
# [ok] - 1188392
# [尝试次数：1] - [剩余数量：199] - [当前时间：16:36:27]
#
# [ok] - 1176556
# [尝试次数：1] - [剩余数量：198] - [当前时间：16:36:27]
# [ok] - 1162028
# [尝试次数：8] - [剩余数量：197] - [当前时间：16:36:28]
#
# [ok] - 1188395
# [尝试次数：2] - [剩余数量：196] - [当前时间：16:36:28]
#
# [ok] - 1188543
# [尝试次数：3] - [剩余数量：195] - [当前时间：16:36:29]
#
# [ok] - 1178216
# [尝试次数：6] - [剩余数量：194] - [当前时间：16:36:29]
#
# [ok] - 1188562
# [尝试次数：2] - [剩余数量：193] - [当前时间：16:36:30]
#
# [ok] - 1188552
# [尝试次数：1] - [剩余数量：192] - [当前时间：16:36:30]
#
# [ok] - 1188294
# [尝试次数：1] - [剩余数量：191] - [当前时间：16:36:30]
#
# [ok] - 1188167
# [尝试次数：2] - [剩余数量：190] - [当前时间：16:36:31]
#
# [ok] - 1188179
# [尝试次数：2] - [剩余数量：189] - [当前时间：16:36:32]
#
# [ok] - 1188402
# [尝试次数：13] - [剩余数量：188] - [当前时间：16:36:32]
#
# [ok] - 1211620
# [尝试次数：3] - [剩余数量：187] - [当前时间：16:36:33]
#
# [ok] - 1209022
# [尝试次数：1] - [剩余数量：186] - [当前时间：16:36:34]
#
# [ok] - 1188174
# [尝试次数：3] - [剩余数量：185] - [当前时间：16:36:34]
#
# [ok] - 1209091
# [尝试次数：12] - [剩余数量：184] - [当前时间：16:36:35]
#
# [ok] - 1216177
# [尝试次数：7] - [剩余数量：183] - [当前时间：16:36:35]
#
# [ok] - 1209090
# [尝试次数：3] - [剩余数量：182] - [当前时间：16:36:35]
#
# [ok] - 1209120
# [尝试次数：1] - [剩余数量：181] - [当前时间：16:36:36]
#
# [ok] - 1188279
# [尝试次数：9] - [剩余数量：180] - [当前时间：16:36:37]
#
# [ok] - 1209138
# [尝试次数：1] - [剩余数量：179] - [当前时间：16:36:37]
#
# [ok] - 1209122
# [尝试次数：2] - [剩余数量：178] - [当前时间：16:36:37]
#
# [ok] - 1188541
# [尝试次数：7] - [剩余数量：177] - [当前时间：16:36:37]
#
# [ok] - 1152836
# [尝试次数：1] - [剩余数量：176] - [当前时间：16:36:37]
#
# [ok] - 1209132
# [尝试次数：3] - [剩余数量：175] - [当前时间：16:36:38]
#
# [ok] - 1209152
# [尝试次数：3] - [剩余数量：174] - [当前时间：16:36:38]
#
# [ok] - 1169766
# [尝试次数：8] - [剩余数量：173] - [当前时间：16:36:39]
#
# [ok] - 1209155
# [尝试次数：4] - [剩余数量：172] - [当前时间：16:36:39]
#
# [ok] - 1209117
# [尝试次数：2] - [剩余数量：171] - [当前时间：16:36:40]
#
# [ok] - 1185744
# [尝试次数：2] - [剩余数量：170] - [当前时间：16:36:40]
#
# [ok] - 1209109
# [尝试次数：6] - [剩余数量：169] - [当前时间：16:36:40]
#
# [ok] - 1209126
# [尝试次数：13] - [剩余数量：168] - [当前时间：16:36:41]
#
# [ok] - 1209088
# [尝试次数：9] - [剩余数量：167] - [当前时间：16:36:41]
#
# [ok] - 1081413
# [尝试次数：2] - [剩余数量：166] - [当前时间：16:36:41]
#
# [ok] - 1191162
# [尝试次数：2] - [剩余数量：165] - [当前时间：16:36:41]
#
# [ok] - 1209173
# [尝试次数：1] - [剩余数量：164] - [当前时间：16:36:42]
#
# [ok] - 1140879
# [尝试次数：2] - [剩余数量：163] - [当前时间：16:36:42]
#
# [ok] - 1209113
# [尝试次数：9] - [剩余数量：162] - [当前时间：16:36:42]
#
# [ok] - 1161922
# [尝试次数：1] - [剩余数量：161] - [当前时间：16:36:42]
#
# [ok] - 1140880
# [尝试次数：3] - [剩余数量：160] - [当前时间：16:36:43]
#
# [ok] - 1116534
# [尝试次数：6] - [剩余数量：159] - [当前时间：16:36:43]
#
# [ok] - 1161917
# [尝试次数：4] - [剩余数量：158] - [当前时间：16:36:43]
#
# [ok] - 1186599
# [尝试次数：1] - [剩余数量：157] - [当前时间：16:36:43]
#
# [ok] - 1171073
# [尝试次数：2] - [剩余数量：156] - [当前时间：16:36:45]
#
# [ok] - 1015924
# [尝试次数：1] - [剩余数量：155] - [当前时间：16:36:45]
#
# [ok] - 1176166
# [尝试次数：4] - [剩余数量：154] - [当前时间：16:36:46]
#
# [ok] - 1177871
# [尝试次数：6] - [剩余数量：153] - [当前时间：16:36:46]
#
# [ok] - 1169677
# [尝试次数：2] - [剩余数量：152] - [当前时间：16:36:46]
#
# [ok] - 1176343
# [尝试次数：1] - [剩余数量：151] - [当前时间：16:36:47]
#
# [ok] - 1169701
# [尝试次数：4] - [剩余数量：150] - [当前时间：16:36:47]
#
# [ok] - 1152829
# [尝试次数：19] - [剩余数量：149] - [当前时间：16:36:47]
#
# [ok] - 1188469
# [尝试次数：2] - [剩余数量：148] - [当前时间：16:36:48]
#
# [ok] - 1188472
# [尝试次数：1] - [剩余数量：147] - [当前时间：16:36:48]
#
# [ok] - 1188408
# [尝试次数：5] - [剩余数量：146] - [当前时间：16:36:48]
#
# [ok] - 1176541
# [尝试次数：6] - [剩余数量：145] - [当前时间：16:36:49]
#
# [ok] - 1188369
# [尝试次数：7] - [剩余数量：144] - [当前时间：16:36:49]
#
# [ok] - 1188470
# [尝试次数：4] - [剩余数量：143] - [当前时间：16:36:49]
#
# [ok] - 1188512
# [尝试次数：2] - [剩余数量：142] - [当前时间：16:36:49]
#
# [ok] - 1188495
# [尝试次数：4] - [剩余数量：141] - [当前时间：16:36:50]
#
# [ok] - 1188529
# [尝试次数：3] - [剩余数量：140] - [当前时间：16:36:50]
#
# [ok] - 1188114
# [尝试次数：2] - [剩余数量：139] - [当前时间：16:36:50]
#
# [ok] - 1188117
# [尝试次数：6] - [剩余数量：138] - [当前时间：16:36:52]
#
# [ok] - 1188522
# [尝试次数：8] - [剩余数量：137] - [当前时间：16:36:52]
#
# [ok] - 1206372
# [尝试次数：4] - [剩余数量：136] - [当前时间：16:36:52]
#
# [ok] - 1206374
# [尝试次数：1] - [剩余数量：135] - [当前时间：16:36:53]
#
# [ok] - 1206398
# [尝试次数：6] - [剩余数量：134] - [当前时间：16:36:53]
#
# [ok] - 1206299
# [尝试次数：2] - [剩余数量：133] - [当前时间：16:36:53]
#
# [ok] - 1161738
# [尝试次数：9] - [剩余数量：132] - [当前时间：16:36:54]
#
# [ok] - 1143527
# [尝试次数：2] - [剩余数量：131] - [当前时间：16:36:54]
#
# [ok] - 1182957
# [尝试次数：2] - [剩余数量：130] - [当前时间：16:36:54]
#
# [ok] - 1096918
# [尝试次数：4] - [剩余数量：129] - [当前时间：16:36:55]
#
# [ok] - 1206359
# [尝试次数：7] - [剩余数量：128] - [当前时间：16:36:56]
#
# [ok] - 1206330
# [尝试次数：2] - [剩余数量：127] - [当前时间：16:36:56]
#
# [ok] - 1161799
# [尝试次数：18] - [剩余数量：126] - [当前时间：16:36:56]
#
# [ok] - 1103367
# [尝试次数：4] - [剩余数量：125] - [当前时间：16:36:57]
#
# [ok] - 1162029
# [尝试次数：1] - [剩余数量：124] - [当前时间：16:36:57]
#
# [ok] - 1176149
# [尝试次数：21] - [剩余数量：123] - [当前时间：16:36:57]
#
# [ok] - 1162027
# [尝试次数：2] - [剩余数量：122] - [当前时间：16:36:57]
#
# [ok] - 1161715
# [尝试次数：2] - [剩余数量：121] - [当前时间：16:36:58]
#
# [ok] - 1176508
# [尝试次数：1] - [剩余数量：120] - [当前时间：16:36:58]
#
# [ok] - 1097664
# [尝试次数：10] - [剩余数量：119] - [当前时间：16:36:59]
#
# [ok] - 1206301
# [尝试次数：6] - [剩余数量：118] - [当前时间：16:36:59]
#
# [ok] - 1192309
# [尝试次数：12] - [剩余数量：117] - [当前时间：16:36:59]
#
# [ok] - 1176374
# [尝试次数：1] - [剩余数量：116] - [当前时间：16:37:00]
#
# [ok] - 1176371
# [尝试次数：3] - [剩余数量：115] - [当前时间：16:37:00]
#
# [ok] - 1176184
# [尝试次数：2] - [剩余数量：114] - [当前时间：16:37:02]
#
# [ok] - 1178032
# [尝试次数：1] - [剩余数量：113] - [当前时间：16:37:02]
#
# [ok] - 1176557
# [尝试次数：11] - [剩余数量：112] - [当前时间：16:37:03]
#
# [ok] - 1178038
# [尝试次数：7] - [剩余数量：111] - [当前时间：16:37:04]
#
# [ok] - 1176310
# [尝试次数：4] - [剩余数量：110] - [当前时间：16:37:04]
#
# [ok] - 1176649
# [尝试次数：6] - [剩余数量：109] - [当前时间：16:37:04]
#
# [ok] - 1177850
# [尝试次数：4] - [剩余数量：108] - [当前时间：16:37:04]
#
# [ok] - 1169683
# [尝试次数：1] - [剩余数量：107] - [当前时间：16:37:05]
#
# [ok] - 1169705
# [尝试次数：2] - [剩余数量：106] - [当前时间：16:37:05]
#
# [ok] - 1176370
# [尝试次数：8] - [剩余数量：105] - [当前时间：16:37:06]
#
# [ok] - 1161789
# [尝试次数：17] - [剩余数量：104] - [当前时间：16:37:06]
#
# [ok] - 1169628
# [尝试次数：4] - [剩余数量：103] - [当前时间：16:37:06]
#
# [ok] - 1152824
# [尝试次数：2] - [剩余数量：102] - [当前时间：16:37:07]
#
# [ok] - 1176650
# [尝试次数：16] - [剩余数量：101] - [当前时间：16:37:08]
#
# [ok] - 1177844
# [尝试次数：5] - [剩余数量：100] - [当前时间：16:37:08]
#
# [ok] - 1166627
# [尝试次数：16] - [剩余数量：99] - [当前时间：16:37:08]
#
# [ok] - 1195907
# [尝试次数：3] - [剩余数量：98] - [当前时间：16:37:08]
#
# [ok] - 1178865
# [尝试次数：4] - [剩余数量：97] - [当前时间：16:37:09]
#
# [ok] - 1188385
# [尝试次数：1] - [剩余数量：96] - [当前时间：16:37:10]
#
# [ok] - 1188394
# [尝试次数：3] - [剩余数量：95] - [当前时间：16:37:10]
#
# [ok] - 1169619
# [尝试次数：7] - [剩余数量：94] - [当前时间：16:37:11]
#
# [ok] - 1169662
# [尝试次数：6] - [剩余数量：93] - [当前时间：16:37:11]
#
# [ok] - 1152834
# [尝试次数：4] - [剩余数量：92] - [当前时间：16:37:11]
#
# [ok] - 1188412
# [尝试次数：5] - [剩余数量：91] - [当前时间：16:37:12]
#
# [ok] - 1188389
# [尝试次数：10] - [剩余数量：90] - [当前时间：16:37:12]
#
# [ok] - 1188556
# [尝试次数：2] - [剩余数量：89] - [当前时间：16:37:13]
#
# [ok] - 1188544
# [尝试次数：4] - [剩余数量：88] - [当前时间：16:37:13]
#
# [ok] - 1152823
# [尝试次数：6] - [剩余数量：87] - [当前时间：16:37:13]
#
# [ok] - 1188563
# [尝试次数：3] - [剩余数量：86] - [当前时间：16:37:13]
#
# [ok] - 1188537
# [尝试次数：8] - [剩余数量：85] - [当前时间：16:37:13]
#
# [ok] - 1169682
# [尝试次数：14] - [剩余数量：84] - [当前时间：16:37:13]
#
# [ok] - 1188158
# [尝试次数：1] - [剩余数量：83] - [当前时间：16:37:14]
#
# [ok] - 1188538
# [尝试次数：8] - [剩余数量：82] - [当前时间：16:37:14]
#
# [ok] - 1188611
# [尝试次数：4] - [剩余数量：81] - [当前时间：16:37:14]
#
# [ok] - 1188173
# [尝试次数：3] - [剩余数量：80] - [当前时间：16:37:15]
#
# [ok] - 1188160
# [尝试次数：3] - [剩余数量：79] - [当前时间：16:37:15]
#
# [ok] - 1209049
# [尝试次数：1] - [剩余数量：78] - [当前时间：16:37:15]
#
# [ok] - 1216170
# [尝试次数：5] - [剩余数量：77] - [当前时间：16:37:16]
#
# [ok] - 1188182
# [尝试次数：7] - [剩余数量：76] - [当前时间：16:37:16]
#
# [ok] - 1209024
# [尝试次数：6] - [剩余数量：75] - [当前时间：16:37:16]
#
# [ok] - 1188190
# [尝试次数：5] - [剩余数量：74] - [当前时间：16:37:17]
#
# [ok] - 1209092
# [尝试次数：3] - [剩余数量：73] - [当前时间：16:37:17]
#
# [ok] - 1209093
# [尝试次数：3] - [剩余数量：72] - [当前时间：16:37:17]
#
# [ok] - 1209157
# [尝试次数：1] - [剩余数量：71] - [当前时间：16:37:18]
#
# [ok] - 1209165
# [尝试次数：1] - [剩余数量：70] - [当前时间：16:37:18]
#
# [ok] - 1188399
# [尝试次数：12] - [剩余数量：69] - [当前时间：16:37:18]
#
# [ok] - 1209130
# [尝试次数：3] - [剩余数量：68] - [当前时间：16:37:18]
#
# [ok] - 1209105
# [尝试次数：2] - [剩余数量：67] - [当前时间：16:37:18]
#
# [ok] - 1196157
# [尝试次数：1] - [剩余数量：66] - [当前时间：16:37:19]
#
# [ok] - 1209115
# [尝试次数：2] - [剩余数量：65] - [当前时间：16:37:19]
#
# [ok] - 1209112
# [尝试次数：3] - [剩余数量：64] - [当前时间：16:37:19]
#
# [ok] - 1099582
# [尝试次数：2] - [剩余数量：63] - [当前时间：16:37:20]
#
# [ok] - 1185726
# [尝试次数：2] - [剩余数量：62] - [当前时间：16:37:20]
#
# [ok] - 1179853
# [尝试次数：5] - [剩余数量：61] - [当前时间：16:37:21]
#
# [ok] - 1209051
# [尝试次数：6] - [剩余数量：60] - [当前时间：16:37:21]
#
# [ok] - 1187973
# [尝试次数：1] - [剩余数量：59] - [当前时间：16:37:21]
#
# [ok] - 1150651
# [尝试次数：7] - [剩余数量：58] - [当前时间：16:37:21]
#
# [ok] - 1192165
# [尝试次数：2] - [剩余数量：57] - [当前时间：16:37:21]
#
# [ok] - 1194022
# [尝试次数：1] - [剩余数量：56] - [当前时间：16:37:22]
#
# [ok] - 1209030
# [尝试次数：11] - [剩余数量：55] - [当前时间：16:37:22]
#
# [ok] - 1220872
# [尝试次数：4] - [剩余数量：54] - [当前时间：16:37:23]
#
# [ok] - 1220956
# [尝试次数：1] - [剩余数量：53] - [当前时间：16:37:23]
#
# [ok] - 1015810
# [尝试次数：2] - [剩余数量：52] - [当前时间：16:37:23]
#
# [ok] - 1192236
# [尝试次数：1] - [剩余数量：51] - [当前时间：16:37:27]
#
# [ok] - 1177008
# [尝试次数：4] - [剩余数量：50] - [当前时间：16:37:27]
# [ok] - 1177976
# [尝试次数：4] - [剩余数量：49] - [当前时间：16:37:27]
#
# [ok] - 1192103
# [尝试次数：3] - [剩余数量：48] - [当前时间：16:37:27]
#
# [ok] - 1209159
# [尝试次数：5] - [剩余数量：47] - [当前时间：16:37:27]
#
# [ok] - 1121054
# [尝试次数：4] - [剩余数量：46] - [当前时间：16:37:28]
#
# [ok] - 1131675
# [尝试次数：6] - [剩余数量：45] - [当前时间：16:37:28]
#
# [ok] - 1140867
# [尝试次数：1] - [剩余数量：44] - [当前时间：16:37:28]
#
# [ok] - 1194184
# [尝试次数：2] - [剩余数量：43] - [当前时间：16:37:28]
#
# [ok] - 1140872
# [尝试次数：2] - [剩余数量：42] - [当前时间：16:37:28]
#
# [ok] - 1097914
# [尝试次数：6] - [剩余数量：41] - [当前时间：16:37:29]
#
# [ok] - 1140885
# [尝试次数：1] - [剩余数量：40] - [当前时间：16:37:29]
#
# [ok] - 1140899
# [尝试次数：1] - [剩余数量：39] - [当前时间：16:37:29]
#
# [ok] - 1140859
# [尝试次数：1] - [剩余数量：38] - [当前时间：16:37:30]
#
# [ok] - 1140836
# [尝试次数：2] - [剩余数量：37] - [当前时间：16:37:30]
#
# [ok] - 1140853
# [尝试次数：2] - [剩余数量：36] - [当前时间：16:37:30]
#
# [ok] - 1140873
# [尝试次数：7] - [剩余数量：35] - [当前时间：16:37:30]
#
# [ok] - 1161924
# [尝试次数：1] - [剩余数量：34] - [当前时间：16:37:31]
#
# [ok] - 1161931
# [尝试次数：4] - [剩余数量：33] - [当前时间：16:37:33]
#
# [ok] - 1194211
# [尝试次数：3] - [剩余数量：32] - [当前时间：16:37:33]
#
# [ok] - 1161903
# [尝试次数：4] - [剩余数量：31] - [当前时间：16:37:33]
#
# [ok] - 1161933
# [尝试次数：4] - [剩余数量：30] - [当前时间：16:37:33]
#
# [ok] - 1153407
# [尝试次数：3] - [剩余数量：29] - [当前时间：16:37:34]
#
# [ok] - 1140891
# [尝试次数：6] - [剩余数量：28] - [当前时间：16:37:34]
#
# [ok] - 1140848
# [尝试次数：1] - [剩余数量：27] - [当前时间：16:37:34]
#
# [ok] - 1161712
# [尝试次数：1] - [剩余数量：26] - [当前时间：16:37:34]
#
# [ok] - 1161768
# [尝试次数：1] - [剩余数量：25] - [当前时间：16:37:34]
#
# [ok] - 1161769
# [尝试次数：4] - [剩余数量：24] - [当前时间：16:37:35]
#
# [ok] - 1161797
# [尝试次数：3] - [剩余数量：23] - [当前时间：16:37:36]
#
# [ok] - 1176552
# [尝试次数：3] - [剩余数量：22] - [当前时间：16:37:36]
#
# [ok] - 1176535
# [尝试次数：4] - [剩余数量：21] - [当前时间：16:37:36]
#
# [ok] - 1161763
# [尝试次数：8] - [剩余数量：20] - [当前时间：16:37:36]
#
# [ok] - 1176553
# [尝试次数：5] - [剩余数量：19] - [当前时间：16:37:37]
#
# [ok] - 1176134
# [尝试次数：1] - [剩余数量：18] - [当前时间：16:37:37]
#
# [ok] - 1176632
# [尝试次数：2] - [剩余数量：17] - [当前时间：16:37:37]
#
# [ok] - 1177846
# [尝试次数：1] - [剩余数量：16] - [当前时间：16:37:38]
#
# [ok] - 1176364
# [尝试次数：3] - [剩余数量：15] - [当前时间：16:37:39]
#
# [ok] - 1176631
# [尝试次数：7] - [剩余数量：14] - [当前时间：16:37:39]
#
# [ok] - 1176154
# [尝试次数：2] - [剩余数量：13] - [当前时间：16:37:40]
#
# [ok] - 1161925
# [尝试次数：7] - [剩余数量：12] - [当前时间：16:37:40]
#
# [ok] - 1169607
# [尝试次数：3] - [剩余数量：11] - [当前时间：16:37:41]
#
# [ok] - 1176308
# [尝试次数：16] - [剩余数量：10] - [当前时间：16:37:41]
#
# [ok] - 1176165
# [尝试次数：9] - [剩余数量：9] - [当前时间：16:37:41]
#
# [ok] - 1176618
# [尝试次数：6] - [剩余数量：8] - [当前时间：16:37:42]
#
# [ok] - 1169669
# [尝试次数：2] - [剩余数量：7] - [当前时间：16:37:42]
#
# [ok] - 1169774
# [尝试次数：5] - [剩余数量：6] - [当前时间：16:37:43]
#
# [ok] - 1169680
# [尝试次数：1] - [剩余数量：5] - [当前时间：16:37:43]
#
# [ok] - 1169615
# [尝试次数：10] - [剩余数量：4] - [当前时间：16:37:43]
#
# [ok] - 1169697
# [尝试次数：1] - [剩余数量：3] - [当前时间：16:37:43]
#
# [ok] - 1188486
# [尝试次数：1] - [剩余数量：2] - [当前时间：16:37:44]
#
# [ok] - 1188409
# [尝试次数：2] - [剩余数量：1] - [当前时间：16:37:45]
#
# [ok] - 1188759
# [尝试次数：4] - [剩余数量：0] - [当前时间：16:37:45]
#
# [ok] - 1188516
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:37:46]
#
# [ok] - 1169752
# [尝试次数：11] - [剩余数量：0] - [当前时间：16:37:47]
#
# [ok] - 1169773
# [尝试次数：7] - [剩余数量：0] - [当前时间：16:37:47]
#
# [ok] - 1188498
# [尝试次数：8] - [剩余数量：0] - [当前时间：16:37:47]
#
# [ok] - 1171078
# [尝试次数：12] - [剩余数量：0] - [当前时间：16:37:48]
#
# [ok] - 1188506
# [尝试次数：6] - [剩余数量：0] - [当前时间：16:37:48]
#
# [ok] - 1161911
# [尝试次数：12] - [剩余数量：0] - [当前时间：16:37:48]
#
# [ok] - 1188507
# [尝试次数：10] - [剩余数量：0] - [当前时间：16:37:49]
#
# [ok] - 1188370
# [尝试次数：19] - [剩余数量：0] - [当前时间：16:37:50]
#
# 输出ing...
#
# Done ~
