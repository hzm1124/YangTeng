# %%
param_x_api_key = '2BeBXg69E53RaoUFhA7hhf17jCg1NkwHoJz3FxmJPNS3bedbpHcb'

# %%
import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# %%
input_ = pd.read_excel('./part.xlsx',
                       header=0,
                       dtype=str).fillna('')

dict_part = {}
list_job = []
for i in range(len(input_)):
    if input_.loc[i, 'Vehicle_Page'] != 0:
        vehicle_page = int(input_.loc[i, 'Vehicle_Page'])
        dict_part[input_.loc[i, 'JOIN_PNBI']] = {'vehicle_page': vehicle_page,
                                                 'crawler': 0,
                                                 'dict_vehicle': {},
                                                 'vehicle': ''}
        for j in range(vehicle_page):
            list_job.append((i, j))

print('总数量：' + str(len(list_job)))
list_job
# Out:
# 总数量：1733
# [(0, 0),
#  (1, 0),
#  (2, 0),
#  (4, 0),
#  (5, 0),
#  (6, 0),
#  (7, 0),
#  (8, 0),
#  (9, 0),
#  (10, 0),
#  (11, 0),
#  (13, 0),
#  (15, 0),
#  (16, 0),
#  (17, 0),
#  (18, 0),
#  (19, 0),
#  (20, 0),
#  (21, 0),
#  (22, 0),
#  (23, 0),
#  (24, 0),
#  (26, 0),
#  (27, 0),
#  (29, 0),
#  (30, 0),
#  (31, 0),
#  (32, 0),
#  (33, 0),
#  (34, 0),
#  (36, 0),
#  (37, 0),
#  (38, 0),
#  (39, 0),
#  (40, 0),
#  (41, 0),
#  (42, 0),
#  (43, 0),
#  (44, 0),
#  (45, 0),
#  (46, 0),
#  (48, 0),
#  (49, 0),
#  (52, 0),
#  (54, 0),
#  (55, 0),
#  (56, 0),
#  (56, 1),
#  (56, 2),
#  (56, 3),
#  (56, 4),
#  (57, 0),
#  (58, 0),
#  (59, 0),
#  (60, 0),
#  (61, 0),
#  (61, 1),
#  (62, 0),
#  (63, 0),
#  (64, 0),
#  (65, 0),
#  (65, 1),
#  (66, 0),
#  (67, 0),
#  (68, 0),
#  (70, 0),
#  (71, 0),
#  (72, 0),
#  (73, 0),
#  (76, 0),
#  (77, 0),
#  (78, 0),
#  (79, 0),
#  (80, 0),
#  (81, 0),
#  (82, 0),
#  (83, 0),
#  (84, 0),
#  (85, 0),
#  (86, 0),
#  (87, 0),
#  (88, 0),
#  (89, 0),
#  (90, 0),
#  (91, 0),
#  (92, 0),
#  (93, 0),
#  (94, 0),
#  (95, 0),
#  (96, 0),
#  (97, 0),
#  (98, 0),
#  (99, 0),
#  (100, 0),
#  (103, 0),
#  (104, 0),
#  (105, 0),
#  (105, 1),
#  (105, 2),
#  (106, 0),
#  (107, 0),
#  (107, 1),
#  (107, 2),
#  (107, 3),
#  (107, 4),
#  (108, 0),
#  (109, 0),
#  (110, 0),
#  (111, 0),
#  (112, 0),
#  (113, 0),
#  (114, 0),
#  (115, 0),
#  (116, 0),
#  (117, 0),
#  (119, 0),
#  (120, 0),
#  (121, 0),
#  (122, 0),
#  (123, 0),
#  (125, 0),
#  (126, 0),
#  (127, 0),
#  (128, 0),
#  (129, 0),
#  (130, 0),
#  (131, 0),
#  (132, 0),
#  (133, 0),
#  (134, 0),
#  (135, 0),
#  (136, 0),
#  (137, 0),
#  (138, 0),
#  (139, 0),
#  (140, 0),
#  (141, 0),
#  (142, 0),
#  (143, 0),
#  (144, 0),
#  (145, 0),
#  (147, 0),
#  (148, 0),
#  (149, 0),
#  (150, 0),
#  (151, 0),
#  (152, 0),
#  (153, 0),
#  (154, 0),
#  (155, 0),
#  (156, 0),
#  (157, 0),
#  (158, 0),
#  (159, 0),
#  (160, 0),
#  (161, 0),
#  (162, 0),
#  (163, 0),
#  (164, 0),
#  (165, 0),
#  (166, 0),
#  (167, 0),
#  (168, 0),
#  (169, 0),
#  (170, 0),
#  (171, 0),
#  (172, 0),
#  (173, 0),
#  (174, 0),
#  (175, 0),
#  (176, 0),
#  (176, 1),
#  (177, 0),
#  (178, 0),
#  (179, 0),
#  (180, 0),
#  (181, 0),
#  (182, 0),
#  (183, 0),
#  (184, 0),
#  (185, 0),
#  (186, 0),
#  (187, 0),
#  (189, 0),
#  (189, 1),
#  (189, 2),
#  (189, 3),
#  (189, 4),
#  (189, 5),
#  (189, 6),
#  (189, 7),
#  (189, 8),
#  (189, 9),
#  (189, 10),
#  (189, 11),
#  (189, 12),
#  (189, 13),
#  (190, 0),
#  (191, 0),
#  (192, 0),
#  (193, 0),
#  (194, 0),
#  (195, 0),
#  (196, 0),
#  (197, 0),
#  (198, 0),
#  (199, 0),
#  (200, 0),
#  (201, 0),
#  (202, 0),
#  (203, 0),
#  (204, 0),
#  (205, 0),
#  (206, 0),
#  (207, 0),
#  (208, 0),
#  (209, 0),
#  (210, 0),
#  (211, 0),
#  (212, 0),
#  (213, 0),
#  (214, 0),
#  (215, 0),
#  (216, 0),
#  (217, 0),
#  (218, 0),
#  (219, 0),
#  (220, 0),
#  (221, 0),
#  (222, 0),
#  (223, 0),
#  (224, 0),
#  (225, 0),
#  (226, 0),
#  (227, 0),
#  (228, 0),
#  (229, 0),
#  (230, 0),
#  (230, 1),
#  (230, 2),
#  (230, 3),
#  (230, 4),
#  (230, 5),
#  (231, 0),
#  (231, 1),
#  (231, 2),
#  (232, 0),
#  (232, 1),
#  (233, 0),
#  (234, 0),
#  (234, 1),
#  (235, 0),
#  (235, 1),
#  (236, 0),
#  (237, 0),
#  (237, 1),
#  (238, 0),
#  (239, 0),
#  (240, 0),
#  (241, 0),
#  (242, 0),
#  (243, 0),
#  (244, 0),
#  (245, 0),
#  (246, 0),
#  (247, 0),
#  (248, 0),
#  (249, 0),
#  (250, 0),
#  (251, 0),
#  (252, 0),
#  (253, 0),
#  (254, 0),
#  (255, 0),
#  (256, 0),
#  (257, 0),
#  (258, 0),
#  (259, 0),
#  (260, 0),
#  (261, 0),
#  (262, 0),
#  (263, 0),
#  (264, 0),
#  (265, 0),
#  (266, 0),
#  (267, 0),
#  (268, 0),
#  (269, 0),
#  (270, 0),
#  (270, 1),
#  (270, 2),
#  (271, 0),
#  (272, 0),
#  (273, 0),
#  (274, 0),
#  (274, 1),
#  (274, 2),
#  (274, 3),
#  (275, 0),
#  (276, 0),
#  (277, 0),
#  (278, 0),
#  (279, 0),
#  (280, 0),
#  (280, 1),
#  (281, 0),
#  (282, 0),
#  (283, 0),
#  (284, 0),
#  (285, 0),
#  (286, 0),
#  (287, 0),
#  (287, 1),
#  (288, 0),
#  (289, 0),
#  (289, 1),
#  (290, 0),
#  (290, 1),
#  (290, 2),
#  (291, 0),
#  (292, 0),
#  (293, 0),
#  (294, 0),
#  (294, 1),
#  (295, 0),
#  (296, 0),
#  (297, 0),
#  (298, 0),
#  (299, 0),
#  (300, 0),
#  (300, 1),
#  (300, 2),
#  (300, 3),
#  (300, 4),
#  (300, 5),
#  (300, 6),
#  (301, 0),
#  (302, 0),
#  (303, 0),
#  (303, 1),
#  (304, 0),
#  (305, 0),
#  (306, 0),
#  (307, 0),
#  (308, 0),
#  (309, 0),
#  (310, 0),
#  (311, 0),
#  (312, 0),
#  (313, 0),
#  (314, 0),
#  (315, 0),
#  (315, 1),
#  (315, 2),
#  (315, 3),
#  (315, 4),
#  (315, 5),
#  (315, 6),
#  (316, 0),
#  (316, 1),
#  (317, 0),
#  (317, 1),
#  (317, 2),
#  (318, 0),
#  (318, 1),
#  (318, 2),
#  (319, 0),
#  (320, 0),
#  (321, 0),
#  (322, 0),
#  (322, 1),
#  (323, 0),
#  (323, 1),
#  (324, 0),
#  (324, 1),
#  (325, 0),
#  (326, 0),
#  (327, 0),
#  (328, 0),
#  (329, 0),
#  (330, 0),
#  (331, 0),
#  (332, 0),
#  (333, 0),
#  (333, 1),
#  (334, 0),
#  (335, 0),
#  (336, 0),
#  (337, 0),
#  (338, 0),
#  (339, 0),
#  (340, 0),
#  (341, 0),
#  (342, 0),
#  (342, 1),
#  (342, 2),
#  (343, 0),
#  (343, 1),
#  (345, 0),
#  (346, 0),
#  (347, 0),
#  (348, 0),
#  (349, 0),
#  (350, 0),
#  (351, 0),
#  (352, 0),
#  (352, 1),
#  (352, 2),
#  (352, 3),
#  (353, 0),
#  (355, 0),
#  (356, 0),
#  (357, 0),
#  (359, 0),
#  (360, 0),
#  (361, 0),
#  (362, 0),
#  (363, 0),
#  (365, 0),
#  (366, 0),
#  (367, 0),
#  (368, 0),
#  (369, 0),
#  (370, 0),
#  (371, 0),
#  (372, 0),
#  (373, 0),
#  (374, 0),
#  (375, 0),
#  (376, 0),
#  (377, 0),
#  (378, 0),
#  (379, 0),
#  (380, 0),
#  (381, 0),
#  (382, 0),
#  (383, 0),
#  (384, 0),
#  (385, 0),
#  (386, 0),
#  (387, 0),
#  (388, 0),
#  (389, 0),
#  (390, 0),
#  (391, 0),
#  (392, 0),
#  (393, 0),
#  (394, 0),
#  (395, 0),
#  (396, 0),
#  (397, 0),
#  (398, 0),
#  (399, 0),
#  (400, 0),
#  (401, 0),
#  (402, 0),
#  (403, 0),
#  (404, 0),
#  (405, 0),
#  (406, 0),
#  (407, 0),
#  (408, 0),
#  (408, 1),
#  (408, 2),
#  (409, 0),
#  (409, 1),
#  (409, 2),
#  (410, 0),
#  (411, 0),
#  (412, 0),
#  (413, 0),
#  (413, 1),
#  (414, 0),
#  (415, 0),
#  (416, 0),
#  (417, 0),
#  (417, 1),
#  (417, 2),
#  (418, 0),
#  (419, 0),
#  (420, 0),
#  (421, 0),
#  (422, 0),
#  (422, 1),
#  (423, 0),
#  (424, 0),
#  (425, 0),
#  (426, 0),
#  (427, 0),
#  (428, 0),
#  (429, 0),
#  (430, 0),
#  (431, 0),
#  (432, 0),
#  (433, 0),
#  (434, 0),
#  (435, 0),
#  (436, 0),
#  (437, 0),
#  (438, 0),
#  (439, 0),
#  (440, 0),
#  (440, 1),
#  (440, 2),
#  (440, 3),
#  (440, 4),
#  (440, 5),
#  (440, 6),
#  (440, 7),
#  (440, 8),
#  (440, 9),
#  (440, 10),
#  (440, 11),
#  (440, 12),
#  (440, 13),
#  (440, 14),
#  (440, 15),
#  (440, 16),
#  (440, 17),
#  (441, 0),
#  (442, 0),
#  (443, 0),
#  (444, 0),
#  (444, 1),
#  (444, 2),
#  (444, 3),
#  (444, 4),
#  (445, 0),
#  (445, 1),
#  (446, 0),
#  (447, 0),
#  (447, 1),
#  (447, 2),
#  (448, 0),
#  (449, 0),
#  (449, 1),
#  (450, 0),
#  (451, 0),
#  (451, 1),
#  (451, 2),
#  (451, 3),
#  (452, 0),
#  (452, 1),
#  (452, 2),
#  (452, 3),
#  (452, 4),
#  (452, 5),
#  (452, 6),
#  (452, 7),
#  (453, 0),
#  (453, 1),
#  (453, 2),
#  (453, 3),
#  (453, 4),
#  (454, 0),
#  (455, 0),
#  (456, 0),
#  (457, 0),
#  (458, 0),
#  (459, 0),
#  (460, 0),
#  (460, 1),
#  (461, 0),
#  (461, 1),
#  (461, 2),
#  (461, 3),
#  (461, 4),
#  (461, 5),
#  (461, 6),
#  (461, 7),
#  (462, 0),
#  (462, 1),
#  (462, 2),
#  (462, 3),
#  (462, 4),
#  (462, 5),
#  (462, 6),
#  (462, 7),
#  (462, 8),
#  (462, 9),
#  (462, 10),
#  (462, 11),
#  (462, 12),
#  (462, 13),
#  (463, 0),
#  (463, 1),
#  (464, 0),
#  (464, 1),
#  (464, 2),
#  (464, 3),
#  (464, 4),
#  (464, 5),
#  (465, 0),
#  (466, 0),
#  (467, 0),
#  (467, 1),
#  (467, 2),
#  (467, 3),
#  (467, 4),
#  (467, 5),
#  (467, 6),
#  (467, 7),
#  (468, 0),
#  (469, 0),
#  (470, 0),
#  (471, 0),
#  (472, 0),
#  (473, 0),
#  (474, 0),
#  (475, 0),
#  (477, 0),
#  (478, 0),
#  (479, 0),
#  (480, 0),
#  (482, 0),
#  (483, 0),
#  (484, 0),
#  (487, 0),
#  (488, 0),
#  (489, 0),
#  (490, 0),
#  (492, 0),
#  (493, 0),
#  (494, 0),
#  (495, 0),
#  (496, 0),
#  (497, 0),
#  (498, 0),
#  (499, 0),
#  (500, 0),
#  (501, 0),
#  (502, 0),
#  (503, 0),
#  (504, 0),
#  (505, 0),
#  (508, 0),
#  (509, 0),
#  (510, 0),
#  (512, 0),
#  (512, 1),
#  (514, 0),
#  (514, 1),
#  (514, 2),
#  (515, 0),
#  (516, 0),
#  (517, 0),
#  (517, 1),
#  (517, 2),
#  (518, 0),
#  (519, 0),
#  (519, 1),
#  (520, 0),
#  (521, 0),
#  (522, 0),
#  (523, 0),
#  (524, 0),
#  (525, 0),
#  (526, 0),
#  (527, 0),
#  (528, 0),
#  (529, 0),
#  (530, 0),
#  (531, 0),
#  (532, 0),
#  (533, 0),
#  (534, 0),
#  (535, 0),
#  (536, 0),
#  (537, 0),
#  (538, 0),
#  (539, 0),
#  (540, 0),
#  (541, 0),
#  (542, 0),
#  (543, 0),
#  (544, 0),
#  (545, 0),
#  (546, 0),
#  (547, 0),
#  (547, 1),
#  (548, 0),
#  (549, 0),
#  (549, 1),
#  (550, 0),
#  (551, 0),
#  (552, 0),
#  (553, 0),
#  (554, 0),
#  (555, 0),
#  (555, 1),
#  (556, 0),
#  (557, 0),
#  (558, 0),
#  (559, 0),
#  (560, 0),
#  (561, 0),
#  (562, 0),
#  (563, 0),
#  (564, 0),
#  (564, 1),
#  (565, 0),
#  (565, 1),
#  (565, 2),
#  (566, 0),
#  (567, 0),
#  (568, 0),
#  (569, 0),
#  (569, 1),
#  (570, 0),
#  (571, 0),
#  (572, 0),
#  (573, 0),
#  (574, 0),
#  (575, 0),
#  (576, 0),
#  (577, 0),
#  (579, 0),
#  (580, 0),
#  (581, 0),
#  (581, 1),
#  (581, 2),
#  (582, 0),
#  (582, 1),
#  (584, 0),
#  (585, 0),
#  (586, 0),
#  (587, 0),
#  (588, 0),
#  (589, 0),
#  (589, 1),
#  (589, 2),
#  (589, 3),
#  (589, 4),
#  (590, 0),
#  (591, 0),
#  (592, 0),
#  (593, 0),
#  (594, 0),
#  (595, 0),
#  (596, 0),
#  (597, 0),
#  (598, 0),
#  (601, 0),
#  (603, 0),
#  (604, 0),
#  (605, 0),
#  (606, 0),
#  (607, 0),
#  (608, 0),
#  (609, 0),
#  (610, 0),
#  (611, 0),
#  (612, 0),
#  (613, 0),
#  (614, 0),
#  (615, 0),
#  (616, 0),
#  (617, 0),
#  (618, 0),
#  (619, 0),
#  (620, 0),
#  (621, 0),
#  (623, 0),
#  (624, 0),
#  (625, 0),
#  (626, 0),
#  (627, 0),
#  (628, 0),
#  (629, 0),
#  (630, 0),
#  (631, 0),
#  (632, 0),
#  (633, 0),
#  (634, 0),
#  (635, 0),
#  (636, 0),
#  (637, 0),
#  (637, 1),
#  (637, 2),
#  (638, 0),
#  (639, 0),
#  (640, 0),
#  (640, 1),
#  (640, 2),
#  (640, 3),
#  (640, 4),
#  (640, 5),
#  (641, 0),
#  (642, 0),
#  (643, 0),
#  (644, 0),
#  (645, 0),
#  (646, 0),
#  (647, 0),
#  (648, 0),
#  (648, 1),
#  (648, 2),
#  (648, 3),
#  (648, 4),
#  (649, 0),
#  (650, 0),
#  (651, 0),
#  (652, 0),
#  (653, 0),
#  (654, 0),
#  (654, 1),
#  (654, 2),
#  (654, 3),
#  (654, 4),
#  (654, 5),
#  (655, 0),
#  (656, 0),
#  (657, 0),
#  (658, 0),
#  (659, 0),
#  (660, 0),
#  (661, 0),
#  (662, 0),
#  (663, 0),
#  (664, 0),
#  (665, 0),
#  (666, 0),
#  (666, 1),
#  (667, 0),
#  (668, 0),
#  (669, 0),
#  (670, 0),
#  (671, 0),
#  (671, 1),
#  (671, 2),
#  (671, 3),
#  (672, 0),
#  (673, 0),
#  (673, 1),
#  (674, 0),
#  (675, 0),
#  (676, 0),
#  (676, 1),
#  (676, 2),
#  (676, 3),
#  (677, 0),
#  (678, 0),
#  (679, 0),
#  (680, 0),
#  (681, 0),
#  (682, 0),
#  (683, 0),
#  (684, 0),
#  (685, 0),
#  (686, 0),
#  (687, 0),
#  (688, 0),
#  (689, 0),
#  (690, 0),
#  (691, 0),
#  (692, 0),
#  (693, 0),
#  (694, 0),
#  (695, 0),
#  (696, 0),
#  (697, 0),
#  (698, 0),
#  (699, 0),
#  (700, 0),
#  (701, 0),
#  (702, 0),
#  (703, 0),
#  (703, 1),
#  (704, 0),
#  (705, 0),
#  (706, 0),
#  (707, 0),
#  (708, 0),
#  (708, 1),
#  (709, 0),
#  (709, 1),
#  (709, 2),
#  (709, 3),
#  (709, 4),
#  (709, 5),
#  (709, 6),
#  (709, 7),
#  (710, 0),
#  (711, 0),
#  (711, 1),
#  (712, 0),
#  (715, 0),
#  (717, 0),
#  (717, 1),
#  (718, 0),
#  (718, 1),
#  (718, 2),
#  (719, 0),
#  (720, 0),
#  (721, 0),
#  (722, 0),
#  (722, 1),
#  (723, 0),
#  (723, 1),
#  (723, 2),
#  (723, 3),
#  (724, 0),
#  (724, 1),
#  (725, 0),
#  (726, 0),
#  (727, 0),
#  (728, 0),
#  (728, 1),
#  (728, 2),
#  (728, 3),
#  (728, 4),
#  (728, 5),
#  (728, 6),
#  (728, 7),
#  (728, 8),
#  (728, 9),
#  (729, 0),
#  (730, 0),
#  (730, 1),
#  (731, 0),
#  (732, 0),
#  (732, 1),
#  (732, 2),
#  (732, 3),
#  (733, 0),
#  (734, 0),
#  (735, 0),
#  (736, 0),
#  (736, 1),
#  (736, 2),
#  (736, 3),
#  (736, 4),
#  (736, 5),
#  (737, 0),
#  (737, 1),
#  (738, 0),
#  (739, 0),
#  (740, 0),
#  (741, 0),
#  (742, 0),
#  (743, 0),
#  (744, 0),
#  (745, 0),
#  (746, 0),
#  (747, 0),
#  (748, 0),
#  (749, 0),
#  (750, 0),
#  (751, 0),
#  (752, 0),
#  (753, 0),
#  (754, 0),
#  (755, 0),
#  (756, 0),
#  (757, 0),
#  (757, 1),
#  (757, 2),
#  (758, 0),
#  (759, 0),
#  (760, 0),
#  (760, 1),
#  (760, 2),
#  (760, 3),
#  (761, 0),
#  (762, 0),
#  (763, 0),
#  (764, 0),
#  (764, 1),
#  (765, 0),
#  (766, 0),
#  (767, 0),
#  (768, 0),
#  (769, 0),
#  (770, 0),
#  (770, 1),
#  (770, 2),
#  (771, 0),
#  (772, 0),
#  (773, 0),
#  (774, 0),
#  (775, 0),
#  (776, 0),
#  (777, 0),
#  (778, 0),
#  (779, 0),
#  (779, 1),
#  (779, 2),
#  (779, 3),
#  (779, 4),
#  (779, 5),
#  (779, 6),
#  (780, 0),
#  (781, 0),
#  (782, 0),
#  (782, 1),
#  (783, 0),
#  (784, 0),
#  (785, 0),
#  (786, 0),
#  (787, 0),
#  ...]

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 1

i, j = list_job[a]

data = '''{"getAutoCarePartApplications":
{"brandCode":"''' + input_.loc[i, 'Brand_Id'] + '''",
 "partNumber":"''' + input_.loc[i, 'Part_Number'] + '''",
 "includeResults":true,
 "includeMatchingBaseVehicles":true,
 "perPage":100,
 "page":''' + str(j+1) + '''}}'''

headers = UA.get_User_Agent_Requests()
headers['X-Api-Key'] = param_x_api_key

resp = requests.post('https://webservice.opticatonline.com/autocare/v1/services/Catalog.jsonEndpoint',
                     data=data,
                     headers=headers,
                     proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '{"total":5,"results":[{"acesApp":{"partNumber":"MF0385","brandCode":"GGNF","brandName":"Blue Streak Electronics Original","mfrLabel":"Blue Streak Electronics Premium Quality - Reman","notes":[{"value":"Plug & Play application"},{"value":"No flash programming required"},{"value":"with OE No.0280 202 023, 0986 280 017, 5920385"}],"quals":[],"qty":"1","partTypeId":5128,"partTypeName":"Mass Air Flow Sensor","years":[],"baseVehicleId":238,"baseVehicleName":"1981 Fiat Brava","attributes":[{"attributeType":"EngineBaseId","attributeTypeName":"Engine Base","attributeValueId":1097,"attributeValueName":"L4 2.0L 1997cc"}],"digitalAssets":[]},"matchingBaseVehicles":[{"baseVehicleId":238,"year":1981,"makeId":7,"makeName":"Fiat","modelId":35,"modelName":"Brava","vehicleTypeId":5,"vehicleTypeName":"Car"}]},{"acesApp":{"partNumber":"MF0385","brandCode":"GGNF","brandName":"Blue Streak Electronics Original","mfrLabel":"Blue Streak Electronics Premium Quality - Reman","notes":[{"value":"Plug & Play application"},{"value":"No flash programming required"},{"value":"with OE No.0280 202 023, 0986 280 017, 5920385"}],"quals":[],"qty":"1","partTypeId":5128,"partTypeName":"Mass Air Flow Sensor","years":[],"baseVehicleId":237,"baseVehicleName":"1980 Fiat Brava","attributes":[{"attributeType":"EngineBaseId","attributeTypeName":"Engine Base","attributeValueId":1097,"attributeValueName":"L4 2.0L 1997cc"}],"digitalAssets":[]},"matchingBaseVehicles":[{"baseVehicleId":237,"year":1980,"makeId":7,"makeName":"Fiat","modelId":35,"modelName":"Brava","vehicleTypeId":5,"vehicleTypeName":"Car"}]},{"acesApp":{"partNumber":"MF0385","brandCode":"GGNF","brandName":"Blue Streak Electronics Original","mfrLabel":"Blue Streak Electronics Premium Quality - Reman","notes":[{"value":"Plug & Play application"},{"value":"No flash programming required"},{"value":"with OE No.0280 202 023, 0986 280 017, 5920385"}],"quals":[],"qty":"1","partTypeId":5128,"partTypeName":"Mass Air Flow Sensor","years":[],"baseVehicleId":225,"baseVehicleName":"1981 Fiat 124","attributes":[{"attributeType":"SubModelId","attributeTypeName":"Sub Model","attributeValueId":123,"attributeValueName":"Spider"},{"attributeType":"EngineBaseId","attributeTypeName":"Engine Base","attributeValueId":1097,"attributeValueName":"L4 2.0L 1997cc"}],"digitalAssets":[]},"matchingBaseVehicles":[{"baseVehicleId":225,"year":1981,"makeId":7,"makeName":"Fiat","modelId":32,"modelName":"124","vehicleTypeId":5,"vehicleTypeName":"Car"}]},{"acesApp":{"partNumber":"MF0385","brandCode":"GGNF","brandName":"Blue Streak Electronics Original","mfrLabel":"Blue Streak Electronics Premium Quality - Reman","notes":[{"value":"Plug & Play application"},{"value":"No flash programming required"},{"value":"with OE No.0280 202 023, 0986 280 017, 5920385"}],"quals":[],"qty":"1","partTypeId":5128,"partTypeName":"Mass Air Flow Sensor","years":[],"baseVehicleId":223,"baseVehicleName":"1979 Fiat 124","attributes":[{"attributeType":"SubModelId","attributeTypeName":"Sub Model","attributeValueId":123,"attributeValueName":"Spider"},{"attributeType":"EngineBaseId","attributeTypeName":"Engine Base","attributeValueId":1097,"attributeValueName":"L4 2.0L 1997cc"}],"digitalAssets":[]},"matchingBaseVehicles":[{"baseVehicleId":223,"year":1979,"makeId":7,"makeName":"Fiat","modelId":32,"modelName":"124","vehicleTypeId":5,"vehicleTypeName":"Car"}]},{"acesApp":{"partNumber":"MF0385","brandCode":"GGNF","brandName":"Blue Streak Electronics Original","mfrLabel":"Blue Streak Electronics Premium Quality - Reman","notes":[{"value":"Plug & Play application"},{"value":"No flash programming required"},{"value":"with OE No.0280 202 023, 0986 280 017, 5920385"}],"quals":[],"qty":"1","partTypeId":5128,"partTypeName":"Mass Air Flow Sensor","years":[],"baseVehicleId":224,"baseVehicleName":"1980 Fiat 124","attributes":[{"attributeType":"SubModelId","attributeTypeName":"Sub Model","attributeValueId":123,"attributeValueName":"Spider"},{"attributeType":"EngineBaseId","attributeTypeName":" ...

# %%
import json

# %%
json_data = json.loads(resp)

json_data
# Out:
# {'total': 5,
#  'results': [{'acesApp': {'partNumber': 'MF0385',
#     'brandCode': 'GGNF',
#     'brandName': 'Blue Streak Electronics Original',
#     'mfrLabel': 'Blue Streak Electronics Premium Quality - Reman',
#     'notes': [{'value': 'Plug & Play application'},
#      {'value': 'No flash programming required'},
#      {'value': 'with OE No.0280 202 023, 0986 280 017, 5920385'}],
#     'quals': [],
#     'qty': '1',
#     'partTypeId': 5128,
#     'partTypeName': 'Mass Air Flow Sensor',
#     'years': [],
#     'baseVehicleId': 238,
#     'baseVehicleName': '1981 Fiat Brava',
#     'attributes': [{'attributeType': 'EngineBaseId',
#       'attributeTypeName': 'Engine Base',
#       'attributeValueId': 1097,
#       'attributeValueName': 'L4 2.0L 1997cc'}],
#     'digitalAssets': []},
#    'matchingBaseVehicles': [{'baseVehicleId': 238,
#      'year': 1981,
#      'makeId': 7,
#      'makeName': 'Fiat',
#      'modelId': 35,
#      'modelName': 'Brava',
#      'vehicleTypeId': 5,
#      'vehicleTypeName': 'Car'}]},
#   {'acesApp': {'partNumber': 'MF0385',
#     'brandCode': 'GGNF',
#     'brandName': 'Blue Streak Electronics Original',
#     'mfrLabel': 'Blue Streak Electronics Premium Quality - Reman',
#     'notes': [{'value': 'Plug & Play application'},
#      {'value': 'No flash programming required'},
#      {'value': 'with OE No.0280 202 023, 0986 280 017, 5920385'}],
#     'quals': [],
#     'qty': '1',
#     'partTypeId': 5128,
#     'partTypeName': 'Mass Air Flow Sensor',
#     'years': [],
#     'baseVehicleId': 237,
#     'baseVehicleName': '1980 Fiat Brava',
#     'attributes': [{'attributeType': 'EngineBaseId',
#       'attributeTypeName': 'Engine Base',
#       'attributeValueId': 1097,
#       'attributeValueName': 'L4 2.0L 1997cc'}],
#     'digitalAssets': []},
#    'matchingBaseVehicles': [{'baseVehicleId': 237,
#      'year': 1980,
#      'makeId': 7,
#      'makeName': 'Fiat',
#      'modelId': 35,
#      'modelName': 'Brava',
#      'vehicleTypeId': 5,
#      'vehicleTypeName': 'Car'}]},
#   {'acesApp': {'partNumber': 'MF0385',
#     'brandCode': 'GGNF',
#     'brandName': 'Blue Streak Electronics Original',
#     'mfrLabel': 'Blue Streak Electronics Premium Quality - Reman',
#     'notes': [{'value': 'Plug & Play application'},
#      {'value': 'No flash programming required'},
#      {'value': 'with OE No.0280 202 023, 0986 280 017, 5920385'}],
#     'quals': [],
#     'qty': '1',
#     'partTypeId': 5128,
#     'partTypeName': 'Mass Air Flow Sensor',
#     'years': [],
#     'baseVehicleId': 225,
#     'baseVehicleName': '1981 Fiat 124',
#     'attributes': [{'attributeType': 'SubModelId',
#       'attributeTypeName': 'Sub Model',
#       'attributeValueId': 123,
#       'attributeValueName': 'Spider'},
#      {'attributeType': 'EngineBaseId',
#       'attributeTypeName': 'Engine Base',
#       'attributeValueId': 1097,
#       'attributeValueName': 'L4 2.0L 1997cc'}],
#     'digitalAssets': []},
#    'matchingBaseVehicles': [{'baseVehicleId': 225,
#      'year': 1981,
#      'makeId': 7,
#      'makeName': 'Fiat',
#      'modelId': 32,
#      'modelName': '124',
#      'vehicleTypeId': 5,
#      'vehicleTypeName': 'Car'}]},
#   {'acesApp': {'partNumber': 'MF0385',
#     'brandCode': 'GGNF',
#     'brandName': 'Blue Streak Electronics Original',
#     'mfrLabel': 'Blue Streak Electronics Premium Quality - Reman',
#     'notes': [{'value': 'Plug & Play application'},
#      {'value': 'No flash programming required'},
#      {'value': 'with OE No.0280 202 023, 0986 280 017, 5920385'}],
#     'quals': [],
#     'qty': '1',
#     'partTypeId': 5128,
#     'partTypeName': 'Mass Air Flow Sensor',
#     'years': [],
#     'baseVehicleId': 223,
#     'baseVehicleName': '1979 Fiat 124',
#     'attributes': [{'attributeType': 'SubModelId',
#       'attributeTypeName': 'Sub Model',
#       'attributeValueId': 123,
#       'attributeValueName': 'Spider'},
#      {'attributeType': 'EngineBaseId',
#       'attributeTypeName': 'Engine Base',
#       'attributeValueId': 1097,
#       'attributeValueName': 'L4 2.0L 1997cc'}],
#     'digitalAssets': []},
#    'matchingBaseVehicles': [{'baseVehicleId': 223,
#      'year': 1979,
#      'makeId': 7,
#      'makeName': 'Fiat',
#      'modelId': 32,
#      'modelName': '124',
#      'vehicleTypeId': 5,
#      'vehicleTypeName': 'Car'}]},
#   {'acesApp': {'partNumber': 'MF0385',
#     'brandCode': 'GGNF',
#     'brandName': 'Blue Streak Electronics Original',
#     'mfrLabel': 'Blue Streak Electronics Premium Quality - Reman',
#     'notes': [{'value': 'Plug & Play application'},
#      {'value': 'No flash programming required'},
#      {'value': 'with OE No.0280 202 023, 0986 280 017, 5920385'}],
#     'quals': [],
#     'qty': '1',
#     'partTypeId': 5128,
#     'partTypeName': 'Mass Air Flow Sensor',
#     'years': [],
#     'baseVehicleId': 224,
#     'baseVehicleName': '1980 Fiat 124',
#     'attributes': [{'attributeType': 'SubModelId',
#       'attributeTypeName': 'Sub Model',
#       'attributeValueId': 123,
#       'attributeValueName': 'Spider'},
#      {'attributeType': 'EngineBaseId',
#       'attributeTypeName': 'Engine Base',
#       'attributeValueId': 1097,
#       'attributeValueName': 'L4 2.0L 1997cc'}],
#     'digitalAssets': []},
#    'matchingBaseVehicles': [{'baseVehicleId': 224,
#      'year': 1980,
#      'makeId': 7,
#      'makeName': 'Fiat',
#      'modelId': 32,
#      'modelName': '124',
#      'vehicleTypeId': 5,
#      'vehicleTypeName': 'Car'}]}],
#  'status': 200}

# %%
for result in json_data['results']:
    make = result['matchingBaseVehicles'][0]['makeName'].strip()
    model = result['matchingBaseVehicles'][0]['modelName'].strip()
    year = result['matchingBaseVehicles'][0]['year']
    
    if make not in dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle']:
        dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make] = {model: [year]}
    else:
        if model not in dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make]:
            dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model] = [year]
        else:
            dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model].append(year)
            
    dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model] = sorted(list(set(dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model])))
    
dict_part[input_.loc[i, 'JOIN_PNBI']]['crawler'] += 1

dict_part[input_.loc[i, 'JOIN_PNBI']]
# Out:
# {'vehicle_page': 1,
#  'crawler': 1,
#  'dict_vehicle': {'Fiat': {'Brava': [1980, 1981], '124': [1979, 1980, 1981]}},
#  'vehicle': ''}

# %%
dict_part[input_.loc[i, 'JOIN_PNBI']]['vehicle_page'] == dict_part[input_.loc[i, 'JOIN_PNBI']]['crawler']
# Out:
# True

# %%
list_vehicle = []
for make in dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle']:
    for model in dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make]:
        year_min = min(dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model])
        year_max = max(dict_part[input_.loc[i, 'JOIN_PNBI']]['dict_vehicle'][make][model])
        
        if year_min == year_max:
            list_vehicle.append(make + ' ' + model + ' ' + str(year_min))
        else:
            list_vehicle.append(make + ' ' + model + ' ' + str(year_min) + '-' + str(year_max))

list_vehicle.sort()

dict_part[input_.loc[i, 'JOIN_PNBI']]['vehicle'] = '\n'.join(list_vehicle)

print(dict_part[input_.loc[i, 'JOIN_PNBI']]['vehicle'])
# Out:
# Fiat 124 1979-1981
# Fiat Brava 1980-1981

# %%
df_temp = pd.DataFrame([{'JOIN_PNBI': input_.loc[i, 'JOIN_PNBI'],
                         'Vehicle': dict_part[input_.loc[i, 'JOIN_PNBI']]['vehicle']}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Part_Number': input_.loc[i, 'Part_Number'],
                             'Brand_Id': input_.loc[i, 'Brand_Id'],
                             'JOIN_PNBI': input_.loc[i, 'JOIN_PNBI']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['JOIN_PNBI'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_vehicle.xlsx', index=False)

output_correct
# Out:
#      JOIN_PNBI                                   Vehicle
# 0  MF0385;GGNF  Fiat 124 1979-1981\nFiat Brava 1980-1981

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['Part_Number', 'Brand_Id'], ascending=[True, True]).reset_index(drop=True)
    output_error.to_excel('./test_vehicle_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
