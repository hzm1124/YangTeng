# %%
import os

# %%
list_file = list(os.walk('./union'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 6

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    df = pd.concat([df, pd.read_excel('./union/' + file)], ignore_index=False)
    
df.to_excel('./crawler.xlsx', index=False)

df
# Out:
# 进度: 100%|████████████████████████████████████| 6/6 [00:09<00:00,  1.56s/it]
#       Item_Number                                              Title  \
# 0    372321518748  Corner Light For 90-93 Volvo 240 86-89 244 Pas...
# 1    351615196189  Set of 2 Tail Light For 98-99 Ford Ranger EV L...
# 2    352366953958  Turn Signal Light Set For 2005-2009 Ford Musta...
# 3    372634369670  Corner Light For 90-93 Volvo 240 86-89 244 Dri...
# 4    351655934056  Tail Light for 2008-2012 Dodge Caliber Driver ...
# ..            ...                                                ...
# 245  372544020257  Bumper Grille For 2002-2008 Dodge Ram 1500 200...
# 246  372497372530  Headlight Set For 2013-2015 Toyota Avalon Left...
# 247  374483270735  Fog Light Covers Front Driver Left Side Hand 8...
# 248  373977017306  Headlight Set For 2011-2014 Hyundai Sonata Lef...
# 249  234041105308  Fog Lights For 2014-2016 Acura MDX Front Drive...
#
#           Price  Sold                                            Vehicle  Pic  \
# 0     USD 51.32    16  Volvo 240 1990-1993\nVolvo 244 1986-1989\nVolv...  NaN
# 1     USD 51.26   886                              Ford Ranger 1998-1999  NaN
# 2     USD 51.26    24                             Ford Mustang 2005-2009  NaN
# 3     USD 51.32    19  Volvo 240 1990-1993\nVolvo 244 1986-1989\nVolv...  NaN
# 4      USD 51.3   251                            Dodge Caliber 2008-2012  NaN
# ..          ...   ...                                                ...  ...
# 245   USD 16.22   308  Dodge Ram 1500 2002-2009\nDodge Ram 2500 2003-...  NaN
# 246  USD 419.51    16                            Toyota Avalon 2013-2015  NaN
# 247  USD 216.19     9                   Hyundai Santa Fe Sport 2018-2018  NaN
# 248  USD 315.89     0                           Hyundai Sonata 2011-2014  NaN
# 249  USD 363.99     0                                Acura MDX 2014-2016  NaN
#
#                                                    Url  \
# 0    https://www.ebay.com/itm/372321518748?hash=ite...
# 1    https://www.ebay.com/itm/351615196189?hash=ite...
# 2    https://www.ebay.com/itm/352366953958?epid=127...
# 3    https://www.ebay.com/itm/372634369670?epid=301...
# 4    https://www.ebay.com/itm/351655934056?hash=ite...
# ..                                                 ...
# 245  https://www.ebay.com/itm/372544020257?hash=ite...
# 246  https://www.ebay.com/itm/372497372530?hash=ite...
# 247  https://www.ebay.com/itm/374483270735?hash=ite...
# 248  https://www.ebay.com/itm/373977017306?epid=157...
# 249  https://www.ebay.com/itm/234041105308?hash=ite...
#
#                                                    Src        brand  \
# 0    https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/G9kA...  Perfect Fit
# 1    https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/3DIA...  Perfect Fit
# 2    https://i.ebayimg.com/00/s/NDAwWDQwMA==/z/IEYA...  Perfect Fit
# 3    https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/1qMA...  Perfect Fit
# 4    https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/NKUA...  Perfect Fit
# ..                                                 ...          ...
# 245  https://i.ebayimg.com/00/s/NDA5WDQwOQ==/z/XkgA...  Perfect Fit
# 246  https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/KfYA...  Perfect Fit
# 247  https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/GvkA...  Perfect Fit
# 248  https://i.ebayimg.com/00/s/MjkxWDI5MQ==/z/C88A...  Perfect Fit
# 249  https://i.ebayimg.com/00/s/MTQwMFgxNDAw/z/l6YA...  Perfect Fit
#
#                             california prop 65 warning  ...  \
# 0    <p><b><img src="https://cld.partsimg.com/image...  ...
# 1    <p><b>WARNING: This product can expose you to ...  ...
# 2    <p><b>WARNING: This product can expose you to ...  ...
# 3    <p><b><img src="https://cld.partsimg.com/image...  ...
# 4    <p><b>WARNING: This product can expose you to ...  ...
# ..                                                 ...  ...
# 245  <p><b>WARNING: This product can expose you to ...  ...
# 246  <p><b>WARNING: This product can expose you to ...  ...
# 247  <p><b>WARNING: This product can expose you to ...  ...
# 248  <p><b>WARNING: This product can expose you to ...  ...
# 249  <p><b>WARNING: This product can expose you to ...  ...
#
#     pressure sensor included light color glass adjustment  \
# 0                        NaN         NaN              NaN
# 1                        NaN         NaN              NaN
# 2                        NaN         NaN              NaN
# 3                        NaN         NaN              NaN
# 4                        NaN         NaN              NaN
# ..                       ...         ...              ...
# 245                      NaN         NaN              NaN
# 246                      NaN         NaN              NaN
# 247                      NaN         NaN              NaN
# 248                      NaN         NaN              NaN
# 249                      NaN         NaN              NaN
#
#     mirror adjustment method |interchange part number parts link number  \
# 0                        NaN                      NaN               NaN
# 1                        NaN                      NaN               NaN
# 2                        NaN                      NaN               NaN
# 3                        NaN                      NaN               NaN
# 4                        NaN                      NaN               NaN
# ..                       ...                      ...               ...
# 245                      NaN                      NaN               NaN
# 246                      NaN                      NaN               NaN
# 247                      NaN                      NaN               NaN
# 248                      NaN                      NaN               NaN
# 249                      NaN                      NaN               NaN
#
#     assembly type  fit product fit quantity sold
# 0             NaN  NaN         NaN           NaN
# 1             NaN  NaN         NaN           NaN
# 2             NaN  NaN         NaN           NaN
# 3             NaN  NaN         NaN           NaN
# 4             NaN  NaN         NaN           NaN
# ..            ...  ...         ...           ...
# 245           NaN  NaN         NaN           NaN
# 246           NaN  NaN         NaN           NaN
# 247           NaN  NaN         NaN           NaN
# 248           NaN  NaN         NaN           NaN
# 249           NaN  NaN         NaN           NaN
#
# [22799 rows x 78 columns]
