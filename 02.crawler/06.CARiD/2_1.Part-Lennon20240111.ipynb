# %%
import pandas as pd

# %%
df = pd.read_excel('./menu.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_url = df['Url'].tolist()

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：204
# ['https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92145.html',
#  'https://www.carid.com/ngk/iridium-ix-spark-plug.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90813.html',
#  'https://www.carid.com/ngk/g-power-platinum-spark-plug-with-copper-core-mpn-3403.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96698.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96698.html?singleid=5087889357',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6700.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6701.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91112.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1555.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95248.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93026.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90911.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90911.html?singleid=5087850343',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97218.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92605.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94731.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91874.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96372.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95003.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97319.html',
#  'https://www.carid.com/ngk/laser-platinum-spark-plug.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94697.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1406.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90074.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-9029.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91215.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91448.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92491.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92924.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93135.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93482.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94167.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95710.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-98376.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6176.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96957.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-127.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-373.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7505.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97506.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90137.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95350.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95264.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1312.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1311.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96964.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90935.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94702.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94201.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92217.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93199.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90565.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97293.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91961.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6858.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90174.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91715.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95993.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97968.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96008.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91731.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91731.html?singleid=5087660506',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93560.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93560.html?singleid=5087720497',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96427.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96206.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96210.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96206.html?singleid=5087797357',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96210.html?singleid=5087870347',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92725.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93759.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91578.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93163.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90654.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97976.html',
#  'https://www.carid.com/ngk/spark-plug-mpn-96107.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91121.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90909.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90909.html?singleid=5087708502',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5245.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93053.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5468.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92373.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92154.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92154.html?singleid=5087784345',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90219.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1422.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7746.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1208.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4458.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5794.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3787.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5887.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6043.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95875.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91568.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3106.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5344.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7418.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3508.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3588.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6507.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7866.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7658.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1402.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7913.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95705.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95369.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93476.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91006.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93618.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97080.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92422.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5787.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7751.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94124.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94940.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96509.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95112.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95660.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93815.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-9723.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91467.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93655.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92315.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1961.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6481.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6741.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7563.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7994.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4294.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3107.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4477.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7854.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4867.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90083.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94290.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97287.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92968.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94524.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94524.html?singleid=5087752490',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4696.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5648.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96024.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97932.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94051.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90656.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91924.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91794.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6215.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1989.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3657.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6994.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-2687.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6774.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5266.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1313.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93593.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93227.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91039.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96870.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4912.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96779.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96588.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97177.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94769.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95609.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91725.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91970.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90483.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90607.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95822.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1637.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92085.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90882.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90644.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5476.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95853.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5258.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96393.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087827358',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087894355',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087752498',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087757502',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087812355',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95927.html?singleid=5087685496',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1465.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4213.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5599.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90117.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-5581.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4904.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96329.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90156.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94489.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90543.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3474.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-3656.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4589.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-4996.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93298.html']

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests

# %%
i = 0

url = list_url[i]

resp = requests.get(url).text

resp
# Out:
# '<!DOCTYPE html><html class="no-js desktop" lang="en"><head><meta charset="utf-8"><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:[]},distributed_tracing:{enabled:true,allowed_origins:["https://carid.com","https://www.carid.com","https://mygarage-api.carid.com"],cors_use_newrelic_header:true,cors_use_tracecontext_headers:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"594445424",accountID:"4146318",trustKey:"4146318",xpid:"UAcDV1VSABAFUFVaAgIHU1A=",licenseKey:"NRJS-5db917892f9cc9a5cff",applicationID:"544853054"};;/*! For license information please see nr-loader-spa-1.249.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>m,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>N,lF:()=>j,Yu:()=>E,Dg:()=>v,CX:()=>c,GE:()=>x,sU:()=>R});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",h=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. \'*\' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},g="All configuration objects require an agent identifier!";function m(e){if(!e)throw new Error(g);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function v(e,t){if(!e)throw new Error(g);p[e]=(0,i.D)(t,h());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e, ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

with open('./part.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js desktop" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:[]},distributed_tracing:{enabled:true,allowed_origins:["https://carid.com","https://www.carid.com","https://mygarage-api.carid.com"],cors_use_newrelic_header:true,cors_use_tracecontext_headers:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"594445424",accountID:"4146318",trustKey:"4146318",xpid:"UAcDV1VSABAFUFVaAgIHU1A=",licenseKey:"NRJS-5db917892f9cc9a5cff",applicationID:"544853054"};;/*! For license information please see nr-loader-spa-1.249.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>m,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>N,lF:()=>j,Yu:()=>E,Dg:()=>v,CX:()=>c,GE:()=>x,sU:()=>R});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",h=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. '*' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},g="All configuration objects require an agent identifier!";function m(e){if(!e)throw new Error(g);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function v(e,t){if(!e)throw new Error(g);p[e]=(0,i.D)(t,h());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e,t){if(!e)throw new Error(g);var r=m(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const y={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},w={};function A(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!w[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return w[e]}function x(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");w[e]=(0,i.D)(t,y);const r=(0,n.ek)(e);r&&(r.loader_config=w[e])}const E=(0,n.mF)().o;var _=r(385),T=r(6818);const S={buildEnv:T.Re,cus ...
#   </script>
#   <title>
#    NGK® 92145 - Laser Iridium™ Spark Plug
#   </title>
#   <link as="script" href="https://cdn.optimizely.com/js/26173860947.js" rel="preload"/>
#   <link href="https://logx.optimizely.com" rel="preconnect"/>
#   <meta content="Laser Iridium™ Spark Plug - Part Number 92145 by NGK. Available in Parts Department at www.carid.com" name="description"/>
#   <meta content="CARiD.com" property="og:site_name"/>
#   <meta content="product" property="og:type"/>
#   <meta content="NGK® 92145 - Laser Iridium™ Spark Plug" property="og:title"/>
#   <meta content="https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92145.html" property="og:url"/>
#   <meta content="https://images.carid.com/ngk/items/92145.jpg" property="og:image"/>
#   <link href="https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92145.html" rel="canonical"/>
#   <script>
#    var number_format_dec='.',number_format_th=',',number_format_point='2',store_language='US',xcart_web_dir='',images_dir='/skin1/images',lbl_no_items_have_been_selected='No items have been selected',current_area='C';
#   </script>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="#2d3034" name="theme-color"/>
#   <link href="/domain-specific/carid/manifest.json" rel="manifest"/>
#   <link crossorigin="" href="https://cdn.carid.com" rel="preconnect"/>
#   <link crossorigin="" href="https://images.carid.com" rel="preconnect"/>
#   <link crossorigin="" href="https://ic.carid.com" rel="preconnect"/>
#   <script>
#    (()=>{"use strict";var e,a,d,f,r={},t={};function c(e){var a=t[e];if(void 0!==a)return a.exports;var d=t[e]={id:e,loaded:!1,exports:{}};return r[e].call(d.exports,d,d.exports,c),d.loaded=!0,d.exports}c.m=r,e=[],c.O=(a,d,f,r)=>{if(!d){var t=1/0;for(i=0;i<e.length;i++){for(var[d,f,r]=e[i],b=!0,o=0;o<d.length;o++)(!1&r||t>=r)&&Object.keys(c.O).every((e=>c.O[e](d[o])))?d.splice(o--,1):(b=!1,r<t&&(t=r));if(b){e.splice(i--,1);var n=f();void 0!==n&&(a=n)}}return a}r=r||0;for(var i=e.length;i>0&&e[i-1][2]>r;i--)e[i]=e[i-1];e[i]=[d,f,r]},c.n=e=>{var a=e&&e.__esModule?()=>e.default:()=>e;return c.d(a,{a}),a},d=Object.getPrototypeOf?e=>Object.getPrototypeOf(e):e=>e.__proto__,c.t=function(e,f){if(1&f&&(e=this(e)),8&f)return e;if("object"==typeof e&&e){if(4&f&&e.__esModule)return e;if(16&f&&"function"==typeof e.then)return e}var r=Object.create(null);c.r(r);var t={};a=a||[null,d({}),d([]),d(d)];for(var b=2&f&&e;"object"==typeof b&&!~a.indexOf(b);b=d(b))Object.getOwnPropertyNames(b).forEach((a=>t[a]=()=>e[a]));return t.default=()=>e,c.d(r,t),r},c.d=(e,a)=>{for(var d in a)c.o(a,d)&&!c.o(e,d)&&Object.defineProperty(e,d,{enumerable:!0,get:a[d]})},c.f={},c.e=e=>Promise.all(Object.keys(c.f).reduce(((a,d)=>(c.f[d](e,a),a)),[])),c.u=e=>"async-chunks/"+{111:"438807f8",124:"6bf9263a",132:"ebc3c4c2",169:"e4da4725",221:"b9e297fc",229:"dd7a5221",261:"ea3761ce",319:"18efbfd8",359:"c58f7fe9",376:"01542f11",408:"39391b74",532:"013658e2",574:"7d76112f",610:"dcb0cc8b",621:"78c3d96b",708:"9ac3c9e3",709:"d4c51f73",832:"135156eb",857:"acc8736f",1051:"4652a18c",1073:"1c06c3b7",1078:"2f2f14b1",1146:"e65e69e0",1176:"51d5e553",1177:"d45e7979",1178:"93a3fa90",1216:"edf95752",1234:"75b11e79",1328:"34a38406",1362:"ae8236ce",1402:"64794122",1423:"a01ec659",1443:"09090b07",1506:"5c32eb39",1526:"7497e0f5",1541:"ad2d1372",1699:"766032df",1719:"6a8bd16f",1853:"33d37d15",1854:"88a2766a",1869:"f91caab1",2066:"cea3a1a7",2070:"dbf8c2ad",2094:"30a1a746",2206:"dd7ed741",2338:"556f5374",2348:"ecebd50a",2395:"095f8a4c",2487:"aa867802",2511:"3e73ee5e",2679:"47c6e004",2691:"e30ce627",2707:"2c26a51e",2814:"b34e5408",2889:"1ed1e767",2912:"36cc4486",2998:"b3a9bff6",2999:"dc8ef371",3083:"83761efc",3143:"44179e54",3145:"8827f2a9",3153:"5a94510f",3188:"bb7ddac7",3219:"f0c4ed3a",3365:"1b761e77",3525:"84831749",3553:"41bfda48",3579:"1e32d5a6",3610:"d01fdb9f",3744:"c8ee9a9a",3750:"ffdeddc7",3838:"309ec7a2",3874:"7270c538",3893:"bde2fb0c",3912:"6d8114ee",4018:"086825b4",4034:"f8fdfa4f",4092:"c7aad79d",4118:"542e68e8",4227:"74c80c26",4289:"7b3531df",4324:"b1b15ea7",4362:"d2afb1c9",4449:"9423cb2c",4499:"8bf93c1c",4552:"f32e4257",4575:"e374ede9",4669:"2d3df995",4724:"bf9bec4a",4771:"ecbb77b2",4775:"44e66615",4786:"ea346960",4870:"6dcdef9d",4938:"def9e737",4941:"bbeb8772",5056:"6eafbc3e",5082:"dcaa3c88",5204:"36b0f088",5211:"6f9489be",5341:"5e2c56df",5369:"6a536beb",5426:"e9fbcc9d",5453:"e1b586e3",5554:"ae30a788",5560:"816bf400",5563:"7f78fbe7",5611:"c5d903f9",5711:"544bc312",5736:"a98818ae",5821:"99adf27c",5827:"ffaa3b67",5873:"5968f604",5929:"81f592e6",5956:"c3ac1ff0",6077:"467976f1",6157:"583abf55",6304:"e7645a37",6356:"58ebf974",6369:"6c505fce",6375:"4aedf93c",6405:"cce37553",6409:"8801457b",6415:"de3a9352",6445:"d123e7bb",6473:"8d7798cb",6506:"8eb7a705",6513:"c1b348f9",6598:"09d57c9c",6710:"46f1d240",6840:"d6889941",7046:"8f96fac5",7067:"ec451c21",7102:"05617b7b",7230:"33df5752",7244:"d5e15b83",7249:"e7684d0d",7266:"4885f292",7371:"9bb40e6b",7463:"2f948e35",7499:"24049751",7557:"cad7fc34",7657:"6e79814f",7666:"5103684a",7762:"3333e2fc",7855:"a6ec2eea",7974:"a8427f27",8080:"70e662fe",8180:"d20034ae",8189:"bccb83c7",8253:"72685026",8334:"78d8cbb6",8432:"c914daa4",8467:"ce9ef3c3",8645:"b04f01fd",8848:"4857a83b",8874:"0b5b49ad",8931:"74689232",8935:"6c1a2ce3",8939:"f3253b16",9180:"2eb51253",9375:"ae09ca5d",9407:"eb9ce396",9417:"801202e9",9429:"27032481",9471:"11517dc4",9512:"4c73964d",9744:"d9e6ff6f",9836:"9d7ca070",9854:"6a53003b",9867:"dc9f4924",9871:"5afee5f7",9931:"bfd6829d",9974:"99c168 ...
#   </script>
#   <script>
#    "use strict";(globalThis.webpackChunkid=globalThis.webpackChunkid||[]).push([[6122],{65775:(t,e,r)=>{r.d(e,{default:()=>n});const n=(window.APP||(window.APP={}),window.APP)},39168:(t,e,r)=>{r.d(e,{Z:()=>n});const n={create(t,e){(arguments.length>2&&void 0!==arguments[2]?arguments[2]:document).addEventListener(t,e)},trigger(t){let e,r=arguments.length>1&&void 0!==arguments[1]?arguments[1]:document;try{e=new Event(t)}catch(n){try{e=r.createEvent("Event"),e.initEvent(t,!1,!1)}catch(t){}}r.dispatchEvent(e)}}},6414:(t,e,r)=>{r(70560);var n=r(65775),o=r(39168);(()=>{n.default.readyCallbacks=[],n.default.ready=t=>{t&&"function"==typeof t&&n.default.readyCallbacks.push(t)},n.default.requireAsync=(t,e)=>{if(t){const r="string"==typeof t?[t]:t,o="function"==typeof e?e:()=>{},i=(t,e)=>{const r=document.getElementsByTagName("head")[0],n=document.createElement("script");n.src=t,n.onload=()=>{e()},r.appendChild(n)};r.length>1?i(r[0],(()=>{n.default.requireAsync(((t,e)=>{const r=[];for(let t=0;t<=e.length-1;t+=1)t+1>1&&r.push(e[t]);return r})(0,r),o)})):i(r[0],o)}};let t=null;const e=[];n.default.loadAsyncStyle=async r=>{if(!e.includes(r)){const n=document.createElement("link");n.rel="stylesheet",n.href=r,document.head.appendChild(n),e.push(r),clearTimeout(t),t=setTimeout((()=>{try{o.Z.trigger("initSpoilerHeight"),o.Z.trigger("resize",window)}catch(t){}}),500)}},n.default.moduleLoader={},n.default.moduleLoader.loadModulesAlreadyExecuted=!1,n.default.moduleLoader.moduleGroups=[],n.default.moduleLoader.add=(t,e)=>{const r="string"==typeof t?[t]:t;if(r.length>0){const t={names:r,callback:e};n.default.moduleLoader.moduleGroups.push(t),n.default.moduleLoader.loadModulesAlreadyExecuted&&n.default.moduleLoader.loadModules&&"function"==typeof n.default.moduleLoader.loadModules&&n.default.moduleLoader.loadModules()}}})()},10509:(t,e,r)=>{var n=r(69985),o=r(23691),i=TypeError;t.exports=function(t){if(n(t))return t;throw new i(o(t)+" is not a function")}},85027:(t,e,r)=>{var n=r(48999),o=String,i=TypeError;t.exports=function(t){if(n(t))return t;throw new i(o(t)+" is not an object")}},84328:(t,e,r)=>{var n=r(65290),o=r(27578),i=r(6310),a=function(t){return function(e,r,a){var u,c=n(e),s=i(c),f=o(a,s);if(t&&r!=r){for(;s>f;)if((u=c[f++])!=u)return!0}else for(;s>f;f++)if((t||f in c)&&c[f]===r)return t||f||0;return!t&&-1}};t.exports={includes:a(!0),indexOf:a(!1)}},5649:(t,e,r)=>{var n=r(67697),o=r(92297),i=TypeError,a=Object.getOwnPropertyDescriptor,u=n&&!function(){if(void 0!==this)return!0;try{Object.defineProperty([],"length",{writable:!1}).length=1}catch(t){return t instanceof TypeError}}();t.exports=u?function(t,e){if(o(t)&&!a(t,"length").writable)throw new i("Cannot set read only .length");return t.length=e}:function(t,e){return t.length=e}},6648:(t,e,r)=>{var n=r(68844),o=n({}.toString),i=n("".slice);t.exports=function(t){return i(o(t),8,-1)}},8758:(t,e,r)=>{var n=r(36812),o=r(19152),i=r(82474),a=r(72560);t.exports=function(t,e,r){for(var u=o(e),c=a.f,s=i.f,f=0;f<u.length;f++){var l=u[f];n(t,l)||r&&n(r,l)||c(t,l,s(e,l))}}},75773:(t,e,r)=>{var n=r(67697),o=r(72560),i=r(75684);t.exports=n?function(t,e,r){return o.f(t,e,i(1,r))}:function(t,e,r){return t[e]=r,t}},75684:t=>{t.exports=function(t,e){return{enumerable:!(1&t),configurable:!(2&t),writable:!(4&t),value:e}}},11880:(t,e,r)=>{var n=r(69985),o=r(72560),i=r(98702),a=r(95014);t.exports=function(t,e,r,u){u||(u={});var c=u.enumerable,s=void 0!==u.name?u.name:e;if(n(r)&&i(r,s,u),u.global)c?t[e]=r:a(e,r);else{try{u.unsafe?t[e]&&(c=!0):delete t[e]}catch(t){}c?t[e]=r:o.f(t,e,{value:r,enumerable:!1,configurable:!u.nonConfigurable,writable:!u.nonWritable})}return t}},95014:(t,e,r)=>{var n=r(19037),o=Object.defineProperty;t.exports=function(t,e){try{o(n,t,{value:e,configurable:!0,writable:!0})}catch(r){n[t]=e}return e}},67697:(t,e,r)=>{var n=r(3689);t.exports=!n((function(){return 7!==Object.defineProperty({},1,{get:function(){return 7}})[1]}))},22659:t=>{var e="object"==typeof document&&document.all,r=voi ...
#   </script>
#   <script defer="" src="/js/vendor/vendor-polyfills.min.js?v=9b52ace9">
#   </script>
#   <script async="" src="/js/b.min.js?v=f5d49ab2">
#   </script>
#   <script>
#    APP.storeName = 'CARiD';APP.domainId = '1';
#   </script>
#   <style data-url="/css/critical.css?v=679a18d6">
#    .media-query-state{height:0;overflow:hidden;position:absolute;transform:scale(7);transition:transform 1ms linear;width:1px;z-index:-1}.media-query-state::after{content:"mobile-small"}@keyframes preloader-rotate{0%{transform:translate(-50%, -50%) rotateZ(0)}100%{transform:translate(-50%, -50%) rotateZ(360deg)}}.body-bg-type1{background:#f0f0f0}.body-bg-type1::after,.body-bg-type1::before{content:"";display:table}.hr{border-top:1px solid #d8d8d8;clear:both;height:0;margin:20px 0}.nobg{background:none !important}.nobg-before::before{background:none !important}.nobrdr{border:0 !important}.align-center{text-align:center !important}.align-left{text-align:left !important}._uppercase{text-transform:uppercase !important}.no-js .product-images-shifter-source{pointer-events:none}body{background-color:#fff;color:#111;font:62.5% "Roboto","Arial","Helvetica",sans-serif;line-height:1.4;margin:0;padding:0;text-align:center}div,span,h1,h2,p,em,img,strong,b,u,i,dl,dt,dd,ol,ul,li,fieldset,legend,form,label,table,tr,th,td{background:rgba(0,0,0,0);border:0;font-size:100%;margin:0;outline:0;padding:0;vertical-align:baseline}a,[data-hlk]{background:rgba(0,0,0,0);color:#3761bf;cursor:pointer;font-size:100%;margin:0;padding:0;text-decoration:none;vertical-align:baseline}a:hover,[data-hlk]:hover{text-decoration:underline}table{border-collapse:collapse;border-spacing:0}table td,table th{vertical-align:top}iframe{border:0}html{overflow-x:hidden}html,body{min-height:100%}body{position:relative}textarea{resize:vertical}#scrollfix{position:relative;width:100%;z-index:5}#scrollfix.hiddenScroll{overflow:hidden}.left-panel,.right-panel{display:none;position:absolute;top:0}.main-content{position:relative;width:100%;z-index:1}.main-content.-overlay.-animate::after{animation:show-opts .4s}.main-content.-selects-overlay-show{z-index:auto}.main-content.-wishlist-panel-holder{z-index:5}.wrap{margin:0 auto;min-width:320px;position:relative;text-align:left}.product-list-with-filter-holder{box-sizing:border-box;width:100%}.mobile-small-show,.mobile-medium-show,.mobile-large-show{display:none !important}.hidden{display:none !important}._hide-text{display:block;font-size:1rem;height:0;overflow:hidden;width:0}.ov-hidden{overflow:hidden !important}.ov-x-auto{overflow-x:auto !important}.block{display:block !important}.clear{clear:both;height:0;overflow:hidden}._clear-modern::before,._clear-modern::after{clear:both;content:"";display:table}.float_right{float:right}.float_left{float:left}.pos_r{position:relative}.row::before,.row::after{clear:both;content:"";display:table}template{display:none}.break-word{word-wrap:break-word}.h1-change-btn-wrap{margin:16px 8px}.h1-fat{color:#111;display:block;font:500 2.2em/1.2 "Roboto","Arial","Helvetica",sans-serif;margin:16px 2%}.h1-fat.-with-button{display:inline;margin:0 24px 0 0}.h1-fat>span{font-weight:400}._store-red{background-color:#d41e2b !important}._store-orange{background-color:#fea934 !important}._store-grey-blue{background-color:#455874 !important}._store-blue{background-color:#0883d4 !important}._store-gray{background-color:#686c73 !important}._store-dark-orange{background-color:#fc6200 !important}._store-green{background-color:#1e824c !important}.stores-list-wrap{background-color:#f8f8f8;border-bottom:1px solid #d8d8d8}.stores-list{align-items:center;display:flex;flex-wrap:nowrap;height:36px;list-style:none;overflow:auto hidden}.stores-list>li{display:flex;font-size:1.3em}.stores-list>li>.item{box-sizing:border-box;color:#464646;display:block;line-height:35px;padding-left:64px;padding-right:28px;position:relative;white-space:nowrap}.stores-list>li>.item.-active{cursor:default;font-weight:700}.stores-list-icon{background-position:20px 50%;background-repeat:no-repeat;background-size:auto 16px}.stores-list-icon.-i1-15{background-image:url(https://cdn.carid.com/css/prod-images/0fd23e3d.svg)}.stores-list-icon.-i1-31{background-image:url(https://cdn.carid.com/css/prod-images/5376f3f3.svg)}.stores-list-icon.-i1-6{background-ima ...
#   </style>
#   <script>
#    APP.loadAsyncStyle('/css/enhance.css?v=278e4df4');
#   </script>
#   <link as="image" fetchpriority="high" href="https://ic.carid.com/ngk/items/92145_1.jpg" rel="preload"/>
#   <style data-url="/css/product.css?v=0a0b9ad7">
#    .prod-help-zone{font-size:1.2em;margin:16px 0 20px;padding:8px 0 8px 60px;position:relative}.prod-help-zone.-on-gift-card{float:none}.prod-help-zone>.ask{margin-bottom:8px;padding-top:4px}.prod-help-zone>.item{font-size:1.2em;vertical-align:middle}.prod-help-zone>.item+.item{margin-left:12px}.prod-help-zone-specialist{background-position:50% 50%;background-repeat:no-repeat;background-size:44px auto;display:block;height:44px;left:0;position:absolute;top:50%;transform:translateY(-50%);width:44px}.prod-help-zone-livechat{color:#3761bf;cursor:pointer;display:inline-block;white-space:nowrap}.prod-help-zone-livechat:hover{text-decoration:underline}.prod-sections{color:#111;margin:0 8px;position:relative}.prod-sections::after{clear:both;content:"";display:table}.prod-media{box-sizing:border-box;position:relative}.prod-title{box-sizing:border-box;padding-bottom:1em;padding-top:16px}.prod-title>.name{font-size:1.8em;font-weight:400;line-height:1.4;word-wrap:break-word}.prod-title>.name>a{color:#111}.prod-rating-h{color:#464646;font-size:1.3em;line-height:22px;margin-top:10px}.prod-rating-h>i{font-style:normal;margin:0 10px}.prod-rating-a{color:#3761bf;display:inline-block}.prod-rating{background-size:auto 12px;box-sizing:border-box;display:inline-block;height:12px;margin-top:4px;vertical-align:top;width:80px}.main-product-gallery-preload{position:relative}.main-product-gallery-preload>.main-img{background-color:#d8d8d8;padding-top:100%;position:relative;width:100%}.main-product-gallery-preload>.main-img>.item{height:100%;left:0;position:absolute;top:0;width:100%}.main-product-gallery-preload>.lists>.thumbs{overflow-y:auto;white-space:nowrap}.main-product-gallery-preload>.lists>.thumbs:first-child{display:none}.main-product-gallery-preload>.lists>.thumbs.-info{text-align:center}.main-product-gallery-preload>.lists>.thumbs>.item{background-size:100% auto;display:inline-block;height:38px;margin:8px 4px 12px 0;overflow:hidden;pointer-events:none;text-indent:-99em;width:56px}.main-product-gallery-preload>.lists>.thumbs>.item.-other{height:56px;margin:8px 8px 8px 0;position:relative;width:76px}.main-product-gallery-preload>.lists>.thumbs>.item.-other::before{border:1px solid #d8d8d8;bottom:0;content:"";left:0;position:absolute;right:0;top:0}.preloader-main-image{background-color:rgba(0,0,0,.06);bottom:0;height:100%;left:0;position:absolute;right:0;top:0}.main-product-gallery{height:100%;left:0;opacity:0;position:absolute;top:0;width:100%}.main-product-gallery.-static{opacity:1;position:static}.product-images-shifter{overflow:hidden;position:relative}.product-images-shifter-move-holder{display:block;height:0;overflow:hidden;padding-bottom:100%;position:relative;-webkit-touch-callout:none;touch-callout:none;-webkit-user-select:none;user-select:none;width:99%}.product-images-shifter-move{-webkit-backface-visibility:hidden;backface-visibility:hidden;cursor:pointer;height:100%;left:0;position:absolute;top:0;transform:translateZ(0);width:100%}.product-images-shifter-move-item{background-color:#fff;background-position:50% 50%;background-repeat:no-repeat;background-size:contain;border-left:.1em solid #fff;border-right:.1em solid #fff;box-sizing:border-box;display:inline-block;height:100%;pointer-events:none;position:relative;-webkit-user-select:none;user-select:none;width:100%}.product-images-shifter-move-item>img{height:auto;left:0;position:absolute;top:50%;transform:translateY(-50%);width:100%}.product-images-shifter-move-item .lazy-loading{bottom:0;display:block}.product-images-shifter-transition{transition:transform .3s ease-out}.product-images-shifter-source{display:block;margin:0 1px;overflow:auto hidden;white-space:nowrap}.product-images-shifter-source.-dots-view{white-space:normal}.product-images-shifter.enabled .product-images-shifter-source>.product-image-main-holder{display:none}.prod-gallery-dots{padding:16px 10px;text-align:center}.prod-gallery-dot{background-clip:content-box;cursor:pointer;display:inline-block;height:14px;overflow:h ...
#   </style>
#   <script>
#    APP.loadAsyncStyle('/css/product-enhance.css?v=246931c9');
#   </script>
#   <script defer="" src="/js/vendor/vendor-main.min.js?v=52f18eeb">
#   </script>
#   <script defer="" src="/js/main.min.js?v=adbd0b9e">
#   </script>
#   <script>
#    APP.myGarageIdentifier = 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJ4aWQiOiIzNzBiYTdkYmU4NmFhMjkxYzVlYWMzZDY4OWJiODEzZiIsImV4cCI6IjIwMjQtMDEtMjUgMDM6MjE6NTciLCJ0b2tlblR5cGUiOiJndWVzdCJ9.ui8uMFxV5a61e4eY8NV61gzyco9Yv9t4J00Jnkes48G_GjyGK17wqI7LudwGCEUcpbQFBsGlLZ-47XpX4ONi8STnU1tZiu6Mke4s7JF0SLWBPetfby06JrLqggGexpxp2mdsAnKv1rKROxCny2mJO9f-kP_oStFoyZkmOSKvU3JldQxQ4zSp5Ccf0RqchiUmdXvExPsm_t3a6qqzv0B9bAjjxX3Ig8wgo9gAZ7moJvmYMot_KKq8HAizRroq4lU9Uvdx0xSOnEMLG5dlG3dUOlabos9Ij3w6-o77TG44fZUmkGAWjIiycbGl75Uddq4vYfQ4kbCqLuF1zveFzhby0A';APP.uid = '52fe51f38cb8852253c92917a3bf43af';
#   </script>
#   <link href="/domain-specific/carid/favicon.ico" rel="shortcut icon"/>
#   <link href="/domain-specific/carid/favicon.ico" rel="icon"/>
#   <link href="/domain-specific/carid/icon-192x192.png" rel="apple-touch-icon"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-500.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-700.woff2" rel="preload" type="font/woff2"/>
#   <script>
#    APP.loadAsyncStyle('/css/fonts.css?v=8044db5b');
#   </script>
#   <script async="" src="https://cdn.optimizely.com/js/26173860947.js">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];window.dataLayer.push({pageType: 'product',pageSubType: 'mpn',productCategory: 'ignition',userId: '',uid: '52fe51f38cb8852253c92917a3bf43af'});APP.moduleLoader.add('gtm-ec');
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PDK6G9P');
#   </script>
#  </head>
#  <body>
#   <aside class="left-panel">
#   </aside>
#   <aside class="right-panel">
#   </aside>
#   <aside class="head-search-holder js-head-search-form-holder" data-code="cae9ff9a9e9529684a6d4c1748fc05ea" data-has-mmy="1" data-id-prefix="head">
#   </aside>
#   <div id="app-root">
#   </div>
#   <div id="scrollfix">
#    <div class="main-wrap">
#     <header class="head-header">
#      <nav class="stores-list-wrap">
#       <div class="wrap">
#        <ul class="stores-list">
#         <li class="js-bg-lazy-load">
#          <div class="item stores-list-icon -active nobg -i1-15">
#           Car &amp; Truck
#          </div>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i4-0 js-new-tab" href="https://www.boatid.com">
#           Boating
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-6 js-new-tab" href="https://www.motorcycleid.com">
#           Motorcycle
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-20 js-new-tab" href="https://www.powersportsid.com">
#           Powersports
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i3-0 js-new-tab" href="https://www.camperid.com">
#           RV / Camper
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i2-0 js-new-tab" href="https://www.recreationid.com">
#           Recreation
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-31 js-new-tab" href="https://www.truckid.com">
#           Semi Truck
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i5-0 js-new-tab" href="https://www.toolsid.com">
#           Tools
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <script>
#       APP = APP || {};APP.storeMenu = {'mmyStores': [ {'store_id': '15','store_name': 'Car & Truck'}, {'store_id': '6','store_name': 'Motorcycle'}, {'store_id': '20','store_name': 'Powersports'}, {'store_id': '31','store_name': 'Semi Truck'}],'currentStore': '15'};
#      </script>
#      <div class="wrap">
#       <div class="header-top">
#        <div class="nav-logo-holder -carid">
#         <span class="left-menu-icon js-hamburger" data-flag-src="/flag-icons/US-small.svg" data-has-mmy="1" data-store-id="0" data-toggle-class="left-panel-show" data-vehicle-garage-id="15" data-vehicle-id="15">
#         </span>
#         <a class="head-logo-a head-logo-img -carid" href="/">
#          CAR ID
#         </a>
#        </div>
#        <div class="input-holder js-supporting-element-data" data-current-value="" data-has-mmy="1" data-host="spellcheck.carid.com" data-page-type="mpn_product" data-store-id="1" data-vehicle-type-id="15" id="dummy-search-input-for-preact-render">
#         <div class="header-search-label">
#         </div>
#        </div>
#        <ul class="home-header-nav-tool">
#         <li aria-haspopup="true" class="header-dd-hover-element nav-tool-garage-item js-garage-header-menu js-garage-header-menu-block" data-vehicle-garage-id="15">
#          <div class="nav-tool -garage -icon-garage -i1-15">
#           <span class="count-item -outline -garage js-my-garage-counter">
#            0
#           </span>
#           <span class="title -empty js-header-garage-mmy">
#           </span>
#           <span class="garage-change-btn hidden js-garage-change-btn">
#            Change
#           </span>
#          </div>
#         </li>
#         <li class="header-dd-hover-element nav-tool-account-item js-account-header-menu">
#          <div class="nav-tool -icon-account">
#          </div>
#          <div class="js-account-dd-holder">
#          </div>
#         </li>
#         <li aria-haspopup="true" class="header-dd-hover-element js-head-cart-holder">
#          <a class="nav-tool -icon-cart" href="/cart.php">
#           <span class="header-access-text">
#            Shopping Cart
#           </span>
#           <span class="count-item -outline js-mini-cart-total-items">
#            0
#           </span>
#          </a>
#          <div class="js-head-dd-cart-prods">
#          </div>
#         </li>
#        </ul>
#       </div>
#       <nav class="head-dd-h">
#        <div class="header-menu-wrapper">
#         <ul class="head-dd js-head-depts">
#          <li class="item js-head-dept" data-id="62" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/auto-parts.html">
#            Parts
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="418" data-store-id="0" data-vehicle-id="15">
#           <span class="head-dd-main">
#            <a class="link" href="/custom-wheels.html">
#             Wheels
#            </a>
#            <span class="extra">
#             &amp;
#            </span>
#            <a class="link" href="/tires.html">
#             <span class="head_dd_main_wide_show">
#              Tires
#             </span>
#            </a>
#           </span>
#          </li>
#          <li class="item js-head-dept" data-id="408" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/exterior-accessories.html">
#            Exterior
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="24" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/automotive-lighting.html">
#            Lighting
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="63" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/auto-body-parts.html">
#            Body Parts
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="407" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/interior-accessories.html">
#            Interior
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="170" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/car-audio-electronics.html">
#            Audio &amp; Electronics
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="29909" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/automotive-tools.html">
#            Automotive Tools
#           </a>
#          </li>
#          <li class="item mobile-hide js-head-dept js-more-ignore" data-id="777">
#           <span class="head-dd-main">
#            Specialty
#            <span class="extra">
#             Shops
#            </span>
#           </span>
#          </li>
#         </ul>
#        </div>
#       </nav>
#      </div>
#      <div class="head-dd-cont-holder js-head-dd-cont-holder">
#       <div class="wrap">
#       </div>
#      </div>
#     </header>
#     <script class="js-phone-link" type="text/x-handlebars-template">
#      <a href="tel:+1-888-577-6964" class="inline-block js-phone-h phone-link">888.577.6964</a>
#     </script>
#     <script class="js-phone-int-link" type="text/x-handlebars-template">
#      <a href="tel:+1-609-642-4700" class="inline-block js-int-phone-h phone-link">1.609.642.4700</a>
#     </script>
#     <div class="main-content">
#      <main>
#       <div class="wrap">
#        <style data-url="/css/affirm-banner.css?v=6eaffa03">
#         .affirm-top-btn,.bread-pay-top-btn{background:url(https://cdn.carid.com/css/prod-images/17ee9df8.svg) 50% 50% no-repeat;background-size:220px 24px;height:24px;left:50%;margin-bottom:18px;min-height:10px;overflow:hidden;padding-top:12px;position:relative;transform:translateX(-50%);width:220px;z-index:4}.affirm-top-btn>.btn,.bread-pay-top-btn>.btn{cursor:pointer;display:block;height:24px;width:220px}.bread-pay-top-btn{background:url(https://cdn.carid.com/css/prod-images/8ecdc645.svg) 50% 50% no-repeat;display:none}.product-list-with-filter-holder>.affirm-top-btn{margin-bottom:30px}.page-title-with-affirm>.affirm-top-btn,.page-title-with-affirm>.bread-pay-top-btn{margin-bottom:0;margin-top:34px}@media only screen and (min-width:421px){.product-list-with-filter-holder>.affirm-top-btn{margin-top:20px}}@media only screen and (min-width:741px){.affirm-top-btn,.bread-pay-top-btn{background-image:url(https://cdn.carid.com/css/prod-images/1de1dbc3.svg);background-size:474px 24px;width:474px}.affirm-top-btn>.btn,.bread-pay-top-btn>.btn{width:474px}.bread-pay-top-btn{background-image:url(https://cdn.carid.com/css/prod-images/93a14f5d.svg);background-size:352px 24px;width:352px}.bread-pay-top-btn>.btn{width:352px}.product-list-with-filter-holder>.affirm-top-btn{margin-bottom:40px}}@media only screen and (min-width:1024px){.affirm-top-btn.-product-list,.bread-pay-top-btn.-product-list{flex-grow:1;left:0;transform:translateX(0)}.page-title-with-affirm>.affirm-top-btn,.page-title-with-affirm>.bread-pay-top-btn{background-color:#f8f8f8;background-position:50% 30%;border-radius:4px;float:right;left:auto;margin-top:24px;padding:11px 32px;transform:none}.page-title-with-affirm>.bread-pay-top-btn{background-color:rgba(0,0,0,0)}.page-title-with-affirm>.h1-fat{float:left;margin-left:0}}
#        </style>
#        <aside class="affirm-top-btn">
#         <span class="btn js-new-tab" data-hlk="/help-center/affirm.html">
#         </span>
#        </aside>
#        <aside class="bread-pay-top-btn">
#         <span class="btn js-new-tab" data-hlk="/help-center/bread-pay.html">
#         </span>
#        </aside>
#        <script>
#         APP.moduleLoader.add('product');APP.isProductPage = 1;APP.isProductOptionsStage2 = Boolean();APP.isPrivateLabelProduct = Boolean();
#        </script>
#        <script defer="" src="/js/vendor/vendor-react.min.js?v=0a5f0c8f">
#        </script>
#        <script defer="" src="/js/react/app.min.js?v=3205dbd9">
#        </script>
#        <script>
#         APP.isMpnProduct = 1;APP.needImmediateDeliveryRequest = true;APP.manufacturerid = 843;APP.productcode = '92145';APP.gallery = {'images': [{'path': 'https://images.carid.com/ngk/items/92145.jpg','alt': 'NGK® - Laser Iridium™ Spark Plug','src': 'https://ic.carid.com/ngk/items/92145_4.jpg','rel': 'image','is_not_reflect': '0'},{'path': 'https://images.carid.com/ngk/items/92145-2.jpg','alt': 'NGK® - Laser Iridium™ Spark Plug','src': 'https://ic.carid.com/ngk/items/92145-2_4.jpg','rel': 'image','is_not_reflect': '0'},{'path': 'https://images.carid.com/ngk/items/heat-range-cross-reference-chart.jpg','alt': 'NKG® - Heat Range Cross Reference Chart','src': 'https://ic.carid.com/ngk/items/heat-range-cross-reference-chart_4.jpg','rel': 'image','is_not_reflect': '0'},],'videos': [{'path': '/videosglobal/ngk/ignition-spark-plugs-wires/video/spark-plugs-comparison_480p.mp4','alt': 'NGK® - Spark Plugs Comparison','src': 'https://ic.carid.com/ngk/ignition-spark-plugs-wires/video/spark-plugs-comparison_480p_2.jpg','rel': 'video','quality': '480'},{'path': '/videosglobal/ngk/ignition-spark-plugs-wires/video/installing-spark-plugs_480p.mp4','alt': 'NGK® - Spark Plugs Installation','src': 'https://ic.carid.com/ngk/ignition-spark-plugs-wires/video/installing-spark-plugs_480p_2.jpg','rel': 'video','quality': '480'},],'files': [{'path': '/css/images/product/pdf-icon_s.png','alt': 'NGK® - Spark Plugs installation instruction','rel': 'installation-instructions','popup': {"name":"c3","width":"920","height":"800","scroll":"yes","newTab":false,"href":"\/ngk\/info\/installation.html"}},{'path': '/css/images/product/pdf-icon_s.png','alt': 'NGK® - FAQ','rel': 'faq','popup': {"name":"c4","width":"920","height":"800","scroll":"yes","newTab":false,"href":"\/ngk\/info\/faq.html"}},{'path': '/css/images/product/pdf-icon_s.png','alt': 'NGK® - Catalogs','rel': 'catalog','popup': {"name":"c7","width":"920","height":"750","scroll":"yes","newTab":false,"href":"\/ngk\/info\/catalogs.html"}},{'path': '/ngk/info/authorized-dealer.html','alt': 'NGK Authorized Dealer','rel': 'authorized-dealer','popup': {"href":"\/ngk\/info\/authorized-dealer.html","name":"authorized_dealer","width":960,"height":800,"scroll":"yes","newTab":false}}]};APP.defaultFormState = {parameters: {namespace: 'parent',WTAjaxListener: '/ajax/ajax.php',mainPtypeGroupUrl: 'ignition-parts.html',ajaxListener: '/ajax/ajax.php','hasProductOptions': 1},mmyParameters: {prod_fitment: '',showSubmodelSelector: true,otherOptionSelectedIn: 0,selectsOrder: 'ymm',mpn_product_fitments: {"_2024":{"Dodge":{"Ram":[{"real_model":"Ram 1500 New Generation","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]}},"_2023":{"Chrysler":{"300":[{"real_model":"300 \/ 300C","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]},"Dodge":{"Ram":[{"real_model":"Ram 1500 New Generation","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]},"Jeep":{"Renegade":[{"submodels":"2.4L","fitment_note":"Your Vehicle Spark Plug Gap Is 0.047\". Please Adjust the Spark Plug Selected to Match This Size[:s:]Your Vehicle Requires 4 Spark Plugs"}]},"Ram":{"1500":[{"real_model":"1500 New Generation","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]}},"_2022":{"Chrysler":{"300":[{"real_model":"300 \/ 300C","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]},"Dodge":{"Ram":[{"real_model":"Ram 1500 New Generation","submodels":"5.7L","fitment_note":"Your Vehicle Requires 8 Spark Plugs."}]},"Jeep":{"Cherokee":[{"submodels":"2.4L","fitment_note":"Your Vehicle Spark Plug Gap Is 0.047\". Please Adjust the Spark Plug Selected to Match This Size[:s:]Your Vehicle Requires 4 Spark Plugs"}],"Renegade":[{"submodels":"2.4L","fitment_note":"Your Vehicle Spark Plug Gap Is 0.047\". Please Adjust the Spark Plug Selected to Match This Size[:s:]Your Vehicle Requires 4 Spark Plugs"}]},"Ram":{"1500":[{"real_model":"1500 New Generation","submodels":"5.7L", ...
#        </script>
#        <div class="breadcrumbs-holder -product">
#         <nav class="breadcrumbs-ov">
#          <ol class="breadcrumbs">
#           <li class="item">
#            <a class="link" href="/">
#             home
#            </a>
#           </li>
#           <li class="item">
#            <a class="link" href="/shop-by-brand/">
#             All Brands
#            </a>
#           </li>
#           <li class="item">
#            <a class="link" href="/ngk/">
#             NGK
#            </a>
#           </li>
#           <li class="item">
#            <a class="link" href="/ngk/ignition-parts/">
#             NGK Ignition
#            </a>
#           </li>
#          </ol>
#         </nav>
#         <script type="application/ld+json">
#          {"@context": "https://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "home","item": "https://www.carid.com/"},{"@type": "ListItem","position": 2,"name": "All Brands","item": "https://www.carid.com/shop-by-brand/"},{"@type": "ListItem","position": 3,"name": "NGK","item": "https://www.carid.com/ngk/"},{"@type": "ListItem","position": 4,"name": "NGK Ignition","item": "https://www.carid.com/ngk/ignition-parts/"}]}
#         </script>
#        </div>
#        <aside class="clear">
#        </aside>
#        <section>
#         <form action="/cart.php?mode=add" autocomplete="off" class="prod-sections" data-brand="NGK" data-cat="Ignition" data-id="mpn4063563134" data-name="NGK® 92145 - Laser Iridium™ Spark Plug" data-price="8.63" data-price-cart="8.63" id="product_orderform" method="post" name="orderform">
#          <input name="prod_parent_id" type="hidden" value="5087862340"/>
#          <input name="prod_real_id" type="hidden" value="mpn4063563134"/>
#          <input name="prod_make" type="hidden" value=""/>
#          <input name="prod_model" type="hidden" value=""/>
#          <input name="prod_year" type="hidden" value=""/>
#          <input name="prod_submodel" type="hidden" value=""/>
#          <input name="prod_fitment" type="hidden" value=""/>
#          <div class="prod-title js-prod-title">
#           <h1 class="name">
#            NGK® 92145 - Laser Iridium™ Spark Plug
#           </h1>
#           <div class="prod-rating-h">
#            <span class="prod-rating stars-0">
#            </span>
#            0 reviews
#            <i>
#             |
#            </i>
#            Item # mpn4063563134
#            <i>
#             |
#            </i>
#            <span class="prod-rating-a js-new-tab js-view-similar-products" data-hlk="/performance-spark-plugs.html">
#             Similar Products
#            </span>
#           </div>
#          </div>
#          <div class="prod-media" id="prodLeftSide">
#           <div class="pos_r" id="main-product-gallery">
#            <div class="main-product-gallery-preload">
#             <div class="prod-wishlist js-product-wishlist js-product-list-item" data-name="NGK® 92145 - Laser Iridium™ Spark Plug" data-src="https://ic.carid.com/ngk/items/92145_4.jpg" data-wl-price="">
#              <div class="add js-wishlist-open-add-popup" data-prod-id="mpn4063563134">
#               <span class="badge">
#               </span>
#              </div>
#             </div>
#             <div class="main-img">
#              <img alt="NGK® - Laser Iridium™ Spark Plug" class="item" fetchpriority="high" src="https://ic.carid.com/ngk/items/92145_1.jpg"/>
#             </div>
#             <div class="lists">
#              <div class="thumbs">
#               <a class="item" href="https://images.carid.com/ngk/items/92145.jpg" style="background-image:url(https://ic.carid.com/ngk/items/92145_4.jpg)">
#                NGK® - Laser Iridium™ Spark Plug
#               </a>
#               <a class="item" href="https://images.carid.com/ngk/items/92145-2.jpg" style="background-image:url(https://ic.carid.com/ngk/items/92145-2_4.jpg)">
#                NGK® - Laser Iridium™ Spark Plug
#               </a>
#               <a class="item" href="https://images.carid.com/ngk/items/heat-range-cross-reference-chart.jpg" style="background-image:url(https://ic.carid.com/ngk/items/heat-range-cross-reference-chart_4.jpg)">
#                NKG® - Heat Range Cross Reference Chart
#               </a>
#              </div>
#              <div class="prod-gallery-dots">
#               <span class="prod-gallery-dot">
#               </span>
#               <span class="prod-gallery-dot">
#               </span>
#               <span class="prod-gallery-dot">
#               </span>
#              </div>
#              <div class="thumbs -info">
#               <a class="item -other gallery-video-bg" href="/videosglobal/ngk/ignition-spark-plugs-wires/video/spark-plugs-comparison_480p.mp4">
#                NGK® - Spark Plugs Comparison
#               </a>
#               <a class="item -other gallery-installation-instructions-bg" href="/ngk/info/installation.html">
#                NGK® - Spark Plugs installation instruction
#               </a>
#               <a class="item -other gallery-faq-bg" href="/ngk/info/faq.html">
#                NGK® - FAQ
#               </a>
#               <a class="item -other gallery-catalog-bg" href="/ngk/info/catalogs.html">
#                NGK® - Catalogs
#               </a>
#               <a class="item -other gallery-authorized-dealer-bg" href="/ngk/info/authorized-dealer.html">
#                NGK Authorized Dealer
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="main-product-gallery">
#            </div>
#           </div>
#          </div>
#          <div class="prod-actions" id="prodRightSide">
#           <div class="prod-info">
#            <div class="prod-price-h">
#             <span class="js-product-price-hide prod-price">
#              $8.63
#             </span>
#             <div class="ab-affirm-block-top hidden">
#             </div>
#            </div>
#            <div class="prod-avail -green js-prod-avail">
#             <span class="js-deliver-text">
#              In Stock (3276) - Ships in 2 to 3 days
#             </span>
#            </div>
#            <div class="js-prod-deliver-location">
#            </div>
#           </div>
#           <div class="prod-right-info-box js-need-this-installed-holder">
#           </div>
#           <div class="js-product-info-box">
#           </div>
#           <div class="prod-right-info-box prod-verify-vehicle">
#            <div class="prod-vehicle js-prod-vehicle">
#             <div>
#              Vehicle Specific
#             </div>
#            </div>
#            <div class="prod-vehicle-notes">
#             <b>
#              Fits Following Model(s):
#              <script>
#               APP.defaultFormState.productParameters.fitmentNotesTitle = 'Fits Following Model(s):';
#              </script>
#             </b>
#             <div>
#              <ul class="prod-expand-wrap -fitment-notes -gradient-fade">
#               <li>
#                Please Select Vehicle Below
#               </li>
#              </ul>
#              <span class="prod-expand-btn js-prod-expand-btn">
#              </span>
#             </div>
#            </div>
#           </div>
#           <div class="prod-right-info-box prod-notes-block hidden">
#           </div>
#           <div class="prod-add">
#            <div data-id="5087862340" id="prod-mpn-holder">
#            </div>
#           </div>
#           <div class="ab-affirm-block-bottom">
#           </div>
#           <div class="prod-dealer">
#            <div class="title">
#             Authorized Dealer
#            </div>
#            <div class="logo">
#             <a class="js-new-tab" href="/ngk/">
#              <img alt="NGK" height="62" src="https://images.carid.com/logos/ngk.png" width="143"/>
#             </a>
#            </div>
#           </div>
#          </div>
#          <aside class="clear">
#          </aside>
#         </form>
#         <script type="application/ld+json">
#          {"@context": "https://schema.org","@type": "Product","name": "NGK® 92145 - Laser Iridium™ Spark Plug","description": "Laser Iridium™ Spark Plug (92145) by NGK®. Often specified as original equipment, NGK Laser Iridium spark plugs are the best combination of performance and longevity. Iridium tip is six (6) times harder than platinum providing the strongest ignitability and the longest life possible. Most Laser Iridium spark plugs feature a platinum pad on the ground electrode for even wear in DIS ignition systems. OE engineered for specific vehicle applications.","image": "https://ic.carid.com/ngk/items/92145_0.jpg","sku": "mpn4063563134","mpn": "92145","brand": {"@type": "Brand","name": "NGK"},"offers": {"@type": "Offer","price": "8.63","itemCondition": "https://schema.org/NewCondition","availability": "https://schema.org/InStock","url": "https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92145.html","priceCurrency": "USD"}}
#         </script>
#        </section>
#        <script>
#         APP.loadAsyncStyle('/css/product-navigation.css?v=0c9af9cf');
#        </script>
#        <nav class="product-navigation-wrap js-product-navigation-wrap">
#         <div class="product-navigation">
#          <span class="item">
#           <a class="js-scroll-to -active" href="#product-details">
#            Product Details
#           </a>
#          </span>
#          <span class="item">
#           <a class="js-scroll-to" href="#specifications">
#            Specifications
#           </a>
#          </span>
#          <span class="item">
# ...
#            </script>
#            <div class="prod-review-write-btn-h">
#             <button class="simple-btn -transparent -wide js-write-prod-review" type="button">
#              Write a Review
#             </button>
#            </div>
#           </div>
#           <div class="prod-review-col-rating">
#            <div class="prod-review-section-name mobile-small-hide mobile-medium-hide -product">
#             NGK® 92145 - Laser Iridium™ Spark Plug
#            </div>
#            <div class="prod-review-section-rating stars-0" data-avg="0" data-count="0 Reviews">
#             /0
#            </div>
#            <div class="rating-percent-star-count stars-0" data-count="0">
#             <div class="percent">
#              <span class="progress" style="width: 0%;">
#              </span>
#             </div>
#            </div>
#            <div class="rating-percent-star-count stars-0" data-count="0">
#             <div class="percent">
#              <span class="progress" style="width: 0%;">
#              </span>
#             </div>
#            </div>
#            <div class="rating-percent-star-count stars-0" data-count="0">
#             <div class="percent">
#              <span class="progress" style="width: 0%;">
#              </span>
#             </div>
#            </div>
#            <div class="rating-percent-star-count stars-0" data-count="0">
#             <div class="percent">
#              <span class="progress" style="width: 0%;">
#              </span>
#             </div>
#            </div>
#            <div class="rating-percent-star-count stars-0" data-count="0">
#             <div class="percent">
#              <span class="progress" style="width: 0%;">
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <script>
#         APP.productQuestionData = APP.productQuestionData || [];APP.productQuestionData.push({productType: "MpnProduct",productId: "4063563134",singleId: "",make: "",model: "",year: "",topics: {"1":"Product details","2":"Installation","3":"Fitment","4":"Shipping (Delivery)","5":"Return","6":"Service","7":"Other"},domainId: "1",sku: "92145",brandId: "843",imageSrc: "https://ic.carid.com/ngk/items/92145_3.jpg",isAutomotive: "1",productBrand: "NGK® 92145",productName: "Laser Iridium™ Spark Plug"});
#        </script>
#        <section class="prod-review-block">
#         <div class="prod-review-section-title prod-section-title prod-content-minus prod-content-plus js-prod-content-toggle" id="qa">
#          <h2 class="heading">
#           Questions and Answers
#          </h2>
#          (0)
#         </div>
#         <div class="prod-accordion-content-wrap">
#          <div class="prod-review-head review-col-section">
#           <div class="prod-review-col-write">
#            <div class="prod-review-section-description">
#             If you have any questions about this product, please don't hesitate to ask us. We will be happy to help you!
#            </div>
#            <div class="prod-review-write-btn-h -center">
#             <button class="simple-btn -transparent -wide js-ask-question" data-product-id="4063563134" type="button">
#              Ask a Question
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <script>
#         APP.loadAsyncStyle('/css/adsense.css?v=c0fd4ba6');
#        </script>
#        <aside class="adsense-block -four-per-row mobile-hide">
#         <div class="item">
#          <div class="js-tpl-lazy-load-parent">
#           <template class="js-tpl">
#            <script>
#             window.googletag = window.googletag || {cmd: []};APP.ready(function(){APP.moduleLoader.add('adsense');});googletag.cmd.push(function() {googletag.defineSlot('/69058015/exterior/exterior_category_300x250', [300, 250], 'div-gpt-ad-1636453272633-0').addService(googletag.pubads());googletag.pubads().enableSingleRequest();googletag.enableServices();});
#            </script>
#            <div id="div-gpt-ad-1636453272633-0" style="min-width:300px;min-height:250px;">
#             <script>
#              googletag.cmd.push(function(){ googletag.display('div-gpt-ad-1636453272633-0'); });
#             </script>
#            </div>
#           </template>
#          </div>
#         </div>
#         <div class="item">
#          <div class="js-tpl-lazy-load-parent">
#           <template class="js-tpl">
#            <script>
#             window.googletag = window.googletag || {cmd: []};APP.ready(function(){APP.moduleLoader.add('adsense');});googletag.cmd.push(function() {googletag.defineSlot('/69058015/exterior/exterior_category_300x250', [300, 250], 'div-gpt-ad-1636453272633-1').addService(googletag.pubads());googletag.pubads().enableSingleRequest();googletag.enableServices();});
#            </script>
#            <div id="div-gpt-ad-1636453272633-1" style="min-width:300px;min-height:250px;">
#             <script>
#              googletag.cmd.push(function(){ googletag.display('div-gpt-ad-1636453272633-1'); });
#             </script>
#            </div>
#           </template>
#          </div>
#         </div>
#         <div class="item">
#          <div class="js-tpl-lazy-load-parent">
#           <template class="js-tpl">
#            <script>
#             window.googletag = window.googletag || {cmd: []};APP.ready(function(){APP.moduleLoader.add('adsense');});googletag.cmd.push(function() {googletag.defineSlot('/69058015/exterior/exterior_category_300x250', [300, 250], 'div-gpt-ad-1636453272633-2').addService(googletag.pubads());googletag.pubads().enableSingleRequest();googletag.enableServices();});
#            </script>
#            <div id="div-gpt-ad-1636453272633-2" style="min-width:300px;min-height:250px;">
#             <script>
#              googletag.cmd.push(function(){ googletag.display('div-gpt-ad-1636453272633-2'); });
#             </script>
#            </div>
#           </template>
#          </div>
#         </div>
#         <div class="item">
#          <div class="js-tpl-lazy-load-parent">
#           <template class="js-tpl">
#            <script>
#             window.googletag = window.googletag || {cmd: []};APP.ready(function(){APP.moduleLoader.add('adsense');});googletag.cmd.push(function() {googletag.defineSlot('/69058015/exterior/exterior_category_300x250', [300, 250], 'div-gpt-ad-1636453272633-3').addService(googletag.pubads());googletag.pubads().enableSingleRequest();googletag.enableServices();});
#            </script>
#            <div id="div-gpt-ad-1636453272633-3" style="min-width:300px;min-height:250px;">
#             <script>
#              googletag.cmd.push(function(){ googletag.display('div-gpt-ad-1636453272633-3'); });
#             </script>
#            </div>
#           </template>
#          </div>
#         </div>
#        </aside>
#        <script class="js-prod-toolbar-fixed-tpl" type="text/x-handlebars-template">
#         <aside class="prod-toolbar-fixed js-scroll-to-indent"><div class="wrap"><div class="prod-toolbar-inner"><div class="prod-toolbar-left"><div class="prod-toolbar-data"><img width="36" height="36" class="prod-toolbar-ic" src="https://ic.carid.com/ngk/items/92145_1.jpg" alt="NGK® - Laser Iridium™ Spark Plug">NGK® 92145 - Laser Iridium™ Spark Plug<div class="prod-toolbar-price"> $8.63 </div></div><div class="prod-toolbar-nav"><span class="item"><a class="js-scroll-to -active" href="#product-details">Product Details</a></span><span class="item"><a class="js-scroll-to" href="#specifications">Specifications</a></span><span class="item"><a class="js-scroll-to" href="#features">Features</a></span><span class="item"><a class="js-scroll-to" href="#installation">Installation</a></span><span class="item"><a class="js-scroll-to" href="#warranty">Warranty</a></span><span class="item"><a class="js-scroll-to" href="#applications">Vehicle Fitment</a></span><span class="item"><a class='js-scroll-to prod-toolbar-rating stars-0' href='#reviews'>Reviews (0)</a></span><span class="item"><a class='js-scroll-to' href='#qa'>Q&A (0)</a></span></div></div><div class="prod-toolbar-right"><button type="button" class="simple-btn -fixed-toolbar-btn -success js-trigger-addtocart-btn js-prod-toolbar-btn">Add To Cart</button><div class="prod-toolbar-wishlist js-product-list-item" data-name="NGK® 92145 - Laser Iridium™ Spark Plug" data-wl-price=" $8.63 " data-src="https://ic.carid.com/ngk/items/92145_4.jpg"><div class="add js-wishlist-open-add-popup" data-prod-id="mpn4063563134"><span class="badge"></span></div></div></div></div></div></aside>
#        </script>
#       </div>
#      </main>
#      <script>
#       APP.moduleLoader.add('recently-viewed')
#      </script>
#      <aside class="wrap js-recently-viewed-products">
#      </aside>
#      <footer class="f-footer js-bg-lazy-load">
#       <aside class="newsletter-subscribe-bnr">
#        <span class="txt">
#        </span>
#        <button class="btn js-subscribe-link" data-subscribe-location-type="Footer Subscription">
#         SUBSCRIBE TO OUR NEWSLETTER
#        </button>
#       </aside>
#       <div class="f-info">
#        <div class="wrap">
#         <div class="f-info-wrap">
#          <div class="f-info-col -f-pub">
#           <div class="pub-block -f-pub">
#            <span class="js-new-tab icon -icon-fb nobg" data-hlk="https://www.facebook.com/CARiDcom">
#             CARiD Facebook
#            </span>
#            <span class="js-new-tab icon -icon-tw nobg" data-hlk="https://twitter.com/carid_com">
#             CARiD Twitter
#            </span>
#            <span class="icon -icon-yt nobg" data-hlk="https://www.youtube.com/user/CARiDcom">
#             CARiD YouTube Channel
#            </span>
#            <span class="js-new-tab icon -icon-pin nobg" data-hlk="https://www.pinterest.com/caridcom/">
#             CARiD Pinterest
#            </span>
#            <span class="js-new-tab icon -icon-in nobg" data-hlk="https://www.instagram.com/caridcom/">
#             CARiD Instagram
#            </span>
#           </div>
#           <span class="f-contact -inspiration nobg-before js-new-tab" data-hlk="/gallery/">
#            Inspiration Gallery
#           </span>
#           <div class="f-text">
#            All manufacturer names, symbols, and descriptions, used in our images and text are used solely for identification purposes only. It is neither inferred nor implied that any item sold by CARiD.com is a product authorized by or in any way connected with any vehicle manufacturers displayed on this page.
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            CUSTOMER SERVICE
#           </span>
#           <div class="footer-toggle-content">
#            <div class="f-list">
#             <span data-hlk="/help-center/">
#              Help Center
#             </span>
#             <span data-hlk="/my-account/login/">
#              My Account
#             </span>
#             <span data-hlk="/my-account/order-status/">
#              Track My Order
#             </span>
#             <span data-hlk="/help-center/product-return.html">
#              Return Policy
#             </span>
#             <span data-hlk="/help-center/privacy.html">
#              Privacy Policy
#             </span>
#             <span data-hlk="/gift-cards.html">
#              Gift Cards
#             </span>
#             <span data-hlk="/contact-us.html">
#              Contact Us
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            INFORMATION
#           </span>
#           <div class="footer-toggle-content">
#            <div class="f-list">
#             <span data-hlk="/about-us.html">
#              About Us
#             </span>
#             <span data-hlk="/articles/">
#              Guides &amp; Articles
#             </span>
#             <span data-hlk="/reviews.html">
#              Customer Reviews
#             </span>
#             <span data-hlk="/coupon-codes.html">
#              Coupon Codes
#             </span>
#             <span data-hlk="/pressroom.html">
#              In the News
#             </span>
#             <span data-hlk="/vendor-portal.html">
#              Sell on CARiD
#             </span>
#             <span data-hlk="/wholesale.html">
#              Buy Wholesale
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            CONTACTS
#           </span>
#           <div class="footer-toggle-content">
#            <span class="f-contact -address nobg-before">
#             CARiD.com
#             <br/>
#             1 Corporate Drive
#             <br/>
#             Cranbury, NJ 08512
#            </span>
#            <span class="f-contact -phone nobg-before">
#             Toll Free:
#             <span>
#              <a class="inline-block js-phone-h phone-link" href="tel:+1-800-505-3274">
#               800.505.3274
#              </a>
#             </span>
#             <br/>
#             International:
#             <span>
#              <a class="inline-block js-int-phone-h phone-link" href="tel:+1-609-642-4700">
#               1.609.642.4700
#              </a>
#             </span>
#             <br/>
#             Fax:
#             <span>
#              1.609.964.1983
#             </span>
#            </span>
#            <span class="f-contact -live-chat nobg-before">
#             <span class="btn js-livechat">
#              Live Chat
#             </span>
#            </span>
#            <span class="f-contact -email nobg-before">
#             Email:
#             <span class="js-show-recommended-contacts">
#              info@carid.com
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="f-other">
#        <div class="wrap">
#         <div class="f-copyright">
#          Copyright © 2003-2024 CARiD.com. All rights reserved.
#         </div>
#         <div class="f-links">
#          <a href="/sitemap/">
#           Sitemap
#          </a>
#         </div>
#        </div>
#       </div>
#       <script type="application/ld+json">
#        {"@context":"https://schema.org","@type":"Organization","name":"CARiD","url":"https://www.carid.com/","logo":"https://www.carid.com/domain-specific/carid/icon-128x128.png","address":{"@type":"PostalAddress","addressCountry":"US","addressRegion":"NJ","addressLocality":"Cranbury","postalCode":"08512","streetAddress":"1 Corporate Drive"},"contactPoint":[{"@type":"ContactPoint","telephone":"+1-800-505-3274","contactType":"customer support","contactOption":"TollFree","areaServed":"US"},{"@type":"ContactPoint","telephone":"+1-609-642-4700","contactType":"customer support"}],"email":"info@carid.com","faxNumber":"+1-609-964-1983","sameAs":["https://www.facebook.com/CARiDcom","https://twitter.com/carid_com","https://www.youtube.com/user/CARiDcom","https://www.pinterest.com/caridcom/","https://www.instagram.com/caridcom/"]}
#       </script>
#      </footer>
#     </div>
#    </div>
#    <aside class="main-content-overlay">
#    </aside>
#   </div>
#   <script>
#    window.dataLayer = window.dataLayer || [];window.dataLayer.push({ klaviyoData: null });window.dataLayer.push({event: 'klaviyo',klaviyoEventName: 'Viewed Product',klaviyoData: {'$value': '8.63','availability': 'In Stock','login': 'false','ProductName': 'NGK® 92145 - Laser Iridium™ Spark Plug','ProductID': 'mpn4063563134','Categories': 'Ignition','ImageURL': 'https://images.carid.com/ngk/items/92145.jpg','URL': 'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92145.html','Price': '8.63',}});
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-5db917892f9cc9a5cff","applicationID":"544853054","transactionName":"M1wENUtUV0dUVEwLCwoWMxNQGlFbWFIWEgwU","queueTime":0,"applicationTime":141,"atts":"HxsHQwNOREk=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_div = html.xpath('//div[@class="prod-fit-info"]/div[contains(@class, "mmy-row")]')

list_div
# Out:
# [<Element div at 0x122cb08c0>,
#  <Element div at 0x122cb0a00>,
#  <Element div at 0x122cb0a40>,
#  <Element div at 0x122cb0b40>,
#  <Element div at 0x122cb0800>]

# %%
list_vehicle = []
for div in list_div:
    make = div.xpath('./div[1]/text()')[0].strip()
    list_model_year = div.xpath('./div[2]/div[@class="mmy-subrow"]/div[@class="mmy-subrow-title"]/text()')
    for model_year in list_model_year:
        list_vehicle.append(make + ' ' + model_year.strip())
        
vehicle = '\n'.join(list_vehicle)

print(vehicle)
# Out:
# Chrysler 200 2015-2017
# Chrysler 300 2009-2023
# Chrysler Aspen 2008-2009
# Dodge Challenger 2009-2020
# Dodge Charger 2009-2020
# Dodge Dakota 2008-2011
# Dodge Dart 2013-2016
# Dodge Durango 2008-2009, 2011-2020
# Dodge Ram 2008-2024
# Fiat 500X 2016-2018
# Jeep Cherokee 2014-2022
# Jeep Commander 2008-2010
# Jeep Compass 2017-2021
# Jeep Grand Cherokee 2008-2021
# Jeep Renegade 2015-2023
# Ram 1500 2011-2023
# Ram 2500 2011-2018
# Ram 3500 2011-2018
# Ram ProMaster City 2015-2021

# %%
list_div = html.xpath('//section[@id="product-details"]/descendant::div[@class="prod-offer-item"]')

list_div
# Out:
# [<Element div at 0x1226ea040>,
#  <Element div at 0x122c06580>,
#  <Element div at 0x122cb1780>]

# %%
list_td = html.xpath('//table[@class="spec-stripped-table"]/tr/td/text()')

list_td
# Out:
# ['Thread Diameter: 14 mm',
#  'Thread Pitch: 1.25 mm',
#  'Seat Type: Gasket',
#  'Reach: 26.5 mm (1.04")',
#  'Hex Size: 5/8" (16 mm)',
#  'Terminal Type: Solid',
#  'Gap: .043" (1.1 mm)',
#  'Center Electrode',
#  'Material: Iridium',
#  'Type: Fine Wire',
#  'Size: 0.6 mm',
#  'Projection: Extended Projection',
#  'Ground Electrode',
#  'Material: Platinum',
#  'Type: Standard',
#  'Quantity: 1',
#  'Resistor: Yes',
#  'Resistor Value: 5k Ohm',
#  'Heat Range: 5',
#  'Torque Specs: Cast Iron: 18-25.3 lb. ft. Aluminum: 18-21.6 lb. ft.',
#  'Electrode Material: Iridium',
#  'Insulator Type: Long Projection',
#  'Nominal Gap: 1.1 mm']

# %%
df_temp = pd.DataFrame([{'status': 'ok',
                         '序号': '',
                         'Sku': '',
                         'Title': '',
                         'Vehicle': vehicle,
                         'Pic': '',
                         'Url': url,
                         'Src': ''}])

for div in list_div:
    df_temp.loc[0, div.xpath('./div[@class="prod-offer-title"]/text()')[0].strip()[:-1]] = ' '.join(div.xpath('./div[@class="prod-offer-content"]/descendant-or-self::*/text()')).strip()

start = ''
for td in list_td:
    if ':' in td:
        if start == '':
            df_temp.loc[0, td.split(':')[0]] = ':'.join(td.split(':')[1:])
        else:
            df_temp.loc[0, start + '_' + td.split(':')[0]] = ':'.join(td.split(':')[1:])
    else:
        start = td
    
df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status 序号 Sku Title                                            Vehicle Pic  \
# 0     ok               Chrysler 200 2015-2017\nChrysler 300 2009-2023...
#
#                                                  Url Src Brand Part Number  \
# 0  https://www.carid.com/ngk/laser-iridium-spark-...       NGK       92145
#
#    ... Ground Electrode_Material Ground Electrode_Type  \
# 0  ...                  Platinum              Standard
#
#   Ground Electrode_Quantity Ground Electrode_Resistor  \
# 0                         1                       Yes
#
#   Ground Electrode_Resistor Value Ground Electrode_Heat Range  \
# 0                          5k Ohm                           5
#
#                        Ground Electrode_Torque Specs  \
# 0   Cast Iron: 18-25.3 lb. ft. Aluminum: 18-21.6 ...
#
#   Ground Electrode_Electrode Material Ground Electrode_Insulator Type  \
# 0                             Iridium                 Long Projection
#
#   Ground Electrode_Nominal Gap
# 0                       1.1 mm
#
# [1 rows x 32 columns]
