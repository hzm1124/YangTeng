# %% [markdown]
# - Update: 2023.05.09

# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230512.xlsx

# %%
import pandas as pd

# %%
table_1 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(1, 9)]).loc[:4]

table_1
# Out:
#       层级   SKU 总数  在库为0（断货数）  在库1-2（干预数）       断货率       干预率  近期海运上架后断货数
# 0   TOP1    493.0       37.0        22.0  0.075051  0.044625        13.0  \
# 1  TOP10   2237.0      181.0       161.0  0.080912  0.071971        70.0
# 2  TOP20   3329.0      202.0       255.0  0.060679  0.076600       101.0
# 3     普通  46287.0     2338.0      6188.0  0.050511  0.133688      1103.0
# 4     总数  52346.0     2758.0      6626.0  0.052688  0.126581      1287.0
#
#    近期海运上架后断货率
# 0    0.026369
# 1    0.031292
# 2    0.030339
# 3    0.023830
# 4    0.024586

# %%
table_2 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(10, 17)]).loc[:4]

table_2
# Out:
#     层级.1  在库为0（断货）   断货无在途        占比  在库1-2（干预）   干预无在途      占比.1
# 0   TOP1      37.0     7.0  0.189189       22.0     0.0  0.000000
# 1  TOP10     181.0    53.0  0.292818      161.0    19.0  0.118012
# 2  TOP20     202.0    80.0  0.396040      255.0   105.0  0.411765
# 3     普通    2338.0   861.0  0.368263     6188.0  2836.0  0.458306
# 4     总数    2758.0  1001.0  0.362944     6626.0  2960.0  0.446725

# %%
table_3 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(18, 27)]).loc[:4]

table_3
# Out:
#     层级.2  W14\n04/08  W15\n04/14  W16\n04/18  W16\n04/22  W17\n04/25
# 0   TOP1        55.0        59.0        58.0        43.0        35.0  \
# 1  TOP10        57.0        66.0       193.0       166.0       152.0
# 2  TOP20       362.0       311.0       165.0       139.0       143.0
# 3     普通      2648.0      2508.0      2404.0      2357.0      2297.0
# 4     总数      3122.0      2944.0      2820.0      2705.0      2627.0
#
#    W18\n05/06  W19\n05/09  W19\n05/12
# 0        32.0        38.0        37.0
# 1       150.0       166.0       181.0
# 2       171.0       188.0       202.0
# 3      2026.0      2137.0      2338.0
# 4      2379.0      2529.0      2758.0

# %%
table_4 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(28, 33)],
                        index_col=0)

table_4
# Out:
#          品类  断货SKU数量  总SKU数      断货占比
# 排名
# TOP1     BC      276   2795  0.098748
# TOP2     CA      199   4704  0.042304
# TOP3     HB      123   1111  0.110711
# TOP4    ALT      110    644  0.170807
# TOP5     WR      105   1898  0.055321
# ...     ...      ...    ...       ...
# TOP402  CST        0     58  0.000000
# TOP403  MSA        0     62  0.000000
# TOP404  CHH        0     79  0.000000
# TOP405  EGR        0     82  0.000000
# TOP406  ACS        0     94  0.000000
#
# [406 rows x 4 columns]

# %%
sheet_2_left = pd.read_excel(calculate,
                             sheet_name='2_断货SKU',
                             header=1,
                             usecols=[i for i in range(5)],
                             index_col=0)

sheet_2_left
# Out:
#                SKU     层级    周销  在途
# 序号
# 1      USADCA00400   TOP1  7.65   0
# 2    USALT11532B-C   TOP1  1.15   0
# 3    USALT14489B-C   TOP1  3.40   0
# 4    USALT82470B-C   TOP1  5.87   0
# 5     USCON30085-C   TOP1  4.25   0
# ..             ...    ...   ...  ..
# 136      USWL00307  TOP20  0.55   0
# 137      USWP01840  TOP20  1.70   0
# 138      USWR49322  TOP20  1.27   0
# 139      USWR49323  TOP20  2.46   0
# 140    USWR51797-C  TOP20  4.12   0
#
# [140 rows x 4 columns]

# %%
sheet_2_right = pd.read_excel(calculate,
                              sheet_name='2_断货SKU',
                              header=1,
                              usecols=[i for i in range(7, 9)],
                              index_col=0).dropna().sort_values(by=['断货数'], ascending=False)

sheet_2_right
# Out:
#         断货数
# 品类去重
# CVA    17.0
# ALT    16.0
# CA     14.0
# BMC     9.0
# CON     9.0
# PSR     7.0
# STR     7.0
# BC      5.0
# SA      5.0
# CS-弹簧   4.0
# MI      4.0
# RAD     4.0
# TF      3.0
# WR      3.0
# TBC     3.0
# AST     2.0
# BRPS    2.0
# EM      2.0
# FF      2.0
# FI      2.0
# ICK     1.0
# WL      1.0
# VLT     1.0
# THA     1.0
# TCV     1.0
# TCK     1.0
# PSH     1.0
# OS      1.0
# OC      1.0
# ADCA    1.0
# IC      1.0
# HCR     1.0
# HB      1.0
# FPB     1.0
# FLW     1.0
# ET      1.0
# EMD     1.0
# EAF     1.0
# BRPR    1.0
# WP      1.0

# %%
print(int(table_1.loc[4, '在库为0（断货数）']), end='; ')
print(str(round(table_1.loc[4, '断货率']*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['断货率'].tolist().index(max(table_1['断货率'])), '层级'], end='; ')
print(str(round(max(table_1['断货率'])*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['干预率'].tolist().index(max(table_1['干预率'])), '层级'], end='; ')
print(str(round(max(table_1['干预率'])*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left), end='; ')
print(sheet_2_right['断货数'].index[0], end='; ')
print(sheet_2_right['断货数'].index[1], end='; ')
print(sheet_2_right['断货数'].index[2], end='; ')
print(int(sheet_2_right.iloc[0, 0]), end='; ')
print(int(sheet_2_right.iloc[1, 0]), end='; ')
print(int(sheet_2_right.iloc[2, 0]))
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left[sheet_2_left['层级']=='TOP1']))
# Out:
# 2758; 5.27%; TOP10; 8.09%; 普通; 13.37%
#
# = = = = = = = = = = = = = = = = = =
#
# 140; CVA; ALT; CA; 17; 16; 14
#
# = = = = = = = = = = = = = = = = = =
#
# 7

# %%
print(int(table_2.loc[4, '在库为0（断货）']), end='; ')
print(int(table_2.loc[4, '断货无在途']), end='; ')
print(str(round(table_2.loc[4, '占比']*100, 2)) + '%', end='; ')
print(int(table_2.loc[4, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[4, '干预无在途']), end='; ')
print(str(round(table_2.loc[4, '占比.1']*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(int(table_2.loc[0, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[0, '干预无在途']))
# Out:
# 2758; 1001; 36.29%; 6626; 2960; 44.67%
#
# = = = = = = = = = = = = = = = = = =
#
# 22; 0

# %%
print('TOP1: ' + str(int(table_3.iloc[0, 8] - table_3.iloc[0, 7])))
print('TOP10: ' + str(int(table_3.iloc[1, 8] - table_3.iloc[1, 7])))
print('TOP20: ' + str(int(table_3.iloc[2, 8] - table_3.iloc[2, 7])))
print('普通: ' + str(int(table_3.iloc[3, 8] - table_3.iloc[3, 7])))
# Out:
# TOP1: -1
# TOP10: 15
# TOP20: 14
# 普通: 201

# %%
print(table_4.loc['TOP1', '品类'], end='; ')
print(table_4.loc['TOP1', '断货SKU数量'])
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 2], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 1], end='; ')
print(str(round(max(table_4['断货占比'][:10])*100, 2)) + '%')
# Out:
# BC; 276
#
# = = = = = = = = = = = = = = = = = =
#
# STR; 398; STR; 71; 17.84%
