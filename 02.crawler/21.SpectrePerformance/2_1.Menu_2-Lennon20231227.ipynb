# %%
import pandas as pd

# %%
df = pd.read_excel('./menu_1.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_url_1 = df['Url'].tolist()

print('总数量：' + str(len(list_url_1)))
list_url_1
# Out:
# 总数量：128
# ['https://www.spectreperformance.com/cross-reference/stp/a5699-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/a6282-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/ca7766-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1119p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1758-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1764-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1765-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1781-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1800c-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf18139-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1813p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1816c-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1820p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1845p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1850p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1869p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1872c-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1873p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1885p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1890p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1897c-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1908p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1911p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1914p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1944p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1947p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/caf1953p-cabin-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/ps10013-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10014-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10110-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10165-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10169-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10171-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10190-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10261-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10262-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10348-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10349-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10465-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10467-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10677-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10881-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10957-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa10989-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa11113-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa11206-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa11257-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa11450-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa3901-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa4309-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa5056-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa5198-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa6479-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa6900-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa7351-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa7421-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa7440-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa7597-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa7620-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8039-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8221-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8243-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8636-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8755-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa8911-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9054-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9055-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9332-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9345-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9360-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9401-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9482-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9492-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9564-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9683-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9687-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9838-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/psa9997-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10013-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10014-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10110-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10165-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10169-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10171-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10190-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10261-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10262-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10348-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10349-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10465-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10467-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10677-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10881-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10957-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa10989-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa11113-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa11206-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa11257-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa11450-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa3901-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa4309-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa5056-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa5198-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa6479-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa6900-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa7351-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa7421-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa7440-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa7597-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa7620-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa8039-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa8221-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa8636-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa8755-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa8911-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9054-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9055-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9332-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9345-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9360-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9401-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9482-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9492-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9564-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9683-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9687-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9838-air-filter',
#  'https://www.spectreperformance.com/cross-reference/stp/sa9997-air-filter']

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests

# %%
i = 0

url_1 = list_url[i]

resp = requests.get(url).text

resp
# Out:
# '<!doctype html>\n<html lang="en">\n<head>\n<script>\n    var LOCALE = \'en\\u002DUS\';\n    var BASE_URL = \'https\\u003A\\u002F\\u002Fwww.spectreperformance.com\\u002F\';\n    var require = {\n        \'baseUrl\': \'https\\u003A\\u002F\\u002Fwww.spectreperformance.com\\u002Fstatic\\u002Fversion1702699708\\u002Ffrontend\\u002Fkn\\u002Ftheme\\u002Dfrontend\\u002Dspectre\\u002Fen_US\'\n    };</script> <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-7b25f93f0651f906972",applicationID:"916197231"};;/*! For license information please see nr-loader-rum-1.249.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>v,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>S,lF:()=>T,Yu:()=>x,Dg:()=>m,CX:()=>c,GE:()=>_,sU:()=>R});var n=r(8632),i=r(9567);const a={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},o={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!o[e])throw new Error("Info for ".concat(e," was never set"));return o[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");o[e]=(0,i.D)(t,a);const r=(0,n.ek)(e);r&&(r.info=o[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",g=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. \'*\' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},h="All configuration objects require an agent identifier!";function v(e){if(!e)throw new Error(h);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function m(e,t){if(!e)throw new Error(h);p[e]=(0,i.D)(t,g());cons ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

with open('./menu_2.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script>
#    var LOCALE = 'en\u002DUS';
#     var BASE_URL = 'https\u003A\u002F\u002Fwww.spectreperformance.com\u002F';
#     var require = {
#         'baseUrl': 'https\u003A\u002F\u002Fwww.spectreperformance.com\u002Fstatic\u002Fversion1702699708\u002Ffrontend\u002Fkn\u002Ftheme\u002Dfrontend\u002Dspectre\u002Fen_US'
#     };
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-7b25f93f0651f906972",applicationID:"916197231"};;/*! For license information please see nr-loader-rum-1.249.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>v,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>S,lF:()=>T,Yu:()=>x,Dg:()=>m,CX:()=>c,GE:()=>_,sU:()=>R});var n=r(8632),i=r(9567);const a={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},o={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!o[e])throw new Error("Info for ".concat(e," was never set"));return o[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");o[e]=(0,i.D)(t,a);const r=(0,n.ek)(e);r&&(r.info=o[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",g=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. '*' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},h="All configuration objects require an agent identifier!";function v(e){if(!e)throw new Error(h);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function m(e,t){if(!e)throw new Error(h);p[e]=(0,i.D)(t,g());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e,t){if(!e)throw new Error(h);var r=v(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const y={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},w={};function A(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!w[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return w[e]}function _(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");w[e]=(0,i.D)(t,y);const r=(0,n.ek)(e);r&&(r.loader_config=w[e])}const x=(0,n.mF)().o;var D=r(385),k=r(6818);const E={buildEnv:k.Re,cus ...
#   </script>
#   <meta content="STP A5699 air filter" name="title"/>
#   <meta content="SPA-2395 Spectre Essential Filter is a across-reference to the STP A5699 Air Filter. Buy a SPA-2395 Spectre Essential Filter here." name="description"/>
#   <meta content="air, filter, air filter, air intake,  air filters, cold air, intake, " name="keywords"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <title>
#    STP A5699 air filter
#   </title>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/mage/calendar.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/css/styles-m.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/Afterpay_Afterpay/css/afterpay-express-checkout.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/Aheadworks_Autorelated/css/main.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/css/styles-l.css" media="screen and (min-width: 768px)" rel="stylesheet" type="text/css"/>
#   <link href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/css/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/requirejs/require.js" type="text/javascript">
#   </script>
#   <script src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/Magento_QuickCheckout/js/disabled.js" type="text/javascript">
#   </script>
#   <script src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/mage/requirejs/mixins.js" type="text/javascript">
#   </script>
#   <script src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/requirejs-config.js" type="text/javascript">
#   </script>
#   <link as="font" crossorigin="anonymous" href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/fonts/opensans/light/opensans-300.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/fonts/opensans/regular/opensans-400.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/fonts/opensans/semibold/opensans-600.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/fonts/opensans/bold/opensans-700.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/fonts/Luma-Icons.woff2" rel="preload"/>
#   <link href="//fonts.googleapis.com/css?family=Montserrat:400,500,700,800,900" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Archivo:400,700" rel="stylesheet"/>
#   <link href="https://media.knfilters.com/prod/media/favicon/stores/68/spectrefav.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://media.knfilters.com/prod/media/favicon/stores/68/spectrefav.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="Mu3vDMT1-8F8drYy_WX5PwlAZrH_p_XLPxkBY_0mTEw" name="google-site-verification"/>
#   <script type="text/x-magento-init">
#    {
#             "*": {
#                 "Magento_PageCache/js/form-key-provider": {
#                     "isPaginationCacheEnabled":
#                         0                }
#             }
#         }
#   </script>
#   <script type="text/x-magento-init">
#    {
#                 "*": {
#                     "Magento_GoogleTagManager/js/google-tag-manager": {
#                         "isCookieRestrictionModeEnabled": 0,
#                         "currentWebsite": 68,
#                         "cookieName": "user_allowed_save_cookie",
#                         "gtmAccountId": "GTM\u002D5ZQWX5F",
#                         "storeCurrencyCode": "USD",
#                         "ordersData": []                    }
#                 }
#             }
#   </script>
#  </head>
#  <body class="csearch-manufacturer-producttype page-layout-1column" data-container="body" data-mage-init='{"loaderAjax": {}, "loader": { "icon": "https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/images/loader-2.gif"}}' id="html-body">
#   <script async="" src="//ui.powerreviews.com/stable/4.1/ui.js">
#   </script>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "lazy-loading": {}
#         }
#     }
#   </script>
#   <script>
#    window.wz_framework = 1;
#         window.wz_magento_store = 'spectreperformance_com USD United States - English';
#   </script>
#   <script async="" src="https://sec.webeyez.com/js/f7a03907-7899-4788-9ec4-3055c016872d/wzbody.js" type="text/javascript">
#   </script>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "Magento_PageBuilder/js/widget-initializer": {
#                 "config": {"[data-content-type=\"slider\"][data-appearance=\"default\"]":{"Magento_PageBuilder\/js\/content-type\/slider\/appearance\/default\/widget":false},"[data-content-type=\"map\"]":{"Magento_PageBuilder\/js\/content-type\/map\/appearance\/default\/widget":false},"[data-content-type=\"row\"]":{"Magento_PageBuilder\/js\/content-type\/row\/appearance\/default\/widget":false},"[data-content-type=\"tabs\"]":{"Magento_PageBuilder\/js\/content-type\/tabs\/appearance\/default\/widget":false},"[data-content-type=\"slide\"]":{"Magento_PageBuilder\/js\/content-type\/slide\/appearance\/default\/widget":{"buttonSelector":".pagebuilder-slide-button","showOverlay":"hover","dataRole":"slide"}},"[data-content-type=\"banner\"]":{"Magento_PageBuilder\/js\/content-type\/banner\/appearance\/default\/widget":{"buttonSelector":".pagebuilder-banner-button","showOverlay":"hover","dataRole":"banner"}},"[data-content-type=\"buttons\"]":{"Magento_PageBuilder\/js\/content-type\/buttons\/appearance\/inline\/widget":false},"[data-content-type=\"products\"][data-appearance=\"carousel\"]":{"Magento_PageBuilder\/js\/content-type\/products\/appearance\/carousel\/widget":false}},
#                 "breakpoints": {"desktop":{"label":"Desktop","stage":true,"default":true,"class":"desktop-switcher","icon":"Magento_PageBuilder::css\/images\/switcher\/switcher-desktop.svg","conditions":{"min-width":"1024px"},"options":{"products":{"default":{"slidesToShow":"5"}}}},"tablet":{"conditions":{"max-width":"1024px","min-width":"768px"},"options":{"products":{"default":{"slidesToShow":"4"},"continuous":{"slidesToShow":"3"}}}},"mobile":{"label":"Mobile","stage":true,"class":"mobile-switcher","icon":"Magento_PageBuilder::css\/images\/switcher\/switcher-mobile.svg","media":"only screen and (max-width: 768px)","conditions":{"max-width":"768px","min-width":"640px"},"options":{"products":{"default":{"slidesToShow":"3"}}}},"mobile-small":{"conditions":{"max-width":"640px"},"options":{"products":{"default":{"slidesToShow":"2"},"continuous":{"slidesToShow":"1"}}}}}            }
#         }
#     }
#   </script>
#   <div class="cookie-status-message" id="cookie-status">
#    The store will not work correctly when cookies are disabled.
#   </div>
#   <script type="text/javascript">
#    document.querySelector("#cookie-status").style.display = "none";
#   </script>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "cookieStatus": {}
#         }
#     }
#   </script>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "mage/cookies": {
#                 "expires": null,
#                 "path": "\u002F",
#                 "domain": ".www.spectreperformance.com",
#                 "secure": true,
#                 "lifetime": "31536000"
#             }
#         }
#     }
#   </script>
#   <noscript>
#    <div class="message global noscript">
#     <div class="content">
#      <p>
#       <strong>
#        JavaScript seems to be disabled in your browser.
#       </strong>
#       <span>
#        For the best experience on our site, be sure to turn on Javascript in your browser.
#       </span>
#      </p>
#     </div>
#    </div>
#   </noscript>
#   <script>
#    require.config({
#         map: {
#             '*': {
#                 wysiwygAdapter: 'mage/adminhtml/wysiwyg/tiny_mce/tinymce5Adapter'
#             }
#         }
#     });
#   </script>
#   <div class="message global cookie" id="notice-cookie-block" role="alertdialog" tabindex="-1">
#    <div class="content" role="document" tabindex="0">
#     <p>
#      <strong>
#       We use cookies to make your experience better.
#      </strong>
#      <span>
#       To comply with the new e-Privacy directive, we need to ask for your consent to set the cookies.
#      </span>
#      <a href="https://www.spectreperformance.com/privacy-policy-cookie-restriction-mode/">
#       Learn more
#      </a>
#      .
#     </p>
#     <div class="actions">
#      <button class="action allow primary" id="btn-cookie-allow">
#       <span>
#        Allow Cookies
#       </span>
#      </button>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var elemf1mNLcL7Array = document.querySelectorAll('div#notice-cookie-block');
#     if(elemf1mNLcL7Array.length !== 'undefined'){
#         elemf1mNLcL7Array.forEach(function(element) {
#             if (element) {
#                 element.style.display = 'none';
#
#             }
#         });
#     }
#   </script>
#   <script type="text/x-magento-init">
#    {
#             "#notice-cookie-block": {
#                 "cookieNotices": {
#                     "cookieAllowButtonSelector": "#btn-cookie-allow",
#                     "cookieName": "user_allowed_save_cookie",
#                     "cookieValue": {"68":1},
#                     "cookieLifetime": 31536000,
#                     "noCookiesUrl": "https\u003A\u002F\u002Fwww.spectreperformance.com\u002Fcookie\u002Findex\u002FnoCookies\u002F"
#                 }
#             }
#         }
#   </script>
#   <script>
#    window.cookiesConfig = window.cookiesConfig || {};
#     window.cookiesConfig.secure = true;
#   </script>
#   <script>
#    require.config({
#         paths: {
#             googleMaps: 'https\u003A\u002F\u002Fmaps.googleapis.com\u002Fmaps\u002Fapi\u002Fjs\u003Fv\u003D3\u0026key\u003D'
#         },
#         config: {
#             'Magento_PageBuilder/js/utils/map': {
#                 style: ''
#             },
#             'Magento_PageBuilder/js/content-type/map/preview': {
#                 apiKey: '',
#                 apiKeyErrorMessage: 'You\u0020must\u0020provide\u0020a\u0020valid\u0020\u003Ca\u0020href\u003D\u0027https\u003A\u002F\u002Fwww.spectreperformance.com\u002Fadminhtml\u002Fsystem_config\u002Fedit\u002Fsection\u002Fcms\u002F\u0023cms_pagebuilder\u0027\u0020target\u003D\u0027_blank\u0027\u003EGoogle\u0020Maps\u0020API\u0020key\u003C\u002Fa\u003E\u0020to\u0020use\u0020a\u0020map.'
#             },
#             'Magento_PageBuilder/js/form/element/map': {
#                 apiKey: '',
#                 apiKeyErrorMessage: 'You\u0020must\u0020provide\u0020a\u0020valid\u0020\u003Ca\u0020href\u003D\u0027https\u003A\u002F\u002Fwww.spectreperformance.com\u002Fadminhtml\u002Fsystem_config\u002Fedit\u002Fsection\u002Fcms\u002F\u0023cms_pagebuilder\u0027\u0020target\u003D\u0027_blank\u0027\u003EGoogle\u0020Maps\u0020API\u0020key\u003C\u002Fa\u003E\u0020to\u0020use\u0020a\u0020map.'
#             },
#         }
#     });
#   </script>
#   <script>
#    require.config({
#         shim: {
#             'Magento_PageBuilder/js/utils/map': {
#                 deps: ['googleMaps']
#             }
#         }
#     });
#   </script>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5ZQWX5F" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "Magento_GoogleTagManager/js/google-tag-manager-cart": {
#                 "blockNames": ["category.products.list","product.info.upsell","catalog.product.related","checkout.cart.crosssell","search_result_list"],
#                 "cookieAddToCart": "add_to_cart",
#                 "cookieRemoveFromCart":
#                     "remove_from_cart",
#                 "advancedAddToCart": "add_to_cart_advanced"
#             }
#         }
#     }
#   </script>
#   <script>
#    window.store_currency_code = 'USD';
#     (function(){
#         'use strict';
#         if(window.store_currency_code == "USD") {
#             var body = document.getElementsByTagName("body")[0];
#             body.classList.add("usd_currency");
#         }
#     })();
#   </script>
#   <div class="widget block block-banners" data-banner-id="361f27e5418423da5ed7fa512fc79a24" data-banner-name="Free Shipping Banner" data-banner-status="Enabled" data-bind="scope: 'banner'" data-display-mode="fixed" data-ids="4" data-rotate="" data-store-id="68" data-types="">
#    <ul class="banner-items" data-bind="afterRender: registerBanner">
#     <!-- ko foreach: getItems361f27e5418423da5ed7fa512fc79a24() -->
#     <li class="banner-item" data-bind="attr: {'data-banner-id': $data.bannerId}">
#      <div class="banner-item-content" data-bind="bindHtml: $data.html">
#      </div>
#     </li>
#     <!-- /ko -->
#    </ul>
#   </div>
#   <script type="text/x-magento-init">
#    {
#         "*": {
#             "Magento_Ui/js/core/app": {
#                 "components": {
#                     "banner": {
#                         "component": "Magento_Banner/js/view/banner"
#                     }
#                 }
#             }
#         }
#     }
#   </script>
#   <div class="widget block block-static-block">
#    <div data-appearance="default" data-content-type="html" data-decoded="true" data-element="main">
#     <p class="banner-text">
#      <span class="banner-toggle">
#       +
#      </span>
#      check
#      <a href="/store-policy">
#       2023 shipping deadlines
#      </a>
#      for holiday packages
#     </p>
#     <div class="holiday-calendar" style="display: none;">
#      <div class="calendar-content">
#       <div class="calendar-tile">
#        <img alt="Holiday Shipping - Home Delivery" src="//res.cloudinary.com/knfilters-com/image/upload/c_lpad,dpr_1.0,f_auto,q_auto/v1638923946/media/cms/holiday/calendar/holiday-home.png"/>
#       </div>
#       <div class="calendar-tile large-tile last">
#        <img alt="Holiday Shipping - 3 Day 2 Day Next Day" src="//res.cloudinary.com/knfilters-com/image/upload/c_lpad,dpr_1.0,f_auto,q_auto/v1638923946/media/cms/holiday/calendar/holiday-3-2-next.png"/>
#       </div>
#      </div>
#      <p class="banner-text disclaimer">
#       * Deliveries are not guaranteed. For questions, please contact our friendly customer service.
#      </p>
#     </div>
#     <script>
#      require(["jquery"], function($){    $(function() {        $(".banner-text .banner-toggle, .banner-text a").click(function() {            if ($(".holiday-calendar").css("display") === "none") {                $(".holiday-calendar").slideDown();                $(".banner-text .banner-toggle").html("x");            }            else {                $(".holiday-calendar").slideUp();                $(".banner-text .banner-toggle").html("+");            }        });    });});
#     </script>
#     <style>
#      .widget.block p.banner-text {    font-size: 1.0em;     line-height: 2.3em;     font-weight: 800;     text-transform: uppercase;     text-align: center;     background-color: #000;     color: #fff;}.widget.block p.banner-text a{    color: #fff;    text-decoration: underline;}.widget.block p.banner-text.disclaimer {    font-size: 0.8em;    text-transform: initial;    padding-top: 10px;    background-color: #000;     color: #fff;} .holiday-calendar {    width: 100%;    display: block;    background-color: #000;    padding: 30px 20px;}.calendar-content {    display: flex;    justify-content: center;}.calendar-tile {    max-width: 350px;    width: 25%;    display: flex;    align-items: center;    padding: 0 40px;    border-right: 2px solid #fff;}.calendar-tile.last { border-right: none; }.calendar-tile.large-tile { width: 100%; max-width: 450px; }@media (max-width: 1023px) {    .widget.block p.banner-text {        font-size: 1em;    }    .widget.block p.banner-text.disclaimer {        font-size: 0.8em;    }    .calendar-content {        flex-wrap: wrap;    }    .calendar-tile {        width: 100%;        padding: 0 20px;        border-right: 0;        margin-bottom: 20px;    }}.block-static-block.widget {    margin-bottom: 0;}
# @media (max-width: 855px) { .calendar-content { justify-content: flex-start; } .calendar-tile { width: 75%; } .calendar-tile.large-tile { max-width: 500px; }}
#     </style>
#    </div>
#   </div>
#   <div class="page-wrapper">
#    <header class="page-header">
#     <div class="box-header-links">
#      <div class="content">
#       <div class="header-links">
#        <li>
#         <a href="https://www.spectreperformance.com/dealersearch/" id="idL8STknUb">
#          Find A Dealer
#         </a>
#        </li>
#        <li>
#         <a href="https://www.spectreperformance.com/contact-us/" id="idt3yTHjqt">
#          Support
#         </a>
#        </li>
#        <li>
#         <a href="https://www.spectreperformance.com/terms-and-conditions/" id="idjKHP0n3u">
#          Promo Terms &amp; Conditions
#         </a>
#        </li>
#       </div>
#      </div>
#     </div>
#     <div class="header content">
#      <div class="primary-links-wrapper">
#       <div class="block block-search">
#        <div class="block block-title">
#         <strong>
#          Search
#         </strong>
#        </div>
#        <div class="block block-content">
#         <form action="https://www.spectreperformance.com/catalogsearch/result/" class="form minisearch" id="search_mini_form" method="get">
#          <div class="field search">
#           <label class="label" data-role="minisearch-label" for="search">
#            <span>
#             Search
#            </span>
#           </label>
#           <div class="control">
#            <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="false" autocomplete="off" class="input-text" data-mage-init='{
#                             "quickSearch": {
#                                 "formSelector": "#search_mini_form",
#                                 "url": "",
#                                 "destinationSelector": "#search_autocomplete",
#                                 "minSearchLength": "3"
#                             }
#                         }' id="search" maxlength="128" name="q" placeholder="Search entire store here..." role="combobox" type="text" value=""/>
#            <div class="search-autocomplete" id="search_autocomplete">
#            </div>
#            <div class="nested">
#             <a class="action advanced" data-action="advanced-search" href="https://www.spectreperformance.com/catalogsearch/advanced/">
#              Advanced Search
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="actions">
#           <button aria-label="Search" class="action search" title="Search" type="submit">
#            <span>
#             Search
#            </span>
#           </button>
#          </div>
#         </form>
#        </div>
#       </div>
#       <span class="action nav-toggle" data-action="toggle-nav">
#        <span>
#         Toggle Nav
#        </span>
#       </span>
#       <div class="nav-sections">
#        <div id="header-menu-mobile">
#         <div class="link-user-account">
#          <div class="link authorization-link">
#           <span class="icon-user">
#           </span>
#           <a href="https://www.spectreperformance.com/customer/account/login/referer/aHR0cHM6Ly93d3cuc3BlY3RyZXBlcmZvcm1hbmNlLmNvbS9jcm9zcy1yZWZlcmVuY2Uvc3RwL2E1Njk5LWFpci1maWx0ZXI~/">
#            Sign In
#           </a>
#          </div>
#         </div>
#         <div class="list-menu">
#          <div class="accordion">
#           <input id="panel-products" name="panel" type="checkbox"/>
#           <label for="panel-products">
#            PRODUCTS
#           </label>
#           <div class="accordion__content">
#            <a href="https://www.spectreperformance.com/air-filters/">
#             <span class="accordion-trigger">
#              Air filters
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cold-air-intake-systems/">
#             <span class="accordion-trigger">
#              Intake Systems
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/air-intake-components/">
#             <span class="accordion-trigger">
#              Intake Components
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/engine-accessories/">
#             <span class="accordion-trigger">
#              Engine Accessories
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/interior-exterior-accessories/">
#             <span class="accordion-trigger">
#              Interior/Exterior Accessories
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/air-filters/filter-cleaner.html/">
#             <span class="accordion-trigger">
#              Air Filter Cleaner
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/exhaust-tips/">
#             <span class="accordion-trigger">
#              Exhaust Tips
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/drivetrain-accessories/">
#             <span class="accordion-trigger">
#              Drivetrain Accessories
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/fuel-system-accessories/">
#             <span class="accordion-trigger">
#              Fuel System Accessories
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/ignition-wiring-accessories/">
#             <span class="accordion-trigger">
#              Ignition - Wiring Accessories
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/cat/cooling-system-accessories/">
#             <span class="accordion-trigger">
#              Cooling System Accessories
#             </span>
#            </a>
#           </div>
#          </div>
#          <a href="https://www.spectreperformance.com/about/">
#           <span class="text-description">
#            About Us
#           </span>
#          </a>
#         </div>
#         <div class="list-more-search">
#          <div class="accordion">
#           <input id="panel-search" name="panel" type="checkbox"/>
#           <label for="panel-search">
#            ADDITIONAL SEARCHES
#           </label>
#           <div class="accordion__content">
#            <a href="/air-filters/search-by-manufacturer">
#             <span class="accordion-trigger">
#              Air filters by vehicle make
#             </span>
#            </a>
#            <a href="/air-intakes/search-by-manufacturer">
#             <span class="accordion-trigger">
#              Air intakes by vehicle make
#             </span>
#            </a>
#            <a href="/dealersearch">
#             <span class="accordion-trigger">
#              Search dealers
#             </span>
#            </a>
#            <a href="/new-products">
#             <span class="accordion-trigger">
#              New products
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="header-bottom">
#          <a href="https://www.spectreperformance.com/dealersearch/">
#           <span class="search-icon search-icon--model icon-brand--map-locate">
#           </span>
#           <span class="text-description">
#            Find A Dealer
#           </span>
#          </a>
#          <a href="https://www.spectreperformance.com/contact-us/">
#           <span class="search-icon">
#            ?
#           </span>
#           <span class="text-description">
#            Support
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="more-searches-menu-wrapper" data-block="more-searches-menu">
#        <button class="action" data-trigger="more-searches-menu" type="button">
#         <span data-bind="i18n: 'More Searches'">
#          More Searches
#         </span>
#        </button>
#       </div>
#       <div class="block block-more-searches-menu" data-mage-init='{
#         "dropdownDialog": {
#             "appendTo": "[data-block=more-searches-menu]",
#             "triggerTarget":"[data-trigger=more-searches-menu]",
#             "timeout": 2000,
#             "closeOnMouseLeave": false,
#             "closeOnEscape": true,
#             "autoOpen": false,
#             "triggerClass": "active",
#             "parentClass": "active",
#             "buttons": []
#         }
#     }' style="display: none;">
#        <div class="more-searches-menu-content-wrapper">
#         <div class="accordion">
#          <input id="panel-search" name="panel" type="checkbox"/>
#          <label for="panel-search">
#           ADDITIONAL SEARCHES
#          </label>
#          <div class="accordion__content">
#           <a href="/air-filters/search-by-manufacturer">
#            <span class="accordion-trigger">
#             Air filters by vehicle make
#            </span>
#           </a>
#           <a href="/air-intakes/search-by-manufacturer">
#            <span class="accordion-trigger">
#             Air intakes by vehicle make
#            </span>
#           </a>
#           <a href="/dealersearch">
#            <span class="accordion-trigger">
#             Search dealers
#            </span>
#           </a>
#           <a href="/new-products">
#            <span class="accordion-trigger">
#             New products
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <span class="action nav-toggle" data-action="toggle-nav">
#       <span>
#        Toggle Nav
#       </span>
#      </span>
#      <a aria-label="store logo" class="logo" href="https://www.spectreperformance.com/" title="">
#       <img alt="" src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/images/logo.svg" title="" width="170"/>
#      </a>
#      <div class="secondary-links-wrapper">
#       <div class="panel wrapper">
#        <div class="panel header">
#         <a class="action skip contentarea" href="#contentarea">
#          <span>
#           Skip to Content
#          </span>
#         </a>
#         <ul class="header links">
#          <li class="greet welcome" data-bind="scope: 'customer'">
#           <!-- ko if: customer().fullname  -->
#           <span class="logged-in" data-bind="text: new String('Welcome, %1!').
#               replace('%1', customer().fullname)">
#           </span>
#           <!-- /ko -->
#           <!-- ko ifnot: customer().fullname  -->
#           <span class="not-logged-in" data-bind="text: 'Welcome'">
#           </span>
#           <!-- /ko -->
#          </li>
#          <script type="text/x-magento-init">
#           {
#             "*": {
#                 "Magento_Ui/js/core/app": {
#                     "components": {
#                         "customer": {
#                             "component": "Magento_Customer/js/view/customer"
#                         }
#                     }
#                 }
#             }
#         }
#          </script>
#          <li class="link authorization-link" data-label="or">
#           <a href="https://www.spectreperformance.com/customer/account/login/referer/aHR0cHM6Ly93d3cuc3BlY3RyZXBlcmZvcm1hbmNlLmNvbS9jcm9zcy1yZWZlcmVuY2Uvc3RwL2E1Njk5LWFpci1maWx0ZXI~/">
#            Sign In
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <button class="action btn-language" data-trigger="localize-modal" type="button">
#        <span data-bind="i18n: 'Change language'">
#        </span>
#       </button>
#       <div data-bind="mageInit: {
#             'Magento_Ui/js/modal/modal':{
#                 'type': 'popup',
#                 'trigger': '[data-trigger=localize-modal]',
#                 'responsive': true,
#                 'buttons': []
#             }
#         }" style="display: none">
#        <div class="localize-modal__content">
#        </div>
#       </div>
#       <script type="text/x-magento-init">
#        {
#         "*": {
#             "KN_WebsiteStoreCreatorFrontendUi/js/topmenu": {
#             }
#         }
#     }
#       </script>
#       <script>
#        let languageSites = [],
#             groups = [],
#             groupMapping = [];
#
#         require([
#             'jquery'
#         ], function ($) {
#             $(function(){
#                 let switcherLanguage = $('.select-language').on('change', function() {
#                     location.href = languageSites[switcherLanguage.val()] || languageSites.en_US;
#                 });
#
#                 let switcherCountry = $('.switcher-language .dropdown.switcher-dropdown'),
#                     allCountries = switcherCountry.find('li');
#
#                 if (allCountries.length === 0) {
#                     $('.modal-country-section').hide();
#                     return;
#                 }
#                 if (allCountries.length < 15) {
#                     return;
#                 }
#                 let unitedStatesLang = switcherCountry.find('li:contains("United States")'),
#                     columns = 2,
#                     columnElements = [],
#                     currentColumn = 0;
#
#                 for (let i = 0; i < columns; i++) {
#                     let colEl = $('<div />').addClass('column').appendTo(switcherCountry);
#                     columnElements.push(colEl);
#                 }
#
#                 for (let i = 0; i < groups.length; i++) {
#                     let group = groups[i],
#                         groupEl = $('<div />').addClass('group'),
#                         groupTitle = $('<h3 />').text(group.name).appendTo(groupEl),
#                         groupContent = $('<ul />').appendTo(groupEl);
#
#                     if (i === groups.length - 1) {
#                         let remainingItems = switcherCountry.find('>li');
#                         if (remainingItems.length) {
#                             remainingItems.appendTo(groupContent);
#                         }
#                     } else {
#                         allCountries.each(function(i, item) {
#                             let groupId = groupMapping[$(this).text().trim()];
#                             if (group.id === groupId) {
#                                 $(this).appendTo(groupContent);
#                             }
#                         });
#                     }
#                     groupTitle.on('click', function() {
#                         const h3 = $(this);
#                         const wasOpen = h3.parent().hasClass('open');
#                         switcherCountry.find('.open').removeClass('open');
#                         if (!wasOpen) {
#                             h3.parent().addClass('open');
#                         }
#                     });
#                     if (groupContent.children().length) {
#                         groupEl.appendTo(columnElements[currentColumn]);
#                         currentColumn += 1;
#                         if (currentColumn + 1 > columns) {
#                             currentColumn = 0;
#                         }
#                     }
#                 }
#                 let currentCountry = $('.current-country:first').text();
#                 $( ".switcher-option a:contains('"+currentCountry+"')").closest("div.group").addClass("open");
#             });
#         });
#       </script>
#       <div class="minicart-wrapper" data-block="minicart">
#        <a class="action showcart" data-bind="scope: 'minicart_content'" href="https://www.spectreperformance.com/checkout/cart/">
#         <span class="text">
#          My Cart
#         </span>
#         <span class="counter qty empty" data-bind="css: { empty: !!getCartParam('summary_count') == false &amp;&amp; !isLoading() },
#                blockLoader: isLoading">
#          <span class="counter-number">
#           <!-- ko if: getCartParam('summary_count') -->
#           <!-- ko text: getCartParam('summary_count').toLocaleString(window.LOCALE) -->
#           <!-- /ko -->
#           <!-- /ko -->
#          </span>
#          <span class="counter-label">
#           <!-- ko if: getCartParam('summary_count') -->
#           <!-- ko text: getCartParam('summary_count').toLocaleString(window.LOCALE) -->
#           <!-- /ko -->
#           <!-- ko i18n: 'items' -->
#           <!-- /ko -->
#           <!-- /ko -->
#          </span>
#         </span>
#        </a>
#        <div class="block block-minicart" data-mage-init='{"dropdownDialog":{
#                 "appendTo":"[data-block=minicart]",
#                 "triggerTarget":".showcart",
#                 "timeout": "2000",
#                 "closeOnMouseLeave": false,
#                 "closeOnEscape": true,
#                 "triggerClass":"active",
#                 "parentClass":"active",
#                 "buttons":[]}}' data-role="dropdownDialog">
#         <div data-bind="scope: 'minicart_content'" id="minicart-content-wrapper">
#          <!-- ko template: getTemplate() -->
#          <!-- /ko -->
#         </div>
#        </div>
#        <script>
#         window.checkout = {"shoppingCartUrl":"https:\/\/www.spectreperformance.com\/checkout\/cart\/","checkoutUrl":"https:\/\/www.spectreperformance.com\/checkout\/","updateItemQtyUrl":"https:\/\/www.spectreperformance.com\/checkout\/sidebar\/updateItemQty\/","removeItemUrl":"https:\/\/www.spectreperformance.com\/checkout\/sidebar\/removeItem\/","imageTemplate":"Magento_Catalog\/product\/image_with_borders","baseUrl":"https:\/\/www.spectreperformance.com\/","minicartMaxItemsVisible":5,"websiteId":"68","maxItemsToDisplay":10,"storeId":"68","storeGroupId":"68","customerLoginUrl":"https:\/\/www.spectreperformance.com\/customer\/account\/login\/referer\/aHR0cHM6Ly93d3cuc3BlY3RyZXBlcmZvcm1hbmNlLmNvbS9jcm9zcy1yZWZlcmVuY2Uvc3RwL2E1Njk5LWFpci1maWx0ZXI~\/","isRedirectRequired":false,"autocomplete":"off","captcha":{"user_login":{"isCaseSensitive":false,"imageHeight":50,"imageSrc":"","refreshUrl":"https:\/\/www.spectreperformance.com\/captcha\/refresh\/","isRequired":false,"timestamp":1703641253}}}
#        </script>
#        <script type="text/x-magento-init">
#         {
#         "[data-block='minicart']": {
#             "Magento_Ui/js/core/app": {"components":{"minicart_content":{"children":{"subtotal.container":{"children":{"subtotal":{"children":{"subtotal.totals":{"config":{"display_cart_subtotal_incl_tax":0,"display_cart_subtotal_excl_tax":1,"template":"Magento_Tax\/checkout\/minicart\/subtotal\/totals"},"component":"Magento_Tax\/js\/view\/checkout\/minicart\/subtotal\/totals","children":{"subtotal.totals.msrp":{"component":"Magento_Msrp\/js\/view\/checkout\/minicart\/subtotal\/totals","config":{"displayArea":"minicart-subtotal-hidden","template":"Magento_Msrp\/checkout\/minicart\/subtotal\/totals"}}}}},"component":"uiComponent","config":{"template":"Magento_Checkout\/minicart\/subtotal"}}},"component":"uiComponent","config":{"displayArea":"subtotalContainer"}},"item.renderer":{"component":"Magento_Checkout\/js\/view\/cart-item-renderer","config":{"displayArea":"defaultRenderer","template":"Magento_Checkout\/minicart\/item\/default"},"children":{"item.image":{"component":"Magento_Catalog\/js\/view\/image","config":{"template":"Magento_Catalog\/product\/image","displayArea":"itemImage"}},"checkout.cart.item.price.sidebar":{"component":"uiComponent","config":{"template":"Magento_Checkout\/minicart\/item\/price","displayArea":"priceSidebar"}}}},"extra_info":{"children":{"afterpay.cta":{"component":"afterpayCta","template":"Afterpay_Afterpay\/cta\/cta","sortOrder":"0","config":{"id":"afterpay-cta-mini-cart","modelContainerId":"afterpay-mini-cart-container"},"children":{"afterpay.cta.mini.cart.data.retriever":{"component":"Afterpay_Afterpay\/js\/service\/container\/cart\/mini-cart-data-retriever","config":{"modelContainerId":"afterpay-mini-cart-container"}}}},"afterpay.express.checkout":{"component":"afterpayExpressCheckoutButton","template":"Afterpay_Afterpay\/express-checkout\/button-minicart","sortOrder":"1","config":{"entryPoint":"mini-cart","modelContainerId":"afterpay-mini-cart-container"},"children":{"afterpay.express.checkout.mini.cart.data.retriever":{"component":"Afterpay_Afterpay\/js\/service\/container\/cart\/mini-cart-data-retriever","config":{"modelContainerId":"afterpay-mini-cart-container"}}}}},"component":"uiComponent","config":{"displayArea":"extraInfo"}},"promotion":{"component":"uiComponent","config":{"displayArea":"promotion"}}},"config":{"itemRenderer":{"default":"defaultRenderer","simple":"defaultRenderer","virtual":"defaultRenderer"},"template":"Magento_Checkout\/minicart\/content"},"component":"Magento_Checkout\/js\/view\/minicart"}},"types":[]}        },
#         "*": {
#             "Magento_Ui/js/block-loader": "https\u003A\u002F\u002Fwww.spectreperformance.com\u002Fstatic\u002Fversion1702699708\u002Ffrontend\u002Fkn\u002Ftheme\u002Dfrontend\u002Dspectre\u002Fen_US\u002Fimages\u002Floader\u002D1.gif"
#         }
#     }
#        </script>
#       </div>
#      </div>
#      <script type="text/javascript">
#       (function(a,b,c,d){
#             a='https://www.mczbf.com/tags/12323/tag.js?cookieUrl=https%3A%2F%2Fwww.spectreperformance.com%2Fcookie%2Findex%2Findex';
#             b=document;c='script';d=b.createElement(c);d.src=a;
#             d.type='text/java'+c;d.async=true;
#             d.id='cjapitag';
#             a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a)
#         })();
#      </script>
#     </div>
#     <script async="" src="https://static.klaviyo.com/onsite/js/klaviyo.js?company_id=XKFdhe" type="application/javascript">
#     </script>
#     <script type="text/x-magento-init">
#      {
#             "*": {
#                 "KlaviyoCustomerData": {}
#             }
#         }
#     </script>
#     <div class="header-products">
#      <div class="content">
#       <div class="accordion">
#        <input id="panel-products" name="panel" type="checkbox"/>
#        <label for="panel-products">
#         PRODUCTS
#        </label>
#        <div class="accordion__content">
#         <a href="https://www.spectreperformance.com/air-filters/">
#          <span class="accordion-trigger">
#           Air filters
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cold-air-intake-systems/">
#          <span class="accordion-trigger">
#           Intake Systems
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/air-intake-components/">
#          <span class="accordion-trigger">
#           Intake Components
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/engine-accessories/">
#          <span class="accordion-trigger">
#           Engine Accessories
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/interior-exterior-accessories/">
#          <span class="accordion-trigger">
#           Interior/Exterior Accessories
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/air-filters/filter-cleaner.html/">
#          <span class="accordion-trigger">
#           Air Filter Cleaner
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/exhaust-tips/">
#          <span class="accordion-trigger">
#           Exhaust Tips
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/drivetrain-accessories/">
#          <span class="accordion-trigger">
#           Drivetrain Accessories
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/fuel-system-accessories/">
#          <span class="accordion-trigger">
#           Fuel System Accessories
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/ignition-wiring-accessories/">
#          <span class="accordion-trigger">
#           Ignition - Wiring Accessories
#          </span>
#         </a>
#         <a href="https://www.spectreperformance.com/cat/cooling-system-accessories/">
#          <span class="accordion-trigger">
#           Cooling System Accessories
#          </span>
#         </a>
#        </div>
#       </div>
#       <li>
#        <a href="https://www.spectreperformance.com/about/" id="idW7raJlpQ">
#         About Us
#        </a>
#       </li>
#      </div>
#     </div>
#    </header>
#    <script>
#     require([
#         'jquery'
#     ], function ($) {
#         $( function(){
#
#         $('.nav-toggle').on('click', function(){
#             let html = $('html');
#             if (html.hasClass('nav-open')) {
#                     html.removeClass('nav-open');
#                     setTimeout(function () {
#                         html.removeClass('nav-before-open');
#                         }, 100);
#                 } else {
#                     html.addClass('nav-before-open');
#                     setTimeout(function () {
#                         html.addClass('nav-open');
#                     }, 100);
#                 }
#             });
#
#             function positionCountrySwitcher() {
#                 let winWidth = window.outerWidth;
#                 if(winWidth < 768) {
#                     let elm = $('.navigation-block__footer #mobile-country-switcher');
#                     if(elm.length > 0) {
#                         elm.insertBefore($('.page-footer .footer__links').eq(0));
#                     }
#                 }
#                 else {
#                     let footerElm = $('.page-footer  #mobile-country-switcher');
#                     if(footerElm.length > 0) {
#                         footerElm.insertBefore($('.navigation-block__footer ul'));
#                     }
#                 }
#             }
#
#             positionCountrySwitcher();
#             $(window).resize(function(){
#                 positionCountrySwitcher();
#             });
#
#         });
#     });
#    </script>
#    <main class="page-main" id="maincontent">
#     <a id="contentarea" tabindex="-1">
#     </a>
#     <div class="columns">
#      <div class="column main">
#       <div class="breadcrumbs">
#        <ul class="items">
#         <li class="item">
#          <a href="https://www.spectreperformance.com/cross-reference">
#           <span>
#            cross-reference
#           </span>
#          </a>
#         </li>
#         <li class="item">
#          <a href="https://www.spectreperformance.com/cross-reference/stp">
#           <span>
#            STP
#           </span>
#          </a>
#         </li>
#         <li class="item">
#          <a href="https://www.spectreperformance.com/cross-reference/STP/a5699-air-filter">
#           <span>
#            A5699 Air Filter
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="page messages">
#        <div data-placeholder="messages">
#        </div>
#        <div data-bind="scope: 'messages'">
#         <!-- ko if: cookieMessages && cookieMessages.length > 0 -->
#         <div aria-atomic="true" class="messages" data-bind="foreach: { data: cookieMessages, as: 'message' }" role="alert">
#          <div data-bind="attr: {
# ...
#                  <option value="">
#                  </option>
#                 </select>
#                </div>
#                <input class="action primary btn btn__find-parts btn-mobile btn-vehicle-search" disabled="disabled" type="submit" value="Search"/>
#               </div>
#              </fieldset>
#             </form>
#             <script type="text/javascript">
#              requirejs(['jquery'], function($){
#     $(function(){
#         $('.search-by-vehicle--mobile').on('chosen:showing_dropdown', '.form-field select', function() {
#             const element = $(this)
#             const id = element.attr('id')
#             $('.search-by-vehicle--mobile > .form-field select').each(function() {
#                 $(this).next().removeClass('chosen-with-drop')
#             });
#             element.next().addClass('chosen-with-drop')
#         })
#     });
# });
#             </script>
#            </div>
#            <div class="accordion-trigger dimension-trigger" data-role="collapsible">
#             <span>
#              Search By Dimension
#             </span>
#            </div>
#            <div class="accordion-content" data-role="content" style="display: none;">
#            </div>
#           </div>
#          </div>
#         </div>
#         <script type="text/x-magento-init">
#          {
#         "*": {
#             "KN_VehicleSearchFrontendUi/js/vehicle-search": {
#                 "vehicleYears": ["2024","2023","2022","2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007","2006","2005","2004","2003","2002","2001","2000","1999","1998","1997","1996","1995","1994","1993","1992","1991","1990","1989","1988","1987","1986","1985","1984","1983","1982","1981","1980","1979","1978","1977","1976","1975","1974","1973","1972","1971","1970","1969","1968","1967","1966","1965","1964","1963","1962","1961","1960","1959","1958","1957","1956","1955","1954","1953","1952","1950","0"],
#                 "vehicleAutomotiveYears": ["2024","2023","2022","2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007","2006","2005","2004","2003","2002","2001","2000","1999","1998","1997","1996","1995","1994","1993","1992","1991","1990","1989","1988","1987","1986","1985","1984","1983","1982","1981","1980","1979","1978","1977","1976","1975","1974","1973","1972","1971","1970","1969","1968","1967","1966","1965","1964","1963","1962","1961","1960","1959","1958","1957","1956","1955","1954","1953","1952","1950","0"],
#                 "vehicletMotorcycleYears": ["2014"],
#                 "vehicleSpecialtyYears": ["2010","2009","2007","2006","2004","2003","2002","2001","2000","1999","1998","1997","1995","1994","1993","1992","1991","1990","1989","1988","1987","1986","1985","1984","1983","1982","1981","1980","1979","1978","1977","1976","1975","1974","1973","1972","1971","1970","1969","1968","1967","1966","1965","1964","1963"],
#                 "shipToNumber": "81515.1.0005",
#                 "ajaxBaseURL": "https://www.spectreperformance.com/",
#                 "dimensionSearchURL" : "https://www.spectreperformance.com/dimsearch/index/",
#                 "isDimensionSearch": "false"
#             }
#         }
#     }
#         </script>
#        </div>
#        <div class="vehicle-compatibility-content no-display">
#         <div class="vehicle-incompatible icon-remove">
#          The item you added to cart DOES NOT FIT your
#         </div>
#         <div class="vehicle-compatible icon-checkmark no-display">
#          This item fits your
#         </div>
#         <strong>
#         </strong>
#         <h4>
#          The item(s) below fits your vehicle
#         </h4>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#    <footer class="page-footer">
#     <div class="footer content">
#      <div class="footer-links" id="footer_acoordion">
#       <div>
#        <div data-role="collapsible">
#         <div data-role="trigger">
#          <span class="title">
#           Support
#          </span>
#         </div>
#        </div>
#        <div data-role="content">
#         <div class="accordion">
#          <input id="panel-support" name="panel" type="checkbox"/>
#          <label for="panel-support">
#           SUPPORT
#          </label>
#          <div class="accordion__content">
#           <a href="/contact-us">
#            <span class="accordion-trigger">
#             Contact Customer Service
#            </span>
#           </a>
#           <a href="/sales/order/history">
#            <span class="accordion-trigger">
#             Order Status
#            </span>
#           </a>
#           <a href="/warranty">
#            <span class="accordion-trigger">
#             Warranty &amp; Registration
#            </span>
#           </a>
#           <a href="/store-policy">
#            <span class="accordion-trigger">
#             Shipping &amp; Returns
#            </span>
#           </a>
#           <a href="/faq">
#            <span class="accordion-trigger">
#             FAQs
#            </span>
#           </a>
#           <a href="/vehicles/need">
#            <span class="accordion-trigger">
#             Let Spectre Borrow Your Vehicle!
#            </span>
#           </a>
#           <a href="https://res.cloudinary.com/knfilters-com/image/upload/c_lpad,dpr_1.0,f_auto,q_auto/v1603294407/media/cms/pdf/eodecalform_ct2ffu.pdf" target="_blank">
#            <span class="accordion-trigger">
#             Replacement CARB EO Decal Request Form for Air Intakes
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div data-role="collapsible">
#         <div data-role="trigger">
#          <span class="title">
#           About Us
#          </span>
#         </div>
#        </div>
#        <div data-role="content">
#         <div data-appearance="default" data-content-type="html" data-decoded="true" data-element="main">
#          <div class="accordion">
#           <input id="panel-about" name="panel" type="checkbox"/>
#           <label for="panel-about">
#            ABOUT SPECTRE
#           </label>
#           <div class="accordion__content">
#            <a href="https://www.spectreperformance.com/about/">
#             <span class="accordion-trigger">
#              About Spectre Performance
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/accessibility/">
#             <span class="accordion-trigger">
#              Accessibility
#             </span>
#            </a>
#            <a href="/events">
#             <span class="accordion-trigger">
#              events
#             </span>
#            </a>
#            <a href="https://www.spectreperformance.com/blog/">
#             <span class="accordion-trigger">
#              blog
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div data-role="collapsible">
#         <div data-role="trigger">
#          <span class="title">
#           Products
#          </span>
#         </div>
#        </div>
#        <div data-role="content">
#         <div class="accordion">
#          <input id="panel-products" name="panel" type="checkbox"/>
#          <label for="panel-products">
#           PRODUCTS
#          </label>
#          <div class="accordion__content">
#           <a href="https://www.spectreperformance.com/air-filters/">
#            <span class="accordion-trigger">
#             Air filters
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cold-air-intake-systems/">
#            <span class="accordion-trigger">
#             Intake Systems
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/air-intake-components/">
#            <span class="accordion-trigger">
#             Intake Components
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/engine-accessories/">
#            <span class="accordion-trigger">
#             Engine Accessories
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/interior-exterior-accessories/">
#            <span class="accordion-trigger">
#             Interior/Exterior Accessories
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/air-filters/filter-cleaner.html/">
#            <span class="accordion-trigger">
#             Air Filter Cleaner
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/exhaust-tips/">
#            <span class="accordion-trigger">
#             Exhaust Tips
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/drivetrain-accessories/">
#            <span class="accordion-trigger">
#             Drivetrain Accessories
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/fuel-system-accessories/">
#            <span class="accordion-trigger">
#             Fuel System Accessories
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/ignition-wiring-accessories/">
#            <span class="accordion-trigger">
#             Ignition - Wiring Accessories
#            </span>
#           </a>
#           <a href="https://www.spectreperformance.com/cat/cooling-system-accessories/">
#            <span class="accordion-trigger">
#             Cooling System Accessories
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div data-role="collapsible">
#         <div data-role="trigger">
#          <span class="title">
#           Additional Searches
#          </span>
#         </div>
#        </div>
#        <div data-role="content">
#         <div class="accordion">
#          <input id="panel-search" name="panel" type="checkbox"/>
#          <label for="panel-search">
#           ADDITIONAL SEARCHES
#          </label>
#          <div class="accordion__content">
#           <a href="/air-filters/search-by-manufacturer">
#            <span class="accordion-trigger">
#             Air filters by vehicle make
#            </span>
#           </a>
#           <a href="/air-intakes/search-by-manufacturer">
#            <span class="accordion-trigger">
#             Air intakes by vehicle make
#            </span>
#           </a>
#           <a href="/dealersearch">
#            <span class="accordion-trigger">
#             Search dealers
#            </span>
#           </a>
#           <a href="/new-products">
#            <span class="accordion-trigger">
#             New products
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#        <ul id="social-icons">
#         <li>
#          <a class="social-icon icon-brand--facebook" href="https://www.facebook.com/spectreperformance" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="social-icon icon-brand--twitter" href="https://twitter.com/speedbyspectre" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="social-icon icon-brand--instagram" href="https://instagram.com/spectreperformance/" target="_blank">
#          </a>
#         </li>
#         <li>
#          <a class="social-icon icon-brand--youtube" href="https://www.youtube.com/user/spectreperformance" target="_blank">
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <script>
#       require([
#         'jquery',
#         'accordion',
#     ], function ($) {
#         if ($(window).width() <= 820) {
#             $("#footer_acoordion").accordion();
#         }
#     });
#      </script>
#     </div>
#    </footer>
#    <div class="box-copyright">
#     <div class="content">
#      <div class="copyright__branding">
#       <div class="copyright__logos">
#        <img alt="Brand Logo" class="copyright__logo-spectre" src="https://www.spectreperformance.com/static/version1702699708/frontend/kn/theme-frontend-spectre/en_US/images/logo.svg"/>
#       </div>
#      </div>
#      <small class="copyright">
#       <span>
#        Copyright © 2023 Spectre Performance. All Rights Reserved.
#       </span>
#      </small>
#      <span class="supply-chains">
#       <a href="/ca-trans">
#        California Transparency in Supply Chains Act
#       </a>
#      </span>
#      <a class="copyright-link copyright-privacy-link" href="/privacy">
#       Privacy Policy
#      </a>
#      <a class="copyright-link copyright-terms-link" href="/terms">
#       Terms of Use
#      </a>
#     </div>
#    </div>
#    <script type="text/x-magento-init">
#     {
#             "*": {
#                 "Magento_Ui/js/core/app": {
#                     "components": {
#                         "storage-manager": {
#                             "component": "Magento_Catalog/js/storage-manager",
#                             "appendTo": "",
#                             "storagesConfiguration" : {"recently_viewed_product":{"requestConfig":{"syncUrl":"https:\/\/www.spectreperformance.com\/catalog\/product\/frontend_action_synchronize\/"},"lifetime":"1000","allowToSendRequest":null},"recently_compared_product":{"requestConfig":{"syncUrl":"https:\/\/www.spectreperformance.com\/catalog\/product\/frontend_action_synchronize\/"},"lifetime":"1000","allowToSendRequest":null},"product_data_storage":{"updateRequestConfig":{"url":"https:\/\/www.spectreperformance.com\/rest\/store_81515_1_0005\/V1\/products-render-info"},"requestConfig":{"syncUrl":"https:\/\/www.spectreperformance.com\/catalog\/product\/frontend_action_synchronize\/"},"allowToSendRequest":null}}                        }
#                     }
#                 }
#             }
#         }
#    </script>
#    <div id="attentiveMagentoPage" style="display: none;">
#    </div>
#    <script type="text/x-magento-init">
#     {"*": {"cloudinaryLazyload": {"threshold":500,"effect":"fadeIn","placeholder":"blur"}}}
#    </script>
#    <script type="application/ld+json">
#     {"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.spectreperformance.com\/","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.spectreperformance.com\/catalogsearch\/result\/?q={search_term_string}","query-input":"required name=search_term_string"}}
#    </script>
#   </div>
#   <script type="text/x-magento-init">
#    {
#     "*": {
#         "KN_RedirectPopupFrontendUi/js/redirect-popup": {}
#     }
# }
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-7b25f93f0651f906972","applicationID":"916197231,916199710","transactionName":"Z1YBMkRZDREEARBfXV4cNhRfFwoMAQccGEJYQw==","queueTime":0,"applicationTime":407,"atts":"SxEWRAxDHk5HA0YMSU1O","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'83bde73bdc629e70',t:'MTcwMzY0MTcyNy4zNjQwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"83bde73bdc629e70","b":1,"version":"2023.10.0","token":"c8227eacfee94a9193900059536c0fd7"}' defer="" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317">
#   </script>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

url = html.xpath('//a[@class="product-info__product-name"]/@href')[0].strip()

# %%
df_temp = pd.DataFrame([{'status': 'ok',
                         'Url_1': url_1,
                         'Url': url,
                         'No.': ''}])

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status                                              Url_1  \
# 0     ok  https://www.spectreperformance.com/cross-refer...
#
#                                                Url_2
# 0  https://www.spectreperformance.com/catalog/pro...
