# %%
import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration_oversea import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# %%
list_series_error, df_input = [], pd.read_excel('./file/1.page.xlsx',
                                                header=0,
                                                dtype=str).fillna('')

df_input['No'] = df_input['No'].astype(int)
df_input['SKU Count'] = df_input['SKU Count'].astype(int)
df_input['Page'] = df_input['Page'].astype(int)

count_remain = len(df_input)

print(f'总数量：{count_remain}')
print()
df_input
# Out:
# 总数量：2
#    No                                                Url  SKU Count  Page
# 0   1  https://toyota.oempartsonline.com/search?searc...       1183    66
# 1   2  https://nissan.oempartsonline.com/search?searc...       1376    77

# %%
(crawler_index, crawler_series) = next(df_input.iterrows())

crawler_index, crawler_series
# Out:
# (0,
#  No                                                           1
#  Url          https://toyota.oempartsonline.com/search?searc...
#  SKU Count                                                 1183
#  Page                                                        66
#  Name: 0, dtype: object)

# %%
import time

list_url = []
for count_cycle in range(5):

    for page in range(crawler_series['Page']):

        count_retry = 0
        while True:
            count_retry += 1
            print(count_cycle, page + 1, count_retry)
            try:
                url_request = f'''{crawler_series['Url']}&page={page}'''

                resp = requests.get(url_request,
                                    headers=get_header(),
                                    proxies=get_proxy(),
                                    timeout=(5, 15))

                if resp.status_code == 200:
                    soup = BeautifulSoup(resp.text, 'lxml')
                    html = etree.HTML(str(soup))

                    list_href = html.xpath('//div[@class="catalog-product marketplace-product row"]/div[@class="product-details-col col-md-10 row"]/div[@class="col-xs-12 col-md-8"]/div[@class="product-partnum-category"]/div[@class="catalog-product-id"]/a/@href') + html.xpath('//div[@class="catalog-product row"]/div[@class="product-details-col col-xs-7"]/div[@class="product-partnum-category"]/div[@class="catalog-product-id"]/a/@href')
                    if list_href:
                        if count_cycle == 0 and page == 0:
                            with open('./url.html', 'w', encoding='UTF-8') as file:
                                file.write(str(soup))
                        break
            except KeyboardInterrupt:
                break
            except:
                time.sleep(3)
                continue

        # = = = = = = = = = = = = = = =

        if 'toyota.oempartsonline.com/' in url_request:
            list_href = [f'https://toyota.oempartsonline.com{href.split('?')[0].strip()}' for href in list_href]
        elif 'nissan.oempartsonline.com/' in url_request:
            list_href = [f'https://nissan.oempartsonline.com{href.split('?')[0].strip()}' for href in list_href]
        elif 'www.hondapartsonline.net/' in url_request:
            list_href = [f'https://www.hondapartsonline.net{href.split('?')[0].strip()}' for href in list_href]
        elif 'www.kiaparts.com/' in url_request:
            list_href = [f'https://www.kiaparts.com{href.split('?')[0].strip()}' for href in list_href]
        elif 'www.hyundaioempartsdirect.com/' in url_request:
            list_href = [f'https://www.hyundaioempartsdirect.com{href.split('?')[0].strip()}' for href in list_href]
        else:
            print('fuck')
        list_url.extend(list_href)
        list_url = list(dict.fromkeys(list_url))

        # = = = = = = = = = = = = = = =

        print(f' - {len(list_url)}/{crawler_series['SKU Count']}')

        # = = = = = = = = = = = = = = =

        if len(list_url) == crawler_series['SKU Count']:
            break

list_url
# Out:
# 0 1 1
#  - 18/1183
# 0 2 1
#  - 18/1183
# 0 3 1
#  - 36/1183
# 0 4 1
#  - 54/1183
# 0 5 1
#  - 72/1183
# 0 6 1
#  - 90/1183
# 0 7 1
#  - 108/1183
# 0 8 1
#  - 126/1183
# 0 9 1
#  - 144/1183
# 0 10 1
#  - 162/1183
# 0 11 1
#  - 180/1183
# 0 12 1
#  - 198/1183
# 0 13 1
#  - 216/1183
# 0 14 1
#  - 234/1183
# 0 15 1
#  - 252/1183
# 0 16 1
#  - 270/1183
# 0 17 1
# 0 17 2
#  - 288/1183
# 0 18 1
#  - 306/1183
# 0 19 1
#  - 324/1183
# 0 20 1
#  - 342/1183
# 0 21 1
#  - 360/1183
# 0 22 1
#  - 378/1183
# 0 23 1
#  - 396/1183
# 0 24 1
#  - 414/1183
# 0 25 1
#  - 432/1183
# 0 26 1
#  - 450/1183
# 0 27 1
#  - 450/1183
# 0 28 1
#  - 450/1183
# 0 29 1
#  - 450/1183
# 0 30 1
#  - 450/1183
# 0 31 1
#  - 450/1183
# 0 32 1
#  - 450/1183
# 0 33 1
#  - 450/1183
# 0 34 1
#  - 450/1183
# 0 35 1
#  - 450/1183
# 0 36 1
#  - 450/1183
# 0 37 1
#  - 450/1183
# 0 38 1
#  - 450/1183
# 0 39 1
#  - 450/1183
# 0 40 1
# 0 40 2
#  - 450/1183
# 0 41 1
#  - 450/1183
# 0 42 1
#  - 450/1183
# 0 43 1
#  - 450/1183
# ...

# %%
list_url
# Out:
# ['https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178050p050',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178800p230',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178930h010',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178930p100',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178930v010',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-1789318010',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-1789362070',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-1789428130',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-5329560010',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-178050p010',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-17881waa01',
#  'https://toyota.oempartsonline.com/oem-parts/toyota-resonator-17881waa02',
# ...

# %%
df_correct = pd.DataFrame({'No': range(1, len(list_url) + 1),
                           'Url': list_url})
df_correct.to_excel('./test_url.xlsx', index=False)

df_correct
# Out:
#       No                                                Url
# 0      1  https://toyota.oempartsonline.com/oem-parts/to...
# 1      2  https://toyota.oempartsonline.com/oem-parts/to...
# 2      3  https://toyota.oempartsonline.com/oem-parts/to...
# 3      4  https://toyota.oempartsonline.com/oem-parts/to...
# 4      5  https://toyota.oempartsonline.com/oem-parts/to...
# ..   ...                                                ...
# 445  446  https://toyota.oempartsonline.com/oem-parts/to...
# 446  447  https://toyota.oempartsonline.com/oem-parts/to...
# 447  448  https://toyota.oempartsonline.com/oem-parts/to...
# 448  449  https://toyota.oempartsonline.com/oem-parts/to...
# 449  450  https://toyota.oempartsonline.com/oem-parts/to...
#
# [450 rows x 2 columns]

# %%
crawler_series['Request_Url'] = url_request

list_series_error.append(crawler_series)

list_series_error
# Out:
# [No                                                             1
#  Url            https://toyota.oempartsonline.com/search?searc...
#  SKU Count                                                   1183
#  Page                                                          66
#  Request_Url    https://toyota.oempartsonline.com/search?searc...
#  Name: 0, dtype: object]

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                           ascending=[True],
                                                           ignore_index=True)
    df_error.to_excel('./test_url_error.xlsx', index=False)

df_error
# Out:
#    No                                                Url  SKU Count  Page  \
# 0   1  https://toyota.oempartsonline.com/search?searc...       1183    66
#
#                                          Request_Url
# 0  https://toyota.oempartsonline.com/search?searc...
