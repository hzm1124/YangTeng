# %%
import os

list_file = sorted(list(os.walk('./file/2.page'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx', 'crawler_2.xlsx', 'crawler_3.xlsx']

# %%
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/2.page/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['Product No'] = input_['Product No'].astype(int)
input_['SKU Count'] = input_['SKU Count'].astype(int)
input_['Page'] = input_['Page'].astype(int)

print(f'总数量：{len(input_)}')
input_['Product Name'].tolist()
# Out:
# 总数量：100
# ['1-1/4" Special One-Piece Couplings - Female JIC 37° Flare Swivel',
#  '12 Reel',
#  '12 Reel',
#  '4217IS Standard Diesel Emission Fluid',
#  '4219BD Barricade™ Bio-Diesel Fuel',
#  '4219BF Barricade™ GreenShield™ Fuel',
#  '4219BG Barricade™ Carbureted Engines Fuel',
#  '45° Silicone Coolant',
#  '90° Curved Silicone',
#  '90° Molded Heater',
#  'AC134A Air Conditioning PolarSeal™ I',
#  'ACC-PSII Air Conditioning PolarSeal™ II',
#  'Ag Master™ PVC Solution',
#  'Air Brake Assortments',
#  'Air Brake Coupling Nut',
#  'Air Brake Coupling Sleeve',
#  'Air Brake Coupling Spring Guard Nut',
#  'Air Brake Couplings Spring Guard',
#  'Air Brake Couplings Union',
#  'Air Brake Couplings to Female Air Brake Couplings Swivel',
#  'Air Brake Couplings to Female Air Brake Couplings Swivel with Adapter',
#  'Air Brake Couplings to Male Pipe Adapter',
#  'Air Brake Couplings to Male Pipe with Nut and Sleeve',
#  'Air Brake Couplings to Male Pipe with Spring Guard',
#  'Air Brake Couplings to Male Pipe without Nut and Sleeve',
#  'Air Brake',
#  'Air Brake Male Pipe to Female Pipe Bulkhead',
#  'Air Duct',
#  'Air Master™ Diving Umbilical',
#  'Aluminum',
#  'Angled Fuel Fill',
#  'Barb Stem Couplings',
#  'Barricade™ Carburetion',
#  'Barricade™ Carburetion',
#  'Barricade™ Fuel Injection',
#  'Barricade™ Fuel Injection',
#  'Barricade™ Fuel Injection',
#  'Black Gold™ ABS Bulk Material - 300SD',
#  'Black Gold™ ABS Mud and Oil',
#  'Black Gold™ Fuel',
#  'Black Gold™ Oilfield Frac',
#  'Black Gold™ Oilfield Service',
#  'Black Gold™ Oilfield Service 400D MegaTuff',
#  'Black Gold™ Oilfield Vacuum',
#  'Black Gold™ Potable Water',
#  'Braid Stainless Steel Couplings',
#  'Brass Lock-On Field Attachable Couplings for LOC and LOL',
#  'Bulk Master™ PVC',
#  'C14',
#  'C14 Swage Equipment',
#  'C5C Hydraulic',
#  'C5C-XH XTreme™ Heat Hydraulic',
#  'C5D Hydraulic',
#  'C5E Hydraulic',
#  'C5M Hydraulic',
#  'CM2T Wire Braid',
#  'CR1 1-Wire Braid',
#  'CR2 2-Wire Braid',
#  'Cam Gear Sprocket Tool',
#  'Charter™ Air',
#  'Chem Master™ Hydrocarbon Drain',
#  'Chem Master™ Plus XLPE',
#  'Clean Master™ 3000',
#  'Clean Master™ PW4000',
#  'Clean Master™ Plus PW6000',
#  'Clean Master™ Pressure Wash',
#  'Clean Master™ Washdown',
#  'Coal Power/Longwall Mine',
#  'Coal Power/Longwall Mine',
#  'Conductive C14 PTFE',
#  'D.O.T. Type A1 Field Attachable Couplings',
#  'D.O.T. Type A2 Field Attachable Couplings',
#  'Data Center Cooling',
#  'Dual I.D. Heater',
#  'EF Coal Power/Longwall Mine',
#  'EF Coal Power/Longwall Mine',
#  'EF Longwall Mine',
#  'EF Longwall Mine',
#  'EFG3K Spiral Wire',
#  'EFG3K-MTF Spiral Wire',
#  'EFG4K Spiral Wire',
#  'EFG4K-MTF Spiral Wire',
#  'EFG4K-XTF Spiral Wire',
#  'EFG4KL Spiral Wire',
#  'EFG5K Spiral Wire',
#  'EFG5K-MTF Spiral Wire',
#  'EFG5K-XTF Spiral Wire',
#  'EFG5KL Spiral Wire',
#  'EFG6K Spiral Wire',
#  'EFG6K-MTF Spiral Wire',
#  'EFG6KL Spiral Wire',
#  'Emission',
#  'Engine Air Intake',
#  'Engine Coolant Soft Wall',
#  'Field Attachable Type T for G1',
#  'Field Attachable Type T for G2',
#  'Flange Kits',
#  'Flexible Fuel Fill',
#  'Food Master™ Beverage 150SD CR',
#  'Food Master™ Beverage 250SD CR']

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import time

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

if input_.loc[a, 'Country'] == 'US':
    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_en_string', 'productnumber_en_string', 'name_text_en', 'en', 'us', 'en'
elif input_.loc[a, 'Country'] == 'DE':
    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_de_string', 'productnumber_de_string', 'name_text_de', 'de', 'de', 'de'
elif input_.loc[a, 'Country'] == 'UK':
    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_en_gb_string', 'productnumber_en_gb_string', 'name_text_en_gb', 'en_gb', 'gb', 'en'
else:
    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'fuck', 'fuck', 'fuck', 'fuck', 'fuck', 'fuck'

list_part_code, list_type = [], []
while len(list_part_code) < input_.loc[a, 'SKU Count']:
    for page in range(input_.loc[a, 'Page']):
        b = 0
        while True:
            b += 1
            print(b, page, len(list_part_code))
            try:
                request_url = f'''https://www.gates.com/bin/listing/products/variant?draw=1&columns%5B0%5D%5Bdata%5D=&columns%5B0%5D%5Bname%5D={partnumberauto_string}&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=&columns%5B1%5D%5Bname%5D={productnumber_string}&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D={name_text}&columns%5B2%5D%5Bname%5D={name_text}&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=1&order%5B0%5D%5Bdir%5D=asc&start={page * 10}&length=10&search%5Bvalue%5D=&search%5Bregex%5D=false&id={input_.loc[a, 'Product Number']}&lang={lang}&country={country}&fieldList=code_string,{partnumberauto_string},{productnumber_string},{name_text}&filters=&_={int(time.time() * 1000)}'''
                check_url = f'''https://www.gates.com/{country}/{lang_2}/search.p.{input_.loc[a, 'Product Number']}.html'''
                
                resp = requests.get(request_url,
                                    headers=get_header(),
                                    proxies=get_proxy(),
                                    timeout=(10, 10))
    
                if resp.status_code == 200:
                    dict_dict = resp.json()

                    if dict_dict:
                        break
            except KeyboardInterrupt:
                break
            except:
                continue

        # = = = = = = = = = = = = = = =

        for dict_ in dict_dict['data']:
            if dict_['code_string'] not in dict_:
                list_part_code.append(dict_['code_string'])
                list_type.append(dict_['itemtype_string'])

        # = = = = = = = = = = = = = = =

        if len(list_part_code) == input_.loc[a, 'SKU Count']:
            break

list_part_code, list_type
# Out:
# 1 0 0
# (['7347-08600',
#   '7347-086005',
#   '7347-086015',
#   '7347-086075',
#   '7347-086085',
#   '7347-086095',
#   '7347-086105',
#   '7347-086115',
#   '7347-086135'],
#  ['CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct',
#   'CouplingVariantProduct'])

# %%
df_temp = pd.DataFrame({'Product No': input_.loc[a, 'Product No'],
                        'Product Name': input_.loc[a, 'Product Name'],
                        'Product Number': input_.loc[a, 'Product Number'],
                        'Country': input_.loc[a, 'Country'],
                        'SKU Count': input_.loc[a, 'SKU Count'],
                        'Page': input_.loc[a, 'Page'],
                        'No': [i+1 for i in range(len(list_part_code))],
                        'Type': list_type,
                        'Part Code': list_part_code})

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Product No                                       Product Name  \
# 0           1  1-1/4" Special One-Piece Couplings - Female JI...
# 1           1  1-1/4" Special One-Piece Couplings - Female JI...
# 2           1  1-1/4" Special One-Piece Couplings - Female JI...
# 3           1  1-1/4" Special One-Piece Couplings - Female JI...
# 4           1  1-1/4" Special One-Piece Couplings - Female JI...
# 5           1  1-1/4" Special One-Piece Couplings - Female JI...
# 6           1  1-1/4" Special One-Piece Couplings - Female JI...
# 7           1  1-1/4" Special One-Piece Couplings - Female JI...
# 8           1  1-1/4" Special One-Piece Couplings - Female JI...
#
#        Product Number Country  SKU Count  Page  No                    Type  \
# 0  7347-000000-000575      US          9     1   1  CouplingVariantProduct
# 1  7347-000000-000575      US          9     1   2  CouplingVariantProduct
# 2  7347-000000-000575      US          9     1   3  CouplingVariantProduct
# 3  7347-000000-000575      US          9     1   4  CouplingVariantProduct
# 4  7347-000000-000575      US          9     1   5  CouplingVariantProduct
# 5  7347-000000-000575      US          9     1   6  CouplingVariantProduct
# 6  7347-000000-000575      US          9     1   7  CouplingVariantProduct
# 7  7347-000000-000575      US          9     1   8  CouplingVariantProduct
# 8  7347-000000-000575      US          9     1   9  CouplingVariantProduct
#
#      Part Code
# 0   7347-08600
# 1  7347-086005
# 2  7347-086015
# 3  7347-086075
# 4  7347-086085
# 5  7347-086095
# 6  7347-086105
# 7  7347-086115
# 8  7347-086135

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
    df_temp.loc[0, 'Request_Url'] = request_url
    df_temp.loc[0, 'Check_Url'] = check_url

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
    
output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Product No', 'No'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_part_code.xlsx', index=False)

output_correct
# Out:
#    Product No                                       Product Name  \
# 0           1  1-1/4" Special One-Piece Couplings - Female JI...
# 1           1  1-1/4" Special One-Piece Couplings - Female JI...
# 2           1  1-1/4" Special One-Piece Couplings - Female JI...
# 3           1  1-1/4" Special One-Piece Couplings - Female JI...
# 4           1  1-1/4" Special One-Piece Couplings - Female JI...
# 5           1  1-1/4" Special One-Piece Couplings - Female JI...
# 6           1  1-1/4" Special One-Piece Couplings - Female JI...
# 7           1  1-1/4" Special One-Piece Couplings - Female JI...
# 8           1  1-1/4" Special One-Piece Couplings - Female JI...
#
#        Product Number Country  SKU Count  Page  No                    Type  \
# 0  7347-000000-000575      US          9     1   1  CouplingVariantProduct
# 1  7347-000000-000575      US          9     1   2  CouplingVariantProduct
# 2  7347-000000-000575      US          9     1   3  CouplingVariantProduct
# 3  7347-000000-000575      US          9     1   4  CouplingVariantProduct
# 4  7347-000000-000575      US          9     1   5  CouplingVariantProduct
# 5  7347-000000-000575      US          9     1   6  CouplingVariantProduct
# 6  7347-000000-000575      US          9     1   7  CouplingVariantProduct
# 7  7347-000000-000575      US          9     1   8  CouplingVariantProduct
# 8  7347-000000-000575      US          9     1   9  CouplingVariantProduct
#
#      Part Code
# 0   7347-08600
# 1  7347-086005
# 2  7347-086015
# 3  7347-086075
# 4  7347-086085
# 5  7347-086095
# 6  7347-086105
# 7  7347-086115
# 8  7347-086135

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Product No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./test_part_code_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
