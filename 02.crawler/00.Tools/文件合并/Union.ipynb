# %%
import sys
sys.path.append('../../../00.module')
import Union

import pandas as pd

# %%
df = Union.get_Union_File('./file')

df.to_excel('./fuck.xlsx')

df
# Out:
# 进度: 100%|████████████████████████████████████| 2/2 [00:00<00:00,  2.92it/s]
#      status                                               Info  \
# 0        ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 1        ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 2        ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 3        ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 4        ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# ...     ...                                                ...
# 2841     ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 2842     ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 2843     ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 2844     ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
# 2845     ok  https://www.rockauto.com/en/moreinfo.php?pt=10...
#
#       branch quantity centerline length contains spring end 1 inside diameter  \
# ...
