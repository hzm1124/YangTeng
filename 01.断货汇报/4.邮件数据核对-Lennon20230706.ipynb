# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230818.xlsx

# %%
import pandas as pd

# %%
table_1 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(1, 9)]).loc[:4]

table_1
# Out:
#       层级   SKU 总数  在库为0（断货数）  在库1-2（干预数）       断货率       干预率  近期海运上架后断货数  \
# 0   TOP1    510.0       32.0        16.0  0.062745  0.031373        12.0
# 1  TOP10   1479.0       71.0        66.0  0.048005  0.044625        33.0
# 2  TOP20   4789.0      284.0       375.0  0.059303  0.078304       117.0
# 3     普通  49108.0     2811.0      7733.0  0.057241  0.157469      1674.0
# 4     总数  55886.0     3198.0      8190.0  0.057224  0.146548      1836.0
#
#    近期海运上架后断货率
# 0    0.023529
# 1    0.022312
# 2    0.024431
# 3    0.034088
# 4    0.032853

# %%
table_2 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(10, 17)]).loc[:4]

table_2
# Out:
#     层级.1  在库为0（断货）   断货无在途        占比  在库1-2（干预）   干预无在途      占比.1
# 0   TOP1      32.0     7.0  0.218750       16.0     1.0  0.062500
# 1  TOP10      71.0    26.0  0.366197       66.0    21.0  0.318182
# 2  TOP20     284.0    75.0  0.264085      375.0   117.0  0.312000
# 3     普通    2811.0  1090.0  0.387762     7733.0  3459.0  0.447304
# 4     总数    3198.0  1198.0  0.374609     8190.0  3598.0  0.439316

# %%
table_3 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(18, 27)]).loc[:4]

table_3
# Out:
#     层级.2  W30\n07/26  W30\n07/29  W31\n08/03  W31\n08/04  W32\n08/08  \
# 0   TOP1        41.0        33.0        31.0        32.0        33.0
# 1  TOP10        80.0        73.0        78.0        82.0        77.0
# 2  TOP20       340.0       321.0       300.0       308.0       297.0
# 3     普通      2963.0      2871.0      2716.0      2722.0      2870.0
# 4     总数      3424.0      3298.0      3125.0      3144.0      3277.0
#
#    W32\n08/10  W33\n08/15  W33\n08/18
# 0        36.0        24.0        32.0
# 1        74.0        66.0        71.0
# 2       286.0       269.0       284.0
# 3      2717.0      2855.0      2811.0
# 4      3113.0      3214.0      3198.0

# %%
table_4 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(28, 33)],
                        index_col=0)

table_4
# Out:
#          品类  断货SKU数量  总SKU数      断货占比
# 排名
# TOP1     BC      335   2866  0.116888
# TOP2     CA      222   4778  0.046463
# TOP3    CVA      172   2062  0.083414
# TOP4    ACH      150   1696  0.088443
# TOP5     WR      139   2041  0.068104
# ...     ...      ...    ...       ...
# TOP424  CHH        0     79  0.000000
# TOP425  EGR        0     82  0.000000
# TOP426  ACS        0     94  0.000000
# TOP427  CLK        0    140  0.000000
# TOP428  SCS        0    168  0.000000
#
# [428 rows x 4 columns]

# %%
sheet_2_left = pd.read_excel(calculate,
                             sheet_name='2_断货SKU',
                             header=1,
                             usecols=[i for i in range(5)],
                             index_col=0)

sheet_2_left
# Out:
#                 SKU     层级    周销  在途
# 序号
# 1      USADCA00400U   TOP1  7.65   0
# 2      USBCB97430-C   TOP1  5.47   0
# 3    USFP7263M0Z1-C   TOP1  2.91   0
# 4      USPBB27358-C   TOP1  1.49   0
# 5      USPSR221014G   TOP1  2.62   0
# ..              ...    ...   ...  ..
# 106      USSKA51216  TOP20  1.70   0
# 107    USSTR19163-C  TOP20  0.68   0
# 108   USSTR66760B-C  TOP20  3.40   0
# 109   USWHN11094-20  TOP20  2.12   0
# 110     USWM42269HY  TOP20  5.41   0
#
# [110 rows x 4 columns]

# %%
sheet_2_right = pd.read_excel(calculate,
                              sheet_name='2_断货SKU',
                              header=1,
                              usecols=[i for i in range(7, 9)],
                              index_col=0).dropna().sort_values(by=['断货数'], ascending=False)

sheet_2_right
# Out:
#         断货数
# 品类去重
# CA     20.0
# CVA    15.0
# ACC     6.0
# DS      6.0
# SA      5.0
# ALT     4.0
# BC      4.0
# BMC     4.0
# PSR     4.0
# STR     3.0
# FP      2.0
# PBB     2.0
# PHLS    2.0
# CS-弹簧   2.0
# CON     2.0
# FF      1.0
# WHN     1.0
# TCA     1.0
# TBK     1.0
# TBC     1.0
# SS      1.0
# SKA     1.0
# PSC     1.0
# OS      1.0
# OC      1.0
# MSA     1.0
# LGH     1.0
# IM      1.0
# HB      1.0
# CA-套件   1.0
# EM      1.0
# EGC     1.0
# EAF     1.0
# DIF     1.0
# DAM     1.0
# CTP     1.0
# BT      1.0
# BRPS    1.0
# BM      1.0
# BHH     1.0
# AEC     1.0
# ADCA    1.0
# ACH     1.0
# WM      1.0

# %%
print(int(table_1.loc[4, '在库为0（断货数）']), end='; ')
print(str(round(table_1.loc[4, '断货率']*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['断货率'].tolist().index(max(table_1['断货率'])), '层级'], end='; ')
print(str(round(max(table_1['断货率'])*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['干预率'].tolist().index(max(table_1['干预率'])), '层级'], end='; ')
print(str(round(max(table_1['干预率'])*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left), end='; ')
print(sheet_2_right['断货数'].index[0], end='; ')
print(sheet_2_right['断货数'].index[1], end='; ')
print(sheet_2_right['断货数'].index[2], end='; ')
print(int(sheet_2_right.iloc[0, 0]), end='; ')
print(int(sheet_2_right.iloc[1, 0]), end='; ')
print(int(sheet_2_right.iloc[2, 0]))
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left[sheet_2_left['层级']=='TOP1']))
# Out:
# 3198; 5.72%; TOP1; 6.27%; 普通; 15.75%
#
# = = = = = = = = = = = = = = = = = =
#
# 110; CA; CVA; ACC; 20; 15; 6
#
# = = = = = = = = = = = = = = = = = =
#
# 7

# %%
print(int(table_2.loc[4, '在库为0（断货）']), end='; ')
print(int(table_2.loc[4, '断货无在途']), end='; ')
print(str(round(table_2.loc[4, '占比']*100, 2)) + '%', end='; ')
print(int(table_2.loc[4, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[4, '干预无在途']), end='; ')
print(str(round(table_2.loc[4, '占比.1']*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(int(table_2.loc[0, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[0, '干预无在途']))
# Out:
# 3198; 1198; 37.46%; 8190; 3598; 43.93%
#
# = = = = = = = = = = = = = = = = = =
#
# 16; 1

# %%
print('TOP1: ' + str(int(table_3.iloc[0, 8] - table_3.iloc[0, 7])))
print('TOP10: ' + str(int(table_3.iloc[1, 8] - table_3.iloc[1, 7])))
print('TOP20: ' + str(int(table_3.iloc[2, 8] - table_3.iloc[2, 7])))
print('普通: ' + str(int(table_3.iloc[3, 8] - table_3.iloc[3, 7])))
# Out:
# TOP1: 8
# TOP10: 5
# TOP20: 15
# 普通: -44

# %%
print(table_4.loc['TOP1', '品类'], end='; ')
print(table_4.loc['TOP1', '断货SKU数量'])
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 2], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 1], end='; ')
print(str(round(max(table_4['断货占比'][:10])*100, 2)) + '%')
# Out:
# BC; 335
#
# = = = = = = = = = = = = = = = = = =
#
# ALT; 657; ALT; 86; 13.09%

# %%
共23款TOP1层级SKU库存1-2，且有1款无在途。
# Out:
#   Cell In[14], line 1
#     共23款TOP1层级SKU库存1-2，且有1款无在途。
#                      ^
# SyntaxError: invalid decimal literal

# %%
（1）与W24周（06/17）相比，W26周（07/01）TOP1断货有所上升，达3款；
（2）TOP10、TOP20和普通层级断货有所下降，其中普通层级断货下降最多，达73款。

# %%
（1）W27周（07/07）断货整体比W27周（07/05）有所下降，其中普通层级断货下降最多，达183款；
（2）在重点SKU（TOP1、TOP10、TOP20）中，TOP10断货下降最多，达17款。
