# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./part.xlsx',
                        header=0,
                        dtype=str).fillna('')

list_part_number = df_menu['Part_Number'].tolist()

print('总数量：' + str(len(list_part_number)))
list_part_number

# %%
df = pd.DataFrame()

df

# %%
part_number = 

part_number

# %%
part_number = 'CMS251103'

# %%
import requests

# %%
i = 0

url = 'https://www.mevotech.com/part/' + list_part_number[0]

# %%
from bs4 import BeautifulSoup
from lxml import etree

# %%
resp = requests.get( + part_number).text
soup = BeautifulSoup(resp, 'lxml')
html = etree.HTML(str(soup))

resp
# Out:
# '\n<!DOCTYPE html>\n<html lang="en-US">\n\t<head>\n        <meta charset="UTF-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1.0">\n        <meta name="format-detection" content="telephone=no">\n        \n        <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<link rel="alternate" href="https://www.mevotech.com/part/" hreflang="en" />\n<link rel="alternate" href="https://www.mevotech.com/fr/partie/" hreflang="fr" />\n<link rel="alternate" href="https://www.mevotech.com/es/parte/" hreflang="es" />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v20.5 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>CMS251103 - Trailing Arm - Mevotech</title>\n\t<link rel="canonical" href="https://www.mevotech.com/part/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:locale:alternate" content="fr_C
# ...
