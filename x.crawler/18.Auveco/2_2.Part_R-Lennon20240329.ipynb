# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                resp = requests.get(input_.loc[a, 'Url'],
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                html = etree.HTML(str(soup))
                
                # = = = = = = = = = = = = = = =
                
                title = html.xpath('//div[@class="span8"]/div[@class="row-fluid"]/h1/text()')[0].strip()

                # = = = = = = = = = = = = = = =
                
                item_number = html.xpath('//div[@class="span8"]/div[@class="row-fluid"]/p[@class="product-details-code"]/text()')[0].replace('Item No:', '').strip()

                # = = = = = = = = = = = = = = =
                
                upc = html.xpath('//div[@class="span8"]/div[@class="row-fluid"]/p[@class="product-details-upccode"]/text()')
                upc = '' if len(upc) == 0 else upc[0].replace('UPC Code:', '').strip()
    
                # = = = = = = = = = = = = = = =
                                
                src = html.xpath('//img[@id="product-detail-gallery-main-img"]/@src')[0].strip()
                
                # = = = = = = = = = = = = = = =
                
                list_li_1 = html.xpath('//li[@class="information-attribute"]')
                
                # = = = = = = = = = = = = = = =
                
                list_li_2 = html.xpath('//div[@class="row-fluid"]/div[@class="span6"]/ul[@class="unstyled"]/li/text()')
                list_li_2 = [li.strip() for li in list_li_2]

                while '' in list_li_2:
                    list_li_2.remove('')
                    
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                                         'Item_Number': item_number,
                                         'UPC': upc,
                                         'Title': title,
                                         'Pic': '',
                                         'Url': input_.loc[a, 'Url'],
                                         'Src': src}])

                for li in list_li_1:
                    df_temp.loc[0, li.xpath('./span[@class="attribute-title"]/text()')[0].replace(':', '').strip().lower()] = li.xpath('./span[@class="attribute-value"]/text()')[0].strip()

                for li in list_li_2:
                    df_temp.loc[0, li.split(':')[0].strip().upper()] = li.split(':')[1].strip()

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
                
                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                                     'Url': input_.loc[a, 'Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Url'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./part-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./part_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：72
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/nylon-nuts-quik-select-kit-6807
# [尝试次数：1] - [剩余数量：62] - [当前时间：17:03:12]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/nylon-rivet-quik-select-kit-6806
# [尝试次数：1] - [剩余数量：61] - [当前时间：17:03:12]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/chry-xmas-tree-retainer-quik-select-kit-6803
# [尝试次数：1] - [剩余数量：60] - [当前时间：17:03:13]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/ford-push-type-retainer-quik-select-kit-6805
# [尝试次数：1] - [剩余数量：59] - [当前时间：17:03:13]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-xmas-tree-retainer-quik-select-kit-6801
# [尝试次数：1] - [剩余数量：58] - [当前时间：17:03:13]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/license-plate-hardware-quik-select-kit-6808
# [尝试次数：1] - [剩余数量：57] - [当前时间：17:03:13]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/reveal-moulding-clip-quik-select-kit-6809
# [尝试次数：1] - [剩余数量：56] - [当前时间：17:03:14]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/ford-xmas-treeretainer-quik-select-kit-6802
# [尝试次数：1] - [剩余数量：55] - [当前时间：17:03:14]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/black-tapping-screw-quik-select-kit-6812
# [尝试次数：1] - [剩余数量：54] - [当前时间：17:03:15]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/body-bolt-quik-select-kit-6814
# [尝试次数：1] - [剩余数量：53] - [当前时间：17:03:15]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-push-type-retainer-quik-select-kit-6804
# [尝试次数：1] - [剩余数量：52] - [当前时间：17:03:15]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/teks-screw-quik-select-kit-6813
# [尝试次数：1] - [剩余数量：51] - [当前时间：17:03:15]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/glass-shop-rivet-quik-select-kit-6821
# [尝试次数：1] - [剩余数量：50] - [当前时间：17:03:17]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/specialty-screw-quik-select-kit-6811
# [尝试次数：1] - [剩余数量：49] - [当前时间：17:03:17]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/oil-drain-plug-gasket-quik-select-kit-6825
# [尝试次数：1] - [剩余数量：48] - [当前时间：17:03:18]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-window-guide-quik-select-kit-6822
# [尝试次数：1] - [剩余数量：47] - [当前时间：17:03:18]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/wshr-nut-push-on-ret-quik-select-kit-6817
# [尝试次数：1] - [剩余数量：46] - [当前时间：17:03:18]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/rubber-vacuum-cap-quik-select-kit-6826
# [尝试次数：1] - [剩余数量：45] - [当前时间：17:03:19]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/tubular-flat-u-j-nut-quik-select-kit-6815
# [尝试次数：1] - [剩余数量：44] - [当前时间：17:03:20]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/cotter-pin-quik-select-kit-6818
# [尝试次数：1] - [剩余数量：43] - [当前时间：17:03:21]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/hair-pin-cotter-quik-select-kit-6830
# [尝试次数：1] - [剩余数量：42] - [当前时间：17:03:21]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/rubber-grommet-quik-select-kit-6827
# [尝试次数：1] - [剩余数量：41] - [当前时间：17:03:22]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/buna-n-rubber-o-ring-quik-select-kit-6835
# [尝试次数：1] - [剩余数量：40] - [当前时间：17:03:22]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/extruded-u-nut-quik-select-kit-6816
# [尝试次数：1] - [剩余数量：39] - [当前时间：17:03:22]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/nylon-connector-quik-select-kit-6836
# [尝试次数：1] - [剩余数量：38] - [当前时间：17:03:23]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/plastic-plug-button-quik-select-kit-6831
# [尝试次数：1] - [剩余数量：37] - [当前时间：17:03:23]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/oil-drain-plug-gasket-quik-select-kit-6820
# [尝试次数：1] - [剩余数量：36] - [当前时间：17:03:25]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/nylon-ins-elec-terminal-quik-select-kit-6842
# [尝试次数：1] - [剩余数量：35] - [当前时间：17:03:25]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/toyota-body-hardware-quik-select-kit-6839
# [尝试次数：1] - [剩余数量：34] - [当前时间：17:03:26]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/honda-body-hardware-quik-select-kit-6837
# [尝试次数：1] - [剩余数量：33] - [当前时间：17:03:26]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-xmas-tree-retainer-quik-select-kit-6845
# [尝试次数：1] - [剩余数量：32] - [当前时间：17:03:27]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/vinyl-ins-elec-terminal-quik-select-kit-6843
# [尝试次数：1] - [剩余数量：31] - [当前时间：17:03:28]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/pan-l-blind-rivets-quik-select-kit-6840
# [尝试次数：1] - [剩余数量：30] - [当前时间：17:03:29]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/phil-oval-hd-tap-scr-chrome-quik-select-6848
# [尝试次数：1] - [剩余数量：29] - [当前时间：17:03:29]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/ford-xmas-treeretainer-quik-select-kit-6846
# [尝试次数：1] - [剩余数量：28] - [当前时间：17:03:29]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/specialty-rivets-quik-select-kit-6841
# [尝试次数：1] - [剩余数量：27] - [当前时间：17:03:30]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/toyota-body-hardware-quik-select-kit-6834
# [尝试次数：1] - [剩余数量：26] - [当前时间：17:03:30]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/sems-screw-quik-select-kit-6810
# [尝试次数：1] - [剩余数量：25] - [当前时间：17:03:31]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/chrysler-retainer-quik-select-kit-6847
# [尝试次数：1] - [剩余数量：24] - [当前时间：17:03:31]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/phillips-pan-head-t-s-quik-select-kit-6851
# [尝试次数：1] - [剩余数量：23] - [当前时间：17:03:33]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/thread-cutting-nut-quik-select-kit-6857
# [尝试次数：1] - [剩余数量：22] - [当前时间：17:03:33]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/ext-int-lock-washer-quik-select-kit-6856
# [尝试次数：1] - [剩余数量：21] - [当前时间：17:03:34]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/metric-specialty-screw-quik-select-kit-6854
# [尝试次数：1] - [剩余数量：20] - [当前时间：17:03:34]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/honda-body-hardware-quik-select-kit-6829
# [尝试次数：1] - [剩余数量：19] - [当前时间：17:03:35]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/e-type-retaining-ring-quik-select-kit-6862
# [尝试次数：1] - [剩余数量：18] - [当前时间：17:03:35]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/pushnut-bolt-retainer-quik-select-kit-6858
# [尝试次数：1] - [剩余数量：17] - [当前时间：17:03:36]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/phil-oval-hd-ts-black-oxide-quik-select-6850
# [尝试次数：1] - [剩余数量：16] - [当前时间：17:03:36]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/hose-connector-tee-quik-select-kit-6859
# [尝试次数：1] - [剩余数量：15] - [当前时间：17:03:37]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/weatherstrip-retainers-quik-select-kit-6865
# [尝试次数：1] - [剩余数量：14] - [当前时间：17:03:37]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/stainless-steel-t-s-quik-select-kit-6852
# [尝试次数：1] - [剩余数量：13] - [当前时间：17:03:37]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/door-lock-rod-clip-quik-select-kit-6864
# [尝试次数：1] - [剩余数量：12] - [当前时间：17:03:37]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/rubber-bumpers-quik-select-kit-6866
# [尝试次数：1] - [剩余数量：11] - [当前时间：17:03:37]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/body-shims-quick-select-kit-6868
# [尝试次数：1] - [剩余数量：10] - [当前时间：17:03:39]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/hyundai-kia-clips-and-fasteners-quik-select-kit-6871
# [尝试次数：1] - [剩余数量：9] - [当前时间：17:03:40]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/wire-loom-routing-clips-quik-select-kit-6867
# [尝试次数：1] - [剩余数量：8] - [当前时间：17:03:40]
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-reveal-moulding-clips-and-stud-screw-quik-select-kit-6876
# [尝试次数：1] - [剩余数量：7] - [当前时间：17:03:40]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/spring-pin-quik-select-kit-6861
# [尝试次数：1] - [剩余数量：6] - [当前时间：17:03:41]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/push-type-retainer-quick-select-kit-gm-ford-chry-6870
# [尝试次数：1] - [剩余数量：5] - [当前时间：17:03:41]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/fender-washers-quick-select-kit-6869
# [尝试次数：1] - [剩余数量：4] - [当前时间：17:03:41]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/retainer-quik-select-kit-6875
# [尝试次数：1] - [剩余数量：3] - [当前时间：17:03:41]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/u-s-specialty-screw-quik-select-kit-6853
# [尝试次数：1] - [剩余数量：2] - [当前时间：17:03:42]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/nissan-body-hardware-quik-select-kit-6838
# [尝试次数：1] - [剩余数量：1] - [当前时间：17:03:42]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/domestic-xmas-tree-retainer-quik-select-kit-6883
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:43]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/foreign-domestic-push-type-retainer-quik-select-kit-6882
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:43]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/copper-sealing-washer-quik-select-kit-6878
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:44]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/throttle-rod-clip-quik-select-kit-6879
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:47]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/ext-int-retaining-ring-quik-select-kit-6863
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:48]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/gm-ford-chrysler-door-hinge-pin-and-bushing-kit-6881
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:49]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/door-lock-rod-end-clip-quik-select-kit-6886
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:49]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/specialty-nut-quik-select-kit-6884
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:51]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/flat-push-on-retainer-quik-select-kit-6887
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:51]
#
# [ok] - https://www.auveco.com/polypropylene-compartment-box-6800-series/push-type-retainer-quik-select-kit-6877
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:03:58]
#
# 输出ing...
#
# Done ~
