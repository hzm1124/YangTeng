# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
param_date = '20240715'

# %%
import os

list_file = sorted(list(os.walk(f'./{param_date}/7.group'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['make_1.ABARTH.xlsx',
#  'make_10.AMERICAN AUSTIN.xlsx',
#  'make_100.GOLIATH.xlsx',
#  'make_101.GORDON-KEEBLE.xlsx',
#  'make_102.GRAHAM.xlsx',
#  'make_103.GRAHAM-PAIGE.xlsx',
#  'make_104.GRIFFITH.xlsx',
#  'make_105.HEALEY.xlsx',
#  'make_106.HENRY J.xlsx',
#  'make_107.HILLMAN.xlsx',
#  'make_108.HINO.xlsx',
#  'make_109.HISPANO-SUIZA.xlsx',
#  'make_11.AMERICAN BANTAM.xlsx',
#  'make_110.HONDA-serial_1.xlsx',
#  'make_110.HONDA-serial_2.xlsx',
#  'make_111.HOTCHKISS.xlsx',
#  'make_112.HRG.xlsx',
#  'make_113.HUDSON.xlsx',
#  'make_114.HUMBER.xlsx',
#  'make_115.HUMMER.xlsx',
#  'make_116.HUPMOBILE.xlsx',
#  'make_117.HYUNDAI-serial_1.xlsx',
#  'make_117.HYUNDAI-serial_2.xlsx',
#  'make_118.INFINITI.xlsx',
#  'make_119.INTERNATIONAL-serial_1.xlsx',
#  'make_119.INTERNATIONAL-serial_2.xlsx',
#  'make_119.INTERNATIONAL-serial_3.xlsx',
#  'make_119.INTERNATIONAL-serial_4.xlsx',
#  'make_12.AMERICAN MOTORS.xlsx',
#  'make_120.ISO.xlsx',
#  'make_121.ISUZU.xlsx',
#  'make_122.IVECO.xlsx',
#  'make_123.JAC.xlsx',
#  'make_124.JAGUAR.xlsx',
#  'make_125.JEEP-serial_1.xlsx',
#  'make_125.JEEP-serial_2.xlsx',
#  'make_125.JEEP-serial_3.xlsx',
#  'make_126.JENSEN.xlsx',
#  'make_127.JEWETT.xlsx',
#  'make_128.JMC.xlsx',
#  'make_129.JORDAN.xlsx',
#  'make_13.AMPHICAR.xlsx',
#  'make_130.JOWETT.xlsx',
#  'make_131.KAISER-FRAZER.xlsx',
#  'make_132.KARMA.xlsx',
#  'make_133.KENWORTH.xlsx',
#  'make_134.KIA.xlsx',
#  'make_135.KISSEL.xlsx',
#  'make_136.KURTIS.xlsx',
#  'make_137.LADA.xlsx',
#  'make_138.LAFORZA.xlsx',
#  'make_139.LAGONDA.xlsx',
#  'make_14.APOLLO.xlsx',
#  'make_140.LAMBORGHINI.xlsx',
#  'make_141.LANCHESTER.xlsx',
#  'make_142.LANCIA.xlsx',
#  'make_143.LAND ROVER.xlsx',
#  'make_144.LASALLE.xlsx',
#  'make_145.LEA-FRANCIS.xlsx',
#  'make_146.LEXINGTON.xlsx',
#  'make_147.LEXUS.xlsx',
#  'make_148.LINCOLN.xlsx',
#  'make_149.LORDSTOWN MOTORS.xlsx',
#  'make_15.ARMSTRONG-SIDDELEY.xlsx',
#  'make_150.LOTUS.xlsx',
#  'make_151.LUCID.xlsx',
#  'make_152.MACK.xlsx',
#  'make_153.MAICO.xlsx',
#  'make_154.MARATHON.xlsx',
#  'make_155.MARAUDER.xlsx',
#  'make_156.MARCOS.xlsx',
#  'make_157.MARMON.xlsx',
#  'make_158.MASERATI.xlsx',
#  'make_159.MASTRETTA.xlsx',
#  'make_16.ARNOLT-BRISTOL.xlsx',
#  'make_160.MATRA.xlsx',
#  'make_161.MAXWELL.xlsx',
#  'make_162.MAYBACH.xlsx',
#  'make_163.MAZDA-serial_1.xlsx',
#  'make_163.MAZDA-serial_2.xlsx',
#  'make_164.MCLAREN.xlsx',
#  'make_165.MERCEDES-BENZ-serial_1.xlsx',
#  'make_165.MERCEDES-BENZ-serial_2.xlsx',
#  'make_165.MERCEDES-BENZ-serial_3.xlsx',
#  'make_165.MERCEDES-BENZ-serial_4.xlsx',
#  'make_166.MERCURY-serial_1.xlsx',
#  'make_166.MERCURY-serial_2.xlsx',
#  'make_166.MERCURY-serial_3.xlsx',
#  'make_167.MERKUR.xlsx',
#  'make_168.MESSERSCHMITT.xlsx',
#  'make_169.MG.xlsx',
#  'make_17.ARNOLT-MG.xlsx',
#  'make_170.MINI.xlsx',
#  'make_171.MITSUBISHI-serial_1.xlsx',
#  'make_171.MITSUBISHI-serial_2.xlsx',
#  'make_172.MITSUBISHI FUSO.xlsx',
#  'make_173.MOBILITY VENTURES.xlsx',
#  'make_174.MONTEVERDI.xlsx',
#  'make_175.MOON.xlsx',
#  'make_176.MORETTI.xlsx',
#  'make_177.MORGAN.xlsx',
#  'make_178.MORRIS.xlsx',
#  'make_179.MOSKVICH.xlsx',
#  'make_18.ASTON MARTIN.xlsx',
#  'make_180.NARDI.xlsx',
#  'make_181.NASH.xlsx',
#  'make_182.NISSAN-serial_1.xlsx',
#  'make_182.NISSAN-serial_2.xlsx',
#  'make_182.NISSAN-serial_3.xlsx',
#  'make_183.NSU.xlsx',
#  'make_184.OAKLAND.xlsx',
#  'make_185.OLDSMOBILE-serial_1.xlsx',
#  'make_185.OLDSMOBILE-serial_2.xlsx',
#  'make_186.OMEGA.xlsx',
#  'make_187.OPEL.xlsx',
#  'make_188.OSCA.xlsx',
#  'make_189.PACKARD.xlsx',
#  'make_19.ASUNA.xlsx',
#  'make_190.PAIGE.xlsx',
#  'make_191.PANHARD.xlsx',
#  'make_192.PANOZ.xlsx',
#  'make_193.PANTHER.xlsx',
#  'make_194.PASSPORT.xlsx',
#  'make_195.PEERLESS.xlsx',
#  'make_196.PEGASO.xlsx',
#  'make_197.PETERBILT.xlsx',
#  'make_198.PEUGEOT.xlsx',
#  'make_199.PIERCE-ARROW.xlsx',
#  'make_2.AC.xlsx',
#  'make_20.AUBURN.xlsx',
#  'make_200.PLYMOUTH-serial_1.xlsx',
#  'make_200.PLYMOUTH-serial_2.xlsx',
#  'make_200.PLYMOUTH-serial_3.xlsx',
#  'make_201.POLESTAR.xlsx',
#  'make_202.PONTIAC-serial_1.xlsx',
#  'make_202.PONTIAC-serial_2.xlsx',
#  'make_202.PONTIAC-serial_3.xlsx',
#  'make_203.PORSCHE-serial_1.xlsx',
#  'make_203.PORSCHE-serial_2.xlsx',
#  'make_204.QVALE.xlsx',
#  'make_205.RAM.xlsx',
#  'make_206.RELIANT.xlsx',
#  'make_207.RENAULT.xlsx',
#  'make_208.REO.xlsx',
#  'make_209.RICKENBACKER.xlsx',
#  'make_21.AUDI-serial_1.xlsx',
#  'make_21.AUDI-serial_2.xlsx',
#  'make_210.RILEY.xlsx',
#  'make_211.RIVIAN.xlsx',
#  'make_212.ROAMER.xlsx',
#  'make_213.ROCKNE.xlsx',
#  'make_214.ROLLS-ROYCE.xlsx',
#  'make_215.ROVER.xlsx',
#  'make_216.SAAB.xlsx',
#  'make_217.SABRA.xlsx',
#  'make_218.SALEEN.xlsx',
#  'make_219.SALMSON.xlsx',
#  'make_22.AUSTIN.xlsx',
#  'make_220.SATURN.xlsx',
#  'make_221.SCION.xlsx',
#  'make_222.SEAT.xlsx',
#  'make_223.SHELBY.xlsx',
#  'make_224.SIATA.xlsx',
#  'make_225.SIMCA.xlsx',
#  'make_226.SINGER.xlsx',
#  'make_227.SKODA.xlsx',
#  'make_228.SMART.xlsx',
#  'make_229.SPYKER.xlsx',
#  'make_23.AUSTIN-HEALEY.xlsx',
#  'make_230.SRT.xlsx',
#  'make_231.SSANGYONG.xlsx',
#  'make_232.STANDARD.xlsx',
#  'make_233.STAR.xlsx',
#  'make_234.STEARNS KNIGHT.xlsx',
#  'make_235.STERLING.xlsx',
#  'make_236.STEVENS-DURYEA.xlsx',
#  'make_237.STUDEBAKER.xlsx',
#  'make_238.STUTZ.xlsx',
#  'make_239.SUBARU.xlsx',
#  'make_24.AVANTI.xlsx',
#  'make_240.SUNBEAM.xlsx',
#  'make_241.SUZUKI.xlsx',
#  'make_242.SWALLOW.xlsx',
#  'make_243.TALBOT-LAGO.xlsx',
#  'make_244.TATRA.xlsx',
#  'make_245.TESLA.xlsx',
#  'make_246.THINK.xlsx',
#  'make_247.TOYOTA-serial_1.xlsx',
#  'make_247.TOYOTA-serial_2.xlsx',
#  'make_247.TOYOTA-serial_3.xlsx',
#  'make_248.TRIUMPH.xlsx',
#  'make_249.TURNER.xlsx',
#  'make_25.BAIC.xlsx',
#  'make_250.TVR.xlsx',
#  'make_251.UAZ.xlsx',
#  'make_252.UD.xlsx',
#  'make_253.UTILIMASTER.xlsx',
#  'make_254.VAM.xlsx',
#  'make_255.VAUXHALL.xlsx',
#  'make_256.VESPA.xlsx',
#  'make_257.VINFAST.xlsx',
#  'make_258.VOLKSWAGEN-serial_1.xlsx',
#  'make_258.VOLKSWAGEN-serial_2.xlsx',
#  'make_258.VOLKSWAGEN-serial_3.xlsx',
#  'make_259.VOLVO-serial_1.xlsx',
#  'make_259.VOLVO-serial_2.xlsx',
#  'make_26.BENTLEY.xlsx',
#  'make_260.VPG.xlsx',
#  'make_261.WARTBURG.xlsx',
#  'make_262.WESTCOTT.xlsx',
#  'make_263.WHIPPET.xlsx',
#  'make_264.WILLYS.xlsx',
#  'make_265.WINDSOR.xlsx',
#  'make_266.WOLSELEY.xlsx',
#  'make_267.WORKHORSE.xlsx',
#  'make_268.YELLOW CAB.xlsx',
#  'make_269.YUGO.xlsx',
#  'make_27.BERKELEY.xlsx',
#  'make_270.ZACUA.xlsx',
#  'make_271.ZUNDAPP.xlsx',
#  'make_28.BIZZARRINI.xlsx',
#  'make_29.BMW-serial_1.xlsx',
#  'make_29.BMW-serial_2.xlsx',
#  'make_29.BMW-serial_3.xlsx',
#  'make_3.ACURA.xlsx',
#  'make_30.BOND.xlsx',
#  'make_31.BORGWARD.xlsx',
#  'make_32.BRICKLIN.xlsx',
#  'make_33.BRIGHTDROP.xlsx',
#  'make_34.BRISTOL.xlsx',
#  'make_35.BUGATTI.xlsx',
#  'make_36.BUICK-serial_1.xlsx',
#  'make_36.BUICK-serial_2.xlsx',
#  'make_37.CADILLAC-serial_1.xlsx',
#  'make_37.CADILLAC-serial_2.xlsx',
#  'make_38.CASE.xlsx',
#  'make_39.CHANGAN.xlsx',
#  'make_4.ALFA ROMEO.xlsx',
#  'make_40.CHECKER.xlsx',
#  'make_41.CHEVROLET-serial_1.xlsx',
#  'make_41.CHEVROLET-serial_10.xlsx',
#  'make_41.CHEVROLET-serial_11.xlsx',
#  'make_41.CHEVROLET-serial_12.xlsx',
#  'make_41.CHEVROLET-serial_2.xlsx',
#  'make_41.CHEVROLET-serial_3.xlsx',
#  'make_41.CHEVROLET-serial_4.xlsx',
#  'make_41.CHEVROLET-serial_5.xlsx',
#  'make_41.CHEVROLET-serial_6.xlsx',
#  'make_41.CHEVROLET-serial_7.xlsx',
#  'make_41.CHEVROLET-serial_8.xlsx',
#  'make_41.CHEVROLET-serial_9.xlsx',
#  'make_42.CHIREY.xlsx',
#  'make_43.CHRYSLER-serial_1.xlsx',
#  'make_43.CHRYSLER-serial_2.xlsx',
#  'make_44.CISITALIA.xlsx',
#  'make_45.CITROEN.xlsx',
#  'make_46.COLE.xlsx',
#  'make_47.CONTINENTAL.xlsx',
#  'make_48.CORD.xlsx',
#  'make_49.CROSLEY.xlsx',
#  'make_5.ALLARD.xlsx',
#  'make_50.CUNNINGHAM.xlsx',
#  'make_51.CUPRA.xlsx',
#  'make_52.DAEWOO.xlsx',
#  'make_53.DAF.xlsx',
#  'make_54.DAIHATSU.xlsx',
#  'make_55.DAIMLER.xlsx',
#  'make_56.DATSUN.xlsx',
#  'make_57.DELAGE.xlsx',
#  'make_58.DELAHAYE.xlsx',
#  'make_59.DELLOW.xlsx',
#  'make_6.ALLSTATE.xlsx',
#  'make_60.DELOREAN.xlsx',
#  'make_61.DENZEL.xlsx',
#  'make_62.DESOTO.xlsx',
#  'make_63.DETOMASO.xlsx',
#  'make_64.DEUTSCH-BONNET.xlsx',
#  'make_65.DIANA.xlsx',
#  'make_66.DKW.xlsx',
#  'make_67.DODGE-serial_1.xlsx',
#  'make_67.DODGE-serial_2.xlsx',
#  'make_67.DODGE-serial_3.xlsx',
#  'make_67.DODGE-serial_4.xlsx',
#  'make_67.DODGE-serial_5.xlsx',
#  'make_67.DODGE-serial_6.xlsx',
#  'make_67.DODGE-serial_7.xlsx',
#  'make_68.DORETTI.xlsx',
#  'make_69.DU PONT.xlsx',
#  'make_7.ALPINE.xlsx',
#  'make_70.DUAL-GHIA.xlsx',
#  'make_71.DUESENBERG.xlsx',
#  'make_72.DURANT.xlsx',
#  'make_73.EAGLE.xlsx',
#  'make_74.EDSEL.xlsx',
#  'make_75.ELCAR.xlsx',
#  'make_76.ELVA.xlsx',
#  'make_77.ERSKINE.xlsx',
#  'make_78.ESSEX.xlsx',
#  'make_79.EXCALIBUR.xlsx',
#  'make_8.ALVIS.xlsx',
#  'make_80.FACEL VEGA.xlsx',
#  'make_81.FAIRTHORPE.xlsx',
#  'make_82.FALCON KNIGHT.xlsx',
#  'make_83.FARGO.xlsx',
#  'make_84.FAW.xlsx',
#  'make_85.FERRARI.xlsx',
#  'make_86.FIAT.xlsx',
#  'make_87.FISKER.xlsx',
#  'make_88.FLINT.xlsx',
#  'make_89.FORD-serial_1.xlsx',
#  'make_89.FORD-serial_10.xlsx',
#  'make_89.FORD-serial_11.xlsx',
#  'make_89.FORD-serial_12.xlsx',
#  'make_89.FORD-serial_2.xlsx',
#  'make_89.FORD-serial_3.xlsx',
#  'make_89.FORD-serial_4.xlsx',
#  'make_89.FORD-serial_5.xlsx',
#  'make_89.FORD-serial_6.xlsx',
#  'make_89.FORD-serial_7.xlsx',
#  'make_89.FORD-serial_8.xlsx',
#  'make_89.FORD-serial_9.xlsx',
#  'make_9.AM GENERAL.xlsx',
#  'make_90.FOTON.xlsx',
#  'make_91.FRANKLIN.xlsx',
#  'make_92.FRAZER NASH.xlsx',
#  'make_93.FREIGHTLINER.xlsx',
#  'make_94.GARDNER.xlsx',
#  'make_95.GENESIS.xlsx',
#  'make_96.GEO.xlsx',
#  'make_97.GIANT MOTORS.xlsx',
#  'make_98.GLAS.xlsx',
#  'make_99.GMC-serial_1.xlsx',
#  'make_99.GMC-serial_2.xlsx',
#  'make_99.GMC-serial_3.xlsx',
#  'make_99.GMC-serial_4.xlsx',
#  'make_99.GMC-serial_5.xlsx',
#  'make_99.GMC-serial_6.xlsx',
#  'make_99.GMC-serial_7.xlsx',
#  'make_99.GMC-serial_8.xlsx']

# %%
for file in list_file:

    # = = = = = = = = = = = = = = =

    import pandas as pd

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./{param_date}/7.group/{file}',
                           header=0,
                           dtype=str).fillna('')

    input_['Make No'] = input_['Make No'].astype(int)
    input_['Model No'] = input_['Model No'].astype(int)
    input_['Engine No'] = input_['Engine No'].astype(int)
    input_['Year'] = input_['Year'].astype(int)
    input_['Group No'] = input_['Group No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =

    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            import requests
            import json

            import sys
            sys.path.append('../../00.Tools')
            from crawler_configuration import get_header, get_proxy

            payload = {'jsn': {'tab': 'catalog',
                               'make': input_.loc[a, 'Make'],
                               'year': int(input_.loc[a, 'Year']),
                               'model': input_.loc[a, 'Model'],
                               'carcode': input_.loc[a, 'Car Code'],
                               'engine': input_.loc[a, 'Engine'],
                               'groupname': input_.loc[a, 'Group'],
                               'nodetype': 'groupname'}}

            data = {'func': 'navnode_fetch',
                    'payload': json.dumps(payload),
                    'api_json_request': '1'}

            try:
                b = 0
                while True:

                    while True:
                        b += 1
                        try:
                            resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                                 data=data,
                                                 headers=get_header(),
                                                 proxies=get_proxy(),
                                                 timeout=(10, 10))
                            break
                        except:
                            continue

                    if resp.status_code == 200:
                        json_ = resp.json()
                        if 'redirect_to_url' in json_:
                            continue
                        elif json_['jsn']['tab'] == 'catalog' and json_['jsn']['make'] == input_.loc[a, 'Make'] and json_['jsn']['year'] == input_.loc[a, 'Year'] and json_['jsn']['model'] == input_.loc[a, 'Model'] and json_['jsn']['carcode'] == input_.loc[a, 'Car Code'] and json_['jsn']['engine'] == input_.loc[a, 'Engine'] and json_['jsn']['groupname'] == input_.loc[a, 'Group'] and json_['jsn']['nodetype'] == 'groupname' and 'collected_javascript' in json_:
                            break

                # = = = = = = = = = = = = = = =

                from bs4 import BeautifulSoup
                from lxml import etree

                soup = BeautifulSoup(json_['html_fill_sections']['navchildren[]'], 'lxml')
                html = etree.HTML(str(soup))

                # = = = = = = = = = = = = = = =

                list_json = html.xpath('//input[contains(@id, "jsn[__GIP__")]/@value')

                # = = = = = = = = = = = = = = =

                list_type_code = [json.loads(json_)['parttype'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_type = html.xpath('//td[@class="nlabel"]/a/text()')

                # = = = = = = = = = = = = = = =

                if not list_type:
                    raise

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'Make No': input_.loc[a, 'Make No'],
                                        'Make': input_.loc[a, 'Make'],
                                        'Model No': input_.loc[a, 'Model No'],
                                        'Model': input_.loc[a, 'Model'],
                                        'Engine No': input_.loc[a, 'Engine No'],
                                        'Engine': input_.loc[a, 'Engine'],
                                        'Car Code': input_.loc[a, 'Car Code'],
                                        'Year': input_.loc[a, 'Year'],
                                        'Group No': input_.loc[a, 'Group No'],
                                        'Group': input_.loc[a, 'Group'],
                                        'Type No': [i+1 for i in range(len(list_type))],
                                        'Type': list_type,
                                        'Type Code': list_type_code,
                                        'Tab 1 Url': [f'''https://www.rockauto.com/en/catalog/{input_.loc[a, 'Make'].replace(',', '%2C')},{input_.loc[a, 'Year']},{input_.loc[a, 'Model'].replace(',', '%2C')},{input_.loc[a, 'Engine'].replace(',', '%2C')},{input_.loc[a, 'Car Code'].replace(',', '%2C')},{input_.loc[a, 'Group'].replace(',', '%2C')},{type_.replace(',', '%2C')},{type_code.replace(',', '%2C')}''' for type_, type_code in zip(list_type, list_type_code)]})

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([{'Make No': input_.loc[a, 'Make No'],
                                         'Make': input_.loc[a, 'Make'],
                                         'Model No': input_.loc[a, 'Model No'],
                                         'Model': input_.loc[a, 'Model'],
                                         'Engine No': input_.loc[a, 'Engine No'],
                                         'Engine': input_.loc[a, 'Engine'],
                                         'Car Code': input_.loc[a, 'Car Code'],
                                         'Year': input_.loc[a, 'Year'],
                                         'Group No': input_.loc[a, 'Group No'],
                                         'Group': input_.loc[a, 'Group']}])

                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Make No']}.{input_.loc[a, 'Make']} > {input_.loc[a, 'Model No']}.{input_.loc[a, 'Model']} > {input_.loc[a, 'Engine No']}.{input_.loc[a, 'Engine']} > {input_.loc[a, 'Year']} > {input_.loc[a, 'Group No']}.{input_.loc[a, 'Group']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(20):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No', 'Type No'],
                                                        ascending=[True, True, True, False, True, True],
                                                        ignore_index=True)
        output_correct.to_excel(f'''./{param_date}/8.type_1/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No'],
                                                ascending=[True, True, True, False, True],
                                                ignore_index=True)
        output_error.to_excel(f'''./{param_date}/8.type_1/0.error/{file.removesuffix('.xlsx')}-type_1_error.xlsx''', index=False)
        print('爬虫存在error')
        print()
    print('Done ~')
# Out:
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2010 > 21.Wiper & Washer
# [剩余数量：1000] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2009 > 1.Belt Drive
# [剩余数量：999] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2010 > 17.Steering
# [剩余数量：998] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2010 > 18.Suspension
# [剩余数量：997] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2009 > 5.Drivetrain
# [剩余数量：996] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2010 > 20.Wheel
# [剩余数量：995] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2010 > 19.Transmission-Automatic
# [剩余数量：994] - [当前时间：12:09:37]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2009 > 2.Body & Lamp Assembly
# [剩余数量：993] - [当前时间：12:09:38]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2009 > 3.Brake & Wheel Hub
# [剩余数量：992] - [当前时间：12:09:38]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2009 > 7.Electrical-Bulb & Socket
# [剩余数量：991] - [当前时间：12:09:38]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 

#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 10.Engine
# [剩余数量：841] - [当前时间：12:10:00]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 14.Ignition
# [剩余数量：840] - [当前时间：12:10:01]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 9.Electrical-Switch & Relay
# [剩余数量：839] - [当前时间：12:10:01]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 15.Interior
# [剩余数量：838] - [当前时间：12:10:01]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 5.Drivetrain
# [剩余数量：837] - [当前时间：12:10:01]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 18.Suspension
# [剩余数量：836] - [当前时间：12:10:01]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 19.Transmission-Automatic
# [剩余数量：835] - [当前时间：12:10:02]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 21.Wiper & Washer
# [剩余数量：834] - [当前时间：12:10:02]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 11.Exhaust & Emission
# [剩余数量：833] - [当前时间：12:10:02]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 2.Body & Lamp Assembly
# [剩余数量：832] - [当前时间：12:10:02]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 1.Belt Drive
# [剩余数量：831] - [当前时间：12:10:02]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 12.Fuel & Air
# [剩余数量：830] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 16.Literature
# [剩余数量：829] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 5.Drivetrain
# [剩余数量：828] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 6.Electrical
# [剩余数量：827] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 7.Electrical-Bulb & Socket
# [剩余数量：826] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：13] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2002 > 17.Steering
# [剩余数量：825] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 7.Electrical-Bulb & Socket
# [剩余数量：824] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 4.Cooling System
# [剩余数量：823] - [当前时间：12:10:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 8.Electrical-Connector
# [剩余数量：822] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 16.Literature
# [剩余数量：821] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 10.Engine
# [剩余数量：820] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 14.Ignition
# [剩余数量：819] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 13.Heat & Air Conditioning
# [剩余数量：818] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 19.Transmission-Automatic
# [剩余数量：817] - [当前时间：12:10:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 12.Fuel & Air
# [剩余数量：816] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 9.Electrical-Switch & Relay
# [剩余数量：815] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2005 > 6.Electrical
# [剩余数量：814] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2003 > 14.Ignition
# [剩余数量：813] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 20.Wheel
# [剩余数量：812] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 15.Interior
# [剩余数量：811] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 1.Belt Drive
# [剩余数量：810] - [当前时间：12:10:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 5.Drivetrain
# [剩余数量：809] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2004 > 18.Suspension
# [剩余数量：808] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 3.Brake & Wheel Hub
# [剩余数量：807] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 7.Electrical-Bulb & Socket
# [剩余数量：806] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 6.Electrical
# [剩余数量：805] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2005 > 4.Cooling System
# [剩余数量：804] - [当前时间：12:10:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 10.Engine
# [剩余数量：803] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 3.Brake & Wheel Hub
# [剩余数量：802] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 21.Wiper & Washer
# [剩余数量：801] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 11.Exhaust & Emission
# [剩余数量：800] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：13] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 4.Cooling System
# [剩余数量：799] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 13.Heat & Air Conditioning
# [剩余数量：798] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 18.Suspension
# [剩余数量：797] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 11.Exhaust & Emission
# [剩余数量：796] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 14.Ignition
# [剩余数量：795] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 9.Electrical-Switch & Relay
# [剩余数量：794] - [当前时间：12:10:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 2.Body & Lamp Assembly
# [剩余数量：793] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 12.Fuel & Air
# [剩余数量：792] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 15.Interior
# [剩余数量：791] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 18.Suspension
# [剩余数量：790] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 20.Wheel
# [剩余数量：789] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 16.Literature
# [剩余数量：788] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 19.Transmission-Automatic
# [剩余数量：787] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 8.Electrical-Connector
# [剩余数量：786] - [当前时间：12:10:08]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 2.Body & Lamp Assembly
# [剩余数量：785] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 21.Wiper & Washer
# [剩余数量：784] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2000 > 17.Steering
# [剩余数量：783] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 8.Electrical-Connector
# [剩余数量：782] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 7.Electrical-Bulb & Socket
# [剩余数量：781] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 14.Ignition
# [剩余数量：780] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 9.Electrical-Switch & Relay
# [剩余数量：779] - [当前时间：12:10:09]
#
# [状态：ok，尝试次数：7] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 5.Drivetrain
# [剩余数量：778] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 10.Engine
# [剩余数量：777] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 16.Literature
# [剩余数量：776] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 13.Heat & Air Conditioning
# [剩余数量：775] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 17.Steering
# [剩余数量：774] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 11.Exhaust & Emission
# [剩余数量：773] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：18] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 3.Brake & Wheel Hub
# [剩余数量：772] - [当前时间：12:10:10]
#
# [状态：ok，尝试次数：22] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 4.Cooling System
# [剩余数量：771] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 15.Interior
# [剩余数量：770] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2003 > 18.Suspension
# [剩余数量：769] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 20.Wheel
# [剩余数量：768] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 3.Brake & Wheel Hub
# [剩余数量：767] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 2.Body & Lamp Assembly
# [剩余数量：766] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 4.Cooling System
# [剩余数量：765] - [当前时间：12:10:11]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 21.Wiper & Washer
# [剩余数量：764] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 6.Electrical
# [剩余数量：763] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 1.Belt Drive
# [剩余数量：762] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：23] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 12.Fuel & Air
# [剩余数量：761] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 7.Electrical-Bulb & Socket
# [剩余数量：760] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 9.Electrical-Switch & Relay
# [剩余数量：759] - [当前时间：12:10:12]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 10.Engine
# [剩余数量：758] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2004 > 5.Drivetrain
# [剩余数量：757] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：16] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 5.Drivetrain
# [剩余数量：756] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：16] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 11.Exhaust & Emission
# [剩余数量：755] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：14] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 14.Ignition
# [剩余数量：754] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 15.Interior
# [剩余数量：753] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 18.Suspension
# [剩余数量：752] - [当前时间：12:10:13]
#
# [状态：ok，尝试次数：26] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 18.Suspension
# [剩余数量：751] - [当前时间：12:10:14]
#
# [状态：ok，尝试次数：18] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 13.Heat & Air Conditioning
# [剩余数量：750] - [当前时间：12:10:14]
#
# [状态：ok，尝试次数：11] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 17.Steering
# [剩余数量：749] - [当前时间：12:10:14]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 21.Wiper & Washer
# [剩余数量：748] - [当前时间：12:10:14]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 4.Cooling System
# [剩余数量：747] - [当前时间：12:10:14]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 2.Body & Lamp Assembly
# [剩余数量：746] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：12] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 1.Belt Drive
# [剩余数量：745] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 16.Literature
# [剩余数量：744] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 12.Fuel & Air
# [剩余数量：743] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 7.Electrical-Bulb & Socket
# [剩余数量：742] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2009 > 6.Electrical
# [剩余数量：741] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 9.Electrical-Switch & Relay
# [剩余数量：740] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：14] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 1.5.3L V8 > 2001 > 17.Steering
# [剩余数量：739] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 20.Wheel
# [剩余数量：738] - [当前时间：12:10:15]
#
# [状态：ok，尝试次数：16] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 6.Electrical
# [剩余数量：737] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 10.Engine
# [剩余数量：736] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 11.Exhaust & Emission
# [剩余数量：735] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 13.Heat & Air Conditioning
# [剩余数量：734] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：12] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 8.Electrical-Connector
# [剩余数量：733] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 16.Literature
# [剩余数量：732] - [当前时间：12:10:16]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 14.Ignition
# [剩余数量：731] - [当前时间：12:10:17]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 20.Wheel
# [剩余数量：730] - [当前时间：12:10:17]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 15.Interior
# [剩余数量：729] - [当前时间：12:10:17]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 21.Wiper & Washer
# [剩余数量：728] - [当前时间：12:10:17]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 19.Transmission-Automatic
# [剩余数量：727] - [当前时间：12:10:17]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 3.Brake & Wheel Hub
# [剩余数量：726] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：27] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 5.Drivetrain
# [剩余数量：725] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 4.Cooling System
# [剩余数量：724] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 18.Suspension
# [剩余数量：723] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 17.Steering
# [剩余数量：722] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：65] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 8.Electrical-Connector
# [剩余数量：721] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：24] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2007 > 12.Fuel & Air
# [剩余数量：720] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 6.Electrical
# [剩余数量：719] - [当前时间：12:10:18]
#
# [状态：ok，尝试次数：15] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 2.Body & Lamp Assembly
# [剩余数量：718] - [当前时间：12:10:19]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 1.Belt Drive
# [剩余数量：717] - [当前时间：12:10:19]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 11.Exhaust & Emission
# [剩余数量：716] - [当前时间：12:10:19]
#
# [状态：ok，尝试次数：7] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 8.Electrical-Connector
# [剩余数量：715] - [当前时间：12:10:19]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 12.Fuel & Air
# [剩余数量：714] - [当前时间：12:10:19]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 10.Engine
# [剩余数量：713] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：11] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 19.Transmission-Automatic
# [剩余数量：712] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：14] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 9.Electrical-Switch & Relay
# [剩余数量：711] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 17.Steering
# [剩余数量：710] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 16.Literature
# [剩余数量：709] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 14.Ignition
# [剩余数量：708] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 7.Electrical-Bulb & Socket
# [剩余数量：707] - [当前时间：12:10:20]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 18.Suspension
# [剩余数量：706] - [当前时间：12:10:21]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 20.Wheel
# [剩余数量：705] - [当前时间：12:10:21]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 3.Brake & Wheel Hub
# [剩余数量：704] - [当前时间：12:10:21]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 21.Wiper & Washer
# [剩余数量：703] - [当前时间：12:10:21]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 2.Body & Lamp Assembly
# [剩余数量：702] - [当前时间：12:10:21]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 7.Electrical-Bulb & Socket
# [剩余数量：701] - [当前时间：12:10:22]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 1.Belt Drive
# [剩余数量：700] - [当前时间：12:10:22]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 6.Electrical
# [剩余数量：699] - [当前时间：12:10:22]
#
# [状态：ok，尝试次数：8] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 13.Heat & Air Conditioning
# [剩余数量：698] - [当前时间：12:10:22]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 9.Electrical-Switch & Relay
# [剩余数量：697] - [当前时间：12:10:22]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 8.Electrical-Connector
# [剩余数量：696] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 4.Cooling System
# [剩余数量：695] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 15.Interior
# [剩余数量：694] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 13.Heat & Air Conditioning
# [剩余数量：693] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 10.Engine
# [剩余数量：692] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 18.Suspension
# [剩余数量：691] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 17.Steering
# [剩余数量：690] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 16.Literature
# [剩余数量：689] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 12.Fuel & Air
# [剩余数量：688] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：17] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 15.Interior
# [剩余数量：687] - [当前时间：12:10:23]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 5.Drivetrain
# [剩余数量：686] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 20.Wheel
# [剩余数量：685] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 2.Body & Lamp Assembly
# [剩余数量：684] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：7] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 11.Exhaust & Emission
# [剩余数量：683] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 14.Ignition
# [剩余数量：682] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 19.Transmission-Automatic
# [剩余数量：681] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 1.Belt Drive
# [剩余数量：680] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：11] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 5.Drivetrain
# [剩余数量：679] - [当前时间：12:10:24]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 6.Electrical
# [剩余数量：678] - [当前时间：12:10:25]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2005 > 21.Wiper & Washer
# [剩余数量：677] - [当前时间：12:10:25]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 5.Drivetrain
# [剩余数量：676] - [当前时间：12:10:25]
#
# [状态：ok，尝试次数：18] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2008 > 1.Belt Drive
# [剩余数量：675] - [当前时间：12:10:25]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2006 > 19.Transmission-Automatic
# [剩余数量：674] - [当前时间：12:10:25]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 11.Exhaust & Emission
# [剩余数量：673] - [当前时间：12:10:26]
#
# [状态：ok，尝试次数：9] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 3.Brake & Wheel Hub
# [剩余数量：672] - [当前时间：12:10:26]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 191.YUKON XL 1500 > 2.6.0L V8 > 2004 > 10.Engine
# ...
# [剩余数量：91] - [当前时间：12:11:51]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2006 > 13.Heat & Air Conditioning
# [剩余数量：90] - [当前时间：12:11:51]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2006 > 19.Transmission-Automatic
# [剩余数量：89] - [当前时间：12:11:51]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 11.Exhaust & Emission
# [剩余数量：88] - [当前时间：12:11:51]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 5.Drivetrain
# [剩余数量：87] - [当前时间：12:11:51]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 8.Electrical-Connector
# [剩余数量：86] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 16.Literature
# [剩余数量：85] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 13.Heat & Air Conditioning
# [剩余数量：84] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 10.Engine
# [剩余数量：83] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2006 > 1.Belt Drive
# [剩余数量：82] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2006 > 21.Wiper & Washer
# [剩余数量：81] - [当前时间：12:11:52]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 17.Steering
# [剩余数量：80] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 9.Electrical-Switch & Relay
# [剩余数量：79] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 12.Fuel & Air
# [剩余数量：78] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 19.Transmission-Automatic
# [剩余数量：77] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 2.6.0L V8 > 2001 > 18.Suspension
# [剩余数量：76] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 7.Electrical-Bulb & Socket
# [剩余数量：75] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 1.Belt Drive
# [剩余数量：74] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 18.Suspension
# [剩余数量：73] - [当前时间：12:11:53]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 2.Body & Lamp Assembly
# [剩余数量：72] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 15.Interior
# [剩余数量：71] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 3.Brake & Wheel Hub
# [剩余数量：70] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 5.Drivetrain
# [剩余数量：69] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 4.Cooling System
# [剩余数量：68] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 21.Wiper & Washer
# [剩余数量：67] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 14.Ignition
# [剩余数量：66] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 6.Electrical
# [剩余数量：65] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：7] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 2.6.0L V8 > 2000 > 3.Brake & Wheel Hub
# [剩余数量：64] - [当前时间：12:11:54]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 6.Electrical
# [剩余数量：63] - [当前时间：12:11:55]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 8.Electrical-Connector
# [剩余数量：62] - [当前时间：12:11:55]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 10.Engine
# [剩余数量：61] - [当前时间：12:11:55]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 9.Electrical-Switch & Relay
# [剩余数量：60] - [当前时间：12:11:55]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 12.Fuel & Air
# [剩余数量：59] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 11.Exhaust & Emission
# [剩余数量：58] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 17.Steering
# [剩余数量：57] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 18.Suspension
# [剩余数量：56] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 19.Transmission-Automatic
# [剩余数量：55] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 20.Wheel
# [剩余数量：54] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 1.Belt Drive
# [剩余数量：53] - [当前时间：12:11:56]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 15.Interior
# [剩余数量：52] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 21.Wiper & Washer
# [剩余数量：51] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：10] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 16.Literature
# [剩余数量：50] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 3.Brake & Wheel Hub
# [剩余数量：49] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 2.6.0L V8 > 2000 > 15.Interior
# [剩余数量：48] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 5.Drivetrain
# [剩余数量：47] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 7.Electrical-Bulb & Socket
# [剩余数量：46] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 11.Exhaust & Emission
# [剩余数量：45] - [当前时间：12:11:57]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 4.Cooling System
# [剩余数量：44] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 10.Engine
# [剩余数量：43] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 13.Heat & Air Conditioning
# [剩余数量：42] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：6] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 9.Electrical-Switch & Relay
# [剩余数量：41] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 8.Electrical-Connector
# [剩余数量：40] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 13.Heat & Air Conditioning
# [剩余数量：39] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 12.Fuel & Air
# [剩余数量：38] - [当前时间：12:11:58]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 15.Interior
# [剩余数量：37] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 16.Literature
# [剩余数量：36] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 18.Suspension
# [剩余数量：35] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 20.Wheel
# [剩余数量：34] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 21.Wiper & Washer
# [剩余数量：33] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 14.Ignition
# [剩余数量：32] - [当前时间：12:11:59]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 1.Belt Drive
# [剩余数量：31] - [当前时间：12:12:00]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 5.Drivetrain
# [剩余数量：30] - [当前时间：12:12:00]
#
# [状态：ok，尝试次数：3] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 3.Brake & Wheel Hub
# [剩余数量：29] - [当前时间：12:12:00]
#
# [状态：ok，尝试次数：5] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 2.Body & Lamp Assembly
# [剩余数量：28] - [当前时间：12:12:00]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 6.Electrical
# [剩余数量：27] - [当前时间：12:12:00]
#
# [状态：ok，尝试次数：7] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 4.Cooling System
# [剩余数量：26] - [当前时间：12:12:01]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 8.Electrical-Connector
# [剩余数量：25] - [当前时间：12:12:01]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 11.Exhaust & Emission
# [剩余数量：24] - [当前时间：12:12:01]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 12.Fuel & Air
# [剩余数量：23] - [当前时间：12:12:01]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 14.Ignition
# [剩余数量：22] - [当前时间：12:12:01]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 9.Electrical-Switch & Relay
# [剩余数量：21] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 14.Ignition
# [剩余数量：20] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 10.Engine
# [剩余数量：19] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 6.Electrical
# [剩余数量：18] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 2.Body & Lamp Assembly
# [剩余数量：17] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 20.Wheel
# [剩余数量：16] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 17.Steering
# [剩余数量：15] - [当前时间：12:12:02]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 15.Interior
# [剩余数量：14] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 18.Suspension
# [剩余数量：13] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 17.Steering
# [剩余数量：12] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 19.Transmission-Automatic
# [剩余数量：11] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 16.Literature
# [剩余数量：10] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 21.Wiper & Washer
# [剩余数量：9] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 2.Body & Lamp Assembly
# [剩余数量：8] - [当前时间：12:12:03]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 4.Cooling System
# [剩余数量：7] - [当前时间：12:12:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 6.Electrical
# [剩余数量：6] - [当前时间：12:12:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 7.Electrical-Bulb & Socket
# [剩余数量：5] - [当前时间：12:12:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 3.Brake & Wheel Hub
# [剩余数量：4] - [当前时间：12:12:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 10.Engine
# [剩余数量：3] - [当前时间：12:12:04]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 13.Heat & Air Conditioning
# [剩余数量：2] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 14.Ignition
# [剩余数量：1] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 11.Exhaust & Emission
# [剩余数量：0] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2004 > 7.Electrical-Bulb & Socket
# [剩余数量：0] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：4] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2003 > 19.Transmission-Automatic
# [剩余数量：0] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 1.Belt Drive
# [剩余数量：0] - [当前时间：12:12:05]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 17.Steering
# [剩余数量：0] - [当前时间：12:12:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 16.Literature
# [剩余数量：0] - [当前时间：12:12:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 19.Transmission-Automatic
# [剩余数量：0] - [当前时间：12:12:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 18.Suspension
# [剩余数量：0] - [当前时间：12:12:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 5.Drivetrain
# [剩余数量：0] - [当前时间：12:12:06]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 12.Fuel & Air
# [剩余数量：0] - [当前时间：12:12:07]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 21.Wiper & Washer
# [剩余数量：0] - [当前时间：12:12:08]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 15.Interior
# [剩余数量：0] - [当前时间：12:12:09]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 20.Wheel
# [剩余数量：0] - [当前时间：12:12:09]
#
# [状态：ok，尝试次数：1] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 7.Electrical-Bulb & Socket
# [剩余数量：0] - [当前时间：12:12:10]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2005 > 2.Body & Lamp Assembly
# [剩余数量：0] - [当前时间：12:12:12]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2002 > 13.Heat & Air Conditioning
# [剩余数量：0] - [当前时间：12:12:13]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2006 > 10.Engine
# [剩余数量：0] - [当前时间：12:12:14]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 9.Electrical-Switch & Relay
# [剩余数量：0] - [当前时间：12:12:16]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 20.Wheel
# [剩余数量：0] - [当前时间：12:12:17]
#
# [状态：ok，尝试次数：2] - 100.00% - make_99.GMC-serial_8 > 99.GMC > 192.YUKON XL 2500 > 3.8.1L V8 > 2001 > 8.Electrical-Connector
# [剩余数量：0] - [当前时间：12:12:25]
#
# 输出ing...
#
# 爬虫存在error
#
# Done ~
