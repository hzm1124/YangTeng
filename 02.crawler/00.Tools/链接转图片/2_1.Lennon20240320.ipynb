# %%
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter

# %%
wb = load_workbook('./part.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        column_src = column
    elif ws.cell(1, column).value == 'Pic':
        column_pic = column
        
print('总数量：' + str(ws.max_row-1))
column_src, get_column_letter(column_src), column_pic, get_column_letter(column_pic)
# Out:
# 总数量：100
# (8, 'H', 6, 'F')

# %%
import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

from io import BytesIO
from PIL import Image

# %%
a = 1

src = ws.cell(a+1, column_src).value

pic = Image.open(BytesIO(requests.get(src,
                                          headers=UA.get_User_Agent_Requests(),
                                          proxies=Proxy.get_Proxy_Requests()).content)).convert('RGB')

pic
# Out:
# <PIL.Image.Image image mode=RGB size=629x450>

# %%
pic.save('./pic/' + str(a) + '.png', 'png')

print('Done ~')
