# %%
import os

# %%
list_file = list(os.walk('./menu'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 16

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./menu/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df[['Page', 'No.', 'Part_Number', 'Url']]
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['Page', 'No.'], ascending=[True, True]).reset_index(drop=True)

df
# Out:
# Progress: 100%|█████████████████████████████| 16/16 [00:00<00:00, 807.88it/s]
#       Page  No. Part_Number                                                Url
# 0        1    1       A2039  https://portal.thepartshq.com/marmon-ride-cont...
# 1        1    2       A2073  https://portal.thepartshq.com/marmon-ride-cont...
# 2        1    3       A2107  https://portal.thepartshq.com/marmon-ride-cont...
# 3        1    4       A2143  https://portal.thepartshq.com/marmon-ride-cont...
# 4        1    5       A2162  https://portal.thepartshq.com/marmon-ride-cont...
# ...    ...  ...         ...                                                ...
# 1261    16   62       AM357  https://portal.thepartshq.com/marmon-ride-cont...
# 1262    16   63       AM369  https://portal.thepartshq.com/marmon-ride-cont...
# 1263    16   64       AM709  https://portal.thepartshq.com/marmon-ride-cont...
# 1264    16   65       AM902  https://portal.thepartshq.com/marmon-ride-cont...
# 1265    16   66       AM931  https://portal.thepartshq.com/marmon-ride-cont...
#
# [1266 rows x 4 columns]

# %%
df = df.drop_duplicates(['Part_Number'], keep='first').reset_index(drop=True)
df['No.'] = [i+1 for i in range(len(df))]
df.to_excel('./menu.xlsx', index=False)

df
# Out:
#       Page   No. Part_Number  \
# 0        1     1       A2039
# 1        1     2       A2073
# 2        1     3       A2107
# 3        1     4       A2143
# 4        1     5       A2162
# ...    ...   ...         ...
# 1261    16  1262       AM357
# 1262    16  1263       AM369
# 1263    16  1264       AM709
# 1264    16  1265       AM902
# 1265    16  1266       AM931
#
#                                                     Url
# 0     https://portal.thepartshq.com/marmon-ride-cont...
# 1     https://portal.thepartshq.com/marmon-ride-cont...
# 2     https://portal.thepartshq.com/marmon-ride-cont...
# 3     https://portal.thepartshq.com/marmon-ride-cont...
# 4     https://portal.thepartshq.com/marmon-ride-cont...
# ...                                                 ...
# 1261  https://portal.thepartshq.com/marmon-ride-cont...
# 1262  https://portal.thepartshq.com/marmon-ride-cont...
# 1263  https://portal.thepartshq.com/marmon-ride-cont...
# 1264  https://portal.thepartshq.com/marmon-ride-cont...
# 1265  https://portal.thepartshq.com/marmon-ride-cont...
#
# [1266 rows x 4 columns]
