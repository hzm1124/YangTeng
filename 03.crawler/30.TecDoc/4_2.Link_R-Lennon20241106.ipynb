# %%
from gevent import monkey
monkey.patch_all(thread=False)

from gevent.pool import Pool
pool = Pool(100)

from gevent.lock import BoundedSemaphore
semaphore_correct, semaphore_error, semaphore_remain = BoundedSemaphore(1), BoundedSemaphore(1), BoundedSemaphore(1)

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

directory_out = './file/4.link'

if os.path.exists(directory_out):
    shutil.rmtree(directory_out)
os.makedirs(directory_out)

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests
import json

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header

import time

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

# = = = = = = = = = = = = = = =

with open('./api.txt', 'r') as api_txt:
    api = api_txt.read()

# = = = = = = = = = = = = = = =

directory_in = './file/3.make'

list_file = [file for file in sorted(os.listdir(directory_in)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_in}/{file}')]
for file in list_file:

    # = = = = = = = = = = = = = = =

    list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(f'{directory_in}/{file}',
                                                                           header=0,
                                                                           dtype=str).fillna('')

    df_input['Part Code'] = df_input['Part Code'].astype(int)
    df_input['Make Code'] = df_input['Make Code'].astype(int)

    count_remain = len(df_input)

    print(f'总数量：{count_remain}')
    print()

    # = = = = = = = = = = = = = = =

    def crawler(crawler_tuple):
        global api, list_dict_correct, list_series_error, count_remain

        crawler_status, (crawler_index, crawler_series) = False, crawler_tuple

        # = = = = = = = = = = = = = = =

        try:
            data = {'getArticleLinkedAllLinkingTarget4': {'articleCountry': 'DE',
                                                          'articleId': crawler_series['Part Code'],
                                                          'country': 'DE',
                                                          'countryGroupFlag': False,
                                                          'lang': 'qa',
                                                          'linkingTargetManuId': crawler_series['Make Code'],
                                                          'linkingTargetType': 'VOLB',
                                                          'provider': 23365,
                                                          'withMainArticles': False}}

            count_retry = 0
            while True:
                count_retry += 1

                try:
                    url_check = crawler_series['Url']

                    resp = requests.post('https://webservice.tecalliance.services/pegasus-3-0/services/TecdocToCatDLB.jsonEndpoint',
                                         data=json.dumps(data),
                                         headers=get_header(**{'x-api-key': api}),
                                         timeout=(5, 15))

                    if resp.status_code == 200:
                        dict_ = resp.json()

                        if dict_['status'] == 401 and dict_['statusText'].strip() == 'Access not allowed':
                            print(f'fuck api {api}')
                            time.sleep(3)
                            with open('./api.txt', 'r') as api_txt:
                                api = api_txt.read()
                        elif dict_['status'] == 200:
                            break
                except KeyboardInterrupt:
                    break
                except:
                    continue

            # = = = = = = = = = = = = = = =

            list_link = dict_['data']['array'][0]['articleLinkages']['array']

            # = = = = = = = = = = = = = = =

            if not list_link:
                raise

            # = = = = = = = = = = = = = = =

            list_dict_link, index_begin, index_end = [], 0, 25
            while True:
                dict_link = {'array': []}
                if index_end < len(list_link):
                    for link in list_link[index_begin:index_end]:
                        dict_link['array'].append({'articleLinkId': link['articleLinkId'], 'linkingTargetId': link['linkingTargetId']})
                    list_dict_link.append(dict_link)
                    index_begin, index_end = index_end, index_end + 25
                else:
                    for link in list_link[index_begin:]:
                        dict_link['array'].append({'articleLinkId': link['articleLinkId'], 'linkingTargetId': link['linkingTargetId']})
                    list_dict_link.append(dict_link)
                    break

            # = = = = = = = = = = = = = = =

            with semaphore_correct:
                list_dict_correct.extend([{'Part Code': crawler_series['Part Code'],
                                           'Make': crawler_series['Make'],
                                           'Make Code': crawler_series['Make Code'],
                                           'JOIN_PCMC': crawler_series['JOIN_PCMC'],
                                           'Url': crawler_series['Url'],
                                           'Link No': i + 1,
                                           'Json_Link': json.dumps(dict_link),
                                           'JOIN_PCMCLN': f'''{crawler_series['JOIN_PCMC']};{i + 1}'''} for i, dict_link in enumerate(list_dict_link)])

            # = = = = = = = = = = = = = = =

            crawler_status = True
        except:
            crawler_series['Check_Url'] = url_check

            with semaphore_error:
                list_series_error.append(crawler_series)

        # = = = = = = = = = = = = = = =

        if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and count_remain == 1 or count_remain % 300 == 0 and count_remain != 0:
            clear_output()
        print(f'''[{crawler_status}] - [请求{count_retry}次] - [剩余{count_remain - 1}条] - [{file.removesuffix('.xlsx')}（{(list_file.index(file) + 1) / len(list_file) * 100:.2f}%）] - [{datetime.now().strftime('%Y/%m/%d %H:%M:%S')}] - {crawler_series['JOIN_PCMC']}. {url_check}\n''')

        with semaphore_remain:
            count_remain -= 1

    # = = = = = = = = = = = = = = =

    pool.map(crawler, df_input.iterrows())

    print('输出ing...')
    print()
    if list_dict_correct:
        df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['Part Code', 'Make', 'Link No'],
                                                                 ascending=[True, True, True],
                                                                 ignore_index=True)
        df_correct.to_excel(f'''{directory_out}/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if list_series_error:
        df_error = pd.DataFrame(list_series_error).sort_values(by=['Part Code', 'Make'],
                                                               ascending=[True, True],
                                                               ignore_index=True)
        df_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-link_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = [file for file in sorted(os.listdir(directory_out)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_out}/{file}')]
for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'{directory_out}/{file}',
              f'''{directory_out}/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：155
#
# [True] - [请求1次] - [剩余154条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;138. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余153条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;184. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余152条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;74. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余151条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余150条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;88. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余149条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;1138. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余148条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;183. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余147条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;1523. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余146条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余145条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;56. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余144条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余143条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;64. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余142条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余141条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余140条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余139条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余138条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;183. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余137条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695203;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566002/detail?groups=298
#
# [True] - [请求1次] - [剩余136条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余135条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695203;64. https://web.tecalliance.net/tecdoc/qa/parts/21/566002/detail?groups=298
#
# [True] - [请求1次] - [剩余134条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余133条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;75. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余132条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;183. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余131条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余130条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余129条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;1523. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余128条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;120. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余127条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余126条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余125条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余124条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;1523. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余123条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余122条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;882. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余121条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;21. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余120条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余119条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余118条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;88. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余117条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;5590. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余116条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;106. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余115条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余114条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;56. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余113条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;21. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余112条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;106. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余111条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;1526. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余110条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余109条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余108条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余107条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;2. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余106条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余105条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余104条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余103条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;139. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余102条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;819. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余101条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;2. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余100条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余99条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;63. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余98条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;2. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余97条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余96条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余95条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;3854. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余94条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;64. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余93条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余92条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695203;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566002/detail?groups=298
#
# [True] - [请求1次] - [剩余91条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695203;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566002/detail?groups=298
#
# [True] - [请求1次] - [剩余90条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695203;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566002/detail?groups=298
#
# [True] - [请求1次] - [剩余89条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;4468. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余88条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余87条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余86条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余85条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;4896. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余84条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余83条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;75. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余82条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;819. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余81条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余80条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余79条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余78条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;1820. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余77条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;776. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余76条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余75条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;776. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余74条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225695424;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566003/detail?groups=298
#
# [True] - [请求1次] - [剩余73条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;74. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余72条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;1820. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余71条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;106. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余70条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余69条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;74. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余68条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余67条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225694837;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566001/detail?groups=298
#
# [True] - [请求1次] - [剩余66条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余65条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;56. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余64条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697032;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566004/detail?groups=298
#
# [True] - [请求1次] - [剩余63条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余62条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余61条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余60条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;88. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余59条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225697307;3328. https://web.tecalliance.net/tecdoc/qa/parts/21/566005/detail?groups=298
#
# [True] - [请求1次] - [剩余58条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225699598;72. https://web.tecalliance.net/tecdoc/qa/parts/21/566006/detail?groups=298
#
# [True] - [请求1次] - [剩余57条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余56条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;882. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余55条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;21. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余54条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;819. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余53条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;120. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余52条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余51条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;88. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余50条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余49条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;92. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余48条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余47条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余46条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余45条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余44条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;111. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余43条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225701240;1138. https://web.tecalliance.net/tecdoc/qa/parts/21/566007/detail?groups=298
#
# [True] - [请求1次] - [剩余42条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;1820. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余41条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;776. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余40条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;72. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余39条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;842. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余38条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;92. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余37条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余36条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;106. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余35条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;1138. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余34条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;74. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余33条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;819. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余32条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;5. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余31条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余30条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;120. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余29条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余28条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;2. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余27条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;139. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余26条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225702870;111. https://web.tecalliance.net/tecdoc/qa/parts/21/566008/detail?groups=298
#
# [True] - [请求1次] - [剩余25条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;64. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余24条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;882. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余23条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;776. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余22条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;39. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余21条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;56. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余20条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;84. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余19条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;36. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余18条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;35. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余17条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;138. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余16条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;121. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余15条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;21. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余14条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# [True] - [请求1次] - [剩余13条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;99. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# [True] - [请求1次] - [剩余12条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;120. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余11条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;88. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余10条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;104. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余9条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;1523. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余8条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;866. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# [True] - [请求1次] - [剩余7条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;74. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余6条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;93. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余5条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;80. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余4条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;819. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# [True] - [请求1次] - [剩余3条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;111. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余2条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;2. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# [True] - [请求1次] - [剩余1条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225703574;1138. https://web.tecalliance.net/tecdoc/qa/parts/21/566009/detail?groups=298
#
# [True] - [请求1次] - [剩余0条] - [crawler_1（50.00%）] - [2024/11/07 10:06:45] - 1225705105;16. https://web.tecalliance.net/tecdoc/qa/parts/21/566010/detail?groups=298
#
# 输出ing...
#
# 总数量：2
#
# [True] - [请求1次] - [剩余1条] - [crawler_2（100.00%）] - [2024/11/07 10:06:46] - 936763199;74. https://web.tecalliance.net/tecdoc/qa/parts/30/3 397 001 013/detail?groups=298
#
# [True] - [请求1次] - [剩余0条] - [crawler_2（100.00%）] - [2024/11/07 10:06:46] - 2680287;74. https://web.tecalliance.net/tecdoc/qa/parts/30/3 397 001 014/detail?groups=298
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 2728.89it/s]
# Done ~
