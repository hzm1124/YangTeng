# %%
import os

list_file = sorted(list(os.walk('./file/3.auth'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx', 'crawler_2.xlsx']

# %%
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/3.auth/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Part Number'].tolist()
# Out:
# 总数量：1401
# ['40-1000',
#  '40-10000',
#  '40-10005',
#  '40-10006',
#  '40-10007',
#  '40-10009',
#  '40-1001',
#  '40-10013',
#  '40-10014',
#  '40-10015',
#  '40-10016',
#  '40-10019',
#  '40-1002',
#  '40-10020',
#  '40-10021',
#  '40-10022',
#  '40-10024',
#  '40-1003',
#  '40-10034',
#  '40-10035',
#  '40-10037',
#  '40-1004',
#  '40-1005',
#  '40-1006',
#  '40-1007',
#  '40-1008',
#  '40-1009',
#  '40-101',
#  '40-1010',
#  '40-1011',
#  '40-1012',
#  '40-1013',
#  '40-1014',
#  '40-1015',
#  '40-1016',
#  '40-1017',
#  '40-1018',
#  '40-1019',
#  '40-1020',
#  '40-1025',
#  '40-1026',
#  '40-1027',
#  '40-1029',
#  '40-1030',
#  '40-1031',
#  '40-1032L',
#  '40-1033',
#  '40-1034',
#  '40-1035',
#  '40-1036',
#  '40-1037',
#  '40-1038',
#  '40-1039',
#  '40-1040',
#  '40-1041',
#  '40-1042',
#  '40-1043',
#  '40-1044',
#  '40-1045',
#  '40-1046',
#  '40-1047',
#  '40-1048',
#  '40-1049',
#  '40-1050L',
#  '40-1051',
#  '40-1053',
#  '40-1054',
#  '40-1055',
#  '40-1056',
#  '40-1057',
#  '40-1058',
#  '40-1059',
#  '40-1060',
#  '40-1061',
#  '40-1062',
#  '40-1063',
#  '40-1064',
#  '40-1065',
#  '40-1067',
#  '40-1068',
#  '40-1069',
#  '40-1070',
#  '40-1071',
#  '40-1072',
#  '40-1074L',
#  '40-1075L',
#  '40-1076L',
#  '40-1077',
#  '40-1080',
#  '40-1081',
#  '40-1082',
#  '40-1083',
#  '40-1084',
#  '40-1085',
#  '40-1086',
#  '40-1087',
#  '40-1088',
#  '40-1089',
#  '40-1094',
#  '40-1095',
#  '40-1096',
#  '40-1097',
#  '40-1101',
#  '40-1102',
#  '40-1103',
#  '40-1104',
#  '40-1105',
#  '40-1107',
#  '40-1108',
#  '40-1110',
#  '40-1113',
#  '40-1114',
#  '40-1115',
#  '40-1118',
#  '40-1119',
#  '40-1120',
#  '40-1122',
#  '40-1125',
#  '40-1126',
#  '40-118',
#  '40-119',
#  '40-120',
#  '40-121',
#  '40-140',
#  '40-142',
#  '40-146',
#  '40-148',
#  '40-152',
#  '40-154',
#  '40-155',
#  '40-156',
#  '40-158',
#  '40-159',
#  '40-160',
#  '40-162',
#  '40-163',
#  '40-166',
#  '40-168',
#  '40-1681',
#  '40-1682',
#  '40-169',
#  '40-175',
#  '40-176',
#  '40-177',
#  '40-178',
#  '40-179',
#  '40-180',
#  '40-181',
#  '40-182',
#  '40-183',
#  '40-184',
',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '3',
#     'SubmodelID': '2477',
#     'VehicleID': '77779',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'MEX',
#     'SubModelName': 'Lujo',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'DeM9i_DynfYTYzhp785gH8_bb2s=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '3',
#     'SubmodelID': '20',
#     'VehicleID': '77778',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'MEX',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'O7wPZlqlHm2KY_KCiT2OBVrXt8M=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '1',
#     'SubmodelID': '454',
#     'VehicleID': '6095',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Z28 SS',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1441',
#       'EngBoreStrokeID': '166',
#       'EngineBaseID': '417',
#       'EngineDesignationID': '115',
#       'EngineDesignationName': 'LS1',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '29',
#       'EngineVINName': 'G',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 's99mZzp-EAc8Unky0KC9JNPctmo=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '1',
#     'SubmodelID': '450',
#     'VehicleID': '6108',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1441',
#       'EngBoreStrokeID': '166',
#       'EngineBaseID': '417',
#       'EngineDesignationID': '115',
#       'EngineDesignationName': 'LS1',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '29',
#       'EngineVINName': 'G',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'aICJMZ5rB2Wk2tt-b3k6lpP-iyg=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '6036',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'ziYI_OGqCigmDIYvV33iOo2rKfw=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '2',
#     'SubmodelID': '450',
#     'VehicleID': '44356',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'CAN',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1441',
#       'EngBoreStrokeID': '166',
#       'EngineBaseID': '417',
#       'EngineDesignationID': '115',
#       'EngineDesignationName': 'LS1',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '29',
#       'EngineVINName': 'G',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'n4Sn8bU3q9BSDAb489bTrGWJ3dg=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3107',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '44355',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1998',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68430',
#     'BaseVehicleId': '3107',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'GYEXLe6NU9jZYkAOEX8uHPCiRHI=',
#    'vs': 'DZ6Gj513sp5rHfAF4AFvZJqfQ-I='}},
#  {'__instanceId': 'NBCnNA0zTeJP6BI6TbqmUWxUeBY=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '3',
#     'SubmodelID': '2477',
#     'VehicleID': '77718',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'MEX',
#     'SubModelName': 'Lujo',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': '6dIlOH9hlU0KyC2m_zM3ReGQQoQ=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '3',
#     'SubmodelID': '20',
#     'VehicleID': '77717',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'MEX',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'xYnSs1oDb9bL1cGUY1RlUp9tpto=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '3',
#     'SubmodelID': '450',
#     'VehicleID': '77719',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'MEX',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'QnP4gOHn_nulJ4n_rIjU6krbM3Y=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '1',
#     'SubmodelID': '450',
#     'VehicleID': '6106',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'KIuJOktRlv720ia4VPpr47F3B00=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '1',
#     'SubmodelID': '148',
#     'VehicleID': '6092',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'RS',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'mTeXgRWJ2Ba6LhMvF8nN4X-iu9A=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '6034',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '9',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'RG0JKcH0vvFfnO05OJSQlha3AlY=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '44347',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '9',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'RTuS9-RNCBQ2vOwIFTf0qYyBLvk=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '2',
#     'SubmodelID': '148',
#     'VehicleID': '44348',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'CAN',
#     'SubModelName': 'RS',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '156',
#       'BlockType': 'V',
#       'CC': '3800',
#       'CID': '231',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '1217',
#       'EngBoreStrokeID': '138',
#       'EngineBaseID': '363',
#       'EngineDesignationID': '15485',
#       'EngineDesignationName': 'L36',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '11',
#       'EngineVersionName': 'Buick',
#       'EngineVINID': '26',
#       'EngineVINName': 'K',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.8,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': '1q2_Px_KvLWili5mevV2aoyFB3k=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3105',
#     'RegionID': '2',
#     'SubmodelID': '450',
#     'VehicleID': '44349',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'CAN',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1996',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68432',
#     'BaseVehicleId': '3105',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': '3WXRBxDxU77h_f2To0pSS50Lcn8=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3103',
#     'RegionID': '1',
#     'SubmodelID': '450',
#     'VehicleID': '6104',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Z28',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '7',
#       'ABSName': '2-Wheel ABS',
#       'ConfigID': '12',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '68434',
#     'BaseVehicleId': '3103',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'FOOfYakRV7b-g1ScXdxdFt3zFa8=',
#    'vs': '1zFbfkBrEt3GriDG1lT9vnAgpn4='}},
#  {'__instanceId': 'lU9kmBxJshLLpTKsB7jGHARlDK4=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.534Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3103',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '6032',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '432',
#     'ModelName': 'Camaro',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '170',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '207',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '3176',
#       'EngBoreStrokeID': '149',
#       'EngineBaseID': '380',
#       'EngineDesignationID': '16423',
#       'EngineDesignationName': 'L32',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '16',
#       'EngineVINName': 'S',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.4,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '7',
#       'ABSName': '2-Wheel ABS',
#       'ConfigID': '12',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '9',
#       'FrontBrakeTypeID': '5',
# ...
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '10352',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '170',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '207',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '3176',
#       'EngBoreStrokeID': '149',
#       'EngineBaseID': '380',
#       'EngineDesignationID': '16423',
#       'EngineDesignationName': 'L32',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '16',
#       'EngineVINName': 'S',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.4,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'},
#      {'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '9',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}},
#  {'__instanceId': '-DjWY4S5aRFEaAepqDy0u6LkBfQ=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '2',
#     'SubmodelID': '631',
#     'VehicleID': '48082',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'CAN',
#     'SubModelName': 'Trans Am',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}},
#  {'__instanceId': 'tZJR02QqZ7WffOzfmHaRSLpGpbc=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '48080',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '170',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '207',
#       'Cylinders': 6,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '3176',
#       'EngBoreStrokeID': '149',
#       'EngineBaseID': '380',
#       'EngineDesignationID': '16423',
#       'EngineDesignationName': 'L32',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '16',
#       'EngineVINName': 'S',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '6',
#       'Liter': 3.4,
#       'PowerOutputID': '1',
#       'ValvesID': '2',
#       'ValvesPerEngine': 12}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '9',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}},
#  {'__instanceId': 'EtDa5_Qti3ecjYhJnqdXFi9v0_I=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '2',
#     'SubmodelID': '632',
#     'VehicleID': '48083',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'CAN',
#     'SubModelName': 'Trans Am GT',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}},
#  {'__instanceId': 'sowKVPbEBQMn9JWK13CIaw_XFbA=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '2',
#     'SubmodelID': '629',
#     'VehicleID': '48081',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'CAN',
#     'SubModelName': 'Formula',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'},
#      {'BodyTypeID': '10',
#       'BodyTypeName': 'Convertible',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '8'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}},
#  {'__instanceId': 'pDP0s_LzNFOQ6kPuqv6sl_Qvo10=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:29:55.681Z',
#   'createdOn': '',
#   'productSKU': '40-1000',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '6510', 'text': 'Motor without Washer Pump'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '4671',
#     'RegionID': '3',
#     'SubmodelID': '631',
#     'VehicleID': '214776',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '595',
#     'ModelName': 'Firebird',
#     'RegionName': 'MEX',
#     'SubModelName': 'Trans Am',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1994',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '37',
#       'BlockType': 'V',
#       'CC': '-',
#       'CID': '350',
#       'Cylinders': 8,
#       'CylinderHeadTypeID': '7',
#       'CylinderHeadTypeName': 'OHV',
#       'EngineConfigID': '6119',
#       'EngBoreStrokeID': '31',
#       'EngineBaseID': '62',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '41',
#       'EngineVINName': 'P',
#       'FuelDeliverySubTypeID': '5',
#       'FuelDeliverySubTypeName': 'MFI',
#       'FuelDeliveryTypeID': '5',
#       'FuelDeliveryTypeName': 'FI',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 5.7,
#       'PowerOutputID': '1',
#       'ValvesID': '3',
#       'ValvesPerEngine': 16}],
#     'Bodies': [{'BodyTypeID': '9',
#       'BodyTypeName': 'Coupe',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '7'}],
#     'Brakes': [{'ABSID': '8',
#       'ABSName': '4-Wheel ABS',
#       'ConfigID': '6',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '5',
#       'RearBrakeTypeName': 'Disc',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '1',
#       'SystemID': '5',
#       'SystemName': 'Power',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '429009',
#     'BaseVehicleId': '4671',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Windshield Wiper Motor',
#     'PositionId': '22',
#     'Part': '40-1000',
#     'PositionName': 'Front'}},
#   'source': 'aces',
#   'h': {'ve': 'finCy8KdtacKFyI1EjBLfKPoRL4=',
#    'vs': '9E8SM5Xqy1H5SeJtkUS8i7Il4zs='}}]

# %%
list_make = [json_['fitment']['Vcdb']['MakeName'].strip() for json_ in list_json]

list_make
# Out:
# ['Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac',
#  'Pontiac']

# %%
list_model = [json_['fitment']['Vcdb']['ModelName'].strip() for json_ in list_json]

list_model
# Out:
# ['Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Camaro',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird',
#  'Firebird']

# %%
list_region = [json_['fitment']['Vcdb']['RegionName'].strip() for json_ in list_json]

list_region
# Out:
# ['MEX',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'MEX',
#  'MEX',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'MEX']

# %%
list_submodel = [json_['fitment']['Vcdb']['SubModelName'].strip() for json_ in list_json]

list_submodel
# Out:
# ['Lujo',
#  'Base',
#  'Z28 SS',
#  'Z28',
#  'Base',
#  'Z28',
#  'Base',
#  'Lujo',
#  'Base',
#  'Z28',
#  'Z28',
#  'RS',
#  'Base',
#  'Base',
#  'RS',
#  'Z28',
#  'Z28',
#  'Base',
#  'Base',
#  'Z28',
#  'Base',
#  'Indianapolis 500 Pace Car',
#  'Z28',
#  'Indianapolis 500 Pace Car',
#  'Base',
#  'Z28',
#  'Base',
#  'Lujo',
#  'Base',
#  'RS',
#  'Z28',
#  'Z28',
#  'RS',
#  'Base',
#  'Z28',
#  'Base',
#  'Z28',
#  'Z28',
#  'Base',
#  'Trans Am',
#  'Trans Am',
#  'Formula',
#  'Base',
#  'Trans Am',
#  'Formula',
#  'Base',
#  'Trans Am',
#  'Base',
#  'Formula',
#  'Trans Am',
#  'Base',
#  'Trans Am',
#  'Formula',
#  'Base',
#  'Trans Am',
#  'Formula',
#  'Formula',
#  'Base',
#  'Trans Am',
#  'Trans Am',
#  'Base',
#  'Formula',
#  'Trans Am',
#  'Base',
#  'Formula',
#  'Trans Am',
#  'Trans Am',
#  'Trans Am',
#  'Base',
#  'Formula',
#  'Base',
#  'Formula',
#  'Trans Am',
#  'Trans Am',
#  'Trans Am GT',
#  'Formula',
#  'Base',
#  'Trans Am',
#  'Base',
#  'Trans Am GT',
#  'Formula',
#  'Trans Am']

# %%
list_vehicle_type = [json_['fitment']['Vcdb']['VehicleTypeName'].strip() for json_ in list_json]

list_vehicle_type
# Out:
# ['Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car',
#  'Car']

# %%
list_year = [int(json_['fitment']['Vcdb']['Year'].strip()) for json_ in list_json]

list_year
# Out:
# [1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1994,
#  1994,
#  1994,
#  1994,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1998,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1996,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1997,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994]

# %%
list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter = [], [], [], [], []
list_list_engine = [json_['fitment']['Vcdb']['Engines'] for json_ in list_json]
for list_engine in list_list_engine:
    if list_engine:
        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [], [], [], [], []
        for engine in list_engine:
            list_aspiration.append(engine['AspirationName'].strip() if 'AspirationName' in engine and engine['AspirationName'].strip() != '-' else '')

            # = = = = = = = = = = = = = = =
            
            cylinder = ''
            if 'BlockType' in engine and engine['BlockType'].strip() != '-':
                cylinder += engine['BlockType'].strip()
            if 'Cylinders' in engine and engine['Cylinders'] != 0:
                cylinder += str(engine['Cylinders'])
            list_cylinder.append(cylinder)
            
            # = = = = = = = = = = = = = = =

            displacement = ''
            if engine['CID'].strip() != '-':
                displacement += f'''{engine['CID'].strip()}cid'''
            elif engine['CC'].strip() != '-':
                displacement += f'''/{engine['CC'].strip()}cc'''
            list_displacement.append(displacement.removeprefix('/'))
            
            # = = = = = = = = = = = = = = =

            list_fuel.append(engine['FuelTypeName'].strip() if 'FuelTypeName' in engine else '')

            # = = = = = = = = = = = = = = =

            list_liter.append(f'''{engine['Liter']}L''' if 'Liter' in engine and engine['Liter'] != 0 else '')
    else:
        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [''], [''], [''], [''], ['']

    list_list_aspiration.append(list_aspiration)
    list_list_cylinder.append(list_cylinder)
    list_list_displacement.append(list_displacement)
    list_list_fuel.append(list_fuel)
    list_list_liter.append(list_liter)

list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter
# Out:
# ([['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated'],
#   ['Naturally Aspirated']],
#  [['V6'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V6'],
#   ['V6'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V6'],
#   ['V6'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V6'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V6'],
#   ['V6'],
#   ['V6'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V6'],
#   ['V8'],
#   ['V6', 'V6'],
#   ['V8'],
#   ['V8'],
#   ['V6', 'V6'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V6', 'V6'],
#   ['V8'],
#   ['V6', 'V6'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V6'],
#   ['V8'],
#   ['V8'],
#   ['V8']],
#  [['231cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['231cid'],
#   ['231cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['231cid'],
#   ['231cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['207cid'],
#   ['207cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['231cid'],
#   ['231cid'],
#   ['231cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['231cid'],
#   ['350cid'],
#   ['231cid', '207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid', '207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['231cid', '207cid'],
#   ['350cid'],
#   ['231cid', '207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['207cid'],
#   ['350cid'],
#   ['350cid'],
#   ['350cid']],
#  [['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS', 'GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS', 'GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS', 'GAS'],
#   ['GAS'],
#   ['GAS', 'GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS'],
#   ['GAS']],
#  [['3.8L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['3.8L', '3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L', '3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.8L', '3.4L'],
#   ['5.7L'],
#   ['3.8L', '3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['3.4L'],
#   ['5.7L'],
#   ['5.7L'],
#   ['5.7L']])

# %%
list_list_drive_type = []
list_list_drive_type_2 = [json_['fitment']['Vcdb']['DriveTypes'] for json_ in list_json]
for list_drive_type_2 in list_list_drive_type_2:
    if list_drive_type_2:
        list_drive_type = []
        for drive_type_2 in list_drive_type_2:
            list_drive_type.append(drive_type_2['DriveTypeName'].strip())
    else:
        list_drive_type = ['']

    list_list_drive_type.append(list_drive_type)

list_list_drive_type
# Out:
# [['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD']]

# %%
list_position = [json_['fitment']['acesCriteria']['PositionName'].strip() if 'PositionName' in json_['fitment']['acesCriteria'] else '' for json_ in list_json]

list_position
# Out:
# ['Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front',
#  'Front']

# %%
df_temp = pd.DataFrame()
for i in range(len(list_json)):
    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                 'Part Number': input_.loc[a, 'Part Number'],
                                 'Auth': input_.loc[a, 'Auth'],
                                 'Vehicle Type': list_vehicle_type[i],
                                 'Region': list_region[i],
                                 'Make': list_make[i],
                                 'Model': list_model[i],
                                 'Submodel': list_submodel[i],
                                 'Cylinder': list_list_cylinder[i],
                                 'Displacement': list_list_displacement[i],
                                 'Liter': list_list_liter[i],
                                 'Year': list_year[i],
                                 'Fuel': list_list_fuel[i],
                                 'Aspiration': list_list_aspiration[i]})
    for j in range(len(list_list_drive_type[i])):
        df_temp_temp_temp = df_temp_temp.copy()
        df_temp_temp_temp['Drive Type'] = list_list_drive_type[i][j]
        df_temp_temp_temp['Position'] = list_position[i]
        df_temp = pd.concat([df_temp, df_temp_temp_temp], ignore_index=True).fillna('')

df_temp = df_temp.drop_duplicates(keep='first', ignore_index=True)
df_temp = df_temp.sort_values(by=['Vehicle Type', 'Region', 'Make', 'Model', 'Submodel', 'Cylinder', 'Displacement', 'Liter', 'Year', 'Fuel', 'Aspiration', 'Drive Type', 'Position'],
                              ascending=[True, True, True, True, True, True, True, True, False, True, True, True, True],
                              ignore_index=True)

df_temp['Row'] = [i+1 for i in range(len(df_temp))]

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#     No Part Number Vehicle Type Region       Make     Model     Submodel  \
# 0    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 1    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 2    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 3    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 4    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# ..  ..         ...          ...    ...        ...       ...          ...
# 81   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 82   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 83   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 84   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 85   1     40-1000          Car    USA    Pontiac  Firebird  Trans Am GT
#
#    Cylinder Displacement Liter  Year Fuel           Aspiration Drive Type  \
# 0        V6       207cid  3.4L  1995  GAS  Naturally Aspirated        RWD
# 1        V6       207cid  3.4L  1994  GAS  Naturally Aspirated        RWD
# 2        V6       207cid  3.4L  1993  GAS  Naturally Aspirated        RWD
# 3        V6       231cid  3.8L  1998  GAS  Naturally Aspirated        RWD
# 4        V6       231cid  3.8L  1997  GAS  Naturally Aspirated        RWD
# ..      ...          ...   ...   ...  ...                  ...        ...
# 81       V8       350cid  5.7L  1996  GAS  Naturally Aspirated        RWD
# 82       V8       350cid  5.7L  1995  GAS  Naturally Aspirated        RWD
# 83       V8       350cid  5.7L  1994  GAS  Naturally Aspirated        RWD
# 84       V8       350cid  5.7L  1993  GAS  Naturally Aspirated        RWD
# 85       V8       350cid  5.7L  1994  GAS  Naturally Aspirated        RWD
#
#    Position  Row
# 0     Front    1
# 1     Front    2
# 2     Front    3
# 3     Front    4
# 4     Front    5
# ..      ...  ...
# 81    Front   82
# 82    Front   83
# 83    Front   84
# 84    Front   85
# 85    Front   86
#
# [86 rows x 16 columns]

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No', 'Row'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct[['No',
                    'Part Number',
                    'Auth',
                    'Row',
                    'Vehicle Type',
                    'Region',
                    'Make',
                    'Model',
                    'Submodel',
                    'Cylinder',
                    'Displacement',
                    'Liter',
                    'Year',
                    'Fuel',
                    'Aspiration',
                    'Drive Type',
                    'Position']].to_excel('./test_vehicle.xlsx', index=False)

output_correct
# Out:
#     No Part Number Vehicle Type Region       Make     Model     Submodel  \
# 0    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 1    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 2    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 3    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# 4    1     40-1000          Car    CAN  Chevrolet    Camaro         Base
# ..  ..         ...          ...    ...        ...       ...          ...
# 81   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 82   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 83   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 84   1     40-1000          Car    USA    Pontiac  Firebird     Trans Am
# 85   1     40-1000          Car    USA    Pontiac  Firebird  Trans Am GT
#
#    Cylinder Displacement Liter  Year Fuel           Aspiration Drive Type  \
# 0        V6       207cid  3.4L  1995  GAS  Naturally Aspirated        RWD
# 1        V6       207cid  3.4L  1994  GAS  Naturally Aspirated        RWD
# 2        V6       207cid  3.4L  1993  GAS  Naturally Aspirated        RWD
# 3        V6       231cid  3.8L  1998  GAS  Naturally Aspirated        RWD
# 4        V6       231cid  3.8L  1997  GAS  Naturally Aspirated        RWD
# ..      ...          ...   ...   ...  ...                  ...        ...
# 81       V8       350cid  5.7L  1996  GAS  Naturally Aspirated        RWD
# 82       V8       350cid  5.7L  1995  GAS  Naturally Aspirated        RWD
# 83       V8       350cid  5.7L  1994  GAS  Naturally Aspirated        RWD
# 84       V8       350cid  5.7L  1993  GAS  Naturally Aspirated        RWD
# 85       V8       350cid  5.7L  1994  GAS  Naturally Aspirated        RWD
#
#    Position  Row
# 0     Front    1
# 1     Front    2
# 2     Front    3
# 3     Front    4
# 4     Front    5
# ..      ...  ...
# 81    Front   82
# 82    Front   83
# 83    Front   84
# 84    Front   85
# 85    Front   86
#
# [86 rows x 16 columns]

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
