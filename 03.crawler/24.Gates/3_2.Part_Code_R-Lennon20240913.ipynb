# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/3.part_code'):
    shutil.rmtree('./file/3.part_code')

os.makedirs('./file/3.part_code')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import time

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.page'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/2.page/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['Product No'] = input_['Product No'].astype(int)
    input_['SKU Count'] = input_['SKU Count'].astype(int)
    input_['Page'] = input_['Page'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                list_part_code, list_type = [], []
                while len(list_part_code) < input_.loc[a, 'SKU Count']:
                    for i in range(input_.loc[a, 'Page']):
                        b = 0
                        while True:
                            b += 1
                            
                            try:
                                resp = requests.get(f'''https://www.gates.com/bin/listing/products/variant?draw=1&columns%5B0%5D%5Bdata%5D=&columns%5B0%5D%5Bname%5D=partnumberauto_en_string&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=&columns%5B1%5D%5Bname%5D=productnumber_en_string&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=name_text_en&columns%5B2%5D%5Bname%5D=name_text_en&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=1&order%5B0%5D%5Bdir%5D=asc&start={i * 10}&length=10&search%5Bvalue%5D=&search%5Bregex%5D=false&id={input_.loc[a, 'Product Number']}&lang=en&country=us&fieldList=code_string,partnumberauto_en_string,productnumber_en_string,name_text_en&filters=&_={int(time.time() * 1000)}''',
                                                headers=get_header(),
                                                proxies=get_proxy(),
                                                timeout=(10, 10))

                                if resp.status_code == 200:
                                    json_ = resp.json()
                
                                    if json_:
                                        break
                            except KeyboardInterrupt:
                                break
                            except:
                                continue
                
                        # = = = = = = = = = = = = = = =

                        for dict_ in json_['data']:
                            if dict_['code_string'] not in dict_:
                                list_part_code.append(dict_['code_string'])
                                list_type.append(dict_['itemtype_string'])

                        # = = = = = = = = = = = = = = =

                        if work.qsize() % 100 == 0 and work.qsize() != 0:
                            clear_output()
    
                        print(f'''[尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Product No']}.{input_.loc[a, 'Product Name']} > Page {i+1}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                        # = = = = = = = = = = = = = = =
                
                        if len(list_part_code) == input_.loc[a, 'SKU Count']:
                            break

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'Product No': input_.loc[a, 'Product No'],
                                        'Product Name': input_.loc[a, 'Product Name'],
                                        'Product Number': input_.loc[a, 'Product Number'],
                                        'SKU Count': input_.loc[a, 'SKU Count'],
                                        'Page': input_.loc[a, 'Page'],
                                        'No': [i+1 for i in range(len(list_part_code))],
                                        'Type': list_type,
                                        'Part Code': list_part_code})
                
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['Product No', 'No'],
                                                    ascending=[True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/3.part_code/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['Product No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-part_code_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/3.part_code'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/3.part_code/{file}',
              f'''./file/3.part_code/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：1
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 1
# [剩余数量：0] - [当前时间：15:29:14]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 2
# [剩余数量：0] - [当前时间：15:29:17]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 3
# [剩余数量：0] - [当前时间：15:29:19]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 4
# [剩余数量：0] - [当前时间：15:29:22]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 5
# [剩余数量：0] - [当前时间：15:29:25]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 6
# [剩余数量：0] - [当前时间：15:29:27]
#
# [尝试次数：5] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 7
# [剩余数量：0] - [当前时间：15:29:31]
#
# [尝试次数：2] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 8
# [剩余数量：0] - [当前时间：15:29:40]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 9
# [剩余数量：0] - [当前时间：15:29:49]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 10
# [剩余数量：0] - [当前时间：15:29:52]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 11
# [剩余数量：0] - [当前时间：15:29:53]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 12
# [剩余数量：0] - [当前时间：15:29:55]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 13
# [剩余数量：0] - [当前时间：15:29:57]
#
# [尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits > Page 14
# [剩余数量：0] - [当前时间：15:30:06]
#
# 输出ing...
#
# 总数量：100
#
# [尝试次数：1] - 100.00% - crawler_2 > 5.4219BD Barricade™ Bio-Diesel Fuel > Page 1
# [剩余数量：95] - [当前时间：15:30:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 2.12 Reel > Page 1
# [剩余数量：94] - [当前时间：15:30:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 4.4217IS Standard Diesel Emission Fluid > Page 1
# [剩余数量：93] - [当前时间：15:30:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 8.45° Silicone Coolant > Page 1
# [剩余数量：92] - [当前时间：15:30:09]
#
# [尝试次数：1] - 100.00% - crawler_2 > 7.4219BG Barricade™ Carbureted Engines Fuel > Page 1
# [剩余数量：91] - [当前时间：15:30:09]
#
# [尝试次数：1] - 100.00% - crawler_2 > 3.12 Reel > Page 1
# [剩余数量：90] - [当前时间：15:30:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 9.90° Curved Silicone > Page 1
# [剩余数量：89] - [当前时间：15:30:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 11.AC134A Air Conditioning PolarSeal™ I > Page 1
# [剩余数量：88] - [当前时间：15:30:11]
#
# [尝试次数：1] - 100.00% - crawler_2 > 10.90° Molded Heater > Page 1
# [剩余数量：87] - [当前时间：15:30:13]
#
# [尝试次数：1] - 100.00% - crawler_2 > 13.Ag Master™ PVC Solution > Page 1
# [剩余数量：87] - [当前时间：15:30:13]
#
# [尝试次数：1] - 100.00% - crawler_2 > 10.90° Molded Heater > Page 2
# [剩余数量：87] - [当前时间：15:30:16]
#
# [尝试次数：1] - 100.00% - crawler_2 > 13.Ag Master™ PVC Solution > Page 2
# [剩余数量：86] - [当前时间：15:30:16]
#
# [尝试次数：1] - 100.00% - crawler_2 > 12.ACC-PSII Air Conditioning PolarSeal™ II > Page 1
# [剩余数量：85] - [当前时间：15:30:17]
#
# [尝试次数：1] - 100.00% - crawler_2 > 15.Air Brake Coupling Nut > Page 1
# [剩余数量：84] - [当前时间：15:30:19]
#
# [尝试次数：1] - 100.00% - crawler_2 > 1.1-1/4" Special One-Piece Couplings - Female JIC 37° Flare Swivel > Page 1
# [剩余数量：83] - [当前时间：15:30:19]
#
# [尝试次数：1] - 100.00% - crawler_2 > 16.Air Brake Coupling Sleeve > Page 1
# [剩余数量：82] - [当前时间：15:30:20]
#
# [尝试次数：1] - 100.00% - crawler_2 > 18.Air Brake Couplings Spring Guard > Page 1
# [剩余数量：81] - [当前时间：15:30:21]
#
# [尝试次数：1] - 100.00% - crawler_2 > 17.Air Brake Coupling Spring Guard Nut > Page 1
# [剩余数量：80] - [当前时间：15:30:22]
#
# [尝试次数：1] - 100.00% - crawler_2 > 20.Air Brake Couplings to Female Air Brake Couplings Swivel > Page 1
# [剩余数量：79] - [当前时间：15:30:23]
#
# [尝试次数：1] - 100.00% - crawler_2 > 14.Air Brake Assortments > Page 1
# [剩余数量：78] - [当前时间：15:30:24]
#
# [尝试次数：1] - 100.00% - crawler_2 > 21.Air Brake Couplings to Female Air Brake Couplings Swivel with Adapter > Page 1
# [剩余数量：77] - [当前时间：15:30:25]
#
# [尝试次数：1] - 100.00% - crawler_2 > 22.Air Brake Couplings to Male Pipe Adapter > Page 1
# [剩余数量：76] - [当前时间：15:30:25]
#
# [尝试次数：1] - 100.00% - crawler_2 > 19.Air Brake Couplings Union > Page 1
# [剩余数量：75] - [当前时间：15:30:25]
#
# [尝试次数：1] - 100.00% - crawler_2 > 24.Air Brake Couplings to Male Pipe with Spring Guard > Page 1
# [剩余数量：74] - [当前时间：15:30:26]
#
# [尝试次数：1] - 100.00% - crawler_2 > 23.Air Brake Couplings to Male Pipe with Nut and Sleeve > Page 1
# [剩余数量：73] - [当前时间：15:30:26]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 1
# [剩余数量：72] - [当前时间：15:30:28]
#
# [尝试次数：1] - 100.00% - crawler_2 > 25.Air Brake Couplings to Male Pipe without Nut and Sleeve > Page 1
# [剩余数量：72] - [当前时间：15:30:28]
#
# [尝试次数：1] - 100.00% - crawler_2 > 28.Air Duct > Page 1
# [剩余数量：71] - [当前时间：15:30:28]
#
# [尝试次数：1] - 100.00% - crawler_2 > 27.Air Brake Male Pipe to Female Pipe Bulkhead > Page 1
# [剩余数量：71] - [当前时间：15:30:29]
#
# [尝试次数：1] - 100.00% - crawler_2 > 30.Aluminum > Page 1
# [剩余数量：70] - [当前时间：15:30:31]
#
# [尝试次数：3] - 100.00% - crawler_2 > 6.4219BF Barricade™ GreenShield™ Fuel > Page 1
# [剩余数量：69] - [当前时间：15:30:31]
#
# [尝试次数：1] - 100.00% - crawler_2 > 29.Air Master™ Diving Umbilical > Page 1
# [剩余数量：68] - [当前时间：15:30:31]
#
# [尝试次数：3] - 100.00% - crawler_2 > 31.Angled Fuel Fill > Page 1
# [剩余数量：67] - [当前时间：15:30:32]
#
# [尝试次数：2] - 100.00% - crawler_2 > 34.Barricade™ Carburetion > Page 1
# [剩余数量：66] - [当前时间：15:30:35]
#
# [尝试次数：1] - 100.00% - crawler_2 > 33.Barricade™ Carburetion > Page 1
# [剩余数量：65] - [当前时间：15:30:35]
#
# [尝试次数：16] - 100.00% - crawler_2 > 32.Barb Stem Couplings > Page 1
# [剩余数量：64] - [当前时间：15:30:37]
#
# [尝试次数：3] - 100.00% - crawler_2 > 36.Barricade™ Fuel Injection > Page 1
# [剩余数量：64] - [当前时间：15:30:37]
#
# [尝试次数：1] - 100.00% - crawler_2 > 28.Air Duct > Page 2
# [剩余数量：63] - [当前时间：15:30:39]
#
# [尝试次数：1] - 100.00% - crawler_2 > 32.Barb Stem Couplings > Page 2
# [剩余数量：63] - [当前时间：15:30:40]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 2
# [剩余数量：63] - [当前时间：15:30:42]
#
# [尝试次数：1] - 100.00% - crawler_2 > 28.Air Duct > Page 3
# [剩余数量：63] - [当前时间：15:30:42]
#
# [尝试次数：4] - 100.00% - crawler_2 > 35.Barricade™ Fuel Injection > Page 1
# [剩余数量：62] - [当前时间：15:30:44]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 3
# [剩余数量：61] - [当前时间：15:30:45]
#
# [尝试次数：1] - 100.00% - crawler_2 > 37.Barricade™ Fuel Injection > Page 1
# [剩余数量：61] - [当前时间：15:30:46]
#
# [尝试次数：1] - 100.00% - crawler_2 > 40.Black Gold™ Fuel > Page 1
# [剩余数量：60] - [当前时间：15:30:47]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 4
# [剩余数量：60] - [当前时间：15:30:47]
#
# [尝试次数：1] - 100.00% - crawler_2 > 40.Black Gold™ Fuel > Page 2
# [剩余数量：60] - [当前时间：15:30:48]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 5
# [剩余数量：59] - [当前时间：15:30:50]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 6
# [剩余数量：59] - [当前时间：15:30:51]
#
# [尝试次数：1] - 100.00% - crawler_2 > 39.Black Gold™ ABS Mud and Oil > Page 1
# [剩余数量：59] - [当前时间：15:30:54]
#
# [尝试次数：6] - 100.00% - crawler_2 > 32.Barb Stem Couplings > Page 3
# [剩余数量：59] - [当前时间：15:30:54]
#
# [尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake > Page 7
# [剩余数量：59] - [当前时间：15:30:55]
#
# [尝试次数：1] - 100.00% - crawler_2 > 41.Black Gold™ Oilfield Frac > Page 1
# [剩余数量：58] - [当前时间：15:30:55]
#
# [尝试次数：1] - 100.00% - crawler_2 > 39.Black Gold™ ABS Mud and Oil > Page 2
# [剩余数量：57] - [当前时间：15:30:57]
#
# [尝试次数：2] - 100.00% - crawler_2 > 38.Black Gold™ ABS Bulk Material - 300SD > Page 1
# [剩余数量：56] - [当前时间：15:30:57]
#
# [尝试次数：1] - 100.00% - crawler_2 > 42.Black Gold™ Oilfield Service > Page 1
# [剩余数量：55] - [当前时间：15:30:57]
#
# [尝试次数：1] - 100.00% - crawler_2 > 43.Black Gold™ Oilfield Service 400D MegaTuff > Page 1
# [剩余数量：54] - [当前时间：15:30:58]
#
# [尝试次数：1] - 100.00% - crawler_2 > 32.Barb Stem Couplings > Page 4
# [剩余数量：53] - [当前时间：15:30:58]
#
# [尝试次数：1] - 100.00% - crawler_2 > 44.Black Gold™ Oilfield Vacuum > Page 1
# [剩余数量：52] - [当前时间：15:31:00]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 1
# [剩余数量：51] - [当前时间：15:31:01]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 1
# [剩余数量：51] - [当前时间：15:31:01]
#
# [尝试次数：1] - 100.00% - crawler_2 > 48.Bulk Master™ PVC > Page 1
# [剩余数量：51] - [当前时间：15:31:02]
#
# [尝试次数：1] - 100.00% - crawler_2 > 45.Black Gold™ Potable Water > Page 1
# [剩余数量：50] - [当前时间：15:31:02]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 2
# [剩余数量：49] - [当前时间：15:31:03]
#
# [尝试次数：1] - 100.00% - crawler_2 > 49.C14 > Page 1
# [剩余数量：49] - [当前时间：15:31:03]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 2
# [剩余数量：48] - [当前时间：15:31:04]
#
# [尝试次数：1] - 100.00% - crawler_2 > 50.C14 Swage Equipment > Page 1
# [剩余数量：48] - [当前时间：15:31:05]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 3
# [剩余数量：48] - [当前时间：15:31:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 3
# [剩余数量：48] - [当前时间：15:31:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 52.C5C-XH XTreme™ Heat Hydraulic > Page 1
# [剩余数量：48] - [当前时间：15:31:07]
#
# [尝试次数：1] - 100.00% - crawler_2 > 51.C5C Hydraulic > Page 1
# [剩余数量：48] - [当前时间：15:31:08]
#
# [尝试次数：1] - 100.00% - crawler_2 > 52.C5C-XH XTreme™ Heat Hydraulic > Page 2
# [剩余数量：48] - [当前时间：15:31:09]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 4
# [剩余数量：47] - [当前时间：15:31:09]
#
# [尝试次数：1] - 100.00% - crawler_2 > 50.C14 Swage Equipment > Page 2
# [剩余数量：47] - [当前时间：15:31:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 4
# [剩余数量：46] - [当前时间：15:31:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 53.C5D Hydraulic > Page 1
# [剩余数量：46] - [当前时间：15:31:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 5
# [剩余数量：46] - [当前时间：15:31:11]
#
# [尝试次数：1] - 100.00% - crawler_2 > 51.C5C Hydraulic > Page 2
# [剩余数量：46] - [当前时间：15:31:12]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 5
# [剩余数量：45] - [当前时间：15:31:14]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 6
# [剩余数量：45] - [当前时间：15:31:14]
#
# [尝试次数：1] - 100.00% - crawler_2 > 55.C5M Hydraulic > Page 1
# [剩余数量：45] - [当前时间：15:31:16]
#
# [尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings > Page 7
# [剩余数量：45] - [当前时间：15:31:16]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 6
# [剩余数量：44] - [当前时间：15:31:17]
#
# [尝试次数：1] - 100.00% - crawler_2 > 55.C5M Hydraulic > Page 2
# [剩余数量：44] - [当前时间：15:31:19]
#
# [尝试次数：1] - 100.00% - crawler_2 > 56.CM2T Wire Braid > Page 1
# [剩余数量：43] - [当前时间：15:31:19]
#
# [尝试次数：1] - 100.00% - crawler_2 > 58.CR2 2-Wire Braid > Page 1
# [剩余数量：42] - [当前时间：15:31:20]
#
# [尝试次数：2] - 100.00% - crawler_2 > 53.C5D Hydraulic > Page 2
# [剩余数量：42] - [当前时间：15:31:22]
#
# [尝试次数：1] - 100.00% - crawler_2 > 57.CR1 1-Wire Braid > Page 1
# [剩余数量：41] - [当前时间：15:31:23]
#
# [尝试次数：1] - 100.00% - crawler_2 > 58.CR2 2-Wire Braid > Page 2
# [剩余数量：41] - [当前时间：15:31:24]
#
# [尝试次数：1] - 100.00% - crawler_2 > 60.Charter™ Air > Page 1
# [剩余数量：40] - [当前时间：15:31:26]
#
# [尝试次数：1] - 100.00% - crawler_2 > 59.Cam Gear Sprocket Tool > Page 1
# [剩余数量：39] - [当前时间：15:31:26]
#
# [尝试次数：2] - 100.00% - crawler_2 > 54.C5E Hydraulic > Page 1
# [剩余数量：38] - [当前时间：15:31:26]
#
# [尝试次数：1] - 100.00% - crawler_2 > 57.CR1 1-Wire Braid > Page 2
# [剩余数量：38] - [当前时间：15:31:26]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 1
# [剩余数量：37] - [当前时间：15:31:28]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 2
# [剩余数量：37] - [当前时间：15:31:29]
#
# [尝试次数：1] - 100.00% - crawler_2 > 63.Clean Master™ 3000 > Page 1
# [剩余数量：37] - [当前时间：15:31:29]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 3
# [剩余数量：37] - [当前时间：15:31:31]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 4
# [剩余数量：37] - [当前时间：15:31:34]
#
# [尝试次数：1] - 100.00% - crawler_2 > 63.Clean Master™ 3000 > Page 2
# [剩余数量：37] - [当前时间：15:31:34]
#
# [尝试次数：1] - 100.00% - crawler_2 > 54.C5E Hydraulic > Page 2
# [剩余数量：36] - [当前时间：15:31:35]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 7
# [剩余数量：35] - [当前时间：15:31:36]
#
# [尝试次数：1] - 100.00% - crawler_2 > 64.Clean Master™ PW4000 > Page 1
# [剩余数量：35] - [当前时间：15:31:36]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 5
# [剩余数量：35] - [当前时间：15:31:37]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 8
# [剩余数量：35] - [当前时间：15:31:38]
#
# [尝试次数：1] - 100.00% - crawler_2 > 65.Clean Master™ Plus PW6000 > Page 1
# [剩余数量：35] - [当前时间：15:31:38]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 9
# [剩余数量：35] - [当前时间：15:31:39]
#
# [尝试次数：1] - 100.00% - crawler_2 > 65.Clean Master™ Plus PW6000 > Page 2
# [剩余数量：35] - [当前时间：15:31:39]
#
# [尝试次数：1] - 100.00% - crawler_2 > 64.Clean Master™ PW4000 > Page 2
# [剩余数量：35] - [当前时间：15:31:40]
#
# [尝试次数：2] - 100.00% - crawler_2 > 61.Chem Master™ Hydrocarbon Drain > Page 1
# [剩余数量：35] - [当前时间：15:31:40]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 6
# [剩余数量：34] - [当前时间：15:31:40]
#
# [尝试次数：1] - 100.00% - crawler_2 > 64.Clean Master™ PW4000 > Page 3
# [剩余数量：34] - [当前时间：15:31:41]
#
# [尝试次数：1] - 100.00% - crawler_2 > 65.Clean Master™ Plus PW6000 > Page 3
# [剩余数量：33] - [当前时间：15:31:42]
#
# [尝试次数：2] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 7
# [剩余数量：33] - [当前时间：15:31:42]
#
# [尝试次数：3] - 100.00% - crawler_2 > 65.Clean Master™ Plus PW6000 > Page 4
# [剩余数量：33] - [当前时间：15:31:44]
#
# [尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE > Page 8
# [剩余数量：32] - [当前时间：15:31:47]
#
# [尝试次数：1] - 100.00% - crawler_2 > 67.Clean Master™ Washdown > Page 1
# [剩余数量：31] - [当前时间：15:31:48]
#
# [尝试次数：2] - 100.00% - crawler_2 > 67.Clean Master™ Washdown > Page 2
# [剩余数量：31] - [当前时间：15:31:50]
#
# [尝试次数：4] - 100.00% - crawler_2 > 69.Coal Power/Longwall Mine > Page 1
# [剩余数量：30] - [当前时间：15:31:50]
#
# [尝试次数：1] - 100.00% - crawler_2 > 70.Conductive C14 PTFE > Page 1
# [剩余数量：29] - [当前时间：15:31:51]
#
# [尝试次数：1] - 100.00% - crawler_2 > 68.Coal Power/Longwall Mine > Page 1
# [剩余数量：28] - [当前时间：15:31:53]
#
# [尝试次数：4] - 100.00% - crawler_2 > 66.Clean Master™ Pressure Wash > Page 1
# [剩余数量：27] - [当前时间：15:31:54]
#
# [尝试次数：8] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 1
# [剩余数量：26] - [当前时间：15:31:54]
#
# [尝试次数：1] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 2
# [剩余数量：26] - [当前时间：15:31:56]
#
# [尝试次数：3] - 100.00% - crawler_2 > 73.Data Center Cooling > Page 1
# [剩余数量：26] - [当前时间：15:31:56]
#
# [尝试次数：1] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 1
# [剩余数量：25] - [当前时间：15:31:57]
#
# [尝试次数：1] - 100.00% - crawler_2 > 74.Dual I.D. Heater > Page 1
# [剩余数量：25] - [当前时间：15:31:57]
#
# [尝试次数：3] - 100.00% - crawler_2 > 76.EF Coal Power/Longwall Mine > Page 1
# [剩余数量：24] - [当前时间：15:31:59]
#
# [尝试次数：3] - 100.00% - crawler_2 > 75.EF Coal Power/Longwall Mine > Page 1
# [剩余数量：23] - [当前时间：15:32:00]
#
# [尝试次数：7] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 3
# [剩余数量：22] - [当前时间：15:32:01]
#
# [尝试次数：7] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 2
# [剩余数量：22] - [当前时间：15:32:01]
#
# [尝试次数：1] - 100.00% - crawler_2 > 78.EF Longwall Mine > Page 1
# [剩余数量：22] - [当前时间：15:32:02]
#
# [尝试次数：2] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 10
# [剩余数量：21] - [当前时间：15:32:02]
#
# [尝试次数：8] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 4
# [剩余数量：21] - [当前时间：15:32:03]
#
# [尝试次数：7] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 3
# [剩余数量：21] - [当前时间：15:32:04]
#
# [尝试次数：5] - 100.00% - crawler_2 > 77.EF Longwall Mine > Page 1
# [剩余数量：21] - [当前时间：15:32:04]
#
# [尝试次数：1] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 5
# [剩余数量：20] - [当前时间：15:32:04]
#
# [尝试次数：1] - 100.00% - crawler_2 > 79.EFG3K Spiral Wire > Page 1
# [剩余数量：20] - [当前时间：15:32:04]
#
# [尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL > Page 11
# [剩余数量：20] - [当前时间：15:32:07]
#
# [尝试次数：5] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 6
# [剩余数量：19] - [当前时间：15:32:07]
#
# [尝试次数：8] - 100.00% - crawler_2 > 80.EFG3K-MTF Spiral Wire > Page 1
# [剩余数量：19] - [当前时间：15:32:08]
#
# [尝试次数：1] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 7
# [剩余数量：18] - [当前时间：15:32:08]
#
# [尝试次数：11] - 100.00% - crawler_2 > 81.EFG4K Spiral Wire > Page 1
# [剩余数量：18] - [当前时间：15:32:09]
#
# [尝试次数：1] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings > Page 8
# [剩余数量：18] - [当前时间：15:32:10]
#
# [尝试次数：1] - 100.00% - crawler_2 > 79.EFG3K Spiral Wire > Page 2
# [剩余数量：17] - [当前时间：15:32:10]
#
# [尝试次数：5] - 100.00% - crawler_2 > 81.EFG4K Spiral Wire > Page 2
# [剩余数量：16] - [当前时间：15:32:11]
#
# [尝试次数：2] - 100.00% - crawler_2 > 81.EFG4K Spiral Wire > Page 3
# [剩余数量：16] - [当前时间：15:32:12]
#
# [尝试次数：6] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 4
# [剩余数量：15] - [当前时间：15:32:14]
#
# [尝试次数：9] - 100.00% - crawler_2 > 84.EFG4KL Spiral Wire > Page 1
# [剩余数量：15] - [当前时间：15:32:16]
#
# [尝试次数：9] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 5
# [剩余数量：14] - [当前时间：15:32:16]
#
# [尝试次数：3] - 100.00% - crawler_2 > 86.EFG5K-MTF Spiral Wire > Page 1
# [剩余数量：14] - [当前时间：15:32:17]
#
# [尝试次数：2] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 6
# [剩余数量：14] - [当前时间：15:32:18]
#
# [尝试次数：1] - 100.00% - crawler_2 > 85.EFG5K Spiral Wire > Page 1
# [剩余数量：14] - [当前时间：15:32:18]
#
# [尝试次数：5] - 100.00% - crawler_2 > 86.EFG5K-MTF Spiral Wire > Page 2
# [剩余数量：14] - [当前时间：15:32:21]
#
# [尝试次数：5] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 7
# [剩余数量：13] - [当前时间：15:32:21]
#
# [尝试次数：15] - 100.00% - crawler_2 > 83.EFG4K-XTF Spiral Wire > Page 1
# [剩余数量：13] - [当前时间：15:32:23]
#
# [尝试次数：1] - 100.00% - crawler_2 > 87.EFG5K-XTF Spiral Wire > Page 1
# [剩余数量：12] - [当前时间：15:32:23]
#
# [尝试次数：5] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 8
# [剩余数量：11] - [当前时间：15:32:24]
#
# [尝试次数：2] - 100.00% - crawler_2 > 88.EFG5KL Spiral Wire > Page 1
# [剩余数量：11] - [当前时间：15:32:25]
#
# [尝试次数：3] - 100.00% - crawler_2 > 89.EFG6K Spiral Wire > Page 1
# [剩余数量：10] - [当前时间：15:32:25]
#
# [尝试次数：5] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 9
# [剩余数量：10] - [当前时间：15:32:27]
#
# [尝试次数：10] - 100.00% - crawler_2 > 82.EFG4K-MTF Spiral Wire > Page 1
# [剩余数量：10] - [当前时间：15:32:28]
#
# [尝试次数：10] - 100.00% - crawler_2 > 89.EFG6K Spiral Wire > Page 2
# [剩余数量：10] - [当前时间：15:32:29]
#
# [尝试次数：3] - 100.00% - crawler_2 > 82.EFG4K-MTF Spiral Wire > Page 2
# [剩余数量：10] - [当前时间：15:32:30]
#
# [尝试次数：7] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 10
# [剩余数量：9] - [当前时间：15:32:31]
#
# [尝试次数：9] - 100.00% - crawler_2 > 89.EFG6K Spiral Wire > Page 3
# [剩余数量：9] - [当前时间：15:32:33]
#
# [尝试次数：9] - 100.00% - crawler_2 > 85.EFG5K Spiral Wire > Page 2
# [剩余数量：8] - [当前时间：15:32:33]
#
# [尝试次数：1] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 11
# [剩余数量：8] - [当前时间：15:32:34]
#
# [尝试次数：1] - 100.00% - crawler_2 > 91.EFG6KL Spiral Wire > Page 1
# [剩余数量：8] - [当前时间：15:32:35]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 1
# [剩余数量：7] - [当前时间：15:32:38]
#
# [尝试次数：1] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 1
# [剩余数量：7] - [当前时间：15:32:38]
#
# [尝试次数：8] - 100.00% - crawler_2 > 90.EFG6K-MTF Spiral Wire > Page 1
# [剩余数量：7] - [当前时间：15:32:41]
#
# [尝试次数：1] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 2
# [剩余数量：7] - [当前时间：15:32:41]
#
# [尝试次数：1] - 100.00% - crawler_2 > 85.EFG5K Spiral Wire > Page 3
# [剩余数量：7] - [当前时间：15:32:41]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 2
# [剩余数量：6] - [当前时间：15:32:42]
#
# [尝试次数：1] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 12
# [剩余数量：6] - [当前时间：15:32:42]
#
# [尝试次数：1] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 3
# [剩余数量：6] - [当前时间：15:32:43]
#
# [尝试次数：5] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 13
# [剩余数量：6] - [当前时间：15:32:46]
#
# [尝试次数：9] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 4
# [剩余数量：6] - [当前时间：15:32:46]
#
# [尝试次数：1] - 100.00% - crawler_2 > 90.EFG6K-MTF Spiral Wire > Page 2
# [剩余数量：6] - [当前时间：15:32:46]
#
# [尝试次数：22] - 100.00% - crawler_2 > 94.Engine Coolant Soft Wall > Page 1
# [剩余数量：5] - [当前时间：15:32:47]
#
# [尝试次数：7] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 5
# [剩余数量：5] - [当前时间：15:32:48]
#
# [尝试次数：6] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 14
# [剩余数量：5] - [当前时间：15:32:49]
#
# [尝试次数：6] - 100.00% - crawler_2 > 95.Field Attachable Type T for G1 > Page 1
# [剩余数量：5] - [当前时间：15:32:49]
#
# [尝试次数：5] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings > Page 15
# [剩余数量：5] - [当前时间：15:32:52]
#
# [尝试次数：2] - 100.00% - crawler_2 > 95.Field Attachable Type T for G1 > Page 2
# [剩余数量：4] - [当前时间：15:32:55]
#
# [尝试次数：2] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 1
# [剩余数量：4] - [当前时间：15:32:56]
#
# [尝试次数：3] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 6
# [剩余数量：4] - [当前时间：15:32:56]
#
# [尝试次数：1] - 100.00% - crawler_2 > 94.Engine Coolant Soft Wall > Page 2
# [剩余数量：4] - [当前时间：15:32:57]
#
# [尝试次数：1] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 2
# [剩余数量：3] - [当前时间：15:32:58]
#
# [尝试次数：3] - 100.00% - crawler_2 > 95.Field Attachable Type T for G1 > Page 3
# [剩余数量：3] - [当前时间：15:32:58]
#
# [尝试次数：1] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 7
# [剩余数量：3] - [当前时间：15:32:58]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 3
# [剩余数量：3] - [当前时间：15:32:59]
#
# [尝试次数：7] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 8
# [剩余数量：3] - [当前时间：15:33:00]
#
# [尝试次数：2] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 3
# [剩余数量：3] - [当前时间：15:33:01]
#
# [尝试次数：3] - 100.00% - crawler_2 > 97.Flange Kits > Page 1
# [剩余数量：3] - [当前时间：15:33:02]
#
# [尝试次数：3] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 9
# [剩余数量：2] - [当前时间：15:33:04]
#
# [尝试次数：3] - 100.00% - crawler_2 > 95.Field Attachable Type T for G1 > Page 4
# [剩余数量：2] - [当前时间：15:33:05]
#
# [尝试次数：6] - 100.00% - crawler_2 > 99.Food Master™ Beverage 150SD CR > Page 1
# [剩余数量：1] - [当前时间：15:33:07]
#
# [尝试次数：6] - 100.00% - crawler_2 > 92.Emission > Page 4
# [剩余数量：0] - [当前时间：15:33:09]
#
# [尝试次数：2] - 100.00% - crawler_2 > 93.Engine Air Intake > Page 10
# [剩余数量：0] - [当前时间：15:33:09]
#
# [尝试次数：6] - 100.00% - crawler_2 > 92.Emission > Page 5
# [剩余数量：0] - [当前时间：15:33:11]
#
# [尝试次数：3] - 100.00% - crawler_2 > 100.Food Master™ Beverage 250SD CR > Page 1
# [剩余数量：0] - [当前时间：15:33:12]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 6
# [剩余数量：0] - [当前时间：15:33:14]
#
# [尝试次数：4] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 4
# [剩余数量：0] - [当前时间：15:33:15]
#
# [尝试次数：5] - 100.00% - crawler_2 > 98.Flexible Fuel Fill > Page 1
# [剩余数量：0] - [当前时间：15:33:15]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 7
# [剩余数量：0] - [当前时间：15:33:17]
#
# [尝试次数：4] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 5
# [剩余数量：0] - [当前时间：15:33:19]
#
# [尝试次数：3] - 100.00% - crawler_2 > 92.Emission > Page 8
# [剩余数量：0] - [当前时间：15:33:21]
#
# [尝试次数：1] - 100.00% - crawler_2 > 100.Food Master™ Beverage 250SD CR > Page 2
# [剩余数量：0] - [当前时间：15:33:24]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 9
# [剩余数量：0] - [当前时间：15:33:25]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 10
# [剩余数量：0] - [当前时间：15:33:27]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 11
# [剩余数量：0] - [当前时间：15:33:29]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 12
# [剩余数量：0] - [当前时间：15:33:30]
#
# [尝试次数：2] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2 > Page 6
# [剩余数量：0] - [当前时间：15:33:31]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 13
# [剩余数量：0] - [当前时间：15:33:34]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 14
# [剩余数量：0] - [当前时间：15:33:38]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 15
# [剩余数量：0] - [当前时间：15:33:39]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 16
# [剩余数量：0] - [当前时间：15:33:49]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 17
# [剩余数量：0] - [当前时间：15:33:50]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 18
# [剩余数量：0] - [当前时间：15:33:55]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 19
# [剩余数量：0] - [当前时间：15:33:57]
#
# [尝试次数：2] - 100.00% - crawler_2 > 92.Emission > Page 20
# [剩余数量：0] - [当前时间：15:34:01]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 21
# [剩余数量：0] - [当前时间：15:34:03]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 22
# [剩余数量：0] - [当前时间：15:34:05]
#
# [尝试次数：2] - 100.00% - crawler_2 > 92.Emission > Page 23
# [剩余数量：0] - [当前时间：15:34:29]
#
# [尝试次数：2] - 100.00% - crawler_2 > 92.Emission > Page 24
# [剩余数量：0] - [当前时间：15:34:54]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 25
# [剩余数量：0] - [当前时间：15:34:59]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 26
# [剩余数量：0] - [当前时间：15:35:02]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 27
# [剩余数量：0] - [当前时间：15:35:12]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 28
# [剩余数量：0] - [当前时间：15:35:19]
#
# [尝试次数：2] - 100.00% - crawler_2 > 92.Emission > Page 29
# [剩余数量：0] - [当前时间：15:35:42]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 30
# [剩余数量：0] - [当前时间：15:35:46]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 31
# [剩余数量：0] - [当前时间：15:35:48]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 32
# [剩余数量：0] - [当前时间：15:35:50]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 33
# [剩余数量：0] - [当前时间：15:35:52]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 34
# [剩余数量：0] - [当前时间：15:36:01]
#
# [尝试次数：1] - 100.00% - crawler_2 > 92.Emission > Page 35
# [剩余数量：0] - [当前时间：15:36:04]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 3729.93it/s]
# Done ~
