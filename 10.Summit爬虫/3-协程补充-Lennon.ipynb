# %%
import os

# %%
directory = list(os.walk('./'))[0][2]

list_file = []
for file in directory:
    if file.startswith('menu-'):
        menu = file
    if file.startswith('crawler-'):
        list_file.append(file)

print('menu：' + menu)
print()
print('list_file：' + str(list_file))
# Out:
# menu：menu-ngk_laser_iridium_spark_plugs.xlsx
#
# list_file：['crawler-0.xlsx', 'crawler-1.xlsx', 'crawler-2.xlsx']

# %%
import pandas as pd

# %%
df = pd.read_excel(menu, header=0)

df
# Out:
#                                           Product
# 0     https://www.summitracing.com/parts/ngk-1961
# 1     https://www.summitracing.com/parts/ngk-1989
# 2     https://www.summitracing.com/parts/ngk-2318
# 3     https://www.summitracing.com/parts/ngk-4282
# 4     https://www.summitracing.com/parts/ngk-3508
# ..                                            ...
# 202  https://www.summitracing.com/parts/ngk-91234
# 203  https://www.summitracing.com/parts/ngk-96412
# 204  https://www.summitracing.com/parts/ngk-90856
# 205  https://www.summitracing.com/parts/ngk-93623
# 206   https://www.summitracing.com/parts/ngk-5899
#
# [207 rows x 1 columns]

# %%
list_df = []
for file in list_file:
    list_df.append(pd.read_excel(file, header=0))
df_temp = pd.concat(list_df, ignore_index=True)

df_temp
# Out:
#           Item                                        标题  图片            Brand  \
# 0     NGK-1961     NGK Laser Iridium Spark Plugs ILZKR7A NaN  NGK Spark Plugs
# 1     NGK-2318      NGK Laser Iridium Spark Plugs BR6FIX NaN  NGK Spark Plugs
# 2     NGK-1989     NGK Laser Iridium Spark Plugs ILKR7B8 NaN  NGK Spark Plugs
# 3     NGK-3508    NGK Laser Iridium Spark Plugs IFR5T-8N NaN  NGK Spark Plugs
# 4     NGK-4282  NGK Laser Iridium Spark Plugs R7440A-10L NaN  NGK Spark Plugs
# ..         ...                                       ...  ..              ...
# 202  NGK-96412    NGK Laser Iridium Spark Plugs ILZKR7D8 NaN  NGK Spark Plugs
# 203   NGK-4214      NGK Laser Iridium Spark Plugs IZFR7M NaN  NGK Spark Plugs
# 204   NGK-5899      NGK Laser Iridium Spark Plugs IZFR5J NaN  NGK Spark Plugs
# 205  NGK-90856    NGK Laser Iridium Spark Plugs IZFR7M6D NaN  NGK Spark Plugs
# 206  NGK-93623    NGK Laser Iridium Spark Plugs IFR7U-4D NaN  NGK Spark Plugs
#
#     Part Number           UPC  车型 Electrode Tip Material  \
# 0       ILZKR7A  8.729512e+10 NaN                Iridium
# 1        BR6FIX  8.729512e+10 NaN                Iridium
# 2       ILKR7B8  8.729512e+10 NaN                Iridium
# 3      IFR5T-8N  8.729514e+10 NaN                Iridium
# 4    R7440A-10L  8.729514e+10 NaN                Iridium
# ..          ...           ...  ..                    ...
# 202    ILZKR7D8  8.729596e+10 NaN                    NaN
# 203      IZFR7M  8.729514e+10 NaN                Iridium
# 204      IZFR5J  8.729516e+10 NaN                Iridium
# 205    IZFR7M6D  8.729591e+10 NaN                    NaN
# 206    IFR7U-4D  8.729594e+10 NaN                    NaN
#
#     Electrode Core Material                                            链接  \
# 0                    Copper   https://www.summitracing.com/parts/ngk-1961
# 1                    Copper   https://www.summitracing.com/parts/ngk-2318
# 2                    Copper   https://www.summitracing.com/parts/ngk-1989
# 3                    Copper   https://www.summitracing.com/parts/ngk-3508
# 4                    Copper   https://www.summitracing.com/parts/ngk-4282
# ..                      ...                                           ...
# 202                     NaN  https://www.summitracing.com/parts/ngk-96412
# 203                  Copper   https://www.summitracing.com/parts/ngk-4214
# 204                  Copper   https://www.summitracing.com/parts/ngk-5899
# 205                     NaN  https://www.summitracing.com/parts/ngk-90856
# 206                     NaN  https://www.summitracing.com/parts/ngk-93623
#
#                                                   图片链接
# 0    https://static.summitracing.com/global/images/...
# 1    https://static.summitracing.com/global/images/...
# 2    https://static.summitracing.com/global/images/...
# 3    https://static.summitracing.com/global/images/...
# 4    https://static.summitracing.com/global/images/...
# ..                                                 ...
# 202  https://static.summitracing.com/global/images/...
# 203  https://static.summitracing.com/global/images/...
# 204  https://static.summitracing.com/global/images/...
# 205  https://static.summitracing.com/global/images/...
# 206  https://static.summitracing.com/global/images/...
#
# [207 rows x 11 columns]

# %%
df = pd.merge(left=df, right=df_temp, how='left', left_on='Product', right_on='链接').fillna('')
df.to_excel('./content_temp.xlsx', index=False)
df = df.drop_duplicates(ignore_index=True)
df.to_excel('./content.xlsx', index=False)

df
# Out:
#                                           Product       Item  \
# 0     https://www.summitracing.com/parts/ngk-1961   NGK-1961
# 1     https://www.summitracing.com/parts/ngk-1989   NGK-1989
# 2     https://www.summitracing.com/parts/ngk-2318   NGK-2318
# 3     https://www.summitracing.com/parts/ngk-4282   NGK-4282
# 4     https://www.summitracing.com/parts/ngk-3508   NGK-3508
# ..                                            ...        ...
# 169  https://www.summitracing.com/parts/ngk-91234  NGK-91234
# 170  https://www.summitracing.com/parts/ngk-96412  NGK-96412
# 171  https://www.summitracing.com/parts/ngk-90856  NGK-90856
# 172  https://www.summitracing.com/parts/ngk-93623  NGK-93623
# 173   https://www.summitracing.com/parts/ngk-5899   NGK-5899
#
#                                            标题 图片            Brand Part Number  \
# 0       NGK Laser Iridium Spark Plugs ILZKR7A     NGK Spark Plugs     ILZKR7A
# 1       NGK Laser Iridium Spark Plugs ILKR7B8     NGK Spark Plugs     ILKR7B8
# 2        NGK Laser Iridium Spark Plugs BR6FIX     NGK Spark Plugs      BR6FIX
# 3    NGK Laser Iridium Spark Plugs R7440A-10L     NGK Spark Plugs  R7440A-10L
# 4      NGK Laser Iridium Spark Plugs IFR5T-8N     NGK Spark Plugs    IFR5T-8N
# ..                                        ... ..              ...         ...
# 169      NGK Laser Iridium Spark Plugs IZFR6Q     NGK Spark Plugs      IZFR6Q
# 170    NGK Laser Iridium Spark Plugs ILZKR7D8     NGK Spark Plugs    ILZKR7D8
# 171    NGK Laser Iridium Spark Plugs IZFR7M6D     NGK Spark Plugs    IZFR7M6D
# 172    NGK Laser Iridium Spark Plugs IFR7U-4D     NGK Spark Plugs    IFR7U-4D
# 173      NGK Laser Iridium Spark Plugs IZFR5J     NGK Spark Plugs      IZFR5J
#
#                UPC 车型 Electrode Tip Material Electrode Core Material  \
# 0    87295119617.0                   Iridium                  Copper
# 1    87295119891.0                   Iridium                  Copper
# 2    87295123188.0                   Iridium                  Copper
# 3    87295142820.0                   Iridium                  Copper
# 4    87295135082.0                   Iridium                  Copper
# ..             ... ..                    ...                     ...
# 169  87295912348.0                   Iridium                  Copper
# 170  87295964125.0
# 171  87295908563.0
# 172  87295936238.0
# 173  87295158999.0                   Iridium                  Copper
#
#                                                链接  \
# 0     https://www.summitracing.com/parts/ngk-1961
# 1     https://www.summitracing.com/parts/ngk-1989
# 2     https://www.summitracing.com/parts/ngk-2318
# 3     https://www.summitracing.com/parts/ngk-4282
# 4     https://www.summitracing.com/parts/ngk-3508
# ..                                            ...
# 169  https://www.summitracing.com/parts/ngk-91234
# 170  https://www.summitracing.com/parts/ngk-96412
# 171  https://www.summitracing.com/parts/ngk-90856
# 172  https://www.summitracing.com/parts/ngk-93623
# 173   https://www.summitracing.com/parts/ngk-5899
#
#                                                   图片链接
# 0    https://static.summitracing.com/global/images/...
# 1    https://static.summitracing.com/global/images/...
# 2    https://static.summitracing.com/global/images/...
# 3    https://static.summitracing.com/global/images/...
# 4    https://static.summitracing.com/global/images/...
# ..                                                 ...
# 169  https://static.summitracing.com/global/images/...
# 170  https://static.summitracing.com/global/images/...
# 171  https://static.summitracing.com/global/images/...
# 172  https://static.summitracing.com/global/images/...
# 173  https://static.summitracing.com/global/images/...
#
# [174 rows x 12 columns]
