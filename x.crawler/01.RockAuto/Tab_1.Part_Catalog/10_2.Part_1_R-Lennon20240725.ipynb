# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
param_date = '20240715'

# %%
import os

list_file = sorted(list(os.walk(f'./{param_date}/9.type'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['make_1.ABARTH.xlsx',
#  'make_10.AMERICAN AUSTIN.xlsx',
#  'make_100.GOLIATH.xlsx',
#  'make_101.GORDON-KEEBLE.xlsx',
#  'make_102.GRAHAM.xlsx',
#  'make_103.GRAHAM-PAIGE.xlsx',
#  'make_104.GRIFFITH.xlsx',
#  'make_105.HEALEY.xlsx',
#  'make_106.HENRY J.xlsx',
#  'make_107.HILLMAN.xlsx',
#  'make_108.HINO.xlsx',
#  'make_109.HISPANO-SUIZA.xlsx',
#  'make_11.AMERICAN BANTAM.xlsx',
#  'make_110.HONDA-serial_1.xlsx',
#  'make_110.HONDA-serial_2.xlsx',
#  'make_110.HONDA-serial_3.xlsx',
#  'make_110.HONDA-serial_4.xlsx',
#  'make_110.HONDA-serial_5.xlsx',
#  'make_110.HONDA-serial_6.xlsx',
#  'make_110.HONDA-serial_7.xlsx',
#  'make_110.HONDA-serial_8.xlsx',
#  'make_110.HONDA-serial_9.xlsx',
#  'make_111.HOTCHKISS.xlsx',
#  'make_112.HRG.xlsx',
#  'make_113.HUDSON.xlsx',
#  'make_114.HUMBER.xlsx',
#  'make_115.HUMMER-serial_1.xlsx',
#  'make_115.HUMMER-serial_2.xlsx',
#  'make_116.HUPMOBILE.xlsx',
#  'make_117.HYUNDAI-serial_1.xlsx',
#  'make_117.HYUNDAI-serial_2.xlsx',
#  'make_117.HYUNDAI-serial_3.xlsx',
#  'make_117.HYUNDAI-serial_4.xlsx',
#  'make_117.HYUNDAI-serial_5.xlsx',
#  'make_117.HYUNDAI-serial_6.xlsx',
#  'make_117.HYUNDAI-serial_7.xlsx',
#  'make_117.HYUNDAI-serial_8.xlsx',
#  'make_118.INFINITI-serial_1.xlsx',
#  'make_118.INFINITI-serial_2.xlsx',
#  'make_118.INFINITI-serial_3.xlsx',
#  'make_118.INFINITI-serial_4.xlsx',
#  'make_118.INFINITI-serial_5.xlsx',
#  'make_118.INFINITI-serial_6.xlsx',
#  'make_119.INTERNATIONAL-serial_1.xlsx',
#  'make_119.INTERNATIONAL-serial_10.xlsx',
#  'make_119.INTERNATIONAL-serial_11.xlsx',
#  'make_119.INTERNATIONAL-serial_12.xlsx',
#  'make_119.INTERNATIONAL-serial_13.xlsx',
#  'make_119.INTERNATIONAL-serial_14.xlsx',
#  'make_119.INTERNATIONAL-serial_15.xlsx',
#  'make_119.INTERNATIONAL-serial_16.xlsx',
#  'make_119.INTERNATIONAL-serial_17.xlsx',
#  'make_119.INTERNATIONAL-serial_18.xlsx',
#  'make_119.INTERNATIONAL-serial_19.xlsx',
#  'make_119.INTERNATIONAL-serial_2.xlsx',
#  'make_119.INTERNATIONAL-serial_3.xlsx',
#  'make_119.INTERNATIONAL-serial_4.xlsx',
#  'make_119.INTERNATIONAL-serial_5.xlsx',
#  'make_119.INTERNATIONAL-serial_6.xlsx',
#  'make_119.INTERNATIONAL-serial_7.xlsx',
#  'make_119.INTERNATIONAL-serial_8.xlsx',
#  'make_119.INTERNATIONAL-serial_9.xlsx',
#  'make_12.AMERICAN MOTORS-serial_1.xlsx',
#  'make_12.AMERICAN MOTORS-serial_2.xlsx',
#  'make_12.AMERICAN MOTORS-serial_3.xlsx',
#  'make_12.AMERICAN MOTORS-serial_4.xlsx',
#  'make_12.AMERICAN MOTORS-serial_5.xlsx',
#  'make_12.AMERICAN MOTORS-serial_6.xlsx',
#  'make_12.AMERICAN MOTORS-serial_7.xlsx',
#  'make_12.AMERICAN MOTORS-serial_8.xlsx',
#  'make_12.AMERICAN MOTORS-serial_9.xlsx',
#  'make_120.ISO.xlsx',
#  'make_121.ISUZU-serial_1.xlsx',
#  'make_121.ISUZU-serial_2.xlsx',
#  'make_121.ISUZU-serial_3.xlsx',
#  'make_121.ISUZU-serial_4.xlsx',
#  'make_121.ISUZU-serial_5.xlsx',
#  'make_121.ISUZU-serial_6.xlsx',
#  'make_121.ISUZU-serial_7.xlsx',
#  'make_121.ISUZU-serial_8.xlsx',
#  'make_122.IVECO.xlsx',
#  'make_123.JAC.xlsx',
#  'make_124.JAGUAR-serial_1.xlsx',
#  'make_124.JAGUAR-serial_2.xlsx',
#  'make_124.JAGUAR-serial_3.xlsx',
#  'make_124.JAGUAR-serial_4.xlsx',
#  'make_124.JAGUAR-serial_5.xlsx',
#  'make_124.JAGUAR-serial_6.xlsx',
#  'make_124.JAGUAR-serial_7.xlsx',
#  'make_125.JEEP-serial_1.xlsx',
#  'make_125.JEEP-serial_10.xlsx',
#  'make_125.JEEP-serial_11.xlsx',
#  'make_125.JEEP-serial_12.xlsx',
#  'make_125.JEEP-serial_13.xlsx',
#  'make_125.JEEP-serial_14.xlsx',
#  'make_125.JEEP-serial_15.xlsx',
#  'make_125.JEEP-serial_16.xlsx',
#  'make_125.JEEP-serial_17.xlsx',
#  'make_125.JEEP-serial_18.xlsx',
#  'make_125.JEEP-serial_19.xlsx',
#  'make_125.JEEP-serial_2.xlsx',
#  'make_125.JEEP-serial_20.xlsx',
#  'make_125.JEEP-serial_21.xlsx',
#  'make_125.JEEP-serial_22.xlsx',
#  'make_125.JEEP-serial_23.xlsx',
#  'make_125.JEEP-serial_3.xlsx',
#  'make_125.JEEP-serial_4.xlsx',
#  'make_125.JEEP-serial_5.xlsx',
#  'make_125.JEEP-serial_6.xlsx',
#  'make_125.JEEP-serial_7.xlsx',
#  'make_125.JEEP-serial_8.xlsx',
#  'make_125.JEEP-serial_9.xlsx',
#  'make_126.JENSEN.xlsx',
#  'make_127.JEWETT.xlsx',
#  'make_128.JMC.xlsx',
#  'make_129.JORDAN.xlsx',
#  'make_13.AMPHICAR.xlsx',
#  'make_130.JOWETT.xlsx',
#  'make_131.KAISER-FRAZER.xlsx',
#  'make_132.KARMA.xlsx',
#  'make_133.KENWORTH.xlsx',
#  'make_134.KIA-serial_1.xlsx',
#  'make_134.KIA-serial_2.xlsx',
#  'make_134.KIA-serial_3.xlsx',
#  'make_134.KIA-serial_4.xlsx',
#  'make_134.KIA-serial_5.xlsx',
#  'make_134.KIA-serial_6.xlsx',
#  'make_134.KIA-serial_7.xlsx',
#  'make_134.KIA-serial_8.xlsx',
#  'make_134.KIA-serial_9.xlsx',
#  'make_135.KISSEL.xlsx',
#  'make_136.KURTIS.xlsx',
#  'make_137.LADA.xlsx',
#  'make_138.LAFORZA.xlsx',
#  'make_139.LAGONDA.xlsx',
#  'make_14.APOLLO.xlsx',
#  'make_140.LAMBORGHINI.xlsx',
#  'make_141.LANCHESTER.xlsx',
#  'make_142.LANCIA.xlsx',
#  'make_143.LAND ROVER-serial_1.xlsx',
#  'make_143.LAND ROVER-serial_2.xlsx',
#  'make_143.LAND ROVER-serial_3.xlsx',
#  'make_143.LAND ROVER-serial_4.xlsx',
#  'make_144.LASALLE.xlsx',
#  'make_145.LEA-FRANCIS.xlsx',
#  'make_146.LEXINGTON.xlsx',
#  'make_147.LEXUS-serial_1.xlsx',
#  'make_147.LEXUS-serial_10.xlsx',
#  'make_147.LEXUS-serial_11.xlsx',
#  'make_147.LEXUS-serial_2.xlsx',
#  'make_147.LEXUS-serial_3.xlsx',
#  'make_147.LEXUS-serial_4.xlsx',
#  'make_147.LEXUS-serial_5.xlsx',
#  'make_147.LEXUS-serial_6.xlsx',
#  'make_147.LEXUS-serial_7.xlsx',
#  'make_147.LEXUS-serial_8.xlsx',
#  'make_147.LEXUS-serial_9.xlsx',
#  'make_148.LINCOLN-serial_1.xlsx',
#  'make_148.LINCOLN-serial_2.xlsx',
#  'make_148.LINCOLN-serial_3.xlsx',
#  'make_148.LINCOLN-serial_4.xlsx',
#  'make_148.LINCOLN-serial_5.xlsx',
#  'make_148.LINCOLN-serial_6.xlsx',
#  'make_148.LINCOLN-serial_7.xlsx',
#  'make_148.LINCOLN-serial_8.xlsx',
#  'make_148.LINCOLN-serial_9.xlsx',
#  'make_149.LORDSTOWN MOTORS.xlsx',
#  'make_15.ARMSTRONG-SIDDELEY.xlsx',
#  'make_150.LOTUS.xlsx',
#  'make_151.LUCID.xlsx',
#  'make_152.MACK.xlsx',
#  'make_153.MAICO.xlsx',
#  'make_154.MARATHON.xlsx',
#  'make_155.MARAUDER.xlsx',
#  'make_156.MARCOS.xlsx',
#  'make_157.MARMON.xlsx',
#  'make_158.MASERATI.xlsx',
#  'make_159.MASTRETTA.xlsx',
#  'make_16.ARNOLT-BRISTOL.xlsx',
#  'make_160.MATRA.xlsx',
#  'make_161.MAXWELL.xlsx',
#  'make_162.MAYBACH.xlsx',
#  'make_163.MAZDA-serial_1.xlsx',
#  'make_163.MAZDA-serial_10.xlsx',
#  'make_163.MAZDA-serial_11.xlsx',
#  'make_163.MAZDA-serial_12.xlsx',
#  'make_163.MAZDA-serial_13.xlsx',
#  'make_163.MAZDA-serial_14.xlsx',
#  'make_163.MAZDA-serial_2.xlsx',
#  'make_163.MAZDA-serial_3.xlsx',
#  'make_163.MAZDA-serial_4.xlsx',
#  'make_163.MAZDA-serial_5.xlsx',
#  'make_163.MAZDA-serial_6.xlsx',
#  'make_163.MAZDA-serial_7.xlsx',
#  'make_163.MAZDA-serial_8.xlsx',
#  'make_163.MAZDA-serial_9.xlsx',
#  'make_164.MCLAREN.xlsx',
#  'make_165.MERCEDES-BENZ-serial_1.xlsx',
#  'make_165.MERCEDES-BENZ-serial_10.xlsx',
#  'make_165.MERCEDES-BENZ-serial_11.xlsx',
#  'make_165.MERCEDES-BENZ-serial_12.xlsx',
#  'make_165.MERCEDES-BENZ-serial_13.xlsx',
#  'make_165.MERCEDES-BENZ-serial_14.xlsx',
#  'make_165.MERCEDES-BENZ-serial_15.xlsx',
#  'make_165.MERCEDES-BENZ-serial_16.xlsx',
#  'make_165.MERCEDES-BENZ-serial_17.xlsx',
#  'make_165.MERCEDES-BENZ-serial_18.xlsx',
#  'make_165.MERCEDES-BENZ-serial_19.xlsx',
#  'make_165.MERCEDES-BENZ-serial_2.xlsx',
#  'make_165.MERCEDES-BENZ-serial_20.xlsx',
#  'make_165.MERCEDES-BENZ-serial_21.xlsx',
#  'make_165.MERCEDES-BENZ-serial_22.xlsx',
#  'make_165.MERCEDES-BENZ-serial_23.xlsx',
#  'make_165.MERCEDES-BENZ-serial_24.xlsx',
#  'make_165.MERCEDES-BENZ-serial_25.xlsx',
#  'make_165.MERCEDES-BENZ-serial_26.xlsx',
#  'make_165.MERCEDES-BENZ-serial_27.xlsx',
#  'make_165.MERCEDES-BENZ-serial_28.xlsx',
#  'make_165.MERCEDES-BENZ-serial_29.xlsx',
#  'make_165.MERCEDES-BENZ-serial_3.xlsx',
#  'make_165.MERCEDES-BENZ-serial_30.xlsx',
#  'make_165.MERCEDES-BENZ-serial_31.xlsx',
#  'make_165.MERCEDES-BENZ-serial_32.xlsx',
#  'make_165.MERCEDES-BENZ-serial_33.xlsx',
#  'make_165.MERCEDES-BENZ-serial_34.xlsx',
#  'make_165.MERCEDES-BENZ-serial_35.xlsx',
#  'make_165.MERCEDES-BENZ-serial_36.xlsx',
#  'make_165.MERCEDES-BENZ-serial_37.xlsx',
#  'make_165.MERCEDES-BENZ-serial_4.xlsx',
#  'make_165.MERCEDES-BENZ-serial_5.xlsx',
#  'make_165.MERCEDES-BENZ-serial_6.xlsx',
#  'make_165.MERCEDES-BENZ-serial_7.xlsx',
#  'make_165.MERCEDES-BENZ-serial_8.xlsx',
#  'make_165.MERCEDES-BENZ-serial_9.xlsx',
#  'make_166.MERCURY-serial_1.xlsx',
#  'make_166.MERCURY-serial_10.xlsx',
#  'make_166.MERCURY-serial_11.xlsx',
#  'make_166.MERCURY-serial_12.xlsx',
#  'make_166.MERCURY-serial_13.xlsx',
#  'make_166.MERCURY-serial_14.xlsx',
#  'make_166.MERCURY-serial_15.xlsx',
#  'make_166.MERCURY-serial_16.xlsx',
#  'make_166.MERCURY-serial_17.xlsx',
#  'make_166.MERCURY-serial_18.xlsx',
#  'make_166.MERCURY-serial_19.xlsx',
#  'make_166.MERCURY-serial_2.xlsx',
#  'make_166.MERCURY-serial_3.xlsx',
#  'make_166.MERCURY-serial_4.xlsx',
#  'make_166.MERCURY-serial_5.xlsx',
#  'make_166.MERCURY-serial_6.xlsx',
#  'make_166.MERCURY-serial_7.xlsx',
#  'make_166.MERCURY-serial_8.xlsx',
#  'make_166.MERCURY-serial_9.xlsx',
#  'make_167.MERKUR.xlsx',
#  'make_168.MESSERSCHMITT.xlsx',
#  'make_169.MG.xlsx',
#  'make_17.ARNOLT-MG.xlsx',
#  'make_170.MINI-serial_1.xlsx',
#  'make_170.MINI-serial_2.xlsx',
#  'make_170.MINI-serial_3.xlsx',
#  'make_171.MITSUBISHI-serial_1.xlsx',
#  'make_171.MITSUBISHI-serial_10.xlsx',
#  'make_171.MITSUBISHI-serial_11.xlsx',
#  'make_171.MITSUBISHI-serial_2.xlsx',
#  'make_171.MITSUBISHI-serial_3.xlsx',
#  'make_171.MITSUBISHI-serial_4.xlsx',
#  'make_171.MITSUBISHI-serial_5.xlsx',
#  'make_171.MITSUBISHI-serial_6.xlsx',
#  'make_171.MITSUBISHI-serial_7.xlsx',
#  'make_171.MITSUBISHI-serial_8.xlsx',
#  'make_171.MITSUBISHI-serial_9.xlsx',
#  'make_172.MITSUBISHI FUSO.xlsx',
#  'make_173.MOBILITY VENTURES.xlsx',
#  'make_174.MONTEVERDI.xlsx',
#  'make_175.MOON.xlsx',
#  'make_176.MORETTI.xlsx',
#  'make_177.MORGAN.xlsx',
#  'make_178.MORRIS.xlsx',
#  'make_179.MOSKVICH.xlsx',
#  'make_18.ASTON MARTIN.xlsx',
#  'make_180.NARDI.xlsx',
#  'make_181.NASH.xlsx',
#  'make_182.NISSAN-serial_1.xlsx',
#  'make_182.NISSAN-serial_10.xlsx',
#  'make_182.NISSAN-serial_11.xlsx',
#  'make_182.NISSAN-serial_12.xlsx',
#  'make_182.NISSAN-serial_13.xlsx',
#  'make_182.NISSAN-serial_14.xlsx',
#  'make_182.NISSAN-serial_15.xlsx',
#  'make_182.NISSAN-serial_16.xlsx',
#  'make_182.NISSAN-serial_17.xlsx',
#  'make_182.NISSAN-serial_18.xlsx',
#  'make_182.NISSAN-serial_19.xlsx',
#  'make_182.NISSAN-serial_2.xlsx',
#  'make_182.NISSAN-serial_20.xlsx',
#  'make_182.NISSAN-serial_21.xlsx',
#  'make_182.NISSAN-serial_22.xlsx',
#  'make_182.NISSAN-serial_3.xlsx',
#  'make_182.NISSAN-serial_4.xlsx',
#  'make_182.NISSAN-serial_5.xlsx',
#  'make_182.NISSAN-serial_6.xlsx',
#  'make_182.NISSAN-serial_7.xlsx',
#  'make_182.NISSAN-serial_8.xlsx',
#  'make_182.NISSAN-serial_9.xlsx',
#  'make_183.NSU.xlsx',
#  'make_184.OAKLAND.xlsx',
#  'make_185.OLDSMOBILE-serial_1.xlsx',
#  'make_185.OLDSMOBILE-serial_10.xlsx',
#  'make_185.OLDSMOBILE-serial_11.xlsx',
#  'make_185.OLDSMOBILE-serial_12.xlsx',
#  'make_185.OLDSMOBILE-serial_13.xlsx',
#  'make_185.OLDSMOBILE-serial_14.xlsx',
#  'make_185.OLDSMOBILE-serial_15.xlsx',
#  'make_185.OLDSMOBILE-serial_16.xlsx',
#  'make_185.OLDSMOBILE-serial_17.xlsx',
#  'make_185.OLDSMOBILE-serial_18.xlsx',
#  'make_185.OLDSMOBILE-serial_19.xlsx',
#  'make_185.OLDSMOBILE-serial_2.xlsx',
#  'make_185.OLDSMOBILE-serial_20.xlsx',
#  'make_185.OLDSMOBILE-serial_21.xlsx',
#  'make_185.OLDSMOBILE-serial_3.xlsx',
#  'make_185.OLDSMOBILE-serial_4.xlsx',
#  'make_185.OLDSMOBILE-serial_5.xlsx',
#  'make_185.OLDSMOBILE-serial_6.xlsx',
#  'make_185.OLDSMOBILE-serial_7.xlsx',
#  'make_185.OLDSMOBILE-serial_8.xlsx',
#  'make_185.OLDSMOBILE-serial_9.xlsx',
#  'make_186.OMEGA.xlsx',
#  'make_187.OPEL.xlsx',
#  'make_188.OSCA.xlsx',
#  'make_189.PACKARD.xlsx',
#  'make_19.ASUNA.xlsx',
#  'make_190.PAIGE.xlsx',
#  'make_191.PANHARD.xlsx',
#  'make_192.PANOZ.xlsx',
#  'make_193.PANTHER.xlsx',
#  'make_194.PASSPORT.xlsx',
#  'make_195.PEERLESS.xlsx',
#  'make_196.PEGASO.xlsx',
#  'make_197.PETERBILT.xlsx',
#  'make_198.PEUGEOT-serial_1.xlsx',
#  'make_198.PEUGEOT-serial_2.xlsx',
#  'make_198.PEUGEOT-serial_3.xlsx',
#  'make_199.PIERCE-ARROW.xlsx',
#  'make_2.AC.xlsx',
#  'make_20.AUBURN.xlsx',
#  'make_200.PLYMOUTH-serial_1.xlsx',
#  'make_200.PLYMOUTH-serial_10.xlsx',
#  'make_200.PLYMOUTH-serial_11.xlsx',
#  'make_200.PLYMOUTH-serial_12.xlsx',
#  'make_200.PLYMOUTH-serial_13.xlsx',
#  'make_200.PLYMOUTH-serial_14.xlsx',
#  'make_200.PLYMOUTH-serial_15.xlsx',
#  'make_200.PLYMOUTH-serial_16.xlsx',
#  'make_200.PLYMOUTH-serial_17.xlsx',
#  'make_200.PLYMOUTH-serial_18.xlsx',
#  'make_200.PLYMOUTH-serial_19.xlsx',
#  'make_200.PLYMOUTH-serial_2.xlsx',
#  'make_200.PLYMOUTH-serial_20.xlsx',
#  'make_200.PLYMOUTH-serial_21.xlsx',
#  'make_200.PLYMOUTH-serial_22.xlsx',
#  'make_200.PLYMOUTH-serial_23.xlsx',
#  'make_200.PLYMOUTH-serial_24.xlsx',
#  'make_200.PLYMOUTH-serial_25.xlsx',
#  'make_200.PLYMOUTH-serial_26.xlsx',
#  'make_200.PLYMOUTH-serial_3.xlsx',
#  'make_200.PLYMOUTH-serial_4.xlsx',
#  'make_200.PLYMOUTH-serial_5.xlsx',
#  'make_200.PLYMOUTH-serial_6.xlsx',
#  'make_200.PLYMOUTH-serial_7.xlsx',
#  'make_200.PLYMOUTH-serial_8.xlsx',
#  'make_200.PLYMOUTH-serial_9.xlsx',
#  'make_201.POLESTAR.xlsx',
#  'make_202.PONTIAC-serial_1.xlsx',
#  'make_202.PONTIAC-serial_10.xlsx',
#  'make_202.PONTIAC-serial_11.xlsx',
#  'make_202.PONTIAC-serial_12.xlsx',
#  'make_202.PONTIAC-serial_13.xlsx',
#  'make_202.PONTIAC-serial_14.xlsx',
#  'make_202.PONTIAC-serial_15.xlsx',
#  'make_202.PONTIAC-serial_16.xlsx',
#  'make_202.PONTIAC-serial_17.xlsx',
#  'make_202.PONTIAC-serial_18.xlsx',
#  'make_202.PONTIAC-serial_19.xlsx',
#  'make_202.PONTIAC-serial_2.xlsx',
#  'make_202.PONTIAC-serial_20.xlsx',
#  'make_202.PONTIAC-serial_21.xlsx',
#  'make_202.PONTIAC-serial_22.xlsx',
#  'make_202.PONTIAC-serial_23.xlsx',
#  'make_202.PONTIAC-serial_24.xlsx',
#  'make_202.PONTIAC-serial_25.xlsx',
#  'make_202.PONTIAC-serial_26.xlsx',
#  'make_202.PONTIAC-serial_3.xlsx',
#  'make_202.PONTIAC-serial_4.xlsx',
#  'make_202.PONTIAC-serial_5.xlsx',
#  'make_202.PONTIAC-serial_6.xlsx',
#  'make_202.PONTIAC-serial_7.xlsx',
#  'make_202.PONTIAC-serial_8.xlsx',
#  'make_202.PONTIAC-serial_9.xlsx',
#  'make_203.PORSCHE-serial_1.xlsx',
#  'make_203.PORSCHE-serial_2.xlsx',
#  'make_203.PORSCHE-serial_3.xlsx',
#  'make_203.PORSCHE-serial_4.xlsx',
#  'make_203.PORSCHE-serial_5.xlsx',
#  'make_203.PORSCHE-serial_6.xlsx',
#  'make_204.QVALE.xlsx',
#  'make_205.RAM-serial_1.xlsx',
#  'make_205.RAM-serial_2.xlsx',
#  'make_205.RAM-serial_3.xlsx',
#  'make_205.RAM-serial_4.xlsx',
#  'make_205.RAM-serial_5.xlsx',
#  'make_205.RAM-serial_6.xlsx',
#  'make_205.RAM-serial_7.xlsx',
#  'make_205.RAM-serial_8.xlsx',
#  'make_206.RELIANT.xlsx',
#  'make_207.RENAULT-serial_1.xlsx',
#  'make_207.RENAULT-serial_2.xlsx',
#  'make_207.RENAULT-serial_3.xlsx',
#  'make_208.REO.xlsx',
#  'make_209.RICKENBACKER.xlsx',
#  'make_21.AUDI-serial_1.xlsx',
#  'make_21.AUDI-serial_10.xlsx',
#  'make_21.AUDI-serial_11.xlsx',
#  'make_21.AUDI-serial_12.xlsx',
#  'make_21.AUDI-serial_13.xlsx',
#  'make_21.AUDI-serial_14.xlsx',
#  'make_21.AUDI-serial_2.xlsx',
#  'make_21.AUDI-serial_3.xlsx',
#  'make_21.AUDI-serial_4.xlsx',
#  'make_21.AUDI-serial_5.xlsx',
#  'make_21.AUDI-serial_6.xlsx',
#  'make_21.AUDI-serial_7.xlsx',
#  'make_21.AUDI-serial_8.xlsx',
#  'make_21.AUDI-serial_9.xlsx',
#  'make_210.RILEY.xlsx',
#  'make_211.RIVIAN.xlsx',
#  'make_212.ROAMER.xlsx',
#  'make_213.ROCKNE.xlsx',
#  'make_214.ROLLS-ROYCE-serial_1.xlsx',
#  'make_214.ROLLS-ROYCE-serial_2.xlsx',
#  'make_215.ROVER.xlsx',
#  'make_216.SAAB-serial_1.xlsx',
#  'make_216.SAAB-serial_2.xlsx',
#  'make_216.SAAB-serial_3.xlsx',
#  'make_216.SAAB-serial_4.xlsx',
#  'make_217.SABRA.xlsx',
#  'make_218.SALEEN.xlsx',
#  'make_219.SALMSON.xlsx',
#  'make_22.AUSTIN.xlsx',
#  'make_220.SATURN-serial_1.xlsx',
#  'make_220.SATURN-serial_2.xlsx',
#  'make_220.SATURN-serial_3.xlsx',
#  'make_220.SATURN-serial_4.xlsx',
#  'make_220.SATURN-serial_5.xlsx',
#  'make_221.SCION-serial_1.xlsx',
#  'make_221.SCION-serial_2.xlsx',
#  'make_222.SEAT-serial_1.xlsx',
#  'make_222.SEAT-serial_2.xlsx',
#  'make_223.SHELBY.xlsx',
#  'make_224.SIATA.xlsx',
#  'make_225.SIMCA.xlsx',
#  'make_226.SINGER.xlsx',
#  'make_227.SKODA.xlsx',
#  'make_228.SMART.xlsx',
#  'make_229.SPYKER.xlsx',
#  'make_23.AUSTIN-HEALEY.xlsx',
#  'make_230.SRT.xlsx',
#  'make_231.SSANGYONG.xlsx',
#  'make_232.STANDARD.xlsx',
#  'make_233.STAR.xlsx',
#  'make_234.STEARNS KNIGHT.xlsx',
#  'make_235.STERLING.xlsx',
#  'make_236.STEVENS-DURYEA.xlsx',
#  'make_237.STUDEBAKER-serial_1.xlsx',
#  'make_237.STUDEBAKER-serial_2.xlsx',
#  'make_237.STUDEBAKER-serial_3.xlsx',
#  'make_237.STUDEBAKER-serial_4.xlsx',
#  'make_238.STUTZ.xlsx',
#  'make_239.SUBARU-serial_1.xlsx',
#  'make_239.SUBARU-serial_2.xlsx',
#  'make_239.SUBARU-serial_3.xlsx',
#  'make_239.SUBARU-serial_4.xlsx',
#  'make_239.SUBARU-serial_5.xlsx',
#  'make_239.SUBARU-serial_6.xlsx',
#  'make_239.SUBARU-serial_7.xlsx',
#  'make_239.SUBARU-serial_8.xlsx',
#  'make_24.AVANTI.xlsx',
#  'make_240.SUNBEAM.xlsx',
#  'make_241.SUZUKI-serial_1.xlsx',
#  'make_241.SUZUKI-serial_2.xlsx',
#  'make_241.SUZUKI-serial_3.xlsx',
#  'make_241.SUZUKI-serial_4.xlsx',
#  'make_242.SWALLOW.xlsx',
#  'make_243.TALBOT-LAGO.xlsx',
#  'make_244.TATRA.xlsx',
#  'make_245.TESLA.xlsx',
#  'make_246.THINK.xlsx',
#  'make_247.TOYOTA-serial_1.xlsx',
#  'make_247.TOYOTA-serial_10.xlsx',
#  'make_247.TOYOTA-serial_11.xlsx',
#  'make_247.TOYOTA-serial_12.xlsx',
#  'make_247.TOYOTA-serial_13.xlsx',
#  'make_247.TOYOTA-serial_14.xlsx',
#  'make_247.TOYOTA-serial_15.xlsx',
#  'make_247.TOYOTA-serial_16.xlsx',
#  'make_247.TOYOTA-serial_17.xlsx',
#  'make_247.TOYOTA-serial_18.xlsx',
#  'make_247.TOYOTA-serial_19.xlsx',
#  'make_247.TOYOTA-serial_2.xlsx',
#  'make_247.TOYOTA-serial_20.xlsx',
#  'make_247.TOYOTA-serial_21.xlsx',
#  'make_247.TOYOTA-serial_3.xlsx',
#  'make_247.TOYOTA-serial_4.xlsx',
#  'make_247.TOYOTA-serial_5.xlsx',
#  'make_247.TOYOTA-serial_6.xlsx',
#  'make_247.TOYOTA-serial_7.xlsx',
#  'make_247.TOYOTA-serial_8.xlsx',
#  'make_247.TOYOTA-serial_9.xlsx',
#  'make_248.TRIUMPH.xlsx',
#  'make_249.TURNER.xlsx',
#  'make_25.BAIC.xlsx',
#  'make_250.TVR.xlsx',
#  'make_251.UAZ.xlsx',
#  'make_252.UD.xlsx',
#  'make_253.UTILIMASTER.xlsx',
#  'make_254.VAM.xlsx',
#  'make_255.VAUXHALL.xlsx',
#  'make_256.VESPA.xlsx',
#  'make_257.VINFAST.xlsx',
#  'make_258.VOLKSWAGEN-serial_1.xlsx',
#  'make_258.VOLKSWAGEN-serial_10.xlsx',
#  'make_258.VOLKSWAGEN-serial_11.xlsx',
#  'make_258.VOLKSWAGEN-serial_12.xlsx',
#  'make_258.VOLKSWAGEN-serial_13.xlsx',
#  'make_258.VOLKSWAGEN-serial_14.xlsx',
#  'make_258.VOLKSWAGEN-serial_15.xlsx',
#  'make_258.VOLKSWAGEN-serial_2.xlsx',
#  'make_258.VOLKSWAGEN-serial_3.xlsx',
#  'make_258.VOLKSWAGEN-serial_4.xlsx',
#  'make_258.VOLKSWAGEN-serial_5.xlsx',
#  'make_258.VOLKSWAGEN-serial_6.xlsx',
#  'make_258.VOLKSWAGEN-serial_7.xlsx',
#  'make_258.VOLKSWAGEN-serial_8.xlsx',
#  'make_258.VOLKSWAGEN-serial_9.xlsx',
#  'make_259.VOLVO-serial_1.xlsx',
#  'make_259.VOLVO-serial_10.xlsx',
#  'make_259.VOLVO-serial_11.xlsx',
#  'make_259.VOLVO-serial_2.xlsx',
#  'make_259.VOLVO-serial_3.xlsx',
#  'make_259.VOLVO-serial_4.xlsx',
#  'make_259.VOLVO-serial_5.xlsx',
#  'make_259.VOLVO-serial_6.xlsx',
#  'make_259.VOLVO-serial_7.xlsx',
#  'make_259.VOLVO-serial_8.xlsx',
#  'make_259.VOLVO-serial_9.xlsx',
#  'make_26.BENTLEY.xlsx',
#  'make_260.VPG.xlsx',
#  'make_261.WARTBURG.xlsx',
#  'make_262.WESTCOTT.xlsx',
#  'make_263.WHIPPET.xlsx',
#  'make_264.WILLYS.xlsx',
#  'make_265.WINDSOR.xlsx',
#  'make_266.WOLSELEY.xlsx',
#  'make_267.WORKHORSE.xlsx',
#  'make_268.YELLOW CAB.xlsx',
#  'make_269.YUGO.xlsx',
#  'make_27.BERKELEY.xlsx',
#  'make_270.ZACUA.xlsx',
#  'make_271.ZUNDAPP.xlsx',
#  'make_28.BIZZARRINI.xlsx',
#  'make_29.BMW-serial_1.xlsx',
#  'make_29.BMW-serial_10.xlsx',
#  'make_29.BMW-serial_11.xlsx',
#  'make_29.BMW-serial_12.xlsx',
#  'make_29.BMW-serial_13.xlsx',
#  'make_29.BMW-serial_14.xlsx',
#  'make_29.BMW-serial_15.xlsx',
#  'make_29.BMW-serial_16.xlsx',
#  'make_29.BMW-serial_17.xlsx',
#  'make_29.BMW-serial_18.xlsx',
#  'make_29.BMW-serial_19.xlsx',
#  'make_29.BMW-serial_2.xlsx',
#  'make_29.BMW-serial_20.xlsx',
#  'make_29.BMW-serial_21.xlsx',
#  'make_29.BMW-serial_22.xlsx',
#  'make_29.BMW-serial_23.xlsx',
#  'make_29.BMW-serial_24.xlsx',
#  'make_29.BMW-serial_25.xlsx',
#  'make_29.BMW-serial_26.xlsx',
#  'make_29.BMW-serial_27.xlsx',
#  'make_29.BMW-serial_28.xlsx',
#  'make_29.BMW-serial_3.xlsx',
#  'make_29.BMW-serial_4.xlsx',
#  'make_29.BMW-serial_5.xlsx',
#  'make_29.BMW-serial_6.xlsx',
#  'make_29.BMW-serial_7.xlsx',
#  'make_29.BMW-serial_8.xlsx',
#  'make_29.BMW-serial_9.xlsx',
#  'make_3.ACURA-serial_1.xlsx',
#  'make_3.ACURA-serial_2.xlsx',
#  'make_3.ACURA-serial_3.xlsx',
#  'make_3.ACURA-serial_4.xlsx',
#  'make_3.ACURA-serial_5.xlsx',
#  'make_3.ACURA-serial_6.xlsx',
#  'make_3.ACURA-serial_7.xlsx',
#  'make_30.BOND.xlsx',
#  'make_31.BORGWARD.xlsx',
#  'make_32.BRICKLIN.xlsx',
#  'make_33.BRIGHTDROP.xlsx',
#  'make_34.BRISTOL.xlsx',
#  'make_35.BUGATTI.xlsx',
#  'make_36.BUICK-serial_1.xlsx',
#  'make_36.BUICK-serial_10.xlsx',
#  'make_36.BUICK-serial_11.xlsx',
#  'make_36.BUICK-serial_12.xlsx',
#  'make_36.BUICK-serial_13.xlsx',
#  'make_36.BUICK-serial_14.xlsx',
#  'make_36.BUICK-serial_15.xlsx',
#  'make_36.BUICK-serial_16.xlsx',
#  'make_36.BUICK-serial_17.xlsx',
#  'make_36.BUICK-serial_2.xlsx',
#  'make_36.BUICK-serial_3.xlsx',
#  'make_36.BUICK-serial_4.xlsx',
#  'make_36.BUICK-serial_5.xlsx',
#  'make_36.BUICK-serial_6.xlsx',
#  'make_36.BUICK-serial_7.xlsx',
#  'make_36.BUICK-serial_8.xlsx',
#  'make_36.BUICK-serial_9.xlsx',
#  'make_37.CADILLAC-serial_1.xlsx',
#  'make_37.CADILLAC-serial_10.xlsx',
#  'make_37.CADILLAC-serial_11.xlsx',
#  'make_37.CADILLAC-serial_12.xlsx',
#  'make_37.CADILLAC-serial_13.xlsx',
#  'make_37.CADILLAC-serial_14.xlsx',
#  'make_37.CADILLAC-serial_15.xlsx',
#  'make_37.CADILLAC-serial_2.xlsx',
#  'make_37.CADILLAC-serial_3.xlsx',
#  'make_37.CADILLAC-serial_4.xlsx',
#  'make_37.CADILLAC-serial_5.xlsx',
#  'make_37.CADILLAC-serial_6.xlsx',
#  'make_37.CADILLAC-serial_7.xlsx',
#  'make_37.CADILLAC-serial_8.xlsx',
#  'make_37.CADILLAC-serial_9.xlsx',
#  'make_38.CASE.xlsx',
#  'make_39.CHANGAN.xlsx',
#  'make_4.ALFA ROMEO-serial_1.xlsx',
#  'make_4.ALFA ROMEO-serial_2.xlsx',
#  'make_40.CHECKER-serial_1.xlsx',
#  'make_40.CHECKER-serial_2.xlsx',
#  'make_41.CHEVROLET-serial_1.xlsx',
#  'make_41.CHEVROLET-serial_10.xlsx',
#  'make_41.CHEVROLET-serial_11.xlsx',
#  'make_41.CHEVROLET-serial_12.xlsx',
#  'make_41.CHEVROLET-serial_13.xlsx',
#  'make_41.CHEVROLET-serial_14.xlsx',
#  'make_41.CHEVROLET-serial_15.xlsx',
#  'make_41.CHEVROLET-serial_16.xlsx',
#  'make_41.CHEVROLET-serial_17.xlsx',
#  'make_41.CHEVROLET-serial_18.xlsx',
#  'make_41.CHEVROLET-serial_19.xlsx',
#  'make_41.CHEVROLET-serial_2.xlsx',
#  'make_41.CHEVROLET-serial_20.xlsx',
#  'make_41.CHEVROLET-serial_21.xlsx',
#  'make_41.CHEVROLET-serial_22.xlsx',
#  'make_41.CHEVROLET-serial_23.xlsx',
#  'make_41.CHEVROLET-serial_24.xlsx',
#  'make_41.CHEVROLET-serial_25.xlsx',
#  'make_41.CHEVROLET-serial_26.xlsx',
#  'make_41.CHEVROLET-serial_27.xlsx',
#  'make_41.CHEVROLET-serial_28.xlsx',
#  'make_41.CHEVROLET-serial_29.xlsx',
#  'make_41.CHEVROLET-serial_3.xlsx',
#  'make_41.CHEVROLET-serial_30.xlsx',
#  'make_41.CHEVROLET-serial_31.xlsx',
#  'make_41.CHEVROLET-serial_32.xlsx',
#  'make_41.CHEVROLET-serial_33.xlsx',
#  'make_41.CHEVROLET-serial_34.xlsx',
#  'make_41.CHEVROLET-serial_35.xlsx',
#  'make_41.CHEVROLET-serial_36.xlsx',
#  'make_41.CHEVROLET-serial_37.xlsx',
#  'make_41.CHEVROLET-serial_38.xlsx',
#  'make_41.CHEVROLET-serial_39.xlsx',
#  'make_41.CHEVROLET-serial_4.xlsx',
#  'make_41.CHEVROLET-serial_40.xlsx',
#  'make_41.CHEVROLET-serial_41.xlsx',
#  'make_41.CHEVROLET-serial_42.xlsx',
#  'make_41.CHEVROLET-serial_43.xlsx',
#  'make_41.CHEVROLET-serial_44.xlsx',
#  'make_41.CHEVROLET-serial_45.xlsx',
#  'make_41.CHEVROLET-serial_46.xlsx',
#  'make_41.CHEVROLET-serial_47.xlsx',
#  'make_41.CHEVROLET-serial_48.xlsx',
#  'make_41.CHEVROLET-serial_49.xlsx',
#  'make_41.CHEVROLET-serial_5.xlsx',
#  'make_41.CHEVROLET-serial_50.xlsx',
#  'make_41.CHEVROLET-serial_51.xlsx',
#  'make_41.CHEVROLET-serial_52.xlsx',
#  'make_41.CHEVROLET-serial_53.xlsx',
#  'make_41.CHEVROLET-serial_54.xlsx',
#  'make_41.CHEVROLET-serial_55.xlsx',
#  'make_41.CHEVROLET-serial_56.xlsx',
#  'make_41.CHEVROLET-serial_57.xlsx',
#  'make_41.CHEVROLET-serial_58.xlsx',
#  'make_41.CHEVROLET-serial_59.xlsx',
#  'make_41.CHEVROLET-serial_6.xlsx',
#  'make_41.CHEVROLET-serial_60.xlsx',
#  'make_41.CHEVROLET-serial_61.xlsx',
#  'make_41.CHEVROLET-serial_62.xlsx',
#  'make_41.CHEVROLET-serial_63.xlsx',
#  'make_41.CHEVROLET-serial_64.xlsx',
#  'make_41.CHEVROLET-serial_65.xlsx',
#  'make_41.CHEVROLET-serial_66.xlsx',
#  'make_41.CHEVROLET-serial_67.xlsx',
#  'make_41.CHEVROLET-serial_68.xlsx',
#  'make_41.CHEVROLET-serial_69.xlsx',
#  'make_41.CHEVROLET-serial_7.xlsx',
#  'make_41.CHEVROLET-serial_70.xlsx',
#  'make_41.CHEVROLET-serial_71.xlsx',
#  'make_41.CHEVROLET-serial_72.xlsx',
#  'make_41.CHEVROLET-serial_73.xlsx',
#  'make_41.CHEVROLET-serial_74.xlsx',
#  'make_41.CHEVROLET-serial_75.xlsx',
#  'make_41.CHEVROLET-serial_76.xlsx',
#  'make_41.CHEVROLET-serial_77.xlsx',
#  'make_41.CHEVROLET-serial_78.xlsx',
#  'make_41.CHEVROLET-serial_79.xlsx',
#  'make_41.CHEVROLET-serial_8.xlsx',
#  'make_41.CHEVROLET-serial_80.xlsx',
#  'make_41.CHEVROLET-serial_81.xlsx',
#  'make_41.CHEVROLET-serial_82.xlsx',
#  'make_41.CHEVROLET-serial_83.xlsx',
#  'make_41.CHEVROLET-serial_84.xlsx',
#  'make_41.CHEVROLET-serial_85.xlsx',
#  'make_41.CHEVROLET-serial_86.xlsx',
#  'make_41.CHEVROLET-serial_87.xlsx',
#  'make_41.CHEVROLET-serial_88.xlsx',
#  'make_41.CHEVROLET-serial_89.xlsx',
#  'make_41.CHEVROLET-serial_9.xlsx',
#  'make_41.CHEVROLET-serial_90.xlsx',
#  'make_41.CHEVROLET-serial_91.xlsx',
#  'make_41.CHEVROLET-serial_92.xlsx',
#  'make_41.CHEVROLET-serial_93.xlsx',
#  'make_41.CHEVROLET-serial_94.xlsx',
#  'make_42.CHIREY.xlsx',
#  'make_43.CHRYSLER-serial_1.xlsx',
#  'make_43.CHRYSLER-serial_10.xlsx',
#  'make_43.CHRYSLER-serial_11.xlsx',
#  'make_43.CHRYSLER-serial_12.xlsx',
#  'make_43.CHRYSLER-serial_13.xlsx',
#  'make_43.CHRYSLER-serial_14.xlsx',
#  'make_43.CHRYSLER-serial_15.xlsx',
#  'make_43.CHRYSLER-serial_16.xlsx',
#  'make_43.CHRYSLER-serial_2.xlsx',
#  'make_43.CHRYSLER-serial_3.xlsx',
#  'make_43.CHRYSLER-serial_4.xlsx',
#  'make_43.CHRYSLER-serial_5.xlsx',
#  'make_43.CHRYSLER-serial_6.xlsx',
#  'make_43.CHRYSLER-serial_7.xlsx',
#  'make_43.CHRYSLER-serial_8.xlsx',
#  'make_43.CHRYSLER-serial_9.xlsx',
#  'make_44.CISITALIA.xlsx',
#  'make_45.CITROEN.xlsx',
#  'make_46.COLE.xlsx',
#  'make_47.CONTINENTAL.xlsx',
#  'make_48.CORD.xlsx',
#  'make_49.CROSLEY.xlsx',
#  'make_5.ALLARD.xlsx',
#  'make_50.CUNNINGHAM.xlsx',
#  'make_51.CUPRA.xlsx',
#  'make_52.DAEWOO.xlsx',
#  'make_53.DAF.xlsx',
#  'make_54.DAIHATSU.xlsx',
#  'make_55.DAIMLER.xlsx',
#  'make_56.DATSUN.xlsx',
#  'make_57.DELAGE.xlsx',
#  'make_58.DELAHAYE.xlsx',
#  'make_59.DELLOW.xlsx',
#  'make_6.ALLSTATE.xlsx',
#  'make_60.DELOREAN.xlsx',
#  'make_61.DENZEL.xlsx',
#  'make_62.DESOTO.xlsx',
#  'make_63.DETOMASO.xlsx',
#  'make_64.DEUTSCH-BONNET.xlsx',
#  'make_65.DIANA.xlsx',
#  'make_66.DKW.xlsx',
#  'make_67.DODGE-serial_1.xlsx',
#  'make_67.DODGE-serial_10.xlsx',
#  'make_67.DODGE-serial_11.xlsx',
#  'make_67.DODGE-serial_12.xlsx',
#  'make_67.DODGE-serial_13.xlsx',
#  'make_67.DODGE-serial_14.xlsx',
#  'make_67.DODGE-serial_15.xlsx',
#  'make_67.DODGE-serial_16.xlsx',
#  'make_67.DODGE-serial_17.xlsx',
#  'make_67.DODGE-serial_18.xlsx',
#  'make_67.DODGE-serial_19.xlsx',
#  'make_67.DODGE-serial_2.xlsx',
#  'make_67.DODGE-serial_20.xlsx',
#  'make_67.DODGE-serial_21.xlsx',
#  'make_67.DODGE-serial_22.xlsx',
#  'make_67.DODGE-serial_23.xlsx',
#  'make_67.DODGE-serial_24.xlsx',
#  'make_67.DODGE-serial_25.xlsx',
#  'make_67.DODGE-serial_26.xlsx',
#  'make_67.DODGE-serial_27.xlsx',
#  'make_67.DODGE-serial_28.xlsx',
#  'make_67.DODGE-serial_29.xlsx',
#  'make_67.DODGE-serial_3.xlsx',
#  'make_67.DODGE-serial_30.xlsx',
#  'make_67.DODGE-serial_31.xlsx',
#  'make_67.DODGE-serial_32.xlsx',
#  'make_67.DODGE-serial_33.xlsx',
#  'make_67.DODGE-serial_34.xlsx',
#  'make_67.DODGE-serial_35.xlsx',
#  'make_67.DODGE-serial_36.xlsx',
#  'make_67.DODGE-serial_37.xlsx',
#  'make_67.DODGE-serial_38.xlsx',
#  'make_67.DODGE-serial_39.xlsx',
#  'make_67.DODGE-serial_4.xlsx',
#  'make_67.DODGE-serial_40.xlsx',
#  'make_67.DODGE-serial_41.xlsx',
#  'make_67.DODGE-serial_42.xlsx',
#  'make_67.DODGE-serial_43.xlsx',
#  'make_67.DODGE-serial_44.xlsx',
#  'make_67.DODGE-serial_45.xlsx',
#  'make_67.DODGE-serial_46.xlsx',
#  'make_67.DODGE-serial_47.xlsx',
#  'make_67.DODGE-serial_48.xlsx',
#  'make_67.DODGE-serial_49.xlsx',
#  'make_67.DODGE-serial_5.xlsx',
#  'make_67.DODGE-serial_50.xlsx',
#  'make_67.DODGE-serial_51.xlsx',
#  'make_67.DODGE-serial_52.xlsx',
#  'make_67.DODGE-serial_53.xlsx',
#  'make_67.DODGE-serial_54.xlsx',
#  'make_67.DODGE-serial_55.xlsx',
#  'make_67.DODGE-serial_56.xlsx',
#  'make_67.DODGE-serial_57.xlsx',
#  'make_67.DODGE-serial_58.xlsx',
#  'make_67.DODGE-serial_6.xlsx',
#  'make_67.DODGE-serial_7.xlsx',
#  'make_67.DODGE-serial_8.xlsx',
#  'make_67.DODGE-serial_9.xlsx',
#  'make_68.DORETTI.xlsx',
#  'make_69.DU PONT.xlsx',
#  'make_7.ALPINE.xlsx',
#  'make_70.DUAL-GHIA.xlsx',
#  'make_71.DUESENBERG.xlsx',
#  'make_72.DURANT.xlsx',
#  'make_73.EAGLE-serial_1.xlsx',
#  'make_73.EAGLE-serial_2.xlsx',
#  'make_74.EDSEL.xlsx',
#  'make_75.ELCAR.xlsx',
#  'make_76.ELVA.xlsx',
#  'make_77.ERSKINE.xlsx',
#  'make_78.ESSEX.xlsx',
#  'make_79.EXCALIBUR.xlsx',
#  'make_8.ALVIS.xlsx',
#  'make_80.FACEL VEGA.xlsx',
#  'make_81.FAIRTHORPE.xlsx',
#  'make_82.FALCON KNIGHT.xlsx',
#  'make_83.FARGO-serial_1.xlsx',
#  'make_83.FARGO-serial_2.xlsx',
#  'make_83.FARGO-serial_3.xlsx',
#  'make_84.FAW.xlsx',
#  'make_85.FERRARI.xlsx',
#  'make_86.FIAT-serial_1.xlsx',
#  'make_86.FIAT-serial_2.xlsx',
#  'make_86.FIAT-serial_3.xlsx',
#  'make_87.FISKER.xlsx',
#  'make_88.FLINT.xlsx',
#  'make_89.FORD-serial_1.xlsx',
#  'make_89.FORD-serial_10.xlsx',
#  'make_89.FORD-serial_11.xlsx',
#  'make_89.FORD-serial_12.xlsx',
#  'make_89.FORD-serial_13.xlsx',
#  'make_89.FORD-serial_14.xlsx',
#  'make_89.FORD-serial_15.xlsx',
#  'make_89.FORD-serial_16.xlsx',
#  'make_89.FORD-serial_17.xlsx',
#  'make_89.FORD-serial_18.xlsx',
#  'make_89.FORD-serial_19.xlsx',
#  'make_89.FORD-serial_2.xlsx',
#  'make_89.FORD-serial_20.xlsx',
#  'make_89.FORD-serial_21.xlsx',
#  'make_89.FORD-serial_22.xlsx',
#  'make_89.FORD-serial_23.xlsx',
#  'make_89.FORD-serial_24.xlsx',
#  'make_89.FORD-serial_25.xlsx',
#  'make_89.FORD-serial_26.xlsx',
#  'make_89.FORD-serial_27.xlsx',
#  'make_89.FORD-serial_28.xlsx',
#  'make_89.FORD-serial_29.xlsx',
#  'make_89.FORD-serial_3.xlsx',
#  'make_89.FORD-serial_30.xlsx',
#  'make_89.FORD-serial_31.xlsx',
#  'make_89.FORD-serial_32.xlsx',
#  'make_89.FORD-serial_33.xlsx',
#  'make_89.FORD-serial_34.xlsx',
#  'make_89.FORD-serial_35.xlsx',
#  'make_89.FORD-serial_36.xlsx',
#  'make_89.FORD-serial_37.xlsx',
#  'make_89.FORD-serial_38.xlsx',
#  'make_89.FORD-serial_39.xlsx',
#  'make_89.FORD-serial_4.xlsx',
#  'make_89.FORD-serial_40.xlsx',
#  'make_89.FORD-serial_41.xlsx',
#  'make_89.FORD-serial_42.xlsx',
#  'make_89.FORD-serial_43.xlsx',
#  'make_89.FORD-serial_44.xlsx',
#  'make_89.FORD-serial_45.xlsx',
#  'make_89.FORD-serial_46.xlsx',
#  'make_89.FORD-serial_47.xlsx',
#  'make_89.FORD-serial_48.xlsx',
#  'make_89.FORD-serial_49.xlsx',
#  'make_89.FORD-serial_5.xlsx',
#  'make_89.FORD-serial_50.xlsx',
#  'make_89.FORD-serial_51.xlsx',
#  'make_89.FORD-serial_52.xlsx',
#  'make_89.FORD-serial_53.xlsx',
#  'make_89.FORD-serial_54.xlsx',
#  'make_89.FORD-serial_55.xlsx',
#  'make_89.FORD-serial_56.xlsx',
#  'make_89.FORD-serial_57.xlsx',
#  'make_89.FORD-serial_58.xlsx',
#  'make_89.FORD-serial_59.xlsx',
#  'make_89.FORD-serial_6.xlsx',
#  'make_89.FORD-serial_60.xlsx',
#  'make_89.FORD-serial_61.xlsx',
#  'make_89.FORD-serial_62.xlsx',
#  'make_89.FORD-serial_63.xlsx',
#  'make_89.FORD-serial_64.xlsx',
#  'make_89.FORD-serial_65.xlsx',
#  'make_89.FORD-serial_66.xlsx',
#  'make_89.FORD-serial_67.xlsx',
#  'make_89.FORD-serial_68.xlsx',
#  'make_89.FORD-serial_69.xlsx',
#  'make_89.FORD-serial_7.xlsx',
#  'make_89.FORD-serial_70.xlsx',
#  'make_89.FORD-serial_71.xlsx',
#  'make_89.FORD-serial_8.xlsx',
#  'make_89.FORD-serial_9.xlsx',
#  'make_9.AM GENERAL.xlsx',
#  'make_90.FOTON.xlsx',
#  'make_91.FRANKLIN.xlsx',
#  'make_92.FRAZER NASH.xlsx',
#  'make_93.FREIGHTLINER-serial_1.xlsx',
#  'make_93.FREIGHTLINER-serial_2.xlsx',
#  'make_93.FREIGHTLINER-serial_3.xlsx',
#  'make_94.GARDNER.xlsx',
#  'make_95.GENESIS.xlsx',
#  'make_96.GEO-serial_1.xlsx',
#  'make_96.GEO-serial_2.xlsx',
#  'make_97.GIANT MOTORS.xlsx',
#  'make_98.GLAS.xlsx',
#  'make_99.GMC-serial_1.xlsx',
#  'make_99.GMC-serial_10.xlsx',
#  'make_99.GMC-serial_11.xlsx',
#  'make_99.GMC-serial_12.xlsx',
#  'make_99.GMC-serial_13.xlsx',
#  'make_99.GMC-serial_14.xlsx',
#  'make_99.GMC-serial_15.xlsx',
#  'make_99.GMC-serial_16.xlsx',
#  'make_99.GMC-serial_17.xlsx',
#  'make_99.GMC-serial_18.xlsx',
#  'make_99.GMC-serial_19.xlsx',
#  'make_99.GMC-serial_2.xlsx',
#  'make_99.GMC-serial_20.xlsx',
#  'make_99.GMC-serial_21.xlsx',
#  'make_99.GMC-serial_22.xlsx',
#  'make_99.GMC-serial_23.xlsx',
#  'make_99.GMC-serial_24.xlsx',
#  'make_99.GMC-serial_25.xlsx',
#  'make_99.GMC-serial_26.xlsx',
#  'make_99.GMC-serial_27.xlsx',
#  'make_99.GMC-serial_28.xlsx',
#  'make_99.GMC-serial_29.xlsx',
#  'make_99.GMC-serial_3.xlsx',
#  'make_99.GMC-serial_30.xlsx',
#  'make_99.GMC-serial_31.xlsx',
#  'make_99.GMC-serial_32.xlsx',
#  'make_99.GMC-serial_33.xlsx',
#  'make_99.GMC-serial_34.xlsx',
#  'make_99.GMC-serial_35.xlsx',
#  'make_99.GMC-serial_36.xlsx',
#  'make_99.GMC-serial_37.xlsx',
#  'make_99.GMC-serial_38.xlsx',
#  'make_99.GMC-serial_39.xlsx',
#  'make_99.GMC-serial_4.xlsx',
#  'make_99.GMC-serial_40.xlsx',
#  'make_99.GMC-serial_41.xlsx',
#  'make_99.GMC-serial_42.xlsx',
#  'make_99.GMC-serial_43.xlsx',
#  'make_99.GMC-serial_44.xlsx',
#  'make_99.GMC-serial_45.xlsx',
#  'make_99.GMC-serial_46.xlsx',
#  'make_99.GMC-serial_47.xlsx',
#  'make_99.GMC-serial_48.xlsx',
#  'make_99.GMC-serial_49.xlsx',
#  'make_99.GMC-serial_5.xlsx',
#  ...]

# %%
for file in list_file[list_file.index('make_121.ISUZU-serial_7.xlsx'):]:

    # = = = = = = = = = = = = = = =

    import pandas as pd

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./{param_date}/9.type/{file}',
                           header=0,
                           dtype=str).fillna('')

    input_['Make No'] = input_['Make No'].astype(int)
    input_['Model No'] = input_['Model No'].astype(int)
    input_['Engine No'] = input_['Engine No'].astype(int)
    input_['Year'] = input_['Year'].astype(int)
    input_['Group No'] = input_['Group No'].astype(int)
    input_['Type No'] = input_['Type No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =

    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            import requests
            import json

            import sys
            sys.path.append('../../00.Tools')
            from crawler_configuration import get_header, get_proxy

            payload = {'jsn': {'tab': 'catalog',
                               'make': input_.loc[a, 'Make'],
                               'year': int(input_.loc[a, 'Year']),
                               'model': input_.loc[a, 'Model'],
                               'carcode': input_.loc[a, 'Car Code'],
                               'engine': input_.loc[a, 'Engine'],
                               'groupname': input_.loc[a, 'Group'],
                               'parttype': input_.loc[a, 'Type Code'],
                               'nodetype': 'parttype'}}

            data = {'func': 'navnode_fetch',
                    'payload': json.dumps(payload),
                    'api_json_request': '1'}

            try:
                b = 0
                while True:

                    while True:
                        b += 1
                        try:
                            resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                                 data=data,
                                                 headers=get_header(),
                                                 proxies=get_proxy(),
                                                 timeout=(10, 10))
                            break
                        except:
                            continue

                    if resp.status_code == 200:
                        json_ = resp.json()
                        if 'redirect_to_url' in json_:
                            continue
                        elif json_['jsn']['tab'] == 'catalog' and json_['jsn']['make'] == input_.loc[a, 'Make'] and json_['jsn']['year'] == input_.loc[a, 'Year'] and json_['jsn']['model'] == input_.loc[a, 'Model'] and json_['jsn']['carcode'] == input_.loc[a, 'Car Code'] and json_['jsn']['engine'] == input_.loc[a, 'Engine'] and json_['jsn']['groupname'] == input_.loc[a, 'Group'] and json_['jsn']['parttype'] == input_.loc[a, 'Type Code'] and json_['jsn']['nodetype'] == 'parttype' and 'collected_javascript' in json_:
                            break

                # = = = = = = = = = = = = = = =

                from bs4 import BeautifulSoup
                from lxml import etree

                soup = BeautifulSoup(json_['html_fill_sections']['navchildren[]'], 'lxml')
                html = etree.HTML(str(soup))

                # = = = = = = = = = = = = = = =

                list_tbody = html.xpath('//tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-a-1") or contains(@class, "altrow-a-0"))]')

                # = = = = = = = = = = = = = = =

                if not list_tbody:
                    raise

                # = = = = = = = = = = = = = = =

                list_list_note = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row-moreinfo-truck"]/span[@class="span-link-underline-remover"]/text()') for tbody in list_tbody]
                list_note = ['\n'.join([note.strip() for note in list_note]) for list_note in list_list_note]

                # = = = = = = = = = = = = = = =

                list_list_info = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row-moreinfo-truck"]/a[@class="ra-btn ra-btn-moreinfo"]/@href') for tbody in list_tbody]
                list_info = [list_info[0].strip() if list_info and list_info[0].startswith('https://www.rockauto.com/en/moreinfo.php?') else '' for list_info in list_list_info]

                # = = = = = = = = = = = = = = =

                list_dict_note = []
                list_span = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row"]/span[contains(@title, "Please make sure")]')[0] for tbody in list_tbody]

                for span in list_span:
                    dict_note = {}
                    list_note_2 = span.xpath('./span[@class="listing-footnote-text"]/text()')
                    list_market = span.xpath('./span[@class="listing-footnote-text"]/a[@class="appflag"]/@data-market')
                    if list_market:
                        dict_note['separate'] = {}
                        for i, note, market in zip(range(len(list_note_2)), list_note_2, list_market):
                            dict_note['separate'][str(i)] = {'market': market.strip(), 'note': note.strip()}
                    else:
                        dict_note = {'combined': {'note': ''.join(list_note_2).strip()}}

                    list_dict_note.append(dict_note)

                # = = = = = = = = = = = = = = =

                list_json = [json.loads(tbody.xpath('./tr[1]/td[contains(@class, "listing-inner-content")]/input[contains(@id, "listing_data_essential[__GIP__")]/@value')[0]) for tbody in list_tbody]

                # = = = = = = = = = = = = = = =

                list_key = [json_['partkey'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_json = [json.loads(tbody.xpath('./tr[1]/td/input[contains(@id, "listing_data_supplemental[")]/@value')[0]) for tbody in list_tbody]

                # = = = = = = = = = = = = = = =

                list_part_number = [json_['partnumber'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_manufacturer = [json_['catalogname'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_partition = [json_['sortgrouptext'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_parameter = [json_['paramdesc'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_list_oem = [tbody.xpath('./tr[1]/td/span[contains(@title, "Replaces these Alternate")]/text()') for tbody in list_tbody]
                list_oem = [','.join(list_oem) for list_oem in list_list_oem]
                list_oem = [';'.join([oem_split.strip() for oem_split in oem.split(',')]) for oem in list_oem]

                # = = = = = = = = = = = = = = =

                list_list_src = [json.loads(tbody.xpath('./tr[1]/td/div/input[contains(@id, "jsninlineimg[")]/@value')[0])['Slots'] if tbody.xpath('./tr[1]/td/div/input[contains(@id, "jsninlineimg[")]/@value') else [] for tbody in list_tbody]

                # = = = = = = = = = = = = = = =

                list_dict_src = []
                for list_src in list_list_src:
                    dict_src = {}
                    for i, src in zip(range(len(list_src)), list_src):
                        dict_src[str(i)] = 'https://www.rockauto.com' + src['ImageData']['Full'].strip()

                    list_dict_src.append(dict_src)

                # = = = = = = = = = = = = = = =

                import re

                list_price = [etree.tostring(tbody.xpath('./tr[1]/td[contains(@id, "listingtd[") and contains(@id, "][price]")]/span/span/span[contains(@id, "dprice[") and contains(@id, "][v]")]')[0]).decode('utf-8') for tbody in list_tbody]
                list_dict_price = [{'0': re.sub(r'<.*?>', '', price.strip())} for price in list_price]

                # = = = = = = = = = = = = = = =

                list_list_li = [tbody.xpath('./tr[1]/td/div/div/span/span[contains(@id, "ddrepl[optionchoice[__")]/table/tr/td[1]/div/div/ul/li') for tbody in list_tbody]
                for i, list_li in zip(range(len(list_list_li)), list_list_li):
                    if list_li:
                        list_dict_price[i]['1'] = {}
                        for j, li in zip(range(len(list_li[1:])), list_li[1:]):
                            list_dict_price[i]['1'][str(j)] = re.sub(r' +', ' ', re.sub(r'<.*?>', ' ', etree.tostring(li.xpath('./div[contains(@class, "outer")]/div[contains(@class, "inner")]')[0]).decode('utf-8'))).strip()

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'Make No': input_.loc[a, 'Make No'],
                                        'Make': input_.loc[a, 'Make'],
                                        'Model No': input_.loc[a, 'Model No'],
                                        'Model': input_.loc[a, 'Model'],
                                        'Engine No': input_.loc[a, 'Engine No'],
                                        'Engine': input_.loc[a, 'Engine'],
                                        'Car Code': input_.loc[a, 'Car Code'],
                                        'Year': input_.loc[a, 'Year'],
                                        'Group No': input_.loc[a, 'Group No'],
                                        'Group': input_.loc[a, 'Group'],
                                        'Type No': input_.loc[a, 'Type No'],
                                        'Type': input_.loc[a, 'Type'],
                                        'Type Code': input_.loc[a, 'Type Code'],
                                        'Tab 1 Url': input_.loc[a, 'Tab 1 Url'],
                                        'Part No': [i+1 for i in range(len(list_part_number))],
                                        'Partition': list_partition,
                                        'Manufacturer': list_manufacturer,
                                        'Part Number': list_part_number,
                                        'Key': list_key,
                                        'JOIN_MPNTCK': [f'''{manufacturer};{part_number};{input_.loc[a, 'Type Code']};{key}''' for manufacturer, part_number, key in zip(list_manufacturer, list_part_number, list_key)],
                                        'Tab 1 Note 1': list_note,
                                        'Tab 1 Note 2': [json.dumps(dict_note) for dict_note in list_dict_note],
                                        'Parameter': list_parameter,
                                        #'Json_Price': [json.dumps(dict_price) for dict_price in list_dict_price],
                                        'OEM': list_oem,
                                        'Info': list_info,
                                        'Json_Src': [json.dumps(dict_src) for dict_src in list_dict_src]})

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([{'Make No': input_.loc[a, 'Make No'],
                                         'Make': input_.loc[a, 'Make'],
                                         'Model No': input_.loc[a, 'Model No'],
                                         'Model': input_.loc[a, 'Model'],
                                         'Engine No': input_.loc[a, 'Engine No'],
                                         'Engine': input_.loc[a, 'Engine'],
                                         'Car Code': input_.loc[a, 'Car Code'],
                                         'Year': input_.loc[a, 'Year'],
                                         'Group No': input_.loc[a, 'Group No'],
                                         'Group': input_.loc[a, 'Group'],
                                         'Type No': input_.loc[a, 'Type No'],
                                         'Type': input_.loc[a, 'Type'],
                                         'Type Code': input_.loc[a, 'Type Code'],
                                         'Tab 1 Url': input_.loc[a, 'Tab 1 Url']}])

                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Model No']}.{input_.loc[a, 'Model']} > {input_.loc[a, 'Engine No']}.{input_.loc[a, 'Engine']} > {input_.loc[a, 'Year']} > {input_.loc[a, 'Group No']}.{input_.loc[a, 'Group']} > {input_.loc[a, 'Type No']}.{input_.loc[a, 'Type']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(9):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No', 'Type No', 'Part No'],
                                                    ascending=[True, True, True, False, True, True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./{param_date}/10.part_1/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No', 'Type No'],
                                                ascending=[True, True, True, False, True, True],
                                                ignore_index=True)
        output_error.to_excel(f'''./{param_date}/10.part_1/0.error/{file.removesuffix('.xlsx')}-part_1_error.xlsx''', index=False)
        print('爬虫存在error')
        print()
print('Done ~')
# Out:
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 6.Cylinder Head Gasket
# [剩余数量：1000] - [当前时间：16:34:10]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 8.Engine Block Heater
# [剩余数量：999] - [当前时间：16:34:10]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 14.Oil Cooler Line
# [剩余数量：998] - [当前时间：16:34:11]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 4.Crankshaft Seal
# [剩余数量：997] - [当前时间：16:34:11]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 15.Oil Drain Plug
# [剩余数量：996] - [当前时间：16:34:12]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 19.Oil Level Sensor
# [剩余数量：995] - [当前时间：16:34:12]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 20.Oil Pan Gasket
# [剩余数量：994] - [当前时间：16:34:13]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 22.Piston Ring
# [剩余数量：993] - [当前时间：16:34:13]
#
# [状态：ok，尝试次数：6] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 9.Electrical-Switch & Relay > 11.Wiper / Washer Switch
# [剩余数量：992] - [当前时间：16:34:14]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 23.Timing Chain
# [剩余数量：991] - [当前时间：16:34:14]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 25.Turbocharger Mounting Kit
# [剩余数量：990] - [当前时间：16:34:16]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 24.Timing Chain Tensioner
# [剩余数量：989] - [当前时间：16:34:16]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 27.Valve Stem Seal
# [剩余数量：988] - [当前时间：16:34:16]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 21.Oil Pump Gasket
# [剩余数量：987] - [当前时间：16:34:16]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 26.Valve Cover Gasket
# [剩余数量：986] - [当前时间：16:34:17]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 28.Variable Valve Timing (VVT) Solenoid / Actuator
# [剩余数量：985] - [当前时间：16:34:17]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 2.Catalytic Converter
# [剩余数量：984] - [当前时间：16:34:18]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 3.Exhaust Manifold Gasket
# [剩余数量：983] - [当前时间：16:34:18]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 6.Mass Air Flow (MAF) Sensor
# [剩余数量：982] - [当前时间：16:34:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 5.Manifold Pressure (MAP) Sensor
# [剩余数量：981] - [当前时间：16:34:20]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 4.Knock / Detonation Sensor
# [剩余数量：980] - [当前时间：16:34:20]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 1.Air / Smog Pump
# [剩余数量：979] - [当前时间：16:34:21]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 7.Oxygen (O2) Sensor
# [剩余数量：978] - [当前时间：16:34:21]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 10.Intake Manifold Gasket
# [剩余数量：977] - [当前时间：16:34:21]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 9.Vapor Canister Purge Valve / Solenoid
# [剩余数量：976] - [当前时间：16:34:22]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 1.Air Filter
# [剩余数量：975] - [当前时间：16:34:22]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 2.Air Intake / Charge Temperature Sensor
# [剩余数量：974] - [当前时间：16:34:22]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 17.Oil Filter
# [剩余数量：973] - [当前时间：16:34:23]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 11.Exhaust & Emission > 8.Vapor Canister
# [剩余数量：972] - [当前时间：16:34:24]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 5.Fuel Injector
# [剩余数量：971] - [当前时间：16:34:24]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 3.Fuel Filter
# [剩余数量：970] - [当前时间：16:34:24]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 8.Fuel Pump & Housing Assembly
# [剩余数量：969] - [当前时间：16:34:24]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 4.Fuel Injection Pressure Sensor
# [剩余数量：968] - [当前时间：16:34:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 10.Fuel Tank Cap
# [剩余数量：967] - [当前时间：16:34:26]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 9.Fuel Pump Gasket / Seal
# [剩余数量：966] - [当前时间：16:34:26]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 11.Fuel Tank Cap Tester Adapter
# [剩余数量：965] - [当前时间：16:34:27]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 7.Fuel Pump
# [剩余数量：964] - [当前时间：16:34:27]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 12.Fuel Tank Pressure Sensor
# [剩余数量：963] - [当前时间：16:34:27]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 1.A/C Compressor
# [剩余数量：962] - [当前时间：16:34:27]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 2.A/C Compressor & Component Kit
# [剩余数量：961] - [当前时间：16:34:28]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 8.A/C System O-Rings / Seals
# [剩余数量：960] - [当前时间：16:34:29]
#
# [状态：ok，尝试次数：6] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 18.Oil Filter Adapter Gasket / O-Ring
# [剩余数量：959] - [当前时间：16:34:29]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 6.A/C Receiver Drier Desiccant Element
# [剩余数量：958] - [当前时间：16:34:30]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 5.A/C Expansion Valve
# [剩余数量：957] - [当前时间：16:34:30]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 7.A/C Refrigerant Oil
# [剩余数量：956] - [当前时间：16:34:31]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 9.Ambient Air Temperature Sensor
# [剩余数量：955] - [当前时间：16:34:31]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 3.A/C Condenser
# [剩余数量：954] - [当前时间：16:34:31]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 12.Fuel & Air > 6.Fuel Injector Seal / O-Ring
# [剩余数量：953] - [当前时间：16:34:32]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 12.Cabin Air Filter
# [剩余数量：952] - [当前时间：16:34:32]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 4.A/C Evaporator Core
# [剩余数量：951] - [当前时间：16:34:33]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 10.Engine > 16.Oil Filler Cap
# [剩余数量：950] - [当前时间：16:34:34]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 14.Ignition > 2.Crankshaft Position Sensor
# [剩余数量：949] - [当前时间：16:34:34]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 11.Blower Motor Control Module / Resistor
# [剩余数量：948] - [当前时间：16:34:35]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 14.Ignition > 4.Spark Plug
# [剩余数量：947] - [当前时间：16:34:35]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 14.Heater Hose
# [剩余数量：946] - [当前时间：16:34:36]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 2.Power Steering Pump
# [剩余数量：945] - [当前时间：16:34:36]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 14.Ignition > 3.Ignition Coil
# [剩余数量：944] - [当前时间：16:34:37]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 1.Power Steering Fluid
# [剩余数量：943] - [当前时间：16:34:37]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 13.Cabin Air Temperature Sensor
# [剩余数量：942] - [当前时间：16:34:37]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 14.Ignition > 1.Camshaft Position Sensor
# [剩余数量：941] - [当前时间：16:34:38]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 4.Rack and Pinion
# [剩余数量：940] - [当前时间：16:34:38]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 1.Air Suspension Solenoid / Valve
# [剩余数量：939] - [当前时间：16:34:40]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 5.Rack and Pinion Bellow
# [剩余数量：938] - [当前时间：16:34:40]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 15.Interior > 1.Accelerator Pedal Position Sensor
# [剩余数量：937] - [当前时间：16:34:40]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 6.Rack and Pinion Bushing
# [剩余数量：936] - [当前时间：16:34:41]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 7.Tie Rod End
# [剩余数量：935] - [当前时间：16:34:41]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 16.Steering > 3.Power Steering Reservoir
# [剩余数量：934] - [当前时间：16:34:42]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 6.Shock / Strut Mount
# [剩余数量：933] - [当前时间：16:34:42]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 2.Bushing Kit
# [剩余数量：932] - [当前时间：16:34:43]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 1.Accumulator
# [剩余数量：931] - [当前时间：16:34:43]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 2.Coil Spring Seat / Insulator
# [剩余数量：930] - [当前时间：16:34:43]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 8.Sway Bar Link
# [剩余数量：929] - [当前时间：16:34:45]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 7.Shock Bushing
# [剩余数量：928] - [当前时间：16:34:45]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 3.Clutch Plate
# [剩余数量：927] - [当前时间：16:34:46]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 6.Filter
# [剩余数量：926] - [当前时间：16:34:46]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 4.Clutch Plate Pack
# [剩余数量：925] - [当前时间：16:34:47]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 5.Shock / Strut
# [剩余数量：924] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 7.Fluid Pan
# [剩余数量：923] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 10.Fluid Pump Seal
# [剩余数量：922] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 11.Input Shaft Seal
# [剩余数量：921] - [当前时间：16:34:50]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 12.Manual Shaft Seal
# [剩余数量：920] - [当前时间：16:34:50]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 13.O-Rings & Seals
# [剩余数量：919] - [当前时间：16:34:51]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 4.Control Arm Bushing
# [剩余数量：918] - [当前时间：16:34:51]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 15.Piston Kit
# [剩余数量：917] - [当前时间：16:34:52]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 16.Rebuild Kit
# [剩余数量：916] - [当前时间：16:34:52]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 18.Shift Solenoid
# [剩余数量：915] - [当前时间：16:34:53]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 14.Output Shaft Seal
# [剩余数量：914] - [当前时间：16:34:55]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 17.Shift Improvement Kit
# [剩余数量：913] - [当前时间：16:34:56]
#
# [状态：ok，尝试次数：5] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 17.Suspension > 3.Control Arm
# [剩余数量：912] - [当前时间：16:34:58]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 22.Transmission Fluid
# [剩余数量：911] - [当前时间：16:34:58]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 13.Heat & Air Conditioning > 10.Blower Motor
# [剩余数量：910] - [当前时间：16:34:58]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 21.Torque Converter Housing Seal
# [剩余数量：909] - [当前时间：16:34:59]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 20.Torque Converter
# [剩余数量：908] - [当前时间：16:34:59]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 24.Valve Body
# [剩余数量：907] - [当前时间：16:35:00]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 9.Fluid Pan Gasket
# [剩余数量：906] - [当前时间：16:35:00]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 5.Extension Housing Seal
# [剩余数量：905] - [当前时间：16:35:01]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 23.Transmission Mount
# [剩余数量：904] - [当前时间：16:35:01]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 2.Lug Nut & Lock Kit
# [剩余数量：903] - [当前时间：16:35:01]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 8.Fluid Pan Bolt
# [剩余数量：902] - [当前时间：16:35:01]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 1.Lug Nut
# [剩余数量：901] - [当前时间：16:35:02]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 7.Wheel
# [剩余数量：900] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 1.Headlamp Washer Pump
# [剩余数量：899] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 18.Transmission-Automatic > 19.Sun Gear Bushing
# [剩余数量：898] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 5.Windshield Washer Nozzle Cover
# [剩余数量：897] - [当前时间：16:35:04]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 3.Windshield Washer Fluid Level Sensor
# [剩余数量：896] - [当前时间：16:35:05]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 4.Windshield Washer Fluid Level Sensor Grommet
# [剩余数量：895] - [当前时间：16:35:06]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 4.Lug Nut Lock Set
# [剩余数量：894] - [当前时间：16:35:08]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 6.Windshield Washer Pump
# [剩余数量：893] - [当前时间：16:35:08]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 7.Wiper Blade
# [剩余数量：892] - [当前时间：16:35:09]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 8.Wiper Linkage / Transmission
# [剩余数量：891] - [当前时间：16:35:09]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 1.Belt Drive > 2.Idler Pulley
# [剩余数量：890] - [当前时间：16:35:10]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 20.Wiper & Washer > 2.Windshield Washer Fluid Heater
# [剩余数量：889] - [当前时间：16:35:11]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 2.Bumper Cover Support
# [剩余数量：888] - [当前时间：16:35:11]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 6.Tire Pressure Monitoring System (TPMS) Stem / Service Kit
# [剩余数量：887] - [当前时间：16:35:12]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 4.Grille
# [剩余数量：886] - [当前时间：16:35:12]
#
# [状态：error，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 3.Bumper Insert
# [剩余数量：885] - [当前时间：16:35:12]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 5.Tire Pressure Monitoring System (TPMS) Sensor
# [剩余数量：884] - [当前时间：16:35:13]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 5.Headlamp Assembly
# [剩余数量：883] - [当前时间：16:35:13]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 1.Belt Drive > 1.Belt
# [剩余数量：882] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 9.Lift Support
# [剩余数量：881] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 10.Outside Mirror Glass
# [剩余数量：880] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 8.Inner Fender Splash Shield
# [剩余数量：879] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 6.Headlamp Level Sensor
# [剩余数量：878] - [当前时间：16:35:16]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 7.Headlamp Washer Nozzle
# [剩余数量：877] - [当前时间：16:35:16]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 2.Brake Bleeder Kit
# [剩余数量：876] - [当前时间：16:35:18]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 8.Wheel Washer
# [剩余数量：875] - [当前时间：16:35:18]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 13.Trailer Hitch Ball & Mount Kit
# [剩余数量：874] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 14.Valance Panel
# [剩余数量：873] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 12.Tow Hook Cover
# [剩余数量：872] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 11.Park Assist (PAS) Camera
# [剩余数量：871] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2014 > 19.Wheel > 3.Lug Nut Installation Tool / Key
# [剩余数量：870] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 3.Brake Bleeder Screw
# [剩余数量：869] - [当前时间：16:35:20]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 2.Body & Lamp Assembly > 1.Bumper Cover
# [剩余数量：868] - [当前时间：16:35:20]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 5.Brake Hose
# [剩余数量：867] - [当前时间：16:35:21]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 1.ABS Wheel Speed Sensor
# [剩余数量：866] - [当前时间：16:35:21]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 11.Caliper Slide Pin
# [剩余数量：865] - [当前时间：16:35:21]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 9.Caliper Piston
# [剩余数量：864] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 6.Brake Pad
# [剩余数量：863] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 7.Brake Pad Wear Sensor
# [剩余数量：862] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 8.Caliper
# [剩余数量：861] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 12.Caliper Slide Pin Boot / Bushing
# [剩余数量：860] - [当前时间：16:35:23]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 13.Disc Brake Hardware Kit
# [剩余数量：859] - [当前时间：16:35:23]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 18.Vacuum Pump Gasket
# [剩余数量：858] - [当前时间：16:35:24]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 17.Vacuum Pump
# [剩余数量：857] - [当前时间：16:35:24]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 15.Rotor
# [剩余数量：856] - [当前时间：16:35:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 19.Wheel Bearing
# [剩余数量：855] - [当前时间：16:35:25]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 10.Caliper Repair Kit
# [剩余数量：854] - [当前时间：16:35:27]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 20.Wheel Bearing & Hub
# [剩余数量：853] - [当前时间：16:35:28]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 14.Power Brake Booster
# [剩余数量：852] - [当前时间：16:35:28]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 2.Coolant Hose / Pipe
# [剩余数量：851] - [当前时间：16:35:28]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 3.Coolant Reservoir
# [剩余数量：850] - [当前时间：16:35:29]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 6.Radiator
# [剩余数量：849] - [当前时间：16:35:30]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 4.Coolant Reservoir Cap
# [剩余数量：848] - [当前时间：16:35:30]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 5.Cooling System Tester Adapter
# [剩余数量：847] - [当前时间：16:35:30]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 7.Radiator Fan Assembly
# [剩余数量：846] - [当前时间：16:35:31]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 1.Coolant / Antifreeze
# [剩余数量：845] - [当前时间：16:35:32]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 8.Temperature Sender / Sensor
# [剩余数量：844] - [当前时间：16:35:33]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 11.Thermostat Housing / Water Outlet
# [剩余数量：843] - [当前时间：16:35:33]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 9.Thermostat
# [剩余数量：842] - [当前时间：16:35:34]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 16.Rotor & Brake Pad Kit
# [剩余数量：841] - [当前时间：16:35:34]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 4.Brake Fluid
# [剩余数量：840] - [当前时间：16:35:34]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 21.Wheel Bearing Snap Ring
# [剩余数量：839] - [当前时间：16:35:34]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 10.Thermostat / Thermostat Housing / Water Outlet Seal
# [剩余数量：838] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 12.Water Pump
# [剩余数量：837] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 5.Drivetrain > 1.Axle Shaft Bearing
# [剩余数量：836] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 3.Brake & Wheel Hub > 22.Wheel Hub
# [剩余数量：835] - [当前时间：16:35:36]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 1.Alternator / Generator
# [剩余数量：834] - [当前时间：16:35:36]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 4.Cooling System > 13.Water Pump Seal / O-Ring
# [剩余数量：833] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 5.Drivetrain > 4.Differential Pinion Bearing / Race
# [剩余数量：832] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 5.Drivetrain > 5.Gear Oil
# [剩余数量：831] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 5.HID Lighting Ballast
# [剩余数量：830] - [当前时间：16:35:38]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 5.Drivetrain > 2.CV Axle
# [剩余数量：829] - [当前时间：16:35:38]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 1.Back Up / Reverse Lamp Bulb
# [剩余数量：828] - [当前时间：16:35:39]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 7.Parking Aid Sensor
# [剩余数量：827] - [当前时间：16:35:40]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 4.Headlamp Bulb
# [剩余数量：826] - [当前时间：16:35:43]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 8.Starter Motor
# [剩余数量：825] - [当前时间：16:35:43]
#
# [状态：ok，尝试次数：6] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 5.Drivetrain > 3.Differential Carrier Bearing / Race
# [剩余数量：824] - [当前时间：16:35:45]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 4.Fuse
# [剩余数量：823] - [当前时间：16:35:47]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 6.License Plate Lamp Bulb
# [剩余数量：822] - [当前时间：16:35:47]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 2.Battery
# [剩余数量：821] - [当前时间：16:35:47]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 7.Map / Reading Light Bulb
# [剩余数量：820] - [当前时间：16:35:47]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 10.Step / Courtesy Light Bulb
# [剩余数量：819] - [当前时间：16:35:49]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 8.Parking Lamp Bulb
# [剩余数量：818] - [当前时间：16:35:49]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 11.Tail Lamp Bulb
# [剩余数量：817] - [当前时间：16:35:49]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 9.Side Marker Light Bulb
# [剩余数量：816] - [当前时间：16:35:49]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 3.Glove Box Light Bulb
# [剩余数量：815] - [当前时间：16:35:50]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 1.A/C Refrigerant Pressure Sensor Connector
# [剩余数量：814] - [当前时间：16:35:51]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 2.ABS Wheel Speed Sensor Connector
# [剩余数量：813] - [当前时间：16:35:51]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 2.Dome Light Bulb
# [剩余数量：812] - [当前时间：16:35:54]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 13.Turn Signal Lamp Bulb
# [剩余数量：811] - [当前时间：16:35:55]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 12.Trunk or Cargo Area Light Bulb
# [剩余数量：810] - [当前时间：16:35:56]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 7.Camshaft Position Sensor Connector
# [剩余数量：809] - [当前时间：16:35:56]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 3.Accelerator Pedal Position Sensor Connector
# [剩余数量：808] - [当前时间：16:35:57]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 9.Headlamp Dimmer Switch Connector
# [剩余数量：807] - [当前时间：16:35:57]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 4.Air Intake / Charge Temperature Sensor Connector
# [剩余数量：806] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 5.Blower Motor Connector
# [剩余数量：805] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 6.Brake Light Switch Connector
# [剩余数量：804] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 3.Battery Cable
# [剩余数量：803] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 11.Knock / Detonation Sensor Connector
# [剩余数量：802] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 12.Oil Pressure Sender / Switch Connector
# [剩余数量：801] - [当前时间：16:36:00]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 8.Crankshaft Position Sensor Connector
# [剩余数量：800] - [当前时间：16:36:00]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 13.Temperature Sender / Sensor Connector
# [剩余数量：799] - [当前时间：16:36:01]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 14.Turn Signal Switch Connector
# [剩余数量：798] - [当前时间：16:36:01]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 2.Dimmer Switch
# [剩余数量：797] - [当前时间：16:36:02]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 10.Headlamp Switch Connector
# [剩余数量：796] - [当前时间：16:36:02]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 8.Electrical-Connector > 15.Windshield Washer Fluid Level Sensor Connector
# [剩余数量：795] - [当前时间：16:36:02]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 1.Brake Light Switch
# [剩余数量：794] - [当前时间：16:36:03]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 5.Ignition Starter Switch
# [剩余数量：793] - [当前时间：16:36:03]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 3.Fuel Pump Cutoff Switch
# [剩余数量：792] - [当前时间：16:36:03]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 9.Refrigerant Pressure Switch
# [剩余数量：791] - [当前时间：16:36:04]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 4.Headlamp Switch
# [剩余数量：790] - [当前时间：16:36:04]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 8.Power Window Switch
# [剩余数量：789] - [当前时间：16:36:04]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 11.Wiper / Washer Switch
# [剩余数量：788] - [当前时间：16:36:05]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 6.Multi-Function Switch
# [剩余数量：787] - [当前时间：16:36:06]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 2.Conversion / Lower Gasket Set
# [剩余数量：786] - [当前时间：16:36:06]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 4.Cylinder Head Bolt
# [剩余数量：785] - [当前时间：16:36:06]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 7.Electrical-Bulb & Socket > 5.Headlamp Socket
# [剩余数量：784] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 6.Electrical > 6.Horn
# [剩余数量：783] - [当前时间：16:36:08]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 1.Camshaft Follower
# [剩余数量：782] - [当前时间：16:36:08]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 6.Cylinder Head Gasket Set
# [剩余数量：781] - [当前时间：16:36:08]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 8.Engine Kit Gasket Set
# [剩余数量：780] - [当前时间：16:36:08]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 7.Oil Pressure Sender / Switch
# [剩余数量：779] - [当前时间：16:36:09]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 7.Engine Block Heater
# [剩余数量：778] - [当前时间：16:36:09]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 9.Electrical-Switch & Relay > 10.Turn Signal Switch
# [剩余数量：777] - [当前时间：16:36:09]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 5.Cylinder Head Gasket
# [剩余数量：776] - [当前时间：16:36:09]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 9.Intake Manifold Gasket
# [剩余数量：775] - [当前时间：16:36:09]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 10.Intake Plenum Gasket
# [剩余数量：774] - [当前时间：16:36:10]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 16.Oil Filter Adapter Gasket / O-Ring
# [剩余数量：773] - [当前时间：16:36:11]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 13.Oil Drain Plug
# [剩余数量：772] - [当前时间：16:36:11]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 14.Oil Filler Cap
# [剩余数量：771] - [当前时间：16:36:11]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 17.Oil Level Sensor
# [剩余数量：770] - [当前时间：16:36:12]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 18.Oil Pan Gasket
# [剩余数量：769] - [当前时间：16:36:13]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 21.Timing Chain
# [剩余数量：768] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 19.Oil Pump Gasket
# [剩余数量：767] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 11.Oil
# [剩余数量：766] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 15.Oil Filter
# [剩余数量：765] - [当前时间：16:36:15]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 23.Turbocharger Mounting Kit
# [剩余数量：764] - [当前时间：16:36:15]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 22.Timing Chain Tensioner
# [剩余数量：763] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 20.Piston Ring
# [剩余数量：762] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 12.Oil Cooler Line
# [剩余数量：761] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 26.Variable Valve Timing (VVT) Solenoid / Actuator
# [剩余数量：760] - [当前时间：16:36:17]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 24.Valve Cover Gasket
# [剩余数量：759] - [当前时间：16:36:17]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 2.Catalytic Converter
# [剩余数量：758] - [当前时间：16:36:17]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 5.Manifold Pressure (MAP) Sensor
# [剩余数量：757] - [当前时间：16:36:18]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 4.Knock / Detonation Sensor
# [剩余数量：756] - [当前时间：16:36:18]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 8.Vapor Canister
# [剩余数量：755] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 6.Mass Air Flow (MAF) Sensor
# [剩余数量：754] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 25.Valve Stem Seal
# [剩余数量：753] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 4.Fuel Injection Pressure Sensor
# [剩余数量：752] - [当前时间：16:36:20]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 2.Air Intake / Charge Temperature Sensor
# [剩余数量：751] - [当前时间：16:36:20]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 5.Fuel Injector
# [剩余数量：750] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 3.Fuel Filter
# [剩余数量：749] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 9.Vapor Canister Purge Valve / Solenoid
# [剩余数量：748] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 9.Fuel Pump Gasket / Seal
# [剩余数量：747] - [当前时间：16:36:23]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 8.Fuel Pump & Housing Assembly
# [剩余数量：746] - [当前时间：16:36:23]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 7.Fuel Pump
# [剩余数量：745] - [当前时间：16:36:24]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 7.Oxygen (O2) Sensor
# [剩余数量：744] - [当前时间：16:36:24]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 6.Fuel Injector Seal / O-Ring
# [剩余数量：743] - [当前时间：16:36:24]
#
# [状态：ok，尝试次数：4] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 3.Exhaust Manifold Gasket
# [剩余数量：742] - [当前时间：16:36:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 10.Fuel Tank Cap
# [剩余数量：741] - [当前时间：16:36:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 11.Fuel Tank Cap Tester Adapter
# [剩余数量：740] - [当前时间：16:36:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 12.Fuel Tank Pressure Sensor
# [剩余数量：739] - [当前时间：16:36:25]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 12.Fuel & Air > 1.Air Filter
# [剩余数量：738] - [当前时间：16:36:26]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 2.A/C Compressor & Component Kit
# [剩余数量：737] - [当前时间：16:36:26]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 1.A/C Compressor
# [剩余数量：736] - [当前时间：16:36:26]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 4.A/C Evaporator Core
# [剩余数量：735] - [当前时间：16:36:27]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 7.A/C Refrigerant Oil
# [剩余数量：734] - [当前时间：16:36:28]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 8.A/C System O-Rings / Seals
# [剩余数量：733] - [当前时间：16:36:28]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 6.A/C Receiver Drier Desiccant Element
# [剩余数量：732] - [当前时间：16:36:29]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 11.Exhaust & Emission > 1.Air / Smog Pump
# [剩余数量：731] - [当前时间：16:36:29]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 5.A/C Expansion Valve
# [剩余数量：730] - [当前时间：16:36:30]
#
# [状态：ok，尝试次数：5] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 10.Engine > 3.Crankshaft Seal
# [剩余数量：729] - [当前时间：16:36:30]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 11.Blower Motor
# [剩余数量：728] - [当前时间：16:36:30]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 13.Cabin Air Filter
# [剩余数量：727] - [当前时间：16:36:31]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 12.Blower Motor Control Module / Resistor
# [剩余数量：726] - [当前时间：16:36:32]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 14.Cabin Air Temperature Sensor
# [剩余数量：725] - [当前时间：16:36:32]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 15.Heater Hose
# [剩余数量：724] - [当前时间：16:36:32]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 14.Ignition > 2.Crankshaft Position Sensor
# [剩余数量：723] - [当前时间：16:36:33]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 14.Ignition > 1.Camshaft Position Sensor
# [剩余数量：722] - [当前时间：16:36:34]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 14.Ignition > 4.Spark Plug
# [剩余数量：721] - [当前时间：16:36:34]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 16.Steering > 2.Power Steering Pump
# [剩余数量：720] - [当前时间：16:36:35]
#
# [状态：ok，尝试次数：3] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 14.Ignition > 3.Ignition Coil
# [剩余数量：719] - [当前时间：16:36:36]
#
# [状态：ok，尝试次数：5] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 10.Ambient Air Temperature Sensor
# [剩余数量：718] - [当前时间：16:36:37]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 16.Steering > 5.Rack and Pinion Bellow
# [剩余数量：717] - [当前时间：16:36:38]
#
# [状态：ok，尝试次数：1] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 16.Steering > 1.Power Steering Fluid
# [剩余数量：716] - [当前时间：16:36:38]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 13.Heat & Air Conditioning > 9.A/C System Service Valve / Core / Cap
# [剩余数量：715] - [当前时间：16:36:38]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 16.Steering > 4.Rack and Pinion
# [剩余数量：714] - [当前时间：16:36:38]
#
# [状态：ok，尝试次数：2] - 8.29% - make_124.JAGUAR-serial_3 > 25.XF > 8.5.0L V8 Supercharged > 2013 > 15.Interior > 1.Accelerator Pedal Position Sensor
# [剩余数量：713] - [当前时间：16:36:38]
#
# ...
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 19.Wheel > 7.Valve Stem Cap
# [剩余数量：13445] - [当前时间：16:46:52]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 1.Belt Drive > 1.Belt
# [剩余数量：13444] - [当前时间：16:46:53]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 17.Suspension > 6.Shock / Strut Bearing
# [剩余数量：13443] - [当前时间：16:46:53]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 19.Wheel > 6.Tire Pressure Monitoring System (TPMS) Stem / Service Kit
# [剩余数量：13442] - [当前时间：16:46:54]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 19.Wheel > 4.Lug Nut Lock Set
# [剩余数量：13441] - [当前时间：16:46:54]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 20.Wiper & Washer > 3.Windshield Washer Pump
# [剩余数量：13440] - [当前时间：16:46:54]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 20.Wiper & Washer > 4.Wiper Blade
# [剩余数量：13439] - [当前时间：16:46:55]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 20.Wiper & Washer > 1.Headlamp Washer Pump
# [剩余数量：13438] - [当前时间：16:46:55]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 20.Wiper & Washer > 2.Windshield Washer Fluid Level Sensor
# [剩余数量：13437] - [当前时间：16:46:55]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 4.Outside Mirror Glass
# [剩余数量：13436] - [当前时间：16:46:56]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 1.Belt Drive > 2.Idler Pulley
# [剩余数量：13435] - [当前时间：16:46:56]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 3.Lift Support
# [剩余数量：13434] - [当前时间：16:46:57]
#
# [状态：error，尝试次数：11] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 1.Air Dam
# [剩余数量：13433] - [当前时间：16:46:58]
#
# [状态：ok，尝试次数：15] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 5.Park Assist (PAS) Camera
# [剩余数量：13432] - [当前时间：16:46:59]
#
# [状态：ok，尝试次数：47] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2019 > 19.Wheel > 8.Wheel
# [剩余数量：13431] - [当前时间：16:47:00]
#
# [状态：ok，尝试次数：13] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 4.Brake Fluid
# [剩余数量：13430] - [当前时间：16:47:00]
#
# [状态：ok，尝试次数：21] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 3.Brake Bleeder Screw
# [剩余数量：13429] - [当前时间：16:47:00]
#
# [状态：ok，尝试次数：34] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 1.ABS Wheel Speed Sensor
# [剩余数量：13428] - [当前时间：16:47:01]
#
# [状态：ok，尝试次数：43] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 2.Front Panel Molding / Radiator Cover
# [剩余数量：13427] - [当前时间：16:47:03]
#
# [状态：ok，尝试次数：13] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 9.Caliper Repair Kit
# [剩余数量：13426] - [当前时间：16:47:03]
#
# [状态：ok，尝试次数：27] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 5.Brake Hose
# [剩余数量：13425] - [当前时间：16:47:03]
#
# [状态：ok，尝试次数：38] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 2.Brake Bleeder Kit
# [剩余数量：13424] - [当前时间：16:47:04]
#
# [状态：ok，尝试次数：6] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 7.Brake Pad Wear Sensor
# [剩余数量：13423] - [当前时间：16:47:05]
#
# [状态：ok，尝试次数：67] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 6.Tail Lamp Assembly
# [剩余数量：13422] - [当前时间：16:47:05]
#
# [状态：ok，尝试次数：18] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 8.Caliper
# [剩余数量：13421] - [当前时间：16:47:05]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 13.Vacuum Pump
# [剩余数量：13420] - [当前时间：16:47:05]
#
# [状态：ok，尝试次数：7] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 6.Brake Pad
# [剩余数量：13419] - [当前时间：16:47:06]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 14.Vacuum Pump Gasket
# [剩余数量：13418] - [当前时间：16:47:06]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 12.Rotor & Brake Pad Kit
# [剩余数量：13417] - [当前时间：16:47:06]
#
# [状态：ok，尝试次数：6] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 16.Wheel Bearing & Hub
# [剩余数量：13416] - [当前时间：16:47:06]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 15.Wheel Bearing
# [剩余数量：13415] - [当前时间：16:47:07]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 2.Coolant Hose / Pipe
# [剩余数量：13414] - [当前时间：16:47:08]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 1.Coolant / Antifreeze
# [剩余数量：13413] - [当前时间：16:47:08]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 5.Coolant Reservoir Cap
# [剩余数量：13412] - [当前时间：16:47:08]
#
# [状态：ok，尝试次数：20] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 2.Body & Lamp Assembly > 7.Tow Hook Cover
# [剩余数量：13411] - [当前时间：16:47:08]
#
# [状态：ok，尝试次数：5] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 3.Coolant Hose Connector / Flange
# [剩余数量：13410] - [当前时间：16:47:09]
#
# [状态：ok，尝试次数：7] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 17.Wheel Hub
# [剩余数量：13409] - [当前时间：16:47:09]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 9.Thermostat
# [剩余数量：13408] - [当前时间：16:47:09]
#
# [状态：ok，尝试次数：10] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 4.Coolant Reservoir
# [剩余数量：13407] - [当前时间：16:47:10]
#
# [状态：ok，尝试次数：10] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 10.Thermostat Housing / Water Outlet
# [剩余数量：13406] - [当前时间：16:47:11]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 1.CV Axle
# [剩余数量：13405] - [当前时间：16:47:12]
#
# [状态：ok，尝试次数：15] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 11.Water Pump
# [剩余数量：13404] - [当前时间：16:47:12]
#
# [状态：ok，尝试次数：5] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 7.Radiator Fan Assembly
# [剩余数量：13403] - [当前时间：16:47:12]
#
# [状态：ok，尝试次数：7] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 10.Disc Brake Hardware Kit
# [剩余数量：13402] - [当前时间：16:47:12]
#
# [状态：ok，尝试次数：8] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 2.Differential Carrier Bearing / Race
# [剩余数量：13401] - [当前时间：16:47:13]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 3.Differential Pinion Bearing / Race
# [剩余数量：13400] - [当前时间：16:47:13]
#
# [状态：ok，尝试次数：12] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 6.Radiator
# [剩余数量：13399] - [当前时间：16:47:14]
#
# [状态：ok，尝试次数：6] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 12.Water Pump Gasket
# [剩余数量：13398] - [当前时间：16:47:14]
#
# [状态：ok，尝试次数：6] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 6.Transfer Case Fluid
# [剩余数量：13397] - [当前时间：16:47:15]
#
# [状态：ok，尝试次数：16] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 1.Alternator / Generator
# [剩余数量：13396] - [当前时间：16:47:16]
#
# [状态：ok，尝试次数：19] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 5.Gear Oil
# [剩余数量：13395] - [当前时间：16:47:16]
#
# [状态：ok，尝试次数：1] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 5.Parking Aid Sensor
# [剩余数量：13394] - [当前时间：16:47:16]
#
# [状态：ok，尝试次数：11] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 3.Horn
# [剩余数量：13393] - [当前时间：16:47:16]
#
# [状态：error，尝试次数：31] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 2.Battery
# [剩余数量：13392] - [当前时间：16:47:17]
#
# [状态：ok，尝试次数：25] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 4.Cooling System > 8.Temperature Sender / Sensor
# [剩余数量：13391] - [当前时间：16:47:17]
#
# [状态：ok，尝试次数：10] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 4.Lighting Control Module (LCM)
# [剩余数量：13390] - [当前时间：16:47:18]
#
# [状态：ok，尝试次数：19] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 7.Electrical-Bulb & Socket > 2.Door Panel Light Bulb
# [剩余数量：13389] - [当前时间：16:47:19]
#
# [状态：ok，尝试次数：14] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 7.Electrical-Bulb & Socket > 1.Door Lock Switch Light Bulb
# [剩余数量：13388] - [当前时间：16:47:19]
#
# [状态：ok，尝试次数：19] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 6.Electrical > 6.Starter Motor
# [剩余数量：13387] - [当前时间：16:47:19]
#
# [状态：ok，尝试次数：13] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 1.ABS Wheel Speed Sensor Connector
# [剩余数量：13386] - [当前时间：16:47:20]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 7.Electrical-Bulb & Socket > 3.License Plate Lamp Bulb
# [剩余数量：13385] - [当前时间：16:47:20]
#
# [状态：ok，尝试次数：7] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 2.Accelerator Pedal Position Sensor Connector
# [剩余数量：13384] - [当前时间：16:47:21]
#
# [状态：ok，尝试次数：18] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 7.Electrical-Bulb & Socket > 4.Step / Courtesy Light Bulb
# [剩余数量：13383] - [当前时间：16:47:21]
#
# [状态：ok，尝试次数：23] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 5.Drivetrain > 4.Drive Shaft
# [剩余数量：13382] - [当前时间：16:47:21]
#
# [状态：ok，尝试次数：8] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 3.Air Intake / Charge Temperature Sensor Connector
# [剩余数量：13381] - [当前时间：16:47:22]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 10.Mass Air Flow (MAF) Sensor Connector
# [剩余数量：13380] - [当前时间：16:47:23]
#
# [状态：ok，尝试次数：12] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 7.Headlamp Dimmer Switch Connector
# [剩余数量：13379] - [当前时间：16:47:24]
#
# [状态：ok，尝试次数：21] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 5.Brake Light Switch Connector
# [剩余数量：13378] - [当前时间：16:47:25]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 2.Brake Light Switch
# [剩余数量：13377] - [当前时间：16:47:26]
#
# [状态：ok，尝试次数：9] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 6.Crankshaft Position Sensor Connector
# [剩余数量：13376] - [当前时间：16:47:26]
#
# [状态：ok，尝试次数：29] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 12.Turn Signal Switch Connector
# [剩余数量：13375] - [当前时间：16:47:27]
#
# [状态：ok，尝试次数：36] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 4.Blower Motor Connector
# [剩余数量：13374] - [当前时间：16:47:28]
#
# [状态：ok，尝试次数：22] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 11.Temperature Sender / Sensor Connector
# [剩余数量：13373] - [当前时间：16:47:28]
#
# [状态：ok，尝试次数：4] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 5.Ignition Starter Switch
# [剩余数量：13372] - [当前时间：16:47:28]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 4.Headlamp Switch
# [剩余数量：13371] - [当前时间：16:47:28]
#
# [状态：ok，尝试次数：29] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 1.Accessory Power Relay
# [剩余数量：13370] - [当前时间：16:47:30]
#
# [状态：ok，尝试次数：8] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 3.Brake & Wheel Hub > 11.Rotor
# [剩余数量：13369] - [当前时间：16:47:30]
#
# [状态：ok，尝试次数：18] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 3.Dimmer Switch
# [剩余数量：13368] - [当前时间：16:47:30]
#
# [状态：ok，尝试次数：9] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 9.Wiring Relay
# [剩余数量：13367] - [当前时间：16:47:30]
#
# [状态：ok，尝试次数：17] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 7.Power Window Switch
# [剩余数量：13366] - [当前时间：16:47:31]
#
# [状态：ok，尝试次数：58] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 8.Electrical-Connector > 8.Headlamp Switch Connector
# [剩余数量：13365] - [当前时间：16:47:31]
#
# [状态：ok，尝试次数：9] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 6.Oil Pressure Sender / Switch
# [剩余数量：13364] - [当前时间：16:47:31]
#
# [状态：ok，尝试次数：23] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 9.Electrical-Switch & Relay > 8.Turn Signal Switch
# [剩余数量：13363] - [当前时间：16:47:31]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 8.Cylinder Head Gasket Set
# [剩余数量：13362] - [当前时间：16:47:33]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 6.Cylinder Head Bolt
# [剩余数量：13361] - [当前时间：16:47:33]
#
# [状态：ok，尝试次数：17] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 3.Conversion / Lower Gasket Set
# [剩余数量：13360] - [当前时间：16:47:34]
#
# [状态：ok，尝试次数：20] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 7.Cylinder Head Gasket
# [剩余数量：13359] - [当前时间：16:47:34]
#
# [状态：ok，尝试次数：7] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 9.Engine Kit Gasket Set
# [剩余数量：13358] - [当前时间：16:47:35]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 10.Intake Manifold Gasket
# [剩余数量：13357] - [当前时间：16:47:36]
#
# [状态：ok，尝试次数：16] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 4.Crankcase Cover Gasket Set
# [剩余数量：13356] - [当前时间：16:47:37]
#
# [状态：ok，尝试次数：2] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 14.Oil Cooler
# [剩余数量：13355] - [当前时间：16:47:38]
#
# [状态：ok，尝试次数：15] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 1.Camshaft Adjuster Magnet
# [剩余数量：13354] - [当前时间：16:47:38]
#
# [状态：ok，尝试次数：34] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 2.Camshaft Follower
# [剩余数量：13353] - [当前时间：16:47:38]
#
# [状态：ok，尝试次数：3] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 11.Intake Plenum Gasket
# [剩余数量：13352] - [当前时间：16:47:38]
#
# [状态：ok，尝试次数：9] - 8.39% - make_124.JAGUAR-serial_4 > 26.XJ > 2.3.0L V6 Supercharged > 2018 > 10.Engine > 12.Motor Mount
# [剩余数量：13351] - [当前时间：16:47:39]
