# %%
import os

list_file = sorted(list(os.walk('./7.oem_2'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['part_type_1.4WD Actuator.xlsx',
#  'part_type_10.Brake Caliper-serial_1.xlsx',
#  'part_type_10.Brake Caliper-serial_10.xlsx',
#  'part_type_10.Brake Caliper-serial_11.xlsx',
#  'part_type_10.Brake Caliper-serial_12.xlsx',
#  'part_type_10.Brake Caliper-serial_13.xlsx',
#  'part_type_10.Brake Caliper-serial_14.xlsx',
#  'part_type_10.Brake Caliper-serial_15.xlsx',
#  'part_type_10.Brake Caliper-serial_16.xlsx',
#  'part_type_10.Brake Caliper-serial_17.xlsx',
#  'part_type_10.Brake Caliper-serial_18.xlsx',
#  'part_type_10.Brake Caliper-serial_19.xlsx',
#  'part_type_10.Brake Caliper-serial_2.xlsx',
#  'part_type_10.Brake Caliper-serial_20.xlsx',
#  'part_type_10.Brake Caliper-serial_21.xlsx',
#  'part_type_10.Brake Caliper-serial_22.xlsx',
#  'part_type_10.Brake Caliper-serial_23.xlsx',
#  'part_type_10.Brake Caliper-serial_24.xlsx',
#  'part_type_10.Brake Caliper-serial_25.xlsx',
#  'part_type_10.Brake Caliper-serial_26.xlsx',
#  'part_type_10.Brake Caliper-serial_27.xlsx',
#  'part_type_10.Brake Caliper-serial_28.xlsx',
#  'part_type_10.Brake Caliper-serial_29.xlsx',
#  'part_type_10.Brake Caliper-serial_3.xlsx',
#  'part_type_10.Brake Caliper-serial_30.xlsx',
#  'part_type_10.Brake Caliper-serial_31.xlsx',
#  'part_type_10.Brake Caliper-serial_4.xlsx',
#  'part_type_10.Brake Caliper-serial_5.xlsx',
#  'part_type_10.Brake Caliper-serial_6.xlsx',
#  'part_type_10.Brake Caliper-serial_7.xlsx',
#  'part_type_10.Brake Caliper-serial_8.xlsx',
#  'part_type_10.Brake Caliper-serial_9.xlsx',
#  'part_type_100.Windshield Wiper Motor-serial_1.xlsx',
#  'part_type_100.Windshield Wiper Motor-serial_2.xlsx',
#  'part_type_100.Windshield Wiper Motor-serial_3.xlsx',
#  'part_type_100.Windshield Wiper Motor-serial_4.xlsx',
#  'part_type_100.Windshield Wiper Motor-serial_5.xlsx',
#  'part_type_101.Windshield Wiper Motor Crank Arm Kit.xlsx',
#  'part_type_102.Wiper Motor Pulse Board.xlsx',
#  'part_type_11.Brake Dust Shield.xlsx',
#  'part_type_12.CV Axle Assembly-serial_1.xlsx',
#  'part_type_12.CV Axle Assembly-serial_10.xlsx',
#  'part_type_12.CV Axle Assembly-serial_11.xlsx',
#  'part_type_12.CV Axle Assembly-serial_12.xlsx',
#  'part_type_12.CV Axle Assembly-serial_2.xlsx',
#  'part_type_12.CV Axle Assembly-serial_3.xlsx',
#  'part_type_12.CV Axle Assembly-serial_4.xlsx',
#  'part_type_12.CV Axle Assembly-serial_5.xlsx',
#  'part_type_12.CV Axle Assembly-serial_6.xlsx',
#  'part_type_12.CV Axle Assembly-serial_7.xlsx',
#  'part_type_12.CV Axle Assembly-serial_8.xlsx',
#  'part_type_12.CV Axle Assembly-serial_9.xlsx',
#  'part_type_13.CV Intermediate Shaft.xlsx',
#  'part_type_14.Caliper Bracket-serial_1.xlsx',
#  'part_type_14.Caliper Bracket-serial_2.xlsx',
#  'part_type_15.Camshaft Synchronizer Alignment Tool Kit.xlsx',
#  'part_type_16.Climate Control Module.xlsx',
#  'part_type_17.Diesel Exhaust Fluid (DEF) Heater.xlsx',
#  'part_type_18.Diesel Exhaust Fluid (DEF) Pump.xlsx',
#  'part_type_19.Diesel Fuel Injector Driver Module.xlsx',
#  'part_type_2.ABS Control Module.xlsx',
#  'part_type_20.Diesel Fuel Injector Driver Module Resistor.xlsx',
#  'part_type_21.Diesel Glow Plug Controller.xlsx',
#  'part_type_22.Diesel Particulate Filter.xlsx',
#  'part_type_23.Diesel Particulate Filter (DPF) Gasket.xlsx',
#  'part_type_24.Disc Brake Caliper.xlsx',
#  'part_type_25.Distributor-serial_1.xlsx',
#  'part_type_25.Distributor-serial_2.xlsx',
#  'part_type_25.Distributor-serial_3.xlsx',
#  'part_type_25.Distributor-serial_4.xlsx',
#  'part_type_26.Drive Axle Assembly.xlsx',
#  'part_type_27.Drive Shaft.xlsx',
#  'part_type_28.Driveshaft %2F Prop Shaft-serial_1.xlsx',
#  'part_type_28.Driveshaft %2F Prop Shaft-serial_2.xlsx',
#  'part_type_29.EGR Cooler.xlsx',
#  'part_type_3.ABS Hydraulic Assembly.xlsx',
#  'part_type_30.EGR Cooler Gasket Kit.xlsx',
#  'part_type_31.Electronic Brake Assembly.xlsx',
#  'part_type_32.Electronic Brake Booster Vacuum Pump.xlsx',
#  'part_type_33.Electronic Brake Pedal Simulator.xlsx',
#  'part_type_34.Electronic Brake Pump and Motor.xlsx',
#  'part_type_35.Electronic Power Steering Assist Column (EPS).xlsx',
#  'part_type_36.Engine Auxiliary Water Pump.xlsx',
#  'part_type_37.Engine Camshaft Position Sensor.xlsx',
#  'part_type_38.Engine Camshaft Synchronizer.xlsx',
#  'part_type_39.Engine Control Module-serial_1.xlsx',
#  'part_type_39.Engine Control Module-serial_10.xlsx',
#  'part_type_39.Engine Control Module-serial_11.xlsx',
#  'part_type_39.Engine Control Module-serial_12.xlsx',
#  'part_type_39.Engine Control Module-serial_13.xlsx',
#  'part_type_39.Engine Control Module-serial_14.xlsx',
#  'part_type_39.Engine Control Module-serial_15.xlsx',
#  'part_type_39.Engine Control Module-serial_16.xlsx',
#  'part_type_39.Engine Control Module-serial_17.xlsx',
#  'part_type_39.Engine Control Module-serial_18.xlsx',
#  'part_type_39.Engine Control Module-serial_19.xlsx',
#  'part_type_39.Engine Control Module-serial_2.xlsx',
#  'part_type_39.Engine Control Module-serial_20.xlsx',
#  'part_type_39.Engine Control Module-serial_21.xlsx',
#  'part_type_39.Engine Control Module-serial_22.xlsx',
#  'part_type_39.Engine Control Module-serial_23.xlsx',
#  'part_type_39.Engine Control Module-serial_24.xlsx',
#  'part_type_39.Engine Control Module-serial_25.xlsx',
#  'part_type_39.Engine Control Module-serial_26.xlsx',
#  'part_type_39.Engine Control Module-serial_27.xlsx',
#  'part_type_39.Engine Control Module-serial_28.xlsx',
#  'part_type_39.Engine Control Module-serial_29.xlsx',
#  'part_type_39.Engine Control Module-serial_3.xlsx',
#  'part_type_39.Engine Control Module-serial_30.xlsx',
#  'part_type_39.Engine Control Module-serial_31.xlsx',
#  'part_type_39.Engine Control Module-serial_32.xlsx',
#  'part_type_39.Engine Control Module-serial_33.xlsx',
#  'part_type_39.Engine Control Module-serial_34.xlsx',
#  'part_type_39.Engine Control Module-serial_4.xlsx',
#  'part_type_39.Engine Control Module-serial_5.xlsx',
#  'part_type_39.Engine Control Module-serial_6.xlsx',
#  'part_type_39.Engine Control Module-serial_7.xlsx',
#  'part_type_39.Engine Control Module-serial_8.xlsx',
#  'part_type_39.Engine Control Module-serial_9.xlsx',
#  'part_type_4.ABS Pump and Motor Assembly.xlsx',
#  'part_type_40.Engine Crankshaft Position Sensor.xlsx',
#  'part_type_41.Engine Oil Pump Drive Shaft.xlsx',
#  'part_type_42.Fuel Injection Pump.xlsx',
#  'part_type_43.Fuel Injection Pump Installation Kit.xlsx',
#  'part_type_44.Fuel Injection Throttle Body-serial_1.xlsx',
#  'part_type_44.Fuel Injection Throttle Body-serial_2.xlsx',
#  'part_type_45.Fuel Injector.xlsx',
#  'part_type_46.Fuel Injector Control Module.xlsx',
#  'part_type_47.Fuel Injector Installation Kit.xlsx',
#  'part_type_48.Fuel Pump Driver Module.xlsx',
#  'part_type_49.HVAC Control Module.xlsx',
#  'part_type_5.Accelerator Pedal Sensor.xlsx',
#  'part_type_50.Headlight Motor.xlsx',
#  'part_type_51.High Pressure Oil Rail Repair Kit.xlsx',
#  'part_type_52.High Pressure Oil Rail Tool.xlsx',
#  'part_type_53.Injection Pressure Regulating Valve.xlsx',
#  'part_type_54.Instrument Cluster.xlsx',
#  'part_type_55.Integrated Control Module.xlsx',
#  'part_type_56.Leaf Spring Axle U-Bolt Kit.xlsx',
#  'part_type_57.Lighting Control Module.xlsx',
#  'part_type_58.Mass Air Flow Sensor-serial_1.xlsx',
#  'part_type_58.Mass Air Flow Sensor-serial_2.xlsx',
#  'part_type_59.Nitrogen Oxide (NOx) Sensor.xlsx',
#  'part_type_6.Active Suspension Control Module.xlsx',
#  'part_type_60.Parking Brake Actuator.xlsx',
#  'part_type_61.Power Brake Booster-serial_1.xlsx',
#  'part_type_61.Power Brake Booster-serial_2.xlsx',
#  'part_type_61.Power Brake Booster-serial_3.xlsx',
#  'part_type_61.Power Brake Booster-serial_4.xlsx',
#  'part_type_61.Power Brake Booster-serial_5.xlsx',
#  'part_type_61.Power Brake Booster-serial_6.xlsx',
#  'part_type_62.Power Brake Booster Hydraulic Motor Pump.xlsx',
#  'part_type_63.Power Liftgate Actuator.xlsx',
#  'part_type_64.Power Sliding Door Motor.xlsx',
#  'part_type_65.Power Sliding Window Motor.xlsx',
#  'part_type_66.Power Steering Assist Motor.xlsx',
#  'part_type_67.Power Steering Control Valve.xlsx',
#  'part_type_68.Power Steering Filter.xlsx',
#  'part_type_69.Power Steering Power Cylinder.xlsx',
#  'part_type_7.Air Brake Disc Caliper.xlsx',
#  'part_type_70.Power Steering Pump-serial_1.xlsx',
#  'part_type_70.Power Steering Pump-serial_2.xlsx',
#  'part_type_70.Power Steering Pump-serial_3.xlsx',
#  'part_type_70.Power Steering Pump-serial_4.xlsx',
#  'part_type_70.Power Steering Pump-serial_5.xlsx',
#  'part_type_70.Power Steering Pump-serial_6.xlsx',
#  'part_type_71.Power Steering Pump Pulley.xlsx',
#  'part_type_72.Power Steering Reservoir.xlsx',
#  'part_type_73.Power Supply Module.xlsx',
#  'part_type_74.Power Window Motor-serial_1.xlsx',
#  'part_type_74.Power Window Motor-serial_2.xlsx',
#  'part_type_74.Power Window Motor-serial_3.xlsx',
#  'part_type_74.Power Window Motor-serial_4.xlsx',
#  'part_type_74.Power Window Motor-serial_5.xlsx',
#  'part_type_74.Power Window Motor-serial_6.xlsx',
#  'part_type_74.Power Window Motor-serial_7.xlsx',
#  'part_type_75.Power Window Motor Gear Kit.xlsx',
#  'part_type_76.Power Window Motor and Regulator Assembly-serial_1.xlsx',
#  'part_type_76.Power Window Motor and Regulator Assembly-serial_2.xlsx',
#  'part_type_76.Power Window Motor and Regulator Assembly-serial_3.xlsx',
#  'part_type_77.Powertrain Control Module.xlsx',
#  'part_type_78.Rack and Pinion Assembly-serial_1.xlsx',
#  'part_type_78.Rack and Pinion Assembly-serial_2.xlsx',
#  'part_type_78.Rack and Pinion Assembly-serial_3.xlsx',
#  'part_type_78.Rack and Pinion Assembly-serial_4.xlsx',
#  'part_type_78.Rack and Pinion Assembly-serial_5.xlsx',
#  'part_type_79.Rack and Pinion Bushing Kit.xlsx',
#  'part_type_8.Body Control Computer.xlsx',
#  'part_type_80.Rack and Pinion Hydraulic Transfer Tubing Assembly.xlsx',
#  'part_type_81.Relay Control Module.xlsx',
#  'part_type_82.Smog Air Pump.xlsx',
#  'part_type_83.Steering Column.xlsx',
#  'part_type_84.Steering Column Intermediate Shaft (EPS).xlsx',
#  'part_type_85.Steering Gear.xlsx',
#  'part_type_86.Steering Pitman Arm.xlsx',
#  'part_type_87.Steering Tie Rod End Bushing Kit.xlsx',
#  'part_type_88.Sunroof Motor.xlsx',
#  'part_type_89.Supercharger.xlsx',
#  'part_type_9.Body Control Module.xlsx',
#  'part_type_90.Tailgate Window Motor.xlsx',
#  'part_type_91.Transfer Case Control Module.xlsx',
#  'part_type_92.Transfer Case Motor.xlsx',
#  'part_type_93.Transmission Control Module.xlsx',
#  'part_type_94.Vacuum Pump.xlsx',
#  'part_type_95.Vacuum Pump Pulley.xlsx',
#  'part_type_96.Vehicle Control Module.xlsx',
#  'part_type_97.Window Regulator-serial_1.xlsx',
#  'part_type_97.Window Regulator-serial_2.xlsx',
#  'part_type_97.Window Regulator-serial_3.xlsx',
#  'part_type_98.Windshield Washer Pump.xlsx',
#  'part_type_99.Windshield Wiper Linkage.xlsx']

# %%
file = list_file[1]

file
# Out:
# 'part_type_10.Brake Caliper-serial_1.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./7.oem_2/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['Part No'] = input_['Part No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Part Number'].tolist()
# Out:
# 总数量：300
# ['18-4002',
#  '18-4003',
#  '18-4004',
#  '18-4005',
#  '18-4006',
#  '18-4007',
#  '18-4008',
#  '18-4009',
#  '18-4010',
#  '18-4011',
#  '18-4012',
#  '18-4013',
#  '18-4014',
#  '18-4015',
#  '18-4018',
#  '18-4019',
#  '18-4020',
#  '18-4021',
#  '18-4025',
#  '18-4026',
#  '18-4027',
#  '18-4028',
#  '18-4029',
#  '18-4030',
#  '18-4031',
#  '18-4032',
#  '18-4033',
#  '18-4033S',
#  '18-4034',
#  '18-4034S',
#  '18-4035',
#  '18-4036',
#  '18-4037',
#  '18-4038',
#  '18-4039',
#  '18-4039XB',
#  '18-4040',
#  '18-4040XB',
#  '18-4041',
#  '18-4042',
#  '18-4043',
#  '18-4044',
#  '18-4045',
#  '18-4046',
#  '18-4049',
#  '18-4050',
#  '18-4051',
#  '18-4052',
#  '18-4053',
#  '18-4054',
#  '18-4055',
#  '18-4056',
#  '18-4059',
#  '18-4060',
#  '18-4063',
#  '18-4064',
#  '18-4065',
#  '18-4066',
#  '18-4067',
#  '18-4068',
#  '18-4069',
#  '18-4070',
#  '18-4071',
#  '18-4071XB',
#  '18-4071XR',
#  '18-4071XY',
#  '18-4072',
#  '18-4072XB',
#  '18-4072XR',
#  '18-4072XY',
#  '18-4073',
#  '18-4073S',
#  '18-4074',
#  '18-4074S',
#  '18-4075',
#  '18-4075S',
#  '18-4076',
#  '18-4076S',
#  '18-4079',
#  '18-4080',
#  '18-4081',
#  '18-4082',
#  '18-4083',
#  '18-4084',
#  '18-4087',
#  '18-4088',
#  '18-4089',
#  '18-4090',
#  '18-4091',
#  '18-4092',
#  '18-4093',
#  '18-4094',
#  '18-4095',
#  '18-4096',
#  '18-4100',
#  '18-4101',
#  '18-4102',
#  '18-4102S',
#  '18-4103',
#  '18-4103S',
#  '18-4106',
#  '18-4107',
#  '18-4112',
#  '18-4113',
#  '18-4114',
#  '18-4115',
#  '18-4116',
#  '18-4117',
#  '18-4118',
#  '18-4119',
#  '18-4121',
#  '18-4122',
#  '18-4123',
#  '18-4124',
#  '18-4124U',
#  '18-4125',
#  '18-4126',
#  '18-4127',
#  '18-4128',
#  '18-4129',
#  '18-4130',
#  '18-4131',
#  '18-4132',
#  '18-4133',
#  '18-4134',
#  '18-4135',
#  '18-4136',
#  '18-4137',
#  '18-4138',
#  '18-4139',
#  '18-4140',
#  '18-4141',
#  '18-4142',
#  '18-4142S',
#  '18-4143',
#  '18-4143S',
#  '18-4144',
#  '18-4144S',
#  '18-4145',
#  '18-4145S',
#  '18-4146',
#  '18-4147',
#  '18-4148',
#  '18-4148S',
#  '18-4149',
#  '18-4149S',
#  '18-4150',
#  '18-4150S',
#  '18-4151',
#  '18-4151S',
#  '18-4152',
#  '18-4153',
#  '18-4154',
#  '18-4155',
#  '18-4158',
#  '18-4159',
#  '18-4164',
#  '18-4166',
#  '18-4167',
#  '18-4168',
#  '18-4169',
#  '18-4174',
#  '18-4177',
#  '18-4177S',
#  '18-4178',
#  '18-4178S',
#  '18-4179',
#  '18-4179S',
#  '18-4180',
#  '18-4180S',
#  '18-4183',
#  '18-4184',
#  '18-4185',
#  '18-4186',
#  '18-4187',
#  '18-4187S',
#  '18-4188',
#  '18-4188S',
#  '18-4192',
#  '18-4193',
#  '18-4194',
#  '18-4195',
#  '18-4196',
#  '18-4196S',
#  '18-4197',
#  '18-4197S',
#  '18-4198',
#  '18-4198S',
#  '18-4199',
#  '18-4199S',
#  '18-4200',
#  '18-4200S',
#  '18-4201',
#  '18-4201S',
#  '18-4202',
#  '18-4203',
#  '18-4204',
#  '18-4205',
#  '18-4208',
#  '18-4209',
#  '18-4223',
#  '18-4224',
#  '18-4225',
#  '18-4226',
#  '18-4227',
#  '18-4228',
#  '18-4229',
#  '18-4230',
#  '18-4231',
#  '18-4232',
#  '18-4237',
#  '18-4237A',
#  '18-4238',
#  '18-4238A',
#  '18-4245',
#  '18-4245S',
#  '18-4246',
#  '18-4246S',
#  '18-4247',
#  '18-4247S',
#  '18-4248',
#  '18-4248S',
#  '18-4249',
#  '18-4250',
#  '18-4253',
#  '18-4254',
#  '18-4255',
#  '18-4255S',
#  '18-4256',
#  '18-4256S',
#  '18-4257',
#  '18-4257XB',
#  '18-4257XR',
#  '18-4258',
#  '18-4258XB',
#  '18-4258XR',
#  '18-4271',
#  '18-4272',
#  '18-4273',
#  '18-4273S',
#  '18-4274',
#  '18-4274S',
#  '18-4275',
#  '18-4276',
#  '18-4293',
#  '18-4293S',
#  '18-4294',
#  '18-4294S',
#  '18-4295',
#  '18-4296',
#  '18-4297',
#  '18-4297HD',
#  '18-4297XB',
#  '18-4297XR',
#  '18-4297XY',
#  '18-4298',
#  '18-4298HD',
#  '18-4298XB',
#  '18-4298XR',
#  '18-4298XY',
#  '18-4299',
#  '18-4299XB',
#  '18-4299XR',
#  '18-4299XY',
#  '18-4300',
#  '18-4300XB',
#  '18-4300XR',
#  '18-4300XY',
#  '18-4301',
#  '18-4302',
#  '18-4303',
#  '18-4303S',
#  '18-4304',
#  '18-4304S',
#  '18-4305',
#  '18-4305S',
#  '18-4305XB',
#  '18-4305XR',
#  '18-4306',
#  '18-4306S',
#  '18-4306XB',
#  '18-4306XR',
#  '18-4307',
#  '18-4307S',
#  '18-4308',
#  '18-4308S',
#  '18-4309',
#  '18-4310',
#  '18-4311',
#  '18-4312',
#  '18-4315',
#  '18-4316',
#  '18-4317',
#  '18-4318',
#  '18-4319',
#  '18-4320',
#  '18-4323',
#  '18-4324',
#  '18-4327',
#  '18-4327A']

# %%
a = 1

a
# Out:
# 1

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:

    while True:
        b += 1
        print(b)
        try:
            resp = requests.get(f'''https://productdesk-api.cellacore.net/legacy/cardone/Vehicle/Recommendation/?q=(productSKU.keyword:{input_.loc[a, 'Part Number']})&size=5000&useCache=true&auth={input_.loc[a, 'Auth']}''',
                                headers=get_header(),
                                proxies=get_proxy(),
                                timeout=(10, 10))
            break
        except:
            continue

    if resp.status_code == 200:
        break

resp
# Out:
# 1
# <Response [200]>

# %%
list_json = resp.json()

list_json
# Out:
# [{'__instanceId': '50KjJoAUAQG5qBasKBYbnkeNL5k=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.685Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3183',
#     'RegionID': '1',
#     'SubmodelID': '474',
#     'VehicleID': '6305',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'USA',
#     'SubModelName': 'Scooter',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1979',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6082',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6083',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '9',
#       'EngineVINName': '0',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71660',
#     'BaseVehicleId': '3183',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'YP-fbqD49scIQphWTFkunpNwnys=',
#    'vs': '0j7W-TyfkuLj1O6PS8d9QwuSmdM='}},
#  {'__instanceId': '5emG8uG9Mv6-iRbJ5xGTA1yZjbg=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.685Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3183',
#     'RegionID': '2',
#     'SubmodelID': '474',
#     'VehicleID': '44551',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'CAN',
#     'SubModelName': 'Scooter',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1979',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6082',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6083',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '9',
#       'EngineVINName': '0',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71660',
#     'BaseVehicleId': '3183',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'YP-fbqD49scIQphWTFkunpNwnys=',
#    'vs': '0j7W-TyfkuLj1O6PS8d9QwuSmdM='}},
#  {'__instanceId': 'jr4XW71QVb5FZvFMPP2Ayhb3jJE=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.685Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3183',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '44550',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1979',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6082',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6083',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '9',
#       'EngineVINName': '0',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71660',
#     'BaseVehicleId': '3183',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'YP-fbqD49scIQphWTFkunpNwnys=',
#    'vs': '0j7W-TyfkuLj1O6PS8d9QwuSmdM='}},
#  {'__instanceId': '0oJQFi6JyPUeFCMSzwZ1O37fPYk=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.685Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3183',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '6284',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1979',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6082',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6083',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '9',
#       'EngineVINName': '0',
#       'FuelDeliverySubTypeID': '6',
#       'FuelDeliverySubTypeName': '2BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71660',
#     'BaseVehicleId': '3183',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'YP-fbqD49scIQphWTFkunpNwnys=',
#    'vs': '0j7W-TyfkuLj1O6PS8d9QwuSmdM='}},
#  {'__instanceId': '8LYBBvAh0eGntnmEH3ZhurWVGbc=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3182',
#     'RegionID': '1',
#     'SubmodelID': '474',
#     'VehicleID': '6304',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'USA',
#     'SubModelName': 'Scooter',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1978',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '3597',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '15',
#       'EngineVINName': 'J',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6081',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71661',
#     'BaseVehicleId': '3182',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'Vk1VbmlmtWwIdOaAIhTBxvWlK7E=',
#    'vs': '0EpYDcedRTXqD5SiODL31wJENxY='}},
#  {'__instanceId': '_F5UJrxB5vntkdyqs9CCU0wGyCU=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3182',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '44548',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1978',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '3597',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '15',
#       'EngineVINName': 'J',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6081',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71661',
#     'BaseVehicleId': '3182',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'Vk1VbmlmtWwIdOaAIhTBxvWlK7E=',
#    'vs': '0EpYDcedRTXqD5SiODL31wJENxY='}},
#  {'__instanceId': 'OyxW5Tu6l3PnNtpYXS_puORegzo=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3182',
#     'RegionID': '2',
#     'SubmodelID': '474',
#     'VehicleID': '44549',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'CAN',
#     'SubModelName': 'Scooter',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1978',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '3597',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '15',
#       'EngineVINName': 'J',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6081',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71661',
#     'BaseVehicleId': '3182',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'Vk1VbmlmtWwIdOaAIhTBxvWlK7E=',
#    'vs': '0EpYDcedRTXqD5SiODL31wJENxY='}},
#  {'__instanceId': 'A9D5oZEED4lUH7w66bCgYpQtWDY=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '3182',
#     'RegionID': '1',
#     'SubmodelID': '20',
#     'VehicleID': '6283',
#     'MakeID': '47',
#     'MakeName': 'Chevrolet',
#     'ModelID': '436',
#     'ModelName': 'Chevette',
#     'RegionName': 'USA',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1978',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '3597',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '15',
#       'EngineVINName': 'J',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '190',
#       'BlockType': 'L',
#       'CC': '-',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '5',
#       'CylinderHeadTypeName': 'SOHC',
#       'EngineConfigID': '6081',
#       'EngBoreStrokeID': '167',
#       'EngineBaseID': '425',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '11',
#       'EngineMfrName': 'General Motors',
#       'EngineVersionID': '5',
#       'EngineVersionName': 'Chevrolet',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '8',
#       'FuelDeliverySubTypeName': '1BBL',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '5',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '14',
#       'ValvesPerEngine': 8}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '14',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '6',
#       'SystemName': 'Manual'},
#      {'ABSID': '6',
#       'ABSName': 'Non-ABS',
#       'ConfigID': '8',
#       'FrontBrakeTypeID': '5',
#       'FrontBrakeTypeName': 'Disc',
#       'RearBrakeTypeID': '6',
#       'RearBrakeTypeName': 'Drum',
#       'SystemID': '5',
#       'SystemName': 'Power'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '4',
#       'SystemID': '6',
#       'SystemName': 'Manual',
#       'TypeID': '6',
#       'TypeName': 'Rack'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '71661',
#     'BaseVehicleId': '3182',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'Vk1VbmlmtWwIdOaAIhTBxvWlK7E=',
#    'vs': '0EpYDcedRTXqD5SiODL31wJENxY='}},
#  {'__instanceId': 'J2ijRLDDew_7RPM3s_dadxP1dy8=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '13104',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '30111',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '1878',
#     'ModelName': 'Acadian',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1979',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '667',
#       'BlockType': 'L',
#       'CC': '1606',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '4',
#       'CylinderHeadTypeName': 'U/K',
#       'EngineConfigID': '6945',
#       'EngBoreStrokeID': '1',
#       'EngineBaseID': '1768',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '4',
#       'EngineMfrName': 'U/K',
#       'EngineVersionID': '50',
#       'EngineVersionName': 'U/K',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '4',
#       'FuelDeliverySubTypeName': 'U/K',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '4',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '16'},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '667',
#       'BlockType': 'L',
#       'CC': '1606',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '4',
#       'CylinderHeadTypeName': 'U/K',
#       'EngineConfigID': '6947',
#       'EngBoreStrokeID': '1',
#       'EngineBaseID': '1768',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '4',
#       'EngineMfrName': 'U/K',
#       'EngineVersionID': '50',
#       'EngineVersionName': 'U/K',
#       'EngineVINID': '9',
#       'EngineVINName': '0',
#       'FuelDeliverySubTypeID': '4',
#       'FuelDeliverySubTypeName': 'U/K',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '4',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '16'}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '4',
#       'ABSName': 'U/K',
#       'ConfigID': '19',
#       'FrontBrakeTypeID': '4',
#       'FrontBrakeTypeName': 'U/K',
#       'RearBrakeTypeID': '4',
#       'RearBrakeTypeName': 'U/K',
#       'SystemID': '4',
#       'SystemName': 'U/K'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '8',
#       'SystemID': '4',
#       'SystemName': 'U/K',
#       'TypeID': '4',
#       'TypeName': 'U/K'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '425809',
#     'BaseVehicleId': '13104',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'NQ5Rwdnd7vO6t-Povxbrp9lSXWI=',
#    'vs': '-ElMUEbjdjFnurvBgYDnD8lTvIA='}},
#  {'__instanceId': 'QCKyEFFCqee1oIG8hxvVGyJ9zGc=',
#   '__type': 'Recommendation',
#   '__modified': '2023-09-20T15:17:15.686Z',
#   'createdOn': '',
#   'productSKU': '18-4003',
#   'brandAAIAID': 'CPCX',
#   'qualifier': [{'id': '15461', 'text': 'with Metal Piston'},
#    {'id': '5582', 'text': 'Installation Hardware Included'}],
#   'fitment': {'Vcdb': {'BaseVehicleID': '13103',
#     'RegionID': '2',
#     'SubmodelID': '20',
#     'VehicleID': '30110',
#     'MakeID': '52',
#     'MakeName': 'Pontiac',
#     'ModelID': '1878',
#     'ModelName': 'Acadian',
#     'RegionName': 'CAN',
#     'SubModelName': 'Base',
#     'VehicleTypeID': '5',
#     'VehicleTypeName': 'Car',
#     'Year': '1978',
#     'Engines': [{'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '667',
#       'BlockType': 'L',
#       'CC': '1606',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '4',
#       'CylinderHeadTypeName': 'U/K',
#       'EngineConfigID': '6945',
#       'EngBoreStrokeID': '1',
#       'EngineBaseID': '1768',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '4',
#       'EngineMfrName': 'U/K',
#       'EngineVersionID': '50',
#       'EngineVersionName': 'U/K',
#       'EngineVINID': '32',
#       'EngineVINName': 'E',
#       'FuelDeliverySubTypeID': '4',
#       'FuelDeliverySubTypeName': 'U/K',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '4',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '16'},
#      {'AspirationID': '5',
#       'AspirationName': 'Naturally Aspirated',
#       'BlockID': '667',
#       'BlockType': 'L',
#       'CC': '1606',
#       'CID': '98',
#       'Cylinders': 4,
#       'CylinderHeadTypeID': '4',
#       'CylinderHeadTypeName': 'U/K',
#       'EngineConfigID': '6946',
#       'EngBoreStrokeID': '1',
#       'EngineBaseID': '1768',
#       'EngineDesignationID': '1',
#       'EngineDesignationName': '-',
#       'EngineMfrID': '4',
#       'EngineMfrName': 'U/K',
#       'EngineVersionID': '50',
#       'EngineVersionName': 'U/K',
#       'EngineVINID': '15',
#       'EngineVINName': 'J',
#       'FuelDeliverySubTypeID': '4',
#       'FuelDeliverySubTypeName': 'U/K',
#       'FuelDeliveryTypeID': '6',
#       'FuelDeliveryTypeName': 'CARB',
#       'FuelTypeID': '5',
#       'FuelTypeName': 'GAS',
#       'IgnitionSystemTypeID': '4',
#       'Liter': 1.6,
#       'PowerOutputID': '1',
#       'ValvesID': '16'}],
#     'Bodies': [{'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '7',
#       'BodyNumDoors': '2',
#       'ConfigID': '17'},
#      {'BodyTypeID': '8',
#       'BodyTypeName': 'Hatchback',
#       'BodyNumDoorsID': '5',
#       'BodyNumDoors': '4',
#       'ConfigID': '18'}],
#     'Brakes': [{'ABSID': '4',
#       'ABSName': 'U/K',
#       'ConfigID': '19',
#       'FrontBrakeTypeID': '4',
#       'FrontBrakeTypeName': 'U/K',
#       'RearBrakeTypeID': '4',
#       'RearBrakeTypeName': 'U/K',
#       'SystemID': '4',
#       'SystemName': 'U/K'}],
#     'DriveTypes': [{'DriveTypeID': '7', 'DriveTypeName': 'RWD'}],
#     'Steerings': [{'ConfigID': '8',
#       'SystemID': '4',
#       'SystemName': 'U/K',
#       'TypeID': '4',
#       'TypeName': 'U/K'}],
#     'Wheelbases': [{'ID': '1'}]},
#    'acesCriteria': {'Id': '425810',
#     'BaseVehicleId': '13103',
#     'BrandAAIAID': 'CPCX',
#     'Qty': '1',
#     'MfrLabel': 'Brake Caliper',
#     'PositionId': '103',
#     'Part': '18-4003',
#     'PositionName': 'Front Left'}},
#   'source': 'aces',
#   'h': {'ve': 'vAxxjUW-L0hi6IrD0qWxyzcRlZc=',
#    'vs': 'simEo48A5HV6EwcceREnk9zfNHg='}}]

# %%
list_make = [json_['fitment']['Vcdb']['MakeName'].strip() for json_ in list_json]

list_make
# Out:
# ['Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Chevrolet',
#  'Pontiac',
#  'Pontiac']

# %%
list_model = [json_['fitment']['Vcdb']['ModelName'].strip() for json_ in list_json]

list_model
# Out:
# ['Chevette',
#  'Chevette',
#  'Chevette',
#  'Chevette',
#  'Chevette',
#  'Chevette',
#  'Chevette',
#  'Chevette',
#  'Acadian',
#  'Acadian']

# %%
list_region = [json_['fitment']['Vcdb']['RegionName'].strip() for json_ in list_json]

list_region
# Out:
# ['USA', 'CAN', 'CAN', 'USA', 'USA', 'CAN', 'CAN', 'USA', 'CAN', 'CAN']

# %%
list_submodel = [json_['fitment']['Vcdb']['SubModelName'].strip() for json_ in list_json]

list_submodel
# Out:
# ['Scooter',
#  'Scooter',
#  'Base',
#  'Base',
#  'Scooter',
#  'Base',
#  'Scooter',
#  'Base',
#  'Base',
#  'Base']

# %%
list_vehicle_type = [json_['fitment']['Vcdb']['VehicleTypeName'].strip() for json_ in list_json]

list_vehicle_type
# Out:
# ['Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car']

# %%
list_year = [int(json_['fitment']['Vcdb']['Year'].strip()) for json_ in list_json]

list_year
# Out:
# [1979, 1979, 1979, 1979, 1978, 1978, 1978, 1978, 1979, 1978]

# %%
list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter = [], [], [], [], []
list_list_engine = [json_['fitment']['Vcdb']['Engines'] for json_ in list_json]
for list_engine in list_list_engine:
    if list_engine:
        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [], [], [], [], []
        for engine in list_engine:
            list_aspiration.append(engine['AspirationName'].strip() if 'AspirationName' in engine and engine['AspirationName'].strip() != '-' else '')

            # = = = = = = = = = = = = = = =

            cylinder = ''
            if 'BlockType' in engine and engine['BlockType'].strip() != '-':
                cylinder += engine['BlockType'].strip()
            if 'Cylinders' in engine and engine['Cylinders'] != 0:
                cylinder += str(engine['Cylinders'])
            list_cylinder.append(cylinder)

            # = = = = = = = = = = = = = = =

            displacement = ''
            if engine['CID'].strip() != '-':
                displacement += f'''{engine['CID'].strip()}cid'''
            elif engine['CC'].strip() != '-':
                displacement += f'''/{engine['CC'].strip()}cc'''
            list_displacement.append(displacement.removeprefix('/'))

            # = = = = = = = = = = = = = = =

            list_fuel.append(engine['FuelTypeName'].strip() if 'FuelTypeName' in engine else '')

            # = = = = = = = = = = = = = = =

            list_liter.append(f'''{engine['Liter']}L''' if 'Liter' in engine and engine['Liter'] != 0 else '')

        # = = = = = = = = = = = = = = =

        list_list_aspiration.append(list_aspiration)
        list_list_cylinder.append(list_cylinder)
        list_list_displacement.append(list_displacement)
        list_list_fuel.append(list_fuel)
        list_list_liter.append(list_liter)
    else:
        list_list_aspiration.append([''])
        list_list_cylinder.append([''])
        list_list_displacement.append([''])
        list_list_fuel.append([''])
        list_list_liter.append([''])

list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter
# Out:
# ([['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated'],
#   ['Naturally Aspirated', 'Naturally Aspirated']],
#  [['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4'],
#   ['L4', 'L4']],
#  [['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid'],
#   ['98cid', '98cid']],
#  [['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS'],
#   ['GAS', 'GAS']],
#  [['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L'],
#   ['1.6L', '1.6L']])

# %%
list_list_drive = []
list_list_drive_type = [json_['fitment']['Vcdb']['DriveTypes'] for json_ in list_json]
for list_drive_type in list_list_drive_type:
    if list_drive_type:
        list_drive = []
        for drive_type in list_drive_type:
            list_drive.append(drive_type['DriveTypeName'].strip())

        # = = = = = = = = = = = = = = =

        list_list_drive.append(list_drive)
    else:
        list_list_drive.append([''])

list_list_drive
# Out:
# [['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD'],
#  ['RWD']]

# %%
list_position = [json_['fitment']['acesCriteria']['PositionName'].strip() if 'PositionName' in json_['fitment']['acesCriteria'] else '' for json_ in list_json]

list_position
# Out:
# ['Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left',
#  'Front Left']

# %%
df_temp = pd.DataFrame()
for i in range(len(list_json)):
    df_temp_temp = pd.DataFrame({'Part No': input_.loc[a, 'Part No'],
                                 'Part Number': input_.loc[a, 'Part Number'],
                                 'Make': list_make[i],
                                 'Model': list_model[i],
                                 'Region': list_region[i],
                                 'Submodel': list_submodel[i],
                                 'Vehicle Type': list_vehicle_type[i],
                                 'Year': list_year[i],
                                 'Aspiration': list_list_aspiration[i],
                                 'Cylinder': list_list_cylinder[i],
                                 'Displacement': list_list_displacement[i],
                                 'Fuel': list_list_fuel[i],
                                 'Liter': list_list_liter[i]})
    for j in range(len(list_list_drive_type[i])):
        df_temp_temp = df_temp_temp.copy()
        df_temp_temp['Drive Type'] = list_list_drive[i][j]
        df_temp = pd.concat([df_temp, df_temp_temp], ignore_index=True).fillna('')
    df_temp['Position'] = list_position[i]

if not df_temp.empty:
    df_temp['Row'] = [i+1 for i in range(len(df_temp))]
    df_temp = df_temp.drop_duplicates(['Part No', 'Part Number', 'Make', 'Model', 'Region', 'Submodel', 'Vehicle Type', 'Year', 'Aspiration', 'Cylinder', 'Displacement', 'Fuel', 'Liter', 'Drive Type', 'Position'],
                                      keep='first',
                                      ignore_index=True)
    df_temp = df_temp.sort_values(by=['Part No', 'Row'],
                                  ascending=[True, True],
                                  ignore_index=True)
    df_temp['Row'] = [i+1 for i in range(len(df_temp))]
    output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Part No Part Number       Make     Model Region Submodel Vehicle Type  \
# 0     2022     18-4003  Chevrolet  Chevette    USA  Scooter          Car
# 1     2022     18-4003  Chevrolet  Chevette    CAN  Scooter          Car
# 2     2022     18-4003  Chevrolet  Chevette    CAN     Base          Car
# 3     2022     18-4003  Chevrolet  Chevette    USA     Base          Car
# 4     2022     18-4003  Chevrolet  Chevette    USA  Scooter          Car
# 5     2022     18-4003  Chevrolet  Chevette    CAN     Base          Car
# 6     2022     18-4003  Chevrolet  Chevette    CAN  Scooter          Car
# 7     2022     18-4003  Chevrolet  Chevette    USA     Base          Car
# 8     2022     18-4003    Pontiac   Acadian    CAN     Base          Car
# 9     2022     18-4003    Pontiac   Acadian    CAN     Base          Car
#
#    Year           Aspiration Cylinder Displacement Fuel Liter Drive Type  \
# 0  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 1  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 2  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 3  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 4  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 5  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 6  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 7  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 8  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 9  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
#
#      Position  Row
# 0  Front Left    1
# 1  Front Left    2
# 2  Front Left    3
# 3  Front Left    4
# 4  Front Left    5
# 5  Front Left    6
# 6  Front Left    7
# 7  Front Left    8
# 8  Front Left    9
# 9  Front Left   10

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Part No': input_.loc[a, 'Part No'],
                             'Title': input_.loc[a, 'Title'],
                             'Subtitle': input_.loc[a, 'Subtitle'],
                             'Part Number': input_.loc[a, 'Part Number'],
                             'Part Type': input_.loc[a, 'Part Type'],
                             'Json_Application_Summary': input_.loc[a, 'Json_Application_Summary'],
                             'Bundle': input_.loc[a, 'Bundle'],
                             'Auth': input_.loc[a, 'Auth'],
                             'Json_Info': input_.loc[a, 'Json_Info'],
                             'Url': input_.loc[a, 'Url'],
                             'Json_Src': input_.loc[a, 'Json_Src']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Part No', 'Row'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_vehicle.xlsx', index=False)

output_correct
# Out:
#    Part No Part Number       Make     Model Region Submodel Vehicle Type  \
# 0     2022     18-4003  Chevrolet  Chevette    USA  Scooter          Car
# 1     2022     18-4003  Chevrolet  Chevette    CAN  Scooter          Car
# 2     2022     18-4003  Chevrolet  Chevette    CAN     Base          Car
# 3     2022     18-4003  Chevrolet  Chevette    USA     Base          Car
# 4     2022     18-4003  Chevrolet  Chevette    USA  Scooter          Car
# 5     2022     18-4003  Chevrolet  Chevette    CAN     Base          Car
# 6     2022     18-4003  Chevrolet  Chevette    CAN  Scooter          Car
# 7     2022     18-4003  Chevrolet  Chevette    USA     Base          Car
# 8     2022     18-4003    Pontiac   Acadian    CAN     Base          Car
# 9     2022     18-4003    Pontiac   Acadian    CAN     Base          Car
#
#    Year           Aspiration Cylinder Displacement Fuel Liter Drive Type  \
# 0  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 1  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 2  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 3  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 4  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 5  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 6  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 7  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 8  1979  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
# 9  1978  Naturally Aspirated       L4        98cid  GAS  1.6L        RWD
#
#      Position  Row
# 0  Front Left    1
# 1  Front Left    2
# 2  Front Left    3
# 3  Front Left    4
# 4  Front Left    5
# 5  Front Left    6
# 6  Front Left    7
# 7  Front Left    8
# 8  Front Left    9
# 9  Front Left   10

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Part No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./test_vehicle_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
