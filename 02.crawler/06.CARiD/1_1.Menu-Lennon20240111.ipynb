# %%
param_len = 5

list_url= ['https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page='+str(_+1)+'#prod-list' for _ in range(param_len)]

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：5
# ['https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page=1#prod-list',
#  'https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page=2#prod-list',
#  'https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page=3#prod-list',
#  'https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page=4#prod-list',
#  'https://www.carid.com/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc?page=5#prod-list']

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests

# %%
i = 0

url = list_url[i]

resp = requests.get(url).text

resp
# Out:
# '<!DOCTYPE html><html class="no-js desktop" lang="en"><head><meta charset="utf-8"><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:[]},distributed_tracing:{enabled:true,allowed_origins:["https://carid.com","https://www.carid.com","https://mygarage-api.carid.com"],cors_use_newrelic_header:true,cors_use_tracecontext_headers:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"594445424",accountID:"4146318",trustKey:"4146318",xpid:"UAcDV1VSABAFUFVaAgIHU1A=",licenseKey:"NRJS-5db917892f9cc9a5cff",applicationID:"544853054"};;/*! For license information please see nr-loader-spa-1.249.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>m,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>N,lF:()=>j,Yu:()=>E,Dg:()=>v,CX:()=>c,GE:()=>x,sU:()=>R});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",h=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. \'*\' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},g="All configuration objects require an agent identifier!";function m(e){if(!e)throw new Error(g);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function v(e,t){if(!e)throw new Error(g);p[e]=(0,i.D)(t,h());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e, ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

with open('./menu.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js desktop" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:[]},distributed_tracing:{enabled:true,allowed_origins:["https://carid.com","https://www.carid.com","https://mygarage-api.carid.com"],cors_use_newrelic_header:true,cors_use_tracecontext_headers:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"594445424",accountID:"4146318",trustKey:"4146318",xpid:"UAcDV1VSABAFUFVaAgIHU1A=",licenseKey:"NRJS-5db917892f9cc9a5cff",applicationID:"544853054"};;/*! For license information please see nr-loader-spa-1.249.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>m,Mt:()=>b,C5:()=>s,DL:()=>A,OP:()=>N,lF:()=>j,Yu:()=>E,Dg:()=>v,CX:()=>c,GE:()=>x,sU:()=>R});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",h=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. '*' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},g="All configuration objects require an agent identifier!";function m(e){if(!e)throw new Error(g);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function v(e,t){if(!e)throw new Error(g);p[e]=(0,i.D)(t,h());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e,t){if(!e)throw new Error(g);var r=m(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const y={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},w={};function A(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!w[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return w[e]}function x(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");w[e]=(0,i.D)(t,y);const r=(0,n.ek)(e);r&&(r.loader_config=w[e])}const E=(0,n.mF)().o;var _=r(385),T=r(6818);const S={buildEnv:T.Re,cus ...
#   </script>
#   <title>
#    CARiD.com
#   </title>
#   <link as="script" href="https://cdn.optimizely.com/js/26173860947.js" rel="preload"/>
#   <link href="https://logx.optimizely.com" rel="preconnect"/>
#   <meta content="Product search and advanced product search options. Find the right Grill, Wood Grain, Spoiler, Car and Truck Accessories for your model, year and make." name="description"/>
#   <link href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=2" rel="next"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="#2d3034" name="theme-color"/>
#   <link href="/domain-specific/carid/manifest.json" rel="manifest"/>
#   <link crossorigin="" href="https://cdn.carid.com" rel="preconnect"/>
#   <link crossorigin="" href="https://images.carid.com" rel="preconnect"/>
#   <link crossorigin="" href="https://ic.carid.com" rel="preconnect"/>
#   <script>
#    (()=>{"use strict";var e,a,d,f,r={},t={};function c(e){var a=t[e];if(void 0!==a)return a.exports;var d=t[e]={id:e,loaded:!1,exports:{}};return r[e].call(d.exports,d,d.exports,c),d.loaded=!0,d.exports}c.m=r,e=[],c.O=(a,d,f,r)=>{if(!d){var t=1/0;for(i=0;i<e.length;i++){for(var[d,f,r]=e[i],b=!0,o=0;o<d.length;o++)(!1&r||t>=r)&&Object.keys(c.O).every((e=>c.O[e](d[o])))?d.splice(o--,1):(b=!1,r<t&&(t=r));if(b){e.splice(i--,1);var n=f();void 0!==n&&(a=n)}}return a}r=r||0;for(var i=e.length;i>0&&e[i-1][2]>r;i--)e[i]=e[i-1];e[i]=[d,f,r]},c.n=e=>{var a=e&&e.__esModule?()=>e.default:()=>e;return c.d(a,{a}),a},d=Object.getPrototypeOf?e=>Object.getPrototypeOf(e):e=>e.__proto__,c.t=function(e,f){if(1&f&&(e=this(e)),8&f)return e;if("object"==typeof e&&e){if(4&f&&e.__esModule)return e;if(16&f&&"function"==typeof e.then)return e}var r=Object.create(null);c.r(r);var t={};a=a||[null,d({}),d([]),d(d)];for(var b=2&f&&e;"object"==typeof b&&!~a.indexOf(b);b=d(b))Object.getOwnPropertyNames(b).forEach((a=>t[a]=()=>e[a]));return t.default=()=>e,c.d(r,t),r},c.d=(e,a)=>{for(var d in a)c.o(a,d)&&!c.o(e,d)&&Object.defineProperty(e,d,{enumerable:!0,get:a[d]})},c.f={},c.e=e=>Promise.all(Object.keys(c.f).reduce(((a,d)=>(c.f[d](e,a),a)),[])),c.u=e=>"async-chunks/"+{111:"438807f8",124:"6bf9263a",132:"ebc3c4c2",169:"e4da4725",221:"b9e297fc",229:"dd7a5221",261:"ea3761ce",319:"18efbfd8",359:"c58f7fe9",376:"01542f11",408:"39391b74",532:"013658e2",574:"7d76112f",610:"dcb0cc8b",621:"78c3d96b",708:"9ac3c9e3",709:"d4c51f73",832:"135156eb",857:"acc8736f",1051:"4652a18c",1073:"1c06c3b7",1078:"2f2f14b1",1146:"e65e69e0",1176:"51d5e553",1177:"d45e7979",1178:"93a3fa90",1216:"edf95752",1234:"75b11e79",1328:"34a38406",1362:"ae8236ce",1402:"64794122",1423:"a01ec659",1443:"09090b07",1506:"5c32eb39",1526:"7497e0f5",1541:"ad2d1372",1699:"766032df",1719:"6a8bd16f",1853:"33d37d15",1854:"88a2766a",1869:"f91caab1",2066:"cea3a1a7",2070:"dbf8c2ad",2094:"30a1a746",2206:"dd7ed741",2338:"556f5374",2348:"ecebd50a",2395:"095f8a4c",2487:"aa867802",2511:"3e73ee5e",2679:"47c6e004",2691:"e30ce627",2707:"2c26a51e",2814:"b34e5408",2889:"1ed1e767",2912:"36cc4486",2998:"b3a9bff6",2999:"dc8ef371",3083:"83761efc",3143:"44179e54",3145:"8827f2a9",3153:"5a94510f",3188:"bb7ddac7",3219:"f0c4ed3a",3365:"1b761e77",3525:"84831749",3553:"41bfda48",3579:"1e32d5a6",3610:"d01fdb9f",3744:"c8ee9a9a",3750:"ffdeddc7",3838:"309ec7a2",3874:"7270c538",3893:"bde2fb0c",3912:"6d8114ee",4018:"086825b4",4034:"f8fdfa4f",4092:"c7aad79d",4118:"542e68e8",4227:"74c80c26",4289:"7b3531df",4324:"b1b15ea7",4362:"d2afb1c9",4449:"9423cb2c",4499:"8bf93c1c",4552:"f32e4257",4575:"e374ede9",4669:"2d3df995",4724:"bf9bec4a",4771:"ecbb77b2",4775:"44e66615",4786:"ea346960",4870:"6dcdef9d",4938:"def9e737",4941:"bbeb8772",5056:"6eafbc3e",5082:"dcaa3c88",5204:"36b0f088",5211:"6f9489be",5341:"5e2c56df",5369:"6a536beb",5426:"e9fbcc9d",5453:"e1b586e3",5554:"ae30a788",5560:"816bf400",5563:"7f78fbe7",5611:"c5d903f9",5711:"544bc312",5736:"a98818ae",5821:"99adf27c",5827:"ffaa3b67",5873:"5968f604",5929:"81f592e6",5956:"c3ac1ff0",6077:"467976f1",6157:"583abf55",6304:"e7645a37",6356:"58ebf974",6369:"6c505fce",6375:"4aedf93c",6405:"cce37553",6409:"8801457b",6415:"de3a9352",6445:"d123e7bb",6473:"8d7798cb",6506:"8eb7a705",6513:"c1b348f9",6598:"09d57c9c",6710:"46f1d240",6840:"d6889941",7046:"8f96fac5",7067:"ec451c21",7102:"05617b7b",7230:"33df5752",7244:"d5e15b83",7249:"e7684d0d",7266:"4885f292",7371:"9bb40e6b",7463:"2f948e35",7499:"24049751",7557:"cad7fc34",7657:"6e79814f",7666:"5103684a",7762:"3333e2fc",7855:"a6ec2eea",7974:"a8427f27",8080:"70e662fe",8180:"d20034ae",8189:"bccb83c7",8253:"72685026",8334:"78d8cbb6",8432:"c914daa4",8467:"ce9ef3c3",8645:"b04f01fd",8848:"4857a83b",8874:"0b5b49ad",8931:"74689232",8935:"6c1a2ce3",8939:"f3253b16",9180:"2eb51253",9375:"ae09ca5d",9407:"eb9ce396",9417:"801202e9",9429:"27032481",9471:"11517dc4",9512:"4c73964d",9744:"d9e6ff6f",9836:"9d7ca070",9854:"6a53003b",9867:"dc9f4924",9871:"5afee5f7",9931:"bfd6829d",9974:"99c168 ...
#   </script>
#   <script>
#    "use strict";(globalThis.webpackChunkid=globalThis.webpackChunkid||[]).push([[6122],{65775:(t,e,r)=>{r.d(e,{default:()=>n});const n=(window.APP||(window.APP={}),window.APP)},39168:(t,e,r)=>{r.d(e,{Z:()=>n});const n={create(t,e){(arguments.length>2&&void 0!==arguments[2]?arguments[2]:document).addEventListener(t,e)},trigger(t){let e,r=arguments.length>1&&void 0!==arguments[1]?arguments[1]:document;try{e=new Event(t)}catch(n){try{e=r.createEvent("Event"),e.initEvent(t,!1,!1)}catch(t){}}r.dispatchEvent(e)}}},6414:(t,e,r)=>{r(70560);var n=r(65775),o=r(39168);(()=>{n.default.readyCallbacks=[],n.default.ready=t=>{t&&"function"==typeof t&&n.default.readyCallbacks.push(t)},n.default.requireAsync=(t,e)=>{if(t){const r="string"==typeof t?[t]:t,o="function"==typeof e?e:()=>{},i=(t,e)=>{const r=document.getElementsByTagName("head")[0],n=document.createElement("script");n.src=t,n.onload=()=>{e()},r.appendChild(n)};r.length>1?i(r[0],(()=>{n.default.requireAsync(((t,e)=>{const r=[];for(let t=0;t<=e.length-1;t+=1)t+1>1&&r.push(e[t]);return r})(0,r),o)})):i(r[0],o)}};let t=null;const e=[];n.default.loadAsyncStyle=async r=>{if(!e.includes(r)){const n=document.createElement("link");n.rel="stylesheet",n.href=r,document.head.appendChild(n),e.push(r),clearTimeout(t),t=setTimeout((()=>{try{o.Z.trigger("initSpoilerHeight"),o.Z.trigger("resize",window)}catch(t){}}),500)}},n.default.moduleLoader={},n.default.moduleLoader.loadModulesAlreadyExecuted=!1,n.default.moduleLoader.moduleGroups=[],n.default.moduleLoader.add=(t,e)=>{const r="string"==typeof t?[t]:t;if(r.length>0){const t={names:r,callback:e};n.default.moduleLoader.moduleGroups.push(t),n.default.moduleLoader.loadModulesAlreadyExecuted&&n.default.moduleLoader.loadModules&&"function"==typeof n.default.moduleLoader.loadModules&&n.default.moduleLoader.loadModules()}}})()},10509:(t,e,r)=>{var n=r(69985),o=r(23691),i=TypeError;t.exports=function(t){if(n(t))return t;throw new i(o(t)+" is not a function")}},85027:(t,e,r)=>{var n=r(48999),o=String,i=TypeError;t.exports=function(t){if(n(t))return t;throw new i(o(t)+" is not an object")}},84328:(t,e,r)=>{var n=r(65290),o=r(27578),i=r(6310),a=function(t){return function(e,r,a){var u,c=n(e),s=i(c),f=o(a,s);if(t&&r!=r){for(;s>f;)if((u=c[f++])!=u)return!0}else for(;s>f;f++)if((t||f in c)&&c[f]===r)return t||f||0;return!t&&-1}};t.exports={includes:a(!0),indexOf:a(!1)}},5649:(t,e,r)=>{var n=r(67697),o=r(92297),i=TypeError,a=Object.getOwnPropertyDescriptor,u=n&&!function(){if(void 0!==this)return!0;try{Object.defineProperty([],"length",{writable:!1}).length=1}catch(t){return t instanceof TypeError}}();t.exports=u?function(t,e){if(o(t)&&!a(t,"length").writable)throw new i("Cannot set read only .length");return t.length=e}:function(t,e){return t.length=e}},6648:(t,e,r)=>{var n=r(68844),o=n({}.toString),i=n("".slice);t.exports=function(t){return i(o(t),8,-1)}},8758:(t,e,r)=>{var n=r(36812),o=r(19152),i=r(82474),a=r(72560);t.exports=function(t,e,r){for(var u=o(e),c=a.f,s=i.f,f=0;f<u.length;f++){var l=u[f];n(t,l)||r&&n(r,l)||c(t,l,s(e,l))}}},75773:(t,e,r)=>{var n=r(67697),o=r(72560),i=r(75684);t.exports=n?function(t,e,r){return o.f(t,e,i(1,r))}:function(t,e,r){return t[e]=r,t}},75684:t=>{t.exports=function(t,e){return{enumerable:!(1&t),configurable:!(2&t),writable:!(4&t),value:e}}},11880:(t,e,r)=>{var n=r(69985),o=r(72560),i=r(98702),a=r(95014);t.exports=function(t,e,r,u){u||(u={});var c=u.enumerable,s=void 0!==u.name?u.name:e;if(n(r)&&i(r,s,u),u.global)c?t[e]=r:a(e,r);else{try{u.unsafe?t[e]&&(c=!0):delete t[e]}catch(t){}c?t[e]=r:o.f(t,e,{value:r,enumerable:!1,configurable:!u.nonConfigurable,writable:!u.nonWritable})}return t}},95014:(t,e,r)=>{var n=r(19037),o=Object.defineProperty;t.exports=function(t,e){try{o(n,t,{value:e,configurable:!0,writable:!0})}catch(r){n[t]=e}return e}},67697:(t,e,r)=>{var n=r(3689);t.exports=!n((function(){return 7!==Object.defineProperty({},1,{get:function(){return 7}})[1]}))},22659:t=>{var e="object"==typeof document&&document.all,r=voi ...
#   </script>
#   <script defer="" src="/js/vendor/vendor-polyfills.min.js?v=9b52ace9">
#   </script>
#   <script async="" src="/js/b.min.js?v=f5d49ab2">
#   </script>
#   <script>
#    APP.storeName = 'CARiD';APP.domainId = '1';
#   </script>
#   <style data-url="/css/critical.css?v=679a18d6">
#    .media-query-state{height:0;overflow:hidden;position:absolute;transform:scale(7);transition:transform 1ms linear;width:1px;z-index:-1}.media-query-state::after{content:"mobile-small"}@keyframes preloader-rotate{0%{transform:translate(-50%, -50%) rotateZ(0)}100%{transform:translate(-50%, -50%) rotateZ(360deg)}}.body-bg-type1{background:#f0f0f0}.body-bg-type1::after,.body-bg-type1::before{content:"";display:table}.hr{border-top:1px solid #d8d8d8;clear:both;height:0;margin:20px 0}.nobg{background:none !important}.nobg-before::before{background:none !important}.nobrdr{border:0 !important}.align-center{text-align:center !important}.align-left{text-align:left !important}._uppercase{text-transform:uppercase !important}.no-js .product-images-shifter-source{pointer-events:none}body{background-color:#fff;color:#111;font:62.5% "Roboto","Arial","Helvetica",sans-serif;line-height:1.4;margin:0;padding:0;text-align:center}div,span,h1,h2,p,em,img,strong,b,u,i,dl,dt,dd,ol,ul,li,fieldset,legend,form,label,table,tr,th,td{background:rgba(0,0,0,0);border:0;font-size:100%;margin:0;outline:0;padding:0;vertical-align:baseline}a,[data-hlk]{background:rgba(0,0,0,0);color:#3761bf;cursor:pointer;font-size:100%;margin:0;padding:0;text-decoration:none;vertical-align:baseline}a:hover,[data-hlk]:hover{text-decoration:underline}table{border-collapse:collapse;border-spacing:0}table td,table th{vertical-align:top}iframe{border:0}html{overflow-x:hidden}html,body{min-height:100%}body{position:relative}textarea{resize:vertical}#scrollfix{position:relative;width:100%;z-index:5}#scrollfix.hiddenScroll{overflow:hidden}.left-panel,.right-panel{display:none;position:absolute;top:0}.main-content{position:relative;width:100%;z-index:1}.main-content.-overlay.-animate::after{animation:show-opts .4s}.main-content.-selects-overlay-show{z-index:auto}.main-content.-wishlist-panel-holder{z-index:5}.wrap{margin:0 auto;min-width:320px;position:relative;text-align:left}.product-list-with-filter-holder{box-sizing:border-box;width:100%}.mobile-small-show,.mobile-medium-show,.mobile-large-show{display:none !important}.hidden{display:none !important}._hide-text{display:block;font-size:1rem;height:0;overflow:hidden;width:0}.ov-hidden{overflow:hidden !important}.ov-x-auto{overflow-x:auto !important}.block{display:block !important}.clear{clear:both;height:0;overflow:hidden}._clear-modern::before,._clear-modern::after{clear:both;content:"";display:table}.float_right{float:right}.float_left{float:left}.pos_r{position:relative}.row::before,.row::after{clear:both;content:"";display:table}template{display:none}.break-word{word-wrap:break-word}.h1-change-btn-wrap{margin:16px 8px}.h1-fat{color:#111;display:block;font:500 2.2em/1.2 "Roboto","Arial","Helvetica",sans-serif;margin:16px 2%}.h1-fat.-with-button{display:inline;margin:0 24px 0 0}.h1-fat>span{font-weight:400}._store-red{background-color:#d41e2b !important}._store-orange{background-color:#fea934 !important}._store-grey-blue{background-color:#455874 !important}._store-blue{background-color:#0883d4 !important}._store-gray{background-color:#686c73 !important}._store-dark-orange{background-color:#fc6200 !important}._store-green{background-color:#1e824c !important}.stores-list-wrap{background-color:#f8f8f8;border-bottom:1px solid #d8d8d8}.stores-list{align-items:center;display:flex;flex-wrap:nowrap;height:36px;list-style:none;overflow:auto hidden}.stores-list>li{display:flex;font-size:1.3em}.stores-list>li>.item{box-sizing:border-box;color:#464646;display:block;line-height:35px;padding-left:64px;padding-right:28px;position:relative;white-space:nowrap}.stores-list>li>.item.-active{cursor:default;font-weight:700}.stores-list-icon{background-position:20px 50%;background-repeat:no-repeat;background-size:auto 16px}.stores-list-icon.-i1-15{background-image:url(https://cdn.carid.com/css/prod-images/0fd23e3d.svg)}.stores-list-icon.-i1-31{background-image:url(https://cdn.carid.com/css/prod-images/5376f3f3.svg)}.stores-list-icon.-i1-6{background-ima ...
#   </style>
#   <script>
#    APP.loadAsyncStyle('/css/enhance.css?v=278e4df4');
#   </script>
#   <style data-url="/css/catalog-critical.css?v=307cf84f">
#    .head-img{line-height:0;overflow:hidden;position:relative;text-align:center}.head-img::after{content:"";display:block;padding-bottom:50%;width:100%}.head-img-aligner{bottom:0;height:100%;left:50%;margin-left:-2500px;position:absolute;top:0;width:5000px}.head-img-aligner.-align-left{left:86%}.head-img-aligner.-align-left.-has-mobile-src{left:50%}.head-img-wrap{height:100%;left:0;overflow:hidden;position:absolute;top:0;width:100%}.head-img-wrap>img{display:block;height:100%;margin:0 auto;width:auto}.head-nav{align-items:center;display:flex;height:230px;justify-content:center;position:relative;width:100%}.head-nav.-with-mmy,.head-nav.-with-mmy .simple-slider-wrap{height:384px}.head-nav::after{background:#111;content:"";display:block;height:100%;left:0;margin:0 auto;max-width:1920px;opacity:.3;position:absolute;right:0;top:0;width:100%}.head-nav-img{display:block;height:100%;left:50%;position:absolute;top:0;transform:translateX(-50%);width:auto}.head-nav-inner{box-sizing:border-box;margin-top:8px;min-width:320px;padding:0 16px;position:relative;text-align:center;width:100%;z-index:3}.head-nav-inner.-with-mmy{padding:0 8px;z-index:21}.head-nav-title{color:#fff;font-size:2.4em;font-weight:700;line-height:1.4;margin-bottom:10px;text-transform:uppercase}.head-nav-title.-with-mmy{line-height:1}.head-nav-subtitle{display:none}.head-nav-subtitle.-with-mmy{margin-bottom:32px}.simple-slider-wrap{display:none}.simple-slider{list-style:none;position:relative;transform:translateX(1920px);transition:transform 500ms ease}.simple-slider.-loaded{transform:translateX(0)}.simple-slider.-no-transition{transition:none}.simple-slider>.slide{float:left;height:0;opacity:0;width:1920px}.simple-slider>.slide.-loaded{height:auto;opacity:1}.head-main-logo{bottom:30px;left:0;position:absolute;right:0;z-index:1}.head-main-logo.-with-main-select-bar{bottom:50px}.head-main-logo>.logo{margin:0 8px}.main-select-bar-h{margin-top:-20px;min-height:290px;position:relative;z-index:21}.ab-main-select-bar-reorder.-active .main-select-bar-h{margin-bottom:16px;margin-top:0 !important;order:3}.head-shop-by-links{bottom:24px;left:0;position:absolute;text-align:center;width:100%;z-index:1}.head-shop-by-links.-with-service-type{bottom:12px}.head-shop-by-links-item,.head-shop-by-links-item>.link{color:#fff;font-size:14px;line-height:16px;text-align:center;text-transform:uppercase}.head-shop-by-links-item:not(:last-child){margin-right:16px;padding-right:16px;position:relative}.head-shop-by-links-item:not(:last-child)::after{border:1px solid #fff;content:"";height:17px;position:absolute;right:0;top:-1px}.head-shop-by-links-item.-service-type{display:block;margin-top:10px}.head-shop-by-links-item.-brand{margin-right:0;padding-right:0}.head-shop-by-links-item.-brand::after{content:none}.head-shop-by-links-item>.link{font-weight:700}.head-shop-by-links-item>.count{display:none}.main-select-bar-preloader{min-height:230px;position:relative;width:100%}.main-select-bar-preloader::after{animation:preloader-rotate .7s infinite linear;background:url(data:image/svg+xml;base64,...) 50% 50% no-repeat;background-size:contain;content:"";height:30px;left:50%;position:absolute;top:50%;transform:translate(-50%, -50%);transform-origin:50% 50%;width:30px}.main-select-bar-preloader.nopreload::after{content:none !important}.ab-main-select-bar-reorder.-active{display:flex;flex-direction:column}.subcats1-item{display:flex;font-size:1.6em;min-height:4em}.product-list-submodel-block{background:#eef1f9;border-radius:4px;margin:16px 8px 32px;padding:24px 16px 16px}.product-list-submodel-block>.header{display:flex;flex-direction:column;font-size:1.6em;font-weight:500;justify-content:center;margin-bottom:16px}.product-list-submodel-block>.list>.btn-holder{display:inline-block;margin-bottom:16px;width:100%}.product-list-submodel-block>.list>.btn-holder>.simple-btn{width:100%}@media only screen and (min-width:421px)and (max-width:740.98px){.head-img::after{padding-bottom:44%}.head-img-aligner.-align-left{le ...
#   </style>
#   <script>
#    APP.loadAsyncStyle('/css/catalog-enhance.css?v=5cb2f6c5');
#   </script>
#   <script defer="" src="/js/vendor/vendor-main.min.js?v=52f18eeb">
#   </script>
#   <script defer="" src="/js/main.min.js?v=adbd0b9e">
#   </script>
#   <script>
#    APP.myGarageIdentifier = 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJ4aWQiOiI0Zjc4NWVmMzIwNWExOGU3NzkxNTY3NzY0YTU4MDNkMSIsImV4cCI6IjIwMjQtMDEtMjUgMDI6MTE6MjgiLCJ0b2tlblR5cGUiOiJndWVzdCJ9.YvB2wCv6hSgWqprjf281DczGO-tK88ceb70s4RkhbzjQRyaBu_rf_viZO2aMImI2f_Eks0wAPLNReLqHd0hS46JlfxKl3INdHyauc2QK-nNXs9QDOeMO3RTVmQWC7k7odZN1ojVEFO26kN4qnI6RJeHNNrFNrZ_aqaIq3DYD2yXU73PniEFRHY4cvPQKIJwWtuhALgoqthMoMvjdngjdhYjDwDStzUCXPqJhKOPx2lASyRqOLZhL4By1_TtUyw04UGr0T_h9d12IR7wbE5DvVUlKbsvPvK6nvtGCBwMsTiAtZKOpQrKiSd3ad20dSnXlyhtlVDDYaX8jND4Nxo9EhA';APP.uid = '71b98275b794a9ae832cf441be38e374';
#   </script>
#   <link href="/domain-specific/carid/favicon.ico" rel="shortcut icon"/>
#   <link href="/domain-specific/carid/favicon.ico" rel="icon"/>
#   <link href="/domain-specific/carid/icon-192x192.png" rel="apple-touch-icon"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-500.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://cdn.carid.com/fonts/roboto-v18-latin-700.woff2" rel="preload" type="font/woff2"/>
#   <script>
#    APP.loadAsyncStyle('/css/fonts.css?v=8044db5b');
#   </script>
#   <script async="" src="https://cdn.optimizely.com/js/26173860947.js">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];window.dataLayer.push({pageType: 'search',pageSubType: '',productCategory: '',view_search_results: 'ngk laser iridium spark plugs',userId: '',uid: '71b98275b794a9ae832cf441be38e374'});APP.moduleLoader.add('gtm-ec');
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PDK6G9P');
#   </script>
#  </head>
#  <body>
#   <aside class="left-panel">
#   </aside>
#   <aside class="right-panel">
#   </aside>
#   <aside class="head-search-holder js-head-search-form-holder" data-code="9ce4892797bb51ab5cb8c042f55b4b7a" data-has-mmy="1" data-id-prefix="head" data-value="ngk laser iridium spark plugs">
#   </aside>
#   <div id="app-root">
#   </div>
#   <div id="scrollfix">
#    <div class="main-wrap">
#     <header class="head-header">
#      <nav class="stores-list-wrap">
#       <div class="wrap">
#        <ul class="stores-list">
#         <li class="js-bg-lazy-load">
#          <div class="item stores-list-icon -active nobg -i1-15">
#           Car &amp; Truck
#          </div>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i4-0 js-new-tab" href="https://www.boatid.com">
#           Boating
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-6 js-new-tab" href="https://www.motorcycleid.com">
#           Motorcycle
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-20 js-new-tab" href="https://www.powersportsid.com">
#           Powersports
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i3-0 js-new-tab" href="https://www.camperid.com">
#           RV / Camper
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i2-0 js-new-tab" href="https://www.recreationid.com">
#           Recreation
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i1-31 js-new-tab" href="https://www.truckid.com">
#           Semi Truck
#          </a>
#         </li>
#         <li class="js-bg-lazy-load">
#          <a class="item stores-list-icon nobg -i5-0 js-new-tab" href="https://www.toolsid.com">
#           Tools
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <script>
#       APP = APP || {};APP.storeMenu = {'mmyStores': [ {'store_id': '15','store_name': 'Car & Truck'}, {'store_id': '6','store_name': 'Motorcycle'}, {'store_id': '20','store_name': 'Powersports'}, {'store_id': '31','store_name': 'Semi Truck'}],'currentStore': '15'};
#      </script>
#      <div class="wrap">
#       <div class="header-top">
#        <div class="nav-logo-holder -carid">
#         <span class="left-menu-icon js-hamburger" data-flag-src="/flag-icons/US-small.svg" data-has-mmy="1" data-store-id="0" data-toggle-class="left-panel-show" data-vehicle-garage-id="15" data-vehicle-id="15">
#         </span>
#         <a class="head-logo-a head-logo-img -carid" href="/">
#          CAR ID
#         </a>
#        </div>
#        <div class="input-holder js-supporting-element-data" data-current-value="ngk laser iridium spark plugs" data-has-mmy="1" data-host="spellcheck.carid.com" data-page-type="search" data-store-id="1" data-vehicle-type-id="15" id="dummy-search-input-for-preact-render">
#         <div class="header-search-label">
#         </div>
#        </div>
#        <ul class="home-header-nav-tool">
#         <li aria-haspopup="true" class="header-dd-hover-element nav-tool-garage-item js-garage-header-menu js-garage-header-menu-block" data-vehicle-garage-id="15">
#          <div class="nav-tool -garage -icon-garage -i1-15">
#           <span class="count-item -outline -garage js-my-garage-counter">
#            0
#           </span>
#           <span class="title -empty js-header-garage-mmy">
#           </span>
#           <span class="garage-change-btn hidden js-garage-change-btn">
#            Change
#           </span>
#          </div>
#         </li>
#         <li class="header-dd-hover-element nav-tool-account-item js-account-header-menu">
#          <div class="nav-tool -icon-account">
#          </div>
#          <div class="js-account-dd-holder">
#          </div>
#         </li>
#         <li aria-haspopup="true" class="header-dd-hover-element js-head-cart-holder">
#          <a class="nav-tool -icon-cart" href="/cart.php">
#           <span class="header-access-text">
#            Shopping Cart
#           </span>
#           <span class="count-item -outline js-mini-cart-total-items">
#            0
#           </span>
#          </a>
#          <div class="js-head-dd-cart-prods">
#          </div>
#         </li>
#        </ul>
#       </div>
#       <nav class="head-dd-h">
#        <div class="header-menu-wrapper">
#         <ul class="head-dd js-head-depts">
#          <li class="item js-head-dept" data-id="62" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/auto-parts.html">
#            Parts
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="418" data-store-id="0" data-vehicle-id="15">
#           <span class="head-dd-main">
#            <a class="link" href="/custom-wheels.html">
#             Wheels
#            </a>
#            <span class="extra">
#             &amp;
#            </span>
#            <a class="link" href="/tires.html">
#             <span class="head_dd_main_wide_show">
#              Tires
#             </span>
#            </a>
#           </span>
#          </li>
#          <li class="item js-head-dept" data-id="408" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/exterior-accessories.html">
#            Exterior
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="24" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/automotive-lighting.html">
#            Lighting
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="63" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/auto-body-parts.html">
#            Body Parts
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="407" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/interior-accessories.html">
#            Interior
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="170" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/car-audio-electronics.html">
#            Audio &amp; Electronics
#           </a>
#          </li>
#          <li class="item js-head-dept" data-id="29909" data-store-id="0" data-vehicle-id="15">
#           <a class="head-dd-main" href="/automotive-tools.html">
#            Automotive Tools
#           </a>
#          </li>
#          <li class="item mobile-hide js-head-dept js-more-ignore" data-id="777">
#           <span class="head-dd-main">
#            Specialty
#            <span class="extra">
#             Shops
#            </span>
#           </span>
#          </li>
#         </ul>
#        </div>
#       </nav>
#      </div>
#      <div class="head-dd-cont-holder js-head-dd-cont-holder">
#       <div class="wrap">
#       </div>
#      </div>
#     </header>
#     <script class="js-phone-link" type="text/x-handlebars-template">
#      <a href="tel:+1-800-505-3274" class="inline-block js-phone-h phone-link">800.505.3274</a>
#     </script>
#     <script class="js-phone-int-link" type="text/x-handlebars-template">
#      <a href="tel:+1-609-642-4700" class="inline-block js-int-phone-h phone-link">1.609.642.4700</a>
#     </script>
#     <div class="main-content">
#      <main>
#       <div class="wrap">
#        <script>
#         APP.loadAsyncStyle('/css/search-page.css?v=44bd8b29');
#        </script>
#        <div class="breadcrumbs-holder -static">
#         <nav class="breadcrumbs-ov">
#          <ol class="breadcrumbs">
#           <li class="item">
#            <a class="link" href="/">
#             Home
#            </a>
#           </li>
#           <li class="item">
#            Search
#           </li>
#          </ol>
#         </nav>
#         <script type="application/ld+json">
#          {"@context": "https://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "Home","item": "https://www.carid.com/"}]}
#         </script>
#        </div>
#        <div class="pos_r">
#         <h1 class="h1-fat">
#          Search
#          <span>
#           Results
#          </span>
#         </h1>
#         <script type="application/ld+json">
#          {"@context":"https://schema.org","@type":"SearchResultsPage","name": "ngk laser iridium spark plugs"}
#         </script>
#         <div class="search-nores-form js-search-result-form-holder" data-yearid="">
#          <span class="search-substring">
#           ngk laser iridium spark plugs
#          </span>
#         </div>
#         <div data-host="spellcheck.carid.com" data-query="ngk laser iridium spark plugs" data-query-id="420738fe115bb7ad7af949d2688d7e1a" data-session-start-time="1704957088262" data-store-id="1" data-vehicle-type-id="15" id="did-you-mean-render-holder">
#         </div>
#         <div class="js-search-page-statistic-data-holder hidden" data-query="ngk laser iridium spark plugs" data-query-id="420738fe115bb7ad7af949d2688d7e1a" data-yearid="">
#         </div>
#        </div>
#        <nav class="search-nav">
#         <span class="link-h">
#          <a class="js-scroll-to link" href="#categories">
#           Categories
#          </a>
#         </span>
#         <span class="link-h">
#          <a class="js-scroll-to link" href="#products">
#           Products
#          </a>
#         </span>
#        </nav>
#        <div class="search-result-total">
#         204 results found
#        </div>
#        <div class="search-related" id="categories">
#         <h2 class="h2">
#          <b>
#           Categories
#          </b>
#         </h2>
#         <ul class="search-related-list">
#          <li class="item">
#           <img alt="Spark Plugs" class="img" src="https://ic.carid.com/pages/icons/spark-plugs_ic_5.jpg"/>
#           <a class="js-search-stat-link link" data-item-id="1246-product_types" data-item-type="type_groups" href="/spark-plugs.html">
#            Spark Plugs
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="search-related" id="products">
#         <h2 class="h2">
#          <b>
#           Products
#          </b>
#         </h2>
#         <div class="js-products-panel-mobile-group" id="prod-list">
#          <div class="products-panel-mobile-wrapper mb0">
#          </div>
#          <div class="prod-list-adj-bar">
#           <div class="plab-sorting-tool">
#            <div class="plab-sorting-tool-wrap plab-sorting-tool-sorter">
#             <div class="form-field -select js-form-field mb0 js-plab-sorting-tool-select">
#              <label for="spark-plugs.html">
#               Sort by
#              </label>
#              <select class="" id="spark-plugs.html" name="sorter" onchange="location = this.options[this.selectedIndex].value;">
#               <option value="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc">
#                Recommended
#               </option>
#               <option value="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-asc">
#                Price Low to High
#               </option>
#               <option selected="" value="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc">
#                Price High to Low
#               </option>
#               <option value="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-top-rated">
#                Top Rated Products
#               </option>
#               <option value="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-new-arrivals">
#                New Arrivals
#               </option>
#              </select>
#             </div>
#            </div>
#           </div>
#           <div class="plab-pagination">
#            1 - 50 of 204 results
#           </div>
#           <div class="plab-view-mode">
#            <span class="plab-view-mode-grid">
#            </span>
#            <span class="plab-view-mode-list active">
#            </span>
#           </div>
#          </div>
#          <aside class="aside-limiter">
#           <div class="aside mb20">
#            <script>
#             APP.plabParams = {wrapper: '.aside',form: '.refine-search-rsp',filters: '.aside-filters'};
#            </script>
#            <script>
#             APP.initialStateMainSelectBar = {purpose: 'search-result-page',vehicleList: {makes: JSON.parse('[]'),models: JSON.parse('[]'),years: JSON.parse('{"2024":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2024","value":2024,"id":null},"2023":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2023","value":2023,"id":null},"2022":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2022","value":2022,"id":null},"2021":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2021","value":2021,"id":null},"2020":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2020","value":2020,"id":null},"2019":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2019","value":2019,"id":null},"2018":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2018","value":2018,"id":null},"2017":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2017","value":2017,"id":null},"2016":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2016","value":2016,"id":null},"2015":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2015","value":2015,"id":null},"2014":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2014","value":2014,"id":null},"2013":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2013","value":2013,"id":null},"2012":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2012","value":2012,"id":null},"2011":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId-420738fe115bb7ad7af949d2688d7e1a\/&redirect=1%2Fsort-price-desc\/sort-price-desc\/year-2011","value":2011,"id":null},"2010":{"number":0,"checked":false,"disabled":false,"url":"\/search\/NGK+Laser+Iridium+Spark+Plugs\/code-ccb8ce4eee843e4eb433d7a9a8931e0d\/queryId ...
#            </script>
#            <div class="js-main-select-bar-holder main-select-bar-preloader">
#            </div>
#            <a class="hidden" href="" id="js-search-result-current-mmy-text">
#             clear
#            </a>
#            <form action="/search.php" class="refine-search-rsp" method="post">
#             <div class="aside-filter">
#              <div class="aside-filters-block filter-section">
#               <div class="aside-filters-counter">
#                <span class="txt">
#                 <span class="title">
#                  Filters
#                 </span>
#                 <span class="counter -filters">
#                  0
#                 </span>
#                </span>
#                <span class="results">
#                 204 Results
#                </span>
#               </div>
#               <div class="aside-filters-btns">
#                <div class="aside-filters-button">
#                 <button class="simple-btn -success -small -wide js-aside-panel-close" type="button">
#                  Done
#                 </button>
#                </div>
#               </div>
#              </div>
#              <div class="aside-filters-summary -mobile">
#               <ul class="universal-label -list">
#               </ul>
#              </div>
#              <div class="aside-filters-title aside-minus">
#               <span class="title">
#                Category
#               </span>
#              </div>
#              <div class="aside-filter-block js-aside-block aside-block -expanded">
#               <ul class="aside-filters">
#                <li class="-icon">
#                 <span class="aside-filters-item form-field-label -checkbox -icon">
#                  <a data-selection="multiple" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc/category-144">
#                   Ignition
#                  </a>
#                  <input name="" type="checkbox" value=""/>
#                 </span>
#                </li>
#                <li class="-icon">
#                 <span class="aside-filters-item form-field-label -checkbox -icon">
#                  <a data-selection="multiple" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc/category-32594">
#                   Ignition System Parts
#                  </a>
#                  <input name="" type="checkbox" value=""/>
#                 </span>
#                </li>
#               </ul>
#              </div>
#              <div class="aside-filters-title aside-minus">
#               <span class="title">
#                Fitment
#               </span>
#              </div>
#              <div class="aside-filter-block js-aside-block aside-block -expanded">
#               <ul class="aside-filters">
#                <li class="-icon">
#                 <span class="aside-filters-item form-field-label -checkbox -icon">
#                  <a data-selection="multiple" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc/fitment_type-1">
#                   Vehicle Specific
#                  </a>
#                  <input name="" type="checkbox" value=""/>
#                 </span>
#                </li>
#               </ul>
#              </div>
#              <div class="aside-filters-title aside-minus">
#               <span class="title">
#                Brand
#               </span>
#              </div>
#              <div class="aside-filter-block js-aside-block aside-block -expanded">
#               <div class="aside-filters-search">
#                <div class="form-field -input js-form-field -mark -zoom mb0">
#                 <label for="brand-filter">
#                  Search Brands
#                 </label>
#                 <input autocomplete="off" class="js-input-text" id="brand-filter" type="text" value=""/>
#                </div>
#               </div>
#               <ul class="aside-filters" data-has-filter="true" data-name="brand">
#                <li class="-icon">
#                 <span class="aside-filters-item form-field-label -checkbox -icon">
#                  <a data-selection="multiple" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc/brand-843">
#                   NGK
#                  </a>
#                  <input name="" type="checkbox" value=""/>
#                 </span>
#                </li>
#               </ul>
#              </div>
#              <div class="aside-filters-title aside-minus">
#               <span class="title">
#                Price
#               </span>
#              </div>
#              <div class="aside-filter-block js-aside-block aside-block -expanded">
#               <ul class="aside-filters">
#                <li class="aside-price-range-filter">
#                 <span class="aside-filters-item hidden">
#                 </span>
#                 <div class="aside-price-range-form">
#                  <div class="form-field -input js-form-field -price-range -small mb0">
#                   <label for="filter-price-min">
#                    $ Min
#                   </label>
#                   <input autocomplete="off" class="js-input-text" data-permitted_min_price="3" id="filter-price-min" maxlength="6" name="minPrice" type="tel" value=""/>
#                  </div>
#                  <div class="form-field -input js-form-field -price-range -small mb0">
#                   <label for="filter-price-max">
#                    $ Max
#                   </label>
#                   <input autocomplete="off" class="js-input-text" data-permitted_max_price="26" id="filter-price-max" maxlength="6" name="maxPrice" type="tel" value=""/>
#                  </div>
#                  <div class="aside-price-range-button-holder">
#                   <button class="simple-btn -large -wide js-facets-price-range-btn" type="submit">
#                    GO
#                   </button>
#                  </div>
#                 </div>
#                 <div class="aside-price-range-slider">
#                  <div class="js-price-range-slider">
#                  </div>
#                 </div>
#                 <div class="error-message -price-range js-price-range-message">
#                 </div>
#                </li>
#               </ul>
#              </div>
#              <div class="aside-filters-title aside-minus">
#               <span class="title">
#                Rating
#               </span>
#              </div>
#              <div class="aside-filter-block js-aside-block aside-block -expanded">
#               <ul class="aside-filters">
#                <li class="-icon">
#                 <span class="aside-filters-item form-field-label -checkbox -icon">
# ...
#             <div class="lst-ic-h">
#              <img alt="NGK® 93199 - Laser Iridium™ Spark Plug" class="lst-ic lazy-load" data-src="https://ic.carid.com/ngk/items/93199_6.jpg" src="..."/>
#             </div>
#             <div class="lst-main">
#              <div class="lst-info-left-part">
#               <a class="lst-a js-search-stat-link" data-item-id="mpn4629111097" data-item-type="products" href="/ngk/laser-iridium-spark-plug-mpn-93199.html">
#                NGK® 93199
#                <span class="lst-a-name">
#                 Laser Iridium™ Spark Plug
#                </span>
#               </a>
#               <div class="lst-meta">
#                <div class="lst-rating stars-0">
#                 0
#                </div>
#                <div class="lst-id -with-fitment-type -vehicle" data-fit-type="Vehicle Specific">
#                 # mpn4629111097
#                </div>
#               </div>
#               <div class="lst-descr js-bg-lazy-load">
#                <div class="lst-descr-text">
#                 <b>
#                  Laser
#                 </b>
#                 <b>
#                  Iridium
#                 </b>
#                 ™
#                 <b>
#                  Spark
#                 </b>
#                 Plug (93199) by
#                 <b>
#                  NGK
#                 </b>
#                 ®. OE Equivalent Design / 105. 000 miles OE Manufacturer Reco mmended Service Interval. Often specified as original equipment,
#                 <b>
#                  NGK
#                 </b>
#                 <b>
#                  Laser
#                 </b>
#                 <b>
#                  Iridium
#                 </b>
#                 ...
#                </div>
#                <div class="prod-lst-feature-images">
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/electrode-material/iridium.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/heat-range/heat-range-6.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/insulator-type/projected.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/spark-plug-gap-size/gap-size-1-1mm.svg')">
#                 </i>
#                 <div class="btn js-prod-lst-feature-images-btn">
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="lst-info-right-part">
#               <div class="product-list-qty-form-holder">
#                <span class="lst-prc">
#                 $16.37
#                </span>
#               </div>
#              </div>
#             </div>
#            </li>
#            <li class="js-product-list-item" data-id="mpn4649055425" data-manufacturer-id="" data-mpn="" data-name="NGK® 90565 - Laser Iridium™ Spark Plug" data-price="16.37" data-src="https://ic.carid.com/ngk/items/90565_6.jpg" data-url="/ngk/laser-iridium-spark-plug-mpn-90565.html" data-wl-price="$16.37">
#             <div class="lst-ic-h">
#              <img alt="NGK® 90565 - Laser Iridium™ Spark Plug" class="lst-ic lazy-load" data-src="https://ic.carid.com/ngk/items/90565_6.jpg" src="..."/>
#             </div>
#             <div class="lst-main">
#              <div class="lst-info-left-part">
#               <a class="lst-a js-search-stat-link" data-item-id="mpn4649055425" data-item-type="products" href="/ngk/laser-iridium-spark-plug-mpn-90565.html">
#                NGK® 90565
#                <span class="lst-a-name">
#                 Laser Iridium™ Spark Plug
#                </span>
#               </a>
#               <div class="lst-meta">
#                <div class="lst-rating stars-0">
#                 0
#                </div>
#                <div class="lst-id -with-fitment-type -vehicle" data-fit-type="Vehicle Specific">
#                 # mpn4649055425
#                </div>
#               </div>
#               <div class="lst-descr js-bg-lazy-load">
#                <div class="lst-descr-text">
#                 <b>
#                  Laser
#                 </b>
#                 <b>
#                  Iridium
#                 </b>
#                 ™
#                 <b>
#                  Spark
#                 </b>
#                 Plug (90565) by
#                 <b>
#                  NGK
#                 </b>
#                 ®. Often specified as original equipment,
#                 <b>
#                  NGK
#                 </b>
#                 <b>
#                  Laser
#                 </b>
#                 <b>
#                  Iridium
#                 </b>
#                 <b>
#                  spark
#                 </b>
#                 <b>
#                  plugs
#                 </b>
#                 are the best combination of performance and longevity....
#                </div>
#                <div class="prod-lst-feature-images">
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/electrode-material/iridium.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/heat-range/heat-range-7.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/insulator-type/projected.svg')">
#                 </i>
#                 <i class="item nobg" style="background-image:url('https://images.carid.com/info-img/performance-spark-plugs/spark-plug-gap-size/gap-size-1-1mm.svg')">
#                 </i>
#                 <div class="btn js-prod-lst-feature-images-btn">
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="lst-info-right-part">
#               <div class="product-list-qty-form-holder">
#                <span class="lst-prc">
#                 $16.37
#                </span>
#               </div>
#              </div>
#             </div>
#            </li>
#           </ul>
#           <aside class="js-aside-fixed-limit-el clear">
#           </aside>
#           <nav class="pagination">
#            <div class="pagination-rsp">
#             <div class="pagination-load-next-btn-h">
#              <button class="simple-btn -large -wide -load-next -transparent js-pagination-more-btn" type="button">
#               Next 50
#              </button>
#             </div>
#             <div class="pagination-txt">
#              Showing
#              <span>
#               1-50
#              </span>
#              of
#              <span>
#               204
#              </span>
#              Products
#             </div>
#             <div class="mobile-pagination-holder">
#              <span class="pagination-prev active">
#               Prev
#              </span>
#              <span class="pagination-btn active">
#               1
#              </span>
#              <a class="pagination-btn" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=2#prod-list">
#               2
#              </a>
#              <a class="pagination-btn" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=3#prod-list">
#               3
#              </a>
#              <a class="pagination-btn" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=4#prod-list">
#               4
#              </a>
#              <a class="pagination-btn" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=5#prod-list">
#               5
#              </a>
#              <a class="pagination-next" href="/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&amp;redirect=1%2Fsort-price-desc/sort-price-desc?page=2#prod-list">
#               Next
#              </a>
#             </div>
#            </div>
#           </nav>
#           <br/>
#           <br/>
#           <script>
#            APP.pagination = {'pageLimit': 5,'baseUrl': '/search/NGK+Laser+Iridium+Spark+Plugs/code-ccb8ce4eee843e4eb433d7a9a8931e0d/queryId-420738fe115bb7ad7af949d2688d7e1a/&redirect=1%2Fsort-price-desc/sort-price-desc','currentPage': 1,'nextPage': 2,'itemsListSector': '.js-main-prod-list'};
#           </script>
#          </div>
#          <div class="clear">
#          </div>
#         </div>
#        </div>
#       </div>
#      </main>
#      <script>
#       APP.moduleLoader.add('recently-viewed')
#      </script>
#      <aside class="wrap js-recently-viewed-products">
#      </aside>
#      <footer class="f-footer js-bg-lazy-load">
#       <aside class="newsletter-subscribe-bnr">
#        <span class="txt">
#        </span>
#        <button class="btn js-subscribe-link" data-subscribe-location-type="Footer Subscription">
#         SUBSCRIBE TO OUR NEWSLETTER
#        </button>
#       </aside>
#       <div class="f-info">
#        <div class="wrap">
#         <div class="f-info-wrap">
#          <div class="f-info-col -f-pub">
#           <div class="pub-block -f-pub">
#            <span class="js-new-tab icon -icon-fb nobg" data-hlk="https://www.facebook.com/CARiDcom">
#             CARiD Facebook
#            </span>
#            <span class="js-new-tab icon -icon-tw nobg" data-hlk="https://twitter.com/carid_com">
#             CARiD Twitter
#            </span>
#            <span class="icon -icon-yt nobg" data-hlk="https://www.youtube.com/user/CARiDcom">
#             CARiD YouTube Channel
#            </span>
#            <span class="js-new-tab icon -icon-pin nobg" data-hlk="https://www.pinterest.com/caridcom/">
#             CARiD Pinterest
#            </span>
#            <span class="js-new-tab icon -icon-in nobg" data-hlk="https://www.instagram.com/caridcom/">
#             CARiD Instagram
#            </span>
#           </div>
#           <span class="f-contact -inspiration nobg-before js-new-tab" data-hlk="/gallery/">
#            Inspiration Gallery
#           </span>
#           <div class="f-text">
#            All manufacturer names, symbols, and descriptions, used in our images and text are used solely for identification purposes only. It is neither inferred nor implied that any item sold by CARiD.com is a product authorized by or in any way connected with any vehicle manufacturers displayed on this page.
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            CUSTOMER SERVICE
#           </span>
#           <div class="footer-toggle-content">
#            <div class="f-list">
#             <span data-hlk="/help-center/">
#              Help Center
#             </span>
#             <span data-hlk="/my-account/login/">
#              My Account
#             </span>
#             <span data-hlk="/my-account/order-status/">
#              Track My Order
#             </span>
#             <span data-hlk="/help-center/product-return.html">
#              Return Policy
#             </span>
#             <span data-hlk="/help-center/privacy.html">
#              Privacy Policy
#             </span>
#             <span data-hlk="/gift-cards.html">
#              Gift Cards
#             </span>
#             <span data-hlk="/contact-us.html">
#              Contact Us
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            INFORMATION
#           </span>
#           <div class="footer-toggle-content">
#            <div class="f-list">
#             <span data-hlk="/about-us.html">
#              About Us
#             </span>
#             <span data-hlk="/articles/">
#              Guides &amp; Articles
#             </span>
#             <span data-hlk="/reviews.html">
#              Customer Reviews
#             </span>
#             <span data-hlk="/coupon-codes.html">
#              Coupon Codes
#             </span>
#             <span data-hlk="/pressroom.html">
#              In the News
#             </span>
#             <span data-hlk="/vendor-portal.html">
#              Sell on CARiD
#             </span>
#             <span data-hlk="/wholesale.html">
#              Buy Wholesale
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="f-info-col">
#           <span class="f-title footer-toggle-header" data-disabled-on="mobile-large desktop">
#            CONTACTS
#           </span>
#           <div class="footer-toggle-content">
#            <span class="f-contact -address nobg-before">
#             CARiD.com
#             <br/>
#             1 Corporate Drive
#             <br/>
#             Cranbury, NJ 08512
#            </span>
#            <span class="f-contact -phone nobg-before">
#             Toll Free:
#             <span>
#              <a class="inline-block js-phone-h phone-link" href="tel:+1-800-505-3274">
#               800.505.3274
#              </a>
#             </span>
#             <br/>
#             International:
#             <span>
#              <a class="inline-block js-int-phone-h phone-link" href="tel:+1-609-642-4700">
#               1.609.642.4700
#              </a>
#             </span>
#             <br/>
#             Fax:
#             <span>
#              1.609.964.1983
#             </span>
#            </span>
#            <span class="f-contact -live-chat nobg-before">
#             <span class="btn js-livechat">
#              Live Chat
#             </span>
#            </span>
#            <span class="f-contact -email nobg-before">
#             Email:
#             <span class="js-show-recommended-contacts">
#              info@carid.com
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="f-other">
#        <div class="wrap">
#         <div class="f-copyright">
#          Copyright © 2003-2024 CARiD.com. All rights reserved.
#         </div>
#         <div class="f-links">
#          <a href="/sitemap/">
#           Sitemap
#          </a>
#         </div>
#        </div>
#       </div>
#       <script type="application/ld+json">
#        {"@context":"https://schema.org","@type":"Organization","name":"CARiD","url":"https://www.carid.com/","logo":"https://www.carid.com/domain-specific/carid/icon-128x128.png","address":{"@type":"PostalAddress","addressCountry":"US","addressRegion":"NJ","addressLocality":"Cranbury","postalCode":"08512","streetAddress":"1 Corporate Drive"},"contactPoint":[{"@type":"ContactPoint","telephone":"+1-800-505-3274","contactType":"customer support","contactOption":"TollFree","areaServed":"US"},{"@type":"ContactPoint","telephone":"+1-609-642-4700","contactType":"customer support"}],"email":"info@carid.com","faxNumber":"+1-609-964-1983","sameAs":["https://www.facebook.com/CARiDcom","https://twitter.com/carid_com","https://www.youtube.com/user/CARiDcom","https://www.pinterest.com/caridcom/","https://www.instagram.com/caridcom/"]}
#       </script>
#      </footer>
#     </div>
#    </div>
#    <aside class="main-content-overlay">
#    </aside>
#   </div>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-5db917892f9cc9a5cff","applicationID":"544853054","transactionName":"M1dTMEZXVkBVWkxbVwodZBZdGUtWVUtbWhYUWkE=","queueTime":0,"applicationTime":1041,"atts":"HxBQRg5NRU4=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_part = html.xpath('//ul[@data-gtm-product-list-type="Search Results"]/li[@class="js-product-list-item"]')

list_part
# Out:
# [<Element li at 0x12648eb00>,
#  <Element li at 0x12648ea40>,
#  <Element li at 0x12648e400>,
#  <Element li at 0x1241ace40>,
#  <Element li at 0x1241ac880>,
#  <Element li at 0x1241ad400>,
#  <Element li at 0x1241acc00>,
#  <Element li at 0x1241adc40>,
#  <Element li at 0x1241ae600>,
#  <Element li at 0x1241ac940>,
#  <Element li at 0x1241af880>,
#  <Element li at 0x1241afe80>,
#  <Element li at 0x1241ac800>,
#  <Element li at 0x1241aff40>,
#  <Element li at 0x1241ac080>,
#  <Element li at 0x1241ac9c0>,
#  <Element li at 0x1241af1c0>,
#  <Element li at 0x1241acec0>,
#  <Element li at 0x1241ad5c0>,
#  <Element li at 0x1241aca40>,
#  <Element li at 0x126474d80>,
#  <Element li at 0x1264767c0>,
#  <Element li at 0x1264768c0>,
#  <Element li at 0x126474f00>,
#  <Element li at 0x126475c80>,
#  <Element li at 0x126476180>,
#  <Element li at 0x126474bc0>,
#  <Element li at 0x126476280>,
#  <Element li at 0x126475a00>,
#  <Element li at 0x126477600>,
#  <Element li at 0x126477900>,
#  <Element li at 0x126477880>,
#  <Element li at 0x1264752c0>,
#  <Element li at 0x126475d00>,
#  <Element li at 0x126475bc0>,
#  <Element li at 0x126475ec0>,
#  <Element li at 0x1264775c0>,
#  <Element li at 0x126477a00>,
#  <Element li at 0x126477bc0>,
#  <Element li at 0x126477b00>,
#  <Element li at 0x126477fc0>,
#  <Element li at 0x126477180>,
#  <Element li at 0x126477d40>,
#  <Element li at 0x126477e80>,
#  <Element li at 0x126477ac0>,
#  <Element li at 0x126477440>,
#  <Element li at 0x126476d00>,
#  <Element li at 0x126475200>,
#  <Element li at 0x126474280>,
#  <Element li at 0x1241bb740>]

# %%
list_sku = [part.xpath('./@data-id')[0].strip() for part in list_part]

list_sku
# Out:
# ['mpn4899600159',
#  'mpn4899600159',
#  'mpn1802026',
#  'mpn1802027',
#  'sp5197',
#  'mpn4899600100',
#  'mpn1725555',
#  'mpn4517138463',
#  'mpn1728609',
#  'mpn4889528618',
#  'mpn4889528618',
#  'mpn1728618',
#  'mpn1890151396',
#  'mpn1890157004',
#  'mpn4649055393',
#  'mpn4649055466',
#  'mpn4649055517',
#  'mpn4649055571',
#  'sp5198',
#  'mpn4792335284',
#  'mpn1728572',
#  'mpn1728603',
#  'mpn1728604',
#  'mpn1728605',
#  'mpn1728606',
#  'mpn1728607',
#  'mpn1728608',
#  'mpn1728611',
#  'mpn1728612',
#  'mpn1728615',
#  'mpn1730069',
#  'mpn1800392',
#  'mpn1802019',
#  'mpn1802036',
#  'mpn1802539',
#  'mpn1802548',
#  'mpn1802575',
#  'mpn1890151438',
#  'mpn1890151531',
#  'mpn1890151554',
#  'mpn1890157005',
#  'mpn4063562616',
#  'mpn4063562901',
#  'mpn4063563136',
#  'mpn4063563469',
#  'mpn4517138420',
#  'mpn4517138434',
#  'mpn4524514814',
#  'mpn4629111097',
#  'mpn4649055425']

# %%
list_title = [part.xpath('./@data-name')[0].strip() for part in list_part]

list_title
# Out:
# ['NGK® 96698 - Laser Iridium™ Spark Plug',
#  'NGK® - Laser Iridium™ Spark Plug',
#  'NGK® 6700 - Laser Iridium™ Spark Plug',
#  'NGK® 6701 - Laser Iridium™ Spark Plug',
#  'NGK® - Laser Iridium™ Spark Plug',
#  'NGK® 91112 - Laser Iridium™ Spark Plug',
#  'NGK® 1555 - Laser Iridium™ Spark Plug',
#  'NGK® 95248 - Laser Iridium™ Spark Plug',
#  'NGK® 93026 - Laser Iridium™ Spark Plug',
#  'NGK® 90911 - Laser Iridium™ Spark Plug',
#  'NGK® - Laser Iridium™ Spark Plug',
#  'NGK® 97218 - Laser Iridium™ Spark Plug',
#  'NGK® 92605 - Laser Iridium™ Spark Plug',
#  'NGK® 94731 - Laser Iridium™ Spark Plug',
#  'NGK® 91874 - Laser Iridium™ Spark Plug',
#  'NGK® 96372 - Laser Iridium™ Spark Plug',
#  'NGK® 95003 - Laser Iridium™ Spark Plug',
#  'NGK® 97319 - Laser Iridium™ Spark Plug',
#  'NGK® - Laser Platinum™ Spark Plug',
#  'NGK® 94697 - Laser Iridium™ Spark Plug',
#  'NGK® 1406 - Laser Iridium™ Spark Plug',
#  'NGK® 90074 - Laser Iridium™ Spark Plug',
#  'NGK® 9029 - Laser Iridium™ Spark Plug',
#  'NGK® 91215 - Laser Iridium™ Spark Plug',
#  'NGK® 91448 - Laser Iridium™ Spark Plug',
#  'NGK® 92491 - Laser Iridium™ Spark Plug',
#  'NGK® 92924 - Laser Iridium™ Spark Plug',
#  'NGK® 93135 - Laser Iridium™ Spark Plug',
#  'NGK® 93482 - Laser Iridium™ Spark Plug',
#  'NGK® 94167 - Laser Iridium™ Spark Plug',
#  'NGK® 95710 - Laser Iridium™ Spark Plug',
#  'NGK® 98376 - Laser Iridium™ Spark Plug',
#  'NGK® 6176 - Laser Iridium™ Spark Plug',
#  'NGK® 96957 - Laser Iridium™ Spark Plug',
#  'NGK® 127 - Laser Iridium™ Spark Plug',
#  'NGK® 373 - Laser Iridium™ Spark Plug',
#  'NGK® 7505 - Laser Iridium™ Spark Plug',
#  'NGK® 97506 - Laser Iridium™ Spark Plug',
#  'NGK® 90137 - Laser Iridium™ Spark Plug',
#  'NGK® 95350 - Laser Iridium™ Spark Plug',
#  'NGK® 95264 - Laser Iridium™ Spark Plug',
#  'NGK® 1312 - Laser Iridium™ Spark Plug',
#  'NGK® 1311 - Laser Iridium™ Spark Plug',
#  'NGK® 96964 - Laser Iridium™ Spark Plug',
#  'NGK® 90935 - Laser Iridium™ Spark Plug',
#  'NGK® 94702 - Laser Iridium™ Spark Plug',
#  'NGK® 94201 - Laser Iridium™ Spark Plug',
#  'NGK® 92217 - Laser Iridium™ Spark Plug',
#  'NGK® 93199 - Laser Iridium™ Spark Plug',
#  'NGK® 90565 - Laser Iridium™ Spark Plug']

# %%
list_url = ['https://www.carid.com' + part.xpath('./@data-url')[0].strip() for part in list_part]

list_url
# Out:
# ['https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96698.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96698.html?singleid=5087889357',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6700.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6701.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91112.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1555.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95248.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93026.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90911.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90911.html?singleid=5087850343',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97218.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92605.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94731.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91874.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96372.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95003.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97319.html',
#  'https://www.carid.com/ngk/laser-platinum-spark-plug.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94697.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1406.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90074.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-9029.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91215.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-91448.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92491.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92924.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93135.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93482.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94167.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95710.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-98376.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-6176.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96957.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-127.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-373.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-7505.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-97506.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90137.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95350.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-95264.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1312.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-1311.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-96964.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90935.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94702.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-94201.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-92217.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-93199.html',
#  'https://www.carid.com/ngk/laser-iridium-spark-plug-mpn-90565.html']

# %%
list_src = [part.xpath('./@data-src')[0].strip() for part in list_part]

list_src
# Out:
# ['https://ic.carid.com/ngk/items/96698_6.jpg',
#  'https://ic.carid.com/ngk/items/96698_6.jpg',
#  'https://ic.carid.com/ngk/items/6700_6.jpg',
#  'https://ic.carid.com/ngk/items/6701_6.jpg',
#  'https://ic.carid.com/ngk/items/hero-ngk-laser-iridium-2_6.jpg',
#  'https://ic.carid.com/ngk/items/91112_6.jpg',
#  'https://ic.carid.com/ngk/items/1555_6.jpg',
#  'https://ic.carid.com/ngk/items/95248_6.jpg',
#  'https://ic.carid.com/ngk/items/93026_6.jpg',
#  'https://ic.carid.com/ngk/items/90911_6.jpg',
#  'https://ic.carid.com/ngk/items/90911_6.jpg',
#  'https://ic.carid.com/ngk/items/97218_6.jpg',
#  'https://ic.carid.com/ngk/items/92605_6.jpg',
#  'https://ic.carid.com/ngk/items/94731_6.jpg',
#  'https://ic.carid.com/ngk/items/91874_6.jpg',
#  'https://ic.carid.com/ngk/items/96372_6.jpg',
#  'https://ic.carid.com/ngk/items/95003_6.jpg',
#  'https://ic.carid.com/ngk/items/97319_6.jpg',
#  'https://ic.carid.com/ngk/ignition-spark-plugs-wires/laser-platinum-spark-plug-box_6.jpg',
#  'https://ic.carid.com/ngk/items/94697_6.jpg',
#  'https://ic.carid.com/ngk/items/1406_6.jpg',
#  'https://ic.carid.com/ngk/items/90074_6.jpg',
#  'https://ic.carid.com/ngk/items/9029_6.jpg',
#  'https://ic.carid.com/ngk/items/91215_6.jpg',
#  'https://ic.carid.com/ngk/items/91448_6.jpg',
#  'https://ic.carid.com/ngk/items/92491_6.jpg',
#  'https://ic.carid.com/ngk/items/92924_6.jpg',
#  'https://ic.carid.com/ngk/items/93135_6.jpg',
#  'https://ic.carid.com/ngk/items/93482_6.jpg',
#  'https://ic.carid.com/ngk/items/94167_6.jpg',
#  'https://ic.carid.com/ngk/items/95710_6.jpg',
#  'https://ic.carid.com/ngk/items/98376_6.jpg',
#  'https://ic.carid.com/ngk/items/6176_6.jpg',
#  'https://ic.carid.com/ngk/items/96957_6.jpg',
#  'https://ic.carid.com/ngk/items/127_6.jpg',
#  'https://ic.carid.com/ngk/items/373_6.jpg',
#  'https://ic.carid.com/ngk/items/7505_6.jpg',
#  'https://ic.carid.com/ngk/items/97506_6.jpg',
#  'https://ic.carid.com/ngk/items/90137_6.jpg',
#  'https://ic.carid.com/ngk/items/95350_6.jpg',
#  'https://ic.carid.com/ngk/items/95264_6.jpg',
#  'https://ic.carid.com/ngk/items/1312_6.jpg',
#  'https://ic.carid.com/ngk/items/1311_6.jpg',
#  'https://ic.carid.com/ngk/items/96964_6.jpg',
#  'https://ic.carid.com/ngk/items/90935_6.jpg',
#  'https://ic.carid.com/ngk/items/94702_6.jpg',
#  'https://ic.carid.com/ngk/items/94201_6.jpg',
#  'https://ic.carid.com/ngk/items/92217_6.jpg',
#  'https://ic.carid.com/ngk/items/93199_6.jpg',
#  'https://ic.carid.com/ngk/items/90565_6.jpg']

# %%
df_temp = pd.DataFrame({'status': 'ok',
                        'Menu': url,
                        'Url': list_url,
                        'Sku': list_sku,
                        'Title': list_title,
                        'Src': list_src})

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#    status                                               Menu            Sku  \
# 0      ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4899600159
# 1      ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4899600159
# 2      ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802026
# 3      ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802027
# 4      ok  https://www.carid.com/search/NGK+Laser+Iridium...         sp5197
# 5      ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4899600100
# 6      ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1725555
# 7      ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4517138463
# 8      ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728609
# 9      ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4889528618
# 10     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4889528618
# 11     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728618
# 12     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890151396
# 13     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890157004
# 14     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4649055393
# 15     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4649055466
# 16     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4649055517
# 17     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4649055571
# 18     ok  https://www.carid.com/search/NGK+Laser+Iridium...         sp5198
# 19     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4792335284
# 20     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728572
# 21     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728603
# 22     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728604
# 23     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728605
# 24     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728606
# 25     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728607
# 26     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728608
# 27     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728611
# 28     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728612
# 29     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1728615
# 30     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1730069
# 31     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1800392
# 32     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802019
# 33     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802036
# 34     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802539
# 35     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802548
# 36     ok  https://www.carid.com/search/NGK+Laser+Iridium...     mpn1802575
# 37     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890151438
# 38     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890151531
# 39     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890151554
# 40     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn1890157005
# 41     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4063562616
# 42     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4063562901
# 43     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4063563136
# 44     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4063563469
# 45     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4517138420
# 46     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4517138434
# 47     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4524514814
# 48     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4629111097
# 49     ok  https://www.carid.com/search/NGK+Laser+Iridium...  mpn4649055425
#
#                                      Title  \
# 0   NGK® 96698 - Laser Iridium™ Spark Plug
# 1         NGK® - Laser Iridium™ Spark Plug
# 2    NGK® 6700 - Laser Iridium™ Spark Plug
# 3    NGK® 6701 - Laser Iridium™ Spark Plug
# 4         NGK® - Laser Iridium™ Spark Plug
# 5   NGK® 91112 - Laser Iridium™ Spark Plug
# 6    NGK® 1555 - Laser Iridium™ Spark Plug
# 7   NGK® 95248 - Laser Iridium™ Spark Plug
# 8   NGK® 93026 - Laser Iridium™ Spark Plug
# 9   NGK® 90911 - Laser Iridium™ Spark Plug
# 10        NGK® - Laser Iridium™ Spark Plug
# 11  NGK® 97218 - Laser Iridium™ Spark Plug
# 12  NGK® 92605 - Laser Iridium™ Spark Plug
# 13  NGK® 94731 - Laser Iridium™ Spark Plug
# 14  NGK® 91874 - Laser Iridium™ Spark Plug
# 15  NGK® 96372 - Laser Iridium™ Spark Plug
# 16  NGK® 95003 - Laser Iridium™ Spark Plug
# 17  NGK® 97319 - Laser Iridium™ Spark Plug
# 18       NGK® - Laser Platinum™ Spark Plug
# 19  NGK® 94697 - Laser Iridium™ Spark Plug
# 20   NGK® 1406 - Laser Iridium™ Spark Plug
# 21  NGK® 90074 - Laser Iridium™ Spark Plug
# 22   NGK® 9029 - Laser Iridium™ Spark Plug
# 23  NGK® 91215 - Laser Iridium™ Spark Plug
# 24  NGK® 91448 - Laser Iridium™ Spark Plug
# 25  NGK® 92491 - Laser Iridium™ Spark Plug
# 26  NGK® 92924 - Laser Iridium™ Spark Plug
# 27  NGK® 93135 - Laser Iridium™ Spark Plug
# 28  NGK® 93482 - Laser Iridium™ Spark Plug
# 29  NGK® 94167 - Laser Iridium™ Spark Plug
# 30  NGK® 95710 - Laser Iridium™ Spark Plug
# 31  NGK® 98376 - Laser Iridium™ Spark Plug
# 32   NGK® 6176 - Laser Iridium™ Spark Plug
# 33  NGK® 96957 - Laser Iridium™ Spark Plug
# 34    NGK® 127 - Laser Iridium™ Spark Plug
# 35    NGK® 373 - Laser Iridium™ Spark Plug
# 36   NGK® 7505 - Laser Iridium™ Spark Plug
# 37  NGK® 97506 - Laser Iridium™ Spark Plug
# 38  NGK® 90137 - Laser Iridium™ Spark Plug
# 39  NGK® 95350 - Laser Iridium™ Spark Plug
# 40  NGK® 95264 - Laser Iridium™ Spark Plug
# 41   NGK® 1312 - Laser Iridium™ Spark Plug
# 42   NGK® 1311 - Laser Iridium™ Spark Plug
# 43  NGK® 96964 - Laser Iridium™ Spark Plug
# 44  NGK® 90935 - Laser Iridium™ Spark Plug
# 45  NGK® 94702 - Laser Iridium™ Spark Plug
# 46  NGK® 94201 - Laser Iridium™ Spark Plug
# 47  NGK® 92217 - Laser Iridium™ Spark Plug
# 48  NGK® 93199 - Laser Iridium™ Spark Plug
# 49  NGK® 90565 - Laser Iridium™ Spark Plug
#
#                                                   Url  \
# 0   https://www.carid.com/ngk/laser-iridium-spark-...
# 1   https://www.carid.com/ngk/laser-iridium-spark-...
# 2   https://www.carid.com/ngk/laser-iridium-spark-...
# 3   https://www.carid.com/ngk/laser-iridium-spark-...
# 4   https://www.carid.com/ngk/laser-iridium-spark-...
# 5   https://www.carid.com/ngk/laser-iridium-spark-...
# 6   https://www.carid.com/ngk/laser-iridium-spark-...
# 7   https://www.carid.com/ngk/laser-iridium-spark-...
# 8   https://www.carid.com/ngk/laser-iridium-spark-...
# 9   https://www.carid.com/ngk/laser-iridium-spark-...
# 10  https://www.carid.com/ngk/laser-iridium-spark-...
# 11  https://www.carid.com/ngk/laser-iridium-spark-...
# 12  https://www.carid.com/ngk/laser-iridium-spark-...
# 13  https://www.carid.com/ngk/laser-iridium-spark-...
# 14  https://www.carid.com/ngk/laser-iridium-spark-...
# 15  https://www.carid.com/ngk/laser-iridium-spark-...
# 16  https://www.carid.com/ngk/laser-iridium-spark-...
# 17  https://www.carid.com/ngk/laser-iridium-spark-...
# 18  https://www.carid.com/ngk/laser-platinum-spark...
# 19  https://www.carid.com/ngk/laser-iridium-spark-...
# 20  https://www.carid.com/ngk/laser-iridium-spark-...
# 21  https://www.carid.com/ngk/laser-iridium-spark-...
# 22  https://www.carid.com/ngk/laser-iridium-spark-...
# 23  https://www.carid.com/ngk/laser-iridium-spark-...
# 24  https://www.carid.com/ngk/laser-iridium-spark-...
# 25  https://www.carid.com/ngk/laser-iridium-spark-...
# 26  https://www.carid.com/ngk/laser-iridium-spark-...
# 27  https://www.carid.com/ngk/laser-iridium-spark-...
# 28  https://www.carid.com/ngk/laser-iridium-spark-...
# 29  https://www.carid.com/ngk/laser-iridium-spark-...
# 30  https://www.carid.com/ngk/laser-iridium-spark-...
# 31  https://www.carid.com/ngk/laser-iridium-spark-...
# 32  https://www.carid.com/ngk/laser-iridium-spark-...
# 33  https://www.carid.com/ngk/laser-iridium-spark-...
# 34  https://www.carid.com/ngk/laser-iridium-spark-...
# 35  https://www.carid.com/ngk/laser-iridium-spark-...
# 36  https://www.carid.com/ngk/laser-iridium-spark-...
# 37  https://www.carid.com/ngk/laser-iridium-spark-...
# 38  https://www.carid.com/ngk/laser-iridium-spark-...
# 39  https://www.carid.com/ngk/laser-iridium-spark-...
# 40  https://www.carid.com/ngk/laser-iridium-spark-...
# 41  https://www.carid.com/ngk/laser-iridium-spark-...
# 42  https://www.carid.com/ngk/laser-iridium-spark-...
# 43  https://www.carid.com/ngk/laser-iridium-spark-...
# 44  https://www.carid.com/ngk/laser-iridium-spark-...
# 45  https://www.carid.com/ngk/laser-iridium-spark-...
# 46  https://www.carid.com/ngk/laser-iridium-spark-...
# 47  https://www.carid.com/ngk/laser-iridium-spark-...
# 48  https://www.carid.com/ngk/laser-iridium-spark-...
# 49  https://www.carid.com/ngk/laser-iridium-spark-...
#
#                                                   Src
# 0          https://ic.carid.com/ngk/items/96698_6.jpg
# 1          https://ic.carid.com/ngk/items/96698_6.jpg
# 2           https://ic.carid.com/ngk/items/6700_6.jpg
# 3           https://ic.carid.com/ngk/items/6701_6.jpg
# 4   https://ic.carid.com/ngk/items/hero-ngk-laser-...
# 5          https://ic.carid.com/ngk/items/91112_6.jpg
# 6           https://ic.carid.com/ngk/items/1555_6.jpg
# 7          https://ic.carid.com/ngk/items/95248_6.jpg
# 8          https://ic.carid.com/ngk/items/93026_6.jpg
# 9          https://ic.carid.com/ngk/items/90911_6.jpg
# 10         https://ic.carid.com/ngk/items/90911_6.jpg
# 11         https://ic.carid.com/ngk/items/97218_6.jpg
# 12         https://ic.carid.com/ngk/items/92605_6.jpg
# 13         https://ic.carid.com/ngk/items/94731_6.jpg
# 14         https://ic.carid.com/ngk/items/91874_6.jpg
# 15         https://ic.carid.com/ngk/items/96372_6.jpg
# 16         https://ic.carid.com/ngk/items/95003_6.jpg
# 17         https://ic.carid.com/ngk/items/97319_6.jpg
# 18  https://ic.carid.com/ngk/ignition-spark-plugs-...
# 19         https://ic.carid.com/ngk/items/94697_6.jpg
# 20          https://ic.carid.com/ngk/items/1406_6.jpg
# 21         https://ic.carid.com/ngk/items/90074_6.jpg
# 22          https://ic.carid.com/ngk/items/9029_6.jpg
# 23         https://ic.carid.com/ngk/items/91215_6.jpg
# 24         https://ic.carid.com/ngk/items/91448_6.jpg
# 25         https://ic.carid.com/ngk/items/92491_6.jpg
# 26         https://ic.carid.com/ngk/items/92924_6.jpg
# 27         https://ic.carid.com/ngk/items/93135_6.jpg
# 28         https://ic.carid.com/ngk/items/93482_6.jpg
# 29         https://ic.carid.com/ngk/items/94167_6.jpg
# 30         https://ic.carid.com/ngk/items/95710_6.jpg
# 31         https://ic.carid.com/ngk/items/98376_6.jpg
# 32          https://ic.carid.com/ngk/items/6176_6.jpg
# 33         https://ic.carid.com/ngk/items/96957_6.jpg
# 34           https://ic.carid.com/ngk/items/127_6.jpg
# 35           https://ic.carid.com/ngk/items/373_6.jpg
# 36          https://ic.carid.com/ngk/items/7505_6.jpg
# 37         https://ic.carid.com/ngk/items/97506_6.jpg
# 38         https://ic.carid.com/ngk/items/90137_6.jpg
# 39         https://ic.carid.com/ngk/items/95350_6.jpg
# 40         https://ic.carid.com/ngk/items/95264_6.jpg
# 41          https://ic.carid.com/ngk/items/1312_6.jpg
# 42          https://ic.carid.com/ngk/items/1311_6.jpg
# 43         https://ic.carid.com/ngk/items/96964_6.jpg
# 44         https://ic.carid.com/ngk/items/90935_6.jpg
# 45         https://ic.carid.com/ngk/items/94702_6.jpg
# 46         https://ic.carid.com/ngk/items/94201_6.jpg
# 47         https://ic.carid.com/ngk/items/92217_6.jpg
# 48         https://ic.carid.com/ngk/items/93199_6.jpg
# 49         https://ic.carid.com/ngk/items/90565_6.jpg
