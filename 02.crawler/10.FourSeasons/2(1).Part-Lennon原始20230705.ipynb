#  '20190',
#  '20191',
#  '20193',
#  '20194',
#  '20195',
#  '20196',
#  '20198',
#  '20199',
#  '20200',
#  '20201',
#  '20202',
#  '20204',
#  '20205',
#  '20206',
#  '20207',
#  '20208',
#  '20209',
#  '20210',
#  '20211',
#  '20213',
#  '20214',
#  '20215',
#  '20216',
#  '20217',
#  '20218',
#  '20219',
#  '20220',
#  '20221',
#  '20222',
#  '20223',
#  '20224',
#  '20227',
#  '20228',
#  '20230',
#  '20231',
#  '20232',
#  '20236',
#  '20237',
#  '20238',
#  '20239',
#  '20240',
#  '20241',
#  '20242',
#  '20243',
#  '20244',
#  '20246',
#  '20247',
#  '20248',
#  '20249',
#  '20252',
#  '20254',
#  '20256',
#  '20257',
#  '20258',
#  '20260',
#  '20261',
#  '20262',
#  '20263',
#  '20264',
#  '20265',
#  '20266',
#  '20267',
#  '20268',
#  '20269',
#  '20270',
#  '20272',
#  '20273',
#  '20274',
#  '20275',
#  '20276',
#  '20277',
#  '20278',
#  '20279',
#  '20280',
#  '20283',
#  '20284',
#  '20285',
#  '20286',
#  '20287',
#  '20288',
#  '20289',
#  '20292',
#  '20293',
#  '75167',
#  '75168',
#  '75169',
#  '75219',
#  '75700',
#  '75701',
#  '75705',
#  '75706',
#  '75707',
#  '75710',
#  '75712',
#  '75712BRK1',
#  '75713',
#  '75714',
#  '75735',
#  '75735BRK1',
#  '75735BRK2',
#  '75735BRK3',
#  '75735BRK4',
#  '75735BRK5',
#  '75736',
#  '75737',
#  '75738',
#  '75739',
#  '75739BRK1',
#  '75739BRK2',
#  '75739BRK3',
#  '75740',
#  '75740BRK1',
#  '75741',
#  '75742',
#  '75743',
#  '75743BRK1',
#  '75743BRK2',
#  '75743BRK3',
#  '75743BRK4',
#  '75744',
#  '75744BRK1',
#  '75748',
#  '75748BRK1',
#  '75748BRK2',
#  '75748BRK3',
#  '75748BRK4',
#  '75748BRK5',
#  '75749',
#  '75749BRK1',
#  '75749BRK2',
#  '75753',
#  '75753BRK1',
#  ...]

# %%
df = pd.DataFrame(columns=['Part_Number',
                           'Part_Type',
                           'POP',
                           'Per_Car',
                           'Vehicle',
                           'Src',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [Part_Number, Part_Type, POP, Per_Car, Vehicle, Src, status]
# Index: []

# %%
import requests
import json

# %%
i = 0

resp = requests.get('https://ecatalog.smpcorp.com/v2/fs/api/part/partselect?part=' + list_part_number[i] + '&func=PART').text
info = json.loads(resp)

info
# Out:
# {'pd': {'rowId': 1,
#   'site': 'FS',
#   'webBase': '20412',
#   'brand': 'FS',
#   'basePart': '20412',
#   'partDesc_en': 'HVAC Blower Motor Resistor',
#   'partLongDesc_en': 'HVAC Blower Motor Resistor',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 1,
#   'brandLink': None,
#   'imageUrl': None},
#  'pp': {'buyersGuides': [{'basePart': '20412',
#     'buyersGuideId': 6998,
#     'buyersGuideDesc': 'Ford Expedition (06)'},
#    {'basePart': '20412',
#     'buyersGuideId': 14377,
#     'buyersGuideDesc': 'Lincoln Navigator (06)'}],
#   'partSpecs': [{'attributeCode': '1063',
#     'attributeValue': 5483,
#     'attributeSort': 0,
#     'attributeName_en': 'Speed',
#     'siteValue_en': 'Variable'},
#    {'attributeCode': '116',
#     'attributeValue': 29190,
#     'attributeSort': 0,
#     'attributeName_en': 'Description',
#     'siteValue_en': 'HVAC Blower Motor Resistor'},
#    {'attributeCode': '1215',
#     'attributeValue': 5362,
#     'attributeSort': 0,
#     'attributeName_en': 'Number of Terminals',
#     'siteValue_en': '5'},
#    {'attributeCode': '1452',
#     'attributeValue': 26845,
#     'attributeSort': 0,
#     'attributeName_en': 'Warranty',
#     'siteValue_en': '120 days'},
#    {'attributeCode': '571',
#     'attributeValue': 21254,
#     'attributeSort': 0,
#     'attributeName_en': 'Type',
#     'siteValue_en': 'Switches'},
#    {'attributeCode': '95',
#     'attributeValue': 3325,
#     'attributeSort': 0,
#     'attributeName_en': 'Connector Gender',
#     'siteValue_en': 'Female'},
#    {'attributeCode': '98',
#     'attributeValue': 16524,
#     'attributeSort': 0,
#     'attributeName_en': 'Connector Shape',
#     'siteValue_en': 'Square'}],
#   'imageUrls': [],
#   'relatedParts': [],
#   'relatedCategories': None,
#   'fandB': [{'basePart': '20412',
#     'fbId': '8177',
#     'fbDesc': 'Our products are engineered and tested to provide years of trouble free operation.  Backed by over 50 years of mobile a/c experience, fix it once and fix it right with Four Seasons.',
#     'taB_Type': 'F&B Heading',
#     'assetSort': 1,
#     'digiSort': 0},
#    {'basePart': '20412',
#     'fbId': '8059',
#     'fbDesc': 'Precision engineered',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 1},
#    {'basePart': '20412',
#     'fbId': '8033',
#     'fbDesc': 'OE style connectors',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 2},
#    {'basePart': '20412',
#     'fbId': '8084',
#     'fbDesc': 'Quality contacts ensure proper conductivity',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 3},
#    {'basePart': '20412',
#     'fbId': '8165',
#     'fbDesc': 'Vehicle specific applications',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 4}],
#   'digiAssests': [{'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'Impact of Airflow on HVAC Performance',
#     'fileURL': 'https://youtube.com/embed/l-dfJQONdy8',
#     'comment_ID': '138880',
#     'comment': 'Impact of Airflow on HVAC Performance',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'SMP Engineering',
#     'fileURL': 'http://youtube.com/embed/z33qr7b3MWU',
#     'comment_ID': '138882',
#     'comment': 'SMP Engineering',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'SMP Facilities',
#     'fileURL': 'https://youtube.com/embed/LMncDliQK_4',
#     'comment_ID': '138883',
#     'comment': 'SMP Facilities',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'SMP Facilities (Quick Tour)',
#     'fileURL': 'https://youtube.com/embed/mGxHhNBSvjA',
#     'comment_ID': '138884',
#     'comment': 'SMP Facilities (Quick Tour)',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'SMP Mobile Parts App 2.0',
#     'fileURL': 'https://youtube.com/embed/HaxUHLT0dfU',
#     'comment_ID': '138885',
#     'comment': 'SMP Mobile Parts App 2.0',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'Standard eCatalog Overview',
#     'fileURL': 'https://youtube.com/embed/k6gIp1HOx4Y',
#     'comment_ID': '138886',
#     'comment': 'Standard eCatalog Overview',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '20412',
#     'fileName': 'Temp Testing TXV System ',
#     'fileURL': 'https://youtube.com/embed/wF37ihNBXq8',
#     'comment_ID': '138887',
#     'comment': 'Temp Testing TXV System ',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None}],
#   'categories': [{'basePart': '20412',
#     'webLayout_ID': 28750,
#     'categoryName_en': 'Switches - HVAC',
#     'prodCategory_ASort': 28750}],
#   'crossRef': None,
#   'completeRepair': {'serviceParts': [],
#    'serviceSpec': [{'serviceName': 'Fuel Filter Flush (Required)'},
#     {'serviceName': 'Oil Change (Required)'}]}}}

# %%
part_type = info['pp']['categories'][0]['categoryName_en']

part_type
# Out:
# 'Switches - HVAC'

# %%
pop = info['pd']['pop']

pop
# Out:
# 'F'

# %%
per_car = info['pd']['qtyEach']

per_car
# Out:
# 1

# %%
list_vehicle = [vehicle['buyersGuideDesc'] for vehicle in info['pp']['buyersGuides']]
vehicle = '\n'.join(list_vehicle)

vehicle
# Out:
# 'Ford Expedition (06)\nLincoln Navigator (06)'

# %%
details = info['pp']['partSpecs']

details
# Out:
# [{'attributeCode': '1063',
#   'attributeValue': 5483,
#   'attributeSort': 0,
#   'attributeName_en': 'Speed',
#   'siteValue_en': 'Variable'},
#  {'attributeCode': '116',
#   'attributeValue': 29190,
#   'attributeSort': 0,
#   'attributeName_en': 'Description',
#   'siteValue_en': 'HVAC Blower Motor Resistor'},
#  {'attributeCode': '1215',
#   'attributeValue': 5362,
#   'attributeSort': 0,
#   'attributeName_en': 'Number of Terminals',
#   'siteValue_en': '5'},
#  {'attributeCode': '1452',
#   'attributeValue': 26845,
#   'attributeSort': 0,
#   'attributeName_en': 'Warranty',
#   'siteValue_en': '120 days'},
#  {'attributeCode': '571',
#   'attributeValue': 21254,
#   'attributeSort': 0,
#   'attributeName_en': 'Type',
#   'siteValue_en': 'Switches'},
#  {'attributeCode': '95',
#   'attributeValue': 3325,
#   'attributeSort': 0,
#   'attributeName_en': 'Connector Gender',
#   'siteValue_en': 'Female'},
#  {'attributeCode': '98',
#   'attributeValue': 16524,
#   'attributeSort': 0,
#   'attributeName_en': 'Connector Shape',
#   'siteValue_en': 'Square'}]

# %%
brand = info['pd']['brand']

brand
# Out:
# 'FS'

# %%
resp = requests.get('https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=' + list_part_number[i] + '&brand=' + brand + '&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960').text
info = json.loads(resp)

info
# Out:
# [{'image_Name': 'GNquRcjvWPEtnYaUb%2FVknQ%3D%3D',
#   'image_SM_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIWs34AmcG1EkFoZj0BakHNMJD5dLnjkb9rm+ZHodTWPuhIKBw3J5SZ5iH9+8ykTJFSKEulrQ0hiWTskhDbDVIOt4K7Mm/YEv3m/CH1/uYPCgXGfdCmo4YlLSCFlglY/QZpt4RQN/T7EoXFyowQKL2g5S3zmc03ZMv',
#   'image_MD_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIBku710yGpH9HHkrtZeXWjKAcgdOg+aAVbEHUQlckYE7y916PDj4mUplpjLqJxiUyNc0Dfr4BAXPekNlQ51Q7yIznwcghdmhavbavYiSVAdwf+9wZqa98qnqcU69cfa9JW0Q+GvOWjS7l7Ga/gIGN4exDDtSObvr3',
#   'image_BG_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuSYF4nkLByFFki+PA/U85obiEfOLNXyVIe72HZkm08flMYvVb8ruU/a2jlDyZ/9SFhHKSDnV/vfUm++2cf2MyJSTHiO+uZMQDMRJmK/E5kGqgMS+q/NNn547DcAIwETg03OoQkqY8OevuJ2sZvj1t3xQ2ulDEJPZWA=='},
#  {'image_Name': 'Ro53CBsKWXyTz1QuT6fmbg%3D%3D',
#   'image_SM_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIWs34AmcG1EkFoZj0BakHNIri6IkYnb/57Pdlud9TngDOnVUip04BiJTs5tLYVtf0Jv0YyvK/rWdJmHQGKl7o+TW7k1Hj4TTuy5K/cNQbQ1spu2svsSDQ4m5fEIOJJ1pB+jZTZrF2GBUifp8ttT7vAAzSuS1O8b1wDAHjgKRqmAc=',
#   'image_MD_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIBku710yGpH9HHkrtZeXWjOgVQdcXLrZurm+ZHodTWPuhIKBw3J5SZ5iH9+8ykTJFSKEulrQ0hiWTskhDbDVIOt4K7Mm/YEv3m/CH1/uYPCgXGfdCmo4YlLSCFlglY/QZpt4RQN/T7EoXFyowQKL2g5S3zmc03ZMv',
#   'image_BG_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuSYF4nkLByFFki+PA/U85obvbJiOkNz8zpIGP8XlP8xfMoN++3vibKFGVC+8Va8jLaI8gQqRXhksVqg+QadFzZ6AfnnMwvAWvxs/HBA23UPYMJi1dAphBIcr+m7fx4OW9NZDtUzqjDnt8/8XMJE0Syuiu9+DXJMMbohJb67kWwLn'},
#  {'image_Name': '%2F4wMlZ6Y%2FMCN8YSbv4X2iA%3D%3D',
#   'image_SM_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIWs34AmcG1EkFoZj0BakHNAiZP91imWjOIlscbECxd3wyg377e+JsoUZUL7xVryMtojyBCpFeGSxWqD5Bp0XNnoB+eczC8Ba/Gz8cEDbdQ9gwmLV0CmEEhyv6bt/Hg5b01kO1TOqMOe3z/xcwkTRLK6K734NckwxuiElvruRbAuc=',
#   'image_MD_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuT9FNpDfGKFIBku710yGpH9HHkrtZeXWjCzlazkwN+nf7vYdmSbTx+Uxi9Vvyu5T9raOUPJn/1IWEcpIOdX+99Sb77Zx/YzIlJMeI765kxAMxEmYr8TmQaqAxL6r802fnjsNwAjARODTc6hCSpjw56+4naxm+PW3fFDa6UMQk9lY',
#   'image_BG_Url': 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuSYF4nkLByFFki+PA/U85oYFWyv20R+TWFpxkq7DAci8bEHUQlckYE7y916PDj4mUplpjLqJxiUyNc0Dfr4BAXPekNlQ51Q7yIznwcghdmhavbavYiSVAdwf+9wZqa98qnqcU69cfa9JW0Q+GvOWjS7l7Ga/gIGN4exDDtSObvr3'}]

# %%
if len(info) == 0:
    src = ''
else:
    src = info[0]['image_BG_Url']

src
# Out:
# 'https://extapi.smpcorp.com/ihgs/imagehandlergs.ashx?p1=g2pkQFK7GCEe31etH9unuSYF4nkLByFFki+PA/U85obiEfOLNXyVIe72HZkm08flMYvVb8ruU/a2jlDyZ/9SFhHKSDnV/vfUm++2cf2MyJSTHiO+uZMQDMRJmK/E5kGqgMS+q/NNn547DcAIwETg03OoQkqY8OevuJ2sZvj1t3xQ2ulDEJPZWA=='

# %%
df_temp = pd.DataFrame([{'Part_Number': list_part_number[i],
                         'Part_Type': part_type,
                         'POP': pop,
                         'Per_Car': per_car,
                         'Vehicle': vehicle,
                         'Src': src,
                         'status': 'ok'}])

df_temp
# Out:
#   Part_Number        Part_Type POP  Per_Car  \
# 0       20412  Switches - HVAC   F        1
#
#                                         Vehicle  \
# 0  Ford Expedition (06)\nLincoln Navigator (06)
#
#                                                  Src status
# 0  https://extapi.smpcorp.com/ihgs/imagehandlergs...     ok

# %%
for name_value in details:
    df_temp[name_value['attributeName_en'].lower()] = name_value['siteValue_en']
    
df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   Part_Number        Part_Type POP  Per_Car  \
# 0       20412  Switches - HVAC   F        1
#
#                                         Vehicle  \
# 0  Ford Expedition (06)\nLincoln Navigator (06)
#
#                                                  Src status     speed  \
# 0  https://extapi.smpcorp.com/ihgs/imagehandlergs...     ok  Variable
#
#                   description number of terminals  warranty      type  \
# 0  HVAC Blower Motor Resistor                   5  120 days  Switches
#
#   connector gender connector shape
# 0           Female          Square
