# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../00.module')
import Proxy

# = = = = = = = = = = = = = = =

from openpyxl import load_workbook

wb = load_workbook('./crawler.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        src_index = column
    elif ws.cell(1, column).value == 'Pic':
        pic_index = column
        
print('Src索引：' + str(src_index))
print('Pic索引：' + str(pic_index))
print()

# = = = = = = = = = = = = = = =

import requests
from io import BytesIO
import PIL
from openpyxl.drawing import image

# = = = = = = = = = = = = = = =

from openpyxl.utils import get_column_letter

# = = = = = = = = = = = = = = =

import time

# = = = = = = = = = = = = = = =

work = Queue()
for row in range(2, ws.max_row+1):
    work.put_nowait(row)

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        
        # = = = = = = = = = = = = = = = = = =
        
        src = ws.cell(row, src_index).value
        
        # = = = = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(11):
            if src == None or src == '':
                break
            
            try:
                pic = PIL.Image.open(BytesIO(requests.get(src, proxies=Proxy.get_Proxy_Requests()).content)).convert('RGB')
                pic.save('./pic/' + str(row) + '.png', 'png')
                pic = image.Image('./pic/' + str(row) + '.png')
                
                # = = = = = = = = = = = = = = = = = =
                
                if pic.width >= pic.height:
                    pic.height = 50.0 / pic.width * pic.height
                    pic.width = 50.0
                else:
                    pic.width = 50.0 / pic.height * pic.width
                    pic.height = 50.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                ws.add_image(pic, get_column_letter(pic_index) + str(row))
                
                status = 'ok'
                
                break
                
            except:
                time.sleep(3)
                continue
                
        # = = = = = = = = = = = = = = = = = =
        
        if src != None and src != '':
            print(src +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print()
print('爬虫输出中')
wb.save('./crawler-pic.xlsx')
print()
print('爬虫结束')
# Out:
# Src索引：15
# Pic索引：13
#
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：47
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：46
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：45
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：44
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：43
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：42
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：41
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：40
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：39
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：38
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：37
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：36
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：35
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：34
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：33
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：32
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：31
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：30
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：29
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_.jpg  <->  [ok] - 剩余数量：28
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：27
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：26
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：25
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：24
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：23
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：22
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：21
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：20
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：19
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：18
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：17
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：16
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：15
# https://m.media-amazon.com/images/I/61eoPK6soZL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：14
# https://m.media-amazon.com/images/I/513Auf5IrnL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：13
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：12
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：11
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：10
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：9
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：8
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：7
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：6
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：5
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：4
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：3
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：2
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：1
# https://m.media-amazon.com/images/I/513Auf5IrnL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：0
#
# 爬虫输出中
#
# 爬虫结束
# D:\venv\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
