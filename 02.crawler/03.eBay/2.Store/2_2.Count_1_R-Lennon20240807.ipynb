# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./1.category.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Url'] = [url_1 if url_2 == '-' else url_2 for url_1, url_2 in zip(input_['1st Category Url'].tolist(), input_['2nd Category Url'].tolist())]

input_['1st Category No'] = input_['1st Category No'].astype(int)
input_['2nd Category No'] = ['-' if _ == '-' else int(_) for _ in input_['2nd Category No'].tolist()]

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        try:
            b = 0
            while True:
                b += 1

                try:
                    resp = requests.get(input_.loc[a, 'Url'],
                                        headers=get_header(ua=False),
                                        proxies=get_proxy(),
                                        timeout=(10, 10))

                    if resp.status_code == 200:
                        break
                except:
                    continue

            # = = = = = = = = = = = = = = =

            soup = BeautifulSoup(resp.text, 'lxml')
            html = etree.HTML(str(soup))

            # = = = = = = = = = = = = = = =

            count = int(html.xpath('//h1[@class="srp-controls__count-heading"]/text()')[0].strip().removesuffix('result').removesuffix('results').strip().removesuffix('+').replace(',', '').replace('.', ''))

            # = = = = = = = = = = = = = = =

            df_temp = pd.DataFrame([{'1st Category No': input_.loc[a, '1st Category No'],
                                     '1st Category Type': input_.loc[a, '1st Category Type'],
                                     '1st Category': input_.loc[a, '1st Category'],
                                     '1st Category Url': input_.loc[a, '1st Category Url'],
                                     '2nd Category No': input_.loc[a, '2nd Category No'],
                                     '2nd Category Type': input_.loc[a, '2nd Category Type'],
                                     '2nd Category': input_.loc[a, '2nd Category'],
                                     '2nd Category Url': input_.loc[a, '2nd Category Url'],
                                     'SKU Count': count,
                                     'Overlimit': False if count < 10_000 else True}])
            
            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            df_temp = pd.DataFrame([{'1st Category No': input_.loc[a, '1st Category No'],
                                     '1st Category Type': input_.loc[a, '1st Category Type'],
                                     '1st Category': input_.loc[a, '1st Category'],
                                     '1st Category Url': input_.loc[a, '1st Category Url'],
                                     '2nd Category No': input_.loc[a, '2nd Category No'],
                                     '2nd Category Type': input_.loc[a, '2nd Category Type'],
                                     '2nd Category': input_.loc[a, '2nd Category'],
                                     '2nd Category Url': input_.loc[a, '2nd Category Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b}] - {input_.loc[a, '1st Category No']}.{input_.loc[a, '1st Category']} > {input_.loc[a, '2nd Category No']}.{input_.loc[a, '2nd Category']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(30):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['1st Category No', '2nd Category No'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./2.count_1-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['1st Category No', '2nd Category No'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel('./count_1_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：180
#
# [状态：ok，尝试次数：1] - 1.Lighting > 17.LED Lights
# [剩余数量：150] - [当前时间：20:52:52]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 12.Headlight Retainer
# [剩余数量：149] - [当前时间：20:52:53]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 10.Lighting
# [剩余数量：148] - [当前时间：20:52:54]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 8.Bumper End
# [剩余数量：147] - [当前时间：20:52:56]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 15.Wiring Harness
# [剩余数量：146] - [当前时间：20:52:56]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 16.Headlight Adjust Screw
# [剩余数量：145] - [当前时间：20:52:56]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 9.Tail Light Lens
# [剩余数量：144] - [当前时间：20:52:56]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 13.Headlight Filler
# [剩余数量：143] - [当前时间：20:52:58]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 4.Bumper Filler
# [剩余数量：142] - [当前时间：20:53:01]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 18.Third Brake Light
# [剩余数量：141] - [当前时间：20:53:02]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 11.Back-Up Light Assembly
# [剩余数量：140] - [当前时间：20:53:03]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 7.Park Light Assembly
# [剩余数量：139] - [当前时间：20:53:04]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 5.Turn Signal Assembly
# [剩余数量：138] - [当前时间：20:53:07]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 12.Bumper Retainer
# [剩余数量：137] - [当前时间：20:53:08]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 4.Side Marker Assembly
# [剩余数量：136] - [当前时间：20:53:08]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 10.Bumper Absorber
# [剩余数量：135] - [当前时间：20:53:09]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 2.Bumper Bracket
# [剩余数量：134] - [当前时间：20:53:09]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 2.Tail Light Assembly
# [剩余数量：133] - [当前时间：20:53:10]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 8.Headlight Housing
# [剩余数量：132] - [当前时间：20:53:11]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 5.Bumper Reinforcement
# [剩余数量：131] - [当前时间：20:53:11]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 1.Headlight Assembly
# [剩余数量：130] - [当前时间：20:53:12]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 6.Fog Light
# [剩余数量：129] - [当前时间：20:53:12]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 3.Cornering Light
# [剩余数量：128] - [当前时间：20:53:13]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 6.Lower Valance
# [剩余数量：127] - [当前时间：20:53:14]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 3.Bumper Trim
# [剩余数量：126] - [当前时间：20:53:14]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 7.Bumper Cover
# [剩余数量：125] - [当前时间：20:53:15]
#
# [状态：ok，尝试次数：1] - 1.Lighting > 14.Others
# [剩余数量：124] - [当前时间：20:53:16]
#
# [状态：ok，尝试次数：1] - 2.Bumpers > 11.Bumper Accessories
# [剩余数量：123] - [当前时间：20:53:17]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 8.Quarter Panel Molding
# [剩余数量：122] - [当前时间：20:53:18]
#
# [状态：ok，尝试次数：40] - 3.Exhaust > 6.Exhaust Tip
# [剩余数量：121] - [当前时间：20:53:19]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 5.Mud Flap
# [剩余数量：120] - [当前时间：20:53:20]
#
# [状态：ok，尝试次数：29] - 3.Exhaust > 8.Exhaust Pipe
# [剩余数量：119] - [当前时间：20:53:20]
#
# [状态：ok，尝试次数：1] - 3.Exhaust > 10.Intake Manifold
# [剩余数量：118] - [当前时间：20:53:21]
#
# [状态：ok，尝试次数：93] - 2.Bumpers > 16.Others
# [剩余数量：117] - [当前时间：20:53:21]
#
# [状态：ok，尝试次数：94] - 3.Exhaust > 3.Muffler
# [剩余数量：116] - [当前时间：20:53:22]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 4.Wheelhouse
# [剩余数量：115] - [当前时间：20:53:23]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 7.Quarter Panel Extension
# [剩余数量：114] - [当前时间：20:53:23]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 6.Quarter Panel
# [剩余数量：113] - [当前时间：20:53:23]
#
# [状态：ok，尝试次数：53] - 3.Exhaust > 5.Exhaust Systems
# [剩余数量：112] - [当前时间：20:53:26]
#
# [状态：ok，尝试次数：32] - 3.Exhaust > 7.Header
# [剩余数量：111] - [当前时间：20:53:26]
#
# [状态：ok，尝试次数：1] - 6.Grilles > 4.Header Panel
# [剩余数量：110] - [当前时间：20:53:27]
#
# [状态：ok，尝试次数：92] - 3.Exhaust > 2.Exhaust Manifold
# [剩余数量：109] - [当前时间：20:53:29]
#
# [状态：ok，尝试次数：1] - 3.Exhaust > 9.Others
# [剩余数量：108] - [当前时间：20:53:32]
#
# [状态：ok，尝试次数：1] - 6.Grilles > 2.Headlight Door
# [剩余数量：107] - [当前时间：20:53:32]
#
# [状态：ok，尝试次数：127] - 2.Bumpers > 13.Step Bumper
# [剩余数量：106] - [当前时间：20:53:33]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 3.Fender Molding
# [剩余数量：105] - [当前时间：20:53:33]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 2.Splash Shield
# [剩余数量：104] - [当前时间：20:53:34]
#
# [状态：ok，尝试次数：1] - 4.Mirrors > 1.Mirror
# [剩余数量：103] - [当前时间：20:53:35]
#
# [状态：ok，尝试次数：119] - 2.Bumpers > 14.License Plate Bracket
# [剩余数量：102] - [当前时间：20:53:35]
#
# [状态：ok，尝试次数：74] - 3.Exhaust > 4.Catalytic Converters
# [剩余数量：101] - [当前时间：20:53:36]
#
# [状态：ok，尝试次数：1] - 6.Grilles > 1.Grille Assembly
# [剩余数量：100] - [当前时间：20:53:37]
#
# [状态：ok，尝试次数：57] - 2.Bumpers > 9.Bumper Grille
# [剩余数量：99] - [当前时间：20:53:37]
#
# [状态：ok，尝试次数：1] - 4.Mirrors > 2.Mirror Glass
# [剩余数量：98] - [当前时间：20:53:38]
#
# [状态：ok，尝试次数：1] - 5.Fenders > 1.Fender
# [剩余数量：97] - [当前时间：20:53:38]
#
# [状态：ok，尝试次数：1] - 6.Grilles > 3.Grille Molding
# [剩余数量：96] - [当前时间：20:53:40]
#
# [状态：ok，尝试次数：95] - 3.Exhaust > 1.Oxygen Sensor
# [剩余数量：95] - [当前时间：20:53:40]
#
# [状态：ok，尝试次数：66] - 8.Radiators > 4.Fan Blade
# [剩余数量：94] - [当前时间：20:53:42]
#
# [状态：ok，尝试次数：91] - 6.Grilles > 7.Grille Guard
# [剩余数量：93] - [当前时间：20:53:43]
#
# [状态：ok，尝试次数：100] - 6.Grilles > 6.Nose Panel
# [剩余数量：92] - [当前时间：20:53:43]
#
# [状态：ok，尝试次数：79] - 8.Radiators > 2.Fan Shroud
# [剩余数量：91] - [当前时间：20:53:44]
#
# [状态：ok，尝试次数：1] - 11.Air Intake > 2.Cold Air Intake
# [剩余数量：90] - [当前时间：20:53:44]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 2.Harmonic Balancer
# [剩余数量：89] - [当前时间：20:53:44]
#
# [状态：ok，尝试次数：65] - 8.Radiators > 5.Expansion Tank
# [剩余数量：88] - [当前时间：20:53:45]
#
# [状态：ok，尝试次数：36] - 9.Door Handles > 1.Door Handle
# [剩余数量：87] - [当前时间：20:53:46]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 5.Flywheel
# [剩余数量：86] - [当前时间：20:53:47]
#
# [状态：ok，尝试次数：1] - 10.Hoods > 4.Hood Molding
# [剩余数量：85] - [当前时间：20:53:47]
#
# [状态：ok，尝试次数：103] - 6.Grilles > 5.Grille Bracket
# [剩余数量：84] - [当前时间：20:53:47]
#
# [状态：ok，尝试次数：16] - 9.Door Handles > 2.Door Handle Trim
# [剩余数量：83] - [当前时间：20:53:48]
#
# [状态：ok，尝试次数：40] - 8.Radiators > 8.Heater Hose
# [剩余数量：82] - [当前时间：20:53:49]
#
# [状态：ok，尝试次数：44] - 8.Radiators > 7.Fan Motor
# [剩余数量：81] - [当前时间：20:53:49]
#
# [状态：ok，尝试次数：63] - 8.Radiators > 6.Radiator Hose
# [剩余数量：80] - [当前时间：20:53:52]
#
# [状态：ok，尝试次数：1] - 10.Hoods > 5.Others
# [剩余数量：79] - [当前时间：20:53:53]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 6.Valve Cover
# [剩余数量：78] - [当前时间：20:53:54]
#
# [状态：ok，尝试次数：2] - 10.Hoods > 1.Hood
# [剩余数量：77] - [当前时间：20:53:54]
#
# [状态：ok，尝试次数：86] - 8.Radiators > 1.Radiator
# [剩余数量：76] - [当前时间：20:53:56]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 4.Oil Pan
# [剩余数量：75] - [当前时间：20:53:56]
#
# [状态：ok，尝试次数：112] - 2.Bumpers > 15.Bumper Step Pad
# [剩余数量：74] - [当前时间：20:53:56]
#
# [状态：ok，尝试次数：2] - 10.Hoods > 2.Hood Hinge
# [剩余数量：73] - [当前时间：20:53:57]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 7.Mount
# [剩余数量：72] - [当前时间：20:53:57]
#
# [状态：ok，尝试次数：1] - 11.Air Intake > 1.Air Filter
# [剩余数量：71] - [当前时间：20:53:58]
#
# [状态：ok，尝试次数：1] - 12.Engine & Transmission > 3.Others
# [剩余数量：70] - [当前时间：20:53:59]
#
# [状态：ok，尝试次数：70] - 8.Radiators > 3.Cooling System & Radiators
# [剩余数量：69] - [当前时间：20:53:59]
#
# [状态：ok，尝试次数：95] - 7.Related Items > -.-
# [剩余数量：68] - [当前时间：20:54:00]
#
# [状态：ok，尝试次数：69] - 12.Engine & Transmission > 12.Sub Frame
# [剩余数量：67] - [当前时间：20:54:02]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 4.Bedside Molding
# [剩余数量：66] - [当前时间：20:54:02]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 7.Tailgate Lock
# [剩余数量：65] - [当前时间：20:54:03]
#
# [状态：ok，尝试次数：70] - 12.Engine & Transmission > 9.Timing Belt Cover
# [剩余数量：64] - [当前时间：20:54:03]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 8.Cab
# [剩余数量：63] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：52] - 12.Engine & Transmission > 14.Timing Belt
# [剩余数量：62] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：85] - 12.Engine & Transmission > 8.Cross member
# [剩余数量：61] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 11.Tonneau Cover
# [剩余数量：60] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 9.Bed Accessories
# [剩余数量：59] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：1] - 15.Doors > 1.Door Shell
# [剩余数量：58] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：48] - 12.Engine & Transmission > 15.Air Temperature Sensor
# [剩余数量：57] - [当前时间：20:54:05]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 6.Tailgate Hinge
# [剩余数量：56] - [当前时间：20:54:07]
#
# [状态：ok，尝试次数：38] - 12.Engine & Transmission > 16.Head Gasket
# [剩余数量：55] - [当前时间：20:54:07]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 5.Tailgate Latch
# [剩余数量：54] - [当前时间：20:54:08]
#
# [状态：ok，尝试次数：3] - 14.Pickup Bed & Tailgate > 3.Tailgate Cable
# [剩余数量：53] - [当前时间：20:54:08]
#
# [状态：ok，尝试次数：67] - 12.Engine & Transmission > 10.Speed Sensor
# [剩余数量：52] - [当前时间：20:54:10]
#
# [状态：ok，尝试次数：1] - 15.Doors > 2.Door Moulding
# [剩余数量：51] - [当前时间：20:54:11]
#
# [状态：ok，尝试次数：36] - 14.Pickup Bed & Tailgate > 1.Tailgate
# [剩余数量：50] - [当前时间：20:54:13]
#
# [状态：ok，尝试次数：1] - 15.Doors > 3.Others
# [剩余数量：49] - [当前时间：20:54:13]
#
# [状态：ok，尝试次数：36] - 13.A/C Condensers > 3.Blower Motor
# [剩余数量：48] - [当前时间：20:54:13]
#
# [状态：ok，尝试次数：8] - 14.Pickup Bed & Tailgate > 2.Tailgate Handle
# [剩余数量：47] - [当前时间：20:54:14]
#
# [状态：ok，尝试次数：37] - 13.A/C Condensers > 1.A/C Condenser
# [剩余数量：46] - [当前时间：20:54:15]
#
# [状态：ok，尝试次数：36] - 12.Engine & Transmission > 17.Mass Air Flow Sensor
# [剩余数量：45] - [当前时间：20:54:15]
#
# [状态：ok，尝试次数：1] - 14.Pickup Bed & Tailgate > 10.Roll Pan
# [剩余数量：44] - [当前时间：20:54:16]
#
# [状态：ok，尝试次数：134] - 2.Bumpers > 1.Bumper
# [剩余数量：43] - [当前时间：20:54:16]
#
# [状态：ok，尝试次数：64] - 12.Engine & Transmission > 13.Distributor
# [剩余数量：42] - [当前时间：20:54:18]
#
# [状态：ok，尝试次数：7] - 18.Suspension > 9.Steering Shaft
# [剩余数量：41] - [当前时间：20:54:18]
#
# [状态：ok，尝试次数：48] - 15.Doors > 8.Seat
# [剩余数量：40] - [当前时间：20:54:18]
#
# [状态：ok，尝试次数：1] - 18.Suspension > 12.Spindle
# [剩余数量：39] - [当前时间：20:54:18]
#
# [状态：ok，尝试次数：60] - 15.Doors > 4.Door Lock
# [剩余数量：38] - [当前时间：20:54:18]
#
# [状态：ok，尝试次数：1] - 19.Radiator Supports > 2.Battery Tray
# [剩余数量：37] - [当前时间：20:54:19]
#
# [状态：ok，尝试次数：58] - 15.Doors > 6.Door Skin
# [剩余数量：36] - [当前时间：20:54:20]
#
# [状态：ok，尝试次数：1] - 20.Doors & Door Handles > -.-
# [剩余数量：35] - [当前时间：20:54:20]
#
# [状态：ok，尝试次数：1] - 18.Suspension > 10.Leaf Spring
# [剩余数量：34] - [当前时间：20:54:21]
#
# [状态：ok，尝试次数：1] - 18.Suspension > 11.Pitman Arm
# [剩余数量：33] - [当前时间：20:54:21]
#
# [状态：ok，尝试次数：1] - 21.Starters > 1.Starter
# [剩余数量：32] - [当前时间：20:54:21]
#
# [状态：ok，尝试次数：1] - 23.Wheels > 1.Wheel Cover
# [剩余数量：31] - [当前时间：20:54:21]
#
# [状态：ok，尝试次数：1] - 22.Weatherstrips & Seals > 1.Weatherstrip
# [剩余数量：30] - [当前时间：20:54:21]
#
# [状态：ok，尝试次数：48] - 16.Alternators > 1.Alternator
# [剩余数量：29] - [当前时间：20:54:22]
#
# [状态：ok，尝试次数：32] - 18.Suspension > 6.Suspension
# [剩余数量：28] - [当前时间：20:54:22]
#
# [状态：ok，尝试次数：62] - 15.Doors > 5.Door Hinge
# [剩余数量：27] - [当前时间：20:54:26]
#
# [状态：ok，尝试次数：37] - 18.Suspension > 5.Others
# [剩余数量：26] - [当前时间：20:54:29]
#
# [状态：ok，尝试次数：47] - 18.Suspension > 3.Strut Assembly
# [剩余数量：25] - [当前时间：20:54:29]
#
# [状态：ok，尝试次数：28] - 18.Suspension > 8.Suspension Kit
# [剩余数量：24] - [当前时间：20:54:30]
#
# [状态：ok，尝试次数：46] - 17.Window Regulators > 1.Window Regulator
# [剩余数量：23] - [当前时间：20:54:31]
#
# [状态：ok，尝试次数：2] - 12.Engine & Transmission > 1.Engine Parts
# [剩余数量：22] - [当前时间：20:54:31]
#
# [状态：ok，尝试次数：29] - 18.Suspension > 7.Ball Joint
# [剩余数量：21] - [当前时间：20:54:32]
#
# [状态：ok，尝试次数：1] - 19.Radiator Supports > 1.Radiator Support
# [剩余数量：20] - [当前时间：20:54:32]
#
# [状态：ok，尝试次数：36] - 13.A/C Condensers > 2.Fan Shroud
# [剩余数量：19] - [当前时间：20:54:33]
#
# [状态：ok，尝试次数：1] - 10.Hoods > 3.Hood Latch
# [剩余数量：18] - [当前时间：20:54:34]
#
# [状态：ok，尝试次数：50] - 18.Suspension > 2.Control Arm
# [剩余数量：17] - [当前时间：20:54:34]
#
# [状态：ok，尝试次数：82] - 23.Wheels > 2.Spare Wheel
# [剩余数量：16] - [当前时间：20:54:34]
#
# [状态：ok，尝试次数：70] - 24.Windshield & Wipers > 3.Windshield Molding
# [剩余数量：15] - [当前时间：20:54:35]
#
# [状态：ok，尝试次数：50] - 15.Doors > 7.Glass
# [剩余数量：14] - [当前时间：20:54:35]
#
# [状态：ok，尝试次数：54] - 26.Fuel Delivery System > 3.Fuel Level Sending Unit
# [剩余数量：13] - [当前时间：20:54:36]
#
# [状态：ok，尝试次数：55] - 26.Fuel Delivery System > 4.Fuel Tank Door
# [剩余数量：12] - [当前时间：20:54:36]
#
# [状态：ok，尝试次数：59] - 25.Spoilers > 1.Spoiler
# [剩余数量：11] - [当前时间：20:54:36]
#
# [状态：ok，尝试次数：1] - 26.Fuel Delivery System > 7.Fuel Pressure Regulator
# [剩余数量：10] - [当前时间：20:54:37]
#
# [状态：ok，尝试次数：62] - 24.Windshield & Wipers > 5.Windshield Frame
# [剩余数量：9] - [当前时间：20:54:37]
#
# [状态：ok，尝试次数：81] - 23.Wheels > 4.Steel Wheel
# [剩余数量：8] - [当前时间：20:54:38]
#
# [状态：ok，尝试次数：1] - 29.Interior > 4.Console
# [剩余数量：7] - [当前时间：20:54:39]
#
# [状态：ok，尝试次数：1] - 29.Interior > 2.Dash
# [剩余数量：6] - [当前时间：20:54:40]
#
# [状态：ok，尝试次数：80] - 24.Windshield & Wipers > 1.Windshield Wiper Arm
# [剩余数量：5] - [当前时间：20:54:40]
#
# [状态：ok，尝试次数：1] - 27.Brakes > 1.Brake Drum
# [剩余数量：4] - [当前时间：20:54:41]
#
# [状态：ok，尝试次数：1] - 29.Interior > 3.Steering Wheel
# [剩余数量：3] - [当前时间：20:54:41]
#
# [状态：ok，尝试次数：44] - 26.Fuel Delivery System > 5.Fuel Rail
# [剩余数量：2] - [当前时间：20:54:41]
#
# [状态：ok，尝试次数：67] - 12.Engine & Transmission > 11.Water Pump
# [剩余数量：1] - [当前时间：20:54:42]
#
# [状态：ok，尝试次数：9] - 26.Fuel Delivery System > 6.Gas Cap
# [剩余数量：0] - [当前时间：20:54:42]
#
# [状态：ok，尝试次数：1] - 27.Brakes > 5.Master Cylinder
# [剩余数量：0] - [当前时间：20:54:43]
#
# [状态：ok，尝试次数：1] - 26.Fuel Delivery System > 8.Fuel Injector
# [剩余数量：0] - [当前时间：20:54:44]
#
# [状态：ok，尝试次数：83] - 23.Wheels > 3.Wheels & Hubcaps
# [剩余数量：0] - [当前时间：20:54:46]
#
# [状态：ok，尝试次数：1] - 29.Interior > 1.Others
# [剩余数量：0] - [当前时间：20:54:46]
#
# [状态：ok，尝试次数：1] - 26.Fuel Delivery System > 9.Fuel Tank Strap
# [剩余数量：0] - [当前时间：20:54:47]
#
# [状态：ok，尝试次数：1] - 27.Brakes > 3.Others
# [剩余数量：0] - [当前时间：20:54:47]
#
# [状态：ok，尝试次数：78] - 24.Windshield & Wipers > 2.Windshield Washer
# [剩余数量：0] - [当前时间：20:54:48]
#
# [状态：ok，尝试次数：1] - 27.Brakes > 4.Brake Pad
# [剩余数量：0] - [当前时间：20:54:49]
#
# [状态：ok，尝试次数：55] - 26.Fuel Delivery System > 1.Fuel Tank
# [剩余数量：0] - [当前时间：20:54:50]
#
# [状态：ok，尝试次数：1] - 30.Trunk Lid & Lift Gate > 1.Trunk Strut
# [剩余数量：0] - [当前时间：20:54:50]
#
# [状态：ok，尝试次数：1] - 27.Brakes > 2.Brake Disc
# [剩余数量：0] - [当前时间：20:54:50]
#
# [状态：ok，尝试次数：58] - 24.Windshield & Wipers > 6.Wiper Motor
# [剩余数量：0] - [当前时间：20:54:51]
#
# [状态：ok，尝试次数：1] - 28.Window Motors > 1.Window Motor
# [剩余数量：0] - [当前时间：20:54:51]
#
# [状态：ok，尝试次数：57] - 26.Fuel Delivery System > 2.Fuel Pump
# [剩余数量：0] - [当前时间：20:54:52]
#
# [状态：ok，尝试次数：1] - 29.Interior > 5.Seat Cover
# [剩余数量：0] - [当前时间：20:54:54]
#
# [状态：ok，尝试次数：49] - 30.Trunk Lid & Lift Gate > 5.Lift Gate
# [剩余数量：0] - [当前时间：20:54:54]
#
# [状态：ok，尝试次数：50] - 30.Trunk Lid & Lift Gate > 2.Trunk Lid
# [剩余数量：0] - [当前时间：20:54:55]
#
# [状态：ok，尝试次数：24] - 32.Others > 4.Body Kits
# [剩余数量：0] - [当前时间：20:54:55]
#
# [状态：ok，尝试次数：55] - 30.Trunk Lid & Lift Gate > 4.Trunk Lock
# [剩余数量：0] - [当前时间：20:54:57]
#
# [状态：ok，尝试次数：53] - 30.Trunk Lid & Lift Gate > 3.Trunk Lid Molding
# [剩余数量：0] - [当前时间：20:54:58]
#
# [状态：ok，尝试次数：25] - 32.Others > 3.Other Interior Parts
# [剩余数量：0] - [当前时间：20:54:59]
#
# [状态：ok，尝试次数：26] - 32.Others > 2.Other Engine Parts
# [剩余数量：0] - [当前时间：20:54:59]
#
# [状态：ok，尝试次数：17] - 33.Other > -.-
# [剩余数量：0] - [当前时间：20:55:00]
#
# [状态：ok，尝试次数：39] - 31.Carpets & Floor Mats > 1.Floor Mat
# [剩余数量：0] - [当前时间：20:55:00]
#
# [状态：ok，尝试次数：68] - 24.Windshield & Wipers > 4.Windshield & Wiper Arms
# [剩余数量：0] - [当前时间：20:55:00]
#
# [状态：ok，尝试次数：81] - 18.Suspension > 1.Shock Absorber
# [剩余数量：0] - [当前时间：20:55:01]
#
# [状态：ok，尝试次数：34] - 31.Carpets & Floor Mats > 2.Carpet
# [剩余数量：0] - [当前时间：20:55:04]
#
# [状态：ok，尝试次数：33] - 32.Others > 1.Other Body Parts
# [剩余数量：0] - [当前时间：20:55:07]
#
# [状态：ok，尝试次数：47] - 18.Suspension > 4.Tie Rod Assembly
# [剩余数量：0] - [当前时间：20:55:14]
#
# 输出ing...
#
# Done ~
