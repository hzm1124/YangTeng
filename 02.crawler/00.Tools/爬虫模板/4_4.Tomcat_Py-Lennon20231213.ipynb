# %%
import os

# %%
list_file = list(os.walk('./crawler_1'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 100

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./crawler_1/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_1.xlsx', index=False)

df
# Out:
# 进度: 100%|███████████████████████████████| 100/100 [00:00<00:00, 416.98it/s]
#           ASIN                                              Title    Price  \
# 0   B08NG92THQ  RANSOTO 100pcs TPMS Tire Pressure Sensor Valve...   $57.39
# 0   B014VZFQAS  ACDelco GM Original Equipment 13598772 Tire Pr...   $14.95
# 0   B07FMJFL2M  TPMS Sensor, 315MHZ 13598772 Tire Pressure Mon...   $25.99
# 0   B0BLZBLL3B  Marsflex TPMS Sensor Fit for Chevy GMC Buick C...   $24.99
# 0   B0C9H88YXW  Zlirfy Universal TPMS Relearn Tool,System Prog...    $9.99
# ..         ...                                                ...      ...
# 0   B07FKTH136  TST 507 Tire Pressure Monitoring System with 4...  $368.00
# 0   B08FJ2XSX8  TPMS Sensor,315MHZ Tire Pressure Monitor Syste...   $54.99
# 0   B082ZXFR59  TPMS Sensor GM, 4-Pack Tire Pressure Monitorin...   $25.95
# 0   B07Q21RNNB  FOBO Bike 2 tire pressure monitoring system (B...   $98.50
# 0   B08PD7ZQVN  LEEPEE Tire Pressure Monitoring System, 5 Alar...   $56.99
#
#                                                 About Pic  \
# 0   1. Replace# 17-20008 20008 20018\n2. Compatibl...
# 0   1. Battery is made to last up to 10 years of n...
# 0   1. 【PREFECT REPLACEMENT】The tire pressure moni...
# 0   1. 🔧Application：Marsflex tire pressure monitor...
# 0   1. [Durable Design]The activation tool of the ...
# ..                                                ...  ..
# 0   1. TPMS TIRE PRESSURE MONITORING SYSTEM - Real...
# 0   1. 【PREFECT REPLACEMENT】The tire pressure moni...
# 0   1. 【Perfect Replacement】: The tire pressure mo...
# 0   1. TRULY BLUETOOTH 5 TPMS FOR MOTORCYCLES\n2. ...
# 0   1. 【 Multiple alarm types 】 Bluetooth5.0 Tire ...
#
#                                                   Url  \
# 0   https://www.amazon.com/Pressure-Compatible-Sil...
# 0   https://www.amazon.com/ACDelco-13598772-Origin...
# 0   https://www.amazon.com/CDWTPS-Compatible-Silve...
# 0   https://www.amazon.com/Marsflex-Cadillac-Press...
# 0   https://www.amazon.com/Zlirfy-Universal-Progra...
# ..                                                ...
# 0   https://www.amazon.com/Truck-Systems-Technolog...
# 0   https://www.amazon.com/Pressure-Monitor-Replac...
# 0   https://www.amazon.com/Jsueng-13581558-Pressur...
# 0   https://www.amazon.com/FOBO-Pressure-Monitorin...
# 0   https://www.amazon.com/LEEPEE-Monitoring-Tempe...
#
#                                                   Src manufacturer      brand  \
# 0   https://m.media-amazon.com/images/I/81-AzaEpD0...          NaN        NaN
# 0   https://m.media-amazon.com/images/I/51V5bTHxGD...     ‎ACDelco   ‎ACDelco
# 0   https://m.media-amazon.com/images/I/712x-3fx0d...      ‎CDWTPS    ‎CDWTPS
# 0   https://m.media-amazon.com/images/I/61Bj3Yo9ul...   ‎Marsmotor  ‎Marsflex
# 0   https://m.media-amazon.com/images/I/61lWTk6k5K...      ‎Zlirfy    ‎Zlirfy
# ..                                                ...          ...        ...
# 0   https://m.media-amazon.com/images/I/81fTJU2Bwh...          NaN        NaN
# 0   https://m.media-amazon.com/images/I/61DFtA5j+-...      ‎CDWTPS    ‎CDWTPS
# 0   https://m.media-amazon.com/images/I/611aqrHBHp...      ‎Jsueng    ‎Jsueng
# 0   https://m.media-amazon.com/images/I/71AlBzbWie...          NaN        NaN
# 0   https://m.media-amazon.com/images/I/61XnffBECr...          NaN        NaN
#
#                      model  ... response time mirror adjustment bulb type  \
# 0                      NaN  ...           NaN               NaN       NaN
# 0   ‎GM Original Equipment  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# ..                     ...  ...           ...               ...       ...
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
# 0                      NaN  ...           NaN               NaN       NaN
#
#    measurement accuracy sensing distance wattage         PACKAGE DIMENSIONS  \
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# ..                  ...              ...     ...                        ...
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN                        NaN
# 0                   NaN              NaN     NaN  4.88 x 3.11 x 1.42 inches
# 0                   NaN              NaN     NaN                        NaN
#
#    ITEM WEIGHT                         MANUFACTURER  \
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# ..         ...                                  ...
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# 0          NaN                                  NaN
# 0     5 ounces  Salutica Allied Solutions Sdn. Bhd.
# 0          NaN                                  NaN
#
#                                          BATTERIES
# 0                                              NaN
# 0                                              NaN
# 0                                              NaN
# 0                                              NaN
# 0                                              NaN
# ..                                             ...
# 0                                              NaN
# 0                                              NaN
# 0                                              NaN
# 0   2 Lithium Metal batteries required. (included)
# 0                                              NaN
#
# [100 rows x 45 columns]
