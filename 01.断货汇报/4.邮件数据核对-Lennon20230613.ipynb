# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230701.xlsx

# %%
import pandas as pd

# %%
table_1 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(1, 9)]).loc[:4]

table_1
# Out:
#       层级   SKU 总数  在库为0（断货数）  在库1-2（干预数）       断货率       干预率  近期海运上架后断货数  \
# 0   TOP1    526.0       31.0        19.0  0.058935  0.036122         6.0
# 1  TOP10   2646.0      139.0       218.0  0.052532  0.082389        69.0
# 2  TOP20   3224.0      241.0       271.0  0.074752  0.084057       141.0
# 3     普通  47700.0     2513.0      7406.0  0.052683  0.155262      1490.0
# 4     总数  54096.0     2924.0      7914.0  0.054052  0.146295      1706.0
#
#    近期海运上架后断货率
# 0    0.011407
# 1    0.026077
# 2    0.043734
# 3    0.031237
# 4    0.031537

# %%
table_2 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(10, 17)]).loc[:4]

table_2
# Out:
#     层级.1  在库为0（断货）   断货无在途        占比  在库1-2（干预）   干预无在途      占比.1
# 0   TOP1      31.0     3.0  0.096774       19.0     0.0  0.000000
# 1  TOP10     139.0    41.0  0.294964      218.0    34.0  0.155963
# 2  TOP20     241.0   103.0  0.427386      271.0    86.0  0.317343
# 3     普通    2513.0   968.0  0.385197     7406.0  3224.0  0.435323
# 4     总数    2924.0  1115.0  0.381327     7914.0  3344.0  0.422542

# %%
table_3 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(18, 27)]).loc[:4]

table_3
# Out:
#     层级.2  W20\n05/20  W21\n05/23  W21\n05/26  W22\n06/03  W23\n06/06  \
# 0   TOP1        21.0        33.0        20.0        20.0        26.0
# 1  TOP10       131.0       173.0       143.0       128.0       166.0
# 2  TOP20       185.0       195.0       189.0       191.0       223.0
# 3     普通      2335.0      2497.0      2360.0      2480.0      2583.0
# 4     总数      2672.0      2898.0      2712.0      2819.0      2998.0
#
#    W23\n06/09  W24\n06/17  W26\n07/01
# 0        29.0        28.0        31.0
# 1       176.0       202.0       139.0
# 2       218.0       262.0       241.0
# 3      2601.0      2586.0      2513.0
# 4      3024.0      3078.0      2924.0

# %%
table_4 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(28, 33)],
                        index_col=0)

table_4
# Out:
#           品类  断货SKU数量  总SKU数      断货占比
# 排名
# TOP1      BC      306   2804  0.109130
# TOP2      CA      248   4738  0.052343
# TOP3     CVA      119   1972  0.060345
# TOP4      WR      118   1971  0.059868
# TOP5     ACH      108   1684  0.064133
# ...      ...      ...    ...       ...
# TOP417  EGTS        0     56  0.000000
# TOP418    SS        0     72  0.000000
# TOP419   EGR        0     82  0.000000
# TOP420   ACS        0     94  0.000000
# TOP421   WSP        0    206  0.000000
#
# [421 rows x 4 columns]

# %%
sheet_2_left = pd.read_excel(calculate,
                             sheet_name='2_断货SKU',
                             header=1,
                             usecols=[i for i in range(5)],
                             index_col=0)

sheet_2_left
# Out:
#                SKU     层级    周销  在途
# 序号
# 1      USADCA00400   TOP1  7.65   0
# 2    USALT82470B-C   TOP1  5.87   0
# 3     USCON37940-C   TOP1  6.54   0
# 4     USACC68669-C  TOP10  1.22   0
# 5    USALT13872B-C  TOP10  2.12   0
# ..             ...    ...   ...  ..
# 143  USSA65144-1-C  TOP20  0.59   0
# 144     USSKA61503  TOP20  0.84   0
# 145     USTBC00470  TOP20  0.40   0
# 146    USTF20695-C  TOP20  0.42   0
# 147  USWHN11075-20  TOP20  2.12   0
#
# [147 rows x 4 columns]

# %%
sheet_2_right = pd.read_excel(calculate,
                              sheet_name='2_断货SKU',
                              header=1,
                              usecols=[i for i in range(7, 9)],
                              index_col=0).dropna().sort_values(by=['断货数'], ascending=False)

sheet_2_right
# Out:
#         断货数
# 品类去重
# CVA    55.0
# CA     21.0
# BMC     7.0
# ALT     5.0
# FI      5.0
# BC      4.0
# SA      4.0
# CON     3.0
# DS      3.0
# PSR     3.0
# FF      2.0
# FSU     2.0
# HB      2.0
# CS-弹簧   2.0
# BRPS    2.0
# MI      1.0
# WHN     1.0
# THK     1.0
# THB     1.0
# TF      1.0
# TCA     1.0
# TBK     1.0
# TBC     1.0
# STR     1.0
# SKA     1.0
# RAD     1.0
# PBB     1.0
# MSA     1.0
# DIF     1.0
# IM      1.0
# ID      1.0
# ICK     1.0
# FPB     1.0
# FP      1.0
# EM      1.0
# BT      1.0
# AST     1.0
# AEC     1.0
# ADCA    1.0
# ACH     1.0
# ACC     1.0
# WP      1.0

# %%
print(int(table_1.loc[4, '在库为0（断货数）']), end='; ')
print(str(round(table_1.loc[4, '断货率']*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['断货率'].tolist().index(max(table_1['断货率'])), '层级'], end='; ')
print(str(round(max(table_1['断货率'])*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['干预率'].tolist().index(max(table_1['干预率'])), '层级'], end='; ')
print(str(round(max(table_1['干预率'])*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left), end='; ')
print(sheet_2_right['断货数'].index[0], end='; ')
print(sheet_2_right['断货数'].index[1], end='; ')
print(sheet_2_right['断货数'].index[2], end='; ')
print(int(sheet_2_right.iloc[0, 0]), end='; ')
print(int(sheet_2_right.iloc[1, 0]), end='; ')
print(int(sheet_2_right.iloc[2, 0]))
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left[sheet_2_left['层级']=='TOP1']))
# Out:
# 2924; 5.41%; TOP20; 7.48%; 普通; 15.53%
#
# = = = = = = = = = = = = = = = = = =
#
# 147; CVA; CA; BMC; 55; 21; 7
#
# = = = = = = = = = = = = = = = = = =
#
# 3

# %%
print(int(table_2.loc[4, '在库为0（断货）']), end='; ')
print(int(table_2.loc[4, '断货无在途']), end='; ')
print(str(round(table_2.loc[4, '占比']*100, 2)) + '%', end='; ')
print(int(table_2.loc[4, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[4, '干预无在途']), end='; ')
print(str(round(table_2.loc[4, '占比.1']*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(int(table_2.loc[0, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[0, '干预无在途']))
# Out:
# 2924; 1115; 38.13%; 7914; 3344; 42.25%
#
# = = = = = = = = = = = = = = = = = =
#
# 19; 0

# %%
print('TOP1: ' + str(int(table_3.iloc[0, 8] - table_3.iloc[0, 7])))
print('TOP10: ' + str(int(table_3.iloc[1, 8] - table_3.iloc[1, 7])))
print('TOP20: ' + str(int(table_3.iloc[2, 8] - table_3.iloc[2, 7])))
print('普通: ' + str(int(table_3.iloc[3, 8] - table_3.iloc[3, 7])))
# Out:
# TOP1: 3
# TOP10: -63
# TOP20: -21
# 普通: -73

# %%
print(table_4.loc['TOP1', '品类'], end='; ')
print(table_4.loc['TOP1', '断货SKU数量'])
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 2], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 1], end='; ')
print(str(round(max(table_4['断货占比'][:10])*100, 2)) + '%')
# Out:
# BC; 306
#
# = = = = = = = = = = = = = = = = = =
#
# STR; 412; STR; 70; 16.99%
