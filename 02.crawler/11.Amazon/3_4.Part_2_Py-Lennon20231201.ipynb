# %%
import os

# %%
list_file = list(os.walk('./crawler_2'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 100

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./crawler_2/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_2.xlsx', index=False)

df
# Out:
# Process: 100%|████████████████████████████| 100/100 [00:00<00:00, 942.98it/s]
#           ASIN       标识       PASIN       品牌  \
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# ..         ...      ...         ...      ...
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
# 0   B08NG92THQ  A+;V;AC  B08NG92THQ  RANSOTO
#
#                                                  品牌链接   大类BSR  BSR增长数 BSR增长率  \
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# ..                                                ...     ...     ...    ...
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
# 0   https://www.amazon.com/stores/RANSOTO/page/052...  26,158  58,611    69%
#
#    父体月销量 父体月销量增长率  ...          重量_1     重量_2                        体积_1  \
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# ..   ...      ...  ...           ...      ...                         ...
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
# 0    146      22%  ...  3.92 Pounds   1.78 kg  6.85 x 4.76 x 3.78 inches
#
#                        体积_2  LQS 变体数 SKU 卖家数 BuyBox卖家 BuyBox卖家链接
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# ..                      ...  ...  ..  ..  ..      ...        ...
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
# 0   17.40 x 12.09 x 9.60 cm  9.9   无      1家
#
# [100 rows x 38 columns]
