# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/4.vehicle'):
    shutil.rmtree('./file/4.vehicle')

os.makedirs('./file/4.vehicle')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import json
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/3.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/3.part/{file}',
                           header=0,
                           dtype=str).fillna('')

    input_ = input_[input_['Json_Compatibility'] != '{}'].reset_index(drop=True)
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                df_temp, dict_, page = pd.DataFrame(), json.loads(input_.loc[a, 'Json_Compatibility']), 0
                while page < dict_['page']:
                    b = 0
                    while True:
                        b += 1

                        try:
                            check_url = input_.loc[a, 'Url']
                            
                            resp = requests.post(f'''{dict_['api']}?module_groups=PART_FINDER&referrer=VIEWITEM&offset={page*20}&module=COMPATIBILITY_TABLE''',
                                                 data=json.dumps(dict_['data']),
                                                 headers=get_header(ua=False, **{'Content-Type': 'application/json; charset=utf-8'}),
                                                 proxies=get_proxy(),
                                                 timeout=(10, 10))
                
                            if resp.status_code == 200:
                                list_header = [cell['textSpans'][0]['text'].strip() for cell in resp.json()['modules']['COMPATIBILITY_TABLE']['paginatedTable']['header']['cells']]
                                list_row = [[cell['textualDisplays'][0]['textSpans'][0]['text'].strip() if 'textualDisplays' in cell else cell['textSpans'][0]['text'].strip() for cell in row['cells']] for row in resp.json()['modules']['COMPATIBILITY_TABLE']['paginatedTable']['rows']]

                                if list_header and list_row:
                                    break
                        except KeyboardInterrupt:
                            break
                        except:
                            continue
                
                    # = = = = = = = = = = = = = = =
                
                    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                                 'Item Number': input_.loc[a, 'Item Number'],
                                                 'Json_Compatibility': input_.loc[a, 'Json_Compatibility'],
                                                 'Page': page + 1,
                                                 'Row': [i+1 for i in range(len(list_row))]})
                
                    for i, row in enumerate(list_row):
                        for j, header in enumerate(list_header):
                            df_temp_temp.loc[i, header] = row[j]
                
                    df_temp = pd.concat([df_temp, df_temp_temp], ignore_index=True).fillna('')
                
                    # = = = = = = = = = = = = = = =

                    if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 10 == 0 and work.qsize() != 0:
                        clear_output()

                    print(f'''[尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} - {input_.loc[a, 'No']}.{input_.loc[a, 'Item Number']} > Page {page + 1}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                    # = = = = = = = = = = = = = = =
                
                    page += 1

                # = = = = = = = = = = = = = = =

                if df_temp.empty:
                    raise

                # = = = = = = = = = = = = = = =

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
                df_temp.loc[0, 'Check_Url'] = check_url
                
                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No', 'Page', 'Row'],
                                                    ascending=[True, True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/4.vehicle/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/4.vehicle'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/4.vehicle/{file}',
              f'''./file/4.vehicle/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '-vehicle.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：10
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 1
# [剩余数量：5] - [当前时间：14:23:20]
#
# [尝试次数：1] - 50.00% - crawler_1 - 4.255586148611 > Page 1
# [剩余数量：5] - [当前时间：14:23:20]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 1
# [剩余数量：4] - [当前时间：14:23:21]
#
# [尝试次数：1] - 50.00% - crawler_1 - 3.235653299500 > Page 1
# [剩余数量：4] - [当前时间：14:23:21]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.255922672592 > Page 1
# [剩余数量：3] - [当前时间：14:23:21]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 2
# [剩余数量：3] - [当前时间：14:23:22]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 3
# [剩余数量：3] - [当前时间：14:23:23]
#
# [尝试次数：1] - 50.00% - crawler_1 - 7.256421824484 > Page 1
# [剩余数量：3] - [当前时间：14:23:23]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.255922672592 > Page 2
# [剩余数量：3] - [当前时间：14:23:23]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 2
# [剩余数量：3] - [当前时间：14:23:24]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 4
# [剩余数量：3] - [当前时间：14:23:24]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.255922672592 > Page 3
# [剩余数量：3] - [当前时间：14:23:24]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 3
# [剩余数量：3] - [当前时间：14:23:25]
#
# [尝试次数：1] - 50.00% - crawler_1 - 7.256421824484 > Page 2
# [剩余数量：3] - [当前时间：14:23:25]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 5
# [剩余数量：2] - [当前时间：14:23:25]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 4
# [剩余数量：2] - [当前时间：14:23:26]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 1
# [剩余数量：2] - [当前时间：14:23:26]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 6
# [剩余数量：2] - [当前时间：14:23:28]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 2
# [剩余数量：2] - [当前时间：14:23:28]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.253139036562 > Page 7
# [剩余数量：2] - [当前时间：14:23:29]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 3
# [剩余数量：1] - [当前时间：14:23:30]
#
# [尝试次数：1] - 50.00% - crawler_1 - 9.256102649999 > Page 1
# [剩余数量：1] - [当前时间：14:23:31]
#
# [尝试次数：2] - 50.00% - crawler_1 - 6.332388018897 > Page 1
# [剩余数量：1] - [当前时间：14:23:32]
#
# [尝试次数：1] - 50.00% - crawler_1 - 9.256102649999 > Page 2
# [剩余数量：1] - [当前时间：14:23:32]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 4
# [剩余数量：1] - [当前时间：14:23:33]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 5
# [剩余数量：1] - [当前时间：14:23:34]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 6
# [剩余数量：1] - [当前时间：14:23:35]
#
# [尝试次数：2] - 50.00% - crawler_1 - 2.255922672592 > Page 4
# [剩余数量：1] - [当前时间：14:23:37]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 7
# [剩余数量：1] - [当前时间：14:23:37]
#
# [尝试次数：2] - 50.00% - crawler_1 - 5.233621258535 > Page 5
# [剩余数量：1] - [当前时间：14:23:38]
#
# [尝试次数：1] - 50.00% - crawler_1 - 9.256102649999 > Page 3
# [剩余数量：1] - [当前时间：14:23:39]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 8
# [剩余数量：0] - [当前时间：14:23:39]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 6
# [剩余数量：0] - [当前时间：14:23:39]
#
# [尝试次数：1] - 50.00% - crawler_1 - 6.332388018897 > Page 2
# [剩余数量：0] - [当前时间：14:23:39]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 7
# [剩余数量：0] - [当前时间：14:23:40]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.255922672592 > Page 5
# [剩余数量：0] - [当前时间：14:23:41]
#
# [尝试次数：1] - 50.00% - crawler_1 - 6.332388018897 > Page 3
# [剩余数量：0] - [当前时间：14:23:41]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 9
# [剩余数量：0] - [当前时间：14:23:41]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.255922672592 > Page 6
# [剩余数量：0] - [当前时间：14:23:42]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 10
# [剩余数量：0] - [当前时间：14:23:47]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 11
# [剩余数量：0] - [当前时间：14:23:49]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 12
# [剩余数量：0] - [当前时间：14:23:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.334041367847 > Page 13
# [剩余数量：0] - [当前时间：14:23:52]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.233621258535 > Page 8
# [剩余数量：0] - [当前时间：14:23:59]
#
# [尝试次数：2] - 50.00% - crawler_1 - 10.256202118103 > Page 1
# [剩余数量：0] - [当前时间：14:24:04]
#
# [尝试次数：1] - 50.00% - crawler_1 - 10.256202118103 > Page 2
# [剩余数量：0] - [当前时间：14:24:05]
#
# [尝试次数：1] - 50.00% - crawler_1 - 10.256202118103 > Page 3
# [剩余数量：0] - [当前时间：14:24:07]
#
# 输出ing...
#
# 总数量：10
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 1
# [剩余数量：5] - [当前时间：14:24:08]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 1
# [剩余数量：5] - [当前时间：14:24:09]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.391525907146 > Page 1
# [剩余数量：5] - [当前时间：14:24:09]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 2
# [剩余数量：5] - [当前时间：14:24:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 1
# [剩余数量：5] - [当前时间：14:24:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.391525907146 > Page 2
# [剩余数量：5] - [当前时间：14:24:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 2
# [剩余数量：5] - [当前时间：14:24:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.391525907146 > Page 3
# [剩余数量：5] - [当前时间：14:24:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 1
# [剩余数量：5] - [当前时间：14:24:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 3
# [剩余数量：5] - [当前时间：14:24:12]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.391525907146 > Page 4
# [剩余数量：5] - [当前时间：14:24:12]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 4
# [剩余数量：5] - [当前时间：14:24:13]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 2
# [剩余数量：5] - [当前时间：14:24:14]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 2
# [剩余数量：5] - [当前时间：14:24:14]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 5
# [剩余数量：5] - [当前时间：14:24:14]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 3
# [剩余数量：5] - [当前时间：14:24:15]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.391525907146 > Page 5
# [剩余数量：5] - [当前时间：14:24:15]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 6
# [剩余数量：5] - [当前时间：14:24:15]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 4
# [剩余数量：5] - [当前时间：14:24:16]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 5
# [剩余数量：5] - [当前时间：14:24:17]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 3
# [剩余数量：5] - [当前时间：14:24:18]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 7
# [剩余数量：5] - [当前时间：14:24:18]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 6
# [剩余数量：5] - [当前时间：14:24:19]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 4
# [剩余数量：5] - [当前时间：14:24:19]
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.371556118150 > Page 7
# [剩余数量：5] - [当前时间：14:24:20]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 8
# [剩余数量：4] - [当前时间：14:24:20]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 5
# [剩余数量：4] - [当前时间：14:24:20]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 9
# [剩余数量：4] - [当前时间：14:24:21]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 6
# [剩余数量：4] - [当前时间：14:24:21]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.391525907148 > Page 1
# [剩余数量：4] - [当前时间：14:24:22]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 7
# [剩余数量：4] - [当前时间：14:24:23]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 10
# [剩余数量：4] - [当前时间：14:24:24]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 11
# [剩余数量：4] - [当前时间：14:24:24]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.391525907148 > Page 2
# [剩余数量：4] - [当前时间：14:24:24]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 8
# [剩余数量：4] - [当前时间：14:24:25]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.391525907148 > Page 3
# [剩余数量：4] - [当前时间：14:24:26]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 9
# [剩余数量：4] - [当前时间：14:24:26]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.301357432588 > Page 10
# [剩余数量：4] - [当前时间：14:24:27]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.391525907148 > Page 4
# [剩余数量：3] - [当前时间：14:24:28]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 1
# [剩余数量：3] - [当前时间：14:24:28]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.391525907148 > Page 5
# [剩余数量：3] - [当前时间：14:24:29]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.371570167825 > Page 1
# [剩余数量：2] - [当前时间：14:24:30]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.371570167825 > Page 2
# [剩余数量：2] - [当前时间：14:24:31]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 12
# [剩余数量：2] - [当前时间：14:24:32]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.371570167825 > Page 3
# [剩余数量：2] - [当前时间：14:24:32]
#
# [尝试次数：3] - 100.00% - crawler_2 - 1.301284845158 > Page 3
# [剩余数量：2] - [当前时间：14:24:33]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 2
# [剩余数量：2] - [当前时间：14:24:33]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 13
# [剩余数量：2] - [当前时间：14:24:33]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 4
# [剩余数量：2] - [当前时间：14:24:34]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.371570167825 > Page 4
# [剩余数量：2] - [当前时间：14:24:34]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 3
# [剩余数量：2] - [当前时间：14:24:34]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 14
# [剩余数量：2] - [当前时间：14:24:34]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.371570167825 > Page 5
# [剩余数量：2] - [当前时间：14:24:35]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 5
# [剩余数量：1] - [当前时间：14:24:35]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.390952552830 > Page 15
# [剩余数量：1] - [当前时间：14:24:35]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 6
# [剩余数量：0] - [当前时间：14:24:36]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 1
# [剩余数量：0] - [当前时间：14:24:36]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 4
# [剩余数量：0] - [当前时间：14:24:37]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 1
# [剩余数量：0] - [当前时间：14:24:37]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 2
# [剩余数量：0] - [当前时间：14:24:38]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 5
# [剩余数量：0] - [当前时间：14:24:38]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 2
# [剩余数量：0] - [当前时间：14:24:38]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 7
# [剩余数量：0] - [当前时间：14:24:38]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 3
# [剩余数量：0] - [当前时间：14:24:39]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 6
# [剩余数量：0] - [当前时间：14:24:39]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 3
# [剩余数量：0] - [当前时间：14:24:39]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 4
# [剩余数量：0] - [当前时间：14:24:40]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 8
# [剩余数量：0] - [当前时间：14:24:41]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 4
# [剩余数量：0] - [当前时间：14:24:41]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 9
# [剩余数量：0] - [当前时间：14:24:42]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 10
# [剩余数量：0] - [当前时间：14:24:43]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 5
# [剩余数量：0] - [当前时间：14:24:43]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 7
# [剩余数量：0] - [当前时间：14:24:43]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 5
# [剩余数量：0] - [当前时间：14:24:43]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 11
# [剩余数量：0] - [当前时间：14:24:44]
#
# [尝试次数：2] - 100.00% - crawler_2 - 2.391525907146 > Page 6
# [剩余数量：0] - [当前时间：14:24:45]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 6
# [剩余数量：0] - [当前时间：14:24:45]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 12
# [剩余数量：0] - [当前时间：14:24:45]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 6
# [剩余数量：0] - [当前时间：14:24:45]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 8
# [剩余数量：0] - [当前时间：14:24:46]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 7
# [剩余数量：0] - [当前时间：14:24:46]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 9
# [剩余数量：0] - [当前时间：14:24:47]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 8
# [剩余数量：0] - [当前时间：14:24:48]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 10
# [剩余数量：0] - [当前时间：14:24:49]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 7
# [剩余数量：0] - [当前时间：14:24:49]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 13
# [剩余数量：0] - [当前时间：14:24:49]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.371165049724 > Page 11
# [剩余数量：0] - [当前时间：14:24:50]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 8
# [剩余数量：0] - [当前时间：14:24:50]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 9
# [剩余数量：0] - [当前时间：14:24:50]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 14
# [剩余数量：0] - [当前时间：14:24:51]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 10
# [剩余数量：0] - [当前时间：14:24:51]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.301284845158 > Page 15
# [剩余数量：0] - [当前时间：14:24:52]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 9
# [剩余数量：0] - [当前时间：14:24:52]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 11
# [剩余数量：0] - [当前时间：14:24:54]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 10
# [剩余数量：0] - [当前时间：14:24:54]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 12
# [剩余数量：0] - [当前时间：14:24:56]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 11
# [剩余数量：0] - [当前时间：14:24:57]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.373222887187 > Page 13
# [剩余数量：0] - [当前时间：14:24:57]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.301791991081 > Page 12
# [剩余数量：0] - [当前时间：14:24:58]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 4524.60it/s]
# Done ~
