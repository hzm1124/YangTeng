# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

import sys
sys.path.append('/Users/hzm/Desktop/YangTeng/code/venv/code/00.module')
import Proxy
import UA
import time

# = = = = = = = = = = = = = = = = = =

import pandas as pd
from selenium.webdriver import ChromeOptions

option = ChromeOptions()
option.add_experimental_option('useAutomationExtension', False)
option.add_argument('blink-settings=imagesEnabled=false')
option.add_argument('--disable-blink-features=AutomationControlled')
option.add_argument('--disable-dev-shm-usage')
option.add_argument('--disable-gpu')
option.add_experimental_option('excludeSwitches', ['enable-automation'])
option.add_argument('--headless')
option.add_argument('--no-sandbox')
option.add_argument('--proxy-server=' + Proxy.get_Proxy_Selenium())
option.add_argument('user-agent=' + UA.get_UA())
option.page_load_strategy = 'eager'

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./detail.xlsx', header=0).fillna('')
list_vehicle_url = df_menu['vehicle_url'].to_list()

print('总数量：' + str(len(list_vehicle_url)))
print()

df = pd.DataFrame()

# = = = = = = = = = = = = = = = = = =

work = Queue()
for url in list_vehicle_url:
    work.put_nowait(url)

def crawler():
    global df
    
    while not work.empty():
        url = work.get_nowait()
        
        # = = = = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(31):
            if url == None or url == '':
                break
            
            try:
                browser = Chrome(service=Service('../../../chromedriver'), options=option)
                browser.maximize_window()
                
                # = = = = = = = = = = = = = = = = = =

                browser.get(url)
                
                time.sleep(3)
                
                # = = = = = = = = = = = = = = = = = =
                
                dict_vehicle = {}
                while True:
                    wait = WebDriverWait(browser, 60)
                    wait.until(EC.presence_of_element_located((By.XPATH, '//tr[@class="detail-app-row"]')))
                    list_row = browser.find_elements(by=By.XPATH, value='//tr[@class="detail-app-row"]')

                    for row in list_row:
                        make = row.find_element(by=By.XPATH, value='./td[2]').text.strip()
                        model = row.find_element(by=By.XPATH, value='./td[3]').text.strip()
                        year = row.find_element(by=By.XPATH, value='./td[1]').text.strip()

                        if make not in dict_vehicle:
                            dict_vehicle[make] = {model: [year]}
                        else:
                            if model not in dict_vehicle[make]:
                                dict_vehicle[make][model] = [year]
                            else:
                                dict_vehicle[make][model].append(year)

                    list_next = browser.find_elements(by=By.XPATH, value='//a[@id="pagingBottom_nextButton"]')
                    if len(list_next) == 0:
                        break
                    else:
                        list_next[0].click()

                list_vehicle = []
                for make in dict_vehicle:
                    for model in dict_vehicle[make]:
                        list_year = list(set(dict_vehicle[make][model]))
                        if len(list_year) == 1:
                            list_vehicle.append(make + ' ' + model + ' ' + list_year[0])
                        else:
                            list_vehicle.append(make + ' ' + model + ' ' + min(list_year) + '-' + max(list_year))

                vehicle = '\n'.join(list_vehicle)
                
                # = = = = = = = = = = = = = = = = = =
                
                
                df_temp = pd.DataFrame([{'status': 'ok',
                                         'vehicle_url': url,
                                         'Vehicle': vehicle}])
                        
                browser.quit()
                
                status = 'ok'

                break

            except:
                time.sleep(3)
                continue

        # = = = = = = = = = = = = = = = = = =

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'vehicle_url': url}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(url +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print()
print('输出中...')
df.to_excel('./vehicle.xlsx', index=False)
print()
print('搞定！')
# Out:
# 总数量：150
#
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=72789&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：130
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=66592&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：129
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=76398&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：128
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=76741&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：127
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=75961&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：126
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=65300&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：125
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=106223&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：124
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=74179&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：123
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=49317&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：122
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=49327&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：121
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128361&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：120
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53418&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：119
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=47094&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：118
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50180&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：117
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=46838&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：116
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=76754&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：115
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=78185&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：114
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=82894&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：113
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131697&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：112
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50856&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：111
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50290&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：110
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=74181&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：109
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131396&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：108
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=52347&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：107
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=48281&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：106
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=73207&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：105
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=74185&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：104
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=73855&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：103
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=46714&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：102
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=49679&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：101
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=140459&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：100
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=65298&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：99
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128360&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：98
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=47096&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：97
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=78895&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：96
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=49678&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：95
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=83820&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：94
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86474&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：93
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=125939&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：92
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=67227&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：91
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=73856&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：90
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=73881&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：89
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=54599&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：88
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=67182&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：87
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131430&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：86
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=83239&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：85
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131698&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：84
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53514&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：83
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=72758&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：82
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=77853&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：81
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=77156&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：80
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=130935&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：79
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=75833&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：78
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=77229&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：77
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=98037&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：76
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53521&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：75
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53511&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：74
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131094&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：73
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=83923&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：72
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=52518&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：71
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=125156&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：70
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=80178&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：69
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=46717&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：68
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=51685&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：67
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128362&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：66
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128707&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：65
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=76094&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：64
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=103190&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：63
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=140733&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：62
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53515&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：61
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=66966&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：60
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=72100&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：59
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=95001&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：58
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=83278&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：57
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=68055&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：56
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=65302&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：55
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=85424&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：54
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=68058&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：53
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=66384&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：52
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86823&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：51
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=67181&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：50
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53516&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：49
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128376&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：48
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=98359&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：47
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=128359&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：46
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=82619&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：45
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=72809&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：44
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53554&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：43
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135657&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：42
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86918&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：41
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=54701&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：40
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135654&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：39
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=72703&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：38
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=97811&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：37
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134913&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：36
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=106089&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：35
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=142937&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：34
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=73910&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：33
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=91341&PartType=HVAC%20Control%20Module%20Repair%20Kit  <->  [ok] - 剩余数量：32
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134900&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：31
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135665&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：30
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134930&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：29
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34196&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：28
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34410&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：27
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=137791&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：26
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=138427&PartType=Seat%20Heater%20Control%20Module  <->  [ok] - 剩余数量：25
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=48404&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：24
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=35242&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：23
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135588&PartType=Seat%20Heater%20Control%20Module  <->  [ok] - 剩余数量：22
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135661&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：21
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=44119&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：20
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34584&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：19
#   <->  [error] - 剩余数量：18
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135912&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：17
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34333&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：16
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135660&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：15
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34610&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：14
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=138708&PartType=Engine%20Water%20Pump  <->  [ok] - 剩余数量：13
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=48767&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：12
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=138165&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：11
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134869&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：10
#   <->  [error] - 剩余数量：9
#   <->  [error] - 剩余数量：8
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134874&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：7
#   <->  [error] - 剩余数量：6
#   <->  [error] - 剩余数量：5
#   <->  [error] - 剩余数量：4
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135354&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：3
#   <->  [error] - 剩余数量：2
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34612&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：1
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34413&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=100654&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134929&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135653&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135915&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135916&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135651&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134897&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134942&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34208&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=138424&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=137483&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=34159&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=100655&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134876&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134891&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=97810&PartType=HVAC%20Control%20Module  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135032&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=49122&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
# https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=140725&PartType=Blower%20Motor%20Resistor  <->  [ok] - 剩余数量：0
#
# 输出中...
#
# 搞定！
