# %%
param_date = '20240715'

# %%
import os

list_file = sorted(list(os.walk(f'./{param_date}/9.type'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['make_1.ABARTH.xlsx',
#  'make_10.AMERICAN AUSTIN.xlsx',
#  'make_100.GOLIATH.xlsx',
#  'make_101.GORDON-KEEBLE.xlsx',
#  'make_102.GRAHAM.xlsx',
#  'make_103.GRAHAM-PAIGE.xlsx',
#  'make_104.GRIFFITH.xlsx',
#  'make_105.HEALEY.xlsx',
#  'make_106.HENRY J.xlsx',
#  'make_107.HILLMAN.xlsx',
#  'make_108.HINO.xlsx',
#  'make_109.HISPANO-SUIZA.xlsx',
#  'make_11.AMERICAN BANTAM.xlsx',
#  'make_110.HONDA-serial_1.xlsx',
#  'make_110.HONDA-serial_2.xlsx',
#  'make_110.HONDA-serial_3.xlsx',
#  'make_110.HONDA-serial_4.xlsx',
#  'make_110.HONDA-serial_5.xlsx',
#  'make_110.HONDA-serial_6.xlsx',
#  'make_110.HONDA-serial_7.xlsx',
#  'make_110.HONDA-serial_8.xlsx',
#  'make_110.HONDA-serial_9.xlsx',
#  'make_111.HOTCHKISS.xlsx',
#  'make_112.HRG.xlsx',
#  'make_113.HUDSON.xlsx',
#  'make_114.HUMBER.xlsx',
#  'make_115.HUMMER-serial_1.xlsx',
#  'make_115.HUMMER-serial_2.xlsx',
#  'make_116.HUPMOBILE.xlsx',
#  'make_117.HYUNDAI-serial_1.xlsx',
#  'make_117.HYUNDAI-serial_2.xlsx',
#  'make_117.HYUNDAI-serial_3.xlsx',
#  'make_117.HYUNDAI-serial_4.xlsx',
#  'make_117.HYUNDAI-serial_5.xlsx',
#  'make_117.HYUNDAI-serial_6.xlsx',
#  'make_117.HYUNDAI-serial_7.xlsx',
#  'make_117.HYUNDAI-serial_8.xlsx',
#  'make_118.INFINITI-serial_1.xlsx',
#  'make_118.INFINITI-serial_2.xlsx',
#  'make_118.INFINITI-serial_3.xlsx',
#  'make_118.INFINITI-serial_4.xlsx',
#  'make_118.INFINITI-serial_5.xlsx',
#  'make_118.INFINITI-serial_6.xlsx',
#  'make_119.INTERNATIONAL-serial_1.xlsx',
#  'make_119.INTERNATIONAL-serial_10.xlsx',
#  'make_119.INTERNATIONAL-serial_11.xlsx',
#  'make_119.INTERNATIONAL-serial_12.xlsx',
#  'make_119.INTERNATIONAL-serial_13.xlsx',
#  'make_119.INTERNATIONAL-serial_14.xlsx',
#  'make_119.INTERNATIONAL-serial_15.xlsx',
#  'make_119.INTERNATIONAL-serial_16.xlsx',
#  'make_119.INTERNATIONAL-serial_17.xlsx',
#  'make_119.INTERNATIONAL-serial_18.xlsx',
#  'make_119.INTERNATIONAL-serial_19.xlsx',
#  'make_119.INTERNATIONAL-serial_2.xlsx',
#  'make_119.INTERNATIONAL-serial_3.xlsx',
#  'make_119.INTERNATIONAL-serial_4.xlsx',
#  'make_119.INTERNATIONAL-serial_5.xlsx',
#  'make_119.INTERNATIONAL-serial_6.xlsx',
#  'make_119.INTERNATIONAL-serial_7.xlsx',
#  'make_119.INTERNATIONAL-serial_8.xlsx',
#  'make_119.INTERNATIONAL-serial_9.xlsx',
#  'make_12.AMERICAN MOTORS-serial_1.xlsx',
#  'make_12.AMERICAN MOTORS-serial_2.xlsx',
#  'make_12.AMERICAN MOTORS-serial_3.xlsx',
#  'make_12.AMERICAN MOTORS-serial_4.xlsx',
#  'make_12.AMERICAN MOTORS-serial_5.xlsx',
#  'make_12.AMERICAN MOTORS-serial_6.xlsx',
#  'make_12.AMERICAN MOTORS-serial_7.xlsx',
#  'make_12.AMERICAN MOTORS-serial_8.xlsx',
#  'make_12.AMERICAN MOTORS-serial_9.xlsx',
#  'make_120.ISO.xlsx',
#  'make_121.ISUZU-serial_1.xlsx',
#  'make_121.ISUZU-serial_2.xlsx',
#  'make_121.ISUZU-serial_3.xlsx',
#  'make_121.ISUZU-serial_4.xlsx',
#  'make_121.ISUZU-serial_5.xlsx',
#  'make_121.ISUZU-serial_6.xlsx',
#  'make_121.ISUZU-serial_7.xlsx',
#  'make_121.ISUZU-serial_8.xlsx',
#  'make_122.IVECO.xlsx',
#  'make_123.JAC.xlsx',
#  'make_124.JAGUAR-serial_1.xlsx',
#  'make_124.JAGUAR-serial_2.xlsx',
#  'make_124.JAGUAR-serial_3.xlsx',
#  'make_124.JAGUAR-serial_4.xlsx',
#  'make_124.JAGUAR-serial_5.xlsx',
#  'make_124.JAGUAR-serial_6.xlsx',
#  'make_124.JAGUAR-serial_7.xlsx',
#  'make_125.JEEP-serial_1.xlsx',
#  'make_125.JEEP-serial_10.xlsx',
#  'make_125.JEEP-serial_11.xlsx',
#  'make_125.JEEP-serial_12.xlsx',
#  'make_125.JEEP-serial_13.xlsx',
#  'make_125.JEEP-serial_14.xlsx',
#  'make_125.JEEP-serial_15.xlsx',
#  'make_125.JEEP-serial_16.xlsx',
#  'make_125.JEEP-serial_17.xlsx',
#  'make_125.JEEP-serial_18.xlsx',
#  'make_125.JEEP-serial_19.xlsx',
#  'make_125.JEEP-serial_2.xlsx',
#  'make_125.JEEP-serial_20.xlsx',
#  'make_125.JEEP-serial_21.xlsx',
#  'make_125.JEEP-serial_22.xlsx',
#  'make_125.JEEP-serial_23.xlsx',
#  'make_125.JEEP-serial_3.xlsx',
#  'make_125.JEEP-serial_4.xlsx',
#  'make_125.JEEP-serial_5.xlsx',
#  'make_125.JEEP-serial_6.xlsx',
#  'make_125.JEEP-serial_7.xlsx',
#  'make_125.JEEP-serial_8.xlsx',
#  'make_125.JEEP-serial_9.xlsx',
#  'make_126.JENSEN.xlsx',
#  'make_127.JEWETT.xlsx',
#  'make_128.JMC.xlsx',
#  'make_129.JORDAN.xlsx',
#  'make_13.AMPHICAR.xlsx',
#  'make_130.JOWETT.xlsx',
#  'make_131.KAISER-FRAZER.xlsx',
#  'make_132.KARMA.xlsx',
#  'make_133.KENWORTH.xlsx',
#  'make_134.KIA-serial_1.xlsx',
#  'make_134.KIA-serial_2.xlsx',
#  'make_134.KIA-serial_3.xlsx',
#  'make_134.KIA-serial_4.xlsx',
#  'make_134.KIA-serial_5.xlsx',
#  'make_134.KIA-serial_6.xlsx',
#  'make_134.KIA-serial_7.xlsx',
#  'make_134.KIA-serial_8.xlsx',
#  'make_134.KIA-serial_9.xlsx',
#  'make_135.KISSEL.xlsx',
#  'make_136.KURTIS.xlsx',
#  'make_137.LADA.xlsx',
#  'make_138.LAFORZA.xlsx',
#  'make_139.LAGONDA.xlsx',
#  'make_14.APOLLO.xlsx',
#  'make_140.LAMBORGHINI.xlsx',
#  'make_141.LANCHESTER.xlsx',
#  'make_142.LANCIA.xlsx',
#  'make_143.LAND ROVER-serial_1.xlsx',
#  'make_143.LAND ROVER-serial_2.xlsx',
#  'make_143.LAND ROVER-serial_3.xlsx',
#  'make_143.LAND ROVER-serial_4.xlsx',
#  'make_144.LASALLE.xlsx',
#  'make_145.LEA-FRANCIS.xlsx',
#  'make_146.LEXINGTON.xlsx',
#  'make_147.LEXUS-serial_1.xlsx',
#  'make_147.LEXUS-serial_10.xlsx',
#  'make_147.LEXUS-serial_11.xlsx',
#  'make_147.LEXUS-serial_2.xlsx',
#  'make_147.LEXUS-serial_3.xlsx',
#  'make_147.LEXUS-serial_4.xlsx',
#  'make_147.LEXUS-serial_5.xlsx',
#  'make_147.LEXUS-serial_6.xlsx',
#  'make_147.LEXUS-serial_7.xlsx',
#  'make_147.LEXUS-serial_8.xlsx',
#  'make_147.LEXUS-serial_9.xlsx',
#  'make_148.LINCOLN-serial_1.xlsx',
#  'make_148.LINCOLN-serial_2.xlsx',
#  'make_148.LINCOLN-serial_3.xlsx',
#  'make_148.LINCOLN-serial_4.xlsx',
#  'make_148.LINCOLN-serial_5.xlsx',
#  'make_148.LINCOLN-serial_6.xlsx',
#  'make_148.LINCOLN-serial_7.xlsx',
#  'make_148.LINCOLN-serial_8.xlsx',
#  'make_148.LINCOLN-serial_9.xlsx',
#  'make_149.LORDSTOWN MOTORS.xlsx',
#  'make_15.ARMSTRONG-SIDDELEY.xlsx',
#  'make_150.LOTUS.xlsx',
#  'make_151.LUCID.xlsx',
#  'make_152.MACK.xlsx',
#  'make_153.MAICO.xlsx',
#  'make_154.MARATHON.xlsx',
#  'make_155.MARAUDER.xlsx',
#  'make_156.MARCOS.xlsx',
#  'make_157.MARMON.xlsx',
#  'make_158.MASERATI.xlsx',
#  'make_159.MASTRETTA.xlsx',
#  'make_16.ARNOLT-BRISTOL.xlsx',
#  'make_160.MATRA.xlsx',
#  'make_161.MAXWELL.xlsx',
#  'make_162.MAYBACH.xlsx',
#  'make_163.MAZDA-serial_1.xlsx',
#  'make_163.MAZDA-serial_10.xlsx',
#  'make_163.MAZDA-serial_11.xlsx',
#  'make_163.MAZDA-serial_12.xlsx',
#  'make_163.MAZDA-serial_13.xlsx',
#  'make_163.MAZDA-serial_14.xlsx',
#  'make_163.MAZDA-serial_2.xlsx',
#  'make_163.MAZDA-serial_3.xlsx',
#  'make_163.MAZDA-serial_4.xlsx',
#  'make_163.MAZDA-serial_5.xlsx',
#  'make_163.MAZDA-serial_6.xlsx',
#  'make_163.MAZDA-serial_7.xlsx',
#  'make_163.MAZDA-serial_8.xlsx',
#  'make_163.MAZDA-serial_9.xlsx',
#  'make_164.MCLAREN.xlsx',
#  'make_165.MERCEDES-BENZ-serial_1.xlsx',
#  'make_165.MERCEDES-BENZ-serial_10.xlsx',
#  'make_165.MERCEDES-BENZ-serial_11.xlsx',
#  'make_165.MERCEDES-BENZ-serial_12.xlsx',
#  'make_165.MERCEDES-BENZ-serial_13.xlsx',
#  'make_165.MERCEDES-BENZ-serial_14.xlsx',
#  'make_165.MERCEDES-BENZ-serial_15.xlsx',
#  'make_165.MERCEDES-BENZ-serial_16.xlsx',
#  'make_165.MERCEDES-BENZ-serial_17.xlsx',
#  'make_165.MERCEDES-BENZ-serial_18.xlsx',
#  'make_165.MERCEDES-BENZ-serial_19.xlsx',
#  'make_165.MERCEDES-BENZ-serial_2.xlsx',
#  'make_165.MERCEDES-BENZ-serial_20.xlsx',
#  'make_165.MERCEDES-BENZ-serial_21.xlsx',
#  'make_165.MERCEDES-BENZ-serial_22.xlsx',
#  'make_165.MERCEDES-BENZ-serial_23.xlsx',
#  'make_165.MERCEDES-BENZ-serial_24.xlsx',
#  'make_165.MERCEDES-BENZ-serial_25.xlsx',
#  'make_165.MERCEDES-BENZ-serial_26.xlsx',
#  'make_165.MERCEDES-BENZ-serial_27.xlsx',
#  'make_165.MERCEDES-BENZ-serial_28.xlsx',
#  'make_165.MERCEDES-BENZ-serial_29.xlsx',
#  'make_165.MERCEDES-BENZ-serial_3.xlsx',
#  'make_165.MERCEDES-BENZ-serial_30.xlsx',
#  'make_165.MERCEDES-BENZ-serial_31.xlsx',
#  'make_165.MERCEDES-BENZ-serial_32.xlsx',
#  'make_165.MERCEDES-BENZ-serial_33.xlsx',
#  'make_165.MERCEDES-BENZ-serial_34.xlsx',
#  'make_165.MERCEDES-BENZ-serial_35.xlsx',
#  'make_165.MERCEDES-BENZ-serial_36.xlsx',
#  'make_165.MERCEDES-BENZ-serial_37.xlsx',
#  'make_165.MERCEDES-BENZ-serial_4.xlsx',
#  'make_165.MERCEDES-BENZ-serial_5.xlsx',
#  'make_165.MERCEDES-BENZ-serial_6.xlsx',
#  'make_165.MERCEDES-BENZ-serial_7.xlsx',
#  'make_165.MERCEDES-BENZ-serial_8.xlsx',
#  'make_165.MERCEDES-BENZ-serial_9.xlsx',
#  'make_166.MERCURY-serial_1.xlsx',
#  'make_166.MERCURY-serial_10.xlsx',
#  'make_166.MERCURY-serial_11.xlsx',
#  'make_166.MERCURY-serial_12.xlsx',
#  'make_166.MERCURY-serial_13.xlsx',
#  'make_166.MERCURY-serial_14.xlsx',
#  'make_166.MERCURY-serial_15.xlsx',
#  'make_166.MERCURY-serial_16.xlsx',
#  'make_166.MERCURY-serial_17.xlsx',
#  'make_166.MERCURY-serial_18.xlsx',
#  'make_166.MERCURY-serial_19.xlsx',
#  'make_166.MERCURY-serial_2.xlsx',
#  'make_166.MERCURY-serial_3.xlsx',
#  'make_166.MERCURY-serial_4.xlsx',
#  'make_166.MERCURY-serial_5.xlsx',
#  'make_166.MERCURY-serial_6.xlsx',
#  'make_166.MERCURY-serial_7.xlsx',
#  'make_166.MERCURY-serial_8.xlsx',
#  'make_166.MERCURY-serial_9.xlsx',
#  'make_167.MERKUR.xlsx',
#  'make_168.MESSERSCHMITT.xlsx',
#  'make_169.MG.xlsx',
#  'make_17.ARNOLT-MG.xlsx',
#  'make_170.MINI-serial_1.xlsx',
#  'make_170.MINI-serial_2.xlsx',
#  'make_170.MINI-serial_3.xlsx',
#  'make_171.MITSUBISHI-serial_1.xlsx',
#  'make_171.MITSUBISHI-serial_10.xlsx',
#  'make_171.MITSUBISHI-serial_11.xlsx',
#  'make_171.MITSUBISHI-serial_2.xlsx',
#  'make_171.MITSUBISHI-serial_3.xlsx',
#  'make_171.MITSUBISHI-serial_4.xlsx',
#  'make_171.MITSUBISHI-serial_5.xlsx',
#  'make_171.MITSUBISHI-serial_6.xlsx',
#  'make_171.MITSUBISHI-serial_7.xlsx',
#  'make_171.MITSUBISHI-serial_8.xlsx',
#  'make_171.MITSUBISHI-serial_9.xlsx',
#  'make_172.MITSUBISHI FUSO.xlsx',
#  'make_173.MOBILITY VENTURES.xlsx',
#  'make_174.MONTEVERDI.xlsx',
#  'make_175.MOON.xlsx',
#  'make_176.MORETTI.xlsx',
#  'make_177.MORGAN.xlsx',
#  'make_178.MORRIS.xlsx',
#  'make_179.MOSKVICH.xlsx',
#  'make_18.ASTON MARTIN.xlsx',
#  'make_180.NARDI.xlsx',
#  'make_181.NASH.xlsx',
#  'make_182.NISSAN-serial_1.xlsx',
#  'make_182.NISSAN-serial_10.xlsx',
#  'make_182.NISSAN-serial_11.xlsx',
#  'make_182.NISSAN-serial_12.xlsx',
#  'make_182.NISSAN-serial_13.xlsx',
#  'make_182.NISSAN-serial_14.xlsx',
#  'make_182.NISSAN-serial_15.xlsx',
#  'make_182.NISSAN-serial_16.xlsx',
#  'make_182.NISSAN-serial_17.xlsx',
#  'make_182.NISSAN-serial_18.xlsx',
#  'make_182.NISSAN-serial_19.xlsx',
#  'make_182.NISSAN-serial_2.xlsx',
#  'make_182.NISSAN-serial_20.xlsx',
#  'make_182.NISSAN-serial_21.xlsx',
#  'make_182.NISSAN-serial_22.xlsx',
#  'make_182.NISSAN-serial_3.xlsx',
#  'make_182.NISSAN-serial_4.xlsx',
#  'make_182.NISSAN-serial_5.xlsx',
#  'make_182.NISSAN-serial_6.xlsx',
#  'make_182.NISSAN-serial_7.xlsx',
#  'make_182.NISSAN-serial_8.xlsx',
#  'make_182.NISSAN-serial_9.xlsx',
#  'make_183.NSU.xlsx',
#  'make_184.OAKLAND.xlsx',
#  'make_185.OLDSMOBILE-serial_1.xlsx',
#  'make_185.OLDSMOBILE-serial_10.xlsx',
#  'make_185.OLDSMOBILE-serial_11.xlsx',
#  'make_185.OLDSMOBILE-serial_12.xlsx',
#  'make_185.OLDSMOBILE-serial_13.xlsx',
#  'make_185.OLDSMOBILE-serial_14.xlsx',
#  'make_185.OLDSMOBILE-serial_15.xlsx',
#  'make_185.OLDSMOBILE-serial_16.xlsx',
#  'make_185.OLDSMOBILE-serial_17.xlsx',
#  'make_185.OLDSMOBILE-serial_18.xlsx',
#  'make_185.OLDSMOBILE-serial_19.xlsx',
#  'make_185.OLDSMOBILE-serial_2.xlsx',
#  'make_185.OLDSMOBILE-serial_20.xlsx',
#  'make_185.OLDSMOBILE-serial_21.xlsx',
#  'make_185.OLDSMOBILE-serial_3.xlsx',
#  'make_185.OLDSMOBILE-serial_4.xlsx',
#  'make_185.OLDSMOBILE-serial_5.xlsx',
#  'make_185.OLDSMOBILE-serial_6.xlsx',
#  'make_185.OLDSMOBILE-serial_7.xlsx',
#  'make_185.OLDSMOBILE-serial_8.xlsx',
#  'make_185.OLDSMOBILE-serial_9.xlsx',
#  'make_186.OMEGA.xlsx',
#  'make_187.OPEL.xlsx',
#  'make_188.OSCA.xlsx',
#  'make_189.PACKARD.xlsx',
#  'make_19.ASUNA.xlsx',
#  'make_190.PAIGE.xlsx',
#  'make_191.PANHARD.xlsx',
#  'make_192.PANOZ.xlsx',
#  'make_193.PANTHER.xlsx',
#  'make_194.PASSPORT.xlsx',
#  'make_195.PEERLESS.xlsx',
#  'make_196.PEGASO.xlsx',
#  'make_197.PETERBILT.xlsx',
#  'make_198.PEUGEOT-serial_1.xlsx',
#  'make_198.PEUGEOT-serial_2.xlsx',
#  'make_198.PEUGEOT-serial_3.xlsx',
#  'make_199.PIERCE-ARROW.xlsx',
#  'make_2.AC.xlsx',
#  'make_20.AUBURN.xlsx',
#  'make_200.PLYMOUTH-serial_1.xlsx',
#  'make_200.PLYMOUTH-serial_10.xlsx',
#  'make_200.PLYMOUTH-serial_11.xlsx',
#  'make_200.PLYMOUTH-serial_12.xlsx',
#  'make_200.PLYMOUTH-serial_13.xlsx',
#  'make_200.PLYMOUTH-serial_14.xlsx',
#  'make_200.PLYMOUTH-serial_15.xlsx',
#  'make_200.PLYMOUTH-serial_16.xlsx',
#  'make_200.PLYMOUTH-serial_17.xlsx',
#  'make_200.PLYMOUTH-serial_18.xlsx',
#  'make_200.PLYMOUTH-serial_19.xlsx',
#  'make_200.PLYMOUTH-serial_2.xlsx',
#  'make_200.PLYMOUTH-serial_20.xlsx',
#  'make_200.PLYMOUTH-serial_21.xlsx',
#  'make_200.PLYMOUTH-serial_22.xlsx',
#  'make_200.PLYMOUTH-serial_23.xlsx',
#  'make_200.PLYMOUTH-serial_24.xlsx',
#  'make_200.PLYMOUTH-serial_25.xlsx',
#  'make_200.PLYMOUTH-serial_26.xlsx',
#  'make_200.PLYMOUTH-serial_3.xlsx',
#  'make_200.PLYMOUTH-serial_4.xlsx',
#  'make_200.PLYMOUTH-serial_5.xlsx',
#  'make_200.PLYMOUTH-serial_6.xlsx',
#  'make_200.PLYMOUTH-serial_7.xlsx',
#  'make_200.PLYMOUTH-serial_8.xlsx',
#  'make_200.PLYMOUTH-serial_9.xlsx',
#  'make_201.POLESTAR.xlsx',
#  'make_202.PONTIAC-serial_1.xlsx',
#  'make_202.PONTIAC-serial_10.xlsx',
#  'make_202.PONTIAC-serial_11.xlsx',
#  'make_202.PONTIAC-serial_12.xlsx',
#  'make_202.PONTIAC-serial_13.xlsx',
#  'make_202.PONTIAC-serial_14.xlsx',
#  'make_202.PONTIAC-serial_15.xlsx',
#  'make_202.PONTIAC-serial_16.xlsx',
#  'make_202.PONTIAC-serial_17.xlsx',
#  'make_202.PONTIAC-serial_18.xlsx',
#  'make_202.PONTIAC-serial_19.xlsx',
#  'make_202.PONTIAC-serial_2.xlsx',
#  'make_202.PONTIAC-serial_20.xlsx',
#  'make_202.PONTIAC-serial_21.xlsx',
#  'make_202.PONTIAC-serial_22.xlsx',
#  'make_202.PONTIAC-serial_23.xlsx',
#  'make_202.PONTIAC-serial_24.xlsx',
#  'make_202.PONTIAC-serial_25.xlsx',
#  'make_202.PONTIAC-serial_26.xlsx',
#  'make_202.PONTIAC-serial_3.xlsx',
#  'make_202.PONTIAC-serial_4.xlsx',
#  'make_202.PONTIAC-serial_5.xlsx',
#  'make_202.PONTIAC-serial_6.xlsx',
#  'make_202.PONTIAC-serial_7.xlsx',
#  'make_202.PONTIAC-serial_8.xlsx',
#  'make_202.PONTIAC-serial_9.xlsx',
#  'make_203.PORSCHE-serial_1.xlsx',
#  'make_203.PORSCHE-serial_2.xlsx',
#  'make_203.PORSCHE-serial_3.xlsx',
#  'make_203.PORSCHE-serial_4.xlsx',
#  'make_203.PORSCHE-serial_5.xlsx',
#  'make_203.PORSCHE-serial_6.xlsx',
#  'make_204.QVALE.xlsx',
#  'make_205.RAM-serial_1.xlsx',
#  'make_205.RAM-serial_2.xlsx',
#  'make_205.RAM-serial_3.xlsx',
#  'make_205.RAM-serial_4.xlsx',
#  'make_205.RAM-serial_5.xlsx',
#  'make_205.RAM-serial_6.xlsx',
#  'make_205.RAM-serial_7.xlsx',
#  'make_205.RAM-serial_8.xlsx',
#  'make_206.RELIANT.xlsx',
#  'make_207.RENAULT-serial_1.xlsx',
#  'make_207.RENAULT-serial_2.xlsx',
#  'make_207.RENAULT-serial_3.xlsx',
#  'make_208.REO.xlsx',
#  'make_209.RICKENBACKER.xlsx',
#  'make_21.AUDI-serial_1.xlsx',
#  'make_21.AUDI-serial_10.xlsx',
#  'make_21.AUDI-serial_11.xlsx',
#  'make_21.AUDI-serial_12.xlsx',
#  'make_21.AUDI-serial_13.xlsx',
#  'make_21.AUDI-serial_14.xlsx',
#  'make_21.AUDI-serial_2.xlsx',
#  'make_21.AUDI-serial_3.xlsx',
#  'make_21.AUDI-serial_4.xlsx',
#  'make_21.AUDI-serial_5.xlsx',
#  'make_21.AUDI-serial_6.xlsx',
#  'make_21.AUDI-serial_7.xlsx',
#  'make_21.AUDI-serial_8.xlsx',
#  'make_21.AUDI-serial_9.xlsx',
#  'make_210.RILEY.xlsx',
#  'make_211.RIVIAN.xlsx',
#  'make_212.ROAMER.xlsx',
#  'make_213.ROCKNE.xlsx',
#  'make_214.ROLLS-ROYCE-serial_1.xlsx',
#  'make_214.ROLLS-ROYCE-serial_2.xlsx',
#  'make_215.ROVER.xlsx',
#  'make_216.SAAB-serial_1.xlsx',
#  'make_216.SAAB-serial_2.xlsx',
#  'make_216.SAAB-serial_3.xlsx',
#  'make_216.SAAB-serial_4.xlsx',
#  'make_217.SABRA.xlsx',
#  'make_218.SALEEN.xlsx',
#  'make_219.SALMSON.xlsx',
#  'make_22.AUSTIN.xlsx',
#  'make_220.SATURN-serial_1.xlsx',
#  'make_220.SATURN-serial_2.xlsx',
#  'make_220.SATURN-serial_3.xlsx',
#  'make_220.SATURN-serial_4.xlsx',
#  'make_220.SATURN-serial_5.xlsx',
#  'make_221.SCION-serial_1.xlsx',
#  'make_221.SCION-serial_2.xlsx',
#  'make_222.SEAT-serial_1.xlsx',
#  'make_222.SEAT-serial_2.xlsx',
#  'make_223.SHELBY.xlsx',
#  'make_224.SIATA.xlsx',
#  'make_225.SIMCA.xlsx',
#  'make_226.SINGER.xlsx',
#  'make_227.SKODA.xlsx',
#  'make_228.SMART.xlsx',
#  'make_229.SPYKER.xlsx',
#  'make_23.AUSTIN-HEALEY.xlsx',
#  'make_230.SRT.xlsx',
#  'make_231.SSANGYONG.xlsx',
#  'make_232.STANDARD.xlsx',
#  'make_233.STAR.xlsx',
#  'make_234.STEARNS KNIGHT.xlsx',
#  'make_235.STERLING.xlsx',
#  'make_236.STEVENS-DURYEA.xlsx',
#  'make_237.STUDEBAKER-serial_1.xlsx',
#  'make_237.STUDEBAKER-serial_2.xlsx',
#  'make_237.STUDEBAKER-serial_3.xlsx',
#  'make_237.STUDEBAKER-serial_4.xlsx',
#  'make_238.STUTZ.xlsx',
#  'make_239.SUBARU-serial_1.xlsx',
#  'make_239.SUBARU-serial_2.xlsx',
#  'make_239.SUBARU-serial_3.xlsx',
#  'make_239.SUBARU-serial_4.xlsx',
#  'make_239.SUBARU-serial_5.xlsx',
#  'make_239.SUBARU-serial_6.xlsx',
#  'make_239.SUBARU-serial_7.xlsx',
#  'make_239.SUBARU-serial_8.xlsx',
#  'make_24.AVANTI.xlsx',
#  'make_240.SUNBEAM.xlsx',
#  'make_241.SUZUKI-serial_1.xlsx',
#  'make_241.SUZUKI-serial_2.xlsx',
#  'make_241.SUZUKI-serial_3.xlsx',
#  'make_241.SUZUKI-serial_4.xlsx',
#  'make_242.SWALLOW.xlsx',
#  'make_243.TALBOT-LAGO.xlsx',
#  'make_244.TATRA.xlsx',
#  'make_245.TESLA.xlsx',
#  'make_246.THINK.xlsx',
#  'make_247.TOYOTA-serial_1.xlsx',
#  'make_247.TOYOTA-serial_10.xlsx',
#  'make_247.TOYOTA-serial_11.xlsx',
#  'make_247.TOYOTA-serial_12.xlsx',
#  'make_247.TOYOTA-serial_13.xlsx',
#  'make_247.TOYOTA-serial_14.xlsx',
#  'make_247.TOYOTA-serial_15.xlsx',
#  'make_247.TOYOTA-serial_16.xlsx',
#  'make_247.TOYOTA-serial_17.xlsx',
#  'make_247.TOYOTA-serial_18.xlsx',
#  'make_247.TOYOTA-serial_19.xlsx',
#  'make_247.TOYOTA-serial_2.xlsx',
#  'make_247.TOYOTA-serial_20.xlsx',
#  'make_247.TOYOTA-serial_21.xlsx',
#  'make_247.TOYOTA-serial_3.xlsx',
#  'make_247.TOYOTA-serial_4.xlsx',
#  'make_247.TOYOTA-serial_5.xlsx',
#  'make_247.TOYOTA-serial_6.xlsx',
#  'make_247.TOYOTA-serial_7.xlsx',
#  'make_247.TOYOTA-serial_8.xlsx',
#  'make_247.TOYOTA-serial_9.xlsx',
#  'make_248.TRIUMPH.xlsx',
#  'make_249.TURNER.xlsx',
#  'make_25.BAIC.xlsx',
#  'make_250.TVR.xlsx',
#  'make_251.UAZ.xlsx',
#  'make_252.UD.xlsx',
#  'make_253.UTILIMASTER.xlsx',
#  'make_254.VAM.xlsx',
#  'make_255.VAUXHALL.xlsx',
#  'make_256.VESPA.xlsx',
#  'make_257.VINFAST.xlsx',
#  'make_258.VOLKSWAGEN-serial_1.xlsx',
#  'make_258.VOLKSWAGEN-serial_10.xlsx',
#  'make_258.VOLKSWAGEN-serial_11.xlsx',
#  'make_258.VOLKSWAGEN-serial_12.xlsx',
#  'make_258.VOLKSWAGEN-serial_13.xlsx',
#  'make_258.VOLKSWAGEN-serial_14.xlsx',
#  'make_258.VOLKSWAGEN-serial_15.xlsx',
#  'make_258.VOLKSWAGEN-serial_2.xlsx',
#  'make_258.VOLKSWAGEN-serial_3.xlsx',
#  'make_258.VOLKSWAGEN-serial_4.xlsx',
#  'make_258.VOLKSWAGEN-serial_5.xlsx',
#  'make_258.VOLKSWAGEN-serial_6.xlsx',
#  'make_258.VOLKSWAGEN-serial_7.xlsx',
#  'make_258.VOLKSWAGEN-serial_8.xlsx',
#  'make_258.VOLKSWAGEN-serial_9.xlsx',
#  'make_259.VOLVO-serial_1.xlsx',
#  'make_259.VOLVO-serial_10.xlsx',
#  'make_259.VOLVO-serial_11.xlsx',
#  'make_259.VOLVO-serial_2.xlsx',
#  'make_259.VOLVO-serial_3.xlsx',
#  'make_259.VOLVO-serial_4.xlsx',
#  'make_259.VOLVO-serial_5.xlsx',
#  'make_259.VOLVO-serial_6.xlsx',
#  'make_259.VOLVO-serial_7.xlsx',
#  'make_259.VOLVO-serial_8.xlsx',
#  'make_259.VOLVO-serial_9.xlsx',
#  'make_26.BENTLEY.xlsx',
#  'make_260.VPG.xlsx',
#  'make_261.WARTBURG.xlsx',
#  'make_262.WESTCOTT.xlsx',
#  'make_263.WHIPPET.xlsx',
#  'make_264.WILLYS.xlsx',
#  'make_265.WINDSOR.xlsx',
#  'make_266.WOLSELEY.xlsx',
#  'make_267.WORKHORSE.xlsx',
#  'make_268.YELLOW CAB.xlsx',
#  'make_269.YUGO.xlsx',
#  'make_27.BERKELEY.xlsx',
#  'make_270.ZACUA.xlsx',
#  'make_271.ZUNDAPP.xlsx',
#  'make_28.BIZZARRINI.xlsx',
#  'make_29.BMW-serial_1.xlsx',
#  'make_29.BMW-serial_10.xlsx',
#  'make_29.BMW-serial_11.xlsx',
#  'make_29.BMW-serial_12.xlsx',
#  'make_29.BMW-serial_13.xlsx',
#  'make_29.BMW-serial_14.xlsx',
#  'make_29.BMW-serial_15.xlsx',
#  'make_29.BMW-serial_16.xlsx',
#  'make_29.BMW-serial_17.xlsx',
#  'make_29.BMW-serial_18.xlsx',
#  'make_29.BMW-serial_19.xlsx',
#  'make_29.BMW-serial_2.xlsx',
#  'make_29.BMW-serial_20.xlsx',
#  'make_29.BMW-serial_21.xlsx',
#  'make_29.BMW-serial_22.xlsx',
#  'make_29.BMW-serial_23.xlsx',
#  'make_29.BMW-serial_24.xlsx',
#  'make_29.BMW-serial_25.xlsx',
#  'make_29.BMW-serial_26.xlsx',
#  'make_29.BMW-serial_27.xlsx',
#  'make_29.BMW-serial_28.xlsx',
#  'make_29.BMW-serial_3.xlsx',
#  'make_29.BMW-serial_4.xlsx',
#  'make_29.BMW-serial_5.xlsx',
#  'make_29.BMW-serial_6.xlsx',
#  'make_29.BMW-serial_7.xlsx',
#  'make_29.BMW-serial_8.xlsx',
#  'make_29.BMW-serial_9.xlsx',
#  'make_3.ACURA-serial_1.xlsx',
#  'make_3.ACURA-serial_2.xlsx',
#  'make_3.ACURA-serial_3.xlsx',
#  'make_3.ACURA-serial_4.xlsx',
#  'make_3.ACURA-serial_5.xlsx',
#  'make_3.ACURA-serial_6.xlsx',
#  'make_3.ACURA-serial_7.xlsx',
#  'make_30.BOND.xlsx',
#  'make_31.BORGWARD.xlsx',
#  'make_32.BRICKLIN.xlsx',
#  'make_33.BRIGHTDROP.xlsx',
#  'make_34.BRISTOL.xlsx',
#  'make_35.BUGATTI.xlsx',
#  'make_36.BUICK-serial_1.xlsx',
#  'make_36.BUICK-serial_10.xlsx',
#  'make_36.BUICK-serial_11.xlsx',
#  'make_36.BUICK-serial_12.xlsx',
#  'make_36.BUICK-serial_13.xlsx',
#  'make_36.BUICK-serial_14.xlsx',
#  'make_36.BUICK-serial_15.xlsx',
#  'make_36.BUICK-serial_16.xlsx',
#  'make_36.BUICK-serial_17.xlsx',
#  'make_36.BUICK-serial_2.xlsx',
#  'make_36.BUICK-serial_3.xlsx',
#  'make_36.BUICK-serial_4.xlsx',
#  'make_36.BUICK-serial_5.xlsx',
#  'make_36.BUICK-serial_6.xlsx',
#  'make_36.BUICK-serial_7.xlsx',
#  'make_36.BUICK-serial_8.xlsx',
#  'make_36.BUICK-serial_9.xlsx',
#  'make_37.CADILLAC-serial_1.xlsx',
#  'make_37.CADILLAC-serial_10.xlsx',
#  'make_37.CADILLAC-serial_11.xlsx',
#  'make_37.CADILLAC-serial_12.xlsx',
#  'make_37.CADILLAC-serial_13.xlsx',
#  'make_37.CADILLAC-serial_14.xlsx',
#  'make_37.CADILLAC-serial_15.xlsx',
#  'make_37.CADILLAC-serial_2.xlsx',
#  'make_37.CADILLAC-serial_3.xlsx',
#  'make_37.CADILLAC-serial_4.xlsx',
#  'make_37.CADILLAC-serial_5.xlsx',
#  'make_37.CADILLAC-serial_6.xlsx',
#  'make_37.CADILLAC-serial_7.xlsx',
#  'make_37.CADILLAC-serial_8.xlsx',
#  'make_37.CADILLAC-serial_9.xlsx',
#  'make_38.CASE.xlsx',
#  'make_39.CHANGAN.xlsx',
#  'make_4.ALFA ROMEO-serial_1.xlsx',
#  'make_4.ALFA ROMEO-serial_2.xlsx',
#  'make_40.CHECKER-serial_1.xlsx',
#  'make_40.CHECKER-serial_2.xlsx',
#  'make_41.CHEVROLET-serial_1.xlsx',
#  'make_41.CHEVROLET-serial_10.xlsx',
#  'make_41.CHEVROLET-serial_11.xlsx',
#  'make_41.CHEVROLET-serial_12.xlsx',
#  'make_41.CHEVROLET-serial_13.xlsx',
#  'make_41.CHEVROLET-serial_14.xlsx',
#  'make_41.CHEVROLET-serial_15.xlsx',
#  'make_41.CHEVROLET-serial_16.xlsx',
#  'make_41.CHEVROLET-serial_17.xlsx',
#  'make_41.CHEVROLET-serial_18.xlsx',
#  'make_41.CHEVROLET-serial_19.xlsx',
#  'make_41.CHEVROLET-serial_2.xlsx',
#  'make_41.CHEVROLET-serial_20.xlsx',
#  'make_41.CHEVROLET-serial_21.xlsx',
#  'make_41.CHEVROLET-serial_22.xlsx',
#  'make_41.CHEVROLET-serial_23.xlsx',
#  'make_41.CHEVROLET-serial_24.xlsx',
#  'make_41.CHEVROLET-serial_25.xlsx',
#  'make_41.CHEVROLET-serial_26.xlsx',
#  'make_41.CHEVROLET-serial_27.xlsx',
#  'make_41.CHEVROLET-serial_28.xlsx',
#  'make_41.CHEVROLET-serial_29.xlsx',
#  'make_41.CHEVROLET-serial_3.xlsx',
#  'make_41.CHEVROLET-serial_30.xlsx',
#  'make_41.CHEVROLET-serial_31.xlsx',
#  'make_41.CHEVROLET-serial_32.xlsx',
#  'make_41.CHEVROLET-serial_33.xlsx',
#  'make_41.CHEVROLET-serial_34.xlsx',
#  'make_41.CHEVROLET-serial_35.xlsx',
#  'make_41.CHEVROLET-serial_36.xlsx',
#  'make_41.CHEVROLET-serial_37.xlsx',
#  'make_41.CHEVROLET-serial_38.xlsx',
#  'make_41.CHEVROLET-serial_39.xlsx',
#  'make_41.CHEVROLET-serial_4.xlsx',
#  'make_41.CHEVROLET-serial_40.xlsx',
#  'make_41.CHEVROLET-serial_41.xlsx',
#  'make_41.CHEVROLET-serial_42.xlsx',
#  'make_41.CHEVROLET-serial_43.xlsx',
#  'make_41.CHEVROLET-serial_44.xlsx',
#  'make_41.CHEVROLET-serial_45.xlsx',
#  'make_41.CHEVROLET-serial_46.xlsx',
#  'make_41.CHEVROLET-serial_47.xlsx',
#  'make_41.CHEVROLET-serial_48.xlsx',
#  'make_41.CHEVROLET-serial_49.xlsx',
#  'make_41.CHEVROLET-serial_5.xlsx',
#  'make_41.CHEVROLET-serial_50.xlsx',
#  'make_41.CHEVROLET-serial_51.xlsx',
#  'make_41.CHEVROLET-serial_52.xlsx',
#  'make_41.CHEVROLET-serial_53.xlsx',
#  'make_41.CHEVROLET-serial_54.xlsx',
#  'make_41.CHEVROLET-serial_55.xlsx',
#  'make_41.CHEVROLET-serial_56.xlsx',
#  'make_41.CHEVROLET-serial_57.xlsx',
#  'make_41.CHEVROLET-serial_58.xlsx',
#  'make_41.CHEVROLET-serial_59.xlsx',
#  'make_41.CHEVROLET-serial_6.xlsx',
#  'make_41.CHEVROLET-serial_60.xlsx',
#  'make_41.CHEVROLET-serial_61.xlsx',
#  'make_41.CHEVROLET-serial_62.xlsx',
#  'make_41.CHEVROLET-serial_63.xlsx',
#  'make_41.CHEVROLET-serial_64.xlsx',
#  'make_41.CHEVROLET-serial_65.xlsx',
#  'make_41.CHEVROLET-serial_66.xlsx',
#  'make_41.CHEVROLET-serial_67.xlsx',
#  'make_41.CHEVROLET-serial_68.xlsx',
#  'make_41.CHEVROLET-serial_69.xlsx',
#  'make_41.CHEVROLET-serial_7.xlsx',
#  'make_41.CHEVROLET-serial_70.xlsx',
#  'make_41.CHEVROLET-serial_71.xlsx',
#  'make_41.CHEVROLET-serial_72.xlsx',
#  'make_41.CHEVROLET-serial_73.xlsx',
#  'make_41.CHEVROLET-serial_74.xlsx',
#  'make_41.CHEVROLET-serial_75.xlsx',
#  'make_41.CHEVROLET-serial_76.xlsx',
#  'make_41.CHEVROLET-serial_77.xlsx',
#  'make_41.CHEVROLET-serial_78.xlsx',
#  'make_41.CHEVROLET-serial_79.xlsx',
#  'make_41.CHEVROLET-serial_8.xlsx',
#  'make_41.CHEVROLET-serial_80.xlsx',
#  'make_41.CHEVROLET-serial_81.xlsx',
#  'make_41.CHEVROLET-serial_82.xlsx',
#  'make_41.CHEVROLET-serial_83.xlsx',
#  'make_41.CHEVROLET-serial_84.xlsx',
#  'make_41.CHEVROLET-serial_85.xlsx',
#  'make_41.CHEVROLET-serial_86.xlsx',
#  'make_41.CHEVROLET-serial_87.xlsx',
#  'make_41.CHEVROLET-serial_88.xlsx',
#  'make_41.CHEVROLET-serial_89.xlsx',
#  'make_41.CHEVROLET-serial_9.xlsx',
#  'make_41.CHEVROLET-serial_90.xlsx',
#  'make_41.CHEVROLET-serial_91.xlsx',
#  'make_41.CHEVROLET-serial_92.xlsx',
#  'make_41.CHEVROLET-serial_93.xlsx',
#  'make_41.CHEVROLET-serial_94.xlsx',
#  'make_42.CHIREY.xlsx',
#  'make_43.CHRYSLER-serial_1.xlsx',
#  'make_43.CHRYSLER-serial_10.xlsx',
#  'make_43.CHRYSLER-serial_11.xlsx',
#  'make_43.CHRYSLER-serial_12.xlsx',
#  'make_43.CHRYSLER-serial_13.xlsx',
#  'make_43.CHRYSLER-serial_14.xlsx',
#  'make_43.CHRYSLER-serial_15.xlsx',
#  'make_43.CHRYSLER-serial_16.xlsx',
#  'make_43.CHRYSLER-serial_2.xlsx',
#  'make_43.CHRYSLER-serial_3.xlsx',
#  'make_43.CHRYSLER-serial_4.xlsx',
#  'make_43.CHRYSLER-serial_5.xlsx',
#  'make_43.CHRYSLER-serial_6.xlsx',
#  'make_43.CHRYSLER-serial_7.xlsx',
#  'make_43.CHRYSLER-serial_8.xlsx',
#  'make_43.CHRYSLER-serial_9.xlsx',
#  'make_44.CISITALIA.xlsx',
#  'make_45.CITROEN.xlsx',
#  'make_46.COLE.xlsx',
#  'make_47.CONTINENTAL.xlsx',
#  'make_48.CORD.xlsx',
#  'make_49.CROSLEY.xlsx',
#  'make_5.ALLARD.xlsx',
#  'make_50.CUNNINGHAM.xlsx',
#  'make_51.CUPRA.xlsx',
#  'make_52.DAEWOO.xlsx',
#  'make_53.DAF.xlsx',
#  'make_54.DAIHATSU.xlsx',
#  'make_55.DAIMLER.xlsx',
#  'make_56.DATSUN.xlsx',
#  'make_57.DELAGE.xlsx',
#  'make_58.DELAHAYE.xlsx',
#  'make_59.DELLOW.xlsx',
#  'make_6.ALLSTATE.xlsx',
#  'make_60.DELOREAN.xlsx',
#  'make_61.DENZEL.xlsx',
#  'make_62.DESOTO.xlsx',
#  'make_63.DETOMASO.xlsx',
#  'make_64.DEUTSCH-BONNET.xlsx',
#  'make_65.DIANA.xlsx',
#  'make_66.DKW.xlsx',
#  'make_67.DODGE-serial_1.xlsx',
#  'make_67.DODGE-serial_10.xlsx',
#  'make_67.DODGE-serial_11.xlsx',
#  'make_67.DODGE-serial_12.xlsx',
#  'make_67.DODGE-serial_13.xlsx',
#  'make_67.DODGE-serial_14.xlsx',
#  'make_67.DODGE-serial_15.xlsx',
#  'make_67.DODGE-serial_16.xlsx',
#  'make_67.DODGE-serial_17.xlsx',
#  'make_67.DODGE-serial_18.xlsx',
#  'make_67.DODGE-serial_19.xlsx',
#  'make_67.DODGE-serial_2.xlsx',
#  'make_67.DODGE-serial_20.xlsx',
#  'make_67.DODGE-serial_21.xlsx',
#  'make_67.DODGE-serial_22.xlsx',
#  'make_67.DODGE-serial_23.xlsx',
#  'make_67.DODGE-serial_24.xlsx',
#  'make_67.DODGE-serial_25.xlsx',
#  'make_67.DODGE-serial_26.xlsx',
#  'make_67.DODGE-serial_27.xlsx',
#  'make_67.DODGE-serial_28.xlsx',
#  'make_67.DODGE-serial_29.xlsx',
#  'make_67.DODGE-serial_3.xlsx',
#  'make_67.DODGE-serial_30.xlsx',
#  'make_67.DODGE-serial_31.xlsx',
#  'make_67.DODGE-serial_32.xlsx',
#  'make_67.DODGE-serial_33.xlsx',
#  'make_67.DODGE-serial_34.xlsx',
#  'make_67.DODGE-serial_35.xlsx',
#  'make_67.DODGE-serial_36.xlsx',
#  'make_67.DODGE-serial_37.xlsx',
#  'make_67.DODGE-serial_38.xlsx',
#  'make_67.DODGE-serial_39.xlsx',
#  'make_67.DODGE-serial_4.xlsx',
#  'make_67.DODGE-serial_40.xlsx',
#  'make_67.DODGE-serial_41.xlsx',
#  'make_67.DODGE-serial_42.xlsx',
#  'make_67.DODGE-serial_43.xlsx',
#  'make_67.DODGE-serial_44.xlsx',
#  'make_67.DODGE-serial_45.xlsx',
#  'make_67.DODGE-serial_46.xlsx',
#  'make_67.DODGE-serial_47.xlsx',
#  'make_67.DODGE-serial_48.xlsx',
#  'make_67.DODGE-serial_49.xlsx',
#  'make_67.DODGE-serial_5.xlsx',
#  'make_67.DODGE-serial_50.xlsx',
#  'make_67.DODGE-serial_51.xlsx',
#  'make_67.DODGE-serial_52.xlsx',
#  'make_67.DODGE-serial_53.xlsx',
#  'make_67.DODGE-serial_54.xlsx',
#  'make_67.DODGE-serial_55.xlsx',
#  'make_67.DODGE-serial_56.xlsx',
#  'make_67.DODGE-serial_57.xlsx',
#  'make_67.DODGE-serial_58.xlsx',
#  'make_67.DODGE-serial_6.xlsx',
#  'make_67.DODGE-serial_7.xlsx',
#  'make_67.DODGE-serial_8.xlsx',
#  'make_67.DODGE-serial_9.xlsx',
#  'make_68.DORETTI.xlsx',
#  'make_69.DU PONT.xlsx',
#  'make_7.ALPINE.xlsx',
#  'make_70.DUAL-GHIA.xlsx',
#  'make_71.DUESENBERG.xlsx',
#  'make_72.DURANT.xlsx',
#  'make_73.EAGLE-serial_1.xlsx',
#  'make_73.EAGLE-serial_2.xlsx',
#  'make_74.EDSEL.xlsx',
#  'make_75.ELCAR.xlsx',
#  'make_76.ELVA.xlsx',
#  'make_77.ERSKINE.xlsx',
#  'make_78.ESSEX.xlsx',
#  'make_79.EXCALIBUR.xlsx',
#  'make_8.ALVIS.xlsx',
#  'make_80.FACEL VEGA.xlsx',
#  'make_81.FAIRTHORPE.xlsx',
#  'make_82.FALCON KNIGHT.xlsx',
#  'make_83.FARGO-serial_1.xlsx',
#  'make_83.FARGO-serial_2.xlsx',
#  'make_83.FARGO-serial_3.xlsx',
#  'make_84.FAW.xlsx',
#  'make_85.FERRARI.xlsx',
#  'make_86.FIAT-serial_1.xlsx',
#  'make_86.FIAT-serial_2.xlsx',
#  'make_86.FIAT-serial_3.xlsx',
#  'make_87.FISKER.xlsx',
#  'make_88.FLINT.xlsx',
#  'make_89.FORD-serial_1.xlsx',
#  'make_89.FORD-serial_10.xlsx',
#  'make_89.FORD-serial_11.xlsx',
#  'make_89.FORD-serial_12.xlsx',
#  'make_89.FORD-serial_13.xlsx',
#  'make_89.FORD-serial_14.xlsx',
#  'make_89.FORD-serial_15.xlsx',
#  'make_89.FORD-serial_16.xlsx',
#  'make_89.FORD-serial_17.xlsx',
#  'make_89.FORD-serial_18.xlsx',
#  'make_89.FORD-serial_19.xlsx',
#  'make_89.FORD-serial_2.xlsx',
#  'make_89.FORD-serial_20.xlsx',
#  'make_89.FORD-serial_21.xlsx',
#  'make_89.FORD-serial_22.xlsx',
#  'make_89.FORD-serial_23.xlsx',
#  'make_89.FORD-serial_24.xlsx',
#  'make_89.FORD-serial_25.xlsx',
#  'make_89.FORD-serial_26.xlsx',
#  'make_89.FORD-serial_27.xlsx',
#  'make_89.FORD-serial_28.xlsx',
#  'make_89.FORD-serial_29.xlsx',
#  'make_89.FORD-serial_3.xlsx',
#  'make_89.FORD-serial_30.xlsx',
#  'make_89.FORD-serial_31.xlsx',
#  'make_89.FORD-serial_32.xlsx',
#  'make_89.FORD-serial_33.xlsx',
#  'make_89.FORD-serial_34.xlsx',
#  'make_89.FORD-serial_35.xlsx',
#  'make_89.FORD-serial_36.xlsx',
#  'make_89.FORD-serial_37.xlsx',
#  'make_89.FORD-serial_38.xlsx',
#  'make_89.FORD-serial_39.xlsx',
#  'make_89.FORD-serial_4.xlsx',
#  'make_89.FORD-serial_40.xlsx',
#  'make_89.FORD-serial_41.xlsx',
#  'make_89.FORD-serial_42.xlsx',
#  'make_89.FORD-serial_43.xlsx',
#  'make_89.FORD-serial_44.xlsx',
#  'make_89.FORD-serial_45.xlsx',
#  'make_89.FORD-serial_46.xlsx',
#  'make_89.FORD-serial_47.xlsx',
#  'make_89.FORD-serial_48.xlsx',
#  'make_89.FORD-serial_49.xlsx',
#  'make_89.FORD-serial_5.xlsx',
#  'make_89.FORD-serial_50.xlsx',
#  'make_89.FORD-serial_51.xlsx',
#  'make_89.FORD-serial_52.xlsx',
#  'make_89.FORD-serial_53.xlsx',
#  'make_89.FORD-serial_54.xlsx',
#  'make_89.FORD-serial_55.xlsx',
#  'make_89.FORD-serial_56.xlsx',
#  'make_89.FORD-serial_57.xlsx',
#  'make_89.FORD-serial_58.xlsx',
#  'make_89.FORD-serial_59.xlsx',
#  'make_89.FORD-serial_6.xlsx',
#  'make_89.FORD-serial_60.xlsx',
#  'make_89.FORD-serial_61.xlsx',
#  'make_89.FORD-serial_62.xlsx',
#  'make_89.FORD-serial_63.xlsx',
#  'make_89.FORD-serial_64.xlsx',
#  'make_89.FORD-serial_65.xlsx',
#  'make_89.FORD-serial_66.xlsx',
#  'make_89.FORD-serial_67.xlsx',
#  'make_89.FORD-serial_68.xlsx',
#  'make_89.FORD-serial_69.xlsx',
#  'make_89.FORD-serial_7.xlsx',
#  'make_89.FORD-serial_70.xlsx',
#  'make_89.FORD-serial_71.xlsx',
#  'make_89.FORD-serial_8.xlsx',
#  'make_89.FORD-serial_9.xlsx',
#  'make_9.AM GENERAL.xlsx',
#  'make_90.FOTON.xlsx',
#  'make_91.FRANKLIN.xlsx',
#  'make_92.FRAZER NASH.xlsx',
#  'make_93.FREIGHTLINER-serial_1.xlsx',
#  'make_93.FREIGHTLINER-serial_2.xlsx',
#  'make_93.FREIGHTLINER-serial_3.xlsx',
#  'make_94.GARDNER.xlsx',
#  'make_95.GENESIS.xlsx',
#  'make_96.GEO-serial_1.xlsx',
#  'make_96.GEO-serial_2.xlsx',
#  'make_97.GIANT MOTORS.xlsx',
#  'make_98.GLAS.xlsx',
#  'make_99.GMC-serial_1.xlsx',
#  'make_99.GMC-serial_10.xlsx',
#  'make_99.GMC-serial_11.xlsx',
#  'make_99.GMC-serial_12.xlsx',
#  'make_99.GMC-serial_13.xlsx',
#  'make_99.GMC-serial_14.xlsx',
#  'make_99.GMC-serial_15.xlsx',
#  'make_99.GMC-serial_16.xlsx',
#  'make_99.GMC-serial_17.xlsx',
#  'make_99.GMC-serial_18.xlsx',
#  'make_99.GMC-serial_19.xlsx',
#  'make_99.GMC-serial_2.xlsx',
#  'make_99.GMC-serial_20.xlsx',
#  'make_99.GMC-serial_21.xlsx',
#  'make_99.GMC-serial_22.xlsx',
#  'make_99.GMC-serial_23.xlsx',
#  'make_99.GMC-serial_24.xlsx',
#  'make_99.GMC-serial_25.xlsx',
#  'make_99.GMC-serial_26.xlsx',
#  'make_99.GMC-serial_27.xlsx',
#  'make_99.GMC-serial_28.xlsx',
#  'make_99.GMC-serial_29.xlsx',
#  'make_99.GMC-serial_3.xlsx',
#  'make_99.GMC-serial_30.xlsx',
#  'make_99.GMC-serial_31.xlsx',
#  'make_99.GMC-serial_32.xlsx',
#  'make_99.GMC-serial_33.xlsx',
#  'make_99.GMC-serial_34.xlsx',
#  'make_99.GMC-serial_35.xlsx',
#  'make_99.GMC-serial_36.xlsx',
#  'make_99.GMC-serial_37.xlsx',
#  'make_99.GMC-serial_38.xlsx',
#  'make_99.GMC-serial_39.xlsx',
#  'make_99.GMC-serial_4.xlsx',
#  'make_99.GMC-serial_40.xlsx',
#  'make_99.GMC-serial_41.xlsx',
#  'make_99.GMC-serial_42.xlsx',
#  'make_99.GMC-serial_43.xlsx',
#  'make_99.GMC-serial_44.xlsx',
#  'make_99.GMC-serial_45.xlsx',
#  'make_99.GMC-serial_46.xlsx',
#  'make_99.GMC-serial_47.xlsx',
#  'make_99.GMC-serial_48.xlsx',
#  'make_99.GMC-serial_49.xlsx',
#  'make_99.GMC-serial_5.xlsx',
#  ...]

# %%
file = list_file[0]

file
# Out:
# 'make_1.ABARTH.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./{param_date}/9.type/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['Make No'] = input_['Make No'].astype(int)
input_['Model No'] = input_['Model No'].astype(int)
input_['Engine No'] = input_['Engine No'].astype(int)
input_['Year'] = input_['Year'].astype(int)
input_['Group No'] = input_['Group No'].astype(int)
input_['Type No'] = input_['Type No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Type'].tolist()
# Out:
# 总数量：439
# ['Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Condenser / Capacitor Connector',
#  'Balance Shaft Sprocket',
#  'Connecting Rod Bearing',
#  'Oil Pan Gasket',
#  'Valve Spring',
#  'Variable Valve Timing (VVT) Sprocket',
#  'Cabin Air Filter',
#  'Ignition Coil',
#  'Spark Plug',
#  'Shock / Strut & Coil Spring Assembly',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Belt',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Oil Pressure Sender / Switch Connector',
#  'Oil Pressure Sender / Switch',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Valve Cover',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Spark Plug',
#  'Filter',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Spark Plug',
#  'Filter',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Spark Plug',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Spark Plug',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Battery',
#  'Starter Solenoid',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Oil Pressure Sender / Switch Connector',
#  'Oil Pressure Sender / Switch',
#  'Conversion / Lower Gasket Set',
#  'Crankshaft Seal',
#  'Cylinder Head Bolt',
#  'Cylinder Head Gasket',
#  'Cylinder Head Gasket Set',
#  'Engine Kit Gasket Set',
#  'Oil Pan Gasket',
#  'Exhaust Manifold Gasket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Conversion / Lower Gasket Set',
#  'Crankshaft Seal',
#  'Cylinder Head Bolt',
#  'Cylinder Head Gasket',
#  'Cylinder Head Gasket Set',
#  'Engine Kit Gasket Set',
#  'Oil Pan Gasket',
#  'Exhaust Manifold Gasket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Conversion / Lower Gasket Set',
#  'Crankshaft Seal',
#  'Cylinder Head Bolt',
#  'Cylinder Head Gasket',
#  'Cylinder Head Gasket Set',
#  'Engine Kit Gasket Set',
#  'Oil Pan Gasket',
#  'Exhaust Manifold Gasket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade',
#  'Brake Pad',
#  'Coolant / Antifreeze',
#  'Cooling Fan Control Module',
#  'Headlamp Bulb',
#  'Headlamp Socket',
#  'Ignition Coil',
#  'Spark Plug',
#  'Wiper Blade']

# %%
a = 1

a
# Out:
# 1

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests
import json

import sys
sys.path.append('../../00.Tools')
from crawler_configuration import get_header, get_proxy

payload = {'jsn': {'tab': 'catalog',
                   'make': input_.loc[a, 'Make'],
                   'year': int(input_.loc[a, 'Year']),
                   'model': input_.loc[a, 'Model'],
                   'carcode': input_.loc[a, 'Car Code'],
                   'engine': input_.loc[a, 'Engine'],
                   'groupname': input_.loc[a, 'Group'],
                   'parttype': input_.loc[a, 'Type Code'],
                   'nodetype': 'parttype'}}

data = {'func': 'navnode_fetch',
        'payload': json.dumps(payload),
        'api_json_request': '1'}

b = 0
while True:

    while True:
        b += 1
        print(b)
        try:
            resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                 data=data,
                                 headers=get_header(),
                                 proxies=get_proxy(),
                                 timeout=(10, 10))
            break
        except:
            continue

    if resp.status_code == 200:
        break

resp
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'html_fill_sections': {'navchildren[]': '<div id="listings[__GIP__1__]" class="listings-container"><form method="post" id="frmlistings[__GIP__1__]" class="nobmp" action="/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+/+antifreeze,11393"><input type="hidden" name="_nck" value="8LVLUxTaILBT+tLxkg8+3Ag7/0bbOhvn7P3rkFbL80/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDXfb4DjpqS2YFwZmedV8KwP6rsWEnDLXPIwe+gviEVQDAYYXJGp1KFqNbseNofMQE"><div class="listing-container-border"><input type="hidden" autocomplete="off" id="parentnode[__GIP__1__]" value="" /><div><div style="padding-top: 1px; padding-left: .25em; padding-right: .25em;"><div class="remove-for-print" style="padding-top:5px;"><div class="ib vtop"><span style="padding-left: .5em;" class="show-if-js"><img onclick="cataloglite.NavNode_SimulateClick(null);" style="vertical-align: top;" class="mouseover" src="/catalog/images/close.gif" alt="Close" title="Close" /></span><span style="padding-left: .5em;" class="show-if-js"><a href="/en/printlistings.php?ni=__GIP__1__&title=Print Part Listings" target="_blank" rel="opener" ><img style="vertical-align: top; border: none; height: 20px;" class="mouseover" src="/Images/mobile/printer.png" alt="Print Part Listings" title="Print Part Listings" /></a></span><span style="padding-left: .5em;" class="show-if-js"><a href="/en/emailpagetofriend.php?nurl=%2Fen%2Fcatalog%2Fabarth%2C1969%2C1000%2C982cc%2Bl4%2C1438885%2Ccooling%2Bsystem%2Ccoolant%2B%2F%2Bantifreeze%2C11393" target="_blank" onclick="cataloglite.AddFiltersToEmailListingURL(&quot;\\/en\\/catalog\\/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+\\/+antifreeze,11393&quot;, &quot;__GIP__1__&quot;); return false;"><img style="vertical-align: top; border: none; height: 14px;" class="mouseover" src="/Images/mobile/envelope.png" alt="Send these listings to a friend" title="Send these listings to a friend" /></a></span><span style="padding-left: .5em;" class="show-if-js"><a href="/help/?page=2" target="_blank" style="text-decoration: none;" title="How do I choose a part?" alt="How do I choose a part?">\n                                            <img class="help_q_icon_16 vtop" src="/Images/questionMark.png" alt="Help" />\n                                            </a></span></div><span style="padding-left: .5em;" class="span-filterinput"><div class="ib"><table class="tblz tbl-input-button-attached attached-filter-size"><tr><td class="td-input"><input type="text" size="25" value="" name="filterinput" class="filter-input" id="filterinput[__GIP__1__]" style="" onclick="cataloglite.DisplayFilterBreakDown(&quot;__GIP__1__&quot;);" onkeypress="return RA.InterceptEnter(event, function(){cataloglite.FilterListings(&quot;__GIP__1__&quot;);});" onblur="cataloglite.FilterListings(&quot;__GIP__1__&quot;);" autocomplete="off" spellcheck="false" autocorrect="off" autocapitalize="off" placeholder="Filter By Keyword(s)" title="Filter listings below by entering words that you want to see. Use \'-\' before a word to find results that do NOT contain that word. Use OR between words or groups of words to see listings that match either. Use quotes &quot;...&quot; around a set of words you wish to match only when they exist together as a phrase. Multiple filters can be applied by entering new words or phrases after each filter operation." /></td><td class="td-button"><img class="ib input-size ra-btn ra-btn-size-normal ra-btn-color-darkblue ra-btn-search-icon" src="/Images/1pxtransparent.png" style="color: black;" onclick="cataloglite.FilterListings(&quot;__GIP__1__&quot;); return false;" alt="Apply Filter" /></td></tr></table></div><span style="position: relative;"><span id="filterbreakdownwrapper___GIP__1__" class="ra-hide" style="position: absolute; z-index: 10;"><div style="background: #FFFFFF; border: 1px solid black; padding: 5px; white-space: nowrap;"><div style="text-align: right;" class="filter-breakdown-row-spacing"><img onclick="cata ...
#  'jsn': {'tab': 'catalog',
#   'make': 'ABARTH',
#   'year': 1969,
#   'model': '1000',
#   'carcode': '1438885',
#   'engine': '982cc L4',
#   'groupname': 'Cooling System',
#   'parttype': '11393',
#   'nodetype': 'parttype',
#   'use_manufacturers_page_url': None,
#   'raw_params': None,
#   'parttypedesc': 'Coolant / Antifreeze'},
#  'collected_javascript': '/**UQ:900C6739**/\nRABoot.WaitFor("jQuery", function() {$(document).ready(function(){clb.DynamicDropDown_SetupMonitoring("ddrepl[rel_parts[__GIP__1__]]");});});\nvar PK_OK ="OK";\nvar PK_XLISTINGSREMOVE="KEY__NUM listings removed";\nvar PK_XLISTINGREMOVE="KEY__NUM listing removed";\nRABoot.WaitFor("jQuery", function() {$(document).ready(function(){clb.DynamicDropDown_SetupMonitoring("ddrepl[optionchoice[__GIP__2__]]");});});\nRABoot.WaitFor("jQuery", function() {$(document).ready(function(){clb.DynamicDropDown_SetupMonitoring("ddrepl[optionchoice[__GIP__3__]]");});});\nRABoot.WaitFor("jQuery", function() {$(document).ready(function(){clb.DynamicDropDown_SetupMonitoring("ddrepl[optionchoice[__GIP__4__]]");});});\nRABoot.WaitFor("jQuery", function() {$(document).ready(function(){clb.DynamicDropDown_SetupMonitoring("ddrepl[optionchoice[__GIP__5__]]");});});\nwindow.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\\/0bbOhvn7P3rkFbL80\\/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDXfb4DjpqS2YFwZmedV8KwP6rsWEnDLXPIwe+gviEVQDAYYXJGp1KFqNbseNofMQE";\n'}

# %%
'redirect_to_url' in json_
# Out:
# False

# %%
json_['jsn']['tab'] == 'catalog' and json_['jsn']['make'] == input_.loc[a, 'Make'] and json_['jsn']['year'] == input_.loc[a, 'Year'] and json_['jsn']['model'] == input_.loc[a, 'Model'] and json_['jsn']['carcode'] == input_.loc[a, 'Car Code'] and json_['jsn']['engine'] == input_.loc[a, 'Engine'] and json_['jsn']['groupname'] == input_.loc[a, 'Group'] and json_['jsn']['parttype'] == input_.loc[a, 'Type Code'] and json_['jsn']['nodetype'] == 'parttype' and 'collected_javascript' in json_
# Out:
# True

# %%
from bs4 import BeautifulSoup
from lxml import etree

soup = BeautifulSoup(json_['html_fill_sections']['navchildren[]'].strip(), 'lxml')
html = etree.HTML(str(soup))

with open('./part_1.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="listings-container" id="listings[__GIP__1__]">
#    <form action="/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+/+antifreeze,11393" class="nobmp" id="frmlistings[__GIP__1__]" method="post">
#     <input name="_nck" type="hidden" value="8LVLUxTaILBT+tLxkg8+3Ag7/0bbOhvn7P3rkFbL80/oQB6RvzNfa5dcHvATqXAMxw5whzaDEdxk+27zeij67BjKru6WqTdNqG6tiEsD1EZhbTv0XForkbYp+nLaIKxDXfb4DjpqS2YFwZmedV8KwP6rsWEnDLXPIwe+gviEVQDAYYXJGp1KFqNbseNofMQE"/>
#     <div class="listing-container-border">
#      <input autocomplete="off" id="parentnode[__GIP__1__]" type="hidden" value=""/>
#      <div>
#       <div style="padding-top: 1px; padding-left: .25em; padding-right: .25em;">
#        <div class="remove-for-print" style="padding-top:5px;">
#         <div class="ib vtop">
#          <span class="show-if-js" style="padding-left: .5em;">
#           <img alt="Close" class="mouseover" onclick="cataloglite.NavNode_SimulateClick(null);" src="/catalog/images/close.gif" style="vertical-align: top;" title="Close"/>
#          </span>
#          <span class="show-if-js" style="padding-left: .5em;">
#           <a href="/en/printlistings.php?ni=__GIP__1__&amp;title=Print Part Listings" rel="opener" target="_blank">
#            <img alt="Print Part Listings" class="mouseover" src="/Images/mobile/printer.png" style="vertical-align: top; border: none; height: 20px;" title="Print Part Listings"/>
#           </a>
#          </span>
#          <span class="show-if-js" style="padding-left: .5em;">
#           <a href="/en/emailpagetofriend.php?nurl=%2Fen%2Fcatalog%2Fabarth%2C1969%2C1000%2C982cc%2Bl4%2C1438885%2Ccooling%2Bsystem%2Ccoolant%2B%2F%2Bantifreeze%2C11393" onclick='cataloglite.AddFiltersToEmailListingURL("\/en\/catalog\/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+\/+antifreeze,11393", "__GIP__1__"); return false;' target="_blank">
#            <img alt="Send these listings to a friend" class="mouseover" src="/Images/mobile/envelope.png" style="vertical-align: top; border: none; height: 14px;" title="Send these listings to a friend"/>
#           </a>
#          </span>
#          <span class="show-if-js" style="padding-left: .5em;">
#           <a alt="How do I choose a part?" href="/help/?page=2" style="text-decoration: none;" target="_blank" title="How do I choose a part?">
#            <img alt="Help" class="help_q_icon_16 vtop" src="/Images/questionMark.png"/>
#           </a>
#          </span>
#         </div>
#         <span class="span-filterinput" style="padding-left: .5em;">
#          <div class="ib">
#           <table class="tblz tbl-input-button-attached attached-filter-size">
#            <tr>
#             <td class="td-input">
#              <input autocapitalize="off" autocomplete="off" autocorrect="off" class="filter-input" id="filterinput[__GIP__1__]" name="filterinput" onblur='cataloglite.FilterListings("__GIP__1__");' onclick='cataloglite.DisplayFilterBreakDown("__GIP__1__");' onkeypress='return RA.InterceptEnter(event, function(){cataloglite.FilterListings("__GIP__1__");});' placeholder="Filter By Keyword(s)" size="25" spellcheck="false" style="" title="Filter listings below by entering words that you want to see. Use '-' before a word to find results that do NOT contain that word. Use OR between words or groups of words to see listings that match either. Use quotes &quot;...&quot; around a set of words you wish to match only when they exist together as a phrase. Multiple filters can be applied by entering new words or phrases after each filter operation." type="text" value=""/>
#             </td>
#             <td class="td-button">
#              <img alt="Apply Filter" class="ib input-size ra-btn ra-btn-size-normal ra-btn-color-darkblue ra-btn-search-icon" onclick='cataloglite.FilterListings("__GIP__1__"); return false;' src="/Images/1pxtransparent.png" style="color: black;"/>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <span style="position: relative;">
#           <span class="ra-hide" id="filterbreakdownwrapper___GIP__1__" style="position: absolute; z-index: 10;">
#            <div style="background: #FFFFFF; border: 1px solid black; padding: 5px; white-space: nowrap;">
#             <div class="filter-breakdown-row-spacing" style="text-align: right;">
#              <img alt="Hide" class="mouseover" onclick='cataloglite.DisplayFilterBreakDown("__GIP__1__", 1);' src="/catalog/images/close.gif" style="vertical-align: top;" title="Hide"/>
#             </div>
#             <div id="filterbreakdownsteps___GIP__1__">
#             </div>
#             <div style="text-align: center; padding-top: .25em;">
#              <input class="ra-btn mo-link" name="clearfilter" onclick=' cataloglite.ClearListingFilter("__GIP__1__"); return false;' style="color: blue;" type="submit" value="Clear Filter"/>
#             </div>
#            </div>
#           </span>
#          </span>
#         </span>
#         <div class="listing-filter-wrapper show-if-js" id="listingfilterwrapper[__GIP__1__]">
#          <div class="filter-dropdown-header" id="filterdropdownheader[__GIP__1__]" onclick="cataloglite.ToggleListingFilterMenu(__GIP__1__)">
#           <img alt="" class="listing-filter-icon" src="/catalog/images/filtericon.png" style="height:1.2em; width:1.2em;"/>
#           <span id="headerattributes[__GIP__1__]">
#            <div class="filter-group">
#             <div class="filter-attribute" onclick="event.stopPropagation();">
#              <label>
#               <input data-codename="MarketFlags" data-issecondarycodename="false" data-relatedcodekeys="" id="filtercodekey[__GIP__1__][US]" name="filtercodekey[__GIP__1__]" onclick='cataloglite.FilterCodeKey(__GIP__1__, "US");' type="checkbox" value="US"/>
#               <span>
#                <span title="Show parts that fit vehicles sold in US">
#                 <img alt="Show parts that fit vehicles sold in US" class="flag-new" src="/catalog/images/flag_us.png"/>
#                </span>
#               </span>
#              </label>
#             </div>
#             <div class="filter-attribute" onclick="event.stopPropagation();">
#              <label>
#               <input data-codename="MarketFlags" data-issecondarycodename="false" data-relatedcodekeys="" id="filtercodekey[__GIP__1__][CA]" name="filtercodekey[__GIP__1__]" onclick='cataloglite.FilterCodeKey(__GIP__1__, "CA");' type="checkbox" value="CA"/>
#               <span>
#                <span title="Show parts that fit vehicles sold in CA">
#                 <img alt="Show parts that fit vehicles sold in CA" class="flag-new" src="/catalog/images/flag_ca.png"/>
#                </span>
#               </span>
#              </label>
#             </div>
#             <div class="filter-attribute" onclick="event.stopPropagation();">
#              <label>
#               <input data-codename="MarketFlags" data-issecondarycodename="false" data-relatedcodekeys="" id="filtercodekey[__GIP__1__][MX]" name="filtercodekey[__GIP__1__]" onclick='cataloglite.FilterCodeKey(__GIP__1__, "MX");' type="checkbox" value="MX"/>
#               <span>
#                <span title="Show parts that fit vehicles sold in MX">
#                 <img alt="Show parts that fit vehicles sold in MX" class="flag-new" src="/catalog/images/flag_mx.png"/>
#                </span>
#               </span>
#              </label>
#             </div>
#            </div>
#           </span>
#           <span class="filter-group ra-hide" id="filtersearchterms[__GIP__1__]">
#           </span>
#           <div class="ra-hide filter-dropdown-content" id="filterdropdownbody[__GIP__1__]" style="position:absolute;">
#            <div class="filter-dropdown-scrollpane">
#             <span id="bodyattributes[__GIP__1__]">
#             </span>
#            </div>
#            <div class="listing-filter-hide mouseover" onclick='cataloglite.ToggleListingFilterMenu("__GIP__1__", true); RA.StopBubble(event);'>
#             Hide
#             <img alt="" src="/Images/mobile/up_arrow_white.png" style="height:.5em;"/>
#            </div>
#           </div>
#          </div>
#          <div class="listing-filter-reset mouseover ra-hide" id="filternumlistings[__GIP__1__]" onclick="cataloglite.ClearListingFilter(__GIP__1__);">
#          </div>
#         </div>
#         <span style="float: right;">
#          <span class="whitebubble">
#           <input aria-label="Choose for Me to Minimize Cost" class="show-if-js" id="chooseformetoggle[__GIP__1__]" onclick='cataloglite.ToggleChooseForMe("__GIP__1__");' type="checkbox"/>
#           <a href="/help/?page=2#MINSHIPCOST" onclick="RA.StopBubble(event); return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#            Choose for Me to Minimize Cost
#           </a>
#           <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-darkblue" name="alts" type="submit" value="Enable"/>
#          </span>
#         </span>
#         <label for="chooseformetoggle[__GIP__1__]" style="display:none;">
#          Choose for Me to Minimize Cost
#         </label>
#        </div>
#       </div>
#       <div style="clear: both; padding-top: .25em;">
#       </div>
#       <table cellpadding="0" cellspacing="0" class="nobmp" style="width: 100%;">
#        <tbody>
#         <tr>
#          <td colspan="2">
#           <div class="remove-for-print" style="padding-bottom:.2em;">
#            <span class="show-if-js remove-for-print" style="font-weight: normal; font-style: normal; margin-left:0.75em; margin-right:0.75em;">
#             <span class="ra-vertical-dropdown-replacement-c" id="ddrepl[rel_parts[__GIP__1__]][container]">
#              <span class="hide-if-js">
#               <select autocomplete="none" class="rayellow" id="rel_parts[__GIP__1__]" onchange="cataloglite.RelatedPartTypeSelected(this);; cataloglite.DynamicDropDown_SetSelected(&quot;ddrepl[rel_parts[__GIP__1__]]&quot;, -1, 'r');" tabindex="0">
#                <option selected="" value="">
#                 Related Parts
#                </option>
#                <option value='{"steps":{"tab":"extras","groupname":"Cooling System","subgroupname":"Sender \/ Sensor","parttype":"2184"},"fallback_url":"\/en\/tools\/cooling+system,sender+\/+sensor,coolant+level+sensor,2184"}'>
#                 Coolant Level Sensor
#                </option>
#                <option value='{"steps":{"tab":"extras","groupname":"Garage Equipment","subgroupname":"Funnel","parttype":"437"},"fallback_url":"\/en\/tools\/garage+equipment,funnel,funnel+\/+dispenser,437"}'>
#                 Funnel / Dispenser
#                </option>
#               </select>
#              </span>
#              <span class="ra-vertical-dropdown-replacement tfk show-if-js" id="ddrepl[rel_parts[__GIP__1__]]" style="">
#               <input autocomplete="off" id="ddrepl[rel_parts[__GIP__1__]][jsstate]" type="hidden" value='{"expanded":"","selectedindex":0,"selectid":"rel_parts[__GIP__1__]","disabled":false,"tfk":false}'/>
#               <table class="control-table nobmp-table">
#                <tr>
#                 <td>
#                  <span class="collapsed input-border input-padding no-text-select rayellow" id="ddrepl[rel_parts[__GIP__1__]][collapse]" onclick='clb.DynamicDropDown_CollapsedClick("ddrepl[rel_parts[__GIP__1__]]", event);' style="min-width: 6.67em;">
#                   <span class="down-arrow">
#                   </span>
#                   <span class="vmiddle" id="ddrepl[rel_parts[__GIP__1__]][collapsetext]">
#                    Related Parts
#                   </span>
#                  </span>
#                  <div class="expanded ra-hide" id="ddrepl[rel_parts[__GIP__1__]][expand]">
#                   <div class="absolute" id="ddrepl[rel_parts[__GIP__1__]][absolute]">
#                    <ul class="scroll" id="ddrepl[rel_parts[__GIP__1__]][scroll]">
#                     <li class="list-item first" id="ddrepl[rel_parts[__GIP__1__]][list-item][0]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[rel_parts[__GIP__1__]]&quot;, 0, 'w');">
#                      <div class="outer selected" id="ddrepl[rel_parts[__GIP__1__]][list-item][0][outer]">
#                       <div class="inner" id="ddrepl[rel_parts[__GIP__1__]][list-item][0][inner]">
#                        Related Parts
#                       </div>
#                      </div>
#                     </li>
#                     <li class="list-item" id="ddrepl[rel_parts[__GIP__1__]][list-item][1]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[rel_parts[__GIP__1__]]&quot;, 1, 'w');">
#                      <div class="outer" id="ddrepl[rel_parts[__GIP__1__]][list-item][1][outer]">
#                       <div class="inner" id="ddrepl[rel_parts[__GIP__1__]][list-item][1][inner]">
#                        Coolant Level Sensor
#                       </div>
#                      </div>
#                     </li>
#                     <li class="list-item last" id="ddrepl[rel_parts[__GIP__1__]][list-item][2]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[rel_parts[__GIP__1__]]&quot;, 2, 'w');">
#                      <div class="outer" id="ddrepl[rel_parts[__GIP__1__]][list-item][2][outer]">
#                       <div class="inner" id="ddrepl[rel_parts[__GIP__1__]][list-item][2][inner]">
#                        Funnel / Dispenser
#                       </div>
#                      </div>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </td>
#                 <td style="width: 1px;">
#                  <label for="ddrepl[rel_parts[__GIP__1__]][tabbable]" style="display:none;">
#                   Intentionally blank
#                  </label>
#                  <input class="almost-hidden-input no-text-select ra-hide" id="ddrepl[rel_parts[__GIP__1__]][tabbable]" onfocus='clb.DynamicDropDown_SetFocus("ddrepl[rel_parts[__GIP__1__]]", event);' tabindex="0" type="text" value=""/>
#                 </td>
#                 <td style="width: 1px;">
#                  <label for="ddrepl[rel_parts[__GIP__1__]][readonly]" style="display:none;">
#                   Intentionally blank
#                  </label>
#                  <input class="almost-hidden-input no-text-select ra-hide" id="ddrepl[rel_parts[__GIP__1__]][readonly]" onblur='clb.DynamicDropDown_Readonly_OnBlur("ddrepl[rel_parts[__GIP__1__]]", event);' onfocus='clb.DynamicDropDown_Readonly_OnFocus("ddrepl[rel_parts[__GIP__1__]]", event);' onkeydown='cataloglite.DynamicDropDown_Readonly_OnKeyDown("ddrepl[rel_parts[__GIP__1__]]", event);' readonly="" tabindex="-1" type="text" value=""/>
#                 </td>
#                </tr>
#               </table>
#              </span>
#             </span>
#             <label for="rel_parts[__GIP__1__]" style="display:none;">
#              Related Parts
#             </label>
#            </span>
#           </div>
#           <div class="show-for-print tacenter ra-hide">
#            <span style="text-align: center;">
#             <span class="ib" style="padding-top:.15em;">
#              <a class="make-blue-for-print" href="/en/catalog/abarth" onclick='cataloglite.AutoOpen({"steps":{"make":"ABARTH"},"collected_key":"catalog","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none; ">
#               <span class="belem inactive" style="font-size: 1em; font-weight: bold;">
#                ABARTH
#               </span>
#              </a>
#             </span>
#             <span class="ib" style="padding-top:.15em;">
#              &gt;
#              <a class="make-blue-for-print" href="/en/catalog/abarth,1969" onclick='cataloglite.AutoOpen({"steps":{"year":1969},"collected_key":"catalog-ABARTH","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none; ">
#               <span class="belem inactive" style="font-size: 1em; font-weight: bold;">
#                1969
#               </span>
#              </a>
#             </span>
#             <span class="ib" style="padding-top:.15em;">
#              &gt;
#              <a class="make-blue-for-print" href="/en/catalog/abarth,1969,1000" onclick='cataloglite.AutoOpen({"steps":{"model":"1000"},"collected_key":"catalog-ABARTH-1969","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none; ">
#               <span class="belem inactive" style="font-size: 1em; font-weight: bold;">
#                1000
#               </span>
#              </a>
#             </span>
#             <span class="ib" style="padding-top:.15em;">
#              &gt;
#              <a class="make-blue-for-print" href="/en/catalog/abarth,1969,1000,982cc+l4,1438885" onclick='cataloglite.AutoOpen({"steps":{"carcode":"1438885"},"collected_key":"catalog-ABARTH-1969-1000","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none; ">
#               <span class="belem inactive" style="font-size: 1em; font-weight: bold;">
#                982cc L4
#               </span>
#              </a>
#             </span>
#             <span class="ib" style="padding-top:.15em;">
#              &gt;
#              <a class="make-blue-for-print" href="/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system" onclick='cataloglite.AutoOpen({"steps":{"groupname":"Cooling System"},"collected_key":"catalog-ABARTH-1969-1000-1438885","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none; ">
#               <span class="belem inactive" style="font-size: 1em; font-weight: bold;">
#                Cooling System
#               </span>
#              </a>
#             </span>
#             <span class="ib" style="padding-top:.15em;">
#              &gt;
#              <a class="make-blue-for-print" href="/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+/+antifreeze,11393" onclick='cataloglite.AutoOpen({"steps":{"parttype":"11393"},"collected_key":"catalog-ABARTH-1969-1000-1438885-Cooling System","collapse_children":true,"save_state_before_starting":true}, this, event); return false;' style="text-decoration: none;  color: black;">
#               <span class="belem active" style="font-size: 1em; font-weight: bold;">
#                Coolant / Antifreeze
#               </span>
#              </a>
#             </span>
#            </span>
#           </div>
#          </td>
#          <td class="listing-float-box-cell-shared-header" colspan="2" style="height: 1px; text-align: center;">
#           <span>
#            Price
#           </span>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared-header" style="height: 1px; text-align: center;">
#          </td>
#          <td class="listing-float-box-cell-shared-header" style="height: 1px; text-align: center;">
#           <span>
#            Pack
#           </span>
#          </td>
#          <td class="listing-float-box-cell-shared-header" style="height: 1px; text-align: center;">
#           <span style="font-weight: bold;">
#            Total
#           </span>
#          </td>
#          <td class="remove-for-print listing-float-box-cell-shared-header" style="text-align: center;">
#           <span class="ra-hide" id="alternateheader[__GIP__1__]">
#            <a href="/help/?page=2#MINSHIPCOST" onclick="return FAQpopup(this);" target="blank">
#             Alternate
#            </a>
#           </span>
#          </td>
#         </tr>
#        </tbody>
#        <tr class="remove-for-print">
#         <td class="ra-hide" colspan="6" id="listingnopartscriteria[__GIP__1__]" style="color: red;">
#          No parts for vehicles in selected markets.
#         </td>
#        </tr>
#        <tr>
#         <td colspan="7">
#          <div class="listing-sortgroupheader mouseover" onclick='cataloglite.ToggleSortGroupHeader("__GIP__1__", 0);' style="background: #ffa500;color: #000000;border-top: 1px solid #d68a00; border-bottom: 1px solid #d68a00;" title="Generally cheaper price and/or shorter life span intended for the budget conscious customer">
#           Economy
#           <img alt="collapse" id="vew_sortgroupicon[__GIP__1__][0]" src="/catalog/images/collapseh.gif"/>
#          </div>
#          <input autocomplete="off" id="mdl_sortgroupicon[__GIP__1__][0]" type="hidden" value="true"/>
#         </td>
#        </tr>
#        <tbody class="listing-inner altrow-a-1" id="listingcontainer[__GIP__2__]" style="background: #fff3de; ">
#         <tr>
#          <td class="listing-inner-content" rowspan="2" style="">
#           <span style="float: right;">
#           </span>
#           <div>
#           </div>
#           <div class="listing-text-row-moreinfo-truck">
#            <span class="listing-final-manufacturer">
#             FVP
#            </span>
#            <span alt="Buyer's Guide" class="listing-final-partnumber as-link-if-js" id="vew_partnumber[__GIP__2__]" onclick='if (cataloglite.IsMobileAndNotExpanded("__GIP__2__")) { return; } cataloglite.ShowBuyersGuidePopup("__GIP__2__");' title="Buyer's Guide">
#             GREEN5050GAL
#            </span>
#            <span class="span-link-underline-remover">
#             Low Silicate Blend; 1 Gallon; Green; IAT
#            </span>
#            <a class="ra-btn ra-btn-moreinfo" href="https://www.rockauto.com/en/moreinfo.php?pk=13527801&amp;cc=1438885&amp;pt=11393" onclick='cataloglite.MoreInfoClick(this, "__GIP__2__"); AddSerializedCookieDataToHref(this);' rel="opener" target="_blank">
#             Info
#            </a>
#            <span class="truck ra-hide remove-for-print mouseover" name="vew_whtruckicon[__GIP__2__][alloptions]" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', &quot;Could ship from same location as parts in cart&quot;, null, this); RA.StopBubble(event); return false;" title="Could ship from same location as parts in cart">
#            </span>
#           </div>
#           <div class="listing-text-row">
#            <span title="Please make sure this note matches your vehicle. A seemingly contradictory note (like &quot;Left; Right;&quot;) means the part fits either (left OR right) -- it does not mean you'll receive two parts. Please do not choose a part if the note does not describe your application (for example, if the note says &quot;Sedan&quot; and you have a station wagon).">
#             <span class="listing-footnote-text">
#              <a class="appflag" data-market="US" href="/help/?page=2#FLAGS" onclick="return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#               <img alt="Flag indicates this part fits vehicles sold in the USA. It does not indicate where the part was made -- manufacturers produce parts in multiple factories worldwide." class="flag" src="/catalog/images/flag_us.png" title="Flag indicates this part fits vehicles sold in the USA. It does not indicate where the part was made -- manufacturers produce parts in multiple factories worldwide."/>
#              </a>
#             </span>
#            </span>
#           </div>
#           <div>
#            <div class="listing-optionchoice-multiple-container remove-for-print">
#             <span class="listing-optionchoice-multiple-label">
#              Choose Type:
#             </span>
#             <span class="ra-vertical-dropdown-replacement-c" id="ddrepl[optionchoice[__GIP__2__]][container]">
#              <span class="hide-if-js">
#               <select autocomplete="none" class="listing-optionchoice-multiple" id="optionchoice[__GIP__2__]" name="optionchoice[__GIP__2__]" onchange="cataloglite.change_opt(&quot;__GIP__2__&quot;); cataloglite.DynamicDropDown_SetSelected(&quot;ddrepl[optionchoice[__GIP__2__]]&quot;, -1, 'r');" tabindex="0">
#                <option selected="" value="">
#                 &amp;nbsp
#                </option>
#                <option value="22-50-0-1">
#                 <span class="param-value-text">
#                  Prediluted
#                 </span>
#                 <b>
#                  ($6.11)
#                 </b>
#                 ^
#                </option>
#                <option value="22-CON-0-1">
#                 <span class="param-value-text">
#                  Concentrated
#                 </span>
#                 <b>
#                  ($8.68)
#                 </b>
#                 ^
#                </option>
#               </select>
#              </span>
#              <span class="ra-vertical-dropdown-replacement tfk show-if-js" id="ddrepl[optionchoice[__GIP__2__]]" style="">
#               <input autocomplete="off" id="ddrepl[optionchoice[__GIP__2__]][jsstate]" type="hidden" value='{"expanded":"","selectedindex":0,"selectid":"optionchoice[__GIP__2__]","disabled":false,"tfk":false}'/>
#               <table class="control-table nobmp-table">
#                <tr>
#                 <td>
#                  <span class="collapsed input-border input-padding no-text-select listing-optionchoice-multiple" id="ddrepl[optionchoice[__GIP__2__]][collapse]" onclick='clb.DynamicDropDown_CollapsedClick("ddrepl[optionchoice[__GIP__2__]]", event);' style="min-width: 7em;">
#                   <span class="down-arrow">
#                   </span>
#                   <span class="vmiddle" id="ddrepl[optionchoice[__GIP__2__]][collapsetext]">
#                    &amp;nbsp
#                   </span>
#                  </span>
#                  <div class="expanded ra-hide" id="ddrepl[optionchoice[__GIP__2__]][expand]">
#                   <div class="absolute" id="ddrepl[optionchoice[__GIP__2__]][absolute]">
#                    <ul class="scroll" id="ddrepl[optionchoice[__GIP__2__]][scroll]">
#                     <li class="list-item first" id="ddrepl[optionchoice[__GIP__2__]][list-item][0]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[optionchoice[__GIP__2__]]&quot;, 0, 'w');">
#                      <div class="outer selected" id="ddrepl[optionchoice[__GIP__2__]][list-item][0][outer]">
#                       <div class="inner" id="ddrepl[optionchoice[__GIP__2__]][list-item][0][inner]">
#                        &amp;nbsp
#                       </div>
#                      </div>
#                     </li>
#                     <li class="list-item" id="ddrepl[optionchoice[__GIP__2__]][list-item][1]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[optionchoice[__GIP__2__]]&quot;, 1, 'w');">
#                      <div class="outer" id="ddrepl[optionchoice[__GIP__2__]][list-item][1][outer]">
#                       <div class="inner" id="ddrepl[optionchoice[__GIP__2__]][list-item][1][inner]">
#                        <span class="di vmiddle">
#                         <span class="param-value-text">
#                          Prediluted
#                         </span>
#                         <b>
#                          ($6.11)
#                         </b>
#                        </span>
#                        <img alt="Warehouse" class="nobmp di vmiddle ra-hide" name="vew_whtruckicon[__GIP__2__][22-50-0-1]" onmousemove="clb.FAQHover_MouseMove(this, event, '/help/?page=2#MINSHIPCOST', 'Could ship from same location as parts in cart');" onmouseout="clb.FAQHover_MouseOut(this, event);" src="/Images/mobile/truck.png" style="height: 1.25em; margin-left: .25em;" title="Could ship from same location as parts in cart"/>
#                       </div>
#                      </div>
#                     </li>
#                     <li class="list-item last" id="ddrepl[optionchoice[__GIP__2__]][list-item][2]" onclick="clb.DynamicDropDown_SetSelected(&quot;ddrepl[optionchoice[__GIP__2__]]&quot;, 2, 'w');">
#                      <div class="outer" id="ddrepl[optionchoice[__GIP__2__]][list-item][2][outer]">
#                       <div class="inner" id="ddrepl[optionchoice[__GIP__2__]][list-item][2][inner]">
#                        <span class="di vmiddle">
#                         <span class="param-value-text">
#                          Concentrated
#                         </span>
#                         <b>
#                          ($8.68)
#                         </b>
#                        </span>
#                        <img alt="Warehouse" class="nobmp di vmiddle ra-hide" name="vew_whtruckicon[__GIP__2__][22-CON-0-1]" onmousemove="clb.FAQHover_MouseMove(this, event, '/help/?page=2#MINSHIPCOST', 'Could ship from same location as parts in cart');" onmouseout="clb.FAQHover_MouseOut(this, event);" src="/Images/mobile/truck.png" style="height: 1.25em; margin-left: .25em;" title="Could ship from same location as parts in cart"/>
#                       </div>
#                      </div>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </td>
#                 <td style="width: 1px;">
#                  <label for="ddrepl[optionchoice[__GIP__2__]][tabbable]" style="display:none;">
#                   Intentionally blank
#                  </label>
#                  <input class="almost-hidden-input no-text-select ra-hide" id="ddrepl[optionchoice[__GIP__2__]][tabbable]" onfocus='clb.DynamicDropDown_SetFocus("ddrepl[optionchoice[__GIP__2__]]", event);' tabindex="0" type="text" value=""/>
#                 </td>
#                 <td style="width: 1px;">
#                  <label for="ddrepl[optionchoice[__GIP__2__]][readonly]" style="display:none;">
#                   Intentionally blank
#                  </label>
#                  <input class="almost-hidden-input no-text-select ra-hide" id="ddrepl[optionchoice[__GIP__2__]][readonly]" onblur='clb.DynamicDropDown_Readonly_OnBlur("ddrepl[optionchoice[__GIP__2__]]", event);' onfocus='clb.DynamicDropDown_Readonly_OnFocus("ddrepl[optionchoice[__GIP__2__]]", event);' onkeydown='cataloglite.DynamicDropDown_Readonly_OnKeyDown("ddrepl[optionchoice[__GIP__2__]]", event);' readonly="" tabindex="-1" type="text" value=""/>
#                 </td>
#                </tr>
#               </table>
#              </span>
#             </span>
#             <label for="optionchoice[__GIP__2__]" style="display:none;">
#              Choose
#             </label>
#            </div>
#           </div>
#           <div>
#            <div class="listing-notification-wrapper hide-if-js">
#             <span class="hide-if-js">
#              ^ Could ship from same location as parts in cart
#             </span>
#             <span class="show-if-js">
#              <img alt="Warehouse" class="nobmp di vmiddle ra-hide" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', 'Could ship from same location as parts in cart', null, this); RA.StopBubble(event); return false;" src="/Images/mobile/truck.png" style="height: 1.25em; margin-left: .25em;" title="Could ship from same location as parts in cart"/>
#             </span>
#            </div>
#           </div>
#           <div>
#           </div>
#           <input autocomplete="off" id="pricebreakdown[__GIP__2__][]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"&lt;span class=\"seeopt-price-text\"&gt;Choose Type at Left&lt;\/span&gt;","colspan":4,"n":"&lt;span class=\"seeopt-price-text\"&gt;Choose Type at Left&lt;\/span&gt;"}'/>
#           <input autocomplete="off" id="corebreakdown[__GIP__2__][]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":null,"display":"none"}'/>
#           <input autocomplete="off" id="totalbreakdown[__GIP__2__][]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":null,"display":"none"}'/>
#           <input autocomplete="off" id="packbreakdown[__GIP__2__][]" type="hidden" value='{"multiple":null,"v":"","display":"none"}'/>
#           <input autocomplete="off" id="pricebreakdown[__GIP__2__][22-50-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"($6.11\/Each)","colspan":2,"display_phrase":"(KEY__PRICE\/Each)","n":"6.11"}'/>
#           <input autocomplete="off" id="corebreakdown[__GIP__2__][22-50-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"$0.00","display":"none","n":"0.00"}'/>
#           <input autocomplete="off" id="totalbreakdown[__GIP__2__][22-50-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"$6.11","display":"","n":"6.11"}'/>
#           <input autocomplete="off" id="packbreakdown[__GIP__2__][22-50-0-1]" type="hidden" value="{&quot;multiple&quot;:&quot;1&quot;,&quot;v&quot;:&quot;&lt;span class=\&quot;hide-if-js\&quot;&gt;+ Sold in packs of 1&lt;\/span&gt;&lt;span class=\&quot;show-if-js\&quot;&gt;&lt;span class=\&quot;pack_size_box no-text-select\&quot; onclick=\&quot;showContextPopup('&amp;nbsp;', &amp;quot;Sold in packs of 1&amp;quot;, this); RA.StopBubble(event); return false;\&quot; title=\&quot;Sold in packs of 1\&quot;&gt;&lt;span class=\&quot;right\&quot;&gt;&lt;span class=\&quot;left\&quot;&gt;&lt;span class=\&quot;text\&quot;&gt;&lt;span class=\&quot;text-x-small\&quot;&gt;x&lt;\/span&gt;1&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&quot;,&quot;display&quot;:&quot;&quot;}"/>
#           <input autocomplete="off" id="pricebreakdown[__GIP__2__][22-CON-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"($8.68\/Each)","colspan":2,"display_phrase":"(KEY__PRICE\/Each)","n":"8.68"}'/>
#           <input autocomplete="off" id="corebreakdown[__GIP__2__][22-CON-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"$0.00","display":"none","n":"0.00"}'/>
#           <input autocomplete="off" id="totalbreakdown[__GIP__2__][22-CON-0-1]" type="hidden" value='{"bold":false,"notbold":false,"oos":false,"v":"$8.68","display":"","n":"8.68"}'/>
#           <input autocomplete="off" id="packbreakdown[__GIP__2__][22-CON-0-1]" type="hidden" value="{&quot;multiple&quot;:&quot;1&quot;,&quot;v&quot;:&quot;&lt;span class=\&quot;hide-if-js\&quot;&gt;+ Sold in packs of 1&lt;\/span&gt;&lt;span class=\&quot;show-if-js\&quot;&gt;&lt;span class=\&quot;pack_size_box no-text-select\&quot; onclick=\&quot;showContextPopup('&amp;nbsp;', &amp;quot;Sold in packs of 1&amp;quot;, this); RA.StopBubble(event); return false;\&quot; title=\&quot;Sold in packs of 1\&quot;&gt;&lt;span class=\&quot;right\&quot;&gt;&lt;span class=\&quot;left\&quot;&gt;&lt;span class=\&quot;text\&quot;&gt;&lt;span class=\&quot;text-x-small\&quot;&gt;x&lt;\/span&gt;1&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&lt;\/span&gt;&quot;,&quot;display&quot;:&quot;&quot;}"/>
#           <input autocomplete="off" id="listing_data_essential[__GIP__2__]" name="listing_data_essential[__GIP__2__]" type="hidden" value='{"groupindex":"__GIP__2__","carcode":"1438885","parttype":"11393","partkey":"13527801","opts":{"22-50-0-1":{"warehouse":"92829","whpartnum":"FVP GREEN50\/50-GAL","optionlist":"22","paramcode":"50","notekey":"0","multiple":"1"},"22-CON-0-1":{"warehouse":"95677","whpartnum":"FVP GREEN-GAL","optionlist":"22","paramcode":"CON","notekey":"0","multiple":"1"}}}'/>
#           <input autocomplete="off" id="listing_data_supplemental[__GIP__2__]" type="hidden" value='{"partnumber":"GREEN5050GAL","catalogname":"FVP","belongstolisting":"__GIP__1__","sortgroup":0,"sortgrouptext":"Economy","paramdesc":"Type"}'/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__2__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_chkalternate[__GIP__2__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnaddtocart[__GIP__2__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnpartincart[__GIP__2__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__2__][alloptions]" type="hidden" value="false"/>
#           <input autocomplete="off" id="lst_shipwhlist[__GIP__2__][22-50-0-1]" type="hidden" value='{"28027":28027,"60524":60524,"55121":55121,"80011":80011,"92829":92829,"6405":6405,"95677":95677}'/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__2__][22-50-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnaddtocart[__GIP__2__][22-50-0-1]" type="hidden" value="true"/>
#           <input autocomplete="off" id="mdl_btnpartincart[__GIP__2__][22-50-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnnotifyoos[__GIP__2__][22-50-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_chkalternate[__GIP__2__][22-50-0-1]" type="hidden" value="true"/>
#           <input autocomplete="off" id="lst_shipwhlist[__GIP__2__][22-CON-0-1]" type="hidden" value='{"92829":92829,"80011":80011,"95677":95677,"64121":64121,"6405":6405,"28027":28027,"60524":60524,"2321":2321,"55121":55121}'/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__2__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnaddtocart[__GIP__2__][22-CON-0-1]" type="hidden" value="true"/>
#           <input autocomplete="off" id="mdl_btnpartincart[__GIP__2__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnnotifyoos[__GIP__2__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_chkalternate[__GIP__2__][22-CON-0-1]" type="hidden" value="true"/>
#           <input autocomplete="off" name="listing-codekey[__GIP__2__]" type="hidden" value="196120,US"/>
#           <input autocomplete="off" name="ssk[__GIP__2__]" type="hidden" value="HPc6NY4sqMvPDBCrBav8qYglqQqcNzX8uasHm0vZ6Fa+5FTdPiRxMkMWwt67+bO5S6R4bvrMRrw="/>
#           <span style="display: none;" title="Replaces these Alternate/ OE Part Numbers">
#            GREENGAL, GREEN5050GAL
#           </span>
#          </td>
#          <td class="listing-float-box-cell-shared" rowspan="2" style="text-align: right; ">
#           <div class="listing-image-space-occupy">
#            <table class="tblz listing-image-table" id="listing_image_table[__GIP__2__]" style="">
#             <tr>
#              <td class="listing-image-table-leftrightcol">
#               <div id="inlineimg_left_small[__GIP__2__]">
#                <img alt="&lt;" class="listing-image-prevnext-image remove-for-print show-if-js" id="inlineimgprevious[__GIP__2__]" onclick='cataloglite.Listing_InlineImageManualScroll("__GIP__2__", -1, false, false)' src="/catalog/images/prevIMGbig.png" style=" margin: .1em;" title="Previous Image"/>
#               </div>
#              </td>
#              <td class="listing-image-table-centercol">
#               <div class="ra-hide" id="inlineimgpositionancestor[__GIP__2__]" style=" position: relative; z-index: 1;">
#                <div class="listing-inlineimg_container listing-inline-image-border" id="inlineimg_container[__GIP__2__]" style="z-index: 1; text-align: center; background: #FFFFFF;">
#                 <div class="listing-inline-image-popup-widget-title ra-hide" id="inlineimg_containertitle[__GIP__2__]" onmousedown='cataloglite.ImagePopupTitleMouseDown("__GIP__2__")'>
#                  <div style="text-align: center; ">
#                   <span style="padding: 0 2em 0 2em;">
#                    FVP GREEN5050GAL
#                   </span>
#                   <span style="position: absolute; right: 5px;">
#                    <img alt="close" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__2__")' src="/catalog/images/close12_1.gif" style="padding: .2em; cursor: pointer; display: block;"/>
#                   </span>
#                  </div>
#                 </div>
#                 <div class="img-topper-container" id="inlineimg_topper[__GIP__2__]">
#                  <table class="tblz w100">
#                   <tr>
#                    <td class="pinched" style="vertical-align: top;">
#                     <div style="text-align: left; padding-right: .25em;">
#                      <span id="inlineimg_left_big[__GIP__2__]">
#                      </span>
#                     </div>
#                     <div class="listing-image-counter">
#                      <div class="inner" id="imagecounterdisplay[__GIP__2__]">
#                      </div>
#                     </div>
#                    </td>
#                    <td style="vertical-align: top;">
#                     <div class="img-carousel-titlephrase" id="imgcarouseltitlephrase[__GIP__2__]">
#                      <b>
#                       Image Represents Prediluted Option
#                      </b>
#                     </div>
#                     <div class="ra-hide" id="inlineimg_container360menu[__GIP__2__]" style="padding: .25em; margin-bottom: .5em;">
#                      <div class="ra-bar-slider-bar-c">
#                       <div class="ra-bar-slider-bar" id="inlineimg_sliderbar[__GIP__2__]" onmousedown='cataloglite.ImageSliderMouseDown("__GIP__2__", event);' ontouchstart='cataloglite.ImageSliderMouseDown("__GIP__2__", event);'>
#                        <span class="ra-bar-slider-slider" id="inlineimg_slider[__GIP__2__]">
#                        </span>
#                       </div>
#                      </div>
#                     </div>
#                    </td>
#                    <td class="pinched" style="vertical-align: top; text-align: right;">
#                     <div style="padding-left: .25em;">
#                      <span id="inlineimg_right_big[__GIP__2__]">
#                      </span>
#                     </div>
#                    </td>
#                   </tr>
#                  </table>
#                 </div>
#                 <div class="inlineimg_containersizer ra-hide" id="inlineimg_containersizer[__GIP__2__]" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__2__")' style=" cursor: pointer;">
#                  <img alt="Part image" class="listing-inline-image" id="inlineimg[__GIP__2__]" src="/info/949/50 50 prediluted orig green front VP__ra_m.jpg"/>
#                 </div>
#                </div>
#               </div>
#               <img alt="Part image" class="listing-inline-image listing-inline-image-thumb listing-inline-image-border" id="inlineimg_thumb[__GIP__2__]" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__2__")' src="/info/949/50 50 prediluted orig green front VP__ra_m.jpg" style="cursor: pointer;" switch-to-highres="1"/>
#              </td>
#              <td class="listing-image-table-leftrightcol">
#               <div id="inlineimg_right_small[__GIP__2__]">
#                <img alt="&gt;" class="listing-image-prevnext-image show-if-js remove-for-print" id="inlineimgnext[__GIP__2__]" name="inlnimgnextbtn" onclick='cataloglite.Listing_InlineImageManualScroll("__GIP__2__", 1, false, false)' src="/catalog/images/nextIMGbig.png" style=" margin: .1em;" title="Next Image"/>
#               </div>
#              </td>
#             </tr>
#            </table>
#            <input autocomplete="off" id="jsninlineimg[__GIP__2__]" type="hidden" value='{"Size":"Thumb","SlotIndex":0,"Slots":[{"TitlePhrase":"&lt;b&gt;Image Represents Prediluted Option&lt;\/b&gt;","ParamCodes":["&lt;b&gt;Image Represents Prediluted Option&lt;\/b&gt;"],"Type":"Single","ImageData":{"Thumb":"\/info\/949\/50 50 prediluted orig green front VP__ra_m.jpg","Popup":"\/info\/949\/50 50 prediluted orig green front VP.jpg","Full":"\/info\/949\/50 50 prediluted orig green front VP.jpg"}},{"TitlePhrase":"&lt;b&gt;Image Represents Concentrated Option&lt;\/b&gt;","ParamCodes":["&lt;b&gt;Image Represents Concentrated Option&lt;\/b&gt;"],"Type":"Single","ImageData":{"Thumb":"\/info\/949\/full strength orig green front VP__ra_m.jpg","Popup":"\/info\/949\/full strength orig green front VP.jpg","Full":"\/info\/949\/full strength orig green front VP.jpg"}}]}'/>
#           </div>
#          </td>
#          <td class="listing-float-box-cell-shared listing-float-box-cell-more-padding" colspan="4" id="listingtd[__GIP__2__][price]" style="height: 1px; text-align: center; ">
#           <span class="" id="dprice[__GIP__2__][td]">
#            <span class="ra-formatted-amount listing-price">
#             <span id="dprice[__GIP__2__][v]">
#              <span class="seeopt-price-text">
#               Choose Type at Left
#              </span>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__2__][core]" style="height: 1px; text-align: center; ">
#           <span class="" id="dcore[__GIP__2__][td]">
#            <span class="ra-formatted-amount listing-core">
#             <span id="dcore[__GIP__2__][v]">
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__2__][pack]" style="height: 1px; text-align: center; ">
#           <span id="dpack[__GIP__2__][v]">
#           </span>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__2__][total]" style="height: 1px; text-align: center; ">
#           <span class="listing-amount-bold" id="dtotal[__GIP__2__][td]">
#            <span class="ra-formatted-amount listing-total">
#             <span id="dtotal[__GIP__2__][v]">
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="listing-float-box-cell-shared" rowspan="2" style="text-align: center; ">
#           <span class="ra-hide listing-altcontainer remove-for-print" id="alternatecontainer[__GIP__2__]" style="text-align: center; display: inline-block;">
#            <input id="alternate[__GIP__2__]" name="alternate[__GIP__2__]" type="checkbox"/>
#            <label for="alternate[__GIP__2__]" style="display:none;">
#             Alternate
#            </label>
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td class="listing-float-box-cell-shared" colspan="4" style="text-align: right;">
#           <div style="padding-top: .25em; padding-bottom: .1em;">
#            <div class="listing-quantity-adjustment ib remove-for-print show-if-js">
#             <input autocomplete="off" id="listingoptkeytomultiple[__GIP__2__]" type="hidden" value='{"22-50-0-1":"1","22-CON-0-1":"1"}'/>
#             <input autocomplete="off" id="listingoptkeytolinenumber[__GIP__2__]" type="hidden" value='{"22-50-0-1":null,"22-CON-0-1":null}'/>
#             <input autocomplete="off" id="listingoptkeytoqtyincart[__GIP__2__]" type="hidden" value='{"22-50-0-1":null,"22-CON-0-1":null}'/>
#             <input autocomplete="off" id="listingoptkeytoalternateid[__GIP__2__]" type="hidden" value='{"22-50-0-1":null,"22-CON-0-1":null}'/>
#             <table class="tblz di tbl-input-button-attached ra-invisible" id="listingquantitytable[__GIP__2__]">
#              <tr>
#               <td class="td-button-left" style="text-align: right;">
#                <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("__GIP__2__", -1);' style="border-top-left-radius: 4px; border-bottom-left-radius: 4px;">
#                 <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_down_white.png"/>
#                </div>
#               </td>
#               <td class="td-input">
#                <label for="raquantity[__GIP__2__]" style="display:none;">
#                 Quantity
#                </label>
#                <input aria-label="Quantity" autocapitalize="off" autocomplete="off" autocorrect="off" class="input-quantity ib" data-autofill="block" id="raquantity[__GIP__2__]" maxlength="5" name="raquantity[__GIP__2__]" onchange='cataloglite.ListingQuantityUpdate("__GIP__2__");' onkeypress='return RA.InterceptEnter(event, function(){RA.ByName("raquantity[__GIP__2__]")[0].blur()});' spellcheck="false" style="text-align: center; width: 2em; padding-left: 0;" type="text" value="1"/>
#               </td>
#               <td class="td-button-right">
#                <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("__GIP__2__", 1);' style="border-top-right-radius: 4px; border-bottom-right-radius: 4px;">
#                 <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_up_white.png"/>
#                </div>
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="catalog-listing-buttons-wrapper ib" style="min-width:105px;">
#             <div class="vew_btnaddtocart remove-for-print hide-if-js" id="vew_btnaddtocart[__GIP__2__]">
#              <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-hotgreen" id="addpart[__GIP__2__]" name="addpart[__GIP__2__]" onclick="cataloglite.ShowLoadingOverlay(null, 'PK_ADDINGPARTTOCART'); return cataloglite.Cart.AddPartWhenReady(&quot;__GIP__2__&quot;);" type="submit" value="Add to Cart &gt;"/>
# ...
#             </div>
#             <div class="vew_btnnotifyoos remove-for-print show-if-js" id="vew_btnnotifyoos[__GIP__8__]">
#              <input class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" onclick='cataloglite.GetAvailabilityAlertForOOSPart("__GIP__8__");' type="button" value="Notify Me When Available"/>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#        <tbody class="listing-inner altrow-a-0" id="listingcontainer[__GIP__9__]" style="">
#         <tr>
#          <td class="listing-border-top-line listing-inner-content" rowspan="2" style="">
#           <span style="float: right;">
#           </span>
#           <div>
#           </div>
#           <div class="listing-text-row-moreinfo-truck">
#            <span class="listing-final-manufacturer">
#             PRESTONE
#            </span>
#            <span alt="Buyer's Guide" class="listing-final-partnumber as-link-if-js" id="vew_partnumber[__GIP__9__]" onclick='if (cataloglite.IsMobileAndNotExpanded("__GIP__9__")) { return; } cataloglite.ShowBuyersGuidePopup("__GIP__9__");' title="Buyer's Guide">
#             71621
#            </span>
#            <span class="span-link-underline-remover">
#             All Vehicles - 10yr/300k mi - Concentrate
#            </span>
#            <a class="ra-btn ra-btn-moreinfo" href="https://www.rockauto.com/en/moreinfo.php?pk=12976781&amp;cc=1438885&amp;pt=11393" onclick='cataloglite.MoreInfoClick(this, "__GIP__9__"); AddSerializedCookieDataToHref(this);' rel="opener" target="_blank">
#             Info
#            </a>
#            <span class="truck ra-hide remove-for-print mouseover" name="vew_whtruckicon[__GIP__9__][22-CON-0-1]" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', &quot;Could ship from same location as parts in cart&quot;, null, this); RA.StopBubble(event); return false;" title="Could ship from same location as parts in cart">
#            </span>
#           </div>
#           <div class="listing-text-row">
#            <span title="Please make sure this note matches your vehicle. A seemingly contradictory note (like &quot;Left; Right;&quot;) means the part fits either (left OR right) -- it does not mean you'll receive two parts. Please do not choose a part if the note does not describe your application (for example, if the note says &quot;Sedan&quot; and you have a station wagon).">
#             <span class="listing-footnote-text">
#              <a class="appflag" data-market="US" href="/help/?page=2#FLAGS" onclick="return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#               <img alt="Flag indicates this part fits vehicles sold in the USA. It does not indicate where the part was made -- manufacturers produce parts in multiple factories worldwide." class="flag" src="/catalog/images/flag_us.png" title="Flag indicates this part fits vehicles sold in the USA. It does not indicate where the part was made -- manufacturers produce parts in multiple factories worldwide."/>
#              </a>
#             </span>
#            </span>
#            (Type:
#            <span class="param-value-text">
#             Concentrated
#            </span>
#            )
#           </div>
#           <div>
#           </div>
#           <div>
#           </div>
#           <div>
#           </div>
#           <input autocomplete="off" id="optionchoice[__GIP__9__]" name="optionchoice[__GIP__9__]" type="hidden" value="22-CON-0-1"/>
#           <input autocomplete="off" id="listing_data_essential[__GIP__9__]" name="listing_data_essential[__GIP__9__]" type="hidden" value='{"groupindex":"__GIP__9__","carcode":"1438885","parttype":"11393","partkey":"12976781","opts":{"22-CON-0-1":{"warehouse":0,"whpartnum":"","optionlist":"22","paramcode":"CON","notekey":"0","multiple":1}}}'/>
#           <input autocomplete="off" id="listing_data_supplemental[__GIP__9__]" type="hidden" value='{"partnumber":"71621","catalogname":"PRESTONE","belongstolisting":"__GIP__1__","sortgroup":3,"sortgrouptext":"","paramdesc":"Type"}'/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__9__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_chkalternate[__GIP__9__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnaddtocart[__GIP__9__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnpartincart[__GIP__9__][]" type="hidden" value="false"/>
#           <input autocomplete="off" id="lst_shipwhlist[__GIP__9__][22-CON-0-1]" type="hidden" value="[]"/>
#           <input autocomplete="off" id="mdl_whtruckicon[__GIP__9__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnaddtocart[__GIP__9__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnpartincart[__GIP__9__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" id="mdl_btnnotifyoos[__GIP__9__][22-CON-0-1]" type="hidden" value="true"/>
#           <input autocomplete="off" id="mdl_chkalternate[__GIP__9__][22-CON-0-1]" type="hidden" value="false"/>
#           <input autocomplete="off" name="listing-codekey[__GIP__9__]" type="hidden" value="US"/>
#           <input autocomplete="off" name="ssk[__GIP__9__]" type="hidden" value="HPc6NY4sqMvPDBCrBav8qYglqQqcNzX8uasHm0vZ6Fa+5FTdPiRxMkMWwt67+bO5S6R4bvrMRrw="/>
#           <span style="display: none;" title="Replaces these Alternate/ OE Part Numbers">
#            71621
#           </span>
#          </td>
#          <td class="listing-border-top-line listing-float-box-cell-shared" rowspan="2" style="text-align: right; ">
#           <div class="listing-image-space-occupy">
#            <table class="tblz listing-image-table" id="listing_image_table[__GIP__9__]" style="">
#             <tr>
#              <td class="listing-image-table-leftrightcol">
#               <div id="inlineimg_left_small[__GIP__9__]">
#                <img alt="&lt;" class="listing-image-prevnext-image remove-for-print show-if-js" id="inlineimgprevious[__GIP__9__]" onclick='cataloglite.Listing_InlineImageManualScroll("__GIP__9__", -1, false, false)' src="/catalog/images/prevIMGbig.png" style=" margin: .1em;" title="Previous Image"/>
#               </div>
#              </td>
#              <td class="listing-image-table-centercol">
#               <div class="ra-hide" id="inlineimgpositionancestor[__GIP__9__]" style=" position: relative; z-index: 1;">
#                <div class="listing-inlineimg_container listing-inline-image-border" id="inlineimg_container[__GIP__9__]" style="z-index: 1; text-align: center; background: #FFFFFF;">
#                 <div class="listing-inline-image-popup-widget-title ra-hide" id="inlineimg_containertitle[__GIP__9__]" onmousedown='cataloglite.ImagePopupTitleMouseDown("__GIP__9__")'>
#                  <div style="text-align: center; ">
#                   <span style="padding: 0 2em 0 2em;">
#                    PRESTONE 71621
#                   </span>
#                   <span style="position: absolute; right: 5px;">
#                    <img alt="close" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__9__")' src="/catalog/images/close12_1.gif" style="padding: .2em; cursor: pointer; display: block;"/>
#                   </span>
#                  </div>
#                 </div>
#                 <div class="img-topper-container" id="inlineimg_topper[__GIP__9__]">
#                  <table class="tblz w100">
#                   <tr>
#                    <td class="pinched" style="vertical-align: top;">
#                     <div style="text-align: left; padding-right: .25em;">
#                      <span id="inlineimg_left_big[__GIP__9__]">
#                      </span>
#                     </div>
#                     <div class="listing-image-counter">
#                      <div class="inner" id="imagecounterdisplay[__GIP__9__]">
#                      </div>
#                     </div>
#                    </td>
#                    <td style="vertical-align: top;">
#                     <div class="img-carousel-titlephrase" id="imgcarouseltitlephrase[__GIP__9__]">
#                     </div>
#                     <div class="ra-hide" id="inlineimg_container360menu[__GIP__9__]" style="padding: .25em; margin-bottom: .5em;">
#                      <div class="ra-bar-slider-bar-c">
#                       <div class="ra-bar-slider-bar" id="inlineimg_sliderbar[__GIP__9__]" onmousedown='cataloglite.ImageSliderMouseDown("__GIP__9__", event);' ontouchstart='cataloglite.ImageSliderMouseDown("__GIP__9__", event);'>
#                        <span class="ra-bar-slider-slider" id="inlineimg_slider[__GIP__9__]">
#                        </span>
#                       </div>
#                      </div>
#                     </div>
#                    </td>
#                    <td class="pinched" style="vertical-align: top; text-align: right;">
#                     <div style="padding-left: .25em;">
#                      <span id="inlineimg_right_big[__GIP__9__]">
#                      </span>
#                     </div>
#                    </td>
#                   </tr>
#                  </table>
#                 </div>
#                 <div class="inlineimg_containersizer ra-hide" id="inlineimg_containersizer[__GIP__9__]" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__9__")' style=" cursor: pointer;">
#                  <img alt="Part image" class="listing-inline-image" id="inlineimg[__GIP__9__]" src="/info/692/71621_P04_FRO__ra_m.jpg"/>
#                 </div>
#                </div>
#               </div>
#               <img alt="Part image" class="listing-inline-image listing-inline-image-thumb listing-inline-image-border" id="inlineimg_thumb[__GIP__9__]" onclick='cataloglite.Listing_InlineImagePopupInPlace("__GIP__9__")' src="/info/692/71621_P04_FRO__ra_m.jpg" style="cursor: pointer;" switch-to-highres="1"/>
#              </td>
#              <td class="listing-image-table-leftrightcol">
#               <div id="inlineimg_right_small[__GIP__9__]">
#                <img alt="&gt;" class="listing-image-prevnext-image show-if-js remove-for-print" id="inlineimgnext[__GIP__9__]" name="inlnimgnextbtn" onclick='cataloglite.Listing_InlineImageManualScroll("__GIP__9__", 1, false, false)' src="/catalog/images/nextIMGbig.png" style=" margin: .1em;" title="Next Image"/>
#               </div>
#              </td>
#             </tr>
#            </table>
#            <input autocomplete="off" id="jsninlineimg[__GIP__9__]" type="hidden" value='{"Size":"Thumb","SlotIndex":0,"Slots":[{"TitlePhrase":null,"ParamCodes":{"0":null,"CON":null},"Type":"Single","ImageData":{"Thumb":"\/info\/692\/71621_P04_FRO__ra_m.jpg","Popup":"\/info\/692\/71621_P04_FRO.jpg","Full":"\/info\/692\/71621_P04_FRO.jpg"}},{"TitlePhrase":null,"ParamCodes":{"0":null,"CON":null},"Type":"Single","ImageData":{"Thumb":"\/info\/692\/71621_P04_SID__ra_m.jpg","Popup":"\/info\/692\/71621_P04_SID.jpg","Full":"\/info\/692\/71621_P04_SID.jpg"}},{"TitlePhrase":null,"ParamCodes":{"0":null,"CON":null},"Type":"Single","ImageData":{"Thumb":"\/info\/692\/71621_P04_BOT__ra_m.jpg","Popup":"\/info\/692\/71621_P04_BOT.jpg","Full":"\/info\/692\/71621_P04_BOT.jpg"}},{"TitlePhrase":null,"ParamCodes":{"0":null,"CON":null},"Type":"Single","ImageData":{"Thumb":"\/info\/692\/71621_P04_TOP__ra_m.jpg","Popup":"\/info\/692\/71621_P04_TOP.jpg","Full":"\/info\/692\/71621_P04_TOP.jpg"}},{"TitlePhrase":null,"ParamCodes":{"0":null,"CON":null},"Type":"Single","ImageData":{"Thumb":"\/info\/692\/71621_P01_BAC__ra_m.jpg","Popup":"\/info\/692\/71621_P01_BAC.jpg","Full":"\/info\/692\/71621_P01_BAC.jpg"}}]}'/>
#           </div>
#          </td>
#          <td class="listing-border-top-line listing-float-box-cell-shared listing-float-box-cell-more-padding" colspan="4" id="listingtd[__GIP__9__][price]" style="height: 1px; text-align: center; ">
#           <span class="" id="dprice[__GIP__9__][td]">
#            <span class="ra-formatted-amount listing-price">
#             <span id="dprice[__GIP__9__][v]">
#              <span class="oos-price-text">
#               Out of Stock
#              </span>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="ra-hide listing-border-top-line listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__9__][core]" style="height: 1px; text-align: center; ">
#           <span class="" id="dcore[__GIP__9__][td]">
#            <span class="ra-formatted-amount listing-core">
#             <span id="dcore[__GIP__9__][v]">
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="ra-hide listing-border-top-line listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__9__][pack]" style="height: 1px; text-align: center; ">
#           <span id="dpack[__GIP__9__][v]">
#           </span>
#          </td>
#          <td class="ra-hide listing-border-top-line listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[__GIP__9__][total]" style="height: 1px; text-align: center; ">
#           <span class="listing-amount-bold" id="dtotal[__GIP__9__][td]">
#            <span class="ra-formatted-amount listing-total">
#             <span id="dtotal[__GIP__9__][v]">
#             </span>
#            </span>
#           </span>
#          </td>
#          <td class="listing-border-top-line listing-float-box-cell-shared" rowspan="2" style="text-align: center; ">
#           <span class="ra-hide listing-altcontainer remove-for-print" id="alternatecontainer[__GIP__9__]" style="text-align: center; display: inline-block;">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td class="listing-float-box-cell-shared" colspan="4" style="text-align: right;">
#           <div style="padding-top: .25em; padding-bottom: .1em;">
#            <div class="listing-quantity-adjustment ib remove-for-print show-if-js">
#            </div>
#            <div class="catalog-listing-buttons-wrapper ib" style="min-width:105px;">
#             <div class="vew_btnaddtocart remove-for-print ra-hide" id="vew_btnaddtocart[__GIP__9__]">
#              <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-hotgreen" id="addpart[__GIP__9__]" name="addpart[__GIP__9__]" onclick="cataloglite.ShowLoadingOverlay(null, 'PK_ADDINGPARTTOCART'); return cataloglite.Cart.AddPartWhenReady(&quot;__GIP__9__&quot;);" type="submit" value="Add to Cart &gt;"/>
#              <a class="show-if-js ra-btn ra-btn-color-hotgreen ra-btn-size-normal ra-btn-add-part" href="#" onclick="RA.Click('addpart[__GIP__9__]'); return false;" style="display: inline-block;">
#               <span class="la-btn-v">
#                Add to Cart
#               </span>
#               <img alt="" class="la-btn-v" src="/Images/mobile/right_arrow_white.png" style="height: 1em; margin-left: .25em;"/>
#              </a>
#             </div>
#             <div class="vew_btnpartincart remove-for-print ra-hide" id="vew_btnpartincart[__GIP__9__]">
#              <input class="ra-btn ra-btn-size-normal ra-btn-part-in-cart" name="addpart[__GIP__9__]" onclick="cataloglite.Cart.ShowPartAlreadyInCart(__GIP__9__); return false;" type="submit" value="Part In Cart"/>
#             </div>
#             <div class="vew_btnnotifyoos remove-for-print show-if-js" id="vew_btnnotifyoos[__GIP__9__]">
#              <input class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" onclick='cataloglite.GetAvailabilityAlertForOOSPart("__GIP__9__");' type="button" value="Notify Me When Available"/>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="listing-filter-bottom-message ra-hide" id="listingfiltermessage[__GIP__1__]">
#       </div>
#       <input autocomplete="off" id="part_groupindexes_in_this_listing[__GIP__1__]" type="hidden" value='["__GIP__2__","__GIP__3__","__GIP__4__","__GIP__5__","__GIP__6__","__GIP__7__","__GIP__8__","__GIP__9__"]'/>
#      </div>
#     </div>
#    </form>
#   </div>
#  </body>
# </html>

# %%
list_tbody = html.xpath('//tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-a-1") or contains(@class, "altrow-a-0"))]')

list_tbody
# Out:
# [<Element tbody at 0x11e0f2480>,
#  <Element tbody at 0x11e0f2280>,
#  <Element tbody at 0x11e0f25c0>,
#  <Element tbody at 0x11e0f2140>,
#  <Element tbody at 0x11e0f2340>,
#  <Element tbody at 0x11e0f2200>,
#  <Element tbody at 0x11e0f2180>,
#  <Element tbody at 0x11e0f1fc0>]

# %%
len(list_tbody) == 0
# Out:
# False

# %%
list_list_note = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row-moreinfo-truck"]/span[@class="span-link-underline-remover"]/text()') for tbody in list_tbody]
list_note = ['\n'.join([note.strip() for note in list_note]) for list_note in list_list_note]

list_note
# Out:
# ['Low Silicate Blend; 1 Gallon; Green; IAT',
#  'Extended Life; All Makes / All Models; 1 Gallon',
#  'Prime®; Low Silicate Blend; 1 Gallon; Green; IAT',
#  'Extended Life; All Makes / All Models; 1 Gallon',
#  'High Mileage Blend; 1 Gallon; Yellow',
#  'Low Tox Antifreeze; 1 Gallon; Green; IAT',
#  'All Makes / All Models 50/50',
#  'All Vehicles - 10yr/300k mi - Concentrate']

# %%
list_list_info = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row-moreinfo-truck"]/a[@class="ra-btn ra-btn-moreinfo"]/@href') for tbody in list_tbody]
list_info = [list_info[0].strip() if list_info and list_info[0].startswith('https://www.rockauto.com/en/moreinfo.php?') else '' for list_info in list_list_info]

list_info
# Out:
# ['https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12973389&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12973393&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12976777&cc=1438885&pt=11393',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12976781&cc=1438885&pt=11393']

# %%
list_dict_note = []
list_span = [tbody.xpath('./tr[1]/td/div[@class="listing-text-row"]/span[contains(@title, "Please make sure")]')[0] for tbody in list_tbody]

for span in list_span:
    dict_note = {}
    list_note_2 = span.xpath('./span[@class="listing-footnote-text"]/text()')
    list_market = span.xpath('./span[@class="listing-footnote-text"]/a[@class="appflag"]/@data-market')
    if list_market:
        dict_note['separate'] = {}
        for i, note, market in zip(range(len(list_note_2)), list_note_2, list_market):
            dict_note['separate'][str(i)] = {'market': market.strip(), 'note': note.strip()}
    else:
        dict_note = {'combined': {'note': ''.join(list_note_2).strip()}}

    list_dict_note.append(dict_note)

list_dict_note
# Out:
# [{'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}},
#  {'separate': {'0': {'market': 'US', 'note': ''}}}]

# %%
list_json = [json.loads(tbody.xpath('./tr[1]/td[contains(@class, "listing-inner-content")]/input[contains(@id, "listing_data_essential[__GIP__")]/@value')[0]) for tbody in list_tbody]

list_json
# Out:
# [{'groupindex': '__GIP__2__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '13527801',
#   'opts': {'22-50-0-1': {'warehouse': '92829',
#     'whpartnum': 'FVP GREEN50/50-GAL',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': '1'},
#    '22-CON-0-1': {'warehouse': '95677',
#     'whpartnum': 'FVP GREEN-GAL',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': '1'}}},
#  {'groupindex': '__GIP__3__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '13527805',
#   'opts': {'22-50-0-1': {'warehouse': '95677',
#     'whpartnum': 'FVP MV50/50-GAL',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': '1'},
#    '22-CON-0-1': {'warehouse': '95677',
#     'whpartnum': 'FVP MV-GAL',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': '1'}}},
#  {'groupindex': '__GIP__4__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12973401',
#   'opts': {'22-50-0-1': {'warehouse': '60524',
#     'whpartnum': 'PRS AF3300',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': '1'},
#    '22-50-0-6': {'warehouse': '72902',
#     'whpartnum': 'PRS AF3300',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': '6'},
#    '22-CON-0-6': {'warehouse': '72901',
#     'whpartnum': 'PRS AF3200',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': '6'}}},
#  {'groupindex': '__GIP__5__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12973389',
#   'opts': {'22-50-0-1': {'warehouse': '90752',
#     'whpartnum': 'PRES AF2100',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': '1'},
#    '22-CON-0-6': {'warehouse': '35957',
#     'whpartnum': 'PRS AF2000',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': '6'}}},
#  {'groupindex': '__GIP__6__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12973393',
#   'opts': {'22-50-0-1': {'warehouse': 0,
#     'whpartnum': '',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': 1}}},
#  {'groupindex': '__GIP__7__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12973409',
#   'opts': {'22-CON-0-1': {'warehouse': 0,
#     'whpartnum': '',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': 1}}},
#  {'groupindex': '__GIP__8__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12976777',
#   'opts': {'22-50-0-1': {'warehouse': 0,
#     'whpartnum': '',
#     'optionlist': '22',
#     'paramcode': '50',
#     'notekey': '0',
#     'multiple': 1}}},
#  {'groupindex': '__GIP__9__',
#   'carcode': '1438885',
#   'parttype': '11393',
#   'partkey': '12976781',
#   'opts': {'22-CON-0-1': {'warehouse': 0,
#     'whpartnum': '',
#     'optionlist': '22',
#     'paramcode': 'CON',
#     'notekey': '0',
#     'multiple': 1}}}]

# %%
list_key = [json_['partkey'] for json_ in list_json]

list_key
# Out:
# ['13527801',
#  '13527805',
#  '12973401',
#  '12973389',
#  '12973393',
#  '12973409',
#  '12976777',
#  '12976781']

# %%
list_json = [json.loads(tbody.xpath('./tr[1]/td/input[contains(@id, "listing_data_supplemental[")]/@value')[0]) for tbody in list_tbody]

list_json
# Out:
# [{'partnumber': 'GREEN5050GAL',
#   'catalogname': 'FVP',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 0,
#   'sortgrouptext': 'Economy',
#   'paramdesc': 'Type'},
#  {'partnumber': 'MV5050GAL',
#   'catalogname': 'FVP',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 0,
#   'sortgrouptext': 'Economy',
#   'paramdesc': 'Type'},
#  {'partnumber': 'AF3300',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 0,
#   'sortgrouptext': 'Economy',
#   'paramdesc': 'Type'},
#  {'partnumber': 'AF2100',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 1,
#   'sortgrouptext': 'Premium',
#   'paramdesc': 'Type'},
#  {'partnumber': 'AF2400',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 1,
#   'sortgrouptext': 'Premium',
#   'paramdesc': 'Type'},
#  {'partnumber': 'AF555',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 2,
#   'sortgrouptext': 'Standard Replacement',
#   'paramdesc': 'Type'},
#  {'partnumber': '71175',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 3,
#   'sortgrouptext': '',
#   'paramdesc': 'Type'},
#  {'partnumber': '71621',
#   'catalogname': 'PRESTONE',
#   'belongstolisting': '__GIP__1__',
#   'sortgroup': 3,
#   'sortgrouptext': '',
#   'paramdesc': 'Type'}]

# %%
list_part_number = [json_['partnumber'] for json_ in list_json]

list_part_number
# Out:
# ['GREEN5050GAL',
#  'MV5050GAL',
#  'AF3300',
#  'AF2100',
#  'AF2400',
#  'AF555',
#  '71175',
#  '71621']

# %%
list_manufacturer = [json_['catalogname'] for json_ in list_json]

list_manufacturer
# Out:
# ['FVP',
#  'FVP',
#  'PRESTONE',
#  'PRESTONE',
#  'PRESTONE',
#  'PRESTONE',
#  'PRESTONE',
#  'PRESTONE']

# %%
list_partition = [json_['sortgrouptext'] for json_ in list_json]

list_partition
# Out:
# ['Economy',
#  'Economy',
#  'Economy',
#  'Premium',
#  'Premium',
#  'Standard Replacement',
#  '',
#  '']

# %%
list_parameter = [json_['paramdesc'] for json_ in list_json]

list_parameter
# Out:
# ['Type', 'Type', 'Type', 'Type', 'Type', 'Type', 'Type', 'Type']

# %%
list_list_oem = [tbody.xpath('./tr[1]/td/span[contains(@title, "Replaces these Alternate")]/text()') for tbody in list_tbody]
list_oem = [','.join(list_oem) for list_oem in list_list_oem]
list_oem = [';'.join([oem_split.strip() for oem_split in oem.split(',')]) for oem in list_oem]

list_oem
# Out:
# ['GREENGAL;GREEN5050GAL',
#  'MVGAL;MV5050GAL',
#  'AF3200;AF3300',
#  'AF2000;AF2100',
#  'AF2400',
#  'AF555',
#  '71175',
#  '71621']

# %%
list_list_src = [json.loads(tbody.xpath('./tr[1]/td/div/input[contains(@id, "jsninlineimg[")]/@value')[0])['Slots'] if tbody.xpath('./tr[1]/td/div/input[contains(@id, "jsninlineimg[")]/@value') else [] for tbody in list_tbody]

list_list_src
# Out:
# [[{'TitlePhrase': '<b>Image Represents Prediluted Option</b>',
#    'ParamCodes': ['<b>Image Represents Prediluted Option</b>'],
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/949/50 50 prediluted orig green front VP__ra_m.jpg',
#     'Popup': '/info/949/50 50 prediluted orig green front VP.jpg',
#     'Full': '/info/949/50 50 prediluted orig green front VP.jpg'}},
#   {'TitlePhrase': '<b>Image Represents Concentrated Option</b>',
#    'ParamCodes': ['<b>Image Represents Concentrated Option</b>'],
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/949/full strength orig green front VP__ra_m.jpg',
#     'Popup': '/info/949/full strength orig green front VP.jpg',
#     'Full': '/info/949/full strength orig green front VP.jpg'}}],
#  [{'TitlePhrase': '<b>Image Represents Prediluted Option</b>',
#    'ParamCodes': ['<b>Image Represents Prediluted Option</b>'],
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/949/50 50 prediluted multi vehicle front VP__ra_m.jpg',
#     'Popup': '/info/949/50 50 prediluted multi vehicle front VP.jpg',
#     'Full': '/info/949/50 50 prediluted multi vehicle front VP.jpg'}},
#   {'TitlePhrase': '<b>Image Represents Concentrated Option</b>',
#    'ParamCodes': ['<b>Image Represents Concentrated Option</b>'],
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/949/full strength multi vehicle front VP__ra_m.jpg',
#     'Popup': '/info/949/full strength multi vehicle front VP.jpg',
#     'Full': '/info/949/full strength multi vehicle front VP.jpg'}}],
#  [{'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF3300_P04_FRO__ra_m.jpg',
#     'Popup': '/info/692/AF3300_P04_FRO.jpg',
#     'Full': '/info/692/AF3300_P04_FRO.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF3300_P01_BAC__ra_m.jpg',
#     'Popup': '/info/692/AF3300_P01_BAC.jpg',
#     'Full': '/info/692/AF3300_P01_BAC.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF3300_P01_TOP__ra_m.jpg',
#     'Popup': '/info/692/AF3300_P01_TOP.jpg',
#     'Full': '/info/692/AF3300_P01_TOP.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF3300_P01_BOT__ra_m.jpg',
#     'Popup': '/info/692/AF3300_P01_BOT.jpg',
#     'Full': '/info/692/AF3300_P01_BOT.jpg'}}],
#  [{'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF2100_P04_FRO__ra_m.jpg',
#     'Popup': '/info/692/AF2100_P04_FRO.jpg',
#     'Full': '/info/692/AF2100_P04_FRO.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': 'Prediluted'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF2100_P01_BAC__ra_m.jpg',
#     'Popup': '/info/692/AF2100_P01_BAC.jpg',
#     'Full': '/info/692/AF2100_P01_BAC.jpg'}},
#   {'TitlePhrase': 'Concentrated',
#    'ParamCodes': {'CON': 'Concentrated'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF2000_P04_FRO__ra_m.jpg',
#     'Popup': '/info/692/AF2000_P04_FRO.jpg',
#     'Full': '/info/692/AF2000_P04_FRO.jpg'}},
#   {'TitlePhrase': 'Concentrated',
#    'ParamCodes': {'CON': 'Concentrated'},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/AF2000_P01_BAC__ra_m.jpg',
#     'Popup': '/info/692/AF2000_P01_BAC.jpg',
#     'Full': '/info/692/AF2000_P01_BAC.jpg'}}],
#  [],
#  [],
#  [{'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71175_P04_FRO__ra_m.jpg',
#     'Popup': '/info/692/71175_P04_FRO.jpg',
#     'Full': '/info/692/71175_P04_FRO.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71175_P04_SID__ra_m.jpg',
#     'Popup': '/info/692/71175_P04_SID.jpg',
#     'Full': '/info/692/71175_P04_SID.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71175_P04_BOT__ra_m.jpg',
#     'Popup': '/info/692/71175_P04_BOT.jpg',
#     'Full': '/info/692/71175_P04_BOT.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71175_P04_TOP__ra_m.jpg',
#     'Popup': '/info/692/71175_P04_TOP.jpg',
#     'Full': '/info/692/71175_P04_TOP.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, '50': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71175_P01_BAC__ra_m.jpg',
#     'Popup': '/info/692/71175_P01_BAC.jpg',
#     'Full': '/info/692/71175_P01_BAC.jpg'}}],
#  [{'TitlePhrase': None,
#    'ParamCodes': {'0': None, 'CON': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71621_P04_FRO__ra_m.jpg',
#     'Popup': '/info/692/71621_P04_FRO.jpg',
#     'Full': '/info/692/71621_P04_FRO.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, 'CON': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71621_P04_SID__ra_m.jpg',
#     'Popup': '/info/692/71621_P04_SID.jpg',
#     'Full': '/info/692/71621_P04_SID.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, 'CON': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71621_P04_BOT__ra_m.jpg',
#     'Popup': '/info/692/71621_P04_BOT.jpg',
#     'Full': '/info/692/71621_P04_BOT.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, 'CON': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71621_P04_TOP__ra_m.jpg',
#     'Popup': '/info/692/71621_P04_TOP.jpg',
#     'Full': '/info/692/71621_P04_TOP.jpg'}},
#   {'TitlePhrase': None,
#    'ParamCodes': {'0': None, 'CON': None},
#    'Type': 'Single',
#    'ImageData': {'Thumb': '/info/692/71621_P01_BAC__ra_m.jpg',
#     'Popup': '/info/692/71621_P01_BAC.jpg',
#     'Full': '/info/692/71621_P01_BAC.jpg'}}]]

# %%
list_dict_src = []
for list_src in list_list_src:
    dict_src = {}
    for i, src in zip(range(len(list_src)), list_src):
        dict_src[str(i)] = 'https://www.rockauto.com' + src['ImageData']['Full'].strip()

    list_dict_src.append(dict_src)

list_dict_src
# Out:
# [{'0': 'https://www.rockauto.com/info/949/50 50 prediluted orig green front VP.jpg',
#   '1': 'https://www.rockauto.com/info/949/full strength orig green front VP.jpg'},
#  {'0': 'https://www.rockauto.com/info/949/50 50 prediluted multi vehicle front VP.jpg',
#   '1': 'https://www.rockauto.com/info/949/full strength multi vehicle front VP.jpg'},
#  {'0': 'https://www.rockauto.com/info/692/AF3300_P04_FRO.jpg',
#   '1': 'https://www.rockauto.com/info/692/AF3300_P01_BAC.jpg',
#   '2': 'https://www.rockauto.com/info/692/AF3300_P01_TOP.jpg',
#   '3': 'https://www.rockauto.com/info/692/AF3300_P01_BOT.jpg'},
#  {'0': 'https://www.rockauto.com/info/692/AF2100_P04_FRO.jpg',
#   '1': 'https://www.rockauto.com/info/692/AF2100_P01_BAC.jpg',
#   '2': 'https://www.rockauto.com/info/692/AF2000_P04_FRO.jpg',
#   '3': 'https://www.rockauto.com/info/692/AF2000_P01_BAC.jpg'},
#  {},
#  {},
#  {'0': 'https://www.rockauto.com/info/692/71175_P04_FRO.jpg',
#   '1': 'https://www.rockauto.com/info/692/71175_P04_SID.jpg',
#   '2': 'https://www.rockauto.com/info/692/71175_P04_BOT.jpg',
#   '3': 'https://www.rockauto.com/info/692/71175_P04_TOP.jpg',
#   '4': 'https://www.rockauto.com/info/692/71175_P01_BAC.jpg'},
#  {'0': 'https://www.rockauto.com/info/692/71621_P04_FRO.jpg',
#   '1': 'https://www.rockauto.com/info/692/71621_P04_SID.jpg',
#   '2': 'https://www.rockauto.com/info/692/71621_P04_BOT.jpg',
#   '3': 'https://www.rockauto.com/info/692/71621_P04_TOP.jpg',
#   '4': 'https://www.rockauto.com/info/692/71621_P01_BAC.jpg'}]

# %%
import re

list_price = [etree.tostring(tbody.xpath('./tr[1]/td[contains(@id, "listingtd[") and contains(@id, "][price]")]/span/span/span[contains(@id, "dprice[") and contains(@id, "][v]")]')[0]).decode('utf-8') for tbody in list_tbody]
list_dict_price = [{'0': re.sub(r'<.*?>', '', price.strip())} for price in list_price]

list_dict_price
# Out:
# [{'0': 'Choose Type at Left'},
#  {'0': 'Choose Type at Left'},
#  {'0': 'Choose Type at Left'},
#  {'0': 'Choose Type at Left'},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'}]

# %%
list_list_li = [tbody.xpath('./tr[1]/td/div/div/span/span[contains(@id, "ddrepl[optionchoice[__")]/table/tr/td[1]/div/div/ul/li') for tbody in list_tbody]
for i, list_li in zip(range(len(list_list_li)), list_list_li):
    if list_li:
        list_dict_price[i]['1'] = {}
        for j, li in zip(range(len(list_li[1:])), list_li[1:]):
            list_dict_price[i]['1'][str(j)] = re.sub(r' +', ' ', re.sub(r'<.*?>', ' ', etree.tostring(li.xpath('./div[contains(@class, "outer")]/div[contains(@class, "inner")]')[0]).decode('utf-8'))).strip()

list_dict_price
# Out:
# [{'0': 'Choose Type at Left',
#   '1': {'0': 'Prediluted ($6.11)', '1': 'Concentrated ($8.68)'}},
#  {'0': 'Choose Type at Left',
#   '1': {'0': 'Prediluted ($6.33)', '1': 'Concentrated ($8.91)'}},
#  {'0': 'Choose Type at Left',
#   '1': {'0': 'Prediluted ($6.61/Each) x 1 $6.61',
#    '1': 'Prediluted ($6.13/Each) x 6 $36.78',
#    '2': 'Concentrated ($8.79/Each) x 6 $52.74'}},
#  {'0': 'Choose Type at Left',
#   '1': {'0': 'Prediluted ($8.40/Each) x 1 $8.40',
#    '1': 'Concentrated ($12.78/Each) x 6 $76.68'}},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'},
#  {'0': 'Out of Stock'}]

# %%
df_temp = pd.DataFrame({'Make No': input_.loc[a, 'Make No'],
                        'Make': input_.loc[a, 'Make'],
                        'Model No': input_.loc[a, 'Model No'],
                        'Model': input_.loc[a, 'Model'],
                        'Engine No': input_.loc[a, 'Engine No'],
                        'Engine': input_.loc[a, 'Engine'],
                        'Car Code': input_.loc[a, 'Car Code'],
                        'Year': input_.loc[a, 'Year'],
                        'Group No': input_.loc[a, 'Group No'],
                        'Group': input_.loc[a, 'Group'],
                        'Type No': input_.loc[a, 'Type No'],
                        'Type': input_.loc[a, 'Type'],
                        'Type Code': input_.loc[a, 'Type Code'],
                        'Tab 1 Url': input_.loc[a, 'Tab 1 Url'],
                        'Part No': [i+1 for i in range(len(list_part_number))],
                        'Partition': list_partition,
                        'Manufacturer': list_manufacturer,
                        'Part Number': list_part_number,
                        'Key': list_key,
                        'JOIN_MPNTCK': [f'''{manufacturer};{part_number};{input_.loc[a, 'Type Code']};{key}''' for manufacturer, part_number, key in zip(list_manufacturer, list_part_number, list_key)],
                        'Tab 1 Note 1': list_note,
                        'Tab 1 Note 2': [json.dumps(dict_note) for dict_note in list_dict_note],
                        'Parameter': list_parameter,
                        'Json_Price': [json.dumps(dict_price) for dict_price in list_dict_price],
                        'OEM': list_oem,
                        'Info': list_info,
                        'Json_Src': [json.dumps(dict_src) for dict_src in list_dict_src]})

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Make No    Make  Model No Model  Engine No    Engine Car Code  Year  \
# 0        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 1        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 2        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 3        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 4        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 5        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 6        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 7        1  ABARTH         1  1000          1  982cc L4  1438885  1969
#
#    Group No           Group  ...   Part Number       Key  \
# 0         2  Cooling System  ...  GREEN5050GAL  13527801
# 1         2  Cooling System  ...     MV5050GAL  13527805
# 2         2  Cooling System  ...        AF3300  12973401
# 3         2  Cooling System  ...        AF2100  12973389
# 4         2  Cooling System  ...        AF2400  12973393
# 5         2  Cooling System  ...         AF555  12973409
# 6         2  Cooling System  ...         71175  12976777
# 7         2  Cooling System  ...         71621  12976781
#
#                        JOIN_MPNTCK  \
# 0  FVP;GREEN5050GAL;11393;13527801
# 1     FVP;MV5050GAL;11393;13527805
# 2   PRESTONE;AF3300;11393;12973401
# 3   PRESTONE;AF2100;11393;12973389
# 4   PRESTONE;AF2400;11393;12973393
# 5    PRESTONE;AF555;11393;12973409
# 6    PRESTONE;71175;11393;12976777
# 7    PRESTONE;71621;11393;12976781
#
#                                           Json_Price  \
# 0  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 1  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 2  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 3  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 4                              {"0": "Out of Stock"}
# 5                              {"0": "Out of Stock"}
# 6                              {"0": "Out of Stock"}
# 7                              {"0": "Out of Stock"}
#
#                                        Tab 1 Note 1  \
# 0          Low Silicate Blend; 1 Gallon; Green; IAT
# 1   Extended Life; All Makes / All Models; 1 Gallon
# 2  Prime®; Low Silicate Blend; 1 Gallon; Green; IAT
# 3   Extended Life; All Makes / All Models; 1 Gallon
# 4              High Mileage Blend; 1 Gallon; Yellow
# 5          Low Tox Antifreeze; 1 Gallon; Green; IAT
# 6                      All Makes / All Models 50/50
# 7         All Vehicles - 10yr/300k mi - Concentrate
#
#                                         Tab 1 Note 2 Parameter  \
# 0  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 1  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 2  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 3  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 4  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 5  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 6  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 7  {"separate": {"0": {"market": "US", "note": ""}}}      Type
#
#                      OEM                                               Info  \
# 0  GREENGAL;GREEN5050GAL  https://www.rockauto.com/en/moreinfo.php?pk=13...
# 1        MVGAL;MV5050GAL  https://www.rockauto.com/en/moreinfo.php?pk=13...
# 2          AF3200;AF3300  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 3          AF2000;AF2100  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 4                 AF2400  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 5                  AF555  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 6                  71175  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 7                  71621  https://www.rockauto.com/en/moreinfo.php?pk=12...
#
#                                             Json_Src
# 0  {"0": "https://www.rockauto.com/info/949/50 50...
# 1  {"0": "https://www.rockauto.com/info/949/50 50...
# 2  {"0": "https://www.rockauto.com/info/692/AF330...
# 3  {"0": "https://www.rockauto.com/info/692/AF210...
# 4                                                 {}
# 5                                                 {}
# 6  {"0": "https://www.rockauto.com/info/692/71175...
# 7  {"0": "https://www.rockauto.com/info/692/71621...
#
# [8 rows x 27 columns]

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Make No': input_.loc[a, 'Make No'],
                             'Make': input_.loc[a, 'Make'],
                             'Model No': input_.loc[a, 'Model No'],
                             'Model': input_.loc[a, 'Model'],
                             'Engine No': input_.loc[a, 'Engine No'],
                             'Engine': input_.loc[a, 'Engine'],
                             'Car Code': input_.loc[a, 'Car Code'],
                             'Year': input_.loc[a, 'Year'],
                             'Group No': input_.loc[a, 'Group No'],
                             'Group': input_.loc[a, 'Group'],
                             'Type No': input_.loc[a, 'Type No'],
                             'Type': input_.loc[a, 'Type'],
                             'Type Code': input_.loc[a, 'Type Code'],
                             'Tab 1 Url': input_.loc[a, 'Tab 1 Url']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No', 'Type No', 'Part No'],
                                                ascending=[True, True, True, False, True, True, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_part_1.xlsx', index=False)

output_correct
# Out:
#    Make No    Make  Model No Model  Engine No    Engine Car Code  Year  \
# 0        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 1        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 2        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 3        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 4        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 5        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 6        1  ABARTH         1  1000          1  982cc L4  1438885  1969
# 7        1  ABARTH         1  1000          1  982cc L4  1438885  1969
#
#    Group No           Group  ...   Part Number       Key  \
# 0         2  Cooling System  ...  GREEN5050GAL  13527801
# 1         2  Cooling System  ...     MV5050GAL  13527805
# 2         2  Cooling System  ...        AF3300  12973401
# 3         2  Cooling System  ...        AF2100  12973389
# 4         2  Cooling System  ...        AF2400  12973393
# 5         2  Cooling System  ...         AF555  12973409
# 6         2  Cooling System  ...         71175  12976777
# 7         2  Cooling System  ...         71621  12976781
#
#                        JOIN_MPNTCK  \
# 0  FVP;GREEN5050GAL;11393;13527801
# 1     FVP;MV5050GAL;11393;13527805
# 2   PRESTONE;AF3300;11393;12973401
# 3   PRESTONE;AF2100;11393;12973389
# 4   PRESTONE;AF2400;11393;12973393
# 5    PRESTONE;AF555;11393;12973409
# 6    PRESTONE;71175;11393;12976777
# 7    PRESTONE;71621;11393;12976781
#
#                                           Json_Price  \
# 0  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 1  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 2  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 3  {"0": "Choose Type at Left", "1": {"0": "Predi...
# 4                              {"0": "Out of Stock"}
# 5                              {"0": "Out of Stock"}
# 6                              {"0": "Out of Stock"}
# 7                              {"0": "Out of Stock"}
#
#                                        Tab 1 Note 1  \
# 0          Low Silicate Blend; 1 Gallon; Green; IAT
# 1   Extended Life; All Makes / All Models; 1 Gallon
# 2  Prime®; Low Silicate Blend; 1 Gallon; Green; IAT
# 3   Extended Life; All Makes / All Models; 1 Gallon
# 4              High Mileage Blend; 1 Gallon; Yellow
# 5          Low Tox Antifreeze; 1 Gallon; Green; IAT
# 6                      All Makes / All Models 50/50
# 7         All Vehicles - 10yr/300k mi - Concentrate
#
#                                         Tab 1 Note 2 Parameter  \
# 0  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 1  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 2  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 3  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 4  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 5  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 6  {"separate": {"0": {"market": "US", "note": ""}}}      Type
# 7  {"separate": {"0": {"market": "US", "note": ""}}}      Type
#
#                      OEM                                               Info  \
# 0  GREENGAL;GREEN5050GAL  https://www.rockauto.com/en/moreinfo.php?pk=13...
# 1        MVGAL;MV5050GAL  https://www.rockauto.com/en/moreinfo.php?pk=13...
# 2          AF3200;AF3300  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 3          AF2000;AF2100  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 4                 AF2400  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 5                  AF555  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 6                  71175  https://www.rockauto.com/en/moreinfo.php?pk=12...
# 7                  71621  https://www.rockauto.com/en/moreinfo.php?pk=12...
#
#                                             Json_Src
# 0  {"0": "https://www.rockauto.com/info/949/50 50...
# 1  {"0": "https://www.rockauto.com/info/949/50 50...
# 2  {"0": "https://www.rockauto.com/info/692/AF330...
# 3  {"0": "https://www.rockauto.com/info/692/AF210...
# 4                                                 {}
# 5                                                 {}
# 6  {"0": "https://www.rockauto.com/info/692/71175...
# 7  {"0": "https://www.rockauto.com/info/692/71621...
#
# [8 rows x 27 columns]

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Make No', 'Model No', 'Engine No', 'Year', 'Group No', 'Type No'],
                                            ascending=[True, True, True, False, True, True],
                                            ignore_index=True)
    output_error.to_excel('./test_part_1_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
