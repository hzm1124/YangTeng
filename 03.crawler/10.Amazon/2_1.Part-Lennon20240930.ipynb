# %%
import os

list_file = sorted(list(os.walk('./file/1.url'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_2-part_error.xlsx']

# %%
file = list_file[0]

file
# Out:
# 'crawler_2-part_error.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/1.url/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Url'].tolist()
# Out:
# 总数量：2
# ['https://www.amazon.com/dp/B0CHYBKQPM?language=en_US',
#  'https://www.amazon.com/dp/B0CGX5KFSF?language=en_US']

# %%
from selenium.webdriver import ChromeOptions

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service

option = ChromeOptions()
option.add_experimental_option('useAutomationExtension', False)
option.add_experimental_option('excludeSwitches', ['enable-automation'])
option.add_argument('--disable-blink-features=AutomationControlled')
option.add_argument('--disable-dev-shm-usage')
option.add_argument('--disable-gpu')
option.add_argument('--no-sandbox')
# option.add_argument('--headless=new')
# option.add_argument('blink-settings=imagesEnabled=false')
option.add_argument(get_header(method='selenium'))
option.add_argument(get_proxy(method='selenium'))
option.page_load_strategy = 'eager'

browser = Chrome(service=Service('../chromedriver'), options=option)
browser.maximize_window()

# = = = = = = = = = = = = = = =

b = 0
while True:
    b += 1
    print(b)
    try:
        browser.get('https://www.amazon.com/?language=en_US')
        
        break
    except KeyboardInterrupt:
        browser.quit()
        break
    except:
        browser.quit()
        continue

browser
# Out:
# 1
# <selenium.webdriver.chrome.webdriver.WebDriver (session="7d2d16315a5247e844c3f3dddd41cbc9")>

# %%
input(f'''fuck-{file.removesuffix('.xlsx')}?: ''')
# Out:
# fuck-crawler_2-part_error?:  fuck
# 'fuck'

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
from bs4 import BeautifulSoup
from lxml import etree

b = 0
while True:
    b += 1
    print(b)
    try:
        request_url = input_.loc[a, 'Url']

        browser.get(request_url)

        soup = BeautifulSoup(browser.page_source, 'lxml')
        html = etree.HTML(str(soup))

        with open('./part.html', 'w', encoding='UTF-8') as file:
            file.write(str(soup))
        break
    except KeyboardInterrupt:
        break
    except:
        continue
# Out:
# 1

# %%
import re

zip_code = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', html.xpath('//span[@id="glow-ingress-line2"]/text()')[0]).strip()

zip_code
# Out:
# 'Chino 91710'

# %%
price = html.xpath('//span[@class="a-offscreen"]/text()')[0].strip() if html.xpath('//span[@class="a-offscreen"]/text()') else ''

price
# Out:
# '$15.99'

# %%
import json

dict_src, list_src = {}, json.loads('{"initial":[{' + browser.page_source.split('\'colorImages\': { \'initial\': [{')[1].split('}]},')[0] + '}]}')['initial']
for i, src in enumerate(list_src):
    dict_src[str(i)] = src['hiRes'].strip() if src['hiRes'] else src['large'].strip()

dict_src
# Out:
# {'0': 'https://m.media-amazon.com/images/I/81sfgvLafuL._AC_SL1500_.jpg',
#  '1': 'https://m.media-amazon.com/images/I/712y+eWmvmL._AC_SL1500_.jpg',
#  '2': 'https://m.media-amazon.com/images/I/71KLzoDzjXL._AC_SL1500_.jpg',
#  '3': 'https://m.media-amazon.com/images/I/71+PNVGBV6L._AC_SL1500_.jpg',
#  '4': 'https://m.media-amazon.com/images/I/81llHhlEG9L._AC_SL1500_.jpg',
#  '5': 'https://m.media-amazon.com/images/I/71gxTajGVXL._AC_SL1500_.jpg'}

# %%
list_tr, dict_count = html.xpath('//table[@class="a-normal a-spacing-micro"]/tbody/tr'), {}
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/span/text()')[0]).strip()
    if key in dict_count:
        dict_count[key] += 1
    else:
        dict_count[key] = 1

dict_overview, dict_no = {}, {}
for i, tr in enumerate(list_tr):
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/span/text()')[0]).strip()
    if dict_count[key] == 1:
        dict_overview[str(i)] = {key: re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/span/text()')[1]).strip()}
    else:
        if key in dict_no:
            dict_no[key] += 1
        else:
            dict_no[key] = 1
        dict_overview[str(i)] = {f'{key}-{dict_no[key]}': re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/span/text()')[1]).strip()}

dict_overview
# Out:
# {'0': {'Brand': 'Miracase'},
#  '1': {'Color': 'Dark Black'},
#  '2': {'Compatible Devices': 'Smartphones'},
#  '3': {'Compatible Phone Models': ''},
#  '4': {'Mounting Type': 'Vent'}}

# %%
about, list_span = '', [re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', text).strip() for text in html.xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]/li/span/text()')]
for i, span in zip(range(len(list_span)), list_span):
    about += f'{i+1}. {span}\n'

print(about.strip())
# Out:
# 1. Never Fall Off-Metal Hook Design: Miracase car phone holder adopts simplified locking design. The steel metal hook will catch one of car air vent blades and provide excellent strudiness. It will work well for your car even in extremely harsh environments. NOTE: ONLY Compatible with horizontal and vertical vents. Not suitable for round vents
# 2. One-hand Operation: With quick release button, adjustable clamp arms and foot, Miracase car phone mount makes it very easy to insert and remove your phone with single hand. Provide you with safer driving whether you are talking, navigating, listening to music or charging
# 3. Universal Compatibility: Miracase cell phone car mount is compatible with the smartphones (4.0-7.2 inches) and thicker cases. Note!!The lengh of vent clip hook is MAX 1.4inch(3.6cm), it will be compatible with vent blades less than 1.4 inches (3.6 cm) wide. Not suitable for Round Vent
# 4. 360-degree Flexible Rotation: The 360-degree rotatable design will provide you with the best viewing angle to keep secure driving. You can place your phone in any orientation (landscape, portrait and more), Just enjoy the best drving experience
# 5. Professional Support: Please contact us for any product issues, a satisfying solution is promised forever

# %%
browser.page_source.split('jQuery.parseJSON(\'')[1]
# Out:
# '{"dataInJson":null,"alwaysIncludeVideo":true,"autoplayVideo":false,"defaultColor":"initial","mainImageSizes":[["342","445"],["385","500"],["425","550"],["466","606"],["522","679"],["569","741"],["679","879"]],"maxAlts":7,"altsOnLeft":true,"productGroupID":"wireless_display_on_website","lazyLoadExperienceDisabled":true,"lazyLoadExperienceOnHoverDisabled":false,"useChromelessVideoPlayer":false,"colorToAsin":{"Pink":{"asin":"B0CYGLWRWT"},"Blue":{"asin":"B0CHY9HX3J"},"Dark Black":{"asin":"B0CHYBKQPM"},"Black":{"asin":"B082SDVTWB"}},"refactorEnabled":true,"useIV":true,"tabletWeb":false,"views":["ImageBlockMagnifierView","ImageBlockAltImageView","ImageBlockVideoView","ImageBlockTwisterView","ImageBlockImmersiveViewImages","ImageBlockImmersiveViewVideos","ImageBlockImmersiveViewDimensionIngress","ImageBlockImmersiveViewShowroom","ImageBlockImmersiveView360","ImageBlockTabbedImmersiveView","ImageBlockShoppableSceneView"],"enhancedHoverOverlay":false,"landingAsinColor":"Dark Black","colorImages":{"Pink":[{"large":"https://m.media-amazon.com/images/I/41-NH7qgpyL._AC_.jpg","thumb":"https://m.media-amazon.com/images/I/41-NH7qgpyL._AC_SR38,50_.jpg","hiRes":"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SL1500_.jpg","variant":"MAIN","main":{"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX385_.jpg":["385","385"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX466_.jpg":["466","466"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX425_.jpg":["425","425"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX569_.jpg":["569","569"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX522_.jpg":["522","522"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX342_.jpg":["342","342"],"https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX679_.jpg":["679","679"]}},{"large":"https://m.media-amaz
#  'maxAlts': 7,
#  'altsOnLeft': True,
#  'productGroupID': 'wireless_display_on_website',
#  'lazyLoadExperienceDisabled': True,
#  'lazyLoadExperienceOnHoverDisabled': False,
#  'useChromelessVideoPlayer': False,
#  'colorToAsin': {'Pink': {'asin': 'B0CYGLWRWT'},
#   'Blue': {'asin': 'B0CHY9HX3J'},
#   'Dark Black': {'asin': 'B0CHYBKQPM'},
#   'Black': {'asin': 'B082SDVTWB'}},
#  'refactorEnabled': True,
#  'useIV': True,
#  'tabletWeb': False,
#  'views': ['ImageBlockMagnifierView',
#   'ImageBlockAltImageView',
#   'ImageBlockVideoView',
#   'ImageBlockTwisterView',
#   'ImageBlockImmersiveViewImages',
#   'ImageBlockImmersiveViewVideos',
#   'ImageBlockImmersiveViewDimensionIngress',
#   'ImageBlockImmersiveViewShowroom',
#   'ImageBlockImmersiveView360',
#   'ImageBlockTabbedImmersiveView',
#   'ImageBlockShoppableSceneView'],
#  'enhancedHoverOverlay': False,
#  'landingAsinColor': 'Dark Black',
#  'colorImages': {'Pink': [{'large': 'https://m.media-amazon.com/images/I/41-NH7qgpyL._AC_.jpg',
#     'thumb': 'https://m.media-amazon.com/images/I/41-NH7qgpyL._AC_SR38,50_.jpg',
#     'hiRes': 'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SL1500_.jpg',
#     'variant': 'MAIN',
#     'main': {'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX385_.jpg': ['385',
#       '385'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX466_.jpg': ['466',
#       '466'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX425_.jpg': ['425',
#       '425'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX569_.jpg': ['569',
#       '569'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX522_.jpg': ['522',
#       '522'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX342_.jpg': ['342',
#       '342'],
#      'https://m.media-amazon.com/images/I/71HJLRGAYjL._AC_SX679_.jpg': ['679',
#       '679']}},
#    {'large': 'https://m.media-amazon.com/images/I/51hO5n9ajgL._AC_.jpg',
#     'thumb': 'https://m.media-amazon.com/images/I/51hO5n9ajgL._AC_SR38,50_.jpg',
#     'hiRes': 'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SL1500_.jpg',
#     'variant': 'PT01',
#     'main': {'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX342_.jpg': ['342',
#       '342'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX679_.jpg': ['679',
#       '679'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX466_.jpg': ['466',
#       '466'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX569_.jpg': ['569',
#       '569'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX385_.jpg': ['385',
#       '385'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX425_.jpg': ['425',
#       '425'],
#      'https://m.media-amazon.com/images/I/712SDkSYfVL._AC_SX522_.jpg': ['522',
#       '522']}},
#    {'large': 'https://m.media-amazon.com/images/I/51wqND16RpL._AC_.jpg',
#     'thumb': 'https://m.media-amazon.com/images/I/51wqND16RpL._AC_SR38,50_.jpg',
#     'hiRes': 'https://m.media-amazon.com/images/I
AC_SR38,50_.jpg',
#     'hiRes': 'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SL1001_.jpg',
#     'variant': 'PT04',
#     'main': {'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX522_.jpg': ['522',
#       '522'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX679_.jpg': ['679',
#       '679'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX342_.jpg': ['342',
#       '342'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX425_.jpg': ['425',
#       '425'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX466_.jpg': ['466',
#       '466'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX385_.jpg': ['385',
#       '385'],
#      'https://m.media-amazon.com/images/I/61R2eMEufjL._AC_SX569_.jpg': ['569',
#       '569']}},
#    {'large': 'https://m.media-amazon.com/images/I/51sLrF6Vg7L._AC_.jpg',
#     'thumb': 'https://m.media-amazon.com/images/I/51sLrF6Vg7L._AC_SR38,50_.jpg',
#     'hiRes': 'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SL1001_.jpg',
#     'variant': 'PT05',
#     'main': {'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX522_.jpg': ['522',
#       '522'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX569_.jpg': ['569',
#       '569'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX385_.jpg': ['385',
#       '385'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX679_.jpg': ['679',
#       '679'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX342_.jpg': ['342',
#       '342'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX425_.jpg': ['425',
#       '425'],
#      'https://m.media-amazon.com/images/I/61CE6Y6WbkL._AC_SX466_.jpg': ['466',
#       '466']}}]},
#  'heroImages': {'Pink': None, 'Blue': None, 'Dark Black': None, 'Black': None},
#  'enable360Map': {},
#  'staticImages': {'hoverZoomIcon': 'https://m.media-amazon.com/images/G/01/img11/apparel/UX/DP/icon_zoom._CB485946671_.png',
#   'shoppableSceneViewProductsButton': 'https://m.media-amazon.com/images/G/01/shopbylook/shoppable-images/view_products._CB427832024_.svg',
#   'zoomLensBackground': 'https://m.media-amazon.com/images/G/01/apparel/rcxgs/tile._CB483369110_.gif',
#   'shoppableSceneDotHighlighted': 'https://m.media-amazon.com/images/G/01/shopbylook/shoppable-images/dot_highlighted._CB649293510_.svg',
#   'zoomInCur': 'https://m.media-amazon.com/images/G/01/detail-page/cursors/zoomIn._CB485921866_.cur',
#   'shoppableSceneSideSheetClose': 'https://m.media-amazon.com/images/G/01/shopbylook/shoppable-images/close_x_white._CB404688921_.png',
#   'shoppableSceneBackToTopArrow': 'https://m.media-amazon.com/images/G/01/shopbylook/shoppable-images/back_to_top_arrow._CB427936690_.svg',
#   'arrow': 'https://m.media-amazon.com/images/G/01/javascripts/lib/popover/images/light/sprite-vertical-popover-arrow._CB485933082_.png',
#   'icon360V2': 'https://m.media-amazon.com/images/G/01/HomeCustomProduct/imageBlock-360-thumbnail-icon-small._CB612115888_.png',
#   'zoomIn': 'https://m.media-amazon.com/images/G/01/detail-page/cursors/zoom-in._CB485944643_.bmp',
#   'zoomOut': 'https://m.media-amazon.com/images/G/01/detail-page/cursors/zoom-out._CB485943857_.bmp',
#   'videoThumbIcon': 'https://m.media-amazon.com/images/G/01/Quarterdeck/en_US/images/video._CB485935537_SX38_SY50_CR,0,0,38,50_.gif',
#   'spinnerNoLabel': 'https://m.media-amazon.com/images/G/01/ui/loadIndicators/loading-large._CB485945288_.gif',
#   'zoomOutCur': 'https://m.media-amazon.com/images/G/01/detail-page/cursors/zoomOut._CB485921725_.cur',
#   'videoSWFPath': 'https://m.media-amazon.com/images/G/01/Quarterdeck/en_US/video/20110518115040892/Video._CB485981003_.swf',
#   'grabbing': 'https://m.media-amazon.com/images/G/01/HomeCustomProduct/grabbingbox._CB485943551_.cur',
#   'shoppableSceneDot': 'https://m.media-amazon.com/images/G/01/shopbylook/shoppable-images/dot._CB649293510_.svg',
#   'icon360': 'https://m.media-amazon.com/images/G/01/HomeCustomProduct/360_icon_73x73v2._CB485971279_SX38_SY50_CR,0,0,38,50_.png',
#   'grab': 'https://m.media-amazon.com/images/G/01/HomeCustomProduct/grabbox._CB485922675_.cur',
#   'spinner': 'https://m.media-amazon.com/images/G/01/ui/loadIndicators/loading-large_labeled._CB485921664_.gif'},
#  'staticStrings': {'dragToSpin': 'Drag to Spin',
#   'videos': 'Videos',
#   'video': 'video',
#   'shoppableSceneTabsTitleT3': 'Shop the collection',
#   'shoppableSceneTabsTitle': 'Shop similar items',
#   'shoppableSceneTabsTitleT2': 'Shop this style ',
#   'rollOverToZoom': 'Roll over image to zoom in',
#   'singleVideo': 'VIDEO',
#   'clickSceneTagsToShopProducts': 'Click the dots to see similar items',
#   'close': 'Close',
#   'shoppableSceneViewProductsButton': 'Shop similar items',
#   'images': 'Images',
#   'watchMoreVideos': 'Click to see more videos',
#   'shoppableSceneViewProductsButtonT2': 'Shop this style ',
#   'shoppableSceneViewProductsButtonT1': 'Shop the look',
#   'shoppableSceneViewProductsButtonT3': 'Shop the collection',
#   'allMedia': 'All Media',
#   'clickToExpand': 'Click image to open expanded view',
#   'shoppableSceneTabsTitleT1': 'Shop the look',
#   'playVideo': 'Click to play video',
#   'shoppableSceneNoSuggestions': 'No results available',
#   'touchToZoom': 'Touch the image to zoom in',
#   'multipleVideos': 'VIDEOS',
#   'shoppableSceneSeeMoreString': 'See more',
#   'pleaseSelect': 'Please select',
#   'clickToZoom': 'Click on image to zoom in'},
#  'useChildVideos': True,
#  'useClickZoom': False,
#  'useHoverZoom': True,
#  'useHoverZoomIpad': False,
#  'visualDimensions': ['color_name'],
#  'mainImageHeightPartitions': None,
#  'mainImageMaxSizes': None,
#  'heroFocalPoint': None,
#  'showMagnifierOnHover': False,
#  'disableHoverOnAltImages': False,
#  'overrideAltImageClickAction': False,
#  'naturalMainImageSize': None,
#  'imgTagWrapperClasses': None,
#  'prioritizeVideos': False,
#  'usePeekHover': False,
#  'fadeMagnifier': False,
#  'repositionHeroImage': False,
#  'heroVideoVariant': None,
#  'videos': [{'creatorProfile': {},
#    'groupType': 'IB_G1',
#    'aciContentId': 'amzn1.vse.video.0b7cacf1b06148aa9ad14ea69965b520',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/61DRnSljd+L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg',
#    'durationSeconds': 50,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'Instructions for Use of Miracase Car Mount',
#    'languageCode': 'en_US',
#    'holderId': 'holder0b7cacf1b06148aa9ad14ea69965b520',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/860f3824-b83b-4cf5-9e8c-5c88b55378f5/default.jobtemplate.hls.m3u8',
#    'videoHeight': '1080',
#    'videoWidth': '1920',
#    'durationTimestamp': '00:50',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/61DRnSljd+L.SX522_.jpg',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'jpg',
#     'physicalID': None,
#     'width': '966',
#     'height': '544'},
#    'mediaObjectId': '0b7cacf1b06148aa9ad14ea69965b520',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/61DRnSljd+L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg'},
#   {'creatorProfile': {},
#    'groupType': 'IB_G2',
#    'aciContentId': 'amzn1.vse.video.0f9f246325cc468c99ff07e97e3542fe',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/91GJyIqWJ2L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg',
#    'durationSeconds': 224,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'MUST WATCH Overview!  Does Miracase Work?',
#    'languageCode': 'en_US',
#    'holderId': 'holder0f9f246325cc468c99ff07e97e3542fe',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/8c4f5d03-d886-4942-b5c2-995cc43d234e/default.jobtemplate.hls.m3u8',
#    'videoHeight': '1080',
#    'videoWidth': '1920',
#    'durationTimestamp': '03:44',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/91GJyIqWJ2L.SX522_.jpg',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'jpg',
#     'physicalID': None,
#     'width': '1920',
#     'height': '1080'},
#    'mediaObjectId': '0f9f246325cc468c99ff07e97e3542fe',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/91GJyIqWJ2L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg'},
#   {'creatorProfile': {},
#    'groupType': 'IB_G2',
#    'aciContentId': 'amzn1.vse.video.05d59b3a93ad45679e090279ae1db9d7',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/71I+O9Zxi9L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg',
#    'durationSeconds': 128,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'Miracase Phone Holder with Metal Clip',
#    'languageCode': 'en_US',
#    'holderId': 'holder05d59b3a93ad45679e090279ae1db9d7',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/cd6452a8-4772-492b-928c-93eba8ab7688/default.jobtemplate.hls.m3u8',
#    'videoHeight': '1080',
#    'videoWidth': '1920',
#    'durationTimestamp': '02:08',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/71I+O9Zxi9L.SX522_.jpg',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'jpg',
#     'physicalID': None,
#     'width': '1760',
#     'height': '990'},
#    'mediaObjectId': '05d59b3a93ad45679e090279ae1db9d7',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/71I+O9Zxi9L.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg'},
#   {'creatorProfile': {},
#    'groupType': 'IB_G2',
#    'aciContentId': 'amzn1.vse.video.04b422b5097a445b9a65ce12e538702a',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/816yjX7w8jL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.png',
#    'durationSeconds': 159,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'Honest Review of Car Vent Holder',
#    'languageCode': 'en_US',
#    'holderId': 'holder04b422b5097a445b9a65ce12e538702a',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/abed266b-2e53-45ae-941c-2220837b9959/default.jobtemplate.hls.m3u8',
#    'videoHeight': '1080',
#    'videoWidth': '1920',
#    'durationTimestamp': '02:39',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/816yjX7w8jL.SX522_.png',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'png',
#     'physicalID': None,
#     'width': '1080',
#     'height': '1080'},
#    'mediaObjectId': '04b422b5097a445b9a65ce12e538702a',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/816yjX7w8jL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.png'},
#   {'creatorProfile': {},
#    'groupType': 'IB_G2',
#    'aciContentId': 'amzn1.vse.video.021f7c2e7bbf45dabb02c814ed814af4',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/51KH8is6lqL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg',
#    'durationSeconds': 120,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'This CAR PHONE HOLDER has so many cool features! ',
#    'languageCode': 'en_US',
#    'holderId': 'holder021f7c2e7bbf45dabb02c814ed814af4',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/b20a28c1-2c87-47bf-824d-d7f7ad54f186/default.jobtemplate.hls.m3u8',
#    'videoHeight': '1080',
#    'videoWidth': '1920',
#    'durationTimestamp': '02:00',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/51KH8is6lqL.SX522_.jpg',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'jpg',
#     'physicalID': None,
#     'width': '640',
#     'height': '360'},
#    'mediaObjectId': '021f7c2e7bbf45dabb02c814ed814af4',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/51KH8is6lqL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.jpg'},
#   {'creatorProfile': {},
#    'groupType': 'IB_G2',
#    'aciContentId': 'amzn1.vse.video.0c1e7654a9d543909db2c1ad47a096e6',
#    'offset': '0',
#    'thumb': 'https://m.media-amazon.com/images/I/C1Dxj3737lL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.png',
#    'durationSeconds': 83,
#    'marketPlaceID': 'ATVPDKIKX0DER',
#    'isVideo': True,
#    'isHeroVideo': False,
#    'title': 'Favorite features of the Miracase Phone Holder',
#    'languageCode': 'en_US',
#    'holderId': 'holder0c1e7654a9d543909db2c1ad47a096e6',
#    'url': 'https://m.media-amazon.com/images/S/vse-vms-transcoding-artifact-us-east-1-prod/2c4859bb-0027-4a7a-8aff-4e5f244542a7/default.vertical.jobtemplate.hls.m3u8',
#    'videoHeight': '1920',
#    'videoWidth': '1080',
#    'durationTimestamp': '01:23',
#    'rankingStrategy': 'DEFAULT',
#    'slateUrl': 'https://m.media-amazon.com/images/I/C1Dxj3737lL.SX522_.png',
#    'minimumAge': 0,
#    'variant': 'MAIN',
#    'slateHash': {'extension': 'png',
#     'physicalID': None,
#     'width': '1179',
#     'height': '2556'},
#    'mediaObjectId': '0c1e7654a9d543909db2c1ad47a096e6',
#    'thumbUrl': 'https://m.media-amazon.com/images/I/C1Dxj3737lL.SX38_SY50_CR,0,0,38,50_BG85,85,85_BR-120_PKdp-play-icon-overlay__.png'}],
#  'title': 'Miracase Phone Holders for Your Car with Newest Metal Hook Clip, Air Vent Cell Phone Car Mount, Universal Automobile Cradle Fit for iPhone Android and All Smartphones, Dark Black',
#  'airyConfigEnabled': False,
#  'airyConfig': None,
#  'vseVideoDataSourceTreatment': 'T1',
#  'mediaAsin': 'B0CHYBKQPM',
#  'parentAsin': 'B0D9K47HP8',
#  'largeSCLVideoThumbnail': False,
#  'displayVideoBanner': False,
#  'useVSEVideos': True,
#  'notShowVideoCount': False,
#  'enableS2WithoutS1': False,
#  'useTabbedImmersiveView': True,
#  'dpRequestId': 'EQ93BNZGX9885H4B1KF8',
#  'contentWeblab': '',
#  'contentWeblabTreatment': '',
#  'dp60VideoThumbMap': None,
#  'videoBackgroundChromefulMainView': 'black'}

# %%
title = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', dict_['title']).strip()

title
# Out:
# 'Miracase Phone Holders for Your Car with Newest Metal Hook Clip, Air Vent Cell Phone Car Mount, Universal Automobile Cradle Fit for iPhone Android and All Smartphones, Dark Black'

# %%
parent_asin = dict_['parentAsin'].strip()

parent_asin
# Out:
# 'B0D9K47HP8'

# %%
list_tr, dict_count = html.xpath('//table[@id="productDetails_techSpec_section_1"]/tbody/tr'), {}
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./th/text()')[0]).strip()
    if key in dict_count:
        dict_count[key] += 1
    else:
        dict_count[key] = 1

dict_technical, dict_no = {}, {}
for i, tr in enumerate(list_tr):
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./th/text()')[0]).strip()
    if dict_count[key] == 1:
        dict_technical[str(i)] = {key: re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/text()')[0]).strip()}
    else:
        if key in dict_no:
            dict_no[key] += 1
        else:
            dict_no[key] = 1
        dict_technical[str(i)] = {f'{key}-{dict_no[key]}': re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/text()')[0]).strip()}

dict_technical
# Out:
# {}

# %%
i, dict_additional, list_tr = 0, {}, html.xpath('//table[@id="productDetails_detailBullets_sections1"]/tbody/tr')
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./th/text()')[0]).strip()
    if key == 'Customer Reviews':
        dict_additional[str(i)] = {'Rating': tr.xpath('./td/div/span[@data-action="acrStarsLink-click-metrics"]/span/@title')[0].strip()}
        dict_additional[str(i+1)] = {'Rating Count': tr.xpath('./td/div/span[@data-action="acrLink-click-metrics"]/a/span/text()')[0].strip()}
        i += 2
    elif key == 'Best Sellers Rank':
        dict_additional[str(i)] = {key: {}}
        list_span = [etree.tostring(span).decode('utf-8') for span in tr.xpath('./td/span/span')]
        list_span = [re.sub(r'<.*?>|\(.*?\)', '', span).strip() for span in list_span]
        list_href = [f'https://www.amazon.com{href.strip()}' for href in tr.xpath('./td/span/span/a/@href')]
        for (j, span), href in zip(enumerate(list_span), list_href):
            dict_additional[str(i)][key][str(j)] = {span: href}
        i += 1
    else:
        dict_additional[str(i)] = {key: re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/text()')[0]).strip()}
        i += 1

dict_additional
# Out:
# {}

# %%
list_tr, dict_count = html.xpath('//div[@id="detailBulletsWrapper_feature_div"]/div[@id="detailBullets_feature_div"]/ul/li/span'), {}
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./span/text()')[0]).strip().removesuffix(':').strip()
    if key in dict_count:
        dict_count[key] += 1
    else:
        dict_count[key] = 1

dict_technical_2, dict_no = {}, {}
for i, tr in enumerate(list_tr):
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./span/text()')[0]).strip().removesuffix(':').strip()
    if dict_count[key] == 1:
        dict_technical_2[str(i)] = {key: re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./span/text()')[1]).strip()}
    else:
        if key in dict_no:
            dict_no[key] += 1
        else:
            dict_no[key] = 1
        dict_technical_2[str(i)] = {f'{key}-{dict_no[key]}': re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./span/text()')[1]).strip()}

dict_technical_2
# Out:
# {}

# %%
i, dict_additional_2, list_span = 0, {}, html.xpath('//div[@id="detailBulletsWrapper_feature_div"]/ul[@class="a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list"]/li/span')
for span in list_span:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', span.xpath('./span/text()')[0]).strip().removesuffix(':').strip()
    if key == 'Customer Reviews':
        dict_additional_2[str(i)] = {'Rating': span.xpath('./div/span[@data-action="acrStarsLink-click-metrics"]/span/@title')[0].strip()}
        dict_additional_2[str(i+1)] = {'Rating Count': span.xpath('./div/span[@data-action="acrLink-click-metrics"]/a/span/text()')[0].strip()}
        i += 2
    elif key == 'Best Sellers Rank':
        dict_additional_2[str(i)] = {key: {}}
        list_span_2 = [etree.tostring(span_2).decode('utf-8') for span_2 in span.xpath('./descendant-or-self::span[@class="a-list-item"]')]
        list_span_2 = [re.sub(r'<ul.*?</ul>|<span.*?Best Sellers Rank.*?</span>|<.*?>|\(.*?\)', '', span_2).strip() for span_2 in list_span_2]
        list_href = [f'https://www.amazon.com{href.strip()}' for href in span.xpath('./descendant-or-self::a/@href')]
        for (j, span_2), href in zip(enumerate(list_span_2), list_href):
            dict_additional_2[str(i)][key][str(j)] = {span_2: href}
        i += 1
    else:
        print('fuck')

dict_additional_2
# Out:
# {}

# %%
list_tr, dict_count = html.xpath('//div[@id="productDetails_expanderSectionTables"]/div[@class="a-row"]/div[contains(@class, "a-column a-span6")]/div[@class="a-row a-spacing-medium-plus"]/div[@class="a-section"]/div[contains(@data-csa-c-content-id, "voyager-expander-btn")]/div/div[@class="a-section"]/table/tbody/tr'), {}
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./th/text()')[0]).strip().removesuffix(':').strip()
    if key in dict_count:
        dict_count[key] += 1
    else:
        dict_count[key] = 1

i, dict_information, dict_no = 0, {}, {}
for tr in list_tr:
    key = re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./th/text()')[0]).strip().removesuffix(':').strip()
    if dict_count[key] == 1:
        if key == 'Customer Reviews':
            dict_information[str(i)] = {'Rating': tr.xpath('./td/div/span[@data-action="acrStarsLink-click-metrics"]/span/@title')[0].strip()}
            dict_information[str(i+1)] = {'Rating Count': tr.xpath('./td/div/span[@data-action="acrLink-click-metrics"]/a/span/text()')[0].strip()}
            i += 2
        elif key == 'Best Sellers Rank':
            dict_information[str(i)] = {key: {}}
            list_span = [etree.tostring(span).decode('utf-8') for span in tr.xpath('./td/span/span')]
            list_span = [re.sub(r'<.*?>|\(.*?\)', '', span).strip() for span in list_span]
            list_href = [f'https://www.amazon.com{href.strip()}' for href in tr.xpath('./td/span/span/a/@href')]
            for (j, span), href in zip(enumerate(list_span), list_href):
                dict_information[str(i)][key][str(j)] = {span: href}
            i += 1
        else:
            dict_information[str(i)] = {key: re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/text()')[0]).strip()}
            i += 1
    else:
        if key in dict_no:
            dict_no[key] += 1
        else:
            dict_no[key] = 1
        dict_information[str(i)] = {f'{key}-{dict_no[key]}': re.sub(r'[\u0020\u00A0\u2000\u2001\u2002\u2003\u2004\u2005\u2006\u2007\u2008\u2009\u200a\u200b\u200c\u200d\u200e\u200f\u202f\u205f\u2060\u2061\u2062\u2063\u2064\u3000\ufeff ]+', ' ', tr.xpath('./td/text()')[0]).strip()}
        i += 1

dict_information
# Out:
# {'0': {'Rating': '4.3 out of 5 stars'},
#  '1': {'Rating Count': '28,872 ratings'},
#  '2': {'ASIN': 'B0CHYBKQPM'},
#  '3': {'Best Sellers Rank': {'0': {'#96 in Cell Phones &amp; Accessories': 'https://www.amazon.com/gp/bestsellers/wireless/ref=pd_zg_ts_wireless'},
#    '1': {'#3 in Cell Phone Automobile Cradles': 'https://www.amazon.com/gp/bestsellers/wireless/7072562011/ref=pd_zg_hrsr_wireless'}}},
#  '4': {'Model Number': 'miracase car phone holder'},
#  '5': {'Brand Name': 'Miracase'},
#  '6': {'Item Weight': '120 Grams'},
#  '7': {'Unit Count': '1.0 Count'},
#  '8': {'Item Dimensions': '3.19 x 2.52 x 4.92 inches'},
#  '9': {'Material Type': 'Carbon Steel'},
#  '10': {'Color': 'Dark Black'},
#  '11': {'Additional Features': '36 Months Service Support,Universal,Military-Grade Metal Hook,Support Thick Cases and Big Phones,Never Fall OFF,One-hand Operation,360° Hassle Flexible Rotation,Easy to Install,Ultra-Stable'},
#  '12': {'Compatible with Vehicle Type': 'Automobile'},
#  '13': {'Compatible Phone Models': 'iPhone 16 Series/15/15 Pro/15 Pro Max/15 Plus/14/ 14 Pro/ 14 Pro Max/ 14 Plus/ iPhone 13/13 Pro/13 Pro Max/13 Mini/12/12 Pro/12 Pro Max/12 mini/11/ 11 Pro/ 11 Pro Max/ SE 2020/8 Plus/ 8/7 Plus/7/XR/X/ XS max/XS/SE/6S/6 Plus/6S Plus/6/ 5s/ 5/ 4s/ 4, Samsung Galaxy S22 Ultra/S22/S21 5G/ S21+ 5G/ S21 Ultra 5G/ Note20/ S20/ S20+/ S20 Ultra 5G/ Note10/ Note10+/ S10/ S10+/ S10e/ S9/ S9+/ S8/ S8+/ Note 8/ S7/ S7 Edge/ S6/ S6 Edge/ S5/ S4, Google Pixel 4 / 4 XL / 3a XL / Pixel 3a / Pixel 3 XL / Pixel 3 / Pixel XL / Pixel 2 XL / Pixel 2 / Pixel'},
#  '14': {'Mounting Type': 'Vent'},
#  '15': {'Compatible Devices': 'Smartphones'}}

# %%
df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                         'Title': title,
                         'About': about.strip(),
                         'Price': price,
                         'Picture': '',
                         'Url': input_.loc[a, 'Url'],
                         'Json_Src': json.dumps(dict_src),
                         'Zip Code': zip_code,
                         'Parent ASIN': parent_asin,
                         'Json_Overview': json.dumps(dict_overview),
                         'Json_Technical': json.dumps(dict_technical),
                         'Json_Additional': json.dumps(dict_additional),
                         'Json_Technical 2': json.dumps(dict_technical_2),
                         'Json_Additional 2': json.dumps(dict_additional_2),
                         'Json_Information': json.dumps(dict_information)}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    No                                              Title  \
# 0   3  Miracase Phone Holders for Your Car with Newes...
#
#                                                About   Price Picture  \
# 0  1. Never Fall Off-Metal Hook Design: Miracase ...  $15.99
#
#                                                  Url  \
# 0  https://www.amazon.com/dp/B0CHYBKQPM?language=...
#
#                                             Json_Src     Zip Code Parent ASIN  \
# 0  {"0": "https://m.media-amazon.com/images/I/81s...  Chino 91710  B0D9K47HP8
#
#                                        Json_Overview Json_Technical  \
# 0  {"0": {"Brand": "Miracase"}, "1": {"Color": "D...             {}
#
#   Json_Additional Json_Technical 2 Json_Additional 2  \
# 0              {}               {}                {}
#
#                                     Json_Information
# 0  {"0": {"Rating": "4.3 out of 5 stars"}, "1": {...

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
browser.quit()

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
    df_temp.loc[0, 'Request_Url'] = request_url

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#    No                                              Title  \
# 0   3  Miracase Phone Holders for Your Car with Newes...
#
#                                                About   Price Picture  \
# 0  1. Never Fall Off-Metal Hook Design: Miracase ...  $15.99
#
#                                                  Url  \
# 0  https://www.amazon.com/dp/B0CHYBKQPM?language=...
#
#                                             Json_Src     Zip Code Parent ASIN  \
# 0  {"0": "https://m.media-amazon.com/images/I/81s...  Chino 91710  B0D9K47HP8
#
#                                        Json_Overview Json_Technical  \
# 0  {"0": {"Brand": "Miracase"}, "1": {"Color": "D...             {}
#
#   Json_Additional Json_Technical 2 Json_Additional 2  \
# 0              {}               {}                {}
#
#                                     Json_Information
# 0  {"0": {"Rating": "4.3 out of 5 stars"}, "1": {...

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[False],
                                            ignore_index=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
