# %% [markdown]
# - Update: 2023.05.11
#
# # 0. 配置参数
#
# - `ajax`：AJAX (ROCKAUTO)
# - `site_code`：品类在网站的内部编码

# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
from urllib.parse import quote
import requests
import json
from bs4 import BeautifulSoup
from lxml import etree
import time

# = = = = = = = = = = = = = = = = = =

site_code= '8528'

ajax = 'https://www.rockauto.com/catalog/catalogapi.php'

proxies = {'http': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818',
           'https': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['info',
                           'vehicle',
                           'status'])

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./part_out.xlsx', header=0)
list_info = df_menu['info'].to_list()
print('总数量：' + str(len(list_info)))
print()

# = = = = = = = = = = = = = = = = = =

work = Queue()
for info in list_info:
    work.put_nowait(info)

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        info = work.get_nowait()
        
        for i in range(31):
            try:
                headers = {'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8'}

                func = r'getbuyersguide'
                payload = r'{"partData":{"listing_data_essential":{"parttype":"' + site_code + '","partkey":"' + info.split('?')[1].split('pk=')[1].split('&')[0] + '"}}}'
                api_json_request = r'1'

                data = 'func=' + func + '&payload=' + quote(payload, safe=' ').replace(' ', '+') + '&api_json_request=' + api_json_request

                # = = = = = = = = = = = = = = = = = =

                resp = requests.post(ajax, headers=headers, data=data, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =

                html = json.loads(resp)['buyersguidepieces']['body']

                # = = = = = = = = = = = = = = = = = =

                soup = BeautifulSoup(html, 'lxml')

                # = = = = = = = = = = = = = = = = = =

                html = etree.HTML(str(soup))

                list_tr = html.xpath('//table[@class="nobmp"]/tr')

                # = = = = = = = = = = = = = = = = = =

                list_vehicle = []
                for tr in list_tr:
                    list_vehicle.append(' '.join(tr.xpath('./td/text()')))

                vehicle = '\n'.join(list_vehicle)

                # = = = = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'info': [info],
                                        'vehicle': [vehicle],
                                        'status': 'ok'})

                break

            except:
                if i == 30:
                    df_temp = pd.DataFrame({'info': [info],
                                            'vehicle': '',
                                            'status': ['error']})
                time.sleep(0.3)
                continue

        # = = = = = = = = = = = = = = = = = =

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(info + '  <->  [' + str(i) + '] - 剩余：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./vehicle_out.xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：55
#
# https://www.rockauto.com/en/moreinfo.php?pk=13699985  <->  [0] - 剩余：45
# https://www.rockauto.com/en/moreinfo.php?pk=14705157  <->  [0] - 剩余：44
# https://www.rockauto.com/en/moreinfo.php?pk=13699981  <->  [0] - 剩余：43
# https://www.rockauto.com/en/moreinfo.php?pk=14705149  <->  [0] - 剩余：42
# https://www.rockauto.com/en/moreinfo.php?pk=13699973  <->  [0] - 剩余：41
# https://www.rockauto.com/en/moreinfo.php?pk=9769820  <->  [0] - 剩余：40
# https://www.rockauto.com/en/moreinfo.php?pk=14705153  <->  [1] - 剩余：39
# https://www.rockauto.com/en/moreinfo.php?pk=10123600  <->  [1] - 剩余：38
# https://www.rockauto.com/en/moreinfo.php?pk=10353532  <->  [0] - 剩余：37
# https://www.rockauto.com/en/moreinfo.php?pk=11171069  <->  [0] - 剩余：36
# https://www.rockauto.com/en/moreinfo.php?pk=11171073  <->  [0] - 剩余：35
# https://www.rockauto.com/en/moreinfo.php?pk=10353528  <->  [0] - 剩余：34
# https://www.rockauto.com/en/moreinfo.php?pk=12495733  <->  [0] - 剩余：33
# https://www.rockauto.com/en/moreinfo.php?pk=10353536  <->  [0] - 剩余：32
# https://www.rockauto.com/en/moreinfo.php?pk=10627172  <->  [1] - 剩余：31
# https://www.rockauto.com/en/moreinfo.php?pk=11171077  <->  [0] - 剩余：30
# https://www.rockauto.com/en/moreinfo.php?pk=10627188  <->  [0] - 剩余：29
# https://www.rockauto.com/en/moreinfo.php?pk=10903204  <->  [0] - 剩余：28
# https://www.rockauto.com/en/moreinfo.php?pk=12755049  <->  [0] - 剩余：27
# https://www.rockauto.com/en/moreinfo.php?pk=12025777  <->  [0] - 剩余：26
# https://www.rockauto.com/en/moreinfo.php?pk=12025781  <->  [0] - 剩余：25
# https://www.rockauto.com/en/moreinfo.php?pk=12025789  <->  [0] - 剩余：24
# https://www.rockauto.com/en/moreinfo.php?pk=10353524  <->  [0] - 剩余：23
# https://www.rockauto.com/en/moreinfo.php?pk=10627192  <->  [0] - 剩余：22
# https://www.rockauto.com/en/moreinfo.php?pk=10903208  <->  [0] - 剩余：21
# https://www.rockauto.com/en/moreinfo.php?pk=12305681  <->  [0] - 剩余：20
# https://www.rockauto.com/en/moreinfo.php?pk=12755061  <->  [0] - 剩余：19
# https://www.rockauto.com/en/moreinfo.php?pk=13699977  <->  [0] - 剩余：18
# https://www.rockauto.com/en/moreinfo.php?pk=11245768  <->  [0] - 剩余：17
# https://www.rockauto.com/en/moreinfo.php?pk=12025785  <->  [0] - 剩余：16
# https://www.rockauto.com/en/moreinfo.php?pk=12025801  <->  [0] - 剩余：15
# https://www.rockauto.com/en/moreinfo.php?pk=12755053  <->  [0] - 剩余：14
# https://www.rockauto.com/en/moreinfo.php?pk=12025809  <->  [0] - 剩余：13
# https://www.rockauto.com/en/moreinfo.php?pk=12025813  <->  [0] - 剩余：12
# https://www.rockauto.com/en/moreinfo.php?pk=10627176  <->  [0] - 剩余：11
# https://www.rockauto.com/en/moreinfo.php?pk=4701423  <->  [0] - 剩余：10
# https://www.rockauto.com/en/moreinfo.php?pk=12495749  <->  [0] - 剩余：9
# https://www.rockauto.com/en/moreinfo.php?pk=12025821  <->  [0] - 剩余：8
# https://www.rockauto.com/en/moreinfo.php?pk=10907632  <->  [0] - 剩余：7
# https://www.rockauto.com/en/moreinfo.php?pk=10354000  <->  [0] - 剩余：6
# https://www.rockauto.com/en/moreinfo.php?pk=10123604  <->  [0] - 剩余：5
# https://www.rockauto.com/en/moreinfo.php?pk=12025793  <->  [0] - 剩余：4
# https://www.rockauto.com/en/moreinfo.php?pk=12025805  <->  [0] - 剩余：3
# https://www.rockauto.com/en/moreinfo.php?pk=10907636  <->  [0] - 剩余：2
# https://www.rockauto.com/en/moreinfo.php?pk=12025797  <->  [0] - 剩余：1
# https://www.rockauto.com/en/moreinfo.php?pk=10907652  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10627420  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10907656  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10354004  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10907660  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=12025817  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10627196  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=9452300  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=13699969  <->  [0] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10354012  <->  [0] - 剩余：0
#
# 搞定
# C:\Users\Lennon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
