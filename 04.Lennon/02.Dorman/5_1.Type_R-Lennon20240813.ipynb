# %%
import os

list_file = sorted(list(os.walk('./file/4.model'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['make_1.AC.xlsx',
#  'make_10.American LaFrance.xlsx',
#  'make_100.Lamborghini.xlsx',
#  'make_101.Lancia.xlsx',
#  'make_102.Land Rover.xlsx',
#  'make_103.Lexus.xlsx',
#  'make_104.Lincoln.xlsx',
#  'make_105.Lion.xlsx',
#  'make_106.Lotus.xlsx',
#  'make_107.MG.xlsx',
#  'make_108.Mack.xlsx',
#  'make_109.Maple Leaf Truck.xlsx',
#  'make_11.American Motors.xlsx',
#  'make_110.Maserati.xlsx',
#  'make_111.Maybach.xlsx',
#  'make_112.Mazda.xlsx',
#  'make_113.Mercedes-Benz.xlsx',
#  'make_114.Mercury.xlsx',
#  'make_115.Merkur.xlsx',
#  'make_116.Metropolitan.xlsx',
#  'make_117.Mini.xlsx',
#  'make_118.Mitsubishi.xlsx',
#  'make_119.Mitsubishi Fuso.xlsx',
#  'make_12.Aston Martin.xlsx',
#  'make_120.Mobility Ventures.xlsx',
#  'make_121.Monaco Coach.xlsx',
#  'make_122.Motor Coach Industries.xlsx',
#  'make_123.Nash.xlsx',
#  'make_124.National RV.xlsx',
#  'make_125.Neoplan.xlsx',
#  'make_126.New Flyer.xlsx',
#  'make_127.Newmar.xlsx',
#  'make_128.Nexus.xlsx',
#  'make_129.Nissan.xlsx',
#  'make_13.Asuna.xlsx',
#  'make_130.Nova Bus Corporation.xlsx',
#  'make_131.Oldsmobile.xlsx',
#  'make_132.Ontario Bus.xlsx',
#  'make_133.Opel.xlsx',
#  'make_134.Orion Bus.xlsx',
#  'make_135.Oshkosh Motor Truck Co..xlsx',
#  'make_136.PEMFAB.xlsx',
#  'make_137.PIERCE.xlsx',
#  'make_138.Packard.xlsx',
#  'make_139.Peterbilt.xlsx',
#  'make_14.Audi.xlsx',
#  'make_140.Peugeot.xlsx',
#  'make_141.Pierce Mfg. Inc..xlsx',
#  'make_142.Plymouth.xlsx',
#  'make_143.Pontiac.xlsx',
#  'make_144.Porsche.xlsx',
#  'make_145.Prevost.xlsx',
#  'make_146.REO Truck.xlsx',
#  'make_147.Ram.xlsx',
#  'make_148.Renault.xlsx',
#  'make_149.Renegade.xlsx',
#  'make_15.Austin.xlsx',
#  'make_150.Roadmaster Rail.xlsx',
#  'make_151.Rolls-Royce.xlsx',
#  'make_152.Rover.xlsx',
#  'make_153.SAVAGE.xlsx',
#  'make_154.SCHMIDT.xlsx',
#  'make_155.SEAGRAVE.xlsx',
#  'make_156.SMI.xlsx',
#  'make_157.SPARTAN.xlsx',
#  'make_158.SRT.xlsx',
#  'make_159.SUTPHEN.xlsx',
#  'make_16.Autocar.xlsx',
#  'make_160.Saab.xlsx',
#  'make_161.Saturn.xlsx',
#  'make_162.Scion.xlsx',
#  'make_163.Seat.xlsx',
#  'make_164.Shelby.xlsx',
#  'make_165.Simca.xlsx',
#  'make_166.Smart.xlsx',
#  'make_167.Spartan Motors.xlsx',
#  'make_168.Sterling.xlsx',
#  'make_169.Sterling Truck.xlsx',
#  'make_17.Autocar LLC..xlsx',
#  'make_170.Studebaker.xlsx',
#  'make_171.Subaru.xlsx',
#  'make_172.Sunbeam.xlsx',
#  'make_173.Suzuki.xlsx',
#  'make_174.Temsa Bus.xlsx',
#  'make_175.Tesla.xlsx',
#  'make_176.Thomas.xlsx',
#  'make_177.Thor Motor Coach.xlsx',
#  'make_178.Tiffin.xlsx',
#  'make_179.Toyota.xlsx',
#  'make_18.BMW.xlsx',
#  'make_180.Transportation Mfg Corp..xlsx',
#  'make_181.Triumph.xlsx',
#  'make_182.UD.xlsx',
#  'make_183.Unimog.xlsx',
#  'make_184.VPG.xlsx',
#  'make_185.Van Hool.xlsx',
#  'make_186.Volkswagen.xlsx',
#  'make_187.Volvo.xlsx',
#  'make_188.Western RV.xlsx',
#  'make_189.Western Star.xlsx',
#  'make_19.Bentley.xlsx',
#  'make_190.White Truck.xlsx',
#  'make_191.White%2FGMC.xlsx',
#  'make_192.Willys.xlsx',
#  'make_193.Winnebago.xlsx',
#  'make_194.Workhorse.xlsx',
#  'make_195.Workhorse Custom Chassis.xlsx',
#  'make_196.Yugo.xlsx',
#  'make_2.AM General.xlsx',
#  'make_20.Bering.xlsx',
#  'make_21.Bertone.xlsx',
#  'make_22.Blue Bird.xlsx',
#  'make_23.Bricklin.xlsx',
#  'make_24.Brockway.xlsx',
#  'make_25.Bugatti.xlsx',
#  'make_26.Buick.xlsx',
#  'make_27.Bus and Coach Intl (BCI).xlsx',
#  'make_28.Cadillac.xlsx',
#  'make_29.Capacity Of Texas.xlsx',
#  'make_3.AMERTEK.xlsx',
#  'make_30.Caterpillar.xlsx',
#  'make_31.Checker.xlsx',
#  'make_32.Chevrolet.xlsx',
#  'make_33.Chrysler.xlsx',
#  'make_34.Citroen.xlsx',
#  'make_35.Coachmen.xlsx',
#  'make_36.Country Coach.xlsx',
#  'make_37.Country Coach Motorhome.xlsx',
#  'make_38.Crane Carrier.xlsx',
#  'make_39.Crown Coach.xlsx',
#  'make_4.ATC.xlsx',
#  'make_40.DIAMOND.xlsx',
#  'make_41.Daewoo.xlsx',
#  'make_42.Daihatsu.xlsx',
#  'make_43.Damon.xlsx',
#  'make_44.DeLorean.xlsx',
#  'make_45.DeSoto.xlsx',
#  'make_46.Dennis Eagle.xlsx',
#  'make_47.Diamond Reo.xlsx',
#  'make_48.Diamond T.xlsx',
#  'make_49.Dina.xlsx',
#  'make_5.Acura.xlsx',
#  'make_50.Divco.xlsx',
#  'make_51.Dodge.xlsx',
#  'make_52.Dynamax Corp.xlsx',
#  'make_53.E-ONE.xlsx',
#  'make_54.Eagle.xlsx',
#  'make_55.Edsel.xlsx',
#  'make_56.El Dorado.xlsx',
#  'make_57.Emergency One.xlsx',
#  'make_58.Entegra Coach.xlsx',
#  'make_59.FWD.xlsx',
#  'make_6.Advance Mixer.xlsx',
#  'make_60.FWD Corporation.xlsx',
#  'make_61.Federal Motors.xlsx',
#  'make_62.Federal Truck.xlsx',
#  'make_63.Ferrari.xlsx',
#  'make_64.Fiat.xlsx',
#  'make_65.Fleetwood.xlsx',
#  'make_66.Ford.xlsx',
#  'make_67.Forest River.xlsx',
#  'make_68.Foretravel Motorhome.xlsx',
#  'make_69.Frazer.xlsx',
#  'make_7.Alexander Dennis.xlsx',
#  'make_70.Freightliner.xlsx',
#  'make_71.GMC.xlsx',
#  'make_72.GRUMMAN.xlsx',
#  'make_73.Genesis.xlsx',
#  'make_74.Geo.xlsx',
#  'make_75.Gillig.xlsx',
#  'make_76.Grande West.xlsx',
#  'make_77.Gulf Stream.xlsx',
#  'make_78.HME.xlsx',
#  'make_79.Hino.xlsx',
#  'make_8.Alfa Romeo.xlsx',
#  'make_80.Holiday Rambler.xlsx',
#  'make_81.Honda.xlsx',
#  'make_82.Hudson.xlsx',
#  'make_83.Hummer.xlsx',
#  'make_84.Hyundai.xlsx',
#  'make_85.IC.xlsx',
#  'make_86.IC Corporation.xlsx',
#  'make_87.Infiniti.xlsx',
#  'make_88.International.xlsx',
#  'make_89.Isuzu.xlsx',
#  'make_9.American Coach.xlsx',
#  'make_90.Itasca.xlsx',
#  'make_91.Jaguar.xlsx',
#  'make_92.Jayco.xlsx',
#  'make_93.Jeep.xlsx',
#  'make_94.KME.xlsx',
#  'make_95.Kaiser.xlsx',
#  'make_96.Kalmar.xlsx',
#  'make_97.Kenworth.xlsx',
#  'make_98.Kia.xlsx',
#  'make_99.Lada.xlsx']

# %%
file = list_file[1]

file
# Out:
# 'make_10.American LaFrance.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/4.model/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['Year'] = input_['Year'].astype(int)

print(f'总数量：{len(input_)}')
input_['Model'].tolist()
# Out:
# 总数量：31
# ['ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'ALF Eagle',
#  'Condor',
#  'Condor',
#  'Condor',
#  'Condor',
#  'Condor',
#  'Condor',
#  'Condor',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan',
#  'Metropolitan']

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests
import json

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

data = {'cssClass': 'form-control',
        'dropdownType': '3',
        'selectedValue': '',
        'vehicleAttributes': {'Make': f'''{input_.loc[a, 'Make']}''',
                              'MakeID': f'''{input_.loc[a, 'Make Code']}''',
                              'ModelID': f'''{input_.loc[a, 'Model Code']}''',
                              'SkinID': '1',
                              'Year': f'''{input_.loc[a, 'Year']}'''}}

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.post('https://www.dormanproducts.com/ApplicationGuideService.asmx/BuildDropdown',
                             data=json.dumps(data),
                             headers=get_header(**{'Content-Type': 'application/json; charset=UTF-8'}),
                             proxies=get_proxy(),
                             timeout=(10, 10))

        if resp.status_code == 200:
            break
    except KeyboardInterrupt:
        break
    except:
        continue

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'d': '<select id="parttypeDropdown" name="parttypeDropdown" onchange="showResults(this);" class="form-control">\n<option value="0"  disabled>{0}</option>\n<option value="12132"  >Accelerator Pedal Sensor</option>\n<option value="17937"  >Diesel Oxidation Catalyst (DOC)</option>\n<option value="17935"  >Diesel Particulate Filter (DPF)</option>\n<option value="51463"  >Diesel Particulate Filter (DPF) Clamp</option>\n<option value="50141"  >Diesel Particulate Filter (DPF) Gasket</option>\n<option value="55872"  >Diesel Particulate Filter (DPF) Hardware Kit</option>\n<option value="55361"  >Engine Oil Dipstick and Tube Kit</option>\n<option value="5816"  >Exhaust Clamp</option>\n<option value="20110"  >Exhaust Gas Recirculation (EGR) Cooler Gasket Kit</option>\n<option value="57149"  >Exhaust Gas Recirculation (EGR) Cooler Installation Kit</option>\n<option value="17051"  >Exhaust Gas Temperature (EGT) Sensor</option>\n<option value="5836"  >Exhaust Pipe Flange Gasket</option>\n<option value="13580"  >Fuel Injection Harness</option>\n<option value="13680"  >Fuel Injector O-Ring Kit</option>\n<option value="50010"  >Nitrogen Oxide (NOx) Sensor</option>\n</select>'}

# %%
from bs4 import BeautifulSoup
from lxml import etree

soup = BeautifulSoup(json_['d'], 'lxml')
html = etree.HTML(str(soup))

with open('./type.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <select class="form-control" id="parttypeDropdown" name="parttypeDropdown" onchange="showResults(this);">
#    <option disabled="" value="0">
#     {0}
#    </option>
#    <option value="12132">
#     Accelerator Pedal Sensor
#    </option>
#    <option value="17937">
#     Diesel Oxidation Catalyst (DOC)
#    </option>
#    <option value="17935">
#     Diesel Particulate Filter (DPF)
#    </option>
#    <option value="51463">
#     Diesel Particulate Filter (DPF) Clamp
#    </option>
#    <option value="50141">
#     Diesel Particulate Filter (DPF) Gasket
#    </option>
#    <option value="55872">
#     Diesel Particulate Filter (DPF) Hardware Kit
#    </option>
#    <option value="55361">
#     Engine Oil Dipstick and Tube Kit
#    </option>
#    <option value="5816">
#     Exhaust Clamp
#    </option>
#    <option value="20110">
#     Exhaust Gas Recirculation (EGR) Cooler Gasket Kit
#    </option>
#    <option value="57149">
#     Exhaust Gas Recirculation (EGR) Cooler Installation Kit
#    </option>
#    <option value="17051">
#     Exhaust Gas Temperature (EGT) Sensor
#    </option>
#    <option value="5836">
#     Exhaust Pipe Flange Gasket
#    </option>
#    <option value="13580">
#     Fuel Injection Harness
#    </option>
#    <option value="13680">
#     Fuel Injector O-Ring Kit
#    </option>
#    <option value="50010">
#     Nitrogen Oxide (NOx) Sensor
#    </option>
#   </select>
#  </body>
# </html>

# %%
list_type_code = html.xpath('//select[@id="parttypeDropdown"]/option/@value')[1:]

list_type_code
# Out:
# ['12132',
#  '17937',
#  '17935',
#  '51463',
#  '50141',
#  '55872',
#  '55361',
#  '5816',
#  '20110',
#  '57149',
#  '17051',
#  '5836',
#  '13580',
#  '13680',
#  '50010']

# %%
list_type = html.xpath('//select[@id="parttypeDropdown"]/option/text()')[1:]

list_type
# Out:
# ['Accelerator Pedal Sensor',
#  'Diesel Oxidation Catalyst (DOC)',
#  'Diesel Particulate Filter (DPF)',
#  'Diesel Particulate Filter (DPF) Clamp',
#  'Diesel Particulate Filter (DPF) Gasket',
#  'Diesel Particulate Filter (DPF) Hardware Kit',
#  'Engine Oil Dipstick and Tube Kit',
#  'Exhaust Clamp',
#  'Exhaust Gas Recirculation (EGR) Cooler Gasket Kit',
#  'Exhaust Gas Recirculation (EGR) Cooler Installation Kit',
#  'Exhaust Gas Temperature (EGT) Sensor',
#  'Exhaust Pipe Flange Gasket',
#  'Fuel Injection Harness',
#  'Fuel Injector O-Ring Kit',
#  'Nitrogen Oxide (NOx) Sensor']

# %%
len(list_type) == 0
# Out:
# False

# %%
df_temp = pd.DataFrame({'Make': input_.loc[a, 'Make'],
                        'Make Code': input_.loc[a, 'Make Code'],
                        'Model': input_.loc[a, 'Model'],
                        'Model Code': input_.loc[a, 'Model Code'],
                        'Year': input_.loc[a, 'Year'],
                        'Type': list_type,
                        'Type Code': list_type_code,
                        'Url': [f'https://www.dormanproducts.com/gsearch.aspx?type=keyword&q={type_}' for type_ in list_type]})

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#                  Make Make Code      Model Model Code  Year  \
# 0   American LaFrance      1269  ALF Eagle      24367  2012
# 1   American LaFrance      1269  ALF Eagle      24367  2012
# 2   American LaFrance      1269  ALF Eagle      24367  2012
# 3   American LaFrance      1269  ALF Eagle      24367  2012
# 4   American LaFrance      1269  ALF Eagle      24367  2012
# 5   American LaFrance      1269  ALF Eagle      24367  2012
# 6   American LaFrance      1269  ALF Eagle      24367  2012
# 7   American LaFrance      1269  ALF Eagle      24367  2012
# 8   American LaFrance      1269  ALF Eagle      24367  2012
# 9   American LaFrance      1269  ALF Eagle      24367  2012
# 10  American LaFrance      1269  ALF Eagle      24367  2012
# 11  American LaFrance      1269  ALF Eagle      24367  2012
# 12  American LaFrance      1269  ALF Eagle      24367  2012
# 13  American LaFrance      1269  ALF Eagle      24367  2012
# 14  American LaFrance      1269  ALF Eagle      24367  2012
#
#                                                  Type Type Code  \
# 0                            Accelerator Pedal Sensor     12132
# 1                     Diesel Oxidation Catalyst (DOC)     17937
# 2                     Diesel Particulate Filter (DPF)     17935
# 3               Diesel Particulate Filter (DPF) Clamp     51463
# 4              Diesel Particulate Filter (DPF) Gasket     50141
# 5        Diesel Particulate Filter (DPF) Hardware Kit     55872
# 6                    Engine Oil Dipstick and Tube Kit     55361
# 7                                       Exhaust Clamp      5816
# 8   Exhaust Gas Recirculation (EGR) Cooler Gasket Kit     20110
# 9   Exhaust Gas Recirculation (EGR) Cooler Install...     57149
# 10               Exhaust Gas Temperature (EGT) Sensor     17051
# 11                         Exhaust Pipe Flange Gasket      5836
# 12                             Fuel Injection Harness     13580
# 13                           Fuel Injector O-Ring Kit     13680
# 14                        Nitrogen Oxide (NOx) Sensor     50010
#
#                                              Type Url
# 0   https://www.dormanproducts.com/gsearch.aspx?ty...
# 1   https://www.dormanproducts.com/gsearch.aspx?ty...
# 2   https://www.dormanproducts.com/gsearch.aspx?ty...
# 3   https://www.dormanproducts.com/gsearch.aspx?ty...
# 4   https://www.dormanproducts.com/gsearch.aspx?ty...
# 5   https://www.dormanproducts.com/gsearch.aspx?ty...
# 6   https://www.dormanproducts.com/gsearch.aspx?ty...
# 7   https://www.dormanproducts.com/gsearch.aspx?ty...
# 8   https://www.dormanproducts.com/gsearch.aspx?ty...
# 9   https://www.dormanproducts.com/gsearch.aspx?ty...
# 10  https://www.dormanproducts.com/gsearch.aspx?ty...
# 11  https://www.dormanproducts.com/gsearch.aspx?ty...
# 12  https://www.dormanproducts.com/gsearch.aspx?ty...
# 13  https://www.dormanproducts.com/gsearch.aspx?ty...
# 14  https://www.dormanproducts.com/gsearch.aspx?ty...

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Make', 'Model', 'Year', 'Type'],
                                                ascending=[True, True, False, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_type.xlsx', index=False)

output_correct
# Out:
#                  Make Make Code      Model Model Code  Year  \
# 0   American LaFrance      1269  ALF Eagle      24367  2012
# 1   American LaFrance      1269  ALF Eagle      24367  2012
# 2   American LaFrance      1269  ALF Eagle      24367  2012
# 3   American LaFrance      1269  ALF Eagle      24367  2012
# 4   American LaFrance      1269  ALF Eagle      24367  2012
# 5   American LaFrance      1269  ALF Eagle      24367  2012
# 6   American LaFrance      1269  ALF Eagle      24367  2012
# 7   American LaFrance      1269  ALF Eagle      24367  2012
# 8   American LaFrance      1269  ALF Eagle      24367  2012
# 9   American LaFrance      1269  ALF Eagle      24367  2012
# 10  American LaFrance      1269  ALF Eagle      24367  2012
# 11  American LaFrance      1269  ALF Eagle      24367  2012
# 12  American LaFrance      1269  ALF Eagle      24367  2012
# 13  American LaFrance      1269  ALF Eagle      24367  2012
# 14  American LaFrance      1269  ALF Eagle      24367  2012
#
#                                                  Type Type Code  \
# 0                            Accelerator Pedal Sensor     12132
# 1                     Diesel Oxidation Catalyst (DOC)     17937
# 2                     Diesel Particulate Filter (DPF)     17935
# 3               Diesel Particulate Filter (DPF) Clamp     51463
# 4              Diesel Particulate Filter (DPF) Gasket     50141
# 5        Diesel Particulate Filter (DPF) Hardware Kit     55872
# 6                    Engine Oil Dipstick and Tube Kit     55361
# 7                                       Exhaust Clamp      5816
# 8   Exhaust Gas Recirculation (EGR) Cooler Gasket Kit     20110
# 9   Exhaust Gas Recirculation (EGR) Cooler Install...     57149
# 10               Exhaust Gas Temperature (EGT) Sensor     17051
# 11                         Exhaust Pipe Flange Gasket      5836
# 12                             Fuel Injection Harness     13580
# 13                           Fuel Injector O-Ring Kit     13680
# 14                        Nitrogen Oxide (NOx) Sensor     50010
#
#                                              Type Url
# 0   https://www.dormanproducts.com/gsearch.aspx?ty...
# 1   https://www.dormanproducts.com/gsearch.aspx?ty...
# 2   https://www.dormanproducts.com/gsearch.aspx?ty...
# 3   https://www.dormanproducts.com/gsearch.aspx?ty...
# 4   https://www.dormanproducts.com/gsearch.aspx?ty...
# 5   https://www.dormanproducts.com/gsearch.aspx?ty...
# 6   https://www.dormanproducts.com/gsearch.aspx?ty...
# 7   https://www.dormanproducts.com/gsearch.aspx?ty...
# 8   https://www.dormanproducts.com/gsearch.aspx?ty...
# 9   https://www.dormanproducts.com/gsearch.aspx?ty...
# 10  https://www.dormanproducts.com/gsearch.aspx?ty...
# 11  https://www.dormanproducts.com/gsearch.aspx?ty...
# 12  https://www.dormanproducts.com/gsearch.aspx?ty...
# 13  https://www.dormanproducts.com/gsearch.aspx?ty...
# 14  https://www.dormanproducts.com/gsearch.aspx?ty...

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Make', 'Model', 'Year'],
                                            ascending=[True, True, False],
                                            ignore_index=True)
    output_error.to_excel('./test_type_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
