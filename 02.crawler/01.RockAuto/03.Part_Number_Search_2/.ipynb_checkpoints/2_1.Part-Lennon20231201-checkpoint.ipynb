# %%
manufacturer = 'MELLING'
type_code = '5756'

# %%
import pandas as pd

# %%
df = pd.read_excel('./menu.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_url = df['Url'].tolist()
list_part_number = df['Part_Number'].tolist()

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：448
# ['https://www.rockauto.com/en/parts/melling,715F,timing+chain,5724',
#  'https://www.rockauto.com/en/parts/melling,30250S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30250SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30420S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30430S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30460S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30460SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30460SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30470S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30470SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30490S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30490SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30719S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,30719SHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31007S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31035S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31035SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31036S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31036SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31038S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31038SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31041S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31045S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31045SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047SH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047SHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047SXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31047SXHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SAH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SBH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SBXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SCH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SCX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SCXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SDH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SDX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SDXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SEH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SFH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SG,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SGX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SJ,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SK,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SL,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SM,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31049SN,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31051S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31051SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31051SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31051SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31054S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31055S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31055SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31056S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31056SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31058S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31058SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31060S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31060SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31062S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31062SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31064S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31065S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31065SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31067S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31067SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31069SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31073S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31075SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31076S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31076SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31076SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31076SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31078S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31090S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31090SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,31093S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3160S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3163S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3163SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3163SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3168S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3168SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3168SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3168SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3168SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3169S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3169SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3171S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3181S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3181SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3182S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3191S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3192SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3195SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3202S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3202SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33235S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3344S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3349S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3350S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3351S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3356S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3358S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3358SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3359S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3359SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3359SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3361S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3365SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3370S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3370SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3372S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3373S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3374S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3374SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3375SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3376S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3376SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3376SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3378SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3380S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3380SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3381A,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3381AS,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3381ASB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3383SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3384S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3385S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3385SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3385SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3385SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SAXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SG,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SGF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SGWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SGX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SHF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SIF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SIFWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SJF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SKF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SKFC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SKFCH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SKFH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SLF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SM,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SMH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SMK3,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SMVVT,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SMVVT1,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3387SMVVTH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3388S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3388SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3390S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3390SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCK3,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCK3A,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCVVT,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCVVT1,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCVVTH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCCWP1,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCK3,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCK3A,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCVVT,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SCVVTH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SFH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SG,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3391SXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3392S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SAH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SBH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SCH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SFH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SFX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SFXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3393SXH,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3395S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3395SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3396S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3397S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3397SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3397SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3397SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3397SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3398LHA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3398RHA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3398S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3398SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33DR130,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33DRH48,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SR60,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SR60AS,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SR64,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SR64S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SR92,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH106,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60HVVT1,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SDHVVT,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SF,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH60SG,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH64,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH64A,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH64AS,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,33SRH64S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34167S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34198S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34198SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34200SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SAHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34201SXHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34202SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34202SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34202SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34207S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34207SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34207SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34207SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34210SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34212S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34212SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34212SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34212SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34212SCX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34214SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34221S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34221SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3489S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3491S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3491SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3494S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3494SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3494SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3494SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3494SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3495S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3495SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3498S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3498SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3498SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3498SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3499S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3499SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR48,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR50,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR50SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR50SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR50SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,34SR50SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3501S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3501SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3503S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3505S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3506S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3506SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3506SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3506SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3507S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3509S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3509SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3509SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700SC,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700SD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3700SE,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3704S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3704SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SCX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SDX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SFX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3705SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3707SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3707SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3708S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3708SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3711SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3711SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3711SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3715S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3715SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3715SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3715SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3715SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3720S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3720SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3720SAHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3720SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3720SAXHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3724S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727SBX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3727SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SA1HWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SAHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SAX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SAX1HWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SAXHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3730SXHWP,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3750S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3750SHVVT,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3750SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3752S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3752SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3753S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3753SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSR130SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSRH62S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSRH62SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSRH72S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSRH72SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,38MMSRH72SB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3900CS,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3900CSA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3900CSB,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3900CSX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3916S,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3916SA,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3916SX,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3DR106D1,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3DR1103,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3DR601,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3DR961,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3DR981,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR1021,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR921,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR941,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR961,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR961HD,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,3SR981,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40201,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40202,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40203,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40204,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40205,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40206,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40217,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40400,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40401,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40402,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40403,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40404,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40405,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40406,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40407,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40408,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40409,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40410,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40500,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40510,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40520,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,40540,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48500T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48510T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48520T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48530T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48551T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48560T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48561T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,485626,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48562T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,485636,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48563T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48564T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48565T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48566T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48567T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,485683,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,485699,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48570T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,48571T9,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1000,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1000HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1001,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1001HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1002,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1002HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1003,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1003HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1004,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1004HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1005,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1006,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1006HV,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1007,timing+chain+&+component+kit,5756',
#  'https://www.rockauto.com/en/parts/melling,TOPK1008,timing+chain+&+component+kit,5756']

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests

# %%
import sys
sys.path.append('../../../00.module')
import UA
import Proxy

i = 0

url = list_url[i]
part_number = list_part_number[i]

resp = requests.get(url,
                   proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '<!DOCTYPE HTML>\n<html class="no-js " lang="en">\n<head>\n<meta http-equiv="content-type" content="text/html; charset=windows-1252">\n<meta name="description" content="RockAuto ships auto parts and body parts from over 300 manufacturers to customers\' doors worldwide, all at warehouse prices. Easy to use parts catalog.">\n<meta name="keywords" content=" Timing Chain,,,, Timing Chain, MELLING,">\n<meta name="Classification" content="automotive">\n<meta name="abstract" content="Online Store for brand name auto parts at warehouse-direct prices...">\n<meta name="robots" content="all">\n<meta http-equiv="Content-Security-Policy" content="script-src \'self\' \'unsafe-inline\' \'unsafe-eval\' *.rockauto.com; base-uri \'self\' *.rockauto.com; ">\n\n<link rel="canonical" href="https://www.rockauto.com/en/parts/melling,715F,timing+chain,5724" />\n<link rel="alternate" href="https://www.rockauto.com/en/parts/melling,715F,timing+chain,5724" hreflang="en" />\n<link rel="alternate" href="https://www.rockauto.com/es/parts/melling,715F,timing+chain,5724" hreflang="es" />\n<link rel="alternate" href="https://www.rockauto.com/de/parts/melling,715F,timing+chain,5724" hreflang="de" />\n<link rel="alternate" href="https://www.rockauto.com/fr/parts/melling,715F,timing+chain,5724" hreflang="fr" />\n<title>MELLING 715F Timing Chain | RockAuto</title>\n<link rel="stylesheet" type="text/css" href="/jslib/sprites/desktopsprites-min.css?1701415457">\n\n<script>\nif(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};\n_getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=\n0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};\n\n</script>\n\n<script>var __mob = false, __mobnew = false;</script>\n\n<script src="/jslib/combined/js/desktopcatalogmain.js?1701415457" defer></script>\n<script>var CURRENTLANGUAGE = "en";</script>\n\n<link rel="stylesheet" type="text/css" href="/jslib/combined/css/desktopcatalogmain.css?1701415457">\n\n</head>\n<body >\n<div id="temp_everything">\n<div id="temp_notfooter">\n<header>\n<div class="rapurp" id="temp_banner">\n<table class="fullwidth noborder">\n<tr>\n<td class="taleft" style="width: 25%;">\n<div style="padding-left: 2em;">\n<a href="/" onclick="AddSerializedCookieDataToHref(this);"><img class="nobmp topbanner" src="/Images/logoDesktop.png" alt="rockauto.com"></a>\n</div>\n</td>\n<td class=" tacenter top" style="width: 50%;">\n<div id="top_slog_alt">MELLING 715F Timing Chain</div><div id="top_slog" class="ra-hide"><h1 class="h1reset">ALL THE PARTS YOUR CAR WILL EVER NEED</h1></div>\n</td>\n<td class="taright" style="width: 25%;">\n<div style="padding-right: 2em;"><a href="/lang/en/promo ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

with open('./part.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="no-js" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="RockAuto ships auto parts and body parts from over 300 manufacturers to customers' doors worldwide, all at warehouse prices. Easy to use parts catalog." name="description"/>
#   <meta content=" Timing Chain,,,, Timing Chain, MELLING," name="keywords"/>
#   <meta content="automotive" name="Classification"/>
#   <meta content="Online Store for brand name auto parts at warehouse-direct prices..." name="abstract"/>
#   <meta content="all" name="robots"/>
#   <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' *.rockauto.com; base-uri 'self' *.rockauto.com; " http-equiv="Content-Security-Policy"/>
#   <link href="https://www.rockauto.com/en/parts/melling,715F,timing+chain,5724" rel="canonical"/>
#   <link href="https://www.rockauto.com/en/parts/melling,715F,timing+chain,5724" hreflang="en" rel="alternate"/>
#   <link href="https://www.rockauto.com/es/parts/melling,715F,timing+chain,5724" hreflang="es" rel="alternate"/>
#   <link href="https://www.rockauto.com/de/parts/melling,715F,timing+chain,5724" hreflang="de" rel="alternate"/>
#   <link href="https://www.rockauto.com/fr/parts/melling,715F,timing+chain,5724" hreflang="fr" rel="alternate"/>
#   <title>
#    MELLING 715F Timing Chain | RockAuto
#   </title>
#   <link href="/jslib/sprites/desktopsprites-min.css?1701415457" rel="stylesheet" type="text/css"/>
#   <script>
#    if(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};
# _getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=
# 0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};
#   </script>
#   <script>
#    var __mob = false, __mobnew = false;
#   </script>
#   <script defer="" src="/jslib/combined/js/desktopcatalogmain.js?1701415457">
#   </script>
#   <script>
#    var CURRENTLANGUAGE = "en";
#   </script>
#   <link href="/jslib/combined/css/desktopcatalogmain.css?1701415457" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="temp_everything">
#    <div id="temp_notfooter">
#     <header>
#      <div class="rapurp" id="temp_banner">
#       <table class="fullwidth noborder">
#        <tr>
#         <td class="taleft" style="width: 25%;">
#          <div style="padding-left: 2em;">
#           <a href="/" onclick="AddSerializedCookieDataToHref(this);">
#            <img alt="rockauto.com" class="nobmp topbanner" src="/Images/logoDesktop.png"/>
#           </a>
#          </div>
#         </td>
#         <td class="tacenter top" style="width: 50%;">
#          <div id="top_slog_alt">
#           MELLING 715F Timing Chain
#          </div>
#          <div class="ra-hide" id="top_slog">
#           <h1 class="h1reset">
#            ALL THE PARTS YOUR CAR WILL EVER NEED
#           </h1>
#          </div>
#         </td>
#         <td class="taright" style="width: 25%;">
#          <div style="padding-right: 2em;">
#           <a href="/lang/en/promo.html" target="_blank">
#            <img alt="Promotions &amp; Manufacturer Rebates" border="0" class="topbanner" src="/Images/en/CurPromo.png"/>
#           </a>
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#      <div class="rayellow sandwich" id="temp_top_yellow" style="line-height: 1; ">
#       <table cellpadding="0" cellspacing="0" class="fullwidth nobmp">
#        <tr>
#         <td class="taleft" style="width: 45%; padding-left: 1em;">
#          <table cellpadding="0" cellspacing="0" style="padding: 0px; margin: 0px;">
#           <tr>
#            <td>
#             <div class="ib" style="font-size: 11px;">
#              <span class="ib">
#               <form action="" method="POST">
#                <input name="_nck" type="hidden" value="ZExt1ysfqhqWnq+EvUNdS3Txyey60IDtnjPWF5UU9J0BWQv7pvqZbh+YrdIIoJ2QMq9prrkIerbFMqky5nGcn4teOg9r2Sw3+Pr1CNOXFqQFzxO1xi2naIVVDqptp38yXkE5m0eM5QCA+y15xTcreiyKbrkDUxw8W4ahXJsSn7oYohtQNmW9Zz5xWB4BFneYzv3HwvKpDsMAg8G2DZydTuI8xq8te6L4Dyh4019H8QM="/>
#                <span class="ib vmiddle">
#                 <label for="displaycurrency">
#                  Show Prices In
#                 </label>
#                </span>
#                <span class="ib vmiddle" style="padding: 0px;">
#                 <select id="displaycurrency" name="newcurrency" onchange="updateCurrencyDisplay(this)" style="font-size: 11px;">
#                  <option value="USD">
#                   US Dollars ($)
#                  </option>
#                  <option value="AUD">
#                   Australian Dollars (AU$)
#                  </option>
#                  <option value="BRL">
#                   Brazilian Real (R$)
#                  </option>
#                  <option value="GBP">
#                   British Pounds (£)
#                  </option>
#                  <option value="CAD">
#                   Canadian Dollars (CAD$)
#                  </option>
#                  <option value="CLP">
#                   Chilean Pesos (CL$)
#                  </option>
#                  <option value="EUR">
#                   Euros ()
#                  </option>
#                  <option value="HUF">
#                   Hungarian Forint (Ft)
#                  </option>
#                  <option value="JPY">
#                   Japanese Yen (¥)
#                  </option>
#                  <option value="MXN">
#                   Mexican Pesos (Mex$)
#                  </option>
#                  <option value="NZD">
#                   New Zealand Dollars (NZ$)
#                  </option>
#                  <option value="NOK">
#                   Norwegian Krone (NOK)
#                  </option>
#                  <option value="PLN">
#                   Polish Zloty (zł)
#                  </option>
#                  <option value="SEK">
#                   Swedish Krona (SEK)
#                  </option>
#                  <option value="CHF">
#                   Swiss Francs (CHF)
#                  </option>
#                 </select>
#                </span>
#                <span class="hide-if-js" style="padding-left: .5em;">
#                 <input class="ra-btn ra-btn-color-darkblue ra-btn-size-normal" name="setcurrency" type="submit" value="Apply"/>
#                </span>
#               </form>
#              </span>
#              <span class="ib vmiddle" style="padding-left: .5em;">
#               <span class="ib" style="padding-left: .25em;">
#                <a class="mo-link" href="/en/parts/melling,715F,timing+chain,5724?language=en" onclick="this.href += GetSerializedCookieData('url', '&amp;');" onmouseover="if (RA.catalog_dynamic_location_href == null) { return; } this.href = RA.catalog_dynamic_location_href + (RA.catalog_dynamic_location_href.indexOf('?') != -1 ? '&amp;' : '?') + 'language=en';" style=" color: black;">
#                 English
#                </a>
#               </span>
#               <span class="ib" style="padding-left: .25em;">
#               </span>
#               <span class="ib" style="padding-left: .25em; border-left: 1px solid #AAAAAA;">
#                <a class="mo-link" href="/en/parts/melling,715F,timing+chain,5724?language=es" onclick="this.href += GetSerializedCookieData('url', '&amp;');" onmouseover="if (RA.catalog_dynamic_location_href == null) { return; } this.href = RA.catalog_dynamic_location_href + (RA.catalog_dynamic_location_href.indexOf('?') != -1 ? '&amp;' : '?') + 'language=es';" style="">
#                 Español
#                </a>
#               </span>
#               <span class="ib" style="padding-left: .25em;">
#               </span>
#               <span class="ib" style="padding-left: .25em; border-left: 1px solid #AAAAAA;">
#                <a class="mo-link" href="/en/parts/melling,715F,timing+chain,5724?language=de" onclick="this.href += GetSerializedCookieData('url', '&amp;');" onmouseover="if (RA.catalog_dynamic_location_href == null) { return; } this.href = RA.catalog_dynamic_location_href + (RA.catalog_dynamic_location_href.indexOf('?') != -1 ? '&amp;' : '?') + 'language=de';" style="">
#                 Deutsch
#                </a>
#               </span>
#               <span class="ib" style="padding-left: .25em;">
#               </span>
#               <span class="ib" style="padding-left: .25em; border-left: 1px solid #AAAAAA;">
#                <a class="mo-link" href="/en/parts/melling,715F,timing+chain,5724?language=fr" onclick="this.href += GetSerializedCookieData('url', '&amp;');" onmouseover="if (RA.catalog_dynamic_location_href == null) { return; } this.href = RA.catalog_dynamic_location_href + (RA.catalog_dynamic_location_href.indexOf('?') != -1 ? '&amp;' : '?') + 'language=fr';" style="">
#                 Français
#                </a>
#               </span>
#               <span class="ib" style="padding-left: .25em;">
#               </span>
#              </span>
#             </div>
#            </td>
#           </tr>
#          </table>
#         </td>
#         <td class="tacenter" style="width: 10%; white-space: nowrap;">
#          <div class="ib">
#           <a class="bluelink" href="/help/" target="_blank">
#           </a>
#           <table cellpadding="0" cellspacing="0" class="graybubble mouseover" onclick="window.open('/help/', '_blank'); return false;" style="height: 26px; font-size: 11px; border-collapse: separate;">
#            <tr>
#             <td class="vmiddle bluelink">
#              Help
#             </td>
#             <td class="vmiddle" style="padding-left: .5em;">
#              <img alt="" class="help_q_icon_18" src="/Images/questionMark.png" style="display: block;"/>
#             </td>
#            </tr>
#           </table>
#          </div>
#         </td>
#         <td class="taright" style="width: 45%;">
#          <table cellpadding="0" cellspacing="0" class="nobmp talignright">
#           <tr>
#            <td style="padding-left: 5px;">
#             <a class="bluelink" href="/orderstatus" target="_blank">
#             </a>
#             <table cellpadding="0" cellspacing="0" class="graybubble mouseover" onclick="window.open('/orderstatus', '_blank'); return false;" style="height: 26px; font-size: 11px;">
#              <tr>
#               <td class="vmiddle bluelink">
#                Order Status &amp; Returns
#               </td>
#               <td class="vmiddle" style="padding-left: .5em;">
#                <i class="sprite navigation boxClrBG" style="height:18px;">
#                </i>
#               </td>
#              </tr>
#             </table>
#            </td>
#            <td style="padding-left: 5px; padding-right: 5px;">
#             <div id="loginlinksection" style="display: inline-block;">
#              <table cellpadding="0" cellspacing="0" class="graybubble mouseover" onclick="showLogin();" style="height: 26px; font-size: .9em;">
#               <tr>
#                <td class="vmiddle">
#                 <a class="bluelink mouseover" href="#" id="loginlink" onclick="showLogin(); return false;">
#                  Log In or Create Account (Optional)
#                 </a>
#                </td>
#                <td class="vmiddle" style="padding-left: .5em;">
#                 <div class="bluelink mouseover">
#                  <i class="sprite navigation acnt">
#                  </i>
#                 </div>
#                </td>
#               </tr>
#              </table>
#              <div class="ra-widget-panel ra-hide" id="ra_widget_panel[accountlogin_panel]" style=" right: 2em;">
#               <div class="ra-widget-panel-c" id="ra_widget_panel_c[accountlogin_panel]" style=" width: 400px;">
#                <div class="ra-widget-panel-t" id="ra_widget_panel_t[accountlogin_panel]">
#                 <span class="ra-widget-panel-closex">
#                  <img alt="Close" onclick="RA.Widget.Panel.Close('accountlogin_panel')" src="/catalog/images/close12_1.gif" style="display: block; border: none;"/>
#                 </span>
#                 <div>
#                  <div>
#                   <div class="lpdm-login">
#                    Log Into My Account
#                   </div>
#                   <div class="lpdm-createaccount">
#                    Create Account
#                   </div>
#                   <div class="lpdm-forgotpassword lpdm-confirmforgot">
#                    Forgot Password
#                   </div>
#                   <div class="lpdm-createpassword">
#                    Create Password
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div id="loginpanel">
#                 <div style="padding: 0.25em;">
#                  <table cellpadding="2" cellspacing="0" style="width: 100%;">
#                   <tr>
#                    <td colspan="3">
#                     <table cellpadding="0" cellspacing="0" style="width: 100%;">
#                      <tr>
#                       <td style="vertical-align: top;">
#                        <div class="lpdm-createaccount lpdm-forgotpassword lpdm-createpassword lpdm-confirmforgot">
#                         <i class="mouseover sprite navigation leftarrowbluecircled" onclick="showLogin(LoginPanelDisplayMode.Login);" title="Back to log in">
#                         </i>
#                        </div>
#                       </td>
#                       <td style="padding-left: 5px;">
#                        <div class="lpdm-createaccount">
#                         <div class="account-login-small">
#                          Please enter your email address and the security code exactly as shown in the image, then press "Submit" to create an account.
#                         </div>
#                        </div>
#                        <div class="lpdm-forgotpassword">
#                         <div class="account-login-small">
#                          Please enter your email address and press "Submit" to reset your password.
#                         </div>
#                        </div>
#                        <div class="lpdm-createpassword">
#                         <div class="tacenter">
#                          Please create a password for your account.
#                         </div>
#                        </div>
#                        <div class="lpdm-confirmforgot">
#                         <div class="tacenter">
#                          Please set a password for your account.
#                         </div>
#                        </div>
#                       </td>
#                      </tr>
#                     </table>
#                    </td>
#                   </tr>
#                   <tr class="ra-hide" id="loginwarningrow">
#                    <td colspan="3" style="font-size: .9em;">
#                     <div style="padding: 3px; background: #FFCDCD; border: 1px solid #D52525;">
#                      If you do not remember your password, please use the 'Forgot Password' link below.
#                      <div>
#                      </div>
#                     </div>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td style="text-align: right; width: 33%;">
#                     <label for="accountemail">
#                      Email Address
#                     </label>
#                    </td>
#                    <td>
#                     <form action="" id="form_login_email" method="post" onsubmit="loginSubmit(); return false;">
#                      <input id="accountemail" name="email" onkeypress="return RA.InterceptEnter(event, function(){RA.Click('btnLoginSubmitDummy');});" style="width: 12em" type="email" value=""/>
#                      <input id="btnLoginSubmitDummy" style="display: none;" type="submit" value="Submit"/>
#                     </form>
#                    </td>
#                    <td class="pinched" style="text-align: right; padding-right: 5px;">
#                     <div class="lpdm-login lpdm-createpassword lpdm-confirmforgot">
#                      <a class="mo-link" href="/help/?page=5" tabindex="-1" target="_blank">
#                       Help
#                      </a>
#                      &amp;nbsp
#                      <a class="mo-link" href="/help/?page=5" style="vertical-align: middle;" tabindex="-1" target="_blank">
#                       <img alt="Help" src="/Images/questionMark.png" style="height: 15px;"/>
#                      </a>
#                     </div>
#                     <div class="lpdm-forgotpassword">
#                      <input class="ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('btnLoginSubmitDummy');" title="Submit" type="button" value="Submit"/>
#                     </div>
#                    </td>
#                   </tr>
#                   <tr class="accountcaptcharow lpdm-createaccount">
#                    <td>
#                    </td>
#                    <td colspan="2" style="padding-top: .5em;">
#                     <table class="tblz taleft captchawrapper">
#                      <tr>
#                       <td>
#                        <img alt="Security Code" class="captchaimage" src="/catalog/images/captchaFiller.png"/>
#                       </td>
#                       <td style="padding-left:.2em;">
#                        <a class="minilink captchaaudio" href="/captcha/securimage/securimage_play.php?1266209171" style="white-space: nowrap;">
#                         Audio
#                        </a>
#                        <br/>
#                        <a class="minilink" href="#" onclick='RA.RefreshCAPTCHA($(this).closest(".captchawrapper"));' style="white-space: nowrap;">
#                         New Code
#                        </a>
#                       </td>
#                      </tr>
#                     </table>
#                    </td>
#                   </tr>
#                   <tr class="accountcaptcharow lpdm-createaccount">
#                    <td style="text-align: right; white-space: nowrap;">
#                     Security Code
#                    </td>
#                    <td>
#                     <form autocomplete="off" method="post">
#                      <input aria-label="Security Code" class="captchatextinput" name="captchacode" size="8" type="text"/>
#                      <input disabled="" style="display: none;" type="submit" value="Submit"/>
#                     </form>
#                    </td>
#                    <td>
#                    </td>
#                   </tr>
#                   <tr class="lpdm-login lpdm-createpassword lpdm-confirmforgot">
#                    <td style="text-align: right; white-space: nowrap;">
#                     <div class="lpdm-login">
#                      <label for="password">
#                       Password
#                      </label>
#                     </div>
#                     <div class="lpdm-createpassword lpdm-confirmforgot">
#                      New Password
#                     </div>
#                    </td>
#                    <td>
#                     <form autocomplete="off" method="post">
#                      <label for="passworddecoy" style="display: none;">
#                       Password
#                      </label>
#                      <input id="passworddecoy" style="display: none;" type="password"/>
#                      <input autocomplete="off" id="password" name="password" onkeypress="return RA.InterceptEnter(event, function(){RA.Click('btnLoginSubmitDummy');});" style="width: 12em" type="password"/>
#                      <input disabled="" style="display: none;" type="submit" value="Submit"/>
#                     </form>
#                    </td>
#                    <td>
#                     <div class="lpdm-login">
#                      <input class="ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('btnLoginSubmitDummy');" style="vertical-align: top;" title="Log In" type="button" value="Log In"/>
#                     </div>
#                    </td>
#                   </tr>
#                   <tr class="lpdm-createpassword lpdm-confirmforgot">
#                    <td style="text-align: right; white-space: nowrap;">
#                     <label for="passwordconfirm">
#                      Confirm New Password
#                     </label>
#                    </td>
#                    <td>
#                     <form autocomplete="off" method="post">
#                      <label for="passwordconfirmdecoy" style="display:none;">
#                       Confirm New Password
#                      </label>
#                      <input id="passwordconfirmdecoy" style="display: none;" type="password"/>
#                      <input autocomplete="off" id="passwordconfirm" name="passwordconfirm" onkeypress="return RA.InterceptEnter(event, function(){RA.Click('btnLoginSubmitDummy');});" style="width: 12em" type="password"/>
#                      <input disabled="" style="display: none;" type="submit" value="Submit"/>
#                     </form>
#                    </td>
#                    <td>
#                     <div>
#                      <input class="ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('btnLoginSubmitDummy');" style="vertical-align: top;" title="Log In" type="button" value="Log In"/>
#                     </div>
#                    </td>
#                   </tr>
#                   <tr class="lpdm-createaccount">
#                    <td>
#                    </td>
#                    <td style="text-align: right; white-space: nowrap;">
#                    </td>
#                    <td>
#                     <input class="ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('btnLoginSubmitDummy');" title="Submit" type="button" value="Submit"/>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td colspan="3" style="font-size: 2px;">
#                     <div id="loginmessagewrapper">
#                      <div>
#                      </div>
#                     </div>
#                    </td>
#                   </tr>
#                   <tr class="lpdm-login">
#                    <td colspan="2" id="createaccountforgotpassword" style="text-align: left">
#                     <span class="account-login-small mo-link" id="gotocreateaccount" onclick="showLogin(LoginPanelDisplayMode.CreateAccount); javascript:account_new_captcha()">
#                      Create Account
#                     </span>
#                     <span class="account-login-small mo-link" id="gotoforgotpassword" onclick="showLogin(LoginPanelDisplayMode.ForgotPassword);">
#                      Forgot Password
#                     </span>
#                    </td>
#                    <td style="white-space: nowrap;">
#                     <input id="keepsignin" name="keepsignin" style="margin: 0px; padding: 0px; vertical-align: middle;" type="checkbox"/>
#                     <label class="account-login-small" for="keepsignin">
#                      Keep Me Logged In
#                     </label>
#                    </td>
#                   </tr>
#                   <tr class="lpdm-login">
#                    <td colspan="3">
#                     <div id="loginpanelnotesdiv">
#                      <span class="account-login-smaller">
#                       If you do not have an account but would like to check the status of an order, request a change, or report a problem with an order or shipment, please go to our
#                       <a class="mo-link" href="/orderstatus/" target="_blank">
#                        Order Status &amp; Returns
#                       </a>
#                       page.
#                      </span>
#                      <br/>
#                     </div>
#                    </td>
#                   </tr>
#                  </table>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </header>
#     <footer id="temp_bottom_wrapper" style="position:fixed; width: 100%; bottom: 0px; z-index: 2;">
#      <div class="rayellow" id="temp_bottom_yellow" style="padding-top: 5px; ">
#      </div>
#      <div class="rapurp tacenter" id="temp_bottom">
#       <div style="overflow: hidden;">
#        <table cellpadding="0" cellspacing="0" style="width: 100%; height: 45px;">
#         <tr>
#          <td style="vertical-align: top;">
#           <table cellpadding="0" cellspacing="0" class="nobmp" style="width: 100%; vertical-align: top;">
#            <tr>
#             <td class="tacenter" style="padding-top: 1px;">
#              <table cellpadding="0" cellspacing="0" class="nobmp" style="width: 100%; padding-top: 3px; margin-left: auto; margin-right: auto;">
#               <tr>
#                <td style="width: 5%">
#                </td>
#                <td style=" text-align: left;">
#                 <nav aria-label="Footer navigation" class="ib whitebubble" style="padding: 0px;">
#                  <table cellpadding="0" cellspacing="0" class="nobmp bottomlinktable bottomlinktabletd">
#                   <tr>
#                    <td class="bottomlinktabletdfirst mouseover" onclick="window.open('/en/tools/?parttype=260', '_blank'); return false;">
#                     <a class="bluelink" href="/en/tools/?parttype=260" target="_blank">
#                      Gift Certificates
#                     </a>
#                    </td>
#                    <td class="mouseover" onclick="window.open('/help/?page=6', '_blank'); return false;">
#                     <a class="bluelink" href="/help/?page=6" target="_blank">
#                      About Us
#                     </a>
#                    </td>
#                    <td class="mouseover" onclick="window.open('/Newsletter/', '_blank'); return false;">
#                     <a class="bluelink" href="/Newsletter/" target="_blank">
#                      Newsletter
#                     </a>
#                    </td>
#                    <td class="mouseover" onclick="cataloglite.ShowNewsletterSubscribe([this, 'bl', 'bl']);" onmouseover="cataloglite.LoadNewsletterSubscribe([this, 'bl', 'bl']);">
#                     <span class="bluelink">
#                      Join Our Email List
#                     </span>
#                    </td>
#                    <td class="mouseover" onclick="window.open('/docs/warranty', '_blank'); return false;">
#                     <a class="bluelink" href="/docs/warranty" target="_blank">
#                      Warranties
#                     </a>
#                    </td>
#                    <td class="mouseover" onclick="window.open('/careers/', '_blank'); return false;">
#                     <a class="bluelink" href="/careers/" target="_blank">
#                      Careers
#                     </a>
#                    </td>
#                   </tr>
#                  </table>
#                 </nav>
#                </td>
#                <td style="text-align: right; padding-right: 50px;">
#                 <div class="ib" style="padding: 1px;">
#                  <table cellpadding="0" cellspacing="0" class="nobmp bottomlinktable bottomlinktabletd">
#                   <tr>
#                    <td class="bottomlinktabletdfirst">
#                     <a class="whitelink" href="/?mof=m" onclick="AddSerializedCookieDataToHref(this);">
#                      Mobile Site
#                     </a>
#                    </td>
#                   </tr>
#                  </table>
#                 </div>
#                </td>
#               </tr>
#              </table>
#             </td>
#            </tr>
#            <tr>
#             <td class="taleft">
#              <div class="copyright taleft ib" id="copyrightdiv" style="padding-left: 10px; padding-top: 8px;">
#               © 1999-2023 RockAuto, LLC - Madison, Wisconsin USA. RockAuto name, logo and
#               <em>
#                ALL THE PARTS YOUR CAR WILL EVER NEED
#               </em>
#               are registered trademarks of RockAuto, LLC. Manufacturer and carrier names and logos in the RockAuto catalog are trademarks of their respective companies and are used only to identify their products. All rights reserved.
#              </div>
#             </td>
#            </tr>
#           </table>
#          </td>
#         </tr>
#        </table>
#       </div>
#      </div>
#     </footer>
#     <div id="temp_main">
#      <div id="section-tabs">
#       <input autocomplete="off" id="jstabkeys" type="hidden" value='["catalog","partsearch","extras","cart","spacer","accountactivity","profile","cart2"]'/>
#       <div id="section-tabs-header">
#        <table cellpadding="0" cellspacing="0" style="width: 100%;">
#         <tr>
#          <td>
#           <nav aria-label="Main navigation" id="section-tab-row" style="padding-top: .2em;">
#            <span class="ra-tab-header-base ra-tab-header-inactive" id="tabheader[catalog]" style="">
#             <a href="/en/catalog/" onclick='cataloglite.LinkIntercept_TabClick("catalog"); return false;'>
#              <span class="outer" id="tabouter[catalog]">
#               <span class="inner" id="tablabel[catalog]">
#                Part
#                <span class="narrow-screen-tab-text">
#                 Catalog
#                </span>
#               </span>
#              </span>
#             </a>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-active" id="tabheader[partsearch]" style="">
#             <a href="/en/partsearch/" onclick='cataloglite.LinkIntercept_TabClick("partsearch"); return false;'>
#              <span class="outer" id="tabouter[partsearch]">
#               <span class="inner" id="tablabel[partsearch]">
#                Part Number Search
#               </span>
#              </span>
#             </a>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-inactive" id="tabheader[extras]" style="">
#             <a href="/en/tools/" onclick='cataloglite.LinkIntercept_TabClick("extras"); return false;'>
#              <span class="outer" id="tabouter[extras]">
#               <span class="inner" id="tablabel[extras]">
#                Tools &amp;
#                <span class="narrow-screen-tab-text">
#                 Universal Parts
#                </span>
#               </span>
#              </span>
#             </a>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-inactive" id="tabheader[cart]" style="">
#             <a href="/en/cart/" onclick='cataloglite.LinkIntercept_TabClick("cart"); return false;'>
#              <span class="outer" id="tabouter[cart]">
#               <span class="inner" id="tablabel[cart]">
#                Cart
#                <span style="display: inline-block; vertical-align: top; position: relative;">
#                 <i class="top-tab-cart-bw-w sprite navigation cartWhite" style="position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;">
#                 </i>
#                 <i class="top-tab-cart-bw-b sprite navigation cartBlack" style="position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;">
#                 </i>
#                </span>
#               </span>
#              </span>
#             </a>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-inactive ra-hide ra-invisible" id="tabheader[spacer]" style="">
#             <span class="outer" id="tabouter[spacer]">
#              <span class="inner" id="tablabel[spacer]">
#               &amp;nbsp &amp;nbsp
#              </span>
#             </span>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-inactive ra-hide" id="tabheader[accountactivity]" style="">
#             <a href="/en/accountactivity/" onclick='cataloglite.LinkIntercept_TabClick("accountactivity"); return false;'>
#              <span class="outer outer-highlight-account" id="tabouter[accountactivity]">
#               <span class="inner" id="tablabel[accountactivity]">
#                Account Activity
#               </span>
#              </span>
#             </a>
#            </span>
#            <span class="ra-tab-header-base ra-tab-header-inactive ra-hide" id="tabheader[profile]" style="">
#             <a href="/en/profile/" onclick='cataloglite.LinkIntercept_TabClick("profile"); return false;'>
#              <span class="outer outer-highlight-account" id="tabouter[profile]">
#               <span class="inner" id="tablabel[profile]">
#                Profile
#               </span>
#              </span>
#             </a>
#            </span>
#            <form action="" class="catalog-search-bar-form" method="post">
#             <input name="_nck" type="hidden" value="8LVLUxTaILBT+tLxkg8+3Ag7/0bbOhvn7P3rkFbL80/4ONrpMMyyMoTAzqUtg75DXjLFbtL0RWwG2TIS5g0HjN+BEpbJggwRicfW87qYxCroJDOCFdvb3koFH0TxTw3x1dhhkAt5X2DwCKM7H+wr2iSOtJHhHxJsSjPiATyw4g4tl9/YjgKefjW5xCoY0Y2d"/>
#             <input autocomplete="off" name="topsearchinput[submit]" type="hidden" value="1"/>
#             <div class="catalog-search-bar-form-div">
#              <table class="tblz catalog-search-bar-form-table tbl-input-button-attached attached-topsearch-size" id="topsearchinputtable">
#               <tr>
#                <td class="input-td td-input">
#                 <label class="ra-hide" for="topsearchinput[input]">
#                  year make model part type or part number or question
#                 </label>
#                 <input autocapitalize="off" autocomplete="off" autocorrect="off" class="topsearchinput topsearchwidth" id="topsearchinput[input]" maxlength="100" name="topsearchinput[input]" onclick=" setTimeout(function() {acmp_request();}, 250);" onfocus="acmp_partcategory = null;" onkeydown="akhandler(event);" onkeyup="acmp_keyup(event);" placeholder="year make model part type or part number or question" spellcheck="false" type="text" value=""/>
#                 <div class="below-absolute search-suggestions">
#                  <span class="ra-hide searchresultmsg" id="searchresultmessage[topsearchinput]" onclick="RA.Hide(this);" style="border: 1px solid #777777; cursor: default; background-color: white;">
#                  </span>
#                  <table class="autosuggest-box topsearchwidth tblz" id="autosuggestions[topsearchinput]" style="display:none">
#                  </table>
#                 </div>
#                </td>
#                <td class="button-td td-button">
#                 <span class="topsearchbuttonwrapspan">
#                  <span class="hide-if-js">
#                   <input alt="Search" class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" id="btntabsearch" name="btntabsearch" onclick="acmp_partcategory = null; go_search(); return false;" title="Search" type="submit" value="Search"/>
#                  </span>
#                  <span class="show-if-js">
#                   <img alt="Search" class="ib input-size ra-btn ra-btn-size-normal ra-btn-color-darkblue ra-btn-search-icon" onclick="RA.Click('btntabsearch')" src="/Images/1pxtransparent.png" style="color: black;" title="Search"/>
#                  </span>
#                 </span>
#                </td>
#               </tr>
#              </table>
#             </div>
#            </form>
#            <span class="ra-tab-header-base ra-tab-header-inactive ra-hide" id="tabheader[cart2]" style="float: right; cursor: default !important;">
#             <span class="outer outer-highlight-cart2" id="tabouter[cart2]">
#              <span class="inner" id="tablabel[cart2]">
#               Quick Cart
#               <span style="display: inline-block; vertical-align: top; position: relative;">
#                <i class="top-tab-cart-bw-w sprite navigation cartWhite" style="position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;">
#                </i>
#                <i class="top-tab-cart-bw-b sprite navigation cartBlack" style="position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;">
#                </i>
#               </span>
#              </span>
#             </span>
#            </span>
#           </nav>
#          </td>
#          <td class="pinched show-if-js" id="show_quick_cart_td" style="padding-right: .5em;">
#           <span style="white-space:nowrap">
#            <label class="mouseover" for="chk_show_side_cart_parent">
#             <input class="ib vmiddle" id="chk_show_side_cart_parent" onclick="side_cart_state['hide_checked'] = !this.checked; setSideCart(); setSideCartCookie();" type="checkbox"/>
#             <span class="ib vmiddle" style="font-size: .9em;">
#              Show
#              <br/>
#              Quick Cart
#             </span>
#            </label>
#           </span>
#          </td>
#          <td class="pinched" style="padding-right: 5px; vertical-align: top;">
#           <div class="" id="minmaxdiv">
#           </div>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <main class="section-tabs-panels" id="section-tabs-panels">
#        <table cellpadding="0" cellspacing="0" class="w100" style="border: none; margin: 0; padding: 0;">
#         <tr>
#          <td>
#           <div class="ra-tab-panel ra-tab-panel-hidden rabacklogo-fixed" id="section-tab-panel[catalog]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[catalog]">
#             <div class="show-if-js" id="jsloadscroll[catalog]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[catalog]">
#              <div id="section-tab-panel-inner-dynamic[catalog]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[catalog]" type="hidden" value='{"key":"catalog","hidden":false,"loaded":false,"label":"Part &lt;span class=\"narrow-screen-tab-text\"&gt;Catalog&lt;\/span&gt;","label_simple":"Part &lt;span class=\"narrow-screen-tab-text\"&gt;Catalog&lt;\/span&gt;","url":"\/en\/catalog\/"}'/>
#           <div class="ra-tab-panel" id="section-tab-panel[partsearch]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[partsearch]">
#             <div class="show-if-js" id="jsloadscroll[partsearch]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[partsearch]">
#              <div id="section-tab-panel-inner-dynamic[partsearch]">
#               <form action="/en/partsearch/" class="" id="frm_partsearch" method="post" name="frm_partsearch" style="margin-top: .5em;">
#                <input name="_nck" type="hidden" value="8LVLUxTaILBT+tLxkg8+3Ag7/0bbOhvn7P3rkFbL80/4ONrpMMyyMoTAzqUtg75DXjLFbtL0RWwG2TIS5g0HjN+BEpbJggwRicfW87qYxCroJDOCFdvb3koFH0TxTw3x1dhhkAt5X2DwCKM7H+wr2iSOtJHhHxJsSjPiATyw4g4tl9/YjgKefjW5xCoY0Y2d"/>
#                <input autocomplete="off" name="dopartsearch" type="hidden" value="1"/>
#                <div style="">
#                 <table class="part-search-input-table tblz" style="margin-left: auto; margin-right: auto; min-width: 25%;">
#                  <tr>
#                   <td class="label">
#                    <label for="partnum_partsearch_007">
#                     Part Number
#                    </label>
#                   </td>
#                   <td class="input">
#                    <input autocapitalize="off" autocomplete="off" autocorrect="off" class="input-full-width" id="partnum_partsearch_007" name="partsearch[partnum][partsearch_007]" onkeypress="" spellcheck="false" type="text" value="715F"/>
#                    (Use
#                    <span style="color: red;">
#                     *
#                    </span>
#                    for wildcards)
#                   </td>
#                  </tr>
#                  <tr>
#                   <td class="label">
#                    <label for="manufacturer_partsearch_007">
#                     Manufacturer
#                    </label>
#                   </td>
#                   <td class="input">
#                    <span class="ra-vertical-dropdown-replacement-c" id="ddrepl[manufacturer_partsearch_007][container]">
#                     <select autocomplete="none" id="manufacturer_partsearch_007" name="partsearch[manufacturer][partsearch_007]" onchange='clb.PartSearchChangeMfrOption(this, "partsearch_007");;' tabindex="0">
#                      <option value="">
#                       All
#                      </option>
#                      <option value="3D">
#                       3D
#                      </option>
#                      <option value="3M">
#                       3M
#                      </option>
#                      <option value="AAE">
#                       AAE
#                      </option>
#                      <option value="ACC">
#                       ACC
#                      </option>
#                      <option value="ACCEL">
#                       ACCEL
#                      </option>
#                      <option value="ACDELCO">
#                       ACDELCO
#                      </option>
#                      <option value="ACE">
#                       ACE
#                      </option>
#                      <option value="ACI">
#                       ACI
#                      </option>
#                      <option value="ACME AUTO">
#                       ACME AUTO
#                      </option>
#                      <option value="ADVAN-TECH">
#                       ADVAN-TECH
#                      </option>
#                      <option value="ADVICS">
#                       ADVICS
#                      </option>
#                      <option value="AGILITY">
#                       AGILITY
#                      </option>
#                      <option value="AGS">
#                       AGS
#                      </option>
#                      <option value="AIMCO">
#                       AIMCO
#                      </option>
#                      <option value="AIR PRO">
#                       AIR PRO
#                      </option>
#                      <option value="AIRQUALITEE">
#                       AIRQUALITEE
#                      </option>
#                      <option value="AIRTEX">
#                       AIRTEX
#                      </option>
#                      <option value="AISIN">
#                       AISIN
#                      </option>
#                      <option value="AJUSA">
#                       AJUSA
#                      </option>
#                      <option value="AKEBONO">
#                       AKEBONO
#                      </option>
#                      <option value="AL'S LINER">
#                       AL'S LINER
#                      </option>
#                      <option value="AL-KO">
#                       AL-KO
#                      </option>
#                      <option value="ALBANY">
#                       ALBANY
#                      </option>
#                      <option value="ALLPARTS">
#                       ALLPARTS
#                      </option>
#                      <option value="ALO">
#                       ALO
#                      </option>
#                      <option value="ALTROM">
#                       ALTROM
#                      </option>
#                      <option value="AMERICAN COMPONENTS">
#                       AMERICAN COMPONENTS
#                      </option>
#                      <option value="AMERICAN REMANUFACTURERS INC.">
#                       AMERICAN REMANUFACTURERS INC.
#                      </option>
#                      <option value="AMERICAN RUBBER">
#                       AMERICAN RUBBER
#                      </option>
#                      <option value="AMS AUTOMOTIVE">
#                       AMS AUTOMOTIVE
#                      </option>
#                      <option value="ANCHOR">
#                       ANCHOR
#                      </option>
#                      <option value="ANCO">
#                       ANCO
#                      </option>
#                      <option value="ANSA">
#                       ANSA
#                      </option>
#                      <option value="AP / EASTERN">
#                       AP / EASTERN
#                      </option>
#                      <option value="APEX">
#                       APEX
#                      </option>
#                      <option value="API">
#                       API
#                      </option>
#                      <option value="APWI">
#                       APWI
#                      </option>
#                      <option value="ARIES">
#                       ARIES
#                      </option>
#                      <option value="ARMORMARK">
#                       ARMORMARK
#                      </option>
#                      <option value="ARNOTT">
#                       ARNOTT
#                      </option>
#                      <option value="ARP">
#                       ARP
#                      </option>
#                      <option value="ARROW AUTOMOTIVE">
#                       ARROW AUTOMOTIVE
#                      </option>
#                      <option value="ATE">
#                       ATE
#                      </option>
#                      <option value="ATP">
#                       ATP
#                      </option>
#                      <option value="ATSCO">
#                       ATSCO
#                      </option>
#                      <option value="AUS INJECTION INC.">
#                       AUS INJECTION INC.
#                      </option>
#                      <option value="AUTO 7">
#                       AUTO 7
#                      </option>
#                      <option value="AUTO EXTRA">
#                       AUTO EXTRA
#                      </option>
#                      <option value="AUTO EXTRA/CHASSIS RITE">
#                       AUTO EXTRA/CHASSIS RITE
#                      </option>
#                      <option value="AUTO PRIDE">
#                       AUTO PRIDE
#                      </option>
#                      <option value="AUTO-TUNE">
#                       AUTO-TUNE
#                      </option>
#                      <option value="AUTOBEST">
#                       AUTOBEST
#                      </option>
#                      <option value="AUTODRIVE">
#                       AUTODRIVE
#                      </option>
#                      <option value="AUTOLINE">
#                       AUTOLINE
#                      </option>
#                      <option value="AUTOLITE">
#                       AUTOLITE
# ...
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[extras]">
#              <div id="section-tab-panel-inner-dynamic[extras]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[extras]" type="hidden" value='{"key":"extras","hidden":false,"loaded":false,"label":"Tools &amp; &lt;span class=\"narrow-screen-tab-text\"&gt;Universal Parts&lt;\/span&gt;","label_simple":"Tools &amp; &lt;span class=\"narrow-screen-tab-text\"&gt;Universal Parts&lt;\/span&gt;","url":"\/en\/tools\/"}'/>
#           <div class="ra-tab-panel ra-tab-panel-hidden" id="section-tab-panel[cart]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[cart]">
#             <div class="show-if-js" id="jsloadscroll[cart]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[cart]">
#              <div id="ppOffsetAnchor_maincart" style="height: 0px; position: relative;">
#              </div>
#              <div class="ra-hide" id="ppOffsetMover_maincart" style="height: 0px; width: 0px; position: relative;">
#               <div class="ra-paypal-zoid-button-outer background en" id="btnRESTPayPal_maincart_outer">
#                <div class="ra-paypal-zoid-button-container remove-when-ready" id="btnRESTPayPal_maincart">
#                </div>
#               </div>
#              </div>
#              <div id="ppOffsetAnchor_maincart_pl" style="height: 0px; position: relative;">
#              </div>
#              <div class="ra-hide" id="ppOffsetMover_maincart_pl" style="height: 0px; width: 0px; position: relative;">
#               <div class="ra-paylater-zoid-button-outer background en" id="btnRESTPayPal_maincart_pl_outer">
#                <div class="ra-paypal-zoid-button-container remove-when-ready" id="btnRESTPayPal_maincart_pl">
#                </div>
#               </div>
#              </div>
#              <div id="section-tab-panel-inner-dynamic[cart]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[cart]" type="hidden" value='{"key":"cart","hidden":false,"loaded":false,"label":"Cart&amp;nbsp;&lt;span style=\"display: inline-block; vertical-align: top; position: relative;\"&gt;&lt;i class=\"top-tab-cart-bw-w sprite navigation cartWhite\" style=\"position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;\"&gt;&lt;\/i&gt;&lt;i class=\"top-tab-cart-bw-b sprite navigation cartBlack\" style=\"position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;\"&gt;&lt;\/i&gt;&lt;\/span&gt;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;","label_simple":"Cart","url":"\/en\/cart\/"}'/>
#           <div class="ra-tab-panel ra-tab-panel-hidden" id="section-tab-panel[spacer]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[spacer]">
#             <div class="show-if-js" id="jsloadscroll[spacer]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[spacer]">
#              <div id="section-tab-panel-inner-dynamic[spacer]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[spacer]" type="hidden" value='{"key":"spacer","hidden":true,"loaded":false,"label":"&amp;nbsp&amp;nbsp;&amp;nbsp&amp;nbsp;","label_simple":null,"url":""}'/>
#           <div class="ra-tab-panel ra-tab-panel-hidden rabacklogo-fixed" id="section-tab-panel[accountactivity]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[accountactivity]">
#             <div class="show-if-js" id="jsloadscroll[accountactivity]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[accountactivity]">
#              <div id="section-tab-panel-inner-dynamic[accountactivity]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[accountactivity]" type="hidden" value='{"key":"accountactivity","hidden":true,"loaded":false,"label":"Account Activity","label_simple":"Account Activity","url":"\/en\/accountactivity\/"}'/>
#           <div class="ra-tab-panel ra-tab-panel-hidden rabacklogo-fixed" id="section-tab-panel[profile]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[profile]">
#             <div class="show-if-js" id="jsloadscroll[profile]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[profile]">
#              <div id="section-tab-panel-inner-dynamic[profile]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[profile]" type="hidden" value='{"key":"profile","hidden":true,"loaded":false,"label":"Profile","label_simple":"Profile","url":"\/en\/profile\/"}'/>
#           <div class="ra-tab-panel ra-tab-panel-hidden" id="section-tab-panel[cart2]">
#            <div class="section-tab-panel-scroll" id="section-tab-panel-scroll[cart2]">
#             <div class="show-if-js" id="jsloadscroll[cart2]" style="text-align: center; padding-top: 15em;">
#              <div class="ib">
#               <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                <div class="hd" style="cursor: auto;">
#                 Loading
#                </div>
#                <div class="bd">
#                 <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="section-tab-panel-inner hide-if-js" id="section-tab-panel-inner[cart2]">
#              <div id="section-tab-panel-inner-dynamic[cart2]">
#              </div>
#             </div>
#             <div class="hide-if-js">
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#             <div>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#              <br/>
#             </div>
#            </div>
#           </div>
#           <input autocomplete="off" id="jstab[cart2]" type="hidden" value='{"key":"cart2","hidden":true,"loaded":false,"label":"Quick Cart&amp;nbsp;&lt;span style=\"display: inline-block; vertical-align: top; position: relative;\"&gt;&lt;i class=\"top-tab-cart-bw-w sprite navigation cartWhite\" style=\"position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;\"&gt;&lt;\/i&gt;&lt;i class=\"top-tab-cart-bw-b sprite navigation cartBlack\" style=\"position: absolute; top: -2px; padding: 0px; margin: 0px; border: none;\"&gt;&lt;\/i&gt;&lt;\/span&gt;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;","label_simple":"Cart","url":""}'/>
#           <input autocomplete="off" id="max_group_index" type="hidden" value="3"/>
#          </td>
#          <td class="ra-hide show-if-js vtop" id="side-cart-cell">
#           <section aria-label="Quick Cart" class="" id="side-cart" style="position: fixed; background-color: #F4F4F4; border-left: 3px solid #666699; box-sizing: border-box;">
#            <div class="w100 taleft" style="">
#             <div class="ramobile nobmp w100" id="side-cart-frame" style="position: relative; font-size: 16px; overflow-y: scroll; overflow-x: hidden;">
#              <div id="ppOffsetAnchor_sidecart" style="height: 0px; position: relative;">
#              </div>
#              <div class="ra-hide" id="ppOffsetMover_sidecart" style="height: 0px; width: 0px; position: relative;">
#               <div class="ra-paypal-zoid-button-outer background en" id="btnRESTPayPal_sidecart_outer">
#                <div class="ra-paypal-zoid-button-container remove-when-ready" id="btnRESTPayPal_sidecart">
#                </div>
#               </div>
#              </div>
#              <div id="ppOffsetAnchor_sidecart_pl" style="height: 0px; position: relative;">
#              </div>
#              <div class="ra-hide" id="ppOffsetMover_sidecart_pl" style="height: 0px; width: 0px; position: relative;">
#               <div class="ra-paylater-zoid-button-outer background en" id="btnRESTPayPal_sidecart_pl_outer">
#                <div class="ra-paypal-zoid-button-container remove-when-ready" id="btnRESTPayPal_sidecart_pl">
#                </div>
#               </div>
#              </div>
#              <div id="side-cart-frame-dynamic">
#               <div style="text-align: center; padding-top: 10em; font-size: .8em;">
#                <div class="ib">
#                 <div class="yui-module yui-overlay yui-panel" style="visibility: inherit; text-align: left;">
#                  <div class="hd" style="cursor: auto;">
#                   Loading
#                  </div>
#                  <div class="bd">
#                   <img alt="Loading" src="/jslib/rel_interstitial_loading.gif"/>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </section>
#          </td>
#         </tr>
#        </table>
#       </main>
#      </div>
#      <div class="hide-if-js" id="temp_nojs_spacer">
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#       <br/>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    /**UQ:5B802676**/
# var $urlDir = "\/catalog";var isFrame = 1;var $hideWelcome = "";var __lang = "en";var javascript_enabled = 1;var simulate_old_html_catalog = 0;var loggedIn = 0;var accountEmailAddress = "";window.accountCarCodes = "";var PK_ADDINGPARTTOCART="Adding Part to Cart",PK_ADDTOLIST="Add to My List",PK_ADJUSTQUANTITY="Adjust Quantity",PK_BIGGER="Bigger",PK_CALCTAXTOTAL="Calculating Tax & Total",PK_CALCULATESHIPPING="Calculate Shipping",PK_CANCEL="Cancel",PK_CART="Cart",PK_CARTNAME="Cart Name",PK_CARTNOTIFICATION="Notification",PK_CONFIRMCLEARCART="Are you sure you want to clear this cart?",PK_ENTERNEWQUANTITY="Enter a new quantity:",PK_GETTINGSHIPQUOTES="Calculating Shipping Cost",PK_HELP="Help",PK_IMAGEDOESNOTREPRESENT="Image does not represent KEY__PARAMDESC selected in catalog",PK_INVALIDID="Invalid ID. Please be sure you have entered a valid Email Address.",PK_LOADING="Loading RockAuto Catalog",PK_LOADINGPAYPAL="<h3>Connecting to PayPal<\/h3>If you continue to see this message after a short period of time, please close this window to return to the RockAuto website.",PK_LOADINGPLAIN="Loading",PK_LOOKINGUPADDRESS="Looking up Address",PK_MULTIPLEMATCHESPLZREFINE="Multiple matches found. Please refine search.",PK_MYADDRESSES="My Addresses",PK_NO="No",PK_NOMATCHESFOUND="No Matches Found",PK_NOPARTSFNDINMARKET="No Parts Found for Selected Market(s)",PK_NUM_LISTINGS_HIDDEN="Reset (KEY__NUM listings hidden) <img src=\"\/catalog\/images\/whiteX.png\" style=\"height:.9em;\" alt=\"\">",PK_OK="OK",PK_PART="Part",PK_PARTALREADYINCART="This part is already in the cart. Please update the quantity in the cart to reflect the quantity you want.",PK_PLEASE="Please",PK_PLEASEENTERPASSWORD="Please enter your password",PK_REMOVE="Remove",PK_RENAME="Rename",PK_RENAMECART="Rename Cart",PK_SMALLER="Smaller",PK_THISVEHICLEISSAVEDTOLIST="This vehicle is saved to your list.",PK_UPDATINGADDRESS="Updating Address Information",PK_UPDATINGCART="Updating Cart",PK_XLISTINGREMOVE="KEY__NUM listing removed",PK_XLISTINGSREMOVE="KEY__NUM listings removed",PK_YES="Yes";
# window["USE_NEW_CHECKOUT"] = true;
# RABoot.WaitFor("jQuery", function() {$(document).ready(function(){if (window['cataloglite']) { cataloglite.AddClearXToInput("topsearchinput[input]", 'cataloglite.ClearTopSearchInput'); }});});
# RABoot.WaitFor("jQuery", function() {$(document).ready(function(){if (window['cataloglite']) { cataloglite.AddTabBaseLine(); }});});
# window['has_side_cart'] = 1;
# var PK_OK ="OK";
# var PK_XLISTINGSREMOVE="KEY__NUM listings removed";
# var PK_XLISTINGREMOVE="KEY__NUM listing removed";
# RABoot.WaitFor("jQuery", function() {$(document).ready(function(){cl_init();});});
# window.top.parent.window["_nck"] = "ZExt1ysfqhqWnq+EvUNdS3Txyey60IDtnjPWF5UU9J0BWQv7pvqZbh+YrdIIoJ2QMq9prrkIerbFMqky5nGcn4teOg9r2Sw3+Pr1CNOXFqQFzxO1xi2naIVVDqptp38yXkE5m0eM5QCA+y15xTcreiyKbrkDUxw8W4ahXJsSn7oYohtQNmW9Zz5xWB4BFneYzv3HwvKpDsMAg8G2DZydTuI8xq8te6L4Dyh4019H8QM=";
#   </script>
#  </body>
# </html>

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

list_part = html.xpath('//tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-a-1") or contains(@class, "altrow-a-0"))]')

list_part
# Out:
# [<Element tbody at 0x12a2dbd00>]

# %%
list_part_number = [_.xpath('./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@title, "Buyer\'s Guide")]')[0].text for _ in list_part]

list_part_number
# Out:
# ['715F']

# %%
import numpy as np

# %%
number_index = np.where(np.array(list_part_number) == part_number)[0]

number_index
# Out:
# array([0])

# %%
list_manufacturer = [_.xpath('./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@class, "listing-final-manufacturer")]')[0].text for _ in list_part]

list_manufacturer
# Out:
# ['MELLING']

# %%
manufacturer_index = np.where(np.array(list_manufacturer) == manufacturer)[0]

manufacturer_index
# Out:
# array([0])

# %%
index = list(np.intersect1d(number_index, manufacturer_index))

index
# Out:
# [0]

# %%
index = index[0]

index
# Out:
# 0

# %%
note_1 = list_part[index].xpath('./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@class, "span-link-underline-remover")]/text()')
if len(note_1) == 0:
    note_1 = ''
else:
    note_1 = note_1[0].strip()

note_1
# Out:
# ''

# %%
note_2 = list_part[index].xpath('./descendant::div[contains(@class, "listing-text-row") and not(contains(@class, "moreinfo-truck"))]/span/span/text()')
if len(note_2) == 0:
    note_2 = ''
else:
    note_2 = [_.strip() for _ in note_2]
    while '' in note_2:
        note_2.remove('')
    note_2 = '\n'.join(note_2)

note_2
# Out:
# 'Category: Timing Chain'

# %%
oe = list_part[index].xpath('./descendant::span[contains(@title, "Replaces these Alternate/ OE Part Numbers")]')
if len(oe) == 0:
    oe = ''
else:
    oe = oe[0].xpath('./text()')[0].strip().replace(', ', ';')

oe
# Out:
# '3L8Z6268AA;L30512201'

# %%
src = list_part[index].xpath('./descendant::img[contains(@id, "inlineimg_thumb")]')
if len(src) == 0:
    src = ''
else:
    src = 'https://www.rockauto.com' + src[0].xpath('./@src')[0].strip().replace('__ra_m.', '.')

src
# Out:
# 'https://www.rockauto.com/info/583/715F-1-ANG.jpg'

# %%
import json

# %%
part_json = list_part[index].xpath('./descendant::input[contains(@id, "listing_data_essential")]')
if len(part_json) == 0:
    part_key = ''
else:
    part_key = json.loads(part_json[0].xpath('./@value')[0])['partkey'].strip()

part_key
# Out:
# '8306448'

# %%
df_temp = pd.DataFrame([{'status': 'ok',
                         '序号': '',
                         'Manufacturer': manufacturer,
                         'Part_Number': part_number,
                         'Vehcile': '',
                         'Alternate_OE_Part_Numbers': oe,
                         'Note_1': note_1,
                         'Note_2': note_2,
                         'Pic': '',
                         'Url': url,
                         'Info': 'https://www.rockauto.com/en/moreinfo.php?pt=' + type_code + '&pk=' + part_key,
                         'Src': src,
                         'Type_Code': type_code,
                         'Part_Key': part_key}])

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#   status 序号 Manufacturer Part_Number Vehcile Alternate_OE_Part_Numbers Note_1  \
# 0     ok         MELLING        715F              3L8Z6268AA;L30512201
#
#                    Note_2 Pic  \
# 0  Category: Timing Chain
#
#                                                  Url  \
# 0  https://www.rockauto.com/en/parts/melling,715F...
#
#                                                 Info  \
# 0  https://www.rockauto.com/en/moreinfo.php?pt=57...
#
#                                                 Src Type_Code Part_Key
# 0  https://www.rockauto.com/info/583/715F-1-ANG.jpg      5724  8306448
