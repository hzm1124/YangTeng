# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests
import json

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./file/1.year.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Year'] = input_['Year'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        try:
            data = {'cssClass': 'form-control',
                    'dropdownType': '1',
                    'selectedValue': '',
                    'vehicleAttributes': {'Make': '',
                                          'MakeID': 0,
                                          'ModelID': 0,
                                          'SkinID': '1',
                                          'Year': f'''{input_.loc[a, 'Year']}'''}}
            
            b = 0
            while True:
                b += 1
                
                try:
                    resp = requests.post('https://www.dormanproducts.com/ApplicationGuideService.asmx/BuildDropdown',
                                         data=json.dumps(data),
                                         headers=get_header(**{'Content-Type': 'application/json; charset=UTF-8'}),
                                         proxies=get_proxy(),
                                         timeout=(10, 10))

                    if resp.status_code == 200:
                        break
                except KeyboardInterrupt:
                    break
                except:
                    continue

            # = = = = = = = = = = = = = = =

            json_ = resp.json()

            # = = = = = = = = = = = = = = =

            soup = BeautifulSoup(json_['d'], 'lxml')
            html = etree.HTML(str(soup))

            # = = = = = = = = = = = = = = =

            list_make_code = html.xpath('//select[@id="makeDropdown"]/option/@value')[1:]

            # = = = = = = = = = = = = = = =

            list_make = html.xpath('//select[@id="makeDropdown"]/option/text()')[1:]

            # = = = = = = = = = = = = = = =

            if not list_make:
                raise

            # = = = = = = = = = = = = = = =

            df_temp = pd.DataFrame({'Make': list_make,
                                    'Make Code': list_make_code,
                                    'Year': input_.loc[a, 'Year']})
            
            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b}] - {input_.loc[a, 'Year']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(30):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Make', 'Year'],
                                                ascending=[True, False],
                                                ignore_index=True)
    output_correct.to_excel(f'''./file/2.make-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['Year'],
                                            ascending=[False],
                                            ignore_index=True)
    output_error.to_excel(f'''./file/make_error.xlsx''', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：102
#
# [状态：ok，尝试次数：1] - 2013
# [剩余数量：72] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2003
# [剩余数量：71] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2004
# [剩余数量：70] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2019
# [剩余数量：69] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2016
# [剩余数量：68] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 1999
# [剩余数量：67] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 1997
# [剩余数量：66] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2008
# [剩余数量：65] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2002
# [剩余数量：64] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2018
# [剩余数量：63] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2024
# [剩余数量：62] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2005
# [剩余数量：61] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2011
# [剩余数量：60] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2007
# [剩余数量：59] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 1996
# [剩余数量：58] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2014
# [剩余数量：57] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2025
# [剩余数量：56] - [当前时间：18:49:19]
#
# [状态：ok，尝试次数：1] - 2020
# [剩余数量：55] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2001
# [剩余数量：54] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2006
# [剩余数量：53] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2012
# [剩余数量：52] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2015
# [剩余数量：51] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2010
# [剩余数量：50] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 1995
# [剩余数量：49] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 1998
# [剩余数量：48] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2023
# [剩余数量：47] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 2009
# [剩余数量：46] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：2] - 2021
# [剩余数量：45] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 1984
# [剩余数量：44] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：1] - 1980
# [剩余数量：43] - [当前时间：18:49:20]
#
# [状态：ok，尝试次数：2] - 2022
# [剩余数量：42] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1982
# [剩余数量：41] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1981
# [剩余数量：40] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1979
# [剩余数量：39] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1992
# [剩余数量：38] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1989
# [剩余数量：37] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1978
# [剩余数量：36] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1988
# [剩余数量：35] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1983
# [剩余数量：34] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 2000
# [剩余数量：33] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1987
# [剩余数量：32] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1976
# [剩余数量：31] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1974
# [剩余数量：30] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1971
# [剩余数量：29] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1990
# [剩余数量：28] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1967
# [剩余数量：27] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1993
# [剩余数量：26] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1970
# [剩余数量：25] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1972
# [剩余数量：24] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1977
# [剩余数量：23] - [当前时间：18:49:21]
#
# [状态：ok，尝试次数：1] - 1975
# [剩余数量：22] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1968
# [剩余数量：21] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：2] - 2017
# [剩余数量：20] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1956
# [剩余数量：19] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1957
# [剩余数量：18] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1960
# [剩余数量：17] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1986
# [剩余数量：16] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1965
# [剩余数量：15] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1961
# [剩余数量：14] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1954
# [剩余数量：13] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1985
# [剩余数量：12] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1969
# [剩余数量：11] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1966
# [剩余数量：10] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1951
# [剩余数量：9] - [当前时间：18:49:22]
#
# [状态：ok，尝试次数：1] - 1952
# [剩余数量：8] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：2] - 1953
# [剩余数量：7] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1950
# [剩余数量：6] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1947
# [剩余数量：5] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1959
# [剩余数量：4] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1948
# [剩余数量：3] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1994
# [剩余数量：2] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1942
# [剩余数量：1] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1943
# [剩余数量：0] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1939
# [剩余数量：0] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1958
# [剩余数量：0] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1946
# [剩余数量：0] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：2] - 1964
# [剩余数量：0] - [当前时间：18:49:23]
#
# [状态：ok，尝试次数：1] - 1935
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1938
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1941
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1945
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1933
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1936
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1940
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1931
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1949
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1932
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1923
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1922
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1955
# [剩余数量：0] - [当前时间：18:49:24]
#
# [状态：ok，尝试次数：1] - 1929
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1915
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1937
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1925
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1930
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1991
# [剩余数量：0] - [当前时间：18:49:25]
#
# [状态：ok，尝试次数：1] - 1928
# [剩余数量：0] - [当前时间：18:49:26]
#
# [状态：ok，尝试次数：1] - 1962
# [剩余数量：0] - [当前时间：18:49:26]
#
# [状态：ok，尝试次数：1] - 1944
# [剩余数量：0] - [当前时间：18:49:26]
#
# [状态：ok，尝试次数：1] - 1934
# [剩余数量：0] - [当前时间：18:49:28]
#
# [状态：ok，尝试次数：2] - 1973
# [剩余数量：0] - [当前时间：18:49:32]
#
# [状态：ok，尝试次数：2] - 1963
# [剩余数量：0] - [当前时间：18:49:33]
#
# 输出ing...
#
# Done ~
