# %%
from gevent import monkey
monkey.patch_all(thread=False)

from gevent.pool import Pool
pool = Pool(5)

from gevent.lock import BoundedSemaphore
semaphore_correct, semaphore_error, semaphore_remain = BoundedSemaphore(1), BoundedSemaphore(1), BoundedSemaphore(1)

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

directory_out = './file/4.vehicle'

if os.path.exists(directory_out):
    shutil.rmtree(directory_out)
os.makedirs(directory_out)

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

# = = = = = = = = = = = = = = =

directory_in = './file/3.part'

list_file = [file for file in sorted(os.listdir(directory_in)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_in}/{file}')]
for file in list_file:

    # = = = = = = = = = = = = = = =

    list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(f'{directory_in}/{file}',
                                                                           header=0,
                                                                           dtype=str).fillna('')

    df_input = df_input[df_input['Vehicle Url'] != ''].reset_index(drop=True)

    df_input['No'] = df_input['No'].astype(int)

    count_remain = len(df_input)

    print(f'总数量：{count_remain}')
    print()

    # = = = = = = = = = = = = = = =

    def crawler(crawler_tuple):
        global list_dict_correct, list_series_error, count_remain

        (crawler_index, crawler_series) = crawler_tuple

        # = = = = = = = = = = = = = = =

        try:
            list_dict_correct_temp, page = [], 0
            while True:

                count_retry = 0
                while True:
                    count_retry += 1

                    try:
                        url_request = f'''{crawler_series['Vehicle Url']}&num=50&start={page * 50}'''

                        resp = requests.get(url_request,
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(5, 15))

                        if resp.status_code == 200:
                            soup = BeautifulSoup(resp.text, 'lxml')
                            html = etree.HTML(str(soup))

                            if html.xpath('//div[@class="detail-app-pager"]'):
                                break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                next_ = html.xpath('//a[@id="pagingBottom_nextButton"]')
                if page == 0 and next_ and next_[0].xpath('./@href')[0].strip() == 'Search/#':
                    raise

                # = = = = = = = = = = = = = = =

                list_text, list_tr = [text.strip() for text in html.xpath('//th[@scope="col"]/text()')], html.xpath('//tr[@class="detail-app-row"]')

                # = = = = = = = = = = = = = = =

                list_dict_correct_temp_temp = [{'Vehicle Url': crawler_series['Vehicle Url'],
                                                'Page': page + 1,
                                                'Row': i + 1} for i in range(len(list_tr))]

                for i, tr in enumerate(list_tr):
                    for j, text in enumerate(list_text):
                        list_dict_correct_temp_temp[i][text] = tr.xpath(f'./td[{j+1}]/text()')[0].strip()

                list_dict_correct_temp.extend(list_dict_correct_temp_temp)

                # = = = = = = = = = = = = = = =

                if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and count_remain == 1 or count_remain % 30 == 0 and count_remain != 0:
                    clear_output()
                print(f'''[第{page + 1}页] - [请求{count_retry}次] - [剩余{count_remain - 1}条] - [{file.removesuffix('.xlsx')}（{(list_file.index(file) + 1) / len(list_file) * 100:.2f}%）] - [{datetime.now().strftime('%Y/%m/%d %H:%M:%S')}] - {crawler_series['No']}. {url_request}\n''')

                # = = = = = = = = = = = = = = =

                if not next_:
                    break

                # = = = = = = = = = = = = = = =

                page += 1

            # = = = = = = = = = = = = = = =

            if not list_dict_correct_temp:
                raise

            # = = = = = = = = = = = = = = =

            with semaphore_correct:
                list_dict_correct.extend(list_dict_correct_temp)
        except:
            crawler_series['Request_Url'] = url_request

            with semaphore_error:
                list_series_error.append(crawler_series)

        # = = = = = = = = = = = = = = =

        with semaphore_remain:
            count_remain -= 1

    # = = = = = = = = = = = = = = =

    pool.map(crawler, df_input.iterrows())

    print('输出ing...')
    print()
    if list_dict_correct:
        df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['Vehicle Url', 'Page', 'Row'],
                                                                 ascending=[True, True, True],
                                                                 ignore_index=True)
        df_correct['Year'] = df_correct['Year'].astype(int)
        df_correct.to_excel(f'''{directory_out}/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if list_series_error:
        df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                               ascending=[True],
                                                               ignore_index=True)
        df_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = [file for file in sorted(os.listdir(directory_out)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_out}/{file}')]
for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'{directory_out}/{file}',
              f'''{directory_out}/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '-vehicle.xlsx', file)}''')

print('Done ~')
# Out:
# [第1页] - [请求1次] - [剩余29条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 70. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86769&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第2页] - [请求6次] - [剩余28条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=50
#
# [第1页] - [请求1次] - [剩余28条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 74. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=85708&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余27条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 78. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=100466&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余26条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 75. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=89000&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余25条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 79. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=100519&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余24条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 72. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86526&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余23条] - [crawler_1（100.00%）] - [2024/10/16 15:43:03] - 63. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53280&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余23条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 82. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86527&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余22条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 84. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=134672&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第3页] - [请求2次] - [剩余21条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 22. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=3098&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=100
#
# [第1页] - [请求1次] - [剩余21条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 83. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=89272&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余20条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 80. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=126452&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第6页] - [请求1次] - [剩余19条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 29. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=2916&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=250
#
# [第3页] - [请求1次] - [剩余18条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=100
#
# [第1页] - [请求1次] - [剩余18条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 76. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86540&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余17条] - [crawler_1（100.00%）] - [2024/10/16 15:43:04] - 73. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=85999&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余16条] - [crawler_1（100.00%）] - [2024/10/16 15:43:05] - 86. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=86528&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余15条] - [crawler_1（100.00%）] - [2024/10/16 15:43:06] - 91. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131747&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余14条] - [crawler_1（100.00%）] - [2024/10/16 15:43:06] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=0
#
# [第1页] - [请求2次] - [剩余14条] - [crawler_1（100.00%）] - [2024/10/16 15:43:06] - 87. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=89226&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第4页] - [请求1次] - [剩余13条] - [crawler_1（100.00%）] - [2024/10/16 15:43:06] - 22. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=3098&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=150
#
# [第1页] - [请求1次] - [剩余13条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 88. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=135492&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求2次] - [剩余12条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 89. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131746&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余11条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 52. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=15569&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第2页] - [请求1次] - [剩余10条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=50
#
# [第1页] - [请求3次] - [剩余10条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 85. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=126960&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求1次] - [剩余9条] - [crawler_1（100.00%）] - [2024/10/16 15:43:07] - 81. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=126959&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求2次] - [剩余8条] - [crawler_1（100.00%）] - [2024/10/16 15:43:08] - 69. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=85441&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第1页] - [请求3次] - [剩余7条] - [crawler_1（100.00%）] - [2024/10/16 15:43:08] - 50. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=27388&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第3页] - [请求1次] - [剩余6条] - [crawler_1（100.00%）] - [2024/10/16 15:43:08] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=100
#
# [第4页] - [请求1次] - [剩余6条] - [crawler_1（100.00%）] - [2024/10/16 15:43:08] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=150
#
# [第1页] - [请求1次] - [剩余6条] - [crawler_1（100.00%）] - [2024/10/16 15:43:09] - 90. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=131983&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第2页] - [请求2次] - [剩余5条] - [crawler_1（100.00%）] - [2024/10/16 15:43:09] - 63. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=53280&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=50
#
# [第1页] - [请求5次] - [剩余4条] - [crawler_1（100.00%）] - [2024/10/16 15:43:09] - 54. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=32263&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第5页] - [请求1次] - [剩余3条] - [crawler_1（100.00%）] - [2024/10/16 15:43:09] - 22. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=3098&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=200
#
# [第4页] - [请求2次] - [剩余3条] - [crawler_1（100.00%）] - [2024/10/16 15:43:11] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=150
#
# [第6页] - [请求1次] - [剩余3条] - [crawler_1（100.00%）] - [2024/10/16 15:43:11] - 22. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=3098&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=250
#
# [第5页] - [请求1次] - [剩余2条] - [crawler_1（100.00%）] - [2024/10/16 15:43:12] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=200
#
# [第6页] - [请求1次] - [剩余2条] - [crawler_1（100.00%）] - [2024/10/16 15:43:14] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=250
#
# [第1页] - [请求4次] - [剩余2条] - [crawler_1（100.00%）] - [2024/10/16 15:43:16] - 92. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=126453&PartType=Air%20Conditioning%20Bypass%20Pulley&num=50&start=0
#
# [第5页] - [请求2次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:19] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=200
#
# [第7页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:20] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=300
#
# [第8页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:21] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=350
#
# [第6页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:21] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=250
#
# [第9页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:23] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=400
#
# [第10页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:27] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=450
#
# [第11页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:29] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=500
#
# [第7页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:30] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=300
#
# [第8页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:31] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=350
#
# [第9页] - [请求2次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:34] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=400
#
# [第12页] - [请求2次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:35] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=550
#
# [第10页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:36] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=450
#
# [第13页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:36] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=600
#
# [第11页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:37] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=500
#
# [第12页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:38] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=550
#
# [第13页] - [请求2次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:41] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=600
#
# [第14页] - [请求2次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:44] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=650
#
# [第15页] - [请求1次] - [剩余1条] - [crawler_1（100.00%）] - [2024/10/16 15:43:45] - 1. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=81798&PartType=Accessory%20Drive%20Belt%20Idler%20Pulley&num=50&start=700
#
# [第14页] - [请求3次] - [剩余0条] - [crawler_1（100.00%）] - [2024/10/16 15:43:49] - 93. https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=23959&PartType=Drive%20Belt%20Tensioner%20Pulley&num=50&start=650
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 1/1 [00:00<00:00, 2947.51it/s]
# Done ~
