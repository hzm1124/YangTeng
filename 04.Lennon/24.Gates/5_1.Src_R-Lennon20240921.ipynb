# %%
import os

list_file = sorted(list(os.walk('./file/4.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1-20240921_100154.xlsx']

# %%
file = list_file[0]

file
# Out:
# 'crawler_1-20240921_100154.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/4.part/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['Product No'] = input_['Product No'].astype(int)
input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Part Number'].tolist()
# Out:
# 总数量：1864
# ['G21100-2020X / 20MGS-20MP XBULK',
#  'G21100-2020 / 20MGS-20MP',
#  'G21165-2020 / 20MGS-20MJ',
#  'G21307-2020 / 20MGS-20FL45S-032',
#  'G21315-2020 / 20MGS-20FL90M-090',
#  'G21720-2038 / 20MGS-38FDHORX',
#  'G21830-2020 / 20MGS-20FBSPORX',
#  'G21715-2038 / 20MGS-38MDH',
#  'G21350-2020 / 20MGS-20FLH',
#  '91183',
#  '91184',
#  '1/2X300 CHEM DEF TRANSFER 500',
#  '5/8X550 4219BD DIESEL FUEL INJ',
#  '3/16 4219BD DIESEL FUEL INJ',
#  '1/4 4219BD DIESEL FUEL INJ',
#  '3/8 4219BD DIESEL FUEL INJ',
#  '5/16 4219BD DIESEL FUEL INJ',
#  '1/2 4219BD',
#  '3/4 4219BD DIESEL FUEL INJ',
#  '1/4XRL FUEL LINE 225 BARRICADE',
#  '5/16XRL FUEL LINE 225 BARRICAD',
#  '3/8XRL FUEL LINE 225 BARRICADE',
#  '1/2XRL FUEL LINE 225 BARRICADE',
#  '3/16XRL FUEL LINE 50 BARRICADE',
#  '1/4XRL FUEL LINE 50 BARRICADE',
#  '5/16XRL FUEL LINE 50 BARRICADE',
#  '3/8XRL FUEL LINE 50 BARRICADE',
#  '1/2XRL FUEL LINE 35 BARRICADE',
#  '28200',
#  '28201',
#  '28202',
#  '28203',
#  '28204',
#  '28207',
#  '28220',
#  '28218',
#  '28210',
#  '28211',
#  '28212',
#  '28213',
#  '28214',
#  '28460',
#  '28461',
#  '28462',
#  '28465',
#  '28466',
#  '28467',
#  '28468',
#  '28469',
#  '28470',
#  '28471',
#  '28472',
#  '28473',
#  '28474',
#  '28475',
#  '28476',
#  '28477',
#  '28478',
#  '28479',
#  '28481',
#  '85664 / 6AC134A X25FT',
#  '70624 / 6AC134A XREEL',
#  '85665 / 8AC134A X25FT',
#  '70625 / 8AC134A XREEL',
#  '85666 / 10AC134A X25FT',
#  '70626 / 10AC134A XREEL',
#  '85667 / 12AC134A X25FT',
#  '70627 / 12AC134A XREEL',
#  '71090 / 6ACC-PS II XREEL',
#  '85384 / 6ACC-PS II X50FT',
#  '71091 / 8ACC-PS II XREEL',
#  '85385 / 8ACC-PS II X50FT',
#  '71092 / 10ACC-PS II XREEL',
#  '85386 / 10ACC-PS II X50FT',
#  '71093 / 12ACC-PS II XREEL',
#  '85387 / 12ACC-PS II X50FT',
#  '3/8X600 AG 200',
#  '1/2X600 AG 200',
#  '5/8X600 AG 200',
#  '3/4X600 AG 200',
#  '1X350 AG 200',
#  '1-1/4X300 AG 250',
#  '1-1/2X250 AG 250',
#  '3X100 AG PVC SOLUTN 35SD CLR',
#  '6X100 AG PVC SOLUTN 35SD CLR',
#  '1-1/4X100 AG PVC SOL 50SD CLR',
#  '2X100 AG PVC XTREME 100SD',
#  '3X100 AG PVC XTREME 90SD',
#  '2X100 AG PVC SOL 70SD CLR',
#  '1X100 AG PVC SOLUTION 80SD',
#  '2X100 AG PVC SOLUTION 60SD',
#  '6X100 AG PVC SOLUTION 35SD',
#  '85111 / AIR LINE REPAIR KIT',
#  '85112 / AIR BRAKE REPAIR',
#  '85113 / TRANS LINE REPAIR',
#  '85114 / TUBING REPAIR KIT',
#  'A33001 / AIR BRK SMALLSURELOK ASST',
#  'A33002 / AIR BRK LG SURELOK ASST',
#  'A33003 / AIR BRK SMALL COMPRSS ASST',
#  'A33004 / AIR BRK LG COMPRSS ASST',
#  '91182 / SM AIR BRAKE ASST',
#  '91181 / LG AIR BRAKE ASST',
#  'G33060-0006 / 6TSN-6ABR',
#  'G33060-0008 / 8TSN-8ABR',
#  'G33050-0006 / 6TS-6ABR',
#  'G33050-0008 / 8TS-8ABR',
#  'G33061-0006 / 6SGN-6ABR',
#  'G33061-0008 / 8SGN-8ABR',
#  'G33112-0006 / 6SGABR',
#  'G33112-0008 / 8SGABR',
#  'G33400-0606 / 6ABR-6ABR',
#  'G33400-0808 / 8ABR-8ABR',
#  'G33150-0606 / 6ABR-6FABX',
#  'G33150-0808 / 8ABR-8FABX',
#  'G33151-0604 / 6ABR-6FABX-4MPA',
#  'G33151-0606 / 6ABR-6FABX-6MPA',
#  'G33151-0608 / 6ABR-8FABX-8MPA',
#  'G33151-0806 / 8ABR-6FABX-6MPA',
#  'G33030-0604 / 6MAB-4MP',
#  'G33030-0606 / 6MAB-6MP',
#  'G33030-0608 / 6MAB-8MP',
#  'G33030-0806 / 8MAB-6MP',
#  'G33030-0808 / 8MAB-8MP',
#  'G33100-0604 / 6ABR-4MP',
#  'G33100-0606 / 6ABR-6MP',
#  'G33100-0608 / 6ABR-8MP',
#  'G33100-0806 / 8ABR-6MP',
#  'G33100-0808 / 8ABR-8MP',
#  'G33110-0604 / 6ABRSG-4MP',
#  'G33110-0606 / 6ABRSG-6MP',
#  'G33110-0608 / 6ABRSG-8MP',
#  'G33110-0806 / 8ABRSG-6MP',
#  'G33110-0808 / 8ABRSG-8MP',
#  'G33111-0604 / 6ABRI-4MP',
#  'G33111-0606 / 6ABRI-6MP',
#  'G33111-0608 / 6ABRI-8MP',
#  'G33111-0806 / 8ABRI-6MP',
#  'G33111-0808 / 8ABRI-8MP',
#  '27602 / 8AB-6MPX-6MPX-08',
#  '27603 / 8AB-6MPX-6MPX-12',
#  '27605 / 8AB-6MPX-6MPX-16',
#  '27607 / 8AB-6MPX-6MPX-20',
#  '27609 / 8AB-6MPX-6MPX-24',
#  '27611 / 8AB-6MPX-6MPX-28',
#  '27613 / 8AB-6MPX-6MPX-32',
#  '27615 / 8AB-6MPX-6MPX-36',
#  '27618 / 8AB-6MPX-6MPX-42',
#  '27624 / 8AB-6MPX-6MPX-54',
#  '27626 / 8AB-6MPX-6MPX-60',
#  '27627 / 8AB-6MPX-6MPX-66',
#  '27628 / 8AB-6MPX-6MPX-72',
#  '27629 / 8AB-6MPX-6MPX-84',
#  '27630 / 6AB-6MPX-6MPX-08',
#  '27631 / 6AB-6MPX-6MPX-12',
#  '27633 / 6AB-6MPX-6MPX-16',
#  '27635 / 6AB-6MPX-6MPX-20',
#  '27637 / 6AB-6MPX-6MPX-24',
#  '27639 / 6AB-6MPX-6MPX-28',
#  '27641 / 6AB-6MPX-6MPX-32',
#  '27643 / 6AB-6MPX-6MPX-36',
#  '27646 / 6AB-6MPX-6MPX-42',
#  '27648 / 6AB-6MPX-6MPX-45',
#  '27650 / 6AB-6MPX-6MPX-48',
#  '27652 / 6AB-6MPX-6MPX-52',
#  '27654 / 6AB-6MPX-6MPX-60',
#  '27655 / 6AB-6MPX-6MPX-66',
#  '27656 / 6AB-6MPX-6MPX-72',
#  '27657 / 6AB-6MPX-6MPX-84',
#  '27658 / 6AB-4MPX-4MPX-08',
#  '27659 / 6AB-4MPX-4MPX-12',
#  '27661 / 6AB-4MPX-4MPX-16',
#  '27663 / 6AB-4MPX-4MPX-20',
#  '27665 / 6AB-4MPX-4MPX-24',
#  '27667 / 6AB-4MPX-4MPX-28',
#  '27669 / 6AB-4MPX-4MPX-32',
#  '27671 / 6AB-4MPX-4MPX-36',
#  '27674 / 6AB-4MPX-4MPX-42',
#  '27677 / 6AB-4MPX-4MPX-48',
#  '27679 / 6AB-4MPX-4MPX-52',
#  '27681 / 6AB-4MPX-4MPX-60',
#  '27682 / 6AB-4MPX-4MPX-66',
#  '27683 / 6AB-4MPX-4MPX-72',
#  '27684 / 6AB-4MPX-4MPX-84',
#  '27685 / 6AB-6FSX-6FSX-18',
#  '27686 / 6AB-6FSX-6FSX-24',
#  '27687 / 6AB-6FSX-6FSX-30',
#  '27688 / 6AB-6FSX-6FSX-36',
#  '27689 / 6AB-6FSX-6FSX-42',
#  '27690 / 6AB-6FSX-6FSX-48',
#  '27691 / 6AB-6FSX-6FSX-54',
#  '27692 / 6AB-6FSX-6FSX-60',
#  '27695 / 8AB-8FSX-8FSX-24',
#  '27696 / 8AB-8FSX-8FSX-30',
#  '27697 / 8AB-8FSX-8FSX-36',
#  '27698 / 8AB-8FSX-8FSX-42',
#  '27699 / 8AB-8FSX-8FSX-48',
#  '27700 / 8AB-8FSX-8FSX-54',
#  '27701 / 8AB-8FSX-8FSX-60',
#  '27693 / 8AB-8FSX-8FSX-18',
#  '27621 / 8AB-6MPX-6MPX-48',
#  'G33302-0804 / 8MP-4FPBKHDL',
#  'G33303-0806 / 8MP-6FPBKHD',
#  '3/4X10 AIR DUCT 20SD',
#  '1X10 AIR DUCT 20SD',
#  '1-1/4X10 AIR DUCT 20SD',
#  '1-1/2X10 AIR DUCT 15SD',
#  '1-5/8X10 AIR DUCT 15SD',
#  '1-7/8X10 AIR DUCT 15SD',
#  '2-1/4X10 AIR DUCT 10SD',
#  '2-3/8X10 AIR DUCT 10SD',
#  '2-1/2X10 AIR DUCT 10SD',
#  '3-1/8X10 AIR DUCT 10SD',
#  '3X10 AIRDUCT 10SD',
#  '3-1/2X10 AIR DUCT 10SD',
#  '4X10 AIR DUCT 10SD',
#  '4-1/2X10 AIR DUCT 10SD',
#  '5X10 AIR DUCT 10SD',
#  '6X10 AIR DUCT 8SD',
#  '2-5/8X10 AIR DUCT 10SD',
#  '1-3/8X10 AIR DUCT 15SD',
#  '5-1/2X10 AIR DUCT 10SD',
#  '2-3/4X10 AIR DUCT 10SD',
#  '2-1/8X10 AIR DUCT 10SD',
#  '1-3/4X10 AIR DUCT 15SD',
#  '1/4XRL AIR RESPIRATOR 500',
#  '1/2X300-999 AIR DVG UMB 1000',
#  '91051-19',
#  '91051-20',
#  '24710',
#  '24712',
#  '24713',
#  '24714',
#  '24715',
#  '24717',
#  '24719',
#  '24721',
#  'G38100-0202 / 2BS-2MP',
#  'G38100-0302 / 3BS-2MP',
#  'G38100-0304 / 3BS-4MP',
#  'G38100-0402 / 4BS-2MP',
#  'G38100-0404 / 4BS-4MP',
#  'G38100-0406 / 4BS-6MP',
#  'G38100-0502 / 5BS-2MP',
#  'G38100-0504 / 5BS-4MP',
#  'G38100-0602 / 6BS-2MP',
#  'G38100-0604 / 6BS-4MP',
#  'G38100-0606 / 6BS-6MP',
#  'G38100-0608 / 6BS-8MP',
#  'G38100-0804 / 8BS-4MP',
#  'G38100-0806 / 8BS-6MP',
#  'G38100-0808 / 8BS-8MP',
#  'G38100-0812 / 8BS-12MP',
#  'G38100-1006 / 10BS-6MP',
#  'G38100-1008 / 10BS-8MP',
#  'G38100-1012 / 10BS-12MP',
#  'G38100-1208 / 12BS-8MP',
#  'G38100-1212 / 12BS-12MP',
#  'G38110-0202 / 2BS-2FP',
#  'G38110-0302 / 3BS-2FP',
#  'G38110-0402 / 4BS-2FP',
#  'G38110-0404 / 4BS-4FP',
#  'G38110-0502 / 5BS-2FP',
#  'G38110-0504 / 5BS-4FP',
#  'G38110-0602 / 6BS-2FP',
#  'G38110-0604 / 6BS-4FP',
#  'G38110-0606 / 6BS-6FP',
#  'G38110-0804 / 8BS-4FP',
#  'G38110-0806 / 8BS-6FP',
#  'G38110-0808 / 8BS-8FP',
#  '27313',
#  '27314',
#  '27315',
#  '27312 / 3/16" X 25 FT BARRICADE FUEL',
#  '27316 / 1/2" X 25 FT BARRICADE FUEL',
#  '27323',
#  '27324',
#  '27325',
#  '27321 / 3/16" X 250 FT BARRICADE FUEL',
#  '27326',
#  '27339',
#  '27344',
#  '27340',
#  '27341',
#  '27342',
#  '27346',
#  '27334',
#  '27335',
#  '5X200 BG BULK MATERIAL 300D',
#  '5X200 BG BULK MATERIAL 300SD',
#  '6X200 BG BULK MATERIAL 300SD',
#  '2X200 BG MUD & OIL 300D',
#  '3X200 BG MUD & OIL 300D',
#  '4X200 BG MUD & OIL 300D',
#  '5X200 BG MUD & OIL 300D',
#  '6X200 BG MUD & OIL 300D',
#  '6X100 BG MUD & OIL 300D',
#  '5X100 BG MUD & OIL 300D',
#  '2X200 BG MUD & OIL 300SD',
#  '4X200 BG MUD & OIL 300SD',
#  '5X200 BG MUD & OIL 300SD',
#  '6X200 BG MUD & OIL 300SD',
#  '3X200 BG MUD & OIL 300SD',
#  '5X100 BG MUD & OIL 300SD',
#  '6X100 BG MUD & OIL 300SD',
#  '6X200 BG FUEL 300D',
#  '6X100 BG FUEL 300D',
#  '4X200 BG OILFIELD SERVICE 400D',
#  '2X200 BG FUEL 300D',
#  '2X100 BG FUEL 300D',
#  '2-1/2X200 BG FUEL 300D',
#  '3X200 BG FUEL 300D',
#  '4X200 BG FUEL 300D',
#  '5X200 BG FUEL 300D',
#  '2X200 BG FUEL 300SD',
#  '3X200 BG FUEL 300SD',
#  '4X200 BG FUEL 300SD',
#  '6X200 BG FUEL 300SD',
#  '6X100 BG FUEL 300SD',
#  '4X100 BG OILFIELD FRAC 400D',
#  '4X200 BG OILFIELD FRAC 400D',
#  '4X100 BG OILFIELD FRAC 400SD',
#  '4X200 BG OILFIELD FRAC 400SD',
#  '4X100 BG OILFIELD SERVCE 400SD',
#  '4X200 BG OILFIELD SERV 400D',
#  '2X200 BG OILFIELD SERV 400SD',
#  '3X200 BG OILFIELD SERV 400SD',
#  '4X200 BG OILFIELD SERV 400SD',
#  '3X200 BG OILFIELD SERV400D-MTF',
#  '4X200 BG OILFIELD SERV400D-MTF',
#  '3X100 BG OILFIELD SERV400D-MTF',
#  '4X100 BG OILFIELD SERV400D-MTF',
#  '4X100 BG OILFIELD SER400SD-MTF',
#  '2X100 BG OILFIELD VACUUM 150SD',
#  '3X100 BG OILFIELD VACUUM 150SD',
#  '4X100 BG OILFIELD VACUUM 100SD',
#  '1X200 BG POTABLE WATER 300D',
#  '2X200 BG POTABLE WATER 300D',
#  '3X200 BG POTABLE WATER 200D',
#  '4X200 BG POTABLE WATER 150D',
#  'G17100-0404 / 4B-4MP-SS',
#  'G17100-0606 / 6B-6MP-SS',
#  'G17100-0808 / 8B-8MP-SS',
#  'G17100-1212 / 12B-12MP-SS',
#  'G17100-1616 / 16B-16MP-SS',
#  'G17100-2020 / 20B-20MP-SS',
#  'G17100-2424 / 24B-24MP-SS',
#  'G17100-3232 / 32B-32MP-SS',
#  'G17210-0404 / 4B-4FJSX-SS',
#  'G17170-0606 / 6B-6FJX-SS',
#  'G17210-0808 / 8B-8FJSX-SS',
#  'G17210-1010 / 10B-10FJSX-SS',
#  'G17170-1212 / 12B-12FJX-SS',
#  'G17200-1212 / 12B-12FSX-SS',
#  'G17170-1616 / 16B-16FJX-SS',
#  'G17170-2020 / 20B-20FJX-SS',
#  'G17170-2424 / 24B-24FJX-SS',
#  'G17170-3232 / 32B-32FJX-SS',
#  'G17230-0404 / 4B-4FFORX-SS',
#  'G17230-0808 / 8B-8FFORX-SS',
#  'G17230-1010 / 10B-10FFORX-SS',
#  'G17230-1212 / 12B-12FFORX-SS',
#  'G17230-1616 / 16B-16FFORX-SS',
#  'G17230-2020 / 20B-20FFORX-SS',
#  'G17230-2424 / 24B-24FFORX-SS',
#  'G17300-3232 / 32B-32FL-SS',
#  'G17300-2424 / 24B-24FL-SS',
#  'G17211-0404 / 4B-4FJSX45S-SS',
#  'G17174-0606 / 6B-6FJX45S-SS',
#  'G17211-0808 / 8B-8FJSX45S-SS',
#  'G17211-1010 / 10B-10FJSX45S-SS',
#  'G17174-1212 / 12B-12FJX45S-SS',
#  'G17174-1616 / 16B-16FJX45S-SS',
#  'G17212-0404 / 4B-4FJSX90S-SS',
#  'G17213-0404 / 4B-4FJSX90M-SS',
#  'G17180-0606 / 6B-6FJX90M-SS',
#  'G17212-0808 / 8B-8FJSX90S-SS',
#  'G17213-0808 / 8B-8FJSX90M-SS',
#  'G17212-1010X / 10B-10FJSX90S-SSXBULK',
#  'G17212-1010 / 10B-10FJSX90S-SS',
#  'G17213-1010 / 10B-10FJSX90M-SS',
#  'G17180-1212 / 12B-12FJX90M-SS',
#  'G17180-1616 / 16B-16FJX90M-SS',
#  'G17995-0104 / 4B1F-1SS',
#  'G17995-0204 / 4B1F-2SS',
#  'G17995-0106 / 6B1F-1SS',
#  'G17995-0206 / 6B1F-2SS',
#  'G17995-0208 / 8B1F-1SS',
#  'G17995-0210 / 10B1F-1SS',
#  'G17995-0212 / 12B1F-1SS',
#  'G17995-0220 / 20B1F-1SS',
#  'G17995-0212DX / 12B1F-2SS XBULK',
#  'G17995-0212D / 12B1F-2SS',
#  'G17995-0224 / 24B1F-2SS',
#  'G17995-0424 / 24B1F-4SS',
#  'G17995-0232 / 32B1F-2SS',
#  'G17995-0432 / 32B1F-4SS',
#  'G17995-0208X / 8B1F-2SS XBULK',
#  'G17995-0216 / 16B1F-3SS',
#  'G17995-0216DX / 16B1F-2SS XBULK',
#  'G17995-0216D / 16B1F-2SS',
#  'G17720-0410 / 4B-10FDHORX-SS',
#  'G17720-0816 / 8B-16FDHORX-SS',
#  'G17720-1220 / 12B-20FDHORX-SS',
#  'G17720-1625 / 16B-25FDHORX-SS',
#  'G17720-1630 / 16B-30FDHORX-SS',
#  'G17720-2038 / 20B-38FDHORX-SS',
#  'G17720-0612 / 6B-12FDHORX-SS',
#  'G36106-0502 / 5LOC-2RMP90',
#  'G36106-0504 / 5LOC-4RMP90',
#  'G36106-0602 / 6LOC-2RMP90',
#  'G36106-0604 / 6LOC-4RMP90',
#  'G36110-0404 / 4LOC-4RFP',
#  'G36110-0606 / 6LOC-6RFP',
#  'G36110-0808 / 8LOC-8RFP',
#  'G36170-0606X',
#  'G36170-0606 / 6LOC-6RFJX',
#  'G36170-1212 / 12LOC-12RFJX',
#  'G36195-0404 / 4LOC-4RMS',
#  'G36195-0405 / 4LOC-5RMS',
#  'G36195-0406 / 4LOC-6RMS',
#  'G36195-0505 / 5LOC-5RMS',
#  'G36195-0606 / 6LOC-6RMS',
#  'G36200-0606 / 6LOC-6RFSX',
#  'G36200-1212 / 12LOC-12RFSX',
#  'G36210-0404 / 4LOC-4RFJSX',
#  'G36210-0405 / 4LOC-5RFJSX',
#  'G36210-0505 / 5LOC-5RFJSX',
#  'G36210-0605 / 6LOC-5RFJSX',
#  'G36210-0808 / 8LOC-8RFJSX',
#  'G36210-1010 / 10LOC-10RFJSX',
#  'G36210-1210 / 12LOC-10RFJSX',
#  'G36500-0403 / 4LOC-3RMIX',
#  'G36500-0404 / 4LOC-4RMIX',
#  'G36500-0405 / 4LOC-5RMIX',
#  'G36500-0504 / 5LOC-4RMIX',
#  'G36500-0506 / 5LOC-6RMIX',
#  'G36500-0605 / 6LOC-5RMIX',
#  'G36500-0606 / 6LOC-6RMIX',
#  'G36500-0808 / 8LOC-8RMIX',
#  'G36508-0403 / 4LOC-3RFI',
#  'G36508-0404 / 4LOC-4RFI',
#  'G36508-0405 / 4LOC-5RFI',
#  'G36508-0505 / 5LOC-5RFI',
#  'G36508-0605 / 6LOC-5RFI',
#  'G36508-0606 / 6LOC-6RFI',
#  'G36508-0808 / 8LOC-8RFI',
#  'G36520-0403 / 4LOC-3RFT',
#  'G36520-0404 / 4LOC-4RFT',
#  'G36520-0405 / 4LOC-5RFT',
#  'G36520-0606 / 6LOC-6RSP',
#  'G36535-0404 / 4LOC-4RHM',
#  'G36535-0505 / 5LOC-5RHM',
#  'G36535-0606 / 6LOC-6RHM',
#  'G36535-0808 / 8LOC-8RHM',
#  'G36105-0404 / 4LOC-4RMPX',
#  'G36105-0606 / 6LOC-6RMPX',
#  'G36105-0808 / 8LOC-8RMPX',
#  'G36105-1212 / 12LOC-12RMPX',
#  'G36106-0402 / 4LOC-2RMP90',
#  'G36106-0404 / 4LOC-4RMP90',
#  'G36106-0606 / 6LOC-6RMP90',
#  'G36106-0808 / 8LOC-8RMP90',
#  'G36106-1212 / 12LOC-12RMP90',
#  'G36110-0504 / 5LOC-4RFP',
#  'G36110-0806 / 8LOC-6RFP',
#  'G36110-1008 / 10LOC-8RFP',
#  'G36110-1212 / 12LOC-12RFP',
#  'G36111-0402 / 4LOC-2RFPX',
#  'G36111-0404 / 4LOC-4RFPX',
#  'G36111-0406 / 4LOC-6RFPX',
#  'G36111-0604 / 6LOC-4RFPX',
#  'G36111-0606 / 6LOC-6RFPX',
#  'G36111-0608 / 6LOC-8RFPX',
#  'G36111-0808 / 8LOC-8RFPX',
#  'G36111-0812 / 8LOC-12RFPX',
#  'G36111-1012 / 10LOC-12RFPX',
#  'G36111-1212 / 12LOC-12RFPX',
#  'G36165-0404 / 4LOC-4RMJ',
#  'G36165-0405 / 4LOC-5RMJ',
#  'G36165-0406 / 4LOC-6RMJ',
#  'G36165-0604 / 6LOC-4RMJ',
#  'G36165-0605 / 6LOC-5RMJ',
#  'G36165-0606 / 6LOC-6RMJ',
#  'G36165-0608 / 6LOC-8RMJ',
#  'G36165-0808 / 8LOC-8RMJ',
#  'G36165-0810 / 8LOC-10RMJ',
#  'G36165-1008 / 10LOC-8RMJ',
#  'G36165-1010 / 10LOC-10RMJ',
#  'G36165-1210 / 12LOC-10RMJ',
#  'G36165-1212 / 12LOC-12RMJ',
#  'G36170-0406 / 4LOC-6RFJX',
#  'G36195-0604 / 6LOC-4RMS',
#  'G36195-0605 / 6LOC-5RMS',
#  'G36195-0608 / 6LOC-8RMS',
#  'G36195-0810 / 8LOC-10RMS',
#  'G36195-1008 / 10LOC-8RMS',
#  'G36195-1010 / 10LOC-10RMS',
#  'G36195-1212 / 12LOC-12RMS',
#  'G36200-0406 / 4LOC-6RFSX',
#  'G36200-0806 / 8LOC-6RFSX',
#  'G36500-0608 / 6LOC-8RMIX',
#  'G36500-0806 / 8LOC-6RMIX',
#  'G36520-0808 / 8LOC-8RSP',
#  'G36520-1010 / 10LOC-10RSP',
#  'G36195-0808 / 8LOC-8RMS',
#  'G36200-0506 / 5LOC-6RFSX',
#  'G36210-0608 / 6LOC-8RFJSX',
#  'G36210-0810 / 8LOC-10RFJSX',
#  'G36500-1010 / 10LOC-10RMIX',
#  'G36535-1010 / 10LOC-10RHM',
#  'G36535-1212 / 12LOC-12RHM',
#  '2X100 BULK PVC 35SD AR',
#  '2-1/2X100 BULK PVC 35SD AR',
#  '4X100 BULK PVC 30SD AR',
#  '6X100 BULK PVC 25SD AR',
#  'G89170-1018 / 10C14-10FJSX-10FJSX-18',
#  'G89170-1024 / 10C14-10FJSX-10FJSX-24',
#  'G89170-1030 / 10C14-10FJSX-10FJSX-30',
#  'G89170-1036 / 10C14-10FJSX-10FJSX-36',
#  'G89170-1042 / 10C14-10FJSX-10FJSX-42',
#  'G89170-1048 / 10C14-10FJSX-10FJSX-48',
#  'G89170-1054 / 10C14-10FJSX-10FJSX-54',
#  'G89170-1072 / 10C14-10FJSX-10FJSX-72',
#  'G89170-1084 / 10C14-10FJSX-10FJSX-84',
#  'G89461-1018',
#  '78006 / CUTTING SHEAR FOR C14',
#  '78521 / HD-4C14 INSERTION DIE',
#  '78522 / HD-5C14 INSERTION DIE',
#  '78523 / HD-6C14 INSERTION DIE',
#  '78524 / HD-8C14 INSERTION DIE',
#  '78525 / HD-10C14 INSERTION DIE',
#  '78526 / HD-12C14 INSERTION DIE',
#  '78527 / HD-16C14 INSERTION DIE',
#  '78518 / INSERTION DIE HOLDER',
#  '78517 / HOSE INSERTION FIXTURE',
#  '78530 / HE-4C14 EXPANDER',
#  '78531 / HE-5C14 EXPANDER',
#  '78532 / HE-6C14 EXPANDER',
#  '78533 / HE-8C14 EXPANDER',
#  '78534 / HE-10C14 EXPANDER',
#  '78535 / HE-12C14 EXPANDER',
#  '78536 / HE-16C14 EXPANDER',
#  '70096 / 20C5C XCTN',
#  '70097 / 24C5C XCTN',
#  '70098 / 32C5C XCTN',
#  '70099 / 40C5C XCTN',
#  '86605 / 4C5C X50FT',
#  '86606 / 5C5C X50FT',
#  '86607 / 6C5C X50FT',
#  '86608 / 8C5C X50FT',
#  '86609 / 10C5C X50FT',
#  '86610 / 12C5C X50FT',
#  '86616 / 16C5C X50FT',
#  '86617 / 20C5C X25FT',
#  '70589 / 4C5C XREEL',
#  '70590 / 5C5C XREEL',
#  '70591 / 6C5C XREEL',
#  '70592 / 8C5C XREEL',
#  '70593 / 10C5C XREEL',
#  '70594 / 12C5C XREEL',
#  '70595 / 16C5C XREEL',
#  '70095 / 4C5CXH XREEL',
#  '70992 / 5C5CXH XREEL',
#  '70993 / 6C5CXH XREEL',
#  '70994 / 8C5CXH XREEL',
#  '70995 / 10C5CXH XREEL',
#  '70996 / 12C5CXH XREEL',
#  '70997 / 16C5CXH XREEL',
#  '70998 / 20C5CXH XCTN',
#  '86992 / 5C5CXH X50FT',
#  '86993 / 6C5CXH X50FT',
#  '86994 / 8C5CXH X50FT',
#  '86995 / 10C5CXH X50FT',
#  '86996 / 12C5CXH X50FT',
#  '86997 / 16C5CXH X50FT',
#  '86998 / 20C5CXH X50FT',
#  '85680 / 4C5D X50FT',
#  '85682 / 6C5D X50FT',
#  '85683 / 8C5D X50FT',
#  '85681 / 5C5D X50FT',
#  '85684 / 10C5D X50FT',
#  '85685 / 12C5D X50FT',
#  '85686 / 16C5D X50FT',
#  '70540 / 4C5D XREEL',
#  '70542 / 6C5D XREEL',
#  '70543 / 8C5D XREEL',
#  '70541 / 5C5D XREEL',
#  '70544 / 10C5D XREEL',
#  '70545 / 12C5D XREEL',
#  '70546 / 16C5D XREEL',
#  '70193 / 8C5E XCTN',
#  '70194 / 10C5E XCTN',
#  '70195 / 12C5E XCTN',
#  '70197 / 20C5E XCTN',
#  '70530 / 4C5E XREEL',
#  '70531 / 5C5E XREEL',
#  '70532 / 6C5E XREEL',
#  '70533 / 8C5E XREEL',
#  '70534 / 10C5E XREEL',
#  '70535 / 12C5E XREEL',
#  '70536 / 16C5E XREEL',
#  '85697 / 20C5E X25FT',
#  '85690 / 4C5E X50FT',
#  '85691 / 5C5E X50FT',
#  '85692 / 6C5E X50FT',
#  '85693 / 8C5E X50FT',
#  '85694 / 10C5E X50FT',
#  '85695 / 12C5E X50FT',
#  '85696 / 16C5E X50FT',
#  '70614 / 5C5M XREEL',
#  '70615 / 6C5M XREEL',
#  '70616 / 8C5M XREEL',
#  '70617 / 10C5M XREEL',
#  '70618 / 12C5M XREEL',
#  '70619 / 16C5M XREEL',
#  '86596 / 6C5M X50FT',
#  '86597 / 8C5M X50FT',
#  '86598 / 10C5M X50FT',
#  '86599 / 12C5M X50FT',
#  '86600 / 16C5M X50FT',
#  '71151 / 6CM2TDL-XTF XCTN',
#  '71152 / 8CM2TDL-XTF XCTN',
#  '85389 / 6CM2TDL-XTF X50FT',
#  '85390 / 8CM2TDL-XTF X50FT',
#  '4CR1 XREEL',
#  '4CR1 XBALE',
#  '6CR1 XREEL',
#  '6CR1 XBALE',
#  '8CR1 XREEL',
#  '8CR1 XBALE',
#  '10CR1 XREEL',
#  '10CR1 XBALE',
#  '12CR1 XREEL',
#  '12CR1 XBALE',
#  '16CR1 XREEL',
#  '16CR1 XBALE',
#  '4CR2 XREEL',
#  '4CR2 XBALE',
#  '6CR2 XREEL',
#  '6CR2 XBALE',
#  '8CR2 XREEL',
#  '8CR2 XBALE',
#  '10CR2 XREEL',
#  '10CR2 XBALE',
#  '12CR2 XREEL',
#  '12CR2 XBALE',
#  '16CR2 XREEL',
#  '16CR2 XBALE',
#  '91008',
#  '27475',
#  '27476',
#  '28673',
#  '27478',
#  '27479',
#  '28674',
#  '3/4X500 CHEM HYDROCBN DRAIN300',
#  '1X500 CHEM HYDROCBN DRAIN300',
#  '2X100 CHEM+ XLPE 200SD BLK',
#  '3/4X100 CHEM+ XLPE 200SD BLK',
#  '1X100 CHEM+ XLPE 200SD BLACK',
#  '1-1/4X100 CHEM+XLPE 200SD BLK',
#  '1-1/2X100 CHEM+ XLPE 200SD BLK',
#  '2-1/2X100 CHEM+ XLPE 150SD BLK',
#  '3X100 CHEM+ XLPE 150SD BLACK',
#  '4X100 CHEM+ XLPE 150SD BLACK',
#  '1X100 CHEM+ XLPE 200SD YELLOW',
#  '3X100 CHEM+ XLPE 150SD YELLOW',
#  '2X100 CHEM+ XLPE 200SD GRN SMO',
#  '3X100 CHEM+ XLPE 150SD GRN SMO',
#  '2X200 CHEM+ XLPE 200SD BLUE',
#  '3X200 CHEM+ XLPE 150SD BLUE',
#  '2X100 CHEM+ XLPE 200SD RED',
#  '1X100 CHEM+ XLPE 200SD CR',
#  '2X100 CHEM+ XLPE 200SD CR',
#  '1X100 CHEM+ XLPE 200SD BLUE',
#  '2X100 CHEM+ XLPE 200SD YELLOW',
#  '3X100 CHEM+ XLPE 150SD GRAY',
#  '1X100 CHEM+ XLPE 200SD RED',
#  '3/4X100 CHEM+ XLPE 200SD YLW',
#  '3X100 CHEM+ XLPE 150SD RED',
#  '1-1/2X100 CHEM+XLP200SD CR GRN',
#  '1-1/2X100 CHEM+ XLPE 200SD BLU',
#  '1-1/2X200 CHEM+ XLPE 200SD BLK',
#  '1-1/2X200 CHEM+ XLPE 200SD YLW',
#  '2-1/2X200 CHEM+ XLPE 150SD GRN',
#  '1-1/2X200 CHEM+ XLPE 200SD RED',
#  '2X100 CHEM+ XLPE 200SD BLUE',
#  '3X100 CHEM+ XLPE 150SD BLUE',
#  '1-1/4X100 CHEM+ XLPE 200SD GRN',
#  '4X100 CHEM+ XLPE 150SD GREEN',
#  '1X100 CHEM EPDM 150SD',
#  '3/4X100 CHEM EPDM 150SD',
#  '1-1/4X100 CHEM EPDM 150SD',
#  '1-1/2X100 CHEM EPDM 150SD',
#  '2X100 CHEM EPDM 150SD',
#  '2-1/2X100 CHEM EPDM 150SD',
#  '3/4X100 CHEM+CPE 200SD MEGAFLX',
#  '1X100 CHEM+ CPE 200SD MEGAFLEX',
#  '4X100 CHEM EPDM 125SD',
#  '3X200 CHEM EPDM 150SD',
#  '2X100 CHEM+ CPE 200SD MEGAFLEX',
#  '6X100 CHEM EPDM 125SD',
#  '3X100 CHEM+ CPE 150SD MEGAFLEX',
#  '4X100 CHEM+ CPE 150SD MEGAFLEX',
#  '1X200 CHEM+ CPE 200SD MEGA BRN',
#  '2X200 CHEM+ CPE 200SD MEGA BRN',
#  '1-1/4X200 CHEM EPDM 150SD',
#  '1X100 CHEM+ UHMWPE 200SD BLK',
#  '1-1/4X100 CHEM+UHMWPE200SD BLK',
#  '1-1/2X100 CHEM+UHMWPE200SD BLK',
#  '2X100 CHEM+ UHMWPE 200SD BLACK',
#  '2-1/2X100 CHEM+UHMWPE150SD BLK',
#  '3X100 CHEM+ UHMWPE 150SD BLACK',
#  '4X100 CHEM+ UHMWPE 150SD BLACK',
#  '1X100 CHEM XTREME FEP 200SD',
#  '2X100 CHEM XTREME FEP 200SD',
#  '3X100 CHEM XTREME FEP 150SD',
#  '3/4X20 CHEM XTREME FEP 200SD',
#  '1X20 CHEM XTREME FEP 200SD',
#  '2X20 CHEM XTREME FEP 200SD',
#  '4X20 CHEM XTREME FEP 125SD',
#  '1X200 CHEM XTREME FEP 200SD',
#  '1X200 CHEM XTREM FEP 200SD BLK',
#  '1X50 CHEM XTREME FEP 200SD CR',
#  '2X50 CHEM XTREME FEP 200SD CR',
#  '1X150 CHEM XTRM FEP200SDCR BLK',
#  '1-1/2X150 CHEM XT FEP200SD BLK',
#  '1-1/2X200 CHEM XTRM FEP200SDCR',
#  '3/8XLGRL 1000 CLEAN PW3000 BLK',
#  '3/8XRL 300 CLEAN PW3000 BLUE',
#  '3/8XRL 300 CLEAN PW3000 GRAY',
#  '70848 / 3/8XRL 300 CLEAN PW3000 YELLOW',
#  '85722 / 3/8X50 CLEAN PW3000 BLACK',
#  '85723 / 3/8X50 CLEAN PW3000 BLUE',
#  '1/2XRL 300 CLEAN PW3000 BLACK',
#  '1/2XLGRL 1000 CLEAN PW3000 BLK',
#  '1/2XRL 300 CLEAN PW3000 BLUE',
#  '1/2XRL 300 CLEAN PW3000 GRAY',
#  '1/2XRL 300 CLEAN PW3000 YELLOW',
#  '1/2X100 CLEAN PW3000 YELLOW',
#  '3/8X50 CLEAN PW4000 GRAY',
#  '3/8X100 CLEAN PW4000 GRAY',
#  '3/8X50 CLEAN PW6000 GRAY',
#  '3/8X100 CLEAN PW6000 GRAY',
#  '70842 / 3/8XRL 300 CLEAN PW3000 BLACK',
#  '1/2XRL 1000 CLEAN PW4000 BLACK',
#  '1/4XRL 300 CLEAN PW4000 BLACK',
#  '1/4XLGRL 1000 CLEAN PW4000 BLK',
#  '3/8XRL 300 CLEAN PW4000 BLACK',
#  '3/8XLGRL 1000 CLEAN PW4000 BLK',
#  '3/8XRL 300 CLEAN PW4000 YELLOW',
#  '3/8XLGRL 1000 CLEAN PW4000 YLW',
#  '3/8X100 CLEAN PW4000 BLACK',
#  '85729 / 3/8X50 CLEAN PW4000 BLACK',
#  '1/2XRL 300 CLEAN PW4000 BLACK',
#  '1/2XLGRL 1000 CLEAN PW4000 GRY',
#  '1/2XRL 300 CLEAN PW4000 GRAY',
#  '1/2XLGRL 1000 CLEAN PW4000 YLW',
#  '1/2XRL 300 CLEAN PW4000 YELLOW',
#  '71117 / 3/8XRL 300 CLEAN PW4000 BLUE',
#  '85728 / 3/8X50 CLEAN PW4000 BLUE',
#  '3/8X100 CLEAN PW4000 BLUE',
#  '3/8XRL 300 CLEAN PW4000 GRAY',
#  '1/4XRL 300 CLEAN PW4000 BLUE',
#  '3/8XBALE CLEAN PW4000 BLACK',
#  '1/2XBALE CLEAN PW4000 BLACK',
#  '1/2XBALE CLEAN PW4000 BLUE',
#  '1/2XBALE CLEAN PW4000 GRAY',
#  '1/4X100 CLEAN PW4000 BLUE',
#  '1/4X300FT CLEAN+ PW6000 BLK',
#  '1/4X1000LGRL CLEAN+ PW6000 BLK',
#  '1/4XBALE CLEAN+ PW6000 BLK',
#  '3/8X50FT CLEAN+ PW6000 BLK',
#  '3/8X100FT CLEAN+ PW6000 BLK',
#  '3/8XRL300FT CLEAN+ PW6000 BLK',
#  '3/8XLGRL 1KFT CLEAN+PW6000 BLK',
#  '3/8XBALE CLEAN+ PW6000 BLK',
#  '1/2XRL300FT CLEAN+ PW6000 BLK',
#  '1/2XRL1000FT CLEAN+ PW6000 BLK',
#  '1/2XBALE CLEAN+ PW6000 BLK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '85698 / 3/8X50 CLEAN PW3000 YELLOW',
#  '1/2XRL CLEAN WASHDOWN W/O NOZZ',
#  '3/4X50 CLEAN WASHDOWN W/O NOZZ',
#  '1XRL CLEAN WASHDOWN W/O NOZZLE',
#  '1X50 CLEAN WASHDOWN W/O NOZZLE',
#  '1/2X500 CLEAN WASHDWN W/O NOZZ',
#  '3/4XRL CLEAN WASHDOWN W/O NOZZ',
#  '3/4X100 WASHDOWN WHIT W/O NOZZ',
#  '3/4X50 CLEAN WSHDWN W/NOZZ GRY',
#  '1X50 CLEAN WASHDOWN W/NOZZ GRY',
#  '1-1/4X50 CLEAN WSHDN W/NZL GRY',
#  '3/4X500 CLEAN WASHDWN W/O NOZZ',
#  '70764 / 4CPB XREEL',
#  '70765 / 6CPB XREEL',
#  '70766 / 8CPB XREEL',
#  '70767 / 12CPB XREEL',
#  '70768 / 16CPBP XREEL',
#  '20CPB XCTN',
#  '24CPB X50FT',
#  '32CPB X50FT',
#  '70642 / 4CPB-MTF XREEL',
#  '70643 / 6CPB-MTF XREEL',
#  '70644 / 8CPB-MTF XREEL',
#  '70645 / 12CPB-MTF XREEL',
#  '70646 / 16CPB-MTF XREEL',
#  '70647 / 20CPB-MTF XCTN',
#  '24CPB-MTF XCTN',
#  '32CPB-MTF XCTN',
#  '10CPB-MTF XREEL',
#  '70906 / 6C14CT XCTN',
#  '85730 / 6C14CT X25FT',
#  '70908 / 8C14CT XCTN',
#  '85731 / 8C14CT X25FT',
#  'G34500-0605 / 6C5-5RMIX',
#  'G34500-0608 / 6C5-8RMIX',
#  'G34181-0606 / 6C5-6RFJX90L',
#  'G34202-0606 / 6C5-6RFSX45',
#  'G34205-0606 / 6C5-6RFSX90',
#  'G34502-0404 / 4C5-4RMIX45',
#  'G34502-0606 / 6C5-6RMIX45',
#  'G34504-0404 / 4C5-4RMIX90',
#  'G34504-0608 / 6C5-8RMIX90',
#  'G34235-0404 / 4C5-4RFFORX45',
#  'G34240-0404 / 4C5-4RFFORX90',
#  'G34239-0606 / 6C5-6RFFORX90S',
#  'G34211-0404 / 4C5-4RFJSX45',
#  'G34211-1010 / 10C5-10RFJSX45',
#  'G34211-0608 / 6C5-8RFJSX45',
#  'G34212-0404 / 4C5-4RFJSX90',
#  'G34212-1010X / 10C5-10RFJSX90 XBULK',
#  'G34212-1010 / 10C5-10RFJSX90',
#  'G34213-0404 / 4C5-4RFJSX90L',
#  'G34213-1010 / 10C5-10RFJSX90L',
#  'G34179-2020X / 20C5-20RFJX90S XBULK',
#  'G34179-2020 / 20C5-20RFJX90S',
#  'G34500-0404 / 4C5-4RMIX',
#  'G34500-0606 / 6C5-6RMIX',
#  'G34504-0606 / 6C5-6RMIX90',
#  'G34175-0606 / 6C5-6RFJX45',
#  'G34175-1616 / 16C5-16RFJX45',
#  'G34180-0606 / 6C5-6RFJX90',
#  'G34180-1616 / 16C5-16RFJX90',
#  'G34181-1616 / 16C5-16RFJX90L',
#  'G34206-0606 / 6C5-6RFSX90L',
#  'G34100-0606B / 6C5-6RMPB',
#  'G34100-1008B / 10C5-8RMPB',
#  'G34100-1616B / 16C5-16RMPB',
#  'G34100-0808B / 8C5-8RMPB',
#  'G34100-0402 / 4C5-2RMP',
#  'G34100-0404X / 4C5-4RMP XBULK',
#  'G34100-0404 / 4C5-4RMP',
#  'G34100-0604X / 6C5-4RMP XBULK',
#  'G34100-0604 / 6C5-4RMP',
#  'G34100-1008X / 10C5-8RMP XBULK',
#  'G34100-1008 / 10C5-8RMP',
#  'G34100-1012 / 10C5-12RMP',
#  'G34100-0606 / 6C5-6RMP',
#  'G34510-0404 / 4C5-4RMFA',
#  'G34510-0604 / 6C5-4RMFA',
#  'G34510-0606 / 6C5-6RMFA',
#  'G34510-1010 / 10C5-10RMFA',
#  'G34100-2424 / 24C5-24RMP',
#  'G34100-3232 / 32C5-32RMP',
#  'G34100-1612 / 16C5-12RMP',
#  'G34100-1616 / 16C5-16RMP',
#  'G34195-0404 / 4C5-4RMS',
#  'G34195-0606 / 6C5-6RMS',
#  'G34195-1010 / 10C5-10RMS',
#  'G34100-2020 / 20C5-20RMP',
#  'G34165-0404 / 4C5-4RMJ',
#  'G34165-0606 / 6C5-6RMJ',
#  'G34165-1010 / 10C5-10RMJ',
#  'G34165-1616 / 16C5-16RMJ',
#  'G34120-0404 / 4C5-4RMB',
#  'G34120-0606 / 6C5-6RMB',
#  'G34100-0502 / 5C5X-2RMP',
#  'G34100-0504X / 5C5X-4RMP XBULK',
#  'G34100-0504 / 5C5X-4RMP',
#  'G34100-0806 / 8C5X-6RMP',
#  'G34100-0808X / 8C5X-8RMP XBULK',
#  'G34100-0808 / 8C5X-8RMP',
#  'G34100-1208 / 12C5X-8RMP',
#  'G34100-1212 / 12C5X-12RMP',
#  'G34170-0806 / 8C5X-6RFJX',
#  'G34170-1212 / 12C5X-12RFJX',
#  'G34175-1212 / 12C5X-12RFJX45S',
#  'G34180-1212 / 12C5X-12RFJX90S',
#  'G34181-1212 / 12C5X-12RFJX90L',
#  'G34120-0808 / 8C5X-8RMB',
#  'G34165-0505 / 5C5X-5RMJ',
#  'G34165-0808 / 8C5X-8RMJ',
#  'G34165-1212 / 12C5X-12RMJ',
#  'G34195-0505 / 5C5X-5RMS',
#  'G34195-0808 / 8C5X-8RMS',
#  'G34195-1212 / 12C5X-12RMS',
#  'G34200-1212 / 12C5X-12RFSX',
#  'G34202-1212 / 12C5X-12RFSX45S',
#  'G34205-1212 / 12C5X-12RFSX90S',
#  'G34206-1212 / 12C5X-12RFSX90L',
#  'G34210-0504 / 5C5X-4RFJSX',
#  'G34210-0505X / 5C5X-5RFJSX XBULK',
#  'G34210-0505 / 5C5X-5RFJSX',
#  'G34210-0808X / 8C5X-8RFJSX XBULK',
#  'G34210-0808 / 8C5X-8RFJSX',
#  'G34211-0505 / 5C5X-5RFJSX45S',
#  'G34211-0808 / 8C5X-8RFJSX45S',
#  'G34212-0505 / 5C5X-5RFJSX90S',
#  'G34213-0505 / 5C5X-5RFJSX90L',
#  'G34212-0808 / 8C5X-8RFJSX90S',
#  'G34213-0808 / 8C5X-8RFJSX90L',
#  'G34230-0808 / 8C5X-8RFFORX',
#  'G34230-1212 / 12C5X-12RFFORX',
#  'G34500-0505 / 5C5X-5RMIX',
#  'G34500-0506 / 5C5X-6RMIX',
#  'G34500-0806 / 8C5X-6RMIX',
#  'G34500-0808 / 8C5X-8RMIX',
#  'G34502-0808 / 8C5X-8RMIX45-028',
#  'G34504-0505 / 5C5X-5RMIX90-042',
#  'G34504-0806 / 8C5X-6RMIX90-043',
#  'G34504-0808 / 8C5X-8RMIX90-045',
#  'G34510-0505 / 5C5X-5RMFA',
#  'G34510-0808 / 8C5X-8RMFA',
#  'G34540-0806 / 8C5X-6RFABX',
#  'G35210-0505X / 5C5E-5RFJSX XBULK',
#  'G34230-0606 / 6C5-6RFFORX',
#  'G34230-0404 / 4C5-4RFFORX',
#  'G34230-1010 / 10C5-10RFFORX',
#  'G34210-0505B / 5C5-5RFJSXB',
#  'G34210-0808B / 8C5-8RFJSXB',
#  'G34210-1010B / 10C5-10RFJSXB',
#  'G34200-0606B / 6C5-6RFSXB',
#  'G34200-1212B / 12C5-12RFSXB',
#  'G34170-0606B / 6C5-6RFJXB',
#  'G34170-1212B / 12C5-12RFJXB',
#  'G34170-1616B / 16C5-16RFJXB',
#  'G34210-0404X / 4C5-4RFJSX XBULK',
#  'G34210-0404 / 4C5-4RFJSX',
#  'G34200-0606X / 6C5-6RFSX XBULK',
#  'G34200-0606 / 6C5-6RFSX',
#  'G34210-1010X / 10C5-10RFJSX XBULK',
#  'G34210-1010 / 10C5-10RFJSX',
#  'G34210-0608 / 6C5-8RFJSX',
#  'G34210-1008X / 10C5-8RFJSX XBULK',
#  'G34210-1008 / 10C5-8RFJSX',
#  'G34170-1012 / 10C5-12RFJX',
#  'G34200-1012 / 10C5-12RFSX',
#  'G34540-0606 / 6C5-6RFABX',
#  '4C5-FRL XBULK',
#  'G34170-2020 / 20C5-20RFJX',
#  'G34170-2424 / 24C5-24RFJX',
#  'G34170-3232 / 32C5-32RFJX',
#  'G34170-0606 / 6C5-6RFJX',
#  'G34170-1616 / 16C5-16RFJX',
#  'G34562-1616 / 16C5-16RFZX',
#  'G35180-1212 / 12C5E-12RFJX90',
#  'G35205-1212X / 12C5E-12RFSX90 XBULK',
#  'G35205-1212 / 12C5E-12RFSX90',
#  'G35180-1616 / 16C5E-16RFJX90',
#  'G35180-0606X / 6C5E-6RFJX90 XBULK',
#  'G35180-0606 / 6C5E-6RFJX90',
#  'G35205-0606 / 6C5E-6RFSX90',
#  'G35502-0606 / 6C5E-6RMIX45',
#  'G35504-0505 / 5C5E-5RMIX90',
#  'G35504-0605 / 6C5E-5RMIX90',
#  'G35504-0606 / 6C5E-6RMIX90',
#  'G35504-0808 / 8C5E-8RMIX90',
#  'G35500-0404 / 4C5E-4RMIX',
#  'G35500-0505 / 5C5E-5RMIX',
#  'G35500-0605 / 6C5E-5RMIX',
#  'G35500-0606 / 6C5E-6RMIX',
#  'G35500-0808 / 8C5E-8RMIX',
#  'G35502-0808 / 8C5E-8RMIX45',
#  'G35212-0404X / 4C5E-4RFJSX90 XBULK',
#  'G35212-0404 / 4C5E-4RFJSX90',
#  'G35212-0808 / 8C5E-8RFJSX90',
#  'G35212-1010 / 10C5E-10RFJSX90',
#  'G35180-2020X / 20C5E-20RFJX90 XBULK',
#  'G35180-2020 / 20C5E-20RFJX90',
#  'G35342-2020 / 20C5E-20RFL90S',
#  'G35211-0404 / 4C5E-4RFJSX45',
#  ...]

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import json

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        request_url = f'''https://gates.scene7.com/is/image/{input_.loc[a, 'Asset']}?req=set,json,UTF-8&labelkey=label&handler=s7classics7sdkJSONResponse'''
        
        resp = requests.get(request_url,
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(10, 10))

        if resp.status_code == 200:
            if 'Error while processing Fvctx image' in resp.text and 'Error while processing Fvctx image' in resp.text:
                break
            
            dict_ = json.loads(resp.text.split('s7classics7sdkJSONResponse(')[1].split(',"");')[0])
            if dict_['set']['n'].strip() == input_.loc[a, 'Asset']:
                break
    except KeyboardInterrupt:
        break
    except:
        continue

resp
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# <Response [200]>

# %%
dict_src = {}
if 'Error while processing Fvctx image' in resp.text and 'Error while processing Fvctx image' in resp.text:
    pass
else:
    list_src = [dict_['s']['n'].strip() if 's' in dict_ else dict_['set']['n'] for dict_ in dict_['set']['item']] if type(dict_['set']['item']) == list else [dict_['set']['item']['s']['n'].strip() if 's' in dict_['set']['item'] else dict_['set']['item']['i']['n'].strip()]
    for i, src in enumerate(list_src):
        dict_src[str(i)] = f'''https://gates.scene7.com/is/image/{src}'''

dict_src
# Out:
# {'0': 'https://gates.scene7.com/is/image/gates/mgs-mp-g21100-1-ang-r',
#  '1': 'https://gates.scene7.com/is/image/gates/mgs-mp-g21100-2-sid-r',
#  '2': 'https://gates.scene7.com/is/image/gates/mgs-mp-g21100-3-top-r'}

# %%
df_temp = pd.DataFrame([{'Product No': input_.loc[a, 'Product No'],
                         'Product Name': input_.loc[a, 'Product Name'],
                         'Product Number': input_.loc[a, 'Product Number'],
                         'Country': input_.loc[a, 'Country'],
                         'No': input_.loc[a, 'No'],
                         'Part Number': input_.loc[a, 'Part Number'],
                         'Type': input_.loc[a, 'Type'],
                         'SKU': input_.loc[a, 'SKU'],
                         'UPC': input_.loc[a, 'UPC'],
                         'Title': input_.loc[a, 'Title'],
                         'Picture': '',
                         'Url': input_.loc[a, 'Url'],
                         'Json_Src': json.dumps(dict_src),
                         'Json_Information': input_.loc[a, 'Json_Information'],
                         'Json_Kit': input_.loc[a, 'Json_Kit'],
                         'Part Code': input_.loc[a, 'Part Code'],
                         'Asset': input_.loc[a, 'Asset']}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Product No                                       Product Name  \
# 0           1  1-1/4" Special One-Piece Couplings - Female JI...
#
#        Product Number Country  No                      Part Number  \
# 0  7347-000000-000575      US   1  G21100-2020X / 20MGS-20MP XBULK
#
#                      Type       SKU           UPC  \
# 0  CouplingVariantProduct  73478600  072053974515
#
#                            Title Picture  \
# 0  G21100-2020X 20MGS-20MP XBULK
#
#                                                  Url  \
# 0  https://www.gates.com/us/en/search.p.7347-0000...
#
#                                             Json_Src  \
# 0  {"0": "https://gates.scene7.com/is/image/gates...
#
#                                     Json_Information Json_Kit   Part Code  \
# 0  {"0": {"H1 Stem Hex (in)": "1.75"}, "1": {"H1 ...       {}  7347-08600
#
#                                              Asset
# 0  gates/mm-mgs-male-pipe-nptf-30-cone-seat-g21100

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
    df_temp.loc[0, 'Request_Url'] = request_url
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Product No', 'No'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#    Product No                                       Product Name  \
# 0           1  1-1/4" Special One-Piece Couplings - Female JI...
#
#        Product Number Country  No                      Part Number  \
# 0  7347-000000-000575      US   1  G21100-2020X / 20MGS-20MP XBULK
#
#                      Type       SKU           UPC  \
# 0  CouplingVariantProduct  73478600  072053974515
#
#                            Title Picture  \
# 0  G21100-2020X 20MGS-20MP XBULK
#
#                                                  Url  \
# 0  https://www.gates.com/us/en/search.p.7347-0000...
#
#                                             Json_Src  \
# 0  {"0": "https://gates.scene7.com/is/image/gates...
#
#                                     Json_Information Json_Kit   Part Code  \
# 0  {"0": {"H1 Stem Hex (in)": "1.75"}, "1": {"H1 ...       {}  7347-08600
#
#                                              Asset
# 0  gates/mm-mgs-male-pipe-nptf-30-cone-seat-g21100

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Product No', 'No'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel('./test_part.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
