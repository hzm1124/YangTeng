# %%
import pandas as pd

import os

import json

# = = =  = = =  = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# %%
directory_in = './file/3.part'
list_file = [file for file in sorted(list(os.walk(directory_in))[0][2]) if file not in ['.DS_Store'] and os.path.isfile(os.path.join(directory_in, file))]
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
print('Data Loading...')
list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(os.path.join(directory_in, file),
                                                                       header=0,
                                                                       dtype=str).fillna('')
print('Loading Done !')
print()

df_input = df_input[df_input['Json_Compatibility'] != json.dumps({})].reset_index(drop=True)
df_input['No'] = df_input['No'].astype(int)

crawler_remain = len(df_input)

print(f'总数量：{crawler_remain}')
print()

df_input
# Out:
# Data Loading...
# Loading Done !
#
# 总数量：510
#       No   Item Number                                              Title  \
# 0      1  232315264904  AC A/C Compressor For 2004 2005 2006 Mitsubish...
# 1      2  335513085831  AC A/C Compressor Fits 06-10 Ford Explorer Mer...
# 2      4  235461387733  AC A/C Compressor For 2003-2009 Chevrolet Trai...
# 3      5  334707355204  A/C AC Compressor FOR Toyota Camry For Solara ...
# 4      6  335372891937  AC A/C Compressor for Jeep Grand Cherokee 1993...
# ..   ...           ...                                                ...
# 505  518  256600835779  Fits Toyota Corolla For Matrix 2003-2008 1.8L ...
# 506  519  256681642957  New A/C AC Compressor Clutch Kit Fit for 2007 ...
# 507  520  335625681208  For Suzuki SX4 2.0L 2010-2013 SX4 Crossover 20...
# 508  521  334712574189  Fits Nissan Rouge 08-13 2.5L A/C AC Compressor...
# 509  522  234544398159  AC Compressor Clutch Kits Pulley Bearing Coil ...
#
#              Price Picture                                                Url  \
# 0    US $100.68/ea          https://www.ebay.com/itm/232315264904?_ul=US&_...
# 1    US $111.21/ea          https://www.ebay.com/itm/335513085831?_ul=US&_...
# 2    US $115.79/ea          https://www.ebay.com/itm/235461387733?_ul=US&_...
# 3       US $101.63          https://www.ebay.com/itm/334707355204?_ul=US&_...
# 4    US $118.83/ea          https://www.ebay.com/itm/335372891937?_ul=US&_...
# ..             ...     ...                                                ...
# 505   US $46.95/ea          https://www.ebay.com/itm/256600835779?_ul=US&_...
# 506   US $39.53/ea          https://www.ebay.com/itm/256681642957?_ul=US&_...
# 507   US $41.16/ea          https://www.ebay.com/itm/335625681208?_ul=US&_...
# 508   US $44.25/ea          https://www.ebay.com/itm/334712574189?_ul=US&_...
# 509   US $41.83/ea          https://www.ebay.com/itm/234544398159?_ul=US&_...
#
#     eBay Market Subtitle        Store Name  \
# 0            US           SCITOO-AutoParts
# 1            US           SCITOO-AutoParts
# 2            US           SCITOO-AutoParts
# 3            US           SCITOO-AutoParts
# 4            US           SCITOO-AutoParts
# ..          ...      ...               ...
# 505          US           SCITOO-AutoParts
# 506          US           SCITOO-AutoParts
# 507          US           SCITOO-AutoParts
# 508          US           SCITOO-AutoParts
# 509          US           SCITOO-AutoParts
#
#                                 Store Url  \
# 0    https://www.ebay.com/str/cnbatteries
# 1    https://www.ebay.com/str/cnbatteries
# 2    https://www.ebay.com/str/cnbatteries
# 3    https://www.ebay.com/str/cnbatteries
# 4    https://www.ebay.com/str/cnbatteries
# ..                                    ...
# 505  https://www.ebay.com/str/cnbatteries
# 506  https://www.ebay.com/str/cnbatteries
# 507  https://www.ebay.com/str/cnbatteries
# 508  https://www.ebay.com/str/cnbatteries
# 509  https://www.ebay.com/str/cnbatteries
#
#                                               Json_Src  \
# 0    {"0": "https://i.ebayimg.com/images/g/404AAOSw...
# 1    {"0": "https://i.ebayimg.com/images/g/VxcAAOSw...
# 2    {"0": "https://i.ebayimg.com/images/g/sakAAOSw...
# 3    {"0": "https://i.ebayimg.com/images/g/OIgAAOSw...
# 4    {"0": "https://i.ebayimg.com/images/g/CdYAAOSw...
# ..                                                 ...
# 505  {"0": "https://i.ebayimg.com/images/g/0VoAAOSw...
# 506  {"0": "https://i.ebayimg.com/images/g/7n4AAOSw...
# 507  {"0": "https://i.ebayimg.com/images/g/kVwAAOSw...
# 508  {"0": "https://i.ebayimg.com/images/g/4lkAAOSw...
# 509  {"0": "https://i.ebayimg.com/images/g/mvIAAOSw...
#
#                                        Description Url  \
# 0    https://vi.vipr.ebaydesc.com/itmdesc/232315264...
# 1    https://vi.vipr.ebaydesc.com/itmdesc/335513085...
# 2    https://vi.vipr.ebaydesc.com/itmdesc/235461387...
# 3    https://vi.vipr.ebaydesc.com/itmdesc/334707355...
# 4    https://vi.vipr.ebaydesc.com/itmdesc/335372891...
# ..                                                 ...
# 505  https://vi.vipr.ebaydesc.com/itmdesc/256600835...
# 506  https://vi.vipr.ebaydesc.com/itmdesc/256681642...
# 507  https://vi.vipr.ebaydesc.com/itmdesc/335625681...
# 508  https://vi.vipr.ebaydesc.com/itmdesc/334712574...
# 509  https://vi.vipr.ebaydesc.com/itmdesc/234544398...
#
#                                        Json_Quantity  \
# 0    {"0": "More than 10 available", "1": "89 sold"}
# 1     {"0": "More than 10 available", "1": "4 sold"}
# 2    {"0": "More than 10 available", "1": "39 sold"}
# 3    {"0": "More than 10 available", "1": "14 sold"}
# 4    {"0": "More than 10 available", "1": "15 sold"}
# ..                                               ...
# 505                  {"0": "More than 10 available"}
# 506                  {"0": "More than 10 available"}
# 507                  {"0": "More than 10 available"}
# 508   {"0": "More than 10 available", "1": "2 sold"}
# 509   {"0": "More than 10 available", "1": "1 sold"}
#
#                                             Json_Price  \
# 0    {"0": "Buy 1 for $100.68", "1": "Buy 2 for $98...
# 1    {"0": "Buy 1 for $111.21", "1": "Buy 2 for $10...
# 2    {"0": "Buy 1 for $115.79", "1": "Buy 2 for $11...
# 3                                                   {}
# 4    {"0": "Buy 1 for $118.83", "1": "Buy 2 for $11...
# ..                                                 ...
# 505  {"0": "Buy 1 for $46.95", "1": "Buy 2 for $46....
# 506  {"0": "Buy 1 for $39.53", "1": "Buy 2 for $38....
# 507  {"0": "Buy 1 for $41.16", "1": "Buy 2 for $40....
# 508  {"0": "Buy 1 for $44.25", "1": "Buy 2 for $43....
# 509  {"0": "Buy 1 for $41.83", "1": "Buy 2 for $40....
#
#                                          Json_Specific  \
# 0    {"0": {"Condition": "New: A brand-new, unused,...
# 1    {"0": {"Condition": "New: A brand-new, unused,...
# 2    {"0": {"Condition": "New: A brand-new, unused,...
# 3    {"0": {"Condition": "New: A brand-new, unused,...
# 4    {"0": {"Condition": "New: A brand-new, unused,...
# ..                                                 ...
# 505  {"0": {"Condition": "New: A brand-new, unused,...
# 506  {"0": {"Condition": "New: A brand-new, unused,...
# 507  {"0": {"Condition": "New: A brand-new, unused,...
# 508  {"0": {"Condition": "New: A brand-new, unused,...
# 509  {"0": {"Condition": "New: A brand-new, unused,...
#
#                                     Json_Compatibility
# 0    {"page": 2, "market_place_id": "EBAY-US", "ite...
# 1    {"page": 7, "market_place_id": "EBAY-US", "ite...
# 2    {"page": 5, "market_place_id": "EBAY-US", "ite...
# 3    {"page": 12, "market_place_id": "EBAY-US", "it...
# 4    {"page": 4, "market_place_id": "EBAY-US", "ite...
# ..                                                 ...
# 505  {"page": 2, "market_place_id": "EBAY-US", "ite...
# 506  {"page": 1, "market_place_id": "EBAY-US", "ite...
# 507  {"page": 3, "market_place_id": "EBAY-US", "ite...
# 508  {"page": 2, "market_place_id": "EBAY-US", "ite...
# 509  {"page": 1, "market_place_id": "EBAY-US", "ite...
#
# [510 rows x 16 columns]

# %%
crawler_index, crawler_series = next(df_input.iterrows())

crawler_index, crawler_series
# Out:
# (0,
#  No                                                                    1
#  Item Number                                                232315264904
#  Title                 AC A/C Compressor For 2004 2005 2006 Mitsubish...
#  Price                                                     US $100.68/ea
#  Picture
#  Url                   https://www.ebay.com/itm/232315264904?_ul=US&_...
#  eBay Market                                                          US
#  Subtitle
#  Store Name                                             SCITOO-AutoParts
#  Store Url                          https://www.ebay.com/str/cnbatteries
#  Json_Src              {"0": "https://i.ebayimg.com/images/g/404AAOSw...
#  Description Url       https://vi.vipr.ebaydesc.com/itmdesc/232315264...
#  Json_Quantity           {"0": "More than 10 available", "1": "89 sold"}
#  Json_Price            {"0": "Buy 1 for $100.68", "1": "Buy 2 for $98...
#  Json_Specific         {"0": {"Condition": "New: A brand-new, unused,...
#  Json_Compatibility    {"page": 2, "market_place_id": "EBAY-US", "ite...
#  Name: 0, dtype: object)

# %%
import time

list_dict_correct_temp, dict_ = [], json.loads(crawler_series['Json_Compatibility'])
data = {'scopedContext': {'catalogDetails': {'categoryId': dict_['category_id'],
                                             'itemId': dict_['item_id'],
                                             'marketplaceId': dict_['market_place_id'],
                                             'sellerName': dict_['seller_name']}}}

for page in range(dict_['page']):

    crawler_retry = 0
    while True:
        crawler_retry += 1
        print(page + 1, crawler_retry)
        try:
            url_check = crawler_series['Url']

            resp = requests.post(f'''{dict_['api']}?module_groups=PART_FINDER&referrer=VIEWITEM&offset={page * 20}&module=COMPATIBILITY_TABLE''',
                                 data=json.dumps(data),
                                 headers=get_header(**{'Content-Type': 'application/json; charset=utf-8'}),
                                 proxies=get_proxy(),
                                 timeout=(5, 15))

            if resp.status_code == 200:
                list_header, list_row = [header['textSpans'][0]['text'].strip() for header in resp.json()['modules']['COMPATIBILITY_TABLE']['paginatedTable']['header']['cells']], [[dict_row['textualDisplays'][0]['textSpans'][0]['text'].strip() if 'textualDisplays' in dict_row else dict_row['textSpans'][0]['text'].strip() for dict_row in list_dict_row['cells']] for list_dict_row in resp.json()['modules']['COMPATIBILITY_TABLE']['paginatedTable']['rows']]

                if list_header and list_row:
                    break
        except KeyboardInterrupt:
            break
        except:
            time.sleep(3)
            continue

    # = = =  = = =  = = =

    list_dict_correct_temp_temp = [{'Json_Compatibility': crawler_series['Json_Compatibility'],
                                    'Page': page + 1,
                                    'Row': i + 1} for i in range(len(list_row))]

    for i, row in enumerate(list_row):
        for j, header in enumerate(list_header):
            list_dict_correct_temp_temp[i][header] = row[j]

    list_dict_correct_temp.extend(list_dict_correct_temp_temp)

list_dict_correct_temp
# Out:
# 1 1
# 2 1
# [{'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 1,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 2,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 3,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 4,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 5,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 6,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 7,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 8,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 9,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 10,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 11,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 12,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 13,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 14,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 15,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 16,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 17,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Ralliart Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 18,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 19,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 20,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 1,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 2,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 3,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 4,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 5,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 6,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','}]

# %%
list_dict_correct_temp
# Out:
# [{'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 1,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 2,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 3,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 4,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 5,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 6,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 7,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 8,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 9,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 10,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 11,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 12,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 13,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 14,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 15,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 16,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 17,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Ralliart Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 18,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 19,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 20,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 1,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 2,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 3,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 4,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 5,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 6,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','}]

# %%
list_dict_correct.extend(list_dict_correct_temp)

list_dict_correct
# Out:
# [{'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 1,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 2,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 3,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 4,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 5,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 6,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 7,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'SE Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 8,
#   'Year': '2006',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 9,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 10,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 11,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 12,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 13,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'Limited Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 14,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 15,
#   'Year': '2005',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 16,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Ralliart Sedan 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 17,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Ralliart Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 18,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Lancer',
#   'Trim': 'Sportback Wagon 4-Door',
#   'Engine': '2.4L 2400CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 19,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 1,
#   'Row': 20,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 1,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 2,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ''},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 3,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 4,
#   'Year': '2004',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2378CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 5,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'LS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','},
#  {'Json_Compatibility': '{"page": 2, "market_place_id": "EBAY-US", "item_id": "232315264904", "seller_name": "scitoo-autoparts", "category_id": "33543", "api": "https://www.ebay.com/g/api/finders"}',
#   'Page': 2,
#   'Row': 6,
#   'Year': '2003',
#   'Make': 'Mitsubishi',
#   'Model': 'Outlander',
#   'Trim': 'XLS Sport Utility 4-Door',
#   'Engine': '2.4L 2351CC l4 GAS SOHC Naturally Aspirated',
#   'Notes': ','}]

# %%
crawler_series['Check_Url'] = url_check

list_series_error.append(crawler_series)

list_series_error
# Out:
# [No                                                                    1
#  Item Number                                                232315264904
#  Title                 AC A/C Compressor For 2004 2005 2006 Mitsubish...
#  Price                                                     US $100.68/ea
#  Picture
#  Url                   https://www.ebay.com/itm/232315264904?_ul=US&_...
#  eBay Market                                                          US
#  Subtitle
#  Store Name                                             SCITOO-AutoParts
#  Store Url                          https://www.ebay.com/str/cnbatteries
#  Json_Src              {"0": "https://i.ebayimg.com/images/g/404AAOSw...
#  Description Url       https://vi.vipr.ebaydesc.com/itmdesc/232315264...
#  Json_Quantity           {"0": "More than 10 available", "1": "89 sold"}
#  Json_Price            {"0": "Buy 1 for $100.68", "1": "Buy 2 for $98...
#  Json_Specific         {"0": {"Condition": "New: A brand-new, unused,...
#  Json_Compatibility    {"page": 2, "market_place_id": "EBAY-US", "ite...
#  Check_Url             https://www.ebay.com/itm/232315264904?_ul=US&_...
#  Name: 0, dtype: object]

# %%
print('Data Outputting...')
if list_dict_correct:
    df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['Json_Compatibility', 'Page', 'Row'],
                                                             ascending=[True, True, True],
                                                             ignore_index=True)
    df_correct.to_excel('./test_vehicle.xlsx', index=False)

df_correct if list_dict_correct else ''
# Out:
# Data Outputting...
#                                    Json_Compatibility  Page  Row  Year  \
# 0   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    1  2006
# 1   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    2  2006
# 2   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    3  2006
# 3   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    4  2006
# 4   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    5  2006
# 5   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    6  2006
# 6   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    7  2006
# 7   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    8  2006
# 8   {"page": 2, "market_place_id": "EBAY-US", "ite...     1    9  2005
# 9   {"page": 2, "market_place_id": "EBAY-US", "ite...     1   10  2005
# 10  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   11  2005
# 11  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   12  2005
# 12  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   13  2005
# 13  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   14  2005
# 14  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   15  2005
# 15  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   16  2004
# 16  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   17  2004
# 17  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   18  2004
# 18  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   19  2004
# 19  {"page": 2, "market_place_id": "EBAY-US", "ite...     1   20  2004
# 20  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    1  2004
# 21  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    2  2004
# 22  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    3  2004
# 23  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    4  2004
# 24  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    5  2003
# 25  {"page": 2, "market_place_id": "EBAY-US", "ite...     2    6  2003
#
#           Make      Model                             Trim  \
# 0   Mitsubishi     Lancer            Ralliart Sedan 4-Door
# 1   Mitsubishi  Outlander          LS Sport Utility 4-Door
# 2   Mitsubishi  Outlander          LS Sport Utility 4-Door
# 3   Mitsubishi  Outlander     Limited Sport Utility 4-Door
# 4   Mitsubishi  Outlander     Limited Sport Utility 4-Door
# 5   Mitsubishi  Outlander          SE Sport Utility 4-Door
# 6   Mitsubishi  Outlander          SE Sport Utility 4-Door
# 7   Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 8   Mitsubishi     Lancer            Ralliart Sedan 4-Door
# 9   Mitsubishi  Outlander          LS Sport Utility 4-Door
# 10  Mitsubishi  Outlander          LS Sport Utility 4-Door
# 11  Mitsubishi  Outlander     Limited Sport Utility 4-Door
# 12  Mitsubishi  Outlander     Limited Sport Utility 4-Door
# 13  Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 14  Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 15  Mitsubishi     Lancer            Ralliart Sedan 4-Door
# 16  Mitsubishi     Lancer  Sportback Ralliart Wagon 4-Door
# 17  Mitsubishi     Lancer           Sportback Wagon 4-Door
# 18  Mitsubishi  Outlander          LS Sport Utility 4-Door
# 19  Mitsubishi  Outlander          LS Sport Utility 4-Door
# 20  Mitsubishi  Outlander          LS Sport Utility 4-Door
# 21  Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 22  Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 23  Mitsubishi  Outlander         XLS Sport Utility 4-Door
# 24  Mitsubishi  Outlander          LS Sport Utility 4-Door
# 25  Mitsubishi  Outlander         XLS Sport Utility 4-Door
#
#                                          Engine Notes
# 0   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 1   2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 2   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 3   2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 4   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 5   2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 6   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 7   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 8   2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 9   2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 10  2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 11  2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 12  2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 13  2.4L 2378CC l4 GAS SOHC Naturally Aspirated
# 14  2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 15  2.4L 2400CC l4 GAS SOHC Naturally Aspirated     ,
# 16  2.4L 2400CC l4 GAS SOHC Naturally Aspirated     ,
# 17  2.4L 2400CC l4 GAS SOHC Naturally Aspirated     ,
# 18  2.4L 2351CC l4 GAS SOHC Naturally Aspirated
# 19  2.4L 2351CC l4 GAS SOHC Naturally Aspirated     ,
# 20  2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 21  2.4L 2351CC l4 GAS SOHC Naturally Aspirated
# 22  2.4L 2351CC l4 GAS SOHC Naturally Aspirated     ,
# 23  2.4L 2378CC l4 GAS SOHC Naturally Aspirated     ,
# 24  2.4L 2351CC l4 GAS SOHC Naturally Aspirated     ,
# 25  2.4L 2351CC l4 GAS SOHC Naturally Aspirated     ,

# %%
print('Output Finished !')
print()
# Out:
# Output Finished !

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                           ascending=[True],
                                                           ignore_index=True)
    df_error.to_excel('./test_vehicle_error.xlsx', index=False)
    print('- Error Occurred -')
    print()

df_error if list_series_error else ''
# Out:
# - Error Occurred -
#    No   Item Number                                              Title  \
# 0   1  232315264904  AC A/C Compressor For 2004 2005 2006 Mitsubish...
#
#            Price Picture                                                Url  \
# 0  US $100.68/ea          https://www.ebay.com/itm/232315264904?_ul=US&_...
#
#   eBay Market Subtitle        Store Name  \
# 0          US           SCITOO-AutoParts
#
#                               Store Url  \
# 0  https://www.ebay.com/str/cnbatteries
#
#                                             Json_Src  \
# 0  {"0": "https://i.ebayimg.com/images/g/404AAOSw...
#
#                                      Description Url  \
# 0  https://vi.vipr.ebaydesc.com/itmdesc/232315264...
#
#                                      Json_Quantity  \
# 0  {"0": "More than 10 available", "1": "89 sold"}
#
#                                           Json_Price  \
# 0  {"0": "Buy 1 for $100.68", "1": "Buy 2 for $98...
#
#                                        Json_Specific  \
# 0  {"0": {"Condition": "New: A brand-new, unused,...
#
#                                   Json_Compatibility  \
# 0  {"page": 2, "market_place_id": "EBAY-US", "ite...
#
#                                            Check_Url
# 0  https://www.ebay.com/itm/232315264904?_ul=US&_...

# %%
print('Done ~')
# Out:
# Done ~
