# %%
import os

# %%
list_file = list(os.walk('./menu'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 19

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./menu/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)
        
df = df[['No.', 'Part_Number', 'Name', 'OE', 'Vehicle', 'Pic', 'Date', 'Url', 'Src']]

df.to_excel('./menu.xlsx', index=False)

df
# Out:
# Progress: 100%|████████████████████████████| 19/19 [00:00<00:00, 1498.64it/s]
#     No.           Part_Number                            Name  \
# 0     1  VS-30C002 / B111-021      Coolant(Thermo) Fan Switch
# 1     2  VS-30C004 / B111-022  Water Temperature Sending Unit
# 2     3  VS-30C007 / B111-023  Water Temperature Sending Unit
# 3     4  VS-30C008 / B111-024      Coolant(Thermo) Fan Switch
# 4     5  VS-30D001 / B022-017         Heater Switch Universal
# ..  ...                   ...                             ...
# 3     4  VS-31A023 / B023-018           Neutral Safety Switch
# 4     5  VS-31A024 / B023-019           Neutral Safety Switch
# 5     6  VS-31A025 / B023-020           Neutral Safety Switch
# 6     7  VS-31A026 / B023-021           Neutral Safety Switch
# 7     8  VS-31A029 / B023-022           Neutral Safety Switch
#
#                                                    OE  \
# 0   226300M200;2263043Y00;2263044B10;2263044B20;22...
# 1                        3922035710;MD177572;MD182467
# 2             88975489;88975490;8942206010;8942233030
# 3   37760P00003;37760P00004;37760PHM004;37760PHM00...
# 4                                            88922438
# ..                                                ...
# 3   4671017;4707123;5234319;88923259;88923270;C220...
# 4                                        C4SZ-7A247-A
# 5         88923278;E9TZ7A247C;F1TZ7A247A;F2221;SW2286
# 6   88923277;E9TP7F293AC;E9TZ7A247A;F2220;F5TP7F29...
# 7      12450016;24229422;8124500160;8242294220;D2285A
#
#                                               Vehicle Pic        Date  \
# 0   INFINITI EX35 2008-2012 INFINITI FX35 2003-201...      2008/03/14
# 1   CHRYSLER SEBRING 2001-2005 DODGE STEALTH 1995-...      2009/05/01
# 2   LEXUS CT200H 2011-2017 LEXUS ES300H 2013-2018 ...      2009/08/19
# 3   ACURA CL 1997-2003 ACURA INTEGRA 1992-2001 ACU...      2012/01/11
# 4   FORD COUNTRY SQUIRE.....1990-1991 FORD CROWN V...      2007/11/28
# ..                                                ...  ..         ...
# 3   CHRYSLER CIRRUS 1995 CHRYSLER IMPERIAL 1990-19...      2007/11/28
# 4                        FORD T-BIRD........1965-1966      2007/11/28
# 5   FORD E-150 1990-1996 FORD E-250 1989-1996 FORD...      2007/11/28
# 6   FORD BRONCO 1990-1994 FORD E-150 1990-1999 FOR...      2007/11/28
# 7   CADILLAC ESCALADE 1999-2003 CHEVROLET ASTRO 19...      2007/11/28
#
#                                                   Url  \
# 0   https://www.cubelec.com.tw/other-product-inner...
# 1   https://www.cubelec.com.tw/other-product-inner...
# 2   https://www.cubelec.com.tw/other-product-inner...
# 3   https://www.cubelec.com.tw/other-product-inner...
# 4   https://www.cubelec.com.tw/other-product-inner...
# ..                                                ...
# 3   https://www.cubelec.com.tw/other-product-inner...
# 4   https://www.cubelec.com.tw/other-product-inner...
# 5   https://www.cubelec.com.tw/other-product-inner...
# 6   https://www.cubelec.com.tw/other-product-inner...
# 7   https://www.cubelec.com.tw/other-product-inner...
#
#                                                   Src
# 0   https://www.cubelec.com.tw/product-new/1205487...
# 1   https://www.cubelec.com.tw/product-new/1248062...
# 2   https://www.cubelec.com.tw/product-new/1258538...
# 3   https://www.cubelec.com.tw/product-new/1339397...
# 4   https://www.cubelec.com.tw/product-new/1200306...
# ..                                                ...
# 3   https://www.cubelec.com.tw/product-new/1200302...
# 4   https://www.cubelec.com.tw/product-new/1200302...
# 5   https://www.cubelec.com.tw/product-new/1200302...
# 6   https://www.cubelec.com.tw/product-new/1200302...
# 7   https://www.cubelec.com.tw/product-new/1200302...
#
# [152 rows x 9 columns]
