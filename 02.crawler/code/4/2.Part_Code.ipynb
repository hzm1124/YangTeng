# %%
item = {'sku_count': 1401,
 'page_count': 15,
 'page': 1,
 'page_url': 'https://www.cardone.com/motors/wiper-and-washer/windshield-wiper-motor/?pageSize=96&sort=name&page=1',
 'page_url_2': 'https://cardone.myconvermax.com/search.json?pagesize=96&sort.0.fieldname=name&page=0&referrer=%2Fmotors%2Fwiper-and-washer%2Fwindshield-wiper-motor%2F'}

item
# Out:
# {'sku_count': 1401,
#  'page_count': 15,
#  'page': 1,
#  'page_url': 'https://www.cardone.com/motors/wiper-and-washer/windshield-wiper-motor/?pageSize=96&sort=name&page=1',
#  'page_url_2': 'https://cardone.myconvermax.com/search.json?pagesize=96&sort.0.fieldname=name&page=0&referrer=%2Fmotors%2Fwiper-and-washer%2Fwindshield-wiper-motor%2F'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(item['page_url_2'],
                        headers=generate_header(),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
list_dict = response.json()['Items']

list_dict
# Out:
# [{'_docid': 25025,
#   '_score': 1.4709444,
#   '_rank': 1,
#   'id': '82816',
#   'name': 'Wiper Motor - 40-1000',
#   'sku': '40-1000',
#   'mpn': '40-1000',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 27,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/82816/images/5488626/482__00992.1687973871.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/82816/images/5488628/482__97909.1687973872.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1000',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Camaro 1998-93', 'Pontiac Firebird 1998-93'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"22110039, 22154913","Pontiac":"22110039, 22154913"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 34417,
#   '_score': 1.3932825,
#   '_rank': 2,
#   'id': '92522',
#   'name': 'Wiper Motor - 40-10000',
#   'sku': '40-10000',
#   'mpn': '40-10000',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 1,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92522/images/5527861/482__03679.1687996091.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92522/images/5527868/482__44407.1687996095.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10000',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Hummer H3 2010-06'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Hummer":"15943193"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 32013,
#   '_score': 1.1927998,
#   '_rank': 3,
#   'id': '90033',
#   'name': 'Wiper Motor - 40-10005',
#   'sku': '40-10005',
#   'mpn': '40-10005',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90033/images/5377350/482__02603.1687910967.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90033/images/5377352/482__13827.1687910968.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10005',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac CTS 2015-08, Escalade 2023-15, Escalade ESV 2023-15',
#    'Chevrolet Silverado 1500 2010-07, Silverado 2500 HD 2010-07, Silverado 3500 HD 2010-07, Suburban 2023-15, Suburban 3500 HD 2018-16, Tahoe 2023-15',
#    'GMC Sierra 1500 2010-08, Sierra 2500 HD 2010-08, Sierra 3500 HD 2010-08, Yukon 2023-15, Yukon XL 2023-15'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Honda":"76505SZTG01"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 31733,
#   '_score': 1.1521459,
#   '_rank': 4,
#   'id': '89742',
#   'name': 'Wiper Motor - 40-10006',
#   'sku': '40-10006',
#   'mpn': '40-10006',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/89742/images/5500021/482__12834.1687980090.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/89742/images/5500025/482__09401.1687980090.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10006',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Buick Enclave 2017-08'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Buick":"25795300, 25864153"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 36448,
#   '_score': 1.4086056,
#   '_rank': 5,
#   'id': '94631',
#   'name': 'Wiper Motor - 40-10007',
#   'sku': '40-10007',
#   'mpn': '40-10007',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 3,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/94631/images/5394893/482__85029.1687921043.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/94631/images/5394897/482__64445.1687921045.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10007',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Malibu 2007-05'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"15252854"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 17187,
#   '_score': 1.1956975,
#   '_rank': 6,
#   'id': '74685',
#   'name': 'Wiper Motor - 40-10009',
#   'sku': '40-10009',
#   'mpn': '40-10009',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/74685/images/5509124/482__48296.1687984278.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/74685/images/5509128/482__22221.1687984279.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10009',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Suburban 1500 2000, Suburban 2500 2000',
#    'GMC Yukon XL 1500 2000, Yukon XL 2500 2000'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12463052","GMC":"12463052"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 3554,
#   '_score': 1.3997825,
#   '_rank': 7,
#   'id': '58402',
#   'name': 'Wiper Motor - 40-1001',
#   'sku': '40-1001',
#   'mpn': '40-1001',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 92,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/58402/images/5440944/482__07864.1687944491.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/58402/images/5440946/482__56573.1687944492.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1001',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Prizm 2002-98',
#    'Geo Prizm 1997-93',
#    'Toyota Corolla 2002-98'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Toyota":"8511002051"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 26538,
#   '_score': 1.41447,
#   '_rank': 8,
#   'id': '84377',
#   'name': 'Wiper Motor - 40-10013',
#   'sku': '40-10013',
#   'mpn': '40-10013',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 14,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84377/images/5317225/482__08262.1687881429.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84377/images/5317229/482__41699.1687881430.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10013',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Captiva Sport 2015-08', 'Saturn Vue 2010-08'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"20829042","Saturn":"20829042, 96673024, 96673047"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 22411,
#   '_score': 1.3526124,
#   '_rank': 9,
#   'id': '80106',
#   'name': 'Wiper Motor - 40-10014',
#   'sku': '40-10014',
#   'mpn': '40-10014',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 22,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/80106/images/5437954/482__94977.1687942735.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/80106/images/5437957/482__84597.1687942736.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10014',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Captiva Sport 2010-08', 'Saturn Vue 2010-08'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Saturn":"25963804, 96673001"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 12950,
#   '_score': 1.3797431,
#   '_rank': 10,
#   'id': '69279',
#   'name': 'Wiper Motor - 40-10015',
#   'sku': '40-10015',
#   'mpn': '40-10015',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 2,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/69279/images/5439184/482__07067.1687943391.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/69279/images/5439189/482__66452.1687943393.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10015',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Geo Metro 1994-89', 'Pontiac Firefly 1991, 1994-89'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Geo":"96061630","Pontiac":"96061630"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 32052,
#   '_score': 1.4368538,
#   '_rank': 11,
#   'id': '90072',
#   'name': 'Wiper Motor - 40-10016',
#   'sku': '40-10016',
#   'mpn': '40-10016',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 95,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90072/images/5497337/482__54747.1687978774.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90072/images/5497340/482__14837.1687978775.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10016',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac Escalade 2007-05, Escalade ESV 2007-05, Escalade EXT 2007-05',
#    'Chevrolet Avalanche 1500 2006-05, Avalanche 2007, Avalanche 2500 2006-05, Silverado 1500 2006-05, Silverado 1500 Classic 2007, Silverado 1500 HD 2006-05, Silverado 1500 HD Classic 2007, Silverado 2500 HD 2006-05, Silverado 2500 HD Classic 2007, Silverado 3500 2006-05, Silverado 3500 Classic 2007, Suburban 1500 2007-05, Suburban 2500 2007-05, Tahoe 2007-05',
#    'GMC Sierra 1500 2007-05, Sierra 1500 Classic 2007, Sierra 1500 HD 2006-05, Sierra 1500 HD Classic 2007, Sierra 2500 HD 2007-05, Sierra 2500 HD Classic 2007, Sierra 3500 2006-05, Sierra 3500 Classic 2007, Sierra 3500 HD 2007, Yukon 2007-05, Yukon XL 1500 2007-05, Yukon XL 2500 2007-05'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"88958406","GMC":"88958406","Cadillac":"88958406"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 187,
#   '_score': 1.1742129,
#   '_rank': 12,
#   'id': '53938',
#   'name': 'Wiper Motor - 40-10019',
#   'sku': '40-10019',
#   'mpn': '40-10019',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/53938/images/5324187/482__02413.1687883396.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/53938/images/5324191/482__66732.1687883397.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10019',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Astra 2008', 'Saturn Astra 2008'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"93179057","Saturn":"93179057"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 25536,
#   '_score': 1.3977576,
#   '_rank': 13,
#   'id': '83346',
#   'name': 'Wiper Motor - 40-1002',
#   'sku': '40-1002',
#   'mpn': '40-1002',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 41,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/83346/images/5466104/482__85799.1687959739.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/83346/images/5466106/482__67091.1687959740.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1002',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Buick Regal 1996-94',
#    'Chevrolet Lumina 1994',
#    'Oldsmobile Cutlass Supreme 1997-94',
#    'Pontiac Grand Prix 1996-94'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Oldsmobile":"22138298","Pontiac":"22138298"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 12009,
#   '_score': 1.3735753,
#   '_rank': 14,
#   'id': '68302',
#   'name': 'Wiper Motor - 40-10020',
#   'sku': '40-10020',
#   'mpn': '40-10020',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 19,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/68302/images/5414421/482__97961.1687930769.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/68302/images/5414423/482__58194.1687930770.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10020',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Caprice 2017-13, SS 2017-14',
#    'Pontiac G8 2009-08'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"92273050, 92293743"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 20309,
#   '_score': 1.3493167,
#   '_rank': 15,
#   'id': '77927',
#   'name': 'Wiper Motor - 40-10021',
#   'sku': '40-10021',
#   'mpn': '40-10021',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 5,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/77927/images/5466936/482__01036.1687960225.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/77927/images/5466938/482__14172.1687960226.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10021',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Suzuki Swift+ 2008-07',
#    'Chevrolet Aveo 2018-07',
#    'Pontiac G3 2010-07, Wave 2008-07'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"96648776, 96850001","Pontiac":"96850001"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 20726,
#   '_score': 1.3909224,
#   '_rank': 16,
#   'id': '78364',
#   'name': 'Wiper Motor - 40-10022',
#   'sku': '40-10022',
#   'mpn': '40-10022',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 52,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/78364/images/5501320/482__02680.1687980617.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/78364/images/5501323/482__41623.1687980618.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10022',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Malibu 2012-09',
#    'Pontiac G6 2010-09',
#    'Saturn Aura 2009'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"25895883","Saturn":"25895883","Pontiac":"25895883"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 10801,
#   '_score': 1.105866,
#   '_rank': 17,
#   'id': '67038',
#   'name': 'Wiper Motor - 40-10024',
#   'sku': '40-10024',
#   'mpn': '40-10024',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/67038/images/5517744/482__80725.1687990540.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/67038/images/5517748/482__42498.1687990547.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10024',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Traverse 2015-09'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"15939211, 20989144"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 18563,
#   '_score': 1.2241988,
#   '_rank': 18,
#   'id': '76123',
#   'name': 'Wiper Motor - 40-1003',
#   'sku': '40-1003',
#   'mpn': '40-1003',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76123/images/5462313/482__18687.1687957268.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76123/images/5462315/482__43588.1687957269.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1003',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Astro 2005-94', 'GMC Safari 2005-94'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12368704, 12494840, 15746784, 22121186","GMC":"12368704, 12494840, 15746784, 22121186"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 26180,
#   '_score': 1.3023599,
#   '_rank': 19,
#   'id': '84007',
#   'name': 'Wiper Motor - 40-10034',
#   'sku': '40-10034',
#   'mpn': '40-10034',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 29,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84007/images/5464052/482__48364.1687958350.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84007/images/5464055/482__99274.1687958351.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10034',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac SRX 2016-10'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Cadillac":"25979382"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 27990,
#   '_score': 1.1037985,
#   '_rank': 20,
#   'id': '85873',
#   'name': 'Wiper Motor - 40-10035',
#   'sku': '40-10035',
#   'mpn': '40-10035',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85873/images/5425908/482__33091.1687936836.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85873/images/5425913/482__16706.1687936838.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10035',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac SRX 2015-10'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Cadillac":"15949229"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 20152,
#   '_score': 1.1795692,
#   '_rank': 21,
#   'id': '77760',
#   'name': 'Wiper Motor - 40-10037',
#   'sku': '40-10037',
#   'mpn': '40-10037',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/77760/images/5341772/482__24825.1687891684.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/77760/images/5341774/482__83044.1687891685.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-10037',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Chevy 2012-96'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"22085493"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 21499,
#   '_score': 1.3445629,
#   '_rank': 22,
#   'id': '79162',
#   'name': 'Wiper Motor - 40-1004',
#   'sku': '40-1004',
#   'mpn': '40-1004',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 83,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/79162/images/5501851/482__45091.1687980794.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/79162/images/5501856/482__36845.1687980795.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1004',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Isuzu Hombre 1997-96',
#    'Chevrolet Blazer 1997-95, S10 1997-94',
#    'GMC Jimmy 1997-95, Sonoma 1997-94',
#    'Oldsmobile Bravada 1997-96'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Isuzu":"8221219670"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 34219,
#   '_score': 1.3786639,
#   '_rank': 23,
#   'id': '92320',
#   'name': 'Wiper Motor - 40-1005',
#   'sku': '40-1005',
#   'mpn': '40-1005',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 887,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92320/images/5380799/482__95927.1687912817.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92320/images/5380801/482__18573.1687912818.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1005',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Blazer 2005-95',
#    'GMC Jimmy 2005-95',
#    'Oldsmobile Bravada 2001-96'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12365368, 12494790, 15053983, 22154965","GMC":"12365368, 12494790, 15053983, 22154965"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 15247,
#   '_score': 1.4058235,
#   '_rank': 24,
#   'id': '72081',
#   'name': 'Wiper Motor - 40-1006',
#   'sku': '40-1006',
#   'mpn': '40-1006',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 38,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/72081/images/5407269/482__28058.1687926905.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/72081/images/5407272/482__50887.1687926906.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1006',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Lumina 2001-95, Monte Carlo 1999-95'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"22137807"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 25475,
#   '_score': 1.3076817,
#   '_rank': 25,
#   'id': '83280',
#   'name': 'Wiper Motor - 40-1007',
#   'sku': '40-1007',
#   'mpn': '40-1007',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 1,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/83280/images/5461380/482__85361.1687956729.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/83280/images/5461382/482__70414.1687956731.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1007',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Lumina APV 1996-94, Lumina Van 1996-95',
#    'Oldsmobile Silhouette 1996-94',
#    'Pontiac Trans Sport 1996-94'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Pontiac":"22138775"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 20400,
#   '_score': 1.1490754,
#   '_rank': 26,
#   'id': '78022',
#   'name': 'Wiper Motor - 40-1008',
#   'sku': '40-1008',
#   'mpn': '40-1008',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/78022/images/5328271/482__67653.1687884647.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/78022/images/5328275/482__98433.1687884648.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1008',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Jeep Wrangler 1995-91',
#    'Chevrolet S10 Blazer 1994-89',
#    'GMC Jimmy 1994-92, S15 Jimmy 1991-89, Typhoon 1993-92',
#    'Oldsmobile Bravada 1994-91'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Jeep":"55154539"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 31088,
#   '_score': 1.195174,
#   '_rank': 27,
#   'id': '89076',
#   'name': 'Wiper Motor - 40-1009',
#   'sku': '40-1009',
#   'mpn': '40-1009',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/89076/images/5303264/482__77187.1687877149.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/89076/images/5303268/482__84490.1687877149.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1009',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Astro 2005-97', 'GMC Safari 2005-97'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12362600, 15149302","GMC":"12362600, 15149302"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 27601,
#   '_score': 1.3029518,
#   '_rank': 28,
#   'id': '85471',
#   'name': 'Wiper Motor - 40-101',
#   'sku': '40-101',
#   'mpn': '40-101',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 128,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85471/images/5475914/482__76237.1687966126.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85471/images/5475916/482__27803.1687966128.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-101',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Saturn SC 1992-91, SC1 2000-93, SC2 2000-93, SL 2000-91, SL1 2000-91, SL2 2000-91, SW1 1999-93, SW2 2000-93'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Saturn":"21049032, 21055768"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 8533,
#   '_score': 1.3051476,
#   '_rank': 29,
#   'id': '64690',
#   'name': 'Wiper Motor - 40-1010',
#   'sku': '40-1010',
#   'mpn': '40-1010',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 120,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/64690/images/5373573/482__98372.1687909029.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/64690/images/5373576/482__66132.1687909030.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1010',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Cavalier 1997-95', 'Pontiac Sunfire 1997-95'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12363317","Pontiac":"12363317"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 2811,
#   '_score': 1.2080061,
#   '_rank': 30,
#   'id': '57516',
#   'name': 'Wiper Motor - 40-1011',
#   'sku': '40-1011',
#   'mpn': '40-1011',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/57516/images/5310872/482__92916.1687879623.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/57516/images/5310876/482__63813.1687879624.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1011',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Camaro 2002-99', 'Pontiac Firebird 2002-99'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12363316","Pontiac":"12363316"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 34653,
#   '_score': 1.4142386,
#   '_rank': 31,
#   'id': '92772',
#   'name': 'Wiper Motor - 40-1012',
#   'sku': '40-1012',
#   'mpn': '40-1012',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 834,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92772/images/5302445/482__14425.1687876930.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/92772/images/5302448/482__66936.1687876930.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1012',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Buick Century 2005-97, Regal 2004-97',
#    'Chevrolet Impala 2005-00, Monte Carlo 2005-00',
#    'Oldsmobile Intrigue 2002-98',
#    'Pontiac Grand Prix 2003-97'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Pontiac":"12487575, 12494761, 22144097","Oldsmobile":"12494761, 22144097"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 13166,
#   '_score': 1.3095965,
#   '_rank': 32,
#   'id': '69504',
#   'name': 'Wiper Motor - 40-1013',
#   'sku': '40-1013',
#   'mpn': '40-1013',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 86,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/69504/images/5445432/482__87960.1687946824.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/69504/images/5445433/482__92894.1687946824.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1013',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Isuzu HXR 2006',
#    'Chevrolet C4500 Kodiak 2009-03, C5500 Kodiak 2009-03, C6500 Kodiak 2009-03, C7500 Kodiak 2009-03, C8500 2009-03, Express 1500 2002-96, Express 2500 2002-96, Express 3500 2002-96',
#    'GMC C4500 Topkick 2009-03, C5500 Topkick 2009-03, C6500 Topkick 2009-03, C7500 Topkick 2009-03, C8500 Topkick 2009-03, Savana 1500 2002-96, Savana 2500 2002-96, Savana 3500 2002-96'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Isuzu":"8124875860"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 593,
#   '_score': 1.4147843,
#   '_rank': 33,
#   'id': '54535',
#   'name': 'Wiper Motor - 40-1014',
#   'sku': '40-1014',
#   'mpn': '40-1014',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 79,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/54535/images/5470474/482__34265.1687962673.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/54535/images/5470477/482__94237.1687962674.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1014',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Classic 2005-04, Malibu 2003-97',
#    'Oldsmobile Cutlass 1999-97'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12463095","Oldsmobile":"22154405"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 5872,
#   '_score': 1.372572,
#   '_rank': 34,
#   'id': '61553',
#   'name': 'Wiper Motor - 40-1015',
#   'sku': '40-1015',
#   'mpn': '40-1015',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 71,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/61553/images/5480941/482__54122.1687969797.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/61553/images/5480943/482__09424.1687969797.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1015',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Cavalier 2003-98',
#    'Oldsmobile Alero 2003-99',
#    'Pontiac Grand Am 2003-99, Sunfire 2003-98'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Pontiac":"12365366"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 26912,
#   '_score': 1.1001682,
#   '_rank': 35,
#   'id': '84758',
#   'name': 'Wiper Motor - 40-1016',
#   'sku': '40-1016',
#   'mpn': '40-1016',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84758/images/5412151/482__05004.1687929903.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84758/images/5412155/482__10187.1687929904.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1016',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac Escalade 2000-99',
#    'Chevrolet Blazer 1994-92, C1500 Suburban 1999-92, C2500 Suburban 1999-92, K1500 Suburban 1999-92, K2500 Suburban 1999-92, Tahoe 2000-95',
#    'GMC C1500 Suburban 1999-92, C2500 Suburban 1999-92, K1500 Suburban 1999-92, K2500 Suburban 1999-92, Yukon 2000-92'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"12365396, 22154964","Cadillac":"12365396, 22154964","Oldsmobile":"12365396, 22154964"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 18163,
#   '_score': 1.3733001,
#   '_rank': 36,
#   'id': '75704',
#   'name': 'Wiper Motor - 40-1017',
#   'sku': '40-1017',
#   'mpn': '40-1017',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 5,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
# ...
#   'custom_url': '/product/windshield-wiper-motor-40-1074l',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Buick Rendezvous 2007-02', 'Pontiac Aztek 2005-01'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Buick":"10303632, 10310227","Pontiac":"10303632, 10310227"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 14183,
#   '_score': 1.3784883,
#   '_rank': 86,
#   'id': '70606',
#   'name': 'Wiper Motor - 40-1075L',
#   'sku': '40-1075L',
#   'mpn': '40-1075L',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 67,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/70606/images/5327889/482__56984.1687884534.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/70606/images/5327892/482__99983.1687884535.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1075l',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Isuzu Ascender 2007-05',
#    'Buick Rainier 2006-04',
#    'Chevrolet Blazer 2005-02, Trailblazer 2009-03, Trailblazer EXT 2006-03',
#    'GMC Envoy 2006-03, Envoy XL 2006-03, Envoy XUV 2005-04, Jimmy 2005-02',
#    'Oldsmobile Bravada 2004'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Oldsmobile":"15094705","Isuzu":"8152143440"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 16520,
#   '_score': 1.4428123,
#   '_rank': 87,
#   'id': '73991',
#   'name': 'Wiper Motor - 40-1076L',
#   'sku': '40-1076L',
#   'mpn': '40-1076L',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 397,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/73991/images/5516860/482__29779.1687989787.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/73991/images/5516865/482__89588.1687989788.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1076l',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Isuzu Ascender 2008-05',
#    'Buick Rainier 2007-04',
#    'Chevrolet Blazer 2005-02, Trailblazer 2009-03, Trailblazer EXT 2006-03',
#    'GMC Envoy 2009-03, Envoy XL 2006-03, Envoy XUV 2005-04, Jimmy 2005-02',
#    'Oldsmobile Bravada 2004-03',
#    'Saab 9-7x 2009-05'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Oldsmobile":"15094704","Saab":"15214343","Isuzu":"8152143430"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 27846,
#   '_score': 1.2470783,
#   '_rank': 88,
#   'id': '85722',
#   'name': 'Wiper Motor - 40-1077',
#   'sku': '40-1077',
#   'mpn': '40-1077',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85722/images/5379055/482__60333.1687911738.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/85722/images/5379057/482__47596.1687911740.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1077',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet HHR 2011-06'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"15943776"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 19019,
#   '_score': 1.4118174,
#   '_rank': 89,
#   'id': '76592',
#   'name': 'Wiper Motor - 40-1080',
#   'sku': '40-1080',
#   'mpn': '40-1080',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 41,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76592/images/5330007/482__15705.1687885728.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76592/images/5330011/482__41257.1687885729.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1080',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Buick Lucerne 2011-06',
#    'Cadillac SRX 2009-07',
#    'Pontiac Solstice 2009-07',
#    'Saturn Sky 2010-07'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Buick":"19121120","Cadillac":"19121120, 19177837","Saturn":"19121120","Pontiac":"19121120"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 15278,
#   '_score': 1.3961701,
#   '_rank': 90,
#   'id': '72113',
#   'name': 'Wiper Motor - 40-1081',
#   'sku': '40-1081',
#   'mpn': '40-1081',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 66,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/72113/images/5319570/482__65269.1687882092.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/72113/images/5319573/482__79594.1687882092.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1081',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Equinox 2006-05', 'Pontiac Torrent 2006'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"05480787"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 35152,
#   '_score': 1.3527365,
#   '_rank': 91,
#   'id': '93285',
#   'name': 'Wiper Motor - 40-1082',
#   'sku': '40-1082',
#   'mpn': '40-1082',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 252,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/93285/images/5478121/482__29126.1687967813.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/93285/images/5478123/482__97457.1687967814.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1082',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Suzuki Swift 2008-07, Swift+ 2006-04',
#    'Chevrolet Aveo 2006-04, Aveo5 2008-06',
#    'Pontiac Wave 2008, Wave5 2007-05'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"96543071","Pontiac":"96543071","Suzuki":"96543071"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 26176,
#   '_score': 1.1771432,
#   '_rank': 92,
#   'id': '84003',
#   'name': 'Wiper Motor - 40-1083',
#   'sku': '40-1083',
#   'mpn': '40-1083',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84003/images/5469542/482__09032.1687962072.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/84003/images/5469546/482__36526.1687962073.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1083',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Saturn L300 2004, LW1 2000, LW2 2000, LW200 2003-01, LW300 2003-01'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Saturn":"22664329, 90584925"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 17666,
#   '_score': 1.2210815,
#   '_rank': 93,
#   'id': '75179',
#   'name': 'Wiper Motor - 40-1084',
#   'sku': '40-1084',
#   'mpn': '40-1084',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/75179/images/5292137/482__44121.1687873899.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/75179/images/5292142/482__86374.1687873900.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1084',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Cadillac Escalade 2014-07, Escalade ESV 2014-07',
#    'Chevrolet Suburban 1500 2014-07, Suburban 2500 2013-07, Tahoe 2014-07',
#    'GMC Yukon 2014-07, Yukon XL 1500 2014-07, Yukon XL 2500 2013-07'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"15282187, 25923437","GMC":"15282187, 25923437","Cadillac":"15282187, 25923437"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 33190,
#   '_score': 1.3097662,
#   '_rank': 94,
#   'id': '91251',
#   'name': 'Wiper Motor - 40-1085',
#   'sku': '40-1085',
#   'mpn': '40-1085',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 5,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/91251/images/5522759/482__36604.1687993593.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/91251/images/5522762/482__31086.1687993595.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1085',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['GMC Envoy XUV 2005-04'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"10372434, 15117168, 15761896, 21997632","GMC":"10372434, 15117168, 15761896, 21997632"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 32846,
#   '_score': 1.1912162,
#   '_rank': 95,
#   'id': '90894',
#   'name': 'Wiper Motor - 40-1086',
#   'sku': '40-1086',
#   'mpn': '40-1086',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 0,
#   'total_sold': 0,
#   'out_of_stock': True,
#   'sort_order': 0,
#   'date_created': '2022-05-04T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90894/images/5459937/482__96486.1687955847.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/90894/images/5459940/482__28509.1687955848.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1086',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Chevrolet Metro 2000-98',
#    'Geo Metro 1997-95',
#    'Pontiac Firefly 2000-95'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"91171308","Geo":"91171308","Pontiac":"91171308"}',
#   'FitmentSource': 'pdm'},
#  {'_docid': 19133,
#   '_score': 1.4227908,
#   '_rank': 96,
#   'id': '76708',
#   'name': 'Wiper Motor - 40-1087',
#   'sku': '40-1087',
#   'mpn': '40-1087',
#   'price': 0.0,
#   'original_price': 0.0,
#   'price_usd': 0.0,
#   'price_cad': 0.0,
#   'inventory_level': 19,
#   'total_sold': 0,
#   'sort_order': 0,
#   'date_created': '2022-05-03T00:00:00',
#   'images_image_thumbnail1': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76708/images/5429014/482__68987.1687938393.220.290.jpg?c=1',
#   'images_image_thumbnail2': 'https://cdn11.bigcommerce.com/s-z9vhe3o238/products/76708/images/5429017/482__20474.1687938394.220.290.jpg?c=1',
#   'custom_url': '/product/windshield-wiper-motor-40-1087',
#   'brand_name': 'CARDONE Reman',
#   'brand_url': '/cardone-reman/',
#   'category': ['Motors',
#    'Motors>Wiper and Washer',
#    'Motors>Wiper and Washer>Windshield Wiper Motor'],
#   'category_urls': ['/motors/wiper-and-washer/windshield-wiper-motor/',
#    '/motors/wiper-and-washer/',
#    '/motors/'],
#   'pdm:general_life_cycle_status': 'Available to Order',
#   'Fitment': 'Vehicle Specific',
#   'fitment_summary': ['Suzuki XL-7 2008-07',
#    'Chevrolet Equinox 2008-07',
#    'Pontiac Torrent 2008-07'],
#   'FitmentType': ['None'],
#   'Part_Type': ['Wiper Motor'],
#   'oe_numbers': '{"Chevrolet":"15849819","Pontiac":"15849819","Suzuki":"3810178J00, 3810178J01"}',
#   'FitmentSource': 'pdm'}]

# %%
not list_dict
# Out:
# False

# %%
part_code = list_dict[0]['id']

part_code
# Out:
# '82816'

# %%
{'sku_count': item['sku_count'],
 'page_count': item['page_count'],
 'page': item['page'],
 'page_url': item['page_url'],
 'page_url_2': item['page_url_2'],
 'no': 1,
 'part_code': part_code,
 'part_url': f'https://cardone.myconvermax.com/item.json?key={part_code}',
 'compatibility_url': f'https://cardone.myconvermax.com/ymm/fitments.json?productId={part_code}'}
# Out:
# {'sku_count': 1401,
#  'page_count': 15,
#  'page': 1,
#  'page_url': 'https://www.cardone.com/motors/wiper-and-washer/windshield-wiper-motor/?pageSize=96&sort=name&page=1',
#  'page_url_2': 'https://cardone.myconvermax.com/search.json?pagesize=96&sort.0.fieldname=name&page=0&referrer=%2Fmotors%2Fwiper-and-washer%2Fwindshield-wiper-motor%2F',
#  'no': 1,
#  'part_code': '82816',
#  'part_url': 'https://cardone.myconvermax.com/item.json?key=82816',
#  'compatibility_url': 'https://cardone.myconvermax.com/ymm/fitments.json?productId=82816'}
