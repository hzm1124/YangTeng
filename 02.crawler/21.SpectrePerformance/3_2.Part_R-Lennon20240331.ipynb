# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                resp = requests.get(input_.loc[a, 'Url'],
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                html = etree.HTML(str(soup))
                
                # = = = = = = = = = = = = = = =
                
                title = html.xpath('//span[@data-ui-id="page-title-wrapper"]/text()')[0].strip()
                
                # = = = = = = = = = = = = = = =
                
                sku = html.xpath('//div[@class="product attribute sku"]/div[@class="value"]/text()')[0].strip()
                
                # = = = = = = = = = = = = = = =
                
                src = html.xpath('//meta[@property="og:image"]/@content')[0].strip()
                
                # = = = = = = = = = = = = = = =
                                
                detail = ''
                list_detail = [li.strip() for li in html.xpath('//div[@id="product_details"]/descendant::li/text()')]
                for i in range(len(list_detail)):
                    detail += str(i+1) + '. ' + list_detail[i] + '\n'
                detail = detail.strip()
                
                # = = = = = = = = = = = = = = =
                
                list_tr = html.xpath('//div[@id="specifications"]/descendant::tr')
                
                # = = = = = = = = = = = = = = =

                list_td = html.xpath('//div[@id="cross_references"]/descendant::tr/td')
                
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                                         'Name': input_.loc[a, 'Name'],
                                         'Title': title,
                                         'Sku': sku,
                                         'Detail': detail,
                                         'Vehicle': '',
                                         'Pic': '',
                                         'Url': input_.loc[a, 'Url'],
                                         'Src': src}])
                
                for td in list_td:
                    df_temp.loc[0, 'OE_' + td.xpath('./text()')[0].split(' ')[0].strip()] = ' '.join([text.strip() for text in td.xpath('./text()')[0].split(' ')[1:]])

                for tr in list_tr:
                    df_temp.loc[0, tr.xpath('./td[1]/text()')[0].strip().lower()] = tr.xpath('./td[2]/text()')[0].strip()

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
                
                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                                     'Url': input_.loc[a, 'Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Url'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./part-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./part_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：128
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30578/s/spa-2395-essential-filter/
# [尝试次数：1] - [剩余数量：108] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30589/s/spa-2498-essential-filter/
# [尝试次数：1] - [剩余数量：107] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30602/s/spc-2022-essential-filter/
# [尝试次数：1] - [剩余数量：106] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30599/s/spc-2005-essential-filter/
# [尝试次数：1] - [剩余数量：105] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30597/s/spc-2002-essential-filter/
# [尝试次数：1] - [剩余数量：104] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30596/s/spc-2001-essential-filter/
# [尝试次数：1] - [剩余数量：103] - [当前时间：16:17:27]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30601/s/spc-2013-essential-filter/
# [尝试次数：1] - [剩余数量：102] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30591/s/spc-1001-essential-filter/
# [尝试次数：1] - [剩余数量：101] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30605/s/spc-2040-essential-filter/
# [尝试次数：1] - [剩余数量：100] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30604/s/spc-2038-essential-filter/
# [尝试次数：1] - [剩余数量：99] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30595/s/spc-2000-essential-filter/
# [尝试次数：1] - [剩余数量：98] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30593/s/spc-1011-essential-filter/
# [尝试次数：1] - [剩余数量：97] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30591/s/spc-1001-essential-filter/
# [尝试次数：1] - [剩余数量：96] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30613/s/spc-3013-essential-filter/
# [尝试次数：1] - [剩余数量：95] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30603/s/spc-2033-essential-filter/
# [尝试次数：1] - [剩余数量：94] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30592/s/spc-1010-essential-filter/
# [尝试次数：1] - [剩余数量：93] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30600/s/spc-2007-essential-filter/
# [尝试次数：1] - [剩余数量：92] - [当前时间：16:17:28]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30609/s/spc-2055-essential-filter/
# [尝试次数：1] - [剩余数量：91] - [当前时间：16:17:29]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30612/s/spc-3012-essential-filter/
# [尝试次数：1] - [剩余数量：90] - [当前时间：16:17:29]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30592/s/spc-1010-essential-filter/
# [尝试次数：1] - [剩余数量：89] - [当前时间：16:17:29]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30569/s/spa-2334-essential-filter/
# [尝试次数：1] - [剩余数量：88] - [当前时间：16:17:29]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30611/s/spc-2059-essential-filter/
# [尝试次数：1] - [剩余数量：87] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30608/s/spc-2050-essential-filter/
# [尝试次数：1] - [剩余数量：86] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30610/s/spc-2058-essential-filter/
# [尝试次数：1] - [剩余数量：85] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30598/s/spc-2003-essential-filter/
# [尝试次数：1] - [剩余数量：84] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30607/s/spc-2049-essential-filter/
# [尝试次数：1] - [剩余数量：83] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30571/s/spa-2360-essential-filter/
# [尝试次数：1] - [剩余数量：82] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30568/s/spa-2326-essential-filter/
# [尝试次数：1] - [剩余数量：81] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30577/s/spa-2394-essential-filter/
# [尝试次数：1] - [剩余数量：80] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30567/s/spa-2309-essential-filter/
# [尝试次数：1] - [剩余数量：79] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30594/s/spc-1012-essential-filter/
# [尝试次数：1] - [剩余数量：78] - [当前时间：16:17:30]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30574/s/spa-2374-essential-filter/
# [尝试次数：1] - [剩余数量：77] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30538/s/spa-0784-essential-filter/
# [尝试次数：1] - [剩余数量：76] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30581/s/spa-2439-essential-filter/
# [尝试次数：1] - [剩余数量：75] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30570/s/spa-2342-essential-filter/
# [尝试次数：1] - [剩余数量：74] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30579/s/spa-2402-essential-filter/
# [尝试次数：1] - [剩余数量：73] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30584/s/spa-2460-essential-filter/
# [尝试次数：1] - [剩余数量：72] - [当前时间：16:17:31]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30576/s/spa-2385-essential-filter/
# [尝试次数：1] - [剩余数量：71] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30572/s/spa-2364-essential-filter/
# [尝试次数：1] - [剩余数量：70] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30583/s/spa-2457-essential-filter/
# [尝试次数：1] - [剩余数量：69] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30590/s/spa-2966-essential-filter/
# [尝试次数：1] - [剩余数量：68] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30573/s/spa-2370-essential-filter/
# [尝试次数：1] - [剩余数量：67] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30586/s/spa-2468-essential-filter/
# [尝试次数：1] - [剩余数量：66] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30542/s/spa-2031-essential-filter/
# [尝试次数：1] - [剩余数量：65] - [当前时间：16:17:32]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30580/s/spa-2409-essential-filter/
# [尝试次数：1] - [剩余数量：64] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30606/s/spc-2044-essential-filter/
# [尝试次数：1] - [剩余数量：63] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30582/s/spa-2448-essential-filter/
# [尝试次数：1] - [剩余数量：62] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30585/s/spa-2462-essential-filter/
# [尝试次数：1] - [剩余数量：61] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30563/s/spa-2286-essential-filter/
# [尝试次数：1] - [剩余数量：60] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30587/s/spa-2472-essential-filter/
# [尝试次数：1] - [剩余数量：59] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30588/s/spa-2478-essential-filter/
# [尝试次数：1] - [剩余数量：58] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30575/s/spa-2381-essential-filter/
# [尝试次数：1] - [剩余数量：57] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30549/s/spa-2141-essential-filter/
# [尝试次数：1] - [剩余数量：56] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30545/s/spa-2084-essential-filter/
# [尝试次数：1] - [剩余数量：55] - [当前时间：16:17:33]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30551/s/spa-2145-essential-filter/
# [尝试次数：1] - [剩余数量：54] - [当前时间：16:17:34]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30543/s/spa-2042-essential-filter/
# [尝试次数：1] - [剩余数量：53] - [当前时间：16:17:34]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30544/s/spa-2063-essential-filter/
# [尝试次数：1] - [剩余数量：52] - [当前时间：16:17:34]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30552/s/spa-2181-essential-filter/
# [尝试次数：1] - [剩余数量：51] - [当前时间：16:17:34]
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30550/s/spa-2144-essential-filter/
# [尝试次数：1] - [剩余数量：50] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30555/s/spa-2206-essential-filter/
# [尝试次数：1] - [剩余数量：49] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30539/s/spa-0945-essential-filter/
# [尝试次数：1] - [剩余数量：48] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30541/s/spa-2012-essential-filter/
# [尝试次数：1] - [剩余数量：47] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30546/s/spa-2106-essential-filter/
# [尝试次数：1] - [剩余数量：46] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30548/s/spa-2129-essential-filter/
# [尝试次数：1] - [剩余数量：45] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30567/s/spa-2309-essential-filter/
# [尝试次数：1] - [剩余数量：44] - [当前时间：16:17:35]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30560/s/spa-2260-essential-filter/
# [尝试次数：1] - [剩余数量：43] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30577/s/spa-2394-essential-filter/
# [尝试次数：1] - [剩余数量：42] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30553/s/spa-2187-essential-filter/
# [尝试次数：1] - [剩余数量：41] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30561/s/spa-2276-essential-filter/
# [尝试次数：1] - [剩余数量：40] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30568/s/spa-2326-essential-filter/
# [尝试次数：1] - [剩余数量：39] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30540/s/spa-1009-essential-filter/
# [尝试次数：1] - [剩余数量：38] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30564/s/spa-2287-essential-filter/
# [尝试次数：1] - [剩余数量：37] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30566/s/spa-2304-essential-filter/
# [尝试次数：1] - [剩余数量：36] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30559/s/spa-2252-essential-filter/
# [尝试次数：1] - [剩余数量：35] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30557/s/spa-2247-essential-filter/
# [尝试次数：1] - [剩余数量：34] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30554/s/spa-2192-essential-filter/
# [尝试次数：1] - [剩余数量：33] - [当前时间：16:17:36]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30562/s/spa-2281-essential-filter/
# [尝试次数：1] - [剩余数量：32] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30565/s/spa-2295-essential-filter/
# [尝试次数：1] - [剩余数量：31] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30569/s/spa-2334-essential-filter/
# [尝试次数：1] - [剩余数量：30] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30558/s/spa-2249-essential-filter/
# [尝试次数：1] - [剩余数量：29] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30570/s/spa-2342-essential-filter/
# [尝试次数：1] - [剩余数量：28] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30581/s/spa-2439-essential-filter/
# [尝试次数：1] - [剩余数量：27] - [当前时间：16:17:37]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30579/s/spa-2402-essential-filter/
# [尝试次数：1] - [剩余数量：26] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30586/s/spa-2468-essential-filter/
# [尝试次数：1] - [剩余数量：25] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30590/s/spa-2966-essential-filter/
# [尝试次数：1] - [剩余数量：24] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30575/s/spa-2381-essential-filter/
# [尝试次数：1] - [剩余数量：23] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30587/s/spa-2472-essential-filter/
# [尝试次数：1] - [剩余数量：22] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30545/s/spa-2084-essential-filter/
# [尝试次数：1] - [剩余数量：21] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30547/s/spa-2121-essential-filter/
# [尝试次数：1] - [剩余数量：20] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30571/s/spa-2360-essential-filter/
# [尝试次数：1] - [剩余数量：19] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30574/s/spa-2374-essential-filter/
# [尝试次数：1] - [剩余数量：18] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30576/s/spa-2385-essential-filter/
# [尝试次数：1] - [剩余数量：17] - [当前时间：16:17:38]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30542/s/spa-2031-essential-filter/
# [尝试次数：1] - [剩余数量：16] - [当前时间：16:17:39]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30549/s/spa-2141-essential-filter/
# [尝试次数：1] - [剩余数量：15] - [当前时间：16:17:39]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30588/s/spa-2478-essential-filter/
# [尝试次数：1] - [剩余数量：14] - [当前时间：16:17:39]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30580/s/spa-2409-essential-filter/
# [尝试次数：1] - [剩余数量：13] - [当前时间：16:17:39]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30563/s/spa-2286-essential-filter/
# [尝试次数：1] - [剩余数量：12] - [当前时间：16:17:39]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30538/s/spa-0784-essential-filter/
# [尝试次数：1] - [剩余数量：11] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30584/s/spa-2460-essential-filter/
# [尝试次数：1] - [剩余数量：10] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30544/s/spa-2063-essential-filter/
# [尝试次数：1] - [剩余数量：9] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30572/s/spa-2364-essential-filter/
# [尝试次数：1] - [剩余数量：8] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30585/s/spa-2462-essential-filter/
# [尝试次数：1] - [剩余数量：7] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30556/s/spa-2207-essential-filter/
# [尝试次数：1] - [剩余数量：6] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30552/s/spa-2181-essential-filter/
# [尝试次数：1] - [剩余数量：5] - [当前时间：16:17:40]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30539/s/spa-0945-essential-filter/
# [尝试次数：1] - [剩余数量：4] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30547/s/spa-2121-essential-filter/
# [尝试次数：1] - [剩余数量：3] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30548/s/spa-2129-essential-filter/
# [尝试次数：1] - [剩余数量：2] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30582/s/spa-2448-essential-filter/
# [尝试次数：1] - [剩余数量：1] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30543/s/spa-2042-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30551/s/spa-2145-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30556/s/spa-2207-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30554/s/spa-2192-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30540/s/spa-1009-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30550/s/spa-2144-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:41]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30559/s/spa-2252-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30553/s/spa-2187-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30555/s/spa-2206-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30573/s/spa-2370-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30561/s/spa-2276-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30560/s/spa-2260-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:42]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30562/s/spa-2281-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:43]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30564/s/spa-2287-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:43]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30557/s/spa-2247-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:43]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30558/s/spa-2249-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:43]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30565/s/spa-2295-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:44]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30583/s/spa-2457-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:44]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30566/s/spa-2304-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:17:45]
#
# [ok] - https://www.spectreperformance.com/catalog/product/view/id/30541/s/spa-2012-essential-filter/
# [尝试次数：1] - [剩余数量：0] - [当前时间：16:18:09]
#
# 输出ing...
#
# Done ~
