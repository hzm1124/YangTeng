# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../../00.module')
import Proxy

# = = = = = = = = = = = = = = =

import pandas as pd

df = pd.read_excel('./1.make.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_make = df['Make'].tolist()

print('总数量：' + str(len(list_make)))
print()

# = = = = = = = = = = = = = = =

df = pd.DataFrame()

# = = = = = = = = = = = = = = =

from urllib.parse import quote
import requests
import json

from bs4 import BeautifulSoup

from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for make in list_make:
    work.put_nowait(make)

def crawler():
    global df
    
    while not work.empty():
        make = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(31):
            try:
                data = 'func=navnode_fetch&payload=' + quote('{"jsn":{"tab":"catalog","make":"') + make.replace(' ', '+') + quote('","nodetype":"make"}}') + '&api_json_request=1&sctchecked=1&scbeenloaded=true&curCartGroupID='

                resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                     data=data,
                                     headers={'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8'},
                                     proxies=Proxy.get_Proxy_Requests()).text

                resp = json.loads(resp)
                
                # = = = = = = = = = = = = = = =
                
                html = resp['html_fill_sections']['navchildren[]']
                
                soup = BeautifulSoup(html, 'lxml')
                
                # = = = = = = = = = = = = = = =
                
                html = etree.HTML(str(soup))

                list_year = html.xpath('//td[@class="nlabel"]/a/text()')
                
                # = = = = = = = = = = = = = = =
                
                list_url = html.xpath('//td[@class="niconspace ncollapsedicon"]/a/@href')

                list_url = ['https://www.rockauto.com'+_ for _ in list_url]
                
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame({'status': 'ok',
                                        'Make': make,
                                        'Year': list_year,
                                        'Url': list_url})
                
                status = 'ok'
                
                break
                
            except:
                time.sleep(1)
                continue

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'Make': make}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        print(make +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df = df.drop_duplicates(ignore_index=True)

print()
print('爬虫输出中')
df.to_excel('./year_' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
print()
print('爬虫结束')
# Out:
# 总数量：267
#
# ARNOLT-MG  <->  [ok] - 剩余数量：247
# ASTON MARTIN  <->  [ok] - 剩余数量：246
# ALLSTATE  <->  [ok] - 剩余数量：245
# ABARTH  <->  [ok] - 剩余数量：244
# ARNOLT-BRISTOL  <->  [ok] - 剩余数量：243
# AC  <->  [ok] - 剩余数量：242
# AMERICAN AUSTIN  <->  [ok] - 剩余数量：241
# AMERICAN BANTAM  <->  [ok] - 剩余数量：240
# AMERICAN MOTORS  <->  [ok] - 剩余数量：239
# AM GENERAL  <->  [ok] - 剩余数量：238
# APOLLO  <->  [ok] - 剩余数量：237
# ASUNA  <->  [ok] - 剩余数量：236
# AMPHICAR  <->  [ok] - 剩余数量：235
# BAIC  <->  [ok] - 剩余数量：234
# ALFA ROMEO  <->  [ok] - 剩余数量：233
# ALPINE  <->  [ok] - 剩余数量：232
# ALLARD  <->  [ok] - 剩余数量：231
# BORGWARD  <->  [ok] - 剩余数量：230
# ARMSTRONG-SIDDELEY  <->  [ok] - 剩余数量：229
# BRICKLIN  <->  [ok] - 剩余数量：228
# BMW  <->  [ok] - 剩余数量：227
# BUGATTI  <->  [ok] - 剩余数量：226
# BUICK  <->  [ok] - 剩余数量：225
# BOND  <->  [ok] - 剩余数量：224
# AUSTIN  <->  [ok] - 剩余数量：223
# BERKELEY  <->  [ok] - 剩余数量：222
# CADILLAC  <->  [ok] - 剩余数量：221
# BRISTOL  <->  [ok] - 剩余数量：220
# CHEVROLET  <->  [ok] - 剩余数量：219
# CASE  <->  [ok] - 剩余数量：218
# CHIREY  <->  [ok] - 剩余数量：217
# ALVIS  <->  [ok] - 剩余数量：216
# CHECKER  <->  [ok] - 剩余数量：215
# KeyboardInterrupt
# 2023-11-21T06:47:37Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 115
#     113     task = gevent.spawn(crawler)
#     114     list_task.append(task)
# --> 115 gevent.joinall(list_task)
#     117 df = df.drop_duplicates(ignore_index=True)
#     119 print()
#
# File src/gevent/greenlet.py:1065, in gevent._gevent_cgreenlet.joinall()
#
# File src/gevent/greenlet.py:1075, in gevent._gevent_cgreenlet.joinall()
#
# File src/gevent/_hub_primitives.py:250, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src/gevent/_hub_primitives.py:287, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src/gevent/_hub_primitives.py:185, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src/gevent/_hub_primitives.py:176, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src/gevent/_waiter.py:195, in gevent._gevent_c_waiter.MultipleWaiter.get()
#
# File src/gevent/_waiter.py:154, in gevent._gevent_c_waiter.Waiter.get()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:65, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_gevent_c_greenlet_primitives.pxd:35, in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# KeyboardInterrupt:
# AUDI  <->  [ok] - 剩余数量：214
