# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

from openpyxl import load_workbook
import requests
from io import BytesIO
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter
import time

# = = = = = = = = = = = = = = = = = =

wb = load_workbook('./crawler.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        index_src = column
    elif ws.cell(1, column).value == 'Pic':
        index_pic = column
        
print('Src索引：' + str(index_src))
print('Pic索引：' + str(index_pic))
print()

work = Queue()
for row in range(2, ws.max_row+1):
    work.put_nowait(row)

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818',
           'https': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818'}
    
# = = = = = = = = = = = = = = = = = =

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        
        src = ws.cell(row, index_src).value
        
        status = 'error'
        for _ in range(31):
            if src == None or src == '':
                break
                
            try:
                pic = Image(BytesIO(requests.get(src, proxies=proxies).content))
                
                
                
                # = = = = = = = = = = = = = = = = = =
                
                if pic.width >= pic.height:
                    pic.height = 50.0 / pic.width * pic.height
                    pic.width = 50.0
                else:
                    pic.width = 50.0 / pic.height * pic.width
                    pic.height = 50.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                status = 'ok'
                ws.add_image(pic, get_column_letter(index_pic) + str(row))
            
                break
            
            except:
                time.sleep(3)
                continue
                
        # = = = = = = = = = = = = = = = = = =
        
        if src != None and src != '':
            print(src +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

wb.save('./crawler-pic.xlsx')
print()
print('搞定')
# Out:
# Src索引：6
# Pic索引：5
#
# https://m.media-amazon.com/images/I/81MeyB1I8lL.__AC_SY300_SX300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：80
# https://m.media-amazon.com/images/I/71C70pnLApL._AC_SX466_.jpg  <->  [ok] - 剩余数量：79
# https://m.media-amazon.com/images/I/616fvbs05mL._AC_SX466_.jpg  <->  [ok] - 剩余数量：78
# https://m.media-amazon.com/images/I/91KaykKEAqL._AC_SX466_.jpg  <->  [ok] - 剩余数量：77
# https://m.media-amazon.com/images/I/71PpS6e2v+L._AC_SX466_.jpg  <->  [ok] - 剩余数量：76
# https://m.media-amazon.com/images/I/71QH33mv0sL._AC_SX466_.jpg  <->  [ok] - 剩余数量：75
# https://m.media-amazon.com/images/I/61CZzaEDNlL._AC_SX466_.jpg  <->  [ok] - 剩余数量：74
# https://m.media-amazon.com/images/I/51+JPW1zjfL._AC_SX300_SY300_.jpg  <->  [ok] - 剩余数量：73
# https://m.media-amazon.com/images/I/51D3G1kCvxL._AC_SX522_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：72
# https://m.media-amazon.com/images/I/71ADEM4bOQL._AC_SX466_.jpg  <->  [ok] - 剩余数量：71
# https://m.media-amazon.com/images/I/81mO6b3U74L._AC_SX466_.jpg  <->  [ok] - 剩余数量：70
# https://m.media-amazon.com/images/I/812lHpLkWNL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量
# https://m.media-amazon.com/images/I/71CL7nBtS2L._AC_SX466_.jpg  <->  [ok] - 剩余数量：7
# https://m.media-amazon.com/images/I/619XkQSFgkL._AC_SX466_.jpg  <->  [ok] - 剩余数量：6
# https://m.media-amazon.com/images/I/412lPjdykfL._AC_SX466_.jpg  <->  [ok] - 剩余数量：5
# https://m.media-amazon.com/images/I/61w50Ac2OhL._AC_SX466_.jpg  <->  [ok] - 剩余数量：4
# https://m.media-amazon.com/images/I/61W-up93D6L._AC_SX466_.jpg  <->  [ok] - 剩余数量：3
# https://m.media-amazon.com/images/I/811IQF36+xL._AC_SX466_.jpg  <->  [ok] - 剩余数量：2
# https://m.media-amazon.com/images/I/61f+wGH9VdL._AC_SX466_.jpg  <->  [ok] - 剩余数量：1
# https://m.media-amazon.com/images/I/81wlPdfubpL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/51S9OSM4dxL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71Dek-O8n8L._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61bk-HnRB7L._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/81FSX+hhUKL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71v9SPbsA7L._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61Fi5Jh0EzL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71jyu8Vw7sL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/51NY9HQD6JL.__AC_SY300_SX300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61j7uMNyhKL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61flnA4GQTL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/51WwDqu7BlL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61mG06AtZ+S._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61HgATFN2aL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/617AB+gkCgL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71lMUALq6DL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71PCx4ugCYL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61lQXXDFG1L._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/614ILZ+t2dL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71DmS9H6t-L._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 92
#      89     list_task.append(task)
#      90 gevent.joinall(list_task)
# ---> 92 wb.save('./crawler-pic.xlsx')
#      93 print()
#      94 print('搞定')
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.utcnow()
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/writer/excel.py:94, in ExcelWriter.write_data(self)
#      90 archive.writestr(ARC_WORKBOOK_RELS, writer.write_rels())
#      92 self._merge_vba()
# ---> 94 self.manifest._write(archive, self.workbook)
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/packaging/manifest.py:165, in Manifest._write(self, archive, workbook)
#     163 self.append(workbook)
#     164 self._write_vba(workbook)
# --> 165 self._register_mimetypes(filenames=archive.namelist())
#     166 archive.writestr(self.path, tostring(self.to_tree()))
#
# File ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/openpyxl/packaging/manifest.py:177, in Manifest._register_mimetypes(self, filenames)
#     175 if not ext:
#     176     continue
# --> 177 mime = mimetypes.types_map[True][ext]
#     178 fe = FileExtension(ext[1:], mime)
#     179 self.Default.append(fe)
#
# KeyError: '.webp'
