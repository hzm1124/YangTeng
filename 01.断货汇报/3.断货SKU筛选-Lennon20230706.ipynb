# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20231024.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate,
                   sheet_name='附_1统计源（含新品、清仓、新品成长）',
                   header=3,
                   usecols=[2, 3, 5, 11, 12])

df
# Out:
#                  MRP SKU  目标\n周销 Level   在库   在途
# 0      USTCV17215HIE-2-C   44.89  TOP1  181  222
# 1          USWP51040WH-C   30.23  TOP1   59  102
# 2         USBDA04108-2-C   25.83    普通  172  111
# 3           USFIK50300-C   28.40  TOP1   24   22
# 4           USET87039H-C   20.64  TOP1   61  265
# ...                  ...     ...   ...  ...  ...
# 60788       USDLA54516-C    0.33    普通    1    4
# 60789    USEAF69000R-2-C    0.50    普通    2    0
# 60790        USWR78870-C    0.17    普通    3    0
# 60791       USAST50151-C    0.75    普通    2    5
# 60792       USCPS31400-C    0.75    普通    6    4
#
# [60793 rows x 5 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU',
                                                                   'Level',
                                                                   '目标\n周销',
                                                                   '在途']]

df
# Out:
#              MRP SKU  Level  目标\n周销  在途
# 333        USSM93573  TOP20    2.24   0
# 503     USABS44600-C  TOP20    5.10   0
# 588     USBHH04621-C  TOP10    3.30   0
# 1015    USEM0MA002-C  TOP10    2.44   0
# 1040    USEM0DO004-C  TOP20    2.51   0
# ...              ...    ...     ...  ..
# 53687  USACC29104-C1  TOP10    2.38   0
# 54009  USWP51040TH-C  TOP10   15.85   0
# 55104   USSCS25272-C  TOP20    0.63   0
# 55691   USRAD71122-C  TOP10    1.70   0
# 60701   USWR48974S-C  TOP20    0.27   0
#
# [191 rows x 4 columns]

# %%
df = df.sort_values(by=['Level', 'MRP SKU'], ascending=[True, True])

df
# Out:
#               MRP SKU  Level  目标\n周销  在途
# 25941  USACC06390S-C1   TOP1    2.55   0
# 9920    USACC11340-C1   TOP1    1.41   0
# 35067   USACC29221-C1   TOP1    3.61   0
# 35107   USACC30011-C1   TOP1    1.07   0
# 35070   USACC32024-C1   TOP1    2.98   0
# ...               ...    ...     ...  ..
# 11117     USWP03071-C  TOP20    0.33   0
# 7652        USWR41685  TOP20    1.70   0
# 60701    USWR48974S-C  TOP20    0.27   0
# 26003       USWR49322  TOP20    1.27   0
# 4721       USWSL66409  TOP20    2.55   0
#
# [191 rows x 4 columns]

# %%
import datetime

# %%
writer = pd.ExcelWriter('Lennon_筛选好的断货SKU_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.xlsx')
df.to_excel(writer, index=False)
writer.close()
