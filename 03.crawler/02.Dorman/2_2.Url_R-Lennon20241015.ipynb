# %%
from gevent import monkey
monkey.patch_all(thread=False)

from gevent.pool import Pool
pool = Pool(5)

from gevent.lock import BoundedSemaphore
semaphore_error, semaphore_remain = BoundedSemaphore(1), BoundedSemaphore(1)

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

directory_out = './file/2.url'

if os.path.exists(directory_out):
    shutil.rmtree(directory_out)
os.makedirs(directory_out)

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

# = = = = = = = = = = = = = = =

list_series_error, df_input = [], pd.read_excel('./file/1.page.xlsx',
                                                header=0,
                                                dtype=str).fillna('')

df_input['No'] = df_input['No'].astype(int)
df_input['SKU Count'] = df_input['SKU Count'].astype(int)
df_input['Page'] = df_input['Page'].astype(int)

count_remain = len(df_input)

print(f'总数量：{count_remain}')
print()

# = = = = = = = = = = = = = = =

def crawler(crawler_tuple):
    global list_series_error, count_remain

    (crawler_index, crawler_series) = crawler_tuple

    # = = = = = = = = = = = = = = =

    try:
        count_cycle, list_url = 0, []
        while len(list_url) < crawler_series['SKU Count']:
            count_cycle += 1

            for page in range(crawler_series['Page']):

                count_retry = 0
                while True:
                    count_retry += 1

                    try:
                        url_request = f'''{crawler_series['Url']}&num=100&start={page * 100}'''

                        resp = requests.get(url_request,
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(5, 15))

                        if resp.status_code == 200:
                            soup = BeautifulSoup(resp.text, 'lxml')
                            html = etree.HTML(str(soup))

                            list_href = html.xpath('//h2[@class="item-headline"]/a/@href')
                            if list_href:
                                break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                list_url += [f'https://www.dormanproducts.com/{href.strip()}' for href in list_href]
                list_url = sorted(list(set(list_url)), key=list_url.index)

                # = = = = = = = = = = = = = = =

                if count_remain % 30 == 0 and count_remain != 0:
                    clear_output()
                print(f'''[第{count_cycle}轮] - [第{page + 1}页] - [请求{count_retry}次] - [{len(list_url)}/{crawler_series['SKU Count']}] - [剩余{count_remain - 1}条] - [{datetime.now().strftime('%Y/%m/%d %H:%M:%S')}] - {crawler_series['No']}. {url_request}\n''')

                # = = = = = = = = = = = = = = =

                if len(list_url) == crawler_series['SKU Count']:
                    break

        # = = = = = = = = = = = = = = =

        df_correct = pd.DataFrame({'No': range(1, len(list_url) + 1),
                                   'Url': list_url})
        df_correct.to_excel(f'''{directory_out}/crawler_{crawler_series['No']}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    except:
        crawler_series['Request_Url'] = url_request

        with semaphore_error:
            list_series_error.append(crawler_series)

    # = = = = = = = = = = = = = = =

    with semaphore_remain:
        count_remain -= 1

# = = = = = = = = = = = = = = =

pool.map(crawler, df_input.iterrows())

print('输出ing...')
print()
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                           ascending=[True],
                                                           ignore_index=True)
    output_error.to_excel('./file/url_error.xlsx', index=False)
    print('爬虫存在error')
    print()

# = = = = = = = = = = = = = = =

list_file = [file for file in sorted(list(os.walk(directory_out))[0][2]) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_out}/{file}')]
for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'{directory_out}/{file}',
              f'''{directory_out}/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：2
#
# [第1轮] - [第1页] - [请求2次] - [100/1091] - [剩余1条] - [2024/10/15 18:24:09] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=0
#
# [第1轮] - [第2页] - [请求1次] - [200/1091] - [剩余1条] - [2024/10/15 18:24:14] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=100
#
# [第1轮] - [第1页] - [请求1次] - [100/1220] - [剩余1条] - [2024/10/15 18:24:21] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=0
#
# [第1轮] - [第3页] - [请求1次] - [290/1091] - [剩余1条] - [2024/10/15 18:24:41] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=200
#
# [第1轮] - [第4页] - [请求1次] - [390/1091] - [剩余1条] - [2024/10/15 18:25:10] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=300
#
# [第1轮] - [第5页] - [请求1次] - [490/1091] - [剩余1条] - [2024/10/15 18:25:19] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=400
#
# [第1轮] - [第6页] - [请求1次] - [590/1091] - [剩余1条] - [2024/10/15 18:25:28] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=500
#
# [第1轮] - [第7页] - [请求1次] - [690/1091] - [剩余1条] - [2024/10/15 18:25:35] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=600
#
# [第1轮] - [第2页] - [请求1次] - [200/1220] - [剩余1条] - [2024/10/15 18:25:38] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=100
#
# [第1轮] - [第8页] - [请求1次] - [790/1091] - [剩余1条] - [2024/10/15 18:25:42] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=700
#
# [第1轮] - [第9页] - [请求1次] - [890/1091] - [剩余1条] - [2024/10/15 18:25:47] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=800
#
# [第1轮] - [第3页] - [请求1次] - [300/1220] - [剩余1条] - [2024/10/15 18:25:50] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=200
#
# [第1轮] - [第10页] - [请求1次] - [990/1091] - [剩余1条] - [2024/10/15 18:25:52] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=900
#
# [第1轮] - [第11页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:26:27] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=1000
#
# [第1轮] - [第4页] - [请求2次] - [400/1220] - [剩余1条] - [2024/10/15 18:26:32] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=300
#
# [第1轮] - [第5页] - [请求1次] - [500/1220] - [剩余1条] - [2024/10/15 18:26:53] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=400
#
# [第2轮] - [第1页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:26:56] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=0
#
# [第2轮] - [第2页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:02] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=100
#
# [第2轮] - [第3页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:06] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=200
#
# [第2轮] - [第4页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:12] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=300
#
# [第2轮] - [第5页] - [请求3次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:28] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=400
#
# [第2轮] - [第6页] - [请求2次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:38] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=500
#
# [第2轮] - [第7页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:43] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=600
#
# [第2轮] - [第8页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:47] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=700
#
# [第2轮] - [第9页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:27:53] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=800
#
# [第1轮] - [第6页] - [请求1次] - [599/1220] - [剩余1条] - [2024/10/15 18:27:56] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=500
#
# [第2轮] - [第10页] - [请求2次] - [1081/1091] - [剩余1条] - [2024/10/15 18:28:01] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=900
#
# [第2轮] - [第11页] - [请求2次] - [1081/1091] - [剩余1条] - [2024/10/15 18:28:07] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=1000
#
# [第3轮] - [第1页] - [请求1次] - [1081/1091] - [剩余1条] - [2024/10/15 18:28:14] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=0
#
# [第1轮] - [第7页] - [请求1次] - [697/1220] - [剩余1条] - [2024/10/15 18:28:20] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=600
#
# [第1轮] - [第8页] - [请求3次] - [797/1220] - [剩余1条] - [2024/10/15 18:28:31] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=700
#
# [第3轮] - [第2页] - [请求2次] - [1091/1091] - [剩余1条] - [2024/10/15 18:28:34] - 2. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan&num=100&start=100
#
# [第1轮] - [第9页] - [请求1次] - [897/1220] - [剩余0条] - [2024/10/15 18:28:36] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=800
#
# [第1轮] - [第10页] - [请求1次] - [997/1220] - [剩余0条] - [2024/10/15 18:28:40] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=900
#
# [第1轮] - [第11页] - [请求1次] - [1095/1220] - [剩余0条] - [2024/10/15 18:28:53] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1000
#
# [第1轮] - [第12页] - [请求1次] - [1195/1220] - [剩余0条] - [2024/10/15 18:29:13] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1100
#
# [第1轮] - [第13页] - [请求1次] - [1215/1220] - [剩余0条] - [2024/10/15 18:29:17] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1200
#
# [第2轮] - [第1页] - [请求1次] - [1215/1220] - [剩余0条] - [2024/10/15 18:29:42] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=0
#
# [第2轮] - [第2页] - [请求1次] - [1215/1220] - [剩余0条] - [2024/10/15 18:30:27] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=100
#
# [第2轮] - [第3页] - [请求2次] - [1215/1220] - [剩余0条] - [2024/10/15 18:30:35] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=200
#
# [第2轮] - [第4页] - [请求1次] - [1215/1220] - [剩余0条] - [2024/10/15 18:30:39] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=300
#
# [第2轮] - [第5页] - [请求1次] - [1215/1220] - [剩余0条] - [2024/10/15 18:30:52] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=400
#
# [第2轮] - [第6页] - [请求1次] - [1217/1220] - [剩余0条] - [2024/10/15 18:31:48] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=500
#
# [第2轮] - [第7页] - [请求4次] - [1217/1220] - [剩余0条] - [2024/10/15 18:32:32] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=600
#
# [第2轮] - [第8页] - [请求2次] - [1217/1220] - [剩余0条] - [2024/10/15 18:32:40] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=700
#
# [第2轮] - [第9页] - [请求1次] - [1217/1220] - [剩余0条] - [2024/10/15 18:32:46] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=800
#
# [第2轮] - [第10页] - [请求2次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:01] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=900
#
# [第2轮] - [第11页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:15] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1000
#
# [第2轮] - [第12页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:19] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1100
#
# [第2轮] - [第13页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:25] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=1200
#
# [第3轮] - [第1页] - [请求2次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:34] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=0
#
# [第3轮] - [第2页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:33:47] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=100
#
# [第3轮] - [第3页] - [请求3次] - [1219/1220] - [剩余0条] - [2024/10/15 18:34:12] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=200
#
# [第3轮] - [第4页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:34:19] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=300
#
# [第3轮] - [第5页] - [请求1次] - [1219/1220] - [剩余0条] - [2024/10/15 18:34:28] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=400
#
# [第3轮] - [第6页] - [请求2次] - [1220/1220] - [剩余0条] - [2024/10/15 18:34:51] - 1. https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder&num=100&start=500
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 3315.66it/s]
# Done ~
