# %%
import os

# %%
list_file = list(os.walk('./crawler'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 5

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    with open('./crawler/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler.xlsx', index=False)

df
# Out:
# 进度: 100%|███████████████████████████████████| 5/5 [00:00<00:00, 626.48it/s]
#                             Title                 Specification     Price  \
# 0   NISSENS 89165 Klimakompressor   SD7V16, 12V, PAG 46, R 134a   74,24 €
# 0   NISSENS 89203 Klimakompressor  SD7H15, 12V, PAG 100, R 134a  138,72 €
# 0   NISSENS 89106 Klimakompressor       V5, 12V, PAG 46, R 134a  166,96 €
# 0   NISSENS 89691 Klimakompressor   SD7B10, 12V, PAG 46, R 134a  159,24 €
# 0  NISSENS 890311 Klimakompressor   SD7H15, 12V, PAG 46, R 134a  160,72 €
#
#                                                   OE  \
# 0      21000094;7M0820803M;7M0820803Q;98NW-19D629-AB
# 0                                21000205;7H0820805D
# 0  21000202;1135025;1135295;1135323;1854032;18540...
# 0                        000771974;71721705;71721706
# 0                         84807673;87300121;87709773
#
#                                              Vehicle  \
# 0  SEAT Alhambra I (7V8, 7V9) (Baujahr 04.1996 - ...
# ...
