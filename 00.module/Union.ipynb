# %%
import os

# %%
list_file = list(os.walk('./union'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 8

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    df = pd.concat([df, pd.read_excel('./union/' + file)], ignore_index=False)
    
df.to_excel('./crawler.xlsx', index=False)

df
# Out:
# 进度: 100%|████████████████████████████████████| 8/8 [00:06<00:00,  1.23it/s]
#     序号   Item_Number                                              Title  \
# 0  NaN  133324592572  STAGE 1 HD OFF-ROAD PREMIUM CLUTCH KIT fits 19...
# 1  NaN  132777995312  CM STAGE 2 PERFORMANCE RACING CLUTCH KIT FOR A...
# 2  NaN  133396758863  CM STAGE 1 CLUTCH FRICTION DISC DISK PLATE for...
# 3  NaN  133160090979  CLUTCHMAX HD SPORT CLUTCH KIT and FLYWHEEL for...
# 4  NaN  132744673662  CM STAGE 1 OFF-ROAD PERFORMANCE CLUTCH KIT for...
# ..  ..           ...                                                ...
# 17 NaN  133515394591  VALEO STAGE 4 SPORT CLUTCH KIT+ FLYWHEEL for C...
# 18 NaN  133516892439  VALEO STAGE 3 CLUTCH KIT+CHROMOLY FLYWHEEL+SLA...
# 19 NaN  133084374156  VALEO STAGE 3 HD RACING CLUTCH SLAVE KIT+ PROL...
# 20 NaN  133599883987  STAGE 4 PERFORMANCE CLUTCH KIT+FLYWHEEL for 19...
# 21 NaN  134085019439  STAGE 5 CLUTCH KIT & ALUMINUM FLYWHEEL fits 99...
#
#          Price  Sold                                            Vehicle  Pic  \
# 0    USD 65.67     3                             Kia Sportage 1995-2002  NaN
# 1    USD 65.98    12  Honda Civic 2006-2011\nAcura CSX 2007-2010\nAc...  NaN
# 2    USD 39.45     2                             Ford Mustang 1994-2004  NaN
# 3   USD 135.49    13  Pontiac Vibe 2003-2008\nToyota Corolla 1998-20...  NaN
# 4     USD 86.5    22    Jeep Wrangler 2007-2011\nJeep Liberty 2002-2004  NaN
# ..         ...   ...                                                ...  ...
# 17  USD 301.25     0                       Chevrolet Corvette 2005-2013  NaN
# 18   USD 360.3     0                         Chevrolet Camaro 2010-2015  NaN
# 19  USD 359.47    41  Chevrolet Camaro 1998-2002\nPontiac Firebird 1...  NaN
# 20   USD 327.5     6                       Chevrolet Corvette 1970-1974  NaN
# 21  USD 432.49     0  BMW Z4 2003-2004\nBMW 325Ci 2001-2003\nBMW 325...  NaN
#
#                                                   Url  \
# 0   https://www.ebay.com/itm/133324592572?hash=ite...
# 1   https://www.ebay.com/itm/132777995312?hash=ite...
# 2   https://www.ebay.com/itm/133396758863?hash=ite...
# 3   https://www.ebay.com/itm/133160090979?hash=ite...
# 4   https://www.ebay.com/itm/132744673662?hash=ite...
# ..                                                ...
# 17  https://www.ebay.com/itm/133515394591?hash=ite...
# 18  https://www.ebay.com/itm/133516892439?hash=ite...
# 19  https://www.ebay.com/itm/133084374156?hash=ite...
# 20  https://www.ebay.com/itm/133599883987?hash=ite...
# 21  https://www.ebay.com/itm/134085019439?hash=ite...
#
#                                                   Src  \
# 0   https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/N2EA...
# 1   https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/Sx4A...
# 2   https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/5TcA...
# 3   https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/YUsA...
# 4   https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/BJQA...
# ..                                                ...
# 17  https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/FjoA...
# 18  https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/mB8A...
# 19  https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/qMkA...
# 20  https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/TPYA...
# 21  https://i.ebayimg.com/00/s/MTEwMFgxMTAw/z/QaMA...
#
#                               clutch disc style  ...  \
# 0   8-7/8" (225mm) Stage 1 Full Face Sprung Hub  ...
# 1      Stage 2 High Torque Full Face Sprung Hub  ...
# 2                          Full Face Sprung Hub  ...
# 3                          Full Face Sprung Hub  ...
# 4                  Stage 1 Full Face Sprung Hub  ...
# ..                                          ...  ...
# 17                High Torque 6-Puck Sprung Hub  ...
# 18     11-3/4" High Torque Full Face Sprung Hub  ...
# 19     Stage 3 High Torque Full Face Sprung Hub  ...
# 20            11" High Torque 6-Puck Sprung Hub  ...
# 21                                          NaN  ...
#
#    mounting hardware include fitment tyoe shipping package detail  \
# 0                        NaN          NaN                     NaN
# 1                        NaN          NaN                     NaN
# 2                        NaN          NaN                     NaN
# 3                        NaN          NaN                     NaN
# 4                        NaN          NaN                     NaN
# ..                       ...          ...                     ...
# 17                       NaN          NaN                     NaN
# 18                       NaN          NaN                     NaN
# 19                       NaN          NaN                     NaN
# 20                       NaN          NaN                     NaN
# 21                       NaN          NaN                     NaN
#
#    clutch bearing type transmission typ  \
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ..                 ...              ...
# 17                 NaN              NaN
# 18                 NaN              NaN
# 19                 NaN              NaN
# 20                 NaN              NaN
# 21                 NaN              NaN
#
#    pressure plate mounting bolts included flyhweel material fitment type:  \
# 0                                     NaN               NaN           NaN
# 1                                     NaN               NaN           NaN
# 2                                     NaN               NaN           NaN
# 3                                     NaN               NaN           NaN
# 4                                     NaN               NaN           NaN
# ..                                    ...               ...           ...
# 17                                    NaN               NaN           NaN
# 18                                    NaN               NaN           NaN
# 19                                    NaN               NaN           NaN
# 20                                    NaN               NaN           NaN
# 21                                    NaN               NaN           NaN
#
#    transmission type: clutch disc styl
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ..                ...              ...
# 17                NaN              NaN
# 18                NaN              NaN
# 19                NaN              NaN
# 20                NaN              NaN
# 21                NaN              NaN
#
# [15977 rows x 111 columns]
