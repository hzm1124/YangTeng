# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('/Users/hzm/Desktop/YangTeng/code/venv/code/00.module')
import Proxy
import UA
import time

# = = = = = = = = = = = = = = = = = =

import pandas as pd
from selenium.webdriver import ChromeOptions

option = ChromeOptions()
option.add_experimental_option('useAutomationExtension', False)
option.add_argument('blink-settings=imagesEnabled=false')
option.add_argument('--disable-blink-features=AutomationControlled')
option.add_argument('--disable-dev-shm-usage')
option.add_argument('--disable-gpu')
option.add_experimental_option('excludeSwitches', ['enable-automation'])
option.add_argument('--headless')
option.add_argument('--no-sandbox')
option.add_argument('--proxy-server=' + Proxy.get_Proxy_selenium())
option.add_argument('user-agent=' + UA.get_UA())
option.page_load_strategy = 'normal'

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./part.xlsx', header=0).fillna('')
list_info = df_menu['Info'].to_list()

print('总数量：' + str(len(list_info)))
print()

df = pd.DataFrame()

# = = = = = = = = = = = = = = = = = =

work = Queue()
for info in list_info:
    work.put_nowait(info)

def crawler():
    global df
    
    while not work.empty():
        info = work.get_nowait()
        
        # = = = = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(11):
            if info == None or info == '':
                status = 'none'
                break
            
            try:
                browser = Chrome(service=Service('../../../chromedriver'), options=option)
                browser.maximize_window()
                
                # = = = = = = = = = = = = = = = = = =

                browser.get(info)
                
                time.sleep(3)
                
                # = = = = = = = = = = = = = = = = = =
                
                wait = WebDriverWait(browser, 60)
                wait.until(EC.presence_of_element_located((By.XPATH, '//section[contains(@aria-label, "Warranty Information")]')))
                list_row = browser.find_elements(by=By.XPATH, value='//tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-b-1") or contains(@class, "altrow-b-0"))]')

                # = = = = = = = = = = = = = = = = = =
                
                if len(list_row) == 0:
                    status = 'none'
                    break
                
                # = = = = = = = = = = = = = = = = = =
                
                list_kit_no = [i+1 for i in range(len(list_row))]
                list_kit_quantity = []
                list_kit_note = []
                list_kit_manufacturer = []
                list_kit_part_number = []
                list_kit_info = []

                for row in list_row:
                    list_td = row.find_elements(by=By.XPATH, value='./tr/td')
                    list_kit_quantity.append(list_td[0].text)
                    list_kit_note.append(list_td[1].text)
                    list_kit_manufacturer.append(list_td[2].find_element(by=By.XPATH, value='./descendant::span[contains(@class, "listing-final-manufacturer")]').text)
                    list_kit_part_number.append(list_td[2].find_element(by=By.XPATH, value='./descendant::span[contains(@class, "listing-final-partnumber")]').text)
                    list_kit_info.append(list_td[2].find_element(by=By.XPATH, value='./descendant::a[contains(@class, "ra-btn") and contains(@class, "ra-btn-moreinfo")]').get_attribute('href'))

                # = = = = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame({'status': 'ok',
                                        'Info': info,
                                        'Kit_No.': list_kit_no,
                                        'Kit_Quantity': list_kit_quantity,
                                        'Kit_Note': list_kit_note,
                                        'Kit_Manufacturer': list_kit_manufacturer,
                                        'Kit_Part_Number': list_kit_part_number,
                                        'Kit_Info': list_kit_info})

                browser.quit()
                
                status = 'ok'
                
                break
                
            except:
                time.sleep(3)
                continue
                
        # = = = = = = = = = = = = = = = = = =

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'Info': info}])
        elif status == 'none':
            df_temp = pd.DataFrame([{'status': 'none',
                                     'Info': info}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        if info != None and info != '':
            print(info +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(25):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print()
print('输出中...')
df.to_excel('./kit.xlsx', index=False)
print()
print('搞定！')
# Out:
# 总数量：50
#
# https://www.rockauto.com/en/moreinfo.php?pk=13570029  <->  [ok] - 剩余数量：25
# https://www.rockauto.com/en/moreinfo.php?pk=8305016  <->  [ok] - 剩余数量：24
# https://www.rockauto.com/en/moreinfo.php?pk=8304968  <->  [none] - 剩余数量：23
# https://www.rockauto.com/en/moreinfo.php?pk=9658988  <->  [ok] - 剩余数量：22
# https://www.rockauto.com/en/moreinfo.php?pk=8305012  <->  [ok] - 剩余数量：21
# https://www.rockauto.com/en/moreinfo.php?pk=11158045  <->  [ok] - 剩余数量：20
# https://www.rockauto.com/en/moreinfo.php?pk=8304976  <->  [ok] - 剩余数量：19
# https://www.rockauto.com/en/moreinfo.php?pk=8921208  <->  [ok] - 剩余数量：18
# https://www.rockauto.com/en/moreinfo.php?pk=11158049  <->  [none] - 剩余数量：17
# https://www.rockauto.com/en/moreinfo.php?pk=9658980  <->  [ok] - 剩余数量：16
# https://www.rockauto.com/en/moreinfo.php?pk=9722076  <->  [ok] - 剩余数量：15
# https://www.rockauto.com/en/moreinfo.php?pk=8921200  <->  [ok] - 剩余数量：14
# https://www.rockauto.com/en/moreinfo.php?pk=8921204  <->  [ok] - 剩余数量：13
# https://www.rockauto.com/en/moreinfo.php?pk=8304980  <->  [ok] - 剩余数量：12
# https://www.rockauto.com/en/moreinfo.php?pk=8304960  <->  [ok] - 剩余数量：11
# https://www.rockauto.com/en/moreinfo.php?pk=8304972  <->  [none] - 剩余数量：10
# https://www.rockauto.com/en/moreinfo.php?pk=8304992  <->  [ok] - 剩余数量：9
# https://www.rockauto.com/en/moreinfo.php?pk=9658984  <->  [ok] - 剩余数量：8
# https://www.rockauto.com/en/moreinfo.php?pk=8305000  <->  [ok] - 剩余数量：7
# https://www.rockauto.com/en/moreinfo.php?pk=10454500  <->  [ok] - 剩余数量：6
# https://www.rockauto.com/en/moreinfo.php?pk=13570025  <->  [ok] - 剩余数量：5
# https://www.rockauto.com/en/moreinfo.php?pk=8305008  <->  [ok] - 剩余数量：4
# https://www.rockauto.com/en/moreinfo.php?pk=8921212  <->  [ok] - 剩余数量：3
# https://www.rockauto.com/en/moreinfo.php?pk=10110000  <->  [ok] - 剩余数量：2
# https://www.rockauto.com/en/moreinfo.php?pk=10454504  <->  [ok] - 剩余数量：1
# https://www.rockauto.com/en/moreinfo.php?pk=11158061  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11492461  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158069  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158077  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158065  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158085  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10981372  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=8305036  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10981380  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158081  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10981376  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=13570037  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158093  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158089  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158073  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10981368  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=12803989  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=8305032  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=13570033  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158053  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10454508  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=8305040  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=11158057  <->  [none] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=10890260  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pk=8305028  <->  [ok] - 剩余数量：0
#
# 输出中...
#
# 搞定！
