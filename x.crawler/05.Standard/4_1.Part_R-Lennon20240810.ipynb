# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel('./3.part_number.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Part Number'].tolist()
# Out:
# 总数量：45086
# ['10001',
#  '10002',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '10010',
#  '10011',
#  '10014',
#  '10016',
#  '10017',
#  '10018',
#  '10019',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
#  '10025',
#  '10026',
#  '10027',
#  '10028',
#  '10029',
#  '10030',
#  '10033',
#  '10034',
#  '10037',
#  '10038',
#  '10039',
#  '10040',
#  '10041',
#  '10042',
#  '10043',
#  '10044',
#  '10045',
#  '10046',
#  '10047',
#  '10048',
#  '10049',
#  '10050',
#  '10051',
#  '10052',
#  '10053',
#  '10054',
#  '10055',
#  '10056',
#  '10057',
#  '10058',
#  '10059',
#  '10060',
#  '10061',
#  '10062',
#  '10063',
#  '10064',
#  '10065',
#  '10069',
#  '10070',
#  '10071',
#  '10072',
#  '10073',
#  '10074',
#  '10075',
#  '10076',
#  '10077',
#  '10078',
#  '10079',
#  '10080',
#  '10081',
#  '10082',
#  '10083',
#  '10084',
#  '10085',
#  '10114',
#  '10116',
#  '10117',
#  '10123',
#  '10124',
#  '10125',
#  '10126',
#  '10127',
#  '101A',
#  '1201',
#  '1202',
#  '1207B',
#  '1208',
#  '1210',
#  '1212B',
#  '1213B',
#  '1217A',
#  '121A',
#  '1220C',
#  '1224A',
#  '1225',
#  '1226',
#  '1227A',
#  '1228',
#  '1229A',
#  '1234B',
#  '1237',
#  '1238B',
#  '1239',
#  '123A',
#  '1240',
#  '1243',
#  '1245',
#  '1246',
#  '1248A',
#  '1249',
#  '1250A',
#  '1251',
#  '1255',
#  '1256B',
#  '1257',
#  '1258',
#  '1259',
#  '1260',
#  '1264',
#  '1267',
#  '1269',
#  '1276',
#  '1280',
#  '1282B',
#  '1283',
#  '1286A',
#  '1289',
#  '1290',
#  '1291',
#  '1293',
#  '1294A',
#  '1296B',
#  '1297',
#  '1298A',
#  '1299',
#  '133A',
#  '1400A',
#  '1401',
#  '1403A',
#  '1408',
#  '1409B',
#  '1413',
#  '1418A',
#  '1420B',
#  '1428',
#  '1430',
#  '1431A',
#  '1432B',
#  '1433B',
#  '1434',
#  '1435',
#  '1439A',
#  '1440B',
#  '1442',
#  '1447A',
#  '1448',
#  '1449A',
#  '1451',
#  '1453',
#  '1457',
#  '1465A',
#  '1472',
#  '1473',
#  '1474A',
#  '1476',
#  '1479B',
#  '1480',
#  '1481',
#  '1484',
#  '1487',
#  '1491B',
#  '1492B',
#  '1493',
#  '1495',
#  '1496A',
#  '1500',
#  '1501',
#  '1502A',
#  '1504A',
#  '1505A',
#  '1506',
#  '1507A',
#  '1509A',
#  '1510B',
#  '1513A',
#  '1514',
#  '1515',
#  '1516',
#  '1517',
#  '1518A',
#  '1520',
#  '1522',
#  '1523',
#  '1524',
#  '1525A',
#  '1526B',
#  '1527D',
#  '1528',
#  '1529',
#  '1531',
#  '1532',
#  '1533',
#  '1535A',
#  '1537',
#  '1550',
#  '1551',
#  '1552',
#  '1553',
#  '1554B',
#  '1556',
#  '1557A',
#  '1559',
#  '1565B',
#  '1566A',
#  '1567',
#  '1568',
#  '1569A',
#  '1570',
#  '1572',
#  '1573A',
#  '1574',
#  '1575',
#  '1580',
#  '1582',
#  '1583',
#  '1584',
#  '1585A',
#  '1586',
#  '1587',
#  '1588',
#  '1589',
#  '1590',
#  '1593',
#  '1594',
#  '1595',
#  '1596',
#  '1597',
#  '1599',
#  '1600',
#  '1601',
#  '1603',
#  '1605',
#  '1606',
#  '1608A',
#  '1609',
#  '160A',
#  '1611',
#  '1613',
#  '1614A',
#  '1615A',
#  '1617',
#  '1618',
#  '1619',
#  '1622',
#  '1626B',
#  '1627',
#  '1628',
#  '1631A',
#  '1632',
#  '1633',
#  '1635',
#  '1636',
#  '1637B',
#  '1638',
#  '1640',
#  '1641',
#  '1642',
#  '1643A',
#  '1644',
#  '1647',
#  '1650',
#  '1652',
#  '1654',
#  '1655',
#  '1656',
#  '1659',
#  '1660',
#  '1661',
#  '1662',
#  '1663',
#  '1664',
#  '1666',
#  '1667A',
#  '1673',
#  '1675',
#  '1676',
#  '1680',
#  '1681',
#  '1683',
#  '1685',
#  '1686',
#  '1688',
#  '1692',
#  '1695',
#  '1696',
#  '1697',
#  '1700',
#  '1701',
#  '1702',
#  '1703',
#  '1704',
#  '1705',
#  '1708',
#  '1709',
#  '1711',
#  '1712',
#  '1715',
#  '1716',
#  '1717',
#  '172',
#  '188A',
#  '194B',
#  '195',
#  '2000A',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2014A',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2029',
#  '2032',
#  '2034',
#  '2035',
#  '2036',
#  '2037',
#  '2038',
#  '2040',
#  '2041',
#  '2042',
#  '2043',
#  '2044',
#  '2045',
#  '2046',
#  '2047',
#  '2048',
#  '2049',
#  '2050',
#  '2051',
#  '2052',
#  '2053',
#  '2054',
#  '2055',
#  '2056',
#  '2057',
#  '2058',
#  '2059',
#  '2061',
#  '2062',
#  '2063',
#  '2064',
#  '2065',
#  '2066',
#  '2067',
#  '2071',
#  '212D',
#  '213C',
#  '224D',
#  '229B',
#  '23400',
#  '23401',
#  '23600',
#  '23601',
#  '23800',
#  '23801',
#  '23802',
#  '24100M',
#  '24402M',
#  '24403M',
#  '24404M',
#  '24405M',
#  '24407M',
#  '24409M',
#  '24601M',
#  '24602M',
#  '24603M',
#  '24606M',
#  '24607M',
#  '24609M',
#  '24804M',
#  '24805M',
#  '24806M',
#  '24808M',
#  '24809M',
#  '24810M',
#  '24811M',
#  '24812M',
#  '24813M',
#  '24814M',
#  '24816M',
#  '24817M',
#  '24819M',
#  '24821M',
#  '24822M',
#  '24823M',
#  '24824M',
#  '24825M',
#  '24826M',
#  '24827M',
#  '252C',
#  '25401',
#  '25402',
#  '25403',
#  '25404',
#  '25405',
#  '25406',
#  '25408',
#  '25409',
#  '25410',
#  '25411',
#  '25412',
#  '25413',
#  '25414',
#  '25415',
#  '25416',
#  '25417',
#  '25418',
#  '25419',
#  '25420',
#  '25421',
#  '25422',
#  '25423',
#  '25424',
#  '25601',
#  '25602',
#  '25604',
#  '25605',
#  '25606',
#  '25607',
#  '25608',
#  '25609',
#  '25610',
#  '25611',
#  '25801',
#  '25802',
#  '260E',
#  '26410',
#  '26413',
#  '26414',
#  '26416',
#  '26421',
#  '26422',
#  '26424',
#  '26429',
#  '26430',
#  '26436',
#  '26440',
#  '26441',
#  '26442',
#  '26444',
#  '26446',
#  '26447',
#  '26452',
#  '26453',
#  '26454',
#  '26457',
#  '26458',
#  '26459',
#  '26460',
#  '26461',
#  '26462',
#  '26463',
#  '26464',
#  '26465',
#  '26466',
#  '26467',
#  '26468',
#  '26469',
#  '26603',
#  '26620',
#  '26627',
#  '26629',
#  '26630',
#  '26632',
#  '26635',
#  '26636',
#  '26637',
#  '26638',
#  '26639',
#  '26640',
#  '26641',
#  '26643',
#  '26644',
#  '26645',
#  '26646',
#  '26647',
#  '26648',
#  '26649',
#  '26650',
#  '26652',
#  '26653',
#  '26655',
#  '26656',
#  '26657',
#  '26658',
#  '26659',
#  '26660',
#  '26661',
#  '26662',
#  '26663',
#  '26664',
#  '26668',
#  '26669',
#  '26670',
#  '26671',
#  '26673',
#  '26674',
#  '26675',
#  '26676',
#  '26677',
#  '26678',
#  '26679',
#  '26680',
#  '26681',
#  '26682',
#  '26683',
#  '26684',
#  '26685',
#  '26686',
#  '26687',
#  '26688',
#  '26689',
#  '26690',
#  '26691',
#  '26692',
#  '26693',
#  '26694',
#  '26695',
#  '26696',
#  '26697',
#  '26698',
#  '26699',
#  '26810',
#  '26816',
#  '26818',
#  '26820',
#  '26821',
#  '26823',
#  '26827',
#  '26828',
#  '26832',
#  '26838',
#  '26841',
#  '26844',
#  '26845',
#  '26846',
#  '26847',
#  '26848',
#  '26850',
#  '26854',
#  '26862',
#  '26865',
#  '26868',
#  '26869',
#  '26870',
#  '26871',
#  '26874',
#  '26875',
#  '26879',
#  '26880',
#  '26882',
#  '26883',
#  '26884',
#  '26885',
#  '26886',
#  '26888',
#  '26889',
#  '26890',
#  '26891',
#  '26892',
#  '26894',
#  '26897',
#  '26898',
#  '26899',
#  '26900',
#  '26901',
#  '26902',
#  '26903',
#  '26904',
#  '26905',
#  '26906',
#  '26907',
#  '26908',
#  '26909',
#  '26910',
#  '26911',
#  '26912',
#  '26913',
#  '26914',
#  '26915',
#  '26916',
#  '26917',
#  '26919',
#  '26920',
#  '26921',
#  '26922',
#  '26923',
#  '26924',
#  '26925',
#  '26926',
#  '26928',
#  '26929',
#  '26930',
#  '26931',
#  '26932',
#  '26934',
#  '26935',
#  '26937',
#  '26938',
#  '26942',
#  '26943',
#  '27301',
#  '27302',
#  '27303',
#  '27402',
#  '27409',
#  '27410',
#  '27411',
#  '27412',
#  '27413',
#  '27414',
#  '27416',
#  '27418',
#  '27419',
#  '27420',
#  '27421',
#  '27422',
#  '27423',
#  '27425',
#  '27426',
#  '27427',
#  '27428',
#  '27429',
#  '27431',
#  '27432',
#  '27434',
#  '27435',
#  '27436',
#  '27437',
#  '27438',
#  '27439',
#  '27440',
#  '27441',
#  '27442',
#  '27443',
#  '27444',
#  '27445',
#  '27446',
#  '27448',
#  '27449',
#  '27450',
#  '27451',
#  '27452',
#  '27453',
#  '27454',
#  '27455',
#  '27456',
#  '27457',
#  '27458',
#  '27459',
#  '27460',
#  '27461',
#  '27462',
#  '27463',
#  '27464',
#  '27465',
#  '27466',
#  '27467',
#  '27468',
#  '27469',
#  '27470',
#  '27471',
#  '27472',
#  '27473',
#  '27474',
#  '27475',
#  '27476',
#  '27477',
#  '27478',
#  '27479',
#  '27481',
#  '27483',
#  '27484',
#  '27485',
#  '27486',
#  '27488',
#  '27489',
#  '27491',
#  '27492',
#  '27493',
#  '27494',
#  '27495',
#  '27496',
#  '27497',
#  '27498',
#  '27499',
#  '27500',
#  '27501',
#  '27502',
#  '27503',
#  '27504',
#  '27505',
#  '27506',
#  '27507',
#  '27508',
#  '27509',
#  '27510',
#  '27511',
#  '27512',
#  '27513',
#  '27514',
#  '27515',
#  '27516',
#  '27517',
#  '27518',
#  '27519',
#  '27520',
#  '27521',
#  '27522',
#  '27523',
#  '27525',
#  '27526',
#  '27527',
#  '27528',
#  '27529',
#  '27531',
#  '27532',
#  '27533',
#  '27534',
#  '27535',
#  '27536',
#  '27537',
#  '27538',
#  '27539',
#  '27540',
#  '27541',
#  '27542',
#  '27543',
#  '27544',
#  '27545',
#  '27546',
#  '27547',
#  '27548',
#  '27549',
#  '27550',
#  '27551',
#  '27552',
#  '27553',
#  '27554',
#  '27555',
#  '27556',
#  '27557',
#  '27558',
#  '27559',
#  '27560',
#  '27561',
#  '27562',
#  '27563',
#  '27564',
#  '27565',
#  '27566',
#  '27567',
#  '27568',
#  '27569',
#  '27570',
#  '27571',
#  '27572',
#  '27573',
#  '27574',
#  '27575',
#  '27576',
#  '27577',
#  '27578',
#  '27579',
#  '27580',
#  '27581',
#  '27582',
#  '27583',
#  '27584',
#  '27585',
#  '27586',
#  '27587',
#  '27588',
#  '27589',
#  '27590',
#  '27591',
#  '27592',
#  '27593',
#  '27594',
#  '27595',
#  '27596',
#  '27597',
#  '27598',
#  '27599',
#  '27601',
#  '27603',
#  '27604',
#  '27608',
#  '27609',
#  '27611',
#  '27615',
#  '27616',
#  '27618',
#  '27619',
#  '27621',
#  '27622',
#  '27623',
#  '27624',
#  '27625',
#  '27626',
#  '27627',
#  '27628',
#  '27629',
#  '27630',
#  '27631',
#  '27632',
#  '27633',
#  '27634',
#  '27636',
#  '27637',
#  '27638',
#  '27639',
#  '27640',
#  '27641',
#  '27642',
#  '27643',
#  '27644',
#  '27645',
#  '27646',
#  '27647',
#  '27648',
#  '27649',
#  '27650',
#  '27651',
#  '27652',
#  '27653',
#  '27654',
#  '27655',
#  '27656',
#  '27657',
#  '27658',
#  '27659',
#  '27660',
#  '27661',
#  '27662',
#  '27663',
#  '27664',
#  '27665',
#  '27666',
#  '27667',
#  '27668',
#  '27669',
#  '27670',
#  '27671',
#  '27672',
#  '27673',
#  '27674',
#  '27675',
#  '27676',
#  '27677',
#  '27678',
#  '27679',
#  '27680',
#  '27681',
#  '27682',
#  '27683',
#  '27684',
#  '27685',
#  '27686',
#  '27687',
#  '27688',
#  '27689',
#  '27690',
#  '27691',
#  '27692',
#  '27693',
#  '27694',
#  '27695',
#  '27696',
#  '27697',
#  '27698',
#  '27699',
#  '27700',
#  '27701',
#  '27702',
#  '27703',
#  '27704',
#  '27705',
#  '27706',
#  '27707',
#  '27708',
#  '27709',
#  '27711',
#  '27712',
#  '27713',
#  '27715',
#  '27716',
#  '27717',
#  '27718',
#  '27720',
#  '27728',
#  '27729',
#  '27730',
#  '27731',
#  '27732',
#  '27733',
#  '27734',
#  '27735',
#  '27736',
#  '27737',
#  '27738',
#  '27739',
#  '27805',
#  '27812',
#  '27813',
#  '27815',
#  '27816',
#  '27819',
#  '27822',
#  '27829',
#  '27830',
#  '27831',
#  '27832',
#  '27833',
#  '27834',
#  '27835',
#  '27836',
#  '27837',
#  '27838',
#  '27839',
#  '27840',
#  '27842',
#  '27843',
#  '27846',
#  '27847',
#  '27848',
#  '27849',
#  '27850',
#  '27851',
#  '27852',
#  '27853',
#  '27854',
#  '27855',
#  '27856',
#  '27857',
#  '27858',
#  '27859',
#  '27860',
#  '27861',
#  '27862',
#  '27863',
#  '27864',
#  '27865',
#  '27866',
#  '27867',
#  '27868',
#  '27869',
#  '27870',
#  '27871',
#  '27872',
#  '27873',
#  '27874',
#  '27876',
#  '27877',
#  '27878',
#  '27879',
#  '27880',
#  '27881',
#  '27882',
#  '27883',
#  '27884',
#  '27885',
#  '27886',
#  '27887',
#  '27888',
#  '27889',
#  '27891',
#  '27892',
#  '27893',
#  '27894',
#  '27895',
#  '28',
#  '2801W',
#  '283D',
#  '28840',
#  '28852',
#  '290',
#  '29301',
#  ...]

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.get(f'''https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?part={input_.loc[a, 'Part Number']}&func=PART&vid=''',
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(10, 10))

        if resp.status_code == 200:
            break
    except:
        continue

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'pd': {'rowId': 1,
#   'site': 'STD',
#   'webBase': 'WX_10001',
#   'brand': 'BSW',
#   'basePart': '10001',
#   'partDesc_en': 'Spark Plug Wire Set',
#   'partLongDesc_en': 'Spark Plug Wire Set',
#   'pop': 'A',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 1,
#   'brandLink': None,
#   'imageUrl': None},
#  'pp': {'buyersGuides': [{'basePart': '10001',
#     'buyersGuideId': 5916,
#     'buyersGuideDesc': 'Chevrolet Bel Air (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 49955,
#     'buyersGuideDesc': 'Chevrolet C10 (80-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 50020,
#     'buyersGuideDesc': 'Chevrolet C10 Suburban (80-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 6693,
#     'buyersGuideDesc': 'Chevrolet C20 (86-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 6751,
#     'buyersGuideDesc': 'Chevrolet C20 Suburban (86-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 50181,
#     'buyersGuideDesc': 'Chevrolet C30 (86-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 7516,
#     'buyersGuideDesc': 'Chevrolet C60 (85-80)'},
#    {'basePart': '10001',
#     'buyersGuideId': 7529,
#     'buyersGuideDesc': 'Chevrolet C70 (85-80)'},
#    {'basePart': '10001',
#     'buyersGuideId': 50359,
#     'buyersGuideDesc': 'Chevrolet Caprice (76-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 50660,
#     'buyersGuideDesc': 'Chevrolet El Camino (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 10706,
#     'buyersGuideDesc': 'Chevrolet Impala (76-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 150809,
#     'buyersGuideDesc': 'Chevrolet K10 (80), (76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 51104,
#     'buyersGuideDesc': 'Chevrolet K20 (78-76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 51165,
#     'buyersGuideDesc': 'Chevrolet K20 Suburban (85)'},
#    {'basePart': '10001',
#     'buyersGuideId': 87518,
#     'buyersGuideDesc': 'Chevrolet K30 (86-80), (77)'},
#    {'basePart': '10001',
#     'buyersGuideId': 9752,
#     'buyersGuideDesc': 'Chevrolet K5 Blazer (78-76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 11385,
#     'buyersGuideDesc': 'Chevrolet Laguna (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 10466,
#     'buyersGuideDesc': 'Chevrolet Malibu (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 10249,
#     'buyersGuideDesc': 'Chevrolet Monte Carlo (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 55386,
#     'buyersGuideDesc': 'GMC C15 (78-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 94216,
#     'buyersGuideDesc': 'GMC C15 Suburban (78), (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23813,
#     'buyersGuideDesc': 'GMC C1500 (80-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23861,
#     'buyersGuideDesc': 'GMC C1500 Suburban (80-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23357,
#     'buyersGuideDesc': 'GMC C25 (78-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 94482,
#     'buyersGuideDesc': 'GMC C25 Suburban (78), (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23917,
#     'buyersGuideDesc': 'GMC C2500 (86-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23951,
#     'buyersGuideDesc': 'GMC C2500 Suburban (86-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 23970,
#     'buyersGuideDesc': 'GMC C35 (78-75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 55586,
#     'buyersGuideDesc': 'GMC C3500 (86-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 25403,
#     'buyersGuideDesc': 'GMC Jimmy (76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 55944,
#     'buyersGuideDesc': 'GMC K15 (76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 24208,
#     'buyersGuideDesc': 'GMC K1500 (80)'},
#    {'basePart': '10001',
#     'buyersGuideId': 24281,
#     'buyersGuideDesc': 'GMC K25 (78-76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 56016,
#     'buyersGuideDesc': 'GMC K25 Suburban (77-76)'},
#    {'basePart': '10001',
#     'buyersGuideId': 56128,
#     'buyersGuideDesc': 'GMC K3500 (86-79)'},
#    {'basePart': '10001',
#     'buyersGuideId': 26166,
#     'buyersGuideDesc': 'GMC Sprint (75-74)'},
#    {'basePart': '10001',
#     'buyersGuideId': 61342,
#     'buyersGuideDesc': 'Pontiac Bonneville (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 41992,
#     'buyersGuideDesc': 'Pontiac Catalina (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 40409,
#     'buyersGuideDesc': 'Pontiac Firebird (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 42139,
#     'buyersGuideDesc': 'Pontiac Grand Am (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 40557,
#     'buyersGuideDesc': 'Pontiac Grand LeMans (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 41296,
#     'buyersGuideDesc': 'Pontiac Grand Prix (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 41353,
#     'buyersGuideDesc': 'Pontiac Grand Safari (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 61733,
#     'buyersGuideDesc': 'Pontiac Grandville (75)'},
#    {'basePart': '10001',
#     'buyersGuideId': 41414,
#     'buyersGuideDesc': 'Pontiac LeMans (75)'}],
#   'partSpecs': [{'attributeCode': '110',
#     'attributeValue': 1905,
#     'attributeSort': 0,
#     'attributeName_en': 'Warranty',
#     'siteValue_en': '3 years/36,000 mile'},
#    {'attributeCode': '300',
#     'attributeValue': 6546,
#     'attributeSort': 0,
#     'attributeName_en': 'Performance Race Wire',
#     'siteValue_en': 'Performance Race Wire'},
#    {'attributeCode': '309',
#     'attributeValue': 5441,
#     'attributeSort': 0,
#     'attributeName_en': 'Wire Set Import / Domestic',
#     'siteValue_en': 'High Performance'},
#    {'attributeCode': '333',
#     'attributeValue': 3343,
#     'attributeSort': 0,
#     'attributeName_en': 'Wire Diameter (mm)',
#     'siteValue_en': '8.5mm'},
#    {'attributeCode': '217',
#     'attributeValue': 5949,
#     'attributeSort': 10430,
#     'attributeName_en': 'Core Construction',
#     'siteValue_en': 'Mag Core'},
#    {'attributeCode': '218',
#     'attributeValue': 3206,
#     'attributeSort': 10450,
#     'attributeName_en': 'Cylinders',
#     'siteValue_en': '8'},
#    {'attributeCode': '229',
#     'attributeValue': 1787,
#     'attributeSort': 12060,
#     'attributeName_en': 'Spark Plug Wire Lead 1',
#     'siteValue_en': '27"'},
#    {'attributeCode': '237',
#     'attributeValue': 1819,
#     'attributeSort': 12140,
#     'attributeName_en': 'Spark Plug Wire Lead 2',
#     'siteValue_en': '29"'},
#    {'attributeCode': '238',
#     'attributeValue': 1819,
#     'attributeSort': 12150,
#     'attributeName_en': 'Spark Plug Wire Lead 3',
#     'siteValue_en': '29"'},
#    {'attributeCode': '239',
#     'attributeValue': 1819,
#     'attributeSort': 12160,
#     'attributeName_en': 'Spark Plug Wire Lead 4',
#     'siteValue_en': '29"'},
#    {'attributeCode': '240',
#     'attributeValue': 2170,
#     'attributeSort': 12170,
#     'attributeName_en': 'Spark Plug Wire Lead 5',
#     'siteValue_en': '34"'},
#    {'attributeCode': '241',
#     'attributeValue': 2211,
#     'attributeSort': 12180,
#     'attributeName_en': 'Spark Plug Wire Lead 6',
#     'siteValue_en': '36"'},
#    {'attributeCode': '242',
#     'attributeValue': 2219,
#     'attributeSort': 12190,
#     'attributeName_en': 'Spark Plug Wire Lead 7',
#     'siteValue_en': '37"'},
#    {'attributeCode': '243',
#     'attributeValue': 2428,
#     'attributeSort': 12200,
#     'attributeName_en': 'Spark Plug Wire Lead 8',
#     'siteValue_en': '40"'},
#    {'attributeCode': '246',
#     'attributeValue': 3206,
#     'attributeSort': 12500,
#     'attributeName_en': 'Total Number of Leads',
#     'siteValue_en': '8'}],
#   'imageUrls': [],
#   'relatedParts': [],
#   'relatedCategories': None,
#   'fandB': [{'basePart': '10001',
#     'fbId': '311845',
#     'fbDesc': "All Blue Streak Performance Race wire sets surpass stringent componentry and manufacturing standards set by the North American racing industry, including premium spark plug boots and protective insulation and outer jacketing that maximize protection from searing underhood temperatures. What's more, only the finest conductive materials are used to deliver maximum voltage to the spark plug.",
#     'taB_Type': 'F&B Heading',
#     'assetSort': 1,
#     'digiSort': 100},
#    {'basePart': '10001',
#     'fbId': '87641',
#     'fbDesc': '600° F spark plug boots',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 200},
#    {'basePart': '10001',
#     'fbId': '87578',
#     'fbDesc': '170 Ohm/ft. Ferrite Mag Resistance Wire',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 210},
#    {'basePart': '10001',
#     'fbId': '311955',
#     'fbDesc': 'Fights extreme heat better than any other spark plug boots available. Same compound as supplied to many winning NASCAR teams.',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 220}],
#   'digiAssests': [{'asset_ID': 2,
#     'assetName': 'Installation Instructions',
#     'basePart': '10001',
#     'fileName': 'GF10584B.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD2/GF10584B.pdf',
#     'comment_ID': '251280',
#     'comment': 'Form No. GF10584B.pdf',
#     'assetSort': 2,
#     'digiSort': 999,
#     'videoImage': None},
#    {'asset_ID': 3,
#     'assetName': 'Bulletins',
#     'basePart': '10001',
#     'fileName': 'ST10235VWL-MAR13_JTF_veh_warn_light.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD/ST10235VWL-MAR13_JTF_veh_warn_light.pdf',
#     'comment_ID': '260657',
#     'comment': 'Just the Facts: Vehicle Warning Lights',
#     'assetSort': 3,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 3,
#     'assetName': 'Bulletins',
#     'basePart': '10001',
#     'fileName': 'ST11237-Standard_Interactive_Buyers_Guide-WEB.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD/ST11237-Standard_Interactive_Buyers_Guide-WEB.pdf',
#     'comment_ID': '260664',
#     'comment': "Standard Interactive Buyer's Guide",
#     'assetSort': 3,
#     'digiSort': 0,
#     'videoImage': None}],
#   'categories': [{'basePart': '10001',
#     'webLayout_ID': 267100,
#     'categoryName_en': 'Spark Plug Wire Set',
#     'prodCategory_ASort': 26430}],
#   'crossRef': None,
#   'completeRepair': {'serviceParts': [],
#    'serviceSpec': [{'serviceName': 'Fuel Filter Flush (Required)'},
#     {'serviceName': 'Oil Change (Required)'}]}}}

# %%
df_temp = pd.concat([pd.DataFrame([input_.iloc[a]]).reset_index(drop=True), pd.DataFrame([json_['pd']])], axis=1).fillna('')

df_temp
# Out:
#    No Part Number                                                Url  rowId  \
# 0   1       10001  https://www.standardbrand.com/en/ecatalog?part...      1
#
#   site   webBase brand basePart          partDesc_en      partLongDesc_en  \
# 0  STD  WX_10001   BSW    10001  Spark Plug Wire Set  Spark Plug Wire Set
#
#    ... partComment qtyEach  webColumn_Id categoryName_en vehicleId mfg  \
# 0  ...                   1
#
#   mfG_Part maxRows  brandLink imageUrl
# 0                1
#
# [1 rows x 21 columns]

# %%
dict_vehicle = {}
list_vehicle = json_['pp']['buyersGuides']
for i, vehicle in zip(range(len(list_vehicle)), list_vehicle):
    dict_vehicle[str(i)] = vehicle['buyersGuideDesc'].strip()

dict_vehicle
# Out:
# {'0': 'Chevrolet Bel Air (75-74)',
#  '1': 'Chevrolet C10 (80-75)',
#  '2': 'Chevrolet C10 Suburban (80-75)',
#  '3': 'Chevrolet C20 (86-75)',
#  '4': 'Chevrolet C20 Suburban (86-75)',
#  '5': 'Chevrolet C30 (86-75)',
#  '6': 'Chevrolet C60 (85-80)',
#  '7': 'Chevrolet C70 (85-80)',
#  '8': 'Chevrolet Caprice (76-74)',
#  '9': 'Chevrolet El Camino (75-74)',
#  '10': 'Chevrolet Impala (76-74)',
#  '11': 'Chevrolet K10 (80), (76)',
#  '12': 'Chevrolet K20 (78-76)',
#  '13': 'Chevrolet K20 Suburban (85)',
#  '14': 'Chevrolet K30 (86-80), (77)',
#  '15': 'Chevrolet K5 Blazer (78-76)',
#  '16': 'Chevrolet Laguna (75-74)',
#  '17': 'Chevrolet Malibu (75-74)',
#  '18': 'Chevrolet Monte Carlo (75-74)',
#  '19': 'GMC C15 (78-75)',
#  '20': 'GMC C15 Suburban (78), (75)',
#  '21': 'GMC C1500 (80-79)',
#  '22': 'GMC C1500 Suburban (80-79)',
#  '23': 'GMC C25 (78-75)',
#  '24': 'GMC C25 Suburban (78), (75)',
#  '25': 'GMC C2500 (86-79)',
#  '26': 'GMC C2500 Suburban (86-79)',
#  '27': 'GMC C35 (78-75)',
#  '28': 'GMC C3500 (86-79)',
#  '29': 'GMC Jimmy (76)',
#  '30': 'GMC K15 (76)',
#  '31': 'GMC K1500 (80)',
#  '32': 'GMC K25 (78-76)',
#  '33': 'GMC K25 Suburban (77-76)',
#  '34': 'GMC K3500 (86-79)',
#  '35': 'GMC Sprint (75-74)',
#  '36': 'Pontiac Bonneville (75)',
#  '37': 'Pontiac Catalina (75)',
#  '38': 'Pontiac Firebird (75)',
#  '39': 'Pontiac Grand Am (75)',
#  '40': 'Pontiac Grand LeMans (75)',
#  '41': 'Pontiac Grand Prix (75)',
#  '42': 'Pontiac Grand Safari (75)',
#  '43': 'Pontiac Grandville (75)',
#  '44': 'Pontiac LeMans (75)'}

# %%
dict_service = {}
list_service = json_['pp']['completeRepair']['serviceSpec']
for i, service in zip(range(len(list_service)), list_service):
    dict_service[str(i)] = service['serviceName'].strip()

dict_service
# Out:
# {'0': 'Fuel Filter Flush (Required)', '1': 'Oil Change (Required)'}

# %%
dict_spec = {}
list_spec = json_['pp']['partSpecs']
for i, spec in zip(range(len(list_spec)), list_spec):
    dict_spec[str(i)] = {spec['attributeName_en'].strip(): spec['siteValue_en'].strip()}

dict_spec
# Out:
# {'0': {'Warranty': '3 years/36,000 mile'},
#  '1': {'Performance Race Wire': 'Performance Race Wire'},
#  '2': {'Wire Set Import / Domestic': 'High Performance'},
#  '3': {'Wire Diameter (mm)': '8.5mm'},
#  '4': {'Core Construction': 'Mag Core'},
#  '5': {'Cylinders': '8'},
#  '6': {'Spark Plug Wire Lead 1': '27"'},
#  '7': {'Spark Plug Wire Lead 2': '29"'},
#  '8': {'Spark Plug Wire Lead 3': '29"'},
#  '9': {'Spark Plug Wire Lead 4': '29"'},
#  '10': {'Spark Plug Wire Lead 5': '34"'},
#  '11': {'Spark Plug Wire Lead 6': '36"'},
#  '12': {'Spark Plug Wire Lead 7': '37"'},
#  '13': {'Spark Plug Wire Lead 8': '40"'},
#  '14': {'Total Number of Leads': '8'}}

# %%
import json

df_temp['Json_Vehicle'] = json.dumps(dict_vehicle)
df_temp['Json_Service'] = json.dumps(dict_service)
df_temp['Json_Spec'] = json.dumps(dict_spec)

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    No Part Number                                                Url  rowId  \
# 0   1       10001  https://www.standardbrand.com/en/ecatalog?part...      1
#
#   site   webBase brand basePart          partDesc_en      partLongDesc_en  \
# 0  STD  WX_10001   BSW    10001  Spark Plug Wire Set  Spark Plug Wire Set
#
#    ... categoryName_en vehicleId  mfg mfG_Part maxRows brandLink imageUrl  \
# 0  ...                                               1
#
#                                         Json_Vehicle  \
# 0  {"0": "Chevrolet Bel Air (75-74)", "1": "Chevr...
#
#                                         Json_Service  \
# 0  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
#
#                                            Json_Spec
# 0  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
#
# [1 rows x 24 columns]

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#    No Part Number                                                Url  rowId  \
# 0   1       10001  https://www.standardbrand.com/en/ecatalog?part...      1
#
#   site   webBase brand basePart          partDesc_en      partLongDesc_en  \
# 0  STD  WX_10001   BSW    10001  Spark Plug Wire Set  Spark Plug Wire Set
#
#    ... categoryName_en vehicleId  mfg mfG_Part maxRows brandLink imageUrl  \
# 0  ...                                               1
#
#                                         Json_Vehicle  \
# 0  {"0": "Chevrolet Bel Air (75-74)", "1": "Chevr...
#
#                                         Json_Service  \
# 0  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
#
#                                            Json_Spec
# 0  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
#
# [1 rows x 24 columns]

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
