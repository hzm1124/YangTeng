# %% [markdown]
# # 1. RockAuto
#
# ## 1.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Specification'])
    for value in dict_.values():
        if len(list(value.values())) == 1:
            input_.loc[i, list(value.values())[0]] = True
        else:
            input_.loc[i, list(value.values())[0]] = list(value.values())[1]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|████████████████████████| 746/746 [00:00<00:00, 117035.75it/s]
#       No                 Group            Type Type Code Manufacturer  \
# 0      1  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 1      2  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 2      3  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 3      4  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 4      5  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# ..   ...                   ...             ...       ...          ...
# 741  742  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 742  743  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 743  744  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 744  745  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
# 745  746  Body & Lamp Assembly  Fog Lamp Bezel   1001224  VARIOUS MFR
#
#     Part Number       Note 1                        Json_Note 2 Choose  \
# 0     AC1038102               {"0": "Category: Fog Lamp Bezel"}
# 1     AC1038109               {"0": "Category: Fog Lamp Bezel"}
# 2     AC1038113               {"0": "Category: Fog Lamp Bezel"}
# 3     AC1038123               {"0": "Category: Fog Lamp Bezel"}
# 4     AC1039102               {"0": "Category: Fog Lamp Bezel"}
# ..          ...          ...                                ...    ...
# 741   VW1039152               {"0": "Category: Fog Lamp Bezel"}
# 742   VW1039157  Satin Black  {"0": "Category: Fog Lamp Bezel"}
# 743   VW1039160               {"0": "Category: Fog Lamp Bezel"}
# 744   VW1039164               {"0": "Category: Fog Lamp Bezel"}
# 745   VW1039165               {"0": "Category: Fog Lamp Bezel"}
#
#                    Json_Price                                         Vehicle  \
# 0     {"automatic": "$26.79"}                             ACURA RDX 2013-2015
# 1     {"automatic": "$29.79"}                             ACURA TSX 2011-2014
# 2     {"automatic": "$41.79"}                             ACURA RDX 2016-2018
# 3     {"automatic": "$19.26"}                             ACURA TSX 2009-2010
# 4     {"automatic": "$26.79"}                             ACURA RDX 2013-2015
# ..                        ...                                             ...
# 741  {"automatic": "$135.79"}                      VOLKSWAGEN ATLAS 2018-2020
# 742   {"automatic": "$36.79"}                      VOLKSWAGEN ATLAS 2018-2020
# 743    {"automatic": "$7.87"}                      VOLKSWAGEN JETTA 2019-2021
# 744   {"automatic": "$24.79"}  VOLKSWAGEN GOLF 2021\nVOLKSWAGEN GTI 2018-2020
# 745   {"automatic": "$42.99"}                      VOLKSWAGEN JETTA 2016-2018
#
#                                                    OEM Picture  \
# 0    71109TX4A11;AC1038102C;AC1038102D;AC1038102DSC...
# 1    71108TL0G50;AC1038109C;AC1038109D;AC1038109DSC...
# 2    71109TX4A81;AC1038113C;AC1038113D;AC1038113DSC...
# 3    71108TL0G00;AC1038123C;AC1038123D;AC1038123DSC...
# 4    71105TX4A11;AC1039102C;AC1039102D;AC1039102DSC...
# ..                                                 ...     ...
# 741  3CN853666BAV3;VW1039152C;VW1039152DSC;VW103915...
# 742  3CN853666A9B9;VW1039157C;VW1039157DSC;VW103915...
# 743  17A853666A9B9;VW1039160C;VW1039160DSC;VW103916...
# 744  5GM853212F9B9;VW1039164C;VW1039164DSC;VW103916...
# 745  5C6807262A;VW1039165C;VW1039165DSC;VW1039165N;...
#
#                                                    Url  \
# 0    https://www.rockauto.com/en/parts/various+mfr,...
# 1    https://www.rockauto.com/en/parts/various+mfr,...
# 2    https://www.rockauto.com/en/parts/various+mfr,...
# 3    https://www.rockauto.com/en/parts/various+mfr,...
# 4    https://www.rockauto.com/en/parts/various+mfr,...
# ..                                                 ...
# 741  https://www.rockauto.com/en/parts/various+mfr,...
# 742  https://www.rockauto.com/en/parts/various+mfr,...
# 743  https://www.rockauto.com/en/parts/various+mfr,...
# 744  https://www.rockauto.com/en/parts/various+mfr,...
# 745  https://www.rockauto.com/en/parts/various+mfr,...
#
#                                                   Info  \
# 0    https://www.rockauto.com/en/moreinfo.php?pk=57...
# 1    https://www.rockauto.com/en/moreinfo.php?pk=70...
# 2    https://www.rockauto.com/en/moreinfo.php?pk=88...
# 3    https://www.rockauto.com/en/moreinfo.php?pk=13...
# 4    https://www.rockauto.com/en/moreinfo.php?pk=57...
# ..                                                 ...
# 741  https://www.rockauto.com/en/moreinfo.php?pk=96...
# 742  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 743  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 744  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 745  https://www.rockauto.com/en/moreinfo.php?pk=10...
#
#                                               Json_Src Json_Specification  \
# 0    {"0": "https://www.rockauto.com/info/69/T2_AC1...                 {}
# 1    {"0": "https://www.rockauto.com/info/69/T2_AC1...                 {}
# 2    {"0": "https://www.rockauto.com/info/69/515235...                 {}
# 3    {"0": "https://www.rockauto.com/info/69/AC1038...                 {}
# 4    {"0": "https://www.rockauto.com/info/69/T2_AC1...                 {}
# ..                                                 ...                ...
# 741  {"0": "https://www.rockauto.com/info/69/VW1039...                 {}
# 742  {"0": "https://www.rockauto.com/info/69/T2_VW1...                 {}
# 743  {"0": "https://www.rockauto.com/info/69/842635...                 {}
# 744                                                 {}                 {}
# 745  {"0": "https://www.rockauto.com/info/69/VW1039...                 {}
#
#     Json_Kit Part Code                            JOIN_MPNTCPC
# 0         {}   5738535   VARIOUS MFR;AC1038102;1001224;5738535
# 1         {}   7065688   VARIOUS MFR;AC1038109;1001224;7065688
# 2         {}   8884140   VARIOUS MFR;AC1038113;1001224;8884140
# 3         {}  13924777  VARIOUS MFR;AC1038123;1001224;13924777
# 4         {}   5738547   VARIOUS MFR;AC1039102;1001224;5738547
# ..       ...       ...                                     ...
# 741       {}   9681248   VARIOUS MFR;VW1039152;1001224;9681248
# 742       {}  10170116  VARIOUS MFR;VW1039157;1001224;10170116
# 743       {}  10386756  VARIOUS MFR;VW1039160;1001224;10386756
# 744       {}  10529828  VARIOUS MFR;VW1039164;1001224;10529828
# 745       {}  10981208  VARIOUS MFR;VW1039165;1001224;10981208
#
# [746 rows x 20 columns]

# %% [markdown]
# ## 1.2. Kit

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

output = pd.DataFrame()
for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    json_ = json.loads(input_.loc[i, 'Json_Kit'])
    for j in range(len(json_)):
        df_temp = pd.concat([pd.DataFrame([input_.iloc[i]]).reset_index(drop=True), pd.DataFrame([{'Kit No': j+1}]), pd.DataFrame([json_[str(j)]])], axis=1).fillna('')
        output = pd.concat([output, df_temp], ignore_index=True).fillna('')

output.to_excel('./kit.xlsx', index=False)

output

# %% [markdown]
# # 2. Dorman
#
# ## 2.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Configuration'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2
# Out:
# Progress: 100%|███████████████████████████| 823/823 [00:03<00:00, 271.11it/s]
#       No Part Number                                        Vehicle Url Page  \
# 0      1     635-549  https://www.dormanproducts.com/itemdetailapp.a...    1
# 1      2     921-042  https://www.dormanproducts.com/itemdetailapp.a...    1
# 2      3     921-092  https://www.dormanproducts.com/itemdetailapp.a...    1
# 3      4     921-041  https://www.dormanproducts.com/itemdetailapp.a...    1
# 4      5     921-070  https://www.dormanproducts.com/itemdetailapp.a...    1
# ..   ...         ...                                                ...  ...
# 818  825     264-058  https://www.dormanproducts.com/itemdetailapp.a...    1
# 819  826     264-046  https://www.dormanproducts.com/itemdetailapp.a...    1
# 820  827     264-398  https://www.dormanproducts.com/itemdetailapp.a...    1
# 821  828     264-392  https://www.dormanproducts.com/itemdetailapp.a...    1
# 822  829     264-011  https://www.dormanproducts.com/itemdetailapp.a...    1
#
#     Row  Year        Make             Model  \
# 0     1  1997        Ford          F-250 HD
# 1     1  1998   Chevrolet                B7
# 2     1  2015  Volkswagen    Vento (Mexico)
# 3     1  2019    Cadillac               XTS
# 4     1  2002       Honda            Accord
# ..   ..   ...         ...               ...
# 818   1  1996        Ford   E-350 Econoline
# 819   1  2010        Ford  F-250 Super Duty
# 820   1  2018         BMW              640i
# 821   1  1987       Mazda               323
# 822   1  1997        Ford             F-150
#
#                                          Configuration Positions  \
# 0                                          V8 460 7.5L
# 1                        V8 366 6.0L; Engine Desg. LS0
# 2                          L4 98 1.6L (1598cc); DIESEL
# 3               V6 217 3.6L (3564cc); Engine Desg. LFX
# 4                                     L4 2.3L (2254cc)
# ..                                                 ...       ...
# 818                                        V8 445 7.3L
# 819                                        V8 391 6.4L     Lower
# 820                                   L6 3.0L (2979cc)
# 821                                   L4 1.6L (1597cc)
# 822  Naturally Aspirated; L6 300 4.9L (4917cc); VIN...
#
#            Application Notes  \
# 0    wo/California Emissions
# 1
# 2              Diesel Engine
# 3
# 4
# ..                       ...
# 818
# 819
# 820
# 821
# 822
#
#                                     Vehicle W/o Engine  \
# 0    Ford Country Sedan 1969-1974\nFord Country Squ...
# 1    Chevrolet B7 1993-1998\nChevrolet C5500 Kodiak...
# 2    Volkswagen Caddy 2011-2013\nVolkswagen Vento (...
# 3    Buick Allure 2010\nBuick LaCrosse 2010-2016\nC...
# 4    Acura CL 1997-1999\nHonda Accord 1994-2002\nHo...
# ..                                                 ...
# 818  Ford E-350 Econoline 1995-1996\nFord E-350 Eco...
# 819  Ford Excursion 2003-2005\nFord F-250 Super Dut...
# 820  BMW 528i 2011\nBMW 530i (Mexico) 2012-2013\nBM...
# 821                                Mazda 323 1986-1987
# 822  Ford Bronco 1983-1992\nFord E-100 Econoline 19...
#
#                                      Vehicle W/ Engine
# 0    Ford Country Sedan 1969-1970 V8 428 7.0L\nFord...
# 1    Chevrolet B7 1993-1998 V8 366 6.0L; Engine Des...
# 2    Volkswagen Caddy 2011-2013 L4 1.6L (1595cc); D...
# 3    Buick Allure 2010 V6 182 3.0L\nBuick LaCrosse ...
# 4    Acura CL 1997 L4 2.2L (2156cc)\nAcura CL 1998-...
# ..                                                 ...
# 818  Ford E-350 Econoline 1995-1996 V8 445 7.3L\nFo...
# 819  Ford Excursion 2003-2005 V8 363 6.0L\nFord F-2...
# 820  BMW 528i 2011 L6 183 3.0L (2996cc)\nBMW 528i 2...
# 821               Mazda 323 1986-1987 L4 1.6L (1597cc)
# 822  Ford Bronco 1983-1992 L6 300 4.9L (4917cc)\nFo...
#
# [823 rows x 13 columns]

# %% [markdown]
# ## 2.2. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Specification'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|███████████████████████████| 829/829 [00:02<00:00, 326.04it/s]
#       No                      Type Part Number                    Brand  \
# 0      1  Engine Oil Dipstick Tube     635-549    Dorman - OE Solutions
# 1      2       Engine Oil Dipstick     921-042  Dorman - HELP! - Bagged
# 2      3  Engine Oil Dipstick Tube     921-092  Dorman - HELP! - Bagged
# 3      4       Engine Oil Dipstick     921-041  Dorman - HELP! - Bagged
# 4      5       Engine Oil Dipstick     921-070  Dorman - HELP! - Bagged
# ..   ...                       ...         ...                      ...
# 824  825            Engine Oil Pan     264-058    Dorman - OE Solutions
# 825  826            Engine Oil Pan     264-046    Dorman - OE Solutions
# 826  827            Engine Oil Pan     264-398    Dorman - OE Solutions
# 827  828            Engine Oil Pan     264-392    Dorman - OE Solutions
# 828  829            Engine Oil Pan     264-011    Dorman - OE Solutions
#
#                           Description  \
# 0          Timing Cover Dipstick Tube
# 1                 Engine Oil Dipstick
# 2    Engine Oil Dipstick Tube - Metal
# 3                 Engine Oil Dipstick
# 4                 Engine Oil Dipstick
# ..                                ...
# 824                    Engine Oil Pan
# 825                    Engine Oil Pan
# 826                    Engine Oil Pan
# 827                    Engine Oil Pan
# 828                    Engine Oil Pan
#
#                                    Application Summary  \
# 0       Ford 1997-68, Lincoln 1978-68, Mercury 1978-69
# 1                       Chevrolet 1998-90, GMC 1998-90
# 2    Volkswagen Caddy 2013-11, Volkswagen Vento 201...
# 3    Buick 2016-12 & 2010, Cadillac 2019-10, Chevro...
# 4    Acura CL 1999-97, Honda Accord 2002-94, Honda ...
# ..                                                 ...
# 824                                       Ford 1996-94
# 825                                       Ford 2010-03
# 826                                        BMW 2018-10
# 827                                  Mazda 323 1987-86
# 828                                       Ford 1997-83
#
#                                                    OEM Picture  \
# 0
# 1                                             15691277
# 2                                         03L 103 634G
# 3                                             12657038
# 4                                          15650P0A013
# ..                                                 ...     ...
# 824         F4TZ6675A;F4TZ6675AAA;F5TZ6675A;F6TZ6675AA
# 825  1843912C91;3C3Z6675A;3C3Z6675AA;3C3Z6675DA;F3C...
# 826                                        11137556663
# 827                                         B63010400A
# 828   E8TZ 6675-B;F1TZ 6675-B;F6TZ 6675-LA;F7TZ 6710-B
#
#                                                    Url  \
# 0    https://www.dormanproducts.com/p-84478-635-549...
# 1    https://www.dormanproducts.com/p-103742-921-04...
# 2    https://www.dormanproducts.com/p-153406-921-09...
# 3    https://www.dormanproducts.com/p-101102-921-04...
# 4    https://www.dormanproducts.com/p-104155-921-07...
# ..                                                 ...
# 824  https://www.dormanproducts.com/p-65053-264-058...
# 825  https://www.dormanproducts.com/p-54061-264-046...
# 826  https://www.dormanproducts.com/p-133886-264-39...
# 827  https://www.dormanproducts.com/p-133880-264-39...
# 828  https://www.dormanproducts.com/p-25898-264-011...
#
#                                            Vehicle Url  ...  \
# 0    https://www.dormanproducts.com/itemdetailapp.a...  ...
# 1    https://www.dormanproducts.com/itemdetailapp.a...  ...
# 2    https://www.dormanproducts.com/itemdetailapp.a...  ...
# 3    https://www.dormanproducts.com/itemdetailapp.a...  ...
# 4    https://www.dormanproducts.com/itemdetailapp.a...  ...
# ..                                                 ...  ...
# 824  https://www.dormanproducts.com/itemdetailapp.a...  ...
# 825  https://www.dormanproducts.com/itemdetailapp.a...  ...
# 826  https://www.dormanproducts.com/itemdetailapp.a...  ...
# 827  https://www.dormanproducts.com/itemdetailapp.a...  ...
# 828  https://www.dormanproducts.com/itemdetailapp.a...  ...
#
#     Thermostat Included Contains Oil Baffles Cylinder Head Type  \
# 0                   NaN                  NaN                NaN
# 1                   NaN                  NaN                NaN
# 2                   NaN                  NaN                NaN
# 3                   NaN                  NaN                NaN
# 4                   NaN                  NaN                NaN
# ..                  ...                  ...                ...
# 824                 NaN                  NaN                NaN
# 825                 NaN                  NaN                NaN
# 826                 NaN                  NaN                NaN
# 827                 NaN                  NaN                NaN
# 828                 NaN                  NaN                NaN
#
#     Grommets Included Hold Down Tabs Included Inside Clearance Height  \
# 0                 NaN                     NaN                     NaN
# 1                 NaN                     NaN                     NaN
# 2                 NaN                     NaN                     NaN
# 3                 NaN                     NaN                     NaN
# 4                 NaN                     NaN                     NaN
# ..                ...                     ...                     ...
# 824               NaN                     NaN                     NaN
# 825               NaN                     NaN                     NaN
# 826               NaN                     NaN                     NaN
# 827               NaN                     NaN                     NaN
# 828               NaN                     NaN                     NaN
#
#     Material Thickness Oil Filler Cap Included Universal Or Specific Fit  \
# 0                  NaN                     NaN                       NaN
# 1                  NaN                     NaN                       NaN
# 2                  NaN                     NaN                       NaN
# 3                  NaN                     NaN                       NaN
# 4                  NaN                     NaN                       NaN
# ..                 ...                     ...                       ...
# 824                NaN                     NaN                       NaN
# 825                NaN                     NaN                       NaN
# 826                NaN                     NaN                       NaN
# 827                NaN                     NaN                       NaN
# 828                NaN                     NaN                       NaN
#
#     Valve Cover Type
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 824              NaN
# 825              NaN
# 826              NaN
# 827              NaN
# 828              NaN
#
# [829 rows x 97 columns]

# %% [markdown]
# # 3. eBay
#
# ## 3.1. Vehicle
#
# ### 3.1.1. US、UK、AU、CA

# %%
import pandas as pd

input_ = pd.read_excel('./crawler-vehicle.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Engine'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2
# Out:
# Progress: 100%|██████████████████████████| 4931/4931 [01:04<00:00, 76.39it/s]
#         No   Item Number                                 Json_Compatibility  \
# 0        1  304764803122  {"api": "https://www.ebay.com/g/api/finders", ...
# 1        2  305097008050  {"api": "https://www.ebay.com/g/api/finders", ...
# 2        3  304858818065  {"api": "https://www.ebay.com/g/api/finders", ...
# 3        4  305713071926  {"api": "https://www.ebay.com/g/api/finders", ...
# 4        5  126503897543  {"api": "https://www.ebay.com/g/api/finders", ...
# ...    ...           ...                                                ...
# 4926  9161  375458053171  {"api": "https://www.ebay.com/g/api/finders", ...
# 4927  9162  375458014040  {"api": "https://www.ebay.com/g/api/finders", ...
# 4928  9163  375458028528  {"api": "https://www.ebay.com/g/api/finders", ...
# 4929  9164  375458038725  {"api": "https://www.ebay.com/g/api/finders", ...
# 4930  9165  322965354977  {"api": "https://www.ebay.com/g/api/finders", ...
#
#      Page Row  Year    Make          Model  \
# 0       1   1  2017   Honda         Accord
# 1       1   1  2009   Honda           CR-V
# 2       1   1  2015   Honda          Civic
# 3       1   1  2024   Honda         Accord
# 4       1   1  2017   Honda         Accord
# ...   ...  ..   ...     ...            ...
# 4926    1   1  2005   Dodge       Ram 1500
# 4927    1   1  2008   Dodge       Ram 1500
# 4928    1   1  2014   Dodge  Grand Caravan
# 4929    1   1  2017  Toyota          Camry
# 4930    1   1  2006   Dodge  Sprinter 2500
#
#                                                    Trim  \
# 0                                     EX-L Coupe 2-Door
# 1                             EX-L Sport Utility 4-Door
# 2                                       DX Sedan 4-Door
# 3                                       EX Sedan 4-Door
# 4                                     EX-L Coupe 2-Door
# ...                                                 ...
# 4926                     Laramie Crew Cab Pickup 4-Door
# 4927                     Laramie Crew Cab Pickup 4-Door
# 4928  30th Anniversary Edition Mini Passenger Van 4-...
# 4929                             Hybrid LE Sedan 4-Door
# 4930                     Base Standard Cargo Van 3-Door
#
#                                                  Engine Notes Submodel  \
# 0     2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally A...
# 1     2.4L 2354CC 144Cu. In. l4 GAS DOHC Naturally A...
# 2           1.8L 1799CC l4 GAS SOHC Naturally Aspirated
# 3                  1.5L 1497CC l4 GAS DOHC Turbocharged
# 4     2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally A...
# ...                                                 ...   ...      ...
# 4926     5.7L 345Cu. In. V8 GAS OHV Naturally Aspirated
# 4927     5.7L 345Cu. In. V8 GAS OHV Naturally Aspirated
# 4928  3.6L 3604CC 220Cu. In. V6 FLEX DOHC Naturally ...
# 4929  2.5L 2494CC 152Cu. In. l4 FULL HYBRID EV-GAS (...
# 4930  2.7L 2687CC 165Cu. In. l5 DIESEL DOHC Turbocha...
#
#                                      Vehicle W/o Engine  \
# 0                                Honda Accord 2013-2017
# 1                                  Honda CR-V 2007-2009
# 2                                 Honda Civic 2012-2015
# 3                                Honda Accord 2023-2024
# 4                                Honda Accord 2013-2017
# ...                                                 ...
# 4926                           Dodge Ram 1500 2003-2005
# 4927                           Dodge Ram 1500 2003-2008
# 4928                      Dodge Grand Caravan 2012-2014
# 4929                             Toyota Camry 2015-2017
# 4930  Dodge Sprinter 2500 2004-2006\nDodge Sprinter ...
#
#                                       Vehicle W/ Engine
# 0     Honda Accord 2013-2017 2.4L 2356CC 144Cu. In. ...
# 1     Honda CR-V 2007-2009 2.4L 2354CC 144Cu. In. l4...
# 2     Honda Civic 2012-2015 1.8L 1799CC l4 CNG SOHC ...
# 3     Honda Accord 2023-2024 1.5L 1497CC l4 GAS DOHC...
# 4     Honda Accord 2013-2017 2.4L 2356CC 144Cu. In. ...
# ...                                                 ...
# 4926  Dodge Ram 1500 2003 5.9L 360Cu. In. V8 GAS OHV...
# 4927  Dodge Ram 1500 2003 5.9L 360Cu. In. V8 GAS OHV...
# 4928  Dodge Grand Caravan 2012-2014 3.6L 3604CC 220C...
# 4929  Toyota Camry 2015-2017 2.5L 2494CC 152Cu. In. ...
# 4930  Dodge Sprinter 2500 2004-2006 2.7L 2687CC 165C...
#
# [4931 rows x 14 columns]

# %% [markdown]
# ### 3.1.2. DE

# %%
import pandas as pd

input_ = pd.read_excel('./crawler-vehicle.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year, year_2 = df_temp.loc[j, 'Marke'], df_temp.loc[j, 'Modell'], df_temp.loc[j, 'Motor'], int(df_temp.loc[j, 'Baujahr'].split('-')[0].split('/')[0]), int(df_temp.loc[j, 'Baujahr'].split('-')[1].split('/')[0])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year] if year == year_2 else [year, year_2]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year] if year == year_2 else [year, year_2]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year] if year == year_2 else [year, year_2]
        else:
            if year not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year)
            if year_2 not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year_2)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ## 3.2 Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Specific'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress:   0%|                                     | 0/7541 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Json_Specific'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 15
#      12 import json
#      14 for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
# ---> 15     dict_ = json.loads(input_.loc[i, 'Json_Specific'])
#      16     for value in dict_.values():
#      17         input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
#
# File ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/frame.py:4214, in DataFrame._get_value(self, index, col, takeable)
#    4211     series = self._ixs(col, axis=1)
#    4212     return series._values[index]
# -> 4214 series = self._get_item_cache(col)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/frame.py:4638, in DataFrame._get_item_cache(self, item)
#    4633 res = cache.get(item)
#    4634 if res is None:
#    4635     # All places that call _get_item_cache have unique columns,
#    4636     #  pending resolution of GH#33047
# -> 4638     loc = self.columns.get_loc(item)
#    4639     res = self._ixs(loc, axis=1)
#    4641     cache[item] = res
#
# File ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Json_Specific'

# %% [markdown]
# # 4. Cardone
#
# ## 4.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], ' '.join([df_temp.loc[j, 'Cylinder'], df_temp.loc[j, 'Displacement'], df_temp.loc[j, 'Liter']]), int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ## 4.2. Json

# %%
# input_ = pd.read_excel('crawler.xlsx',
#                        header=0,
#                        dtype=str).fillna('')

# input_

# import json

# for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
#     dict_ = json.loads(input_.loc[i, 'Json_Info'])
#     for value in dict_.values():
#         input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

# input_.to_excel('./json.xlsx', index=False)

# input_

# %% [markdown]
# # 5. Standard
#
# ## 5.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Vehicle'])
    vehicle = ''
    for value in dict_.values():
        vehicle += f'{value}\n'

    input_.loc[i, 'Vehicle'] = vehicle.strip()

# = = = = = = = = = = = = = = =

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|██████████████████████████| 392/392 [00:00<00:00, 6865.74it/s]
#       No Part Number brand partDesc_en pop qtyEach Picture  \
# 0      1        BF41   STD   PCV Valve   F       1
# 1      2      G16001   TEC   PCV Valve   D       1
# 2      3      G16004   TEC   PCV Valve   F       1
# 3      4        GV33   STD   PCV Valve   C       1
# 4      5      N16001   TEC   PCV Valve   A       1
# ..   ...         ...   ...         ...  ..     ...     ...
# 387  388        V752   STI   PCV Valve   F       1
# 388  389        V754   STI   PCV Valve   F       1
# 389  390        V801   STI   PCV Valve   F       1
# 390  391      Z16003   TEC   PCV Valve   F       1
# 391  392      Z58001   TEC   PCV Valve   C       1
#
#                                                    Url  \
# 0    https://www.standardbrand.com/en/ecatalog?part...
# 1    https://www.standardbrand.com/en/ecatalog?part...
# 2    https://www.standardbrand.com/en/ecatalog?part...
# 3    https://www.standardbrand.com/en/ecatalog?part...
# 4    https://www.standardbrand.com/en/ecatalog?part...
# ..                                                 ...
# 387  https://www.standardbrand.com/en/ecatalog?part...
# 388  https://www.standardbrand.com/en/ecatalog?part...
# 389  https://www.standardbrand.com/en/ecatalog?part...
# 390  https://www.standardbrand.com/en/ecatalog?part...
# 391  https://www.standardbrand.com/en/ecatalog?part...
#
#                                                Service             Warranty  \
# 0    1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 1    1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 2    1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 3    1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 4    1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# ..                                                 ...                  ...
# 387  1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 388  1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 389  1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 390  1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
# 391  1. Fuel Filter Flush (Required)\n2. Oil Change...  3 years/36,000 mile
#
#      ... Terminal Type Thread Size (in) Connector Type Thread Size - Metric  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...           ...              ...            ...                  ...
# 387  ...
# 388  ...                                      Screw-in
# 389  ...
# 390  ...
# 391  ...
#
#     Thread Size - NPT                                       Json_Vehicle  \
# 0                      {"0": "Chevrolet C1500 (98-96)", "1": "Chevrol...
# 1                      {"0": "Audi A4 (05-01)", "1": "Audi A4 Quattro...
# 2                      {"0": "Audi A4 (05-02)", "1": "Audi A4 Quattro...
# 3                                   {"0": "Jeep Grand Cherokee (04-01)"}
# 4                      {"0": "Audi A3 (08-05)", "1": "Audi A4 (08-06)...
# ..                ...                                                ...
# 387                    {"0": "Honda Accord (21-18)", "1": "Honda Civi...
# 388                    {"0": "Nissan Altima (23-19)", "1": "Nissan Ro...
# 389                    {"0": "BMW 545i (05-04)", "1": "BMW 550i (10-0...
# 390                    {"0": "BMW 540i (03-97)", "1": "BMW 740i (01-9...
# 391                    {"0": "Ford Expedition (04-03)", "1": "Ford F-...
#
#                                           Json_Service  \
# 0    {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 1    {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 2    {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 3    {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 4    {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# ..                                                 ...
# 387  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 388  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 389  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 390  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 391  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
#
#                                              Json_Spec  \
# 0    {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 1    {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 2    {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 3    {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 4    {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# ..                                                 ...
# 387  {"0": {"End 1 Gender": "Male"}, "1": {"Hose Co...
# 388  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 389  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 390  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 391  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
#
#                                               Json_Src  \
# 0    {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 1    {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 2    {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 3    {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 4    {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# ..                                                 ...
# 387  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 388  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 389  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 390  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 391  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
#
#                                                Vehicle
# 0    Chevrolet C1500 (98-96)\nChevrolet C1500 Subur...
# 1    Audi A4 (05-01)\nAudi A4 Quattro (05)\nVolkswa...
# 2    Audi A4 (05-02)\nAudi A4 Quattro (05-02)\nAudi...
# 3                          Jeep Grand Cherokee (04-01)
# 4    Audi A3 (08-05)\nAudi A4 (08-06)\nAudi A4 Quat...
# ..                                                 ...
# 387          Honda Accord (21-18)\nHonda Civic (21-17)
# 388        Nissan Altima (23-19)\nNissan Rogue (23-20)
# 389  BMW 545i (05-04)\nBMW 550i (10-06)\nBMW 645Ci ...
# 390  BMW 540i (03-97)\nBMW 740i (01-97)\nBMW 740iL ...
# 391  Ford Expedition (04-03)\nFord F-150 (03-02)\nL...
#
# [392 rows x 46 columns]

# %% [markdown]
# ## 5.2. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    service, dict_ = '', json.loads(input_.loc[i, 'Json_Service'])
    for k, v in dict_.items():
        service += f'{int(k)+1}. {v}\n'
    input_.loc[i, 'Service'] = service.strip()

    dict_ = json.loads(input_.loc[i, 'Json_Spec'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|███████████████████████████| 392/392 [00:00<00:00, 429.98it/s]
#       No Part Number brand partDesc_en pop qtyEach Picture  \
# 0      1        BF41   STD   PCV Valve   F       1
# 1      2      G16001   TEC   PCV Valve   D       1
# 2      3      G16004   TEC   PCV Valve   F       1
# 3      4        GV33   STD   PCV Valve   C       1
# 4      5      N16001   TEC   PCV Valve   A       1
# ..   ...         ...   ...         ...  ..     ...     ...
# 387  388        V752   STI   PCV Valve   F       1
# 388  389        V754   STI   PCV Valve   F       1
# 389  390        V801   STI   PCV Valve   F       1
# 390  391      Z16003   TEC   PCV Valve   F       1
# 391  392      Z58001   TEC   PCV Valve   C       1
#
#                                                    Url  \
# 0    https://www.standardbrand.com/en/ecatalog?part...
# 1    https://www.standardbrand.com/en/ecatalog?part...
# 2    https://www.standardbrand.com/en/ecatalog?part...
# 3    https://www.standardbrand.com/en/ecatalog?part...
# 4    https://www.standardbrand.com/en/ecatalog?part...
# ..                                                 ...
# 387  https://www.standardbrand.com/en/ecatalog?part...
# 388  https://www.standardbrand.com/en/ecatalog?part...
# 389  https://www.standardbrand.com/en/ecatalog?part...
# 390  https://www.standardbrand.com/en/ecatalog?part...
# 391  https://www.standardbrand.com/en/ecatalog?part...
#
#                                           Json_Vehicle  \
# 0    {"0": "Chevrolet C1500 (98-96)", "1": "Chevrol...
# 1    {"0": "Audi A4 (05-01)", "1": "Audi A4 Quattro...
# 2    {"0": "Audi A4 (05-02)", "1": "Audi A4 Quattro...
# 3                 {"0": "Jeep Grand Cherokee (04-01)"}
# 4    {"0": "Audi A3 (08-05)", "1": "Audi A4 (08-06)...
# ..                                                 ...
# 387  {"0": "Honda Accord (21-18)", "1": "Honda Civi...
# 388  {"0": "Nissan Altima (23-19)", "1": "Nissan Ro...
# 389  {"0": "BMW 545i (05-04)", "1": "BMW 550i (10-0...
# 390  {"0": "BMW 540i (03-97)", "1": "BMW 740i (01-9...
# 391  {"0": "Ford Expedition (04-03)", "1": "Ford F-...
#
#                                           Json_Service  ... Voltage  \
# 0    {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 1    {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 2    {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 3    {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 4    {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# ..                                                 ...  ...     ...
# 387  {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 388  {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 389  {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 390  {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...     NaN
# 391  {"0": "Fuel Filter Flush (Required)", "1": "Oi...  ...      12
#
#     Thread Size (mm) Terminal Quantity Notes Terminal Gender Terminal Type  \
# 0                NaN               NaN   NaN             NaN           NaN
# 1                NaN               NaN   NaN             NaN           NaN
# 2                NaN               NaN   NaN             NaN           NaN
# 3                NaN               NaN   NaN             NaN           NaN
# 4                NaN               NaN   NaN             NaN           NaN
# ..               ...               ...   ...             ...           ...
# 387              NaN               NaN   NaN             NaN           NaN
# 388              NaN               NaN   NaN             NaN           NaN
# 389              NaN                 0   NaN             NaN           NaN
# 390              NaN               NaN   NaN             NaN           NaN
# 391              NaN               NaN   NaN             NaN           NaN
#
#     Thread Size (in) Connector Type Thread Size - Metric Thread Size - NPT
# 0                NaN            NaN                  NaN               NaN
# 1                NaN            NaN                  NaN               NaN
# 2                NaN            NaN                  NaN               NaN
# 3                NaN            NaN                  NaN               NaN
# 4                NaN            NaN                  NaN               NaN
# ..               ...            ...                  ...               ...
# 387              NaN            NaN                  NaN               NaN
# 388              NaN       Screw-in                  NaN               NaN
# 389              NaN            NaN                  NaN               NaN
# 390              NaN            NaN                  NaN               NaN
# 391              NaN            NaN                  NaN               NaN
#
# [392 rows x 45 columns]

# %% [markdown]
# # 7. SpectraPremium
#
# ## 7.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make_model_engine, year = df_temp.loc[j, 'Make Model Engine'], int(df_temp.loc[j, 'Year'])

        if make_model_engine not in dict_vehicle:
            dict_vehicle[make_model_engine] = [year]
        elif year not in dict_vehicle[make_model_engine]:
            dict_vehicle[make_model_engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make_model_engine in dict_vehicle:
        year_begin = min(dict_vehicle[make_model_engine])
        year_end = max(dict_vehicle[make_model_engine])
        list_vehicle.append(f'{make_model_engine}'.strip() if year_begin == year_end else f'{make_model_engine} {year_begin}-{year_end}'.strip())

    input_2.loc[i, 'Vehicle'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 12. 1AAuto
#
# ## 12.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Description'])
    for value in dict_.values():
        if type(list(value.values())[0]) == dict:
            str_ = ''
            for k, v in list(value.values())[0].items():
                str_ += f'{int(k)+1}. {v}\n'
            input_.loc[i, list(value.keys())[0]] = str_.strip()
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|████████████████████████| 1384/1384 [00:00<00:00, 3362.02it/s]
#         No              Type      Part Number                 Brand       Tag  \
# 0        1  Weatherstripping            T3011  Fairchild Automotive  Replaces
# 1        2  Weatherstripping            TK 70   Metro Moulded Parts  Replaces
# 2        3  Weatherstripping       1AWSK00236  Fairchild Automotive  Replaces
# 3        4  Weatherstripping            F3033  Fairchild Automotive  Replaces
# 4        5  Weatherstripping         WSA74804                   TRQ  Replaces
# ...    ...               ...              ...                   ...       ...
# 1379  1380  Weatherstripping      68160-89116            Toyota OEM  Replaces
# 1380  1381  Weatherstripping     NA01-58-810F                 Mazda  Replaces
# 1381  1382  Weatherstripping  5L1Z-7851884-AA              Ford OEM  Replaces
# 1382  1383  Weatherstripping    F81Z2520758AA              Ford OEM  Replaces
# 1383  1384  Weatherstripping    F81Z2521453AA              Ford OEM  Replaces
#
#                                                   Title         SKU  \
# 0     1995-00 Toyota Tacoma Front Body Mounted Door ...  1AWSD00639
# 1     1996-00 Honda Civic 4 Door Sedan Trunk Weather...  1AWST00056
# 2     1991-00 Ford Explorer 2 Door Door Weatherstrip...  1AWSK00236
# 3     1991-00 Ford Explorer 2 Door Door Weatherstrip...  1AWSD00347
# 4     1995-00 Toyota Tacoma Front Body Mounted Door ...  1AWSD00898
# ...                                                 ...         ...
# 1379  Toyota 4Runner Pickup Window Sweep Toyota OEM ...  TYWSD00001
# 1380  Mazda Miata Passenger Side Outer Window Sweep ...  MZWSD00002
# 1381  Ford Lincoln Sunroof Glass Edge Weatherstrip S...  FDWSX00001
# 1382  Ford Front Door Weatherstrip Seal Kit Ford OEM...  FDWSD00001
# 1383  Ford Front Driver Side Outer Window Sweep Ford...  FDWSS00002
#
#            Price  Rating Rating Count  ...     Quantity  \
# 0      USD 72.95  5/ 5.0            1  ...          NaN
# 1      USD 59.95  5/ 5.0            1  ...          NaN
# 2      USD 56.02                    0  ...  2 Piece Set
# 3      USD 40.33                    0  ...          NaN
# 4      USD 71.95                    0  ...          NaN
# ...          ...     ...          ...  ...          ...
# 1379   USD 42.45  5/ 5.0            1  ...          NaN
# 1380  USD 149.52                    0  ...          NaN
# 1381  USD 155.45  5/ 5.0            1  ...          NaN
# 1382   USD 49.95  5/ 5.0            1  ...          NaN
# 1383   USD 78.95                    0  ...          NaN
#
#                      Kit Includes Color Includes Design Material  \
# 0                             NaN   NaN      NaN    NaN      NaN
# 1                             NaN   NaN      NaN    NaN      NaN
# 2     (2) Door Weatherstrip Seals   NaN      NaN    NaN      NaN
# 3                             NaN   NaN      NaN    NaN      NaN
# 4                             NaN   NaN      NaN    NaN      NaN
# ...                           ...   ...      ...    ...      ...
# 1379                          NaN   NaN      NaN    NaN      NaN
# 1380                          NaN   NaN      NaN    NaN      NaN
# 1381                          NaN   NaN      NaN    NaN      NaN
# 1382                          NaN   NaN      NaN    NaN      NaN
# 1383                          NaN   NaN      NaN    NaN      NaN
#
#      Housing Color Manufacturing Process Product Grade Body Trim Clip Type
# 0              NaN                   NaN           NaN                 NaN
# 1              NaN                   NaN           NaN                 NaN
# 2              NaN                   NaN           NaN                 NaN
# 3              NaN                   NaN           NaN                 NaN
# 4              NaN                   NaN           NaN                 NaN
# ...            ...                   ...           ...                 ...
# 1379           NaN                   NaN           NaN                 NaN
# 1380           NaN                   NaN           NaN                 NaN
# 1381           NaN                   NaN           NaN                 NaN
# 1382           NaN                   NaN           NaN                 NaN
# 1383           NaN                   NaN           NaN                 NaN
#
# [1384 rows x 27 columns]

# %% [markdown]
# # 18. Auveco
#
# ## 18.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Description'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress: 100%|███████████████████████████| 124/124 [00:00<00:00, 540.74it/s]
#       No    SKU                                              Title  \
# 0      1  25468  Hood Latch Mounting T-30 Torx® Round Undercut ...
# 1      2  25467  Headlamp & Radiator Support Torx® Button Head ...
# 2      3  25044  Ford 1999-2016 Replacement Bed Bolts M14-2.0 x...
# 3      4  25043  Ford 1999-2016 Replacement Bed Bolts M14-2.0 x...
# 4      5  25042  Ford 1999-2016 Replacement Bed Bolts M14-2.0 x...
# ..   ...    ...                                                ...
# 119  120   5713  5/16"-18 x 1-1/4" Indented Hex Large Flange Wa...
# 120  121   5711  5/16"-18 x 1" Indented Hex Large Flange Washer...
# 121  122   3615    5/16"-18 x 3/4" Hex Washer Head Spin Lock Bolts
# 122  123   2753      1/4"-20 x 5/8" Hex Washer Head Spin Lock Bolt
# 123  124   2688  5/16"-24 x 1" Indented Hex Washer Head Spin-Lo...
#
#                            OEM Picture  \
# 0
# 1
# 2    W714264-S902;W714264?S902
# 3    W714263-S902;W714263?S902
# 4    W714262-S902;W714262?S902
# ..                         ...     ...
# 119
# 120
# 121
# 122
# 123
#
#                                                    Url  \
# 0    https://www.auveco.com/hood-latch-mounting-tor...
# 1    https://www.auveco.com/headlamp-radiator-suppo...
# 2    https://www.auveco.com/ford-truck-bed-mounting...
# 3    https://www.auveco.com/ford-truck-bed-mounting...
# 4    https://www.auveco.com/ford-truck-bed-mounting...
# ..                                                 ...
# 119  https://www.auveco.com/5-16-18-x-1-1-4-ind-hex...
# 120  https://www.auveco.com/5-16-18-x-1ind-hex-lrg-...
# 121  https://www.auveco.com/5-16-18-x-3-4-hex-washe...
# 122  https://www.auveco.com/1-4-20-x-5-8-hex-washer...
# 123  https://www.auveco.com/5-16-24-x-1-ind-hex-was...
#
#                                               Json_Src  \
# 0    {"0": "https://www.auveco.com/site/item-images...
# 1    {"0": "https://www.auveco.com/site/item-images...
# 2    {"0": "https://www.auveco.com/site/item-images...
# 3    {"0": "https://www.auveco.com/site/item-images...
# 4    {"0": "https://www.auveco.com/site/item-images...
# ..                                                 ...
# 119  {"0": "https://www.auveco.com/site/item-images...
# 120  {"0": "https://www.auveco.com/site/item-images...
# 121  {"0": "https://www.auveco.com/site/item-images...
# 122  {"0": "https://www.auveco.com/site/item-images...
# 123  {"0": "https://www.auveco.com/site/item-images...
#
#                                       Json_Description Pcs/Unit  \
# 0    {"0": {"Pcs/Unit": "25"}, "1": {"Screw Size": ...       25
# 1    {"0": {"Pcs/Unit": "25"}, "1": {"Screw Size": ...       25
# 2    {"0": {"Pcs/Unit": "2"}, "1": {"Screw Size": "...        2
# 3    {"0": {"Pcs/Unit": "2"}, "1": {"Screw Size": "...        2
# 4    {"0": {"Pcs/Unit": "2"}, "1": {"Screw Size": "...        2
# ..                                                 ...      ...
# 119  {"0": {"Pcs/Unit": "50"}, "1": {"Head Style": ...       50
# 120  {"0": {"Pcs/Unit": "50"}, "1": {"Head Style": ...       50
# 121  {"0": {"Pcs/Unit": "100"}, "1": {"Head Style":...      100
# 122  {"0": {"Pcs/Unit": "100"}, "1": {"Head Style":...      100
# 123  {"0": {"Pcs/Unit": "50"}, "1": {"Head Style": ...       50
#
#           Screw Size  ... Includes Head Diameter Shoulder Diameter  \
# 0      M6-1.0 x 32mm  ...      NaN           NaN               NaN
# 1             M6-1.0  ...      NaN           NaN               NaN
# 2    M14-2.0 x 108mm  ...      NaN           NaN               NaN
# 3    M14-2.0 x 138mm  ...      NaN           NaN               NaN
# 4    M14-2.0 x 138mm  ...      NaN           NaN               NaN
# ..               ...  ...      ...           ...               ...
# 119              NaN  ...      NaN           NaN               NaN
# 120              NaN  ...      NaN           NaN               NaN
# 121              NaN  ...      NaN           NaN               NaN
# 122              NaN  ...      NaN           NaN               NaN
# 123              NaN  ...      NaN           NaN               NaN
#
#     Flange Diameter Color Size Hex Size Head Size Screw Type Grade
# 0               NaN   NaN  NaN      NaN       NaN        NaN   NaN
# 1               NaN   NaN  NaN      NaN       NaN        NaN   NaN
# 2               NaN   NaN  NaN      NaN       NaN        NaN   NaN
# 3               NaN   NaN  NaN      NaN       NaN        NaN   NaN
# 4               NaN   NaN  NaN      NaN       NaN        NaN   NaN
# ..              ...   ...  ...      ...       ...        ...   ...
# 119             NaN   NaN  NaN  1/2 in.       NaN        NaN     2
# 120             NaN   NaN  NaN  1/2 in.       NaN        NaN     2
# 121             NaN   NaN  NaN  1/2 in.       NaN        NaN     2
# 122             NaN   NaN  NaN  3/8 in.       NaN        NaN     2
# 123             NaN   NaN  NaN  1/2 in.       NaN        NaN     2
#
# [124 rows x 33 columns]

# %% [markdown]
# # 24.Gates
#
# ## 24.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Product No'] = input_['Product No'].astype(int)
input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Information'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_
# Out:
# Progress:  68%|████████████████▉        | 1263/1864 [00:05<00:03, 154.85it/s]/var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# Progress:  69%|█████████████████▏       | 1280/1864 [00:05<00:03, 156.91it/s]/var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# Progress:  71%|█████████████████▋       | 1320/1864 [00:05<00:02, 222.36it/s]/var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# Progress:  96%|████████████████████████ | 1792/1864 [00:06<00:00, 406.86it/s]/var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_69755/3210954159.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   input_.loc[i, list(value.keys())[0]] = list(value.values())[0]
# Progress: 100%|█████████████████████████| 1864/1864 [00:06<00:00, 276.08it/s]
#      Product No                                       Product Name  \
# 0             1  1-1/4" Special One-Piece Couplings - Female JI...
# 1             1  1-1/4" Special One-Piece Couplings - Female JI...
# 2             1  1-1/4" Special One-Piece Couplings - Female JI...
# 3             1  1-1/4" Special One-Piece Couplings - Female JI...
# 4             1  1-1/4" Special One-Piece Couplings - Female JI...
# ...         ...                                                ...
# 1859        100                     Food Master™ Beverage 250SD CR
# 1860        100                     Food Master™ Beverage 250SD CR
# 1861        100                     Food Master™ Beverage 250SD CR
# 1862        100                     Food Master™ Beverage 250SD CR
# 1863        100                     Food Master™ Beverage 250SD CR
#
#           Product Number  No                      Part Number    Part Code  \
# 0     7347-000000-000575   1  G21100-2020X / 20MGS-20MP XBULK   7347-08600
# 1     7347-000000-000575   2         G21100-2020 / 20MGS-20MP  7347-086005
# 2     7347-000000-000575   3         G21165-2020 / 20MGS-20MJ  7347-086015
# 3     7347-000000-000575   4  G21307-2020 / 20MGS-20FL45S-032  7347-086075
# 4     7347-000000-000575   5  G21315-2020 / 20MGS-20FL90M-090  7347-086085
# ...                  ...  ..                              ...          ...
# 1859  3132-000000-000004  10     1X50 FOOD XTREME 250SD WHITE     31325023
# 1860  3132-000000-000004  11   1-1/2X50 FOOD XTREME 250SD WHI     31325024
# 1861  3132-000000-000004  12     2X50 FOOD XTREME 250SD WHITE     31325025
# 1862  3132-000000-000004  13   2-1/2X50 FOOD XTREME 250SD WHI     31325026
# 1863  3132-000000-000004  14     3X50 FOOD XTREME 250SD WHITE     31325027
#
#                         Type        SKU           UPC  \
# 0     CouplingVariantProduct   73478600  072053974515
# 1     CouplingVariantProduct  734786005  072053699807
# 2     CouplingVariantProduct  734786015  072053737318
# 3     CouplingVariantProduct  734786075  072053700022
# 4     CouplingVariantProduct  734786085  072053700015
# ...                      ...        ...           ...
# 1859      HoseVariantProduct   31325023
# 1860      HoseVariantProduct   31325024
# 1861      HoseVariantProduct   31325025
# 1862      HoseVariantProduct   31325026
# 1863      HoseVariantProduct   31325027
#
#                                              Title  ...  \
# 0                    G21100-2020X 20MGS-20MP XBULK  ...
# 1                           G21100-2020 20MGS-20MP  ...
# 2                           G21165-2020 20MGS-20MJ  ...
# 3                    G21307-2020 20MGS-20FL45S-032  ...
# 4                    G21315-2020 20MGS-20FL90M-090  ...
# ...                                            ...  ...
# 1859      1X50FT FOOD MASTER XTREME 250SD CR WHITE  ...
# 1860  1 1/2X50FT FOOD MASTER XTREME 250SD CR WHITE  ...
# 1861      2X50FT FOOD MASTER XTREME 250SD CR WHITE  ...
# 1862  2 1/2X50FT FOOD MASTER XTREME 250SD CR WHITE  ...
# 1863      3X50FT FOOD MASTER XTREME 250SD CR WHITE  ...
#
#      Inside Diameter 1 (in) Inside Diameter 1 (mm) Inside Diameter 3 (in)  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 1859                    NaN                    NaN                    NaN
# 1860                    NaN                    NaN                    NaN
# 1861                    NaN                    NaN                    NaN
# 1862                    NaN                    NaN                    NaN
# 1863                    NaN                    NaN                    NaN
#
#      Inside Diameter 3 (mm) Inside Diameter 4 (in) Inside Diameter 4 (mm)  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 1859                    NaN                    NaN                    NaN
# 1860                    NaN                    NaN                    NaN
# 1861                    NaN                    NaN                    NaN
# 1862                    NaN                    NaN                    NaN
# 1863                    NaN                    NaN                    NaN
#
#      Inside Diameter 5 (in) Inside Diameter 5 (mm) A (in) B (in)
# 0                       NaN                    NaN    NaN    NaN
# 1                       NaN                    NaN    NaN    NaN
# 2                       NaN                    NaN    NaN    NaN
# 3                       NaN                    NaN    NaN    NaN
# 4                       NaN                    NaN    NaN    NaN
# ...                     ...                    ...    ...    ...
# 1859                    NaN                    NaN    NaN    NaN
# 1860                    NaN                    NaN    NaN    NaN
# 1861                    NaN                    NaN    NaN    NaN
# 1862                    NaN                    NaN    NaN    NaN
# 1863                    NaN                    NaN    NaN    NaN
#
# [1864 rows x 122 columns]

# %% [markdown]
# # 30.TecDoc
#
# ## 30.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
from datetime import datetime

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year, year_2 = df_temp.loc[j, 'manuDesc'], df_temp.loc[j, 'modelDesc'], df_temp.loc[j, 'carDesc'], int(str(df_temp.loc[j, 'yearOfConstructionFrom'][:4])), int(datetime.now().strftime('%Y') if df_temp.loc[j, 'yearOfConstructionTo'] == '' else str(df_temp.loc[j, 'yearOfConstructionTo'][:4]))

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year] if year == year_2 else [year, year_2]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year] if year == year_2 else [year, year_2]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year] if year == year_2 else [year, year_2]
        else:
            if year not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year)
            if year_2 not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year_2)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 10. Amazon

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_

# %%
import json

for i in range(len(input_)):
    dict_ = json.loads(input_.loc[i, 'Json_Overview'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 1'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 2'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 1'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 2'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./fuck.xlsx', index=False)

input_
