# %%
import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# %%
input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
input_['Url'].tolist()
# Out:
# 总数量：11
# ['https://ecat.spectrapremium.com/en/parts/CATP04A',
#  'https://ecat.spectrapremium.com/en/parts/CRP01A',
#  'https://ecat.spectrapremium.com/en/parts/CRP03B',
#  'https://ecat.spectrapremium.com/en/parts/FP66A',
#  'https://ecat.spectrapremium.com/en/parts/GMP40B',
#  'https://ecat.spectrapremium.com/en/parts/GMP66C',
#  'https://ecat.spectrapremium.com/en/parts/HOP20A',
#  'https://ecat.spectrapremium.com/en/parts/NSP29A',
#  'https://ecat.spectrapremium.com/en/parts/NSP31A',
#  'https://ecat.spectrapremium.com/en/parts/SUP06A',
#  'https://ecat.spectrapremium.com/en/parts/VWP35A']

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 0

resp = requests.get(input_.loc[a, 'Url'],
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta charset="utf-8">    <link href="/safari-pinned-tab.svg" color="#036" rel="mask-icon">    <meta content="ie=edge" http-equiv="x-ua-compatible">    <meta name="description" content="Spectra Premium believes in a green and sustainable economy. That&#039;s why it uses its core competencies of metallurgical transformation, heat transfer and high quality assembly capacity, as well as its extensive expertise, to stand out in the booming vehicle electrification sector in Quebec.">    <link href="/favicon.ico" type="image/x-icon" rel="icon"><link href="/favicon.ico" type="image/x-icon" rel="shortcut icon">    <link href="/apple-touch-icon.png" rel="apple-touch-icon">    <link href="/manifest.php?locale=en" rel="manifest">    <link href="https://fonts.googleapis.com" rel="preconnect">    <link href="https://fonts.gstatic.com" crossorigin="" rel="preconnect">    <meta name="msapplication-TileColor" content="#036">    <meta property="og:image" content="https://ecat.spectrapremium.com/logo-spectra--open-graph.jpg">    <meta property="og:title" content="CATP04A">    <meta property="og:type" content="website">    <meta property="og:url" content="https://ecat.spectrapremium.com/en/parts/CATP04A">    <meta name="theme-color" content="#036">    <meta name="viewport" content="width=device-width, initial-scale=1">                <style>:root { --view:\'View\'; --year:\'Year\'; --fuel:\'Fuel\'; --fueldel:\'Fuel Del.\'; --asp:\'ASP.\'; --engvin:\'Eng. VIN\'; --engdesg:\'Eng. Desg.\'; --cc:\'CC\'; --cid:\'CID\'; }</style>\n                <link rel="stylesheet" href="/css/pages/part.css?id=38a39161e4270f1992b91d7e69081719">    <title>CATP04A</title>\n            <!-- Google Tag Manager (head du document) -->\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-MHFHCJL\');</script>\n\n<!-- End Google Tag Manager -->\n        <script src="https://www.google.com/recaptcha/api.js?hl=en" async="async" defer="defer"></script></head>\n<body class="produits view part">\n            <!-- Google Tag Manager (noscript) -->\n\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MHFHCJL"\nheight="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n\n<!-- End Google Tag Manager (noscript) -->\n            <header class="header">\n    <nav class="header__nav">\n        <a href="/en">\n            <picture>\n                <source media="(max-width: 767px)" srcset="/img/logo-spectra--small.svg">\n                <source media="(min-width: 768px)" srcset="/img/logo-spectra--medium.svg">\n                <img src="/img/logo-spectra--medium.svg" alt="Spectra Premium" class="header__logo" height="42" width="161">            </picture>\n        </a>\n        <div class="header__colonne-droite">\n                            <button id="login-btn" class="btn btn--login">Login</button>\n                <form method="post" accept-charset="utf-8" class="form header__login-form" id="login-form" action="/en/users/login"><div style="display:none;"><input class="input input--hidden" type="hidden" name="_csrfToken" value="xk54PND5l/z2crsSvPM8f/u4IpThHDO/F9DJmnQHjYve3zTi1AjFDc6YpoaVo9yhynQ35RLKsl0AgeQLAGqH4eZcQnnk0nRpw4obptd/AodzsfmjRzHuuO28V9u3MKdvrPnAsvPFv5H/FlOBIfuCPg=="/></div><aside class="header__login-form__info">\n    <span class="material-icons header__login-form__info-icon">info</span>\n    <div class="header__login-form__info-container">\n        <p class="header__login-form__paragraph">Enter your personal login and password.</p>\n        <p class="header__login-form__paragraph">Caution: Sharing the same username among colleagues or opening the session on different comput ...

# %%
from bs4 import BeautifulSoup
from lxml import etree

# %%
soup = BeautifulSoup(resp, 'lxml')
html = etree.HTML(str(soup))

with open('./part.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link color="#036" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="Spectra Premium believes in a green and sustainable economy. That's why it uses its core competencies of metallurgical transformation, heat transfer and high quality assembly capacity, as well as its extensive expertise, to stand out in the booming vehicle electrification sector in Quebec." name="description"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/manifest.php?locale=en" rel="manifest"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <meta content="#036" name="msapplication-TileColor"/>
#   <meta content="https://ecat.spectrapremium.com/logo-spectra--open-graph.jpg" property="og:image"/>
#   <meta content="CATP04A" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://ecat.spectrapremium.com/en/parts/CATP04A" property="og:url"/>
#   <meta content="#036" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style>
#    :root { --view:'View'; --year:'Year'; --fuel:'Fuel'; --fueldel:'Fuel Del.'; --asp:'ASP.'; --engvin:'Eng. VIN'; --engdesg:'Eng. Desg.'; --cc:'CC'; --cid:'CID'; }
#   </style>
#   <link href="/css/pages/part.css?id=38a39161e4270f1992b91d7e69081719" rel="stylesheet"/>
#   <title>
#    CATP04A
#   </title>
#   <!-- Google Tag Manager (head du document) -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MHFHCJL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script async="async" defer="defer" src="https://www.google.com/recaptcha/api.js?hl=en">
#   </script>
#  </head>
#  <body class="produits view part">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MHFHCJL" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <header class="header">
#    <nav class="header__nav">
#     <a href="/en">
#      <picture>
#       <source media="(max-width: 767px)" srcset="/img/logo-spectra--small.svg">
#        <source media="(min-width: 768px)" srcset="/img/logo-spectra--medium.svg">
#         <img alt="Spectra Premium" class="header__logo" height="42" src="/img/logo-spectra--medium.svg" width="161"/>
#        </source>
#       </source>
#      </picture>
#     </a>
#     <div class="header__colonne-droite">
#      <button class="btn btn--login" id="login-btn">
#       Login
#      </button>
#      <form accept-charset="utf-8" action="/en/users/login" class="form header__login-form" id="login-form" method="post">
#       <div style="display:none;">
#        <input class="input input--hidden" name="_csrfToken" type="hidden" value="xk54PND5l/z2crsSvPM8f/u4IpThHDO/F9DJmnQHjYve3zTi1AjFDc6YpoaVo9yhynQ35RLKsl0AgeQLAGqH4eZcQnnk0nRpw4obptd/AodzsfmjRzHuuO28V9u3MKdvrPnAsvPFv5H/FlOBIfuCPg=="/>
#       </div>
#       <aside class="header__login-form__info">
#        <span class="material-icons header__login-form__info-icon">
#         info
#        </span>
#        <div class="header__login-form__info-container">
#         <p class="header__login-form__paragraph">
#          Enter your personal login and password.
#         </p>
#         <p class="header__login-form__paragraph">
#          Caution: Sharing the same username among colleagues or opening the session on different computers may create order conflicts and disrupt the email confirmation of the receipts.
#         </p>
#         <p class="header__login-form__paragraph">
#          Your administrator may create your own account. If you have any questions, email us at
#          <a class="link" href="mailto:internaldataservice@spectrapremium.com">
#           internaldataservice@spectrapremium.com
#          </a>
#          .
#         </p>
#        </div>
#       </aside>
#       <div class="header__login-form__title">
#        Login
#       </div>
#       <div class="input-container input-container--text">
#        <input aria-label="Username" class="input input--text" id="username-login-form" name="username" placeholder="Username" type="text"/>
#       </div>
#       <div class="input-container input-container--password">
#        <input aria-label="Password" autocomplete="current-password" class="input input--password" id="password-login-form" name="password" placeholder="Password" type="password"/>
#       </div>
#       <div class="input-container input-container--checkbox">
#        <input class="input input--hidden" name="remember_me" type="hidden" value="0"/>
#        <label for="remember-me">
#         Remember Me
#         <input class="checkbox" id="remember-me" name="remember_me" type="checkbox" value="1"/>
#        </label>
#       </div>
#       <button class="btn" type="submit">
#        Login
#       </button>
#       <a class="link" href="/en/pages/embedded-forms?name=open-a-commercial-account">
#        Open a commercial account
#       </a>
#       <span class="link" id="forgot-password-span">
#        Forgot your password?
#       </span>
#       <p class="header__login-form__paragraph">
#        For any problem or inquiry please consult our
#        <a class="link" href="https://ecat.spectrapremium.com/documents/guides/ecommerce_user_guide.pdf">
#         user guide
#        </a>
#        or email us at
#        <a class="link" href="mailto:techinfo@spectrapremium.com">
#         techinfo@spectrapremium.com
#        </a>
#        .
#       </p>
#       <div style="display:none;">
#        <input class="input input--hidden" name="_Token[fields]" type="hidden" value="1936d8149999067fc82a92122a4fa57f59a7b685%3A"/>
#        <input class="input input--hidden" name="_Token[unlocked]" type="hidden" value=""/>
#       </div>
#      </form>
#      <form accept-charset="utf-8" action="/en/users/forgot-password" class="form header__forgot-password-form" id="forgot-password-form" method="post">
#       <div style="display:none;">
#        <input class="input input--hidden" name="_csrfToken" type="hidden" value="xk54PND5l/z2crsSvPM8f/u4IpThHDO/F9DJmnQHjYve3zTi1AjFDc6YpoaVo9yhynQ35RLKsl0AgeQLAGqH4eZcQnnk0nRpw4obptd/AodzsfmjRzHuuO28V9u3MKdvrPnAsvPFv5H/FlOBIfuCPg=="/>
#       </div>
#       <div class="header__forgot-password-form__title">
#        Forgot your password?
#       </div>
#       <p class="header__forgot-password-form__paragraph header__forgot-password-form__paragraph--brand-color">
#        Please enter your username. We will send you an email explaining how to reset your password (it may be in your spam folder).
#       </p>
#       <div class="input-container input-container--text">
#        <input aria-label="Username" class="input input--text" id="username-forgot-password-form" name="username" placeholder="Username" type="text"/>
#       </div>
#       <button class="btn" type="submit">
#        Submit
#       </button>
#       <p class="header__login-form__paragraph">
#        If you don’t remember your username, contact your company account administrator. For any other problem or inquiry, email us at
#        <a class="link" href="mailto:internaldataservice@spectrapremium.com">
#         internaldataservice@spectrapremium.com
#        </a>
#        .
#       </p>
#       <div style="display:none;">
#        <input class="input input--hidden" name="_Token[fields]" type="hidden" value="4045e64c88c9af025e56fec3ef018a1dd0810306%3A"/>
#        <input class="input input--hidden" name="_Token[unlocked]" type="hidden" value=""/>
#       </div>
#      </form>
#      <button class="material-icons md-48 header__btn-menu" id="menu-btn">
#       menu
#      </button>
#      <ul class="header__menu" id="menu-list">
#       <li class="header__menu__item">
#        <a class="link header__menu__link" href="https://ecat.spectrapremium.com/es/parts/CATP04A">
#         Español
#        </a>
#       </li>
#       <li class="header__menu__item">
#        <a class="link header__menu__link" href="https://ecat.spectrapremium.com/fr/parts/CATP04A">
#         Français
#        </a>
#       </li>
#       <li class="header__menu__item">
#        <hr/>
#       </li>
#       <li class="header__menu__item">
#        <a class="link header__menu__link" href="/en/find-a-store">
#         Find a store
#        </a>
#       </li>
#       <li class="header__menu__item">
#        <a class="link header__menu__link" href="https://www.spectrapremium.com/en/contact" target="_blank">
#         Contact us
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </header>
#   <main class="main">
#    <div class="main__container">
#     <div class="search-container">
#      <div class="search">
#       <div class="search__icon-searches">
#        <span class="material-icons md-48">
#         search
#        </span>
#        <ul class="search__searches">
#         <li class="search__search">
#          <button class="btn btn--search" data-search="vehicleSearch" id="btn-vehicle-search">
#           Vehicle | VIN
#          </button>
#         </li>
#         <li class="search__search">
#          <button class="btn btn--search" data-search="partNumberSearchForm" id="btn-part-number-search">
#           Part | Interchange #
#          </button>
#         </li>
#         <li class="search__search">
#          <button class="btn btn--search" data-search="advancedSearchForm" id="btn-advanced-search">
#           Advanced Search
#          </button>
#         </li>
#        </ul>
#       </div>
#       <div class="search__vehicle-search" id="vehicle-search">
#        <form accept-charset="utf-8" action="/en/parts/CATP04A" class="form search__vehicle-search-form" data-error-message="Please fill out this field." id="vehicle-search-form" method="get">
#         <div class="input-container input-container--select required">
#          <select class="select" id="vehicle-search-year" name="year" required="required">
#           <option value="">
#            Year
#           </option>
#           <option value="2024">
#            2024
#           </option>
#           <option value="2023">
#            2023
#           </option>
#           <option value="2022">
#            2022
#           </option>
#           <option value="2021">
#            2021
#           </option>
#           <option value="2020">
#            2020
#           </option>
#           <option value="2019">
#            2019
#           </option>
#           <option value="2018">
#            2018
#           </option>
#           <option value="2017">
#            2017
#           </option>
#           <option value="2016">
#            2016
#           </option>
#           <option value="2015">
#            2015
#           </option>
#           <option value="2014">
#            2014
#           </option>
#           <option value="2013">
#            2013
#           </option>
#           <option value="2012">
#            2012
#           </option>
#           <option value="2011">
#            2011
#           </option>
#           <option value="2010">
#            2010
#           </option>
#           <option value="2009">
#            2009
#           </option>
#           <option value="2008">
#            2008
#           </option>
#           <option value="2007">
#            2007
#           </option>
#           <option value="2006">
#            2006
#           </option>
#           <option value="2005">
#            2005
#           </option>
#           <option value="2004">
#            2004
#           </option>
#           <option value="2003">
#            2003
#           </option>
#           <option value="2002">
#            2002
#           </option>
#           <option value="2001">
#            2001
#           </option>
#           <option value="2000">
#            2000
#           </option>
#           <option value="1999">
#            1999
#           </option>
#           <option value="1998">
#            1998
#           </option>
#           <option value="1997">
#            1997
#           </option>
#           <option value="1996">
#            1996
#           </option>
#           <option value="1995">
#            1995
#           </option>
#           <option value="1994">
#            1994
#           </option>
#           <option value="1993">
#            1993
#           </option>
#           <option value="1992">
#            1992
#           </option>
#           <option value="1991">
#            1991
#           </option>
#           <option value="1990">
#            1990
#           </option>
#           <option value="1989">
#            1989
#           </option>
#           <option value="1988">
#            1988
#           </option>
#           <option value="1987">
#            1987
#           </option>
#           <option value="1986">
#            1986
#           </option>
#           <option value="1985">
#            1985
#           </option>
#           <option value="1984">
#            1984
#           </option>
#           <option value="1983">
#            1983
#           </option>
#           <option value="1982">
#            1982
#           </option>
#           <option value="1981">
#            1981
#           </option>
#           <option value="1980">
#            1980
#           </option>
#           <option value="1979">
#            1979
#           </option>
#           <option value="1978">
#            1978
#           </option>
#           <option value="1977">
#            1977
#           </option>
#           <option value="1976">
#            1976
#           </option>
#           <option value="1975">
#            1975
#           </option>
#           <option value="1974">
#            1974
#           </option>
#           <option value="1973">
#            1973
#           </option>
#           <option value="1972">
#            1972
#           </option>
#           <option value="1971">
#            1971
#           </option>
#           <option value="1970">
#            1970
#           </option>
#           <option value="1969">
#            1969
#           </option>
#           <option value="1968">
#            1968
#           </option>
#           <option value="1967">
#            1967
#           </option>
#           <option value="1966">
#            1966
#           </option>
#           <option value="1965">
#            1965
#           </option>
#           <option value="1964">
#            1964
#           </option>
#           <option value="1963">
#            1963
#           </option>
#           <option value="1962">
#            1962
#           </option>
#           <option value="1961">
#            1961
#           </option>
#           <option value="1960">
#            1960
#           </option>
#           <option value="1959">
#            1959
#           </option>
#           <option value="1958">
#            1958
#           </option>
#           <option value="1957">
#            1957
#           </option>
#           <option value="1956">
#            1956
#           </option>
#           <option value="1955">
#            1955
#           </option>
#           <option value="1954">
#            1954
#           </option>
#           <option value="1953">
#            1953
#           </option>
#           <option value="1952">
#            1952
#           </option>
#           <option value="1951">
#            1951
#           </option>
#           <option value="1950">
#            1950
#           </option>
#           <option value="1949">
#            1949
#           </option>
#           <option value="1948">
#            1948
#           </option>
#           <option value="1947">
#            1947
#           </option>
#           <option value="1946">
#            1946
#           </option>
#           <option value="1945">
#            1945
#           </option>
#           <option value="1944">
#            1944
#           </option>
#           <option value="1943">
#            1943
#           </option>
#           <option value="1942">
#            1942
#           </option>
#          </select>
#         </div>
#         <div class="input-container input-container--select required">
#          <select class="select" id="vehicle-search-make" name="make" required="required">
#           <option value="">
#            Make
#           </option>
#          </select>
#         </div>
#         <div class="input-container input-container--select required">
#          <select class="select" id="vehicle-search-model" name="model" required="required">
#           <option value="">
#            Model
#           </option>
#          </select>
#         </div>
#         <div class="input-container input-container--select required">
#          <select class="select" id="vehicle-search-submodel" name="vehiculeIds" required="required">
#           <option value="">
#            Submodel
#           </option>
#          </select>
#         </div>
#         <div class="input-container input-container--select search__vehicle-search-form__motorization">
#          <select class="select" id="vehicle-search-motorization" name="vehicule_id">
#           <option value="">
#            Motorization
#           </option>
#          </select>
#         </div>
#        </form>
#        <div class="search__vin-btn">
#         <span class="search__vin-btn__or">
#          or
#         </span>
#         <form accept-charset="utf-8" action="/en/vehicules/get-vehicle" class="form search__vin-search-form" id="vin-search-form" method="get">
#          <div class="g-recaptcha" data-callback="googleRecaptchaOnSubmit" data-sitekey="6Ldad98ZAAAAAF8FuwzhSxxLDDjevI_pY2VMXt9A" data-size="invisible">
#          </div>
#          <div class="input-container input-container--text required">
#           <input aria-label="VIN" aria-required="true" class="input input--text" id="vin-search-vin" name="vin" pattern="((?![IOQ])[a-zA-Z0-9]){17}" placeholder="VIN" required="required" title="A VIN is made of alphanumeric characters. A VIN must have 17 characters. 1981 vehicles through present. 17 characters which do not include the letters I (i), O (o), or Q (q) (to avoid confusion with numerals 1 and 0)." type="text"/>
#          </div>
#         </form>
#         <button class="btn btn--search-search" id="vehicle-search-search-btn" type="submit">
#          Search
#         </button>
#         <button class="btn btn--search-back" id="vehicle-search-back-btn" type="reset">
#          Back
#         </button>
#        </div>
#       </div>
#       <form accept-charset="utf-8" action="/en/parts/results" class="form search__part-number-search-form" id="part-number-search-form" method="get">
#        <div class="input-container input-container--text required">
#         <input aria-label="Part #" aria-required="true" class="input input--text" id="part-number-search-part-number" maxlength="20" name="part-number" placeholder="Part #" required="required" type="text"/>
#        </div>
#        <div class="search__part-number-search-form__buttons">
#         <button class="add-spinner btn btn--search-search" id="part-number-search-search-btn" type="submit">
#          Search
#         </button>
#         <button class="btn btn--search-back" id="part-number-search-back-btn" type="reset">
#          Back
#         </button>
#        </div>
#       </form>
#       <form accept-charset="utf-8" action="/en/parts" class="form search__advanced-search-form" id="advanced-search-form" method="get">
#        <div class="input-container input-container--select required">
#         <select class="select" id="advanced-search-line" name="line" required="required">
#          <optgroup label="Heating &amp; Cooling">
#           <option value="radiators">
#            Automotive Radiator
#           </option>
#           <option value="charge_air_coolers">
#            Charge Air Cooler
#           </option>
#           <option value="fluid_coolers">
#            Fluid Cooler
#           </option>
#           <option value="indus_complete_radiators">
#            HD Radiator
#           </option>
#           <option value="heaters">
#            Heater
#           </option>
#           <option value="heavy_duty_heater">
#            Heavy duty heater
#           </option>
#           <option value="intercoolers">
#            Intercooler
#           </option>
#          </optgroup>
#          <optgroup label="Air conditioning">
#           <option value="accumulators">
#            Accumulator
#           </option>
#           <option value="compressors">
#            Compressor
#           </option>
#           <option value="condensers">
#            Condenser
#           </option>
#           <option value="evaporators">
#            Evaporator
#           </option>
#           <option value="heavy_duty_condenser">
#            Heavy duty condenser
#           </option>
#          </optgroup>
#          <optgroup label="Undercar">
#           <option value="filler_necks">
#            Filler Neck
#           </option>
#           <option value="filler_neck_acc">
#            Filler Neck Accessory
#           </option>
#           <option value="filler_neck_hoses">
#            Filler Neck Hose
#           </option>
#           <option value="fuel_tanks">
#            Fuel Tank
#           </option>
#           <option value="lock_rings">
#            Lock Ring
#           </option>
#           <option value="oil_pans">
#            Oil Pan
#           </option>
#           <option value="straps">
#            Strap
#           </option>
#           <option value="transmission_oil_pan">
#            Transmission Oil Pan
#           </option>
#          </optgroup>
#          <optgroup label="Ignition &amp; Engine Management">
#           <option value="camshaft_phasers">
#            Camshaft Phasers
#           </option>
#           <option value="camshaft_position_sensors">
#            Camshaft Position Sensor
#           </option>
#           <option value="crankshaft_position_sensors">
#            Crankshaft Position Sensor
#           </option>
#           <option value="electronic_throttle_bodies">
#            Electronic Throttle Body
#           </option>
#           <option value="emission_components">
#            Emission Component
#           </option>
#           <option value="ignition_coils">
#            Ignition Coil
#           </option>
#           <option value="manifold_pressure_sensors">
#            Manifold Absolute Pressure Sensor
#           </option>
#           <option value="maf_sensors">
#            Mass Airflow Sensor
#           </option>
#           <option value="oxygen_sensors">
#            Oxygen Sensor
#           </option>
#           <option value="variable_timing_products">
#            Variable Timing Products
#           </option>
#           <option value="vvt">
#            Variable Valve Timing Solenoid
#           </option>
#          </optgroup>
#          <optgroup label="Fuel Delivery">
#           <option value="fuel_injection_pumps">
#            Fuel Injection Pump
#           </option>
#           <option value="fuel_modules">
#            Fuel Module
#           </option>
#           <option value="fuel_pumps">
#            Fuel Pump
#           </option>
#           <option value="fuel_pump_drivers">
#            Fuel Pump Driver Module
#           </option>
#           <option value="fuel_system_acc">
#            Fuel System Accessory
#           </option>
#           <option value="fuel_tank_assemblies">
#            Fuel Tank Assembly
#           </option>
#           <option value="sending_units">
#            Sending Unit
#           </option>
#           <option value="strainers">
#            Strainer
#           </option>
#          </optgroup>
#          <optgroup label="Classic parts">
#           <option value="body_panels">
#            Body Panel
#           </option>
#           <option value="classic_fuel_tank">
#            Classic Fuel Tank
#           </option>
#           <option value="classic_inj_fuel_tanks">
#            Classic Injection Fuel Tank
#           </option>
#           <option value="sending_unit_classic">
#            Sending Unit Classic
#           </option>
#          </optgroup>
#         </select>
#        </div>
#        <div class="search__advanced-search-form__buttons">
#         <button class="add-spinner btn btn--search-search" id="advanced-search-search-btn" type="submit">
#          Search
#         </button>
#         <button class="btn btn--search-back" id="advanced-search-back-btn" type="reset">
#          Back
#         </button>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="part__container">
#      <ul class="fil-ariane">
#       <li>
#        <a class="fil-ariane__link" href="/en">
#         Home
#        </a>
#       </li>
#       <li>
#        <span class="material-icons">
#         navigate_next
#        </span>
#       </li>
#       <li>
#        <a class="fil-ariane__link" href="/en/parts/CATP04A">
#         CATP04A
#        </a>
#       </li>
#      </ul>
#      <div class="part__canada-ligne-image-formulaire-code-specifications-container">
#       <div class="part__canada-ligne-image-formulaire">
#        <div class="part__canada-ligne-image-formulaire-container">
#         <div class="part__canada-ligne-image-magic-scroll">
#          <div class="part__canada-ligne-image">
#           <div class="part__canada-ligne">
#            Oil Pan
#           </div>
#           <div class="part__zoom-gallery">
#            <div class="magic-zoom-plus-container" id="magic-zoom-plus-container">
#             <a class="MagicZoomPlus" data-mobile-options="textTouchZoomHint: Touch to zoom; textClickZoomHint: Double tap to zoom; textExpandHint: Tap to expand" data-options="rightClick: true; textBtnClose: Close; textBtnNext: Next; textBtnPrev: Previous; textClickZoomHint: Click to zoom; textExpandHint: Click to expand; textHoverZoomHint: Hover to zoom; zoomCaption: bottom" href="/img/produits/CATP04A_ANG_P04.jpg" id="magic-zoom-plus" title="Angle">
#              <img alt="" height="310" src="/img/produits/imagettes/CATP04A_ANG_P04_220.jpg" width="310"/>
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="part__magic-scroll-container">
#           <div class="part__magic-scroll-images MagicScroll" id="magic-scroll-images">
#            <a class="part__magic-scroll-images__thumbnail" data-zoom-id="magic-zoom-plus" href="/img/produits/CATP04A_ANG_P04.jpg" title="Angle">
#             <img alt="" class="part__magic-scroll-images__img" height="110" src="/img/produits/imagettes/CATP04A_ANG_P04_220.jpg" width="110"/>
#             Angle
#            </a>
#            <a class="part__magic-scroll-images__thumbnail" data-zoom-id="magic-zoom-plus" href="/img/produits/CATP04A_BOT_P01.jpg" title="Bottom">
#             <img alt="" class="part__magic-scroll-images__img" height="110" src="/img/produits/imagettes/CATP04A_BOT_P01_220.jpg" width="110"/>
#             Bottom
#            </a>
#            <a class="part__magic-scroll-images__thumbnail" data-zoom-id="magic-zoom-plus" href="/img/produits/CATP04A_BAC_P01.jpg" title="Back">
#             <img alt="" class="part__magic-scroll-images__img" height="110" src="/img/produits/imagettes/CATP04A_BAC_P01_220.jpg" width="110"/>
#             Back
#            </a>
#            <a class="part__magic-scroll-images__thumbnail" data-zoom-id="magic-zoom-plus" href="/img/produits/CATP04A_FRO_P01.jpg" title="Front">
#             <img alt="" class="part__magic-scroll-images__img" height="110" src="/img/produits/imagettes/CATP04A_FRO_P01_220.jpg" width="110"/>
#             Front
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="part__formulaire-where-to-buy-contact">
#          <div class="part__where-to-buy-contact">
#           <a class="part__where-to-buy" href="/en/find-a-store">
#            <span class="material-icons">
#             place
#            </span>
#            Where to buy
#           </a>
#           <a class="part__contact" href="tel:18889108888">
#            <span class="material-icons">
#             call
#            </span>
#            <span class="part__contact__tel">
#             1 888 910-8888
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <section class="part__code-specifications">
#        <h1 class="part__titre-code">
#         CATP04A
#        </h1>
#        <h2 class="part__titre-specifications">
#         Part Specifications
#        </h2>
#        <dl class="part__specifications">
#         <div class="part__nom-spec-valeur-spec">
#          <dt class="part__nom-spec">
#           Material
#          </dt>
#          <dd class="part__valeur-spec">
#           Aluminum
#          </dd>
#         </div>
#         <div class="part__nom-spec-valeur-spec">
#          <dt class="part__nom-spec">
#           Height
#          </dt>
#          <dd class="part__valeur-spec">
#           9.4375 in.
#          </dd>
#         </div>
#         <div class="part__nom-spec-valeur-spec">
#          <dt class="part__nom-spec">
#           Drain Plug Thread
#          </dt>
#          <dd class="part__valeur-spec">
#           3/4 X 16 Unf
#          </dd>
#         </div>
#         <div class="part__nom-spec-valeur-spec">
#          <dt class="part__nom-spec">
#           Pop. Code
#          </dt>
#          <dd class="part__valeur-spec">
#           D
#          </dd>
#         </div>
#        </dl>
#        <p class="part__disclaimer-image">
#         <em>
#          * Part finish and color may vary
#         </em>
#        </p>
#       </section>
#      </div>
#      <section class="part__ressources">
#       <h2 class="part__titre-ressources">
#        Related Documents
#       </h2>
#       <div class="part__ressources-container">
#        <a class="part__ressource" href="https://www.spectrapremium.com/ressources/televerser/[779]" target="_blank">
#         <div class="part__ressource__type">
#          Flyers
#         </div>
#         <figure class="part__ressource__figure">
#          <img alt="" class="part__ressource__img" height="256" src="/img/vignettes/ENGE08-Tech_Support-updated%202021-vertical.png" width="198"/>
#          <figcaption class="part__ressource__caption">
#           Tech Support
#          </figcaption>
#         </figure>
#        </a>
#        <a class="part__ressource" href="https://www.spectrapremium.com/ressources/televerser/[835]" target="_blank">
#         <div class="part__ressource__type">
#          Technical
#         </div>
#         <figure class="part__ressource__figure">
#          <img alt="" class="part__ressource__img" height="256" src="/img/vignettes/Oil%20Pan%20Note%202NW0301%20Rev_03.png" width="198"/>
#          <figcaption class="part__ressource__caption">
#           Oil Pan Warning: What to Verify before Installation
#          </figcaption>
#         </figure>
#        </a>
#        <a class="part__ressource" href="https://www.spectrapremium.com/ressources/televerser/[435]" target="_blank">
#         <div class="part__ressource__type">
#          Technical
#         </div>
#         <figure class="part__ressource__figure">
#          <img alt="" class="part__ressource__img" height="256" src="/img/vignettes/BOU-AVM-1-I-002B_Technical%20Notice_Oil%20Pan.png" width="198"/>
#          <figcaption class="part__ressource__caption">
#           Prevent Oil Pan Leak after Installation
#          </figcaption>
#         </figure>
#        </a>
#        <a class="part__ressource" href="https://www.spectrapremium.com/ressources/televerser/[540]" target="_blank">
#         <div class="part__ressource__type">
#          Warranties
#         </div>
#         <figure class="part__ressource__figure">
#          <img alt="" class="part__ressource__img" height="256" src="/img/vignettes/WAR_Oil_Pans.png" width="198"/>
#          <figcaption class="part__ressource__caption">
#           Oil Pan Warranty
#          </figcaption>
#         </figure>
#        </a>
#       </div>
#      </section>
#      <section class="part__applications" id="applications">
#       <h2 class="part__titre-applications">
#        Applications
#       </h2>
#       <div class="part__application-filters">
#        <h3 class="titre titre--3">
#         Filters
#        </h3>
#        <form accept-charset="utf-8" action="#application-filters" class="part__application-filters__form form" id="application-filters" method="get">
#         <select class="select" name="year" onchange="this.form.make.value='';this.form.model.value='';this.form.submodel.value='';this.form.submit()">
#          <option value="">
#           Year
#          </option>
#          <option value="2002">
#           2002
#          </option>
#          <option value="2001">
#           2001
#          </option>
#          <option value="2000">
#           2000
#          </option>
#          <option value="1999">
#           1999
#          </option>
#          <option value="1998">
#           1998
#          </option>
#          <option value="1997">
#           1997
#          </option>
#          <option value="1996">
#           1996
#          </option>
#          <option value="1995">
#           1995
#          </option>
#         </select>
#         <select class="select" name="make" onchange="this.form.model.value='';this.form.submodel.value='';this.form.submit()">
#          <option value="">
#           Make
#          </option>
#          <option value="American LaFrance">
#           American LaFrance
#          </option>
#          <option value="Blue Bird">
#           Blue Bird
#          </option>
#          <option value="Chevrolet">
#           Chevrolet
#          </option>
#          <option value="Crane Carrier">
#           Crane Carrier
#          </option>
#          <option value="Ford">
#           Ford
#          </option>
#          <option value="Freightliner">
#           Freightliner
#          </option>
#          <option value="GMC">
#           GMC
#          </option>
#          <option value="Gillig">
#           Gillig
#          </option>
#          <option value="Kenworth">
#           Kenworth
#          </option>
#          <option value="Peterbilt">
#           Peterbilt
#          </option>
#          <option value="Spartan Motors">
#           Spartan Motors
#          </option>
#          <option value="Sterling Truck">
#           Sterling Truck
#          </option>
#          <option value="Thomas">
#           Thomas
#          </option>
#          <option value="Western Star">
#           Western Star
#          </option>
#         </select>
#         <select class="select" name="model" onchange="this.form.submodel.value='';this.form.submit()">
#          <option value="">
#           Model
#          </option>
#          <option value="320">
#           320
#          </option>
#          <option value="330">
#           330
#          </option>
#          <option value="357">
#           357
#          </option>
#          <option value="378">
#           378
#          </option>
#          <option value="379">
#           379
#          </option>
#          <option value="387">
#           387
#          </option>
#          <option value="3700">
#           3700
#          </option>
#          <option value="4800">
#           4800
#          </option>
#          <option value="4900">
#           4900
#          </option>
#          <option value="ALF Eagle">
#           ALF Eagle
#          </option>
#          <option value="Advantage">
#           Advantage
#          </option>
#          <option value="All American FE">
#           All American FE
#          </option>
#          <option value="All American RE">
#           All American RE
#          </option>
#          <option value="Argosy">
#           Argosy
#          </option>
#          <option value="B7">
#           B7
#          </option>
#          <option value="Baron">
#           Baron
#          </option>
#          <option value="C6500 Kodiak">
#           C6500 Kodiak
#          </option>
#          <option value="C6500 Topkick">
#           C6500 Topkick
#          </option>
#          <option value="C7500 Kodiak">
#           C7500 Kodiak
#          </option>
#          <option value="C7500 Topkick">
#           C7500 Topkick
#          </option>
#          <option value="Centurion">
#           Centurion
#          </option>
#          <option value="Equipment Carrier">
#           Equipment Carrier
#          </option>
#          <option value="F-650">
#           F-650
#          </option>
#          <option value="F-750">
#           F-750
#          </option>
#          <option value="FL50">
#           FL50
#          </option>
#          <option value="FL60">
#           FL60
#          </option>
#          <option value="FL70">
#           FL70
#          </option>
#          <option value="FL80">
#           FL80
#          </option>
#          <option value="FLC112">
#           FLC112
#          </option>
#          <option value="FLD120">
#           FLD120
#          </option>
#          <option value="FS65">
#           FS65
#          </option>
#          <option value="Gladiator">
#           Gladiator
#          </option>
#          <option value="IRL">
#           IRL
#          </option>
#          <option value="K2">
#           K2
#          </option>
#          <option value="L7500">
#           L7500
#          </option>
#          <option value="L7501">
#           L7501
#          </option>
#          <option value="L8500">
#           L8500
#          </option>
#          <option value="L8501">
#           L8501
#          </option>
#          <option value="L8511">
#           L8511
#          </option>
#          <option value="L8513">
#           L8513
#          </option>
#          <option value="L9522">
#           L9522
#          </option>
#          <option value="LT7500">
#           LT7500
#          </option>
#          <option value="LT7501">
#           LT7501
#          </option>
#          <option value="LT8500">
#           LT8500
#          </option>
#          <option value="LT8501">
#           LT8501
#          </option>
#          <option value="LT8511">
#           LT8511
#          </option>
#          <option value="LT8513">
#           LT8513
#          </option>
#          <option value="Low Entry">
#           Low Entry
#          </option>
#          <option value="Metro Star">
#           Metro Star
#          </option>
#          <option value="Metropolitan">
#           Metropolitan
#          </option>
#          <option value="Motorhome">
#           Motorhome
#          </option>
#          <option value="Rangemaster">
#           Rangemaster
#          </option>
#          <option value="Saf-T-Liner">
#           Saf-T-Liner
#          </option>
#          <option value="School Bus">
#           School Bus
#          </option>
#          <option value="T2000">
#           T2000
#          </option>
#          <option value="T300">
#           T300
#          </option>
#          <option value="T6500">
#           T6500
#          </option>
#          <option value="T7500">
#           T7500
#          </option>
#          <option value="T800">
#           T800
#          </option>
#          <option value="TC2000">
#           TC2000
#          </option>
#          <option value="Transit Liner">
#           Transit Liner
#          </option>
#          <option value="W900">
#           W900
#          </option>
#          <option value="XB Line">
#           XB Line
#          </option>
#         </select>
#         <select class="select" name="submodel" onchange="this.form.submit()">
#          <option value="">
#           Submodel
#          </option>
#          <option value="101 L6 7.2L">
#           101 L6 7.2L
#          </option>
#          <option value="3742 L6 7.2L">
#           3742 L6 7.2L
#          </option>
#          <option value="3764 L6 7.2L">
#           3764 L6 7.2L
#          </option>
#          <option value="4864-2 L6 7.2L">
#           4864-2 L6 7.2L
#          </option>
#          <option value="4964-2 L6 7.2L">
#           4964-2 L6 7.2L
#          </option>
#          <option value="AAC3109-3400 L6 7.2L">
#           AAC3109-3400 L6 7.2L
#          </option>
#          <option value="AAC3401-3502 L6 7.2L">
#           AAC3401-3502 L6 7.2L
#          </option>
#          <option value="AAC3503-3604 L6 7.2L">
#           AAC3503-3604 L6 7.2L
#          </option>
#          <option value="AAC3605-3706 L6 7.2L">
#           AAC3605-3706 L6 7.2L
#          </option>
#          <option value="AAC3707-3808 L6 7.2L">
#           AAC3707-3808 L6 7.2L
#          </option>
#          <option value="AAC3809-3903 L6 7.2L">
#           AAC3809-3903 L6 7.2L
#          </option>
#          <option value="AAC3904-4100 L6 7.2L">
#           AAC3904-4100 L6 7.2L
#          </option>
#          <option value="B7T042 L6 7.2L">
#           B7T042 L6 7.2L
#          </option>
#          <option value="Base L6 7.2L">
#           Base L6 7.2L
#          </option>
#          <option value="C6H042 L6 7.2L">
#           C6H042 L6 7.2L
#          </option>
#          <option value="C7H042 L6 7.2L">
#           C7H042 L6 7.2L
#          </option>
#          <option value="C7H064 L6 7.2L">
#           C7H064 L6 7.2L
#          </option>
#          <option value="F6B042 L6 7.2L">
#           F6B042 L6 7.2L
#          </option>
#          <option value="F7B042 L6 7.2L">
#           F7B042 L6 7.2L
#          </option>
#          <option value="F7B064 L6 7.2L">
#           F7B064 L6 7.2L
#          </option>
#          <option value="FL5042S L6 7.2L">
#           FL5042S L6 7.2L
#          </option>
#          <option value="FL6042S L6 7.2L">
#           FL6042S L6 7.2L
#          </option>
#          <option value="FL7042S L6 7.2L">
#           FL7042S L6 7.2L
#          </option>
#          <option value="FL8042S L6 7.2L">
#           FL8042S L6 7.2L
#          </option>
#          <option value="FL8042ST L6 7.2L">
#           FL8042ST L6 7.2L
#          </option>
#          <option value="FL8044S L6 7.2L">
#           FL8044S L6 7.2L
#          </option>
#          <option value="FL8062S L6 7.2L">
#           FL8062S L6 7.2L
#          </option>
#          <option value="FL8062ST L6 7.2L">
#           FL8062ST L6 7.2L
#          </option>
#          <option value="FL8064S L6 7.2L">
#           FL8064S L6 7.2L
#          </option>
#          <option value="FL8064ST L6 7.2L">
#           FL8064ST L6 7.2L
#          </option>
#          <option value="FL8066S L6 7.2L">
#           FL8066S L6 7.2L
#          </option>
#          <option value="FL8084S L6 7.2L">
#           FL8084S L6 7.2L
#          </option>
#          <option value="FLC11244S L6 7.2L">
#           FLC11244S L6 7.2L
#          </option>
#          <option value="FLD12064ST L6 7.2L">
#           FLD12064ST L6 7.2L
#          </option>
#          <option value="MVP EF L6 7.2L">
#           MVP EF L6 7.2L
#          </option>
#          <option value="MVP L6 7.2L">
#           MVP L6 7.2L
#          </option>
#          <option value="Multi Pass L6 7.2L">
#           Multi Pass L6 7.2L
#          </option>
#          <option value="TC3904-4100 L6 7.2L">
#           TC3904-4100 L6 7.2L
#          </option>
#         </select>
#        </form>
#       </div>
#       <h3 class="part__titre-groupe-vehicules">
#        American LaFrance ALF Eagle Base L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
#          <th class="part__table-applications__header">
#           Year
#          </th>
#          <th class="part__table-applications__header">
#           Fuel
#          </th>
#          <th class="part__table-applications__header">
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/111923/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/51716/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1999
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/154576/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1998
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3 class="part__titre-groupe-vehicules">
#        American LaFrance Metropolitan Base L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
#          <th class="part__table-applications__header">
#           Year
#          </th>
#          <th class="part__table-applications__header">
#           Fuel
#          </th>
#          <th class="part__table-applications__header">
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/79916/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3 class="part__titre-groupe-vehicules">
#        Blue Bird All American FE AAC3109-3400 L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
# ...
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/45201/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/113916/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1999
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3 class="part__titre-groupe-vehicules">
#        Blue Bird All American RE AAC3605-3706 L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
#          <th class="part__table-applications__header">
#           Year
#          </th>
#          <th class="part__table-applications__header">
#           Fuel
#          </th>
#          <th class="part__table-applications__header">
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/132260/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/88960/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1999
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3 class="part__titre-groupe-vehicules">
#        Blue Bird All American RE AAC3904-4100 L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
#          <th class="part__table-applications__header">
#           Year
#          </th>
#          <th class="part__table-applications__header">
#           Fuel
#          </th>
#          <th class="part__table-applications__header">
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/72147/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/102545/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1999
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3 class="part__titre-groupe-vehicules">
#        Blue Bird TC2000 TC3904-4100 L6 7.2L
#       </h3>
#       <table class="part__table-applications">
#        <thead>
#         <tr class="part__table-applications__row">
#          <th class="part__table-applications__header">
#          </th>
#          <th class="part__table-applications__header">
#           Year
#          </th>
#          <th class="part__table-applications__header">
#           Fuel
#          </th>
#          <th class="part__table-applications__header">
#           Fuel Del.
#          </th>
#          <th class="part__table-applications__header">
#           ASP.
#          </th>
#          <th class="part__table-applications__header">
#           Eng. VIN
#          </th>
#          <th class="part__table-applications__header">
#           Eng. Desg.
#          </th>
#          <th class="part__table-applications__header">
#           CC
#          </th>
#          <th class="part__table-applications__header">
#           CID
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/123920/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           2000
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/29473/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1999
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/41444/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1998
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#         <tr class="part__table-applications__row">
#          <td class="add-spinner part__table-applications__data">
#           <a href="/en/vehicles/68887/parts">
#            <span class="material-icons">
#             launch
#            </span>
#           </a>
#          </td>
#          <td class="part__table-applications__data">
#           1997
#          </td>
#          <td class="part__table-applications__data">
#           DIESEL
#          </td>
#          <td class="part__table-applications__data">
#           FI
#          </td>
#          <td class="part__table-applications__data">
#           T
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           3126
#          </td>
#          <td class="part__table-applications__data">
#           -
#          </td>
#          <td class="part__table-applications__data">
#           441
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <ul class="paginator">
#        <li class="paginator__active">
#         <a class="link" href="">
#          1
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=2#applications">
#          2
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=3#applications">
#          3
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=4#applications">
#          4
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=5#applications">
#          5
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=6#applications">
#          6
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=7#applications">
#          7
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=8#applications">
#          8
#         </a>
#        </li>
#        <li>
#         <a class="link" href="/en/parts/CATP04A?page=9#applications">
#          9
#         </a>
#        </li>
#        <li class="paginator__next">
#         <a class="link" href="/en/parts/CATP04A?page=2#applications" rel="next">
#          &gt;
#         </a>
#        </li>
#        <li class="paginator__last">
#         <a class="link" href="/en/parts/CATP04A?page=10#applications">
#          &gt;&gt;
#         </a>
#        </li>
#       </ul>
#      </section>
#     </div>
#    </div>
#   </main>
#   <footer class="footer">
#    <div class="footer__logo-reseaux-sociaux">
#     <a class="footer__logo" href="https://www.spectrapremium.com/en" target="_blank">
#      <img alt="Spectra Premium" height="64" src="/img/logo-spectra--blanc.svg" width="235"/>
#     </a>
#     <ul class="footer__reseaux-sociaux">
#      <li>
#       <a href="https://www.facebook.com/SpectraPremium" target="_blank">
#        <img alt="Facebook" height="32" src="/img/facebook.svg" width="31"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://www.youtube.com/user/spectrapremiumvideos" target="_blank">
#        <img alt="YouTube" height="29" src="/img/youtube.svg" width="41"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://ca.linkedin.com/company/spectrapremium" target="_blank">
#        <img alt="LinkedIn" height="31" src="/img/linkedin.svg" width="31"/>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <ul class="footer__legal-copyright-cakephp">
#     <li>
#      <a class="link" href="https://www.spectrapremium.com/en/legal-notice" target="_blank">
#       Legal Notice
#      </a>
#     </li>
#     <li>
#      © Spectra Premium inc.
#     </li>
#     <li>
#      Powered by
#      <a class="link" href="https://cakephp.org" rel="noopener" target="_blank">
#       CakePHP
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script defer="defer" src="/js/pages/part.js?id=a7a2ecd2894f165e6fd16b87d550b532">
#   </script>
#  </body>
# </html>

# %%
type_ = html.xpath('//div[@class="part__canada-ligne"]/text()')[0].strip()

type_
# Out:
# 'Oil Pan'

# %%
part_number = html.xpath('//h1[@class="part__titre-code"]/text()')[0].strip()

part_number
# Out:
# 'CATP04A'

# %%
list_div = html.xpath('//div[@class="part__nom-spec-valeur-spec"]')

list_div
# Out:
# [<Element div at 0x12526d600>,
#  <Element div at 0x1281bc680>,
#  <Element div at 0x1282b4980>,
#  <Element div at 0x1282b58c0>]

# %%
src = 'https://ecat.spectrapremium.com/' + html.xpath('//div[@class="part__zoom-gallery"]/descendant::img/@src')[0].strip().replace('/imagettes/', '/').replace('_220.', '.')

src
# Out:
# 'https://ecat.spectrapremium.com//img/produits/CATP04A_ANG_P04.jpg'

# %%
vehicle_page = 1 if len(html.xpath('//li[@class="paginator__last"]')) == 0 else int(html.xpath('//li[@class="paginator__last"]/a/@href')[0].split('#')[0].split('=')[-1])

vehicle_page
# Out:
# 0

# %%
df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                         'Type': type_,
                         'Part_Number': part_number,
                         'Vehicle': '',
                         'Pic': '',
                         'Url': input_.loc[a, 'Url'],
                         'Src': src,
                         'Vehicle_Page': vehicle_page}])

for div in list_div:
    df_temp.loc[0, div.xpath('./dt/text()')[0].strip()] = div.xpath('./dd/text()')[0].strip()

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
crawler_status = 'ok'

crawler_status

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                             'Url': input_.loc[a, 'Url']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_part.xlsx', index=False)

output_correct

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
