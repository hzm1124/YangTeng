# %%
dict_ = {'no': 1,
 'item_number': '256756876675',
 'default_no': 1,
 'join_indn': '256756876675;1',
 'market': 'EBAY-US',
 'country': 'US',
 'language': 'en',
 'locale': 'en-US',
 'url': 'https://www.ebay.com/itm/256756876675?_ul=US&_stpos=91710&orig_cvip=true',
 'picture': '',
 'json_delivery': '{"0": "Standard Shipping", "1": "Estimated between Thu, Jun 12 and Mon, Jun 16", "2": "Shipping: Free shipping"}',
 'json_location': '{"0": "Ontario, California, United States"}',
 'json_src': '{"0": "https://i.ebayimg.com/images/g/w~QAAOSw7tFnZQPw/s-l500.jpg", "1": "https://i.ebayimg.com/images/g/ahcAAOSw-WhnZQPw/s-l500.jpg", "2": "https://i.ebayimg.com/images/g/QyQAAOSwL3BnZQPw/s-l500.jpg", "3": "https://i.ebayimg.com/images/g/rwoAAOSw3kVnZQPx/s-l500.jpg", "4": "https://i.ebayimg.com/images/g/AJIAAOSwOstnZQQE/s-l500.jpg", "5": "https://i.ebayimg.com/images/g/f8EAAOSwr8lnZQQF/s-l500.jpg", "6": "https://i.ebayimg.com/images/g/zkgAAOSwgutnZQQF/s-l500.jpg", "7": "https://i.ebayimg.com/images/g/DOcAAOSw8NplLtwK/s-l500.jpg"}',
 'breadcrumbs': '5. A/C Compressors & Clutches (https://www.ebay.com/b/Car-Truck-A-C-Compressors-Clutches/33543/bn_561583)\n4. Air Conditioning & Heating (https://www.ebay.com/b/Car-Truck-Air-Conditioning-Heating/33542/bn_584326)\n3. Car & Truck Parts & Accessories (https://www.ebay.com/b/Car-Truck-Parts-Accessories/6030/bn_562630)\n2. Parts & Accessories (https://www.ebay.com/b/Auto-Parts-Accessories/6028/bn_569479)\n1. eBay Motors (https://www.ebay.com/b/Auto-Parts-and-Vehicles/6000/bn_1865334)',
 'json_seller_rating': '{"Accurate description": 4.9, "Reasonable shipping cost": 5, "Shipping speed": 5, "Communication": 5}',
 'json_specification': '{"Condition": "New: A brand-new, unused, unopened, undamaged item in its original packaging (where packaging is applicable). Packaging should be the same as what is found in a retail store, unless the item was packaged by the manufacturer in non-retail packaging, such as an unprinted box or plastic bag. See the seller\'s listing for full details.", "Brand": "SCITOO", "Manufacturer Part Number": "CB109TE21147S", "Interchange Part Number": "1K0820803, 1K0 820 803", "Other Part Number": "4572, 8689 8680, 8681, 4568, 8688, 4574", "Superseded Part Number": "1K0820803S, 1K0 820 803S, 1K820859F, 1K8 208 59F", "Manufacturer Warranty": "1 Year", "UPC": "Does not apply", "Feature": "ESCP"}',
 'description_url': 'https://itm.ebaydesc.com/itmdesc/256756876675?t=1748242969000&category=33543&seller=scitoo-autoparts&excSoj=1&ver=0&excTrk=1&lsite=100&ittenable=true&domain=ebay.com&descgauge=1&cspheader=1&oneClk=2&secureDesc=1',
 'title': 'A/C Compressor Control Solenoid Valve For Volkswagen Sanden PXE13 PXE16 2006',
 'subtitle': '',
 'json_price': '{"style": 1, "now": "US $17.66", "origin": "Was US $18.99 (7% off)"}',
 'json_quantity': '{"0": "5 available", "1": "1 sold"}',
 'store_name': 'SCITOO-AutoParts',
 'store_url': 'https://www.ebay.com/str/cnbatteries?_trksid=p4429486.m145687.l149267',
 'store_ssn': 'SCITOO-AutoParts',
 'store_popular_category': '1. ABS Wheel Speed Sensor (https://www.ebay.com/str/cnbatteries/ABS-Wheel-Speed-Sensor/_i.html?store_cat=27808260016)\n2. AC Compressor (https://www.ebay.com/str/cnbatteries/AC-Compressor/_i.html?store_cat=16398759016)\n3. AC Compressor Control Valve+A (https://www.ebay.com/str/cnbatteries/AC-Compressor-Control-Valve-A/_i.html?store_cat=35372442016)\n4. AC Condenser & Radiator (https://www.ebay.com/str/cnbatteries/AC-Condenser-Radiator/_i.html?store_cat=25489422016)\n5. Adjustable Control /Camber Arm (https://www.ebay.com/str/cnbatteries/Adjustable-Control-Camber-Arm/_i.html?store_cat=41708444016)\n6. Air Cleaner Filter Box (https://www.ebay.com/str/cnbatteries/Air-Cleaner-Filter-Box/_i.html?store_cat=29351514016)\n7. Air Diesel Heater (https://www.ebay.com/str/cnbatteries/Air-Diesel-Heater/_i.html?store_cat=29256624016)\n8. Air Dryer (https://www.ebay.com/str/cnbatteries/Air-Dryer/_i.html?store_cat=37459800016)\n9. Air suspension valves solenoid (https://www.ebay.com/str/cnbatteries/Air-suspension-valves-solenoid/_i.html?store_cat=29869987016)',
 'compatibility_page': 1,
 'category_id': '33543',
 'compatibility_url': 'https://www.ebay.com/g/api/finders?marketplaceId=EBAY-US&itemId=256756876675&referrer=VIEWITEM&offset=0&module=COMPATIBILITY_TABLE&sellerName=scitoo-autoparts&module_groups=PART_FINDER&categoryId=33543'}

dict_
# Out:
# {'no': 1,
#  'item_number': '256756876675',
#  'default_no': 1,
#  'join_indn': '256756876675;1',
#  'market': 'EBAY-US',
#  'country': 'US',
#  'language': 'en',
#  'locale': 'en-US',
#  'url': 'https://www.ebay.com/itm/256756876675?_ul=US&_stpos=91710&orig_cvip=true',
#  'picture': '',
#  'json_delivery': '{"0": "Standard Shipping", "1": "Estimated between Thu, Jun 12 and Mon, Jun 16", "2": "Shipping: Free shipping"}',
#  'json_location': '{"0": "Ontario, California, United States"}',
#  'json_src': '{"0": "https://i.ebayimg.com/images/g/w~QAAOSw7tFnZQPw/s-l500.jpg", "1": "https://i.ebayimg.com/images/g/ahcAAOSw-WhnZQPw/s-l500.jpg", "2": "https://i.ebayimg.com/images/g/QyQAAOSwL3BnZQPw/s-l500.jpg", "3": "https://i.ebayimg.com/images/g/rwoAAOSw3kVnZQPx/s-l500.jpg", "4": "https://i.ebayimg.com/images/g/AJIAAOSwOstnZQQE/s-l500.jpg", "5": "https://i.ebayimg.com/images/g/f8EAAOSwr8lnZQQF/s-l500.jpg", "6": "https://i.ebayimg.com/images/g/zkgAAOSwgutnZQQF/s-l500.jpg", "7": "https://i.ebayimg.com/images/g/DOcAAOSw8NplLtwK/s-l500.jpg"}',
#  'breadcrumbs': '5. A/C Compressors & Clutches (https://www.ebay.com/b/Car-Truck-A-C-Compressors-Clutches/33543/bn_561583)\n4. Air Conditioning & Heating (https://www.ebay.com/b/Car-Truck-Air-Conditioning-Heating/33542/bn_584326)\n3. Car & Truck Parts & Accessories (https://www.ebay.com/b/Car-Truck-Parts-Accessories/6030/bn_562630)\n2. Parts & Accessories (https://www.ebay.com/b/Auto-Parts-Accessories/6028/bn_569479)\n1. eBay Motors (https://www.ebay.com/b/Auto-Parts-and-Vehicles/6000/bn_1865334)',
#  'json_seller_rating': '{"Accurate description": 4.9, "Reasonable shipping cost": 5, "Shipping speed": 5, "Communication": 5}',
#  'json_specification': '{"Condition": "New: A brand-new, unused, unopened, undamaged item in its original packaging (where packaging is applicable). Packaging should be the same as what is found in a retail store, unless the item was packaged by the manufacturer in non-retail packaging, such as an unprinted box or plastic bag. See the seller\'s listing for full details.", "Brand": "SCITOO", "Manufacturer Part Number": "CB109TE21147S", "Interchange Part Number": "1K0820803, 1K0 820 803", "Other Part Number": "4572, 8689 8680, 8681, 4568, 8688, 4574", "Superseded Part Number": "1K0820803S, 1K0 820 803S, 1K820859F, 1K8 208 59F", "Manufacturer Warranty": "1 Year", "UPC": "Does not apply", "Feature": "ESCP"}',
#  'description_url': 'https://itm.ebaydesc.com/itmdesc/256756876675?t=1748242969000&category=33543&seller=scitoo-autoparts&excSoj=1&ver=0&excTrk=1&lsite=100&ittenable=true&domain=ebay.com&descgauge=1&cspheader=1&oneClk=2&secureDesc=1',
#  'title': 'A/C Compressor Control Solenoid Valve For Volkswagen Sanden PXE13 PXE16 2006',
#  'subtitle': '',
#  'json_price': '{"style": 1, "now": "US $17.66", "origin": "Was US $18.99 (7% off)"}',
#  'json_quantity': '{"0": "5 available", "1": "1 sold"}',
#  'store_name': 'SCITOO-AutoParts',
#  'store_url': 'https://www.ebay.com/str/cnbatteries?_trksid=p4429486.m145687.l149267',
#  'store_ssn': 'SCITOO-AutoParts',
#  'store_popular_category': '1. ABS Wheel Speed Sensor (https://www.ebay.com/str/cnbatteries/ABS-Wheel-Speed-Sensor/_i.html?store_cat=27808260016)\n2. AC Compressor (https://www.ebay.com/str/cnbatteries/AC-Compressor/_i.html?store_cat=16398759016)\n3. AC Compressor Control Valve+A (https://www.ebay.com/str/cnbatteries/AC-Compressor-Control-Valve-A/_i.html?store_cat=35372442016)\n4. AC Condenser & Radiator (https://www.ebay.com/str/cnbatteries/AC-Condenser-Radiator/_i.html?store_cat=25489422016)\n5. Adjustable Control /Camber Arm (https://www.ebay.com/str/cnbatteries/Adjustable-Control-Camber-Arm/_i.html?store_cat=41708444016)\n6. Air Cleaner Filter Box (https://www.ebay.com/str/cnbatteries/Air-Cleaner-Filter-Box/_i.html?store_cat=29351514016)\n7. Air Diesel Heater (https://www.ebay.com/str/cnbatteries/Air-Diesel-Heater/_i.html?store_cat=29256624016)\n8. Air Dryer (https://www.ebay.com/str/cnbatteries/Air-Dryer/_i.html?store_cat=37459800016)\n9. Air suspension valves solenoid (https://www.ebay.com/str/cnbatteries/Air-suspension-valves-solenoid/_i.html?store_cat=29869987016)',
#  'compatibility_page': 1,
#  'category_id': '33543',
#  'compatibility_url': 'https://www.ebay.com/g/api/finders?marketplaceId=EBAY-US&itemId=256756876675&referrer=VIEWITEM&offset=0&module=COMPATIBILITY_TABLE&sellerName=scitoo-autoparts&module_groups=PART_FINDER&categoryId=33543'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
data = {'scopedContext': {'catalogDetails': {'categoryId': dict_['category_id'],
                                             'itemId': dict_['item_number']}}}
response = requests.post(dict_['compatibility_url'],
                         json=data,
                         headers=generate_header(**{'Accept-Language': 'en',
                                                    'Content-Type': 'application/json'}),
                         proxies=generate_proxy(),
                         timeout=(10, 15),
                         allow_redirects=False)

response.status_code
# Out:
# 200

# %%
try:
    response.json()
except Exception as e:
    print(e)

# %%
dict_2 = response.json()['modules']['COMPATIBILITY_TABLE']['paginatedTable']

dict_2
# Out:
# {'_type': 'PaginatedTable',
#  'title': {'_type': 'TextualDisplay',
#   'textSpans': [{'_type': 'TextSpan', 'text': '此零件适用于 735 种车款'}]},
#  'header': {'_type': 'TableHeader',
#   'cells': [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Year'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Make'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Model'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Trim'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Engine'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Notes'}]}]},
#  'caption': {'_type': 'TextualDisplay',
#   'textSpans': [{'_type': 'TextSpan', 'text': '此表中包含的部分信息由 null 提供'}]},
#  'rows': [{'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '1.8T Sport Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '--'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Comfortline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Comfortline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Comfortline TDI Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Highline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Highline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Highline TDI Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'SEL Premium Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'SE Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'S Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Sportline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'TDI SEL Premium Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'TDI SE Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Trendline Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Trendline TDI Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Wolfsburg Edition Sedan 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Base Sport Utility 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '1.4L 1390CC 85Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Base Sport Utility 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Comfortline Sport Utility 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]},
#   {'_type': 'TableRow',
#    'cells': [{'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': 'Highline Sport Utility 4-Door'}]},
#     {'_type': 'TextualDisplay',
#      'textSpans': [{'_type': 'TextSpan',
#        'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#     {'_type': 'ExpandableTextualDisplayBlock',
#      'textualDisplays': [{'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#      'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#       'viewMore': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读更多内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#          'accessibilityText': '阅读更多适配信息'}]},
#       'viewLess': {'_type': 'TextualDisplay',
#        'textSpans': [{'_type': 'TextSpan',
#          'text': '阅读较少内容',
#          'action': {'_type': 'Action',
#           'type': 'OPERATION',
#           'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#          'accessibilityText': '阅读较少适配信息'}]}},
#      'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]}],
#  'pagination': {'previous': {'_type': 'TextSpan',
#    'accessibilityText': '上一适用车款表格页'},
#   'next': {'_type': 'TextSpan',
#    'action': {'_type': 'Action',
#     'type': 'OPERATION',
#     'params': {'marketplaceId': 'EBAY-US',
#      'itemId': '256756876675',
#      'referrer': 'VIEWITEM',
#      'offset': '20',
#      'module': 'COMPATIBILITY_TABLE',
#      'sellerName': None,
#      'module_groups': 'PART_FINDER',
#      'categoryId': '33543'},
#     'trackingList': [],
#     'signInRequired': False,
#     'URL': 'https://www.ebay.com/g/api/finders'},
#    'accessibilityText': '下一适用车款表格页'},
#   'pages': [{'_type': 'OptionTextSpan',
#     'text': '1',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '0',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': True},
#    {'_type': 'OptionTextSpan',
#     'text': '2',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '20',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '3',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '40',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '4',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '60',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '5',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '80',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '6',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '100',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '7',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '120',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '8',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '140',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '9',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '160',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '10',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '180',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '11',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '200',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '12',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '220',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '13',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '240',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '14',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '260',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '15',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '280',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '16',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '300',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '17',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '320',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '18',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '340',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '19',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '360',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '20',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '380',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '21',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '400',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '22',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '420',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '23',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '440',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '24',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '460',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '25',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '480',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '26',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '500',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '27',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '520',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '28',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '540',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '29',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '560',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '30',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '580',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '31',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '600',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '32',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '620',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '33',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '640',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '34',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '660',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '35',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '680',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '36',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '700',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False},
#    {'_type': 'OptionTextSpan',
#     'text': '37',
#     'action': {'_type': 'Action',
#      'type': 'OPERATION',
#      'params': {'marketplaceId': 'EBAY-US',
#       'itemId': '256756876675',
#       'referrer': 'VIEWITEM',
#       'offset': '720',
#       'module': 'COMPATIBILITY_TABLE',
#       'sellerName': None,
#       'module_groups': 'PART_FINDER',
#       'categoryId': '33543'},
#      'trackingList': [],
#      'signInRequired': False,
#      'URL': 'https://www.ebay.com/g/api/finders'},
#     'selected': False}],
#   'itemsPerPage': {'label': {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '第 1 页/共 37 页'}]},
#    'currentOption': None,
#    'options': None}}}

# %%
list_header, list_row = [cell['textSpans'][0]['text'].strip() for cell in dict_2['header']['cells']], [row['cells'] for row in dict_2['rows']]

list_header, list_row
# Out:
# (['Year', 'Make', 'Model', 'Trim', 'Engine', 'Notes'],
#  [[{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '1.8T Sport Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '--'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Comfortline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Comfortline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'Comfortline TDI Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Highline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Highline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Highline TDI Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'SEL Premium Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'SE Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'S Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Sportline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.5L 2480CC 151Cu. In. l5 GAS DOHC Naturally Aspirated'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'TDI SEL Premium Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'TDI SE Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Trendline Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'Trendline TDI Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1968CC 120Cu. In. l4 DIESEL DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Passat'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'Wolfsburg Edition Sedan 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.8L 1798CC 110Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Base Sport Utility 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '1.4L 1390CC 85Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Base Sport Utility 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'Comfortline Sport Utility 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}],
#   [{'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': '2015'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Volkswagen'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan', 'text': 'Tiguan'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': 'Highline Sport Utility 4-Door'}]},
#    {'_type': 'TextualDisplay',
#     'textSpans': [{'_type': 'TextSpan',
#       'text': '2.0L 1984CC 121Cu. In. l4 GAS DOHC Turbocharged'}]},
#    {'_type': 'ExpandableTextualDisplayBlock',
#     'textualDisplays': [{'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': 'Sanden bolt down style AC compressor ONLY!'}]}],
#     'expandCollapseControls': {'_type': 'ExpandCollapseControls',
#      'viewMore': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读更多内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'EXPAND_INLINE'}},
#         'accessibilityText': '阅读更多适配信息'}]},
#      'viewLess': {'_type': 'TextualDisplay',
#       'textSpans': [{'_type': 'TextSpan',
#         'text': '阅读较少内容',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'clientPresentationMetadata': {'presentationType': 'COLLAPSE_INLINE'}},
#         'accessibilityText': '阅读较少适配信息'}]}},
#     'uxComponentHint': 'EXPAND_COLLAPSE_INLINE'}]])

# %%
not list_header or not list_row
# Out:
# False

# %%
dict_compatibility = {'compatibility_no': 1}
for j, header in enumerate(list_header):
    dict_compatibility[header] = list_row[0][j]['textualDisplays'][0]['textSpans'][0]['text'].strip() if 'textualDisplays' in list_row[0][j] else list_row[0][j]['textSpans'][0]['text'].strip()

dict_compatibility
# Out:
# {'compatibility_no': 1,
#  'Year': '2015',
#  'Make': 'Volkswagen',
#  'Model': 'Passat',
#  'Trim': '1.8T Sport Sedan 4-Door',
#  'Engine': '--',
#  'Notes': 'Sanden bolt down style AC compressor ONLY!'}

# %%
{**dict_, **dict_compatibility}
# Out:
# {'no': 1,
#  'item_number': '256756876675',
#  'default_no': 1,
#  'join_indn': '256756876675;1',
#  'market': 'EBAY-US',
#  'country': 'US',
#  'language': 'en',
#  'locale': 'en-US',
#  'url': 'https://www.ebay.com/itm/256756876675?_ul=US&_stpos=91710&orig_cvip=true',
#  'picture': '',
#  'json_delivery': '{"0": "Standard Shipping", "1": "Estimated between Thu, Jun 12 and Mon, Jun 16", "2": "Shipping: Free shipping"}',
#  'json_location': '{"0": "Ontario, California, United States"}',
#  'json_src': '{"0": "https://i.ebayimg.com/images/g/w~QAAOSw7tFnZQPw/s-l500.jpg", "1": "https://i.ebayimg.com/images/g/ahcAAOSw-WhnZQPw/s-l500.jpg", "2": "https://i.ebayimg.com/images/g/QyQAAOSwL3BnZQPw/s-l500.jpg", "3": "https://i.ebayimg.com/images/g/rwoAAOSw3kVnZQPx/s-l500.jpg", "4": "https://i.ebayimg.com/images/g/AJIAAOSwOstnZQQE/s-l500.jpg", "5": "https://i.ebayimg.com/images/g/f8EAAOSwr8lnZQQF/s-l500.jpg", "6": "https://i.ebayimg.com/images/g/zkgAAOSwgutnZQQF/s-l500.jpg", "7": "https://i.ebayimg.com/images/g/DOcAAOSw8NplLtwK/s-l500.jpg"}',
#  'breadcrumbs': '5. A/C Compressors & Clutches (https://www.ebay.com/b/Car-Truck-A-C-Compressors-Clutches/33543/bn_561583)\n4. Air Conditioning & Heating (https://www.ebay.com/b/Car-Truck-Air-Conditioning-Heating/33542/bn_584326)\n3. Car & Truck Parts & Accessories (https://www.ebay.com/b/Car-Truck-Parts-Accessories/6030/bn_562630)\n2. Parts & Accessories (https://www.ebay.com/b/Auto-Parts-Accessories/6028/bn_569479)\n1. eBay Motors (https://www.ebay.com/b/Auto-Parts-and-Vehicles/6000/bn_1865334)',
#  'json_seller_rating': '{"Accurate description": 4.9, "Reasonable shipping cost": 5, "Shipping speed": 5, "Communication": 5}',
#  'json_specification': '{"Condition": "New: A brand-new, unused, unopened, undamaged item in its original packaging (where packaging is applicable). Packaging should be the same as what is found in a retail store, unless the item was packaged by the manufacturer in non-retail packaging, such as an unprinted box or plastic bag. See the seller\'s listing for full details.", "Brand": "SCITOO", "Manufacturer Part Number": "CB109TE21147S", "Interchange Part Number": "1K0820803, 1K0 820 803", "Other Part Number": "4572, 8689 8680, 8681, 4568, 8688, 4574", "Superseded Part Number": "1K0820803S, 1K0 820 803S, 1K820859F, 1K8 208 59F", "Manufacturer Warranty": "1 Year", "UPC": "Does not apply", "Feature": "ESCP"}',
#  'description_url': 'https://itm.ebaydesc.com/itmdesc/256756876675?t=1748242969000&category=33543&seller=scitoo-autoparts&excSoj=1&ver=0&excTrk=1&lsite=100&ittenable=true&domain=ebay.com&descgauge=1&cspheader=1&oneClk=2&secureDesc=1',
#  'title': 'A/C Compressor Control Solenoid Valve For Volkswagen Sanden PXE13 PXE16 2006',
#  'subtitle': '',
#  'json_price': '{"style": 1, "now": "US $17.66", "origin": "Was US $18.99 (7% off)"}',
#  'json_quantity': '{"0": "5 available", "1": "1 sold"}',
#  'store_name': 'SCITOO-AutoParts',
#  'store_url': 'https://www.ebay.com/str/cnbatteries?_trksid=p4429486.m145687.l149267',
#  'store_ssn': 'SCITOO-AutoParts',
#  'store_popular_category': '1. ABS Wheel Speed Sensor (https://www.ebay.com/str/cnbatteries/ABS-Wheel-Speed-Sensor/_i.html?store_cat=27808260016)\n2. AC Compressor (https://www.ebay.com/str/cnbatteries/AC-Compressor/_i.html?store_cat=16398759016)\n3. AC Compressor Control Valve+A (https://www.ebay.com/str/cnbatteries/AC-Compressor-Control-Valve-A/_i.html?store_cat=35372442016)\n4. AC Condenser & Radiator (https://www.ebay.com/str/cnbatteries/AC-Condenser-Radiator/_i.html?store_cat=25489422016)\n5. Adjustable Control /Camber Arm (https://www.ebay.com/str/cnbatteries/Adjustable-Control-Camber-Arm/_i.html?store_cat=41708444016)\n6. Air Cleaner Filter Box (https://www.ebay.com/str/cnbatteries/Air-Cleaner-Filter-Box/_i.html?store_cat=29351514016)\n7. Air Diesel Heater (https://www.ebay.com/str/cnbatteries/Air-Diesel-Heater/_i.html?store_cat=29256624016)\n8. Air Dryer (https://www.ebay.com/str/cnbatteries/Air-Dryer/_i.html?store_cat=37459800016)\n9. Air suspension valves solenoid (https://www.ebay.com/str/cnbatteries/Air-suspension-valves-solenoid/_i.html?store_cat=29869987016)',
#  'compatibility_page': 1,
#  'category_id': '33543',
#  'compatibility_url': 'https://www.ebay.com/g/api/finders?marketplaceId=EBAY-US&itemId=256756876675&referrer=VIEWITEM&offset=0&module=COMPATIBILITY_TABLE&sellerName=scitoo-autoparts&module_groups=PART_FINDER&categoryId=33543',
#  'compatibility_no': 1,
#  'Year': '2015',
#  'Make': 'Volkswagen',
#  'Model': 'Passat',
#  'Trim': '1.8T Sport Sedan 4-Door',
#  'Engine': '--',
#  'Notes': 'Sanden bolt down style AC compressor ONLY!'}
