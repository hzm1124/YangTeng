# %%
import os

# %%
list_file = list(os.walk('./crawler_1'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 100

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    with open('./crawler_1/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_1.xlsx', index=False)

df
# Out:
# 进度: 100%|███████████████████████████████| 100/100 [00:00<00:00, 673.38it/s]
#           ASIN                                              Title  \
# 0   B09ZXK8HR4  A ABSOPRO Car AC Compressor Control Solenoid V...
# 0   B005OVLAXQ  ACDelco Professional 24256861 Transmission Con...
# 0   B082XR26G8  ACTECmax A/C Compressor Control solenoid Valve...
# 0   B082XRWLPB  ACTECmax A/C Compressor Control Solenoid Valve...
# 0   B07W5B5GJD  ACTECmax AC Compressor Solenoid Control Soleno...
# ..         ...                                                ...
# 0   B081V3XYL1  A/C Compressor Electronic Control Valve 317097...
# 0   B0838VMSLH  A/C DVE12 Compressor Electronic Control Valve ...
# 0   B0838VQGBW  DVE12 A/C Compressor Electronic Control Valve ...
# 0   B01HCUMMSS  ACTECmax AC Compressor A/C Control Solenoid Va...
# 0   B01HCUMPXU  ACTECmax AC Compressor A/C Control Solenoid Va...
#
#                                                 Price  \
# 0                                              $21.69
# 0   ACDelco Professional 19294247 Ignition Control...
# 0                                              $25.86
# 0                                              $26.98
# 0                                              $28.98
# ..                                                ...
# 0                                              $25.69
# 0                                              $30.55
# 0                                              $26.99
# 0                                              $28.98
# 0                                              $25.98
#
#                                                 About Pic  \
# 0   1. Replacement For - 976742S000 ; Suitable for...
# 0   1. Vital to vehicle performance because they d...
# 0   1. 100% Brand New and High Quality!\n2. Manufa...
# 0   1. 100% Brand New and High Quality!\n2. Manufa...
# 0   1. 100% Brand New and High Quality!\n2. Suitab...
# ..                                                ...  ..
# 0   1. High Quality: Made of high-quality material...
# 0   1. The most common problem with this particula...
# 0   1. A/C Compressor Electronic Control Valve for...
# 0   1. 100% Brand New\n2. Suitable for DENSO 5SEU1...
# 0   1. 100% Brand New and High Quality!\n2. Manufa...
#
#                                                   Url  \
# 0   https://www.amazon.com/ABSOPRO-Compressor-Sole...
# 0   https://www.amazon.com/ACDelco-24256861-Profes...
# 0   https://www.amazon.com/ACTECmax-Compressor-Con...
# 0   https://www.amazon.com/ACTECmax-Compressor-Con...
# 0   https://www.amazon.com/ACTECmax-Compressor-Con...
# ..                                                ...
# 0   https://www.amazon.com/WFLNHB-Compressor-Elect...
# 0   https://www.amazon.com/WFLNHB-Compressor-Elect...
# 0   https://www.amazon.com/WFLNHB-Compressor-Elect...
# 0   https://www.amazon.com/Wisepick-Compressor-Con...
# 0   https://www.amazon.com/Wisepick-Compressor-Con...
#
#                                                   Src manufacturer  \
# 0   https://m.media-amazon.com/images/I/51f4ZvKteR...   ‎A ABSOPRO
# 0   https://m.media-amazon.com/images/I/61grmrEzhw...     ‎ACDelco
# 0   https://m.media-amazon.com/images/I/717KE1Bc6A...    ‎ACTECmax
# 0   https://m.media-amazon.com/images/I/71dHK55oCJ...    ‎ACTECmax
# 0   https://m.media-amazon.com/images/I/71pJYTvUYe...    ‎ACTECmax
# ..                                                ...          ...
# 0   https://m.media-amazon.com/images/I/31ieESkfMu...      ‎WFLNHB
# 0   https://m.media-amazon.com/images/I/51xk-NZcJS...      ‎WFLNHB
# 0   https://m.media-amazon.com/images/I/51iSw1USDP...      ‎WFLNHB
# 0   https://m.media-amazon.com/images/I/61MWs3w9Uq...    ‎ACTECmax
# 0   https://m.media-amazon.com/images/I/51V7rNoUke...    ‎ACTECmax
#
#          brand    item weight  ... connector type terminal  \
# 0   ‎A ABSOPRO  ‎0.035 ounces  ...            NaN      NaN
# 0     ‎ACDelco   ‎1.17 pounds  ...            NaN      NaN
# 0    ‎ACTECMAX    ‎6.4 ounces  ...            NaN      NaN
# 0    ‎ACTECMAX    ‎4.2 ounces  ...            NaN      NaN
# 0    ‎ACTECMAX      ‎6 ounces  ...            NaN      NaN
# ..         ...            ...  ...            ...      ...
# 0          NaN    ‎6.3 ounces  ...            NaN      NaN
# 0          NaN    ‎5.6 ounces  ...            NaN      NaN
# 0          NaN    ‎5.4 ounces  ...            NaN      NaN
# 0    ‎Wisepick    ‎5.6 ounces  ...            NaN      NaN
# 0    ‎ACTECMAX   ‎3.19 ounces  ...            NaN      NaN
#
#    item dimensions lxwxh international protection rating  \
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# ..                   ...                             ...
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
# 0                    NaN                             NaN
#
#    connectivity protocol unit count number of items style  \
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# ..                   ...        ...             ...   ...
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
# 0                    NaN        NaN             NaN   NaN
#
#    warranty description included components
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# ..                  ...                 ...
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
# 0                   NaN                 NaN
#
# [100 rows x 59 columns]
