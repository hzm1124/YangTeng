# %%
import os

# %%
list_file = list(os.walk('./menu'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 103

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./menu/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df[['Page', 'No.', 'Part_Number', 'Name', 'Vehicle', 'OE', 'Date', 'Url', 'Src']]
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['Page', 'No.'], ascending=[True, True]).reset_index(drop=True)
df['No.'] = [i+1 for i in range(len(df))]
df = df[df.columns[1:]]
df.to_excel('./menu.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 103/103 [00:00<00:00, 751.08it/s]
#      No.           Part_Number                                   Name  \
# 0      1  VS-27A023 / B014-018                           TCC SOLENOID
# 1      2  VS-27A027 / B014-032                               SOLENOID
# 2      3  VS-27A028 / B014-036             EGR Valve Control Solenoid
# 3      4  VS-27B003 / B014-021  Vapor Canister Purge Valve / Solenoid
# 4      5  VS-27C031 / B014-037                         SHIFT SOLENOID
# ..   ...                   ...                                    ...
# 819  820  VS-39A119 / B027-109                       Headlight Switch
# 820  821  VS-39A120 / B027-110                       Headlight Switch
# 821  822  VS-39A121 / B027-111                       Headlight Switch
# 822  823  VS-39A122 / B027-112                       Headlight Switch
# 823  824  VS-39A123 / B027-113                       Headlight Switch
#
#                                                Vehicle  \
# 0    FORD AEROSTAR 1997 FORD EXPLORER 1997-2001 FOR...
# 1    BUICK CASCADA 2016-2019 BUICK ENVISION 2016 BU...
# 2    CHEVROLET ASTRO 1990 CHEVROLET S10 PICKUP 1991...
# 3    BMW 323CI 2000 BMW 323I 1999-2000 BMW 325CI 20...
# 4           ACURA TL 2004-2006 HONDA ODYSSEY 2004-2006
# ..                                                 ...
# 819  DODGE RAM 1500 PICKUP 2002-2005 DODGE RAM 1500...
# 820  FORD EXCURSION 2002-2005 FORD TAURUS 2000-2007...
# 821  FORD EXCURSION 2002-2004 FORD F-250 SUPER DUTY...
# 822  FORD EXPLORER 2001-2002 MERCURY MOUNTAINEER 20...
# 823  FORD EXCURSION 2000-2005 FORD TAURUS 2000-2007...
#
#                                                     OE        Date  \
# 0                        F77Z7G136AA;TKS26;XL2Z7G136AA  2015/11/02
# 1                           22740537;84065747;84802774  2020/04/15
# 2                                             10096137  2020/12/30
# 3                                          13901433603  2016/09/08
# 4                              28500P6H003;28500P6H013  2019/03/15
# ..                                                 ...         ...
# 819                   56045536AA;56045536AB;56045536AC  2010/03/10
# 820  1F1Z11654BAA;2F1Z11654BAA;YF1Z11654BAA;YF1Z116...  2010/07/07
# 821  1F1Z11654CAA;2F1Z11654CAA;2F1Z11654CAB;YF1Z116...  2010/07/07
# 822               1L2Z11654DA;1L2Z11654DAA;IL2Z11654DA  2010/07/07
# 823  1F1Z11654AAA;YC3Z11654AAA;YF1Z11654AAA;YF1Z116...  2010/07/07
#
#                                                    Url  \
# 0    https://www.cubelec.com.tw/other-product-inner...
# 1    https://www.cubelec.com.tw/other-product-inner...
# 2    https://www.cubelec.com.tw/other-product-inner...
# 3    https://www.cubelec.com.tw/other-product-inner...
# 4    https://www.cubelec.com.tw/other-product-inner...
# ..                                                 ...
# 819  https://www.cubelec.com.tw/other-product-inner...
# 820  https://www.cubelec.com.tw/other-product-inner...
# 821  https://www.cubelec.com.tw/other-product-inner...
# 822  https://www.cubelec.com.tw/other-product-inner...
# 823  https://www.cubelec.com.tw/other-product-inner...
#
#                                                    Src
# 0    https://www.cubelec.com.tw/product-new/2023010...
# 1    https://www.cubelec.com.tw/product-new/2023010...
# 2    https://www.cubelec.com.tw/product-new/2023010...
# 3    https://www.cubelec.com.tw/product-new/2023010...
# 4    https://www.cubelec.com.tw/product-new/2023010...
# ..                                                 ...
# 819  https://www.cubelec.com.tw/product-new/1268643...
# 820  https://www.cubelec.com.tw/product-new/1278496...
# 821  https://www.cubelec.com.tw/product-new/1278496...
# 822  https://www.cubelec.com.tw/product-new/1278496...
# 823  https://www.cubelec.com.tw/product-new/1278496...
#
# [824 rows x 8 columns]
