# %% [markdown]
# # 1. RockAuto
#
# ## 1.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

list_df = []
for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    df_temp, dict_dict = pd.DataFrame([input_.iloc[i]]).reset_index(drop=True), json.loads(input_.loc[i, 'Json_Specification'])

    for dict_ in dict_dict.values():
        key = list(dict_.values())[0]
        if len(dict_) == 1:
            df_temp.loc[0, key] = True
        else:
            df_temp.loc[0, key] = list(dict_.values())[1]

    list_df.append(df_temp)

# = = = = = = = = = = = = = = =

output = pd.concat(list_df, ignore_index=True).fillna('')

output = output.sort_values(by=['No'],
                            ascending=[True],
                            ignore_index=True)

output.to_excel('./crawler.xlsx', index=False)

output
# Out:
# Progress: 100%|█████████████████████████| 3594/3594 [00:29<00:00, 120.25it/s]
#         No Group              Type Type Code  Manufacturer Part Number  \
# 0        1  FUCK             Mahle      6628  FOUR SEASONS      198276
# 1        2  FUCK  A/C Service Kits      6788  FOUR SEASONS     10900SK
# 2        3  FUCK              FORD      6628  FOUR SEASONS       78588
# 3        4  FUCK  A/C Service Kits      6972  FOUR SEASONS     60061SK
# 4        5  FUCK              FORD      6628  FOUR SEASONS       58124
# ...    ...   ...               ...       ...           ...         ...
# 3589  3590  FUCK            Hannon      6628  FOUR SEASONS      167365
# 3590  3591  FUCK              FORD      6628  FOUR SEASONS     1197554
# 3591  3592  FUCK     Sanden/Sankyo      6628  FOUR SEASONS      157581
# 3592  3593  FUCK        Block Type      6788  FOUR SEASONS       39686
# 3593  3594  FUCK            DELPHI      6628  FOUR SEASONS      197297
#
#                                                  Note 1  \
# 0                      Includes 3 oz. of HFO-1234yf Oil
# 1     Includes Desiccant Bag Kit, Expansion Valve, R...
# 2                         Prefilled w/ OE-Specified Oil
# 3     Includes: Accumulator, Orifice Tube, Expansion...
# 4                         Prefilled w/ OE-Specified Oil
# ...                                                 ...
# 3589                                  Reman; Compressor
# 3590                                  Reman; Compressor
# 3591                                  Reman; Compressor
# 3592
# 3593                                   Reman Compressor
#
#                                             Json_Note 2 Choose  \
# 0                     {"0": "Category: A/C Compressor"}
# 1                {"0": "Category: A/C Expansion Valve"}
# 2                     {"0": "Category: A/C Compressor"}
# 3     {"0": "Category: A/C Receiver Drier / Accumula...
# 4                     {"0": "Category: A/C Compressor"}
# ...                                                 ...    ...
# 3589                  {"0": "Category: A/C Compressor"}
# 3590                  {"0": "Category: A/C Compressor"}
# 3591                  {"0": "Category: A/C Compressor"}
# 3592             {"0": "Category: A/C Expansion Valve"}
# 3593                  {"0": "Category: A/C Compressor"}
#
#                     Json_Price  ... Mounting Hole Quantity  \
# 0     {"automatic": "$343.79"}  ...
# 1      {"automatic": "$38.89"}  ...
# 2     {"automatic": "$181.79"}  ...
# 3      {"automatic": "$62.79"}  ...
# 4     {"automatic": "$144.99"}  ...
# ...                        ...  ...                    ...
# 3589  {"automatic": "$240.89"}  ...
# 3590  {"automatic": "$141.99"}  ...
# 3591  {"automatic": "$153.79"}  ...
# 3592   {"automatic": "$21.79"}  ...
# 3593  {"automatic": "$168.79"}  ...
#
#      Suction Inlet Fitting Gender Suction Outlet Fitting Gender Switch Gender  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                           ...           ...
# 3589
# 3590
# 3591
# 3592
# 3593
#
#      Suction End Size Suction End Style System Pressure Desiccant Diameter  \
# 0
# 1
# 2
# 3
# 4
# ...               ...               ...             ...                ...
# 3589
# 3590
# 3591
# 3592
# 3593
#
#      Outlet Diameter Connector Gender
# 0
# 1
# 2
# 3
# 4
# ...              ...              ...
# 3589
# 3590
# 3591
# 3592
# 3593
#
# [3594 rows x 199 columns]

# %% [markdown]
# ## 1.2. Kit

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

list_df = []
for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Kit'])
    
    for key, value in dict_.items():
        df_temp = pd.concat([pd.DataFrame([input_.iloc[i]]).reset_index(drop=True),
                             pd.DataFrame([{'Kit_No': int(key)+1}]),
                             pd.DataFrame([dict_[key]])], axis=1).fillna('')
        list_df.append(df_temp)

# = = = = = = = = = = = = = = =

output = pd.concat(list_df, ignore_index=True).fillna('')

output = output.sort_values(by=['No', 'Kit_No'],
                            ascending=[True, True],
                            ignore_index=True)

output.to_excel('./crawler.xlsx', index=False)

output
# Out:
# Progress: 100%|██████████████████████████| 8721/8721 [02:29<00:00, 58.42it/s]
#          No                    Group  \
# 0         1  Heat & Air Conditioning
# 1         1  Heat & Air Conditioning
# 2         2  Heat & Air Conditioning
# 3         2  Heat & Air Conditioning
# 4         3  Heat & Air Conditioning
# ...     ...                      ...
# 26075  8720  Heat & Air Conditioning
# 26076  8720  Heat & Air Conditioning
# 26077  8721  Heat & Air Conditioning
# 26078  8721  Heat & Air Conditioning
# 26079  8721  Heat & Air Conditioning
#
#                                                   Type Type Code  \
# 0      Complete Air Conditioning Kit w/ New Compressor     17507
# 1      Complete Air Conditioning Kit w/ New Compressor     17507
# 2      Complete Air Conditioning Kit w/ New Compressor     17507
# 3      Complete Air Conditioning Kit w/ New Compressor     17507
# 4      Complete Air Conditioning Kit w/ New Compressor     17507
# ...                                                ...       ...
# 26075                   A/C Compressor & Component Kit     17507
# 26076                   A/C Compressor & Component Kit     17507
# 26077                   A/C Compressor & Component Kit     17507
# 26078                   A/C Compressor & Component Kit     17507
# 26079                   A/C Compressor & Component Kit     17507
#
#        Manufacturer Part Number                                       Note 1  \
# 0      FOUR SEASONS     10059NK  Includes Gasket Set and A/C Refrigerant Oil
# 1      FOUR SEASONS     10059NK  Includes Gasket Set and A/C Refrigerant Oil
# 2      FOUR SEASONS      1007NK  Includes Gasket Set and A/C Refrigerant Oil
# 3      FOUR SEASONS      1007NK  Includes Gasket Set and A/C Refrigerant Oil
# 4      FOUR SEASONS      1014NK  Includes Gasket Set and A/C Refrigerant Oil
# ...             ...         ...                                          ...
# 26075  FOUR SEASONS     TSR7372                                        Reman
# 26076  FOUR SEASONS     TSR7372                                        Reman
# 26077  FOUR SEASONS     TSR7379                                        Reman
# 26078  FOUR SEASONS     TSR7379                                        Reman
# 26079  FOUR SEASONS     TSR7379                                        Reman
#
#                                              Json_Note 2 Choose  \
# 0      {"0": "Category: A/C Compressor &amp; Componen...
# 1      {"0": "Category: A/C Compressor &amp; Componen...
# 2      {"0": "Category: A/C Compressor &amp; Componen...
# 3      {"0": "Category: A/C Compressor &amp; Componen...
# 4      {"0": "Category: A/C Compressor &amp; Componen...
# ...                                                  ...    ...
# 26075  {"0": "Category: A/C Compressor &amp; Componen...
# 26076  {"0": "Category: A/C Compressor &amp; Componen...
# 26077  {"0": "Category: A/C Compressor &amp; Componen...
# 26078  {"0": "Category: A/C Compressor &amp; Componen...
# 26079  {"0": "Category: A/C Compressor &amp; Componen...
#
#                      Json_Price  ... Kit_No quantity  \
# 0      {"automatic": "$346.79"}  ...      1        1
# 1      {"automatic": "$346.79"}  ...      2        1
# 2      {"automatic": "$273.79"}  ...      1        1
# 3      {"automatic": "$273.79"}  ...      2        1
# 4      {"automatic": "$169.79"}  ...      1        1
# ...                         ...  ...    ...      ...
# 26075  {"automatic": "$201.79"}  ...      2        1
# 26076  {"automatic": "$201.79"}  ...      3        1
# 26077  {"automatic": "$201.79"}  ...      1        1
# 26078  {"automatic": "$201.79"}  ...      2        1
# 26079  {"automatic": "$201.79"}  ...      3        1
#
#                                        type type_code part_code part_number  \
# 0                            A/C Compressor      6628  10530432      198276
# 1                       A/C Expansion Valve      6788  15575473     10900SK
# 2                            A/C Compressor      6628   1003188       78588
# 3          A/C Receiver Drier / Accumulator      6972  12735369     60061SK
# 4                            A/C Compressor      6628    815939       58124
# ...                                     ...       ...       ...         ...
# 26075  A/C Receiver Drier Desiccant Element     16858  11329045       83387
# 26076                   A/C Expansion Valve      6788  13235597       39623
# 26077                        A/C Compressor      6628  14755249      197297
# 26078  A/C Receiver Drier Desiccant Element     16858   8138000       83235
# 26079                   A/C Expansion Valve      6788  10530504       39558
#
#        manufacturer                                                url  \
# 0      FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 1      FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 2      FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 3      FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 4      FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# ...             ...                                                ...
# 26075  FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 26076  FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 26077  FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 26078  FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
# 26079  FOUR SEASONS  https://www.rockauto.com/en/parts/FOUR SEASONS...
#
#                                                     info  \
# 0      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 1      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 2      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 3      https://www.rockauto.com/en/moreinfo.php?pk=12...
# 4      https://www.rockauto.com/en/moreinfo.php?pk=81...
# ...                                                  ...
# 26075  https://www.rockauto.com/en/moreinfo.php?pk=11...
# 26076  https://www.rockauto.com/en/moreinfo.php?pk=13...
# 26077  https://www.rockauto.com/en/moreinfo.php?pk=14...
# 26078  https://www.rockauto.com/en/moreinfo.php?pk=81...
# 26079  https://www.rockauto.com/en/moreinfo.php?pk=10...
#
#                                                 dict_src
# 0      {'0': 'https://www.rockauto.com/info/52/198276...
# 1      {'0': 'https://www.rockauto.com/info/52/10900S...
# 2      {'0': 'https://www.rockauto.com/info/52/78588....
# 3      {'0': 'https://www.rockauto.com/info/52/60061S...
# 4      {'0': 'https://www.rockauto.com/info/52/58124....
# ...                                                  ...
# 26075  {'0': 'https://www.rockauto.com/info/52/83387....
# 26076  {'0': 'https://www.rockauto.com/info/52/39623....
# 26077  {'0': 'https://www.rockauto.com/info/52/197297...
# 26078  {'0': 'https://www.rockauto.com/info/52/83235....
# 26079  {'0': 'https://www.rockauto.com/info/52/39558....
#
# [26080 rows x 189 columns]

# %% [markdown]
# # 2. Dorman
#
# ## 2.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

list_df = []
for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Configuration'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')
    
    vehicle_without_engine = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    vehicle_with_engine = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =
    
    df_temp = pd.DataFrame([{'No': input_2.loc[i, 'No'],
                             'Part Number': input_2.loc[i, 'Part Number'],
                             'Vehicle W/o Engine': vehicle_without_engine,
                             'Vehicle W/ Engine': vehicle_with_engine}])
    list_df.append(df_temp)
    
# = = = = = = = = = = = = = = =

output = pd.concat(list_df, ignore_index=True).fillna('')

output = output.sort_values(by=['No'],
                            ascending=[True],
                            ignore_index=True)

output.to_excel('./vehicle.xlsx', index=False)

output

# %% [markdown]
# ## 2.2. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

list_df = []
for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_dict = json.loads(input_.loc[i, 'Json_Specification'])

    for dict_ in dict_dict.values():
        df_temp.loc[0, list(dict_.keys())[0]] = list(dict_.values())[0]

    list_df.append(df_temp)

# = = = = = = = = = = = = = = =

output = pd.concat(list_df, ignore_index=True).fillna('')

output = output.sort_values(by=['No'],
                            ascending=[True],
                            ignore_index=True)

output.to_excel('./crawler.xlsx', index=False)

output

# %% [markdown]
# # 3. eBay
#
# ## 3.1. Vehicle
#
# ### 3.1.1. US、UK、AU、CA

# %%
import pandas as pd

input_ = pd.read_excel('./crawler-vehicle.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Engine'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ### 3.1.2. DE

# %%
import pandas as pd

input_ = pd.read_excel('./crawler-vehicle.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year, year_2 = df_temp.loc[j, 'Marke'], df_temp.loc[j, 'Modell'], df_temp.loc[j, 'Motor'], int(df_temp.loc[j, 'Baujahr'].split('-')[0].split('/')[0]), int(df_temp.loc[j, 'Baujahr'].split('-')[1].split('/')[0])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year] if year == year_2 else [year, year_2]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year] if year == year_2 else [year, year_2]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year] if year == year_2 else [year, year_2]
        else:
            if year not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year)
            if year_2 not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year_2)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ## 3.2 Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Specific'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 4. Cardone
#
# ## 4.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], ' '.join([df_temp.loc[j, 'Cylinder'], df_temp.loc[j, 'Displacement'], df_temp.loc[j, 'Liter']]), int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ## 4.2. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Info'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 5. Standard
#
# ## 5.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Vehicle'])
    vehicle = ''
    for value in dict_.values():
        vehicle += f'{value}\n'

    input_.loc[i, 'Vehicle'] = vehicle.strip()

# = = = = = = = = = = = = = = =

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# ## 5.2. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    service, dict_ = '', json.loads(input_.loc[i, 'Json_Service'])
    for k, v in dict_.items():
        service += f'{int(k)+1}. {v}\n'
    input_.loc[i, 'Service'] = service.strip()

    dict_ = json.loads(input_.loc[i, 'Json_Spec'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 7. SpectraPremium
#
# ## 7.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make_model_engine, year = df_temp.loc[j, 'Make Model Engine'], int(df_temp.loc[j, 'Year'])

        if make_model_engine not in dict_vehicle:
            dict_vehicle[make_model_engine] = [year]
        elif year not in dict_vehicle[make_model_engine]:
            dict_vehicle[make_model_engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make_model_engine in dict_vehicle:
        year_begin = min(dict_vehicle[make_model_engine])
        year_end = max(dict_vehicle[make_model_engine])
        list_vehicle.append(f'{make_model_engine}'.strip() if year_begin == year_end else f'{make_model_engine} {year_begin}-{year_end}'.strip())

    input_2.loc[i, 'Vehicle'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 12. 1AAuto
#
# ## 12.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Description'])
    for value in dict_.values():
        if type(list(value.values())[0]) == dict:
            str_ = ''
            for k, v in list(value.values())[0].items():
                str_ += f'{int(k)+1}. {v}\n'
            input_.loc[i, list(value.keys())[0]] = str_.strip()
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 18. Auveco
#
# ## 18.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Description'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 24.Gates
#
# ## 24.1. Json

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Product No'] = input_['Product No'].astype(int)
input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_ = json.loads(input_.loc[i, 'Json_Information'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./crawler.xlsx', index=False)

input_

# %% [markdown]
# # 30.TecDoc
#
# ## 30.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm
from datetime import datetime

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year, year_2 = df_temp.loc[j, 'manuDesc'], df_temp.loc[j, 'modelDesc'], df_temp.loc[j, 'carDesc'], int(str(df_temp.loc[j, 'yearOfConstructionFrom'][:4])), int(datetime.now().strftime('%Y') if df_temp.loc[j, 'yearOfConstructionTo'] == '' else str(df_temp.loc[j, 'yearOfConstructionTo'][:4]))

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year] if year == year_2 else [year, year_2]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year] if year == year_2 else [year, year_2]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year] if year == year_2 else [year, year_2]
        else:
            if year not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year)
            if year_2 not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year_2)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 10. Amazon

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_

# %%
import json

for i in range(len(input_)):
    dict_ = json.loads(input_.loc[i, 'Json_Overview'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 1'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 2'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 1'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 2'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./fuck.xlsx', index=False)

input_
