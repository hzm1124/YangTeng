# %%
import os

list_file = sorted(list(os.walk('./file/4.src'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_100.xlsx',
#  'crawler_1000.xlsx',
#  'crawler_1001.xlsx',
#  'crawler_1002.xlsx',
#  'crawler_1003.xlsx',
#  'crawler_1004.xlsx',
#  'crawler_1005.xlsx',
#  'crawler_1006.xlsx',
#  'crawler_1007.xlsx',
#  'crawler_1008.xlsx',
#  'crawler_1009.xlsx',
#  'crawler_101.xlsx',
#  'crawler_1010.xlsx',
#  'crawler_1011.xlsx',
#  'crawler_1012.xlsx',
#  'crawler_1013.xlsx',
#  'crawler_1014.xlsx',
#  'crawler_1015.xlsx',
#  'crawler_1016.xlsx',
#  'crawler_1017.xlsx',
#  'crawler_1018.xlsx',
#  'crawler_1019.xlsx',
#  'crawler_102.xlsx',
#  'crawler_1020.xlsx',
#  'crawler_1021.xlsx',
#  'crawler_1022.xlsx',
#  'crawler_1023.xlsx',
#  'crawler_1024.xlsx',
#  'crawler_1025.xlsx',
#  'crawler_1026.xlsx',
#  'crawler_1027.xlsx',
#  'crawler_1028.xlsx',
#  'crawler_1029.xlsx',
#  'crawler_103.xlsx',
#  'crawler_1030.xlsx',
#  'crawler_1031.xlsx',
#  'crawler_1032.xlsx',
#  'crawler_1033.xlsx',
#  'crawler_1034.xlsx',
#  'crawler_1035.xlsx',
#  'crawler_1036.xlsx',
#  'crawler_1037.xlsx',
#  'crawler_1038.xlsx',
#  'crawler_1039.xlsx',
#  'crawler_104.xlsx',
#  'crawler_1040.xlsx',
#  'crawler_1041.xlsx',
#  'crawler_1042.xlsx',
#  'crawler_1043.xlsx',
#  'crawler_1044.xlsx',
#  'crawler_1045.xlsx',
#  'crawler_1046.xlsx',
#  'crawler_1047.xlsx',
#  'crawler_1048.xlsx',
#  'crawler_1049.xlsx',
#  'crawler_105.xlsx',
#  'crawler_1050.xlsx',
#  'crawler_1051.xlsx',
#  'crawler_1052.xlsx',
#  'crawler_1053.xlsx',
#  'crawler_1054.xlsx',
#  'crawler_1055.xlsx',
#  'crawler_1056.xlsx',
#  'crawler_1057.xlsx',
#  'crawler_1058.xlsx',
#  'crawler_1059.xlsx',
#  'crawler_106.xlsx',
#  'crawler_1060.xlsx',
#  'crawler_1061.xlsx',
#  'crawler_1062.xlsx',
#  'crawler_1063.xlsx',
#  'crawler_1064.xlsx',
#  'crawler_1065.xlsx',
#  'crawler_1066.xlsx',
#  'crawler_1067.xlsx',
#  'crawler_1068.xlsx',
#  'crawler_1069.xlsx',
#  'crawler_107.xlsx',
#  'crawler_1070.xlsx',
#  'crawler_1071.xlsx',
#  'crawler_1072.xlsx',
#  'crawler_1073.xlsx',
#  'crawler_1074.xlsx',
#  'crawler_1075.xlsx',
#  'crawler_1076.xlsx',
#  'crawler_1077.xlsx',
#  'crawler_1078.xlsx',
#  'crawler_1079.xlsx',
#  'crawler_108.xlsx',
#  'crawler_1080.xlsx',
#  'crawler_1081.xlsx',
#  'crawler_1082.xlsx',
#  'crawler_1083.xlsx',
#  'crawler_1084.xlsx',
#  'crawler_1085.xlsx',
#  'crawler_1086.xlsx',
#  'crawler_1087.xlsx',
#  'crawler_1088.xlsx',
#  'crawler_1089.xlsx',
#  'crawler_109.xlsx',
#  'crawler_1090.xlsx',
#  'crawler_1091.xlsx',
#  'crawler_1092.xlsx',
#  'crawler_1093.xlsx',
#  'crawler_1094.xlsx',
#  'crawler_1095.xlsx',
#  'crawler_1096.xlsx',
#  'crawler_1097.xlsx',
#  'crawler_1098.xlsx',
#  'crawler_1099.xlsx',
#  'crawler_11.xlsx',
#  'crawler_110.xlsx',
#  'crawler_1100.xlsx',
#  'crawler_1101.xlsx',
#  'crawler_1102.xlsx',
#  'crawler_1103.xlsx',
#  'crawler_1104.xlsx',
#  'crawler_1105.xlsx',
#  'crawler_1106.xlsx',
#  'crawler_1107.xlsx',
#  'crawler_1108.xlsx',
#  'crawler_1109.xlsx',
#  'crawler_111.xlsx',
#  'crawler_1110.xlsx',
#  'crawler_1111.xlsx',
#  'crawler_1112.xlsx',
#  'crawler_1113.xlsx',
#  'crawler_1114.xlsx',
#  'crawler_1115.xlsx',
#  'crawler_1116.xlsx',
#  'crawler_1117.xlsx',
#  'crawler_1118.xlsx',
#  'crawler_1119.xlsx',
#  'crawler_112.xlsx',
#  'crawler_1120.xlsx',
#  'crawler_1121.xlsx',
#  'crawler_1122.xlsx',
#  'crawler_1123.xlsx',
#  'crawler_1124.xlsx',
#  'crawler_1125.xlsx',
#  'crawler_1126.xlsx',
#  'crawler_1127.xlsx',
#  'crawler_1128.xlsx',
#  'crawler_1129.xlsx',
#  'crawler_113.xlsx',
#  'crawler_1130.xlsx',
#  'crawler_1131.xlsx',
#  'crawler_1132.xlsx',
#  'crawler_1133.xlsx',
#  'crawler_1134.xlsx',
#  'crawler_1135.xlsx',
#  'crawler_1136.xlsx',
#  'crawler_1137.xlsx',
#  'crawler_1138.xlsx',
#  'crawler_1139.xlsx',
#  'crawler_114.xlsx',
#  'crawler_1140.xlsx',
#  'crawler_1141.xlsx',
#  'crawler_1142.xlsx',
#  'crawler_1143.xlsx',
#  'crawler_1144.xlsx',
#  'crawler_1145.xlsx',
#  'crawler_1146.xlsx',
#  'crawler_1147.xlsx',
#  'crawler_1148.xlsx',
#  'crawler_1149.xlsx',
#  'crawler_115.xlsx',
#  'crawler_1150.xlsx',
#  'crawler_1151.xlsx',
#  'crawler_1152.xlsx',
#  'crawler_1153.xlsx',
#  'crawler_1154.xlsx',
#  'crawler_1155.xlsx',
#  'crawler_1156.xlsx',
#  'crawler_1157.xlsx',
#  'crawler_1158.xlsx',
#  'crawler_1159.xlsx',
#  'crawler_116.xlsx',
#  'crawler_1160.xlsx',
#  'crawler_1161.xlsx',
#  'crawler_1162.xlsx',
#  'crawler_1163.xlsx',
#  'crawler_1164.xlsx',
#  'crawler_1165.xlsx',
#  'crawler_1166.xlsx',
#  'crawler_1167.xlsx',
#  'crawler_1168.xlsx',
#  'crawler_1169.xlsx',
#  'crawler_117.xlsx',
#  'crawler_1170.xlsx',
#  'crawler_1171.xlsx',
#  'crawler_1172.xlsx',
#  'crawler_1173.xlsx',
#  'crawler_1174.xlsx',
#  'crawler_1175.xlsx',
#  'crawler_1176.xlsx',
#  'crawler_1177.xlsx',
#  'crawler_1178.xlsx',
#  'crawler_1179.xlsx',
#  'crawler_118.xlsx',
#  'crawler_1180.xlsx',
#  'crawler_1181.xlsx',
#  'crawler_1182.xlsx',
#  'crawler_1183.xlsx',
#  'crawler_1184.xlsx',
#  'crawler_1185.xlsx',
#  'crawler_1186.xlsx',
#  'crawler_1187.xlsx',
#  'crawler_1188.xlsx',
#  'crawler_1189.xlsx',
#  'crawler_119.xlsx',
#  'crawler_1190.xlsx',
#  'crawler_1191.xlsx',
#  'crawler_1192.xlsx',
#  'crawler_1193.xlsx',
#  'crawler_1194.xlsx',
#  'crawler_1195.xlsx',
#  'crawler_1196.xlsx',
#  'crawler_1197.xlsx',
#  'crawler_1198.xlsx',
#  'crawler_1199.xlsx',
#  'crawler_12.xlsx',
#  'crawler_120.xlsx',
#  'crawler_1200.xlsx',
#  'crawler_1201.xlsx',
#  'crawler_1202.xlsx',
#  'crawler_1203.xlsx',
#  'crawler_1204.xlsx',
#  'crawler_1205.xlsx',
#  'crawler_1206.xlsx',
#  'crawler_1207.xlsx',
#  'crawler_1208.xlsx',
#  'crawler_1209.xlsx',
#  'crawler_121.xlsx',
#  'crawler_1210.xlsx',
#  'crawler_1211.xlsx',
#  'crawler_1212.xlsx',
#  'crawler_1213.xlsx',
#  'crawler_1214.xlsx',
#  'crawler_1215.xlsx',
#  'crawler_1216.xlsx',
#  'crawler_1217.xlsx',
#  'crawler_1218.xlsx',
#  'crawler_1219.xlsx',
#  'crawler_122.xlsx',
#  'crawler_1220.xlsx',
#  'crawler_1221.xlsx',
#  'crawler_1222.xlsx',
#  'crawler_1223.xlsx',
#  'crawler_1224.xlsx',
#  'crawler_1225.xlsx',
#  'crawler_1226.xlsx',
#  'crawler_1227.xlsx',
#  'crawler_1228.xlsx',
#  'crawler_1229.xlsx',
#  'crawler_123.xlsx',
#  'crawler_1230.xlsx',
#  'crawler_1231.xlsx',
#  'crawler_1232.xlsx',
#  'crawler_1233.xlsx',
#  'crawler_1234.xlsx',
#  'crawler_1235.xlsx',
#  'crawler_1236.xlsx',
#  'crawler_1237.xlsx',
#  'crawler_1238.xlsx',
#  'crawler_1239.xlsx',
#  'crawler_124.xlsx',
#  'crawler_1240.xlsx',
#  'crawler_1241.xlsx',
#  'crawler_1242.xlsx',
#  'crawler_1243.xlsx',
#  'crawler_1244.xlsx',
#  'crawler_1245.xlsx',
#  'crawler_1246.xlsx',
#  'crawler_1247.xlsx',
#  'crawler_1248.xlsx',
#  'crawler_1249.xlsx',
#  'crawler_125.xlsx',
#  'crawler_1250.xlsx',
#  'crawler_1251.xlsx',
#  'crawler_1252.xlsx',
#  'crawler_1253.xlsx',
#  'crawler_1254.xlsx',
#  'crawler_1255.xlsx',
#  'crawler_1256.xlsx',
#  'crawler_1257.xlsx',
#  'crawler_1258.xlsx',
#  'crawler_1259.xlsx',
#  'crawler_126.xlsx',
#  'crawler_1260.xlsx',
#  'crawler_1261.xlsx',
#  'crawler_1262.xlsx',
#  'crawler_1263.xlsx',
#  'crawler_1264.xlsx',
#  'crawler_1265.xlsx',
#  'crawler_1266.xlsx',
#  'crawler_1267.xlsx',
#  'crawler_1268.xlsx',
#  'crawler_1269.xlsx',
#  'crawler_127.xlsx',
#  'crawler_1270.xlsx',
#  'crawler_1271.xlsx',
#  'crawler_1272.xlsx',
#  'crawler_1273.xlsx',
#  'crawler_1274.xlsx',
#  'crawler_1275.xlsx',
#  'crawler_1276.xlsx',
#  'crawler_1277.xlsx',
#  'crawler_1278.xlsx',
#  'crawler_1279.xlsx',
#  'crawler_128.xlsx',
#  'crawler_1280.xlsx',
#  'crawler_1281.xlsx',
#  'crawler_1282.xlsx',
#  'crawler_1283.xlsx',
#  'crawler_1284.xlsx',
#  'crawler_1285.xlsx',
#  'crawler_1286.xlsx',
#  'crawler_1287.xlsx',
#  'crawler_1288.xlsx',
#  'crawler_1289.xlsx',
#  'crawler_129.xlsx',
#  'crawler_1290.xlsx',
#  'crawler_1291.xlsx',
#  'crawler_1292.xlsx',
#  'crawler_1293.xlsx',
#  'crawler_1294.xlsx',
#  'crawler_1295.xlsx',
#  'crawler_1296.xlsx',
#  'crawler_1297.xlsx',
#  'crawler_1298.xlsx',
#  'crawler_1299.xlsx',
#  'crawler_13.xlsx',
#  'crawler_130.xlsx',
#  'crawler_1300.xlsx',
#  'crawler_1301.xlsx',
#  'crawler_1302.xlsx',
#  'crawler_1303.xlsx',
#  'crawler_1304.xlsx',
#  'crawler_1305.xlsx',
#  'crawler_1306.xlsx',
#  'crawler_1307.xlsx',
#  'crawler_1308.xlsx',
#  'crawler_1309.xlsx',
#  'crawler_131.xlsx',
#  'crawler_1310.xlsx',
#  'crawler_1311.xlsx',
#  'crawler_1312.xlsx',
#  'crawler_1313.xlsx',
#  'crawler_1314.xlsx',
#  'crawler_1315.xlsx',
#  'crawler_1316.xlsx',
#  'crawler_1317.xlsx',
#  'crawler_1318.xlsx',
#  'crawler_1319.xlsx',
#  'crawler_132.xlsx',
#  'crawler_1320.xlsx',
#  'crawler_1321.xlsx',
#  'crawler_1322.xlsx',
#  'crawler_1323.xlsx',
#  'crawler_1324.xlsx',
#  'crawler_1325.xlsx',
#  'crawler_1326.xlsx',
#  'crawler_1327.xlsx',
#  'crawler_1328.xlsx',
#  'crawler_1329.xlsx',
#  'crawler_133.xlsx',
#  'crawler_1330.xlsx',
#  'crawler_1331.xlsx',
#  'crawler_1332.xlsx',
#  'crawler_1333.xlsx',
#  'crawler_1334.xlsx',
#  'crawler_1335.xlsx',
#  'crawler_1336.xlsx',
#  'crawler_1337.xlsx',
#  'crawler_1338.xlsx',
#  'crawler_1339.xlsx',
#  'crawler_134.xlsx',
#  'crawler_1340.xlsx',
#  'crawler_1341.xlsx',
#  'crawler_1342.xlsx',
#  'crawler_1343.xlsx',
#  'crawler_1344.xlsx',
#  'crawler_1345.xlsx',
#  'crawler_1346.xlsx',
#  'crawler_1347.xlsx',
#  'crawler_1348.xlsx',
#  'crawler_1349.xlsx',
#  'crawler_135.xlsx',
#  'crawler_1350.xlsx',
#  'crawler_1351.xlsx',
#  'crawler_1352.xlsx',
#  'crawler_1353.xlsx',
#  'crawler_1354.xlsx',
#  'crawler_1355.xlsx',
#  'crawler_1356.xlsx',
#  'crawler_1357.xlsx',
#  'crawler_1358.xlsx',
#  'crawler_1359.xlsx',
#  'crawler_136.xlsx',
#  'crawler_1360.xlsx',
#  'crawler_1361.xlsx',
#  'crawler_1362.xlsx',
#  'crawler_1363.xlsx',
#  'crawler_1364.xlsx',
#  'crawler_1365.xlsx',
#  'crawler_1366.xlsx',
#  'crawler_1367.xlsx',
#  'crawler_1368.xlsx',
#  'crawler_1369.xlsx',
#  'crawler_137.xlsx',
#  'crawler_1370.xlsx',
#  'crawler_1371.xlsx',
#  'crawler_1372.xlsx',
#  'crawler_1373.xlsx',
#  'crawler_1374.xlsx',
#  'crawler_1375.xlsx',
#  'crawler_1376.xlsx',
#  'crawler_1377.xlsx',
#  'crawler_1378.xlsx',
#  'crawler_1379.xlsx',
#  'crawler_138.xlsx',
#  'crawler_1380.xlsx',
#  'crawler_1381.xlsx',
#  'crawler_1382.xlsx',
#  'crawler_1383.xlsx',
#  'crawler_1384.xlsx',
#  'crawler_1385.xlsx',
#  'crawler_1386.xlsx',
#  'crawler_1387.xlsx',
#  'crawler_1388.xlsx',
#  'crawler_1389.xlsx',
#  'crawler_139.xlsx',
#  'crawler_1390.xlsx',
#  'crawler_1391.xlsx',
#  'crawler_1392.xlsx',
#  'crawler_1393.xlsx',
#  'crawler_1394.xlsx',
#  'crawler_1395.xlsx',
#  'crawler_1396.xlsx',
#  'crawler_1397.xlsx',
#  'crawler_1398.xlsx',
#  'crawler_1399.xlsx',
#  'crawler_14.xlsx',
#  'crawler_140.xlsx',
#  'crawler_1400.xlsx',
#  'crawler_1401.xlsx',
#  'crawler_1402.xlsx',
#  'crawler_1403.xlsx',
#  'crawler_1404.xlsx',
#  'crawler_1405.xlsx',
#  'crawler_1406.xlsx',
#  'crawler_1407.xlsx',
#  'crawler_1408.xlsx',
#  'crawler_1409.xlsx',
#  'crawler_141.xlsx',
#  'crawler_1410.xlsx',
#  'crawler_1411.xlsx',
#  'crawler_1412.xlsx',
#  'crawler_1413.xlsx',
#  'crawler_1414.xlsx',
#  'crawler_1415.xlsx',
#  'crawler_1416.xlsx',
#  'crawler_1417.xlsx',
#  'crawler_1418.xlsx',
#  'crawler_1419.xlsx',
#  'crawler_142.xlsx',
#  'crawler_1420.xlsx',
#  'crawler_1421.xlsx',
#  'crawler_1422.xlsx',
#  'crawler_1423.xlsx',
#  'crawler_1424.xlsx',
#  'crawler_1425.xlsx',
#  'crawler_1426.xlsx',
#  'crawler_1427.xlsx',
#  'crawler_1428.xlsx',
#  'crawler_1429.xlsx',
#  'crawler_143.xlsx',
#  'crawler_1430.xlsx',
#  'crawler_1431.xlsx',
#  'crawler_1432.xlsx',
#  'crawler_1433.xlsx',
#  'crawler_1434.xlsx',
#  'crawler_1435.xlsx',
#  'crawler_1436.xlsx',
#  'crawler_1437.xlsx',
#  'crawler_1438.xlsx',
#  'crawler_1439.xlsx',
#  'crawler_144.xlsx',
#  'crawler_1440.xlsx',
#  'crawler_1441.xlsx',
#  'crawler_1442.xlsx',
#  'crawler_1443.xlsx',
#  'crawler_1444.xlsx',
#  'crawler_1445.xlsx',
#  'crawler_1446.xlsx',
#  'crawler_1447.xlsx',
#  'crawler_1448.xlsx',
#  'crawler_1449.xlsx',
#  'crawler_145.xlsx',
#  'crawler_1450.xlsx',
#  'crawler_1451.xlsx',
#  'crawler_1452.xlsx',
#  'crawler_1453.xlsx',
#  'crawler_1454.xlsx',
#  'crawler_1455.xlsx',
#  'crawler_1456.xlsx',
#  'crawler_1457.xlsx',
#  'crawler_1458.xlsx',
#  'crawler_1459.xlsx',
#  'crawler_146.xlsx',
#  'crawler_1460.xlsx',
#  'crawler_1461.xlsx',
#  'crawler_1462.xlsx',
#  'crawler_1463.xlsx',
#  'crawler_1464.xlsx',
#  'crawler_1465.xlsx',
#  'crawler_1466.xlsx',
#  'crawler_1467.xlsx',
#  'crawler_1468.xlsx',
#  'crawler_1469.xlsx',
#  'crawler_147.xlsx',
#  'crawler_1470.xlsx',
#  'crawler_1471.xlsx',
#  'crawler_1472.xlsx',
#  'crawler_1473.xlsx',
#  'crawler_1474.xlsx',
#  'crawler_1475.xlsx',
#  'crawler_1476.xlsx',
#  'crawler_1477.xlsx',
#  'crawler_1478.xlsx',
#  'crawler_1479.xlsx',
#  'crawler_148.xlsx',
#  'crawler_1480.xlsx',
#  'crawler_1481.xlsx',
#  'crawler_1482.xlsx',
#  'crawler_1483.xlsx',
#  'crawler_1484.xlsx',
#  'crawler_1485.xlsx',
#  'crawler_1486.xlsx',
#  'crawler_1487.xlsx',
#  'crawler_1488.xlsx',
#  'crawler_1489.xlsx',
#  'crawler_149.xlsx',
#  'crawler_1490.xlsx',
#  'crawler_1491.xlsx',
#  'crawler_1492.xlsx',
#  'crawler_1493.xlsx',
#  'crawler_1494.xlsx',
#  'crawler_1495.xlsx',
#  'crawler_1496.xlsx',
#  'crawler_1497.xlsx',
#  'crawler_1498.xlsx',
#  'crawler_1499.xlsx',
#  'crawler_15.xlsx',
#  'crawler_150.xlsx',
#  'crawler_1500.xlsx',
#  'crawler_1501.xlsx',
#  'crawler_1502.xlsx',
#  'crawler_1503.xlsx',
#  'crawler_1504.xlsx',
#  'crawler_1505.xlsx',
#  'crawler_1506.xlsx',
#  'crawler_1507.xlsx',
#  'crawler_1508.xlsx',
#  'crawler_1509.xlsx',
#  'crawler_151.xlsx',
#  'crawler_1510.xlsx',
#  'crawler_1511.xlsx',
#  'crawler_1512.xlsx',
#  'crawler_1513.xlsx',
#  'crawler_1514.xlsx',
#  'crawler_1515.xlsx',
#  'crawler_1516.xlsx',
#  'crawler_1517.xlsx',
#  'crawler_1518.xlsx',
#  'crawler_1519.xlsx',
#  'crawler_152.xlsx',
#  'crawler_1520.xlsx',
#  'crawler_1521.xlsx',
#  'crawler_1522.xlsx',
#  'crawler_1523.xlsx',
#  'crawler_1524.xlsx',
#  'crawler_1525.xlsx',
#  'crawler_1526.xlsx',
#  'crawler_1527.xlsx',
#  'crawler_1528.xlsx',
#  'crawler_1529.xlsx',
#  'crawler_153.xlsx',
#  'crawler_1530.xlsx',
#  'crawler_1531.xlsx',
#  'crawler_1532.xlsx',
#  'crawler_1533.xlsx',
#  'crawler_1534.xlsx',
#  'crawler_1535.xlsx',
#  'crawler_1536.xlsx',
#  'crawler_1537.xlsx',
#  'crawler_1538.xlsx',
#  'crawler_1539.xlsx',
#  'crawler_154.xlsx',
#  'crawler_1540.xlsx',
#  'crawler_1541.xlsx',
#  'crawler_1542.xlsx',
#  'crawler_1543.xlsx',
#  'crawler_1544.xlsx',
#  'crawler_1545.xlsx',
#  'crawler_1546.xlsx',
#  'crawler_1547.xlsx',
#  'crawler_1548.xlsx',
#  'crawler_1549.xlsx',
#  'crawler_155.xlsx',
#  'crawler_1550.xlsx',
#  'crawler_1551.xlsx',
#  'crawler_1552.xlsx',
#  'crawler_1553.xlsx',
#  'crawler_1554.xlsx',
#  'crawler_1555.xlsx',
#  'crawler_1556.xlsx',
#  'crawler_1557.xlsx',
#  'crawler_1558.xlsx',
#  'crawler_1559.xlsx',
#  'crawler_156.xlsx',
#  'crawler_1560.xlsx',
#  'crawler_1561.xlsx',
#  'crawler_1562.xlsx',
#  'crawler_1563.xlsx',
#  'crawler_1564.xlsx',
#  'crawler_1565.xlsx',
#  'crawler_1566.xlsx',
#  'crawler_1567.xlsx',
#  'crawler_1568.xlsx',
#  'crawler_1569.xlsx',
#  'crawler_157.xlsx',
#  'crawler_1570.xlsx',
#  'crawler_1571.xlsx',
#  'crawler_1572.xlsx',
#  'crawler_1573.xlsx',
#  'crawler_1574.xlsx',
#  'crawler_158.xlsx',
#  'crawler_159.xlsx',
#  'crawler_16.xlsx',
#  'crawler_160.xlsx',
#  'crawler_161.xlsx',
#  'crawler_162.xlsx',
#  'crawler_163.xlsx',
#  'crawler_164.xlsx',
#  'crawler_165.xlsx',
#  'crawler_166.xlsx',
#  'crawler_167.xlsx',
#  'crawler_168.xlsx',
#  'crawler_169.xlsx',
#  'crawler_17.xlsx',
#  'crawler_170.xlsx',
#  'crawler_171.xlsx',
#  'crawler_172.xlsx',
#  'crawler_173.xlsx',
#  'crawler_174.xlsx',
#  'crawler_175.xlsx',
#  'crawler_176.xlsx',
#  'crawler_177.xlsx',
#  'crawler_178.xlsx',
#  'crawler_179.xlsx',
#  'crawler_18.xlsx',
#  'crawler_180.xlsx',
#  'crawler_181.xlsx',
#  'crawler_182.xlsx',
#  'crawler_183.xlsx',
#  'crawler_184.xlsx',
#  'crawler_185.xlsx',
#  'crawler_186.xlsx',
#  'crawler_187.xlsx',
#  'crawler_188.xlsx',
#  'crawler_189.xlsx',
#  'crawler_19.xlsx',
#  'crawler_190.xlsx',
#  'crawler_191.xlsx',
#  'crawler_192.xlsx',
#  'crawler_193.xlsx',
#  'crawler_194.xlsx',
#  'crawler_195.xlsx',
#  'crawler_196.xlsx',
#  'crawler_197.xlsx',
#  'crawler_198.xlsx',
#  'crawler_199.xlsx',
#  'crawler_2.xlsx',
#  'crawler_20.xlsx',
#  'crawler_200.xlsx',
#  'crawler_201.xlsx',
#  'crawler_202.xlsx',
#  'crawler_203.xlsx',
#  'crawler_204.xlsx',
#  'crawler_205.xlsx',
#  'crawler_206.xlsx',
#  'crawler_207.xlsx',
#  'crawler_208.xlsx',
#  'crawler_209.xlsx',
#  'crawler_21.xlsx',
#  'crawler_210.xlsx',
#  'crawler_211.xlsx',
#  'crawler_212.xlsx',
#  'crawler_213.xlsx',
#  'crawler_214.xlsx',
#  'crawler_215.xlsx',
#  'crawler_216.xlsx',
#  'crawler_217.xlsx',
#  'crawler_218.xlsx',
#  'crawler_219.xlsx',
#  'crawler_22.xlsx',
#  'crawler_220.xlsx',
#  'crawler_221.xlsx',
#  'crawler_222.xlsx',
#  'crawler_223.xlsx',
#  'crawler_224.xlsx',
#  'crawler_225.xlsx',
#  'crawler_226.xlsx',
#  'crawler_227.xlsx',
#  'crawler_228.xlsx',
#  'crawler_229.xlsx',
#  'crawler_23.xlsx',
#  'crawler_230.xlsx',
#  'crawler_231.xlsx',
#  'crawler_232.xlsx',
#  'crawler_233.xlsx',
#  'crawler_234.xlsx',
#  'crawler_235.xlsx',
#  'crawler_236.xlsx',
#  'crawler_237.xlsx',
#  'crawler_238.xlsx',
#  'crawler_239.xlsx',
#  'crawler_24.xlsx',
#  'crawler_240.xlsx',
#  'crawler_241.xlsx',
#  'crawler_242.xlsx',
#  'crawler_243.xlsx',
#  'crawler_244.xlsx',
#  'crawler_245.xlsx',
#  'crawler_246.xlsx',
#  'crawler_247.xlsx',
#  'crawler_248.xlsx',
#  'crawler_249.xlsx',
#  'crawler_25.xlsx',
#  'crawler_250.xlsx',
#  'crawler_251.xlsx',
#  'crawler_252.xlsx',
#  'crawler_253.xlsx',
#  'crawler_254.xlsx',
#  'crawler_255.xlsx',
#  'crawler_256.xlsx',
#  'crawler_257.xlsx',
#  'crawler_258.xlsx',
#  'crawler_259.xlsx',
#  'crawler_26.xlsx',
#  'crawler_260.xlsx',
#  'crawler_261.xlsx',
#  'crawler_262.xlsx',
#  'crawler_263.xlsx',
#  'crawler_264.xlsx',
#  'crawler_265.xlsx',
#  'crawler_266.xlsx',
#  'crawler_267.xlsx',
#  'crawler_268.xlsx',
#  'crawler_269.xlsx',
#  'crawler_27.xlsx',
#  'crawler_270.xlsx',
#  'crawler_271.xlsx',
#  'crawler_272.xlsx',
#  'crawler_273.xlsx',
#  'crawler_274.xlsx',
#  'crawler_275.xlsx',
#  'crawler_276.xlsx',
#  'crawler_277.xlsx',
#  'crawler_278.xlsx',
#  'crawler_279.xlsx',
#  'crawler_28.xlsx',
#  'crawler_280.xlsx',
#  'crawler_281.xlsx',
#  'crawler_282.xlsx',
#  'crawler_283.xlsx',
#  'crawler_284.xlsx',
#  'crawler_285.xlsx',
#  'crawler_286.xlsx',
#  'crawler_287.xlsx',
#  'crawler_288.xlsx',
#  'crawler_289.xlsx',
#  'crawler_29.xlsx',
#  'crawler_290.xlsx',
#  'crawler_291.xlsx',
#  'crawler_292.xlsx',
#  'crawler_293.xlsx',
#  'crawler_294.xlsx',
#  'crawler_295.xlsx',
#  'crawler_296.xlsx',
#  'crawler_297.xlsx',
#  'crawler_298.xlsx',
#  'crawler_299.xlsx',
#  'crawler_3.xlsx',
#  'crawler_30.xlsx',
#  'crawler_300.xlsx',
#  'crawler_301.xlsx',
#  'crawler_302.xlsx',
#  'crawler_303.xlsx',
#  'crawler_304.xlsx',
#  'crawler_305.xlsx',
#  'crawler_306.xlsx',
#  'crawler_307.xlsx',
#  'crawler_308.xlsx',
#  'crawler_309.xlsx',
#  'crawler_31.xlsx',
#  'crawler_310.xlsx',
#  'crawler_311.xlsx',
#  'crawler_312.xlsx',
#  'crawler_313.xlsx',
#  'crawler_314.xlsx',
#  'crawler_315.xlsx',
#  'crawler_316.xlsx',
#  'crawler_317.xlsx',
#  'crawler_318.xlsx',
#  'crawler_319.xlsx',
#  'crawler_32.xlsx',
#  'crawler_320.xlsx',
#  'crawler_321.xlsx',
#  'crawler_322.xlsx',
#  'crawler_323.xlsx',
#  'crawler_324.xlsx',
#  'crawler_325.xlsx',
#  'crawler_326.xlsx',
#  'crawler_327.xlsx',
#  'crawler_328.xlsx',
#  'crawler_329.xlsx',
#  'crawler_33.xlsx',
#  'crawler_330.xlsx',
#  'crawler_331.xlsx',
#  'crawler_332.xlsx',
#  'crawler_333.xlsx',
#  'crawler_334.xlsx',
#  'crawler_335.xlsx',
#  'crawler_336.xlsx',
#  'crawler_337.xlsx',
#  'crawler_338.xlsx',
#  'crawler_339.xlsx',
#  'crawler_34.xlsx',
#  'crawler_340.xlsx',
#  'crawler_341.xlsx',
#  'crawler_342.xlsx',
#  'crawler_343.xlsx',
#  'crawler_344.xlsx',
#  'crawler_345.xlsx',
#  'crawler_346.xlsx',
#  'crawler_347.xlsx',
#  'crawler_348.xlsx',
#  'crawler_349.xlsx',
#  'crawler_35.xlsx',
#  'crawler_350.xlsx',
#  'crawler_351.xlsx',
#  'crawler_352.xlsx',
#  'crawler_353.xlsx',
#  'crawler_354.xlsx',
#  'crawler_355.xlsx',
#  'crawler_356.xlsx',
#  'crawler_357.xlsx',
#  'crawler_358.xlsx',
#  'crawler_359.xlsx',
#  'crawler_36.xlsx',
#  'crawler_360.xlsx',
#  'crawler_361.xlsx',
#  'crawler_362.xlsx',
#  'crawler_363.xlsx',
#  'crawler_364.xlsx',
#  'crawler_365.xlsx',
#  'crawler_366.xlsx',
#  'crawler_367.xlsx',
#  'crawler_368.xlsx',
#  'crawler_369.xlsx',
#  'crawler_37.xlsx',
#  'crawler_370.xlsx',
#  'crawler_371.xlsx',
#  'crawler_372.xlsx',
#  'crawler_373.xlsx',
#  'crawler_374.xlsx',
#  'crawler_375.xlsx',
#  'crawler_376.xlsx',
#  'crawler_377.xlsx',
#  'crawler_378.xlsx',
#  'crawler_379.xlsx',
#  'crawler_38.xlsx',
#  'crawler_380.xlsx',
#  'crawler_381.xlsx',
#  'crawler_382.xlsx',
#  'crawler_383.xlsx',
#  'crawler_384.xlsx',
#  'crawler_385.xlsx',
#  'crawler_386.xlsx',
#  'crawler_387.xlsx',
#  'crawler_388.xlsx',
#  'crawler_389.xlsx',
#  'crawler_39.xlsx',
#  'crawler_390.xlsx',
#  'crawler_391.xlsx',
#  'crawler_392.xlsx',
#  'crawler_393.xlsx',
#  'crawler_394.xlsx',
#  'crawler_395.xlsx',
#  'crawler_396.xlsx',
#  'crawler_397.xlsx',
#  'crawler_398.xlsx',
#  'crawler_399.xlsx',
#  'crawler_4.xlsx',
#  'crawler_40.xlsx',
#  'crawler_400.xlsx',
#  'crawler_401.xlsx',
#  'crawler_402.xlsx',
#  'crawler_403.xlsx',
#  'crawler_404.xlsx',
#  'crawler_405.xlsx',
#  'crawler_406.xlsx',
#  'crawler_407.xlsx',
#  'crawler_408.xlsx',
#  'crawler_409.xlsx',
#  'crawler_41.xlsx',
#  'crawler_410.xlsx',
#  'crawler_411.xlsx',
#  'crawler_412.xlsx',
#  'crawler_413.xlsx',
#  'crawler_414.xlsx',
#  'crawler_415.xlsx',
#  'crawler_416.xlsx',
#  'crawler_417.xlsx',
#  'crawler_418.xlsx',
#  'crawler_419.xlsx',
#  'crawler_42.xlsx',
#  'crawler_420.xlsx',
#  'crawler_421.xlsx',
#  'crawler_422.xlsx',
#  'crawler_423.xlsx',
#  'crawler_424.xlsx',
#  'crawler_425.xlsx',
#  'crawler_426.xlsx',
#  'crawler_427.xlsx',
#  'crawler_428.xlsx',
#  'crawler_429.xlsx',
#  'crawler_43.xlsx',
#  'crawler_430.xlsx',
#  'crawler_431.xlsx',
#  'crawler_432.xlsx',
#  'crawler_433.xlsx',
#  'crawler_434.xlsx',
#  'crawler_435.xlsx',
#  'crawler_436.xlsx',
#  'crawler_437.xlsx',
#  'crawler_438.xlsx',
#  'crawler_439.xlsx',
#  'crawler_44.xlsx',
#  'crawler_440.xlsx',
#  'crawler_441.xlsx',
#  'crawler_442.xlsx',
#  'crawler_443.xlsx',
#  'crawler_444.xlsx',
#  'crawler_445.xlsx',
#  'crawler_446.xlsx',
#  'crawler_447.xlsx',
#  'crawler_448.xlsx',
#  'crawler_449.xlsx',
#  'crawler_45.xlsx',
#  'crawler_450.xlsx',
#  'crawler_451.xlsx',
#  'crawler_452.xlsx',
#  'crawler_453.xlsx',
#  'crawler_454.xlsx',
#  'crawler_455.xlsx',
#  'crawler_456.xlsx',
#  'crawler_457.xlsx',
#  'crawler_458.xlsx',
#  'crawler_459.xlsx',
#  'crawler_46.xlsx',
#  'crawler_460.xlsx',
#  'crawler_461.xlsx',
#  'crawler_462.xlsx',
#  'crawler_463.xlsx',
#  'crawler_464.xlsx',
#  'crawler_465.xlsx',
#  'crawler_466.xlsx',
#  'crawler_467.xlsx',
#  'crawler_468.xlsx',
#  'crawler_469.xlsx',
#  'crawler_47.xlsx',
#  'crawler_470.xlsx',
#  'crawler_471.xlsx',
#  'crawler_472.xlsx',
#  'crawler_473.xlsx',
#  'crawler_474.xlsx',
#  'crawler_475.xlsx',
#  'crawler_476.xlsx',
#  'crawler_477.xlsx',
#  'crawler_478.xlsx',
#  'crawler_479.xlsx',
#  'crawler_48.xlsx',
#  'crawler_480.xlsx',
#  'crawler_481.xlsx',
#  ...]

# %%
from tqdm import tqdm
import pandas as pd
from datetime import datetime

input_ = pd.DataFrame()
for file in tqdm(list_file, desc='Progress', ncols=77):
    df_temp = pd.read_excel(f'./file/4.src/{file}',
                            header=0,
                            dtype=str).fillna('')
    
    df_temp['No'] = df_temp['No'].astype(int)
    df_temp['rowId'] = df_temp['rowId'].astype(int)
    df_temp['qtyEach'] = df_temp['qtyEach'].astype(int)
    df_temp['maxRows'] = df_temp['maxRows'].astype(int)

    input_ = pd.concat([input_, df_temp], ignore_index=True).fillna('')

list_column = input_.columns.tolist()
list_column.remove('No')
list_column.remove('Json_Src')
input_ = input_.drop_duplicates(list_column,
                                keep='first',
                                ignore_index=True)
input_ = input_.sort_values(by=['partLongDesc_en', 'Part Number'],
                            ascending=[True, True],
                            ignore_index=True)

input_['No'] = [_+1 for _ in range(len(input_))]

input_.to_excel(f'''./file/【网站爬虫】Standard-{datetime.now().strftime('%Y%m%d')}.xlsx''', index=False)

input_
# Out:
# Progress: 100%|██████████████████████████| 1574/1574 [02:57<00:00,  8.89it/s]
#           No Part Number  rowId site webBase brand basePart  \
# 0          1      HVH001      1  STD  HVH001   STD   HVH001
# 1          2      HVH002      1  STD  HVH002   STD   HVH002
# 2          3      HVH003      1  STD  HVH003   STD   HVH003
# 3          4      HVH004      1  STD  HVH004   STD   HVH004
# 4          5      HVH005      1  STD  HVH005   STD   HVH005
# ...      ...         ...    ...  ...     ...   ...      ...
# 45081  45082       YA212      1  STD   YA212   STI    YA212
# 45082  45083       YA219      1  STD   YA219   STI    YA219
# 45083  45084      S-1714      1  STD   S1714   STD   S-1714
# 45084  45085      S-1776      1  STD   S1776   STD   S-1776
# 45085  45086       S2923      1  STD   S2923   STI    S2923
#
#                                 partDesc_en  \
# 0      4WD Hub Locking Actuator Vacuum Hose
# 1      4WD Hub Locking Actuator Vacuum Hose
# 2      4WD Hub Locking Actuator Vacuum Hose
# 3      4WD Hub Locking Actuator Vacuum Hose
# 4      4WD Hub Locking Actuator Vacuum Hose
# ...                                     ...
# 45081                       YAW Rate Sensor
# 45082                       YAW Rate Sensor
# 45083                  Electrical Connector
# 45084                  Electrical Connector
# 45085                  Electrical Connector
#
#                             partLongDesc_en pop  ... mfG_Part  maxRows  \
# 0      4WD Hub Locking Actuator Vacuum Hose   D  ...                 1
# 1      4WD Hub Locking Actuator Vacuum Hose   D  ...                 1
# 2      4WD Hub Locking Actuator Vacuum Hose   D  ...                 1
# 3      4WD Hub Locking Actuator Vacuum Hose   D  ...                 1
# 4      4WD Hub Locking Actuator Vacuum Hose   B  ...                 1
# ...                                     ...  ..  ...      ...      ...
# 45081                       YAW Rate Sensor   X  ...                 1
# 45082                       YAW Rate Sensor   X  ...                 1
# 45083             Yaw Rate Sensor Connector   Q  ...                 1
# 45084             Yaw Rate Sensor Connector   Q  ...                 1
# 45085             Yaw Rate Sensor Connector   F  ...                 1
#
#       brandLink imageUrl Picture  \
# 0
# 1
# 2
# 3
# 4
# ...         ...      ...     ...
# 45081
# 45082
# 45083
# 45084
# 45085
#
#                                                      Url  \
# 0      https://www.standardbrand.com/en/ecatalog?part...
# 1      https://www.standardbrand.com/en/ecatalog?part...
# 2      https://www.standardbrand.com/en/ecatalog?part...
# 3      https://www.standardbrand.com/en/ecatalog?part...
# 4      https://www.standardbrand.com/en/ecatalog?part...
# ...                                                  ...
# 45081  https://www.standardbrand.com/en/ecatalog?part...
# 45082  https://www.standardbrand.com/en/ecatalog?part...
# 45083  https://www.standardbrand.com/en/ecatalog?part...
# 45084  https://www.standardbrand.com/en/ecatalog?part...
# 45085  https://www.standardbrand.com/en/ecatalog?part...
#
#                                             Json_Vehicle  \
# 0      {"0": "Ford F-150 (08-04)", "1": "Lincoln Mark...
# 1                            {"0": "Ford F-150 (18-15)"}
# 2      {"0": "Ford Expedition (21-18)", "1": "Ford F-...
# 3      {"0": "Ford F-150 (14-11)", "1": "Lincoln Mark...
# 4      {"0": "Ford Expedition (21-18)", "1": "Ford F-...
# ...                                                  ...
# 45081             {"0": "Nissan Frontier (17), (15-11)"}
# 45082  {"0": "Lexus LS400 (00-99)", "1": "Lexus RX300...
# 45083  {"0": "Chevrolet Corvette (09)", "1": "Honda C...
# 45084  {"0": "Ford Expedition (10-04)", "1": "Ford Ex...
# 45085  {"0": "Honda Civic (11-09)", "1": "Honda Fit (...
#
#                                             Json_Service  \
# 0      {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 1      {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 2      {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 3      {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 4      {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# ...                                                  ...
# 45081  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 45082  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 45083  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 45084  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
# 45085  {"0": "Fuel Filter Flush (Required)", "1": "Oi...
#
#                                                Json_Spec  \
# 0      {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 1      {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 2      {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 3      {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 4      {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# ...                                                  ...
# 45081  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 45082  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 45083  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 45084  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
# 45085  {"0": {"Warranty": "3 years/36,000 mile"}, "1"...
#
#                                                 Json_Src
# 0      {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 1      {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 2      {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 3      {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 4      {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# ...                                                  ...
# 45081  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 45082  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 45083  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 45084  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
# 45085  {"0": "https://ecatalog.smpcorp.com/ihgs/image...
#
# [45086 rows x 26 columns]
