# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 521

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 521/521 [00:01<00:00, 306.11it/s]
#       序号                Part_Type Part_Number          Brand  \
# 0      1  Driveshaft / Prop Shaft     65-1000  CARDONE Reman
# 1      2  Driveshaft / Prop Shaft    65-1001A  CARDONE Reman
# 2      3  Driveshaft / Prop Shaft    65-1001B  CARDONE Reman
# 3      4  Driveshaft / Prop Shaft     65-1002  CARDONE Reman
# 4      5  Driveshaft / Prop Shaft     65-1003  CARDONE Reman
# ..   ...                      ...         ...            ...
# 516  517  Driveshaft / Prop Shaft     65-9875  CARDONE Reman
# 517  518  Driveshaft / Prop Shaft     65-9915  CARDONE Reman
# 518  519  Driveshaft / Prop Shaft     65-9918  CARDONE Reman
# 519  520  Driveshaft / Prop Shaft     65-9919  CARDONE Reman
# 520  521  Driveshaft / Prop Shaft     65-9921  CARDONE Reman
#
#                                   Title  \
# 0     Driveshaft / Prop Shaft - 65-1000
# 1    Driveshaft / Prop Shaft - 65-1001A
# 2    Driveshaft / Prop Shaft - 65-1001B
# 3     Driveshaft / Prop Shaft - 65-1002
# 4     Driveshaft / Prop Shaft - 65-1003
# ..                                  ...
# 516   Driveshaft / Prop Shaft - 65-9875
# 517   Driveshaft / Prop Shaft - 65-9915
# 518   Driveshaft / Prop Shaft - 65-9918
# 519   Driveshaft / Prop Shaft - 65-9919
# 520   Driveshaft / Prop Shaft - 65-9921
#
#                                              Vehicle_1  \
# 0    Buick Enclave 2008-2017\nChevrolet Traverse 20...
# 1
# 2    Chevrolet Equinox 2005-2007\nPontiac Torrent 2...
# 3                               Cadillac CTS 2004-2007
# 4    Cadillac CTS 2008-2014\nCadillac SRX 2004-2009...
# ..                                                 ...
# 516  Dodge Ramcharger 1990-1993\nDodge W150 1990-19...
# 517       Toyota 4Runner 1987-1988\nToyota Pickup 1988
# 518  Toyota 4Runner 1989-1995\nToyota Pickup 1989-1...
# 519
# 520
#
#                                              Vehicle_2  \
# 0    Buick Enclave 2008-2017 3.6L V6 217cid/3564cc\...
# 1
# 2    Chevrolet Equinox 2005-2007 3.4L V6 207cid\nPo...
# 3    Cadillac CTS 2004-2007 3.6L V6 217cid/3564cc\n...
# 4    Cadillac CTS 2008-2013 3.6L V6 217cid/3564cc\n...
# ..                                                 ...
# 516  Dodge Ramcharger 1990-1993 5.2L V8 318cid/5211...
# 517  Toyota 4Runner 1987-1988 2.4L L4 2366cc\nToyot...
# 518  Toyota 4Runner 1989-1995 3.0L V6 2959cc\nToyot...
# 519
# 520
#
#                              OE Pic  \
# 0    23167530;25995544;25995545
# 1                      19259831
# 2                      19259831
# 3    25751875;25773495;25773497
# 4             15212141;25768518
# ..                          ...  ..
# 516
# 517
# 518                  3714035050
# 519
# 520
#
#                                                    Url  ...  \
# 0    https://www.cardone.com/product/driveshaft-pro...  ...
# 1    https://www.cardone.com/product/driveshaft-pro...  ...
# 2    https://www.cardone.com/product/driveshaft-pro...  ...
# 3    https://www.cardone.com/product/driveshaft-pro...  ...
# 4    https://www.cardone.com/product/driveshaft-pro...  ...
# ..                                                 ...  ...
# 516  https://www.cardone.com/product/driveshaft-pro...  ...
# 517  https://www.cardone.com/product/driveshaft-pro...  ...
# 518  https://www.cardone.com/product/driveshaft-pro...  ...
# 519  https://www.cardone.com/product/driveshaft-pro...  ...
# 520  https://www.cardone.com/product/driveshaft-pro...  ...
#
#                                     Measurement Method  \
# 0    Measurement taken from end of flange face to e...
# 1    Measurement is taken from the CV face to the c...
# 2    Measurement is taken from end of the flange to...
# 3    Measurement taken from end of flange face to e...
# 4    Measurement taken from end of CV joint flange ...
# ..                                                 ...
# 516  Measurement is taken from end of the flange to...
# 517  Measurement taken from end of flange face to e...
# 518  Measurement taken from end of flange face to e...
# 519  Measurement taken from end of flange face to e...
# 520  Measurement taken from end of flange face to e...
#
#                    Part Type       Warranty Info Sustainable Choice  \
# 0    Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 1    Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 2    Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 3    Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 4    Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# ..                       ...                 ...                ...
# 516  Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 517  Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 518  Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 519  Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
# 520  Driveshaft / Prop Shaft  1 Year/18,000 Mile                Yes
#
#        Lifecycle Status Shaft Material  \
# 0    Available to Order          Steel
# 1    Available to Order          Steel
# 2    Available to Order          Steel
# 3    Available to Order          Steel
# 4    Available to Order          Steel
# ..                  ...            ...
# 516            Obsolete          Steel
# 517  Available to Order          Steel
# 518  Available to Order          Steel
# 519            Obsolete          Steel
# 520  Available to Order          Steel
#
#                                    Application_Summary   ItemLevelGTIN  \
# 0    Buick Enclave 2017-08\nChevrolet Traverse 2017...  00884548185746
# 1    Chevrolet Equinox 2007-05\nPontiac Torrent 200...  00884548196179
# 2    Chevrolet Equinox 2007-05\nPontiac Torrent 200...  00884548196186
# 3                                 Cadillac CTS 2007-04  00884548212916
# 4       Cadillac CTS 2014-08, SRX 2009-04, STS 2011-05  00884548216099
# ..                                                 ...             ...
# 516  Dodge Ramcharger 1993-90, W150 1993-90, W250 1...  00082617565288
# 517                Toyota 4Runner 1988-87, Pickup 1988  00082617565295
# 518  Toyota 4Runner 1995-89, Pickup 1995-89, T100 1...  00082617565325
# 519             Toyota 4Runner 1995-89, Pickup 1995-89  00082617565332
# 520  Land Rover Defender 90 1997 1995-94, Discovery...  00082617565356
#
#                   _addonCardone Flash Programming Service
# 0     65-1000::98299:105110:482
# 1    65-1001A::98299:105127:482
# 2    65-1001B::98299:105145:482
# 3     65-1002::98299:105166:482
# 4     65-1003::98299:105184:482
# ..                          ...                       ...
# 516   65-9875::98378:127789:221
# 517   65-9915::98378:127790:221
# 518   65-9918::98378:127791:221
# 519   65-9919::98378:127792:221
# 520   65-9921::98378:127793:221
#
# [521 rows x 30 columns]
