# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 425

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)

df
# Out:
# Progress: 100%|███████████████████████████| 425/425 [00:03<00:00, 132.90it/s]
#       序号 Brand Part_Number                                              Title  \
# 0      1  febi       38872           Axial Bearing for automatic transmission
# 1      2  febi       38871           Axial Bearing for automatic transmission
# 2      3  febi       38869           Axial Bearing for automatic transmission
# 3      4  febi       38870           Axial Bearing for automatic transmission
# 4      5  febi       33460  Axle Beam Mount for axle support and transmiss...
# ..   ...   ...         ...                                                ...
# 420  421  febi      184934                                 Transmission Mount
# 421  422  febi      103234                                 Transmission Mount
# 422  423  febi      104384                                 Transmission Mount
# 423  424  febi      176492                                 Transmission Mount
# 424  425  febi       10017                            Transmission Suspension
#
#                                               Subtitle Pic  \
# 0
# 1
# 2
# 3
# 4    Fitting Position: vehicle-dependent installati...
# ..                                                 ...  ..
# 420                             Fitting Position: left
# 421                             Fitting Position: left
# 422                             Fitting Position: left
# 423                             Fitting Position: rear
# 424                       Fitting Position: rear right
#
#                                                    Url  \
# 0    https://partsfinder.bilsteingroup.com/en/artic...
# 1    https://partsfinder.bilsteingroup.com/en/artic...
# 2    https://partsfinder.bilsteingroup.com/en/artic...
# 3    https://partsfinder.bilsteingroup.com/en/artic...
# 4    https://partsfinder.bilsteingroup.com/en/artic...
# ..                                                 ...
# 420  https://partsfinder.bilsteingroup.com/en/artic...
# 421  https://partsfinder.bilsteingroup.com/en/artic...
# 422  https://partsfinder.bilsteingroup.com/en/artic...
# 423  https://partsfinder.bilsteingroup.com/en/artic...
# 424  https://partsfinder.bilsteingroup.com/en/artic...
#
#                                                    Src  Brand_Id Master_Id  \
# 0    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6101192   1489386
# 1    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102177   1723728
# 2    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102726   1723736
# 3    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102737   1723733
# 4    https://cdn.partsfinder.bilsteingroup.com/pf-a...   4885807    383720
# ..                                                 ...       ...       ...
# 420  https://cdn.partsfinder.bilsteingroup.com/pf-a...  31096806   3624555
# 421  https://cdn.partsfinder.bilsteingroup.com/pf-a...  20651715   1608156
# 422  https://cdn.partsfinder.bilsteingroup.com/pf-a...  21018557   3548948
# 423  https://cdn.partsfinder.bilsteingroup.com/pf-a...  26707352   3505400
# 424  https://cdn.partsfinder.bilsteingroup.com/pf-a...     96133      4519
#
#      ... OE_Chevrolet OE_IVECO (LCV) OE_Jaguar OE_Land Rover  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...          ...            ...       ...           ...
# 420  ...
# 421  ...
# 422  ...
# 423  ...
# 424  ...
#
#     no. of connections OE_Alpina (BMW) OE_DS height pitch circle diameter  \
# 0
# 1
# 2
# 3
# 4
# ..                 ...             ...   ...    ...                   ...
# 420
# 421
# 422
# 423
# 424
#
#     no. of holes
# 0
# 1
# 2
# 3
# 4
# ..           ...
# 420
# 421
# 422
# 423
# 424
#
# [425 rows x 81 columns]

# %%
df['list_make'] = [make.split(';') for make in df['Make'].tolist()]
df = df.explode('list_make').reset_index(drop=True)
df['序号'] = [i+1 for i in range(len(df))]

df.to_excel('./part.xlsx', index=False)

df
# Out:
#       序号 Brand Part_Number                                     Title  \
# 0      1  febi       38872  Axial Bearing for automatic transmission
# 1      2  febi       38872  Axial Bearing for automatic transmission
# 2      3  febi       38871  Axial Bearing for automatic transmission
# 3      4  febi       38869  Axial Bearing for automatic transmission
# 4      5  febi       38870  Axial Bearing for automatic transmission
# ..   ...   ...         ...                                       ...
# 766  767  febi      184934                        Transmission Mount
# 767  768  febi      103234                        Transmission Mount
# 768  769  febi      104384                        Transmission Mount
# 769  770  febi      176492                        Transmission Mount
# 770  771  febi       10017                   Transmission Suspension
#
#                          Subtitle Pic  \
# 0
# 1
# 2
# 3
# 4
# ..                            ...  ..
# 766        Fitting Position: left
# 767        Fitting Position: left
# 768        Fitting Position: left
# 769        Fitting Position: rear
# 770  Fitting Position: rear right
#
#                                                    Url  \
# 0    https://partsfinder.bilsteingroup.com/en/artic...
# 1    https://partsfinder.bilsteingroup.com/en/artic...
# 2    https://partsfinder.bilsteingroup.com/en/artic...
# 3    https://partsfinder.bilsteingroup.com/en/artic...
# 4    https://partsfinder.bilsteingroup.com/en/artic...
# ..                                                 ...
# 766  https://partsfinder.bilsteingroup.com/en/artic...
# 767  https://partsfinder.bilsteingroup.com/en/artic...
# 768  https://partsfinder.bilsteingroup.com/en/artic...
# 769  https://partsfinder.bilsteingroup.com/en/artic...
# 770  https://partsfinder.bilsteingroup.com/en/artic...
#
#                                                    Src  Brand_Id Master_Id  \
# 0    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6101192   1489386
# 1    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6101192   1489386
# 2    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102177   1723728
# 3    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102726   1723736
# 4    https://cdn.partsfinder.bilsteingroup.com/pf-a...   6102737   1723733
# ..                                                 ...       ...       ...
# 766  https://cdn.partsfinder.bilsteingroup.com/pf-a...  31096806   3624555
# 767  https://cdn.partsfinder.bilsteingroup.com/pf-a...  20651715   1608156
# 768  https://cdn.partsfinder.bilsteingroup.com/pf-a...  21018557   3548948
# 769  https://cdn.partsfinder.bilsteingroup.com/pf-a...  26707352   3505400
# 770  https://cdn.partsfinder.bilsteingroup.com/pf-a...     96133      4519
#
#      ... OE_IVECO (LCV) OE_Jaguar OE_Land Rover no. of connections  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...            ...       ...           ...                ...
# 766  ...
# 767  ...
# 768  ...
# 769  ...
# 770  ...
#
#     OE_Alpina (BMW) OE_DS height pitch circle diameter no. of holes  \
# 0
# 1
# 2
# 3
# 4
# ..              ...   ...    ...                   ...          ...
# 766
# 767
# 768
# 769
# 770
#
#          list_make
# 0         Chrysler
# 1    Mercedes-Benz
# 2    Mercedes-Benz
# 3    Mercedes-Benz
# 4    Mercedes-Benz
# ..             ...
# 766       Vauxhall
# 767          Honda
# 768        Peugeot
# 769            KIA
# 770           Audi
#
# [771 rows x 82 columns]
