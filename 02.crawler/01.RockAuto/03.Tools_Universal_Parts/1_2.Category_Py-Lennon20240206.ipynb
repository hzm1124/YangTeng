# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import json

# %%
with open('./category.txt', 'r', encoding='UTF-8') as f:
    df = pd.DataFrame(json.loads(f.read()))
    
df.to_excel('./1.category.xlsx', index=False)

df
# Out:
#                   Tab_Label  No.                   Category  \
# 0   Tools & Universal Parts    1            Apparel & Gifts
# 1   Tools & Universal Parts    2                 Belt Drive
# 2   Tools & Universal Parts    3       Body & Lamp Assembly
# 3   Tools & Universal Parts    4          Brake & Wheel Hub
# 4   Tools & Universal Parts    5             Cooling System
# 5   Tools & Universal Parts    6                 Drivetrain
# 6   Tools & Universal Parts    7                 Electrical
# 7   Tools & Universal Parts    8   Electrical-Bulb & Socket
# 8   Tools & Universal Parts    9       Electrical-Connector
# 9   Tools & Universal Parts   10  Electrical-Switch & Relay
# 10  Tools & Universal Parts   11                     Engine
# 11  Tools & Universal Parts   12         Exhaust & Emission
# 12  Tools & Universal Parts   13                 Fuel & Air
# 13  Tools & Universal Parts   14           Garage Equipment
# 14  Tools & Universal Parts   15                   Hardware
# ...
