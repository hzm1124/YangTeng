# %%
import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()
output_null = pd.DataFrame()

# %%
input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
input_['Part_Number'].tolist()
# Out:
# 总数量：1266
# ['A2039',
#  'A2073',
#  'A2107',
#  'A2143',
#  'A2162',
#  'A2163',
#  'A2172',
#  'A2201',
#  'A2217',
#  'A2236',
#  'A2253',
#  'A2268',
#  'A2272',
#  'A2288',
#  'A2293',
#  'A2294',
#  'A2299',
#  'A2305',
#  'A2306',
#  'A2320',
#  'A2321',
#  'A2327',
#  'A2339',
#  'A2348',
#  'A2349',
#  'A2360',
#  'A2374',
#  'A2378',
#  'A2379',
#  'A2388',
#  'A2391',
#  'A2392',
#  'A2393',
#  'A2394',
#  'A2409',
#  'A2410',
#  'A2411',
#  'A2418',
#  'A2420',
#  'A2425',
#  'A2452',
#  'A2453',
#  'A2454',
#  'A2463',
#  'A2464',
#  'A2466',
#  'A2467',
#  'A2471',
#  'A2489',
#  'A2495',
#  'A2497',
#  'A2499',
#  'A2508',
#  'A2512',
#  'A2513',
#  'A2514',
#  'A2525',
#  'A2537',
#  'A2543',
#  'A2544',
#  'A2557',
#  'A2567',
#  'A2601',
#  'A2617',
#  'A2618',
#  'A2624',
#  'A2625',
#  'A2628',
#  'A2631',
#  'A2632',
#  'A2633',
#  'A2634',
#  'A2638',
#  'A2639',
#  'A2648',
#  'A2653',
#  'A2657',
#  'A2659',
#  'A2663',
#  'A2664',
#  'A2667',
#  'A2671',
#  'A2675',
#  'A2679',
#  'A2685',
#  'A2686',
#  'A2687',
#  'A2690',
#  'A2691',
#  'A2696HY',
#  'A2712HY',
#  'A2715',
#  'A2717HY',
#  'A2719',
#  'A2721',
#  'A2734',
#  'A2742',
#  'A2750',
#  'A2751',
#  'A2752',
#  'A2753',
#  'A2759',
#  'A2760',
#  'A2762',
#  'A2766',
#  'A2773',
#  'A2779HY',
#  'A2783',
#  'A2800',
#  'A2810',
#  'A2811',
#  'A2817',
#  'A2818',
#  'A2820',
#  'A2821',
#  'A2823HY',
#  'A2826',
#  'A2828',
#  'A2837HY',
#  'A2839',
#  'A2842HY',
#  'A2843',
#  'A2845',
#  'A2848',
#  'A2849',
#  'A2852',
#  'A2858',
#  'A2864',
#  'A2865',
#  'A2868',
#  'A2870',
#  'A2871',
#  'A2873',
#  'A2874',
#  'A2875',
#  'A2879HY',
#  'A2880HY',
#  'A2881',
#  'A2882',
#  'A2884',
#  'A2887',
#  'A2893',
#  'A2896HY',
#  'A2897HY',
#  'A2898',
#  'A2907',
#  'A2908',
#  'A2921',
#  'A2923',
#  'A2924',
#  'A2927',
#  'A2946',
#  'A2950',
#  'A2954',
#  'A2956',
#  'A2957',
#  'A2960',
#  'A2965',
#  'A2966',
#  'A2969',
#  'A2971',
#  'A2974',
#  'A2975',
#  'A2982',
#  'A2986',
#  'A2988',
#  'A3007',
#  'A3026',
#  'A3027',
#  'A3032',
#  'A3041',
#  'A3052',
#  'A3054',
#  'A3065',
#  'A3069',
#  'A3081',
#  'A3081IN',
#  'A3082',
#  'A4000',
#  'A4004',
#  'A4028',
#  'A4029',
#  'A4034',
#  'A4041',
#  'A4042',
#  'A4043',
#  'A4056',
#  'A4058',
#  'A4059',
#  'A4060',
#  'A4074',
#  'A4075',
#  'A4078',
#  'A4079',
#  'A4080',
#  'A4083',
#  'A4088',
#  'A4091',
#  'A4093',
#  'A4096',
#  'A42000',
#  'A42005',
#  'A42007',
#  'A42012',
#  'A42016',
#  'A42021',
#  'A42026',
#  'A42031',
#  'A42037',
#  'A42042',
#  'A42048',
#  'A42053',
#  'A42058',
#  'A42061',
#  'A42064',
#  'A42066',
#  'A42068',
#  'A4207',
#  'A42070',
#  'A42078',
#  'A42082',
#  'A42084',
#  'A4218',
#  'A4223',
#  'A4243',
#  'A4245',
#  'A4246',
#  'A4251',
#  'A4263',
#  'A4265',
#  'A4275',
#  'A4283',
#  'A4288',
#  'A4298',
#  'A4299',
#  'A4301',
#  'A4303',
#  'A4307',
#  'A4312',
#  'A4314',
#  'A4321',
#  'A4336',
#  'A4340',
#  'A4343',
#  'A4346',
#  'A4361',
#  'A4363',
#  'A4377',
#  'A4378',
#  'A4404',
#  'A4409',
#  'A4414',
#  'A4415',
#  'A4420',
#  'A4421',
#  'A4422',
#  'A4423',
#  'A4425',
#  'A4427',
#  'A4430',
#  'A4438',
#  'A4441',
#  'A45005',
#  'A45008',
#  'A4501',
#  'A4502',
#  'A4506',
#  'A4509',
#  'A4510',
#  'A4511',
#  'A4512',
#  'A4515',
#  'A4524',
#  'A4525',
#  'A4528',
#  'A4531',
#  'A4532',
#  'A4537',
#  'A4542',
#  'A4544',
#  'A4546',
#  'A4557',
#  'A4559',
#  'A4561',
#  'A4562',
#  'A4577',
#  'A4582',
#  'A4584',
#  'A4585',
#  'A4586',
#  'A4590',
#  'A4593',
#  'A4594',
#  'A4598',
#  'A4600',
#  'A4611',
#  'A4612',
#  'A4625',
#  'A4630',
#  'A4631',
#  'A4634',
#  'A4639',
#  'A4643',
#  'A4646',
#  'A4702',
#  'A4703',
#  'A4704',
#  'A4709',
#  'A4913',
#  'A4914',
#  'A4915',
#  'A4916',
#  'A4917',
#  'A4920',
#  'A4921',
#  'A4922',
#  'A4923',
#  'A4928',
#  'A4929',
#  'A4932',
#  'A4933',
#  'A4936',
#  'A4939',
#  'A5021',
#  'A5123',
#  'A5132',
#  'A5198',
#  'A5203',
#  'A5209',
#  'A5212',
#  'A5219B',
#  'A5223',
#  'A5225',
#  'A5229',
#  'A5236',
#  'A5253',
#  'A5260',
#  'A5261',
#  'A5271',
#  'A5276',
#  'A5277',
#  'A5279',
#  'A5281',
#  'A5283',
#  'A5287',
#  'A5288',
#  'A5291',
#  'A5292',
#  'A5297',
#  'A5298',
#  'A5300',
#  'A5302HY',
#  'A5310',
#  'A5315',
#  'A5318',
#  'A5319',
#  'A5325',
#  'A5340',
#  'A5346',
#  'A5351',
#  'A5352',
#  'A5355',
#  'A5356HY',
#  'A5357',
#  'A5367',
#  'A5373',
#  'A5374',
#  'A5375',
#  'A5380',
#  'A5382',
#  'A5386HY',
#  'A5388',
#  'A5395',
#  'A5402',
#  'A5404',
#  'A5418',
#  'A5424',
#  'A5429',
#  'A5433',
#  'A5435',
#  'A5436',
#  'A5439',
#  'A5441',
#  'A5442HY',
#  'A5448',
#  'A5458HY',
#  'A5459',
#  'A5461',
#  'A5465',
#  'A5466',
#  'A5474',
#  'A5478',
#  'A5479',
#  'A5489',
#  'A5493',
#  'A5494',
#  'A5501',
#  'A5502',
#  'A5503',
#  'A5504',
#  'A5506',
#  'A5508',
#  'A5511',
#  'A5514',
#  'A5515',
#  'A5520',
#  'A5521',
#  'A5526',
#  'A5530',
#  'A5532',
#  'A5536',
#  'A5539',
#  'A5540',
#  'A5543',
#  'A5545',
#  'A5546',
#  'A5554',
#  'A5558',
#  'A5560',
#  'A5561',
#  'A5562',
#  'A5563',
#  'A5575',
#  'A5577',
#  'A5579',
#  'A5583',
#  'A5584',
#  'A5591',
#  'A5594',
#  'A5596',
#  'A5598',
#  'A5601',
#  'A5603',
#  'A5604',
#  'A5605',
#  'A5607',
#  'A5609',
#  'A5612',
#  'A5613',
#  'A5618',
#  'A5619',
#  'A5620',
#  'A5625',
#  'A5632',
#  'A5633',
#  'A5636',
#  'A5640',
#  'A5641',
#  'A5643',
#  'A5644',
#  'A5647',
#  'A5649',
#  'A5653',
#  'A5655',
#  'A5656',
#  'A5658',
#  'A5668',
#  'A5675',
#  'A5676',
#  'A5677',
#  'A5678',
#  'A5683',
#  'A5687',
#  'A5696',
#  'A5697',
#  'A5704',
#  'A5705',
#  'A5707',
#  'A5711',
#  'A5713',
#  'A5721',
#  'A5726',
#  'A5727',
#  'A5728',
#  'A5729',
#  'A5733',
#  'A5734',
#  'A5735',
#  'A5736',
#  'A5737',
#  'A5740',
#  'A5741',
#  'A5742',
#  'A5743',
#  'A5747',
#  'A5748',
#  'A5749',
#  'A5750',
#  'A5751',
#  'A5778',
#  'A5779',
#  'A5787',
#  'A5791',
#  'A5792',
#  'A5793',
#  'A5794',
#  'A5796',
#  'A5797',
#  'A5806',
#  'A5807',
#  'A5808',
#  'A5810',
#  'A5814',
#  'A5817',
#  'A5822',
#  'A5823',
#  'A5829',
#  'A5831',
#  'A5832',
#  'A5839',
#  'A5853',
#  'A5854',
#  'A5861',
#  'A5863',
#  'A5864',
#  'A5865',
#  'A5867',
#  'A5868',
#  'A5869',
#  'A5871',
#  'A5875',
#  'A5876',
#  'A5879',
#  'A5880',
#  'A5882',
#  'A5886',
#  'A5894',
#  'A5908',
#  'A5911',
#  'A5914',
#  'A5915',
#  'A5921',
#  'A5922',
#  'A5925',
#  'A5929',
#  'A5930',
#  'A5932',
#  'A5942',
#  'A5943',
#  'A5947',
#  'A5948',
#  'A5957',
#  'A5963',
#  'A5972',
#  'A5974',
#  'A5976',
#  'A5980',
#  'A5983',
#  'A5997',
#  'A6101',
#  'A61036',
#  'A6110',
#  'A6112',
#  'A6113',
#  'A6114',
#  'A6115',
#  'A6116',
#  'A6117',
#  'A6118',
#  'A6121',
#  'A6128',
#  'A6144',
#  'A6162',
#  'A6166',
#  'A6172',
#  'A6178',
#  'A6187',
#  'A6188',
#  'A6191',
#  'A6192',
#  'A6193',
#  'A6194',
#  'A6198',
#  'A6199',
#  'A62014',
#  'A62018',
#  'A62020',
#  'A62021',
#  'A62022',
#  'A62031',
#  'A62032',
#  'A62039',
#  'A6204',
#  'A62040',
#  'A62041',
#  'A62043',
#  'A62044',
#  'A62051',
#  'A62054',
#  'A62056',
#  'A62064',
#  'A62065',
#  'A62066',
#  'A6207',
#  'A62070',
#  'A62076',
#  'A62077',
#  'A62088',
#  'A62094',
#  'A62095',
#  'A62097',
#  'A6210',
#  'A6211',
#  'A6223',
#  'A6224',
#  'A6234',
#  'A6236',
#  'A6239',
#  'A6244',
#  'A6245',
#  'A6248',
#  'A6256',
#  'A6257',
#  'A6258',
#  'A6259',
#  'A6262',
#  'A6270',
#  'A6274',
#  'A6284',
#  'A6286',
#  'A6293',
#  'A6294',
#  'A6311',
#  'A6312',
#  'A6320',
#  'A6326',
#  'A6329',
#  'A6334',
#  'A6339',
#  'A6351',
#  'A6352',
#  'A6360',
#  'A6372',
#  'A6373',
#  'A6375',
#  'A6380',
#  'A6388',
#  'A6391',
#  'A6392',
#  'A6403',
#  'A6404',
#  'A6406',
#  'A6415',
#  'A6419',
#  'A6422',
#  'A6427',
#  'A6428',
#  'A6437',
#  'A6438',
#  'A6440',
#  'A6445',
#  'A6447',
#  'A6448',
#  'A6450',
#  'A6461',
#  'A6463',
#  'A6464',
#  'A6465',
#  'A6471',
#  'A6474',
#  'A6482',
#  'A6490',
#  'A6499',
#  'A6500',
#  'A65002',
#  'A65004',
#  'A65005',
#  'A65006',
#  'A65012',
#  'A65013',
#  'A65015',
#  'A65018',
#  'A65020',
#  'A65021',
#  'A65022',
#  'A65036',
#  'A65037',
#  'A65039',
#  'A65044',
#  'A65045',
#  'A65056',
#  'A65057',
#  'A65058',
#  'A65060',
#  'A65062',
#  'A65068',
#  'A65071',
#  'A65073',
#  'A65075',
#  'A65076',
#  'A6508',
#  'A65082',
#  'A65083',
#  'A65085',
#  'A6509',
#  'A65092',
#  'A65094',
#  'A65099',
#  'A65100',
#  'A65101',
#  'A65102',
#  'A65111',
#  'A65113',
#  'A65118',
#  'A6513',
#  'A6524',
#  'A6526',
#  'A6531',
#  'A6551',
#  'A6562',
#  'A6569',
#  'A6570',
#  'A6579',
#  'A6582',
#  'A6584',
#  'A6603',
#  'A6608',
#  'A6623',
#  'A6629',
#  'A6630',
#  'A6634',
#  'A6642',
#  'A6644',
#  'A6646',
#  'A6650',
#  'A6651',
#  'A6652',
#  'A6664',
#  'A6665',
#  'A6667',
#  'A6671',
#  'A6675',
#  'A6677',
#  'A6679',
#  'A6681',
#  'A6689',
#  'A6692',
#  'A6693',
#  'A6694',
#  'A6698',
#  'A6707',
#  'A6708',
#  'A6713',
#  'A6714',
#  'A6717',
#  'A6724',
#  'A6727',
#  'A6739',
#  'A6743',
#  'A6744',
#  'A6750',
#  'A6757',
#  'A6764',
#  'A6766',
#  'A6774',
#  'A6776',
#  'A6777',
#  'A6781',
#  'A6782',
#  'A6783',
#  'A6791',
#  'A6796',
#  'A6798',
#  'A6800',
#  'A6807',
#  'A6810',
#  'A6815',
#  'A6819',
#  'A6825',
#  'A6831',
#  'A6833',
#  'A6838',
#  'A6839',
#  'A6843',
#  'A6848',
#  'A6851',
#  'A6877',
#  'A6878',
#  'A6901',
#  'A6905',
#  'A6907',
#  'A6918',
#  'A6919',
#  'A6923',
#  'A6924',
#  'A6933',
#  'A6938',
#  'A6952',
#  'A6959HY',
#  'A6960HY',
#  'A6961',
#  'A6967',
#  'A6970',
#  'A6975',
#  'A6982',
#  'A6984',
#  'A6985',
#  'A6986',
#  'A6990',
#  'A6994',
#  'A6995',
#  'A70003',
#  'A70005',
#  'A70007',
#  'A70008',
#  'A7001',
#  'A70011',
#  'A70012',
#  'A70015',
#  'A70057',
#  'A7006',
#  'A70080',
#  'A7011',
#  'A7013',
#  'A7015',
#  'A7017',
#  'A7018',
#  'A7019',
#  'A7022',
#  'A7023',
#  'A7024',
#  'A7025',
#  'A7026',
#  'A7028',
#  'A7045',
#  'A7066',
#  'A7068',
#  'A7069',
#  'A7070',
#  'A7094',
#  'A7095',
#  'A7098',
#  'A71005',
#  'A71008',
#  'A71009',
#  'A7101',
#  'A71010',
#  'A71011',
#  'A71012',
#  'A71026',
#  'A71027',
#  'A71029',
#  'A71032',
#  'A7104',
#  'A71040',
#  'A71042',
#  'A71057',
#  'A71061',
#  'A71066',
#  'A71067',
#  'A71070',
#  'A71082',
#  'A71089',
#  'A71098',
#  'A71099',
#  'A7115',
#  'A7117',
#  'A71201',
#  'A71205',
#  'A71206',
#  'A71207',
#  'A71214',
#  'A71215',
#  'A71216',
#  'A7122',
#  'A7123',
#  'A7132',
#  'A7133',
#  'A7134',
#  'A7145',
#  'A7152',
#  'A7155',
#  'A7156',
#  'A7157',
#  'A7158',
#  'A7171',
#  'A7172',
#  'A7174',
#  'A7182',
#  'A7186',
#  'A7189',
#  'A7195',
#  'A7197',
#  'A72007',
#  'A72012',
#  'A72025',
#  'A72028',
#  'A72033',
#  'A7206',
#  'A7232',
#  'A7244',
#  'A7245',
#  'A7259',
#  'A7260',
#  'A7274',
#  'A7275',
#  'A7276',
#  'A7277',
#  'A7280',
#  'A7281',
#  'A7282',
#  'A7285',
#  'A7294',
#  'A7295',
#  'A7298',
#  'A7300',
#  'A7303',
#  'A7319',
#  'A7322',
#  'A7328',
#  'A7329',
#  'A7330',
#  'A7337',
#  'A7343',
#  'A7345',
#  'A7350',
#  'A7351',
#  'A7352',
#  'A7356',
#  'A7357',
#  'A7359',
#  'A7361',
#  'A7366',
#  'A7372',
#  'A7374',
#  'A7375',
#  'A7382',
#  'A7383',
#  'A7384',
#  'A7387',
#  'A7389',
#  'A7390',
#  'A7392',
#  'AM001',
#  'AM006',
#  'AM008',
#  'AM014',
#  'AM015',
#  'AM018',
#  'AM039',
#  'AM049',
#  'AM110',
#  'AM153',
#  'AM156',
#  'AM159',
#  'AM162',
#  'AM174',
#  'AM201',
#  'AM208',
#  'AM210',
#  'AM211',
#  'AM216',
#  'AM222',
#  'AM224',
#  'AM229',
#  'AM235',
#  'AM249',
#  'AM250',
#  'AM256',
#  'AM261',
#  'AM268',
#  'AM269',
#  'AM272HY',
#  'AM283',
#  'AM300',
#  'AM301',
#  'AM323',
#  'AM328',
#  'AM331',
#  'AM333',
#  'AM338',
#  'AM352',
#  'AM353',
#  'AM358',
#  'AM360',
#  'AM710',
#  'AM909',
#  'AM923',
#  'A2014',
#  'A2057',
#  'A2060',
#  'A2070',
#  'A2108',
#  'A2119',
#  'A2121',
#  'A2124',
#  'A2125',
#  'A2126',
#  'A2127',
#  'A2171',
#  'A2206',
#  'A2216',
#  'A2242',
#  'A2268C',
#  'A2295',
#  'A2302',
#  'A2307',
#  'A2310',
#  'A2311',
#  'A2317',
#  ...]

# %%
crawler_status = 'error'

print(crawler_status)
# Out:
# error

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 2

resp = requests.get('https://portal.thepartshq.com/rest/V1/marmon/product/details/sku/' + input_.loc[a, 'Part_Number'],
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '[{"_value":{"supplier":"Perfection Hy-Test","brand":null,"part_no":"A2107","part_key":"008370844","part_type":"Manual Transmission Mount, Automatic Transmission Mount","storelocator":"0","buyersguide":["1",{"app":[{"make":"CHEVROLET","model":"3B","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3B","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3C","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3C","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3D","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3D","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3E","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3E","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3F","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3F","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3G","year":"1959","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"3G","year":"1959","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"BLAZER","year":"1987","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"BLAZER","year":"1987","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"BLAZER","year":"69-74","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"BLAZER","year":"69-74","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C50","year":"71-78","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C50","year":"71-78","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C50","year":"83-86","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C50","year":"83-86","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C60","year":"83-85","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"C60","year":"83-85","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"G10 VAN","year":"64-67","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"G10 VAN","year":"64-67","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"G20 VAN","year":"1967","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"G20 VAN","year":"1967","engine":"All Engines","parttype":"Automatic Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"K10","year":"75-84","engine":"All Engines","parttype":"Manual Transmission Mount","apptype":"A","qty":"1"},{"make":"CHEVROLET","model":"K10","year":"75-84","engine":"All Engines","p ...

# %%
import json

# %%
json_data = json.loads(resp)

json_data
# Out:
# [{'_value': {'supplier': 'Perfection Hy-Test',
#    'brand': None,
#    'part_no': 'A2107',
#    'part_key': '008370844',
#    'part_type': 'Manual Transmission Mount, Automatic Transmission Mount',
#    'storelocator': '0',
#    'buyersguide': ['1',
#     {'app': [{'make': 'CHEVROLET',
#        'model': '3B',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3B',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3C',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3C',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3D',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3D',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3E',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3E',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3F',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3F',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3G',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': '3G',
#        'year': '1959',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'BLAZER',
#        'year': '1987',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'BLAZER',
#        'year': '1987',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'BLAZER',
#        'year': '69-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'BLAZER',
#        'year': '69-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C50',
#        'year': '71-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C50',
#        'year': '71-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C50',
#        'year': '83-86',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C50',
#        'year': '83-86',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C60',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'C60',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'G10 VAN',
#        'year': '64-67',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'G10 VAN',
#        'year': '64-67',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'G20 VAN',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'G20 VAN',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10 PICKUP',
#        'year': '60-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10 PICKUP',
#        'year': '60-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10 SUBURBAN',
#        'year': '67-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K10 SUBURBAN',
#        'year': '67-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 PANEL',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 PANEL',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 PICKUP',
#        'year': '60-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 PICKUP',
#        'year': '60-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 SUBURBAN',
#        'year': '67-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K20 SUBURBAN',
#        'year': '67-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K30',
#        'year': '77-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K30',
#        'year': '77-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K30 PICKUP',
#        'year': '68-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K30 PICKUP',
#        'year': '68-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K5 BLAZER',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'K5 BLAZER',
#        'year': '75-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P10 SERIES',
#        'year': '63-67',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P10 SERIES',
#        'year': '63-67',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P20 SERIES',
#        'year': '63-65',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P20 SERIES',
#        'year': '63-65',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P30 SERIES',
#        'year': '63-65',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'P30 SERIES',
#        'year': '63-65',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'TRUCK',
#        'year': '54-60',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'CHEVROLET',
#        'model': 'TRUCK',
#        'year': '54-60',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'C5000',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'C5000',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'C6000',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'C6000',
#        'year': '83-85',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G1000 SERIES',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G1000 SERIES',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G15/G1500 VAN',
#        'year': '67-69',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G15/G1500 VAN',
#        'year': '67-69',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G25/G2500 VAN',
#        'year': '67-69',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'G25/G2500 VAN',
#        'year': '67-69',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'JIMMY',
#        'year': '70-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'JIMMY',
#        'year': '70-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15 SUBURBAN',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15 SUBURBAN',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15/K1500 PICKUP',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15/K1500 PICKUP',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15/K1500 SUBURBAN',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K15/K1500 SUBURBAN',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K1500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K1500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K1500 SUBURBAN',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K1500 SUBURBAN',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25 SUBURBAN',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25 SUBURBAN',
#        'year': '75-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25/K2500 PICKUP',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25/K2500 PICKUP',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25/K2500 SUBURBAN',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K25/K2500 SUBURBAN',
#        'year': '67-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K2500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K2500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K2500 SUBURBAN',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K2500 SUBURBAN',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K35',
#        'year': '77-78',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K35',
#        'year': '77-78',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K35/K3500 PICKUP',
#        'year': '68-74',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K35/K3500 PICKUP',
#        'year': '68-74',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K3500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'K3500',
#        'year': '79-84',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'P1000',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'P1000',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'P15/P1500 VAN',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'P15/P1500 VAN',
#        'year': '1967',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'PB1000 SERIES',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'PB1000 SERIES',
#        'year': '1966',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'TRUCK',
#        'year': '56-59',
#        'engine': 'All Engines',
#        'parttype': 'Manual Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'},
#       {'make': 'GMC',
#        'model': 'TRUCK',
#        'year': '56-59',
#        'engine': 'All Engines',
#        'parttype': 'Automatic Transmission Mount',
#        'apptype': 'A',
#        'qty': '1'}]}],
#    'aaiabrandid': None,
#    'buylinkcnt': '0',
#    'location': None,
#    'images': {'image': [{'id': 'HTTPS://WWW.SHOWMETHEPARTSDB3.COM/BIN/images/Perfection/A2107_ANG.JPG',
#       'height': '480',
#       'width': '480'},
#      {'id': 'HTTPS://WWW.SHOWMETHEPARTSDB3.COM/BIN/images/Perfection/360_Files/A2107.html',
#       'height': '475',
#       'width': '629'}]},
#    'Attributes': {'partattributes': [{'attribute': 'Brand Description',
#       'value': 'Auto Trans Mount',
#       'recno': '1'},
#      {'attribute': 'Mount Material', 'value': 'Steel, Rubber', 'recno': '71'},
#      {'attribute': 'Mount Category', 'value': 'Solid', 'recno': '72'},
#      {'attribute': 'Position',
#       'value': 'Left Upper, Right Upper',
#       'recno': '73'},
#      {'attribute': 'Stud Quantity', 'value': '0', 'recno': '74'},
#      {'attribute': 'Mount Hole Quantity', 'value': '1', 'recno': '75'},
#      {'attribute': 'Grade Type', 'value': 'Standard', 'recno': '76'},
#      {'attribute': 'Mounting Bracket Included', 'value': 'No', 'recno': '77'},
#      {'attribute': 'Bushing Material', 'value': 'Rubber', 'recno': '78'},
#      {'attribute': 'Description', 'value': 'TRANS MOUNT', 'recno': '79'},
#      {'attribute': 'Country Of Origin', 'value': 'IN', 'recno': '80'},
#      {'attribute': 'Hardware Included', 'value': 'No', 'recno': '81'}]},
#    'interchangepartdata': {'interchange': [{'mfg': 'ANCHOR',
#       'comp_no': '2107',
#       'part_no': 'A2107',
#       'part_key': '008370844',
#       'supplier': 'Perfection Hy-Test',
#       'comment': None,
#       'storelocator': '0',
#       'part_type': 'Manual Transmission Mount, Automatic Transmission Mount'},
#      {'mfg': 'GENERAL MOTORS',
#       'comp_no': '3763761',
#       'part_no': 'A2107',
#       'part_key': '008370844',
#       'supplier': 'Perfection Hy-Test',
#       'comment': None,
#       'storelocator': '0',
#       'part_type': 'Manual Transmission Mount, Automatic Transmission Mount'},
#      {'mfg': 'GENERAL MOTORS',
#       'comp_no': '3705444',
#       'part_no': 'A2107',
#       'part_key': '008370844',
#       'supplier': 'Perfection Hy-Test',
#       'comment': None,
#       'storelocator': '0',
#       'part_type': 'Manual Transmission Mount, Automatic Transmission Mount'},
#      {'mfg': 'PIONEER',
#       'comp_no': '602107',
#       'part_no': 'A2107',
#       'part_key': '008370844',
#       'supplier': 'Perfection Hy-Test',
#       'comment': None,
#       'storelocator': '0',
#       'part_type': 'Manual Transmission Mount, Automatic Transmission Mount'},
#      {'mfg': 'WESTAR',
#       'comp_no': 'EM-2107',
#       'part_no': 'A2107',
#       'part_key': '008370844',
#       'supplier': 'Perfection Hy-Test',
#       'comment': None,
#       'storelocator': '0',
#       'part_type': 'Manual Transmission Mount, Automatic Transmission Mount'}]}},
#   '_attribute': {'ver': '12.3', 'err_num': '0', 'totalrecords': '1'}}]

# %%
json_data[0]['_value'] == None
# Out:
# False

# %%
part_type = '' if json_data[0]['_value']['part_type'] == None else json_data[0]['_value']['part_type'].strip()

part_type
# Out:
# 'Manual Transmission Mount, Automatic Transmission Mount'

# %%
list_vehicle = [] if json_data[0]['_value']['buyersguide'] == '1' else json_data[0]['_value']['buyersguide'][1]['app']
list_vehicle = list_vehicle if type(list_vehicle) == list else [list_vehicle]

list_vehicle
# Out:
# [{'make': 'CHEVROLET',
#   'model': '3B',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3B',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3C',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3C',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3D',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3D',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3E',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3E',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3F',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3F',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3G',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': '3G',
#   'year': '1959',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'BLAZER',
#   'year': '1987',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'BLAZER',
#   'year': '1987',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'BLAZER',
#   'year': '69-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'BLAZER',
#   'year': '69-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C50',
#   'year': '71-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C50',
#   'year': '71-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C50',
#   'year': '83-86',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C50',
#   'year': '83-86',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C60',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'C60',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'G10 VAN',
#   'year': '64-67',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'G10 VAN',
#   'year': '64-67',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'G20 VAN',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'G20 VAN',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10 PICKUP',
#   'year': '60-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10 PICKUP',
#   'year': '60-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10 SUBURBAN',
#   'year': '67-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K10 SUBURBAN',
#   'year': '67-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 PANEL',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 PANEL',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 PICKUP',
#   'year': '60-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 PICKUP',
#   'year': '60-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 SUBURBAN',
#   'year': '67-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K20 SUBURBAN',
#   'year': '67-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K30',
#   'year': '77-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K30',
#   'year': '77-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K30 PICKUP',
#   'year': '68-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K30 PICKUP',
#   'year': '68-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K5 BLAZER',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'K5 BLAZER',
#   'year': '75-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P10 SERIES',
#   'year': '63-67',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P10 SERIES',
#   'year': '63-67',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P20 SERIES',
#   'year': '63-65',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P20 SERIES',
#   'year': '63-65',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P30 SERIES',
#   'year': '63-65',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'P30 SERIES',
#   'year': '63-65',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'TRUCK',
#   'year': '54-60',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'CHEVROLET',
#   'model': 'TRUCK',
#   'year': '54-60',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'C5000',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'C5000',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'C6000',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'C6000',
#   'year': '83-85',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G1000 SERIES',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G1000 SERIES',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G15/G1500 VAN',
#   'year': '67-69',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G15/G1500 VAN',
#   'year': '67-69',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G25/G2500 VAN',
#   'year': '67-69',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'G25/G2500 VAN',
#   'year': '67-69',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'JIMMY',
#   'year': '70-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'JIMMY',
#   'year': '70-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15 SUBURBAN',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15 SUBURBAN',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15/K1500 PICKUP',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15/K1500 PICKUP',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15/K1500 SUBURBAN',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K15/K1500 SUBURBAN',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K1500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K1500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K1500 SUBURBAN',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K1500 SUBURBAN',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25 SUBURBAN',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25 SUBURBAN',
#   'year': '75-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25/K2500 PICKUP',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25/K2500 PICKUP',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25/K2500 SUBURBAN',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K25/K2500 SUBURBAN',
#   'year': '67-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K2500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K2500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K2500 SUBURBAN',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K2500 SUBURBAN',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K35',
#   'year': '77-78',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K35',
#   'year': '77-78',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K35/K3500 PICKUP',
#   'year': '68-74',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K35/K3500 PICKUP',
#   'year': '68-74',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K3500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'K3500',
#   'year': '79-84',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'P1000',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'P1000',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'P15/P1500 VAN',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'P15/P1500 VAN',
#   'year': '1967',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'PB1000 SERIES',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'PB1000 SERIES',
#   'year': '1966',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'TRUCK',
#   'year': '56-59',
#   'engine': 'All Engines',
#   'parttype': 'Manual Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'},
#  {'make': 'GMC',
#   'model': 'TRUCK',
#   'year': '56-59',
#   'engine': 'All Engines',
#   'parttype': 'Automatic Transmission Mount',
#   'apptype': 'A',
#   'qty': '1'}]

# %%
dict_vehicle = {}
for vehicle in list_vehicle:
    if vehicle['make'].strip() not in dict_vehicle:
        dict_vehicle[vehicle['make'].strip()] = {vehicle['model'].strip(): {vehicle['engine'].strip(): [vehicle['year'].strip()]}}
    else:
        if vehicle['model'].strip() not in dict_vehicle[vehicle['make'].strip()]:
            dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()] = {vehicle['engine'].strip(): [vehicle['year'].strip()]}
        else:
            if vehicle['engine'].strip() not in dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()]:
                dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()][vehicle['engine'].strip()] = [vehicle['year'].strip()]
            else:
                dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()][vehicle['engine'].strip()].append(vehicle['year'].strip())
                
    dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()][vehicle['engine'].strip()] = sorted(list(set(dict_vehicle[vehicle['make'].strip()][vehicle['model'].strip()][vehicle['engine'].strip()])))
    
dict_vehicle
# Out:
# {'CHEVROLET': {'3B': {'All Engines': ['1959']},
#   '3C': {'All Engines': ['1959']},
#   '3D': {'All Engines': ['1959']},
#   '3E': {'All Engines': ['1959']},
#   '3F': {'All Engines': ['1959']},
#   '3G': {'All Engines': ['1959']},
#   'BLAZER': {'All Engines': ['1987', '69-74']},
#   'C50': {'All Engines': ['71-78', '83-86']},
#   'C60': {'All Engines': ['83-85']},
#   'G10 VAN': {'All Engines': ['64-67']},
#   'G20 VAN': {'All Engines': ['1967']},
#   'K10': {'All Engines': ['75-84']},
#   'K10 PICKUP': {'All Engines': ['60-74']},
#   'K10 SUBURBAN': {'All Engines': ['67-84']},
#   'K20': {'All Engines': ['75-84']},
#   'K20 PANEL': {'All Engines': ['1967']},
#   'K20 PICKUP': {'All Engines': ['60-74']},
#   'K20 SUBURBAN': {'All Engines': ['67-84']},
#   'K30': {'All Engines': ['77-84']},
#   'K30 PICKUP': {'All Engines': ['68-74']},
#   'K5 BLAZER': {'All Engines': ['75-84']},
#   'P10 SERIES': {'All Engines': ['63-67']},
#   'P20 SERIES': {'All Engines': ['63-65']},
#   'P30 SERIES': {'All Engines': ['63-65']},
#   'TRUCK': {'All Engines': ['54-60']}},
#  'GMC': {'C5000': {'All Engines': ['83-85']},
#   'C6000': {'All Engines': ['83-85']},
#   'G1000 SERIES': {'All Engines': ['1966']},
#   'G15/G1500 VAN': {'All Engines': ['67-69']},
#   'G25/G2500 VAN': {'All Engines': ['67-69']},
#   'JIMMY': {'All Engines': ['70-84']},
#   'K15': {'All Engines': ['75-78']},
#   'K15 SUBURBAN': {'All Engines': ['75-78']},
#   'K15/K1500 PICKUP': {'All Engines': ['67-74']},
#   'K15/K1500 SUBURBAN': {'All Engines': ['67-74']},
#   'K1500': {'All Engines': ['79-84']},
#   'K1500 SUBURBAN': {'All Engines': ['79-84']},
#   'K25': {'All Engines': ['75-78']},
#   'K25 SUBURBAN': {'All Engines': ['75-78']},
#   'K25/K2500 PICKUP': {'All Engines': ['67-74']},
#   'K25/K2500 SUBURBAN': {'All Engines': ['67-74']},
#   'K2500': {'All Engines': ['79-84']},
#   'K2500 SUBURBAN': {'All Engines': ['79-84']},
#   'K35': {'All Engines': ['77-78']},
#   'K35/K3500 PICKUP': {'All Engines': ['68-74']},
#   'K3500': {'All Engines': ['79-84']},
#   'P1000': {'All Engines': ['1966']},
#   'P15/P1500 VAN': {'All Engines': ['1967']},
#   'PB1000 SERIES': {'All Engines': ['1966']},
#   'TRUCK': {'All Engines': ['56-59']}}}

# %%
list_vehicle = []
for make in dict_vehicle:
    for model in dict_vehicle[make]:
        list_year = []
        for engine in dict_vehicle[make][model]:
            list_year += dict_vehicle[make][model][engine]
        list_year = sorted(list(set(list_year)))
        
        list_vehicle.append(make + ' ' + model + ' ' + ','.join(list_year))
        
vehicle_1 = '\n'.join(sorted(list_vehicle))

print(vehicle_1)
# Out:
# CHEVROLET 3B 1959
# CHEVROLET 3C 1959
# CHEVROLET 3D 1959
# CHEVROLET 3E 1959
# CHEVROLET 3F 1959
# CHEVROLET 3G 1959
# CHEVROLET BLAZER 1987,69-74
# CHEVROLET C50 71-78,83-86
# CHEVROLET C60 83-85
# CHEVROLET G10 VAN 64-67
# CHEVROLET G20 VAN 1967
# CHEVROLET K10 75-84
# CHEVROLET K10 PICKUP 60-74
# CHEVROLET K10 SUBURBAN 67-84
# CHEVROLET K20 75-84
# CHEVROLET K20 PANEL 1967
# CHEVROLET K20 PICKUP 60-74
# CHEVROLET K20 SUBURBAN 67-84
# CHEVROLET K30 77-84
# CHEVROLET K30 PICKUP 68-74
# CHEVROLET K5 BLAZER 75-84
# CHEVROLET P10 SERIES 63-67
# CHEVROLET P20 SERIES 63-65
# CHEVROLET P30 SERIES 63-65
# CHEVROLET TRUCK 54-60
# GMC C5000 83-85
# GMC C6000 83-85
# GMC G1000 SERIES 1966
# GMC G15/G1500 VAN 67-69
# GMC G25/G2500 VAN 67-69
# GMC JIMMY 70-84
# GMC K15 75-78
# GMC K15 SUBURBAN 75-78
# GMC K15/K1500 PICKUP 67-74
# GMC K15/K1500 SUBURBAN 67-74
# GMC K1500 79-84
# GMC K1500 SUBURBAN 79-84
# GMC K25 75-78
# GMC K25 SUBURBAN 75-78
# GMC K25/K2500 PICKUP 67-74
# GMC K25/K2500 SUBURBAN 67-74
# GMC K2500 79-84
# GMC K2500 SUBURBAN 79-84
# GMC K35 77-78
# GMC K35/K3500 PICKUP 68-74
# GMC K3500 79-84
# GMC P1000 1966
# GMC P15/P1500 VAN 1967
# GMC PB1000 SERIES 1966
# GMC TRUCK 56-59

# %%
list_vehicle = []
for make in dict_vehicle:
    for model in dict_vehicle[make]:
        for engine in dict_vehicle[make][model]:
            if engine == '':
                list_vehicle.append(make + ' ' + model + ' ' + ','.join(list_year))
            else:
                list_vehicle.append(make + ' ' + model + ' ' + ','.join(list_year) + ' ' + engine)

vehicle_2 = '\n'.join(sorted(list_vehicle))

print(vehicle_2)
# Out:
# CHEVROLET 3B 56-59 All Engines
# CHEVROLET 3C 56-59 All Engines
# CHEVROLET 3D 56-59 All Engines
# CHEVROLET 3E 56-59 All Engines
# CHEVROLET 3F 56-59 All Engines
# CHEVROLET 3G 56-59 All Engines
# CHEVROLET BLAZER 56-59 All Engines
# CHEVROLET C50 56-59 All Engines
# CHEVROLET C60 56-59 All Engines
# CHEVROLET G10 VAN 56-59 All Engines
# CHEVROLET G20 VAN 56-59 All Engines
# CHEVROLET K10 56-59 All Engines
# CHEVROLET K10 PICKUP 56-59 All Engines
# CHEVROLET K10 SUBURBAN 56-59 All Engines
# CHEVROLET K20 56-59 All Engines
# CHEVROLET K20 PANEL 56-59 All Engines
# CHEVROLET K20 PICKUP 56-59 All Engines
# CHEVROLET K20 SUBURBAN 56-59 All Engines
# CHEVROLET K30 56-59 All Engines
# CHEVROLET K30 PICKUP 56-59 All Engines
# CHEVROLET K5 BLAZER 56-59 All Engines
# CHEVROLET P10 SERIES 56-59 All Engines
# CHEVROLET P20 SERIES 56-59 All Engines
# CHEVROLET P30 SERIES 56-59 All Engines
# CHEVROLET TRUCK 56-59 All Engines
# GMC C5000 56-59 All Engines
# GMC C6000 56-59 All Engines
# GMC G1000 SERIES 56-59 All Engines
# GMC G15/G1500 VAN 56-59 All Engines
# GMC G25/G2500 VAN 56-59 All Engines
# GMC JIMMY 56-59 All Engines
# GMC K15 56-59 All Engines
# GMC K15 SUBURBAN 56-59 All Engines
# GMC K15/K1500 PICKUP 56-59 All Engines
# GMC K15/K1500 SUBURBAN 56-59 All Engines
# GMC K1500 56-59 All Engines
# GMC K1500 SUBURBAN 56-59 All Engines
# GMC K25 56-59 All Engines
# GMC K25 SUBURBAN 56-59 All Engines
# GMC K25/K2500 PICKUP 56-59 All Engines
# GMC K25/K2500 SUBURBAN 56-59 All Engines
# GMC K2500 56-59 All Engines
# GMC K2500 SUBURBAN 56-59 All Engines
# GMC K35 56-59 All Engines
# GMC K35/K3500 PICKUP 56-59 All Engines
# GMC K3500 56-59 All Engines
# GMC P1000 56-59 All Engines
# GMC P15/P1500 VAN 56-59 All Engines
# GMC PB1000 SERIES 56-59 All Engines
# GMC TRUCK 56-59 All Engines

# %%
src = json_data[0]['_value']['images']['image']['id'].strip() if type(json_data[0]['_value']['images']['image']) == dict else json_data[0]['_value']['images']['image'][0]['id'].strip()

src
# Out:
# 'HTTPS://WWW.SHOWMETHEPARTSDB3.COM/BIN/images/Perfection/A2107_ANG.JPG'

# %%
list_attribute = json_data[0]['_value']['Attributes']['partattributes'] if 'Attributes' in json_data[0]['_value'] else []
list_attribute = list_attribute if type(list_attribute) == list else [list_attribute]

list_attribute
# Out:
# [{'attribute': 'Brand Description', 'value': 'Auto Trans Mount', 'recno': '1'},
#  {'attribute': 'Mount Material', 'value': 'Steel, Rubber', 'recno': '71'},
#  {'attribute': 'Mount Category', 'value': 'Solid', 'recno': '72'},
#  {'attribute': 'Position', 'value': 'Left Upper, Right Upper', 'recno': '73'},
#  {'attribute': 'Stud Quantity', 'value': '0', 'recno': '74'},
#  {'attribute': 'Mount Hole Quantity', 'value': '1', 'recno': '75'},
#  {'attribute': 'Grade Type', 'value': 'Standard', 'recno': '76'},
#  {'attribute': 'Mounting Bracket Included', 'value': 'No', 'recno': '77'},
#  {'attribute': 'Bushing Material', 'value': 'Rubber', 'recno': '78'},
#  {'attribute': 'Description', 'value': 'TRANS MOUNT', 'recno': '79'},
#  {'attribute': 'Country Of Origin', 'value': 'IN', 'recno': '80'},
#  {'attribute': 'Hardware Included', 'value': 'No', 'recno': '81'}]

# %%
df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                         'Part_Number': input_.loc[a, 'Part_Number'],
                         'Part_Type': part_type,
                         'Vehicle_1': vehicle_1,
                         'Vehicle_2': vehicle_2,
                         'Pic': '',
                         'Url': input_.loc[a, 'Url'],
                         'Src': src}])

for attribute in list_attribute:
    df_temp.loc[0, attribute['attribute'].strip()] = attribute['value'].strip()
    
output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
crawler_status = 'ok'

print(crawler_status)
# Out:
# ok

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                             'Part_Number': input_.loc[a, 'Part_Number'],
                             'Url': input_.loc[a, 'Url']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
if crawler_status == 'null':
    df_temp = pd.DataFrame([{'No.': input_.loc[a, 'No.'],
                             'Part_Number': int(input_.loc[a, 'Part_Number']),
                             'Url': input_.loc[a, 'Url']}])
    
    output_null = pd.concat([output_null, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#    序号 Part_Number                                          Part_Type  \
# 0   3       A2107  Manual Transmission Mount, Automatic Transmiss...
#
#                                            Vehicle_1  \
# 0  CHEVROLET 3B 1959\nCHEVROLET 3C 1959\nCHEVROLE...
#
#                                            Vehicle_2 Pic  \
# 0  CHEVROLET 3B 56-59 All Engines\nCHEVROLET 3C 5...
#
#                                                  Url  \
# 0  https://portal.thepartshq.com/marmon-ride-cont...
#
#                                                  Src Brand Description  \
# 0  HTTPS://WWW.SHOWMETHEPARTSDB3.COM/BIN/images/P...  Auto Trans Mount
#
#   Mount Material Mount Category                 Position Stud Quantity  \
# 0  Steel, Rubber          Solid  Left Upper, Right Upper             0
#
#   Mount Hole Quantity Grade Type Mounting Bracket Included Bushing Material  \
# 0                   1   Standard                        No           Rubber
#
#    Description Country Of Origin Hardware Included
# 0  TRANS MOUNT                IN                No

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if len(output_null) != 0:
    output_null = output_null.drop_duplicates(ignore_index=True)
    output_null = output_null.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_null.to_excel('./test_part_null.xlsx', index=False)

output_null
# Out:
# Empty DataFrame
# Columns: []
# Index: []
