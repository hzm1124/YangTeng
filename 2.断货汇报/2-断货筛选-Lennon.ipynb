# %% [markdown]
# - Update: 2023.05.09

# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230512.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate,
                   sheet_name='附_1统计源（含新品、清仓、新品成长）',
                   header=3,
                   usecols=[2, 3, 5, 11, 12])

df
# Out:
#                  MRP SKU  目标\n周销  Level   在库   在途
# 0           USTBC40007-C   37.60   TOP1  127  264
# 1            USGS06060NZ   34.29  TOP10  174  124
# 2             USGS43640B   25.50  TOP10    0  235
# 3      USTCV17215HIE-2-C   33.42   TOP1   74  275
# 4           USWR644FLU-C   30.61   TOP1   76  349
# ...                  ...     ...    ...  ...  ...
# 52341         USTCA04824    2.00  TOP10    0   11
# 52342         USPSP15636    1.40     普通    0    0
# 52343         USCOS31423    0.00     普通    0    0
# 52344          USWR04923    0.00     普通   10    0
# 52345         USWR04923D    0.00     普通    6    0
#
# [52346 rows x 5 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU',
                                                                   'Level',
                                                                   '目标\n周销',
                                                                   '在途']]

df
# Out:
#                MRP SKU  Level  目标\n周销  在途
# 133         USSTR69470  TOP10    3.83   0
# 344      USALT84370B-C  TOP20    1.71   0
# 595         USHCR98007  TOP20    2.70   0
# 649         USFLW00513  TOP20    1.45   0
# 656        USWR51797-C  TOP20    4.12   0
# ...                ...    ...     ...  ..
# 49959        USOC47127  TOP20    2.55   0
# 50636  USFFTOPO002S-YC  TOP20    6.29   0
# 50642  USFFCHPO007S-YC  TOP20    0.40   0
# 51497   USBRPS588805FR  TOP20    2.55   0
# 51502   USBRPS721486FR  TOP20    0.85   0
#
# [140 rows x 4 columns]

# %%
import datetime

writer = pd.ExcelWriter('Lennon_筛选好的断货SKU_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.xlsx')
df.to_excel(writer, index=False)
writer.close()
