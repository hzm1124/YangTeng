# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./menu.xlsx', header=0)
list_url = df_menu['Url'].to_list()

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：150
# ['https://www.dormanproducts.com/p-131697-599-210xd.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-131698-599-211xd.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-106223-601-036.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128361-599-215.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-82894-599-228.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-76754-599-226.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-72789-599-147.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-66592-599-149.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-76398-599-197.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-65302-599-140.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-78185-599-206.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-76741-599-198.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53418-599-128.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-49327-599-020.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-74179-599-144.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73910-599-190.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-65300-599-130.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-75961-599-145.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-131430-599-280.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-50290-599-027.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-74185-599-138.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-49679-599-004.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-50180-599-015.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-47094-599-009.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-46838-599-003.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-49317-599-017.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-74181-599-146.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-48281-599-019.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73207-599-189.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-50856-599-018.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-46714-599-001.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-52347-599-029.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53514-599-133.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-131396-599-282.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-65298-599-132.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73881-599-143.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-47096-599-013.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-49678-599-025.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73856-599-148.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73855-599-142.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-131094-599-217.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128360-599-213.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-67227-599-151.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-140459-599-272.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-83820-599-267.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-78895-599-150.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-125939-599-214.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-83239-599-266.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-86474-599-203.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-67182-599-173.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53521-599-172.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-54599-599-002.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-72809-599-191.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-83923-599-204.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-72758-599-196.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-77229-599-260.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-98037-599-268.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-77156-599-152.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-130935-599-220.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-140733-599-294.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-103190-599-012.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128707-599-269.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-77853-599-225.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-52518-599-141.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-80178-599-153.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-51685-599-011.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-125156-599-218.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-75833-599-199.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53515-599-129.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53516-599-134.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-46717-599-030.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53511-599-161.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-72703-599-127.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-85424-599-205.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128362-599-216.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-76094-599-193.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-83278-599-261.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-53554-599-032.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-68058-599-183.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-95001-599-270.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-106089-599-212.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-68055-599-186.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-72100-599-035.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-66966-599-135.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-86823-599-207.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-98359-599-271.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-67181-599-171.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-86918-599-265.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-66384-599-139.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-54701-599-033.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-142937-599-293.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-82619-599-040.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128359-599-008.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-128376-599-5511.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-97810-599-006.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-97811-599-007.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-138427-601-715.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-91341-599-050.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135588-601-704.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135657-973-196.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135654-973-176.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135912-973-420.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135665-973-245.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134913-973-233.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134900-973-189.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-137791-973-030.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134891-973-045.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34584-973-008.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34410-973-020.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134930-984-484.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34196-973-022.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-35242-973-201.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34610-973-000.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34333-973-017.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-48404-973-047.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-44119-973-001.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135661-973-238.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134869-973-073.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-48767-973-027.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135660-973-235.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34413-973-026.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134874-973-180.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-100654-973-103.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-138708-599-961.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-100655-973-108.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135354-984-267.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-138165-984-251.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134897-973-155.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-137483-984-123.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134942-984-664.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134876-973-226.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-49122-973-032.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34612-973-028.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-50806-84645.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34208-973-003.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-134929-984-482.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135653-973-160.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135915-984-401.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135916-984-486.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135651-973-157.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-34159-973-016.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-135032-984-201.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-10376-645-702.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-138424-973-271.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-140725-984-247.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-73244-961-304.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-100837-961-304d.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-8384-700-520.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-21977-45406.aspx?origin=keyword',
#  'https://www.dormanproducts.com/p-125851-700-520bx.aspx?origin=keyword']

# %%
df = pd.DataFrame(columns=['Url',
                           'OE_Numbers',
                           'vehicle_url',
                           'Src',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [Url, OE_Numbers, vehicle_url, Src, status]
# Index: []

# %%
import requests

# %%
i = 133

resp = requests.get(list_url[i]).text

resp
# Out:
# '\r\n<!doctype html>\r\n<html lang="en">\r\n<head>\r\n    <title>Electrical Pigtail | 84645 | 7-Wire Pigtail Connector | Dorman Products</title>\r\n\t<meta charset="utf-8" />\r\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate" />\r\n    <meta http-equiv="pragma" content="no-cache" />\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <meta http-equiv="expires" content="-1" />\r\n\r\n    <meta name="description" content="Dorman Products - 84645 : 7-Wire Pigtail Connector. Make better electrical repairs and accessory installations with this pigtail connector. Designed for a clean appearance when installed, it features weatherproof terminals and a locking tab for a reliable quick disconnect electrical connection." />\r\n    <meta name="keywords" content="84645,  Pigtail, Pigtails, General Use Electrical Connector, Headlight, Control, Module, Connector, Headlights, Controls, Modules, Connectors, Headlight Control Module Electrical Plug, Windshield, Wiper, Switch, Connector, Wipers, Switches, Connectors, Windshield Wiper Switch Electrical Plug, Wiper Switch Electrical Plug, Convertible, Top, Switch, Connector, Convertibles, Tops, Switches, Connectors, Convertible Switch Connector, Convertible Roof Switch Connector, Roof Switch Connector, Wire Connector, Connector, Door, Window, Switch, Connector, Doors, Windows, Switches, Connectors, Window Switch Connector, Switch Connector, Connector, Rear, Window, Washer, Fluid, Pump, Motor, Connector, Pumps, Motors, Connectors, Window Washer Fluid Pump Motor Electrical Plug, Windshield Washer Fluid Pump Motor Electrical Plug, Daytime, Running, Lamp, Module, Connector, Lamps, Modules, Connectors, DRLM, Daytime Running Lamp Module Electrical Plug, Power, Seat, Track, Motor, Connector, Seats, Tracks, Motors, Connectors, Power Seat Track Motor Electrical Plug, Fuel, Filler, Door, Relay, Connector, Relays, Connectors, Gas Door Connector, Electric, Sliding, Door, Actuator, Connector, Actuators, Connectors, Sliding Door Actuator Electrical Plug, HVAC, Air, Inlet, Door, Actuator, Connector, Doors, Actuators, Connectors, HVAC Air Inlet Door Actuator Electrical Plug, Time, Delay, Relay, Accessory, Connector, Relays, Accessories, Connectors, Time Delay Relay Accessory Electrical Plug, HVAC, Blower, Motor, Resistor, Connector, Motors, Resistors, Connectors, Blower Motor Resistor Electrical Plug, Headlight, Switch, Connector, Headlights, Switches, Connectors, Headlight Switch Electrical Plug" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\r\n    <meta name="apple-mobile-web-app-capable" content="no" />\r\n    <link rel="canonical" href="https://www.dormanproducts.com/p-50806-84645.aspx" /><meta property="og:title" content="Dorman Products - 84645" /><meta property="og:type" content="product" /><meta property="og:image" content="https://www.dormanproducts.com/images/product/icon/645-702-007.JPG" /><meta property="og:url" content="https://www.dormanproducts.com/p-50806-84645.aspx" /><meta property="og:description" content="7-Wire Pigtail Connector" /><link rel="image_src" href="https://www.dormanproducts.com/images/product/icon/645-702-007.JPG" />\r\n    \r\n    <!--[if lt IE 9]>\r\n      <script src="/scripts/html5shiv.js"></script>\r\n    <![endif]-->\r\n    <!--[if IE]>\r\n  \t\t<script src="/scripts/html5shiv.js"></script>\r\n\t<![endif]-->\r\n\r\n    <link rel="stylesheet" href="/content/webfonts.min.css" />\r\n    <link rel="stylesheet" href="/content/bootstrap.min.css" />\r\n    <link rel="stylesheet" href="/content/bootstrap-dialog.min.css" />\r\n    <link rel="stylesheet" href="/content/style.css?d=20220208" />\r\n    <link rel="stylesheet" href="/content/fontello.min.css" />\r\n    <link rel="stylesheet" href="/content/yamm.css" />\r\n\r\n    <link id="nonloginStyle" rel="stylesheet" href="/content/non_login.css?d=20190905"></link>\r\n    \r\n    \r\n\r\n    <!- ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Electrical Pigtail | 84645 | 7-Wire Pigtail Connector | Dorman Products
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="-1" http-equiv="expires"/>
#   <meta content="Dorman Products - 84645 : 7-Wire Pigtail Connector. Make better electrical repairs and accessory installations with this pigtail connector. Designed for a clean appearance when installed, it features weatherproof terminals and a locking tab for a reliable quick disconnect electrical connection." name="description"/>
#   <meta content="84645,  Pigtail, Pigtails, General Use Electrical Connector, Headlight, Control, Module, Connector, Headlights, Controls, Modules, Connectors, Headlight Control Module Electrical Plug, Windshield, Wiper, Switch, Connector, Wipers, Switches, Connectors, Windshield Wiper Switch Electrical Plug, Wiper Switch Electrical Plug, Convertible, Top, Switch, Connector, Convertibles, Tops, Switches, Connectors, Convertible Switch Connector, Convertible Roof Switch Connector, Roof Switch Connector, Wire Connector, Connector, Door, Window, Switch, Connector, Doors, Windows, Switches, Connectors, Window Switch Connector, Switch Connector, Connector, Rear, Window, Washer, Fluid, Pump, Motor, Connector, Pumps, Motors, Connectors, Window Washer Fluid Pump Motor Electrical Plug, Windshield Washer Fluid Pump Motor Electrical Plug, Daytime, Running, Lamp, Module, Connector, Lamps, Modules, Connectors, DRLM, Daytime Running Lamp Module Electrical Plug, Power, Seat, Track, Motor, Connector, Seats, Tracks, Motors, Connectors, Power Seat Track Motor Electrical Plug, Fuel, Filler, Door, Relay, Connector, Relays, Connectors, Gas Door Connector, Electric, Sliding, Door, Actuator, Connector, Actuators, Connectors, Sliding Door Actuator Electrical Plug, HVAC, Air, Inlet, Door, Actuator, Connector, Doors, Actuators, Connectors, HVAC Air Inlet Door Actuator Electrical Plug, Time, Delay, Relay, Accessory, Connector, Relays, Accessories, Connectors, Time Delay Relay Accessory Electrical Plug, HVAC, Blower, Motor, Resistor, Connector, Motors, Resistors, Connectors, Blower Motor Resistor Electrical Plug, Headlight, Switch, Connector, Headlights, Switches, Connectors, Headlight Switch Electrical Plug" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="no" name="apple-mobile-web-app-capable"/>
#   <link href="https://www.dormanproducts.com/p-50806-84645.aspx" rel="canonical"/>
#   <meta content="Dorman Products - 84645" property="og:title"/>
#   <meta content="product" property="og:type"/>
#   <meta content="https://www.dormanproducts.com/images/product/icon/645-702-007.JPG" property="og:image"/>
#   <meta content="https://www.dormanproducts.com/p-50806-84645.aspx" property="og:url"/>
#   <meta content="7-Wire Pigtail Connector" property="og:description"/>
#   <link href="https://www.dormanproducts.com/images/product/icon/645-702-007.JPG" rel="image_src"/>
#   <!--[if lt IE 9]>
#       <script src="/scripts/html5shiv.js"></script>
#     <![endif]-->
#   <!--[if IE]>
#   		<script src="/scripts/html5shiv.js"></script>
# 	<![endif]-->
#   <link href="/content/webfonts.min.css" rel="stylesheet"/>
#   <link href="/content/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/content/bootstrap-dialog.min.css" rel="stylesheet"/>
#   <link href="/content/style.css?d=20220208" rel="stylesheet"/>
#   <link href="/content/fontello.min.css" rel="stylesheet"/>
#   <link href="/content/yamm.css" rel="stylesheet"/>
#   <link href="/content/non_login.css?d=20190905" id="nonloginStyle" rel="stylesheet"/>
#   <!--[if lte IE 9]>
#         <link href="/content/animations-ie-fix.css" rel="stylesheet" type="text/css">
#     <![endif]-->
#   <link href="/content/sliderstyle-3.min.css" rel="stylesheet"/>
#   <link href="/content/animations.min.css" rel="stylesheet"/>
#   <link href="/content/off-canvas.min.css" rel="stylesheet"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <script src="/scripts/head.min.js?d=20190905" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#     head.load({ stringresources: "/scripts/StringResources.js?d=20190905" },
#         { jquery: "/scripts/jquery.min.js?d=20190905" },
#         { bootstrap: "/scripts/bootstrap.min.js?d=20190905" },
#         { dialog: "/scripts/bootstrap-dialog.min.js?d=20190905" },
#         { validator: "/scripts/validator.min.js?d=20190905" },
#         { modernizr: "/scripts/modernizr.min.js?d=20190905" },
#         { isotope: "/scripts/isotope.pkgd.min.js?d=20190905" },
#         { bootstrapdropdown: "/scripts/jquery.bootstrap-dropdown-hover.min.js?d=20190905" },
#         { dormanscript: "/scripts/dorman-scripts.js?d=20210709" },
#         { slider: "/scripts/slidermain.js?d=20190905" },
#         { css3animate: "/scripts/css3-animate-it.js?d=20190905" },
#         { jqcustom: "/scripts/jquery.custom.js?d=20190905" },
#         { typeahead: "/scripts/bootstrap3-typeahead.min.js?d=20190905" },
#         { checkform: "/scripts/CheckForm.js?d=20220208" },
#         { ie10viewport: "/scripts/ie10-viewport-bug-workaround.js?d=20190905" },
#         { eventtracking: "/scripts/eventTracking.js?d=20190905" },
#         { recentActivities: "/scripts/recentactivites.js?d=20190905" });
#     //-->
#   </script>
#   <script src="/scripts/autodetect.js?d=20190905" type="text/javascript">
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-5JGR3XL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return; n = f.fbq = function () {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#             n.queue = []; t = b.createElement(e); t.async = !0;
#             t.src = v; s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '362412311106864');
#         fbq('track', 'PageView');
#   </script>
#   <!-- End Facebook Pixel Code -->
#   <!-- Microsoft ad Conversion Tracking -->
#   <script>
#    (function (w, d, t, r, u) {
#             var f, n, i; w[u] = w[u] || [], f = function () {
#                 var o = { ti: "137031075" }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad")
#             }, n = d.createElement(t), n.src = r, n.async = 1, n.onload = n.onreadystatechange = function () {
#                 var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null)
#             }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i)
#         })(window, document, "script", " //bat.bing.com/bat.js", "uetq");
#   </script>
#   <!-- End Microsoft ad Conversion Tracking -->
#   <style>
#    #divWTBlabels h4 {margin-bottom:0px;}
# 		#divWTBlabels p {margin-bottom:5px;}
#   </style>
#   <script>
#    var __uzdbm_1 = "c186a3f6-c303-4676-ba22-c9f1f2c53145";var __uzdbm_2 = "MGJmYTFiYWUtYnUydi00YTg0LTgyZjEtZmEyNjg0NzBkZGM4JDEyMC4zMi4xMjUuMTAy";var __uzdbm_3 = "";var __uzdbm_4 = "false";
#   </script>
#   <script>
#    (function(w, d, e, u, c, g, a, b){ w["SSJSConnectorObj"] = {ss_cid : c, domain_info: "auto"}; a = d.createElement(e); a.async = true; a.src = u; b = d.getElementsByTagName(e)[0]; b.parentNode.insertBefore(a, b); })(window,document,"script","https://cdn.perfdrive.com/aperture/aperture.js","bu2x","ssConf");
#   </script>
#  </head>
#  <body data-spy="scroll">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5JGR3XL" style="display: none; visibility: hidden" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=362412311106864&amp;ev=PageView&amp;noscript=1" style="display: none" width="1"/>
#   </noscript>
#   <input id="WebsiteSkinID" name="WebsiteSkinID" type="hidden" value="1"/>
#   <input id="IsMobile" name="IsMobile" type="hidden" value="0"/>
#   <input id="hideskin" name="hideskin" type="hidden" value="0"/>
#   <input id="sitewebsubpath" name="sitewebsubpath" type="hidden" value="/"/>
#   <input id="IsLoggedInHidden" name="IsLoggedInHidden" type="hidden" value="0"/>
#   <input id="IsEnglishLinkActiveHidden" name="IsEnglishLinkActiveHidden" type="hidden" value="Y"/>
#   <input id="IsESPLinkActiveHidden" name="IsESPLinkActiveHidden" type="hidden" value="Y"/>
#   <input id="englishurlHidden" name="englishurlHidden" type="hidden" value="www.dormanproducts.com"/>
#   <input id="spanishurlHidden" name="spanishurlHidden" type="hidden" value="www.dormanproducts.es"/>
#   <input id="browserLanguage" name="browserLanguage" type="hidden"/>
#   <input id="AccountNumber" name="AccountNumber" type="hidden"/>
#   <input id="SearchIndexID" name="SearchIndexID" type="hidden" value="4"/>
#   <input id="SearchResultPage" name="SearchResultPage" type="hidden" value="gsearch.aspx"/>
#   <input id="showWTBMap" name="showWTBMap" type="hidden"/>
#   <input id="showWTBError" name="showWTBError" type="hidden"/>
#   <input id="uiCultureLanguage" name="uiCultureLanguage" type="hidden" value="en-US"/>
#   <input id="WTBUrlHolder" name="WTBUrlHolder" type="hidden" value="https://wtbmap.dormanproducts.com?d=1"/>
#   <input id="WhereToBuyMarketingParams" name="WhereToBuyMarketingParams" type="hidden" value="?amp;wmode=opaque&amp;partNumber=header&amp;brand=header&amp;specialOrder=0&amp;language="/>
#   <!-- feedback/questions details -->
#   <!-- login maintenace -->
#   <!-- login webbanner -->
#   <!--Redesign Header-->
#   <!-- top banner navigation -->
#   <header class="topbannerbg yamm" id="header">
#    <div class="container">
#     <nav class="row">
#      <ul class="topbannernav topnav">
#       <!-- language selection -->
#       <li class="topbanner-link pull-left border-right border-left language-selection">
#        <div aria-expanded="false" class="topbanner-btn" data-toggle="dropdown" role="button">
#         <span aria-hidden="true" class="glyphicon glyphicon-globe">
#         </span>
#         <span class="hidden-xs hidden-sm hidden-md">
#          Language:
#          <span class="font-wht">
#           English
#           <span aria-hidden="true" class="icon-down-open-1">
#           </span>
#          </span>
#         </span>
#        </div>
#        <ul class="topbanner-menu dropdown-menu">
#         <script type="text/javascript">
#          defaultLanguage_ENG();
#         </script>
#        </ul>
#       </li>
#      </ul>
#      <ul class="topbannernav topnav topnav-right">
#       <!-- show hide price -->
#       <!-- new product details -->
#       <li class="topbanner-link border-left">
#        <a href="/Pages/forms/ideas.aspx">
#         <div class="topbanner-btn dorman" data-target="#newproductModal" data-toggle="modal">
#          <span aria-hidden="true" class="icon-lamp">
#          </span>
#          <span class="hidden-xs hidden-sm">
#           New Product Idea
#          </span>
#         </div>
#        </a>
#       </li>
#       <!-- be the first to know -->
#       <li class="btftk-dropdown topbanner-link border-left">
#        <a href="/Pages/forms/btftk.aspx">
#         <div aria-controls="topBTFTK" aria-expanded="false" class="topbanner-btn" data-toggle="modal" role="button">
#          <span aria-hidden="true" class="icon-mail-alt">
#          </span>
#          <span class="hidden-xs hidden-sm">
#           Email Newsletters
#          </span>
#         </div>
#        </a>
#       </li>
#       <!-- Live Chat -->
#       <li class="topbanner-link border-left">
#        <div class="topbanner-btn" id="hd_chat_link" onclick="return openMessenger('Header', 'Header Navigation');">
#        </div>
#       </li>
#       <!-- recent activities -->
#       <li class="topbanner-link border-left">
#        <div class="topbanner-btn" id="divMenuRecentActivities" onclick="showRecentActiviesPopupDialog('link_click');">
#         <span aria-hidden="true" class="glyphicon glyphicon-time">
#         </span>
#         <span class="hidden-xs hidden-sm">
#          Recent Activities
#         </span>
#        </div>
#       </li>
#       <!-- distributor login -->
#       <li class="dropdown topbanner-link border-left border-right" id="dist-login">
#        <div class="topbanner-btn" onclick="return trackRedirectToPage('signin.aspx','link_click','Login');">
#         <span aria-hidden="true" class="glyphicon glyphicon-cog">
#         </span>
#         <span class="hidden-xs">
#          Login
#         </span>
#        </div>
#       </li>
#       <!-- distributor login success -->
#       <li class="dropdown megamenu-fw topbanner-link border-left border-right bg-orange dist-login-link" id="dist-login-success">
#        <div aria-expanded="false" class="topbanner-btn" data-toggle="dropdown" role="button">
#         <span class="hidden-xs">
#          <span aria-hidden="true" class="glyphicon glyphicon-cog">
#          </span>
#          :
#         </span>
#         <span aria-hidden="true" class="icon-basket-1">
#         </span>
#         <span class="hidden-xxs hidden-xxxs" id="cart-total">
#          [] Items
#                                 |
#          <strong>
#           $
#          </strong>
#         </span>
#         <span aria-hidden="true" class="icon-down-open-1">
#         </span>
#        </div>
#        <ul class="collapse dropdown-menu topbanner-megamenu dist-logged-menu" id="topDistSuccess">
#         <li>
#          <div class="yamm-content">
#           <div class="row topbanner-submenu">
#            <div class="col-xs-6 col-xxs-12">
#             <h5 class="dist-welcome">
#              Welcome:
#             </h5>
#             <ul>
#              <li class="cust_name">
#               <h4>
#                <a href="/account.aspx">
#                </a>
#               </h4>
#              </li>
#              <li>
#               <a href="#">
#                <div class="cust_phone">
#                 Customer Service:
#                </div>
#                <div class="cust_phone">
#                </div>
#               </a>
#              </li>
#              <li>
#               <a href="/Pages/products/cores/returns.aspx">
#                Core Policy &amp; Procedures
#               </a>
#              </li>
#              <li id="menuSubAccountMaintenance">
#               <a href="/dp_DCAdministration.aspx">
#                Sub-Account Maintenance
#               </a>
#              </li>
#              <li id="menuRegAccMaintenance">
#               <a href="/dp_RegAccAdministration.aspx">
#                Regional Account Maintenance
#               </a>
#              </li>
#              <li id="menuProductFeed">
#               <a href="/dp_ProductFeed.aspx">
#                Product Feed
#               </a>
#              </li>
#              <li id="menuWhereToBuyMaintenance">
#               <a href="/dp_WhereToBuyAdministration.aspx">
#                Where To Buy Maintenance
#               </a>
#              </li>
#              <li id="menuFKey">
#               <a href="/FKey">
#                Dorman Products F-Key
#               </a>
#              </li>
#             </ul>
#             <hr class="topbanner-ruler hidden-xxs"/>
#             <div class="dist-map-area" id="divEMRP">
#              <h5>
#               Electronic Minimum Advertised Price Policy (eMAP)
#              </h5>
#              <ul>
#               <li>
#                <a href="https://static.dormanproducts.com/document/corporate/Electronic-Minimum-Advertised-Price-Policy.pdf" target="_blank">
#                 eMAP Policy
#                </a>
#               </li>
#              </ul>
#             </div>
#             <button class="btn btn-orange" onclick="window.location='/signout.aspx';">
#              Log out
#             </button>
#            </div>
#            <div class="col-xs-6 col-xxs-12">
#             <div class="dist-shopcart">
#              <h4>
#               Shopping Cart:
#              </h4>
#              <h5>
#               <span class="dist-shopcart-cat">
#                Items in Cart:
#               </span>
#              </h5>
#              <h5>
#               <span class="dist-shopcart-cat">
#                Total in Cart:
#               </span>
#               $
#              </h5>
#              <button class="btn btn-orange" onclick="window.location='/shoppingcart.aspx';">
#               Checkout
#              </button>
#             </div>
#             <hr class="topbanner-ruler hidden-xxs"/>
#             <ul>
#              <li>
#               <a href="/orderhistorysearch.aspx">
#                Order History
#               </a>
#              </li>
#              <li>
#               <a href="/expressorderform.aspx">
#                Order Form
#               </a>
#              </li>
#              <li id="menuUploadOrders">
#               <a href="/dp_UploadOrders.aspx">
#                Upload Order
#               </a>
#              </li>
#              <li id="menuUpdateMenus">
#               <a href="/dp_Menus.aspx">
#                Update Menus
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </nav>
#    </div>
#   </header>
#   <!-- top banner navigation end -->
#   <!-- menu -->
#   <div class="nav-wrapper" id="navWrap">
#    <div class="container">
#     <nav class="navbar row yamm">
#      <a class="navbar-brand" href="/">
#       <img alt="Dorman Products" class="navbar-logo img-responsive" src="//static.dormanproducts.com/images/website/homepage/dorman_logo.gif"/>
#      </a>
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#      <div class="collapse right navbar-collapse navbar-ex1-collapse">
#       <div class="cl-effect-12">
#        <ul class="nav navbar-nav pull-right">
#         <!--- what's new --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           What's New
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="whats-new">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                New Top Parts
#               </h4>
#               <div class="navbar-sublinks" id="divNewTopParts">
#                <li>
#                 <a href="/p--926-408.aspx">
#                  Torque Converter Lock-Up Solenoid
#                 </a>
#                </li>
#                <li>
#                 <a href="/p--928-581.aspx">
#                  Suspension Sway Bar Bracket Kit
#                 </a>
#                </li>
#                <li>
#                 <a href="/p--626-738.aspx">
#                  Engine Heater Hose Assembly
#                 </a>
#                </li>
#                <li>
#                 <a href="/p--819-001.aspx">
#                  Fuel Lines
#                 </a>
#                </li>
#                <li>
#                 <a href="/p--999-800.aspx">
#                  Coil Spring Bracket Repair
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/document/web/must-see-solutions_june-2023.pdf" target="_blank">
#                  View All New Products
#                 </a>
#                </li>
#               </div>
#               <h4>
#                New Product Announcements
#               </h4>
#               <div class="navbar-sublinks" id="divNewProductAnnouncements">
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#june2023">
#                  June
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#may2023">
#                  May
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#apr2023">
#                  April
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#mar2023">
#                  March
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx">
#                  View All Announcements
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                OE FIX Products
#               </h4>
#               <div class="navbar-sublinks" id="divOEFixProducts">
#                <li>
#                 <a href="/pages/products/stories/power-steering.aspx">
#                  Power Steering Pumps
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/vvt-solenoid-sprocket.aspx">
#                  VVT Solenoids
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/egt-bung-repair.aspx">
#                  EGT Sensor Bung Repair Kit
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/intake-manifold.aspx">
#                  Intake Manifold
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/oe-fix/index.aspx">
#                  Learn more about our signature innovations
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Catalogs &amp; Guides
#               </h4>
#               <div class="navbar-sublinks" id="divCatalogsAndGuides">
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v4/index.html" target="_blank">
#                  OE FIX Guide - Volume 4
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/new-solutions-catalog/index.html" target="_blank">
#                  New Solutions Catalog
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v3/index.html" target="_blank">
#                  OE FIX Guide - Volume 3
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v2/index.html" target="_blank">
#                  OE FIX Guide - Volume 2
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/catalogs/dorman.aspx">
#                  View All Catalog &amp; Guides
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Top Part Video of the Month
#             </h4>
#             <a href="/pages/videos/installs/index.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/Top-Part-Video-June-2023-Active-Grille-Shutter.jpg"/>
#             </a>
#             <h5>
#              Control the air flow. Control the cost.
#             </h5>
#             <p>
#              Dorman active grille shutters match the fit and function of the original shutters for a predictable, long-lasting repair.
#             </p>
#             <a class="btn btn-orange" href="/pages/videos/installs/index.aspx">
#              View Video
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <!--- mega menu --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Products
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="product">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                Product Categories
#               </h4>
#               <div class="navbar-sublinks" id="divProductCategories">
#                <li>
#                 <a href="/Pages/products/categories/body.aspx">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/steering.aspx">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/undercar.aspx">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/underhood.aspx">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/hardware.aspx">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.dormanhdsolutions.com" target="_blank">
#                  Heavy Duty
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Featured Products
#               </h4>
#               <div class="navbar-sublinks" id="divFeaturedProducts">
#                <li>
#                 <a href="/Pages/products/chrome-wheel-hardware/index.aspx">
#                  Chrome Wheel Hardware
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/drive-shafts/index.aspx">
#                  Drive Shafts
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/intake-manifolds/index.aspx">
#                  Intake Manifolds
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/steering-shafts/index.aspx">
#                  Steering Shafts
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/window-regulators/index.aspx">
#                  Window Regulators
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                Product Info
#               </h4>
#               <div class="navbar-sublinks" id="divProductInfo">
#                <li>
#                 <a href="/Pages/resources/catalogs/dorman.aspx">
#                  Catalogs
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/web/patents.aspx">
#                  Patents
#                 </a>
#                </li>
#                <li>
#                 <a href="/install.aspx">
#                  Install Instructions
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/cores/returns.aspx">
#                  Core Returns
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#quality">
#                  Quality
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#recalls">
#                  Recalls
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#warranty">
#                  Warranty
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/web/terms-of-sale.aspx">
#                  Terms &amp; Condition of Sale
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Product Training
#               </h4>
#               <div class="navbar-sublinks" id="divProductTraining">
#                <li>
#                 <a href="https://www.dormantrainingcenter.com" target="_blank">
#                  Dorman Training Center
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Product of the Month
#             </h4>
#             <a href="/pages/products/ccm/index.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/Product-of-the-Month-June-2023-CCM.jpg"/>
#             </a>
#             <h5>
#              Original fit, function and appearance
#             </h5>
#             <p>
#              Dorman climate control modules offer a direct, seamless repair with the convenience of plug-and-play installation.
#             </p>
#             <a class="btn btn-orange" href="/pages/products/ccm/index.aspx">
#              View Details
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <!--- mega menu end --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Videos
#          </a>
#          <ul class="nav-megamenu dropdown-menu">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                Highlighted Installation
#               </h4>
#               <div class="navbar-sublinks" id="divVideoHighlightedInstallation">
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#body">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#electronics">
#                  Electronics
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#steering">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#undercar">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#underhood">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#hardware">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx">
#                  View All Install Videos
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                Highlighted Overview
#               </h4>
#               <div class="navbar-sublinks" id="divVideoHighlightedOverview">
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#body">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#electronics">
#                  Electronics
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#steering">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#undercar">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#underhood">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#hardware">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#hd">
#                  Heavy Duty
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#oefix">
#                  OE FIX
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx">
#                  View All Info Videos
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#             <div class="row hidden-xs">
#              <div class="col-sm-11 mega-callout" id="divVideoViewAll">
#               <div class="col-sm-12">
#                <h4>
#                 Dorman Products offers hundreds of installation and informational videos.
#                </h4>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Featured Video
#             </h4>
#             <a href="/Pages/videos/info/index.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/Featured-Video-June-2023-Pentastar.jpg"/>
#             </a>
#             <h5>
#              Solutions for Pentastar V6 engines
#             </h5>
#             <p>
#              Repair solutions that save time, save money, and increase reliability.
#             </p>
#             <a class="btn btn-orange" href="/Pages/videos/info/index.aspx">
#              View Video
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li id="liMenuWhereToBuy">
#          <a href="/Pages/wheretobuy/dorman.aspx">
#           Where to Buy
#          </a>
#         </li>
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Contact
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="Ul1">
#           <div class="yamm-content">
#            <div class="nav-featured col-sm-7 hidden-xs">
#             <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/website/images/nav-warehouse.jpg" style="margin-top: 30px;"/>
#            </div>
#            <div class="col-sm-5">
#             <div class="row">
#              <div class="col-sm-12">
#               <h4 class="hidden-xs">
#                Contact Us
#               </h4>
#               <div class="navbar-sublinks" id="divContactUs">
#                <li>
#                 <a href="/Pages/forms/customer.aspx">
#                  Customer Service
#                 </a>
#                </li>
#                <li>
#                 <a class="hidden" href="/Pages/products/cores/purchases.aspx">
#                  Core Purchases
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/investor-resources/investor-contacts/default.aspx" target="_blank">
#                  Investor Relations
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/ideas.aspx">
#                  New Product Ideas
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/sales.aspx">
#                  Sales
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/support.aspx">
#                  Technical Support
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           About
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="Ul2">
#           <div class="yamm-content">
#            <div class="nav-featured col-sm-7 hidden-xs">
#             <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/website/images/nav-building.jpg" style="margin-top: 30px;"/>
#            </div>
#            <div class="col-sm-5">
#             <div class="row">
#              <div class="col-sm-12">
#               <h4 class="hidden-xs">
#                About Dorman Products
#               </h4>
#               <div class="navbar-sublinks" id="divAboutDormanProducts">
#                <li>
#                 <a href="/pages/corporate/about.aspx">
#                  About Us
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/tour/index.html" target="_blank">
#                  Virtual Tour
#                 </a>
#                </li>
#                <li>
#                 <a href="https://jobs.dormanproducts.com/" target="_blank">
#                  Careers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/home/default.aspx" target="_blank">
#                  Investor Relations
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/corporate-governance/esg/default.aspx" target="_blank">
#                  Environmental, Social &amp; Governance
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/corporate-governance/executive-management/default.aspx" target="_blank">
#                  Executive Team
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/news-and-events/default.aspx" target="_blank">
#                  Press Releases
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/corporate/suppliers.aspx">
#                  Suppliers
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/corporate/emap.aspx">
#                  eMAP Policy
#                 </a>
#                </li>
#                <li>
#                 <a href="https://shoppress.dormanproducts.com" target="_blank">
#                  Shop Press
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li class="nav-bar-no-rollover hidden-sm">
#          <div class="navbar-social">
#           <a href="https://www.facebook.com/dormanproducts" target="_blank">
#            <span aria-hidden="true" class="icon-facebook">
#            </span>
#           </a>
#           <a href="https://www.instagram.com/dormanproducts/" target="_blank">
#            <span aria-hidden="true" class="icon-instagram">
#            </span>
#           </a>
#           <a href="https://www.youtube.com/dormanproducts" target="_blank">
#            <span aria-hidden="true" class="icon-youtube-play">
#            </span>
#           </a>
#           <a href="https://www.linkedin.com/company/dorman-products" target="_blank">
#            <span aria-hidden="true" class="icon-linkedin">
#            </span>
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <!-- menu end -->
#   <!-- searchbar start -->
#   <div class="searchbar-wrap" id="searchWrap">
#    <div class="container">
#     <div class="searchbar row">
#      <div class="searchbar-header">
#       <h4>
#        Search
#        <span class="hidden-xxs">
#         Products
#        </span>
#        <a class="adv-search" href="/hcategory.aspx">
#         <span class="glyphicon glyphicon-eye-open" style="margin-right: 3px;">
#         </span>
#         VISUAL
#         <span class="hidden-xxxs">
#          SEARCH
#         </span>
#        </a>
#       </h4>
#      </div>
#      <div class="searchbar-toggle" data-target="#searchbar-ex1-collapse" data-toggle="collapse">
#       <h4>
#        Search
#        <span class="hidden-search-prod">
#         Products
#        </span>
#        <a class="adv-search" href="/hcategory.aspx">
#         <span class="glyphicon glyphicon-eye-open" style="margin-right: 3px;">
#         </span>
#         VISUAL
#         <span class="hidden-xxxs">
#          SEARCH
#         </span>
#        </a>
#       </h4>
#      </div>
#     </div>
#     <div class="searchnav row collapse searchbar-collapse" id="searchbar-ex1-collapse">
#      <div class="col-sm-12">
#       <div class="col-sm-3 search-fields" id="search-ymm">
#        <div class="form-group input-group">
#         <select class="form-control" data-placement="bottom" data-toggle="tooltip" id="SelectYear" name="SelectYear" onchange="showApplicationPopupDialog();" title="Year/Make/Model">
#          <option selected="selected" value="0">
#           Year/Make/Model
#          </option>
#          <option value="2024">
#           2024
#          </option>
#          <option value="2023">
#           2023
#          </option>
#          <option value="2022">
#           2022
#          </option>
#          <option value="2021">
#           2021
#          </option>
#          <option value="2020">
#           2020
#          </option>
#          <option value="2019">
#           2019
#          </option>
#          <option value="2018">
#           2018
#          </option>
#          <option value="2017">
#           2017
#          </option>
#          <option value="2016">
#           2016
#          </option>
#          <option value="2015">
#           2015
#          </option>
#          <option value="2014">
#           2014
#          </option>
#          <option value="2013">
#           2013
#          </option>
#          <option value="2012">
#           2012
#          </option>
#          <option value="2011">
#           2011
#          </option>
#          <option value="2010">
#           2010
#          </option>
#          <option value="2009">
#           2009
#          </option>
#          <option value="2008">
#           2008
#          </option>
#          <option value="2007">
#           2007
#          </option>
#          <option value="2006">
#           2006
#          </option>
#          <option value="2005">
#           2005
#          </option>
#          <option value="2004">
#           2004
#          </option>
#          <option value="2003">
#           2003
#          </option>
#          <option value="2002">
#           2002
#          </option>
#          <option value="2001">
#           2001
#          </option>
#          <option value="2000">
#           2000
#          </option>
#          <option value="1999">
#           1999
#          </option>
#          <option value="1998">
#           1998
#          </option>
#          <option value="1997">
#           1997
#          </option>
#          <option value="1996">
#           1996
#          </option>
#          <option value="1995">
#           1995
#          </option>
#          <option value="1994">
#           1994
#          </option>
#          <option value="1993">
#           1993
#          </option>
#          <option value="1992">
#           1992
#          </option>
#          <option value="1991">
#           1991
#          </option>
#          <option value="1990">
#           1990
#          </option>
#          <option value="1989">
#           1989
#          </option>
#          <option value="1988">
#           1988
#          </option>
#          <option value="1987">
#           1987
#          </option>
#          <option value="1986">
#           1986
#          </option>
#          <option value="1985">
#           1985
#          </option>
#          <option value="1984">
#           1984
#          </option>
#          <option value="1983">
#           1983
#          </option>
#          <option value="1982">
#           1982
#          </option>
#          <option value="1981">
#           1981
#          </option>
#          <option value="1980">
#           1980
#          </option>
#          <option value="1979">
#           1979
#          </option>
#          <option value="1978">
#           1978
#          </option>
#          <option value="1977">
#           1977
#          </option>
#          <option value="1976">
#           1976
#          </option>
#          <option value="1975">
#           1975
#          </option>
#          <option value="1974">
#           1974
#          </option>
#          <option value="1973">
#           1973
#          </option>
#          <option value="1972">
#           1972
#          </option>
#          <option value="1971">
#           1971
#          </option>
#          <option value="1970">
#           1970
#          </option>
#          <option value="1969">
#           1969
#          </option>
#          <option value="1968">
#           1968
#          </option>
#          <option value="1967">
#           1967
#          </option>
#          <option value="1966">
#           1966
#          </option>
#          <option value="1965">
#           1965
#          </option>
#          <option value="1964">
#           1964
#          </option>
#          <option value="1963">
#           1963
#          </option>
#          <option value="1962">
#           1962
#          </option>
#          <option value="1961">
#           1961
#          </option>
#          <option value="1960">
#           1960
#          </option>
#          <option value="1959">
#           1959
#          </option>
#          <option value="1958">
#           1958
#          </option>
#          <option value="1957">
#           1957
#          </option>
#          <option value="1956">
#           1956
#          </option>
#          <option value="1955">
#           1955
#          </option>
#          <option value="1954">
#           1954
#          </option>
#          <option value="1953">
#           1953
#          </option>
#          <option value="1952">
#           1952
#          </option>
#          <option value="1951">
#           1951
#          </option>
#          <option value="1950">
#           1950
#          </option>
#          <option value="1949">
#           1949
#          </option>
#          <option value="1948">
#           1948
#          </option>
#          <option value="1947">
#           1947
#          </option>
#          <option value="1946">
#           1946
#          </option>
#          <option value="1945">
#           1945
#          </option>
#          <option value="1944">
#           1944
#          </option>
#          <option value="1943">
#           1943
#          </option>
#          <option value="1942">
#           1942
#          </option>
#          <option value="1941">
#           1941
#          </option>
#          <option value="1940">
#           1940
#          </option>
#          <option value="1939">
#           1939
#          </option>
#          <option value="1938">
#           1938
#          </option>
#          <option value="1937">
#           1937
#          </option>
#          <option value="1936">
# ...
#                                 $('.thumbnail').on('click', function () { chkbordercount = 0; showOEFixBorder(); });
#                             }
#
#                             $(document).on('click touch', '.magic-thumb img, .mz-button', function () {
#                                 showVideo360OnZoom();
#                             });
#
#                             $(document).keydown(function (e) {
#                                 if (e.which == 37 || e.which == 39) {
#                                     clearZoom();
#                                 }
#                             });
#
#                             var eventMethod = window.addEventListener ? "addEventListener" : "attachEvent";
#                             var eventer = window[eventMethod];
#                             var messageEvent = eventMethod == "attachEvent" ? "onmessage" : "message";
#
#                             // Listen to message from wtb iframe
#                             eventer(messageEvent, function (e) {
#                                 var key = e.message ? "message" : "data";
#                                 var datastr = e[key];
#                                 if (datastr.length > 0 && isJson(datastr)) {
#                                     var data = JSON.parse(datastr);
#
#                                     if ((data.Area == "list panel" && data.Feature == "open filters") ||
#                                         (data.Area == "list panel" && data.Feature == "close filters") ||
#                                         (data.Area == "list panel" && data.Feature == "hide list panel") ||
#                                         (data.Area == "list panel" && data.Feature == "show list panel") ||
#                                         (data.Area == "list panel" && data.Feature.startsWith == "filter selected") ||
#                                         (data.Area == "list panel" && data.Feature.startsWith == "filter unselected")) {
#                                         GAEventItemDetailWTB("store_list_panel", data);
#                                     }
#                                     else if ((data.Area == "favorite" && data.Feature == "open favorites") ||
#                                         (data.Area == "favorite" && data.Feature == "close favorites")) {
#                                         GAEventItemDetailWTB("store_favorites_panel", data);
#                                     }
#                                     else if ((data.Area == "search" && data.Feature == "default location") ||
#                                         (data.Area == "search" && data.Feature == "location change") ||
#                                         (data.Area == "search" && data.Feature == "radius change")) {
#                                         GAEventItemDetailWTB("store_search_click", data);
#                                     }
#                                     else if ((data.Area == "map" && data.Feature.startsWith == "zoom out") ||
#                                         (data.Area == "map" && data.Feature.startsWith == "zoom in") ||
#                                         (data.Area == "map" && data.Feature.startsWith == "layout changed") ||
#                                         (data.Area == "map" && data.Feature == "full screen") ||
#                                         (data.Area == "map" && data.Feature == "exit full screen")) {
#                                         GAEventItemDetailWTB("store_map", data);
#                                     }
#                                     else if ((data.Area == "map pin" && data.Feature == "select store") ||
#                                         (data.Area == "store list" && data.Feature == "select store") ||
#                                         (data.Area == "favorite" && data.Feature == "select store")) {
#                                         GAEventItemDetailWTB("store_click", data);
#                                     }
#                                     else if ((data.Area == "map pin" && data.Feature == "add favorite") ||
#                                         (data.Area == "map pin" && data.Feature == "delete favorite") ||
#                                         (data.Area == "store list" && data.Feature == "add favorite") ||
#                                         (data.Area == "store list" && data.Feature == "delete favorite") ||
#                                         (data.Area == "favorite" && data.Feature == "add favorite") ||
#                                         (data.Area == "favorite" && data.Feature == "delete favorite")) {
#                                         GAEventItemDetailWTB("store_favorite_click", data);
#                                     }
#                                     else if ((data.Area == "map pin" && data.Feature == "phone call") ||
#                                         (data.Area == "store list" && data.Feature == "phone call") ||
#                                         (data.Area == "favorite" && data.Feature == "phone call")) {
#                                         GAEventItemDetailWTB("store_phone_click", data);
#                                     }
#                                     else if ((data.Area == "map pin" && data.Feature == "get directions") ||
#                                         (data.Area == "store list" && data.Feature == "get directions") ||
#                                         (data.Area == "favorite" && data.Feature == "get directions")) {
#                                         GAEventItemDetailWTB("store_direction_click", data);
#                                     }
#                                 }
#                             }, false);
#
#                         });
#
#                     });
#             });
#             //-->
#     </script>
#     <input id="hdnVICURL" name="hdnVICURL" type="hidden" value="http://gcommercebridge-vic.cloudapp.net/search/search.html"/>
#     <input id="hdnWhereToBuyUrl" name="hdnWhereToBuyUrl" type="hidden" value="https://wtbmap.dormanproducts.com?d=1"/>
#     <input id="hdnfinditbtn" name="hdnfinditbtn" type="hidden" value="false"/>
#     <input id="hdnHDPart" name="hdnHDPart" type="hidden" value="true"/>
#     <div id="loadingoverlay" style="display: none">
#      <img alt="Loading" id="loadingImage" src="//static.dormanproducts.com/images/website/images/ajaxloader.gif"/>
#      <br/>
#      Loading...
#     </div>
#    </form>
#    <!-- CONTENTS END -->
#   </div>
#   <!-- footer start -->
#   <footer class="footer" id="footer">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-3 col-sm-4 col-xs-6">
#       <div class="footerheadline">
#        <h4>
#         Distributors
#        </h4>
#       </div>
#       <ul>
#        <li>
#         <a href="/signin.aspx">
#          Login
#         </a>
#        </li>
#        <li>
#         <a href="/createaccount.aspx">
#          Register
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Product Training
#        </h4>
#       </div>
#       <ul id="ulProductTraining">
#        <li>
#         <a href="https://www.dormantrainingcenter.com/">
#          Dorman Training Center
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Product Info
#        </h4>
#       </div>
#       <ul id="ulProductInfo">
#        <li>
#         <a href="/Pages/resources/catalogs/dorman.aspx">
#          Catalogs
#         </a>
#        </li>
#        <li>
#         <a href="/pages/forms/product-registration.aspx">
#          Product Registration
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/patents.aspx">
#          Patents
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/cores/returns.aspx">
#          Core Returns
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#quality">
#          Quality
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#recalls">
#          Recalls
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#warranty">
#          Warranty
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/terms-of-sale.aspx">
#          Terms &amp; Condition of Sale
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-md-3 col-sm-4 col-xs-6">
#       <div class="footerheadline">
#        <h4>
#         Contact
#        </h4>
#       </div>
#       <ul id="ulContact">
#        <li>
#         <a href="/Pages/forms/customer.aspx">
#          Customer Service
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/ideas.aspx">
#          New Product Ideas
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/sales.aspx">
#          Sales
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/support.aspx">
#          Technical Support
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Corporate Info
#        </h4>
#       </div>
#       <ul id="ulCorporateInfo">
#        <li>
#         <a href="/pages/corporate/about.aspx">
#          About Dorman
#         </a>
#        </li>
#        <li>
#         <a href="/pages/tour/index.html" target="_blank">
#          Virtual Tour
#         </a>
#        </li>
#        <li>
#         <a href="https://jobs.dormanproducts.com/" target="_blank">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/news-and-events/default.aspx" target="_blank">
#          Press Releases
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/home/default.aspx" target="_blank">
#          Investor Relations
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/corporate-governance/esg/default.aspx" target="_blank">
#          Environmental, Social &amp; Governance
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/corporate-governance/executive-management/default.aspx" target="_blank">
#          Executive Team
#         </a>
#        </li>
#        <li>
#         <a href="/pages/corporate/suppliers.aspx">
#          Suppliers
#         </a>
#        </li>
#        <li>
#         <a class="hidden" href="/pages/corporate/emap.aspx">
#          eMAP Policy
#         </a>
#        </li>
#        <li>
#         <a href="https://shoppress.dormanproducts.com" target="_blank">
#          Shop Press
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-md-3 hidden-sm hidden-xs">
#       <div class="footerheadline">
#        <h4>
#         Site Info
#        </h4>
#       </div>
#       <ul id="ulSiteInfo">
#        <li>
#         <a href="/Pages/web/sitemap.aspx">
#          Site Map
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/terms.aspx">
#          Web Terms &amp; Conditions
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/privacy.aspx">
#          Privacy
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Aftermarket Membership
#        </h4>
#       </div>
#       <p>
#        Dorman Products is a proud member of the following aftermarket organizations:
#       </p>
#       <div class="row">
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.autocare.org" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/autocare-assocation.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.carcare.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/bcca.jpg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.aftermarketsuppliers.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/aasa.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.cawa.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/cawa.jpg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-3 col-sm-4 btftk-clear" id="divNewProductAlert">
#       <div class="footerheadline">
#        <h4>
#         Email Newsletters Signup
#        </h4>
#       </div>
#       <p>
#        Never miss a new solution. Get regular updates on new innovations and repair tips.
#       </p>
#       <p>
#        <a class="btn btn-orange" href="/Pages/forms/btftk.aspx?origin=footersignup">
#         Sign Up Now
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- footer end -->
#   <!-- copyright bottom start -->
#   <div class="bottom" id="copyrightWrap">
#    <div class="container">
#     <div class="row">
#      <section class="copyright col-sm-6">
#       <p>
#        ©
#        <a href="/default.aspx">
#         Dorman Products
#        </a>
#        . All rights reserved.
#       </p>
#      </section>
#      <section class="col-sm-6 footer-social hidden-xs">
#       <p>
#        Follow Us:
#        <a href="https://www.facebook.com/dormanproducts" target="_blank">
#         <span aria-hidden="true" class="icon-facebook">
#         </span>
#        </a>
#        <a href="https://www.instagram.com/dormanproducts/" target="_blank">
#         <span aria-hidden="true" class="icon-instagram">
#         </span>
#        </a>
#        <a href="https://www.youtube.com/dormanproducts" target="_blank">
#         <span aria-hidden="true" class="icon-youtube-play">
#         </span>
#        </a>
#        <a href="https://www.linkedin.com/company/dorman-products" target="_blank">
#         <span aria-hidden="true" class="icon-linkedin">
#         </span>
#        </a>
#        <a href="javascript:scrollToTop()" id="topPageBtn" title="top of page">
#         <span class="topofpage">
#          <span aria-hidden="true" class="icon-up-open topofpage-icon">
#          </span>
#          <br/>
#          <span class="topofpage-text">
#           TOP
#          </span>
#         </span>
#        </a>
#       </p>
#      </section>
#     </div>
#    </div>
#   </div>
#   <!-- copyright bottom end -->
#   <!-- New Product Idea Modal -->
#   <!-- new product idea modal end -->
#   <!-- Modal Recent Activity -->
#   <div aria-labelledby="windowTitleLabel" class="modal fade" id="recentactivityModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        <span aria-hidden="true" class="glyphicon glyphicon-time">
#        </span>
#        <span id="recentactivityDialogLabel">
#         Recent Activities
#        </span>
#       </h4>
#      </div>
#      <div class="modal-body iframe">
#       <div id="recentactivityLoading" style="display:block;">
#        <div class="progress" style="height:25px;">
#         <div class="progress-bar progress-bar-striped active" style="width:100%">
#         </div>
#        </div>
#       </div>
#       <iframe class="embed-responsive-item" id="recentactivityIFrame" style="border:0px; width:100%; height: 100%;display:none;">
#       </iframe>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="/scripts/livechat.js?d=20190905" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-9Z678K7TDD">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'G-9Z678K7TDD', {'site_speed_sample_rate': 100,
# 'custom_map': {
# 'dimension1': 'Logged_In',
# 'dimension2': 'Dorman_Account_Number',
# 'dimension3': 'Store_Number'}
# });
# gtag('event', 'login', {'Logged_In': 'No'});
# gtag('config', 'AW-997247862');
#   </script>
#  </body>
# </html>

# %%
with open('./part.html', 'w', encoding='utf-8') as file:
    file.write(str(soup))

# %%
from lxml import etree

# %%
html = etree.HTML(str(soup))

oe = ';'.join(html.xpath('//section[@id="productOE"]/descendant::*/th[@scope="row"]/text()'))

oe
# Out:
# '15862656'

# %%
if len(html.xpath('//input[@id="hidfDetailApp"]/@value')) == 0:
    vehicle_url = ''
else:
    vehicle_url = 'https://www.dormanproducts.com/' + html.xpath('//input[@id="hidfDetailApp"]/@value')[0]

vehicle_url
# Out:
# ''

# %%
src = html.xpath('//img[@id="imgProductMain"]/@src')[0]

src
# Out:
# 'https://static.dormanproducts.com/images/product/icon/645-702-007.JPG'

# %%
df_temp = pd.DataFrame([{'Url': list_url[i],
                         'OE_Numbers': oe,
                         'vehicle_url': vehicle_url,
                         'Src': src,
                         'status': 'ok'}])

df_temp

# %%
list_row = html.xpath('//section[@id="productSpec"]/descendant::tr')
for row in list_row:
    df_temp[row.xpath('./th')[0].text.strip()[:-1].lower()] = row.xpath('./td')[0].text
    
df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#                                                  Url OE_Numbers vehicle_url  \
# 0  https://www.dormanproducts.com/p-50806-84645.a...   15862656
#
#                                                  Src status  \
# 0  https://static.dormanproducts.com/images/produ...     ok
#
#   Overall Length (In) Package Contents Package Quantity Packaging Type  \
# 0             1.57 in   7-wire Harness                1      Clamshell
#
#   Terminal Gender Terminal Material Terminal Type Wire Gauge Measurement  \
# 0          Female             Metal           Pin                 14 ga.
#
#   Wire Quantity
# 0             7
