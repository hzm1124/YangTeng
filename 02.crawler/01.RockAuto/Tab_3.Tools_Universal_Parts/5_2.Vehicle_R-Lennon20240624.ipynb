# %%
param_date = '20240623'

# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel(f'./{param_date}/part.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_.drop_duplicates(['JOIN_PTPKPNCN'], keep='first', ignore_index=True)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'
        for b in range(666):
            try:
                data = {'func': 'getbuyersguide',
                        'payload': f'''{{"partData":{{"listing_data_essential":{{"parttype":"{input_.loc[a, 'Part PartType']}","partkey":"{input_.loc[a, 'PartKey']}"}},"listing_data_supplemental":{{"partnumber":"{input_.loc[a, 'PartNumber']}","catalogname":"{input_.loc[a, 'CatalogName']}"}}}}}}''',
                        'partsearch[manufacturer][partsearch_007]': input_.loc[a, 'CatalogName'],
                        'api_json_request': '1'}

                resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                     data=data,
                                     headers=UA.get_User_Agent_Requests(),
                                     proxies=Proxy.get_Proxy_Requests()).text

                # = = = = = = = = = = = = = = =

                json_ = json.loads(resp)

                # = = = = = = = = = = = = = = =

                soup = BeautifulSoup(json_['buyersguidepieces']['body'], 'lxml')
                html = etree.HTML(str(soup))

                # = = = = = = = = = = = = = = =

                list_tr = html.xpath('//tr')

                # = = = = = = = = = = = = = = =

                dict_vehicle = {}
                for i in range(len(list_tr)):
                    dict_vehicle[str(i)] = {}
                    list_td = [td.strip() for td in list_tr[i].xpath('./td/text()')]
                    for j in range(len(list_td)):
                        dict_vehicle[str(i)][str(j)] = list_td[j]

                json_vehicle = json.dumps(dict_vehicle)

                # = = = = = = = = = = = = = = =

                vehicle = 'No applications found.' if json_['buyersguidepieces']['body'].strip() == 'No applications found.' else ''
                for i in dict_vehicle:
                    for j in dict_vehicle[i]:
                        vehicle += dict_vehicle[i][j] + ' '
                    vehicle = vehicle.strip() + '\n'

                vehicle = vehicle.strip()

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                                         'Json_Vehicle': json_vehicle,
                                         'Vehicle': vehicle}])

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'

                # = = = = = = = = = = = = = = =

                break
            except:
                continue

        # = = = = = = = = = = = = = = =

        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'PartType': input_.loc[a, 'PartType'],
                                     'Tab Url': input_.loc[a, 'Tab Url'],
                                     'CatalogName': input_.loc[a, 'CatalogName'],
                                     'PartNumber': input_.loc[a, 'PartNumber'],
                                     'Part PartType': input_.loc[a, 'Part PartType'],
                                     'PartKey': input_.loc[a, 'PartKey'],
                                     'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                                     'Url': input_.loc[a, 'Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        print(f'''[状态：{crawler_status}，尝试次数：{b+1:3d}] - {input_.loc[a, 'JOIN_PTPKPNCN']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(15):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if len(output_correct) != 0:
    output_correct = output_correct.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_correct.to_excel(f'''./{param_date}/vehicle-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if len(output_error) != 0:
    output_error = output_error.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_error.to_excel(f'./{param_date}/vehicle_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：24720
#
# [状态：ok，尝试次数：  4] - 1002098;15104209;H2;ROCKAUTO
# [剩余数量：24705] - [当前时间：13:49:29]
#
# [状态：ok，尝试次数：  1] - 256;14919165;T3;ROCKAUTO
# [剩余数量：24704] - [当前时间：13:49:29]
#
# [状态：ok，尝试次数：  5] - 131;15108565;B3;ROCKAUTO
# [剩余数量：24703] - [当前时间：13:49:29]
#
# [状态：ok，尝试次数： 11] - 1002098;15104205;H1;ROCKAUTO
# [剩余数量：24702] - [当前时间：13:49:29]
#
# [状态：ok，尝试次数：  8] - 256;14922129;T5;ROCKAUTO
# [剩余数量：24701] - [当前时间：13:49:30]
#
# [状态：ok，尝试次数： 20] - 131;10671829;BLACKHAT;ROCKAUTO
# [剩余数量：24700] - [当前时间：13:49:30]
#
# [状态：ok，尝试次数：  2] - 256;15001073;T6;ROCKAUTO
# [剩余数量：24699] - [当前时间：13:49:30]
#
# [状态：ok，尝试次数：  9] - 131;15108561;B2;ROCKAUTO
# [剩余数量：24698] - [当前时间：13:49:30]
#
# [状态：ok，尝试次数： 16] - 256;14922125;T4;ROCKAUTO
# [剩余数量：24697] - [当前时间：13:49:30]
#
# [状态：ok，尝试次数：  3] - 260;1285405;GIFTCERTVAR;ROCKAUTO
# [剩余数量：24696] - [当前时间：13:49:31]
#
# [状态：ok，尝试次数： 32] - 256;15138773;T9;ROCKAUTO
# [剩余数量：24695] - [当前时间：13:49:31]
#
# [状态：ok，尝试次数： 25] - 256;15138777;T10;ROCKAUTO
# [剩余数量：24694] - [当前时间：13:49:31]
#
# [状态：ok，尝试次数： 41] - 256;15521065;T3C;ROCKAUTO
# [剩余数量：24693] - [当前时间：13:49:31]
#
# [状态：ok，尝试次数： 44] - 256;10512261;T2;ROCKAUTO
# [剩余数量：24692] - [当前时间：13:49:31]
#
# [状态：ok，尝试次数： 53] - 131;15108557;B1;ROCKAUTO
# [剩余数量：24691] - [当前时间：13:49:32]
#
# [状态：ok，尝试次数： 56] - 256;15138781;T11;ROCKAUTO
# [剩余数量：24690] - [当前时间：13:49:32]
#
# [状态：ok，尝试次数：  7] - 1001191;2961354;LANYARD;ROCKAUTO
# [剩余数量：24689] - [当前时间：13:49:32]
#
# [状态：ok，尝试次数： 17] - 260;368851;GIFTCERT75;ROCKAUTO
# [剩余数量：24688] - [当前时间：13:49:33]
#
# [状态：ok，尝试次数：  9] - 260;368852;GIFTCERT100;ROCKAUTO
# [剩余数量：24687] - [当前时间：13:49:33]
#
# [状态：ok，尝试次数：  7] - 1001187;3472857;BUMPERDECAL2;ROCKAUTO
# [剩余数量：24686] - [当前时间：13:49:33]
#
# [状态：ok，尝试次数： 11] - 1001187;2867487;WINDOWDECAL;ROCKAUTO
# [剩余数量：24685] - [当前时间：13:49:33]
#
# [状态：ok，尝试次数：  8] - 1001187;4170858;DECALCOMBO3;ROCKAUTO
# [剩余数量：24684] - [当前时间：13:49:34]
#
# [状态：ok，尝试次数： 41] - 260;368849;GIFTCERT25;ROCKAUTO
# [剩余数量：24683] - [当前时间：13:49:34]
#
# [状态：ok，尝试次数：  4] - 1001344;101271;6013;GATES
# [剩余数量：24682] - [当前时间：13:49:34]
#
# [状态：ok，尝试次数： 32] - 1001187;2867484;BUMPERDECAL;ROCKAUTO
# [剩余数量：24681] - [当前时间：13:49:34]
#
# [状态：ok，尝试次数： 43] - 256;15521069;T3R;ROCKAUTO
# [剩余数量：24680] - [当前时间：13:49:35]
#
# [状态：ok，尝试次数： 32] - 1001187;2867490;DECALCOMBO;ROCKAUTO
# [剩余数量：24679] - [当前时间：13:49:35]
#
# [状态：ok，尝试次数：104] - 256;9097025;T1;ROCKAUTO
# [剩余数量：24678] - [当前时间：13:49:35]
#
# [状态：ok，尝试次数： 31] - 1001187;3603579;DECALCOMBO2;ROCKAUTO
# [剩余数量：24677] - [当前时间：13:49:35]
#
# [状态：ok，尝试次数： 16] - 1001344;12872429;66G3081;GATES
# [剩余数量：24676] - [当前时间：13:49:36]
#
# [状态：ok，尝试次数：  9] - 1001344;12873173;77G3158;GATES
# [剩余数量：24675] - [当前时间：13:49:36]
#
# [状态：ok，尝试次数：  8] - 1000000;1272469;MAGPACK;ROCKAUTO
# [剩余数量：24674] - [当前时间：13:49:36]
#
# [状态：ok，尝试次数： 26] - 1001344;12873537;94G3020;GATES
# [剩余数量：24673] - [当前时间：13:49:36]
#
# [状态：ok，尝试次数： 15] - 1001344;4970703;95G3021;GATES
# [剩余数量：24672] - [当前时间：13:49:36]
#
# [状态：ok，尝试次数：  7] - 1001521;12871565;01G2748;GATES
# [剩余数量：24671] - [当前时间：13:49:37]
#
# [状态：ok，尝试次数：  4] - 1001521;12871569;02G3470;GATES
# [剩余数量：24670] - [当前时间：13:49:37]
#
# [状态：ok，尝试次数： 54] - 1001344;101270;6012;GATES
# [剩余数量：24669] - [当前时间：13:49:38]
#
# [状态：ok，尝试次数： 10] - 1001344;12873161;71G2776;GATES
# [剩余数量：24668] - [当前时间：13:49:38]
#
# [状态：ok，尝试次数： 66] - 256;15138769;T8;ROCKAUTO
# [剩余数量：24667] - [当前时间：13:49:39]
#
# [状态：ok，尝试次数： 15] - 1001521;4970370;03G3470;GATES
# [剩余数量：24666] - [当前时间：13:49:39]
#
# [状态：ok，尝试次数：  2] - 1001356;4784736;HP2007;DAYCO
# [剩余数量：24665] - [当前时间：13:49:39]
#
# [状态：ok，尝试次数： 45] - 1001344;4970697;73G2644;GATES
# [剩余数量：24664] - [当前时间：13:49:39]
#
# [状态：ok，尝试次数： 57] - 1001344;12873177;80G2949;GATES
# [剩余数量：24663] - [当前时间：13:49:39]
#
# [状态：ok，尝试次数：  4] - 1001346;4784985;HP2000;DAYCO
# [剩余数量：24662] - [当前时间：13:49:40]
#
# [状态：ok，尝试次数： 68] - 1001344;12873529;93G3499;GATES
# [剩余数量：24661] - [当前时间：13:49:40]
#
# [状态：ok，尝试次数： 18] - 1001346;4785048;HP2027;DAYCO
# [剩余数量：24660] - [当前时间：13:49:40]
#
# [状态：ok，尝试次数：128] - 260;368850;GIFTCERT50;ROCKAUTO
# [剩余数量：24659] - [当前时间：13:49:40]
#
# [状态：ok，尝试次数： 31] - 1001346;4785027;HP2017;DAYCO
# [剩余数量：24658] - [当前时间：13:49:40]
#
# [状态：ok，尝试次数： 37] - 1001346;4785003;HP2009;DAYCO
# [剩余数量：24657] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数： 32] - 1001346;5015469;13G3218;GATES
# [剩余数量：24656] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数： 12] - 1001346;1146263;PL30069;GATES
# [剩余数量：24655] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数： 68] - 256;15138765;T7;ROCKAUTO
# [剩余数量：24654] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数： 11] - 1001346;4970373;11G3218;GATES
# [剩余数量：24653] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数：  2] - 1001352;5417868;XTX2255;DAYCO
# [剩余数量：24652] - [当前时间：13:49:41]
#
# [状态：ok，尝试次数： 59] - 1001356;4776978;27GBS912;CONTINENTAL
# [剩余数量：24651] - [当前时间：13:49:42]
#
# [状态：ok，尝试次数： 14] - 1001352;5015472;19C3218;GATES
# [剩余数量：24650] - [当前时间：13:49:42]
#
# [状态：ok，尝试次数： 86] - 1001344;101322;6354;GATES
# [剩余数量：24649] - [当前时间：13:49:42]
#
# [状态：ok，尝试次数：  6] - 1001349;4784997;HP2005;DAYCO
# [剩余数量：24648] - [当前时间：13:49:43]
#
# [状态：ok，尝试次数： 11] - 1001352;12872293;48C4867;GATES
# [剩余数量：24647] - [当前时间：13:49:43]
#
# [状态：ok，尝试次数： 12] - 1001352;4970379;19G3218;GATES
# [剩余数量：24646] - [当前时间：13:49:43]
#
# [状态：ok，尝试次数：  3] - 1001352;12872305;48G4867;GATES
# [剩余数量：24645] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数：  8] - 1001352;4785048;HP2027;DAYCO
# [剩余数量：24644] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数：  1] - 1001349;4784913;XTX2240;DAYCO
# [剩余数量：24643] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数：  8] - 1001349;4785000;HP2008;DAYCO
# [剩余数量：24642] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数： 40] - 1001352;4784901;XTX2217;DAYCO
# [剩余数量：24641] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数： 11] - 1001349;4785024;HP2016;DAYCO
# [剩余数量：24640] - [当前时间：13:49:44]
#
# [状态：ok，尝试次数： 41] - 1001352;5015538;46G3596;GATES
# [剩余数量：24639] - [当前时间：13:49:45]
#
# [状态：ok，尝试次数： 18] - 1001352;12872325;48R4867;GATES
# [剩余数量：24638] - [当前时间：13:49:45]
#
# [状态：ok，尝试次数： 16] - 1001349;12871589;19C3450;GATES
# [剩余数量：24637] - [当前时间：13:49:46]
#
# [状态：ok，尝试次数： 10] - 1001349;101269;6007;GATES
# [剩余数量：24636] - [当前时间：13:49:46]
#
# [状态：ok，尝试次数： 27] - 1001349;101320;6316;GATES
# [剩余数量：24635] - [当前时间：13:49:46]
#
# [状态：ok，尝试次数： 20] - 1001346;4784919;XTX2243;DAYCO
# [剩余数量：24634] - [当前时间：13:49:46]
#
# [状态：ok，尝试次数： 89] - 1001346;5015466;13C3218;GATES
# [剩余数量：24633] - [当前时间：13:49:47]
#
# [状态：ok，尝试次数：  6] - 1001349;4784994;HP2004;DAYCO
# [剩余数量：24632] - [当前时间：13:49:47]
#
# [状态：ok，尝试次数： 59] - 1001349;4970385;19G3332;GATES
# [剩余数量：24631] - [当前时间：13:49:47]
#
# [状态：ok，尝试次数： 27] - 1001349;101318;6314;GATES
# [剩余数量：24630] - [当前时间：13:49:48]
#
# [状态：ok，尝试次数：  8] - 1001349;4785036;HP2020;DAYCO
# [剩余数量：24629] - [当前时间：13:49:48]
#
# [状态：ok，尝试次数： 33] - 1001349;4784574;32GBS1002;CONTINENTAL
# [剩余数量：24628] - [当前时间：13:49:48]
#
# [状态：ok，尝试次数： 46] - 1001349;12871621;20G5016;GATES
# [剩余数量：24627] - [当前时间：13:49:48]
#
# [状态：ok，尝试次数：  1] - 1001349;4970388;19G3982;GATES
# [剩余数量：24626] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数： 14] - 1001349;4785012;HP2012;DAYCO
# [剩余数量：24625] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数： 27] - 1001349;4784991;HP2003;DAYCO
# [剩余数量：24624] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数： 13] - 1001349;4785009;HP2011;DAYCO
# [剩余数量：24623] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数：  1] - 1001349;4970301;19C3982;GATES
# [剩余数量：24622] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数：  4] - 1001349;4970391;19G3982E;GATES
# [剩余数量：24621] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数： 47] - 1001349;4785018;HP2014;DAYCO
# [剩余数量：24620] - [当前时间：13:49:49]
#
# [状态：ok，尝试次数： 57] - 1001349;4785051;HP2028;DAYCO
# [剩余数量：24619] - [当前时间：13:49:50]
#
# [状态：ok，尝试次数：  1] - 1001349;4784811;HPX2239;DAYCO
# [剩余数量：24618] - [当前时间：13:49:50]
#
# [状态：ok，尝试次数： 20] - 1001349;4784790;HPX2203;DAYCO
# [剩余数量：24617] - [当前时间：13:49:50]
#
# [状态：ok，尝试次数： 10] - 1001349;12871601;19R4022;GATES
# [剩余数量：24616] - [当前时间：13:49:50]
#
# [状态：ok，尝试次数： 47] - 1001349;4785039;HP2021;DAYCO
# [剩余数量：24615] - [当前时间：13:49:51]
#
# [状态：ok，尝试次数： 13] - 1001349;4970304;19C4022;GATES
# [剩余数量：24614] - [当前时间：13:49:51]
#
# [状态：ok，尝试次数：  6] - 1001546;12871609;20C4022;GATES
# [剩余数量：24613] - [当前时间：13:49:51]
#
# [状态：ok，尝试次数： 14] - 1001546;4970403;20G4022;GATES
# [剩余数量：24612] - [当前时间：13:49:51]
#
# [状态：ok，尝试次数： 21] - 1001349;4784808;HPX2237;DAYCO
# [剩余数量：24611] - [当前时间：13:49:52]
#
# [状态：ok，尝试次数：159] - 1001346;4970298;11C3218;GATES
# [剩余数量：24610] - [当前时间：13:49:52]
#
# [状态：ok，尝试次数： 30] - 1001349;4784910;XTX2239;DAYCO
# [剩余数量：24609] - [当前时间：13:49:52]
#
# [状态：ok，尝试次数： 29] - 1001546;4970406;20G4022E;GATES
# [剩余数量：24608] - [当前时间：13:49:53]
#
# [状态：ok，尝试次数：  2] - 1001354;12871605;20C3596;GATES
# [剩余数量：24607] - [当前时间：13:49:53]
#
# [状态：ok，尝试次数： 24] - 1001354;4970421;23G3805;GATES
# [剩余数量：24606] - [当前时间：13:49:53]
#
# [状态：ok，尝试次数： 11] - 1001354;12871649;23C3856;GATES
# [剩余数量：24605] - [当前时间：13:49:53]
#
# [状态：ok，尝试次数： 28] - 1001354;12871661;23G3856;GATES
# [剩余数量：24604] - [当前时间：13:49:54]
#
# [状态：ok，尝试次数： 46] - 1001354;4785003;HP2009;DAYCO
# [剩余数量：24603] - [当前时间：13:49:54]
#
# [状态：ok，尝试次数： 13] - 1001354;4970310;23C3836;GATES
# [剩余数量：24602] - [当前时间：13:49:54]
#
# [状态：ok，尝试次数： 17] - 1001354;12871669;23R3856;GATES
# [剩余数量：24601] - [当前时间：13:49:55]
#
# [状态：ok，尝试次数： 29] - 1001349;12871597;19R3982;GATES
# [剩余数量：24600] - [当前时间：13:49:55]
#
# [状态：ok，尝试次数： 84] - 1001349;12871617;20G4699;GATES
# [剩余数量：24599] - [当前时间：13:49:55]
#
# [状态：ok，尝试次数： 18] - 1001354;4970424;23G3836;GATES
# [剩余数量：24598] - [当前时间：13:49:55]
#
# [状态：ok，尝试次数：  3] - 1001354;4970412;20G4272;GATES
# [剩余数量：24597] - [当前时间：13:49:56]
#
# [状态：ok，尝试次数： 21] - 1001354;4777059;31GBS1072;CONTINENTAL
# [剩余数量：24596] - [当前时间：13:49:56]
#
# [状态：ok，尝试次数： 45] - 1001354;4784997;HP2005;DAYCO
# [剩余数量：24595] - [当前时间：13:49:56]
#
# [状态：ok，尝试次数： 27] - 1001354;4785042;HP2025;DAYCO
# [剩余数量：24594] - [当前时间：13:49:56]
#
# [状态：ok，尝试次数： 83] - 1001349;4970397;19G4022;GATES
# [剩余数量：24593] - [当前时间：13:49:57]
#
# [状态：ok，尝试次数： 13] - 1001354;4785045;HP2026;DAYCO
# [剩余数量：24592] - [当前时间：13:49:57]
#
# [状态：ok，尝试次数： 49] - 1001354;12871625;21C3636;GATES
# [剩余数量：24591] - [当前时间：13:49:57]
#
# [状态：ok，尝试次数： 54] - 1001349;4970409;20G4154;GATES
# [剩余数量：24590] - [当前时间：13:49:57]
#
# [状态：ok，尝试次数：  2] - 1001354;5545647;23G4057;GATES
# [剩余数量：24589] - [当前时间：13:49:58]
#
# [状态：ok，尝试次数：  5] - 1001354;4785060;HP2031;DAYCO
# [剩余数量：24588] - [当前时间：13:49:58]
#
# [状态：ok，尝试次数： 15] - 1001354;4784922;XTX2244;DAYCO
# [剩余数量：24587] - [当前时间：13:49:58]
#
# [状态：ok，尝试次数：  4] - 1001345;101317;6312;GATES
# [剩余数量：24586] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 26] - 1001354;12871641;21R4140;GATES
# [剩余数量：24585] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 23] - 1001354;4785057;HP2030;DAYCO
# [剩余数量：24584] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 24] - 1001354;5417865;XTX2254;DAYCO
# [剩余数量：24583] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 22] - 1001354;12871677;23R4340;GATES
# [剩余数量：24582] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 62] - 1001354;4970433;23G4340;GATES
# [剩余数量：24581] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数：178] - 1001349;4784793;HPX2204;DAYCO
# [剩余数量：24580] - [当前时间：13:49:59]
#
# [状态：ok，尝试次数： 15] - 1001345;4970451;26G3596;GATES
# [剩余数量：24579] - [当前时间：13:50:00]
#
# [状态：ok，尝试次数： 39] - 1001354;12871637;21G4289;GATES
# [剩余数量：24578] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数：  7] - 1001354;4970400;20G3982;GATES
# [剩余数量：24577] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数： 63] - 1001354;12871653;23C4057;GATES
# [剩余数量：24576] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数：  7] - 1001345;12871721;25R4108;GATES
# [剩余数量：24575] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数： 14] - 1001345;4970436;24G3884;GATES
# [剩余数量：24574] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数：  7] - 1001345;12871713;25G4108;GATES
# [剩余数量：24573] - [当前时间：13:50:01]
#
# [状态：ok，尝试次数： 23] - 1001345;12871753;26G4829;GATES
# [剩余数量：24572] - [当前时间：13:50:01]
