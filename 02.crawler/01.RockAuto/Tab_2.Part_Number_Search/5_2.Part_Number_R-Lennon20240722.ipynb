# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
param_date = '20240726'

# %%
import os

list_file = sorted(list(os.walk(f'./{param_date}/4.type_2'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['group_1.Apparel & Gifts.xlsx',
#  'group_10.Electrical-Switch & Relay.xlsx',
#  'group_11.Engine.xlsx',
#  'group_12.Exhaust & Emission.xlsx',
#  'group_13.Fuel & Air.xlsx',
#  'group_14.Garage Equipment.xlsx',
#  'group_15.Hardware.xlsx',
#  'group_16.Heat & Air Conditioning.xlsx',
#  'group_17.Hoses%2FLines & Clamps.xlsx',
#  'group_18.Ignition.xlsx',
#  'group_19.Interior.xlsx',
#  'group_2.Belt Drive.xlsx',
#  'group_20.Literature.xlsx',
#  'group_21.Steering.xlsx',
#  'group_22.Suspension.xlsx',
#  'group_23.Transmission-Automatic.xlsx',
#  'group_24.Transmission-Manual.xlsx',
#  'group_25.Wheel.xlsx',
#  'group_26.Wiper & Washer.xlsx',
#  'group_3.Body & Lamp Assembly.xlsx',
#  'group_4.Brake & Wheel Hub.xlsx',
#  'group_5.Cooling System.xlsx',
#  'group_6.Drivetrain.xlsx',
#  'group_7.Electrical.xlsx',
#  'group_8.Electrical-Bulb & Socket.xlsx',
#  'group_9.Electrical-Connector.xlsx']

# %%
for file in list_file[list_file.index('group_2.Belt Drive.xlsx'):]:

    # = = = = = = = = = = = = = = =

    import pandas as pd

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./{param_date}/4.type_2/{file}',
                           header=0,
                           dtype=str).fillna('')

    input_['Group No'] = input_['Group No'].astype(int)
    input_['Type No'] = input_['Type No'].astype(int)
    input_['Manufacturer No'] = input_['Manufacturer No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =

    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            import requests

            import sys
            sys.path.append('../../00.Tools')
            from crawler_configuration import get_header, get_proxy

            from bs4 import BeautifulSoup
            from lxml import etree

            import re

            try:
                b = 0
                while True:

                    while True:
                        b += 1
                        try:
                            resp = requests.get(input_.loc[a, 'Tab 2 Url'],
                                                headers=get_header(),
                                                proxies=get_proxy(),
                                                timeout=(10, 10))
                            break
                        except:
                            continue

                    if resp.status_code == 500:
                        break
                    elif resp.status_code == 200:
                        soup = BeautifulSoup(resp.text, 'lxml')
                        html = etree.HTML(str(soup))
                        try:
                            title = re.sub(r' +', ' ', html.xpath('//div[@id="nav_o[1]"]/div[@class="inner"]/div/div[@style="display: inline-block; padding: 0em 5em 0em 5em; "]/text()')[0]).strip()

                            if html.xpath('//select[@id="manufacturer_partsearch_007"]/option[@selected]/@value')[0] == input_.loc[a, 'Manufacturer'] and html.xpath('//select[@id="partgroup_partsearch_007"]/option[@selected]/@value')[0] == input_.loc[a, 'Group'] and html.xpath('//select[@id="parttype_partsearch_007"]/option[@selected]/@value')[0] == input_.loc[a, 'Type Code'] and html.xpath('//select[@id="parttype_partsearch_007"]/option[@selected]/text()')[0] == input_.loc[a, 'Type'] or re.sub(r' +', ' ', f'''{input_.loc[a, 'Manufacturer']} {input_.loc[a, 'Type']} Part Numbers''').strip() == title:
                                break
                        except:
                            continue

                # = = = = = = = = = = = = = = =

                list_json = html.xpath('//div[@id="navchildren[1]"]/div[contains(@id, "nav[")]/input[contains(@id, "jsn[")]/@value')

                # = = = = = = = = = = = = = = =

                import json

                list_part_number = [json.loads(json_)['partnumber'] for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_url = [f'https://www.rockauto.com{href.strip()}' for href in html.xpath('//div[@id="navchildren[1]"]/div[contains(@id, "nav[")]/div[contains(@id, "nav_o[")]/div/table/tr/td[@class="nlabel nlbl-docolumns"]/a/@href')]

                # = = = = = = = = = = = = = = =

                if not list_part_number:
                    raise

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'Group No': input_.loc[a, 'Group No'],
                                        'Group': input_.loc[a, 'Group'],
                                        'Type No': input_.loc[a, 'Type No'],
                                        'Type': input_.loc[a, 'Type'],
                                        'Type Code': input_.loc[a, 'Type Code'],
                                        'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                                        'Manufacturer': input_.loc[a, 'Manufacturer'],
                                        'Tab 2 Url': input_.loc[a, 'Tab 2 Url'],
                                        'SKU Count': len(list_part_number),
                                        'Part No': [i+1 for i in range(len(list_part_number))],
                                        'Part Number': list_part_number,
                                        'Url': list_url})

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                if crawler_status == 'error':
                    df_temp = pd.DataFrame([{'Group No': input_.loc[a, 'Group No'],
                                             'Group': input_.loc[a, 'Group'],
                                             'Type No': input_.loc[a, 'Type No'],
                                             'Type': input_.loc[a, 'Type'],
                                             'Type Code': input_.loc[a, 'Type Code'],
                                             'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                                             'Manufacturer': input_.loc[a, 'Manufacturer'],
                                             'Tab 2 Url': input_.loc[a, 'Tab 2 Url']}])

                    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Type No']}.{input_.loc[a, 'Type']} > {input_.loc[a, 'Manufacturer No']}.{input_.loc[a, 'Manufacturer']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(20):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['Group No', 'Type No', 'Manufacturer No', 'Part No'],
                                                    ascending=[True, True, True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./{param_date}/5.part_number/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['Group No', 'Type No', 'Manufacturer No'],
                                                ascending=[True, True, True],
                                                ignore_index=True)
        output_error.to_excel(f'''./{param_date}/5.part_number/0.error/{file.removesuffix('.xlsx')}-part_number_error.xlsx''', index=False)
        print('爬虫存在error')
        print()
    print('Done ~')
# Out:
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 128.Door Jamb Switch Connector > 6.STANDARD MOTOR PRODUCTS
# [剩余数量：1000] - [当前时间：18:39:19]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 129.Door Lock Actuator Connector > 7.WVE
# [剩余数量：999] - [当前时间：18:39:19]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 128.Door Jamb Switch Connector > 9.WVE
# [剩余数量：998] - [当前时间：18:39:19]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 119.Diesel Glow Plug Connector > 7.SKP
# [剩余数量：997] - [当前时间：18:39:19]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 6.WVE
# [剩余数量：996] - [当前时间：18:39:20]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 5.UNITED MOTOR PRODUCTS
# [剩余数量：995] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 129.Door Lock Actuator Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：994] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：993] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 132.Downshift Solenoid Connector > 1.ROSTRA
# [剩余数量：992] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 131.Door Wiring Connector > 4.WVE
# [剩余数量：991] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 111.Cruise Control Switch Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：990] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 132.Downshift Solenoid Connector > 2.WVE
# [剩余数量：989] - [当前时间：18:39:22]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 1.BWD/NIEHOFF
# [剩余数量：988] - [当前时间：18:39:23]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 133.Drive Clutch Actuator Solenoid Connector > 1.DANA
# [剩余数量：987] - [当前时间：18:39:23]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 136.EEC-IV Test Plug Connector > 2.WVE
# [剩余数量：986] - [当前时间：18:39:24]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 134.Driver Information Display Module Connector > 1.MOTORCRAFT
# [剩余数量：985] - [当前时间：18:39:24]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 107.Crankshaft Position Sensor Connector > 8.STANDARD MOTOR PRODUCTS
# [剩余数量：984] - [当前时间：18:39:24]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 131.Door Wiring Connector > 2.GM GENUINE
# [剩余数量：983] - [当前时间：18:39:24]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 1.BWD/NIEHOFF
# [剩余数量：982] - [当前时间：18:39:25]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：981] - [当前时间：18:39:25]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 136.EEC-IV Test Plug Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：980] - [当前时间：18:39:26]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 3.ROSTRA
# [剩余数量：979] - [当前时间：18:39:26]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 4.SKP
# [剩余数量：978] - [当前时间：18:39:26]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 131.Door Wiring Connector > 1.DORMAN
# [剩余数量：977] - [当前时间：18:39:26]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 129.Door Lock Actuator Connector > 3.GM GENUINE
# [剩余数量：976] - [当前时间：18:39:27]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 127.Door Ajar Indicator Switch Connector > 3.WVE
# [剩余数量：975] - [当前时间：18:39:27]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 127.Door Ajar Indicator Switch Connector > 1.GM GENUINE
# [剩余数量：974] - [当前时间：18:39:27]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 139.EGR Vacuum Solenoid Connector > 1.DORMAN
# [剩余数量：973] - [当前时间：18:39:27]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 139.EGR Vacuum Solenoid Connector > 2.MOTORCRAFT
# [剩余数量：972] - [当前时间：18:39:28]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 135.Driver Information Display Switch Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：971] - [当前时间：18:39:29]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 139.EGR Vacuum Solenoid Connector > 3.ROSTRA
# [剩余数量：970] - [当前时间：18:39:29]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 2.MOTORCRAFT
# [剩余数量：969] - [当前时间：18:39:29]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 122.Digital Sound Processing Unit Connector > 1.MOTORCRAFT
# [剩余数量：968] - [当前时间：18:39:30]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 3.MOTORCRAFT
# [剩余数量：967] - [当前时间：18:39:30]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 1.DORMAN
# [剩余数量：966] - [当前时间：18:39:31]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 1.CURT
# [剩余数量：965] - [当前时间：18:39:31]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 7.UNITED MOTOR PRODUCTS
# [剩余数量：964] - [当前时间：18:39:31]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 4.ROSTRA
# [剩余数量：963] - [当前时间：18:39:31]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 3.MOTORCRAFT
# [剩余数量：962] - [当前时间：18:39:32]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 130.Door Lock Switch Connector > 2.GM GENUINE
# [剩余数量：961] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 3.PROFESSIONAL PARTS SWEDEN
# [剩余数量：960] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 5.SKP
# [剩余数量：959] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 6.WVE
# [剩余数量：958] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 2.MOTORCRAFT
# [剩余数量：957] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：956] - [当前时间：18:39:33]
#
# [状态：error，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 142.Emergency Vehicle Lamp Connector > 1.GM GENUINE
# [剩余数量：955] - [当前时间：18:39:33]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 6.STANDARD MOTOR PRODUCTS
# [剩余数量：954] - [当前时间：18:39:34]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 140.EGR Valve Connector > 8.WVE
# [剩余数量：953] - [当前时间：18:39:34]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 6.UNITED MOTOR PRODUCTS
# [剩余数量：952] - [当前时间：18:39:35]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 134.Driver Information Display Module Connector > 2.WVE
# [剩余数量：951] - [当前时间：18:39:35]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 2.GM GENUINE
# [剩余数量：950] - [当前时间：18:39:36]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 144.Engine Control Module (ECM) Connector > 3.UNITED MOTOR PRODUCTS
# [剩余数量：949] - [当前时间：18:39:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 144.Engine Control Module (ECM) Connector > 1.ACDELCO
# [剩余数量：948] - [当前时间：18:39:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 2.GM GENUINE
# [剩余数量：947] - [当前时间：18:39:37]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 129.Door Lock Actuator Connector > 4.MOTORCRAFT
# [剩余数量：946] - [当前时间：18:39:37]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 144.Engine Control Module (ECM) Connector > 4.WVE
# [剩余数量：945] - [当前时间：18:39:37]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 8.STANDARD MOTOR PRODUCTS
# [剩余数量：944] - [当前时间：18:39:37]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 7.SKP
# [剩余数量：943] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 131.Door Wiring Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：942] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 138.EGR System Module Connector > 1.MOTORCRAFT
# [剩余数量：941] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 3.HYUNDAI
# [剩余数量：940] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 143.Engine Compartment Lamp Connector > 2.WVE
# [剩余数量：939] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 143.Engine Compartment Lamp Connector > 1.MOTORCRAFT
# [剩余数量：938] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 9.UNITED MOTOR PRODUCTS
# [剩余数量：937] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 4.MOPAR
# [剩余数量：936] - [当前时间：18:39:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 152.Flasher Connector > 2.MOTORCRAFT
# [剩余数量：935] - [当前时间：18:39:40]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 147.Engine Metal Temperature Switch Connector > 1.GM GENUINE
# [剩余数量：934] - [当前时间：18:39:40]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 149.Engine Valve Deactivation Solenoid Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：933] - [当前时间：18:39:40]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 137.EGR Pressure Feedback (DPFE) Sensor Connector > 7.WVE
# [剩余数量：932] - [当前时间：18:39:40]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 152.Flasher Connector > 1.DORMAN
# [剩余数量：931] - [当前时间：18:39:41]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 146.Engine Heater Cord > 3.MOPAR
# [剩余数量：930] - [当前时间：18:39:41]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 154.Fog Lamp Connector > 3.MOTORCRAFT
# [剩余数量：929] - [当前时间：18:39:41]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 10.WVE
# [剩余数量：928] - [当前时间：18:39:42]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 141.Electronic Brake Control Connector > 4.RAYBESTOS
# [剩余数量：927] - [当前时间：18:39:42]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 154.Fog Lamp Connector > 1.GM GENUINE
# [剩余数量：926] - [当前时间：18:39:42]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 146.Engine Heater Cord > 2.GM GENUINE
# [剩余数量：925] - [当前时间：18:39:42]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 148.Engine Oil Temperature Sensor Connector > 1.BWD/NIEHOFF
# [剩余数量：924] - [当前时间：18:39:43]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 5.MOTORCRAFT
# [剩余数量：923] - [当前时间：18:39:43]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 154.Fog Lamp Connector > 2.HELLA
# [剩余数量：922] - [当前时间：18:39:43]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 2.DORMAN
# [剩余数量：921] - [当前时间：18:39:43]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 154.Fog Lamp Connector > 4.WVE
# [剩余数量：920] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 136.EEC-IV Test Plug Connector > 3.ÜRO PARTS
# [剩余数量：919] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 4.MOTORCRAFT
# [剩余数量：918] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 6.SKP
# [剩余数量：917] - [当前时间：18:39:44]
#
# [状态：error，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 156.Fuel Injection Idle Speed Stabilizer Connector > 1.BWD/NIEHOFF
# [剩余数量：916] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 5.SHEE-MAR
# [剩余数量：915] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 151.Flag Connector > 1.DORMAN
# [剩余数量：914] - [当前时间：18:39:44]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 153.Floor Console Harness Connector > 1.WVE
# [剩余数量：913] - [当前时间：18:39:45]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 1.BECK/ARNLEY
# [剩余数量：912] - [当前时间：18:39:45]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 6.GM GENUINE
# [剩余数量：911] - [当前时间：18:39:45]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 128.Door Jamb Switch Connector > 4.GM GENUINE
# [剩余数量：910] - [当前时间：18:39:45]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 3.DORMAN
# [剩余数量：909] - [当前时间：18:39:46]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 8.MOPAR
# [剩余数量：908] - [当前时间：18:39:46]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 155.Fuel Injection Harness > 7.STANDARD MOTOR PRODUCTS
# [剩余数量：907] - [当前时间：18:39:46]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 5.GB REMANUFACTURING
# [剩余数量：906] - [当前时间：18:39:46]
#
# [状态：error，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 2.BWD/NIEHOFF
# [剩余数量：905] - [当前时间：18:39:46]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 1.ACDELCO
# [剩余数量：904] - [当前时间：18:39:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 9.MOTORCRAFT
# [剩余数量：903] - [当前时间：18:39:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 14.WALKER PRODUCTS
# [剩余数量：902] - [当前时间：18:39:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 15.WVE
# [剩余数量：901] - [当前时间：18:39:48]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 150.Extension Harness > 1.CURT
# [剩余数量：900] - [当前时间：18:39:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 6.SHEE-MAR
# [剩余数量：899] - [当前时间：18:39:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 159.Fuel Pressure Sensor Connector > 3.ROSTRA
# [剩余数量：898] - [当前时间：18:39:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 159.Fuel Pressure Sensor Connector > 1.GM GENUINE
# [剩余数量：897] - [当前时间：18:39:49]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 145.Engine Harness Connector > 1.ACDELCO
# [剩余数量：896] - [当前时间：18:39:49]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 160.Fuel Pump Connector > 3.ROSTRA
# [剩余数量：895] - [当前时间：18:39:49]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 160.Fuel Pump Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：894] - [当前时间：18:39:50]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 160.Fuel Pump Connector > 1.GM GENUINE
# [剩余数量：893] - [当前时间：18:39:50]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 159.Fuel Pressure Sensor Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：892] - [当前时间：18:39:51]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 160.Fuel Pump Connector > 6.WVE
# [剩余数量：891] - [当前时间：18:39:51]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 161.Fuel Pump Drive Module Connector > 1.DORMAN
# [剩余数量：890] - [当前时间：18:39:51]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 12.STANDARD MOTOR PRODUCTS
# [剩余数量：889] - [当前时间：18:39:51]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 161.Fuel Pump Drive Module Connector > 2.GB REMANUFACTURING
# [剩余数量：888] - [当前时间：18:39:51]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 13.UNITED MOTOR PRODUCTS
# [剩余数量：887] - [当前时间：18:39:52]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 139.EGR Vacuum Solenoid Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：886] - [当前时间：18:39:52]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 1.ACDELCO
# [剩余数量：885] - [当前时间：18:39:52]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 159.Fuel Pressure Sensor Connector > 2.MOTORCRAFT
# [剩余数量：884] - [当前时间：18:39:52]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 4.FORD
# [剩余数量：883] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 5.BWD/NIEHOFF
# [剩余数量：882] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 161.Fuel Pump Drive Module Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：881] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 161.Fuel Pump Drive Module Connector > 3.MOTORCRAFT
# [剩余数量：880] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 10.ROSTRA
# [剩余数量：879] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 6.CARTER
# [剩余数量：878] - [当前时间：18:39:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 3.BOSCH
# [剩余数量：877] - [当前时间：18:39:54]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 9.GM GENUINE
# [剩余数量：876] - [当前时间：18:39:54]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 7.HOLSTEIN
# [剩余数量：875] - [当前时间：18:39:54]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 8.DORMAN
# [剩余数量：874] - [当前时间：18:39:54]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 11.ROSTRA
# [剩余数量：873] - [当前时间：18:39:55]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 12.SPARTA
# [剩余数量：872] - [当前时间：18:39:55]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 159.Fuel Pressure Sensor Connector > 5.WVE
# [剩余数量：871] - [当前时间：18:39:55]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 146.Engine Heater Cord > 1.AUTOTECNICA
# [剩余数量：870] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 7.DELPHI
# [剩余数量：869] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 4.BRUTE POWER
# [剩余数量：868] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 2.AUTOBEST
# [剩余数量：867] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 16.UNITED MOTOR PRODUCTS
# [剩余数量：866] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 163.Fuel Shutoff Solenoid Connector > 4.WVE
# [剩余数量：865] - [当前时间：18:39:56]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 14.STANDARD MOTOR PRODUCTS
# [剩余数量：864] - [当前时间：18:39:57]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 2.GM GENUINE
# [剩余数量：863] - [当前时间：18:39:58]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 158.Fuel Level Sensor Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：862] - [当前时间：18:39:58]
#
# [状态：ok，尝试次数：8] - 100.00% - group_9.Electrical-Connector > 144.Engine Control Module (ECM) Connector > 2.STANDARD MOTOR PRODUCTS
# [剩余数量：861] - [当前时间：18:39:58]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 163.Fuel Shutoff Solenoid Connector > 1.DORMAN
# [剩余数量：860] - [当前时间：18:39:59]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 164.Fuel Tank Connector > 2.GM GENUINE
# [剩余数量：859] - [当前时间：18:39:59]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 4.ROSTRA
# [剩余数量：858] - [当前时间：18:39:59]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 5.SKP
# [剩余数量：857] - [当前时间：18:40:00]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 7.UNITED MOTOR PRODUCTS
# [剩余数量：856] - [当前时间：18:40:00]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 17.WVE
# [剩余数量：855] - [当前时间：18:40:01]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 166.Fuel Tank Selector Connector > 2.ROSTRA
# [剩余数量：854] - [当前时间：18:40:01]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 8.WVE
# [剩余数量：853] - [当前时间：18:40:01]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 163.Fuel Shutoff Solenoid Connector > 3.ROSTRA
# [剩余数量：852] - [当前时间：18:40:02]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 157.Fuel Injector Connector > 11.SKP
# [剩余数量：851] - [当前时间：18:40:03]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 167.Fuel Tank Sending Unit Connector > 1.ACDELCO
# [剩余数量：850] - [当前时间：18:40:03]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 164.Fuel Tank Connector > 1.DORMAN
# [剩余数量：849] - [当前时间：18:40:03]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 167.Fuel Tank Sending Unit Connector > 3.GM GENUINE
# [剩余数量：848] - [当前时间：18:40:03]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 167.Fuel Tank Sending Unit Connector > 4.MOTORCRAFT
# [剩余数量：847] - [当前时间：18:40:04]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 164.Fuel Tank Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：846] - [当前时间：18:40:04]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 10.GMB
# [剩余数量：845] - [当前时间：18:40:04]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 160.Fuel Pump Connector > 2.MOTORCRAFT
# [剩余数量：844] - [当前时间：18:40:04]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 165.Fuel Tank Pressure Sensor Connector > 1.ACDELCO
# [剩余数量：843] - [当前时间：18:40:05]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 167.Fuel Tank Sending Unit Connector > 8.UNITED MOTOR PRODUCTS
# [剩余数量：842] - [当前时间：18:40:05]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 162.Fuel Pump Relay Connector > 15.ULTRA-POWER
# [剩余数量：841] - [当前时间：18:40:05]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 167.Fuel Tank Sending Unit Connector > 9.WVE
# [剩余数量：840] - [当前时间：18:40:05]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 166.Fuel Tank Selector Connector > 1.MOTORCRAFT
# [剩余数量：839] - [当前时间：18:40:06]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 169.Fuel Volume Regulator Solenoid Connector > 1.ROSTRA
# [剩余数量：838] - [当前时间：18:40:06]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector >

#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 212.Interior Light Switch Connector > 1.MOTORCRAFT
# [剩余数量：670] - [当前时间：18:40:52]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 211.Interior Lamp Module Connector > 2.SKP
# [剩余数量：669] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 211.Interior Lamp Module Connector > 4.WVE
# [剩余数量：668] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 214.Keyless Entry Module Connector > 1.GM GENUINE
# [剩余数量：667] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 213.Junction Block Relay Connector > 1.DORMAN
# [剩余数量：666] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 212.Interior Light Switch Connector > 2.ROSTRA
# [剩余数量：665] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 212.Interior Light Switch Connector > 5.ÜRO PARTS
# [剩余数量：664] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 193.Horn Connector > 2.DORMAN
# [剩余数量：663] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 209.Intake Manifold Tuning Valve Connector > 1.GM GENUINE
# [剩余数量：662] - [当前时间：18:40:53]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 212.Interior Light Switch Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：661] - [当前时间：18:40:54]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 207.Intake Manifold Hose Connector > 2.ÜRO PARTS
# [剩余数量：660] - [当前时间：18:40:54]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 215.Keyless Entry Receiver Connector > 2.WVE
# [剩余数量：659] - [当前时间：18:40:54]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 214.Keyless Entry Module Connector > 2.MOTORCRAFT
# [剩余数量：658] - [当前时间：18:40:55]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 216.Knock / Detonation Sensor Connector > 2.BWD/NIEHOFF
# [剩余数量：657] - [当前时间：18:40:55]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 212.Interior Light Switch Connector > 4.WVE
# [剩余数量：656] - [当前时间：18:40:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 216.Knock / Detonation Sensor Connector > 1.ACDELCO
# [剩余数量：655] - [当前时间：18:40:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 216.Knock / Detonation Sensor Connector > 5.HOLSTEIN
# [剩余数量：654] - [当前时间：18:40:56]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 216.Knock / Detonation Sensor Connector > 6.MOTORAD
# [剩余数量：653] - [当前时间：18:40:57]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 216.Knock / Detonation Sensor Connector > 7.MOTORCRAFT
# [剩余数量：652] - [当前时间：18:40:57]
#
# ...
# [剩余数量：96] - [当前时间：18:43:19]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 6.STANDARD MOTOR PRODUCTS
# [剩余数量：95] - [当前时间：18:43:20]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 3.MOTORCRAFT
# [剩余数量：94] - [当前时间：18:43:20]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 8.WVE
# [剩余数量：93] - [当前时间：18:43:20]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 4.ROSTRA
# [剩余数量：92] - [当前时间：18:43:20]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 371.Valve Cover Gasket Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：91] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 7.UNITED MOTOR PRODUCTS
# [剩余数量：90] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 370.Vacuum Pump Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：89] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 5.ROSTRA
# [剩余数量：88] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 372.Vanity Mirror Connector > 2.MOTORCRAFT
# [剩余数量：87] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 368.Turn Signal Switch Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：86] - [当前时间：18:43:21]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 8.WVE
# [剩余数量：85] - [当前时间：18:43:22]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 369.Twist-On Connector > 1.CURT
# [剩余数量：84] - [当前时间：18:43:23]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 1.ACDELCO
# [剩余数量：83] - [当前时间：18:43:23]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 361.Trunk or Cargo Area Lamp Connector > 4.WVE
# [剩余数量：82] - [当前时间：18:43:23]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：81] - [当前时间：18:43:23]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 4.ROSTRA
# [剩余数量：80] - [当前时间：18:43:23]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 3.GM GENUINE
# [剩余数量：79] - [当前时间：18:43:24]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 1.ACDELCO
# [剩余数量：78] - [当前时间：18:43:24]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 2.GM GENUINE
# [剩余数量：77] - [当前时间：18:43:25]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 376.Variable Valve Timing (VVT) Solenoid Connector > 2.ROSTRA
# [剩余数量：76] - [当前时间：18:43:25]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 361.Trunk or Cargo Area Lamp Connector > 2.MOTORCRAFT
# [剩余数量：75] - [当前时间：18:43:25]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：74] - [当前时间：18:43:25]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 376.Variable Valve Timing (VVT) Solenoid Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：73] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 369.Twist-On Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：72] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 365.Turbocharger Wastegate Solenoid Connector > 4.WVE
# [剩余数量：71] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 2.GM GENUINE
# [剩余数量：70] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 376.Variable Valve Timing (VVT) Solenoid Connector > 1.MOTORCRAFT
# [剩余数量：69] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 6.UNITED MOTOR PRODUCTS
# [剩余数量：68] - [当前时间：18:43:26]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 4.GM GENUINE
# [剩余数量：67] - [当前时间：18:43:27]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 6.WVE
# [剩余数量：66] - [当前时间：18:43:28]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 376.Variable Valve Timing (VVT) Solenoid Connector > 5.WVE
# [剩余数量：65] - [当前时间：18:43:28]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 376.Variable Valve Timing (VVT) Solenoid Connector > 4.WALKER PRODUCTS
# [剩余数量：64] - [当前时间：18:43:29]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 6.MOTORCRAFT
# [剩余数量：63] - [当前时间：18:43:29]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 8.PROFESSIONAL PARTS SWEDEN
# [剩余数量：62] - [当前时间：18:43:29]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 14.WVE
# [剩余数量：61] - [当前时间：18:43:30]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 379.Voltage Converter Connector > 1.MOTORCRAFT
# [剩余数量：60] - [当前时间：18:43:30]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 2.BWD/NIEHOFF
# [剩余数量：59] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 3.DORMAN
# [剩余数量：58] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 378.Vehicle Speed Sensor Module Connector > 1.GM GENUINE
# [剩余数量：57] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 1.ACDELCO
# [剩余数量：56] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 11.STANDARD MOTOR PRODUCTS
# [剩余数量：55] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 378.Vehicle Speed Sensor Module Connector > 2.STANDARD MOTOR PRODUCTS
# [剩余数量：54] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 9.ROSTRA
# [剩余数量：53] - [当前时间：18:43:31]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 12.UNITED MOTOR PRODUCTS
# [剩余数量：52] - [当前时间：18:43:32]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 373.Vapor Canister Purge Valve Connector > 2.DORMAN
# [剩余数量：51] - [当前时间：18:43:32]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 381.Water Pump Connector > 2.ROSTRA
# [剩余数量：50] - [当前时间：18:43:32]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 381.Water Pump Connector > 1.GM GENUINE
# [剩余数量：49] - [当前时间：18:43:33]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 344.Trailer Connector > 15.SKP
# [剩余数量：48] - [当前时间：18:43:33]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 6.UNITED MOTOR PRODUCTS
# [剩余数量：47] - [当前时间：18:43:34]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 7.WALKER PRODUCTS
# [剩余数量：46] - [当前时间：18:43:34]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 10.SKP
# [剩余数量：45] - [当前时间：18:43:34]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 13.WALKER PRODUCTS
# [剩余数量：44] - [当前时间：18:43:35]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 381.Water Pump Connector > 4.WVE
# [剩余数量：43] - [当前时间：18:43:35]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 382.Water in Fuel Sensor Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：42] - [当前时间：18:43:35]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 382.Water in Fuel Sensor Connector > 2.MOTORCRAFT
# [剩余数量：41] - [当前时间：18:43:35]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 384.Weather Pack Housing > 1.DORMAN
# [剩余数量：40] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 375.Variable Power Steering Solenoid Connector > 3.MOTORCRAFT
# [剩余数量：39] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 386.Window Defogger Connector > 1.GM GENUINE
# [剩余数量：38] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 386.Window Defogger Connector > 2.MOTORCRAFT
# [剩余数量：37] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 385.Weather Pack Plug / Seal > 1.DORMAN
# [剩余数量：36] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 386.Window Defogger Connector > 4.WVE
# [剩余数量：35] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 382.Water in Fuel Sensor Connector > 1.DORMAN
# [剩余数量：34] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 374.Vapor Canister Vent Solenoid Connector > 1.DORMAN
# [剩余数量：33] - [当前时间：18:43:36]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 387.Windshield Washer Fluid Heater Connector > 1.STANDARD MOTOR PRODUCTS
# [剩余数量：32] - [当前时间：18:43:37]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 2.ANCO
# [剩余数量：31] - [当前时间：18:43:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 4.GM GENUINE
# [剩余数量：30] - [当前时间：18:43:38]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 5.MOTORCRAFT
# [剩余数量：29] - [当前时间：18:43:38]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 5.MOPAR
# [剩余数量：28] - [当前时间：18:43:38]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 388.Windshield Washer Fluid Level Sensor Connector > 2.STANDARD MOTOR PRODUCTS
# [剩余数量：27] - [当前时间：18:43:39]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 3.DORMAN
# [剩余数量：26] - [当前时间：18:43:39]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 390.Wiper Control Module Connector > 1.ACDELCO
# [剩余数量：25] - [当前时间：18:43:39]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 381.Water Pump Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：24] - [当前时间：18:43:39]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 7.WALKER PRODUCTS
# [剩余数量：23] - [当前时间：18:43:40]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 2.DORMAN
# [剩余数量：22] - [当前时间：18:43:40]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 3.DORMAN
# [剩余数量：21] - [当前时间：18:43:41]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 5.ROSTRA
# [剩余数量：20] - [当前时间：18:43:41]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 7.STANDARD MOTOR PRODUCTS
# [剩余数量：19] - [当前时间：18:43:42]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 4.MOTORCRAFT
# [剩余数量：18] - [当前时间：18:43:42]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 393.Wiper Switch Connector > 2.GM GENUINE
# [剩余数量：17] - [当前时间：18:43:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 393.Wiper Switch Connector > 1.DORMAN
# [剩余数量：16] - [当前时间：18:43:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 3.GM GENUINE
# [剩余数量：15] - [当前时间：18:43:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 388.Windshield Washer Fluid Level Sensor Connector > 3.WVE
# [剩余数量：14] - [当前时间：18:43:44]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 386.Window Defogger Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：13] - [当前时间：18:43:44]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 5.STANDARD MOTOR PRODUCTS
# [剩余数量：12] - [当前时间：18:43:45]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 6.STANDARD MOTOR PRODUCTS
# [剩余数量：11] - [当前时间：18:43:45]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 395.Wire Connector Assortment > 1.DORMAN
# [剩余数量：10] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 7.PIONEER
# [剩余数量：9] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 7.WVE
# [剩余数量：8] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 394.Wire Connector > 1.BOSCH
# [剩余数量：7] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 393.Wiper Switch Connector > 5.WVE
# [剩余数量：6] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 395.Wire Connector Assortment > 2.PETERSON MANUFACTURING
# [剩余数量：5] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 4.ROSTRA
# [剩余数量：4] - [当前时间：18:43:47]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 1.ACI
# [剩余数量：3] - [当前时间：18:43:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 393.Wiper Switch Connector > 3.ROSTRA
# [剩余数量：2] - [当前时间：18:43:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 391.Wiper Motor Connector > 1.BWD/NIEHOFF
# [剩余数量：1] - [当前时间：18:43:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 397.Wiring Connector > 1.GM GENUINE
# [剩余数量：0] - [当前时间：18:43:48]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 396.Wire Terminal > 3.WVE
# [剩余数量：0] - [当前时间：18:43:49]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 398.Wiring Harness Connector > 1.WVE
# [剩余数量：0] - [当前时间：18:43:49]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 397.Wiring Connector > 2.RAYBESTOS
# [剩余数量：0] - [当前时间：18:43:49]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 392.Wiper Motor Pulse Board Module Connector > 2.WVE
# [剩余数量：0] - [当前时间：18:43:49]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 399.Yaw Sensor Connector > 3.STANDARD MOTOR PRODUCTS
# [剩余数量：0] - [当前时间：18:43:50]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 383.Weather Pack Connector > 1.DORMAN
# [剩余数量：0] - [当前时间：18:43:50]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 396.Wire Terminal > 2.STANDARD MOTOR PRODUCTS
# [剩余数量：0] - [当前时间：18:43:50]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 380.Voltage Regulator Connector > 8.WVE
# [剩余数量：0] - [当前时间：18:43:51]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 394.Wire Connector > 2.STANDARD MOTOR PRODUCTS
# [剩余数量：0] - [当前时间：18:43:51]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 388.Windshield Washer Fluid Level Sensor Connector > 1.MOTORCRAFT
# [剩余数量：0] - [当前时间：18:43:51]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 399.Yaw Sensor Connector > 1.GM GENUINE
# [剩余数量：0] - [当前时间：18:43:51]
#
# [状态：ok，尝试次数：2] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 8.WVE
# [剩余数量：0] - [当前时间：18:43:52]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 377.Vehicle / Output Speed Sensor Connector > 2.BWD/NIEHOFF
# [剩余数量：0] - [当前时间：18:43:52]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 399.Yaw Sensor Connector > 2.MOTORCRAFT
# [剩余数量：0] - [当前时间：18:43:52]
#
# [状态：ok，尝试次数：1] - 100.00% - group_9.Electrical-Connector > 399.Yaw Sensor Connector > 4.WVE
# [剩余数量：0] - [当前时间：18:43:52]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 392.Wiper Motor Pulse Board Module Connector > 1.ROSTRA
# [剩余数量：0] - [当前时间：18:43:55]
#
# [状态：ok，尝试次数：3] - 100.00% - group_9.Electrical-Connector > 393.Wiper Switch Connector > 4.STANDARD MOTOR PRODUCTS
# [剩余数量：0] - [当前时间：18:43:57]
#
# [状态：ok，尝试次数：5] - 100.00% - group_9.Electrical-Connector > 396.Wire Terminal > 1.PERFORMANCE TOOL
# [剩余数量：0] - [当前时间：18:43:58]
#
# [状态：ok，尝试次数：4] - 100.00% - group_9.Electrical-Connector > 389.Windshield Washer Pump Connector > 6.ROSTRA
# [剩余数量：0] - [当前时间：18:44:01]
#
# 输出ing...
#
# 爬虫存在error
#
# Done ~
