#  '56016',
#  '56017',
#  '56018',
#  '56019',
#  '56020',
#  '56021',
#  '56022',
#  '56023',
#  '56024',
#  '56025',
#  '56026',
#  '56027',
#  '56028',
#  '56029',
#  '56030',
#  '56031',
#  '56032',
#  '56033',
#  '56036',
#  '56037',
#  '56038',
#  '56039',
#  '56040',
#  '56041',
#  '56042',
#  '56043',
#  '56044',
#  '56045',
#  '56046',
#  '56047',
#  '56048',
#  '56049',
#  '56050',
#  '56051',
#  '56052',
#  '56053',
#  '56054',
#  '56055',
#  '56056',
#  '56057',
#  '56058',
#  '56059',
#  '56060',
#  '56061',
#  '56062',
#  '56063',
#  '56064',
#  '56065',
#  '56066',
#  '56067',
#  '56068',
#  '56069',
#  '56070',
#  '56073',
#  '56074',
#  '56075',
#  '56076',
#  '56077',
#  '56078',
#  '56079',
#  '56080',
#  '56081',
#  '56082',
#  '56083',
#  '56084',
#  '56085',
#  '56086',
#  '56087',
#  '56088',
#  '56089',
#  '56090',
#  '56091',
#  '56092',
#  '56093',
#  '56094',
#  '56095',
#  '56096',
#  '56097',
#  '56098',
#  '56099',
#  '56101',
#  '56103',
#  '56104',
#  '56105',
#  '56106',
#  '56107',
#  '56108',
#  '56109',
#  '56110',
#  '56111',
#  '56112',
#  '56113',
#  '56114',
#  '56115',
#  '56116',
#  ...]

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 0

url = 'https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=' + input_.loc[a, 'Part_Number'] + '&brand=' + input_.loc[a, 'Brand'] + '&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960'

resp = requests.get(url,
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '[{"image_Name":"pUCM3qtVE%2F%2FT19ecUgo9pw%3D%3D","image_SM_Url":"https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuT9FNpDfGKFIWs34AmcG1EkFoZj0BakHNFnFl6zRCvvlrm+ZHodTWPuhIKBw3J5SZ5iH9+8ykTJFSKEulrQ0hiWTskhDbDVIOt4K7Mm/YEv3m/CH1/uYPCgXGfdCmo4YlLSCFlglY/QZxJqZnExfKoUw9whDiuSOa9jIzcIuTor1","image_MD_Url":"https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuT9FNpDfGKFIBku710yGpH+HJHRxkJfhuwSUxXGVAdRLbEHUQlckYE7y916PDj4mUplpjLqJxiUyNc0Dfr4BAXPekNlQ51Q7yIznwcghdmhavbavYiSVAdwf+9wZqa98qkDWYgcXOd3pX0Utk6ajwYRZsk7sLOJhZuxDDtSObvr3","image_BG_Url":"https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuSYF4nkLByFFki+PA/U85oYyCn2Odtodzu72HZkm08flMYvVb8ruU/a2jlDyZ/9SFhHKSDnV/vfUm++2cf2MyJSTHiO+uZMQDMRJmK/E5kGqgMS+q/NNn547DcAIwETg08mC8jZdED2DtxvSKxtZsuQcplcwOJBGqg=="}]'

# %%
import json

# %%
json_data = json.loads(resp)

json_data
# Out:
# [{'image_Name': 'pUCM3qtVE%2F%2FT19ecUgo9pw%3D%3D',
#   'image_SM_Url': 'https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuT9FNpDfGKFIWs34AmcG1EkFoZj0BakHNFnFl6zRCvvlrm+ZHodTWPuhIKBw3J5SZ5iH9+8ykTJFSKEulrQ0hiWTskhDbDVIOt4K7Mm/YEv3m/CH1/uYPCgXGfdCmo4YlLSCFlglY/QZxJqZnExfKoUw9whDiuSOa9jIzcIuTor1',
#   'image_MD_Url': 'https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuT9FNpDfGKFIBku710yGpH+HJHRxkJfhuwSUxXGVAdRLbEHUQlckYE7y916PDj4mUplpjLqJxiUyNc0Dfr4BAXPekNlQ51Q7yIznwcghdmhavbavYiSVAdwf+9wZqa98qkDWYgcXOd3pX0Utk6ajwYRZsk7sLOJhZuxDDtSObvr3',
#   'image_BG_Url': 'https://ecatalog.smpcorp.com/ihgs/imagehandlergs.ashx?p1=3BWWpoVsQQ0e31etH9unuSYF4nkLByFFki+PA/U85oYyCn2Odtodzu72HZkm08flMYvVb8ruU/a2jlDyZ/9SFhHKSDnV/vfUm++2cf2MyJSTHiO+uZMQDMRJmK/E5kGqgMS+q/NNn547DcAIwETg08mC8jZdED2DtxvSKxtZsuQcplcwOJBGqg=='}]

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
df_temp = pd.DataFrame([{'JOIN_PNB': input_.loc[a, 'JOIN_PNB'],
                         'Src': '' if len(json_data) == 0 else json_data[0]['image_BG_Url']}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Part_Number': input_.loc[a, 'Part_Number'],
                             'Brand': input_.loc[a, 'Brand']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['JOIN_PNB'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_src.xlsx', index=False)

output_correct
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_11412/2839804355.py in ?()
#       1 output_correct = output_correct.drop_duplicates(ignore_index=True)
# ----> 2 output_correct = output_correct.sort_values(by=['JOIN_PTB'], ascending=[True]).reset_index(drop=True)
#       3 output_correct.to_excel('./test_src.xlsx', index=False)
#       4
#       5 output_correct
#
# ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ~/Desktop/YangTeng/code/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'JOIN_PTB'

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['Part_Number', 'Brand'], ascending=[True, True]).reset_index(drop=True)
    output_error.to_excel('./test_src_error.xlsx', index=False)

output_error
