# %%
param_x_api_key = '2BeBXg69osbuG45Rjtv1wLEnHL3nuT3WPQQK1EaYHT4PutPkDrXB'

# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                data = '''{"getArticles":
                {"articleCountry":"DE",
                 "provider":40000,
                 "lang":"en",
                 "searchQuery":"''' + input_.loc[a, 'Row_Id'].split(']-[')[1].replace(']', '') + '''",
                 "searchMatchType":"exact",
                 "searchType":0,
                 "page":1,
                 "perPage":10,
                 "filterQueries":["(dataSupplierId NOT IN (4978,4982))"],
                 "dataSupplierIds":[''' + input_.loc[a, 'Row_Id'].split(']-[')[0].replace('[', '') + '''],
                 "genericArticleIds":[''' + input_.loc[a, 'Groups'] + '''],
                 "includeAll":false,
                 "includeLinkages":true,
                 "linkagesPerPage":100,
                 "includeGenericArticles":true,
                 "includeArticleCriteria":true,
                 "includeMisc":true,
                 "includeImages":true,
                 "includePDFs":true,
                 "includeLinks":true,
                 "includeArticleText":true,
                 "includeOEMNumbers":true,
                 "includeReplacedByArticles":true,
                 "includeReplacesArticles":true,
                 "includeComparableNumbers":true,
                 "includeGTINs":true,
                 "includeTradeNumbers":true,
                 "includePrices":true,
                 "includePartsListArticles":false,
                 "includeAccessoryArticles":false,
                 "includeArticleLogisticsCriteria":true,
                 "includeDataSupplierFacets":false,
                 "includeGenericArticleFacets":false,
                 "includeCriteriaFacets":false}}'''

                headers = UA.get_User_Agent_Requests()
                headers['X-Api-Key'] = param_x_api_key

                resp = requests.post('https://webservice.tecalliance.services/pegasus-3-0/services/TecdocToCatDLB.jsonEndpoint',
                                     data=data,
                                     headers=headers,
                                     proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                json_data = json.loads(resp)
                
                # = = = = = = = = = = = = = = =
                
                part_number = json_data['articles'][0]['articleNumber'].strip()
                
                # = = = = = = = = = = = = = = =
                
                manufactuer = json_data['articles'][0]['mfrName'].strip()
                
                # = = = = = = = = = = = = = = =
                
                type_ = json_data['articles'][0]['genericArticles'][0]['genericArticleDescription'].strip()

                # = = = = = = = = = = = = = = =
                
                article_id = str(json_data['articles'][0]['genericArticles'][0]['legacyArticleId'])

                # = = = = = = = = = = = = = = =
                
                information = ' '.join(json_data['articles'][0]['articleText'][0]['text'])

                # = = = = = = = = = = = = = = =
                
                gtin = '' if len(json_data['articles'][0]['gtins']) == 0 else json_data['articles'][0]['gtins'][0].strip()

                # = = = = = = = = = = = = = = =
                
                oe = ';'.join(sorted(list(set(oe['articleNumber'].strip().replace(' ', '') for oe in json_data['articles'][0]['oemNumbers']))))

                # = = = = = = = = = = = = = = =
                
                list_manufactuer_id = [''] if len(sorted(list(set([str(oe['mfrId']) for oe in json_data['articles'][0]['oemNumbers']])))) == 0 else sorted(list(set([str(oe['mfrId']) for oe in json_data['articles'][0]['oemNumbers']])))

                # = = = = = = = = = = = = = = =
                
                list_criteria = json_data['articles'][0]['articleCriteria']
                
                # = = = = = = = = = = = = = = =
                
                src = '' if len(json_data['articles'][0]['images']) == 0 else json_data['articles'][0]['images'][0]['imageURL3200'].strip()

                # = = = = = = = = = = = = = = =
                
                price_type = '' if len(json_data['articles'][0]['prices']) == 0 else json_data['articles'][0]['prices'][0]['kindOfPriceDescription'].strip()

                # = = = = = = = = = = = = = = =
                
                price_unit = '' if len(json_data['articles'][0]['prices']) == 0 else json_data['articles'][0]['prices'][0]['priceUnitDescription'].strip()

                # = = = = = = = = = = = = = = =
                
                quantity_unit = '' if len(json_data['articles'][0]['prices']) == 0 else json_data['articles'][0]['prices'][0]['quantityUnitDescription'].strip()

                # = = = = = = = = = = = = = = =
                
                price = '' if len(json_data['articles'][0]['prices']) == 0 else json_data['articles'][0]['prices'][0]['currencyCode'].strip() + ' ' + str(json_data['articles'][0]['prices'][0]['price'])

                # = = = = = = = = = = = = = = =
                
                discount_group = '' if len(json_data['articles'][0]['prices']) == 0 else json_data['articles'][0]['prices'][0]['isDiscount']

                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame({'序号': int(input_.loc[a, 'No.']),
                                        'Manufactuer': manufactuer,
                                        'Part_Number': part_number,
                                        'Type': type_,
                                        'GTIN': gtin,
                                        'Price_Type': price_type,
                                        'Price_Unit': price_unit,
                                        'Quantity_Unit': quantity_unit,
                                        'Price': price,
                                        'Discount_Group': discount_group,
                                        'Vehicle_1': '',
                                        'Vehicle_2': '',
                                        'OE': oe,
                                        'Pic': '',
                                        'Url': 'https://web.tecalliance.net/tecdocsw/en/parts/' + input_.loc[a, 'Row_Id'].split(']-[')[0].replace('[', '') + '/' + input_.loc[a, 'Row_Id'].split(']-[')[1].replace(']', '') + '/detail',
                                        'Src': src,
                                        'Information': information,
                                        'Article_Id': article_id,
                                        'Manufactuer_Id': list_manufactuer_id})

                for criteria in list_criteria:
                    df_temp['Criteria_' + criteria['criteriaAbbrDescription'] if 'criteriaAbbrDescription' in criteria else 'Criteria_' + criteria['criteriaDescription'].strip()] = criteria['formattedValue'].strip() + criteria['criteriaUnitDescription'].strip() if 'criteriaUnitDescription' in criteria else criteria['formattedValue'].strip()

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                                     'Row_Id': input_.loc[a, 'Row_Id'],
                                     'Groups': input_.loc[a, 'Groups']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Row_Id'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
list_column = output_correct.columns.tolist()
list_column.remove('Manufactuer_Id')
output_correct_1 = output_correct[list_column].drop_duplicates(ignore_index=True)
output_correct_1 = output_correct_1.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct_1.to_excel('./part-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
output_correct_2 = output_correct[['Article_Id', 'Manufactuer_Id']].drop_duplicates(ignore_index=True)
output_correct_2 = output_correct_2[output_correct_2['Manufactuer_Id'] != '']
output_correct_2 = output_correct_2.sort_values(by=['Article_Id', 'Manufactuer_Id'], ascending=[True, True]).reset_index(drop=True)
output_correct_2.to_excel('./part_2-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./part_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：413
#
# [ok] - [101]-[01513]
# [尝试次数：1] - [剩余数量：393] - [当前时间：14:18:03]
#
# [ok] - [101]-[02024]
# [尝试次数：1] - [剩余数量：392] - [当前时间：14:18:03]
#
# [ok] - [101]-[01628]
# [尝试次数：1] - [剩余数量：391] - [当前时间：14:18:04]
#
# [ok] - [101]-[02222]
# [尝试次数：1] - [剩余数量：390] - [当前时间：14:18:04]
#
# [ok] - [101]-[02034]
# [尝试次数：1] - [剩余数量：389] - [当前时间：14:18:04]
#
# [ok] - [101]-[02032]
# [尝试次数：1] - [剩余数量：388] - [当前时间：14:18:04]
#
# [ok] - [101]-[01514]
# [尝试次数：1] - [剩余数量：387] - [当前时间：14:18:04]
#
# [ok] - [101]-[01520]
# [尝试次数：1] - [剩余数量：386] - [当前时间：14:18:04]
#
# [ok] - [101]-[01626]
# [尝试次数：1] - [剩余数量：385] - [当前时间：14:18:04]
#
# [ok] - [101]-[02023]
# [尝试次数：1] - [剩余数量：384] - [当前时间：14:18:04]
#
# [ok] - [101]-[02031]
# [尝试次数：1] - [剩余数量：383] - [当前时间：14:18:04]
#
# [ok] - [101]-[02388]
# [尝试次数：1] - [剩余数量：382] - [当前时间：14:18:04]
#
# [ok] - [101]-[03048]
# [尝试次数：1] - [剩余数量：381] - [当前时间：14:18:04]
#
# [ok] - [101]-[01110]
# [尝试次数：1] - [剩余数量：380] - [当前时间：14:18:04]
#
# [ok] - [101]-[01750]
# [尝试次数：1] - [剩余数量：379] - [当前时间：14:18:04]
#
# [ok] - [101]-[04125]
# [尝试次数：1] - [剩余数量：378] - [当前时间：14:18:04]
#
# [ok] - [101]-[04395]
# [尝试次数：1] - [剩余数量：377] - [当前时间：14:18:04]
#
# [ok] - [101]-[04046]
# [尝试次数：1] - [剩余数量：376] - [当前时间：14:18:04]
#
# [ok] - [101]-[01907]
# [尝试次数：1] - [剩余数量：375] - [当前时间：14:18:04]
#
# [ok] - [101]-[01107]
# [尝试次数：1] - [剩余数量：374] - [当前时间：14:18:05]
#
# [ok] - [101]-[01933]
# [尝试次数：1] - [剩余数量：373] - [当前时间：14:18:05]
#
# [ok] - [101]-[04517]
# [尝试次数：1] - [剩余数量：372] - [当前时间：14:18:05]
#
# [ok] - [101]-[06020]
# [尝试次数：1] - [剩余数量：371] - [当前时间：14:18:05]
#
# [ok] - [101]-[04994]
# [尝试次数：1] - [剩余数量：370] - [当前时间：14:18:05]
#
# [ok] - [101]-[05723]
# [尝试次数：1] - [剩余数量：369] - [当前时间：14:18:05]
#
# [ok] - [101]-[05157]
# [尝试次数：1] - [剩余数量：368] - [当前时间：14:18:05]
#
# [ok] - [101]-[06791]
# [尝试次数：1] - [剩余数量：367] - [当前时间：14:18:06]
#
# [ok] - [101]-[04394]
# [尝试次数：1] - [剩余数量：366] - [当前时间：14:18:06]
#
# [ok] - [101]-[04113]
# [尝试次数：1] - [剩余数量：365] - [当前时间：14:18:06]
#
# [ok] - [101]-[06071]
# [尝试次数：1] - [剩余数量：364] - [当前时间：14:18:06]
#
# [ok] - [101]-[04112]
# [尝试次数：1] - [剩余数量：363] - [当前时间：14:18:06]
#
# [ok] - [101]-[07384]
# [尝试次数：1] - [剩余数量：362] - [当前时间：14:18:06]
#
# [ok] - [101]-[06657]
# [尝试次数：1] - [剩余数量：361] - [当前时间：14:18:06]
#
# [ok] - [101]-[06468]
# [尝试次数：1] - [剩余数量：360] - [当前时间：14:18:06]
#
# [ok] - [101]-[06475]
# [尝试次数：1] - [剩余数量：359] - [当前时间：14:18:06]
#
# [ok] - [101]-[07742]
# [尝试次数：1] - [剩余数量：358] - [当前时间：14:18:06]
#
# [ok] - [101]-[07998]
# [尝试次数：1] - [剩余数量：357] - [当前时间：14:18:06]
#
# [ok] - [101]-[05764]
# [尝试次数：1] - [剩余数量：356] - [当前时间：14:18:06]
#
# [ok] - [101]-[06623]
# [尝试次数：1] - [剩余数量：355] - [当前时间：14:18:06]
#
# [ok] - [101]-[08659]
# [尝试次数：1] - [剩余数量：354] - [当前时间：14:18:07]
#
# [ok] - [101]-[08388]
# [尝试次数：1] - [剩余数量：353] - [当前时间：14:18:07]
#
# [ok] - [101]-[04533]
# [尝试次数：1] - [剩余数量：352] - [当前时间：14:18:07]
#
# [ok] - [101]-[08974]
# [尝试次数：1] - [剩余数量：351] - [当前时间：14:18:07]
#
# [ok] - [101]-[01629]
# [尝试次数：1] - [剩余数量：350] - [当前时间：14:18:07]
#
# [ok] - [101]-[07642]
# [尝试次数：1] - [剩余数量：349] - [当前时间：14:18:07]
#
# [ok] - [101]-[07612]
# [尝试次数：1] - [剩余数量：348] - [当前时间：14:18:07]
#
# [ok] - [101]-[09045]
# [尝试次数：1] - [剩余数量：347] - [当前时间：14:18:08]
#
# [ok] - [101]-[09465]
# [尝试次数：1] - [剩余数量：346] - [当前时间：14:18:08]
#
# [ok] - [101]-[09046]
# [尝试次数：1] - [剩余数量：345] - [当前时间：14:18:08]
#
# [ok] - [101]-[09483]
# [尝试次数：1] - [剩余数量：344] - [当前时间：14:18:08]
#
# [ok] - [101]-[09491]
# [尝试次数：1] - [剩余数量：343] - [当前时间：14:18:08]
#
# [ok] - [101]-[10124]
# [尝试次数：1] - [剩余数量：342] - [当前时间：14:18:08]
#
# [ok] - [101]-[09044]
# [尝试次数：1] - [剩余数量：341] - [当前时间：14:18:09]
#
# [ok] - [101]-[05955]
# [尝试次数：1] - [剩余数量：340] - [当前时间：14:18:09]
#
# [ok] - [101]-[102688]
# [尝试次数：1] - [剩余数量：339] - [当前时间：14:18:09]
#
# [ok] - [101]-[09838]
# [尝试次数：1] - [剩余数量：338] - [当前时间：14:18:09]
#
# [ok] - [101]-[102691]
# [尝试次数：1] - [剩余数量：337] - [当前时间：14:18:09]
#
# [ok] - [101]-[06624]
# [尝试次数：1] - [剩余数量：336] - [当前时间：14:18:09]
#
# [ok] - [101]-[102739]
# [尝试次数：1] - [剩余数量：335] - [当前时间：14:18:09]
#
# [ok] - [101]-[07999]
# [尝试次数：1] - [剩余数量：334] - [当前时间：14:18:09]
#
# [ok] - [101]-[103324]
# [尝试次数：1] - [剩余数量：333] - [当前时间：14:18:09]
#
# [ok] - [101]-[09771]
# [尝试次数：1] - [剩余数量：332] - [当前时间：14:18:09]
#
# [ok] - [101]-[103304]
# [尝试次数：1] - [剩余数量：331] - [当前时间：14:18:09]
#
# [ok] - [101]-[102146]
# [尝试次数：1] - [剩余数量：330] - [当前时间：14:18:09]
#
# [ok] - [101]-[102702]
# [尝试次数：1] - [剩余数量：329] - [当前时间：14:18:10]
#
# [ok] - [101]-[103117]
# [尝试次数：1] - [剩余数量：328] - [当前时间：14:18:10]
#
# [ok] - [101]-[103397]
# [尝试次数：1] - [剩余数量：327] - [当前时间：14:18:10]
#
# [ok] - [101]-[103316]
# [尝试次数：1] - [剩余数量：326] - [当前时间：14:18:10]
#
# [ok] - [101]-[102700]
# [尝试次数：1] - [剩余数量：325] - [当前时间：14:18:10]
#
# [ok] - [101]-[102880]
# [尝试次数：1] - [剩余数量：324] - [当前时间：14:18:10]
#
# [ok] - [101]-[103441]
# [尝试次数：1] - [剩余数量：323] - [当前时间：14:18:10]
#
# [ok] - [101]-[100502]
# [尝试次数：1] - [剩余数量：322] - [当前时间：14:18:10]
#
# [ok] - [101]-[103683]
# [尝试次数：1] - [剩余数量：321] - [当前时间：14:18:10]
#
# [ok] - [101]-[104411]
# [尝试次数：1] - [剩余数量：320] - [当前时间：14:18:11]
#
# [ok] - [101]-[104266]
# [尝试次数：1] - [剩余数量：319] - [当前时间：14:18:11]
#
# [ok] - [101]-[104385]
# [尝试次数：2] - [剩余数量：318] - [当前时间：14:18:11]
#
# [ok] - [101]-[104444]
# [尝试次数：2] - [剩余数量：317] - [当前时间：14:18:11]
#
# [ok] - [101]-[104689]
# [尝试次数：1] - [剩余数量：316] - [当前时间：14:18:11]
#
# [ok] - [101]-[103682]
# [尝试次数：1] - [剩余数量：315] - [当前时间：14:18:11]
#
# [ok] - [101]-[102404]
# [尝试次数：1] - [剩余数量：314] - [当前时间：14:18:11]
#
# [ok] - [101]-[104415]
# [尝试次数：3] - [剩余数量：313] - [当前时间：14:18:11]
#
# [ok] - [101]-[105897]
# [尝试次数：1] - [剩余数量：312] - [当前时间：14:18:12]
#
# [ok] - [101]-[105684]
# [尝试次数：2] - [剩余数量：311] - [当前时间：14:18:12]
#
# [ok] - [101]-[104384]
# [尝试次数：1] - [剩余数量：310] - [当前时间：14:18:12]
#
# [ok] - [101]-[10689]
# [尝试次数：1] - [剩余数量：309] - [当前时间：14:18:12]
#
# [ok] - [101]-[104204]
# [尝试次数：1] - [剩余数量：308] - [当前时间：14:18:12]
#
# [ok] - [101]-[08740]
# [尝试次数：1] - [剩余数量：307] - [当前时间：14:18:12]
#
# [ok] - [101]-[105508]
# [尝试次数：4] - [剩余数量：306] - [当前时间：14:18:12]
#
# [ok] - [101]-[105748]
# [尝试次数：3] - [剩余数量：305] - [当前时间：14:18:13]
#
# [ok] - [101]-[104410]
# [尝试次数：3] - [剩余数量：304] - [当前时间：14:18:13]
#
# [ok] - [101]-[108133]
# [尝试次数：3] - [剩余数量：303] - [当前时间：14:18:13]
#
# [ok] - [101]-[11678]
# [尝试次数：1] - [剩余数量：302] - [当前时间：14:18:13]
#
# [ok] - [101]-[108156]
# [尝试次数：2] - [剩余数量：301] - [当前时间：14:18:13]
#
# [ok] - [101]-[105746]
# [尝试次数：5] - [剩余数量：300] - [当前时间：14:18:13]
#
# [ok] - [101]-[107967]
# [尝试次数：1] - [剩余数量：299] - [当前时间：14:18:13]
#
# [ok] - [101]-[106927]
# [尝试次数：5] - [剩余数量：298] - [当前时间：14:18:13]
#
# [ok] - [101]-[109373]
# [尝试次数：3] - [剩余数量：297] - [当前时间：14:18:14]
#
# [ok] - [101]-[12276]
# [尝试次数：1] - [剩余数量：296] - [当前时间：14:18:14]
#
# [ok] - [101]-[12052]
# [尝试次数：3] - [剩余数量：295] - [当前时间：14:18:14]
#
# [ok] - [101]-[12022]
# [尝试次数：2] - [剩余数量：294] - [当前时间：14:18:14]
#
# [ok] - [101]-[10125]
# [尝试次数：1] - [剩余数量：293] - [当前时间：14:18:15]
#
# [ok] - [101]-[12050]
# [尝试次数：4] - [剩余数量：292] - [当前时间：14:18:15]
#
# [ok] - [101]-[11107]
# [尝试次数：7] - [剩余数量：291] - [当前时间：14:18:15]
#
# [ok] - [101]-[12505]
# [尝试次数：5] - [剩余数量：290] - [当前时间：14:18:15]
#
# [ok] - [101]-[12690]
# [尝试次数：4] - [剩余数量：289] - [当前时间：14:18:16]
#
# [ok] - [101]-[14193]
# [尝试次数：1] - [剩余数量：288] - [当前时间：14:18:16]
#
# [ok] - [101]-[12346]
# [尝试次数：3] - [剩余数量：287] - [当前时间：14:18:16]
#
# [ok] - [101]-[12506]
# [尝试次数：7] - [剩余数量：286] - [当前时间：14:18:16]
#
# [ok] - [101]-[12734]
# [尝试次数：4] - [剩余数量：285] - [当前时间：14:18:16]
#
# [ok] - [101]-[14921]
# [尝试次数：1] - [剩余数量：284] - [当前时间：14:18:17]
#
# [ok] - [101]-[11685]
# [尝试次数：11] - [剩余数量：283] - [当前时间：14:18:17]
#
# [ok] - [101]-[14192]
# [尝试次数：3] - [剩余数量：282] - [当前时间：14:18:17]
#
# [ok] - [101]-[14918]
# [尝试次数：1] - [剩余数量：281] - [当前时间：14:18:17]
#
# [ok] - [101]-[15485]
# [尝试次数：2] - [剩余数量：280] - [当前时间：14:18:17]
#
# [ok] - [101]-[14189]
# [尝试次数：1] - [剩余数量：279] - [当前时间：14:18:17]
#
# [ok] - [101]-[12733]
# [尝试次数：9] - [剩余数量：278] - [当前时间：14:18:18]
#
# [ok] - [101]-[103443]
# [尝试次数：1] - [剩余数量：277] - [当前时间：14:18:18]
#
# [ok] - [101]-[14492]
# [尝试次数：5] - [剩余数量：276] - [当前时间：14:18:18]
#
# [ok] - [101]-[15486]
# [尝试次数：1] - [剩余数量：275] - [当前时间：14:18:18]
#
# [ok] - [101]-[14599]
# [尝试次数：5] - [剩余数量：274] - [当前时间：14:18:18]
#
# [ok] - [101]-[15645]
# [尝试次数：1] - [剩余数量：273] - [当前时间：14:18:18]
#
# [ok] - [101]-[15673]
# [尝试次数：1] - [剩余数量：272] - [当前时间：14:18:18]
#
# [ok] - [101]-[15788]
# [尝试次数：1] - [剩余数量：271] - [当前时间：14:18:19]
#
# [ok] - [101]-[15692]
# [尝试次数：1] - [剩余数量：270] - [当前时间：14:18:19]
#
# [ok] - [101]-[15643]
# [尝试次数：5] - [剩余数量：269] - [当前时间：14:18:19]
#
# [ok] - [101]-[15671]
# [尝试次数：5] - [剩余数量：268] - [当前时间：14:18:20]
#
# [ok] - [101]-[14491]
# [尝试次数：9] - [剩余数量：267] - [当前时间：14:18:20]
#
# [ok] - [101]-[15789]
# [尝试次数：4] - [剩余数量：266] - [当前时间：14:18:20]
#
# [ok] - [101]-[15937]
# [尝试次数：1] - [剩余数量：265] - [当前时间：14:18:20]
#
# [ok] - [101]-[15487]
# [尝试次数：9] - [剩余数量：264] - [当前时间：14:18:20]
#
# [ok] - [101]-[15910]
# [尝试次数：5] - [剩余数量：263] - [当前时间：14:18:20]
#
# [ok] - [101]-[12799]
# [尝试次数：13] - [剩余数量：262] - [当前时间：14:18:21]
#
# [ok] - [101]-[15693]
# [尝试次数：2] - [剩余数量：261] - [当前时间：14:18:21]
# [ok] - [101]-[172797]
# [尝试次数：1] - [剩余数量：260] - [当前时间：14:18:21]
#
# [ok] - [101]-[170838]
# [尝试次数：1] - [剩余数量：259] - [当前时间：14:18:21]
#
# [ok] - [101]-[172292]
# [尝试次数：2] - [剩余数量：258] - [当前时间：14:18:22]
#
# [ok] - [101]-[173218]
# [尝试次数：1] - [剩余数量：257] - [当前时间：14:18:22]
#
# [ok] - [101]-[15928]
# [尝试次数：6] - [剩余数量：256] - [当前时间：14:18:22]
#
# [ok] - [101]-[15911]
# [尝试次数：9] - [剩余数量：255] - [当前时间：14:18:22]
#
# [ok] - [101]-[173815]
# [尝试次数：1] - [剩余数量：254] - [当前时间：14:18:22]
#
# [ok] - [101]-[05651]
# [尝试次数：1] - [剩余数量：253] - [当前时间：14:18:22]
#
# [ok] - [101]-[15932]
# [尝试次数：11] - [剩余数量：252] - [当前时间：14:18:24]
#
# [ok] - [101]-[173814]
# [尝试次数：4] - [剩余数量：251] - [当前时间：14:18:24]
#
# [ok] - [101]-[12019]
# [尝试次数：4] - [剩余数量：250] - [当前时间：14:18:24]
#
# [ok] - [101]-[173216]
# [尝试次数：6] - [剩余数量：249] - [当前时间：14:18:24]
#
# [ok] - [101]-[175790]
# [尝试次数：2] - [剩余数量：248] - [当前时间：14:18:25]
#
# [ok] - [101]-[175984]
# [尝试次数：1] - [剩余数量：247] - [当前时间：14:18:25]
#
# [ok] - [101]-[173673]
# [尝试次数：1] - [剩余数量：246] - [当前时间：14:18:26]
#
# [ok] - [101]-[175344]
# [尝试次数：1] - [剩余数量：245] - [当前时间：14:18:26]
#
# [ok] - [101]-[172793]
# [尝试次数：10] - [剩余数量：244] - [当前时间：14:18:26]
#
# [ok] - [101]-[176000]
# [尝试次数：1] - [剩余数量：243] - [当前时间：14:18:26]
#
# [ok] - [101]-[176007]
# [尝试次数：2] - [剩余数量：242] - [当前时间：14:18:26]
#
# [ok] - [101]-[174884]
# [尝试次数：6] - [剩余数量：241] - [当前时间：14:18:27]
#
# [ok] - [101]-[176565]
# [尝试次数：1] - [剩余数量：240] - [当前时间：14:18:27]
#
# [ok] - [101]-[170631]
# [尝试次数：10] - [剩余数量：239] - [当前时间：14:18:28]
#
# [ok] - [101]-[176834]
# [尝试次数：1] - [剩余数量：238] - [当前时间：14:18:28]
#
# [ok] - [101]-[176990]
# [尝试次数：1] - [剩余数量：237] - [当前时间：14:18:28]
#
# [ok] - [101]-[176527]
# [尝试次数：3] - [剩余数量：236] - [当前时间：14:18:28]
#
# [ok] - [101]-[176529]
# [尝试次数：1] - [剩余数量：235] - [当前时间：14:18:28]
#
# [ok] - [101]-[177128]
# [尝试次数：1] - [剩余数量：234] - [当前时间：14:18:28]
#
# [ok] - [101]-[17736]
# [尝试次数：1] - [剩余数量：233] - [当前时间：14:18:29]
#
# [ok] - [101]-[178330]
# [尝试次数：2] - [剩余数量：232] - [当前时间：14:18:29]
#
# [ok] - [101]-[178331]
# [尝试次数：1] - [剩余数量：231] - [当前时间：14:18:29]
#
# [ok] - [101]-[178863]
# [尝试次数：1] - [剩余数量：230] - [当前时间：14:18:29]
#
# [ok] - [101]-[175999]
# [尝试次数：3] - [剩余数量：229] - [当前时间：14:18:30]
#
# [ok] - [101]-[179529]
# [尝试次数：1] - [剩余数量：228] - [当前时间：14:18:30]
#
# [ok] - [101]-[179361]
# [尝试次数：1] - [剩余数量：227] - [当前时间：14:18:30]
#
# [ok] - [101]-[179530]
# [尝试次数：1] - [剩余数量：226] - [当前时间：14:18:30]
#
# [ok] - [101]-[180430]
# [尝试次数：1] - [剩余数量：225] - [当前时间：14:18:30]
#
# [ok] - [101]-[176911]
# [尝试次数：1] - [剩余数量：224] - [当前时间：14:18:30]
#
# [ok] - [101]-[180401]
# [尝试次数：1] - [剩余数量：223] - [当前时间：14:18:30]
#
# [ok] - [101]-[176528]
# [尝试次数：1] - [剩余数量：222] - [当前时间：14:18:31]
#
# [ok] - [101]-[180432]
# [尝试次数：1] - [剩余数量：221] - [当前时间：14:18:31]
#
# [ok] - [101]-[181121]
# [尝试次数：1] - [剩余数量：220] - [当前时间：14:18:31]
#
# [ok] - [101]-[180625]
# [尝试次数：2] - [剩余数量：219] - [当前时间：14:18:31]
#
# [ok] - [101]-[179642]
# [尝试次数：2] - [剩余数量：218] - [当前时间：14:18:31]
#
# [ok] - [101]-[181126]
# [尝试次数：1] - [剩余数量：217] - [当前时间：14:18:31]
#
# [ok] - [101]-[18239]
# [尝试次数：1] - [剩余数量：216] - [当前时间：14:18:32]
#
# [ok] - [101]-[181464]
# [尝试次数：1] - [剩余数量：215] - [当前时间：14:18:32]
#
# [ok] - [101]-[18079]
# [尝试次数：3] - [剩余数量：214] - [当前时间：14:18:32]
#
# [ok] - [101]-[18241]
# [尝试次数：1] - [剩余数量：213] - [当前时间：14:18:32]
#
# [ok] - [101]-[181872]
# [尝试次数：3] - [剩余数量：212] - [当前时间：14:18:33]
#
# [ok] - [101]-[181053]
# [尝试次数：2] - [剩余数量：211] - [当前时间：14:18:33]
#
# [ok] - [101]-[182557]
# [尝试次数：1] - [剩余数量：210] - [当前时间：14:18:33]
#
# [ok] - [101]-[182977]
# [尝试次数：2] - [剩余数量：209] - [当前时间：14:18:34]
#
# [ok] - [101]-[183051]
# [尝试次数：3] - [剩余数量：208] - [当前时间：14:18:34]
#
# [ok] - [101]-[182782]
# [尝试次数：1] - [剩余数量：207] - [当前时间：14:18:35]
#
# [ok] - [101]-[182072]
# [尝试次数：7] - [剩余数量：206] - [当前时间：14:18:35]
#
# [ok] - [101]-[183651]
# [尝试次数：1] - [剩余数量：205] - [当前时间：14:18:35]
#
# [ok] - [101]-[183048]
# [尝试次数：1] - [剩余数量：204] - [当前时间：14:18:36]
#
# [ok] - [101]-[183676]
# [尝试次数：1] - [剩余数量：203] - [当前时间：14:18:36]
#
# [ok] - [101]-[183439]
# [尝试次数：1] - [剩余数量：202] - [当前时间：14:18:36]
#
# [ok] - [101]-[183686]
# [尝试次数：1] - [剩余数量：201] - [当前时间：14:18:36]
#
# [ok] - [101]-[184166]
# [尝试次数：1] - [剩余数量：200] - [当前时间：14:18:36]
#
# [ok] - [101]-[184548]
# [尝试次数：1] - [剩余数量：199] - [当前时间：14:18:37]
#
# [ok] - [101]-[174533]
# [尝试次数：2] - [剩余数量：198] - [当前时间：14:18:38]
#
# [ok] - [101]-[183688]
# [尝试次数：1] - [剩余数量：197] - [当前时间：14:18:38]
#
# [ok] - [101]-[184255]
# [尝试次数：1] - [剩余数量：196] - [当前时间：14:18:38]
#
# [ok] - [101]-[184600]
# [尝试次数：1] - [剩余数量：195] - [当前时间：14:18:38]
#
# [ok] - [101]-[184838]
# [尝试次数：1] - [剩余数量：194] - [当前时间：14:18:39]
#
# [ok] - [101]-[184934]
# [尝试次数：1] - [剩余数量：193] - [当前时间：14:18:39]
#
# [ok] - [101]-[183692]
# [尝试次数：1] - [剩余数量：192] - [当前时间：14:18:39]
#
# [ok] - [101]-[184736]
# [尝试次数：1] - [剩余数量：191] - [当前时间：14:18:39]
#
# [ok] - [101]-[184739]
# [尝试次数：1] - [剩余数量：190] - [当前时间：14:18:39]
#
# [ok] - [101]-[187744]
# [尝试次数：1] - [剩余数量：189] - [当前时间：14:18:41]
#
# [ok] - [101]-[188757]
# [尝试次数：1] - [剩余数量：188] - [当前时间：14:18:41]
#
# [ok] - [101]-[184257]
# [尝试次数：2] - [剩余数量：187] - [当前时间：14:18:41]
#
# [ok] - [101]-[193523]
# [尝试次数：1] - [剩余数量：186] - [当前时间：14:18:42]
#
# [ok] - [101]-[183095]
# [尝试次数：3] - [剩余数量：185] - [当前时间：14:18:43]
#
# [ok] - [101]-[188654]
# [尝试次数：1] - [剩余数量：184] - [当前时间：14:18:43]
#
# [ok] - [101]-[185513]
# [尝试次数：1] - [剩余数量：183] - [当前时间：14:18:43]
#
# [ok] - [101]-[19492]
# [尝试次数：1] - [剩余数量：182] - [当前时间：14:18:43]
#
# [ok] - [101]-[18063]
# [尝试次数：6] - [剩余数量：181] - [当前时间：14:18:44]
#
# [ok] - [101]-[19594]
# [尝试次数：1] - [剩余数量：180] - [当前时间：14:18:44]
#
# [ok] - [101]-[19802]
# [尝试次数：1] - [剩余数量：179] - [当前时间：14:18:44]
#
# [ok] - [101]-[19494]
# [尝试次数：1] - [剩余数量：178] - [当前时间：14:18:44]
#
# [ok] - [101]-[19806]
# [尝试次数：1] - [剩余数量：177] - [当前时间：14:18:44]
#
# [ok] - [101]-[19899]
# [尝试次数：1] - [剩余数量：176] - [当前时间：14:18:45]
#
# [ok] - [101]-[19909]
# [尝试次数：1] - [剩余数量：175] - [当前时间：14:18:45]
#
# [ok] - [101]-[19886]
# [尝试次数：1] - [剩余数量：174] - [当前时间：14:18:46]
#
# [ok] - [101]-[19901]
# [尝试次数：1] - [剩余数量：173] - [当前时间：14:18:46]
#
# [ok] - [101]-[183058]
# [尝试次数：2] - [剩余数量：172] - [当前时间：14:18:46]
#
# [ok] - [101]-[21885]
# [尝试次数：1] - [剩余数量：171] - [当前时间：14:18:46]
#
# [ok] - [101]-[21938]
# [尝试次数：1] - [剩余数量：170] - [当前时间：14:18:47]
#
# [ok] - [101]-[22128]
# [尝试次数：1] - [剩余数量：169] - [当前时间：14:18:47]
#
# [ok] - [101]-[19804]
# [尝试次数：1] - [剩余数量：168] - [当前时间：14:18:48]
#
# [ok] - [101]-[21937]
# [尝试次数：1] - [剩余数量：167] - [当前时间：14:18:48]
#
# [ok] - [101]-[22163]
# [尝试次数：1] - [剩余数量：166] - [当前时间：14:18:48]
#
# [ok] - [101]-[19596]
# [尝试次数：1] - [剩余数量：165] - [当前时间：14:18:48]
#
# [ok] - [101]-[185405]
# [尝试次数：1] - [剩余数量：164] - [当前时间：14:18:49]
#
# [ok] - [101]-[19911]
# [尝试次数：1] - [剩余数量：163] - [当前时间：14:18:49]
#
# [ok] - [101]-[22245]
# [尝试次数：1] - [剩余数量：162] - [当前时间：14:18:49]
#
# [ok] - [101]-[22285]
# [尝试次数：1] - [剩余数量：161] - [当前时间：14:18:50]
#
# [ok] - [101]-[22243]
# [尝试次数：1] - [剩余数量：160] - [当前时间：14:18:50]
#
# [ok] - [101]-[173499]
# [尝试次数：3] - [剩余数量：159] - [当前时间：14:18:50]
#
# [ok] - [101]-[22244]
# [尝试次数：1] - [剩余数量：158] - [当前时间：14:18:51]
#
# [ok] - [101]-[22299]
# [尝试次数：1] - [剩余数量：157] - [当前时间：14:18:51]
#
# [ok] - [101]-[22673]
# [尝试次数：1] - [剩余数量：156] - [当前时间：14:18:51]
#
# [ok] - [101]-[22429]
# [尝试次数：1] - [剩余数量：155] - [当前时间：14:18:52]
#
# [ok] - [101]-[22161]
# [尝试次数：1] - [剩余数量：154] - [当前时间：14:18:53]
#
# [ok] - [101]-[22685]
# [尝试次数：1] - [剩余数量：153] - [当前时间：14:18:53]
#
# [ok] - [101]-[22246]
# [尝试次数：1] - [剩余数量：152] - [当前时间：14:18:53]
#
# [ok] - [101]-[22722]
# [尝试次数：1] - [剩余数量：151] - [当前时间：14:18:53]
#
# [ok] - [101]-[22275]
# [尝试次数：1] - [剩余数量：150] - [当前时间：14:18:54]
#
# [ok] - [101]-[22724]
# [尝试次数：1] - [剩余数量：149] - [当前时间：14:18:54]
#
# [ok] - [101]-[22726]
# [尝试次数：1] - [剩余数量：148] - [当前时间：14:18:55]
#
# [ok] - [101]-[22394]
# [尝试次数：1] - [剩余数量：147] - [当前时间：14:18:55]
#
# [ok] - [101]-[22935]
# [尝试次数：1] - [剩余数量：146] - [当前时间：14:18:55]
#
# [ok] - [101]-[22728]
# [尝试次数：1] - [剩余数量：145] - [当前时间：14:18:55]
#
# [ok] - [101]-[22932]
# [尝试次数：1] - [剩余数量：144] - [当前时间：14:18:55]
#
# [ok] - [101]-[22934]
# [尝试次数：1] - [剩余数量：143] - [当前时间：14:18:55]
#
# [ok] - [101]-[22703]
# [尝试次数：1] - [剩余数量：142] - [当前时间：14:18:56]
#
# [ok] - [101]-[23026]
# [尝试次数：1] - [剩余数量：141] - [当前时间：14:18:56]
#
# [ok] - [101]-[23278]
# [尝试次数：1] - [剩余数量：140] - [当前时间：14:18:56]
#
# [ok] - [101]-[23279]
# [尝试次数：1] - [剩余数量：139] - [当前时间：14:18:56]
#
# [ok] - [101]-[23280]
# [尝试次数：1] - [剩余数量：138] - [当前时间：14:18:56]
#
# [ok] - [101]-[23426]
# [尝试次数：1] - [剩余数量：137] - [当前时间：14:18:56]
#
# [ok] - [101]-[23673]
# [尝试次数：1] - [剩余数量：136] - [当前时间：14:18:57]
#
# [ok] - [101]-[23990]
# [尝试次数：1] - [剩余数量：135] - [当前时间：14:18:57]
#
# [ok] - [101]-[23140]
# [尝试次数：1] - [剩余数量：134] - [当前时间：14:18:57]
#
# [ok] - [101]-[19011]
# [尝试次数：1] - [剩余数量：133] - [当前时间：14:18:57]
#
# [ok] - [101]-[24582]
# [尝试次数：1] - [剩余数量：132] - [当前时间：14:18:57]
#
# [ok] - [101]-[24030]
# [尝试次数：1] - [剩余数量：131] - [当前时间：14:18:58]
#
# [ok] - [101]-[23672]
# [尝试次数：1] - [剩余数量：130] - [当前时间：14:18:58]
#
# [ok] - [101]-[23374]
# [尝试次数：1] - [剩余数量：129] - [当前时间：14:18:58]
#
# [ok] - [101]-[22195]
# [尝试次数：1] - [剩余数量：128] - [当前时间：14:18:58]
# [ok] - [101]-[24585]
# [尝试次数：1] - [剩余数量：127] - [当前时间：14:18:59]
#
# [ok] - [101]-[26610]
# [尝试次数：1] - [剩余数量：126] - [当前时间：14:18:59]
#
# [ok] - [101]-[24583]
# [尝试次数：1] - [剩余数量：125] - [当前时间：14:18:59]
#
# [ok] - [101]-[26383]
# [尝试次数：1] - [剩余数量：124] - [当前时间：14:18:59]
#
# [ok] - [101]-[24191]
# [尝试次数：1] - [剩余数量：123] - [当前时间：14:18:59]
#
# [ok] - [101]-[23988]
# [尝试次数：1] - [剩余数量：122] - [当前时间：14:19:00]
#
# [ok] - [101]-[26776]
# [尝试次数：1] - [剩余数量：121] - [当前时间：14:19:00]
#
# [ok] - [101]-[26308]
# [尝试次数：1] - [剩余数量：120] - [当前时间：14:19:00]
#
# [ok] - [101]-[24029]
# [尝试次数：1] - [剩余数量：119] - [当前时间：14:19:01]
#
# [ok] - [101]-[24009]
# [尝试次数：1] - [剩余数量：118] - [当前时间：14:19:01]
#
# [ok] - [101]-[27417]
# [尝试次数：1] - [剩余数量：117] - [当前时间：14:19:02]
#
# [ok] - [101]-[26666]
# [尝试次数：1] - [剩余数量：116] - [当前时间：14:19:02]
#
# [ok] - [101]-[28198]
# [尝试次数：1] - [剩余数量：115] - [当前时间：14:19:02]
#
# [ok] - [101]-[28202]
# [尝试次数：1] - [剩余数量：114] - [当前时间：14:19:02]
#
# [ok] - [101]-[26478]
# [尝试次数：1] - [剩余数量：113] - [当前时间：14:19:02]
#
# [ok] - [101]-[27420]
# [尝试次数：1] - [剩余数量：112] - [当前时间：14:19:03]
#
# [ok] - [101]-[28360]
# [尝试次数：1] - [剩余数量：111] - [当前时间：14:19:03]
#
# [ok] - [101]-[28471]
# [尝试次数：1] - [剩余数量：110] - [当前时间：14:19:03]
#
# [ok] - [101]-[26778]
# [尝试次数：1] - [剩余数量：109] - [当前时间：14:19:03]
#
# [ok] - [101]-[27816]
# [尝试次数：1] - [剩余数量：108] - [当前时间：14:19:03]
#
# [ok] - [101]-[29331]
# [尝试次数：1] - [剩余数量：107] - [当前时间：14:19:03]
#
# [ok] - [101]-[29593]
# [尝试次数：1] - [剩余数量：106] - [当前时间：14:19:04]
#
# [ok] - [101]-[29397]
# [尝试次数：1] - [剩余数量：105] - [当前时间：14:19:04]
#
# [ok] - [101]-[29567]
# [尝试次数：1] - [剩余数量：104] - [当前时间：14:19:04]
#
# [ok] - [101]-[28528]
# [尝试次数：1] - [剩余数量：103] - [当前时间：14:19:04]
#
# [ok] - [101]-[29586]
# [尝试次数：1] - [剩余数量：102] - [当前时间：14:19:04]
#
# [ok] - [101]-[29701]
# [尝试次数：1] - [剩余数量：101] - [当前时间：14:19:04]
#
# [ok] - [101]-[29618]
# [尝试次数：1] - [剩余数量：100] - [当前时间：14:19:04]
#
# [ok] - [101]-[29747]
# [尝试次数：1] - [剩余数量：99] - [当前时间：14:19:05]
#
# [ok] - [101]-[29913]
# [尝试次数：1] - [剩余数量：98] - [当前时间：14:19:05]
#
# [ok] - [101]-[29907]
# [尝试次数：1] - [剩余数量：97] - [当前时间：14:19:05]
#
# [ok] - [101]-[26667]
# [尝试次数：1] - [剩余数量：96] - [当前时间：14:19:05]
#
# [ok] - [101]-[29971]
# [尝试次数：1] - [剩余数量：95] - [当前时间：14:19:05]
#
# [ok] - [101]-[30008]
# [尝试次数：1] - [剩余数量：94] - [当前时间：14:19:05]
#
# [ok] - [101]-[30056]
# [尝试次数：1] - [剩余数量：93] - [当前时间：14:19:05]
#
# [ok] - [101]-[29502]
# [尝试次数：1] - [剩余数量：92] - [当前时间：14:19:05]
#
# [ok] - [101]-[30009]
# [尝试次数：1] - [剩余数量：91] - [当前时间：14:19:06]
#
# [ok] - [101]-[30007]
# [尝试次数：1] - [剩余数量：90] - [当前时间：14:19:06]
#
# [ok] - [101]-[30059]
# [尝试次数：1] - [剩余数量：89] - [当前时间：14:19:06]
#
# [ok] - [101]-[30057]
# [尝试次数：1] - [剩余数量：88] - [当前时间：14:19:06]
#
# [ok] - [101]-[31209]
# [尝试次数：1] - [剩余数量：87] - [当前时间：14:19:07]
#
# [ok] - [101]-[30630]
# [尝试次数：1] - [剩余数量：86] - [当前时间：14:19:07]
#
# [ok] - [101]-[30103]
# [尝试次数：1] - [剩余数量：85] - [当前时间：14:19:07]
#
# [ok] - [101]-[30144]
# [尝试次数：1] - [剩余数量：84] - [当前时间：14:19:07]
#
# [ok] - [101]-[31146]
# [尝试次数：1] - [剩余数量：83] - [当前时间：14:19:07]
#
# [ok] - [101]-[31381]
# [尝试次数：1] - [剩余数量：82] - [当前时间：14:19:08]
#
# [ok] - [101]-[31777]
# [尝试次数：1] - [剩余数量：81] - [当前时间：14:19:08]
#
# [ok] - [101]-[30086]
# [尝试次数：1] - [剩余数量：80] - [当前时间：14:19:08]
#
# [ok] - [101]-[30058]
# [尝试次数：1] - [剩余数量：79] - [当前时间：14:19:08]
#
# [ok] - [101]-[32273]
# [尝试次数：1] - [剩余数量：78] - [当前时间：14:19:08]
#
# [ok] - [101]-[04111]
# [尝试次数：2] - [剩余数量：77] - [当前时间：14:19:08]
#
# [ok] - [101]-[31776]
# [尝试次数：1] - [剩余数量：76] - [当前时间：14:19:09]
#
# [ok] - [101]-[31980]
# [尝试次数：1] - [剩余数量：75] - [当前时间：14:19:09]
#
# [ok] - [101]-[32124]
# [尝试次数：1] - [剩余数量：74] - [当前时间：14:19:09]
#
# [ok] - [101]-[31986]
# [尝试次数：1] - [剩余数量：73] - [当前时间：14:19:09]
#
# [ok] - [101]-[32282]
# [尝试次数：1] - [剩余数量：72] - [当前时间：14:19:10]
#
# [ok] - [101]-[32284]
# [尝试次数：1] - [剩余数量：71] - [当前时间：14:19:10]
#
# [ok] - [101]-[31957]
# [尝试次数：1] - [剩余数量：70] - [当前时间：14:19:10]
#
# [ok] - [101]-[32275]
# [尝试次数：1] - [剩余数量：69] - [当前时间：14:19:10]
#
# [ok] - [101]-[32286]
# [尝试次数：1] - [剩余数量：68] - [当前时间：14:19:11]
#
# [ok] - [101]-[32285]
# [尝试次数：1] - [剩余数量：67] - [当前时间：14:19:11]
#
# [ok] - [101]-[32716]
# [尝试次数：1] - [剩余数量：66] - [当前时间：14:19:11]
#
# [ok] - [101]-[32515]
# [尝试次数：1] - [剩余数量：65] - [当前时间：14:19:11]
#
# [ok] - [101]-[32280]
# [尝试次数：1] - [剩余数量：64] - [当前时间：14:19:11]
#
# [ok] - [101]-[32967]
# [尝试次数：1] - [剩余数量：63] - [当前时间：14:19:12]
#
# [ok] - [101]-[33724]
# [尝试次数：1] - [剩余数量：62] - [当前时间：14:19:12]
#
# [ok] - [101]-[33962]
# [尝试次数：1] - [剩余数量：61] - [当前时间：14:19:12]
#
# [ok] - [101]-[33392]
# [尝试次数：1] - [剩余数量：60] - [当前时间：14:19:13]
#
# [ok] - [101]-[34307]
# [尝试次数：1] - [剩余数量：59] - [当前时间：14:19:13]
#
# [ok] - [101]-[32274]
# [尝试次数：1] - [剩余数量：58] - [当前时间：14:19:13]
#
# [ok] - [101]-[33982]
# [尝试次数：1] - [剩余数量：57] - [当前时间：14:19:13]
#
# [ok] - [101]-[34145]
# [尝试次数：1] - [剩余数量：56] - [当前时间：14:19:13]
#
# [ok] - [101]-[34719]
# [尝试次数：1] - [剩余数量：55] - [当前时间：14:19:14]
#
# [ok] - [101]-[34390]
# [尝试次数：1] - [剩余数量：54] - [当前时间：14:19:14]
#
# [ok] - [101]-[34797]
# [尝试次数：2] - [剩余数量：53] - [当前时间：14:19:14]
#
# [ok] - [101]-[36611]
# [尝试次数：1] - [剩余数量：52] - [当前时间：14:19:15]
#
# [ok] - [101]-[33722]
# [尝试次数：1] - [剩余数量：51] - [当前时间：14:19:15]
#
# [ok] - [101]-[36682]
# [尝试次数：1] - [剩余数量：50] - [当前时间：14:19:16]
#
# [ok] - [101]-[36906]
# [尝试次数：1] - [剩余数量：49] - [当前时间：14:19:16]
#
# [ok] - [101]-[26665]
# [尝试次数：1] - [剩余数量：48] - [当前时间：14:19:17]
#
# [ok] - [101]-[36814]
# [尝试次数：1] - [剩余数量：47] - [当前时间：14:19:17]
#
# [ok] - [101]-[21886]
# [尝试次数：1] - [剩余数量：46] - [当前时间：14:19:17]
#
# [ok] - [101]-[36908]
# [尝试次数：1] - [剩余数量：45] - [当前时间：14:19:17]
#
# [ok] - [101]-[36813]
# [尝试次数：2] - [剩余数量：44] - [当前时间：14:19:17]
#
# [ok] - [101]-[36972]
# [尝试次数：1] - [剩余数量：43] - [当前时间：14:19:18]
#
# [ok] - [101]-[36973]
# [尝试次数：1] - [剩余数量：42] - [当前时间：14:19:18]
#
# [ok] - [101]-[37244]
# [尝试次数：1] - [剩余数量：41] - [当前时间：14:19:18]
#
# [ok] - [101]-[37099]
# [尝试次数：1] - [剩余数量：40] - [当前时间：14:19:18]
#
# [ok] - [101]-[32698]
# [尝试次数：1] - [剩余数量：39] - [当前时间：14:19:18]
#
# [ok] - [101]-[37014]
# [尝试次数：1] - [剩余数量：38] - [当前时间：14:19:18]
#
# [ok] - [101]-[02230]
# [尝试次数：2] - [剩余数量：37] - [当前时间：14:19:19]
#
# [ok] - [101]-[37245]
# [尝试次数：1] - [剩余数量：36] - [当前时间：14:19:19]
#
# [ok] - [101]-[37438]
# [尝试次数：1] - [剩余数量：35] - [当前时间：14:19:19]
#
# [ok] - [101]-[36971]
# [尝试次数：1] - [剩余数量：34] - [当前时间：14:19:19]
#
# [ok] - [101]-[38522]
# [尝试次数：1] - [剩余数量：33] - [当前时间：14:19:20]
#
# [ok] - [101]-[38413]
# [尝试次数：2] - [剩余数量：32] - [当前时间：14:19:20]
#
# [ok] - [101]-[33961]
# [尝试次数：2] - [剩余数量：31] - [当前时间：14:19:20]
#
# [ok] - [101]-[38534]
# [尝试次数：1] - [剩余数量：30] - [当前时间：14:19:21]
#
# [ok] - [101]-[06469]
# [尝试次数：3] - [剩余数量：29] - [当前时间：14:19:21]
#
# [ok] - [101]-[30143]
# [尝试次数：2] - [剩余数量：28] - [当前时间：14:19:21]
#
# [ok] - [101]-[38133]
# [尝试次数：1] - [剩余数量：27] - [当前时间：14:19:21]
#
# [ok] - [101]-[38784]
# [尝试次数：2] - [剩余数量：26] - [当前时间：14:19:22]
#
# [ok] - [101]-[38524]
# [尝试次数：1] - [剩余数量：25] - [当前时间：14:19:22]
#
# [ok] - [101]-[38515]
# [尝试次数：6] - [剩余数量：24] - [当前时间：14:19:22]
#
# [ok] - [101]-[39280]
# [尝试次数：1] - [剩余数量：23] - [当前时间：14:19:22]
#
# [ok] - [101]-[39282]
# [尝试次数：1] - [剩余数量：22] - [当前时间：14:19:22]
#
# [ok] - [101]-[36627]
# [尝试次数：1] - [剩余数量：21] - [当前时间：14:19:22]
#
# [ok] - [101]-[39002]
# [尝试次数：5] - [剩余数量：20] - [当前时间：14:19:22]
#
# [ok] - [101]-[39642]
# [尝试次数：1] - [剩余数量：19] - [当前时间：14:19:22]
#
# [ok] - [101]-[40454]
# [尝试次数：1] - [剩余数量：18] - [当前时间：14:19:22]
#
# [ok] - [101]-[37569]
# [尝试次数：2] - [剩余数量：17] - [当前时间：14:19:23]
#
# [ok] - [101]-[44495]
# [尝试次数：2] - [剩余数量：16] - [当前时间：14:19:23]
#
# [ok] - [101]-[39281]
# [尝试次数：2] - [剩余数量：15] - [当前时间：14:19:24]
#
# [ok] - [101]-[44551]
# [尝试次数：1] - [剩余数量：14] - [当前时间：14:19:24]
#
# [ok] - [101]-[38525]
# [尝试次数：2] - [剩余数量：13] - [当前时间：14:19:24]
#
# [ok] - [101]-[39866]
# [尝试次数：4] - [剩余数量：12] - [当前时间：14:19:24]
#
# [ok] - [101]-[44497]
# [尝试次数：2] - [剩余数量：11] - [当前时间：14:19:24]
#
# [ok] - [101]-[44922]
# [尝试次数：2] - [剩余数量：10] - [当前时间：14:19:25]
#
# [ok] - [101]-[45414]
# [尝试次数：1] - [剩余数量：9] - [当前时间：14:19:26]
#
# [ok] - [101]-[45587]
# [尝试次数：1] - [剩余数量：8] - [当前时间：14:19:26]
#
# [ok] - [101]-[44884]
# [尝试次数：2] - [剩余数量：7] - [当前时间：14:19:26]
#
# [ok] - [101]-[40065]
# [尝试次数：2] - [剩余数量：6] - [当前时间：14:19:26]
#
# [ok] - [101]-[44733]
# [尝试次数：1] - [剩余数量：5] - [当前时间：14:19:26]
#
# [ok] - [101]-[44921]
# [尝试次数：2] - [剩余数量：4] - [当前时间：14:19:26]
#
# [ok] - [101]-[46605]
# [尝试次数：1] - [剩余数量：3] - [当前时间：14:19:27]
#
# [ok] - [101]-[47562]
# [尝试次数：1] - [剩余数量：2] - [当前时间：14:19:27]
#
# [ok] - [101]-[47652]
# [尝试次数：1] - [剩余数量：1] - [当前时间：14:19:27]
#
# [ok] - [101]-[46606]
# [尝试次数：1] - [剩余数量：0] - [当前时间：14:19:28]
#
# [ok] - [101]-[40066]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:28]
#
# [ok] - [101]-[48922]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:28]
#
# [ok] - [101]-[11502]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:29]
#
# [ok] - [101]-[46607]
# [尝试次数：2] - [剩余数量：0] - [当前时间：14:19:29]
#
# [ok] - [101]-[49412]
# [尝试次数：4] - [剩余数量：0] - [当前时间：14:19:29]
#
# [ok] - [101]-[35467]
# [尝试次数：2] - [剩余数量：0] - [当前时间：14:19:29]
#
# [ok] - [101]-[11937]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:30]
# [ok] - [101]-[49215]
# [尝试次数：5] - [剩余数量：0] - [当前时间：14:19:30]
#
# [ok] - [101]-[44496]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:32]
#
# [ok] - [101]-[15527]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:34]
#
# [ok] - [101]-[44423]
# [尝试次数：5] - [剩余数量：0] - [当前时间：14:19:36]
#
# [ok] - [101]-[173635]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:39]
#
# [ok] - [101]-[174193]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:39]
#
# [ok] - [101]-[171789]
# [尝试次数：2] - [剩余数量：0] - [当前时间：14:19:41]
#
# [ok] - [101]-[43721]
# [尝试次数：1] - [剩余数量：0] - [当前时间：14:19:53]
#
# [ok] - [101]-[07654]
# [尝试次数：3] - [剩余数量：0] - [当前时间：14:19:55]
#
# [ok] - [101]-[32281]
# [尝试次数：2] - [剩余数量：0] - [当前时间：14:20:31]
#
# [ok] - [101]-[45608]
# [尝试次数：2] - [剩余数量：0] - [当前时间：14:20:42]
#
# [ok] - [101]-[44371]
# [尝试次数：5] - [剩余数量：0] - [当前时间：14:21:55]
#
# 输出ing...
#
# Done ~
