# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20231024.xlsx

# %%
import pandas as pd

# %%
table_1 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(1, 9)]).loc[:4]

table_1
# Out:
#       层级   SKU 总数  在库为0（断货数）  在库1-2（干预数）       断货率       干预率  近期海运上架后断货数  \
# 0   TOP1    895.0       59.0        50.0  0.065922  0.055866        30.0
# 1  TOP10   2206.0      169.0       119.0  0.076609  0.053944        81.0
# 2  TOP20   4668.0      339.0       399.0  0.072622  0.085476       154.0
# 3     普通  53024.0     4215.0      8992.0  0.079492  0.169584      2528.0
# 4     总数  60793.0     4782.0      9560.0  0.078660  0.157255      2793.0
#
#    近期海运上架后断货率
# 0    0.033520
# 1    0.036718
# 2    0.032991
# 3    0.047677
# 4    0.045943

# %%
table_2 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(10, 17)]).loc[:4]

table_2
# Out:
#     层级.1  在库为0（断货）   断货无在途        占比  在库1-2（干预）   干预无在途      占比.1
# 0   TOP1      59.0    24.0  0.406780       50.0    17.0  0.340000
# 1  TOP10     169.0    64.0  0.378698      119.0    35.0  0.294118
# 2  TOP20     339.0   101.0  0.297935      399.0    87.0  0.218045
# 3     普通    4215.0  1754.0  0.416133     8992.0  4401.0  0.489435
# 4     总数    4782.0  1943.0  0.406315     9560.0  4540.0  0.474895

# %%
table_3 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(18, 27)]).loc[:4]

table_3
# Out:
#     层级.2  W35\n08/30  W36\n09/05  W36\n09/09  W37\n09/13  W39\n09/27  \
# 0   TOP1        25.0        28.0        23.0        49.0        83.0
# 1  TOP10        97.0        99.0        98.0        49.0       168.0
# 2  TOP20       317.0       328.0       340.0       297.0       374.0
# 3     普通      2978.0      2974.0      3151.0      3623.0      3711.0
# 4     总数      3417.0      3429.0      3612.0      4018.0      4336.0
#
#    W41\n10/09  W42\n10/17  W43\n10/24
# 0        62.0        71.0        59.0
# 1       140.0       161.0       169.0
# 2       308.0       326.0       339.0
# 3      3795.0      4144.0      4215.0
# 4      4305.0      4702.0      4782.0

# %%
table_4 = pd.read_excel(calculate,
                        sheet_name='1_断货数据分析',
                        header=1,
                        usecols=[i for i in range(28, 33)],
                        index_col=0)

table_4
# Out:
#          品类  断货SKU数量  总SKU数      断货占比
# 排名
# TOP1     CA      497   4790  0.103758
# TOP2     BC      375   2935  0.127768
# TOP3    CVA      197   2163  0.091077
# TOP4    ABS      162   1418  0.114245
# TOP5     WR      162   2062  0.078565
# ...     ...      ...    ...       ...
# TOP443  EGR        0     83  0.000000
# TOP444  ACS        0     94  0.000000
# TOP445  PAS        0     97  0.000000
# TOP446   DH        0    106  0.000000
# TOP447   SP        0    251  0.000000
#
# [447 rows x 4 columns]

# %%
sheet_2_left = pd.read_excel(calculate,
                             sheet_name='2_断货SKU',
                             header=1,
                             usecols=[i for i in range(5)],
                             index_col=0)

sheet_2_left
# Out:
#                 SKU     层级    周销  在途
# 序号
# 1    USACC06390S-C1   TOP1  2.55   0
# 2     USACC11340-C1   TOP1  1.41   0
# 3     USACC29221-C1   TOP1  3.61   0
# 4     USACC30011-C1   TOP1  1.07   0
# 5     USACC32024-C1   TOP1  2.98   0
# ..              ...    ...   ...  ..
# 187     USWP03071-C  TOP20  0.33   0
# 188       USWR41685  TOP20  1.70   0
# 189    USWR48974S-C  TOP20  0.27   0
# 190       USWR49322  TOP20  1.27   0
# 191      USWSL66409  TOP20  2.55   0
#
# [191 rows x 4 columns]

# %%
sheet_2_right = pd.read_excel(calculate,
                              sheet_name='2_断货SKU',
                              header=1,
                              usecols=[i for i in range(7, 9)],
                              index_col=0).dropna().sort_values(by=['断货数'], ascending=False)

sheet_2_right
# Out:
#         断货数
# 品类去重
# ACC    41.0
# CA     24.0
# STR    11.0
# BC     10.0
# EM      7.0
# BMC     6.0
# SKA     5.0
# WR      5.0
# PBB     4.0
# WM      4.0
# PSR     4.0
# HB      4.0
# CVA     4.0
# ALT     4.0
# ACH     4.0
# ABS     3.0
# CON     3.0
# SA      3.0
# HLS     2.0
# WP      2.0
# PSH     2.0
# HMB     2.0
# TBC     2.0
# FI      2.0
# DLA     2.0
# DAM     2.0
# BHH     2.0
# EMD     2.0
# TH      1.0
# RBM     1.0
# SCS     1.0
# SM      1.0
# STW     1.0
# TLA     1.0
# THA     1.0
# OS      1.0
# VAP     1.0
# WGA     1.0
# WLA     1.0
# RAD     1.0
# OC      1.0
# OP      1.0
# MI      1.0
# LGH     1.0
# KS      1.0
# HCR     1.0
# FC      1.0
# CS-弹簧   1.0
# BT      1.0
# BRPS    1.0
# BPD     1.0
# BM      1.0
# WSL     1.0

# %%
print(int(table_1.loc[4, '在库为0（断货数）']), end='; ')
print(str(round(table_1.loc[4, '断货率']*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['断货率'].tolist().index(max(table_1['断货率'])), '层级'], end='; ')
print(str(round(max(table_1['断货率'])*100, 2)) + '%', end='; ')
print(table_1.loc[table_1['干预率'].tolist().index(max(table_1['干预率'])), '层级'], end='; ')
print(str(round(max(table_1['干预率'])*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left), end='; ')
print(sheet_2_right['断货数'].index[0], end='; ')
print(sheet_2_right['断货数'].index[1], end='; ')
print(sheet_2_right['断货数'].index[2], end='; ')
print(int(sheet_2_right.iloc[0, 0]), end='; ')
print(int(sheet_2_right.iloc[1, 0]), end='; ')
print(int(sheet_2_right.iloc[2, 0]))
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(len(sheet_2_left[sheet_2_left['层级']=='TOP1']))
# Out:
# 4782; 7.87%; 普通; 7.95%; 普通; 16.96%
#
# = = = = = = = = = = = = = = = = = =
#
# 191; ACC; CA; STR; 41; 24; 11
#
# = = = = = = = = = = = = = = = = = =
#
# 24

# %%
print(int(table_2.loc[4, '在库为0（断货）']), end='; ')
print(int(table_2.loc[4, '断货无在途']), end='; ')
print(str(round(table_2.loc[4, '占比']*100, 2)) + '%', end='; ')
print(int(table_2.loc[4, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[4, '干预无在途']), end='; ')
print(str(round(table_2.loc[4, '占比.1']*100, 2)) + '%')
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(int(table_2.loc[0, '在库1-2（干预）']), end='; ')
print(int(table_2.loc[0, '干预无在途']))
# Out:
# 4782; 1943; 40.63%; 9560; 4540; 47.49%
#
# = = = = = = = = = = = = = = = = = =
#
# 50; 17

# %%
print('TOP1: ' + str(int(table_3.iloc[0, 8] - table_3.iloc[0, 7])))
print('TOP10: ' + str(int(table_3.iloc[1, 8] - table_3.iloc[1, 7])))
print('TOP20: ' + str(int(table_3.iloc[2, 8] - table_3.iloc[2, 7])))
print('普通: ' + str(int(table_3.iloc[3, 8] - table_3.iloc[3, 7])))
# Out:
# TOP1: -12
# TOP10: 8
# TOP20: 13
# 普通: 71

# %%
print(table_4.loc['TOP1', '品类'], end='; ')
print(table_4.loc['TOP1', '断货SKU数量'])
print()
print('= = = = = = = = = = = = = = = = = =')
print()
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 2], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 0], end='; ')
print(table_4.iloc[table_4['断货占比'][:10].tolist().index(max(table_4['断货占比'][:10])), 1], end='; ')
print(str(round(max(table_4['断货占比'][:10])*100, 2)) + '%')
# Out:
# CA; 497
#
# = = = = = = = = = = = = = = = = = =
#
# ALT; 1015; ALT; 156; 15.37%

# %%
共23款TOP1层级SKU库存1-2，且有1款无在途。
# Out:
#   Cell In[14], line 1
#     共23款TOP1层级SKU库存1-2，且有1款无在途。
#                      ^
# SyntaxError: invalid decimal literal

# %%
（1）与W24周（06/17）相比，W26周（07/01）TOP1断货有所上升，达3款；
（2）TOP10、TOP20和普通层级断货有所下降，其中普通层级断货下降最多，达73款。

# %%
（1）W27周（07/07）断货整体比W27周（07/05）有所下降，其中普通层级断货下降最多，达183款；
（2）在重点SKU（TOP1、TOP10、TOP20）中，TOP10断货下降最多，达17款。
