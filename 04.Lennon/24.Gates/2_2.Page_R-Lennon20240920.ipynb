# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/2.page'):
    shutil.rmtree('./file/2.page')

os.makedirs('./file/2.page')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import time

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

import math

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/1.product'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/1.product/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['Product No'] = input_['Product No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                if input_.loc[a, 'Country'] == 'US':
                    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_en_string', 'productnumber_en_string', 'name_text_en', 'en', 'us', 'en'
                elif input_.loc[a, 'Country'] == 'DE':
                    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_de_string', 'productnumber_de_string', 'name_text_de', 'de', 'de', 'de'
                elif input_.loc[a, 'Country'] == 'UK':
                    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'partnumberauto_en_gb_string', 'productnumber_en_gb_string', 'name_text_en_gb', 'en_gb', 'gb', 'en'
                else:
                    partnumberauto_string, productnumber_string, name_text, lang, country, lang_2 = 'fuck', 'fuck', 'fuck', 'fuck', 'fuck', 'fuck'

                b = 0
                while True:
                    b += 1
                    
                    try:
                        request_url = f'''https://www.gates.com/bin/listing/products/variant?draw=1&columns%5B0%5D%5Bdata%5D=&columns%5B0%5D%5Bname%5D={partnumberauto_string}&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=&columns%5B1%5D%5Bname%5D={productnumber_string}&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D={name_text}&columns%5B2%5D%5Bname%5D={name_text}&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=1&order%5B0%5D%5Bdir%5D=asc&start=0&length=10&search%5Bvalue%5D=&search%5Bregex%5D=false&id={input_.loc[a, 'Product Number']}&lang={lang}&country={country}&fieldList=code_string,{partnumberauto_string},{productnumber_string},{name_text}&filters=&_={int(time.time() * 1000)}'''
                        check_url = f'''https://www.gates.com/{country}/{lang_2}/search.p.{input_.loc[a, 'Product Number']}.html'''
        
                        resp = requests.get(request_url,
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            dict_ = resp.json()
                            
                            if dict_:
                                break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                if int(dict_['recordsTotal'].strip()) <= 0:
                    raise

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'Product No': input_.loc[a, 'Product No'],
                                         'Product Name': input_.loc[a, 'Product Name'],
                                         'Product Number': input_.loc[a, 'Product Number'],
                                         'Country': input_.loc[a, 'Country'],
                                         'SKU Count': int(dict_['recordsTotal'].strip()),
                                         'Page': math.ceil(int(dict_['recordsTotal'].strip()) / 10)}])
                
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
                df_temp.loc[0, 'Request_Url'] = request_url
                df_temp.loc[0, 'Check_Url'] = check_url

                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
                
            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Product No']}.{input_.loc[a, 'Product Name']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['Product No'],
                                                    ascending=[True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/2.page/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['Product No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-page_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.page'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/2.page/{file}',
              f'''./file/2.page/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：1
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 1.PowerGrip™ Timing Kits
# [剩余数量：0] - [当前时间：13:34:32]
#
# 输出ing...
#
# 总数量：100
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 5.4219BD Barricade™ Bio-Diesel Fuel
# [剩余数量：95] - [当前时间：13:34:34]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 2.12 Reel
# [剩余数量：94] - [当前时间：13:34:34]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 3.12 Reel
# [剩余数量：93] - [当前时间：13:34:36]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 1.1-1/4" Special One-Piece Couplings - Female JIC 37° Flare Swivel
# [剩余数量：92] - [当前时间：13:34:36]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 7.4219BG Barricade™ Carbureted Engines Fuel
# [剩余数量：91] - [当前时间：13:34:37]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 6.4219BF Barricade™ GreenShield™ Fuel
# [剩余数量：90] - [当前时间：13:34:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 10.90° Molded Heater
# [剩余数量：89] - [当前时间：13:34:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 8.45° Silicone Coolant
# [剩余数量：88] - [当前时间：13:34:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 9.90° Curved Silicone
# [剩余数量：87] - [当前时间：13:34:40]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 12.ACC-PSII Air Conditioning PolarSeal™ II
# [剩余数量：86] - [当前时间：13:34:41]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 11.AC134A Air Conditioning PolarSeal™ I
# [剩余数量：85] - [当前时间：13:34:41]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 14.Air Brake Assortments
# [剩余数量：84] - [当前时间：13:34:41]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 16.Air Brake Coupling Sleeve
# [剩余数量：83] - [当前时间：13:34:43]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 17.Air Brake Coupling Spring Guard Nut
# [剩余数量：82] - [当前时间：13:34:43]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 15.Air Brake Coupling Nut
# [剩余数量：81] - [当前时间：13:34:44]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 19.Air Brake Couplings Union
# [剩余数量：80] - [当前时间：13:34:45]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 13.Ag Master™ PVC Solution
# [剩余数量：79] - [当前时间：13:34:45]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 18.Air Brake Couplings Spring Guard
# [剩余数量：78] - [当前时间：13:34:46]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 20.Air Brake Couplings to Female Air Brake Couplings Swivel
# [剩余数量：77] - [当前时间：13:34:46]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 4.4217IS Standard Diesel Emission Fluid
# [剩余数量：76] - [当前时间：13:34:46]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 21.Air Brake Couplings to Female Air Brake Couplings Swivel with Adapter
# [剩余数量：75] - [当前时间：13:34:47]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 23.Air Brake Couplings to Male Pipe with Nut and Sleeve
# [剩余数量：74] - [当前时间：13:34:47]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 24.Air Brake Couplings to Male Pipe with Spring Guard
# [剩余数量：73] - [当前时间：13:34:48]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 25.Air Brake Couplings to Male Pipe without Nut and Sleeve
# [剩余数量：72] - [当前时间：13:34:48]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 27.Air Brake Male Pipe to Female Pipe Bulkhead
# [剩余数量：71] - [当前时间：13:34:49]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 26.Air Brake
# [剩余数量：70] - [当前时间：13:34:49]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 29.Air Master™ Diving Umbilical
# [剩余数量：69] - [当前时间：13:34:50]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 32.Barb Stem Couplings
# [剩余数量：68] - [当前时间：13:34:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 28.Air Duct
# [剩余数量：67] - [当前时间：13:34:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 31.Angled Fuel Fill
# [剩余数量：66] - [当前时间：13:34:52]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 34.Barricade™ Carburetion
# [剩余数量：65] - [当前时间：13:34:54]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 33.Barricade™ Carburetion
# [剩余数量：64] - [当前时间：13:34:55]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 30.Aluminum
# [剩余数量：63] - [当前时间：13:34:55]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 35.Barricade™ Fuel Injection
# [剩余数量：62] - [当前时间：13:34:56]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 22.Air Brake Couplings to Male Pipe Adapter
# [剩余数量：61] - [当前时间：13:34:57]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 38.Black Gold™ ABS Bulk Material - 300SD
# [剩余数量：60] - [当前时间：13:34:57]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 37.Barricade™ Fuel Injection
# [剩余数量：59] - [当前时间：13:34:58]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 39.Black Gold™ ABS Mud and Oil
# [剩余数量：58] - [当前时间：13:34:58]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 40.Black Gold™ Fuel
# [剩余数量：57] - [当前时间：13:34:59]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 41.Black Gold™ Oilfield Frac
# [剩余数量：56] - [当前时间：13:34:59]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 42.Black Gold™ Oilfield Service
# [剩余数量：55] - [当前时间：13:34:59]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 45.Black Gold™ Potable Water
# [剩余数量：54] - [当前时间：13:35:00]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 43.Black Gold™ Oilfield Service 400D MegaTuff
# [剩余数量：53] - [当前时间：13:35:01]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 44.Black Gold™ Oilfield Vacuum
# [剩余数量：52] - [当前时间：13:35:01]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 48.Bulk Master™ PVC
# [剩余数量：51] - [当前时间：13:35:03]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 49.C14
# [剩余数量：50] - [当前时间：13:35:03]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 46.Braid Stainless Steel Couplings
# [剩余数量：49] - [当前时间：13:35:03]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 47.Brass Lock-On Field Attachable Couplings for LOC and LOL
# [剩余数量：48] - [当前时间：13:35:04]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 50.C14 Swage Equipment
# [剩余数量：47] - [当前时间：13:35:05]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 36.Barricade™ Fuel Injection
# [剩余数量：46] - [当前时间：13:35:06]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 52.C5C-XH XTreme™ Heat Hydraulic
# [剩余数量：45] - [当前时间：13:35:06]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 53.C5D Hydraulic
# [剩余数量：44] - [当前时间：13:35:06]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 51.C5C Hydraulic
# [剩余数量：43] - [当前时间：13:35:07]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 57.CR1 1-Wire Braid
# [剩余数量：42] - [当前时间：13:35:10]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 59.Cam Gear Sprocket Tool
# [剩余数量：41] - [当前时间：13:35:12]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 60.Charter™ Air
# [剩余数量：40] - [当前时间：13:35:13]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 58.CR2 2-Wire Braid
# [剩余数量：39] - [当前时间：13:35:18]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 62.Chem Master™ Plus XLPE
# [剩余数量：38] - [当前时间：13:35:20]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 63.Clean Master™ 3000
# [剩余数量：37] - [当前时间：13:35:24]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 64.Clean Master™ PW4000
# [剩余数量：36] - [当前时间：13:35:26]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 61.Chem Master™ Hydrocarbon Drain
# [剩余数量：35] - [当前时间：13:35:27]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 56.CM2T Wire Braid
# [剩余数量：34] - [当前时间：13:35:27]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 66.Clean Master™ Pressure Wash
# [剩余数量：33] - [当前时间：13:35:29]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 65.Clean Master™ Plus PW6000
# [剩余数量：32] - [当前时间：13:35:29]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 54.C5E Hydraulic
# [剩余数量：31] - [当前时间：13:35:30]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 55.C5M Hydraulic
# [剩余数量：30] - [当前时间：13:35:30]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 70.Conductive C14 PTFE
# [剩余数量：29] - [当前时间：13:35:31]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 69.Coal Power/Longwall Mine
# [剩余数量：28] - [当前时间：13:35:32]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 68.Coal Power/Longwall Mine
# [剩余数量：27] - [当前时间：13:35:32]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 72.D.O.T. Type A2 Field Attachable Couplings
# [剩余数量：26] - [当前时间：13:35:33]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 71.D.O.T. Type A1 Field Attachable Couplings
# [剩余数量：25] - [当前时间：13:35:33]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 73.Data Center Cooling
# [剩余数量：24] - [当前时间：13:35:34]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 74.Dual I.D. Heater
# [剩余数量：23] - [当前时间：13:35:34]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 67.Clean Master™ Washdown
# [剩余数量：22] - [当前时间：13:35:34]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 76.EF Coal Power/Longwall Mine
# [剩余数量：21] - [当前时间：13:35:35]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 75.EF Coal Power/Longwall Mine
# [剩余数量：20] - [当前时间：13:35:35]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 78.EF Longwall Mine
# [剩余数量：19] - [当前时间：13:35:35]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 82.EFG4K-MTF Spiral Wire
# [剩余数量：18] - [当前时间：13:35:37]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 80.EFG3K-MTF Spiral Wire
# [剩余数量：17] - [当前时间：13:35:37]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 77.EF Longwall Mine
# [剩余数量：16] - [当前时间：13:35:37]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 83.EFG4K-XTF Spiral Wire
# [剩余数量：15] - [当前时间：13:35:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 85.EFG5K Spiral Wire
# [剩余数量：14] - [当前时间：13:35:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 84.EFG4KL Spiral Wire
# [剩余数量：13] - [当前时间：13:35:39]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 86.EFG5K-MTF Spiral Wire
# [剩余数量：12] - [当前时间：13:35:40]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 87.EFG5K-XTF Spiral Wire
# [剩余数量：11] - [当前时间：13:35:41]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 88.EFG5KL Spiral Wire
# [剩余数量：10] - [当前时间：13:35:41]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 91.EFG6KL Spiral Wire
# [剩余数量：9] - [当前时间：13:35:43]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 90.EFG6K-MTF Spiral Wire
# [剩余数量：8] - [当前时间：13:35:43]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 89.EFG6K Spiral Wire
# [剩余数量：7] - [当前时间：13:35:44]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 92.Emission
# [剩余数量：6] - [当前时间：13:35:45]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 93.Engine Air Intake
# [剩余数量：5] - [当前时间：13:35:46]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 95.Field Attachable Type T for G1
# [剩余数量：4] - [当前时间：13:35:48]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 81.EFG4K Spiral Wire
# [剩余数量：3] - [当前时间：13:35:49]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 96.Field Attachable Type T for G2
# [剩余数量：2] - [当前时间：13:35:49]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 97.Flange Kits
# [剩余数量：1] - [当前时间：13:35:49]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 94.Engine Coolant Soft Wall
# [剩余数量：0] - [当前时间：13:35:50]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 99.Food Master™ Beverage 150SD CR
# [剩余数量：0] - [当前时间：13:35:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 100.Food Master™ Beverage 250SD CR
# [剩余数量：0] - [当前时间：13:35:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 98.Flexible Fuel Fill
# [剩余数量：0] - [当前时间：13:35:52]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_2 > 79.EFG3K Spiral Wire
# [剩余数量：0] - [当前时间：13:35:56]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 3802.63it/s]
# Done ~
