# %%
param_date = '20240621'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./{param_date}/part.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_.drop_duplicates(['Info'], keep='first', ignore_index=True)

print(f'总数量：{len(input_)}')
input_['Info'].tolist()
# Out:
# 总数量：1
# ['https://www.rockauto.com/en/moreinfo.php?pk=612457&cc=0&pt=1000873']

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

# %%
a = 0

resp = requests.get(input_.loc[a, 'Info'],
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '<!DOCTYPE HTML>\n<html class="no-js REPLACEHTMLCLASS" onclick="" lang="en">\n<head>\n<meta name="robots" content="all">\n<meta http-equiv="Content-Security-Policy" content="script-src \'self\' \'unsafe-inline\' \'unsafe-eval\' *.rockauto.com; base-uri \'self\' *.rockauto.com; ">\n<link rel="stylesheet" type="text/css" href="/jslib/combined/css/desktopmoreinfo.css?1719109458">\n\n<script>\nif(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};\n_getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=\n0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};\n\n</script>\n\n<script src="/jslib/combined/js/desktopcatalogmain.js?1719109458"></script>\n\n<script src="/catalog/moreinfo-min.js?1719109458"></script>\n\n<link rel="stylesheet" type="text/css" href="/catalog/moreinfo-min.css?1719109458">\n<title>More Information for GATES 43X4320</title>\n<link rel="canonical" href="https://www.rockauto.com/en/moreinfo.php?pk=612457"/>\n<link rel="alternate" href="https://www.rockauto.com/en/moreinfo.php?pk=612457" hreflang="en" />\n<link rel="alternate" href="https://www.rockauto.com/es/moreinfo.php?pk=612457" hreflang="es" />\n<link rel="alternate" href="https://www.rockauto.com/de/moreinfo.php?pk=612457" hreflang="de" />\n<link rel="alternate" href="https://www.rockauto.com/fr/moreinfo.php?pk=612457" hreflang="fr" />\n</head>\n<body onLoad="ResizePiclookup();" class="mi-body">\n<div id="mi_everything">\n<div>\n<div style="float:left; margin-right:1em;"><a href="https://www.gates.com/us/en.html" target="_blank"><img style="max-height:100px;" src="/logos/gatesLogo.png" alt="GATES" border="0"></a></div>\n<div style="float:left;"></div>\n<div style="float:right;">\n<table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">\n<tr>\n<td style="text-align: center">\n<a href="/" onclick="AddSerializedCookieDataToHref(this);"><img src="/Images/logoNoLine.png" class="ralogo" border="0" alt="Go to RockAuto Home Page"></a>\n</td>\n</tr>\n</table>\n</div>\n<div style="font-size:.9em;"></div>\n<div style="clear:both;"></div>\n</div>\n<div class="bdytext hide-for-inline-mobile">\n<div style="float: left; padding-right: 20px;">\n<div style="padding-bottom:.4em;">More Information for GATES 43X4320</div>\n<div style="padding-bottom:.4em;"></div>\n<input type="button" id="mi_continue_shopping_btn" class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" style="padding-top: 5px; padding-bottom: 5px; background-position: left center;" onclick="if(HasOpener()) window.close(); else window.location=\'/?mfr=GATES&partnum=43X4320\';" value = "Continue Shopping" title="Back to the Rock ...

# %%
from bs4 import BeautifulSoup
from lxml import etree

# %%
soup = BeautifulSoup(resp, 'lxml')
html = etree.HTML(str(soup))

with open('./info.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="no-js REPLACEHTMLCLASS" lang="en" onclick="">
#  <head>
#   <meta content="all" name="robots"/>
#   <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' *.rockauto.com; base-uri 'self' *.rockauto.com; " http-equiv="Content-Security-Policy"/>
#   <link href="/jslib/combined/css/desktopmoreinfo.css?1719109458" rel="stylesheet" type="text/css"/>
#   <script>
#    if(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};
# _getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=
# 0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};
#   </script>
#   <script src="/jslib/combined/js/desktopcatalogmain.js?1719109458">
#   </script>
#   <script src="/catalog/moreinfo-min.js?1719109458">
#   </script>
#   <link href="/catalog/moreinfo-min.css?1719109458" rel="stylesheet" type="text/css"/>
#   <title>
#    More Information for GATES 43X4320
#   </title>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=612457" rel="canonical"/>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=612457" hreflang="en" rel="alternate"/>
#   <link href="https://www.rockauto.com/es/moreinfo.php?pk=612457" hreflang="es" rel="alternate"/>
#   <link href="https://www.rockauto.com/de/moreinfo.php?pk=612457" hreflang="de" rel="alternate"/>
#   <link href="https://www.rockauto.com/fr/moreinfo.php?pk=612457" hreflang="fr" rel="alternate"/>
#  </head>
#  <body class="mi-body" onload="ResizePiclookup();">
#   <div id="mi_everything">
#    <div>
#     <div style="float:left; margin-right:1em;">
#      <a href="https://www.gates.com/us/en.html" target="_blank">
#       <img alt="GATES" border="0" src="/logos/gatesLogo.png" style="max-height:100px;"/>
#      </a>
#     </div>
#     <div style="float:left;">
#     </div>
#     <div style="float:right;">
#      <table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">
#       <tr>
#        <td style="text-align: center">
#         <a href="/" onclick="AddSerializedCookieDataToHref(this);">
#          <img alt="Go to RockAuto Home Page" border="0" class="ralogo" src="/Images/logoNoLine.png"/>
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div style="font-size:.9em;">
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <div class="bdytext hide-for-inline-mobile">
#     <div style="float: left; padding-right: 20px;">
#      <div style="padding-bottom:.4em;">
#       More Information for GATES 43X4320
#      </div>
#      <div style="padding-bottom:.4em;">
#      </div>
#      <input class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" id="mi_continue_shopping_btn" onclick="if(HasOpener()) window.close(); else window.location='/?mfr=GATES&amp;partnum=43X4320';" style="padding-top: 5px; padding-bottom: 5px; background-position: left center;" title="Back to the RockAuto Catalog" type="button" value="Continue Shopping"/>
#      <div class="show-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('mi_continue_shopping_btn')" style="display: inline-block; font-size: 13px;">
#       <img alt="" class="la-btn-v" src="/Images/mobile/left_arrow_white.png" style="height: 1em; margin-right: .25em;"/>
#       <span class="la-btn-v">
#        Continue Shopping
#       </span>
#      </div>
#     </div>
#     <div class="buybox show-if-js" style="float: right;">
#      <section aria-label="Add to Cart">
#       <table border="0" cellpadding="0" cellspacing="0" id="frmlistings[1]">
#        <tbody class="listing-inner" id="mibuybox">
#         <tr>
#          <td class="buybox-inner-content">
#           <span style="float: right;">
#           </span>
#           <div>
#           </div>
#           <div class="listing-text-row-moreinfo-truck">
#            <b>
#             <span class="listing-final-manufacturer">
#              GATES
#             </span>
#            </b>
#            <span alt="Buyer's Guide" class="listing-final-partnumber as-link-if-js" id="vew_partnumber[1]" onclick='if (cataloglite.IsMobileAndNotExpanded("1")) { return; } cataloglite.ShowBuyersGuidePopup("1");' title="Buyer's Guide">
#             43X4320
#            </span>
#            <span class="truck ra-hide remove-for-print mouseover" name="vew_whtruckicon[1][0-0-0-1]" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', &quot;Could ship from same location as parts in cart&quot;, null, this); RA.StopBubble(event); return false;" title="Could ship from same location as parts in cart">
#            </span>
#           </div>
#           <div class="listing-text-row buybox-rebate">
#           </div>
#           <div>
#           </div>
#          </td>
#          <td class="buybox-inner-content">
#           <div class="listing-quantity-adjustment ib remove-for-print show-if-js" id="frmlistings[1]">
#            <input autocomplete="off" id="listingoptkeytomultiple[1]" type="hidden" value='{"0-0-0-1":"1"}'/>
#            <input autocomplete="off" id="listingoptkeytolinenumber[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoqtyincart[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoalternateid[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <table class="tblz di tbl-input-button-attached" id="listingquantitytable[1]">
#             <tr>
#              <td class="td-button-left" style="text-align: right;">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", -1);' style="border-top-left-radius: 4px; border-bottom-left-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_down_white.png"/>
#               </div>
#              </td>
#              <td class="td-input">
#               <label for="raquantity[1]" style="display:none;">
#                Quantity
#               </label>
#               <input aria-label="Quantity" autocapitalize="off" autocomplete="off" autocorrect="off" class="input-quantity ib" data-autofill="block" id="raquantity[1]" maxlength="5" name="raquantity[1]" onchange='cataloglite.ListingQuantityUpdate("1");' onkeypress='return RA.InterceptEnter(event, function(){RA.ByName("raquantity[1]")[0].blur()});' spellcheck="false" style="text-align: center; width: 2em; padding-left: 0;" type="text" value="1"/>
#              </td>
#              <td class="td-button-right">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", 1);' style="border-top-right-radius: 4px; border-bottom-right-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_up_white.png"/>
#               </div>
#              </td>
#             </tr>
#            </table>
#            <input autocomplete="off" id="optionchoice[1]" name="optionchoice[1]" type="hidden" value="0-0-0-1"/>
#            <input autocomplete="off" id="listing_data_essential[1]" name="listing_data_essential[1]" type="hidden" value='{"groupindex":"1","carcode":0,"parttype":"1000873","partkey":"612457","opts":{"0-0-0-1":{"warehouse":"97124","whpartnum":"GAT 43X4320","optionlist":"0","paramcode":"0","notekey":"0","multiple":"1"}}}'/>
#            <input autocomplete="off" id="listing_data_supplemental[1]" type="hidden" value='{"partnumber":"43X4320","catalogname":"GATES","belongstolisting":"1","sortgroup":null,"sortgrouptext":null,"paramdesc":""}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="lst_shipwhlist[1][0-0-0-1]" type="hidden" value='{"97124":97124}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][0-0-0-1]" type="hidden" value="true"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnnotifyoos[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][0-0-0-1]" type="hidden" value="true"/>
#            <input autocomplete="off" name="ssk[1]" type="hidden" value="HPc6NY4sqMvPDBCrBav8qfOtsmbY5p6Sh/ZCUQxfFMQWbkCoZsKyaiQ5wGNApoqH2ju77XX8eJE="/>
#           </div>
#          </td>
#          <td class="listing-float-box-cell-shared listing-float-box-cell-more-padding" colspan="4" id="listingtd[1][price]" style="height: 1px; text-align: center;">
#           <span class="" id="dprice[1][td]">
#            <span class="ra-formatted-amount listing-price listing-amount-bold">
#             <span id="dprice[1][v]">
#              $46.79
#             </span>
#            </span>
#           </span>
#           <div class="none" style="font-size:.8em;">
#            Price
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][core]" style="height: 1px; text-align: center;">
#           <span class="" id="dcore[1][td]">
#            <span class="ra-formatted-amount listing-core">
#             <a class="" href="/help/?page=2#CORE" id="dcore[1][color]" onclick="return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#              <span id="dcore[1][v]">
#               $0.00
#              </span>
#             </a>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Core
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][pack]" style="height: 1px; text-align: center;">
#           <span id="dpack[1][v]">
#            <span class="hide-if-js">
#             + Sold in packs of 1
#            </span>
#            <span class="show-if-js">
#             <span class="pack_size_box no-text-select" onclick="showContextPopup(' ', &quot;Sold in packs of 1&quot;, this); RA.StopBubble(event); return false;" title="Sold in packs of 1">
#              <span class="right">
#               <span class="left">
#                <span class="text">
#                 <span class="text-x-small">
#                  x
#                 </span>
#                 1
#                </span>
#               </span>
#              </span>
#             </span>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Pack
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][total]" style="height: 1px; text-align: center;">
#           <span class="listing-amount-bold" id="dtotal[1][td]">
#            <span class="ra-formatted-amount listing-total">
#             <span id="dtotal[1][v]">
#              $46.79
#             </span>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Total
#           </div>
#          </td>
#          <td class="buybox-inner-content" style="white-space:nowrap; padding-right:.5em;">
#           <div class="catalog-listing-buttons-wrapper ib" style="min-width:105px;">
#            <div class="vew_btnaddtocart remove-for-print" id="vew_btnaddtocart[1]">
#             <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-hotgreen" id="addpart[1]" name="addpart[1]" onclick="showLoading(); RA.SubscribeOnce('cartevent', 'callback_complete', function () { AddPartToCart_cb(); }); cataloglite.Cart.AddPartToCart(&quot;1&quot;); return false;" type="submit" value="Add to Cart &gt;"/>
#             <a class="show-if-js ra-btn ra-btn-color-hotgreen ra-btn-size-normal ra-btn-add-part" href="#" onclick="RA.Click('addpart[1]'); return false;" style="display: inline-block;">
#              <span class="la-btn-v">
#               Add to Cart
#              </span>
#              <img alt="" class="la-btn-v" src="/Images/mobile/right_arrow_white.png" style="height: 1em; margin-left: .25em;"/>
#             </a>
#            </div>
#            <div class="vew_btnpartincart remove-for-print ra-hide" id="vew_btnpartincart[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-part-in-cart" name="addpart[1]" onclick="cataloglite.Cart.ShowPartAlreadyInCart(1); return false;" type="submit" value="Part In Cart"/>
#            </div>
#            <div class="vew_btnnotifyoos remove-for-print ra-hide show-if-js" id="vew_btnnotifyoos[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" onclick='cataloglite.GetAvailabilityAlertForOOSPart("1");' type="button" value="Notify Me When Available"/>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#           <div class="listing-text-row">
#            <span class="mtf-h-t">
#             (Only 1 Remaining)
#            </span>
#           </div>
#           <div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </section>
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <table class="bdytext" style="width: 100%; border: none;">
#     <tr>
#      <td style="width: 525px; " valign="top">
#       <div style="">
#        <table cellpadding="8" cellspacing="0" style="border: 1px solid #dcdcdc;">
#         <tr align="center">
#          <td colspan="3" style="width: 500px;">
#           <section aria-label="Image of part">
#            <img alt="Zoom Lens" id="zoomlens" onmousemove="MouseMoveZoom(null, event);" onmouseout="MouseOutOfLens(null, event);" onmouseover="MouseOverLens(null, event);" src="/catalog/images/transpurple100.png" style="position: absolute: width: 100px; height: 100px; display: none; border: 1px solid white; z-index: 10;"/>
#            <div class="">
#             <table class="tblz listing-image-table" id="listing_image_table[1]" style=" width: 100%;">
#              <tr>
#               <td class="listing-image-table-centercol">
#                <div class="" id="inlineimgpositionancestor[1]" style=" position: relative; z-index: 1; width: 100%;">
#                 <div class="listing-inlineimg_container" id="inlineimg_container[1]" style="z-index: 1; text-align: center; background: #FFFFFF; width: 100%;">
#                  <div class="listing-inline-image-popup-widget-title ra-hide" id="inlineimg_containertitle[1]" onmousedown='cataloglite.ImagePopupTitleMouseDown("1")'>
#                   <div style="text-align: center; ">
#                    <span style="padding: 0 2em 0 2em;">
#                     GATES 43X4320
#                    </span>
#                    <span style="position: absolute; right: 5px;">
#                     <img alt="close" onclick='cataloglite.Listing_InlineImagePopupInPlace("1")' src="/catalog/images/close12_1.gif" style="padding: .2em; cursor: pointer; display: block;"/>
#                    </span>
#                   </div>
#                  </div>
#                  <div class="img-topper-container" id="inlineimg_topper[1]">
#                   <table class="tblz w100">
#                    <tr>
#                     <td class="pinched" style="vertical-align: top;">
#                      <div style="text-align: left; padding-right: .25em;">
#                       <span id="inlineimg_left_big[1]">
#                        <img alt="&lt;" class="listing-image-prevnext-image-moreinfo remove-for-print show-if-js" id="inlineimgprevious[1]" onclick='cataloglite.Listing_InlineImageManualScroll("1", -1, false, false)' src="/catalog/images/prevIMGbig.png" style="visibility: hidden; margin: .1em;" title="Previous Image"/>
#                       </span>
#                      </div>
#                      <div class="listing-image-counter">
#                       <div class="inner" id="imagecounterdisplay[1]">
#                       </div>
#                      </div>
#                     </td>
#                     <td style="vertical-align: top;">
#                      <div id="pointtozoom" style="text-align:center; font-size: 11px; color: blue; white-space: nowrap; visibility: hidden;">
#                       Point to Zoom
#                      </div>
#                      <div class="img-carousel-titlephrase" id="imgcarouseltitlephrase[1]">
#                      </div>
#                      <div class="ra-hide" id="inlineimg_container360menu[1]" onmouseout='cataloglite.Listing_360ImageStartAutomatic("1");' onmouseover='cataloglite.Listing_360ImagesStopAutomatic("1");' style="padding: .25em; margin-bottom: .5em;">
#                       <div class="ra-bar-slider-bar-c">
#                        <div class="ra-bar-slider-bar" id="inlineimg_sliderbar[1]" onmousedown='cataloglite.ImageSliderMouseDown("1", event);' ontouchstart='cataloglite.ImageSliderMouseDown("1", event);'>
#                         <span class="ra-bar-slider-slider" id="inlineimg_slider[1]">
#                         </span>
#                        </div>
#                       </div>
#                      </div>
#                     </td>
#                     <td class="pinched" style="vertical-align: top; text-align: right;">
#                      <div style="padding-left: .25em;">
#                       <span id="inlineimg_right_big[1]">
#                        <img alt="&gt;" class="listing-image-prevnext-image-moreinfo remove-for-print" id="inlineimgnext[1]" name="inlnimgnextbtn" onclick='cataloglite.Listing_InlineImageManualScroll("1", 1, false, false)' src="/catalog/images/nextIMGbig.png" style="visibility: hidden; margin: .1em;" title="Next Image"/>
#                       </span>
#                      </div>
#                     </td>
#                    </tr>
#                   </table>
#                  </div>
#                  <div class="inlineimg_containersizer" id="inlineimg_containersizer[1]" style="">
#                   <img alt="Part image" class="listing-inline-image listing-inline-image-moreinfo" id="inlineimg[1]" onmousemove='ShowZoomLens("1", event); MouseMoveZoom("1", event);' onmouseout='MouseOutOfImage("1", event);' onmouseover='MouseOverImage("1", event);' src="/info/64/43X4320-1_ANG_R.jpg"/>
#                  </div>
#                 </div>
#                </div>
#               </td>
#              </tr>
#             </table>
#             <input autocomplete="off" id="jsninlineimg[1]" type="hidden" value='{"Size":"Popup","SlotIndex":0,"Slots":[{"Type":"Single","ImageData":{"Thumb":"\/info\/64\/43X4320-1_ANG_R__ra_m.jpg","Popup":"\/info\/64\/43X4320-1_ANG_R.jpg","Full":"\/info\/64\/43X4320-1_ANG_R.jpg"},"TitlePhrase":null,"ParamCodes":["0"]}],"IsMoreInfoPageImageBox":1}'/>
#            </div>
#            <script>
#             last_group_index = "1";
#            </script>
#            <script>
#             setInterval(function () {if (!document.getElementById("pointtozoom")) { return; } document.getElementById("pointtozoom").style.visibility = (IsCurrentImageZoomable(null) ? "visible" : "hidden");}, 250);
#            </script>
#            <script>
#             setTimeout(function () {if (!document.getElementById("pointtozoom")) { return; } cataloglite.Listing_InlineImageManualScroll("1", 0);}, 250);
#            </script>
#           </section>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#        <table class="disclaimer" width="100%">
#         <tr>
#          <td valign="top">
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#        <section aria-label="GATES 43X4320 Specifications">
#         <table class="moreinfotable" style="width: 500px; margin-left:5px;">
#          <tr>
#           <th colspan="1">
#            GATES 43X4320 Specifications
#           </th>
#          </tr>
#          <tr>
#           <td>
#            2013 Ski-Doo Expedition SE 4-TEC 1200
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2013 Ski-Doo Grand Touring Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2013 Ski-Doo MX Z Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2013 Ski-Doo Summit Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo Expedition LE 4-TEC 1200
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo Expedition SE 4-TEC 1200
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo Grand Touring Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo MX Z Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo MX Z TNT 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo Summit Sport 600 Carb
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2012 Ski-Doo Summit Sport Power TEK 800R
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Expedition LE 4-TEC 1200
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Expedition SE 4-TEC 1200
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Grand Touring 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo MX Z 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo MX Z 600 TNT
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit Everest E-TEC 800R
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit Freeride E-TEC 800R
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit SP
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit X E-TEC 800R 146
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit X E-TEC 800R 154
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2011 Ski-Doo Summit X E-TEC 800R 163
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Expedition 1200 SE
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Expedition 600
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Expedition 600 SE
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Grand Touring 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo GSX 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo MX Z 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Renegade 800 Adrenaline
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Renegade 800 Backcountry
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Renegade 800 Backcountry X
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Renegade 800 X
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2010 Ski-Doo Summit 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2009 Ski-Doo Legend Touring V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2009 Ski-Doo Skandic V-800 Tundra LT
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo Expedition Sport V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo GSX 600 Limited Touring
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo GTX 600 Limited
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo GTX 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo Legend Touring V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo Legend Trail V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo MX Z 800 Renegade
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo MX Z 800 Renegade X
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo MX Z 800R Renegade
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo MX Z 800R Renegade X
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo Skandic V-800 Tundra
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2008 Ski-Doo Skandic V-800 Tundra LT
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo GTX 600 Limited
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo GTX 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo Legend Touring V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo Legend Trail V-800
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo Skandic V-800 SWT
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2007 Ski-Doo Skandic V-800 Tundra
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2006 Ski-Doo GTX 600 Limited
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2006 Ski-Doo GTX 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo GTX 600 Limited
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo GTX 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo Legend V-1000 GT SE
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo Legend V-1000 GT Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo Legend V-1000 SE
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2005 Ski-Doo Legend V-1000 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2004 Ski-Doo Legend 600 SE
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2004 Ski-Doo Legend 600 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2004 Ski-Doo Legend 800 SE SDI
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2004 Ski-Doo Legend V-1000 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Grand Touring V-1000 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Legend V-1000 Sport
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Summit 800 Adrenaline 144
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Summit 800 Highmark
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Summit 800 Highmark X
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Summit 800 Highmark Xtreme
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2003 Ski-Doo Summit 800 X
#           </td>
#          </tr>
#         </table>
#        </section>
#       </div>
#      </td>
#      <td valign="top">
#       <div style="position: absolute; background: white; z-index:1;">
#        <img alt="" id="zoomedimage" onmousedown="HideZoomLens(event);" src="/catalog/images/clear100.png" style="display: none; border: 1px solid #777777;"/>
#       </div>
#      </td>
#      <td valign="top">
#       <table border="0" cellspacing="5" class="bdydesc">
#        <tr>
#         <td>
#          <section aria-label="Part Description">
#           Xtreme Snowmobile Belt; 1 7/16" x 43 3/8"
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#        <tr>
#         <td>
#          <section aria-label="More Information for GATES 43X4320">
#           <p>
#            Gates Xtreme snowmobile belt uses advanced composite technology to maximize
#  durability and functional performance over the life of the belt. The belt is
#  designed for aggressive trail running and hyper-sled action requiring wear resistant
#  and instant response.
#           </p>
#           <p>
#            To achieve long lasting durability, Gates designed its Xtreme belt with many
#  proprietary construction features. Two of these, exclusive to Gates Xtreme belt,
#  are the undercord and the notch fabric.
#           </p>
#           <p>
#            The special undercord is a polycholorprene/aramid fiber composite, processed
#  to resist degradation of functional performance, under extreme operating conditions,
#  for the life of the belt. Among other benefits for the rider, this equates to
#  rugged dependability, especially under high horsepower loads.
#           </p>
#           <p>
#            The special notch fabric performs three main functions. It reinforces the notch
#  structure, prevents cracking, and it minimizes belt material deposits, or greasing,
#  that cause pulley lock up and rough idling.
#           </p>
#           <ul>
#            <li>
#             Compounded with wear resistant sidewalls that have been tested, with a
#  properly adjusted clutch, to handle loads up to 160 hp and 9,000 rpm.
#            </li>
#            <li>
#             Belt resists fatigue, stretch and growth.
#            </li>
#            <li>
#             Kevlar® reinforcement provides up to 25 percent longer belt life due
#  to its ability to withstand the flexing and cycling.
#            </li>
#            <li>
#             Excellent overall performance in operating ranges from -35 C to 110 C.
#            </li>
#            <li>
#             Recommended for snowmobiles in the 440cc to 900cc, and up, range.
#             <br/>
#            </li>
#           </ul>
#           <div class="mil-spacer">
#           </div>
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#       </table>
#       <table border="0" cellspacing="5" class="warranty">
#        <tr>
#         <td>
#          <br/>
#          <section aria-label="Warranty Information">
#           GATES Warranty Information:Limited Lifetime
#           <a href="https://www.gates.com/us/en/knowledge-center/resource-library/policies-and-statements/limited-warranty.html" target="_blank">
#            Warranty Details
#           </a>
#          </section>
#         </td>
#        </tr>
#       </table>
#       <p class="bdytext hide-for-inline-mobile">
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <script>
#    /**UQ:B1CE32E3**/
# PK_ADDINGPARTTOCART = "Adding Part to Cart";
# PK_ADDTOLIST = "Add to My List";
# PK_ADJUSTQUANTITY = "Adjust Quantity";
# PK_BIGGER = "Bigger";
# PK_CALCTAXTOTAL = "Calculating Tax & Total";
# PK_CALCULATESHIPPING = "Calculate Shipping";
# PK_CANCEL = "Cancel";
# PK_CARTNAME = "Cart Name";
# PK_CARTNOTIFICATION = "Notification";
# PK_CONFIRMCLEARCART = "Are you sure you want to clear this cart?";
# PK_ENTERNEWQUANTITY = "Enter a new quantity:";
# PK_GETTINGSHIPQUOTES = "Calculating Shipping Cost";
# PK_HELP = "Help";
# PK_IMAGEDOESNOTREPRESENT = "Image does not represent KEY__PARAMDESC selected in catalog";
# PK_INVALIDID = "Invalid ID. Please be sure you have entered a valid Email Address.";
# PK_LOADINGPAYPAL = "<h3>Connecting to PayPal<\/h3>If you continue to see this message after a short period of time, please close this window to return to the RockAuto website.";
# PK_LOADINGPLAIN = "Loading";
# PK_LOOKINGUPADDRESS = "Looking up Address";
# PK_MULTIPLEMATCHESPLZREFINE = "Multiple matches found. Please refine search.";
# PK_MYADDRESSES = "My Addresses";
# PK_NO = "No";
# PK_NOMATCHESFOUND = "No Matches Found";
# PK_NOPARTSFNDINMARKET = "No Parts Found for Selected Market(s)";
# PK_NUM_LISTINGS_HIDDEN = "Reset (KEY__NUM listings hidden) <img src=\"\/catalog\/images\/whiteX.png\" style=\"height:.9em;\" alt=\"\">";
# PK_OK = "OK";
# PK_PART = "Part";
# PK_PARTALREADYINCART = "This part is already in the cart. Please update the quantity in the cart to reflect the quantity you want.";
# PK_PLEASEENTERPASSWORD = "Please enter your password";
# PK_REMOVE = "Remove";
# PK_RENAMECART = "Rename Cart";
# PK_SMALLER = "Smaller";
# PK_THISVEHICLEISSAVEDTOLIST = "This vehicle is saved to your list.";
# PK_UPDATINGADDRESS = "Updating Address Information";
# PK_UPDATINGCART = "Updating Cart";
# PK_XLISTINGREMOVE = "KEY__NUM listing removed";
# PK_XLISTINGSREMOVE = "KEY__NUM listings removed";
# PK_YES = "Yes";
# window.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\/0bbOhvn7P3rkFbL80\/4ONrpMMyyMoTAzqUtg75DXjLFbtL0RWwG2TIS5g0HjN+BEpbJggwRicfW87qYxCroJDOCFdvb3koFH0TxTw3xVSCSrP49mW03RfyfTDiI5\/go7epez8O\/2RQb05nbTEka54liSU3txw88IA1kgPpO";
#   </script>
#  </body>
# </html>

# %%
html.xpath('//span[@class="la-btn-v"]/text()')[0].strip() != 'Continue Shopping'
# Out:
# False

# %%
list_tr = html.xpath('//table[@class="moreinfotable"]/tr')

list_tr
# Out:
# [<Element tr at 0x111f48d00>,
#  <Element tr at 0x111f48c40>,
#  <Element tr at 0x111f48dc0>,
#  <Element tr at 0x111f48e80>,
#  <Element tr at 0x111f48e40>,
#  <Element tr at 0x111f48f80>,
#  <Element tr at 0x111f48ec0>,
#  <Element tr at 0x111f48e00>,
#  <Element tr at 0x111f48fc0>,
#  <Element tr at 0x111f48b80>,
#  <Element tr at 0x111f48f00>,
#  <Element tr at 0x111f49000>,
#  <Element tr at 0x111f49080>,
#  <Element tr at 0x111f49040>,
#  <Element tr at 0x111f49100>,
#  <Element tr at 0x111f48f40>,
#  <Element tr at 0x111f49140>,
#  <Element tr at 0x111f491c0>,
#  <Element tr at 0x111f49180>,
#  <Element tr at 0x111f490c0>,
#  <Element tr at 0x111f49280>,
#  <Element tr at 0x111f49200>,
#  <Element tr at 0x111f49300>,
#  <Element tr at 0x111f49240>,
#  <Element tr at 0x111f49380>,
#  <Element tr at 0x111f493c0>,
#  <Element tr at 0x111f492c0>,
#  <Element tr at 0x111f49340>,
#  <Element tr at 0x111f49440>,
#  <Element tr at 0x111f49400>,
#  <Element tr at 0x111f494c0>,
#  <Element tr at 0x111f49480>,
#  <Element tr at 0x111f49580>,
#  <Element tr at 0x111f49500>,
#  <Element tr at 0x111f49540>,
#  <Element tr at 0x111f49600>,
#  <Element tr at 0x111f49640>,
#  <Element tr at 0x111f496c0>,
#  <Element tr at 0x111f49700>,
#  <Element tr at 0x111f49900>,
#  <Element tr at 0x111f49780>,
#  <Element tr at 0x111f49a80>,
#  <Element tr at 0x111f497c0>,
#  <Element tr at 0x111f49a00>,
#  <Element tr at 0x111f49680>,
#  <Element tr at 0x111f49980>,
#  <Element tr at 0x111f49d00>,
#  <Element tr at 0x111f49840>,
#  <Element tr at 0x111f49e80>,
#  <Element tr at 0x111f49b00>,
#  <Element tr at 0x111f49b80>,
#  <Element tr at 0x111f49c00>,
#  <Element tr at 0x111f49d80>,
#  <Element tr at 0x111f49c80>,
#  <Element tr at 0x111f49f00>,
#  <Element tr at 0x111f49f80>,
#  <Element tr at 0x111f4a080>,
#  <Element tr at 0x111f49e00>,
#  <Element tr at 0x111f4a200>,
#  <Element tr at 0x111f4a100>,
#  <Element tr at 0x111f4a000>,
#  <Element tr at 0x111f4a180>,
#  <Element tr at 0x111f4a380>,
#  <Element tr at 0x111f4a300>,
#  <Element tr at 0x111f4a280>,
#  <Element tr at 0x111f4a400>,
#  <Element tr at 0x111f4a600>,
#  <Element tr at 0x111f4a500>,
#  <Element tr at 0x111f4a680>,
#  <Element tr at 0x111f4a780>,
#  <Element tr at 0x111f4a480>,
#  <Element tr at 0x111f4a580>,
#  <Element tr at 0x111f4a880>,
#  <Element tr at 0x111f4a900>]

# %%
import json

# %%
dict_specification = {}
for i in range(len(list_tr)):
    if i == 0:
        continue

    list_td = [td.strip() for td in list_tr[i].xpath('./td/text()')]
    if len(list_td) == 1:
        dict_specification[str(i-1)] = list_td[0].strip()
    elif len(list_td) == 2:
        dict_specification[str(i-1)] = {list_td[0].strip(): list_td[1].strip()}
    else:
        pass

json_specification = json.dumps(dict_specification)

json_specification
# Out:
# '{"0": "2013 Ski-Doo Expedition SE 4-TEC 1200", "1": "2013 Ski-Doo Grand Touring Sport 600 Carb", "2": "2013 Ski-Doo MX Z Sport 600 Carb", "3": "2013 Ski-Doo Summit Sport 600 Carb", "4": "2012 Ski-Doo Expedition LE 4-TEC 1200", "5": "2012 Ski-Doo Expedition SE 4-TEC 1200", "6": "2012 Ski-Doo Grand Touring Sport 600 Carb", "7": "2012 Ski-Doo MX Z Sport 600 Carb", "8": "2012 Ski-Doo MX Z TNT 600 Carb", "9": "2012 Ski-Doo Summit Sport 600 Carb", "10": "2012 Ski-Doo Summit Sport Power TEK 800R", "11": "2011 Ski-Doo Expedition LE 4-TEC 1200", "12": "2011 Ski-Doo Expedition SE 4-TEC 1200", "13": "2011 Ski-Doo Grand Touring 600 Sport", "14": "2011 Ski-Doo MX Z 600 Sport", "15": "2011 Ski-Doo MX Z 600 TNT", "16": "2011 Ski-Doo Summit Everest E-TEC 800R", "17": "2011 Ski-Doo Summit Freeride E-TEC 800R", "18": "2011 Ski-Doo Summit SP", "19": "2011 Ski-Doo Summit Sport", "20": "2011 Ski-Doo Summit X E-TEC 800R 146", "21": "2011 Ski-Doo Summit X E-TEC 800R 154", "22": "2011 Ski-Doo Summit X E-TEC 800R 163", "23": "2010 Ski-Doo Expedition 1200 SE", "24": "2010 Ski-Doo Expedition 600", "25": "2010 Ski-Doo Expedition 600 SE", "26": "2010 Ski-Doo Grand Touring 600 Sport", "27": "2010 Ski-Doo GSX 600 Sport", "28": "2010 Ski-Doo MX Z 600 Sport", "29": "2010 Ski-Doo Renegade 800 Adrenaline", "30": "2010 Ski-Doo Renegade 800 Backcountry", "31": "2010 Ski-Doo Renegade 800 Backcountry X", "32": "2010 Ski-Doo Renegade 800 X", "33": "2010 Ski-Doo Summit 600 Sport", "34": "2009 Ski-Doo Legend Touring V-800", "35": "2009 Ski-Doo Skandic V-800 Tundra LT", "36": "2008 Ski-Doo Expedition Sport V-800", "37": "2008 Ski-Doo GSX 600 Limited Touring", "38": "2008 Ski-Doo GTX 600 Limited", "39": "2008 Ski-Doo GTX 600 Sport", "40": "2008 Ski-Doo Legend Touring V-800", "41": "2008 Ski-Doo Legend Trail V-800", "42": "2008 Ski-Doo MX Z 800 Renegade", "43": "2008 Ski-Doo MX Z 800 Renegade X", "44": "2008 Ski-Doo MX Z 800R Renegade", "45": "2008 Ski-Doo MX Z 800R Renegade X", "46": "2008 Ski-Doo Skandic V-800 Tundra", "47": "2008 Ski-Doo Skandic V-800 Tundra LT", "48": "2007 Ski-Doo GTX 600 Limited", "49": "2007 Ski-Doo GTX 600 Sport", "50": "2007 Ski-Doo Legend Touring V-800", "51": "2007 Ski-Doo Legend Trail V-800", "52": "2007 Ski-Doo Skandic V-800 SWT", "53": "2007 Ski-Doo Skandic V-800 Tundra", "54": "2006 Ski-Doo GTX 600 Limited", "55": "2006 Ski-Doo GTX 600 Sport", "56": "2005 Ski-Doo GTX 600 Limited", "57": "2005 Ski-Doo GTX 600 Sport", "58": "2005 Ski-Doo Legend V-1000 GT SE", "59": "2005 Ski-Doo Legend V-1000 GT Sport", "60": "2005 Ski-Doo Legend V-1000 SE", "61": "2005 Ski-Doo Legend V-1000 Sport", "62": "2004 Ski-Doo Legend 600 SE", "63": "2004 Ski-Doo Legend 600 Sport", "64": "2004 Ski-Doo Legend 800 SE SDI", "65": "2004 Ski-Doo Legend V-1000 Sport", "66": "2003 Ski-Doo Grand Touring V-1000 Sport", "67": "2003 Ski-Doo Legend V-1000 Sport", "68": "2003 Ski-Doo Summit 800 Adrenaline 144", "69": "2003 Ski-Doo Summit 800 Highmark", "70": "2003 Ski-Doo Summit 800 Highmark X", "71": "2003 Ski-Doo Summit 800 Highmark Xtreme", "72": "2003 Ski-Doo Summit 800 X"}'

# %%
list_tr = html.xpath('//section[contains(@aria-label, "Components") and contains(@aria-label, "kit")]/table/tbody/tr/td/table/tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-b-1") or (contains(@class, "altrow-b-0")))]/tr')

list_tr
# Out:
# []

# %%
dict_kit = {}
for i in range(len(list_tr)):
    dict_kit[str(i)] = {}

    list_td = list_tr[i].xpath('./td')
    dict_kit[str(i)]['quantity'] = list_td[0].xpath('./text()')[0].strip()
    dict_kit[str(i)]['component_tag'] = list_td[1].xpath('./text()')[0].strip()

    json_ = json.loads(list_td[2].xpath('./@value')[0])
    dict_kit[str(i)]['parttype'] = json_['parttype'].strip()
    dict_kit[str(i)]['partkey'] = json_['partkey'].strip()

    json_ = json.loads(list_tr[i].xpath('./input[contains(@id, "listing_data_supplemental[")]/@value')[0])
    dict_kit[str(i)]['partnumber'] = json_['partnumber'].strip()
    dict_kit[str(i)]['catalogname'] = json_['catalogname'].strip()

    dict_kit[str(i)]['url'] = f'''https://www.rockauto.com/en/parts/{dict_kit[str(i)]['partkey']},{dict_kit[str(i)]['partnumber']},{dict_kit[str(i)]['component_tag']},{dict_kit[str(i)]['parttype']}'''

    a_ = list_tr[i].xpath('./div[@class="listing-text-row-moreinfo-truck"]/a/@href')
    dict_kit[str(i)]['info'] =  f'''https://www.rockauto.com/en/moreinfo.php?pk={dict_kit[str(i)]['catalogname']}&pt={dict_kit[str(i)]['parttype']}&Lennon=1''' if len(a_) == 0 else a_[0].strip()

    list_src = [] if len(list_td[3].xpath('./div/input/@value')) == 0 else json.loads(list_td[3].xpath('./div/input/@value')[0])['Slots']
    dict_src = {}
    for j in range(len(list_src)):
        dict_src[str(j)] = 'https://www.rockauto.com' + list_src[j]['ImageData']['Full'].strip()
    dict_kit[str(i)]['json_src'] = json.dumps(dict_src)

json_kit = json.dumps(dict_kit)

json_kit
# Out:
# '{}'

# %%
df_temp = pd.DataFrame([{'Info': input_.loc[a, 'Info'],
                         'Json_Specification': json_specification,
                         'Json_Kit': json_kit}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#                                                 Info  \
# 0  https://www.rockauto.com/en/moreinfo.php?pk=61...
#
#                                   Json_Specification Json_Kit
# 0  {"0": "2013 Ski-Doo Expedition SE 4-TEC 1200",...       {}

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Info': input_.loc[a, 'Info']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if len(output_correct) != 0:
    output_correct = output_correct.sort_values(by=['Info'], ascending=[True], ignore_index=True)
    output_correct.to_excel('./test_info.xlsx', index=False)

output_correct
# Out:
#                                                 Info  \
# 0  https://www.rockauto.com/en/moreinfo.php?pk=61...
#
#                                   Json_Specification Json_Kit
# 0  {"0": "2013 Ski-Doo Expedition SE 4-TEC 1200",...       {}

# %%
if len(output_error) != 0:
    output_error = output_error.sort_values(by=['Info'], ascending=[True], ignore_index=True)
    output_error.to_excel('./test_info_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
