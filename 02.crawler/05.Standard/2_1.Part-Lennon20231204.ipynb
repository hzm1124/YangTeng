# %%
import pandas as pd

# %%
df = pd.read_excel('./menu.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_url = df['Part_Number'].tolist()
list_url = ['https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=' + _ for _ in list_url]

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：498
# ['https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APK103',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APK102',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APK101',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APK100',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS101',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS102',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS103',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS104',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS109',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS107',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS108',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS105',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS106',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS112',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS111',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS116',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS115',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS120',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS117',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS123',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS118',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS125',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS126',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS130',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS131',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS114',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS133',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS132',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS134',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS127',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS128',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS136',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS137',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS135',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS138',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS140',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS141',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS139',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS146',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS143',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS145',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS142',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS147',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS149',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS150',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS151',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS154',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS152',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS153',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS148',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS156',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS155',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS158',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS157',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS159',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS160',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS162',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS161',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS163',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS164',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS166',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS169',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS172',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS165',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS174',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS173',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS175',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS176',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS177',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS178',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS181',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS171',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS183',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS185',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS186',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS188',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS179',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS189',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS184',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS192',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS191',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS193',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS190',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS187',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS195',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS197',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS198',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS193H',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS199',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS194',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS201',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS202',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS200',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS203',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS206',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS204',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS210',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS209',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS212',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS205',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS207',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS213',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS214',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS222',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS216',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS223',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS224',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS226',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS228',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS225',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS229',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS232',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS231',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS233',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS236',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS215',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS235',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS239',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS242',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS241',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS245',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS244',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS246',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS247',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS252',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS237',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS250',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS253',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS257',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS255',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS254',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS258',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS260',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS262',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS261',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS263',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS265',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS266',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS196',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS271',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS269',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS272',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS273',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS274',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS278',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS279',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS264',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS281',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS282',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS280',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS284',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS240',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS283',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS287',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS286',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS285',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS276',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS291',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS292',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS288',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS295',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS297',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS298',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS303',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS305',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS296',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS306',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS293',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS308',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS310',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS311',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS307',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS314',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS313',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS318',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS320',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS319',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS321',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS322',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS325',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS326',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS332',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS333',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS302',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS334',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS337',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS335',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS339',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS338',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS327',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS341',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS342',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS340',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS346',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS312',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS345',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS344',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS347',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS349',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS348',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS352',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS353',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS358',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS355',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS359',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS350',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS360',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS361',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS357',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS356',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS366',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS363',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS364',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS365',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS362',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS370',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS367',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS371',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS368',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS372',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS374',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS373',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS369',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS377',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS380',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS376',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS382',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS383',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS379',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS384',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS381',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS386',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS388',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS389',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS387',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS391',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS393',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS394',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS398',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS396',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS397',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS401',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS399',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS400',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS404',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS403',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS406',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS408',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS407',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS410',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS412',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS411',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS414',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS416',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS418',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS419',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS420',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS421',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS424',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS425',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS426',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS427',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS428',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS431',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS432',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS433',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS422',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS434',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS435',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS439',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS441',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS442',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS436',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS444',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS445',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS449',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS450',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS452',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS453',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS458',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS459',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS462',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS467',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS469',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS470',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS471',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS472',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS468',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS473',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS475',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS474',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS430',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS476',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS477',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS479',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS480',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS481',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS483',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS484',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS485',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS478',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS486',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS488',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS490',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS493',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS491',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS492',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS494',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS496',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS495',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS497',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS498',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS499',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS502',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS503',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS506',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS509',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS504',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS510',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS511',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS505',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS515',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS512',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS517',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS513',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS518',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS519',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS520',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS522',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS523',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS524',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS527',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS525',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS526',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS528',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS532',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS537',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS536',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS542',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS530',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS544',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS543',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS548',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS545',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS546',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS549',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS570',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS571',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS572',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS574',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS573',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS575',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS577',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS576',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS579',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS578',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS580',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS581',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS582',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS584',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS585',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS583',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS587',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS588',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS586',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS550',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS590',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS589',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS592',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS593',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS594',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS595',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS597',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS596',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS599',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS598',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS600',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS601',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS602',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS603',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS604',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS605',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS607',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS608',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS606',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS610',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS611',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS612',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS614',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS613',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS616',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS615',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS617',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS619',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS618',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS620',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS623',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS624',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS622',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS626',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS627',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS625',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS628',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS629',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS631',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS632',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS633',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS630',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS634',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS635',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS637',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS639',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS640',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS638',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS642',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS643',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS645',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS647',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS644',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS648',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS650',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS651',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS653',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS654',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS655',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS652',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS656',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS657',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS665',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS658',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS668',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS669',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS671',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS675',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS676',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS679',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS680',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS686',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS687',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS688',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS689',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS692',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS693',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS666',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS704',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS705',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS708',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS710',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS703',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS713',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS714',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS390',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS716',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS717',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=G92003',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS402',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=G92005',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=HP3860',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=HP3975',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-674',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=G92004',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=HP3945',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-697',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-689',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1001',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-745',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1025',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1057',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-824',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1094',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1085',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1147',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1197',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1207',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1478',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1479',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1660',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1764',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1789',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1048',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-2038',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1911',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-2082',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-2095',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2398',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2412',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2493',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2815',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2817',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2822',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2814',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2912',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S3015',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=T92001',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=TH371',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S2342',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=S-1292',
#  'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?func=PART&vid=&part=APS591']

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import json

# %%
i = 0

url = list_url[i]

resp = json.loads(requests.get(url).text)

resp
# Out:
# {'pd': {'rowId': 1,
#   'site': 'STD',
#   'webBase': 'APK103',
#   'brand': 'STD',
#   'basePart': 'APK103',
#   'partDesc_en': 'Accelerator Pedal Sensor',
#   'partLongDesc_en': 'Accelerator Pedal Sensor',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 1,
#   'brandLink': None,
#   'imageUrl': None},
#  'pp': {'buyersGuides': [{'basePart': 'APK103',
#     'buyersGuideId': 19733,
#     'buyersGuideDesc': 'Ford F-250 (96)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 117423,
#     'buyersGuideDesc': 'Ford F-250 HD (97)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 19774,
#     'buyersGuideDesc': 'Ford F-250 Super Duty (01-99)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 54555,
#     'buyersGuideDesc': 'Ford F-350 (97-96)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 54565,
#     'buyersGuideDesc': 'Ford F-350 Super Duty (01-99)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 54586,
#     'buyersGuideDesc': 'Ford F-450 Super Duty (01-99)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 21131,
#     'buyersGuideDesc': 'Ford F-550 Super Duty (01-99)'},
#    {'basePart': 'APK103',
#     'buyersGuideId': 170695,
#     'buyersGuideDesc': 'Ford F-Super Duty (97-96)'}],
#   'partSpecs': [{'attributeCode': '110',
#     'attributeValue': 1905,
#     'attributeSort': 0,
#     'attributeName_en': 'Warranty',
#     'siteValue_en': '3 years/36,000 mile'},
#    {'attributeCode': '357',
#     'attributeValue': 4038,
#     'attributeSort': 0,
#     'attributeName_en': 'Attachment Method',
#     'siteValue_en': 'Bolt On'},
#    {'attributeCode': '455',
#     'attributeValue': 6306,
#     'attributeSort': 0,
#     'attributeName_en': 'New or Reman',
#     'siteValue_en': 'New'},
#    {'attributeCode': '479',
#     'attributeValue': 6323,
#     'attributeSort': 0,
#     'attributeName_en': 'Linkage Attached',
#     'siteValue_en': 'No'},
#    {'attributeCode': '480',
#     'attributeValue': 7905,
#     'attributeSort': 0,
#     'attributeName_en': 'Pedal Assembly Included',
#     'siteValue_en': 'Yes'},
#    {'attributeCode': '159',
#     'attributeValue': 3974,
#     'attributeSort': 10290,
#     'attributeName_en': 'Color/Finish',
#     'siteValue_en': 'Black'},
#    {'attributeCode': '9',
#     'attributeValue': 4752,
#     'attributeSort': 10310,
#     'attributeName_en': 'Connector Gender',
#     'siteValue_en': 'Female'},
#    {'attributeCode': '160',
#     'attributeValue': 249,
#     'attributeSort': 10340,
#     'attributeName_en': 'Connector Quantity',
#     'siteValue_en': '1'},
#    {'attributeCode': '171',
#     'attributeValue': 6494,
#     'attributeSort': 10350,
#     'attributeName_en': 'Connector Shape',
#     'siteValue_en': 'Oval'},
#    {'attributeCode': '14',
#     'attributeValue': 7049,
#     'attributeSort': 10410,
#     'attributeName_en': 'Contents',
#     'siteValue_en': 'Sensor'},
#    {'attributeCode': '143',
#     'attributeValue': 6323,
#     'attributeSort': 10820,
#     'attributeName_en': 'Hardware included',
#     'siteValue_en': 'No'},
#    {'attributeCode': '52',
#     'attributeValue': 10289,
#     'attributeSort': 11300,
#     'attributeName_en': 'Material',
#     'siteValue_en': 'Polyamide 6'},
#    {'attributeCode': '162',
#     'attributeValue': 6323,
#     'attributeSort': 11350,
#     'attributeName_en': 'Mounting Bracket(s) Included',
#     'siteValue_en': 'No'},
#    {'attributeCode': '54',
#     'attributeValue': 3559,
#     'attributeSort': 11370,
#     'attributeName_en': 'Mounting Location',
#     'siteValue_en': 'Accelerator Pedal'},
#    {'attributeCode': '104',
#     'attributeValue': 5959,
#     'attributeSort': 12380,
#     'attributeName_en': 'Terminal Gender',
#     'siteValue_en': 'Male (1)'},
#    {'attributeCode': '164',
#     'attributeValue': 1843,
#     'attributeSort': 12390,
#     'attributeName_en': 'Terminal Quantity',
#     'siteValue_en': '3'},
#    {'attributeCode': '105',
#     'attributeValue': 3983,
#     'attributeSort': 12400,
#     'attributeName_en': 'Terminal Type',
#     'siteValue_en': 'Blade'}],
#   'imageUrls': [],
#   'relatedParts': [{'webBase': 'S2095',
#     'brand': 'STD',
#     'basePart': 'S-2095',
#     'partDesc_en': 'Electrical Connector',
#     'partLongDesc_en': 'Electrical Connector',
#     'rowId': 1}],
#   'relatedCategories': None,
#   'fandB': [{'basePart': 'APK103',
#     'fbId': '301746',
#     'fbDesc': 'For over 100 years, professional technicians have trusted Standard® to replace the failed OE part. Standard® manufacturers the highest-quality, best-performing parts for all import and domestic vehicles; gas, diesel, electric and hybrid. Precision manufacturing, multiple layers of testing, and a detailed validation process ensures Standard® parts don’t just fit, they perform and they last.',
#     'taB_Type': 'F&B Heading',
#     'assetSort': 1,
#     'digiSort': 100},
#    {'basePart': 'APK103',
#     'fbId': '218525',
#     'fbDesc': 'Complete repair kit comes with everything needed to replace only failed sensor instead of entire pedal assembly ',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 200},
#    {'basePart': 'APK103',
#     'fbId': '218526',
#     'fbDesc': 'Designed and extensively tested to ensure proper throttle response ',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 210},
#    {'basePart': 'APK103',
#     'fbId': '218866',
#     'fbDesc': 'Allows you to replace only failed sensor instead of entire pedal assembly ',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 220},
#    {'basePart': 'APK103',
#     'fbId': '272134',
#     'fbDesc': "Our parts meet or exceed OE performance, providing today's technician with the quality parts needed to get the job done right, the first time",
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 230}],
#   'digiAssests': [{'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'APK103',
#     'fileName': 'WIYB: Engineering Spotlight: Long Island City',
#     'fileURL': 'https://youtube.com/embed/I-kWdiTPe08',
#     'comment_ID': '291618',
#     'comment': 'WIYB: Engineering Spotlight: Long Island City',
#     'assetSort': 7,
#     'digiSort': 80003,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'APK103',
#     'fileName': 'SMP Engineering - Long Island City Facility Tour',
#     'fileURL': 'https://youtube.com/embed/ut5LYbUFCKo',
#     'comment_ID': '271219',
#     'comment': 'SMP Engineering - Long Island City Facility Tour',
#     'assetSort': 7,
#     'digiSort': 80350,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'APK103',
#     'fileName': 'Standard Interactive Buyers Guide',
#     'fileURL': 'https://youtube.com/embed/mRzK11T9pxg',
#     'comment_ID': '251346',
#     'comment': 'Standard Interactive Buyers Guide',
#     'assetSort': 7,
#     'digiSort': 90030,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'APK103',
#     'fileName': 'SMP Parts App Update (3.0.9)',
#     'fileURL': 'https://youtube.com/embed/HvA2lY15M28',
#     'comment_ID': '270593',
#     'comment': 'SMP Parts App Update (3.0.9)',
#     'assetSort': 7,
#     'digiSort': 90090,
#     'videoImage': None}],
#   'categories': [{'basePart': 'APK103',
#     'webLayout_ID': 220300,
#     'categoryName_en': 'Sensor - Accelerator Pedal',
#     'prodCategory_ASort': 24970}],
#   'crossRef': None,
#   'completeRepair': {'serviceParts': [{'webBase': 'S2095',
#      'brand': 'STD',
#      'basePart': 'S-2095',
#      'partDesc_en': 'Electrical Connector',
#      'partLongDesc_en': 'Electrical Connector',
#      'rowId': 1}],
#    'serviceSpec': [{'serviceName': 'Fuel Filter Flush (Required)'},
#     {'serviceName': 'Oil Change (Required)'}]}}}

# %%
list_vehicle = []
for _ in resp['pp']['buyersGuides']:
    list_vehicle.append(_['buyersGuideDesc'])
    
vehicle = '\n'.join(list_vehicle)

print(vehicle)
# Out:
# Ford F-250 (96)
# Ford F-250 HD (97)
# Ford F-250 Super Duty (01-99)
# Ford F-350 (97-96)
# Ford F-350 Super Duty (01-99)
# Ford F-450 Super Duty (01-99)
# Ford F-550 Super Duty (01-99)
# Ford F-Super Duty (97-96)

# %%
df_temp = pd.DataFrame([{'status': 'ok',
                         '序号': '',
                         'Part_Number': resp['pd']['basePart'],
                         'Part_Type': resp['pd']['partDesc_en'],
                         'Part_Type_Long': resp['pd']['partLongDesc_en'],
                         'Brand': resp['pd']['brand'],
                         'Pop': resp['pd']['pop'],
                         'Per_Car': resp['pd']['qtyEach'],
                         'Vehicle': vehicle,
                         'Pic': '',
                         'Url': 'https://ecatalog.smpcorp.com/V2/STD/#/partdetail/part/' + resp['pd']['basePart'],
                         'Src': ''}])

for name_value in resp['pp']['partSpecs']:
    df_temp[name_value['attributeName_en'].lower()] = name_value['siteValue_en']

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df_temp
# Out:
#   status 序号 Part_Number                 Part_Type            Part_Type_Long  \
# 0     ok         APK103  Accelerator Pedal Sensor  Accelerator Pedal Sensor
#
#   Brand Pop  Per_Car                                            Vehicle Pic  \
# 0   STD   B        1  Ford F-250 (96)\nFord F-250 HD (97)\nFord F-25...
#
#    ... connector quantity connector shape contents hardware included  \
# 0  ...                  1            Oval   Sensor                No
#
#       material mounting bracket(s) included  mounting location  \
# 0  Polyamide 6                           No  Accelerator Pedal
#
#   terminal gender terminal quantity terminal type
# 0        Male (1)                 3         Blade
#
# [1 rows x 29 columns]
