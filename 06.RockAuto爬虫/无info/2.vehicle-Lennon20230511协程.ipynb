# %% [markdown]
# - Update: 2023.05.11
#
# # 0. 配置参数
#
# - `ajax`：AJAX (ROCKAUTO)
# - `site_code`：品类在网站的内部编码

# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree
import time

# = = = = = = = = = = = = = = = = = =

site_code= '10401'

ajax = 'https://www.rockauto.com/catalog/catalogapi.php'

proxies = {'http': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818',
           'https': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['url',
                           'part_number',
                           'vehicle',
                           'status'])

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./ajax_out.xlsx', header=0)
list_url = df_menu['url'].to_list()
list_part_number = df_menu['part_number'].to_list()
list_payload = df_menu['payload'].to_list()
print('总数量：' + str(len(list_payload)))
print()

# = = = = = = = = = = = = = = = = = =

work = Queue()
for url, part_number, payload in zip(list_url, list_part_number, list_payload):
    work.put_nowait((url, part_number, payload))

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        url, part_number, payload = work.get_nowait()
        
        for i in range(31):
            try:
                headers = {'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8'}

                func = r'getbuyersguide'
                payload = r'{"partData":{"listing_data_essential":{"parttype":"' + site_code + '","partkey":"' + payload.split('partkey')[1].split('%22')[2] + '"}}}'
                api_json_request = r'1'

                data = 'func=' + func + '&payload=' + quote(payload, safe=' ').replace(' ', '+') + '&api_json_request=' + api_json_request

                # = = = = = = = = = = = = = = = = = =

                resp = requests.post(ajax, headers=headers, data=data, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =

                html = json.loads(resp)['buyersguidepieces']['body']

                # = = = = = = = = = = = = = = = = = =

                soup = BeautifulSoup(html, 'lxml')

                # = = = = = = = = = = = = = = = = = =

                html = etree.HTML(str(soup))

                list_tr = html.xpath('//table[@class="nobmp"]/tr')

                # = = = = = = = = = = = = = = = = = =

                list_vehicle = []
                for tr in list_tr:
                    list_vehicle.append(' '.join(tr.xpath('./td/text()')))

                vehicle = '\n'.join(list_vehicle)

                # = = = = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'url': [url],
                                        'part_number': [part_number],
                                        'vehicle': [vehicle],
                                        'status': 'ok'})

                break

            except:
                if i == 30:
                    df_temp = pd.DataFrame({'url': [url],
                                            'part_number': [part_number],
                                            'vehicle': '',
                                            'status': ['error']})
                time.sleep(0.3)
                continue

        # = = = = = = = = = = = = = = = = = =

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(url + '  <->  [' + str(i) + '] - 剩余：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./vehicle (without info).xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：90
#
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：80
# https://www.rockauto.com/en/catalog/chevrolet,2020,camaro,2.0l+l4+turbocharged,3444556,suspension,control+arm,10401  <->  [0] - 剩余：79
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：78
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：77
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：76
# https://www.rockauto.com/en/catalog/bmw,2020,530e,2.0l+l4+electric/gas+turbocharged,3444484,suspension,control+arm,10401  <->  [0] - 剩余：75
# https://www.rockauto.com/en/catalog/chevrolet,2020,camaro,2.0l+l4+turbocharged,3444556,suspension,control+arm,10401  <->  [0] - 剩余：74
# https://www.rockauto.com/en/catalog/chevrolet,2020,camaro,2.0l+l4+turbocharged,3444556,suspension,control+arm,10401  <->  [0] - 剩余：73
# https://www.rockauto.com/en/catalog/bmw,2020,530e,2.0l+l4+electric/gas+turbocharged,3444484,suspension,control+arm,10401  <->  [0] - 剩余：72
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：71
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+2500,6.0l+v8,3444569,suspension,control+arm,10401  <->  [0] - 剩余：70
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+2500,4.3l+v6,3444567,suspension,control+arm,10401  <->  [0] - 剩余：69
# https://www.rockauto.com/en/catalog/bmw,2020,530i,2.0l+l4+turbocharged,3444486,suspension,control+arm,10401  <->  [0] - 剩余：68
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+3500,6.0l+v8,3444572,suspension,control+arm,10401  <->  [0] - 剩余：67
# https://www.rockauto.com/en/catalog/chevrolet,2020,camaro,2.0l+l4+turbocharged,3444556,suspension,control+arm,10401  <->  [0] - 剩余：66
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+2500,4.3l+v6,3444567,suspension,control+arm,10401  <->  [0] - 剩余：65
# https://www.rockauto.com/en/catalog/chevrolet,2020,traverse,3.6l+v6,3444668,suspension,control+arm,10401  <->  [0] - 剩余：64
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+3500,6.0l+v8,3444572,suspension,control+arm,10401  <->  [0] - 剩余：63
# https://www.rockauto.com/en/catalog/ford,2020,ranger,2.5l+l4,3445188,suspension,control+arm,10401  <->  [0] - 剩余：62
# https://www.rockauto.com/en/catalog/honda,2020,accord,2.0l+l4+turbocharged,3445239,suspension,control+arm,10401  <->  [0] - 剩余：61
# https://www.rockauto.com/en/catalog/chevrolet,2020,traverse,3.6l+v6,3444668,suspension,control+arm,10401  <->  [0] - 剩余：60
# https://www.rockauto.com/en/catalog/honda,2020,accord,2.0l+l4+turbocharged,3445239,suspension,control+arm,10401  <->  [0] - 剩余：59
# https://www.rockauto.com/en/catalog/honda,2020,accord,2.0l+l4+turbocharged,3445239,suspension,control+arm,10401  <->  [0] - 剩余：58
# https://www.rockauto.com/en/catalog/jeep,2020,compass,2.4l+l4,3445267,suspension,control+arm,10401  <->  [0] - 剩余：57
# https://www.rockauto.com/en/catalog/honda,2020,accord,2.0l+l4+turbocharged,3445239,suspension,control+arm,10401  <->  [1] - 剩余：56
# https://www.rockauto.com/en/catalog/jeep,2020,gladiator,3.6l+v6,3444100,suspension,control+arm,10401  <->  [0] - 剩余：55
# https://www.rockauto.com/en/catalog/jeep,2020,compass,2.4l+l4,3445267,suspension,control+arm,10401  <->  [0] - 剩余：54
# https://www.rockauto.com/en/catalog/jeep,2020,renegade,1.3l+l4+turbocharged,3445274,suspension,control+arm,10401  <->  [0] - 剩余：53
# https://www.rockauto.com/en/catalog/jeep,2020,renegade,1.3l+l4+turbocharged,3445274,suspension,control+arm,10401  <->  [0] - 剩余：52
# https://www.rockauto.com/en/catalog/jeep,2020,renegade,1.3l+l4+turbocharged,3445274,suspension,control+arm,10401  <->  [0] - 剩余：51
# https://www.rockauto.com/en/catalog/jeep,2020,renegade,1.3l+l4+turbocharged,3445274,suspension,control+arm,10401  <->  [0] - 剩余：50
# https://www.rockauto.com/en/catalog/jeep,2020,wrangler,2.0l+l4+turbocharged,3445276,suspension,control+arm,10401  <->  [0] - 剩余：49
# https://www.rockauto.com/en/catalog/jeep,2020,wrangler,2.0l+l4+turbocharged,3445276,suspension,control+arm,10401  <->  [0] - 剩余：48
# https://www.rockauto.com/en/catalog/mercedes-benz,2020,e450,3.0l+v6+turbocharged,3445454,suspension,control+arm,10401  <->  [0] - 剩余：47
# https://www.rockauto.com/en/catalog/jeep,2020,wrangler,2.0l+l4+turbocharged,3445276,suspension,control+arm,10401  <->  [1] - 剩余：46
# https://www.rockauto.com/en/catalog/mercedes-benz,2020,e450,3.0l+v6+turbocharged,3445454,suspension,control+arm,10401  <->  [0] - 剩余：45
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.0l+l4+turbocharged,3444995,suspension,control+arm,10401  <->  [0] - 剩余：44
# https://www.rockauto.com/en/catalog/mercedes-benz,2020,s560,4.0l+v8+turbocharged,3445467,suspension,control+arm,10401  <->  [0] - 剩余：43
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.0l+l4+turbocharged,3444995,suspension,control+arm,10401  <->  [0] - 剩余：42
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.0l+l4+turbocharged,3444995,suspension,control+arm,10401  <->  [0] - 剩余：41
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.0l+l4+turbocharged,3444995,suspension,control+arm,10401  <->  [0] - 剩余：40
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [0] - 剩余：39
# https://www.rockauto.com/en/catalog/mercedes-benz,2020,s560,4.0l+v8+turbocharged,3445467,suspension,control+arm,10401  <->  [1] - 剩余：38
# https://www.rockauto.com/en/catalog/chevrolet,2020,malibu,1.5l+l4+turbocharged,3444606,suspension,control+arm,10401  <->  [1] - 剩余：37
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [0] - 剩余：36
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.0l+l4+turbocharged,3444995,suspension,control+arm,10401  <->  [0] - 剩余：35
# https://www.rockauto.com/en/catalog/chevrolet,2020,traverse,3.6l+v6,3444668,suspension,control+arm,10401  <->  [2] - 剩余：34
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [0] - 剩余：33
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [1] - 剩余：32
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [0] - 剩余：31
# https://www.rockauto.com/en/catalog/nissan,2020,kicks,1.6l+l4,3445323,suspension,control+arm,10401  <->  [0] - 剩余：30
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：29
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [1] - 剩余：28
# https://www.rockauto.com/en/catalog/nissan,2020,altima,2.5l+l4,3444996,suspension,control+arm,10401  <->  [1] - 剩余：27
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：26
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：25
# https://www.rockauto.com/en/catalog/tesla,2020,3,electric,3445775,suspension,control+arm,10401  <->  [0] - 剩余：24
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [1] - 剩余：23
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：22
# https://www.rockauto.com/en/catalog/tesla,2020,3,electric,3445775,suspension,control+arm,10401  <->  [0] - 剩余：21
# https://www.rockauto.com/en/catalog/tesla,2020,y,electric,3446182,suspension,control+arm,10401  <->  [0] - 剩余：20
# https://www.rockauto.com/en/catalog/tesla,2020,3,electric,3445775,suspension,control+arm,10401  <->  [1] - 剩余：19
# https://www.rockauto.com/en/catalog/tesla,2020,y,electric,3446182,suspension,control+arm,10401  <->  [0] - 剩余：18
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：17
# https://www.rockauto.com/en/catalog/tesla,2020,3,electric,3445775,suspension,control+arm,10401  <->  [0] - 剩余：16
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,2.5l+l4+electric/gas,3445044,suspension,control+arm,10401  <->  [0] - 剩余：15
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,2.5l+l4+electric/gas,3445044,suspension,control+arm,10401  <->  [0] - 剩余：14
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,2.5l+l4+electric/gas,3445044,suspension,control+arm,10401  <->  [1] - 剩余：13
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,3.5l+v6,3445045,suspension,control+arm,10401  <->  [0] - 剩余：12
# https://www.rockauto.com/en/catalog/toyota,2020,c-hr,2.0l+l4,3445371,suspension,control+arm,10401  <->  [0] - 剩余：11
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,3.5l+v6,3445045,suspension,control+arm,10401  <->  [0] - 剩余：10
# https://www.rockauto.com/en/catalog/toyota,2020,corolla,2.0l+l4,3444156,suspension,control+arm,10401  <->  [0] - 剩余：9
# https://www.rockauto.com/en/catalog/toyota,2020,avalon,3.5l+v6,3445045,suspension,control+arm,10401  <->  [0] - 剩余：8
# https://www.rockauto.com/en/catalog/toyota,2020,prius,1.8l+l4+electric/gas,3445376,suspension,control+arm,10401  <->  [0] - 剩余：7
# https://www.rockauto.com/en/catalog/toyota,2020,corolla,2.0l+l4,3444156,suspension,control+arm,10401  <->  [0] - 剩余：6
# https://www.rockauto.com/en/catalog/toyota,2020,prius+prime,1.8l+l4+electric/gas,3445049,suspension,control+arm,10401  <->  [0] - 剩余：5
# https://www.rockauto.com/en/catalog/toyota,2020,prius,1.8l+l4+electric/gas,3445376,suspension,control+arm,10401  <->  [0] - 剩余：4
# https://www.rockauto.com/en/catalog/nissan,2020,kicks,1.6l+l4,3445323,suspension,control+arm,10401  <->  [0] - 剩余：3
# https://www.rockauto.com/en/catalog/toyota,2020,prius+prime,1.8l+l4+electric/gas,3445049,suspension,control+arm,10401  <->  [0] - 剩余：2
# https://www.rockauto.com/en/catalog/toyota,2020,prius,1.8l+l4+electric/gas,3445376,suspension,control+arm,10401  <->  [0] - 剩余：1
# https://www.rockauto.com/en/catalog/toyota,2020,prius+prime,1.8l+l4+electric/gas,3445049,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc60,2.0l+l4+electric/gas+turbocharged,3445087,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc90,2.0l+l4+electric/gas+turbocharged,3445089,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc90,2.0l+l4+turbocharged,3445088,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc90,2.0l+l4+electric/gas+turbocharged,3445089,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc60,2.0l+l4+electric/gas+turbocharged,3445087,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/volvo,2020,xc90,2.0l+l4+turbocharged,3445088,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/toyota,2020,corolla,2.0l+l4,3444156,suspension,control+arm,10401  <->  [1] - 剩余：0
# https://www.rockauto.com/en/catalog/nissan,2020,maxima,3.5l+v6,3444999,suspension,control+arm,10401  <->  [0] - 剩余：0
# https://www.rockauto.com/en/catalog/chevrolet,2020,express+2500,6.0l+v8,3444569,suspension,control+arm,10401  <->  [0] - 剩余：0
#
# 搞定
# C:\Users\Lennon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
