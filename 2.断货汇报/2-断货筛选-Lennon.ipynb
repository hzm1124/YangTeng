# %% [markdown]
# - Update: 2023.04.14

# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20230408.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate,
                   sheet_name='附_1统计源（含新品、清仓、新品成长）',
                   header=3,
                   usecols=[2, 3, 5, 11, 12])

df
# Out:
#               MRP SKU  目标\n周销  Level   在库   在途
# 0        USTBC40007-C   44.60   TOP1  198  319
# 1        USICK10241-4   36.90   TOP1   31  186
# 2          USGS43640B   29.83  TOP10   94  175
# 3        USWR644FLU-C   25.00   TOP1  156  111
# 4       USBCB08180ZLR   10.56   TOP1   95   50
# ...               ...     ...    ...  ...  ...
# 51751  USBRPR755782FR    1.00     普通    0   10
# 51752     USBRPS16887    1.00     普通    0   10
# 51753     USBRPS33222    1.00     普通    0   15
# 51754   USMAF7S000R-C    5.00  TOP20    0   40
# 51755     USRSA0HY167    1.00     普通    0   11
#
# [51756 rows x 5 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU',
                                                                   'Level',
                                                                   '目标\n周销',
                                                                   '在途']]

df
# Out:
#                MRP SKU  Level  目标\n周销  在途
# 252         USABS25980  TOP20    2.59   0
# 266         USCAKVW010   TOP1    4.21   0
# 547       USCON33960-C  TOP20    3.53   0
# 579       USMI20283W-C  TOP10    7.22   0
# 971          USWP66890  TOP20    3.37   0
# ...                ...    ...     ...  ..
# 49281   USCAF99594-2-C  TOP10    2.21   0
# 49382   USEAF11062-2-C  TOP20    0.42   0
# 50980  USFFCHOE005S-YC  TOP20    2.55   0
# 51376   USBRPS198423FR  TOP20    0.10   0
# 51410   USBRPS588805FR  TOP20    2.55   0
#
# [111 rows x 4 columns]

# %%
import datetime

writer = pd.ExcelWriter('Lennon_筛选好的断货SKU_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.xlsx')
df.to_excel(writer, index=False)
writer.close()
