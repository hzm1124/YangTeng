# %%
param_market = 'UK'

# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                if param_market == 'US':
                    url = 'https://www.ebay.com/itm/' + input_.loc[a, 'Item_Number'] + '?_ul=US&_stpos=91710&orig_cvip=true'
                elif param_market == 'DE':
                    url = 'https://www.ebay.de/itm/' + input_.loc[a, 'Item_Number'] + '?_ul=DE&_stpos=10115&orig_cvip=true'
                elif param_market == 'UK':
                    url = 'https://www.ebay.co.uk/itm/' + input_.loc[a, 'Item_Number'] + '?_ul=GB&_stpos=BS81QU&orig_cvip=true'


                resp = requests.get(url,
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                json_data = json.loads(resp.split('$MC=(window.$MC||[]).concat(')[1].split(']}]})</script></body></html>')[0] + ']}]}')
                
                # = = = = = = = = = = = = = = =
                
                market_id = json_data['o']['g']['marketplaceId'].strip()
                
                # = = = = = = = = = = = = = = =
                
                country = json_data['o']['g']['country'].strip()

                # = = = = = = = = = = = = = = =
                
                language = json_data['o']['g']['language'].strip()

                # = = = = = = = = = = = = = = =
                
                locale = json_data['o']['g']['locale'].strip()

                # = = = = = = = = = = = = = = =
                
                item_id = json_data['o']['g']['itemId'].strip()

                # = = = = = = = = = = = = = = =
                
                if param_market == 'US':
                    if market_id != 'EBAY-US' or country != 'US' or language != 'en' or locale != 'en-US' or item_id != input_.loc[a, 'Item_Number']:
                        continue
                elif param_market == 'UK':
                    if market_id != 'EBAY-GB' or country != 'GB' or language != 'en' or locale != 'en-GB' or item_id != input_.loc[a, 'Item_Number']:
                        continue
                    
                # = = = = = = = = = = = = = = =
                
                specification = json_data['o']['w'][0][2]['model']['modules']['ABOUT_THIS_ITEM']['sections']['features']['dataItems']

                # = = = = = = = = = = = = = = =
                
                if param_market in ['US', 'AU', 'UK']:
                    if 'VEHICLE_SELECTION' in json_data['o']['w'][0][2]['model']['modules']:
                        category_id = json_data['o']['w'][0][2]['model']['modules']['VEHICLE_SELECTION']['callToActions'][0]['action']['params']['categoryId'].strip()
                        # print(json_data['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['title']['textSpans'][0]['text'].strip())
                        vehicle_page = json_data['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['pagination']['itemsPerPage']['label']['textSpans'][0]['text'].split('of')[1].strip()
                    else:
                        category_id = ''
                        vehicle_page = ''
                elif param_market == 'DE':
                    if 'MOTORS_TAB' in json_data['o']['w'][0][2]['model']['modules']:
                        category_id = json_data['o']['w'][0][2]['model']['modules']['MOTORS_TAB']['tabContent']['vehicleHsnTsnLookupTab']['callToActions'][0]['action']['params']['categoryId'].strip()
                        # print(json_data['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['title']['textSpans'][0]['text'].strip())
                        vehicle_page = json_data['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['pagination']['itemsPerPage']['label']['textSpans'][0]['text'].split('von')[1].strip()
                    else:
                        category_id = ''
                        vehicle_page = ''
                        
                # = = = = = = = = = = = = = = =
                
                title = json_data['o']['w'][0][2]['model']['modules']['TITLE']['mainTitle']['textSpans'][0]['text'].strip()

                # = = = = = = = = = = = = = = =
                
                if 'subTitle' in json_data['o']['w'][0][2]['model']['modules']['TITLE']:
                    subtitle = json_data['o']['w'][0][2]['model']['modules']['TITLE']['subTitle']['textSpans'][0]['text'].strip()
                else:
                    subtitle = ''
                    
                # = = = = = = = = = = = = = = =
                
                if 'binModel' in json_data['o']['w'][0][2]['model']['modules']['BUY_BOX']:
                    price = json_data['o']['w'][0][2]['model']['modules']['BUY_BOX']['binModel']['price']['textSpans'][0]['text'].strip()
                elif 'bidPrice' in json_data['o']['w'][0][2]['model']['modules']['BUY_BOX']:
                    price = json_data['o']['w'][0][2]['model']['modules']['BUY_BOX']['bidPrice']['textSpans'][0]['text'].strip()

                # = = = = = = = = = = = = = = =
                
                if 'QUANTITY' in json_data['o']['w'][0][2]['model']['modules']:
                    available = ''
                    sold = ''
                    list_text = json_data['o']['w'][0][2]['model']['modules']['QUANTITY']['availabilitySignal']['textSpans']
                    for text in list_text:
                        if param_market in ['US', 'AU', 'UK']:
                            if 'available' in text['text']:
                                available = text['text'].strip()
                            elif 'sold' in text['text']:
                                sold = text['text'].strip()
                        elif param_market == 'DE':
                            if 'verfügbar' in text['text']:
                                available = text['text'].strip()
                            elif 'verkauft' in text['text']:
                                sold = text['text'].strip()
                else:
                    available = ''
                    sold = ''
                    
                # = = = = = = = = = = = = = = =
                
                if 'largeImg' in json_data['o']['w'][0][2]['model']['modules']['PICTURE']['mediaList'][0]['image']:
                    src = json_data['o']['w'][0][2]['model']['modules']['PICTURE']['mediaList'][0]['image']['largeImg']['URL'].strip()
                else:
                    src = json_data['o']['w'][0][2]['model']['modules']['PICTURE']['mediaList'][0]['image']['originalImg']['URL'].strip()

                # = = = = = = = = = = = = = = =
                
                description_url = json_data['o']['w'][0][2]['model']['modules']['ITEM_DESCRIPTION_MIN_VIEW_MODULE']['sections'][0]['action']['URL'].strip()

                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                                         'Item_Number': input_.loc[a, 'Item_Number'],
                                         'Title': title,
                                         'Subtitle': subtitle,
                                         'Price': price,
                                         'Available': available,
                                         'Sold': sold,
                                         'Vehicle_1': '',
                                         'Vehicle_2': '',
                                         'Pic': '',
                                         'Url': url,
                                         'Description_Url': description_url,
                                         'Src': src,
                                         'Vehicle_Page': vehicle_page,
                                         'Category_Id': category_id,
                                         'Market_Id': market_id,
                                         'Country': country,
                                         'Language': language,
                                         'Locale': locale}])

                dict_name = {}
                if param_market in ['US', 'AU', 'UK']:
                    condition = 'Condition'
                elif param_market == 'DE':
                    condition = 'Artikelzustand'

                for i, name_value in zip(range(len(specification)), specification):
                    name = specification[name_value]['labels'][0]['textSpans'][0]['text'].strip()
                    if i == 0 and name == condition:
                        df_temp[condition] = specification[name_value]['values'][0]['textualDisplays'][0]['textSpans'][0]['text'].strip()
                    else:
                        name = name.lower()
                        if name in dict_name:
                            dict_name[name] += 1
                        else:
                            dict_name[name] = 1
                        df_temp[name if dict_name[name] == 1 else name + '-' + str(dict_name[name])] = specification[name_value]['values'][0]['textSpans'][0]['text'].strip()

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                                     'Item_Number': input_.loc[a, 'Item_Number']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Item_Number'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./item-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./item_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：122
#
# [ok] - 334736275234
# [尝试次数：1] - [剩余数量：102] - [当前时间：17:26:52]
#
# [ok] - 334736275231
# [尝试次数：1] - [剩余数量：101] - [当前时间：17:26:52]
#
# [ok] - 334736275230
# [尝试次数：1] - [剩余数量：100] - [当前时间：17:26:53]
#
# [ok] - 332815548809
# [尝试次数：1] - [剩余数量：99] - [当前时间：17:26:53]
#
# [ok] - 234888507108
# [尝试次数：1] - [剩余数量：98] - [当前时间：17:26:53]
#
# [ok] - 234888507385
# [尝试次数：1] - [剩余数量：97] - [当前时间：17:26:54]
#
# [ok] - 333597740697
# [尝试次数：1] - [剩余数量：96] - [当前时间：17:26:54]
#
# [ok] - 255967069224
# [尝试次数：1] - [剩余数量：95] - [当前时间：17:26:54]
#
# [ok] - 255967227720
# [尝试次数：1] - [剩余数量：94] - [当前时间：17:26:54]
#
# [ok] - 332815541872
# [尝试次数：1] - [剩余数量：93] - [当前时间：17:26:54]
#
# [ok] - 331893909141
# [尝试次数：1] - [剩余数量：92] - [当前时间：17:26:54]
#
# [ok] - 255967227716
# [尝试次数：1] - [剩余数量：91] - [当前时间：17:26:54]
#
# [ok] - 253003255617
# [尝试次数：1] - [剩余数量：90] - [当前时间：17:26:54]
#
# [ok] - 234887430733
# [尝试次数：1] - [剩余数量：89] - [当前时间：17:26:54]
#
# [ok] - 255965515063
# [尝试次数：1] - [剩余数量：88] - [当前时间：17:26:54]
#
# [ok] - 331893907451
# [尝试次数：1] - [剩余数量：87] - [当前时间：17:26:55]
#
# [ok] - 234888507102
# [尝试次数：1] - [剩余数量：86] - [当前时间：17:26:56]
#
# [ok] - 255967124702
# [尝试次数：1] - [剩余数量：85] - [当前时间：17:26:56]
#
# [ok] - 334736166593
# [尝试次数：1] - [剩余数量：84] - [当前时间：17:26:56]
#
# [ok] - 334736166591
# [尝试次数：1] - [剩余数量：83] - [当前时间：17:26:56]
#
# [ok] - 232181326901
# [尝试次数：1] - [剩余数量：82] - [当前时间：17:26:56]
#
# [ok] - 334736166567
# [尝试次数：1] - [剩余数量：81] - [当前时间：17:26:57]
#
# [ok] - 334737527487
# [尝试次数：1] - [剩余数量：80] - [当前时间：17:26:57]
#
# [ok] - 330572952784
# [尝试次数：1] - [剩余数量：79] - [当前时间：17:26:57]
#
# [ok] - 234888507105
# [尝试次数：1] - [剩余数量：78] - [当前时间：17:26:57]
#
# [ok] - 255134027144
# [尝试次数：1] - [剩余数量：77] - [当前时间：17:26:58]
#
# [ok] - 331541241872
# [尝试次数：1] - [剩余数量：76] - [当前时间：17:26:58]
#
# [ok] - 332970597711
# [尝试次数：1] - [剩余数量：75] - [当前时间：17:26:58]
#
# [ok] - 254795122793
# [尝试次数：1] - [剩余数量：74] - [当前时间：17:26:58]
#
# [ok] - 254435426972
# [尝试次数：1] - [剩余数量：73] - [当前时间：17:26:58]
#
# [ok] - 334737527492
# [尝试次数：1] - [剩余数量：72] - [当前时间：17:26:58]
#
# [ok] - 331541245075
# [尝试次数：1] - [剩余数量：71] - [当前时间：17:26:58]
#
# [ok] - 334734712470
# [尝试次数：1] - [剩余数量：70] - [当前时间：17:26:59]
#
# [ok] - 255079187349
# [尝试次数：1] - [剩余数量：69] - [当前时间：17:26:59]
#
# [ok] - 233642778293
# [尝试次数：1] - [剩余数量：68] - [当前时间：17:26:59]
#
# [ok] - 234889702474
# [尝试次数：1] - [剩余数量：67] - [当前时间：17:27:00]
#
# [ok] - 255965415105
# [尝试次数：1] - [剩余数量：66] - [当前时间：17:27:00]
#
# [ok] - 233398266952
# [尝试次数：1] - [剩余数量：65] - [当前时间：17:27:00]
#
# [ok] - 331470815776
# [尝试次数：1] - [剩余数量：64] - [当前时间：17:27:01]
#
# [ok] - 334483887592
# [尝试次数：1] - [剩余数量：63] - [当前时间：17:27:01]
#
# [ok] - 234600279292
# [尝试次数：1] - [剩余数量：62] - [当前时间：17:27:01]
#
# [ok] - 334736088458
# [尝试次数：3] - [剩余数量：61] - [当前时间：17:27:01]
#
# [ok] - 254687714598
# [尝试次数：1] - [剩余数量：60] - [当前时间：17:27:01]
#
# [ok] - 334483887593
# [尝试次数：1] - [剩余数量：59] - [当前时间：17:27:01]
#
# [ok] - 234887373084
# [尝试次数：1] - [剩余数量：58] - [当前时间：17:27:01]
#
# [ok] - 255091102600
# [尝试次数：1] - [剩余数量：57] - [当前时间：17:27:02]
#
# [ok] - 334483887601
# [尝试次数：1] - [剩余数量：56] - [当前时间：17:27:02]
#
# [ok] - 254429828362
# [尝试次数：1] - [剩余数量：55] - [当前时间：17:27:02]
#
# [ok] - 234883618887
# [尝试次数：1] - [剩余数量：54] - [当前时间：17:27:03]
#
# [ok] - 255960181217
# [尝试次数：1] - [剩余数量：53] - [当前时间：17:27:03]
#
# [ok] - 254325264592
# [尝试次数：1] - [剩余数量：52] - [当前时间：17:27:03]
#
# [ok] - 255960181221
# [尝试次数：1] - [剩余数量：51] - [当前时间：17:27:03]
#
# [ok] - 254325264568
# [尝试次数：2] - [剩余数量：50] - [当前时间：17:27:03]
#
# [ok] - 234583797283
# [尝试次数：1] - [剩余数量：49] - [当前时间：17:27:03]
#
# [ok] - 254795124704
# [尝试次数：1] - [剩余数量：48] - [当前时间：17:27:03]
#
# [ok] - 334731141966
# [尝试次数：1] - [剩余数量：47] - [当前时间：17:27:04]
#
# [ok] - 234884783553
# [尝试次数：1] - [剩余数量：46] - [当前时间：17:27:04]
#
# [ok] - 332678309249
# [尝试次数：1] - [剩余数量：45] - [当前时间：17:27:04]
#
# [ok] - 334468972416
# [尝试次数：1] - [剩余数量：44] - [当前时间：17:27:04]
#
# [ok] - 254325254110
# [尝试次数：1] - [剩余数量：43] - [当前时间：17:27:04]
#
# [ok] - 234887430729
# [尝试次数：1] - [剩余数量：42] - [当前时间：17:27:04]
#
# [ok] - 334731343848
# [尝试次数：1] - [剩余数量：41] - [当前时间：17:27:05]
#
# [ok] - 234601301988
# [尝试次数：1] - [剩余数量：40] - [当前时间：17:27:05]
#
# [ok] - 255599412343
# [尝试次数：1] - [剩余数量：39] - [当前时间：17:27:05]
#
# [ok] - 255090817709
# [尝试次数：1] - [剩余数量：38] - [当前时间：17:27:06]
#
# [ok] - 234186225337
# [尝试次数：1] - [剩余数量：37] - [当前时间：17:27:06]
#
# [ok] - 234601301991
# [尝试次数：1] - [剩余数量：36] - [当前时间：17:27:06]
#
# [ok] - 334484648154
# [尝试次数：1] - [剩余数量：35] - [当前时间：17:27:06]
#
# [ok] - 255961766222
# [尝试次数：1] - [剩余数量：34] - [当前时间：17:27:06]
#
# [ok] - 334223298645
# [尝试次数：1] - [剩余数量：33] - [当前时间：17:27:06]
#
# [ok] - 230613508176
# [尝试次数：1] - [剩余数量：32] - [当前时间：17:27:06]
#
# [ok] - 334147228429
# [尝试次数：1] - [剩余数量：31] - [当前时间：17:27:07]
#
# [ok] - 334484648158
# [尝试次数：1] - [剩余数量：30] - [当前时间：17:27:07]
#
# [ok] - 234884783559
# [尝试次数：1] - [剩余数量：29] - [当前时间：17:27:07]
#
# [ok] - 231995118792
# [尝试次数：1] - [剩余数量：28] - [当前时间：17:27:07]
#
# [ok] - 234884987348
# [尝试次数：1] - [剩余数量：27] - [当前时间：17:27:08]
#
# [ok] - 255233880055
# [尝试次数：1] - [剩余数量：26] - [当前时间：17:27:08]
#
# [ok] - 234136973904
# [尝试次数：1] - [剩余数量：25] - [当前时间：17:27:08]
#
# [ok] - 235083429885
# [尝试次数：1] - [剩余数量：24] - [当前时间：17:27:08]
#
# [ok] - 232976817111
# [尝试次数：1] - [剩余数量：23] - [当前时间：17:27:08]
#
# [ok] - 234186225971
# [尝试次数：1] - [剩余数量：22] - [当前时间：17:27:09]
#
# [ok] - 253477957000
# [尝试次数：1] - [剩余数量：21] - [当前时间：17:27:09]
#
# [ok] - 334217991313
# [尝试次数：1] - [剩余数量：20] - [当前时间：17:27:09]
#
# [ok] - 231115557818
# [尝试次数：1] - [剩余数量：19] - [当前时间：17:27:09]
#
# [ok] - 232692178325
# [尝试次数：1] - [剩余数量：18] - [当前时间：17:27:09]
#
# [ok] - 331085144899
# [尝试次数：1] - [剩余数量：17] - [当前时间：17:27:10]
#
# [ok] - 254854888209
# [尝试次数：1] - [剩余数量：16] - [当前时间：17:27:10]
#
# [ok] - 232702899673
# [尝试次数：1] - [剩余数量：15] - [当前时间：17:27:10]
#
# [ok] - 333046139436
# [尝试次数：2] - [剩余数量：14] - [当前时间：17:27:11]
#
# [ok] - 255968704520
# [尝试次数：1] - [剩余数量：13] - [当前时间：17:27:11]
#
# [ok] - 255233880068
# [尝试次数：1] - [剩余数量：12] - [当前时间：17:27:11]
#
# [ok] - 253502722895
# [尝试次数：1] - [剩余数量：11] - [当前时间：17:27:11]
#
# [ok] - 255134025625
# [尝试次数：1] - [剩余数量：10] - [当前时间：17:27:11]
#
# [ok] - 332568026195
# [尝试次数：1] - [剩余数量：9] - [当前时间：17:27:11]
#
# [ok] - 234120524621
# [尝试次数：1] - [剩余数量：8] - [当前时间：17:27:11]
#
# [ok] - 333291659492
# [尝试次数：3] - [剩余数量：7] - [当前时间：17:27:12]
#
# [ok] - 332331670271
# [尝试次数：1] - [剩余数量：6] - [当前时间：17:27:12]
#
# [ok] - 233308595310
# [尝试次数：4] - [剩余数量：5] - [当前时间：17:27:12]
#
# [ok] - 234887373082
# [尝试次数：2] - [剩余数量：4] - [当前时间：17:27:12]
#
# [ok] - 234124500367
# [尝试次数：2] - [剩余数量：3] - [当前时间：17:27:13]
#
# [ok] - 232463071851
# [尝试次数：1] - [剩余数量：2] - [当前时间：17:27:13]
#
# [ok] - 233399890617
# [尝试次数：3] - [剩余数量：1] - [当前时间：17:27:13]
#
# [ok] - 234131489962
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:13]
#
# [ok] - 234186225338
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:13]
#
# [ok] - 255134027127
# [尝试次数：4] - [剩余数量：0] - [当前时间：17:27:14]
#
# [ok] - 255574641093
# [尝试次数：2] - [剩余数量：0] - [当前时间：17:27:15]
#
# [ok] - 331837889689
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:15]
#
# [ok] - 251168844549
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:15]
#
# [ok] - 231911318577
# [尝试次数：2] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 332328649104
# [尝试次数：9] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 231786715451
# [尝试次数：4] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 254791771710
# [尝试次数：8] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 255080438225
# [尝试次数：3] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 231921315772
# [尝试次数：7] - [剩余数量：0] - [当前时间：17:27:16]
#
# [ok] - 231732286784
# [尝试次数：10] - [剩余数量：0] - [当前时间：17:27:17]
#
# [ok] - 234135085000
# [尝试次数：2] - [剩余数量：0] - [当前时间：17:27:20]
#
# [ok] - 254795124609
# [尝试次数：8] - [剩余数量：0] - [当前时间：17:27:22]
#
# [ok] - 332530742662
# [尝试次数：3] - [剩余数量：0] - [当前时间：17:27:33]
#
# [ok] - 255226859612
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:34]
#
# [ok] - 255086493126
# [尝试次数：3] - [剩余数量：0] - [当前时间：17:27:35]
#
# [ok] - 332583412825
# [尝试次数：1] - [剩余数量：0] - [当前时间：17:27:40]
#
# [ok] - 332678310757
# [尝试次数：2] - [剩余数量：0] - [当前时间：17:27:52]
#
# 输出ing...
#
# Done ~
