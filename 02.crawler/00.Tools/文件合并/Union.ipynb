# %%
import sys
sys.path.append('../../../00.module')
import Union

import pandas as pd

# %%
df = Union.get_Union_File('./file')

df.to_excel('./fuck.xlsx', index=False)

df
# Out:
# 进度: 100%|████████████████████████████████████| 2/2 [00:06<00:00,  3.28s/it]
#         序号 Part_Number                    Type  \
# 0        1     938-374             Drive Shaft
# 1        2     938-375             Drive Shaft
# 2        3     938-293             Drive Shaft
# 3        4     938-384             Drive Shaft
# 4        5     938-385             Drive Shaft
# ...    ...         ...                     ...
# 4062  4064    961-043D     Multi-Purpose Screw
# 4063  4065     963-232      Multi-Purpose Bolt
# 4064  4066    961-364D  Multi-Purpose Retainer
# 4065  4067    963-232D      Multi-Purpose Bolt
# 4066  3070     976-720             Drive Shaft
#
#                                             Description  \
# 0                             Front Driveshaft Assembly
# 1                             Front Driveshaft Assembly
# 2                             Front Driveshaft Assembly
# 3                             Front Driveshaft Assembly
# ...
