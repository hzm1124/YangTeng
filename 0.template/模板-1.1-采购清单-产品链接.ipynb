# %% [markdown]
# - Update: 2023.01.09
#
# # 0. 配置参数
#
# - `url`：what the fuck

# %%
import pyperclip

url = 'https://www.ebay.com/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=autopartszone2008&store_name=xpowerperformance&_oac=1&_nkw=spark%20plug%20wires'
# ytbuyer@hotmail.com
# yangteng20220811!

pyperclip.copy(url)

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By

browser = Chrome()

# %%
browser.get(url)

# %%
list_a =  browser.find_elements(by=By.CLASS_NAME, value='s-item__info')
list_a.pop(0)
for a in list_a:
    print(str(i) + ':')
    print(a.find_element(by=By.CLASS_NAME, value='s-item__title').text)
    print(a.find_element(by=By.CLASS_NAME, value='s-item__detail--primary').text.split('$')[1])
    print(a.find_element(by=By.TAG_NAME, value='a').get_attribute('href').split('?')[0])
    print()
# Out:
# 1:
# https://www.ebay.com/itm/272746571910
# JDMSPEED 10.5 MM SPARK PLUG WIRES FOR CHEVY GMC TRUCK 4.8 5.3 6.0 VORTEC ENGINES
# 26.88
#
# 2:
# https://www.ebay.com/itm/282581189046
# Red 10.5mm JDMSPEED Racing Spark Plug Wires Set for Ford 5.0L 5.8L, SB SBF 302
# 33.96
#
# 3:
# https://www.ebay.com/itm/282530512356
# JDMSPEED High Performance Spark Plug Ignition Wire For 2000-2009 CHEVY GMC V8
# 26.85
#
# 4:
# https://www.ebay.com/itm/283907790642
# HEI Spark Plug Wires Set 90 to Straight For Chevy SBC BBC 350 383 400 454 V8
# 32.85
#
# 5:
# https://www.ebay.com/itm/282559127003
# HEI RED Spiral Core SPARK PLUG WIRES 45 DEGREE END For BBC CHEVY 396-427-454-502
# 34.85
#
# 6:
# https://www.ebay.com/itm/272927723025
# JDMSPEED Ignition Spark Plug Wires Set for 97-01 Toyota Camry Solara Rav4 2.2L
# 19.96
#
# 7:
# https://www.ebay.com/itm/282024817363
# SPARK PLUG WIRE SET FOR HONDA CIVIC DEL SOL 92-00 EG EK EJ D15/D16 SPIRAL CORE
# 24.36
#
# 8:
# https://www.ebay.com/itm/273466525850
# ...

# %%
browser.close()
