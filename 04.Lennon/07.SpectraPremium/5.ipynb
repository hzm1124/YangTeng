# %%
import os

list_file = sorted(list(os.walk('./file/3.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_11.xlsx',
#  'crawler_12.xlsx',
#  'crawler_13.xlsx',
#  'crawler_14.xlsx',
#  'crawler_15.xlsx',
#  'crawler_16.xlsx',
#  'crawler_17.xlsx',
#  'crawler_18.xlsx',
#  'crawler_19.xlsx',
#  'crawler_2.xlsx',
#  'crawler_20.xlsx',
#  'crawler_21.xlsx',
#  'crawler_22.xlsx',
#  'crawler_23.xlsx',
#  'crawler_24.xlsx',
#  'crawler_25.xlsx',
#  'crawler_26.xlsx',
#  'crawler_27.xlsx',
#  'crawler_28.xlsx',
#  'crawler_29.xlsx',
#  'crawler_3.xlsx',
#  'crawler_30.xlsx',
#  'crawler_31.xlsx',
#  'crawler_32.xlsx',
#  'crawler_33.xlsx',
#  'crawler_34.xlsx',
#  'crawler_35.xlsx',
#  'crawler_36.xlsx',
#  'crawler_37.xlsx',
#  'crawler_38.xlsx',
#  'crawler_39.xlsx',
#  'crawler_4.xlsx',
#  'crawler_40.xlsx',
#  'crawler_41.xlsx',
#  'crawler_42.xlsx',
#  'crawler_43.xlsx',
#  'crawler_5.xlsx',
#  'crawler_6.xlsx',
#  'crawler_7.xlsx',
#  'crawler_8.xlsx',
#  'crawler_9.xlsx']

# %%
from tqdm import tqdm
import pandas as pd
from datetime import datetime

input_ = pd.DataFrame()
for file in tqdm(list_file, desc='Progress', ncols=77):
    df_temp = pd.read_excel(f'./file/3.part/{file}',
                            header=0,
                            dtype=str).fillna('')
    
    df_temp['No'] = df_temp['No'].astype(int)
    df_temp['Vehicle Page'] = df_temp['Vehicle Page'].astype(int)

    input_ = pd.concat([input_, df_temp], ignore_index=True).fillna('')

list_column = input_.columns.tolist()
list_column.remove('No')
input_ = input_.drop_duplicates(list_column,
                                keep='first',
                                ignore_index=True)
input_ = input_.sort_values(by=['Type', 'Part Number'],
                            ascending=[True, True],
                            ignore_index=True)

input_['No'] = [_+1 for _ in range(len(input_))]

input_.to_excel(f'''./file/【网站爬虫】SpectraPremium-{datetime.now().strftime('%Y%m%d')}.xlsx''', index=False)

input_
# Out:
# Progress: 100%|██████████████████████████████| 43/43 [00:01<00:00, 25.39it/s]
#           No                                             Market  \
# 0          1  All product lines marked with a maple leaf are...
# 1          2  All product lines marked with a maple leaf are...
# 2          3  All product lines marked with a maple leaf are...
# 3          4  All product lines marked with a maple leaf are...
# 4          5  All product lines marked with a maple leaf are...
# ...      ...                                                ...
# 10907  10908
# 10908  10909
# 10909  10910
# 10910  10911
# 10911  10912
#
#                                  Type Part Number Picture  \
# 0                         Accumulator     0210000
# 1                         Accumulator     0210003
# 2                         Accumulator     0210005
# 3                         Accumulator     0210007
# 4                         Accumulator     0210008
# ...
