# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./11.part_2'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:

    # = = = = = = = = = = = = = = =
    
    output_correct, output_error = pd.DataFrame(), pd.DataFrame()
    
    # = = = = = = = = = = = = = = =
    
    input_ = pd.read_excel(f'./11.part_2/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_ = input_[input_['Vehicle Url'] != ''].reset_index(drop=True)
    
    input_['No'] = input_['No'].astype(int)
    
    print(f'总数量：{len(input_)}')
    print()
    
    # = = = = = = = = = = = = = = =
    
    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)
    
    # = = = = = = = = = = = = = = =
    
    def crawler():
        global output_correct, output_error
    
        while not work.empty():
            a = work.get_nowait()
    
            # = = = = = = = = = = = = = = =
    
            crawler_status = 'error'
    
            # = = = = = = = = = = = = = = =
    
            try:
                df_temp, page = pd.DataFrame(), 1
                while True:
                    b = 0
                    while True:
                        b += 1
                        
                        try:
                            resp = requests.get(f'''{input_.loc[a, 'Vehicle Url']}&start={page*50-50}&num=50''',
                                                headers=get_header(),
                                                proxies=get_proxy(),
                                                timeout=(10, 10))
                
                            if resp.status_code == 200:
                                soup = BeautifulSoup(resp.text, 'lxml')
                                html = etree.HTML(str(soup))
                
                                # = = = = = = = = = = = = = = =
                
                                if html.xpath('//div[@class="detail-app-pager"]'):
                                    break
                        except:
                            continue

                    # = = = = = = = = = = = = = = =

                    next_ = html.xpath('//a[@id="pagingBottom_nextButton"]')

                    # = = = = = = = = = = = = = = =

                    if next_ and next_[0].xpath('./@href')[0].strip() == 'Search/#':
                        raise
                        
                    # = = = = = = = = = = = = = = =

                    list_th = [text.strip() for text in html.xpath('//th[@scope="col"]/text()')]

                    # = = = = = = = = = = = = = = =

                    list_tr = html.xpath('//tr[@class="detail-app-row"]')

                    # = = = = = = = = = = = = = = =

                    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                                 'Part Number': input_.loc[a, 'Part Number'],
                                                 'Vehicle Url': input_.loc[a, 'Vehicle Url'],
                                                 'Page': page,
                                                 'Row': [i+1 for i in range(len(list_tr))]})
                
                    for i, tr in zip(range(len(list_tr)), list_tr):
                        for j, th in zip(range(len(list_th)), list_th):
                            df_temp_temp.loc[i, th] = tr.xpath(f'./td[{j+1}]/text()')[0].strip()
                
                    df_temp = pd.concat([df_temp, df_temp_temp], ignore_index=True).fillna('')

                    # = = = = = = = = = = = = = = =

                    if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 100 == 0 and work.qsize() != 0:
                        clear_output()
                    
                    print(f'''[尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} - {input_.loc[a, 'No']}.{input_.loc[a, 'Part Number']} > Page {page}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                    # = = = = = = = = = = = = = = =

                    page += 1

                    # = = = = = = = = = = = = = = =

                    if not next_:
                        break

                # = = = = = = = = = = = = = = =

                if df_temp.empty:
                    raise

                # = = = = = = = = = = = = = = =

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
    
                # = = = = = = = = = = = = = = =
    
                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                                         'Part Number': input_.loc[a, 'Part Number'],
                                         'Vehicle Url': input_.loc[a, 'Vehicle Url']}])
    
                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

    # = = = = = = = = = = = = = = =
    
    list_task = []
    for _ in range(10):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)
    
    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No', 'Page', 'Row'],
                                                    ascending=[True, True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./12.vehicle/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./12.vehicle/0.error/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()
print('Done ~')
# Out:
# 总数量：2
#
# [尝试次数：21] - 0.05% - type_1.Air Suspension Line Repair Kit - 2.949-210 > Page 1
# [剩余数量：0] - [当前时间：17:22:14]
#
# [尝试次数：1] - 0.05% - type_1.Air Suspension Line Repair Kit - 2.949-210 > Page 2
# [剩余数量：0] - [当前时间：17:22:17]
#
# [尝试次数：21] - 0.05% - type_1.Air Suspension Line Repair Kit - 1.949-006 > Page 1
# [剩余数量：0] - [当前时间：17:22:18]
#
# [尝试次数：1] - 0.05% - type_1.Air Suspension Line Repair Kit - 2.949-210 > Page 3
# [剩余数量：0] - [当前时间：17:22:23]
#
# [尝试次数：1] - 0.05% - type_1.Air Suspension Line Repair Kit - 2.949-210 > Page 4
# [剩余数量：0] - [当前时间：17:22:29]
#
# 输出ing...
#
# 总数量：2
#
# [尝试次数：19] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 1
# [剩余数量：0] - [当前时间：17:22:33]
#
# [尝试次数：16] - 0.10% - type_10.4WD Actuator Wiring Harness - 40.600-600 > Page 1
# [剩余数量：0] - [当前时间：17:22:33]
#
# [尝试次数：3] - 0.10% - type_10.4WD Actuator Wiring Harness - 40.600-600 > Page 2
# [剩余数量：0] - [当前时间：17:22:36]
#
# [尝试次数：38] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 2
# [剩余数量：0] - [当前时间：17:22:37]
#
# [尝试次数：10] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 3
# [剩余数量：0] - [当前时间：17:22:51]
#
# [尝试次数：27] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 4
# [剩余数量：0] - [当前时间：17:23:02]
#
# [尝试次数：1] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 5
# [剩余数量：0] - [当前时间：17:23:03]
#
# [尝试次数：1] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 6
# [剩余数量：0] - [当前时间：17:23:08]
#
# [尝试次数：2] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 7
# [剩余数量：0] - [当前时间：17:23:12]
#
# [尝试次数：5] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 8
# [剩余数量：0] - [当前时间：17:23:15]
#
# [尝试次数：43] - 0.10% - type_10.4WD Actuator Wiring Harness - 41.645-902 > Page 9
# [剩余数量：0] - [当前时间：17:23:21]
#
# 输出ing...
#
# 总数量：250
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2488.533-063 > Page 1
# [剩余数量：240] - [当前时间：17:23:24]
#
# [尝试次数：5] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2491.533-066 > Page 1
# [剩余数量：240] - [当前时间：17:23:25]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2483.533-058 > Page 1
# [剩余数量：239] - [当前时间：17:23:25]
#
# [尝试次数：6] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2487.533-062 > Page 1
# [剩余数量：239] - [当前时间：17:23:25]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2486.533-061 > Page 1
# [剩余数量：239] - [当前时间：17:23:25]
#
# [尝试次数：2] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2490.533-065 > Page 1
# [剩余数量：239] - [当前时间：17:23:25]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2489.533-064 > Page 1
# [剩余数量：239] - [当前时间：17:23:25]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2485.533-060 > Page 1
# [剩余数量：239] - [当前时间：17:23:26]
#
# [尝试次数：9] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2484.533-059 > Page 1
# [剩余数量：239] - [当前时间：17:23:26]
#
# [尝试次数：4] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2487.533-062 > Page 2
# [剩余数量：239] - [当前时间：17:23:26]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2483.533-058 > Page 2
# [剩余数量：238] - [当前时间：17:23:27]
#
# [尝试次数：6] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2486.533-061 > Page 2
# [剩余数量：237] - [当前时间：17:23:27]
#
# [尝试次数：15] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2485.533-060 > Page 2
# [剩余数量：236] - [当前时间：17:23:28]
#
# [尝试次数：22] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2492.533-067 > Page 1
# [剩余数量：235] - [当前时间：17:23:28]
#
# [尝试次数：20] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2489.533-064 > Page 2
# [剩余数量：234] - [当前时间：17:23:28]
#
# [尝试次数：8] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2484.533-059 > Page 2
# [剩余数量：233] - [当前时间：17:23:28]
#
# [尝试次数：12] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2493.533-068 > Page 1
# [剩余数量：232] - [当前时间：17:23:30]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2499.533-074 > Page 1
# [剩余数量：232] - [当前时间：17:23:31]
#
# [尝试次数：16] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2490.533-065 > Page 2
# [剩余数量：232] - [当前时间：17:23:31]
#
# [尝试次数：5] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2498.533-073 > Page 1
# [剩余数量：231] - [当前时间：17:23:32]
#
# [尝试次数：30] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2494.533-069 > Page 1
# [剩余数量：231] - [当前时间：17:23:33]
#
# [尝试次数：31] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2500.533-075 > Page 1
# [剩余数量：231] - [当前时间：17:23:34]
#
# [尝试次数：11] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2494.533-069 > Page 2
# [剩余数量：231] - [当前时间：17:23:35]
#
# [尝试次数：109] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2488.533-063 > Page 2
# [剩余数量：231] - [当前时间：17:23:35]
#
# [尝试次数：47] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2493.533-068 > Page 2
# [剩余数量：230] - [当前时间：17:23:35]
#
# [尝试次数：72] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2496.533-071 > Page 1
# [剩余数量：230] - [当前时间：17:23:36]
#
# [尝试次数：33] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2482.533-057 > Page 1
# [剩余数量：230] - [当前时间：17:23:36]
#
# [尝试次数：32] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2499.533-074 > Page 2
# [剩余数量：230] - [当前时间：17:23:37]
#
# [尝试次数：39] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2498.533-073 > Page 2
# [剩余数量：230] - [当前时间：17:23:38]
#
# [尝试次数：7] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2501.533-076 > Page 1
# [剩余数量：230] - [当前时间：17:23:38]
#
# [尝试次数：18] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2500.533-075 > Page 2
# [剩余数量：230] - [当前时间：17:23:38]
#
# [尝试次数：11] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2495.533-070 > Page 1
# [剩余数量：230] - [当前时间：17:23:38]
#
# [尝试次数：91] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2497.533-072 > Page 1
# [剩余数量：230] - [当前时间：17:23:39]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2493.533-068 > Page 3
# [剩余数量：230] - [当前时间：17:23:39]
#
# [尝试次数：2] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2493.533-068 > Page 4
# [剩余数量：230] - [当前时间：17:23:41]
#
# [尝试次数：11] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2495.533-070 > Page 2
# [剩余数量：229] - [当前时间：17:23:41]
#
# [尝试次数：10] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2497.533-072 > Page 2
# [剩余数量：229] - [当前时间：17:23:41]
#
# [尝试次数：27] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2501.533-076 > Page 2
# [剩余数量：229] - [当前时间：17:23:42]
#
# [尝试次数：22] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2500.533-075 > Page 3
# [剩余数量：229] - [当前时间：17:23:42]
#
# [尝试次数：47] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2499.533-074 > Page 3
# [剩余数量：229] - [当前时间：17:23:43]
#
# [尝试次数：75] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2494.533-069 > Page 3
# [剩余数量：229] - [当前时间：17:23:43]
#
# [尝试次数：63] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2496.533-071 > Page 2
# [剩余数量：229] - [当前时间：17:23:43]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2502.533-077 > Page 1
# [剩余数量：229] - [当前时间：17:23:43]
#
# [尝试次数：7] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2498.533-073 > Page 3
# [剩余数量：229] - [当前时间：17:23:44]
#
# [尝试次数：7] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2495.533-070 > Page 3
# [剩余数量：229] - [当前时间：17:23:44]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2500.533-075 > Page 4
# [剩余数量：229] - [当前时间：17:23:45]
#
# [尝试次数：28] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2497.533-072 > Page 3
# [剩余数量：229] - [当前时间：17:23:46]
#
# [尝试次数：8] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2495.533-070 > Page 4
# [剩余数量：229] - [当前时间：17:23:47]
#
# [尝试次数：38] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2501.533-076 > Page 3
# [剩余数量：229] - [当前时间：17:23:47]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2496.533-071 > Page 3
# [剩余数量：229] - [当前时间：17:23:48]
#
# [尝试次数：25] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2498.533-073 > Page 4
# [剩余数量：229] - [当前时间：17:23:48]
#
# [尝试次数：41] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2502.533-077 > Page 2
# [剩余数量：229] - [当前时间：17:23:49]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2500.533-075 > Page 5
# [剩余数量：229] - [当前时间：17:23:49]
#
# [尝试次数：15] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2499.533-074 > Page 4
# [剩余数量：228] - [当前时间：17:23:49]
#
# [尝试次数：24] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2497.533-072 > Page 4
# [剩余数量：228] - [当前时间：17:23:49]
#
# [尝试次数：12] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2495.533-070 > Page 5
# [剩余数量：228] - [当前时间：17:23:50]
#
# [尝试次数：7] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2496.533-071 > Page 4
# [剩余数量：227] - [当前时间：17:23:51]
#
# [尝试次数：20] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2499.533-074 > Page 5
# [剩余数量：227] - [当前时间：17:23:53]
#
# [尝试次数：38] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2498.533-073 > Page 5
# [剩余数量：226] - [当前时间：17:23:53]
#
# [尝试次数：35] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2504.533-079 > Page 1
# [剩余数量：225] - [当前时间：17:23:55]
#
# [尝试次数：47] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2497.533-072 > Page 5
# [剩余数量：225] - [当前时间：17:23:56]
#
# [尝试次数：16] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2496.533-071 > Page 5
# [剩余数量：224] - [当前时间：17:23:57]
#
# [尝试次数：37] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2505.533-080 > Page 1
# [剩余数量：223] - [当前时间：17:23:57]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2507.533-082 > Page 1
# [剩余数量：222] - [当前时间：17:23:58]
#
# [尝试次数：15] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2501.533-076 > Page 4
# [剩余数量：222] - [当前时间：17:23:59]
#
# [尝试次数：19] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2494.533-069 > Page 4
# [剩余数量：222] - [当前时间：17:23:59]
#
# [尝试次数：51] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2482.533-057 > Page 2
# [剩余数量：222] - [当前时间：17:24:00]
#
# [尝试次数：8] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2509.533-084 > Page 1
# [剩余数量：221] - [当前时间：17:24:00]
#
# [尝试次数：16] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2507.533-082 > Page 2
# [剩余数量：220] - [当前时间：17:24:02]
#
# [尝试次数：9] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2504.533-079 > Page 2
# [剩余数量：219] - [当前时间：17:24:02]
#
# [尝试次数：15] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2510.533-085 > Page 1
# [剩余数量：219] - [当前时间：17:24:03]
#
# [尝试次数：55] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2508.533-083 > Page 1
# [剩余数量：218] - [当前时间：17:24:03]
#
# [尝试次数：23] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2501.533-076 > Page 5
# [剩余数量：217] - [当前时间：17:24:04]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2513.533-088 > Page 1
# [剩余数量：216] - [当前时间：17:24:04]
#
# [尝试次数：59] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2494.533-069 > Page 5
# [剩余数量：216] - [当前时间：17:24:06]
#
# [尝试次数：26] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2512.533-087 > Page 1
# [剩余数量：215] - [当前时间：17:24:06]
#
# [尝试次数：147] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2503.533-078 > Page 1
# [剩余数量：215] - [当前时间：17:24:06]
#
# [尝试次数：50] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2502.533-077 > Page 3
# [剩余数量：215] - [当前时间：17:24:07]
#
# [尝试次数：10] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2515.533-090 > Page 1
# [剩余数量：215] - [当前时间：17:24:07]
#
# [尝试次数：32] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2504.533-079 > Page 3
# [剩余数量：215] - [当前时间：17:24:07]
#
# [尝试次数：130] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2506.533-081 > Page 1
# [剩余数量：215] - [当前时间：17:24:07]
#
# [尝试次数：29] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2511.533-086 > Page 1
# [剩余数量：215] - [当前时间：17:24:07]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2512.533-087 > Page 2
# [剩余数量：214] - [当前时间：17:24:09]
#
# [尝试次数：7] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2515.533-090 > Page 2
# [剩余数量：213] - [当前时间：17:24:09]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2514.533-089 > Page 1
# [剩余数量：212] - [当前时间：17:24:10]
#
# [尝试次数：3] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2503.533-078 > Page 2
# [剩余数量：212] - [当前时间：17:24:10]
#
# [尝试次数：2] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2516.533-091 > Page 1
# [剩余数量：212] - [当前时间：17:24:10]
#
# [尝试次数：13] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2504.533-079 > Page 4
# [剩余数量：212] - [当前时间：17:24:10]
#
# [尝试次数：15] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2517.533-092 > Page 1
# [剩余数量：212] - [当前时间：17:24:11]
#
# [尝试次数：21] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2502.533-077 > Page 4
# [剩余数量：212] - [当前时间：17:24:12]
#
# [尝试次数：5] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2514.533-089 > Page 2
# [剩余数量：212] - [当前时间：17:24:12]
#
# [尝试次数：10] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2516.533-091 > Page 2
# [剩余数量：211] - [当前时间：17:24:13]
#
# [尝试次数：59] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2506.533-081 > Page 2
# [剩余数量：210] - [当前时间：17:24:13]
#
# [尝试次数：64] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2513.533-088 > Page 2
# [剩余数量：209] - [当前时间：17:24:14]
#
# [尝试次数：9] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2520.533-105 > Page 1
# [剩余数量：208] - [当前时间：17:24:15]
#
# [尝试次数：54] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2518.533-093 > Page 1
# [剩余数量：208] - [当前时间：17:24:16]
#
# [尝试次数：18] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2521.533-106 > Page 1
# [剩余数量：208] - [当前时间：17:24:16]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2517.533-092 > Page 2
# [剩余数量：208] - [当前时间：17:24:16]
#
# [尝试次数：4] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2522.533-107 > Page 1
# [剩余数量：207] - [当前时间：17:24:16]
#
# [尝试次数：5] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2520.533-105 > Page 2
# [剩余数量：207] - [当前时间：17:24:17]
#
# [尝试次数：13] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2523.533-112 > Page 1
# [剩余数量：207] - [当前时间：17:24:17]
#
# [尝试次数：56] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2503.533-078 > Page 3
# [剩余数量：207] - [当前时间：17:24:17]
#
# [尝试次数：45] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2502.533-077 > Page 5
# [剩余数量：207] - [当前时间：17:24:17]
#
# [尝试次数：9] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2523.533-112 > Page 2
# [剩余数量：206] - [当前时间：17:24:19]
#
# [尝试次数：26] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2521.533-106 > Page 2
# [剩余数量：206] - [当前时间：17:24:19]
#
# [尝试次数：24] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2522.533-107 > Page 2
# [剩余数量：206] - [当前时间：17:24:20]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2503.533-078 > Page 4
# [剩余数量：206] - [当前时间：17:24:20]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2520.533-105 > Page 3
# [剩余数量：206] - [当前时间：17:24:21]
#
# [尝试次数：98] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2519.533-094 > Page 1
# [剩余数量：206] - [当前时间：17:24:21]
#
# [尝试次数：41] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2518.533-093 > Page 2
# [剩余数量：205] - [当前时间：17:24:22]
#
# [尝试次数：30] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2523.533-112 > Page 3
# [剩余数量：205] - [当前时间：17:24:23]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2520.533-105 > Page 4
# [剩余数量：205] - [当前时间：17:24:24]
#
# [尝试次数：71] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2524.545-100 > Page 1
# [剩余数量：205] - [当前时间：17:24:24]
#
# [尝试次数：46] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2525.545-101 > Page 1
# [剩余数量：205] - [当前时间：17:24:24]
#
# [尝试次数：9] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2526.545-106 > Page 1
# [剩余数量：205] - [当前时间：17:24:25]
#
# [尝试次数：61] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2504.533-079 > Page 5
# [剩余数量：205] - [当前时间：17:24:25]
#
# [尝试次数：32] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2521.533-106 > Page 3
# [剩余数量：204] - [当前时间：17:24:25]
#
# [尝试次数：24] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2522.533-107 > Page 3
# [剩余数量：204] - [当前时间：17:24:25]
#
# [尝试次数：1] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2523.533-112 > Page 4
# [剩余数量：204] - [当前时间：17:24:26]
#
# [尝试次数：11] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2503.533-078 > Page 5
# [剩余数量：204] - [当前时间：17:24:27]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2527.545-113 > Page 1
# [剩余数量：203] - [当前时间：17:24:28]
#
# [尝试次数：16] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2525.545-101 > Page 2
# [剩余数量：203] - [当前时间：17:24:28]
#
# [尝试次数：2] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2520.533-105 > Page 5
# [剩余数量：203] - [当前时间：17:24:28]
#
# [尝试次数：6] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2528.545-116 > Page 1
# [剩余数量：202] - [当前时间：17:24:28]
#
# [尝试次数：17] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2521.533-106 > Page 4
# [剩余数量：202] - [当前时间：17:24:29]
#
# [尝试次数：27] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2522.533-107 > Page 4
# [剩余数量：202] - [当前时间：17:24:29]
#
# [尝试次数：57] - 0.15% - type_100.Alignment - Caster %2F Camber Bushing - 2524.545-100 > Page 2
# [剩余数量：202] - [当前时间：17:24:32]
