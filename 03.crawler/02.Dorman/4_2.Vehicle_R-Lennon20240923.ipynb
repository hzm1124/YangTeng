# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/4.vehicle'):
    shutil.rmtree('./file/4.vehicle')

os.makedirs('./file/4.vehicle')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/3.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/3.part/{file}',
                           header=0,
                           dtype=str).fillna('')

    input_ = input_[input_['Vehicle Url'] != ''].reset_index(drop=True)
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                df_temp, page = pd.DataFrame(), 0
                while True:
                    b = 0
                    while True:
                        b += 1

                        try:
                            request_url = f'''{input_.loc[a, 'Vehicle Url']}&start={page*50}&num=50'''
                            
                            resp = requests.get(request_url,
                                                headers=get_header(),
                                                proxies=get_proxy(),
                                                timeout=(10, 10))
                        
                            if resp.status_code == 200:
                                soup = BeautifulSoup(resp.text, 'lxml')
                                html = etree.HTML(str(soup))
                    
                                if html.xpath('//div[@class="detail-app-pager"]'):
                                    break
                        except KeyboardInterrupt:
                            break
                        except:
                            continue
                
                    # = = = = = = = = = = = = = = =
                
                    next_ = html.xpath('//a[@id="pagingBottom_nextButton"]')
                    if page == 0 and next_ and next_[0].xpath('./@href')[0].strip() == 'Search/#':
                        raise
                        
                    # = = = = = = = = = = = = = = =
                
                    list_th, list_tr = [text.strip() for text in html.xpath('//th[@scope="col"]/text()')], html.xpath('//tr[@class="detail-app-row"]')
                
                    # = = = = = = = = = = = = = = =
                
                    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                                 'Part Number': input_.loc[a, 'Part Number'],
                                                 'Vehicle Url': input_.loc[a, 'Vehicle Url'],
                                                 'Page': page + 1,
                                                 'Row': [i+1 for i in range(len(list_tr))]})
                
                    for i, tr in enumerate(list_tr):
                        for j, th in enumerate(list_th):
                            df_temp_temp.loc[i, th] = tr.xpath(f'./td[{j+1}]/text()')[0].strip()
                
                    df_temp = pd.concat([df_temp, df_temp_temp], ignore_index=True).fillna('')
                
                    # = = = = = = = = = = = = = = =

                    if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 10 == 0 and work.qsize() != 0:
                        clear_output()

                    print(f'''[尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} - {input_.loc[a, 'No']}.{request_url} > Page {page + 1}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                    # = = = = = = = = = = = = = = =
                
                    page += 1
                    
                    # = = = = = = = = = = = = = = =
                
                    if not next_:
                        break

                # = = = = = = = = = = = = = = =

                if df_temp.empty:
                    raise

                # = = = = = = = = = = = = = = =

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
                df_temp.loc[0, 'Request_Url'] = request_url
                
                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct['Year'] = output_correct['Year'].astype(int)
        
        output_correct = output_correct.sort_values(by=['No', 'Page', 'Row'],
                                                    ascending=[True, True, True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/4.vehicle/{file.removesuffix('.xlsx')}-vehicle-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/4.vehicle'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/4.vehicle/{file}',
              f'''./file/4.vehicle/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：10
#
# [尝试次数：1] - 50.00% - crawler_1 - 4.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=15216&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：5] - [当前时间：14:05:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 3.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=9423&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：4] - [当前时间：14:05:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 5.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=15277&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：3] - [当前时间：14:05:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 2.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=9421&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：2] - [当前时间：14:05:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 1.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=25698&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：1] - [当前时间：14:05:51]
#
# [尝试次数：1] - 50.00% - crawler_1 - 7.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50659&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:05:52]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50424&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:05:53]
#
# [尝试次数：1] - 50.00% - crawler_1 - 6.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=47833&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:05:53]
#
# [尝试次数：1] - 50.00% - crawler_1 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=12090&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:05:55]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50424&PartType=Wheel%20Cylinder&start=50&num=50 > Page 2
# [剩余数量：0] - [当前时间：14:05:55]
#
# [尝试次数：1] - 50.00% - crawler_1 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=12090&PartType=Wheel%20Cylinder&start=50&num=50 > Page 2
# [剩余数量：0] - [当前时间：14:05:56]
#
# [尝试次数：1] - 50.00% - crawler_1 - 8.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=50424&PartType=Wheel%20Cylinder&start=100&num=50 > Page 3
# [剩余数量：0] - [当前时间：14:05:56]
#
# [尝试次数：4] - 50.00% - crawler_1 - 9.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=21537&PartType=Wheel%20Cylinder&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:06]
#
# [尝试次数：1] - 50.00% - crawler_1 - 9.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=21537&PartType=Wheel%20Cylinder&start=50&num=50 > Page 2
# [剩余数量：0] - [当前时间：14:06:08]
#
# 输出ing...
#
# 总数量：10
#
# [尝试次数：1] - 100.00% - crawler_2 - 4.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=3053&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：5] - [当前时间：14:06:09]
#
# [尝试次数：1] - 100.00% - crawler_2 - 3.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=2022&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：4] - [当前时间：14:06:09]
#
# [尝试次数：1] - 100.00% - crawler_2 - 2.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=17619&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：3] - [当前时间：14:06:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 1.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=32211&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：2] - [当前时间：14:06:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 5.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=15500&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：1] - [当前时间：14:06:10]
#
# [尝试次数：1] - 100.00% - crawler_2 - 6.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=153595&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 7.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=152638&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 9.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=152746&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:11]
#
# [尝试次数：1] - 100.00% - crawler_2 - 8.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=152639&PartType=Engine%20Oil%20Pan&start=0&num=50 > Page 1
# [剩余数量：0] - [当前时间：14:06:14]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=50&num=50 > Page 2
# [剩余数量：0] - [当前时间：14:06:14]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=100&num=50 > Page 3
# [剩余数量：0] - [当前时间：14:06:18]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=150&num=50 > Page 4
# [剩余数量：0] - [当前时间：14:06:20]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=200&num=50 > Page 5
# [剩余数量：0] - [当前时间：14:06:21]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=250&num=50 > Page 6
# [剩余数量：0] - [当前时间：14:06:24]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=300&num=50 > Page 7
# [剩余数量：0] - [当前时间：14:06:27]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=350&num=50 > Page 8
# [剩余数量：0] - [当前时间：14:06:28]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=400&num=50 > Page 9
# [剩余数量：0] - [当前时间：14:06:33]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=450&num=50 > Page 10
# [剩余数量：0] - [当前时间：14:06:35]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=500&num=50 > Page 11
# [剩余数量：0] - [当前时间：14:06:36]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=550&num=50 > Page 12
# [剩余数量：0] - [当前时间：14:06:45]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=600&num=50 > Page 13
# [剩余数量：0] - [当前时间：14:06:46]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=650&num=50 > Page 14
# [剩余数量：0] - [当前时间：14:06:53]
#
# [尝试次数：1] - 100.00% - crawler_2 - 10.https://www.dormanproducts.com/itemdetailapp.aspx?ProductID=133461&PartType=Engine%20Oil%20Pan%20Gasket&start=700&num=50 > Page 15
# [剩余数量：0] - [当前时间：14:06:55]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 4148.67it/s]
# Done ~
