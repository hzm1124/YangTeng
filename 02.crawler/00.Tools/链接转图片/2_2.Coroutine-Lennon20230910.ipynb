# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../../00.module')
import Proxy

# = = = = = = = = = = = = = = =

from openpyxl import load_workbook

wb = load_workbook('./crawler.xlsx')
ws = wb.active

for column in range(1, ws.max_column+1):
    if ws.cell(1, column).value == 'Src':
        src_index = column
    elif ws.cell(1, column).value == 'Pic':
        pic_index = column
        
print('Src索引：' + str(src_index))
print('Pic索引：' + str(pic_index))
print()
print('总数量：' + str(ws.max_row-1))
print()     

# = = = = = = = = = = = = = = =

import requests
from io import BytesIO
import PIL
from openpyxl.drawing import image

# = = = = = = = = = = = = = = =

from openpyxl.utils import get_column_letter

# = = = = = = = = = = = = = = =

import time

# = = = = = = = = = = = = = = =

work = Queue()
for row in range(2, ws.max_row+1):
    work.put_nowait(row)

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        
        # = = = = = = = = = = = = = = = = = =
        
        src = ws.cell(row, src_index).value
        
        # = = = = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(101):
            if src == None or src == '':
                break
            
            try:
                pic = PIL.Image.open(BytesIO(requests.get(src, proxies=Proxy.get_Proxy_Requests()).content)).convert('RGB')
                pic.save('./pic/' + str(row) + '.png', 'png')
                pic = image.Image('./pic/' + str(row) + '.png')
                
                # = = = = = = = = = = = = = = = = = =
                
                if pic.width >= pic.height:
                    pic.height = 50.0 / pic.width * pic.height
                    pic.width = 50.0
                else:
                    pic.width = 50.0 / pic.height * pic.width
                    pic.height = 50.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                ws.add_image(pic, get_column_letter(pic_index) + str(row))
                
                status = 'ok'
                
                break
                
            except:
                time.sleep(3)
                continue
                
        # = = = = = = = = = = = = = = = = = =
        
        if src != None and src != '':
            print(src +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print()
print('爬虫输出中')
wb.save('./crawler-pic.xlsx')
print()
print('爬虫结束')
# Out:
# Src索引：7
# Pic索引：5
#
# https://m.media-amazon.com/images/I/61JMep0bhrL._AC_SY355_.jpg  <->  [ok] - 剩余数量：80
# https://m.media-amazon.com/images/I/61WpXMyvVOL._AC_SY355_.jpg  <->  [ok] - 剩余数量：79
# https://m.media-amazon.com/images/I/51V5bTHxGDL._AC_SX466_.jpg  <->  [ok] - 剩余数量：78
# https://m.media-amazon.com/images/I/71eMlezEyyL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：77
# https://m.media-amazon.com/images/I/71528ZWiHbL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：76
# https://m.media-amazon.com/images/I/71Ik8u6EJXL._AC_SX466_.jpg  <->  [ok] - 剩余数量：75
# https://m.media-amazon.com/images/I/51I++LTxEPL._AC_SY300_SX300_.jpg  <->  [ok] - 剩余数量：74
# https://m.media-amazon.com/images/I/71fPVQNMiEL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：73
# https://m.media-amazon.com/images/I/31k+wj4KGzS._SX342_SY445_.jpg  <->  [ok] - 剩余数量：72
# https://m.media-amazon.com/images/I/61Re7UhiwbL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：71
# https://m.media-amazon.com/images/I/616AGFwwYNL._AC_SX466_.jpg  <->  [ok] - 剩余数量：70
# https://m.media-amazon.com/images/I/61ZXvT+NHaL._AC_SY550_.jpg  <->  [ok] - 剩余数量：69
# https://m.media-amazon.com/images/I/61kctAqfL3L._AC_SY355_.jpg  <->  [ok] - 剩余数量：68
# https://m.media-amazon.com/images/I/6106QAF5-YL._AC_SY679_.jpg  <->  [ok] - 剩余数量：67
# https://m.media-amazon.com/images/I/61L-dRpbJJL._SX522_.jpg  <->  [ok] - 剩余数量：66
# https://m.media-amazon.com/images/I/51ytOl-pkIL._AC_SX466_.jpg  <->  [ok] - 剩余数量：65
# https://m.media-amazon.com/images/I/61l2D-jhE6L._AC_SY355_.jpg  <->  [ok] - 剩余数量：64
# https://m.media-amazon.com/images/I/71yqZBXnYLL._AC_SY679_PIbundle-10,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：63
# https://m.media-amazon.com/images/I/71-yd42pEvL._AC_SX466_.jpg  <->  [ok] - 剩余数量：62
# https://m.media-amazon.com/images/I/518g7dCkRmL._AC_SY879_.jpg  <->  [ok] - 剩余数量：61
# https://m.media-amazon.com/images/I/6178oh9UBjS._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：60
# https://m.media-amazon.com/images/I/71AlBzbWieL.__AC_SY445_SX342_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：59
# https://m.media-amazon.com/images/I/41asKsg57zL._SY445_SX342_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：58
# https://m.media-amazon.com/images/I/71XXnMPJk1L._AC_SY355_.jpg  <->  [ok] - 剩余数量：57
# https://m.media-amazon.com/images/I/6122adduCdL._SX425_.jpg  <->  [ok] - 剩余数量：56
# https://m.media-amazon.com/images/I/61SoX+1Eb6L._AC_SY450_.jpg  <->  [ok] - 剩余数量：55
# https://m.media-amazon.com/images/I/716wHldkD4L.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：54
# https://m.media-amazon.com/images/I/619Di3eMM9L._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：53
# https://m.media-amazon.com/images/I/71+b501uFZL._AC_SX450_.jpg  <->  [ok] - 剩余数量：52
# https://m.media-amazon.com/images/I/712x-3fx0dL._AC_SX466_.jpg  <->  [ok] - 剩余数量：51
# https://m.media-amazon.com/images/I/61qUQfsZ18L._SX522_.jpg  <->  [ok] - 剩余数量：50
# https://m.media-amazon.com/images/I/61Bj3Yo9ulL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：49
# https://m.media-amazon.com/images/I/71TYrBF2VGL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：48
# https://m.media-amazon.com/images/I/71v4TjqNX6L._AC_SY355_.jpg  <->  [ok] - 剩余数量：47
# https://m.media-amazon.com/images/I/61PbFQRk0jL._AC_SX466_.jpg  <->  [ok] - 剩余数量：46
# https://m.media-amazon.com/images/I/81-AzaEpD0L._SX342_.jpg  <->  [ok] - 剩余数量：45
# https://m.media-amazon.com/images/I/71MxWvlw4BL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：44
# https://m.media-amazon.com/images/I/61vZOrDewEL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：43
# https://m.media-amazon.com/images/I/51hS0TOP9DL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：42
# https://m.media-amazon.com/images/I/61vyOLCaS0L._SX342_.jpg  <->  [ok] - 剩余数量：41
# https://m.media-amazon.com/images/I/71LjSnlYBTL._AC_SY355_.jpg  <->  [ok] - 剩余数量：40
# https://m.media-amazon.com/images/I/61J4WXAfRuL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：39
# https://m.media-amazon.com/images/I/71PyWnYUO-L._SX522_.jpg  <->  [ok] - 剩余数量：38
# https://m.media-amazon.com/images/I/71QCfmIHgAS._SX342_.jpg  <->  [ok] - 剩余数量：37
# https://m.media-amazon.com/images/I/51KRfjlWRSL._AC_SY355_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：36
# https://m.media-amazon.com/images/I/61w0kWhKHMS._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：35
# https://m.media-amazon.com/images/I/51lEKxxKzKL._AC_SX355_.jpg  <->  [ok] - 剩余数量：34
# https://m.media-amazon.com/images/I/71FHrWFcHEL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：33
# https://m.media-amazon.com/images/I/615i-ArohaL._SX522_.jpg  <->  [ok] - 剩余数量：32
# https://m.media-amazon.com/images/I/61k8XuIGZbL.__AC_SY300_SX300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：31
# https://m.media-amazon.com/images/I/61fl8+aRxZL._AC_SX466_.jpg  <->  [ok] - 剩余数量：30
# https://m.media-amazon.com/images/I/61+Ryw8zvHL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：29
# https://m.media-amazon.com/images/I/61iDIRJMmEL._SX522_.jpg  <->  [ok] - 剩余数量：28
# https://m.media-amazon.com/images/I/5156wel--TL._AC_SY879_.jpg  <->  [ok] - 剩余数量：27
# https://m.media-amazon.com/images/I/71gGirUp89L._AC_SX466_PIbundle-2,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：26
# https://m.media-amazon.com/images/I/71vZ4R-p3mL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：25
# https://m.media-amazon.com/images/I/5172d0NN5ML.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：24
# https://m.media-amazon.com/images/I/719pFOmLcOL._AC_SY355_.jpg  <->  [ok] - 剩余数量：23
# https://m.media-amazon.com/images/I/61Uiq0jnkmL._AC_SX466_PIbundle-3,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：22
# https://m.media-amazon.com/images/I/61jQxOl3NdL._AC_SY355_.jpg  <->  [ok] - 剩余数量：21
# https://m.media-amazon.com/images/I/41m57pxxIeL._AC_SY550_.jpg  <->  [ok] - 剩余数量：20
# https://m.media-amazon.com/images/I/71n87HO5sJL._AC_SX466_.jpg  <->  [ok] - 剩余数量：19
# https://m.media-amazon.com/images/I/71TYrBF2VGL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：18
# https://m.media-amazon.com/images/I/613Vu6pBluL._AC_SX466_.jpg  <->  [ok] - 剩余数量：17
# https://m.media-amazon.com/images/I/61JpxkEOIPL._AC_SX466_.jpg  <->  [ok] - 剩余数量：16
# https://m.media-amazon.com/images/I/81TzcQFa75L._AC_SX466_.jpg  <->  [ok] - 剩余数量：15
# https://m.media-amazon.com/images/I/6101E-BRrLL._SX522_.jpg  <->  [ok] - 剩余数量：14
# https://m.media-amazon.com/images/I/61DfZRbbtMS._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：13
# https://m.media-amazon.com/images/I/516JAe+AIoL._AC_SY300_SX300_.jpg  <->  [ok] - 剩余数量：12
# https://m.media-amazon.com/images/I/61eq6RdwSoL._AC_SY355_.jpg  <->  [ok] - 剩余数量：11
# https://m.media-amazon.com/images/I/51NK1pU2TPL._AC_SY550_.jpg  <->  [ok] - 剩余数量：10
# https://m.media-amazon.com/images/I/814E1wUFluL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：9
# https://m.media-amazon.com/images/I/61lWTk6k5KL._AC_SX466_.jpg  <->  [ok] - 剩余数量：8
# https://m.media-amazon.com/images/I/61pGVUxVdsL._SX342_.jpg  <->  [ok] - 剩余数量：7
# https://m.media-amazon.com/images/I/51ZW36FXIBL._AC_SX466_.jpg  <->  [ok] - 剩余数量：6
# https://m.media-amazon.com/images/I/81k7wy4O3EL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：5
# https://m.media-amazon.com/images/I/61ZjhNJo9SL._AC_SX466_.jpg  <->  [ok] - 剩余数量：4
# https://m.media-amazon.com/images/I/61mIxdsUtMS._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：3
# https://m.media-amazon.com/images/I/61Fhcx2uBeL._AC_SX466_.jpg  <->  [ok] - 剩余数量：2
# https://m.media-amazon.com/images/I/51f+OpTnOtL._SX522_.jpg  <->  [ok] - 剩余数量：1
# https://m.media-amazon.com/images/I/71Zfw-gXG7S._SX522_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/611Hms07qML._AC_SY355_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61HD2VTjOMS._AC_SY355_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71OKn6iTzZL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61S4LQdh4HL._SY445_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/818h-IZ2byL.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71DluJUr0cL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71jEd3zX04L.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61GQtLoPPLL._AC_SX466_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61pUHEA2-9L._SX522_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/71dLXfyIO1L.__AC_SX300_SY300_QL70_FMwebp_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61-ehadyDML._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/613RmLDTIbL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/710Ln-ixD6L._AC_SY355_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/51DMiYuUauL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61V1uhIWKeL._AC_SY355_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/719j529BXpL._AC_SY355_PIbundle-4,TopRight,0,0_SH20_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61yOFgGhOiL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/611aqrHBHpL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
# https://m.media-amazon.com/images/I/61OjYzqzaGL._AC_SX466_.jpg  <->  [ok] - 剩余数量：0
#
# 爬虫输出中
#
# 爬虫结束
