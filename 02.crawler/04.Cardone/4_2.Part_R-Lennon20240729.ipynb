# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./3.url_2.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Part No'] = input_['Part No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        import requests

        import sys
        sys.path.append('../00.Tools')
        from crawler_configuration import get_header, get_proxy

        try:
            b = 0
            while True:

                while True:
                    b += 1
                    try:
                        resp = requests.get(input_.loc[a, 'Url'],
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))
                        break
                    except:
                        continue

                if resp.status_code == 200:
                    break

            # = = = = = = = = = = = = = = =

            from bs4 import BeautifulSoup
            from lxml import etree

            soup = BeautifulSoup(resp.text, 'lxml')
            html = etree.HTML(str(soup))

            # = = = = = = = = = = = = = = =

            title = html.xpath('//head/title/text()')[0].strip()

            # = = = = = = = = = = = = = = =

            subtitle = html.xpath('//h2[@itemprop="brand"]/a/span[@itemprop="name"]/text()')[0].strip()

            # = = = = = = = = = = = = = = =

            part_number = html.xpath('//dd[@itemprop="sku"]/text()')[0].strip()

            # = = = = = = = = = = = = = = =

            part_type = html.xpath('//dd[@data-product-parttype]/text()')[0].strip()

            # = = = = = = = = = = = = = = =

            dict_application_summary = {}
            list_application_summary = html.xpath('//meta[@name="description"]/@content')[0].strip().removeprefix(f'{subtitle},').removeprefix(f'{part_type},').split(';') if html.xpath('//meta[@name="description"]/@content') else ''
            for i, application_summary in zip(range(len(list_application_summary)), list_application_summary):
                dict_application_summary[str(i)] = application_summary.strip()

            # = = = = = = = = = = = = = = =

            dict_src = {}
            list_src = html.xpath('//li[contains(@class, "productView-thumbnail")]/a[@class="productView-thumbnail-link"]/@href')
            for i, src in zip(range(len(list_src)), list_src):
                dict_src[str(i)] = src.strip()

            # = = = = = = = = = = = = = = =

            import json

            dict_info = {}
            list_dict = json.loads(html.xpath('//div[@id="addon"]/@data-custom-fields')[0])
            for i, dict_ in zip(range(len(list_dict)), list_dict):
                dict_info[str(i)] = {dict_['name'].strip(): dict_['value'].strip()}

            # = = = = = = = = = = = = = = =

            bundle = resp.text.split('window.__webpack_public_path__ = "')[1].split('";</script>')[0]

            # = = = = = = = = = = = = = = =

            df_temp = pd.DataFrame([{'Part No': input_.loc[a, 'Part No'],
                                     'Title': title,
                                     'Subtitle': subtitle,
                                     'Part Number': part_number,
                                     'Part Type': part_type,
                                     'Json_Application_Summary': json.dumps(dict_application_summary),
                                     'Bundle': bundle,
                                     'Json_Info': json.dumps(dict_info),
                                     'Url': input_.loc[a, 'Url'],
                                     'Json_Src': json.dumps(dict_src)}])

            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            df_temp = pd.DataFrame([{'Part No': input_.loc[a, 'Part No'],
                                     'Url': input_.loc[a, 'Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b}] - {input_.loc[a, 'Part No']}.{input_.loc[a, 'Url']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(12):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Part No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./4.part-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['Part No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./part_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：107
#
# [状态：ok，尝试次数：1] - 86.https://www.cardone.com/product/abs-control-module-12-10304
# [剩余数量：95] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 4851.https://www.cardone.com/product/brake-caliper-18-p5610
# [剩余数量：94] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 24.https://www.cardone.com/product/abs-control-module-12-10219
# [剩余数量：93] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 165.https://www.cardone.com/product/abs-control-module-12-17412
# [剩余数量：92] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 94.https://www.cardone.com/product/abs-control-module-12-10317
# [剩余数量：91] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 115.https://www.cardone.com/product/abs-control-module-12-10362
# [剩余数量：90] - [当前时间：09:34:52]
#
# [状态：ok，尝试次数：1] - 435.https://www.cardone.com/product/power-brake-booster-53-7641
# [剩余数量：89] - [当前时间：09:34:53]
#
# [状态：ok，尝试次数：1] - 4239.https://www.cardone.com/product/brake-caliper-18-b5649
# [剩余数量：88] - [当前时间：09:34:53]
#
# [状态：ok，尝试次数：1] - 70.https://www.cardone.com/product/abs-control-module-12-10280
# [剩余数量：87] - [当前时间：09:34:53]
#
# [状态：ok，尝试次数：1] - 4221.https://www.cardone.com/product/brake-caliper-18-b5619
# [剩余数量：86] - [当前时间：09:34:53]
#
# [状态：ok，尝试次数：1] - 4238.https://www.cardone.com/product/brake-caliper-18-b5648
# [剩余数量：85] - [当前时间：09:34:54]
#
# [状态：ok，尝试次数：1] - 4855.https://www.cardone.com/product/brake-caliper-18-p5618
# [剩余数量：84] - [当前时间：09:34:54]
#
# [状态：ok，尝试次数：1] - 4856.https://www.cardone.com/product/brake-caliper-18-p5619
# [剩余数量：83] - [当前时间：09:34:54]
#
# [状态：ok，尝试次数：1] - 9613.https://www.cardone.com/product/brake-caliper-19-b7505
# [剩余数量：82] - [当前时间：09:34:54]
#
# [状态：ok，尝试次数：1] - 9612.https://www.cardone.com/product/brake-caliper-19-b7504
# [剩余数量：81] - [当前时间：09:34:54]
#
# [状态：ok，尝试次数：1] - 4852.https://www.cardone.com/product/brake-caliper-18-p5611
# [剩余数量：80] - [当前时间：09:34:55]
#
# [状态：ok，尝试次数：1] - 9630.https://www.cardone.com/product/brake-caliper-19-b7538
# [剩余数量：79] - [当前时间：09:34:55]
#
# [状态：ok，尝试次数：1] - 4870.https://www.cardone.com/product/brake-caliper-18-p5649
# [剩余数量：78] - [当前时间：09:34:55]
#
# [状态：ok，尝试次数：1] - 9648.https://www.cardone.com/product/brake-caliper-19-b7573
# [剩余数量：77] - [当前时间：09:34:56]
#
# [状态：ok，尝试次数：1] - 26515.https://www.cardone.com/product/engine-control-module-79-2487v
# [剩余数量：53] - [当前时间：09:35:02]
#
# [状态：ok，尝试次数：1] - 25857.https://www.cardone.com/product/engine-control-module-78-9230f
# [剩余数量：52] - [当前时间：09:35:02]
#
# [状态：ok，尝试次数：1] - 26741.https://www.cardone.com/product/integrated-control-module-73-1500v
# [剩余数量：51] - [当前时间：09:35:03]
#
# [状态：ok，尝试次数：1] - 15907.https://www.cardone.com/product/driveshaft-prop-shaft-65-9002
# [剩余数量：50] - [当前时间：09:35:03]
#
# [状态：ok，尝试次数：1] - 26746.https://www.cardone.com/product/integrated-control-module-73-1504v
# [剩余数量：49] - [当前时间：09:35:03]
#
# [状态：ok，尝试次数：1] - 26485.https://www.cardone.com/product/engine-control-module-79-2246v
# [剩余数量：48] - [当前时间：09:35:03]
#
# [状态：ok，尝试次数：1] - 26762.https://www.cardone.com/product/integrated-control-module-73-1525v
# [剩余数量：47] - [当前时间：09:35:03]
#
# [状态：ok，尝试次数：1] - 26749.https://www.cardone.com/product/integrated-control-module-73-1506v
# [剩余数量：46] - [当前时间：09:35:04]
#
# [状态：ok，尝试次数：1] - 26768.https://www.cardone.com/product/integrated-control-module-73-1533v
# [剩余数量：45] - [当前时间：09:35:04]
#
# [状态：ok，尝试次数：1] - 26772.https://www.cardone.com/product/integrated-control-module-73-1538v
# [剩余数量：44] - [当前时间：09:35:04]
#
# [状态：ok，尝试次数：1] - 26759.https://www.cardone.com/product/integrated-control-module-73-1523v
# [剩余数量：43] - [当前时间：09:35:04]
#
# [状态：ok，尝试次数：1] - 26784.https://www.cardone.com/product/integrated-control-module-73-1591v
# [剩余数量：42] - [当前时间：09:35:04]
#
# [状态：ok，尝试次数：1] - 26781.https://www.cardone.com/product/integrated-control-module-73-1552v
# [剩余数量：41] - [当前时间：09:35:05]
#
# [状态：ok，尝试次数：1] - 26783.https://www.cardone.com/product/integrated-control-module-73-1589v
# [剩余数量：40] - [当前时间：09:35:05]
#
# [状态：ok，尝试次数：1] - 26799.https://www.cardone.com/product/lighting-control-module-73-71019
# [剩余数量：39] - [当前时间：09:35:06]
#
# [状态：ok，尝试次数：1] - 27017.https://www.cardone.com/product/climate-control-module-4c-3005
# [剩余数量：38] - [当前时间：09:35:06]
#
# [状态：ok，尝试次数：1] - 26796.https://www.cardone.com/product/lighting-control-module-73-71014
# [剩余数量：37] - [当前时间：09:35:07]
#
# [状态：ok，尝试次数：1] - 27009.https://www.cardone.com/product/climate-control-module-4c-1015
# [剩余数量：36] - [当前时间：09:35:07]
#
# [状态：ok，尝试次数：1] - 27018.https://www.cardone.com/product/climate-control-module-4c-3007
# [剩余数量：35] - [当前时间：09:35:07]
#
# [状态：ok，尝试次数：1] - 27013.https://www.cardone.com/product/climate-control-module-4c-1033
# [剩余数量：34] - [当前时间：09:35:07]
#
# [状态：ok，尝试次数：1] - 27119.https://www.cardone.com/product/instrument-cluster-2l-2110
# [剩余数量：33] - [当前时间：09:35:08]
#
# [状态：ok，尝试次数：1] - 28619.https://www.cardone.com/product/fuel-injection-throttle-body-67-3058
# [剩余数量：32] - [当前时间：09:35:08]
#
# [状态：ok，尝试次数：1] - 27019.https://www.cardone.com/product/climate-control-module-4c-3008
# [剩余数量：31] - [当前时间：09:35:08]
#
# [状态：ok，尝试次数：1] - 27010.https://www.cardone.com/product/climate-control-module-4c-1024
# [剩余数量：30] - [当前时间：09:35:08]
#
# [状态：ok，尝试次数：1] - 28617.https://www.cardone.com/product/fuel-injection-throttle-body-67-3054
# [剩余数量：29] - [当前时间：09:35:09]
#
# [状态：ok，尝试次数：1] - 27012.https://www.cardone.com/product/climate-control-module-4c-1032
# [剩余数量：28] - [当前时间：09:35:09]
#
# [状态：ok，尝试次数：1] - 28719.https://www.cardone.com/product/fuel-injection-throttle-body-67-7009
# [剩余数量：27] - [当前时间：09:35:09]
#
# [状态：ok，尝试次数：1] - 28691.https://www.cardone.com/product/fuel-injection-throttle-body-67-6017
# [剩余数量：26] - [当前时间：09:35:09]
#
# [状态：ok，尝试次数：1] - 28654.https://www.cardone.com/product/fuel-injection-throttle-body-67-4213
# [剩余数量：25] - [当前时间：09:35:10]
#
# [状态：ok，尝试次数：1] - 28806.https://www.cardone.com/product/fuel-injection-throttle-body-6e-2012
# [剩余数量：24] - [当前时间：09:35:10]
#
# [状态：ok，尝试次数：1] - 28867.https://www.cardone.com/product/fuel-injection-throttle-body-6e-6005
# [剩余数量：23] - [当前时间：09:35:10]
#
# [状态：ok，尝试次数：2] - 4220.https://www.cardone.com/product/brake-caliper-18-b5618
# [剩余数量：22] - [当前时间：09:35:11]
#
# [状态：ok，尝试次数：1] - 28838.https://www.cardone.com/product/fuel-injection-throttle-body-6e-3042
# [剩余数量：21] - [当前时间：09:35:11]
#
# [状态：ok，尝试次数：1] - 28829.https://www.cardone.com/product/fuel-injection-throttle-body-6e-3026
# [剩余数量：20] - [当前时间：09:35:11]
#
# [状态：ok，尝试次数：1] - 28840.https://www.cardone.com/product/fuel-injection-throttle-body-6e-3046
# [剩余数量：19] - [当前时间：09:35:12]
#
# [状态：ok，尝试次数：1] - 28881.https://www.cardone.com/product/fuel-injection-throttle-body-6e-6032
# [剩余数量：18] - [当前时间：09:35:12]
#
# [状态：ok，尝试次数：1] - 28882.https://www.cardone.com/product/fuel-injection-throttle-body-6e-6040
# [剩余数量：17] - [当前时间：09:35:12]
#
# [状态：ok，尝试次数：1] - 29662.https://www.cardone.com/product/electronic-power-steering-assist-column-eps-1c-4006
# [剩余数量：16] - [当前时间：09:35:13]
#
# [状态：ok，尝试次数：1] - 28653.https://www.cardone.com/product/fuel-injection-throttle-body-67-4212
# [剩余数量：15] - [当前时间：09:35:13]
#
# [状态：ok，尝试次数：1] - 31129.https://www.cardone.com/product/power-steering-pump-96-486
# [剩余数量：14] - [当前时间：09:35:13]
#
# [状态：ok，尝试次数：1] - 29658.https://www.cardone.com/product/electronic-power-steering-assist-column-eps-1c-18018
# [剩余数量：13] - [当前时间：09:35:14]
#
# [状态：ok，尝试次数：1] - 29655.https://www.cardone.com/product/electronic-power-steering-assist-column-eps-1c-1008
# [剩余数量：12] - [当前时间：09:35:14]
#
# [状态：ok，尝试次数：1] - 28893.https://www.cardone.com/product/fuel-injection-throttle-body-6e-7016
# [剩余数量：11] - [当前时间：09:35:14]
#
# [状态：ok，尝试次数：1] - 31685.https://www.cardone.com/product/rack-and-pinion-assembly-1a-2025
# [剩余数量：10] - [当前时间：09:35:14]
