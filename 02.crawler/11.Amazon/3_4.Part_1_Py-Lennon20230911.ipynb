# %%
import os

# %%
list_file = list(os.walk('./crawler_2'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 82

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    with open('./crawler_2/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_2.xlsx', index=False)

df
# Out:
# 进度: 100%|████████████████████████████████| 82/82 [00:00<00:00, 1490.45it/s]
#           ASIN       标识       PASIN                         品牌  \
# 0   B07H853N6R  A+;V;AC  B07H853N6R          Automotive-leader
# 0   B006GPVU0C    A+;AC  B006GPVU0C               HornBlasters
# 0   B0722HJNDT           B0722HJNDT  Universal Air Conditioner
# 0   B09M36ZH6H     A+;V  B09M36ZH6H                     QSERON
# 0   B082XRWLPB     A+;V  B082XRWLPB                   ACTECMAX
# ..         ...      ...         ...                        ...
# 0   B073WP1QC1  A+;V;BS  B073WP1QC1                AA Ignition
# 0   B09MTFRGC4           B09MTFRGC4                    NewYall
# 0   B07T9DTS4G       AC  B07T9DTS4G                    NewYall
# 0   B087M6N45M           B087M6N45M                   AUTOMUTO
# 0   B0080DWR5A    BS;AC  B0080DWR5A                 Motorcraft
#
#                                                  品牌链接    大类BSR    BSR增长数  \
# 0   https://www.amazon.com/stores/Automotive-leade...  244,699   498,169
# 0   https://www.amazon.com/stores/HornBlasters/pag...  226,922  -119,714
# 0   https://www.amazon.com/UAC/b/ref=bl_dp_s_web_8...  319,079  -123,425
# 0   https://www.amazon.com/stores/QSERON/page/9D40...  418,398   769,869
# 0   https://www.amazon.com/ACTECMAX/b/ref=bl_dp_s_...  508,845  -284,326
# ..                                                ...      ...       ...
# 0   https://www.amazon.com/stores/AAIgnition/page/...   76,250   -39,079
# 0   https://www.amazon.com/stores/NewYall/page/D38...  207,552   -47,021
# 0   https://www.amazon.com/stores/NewYall/page/D38...  148,052    99,906
# 0   https://www.amazon.com/stores/AUTOMUTO/page/CF...  513,334   591,550
# 0   https://www.amazon.com/Motorcraft/b/ref=bl_dp_...   52,592    55,036
#
#    BSR增长率 父体月销量 父体月销量增长率  ...          重量_1      重量_2  \
# 0    385%    17     -30%  ...  0.29 pounds   131.54 g
# 0    -34%    22     -50%  ...     1 pounds   453.59 g
# 0    -39%    17     -51%  ...  0.52 pounds   235.87 g
# 0    184%   < 5     -67%  ...  0.45 pounds   204.12 g
# 0    -56%    29     183%  ...   4.2 ounces   119.07 g
# ..    ...   ...      ...  ...           ...       ...
# 0   -105%   138     -43%  ...  0.15 pounds    68.04 g
# 0    -18%    33       6%  ...   5.9 ounces   167.26 g
# 0    112%    72     -12%  ...   5.6 ounces   158.76 g
# 0    115%   < 5        -  ...   5.3 ounces   150.25 g
# 0    175%   145     -16%  ...   4.6 ounces   130.41 g
#
#                           体积_1                      体积_2   LQS 变体数 SKU  卖家数  \
# 0   7.17 x 3.23 x 2.09 inches     18.21 x 8.20 x 5.31 cm   9.9   无       2家
# 0      5 x 2.75 x 2.75 inches     12.70 x 6.99 x 6.99 cm   7.3   无       2家
# 0            8 x 8 x 8 inches   20.32 x 20.32 x 20.32 cm   6.5   无      10家
# 0     5.3 x 1.57 x 1.2 inches     13.46 x 3.99 x 3.05 cm   8.0   无       1家
# 0   4.76 x 3.15 x 1.26 inches     12.09 x 8.00 x 3.20 cm  10.0   无       1家
# ..                         ...                       ...   ...  ..  ..  ...
# 0            7 x 3 x 3 inches     17.78 x 7.62 x 7.62 cm   9.4   无       2家
# 0   4.69 x 2.91 x 1.65 inches     11.91 x 7.39 x 4.19 cm   5.6   无       1家
# 0      5.02 x 4 x 1.85 inches    12.75 x 10.16 x 4.70 cm   5.3   无       1家
# 0      5.6 x 3.2 x 1.3 inches     14.22 x 8.13 x 3.30 cm   7.7   无       1家
# 0   3.63 x 2.95 x 2.28 inches      9.22 x 7.49 x 5.79 cm   6.0   无       6家
#
#                        BuyBox卖家  \
# 0       Merry Popper (FBA ,  )
# 0       Hornblasters (FBM ,  )
# 0                  Amazon (AMZ)
# 0             HYCONG (FBA ,  )
# 0
# ..                          ...
# 0       PRODUCTS 360 (FBA ,  )
# 0       NewYallDirect (NA ,  )
# 0       NewYallDirect (NA ,  )
# 0           Automuto (FBM ,  )
# 0   AUTO-PRO AMERICA (FBM ,  )
#
#                                            BuyBox卖家链接
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0
# ..                                                ...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
# 0   https://www.amazon.com/gp/help/seller/at-a-gla...
#
# [82 rows x 38 columns]
