# %% [markdown]
# - Update: 2023.04.12
#
# # 0. 配置参数
#
# - `file`：要下载图片的文件的路径

# %%
file = './NGK Laser Iridium Spark Plugs-Summit-20230412.xlsx'

# = = = = = = = = = = = = = = = = = =

from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

from openpyxl import load_workbook
import requests
from io import BytesIO
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter

# = = = = = = = = = = = = = = = = = =

wb = load_workbook(file)
ws = wb.active

for i in range(1, ws.max_column+1):
    if ws.cell(1, i).value == '图片链接':
        index_url = i
    elif ws.cell(1, i).value == '图片':
        index_img = i

# = = = = = = = = = = = = = = = = = =

work = Queue()
for i in range(2, ws.max_row+1):
    work.put_nowait(i)

# = = = = = = = = = = = = = = = = = =

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        url = ws.cell(row, index_url).value
        
        for i in range(5):
            try:
                img = Image(BytesIO(requests.get(url).content))
                
                # = = = = = = = = = = = = = = = = = =
                
                if img.width >= img.height:
                    img.height = 18.0 / img.width * img.height
                    img.width = 18.0
                else:
                    img.width = 18.0 / img.height * img.width
                    img.height = 18.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                ws.add_image(img, get_column_letter(index_img) + str(row))
            
                break
            
            except:
            
                continue
                
        # = = = = = = = = = = = = = = = = = =
                
        print(url, ' [' + str(i) + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(5):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

wb.save(file.replace('.xlsx', '-pic.xlsx'))
print()
print('搞定')
# Out:
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1961_xl.jpg  [0] - 剩余数量：168
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4282_xl.jpg  [0] - 剩余数量：167
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：166
# https://static.summitracing.com/global/images/prod/xlarge/ngk-2318_xl.jpg  [0] - 剩余数量：165
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：164
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：163
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1553_xl.jpg  [0] - 剩余数量：162
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1555_qq_xl.jpg  [0] - 剩余数量：161
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1989_xl.jpg  [0] - 剩余数量：160
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93298_xl.jpg  [0] - 剩余数量：159
# https://static.summitracing.com/global/images/prod/xlarge/ngk-7692_xl.jpg  [0] - 剩余数量：158
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93227_uv_xl.jpg  [0] - 剩余数量：157
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93618_xl.jpg  [0] - 剩余数量：156
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93655_gv_xl.jpg  [0] - 剩余数量：155
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90644_fh_xl.jpg  [0] - 剩余数量：154
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93675_ga_xl.jpg  [0] - 剩余数量：153
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96956_xl.jpg  [0] - 剩余数量：152
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90607_lr_xl.jpg  [0] - 剩余数量：151
# https://static.summitracing.com/global/images/prod/large/noimage_125.jpg  [0] - 剩余数量：150
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96957_kw_xl.jpg  [0] - 剩余数量：149
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96870_xl.jpg  [0] - 剩余数量：148
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90813_vr_xl.jpg  [0] - 剩余数量：147
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90656_dm_xl.jpg  [0] - 剩余数量：146
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93560_vr_xl.jpg  [0] - 剩余数量：145
# https://static.summitracing.com/global/images/prod/large/ngk-127.jpg  [0] - 剩余数量：144
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94489_mm_xl.jpg  [0] - 剩余数量：143
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90543_rj_xl.jpg  [0] - 剩余数量：142
# https://static.summitracing.com/global/images/prod/large/ngk-90074.jpg  [0] - 剩余数量：141
# https://static.summitracing.com/global/images/prod/large/ngk-90083.jpg  [0] - 剩余数量：140
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6774_xl.jpg  [0] - 剩余数量：139
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6777_xl.jpg  [0] - 剩余数量：138
# https://static.summitracing.com/global/images/prod/large/ngk-5068_w.jpg  [0] - 剩余数量：137
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：136
# https://static.summitracing.com/global/images/prod/large/ngk-90074.jpg  [0] - 剩余数量：135
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91970_je_xl.jpg  [0] - 剩余数量：134
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90219_xl.jpg  [0] - 剩余数量：133
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92154_cq_xl.jpg  [0] - 剩余数量：132
# https://static.summitracing.com/global/images/prod/large/ngk-6706.jpg  [0] - 剩余数量：131
# https://static.summitracing.com/global/images/prod/xlarge/ngk-7658_jy_xl.jpg  [0] - 剩余数量：130
# https://static.summitracing.com/global/images/prod/large/ngk-90074.jpg  [0] - 剩余数量：129
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91568_xl.jpg  [0] - 剩余数量：128
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1208_xl.jpg  [0] - 剩余数量：127
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6858_xl.jpg  [0] - 剩余数量：126
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90526_xl.jpg  [0] - 剩余数量：125
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92085_wg_xl.jpg  [0] - 剩余数量：124
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93759_xl.jpg  [0] - 剩余数量：123
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4213_xl.jpg  [0] - 剩余数量：122
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4888_xg_xl.jpg  [0] - 剩余数量：121
# https://static.summitracing.com/global/images/prod/large/noimage_125.jpg  [0] - 剩余数量：120
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91112_wg_xl.jpg  [0] - 剩余数量：119
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91215_bd_xl.jpg  [0] - 剩余数量：118
# https://static.summitracing.com/global/images/prod/large/ngk-127.jpg  [0] - 剩余数量：117
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3678_xl.jpg  [0] - 剩余数量：116
# https://static.summitracing.com/global/images/prod/large/noimage_125.jpg  [0] - 剩余数量：115
# https://static.summitracing.com/global/images/prod/large/ngk-7994_w.jpg  [0] - 剩余数量：114
# https://static.summitracing.com/global/images/prod/large/ngk-3588_w.jpg  [0] - 剩余数量：113
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3656_xl.jpg  [0] - 剩余数量：112
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90156_lw_xl.jpg  [0] - 剩余数量：111
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：110
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6043_xl.jpg  [0] - 剩余数量：109
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91360_xl.jpg  [0] - 剩余数量：108
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5766_xl.jpg  [0] - 剩余数量：107
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5344_xl.jpg  [0] - 剩余数量：106
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6176_xl.jpg  [0] - 剩余数量：105
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3107_xl.jpg  [0] - 剩余数量：104
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4294_xl.jpg  [0] - 剩余数量：103
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3106_xl.jpg  [0] - 剩余数量：102
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4867_xl.jpg  [0] - 剩余数量：101
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5368_xl.jpg  [0] - 剩余数量：100
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4709_xl.jpg  [0] - 剩余数量：99
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4757_xl.jpg  [0] - 剩余数量：98
# https://static.summitracing.com/global/images/prod/large/ngk-4095_w.jpg  [0] - 剩余数量：97
# https://static.summitracing.com/global/images/prod/large/ngk-4288.jpg  [0] - 剩余数量：96
# https://static.summitracing.com/global/images/prod/large/ngk-4288.jpg  [0] - 剩余数量：95
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4286_xl.jpg  [0] - 剩余数量：94
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：93
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91448_jy_xl.jpg  [0] - 剩余数量：92
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92288_zg_xl.jpg  [0] - 剩余数量：91
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91874_bp_xl.jpg  [0] - 剩余数量：90
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96024_xl.jpg  [0] - 剩余数量：89
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6706_wb_xl.jpg  [0] - 剩余数量：88
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5648_xl.jpg  [0] - 剩余数量：87
# https://static.summitracing.com/global/images/prod/large/ngk-6502_w.jpg  [0] - 剩余数量：86
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6588_xl.jpg  [0] - 剩余数量：85
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1654_xl.jpg  [0] - 剩余数量：84
# https://static.summitracing.com/global/images/prod/xlarge/ngk-7866_xl.jpg  [0] - 剩余数量：83
# https://static.summitracing.com/global/images/prod/large/ngk-5245_w.jpg  [0] - 剩余数量：82
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3653_xl.jpg  [0] - 剩余数量：81
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94051_gb_xl.jpg  [0] - 剩余数量：80
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94702_qi_xl.jpg  [0] - 剩余数量：79
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93593_dm_xl.jpg  [0] - 剩余数量：78
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90137_xl.jpg  [0] - 剩余数量：77
# https://static.summitracing.com/global/images/prod/xlarge/ngk-97312_xl.jpg  [0] - 剩余数量：76
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5114_xl.jpg  [0] - 剩余数量：75
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6966_xl.jpg  [0] - 剩余数量：74
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92743_xl.jpg  [0] - 剩余数量：73
# https://static.summitracing.com/global/images/prod/xlarge/ngk-97287_jo_xl.jpg  [0] - 剩余数量：72
# https://static.summitracing.com/global/images/prod/large/noimage_125.jpg  [0] - 剩余数量：71
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6501_wb_xl.jpg  [0] - 剩余数量：70
# https://static.summitracing.com/global/images/prod/large/noimage_125.jpg  [0] - 剩余数量：69
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6289_xl.jpg  [0] - 剩余数量：68
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96372_xl.jpg  [0] - 剩余数量：67
# https://static.summitracing.com/global/images/prod/xlarge/ngk-3787_vi_xl.jpg  [0] - 剩余数量：66
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92924_px_xl.jpg  [0] - 剩余数量：65
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93135_sk_xl.jpg  [0] - 剩余数量：64
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93026_xl.jpg  [0] - 剩余数量：63
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94167_mx_xl.jpg  [0] - 剩余数量：62
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93819_xl.jpg  [0] - 剩余数量：61
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94021_lp_xl.jpg  [0] - 剩余数量：60
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94124_uk_xl.jpg  [0] - 剩余数量：59
# https://static.summitracing.com/global/images/prod/large/ngk-6481_w.jpg  [0] - 剩余数量：58
# https://static.summitracing.com/global/images/prod/xlarge/ngk-97218_xl.jpg  [0] - 剩余数量：57
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93815_oy_xl.jpg  [0] - 剩余数量：56
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90909_rk_xl.jpg  [0] - 剩余数量：55
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90882_yb_xl.jpg  [0] - 剩余数量：54
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90911_np_xl.jpg  [0] - 剩余数量：53
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90935_jl_xl.jpg  [0] - 剩余数量：52
# https://static.summitracing.com/global/images/prod/large/ngk-90074.jpg  [0] - 剩余数量：51
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90992_bf_xl.jpg  [0] - 剩余数量：50
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90982_xl.jpg  [0] - 剩余数量：49
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96416_uh_xl.jpg  [0] - 剩余数量：48
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4212_xl.jpg  [0] - 剩余数量：47
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6994_xl.jpg  [0] - 剩余数量：46
# https://static.summitracing.com/global/images/prod/large/ngk-6741_w.jpg  [0] - 剩余数量：45
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5599_xl.jpg  [0] - 剩余数量：44
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6205_xl.jpg  [0] - 剩余数量：43
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：42
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91039_kz_xl.jpg  [0] - 剩余数量：41
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5477_xl.jpg  [0] - 剩余数量：40
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91418_xl.jpg  [0] - 剩余数量：39
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91924_vo_xl.jpg  [0] - 剩余数量：38
# https://static.summitracing.com/global/images/prod/large/ngk-5581_w.jpg  [0] - 剩余数量：37
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93026_sn_xl.jpg  [0] - 剩余数量：36
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：35
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96964_gl_xl.jpg  [0] - 剩余数量：34
# https://static.summitracing.com/global/images/prod/large/ngk-3657_w.jpg  [0] - 剩余数量：33
# https://static.summitracing.com/global/images/prod/large/ngk-4996_w.jpg  [0] - 剩余数量：32
# https://static.summitracing.com/global/images/prod/xlarge/ngk-97968_ts_xl.jpg  [0] - 剩余数量：31
# https://static.summitracing.com/global/images/prod/large/ngk-5238_w.jpg  [0] - 剩余数量：30
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：29
# https://static.summitracing.com/global/images/prod/large/ngk-7755_w.jpg  [0] - 剩余数量：28
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1402_cd_xl.jpg  [0] - 剩余数量：27
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6507_xl.jpg  [0] - 剩余数量：26
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96779_xl.jpg  [0] - 剩余数量：25
# https://static.summitracing.com/global/images/prod/large/ngk-127.jpg  [0] - 剩余数量：24
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92315_sf_xl.jpg  [0] - 剩余数量：23
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94940_go_xl.jpg  [0] - 剩余数量：22
# https://static.summitracing.com/global/images/prod/large/ngk-7854_w.jpg  [0] - 剩余数量：21
# https://static.summitracing.com/global/images/prod/xlarge/ngk-6544_xl.jpg  [0] - 剩余数量：20
# https://static.summitracing.com/global/images/prod/xlarge/ngk-95609_ph_xl.jpg  [0] - 剩余数量：19
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5115_xl.jpg  [0] - 剩余数量：18
# https://static.summitracing.com/global/images/prod/xlarge/ngk-94201_lo_xl.jpg  [0] - 剩余数量：17
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93026_sn_xl.jpg  [0] - 剩余数量：16
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93026_sn_xl.jpg  [0] - 剩余数量：15
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93482_xl.jpg  [0] - 剩余数量：14
# https://static.summitracing.com/global/images/prod/xlarge/ngk-5787_xl.jpg  [0] - 剩余数量：13
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91909_rg_xl.jpg  [0] - 剩余数量：12
# https://static.summitracing.com/global/images/prod/large/ngk-96107.jpg  [0] - 剩余数量：11
# https://static.summitracing.com/global/images/prod/xlarge/ngk-7751_xl.jpg  [0] - 剩余数量：10
# https://static.summitracing.com/global/images/prod/xlarge/ngk-95710_xl.jpg  [0] - 剩余数量：9
# https://static.summitracing.com/global/images/prod/xlarge/ngk-1465_xl.jpg  [0] - 剩余数量：8
# https://static.summitracing.com/global/images/prod/xlarge/ngk-92145_pn_xl.jpg  [0] - 剩余数量：7
# https://static.summitracing.com/global/images/prod/xlarge/ngk-95264_ir_xl.jpg  [0] - 剩余数量：6
# https://static.summitracing.com/global/images/prod/xlarge/ngk-9723_uk_xl.jpg  [0] - 剩余数量：5
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93026_sn_xl.jpg  [0] - 剩余数量：4
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4477_nf_xl.jpg  [0] - 剩余数量：3
# https://static.summitracing.com/global/images/prod/large/ngk-4589_w.jpg  [0] - 剩余数量：2
# https://static.summitracing.com/global/images/prod/xlarge/ngk-96412_ij_xl.jpg  [0] - 剩余数量：1
# https://static.summitracing.com/global/images/prod/xlarge/ngk-90856_es_xl.jpg  [0] - 剩余数量：0
# https://static.summitracing.com/global/images/prod/xlarge/ngk-93623_in_xl.jpg  [0] - 剩余数量：0
# https://static.summitracing.com/global/images/prod/xlarge/ngk-4214_xl.jpg  [0] - 剩余数量：0
# https://static.summitracing.com/global/images/prod/large/ngk-5899_w.jpg  [0] - 剩余数量：0
# https://static.summitracing.com/global/images/prod/xlarge/ngk-91234_cy_xl.jpg  [0] - 剩余数量：0
#
# 搞定
# D:\Lennon\python\venv\lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
