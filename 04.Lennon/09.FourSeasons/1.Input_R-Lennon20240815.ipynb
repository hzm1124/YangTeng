# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.get('https://ecatalog.smpcorp.com/V2/fs/api/part/partsearchfilter?filter=-All-&filterType=n&searchType=p&catFilter=-All-&yearFilter=-All-&makeFilter=-All-&modelFilter=-All-&engineFilter=-All-&attrCodeFilter=-All-&attrValueFilter=-All-&plkEngineMakeFilter=-All-&plkEngineModelFilter=-All-&plkEngineDispFilter=-All-',
                             headers=get_header(),
                             proxies=get_proxy(),
                             timeout=(10, 10))
        
        if resp.status_code == 200:
            break
    except KeyboardInterrupt:
        break
    except:
        continue

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'productCategoryShort': [{'webColumn_Id': 18300,
#    'categoryName_en': 'A/C Kit',
#    'prodCategory_ASort': 10100},
#   {'webColumn_Id': 10120,
#    'categoryName_en': 'A/C Fittings',
#    'prodCategory_ASort': 10120},
#   {'webColumn_Id': 21600,
#    'categoryName_en': 'A/C Service Kit',
#    'prodCategory_ASort': 10400},
#   {'webColumn_Id': 1000,
#    'categoryName_en': 'A/C System Seal Kits',
#    'prodCategory_ASort': 10500},
#   {'webColumn_Id': 3300,
#    'categoryName_en': 'Accumulators',
#    'prodCategory_ASort': 10600},
#   {'webColumn_Id': 10650,
#    'categoryName_en': 'Bearings',
#    'prodCategory_ASort': 10650},
#   {'webColumn_Id': 1400,
#    'categoryName_en': 'Blower Motor Resistor',
#    'prodCategory_ASort': 10700},
#   {'webColumn_Id': 1501,
#    'categoryName_en': 'Blower Motor Wheels',
#    'prodCategory_ASort': 10800},
#   {'webColumn_Id': 1500,
#    'categoryName_en': 'Blower Motors',
#    'prodCategory_ASort': 10900},
#   {'webColumn_Id': 10950,
# ...

# %%
list_type_code = [_['webColumn_Id']for _ in json_['productCategoryShort']]

list_type_code
# Out:
# [18300,
#  10120,
#  21600,
#  1000,
#  3300,
#  10650,
#  1400,
#  1501,
#  1500,
#  10950,
#  1600,
#  11050,
#  1903,
#  1904,
#  11350,
#  1700,
#  1900,
#  2000,
#  11850,
#  32400,
#  5401,
#  5400,
#  15500,
#  15501,
#  11800,
#  2800,
#  2901,
#  3101,
#  3100,
#  3200,
#  3301,
#  20450,
#  3800,
#  22900,
#  3900,
#  4000,
#  4100,
#  4400,
#  2900,
#  22250,
#  15900,
#  13200,
#  28750,
#  30250,
#  14100]

# %%
list_type = [_['categoryName_en'].strip() for _ in json_['productCategoryShort']]

list_type
# Out:
# ['A/C Kit',
#  'A/C Fittings',
#  'A/C Service Kit',
#  'A/C System Seal Kits',
#  'Accumulators',
#  'Bearings',
#  'Blower Motor Resistor',
#  'Blower Motor Wheels',
#  'Blower Motors',
#  'Bulk Hoses',
#  'Cabin Air Filters',
#  'Chemicals',
#  'Clutch Assemblies - New',
#  'Clutch Assemblies - Reman',
#  'Clutch Components',
#  'Compressor Lubricant',
#  'Compressors - New',
#  'Condensers',
#  'Compressor Components',
#  'Connector - HVAC Relay',
#  'Cooling Fan Assemblies',
#  'Cooling Fan Motors',
#  'Electric Engine Cooling Fan',
#  'Electric Engine Cooling Fan Controller',
#  'Engine Coolant Components',
#  'Evaporator Cores',
#  'Expansion Valves',
#  'Fan Blades',
#  'Fan Clutches',
#  'Filter - Refrigerant',
#  'Filter Driers',
#  'Gaskets',
#  'Heater Cores',
#  'Heater Fitting',
#  'Heater Valves',
#  'Hose Assemblies',
#  'HVAC Door Actuator',
#  'Idler / Tensioners',
#  'Orifice Tubes',
#  'O-Rings',
#  'Power Steering Cooler',
#  'Relays - HVAC',
# ...

# %%
len(list_type) == 0
# Out:
# False

# %%
import pandas as pd

output = pd.DataFrame({'No': [_+1 for _ in range(len(list_type))],
                       'Type Code': list_type_code})

output.to_excel('./file/input.xlsx', index=False)

output
# Out:
#     No  Type Code
# 0    1      18300
# 1    2      10120
# 2    3      21600
# 3    4       1000
# 4    5       3300
# 5    6      10650
# 6    7       1400
# 7    8       1501
# 8    9       1500
# 9   10      10950
# 10  11       1600
# 11  12      11050
# 12  13       1903
# 13  14       1904
# 14  15      11350
# 15  16       1700
# 16  17       1900
# 17  18       2000
# 18  19      11850
# 19  20      32400
# 20  21       5401
# 21  22       5400
# 22  23      15500
# 23  24      15501
# 24  25      11800
# 25  26       2800
# 26  27       2901
# 27  28       3101
# 28  29       3100
# 29  30       3200
# 30  31       3301
# 31  32      20450
# 32  33       3800
# 33  34      22900
# 34  35       3900
# 35  36       4000
# 36  37       4100
# 37  38       4400
# 38  39       2900
# 39  40      22250
# 40  41      15900
# 41  42      13200
# 42  43      28750
# 43  44      30250
# 44  45      14100
