# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/2.url'):
    shutil.rmtree('./file/2.url')

os.makedirs('./file/2.url')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel(f'./file/1.page.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)
input_['SKU Count'] = input_['SKU Count'].astype(int)
input_['Page'] = input_['Page'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =


work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        try:
            list_url = []
            while len(list_url) < input_.loc[a, 'SKU Count']:
                for i in range(input_.loc[a, 'Page']):
                    b = 0
                    while True:
                        b += 1

                        try:
                            resp = requests.get(f'''{input_.loc[a, 'Url']}&start={i*100}&num=100''',
                                                 headers=get_header(),
                                                 proxies=get_proxy(),
                                                 timeout=(10, 10))
                            
                            if resp.status_code == 200:
                                break
                        except KeyboardInterrupt:
                            break
                        except:
                            continue
            
                    # = = = = = = = = = = = = = = =
            
                    soup = BeautifulSoup(resp.text, 'lxml')
                    html = etree.HTML(str(soup))
            
                    # = = = = = = = = = = = = = = =
            
                    list_url += [f'https://www.dormanproducts.com/{href.strip()}' for href in html.xpath('//h2[@class="item-headline"]/a/@href')]
                    list_url = sorted(list(set(list_url)), key=list_url.index)
            
                    # = = = = = = = = = = = = = = =

                    if work.qsize() % 100 == 0 and work.qsize() != 0:
                        clear_output()

                    print(f'''[尝试次数：{b}] - {input_.loc[a, 'No']}.{input_.loc[a, 'Url']} > Page {i+1}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                    # = = = = = = = = = = = = = = =
            
                    if len(list_url) == input_.loc[a, 'SKU Count']:
                        break
                        
            # = = = = = = = = = = = = = = =

            output = pd.DataFrame({'No': [i+1 for i in range(len(list_url))],
                                    'Url': list_url})

            output.to_excel(f'''./file/2.url/crawler_{input_.loc[a, 'No']}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(5):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel(f'''./file/url_error.xlsx''', index=False)
    print('爬虫存在error')
    print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.url'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/2.url/{file}',
              f'''./file/2.url/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：2
#
# [尝试次数：26] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 1
# [剩余数量：0] - [当前时间：16:59:33]
#
# [尝试次数：29] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 1
# [剩余数量：0] - [当前时间：16:59:34]
#
# [尝试次数：5] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 2
# [剩余数量：0] - [当前时间：16:59:55]
#
# [尝试次数：14] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 2
# [剩余数量：0] - [当前时间：17:00:36]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 3
# [剩余数量：0] - [当前时间：17:00:42]
#
# [尝试次数：21] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 3
# [剩余数量：0] - [当前时间：17:00:44]
#
# [尝试次数：59] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 4
# [剩余数量：0] - [当前时间：17:01:00]
#
# [尝试次数：3] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 5
# [剩余数量：0] - [当前时间：17:01:07]
#
# [尝试次数：108] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 6
# [剩余数量：0] - [当前时间：17:01:21]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 7
# [剩余数量：0] - [当前时间：17:01:30]
#
# [尝试次数：29] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 8
# [剩余数量：0] - [当前时间：17:01:41]
#
# [尝试次数：5] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 9
# [剩余数量：0] - [当前时间：17:01:48]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 10
# [剩余数量：0] - [当前时间：17:01:55]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 11
# [剩余数量：0] - [当前时间：17:01:59]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 1
# [剩余数量：0] - [当前时间：17:02:04]
#
# [尝试次数：309] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 4
# [剩余数量：0] - [当前时间：17:02:13]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 5
# [剩余数量：0] - [当前时间：17:02:22]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 2
# [剩余数量：0] - [当前时间：17:02:25]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 3
# [剩余数量：0] - [当前时间：17:02:31]
#
# [尝试次数：5] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 6
# [剩余数量：0] - [当前时间：17:02:34]
#
# [尝试次数：122] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 4
# [剩余数量：0] - [当前时间：17:02:45]
#
# [尝试次数：100] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 7
# [剩余数量：0] - [当前时间：17:02:46]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 5
# [剩余数量：0] - [当前时间：17:02:50]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 6
# [剩余数量：0] - [当前时间：17:02:56]
#
# [尝试次数：107] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 7
# [剩余数量：0] - [当前时间：17:03:10]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 8
# [剩余数量：0] - [当前时间：17:03:15]
#
# [尝试次数：8] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 9
# [剩余数量：0] - [当前时间：17:03:21]
#
# [尝试次数：2] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 10
# [剩余数量：0] - [当前时间：17:03:30]
#
# [尝试次数：15] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 11
# [剩余数量：0] - [当前时间：17:03:36]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 12
# [剩余数量：0] - [当前时间：17:03:42]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 13
# [剩余数量：0] - [当前时间：17:03:46]
#
# [尝试次数：3] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 8
# [剩余数量：0] - [当前时间：17:03:49]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 1
# [剩余数量：0] - [当前时间：17:03:50]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 2
# [剩余数量：0] - [当前时间：17:03:54]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 9
# [剩余数量：0] - [当前时间：17:03:55]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 3
# [剩余数量：0] - [当前时间：17:03:58]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 10
# [剩余数量：0] - [当前时间：17:04:00]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 4
# [剩余数量：0] - [当前时间：17:04:07]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 5
# [剩余数量：0] - [当前时间：17:04:12]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 6
# [剩余数量：0] - [当前时间：17:04:16]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 7
# [剩余数量：0] - [当前时间：17:04:21]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 11
# [剩余数量：0] - [当前时间：17:04:32]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 1
# [剩余数量：0] - [当前时间：17:04:37]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 2
# [剩余数量：0] - [当前时间：17:04:41]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 8
# [剩余数量：0] - [当前时间：17:04:47]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 9
# [剩余数量：0] - [当前时间：17:04:52]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 3
# [剩余数量：0] - [当前时间：17:04:59]
#
# [尝试次数：17] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 10
# [剩余数量：0] - [当前时间：17:05:07]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 11
# [剩余数量：0] - [当前时间：17:05:12]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 12
# [剩余数量：0] - [当前时间：17:05:15]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 4
# [剩余数量：0] - [当前时间：17:05:21]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 13
# [剩余数量：0] - [当前时间：17:05:21]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 1
# [剩余数量：0] - [当前时间：17:05:25]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 2
# [剩余数量：0] - [当前时间：17:05:30]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 5
# [剩余数量：0] - [当前时间：17:05:32]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 3
# [剩余数量：0] - [当前时间：17:05:34]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 6
# [剩余数量：0] - [当前时间：17:05:36]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 4
# [剩余数量：0] - [当前时间：17:05:39]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 7
# [剩余数量：0] - [当前时间：17:05:43]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 5
# [剩余数量：0] - [当前时间：17:05:44]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 8
# [剩余数量：0] - [当前时间：17:05:49]
#
# [尝试次数：1] - 1.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=wheel%2520cylinder > Page 6
# [剩余数量：0] - [当前时间：17:05:49]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 9
# [剩余数量：0] - [当前时间：17:06:01]
#
# [尝试次数：2] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 10
# [剩余数量：0] - [当前时间：17:06:56]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 11
# [剩余数量：0] - [当前时间：17:07:53]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 1
# [剩余数量：0] - [当前时间：17:08:06]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 2
# [剩余数量：0] - [当前时间：17:08:10]
#
# [尝试次数：1] - 2.https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Engine%2520Oil%2520Pan > Page 3
# [剩余数量：0] - [当前时间：17:08:16]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 4443.12it/s]
# Done ~
