# %%
import os

# %%
list_file = list(os.walk('./crawler_2'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 1821

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./crawler_2/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|█████████████████████████| 1821/1821 [00:13<00:00, 131.45it/s]
#    序号                       Title                     Subtitle     Price  \
# 0      SKF VKBA 1360 Radlagersatz                               110,24 €
# 0      SKF VKBA 3758 Radlagersatz                               115,72 €
# 0      SKF VKBA 6776 Radlagersatz                                81,96 €
# 0      SKF VKBA 7812 Radlagersatz  mit integriertem ABS-Sensor  200,24 €
# 0      SKF VKBA 1301 Radlagersatz           mit ABS-Sensorring   68,72 €
# .. ..                         ...                          ...       ...
# 0          SKF VKHB 2088 Radlager           57,1x112,7x30,1 mm   36,24 €
# 0          SKF VKHB 2167 Radlager               50x90x21,75 mm   34,96 €
# 0      SKF VKBA 6888 Radlagersatz                    84, 80 mm   78,96 €
# 0       SKF VKBA 899 Radlagersatz                        68 mm   38,48 €
# 0      SKF VKBA 6767 Radlagersatz  mit integriertem ABS-Sensor   55,48 €
#
#                                                   Kit  \
# 0
# 0   1 x Lager (Art. Nr: SKF04751)\n1 x Wellendicht...
# 0   1 x Mutter (Art. Nr: SKF01916)\n1 x Verschluss...
# 0
# 0   1 x Mutter (Art. Nr: SKF01991)\n1 x Lager (Art...
# ..                                                ...
# 0
# 0
# 0   1 x Mutter (Art. Nr: SKF02053)\n1 x Lager (Art...
# 0   1 x Mutter (Art. Nr: SKF01946)\n1 x Sicherungs...
# 0   1 x Mutter (Art. Nr: SKF02235)\n1 x Verschluss...
#
#                                               Vehicle  \
# 0
# 0
# 0   FIAT Doblo II Kombi (263) (Baujahr 11.2009 - ....
# 0   LEXUS UX (_AA1_, _AH1_) (Baujahr 10.2018 - ......
# 0   OPEL Senator B (V88) (Baujahr 09.1987 - 09.199...
# ..                                                ...
# 0
# 0
# 0   SUBARU Legacy III Kombi (BH) (Baujahr 10.1998 ...
# 0   MAZDA 626 II Limousine (GC) (Baujahr 11.1982 -...
# 0   SEAT Mii (KF1) (Baujahr 10.2011 - ...)\nSKODA ...
#
#                                                  OE Pic  \
# 0
# 0             9-00032-209-0;40210-61501;43215-T3200
# 0                                 51810394;3 28 027
# 0   42450-10020;42450-76030;42450-02270;42450-F4010
# 0              90235571;16 03 194;3 26 180;90486467
# ..                                              ...  ..
# 0                                           1400075
# 0                                          26799980
# 0                                        28474AE000
# 0                         8114-07625-D;0K954-26-151
# 0                         1S0 501 611 A;1S0 598 611
#
#                                                   Url  \
# 0   https://www.autoteiledirekt.de/skf-1362300.htm...
# 0   https://www.autoteiledirekt.de/skf-1362816.htm...
# 0   https://www.autoteiledirekt.de/skf-7019860.htm...
# 0   https://www.autoteiledirekt.de/skf-18750442.ht...
# 0   https://www.autoteiledirekt.de/skf-1362257.htm...
# ..                                                ...
# 0   https://www.autoteiledirekt.de/skf-15766.html?...
# 0   https://www.autoteiledirekt.de/skf-15792.html?...
# 0   https://www.autoteiledirekt.de/skf-1363125.htm...
# 0   https://www.autoteiledirekt.de/skf-1363288.htm...
# 0   https://www.autoteiledirekt.de/skf-7487180.htm...
#
#                                                   Src  ...   zf jost  \
# 0   https://cdn.autoteiledirekt.de/uploads/generic...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=136281...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=701986...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/uploads/generic...  ...  NaN  NaN
# 0   https://media.autoteiledirekt.de/360_photos/13...  ...  NaN  NaN
# ..                                                ...  ...  ...  ...
# 0   https://cdn.autoteiledirekt.de/thumb?id=15766&...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=15792&...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=136312...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=136328...  ...  NaN  NaN
# 0   https://cdn.autoteiledirekt.de/thumb?id=748718...  ...  NaN  NaN
#
#    triple five  trp breda lorett GEWINDEMASS: SCHRAUBENKOPF-/MUTTERNPROFIL:  \
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# ..         ...  ...          ...          ...                           ...
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
# 0          NaN  NaN          NaN          NaN                           NaN
#
#    maxgear japanparts  nps
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# ..     ...        ...  ...
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
# 0      NaN        NaN  NaN
#
# [1821 rows x 103 columns]
