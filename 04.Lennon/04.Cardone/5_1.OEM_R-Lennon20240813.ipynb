# %%
import os

list_file = sorted(list(os.walk('./file/4.auth'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_100.xlsx',
#  'crawler_101.xlsx',
#  'crawler_102.xlsx',
#  'crawler_103.xlsx',
#  'crawler_104.xlsx',
#  'crawler_105.xlsx',
#  'crawler_106.xlsx',
#  'crawler_107.xlsx',
#  'crawler_108.xlsx',
#  'crawler_109.xlsx',
#  'crawler_11.xlsx',
#  'crawler_111.xlsx',
#  'crawler_112.xlsx',
#  'crawler_12.xlsx',
#  'crawler_13.xlsx',
#  'crawler_14.xlsx',
#  'crawler_15.xlsx',
#  'crawler_16.xlsx',
#  'crawler_17.xlsx',
#  'crawler_18.xlsx',
#  'crawler_19.xlsx',
#  'crawler_2.xlsx',
#  'crawler_20.xlsx',
#  'crawler_21.xlsx',
#  'crawler_22.xlsx',
#  'crawler_23.xlsx',
#  'crawler_24.xlsx',
#  'crawler_25.xlsx',
#  'crawler_26.xlsx',
#  'crawler_27.xlsx',
#  'crawler_28.xlsx',
#  'crawler_29.xlsx',
#  'crawler_3.xlsx',
#  'crawler_30.xlsx',
#  'crawler_31.xlsx',
#  'crawler_32.xlsx',
#  'crawler_33.xlsx',
#  'crawler_34.xlsx',
#  'crawler_35.xlsx',
#  'crawler_36.xlsx',
#  'crawler_37.xlsx',
#  'crawler_38.xlsx',
#  'crawler_39.xlsx',
#  'crawler_4.xlsx',
#  'crawler_40.xlsx',
#  'crawler_41.xlsx',
#  'crawler_42.xlsx',
#  'crawler_43.xlsx',
#  'crawler_44.xlsx',
#  'crawler_45.xlsx',
#  'crawler_46.xlsx',
#  'crawler_47.xlsx',
#  'crawler_48.xlsx',
#  'crawler_49.xlsx',
#  'crawler_5.xlsx',
#  'crawler_50.xlsx',
#  'crawler_51.xlsx',
#  'crawler_52.xlsx',
#  'crawler_53.xlsx',
#  'crawler_54.xlsx',
#  'crawler_55.xlsx',
#  'crawler_56.xlsx',
#  'crawler_57.xlsx',
#  'crawler_58.xlsx',
#  'crawler_59.xlsx',
#  'crawler_6.xlsx',
#  'crawler_60.xlsx',
#  'crawler_61.xlsx',
#  'crawler_62.xlsx',
#  'crawler_63.xlsx',
#  'crawler_64.xlsx',
#  'crawler_65.xlsx',
#  'crawler_66.xlsx',
#  'crawler_68.xlsx',
#  'crawler_69.xlsx',
#  'crawler_7.xlsx',
#  'crawler_70.xlsx',
#  'crawler_71.xlsx',
#  'crawler_72.xlsx',
#  'crawler_73.xlsx',
#  'crawler_74.xlsx',
#  'crawler_75.xlsx',
#  'crawler_76.xlsx',
#  'crawler_77.xlsx',
#  'crawler_78.xlsx',
#  'crawler_79.xlsx',
#  'crawler_8.xlsx',
#  'crawler_80.xlsx',
#  'crawler_81.xlsx',
#  'crawler_82.xlsx',
#  'crawler_83.xlsx',
#  'crawler_84.xlsx',
#  'crawler_85.xlsx',
#  'crawler_86.xlsx',
#  'crawler_87.xlsx',
#  'crawler_88.xlsx',
#  'crawler_89.xlsx',
#  'crawler_9.xlsx',
#  'crawler_90.xlsx',
#  'crawler_91.xlsx',
#  'crawler_92.xlsx',
#  'crawler_93.xlsx',
#  'crawler_94.xlsx',
#  'crawler_95.xlsx',
#  'crawler_96.xlsx',
#  'crawler_97.xlsx',
#  'crawler_98.xlsx',
#  'crawler_99.xlsx']

# %%
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./file/4.auth/{file}',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Part Number'].tolist()
# Out:
# 总数量：167
# ['12-1000',
#  '12-1001',
#  '12-1002',
#  '12-1011',
#  '12-1014',
#  '12-1015',
#  '12-1017',
#  '12-10200',
#  '12-10201',
#  '12-10202',
#  '12-10203',
#  '12-10205',
#  '12-10206',
#  '12-10207',
#  '12-10208',
#  '12-10209',
#  '12-10210',
#  '12-10212',
#  '12-10213',
#  '12-10214',
#  '12-10215',
#  '12-10216',
#  '12-10217',
#  '12-10219',
#  '12-10220',
#  '12-10222',
#  '12-10224',
#  '12-10225F',
#  '12-10228',
#  '12-10229',
#  '12-10230',
#  '12-10232',
#  '12-10235',
#  '12-10236',
#  '12-10237',
#  '12-10238',
#  '12-10240',
#  '12-10241',
#  '12-10242',
#  '12-10243',
#  '12-10244',
#  '12-10245',
#  '12-10246',
#  '12-10247',
#  '12-10248',
#  '12-10249',
#  '12-10250',
#  '12-10251',
#  '12-10252',
#  '12-10253',
#  '12-10254',
#  '12-10255F',
#  '12-10256',
#  '12-10257',
#  '12-10259',
#  '12-10261',
#  '12-10262',
#  '12-10263',
#  '12-10264',
#  '12-10265',
#  '12-10267',
#  '12-10268',
#  '12-10269',
#  '12-10271',
#  '12-10273',
#  '12-10275',
#  '12-10276',
#  '12-10277',
#  '12-10278',
#  '12-10280',
#  '12-10281',
#  '12-10283',
#  '12-10284',
#  '12-10285',
#  '12-10286',
#  '12-10288F',
#  '12-1029',
#  '12-10290F',
#  '12-10294',
#  '12-10295',
#  '12-10296',
#  '12-10297',
#  '12-10298',
#  '12-10302',
#  '12-10303',
#  '12-10304',
#  '12-10305',
#  '12-10306',
#  '12-10310',
#  '12-10311',
#  '12-10312',
#  '12-10313',
#  '12-10314',
#  '12-10317',
#  '12-1032',
#  '12-10321',
#  '12-10323',
#  '12-10324',
#  '12-10334',
#  '12-10335',
#  '12-10336',
#  '12-10337',
#  '12-10340',
#  '12-10341',
#  '12-10349',
#  '12-10350',
#  '12-10351',
#  '12-10352',
#  '12-10353',
#  '12-10356',
#  '12-10357',
#  '12-10358',
#  '12-10359',
#  '12-10360',
#  '12-10362',
#  '12-12173',
#  '12-12200',
#  '12-12201',
#  '12-12202',
#  '12-12203',
#  '12-12204',
#  '12-12205',
#  '12-12207',
#  '12-12212',
#  '12-12214',
#  '12-12220',
#  '12-12221',
#  '12-12223',
#  '12-12229',
#  '12-12230',
#  '12-12231',
#  '12-12232',
#  '12-12233',
#  '12-12234',
#  '12-12236',
#  '12-1408',
#  '12-1432',
#  '12-1460',
#  '12-17200',
#  '12-17201',
#  '12-17202',
#  '12-17203',
#  '12-17204',
#  '12-17207',
#  '12-17213',
#  '12-17214',
#  '12-17215',
#  '12-17218',
#  '12-17219',
#  '12-17220',
#  '12-17221',
#  '12-17224',
#  '12-17225',
#  '12-17226',
#  '12-17228',
#  '12-17237',
#  '12-17239',
#  '12-17240',
#  '12-17241',
#  '12-17242',
#  '12-17245',
#  '12-17248',
#  '12-17261',
#  '12-17264',
#  '12-17412',
#  '12-17413',
#  '12-17420']

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.get(f'''https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:{input_.loc[a, 'Part Number']}&size=1&useCache=true&auth={input_.loc[a, 'Auth']}''',
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(10, 10))

        if resp.status_code == 200:
            break
    except KeyboardInterrupt:
        break
    except:
        continue

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()[0]

json_
# Out:
# {'__type': 'FinishedGood',
#  '__isSchema': False,
#  '__path': '/ProductDeskEntity/',
#  '__fullPath': '/ProductDeskEntity/CPCX|12-1000',
#  '__modified': '2024-08-13T08:00:08.350Z',
#  '__instanceId': 'CPCX|12-1000',
#  '__legacyId': '8274829994637027259',
#  'productDeskName': 'ABS Control Module',
#  'id': 'CPCX|12-1000',
#  'RelatedProducts': [],
#  'modifiedOn': '2024-08-13T08:00:08.350Z',
#  'channels': [{'code': 'R0164',
#    'name': 'B Attributes',
#    'requiresApproval': 0,
#    'id': '5500392672583901'},
#   {'code': 'R0159',
#    'name': '"Popularity Sorting"',
#    'requiresApproval': 0,
#    'id': '14085640583406600'},
#   {'code': 'R0118',
#    'name': 'All SKU only',
#    'requiresApproval': 0,
#    'id': '79040821002085808'},
#   {'code': 'R0161',
#    'name': 'Show on Site',
#    'requiresApproval': 0,
#    'id': '115580352379583008'},
#   {'code': 'R0107',
#    'name': 'Vibrant Marketing Q',
#    'requiresApproval': 0,
#    'id': '125106138327532704'},
#   {'code': 'R0155',
#    'name': '"Descriptions"',
#    'requiresApproval': 0,
#    'id': '250597815806126112'},
#   {'code': 'R0106',
#    'name': 'YouTube',
#    'requiresApproval': 0,
#    'id': '391720998998962112'},
#   {'code': 'R0105',
#    'name': '"Digital Assets"',
#    'requiresApproval': 0,
#    'id': '440482911086949952'},
#   {'code': 'R0157',
#    'name': 'Brand New',
#    'requiresApproval': 0,
#    'id': '527652436813773696'},
#   {'code': 'R0154',
#    'name': 'Item Descriptions',
#    'requiresApproval': 0,
#    'id': '542604911495065984'},
#   {'code': 'R0156',
#    'name': 'Rebates Manager',
#    'requiresApproval': 0,
#    'id': '599470158614506496'},
#   {'code': 'R0137',
#    'name': 'Color WorkQ',
#    'requiresApproval': 0,
#    'id': '671808520482284928'},
#   {'code': 'R0109',
#    'name': 'Weight Update WorkQ',
#    'requiresApproval': 0,
#    'id': '963914442537601152'}],
#  'Category': [{'code': 'Category|31',
#    'name': 'ABS Control Module',
#    'modified': '2023-01-31T22:00:01.763Z',
#    'id': '4841354158492619015',
#    'parentId': '2531612847404059032'},
#   {'code': 'Category|66',
#    'name': 'ABS Control Module',
#    'modified': '2023-01-31T22:00:01.763Z',
#    'id': '6059942310538499163',
#    'parentId': '6211635254849806247'}],
#  'Category Mapping': [{'name': 'ABS Control Module',
#    'modified': '2022-07-18T21:36:52.100Z',
#    'id': '945771484497230438',
#    'value': 'Category|66'},
#   {'name': 'ABS Control Module',
#    'modified': '2022-07-18T21:34:05.640Z',
#    'id': '7582090137186183160',
#    'value': 'Category|31'}],
#  'CrossReferences': [{'reference': 'ABS1500',
#    'accountId': '1299817030461690390',
#    'note': 'BCVP',
#    'code': 'ABS1500',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'Blue Streak',
#    'referenceType': 'Competitor Part',
#    'id': '44502106049874264',
#    'quality': 'Standard'},
#   {'reference': 'ALB1001',
#    'accountId': '1299817030461690390',
#    'note': 'BCVQ',
#    'code': 'ALB1001',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'BorgWarner',
#    'referenceType': 'Competitor Part',
#    'id': '401415645012957169',
#    'quality': 'Standard'},
#   {'reference': '15976820',
#    'accountId': '1299817030461690390',
#    'note': 'BCVC',
#    'code': '15976820',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'ACDelco',
#    'referenceType': 'Competitor Part',
#    'id': '406464211420263411',
#    'quality': 'Standard'},
#   {'reference': '15649220',
#    'accountId': '1299817030461690390',
#    'note': 'CNWG',
#    'code': '15649220',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'GMC',
#    'referenceType': 'OE Part',
#    'id': '588384757098797213',
#    'quality': 'Standard'},
#   {'reference': '15679730',
#    'accountId': '1299817030461690390',
#    'note': 'BWPP',
#    'code': '15679730',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'Chevrolet',
#    'referenceType': 'OE Part',
#    'id': '752890066313287566',
#    'quality': 'Standard'},
#   {'reference': '15676820',
#    'accountId': '1299817030461690390',
#    'note': 'BCVC',
#    'code': '15676820',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'ACDelco',
#    'referenceType': 'Competitor Part',
#    'id': '874102117230762272',
#    'quality': 'Standard'},
#   {'reference': '12-1000',
#    'accountId': '1299817030461690390',
#    'note': 'CPCX',
#    'code': '12-1000',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'P',
#    'name': 'CARDONE Reman',
#    'referenceType': 'User Defined',
#    'id': '8310567595719745927',
#    'quality': 'Premium'},
#   {'reference': '15649220',
#    'accountId': '1299817030461690390',
#    'note': 'BWPP',
#    'code': '15649220',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'Chevrolet',
#    'referenceType': 'OE Part',
#    'id': '194932992026525453',
#    'quality': 'Standard'},
#   {'reference': '15679730',
#    'accountId': '1299817030461690390',
#    'note': 'CNWG',
#    'code': '15679730',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'GMC',
#    'referenceType': 'OE Part',
#    'id': '588493242363234282',
#    'quality': 'Standard'},
#   {'reference': 'ALB1001',
#    'accountId': '1299817030461690390',
#    'note': 'BCVP',
#    'code': 'ALB1001',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'Blue Streak',
#    'referenceType': 'Competitor Part',
#    'id': '74734890477176679',
#    'quality': 'Standard'},
#   {'reference': '121000',
#    'accountId': '1299817030461690390',
#    'note': 'CPCX',
#    'code': '121000',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'P',
#    'name': 'CARDONE Reman',
#    'referenceType': 'Competitor Part',
#    'id': '747988100561740969',
#    'quality': 'Premium'},
#   {'reference': '15693489',
#    'accountId': '1299817030461690390',
#    'note': 'BCVC',
#    'code': '15693489',
#    'accountName': 'DefaultVendor',
#    'qualityCode': 'S',
#    'name': 'ACDelco',
#    'referenceType': 'Competitor Part',
#    'id': '929404702836780325',
#    'quality': 'Standard'}],
#  'DigitalAssets': [{'fileName': '121000-ang',
#    'orientation': 'ang',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Angle',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 1',
#    'modified': '1723563879168',
#    'sort': '1',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/0da4b09c-31e0-4ac2-86df-5ea5d348aff5/Cache/482.jpg',
#    'assetType': 'P04'},
#   {'fileName': '121000-fro',
#    'orientation': 'fro',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Front',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 2',
#    'modified': '1723563879168',
#    'sort': '2',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/e496f491-8b08-4ffa-8bc7-8d2e88ca309f/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': '121000-bac',
#    'orientation': 'bac',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Back',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 3',
#    'modified': '1723563879168',
#    'sort': '3',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/1188b706-cff7-4647-afcc-5ef9e35bab8f/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': '121000-lef',
#    'orientation': 'lef',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Left',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 4',
#    'modified': '1723563879168',
#    'sort': '4',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/ef70544d-134d-4791-b43f-9e9c6e8eb386/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': '121000-rit',
#    'orientation': 'rit',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Right',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 5',
#    'modified': '1723563879168',
#    'sort': '5',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/a925cd46-500c-4189-8f84-6c6a2ce51b89/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': '121000-con',
#    'orientation': 'con',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - Connector',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 6',
#    'modified': '1723563879168',
#    'sort': '6',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/16cb43ce-c7a5-4f46-baf4-ef27df1adfa8/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': 'Recycle-zz1',
#    'orientation': 'zz1',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - User Defined 1',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 10',
#    'modified': '1723563879168',
#    'sort': '10',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/2a13bb74-bd17-4387-b121-40110b8eb684/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': 'CARDONEcore-zz2',
#    'orientation': 'zz2',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - User Defined 2',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 20',
#    'modified': '1723563879168',
#    'sort': '20',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/4e9b1d03-e0f8-4903-bd01-2b04646022b6/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': 'USA-zz3',
#    'orientation': 'zz3',
#    'altText': 'CARDONE Reman 12-1000 ABS Control Module - User Defined 3',
#    'PIESAssetTypeCode': '',
#    'description': 'Image 30',
#    'modified': '1723563879168',
#    'sort': '30',
#    'fileType': 'jpg',
#    'partType': 'ABS Control Module',
#    'url': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/0baf0730-5f1d-434c-b5c4-000f31ef157d/Cache/482.jpg',
#    'assetType': 'P01'},
#   {'fileName': '931185-12DS ABS Control Modules Digital Spanish',
#    'PIESAssetTypeCode': 'INS',
#    'alias': 'ABS Control Modules Digital Spanish',
#    'description': 'Installation',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/931185-12DS ABS Control Modules Digital Spanish.pdf'},
#   {'fileName': '931185-12DE ABS Control Modules Digital English',
#    'PIESAssetTypeCode': 'INS',
#    'alias': 'ABS Control Modules Digital English',
#    'description': 'Installation',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/931185-12DE ABS Control Modules Digital English.pdf'},
#   {'fileName': '931185-12DF ABS Control Modules Digital French',
#    'PIESAssetTypeCode': 'INS',
#    'alias': 'ABS Control Modules Digital French',
#    'description': 'Installation',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/931185-12DF ABS Control Modules Digital French.pdf'},
#   {'fileName': '121214CPABS Core Policy - ABS',
#    'PIESAssetTypeCode': 'PDB',
#    'alias': 'ABS Core Policy',
#    'description': 'Product Brochure',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/121214CPABS Core Policy - ABS.pdf'},
#   {'fileName': 'PT12-0005',
#    'PIESAssetTypeCode': 'BUL',
#    'alias': 'Brake Bleeding Vehicles with Antilock Brakes',
#    'description': 'Technical Bulletin',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/PT12-0005.pdf'},
#   {'fileName': 'PT12-0004',
#    'PIESAssetTypeCode': 'BUL',
#    'alias': 'Intermittent ABS Operation Caused by Cranked Sensor Ring',
#    'description': 'Technical Bulletin',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/PT12-0004.pdf'},
#   {'fileName': 'CARDONE Warranty - Canada French',
#    'PIESAssetTypeCode': 'WAR',
#    'alias': 'Cardone French Warranty',
#    'description': 'Warranty',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/CARDONE Warranty - Canada French.pdf'},
#   {'fileName': 'CARDONE Warranty - Mexico Spanish',
#    'PIESAssetTypeCode': 'WAR',
#    'alias': 'Cardone Mexico Warranty',
#    'description': 'Warranty',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/CARDONE Warranty - Mexico Spanish.pdf'},
#   {'fileName': 'CARDONE Warranty - Canada English',
#    'PIESAssetTypeCode': 'WAR',
#    'alias': 'Cardone Canada Warranty',
#    'description': 'Warranty',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/CARDONE Warranty - Canada English.pdf'},
#   {'fileName': 'CARDONE Warranty - USA English',
#    'PIESAssetTypeCode': 'WAR',
#    'alias': 'Cardone USA Warranty',
#    'description': 'Warranty',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/CARDONE Warranty - USA English.pdf'},
#   {'fileName': 'CARDONE Warranty - USA Spanish',
#    'PIESAssetTypeCode': 'WAR',
#    'alias': 'Cardone Spanish Warranty',
#    'description': 'Warranty',
#    'modified': '1723563879168',
#    'fileType': 'pdf',
#    'url': 'https://www.cardone.com/content/Products/CARDONE Warranty - USA Spanish.pdf'}],
#  'createdOn': '2022-02-03T17:12:01.387Z',
#  'Design Upgrade': None,
#  'EXPI EMS': '1',
#  'Image 4 AltText': 'CARDONE Reman 12-1000 ABS Control Module-Right',
#  'ApplicationSummary': 'Chevrolet Astro 1992-90, Blazer 1991-90, C1500 1993-88, C2500 1993-88, C35 1993-88, C3500 1993-88, C3500HD 1991, G10 1992-90, G20 1992-90, G30 1992-90, K1500 1993-88, K2500 1993-88, K3500 1993-88, R1500 Suburban 1991-90, R2500 Suburban 1991-90, S10 1993-89, S10 Blazer 1991-89, V1500 Suburban 1991-90, V2500 Suburban 1991-90; GMC C1500 1993-88, C2500 1993-88, C3500 1993-88, C3500HD 1991, G1500 1992-90, G2500 1992-90, G3500 1992-90, Jimmy 1991-90, K1500 1993-88, K2500 1993-88, K3500 1993-88, R1500 Suburban 1991-90, R2500 Suburban 1991-90, S15 1990-89, S15 Jimmy 1991-89, Safari 1992-90, Sonoma 1993-91, V1500 Suburban 1991-90, V2500 Suburban 1991-90',
#  'DES Description': 'ABS Control Module',
#  'PackageUOM': 'EA',
#  'KEY Description': 'ABS, ABS Control Module, ABS Module, Anti-Lock Brakes, ABS Computer, ABS Control Unit, EBCM',
#  'Left FileName': 'CARDONE_Reman_12-1000_Left.jpg',
#  'Exclusive Coverage': None,
#  'Weight PG': '1.0200',
#  'Product Condition': 'Remanufactured',
#  'Technical Bulletin': 'https://cardoneb2b.mybigcommerce.com/content/Products/PT10-0002.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0005.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0002.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0004.pdf',
#  'Terminal Gender': 'Male',
#  'UOM': 'IN',
#  'MinimumOrderQuantity': '1',
#  'ItemEffectiveDate': '2002-10-01',
#  'Product Line Marketing Stmt': 'After 50 years of leadership in the automotive aftermarket, we are excited to start the next chapter of CARDONE’s dynamic history. We are positioned to support the next wave of vehicle technology and ready to innovate new solutions that bring value to our customers – all while upholding sustainable business practices and high ethical principles. We build it better.',
#  'DEF Description': 'ABS Control Module',
#  'Front AltText': 'CARDONE Reman 12-1000 ABS Control Module-Front',
#  'Lifecycle Status': 'Available to Order',
#  'Technical Bulletin2': 'https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0005.pdf',
#  'User Defined 1 FileName': 'CARDONE_Reman_12-1000_User_Defined_1.jpg',
#  'Installation': 'https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DF ABS Control Modules Digital French.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DS ABS Control Modules Digital Spanish.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DE ABS Control Modules Digital English.pdf',
#  'Attachment Method': 'Bolt on',
#  'ACESApplications': 'Y',
#  'Warranty': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519WARR Cardone Warranty Policy_USA.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/99519CWARR Cardone Warranty Policy_Canada.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/99519WARRS_Cardone_Warranty_Span.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/99519WARRMS_Cardone_Warranty_MEX_Span.pdf|https://cardoneb2b.mybigcommerce.com/content/Products/99519CWARRF_Cardone_Warranty_Canada French.pdf',
#  'EXPI PLC': '72',
#  'ItemQuantitySize': '1.02',
#  'Programming Required': 'No',
#  'Website Part Type': 'ABS Control Module',
#  'Length': '5.5000',
#  'Installation3': 'https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DE ABS Control Modules Digital English.pdf',
#  'Terminal Quantity': '99',
#  'LAB Description': 'Remanufactured ABS Control Module',
#  'EXPI WT2': 'MO',
#  'Image 1': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/e496f491-8b08-4ffa-8bc7-8d2e88ca309f/Cache/482.jpg',
#  'Image 4': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/a925cd46-500c-4189-8f84-6c6a2ce51b89/Cache/482.jpg',
#  'Technical Bulletin3': 'https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0002.pdf',
#  'Image 2': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/1188b706-cff7-4647-afcc-5ef9e35bab8f/Cache/482.jpg',
#  'User Defined 2 FileName': 'CARDONE_Reman_12-1000_User_Defined_2.jpg',
#  'Height': '4.6250',
#  'EXPI LIF': '2',
#  'Warranty5': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519CWARRF_Cardone_Warranty_Canada French.pdf',
#  'Image 10': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/0baf0730-5f1d-434c-b5c4-000f31ef157d/Cache/482.jpg',
#  'Warranty Info': 'Limited Lifetime',
#  'Warranty Disclaimer': "A warranty must be returned to the parts supplier where the CARDONE product was purchased and is subject to that part store's terms & conditions. If the parts retailer offers a different warranty than the CARDONE warranty, the retailer’s policy will prevail",
#  'User Defined 3 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 3',
#  'Right FileName': 'CARDONE_Reman_12-1000_Right.jpg',
#  'Image 10 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 3',
#  'MKT Description': 'CARDONE Remanufactured ABS Control Modules are designed to meet or exceed O.E. performance. Reverse engineering provides insight into how and why the unit originally failed, allowing our engineers to identify and correct original design flaws. Every CARDONE unit goes through stringent testing, ensuring like-new performance and quick reaction time when traction control is required.',
#  'Back AltText': 'CARDONE Reman 12-1000 ABS Control Module-Back',
#  'SHO Description': 'ABS Ctrl Module',
#  'Warranty4': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519WARRMS_Cardone_Warranty_MEX_Span.pdf',
#  'AvailableDate': '2002-10-01',
#  'ContainerType': 'BX',
#  'EXPI PLM': '3',
#  'User Defined 2 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 2',
#  'ItemLevelGTIN': '00082617165631',
#  'Warranty1': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519WARR Cardone Warranty Policy_USA.pdf',
#  'Image 2 AltText': 'CARDONE Reman 12-1000 ABS Control Module-Back',
#  'E-Waste': 'Yes',
#  'Dimensional Weight PG': '0.97',
#  'Technical Bulletin1': 'https://cardoneb2b.mybigcommerce.com/content/Products/PT10-0002.pdf',
#  'Installation1': 'https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DF ABS Control Modules Digital French.pdf',
#  'Width': '7.3750',
#  'Product Brochure': 'https://cardoneb2b.mybigcommerce.com/content/Products/121214CPABS Core Policy - ABS.pdf',
#  'Meta Description': 'CARDONE Reman,ABS Control Module,Chevrolet Astro 1992-90, Blazer 1991-90, C1500 1993-88, C2500 1993-88, C35 1993-88, C3500 1993-88, C3500HD 1991, G10 1992-90, G20 1992-90, G30 1992-90, K1500 1993-88, K2500 1993-88, K3500 1993-88, R1500 Suburban 1991-90, R2500 Suburban 1991-90, S10 1993-89, S10 Blazer 1991-89, V1500 Suburban 1991-90, V2500 Suburban 1991-90; GMC C1500 1993-88, C2500 1993-88, C3500 1993-88, C3500HD 1991, G1500 1992-90, G2500 1992-90, G3500 1992-90, Jimmy 1991-90, K1500 1993-88, K2500 1993-88, K3500 1993-88, R1500 Suburban 1991-90, R2500 Suburban 1991-90, S15 1990-89, S15 Jimmy 1991-89, Safari 1992-90, Sonoma 1993-91, V1500 Suburban 1991-90, V2500 Suburban 1991-90',
#  'SyncToBC': '1',
#  'QuantityofEaches': '1',
#  'QuantityPerApplicationQualifier': 'NOR',
#  'Warranty3': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519WARRS_Cardone_Warranty_Span.pdf',
#  'Sustainable Choice': 'Yes',
#  'EXPI WS1': 'Limited Lifetime',
#  'Left AltText': 'CARDONE Reman 12-1000 ABS Control Module-Left',
#  'ItemQuantitySizeUOM': 'LB',
#  'EXPI CTO': 'US',
#  'AAIAProductCategoryCode': '400501',
#  'INV Description': 'Reman. ABS Control Module',
#  'PackageBarCodeCharacters': '00082617165631',
#  'Image 3 AltText': 'CARDONE Reman 12-1000 ABS Control Module-Left',
#  'Module Housing Material': 'Plastic',
#  'EXPI WD2': 'MI',
#  'Image 8 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 1',
#  'QuantityPerApplicationUOM': 'EA',
#  'Warranty2': 'https://cardoneb2b.mybigcommerce.com/content/Products/99519CWARR Cardone Warranty Policy_Canada.pdf',
#  'Product Brochure1': 'https://cardoneb2b.mybigcommerce.com/content/Products/121214CPABS Core Policy - ABS.pdf',
#  'Image 9': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/4e9b1d03-e0f8-4903-bd01-2b04646022b6/Cache/482.jpg',
#  'Image 1 AltText': 'CARDONE Reman 12-1000 ABS Control Module-Front',
#  'Technical Bulletin4': 'https://cardoneb2b.mybigcommerce.com/content/Products/PT12-0004.pdf',
#  'MinimumOrderQuantityUOM': 'EA',
#  'EXPI HTS': '9032896085',
#  'User Defined 1 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 1',
#  'Connector Quantity': '1',
#  'Brochure': 'https://cardoneb2b.mybigcommerce.com/content/Products/CPCX_Cardone Reman_ABS Control Module_Mkt.pdf',
#  'Features and Benefits': '<li>Worn-out, missing or non-functioning components are replaced with new or rebuilt components, where necessary</li><li>Critical components are re-soldered, where necessary, to ensure superior electrical connections, eliminate intermittent failures and extend product life</li><li>100% computer testing ensures consistent performance</li><li>Air-decay testing ensures unit is void of brake fluid</li><li>On-car testing is done, when necessary, for validation of product reliability</li><li>High-pressure hydraulic testing ensures zero leakage</li><li>As a remanufactured Original Equipment part, this unit guarantees a perfect vehicle fit.</li><li>Our remanufacturing process is earth-friendly, as it reduces the energy and raw material needed to make a new part by 80%.</li>',
#  'Image 8': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/2a13bb74-bd17-4387-b121-40110b8eb684/Cache/482.jpg',
#  'Image 3': 'https://cardone.vsdam.com/Data/23/Repositories/F6C5638756DB46949C52F2D92027A142/ef70544d-134d-4791-b43f-9e9c6e8eb386/Cache/482.jpg',
#  'VisibleOnBC': '1',
#  'Right AltText': 'CARDONE Reman 12-1000 ABS Control Module-Right',
#  'Mounting Hardware Included': 'No',
#  'User Defined 3 FileName': 'CARDONE_Reman_12-1000_User_Defined_3.jpg',
#  'Back FileName': 'CARDONE_Reman_12-1000_Back.jpg',
#  'Brochure1': 'https://cardoneb2b.mybigcommerce.com/content/Products/CPCX_Cardone Reman_ABS Control Module_Mkt.pdf',
#  'Image 9 AltText': 'CARDONE Reman 12-1000 ABS Control Module-User Defined 2',
#  'EXPI WS2': 'TX',
#  'EXPI REM': 'Y',
#  'ItemLevelGTINQualifier': 'UP',
#  'Front FileName': 'CARDONE_Reman_12-1000_Front.jpg',
#  'EXPI MSR': 'N',
#  'Lifetime Warranty': 'Yes',
#  'Installation2': 'https://cardoneb2b.mybigcommerce.com/content/Products/931142-12DS ABS Control Modules Digital Spanish.pdf',
#  'EXPI LIS': 'Available to Order',
#  'PackageLevelGTIN': '00082617165631',
#  'Install Solution': None,
#  'QuantityPerApplication': '1',
#  'Brand': {'id': '8689581028987187766',
#   'number': 'CPCX',
#   'name': 'CARDONE Reman',
#   'BrandAAIAID': None},
#  'Product Type': {'id': '322166848018378410',
#   'number': '1844',
#   'name': 'ABS Control Module',
#   'Site Keywords': 'ABS, ABS Control Module, ABS Module, Anti-Lock Brakes, ABS Computer, ABS control unit, EBCM',
#   'Auto Care Category': 'Brake',
#   'Reman Prefix': '12',
#   'Auto Care Subcategory': 'Control Modules',
#   'PartTerminologyName': 'ABS Control Module',
#   'PartSubCategory': 'Control Modules',
#   'Positions': [{'Position': 'N/A', 'PositionID': '1'}],
#   'PartCategory': 'Brake',
#   'SyncPartTypeToDMT': '1'},
#  'productDeskTypeId': '2',
#  'productDeskTypeName': 'Finished Good',
#  'productDeskItemNumber': '12-1000',
#  'productDeskExternalKey': 'CPCX|12-1000',
#  'childrenCount': 0,
#  'parentId': '322166848018378410',
#  '__parentId': '322166848018378410',
#  'Availability Text': 'Eligible for same-day shipment on Priority Plus orders. See Hours & Service Levels page for cutoff times.',
#  'PurchasableOnBC': 'available',
#  '_addon': '12-1000::93812:140243:22416',
#  '_addonCardone': '12-1000::98251:116537:524',
#  'EXPI HSB': '9032896085',
#  'EXPI HAC': '9032890099',
#  'Eligible for R&R Service': 'Yes',
#  'Flash Programming Service': None}

# %%
list_oem = []
list_dict = json_['CrossReferences'] if 'CrossReferences' in json_ else []
for dict_ in list_dict:
    if dict_['referenceType'].strip() == 'OE Part':
        list_oem.append(dict_['reference'].strip())

oem = ';'.join(sorted(list(set(list_oem)), key=list_oem.index))

oem
# Out:
# '15649220;15679730'

# %%
df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                         'Type': input_.loc[a, 'Type'],
                         'Part Number': input_.loc[a, 'Part Number'],
                         'Title': input_.loc[a, 'Title'],
                         'Subtitle': input_.loc[a, 'Subtitle'],
                         'Application Summary': input_.loc[a, 'Application Summary'],
                         'OEM': oem,
                         'Picture': input_.loc[a, 'Picture'],
                         'Url': input_.loc[a, 'Url'],
                         'Json_Src': input_.loc[a, 'Json_Src'],
                         'Json_Info': input_.loc[a, 'Json_Info'],
                         'Bundle': input_.loc[a, 'Bundle'],
                         'Auth': input_.loc[a, 'Auth']}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    No                Type Part Number                         Title  \
# 0   1  ABS Control Module     12-1000  ABS Control Module - 12-1000
#
#         Subtitle                                Application Summary  \
# 0  CARDONE Reman  CARDONE Reman,ABS Control Module,Chevrolet Ast...
#
#                  OEM Picture  \
# 0  15649220;15679730
#
#                                                  Url  \
# 0  https://www.cardone.com/product/abs-control-mo...
#
#                                             Json_Src  \
# 0  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
#
#                                            Json_Info  \
# 0  {"0": {"productDeskExternalKey": "CPCX|12-1000...
#
#                                               Bundle  \
# 0  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
#
#                                Auth
# 0  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel('./test_oem.xlsx', index=False)

output_correct
# Out:
#    No                Type Part Number                         Title  \
# 0   1  ABS Control Module     12-1000  ABS Control Module - 12-1000
#
#         Subtitle                                Application Summary  \
# 0  CARDONE Reman  CARDONE Reman,ABS Control Module,Chevrolet Ast...
#
#                  OEM Picture  \
# 0  15649220;15679730
#
#                                                  Url  \
# 0  https://www.cardone.com/product/abs-control-mo...
#
#                                             Json_Src  \
# 0  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
#
#                                            Json_Info  \
# 0  {"0": {"productDeskExternalKey": "CPCX|12-1000...
#
#                                               Bundle  \
# 0  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
#
#                                Auth
# 0  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./test_oem_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
