# %% [markdown]
# - Update: 2023.01.14
#
# # 0. 配置参数
#
# - `category`：what the fuck

# %%
html = '''
<html lang="en"><head style="">
<meta charset="ISO-8859-1">
<meta name="description" content="Discount auto parts and accessories catalog for all foreign and import cars and trucks. Low Prices, Quality, Service and Free shipping.">
<meta name="keywords" content="auto parts">
<meta name="viewport" content="width=device-width, initial-scale=1">
<meta http-equiv="x-ua-compatible" content="ie=edge">
<meta name="format-detection" content="telephone=no">
<meta name="robots" content="noindex, nofollow">
<title>2203710 | Partsgeek.com</title>
<link type="text/css" rel="stylesheet" href="https://www.partsgeek.com/css/2806602213-partsgeek.main.min.css">
<link type="text/css" rel="prefetch" as="style" href="https://www.partsgeek.com/css/2806602213-partsgeek.checkout.min.css">
<script type="text/javascript" src="https://cdn.taboola.com/scripts/eid.es5.js" charset="UTF-8" async="async"></script><script type="text/javascript" src="https://cdn.taboola.com/scripts/cds-pips.js" charset="UTF-8" async="async"></script><script async="" src="//cdn.taboola.com/libtrc/unip/1424786/tfa.js" id="tb_tfa_script"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-RV4L35KF7B&amp;l=dataLayer&amp;cx=c"></script><script src="https://connect.facebook.net/signals/config/386264895475857?v=2.9.92&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://bat.bing.com/bat.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WSTV37R"></script><script type="text/javascript" src="https://www.partsgeek.com/js/2806602213-partsgeek.main.min.js" defer=""></script>
<script type="text/javascript" src="https://www.partsgeek.com/js/2806602213-partsgeek.sub.min.js" defer=""></script>
<link type="text/javascript" rel="prefetch" as="script" href="https://www.partsgeek.com/js/2806602213-partsgeek.checkout.min.js">
<link type="text/javascript" rel="prefetch" as="script" href="https://www.partsgeek.com/js/2806602213-partsgeek.vehicle-selector.min.js">
<link type="text/javascript" rel="prefetch" as="script" href="https://www.partsgeek.com/js/2806602213-partsgeek.vehicle-selector-two.min.js">
<link type="text/javascript" rel="prefetch" as="script" href="https://www.partsgeek.com/js/2806602213-partsgeek.auto-complete.min.js">
<link type="text/javascript" rel="prefetch" as="script" href="https://www.partsgeek.com/js/2806602213-partsgeek.carousel.min.js">
<link rel="preconnect" href="https://fonts.gstatic.com">
<link href="https://fonts.googleapis.com/css2?family=Noto+Sans:wght@400;700&amp;family=Roboto:wght@400;700&amp;display=swap" rel="stylesheet"> <link rel="canonical" href="https://www.partsgeek.com/ss/">
<script>
window.dataLayer = window.dataLayer || [];
dataLayer.push({"siteSection":"site-search","vistorType":"regular","remarketing":{"ecomm_pagetype":"searchresults","ecomm_prodid":"","ecomm_totalvalue":""}});
</script>

<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
})(window,document,'script','dataLayer','GTM-WSTV37R');</script>

<script async="" src="https://www.googleoptimize.com/optimize.js?id=OPT-5MP8WBN"></script>
<script>
                dataLayer.push({ ecommerce2: null });
                dataLayer.push({"event":"view_item_list","ecommerce2":{"item_list_id":"sitesearch","item_list_name":"SiteSearch","items":[{"index":0,"item_id":"7948-07402831","item_name":"Brake Hose","currency":"USD","item_brand":"Sunsong","item_category":"Brake","item_category2":"1992-2001","item_category3":"Toyota","item_category4":"Camry","item_category5":"T","price":"12.72","quantity":1},{"index":1,"item_id":"7878-07402831","item_name":"Brake Hose","currency":"USD","item_brand":"Sunsong","item_category":"Brake","item_category2":"1999-2003","item_category3":"Lexus","item_category4":"RX300","item_category5":"T","price":"12.72","quantity":1},{"index":2,"item_id":"7930-07402831","item_name":"Brake Hose","currency":"USD","item_brand":"Sunsong","item_category":"Brake","item_category2":"1995-2004","item_category3":"Toyota","item_category4":"Avalon","item_category5":"T","price":"12.72","quantity":1},{"index":3,"item_id":"8134-07402831","item_name":"Brake Hose","currency":"USD","item_brand":"Sunsong","item_category":"Brake","item_category2":"1999-2003","item_category3":"Toyota","item_category4":"Solara","item_category5":"T","price":"12.72","quantity":1},{"index":4,"item_id":"1970-01492348","item_name":"Shock Bump Stop","currency":"USD","item_brand":"Dorman","item_category":"Suspension","item_category2":"2000-2001","item_category3":"Dodge","item_category4":"Ram 1500","item_category5":"A","price":"33.58","quantity":1},{"index":5,"item_id":"1985-01492348","item_name":"Shock Bump Stop","currency":"USD","item_brand":"Dorman","item_category":"Suspension","item_category2":"2000-2002","item_category3":"Dodge","item_category4":"Ram 2500","item_category5":"A","price":"33.58","quantity":1},{"index":6,"item_id":"2000-01492348","item_name":"Shock Bump Stop","currency":"USD","item_brand":"Dorman","item_category":"Suspension","item_category2":"2000-2002","item_category3":"Dodge","item_category4":"Ram 3500","item_category5":"A","price":"33.58","quantity":1},{"index":7,"item_id":"2324-01492348","item_name":"Shock Bump Stop","currency":"USD","item_brand":"Dorman","item_category":"Suspension","item_category2":"2000-2006","item_category3":"Jeep","item_category4":"Wrangler","item_category5":"A","price":"33.58","quantity":1}]}});
            </script><script>
    dataLayer.push({
       event: 'search',
       searchTerm: '2203710'
    });
    </script>
<meta http-equiv="origin-trial" content=""><script type="text/javascript" async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1071348958/?random=1673675698515&amp;cv=11&amp;fst=1673675698515&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2wg1a1&amp;u_w=1920&amp;u_h=1080&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fwww.partsgeek.com%2Fss%2F%3Fi%3D1%26ssq%3D2203710&amp;ref=https%3A%2F%2Fwww.partsgeek.com%2Fss%2F%3Fi%3D1%26ssq%3D2203710&amp;tiba=2203710%20%7C%20Partsgeek.com&amp;auid=1840061459.1673665689&amp;data=ecomm_pagetype%3Dsearchresults%3Becomm_prodid%3D%3Becomm_totalvalue%3D&amp;rfmt=3&amp;fmt=4"></script><script async="" type="text/javascript" src="https://cdn.livechatinc.com/tracking.js"></script><script src="https://bat.bing.com/p/action/5213803.js" type="text/javascript" async="" data-ueto="ueto_22956e5a6f"></script></head>
<body>

<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WSTV37R" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<div id="whole">
<header>
<a class="skip-link" tabindex="0" href="#">Skip to main content</a> <div id="header-top">
<a href="https://www.partsgeek.com/" title="Discount Auto Parts Geek" aria-label="home"></a>
<span class="header-tagline">Discount Auto Parts and Accessories</span>
<img alt="Auto Parts Since 2008" aria-label="buy with confidence since 2008 stamp" class="header-stamp" src="https://www.partsgeek.com/images/stamp.png" width="106" height="79">
<button class="show-menu" aria-label="show menu">
<svg viewBox="0 0 100 100">
<path class="line line1" d="M 20,29.000046 H 80.000231 C 80.000231,29.000046 94.498839,28.817352 94.532987,66.711331 94.543142,77.980673 90.966081,81.670246 85.259173,81.668997 79.552261,81.667751 75.000211,74.999942 75.000211,74.999942 L 25.000021,25.000058"></path>
<path class="line line2" d="M 20,50 H 80"></path>
<path class="line line3" d="M 20,70.999954 H 80.000231 C 80.000231,70.999954 94.498839,71.182648 94.532987,33.288669 94.543142,22.019327 90.966081,18.329754 85.259173,18.331003 79.552261,18.332249 75.000211,25.000058 75.000211,25.000058 L 25.000021,74.999942"></path>
</svg>
<span>Menu</span>
</button>
</div>
<nav id="header-nav" class="group" aria-label="main">
<ul>
<li><a href="https://www.partsgeek.com/" class="topmenu">Home</a></li>
<li class="header-online-catalog"><a href="https://www.partsgeek.com/catalog/" class="topmenu">Online Catalog</a></li>
<li class="header-brands"><a href="https://www.partsgeek.com/brands/" class="topmenu">Brands</a></li>
<li class="header-shop-by-make"><a href="https://www.partsgeek.com/makes/replacement_auto_parts.html" class="topmenu">Shop By Make</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html" class="topmenu">Customer Service</a></li>
<li class="header-quote"><a href="https://www.partsgeek.com/cart/quote/" class="topmenu">Retrieve Quote</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html" class="topmenu">Track Order</a></li>
<li><a href="https://www.partsgeek.com/cart/" class="topmenu">View Cart</a></li>
<li class="header-checkout">
<a href="https://www.partsgeek.com/cart/" class="topmenu">Checkout<i class="pgfont-basket"></i></a>
 </li>
</ul>
</nav>
<div class="header-search">
<div class="header-search-left">
<form role="search" id="ss" aria-label="site wide" action="/ss/">
<input type="hidden" name="i" value="1">
<div class="search-label">Search</div>
<div class="input-group search-group">
<input type="text" aria-label="search" class="form-control search-text" name="ssq" id="ssq" value="2203710">
<i class="pgfont-search"></i>
<button class="search-button btn btn-secondary" aria-label="submit">Go</button>
</div>
</form>
</div>
<div class="header-search-right">
<div class="mm-dd-container">
<div class="search-label">Search</div>
<button class="mm-dd-button btn btn-link mm-modal" aria-label="toggle make model search" alt="toggle make model search">
<span class="mr-sm">Make/Model</span>
<div><i class="pgfont-down-open"></i></div>
</button>
</div>
<a href="https://www.partsgeek.com/cart/" class="btn btn-success btn m-checkout-btn">Checkout<i class="pgfont-basket"></i></a>
</div>
</div>
</header>
<main>
<div class="phone">
Call To Order: <a aria-label="call us to order at 1-800-541-9352" href="tel:+1-800-541-9352">1-800-541-9352</a>
</div>
<h1 class="ss-search-text">
<div>
Results for
</div>
<span>
"2203710"
</span>
<span class="catalog-filter-remove"><a aria-label="remove 2203710 from search" href="https://www.partsgeek.com/ss/?"></a></span>
</h1>
<div class="content-buttons-mobile">
<div class="heading"><span>Select Your Vehicle Year</span></div>
<div class="content-buttons content-buttons-sm">
<ul>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2006" title="2006">
2006 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2005" title="2005">
2005 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2004" title="2004">
2004 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2003" title="2003">
2003 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2002" title="2002">
2002 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2001" title="2001">
2001 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2000" title="2000">
2000 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1999" title="1999">
1999 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1998" title="1998">
1998 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1997" title="1997">
1997 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1996" title="1996">
1996 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1995" title="1995">
1995 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1994" title="1994">
1994 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1993" title="1993">
1993 <i class="pgfont-right-open-big"></i>
</a>
</li>
<li>
<a class="btn btn-outline-secondary" href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1992" title="1992">
1992 <i class="pgfont-right-open-big"></i>
</a>
</li>
</ul>
</div>
</div>
<span class="review-fitment-notes">Review Fitment Notes</span>
<div id="sticky_parent">
<div class="ss-container">
<div class="side-nav-container">
<div class="side-nav-section">
<div class="side-nav-section-heading">Selected Items
<div class="side-nav-close"></div>
</div>
<ul class="side-nav-section-content">
<li>Keyword: <span>2203710</span></li>
<li>
<a style="text-decoration: underline" href="https://www.partsgeek.com/ss/?" rel="nofollow">Remove</a>
</li>
</ul>
</div>
<div class="side-nav-section">
<div class="side-nav-section-heading">Select Year
<div class="side-nav-close"></div>
</div>
<div class="side-nav-section-content">
<ul class="side-nav-section-column-4">
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2006" rel="nofollow">2006</a>
</li>
 <li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2005" rel="nofollow">2005</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2004" rel="nofollow">2004</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2003" rel="nofollow">2003</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2002" rel="nofollow">2002</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2001" rel="nofollow">2001</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=2000" rel="nofollow">2000</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1999" rel="nofollow">1999</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1998" rel="nofollow">1998</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1997" rel="nofollow">1997</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1996" rel="nofollow">1996</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1995" rel="nofollow">1995</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1994" rel="nofollow">1994</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1993" rel="nofollow">1993</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;year=1992" rel="nofollow">1992</a>
</li>
</ul>
</div>
</div>
<div class="side-nav-section">
<div class="side-nav-section-heading">Select Make
<div class="side-nav-close"></div>
</div>
<ul class="side-nav-section-content">
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;make=Dodge" rel="nofollow">Dodge</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;make=Jeep" rel="nofollow">Jeep</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;make=Lexus" rel="nofollow">Lexus</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;make=Toyota" rel="nofollow">Toyota</a>
</li>
</ul>
</div>
<div class="side-nav-section">
<div class="side-nav-section-heading">Select Part
<div class="side-nav-close"></div>
</div>
<ul class="side-nav-section-content">
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;partname=Brake+Hose" rel="nofollow">Brake Hose</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;partname=Shock+Bump+Stop" rel="nofollow">Shock Bump Stop</a>
</li>
</ul>
</div>
<div class="side-nav-section">
<div class="side-nav-section-heading">Select Category
<div class="side-nav-close"></div>
</div>
<ul class="side-nav-section-content">
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;category=Brake" rel="nofollow">Brake</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;category=Suspension" rel="nofollow">Suspension</a>
</li>
</ul>
</div>
<div class="side-nav-section">
<div class="side-nav-section-heading">Select Brand
<div class="side-nav-close"></div>
</div>
<ul class="side-nav-section-content">
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;brand=Dorman" rel="nofollow">Dorman</a>
</li>
<li>
<a href="https://www.partsgeek.com/ss/?ssq=2203710&amp;brand=Sunsong" rel="nofollow">Sunsong</a>
</li>
</ul>
</div>
</div>
<div class="catalog-main-container js-stickybit-parent">
<div id="sticky_change" class=" js-is-sticky js-is-sticky--change" style="position: sticky; top: 0px;">
<div class="catalog-change-container">
<button id="change_part" type="submit" aria-label="submit" class="btn btn-primary catalog-change-part"><i class="pgfont-left-open"></i>Change Filters
</button>
<button type="submit" aria-label="submit" class="btn btn-primary catalog-change-vehicle mm-modal">Change Vehicle</button>
</div>
<div class="catalog-filters">
<span class="catalog-filters-product-count">
Showing 1 to 8 of 8 Products </span>
</div>
</div>
<div class="products-container">
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Sunsong logo" src="https://www.partsgeek.com/assets/logos/sunsong.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="1992-2001 Toyota Camry Brake Hose - Rear Left - Sunsong 2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" data-menu-off="1" src="https://www.partsgeek.com/assets/dimage/thumbn/1574414.jpg?9f53c">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_1" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_1" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
 </div>
<button class="review-close btn btn-link" data-boxid="bb_1" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">1992-2001 Toyota Camry</span> Brake Hose - Rear Left - Sunsong 2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> 2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Sunsong</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> Brake Hydraulic Hose</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Rear Left</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="8922954">
<input type="hidden" name="app_id" value="594122">
<input type="hidden" name="alt_sku" value="2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="7948-07402831">
<div class="product-offer">
<span class="product-price product-price-pad">
<span>$</span>12.72 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="1992">1992</option>
<option value="1993">1993</option>
<option value="1994">1994</option>
<option value="1995">1995</option>
<option value="1996">1996</option>
<option value="1997">1997</option>
<option value="1998">1998</option>
<option value="1999">1999</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>T</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Brake</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>1992-1996 Toyota Camry </td>
<td class="application-content">Rear: Disc</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>T</span>
</div>
</div>
<div class="applications-notes">
<div class="application-note">
<span>Notes:</span>
USA Built </div>
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Brake</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>1997-2001 Toyota Camry </td>
<td class="application-content">Rear: Disc</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Sunsong logo" src="https://www.partsgeek.com/assets/logos/sunsong.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="1999-2003 Lexus RX300 Brake Hose - Rear Left - Sunsong 2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" data-menu-off="1" src="https://www.partsgeek.com/assets/dimage/thumbn/1574414.jpg?9f53c">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_2" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_2" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_2" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">1999-2003 Lexus RX300</span> Brake Hose - Rear Left - Sunsong 2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> 2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Sunsong</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> Brake Hydraulic Hose</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Rear Left</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="8922954">
<input type="hidden" name="app_id" value="206884">
<input type="hidden" name="alt_sku" value="2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="7878-07402831">
<div class="product-offer">
<span class="product-price product-price-pad">
<span>$</span>12.72 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="1999">1999</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
<option value="2002">2002</option>
<option value="2003">2003</option>
</select>
</div>
 <button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>T</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Sub Model</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>1999-2003 Lexus RX300 </td>
<td class="application-content">FWD</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Sunsong logo" src="https://www.partsgeek.com/assets/logos/sunsong.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="1995-2004 Toyota Avalon Brake Hose - Rear Left - Sunsong 2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" data-menu-off="1" src="https://www.partsgeek.com/assets/dimage/thumbn/1574414.jpg?9f53c">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_3" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_3" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_3" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">1995-2004 Toyota Avalon</span> Brake Hose - Rear Left - Sunsong 2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> 2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Sunsong</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> Brake Hydraulic Hose</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Rear Left</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="8922954">
<input type="hidden" name="app_id" value="5224">
<input type="hidden" name="alt_sku" value="2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="7930-07402831">
<div class="product-offer">
<span class="product-price product-price-pad">
<span>$</span>12.72 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="1995">1995</option>
<option value="1996">1996</option>
<option value="1997">1997</option>
<option value="1998">1998</option>
<option value="1999">1999</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
<option value="2002">2002</option>
<option value="2003">2003</option>
<option value="2004">2004</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>T</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>1995-2004 Toyota Avalon </td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Sunsong logo" src="https://www.partsgeek.com/assets/logos/sunsong.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="1999-2003 Toyota Solara Brake Hose - Rear Left - Sunsong 2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" data-menu-off="1" src="https://www.partsgeek.com/assets/dimage/thumbn/1574414.jpg?9f53c">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/dimage/full/1574414.jpg?9f53c" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_4" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_4" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_4" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">1999-2003 Toyota Solara</span> Brake Hose - Rear Left - Sunsong 2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> 2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Sunsong</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> Brake Hydraulic Hose</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Rear Left</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="8922954">
<input type="hidden" name="app_id" value="5267">
<input type="hidden" name="alt_sku" value="2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="8134-07402831">
<div class="product-offer">
<span class="product-price product-price-pad">
 <span>$</span>12.72 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="1999">1999</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
<option value="2002">2002</option>
<option value="2003">2003</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>T</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>1999-2003 Toyota Solara </td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Dorman logo" src="https://www.partsgeek.com/assets/rep/logo/dorman.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="2000-2001 Dodge Ram 1500 Shock Bump Stop - Front - Dorman W0133-2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" data-menu-off="1" src="https://www.partsgeek.com/assets/rep/thumbn/1335646.jpg?">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_5" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_5" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_5" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">2000-2001 Dodge Ram 1500</span> Shock Bump Stop - Front - Dorman W0133-2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> W0133-2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Dorman</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> OE Solutions -- Independent Suspension</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Front</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground, Overnight, 2 Day</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="1317937">
<input type="hidden" name="app_id" value="124895">
<input type="hidden" name="alt_sku" value="W0133-2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="1970-01492348">
<div>List Price:</div><span aria-label="list price" class="product-strike">$37.27</span>
<div class="product-offer">
Our Price: <span class="product-price">
<span>$</span>33.58 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>A</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Sub Model</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>2001 Dodge Ram 1500 </td>
<td class="application-content">SLT RWD</td>
</tr>
<tr>
<td class="application-content">
<span class="bb_g"></span>2000-2001 Dodge Ram 1500 </td>
<td class="application-content">Laramie RWD</td>
</tr>
<tr>
<td class="application-content">
<span class="bb_g"></span>2000-2001 Dodge Ram 1500 </td>
<td class="application-content">Sport RWD</td>
</tr>
<tr>
<td class="application-content">
<span class="bb_g"></span>2000-2001 Dodge Ram 1500 </td>
<td class="application-content">ST RWD</td>
</tr>
<tr>
<td class="application-content">
<span class="bb_g"></span>2000-2001 Dodge Ram 1500 </td>
<td class="application-content">WS</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Dorman logo" src="https://www.partsgeek.com/assets/rep/logo/dorman.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="2000-2002 Dodge Ram 2500 Shock Bump Stop - Front - Dorman W0133-2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" data-menu-off="1" src="https://www.partsgeek.com/assets/rep/thumbn/1335646.jpg?">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_6" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_6" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_6" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">2000-2002 Dodge Ram 2500</span> Shock Bump Stop - Front - Dorman W0133-2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> W0133-2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Dorman</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> OE Solutions -- Independent Suspension</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Front</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground, Overnight, 2 Day</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="1317937">
<input type="hidden" name="app_id" value="24143">
<input type="hidden" name="alt_sku" value="W0133-2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="1985-01492348">
<div>List Price:</div><span aria-label="list price" class="product-strike">$37.27</span>
<div class="product-offer">
Our Price: <span class="product-price">
<span>$</span>33.58 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
<option value="2002">2002</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>A</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Sub Model</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>2000-2002 Dodge Ram 2500 </td>
<td class="application-content">RWD</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Dorman logo" src="https://www.partsgeek.com/assets/rep/logo/dorman.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="2000-2002 Dodge Ram 3500 Shock Bump Stop - Front - Dorman W0133-2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" data-menu-off="1" src="https://www.partsgeek.com/assets/rep/thumbn/1335646.jpg?">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_7" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_7" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_7" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">2000-2002 Dodge Ram 3500</span> Shock Bump Stop - Front - Dorman W0133-2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> W0133-2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Dorman</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> OE Solutions -- Independent Suspension</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Position:</span> <span class="product-attribute-content">Front</span></div>
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground, Overnight, 2 Day</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="1317937">
<input type="hidden" name="app_id" value="17139">
<input type="hidden" name="alt_sku" value="W0133-2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="2000-01492348">
<div>List Price:</div><span aria-label="list price" class="product-strike">$37.27</span>
<div class="product-offer">
Our Price: <span class="product-price">
<span>$</span>33.58 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
<option value="2002">2002</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>A</span>
</div>
</div>
<div class="applications-notes">
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
<th class="application-heading">Sub Model</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>2000-2002 Dodge Ram 3500 </td>
<td class="application-content">RWD</td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
<div class="product dp-product">
<div class="product-image-container">
<img class="product-logo" alt="Dorman logo" src="https://www.partsgeek.com/assets/rep/logo/dorman.gif" border="0">
<div class="product-images">
<div class="product-image">
<img loading="auto" alt="2000-2006 Jeep Wrangler Shock Bump Stop - Dorman W0133-2203710" tabindex="0" class="pg-image-popover pointer" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" data-menu-off="1" src="https://www.partsgeek.com/assets/rep/thumbn/1335646.jpg?">
<span class="pg-image-popover bb_jlink" data-image="https://www.partsgeek.com/assets/rep/full/1335646.jpg?" tabindex="0" data-menu-off="1">Click to Enlarge</span>
</div>
</div>
<div>
<div class="r_starc r_star_"></div>
<button class="btn btn-link review_link" data-reviewid="bb_8" data-reviewl="ac=grs" role="link" tabindex="0">
(Read Reviews)
</button>
</div>
<div id="bb_8" class="review-contain">
<div class="review-box">
<div class="review-heading">
<div class="review-title">
Website Reviews
</div>
<button class="review-close btn btn-link" data-boxid="bb_8" role="link" tabindex="0"><i class="pgfont-cancel-circled"></i></button>
</div>
<div class="review-line"></div>
<div class="review-content">
<div class="content">Loading Reviews...</div>
</div>
</div>
</div> </div>
<div class="product-info-container">
<div class="product-title">
<span class="product-title-red">2000-2006 Jeep Wrangler</span> Shock Bump Stop - Dorman W0133-2203710 </div> <div class="product-info">
<div><span class="product-attribute-heading">Part Number:</span> W0133-2203710</div>
<div><span class="product-attribute-heading">Brand:</span> Dorman</div>
<div class="product-notes">
<div><span class="product-attribute-heading">Notes:</span> OE Solutions</div>
</div>
<div class="product-attributes">
<div><span class="product-attribute-heading">Condition:</span> <span class="product-attribute-content">New</span></div>
<div>
<span class="product-attribute-heading">Shipping Options: </span>
<span class="product-attribute-content">Ground, Overnight, 2 Day</span>
</div>
</div>
<div class="product-attributes-red-bold">
</div>
</div> <div class="product-add-cart">
<form class="product-form" name="add_cart" method="post" action="https://www.partsgeek.com/cart/add/" data-check-cart-year="true">
<input type="hidden" name="prod_id" value="1226149">
<input type="hidden" name="app_id" value="8394">
<input type="hidden" name="alt_sku" value="W0133-2203710">
<input type="hidden" name="item_list_id" value="sitesearch">
<input type="hidden" name="item_list_name" value="SiteSearch">
<input type="hidden" name="part_number" value="2324-01492348">
<div>List Price:</div><span aria-label="list price" class="product-strike">$37.27</span>
<div class="product-offer">
Our Price: <span class="product-price">
<span>$</span>33.58 </span>
<div style="height:1px; line-height:1px; background-color:gray;"></div>
</div>
<div class="product-qty-container">
<label for="product-qty-0">Quantity:</label>
<input type="text" value="1" name="quantity" class="form-control product-qty" id="product-qty-0">
</div>
<div align="center" class="product-year-select marb5 mart10">
<select aria-label="select your year" class="form-select form-select-sm" name="year">
<option value="">Select Year</option>
<option value="2000">2000</option>
<option value="2001">2001</option>
 <option value="2002">2002</option>
<option value="2003">2003</option>
<option value="2004">2004</option>
<option value="2005">2005</option>
<option value="2006">2006</option>
</select>
</div>
<button type="submit" aria-label="submit" class="btn btn-danger btn-sm add-cart-btn">Add to Cart</button>
<div class="product-stock">
(2) In Stock </div>
</form>
</div> </div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>A</span>
</div>
</div>
<div class="applications-notes">
<div class="application-note">
<span>Position:</span>
Front </div>
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>2000-2006 Jeep Wrangler </td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
<div class="fitment-container">
<div class="fitment-heading">
<div><i class="pgfont-play"></i> This Part Fits:</div>
<div class="product-catalog">
Catalog: <span>A</span>
</div>
</div>
<div class="applications-notes">
<div class="application-note">
<span>Position:</span>
Rear </div>
</div>
<div class="applications-container">
<table>
<thead>
<tr>
<th class="application-heading">Vehicle</th>
</tr>
</thead>
<tbody><tr>
<td class="application-content">
<span class="bb_g"></span>2000-2006 Jeep Wrangler </td>
</tr>
</tbody></table>
<button class="btn btn-sm btn-secondary"><i class="pgfont-down-open"></i><span>Show More</span><i class="pgfont-down-open"></i></button>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</main>
<footer class="footer">
<div class="popular-searches-container">
<div class="popular-searches">
<strong>Popular Parts:</strong>
<ul>
<li><a href="https://www.partsgeek.com/parts/brake_pads.html">Brake Pads</a></li>
<li><a href="https://www.partsgeek.com/parts/brake_rotors.html">Brake Rotors</a></li>
<li><a href="https://www.partsgeek.com/parts/clutch.html">Clutch</a></li>
<li><a href="https://www.partsgeek.com/parts/control_arm.html">Control Arm</a></li>
<li><a href="https://www.partsgeek.com/parts/fuel_pump.html">Fuel Pump</a></li>
<li><a href="https://www.partsgeek.com/parts/headlight.html">Headlights</a></li>
<li><a href="https://www.partsgeek.com/parts/mirror.html">Mirror</a></li>
<li><a href="https://www.partsgeek.com/parts/muffler.html">Muffler</a></li>
<li><a href="https://www.partsgeek.com/parts/radiator.html">Radiator</a></li>
<li><a href="https://www.partsgeek.com/parts/struts.html">Struts</a></li>
<li><a href="https://www.partsgeek.com/parts/tail_light.html">Tail Lights</a></li>
<li><a href="https://www.partsgeek.com/parts/wheel.html">Wheel</a></li>
<li><a href="https://www.partsgeek.com/parts/wheel_hub.html">Wheel Bearing</a></li>
</ul>
</div>
</div>
<div class="email-signup">
<div class="signup-tagline">Email Special Offers</div>
<div class="signup-info">Be the first to receive exclusive coupons, updates, and product announcements. Join our mailing list now!</div>
<form aria-label="email sign up form" class="signup-form" name="ccoptin" action="https://visitor.constantcontact.com/d.jsp" target="_blank" method="post">
<input type="hidden" name="m" value="1102238942666">
<input type="hidden" name="p" value="oi">
<div class="input-group">
<input class="form-control" type="email" aria-label="email address" id="ea" name="ea" value="" placeholder="Email Address" required="">
<button class="btn btn-warning" aria-label="sign up (opens in new tab)">Sign Up</button>
</div>
</form>
</div>
<nav class="footer-nav" aria-label="footer">
<div class="footer-nav-column">
<div aria-label="browse">Browse</div>
<ul>
<li><a href="https://www.partsgeek.com/">Home</a></li>
<li><a href="https://www.partsgeek.com/cart/">View Cart</a></li>
<li><a href="https://www.partsgeek.com/catalog/">Catalog</a></li>
<li><a href="https://www.partsgeek.com/articles.html">Articles</a></li>
</ul>
</div>
<div class="footer-nav-column">
<div aria-label="browse">Help</div>
<ul>
<li><a href="https://www.partsgeek.com/aboutus.html">Track Order</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html">Contact Us</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html">About Us</a></li>
<li><a href="https://www.partsgeek.com/cart/quote/">Retrieve Quote</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html#return-policy">Return Policy</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html#cancellation-policy">Cancellation Policy</a></li>
</ul>
</div>
<div class="footer-nav-column">
<div aria-label="browse">Privacy &amp; Terms</div>
<ul>
<li><a href="https://www.partsgeek.com/legal-notice.html">Legal Notice</a></li>
<li><a href="https://www.partsgeek.com/terms-and-conditions.html">Terms of Service</a></li>
<li><a href="https://www.partsgeek.com/privacy_policy.html">Privacy Policy</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html#shipping-policy">Shipping Policy</a></li>
<li><a href="https://www.partsgeek.com/aboutus.html#delivery-policy">Delivery Policy</a></li>
<li><a href="https://www.partsgeek.com/prohibited-restricted-items.html">Regulatory Compliance</a></li>
</ul>
</div>
<div class="footer-nav-column">
<div aria-label="browse">Resources</div>
<ul>
<li><a href="https://www.partsgeek.com/affliates.html">Affliate Program</a></li>
 <li><a href="https://www.partsgeek.com/makes/replacement_auto_parts.html">Shop By Make</a></li>
<li><a href="https://www.partsgeek.com/models/">Models</a></li>
<li><a href="https://www.partsgeek.com/brands/">Brands</a></li>
</ul>
</div>
<div class="footer-nav-column">
<div aria-label="browse">Security</div>
<ul>
<li>
<img loading="lazy" tabindex="0" id="trustwaveSealImage" width="105" height="54" src="https://www.partsgeek.com/images/seal_image.png" border="0" style="cursor:pointer;" onclick="javascript:window.open('https://sealserver.trustwave.com/cert.php?customerId=w6otlmrNftNVByuB1cfZ1SvaOTL8Ww&amp;size=105x54&amp;style=invert', 'c_TW', 'location=no, toolbar=no, resizable=yes, scrollbars=yes, directories=no, status=no, width=615, height=720'); return false;" oncontextmenu="javascript:alert('Copying Prohibited by Law - Trusted Commerce is a Service Mark of TrustWave Holdings, Inc.'); return false;" alt="This site protected by Trustwave's Trusted Commerce program" title="This site protected by Trustwave's Trusted Commerce program">
</li>
</ul>
</div>
<div class="footer-nav-column">
<div aria-label="browse">Reviews</div>
<ul>
<li>
<a class="br-button" href="//bizratesurveys.com/reviews/detail/www.partsgeek.com/192248?utm_source=merchant_page&amp;utm_medium=customer_certified_medal&amp;utm_content=medal_image" title="See PartsGeek.com Reviews and Ratings" target="_blank" aria-label="See PartsGeek.com Reviews and Ratings at Bizrate (opens in a new tab)" rel="noopener">
<img loading="lazy" src="//medals.bizrate.com/medals/dynamic/small/192248_medal.gif" width="112" height="37" border="0" alt="See PartsGeek.com Reviews and Ratings">
</a>
</li>
</ul>
</div>
</nav>
<div class="footer-bottom">
<div class="footer-cards">
<i class="pgfont-cc-paypal"></i>
<i class="pgfont-cc-visa"></i>
<i class="pgfont-cc-mastercard"></i>
<i class="pgfont-cc-discover"></i>
<i class="pgfont-cc-amex"></i>
</div>
<div class="footer-social">
<a href="https://facebook.com/autopartsgeek/" rel="noopener" target="_blank" aria-label="partsgeek facebook page (opens in a new tab)">
<svg aria-label="facebook icon" viewBox="0 35 512 512"><path d="M355.6 330l11.4-74h-71v-48c0-20.2 9.9-40 41.7-40H370v-63s-29.3-5-57.3-5c-58.5 0-96.7 35.4-96.7 99.6V256h-65v74h65v182h80V330h59.6z"></path></svg>
</a>
<a href="https://twitter.com/partsgeek" rel="noopener" target="_blank" aria-label="partsgeek twitter page (opens in a new tab)">
<svg aria-label="twitter icon" viewBox="50 50 400 400"><path d="M437 152a72 72 0 01-40 12a72 72 0 0032-40a72 72 0 01-45 17a72 72 0 00-122 65a200 200 0 01-145-74a72 72 0 0022 94a72 72 0 01-32-7a72 72 0 0056 69a72 72 0 01-32 1a72 72 0 0067 50a200 200 0 01-105 29a200 200 0 00309-179a200 200 0 0035-37"></path></svg>
</a>
</div>
<div class="footer-copy">© Copyright 2023 PartsGeek®</div>
<div class="footer-tagline">Providing discount auto parts online since 2008</div>
<div class="footer-phone">Order at <a aria-label="call us to order at 1-800-541-9352" href="tel:+1-800-541-9352">1-800-541-9352</a></div>
</div>
</footer>
</div>
<script>
    var vehicleSelector = {"year":"","make":"","model":"","search":""}</script>
<div id="scroll-top" style="display: block;">
<button class="btn" aria-label="scroll to top of the page"><i class="pgfont-up-open"></i></button>
</div><script defer="" src="https://static.cloudflareinsights.com/beacon.min.js/vaafb692b2aea4879b33c060e79fe94621666317369993" integrity="sha512-0ahDYl866UMhKuYcW078ScMalXqtFJggm7TmlUtp0UlD4eQk0Ixfnm5ykXKvGJNFjLMoortdseTfsRT8oCfgGA==" data-cf-beacon="{&quot;rayId&quot;:&quot;78941eb649941111&quot;,&quot;token&quot;:&quot;df6fc871b9bc45fbad9abd1837a887c0&quot;,&quot;version&quot;:&quot;2022.11.3&quot;,&quot;si&quot;:100}" crossorigin="anonymous"></script>

<script type="text/javascript" id="">function getParameterByName(a){a=a.replace(/\[]/,"\\[").replace(/[\]]/,"\\]");a=new RegExp("[\\?\x26]"+a+"\x3d([^\x26#]*)");a=a.exec(location.search);return null===a?"":decodeURIComponent(a[1].replace(/\+/g," "))}var cjeventid=getParameterByName("cjevent"),expiryDate=new Date,month=(expiryDate.getMonth()+1)%12,year=expiryDate.getFullYear()+1;expiryDate.setFullYear(year);expiryDate.setMonth(month);cjeventid&&(document.cookie="cje\x3d"+cjeventid+"; expires\x3d"+expiryDate.toGMTString()+"; secure");</script>
<script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","386264895475857");fbq("track","PageView");</script>
<noscript>
<img height="1" width="1" src="https://www.facebook.com/tr?id=386264895475857&amp;ev=PageView
&amp;noscript=1">
</noscript>
<script type="text/javascript" id="">window.cnxDataLayer=[];function cnxtag(){cnxDataLayer.push(arguments)};</script>
<script type="text/javascript" id="" src="https://js.cnnx.link/roi/cnxtag-min.js?id=192248"></script>
<script type="text/javascript" id="">window.__lc=window.__lc||{};window.__lc.license=13149207;
(function(e,f,c){function d(a){return b._h?b._h.apply(null,a):b._q.push(a)}var b={_q:[],_h:null,_v:"2.0",on:function(){d(["on",c.call(arguments)])},once:function(){d(["once",c.call(arguments)])},off:function(){d(["off",c.call(arguments)])},get:function(){if(!b._h)throw Error("[LiveChatWidget] You can't use getters before load.");return d(["get",c.call(arguments)])},call:function(){d(["call",c.call(arguments)])},init:function(){var a=f.createElement("script");a.async=!0;a.type="text/javascript";a.src=
"https://cdn.livechatinc.com/tracking.js";f.head.appendChild(a)}};!e.__lc.asyncInit&&b.init();e.LiveChatWidget=e.LiveChatWidget||b})(window,document,[].slice);</script>
<noscript><a href="https://www.livechatinc.com/chat-with/13149207/" rel="nofollow">Chat with us</a>, powered by <a href="https://www.livechatinc.com/?welcome" rel="noopener nofollow" target="_blank">LiveChat</a></noscript>

<script type="text/javascript" id="">cnxtag("event","pageview",{product_ids:google_tag_manager["GTM-WSTV37R"].macro(9),category_id:google_tag_manager["GTM-WSTV37R"].macro(10),category_name:google_tag_manager["GTM-WSTV37R"].macro(11)});</script><div style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon285255251493"><img style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon490900916889" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=5213803&amp;tm=gtm002&amp;Ver=2&amp;mid=a685822f-3f5a-4e73-971a-4b874e83e67a&amp;sid=ac50c52093b811ed8b455b8b2eadea7b&amp;vid=ac50f2b093b811ed85af2b6283597bf7&amp;vids=0&amp;msclkid=N&amp;uach=pv%3D10.0.0&amp;pi=918639831&amp;lg=zh-CN&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=2203710%20%7C%20Partsgeek.com&amp;kw=auto%20parts&amp;p=https%3A%2F%2Fwww.partsgeek.com%2Fss%2F%3Fi%3D1%26ssq%3D2203710&amp;r=https%3A%2F%2Fwww.partsgeek.com%2Fss%2F%3Fi%3D1%26ssq%3D2203710&amp;lt=774&amp;evt=pageLoad&amp;sv=1&amp;rn=221678"></div><div id="chat-widget-container" style="opacity: 1; visibility: visible; z-index: 2147483639; position: fixed; bottom: 0px; width: 281px; height: 63px; max-width: 100%; max-height: calc(100% - 0px); min-height: 0px; min-width: 0px; background-color: transparent; border: 0px; overflow: hidden; left: 15px; transition: none 0s ease 0s !important;"><iframe allow="autoplay; microphone *; camera *; display-capture *; picture-in-picture *; fullscreen *;" src="https://secure.livechatinc.com/customer/action/open_chat?license_id=13149207&amp;group=0&amp;embedded=1&amp;widget_version=3&amp;unique_groups=0" allowtransparency="true" id="chat-widget" name="chat-widget" title="LiveChat chat widget" scrolling="no" style="width: 100%; height: 100%; min-height: 0px; min-width: 0px; margin: 0px; padding: 0px; background-image: none; background-position: 0% 0%; background-size: initial; background-attachment: scroll; background-origin: initial; background-clip: initial; background-color: rgba(0, 0, 0, 0); border-width: 0px; float: none; color-scheme: normal; position: absolute; inset: 0px; transition: none 0s ease 0s !important; display: none;"></iframe><iframe allowtransparency="true" id="chat-widget-minimized" name="chat-widget-minimized" title="LiveChat chat widget" scrolling="no" style="width: 100%; height: 100%; min-height: 0px; min-width: 0px; margin: 0px; padding: 0px; background-image: none; background-position: 0% 0%; background-size: initial; background-attachment: scroll; background-origin: initial; background-clip: initial; background-color: rgba(0, 0, 0, 0); border-width: 0px; float: none; color-scheme: normal; display: block;"></iframe></div></body></html>
'''

# %%
from bs4 import BeautifulSoup

# %%
page = BeautifulSoup(html)

auto = False
if auto:
    list_vehicle = []
    for div in page.find_all('div', attrs={'class': 'applications-container'}):
        for tr in div.find('tbody').find_all('tr'):
            list_vehicle.append(tr.find_all('td')[0].text.strip())
    print('vehicle:')
    for vehicle in list_vehicle:
        print(vehicle)
    print('\n= = = = = = = = = = = = = = = = = =\n')
    print('vehicle:')
    print('\'' + list_vehicle[0] + '\',')
    for vehicle in list_vehicle[1:-1]:
        print('                    \'' + vehicle + '\',')
    print('                    \'' + list_vehicle[-1] + '\'')
else:
    list_vehicle = ['1992-1996 Toyota Camry',
                    '1997-2001 Toyota Camry',
                    '1999-2003 Lexus RX300',
                    '1995-2004 Toyota Avalon',
                    '1999-2003 Toyota Solara']
    print('vehicle:')
    for vehicle in list_vehicle:
        print(vehicle)
# Out:
# vehicle:
# 1992-1996 Toyota Camry
# 1997-2001 Toyota Camry
# 1999-2003 Lexus RX300
# 1995-2004 Toyota Avalon
# 1999-2003 Toyota Solara

# %%
list_make = []
for vehicle in list_vehicle:
    list_make.append(vehicle.split(' ')[1])

list_make = list(set(list_make))
list_make.sort()

print('make: ' + str(list_make))
# Out:
# make: ['Lexus', 'Toyota']

# %%
dict_vehicle = {}
for make in list_make:
    dict_vehicle[make] = {}

for vehicle in list_vehicle:
    for make in list_make:
        if make in vehicle:
            list_str = vehicle.split(' ' + make + ' ')
            model = list_str[1]
            year = list_str[0]
            if model in dict_vehicle[make]:
                dict_vehicle[make][model].append(year)
            else:
                dict_vehicle[make][model] = [year]

# %%
import pyperclip

# %%
list_vehicle = []
for vehicle in dict_vehicle:
    for model in dict_vehicle[vehicle]:
        list_vehicle.append(vehicle + ',' + model + ',' + ';'.join(dict_vehicle[vehicle][model]))

list_vehicle.sort()

vehicle = '\n'.join([i.replace(',', ' ') for i in list_vehicle])
print(vehicle)
pyperclip.copy(vehicle)
# Out:
# Lexus RX300 1999-2003
# Toyota Avalon 1995-2004
# Toyota Camry 1992-1996;1997-2001
# Toyota Solara 1999-2003
