# %%
param_date = '20240623'

# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel(f'./{param_date}/part.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_.drop_duplicates(['JOIN_PTPKPNCN'], keep='first', ignore_index=True)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'
        for b in range(666):
            try:
                resp = requests.get(input_.loc[a, 'Info'],
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text

                # = = = = = = = = = = = = = = =

                soup = BeautifulSoup(resp, 'lxml')
                html = etree.HTML(str(soup))

                # = = = = = = = = = = = = = = =

                if html.xpath('//span[@class="la-btn-v"]/text()')[0].strip() != 'Continue Shopping':
                    continue

                # = = = = = = = = = = = = = = =

                list_tr = html.xpath('//table[@class="moreinfotable"]/tr')

                # = = = = = = = = = = = = = = =

                dict_specification = {}
                for i in range(len(list_tr)):
                    if i == 0:
                        continue

                    list_td = [td.strip() for td in list_tr[i].xpath('./td/text()')]
                    if len(list_td) == 1:
                        dict_specification[str(i-1)] = list_td[0].strip()
                    elif len(list_td) == 2:
                        dict_specification[str(i-1)] = {list_td[0].strip(): list_td[1].strip()}
                    else:
                        break

                json_specification = json.dumps(dict_specification)

                # = = = = = = = = = = = = = = =

                list_tr = html.xpath('//section[contains(@aria-label, "Components") and contains(@aria-label, "kit")]/table/tbody/tr/td/table/tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-b-1") or (contains(@class, "altrow-b-0")))]/tr')

                # = = = = = = = = = = = = = = =

                dict_kit = {}
                for i in range(len(list_tr)):
                    dict_kit[str(i)] = {}

                    list_td = list_tr[i].xpath('./td')
                    dict_kit[str(i)]['quantity'] = list_td[0].xpath('./text()')[0].strip()
                    dict_kit[str(i)]['component_tag'] = list_td[1].xpath('./text()')[0].strip()

                    json_ = json.loads(list_td[2].xpath('./@value')[0])
                    dict_kit[str(i)]['parttype'] = json_['parttype'].strip()
                    dict_kit[str(i)]['partkey'] = json_['partkey'].strip()

                    json_ = json.loads(list_tr[i].xpath('./input[contains(@id, "listing_data_supplemental[")]/@value')[0])
                    dict_kit[str(i)]['partnumber'] = json_['partnumber'].strip()
                    dict_kit[str(i)]['catalogname'] = json_['catalogname'].strip()

                    dict_kit[str(i)]['url'] = f'''https://www.rockauto.com/en/parts/{dict_kit[str(i)]['partkey']},{dict_kit[str(i)]['partnumber']},{dict_kit[str(i)]['component_tag']},{dict_kit[str(i)]['parttype']}'''

                    a_ = list_tr[i].xpath('./div[@class="listing-text-row-moreinfo-truck"]/a/@href')
                    dict_kit[str(i)]['info'] =  f'''https://www.rockauto.com/en/moreinfo.php?pk={dict_kit[str(i)]['catalogname']}&pt={dict_kit[str(i)]['parttype']}&Lennon=1''' if len(a_) == 0 else a_[0].strip()

                    list_src = [] if len(list_td[3].xpath('./div/input/@value')) == 0 else json.loads(list_td[3].xpath('./div/input/@value')[0])['Slots']
                    dict_src = {}
                    for j in range(len(list_src)):
                        dict_src[str(j)] = 'https://www.rockauto.com' + list_src[j]['ImageData']['Full'].strip()
                    dict_kit[str(i)]['json_src'] = json.dumps(dict_src)

                json_kit = json.dumps(dict_kit)

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                                         'Json_Specification': json_specification,
                                         'Json_Kit': json_kit,
                                         'Info': input_.loc[a, 'Info']}])

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'

                # = = = = = = = = = = = = = = =

                break
            except:
                continue

        # = = = = = = = = = = = = = = =

        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                                     'Info': input_.loc[a, 'Info']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        print(f'''[状态：{crawler_status}，尝试次数：{b+1:3d}] - {input_.loc[a, 'JOIN_PTPKPNCN']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(15):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if len(output_correct) != 0:
    output_correct = output_correct.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_correct.to_excel(f'''./{param_date}/info-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if len(output_error) != 0:
    output_error = output_error.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_error.to_excel(f'./{param_date}/info_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：24720
#
# [状态：ok，尝试次数：  1] - 256;14919165;T3;ROCKAUTO
# [剩余数量：24705] - [当前时间：15:41:46]
#
# [状态：ok，尝试次数：  1] - 256;14922125;T4;ROCKAUTO
# [剩余数量：24704] - [当前时间：15:41:46]
#
# [状态：ok，尝试次数：  1] - 256;15521065;T3C;ROCKAUTO
# [剩余数量：24703] - [当前时间：15:41:46]
#
# [状态：ok，尝试次数：  1] - 1002098;15104209;H2;ROCKAUTO
# [剩余数量：24702] - [当前时间：15:41:47]
#
# [状态：ok，尝试次数：  1] - 131;15108557;B1;ROCKAUTO
# [剩余数量：24701] - [当前时间：15:41:47]
#
# [状态：ok，尝试次数：  1] - 131;10671829;BLACKHAT;ROCKAUTO
# [剩余数量：24700] - [当前时间：15:41:47]
#
# [状态：ok，尝试次数：  2] - 131;15108565;B3;ROCKAUTO
# [剩余数量：24699] - [当前时间：15:41:48]
#
# [状态：ok，尝试次数：  1] - 260;1285405;GIFTCERTVAR;ROCKAUTO
# [剩余数量：24698] - [当前时间：15:41:48]
#
# [状态：ok，尝试次数：  1] - 260;368849;GIFTCERT25;ROCKAUTO
# [剩余数量：24697] - [当前时间：15:41:48]
#
# [状态：ok，尝试次数：  1] - 256;15001073;T6;ROCKAUTO
# [剩余数量：24696] - [当前时间：15:41:49]
#
# [状态：ok，尝试次数：  3] - 256;15138773;T9;ROCKAUTO
# [剩余数量：24695] - [当前时间：15:41:50]
#
# [状态：ok，尝试次数：  2] - 256;15138781;T11;ROCKAUTO
# [剩余数量：24694] - [当前时间：15:41:50]
#
# [状态：ok，尝试次数：  3] - 256;15521069;T3R;ROCKAUTO
# [剩余数量：24693] - [当前时间：15:41:50]
#
# [状态：ok，尝试次数：  3] - 256;15138765;T7;ROCKAUTO
# [剩余数量：24692] - [当前时间：15:41:51]
#
# [状态：ok，尝试次数：  1] - 131;15108561;B2;ROCKAUTO
# [剩余数量：24691] - [当前时间：15:41:51]
#
# [状态：ok，尝试次数：  2] - 260;368851;GIFTCERT75;ROCKAUTO
# [剩余数量：24690] - [当前时间：15:41:51]
#
# [状态：ok，尝试次数：  1] - 1001187;2867484;BUMPERDECAL;ROCKAUTO
# [剩余数量：24689] - [当前时间：15:41:51]
#
# [状态：ok，尝试次数：  1] - 1002098;15104205;H1;ROCKAUTO
# [剩余数量：24688] - [当前时间：15:41:53]
#
# [状态：ok，尝试次数：  1] - 1001187;3472857;BUMPERDECAL2;ROCKAUTO
# [剩余数量：24687] - [当前时间：15:41:53]
#
# [状态：ok，尝试次数：  1] - 1001187;4170858;DECALCOMBO3;ROCKAUTO
# [剩余数量：24686] - [当前时间：15:41:53]
#
# [状态：ok，尝试次数：  4] - 256;10512261;T2;ROCKAUTO
# [剩余数量：24685] - [当前时间：15:41:54]
#
# [状态：ok，尝试次数：  2] - 1000000;1272469;MAGPACK;ROCKAUTO
# [剩余数量：24684] - [当前时间：15:41:54]
#
# [状态：ok，尝试次数：  1] - 1001344;12873537;94G3020;GATES
# [剩余数量：24683] - [当前时间：15:41:55]
#
# [状态：ok，尝试次数：  2] - 1001187;3603579;DECALCOMBO2;ROCKAUTO
# [剩余数量：24682] - [当前时间：15:41:55]
#
# [状态：ok，尝试次数：  1] - 1001344;101270;6012;GATES
# [剩余数量：24681] - [当前时间：15:41:55]
#
# [状态：ok，尝试次数：  2] - 1001187;2867487;WINDOWDECAL;ROCKAUTO
# [剩余数量：24680] - [当前时间：15:41:55]
#
# [状态：ok，尝试次数：  2] - 1001191;2961354;LANYARD;ROCKAUTO
# [剩余数量：24679] - [当前时间：15:41:56]
#
# [状态：ok，尝试次数：  1] - 1001344;12873529;93G3499;GATES
# [剩余数量：24678] - [当前时间：15:41:56]
#
# [状态：ok，尝试次数：  2] - 256;9097025;T1;ROCKAUTO
# [剩余数量：24677] - [当前时间：15:41:56]
#
# [状态：ok，尝试次数：  2] - 1001344;12872429;66G3081;GATES
# [剩余数量：24676] - [当前时间：15:41:57]
#
# [状态：ok，尝试次数：  1] - 1001344;101271;6013;GATES
# [剩余数量：24675] - [当前时间：15:41:57]
#
# [状态：ok，尝试次数：  2] - 1001344;12873177;80G2949;GATES
# [剩余数量：24674] - [当前时间：15:41:57]
#
# [状态：ok，尝试次数：  2] - 260;368852;GIFTCERT100;ROCKAUTO
# [剩余数量：24673] - [当前时间：15:41:58]
#
# [状态：ok，尝试次数：  1] - 1001356;4784736;HP2007;DAYCO
# [剩余数量：24672] - [当前时间：15:41:58]
#
# [状态：ok，尝试次数：  1] - 1001344;12873161;71G2776;GATES
# [剩余数量：24671] - [当前时间：15:41:58]
#
# [状态：ok，尝试次数：  1] - 1001356;4776978;27GBS912;CONTINENTAL
# [剩余数量：24670] - [当前时间：15:41:58]
#
# [状态：ok，尝试次数：  1] - 1001521;12871565;01G2748;GATES
# [剩余数量：24669] - [当前时间：15:41:59]
#
# [状态：ok，尝试次数：  1] - 1001187;2867490;DECALCOMBO;ROCKAUTO
# [剩余数量：24668] - [当前时间：15:41:59]
#
# [状态：ok，尝试次数：  6] - 256;14922129;T5;ROCKAUTO
# [剩余数量：24667] - [当前时间：15:41:59]
#
# [状态：ok，尝试次数：  1] - 1001346;4785048;HP2027;DAYCO
# [剩余数量：24666] - [当前时间：15:42:00]
#
# [状态：ok，尝试次数：  1] - 1001346;4784985;HP2000;DAYCO
# [剩余数量：24665] - [当前时间：15:42:00]
#
# [状态：ok，尝试次数：  1] - 1001521;12871569;02G3470;GATES
# [剩余数量：24664] - [当前时间：15:42:00]
#
# [状态：ok，尝试次数：  1] - 1001346;4784919;XTX2243;DAYCO
# [剩余数量：24663] - [当前时间：15:42:01]
#
# [状态：ok，尝试次数：  3] - 1001344;4970703;95G3021;GATES
# [剩余数量：24662] - [当前时间：15:42:01]
#
# [状态：ok，尝试次数：  3] - 1001344;101322;6354;GATES
# [剩余数量：24661] - [当前时间：15:42:01]
#
# [状态：ok，尝试次数：  1] - 1001346;4970298;11C3218;GATES
# [剩余数量：24660] - [当前时间：15:42:02]
#
# [状态：ok，尝试次数：  2] - 1001346;5015469;13G3218;GATES
# [剩余数量：24659] - [当前时间：15:42:02]
#
# [状态：ok，尝试次数：  2] - 1001346;4785003;HP2009;DAYCO
# [剩余数量：24658] - [当前时间：15:42:02]
#
# [状态：ok，尝试次数：  2] - 1001346;4785027;HP2017;DAYCO
# [剩余数量：24657] - [当前时间：15:42:02]
#
# [状态：ok，尝试次数：  1] - 1001352;4785048;HP2027;DAYCO
# [剩余数量：24656] - [当前时间：15:42:03]
#
# [状态：ok，尝试次数：  1] - 1001352;5015538;46G3596;GATES
# [剩余数量：24655] - [当前时间：15:42:04]
#
# [状态：ok，尝试次数：  2] - 1001346;5015466;13C3218;GATES
# [剩余数量：24654] - [当前时间：15:42:04]
#
# [状态：ok，尝试次数：  3] - 1001346;4970373;11G3218;GATES
# [剩余数量：24653] - [当前时间：15:42:05]
#
# [状态：ok，尝试次数：  2] - 1001352;12872305;48G4867;GATES
# [剩余数量：24652] - [当前时间：15:42:05]
#
# [状态：ok，尝试次数：  1] - 1001352;12872293;48C4867;GATES
# [剩余数量：24651] - [当前时间：15:42:05]
#
# [状态：ok，尝试次数：  2] - 1001346;1146263;PL30069;GATES
# [剩余数量：24650] - [当前时间：15:42:05]
#
# [状态：ok，尝试次数：  3] - 1001344;4970697;73G2644;GATES
# [剩余数量：24649] - [当前时间：15:42:06]
#
# [状态：ok，尝试次数：  2] - 1001352;5015472;19C3218;GATES
# [剩余数量：24648] - [当前时间：15:42:06]
#
# [状态：ok，尝试次数：  1] - 1001352;12872325;48R4867;GATES
# [剩余数量：24647] - [当前时间：15:42:06]
#
# [状态：ok，尝试次数：  1] - 1001349;4784997;HP2005;DAYCO
# [剩余数量：24646] - [当前时间：15:42:06]
#
# [状态：ok，尝试次数：  1] - 1001349;12871589;19C3450;GATES
# [剩余数量：24645] - [当前时间：15:42:07]
#
# [状态：ok，尝试次数：  1] - 1001352;4784901;XTX2217;DAYCO
# [剩余数量：24644] - [当前时间：15:42:07]
#
# [状态：ok，尝试次数：  1] - 256;15138777;T10;ROCKAUTO
# [剩余数量：24643] - [当前时间：15:42:07]
#
# [状态：ok，尝试次数：  1] - 1001349;101320;6316;GATES
# [剩余数量：24642] - [当前时间：15:42:07]
#
# [状态：ok，尝试次数：  3] - 1001352;5417868;XTX2255;DAYCO
# [剩余数量：24641] - [当前时间：15:42:07]
#
# [状态：ok，尝试次数：  1] - 1001349;12871621;20G5016;GATES
# [剩余数量：24640] - [当前时间：15:42:08]
#
# [状态：ok，尝试次数：  1] - 1001349;4785051;HP2028;DAYCO
# [剩余数量：24639] - [当前时间：15:42:08]
#
# [状态：ok，尝试次数：  1] - 1001349;4784994;HP2004;DAYCO
# [剩余数量：24638] - [当前时间：15:42:10]
#
# [状态：ok，尝试次数：  4] - 1001521;4970370;03G3470;GATES
# [剩余数量：24637] - [当前时间：15:42:10]
#
# [状态：ok，尝试次数：  2] - 1001349;4784574;32GBS1002;CONTINENTAL
# [剩余数量：24636] - [当前时间：15:42:10]
#
# [状态：ok，尝试次数：  1] - 1001349;4970385;19G3332;GATES
# [剩余数量：24635] - [当前时间：15:42:10]
#
# [状态：ok，尝试次数：  1] - 1001349;4785018;HP2014;DAYCO
# [剩余数量：24634] - [当前时间：15:42:11]
#
# [状态：ok，尝试次数：  3] - 1001349;4784991;HP2003;DAYCO
# [剩余数量：24633] - [当前时间：15:42:12]
#
# [状态：ok，尝试次数：  2] - 1001349;4784793;HPX2204;DAYCO
# [剩余数量：24632] - [当前时间：15:42:12]
#
# [状态：ok，尝试次数：  2] - 1001349;4785024;HP2016;DAYCO
# [剩余数量：24631] - [当前时间：15:42:12]
#
# [状态：ok，尝试次数：  3] - 1001349;101269;6007;GATES
# [剩余数量：24630] - [当前时间：15:42:12]
#
# [状态：ok，尝试次数：  1] - 1001349;4970388;19G3982;GATES
# [剩余数量：24629] - [当前时间：15:42:13]
#
# [状态：ok，尝试次数：  2] - 1001349;4785000;HP2008;DAYCO
# [剩余数量：24628] - [当前时间：15:42:13]
#
# [状态：ok，尝试次数：  1] - 1001349;4785012;HP2012;DAYCO
# [剩余数量：24627] - [当前时间：15:42:13]
#
# [状态：ok，尝试次数：  1] - 1001349;4970301;19C3982;GATES
# [剩余数量：24626] - [当前时间：15:42:13]
#
# [状态：ok，尝试次数：  3] - 1001349;101318;6314;GATES
# [剩余数量：24625] - [当前时间：15:42:14]
#
# [状态：ok，尝试次数：  1] - 1001349;4970397;19G4022;GATES
# [剩余数量：24624] - [当前时间：15:42:14]
#
# [状态：ok，尝试次数：  2] - 1001349;4785039;HP2021;DAYCO
# [剩余数量：24623] - [当前时间：15:42:14]
#
# [状态：ok，尝试次数：  1] - 1001349;4784808;HPX2237;DAYCO
# [剩余数量：24622] - [当前时间：15:42:15]
#
# [状态：ok，尝试次数：  2] - 256;15138769;T8;ROCKAUTO
# [剩余数量：24621] - [当前时间：15:42:15]
#
# [状态：ok，尝试次数：  1] - 1001349;12871601;19R4022;GATES
# [剩余数量：24620] - [当前时间：15:42:16]
#
# [状态：ok，尝试次数：  1] - 1001349;12871597;19R3982;GATES
# [剩余数量：24619] - [当前时间：15:42:16]
#
# [状态：ok，尝试次数：  3] - 1001349;4785009;HP2011;DAYCO
# [剩余数量：24618] - [当前时间：15:42:17]
#
# [状态：ok，尝试次数：  2] - 1001349;4970304;19C4022;GATES
# [剩余数量：24617] - [当前时间：15:42:17]
#
# [状态：ok，尝试次数：  2] - 1001349;4784913;XTX2240;DAYCO
# [剩余数量：24616] - [当前时间：15:42:17]
#
# [状态：ok，尝试次数：  1] - 1001546;4970403;20G4022;GATES
# [剩余数量：24615] - [当前时间：15:42:17]
#
# [状态：ok，尝试次数：  4] - 1001352;4970379;19G3218;GATES
# [剩余数量：24614] - [当前时间：15:42:18]
#
# [状态：ok，尝试次数：  1] - 1001354;4784997;HP2005;DAYCO
# [剩余数量：24613] - [当前时间：15:42:18]
#
# [状态：ok，尝试次数：  1] - 1001354;4970421;23G3805;GATES
# [剩余数量：24612] - [当前时间：15:42:18]
#
# [状态：ok，尝试次数：  1] - 1001354;4785003;HP2009;DAYCO
# [剩余数量：24611] - [当前时间：15:42:18]
#
# [状态：ok，尝试次数：  2] - 1001349;4970391;19G3982E;GATES
# [剩余数量：24610] - [当前时间：15:42:18]
#
# [状态：ok，尝试次数：  2] - 1001349;4970409;20G4154;GATES
# [剩余数量：24609] - [当前时间：15:42:19]
#
# [状态：ok，尝试次数：  4] - 1001349;4784790;HPX2203;DAYCO
# [剩余数量：24608] - [当前时间：15:42:19]
#
# [状态：ok，尝试次数：  2] - 1001546;12871609;20C4022;GATES
# [剩余数量：24607] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;4970310;23C3836;GATES
# [剩余数量：24606] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;12871649;23C3856;GATES
# [剩余数量：24605] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;4970424;23G3836;GATES
# [剩余数量：24604] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;12871661;23G3856;GATES
# [剩余数量：24603] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;12871605;20C3596;GATES
# [剩余数量：24602] - [当前时间：15:42:20]
#
# [状态：ok，尝试次数：  1] - 1001354;12871669;23R3856;GATES
# [剩余数量：24601] - [当前时间：15:42:21]
#
# [状态：ok，尝试次数：  1] - 260;368850;GIFTCERT50;ROCKAUTO
# [剩余数量：24600] - [当前时间：15:42:21]
#
# [状态：ok，尝试次数：  1] - 1001354;4785045;HP2026;DAYCO
# [剩余数量：24599] - [当前时间：15:42:22]
#
# [状态：ok，尝试次数：  2] - 1001349;4784811;HPX2239;DAYCO
# [剩余数量：24598] - [当前时间：15:42:22]
#
# [状态：ok，尝试次数：  1] - 1001354;4785042;HP2025;DAYCO
# [剩余数量：24597] - [当前时间：15:42:22]
#
# [状态：ok，尝试次数：  1] - 1001354;4777059;31GBS1072;CONTINENTAL
# [剩余数量：24596] - [当前时间：15:42:23]
#
# [状态：ok，尝试次数：  2] - 1001354;12871625;21C3636;GATES
# [剩余数量：24595] - [当前时间：15:42:23]
#
# [状态：ok，尝试次数：  1] - 1001354;4784922;XTX2244;DAYCO
# [剩余数量：24594] - [当前时间：15:42:24]
#
# [状态：ok，尝试次数：  2] - 1001349;12871617;20G4699;GATES
# [剩余数量：24593] - [当前时间：15:42:24]
#
# [状态：ok，尝试次数：  4] - 1001349;4785036;HP2020;DAYCO
# [剩余数量：24592] - [当前时间：15:42:24]
#
# [状态：ok，尝试次数：  2] - 1001354;5545647;23G4057;GATES
# [剩余数量：24591] - [当前时间：15:42:24]
#
# [状态：ok，尝试次数：  3] - 1001354;4970412;20G4272;GATES
# [剩余数量：24590] - [当前时间：15:42:25]
#
# [状态：ok，尝试次数：  1] - 1001354;4970415;21G4140;GATES
# [剩余数量：24589] - [当前时间：15:42:25]
#
# [状态：ok，尝试次数：  2] - 1001344;12873173;77G3158;GATES
# [剩余数量：24588] - [当前时间：15:42:25]
#
# [状态：ok，尝试次数：  1] - 1001354;12871677;23R4340;GATES
# [剩余数量：24587] - [当前时间：15:42:26]
#
# [状态：ok，尝试次数：  1] - 1001345;12871705;25G3750;GATES
# [剩余数量：24586] - [当前时间：15:42:26]
#
# [状态：ok，尝试次数：  1] - 1001354;12871653;23C4057;GATES
# [剩余数量：24585] - [当前时间：15:42:27]
#
# [状态：ok，尝试次数：  1] - 1001354;12871641;21R4140;GATES
# [剩余数量：24584] - [当前时间：15:42:27]
#
# [状态：ok，尝试次数：  2] - 1001345;101317;6312;GATES
# [剩余数量：24583] - [当前时间：15:42:27]
#
# [状态：ok，尝试次数：  2] - 1001345;4970436;24G3884;GATES
# [剩余数量：24582] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  2] - 1001354;4785057;HP2030;DAYCO
# [剩余数量：24581] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  3] - 1001546;4970406;20G4022E;GATES
# [剩余数量：24580] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  2] - 1001354;5417865;XTX2254;DAYCO
# [剩余数量：24579] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  5] - 1001349;4784910;XTX2239;DAYCO
# [剩余数量：24578] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  2] - 1001354;4785060;HP2031;DAYCO
# [剩余数量：24577] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  2] - 1001354;4970400;20G3982;GATES
# [剩余数量：24576] - [当前时间：15:42:28]
#
# [状态：ok，尝试次数：  3] - 1001354;12871637;21G4289;GATES
# [剩余数量：24575] - [当前时间：15:42:30]
#
# [状态：ok，尝试次数：  1] - 1001345;12871673;23R4140;GATES
# [剩余数量：24574] - [当前时间：15:42:30]
#
# [状态：ok，尝试次数：  5] - 1001354;4970433;23G4340;GATES
# [剩余数量：24573] - [当前时间：15:42:31]
#
# [状态：ok，尝试次数：  2] - 1001345;4970439;24G4022;GATES
# [剩余数量：24572] - [当前时间：15:42:31]
#
# [状态：ok，尝试次数：  2] - 1001345;12871753;26G4829;GATES
# [剩余数量：24571] - [当前时间：15:42:31]
#
# [状态：ok，尝试次数：  2] - 1001345;12871745;26C4829;GATES
# [剩余数量：24570] - [当前时间：15:42:32]
#
# [状态：ok，尝试次数：  1] - 1001345;5545650;23G4140;GATES
# [剩余数量：24569] - [当前时间：15:42:32]
#
# [状态：ok，尝试次数：  1] - 1001345;5545632;23C4140;GATES
# [剩余数量：24568] - [当前时间：15:42:32]
#
# [状态：ok，尝试次数：  2] - 1001345;12871721;25R4108;GATES
# [剩余数量：24567] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  1] - 1001345;4970442;24G4108;GATES
# [剩余数量：24566] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  3] - 1001345;12871749;26G4140;GATES
# [剩余数量：24565] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  1] - 1001345;12871725;25R4789;GATES
# [剩余数量：24564] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  1] - 1001345;5417859;XTX2252;DAYCO
# [剩余数量：24563] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  2] - 1001345;12871709;25G4076;GATES
# [剩余数量：24562] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  2] - 1001345;4784922;XTX2244;DAYCO
# [剩余数量：24561] - [当前时间：15:42:33]
#
# [状态：ok，尝试次数：  3] - 1001345;12871741;26C4140;GATES
# [剩余数量：24560] - [当前时间：15:42:34]
#
# [状态：ok，尝试次数：  1] - 1001345;4970445;24G5596;GATES
# [剩余数量：24559] - [当前时间：15:42:34]
#
# [状态：ok，尝试次数：  1] - 1001355;12871777;27C4159;GATES
# [剩余数量：24558] - [当前时间：15:42:34]
#
# [状态：ok，尝试次数：  1] - 1001345;12871765;26R4829;GATES
# [剩余数量：24557] - [当前时间：15:42:34]
#
# [状态：ok，尝试次数：  4] - 1001345;12871761;26R4140;GATES
# [剩余数量：24556] - [当前时间：15:42:35]
#
# [状态：ok，尝试次数：  1] - 1001355;12871869;29G4266;GATES
# [剩余数量：24555] - [当前时间：15:42:36]
#
# [状态：ok，尝试次数：  9] - 1001355;4970469;28G4313;GATES
# [剩余数量：24554] - [当前时间：15:42:36]
#
# [状态：ok，尝试次数：  1] - 1001345;12871713;25G4108;GATES
# [剩余数量：24553] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  2] - 1001345;4970451;26G3596;GATES
# [剩余数量：24552] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  2] - 1001345;12871769;26R5407;GATES
# [剩余数量：24551] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  5] - 1001354;4970307;21C4140;GATES
# [剩余数量：24550] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  1] - 1001345;12871689;24R4022;GATES
# [剩余数量：24549] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  2] - 1001355;12871865;29G4195;GATES
# [剩余数量：24548] - [当前时间：15:42:37]
#
# [状态：ok，尝试次数：  2] - 1001355;4784934;XTX2250;DAYCO
# [剩余数量：24547] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  1] - 1001355;12871845;29C4266;GATES
# [剩余数量：24546] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  1] - 1001355;12871825;28G4588;GATES
# [剩余数量：24545] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  1] - 1001355;4970463;27G4313;GATES
# [剩余数量：24544] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  1] - 1001345;5545653;26G5407;GATES
# [剩余数量：24543] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  1] - 1001355;12871841;29C4195;GATES
# [剩余数量：24542] - [当前时间：15:42:38]
#
# [状态：ok，尝试次数：  2] - 1001355;12871801;28C3982;GATES
# [剩余数量：24541] - [当前时间：15:42:39]
#
# [状态：ok，尝试次数：  1] - 1001355;4785066;HP2035;DAYCO
# [剩余数量：24540] - [当前时间：15:42:39]
#
# [状态：ok，尝试次数：  2] - 1001355;12871781;27G3636;GATES
# [剩余数量：24539] - [当前时间：15:42:39]
#
# [状态：ok，尝试次数： 12] - 1001355;4970472;28G4573;GATES
# [剩余数量：24538] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数：  1] - 1001355;4970460;27G3450;GATES
# [剩余数量：24537] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数：  5] - 1001355;12871773;27C3636;GATES
# [剩余数量：24536] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数：  1] - 1001355;12871837;28R4313;GATES
# [剩余数量：24535] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数：  1] - 1001355;12871797;28C3636;GATES
# [剩余数量：24534] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数：  1] - 1001355;12871793;27R4159;GATES
# [剩余数量：24533] - [当前时间：15:42:40]
#
# [状态：ok，尝试次数： 10] - 1001355;12871833;28R3982;GATES
# [剩余数量：24532] - [当前时间：15:42:41]
#
# [状态：ok，尝试次数：  6] - 1001355;4970319;29C3596;GATES
# [剩余数量：24531] - [当前时间：15:42:41]
#
# [状态：ok，尝试次数：  6] - 1001355;4784916;XTX2241;DAYCO
# [剩余数量：24530] - [当前时间：15:42:41]
#
# [状态：ok，尝试次数： 10] - 1001355;4970475;29G3596;GATES
# [剩余数量：24529] - [当前时间：15:42:41]
#
# [状态：ok，尝试次数：  3] - 1001355;4784925;XTX2247;DAYCO
# [剩余数量：24528] - [当前时间：15:42:41]
#
# [状态：ok，尝试次数：  2] - 1001351;5545656;31G3569;GATES
# [剩余数量：24527] - [当前时间：15:42:42]
#
# [状态：ok，尝试次数：  2] - 1001351;4970490;30G3750;GATES
# [剩余数量：24526] - [当前时间：15:42:43]
#
# [状态：ok，尝试次数： 13] - 1001351;4785066;HP2035;DAYCO
# [剩余数量：24525] - [当前时间：15:42:43]
#
# [状态：ok，尝试次数： 13] - 1001351;12871905;30R3750;GATES
# [剩余数量：24524] - [当前时间：15:42:43]
#
# [状态：ok，尝试次数： 24] - 1001355;4970454;26G3628;GATES
# [剩余数量：24523] - [当前时间：15:42:43]
#
# [状态：ok，尝试次数：  6] - 1001351;4784784;XTX2236;DAYCO
# [剩余数量：24522] - [当前时间：15:42:45]
#
# [状态：ok，尝试次数： 20] - 1001355;12871877;29G4573;GATES
# [剩余数量：24521] - [当前时间：15:42:45]
#
# [状态：ok，尝试次数：  6] - 1001355;12871881;29R4266;GATES
# [剩余数量：24520] - [当前时间：15:42:45]
#
# [状态：ok，尝试次数：  5] - 1001355;4784805;HPX2236;DAYCO
# [剩余数量：24519] - [当前时间：15:42:45]
#
# [状态：ok，尝试次数：  1] - 1001351;12871909;30R4604;GATES
# [剩余数量：24518] - [当前时间：15:42:45]
#
# [状态：ok，尝试次数：  1] - 1001351;12871925;32C3856;GATES
# [剩余数量：24517] - [当前时间：15:42:46]
#
# [状态：ok，尝试次数：  9] - 1001355;4970316;27C3450;GATES
# [剩余数量：24516] - [当前时间：15:42:46]
#
# [状态：ok，尝试次数： 13] - 1001351;12871921;31R4573;GATES
# [剩余数量：24515] - [当前时间：15:42:47]
#
# [状态：ok，尝试次数：  7] - 1001351;12871913;31C4573;GATES
# [剩余数量：24514] - [当前时间：15:42:48]
#
# [状态：ok，尝试次数：  7] - 1001351;12871937;32G4195;GATES
# [剩余数量：24513] - [当前时间：15:42:48]
#
# [状态：ok，尝试次数：  5] - 1001351;12871941;32R4195;GATES
# [剩余数量：24512] - [当前时间：15:42:48]
#
# [状态：ok，尝试次数： 13] - 1001351;4970322;30C3750;GATES
# [剩余数量：24511] - [当前时间：15:42:48]
#
# [状态：ok，尝试次数： 41] - 1001355;12871789;27R3636;GATES
# [剩余数量：24510] - [当前时间：15:42:48]
#
# [状态：ok，尝试次数： 31] - 1001351;12871917;31G4573;GATES
# [剩余数量：24509] - [当前时间：15:42:49]
#
# [状态：ok，尝试次数： 19] - 1001355;4784904;XTX2233;DAYCO
# [剩余数量：24508] - [当前时间：15:42:49]
#
# [状态：ok，尝试次数：  3] - 1001350;12872069;40R4340;GATES
# [剩余数量：24507] - [当前时间：15:42:49]
#
# [状态：ok，尝试次数：  8] - 1001350;5417871;XTX2256;DAYCO
# [剩余数量：24506] - [当前时间：15:42:50]
#
# [状态：ok，尝试次数： 11] - 1001351;12871933;32G3856;GATES
# [剩余数量：24505] - [当前时间：15:42:50]
#
# [状态：ok，尝试次数： 26] - 1001351;12871929;32C4588;GATES
# [剩余数量：24504] - [当前时间：15:42:51]
#
# [状态：ok，尝试次数：  1] - 1001350;4970529;38G4266;GATES
# [剩余数量：24503] - [当前时间：15:42:51]
#
# [状态：ok，尝试次数： 29] - 1001350;12872001;36C4368;GATES
# [剩余数量：24502] - [当前时间：15:42:52]
#
# [状态：ok，尝试次数： 12] - 1001355;12871817;28G3982;GATES
# [剩余数量：24501] - [当前时间：15:42:52]
#
# [状态：ok，尝试次数：  6] - 1001543;12871957;34C3596;GATES
# [剩余数量：24500] - [当前时间：15:42:53]
#
# [状态：ok，尝试次数： 22] - 1001355;12871893;30C3636;GATES
# [剩余数量：24499] - [当前时间：15:42:53]
#
# [状态：ok，尝试次数： 30] - 1001350;12872013;36G4368;GATES
# [剩余数量：24498] - [当前时间：15:42:53]
#
# [状态：ok，尝试次数： 10] - 1001347;4970553;40G3569;GATES
# [剩余数量：24497] - [当前时间：15:42:54]
#
# [状态：ok，尝试次数： 21] - 1001350;12872021;36R4368;GATES
# [剩余数量：24496] - [当前时间：15:42:54]
#
# [状态：ok，尝试次数： 13] - 1001347;4970556;40G3691;GATES
# [剩余数量：24495] - [当前时间：15:42:55]
#
# [状态：ok，尝试次数： 13] - 1001543;12871953;33R3836;GATES
# [剩余数量：24494] - [当前时间：15:42:55]
#
# [状态：ok，尝试次数：  4] - 1001543;12872017;36R4246;GATES
# [剩余数量：24493] - [当前时间：15:42:55]
#
# [状态：ok，尝试次数： 14] - 1001543;12871997;36C4246;GATES
# [剩余数量：24492] - [当前时间：15:42:55]
#
# [状态：ok，尝试次数：  1] - 1001347;12872101;41G4514;GATES
# [剩余数量：24491] - [当前时间：15:42:55]
#
# [状态：ok，尝试次数： 21] - 1001351;4970496;32G4588;GATES
# [剩余数量：24490] - [当前时间：15:42:56]
#
# [状态：ok，尝试次数： 31] - 1001350;4970520;37G4474;GATES
# [剩余数量：24489] - [当前时间：15:42:56]
#
# [状态：ok，尝试次数：  6] - 1001350;12872041;38C4683;GATES
# [剩余数量：24488] - [当前时间：15:42:57]
#
# [状态：ok，尝试次数：  8] - 1001347;5417862;XTX2253;DAYCO
# [剩余数量：24487] - [当前时间：15:42:57]
#
# [状态：ok，尝试次数：  7] - 1001347;12872117;41R4514;GATES
# [剩余数量：24486] - [当前时间：15:42:57]
#
# [状态：ok，尝试次数：  3] - 1001347;12872061;40R3691;GATES
# [剩余数量：24485] - [当前时间：15:42:57]
#
# [状态：ok，尝试次数： 15] - 1001347;12872073;40R4683;GATES
# [剩余数量：24484] - [当前时间：15:42:58]
#
# [状态：ok，尝试次数：  4] - 1001347;12872089;41C4620;GATES
# [剩余数量：24483] - [当前时间：15:42:58]
#
# [状态：ok，尝试次数：  1] - 1001347;12872113;41R4313;GATES
# [剩余数量：24482] - [当前时间：15:42:58]
#
# [状态：ok，尝试次数：  6] - 1001347;12872045;38R4494;GATES
# [剩余数量：24481] - [当前时间：15:42:59]
#
# [状态：ok，尝试次数：  3] - 1001353;12872225;46G4387;GATES
# [剩余数量：24480] - [当前时间：15:42:59]
#
# [状态：ok，尝试次数：  2] - 1001353;12872149;42R4474;GATES
# [剩余数量：24479] - [当前时间：15:42:59]
#
# [状态：ok，尝试次数： 19] - 1001347;12872057;40C3691;GATES
# [剩余数量：24478] - [当前时间：15:43:00]
#
# [状态：ok，尝试次数： 13] - 1001353;12872193;45G4553;GATES
# [剩余数量：24477] - [当前时间：15:43:00]
#
# [状态：ok，尝试次数： 19] - 1001347;4784748;HP2032;DAYCO
# [剩余数量：24476] - [当前时间：15:43:00]
#
# [状态：ok，尝试次数： 21] - 1001347;12872105;41G4620;GATES
# [剩余数量：24475] - [当前时间：15:43:00]
#
# [状态：ok，尝试次数：  1] - 1001353;12872181;44C4714;GATES
# [剩余数量：24474] - [当前时间：15:43:01]
#
# [状态：ok，尝试次数：  9] - 1001347;12872125;42C4313;GATES
# [剩余数量：24473] - [当前时间：15:43:01]
#
# [状态：ok，尝试次数： 10] - 1001347;12872065;40R4313;GATES
# [剩余数量：24472] - [当前时间：15:43:01]
#
# [状态：ok，尝试次数：  1] - 1001353;12872213;46C4387;GATES
# [剩余数量：24471] - [当前时间：15:43:01]
#
# [状态：ok，尝试次数：  1] - 1001347;12872093;41G3982;GATES
# [剩余数量：24470] - [当前时间：15:43:02]
#
# [状态：ok，尝试次数：  1] - 1001353;12872189;45C4553;GATES
# [剩余数量：24469] - [当前时间：15:43:02]
#
# [状态：ok，尝试次数： 15] - 1001543;12871961;34G3596;GATES
# [剩余数量：24468] - [当前时间：15:43:02]
#
# [状态：ok，尝试次数： 17] - 1001347;12872085;41C4514;GATES
# [剩余数量：24467] - [当前时间：15:43:03]
#
# [状态：ok，尝试次数： 18] - 1001353;12872201;45R4553;GATES
# [剩余数量：24466] - [当前时间：15:43:03]
#
# [状态：ok，尝试次数：  9] - 1001353;12872237;46R4387;GATES
# [剩余数量：24465] - [当前时间：15:43:03]
#
# [状态：ok，尝试次数： 27] - 1001353;12872165;43G4289;GATES
# [剩余数量：24464] - [当前时间：15:43:04]
#
# [状态：ok，尝试次数： 10] - 1001353;12872169;43R4210;GATES
# [剩余数量：24463] - [当前时间：15:43:05]
#
# [状态：ok，尝试次数：  7] - 1001353;4784907;XTX2234;DAYCO
# [剩余数量：24462] - [当前时间：15:43:05]
#
# [状态：ok，尝试次数： 10] - 1001353;4970619;44G3569;GATES
# [剩余数量：24461] - [当前时间：15:43:05]
#
# [状态：ok，尝试次数： 39] - 1001353;12872133;42C4474;GATES
# [剩余数量：24460] - [当前时间：15:43:05]
#
# [状态：ok，尝试次数： 25] - 1001353;12872173;43R4289;GATES
# [剩余数量：24459] - [当前时间：15:43:05]
#
# [状态：ok，尝试次数：  1] - 1001348;4970652;46G3569;GATES
# [剩余数量：24458] - [当前时间：15:43:06]
#
# [状态：ok，尝试次数：  2] - 1001348;12872233;46R3596;GATES
# [剩余数量：24457] - [当前时间：15:43:06]
#
# [状态：ok，尝试次数： 30] - 1001353;12872153;43C4289;GATES
# [剩余数量：24456] - [当前时间：15:43:06]
#
# [状态：ok，尝试次数：  8] - 1001353;4970343;43C3596;GATES
# [剩余数量：24455] - [当前时间：15:43:06]
#
# [状态：ok，尝试次数：  1] - 1001348;12872309;48R4246;GATES
# [剩余数量：24454] - [当前时间：15:43:07]
#
# [状态：ok，尝试次数： 11] - 1001353;12872177;44C3569;GATES
# [剩余数量：24453] - [当前时间：15:43:07]
#
# [状态：ok，尝试次数：  3] - 1001348;12872277;47R4572;GATES
# [剩余数量：24452] - [当前时间：15:43:07]
#
# [状态：ok，尝试次数：  4] - 1001353;4970601;43G3596;GATES
# [剩余数量：24451] - [当前时间：15:43:07]
#
# [状态：ok，尝试次数： 21] - 1001353;12872129;42C4455;GATES
# [剩余数量：24450] - [当前时间：15:43:07]
#
# [状态：ok，尝试次数： 10] - 1001348;4970355;46C3596;GATES
# [剩余数量：24449] - [当前时间：15:43:08]
#
# [状态：ok，尝试次数：  1] - 1001348;12872205;46C3569;GATES
# [剩余数量：24448] - [当前时间：15:43:08]
#
# [状态：ok，尝试次数： 13] - 1001348;12872285;48C4289;GATES
# [剩余数量：24447] - [当前时间：15:43:09]
#
# [状态：ok，尝试次数：  5] - 1001348;12872273;47R4368;GATES
# [剩余数量：24446] - [当前时间：15:43:09]
#
# [状态：ok，尝试次数： 16] - 1001348;12872313;48R4289;GATES
# [剩余数量：24445] - [当前时间：15:43:10]
#
# [状态：ok，尝试次数： 14] - 1001348;12872257;47C4572;GATES
# [剩余数量：24444] - [当前时间：15:43:10]
#
# [状态：ok，尝试次数： 18] - 1001348;12872321;48R4738;GATES
# [剩余数量：24443] - [当前时间：15:43:11]
#
# [状态：ok，尝试次数：  2] - 1001348;12872297;48G4289;GATES
# [剩余数量：24442] - [当前时间：15:43:11]
#
# [状态：ok，尝试次数： 10] - 1001353;12872185;44R4553;GATES
# [剩余数量：24441] - [当前时间：15:43:11]
#
# [状态：ok，尝试次数： 24] - 1001347;12872109;41R3982;GATES
# [剩余数量：24440] - [当前时间：15:43:11]
#
# [状态：ok，尝试次数： 18] - 1001348;12872261;47C4738;GATES
# [剩余数量：24439] - [当前时间：15:43:11]
#
# [状态：ok，尝试次数： 17] - 1001347;12872077;41C3982;GATES
# [剩余数量：24438] - [当前时间：15:43:12]
#
# [状态：ok，尝试次数：  1] - 1001348;12872209;46C4266;GATES
# [剩余数量：24437] - [当前时间：15:43:12]
#
# [状态：ok，尝试次数： 23] - 1001348;12872249;47C4368;GATES
# [剩余数量：24436] - [当前时间：15:43:13]
#
# [状态：ok，尝试次数：  4] - 1001348;12872317;48R4553;GATES
# [剩余数量：24435] - [当前时间：15:43:14]
#
# [状态：ok，尝试次数： 36] - 1001348;12872269;47R4266;GATES
# [剩余数量：24434] - [当前时间：15:43:14]
#
# [状态：ok，尝试次数： 17] - 1001348;12872241;46R5289;GATES
# [剩余数量：24433] - [当前时间：15:43:15]
#
# [状态：ok，尝试次数：  1] - 1000587;101756;9850;GATES
# [剩余数量：24432] - [当前时间：15:43:15]
#
# [状态：ok，尝试次数：  9] - 1000587;101750;9770;GATES
# [剩余数量：24431] - [当前时间：15:43:15]
#
# [状态：ok，尝试次数：  5] - 1000587;101753;9820;GATES
# [剩余数量：24430] - [当前时间：15:43:16]
#
# [状态：ok，尝试次数：  7] - 1001348;12872229;46G5289;GATES
# [剩余数量：24429] - [当前时间：15:43:16]
#
# [状态：ok，尝试次数： 12] - 1001348;12872265;47G4368;GATES
# [剩余数量：24428] - [当前时间：15:43:17]
#
# [状态：ok，尝试次数：  1] - 1001538;4970769;K050271;GATES
# [剩余数量：24427] - [当前时间：15:43:17]
#
# [状态：ok，尝试次数：  2] - 1000587;101754;9830;GATES
# [剩余数量：24426] - [当前时间：15:43:18]
#
# [状态：ok，尝试次数：  7] - 1001538;5545623;2B86;GATES
# [剩余数量：24425] - [当前时间：15:43:18]
#
# [状态：ok，尝试次数：  2] - 1000587;101752;9810;GATES
# [剩余数量：24424] - [当前时间：15:43:19]
#
# [状态：ok，尝试次数：  3] - 1001517;670342;10K739;ACDELCO
# [剩余数量：24423] - [当前时间：15:43:19]
#
# [状态：ok，尝试次数： 26] - 1001348;12872217;46C5289;GATES
# [剩余数量：24422] - [当前时间：15:43:19]
#
# [状态：ok，尝试次数： 26] - 1001353;12872157;43C4340;GATES
# [剩余数量：24421] - [当前时间：15:43:19]
#
# [状态：ok，尝试次数： 28] - 1001348;12872301;48G4738;GATES
# [剩余数量：24420] - [当前时间：15:43:19]
#
# [状态：ok，尝试次数：  1] - 1001517;670345;10K852;ACDELCO
# [剩余数量：24419] - [当前时间：15:43:20]
#
# [状态：ok，尝试次数：  2] - 1001517;670331;10K630;ACDELCO
# [剩余数量：24418] - [当前时间：15:43:20]
#
# [状态：ok，尝试次数： 28] - 1001348;12872289;48C4738;GATES
# [剩余数量：24417] - [当前时间：15:43:21]
#
# [状态：ok，尝试次数：  1] - 1001213;612600;6599;GATES
# [剩余数量：24416] - [当前时间：15:43:21]
#
# [状态：ok，尝试次数： 13] - 1001348;12872245;47C4266;GATES
# [剩余数量：24415] - [当前时间：15:43:21]
#
# [状态：ok，尝试次数：  1] - 1001549;670355;12K720;ACDELCO
# [剩余数量：24414] - [当前时间：15:43:21]
#
# [状态：ok，尝试次数：  7] - 1001517;670335;10K658;ACDELCO
# [剩余数量：24413] - [当前时间：15:43:22]
#
# [状态：ok，尝试次数：  1] - 1001549;670350;12K410;ACDELCO
# [剩余数量：24412] - [当前时间：15:43:22]
#
# [状态：ok，尝试次数： 22] - 1001517;670343;10K771;ACDELCO
# [剩余数量：24411] - [当前时间：15:43:23]
#
# [状态：ok，尝试次数： 12] - 1001348;12872253;47C4384;GATES
# [剩余数量：24410] - [当前时间：15:43:23]
#
# [状态：ok，尝试次数：  5] - 17545;10450253;80073;PERMATEX
# [剩余数量：24409] - [当前时间：15:43:23]
#
# [状态：ok，尝试次数： 11] - 1001517;670340;10K719;ACDELCO
# [剩余数量：24408] - [当前时间：15:43:23]
#
# [状态：ok，尝试次数：  2] - 1001549;670360;12K901;ACDELCO
# [剩余数量：24407] - [当前时间：15:43:24]
#
# [状态：ok，尝试次数：  2] - 1000578;671489;3VX315;ACDELCO
# [剩余数量：24406] - [当前时间：15:43:24]
#
# [状态：ok，尝试次数：  2] - 1001549;670357;12K815;ACDELCO
# [剩余数量：24405] - [当前时间：15:43:24]
#
# [状态：ok，尝试次数：  4] - 1001549;670349;12K400;ACDELCO
# [剩余数量：24404] - [当前时间：15:43:24]
#
# [状态：ok，尝试次数：  4] - 1000578;101116;3VX315;GATES
# [剩余数量：24403] - [当前时间：15:43:24]
#
# [状态：ok，尝试次数：  6] - 1000578;101115;3VX300;GATES
# [剩余数量：24402] - [当前时间：15:43:25]
#
# [状态：ok，尝试次数：  2] - 1000578;101118;3VX355;GATES
# [剩余数量：24401] - [当前时间：15:43:25]
#
# [状态：ok，尝试次数：  2] - 1000578;101088;3V375;GATES
# [剩余数量：24400] - [当前时间：15:43:26]
#
# [状态：ok，尝试次数：  9] - 1001549;670353;12K606;ACDELCO
# [剩余数量：24399] - [当前时间：15:43:26]
#
# [状态：ok，尝试次数：  3] - 1000587;101755;9840;GATES
# [剩余数量：24398] - [当前时间：15:43:27]
#
# [状态：ok，尝试次数：  6] - 1000578;295740;5VX450;GATES
# [剩余数量：24397] - [当前时间：15:43:27]
#
# [状态：ok，尝试次数：  4] - 1000578;101121;3VX425;GATES
# [剩余数量：24396] - [当前时间：15:43:27]
#
# [状态：ok，尝试次数：  6] - 1000578;101122;3VX450;GATES
# [剩余数量：24395] - [当前时间：15:43:29]
#
# [状态：ok，尝试次数：  6] - 1000578;101090;3V425;GATES
# [剩余数量：24394] - [当前时间：15:43:29]
#
# [状态：ok，尝试次数：  2] - 1000578;101086;3V335;GATES
# [剩余数量：24393] - [当前时间：15:43:29]
#
# [状态：ok，尝试次数：  1] - 1000578;295741;5VX470;GATES
# [剩余数量：24392] - [当前时间：15:43:30]
#
# [状态：ok，尝试次数： 24] - 1000578;101123;3VX475;GATES
# [剩余数量：24391] - [当前时间：15:43:30]
#
# [状态：ok，尝试次数：  9] - 1000578;101120;3VX400;GATES
# [剩余数量：24390] - [当前时间：15:43:30]
#
# [状态：ok，尝试次数：  2] - 1000578;101084;3V300;GATES
# [剩余数量：24389] - [当前时间：15:43:31]
#
# [状态：ok，尝试次数：  7] - 1000578;295742;5VX490;GATES
# [剩余数量：24388] - [当前时间：15:43:31]
#
# [状态：ok，尝试次数： 25] - 1001549;670347;12K281;ACDELCO
# [剩余数量：24387] - [当前时间：15:43:32]
#
# [状态：ok，尝试次数： 29] - 1001348;12872281;47R4738;GATES
# [剩余数量：24386] - [当前时间：15:43:32]
#
# [状态：ok，尝试次数： 19] - 1000587;101749;9765;GATES
# [剩余数量：24385] - [当前时间：15:43:32]
#
# [状态：ok，尝试次数：  1] - 1000578;295738;5VX1150;GATES
# [剩余数量：24384] - [当前时间：15:43:33]
#
# [状态：ok，尝试次数：  1] - 1000578;295737;5VX1080;GATES
# [剩余数量：24383] - [当前时间：15:43:33]
#
# [状态：ok，尝试次数：  6] - 1000578;101082;3V265;GATES
# [剩余数量：24382] - [当前时间：15:43:33]
#
# [状态：ok，尝试次数：  1] - 1000578;295739;5VX1230;GATES
# [剩余数量：24381] - [当前时间：15:43:35]
#
# [状态：ok，尝试次数：  9] - 1000578;101105;3VX1000;GATES
# [剩余数量：24380] - [当前时间：15:43:35]
#
# [状态：ok，尝试次数：  3] - 1000578;101113;3VX265;GATES
# [剩余数量：24379] - [当前时间：15:43:35]
#
# [状态：ok，尝试次数： 10] - 1000578;101112;3VX250;GATES
# [剩余数量：24378] - [当前时间：15:43:36]
#
# [状态：ok，尝试次数： 20] - 1000578;101114;3VX280;GATES
# [剩余数量：24377] - [当前时间：15:43:36]
#
# [状态：ok，尝试次数： 21] - 1000578;5418063;3V1120;DAYCO
# [剩余数量：24376] - [当前时间：15:43:36]
#
# [状态：ok，尝试次数：  7] - 1000578;101083;3V280;GATES
# [剩余数量：24375] - [当前时间：15:43:36]
#
# [状态：ok，尝试次数： 31] - 1000578;101087;3V355;GATES
# [剩余数量：24374] - [当前时间：15:43:36]
#
# [状态：ok，尝试次数：  4] - 1000578;101108;3VX1180;GATES
# [剩余数量：24373] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数：  6] - 1000578;101107;3VX1120;GATES
# [剩余数量：24372] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数：  1] - 1000578;101243;5VX1000;GATES
# [剩余数量：24371] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数：  1] - 1000578;295736;5VX1030;GATES
# [剩余数量：24370] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数： 10] - 17545;10450257;80074;PERMATEX
# [剩余数量：24369] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数： 17] - 1000578;5418057;3V1000;DAYCO
# [剩余数量：24368] - [当前时间：15:43:37]
#
# [状态：ok，尝试次数：  4] - 1000578;101245;5VX1120;GATES
# [剩余数量：24367] - [当前时间：15:43:38]
#
# [状态：ok，尝试次数：  4] - 1000578;101244;5VX1060;GATES
# [剩余数量：24366] - [当前时间：15:43:38]
#
# [状态：ok，尝试次数：  1] - 1000578;101248;5VX1320;GATES
# [剩余数量：24365] - [当前时间：15:43:38]
#
# [状态：ok，尝试次数：  1] - 1000578;101096;3V600;GATES
# [剩余数量：24364] - [当前时间：15:43:40]
#
# [状态：ok，尝试次数：  4] - 1000578;101261;5VX670;GATES
# [剩余数量：24363] - [当前时间：15:43:40]
#
# [状态：ok，尝试次数：  6] - 1000578;101259;5VX600;GATES
# [剩余数量：24362] - [当前时间：15:43:40]
#
# [状态：ok，尝试次数：  1] - 1000578;101128;3VX630;GATES
# [剩余数量：24361] - [当前时间：15:43:40]
#
# [状态：ok，尝试次数：  1] - 1000578;101127;3VX600;GATES
# [剩余数量：24360] - [当前时间：15:43:40]
#
# [状态：ok，尝试次数： 19] - 1000578;101119;3VX375;GATES
# [剩余数量：24359] - [当前时间：15:43:41]
#
# [状态：ok，尝试次数：  7] - 1000578;101129;3VX670;GATES
# [剩余数量：24358] - [当前时间：15:43:42]
#
# [状态：ok，尝试次数：  4] - 1000578;295750;5VX650;GATES
# [剩余数量：24357] - [当前时间：15:43:42]
#
# [状态：ok，尝试次数：  2] - 1000578;295751;5VX660;GATES
# [剩余数量：24356] - [当前时间：15:43:42]
#
# [状态：ok，尝试次数： 18] - 1000586;5545620;2A74;GATES
# [剩余数量：24355] - [当前时间：15:43:43]
#
# [状态：ok，尝试次数： 34] - 1000578;101247;5VX1250;GATES
# [剩余数量：24354] - [当前时间：15:43:43]
#
# [状态：ok，尝试次数： 19] - 1000578;671450;3V1120;ACDELCO
# [剩余数量：24353] - [当前时间：15:43:43]
#
# [状态：ok，尝试次数： 27] - 1000578;101106;3VX1060;GATES
# [剩余数量：24352] - [当前时间：15:43:44]
#
# [状态：ok，尝试次数： 19] - 1000578;671502;3VX670;ACDELCO
# [剩余数量：24351] - [当前时间：15:43:45]
#
# [状态：ok，尝试次数： 10] - 1000578;101132;3VX800;GATES
# [剩余数量：24350] - [当前时间：15:43:45]
#
# [状态：ok，尝试次数：  2] - 1000578;101092;3V475;GATES
# [剩余数量：24349] - [当前时间：15:43:45]
#
# [状态：ok，尝试次数： 32] - 1000578;295753;5VX690;GATES
# [剩余数量：24348] - [当前时间：15:43:45]
#
# [状态：ok，尝试次数：  2] - 1000578;101264;5VX800;GATES
# [剩余数量：24347] - [当前时间：15:43:46]
#
# [状态：ok，尝试次数： 14] - 1000578;101097;3V630;GATES
# [剩余数量：24346] - [当前时间：15:43:46]
#
# [状态：ok，尝试次数：  1] - 1000578;295757;5VX810;GATES
# [剩余数量：24345] - [当前时间：15:43:46]
#
# [状态：ok，尝试次数：  1] - 1000578;101265;5VX850;GATES
# [剩余数量：24344] - [当前时间：15:43:47]
#
# [状态：ok，尝试次数： 19] - 1000578;295752;5VX680;GATES
# [剩余数量：24343] - [当前时间：15:43:47]
#
# [状态：ok，尝试次数：  1] - 1000578;295759;5VX840;GATES
# [剩余数量：24342] - [当前时间：15:43:47]
#
# [状态：ok，尝试次数：  1] - 1000578;295761;5VX880;GATES
# [剩余数量：24341] - [当前时间：15:43:47]
#
# [状态：ok，尝试次数：  7] - 1000578;101134;3VX900;GATES
# [剩余数量：24340] - [当前时间：15:43:48]
#
# [状态：ok，尝试次数： 20] - 1000578;295749;5VX610;GATES
# [剩余数量：24339] - [当前时间：15:43:49]
#
# [状态：ok，尝试次数：  9] - 1000578;101103;3V900;GATES
# [剩余数量：24338] - [当前时间：15:43:49]
#
# [状态：ok，尝试次数： 14] - 1000578;295763;5VX960;GATES
# [剩余数量：24337] - [当前时间：15:43:49]
#
# [状态：ok，尝试次数： 10] - 1000578;101267;5VX950;GATES
# [剩余数量：24336] - [当前时间：15:43:50]
#
# [状态：ok，尝试次数： 32] - 1000578;101117;3VX335;GATES
# [剩余数量：24335] - [当前时间：15:43:50]
#
# [状态：ok，尝试次数：  3] - 1000578;671468;3V560;ACDELCO
# [剩余数量：24334] - [当前时间：15:43:50]
#
# [状态：ok，尝试次数：  1] - 1000578;101135;3VX950;GATES
# [剩余数量：24333] - [当前时间：15:43:51]
#
# [状态：ok，尝试次数：  1] - 1000578;671499;3VX560;ACDELCO
# [剩余数量：24332] - [当前时间：15:43:51]
#
# [状态：ok，尝试次数： 12] - 1000578;101133;3VX850;GATES
# [剩余数量：24331] - [当前时间：15:43:51]
#
# [状态：ok，尝试次数： 15] - 1000578;295760;5VX860;GATES
# [剩余数量：24330] - [当前时间：15:43:52]
#
# [状态：ok，尝试次数：  1] - 1000578;101095;3V560;GATES
# [剩余数量：24329] - [当前时间：15:43:52]
#
# [状态：ok，尝试次数： 11] - 1000578;101256;5VX500;GATES
# [剩余数量：24328] - [当前时间：15:43:52]
#
# [状态：ok，尝试次数：  9] - 1000578;101266;5VX900;GATES
# [剩余数量：24327] - [当前时间：15:43:53]
#
# [状态：ok，尝试次数： 11] - 1000578;101124;3VX500;GATES
# [剩余数量：24326] - [当前时间：15:43:53]
#
# [状态：ok，尝试次数：  3] - 1000578;295758;5VX830;GATES
# [剩余数量：24325] - [当前时间：15:43:53]
#
# [状态：ok，尝试次数：  1] - 1000578;101094;3V530;GATES
# [剩余数量：24324] - [当前时间：15:43:53]
#
# [状态：ok，尝试次数：  7] - 1000578;101093;3V500;GATES
# [剩余数量：24323] - [当前时间：15:43:54]
#
# [状态：ok，尝试次数：  1] - 1000578;101258;5VX560;GATES
# [剩余数量：24322] - [当前时间：15:43:54]
#
# [状态：ok，尝试次数：  1] - 1000578;295746;5VX570;GATES
# [剩余数量：24321] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数： 17] - 1000578;101101;3V800;GATES
# [剩余数量：24320] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  2] - 1000578;295762;5VX930;GATES
# [剩余数量：24319] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  1] - 1000578;295745;5VX550;GATES
# [剩余数量：24318] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  7] - 1000578;101125;3VX530;GATES
# [剩余数量：24317] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  4] - 1000578;101126;3VX560;GATES
# [剩余数量：24316] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  1] - 1000578;101131;3VX750;GATES
# [剩余数量：24315] - [当前时间：15:43:55]
#
# [状态：ok，尝试次数：  1] - 1000578;101262;5VX710;GATES
# [剩余数量：24314] - [当前时间：15:43:56]
#
# [状态：ok，尝试次数：  3] - 1000578;295743;5VX510;GATES
# [剩余数量：24313] - [当前时间：15:43:56]
#
# [状态：ok，尝试次数：  3] - 1000578;295744;5VX540;GATES
# [剩余数量：24312] - [当前时间：15:43:56]
#
# [状态：ok，尝试次数：  2] - 1000578;101257;5VX530;GATES
# [剩余数量：24311] - [当前时间：15:43:57]
#
# [状态：ok，尝试次数：  1] - 1000578;101100;3V750;GATES
# [剩余数量：24310] - [当前时间：15:43:57]
#
# [状态：ok，尝试次数：  7] - 1000578;5418120;3V560;DAYCO
# [剩余数量：24309] - [当前时间：15:43:57]
#
# [状态：ok，尝试次数：  5] - 1000578;101109;3VX1250;GATES
# [剩余数量：24308] - [当前时间：15:43:57]
#
# [状态：ok，尝试次数：  8] - 1000578;295755;5VX740;GATES
# [剩余数量：24307] - [当前时间：15:43:59]
#
# [状态：ok，尝试次数：  1] - 1000578;101099;3V710;GATES
# [剩余数量：24306] - [当前时间：15:43:59]
#
# [状态：ok，尝试次数：  9] - 1000578;101251;5VX1600;GATES
# [剩余数量：24305] - [当前时间：15:43:59]
#
# [状态：ok，尝试次数： 11] - 1000578;101246;5VX1180;GATES
# [剩余数量：24304] - [当前时间：15:43:59]
#
# [状态：ok，尝试次数：  4] - 1000578;295756;5VX780;GATES
# [剩余数量：24303] - [当前时间：15:43:59]
#
# [状态：ok，尝试次数： 29] - 1000578;101249;5VX1400;GATES
# [剩余数量：24302] - [当前时间：15:44:00]
#
# [状态：ok，尝试次数：  5] - 1000578;101254;5VX1900;GATES
# [剩余数量：24301] - [当前时间：15:44:00]
#
# [状态：ok，尝试次数：  9] - 1000581;672371;IA31;ACDELCO
# [剩余数量：24300] - [当前时间：15:44:01]
#
# [状态：ok，尝试次数： 21] - 1000578;295754;5VX730;GATES
# [剩余数量：24299] - [当前时间：15:44:01]
#
# [状态：ok，尝试次数： 11] - 1000578;101263;5VX750;GATES
# [剩余数量：24298] - [当前时间：15:44:03]
#
# [状态：ok，尝试次数： 30] - 1000578;101250;5VX1500;GATES
# [剩余数量：24297] - [当前时间：15:44:04]
#
# [状态：ok，尝试次数： 21] - 1000581;672370;IA30;ACDELCO
# [剩余数量：24296] - [当前时间：15:44:04]
#
# [状态：ok，尝试次数： 52] - 1000581;101785;A36;GATES
# [剩余数量：24295] - [当前时间：15:44:06]
#
# [状态：ok，尝试次数：  2] - 1000581;101780;A31;GATES
# [剩余数量：24294] - [当前时间：15:44:07]
#
# [状态：ok，尝试次数： 27] - 1000581;101777;A29;GATES
# [剩余数量：24293] - [当前时间：15:44:07]
#
# [状态：ok，尝试次数： 12] - 1000581;5419260;AP34;DAYCO
# [剩余数量：24292] - [当前时间：15:44:07]
#
# [状态：ok，尝试次数： 25] - 1000581;101776;A28;GATES
# [剩余数量：24291] - [当前时间：15:44:07]
#
# [状态：ok，尝试次数： 31] - 1000581;5419245;AP29;DAYCO
# [剩余数量：24290] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数： 26] - 1000581;672372;IA32;ACDELCO
# [剩余数量：24289] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数：  1] - 1000581;101779;A30;GATES
# [剩余数量：24288] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数：  1] - 1000581;5419263;AP35;DAYCO
# [剩余数量：24287] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数：  1] - 1000578;101130;3VX710;GATES
# [剩余数量：24286] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数：  1] - 1000581;5419266;AP36;DAYCO
# [剩余数量：24285] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数： 29] - 1000581;5419251;AP31;DAYCO
# [剩余数量：24284] - [当前时间：15:44:08]
#
# [状态：ok，尝试次数：  1] - 1000581;101781;A32;GATES
# [剩余数量：24283] - [当前时间：15:44:10]
#
# [状态：ok，尝试次数：  2] - 1000581;295779;AX29;GATES
# [剩余数量：24282] - [当前时间：15:44:10]
#
# [状态：ok，尝试次数：  3] - 1000581;101783;A34;GATES
# [剩余数量：24281] - [当前时间：15:44:10]
#
# [状态：ok，尝试次数： 47] - 1000581;5419254;AP32;DAYCO
# [剩余数量：24280] - [当前时间：15:44:10]
#
# [状态：ok，尝试次数：  1] - 1000581;101854;AX28;GATES
# [剩余数量：24279] - [当前时间：15:44:11]
#
# [状态：ok，尝试次数： 21] - 1000581;5545614;AX30;GATES
# [剩余数量：24278] - [当前时间：15:44:11]
#
# [状态：ok，尝试次数： 18] - 1000581;101860;AX36;GATES
# [剩余数量：24277] - [当前时间：15:44:12]
#
# [状态：ok，尝试次数： 17] - 1000581;5545629;A298;GATES
# [剩余数量：24276] - [当前时间：15:44:12]
#
# [状态：ok，尝试次数： 52] - 1000581;672367;IA28;ACDELCO
# [剩余数量：24275] - [当前时间：15:44:13]
#
# [状态：ok，尝试次数： 14] - 1000581;101784;A35;GATES
# [剩余数量：24274] - [当前时间：15:44:13]
#
# [状态：ok，尝试次数： 26] - 1000581;5419269;AP37;DAYCO
# [剩余数量：24273] - [当前时间：15:44:14]
#
# [状态：ok，尝试次数： 11] - 1000581;101857;AX33;GATES
# [剩余数量：24272] - [当前时间：15:44:14]
#
# [状态：ok，尝试次数：  1] - 1000581;5419224;AP22;DAYCO
# [剩余数量：24271] - [当前时间：15:44:14]
#
# [状态：ok，尝试次数： 49] - 1000578;101253;5VX1800;GATES
# [剩余数量：24270] - [当前时间：15:44:14]
#
# [状态：ok，尝试次数： 18] - 1000581;5419257;AP33;DAYCO
# [剩余数量：24269] - [当前时间：15:44:15]
#
# [状态：ok，尝试次数： 16] - 1000581;672365;IA26;ACDELCO
# [剩余数量：24268] - [当前时间：15:44:15]
#
# [状态：ok，尝试次数： 16] - 1000581;101856;AX32;GATES
# [剩余数量：24267] - [当前时间：15:44:15]
#
# [状态：ok，尝试次数：  3] - 1000581;672366;IA27;ACDELCO
# [剩余数量：24266] - [当前时间：15:44:15]
#
# [状态：ok，尝试次数： 12] - 1000581;101858;AX34;GATES
# [剩余数量：24265] - [当前时间：15:44:16]
#
# [状态：ok，尝试次数： 12] - 1000581;101855;AX31;GATES
# [剩余数量：24264] - [当前时间：15:44:17]
#
# [状态：ok，尝试次数： 16] - 1000581;101859;AX35;GATES
# [剩余数量：24263] - [当前时间：15:44:17]
#
# [状态：ok，尝试次数： 35] - 1000578;101260;5VX630;GATES
# [剩余数量：24262] - [当前时间：15:44:17]
#
# [状态：ok，尝试次数：  8] - 1000581;101772;A24;GATES
# [剩余数量：24261] - [当前时间：15:44:17]
#
# [状态：ok，尝试次数： 37] - 1000581;672364;IA25;ACDELCO
# [剩余数量：24260] - [当前时间：15:44:18]
#
# [状态：ok，尝试次数： 11] - 1000581;101773;A25;GATES
# [剩余数量：24259] - [当前时间：15:44:19]
#
# [状态：ok，尝试次数：  4] - 1000581;295775;AX22;GATES
# [剩余数量：24258] - [当前时间：15:44:19]
#
# [状态：ok，尝试次数： 35] - 1000581;5419230;AP24;DAYCO
# [剩余数量：24257] - [当前时间：15:44:19]
#
# [状态：ok，尝试次数： 26] - 1000581;5419239;AP27;DAYCO
# [剩余数量：24256] - [当前时间：15:44:20]
#
# [状态：ok，尝试次数：  3] - 1000581;101774;A26;GATES
# [剩余数量：24255] - [当前时间：15:44:20]
#
# [状态：ok，尝试次数：  4] - 1000581;295776;AX23;GATES
# [剩余数量：24254] - [当前时间：15:44:20]
#
# [状态：ok，尝试次数： 10] - 1000581;101853;AX26;GATES
# [剩余数量：24253] - [当前时间：15:44:20]
#
# [状态：ok，尝试次数：  2] - 1000581;295778;AX27;GATES
# [剩余数量：24252] - [当前时间：15:44:20]
#
# [状态：ok，尝试次数：  1] - 1000581;101803;A54;GATES
# [剩余数量：24251] - [当前时间：15:44:21]
#
# [状态：ok，尝试次数： 43] - 1000581;101782;A33;GATES
# [剩余数量：24250] - [当前时间：15:44:21]
#
# [状态：ok，尝试次数：  5] - 1000581;672397;IA57;ACDELCO
# [剩余数量：24249] - [当前时间：15:44:22]
#
# [状态：ok，尝试次数： 30] - 1000581;5419227;AP23;DAYCO
# [剩余数量：24248] - [当前时间：15:44:23]
#
# [状态：ok，尝试次数：  2] - 1000581;672391;IA51;ACDELCO
# [剩余数量：24247] - [当前时间：15:44:23]
#
# [状态：ok，尝试次数： 19] - 1000581;295777;AX24;GATES
# [剩余数量：24246] - [当前时间：15:44:25]
#
# [状态：ok，尝试次数： 29] - 1000581;672389;IA49;ACDELCO
# [剩余数量：24245] - [当前时间：15:44:25]
#
# [状态：ok，尝试次数： 33] - 1000581;101798;A49;GATES
# [剩余数量：24244] - [当前时间：15:44:25]
#
# [状态：ok，尝试次数：  1] - 1000581;101797;A48;GATES
# [剩余数量：24243] - [当前时间：15:44:25]
#
# [状态：ok，尝试次数：  8] - 1000581;5419311;AP51;DAYCO
# [剩余数量：24242] - [当前时间：15:44:26]
#
# [状态：ok，尝试次数： 45] - 1000581;672363;IA24;ACDELCO
# [剩余数量：24241] - [当前时间：15:44:26]
#
# [状态：ok，尝试次数： 35] - 1000581;5419233;AP25;DAYCO
# [剩余数量：24240] - [当前时间：15:44:26]
#
# [状态：ok，尝试次数：  1] - 1000581;5419314;AP52;DAYCO
# [剩余数量：24239] - [当前时间：15:44:26]
#
# [状态：ok，尝试次数： 24] - 1000581;101861;AX37;GATES
# [剩余数量：24238] - [当前时间：15:44:27]
#
# [状态：ok，尝试次数：  1] - 1000581;101799;A50;GATES
# [剩余数量：24237] - [当前时间：15:44:27]
#
# [状态：ok，尝试次数： 43] - 1000581;5419302;AP48;DAYCO
# [剩余数量：24236] - [当前时间：15:44:28]
#
# [状态：ok，尝试次数：  4] - 1000581;5419326;AP56;DAYCO
# [剩余数量：24235] - [当前时间：15:44:28]
#
# [状态：ok，尝试次数：  3] - 1000581;5419329;AP57;DAYCO
# [剩余数量：24234] - [当前时间：15:44:28]
#
# [状态：ok，尝试次数：  7] - 1000581;5419308;AP50;DAYCO
# [剩余数量：24233] - [当前时间：15:44:29]
#
# [状态：ok，尝试次数： 10] - 1000581;5419317;AP53;DAYCO
# [剩余数量：24232] - [当前时间：15:44:29]
#
# [状态：ok，尝试次数： 27] - 1000581;672390;IA50;ACDELCO
# [剩余数量：24231] - [当前时间：15:44:29]
#
# [状态：ok，尝试次数：  2] - 1000581;101869;AX48;GATES
# [剩余数量：24230] - [当前时间：15:44:30]
#
# [状态：ok，尝试次数：  4] - 1000581;5419305;AP49;DAYCO
# [剩余数量：24229] - [当前时间：15:44:30]
#
# [状态：ok，尝试次数：  1] - 1000581;672388;IA48;ACDELCO
# [剩余数量：24228] - [当前时间：15:44:31]
#
# [状态：ok，尝试次数： 10] - 1000581;672225;AX54;ACDELCO
# [剩余数量：24227] - [当前时间：15:44:31]
#
# [状态：ok，尝试次数：  1] - 1000581;295783;AX49;GATES
# [剩余数量：24226] - [当前时间：15:44:32]
#
# [状态：ok，尝试次数：  1] - 1000581;101871;AX53;GATES
# [剩余数量：24225] - [当前时间：15:44:32]
#
# [状态：ok，尝试次数： 12] - 1000581;101801;A52;GATES
# [剩余数量：24224] - [当前时间：15:44:32]
#
# [状态：ok，尝试次数：  7] - 1000581;5419236;AP26;DAYCO
# [剩余数量：24223] - [当前时间：15:44:33]
#
# [状态：ok，尝试次数： 14] - 1000581;101802;A53;GATES
# [剩余数量：24222] - [当前时间：15:44:33]
#
# [状态：ok，尝试次数：  1] - 1000581;101870;AX51;GATES
# [剩余数量：24221] - [当前时间：15:44:33]
#
# [状态：ok，尝试次数：  1] - 1000581;101873;AX55;GATES
# [剩余数量：24220] - [当前时间：15:44:34]
#
# [状态：ok，尝试次数：  1] - 1000581;295785;AX52;GATES
# [剩余数量：24219] - [当前时间：15:44:34]
#
# [状态：ok，尝试次数：  1] - 1000581;101872;AX54;GATES
# [剩余数量：24218] - [当前时间：15:44:34]
#
# [状态：ok，尝试次数： 11] - 1000581;101800;A51;GATES
# [剩余数量：24217] - [当前时间：15:44:35]
#
# [状态：ok，尝试次数：  2] - 1000581;295794;AX73;GATES
# [剩余数量：24216] - [当前时间：15:44:36]
#
# [状态：ok，尝试次数： 19] - 1000581;5419320;AP54;DAYCO
# [剩余数量：24215] - [当前时间：15:44:37]
#
# [状态：ok，尝试次数：  1] - 1000581;5419365;AP69;DAYCO
# [剩余数量：24214] - [当前时间：15:44:37]
#
# [状态：ok，尝试次数：  4] - 1000581;5419323;AP55;DAYCO
# [剩余数量：24213] - [当前时间：15:44:37]
#
# [状态：ok，尝试次数：  1] - 1000581;101824;A75;GATES
# [剩余数量：24212] - [当前时间：15:44:37]
#
# [状态：ok，尝试次数：  5] - 1000581;5419137;AA55;DAYCO
# [剩余数量：24211] - [当前时间：15:44:38]
#
# [状态：ok，尝试次数：  1] - 1000581;101874;AX56;GATES
# [剩余数量：24210] - [当前时间：15:44:38]
#
# [状态：ok，尝试次数：  1] - 1000581;672411;IA71;ACDELCO
# [剩余数量：24209] - [当前时间：15:44:38]
#
# [状态：ok，尝试次数：  4] - 1000581;295786;AX57;GATES
# [剩余数量：24208] - [当前时间：15:44:38]
#
# [状态：ok，尝试次数：  1] - 1000581;672412;IA72;ACDELCO
# [剩余数量：24207] - [当前时间：15:44:39]
#
# [状态：ok，尝试次数：  3] - 1000581;672413;IA73;ACDELCO
# [剩余数量：24206] - [当前时间：15:44:39]
#
# [状态：ok，尝试次数： 17] - 1000581;101804;A55;GATES
# [剩余数量：24205] - [当前时间：15:44:39]
#
# [状态：ok，尝试次数：  1] - 1000581;672416;IA76;ACDELCO
# [剩余数量：24204] - [当前时间：15:44:39]
#
# [状态：ok，尝试次数：  2] - 1000581;101805;A56;GATES
# [剩余数量：24203] - [当前时间：15:44:39]
#
# [状态：ok，尝试次数：  1] - 1000581;5419377;AP73;DAYCO
# [剩余数量：24202] - [当前时间：15:44:40]
#
# [状态：ok，尝试次数：  1] - 1000581;5419368;AP70;DAYCO
# [剩余数量：24201] - [当前时间：15:44:40]
#
# [状态：ok，尝试次数： 26] - 1000581;295784;AX50;GATES
# [剩余数量：24200] - [当前时间：15:44:41]
#
# [状态：ok，尝试次数：  4] - 1000581;101821;A72;GATES
# [剩余数量：24199] - [当前时间：15:44:41]
#
# [状态：ok，尝试次数：  7] - 1000581;5419380;AP74;DAYCO
# [剩余数量：24198] - [当前时间：15:44:41]
#
# [状态：ok，尝试次数：  1] - 1000581;5419371;AP71;DAYCO
# [剩余数量：24197] - [当前时间：15:44:41]
#
# [状态：ok，尝试次数： 13] - 1000581;5419362;AP68;DAYCO
# [剩余数量：24196] - [当前时间：15:44:42]
#
# [状态：ok，尝试次数：  7] - 1000581;5419374;AP72;DAYCO
# [剩余数量：24195] - [当前时间：15:44:42]
#
# [状态：ok，尝试次数： 12] - 1000581;101806;A57;GATES
# [剩余数量：24194] - [当前时间：15:44:42]
#
# [状态：ok，尝试次数：  1] - 1000581;101817;A68;GATES
# [剩余数量：24193] - [当前时间：15:44:43]
#
# [状态：ok，尝试次数： 14] - 1000581;5419386;AP76;DAYCO
# [剩余数量：24192] - [当前时间：15:44:43]
#
# [状态：ok，尝试次数： 14] - 1000581;101820;A71;GATES
# [剩余数量：24191] - [当前时间：15:44:43]
#
# [状态：ok，尝试次数：  9] - 1000581;672408;IA68;ACDELCO
# [剩余数量：24190] - [当前时间：15:44:43]
#
# [状态：ok，尝试次数： 94] - 1000581;101775;A27;GATES
# [剩余数量：24189] - [当前时间：15:44:44]
#
# [状态：ok，尝试次数：  8] - 1000581;672236;AX75;ACDELCO
# [剩余数量：24188] - [当前时间：15:44:44]
#
# [状态：ok，尝试次数：  5] - 1000581;101822;A73;GATES
# [剩余数量：24187] - [当前时间：15:44:44]
#
# [状态：ok，尝试次数：  7] - 1000581;5419389;AP77;DAYCO
# [剩余数量：24186] - [当前时间：15:44:44]
#
# [状态：ok，尝试次数： 27] - 1000581;5419383;AP75;DAYCO
# [剩余数量：24185] - [当前时间：15:44:45]
#
# [状态：ok，尝试次数： 28] - 1000581;5419248;AP30;DAYCO
# [剩余数量：24184] - [当前时间：15:44:45]
#
# [状态：ok，尝试次数：  1] - 1000581;101823;A74;GATES
# [剩余数量：24183] - [当前时间：15:44:46]
#
# [状态：ok，尝试次数：  6] - 1000581;101881;AX70;GATES
# [剩余数量：24182] - [当前时间：15:44:46]
#
# [状态：ok，尝试次数：  1] - 1000581;101825;A76;GATES
# [剩余数量：24181] - [当前时间：15:44:46]
#
# [状态：ok，尝试次数： 18] - 1000581;101826;A77;GATES
# [剩余数量：24180] - [当前时间：15:44:46]
#
# [状态：ok，尝试次数： 22] - 1000581;101880;AX68;GATES
# [剩余数量：24179] - [当前时间：15:44:46]
#
# [状态：ok，尝试次数： 37] - 1000581;101818;A69;GATES
# [剩余数量：24178] - [当前时间：15:44:47]
#
# [状态：ok，尝试次数：  2] - 1000581;5419146;AA68;DAYCO
# [剩余数量：24177] - [当前时间：15:44:47]
#
# [状态：ok，尝试次数：  9] - 1000581;295797;AX77;GATES
# [剩余数量：24176] - [当前时间：15:44:48]
#
# [状态：ok，尝试次数：  3] - 1000581;672400;IA60;ACDELCO
# [剩余数量：24175] - [当前时间：15:44:48]
#
# [状态：ok，尝试次数：  5] - 1000581;672415;IA75;ACDELCO
# [剩余数量：24174] - [当前时间：15:44:48]
#
# [状态：ok，尝试次数： 18] - 1000581;672404;IA64;ACDELCO
# [剩余数量：24173] - [当前时间：15:44:48]
#
# [状态：ok，尝试次数：  7] - 1000581;672401;IA61;ACDELCO
# [剩余数量：24172] - [当前时间：15:44:48]
#
# [状态：ok，尝试次数：  7] - 1000581;295793;AX72;GATES
# [剩余数量：24171] - [当前时间：15:44:49]
#
# [状态：ok，尝试次数：  4] - 1000581;5419332;AP58;DAYCO
# [剩余数量：24170] - [当前时间：15:44:49]
#
# [状态：ok，尝试次数： 17] - 1000581;295795;AX74;GATES
# [剩余数量：24169] - [当前时间：15:44:50]
#
# [状态：ok，尝试次数： 23] - 1000581;672407;IA67;ACDELCO
# [剩余数量：24168] - [当前时间：15:44:50]
#
# [状态：ok，尝试次数： 14] - 1000581;101882;AX71;GATES
# [剩余数量：24167] - [当前时间：15:44:50]
#
# [状态：ok，尝试次数：  7] - 1000581;101883;AX75;GATES
# [剩余数量：24166] - [当前时间：15:44:51]
#
# [状态：ok，尝试次数： 10] - 1000581;5419335;AP59;DAYCO
# [剩余数量：24165] - [当前时间：15:44:51]
#
# [状态：ok，尝试次数： 20] - 1000581;5419341;AP61;DAYCO
# [剩余数量：24164] - [当前时间：15:44:51]
#
# [状态：ok，尝试次数：  6] - 1000581;5419347;AP63;DAYCO
# [剩余数量：24163] - [当前时间：15:44:52]
#
# [状态：ok，尝试次数： 20] - 1000581;672405;IA65;ACDELCO
# [剩余数量：24162] - [当前时间：15:44:53]
#
# [状态：ok，尝试次数：  5] - 1000581;5419353;AP65;DAYCO
# [剩余数量：24161] - [当前时间：15:44:53]
#
# [状态：ok，尝试次数：  3] - 1000581;5419356;AP66;DAYCO
# [剩余数量：24160] - [当前时间：15:44:53]
#
# [状态：ok，尝试次数：  8] - 1000581;101808;A59;GATES
# [剩余数量：24159] - [当前时间：15:44:53]
#
# [状态：ok，尝试次数： 35] - 1000581;295796;AX76;GATES
# [剩余数量：24158] - [当前时间：15:44:54]
#
# [状态：ok，尝试次数：  2] - 1000581;101812;A63;GATES
# [剩余数量：24157] - [当前时间：15:44:54]
#
# [状态：ok，尝试次数： 11] - 1000581;101807;A58;GATES
# [剩余数量：24156] - [当前时间：15:44:56]
#
# [状态：ok，尝试次数： 17] - 1000581;101819;A70;GATES
# [剩余数量：24155] - [当前时间：15:44:56]
#
# [状态：ok，尝试次数：  9] - 1000581;101815;A66;GATES
# [剩余数量：24154] - [当前时间：15:44:56]
#
# [状态：ok，尝试次数：  1] - 1000581;101816;A67;GATES
# [剩余数量：24153] - [当前时间：15:44:57]
#
# [状态：ok，尝试次数： 12] - 1000581;101814;A65;GATES
# [剩余数量：24152] - [当前时间：15:44:58]
#
# [状态：ok，尝试次数： 16] - 1000581;101810;A61;GATES
# [剩余数量：24151] - [当前时间：15:44:58]
#
# [状态：ok，尝试次数：  1] - 1000581;101875;AX58;GATES
# [剩余数量：24150] - [当前时间：15:44:58]
#
# [状态：ok，尝试次数：  1] - 1000581;101811;A62;GATES
# [剩余数量：24149] - [当前时间：15:44:58]
#
# [状态：ok，尝试次数：  1] - 1000581;295789;AX63;GATES
# [剩余数量：24148] - [当前时间：15:44:59]
#
# [状态：ok，尝试次数：  5] - 1000581;295787;AX59;GATES
# [剩余数量：24147] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数： 17] - 1000581;101813;A64;GATES
# [剩余数量：24146] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数： 11] - 1000581;5419359;AP67;DAYCO
# [剩余数量：24145] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数：  5] - 1000581;101879;AX66;GATES
# [剩余数量：24144] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数： 22] - 1000581;672410;IA70;ACDELCO
# [剩余数量：24143] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数： 24] - 1000581;295790;AX65;GATES
# [剩余数量：24142] - [当前时间：15:45:00]
#
# [状态：ok，尝试次数：  1] - 1000581;1146368;AP64;GATES
# [剩余数量：24141] - [当前时间：15:45:01]
#
# [状态：ok，尝试次数：  1] - 1000581;672423;IA83;ACDELCO
# [剩余数量：24140] - [当前时间：15:45:01]
#
# [状态：ok，尝试次数：  7] - 1000581;295788;AX61;GATES
# [剩余数量：24139] - [当前时间：15:45:01]
#
# [状态：ok，尝试次数： 14] - 1000581;5419338;AP60;DAYCO
# [剩余数量：24138] - [当前时间：15:45:02]
#
# [状态：ok，尝试次数：  1] - 1000581;672424;IA84;ACDELCO
# [剩余数量：24137] - [当前时间：15:45:02]
#
# [状态：ok，尝试次数：  1] - 1000581;672422;IA82;ACDELCO
# [剩余数量：24136] - [当前时间：15:45:03]
#
# [状态：ok，尝试次数：  3] - 1000581;101827;A78;GATES
# [剩余数量：24135] - [当前时间：15:45:03]
#
# [状态：ok，尝试次数：  1] - 1000581;672426;IA86;ACDELCO
# [剩余数量：24134] - [当前时间：15:45:03]
#
# [状态：ok，尝试次数：  1] - 1000581;672427;IA87;ACDELCO
# [剩余数量：24133] - [当前时间：15:45:03]
#
# [状态：ok，尝试次数：  2] - 1000581;5419404;AP82;DAYCO
# [剩余数量：24132] - [当前时间：15:45:04]
#
# [状态：ok，尝试次数： 11] - 1000581;5419401;AP81;DAYCO
# [剩余数量：24131] - [当前时间：15:45:04]
#
# [状态：ok，尝试次数：  2] - 1000581;5419410;AP84;DAYCO
# [剩余数量：24130] - [当前时间：15:45:04]
#
# [状态：ok，尝试次数： 12] - 1000581;101877;AX62;GATES
# [剩余数量：24129] - [当前时间：15:45:05]
#
# [状态：ok，尝试次数： 31] - 1000581;101876;AX60;GATES
# [剩余数量：24128] - [当前时间：15:45:05]
#
# [状态：ok，尝试次数：  2] - 1000581;5419395;AP79;DAYCO
# [剩余数量：24127] - [当前时间：15:45:06]
#
# [状态：ok，尝试次数：  1] - 1000581;101832;A83;GATES
# [剩余数量：24126] - [当前时间：15:45:06]
#
# [状态：ok，尝试次数： 22] - 1000581;5419398;AP80;DAYCO
# [剩余数量：24125] - [当前时间：15:45:06]
#
# [状态：ok，尝试次数：  1] - 1000581;101830;A81;GATES
# [剩余数量：24124] - [当前时间：15:45:07]
#
# [状态：ok，尝试次数： 43] - 1000581;101809;A60;GATES
# [剩余数量：24123] - [当前时间：15:45:07]
#
# [状态：ok，尝试次数：  1] - 1000581;101831;A82;GATES
# [剩余数量：24122] - [当前时间：15:45:07]
#
# [状态：ok，尝试次数： 54] - 1000581;5419344;AP62;DAYCO
# [剩余数量：24121] - [当前时间：15:45:08]
#
# [状态：ok，尝试次数：  2] - 1000581;101836;A87;GATES
# [剩余数量：24120] - [当前时间：15:45:08]
#
# [状态：ok，尝试次数：  9] - 1000581;5419392;AP78;DAYCO
# [剩余数量：24119] - [当前时间：15:45:09]
#
# [状态：ok，尝试次数：  7] - 1000581;5419419;AP87;DAYCO
# [剩余数量：24118] - [当前时间：15:45:09]
#
# [状态：ok，尝试次数： 15] - 1000581;101829;A80;GATES
# [剩余数量：24117] - [当前时间：15:45:09]
#
# [状态：ok，尝试次数：  1] - 1000581;295802;AX87;GATES
# [剩余数量：24116] - [当前时间：15:45:10]
#
# [状态：ok，尝试次数：  6] - 1000581;101835;A86;GATES
# [剩余数量：24115] - [当前时间：15:45:10]
#
# [状态：ok，尝试次数：  4] - 1000581;101884;AX78;GATES
# [剩余数量：24114] - [当前时间：15:45:10]
#
# [状态：ok，尝试次数：  1] - 1000581;101886;AX85;GATES
# [剩余数量：24113] - [当前时间：15:45:11]
#
# [状态：ok，尝试次数：  7] - 1000581;101828;A79;GATES
# [剩余数量：24112] - [当前时间：15:45:11]
#
# [状态：ok，尝试次数：  1] - 1000581;672438;IA98;ACDELCO
# [剩余数量：24111] - [当前时间：15:45:11]
#
# [状态：ok，尝试次数：  1] - 1000581;101885;AX80;GATES
# [剩余数量：24110] - [当前时间：15:45:13]
#
# [状态：ok，尝试次数：  2] - 1000581;295801;AX86;GATES
# [剩余数量：24109] - [当前时间：15:45:14]
#
# [状态：ok，尝试次数： 16] - 1000581;672348;IA100;ACDELCO
# [剩余数量：24108] - [当前时间：15:45:15]
#
# [状态：ok，尝试次数：  8] - 1000581;101833;A84;GATES
# [剩余数量：24107] - [当前时间：15:45:15]
#
# [状态：ok，尝试次数：  1] - 1000581;5419164;AP100;DAYCO
# [剩余数量：24106] - [当前时间：15:45:15]
#
# [状态：ok，尝试次数：  1] - 1000581;672350;IA105;ACDELCO
# [剩余数量：24105] - [当前时间：15:45:16]
#
# [状态：ok，尝试次数：  1] - 1000581;672354;IA120;ACDELCO
# [剩余数量：24104] - [当前时间：15:45:17]
#
# [状态：ok，尝试次数：  3] - 1000581;5419452;AP98;DAYCO
# ...
#
# [状态：ok，尝试次数：  1] - 1000975;11963041;W1339;PERFORMANCE TOOL
# [剩余数量：18187] - [当前时间：16:34:47]
#
# [状态：ok，尝试次数：  1] - 1000975;11968181;W1337;PERFORMANCE TOOL
# [剩余数量：18186] - [当前时间：16:34:47]
#
# [状态：ok，尝试次数：  2] - 56831;8785616;W80624;PERFORMANCE TOOL
# [剩余数量：18185] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数：  1] - 1000975;8785748;W86022;PERFORMANCE TOOL
# [剩余数量：18184] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数： 15] - 1000977;14967829;W80561;PERFORMANCE TOOL
# [剩余数量：18183] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数：  6] - 1000975;621176;49015;DORMAN
# [剩余数量：18182] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数：  8] - 1000975;2784014;12550;LISLE
# [剩余数量：18181] - [当前时间：16:34:48]
#
# [状态：ok，尝试次数： 29] - 17282;580659;125007;DORMAN
# [剩余数量：18180] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数：  9] - 1000975;8785740;W86020;PERFORMANCE TOOL
# [剩余数量：18179] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数： 10] - 56831;12728697;48020;LISLE
# [剩余数量：18178] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数：  2] - 1000891;11957169;W80627;PERFORMANCE TOOL
# [剩余数量：18177] - [当前时间：16:34:49]
#
# [状态：ok，尝试次数：  4] - 1000977;8785640;W80633;PERFORMANCE TOOL
# [剩余数量：18176] - [当前时间：16:34:50]
#
# [状态：ok，尝试次数： 14] - 1000891;2783766;28600;LISLE
# [剩余数量：18175] - [当前时间：16:34:50]
#
# [状态：ok，尝试次数：  9] - 1000891;8785548;W80112;PERFORMANCE TOOL
# [剩余数量：18174] - [当前时间：16:34:52]
#
# [状态：ok，尝试次数： 12] - 1000891;8785720;W83165;PERFORMANCE TOOL
# [剩余数量：18173] - [当前时间：16:34:53]
#
# [状态：ok，尝试次数： 28] - 1000891;8785612;W80621;PERFORMANCE TOOL
# [剩余数量：18172] - [当前时间：16:34:53]
#
# [状态：ok，尝试次数： 47] - 1000891;11957165;W83166;PERFORMANCE TOOL
# [剩余数量：18171] - [当前时间：16:34:54]
#
# [状态：ok，尝试次数： 54] - 1000891;8785532;W209;PERFORMANCE TOOL
# [剩余数量：18170] - [当前时间：16:34:55]
#
# [状态：ok，尝试次数： 10] - 1000891;2784064;24300;LISLE
# [剩余数量：18169] - [当前时间：16:34:56]
#
# [状态：ok，尝试次数： 46] - 1000975;8785744;W86021;PERFORMANCE TOOL
# [剩余数量：18168] - [当前时间：16:34:57]
#
# [状态：ok，尝试次数： 99] - 1000608;614519;13910;DORMAN
# [剩余数量：18167] - [当前时间：16:34:58]
#
# [状态：ok，尝试次数： 60] - 1000891;2784198;25000;LISLE
# [剩余数量：18166] - [当前时间：16:34:58]
#
# [状态：ok，尝试次数： 38] - 1000891;15172585;25200;LISLE
# [剩余数量：18165] - [当前时间：16:34:59]
#
# [状态：ok，尝试次数： 41] - 1000891;12302645;SM2396;SHEE-MAR
# [剩余数量：18164] - [当前时间：16:34:59]
#
# [状态：ok，尝试次数： 65] - 1000975;5812680;33960;LISLE
# [剩余数量：18163] - [当前时间：16:35:00]
#
# [状态：ok，尝试次数：  6] - 1000891;8785760;W89200;PERFORMANCE TOOL
# [剩余数量：18162] - [当前时间：16:35:00]
#
# [状态：ok，尝试次数： 39] - 1000891;2784368;25750;LISLE
# [剩余数量：18161] - [当前时间：16:35:00]
#
# [状态：ok，尝试次数： 36] - 1000891;14741737;FA14;S.U.R.&R.
# [剩余数量：18160] - [当前时间：16:35:01]
#
# [状态：ok，尝试次数： 24] - 1001056;14959897;W86025;PERFORMANCE TOOL
# [剩余数量：18159] - [当前时间：16:35:02]
#
# [状态：ok，尝试次数： 34] - 1001056;15172605;29120;LISLE
# [剩余数量：18158] - [当前时间：16:35:02]
#
# [状态：ok，尝试次数：  4] - 18938;12553113;12560;LISLE
# [剩余数量：18157] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数：  9] - 1000891;8786012;29350;LISLE
# [剩余数量：18156] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数： 27] - 1000891;10895661;W80110;PERFORMANCE TOOL
# [剩余数量：18155] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数： 16] - 1000978;2783834;48400;LISLE
# [剩余数量：18154] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数： 79] - 1000891;2783922;24400;LISLE
# [剩余数量：18153] - [当前时间：16:35:03]
#
# [状态：ok，尝试次数： 68] - 1002076;14967257;W84551;PERFORMANCE TOOL
# [剩余数量：18152] - [当前时间：16:35:04]
#
# [状态：ok，尝试次数： 37] - 18938;9477164;WGM38;PERFORMANCE TOOL
# [剩余数量：18151] - [当前时间：16:35:04]
#
# [状态：ok，尝试次数：  3] - 1000981;2783982;40750;LISLE
# [剩余数量：18150] - [当前时间：16:35:04]
#
# [状态：ok，尝试次数： 11] - 1000984;3616116;20300;LISLE
# [剩余数量：18149] - [当前时间：16:35:05]
#
# [状态：ok，尝试次数：  6] - 320;8785784;W89325;PERFORMANCE TOOL
# [剩余数量：18148] - [当前时间：16:35:06]
#
# [状态：ok，尝试次数： 34] - 1000984;3616992;75400;LISLE
# [剩余数量：18147] - [当前时间：16:35:07]
#
# [状态：ok，尝试次数： 40] - 18938;12553109;12450;LISLE
# [剩余数量：18146] - [当前时间：16:35:07]
#
# [状态：ok，尝试次数：  6] - 320;8785808;W89725;PERFORMANCE TOOL
# [剩余数量：18145] - [当前时间：16:35:07]
#
# [状态：ok，尝试次数： 20] - 10479;6337728;03006;DORMAN
# [剩余数量：18144] - [当前时间：16:35:08]
#
# [状态：ok，尝试次数：  4] - 11542;11305632;030008;DORMAN
# [剩余数量：18143] - [当前时间：16:35:09]
#
# [状态：ok，尝试次数：  8] - 320;15172761;40100;LISLE
# [剩余数量：18142] - [当前时间：16:35:09]
#
# [状态：ok，尝试次数： 11] - 1956;580331;11304;DORMAN
# [剩余数量：18141] - [当前时间：16:35:09]
#
# [状态：ok，尝试次数： 11] - 1001812;8785944;19852;LISLE
# [剩余数量：18140] - [当前时间：16:35:10]
#
# [状态：ok，尝试次数： 31] - 1956;580813;13690;DORMAN
# [剩余数量：18139] - [当前时间：16:35:12]
#
# [状态：ok，尝试次数： 10] - 1000891;12553261;29100;LISLE
# [剩余数量：18138] - [当前时间：16:35:12]
#
# [状态：ok，尝试次数： 27] - 18938;9477168;WGM56;PERFORMANCE TOOL
# [剩余数量：18137] - [当前时间：16:35:12]
#
# [状态：ok，尝试次数： 20] - 1956;582100;19349;DORMAN
# [剩余数量：18136] - [当前时间：16:35:13]
#
# [状态：ok，尝试次数： 14] - 2180;3843783;3652;HAYDEN
# [剩余数量：18135] - [当前时间：16:35:14]
#
# [状态：ok，尝试次数： 16] - 2180;4791498;3647;HAYDEN
# [剩余数量：18134] - [当前时间：16:35:14]
#
# [状态：ok，尝试次数：  7] - 1000982;2783972;21520;LISLE
# [剩余数量：18133] - [当前时间：16:35:14]
#
# [状态：ok，尝试次数： 17] - 2180;3843714;3653;HAYDEN
# [剩余数量：18132] - [当前时间：16:35:14]
#
# [状态：ok，尝试次数：  5] - 11393;13527801;GREEN5050GAL;FVP
# [剩余数量：18131] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数： 15] - 1000891;8785764;W89201;PERFORMANCE TOOL
# [剩余数量：18130] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数： 27] - 2180;4664736;35879;FOUR SEASONS
# [剩余数量：18129] - [当前时间：16:35:15]
#
# [状态：ok，尝试次数： 13] - 11393;13527805;MV5050GAL;FVP
# [剩余数量：18128] - [当前时间：16:35:16]
#
# [状态：ok，尝试次数： 43] - 2180;3843708;3651;HAYDEN
# [剩余数量：18127] - [当前时间：16:35:17]
#
# [状态：ok，尝试次数： 29] - 11393;12973401;AF3300;PRESTONE
# [剩余数量：18126] - [当前时间：16:35:17]
#
# [状态：ok，尝试次数： 16] - 11393;10411229;ZX001;VALVOLINE
# [剩余数量：18125] - [当前时间：16:35:18]
#
# [状态：ok，尝试次数： 25] - 320;2784382;39250;LISLE
# [剩余数量：18124] - [当前时间：16:35:18]
#
# [状态：ok，尝试次数：  1] - 11393;12973425;AF6400;PRESTONE
# [剩余数量：18123] - [当前时间：16:35:18]
#
# [状态：ok，尝试次数： 18] - 320;8785780;W89324;PERFORMANCE TOOL
# [剩余数量：18122] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数： 67] - 320;2783994;38210;LISLE
# [剩余数量：18121] - [当前时间：16:35:19]
#
# [状态：ok，尝试次数： 14] - 11393;12973405;AF3400;PRESTONE
# [剩余数量：18120] - [当前时间：16:35:20]
#
# [状态：ok，尝试次数：  4] - 11393;10411221;719009;VALVOLINE
# [剩余数量：18119] - [当前时间：16:35:20]
#
# [状态：ok，尝试次数：  8] - 11393;7668852;8114117;PENTOSIN
# [剩余数量：18118] - [当前时间：16:35:21]
#
# [状态：ok，尝试次数： 59] - 11393;13527797;DEX5050GAL;FVP
# [剩余数量：18117] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数： 71] - 11393;12973397;AF3100;PRESTONE
# [剩余数量：18116] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数： 26] - 11393;14990840;888418;VALVOLINE
# [剩余数量：18115] - [当前时间：16:35:22]
#
# [状态：ok，尝试次数： 42] - 11393;7668836;8113106;PENTOSIN
# [剩余数量：18114] - [当前时间：16:35:23]
#
# [状态：ok，尝试次数： 11] - 11393;10411265;ZXEL1;VALVOLINE
# [剩余数量：18113] - [当前时间：16:35:24]
#
# [状态：ok，尝试次数： 52] - 11393;12973441;AF850;PRESTONE
# [剩余数量：18112] - [当前时间：16:35:24]
#
# [状态：ok，尝试次数： 10] - 11393;10858600;859537;VALVOLINE
# [剩余数量：18111] - [当前时间：16:35:24]
#
# [状态：ok，尝试次数： 28] - 11393;10411273;675130;VALVOLINE
# [剩余数量：18110] - [当前时间：16:35:25]
#
# [状态：ok，尝试次数：  1] - 11393;14898885;V600164US;VAICO
# [剩余数量：18109] - [当前时间：16:35:26]
#
# [状态：ok，尝试次数： 21] - 11393;10697520;VC13G;MOTORCRAFT
# [剩余数量：18108] - [当前时间：16:35:26]
#
# [状态：ok，尝试次数： 11] - 11393;8120628;VC5;MOTORCRAFT
# [剩余数量：18107] - [当前时间：16:35:27]
#
# [状态：ok，尝试次数：  6] - 11393;10858604;861399;VALVOLINE
# [剩余数量：18106] - [当前时间：16:35:27]
#
# [状态：ok，尝试次数： 25] - 11393;9721800;105027;ACDELCO
# [剩余数量：18105] - [当前时间：16:35:27]
#
# [状态：ok，尝试次数： 10] - 11393;7668848;8114107;PENTOSIN
# [剩余数量：18104] - [当前时间：16:35:28]
#
# [状态：ok，尝试次数： 14] - 11393;9472272;68163848AB;MOPAR
# [剩余数量：18103] - [当前时间：16:35:29]
#
# [状态：ok，尝试次数： 13] - 11393;8453512;2521023;BECK/ARNLEY
# [剩余数量：18102] - [当前时间：16:35:29]
#
# [状态：ok，尝试次数： 25] - 11393;6304125;2521001;BECK/ARNLEY
# [剩余数量：18101] - [当前时间：16:35:30]
#
# [状态：ok，尝试次数：  9] - 11393;7668892;8115209;PENTOSIN
# [剩余数量：18100] - [当前时间：16:35:31]
#
# [状态：ok，尝试次数： 17] - 11393;8491476;8115213;PENTOSIN
# [剩余数量：18099] - [当前时间：16:35:31]
#
# [状态：ok，尝试次数：  1] - 11393;8453464;2521022;BECK/ARNLEY
# [剩余数量：18098] - [当前时间：16:35:31]
#
# [状态：ok，尝试次数：  7] - 11393;8120608;VC10A2;MOTORCRAFT
# [剩余数量：18097] - [当前时间：16:35:32]
#
# [状态：ok，尝试次数：  7] - 11393;7668840;8113206;PENTOSIN
# [剩余数量：18096] - [当前时间：16:35:32]
#
# [状态：ok，尝试次数：  7] - 11393;8491480;8115215;PENTOSIN
# [剩余数量：18095] - [当前时间：16:35:33]
#
# [状态：ok，尝试次数：  5] - 11393;10411225;ZXPCRU1;VALVOLINE
# [剩余数量：18094] - [当前时间：16:35:33]
#
# [状态：ok，尝试次数：  1] - 11393;12976989;AFC10000;PRESTONE
# [剩余数量：18093] - [当前时间：16:35:34]
#
# [状态：ok，尝试次数： 53] - 320;2783942;39300;LISLE
# [剩余数量：18092] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数： 17] - 11393;8120640;VC7B;MOTORCRAFT
# [剩余数量：18091] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数：  3] - 11393;14892645;AFC12100;PRESTONE
# [剩余数量：18090] - [当前时间：16:35:35]
#
# [状态：ok，尝试次数： 10] - 11393;10411253;841943;VALVOLINE
# [剩余数量：18089] - [当前时间：16:35:36]
#
# [状态：ok，尝试次数：  3] - 11393;10411257;ZXED1;VALVOLINE
# [剩余数量：18088] - [当前时间：16:35:36]
#
# [状态：ok，尝试次数： 35] - 11393;9471656;68048953AA;MOPAR
# [剩余数量：18087] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数： 59] - 11393;10411277;861398;VALVOLINE
# [剩余数量：18086] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数： 10] - 11393;14892661;AFC13000;PRESTONE
# [剩余数量：18085] - [当前时间：16:35:37]
#
# [状态：ok，尝试次数： 31] - 1001056;14959901;W80603;PERFORMANCE TOOL
# [剩余数量：18084] - [当前时间：16:35:39]
#
# [状态：ok，尝试次数：  1] - 11393;12976981;AF225;PRESTONE
# [剩余数量：18083] - [当前时间：16:35:39]
#
# [状态：ok，尝试次数：  9] - 11393;15001105;HDGOLDGAL;FVP
# [剩余数量：18082] - [当前时间：16:35:40]
#
# [状态：ok，尝试次数：  8] - 11393;15001101;HDRED5050GAL;FVP
# [剩余数量：18081] - [当前时间：16:35:41]
#
# [状态：ok，尝试次数： 18] - 11393;6304131;2521020;BECK/ARNLEY
# [剩余数量：18080] - [当前时间：16:35:41]
#
# [状态：ok，尝试次数： 29] - 11393;10411241;846439;VALVOLINE
# [剩余数量：18079] - [当前时间：16:35:42]
#
# [状态：ok，尝试次数：  2] - 11393;15006905;AF6510;PRESTONE
# [剩余数量：18078] - [当前时间：16:35:42]
#
# [状态：ok，尝试次数：  4] - 11393;15006901;AF6410;PRESTONE
# [剩余数量：18077] - [当前时间：16:35:42]
#
# [状态：ok，尝试次数：  4] - 11393;15006909;AF6610;PRESTONE
# [剩余数量：18076] - [当前时间：16:35:43]
#
# [状态：ok，尝试次数：  8] - 11393;15006889;AF6110;PRESTONE
# [剩余数量：18075] - [当前时间：16:35:44]
#
# [状态：ok，尝试次数： 11] - 11393;15006897;AF6310;PRESTONE
# [剩余数量：18074] - [当前时间：16:35:45]
#
# [状态：ok，尝试次数：  4] - 11393;6304137;2521502;BECK/ARNLEY
# [剩余数量：18073] - [当前时间：16:35:46]
#
# [状态：ok，尝试次数： 28] - 11393;6304128;2521002;BECK/ARNLEY
# [剩余数量：18072] - [当前时间：16:35:46]
#
# [状态：ok，尝试次数： 24] - 11393;8453516;2521501;BECK/ARNLEY
# [剩余数量：18071] - [当前时间：16:35:46]
#
# [状态：ok，尝试次数： 22] - 11393;7668684;ACT002;AISIN
# [剩余数量：18070] - [当前时间：16:35:46]
#
# [状态：ok，尝试次数：  8] - 11393;7668680;ACB003;AISIN
# [剩余数量：18069] - [当前时间：16:35:47]
#
# [状态：ok，尝试次数：  7] - 11393;13931301;ACG004;AISIN
# [剩余数量：18068] - [当前时间：16:35:48]
#
# [状态：ok，尝试次数：  4] - 14574;8319200;VC8;MOTORCRAFT
# [剩余数量：18067] - [当前时间：16:35:48]
#
# [状态：ok，尝试次数： 12] - 1002058;13615153;LF3001;LEAKFINDER
# [剩余数量：18066] - [当前时间：16:35:49]
#
# [状态：ok，尝试次数：  5] - 1002058;13615157;LF3008;LEAKFINDER
# [剩余数量：18065] - [当前时间：16:35:50]
#
# [状态：ok，尝试次数： 35] - 1002058;15030577;105046;ACDELCO
# [剩余数量：18064] - [当前时间：16:35:50]
#
# [状态：ok，尝试次数：  4] - 14574;9457060;96001;LUBEGARD
# [剩余数量：18063] - [当前时间：16:35:50]
#
# [状态：ok，尝试次数： 12] - 11393;12973389;AF2100;PRESTONE
# [剩余数量：18062] - [当前时间：16:35:51]
#
# [状态：ok，尝试次数： 23] - 1001880;9459404;4917;JOHNSEN'S
# [剩余数量：18061] - [当前时间：16:35:51]
#
# [状态：ok，尝试次数： 14] - 1001880;10938385;2051;LIQUI MOLY
# [剩余数量：18060] - [当前时间：16:35:52]
#
# [状态：ok，尝试次数： 14] - 14574;8319196;VC12;MOTORCRAFT
# [剩余数量：18059] - [当前时间：16:35:52]
#
# [状态：ok，尝试次数：  3] - 1001880;8319192;VC1;MOTORCRAFT
# [剩余数量：18058] - [当前时间：16:35:53]
#
# [状态：ok，尝试次数： 16] - 1002058;15030585;105057;ACDELCO
# [剩余数量：18057] - [当前时间：16:35:53]
#
# [状态：ok，尝试次数： 22] - 11393;10411245;ZXG051;VALVOLINE
# [剩余数量：18056] - [当前时间：16:35:53]
#
# [状态：ok，尝试次数：  7] - 1001880;10147469;C1412;MOTOR MEDIC
# [剩余数量：18055] - [当前时间：16:35:53]
#
# [状态：ok，尝试次数：  6] - 17603;15030513;10108;ACDELCO
# [剩余数量：18054] - [当前时间：16:35:54]
#
# [状态：ok，尝试次数：  6] - 1001880;9457048;95020;LUBEGARD
# [剩余数量：18053] - [当前时间：16:35:54]
#
# [状态：ok，尝试次数：  6] - 1001880;8319204;VC9;MOTORCRAFT
# [剩余数量：18052] - [当前时间：16:35:55]
#
# [状态：ok，尝试次数： 19] - 17603;12977005;AS120;PRESTONE
# [剩余数量：18051] - [当前时间：16:35:55]
#
# [状态：ok，尝试次数： 19] - 17603;12977009;AS145;PRESTONE
# [剩余数量：18050] - [当前时间：16:35:56]
#
# [状态：ok，尝试次数： 32] - 17603;10933340;20132;LIQUI MOLY
# [剩余数量：18049] - [当前时间：16:35:56]
#
# [状态：ok，尝试次数：  7] - 1000815;588016;493101;DORMAN
# [剩余数量：18048] - [当前时间：16:35:57]
#
# [状态：ok，尝试次数：  2] - 2176;10856820;328000;EDELMANN
# [剩余数量：18047] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数： 22] - 2068;100259;31308;GATES
# [剩余数量：18046] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数：111] - 11393;7668884;8115207;PENTOSIN
# [剩余数量：18045] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数： 18] - 2068;100260;31309;GATES
# [剩余数量：18044] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数：  7] - 2068;100266;31348;GATES
# [剩余数量：18043] - [当前时间：16:35:58]
#
# [状态：ok，尝试次数：  4] - 2176;10856792;311400;EDELMANN
# [剩余数量：18042] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数： 12] - 2176;10856788;310200;EDELMANN
# [剩余数量：18041] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数： 51] - 1000815;588015;493100;DORMAN
# [剩余数量：18040] - [当前时间：16:35:59]
#
# [状态：ok，尝试次数： 10] - 2181;3584031;3680;HAYDEN
# [剩余数量：18039] - [当前时间：16:36:01]
#
# [状态：ok，尝试次数： 20] - 2176;10856804;321000;EDELMANN
# [剩余数量：18038] - [当前时间：16:36:01]
#
# [状态：ok，尝试次数： 29] - 2176;10856816;327000;EDELMANN
# [剩余数量：18037] - [当前时间：16:36:02]
#
# [状态：ok，尝试次数： 36] - 17603;9459432;4918;JOHNSEN'S
# [剩余数量：18036] - [当前时间：16:36:03]
#
# [状态：ok，尝试次数： 64] - 1001805;11968789;W3000;PERFORMANCE TOOL
# [剩余数量：18035] - [当前时间：16:36:04]
#
# [状态：ok，尝试次数：  3] - 2181;3583992;3700;HAYDEN
# [剩余数量：18034] - [当前时间：16:36:06]
#
# [状态：ok，尝试次数： 24] - 2181;3584364;3670;HAYDEN
# [剩余数量：18033] - [当前时间：16:36:06]
#
# [状态：ok，尝试次数：  9] - 2181;11920725;3900;HAYDEN
# [剩余数量：18032] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数： 11] - 2181;3578058;36898;FOUR SEASONS
# [剩余数量：18031] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数：  9] - 2181;3584262;3690;HAYDEN
# [剩余数量：18030] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数：  2] - 2181;11920729;3901;HAYDEN
# [剩余数量：18029] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数：  1] - 2181;3577800;36896;FOUR SEASONS
# [剩余数量：18028] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数： 12] - 2176;10856824;329000;EDELMANN
# [剩余数量：18027] - [当前时间：16:36:07]
#
# [状态：ok，尝试次数：  2] - 2181;11920733;3910;HAYDEN
# [剩余数量：18026] - [当前时间：16:36:08]
#
# [状态：ok，尝试次数： 13] - 2181;11920753;3931;HAYDEN
# [剩余数量：18025] - [当前时间：16:36:10]
#
# [状态：ok，尝试次数： 16] - 2181;11920737;3911;HAYDEN
# [剩余数量：18024] - [当前时间：16:36:10]
#
# [状态：ok，尝试次数： 47] - 2181;3577989;36897;FOUR SEASONS
# [剩余数量：18023] - [当前时间：16:36:11]
#
# [状态：ok，尝试次数：  6] - 305;586780;47122;DORMAN
# [剩余数量：18022] - [当前时间：16:36:12]
#
# [状态：ok，尝试次数： 71] - 11393;14990836;888374;VALVOLINE
# [剩余数量：18021] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数： 14] - 11393;10858616;877981;VALVOLINE
# [剩余数量：18020] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数： 35] - 2181;3577938;36895;FOUR SEASONS
# [剩余数量：18019] - [当前时间：16:36:14]
#
# [状态：ok，尝试次数： 18] - 305;11306192;47126A;DORMAN
# [剩余数量：18018] - [当前时间：16:36:15]
#
# [状态：ok，尝试次数： 85] - 1956;582099;19341;DORMAN
# [剩余数量：18017] - [当前时间：16:36:15]
#
# [状态：ok，尝试次数： 41] - 305;586779;47121;DORMAN
# [剩余数量：18016] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数： 43] - 2181;3584439;3710;HAYDEN
# [剩余数量：18015] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数： 13] - 305;586709;47018;DORMAN
# [剩余数量：18014] - [当前时间：16:36:16]
#
# [状态：ok，尝试次数：  9] - 305;11306188;47125A;DORMAN
# [剩余数量：18013] - [当前时间：16:36:17]
#
# [状态：ok，尝试次数： 41] - 11393;15006893;AF6210;PRESTONE
# [剩余数量：18012] - [当前时间：16:36:17]
#
# [状态：ok，尝试次数： 18] - 1000830;613971;10665;DORMAN
# [剩余数量：18011] - [当前时间：16:36:18]
#
# [状态：ok，尝试次数： 31] - 2181;11920745;3921;HAYDEN
# [剩余数量：18010] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数： 10] - 2200;100562;33347;GATES
# [剩余数量：18009] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数： 20] - 11393;12976993;AFC11000;PRESTONE
# [剩余数量：18008] - [当前时间：16:36:19]
#
# [状态：ok，尝试次数： 53] - 2181;11920741;3920;HAYDEN
# [剩余数量：18007] - [当前时间：16:36:20]
#
# [状态：ok，尝试次数：  1] - 1000816;577705;24240;WIX
# [剩余数量：18006] - [当前时间：16:36:20]
#
# [状态：ok，尝试次数：  9] - 1000816;577685;24105;WIX
# [剩余数量：18005] - [当前时间：16:36:21]
#
# [状态：ok，尝试次数： 32] - 2181;11920749;3930;HAYDEN
# [剩余数量：18004] - [当前时间：16:36:21]
#
# [状态：ok，尝试次数： 38] - 305;586781;47125;DORMAN
# [剩余数量：18003] - [当前时间：16:36:21]
#
# [状态：ok，尝试次数：  8] - 1000616;11957685;W1655C;PERFORMANCE TOOL
# [剩余数量：18002] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数：  2] - 305;586778;47120;DORMAN
# [剩余数量：18001] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数： 28] - 1000816;577686;24106;WIX
# [剩余数量：18000] - [当前时间：16:36:22]
#
# [状态：ok，尝试次数： 29] - 1000337;2849397;LP14MFT;METRO
# [剩余数量：17999] - [当前时间：16:36:23]
#
# [状态：ok，尝试次数： 32] - 2200;5546310;34034;GATES
# [剩余数量：17998] - [当前时间：16:36:23]
#
# [状态：ok，尝试次数：  5] - 249;100310;31425;GATES
# [剩余数量：17997] - [当前时间：16:36:24]
#
# [状态：ok，尝试次数：  8] - 1000616;612719;91001;GATES
# [剩余数量：17996] - [当前时间：16:36:24]
#
# [状态：ok，尝试次数： 20] - 249;100305;31420;GATES
# [剩余数量：17995] - [当前时间：16:36:25]
#
# [状态：ok，尝试次数： 20] - 1000616;11441857;W1656C;PERFORMANCE TOOL
# [剩余数量：17994] - [当前时间：16:36:26]
#
# [状态：ok，尝试次数： 32] - 305;586783;47127;DORMAN
# [剩余数量：17993] - [当前时间：16:36:27]
#
# [状态：ok，尝试次数： 21] - 249;100302;31416;GATES
# [剩余数量：17992] - [当前时间：16:36:27]
