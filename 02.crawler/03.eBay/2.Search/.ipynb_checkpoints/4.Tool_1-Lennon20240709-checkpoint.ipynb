# %%
import pandas as pd
import json

input_ = pd.read_excel(f'./3.item.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_[input_['Json_Compatibility'] != json.dumps('')].reset_index(drop=True)

input_
# Out:
#         No   Item Number                                              Title  \
# 0        1  312755157869  18 Piece Steering &amp; Suspension Kit Control...
# 1        2  131961711574  Front &amp; Rear Strut Spring Outer Tie Rod En...
# 2        3  132593161426  7 Piece Steering &amp; Suspension Kit Rack &am...
# 3        4  372474337712  12 Piece Steering &amp; Suspension Kit Complet...
# 4        5  133602141788  Control Arm Sway Link Tie Rod Hub Steering Sus...
# ...    ...           ...                                                ...
# 2692  2697  372350327405  Front Bearing Wheel Seal Pair Driver &amp; Pas...
# 2693  2698  373384912335  Valve Cover Retaining Bolt Sealing Grommet Set...
# 2694  2699  131125984971  Front Inner Wheel Seal Pair Set for SLX Passpo...
# 2695  2700  312732823880  Thermostat Housing Plug O Ring Seal Retainer K...
# 2696  2701  133944723164  IPR Injection Pressure Regulator Valve Seal Ki...
#
#                                           Subtitle       Price    Available  \
# 0     Order by Noon EST and this part ships today!  US $683.34  7 available
# 1     Order by Noon EST and this part ships today!  US $621.16
# 2     Order by Noon EST and this part ships today!  US $619.25  5 available
# 3     Order by Noon EST and this part ships today!  US $606.97  5 available
# 4     Order by Noon EST and this part ships today!  US $593.99  7 available
# ...                                            ...         ...          ...
# 2692  Order by Noon EST and this part ships today!   US $12.99  5 available
# 2693  Order by Noon EST and this part ships today!   US $12.58  5 available
# 2694  Order by Noon EST and this part ships today!   US $11.36  5 available
# 2695  Order by Noon EST and this part ships today!   US $10.32  3 available
# 2696  Order by Noon EST and this part ships today!    US $9.41  5 available
#
#          Sold                                 Json_Compatibility Picture  \
# 0              {"market": "US", "page": 1, "data": {"scopedCo...
# 1      4 sold  {"market": "US", "page": 3, "data": {"scopedCo...
# 2              {"market": "US", "page": 45, "data": {"scopedC...
# 3      4 sold  {"market": "US", "page": 1, "data": {"scopedCo...
# 4              {"market": "US", "page": 2, "data": {"scopedCo...
# ...       ...                                                ...     ...
# 2692  10 sold  {"market": "US", "page": 30, "data": {"scopedC...
# 2693  63 sold  {"market": "US", "page": 16, "data": {"scopedC...
# 2694   9 sold  {"market": "US", "page": 12, "data": {"scopedC...
# 2695  17 sold  {"market": "US", "page": 20, "data": {"scopedC...
# 2696   4 sold  {"market": "US", "page": 39, "data": {"scopedC...
#
#                                                     Url  \
# 0     https://www.ebay.com/itm/312755157869?_ul=US&_...
# 1     https://www.ebay.com/itm/131961711574?_ul=US&_...
# 2     https://www.ebay.com/itm/132593161426?_ul=US&_...
# 3     https://www.ebay.com/itm/372474337712?_ul=US&_...
# 4     https://www.ebay.com/itm/133602141788?_ul=US&_...
# ...                                                 ...
# 2692  https://www.ebay.com/itm/372350327405?_ul=US&_...
# 2693  https://www.ebay.com/itm/373384912335?_ul=US&_...
# 2694  https://www.ebay.com/itm/131125984971?_ul=US&_...
# 2695  https://www.ebay.com/itm/312732823880?_ul=US&_...
# 2696  https://www.ebay.com/itm/133944723164?_ul=US&_...
#
#                                         Description Url  \
# 0     https://vi.vipr.ebaydesc.com/itmdesc/312755157...
# 1     https://vi.vipr.ebaydesc.com/itmdesc/131961711...
# 2     https://vi.vipr.ebaydesc.com/itmdesc/132593161...
# 3     https://vi.vipr.ebaydesc.com/itmdesc/372474337...
# 4     https://vi.vipr.ebaydesc.com/itmdesc/133602141...
# ...                                                 ...
# 2692  https://vi.vipr.ebaydesc.com/itmdesc/372350327...
# 2693  https://vi.vipr.ebaydesc.com/itmdesc/373384912...
# 2694  https://vi.vipr.ebaydesc.com/itmdesc/131125984...
# 2695  https://vi.vipr.ebaydesc.com/itmdesc/312732823...
# 2696  https://vi.vipr.ebaydesc.com/itmdesc/133944723...
#
#                                                Json_Src  \
# 0     {"0": "https://i.ebayimg.com/images/g/Qy8AAOSw...
# 1     {"0": "https://i.ebayimg.com/images/g/MZwAAOSw...
# 2     {"0": "https://i.ebayimg.com/images/g/EFIAAOSw...
# 3     {"0": "https://i.ebayimg.com/images/g/LoYAAOSw...
# 4     {"0": "https://i.ebayimg.com/images/g/XK4AAOSw...
# ...                                                 ...
# 2692  {"0": "https://i.ebayimg.com/images/g/XHUAAOSw...
# 2693  {"0": "https://i.ebayimg.com/images/g/AMIAAOSw...
# 2694  {"0": "https://i.ebayimg.com/images/g/RIgAAOSw...
# 2695  {"0": "https://i.ebayimg.com/images/g/dr8AAOSw...
# 2696  {"0": "https://i.ebayimg.com/images/g/G4YAAOSw...
#
#                                           Json_Specific
# 0     {"0": {"Condition": "New: A brand-new, unused,...
# 1     {"0": {"Condition": "New: A brand-new, unused,...
# 2     {"0": {"Condition": "New: A brand-new, unused,...
# 3     {"0": {"Condition": "New: A brand-new, unused,...
# 4     {"0": {"Condition": "New: A brand-new, unused,...
# ...                                                 ...
# 2692  {"0": {"Condition": "New: A brand-new, unused,...
# 2693  {"0": {"Condition": "New: A brand-new, unused,...
# 2694  {"0": {"Condition": "New: A brand-new, unused,...
# 2695  {"0": {"Condition": "New: A brand-new, unused,...
# 2696  {"0": {"Condition": "New: A brand-new, unused,...
#
# [2697 rows x 13 columns]

# %%
from tqdm import tqdm

output = pd.DataFrame()
for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    json_ = json.loads(input_.loc[i, 'Json_Compatibility'])
    if json_['market'] == 'US':
        list_vehicle_url = [f'''https://www.ebay.com/g/api/finders?module_groups=PART_FINDER&referrer=VIEWITEM&offset={j*20}&module=COMPATIBILITY_TABLE''' for j in range(json_['page'])]
    df_temp = pd.DataFrame({'Item Number': input_.loc[i, 'Item Number'],
                            'Page': [j+1 for j in range(json_['page'])],
                            'JOIN_INP': [f'''{input_.loc[i, 'Item Number']};{j+1}''' for j in range(json_['page'])],
                            'Vehicle Url': list_vehicle_url,
                            'Data': json.dumps(json_['data'])})

    output = pd.concat([output, df_temp], ignore_index=True).fillna('')

output.to_excel(f'4.item_2.xlsx', index=False)

output
# Out:
# Progress: 100%|█████████████████████████| 2697/2697 [00:08<00:00, 330.63it/s]
#         Item Number  Page                                        Vehicle Url  \
# 0      312755157869     1  https://www.ebay.com/g/api/finders?module_grou...
# 1      131961711574     1  https://www.ebay.com/g/api/finders?module_grou...
# 2      131961711574     2  https://www.ebay.com/g/api/finders?module_grou...
# 3      131961711574     3  https://www.ebay.com/g/api/finders?module_grou...
# 4      132593161426     1  https://www.ebay.com/g/api/finders?module_grou...
# ...             ...   ...                                                ...
# 42431  133944723164    35  https://www.ebay.com/g/api/finders?module_grou...
# 42432  133944723164    36  https://www.ebay.com/g/api/finders?module_grou...
# 42433  133944723164    37  https://www.ebay.com/g/api/finders?module_grou...
# 42434  133944723164    38  https://www.ebay.com/g/api/finders?module_grou...
# 42435  133944723164    39  https://www.ebay.com/g/api/finders?module_grou...
#
#                                                     Data
# 0      {"scopedContext": {"catalogDetails": {"categor...
# 1      {"scopedContext": {"catalogDetails": {"categor...
# 2      {"scopedContext": {"catalogDetails": {"categor...
# 3      {"scopedContext": {"catalogDetails": {"categor...
# 4      {"scopedContext": {"catalogDetails": {"categor...
# ...                                                  ...
# 42431  {"scopedContext": {"catalogDetails": {"categor...
# 42432  {"scopedContext": {"catalogDetails": {"categor...
# 42433  {"scopedContext": {"catalogDetails": {"categor...
# 42434  {"scopedContext": {"catalogDetails": {"categor...
# 42435  {"scopedContext": {"catalogDetails": {"categor...
#
# [42436 rows x 4 columns]
