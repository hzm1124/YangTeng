# %%
import pandas as pd

input_ = pd.read_excel(f'./3.item.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_
# Out:
#         No   Item Number                                              Title  \
# 0        1  312755157869  18 Piece Steering &amp; Suspension Kit Control...
# 1        2  131961711574  Front &amp; Rear Strut Spring Outer Tie Rod En...
# 2        3  132593161426  7 Piece Steering &amp; Suspension Kit Rack &am...
# 3        4  372474337712  12 Piece Steering &amp; Suspension Kit Complet...
# 4        5  133602141788  Control Arm Sway Link Tie Rod Hub Steering Sus...
# ...    ...           ...                                                ...
# 2696  2697  372350327405  Front Bearing Wheel Seal Pair Driver &amp; Pas...
# 2697  2698  373384912335  Valve Cover Retaining Bolt Sealing Grommet Set...
# 2698  2699  131125984971  Front Inner Wheel Seal Pair Set for SLX Passpo...
# 2699  2700  312732823880  Thermostat Housing Plug O Ring Seal Retainer K...
# 2700  2701  133944723164  IPR Injection Pressure Regulator Valve Seal Ki...
#
#                                           Subtitle       Price    Available  \
# 0     Order by Noon EST and this part ships today!  US $683.34  7 available
# 1     Order by Noon EST and this part ships today!  US $621.16
# 2     Order by Noon EST and this part ships today!  US $619.25  5 available
# 3     Order by Noon EST and this part ships today!  US $606.97  5 available
# 4     Order by Noon EST and this part ships today!  US $593.99  7 available
# ...                                            ...         ...          ...
# 2696  Order by Noon EST and this part ships today!   US $12.99  5 available
# 2697  Order by Noon EST and this part ships today!   US $12.58  5 available
# 2698  Order by Noon EST and this part ships today!   US $11.36  5 available
# 2699  Order by Noon EST and this part ships today!   US $10.32  3 available
# 2700  Order by Noon EST and this part ships today!    US $9.41  5 available
#
#          Sold                                 Vehicle W/o Engine  \
# 0                                           Lincoln LS 2000-2002
# 1      4 sold  Chevrolet Impala 2000-2005\nChevrolet Monte Ca...
# 2              Cadillac Escalade 2007-2014\nCadillac Escalade...
# 3      4 sold  Ford Explorer 2011-2013\nFord Police Intercept...
# 4               Lincoln LS 2002-2006\nFord Thunderbird 2003-2005
# ...       ...                                                ...
# 2696  10 sold  Lincoln Blackwood 2002\nLincoln Navigator 1998...
# 2697  63 sold  BMW Z4 2003-2008\nBMW 325Ci 2001-2006\nBMW 330...
# 2698   9 sold  Isuzu Axiom 2002\nIsuzu Trooper 1988-2002\nIsu...
# 2699  17 sold  Audi A4 1996-2005\nAudi A4 Quattro 1996-2005\n...
# 2700   4 sold  Ford E-350 Super Duty 2004-2010\nFord E-450 Su...
#
#                                       Vehicle W/ Engine Picture  \
# 0     Lincoln LS 2000-2002 3.9L 242Cu. In. V8 GAS DO...
# 1     Chevrolet Impala 2000-2005 3.4L 207Cu. In. V6 ...
# 2     Cadillac Escalade 2009-2014 6.2L 6162CC 376Cu....
# 3     Ford Explorer 2012-2013 2.0L 1999CC 122Cu. In....
# 4     Lincoln LS 2002-2006 3.9L 242Cu. In. V8 GAS DO...
# ...                                                 ...     ...
# 2696  Lincoln Blackwood 2002 5.4L 330Cu. In. V8 GAS ...
# 2697  BMW Z4 2003-2008 2.5L 2494CC 152Cu. In. l6 GAS...
# 2698  Isuzu Axiom 2002 3.5L 3475CC V6 GAS DOHC Natur...
# 2699  Audi A4 1997-2005 1.8L 1781CC l4 GAS DOHC Turb...
# 2700  Ford E-350 Super Duty 2004-2010 6.0L 363Cu. In...
#
#                                                     Url  \
# 0     https://www.ebay.com/itm/312755157869?_ul=US&_...
# 1     https://www.ebay.com/itm/131961711574?_ul=US&_...
# 2     https://www.ebay.com/itm/132593161426?_ul=US&_...
# 3     https://www.ebay.com/itm/372474337712?_ul=US&_...
# 4     https://www.ebay.com/itm/133602141788?_ul=US&_...
# ...                                                 ...
# 2696  https://www.ebay.com/itm/372350327405?_ul=US&_...
# 2697  https://www.ebay.com/itm/373384912335?_ul=US&_...
# 2698  https://www.ebay.com/itm/131125984971?_ul=US&_...
# 2699  https://www.ebay.com/itm/312732823880?_ul=US&_...
# 2700  https://www.ebay.com/itm/133944723164?_ul=US&_...
#
#                                         Description Url  \
# 0     https://vi.vipr.ebaydesc.com/itmdesc/312755157...
# 1     https://vi.vipr.ebaydesc.com/itmdesc/131961711...
# 2     https://vi.vipr.ebaydesc.com/itmdesc/132593161...
# 3     https://vi.vipr.ebaydesc.com/itmdesc/372474337...
# 4     https://vi.vipr.ebaydesc.com/itmdesc/133602141...
# ...                                                 ...
# 2696  https://vi.vipr.ebaydesc.com/itmdesc/372350327...
# 2697  https://vi.vipr.ebaydesc.com/itmdesc/373384912...
# 2698  https://vi.vipr.ebaydesc.com/itmdesc/131125984...
# 2699  https://vi.vipr.ebaydesc.com/itmdesc/312732823...
# 2700  https://vi.vipr.ebaydesc.com/itmdesc/133944723...
#
#                                                Json_Src  \
# 0     {"0": "https://i.ebayimg.com/images/g/Qy8AAOSw...
# 1     {"0": "https://i.ebayimg.com/images/g/MZwAAOSw...
# 2     {"0": "https://i.ebayimg.com/images/g/EFIAAOSw...
# 3     {"0": "https://i.ebayimg.com/images/g/LoYAAOSw...
# 4     {"0": "https://i.ebayimg.com/images/g/XK4AAOSw...
# ...                                                 ...
# 2696  {"0": "https://i.ebayimg.com/images/g/XHUAAOSw...
# 2697  {"0": "https://i.ebayimg.com/images/g/AMIAAOSw...
# 2698  {"0": "https://i.ebayimg.com/images/g/RIgAAOSw...
# 2699  {"0": "https://i.ebayimg.com/images/g/dr8AAOSw...
# 2700  {"0": "https://i.ebayimg.com/images/g/G4YAAOSw...
#
#                                           Json_Specific
# 0     {"0": {"Condition": "New: A brand-new, unused,...
# 1     {"0": {"Condition": "New: A brand-new, unused,...
# 2     {"0": {"Condition": "New: A brand-new, unused,...
# 3     {"0": {"Condition": "New: A brand-new, unused,...
# 4     {"0": {"Condition": "New: A brand-new, unused,...
# ...                                                 ...
# 2696  {"0": {"Condition": "New: A brand-new, unused,...
# 2697  {"0": {"Condition": "New: A brand-new, unused,...
# 2698  {"0": {"Condition": "New: A brand-new, unused,...
# 2699  {"0": {"Condition": "New: A brand-new, unused,...
# 2700  {"0": {"Condition": "New: A brand-new, unused,...
#
# [2701 rows x 14 columns]

# %%
from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_specific = json.loads(input_.loc[i, 'Json_Specific'])
    for value in list(dict_specific.values()):
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./7.item.xlsx', index=False)

input_

print('Done ~')
# Out:
# Progress: 100%|█████████████████████████| 2701/2701 [00:04<00:00, 619.75it/s]
# Done ~
