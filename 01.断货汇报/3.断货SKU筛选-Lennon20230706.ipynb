# %%
import os
import datetime

# %%
list_file = list(os.walk('./'))[0][2]
for file in list_file:
    if '计算表' in file:
        calculate = file

print(f'calculate: \t{calculate}')
# Out:
# calculate: 	计算表-【每日断货汇报】US-Ebay 20231122.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate,
                   sheet_name='附_1统计源（含新品、清仓、新品成长）',
                   header=3,
                   usecols=[2, 3, 5, 11, 12])

df
# Out:
#                  MRP SKU  目标\n周销  Level   在库   在途
# 0      USTCV17215HIE-2-C   46.91   TOP1   32  513
# 1           USET87039H-C   24.65   TOP1   50  256
# 2             USOBDTK100   34.70  TOP10  278    0
# 3        USBDA04108U-2-C   30.09   TOP1  104  202
# 4          USBDA04108U-C   24.18   TOP1   45  251
# ...                  ...     ...    ...  ...  ...
# 63377      USGS4917L8R-C    0.76  TOP20    5   18
# 63378     USIC677650-8-C    2.20  TOP10   22   10
# 63379        USDS86070-C    0.50  TOP20    0    6
# 63380         USTLA48075    0.17     普通    2    0
# 63381     USSGUN005-2R-C    0.09     普通    0    0
#
# [63382 rows x 5 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU',
                                                                   'Level',
                                                                   '目标\n周销',
                                                                   '在途']]

df
# Out:
#                 MRP SKU  Level  目标\n周销  在途
# 338     USVLTK256225-16   TOP1    4.50   0
# 348         USDS36159-C  TOP10    1.79   0
# 351       USSP91970-4-C  TOP10    4.82   0
# 645      USFP3088M0Z1-C  TOP10    1.85   0
# 747         USWR48896-C  TOP20    2.99   0
# ...                 ...    ...     ...  ..
# 57207      USEAF12879-C  TOP20    0.21   0
# 57414      USPSR62450-C  TOP10    1.22   0
# 57901  USTPMS72547U-4-C  TOP20    2.55   0
# 58225      USPSRG3038-C  TOP20    0.82   0
# 58231     USACC11441-C1  TOP20    1.00   0
#
# [478 rows x 4 columns]

# %%
df = df.sort_values(by=['Level', 'MRP SKU'], ascending=[True, True])

df
# Out:
#               MRP SKU  Level  目标\n周销  在途
# 25394  USACC06390S-C1   TOP1    2.55   0
# 9103    USACC11267-C1   TOP1    3.43   0
# 34860   USACC11340-C1   TOP1    1.41   0
# 13605  USACC1U500S-C1   TOP1    2.55   0
# 53847   USACC29136-C1   TOP1    3.82   0
# ...               ...    ...     ...  ..
# 24075    USWR49320DHY  TOP20    0.85   0
# 25455       USWR49322  TOP20    1.27   0
# 54293    USWRM41345-C  TOP20    1.06   0
# 12264   USWRM51293H-C  TOP20    0.66   0
# 27457    USWS00854Y-C  TOP20    0.37   0
#
# [478 rows x 4 columns]

# %%
import datetime

# %%
writer = pd.ExcelWriter('Lennon_筛选好的断货SKU_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.xlsx')
df.to_excel(writer, index=False)
writer.close()
