# %%
import pandas as pd
import json

# %%
with open('./menu_1.txt', 'r', encoding='UTF-8') as f:
    df = pd.DataFrame(json.loads(f.read()))

df = df[['No.', 'Name', 'Url_1']]
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
df['No.'] = [i+1 for i in range(len(df))]
df.to_excel('./menu_1.xlsx', index=False)

df
# Out:
#      No.                            Sku  \
# 0      1           STP A5699 Air Filter
# 1      2           STP A6282 Air Filter
# 2      3    STP CA7766 Cabin Air Filter
# 3      4  STP CAF1119P Cabin Air Filter
# 4      5   STP CAF1758 Cabin Air Filter
# ..   ...                            ...
# 123  124          STP SA9564 Air Filter
# 124  125          STP SA9683 Air Filter
# 125  126          STP SA9687 Air Filter
# 126  127          STP SA9838 Air Filter
# 127  128          STP SA9997 Air Filter
#
#                                                  Url_1
# 0    https://www.spectreperformance.com/cross-refer...
# 1    https://www.spectreperformance.com/cross-refer...
# 2    https://www.spectreperformance.com/cross-refer...
# 3    https://www.spectreperformance.com/cross-refer...
# 4    https://www.spectreperformance.com/cross-refer...
# ..                                                 ...
# 123  https://www.spectreperformance.com/cross-refer...
# 124  https://www.spectreperformance.com/cross-refer...
# 125  https://www.spectreperformance.com/cross-refer...
# 126  https://www.spectreperformance.com/cross-refer...
# 127  https://www.spectreperformance.com/cross-refer...
#
# [128 rows x 3 columns]
