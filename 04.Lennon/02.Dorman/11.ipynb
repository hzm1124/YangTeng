# %%
import os

list_file = sorted(list(os.walk('./file/9.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_100.xlsx',
#  'crawler_1000.xlsx',
#  'crawler_1001.xlsx',
#  'crawler_1002.xlsx',
#  'crawler_1003.xlsx',
#  'crawler_1004.xlsx',
#  'crawler_1005.xlsx',
#  'crawler_1006.xlsx',
#  'crawler_1007.xlsx',
#  'crawler_1008.xlsx',
#  'crawler_1009.xlsx',
#  'crawler_101.xlsx',
#  'crawler_1010.xlsx',
#  'crawler_1011.xlsx',
#  'crawler_1012.xlsx',
#  'crawler_1013.xlsx',
#  'crawler_1014.xlsx',
#  'crawler_1015.xlsx',
#  'crawler_1016.xlsx',
#  'crawler_1017.xlsx',
#  'crawler_1018.xlsx',
#  'crawler_1019.xlsx',
#  'crawler_102.xlsx',
#  'crawler_1020.xlsx',
#  'crawler_1021.xlsx',
#  'crawler_1022.xlsx',
#  'crawler_1023.xlsx',
#  'crawler_1024.xlsx',
#  'crawler_1025.xlsx',
#  'crawler_1026.xlsx',
#  'crawler_1027.xlsx',
#  'crawler_1028.xlsx',
#  'crawler_1029.xlsx',
#  'crawler_103.xlsx',
#  'crawler_1030.xlsx',
#  'crawler_1031.xlsx',
#  'crawler_1032.xlsx',
#  'crawler_1033.xlsx',
#  'crawler_1034.xlsx',
#  'crawler_1035.xlsx',
# ...

# %%
from tqdm import tqdm
import pandas as pd
from datetime import datetime

input_ = pd.DataFrame()
for file in tqdm(list_file, desc='Progress', ncols=77):
    df_temp = pd.read_excel(f'./file/9.part/{file}',
                            header=0,
                            dtype=str).fillna('')

    input_ = pd.concat([input_, df_temp], ignore_index=True).fillna('')

input_ = input_.drop_duplicates(['Url'],
                                keep='first',
                                ignore_index=True)
input_ = input_.sort_values(by=['Type', 'Part Number'],
                            ascending=[True, True],
                            ignore_index=True)

input_['No'] = [_+1 for _ in range(len(input_))]

input_.to_excel(f'''./file/【网站爬虫】Dorman-{datetime.now().strftime('%Y%m%d')}.xlsx''', index=False)

input_
# Out:
# Progress: 100%|██████████████████████████| 2279/2279 [15:56<00:00,  2.38it/s]
#           No                                  Type Part Number  \
# 0          1       110 Volt Accessory Power Outlet       84942
# 1          2  12 Volt Accessory Power Outlet Cover       57020
# 2          3  12 Volt Accessory Power Outlet Cover       57023
# 3          4  12 Volt Accessory Power Outlet Cover       57024
# 4          5  12 Volt Accessory Power Outlet Cover       57029
# ...      ...                                   ...         ...
# 97487  97488                          Woodruff Key     595-061
# 97488  97489                          Woodruff Key     595-064
# 97489  97490                          Woodruff Key     595-065
# 97490  97491                          Woodruff Key     595-068
# 97491  97492                          Woodruff Key     595-069
#
#                             Brand  \
# 0          Dorman - HELP! - Boxed
# 1         Dorman - HELP! - Carded
# ...
