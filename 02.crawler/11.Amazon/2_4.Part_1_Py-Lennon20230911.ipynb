# %%
import os

# %%
list_file = list(os.walk('./crawler_1'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 200

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    with open('./crawler_1/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_1.xlsx', index=False)

df
# Out:
# 进度: 100%|███████████████████████████████| 200/200 [00:00<00:00, 829.34it/s]
#           ASIN                                              Title   Price  \
# 0   B07CCKXRQL  Window Visor Compatible with 1995-2005 GMC Son...  $41.99
# 0   B07CGKJG3S  IKON MOTORSPORTS Tape On External Window Visor...  $41.99
# 0   B01HO657RS  IKON MOTORSPORTS, Window Visor Compatible with...  $28.98
# 0   B07BHKY36Y  Window Visor Compatible with 2001-2006 Chevy S...  $42.99
# 0   B088WM8ZYK  WV194355 In-Channel Rain Guard, Dark Smoke 4-P...  $39.99
# ..         ...                                                ...     ...
# 0   B0BPC7RDZ7  YQAUTEC Window Visors Rain Guards Shield for 1...  $34.99
# 0   B0C85VXZ2Q  YQAUTEC Window Visors Rain Guards Shield for H...  $34.99
# 0   B0BNBHYZWX  ZONFANT Window Rain Guards, Side Window Deflec...  $49.98
# 0   B0BB71CTPV  ZXMOTO Rain Guards Side Window Visor Vent Outs...  $26.99
# 0   B09V4N9CLF  ZYFZZDS Window Visors Window Deflectors for 20...  $41.89
#
#                                                 About  \
# 0   1. Fitment: Fit For 1995-2001 GMC Jimmy 4-Door...
# 0   1. Compatible with 1999-2016 Ford F250 Super D...
# 0   1. Compatible With: 2001-2005 Honda Civic Seda...
# 0   1. Fitment: Compatible with 2002-2006 Cadillac...
# 0   1. Made of high-impact acrylic in UV & scratch...
# ..                                                ...
# 0   1. 【Perfect Fit】YQAUTEC window visors rain gua...
# 0   1. 【Perfect Fit】YQAUTEC Window Rain Guards Shi...
# 0   1. 【Compatible Vehicle】 - This rain guard comp...
# 0   1. Made of PMMA Material in UV & scratch resis...
# 0   1. 【Fitment】It fit for Chevrolet Chevy Colorad...
#
#                                                   Url  \
# 0   https://www.amazon.com/1995-2005-Acrylic-Defle...
# 0   https://www.amazon.com/1999-2016-Acrylic-Defle...
# 0   https://www.amazon.com/2001-2005-Acrylic-Semi-...
# 0   https://www.amazon.com/2001-2006-Silverado-Def...
# 0   https://www.amazon.com/2002-2006-Avalanche-200...
# ..                                                ...
# 0   https://www.amazon.com/YQAUTEC-Window-1999-201...
# 0   https://www.amazon.com/YQAUTEC-Window-Visors-2...
# 0   https://www.amazon.com/ZONFANT-Window-Deflecto...
# 0   https://www.amazon.com/ZXMOTO-Guards-Window-Ou...
# 0   https://www.amazon.com/ZYFZZDS-Window-Visors-D...
#
#                                                   Src  \
# 0   https://m.media-amazon.com/images/I/61WvfUPQlR...
# 0   https://m.media-amazon.com/images/I/711W3+VZNU...
# 0   https://m.media-amazon.com/images/I/51yJZanjpQ...
# 0   https://m.media-amazon.com/images/I/51rPY0fZ3a...
# 0   https://m.media-amazon.com/images/I/51dJ4fQvq7...
# ..                                                ...
# 0   https://m.media-amazon.com/images/I/71eu0EqP6N...
# 0   https://m.media-amazon.com/images/I/71M4Oi-qa9...
# 0   https://m.media-amazon.com/images/I/612KzQDTPn...
# 0   https://m.media-amazon.com/images/I/61-YiwKic+...
# 0   https://m.media-amazon.com/images/I/611yJQUbkT...
#
#                               color              brand          style  \
# 0                     ‎Smoke/Tinted  ‎IKON MOTORSPORTS  ‎Professional
# 0                     ‎Smoke/Tinted  ‎IKON MOTORSPORTS  ‎Professional
# 0         ‎Mugen Style Smoke/Tinted  ‎IKON MOTORSPORTS  ‎Professional
# 0                     ‎Smoke/Tinted  ‎IKON MOTORSPORTS       ‎Classic
# 0                       ‎Dark Smoke        ‎Lightronic       ‎Classic
# ..                              ...                ...            ...
# 0                ‎Dark Smoke Tinted           ‎YQAUTEC       ‎Classic
# 0                               NaN           ‎YQAUTEC       ‎Classic
# 0                               NaN           ‎ZONFANT     ‎Sun Visor
# 0                      ‎Transparent            ‎ZXMOTO       ‎Classic
# 0   ‎2015 - 2022 Chevrolet Colorado           ‎ZYFZZDS       ‎Classic
#
#    auto part position  ... STYLE AUTO PART POSITION NUMBER OF PIECES  \
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0              ‎Outer  ...   NaN                NaN              NaN
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0        ‎Front Outer  ...   NaN                NaN              NaN
# ..                ...  ...   ...                ...              ...
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0            ‎Outside  ...   NaN                NaN              NaN
# 0     ‎Upper, Outside  ...   NaN                NaN              NaN
# 0        ‎Rear, Front  ...   NaN                NaN              NaN
#
#    PRODUCT DIMENSIONS ITEM WEIGHT MANUFACTURER ITEM MODEL NUMBER  \
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# ..                ...         ...          ...               ...
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
# 0                 NaN         NaN          NaN               NaN
#
#    IS DISCONTINUED BY MANUFACTURER BATTERIES REQUIRED mirror lens type
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# ..                             ...                ...              ...
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
# 0                              NaN                NaN              NaN
#
# [200 rows x 41 columns]
