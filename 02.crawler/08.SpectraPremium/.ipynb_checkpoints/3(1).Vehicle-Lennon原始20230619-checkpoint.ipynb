# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./menu.xlsx', header=0)
list_url = df_menu['Url'].to_list()

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：572
# ['https://ecat.spectrapremium.com/en/parts/CRP70A',
#  'https://ecat.spectrapremium.com/en/parts/CRP72A',
#  'https://ecat.spectrapremium.com/en/parts/CRP73A',
#  'https://ecat.spectrapremium.com/en/parts/CRP74A',
#  'https://ecat.spectrapremium.com/en/parts/CRP75A',
#  'https://ecat.spectrapremium.com/en/parts/CRP76A',
#  'https://ecat.spectrapremium.com/en/parts/CRP78A',
#  'https://ecat.spectrapremium.com/en/parts/DTP01A',
#  'https://ecat.spectrapremium.com/en/parts/DTP02A',
#  'https://ecat.spectrapremium.com/en/parts/DTP03A',
#  'https://ecat.spectrapremium.com/en/parts/DTP04A',
#  'https://ecat.spectrapremium.com/en/parts/DTP04B',
#  'https://ecat.spectrapremium.com/en/parts/DTP05A',
#  'https://ecat.spectrapremium.com/en/parts/DTP06A',
#  'https://ecat.spectrapremium.com/en/parts/FP01A',
#  'https://ecat.spectrapremium.com/en/parts/FP01B',
#  'https://ecat.spectrapremium.com/en/parts/FP02A',
#  'https://ecat.spectrapremium.com/en/parts/FP02B',
#  'https://ecat.spectrapremium.com/en/parts/FP03A',
#  'https://ecat.spectrapremium.com/en/parts/FP05A',
#  'https://ecat.spectrapremium.com/en/parts/FP05B',
#  'https://ecat.spectrapremium.com/en/parts/FP06A',
#  'https://ecat.spectrapremium.com/en/parts/FP07A',
#  'https://ecat.spectrapremium.com/en/parts/FP07B',
#  'https://ecat.spectrapremium.com/en/parts/FP08A',
#  'https://ecat.spectrapremium.com/en/parts/FP08B',
#  'https://ecat.spectrapremium.com/en/parts/FP09A',
#  'https://ecat.spectrapremium.com/en/parts/FP09B',
#  'https://ecat.spectrapremium.com/en/parts/FP09C',
#  'https://ecat.spectrapremium.com/en/parts/FP11A',
#  'https://ecat.spectrapremium.com/en/parts/FP11B',
#  'https://ecat.spectrapremium.com/en/parts/FP11C',
#  'https://ecat.spectrapremium.com/en/parts/FP12A',
#  'https://ecat.spectrapremium.com/en/parts/FP14A',
#  'https://ecat.spectrapremium.com/en/parts/FP14B',
#  'https://ecat.spectrapremium.com/en/parts/FP15B',
#  'https://ecat.spectrapremium.com/en/parts/FP16B',
#  'https://ecat.spectrapremium.com/en/parts/FP17A',
#  'https://ecat.spectrapremium.com/en/parts/FP18A',
#  'https://ecat.spectrapremium.com/en/parts/FP18B',
#  'https://ecat.spectrapremium.com/en/parts/FP18D',
#  'https://ecat.spectrapremium.com/en/parts/FP19A',
#  'https://ecat.spectrapremium.com/en/parts/FP19B',
#  'https://ecat.spectrapremium.com/en/parts/FP19C',
#  'https://ecat.spectrapremium.com/en/parts/FP20A',
#  'https://ecat.spectrapremium.com/en/parts/FP20B',
#  'https://ecat.spectrapremium.com/en/parts/FP21A',
#  'https://ecat.spectrapremium.com/en/parts/FP21B',
#  'https://ecat.spectrapremium.com/en/parts/FP22A',
#  'https://ecat.spectrapremium.com/en/parts/FP24B',
#  'https://ecat.spectrapremium.com/en/parts/BMP02A',
#  'https://ecat.spectrapremium.com/en/parts/BMP03A',
#  'https://ecat.spectrapremium.com/en/parts/BMP05A',
#  'https://ecat.spectrapremium.com/en/parts/BMP06A',
#  'https://ecat.spectrapremium.com/en/parts/BMP07A',
#  'https://ecat.spectrapremium.com/en/parts/BMP08A',
#  'https://ecat.spectrapremium.com/en/parts/BMP09A',
#  'https://ecat.spectrapremium.com/en/parts/BMP10A',
#  'https://ecat.spectrapremium.com/en/parts/BMP11A',
#  'https://ecat.spectrapremium.com/en/parts/BMP12A',
#  'https://ecat.spectrapremium.com/en/parts/BMP13A',
#  'https://ecat.spectrapremium.com/en/parts/BMP14A',
#  'https://ecat.spectrapremium.com/en/parts/BMP15A',
#  'https://ecat.spectrapremium.com/en/parts/BMP16A',
#  'https://ecat.spectrapremium.com/en/parts/BMP17A',
#  'https://ecat.spectrapremium.com/en/parts/BMP19A',
#  'https://ecat.spectrapremium.com/en/parts/BMP20A',
#  'https://ecat.spectrapremium.com/en/parts/BMP21A',
#  'https://ecat.spectrapremium.com/en/parts/BMP22A',
#  'https://ecat.spectrapremium.com/en/parts/BMP23A',
#  'https://ecat.spectrapremium.com/en/parts/BMP24A',
#  'https://ecat.spectrapremium.com/en/parts/CATP04A',
#  'https://ecat.spectrapremium.com/en/parts/CATP05A',
#  'https://ecat.spectrapremium.com/en/parts/CMP01A',
#  'https://ecat.spectrapremium.com/en/parts/CMP02A',
#  'https://ecat.spectrapremium.com/en/parts/CMP03A',
#  'https://ecat.spectrapremium.com/en/parts/CMP04A',
#  'https://ecat.spectrapremium.com/en/parts/CMP05A',
#  'https://ecat.spectrapremium.com/en/parts/CMP06A',
#  'https://ecat.spectrapremium.com/en/parts/CMP08A',
#  'https://ecat.spectrapremium.com/en/parts/CRP01A',
#  'https://ecat.spectrapremium.com/en/parts/CRP02A',
#  'https://ecat.spectrapremium.com/en/parts/CRP03A',
#  'https://ecat.spectrapremium.com/en/parts/CRP03B',
#  'https://ecat.spectrapremium.com/en/parts/CRP04A',
#  'https://ecat.spectrapremium.com/en/parts/CRP04B',
#  'https://ecat.spectrapremium.com/en/parts/CRP05A',
#  'https://ecat.spectrapremium.com/en/parts/CRP05B',
#  'https://ecat.spectrapremium.com/en/parts/CRP06A',
#  'https://ecat.spectrapremium.com/en/parts/CRP06B',
#  'https://ecat.spectrapremium.com/en/parts/CRP06C',
#  'https://ecat.spectrapremium.com/en/parts/CRP07A',
#  'https://ecat.spectrapremium.com/en/parts/CRP08A',
#  'https://ecat.spectrapremium.com/en/parts/CRP09B',
#  'https://ecat.spectrapremium.com/en/parts/CRP10A',
#  'https://ecat.spectrapremium.com/en/parts/CRP11A',
#  'https://ecat.spectrapremium.com/en/parts/CRP12A',
#  'https://ecat.spectrapremium.com/en/parts/CRP14A',
#  'https://ecat.spectrapremium.com/en/parts/CRP14B',
#  'https://ecat.spectrapremium.com/en/parts/CRP15A',
#  'https://ecat.spectrapremium.com/en/parts/TOP25A',
#  'https://ecat.spectrapremium.com/en/parts/TOP26A',
#  'https://ecat.spectrapremium.com/en/parts/TOP27A',
#  'https://ecat.spectrapremium.com/en/parts/TOP28A',
#  'https://ecat.spectrapremium.com/en/parts/TOP28B',
#  'https://ecat.spectrapremium.com/en/parts/TOP30A',
#  'https://ecat.spectrapremium.com/en/parts/TOP31A',
#  'https://ecat.spectrapremium.com/en/parts/TOP32A',
#  'https://ecat.spectrapremium.com/en/parts/TOP33A',
#  'https://ecat.spectrapremium.com/en/parts/TOP34A',
#  'https://ecat.spectrapremium.com/en/parts/TOP34B',
#  'https://ecat.spectrapremium.com/en/parts/TOP35A',
#  'https://ecat.spectrapremium.com/en/parts/TOP36A',
#  'https://ecat.spectrapremium.com/en/parts/TOP37A',
#  'https://ecat.spectrapremium.com/en/parts/TOP38A',
#  'https://ecat.spectrapremium.com/en/parts/TOP39A',
#  'https://ecat.spectrapremium.com/en/parts/TOP40A',
#  'https://ecat.spectrapremium.com/en/parts/TOP41A',
#  'https://ecat.spectrapremium.com/en/parts/TOP42A',
#  'https://ecat.spectrapremium.com/en/parts/TOP43A',
#  'https://ecat.spectrapremium.com/en/parts/TOP44A',
#  'https://ecat.spectrapremium.com/en/parts/TOP45A',
#  'https://ecat.spectrapremium.com/en/parts/TOP63A',
#  'https://ecat.spectrapremium.com/en/parts/TOP64A',
#  'https://ecat.spectrapremium.com/en/parts/TOP66A',
#  'https://ecat.spectrapremium.com/en/parts/TOP67A',
#  'https://ecat.spectrapremium.com/en/parts/TOP68A',
#  'https://ecat.spectrapremium.com/en/parts/TOP69A',
#  'https://ecat.spectrapremium.com/en/parts/TOP72A',
#  'https://ecat.spectrapremium.com/en/parts/TOP73A',
#  'https://ecat.spectrapremium.com/en/parts/TOP74A',
#  'https://ecat.spectrapremium.com/en/parts/VOP01A',
#  'https://ecat.spectrapremium.com/en/parts/VOP02A',
#  'https://ecat.spectrapremium.com/en/parts/VOP03A',
#  'https://ecat.spectrapremium.com/en/parts/VOP04A',
#  'https://ecat.spectrapremium.com/en/parts/VOP05A',
#  'https://ecat.spectrapremium.com/en/parts/VOP06A',
#  'https://ecat.spectrapremium.com/en/parts/VOP09A',
#  'https://ecat.spectrapremium.com/en/parts/VOP10A',
#  'https://ecat.spectrapremium.com/en/parts/VWP20A',
#  'https://ecat.spectrapremium.com/en/parts/VWP20B',
#  'https://ecat.spectrapremium.com/en/parts/VWP21A',
#  'https://ecat.spectrapremium.com/en/parts/VWP22A',
#  'https://ecat.spectrapremium.com/en/parts/VWP23A',
#  'https://ecat.spectrapremium.com/en/parts/VWP24A',
#  'https://ecat.spectrapremium.com/en/parts/VWP25A',
#  'https://ecat.spectrapremium.com/en/parts/VWP26A',
#  'https://ecat.spectrapremium.com/en/parts/VWP27A',
#  'https://ecat.spectrapremium.com/en/parts/VWP28A',
#  'https://ecat.spectrapremium.com/en/parts/VWP30A',
#  'https://ecat.spectrapremium.com/en/parts/FP25A',
#  'https://ecat.spectrapremium.com/en/parts/FP26A',
#  'https://ecat.spectrapremium.com/en/parts/FP27A',
#  'https://ecat.spectrapremium.com/en/parts/FP41A',
#  'https://ecat.spectrapremium.com/en/parts/FP42A',
#  'https://ecat.spectrapremium.com/en/parts/FP43A',
#  'https://ecat.spectrapremium.com/en/parts/FP45A',
#  'https://ecat.spectrapremium.com/en/parts/FP45B',
#  'https://ecat.spectrapremium.com/en/parts/FP46A',
#  'https://ecat.spectrapremium.com/en/parts/FP46B',
#  'https://ecat.spectrapremium.com/en/parts/FP47A',
#  'https://ecat.spectrapremium.com/en/parts/FP48A',
#  'https://ecat.spectrapremium.com/en/parts/FP49A',
#  'https://ecat.spectrapremium.com/en/parts/FP50A',
#  'https://ecat.spectrapremium.com/en/parts/FP51A',
#  'https://ecat.spectrapremium.com/en/parts/FP52A',
#  'https://ecat.spectrapremium.com/en/parts/FP53A',
#  'https://ecat.spectrapremium.com/en/parts/FP54A',
#  'https://ecat.spectrapremium.com/en/parts/FP54B',
#  'https://ecat.spectrapremium.com/en/parts/FP54C',
#  'https://ecat.spectrapremium.com/en/parts/FP55A',
#  'https://ecat.spectrapremium.com/en/parts/FP56A',
#  'https://ecat.spectrapremium.com/en/parts/FP57A',
#  'https://ecat.spectrapremium.com/en/parts/FP58A',
#  'https://ecat.spectrapremium.com/en/parts/FP61A',
#  'https://ecat.spectrapremium.com/en/parts/FP63A',
#  'https://ecat.spectrapremium.com/en/parts/FP64A',
#  'https://ecat.spectrapremium.com/en/parts/FP65A',
#  'https://ecat.spectrapremium.com/en/parts/FP66A',
#  'https://ecat.spectrapremium.com/en/parts/FP66B',
#  'https://ecat.spectrapremium.com/en/parts/FP67A',
#  'https://ecat.spectrapremium.com/en/parts/FP68A',
#  'https://ecat.spectrapremium.com/en/parts/FP69A',
#  'https://ecat.spectrapremium.com/en/parts/FP70A',
#  'https://ecat.spectrapremium.com/en/parts/FP71A',
#  'https://ecat.spectrapremium.com/en/parts/FP72A',
#  'https://ecat.spectrapremium.com/en/parts/FP73A',
#  'https://ecat.spectrapremium.com/en/parts/FP74A',
#  'https://ecat.spectrapremium.com/en/parts/FP75A',
#  'https://ecat.spectrapremium.com/en/parts/FP76A',
#  'https://ecat.spectrapremium.com/en/parts/FP77A',
#  'https://ecat.spectrapremium.com/en/parts/FP78A',
#  'https://ecat.spectrapremium.com/en/parts/FP78B',
#  'https://ecat.spectrapremium.com/en/parts/FP79A',
#  'https://ecat.spectrapremium.com/en/parts/FP80A',
#  'https://ecat.spectrapremium.com/en/parts/FP81A',
#  'https://ecat.spectrapremium.com/en/parts/FP82A',
#  'https://ecat.spectrapremium.com/en/parts/FP83A',
#  'https://ecat.spectrapremium.com/en/parts/FP86A',
#  'https://ecat.spectrapremium.com/en/parts/FP87A',
#  'https://ecat.spectrapremium.com/en/parts/NSP28A',
#  'https://ecat.spectrapremium.com/en/parts/NSP29A',
#  'https://ecat.spectrapremium.com/en/parts/NSP30A',
#  'https://ecat.spectrapremium.com/en/parts/NSP31A',
#  'https://ecat.spectrapremium.com/en/parts/NSP32A',
#  'https://ecat.spectrapremium.com/en/parts/NSP33A',
#  'https://ecat.spectrapremium.com/en/parts/NSP34A',
#  'https://ecat.spectrapremium.com/en/parts/NSP35A',
#  'https://ecat.spectrapremium.com/en/parts/NSP36A',
#  'https://ecat.spectrapremium.com/en/parts/NSP37A',
#  'https://ecat.spectrapremium.com/en/parts/NSP38A',
#  'https://ecat.spectrapremium.com/en/parts/NSP39A',
#  'https://ecat.spectrapremium.com/en/parts/NSP40A',
#  'https://ecat.spectrapremium.com/en/parts/NSP41A',
#  'https://ecat.spectrapremium.com/en/parts/NSP44A',
#  'https://ecat.spectrapremium.com/en/parts/NSP45A',
#  'https://ecat.spectrapremium.com/en/parts/NSP46A',
#  'https://ecat.spectrapremium.com/en/parts/NSP47A',
#  'https://ecat.spectrapremium.com/en/parts/OPA001',
#  'https://ecat.spectrapremium.com/en/parts/SAP01A',
#  'https://ecat.spectrapremium.com/en/parts/SAP02A',
#  'https://ecat.spectrapremium.com/en/parts/SAP03A',
#  'https://ecat.spectrapremium.com/en/parts/SUP01A',
#  'https://ecat.spectrapremium.com/en/parts/SUP02A',
#  'https://ecat.spectrapremium.com/en/parts/SUP03A',
#  'https://ecat.spectrapremium.com/en/parts/SUP04A',
#  'https://ecat.spectrapremium.com/en/parts/SUP04B',
#  'https://ecat.spectrapremium.com/en/parts/SUP05A',
#  'https://ecat.spectrapremium.com/en/parts/SUP06A',
#  'https://ecat.spectrapremium.com/en/parts/SUP08A',
#  'https://ecat.spectrapremium.com/en/parts/SZP01A',
#  'https://ecat.spectrapremium.com/en/parts/SZP02A',
#  'https://ecat.spectrapremium.com/en/parts/SZP03A',
#  'https://ecat.spectrapremium.com/en/parts/SZP03B',
#  'https://ecat.spectrapremium.com/en/parts/SZP04A',
#  'https://ecat.spectrapremium.com/en/parts/TOP01A',
#  'https://ecat.spectrapremium.com/en/parts/TOP02A',
#  'https://ecat.spectrapremium.com/en/parts/TOP02B',
#  'https://ecat.spectrapremium.com/en/parts/TOP03A',
#  'https://ecat.spectrapremium.com/en/parts/TOP04A',
#  'https://ecat.spectrapremium.com/en/parts/TOP05A',
#  'https://ecat.spectrapremium.com/en/parts/TOP06A',
#  'https://ecat.spectrapremium.com/en/parts/TOP07A',
#  'https://ecat.spectrapremium.com/en/parts/TOP08A',
#  'https://ecat.spectrapremium.com/en/parts/TOP09A',
#  'https://ecat.spectrapremium.com/en/parts/TOP10A',
#  'https://ecat.spectrapremium.com/en/parts/TOP10B',
#  'https://ecat.spectrapremium.com/en/parts/TOP22A',
#  'https://ecat.spectrapremium.com/en/parts/TOP23A',
#  'https://ecat.spectrapremium.com/en/parts/TOP24A',
#  'https://ecat.spectrapremium.com/en/parts/CRP16A',
#  'https://ecat.spectrapremium.com/en/parts/CRP18A',
#  'https://ecat.spectrapremium.com/en/parts/CRP19A',
#  'https://ecat.spectrapremium.com/en/parts/CRP19B',
#  'https://ecat.spectrapremium.com/en/parts/CRP25A',
#  'https://ecat.spectrapremium.com/en/parts/CRP26A',
#  'https://ecat.spectrapremium.com/en/parts/CRP28A',
#  'https://ecat.spectrapremium.com/en/parts/CRP29A',
#  'https://ecat.spectrapremium.com/en/parts/CRP30A',
#  'https://ecat.spectrapremium.com/en/parts/CRP31A',
#  'https://ecat.spectrapremium.com/en/parts/CRP32A',
#  'https://ecat.spectrapremium.com/en/parts/CRP33A',
#  'https://ecat.spectrapremium.com/en/parts/CRP33B',
#  'https://ecat.spectrapremium.com/en/parts/CRP34A',
#  'https://ecat.spectrapremium.com/en/parts/CRP35A',
#  'https://ecat.spectrapremium.com/en/parts/CRP35B',
#  'https://ecat.spectrapremium.com/en/parts/CRP37A',
#  'https://ecat.spectrapremium.com/en/parts/CRP38A',
#  'https://ecat.spectrapremium.com/en/parts/CRP39A',
#  'https://ecat.spectrapremium.com/en/parts/CRP40A',
#  'https://ecat.spectrapremium.com/en/parts/CRP41A',
#  'https://ecat.spectrapremium.com/en/parts/CRP42A',
#  'https://ecat.spectrapremium.com/en/parts/CRP43A',
#  'https://ecat.spectrapremium.com/en/parts/CRP44A',
#  'https://ecat.spectrapremium.com/en/parts/CRP44B',
#  'https://ecat.spectrapremium.com/en/parts/CRP45A',
#  'https://ecat.spectrapremium.com/en/parts/CRP46A',
#  'https://ecat.spectrapremium.com/en/parts/CRP47A',
#  'https://ecat.spectrapremium.com/en/parts/CRP49A',
#  'https://ecat.spectrapremium.com/en/parts/CRP50A',
#  'https://ecat.spectrapremium.com/en/parts/CRP51A',
#  'https://ecat.spectrapremium.com/en/parts/CRP52A',
#  'https://ecat.spectrapremium.com/en/parts/CRP53A',
#  'https://ecat.spectrapremium.com/en/parts/CRP54A',
#  'https://ecat.spectrapremium.com/en/parts/CRP55A',
#  'https://ecat.spectrapremium.com/en/parts/CRP56A',
#  'https://ecat.spectrapremium.com/en/parts/CRP57A',
#  'https://ecat.spectrapremium.com/en/parts/CRP57B',
#  'https://ecat.spectrapremium.com/en/parts/CRP58A',
#  'https://ecat.spectrapremium.com/en/parts/CRP59A',
#  'https://ecat.spectrapremium.com/en/parts/CRP60A',
#  'https://ecat.spectrapremium.com/en/parts/CRP61A',
#  'https://ecat.spectrapremium.com/en/parts/CRP62A',
#  'https://ecat.spectrapremium.com/en/parts/CRP63A',
#  'https://ecat.spectrapremium.com/en/parts/CRP64A',
#  'https://ecat.spectrapremium.com/en/parts/CRP65A',
#  'https://ecat.spectrapremium.com/en/parts/CRP66A',
#  'https://ecat.spectrapremium.com/en/parts/CRP67A',
#  'https://ecat.spectrapremium.com/en/parts/CRP68A',
#  'https://ecat.spectrapremium.com/en/parts/CRP69A',
#  'https://ecat.spectrapremium.com/en/parts/FP88A',
#  'https://ecat.spectrapremium.com/en/parts/FP89A',
#  'https://ecat.spectrapremium.com/en/parts/FP90A',
#  'https://ecat.spectrapremium.com/en/parts/FP92A',
#  'https://ecat.spectrapremium.com/en/parts/FP94A',
#  'https://ecat.spectrapremium.com/en/parts/FP95A',
#  'https://ecat.spectrapremium.com/en/parts/FP96A',
#  'https://ecat.spectrapremium.com/en/parts/GMP01A',
#  'https://ecat.spectrapremium.com/en/parts/GMP01B',
#  'https://ecat.spectrapremium.com/en/parts/GMP02A',
#  'https://ecat.spectrapremium.com/en/parts/GMP02B',
#  'https://ecat.spectrapremium.com/en/parts/GMP03A',
#  'https://ecat.spectrapremium.com/en/parts/GMP04A',
#  'https://ecat.spectrapremium.com/en/parts/GMP05A',
#  'https://ecat.spectrapremium.com/en/parts/GMP07A',
#  'https://ecat.spectrapremium.com/en/parts/GMP07B',
#  'https://ecat.spectrapremium.com/en/parts/GMP08A',
#  'https://ecat.spectrapremium.com/en/parts/GMP08B',
#  'https://ecat.spectrapremium.com/en/parts/GMP09A',
#  'https://ecat.spectrapremium.com/en/parts/GMP100A',
#  'https://ecat.spectrapremium.com/en/parts/GMP101A',
#  'https://ecat.spectrapremium.com/en/parts/GMP102A',
#  'https://ecat.spectrapremium.com/en/parts/GMP103A',
#  'https://ecat.spectrapremium.com/en/parts/GMP105A',
#  'https://ecat.spectrapremium.com/en/parts/GMP109A',
#  'https://ecat.spectrapremium.com/en/parts/GMP10A',
#  'https://ecat.spectrapremium.com/en/parts/GMP112A',
#  'https://ecat.spectrapremium.com/en/parts/GMP113A',
#  'https://ecat.spectrapremium.com/en/parts/GMP114A',
#  'https://ecat.spectrapremium.com/en/parts/GMP115A',
#  'https://ecat.spectrapremium.com/en/parts/GMP11A',
#  'https://ecat.spectrapremium.com/en/parts/GMP11B',
#  'https://ecat.spectrapremium.com/en/parts/GMP121A',
#  'https://ecat.spectrapremium.com/en/parts/GMP123A',
#  'https://ecat.spectrapremium.com/en/parts/GMP124A',
#  'https://ecat.spectrapremium.com/en/parts/GMP125A',
#  'https://ecat.spectrapremium.com/en/parts/GMP127A',
#  'https://ecat.spectrapremium.com/en/parts/GMP128A',
#  'https://ecat.spectrapremium.com/en/parts/GMP129A',
#  'https://ecat.spectrapremium.com/en/parts/GMP12A',
#  'https://ecat.spectrapremium.com/en/parts/GMP14A',
#  'https://ecat.spectrapremium.com/en/parts/GMP15A',
#  'https://ecat.spectrapremium.com/en/parts/GMP19A',
#  'https://ecat.spectrapremium.com/en/parts/GMP20A',
#  'https://ecat.spectrapremium.com/en/parts/GMP20B',
#  'https://ecat.spectrapremium.com/en/parts/GMP21A',
#  'https://ecat.spectrapremium.com/en/parts/GMP24A',
#  'https://ecat.spectrapremium.com/en/parts/GMP24B',
#  'https://ecat.spectrapremium.com/en/parts/GMP25A',
#  'https://ecat.spectrapremium.com/en/parts/GMP25B',
#  'https://ecat.spectrapremium.com/en/parts/GMP26A',
#  'https://ecat.spectrapremium.com/en/parts/GMP26B',
#  'https://ecat.spectrapremium.com/en/parts/GMP27A',
#  'https://ecat.spectrapremium.com/en/parts/GMP29A',
#  'https://ecat.spectrapremium.com/en/parts/GMP37A',
#  'https://ecat.spectrapremium.com/en/parts/GMP38A',
#  'https://ecat.spectrapremium.com/en/parts/GMP40A',
#  'https://ecat.spectrapremium.com/en/parts/GMP40B',
#  'https://ecat.spectrapremium.com/en/parts/GMP41A',
#  'https://ecat.spectrapremium.com/en/parts/GMP46A',
#  'https://ecat.spectrapremium.com/en/parts/GMP47A',
#  'https://ecat.spectrapremium.com/en/parts/GMP50A',
#  'https://ecat.spectrapremium.com/en/parts/GMP51A',
#  'https://ecat.spectrapremium.com/en/parts/GMP52A',
#  'https://ecat.spectrapremium.com/en/parts/GMP53A',
#  'https://ecat.spectrapremium.com/en/parts/GMP53B',
#  'https://ecat.spectrapremium.com/en/parts/GMP53C',
#  'https://ecat.spectrapremium.com/en/parts/GMP55A',
#  'https://ecat.spectrapremium.com/en/parts/GMP56A',
#  'https://ecat.spectrapremium.com/en/parts/GMP57A',
#  'https://ecat.spectrapremium.com/en/parts/GMP58A',
#  'https://ecat.spectrapremium.com/en/parts/GMP59A',
#  'https://ecat.spectrapremium.com/en/parts/GMP60A',
#  'https://ecat.spectrapremium.com/en/parts/GMP62A',
#  'https://ecat.spectrapremium.com/en/parts/GMP63A',
#  'https://ecat.spectrapremium.com/en/parts/GMP63B',
#  'https://ecat.spectrapremium.com/en/parts/GMP64A',
#  'https://ecat.spectrapremium.com/en/parts/GMP65A',
#  'https://ecat.spectrapremium.com/en/parts/GMP66A',
#  'https://ecat.spectrapremium.com/en/parts/GMP66B',
#  'https://ecat.spectrapremium.com/en/parts/GMP66C',
#  'https://ecat.spectrapremium.com/en/parts/GMP67A',
#  'https://ecat.spectrapremium.com/en/parts/GMP68A',
#  'https://ecat.spectrapremium.com/en/parts/GMP69A',
#  'https://ecat.spectrapremium.com/en/parts/GMP70A',
#  'https://ecat.spectrapremium.com/en/parts/GMP71A',
#  'https://ecat.spectrapremium.com/en/parts/GMP72A',
#  'https://ecat.spectrapremium.com/en/parts/GMP73A',
#  'https://ecat.spectrapremium.com/en/parts/GMP74A',
#  'https://ecat.spectrapremium.com/en/parts/GMP74B',
#  'https://ecat.spectrapremium.com/en/parts/GMP75A',
#  'https://ecat.spectrapremium.com/en/parts/GMP76A',
#  'https://ecat.spectrapremium.com/en/parts/GMP77A',
#  'https://ecat.spectrapremium.com/en/parts/GMP79A',
#  'https://ecat.spectrapremium.com/en/parts/GMP80A',
#  'https://ecat.spectrapremium.com/en/parts/GMP83A',
#  'https://ecat.spectrapremium.com/en/parts/GMP84A',
#  'https://ecat.spectrapremium.com/en/parts/GMP85A',
#  'https://ecat.spectrapremium.com/en/parts/GMP86A',
#  'https://ecat.spectrapremium.com/en/parts/GMP87A',
#  'https://ecat.spectrapremium.com/en/parts/MDP24A',
#  'https://ecat.spectrapremium.com/en/parts/MDP25A',
#  'https://ecat.spectrapremium.com/en/parts/MDP26A',
#  'https://ecat.spectrapremium.com/en/parts/MIP01A',
#  'https://ecat.spectrapremium.com/en/parts/MIP02A',
#  'https://ecat.spectrapremium.com/en/parts/MIP03A',
#  'https://ecat.spectrapremium.com/en/parts/MIP04A',
#  'https://ecat.spectrapremium.com/en/parts/MIP05A',
#  'https://ecat.spectrapremium.com/en/parts/MIP06A',
#  'https://ecat.spectrapremium.com/en/parts/MIP07A',
#  'https://ecat.spectrapremium.com/en/parts/MIP08A',
#  'https://ecat.spectrapremium.com/en/parts/MIP09A',
#  'https://ecat.spectrapremium.com/en/parts/MIP11A',
#  'https://ecat.spectrapremium.com/en/parts/MIP13A',
#  'https://ecat.spectrapremium.com/en/parts/MZP01A',
#  'https://ecat.spectrapremium.com/en/parts/MZP02A',
#  'https://ecat.spectrapremium.com/en/parts/MZP03A',
#  'https://ecat.spectrapremium.com/en/parts/MZP03B',
#  'https://ecat.spectrapremium.com/en/parts/MZP05A',
#  'https://ecat.spectrapremium.com/en/parts/MZP06A',
#  'https://ecat.spectrapremium.com/en/parts/MZP07A',
#  'https://ecat.spectrapremium.com/en/parts/MZP08A',
#  'https://ecat.spectrapremium.com/en/parts/MZP11A',
#  'https://ecat.spectrapremium.com/en/parts/MZP12A',
#  'https://ecat.spectrapremium.com/en/parts/MZP14A',
#  'https://ecat.spectrapremium.com/en/parts/MZP15A',
#  'https://ecat.spectrapremium.com/en/parts/MZP16A',
#  'https://ecat.spectrapremium.com/en/parts/MZP17A',
#  'https://ecat.spectrapremium.com/en/parts/MZP18A',
#  'https://ecat.spectrapremium.com/en/parts/MZP19A',
#  'https://ecat.spectrapremium.com/en/parts/MZP20A',
#  'https://ecat.spectrapremium.com/en/parts/MZP21A',
#  'https://ecat.spectrapremium.com/en/parts/NSP01A',
#  'https://ecat.spectrapremium.com/en/parts/NSP11A',
#  'https://ecat.spectrapremium.com/en/parts/NSP11B',
#  'https://ecat.spectrapremium.com/en/parts/NSP12A',
#  'https://ecat.spectrapremium.com/en/parts/NSP14A',
#  'https://ecat.spectrapremium.com/en/parts/NSP15A',
#  'https://ecat.spectrapremium.com/en/parts/NSP16A',
#  'https://ecat.spectrapremium.com/en/parts/NSP17A',
#  'https://ecat.spectrapremium.com/en/parts/NSP23A',
#  'https://ecat.spectrapremium.com/en/parts/NSP24A',
#  'https://ecat.spectrapremium.com/en/parts/NSP24C',
#  'https://ecat.spectrapremium.com/en/parts/NSP24D',
#  'https://ecat.spectrapremium.com/en/parts/NSP25A',
#  'https://ecat.spectrapremium.com/en/parts/NSP25B',
#  'https://ecat.spectrapremium.com/en/parts/NSP25C',
#  'https://ecat.spectrapremium.com/en/parts/NSP26A',
#  'https://ecat.spectrapremium.com/en/parts/NSP26C',
#  'https://ecat.spectrapremium.com/en/parts/NSP27A',
#  'https://ecat.spectrapremium.com/en/parts/HOP41A',
#  'https://ecat.spectrapremium.com/en/parts/HYP01A',
#  'https://ecat.spectrapremium.com/en/parts/HYP01B',
#  'https://ecat.spectrapremium.com/en/parts/HYP02A',
#  'https://ecat.spectrapremium.com/en/parts/HYP03A',
#  'https://ecat.spectrapremium.com/en/parts/HYP03B',
#  'https://ecat.spectrapremium.com/en/parts/HYP04A',
#  'https://ecat.spectrapremium.com/en/parts/HYP04B',
#  'https://ecat.spectrapremium.com/en/parts/HYP05A',
#  'https://ecat.spectrapremium.com/en/parts/HYP05B',
#  'https://ecat.spectrapremium.com/en/parts/HYP05C',
#  'https://ecat.spectrapremium.com/en/parts/HYP06A',
#  'https://ecat.spectrapremium.com/en/parts/HYP07A',
#  'https://ecat.spectrapremium.com/en/parts/HYP08A',
#  'https://ecat.spectrapremium.com/en/parts/HYP09A',
#  'https://ecat.spectrapremium.com/en/parts/HYP12A',
#  'https://ecat.spectrapremium.com/en/parts/HYP14A',
#  'https://ecat.spectrapremium.com/en/parts/HYP16A',
#  'https://ecat.spectrapremium.com/en/parts/HYP17A',
#  'https://ecat.spectrapremium.com/en/parts/HYP18A',
#  'https://ecat.spectrapremium.com/en/parts/HYP19A',
#  'https://ecat.spectrapremium.com/en/parts/HYP20A',
#  'https://ecat.spectrapremium.com/en/parts/HYP21A',
#  'https://ecat.spectrapremium.com/en/parts/HYP22A',
#  'https://ecat.spectrapremium.com/en/parts/HYP23A',
#  'https://ecat.spectrapremium.com/en/parts/HYP25A',
#  'https://ecat.spectrapremium.com/en/parts/HYP27A',
#  'https://ecat.spectrapremium.com/en/parts/HYP28A',
#  'https://ecat.spectrapremium.com/en/parts/HYP30A',
#  'https://ecat.spectrapremium.com/en/parts/HYP31A',
#  'https://ecat.spectrapremium.com/en/parts/HYP32A',
#  'https://ecat.spectrapremium.com/en/parts/HYP33A',
#  'https://ecat.spectrapremium.com/en/parts/HYP34A',
#  'https://ecat.spectrapremium.com/en/parts/KIP03A',
#  'https://ecat.spectrapremium.com/en/parts/MDP01A',
#  'https://ecat.spectrapremium.com/en/parts/MDP02A',
#  'https://ecat.spectrapremium.com/en/parts/MDP03A',
#  'https://ecat.spectrapremium.com/en/parts/MDP04A',
#  'https://ecat.spectrapremium.com/en/parts/MDP06A',
#  'https://ecat.spectrapremium.com/en/parts/MDP10A',
#  'https://ecat.spectrapremium.com/en/parts/MDP11A',
#  'https://ecat.spectrapremium.com/en/parts/MDP12A',
#  'https://ecat.spectrapremium.com/en/parts/MDP14A',
#  'https://ecat.spectrapremium.com/en/parts/MDP16A',
#  'https://ecat.spectrapremium.com/en/parts/MDP17A',
#  'https://ecat.spectrapremium.com/en/parts/MDP19A',
#  'https://ecat.spectrapremium.com/en/parts/MDP20A',
#  'https://ecat.spectrapremium.com/en/parts/MDP21A',
#  'https://ecat.spectrapremium.com/en/parts/MDP22A',
#  'https://ecat.spectrapremium.com/en/parts/MDP23A',
#  'https://ecat.spectrapremium.com/en/parts/GMP88A',
#  'https://ecat.spectrapremium.com/en/parts/GMP89A',
#  'https://ecat.spectrapremium.com/en/parts/GMP92A',
#  'https://ecat.spectrapremium.com/en/parts/GMP93A',
#  'https://ecat.spectrapremium.com/en/parts/GMP95A',
#  'https://ecat.spectrapremium.com/en/parts/GMP97A',
#  'https://ecat.spectrapremium.com/en/parts/GMP98A',
#  'https://ecat.spectrapremium.com/en/parts/HOP01A',
#  'https://ecat.spectrapremium.com/en/parts/HOP01B',
#  'https://ecat.spectrapremium.com/en/parts/HOP02A',
#  'https://ecat.spectrapremium.com/en/parts/HOP03A',
#  'https://ecat.spectrapremium.com/en/parts/HOP04A',
#  'https://ecat.spectrapremium.com/en/parts/HOP06A',
#  'https://ecat.spectrapremium.com/en/parts/HOP06B',
#  'https://ecat.spectrapremium.com/en/parts/HOP07A',
#  'https://ecat.spectrapremium.com/en/parts/HOP10A',
#  'https://ecat.spectrapremium.com/en/parts/HOP11A',
#  'https://ecat.spectrapremium.com/en/parts/HOP11B',
#  'https://ecat.spectrapremium.com/en/parts/HOP12A',
#  'https://ecat.spectrapremium.com/en/parts/HOP13A',
#  'https://ecat.spectrapremium.com/en/parts/HOP14A',
#  'https://ecat.spectrapremium.com/en/parts/HOP15A',
#  'https://ecat.spectrapremium.com/en/parts/HOP16A',
#  'https://ecat.spectrapremium.com/en/parts/HOP16B',
#  'https://ecat.spectrapremium.com/en/parts/HOP17B',
#  'https://ecat.spectrapremium.com/en/parts/HOP18A',
#  'https://ecat.spectrapremium.com/en/parts/HOP18B',
#  'https://ecat.spectrapremium.com/en/parts/HOP19A',
#  'https://ecat.spectrapremium.com/en/parts/HOP20A',
#  'https://ecat.spectrapremium.com/en/parts/HOP20B',
#  'https://ecat.spectrapremium.com/en/parts/HOP20C',
#  'https://ecat.spectrapremium.com/en/parts/HOP21A',
#  'https://ecat.spectrapremium.com/en/parts/HOP22A',
#  'https://ecat.spectrapremium.com/en/parts/HOP23A',
#  'https://ecat.spectrapremium.com/en/parts/HOP23B',
#  'https://ecat.spectrapremium.com/en/parts/HOP24A',
#  'https://ecat.spectrapremium.com/en/parts/HOP25A',
#  'https://ecat.spectrapremium.com/en/parts/HOP26A',
#  'https://ecat.spectrapremium.com/en/parts/HOP28A',
#  'https://ecat.spectrapremium.com/en/parts/HOP29A',
#  'https://ecat.spectrapremium.com/en/parts/HOP30A',
#  'https://ecat.spectrapremium.com/en/parts/HOP31A',
#  'https://ecat.spectrapremium.com/en/parts/HOP33A',
#  'https://ecat.spectrapremium.com/en/parts/HOP34A',
#  'https://ecat.spectrapremium.com/en/parts/HOP35A',
#  'https://ecat.spectrapremium.com/en/parts/HOP36A',
#  'https://ecat.spectrapremium.com/en/parts/HOP37A',
#  'https://ecat.spectrapremium.com/en/parts/HOP38A',
#  'https://ecat.spectrapremium.com/en/parts/HOP39A',
#  'https://ecat.spectrapremium.com/en/parts/HOP40A',
#  'https://ecat.spectrapremium.com/en/parts/VWP31A',
#  'https://ecat.spectrapremium.com/en/parts/VWP32A',
#  'https://ecat.spectrapremium.com/en/parts/VWP33A',
#  'https://ecat.spectrapremium.com/en/parts/VWP34A',
#  'https://ecat.spectrapremium.com/en/parts/VWP35A',
#  'https://ecat.spectrapremium.com/en/parts/VWP36A',
#  'https://ecat.spectrapremium.com/en/parts/VWP37A',
#  'https://ecat.spectrapremium.com/en/parts/VWP38A',
#  'https://ecat.spectrapremium.com/en/parts/VWP39A',
#  'https://ecat.spectrapremium.com/en/parts/VWP40A',
#  'https://ecat.spectrapremium.com/en/parts/VWP42A',
#  'https://ecat.spectrapremium.com/en/parts/VWP43A',
#  'https://ecat.spectrapremium.com/en/parts/VWP44A',
#  'https://ecat.spectrapremium.com/en/parts/VWP45A',
#  'https://ecat.spectrapremium.com/en/parts/VWP47A',
#  'https://ecat.spectrapremium.com/en/parts/VWP55A',
#  'https://ecat.spectrapremium.com/en/parts/VWP56A',
#  'https://ecat.spectrapremium.com/en/parts/VWP57A',
#  'https://ecat.spectrapremium.com/en/parts/VWP58A',
#  'https://ecat.spectrapremium.com/en/parts/VWP59A',
#  'https://ecat.spectrapremium.com/en/parts/VWP60A',
#  'https://ecat.spectrapremium.com/en/parts/VWP61A']

# %%
df = pd.DataFrame(columns=['Url',
                           'Vehicle',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [Url, Vehicle, status]
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

# %%
i = 2

page = 0
list_make_model_year = []
while True:
    print(page)
    resp = requests.get(list_url[i] + '?page=' + str(page) + '#applications').text
    soup = BeautifulSoup(resp, 'lxml')
    html = etree.HTML(str(soup))
    
    if len(html.xpath('//h1[@class="titre titre--1"]')) != 0:
        break
    
    list_make_model = [make_model.text for make_model in html.xpath('//section[@id="applications"]/h3[@class="part__titre-groupe-vehicules"]')]
    list_table = html.xpath('//section[@id="applications"]/table[@class="part__table-applications"]')
    for j in range(len(list_table)):
        index = [header.text for header in list_table[j].xpath('./descendant::th[@class="part__table-applications__header"]')].index('Year')
        list_year = [int(year.text) for year in list_table[j].xpath('./descendant::tbody/tr[@class="part__table-applications__row"]/td[@class="part__table-applications__data"][1]')]
        list_year = list(set(list_year))
        if len(list_year) == 1:
            year = str(list_year[0])
        else:
            year = str(min(list_year)) + '-' + str(max(list_year))

        list_make_model_year.append(list_make_model[j] + ' ' + year)
        
    page += 1
    
list_make_model_year
# Out:
# 0
# 1
# 2
# 3
# 4
# ['Jeep Wrangler 75th Anniversary V6 3.6L 2016',
#  'Jeep Wrangler Rubicon V6 3.6L 2012-2018',
#  'Jeep Wrangler Sahara V6 3.6L 2012-2017',
#  'Jeep Wrangler Sport V6 3.6L 2012-2018',
#  'Jeep Wrangler Sport S V6 3.6L 2016-2018',
#  'Jeep Wrangler Unlimited V6 3.6L 2012',
#  'Jeep Wrangler Unlimited 75th Anniversary V6 3.6L 2016',
#  'Jeep Wrangler 75th Anniversary V6 3.6L 2016',
#  'Jeep Wrangler Rubicon V6 3.6L 2012-2018',
#  'Jeep Wrangler Sahara V6 3.6L 2012-2017',
#  'Jeep Wrangler Sport V6 3.6L 2012-2018',
#  'Jeep Wrangler Sport S V6 3.6L 2016-2018',
#  'Jeep Wrangler Unlimited V6 3.6L 2012',
#  'Jeep Wrangler Unlimited 75th Anniversary V6 3.6L 2016',
#  'Jeep Wrangler Unlimited Altitude V6 3.6L 2012-2015',
#  'Jeep Wrangler Unlimited Black Bear V6 3.6L 2016',
#  'Jeep Wrangler Unlimited Hard Rock V6 3.6L 2015',
#  'Jeep Wrangler Unlimited Moab V6 3.6L 2018',
#  'Jeep Wrangler Unlimited Mountain V6 3.6L 2012',
#  'Jeep Wrangler Unlimited Rubicon V6 3.6L 2012-2018',
#  'Jeep Wrangler Unlimited Sahara V6 3.6L 2012-2018',
#  'Jeep Wrangler Unlimited Smoky Mountain V6 3.6L 2017',
#  'Jeep Wrangler Unlimited Sport V6 3.6L 2015-2018',
#  'Jeep Wrangler Unlimited Sport V6 3.6L 2012-2014',
#  'Jeep Wrangler Unlimited Sport S V6 3.6L 2016-2018',
#  'Jeep Wrangler Unlimited Willys Wheeler V6 3.6L 2014',
#  'Jeep Wrangler Unlimited Winter Edition V6 3.6L 2017',
#  'Jeep Wrangler Willys Wheeler V6 3.6L 2014',
#  'Jeep Wrangler JK Rubicon V6 3.6L 2018',
#  'Jeep Wrangler JK Sahara V6 3.6L 2018',
#  'Jeep Wrangler JK Sport V6 3.6L 2018',
#  'Jeep Wrangler JK Sport S V6 3.6L 2018',
#  'Jeep Wrangler JK Unlimited Rubicon V6 3.6L 2018',
#  'Jeep Wrangler JK Unlimited Sahara V6 3.6L 2018',
#  'Jeep Wrangler JK Unlimited Sport V6 3.6L 2018',
#  'Jeep Wrangler JK Unlimited Sport S V6 3.6L 2018',
#  'Jeep Wrangler JK Unlimited Willys Wheeler V6 3.6L 2018']
