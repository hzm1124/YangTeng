# %%
param_date = '20240715'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./{param_date}/2.group.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Manufacturer No'] = input_['Manufacturer No'].astype(int)
input_['Group No'] = input_['Group No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Group'].tolist()
# Out:
# 总数量：2525
# ['Body & Lamp Assembly',
#  'Interior',
#  'Body & Lamp Assembly',
#  'Engine',
#  'Garage Equipment',
#  'Interior',
#  'Steering',
#  'Interior',
#  'Fuel & Air',
#  'Ignition',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Ignition',
#  'Body & Lamp Assembly',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Fuel & Air',
#  'Cooling System',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Engine',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Cooling System',
#  'Electrical-Connector',
#  'Engine',
#  'Fuel & Air',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Steering',
#  'Transmission-Manual',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Interior',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Engine',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Electrical-Connector',
#  'Wiper & Washer',
#  'Exhaust & Emission',
#  'Exhaust & Emission',
#  'Garage Equipment',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Exhaust & Emission',
#  'Steering',
#  'Body & Lamp Assembly',
#  'Interior',
#  'Wheel',
#  'Belt Drive',
#  'Suspension',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Apparel & Gifts',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Steering',
#  'Fuel & Air',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Steering',
#  'Suspension',
#  'Engine',
#  'Fuel & Air',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Transmission-Automatic',
#  'Electrical-Connector',
#  'Fuel & Air',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Fuel & Air',
#  'Ignition',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Wheel',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Heat & Air Conditioning',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Wheel',
#  'Body & Lamp Assembly',
#  'Ignition',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Engine',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Engine',
#  'Steering',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Electrical',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Wheel',
#  'Literature',
#  'Brake & Wheel Hub',
#  'Wheel',
#  'Engine',
#  'Steering',
#  'Suspension',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Wheel',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Exhaust & Emission',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Suspension',
#  'Transmission-Automatic',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Hardware',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Heat & Air Conditioning',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Transmission-Automatic',
#  'Cooling System',
#  'Exhaust & Emission',
#  'Ignition',
#  'Heat & Air Conditioning',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Electrical-Bulb & Socket',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Ignition',
#  'Wiper & Washer',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Exhaust & Emission',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Engine',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Engine',
#  'Wiper & Washer',
#  'Electrical',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Electrical',
#  'Heat & Air Conditioning',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Steering',
#  'Transmission-Automatic',
#  'Interior',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Wiper & Washer',
#  'Engine',
#  'Cooling System',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Interior',
#  'Wheel',
#  'Drivetrain',
#  'Steering',
#  'Engine',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Garage Equipment',
#  'Hardware',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Interior',
#  'Body & Lamp Assembly',
#  'Engine',
#  'Interior',
#  'Literature',
#  'Exhaust & Emission',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Wiper & Washer',
#  'Suspension',
#  'Drivetrain',
#  'Engine',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Exhaust & Emission',
#  'Body & Lamp Assembly',
#  'Fuel & Air',
#  'Interior',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Wheel',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Cooling System',
#  'Literature',
#  'Fuel & Air',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Manual',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Body & Lamp Assembly',
#  'Wheel',
#  'Drivetrain',
#  'Body & Lamp Assembly',
#  'Engine',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Transmission-Automatic',
#  'Exhaust & Emission',
#  'Electrical-Switch & Relay',
#  'Ignition',
#  'Ignition',
#  'Cooling System',
#  'Drivetrain',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Engine',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Engine',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Hardware',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Electrical-Bulb & Socket',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Ignition',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Steering',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Garage Equipment',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Engine',
#  'Engine',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Cooling System',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Electrical',
#  'Transmission-Manual',
#  'Electrical',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Interior',
#  'Wheel',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Body & Lamp Assembly',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Steering',
#  'Suspension',
#  'Body & Lamp Assembly',
#  'Drivetrain',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Engine',
#  'Steering',
#  'Suspension',
#  'Wheel',
#  'Wiper & Washer',
#  'Electrical',
#  'Ignition',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Ignition',
#  'Interior',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Steering',
#  'Transmission-Manual',
#  'Brake & Wheel Hub',
#  'Electrical',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Ignition',
#  'Transmission-Automatic',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Suspension',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Belt Drive',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Brake & Wheel Hub',
#  'Heat & Air Conditioning',
#  'Brake & Wheel Hub',
#  'Transmission-Manual',
#  'Electrical',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Ignition',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Drivetrain',
#  'Steering',
#  'Suspension',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Steering',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wiper & Washer',
#  'Electrical-Connector',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Electrical-Bulb & Socket',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Fuel & Air',
#  'Brake & Wheel Hub',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Transmission-Automatic',
#  'Drivetrain',
#  'Body & Lamp Assembly',
#  'Belt Drive',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Hardware',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Suspension',
#  'Transmission-Automatic',
#  'Transmission-Manual',
#  'Wheel',
#  'Wiper & Washer',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Drivetrain',
#  'Electrical-Connector',
#  'Engine',
#  'Fuel & Air',
#  'Belt Drive',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Heat & Air Conditioning',
#  'Hoses/Lines & Clamps',
#  'Ignition',
#  'Interior',
#  'Steering',
#  'Transmission-Automatic',
#  'Wiper & Washer',
#  'Interior',
#  'Body & Lamp Assembly',
#  'Electrical',
#  'Electrical-Bulb & Socket',
#  'Electrical-Connector',
#  'Electrical-Switch & Relay',
#  'Garage Equipment',
#  'Interior',
#  'Brake & Wheel Hub',
#  'Drivetrain',
#  'Suspension',
#  'Cooling System',
#  'Electrical',
#  'Electrical-Switch & Relay',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Ignition',
#  'Brake & Wheel Hub',
#  'Steering',
#  'Suspension',
#  'Brake & Wheel Hub',
#  'Engine',
#  'Fuel & Air',
#  'Garage Equipment',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Engine',
#  'Exhaust & Emission',
#  'Fuel & Air',
#  'Heat & Air Conditioning',
#  'Steering',
#  'Transmission-Automatic',
#  'Brake & Wheel Hub',
#  'Engine',
#  'Belt Drive',
#  'Cooling System',
#  'Engine',
#  'Steering',
#  'Transmission-Automatic',
#  'Literature',
#  'Body & Lamp Assembly',
#  'Brake & Wheel Hub',
#  'Cooling System',
#  'Electrical',
#  ...]

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests
import json

import sys
sys.path.append('../../00.Tools')
from crawler_configuration import get_header, get_proxy

data = {'func': 'partsearchgetparttypessdd',
        'mfr': input_.loc[a, 'Manufacturer'],
        'pg': input_.loc[a, 'Group'],
        'giveback': json.dumps({'id': 'partsearch_007'}),
        'api_json_request': '1'}

b = 0
while True:

    while True:
        b += 1
        print(b)
        try:
            resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                 data=data,
                                 headers=get_header(),
                                 proxies=get_proxy(),
                                 timeout=(10, 10))
            break
        except:
            continue

    if resp.status_code == 200:
        break

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'html_replace_sections': {'ddrepl[parttype_][container]': '<span id="ddrepl[parttype_][container]" class="ra-vertical-dropdown-replacement-c"><select id="parttype_" name="partsearch[parttype][]" onchange = "" tabindex="0" autocomplete = "none"><option value=""  selected >All</option><option value="1263"  >Cargo Bag</option><option value="1000410"  >Cargo Carrier</option><option value="1104"  >Roof Rack</option><option value="1152"  >Sunroof Wind Deflector</option></select></span>'},
#  'giveback': {'id': 'partsearch_007'},
#  'collected_javascript': '/**UQ:1F7A8A93**/\nwindow.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\\/0bbOhvn7P3rkFbL809YNOHQDmNBznFtdYfbcEUriQ0mcmy\\/TcWfcbfHTjxSwndfe2chgzy88liHO2MoAcp7wW7lek5DxawTLSg\\/DpYUwwgKwrMfy32BI6R68c\\/w7j6KldZsshRcNdDKSl4lF2c=";\n'}

# %%
'redirect_to_url' in json_

# %%
json_['giveback']['id'] == 'partsearch_007' and 'collected_javascript' in json_
# Out:
# True

# %%
from bs4 import BeautifulSoup
from lxml import etree

soup = BeautifulSoup(json_['html_replace_sections']['ddrepl[parttype_][container]'], 'lxml')
html = etree.HTML(str(soup))

with open('./type.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <span class="ra-vertical-dropdown-replacement-c" id="ddrepl[parttype_][container]">
#    <select autocomplete="none" id="parttype_" name="partsearch[parttype][]" onchange="" tabindex="0">
#     <option selected="" value="">
#      All
#     </option>
#     <option value="1263">
#      Cargo Bag
#     </option>
#     <option value="1000410">
#      Cargo Carrier
#     </option>
#     <option value="1104">
#      Roof Rack
#     </option>
#     <option value="1152">
#      Sunroof Wind Deflector
#     </option>
#    </select>
#   </span>
#  </body>
# </html>

# %%
list_type_code = html.xpath('//select[@id="parttype_"]/option/@value')[1:]

list_type_code
# Out:
# ['1263', '1000410', '1104', '1152']

# %%
list_type = html.xpath('//select[@id="parttype_"]/option/text()')[1:]

list_type
# Out:
# ['Cargo Bag', 'Cargo Carrier', 'Roof Rack', 'Sunroof Wind Deflector']

# %%
len(list_type) == 0
# Out:
# False

# %%
df_temp = pd.DataFrame({'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                        'Manufacturer': input_.loc[a, 'Manufacturer'],
                        'Group No': input_.loc[a, 'Group No'],
                        'Group': input_.loc[a, 'Group'],
                        'Type No': [i+1 for i in range(len(list_type))],
                        'Type': list_type,
                        'Type Code': list_type_code,
                        'Tab 2 Url': [f'''https://www.rockauto.com/en/parts/{input_.loc[a, 'Manufacturer'].replace(',', '%2C').replace('+', '%2B')},{type_.replace(',', '%2C')},{type_code.replace(',', '%2C')}''' for type_, type_code in zip(list_type, list_type_code)]})

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Manufacturer No Manufacturer  Group No                 Group  Type No  \
# 0                1           3D         1  Body & Lamp Assembly        1
# 1                1           3D         1  Body & Lamp Assembly        2
# 2                1           3D         1  Body & Lamp Assembly        3
# 3                1           3D         1  Body & Lamp Assembly        4
#
#                      Type Type Code  \
# 0               Cargo Bag      1263
# 1           Cargo Carrier   1000410
# 2               Roof Rack      1104
# 3  Sunroof Wind Deflector      1152
#
#                                            Tab 2 Url
# 0  https://www.rockauto.com/en/parts/3D,Cargo Bag...
# 1  https://www.rockauto.com/en/parts/3D,Cargo Car...
# 2  https://www.rockauto.com/en/parts/3D,Roof Rack...
# 3  https://www.rockauto.com/en/parts/3D,Sunroof W...

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                             'Manufacturer': input_.loc[a, 'Manufacturer'],
                             'Group No': input_.loc[a, 'Group No'],
                             'Group': input_.loc[a, 'Group']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Manufacturer No', 'Group No', 'Type No'],
                                                ascending=[True, True, True],
                                                ignore_index=True)
    output_correct.to_excel('./test_type.xlsx', index=False)

output_correct
# Out:
#    Manufacturer No Manufacturer  Group No                 Group  Type No  \
# 0                1           3D         1  Body & Lamp Assembly        1
# 1                1           3D         1  Body & Lamp Assembly        2
# 2                1           3D         1  Body & Lamp Assembly        3
# 3                1           3D         1  Body & Lamp Assembly        4
#
#                      Type Type Code  \
# 0               Cargo Bag      1263
# 1           Cargo Carrier   1000410
# 2               Roof Rack      1104
# 3  Sunroof Wind Deflector      1152
#
#                                            Tab 2 Url
# 0  https://www.rockauto.com/en/parts/3D,Cargo Bag...
# 1  https://www.rockauto.com/en/parts/3D,Cargo Car...
# 2  https://www.rockauto.com/en/parts/3D,Roof Rack...
# 3  https://www.rockauto.com/en/parts/3D,Sunroof W...

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Manufacturer No', 'Group No'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel('./test_type_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
