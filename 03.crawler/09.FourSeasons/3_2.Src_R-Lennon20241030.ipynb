# %%
from gevent import monkey
monkey.patch_all(thread=False)

from gevent.pool import Pool
pool = Pool(30)

from gevent.lock import BoundedSemaphore
semaphore_correct, semaphore_error, semaphore_remain = BoundedSemaphore(1), BoundedSemaphore(1), BoundedSemaphore(1)

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

directory_out = './file/3.src'

if os.path.exists(directory_out):
    shutil.rmtree(directory_out)
os.makedirs(directory_out)

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

import json

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

# = = = = = = = = = = = = = = =

directory_in = './file/2.part'

list_file = [file for file in sorted(os.listdir(directory_in)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_in}/{file}')]
for file in list_file:

    # = = = = = = = = = = = = = = =

    list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(f'{directory_in}/{file}',
                                                                           header=0,
                                                                           dtype=str).fillna('')

    df_input['No'] = df_input['No'].astype(int)

    count_remain = len(df_input)

    print(f'总数量：{count_remain}')
    print()

    # = = = = = = = = = = = = = = =

    def crawler(crawler_tuple):
        global list_dict_correct, list_series_error, count_remain

        crawler_status, (crawler_index, crawler_series) = False, crawler_tuple

        # = = = = = = = = = = = = = = =

        try:
            count_retry = 0
            while True:
                count_retry += 1

                try:
                    url_request, url_check = f'''https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum={crawler_series['Part Number']}&brand={json.loads(crawler_series['Json_Info'])['Brand']}&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960''', crawler_series['Url']

                    resp = requests.get(url_request,
                                        headers=get_header(),
                                        proxies=get_proxy(),
                                        timeout=(5, 15))

                    if resp.status_code == 200:
                        break
                except KeyboardInterrupt:
                    break
                except:
                    continue

            # = = = = = = = = = = = = = = =

            dict_src = {}
            for i, dict_ in enumerate(resp.json()):
                dict_src[str(i)] = dict_['image_BG_Url'].strip()

            # = = = = = = = = = = = = = = =

            with semaphore_correct:
                list_dict_correct.append({'No': crawler_series['No'],
                                          'Part Number': crawler_series['Part Number'],
                                          'Vehicle': crawler_series['Vehicle'],
                                          'Picture': crawler_series['Picture'],
                                          'Url': crawler_series['Url'],
                                          'Json_Src': json.dumps(dict_src),
                                          'Json_Type': crawler_series['Json_Type'],
                                          'Json_Info': crawler_series['Json_Info'],
                                          'Json_Specification': crawler_series['Json_Specification']})

            # = = = = = = = = = = = = = = =

            crawler_status = True
        except:
            crawler_series['Request_Url'], crawler_series['Check_Url'] = url_request, url_check

            with semaphore_error:
                list_series_error.append(crawler_series)

        # = = = = = = = = = = = = = = =

        if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and count_remain == 1 or count_remain % 300 == 0 and count_remain != 0:
            clear_output()
        print(f'''[{crawler_status}] - [请求{count_retry}次] - [剩余{count_remain - 1}条] - [{file.removesuffix('.xlsx')}（{(list_file.index(file) + 1) / len(list_file) * 100:.2f}%）] - [{datetime.now().strftime('%Y/%m/%d %H:%M:%S')}] - {crawler_series['No']}. {url_request}\n''')

        with semaphore_remain:
            count_remain -= 1

    # = = = = = = = = = = = = = = =

    pool.map(crawler, df_input.iterrows())

    print('输出ing...')
    print()
    if list_dict_correct:
        df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['No'],
                                                                 ascending=[True],
                                                                 ignore_index=True)
        df_correct.to_excel(f'''{directory_out}/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if list_series_error:
        df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                               ascending=[True],
                                                               ignore_index=True)
        df_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-src_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = [file for file in sorted(os.listdir(directory_out)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_out}/{file}')]
for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'{directory_out}/{file}',
              f'''{directory_out}/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：10
#
# [True] - [请求1次] - [剩余9条] - [crawler_1（50.00%）] - [2024/10/30 08:36:46] - 10. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44021&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求7次] - [剩余8条] - [crawler_1（50.00%）] - [2024/10/30 08:36:46] - 5. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44002&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求1次] - [剩余7条] - [crawler_1（50.00%）] - [2024/10/30 08:36:47] - 6. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44003&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求6次] - [剩余6条] - [crawler_1（50.00%）] - [2024/10/30 08:36:47] - 8. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44015&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求2次] - [剩余5条] - [crawler_1（50.00%）] - [2024/10/30 08:36:47] - 4. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44001&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求10次] - [剩余4条] - [crawler_1（50.00%）] - [2024/10/30 08:36:47] - 2. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=16152&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求22次] - [剩余3条] - [crawler_1（50.00%）] - [2024/10/30 08:36:48] - 9. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44017&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求14次] - [剩余2条] - [crawler_1（50.00%）] - [2024/10/30 08:36:49] - 3. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=16155&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求19次] - [剩余1条] - [crawler_1（50.00%）] - [2024/10/30 08:36:50] - 1. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=16149&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求50次] - [剩余0条] - [crawler_1（50.00%）] - [2024/10/30 08:36:55] - 7. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44014&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# 输出ing...
#
# 总数量：10
#
# [True] - [请求5次] - [剩余9条] - [crawler_2（100.00%）] - [2024/10/30 08:36:57] - 1. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=44136&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求1次] - [剩余8条] - [crawler_2（100.00%）] - [2024/10/30 08:36:57] - 10. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90010&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求7次] - [剩余7条] - [crawler_2（100.00%）] - [2024/10/30 08:36:57] - 6. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90004&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求10次] - [剩余6条] - [crawler_2（100.00%）] - [2024/10/30 08:36:57] - 4. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90002&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求9次] - [剩余5条] - [crawler_2（100.00%）] - [2024/10/30 08:36:57] - 9. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90009&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求16次] - [剩余4条] - [crawler_2（100.00%）] - [2024/10/30 08:36:58] - 8. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90007&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求11次] - [剩余3条] - [crawler_2（100.00%）] - [2024/10/30 08:36:59] - 3. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90001&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求37次] - [剩余2条] - [crawler_2（100.00%）] - [2024/10/30 08:37:00] - 5. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90003&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求39次] - [剩余1条] - [crawler_2（100.00%）] - [2024/10/30 08:37:00] - 2. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=86043&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# [True] - [请求54次] - [剩余0条] - [crawler_2（100.00%）] - [2024/10/30 08:37:03] - 7. https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=90005&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 3867.50it/s]
# Done ~
