# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel('./menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

print(f'总数量：{len(input_)}')
input_['Url'].tolist()
# Out:
# 总数量：11
# ['http://www.fenderliner.com/products-show.asp?seq=4650',
#  'http://www.fenderliner.com/products-show.asp?seq=4599',
#  'http://www.fenderliner.com/products-show.asp?seq=4882',
#  'http://www.fenderliner.com/products-show.asp?seq=4884',
#  'http://www.fenderliner.com/products-show.asp?seq=6063',
#  'http://www.fenderliner.com/products-show.asp?seq=6099',
#  'http://www.fenderliner.com/products-show.asp?seq=6027',
#  'http://www.fenderliner.com/products-show.asp?seq=6028',
#  'http://www.fenderliner.com/products-show.asp?seq=6172',
#  'http://www.fenderliner.com/products-show.asp?seq=6173',
#  'http://www.fenderliner.com/products-show.asp?seq=6042']

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 0

resp = requests.get(input_.loc[a, 'Url'],
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml" vocab="http://schema.org/">\r\n<head>\r\n\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<title>Fender Liner Manufacturer in Taiwan│GBC</title>\r\n<meta name="viewport" content="user-scalable=1,width=1200,initial-scale=1">\r\n<meta http-equiv="content-language" content="en">\r\n<meta name="description" property="og:description"  content="Fender Liner Manufacturer in Taiwan│GBC" />\r\n<meta name="keywords" content="Fender Liner Manufacturer in Taiwan│GBC" />\r\n<meta property="og:title" content="Fender Liner Manufacturer in Taiwan│GBC"/>\r\n<meta property="og:url" content=""/>\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:image" content=""/>\r\n<meta property="og:site_name" content=""/>\r\n<meta name="author" content="" />\r\n<meta name="copyright" content="" />\r\n<link rel="Shortcut icon" href="images/favicon.ico" type="image/x-icon" />\r\n<link rel="Bookmark" href="images/favicon.ico" type="image/x-icon"/>\r\n\r\n<!--font-->\r\n<script src="js/fonts.js" type="text/javascript"></script>\r\n<link href="css/css.css?2" type="text/css" rel="stylesheet" />\r\n<!-- google language -->\r\n<script type="text/javascript">\r\nfunction googleTranslateElementInit() {\r\n  new google.translate.TranslateElement({pageLanguage: \'en\', layout: google.translate.TranslateElement.InlineLayout.SIMPLE}, \'google_translate_element\');\r\n}\r\n</script>\r\n<script type="text/javascript" src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit"></script>\r\n<!-- js -->\r\n<script src="http://code.jquery.com/jquery-1.11.3.min.js"></script>\r\n<!-- menu -->\r\n<script>\r\n\tjQuery( document ).ready( function( $ ) {\r\n    //menu\r\n\tvar $menu = $(\'#nav-level\'),\r\n\t$menulink = $(\'.nav-link\');\r\n\t$menulink.hover(function(e) {\r\n\t\te.preventDefault();\r\n\t\t$menulink.toggleClass(\'nav-on\');\r\n\t\t$menu.toggleClass(\'nav-open\');\r\n\t});\r\n});\r\n</script>\r\n<div style="position: absolute; top: -999px;left: -999px;">how to comb black male hair peruvian hair deep wave <a href="https://www.finesthairextensions.co.uk/">hair extensions</a> using toner on hair extensions curly human hair weave bundles <a href="https://www.hair-extensions2go.co.uk/">remy hair</a> secret extensions review custom made wigs manchester <a href="http://www.hairflair.org.uk">human lace wigs</a> hair barrettes uk 3/4 hairpiece uk <a href="https://www.leez-extensions.co.uk/">human hair</a> </div>\r\n<!--fancybox-->\r\n<script type="text/javascript" src="fancybox/lib/jquery.mousewheel-3.0.6.pack.js"></script>\r\n<link rel="stylesheet" href="fancybox/jquery.fancybox.css" type="text/css" media="screen" />\r\n<script type="text/javascript" src="fancybox/jquery.fancybox.js"></script>\r\n<link rel="stylesheet" href="fancybox/helpers/jquery.fancybox-buttons.css" type="text/css" media="screen" />\r\n<script type="text/javascript" src="fancybox/helpers/jquery.fancybox-buttons.js"></script>\r\n<script type="text/javascript" src="fancybox/helpers/jquery.fancybox-media.js"></script>\r\n<script type="text/javascript">\r\n$(function() {\r\n\t$(".fancybox").fancybox({\r\n\t\topenEffect: \'none\',\r\n\t\tcloseEffect: \'none\'\r\n\t});\r\n});\r\n</script>\r\n<!--slick slider-->\r\n<link rel="stylesheet" type="text/css" href="css/slick.css"/>\r\n<script type="text/javascript" src="js/slick.js"></script>\r\n<script type="text/javascript">\r\n  $(function(){\r\n      $(\'.related-area\').slick({\r\n        infinite: true,\r\n        speed: 1000,\r\n        autoplay: true,\r\n        slidesToShow: 4,\r\n        slidesToScroll: 4,\r\n        prevArrow: \'<div type="button" class="related-nav slick-prev">&lt;&nbsp;&lt;</div>\',\r\n        nextArrow: \'<div type="button" class="related-nav slick-next">&gt;&nbsp;&gt;</div>\'\r\n      });\r\n  });\r\n</script>\r\n<!--FB-->\r\n<div id="fb-root"></div>\r\n<script>(function(d, s, id) {\r\n  var js, fjs = d ...

# %%
from bs4 import BeautifulSoup
from lxml import etree

# %%
soup = BeautifulSoup(resp, 'lxml')
html = etree.HTML(str(soup))

with open('./part.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html vocab="http://schema.org/" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Fender Liner Manufacturer in Taiwan│GBC
#   </title>
#   <meta content="user-scalable=1,width=1200,initial-scale=1" name="viewport"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="Fender Liner Manufacturer in Taiwan│GBC" name="description" property="og:description"/>
#   <meta content="Fender Liner Manufacturer in Taiwan│GBC" name="keywords"/>
#   <meta content="Fender Liner Manufacturer in Taiwan│GBC" property="og:title"/>
#   <meta content="" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="" property="og:image"/>
#   <meta content="" property="og:site_name"/>
#   <meta content="" name="author"/>
#   <meta content="" name="copyright"/>
#   <link href="images/favicon.ico" rel="Shortcut icon" type="image/x-icon"/>
#   <link href="images/favicon.ico" rel="Bookmark" type="image/x-icon"/>
#   <!--font-->
#   <script src="js/fonts.js" type="text/javascript">
#   </script>
#   <link href="css/css.css?2" rel="stylesheet" type="text/css"/>
#   <!-- google language -->
#   <script type="text/javascript">
#    function googleTranslateElementInit() {
#   new google.translate.TranslateElement({pageLanguage: 'en', layout: google.translate.TranslateElement.InlineLayout.SIMPLE}, 'google_translate_element');
# }
#   </script>
#   <script src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript">
#   </script>
#   <!-- js -->
#   <script src="http://code.jquery.com/jquery-1.11.3.min.js">
#   </script>
#   <!-- menu -->
#   <script>
#    jQuery( document ).ready( function( $ ) {
#     //menu
# 	var $menu = $('#nav-level'),
# 	$menulink = $('.nav-link');
# 	$menulink.hover(function(e) {
# 		e.preventDefault();
# 		$menulink.toggleClass('nav-on');
# 		$menu.toggleClass('nav-open');
# 	});
# });
#   </script>
#  </head>
#  <body>
#   <div style="position: absolute; top: -999px;left: -999px;">
#    how to comb black male hair peruvian hair deep wave
#    <a href="https://www.finesthairextensions.co.uk/">
#     hair extensions
#    </a>
#    using toner on hair extensions curly human hair weave bundles
#    <a href="https://www.hair-extensions2go.co.uk/">
#     remy hair
#    </a>
#    secret extensions review custom made wigs manchester
#    <a href="http://www.hairflair.org.uk">
#     human lace wigs
#    </a>
#    hair barrettes uk 3/4 hairpiece uk
#    <a href="https://www.leez-extensions.co.uk/">
#     human hair
#    </a>
#   </div>
#   <!--fancybox-->
#   <script src="fancybox/lib/jquery.mousewheel-3.0.6.pack.js" type="text/javascript">
#   </script>
#   <link href="fancybox/jquery.fancybox.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="fancybox/jquery.fancybox.js" type="text/javascript">
#   </script>
#   <link href="fancybox/helpers/jquery.fancybox-buttons.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="fancybox/helpers/jquery.fancybox-buttons.js" type="text/javascript">
#   </script>
#   <script src="fancybox/helpers/jquery.fancybox-media.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
# 	$(".fancybox").fancybox({
# 		openEffect: 'none',
# 		closeEffect: 'none'
# 	});
# });
#   </script>
#   <!--slick slider-->
#   <link href="css/slick.css" rel="stylesheet" type="text/css"/>
#   <script src="js/slick.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function(){
#       $('.related-area').slick({
#         infinite: true,
#         speed: 1000,
#         autoplay: true,
#         slidesToShow: 4,
#         slidesToScroll: 4,
#         prevArrow: '<div type="button" class="related-nav slick-prev">&lt;&nbsp;&lt;</div>',
#         nextArrow: '<div type="button" class="related-nav slick-next">&gt;&nbsp;&gt;</div>'
#       });
#   });
#   </script>
#   <!--FB-->
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.6";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <!--header start-->
#   <header>
#    <div class="wrapper">
#     <div class="logo">
#      <a href="/" title="GREAT BESTCAM CO., LTD.">
#       <img alt="GREAT BESTCAM CO., LTD." src="images/logo.svg"/>
#      </a>
#     </div>
#     <div class="head_right">
#      <div class="top_area">
#       <div class="google-language" id="google_translate_element">
#       </div>
#       <ul class="top-link">
#        <li>
#         <a href="/" title="GREAT BESTCAM CO., LTD.">
#          <img alt="GREAT BESTCAM CO., LTD." src="images/icon01.gif"/>
#         </a>
#        </li>
#        <li>
#         <a href="sitemap.asp" title="Sitemap">
#          <img alt="Sitemap" src="images/icon02.gif"/>
#         </a>
#        </li>
#       </ul>
#       <h1>
#        Fender Liner Manufacturer in Taiwan│GBC
#       </h1>
#      </div>
#      <form action="search.asp" class="top-search" id="products-search" method="post" onsubmit="return ch_from()">
#       <h3>
#        Products Search
#       </h3>
#       <select id="Products" name="Products" onchange="p_chg()">
#        <option disabled="" hidden="" selected="" value="0">
#         Products
#        </option>
#        <option value="7">
#         Inner Fender
#        </option>
#        <option value="3">
#         Air Duct
#        </option>
#        <option value="1">
#         Bumper
#        </option>
#        <option value="4">
#         Fender Flare
#        </option>
#        <option value="5">
#         Fender
#        </option>
#        <option value="6">
#         Grille
#        </option>
#        <option value="8">
#         Heavy Duty Truck
#        </option>
#        <option value="9">
#         Spoiler
#        </option>
#        <option value="11">
#         Bumper Filler
#        </option>
#        <option value="12">
#         Bumper Molding
#        </option>
#        <option value="13">
#         Fog Lamp Cover
#        </option>
#       </select>
#       <select id="Brand" name="Brand" onchange="b_chg()">
#        <option disabled="" hidden="" selected="" value="0">
#         Brand / Make
#        </option>
#       </select>
#       <select id="Model" name="Model">
#        <option disabled="" hidden="" selected="" value="0">
#         Model
#        </option>
#       </select>
#       <input class="search-btn" type="submit" value="Search"/>
#      </form>
#      <form action="search.asp" class="top-search" id="Keyword-search" method="post" onsubmit="return ch2_from()">
#       <h3>
#        Keyword Search
#       </h3>
#       <input class="search-f" id="keywords" maxlength="20" name="keywords" placeholder="OE# / PARTSLINK#" type="text"/>
#       <input class="search-btn" type="submit" value="Search"/>
#      </form>
#     </div>
#     <div class="clean">
#     </div>
#    </div>
#    <div class="nav-area">
#     <div class="wrapper">
#      <div class="category-title">
#       Categories
#      </div>
#      <ul class="nav">
#       <li>
#        <a href="about.asp" title="About">
#         About
#        </a>
#       </li>
#       <li class="nav-link">
#        <a href="products.asp" title="Products">
#         Products
#        </a>
#        <ul class="level2" id="nav-level">
#         <li>
#          <a href="products-list.asp?title_seq=7" title="Inner Fender">
#           Inner Fender
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=3" title="Air Duct">
#           Air Duct
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=1" title="Bumper">
#           Bumper
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=4" title="Fender Flare">
#           Fender Flare
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=5" title="Fender">
#           Fender
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=6" title="Grille">
#           Grille
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=8" title="Heavy Duty Truck">
#           Heavy Duty Truck
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=9" title="Spoiler">
#           Spoiler
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=11" title="Bumper Filler">
#           Bumper Filler
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=12" title="Bumper Molding">
#           Bumper Molding
#          </a>
#         </li>
#         <li>
#          <a href="products-list.asp?title_seq=13" title="Fog Lamp Cover">
#           Fog Lamp Cover
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="news.asp" title="News">
#         News
#        </a>
#       </li>
#       <li>
#        <a href="quality.asp" title="Quality">
#         Quality
#        </a>
#       </li>
#       <li>
#        <a href="contact.asp" title="Contact">
#         Contact
#        </a>
#       </li>
#       <li>
#        <a href="download.asp" title="Download">
#         Download
#        </a>
#       </li>
#      </ul>
#      <div class="clean">
#      </div>
#     </div>
#    </div>
#   </header>
#   <script language="javascript" src="/js/system/myFormat.js">
#   </script>
#   <script language="javaScript">
#    function ch_from() {
#         var ok = true;
# 		if (ok) ok &= IsNaturalNum(document.getElementById("Products"), "Please fill the Products!!");
# 		if (ok) ok &= IsNaturalNum(document.getElementById("Brand"), "Please fill the Brand / Make!!");
#
#         if (ok == false){return false;}
# 		if (ok) {
# 			document.getElementById("products-search").submit();
# 		}
#     }
# 	function ch2_from() {
#         var ok = true;
# 		if (ok) ok &= toCheckData(document.getElementById("keywords"), "Please fill the OE# / PARTSLINK#!!");
#
#         if (ok == false){return false;}
# 		if (ok) {
# 			document.getElementById("Keyword-search").submit();
# 		}
#     }
#   </script>
#   <!--header //-->
#   <div class="wrapper">
#    <div class="wrap-right">
#     <ul class="breadcrumb" typeof="BreadcrumbList">
#      <li property="itemListElement" typeof="ListItem">
#       <span property="item">
#        <a href="/" property="url" title="Home" typeof="WebPage">
#         <span property="name">
#          Home
#         </span>
#        </a>
#        &gt;
#       </span>
#       <meta content="1" property="position"/>
#      </li>
#      <li property="itemListElement" typeof="ListItem">
#       <span property="item">
#        <a href="products.asp" property="url" title="Products" typeof="WebPage">
#         <span property="name">
#          Products
#         </span>
#        </a>
#        &gt;
#       </span>
#       <meta content="2" property="position"/>
#      </li>
#      <li property="itemListElement" typeof="ListItem">
#       <span property="item">
#        <a href="products-list.asp?title_seq=7" property="url" title="Inner Fender" typeof="WebPage">
#         <span property="name">
#          Inner Fender
#         </span>
#        </a>
#        &gt;
#       </span>
#       <meta content="3" property="position"/>
#      </li>
#      <li property="itemListElement" typeof="ListItem">
#       <span property="item">
#        <a href="products-list.asp?title_seq=7&amp;seq=1" property="url" title="BMW" typeof="WebPage">
#         <span property="name">
#          BMW
#         </span>
#        </a>
#        &gt;
#       </span>
#       <meta content="4" property="position"/>
#      </li>
#      <li class="bc-on" property="itemListElement" typeof="ListItem">
#       <span property="item">
#        <a href="products-show.asp?seq=4650" property="url" title="BMW X3 11-17 (51 71 7 213 641)" typeof="WebPage">
#         <span property="name">
#          BMW X3 11-17 (51 71 7 213 641)
#         </span>
#        </a>
#       </span>
#       <meta content="5" property="position"/>
#      </li>
#     </ul>
#     <div class="show-img">
#      <div class="b-img">
#       <img alt="BMW X3 11-17 (51 71 7 213 641)" src="/img/product/BMX6014A0L-C-1.jpg"/>
#      </div>
#      <ul class="s-img">
#       <li>
#        <a class="fancybox" href="/img/product/BMX6014A0L-C-1.jpg" rel="pro-show" title="51 71 7 213 641">
#         <img alt="BMW X3 11-17 (51 71 7 213 641)" src="/img/product/BMX6014A0L-C-1.jpg"/>
#        </a>
#       </li>
#       <li>
#        <a class="fancybox" href="/img/product/BMX6014A0L-C-2.jpg" rel="pro-show" title="51 71 7 213 641">
#         <img alt="BMW X3 11-17 (51 71 7 213 641)" src="/img/product/BMX6014A0L-C-2.jpg"/>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="show-info">
#      <h3 class="title01">
#       BMW X3 11-17 (51 71 7 213 641)
#      </h3>
#      <h4 class="title03">
#       Replacement For
#      </h4>
#      <ul class="show-info-list">
#       <li>
#        <span>
#         Brand:
#        </span>
#        BMW
#       </li>
#       <li>
#        <span>
#         Model:
#        </span>
#        X3
#       </li>
#       <li>
#        <span>
#         Year:
#        </span>
#        11-17
#       </li>
#       <li>
#        <span>
#         OE#:
#        </span>
#        51 71 7 213 641
#       </li>
#       <li>
#        <span>
#         Partslink No.:
#        </span>
#       </li>
#       <li>
#        <span>
#         Product ID:
#        </span>
#        BMX6014A0L-C
#       </li>
#       <li>
#        <span>
#         Certifed by:
#        </span>
#        <img alt="CAPA" src="images/cer-icon01.gif"/>
#       </li>
#       <li style="background: none;">
#        <div class="fb-like" data-action="like" data-href="http://61.63.232.42:22690/products-show.asp?seq=4650" data-layout="button" data-share="true" data-show-faces="false">
#        </div>
#       </li>
#      </ul>
#      <div class="btn" style="text-align: left;">
#       <a class="all-btn btn01" href="javascript:history.go(-1);" title="Back">
#        Back
#       </a>
#       <a class="all-btn btn02" href="inquiry.asp?seq=4650" title="Inquiry">
#        Inquiry
#       </a>
#      </div>
#     </div>
#     <div class="clean">
#     </div>
#     <h4 class="title03">
#      Description
#     </h4>
#     <div class="edit">
#      <ul class="about-list">
#       <li>
#        PARTS MODEL: BMW X3 F25 /X4 F26
#       </li>
#       <li>
#        PARTS DESCRIPTION: F.LINER FENDER FT. SECTION LH (CAPA)
#       </li>
#       <li>
#        YEAR: 2011,2012,2013,2014,2015,2016,2017
#       </li>
#       <li>
#        OE/AM MATERIAL: PP/PP
#       </li>
#       <li>
#        OE WEIGHT: 1.08(KG)
#       </li>
#       <li>
#        AM WEIGHT: 0.86(KG)
#       </li>
#       <li>
#        OE THICKNESS: 1.85(mm)
#       </li>
#       <li>
#        AM THICKNESS: 1.95(mm)
#       </li>
#       <li>
#        OE IZOD IMPACT TEST: 16.2(J)
#       </li>
#       <li>
#        AM IZOD IMPACT TEST: 17.34(J)
#       </li>
#       <li>
#        ALSO NAME: FR FENDER LINER / FR FENDER LINER ASSEMBLY/ FR INNER FENDER / FR WATER SPLASH SHIELD/ FR INNER FENDER WELL
#       </li>
#      </ul>
#     </div>
#     <h4 class="title03">
#      Advantage
#     </h4>
#     <div class="edit">
#      <div class="adv-btitle">
#       What make GBC replacement inner fender different to others
#      </div>
#      <h3 class="title01">
#       Material selection on production
#      </h3>
#      <p style="width:865px">
#       The plastic material used on GBC production is subject to OE(CCS) and they are tested by the CAPA approved labs to verify the physical properties within tolerance as below.
#      </p>
#      <ul class="about-list">
#       <li>
#        Material thickness(mounting point and center)&gt;0.05mm
#       </li>
#       <li>
#        Tensile strength &gt; -10%
#       </li>
#       <li>
#        Impact test &gt; -10%
#       </li>
#       <li>
#        Coefficient of liner thermo expansion &lt; +20%
#       </li>
#       <li>
#        Heat aged tensile &gt;-10%
#       </li>
#       <li>
#        Heat deflection&gt;-10%
#       </li>
#       <li>
#        Non woven fabric (sound barrier) test require TGA, DSC, thickness, mass and density, Length and width
#       </li>
#       <li style="background-position: 0 35px;">
#        GBC material source from “
#        <b class="red">
#         Formosa Chemicals &amp; Fibre Corporation
#        </b>
#        ”
#        <img alt="" height="42" src="images/adv-icon01.gif" width="50"/>
#        .
#       </li>
#      </ul>
#      <br/>
#      <br/>
#      <h3 class="title01">
#       In house manufacturing
#      </h3>
#      <ul class="about-list">
#       <li>
#        Over 11 years of production experience on the inner fender, GBC now owns.
#       </li>
#       <li>
#        <b class="red">
#         2 factories
#        </b>
#        , total over 220,000 square feet production base.
#        <br/>
#       </li>
#       <img alt="" height="306" src="images/adv-img01.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#       <li>
#        Warehouses space, 200,000 square feet with more than
#        <b class="red">
#         180,000 pcs stock
#        </b>
#        available.
#        <br/>
#       </li>
#       <img alt="" height="398" src="images/adv-img02.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#      </ul>
#      <br/>
#      <br/>
#      <h3 class="title01">
#       The production features
#      </h3>
#      <ul class="about-list">
#       <li>
#        Engineering over Injection, vacuum and composite material.
#       </li>
#       <li>
#        <b class="red">
#         Injection tooling design.
#        </b>
#        <br/>
#       </li>
#       <img alt="" height="637" src="images/adv-img03.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#       <li>
#        <b class="red">
#         Robotic CNC drilling for precise mounting hole.
#        </b>
#        <br/>
#       </li>
#       <img alt="" height="439" src="images/adv-img04.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#       <li>
#        <b class="red">
#         Plastic injection forming.
#        </b>
#        <br/>
#       </li>
#       <img alt="" height="265" src="images/adv-img05.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#      </ul>
#      <br/>
#      <br/>
#      <h3 class="title01">
#       Fitting Guaranty
#      </h3>
#      <p style="width: 865px">
#       Verified by certification organization,
#       <b class="blue">
#        GBC
#       </b>
#       certified inner fender must pass the
#       <b class="red">
#        actual vehicle test fit
#       </b>
#       from the US workshop before mass production.
#       <br/>
#       <img alt="" height="632" src="images/adv-img06.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#      </p>
#      <br/>
#      <br/>
#      <h3 class="title01">
#       Why choose GBC replacement inner fender
#      </h3>
#      <ul class="about-list">
#       <li>
#        In house manufacturing, better QC from the material to final assembly on every production.
#       </li>
#       <li>
#        <b class="red">
#         Similar material, appearance, components and function to the OE.
#        </b>
#       </li>
#       <li>
#        Better finishing and more durable
#        <b class="red">
#         than the other A/M brands.
#        </b>
#       </li>
#       <img alt="" height="294" src="images/adv-img07.jpg" style="margin: 15px 0 10px 0;" width="864"/>
#       <li style="background-position: 0 18px">
#        Item individually certified by “
#        <b class="blue">
#         CAPA
#        </b>
#        ”.
#        <img alt="" src="images/adv-icon02.gif"/>
#       </li>
#       <li>
#        The application covers most US fast movers, the largest certified inner fender manufacturer.
#       </li>
#       <li>
#        Good fitting, precise mounting holes’ position, easy installation, saving repair time half hour up to an hour.
#       </li>
#       <li>
#        Insurance companies adopt GBC inner fenders on the collision vehicle repair.
#       </li>
#      </ul>
#     </div>
#     <h4 class="title03">
#      Related Products
#     </h4>
#     <ul class="related-area">
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=457" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES E90 06-08 (51 71 7 059 379)" src="/img/product/BM31014D0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=457" title="BMW 3 SERIES E90 06-08 (51 71 7 059 379)">
#         BMW 3 SERIES E90 06-08 (51 71 7 059 379)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=458" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES E90 06-08 (51 71 7 059 380)" src="/img/product/BM31014D0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=458" title="BMW 3 SERIES E90 06-08 (51 71 7 059 380)">
#         BMW 3 SERIES E90 06-08 (51 71 7 059 380)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=459" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES E90 09-11 (51 71 7 172 499)" src="/img/product/BM31014G0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=459" title="BMW 3 SERIES E90 09-11 (51 71 7 172 499)">
#         BMW 3 SERIES E90 09-11 (51 71 7 172 499)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=460" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES E90 09-11 (51 71 7 172 500)" src="/img/product/BM31014G0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=460" title="BMW 3 SERIES E90 09-11 (51 71 7 172 500)">
#         BMW 3 SERIES E90 09-11 (51 71 7 172 500)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=461" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES E90 06-11 (51 71 7 059 377)" src="/img/product/BM31014D1L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=461" title="BMW 3 SERIES E90 06-11 (51 71 7 059 377)">
#         BMW 3 SERIES E90 06-11 (51 71 7 059 377)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=462" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES E90 06-11 (51 71 7 059 378)" src="/img/product/BM31014D1R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=462" title="BMW 3 SERIES E90 06-11 (51 71 7 059 378)">
#         BMW 3 SERIES E90 06-11 (51 71 7 059 378)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=465" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES F30 12-15 (51 71 7 260 725)" src="/img/product/BM35014B0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=465" title="BMW 3 SERIES F30 12-15 (51 71 7 260 725)">
#         BMW 3 SERIES F30 12-15 (51 71 7 260 725)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=466" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES F30 12-15 (51 71 7 260 726)" src="/img/product/BM35014B0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=466" title="BMW 3 SERIES F30 12-15 (51 71 7 260 726)">
#         BMW 3 SERIES F30 12-15 (51 71 7 260 726)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=469" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES F30 13-17 (51 71 7 260 727)" src="/img/product/BM35014A0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=469" title="BMW 3 SERIES F30 13-17 (51 71 7 260 727)">
#         BMW 3 SERIES F30 13-17 (51 71 7 260 727)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=470" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES F30 13-17 (51 71 7 260 728)" src="/img/product/BM35014A0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=470" title="BMW 3 SERIES F30 13-17 (51 71 7 260 728)">
#         BMW 3 SERIES F30 13-17 (51 71 7 260 728)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=883" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 3 SERIES F30 12-14 (51 71 7 260 699)" src="/img/product/BM35014C1L-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=883" title="BMW 3 SERIES F30 12-14 (51 71 7 260 699)">
#         BMW 3 SERIES F30 12-14 (51 71 7 260 699)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=884" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 3 SERIES F30 09-14 (51 71 7 260 700)" src="/img/product/BM35014C1R-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=884" title="BMW 3 SERIES F30 09-14 (51 71 7 260 700)">
#         BMW 3 SERIES F30 09-14 (51 71 7 260 700)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=3336" title="FRONT LINER FENDER F.SECTION LH">
#        </a>
#        <img alt="BMW 5 SERIES E60 11-16 (51717186727)" src="/img/product/BM51014CL-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=3336" title="BMW 5 SERIES E60 11-16 (51717186727)">
#         BMW 5 SERIES E60 11-16 (51717186727)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=3337" title="FRONT LINER FENDER F.SECTION RH">
#        </a>
#        <img alt="BMW 5 SERIES E60 11-16 (51717186728)" src="/img/product/BM51014CR-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=3337" title="BMW 5 SERIES E60 11-16 (51717186728)">
#         BMW 5 SERIES E60 11-16 (51717186728)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=3340" title="FRONT LINER FENDER LH">
#        </a>
#        <img alt="BMW 5 SERIES E60 04-07 (51717033749)" src="/img/product/BM51014AL-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=3340" title="BMW 5 SERIES E60 04-07 (51717033749)">
#         BMW 5 SERIES E60 04-07 (51717033749)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=3341" title="FRONT LINER FENDER RH">
#        </a>
#        <img alt="BMW 5 SERIES E60 04-07 (51717033750)" src="/img/product/BM51014AR-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=3341" title="BMW 5 SERIES E60 04-07 (51717033750)">
#         BMW 5 SERIES E60 04-07 (51717033750)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4507" title="FRONT LINER FENDER LH (CAPA)">
#        </a>
#        <img alt="BMW 5 SERIES E60 08-10 (51717186921)" src="/img/product/BM51014DL-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4507" title="BMW 5 SERIES E60 08-10 (51717186921)">
#         BMW 5 SERIES E60 08-10 (51717186921)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4508" title="FRONT LINER FENDER RH (CAPA)">
#        </a>
#        <img alt="BMW 5 SERIES E60 08-10 (51717186922)" src="/img/product/BM51014DR-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4508" title="BMW 5 SERIES E60 08-10 (51717186922)">
#         BMW 5 SERIES E60 08-10 (51717186922)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4535" title="FRONT LINER FENDER LH  (CAPA)">
#        </a>
#        <img alt="BMW 5 SERIES E60 11-14 (68084289AG)" src="/img/product/CS33014BL-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4535" title="BMW 5 SERIES E60 11-14 (68084289AG)">
#         BMW 5 SERIES E60 11-14 (68084289AG)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4536" title="FRONT LINER FENDER RH  (CAPA)">
#        </a>
#        <img alt="BMW 5 SERIES E60 11-14 (68084288AG)" src="/img/product/CS33014BR-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4536" title="BMW 5 SERIES E60 11-14 (68084288AG)">
#         BMW 5 SERIES E60 11-14 (68084288AG)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4629" title="FRONT LINER FENDER LH (CAPA)">
#        </a>
#        <img alt="BMW X5 14-17 (51 71 7 290 853)" src="/img/product/BMX5014A0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4629" title="BMW X5 14-17 (51 71 7 290 853)">
#         BMW X5 14-17 (51 71 7 290 853)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4630" title="FRONT LINER FENDER LH (CAPA)">
#        </a>
#        <img alt="BMW X5 14-17 (51 71 7 290 854)" src="/img/product/BMX5014A0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4630" title="BMW X5 14-17 (51 71 7 290 854)">
#         BMW X5 14-17 (51 71 7 290 854)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4644" title="F.LINER FENDER FT. SECTION LH (CAPA)">
#        </a>
#        <img alt="BMW X5 11-13 (51 71 7 234 831)" src="/img/product/BMX2014A0L-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4644" title="BMW X5 11-13 (51 71 7 234 831)">
#         BMW X5 11-13 (51 71 7 234 831)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4645" title="F.LINER FENDER FT. SECTION RH (CAPA)">
#        </a>
#        <img alt="BMW X5 11-13 (51 71 7 234 832)" src="/img/product/BMX2014A0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4645" title="BMW X5 11-13 (51 71 7 234 832)">
#         BMW X5 11-13 (51 71 7 234 832)
#        </a>
#       </h3>
#      </li>
#      <li class="related">
#       <span class="related-img">
#        <a href="products-show.asp?seq=4651" title="F.LINER FENDER FT. SECTION RH (CAPA)">
#        </a>
#        <img alt="BMW X3 11-17 (51 71 7 213 642)" src="/img/product/BMX6014A0R-C-1.jpg"/>
#       </span>
#       <h3>
#        <a href="products-show.asp?seq=4651" title="BMW X3 11-17 (51 71 7 213 642)">
#         BMW X3 11-17 (51 71 7 213 642)
#        </a>
#       </h3>
#      </li>
#     </ul>
#     <div class="btn">
#      <a class="all-btn btn01" href="javascript:history.go(-1);" title="Back">
#       Back
#      </a>
#      <a class="all-btn btn02" href="inquiry.asp?seq=4650" title="Inquiry">
#       Inquiry
#      </a>
#     </div>
#    </div>
#    <div class="wrap-left">
#     <ul class="menu">
#      <li>
#       <a href="products-list.asp?title_seq=7" title="Inner Fender">
#        Inner Fender
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=3" title="Air Duct">
#        Air Duct
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=1" title="Bumper">
#        Bumper
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=4" title="Fender Flare">
#        Fender Flare
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=5" title="Fender">
#        Fender
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=6" title="Grille">
#        Grille
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=8" title="Heavy Duty Truck">
#        Heavy Duty Truck
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=9" title="Spoiler">
#        Spoiler
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=11" title="Bumper Filler">
#        Bumper Filler
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=12" title="Bumper Molding">
#        Bumper Molding
#       </a>
#      </li>
#      <li>
#       <a href="products-list.asp?title_seq=13" title="Fog Lamp Cover">
#        Fog Lamp Cover
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="clean">
#    </div>
#   </div>
#   <!--footer start-->
#   <div class="btm-box-area">
#    <div class="wrapper">
#     <div class="btm-box">
#      Fender Liner Manufacturer in Taiwan│GBC
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="footer-nav-bg">
#     <div class="wrapper">
#      <ul class="footer-nav">
#       <li>
#        <a href="/" title="Home">
#         Home
#        </a>
#       </li>
#       <li>
#        <a href="about.asp" title="About">
#         About
#        </a>
#       </li>
#       <li>
#        <a href="products.asp" title="Products">
#         Products
#        </a>
#       </li>
#       <li>
#        <a href="news.asp" title="News">
#         News
#        </a>
#       </li>
#       <li>
#        <a href="quality.asp" title="Quality">
#         Quality
#        </a>
#       </li>
#       <li>
#        <a href="contact.asp" title="Contact">
#         Contact
#        </a>
#       </li>
#       <li>
#        <a href="download.asp" title="Download">
#         Download
#        </a>
#       </li>
#       <li>
#        <a href="sitemap.asp" title="Sitemap">
#         Sitemap
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="footer">
#     <div class="wrapper">
#      <!-- <div class="footer-qr"><img src="images/qr-code.gif" alt=""></div> -->
#      <ul class="footer-link">
#       <li>
#        <a href="https://www.facebook.com/sharer.php?u=http%3A%2F%2F61.63.232.42%3A22690%2F&amp;display=popup&amp;ref=plugin&amp;src=like&amp;app_id=113869198637480" onclick="javascript:window.open(this.href,
#   '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" title="Facebook">
#         <img alt="Facebook" src="images/footer-icon01.gif"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://plus.google.com/share?url=http://61.63.232.42:22690/" onclick="javascript:window.open(this.href,
#   '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" title="Google+">
#         <img alt="Google+" src="images/footer-icon02.gif"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://twitter.com/share?url=http%3A%2F%2F61.63.232.42%3A22690%2F&amp;  via=twitterdev&amp;
# 				related=twitterapi%2Ctwitter&amp;
# 				hashtags=example%2Cdemo&amp;
# 				text=custom%20share%20text" onclick="javascript:window.open(this.href,
#   '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" title="Twitter">
#         <img alt="Twitter" src="images/footer-icon03.gif"/>
#        </a>
#       </li>
#       <!-- <li><a href="#" title="Youtube" target="_blank"><img src="images/footer-icon04.gif" alt="Youtube"></a></li> -->
#      </ul>
#      <div class="footer-info">
#       <div class="footer-logo">
#        <a class="flogo-img" href="/" title="GREAT BESTCAM CO., LTD.">
#         <img alt="GREAT BESTCAM CO., LTD." src="images/logo.svg"/>
#        </a>
#        <a class="fcom-name" href="/" title="GREAT BESTCAM CO., LTD.">
#         GREAT BESTCAM CO., LTD.
#        </a>
#       </div>
#       <div class="footer-info-list">
#        <li>
#         <span class="footer-info-title">
#          TEL :
#         </span>
#         +886-3-9909996
#        </li>
#        <li>
#         <span class="footer-info-title">
#          FAX :
#         </span>
#         +886-3-9907915
#        </li>
#        <li>
#         <span class="footer-info-title">
#          MAIL :
#         </span>
#         <a href="contact.asp" title="Email">
#          gb427@gbcmotor.com.tw
#         </a>
#        </li>
#        <br/>
#        <li>
#         <span class="footer-info-title">
#          ADD :
#         </span>
#         <address>
#          NO.63,Ligong 2nd Rd.,Wujie Township,Yilan County 26841,Taiwan
#         </address>
#        </li>
#       </div>
#      </div>
#      <div class="clean">
#      </div>
#     </div>
#    </div>
#    <div class="copyright-area">
#     <div class="wrapper">
#      <div class="ezlook">
#       <a href="https://www.webdesigns.com.tw/" target="_blank" title="專業網頁設計 webdesigns co. ltd">
#        Design
#       </a>
#       by
#       <a href="https://www.ezlook.com.tw/" target="_blank" title="Ezlook">
#        Ezlook
#       </a>
#       .
#      </div>
#      Copyright©2017 GREAT BESTCAM CO., LTD. All rights reserved.
#     </div>
#    </div>
#   </footer>
#   <!--選單 js-->
#   <script language="javascript">
#    function p_chg() {
# 		$.ajax({
# 			url: 'brand_chk.asp',
# 			type: 'GET',
# 			data: {
# 				seq: $('#Products').val()
# 			},
# 			error: function (xhr) {
# 				alert('Ajax request 發生錯誤');
# 			},
# 			success: function (response) {
# 				//alert(response);
# 				$('#Brand').html(response);
# 				//$('#msg_user_name').fadeIn();
#
# 			}
# 		});
# 	}
#
# 	function b_chg() {
# 		$.ajax({
# 			url: 'model_chk.asp',
# 			type: 'GET',
# 			data: {
# 				seq: $('#Brand').val(),
# 				t_seq: $('#Products').val()
# 			},
# 			error: function (xhr) {
# 				alert('Ajax request 發生錯誤');
# 			},
# 			success: function (response) {
# 				//alert(response);
# 				$('#Model').html(response);
# 				//$('#msg_user_name').fadeIn();
#
# 			}
# 		});
# 	}
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-80043522-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-80043522-1');
#   </script>
#   <!--footer //-->
#  </body>
# </html>

# %%
title = html.xpath('//h3[@class="title01"]/text()')[0].strip()

title
# Out:
# 'BMW\xa0X3\xa011-17\xa0(51 71 7 213 641)'

# %%
src = 'http://www.fenderliner.com' + html.xpath('//div[@class="b-img"]/img/@src')[0].strip()

src
# Out:
# 'http://www.fenderliner.com/img/product/BMX6014A0L-C-1.jpg'

# %%
list_ul = html.xpath('//ul[@class="show-info-list"]/li')

list_ul
# Out:
# [<Element li at 0x1156ab400>,
#  <Element li at 0x1156ab680>,
#  <Element li at 0x1156fad80>,
#  <Element li at 0x1156f80c0>,
#  <Element li at 0x1156f8140>,
#  <Element li at 0x1156f8080>,
#  <Element li at 0x1156f8100>,
#  <Element li at 0x1156f8280>]

# %%
list_h4 = html.xpath('//h4[@class="title03"]')
for h4 in list_h4:
    if h4.xpath('./text()')[0].strip() == 'Description':
        list_li = h4.xpath('./following-sibling::div[@class="edit"]')[0].xpath('./ul[@class="about-list"]/li/text()')

list_li
# Out:
# ['PARTS MODEL: BMW X3 F25 /X4 F26',
#  'PARTS DESCRIPTION: F.LINER FENDER FT. SECTION LH (CAPA)',
#  'YEAR: 2011,2012,2013,2014,2015,2016,2017',
#  'OE/AM MATERIAL: PP/PP',
#  'OE WEIGHT: 1.08(KG)',
#  'AM WEIGHT: 0.86(KG)',
#  'OE THICKNESS: 1.85(mm)',
#  'AM THICKNESS: 1.95(mm)',
#  'OE IZOD IMPACT TEST: 16.2(J)',
#  'AM IZOD IMPACT TEST: 17.34(J)',
#  'ALSO NAME: FR FENDER LINER / FR FENDER LINER ASSEMBLY/ FR INNER FENDER / FR WATER SPLASH SHIELD/ FR INNER FENDER WELL']

# %%
df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'No.']),
                         'Title': title,
                         'Picture': '',
                         'Url': input_.loc[a, 'Url'],
                         'Src': src}])

for ul in list_ul:
    if len(ul.xpath('./@style')) != 0:
        continue
    
    name = ul.xpath('./span/text()')[0].strip()[:-1].strip()
    if name == 'Certifed by':
        df_temp.loc[0, name.upper()] = '' if len(ul.xpath('./img')) == 0 else ';'.join([_.strip() for _ in ul.xpath('./img/@alt')])
    else:
        df_temp.loc[0, name.upper()] = '' if len(ul.xpath('./text()')) == 0 else ul.xpath('./text()')[0].strip()

for li in list_li:
    df_temp.loc[0, li.split(':')[0].strip().lower()] = ' : '.join(_.strip() for _ in li.split(':')[1:])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'No.': int(input_.loc[a, 'No.']),
                             'Url': input_.loc[a, 'Url']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#    序号                           Title Pic  \
# 0  45  BMW X3 11-17 (51 71 7 213 641)
#
#                                                  Url  \
# 0  http://www.fenderliner.com/products-show.asp?s...
#
#                                                  Src BRAND MODEL   YEAR  \
# 0  http://www.fenderliner.com/img/product/BMX6014...   BMW    X3  11-17
#
#                OE# PARTSLINK NO.  ...                     parts description  \
# 0  51 71 7 213 641                ...  F.LINER FENDER FT. SECTION LH (CAPA)
#
#                                  year oe/am material oe weight am weight  \
# 0  2011,2012,2013,2014,2015,2016,2017          PP/PP  1.08(KG)  0.86(KG)
#
#   oe thickness am thickness oe izod impact test am izod impact test  \
# 0     1.85(mm)     1.95(mm)             16.2(J)            17.34(J)
#
#                                            also name
# 0  FR FENDER LINER / FR FENDER LINER ASSEMBLY/ FR...
#
# [1 rows x 23 columns]

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
