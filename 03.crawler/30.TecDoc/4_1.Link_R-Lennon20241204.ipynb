# %%
import platform
import os

system = platform.system().lower().strip()
if system in ['darwin', 'windows']:
    path_root = '.'
elif system == 'linux':
    from google.colab import drive
    drive.mount('/content/drive')

    path_root = './drive/MyDrive/code/03.crawler/30.TecDoc'
else:
    print('fuck')

path_root
# Out:
# '.'

# %%
import pandas as pd

# = = =  = = =  = = =

import requests
import json

import sys
sys.path.append(os.path.join(path_root, '../00.Tools'))
from crawler_configuration_oversea import get_header, get_proxy

import time

# %%
with open('./api.txt', 'r') as api_txt:
    api = api_txt.read()

api
# Out:
# '2BeBXg6KgXfwZr8i2P2L7H5W6ujr4XXcyxXsJQb34CwMS3Nb2Hk8'

# %%
directory_in = os.path.join(path_root, './file/3.make')
list_file = [file for file in sorted(list(os.walk(directory_in))[0][2]) if file not in ['.DS_Store'] and os.path.isfile(os.path.join(directory_in, file))]
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
print('Data Loading...')
list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(os.path.join(directory_in, file),
                                                                       header=0,
                                                                       dtype=str).fillna('')
print('Loading Done !')
print()

df_input['Part Code'] = df_input['Part Code'].astype(int)
df_input['Make No'] = df_input['Make No'].astype(int)
df_input['Make Code'] = df_input['Make Code'].astype(int)

crawler_remain = len(df_input)

print(f'总数量：{crawler_remain}')
print()

df_input
# Out:
# Data Loading...
# Loading Done !
#
# 总数量：1443
#        Part Code  Make No      Make  Make Code        JOIN_PCMC  \
# 0      127680953        1       BMW         16     127680953;16
# 1      127680979        1       BMW         16     127680979;16
# 2      127680982        1      MINI       1523   127680982;1523
# 3      127680984        1       BMW         16     127680984;16
# 4      127680985        1  CHRYSLER         20     127680985;20
# ...          ...      ...       ...        ...              ...
# 1438  1521756049        2     DACIA        139   1521756049;139
# 1439  1521756049        3     SMART       1138  1521756049;1138
# 1440  1521756651        1    TOYOTA        111   1521756651;111
# 1441  1521756743        1        VW        121   1521756743;121
# 1442  1521756754        1        VW        121   1521756754;121
#
#                                               Check_Url
# 0     https://web.tecalliance.net/tecdoc/qa/parts/45...
# 1     https://web.tecalliance.net/tecdoc/qa/parts/45...
# 2     https://web.tecalliance.net/tecdoc/qa/parts/45...
# 3     https://web.tecalliance.net/tecdoc/qa/parts/45...
# 4     https://web.tecalliance.net/tecdoc/qa/parts/45...
# ...                                                 ...
# 1438  https://web.tecalliance.net/tecdoc/qa/parts/45...
# 1439  https://web.tecalliance.net/tecdoc/qa/parts/45...
# 1440  https://web.tecalliance.net/tecdoc/qa/parts/45...
# 1441  https://web.tecalliance.net/tecdoc/qa/parts/45...
# 1442  https://web.tecalliance.net/tecdoc/qa/parts/45...
#
# [1443 rows x 6 columns]

# %%
crawler_status, (crawler_index, crawler_series) = False, next(df_input.iterrows())

crawler_status, crawler_index, crawler_series
# Out:
# (False,
#  0,
#  Part Code                                            127680953
#  Make No                                                      1
#  Make                                                       BMW
#  Make Code                                                   16
#  JOIN_PCMC                                         127680953;16
#  Check_Url    https://web.tecalliance.net/tecdoc/qa/parts/45...
#  Name: 0, dtype: object)

# %%
data = {'getArticleLinkedAllLinkingTarget4': {'articleCountry': 'DE',
                                              'articleId': crawler_series['Part Code'],
                                              'country': 'DE',
                                              'countryGroupFlag': False,
                                              'lang': 'qa',
                                              'linkingTargetManuId': crawler_series['Make Code'],
                                              'linkingTargetType': 'VOLB',
                                              'provider': 23365,
                                              'withMainArticles': False}}

crawler_retry = 0
while True:
    crawler_retry += 1
    print(crawler_retry)
    try:
        url_check = crawler_series['Check_Url']

        resp = requests.post('https://webservice.tecalliance.services/pegasus-3-0/services/TecdocToCatDLB.jsonEndpoint',
                             data=json.dumps(data),
                             headers=get_header(**{'X-Api-Key': api}),
                             proxies=get_proxy(),
                             timeout=(5, 15))

        if resp.status_code == 200:
            dict_ = resp.json()

            if dict_['status'] == 200:
                break
            elif dict_['status'] == 401 and dict_['statusText'].strip() == 'Access not allowed':
                print(f'fuck api {api}')
                time.sleep(3)
                with open('./api.txt', 'r') as api_txt:
                    api = api_txt.read()
    except requests.exceptions.ProxyError as e:
        if '456 CN Client Forbidden' in str(e):
            print('Long live the People\'s Republic of China!')
            break
    except KeyboardInterrupt:
        break
    except:
        time.sleep(3)
        continue

dict_
# Out:
# 1
# {'data': {'array': [{'articleLinkages': {'array': [{'articleLinkId': 127680954,
#        'linked': True,
#        'linkingTargetId': 40,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680955,
#        'linked': True,
#        'linkingTargetId': 41,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680956,
#        'linked': True,
#        'linkingTargetId': 43,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680957,
#        'linked': True,
#        'linkingTargetId': 48,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680958,
#        'linked': True,
#        'linkingTargetId': 54,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681086,
#        'linked': True,
#        'linkingTargetId': 4628,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680960,
#        'linked': True,
#        'linkingTargetId': 59,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680962,
#        'linked': True,
#        'linkingTargetId': 62,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680963,
#        'linked': True,
#        'linkingTargetId': 63,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680959,
#        'linked': True,
#        'linkingTargetId': 55,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681195,
#        'linked': True,
#        'linkingTargetId': 5099,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680961,
#        'linked': True,
#        'linkingTargetId': 61,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680977,
#        'linked': True,
#        'linkingTargetId': 302,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681194,
#        'linked': True,
#        'linkingTargetId': 5095,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680978,
#        'linked': True,
#        'linkingTargetId': 303,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681336,
#        'linked': True,
#        'linkingTargetId': 8784,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680981,
#        'linked': True,
#        'linkingTargetId': 4623,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681256,
#        'linked': True,
#        'linkingTargetId': 5100,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680995,
#        'linked': True,
#        'linkingTargetId': 4626,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680965,
#        'linked': True,
#        'linkingTargetId': 229,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680966,
#        'linked': True,
#        'linkingTargetId': 230,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680967,
#        'linked': True,
#        'linkingTargetId': 231,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680964,
#        'linked': True,
#        'linkingTargetId': 227,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680968,
#        'linked': True,
#        'linkingTargetId': 238,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680970,
#        'linked': True,
#        'linkingTargetId': 241,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680971,
#        'linked': True,
#        'linkingTargetId': 242,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680969,
#        'linked': True,
#        'linkingTargetId': 239,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681257,
#        'linked': True,
#        'linkingTargetId': 7069,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680972,
#        'linked': True,
#        'linkingTargetId': 243,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680973,
#        'linked': True,
#        'linkingTargetId': 251,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680974,
#        'linked': True,
#        'linkingTargetId': 252,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680975,
#        'linked': True,
#        'linkingTargetId': 253,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681087,
#        'linked': True,
#        'linkingTargetId': 4633,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127680976,
#        'linked': True,
#        'linkingTargetId': 254,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 518197106,
#        'linked': True,
#        'linkingTargetId': 5052,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681193,
#        'linked': True,
#        'linkingTargetId': 5093,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681335,
#        'linked': True,
#        'linkingTargetId': 8526,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681258,
#        'linked': True,
#        'linkingTargetId': 7745,
#        'linkingTargetType': 'P'},
#       {'articleLinkId': 127681259,
#        'linked': True,
#        'linkingTargetId': 7747,
#        'linkingTargetType': 'P'}]}}]},
#  'status': 200}

# %%
list_dict_link = dict_['data']['array'][0]['articleLinkages']['array']

list_dict_link
# Out:
# [{'articleLinkId': 127680954,
#   'linked': True,
#   'linkingTargetId': 40,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680955,
#   'linked': True,
#   'linkingTargetId': 41,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680956,
#   'linked': True,
#   'linkingTargetId': 43,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680957,
#   'linked': True,
#   'linkingTargetId': 48,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680958,
#   'linked': True,
#   'linkingTargetId': 54,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681086,
#   'linked': True,
#   'linkingTargetId': 4628,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680960,
#   'linked': True,
#   'linkingTargetId': 59,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680962,
#   'linked': True,
#   'linkingTargetId': 62,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680963,
#   'linked': True,
#   'linkingTargetId': 63,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680959,
#   'linked': True,
#   'linkingTargetId': 55,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681195,
#   'linked': True,
#   'linkingTargetId': 5099,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680961,
#   'linked': True,
#   'linkingTargetId': 61,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680977,
#   'linked': True,
#   'linkingTargetId': 302,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681194,
#   'linked': True,
#   'linkingTargetId': 5095,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680978,
#   'linked': True,
#   'linkingTargetId': 303,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681336,
#   'linked': True,
#   'linkingTargetId': 8784,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680981,
#   'linked': True,
#   'linkingTargetId': 4623,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681256,
#   'linked': True,
#   'linkingTargetId': 5100,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680995,
#   'linked': True,
#   'linkingTargetId': 4626,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680965,
#   'linked': True,
#   'linkingTargetId': 229,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680966,
#   'linked': True,
#   'linkingTargetId': 230,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680967,
#   'linked': True,
#   'linkingTargetId': 231,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680964,
#   'linked': True,
#   'linkingTargetId': 227,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680968,
#   'linked': True,
#   'linkingTargetId': 238,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680970,
#   'linked': True,
#   'linkingTargetId': 241,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680971,
#   'linked': True,
#   'linkingTargetId': 242,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680969,
#   'linked': True,
#   'linkingTargetId': 239,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681257,
#   'linked': True,
#   'linkingTargetId': 7069,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680972,
#   'linked': True,
#   'linkingTargetId': 243,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680973,
#   'linked': True,
#   'linkingTargetId': 251,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680974,
#   'linked': True,
#   'linkingTargetId': 252,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680975,
#   'linked': True,
#   'linkingTargetId': 253,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681087,
#   'linked': True,
#   'linkingTargetId': 4633,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680976,
#   'linked': True,
#   'linkingTargetId': 254,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 518197106,
#   'linked': True,
#   'linkingTargetId': 5052,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681193,
#   'linked': True,
#   'linkingTargetId': 5093,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681335,
#   'linked': True,
#   'linkingTargetId': 8526,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681258,
#   'linked': True,
#   'linkingTargetId': 7745,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681259,
#   'linked': True,
#   'linkingTargetId': 7747,
#   'linkingTargetType': 'P'}]

# %%
list_dict_link
# Out:
# [{'articleLinkId': 127680954,
#   'linked': True,
#   'linkingTargetId': 40,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680955,
#   'linked': True,
#   'linkingTargetId': 41,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680956,
#   'linked': True,
#   'linkingTargetId': 43,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680957,
#   'linked': True,
#   'linkingTargetId': 48,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680958,
#   'linked': True,
#   'linkingTargetId': 54,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681086,
#   'linked': True,
#   'linkingTargetId': 4628,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680960,
#   'linked': True,
#   'linkingTargetId': 59,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680962,
#   'linked': True,
#   'linkingTargetId': 62,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680963,
#   'linked': True,
#   'linkingTargetId': 63,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680959,
#   'linked': True,
#   'linkingTargetId': 55,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681195,
#   'linked': True,
#   'linkingTargetId': 5099,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680961,
#   'linked': True,
#   'linkingTargetId': 61,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680977,
#   'linked': True,
#   'linkingTargetId': 302,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681194,
#   'linked': True,
#   'linkingTargetId': 5095,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680978,
#   'linked': True,
#   'linkingTargetId': 303,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681336,
#   'linked': True,
#   'linkingTargetId': 8784,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680981,
#   'linked': True,
#   'linkingTargetId': 4623,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681256,
#   'linked': True,
#   'linkingTargetId': 5100,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680995,
#   'linked': True,
#   'linkingTargetId': 4626,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680965,
#   'linked': True,
#   'linkingTargetId': 229,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680966,
#   'linked': True,
#   'linkingTargetId': 230,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680967,
#   'linked': True,
#   'linkingTargetId': 231,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680964,
#   'linked': True,
#   'linkingTargetId': 227,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680968,
#   'linked': True,
#   'linkingTargetId': 238,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680970,
#   'linked': True,
#   'linkingTargetId': 241,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680971,
#   'linked': True,
#   'linkingTargetId': 242,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680969,
#   'linked': True,
#   'linkingTargetId': 239,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681257,
#   'linked': True,
#   'linkingTargetId': 7069,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680972,
#   'linked': True,
#   'linkingTargetId': 243,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680973,
#   'linked': True,
#   'linkingTargetId': 251,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680974,
#   'linked': True,
#   'linkingTargetId': 252,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680975,
#   'linked': True,
#   'linkingTargetId': 253,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681087,
#   'linked': True,
#   'linkingTargetId': 4633,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127680976,
#   'linked': True,
#   'linkingTargetId': 254,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 518197106,
#   'linked': True,
#   'linkingTargetId': 5052,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681193,
#   'linked': True,
#   'linkingTargetId': 5093,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681335,
#   'linked': True,
#   'linkingTargetId': 8526,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681258,
#   'linked': True,
#   'linkingTargetId': 7745,
#   'linkingTargetType': 'P'},
#  {'articleLinkId': 127681259,
#   'linked': True,
#   'linkingTargetId': 7747,
#   'linkingTargetType': 'P'}]

# %%
list_dict_link_2, index_begin, index_end = [], 0, 25
while True:
    dict_link_2 = {'array': []}
    if index_end < len(list_dict_link):
        for dict_link in list_dict_link[index_begin:index_end]:
            dict_link_2['array'].append({'articleLinkId': dict_link['articleLinkId'], 'linkingTargetId': dict_link['linkingTargetId']})
        list_dict_link_2.append(dict_link_2)
        index_begin, index_end = index_end, index_end + 25
    else:
        for dict_link in list_dict_link[index_begin:]:
            dict_link_2['array'].append({'articleLinkId': dict_link['articleLinkId'], 'linkingTargetId': dict_link['linkingTargetId']})
        list_dict_link_2.append(dict_link_2)
        break

list_dict_link_2
# Out:
# [{'array': [{'articleLinkId': 127680954, 'linkingTargetId': 40},
#    {'articleLinkId': 127680955, 'linkingTargetId': 41},
#    {'articleLinkId': 127680956, 'linkingTargetId': 43},
#    {'articleLinkId': 127680957, 'linkingTargetId': 48},
#    {'articleLinkId': 127680958, 'linkingTargetId': 54},
#    {'articleLinkId': 127681086, 'linkingTargetId': 4628},
#    {'articleLinkId': 127680960, 'linkingTargetId': 59},
#    {'articleLinkId': 127680962, 'linkingTargetId': 62},
#    {'articleLinkId': 127680963, 'linkingTargetId': 63},
#    {'articleLinkId': 127680959, 'linkingTargetId': 55},
#    {'articleLinkId': 127681195, 'linkingTargetId': 5099},
#    {'articleLinkId': 127680961, 'linkingTargetId': 61},
#    {'articleLinkId': 127680977, 'linkingTargetId': 302},
#    {'articleLinkId': 127681194, 'linkingTargetId': 5095},
#    {'articleLinkId': 127680978, 'linkingTargetId': 303},
#    {'articleLinkId': 127681336, 'linkingTargetId': 8784},
#    {'articleLinkId': 127680981, 'linkingTargetId': 4623},
#    {'articleLinkId': 127681256, 'linkingTargetId': 5100},
#    {'articleLinkId': 127680995, 'linkingTargetId': 4626},
#    {'articleLinkId': 127680965, 'linkingTargetId': 229},
#    {'articleLinkId': 127680966, 'linkingTargetId': 230},
#    {'articleLinkId': 127680967, 'linkingTargetId': 231},
#    {'articleLinkId': 127680964, 'linkingTargetId': 227},
#    {'articleLinkId': 127680968, 'linkingTargetId': 238},
#    {'articleLinkId': 127680970, 'linkingTargetId': 241}]},
#  {'array': [{'articleLinkId': 127680971, 'linkingTargetId': 242},
#    {'articleLinkId': 127680969, 'linkingTargetId': 239},
#    {'articleLinkId': 127681257, 'linkingTargetId': 7069},
#    {'articleLinkId': 127680972, 'linkingTargetId': 243},
#    {'articleLinkId': 127680973, 'linkingTargetId': 251},
#    {'articleLinkId': 127680974, 'linkingTargetId': 252},
#    {'articleLinkId': 127680975, 'linkingTargetId': 253},
#    {'articleLinkId': 127681087, 'linkingTargetId': 4633},
#    {'articleLinkId': 127680976, 'linkingTargetId': 254},
#    {'articleLinkId': 518197106, 'linkingTargetId': 5052},
#    {'articleLinkId': 127681193, 'linkingTargetId': 5093},
#    {'articleLinkId': 127681335, 'linkingTargetId': 8526},
#    {'articleLinkId': 127681258, 'linkingTargetId': 7745},
#    {'articleLinkId': 127681259, 'linkingTargetId': 7747}]}]

# %%
list_dict_correct.extend([{'Part Code': crawler_series['Part Code'],
                           'Make No': crawler_series['Make No'],
                           'Make': crawler_series['Make'],
                           'Make Code': crawler_series['Make Code'],
                           'JOIN_PCMC': crawler_series['JOIN_PCMC'],
                           'Link No': i + 1,
                           'Json_Link': json.dumps(dict_link_2),
                           'JOIN_PCMCLN': f'''{crawler_series['JOIN_PCMC']};{i + 1}''',
                           'Check_Url': crawler_series['Check_Url']} for i, dict_link_2 in enumerate(list_dict_link_2)])

list_dict_correct
# Out:
# [{'Part Code': 127680953,
#   'Make No': 1,
#   'Make': 'BMW',
#   'Make Code': 16,
#   'JOIN_PCMC': '127680953;16',
#   'Link No': 1,
#   'Json_Link': '{"array": [{"articleLinkId": 127680954, "linkingTargetId": 40}, {"articleLinkId": 127680955, "linkingTargetId": 41}, {"articleLinkId": 127680956, "linkingTargetId": 43}, {"articleLinkId": 127680957, "linkingTargetId": 48}, {"articleLinkId": 127680958, "linkingTargetId": 54}, {"articleLinkId": 127681086, "linkingTargetId": 4628}, {"articleLinkId": 127680960, "linkingTargetId": 59}, {"articleLinkId": 127680962, "linkingTargetId": 62}, {"articleLinkId": 127680963, "linkingTargetId": 63}, {"articleLinkId": 127680959, "linkingTargetId": 55}, {"articleLinkId": 127681195, "linkingTargetId": 5099}, {"articleLinkId": 127680961, "linkingTargetId": 61}, {"articleLinkId": 127680977, "linkingTargetId": 302}, {"articleLinkId": 127681194, "linkingTargetId": 5095}, {"articleLinkId": 127680978, "linkingTargetId": 303}, {"articleLinkId": 127681336, "linkingTargetId": 8784}, {"articleLinkId": 127680981, "linkingTargetId": 4623}, {"articleLinkId": 127681256, "linkingTargetId": 5100}, {"articleLinkId": 127680995, "linkingTargetId": 4626}, {"articleLinkId": 127680965, "linkingTargetId": 229}, {"articleLinkId": 127680966, "linkingTargetId": 230}, {"articleLinkId": 127680967, "linkingTargetId": 231}, {"articleLinkId": 127680964, "linkingTargetId": 227}, {"articleLinkId": 127680968, "linkingTargetId": 238}, {"articleLinkId": 127680970, "linkingTargetId": 241}]}',
#   'JOIN_PCMCLN': '127680953;16;1'},
#  {'Part Code': 127680953,
#   'Make No': 1,
#   'Make': 'BMW',
#   'Make Code': 16,
#   'JOIN_PCMC': '127680953;16',
#   'Link No': 2,
#   'Json_Link': '{"array": [{"articleLinkId": 127680971, "linkingTargetId": 242}, {"articleLinkId": 127680969, "linkingTargetId": 239}, {"articleLinkId": 127681257, "linkingTargetId": 7069}, {"articleLinkId": 127680972, "linkingTargetId": 243}, {"articleLinkId": 127680973, "linkingTargetId": 251}, {"articleLinkId": 127680974, "linkingTargetId": 252}, {"articleLinkId": 127680975, "linkingTargetId": 253}, {"articleLinkId": 127681087, "linkingTargetId": 4633}, {"articleLinkId": 127680976, "linkingTargetId": 254}, {"articleLinkId": 518197106, "linkingTargetId": 5052}, {"articleLinkId": 127681193, "linkingTargetId": 5093}, {"articleLinkId": 127681335, "linkingTargetId": 8526}, {"articleLinkId": 127681258, "linkingTargetId": 7745}, {"articleLinkId": 127681259, "linkingTargetId": 7747}]}',
#   'JOIN_PCMCLN': '127680953;16;2'}]

# %%
crawler_status = True

crawler_status
# Out:
# True

# %%
crawler_series['Check_Url'] = url_check

list_series_error.append(crawler_series)

list_series_error
# Out:
# [Part Code                                            127680953
#  Make No                                                      1
#  Make                                                       BMW
#  Make Code                                                   16
#  JOIN_PCMC                                         127680953;16
#  Check_Url    https://web.tecalliance.net/tecdoc/qa/parts/45...
#  Name: 0, dtype: object]

# %%
print('Data Outputting...')
if list_dict_correct:
    df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['Part Code', 'Make No', 'Link No'],
                                                             ascending=[True, True, True],
                                                             ignore_index=True)
    df_correct.to_excel(os.path.join(path_root, './test_link.xlsx'), index=False)

df_correct if list_dict_correct else ''
# Out:
# Data Outputting...
#    Part Code  Make No Make  Make Code     JOIN_PCMC  Link No  \
# 0  127680953        1  BMW         16  127680953;16        1
# 1  127680953        1  BMW         16  127680953;16        2
#
#                                            Json_Link     JOIN_PCMCLN
# 0  {"array": [{"articleLinkId": 127680954, "linki...  127680953;16;1
# 1  {"array": [{"articleLinkId": 127680971, "linki...  127680953;16;2

# %%
print('Output Finished !')
print()
# Out:
# Output Finished !

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['Part Code', 'Make No'],
                                                           ascending=[True, True],
                                                           ignore_index=True)
    df_error.to_excel(os.path.join(path_root, './test_link_error.xlsx'), index=False)
    print('- Error Occurred -')
    print()

df_error if list_series_error else ''
# Out:
# - Error Occurred -
#    Part Code  Make No Make  Make Code     JOIN_PCMC  \
# 0  127680953        1  BMW         16  127680953;16
#
#                                            Check_Url
# 0  https://web.tecalliance.net/tecdoc/qa/parts/45...
