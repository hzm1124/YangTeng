# %%
from urllib.parse import urlsplit

# %%
tuple_ = urlsplit('https://www.standardbrand.com/en/ecatalog?part=Clutch%20Starter%20Safety%20Switch&type=p')

tuple_
# Out:
# SplitResult(scheme='https', netloc='www.standardbrand.com', path='/en/ecatalog', query='part=Clutch%20Starter%20Safety%20Switch&type=p', fragment='')

# %%
from urllib.parse import parse_qs

# %%
dict_query = {key: value[0] for key, value in parse_qs(tuple_.query).items()}

dict_query
# Out:
# {'part': 'Clutch Starter Safety Switch', 'type': 'p'}

# %%
dict_query_2 = {'filter': dict_query['part'],
                'filterType': dict_query.get('search', 'n'),
                'searchType': dict_query.get('type', 'null'),
                'start': 0,
                'limit': 96,
                'sort': 3,
                'catFilter': '-All-',
                'attrValueFilter': '-All-'}

dict_query_2
# Out:
# {'filter': 'Clutch Starter Safety Switch',
#  'filterType': 'n',
#  'searchType': 'p',
#  'start': 0,
#  'limit': 96,
#  'sort': 3,
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
from urllib.parse import urlunsplit
from urllib.parse import urlencode

# %%
url = urlunsplit((tuple_.scheme, tuple_.netloc, tuple_.path, urlencode(dict_query), tuple_.fragment))

url
# Out:
# 'https://www.standardbrand.com/en/ecatalog?part=Clutch+Starter+Safety+Switch&type=p'

# %%
url_2 = urlunsplit(('https', 'ecatalog.smpcorp.com', '/V2/STD/api/part/partsearch', urlencode(dict_query_2), ''))

url_2
# Out:
# 'https://ecatalog.smpcorp.com/V2/STD/api/part/partsearch?filter=Clutch+Starter+Safety+Switch&filterType=n&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'

# %%
dict_ = {'home': url,
         'url_2': url_2}

dict_
# Out:
# {'home': 'https://www.standardbrand.com/en/ecatalog?part=Clutch+Starter+Safety+Switch&type=p',
#  'url_2': 'https://ecatalog.smpcorp.com/V2/STD/api/part/partsearch?filter=Clutch+Starter+Safety+Switch&filterType=n&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(dict_['url_2'],
                        headers=generate_header(),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
list_dict_2 = response.json()

list_dict_2
# Out:
# [{'rowId': 1,
#   'site': 'STD',
#   'webBase': 'CCR3',
#   'brand': 'STI',
#   'basePart': 'CCR-3',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 2,
#   'site': 'STD',
#   'webBase': 'CCR6',
#   'brand': 'STI',
#   'basePart': 'CCR-6',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 3,
#   'site': 'STD',
#   'webBase': 'CCR7',
#   'brand': 'STD',
#   'basePart': 'CCR-7',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 4,
#   'site': 'STD',
#   'webBase': 'DS2282',
#   'brand': 'STI',
#   'basePart': 'DS-2282',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 5,
#   'site': 'STD',
#   'webBase': 'LS312',
#   'brand': 'STI',
#   'basePart': 'LS-312',
#   'partDesc_en': 'Back-Up Light Switch',
#   'partLongDesc_en': 'Back-Up Light Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 6,
#   'site': 'STD',
#   'webBase': 'NS35',
#   'brand': 'STD',
#   'basePart': 'NS-35',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 7,
#   'site': 'STD',
#   'webBase': 'NS56',
#   'brand': 'STI',
#   'basePart': 'NS-56',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 8,
#   'site': 'STD',
#   'webBase': 'NS63',
#   'brand': 'STD',
#   'basePart': 'NS-63',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 9,
#   'site': 'STD',
#   'webBase': 'NS68',
#   'brand': 'STD',
#   'basePart': 'NS-68',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 10,
#   'site': 'STD',
#   'webBase': 'NS69',
#   'brand': 'STI',
#   'basePart': 'NS-69',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 11,
#   'site': 'STD',
#   'webBase': 'NS73',
#   'brand': 'STD',
#   'basePart': 'NS-73',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 12,
#   'site': 'STD',
#   'webBase': 'NS79',
#   'brand': 'STD',
#   'basePart': 'NS-79',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 13,
#   'site': 'STD',
#   'webBase': 'NS88',
#   'brand': 'STD',
#   'basePart': 'NS-88',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 14,
#   'site': 'STD',
#   'webBase': 'NS114',
#   'brand': 'STD',
#   'basePart': 'NS-114',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 15,
#   'site': 'STD',
#   'webBase': 'NS119',
#   'brand': 'STD',
#   'basePart': 'NS-119',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 16,
#   'site': 'STD',
#   'webBase': 'NS120',
#   'brand': 'STD',
#   'basePart': 'NS-120',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 17,
#   'site': 'STD',
#   'webBase': 'NS121',
#   'brand': 'STD',
#   'basePart': 'NS-121',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 18,
#   'site': 'STD',
#   'webBase': 'NS127',
#   'brand': 'STD',
#   'basePart': 'NS-127',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'A',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 19,
#   'site': 'STD',
#   'webBase': 'NS127',
#   'brand': 'TTR',
#   'basePart': 'NS127T',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'A',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 20,
#   'site': 'STD',
#   'webBase': 'NS131',
#   'brand': 'STD',
#   'basePart': 'NS-131',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 21,
#   'site': 'STD',
#   'webBase': 'NS146',
#   'brand': 'STD',
#   'basePart': 'NS-146',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 22,
#   'site': 'STD',
#   'webBase': 'NS147',
#   'brand': 'STD',
#   'basePart': 'NS-147',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 23,
#   'site': 'STD',
#   'webBase': 'NS148',
#   'brand': 'STI',
#   'basePart': 'NS-148',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 24,
#   'site': 'STD',
#   'webBase': 'NS149',
#   'brand': 'STI',
#   'basePart': 'NS-149',
#   'partDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 25,
#   'site': 'STD',
#   'webBase': 'NS149',
#   'brand': 'TTR',
#   'basePart': 'NS149T',
#   'partDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 26,
#   'site': 'STD',
#   'webBase': 'NS151',
#   'brand': 'STI',
#   'basePart': 'NS-151',
#   'partDesc_en': 'Cruise Control Release Switch',
#   'partLongDesc_en': 'Cruise Control Release Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 27,
#   'site': 'STD',
#   'webBase': 'NS153',
#   'brand': 'STI',
#   'basePart': 'NS-153',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 28,
#   'site': 'STD',
#   'webBase': 'NS157',
#   'brand': 'STI',
#   'basePart': 'NS-157',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 29,
#   'site': 'STD',
#   'webBase': 'NS188',
#   'brand': 'STI',
#   'basePart': 'NS-188',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 30,
#   'site': 'STD',
#   'webBase': 'NS193',
#   'brand': 'STD',
#   'basePart': 'NS-193',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 31,
#   'site': 'STD',
#   'webBase': 'NS205',
#   'brand': 'STD',
#   'basePart': 'NS-205',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 32,
#   'site': 'STD',
#   'webBase': 'NS225',
#   'brand': 'STI',
#   'basePart': 'NS-225',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 33,
#   'site': 'STD',
#   'webBase': 'NS225',
#   'brand': 'TTR',
#   'basePart': 'NS225T',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 34,
#   'site': 'STD',
#   'webBase': 'NS228',
#   'brand': 'STD',
#   'basePart': 'NS-228',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 35,
#   'site': 'STD',
#   'webBase': 'NS233',
#   'brand': 'STI',
#   'basePart': 'NS-233',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 36,
#   'site': 'STD',
#   'webBase': 'NS235',
#   'brand': 'STD',
#   'basePart': 'NS-235',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 37,
#   'site': 'STD',
#   'webBase': 'NS236',
#   'brand': 'STI',
#   'basePart': 'NS-236',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 38,
#   'site': 'STD',
#   'webBase': 'NS238',
#   'brand': 'STI',
#   'basePart': 'NS-238',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 39,
#   'site': 'STD',
#   'webBase': 'NS251',
#   'brand': 'STI',
#   'basePart': 'NS-251',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 40,
#   'site': 'STD',
#   'webBase': 'NS252',
#   'brand': 'STI',
#   'basePart': 'NS-252',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 41,
#   'site': 'STD',
#   'webBase': 'NS253',
#   'brand': 'STI',
#   'basePart': 'NS-253',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 42,
#   'site': 'STD',
#   'webBase': 'NS257',
#   'brand': 'STI',
#   'basePart': 'NS-257',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 43,
#   'site': 'STD',
#   'webBase': 'NS260',
#   'brand': 'STI',
#   'basePart': 'NS-260',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 44,
#   'site': 'STD',
#   'webBase': 'NS261',
#   'brand': 'STI',
#   'basePart': 'NS-261',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 45,
#   'site': 'STD',
#   'webBase': 'NS267',
#   'brand': 'STD',
#   'basePart': 'NS-267',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 46,
#   'site': 'STD',
#   'webBase': 'NS269',
#   'brand': 'STD',
#   'basePart': 'NS-269',
#   'partDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch / Clutch Pedal Position Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 47,
#   'site': 'STD',
#   'webBase': 'NS272',
#   'brand': 'STI',
#   'basePart': 'NS-272',
#   'partDesc_en': 'Neutral Safety Switch',
#   'partLongDesc_en': 'Neutral Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 48,
#   'site': 'STD',
#   'webBase': 'NS297',
#   'brand': 'STI',
#   'basePart': 'NS-297',
#   'partDesc_en': 'Neutral Safety Switch',
#   'partLongDesc_en': 'Neutral Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 49,
#   'site': 'STD',
#   'webBase': 'NS299',
#   'brand': 'STD',
#   'basePart': 'NS-299',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 50,
#   'site': 'STD',
#   'webBase': 'NS300',
#   'brand': 'STI',
#   'basePart': 'NS-300',
#   'partDesc_en': 'Clutch Switch',
#   'partLongDesc_en': 'Clutch Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 51,
#   'site': 'STD',
#   'webBase': 'NS301',
#   'brand': 'STI',
#   'basePart': 'NS-301',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 52,
#   'site': 'STD',
#   'webBase': 'NS314',
#   'brand': 'STI',
#   'basePart': 'NS-314',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 53,
#   'site': 'STD',
#   'webBase': 'NS315',
#   'brand': 'STI',
#   'basePart': 'NS-315',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 54,
#   'site': 'STD',
#   'webBase': 'NS323',
#   'brand': 'STI',
#   'basePart': 'NS-323',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 55,
#   'site': 'STD',
#   'webBase': 'NS325',
#   'brand': 'STD',
#   'basePart': 'NS-325',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 56,
#   'site': 'STD',
#   'webBase': 'NS344',
#   'brand': 'STI',
#   'basePart': 'NS-344',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 57,
#   'site': 'STD',
#   'webBase': 'NS381',
#   'brand': 'STI',
#   'basePart': 'NS-381',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 58,
#   'site': 'STD',
#   'webBase': 'NS384',
#   'brand': 'STD',
#   'basePart': 'NS-384',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 59,
#   'site': 'STD',
#   'webBase': 'NS386',
#   'brand': 'STD',
#   'basePart': 'NS-386',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 60,
#   'site': 'STD',
#   'webBase': 'NS387',
#   'brand': 'STD',
#   'basePart': 'NS-387',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 61,
#   'site': 'STD',
#   'webBase': 'NS389',
#   'brand': 'STD',
#   'basePart': 'NS-389',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 62,
#   'site': 'STD',
#   'webBase': 'NS461',
#   'brand': 'STD',
#   'basePart': 'NS-461',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 63,
#   'site': 'STD',
#   'webBase': 'NS479',
#   'brand': 'STD',
#   'basePart': 'NS-479',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 64,
#   'site': 'STD',
#   'webBase': 'NS491',
#   'brand': 'STD',
#   'basePart': 'NS-491',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 65,
#   'site': 'STD',
#   'webBase': 'NS508',
#   'brand': 'STI',
#   'basePart': 'NS-508',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 66,
#   'site': 'STD',
#   'webBase': 'NS515',
#   'brand': 'STI',
#   'basePart': 'NS-515',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 67,
#   'site': 'STD',
#   'webBase': 'NS525',
#   'brand': 'STD',
#   'basePart': 'NS-525',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 68,
#   'site': 'STD',
#   'webBase': 'NS526',
#   'brand': 'STI',
#   'basePart': 'NS-526',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 69,
#   'site': 'STD',
#   'webBase': 'NS529',
#   'brand': 'STI',
#   'basePart': 'NS-529',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 70,
#   'site': 'STD',
#   'webBase': 'NS542',
#   'brand': 'STI',
#   'basePart': 'NS-542',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 71,
#   'site': 'STD',
#   'webBase': 'NS545',
#   'brand': 'STI',
#   'basePart': 'NS-545',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 72,
#   'site': 'STD',
#   'webBase': 'NS546',
#   'brand': 'STI',
#   'basePart': 'NS-546',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 73,
#   'site': 'STD',
#   'webBase': 'NS565',
#   'brand': 'STD',
#   'basePart': 'NS-565',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 74,
#   'site': 'STD',
#   'webBase': 'NS567',
#   'brand': 'STI',
#   'basePart': 'NS-567',
#   'partDesc_en': 'Clutch Pedal Position Switch',
#   'partLongDesc_en': 'Clutch Pedal Position Switch',
#   'pop': 'B',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 75,
#   'site': 'STD',
#   'webBase': 'NS583',
#   'brand': 'STI',
#   'basePart': 'NS-583',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 76,
#   'site': 'STD',
#   'webBase': 'NS584',
#   'brand': 'STI',
#   'basePart': 'NS-584',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 77,
#   'site': 'STD',
#   'webBase': 'NS598',
#   'brand': 'STI',
#   'basePart': 'NS-598',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 78,
#   'site': 'STD',
#   'webBase': 'NS603',
#   'brand': 'STI',
#   'basePart': 'NS-603',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 79,
#   'site': 'STD',
#   'webBase': 'NS605',
#   'brand': 'STI',
#   'basePart': 'NS-605',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 80,
#   'site': 'STD',
#   'webBase': 'NS607',
#   'brand': 'STI',
#   'basePart': 'NS-607',
#   'partDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'partLongDesc_en': 'Clutch Starter Safety / Cruise Release Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 81,
#   'site': 'STD',
#   'webBase': 'NS633',
#   'brand': 'STI',
#   'basePart': 'NS-633',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 82,
#   'site': 'STD',
#   'webBase': 'NS637',
#   'brand': 'STI',
#   'basePart': 'NS-637',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 83,
#   'site': 'STD',
#   'webBase': '17A16763',
#   'brand': 'STD',
#   'basePart': 'NS639',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 84,
#   'site': 'STD',
#   'webBase': 'NS675',
#   'brand': 'STI',
#   'basePart': 'NS675',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 85,
#   'site': 'STD',
#   'webBase': 'NS692',
#   'brand': 'STI',
#   'basePart': 'NS692',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 86,
#   'site': 'STD',
#   'webBase': 'NS693',
#   'brand': 'STD',
#   'basePart': 'NS693',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 87,
#   'site': 'STD',
#   'webBase': 'NS694',
#   'brand': 'STI',
#   'basePart': 'NS694',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 88,
#   'site': 'STD',
#   'webBase': 'NS709',
#   'brand': 'STD',
#   'basePart': 'NS709',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 89,
#   'site': 'STD',
#   'webBase': 'NS713',
#   'brand': 'STD',
#   'basePart': 'NS713',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 90,
#   'site': 'STD',
#   'webBase': 'NS714',
#   'brand': 'STD',
#   'basePart': 'NS714',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 91,
#   'site': 'STD',
#   'webBase': 'NS720',
#   'brand': 'STD',
#   'basePart': 'NS720',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 92,
#   'site': 'STD',
#   'webBase': 'NS722',
#   'brand': 'STD',
#   'basePart': 'NS722',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 93,
#   'site': 'STD',
#   'webBase': 'NS723',
#   'brand': 'STD',
#   'basePart': 'NS723',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 94,
#   'site': 'STD',
#   'webBase': 'NS724',
#   'brand': 'STD',
#   'basePart': 'NS724',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 95,
#   'site': 'STD',
#   'webBase': 'NS726',
#   'brand': 'STI',
#   'basePart': 'NS726',
#   'partDesc_en': 'Clutch Starter Safety Switch',
#   'partLongDesc_en': 'Clutch Starter Safety Switch',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 96,
#   'site': 'STD',
#   'webBase': 'NS727',
#   'brand': 'STD',
#   'basePart': 'NS727',
#   'partDesc_en': 'Neutral Safety Switch',
#   'partLongDesc_en': 'Neutral Safety Switch',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 113,
#   'brandLink': None,
#   'imageUrl': None}]

# %%
sku_count = list_dict_2[0]['maxRows']

sku_count
# Out:
# 113

# %%
sku_count <= 0
# Out:
# False

# %%
import math

# %%
page_count = math.ceil(sku_count / 96)

page_count
# Out:
# 2

# %%
tuple_ = urlsplit(dict_['url_2'])

tuple_
# Out:
# SplitResult(scheme='https', netloc='ecatalog.smpcorp.com', path='/V2/STD/api/part/partsearch', query='filter=Clutch+Starter+Safety+Switch&filterType=n&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-', fragment='')

# %%
dict_query = {key: value[0] for key, value in parse_qs(tuple_.query).items()}

dict_query
# Out:
# {'filter': 'Clutch Starter Safety Switch',
#  'filterType': 'n',
#  'searchType': 'p',
#  'start': '0',
#  'limit': '96',
#  'sort': '3',
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
dict_query['start'] = 0 * 96

dict_query
# Out:
# {'filter': 'Clutch Starter Safety Switch',
#  'filterType': 'n',
#  'searchType': 'p',
#  'start': 0,
#  'limit': '96',
#  'sort': '3',
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
url = urlunsplit((tuple_.scheme, tuple_.netloc, tuple_.path, urlencode(dict_query), tuple_.fragment))

url
# Out:
# 'https://ecatalog.smpcorp.com/V2/STD/api/part/partsearch?filter=Clutch+Starter+Safety+Switch&filterType=n&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'

# %%
{'home': dict_['home'],
 'sku_count': sku_count,
 'page_count': page_count,
 'page': 1,
 'page_url': url}
# Out:
# {'home': 'https://www.standardbrand.com/en/ecatalog?part=Clutch+Starter+Safety+Switch&type=p',
#  'sku_count': 113,
#  'page_count': 2,
#  'page': 1,
#  'page_url': 'https://ecatalog.smpcorp.com/V2/STD/api/part/partsearch?filter=Clutch+Starter+Safety+Switch&filterType=n&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}
