# %%
computer = 'win'

if computer == 'mac':
    str_chromedriver = '../../../../chromedriver'
elif computer == 'win':
    str_chromedriver = '../../../../chromedriver.exe'
else:
    print('？？？')
    exit(0)

# = = = = = = = = = = = = = = =

from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../../00.module')
import Proxy
import UA

# = = = = = = = = = = = = = = =

import pandas as pd

df_menu = pd.read_excel('./menu.xlsx',
                        header=0,
                        dtype=str).fillna('')

list_url = df_menu['Url'].tolist()

print('总数量：' + str(len(list_url)))
print()

# = = = = = = = = = = = = = = =

df = pd.DataFrame()

# = = = = = = = = = = = = = = =

from selenium.webdriver import ChromeOptions

option = ChromeOptions()
option.add_experimental_option('useAutomationExtension', False)
option.add_argument('blink-settings=imagesEnabled=false')
option.add_argument('--disable-blink-features=AutomationControlled')
option.add_argument('--disable-dev-shm-usage')
option.add_argument('--disable-gpu')
option.add_experimental_option('excludeSwitches', ['enable-automation'])
option.add_argument('--headless')
option.add_argument('--no-sandbox')
option.add_argument('--proxy-server=' + Proxy.get_Proxy_Selenium())
option.add_argument('user-agent=' + UA.get_User_Agent())
option.page_load_strategy = 'eager'

# = = = = = = = = = = = = = = =

from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service

# = = = = = = = = = = = = = = =

import time

# = = = = = = = = = = = = = = =

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

# = = = = = = = = = = = = = = =

from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for url in list_url:
    work.put_nowait(url)

def crawler():
    global df
    
    while not work.empty():
        url = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(11):
            try:
                browser = Chrome(service=Service(str_chromedriver), options=option)

                browser.maximize_window()
                
                # = = = = = = = = = = = = = = =
                
                browser.get(url)

                time.sleep(3)
                
                # = = = = = = = = = = = = = = =
                
                if len(browser.find_elements(by=By.XPATH, value='//span[contains(@class, "navlabellink") and contains(@class, "nvoffset") and contains(@class, "nnormal")]')) != 0:
                    break
                
                # = = = = = = = = = = = = = = =
                
                wait = WebDriverWait(browser, 60)
                wait.until(EC.presence_of_element_located((By.XPATH, '//tbody[contains(@class, "listing-inner") and contains(@class, "altrow-a-1")]')))
                list_part = browser.find_elements(by=By.XPATH, value='//tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-a-1") or contains(@class, "altrow-a-0"))]')
                
                # = = = = = = = = = = = = = = =
                
                list_part_number = [_.find_element(by=By.XPATH, value='./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@title, "Buyer\'s Guide")]') for _ in list_part]
                
                # = = = = = = = = = = = = = = =
                
                part_index = [_.text for _ in list_part_number].index(url.split(',')[-3])
                
                # = = = = = = = = = = = = = = =
                
                manufacturer = list_part[part_index].find_element(by=By.XPATH, value='./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@class, "listing-final-manufacturer")]').text
                
                # = = = = = = = = = = = = = = =
                
                list_part_number[part_index].click()
                time.sleep(7)
                list_vehicle = browser.find_element(by=By.XPATH, value='//div[contains(@id, "buyersguidepopup-outer_c")]').find_elements(by=By.XPATH, value='./descendant::table[contains(@class, "nobmp")]')
                if len(list_vehicle) == 0:
                    vehicle = ''
                else:
                    vehicle = list_vehicle[0].text
                
                # = = = = = = = = = = = = = = =
                
                note_1 = ';'.join(_.text for _ in list_part[part_index].find_elements(by=By.XPATH, value='./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/span[contains(@class, "span-link-underline-remover")]'))
                
                # = = = = = = = = = = = = = = =
                
                info = ';'.join(_.get_attribute('href') for _ in list_part[part_index].find_elements(by=By.XPATH, value='./descendant::div[contains(@class, "listing-text-row-moreinfo-truck")]/a[contains(@class, "ra-btn") and contains(@class, "ra-btn-moreinfo")]'))
                
                # = = = = = = = = = = = = = = =
                
                note_2 = ';'.join(_.text for _ in list_part[part_index].find_elements(by=By.XPATH, value='./descendant::div[contains(@class, "listing-text-row") and not(contains(@class, "moreinfo-truck"))]'))
                
                # = = = = = = = = = = = = = = =
                
                oe = ';'.join(_.get_attribute('textContent') for _ in list_part[part_index].find_elements(by=By.XPATH, value='./descendant::span[contains(@title, "Replaces these Alternate/ OE Part Numbers")]'))
                oe = ';'.join(oe.split(', '))
                
                # = = = = = = = = = = = = = = =
                
                src = ';'.join(_.get_attribute('src') for _ in list_part[part_index].find_elements(by=By.XPATH, value='./descendant::img[contains(@id, "inlineimg_thumb")]'))
                
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'status': 'ok',
                                         '序号': '',
                                         'Part_Number': url.split(',')[-3],
                                         'Manufacturer': manufacturer,
                                         'Vehicle': vehicle,
                                         'Alternate_OE_Part_Numbers': oe,
                                         'Note_1': note_1,
                                         'Note_2': note_2,
                                         'Pic': '',
                                         'Url': url,
                                         'Info': info,
                                         'Src': src}])
                
                browser.quit()
                
                status = 'ok'
                
                break
                
            except:
                browser.quit()
                time.sleep(3)
                continue
                
                
        # = = = = = = = = = = = = = = =

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'Part_number': url.split(',')[-3],
                                     'Url': url}])

        # = = = = = = = = = = = = = = =

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        print(url.split(',')[-3] +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(25):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df = df.drop_duplicates(ignore_index=True)

print()
print('爬虫输出中')
df.to_excel('./part_' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
print()
print('爬虫结束')
# Out:
# 总数量：5234
#
# CMK7425  <->  [ok] - 剩余数量：5209
# CMK80068  <->  [ok] - 剩余数量：5208
# CMK7427  <->  [ok] - 剩余数量：5207
# CMK6402  <->  [ok] - 剩余数量：5206
# CMK80115  <->  [ok] - 剩余数量：5205
# CMK7424  <->  [ok] - 剩余数量：5204
# CMK7462  <->  [ok] - 剩余数量：5203
# CMK80011  <->  [ok] - 剩余数量：5202
# CMK80009  <->  [ok] - 剩余数量：5201
# CMK80038  <->  [ok] - 剩余数量：5200
# CMK80052  <->  [ok] - 剩余数量：5199
# CMK80040  <->  [ok] - 剩余数量：5198
# CMK7318  <->  [ok] - 剩余数量：5197
# CMK7213  <->  [ok] - 剩余数量：5196
# CMK7331  <->  [ok] - 剩余数量：5195
# CMK100003  <->  [ok] - 剩余数量：5194
# CMK80054  <->  [ok] - 剩余数量：5193
# CMK5313  <->  [ok] - 剩余数量：5192
# CMK5311  <->  [ok] - 剩余数量：5191
# CMK80053  <->  [ok] - 剩余数量：5190
# CMK100004  <->  [ok] - 剩余数量：5189
# CMK80055  <->  [ok] - 剩余数量：5188
# CMK80306  <->  [ok] - 剩余数量：5187
# CMK80308  <->  [ok] - 剩余数量：5186
# CMK80342  <->  [ok] - 剩余数量：5185
# CMK80323  <->  [ok] - 剩余数量：5184
# CMK80326  <->  [ok] - 剩余数量：5183
# CMK80347  <->  [ok] - 剩余数量：5182
# CMK80334  <->  [ok] - 剩余数量：5181
# CMK80327  <->  [ok] - 剩余数量：5180
# CMK80354  <->  [ok] - 剩余数量：5179
# CMK80355  <->  [ok] - 剩余数量：5178
# CMK80346  <->  [ok] - 剩余数量：5177
# CMK80357  <->  [ok] - 剩余数量：5176
# CMK80325  <->  [ok] - 剩余数量：5175
# CMK80328  <->  [ok] - 剩余数量：5174
# CMK80352  <->  [ok] - 剩余数量：5173
# CMK80389  <->  [ok] - 剩余数量：5172
# CMK80324  <->  [ok] - 剩余数量：5171
# CMK80394  <->  [ok] - 剩余数量：5170
# CMK80387  <->  [ok] - 剩余数量：5169
# CMK80356  <->  [ok] - 剩余数量：5168
# CMK80398  <->  [ok] - 剩余数量：5167
# CMK80393  <->  [ok] - 剩余数量：5166
# CMK80350  <->  [ok] - 剩余数量：5165
# CMK80343  <->  [ok] - 剩余数量：5164
# CMK80349  <->  [ok] - 剩余数量：5163
# CMK80405  <->  [ok] - 剩余数量：5162
# CMK80397  <->  [ok] - 剩余数量：5161
# CMK80395  <->  [ok] - 剩余数量：5160
# CMK80403  <->  [ok] - 剩余数量：5159
# CMK80333  <->  [ok] - 剩余数量：5158
# CMK80408  <->  [ok] - 剩余数量：5157
# CMK80409  <->  [ok] - 剩余数量：5156
# CMK3198  <->  [ok] - 剩余数量：5155
# CMK7211  <->  [ok] - 剩余数量：5154
# CMK80329  <->  [ok] - 剩余数量：5153
# CMK80388  <->  [ok] - 剩余数量：5152
# CMK80330  <->  [ok] - 剩余数量：5151
# CMK80396  <->  [ok] - 剩余数量：5150
# CMK80524  <->  [ok] - 剩余数量：5149
# CMK80407  <->  [ok] - 剩余数量：5148
# CMK80446  <->  [ok] - 剩余数量：5147
# CMK80353  <->  [ok] - 剩余数量：5146
# CMK80406  <->  [ok] - 剩余数量：5145
# CMK80528  <->  [ok] - 剩余数量：5144
# CMK80410  <->  [ok] - 剩余数量：5143
# CMK80400  <->  [ok] - 剩余数量：5142
# CMK80532  <->  [ok] - 剩余数量：5141
# CMK80534  <->  [ok] - 剩余数量：5140
# CMK80411  <->  [ok] - 剩余数量：5139
# CMK80547  <->  [ok] - 剩余数量：5138
# CMK80548  <->  [ok] - 剩余数量：5137
# CMK80639  <->  [ok] - 剩余数量：5136
# CMK80640  <->  [ok] - 剩余数量：5135
# CMK80641  <->  [ok] - 剩余数量：5134
# CMK80390  <->  [ok] - 剩余数量：5133
# CMK80556  <->  [ok] - 剩余数量：5132
# CMK80412  <->  [ok] - 剩余数量：5131
# CMK80669  <->  [ok] - 剩余数量：5130
# CMK80530  <->  [ok] - 剩余数量：5129
# CMK80545  <->  [ok] - 剩余数量：5128
# CMK80348  <->  [ok] - 剩余数量：5127
# CMK80428  <->  [ok] - 剩余数量：5126
# CMK80533  <->  [ok] - 剩余数量：5125
# CMK80529  <->  [ok] - 剩余数量：5124
# CMK80670  <->  [ok] - 剩余数量：5123
# CMK80715  <->  [ok] - 剩余数量：5122
# CMK80546  <->  [ok] - 剩余数量：5121
# CMK80718  <->  [ok] - 剩余数量：5120
# CMK80719  <->  [ok] - 剩余数量：5119
# CMK80720  <->  [ok] - 剩余数量：5118
# CMK80708  <->  [ok] - 剩余数量：5117
# CMK80713  <->  [ok] - 剩余数量：5116
# CMK80717  <->  [ok] - 剩余数量：5115
# CMK80722  <->  [ok] - 剩余数量：5114
# CMK80723  <->  [ok] - 剩余数量：5113
# CMK80724  <->  [ok] - 剩余数量：5112
# CMK80725  <->  [ok] - 剩余数量：5111
# CMK80726  <->  [ok] - 剩余数量：5110
# CMK80531  <->  [ok] - 剩余数量：5109
# CMK80712  <->  [ok] - 剩余数量：5108
# CMK80733  <->  [ok] - 剩余数量：5107
# CMK80714  <->  [ok] - 剩余数量：5106
# CMK80735  <->  [ok] - 剩余数量：5105
# CMK80736  <->  [ok] - 剩余数量：5104
# Traceback (most recent call last):
#   File "D:\venv\Lib\site-packages\gevent\_ffi\loop.py", line 296, in python_prepare_callback
#     def python_prepare_callback(self, watcher_ptr):
#
# KeyboardInterrupt
# 2023-11-17T01:01:16Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 203
#     201     task = gevent.spawn(crawler)
#     202     list_task.append(task)
# --> 203 gevent.joinall(list_task)
#     205 df = df.drop_duplicates(ignore_index=True)
#     207 print()
#
# File src\\gevent\\greenlet.py:1065, in gevent._gevent_cgreenlet.joinall()
#
# File src\\gevent\\greenlet.py:1075, in gevent._gevent_cgreenlet.joinall()
#
# File src\\gevent\\_hub_primitives.py:250, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src\\gevent\\_hub_primitives.py:287, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src\\gevent\\_hub_primitives.py:185, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src\\gevent\\_hub_primitives.py:176, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src\\gevent\\_waiter.py:195, in gevent._gevent_c_waiter.MultipleWaiter.get()
#
# File src\\gevent\\_waiter.py:154, in gevent._gevent_c_waiter.Waiter.get()
#
# File src\\gevent\\_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src\\gevent\\_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src\\gevent\\_greenlet_primitives.py:65, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src\\gevent\\_gevent_c_greenlet_primitives.pxd:35, in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# File D:\venv\Lib\site-packages\gevent\_ffi\loop.py:296, in AbstractCallbacks.python_prepare_callback(self, watcher_ptr)
#     293         except MemoryError:
#     294             pass
# --> 296 def python_prepare_callback(self, watcher_ptr):
#     297     loop = self._find_loop_from_c_watcher(watcher_ptr)
#     298     if loop is None: # pragma: no cover
#
# KeyboardInterrupt:
# D:\venv\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
