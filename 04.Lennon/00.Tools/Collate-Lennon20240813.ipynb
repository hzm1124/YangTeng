# %% [markdown]
# # 2. Dorman
#
# ## 2.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Configuration'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 3. eBay
#
# ## 3.1 Json

# %%
# import pandas as pd

# input_ = pd.read_excel('./2.item.xlsx',
#                        header=0,
#                        dtype=str).fillna('')

# input_['No'] = input_['No'].astype(int)

# # = = = = = = = = = = = = = = =

# from tqdm import tqdm
# import json

# for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
#     dict_ = json.loads(input_.loc[i, 'Json_Specific'])
#     for value in dict_.values():
#         input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

# input_.to_excel('./2.item-new.xlsx', index=False)

# input_

# %% [markdown]
# ## 3.2. Vehicle
#
# ### 3.2.1. US、UK、AU、CA

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], df_temp.loc[j, 'Engine'], int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# ### 3.2.2. DE

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Item Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Item Number'] == input_2.loc[i, 'Item Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year, year_2 = df_temp.loc[j, 'Marke'], df_temp.loc[j, 'Modell'], df_temp.loc[j, 'Motor'], int(df_temp.loc[j, 'Baujahr'].split('-')[0].split('/')[0]), int(df_temp.loc[j, 'Baujahr'].split('-')[1].split('/')[0])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year] if year == year_2 else [year, year_2]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year] if year == year_2 else [year, year_2]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year] if year == year_2 else [year, year_2]
        else:
            if year not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year)
            if year_2 not in dict_vehicle[make][model][engine]:
                dict_vehicle[make][model][engine].append(year_2)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Item Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2

# %% [markdown]
# # 4. Cardone
#
# ## 4.1. Json

# %%
# input_ = pd.read_excel('crawler.xlsx',
#                        header=0,
#                        dtype=str).fillna('')

# input_

# import json

# for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
#     dict_ = json.loads(input_.loc[i, 'Json_Info'])
#     for value in dict_.values():
#         input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

# input_.to_excel('./json.xlsx', index=False)

# input_

# %% [markdown]
# ## 4.2. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make, model, engine, year = df_temp.loc[j, 'Make'], df_temp.loc[j, 'Model'], ' '.join([df_temp.loc[j, 'Cylinder'], df_temp.loc[j, 'Displacement'], df_temp.loc[j, 'Liter']]), int(df_temp.loc[j, 'Year'])

        if make not in dict_vehicle:
            dict_vehicle[make] = {model: {engine: [year]}}
        elif model not in dict_vehicle[make]:
            dict_vehicle[make][model] = {engine: [year]}
        elif engine not in dict_vehicle[make][model]:
            dict_vehicle[make][model][engine] = [year]
        elif year not in dict_vehicle[make][model][engine]:
            dict_vehicle[make][model][engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            list_year = []
            for engine in dict_vehicle[make][model]:
                list_year = list(set(list_year + dict_vehicle[make][model][engine]))
            year_begin = min(list_year)
            year_end = max(list_year)
            list_vehicle.append(f'{make} {model} {year_begin}' if year_begin == year_end else f'{make} {model} {year_begin}-{year_end}')

    input_2.loc[i, 'Vehicle W/o Engine'] = '\n'.join(sorted(list_vehicle))

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make in dict_vehicle:
        for model in dict_vehicle[make]:
            for engine in dict_vehicle[make][model]:
                year_begin = min(dict_vehicle[make][model][engine])
                year_end = max(dict_vehicle[make][model][engine])
                list_vehicle.append(f'{make} {model} {year_begin} {engine}'.strip() if year_begin == year_end else f'{make} {model} {year_begin}-{year_end} {engine}'.strip())

    input_2.loc[i, 'Vehicle W/ Engine'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle W/o Engine',
         'Vehicle W/ Engine']].to_excel('./vehicle.xlsx', index=False)

input_2
# Out:
# Progress: 100%|███████████████████████████| 498/498 [00:03<00:00, 135.34it/s]
#       No Part Number Row Vehicle Type Region        Make        Model  \
# 0      1     65-1000  45        Truck    CAN   Chevrolet     Traverse
# 1      2    65-1001A   1        Truck    CAN   Chevrolet      Equinox
# 2      3    65-1001B   9        Truck    CAN     Pontiac      Torrent
# 3      4     65-1002  16          Car    USA    Cadillac          CTS
# 4      5     65-1003  73          Car    USA    Cadillac          STS
# ..   ...         ...  ..          ...    ...         ...          ...
# 493  517     65-9875  77        Truck    MEX       Dodge   Ramcharger
# 494  518     65-9915  18        Truck    USA      Toyota       Pickup
# 495  519     65-9918  39        Truck    USA      Toyota       Pickup
# 496  520     65-9919  28        Truck    USA      Toyota       Pickup
# 497  521     65-9921   8        Truck    CAN  Land Rover  Range Rover
#
#     Submodel Cylinder Displacement Liter  Year Fuel           Aspiration  \
# 0    Premier       V6       217cid  3.6L  2017  GAS  Naturally Aspirated
# 1         LS       V6       207cid  3.4L  2007  GAS  Naturally Aspirated
# 2      Sport       V6       207cid  3.4L  2007  GAS  Naturally Aspirated
# 3       Base       V6       217cid  3.6L  2006  GAS  Naturally Aspirated
# 4       Base       V6       217cid  3.6L  2008  GAS  Naturally Aspirated
# ..       ...      ...          ...   ...   ...  ...                  ...
# 493     Base       V8       360cid  5.9L  1991  GAS  Naturally Aspirated
# 494      SR5       L4       2366cc  2.4L  1988  GAS  Naturally Aspirated
# 495      DLX       V6       2959cc    3L  1990  GAS  Naturally Aspirated
# 496      DLX       L4       2366cc  2.4L  1994  GAS  Naturally Aspirated
# 497     Base       V8       216cid  3.5L  1987  GAS  Naturally Aspirated
#
#     Drive Type Position                                 Vehicle W/o Engine  \
# 0          AWD     Rear  Buick Enclave 2008-2017\nChevrolet Traverse 20...
# 1          AWD     Rear  Chevrolet Equinox 2005-2007\nPontiac Torrent 2...
# 2          AWD     Rear  Chevrolet Equinox 2005-2007\nPontiac Torrent 2...
# 3          RWD     Rear                             Cadillac CTS 2004-2007
# 4          AWD    Front  Cadillac CTS 2008-2014\nCadillac SRX 2004-2009...
# ..         ...      ...                                                ...
# 493        4WD    Front  Dodge Ramcharger 1990-1993\nDodge W150 1990-19...
# 494        4WD    Front       Toyota 4Runner 1987-1988\nToyota Pickup 1988
# 495        4WD    Front  Toyota 4Runner 1989-1995\nToyota Pickup 1989-1...
# 496        4WD    Front  Toyota 4Runner 1989-1995\nToyota Pickup 1989-1995
# 497        4WD    Front  Land Rover Defender 90 1994-1997\nLand Rover D...
#
#                                      Vehicle W/ Engine
# 0    Buick Enclave 2008-2017 V6 217cid 3.6L\nChevro...
# 1    Chevrolet Equinox 2005-2007 V6 207cid 3.4L\nPo...
# 2    Chevrolet Equinox 2005-2007 V6 207cid 3.4L\nPo...
# 3    Cadillac CTS 2004-2007 V6 217cid 3.6L\nCadilla...
# 4    Cadillac CTS 2008-2014 V6 217cid 3.6L\nCadilla...
# ..                                                 ...
# 493  Dodge Ramcharger 1990-1993 V8 318cid 5.2L\nDod...
# 494  Toyota 4Runner 1987-1988 L4 2366cc 2.4L\nToyot...
# 495  Toyota 4Runner 1989-1995 V6 2959cc 3L\nToyota ...
# 496  Toyota 4Runner 1989-1995 L4 2366cc 2.4L\nToyot...
# 497  Land Rover Defender 90 1994-1995 V8 3950cc 3.9...
#
# [498 rows x 18 columns]

# %% [markdown]
# # 7. SpectraPremium
#
# ## 7.1. Vehicle

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

# = = = = = = = = = = = = = = =

input_2 = input_.drop_duplicates(['Part Number'],
                                 keep='first',
                                 ignore_index=True)
input_2 = input_2.sort_values(by=['No'],
                              ascending=[True],
                              ignore_index=True)

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for i in tqdm(range(len(input_2)), desc='Progress', ncols=77):
    df_temp = input_[input_['Part Number'] == input_2.loc[i, 'Part Number']].reset_index(drop=True)

    # = = = = = = = = = = = = = = =

    dict_vehicle = {}
    for j in range(len(df_temp)):
        make_model_engine, year = df_temp.loc[j, 'Make Model Engine'], int(df_temp.loc[j, 'Year'])

        if make_model_engine not in dict_vehicle:
            dict_vehicle[make_model_engine] = [year]
        elif year not in dict_vehicle[make_model_engine]:
            dict_vehicle[make_model_engine].append(year)

    # = = = = = = = = = = = = = = =

    list_vehicle = []
    for make_model_engine in dict_vehicle:
        year_begin = min(dict_vehicle[make_model_engine])
        year_end = max(dict_vehicle[make_model_engine])
        list_vehicle.append(f'{make_model_engine}'.strip() if year_begin == year_end else f'{make_model_engine} {year_begin}-{year_end}'.strip())

    input_2.loc[i, 'Vehicle'] = '\n'.join(sorted(list_vehicle))

# = = = = = = = = = = = = = = =

input_2[['No',
         'Part Number',
         'Vehicle']].to_excel('./vehicle.xlsx', index=False)

input_2
# Out:
# Progress: 100%|███████████████████████████| 210/210 [00:00<00:00, 399.05it/s]
#       No Part Number Page Make Model Engine No  \
# 0      1      TB1001    1                    1
# 1      2      TB1173    1                    1
# 2      3      TB1174    1                    1
# 3      4      TB1175    1                    1
# 4      5      TB1176    1                    1
# ..   ...         ...  ...                  ...
# 205  207      TB1093    1                    1
# 206  208      TB1094    1                    1
# 207  209      TB1095    1                    1
# 208  210      TB1063    1                    1
# 209  211      TB1335    1                    1
#
#                                Make Model Engine Row  Year  \
# 0                     INFINITI FX35 Base V6 3.5L   1  2008
# 1                         Ford Escape SE L4 1.6L   1  2016
# 2                     Ford Escape Hybrid L4 2.3L   1  2008
# 3                    Hyundai Santa Fe GL L4 2.4L   1  2012
# 4                    Hyundai Santa Fe GL V6 2.7L   1  2009
# ..                                           ...  ..   ...
# 205              Volkswagen Touareg Base V6 3.2L   1  2006
# 206                 Audi A3 Quattro Base V6 3.2L   1  2009
# 207  Volkswagen Jetta City (Canada) Base L4 2.0L   1  2009
# 208                        Audi A4 Avant L4 1.8L   1  2005
# 209                         Kia Forte EX L4 2.0L   1  2013
#
#                           Fuel Fuel Del. ASP. Eng. VIN Eng. Desg.    CC  CID  \
# 0                          GAS        FI    N        -     VQ35DE  3498    -
# 1                          GAS        FI    T        X          -  1596   97
# 2    FULL HYBRID EV-GAS (FHEV)        FI    N        H          -     -  140
# 3                          GAS        FI    N        B          -  2359    -
# 4                          GAS        FI    N        D          -  2656    -
# ..                         ...       ...  ...      ...        ...   ...  ...
# 205                        GAS        FI    N        -        BMX  3189  195
# 206                        GAS        FI    N        -       CBRA  3189  195
# 207                        GAS        FI    N        -        BEV  1984  121
# 208                        GAS        FI    T        C        AMB  1781    -
# 209                        GAS        FI    N        2          -  1998  122
#
#                                                Vehicle
# 0    INFINITI FX35 Base V6 3.5L 2003-2008\nINFINITI...
# 1    Ford Escape SE L4 1.6L 2013-2016\nFord Escape ...
# 2    Ford Escape Hybrid L4 2.3L 2005-2008\nMercury ...
# 3    Hyundai Santa Fe GL L4 2.4L 2010-2012\nHyundai...
# 4    Hyundai Santa Fe GL V6 2.7L 2007-2009\nHyundai...
# ..                                                 ...
# 205  Volkswagen Touareg Base V6 3.2L 2005-2006\nVol...
# 206  Audi A3 Quattro Base V6 3.2L 2006-2009\nAudi T...
# 207  Volkswagen Jetta City (Canada) Base L4 2.0L 20...
# 208  Audi A4 Avant Confort L4 1.8L\nAudi A4 Avant L...
# 209  Kia Forte EX L4 2.0L 2010-2013\nKia Forte LX L...
#
# [210 rows x 15 columns]

# %% [markdown]
# # 10. Amazon

# %%
import pandas as pd

input_ = pd.read_excel('./crawler.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_

# %%
import json

for i in range(len(input_)):
    dict_ = json.loads(input_.loc[i, 'Json_Overview'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 1'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Detail 2'])
    for value in dict_.values():
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 1'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

    dict_ = json.loads(input_.loc[i, 'Json_Information 2'])
    for value in dict_.values():
        if list(value.keys())[0] == 'Customer Reviews':
            input_.loc[i, f'{list(value.keys())[0]} Star'] = list(value.values())[0]['0']
            input_.loc[i, f'{list(value.keys())[0]} Rating'] = list(value.values())[0]['1']
        elif list(value.keys())[0] == 'Best Sellers Rank':
            list_rank = []
            for value_2 in list(value.values())[0].values():
                list_rank.append(f'{list(value_2.keys())[0]} -> {list(value_2.values())[0]}')
            input_.loc[i, 'Best Sellers Rank'] = '\n'.join(list_rank)
        else:
            input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./fuck.xlsx', index=False)

input_
