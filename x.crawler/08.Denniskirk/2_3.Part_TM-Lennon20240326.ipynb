# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 260

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 260/260 [00:00<00:00, 543.78it/s]
#       序号      Brand                                              Title  \
# 0      1  All Balls        8Ball Extreme Duty Rear Axle - AB8-HO-8-327
# 1      2  All Balls   8Ball Extreme Duty Rear Left Axle - AB8-KW-8-320
# 2      3  All Balls  8Ball Extreme Duty Rear Left or Right side Axl...
# 3      4  All Balls  8Ball Extreme Duty Rear Right Axle - AB8-KW-8-321
# 4      5  All Balls              Complete Rear Axle Kit - AB8-PO-8-398
# ..   ...        ...                                                ...
# 255  256      Moose                 Complete Front Axle Kit - YAM-7004
# 256  257      Moose                  Complete Rear Axle Kit - YAM-7009
# 257  258      Moose                  Complete Rear Axle Kit - YAM-7010
# 258  259      Moose                 Complete Front Axle Kit - YAM-7017
# 259  260      Moose                 Complete Front Axle Kit - YAM-7019
#
#                                                Vehicle  \
# 0    Honda TRX420FA Rancher AT 4x4 2014\nHonda TRX4...
# 1    Kawasaki KAF1000A Mule Pro-DXT 2016-2022\nKawa...
# 2    Polaris Sportsman 450 H.O. 2016-2020\nPolaris ...
# 3    Kawasaki KAF1000A Mule Pro-DXT 2016-2022\nKawa...
# 4                    Polaris RZR Turbo 4 S XP EPS 2019
# ..                                                 ...
# 255  Yamaha YFM660F Grizzly 4x4 2003-2004\nYamaha Y...
# 256  Yamaha YFM660F Grizzly 4x4 2003-2004\nYamaha Y...
# 257  Yamaha YFM660F Grizzly 4x4 2003-2004\nYamaha Y...
# 258  Yamaha YXR450F Rhino 4x4 2008-2009\nYamaha YXR...
# 259  Yamaha YXR450F Rhino 4x4 2008-2009\nYamaha YXR...
#
#                          OE Pic  \
# 0    02141526;42220-HR6-A61
# 1       02141528;59266-0049
# 2          02141529;1333275
# 3       02141531;59266-0050
# 4          02141790;1334060
# ..                      ...  ..
# 255                02142700
# 256                02142701
# 257                02142702
# 258                02142703
# 259                02142704
#
#                                                    Url  \
