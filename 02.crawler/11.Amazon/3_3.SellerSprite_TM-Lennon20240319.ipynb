# %%
import os

# %%
list_file = list(os.walk('./sellersprite'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 96

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./sellersprite/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['ASIN'], ascending=[True]).reset_index(drop=True)
df.to_excel('./sellersprite.xlsx', index=False)

df
# Out:
# Progress: 100%|█████████████████████████████| 96/96 [00:00<00:00, 331.22it/s]
#           ASIN    标识       父ASIN               品牌  \
# 0   B019DTLTX0        B019DTLTX0    Hex Autoparts
# 1   B01EENLX18   ;BS  B01EENLX18  269 Motorsports
# 2   B06XHPZ17V    A+  B06XHPZ17V            TOPAZ
# 3   B07B9WNPJ9        B07B9WNPJ9    Hex Autoparts
# 4   B07DLK9VFY        B07DLK9VFY  Maxsam Clutches
# ..         ...   ...         ...              ...
# 91  B0CNGG6YFR  V;NR  B0CNGG6YFR          AUTOKAY
# 92  B0CP3RFT23  V;NR  B0CP3RFT23          AUTOKAY
# 93  B0CPJ947P7     V  B0CPJ947P7          AUTOKAY
# 94  B0CPVG4L9S        B0CPVG4L9S         RAYAMURR
# 95  B0CWZVYYX2   ;NR  B0CWZVYYX2          PHILTOP
#
#                                                  品牌链接    大类BSR排名  近7天BSR增长数  \
# 0   https://www.amazon.com/stores/HexAutoparts/pag...    252,367    632,374
# 1   https://www.amazon.com/269-Motorsports/b/ref=b...    133,716    339,470
# 2   https://www.amazon.com/stores/AftermarketAutom...    534,326    413,040
# 3   https://www.amazon.com/stores/HexAutoparts/pag...     98,623          -
# 4   https://www.amazon.com/s/ref=bl_dp_s_web_0?ie=...    239,463  2,689,276
# ..                                                ...        ...        ...
# 91  https://www.amazon.com/AUTOKAY/b/ref=bl_dp_s_w...    191,546          -
# 92  https://www.amazon.com/AUTOKAY/b/ref=bl_dp_s_w...    248,232    465,462
# 93  https://www.amazon.com/AUTOKAY/b/ref=bl_dp_s_w...  1,451,644   -273,602
# 94  https://www.amazon.com/RAYAMURR/b/ref=bl_dp_s_...    481,072    921,454
# 95  https://www.amazon.com/stores/PHILTOP/page/074...    178,693          -
#
#    近7天BSR增长率 父体近30天总销量 父体近30天销量增长率  ...   配送  \
# 0        71%         4        120%  ...  FBM
# 1        75%        24           -  ...  FBA
# 2        44%        17        700%  ...  FBA
# 3          -        18           -  ...   NA
# 4        92%         1           -  ...  FBM
# ..       ...       ...         ...  ...  ...
# 91         -        19           -  ...  FBA
# 92       65%        15           -  ...  FBA
# 93      -23%         7           -  ...  FBA
# 94       66%         3           -  ...  FBM
# 95         -         6           -  ...  AMZ
#
#                                                类目路径_1  \
# 0   Automotive -> Replacement Parts -> Engine Cool...
# 1   Automotive -> Replacement Parts -> Engine Cool...
# 2   Automotive -> Replacement Parts -> Engine Cool...
# 3   Automotive -> Replacement Parts -> Engine Cool...
# 4   Automotive -> Replacement Parts -> Engine Cool...
# ..                                                ...
# 91  Automotive -> Replacement Parts -> Engine Cool...
# 92  Automotive -> Replacement Parts -> Engine Cool...
# 93  Automotive -> Replacement Parts -> Engine Cool...
# 94  Automotive -> Replacement Parts -> Engine Cool...
# 95  Automotive -> Replacement Parts -> Engine Cool...
#
#                                      类目路径_2  \
# 0   汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 1   汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 2   汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 3   汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 4   汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# ..                                      ...
# 91  汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 92  汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 93  汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 94  汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
# 95  汽车 -> 替换零件 -> 发动机冷却 -> 空调 -> 离合器 -> 离合器
#
#                                                   小类目            重量  \
# 0   #20 - Automotive Replacement Air Conditioning ...   5.35 pounds
# 1   #5 - Automotive Replacement Air Conditioning C...  0.634 ounces
# 2   #72 - Automotive Replacement Air Conditioning ...    3.1 pounds
# 3   #145 - Automotive Replacement Air Conditioning...            --
# 4   #17 - Automotive Replacement Air Conditioning ...      6 pounds
# ..                                                ...           ...
# 91  #13 - Automotive Replacement Air Conditioning ...   5.19 pounds
# 92  #95 - Automotive Replacement Air Conditioning ...   4.91 pounds
# 93  #246 - Automotive Replacement Air Conditioning...   5.66 pounds
# 94  #37 - Automotive Replacement Air Conditioning ...            --
# 95  #12 - Automotive Replacement Air Conditioning ...   3.96 pounds
#
#                                     体积  LQS  卖家数                    BuyBox卖家  \
# 0   6.02 x 5.79 x 2.76 inches (大号标准尺寸)  6.2  1 家    BuyBox卖家:  AiKai America
# 1        7.5 x 5 x 0.3 inches (小号标准尺寸)  6.8  1 家  BuyBox卖家:  269 Motorsports
# 2      0.6 x 0.6 x 0.6 inches (大号标准尺寸)  9.0  2 家  BuyBox卖家:  Carparts Online
# 3                            -- (其他尺寸)  8.2  1 家
# 4            6 x 6 x 2 inches (大号标准尺寸)   --  1 家    BuyBox卖家:  Automotive AC
# ..                                 ...  ...  ...                         ...
# 91    6.5 x 6.22 x 2.2 inches (大号标准尺寸)  6.2  1 家          BuyBox卖家:  AUTOKAY
# 92  6.02 x 5.51 x 2.56 inches (大号标准尺寸)  5.8  1 家          BuyBox卖家:  AUTOKAY
# 93   6.42 x 6.22 x 2.2 inches (大号标准尺寸)   --  1 家          BuyBox卖家:  AUTOKAY
# 94                           -- (其他尺寸)  6.6  1 家      BuyBox卖家:  GNJINX SHOP
# 95  5.91 x 5.91 x 2.44 inches (大号标准尺寸)  6.2  2 家           BuyBox卖家:  Amazon
#
#      BuyBox
# 0   (FBM, )
# 1   (FBA, )
# 2   (FBA, )
# 3
# 4   (FBM, )
# ..      ...
# 91  (FBA, )
# 92  (FBA, )
# 93  (FBA, )
# 94  (FBM, )
# 95    (AMZ)
#
# [96 rows x 34 columns]
