# %%
import pandas as pd

# %%
df_menu = pd.read_excel('./menu.xlsx', header=0)
list_url = df_menu['Url'].to_list()

print('总数量：' + str(len(list_url)))
list_url
# Out:
# 总数量：745
# ['https://www.summitracing.com/parts/trd-42913',
#  'https://www.summitracing.com/parts/trd-42921',
#  'https://www.summitracing.com/parts/trd-4336',
#  'https://www.summitracing.com/parts/trd-46001',
#  'https://www.summitracing.com/parts/trd-46002',
#  'https://www.summitracing.com/parts/trd-46004',
#  'https://www.summitracing.com/parts/trd-46005',
#  'https://www.summitracing.com/parts/trd-46007',
#  'https://www.summitracing.com/parts/trd-46008',
#  'https://www.summitracing.com/parts/trd-46011',
#  'https://www.summitracing.com/parts/trd-46012',
#  'https://www.summitracing.com/parts/trd-46014',
#  'https://www.summitracing.com/parts/trd-46015',
#  'https://www.summitracing.com/parts/trd-46017',
#  'https://www.summitracing.com/parts/trd-46018',
#  'https://www.summitracing.com/parts/trd-48061',
#  'https://www.summitracing.com/parts/trd-48062',
#  'https://www.summitracing.com/parts/trd-48063',
#  'https://www.summitracing.com/parts/trd-9469',
# ...

# %%
df = pd.DataFrame(columns=['Url',
                           'Price',
                           'Src',
                           'status'])

df
# Out:
# Empty DataFrame
# Columns: [Url, Price, Src, status]
# Index: []

# %%
from selenium.webdriver import ChromeOptions

# %%
option = ChromeOptions()
option.add_experimental_option('useAutomationExtension', False)
option.add_argument('blink-settings=imagesEnabled=false')
option.add_argument('--disable-blink-features=AutomationControlled')
option.add_argument('--disable-dev-shm-usage')
option.add_argument('--disable-gpu')
option.add_experimental_option('excludeSwitches', ['enable-automation'])
# option.add_argument('--headless')
option.add_argument('--no-sandbox')
option.add_argument('--proxy-server=http://u431.kdltps.com:15818')
option.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36')
option.page_load_strategy = 'eager'

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service

# %%
browser = Chrome(service=Service('../../../chromedriver'), options=option)

browser.maximize_window()

# %%
import time

# %%
i = 4

browser.get(list_url[i])

time.sleep(5)

# %%
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

# %%
wait = WebDriverWait(browser, 60)
wait.until(EC.presence_of_element_located((By.XPATH, '//p[@class="price"]')))
price = browser.find_element(by=By.XPATH, value='//p[@class="price"]').text

price
# Out:
# '$1,260.99'

# %%
wait.until(EC.presence_of_element_located((By.XPATH, '//img[@id="primaryImage"]')))
src = browser.find_element(by=By.XPATH, value='//img[@id="primaryImage"]').get_attribute('src')

src
# Out:
# 'https://static.summitracing.com/global/images/prod/xlarge/trd-46002_xl.jpg'

# %%
df_temp = pd.DataFrame([{'Url': list_url[i],
                         'Price': price,
                         'Src': src,
                         'status': 'ok'}])

df_temp
# Out:
#                                             Url      Price  \
# 0  https://www.summitracing.com/parts/trd-46002  $1,260.99
#
#                                                  Src status
# 0  https://static.summitracing.com/global/images/...     ok

# %%
wait.until(EC.presence_of_element_located((By.XPATH, '//div[@class="attribute-container flex-container flex-wrap"]')))
list_name = [name.text for name in browser.find_elements(by=By.XPATH, value='//div[@class="attribute-container flex-container flex-wrap"]/div[@class="small-12 medium-9 large-6"]/strong')]
list_value = [value.text for value in browser.find_elements(by=By.XPATH, value='//div[@class="attribute-container flex-container flex-wrap"]/div[@class="small-12 medium-15 large-18"]')]

for name, value in zip(list_name, list_value):
    df_temp[name[:-1].lower()] = value
    
browser.quit()

df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#                                             Url      Price  \
# 0  https://www.summitracing.com/parts/trd-46002  $1,260.99
#
#                                                  Src status  \
# 0  https://static.summitracing.com/global/images/...     ok
#
#                              brand manufacturer's part number  \
# 0  Trans-Dapt Performance Products                      46002
#
#           part type                                       product line  \
# 0  Engine Swap Kits  Trans-Dapt Performance Swap-In-A-Box Complete ...
#
#   summit racing part number          upc  ...  \
# 0                 TRD-46002  86923460022  ...
#
#   transmission crossmember included oil pan included pickup included  \
# 0                                No              Yes             Yes
#
#   oil pan material oil pan finish oil pan capacity stroker clearanced  \
# 0            Steel    Red painted      5.00 quarts                 No
#
#   gaskets included hardware included        quantity
# ...
