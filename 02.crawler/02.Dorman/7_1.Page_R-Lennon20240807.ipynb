# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel('./6.type.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Type No'] = input_['Type No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Type'].tolist()
# Out:
# 总数量：2278
# [' Air Suspension Line Repair Kit',
#  '110 Volt Accessory Power Outlet',
#  '12 Volt Accessory Power Outlet Cover',
#  '12 Volt Accessory Power Outlet Socket',
#  '4 Wheel Drive Switch',
#  '4WD Actuator Cable',
#  '4WD Actuator Fork',
#  '4WD Actuator Valve',
#  '4WD Actuator Wiring Harness',
#  '4WD Axle Actuator',
#  '4WD Axle Actuator Housing',
#  '4WD Disconnect',
#  '4WD Disconnect Gear',
#  '4WD Disconnect Gear Kit',
#  '4WD Hub Locking Actuator Delete',
#  '4WD Hub Locking Actuator Vacuum Hose',
#  '4WD Hub Locking Solenoid',
#  '4WD Vacuum Check Valve',
#  'A/C Accumulator Bracket Retainer',
#  'A/C Compressor Clutch',
#  'A/C Compressor Clutch Dust Cover Retaining Clip',
#  'A/C Compressor Clutch Relay',
#  'A/C Compressor Control Valve',
#  'A/C Compressor Flow Sensor',
#  'A/C Condenser Bolt',
#  'A/C Condenser Fan Assembly',
#  'A/C Condenser Fan Motor Relay',
#  'A/C Expansion Valve Mount Plate',
#  'A/C Hose Assembly',
#  'A/C Hose Bolt',
#  'A/C Line Clip',
#  'A/C Refrigerant Pressure Sensor',
#  'A/C Service Valve Cap',
#  'A/C Vacuum Actuator',
#  'ABS Control Module',
#  'ABS Control Module Bolt',
#  'ABS Control Module Clip',
#  'ABS Hydraulic Actuator Dust Shield Retaining Clip',
#  'ABS Pump and Motor Assembly',
#  'ABS Relay',
#  'ABS Tone Ring',
#  'ABS Wheel Speed Sensor',
#  'ABS Wheel Speed Sensor Bracket',
#  'ABS Wheel Speed Sensor Retainer',
#  'ABS Wheel Speed Sensor Wiring Harness',
#  'AWD Coupling Oil Pump',
#  'AWD Coupling Unit',
#  'Accelerator Pedal',
#  'Accelerator Pedal Bracket',
#  'Accelerator Pedal Bushing',
#  'Accelerator Pedal Sensor',
#  'Accelerator Pedal Sensor Clip Nut',
#  'Accelerator Pedal Stop Pad',
#  'Accessory Box Cover Retainer',
#  'Accessory Drive Belt Idler Pulley',
#  'Accessory Drive Belt Idler Pulley Adjustment Bolt Kit',
#  'Accessory Drive Belt Tensioner Assembly',
#  'Accessory Power Relay',
#  'Accessory Safety Relay',
#  'Active Suspension Control Module Clip',
#  'Adaptive Light Module',
#  'Air Bag Clockspring',
#  'Air Bag Control Module Bolt',
#  'Air Bag Impact Sensor',
#  'Air Bag Impact Sensor Screw',
#  'Air Bag Passenger Presence Module Retainer',
#  'Air Brake Compressor Mounting Gasket',
#  'Air Brake Pressure Sensor',
#  'Air Brake Pressure Switch',
#  'Air Brake Reservoir',
#  'Air Brake Reservoir Mounting Cable',
#  'Air Charge Temperature Sensor',
#  'Air Cleaner Assembly',
#  'Air Cleaner Cover Bolt',
#  'Air Cleaner Duct Bolt',
#  'Air Cleaner Parts',
#  'Air Conditioning Bypass Pulley',
#  'Air Conditioning Service Valve',
#  'Air Control Valve Relay',
#  'Air Dam',
#  'Air Dam Clip',
#  'Air Dam Support',
#  'Air Distribution Duct Clip',
#  'Air Filter Housing',
#  'Air Filter Housing Clamp',
#  'Air Filter Housing Grommet',
#  'Air Filter Housing Screw',
#  'Air Intake Coupling',
#  'Air Intake Heater Relay',
#  'Air Intake Hose',
#  'Air Spring to Coil Spring Conversion Kit',
#  'Air Suspension Compressor',
#  'Air Suspension Compressor Bolt',
#  'Air Suspension Compressor Case',
#  'Air Suspension Compressor Dryer',
#  'Air Suspension Compressor Isolator',
#  'Air Suspension O-Ring Kit',
#  'Air Suspension Refill Tool Kit',
#  'Air Suspension Solenoid Valve Unit',
#  'Alignment - Cam Bolt',
#  'Alignment - Cam Bolt Kit',
#  'Alignment - Camber / Toe Arm',
#  'Alignment - Camber / Toe Kit',
#  'Alignment - Camber / Toe Lateral Link',
#  'Alignment - Camber / Toe Shim',
#  'Alignment - Camber Adjusting Anchor Bolt',
#  'Alignment - Camber Bushing',
#  'Alignment - Camber King Pin',
#  'Alignment - Camber Kit',
#  'Alignment - Camber Lateral Link',
#  'Alignment - Camber Plate',
#  'Alignment - Camber Shim',
#  'Alignment - Camber Shim Assortment',
#  'Alignment - Camber Shim Kit',
#  'Alignment - Camber Wedge',
#  'Alignment - Caster / Camber Ball Joint',
#  'Alignment - Caster / Camber Bushing',
#  'Alignment - Caster / Camber Cam',
#  'Alignment - Caster / Camber Cam Bolt Kit',
#  'Alignment - Caster / Camber Control Arm',
#  'Alignment - Caster / Camber Kit',
#  'Alignment - Caster / Camber Tool',
#  'Alignment - Caster / Camber Washer Kit',
#  'Alignment - Caster / Pinion Angle Bolt Kit',
#  'Alignment - Caster / Pinion Angle Control Arm',
#  'Alignment - Caster Radius Arm Bushing Kit',
#  'Alignment - Caster Shim Kit',
#  'Alignment - Guide Pin',
#  'Alignment - Shim',
#  'Alignment - Toe Arm',
#  'Alignment - Toe Shim',
#  'Alternator Bracket',
#  'Alternator Bushing',
#  'Alternator Extension Harness',
#  'Alternator Pulley',
#  'Ambient Air Temperature Sensor',
#  'Ambient Air Temperature Sensor Bolt',
#  'Ambient Air Temperature Sensor Clip',
#  'Ambient Light Sensor',
#  'Antenna',
#  'Antenna Base',
#  'Antenna Base Cover',
#  'Antenna Mast',
#  'Antenna Retainer',
#  'Antenna Seal',
#  'Anti-Theft Alarm Control Unit Clip',
#  'Anti-Theft Alarm Switch',
#  'Anti-Theft Relay',
#  'Ash Tray Clip',
#  'Ash Tray Light Bulb',
#  'Atomization Module Air Drier Filter Mount Kit',
#  'Audio / Video Jack',
#  'Audio Amplifier Bolt',
#  'Auto Shut Down Relay',
#  'Auto Trans Filler Pipe Cover Lock Pin',
#  'Auto Transmission Case Vent',
#  'Auto Transmission Drain Plug Gasket',
#  'Auto Transmission Security Cap',
#  'Auto Transmission Shift Lever Collar',
#  'Auto Transmission Shift Linkage Bushing',
#  'Auto Transmission Shift Tube Bushing',
#  'Automatic / Manual Transmission Shift Boot',
#  'Automatic Headlight Control Relay',
#  'Automatic Transmission Case Cover',
#  'Automatic Transmission Case Vent Valve',
#  'Automatic Transmission Conductor Plate',
#  'Automatic Transmission Dipstick',
#  'Automatic Transmission Dipstick Tube',
#  'Automatic Transmission Flexplate Mounting Bolt',
#  'Automatic Transmission Fluid Temperature Sensor',
#  'Automatic Transmission Indicator Light Bulb',
#  'Automatic Transmission Kickdown Solenoid',
#  'Automatic Transmission Lube Line Retainer',
#  'Automatic Transmission Mount Bushing',
#  'Automatic Transmission Oil Cooler',
#  'Automatic Transmission Oil Cooler Gasket',
#  'Automatic Transmission Oil Cooler Hose Elbow',
#  'Automatic Transmission Oil Cooler Line Connector O-Ring',
#  'Automatic Transmission Oil Cooler O-Ring',
#  'Automatic Transmission Oil Cooler Retainer',
#  'Automatic Transmission Oil Cooler Thermostat',
#  'Automatic Transmission Oil Cooler Thermostat Bracket',
#  'Automatic Transmission Oil Pressure Switch',
#  'Automatic Transmission Plug Adapter',
#  'Automatic Transmission Pressure Sensor Transducer',
#  'Automatic Transmission Shift Bezel',
#  'Automatic Transmission Shift Cable Bushing',
#  'Automatic Transmission Shift Cover Plate',
#  'Automatic Transmission Shift Indicator',
#  'Automatic Transmission Shift Indicator Cable Bracket',
#  'Automatic Transmission Shift Lever',
#  'Automatic Transmission Shift Lever Bracket',
#  'Automatic Transmission Shift Lever Bushing',
#  'Automatic Transmission Shift Lever Control Rod Bushing',
#  'Automatic Transmission Shift Lever Knob',
#  'Automatic Transmission Shift Linkage Clip',
#  'Automatic Transmission Shift Repair Kit',
#  'Automatic Transmission Shift Tube Clamp',
#  'Automatic Transmission Shift Tube Lever Pin',
#  'Automatic Transmission Shifter Cable Lever',
#  'Automatic Transmission Shifter Cable Repair Kit',
#  'Automatic Transmission Shifter Repair Kit',
#  'Automatic Transmission Throttle Valve',
#  'Automatic Transmission Torque Converter Bolt',
#  'Automatic Transmission Torque Converter Clutch Solenoid',
#  'Automatic Transmission Valve Body Sealing Sleeve',
#  'Auxiliary Engine Cooling Fan Relay',
#  'Axle Bolt',
#  'Axle Differential Seal',
#  'Axle Hub O-Ring',
#  'Axle Shaft',
#  'Axle Shaft Assembly',
#  'Axle Vent',
#  'Back Glass Release Actuator',
#  'Back Glass Sunshade Retainer',
#  'Back Glass Washer Nozzle',
#  'Back Glass Wiper Switch Clip Nut',
#  'Back Up Alarm',
#  'Back Up Light Assembly',
#  'Back Up Light Assembly Retainer',
#  'Back Up Light Bulb',
#  'Back Up Light Relay',
#  'Back Up Light Switch Clip',
#  'Barometric Pressure Sensor',
#  'Battery Cable Retainer',
#  'Battery Cable Terminal Adjuster',
#  'Battery Capacitor',
#  'Battery Cover',
#  'Battery Current Sensor',
#  'Battery Cut-Off Switch',
#  'Battery Fuse',
#  'Battery Heat Shield Retainer',
#  'Battery Hold Down',
#  'Battery Hold Down Bolt',
#  'Battery Terminal',
#  'Battery Terminal Bolt',
#  'Battery Terminal Bus Bar',
#  'Battery Terminal Cover',
#  'Battery Tray',
#  'Battery Tray Brace',
#  'Battery Tray Retainer',
#  'Battery Vent Tube',
#  'Belt Tensioner Bolt',
#  'Belt Tensioner Damper',
#  'Blind Spot Detection (BSD) Module',
#  'Blower Fan Switch',
#  'Blower Motor Resistor',
#  'Blower Motor Resistor Kit',
#  'Blower Motor Wiring Harness',
#  'Body A-Pillar Trim Panel',
#  'Body A-Pillar Trim Panel Clip',
#  'Body Bolt',
#  'Body Control Module',
#  'Body Control Module Retainer',
#  'Body Hardware',
#  'Body Mount',
#  'Body Mount Bracket',
#  'Body Mount Cushion Bolt',
#  'Body Mount Nut',
#  'Body Mount Set',
#  'Body Wiring Harness Clip',
#  'Body Wiring Harness Retainer Bolt',
#  'Brake Adjusting Lever',
#  'Brake Adjusting Screw Assembly',
#  'Brake Adjusting Screw Spring Kit',
#  'Brake Air Duct Retainer',
#  'Brake Anti-Rattle Clip',
#  'Brake Backing Plate',
#  'Brake Bleeder Screw',
#  'Brake Bleeder Screw Set',
#  'Brake Caliper Bolt',
#  'Brake Caliper Bracket Bolt',
#  'Brake Caliper Piston',
#  'Brake Caliper Repair Kit',
#  'Brake Dust Shield',
#  'Brake Filter',
#  'Brake Fluid Pressure Sensor',
#  'Brake Hardware Kit - Disc',
#  'Brake Hardware Kit - Drum',
#  'Brake Hold Down Cup',
#  'Brake Hold Down Kit',
#  'Brake Hold Down Pin',
#  'Brake Hold Down Pin Clip',
#  'Brake Hose',
#  'Brake Hose Banjo Bolt',
#  'Brake Hose to Caliper Bolt Washer',
#  'Brake Hydraulic Hose Bracket Bolt',
#  'Brake Hydraulic Hose Lock Clip',
#  'Brake Hydraulic Line Clip',
#  'Brake Hydraulic Line Kit',
#  'Brake Hydraulic Line Screw',
#  'Brake Light Bulb',
#  'Brake Light Switch',
#  'Brake Light Switch Retainer',
#  'Brake Line - Preformed',
#  'Brake Master Cylinder Reservoir',
#  'Brake Master Cylinder Reservoir Bolt',
#  'Brake Master Cylinder Reservoir Cap and Gasket Kit',
#  'Brake Pedal Bracket Bolt',
#  'Brake Pedal Bracket Clip',
#  'Brake Pedal Bushing',
#  'Brake Pedal Stop Pad',
#  'Brake Proportioning Valve',
#  'Brake Return Spring',
#  'Brake Self Adjuster Cable Link',
#  'Brake Self Adjuster Repair Kit',
#  'Brake Self Adjusting Cable Guide',
#  'Brake Sleeve Stabilizer',
#  'Bumper',
#  'Bumper Bracket',
#  'Bumper Clip',
#  'Bumper Cover',
#  'Bumper Cover Grille',
#  'Bumper Cover Reinforcement',
#  'Bumper Cover Retainer',
#  'Bumper Cover Trim Panel Retainer',
#  'Bumper Deflector',
#  'Bumper End',
#  'Bumper End Cap',
#  'Bumper Extension',
#  'Bumper Grille Insert',
#  'Bumper Impact Absorber Bracket Bolt',
#  'Bumper Seal',
#  'Bumper Trim',
#  'Bus Door Motor',
#  'CD Player',
#  'CV Axle Shaft Carrier Bearing Bracket',
#  'CV Boot Kit',
#  'CV Intermediate Shaft',
#  'Cab Door Vent',
#  'Cabin Air Filter',
#  'Cabin Air Filter Cover',
#  'Cabin Air Filter Retainer',
#  'Cabin Air Filter Retrofit Kit',
#  'Cabin Pressure Relief Valve',
#  'Cable - Automatic Transmission Shift',
#  'Cable - Clutch',
#  'Cable - Door Latch',
#  'Cable - Fuel Filler Door Release',
#  'Cable - Fuel Filler Door and Trunk Release',
#  'Cable - HVAC Heater Control',
#  'Cable - Hood Release',
#  'Cable - Manual Transmission Shift',
#  'Cable - Parking Brake',
#  'Cable - Tailgate Support',
#  'Cable - Trunk Release',
#  'Camshaft Expansion Plug',
#  'Camshaft Position Sensor',
#  'Camshaft Position Sensor Magnet',
#  'Camshaft Synchronizer',
#  'Capless Fuel Filler Dust Cap',
#  'Capless Fuel Funnel',
#  'Cargo Area Light',
#  'Cargo Area Light Clip',
#  'Cargo Area Light Switch',
#  'Cargo Net Bolt',
#  'Cargo Net Clip',
#  'Catalytic Converter',
#  'Catalytic Converter Anti-Theft Shield',
#  'Catalytic Converter Flange',
#  'Catalytic Converter Heat Shield Bolt Set',
#  'Catalytic Converter with Integrated Exhaust Manifold',
#  'Caution Label Clip',
#  'Center Console Base',
#  'Center Console Hinge Repair Kit',
#  'Center Console Latch',
#  'Chassis Fairing Handle Extension',
#  'Chassis Fairing Handle Kit',
#  'Check Engine Light Bulb',
#  'Cigarette Lighter',
#  'Cigarette Lighter Bezel',
#  'Cigarette Lighter Kit',
#  'Clock Light',
#  'Clutch Alignment Tool',
#  'Clutch Combination Master and Slave Cylinder Assy',
#  'Clutch Fork',
#  'Clutch Fork Lever Bolt',
#  'Clutch Hose',
#  'Clutch Hydraulic Line',
#  'Clutch Hydraulic Line Clip',
#  'Clutch Master Cylinder',
#  'Clutch Master Cylinder Reservoir Bolt',
#  'Clutch Master Cylinder Reservoir Retainer',
#  'Clutch Pedal Bracket',
#  'Clutch Pedal Bushing',
#  'Clutch Pilot Bearing',
#  'Clutch Pilot Bushing',
#  'Clutch Pivot Ball Stud',
#  'Clutch Push Rod',
#  'Clutch Push Rod Lever',
#  'Clutch Push Rod Repair Kit',
#  'Clutch Servo',
#  'Clutch Slave Cylinder',
#  'Clutch Starter Safety Switch',
#  'Coat Hook Bolt',
#  'Coat Hook Clip',
#  'Coil Boot',
#  'Communication Interface Module Retainer',
#  'Computer Control Relay',
#  'Connecting Rod Nut',
#  'Console Bolt',
#  'Console Lid',
#  'Console Trim Panel Clip',
#  'Convertible Top Latch Bracket Retainer',
#  'Convertible Top Relay',
#  'Coolant Air Bleeder',
#  'Coolant Air Bleeder Screw',
#  'Coolant Filler Neck',
#  'Coolant Heat Storage Tank Pump',
#  'Coolant Hose Connector',
#  'Coolant Pipe',
#  'Coolant Pump Motion Sensor',
#  'Coolant Reservoir',
#  'Coolant Reservoir Cap',
#  'Coolant Thermostat Housing',
#  'Coolant Thermostat Housing Assembly',
#  'Coolant Water Bypass Gasket',
#  'Coolant Water Outlet',
#  'Cornering Light Assembly',
#  'Cornering Light Bulb',
#  'Cornering Light Clip',
#  'Courtesy Light Bulb',
#  'Cowl Cover',
#  'Cowl Panel',
#  'Cowl Panel Retainer',
#  'Crankshaft Angle Sensor Blade',
#  'Crankshaft Position Sensor',
#  'Cruise Control Cable Retainer',
#  'Cruise Control Distance (CCD) Sensor',
#  'Cruise Control Kit',
#  'Cruise Control Module Bolt',
#  'Cruise Control Module Bracket Clip Nut',
#  'Cruise Control Servo Bolt',
#  'Cruise Control Servo Bracket Clip',
#  'Cruise Control Switch',
#  'Cruise Control Vacuum Check Valve',
#  'Cup Holder',
#  'Curtain Air Bag Bolt',
#  'Curtain Air Bag Clip',
#  'Cylinder Head Bolt',
#  'DEF Filler Cap',
#  'DVD Player',
#  'DVD Player Remote Control',
#  'Dash Board Air Vent',
#  'Dashboard Cover',
#  'Dashboard Panel',
#  'Dashboard Panel Insulator Clip',
#  'Daytime Running Light Bulb',
#  'Daytime Running Light Module',
#  'Daytime Running Light Relay',
#  'Daytime Running Light Resistor',
#  'Delta Pressure Feedback Exhaust Gas Recirculation (EGR) Tube and Sensor Kit',
#  'Diesel Engine Air Intake Throttle Duct',
#  'Diesel Engine Air Intake Throttle Duct Installation Kit',
#  'Diesel Exhaust Fluid (DEF) Filler Neck',
#  'Diesel Exhaust Fluid (DEF) Filler Neck Filter',
#  'Diesel Exhaust Fluid (DEF) Heater',
#  'Diesel Exhaust Fluid (DEF) Injector',
#  'Diesel Exhaust Fluid (DEF) Injector Feed Line',
#  'Diesel Exhaust Fluid (DEF) Injector Gasket',
#  'Diesel Exhaust Fluid (DEF) Level Sensor',
#  'Diesel Exhaust Fluid (DEF) Pump',
#  'Diesel Exhaust Fluid (DEF) Pump Cover',
#  'Diesel Exhaust Fluid (DEF) Pump Wiring Harness',
#  'Diesel Exhaust Fluid (DEF) Urea Filter Kit',
#  'Diesel Fuel Filter Bleeder Screw',
#  'Diesel Fuel Heating Element',
#  'Diesel Fuel Injector Driver Module',
#  'Diesel Fuel Injector Driver Module Resistor',
#  'Diesel Fuel Injector Pump',
#  'Diesel Fuel Injector Pump Driver Relocation Kit',
#  'Diesel Fuel Injector Rail Plug',
#  'Diesel Glow Plug Controller',
#  'Diesel Glow Plug Power Strap',
#  'Diesel Glow Plug Relay',
#  'Diesel Glow Plug Wiring Harness',
#  'Diesel High Pressure Oil Pump',
#  'Diesel High Pressure Oil Pump Fitting Kit',
#  'Diesel High Pressure Oil Pump Hose',
#  'Diesel High Pressure Oil Pump Seal Kit',
#  'Diesel Injection Control Pressure Harness',
#  'Diesel Injection Control Pressure Sensor',
#  'Diesel Oxidation Catalyst (DOC)',
#  'Diesel Particulate Filter (DPF)',
#  'Diesel Particulate Filter (DPF) Clamp',
#  'Diesel Particulate Filter (DPF) Gasket',
#  'Diesel Particulate Filter (DPF) Hardware Kit',
#  'Diesel Particulate Filter (DPF) Igniter Coil Lead Wire',
#  'Diesel Particulate Filter (DPF) Igniter Plug',
#  'Diesel Particulate Filter (DPF) Pressure Sensor',
#  'Diesel Primer Pump',
#  'Differential Bearing Kit',
#  'Differential Carrier',
#  'Differential Carrier Gear Kit',
#  'Differential Clutch Kit',
#  'Differential Clutch Pressure Control Valve',
#  'Differential Clutch Pump Motor',
#  'Differential Cover',
#  'Differential Cover Plug',
#  'Differential Crush Sleeve',
#  'Differential Drain Plug',
#  'Differential Dynamic Dampener',
#  'Differential Gasket',
#  'Differential Housing',
#  'Differential Lock Actuator',
#  'Differential Lock Motor',
#  'Differential Lock Sensor',
#  'Differential Oil Temperature Sensor',
#  'Differential Pinion Flange',
#  'Differential Pinion Shaft Lock Bolt',
#  'Differential Pinion Shaft Nut',
#  'Differential Pinion Yoke',
#  'Differential Ring and Pinion',
#  'Dimmer Switch',
#  'Disc Brake Caliper Bolt Kit',
#  'Disc Brake Caliper Bushing',
#  'Disc Brake Caliper Cover',
#  'Disc Brake Caliper Pin',
#  'Disc Brake Caliper Pin Boot Kit',
#  'Disc Brake Caliper Pin Kit',
#  'Disc Brake Caliper Support Spring',
#  'Disc Brake Guide Pin Retaining Clip',
#  'Disc Brake Pad Retaining Clip',
#  'Disc Brake Rotor Bolt',
#  'Disc Brake Rotor Set Screw',
#  'Distributor Cap O-Ring',
#  'Distributor Drive Gear',
#  'Distributor Repair Plate',
#  'Distributor Seal Kit',
#  'Dome Light',
#  'Dome Light Bulb',
#  'Dome Light Clip',
#  'Dome Light Housing',
#  'Dome Light Lens',
#  'Door',
#  'Door Applique',
#  'Door Armrest',
#  'Door Armrest Clip',
#  'Door Armrest Cover',
#  'Door Armrest Cover Clip',
#  'Door Belt Molding',
#  'Door Bumper Clip',
#  'Door Check',
#  'Door Check Bolt',
#  'Door Check Pin',
#  'Door Check Strap',
#  'Door Control Module',
#  'Door Glass Attaching Clips',
#  'Door Glass Spacer',
#  'Door Glass Sunshade Clip',
#  'Door Hinge Assembly',
#  'Door Hinge Bushing',
#  'Door Hinge Detent Roller',
#  'Door Hinge Nut',
#  'Door Hinge Pin',
#  'Door Hinge Pin and Bushing Kit',
#  'Door Hinge Screw',
#  'Door Hinge Spring',
#  'Door Interior Reflector',
#  'Door Interior Trim Panel',
#  'Door Interior Trim Panel Retainer',
#  'Door Latch Anti-Theft Shield Retainer',
#  'Door Latch Assembly',
#  'Door Latch Bolt',
#  'Door Latch Cable Repair Kit',
#  'Door Latch Reinforcement',
#  'Door Lock Actuator Motor',
#  'Door Lock Actuator Motor Clip',
#  'Door Lock Cylinder',
#  'Door Lock Cylinder Clip',
#  'Door Lock Knob',
#  'Door Lock Relay',
#  'Door Lock Rod Clip',
#  'Door Lock Striker',
#  'Door Lock Striker Anti-Rattle Kit',
#  'Door Mirror Bracket',
#  'Door Mirror Clip',
#  'Door Mirror Control Module',
#  'Door Mirror Cover',
#  'Door Mirror Mount Cover',
#  'Door Mirror Turn Signal Light',
#  'Door Molding',
#  'Door Motor',
#  'Door Panel Install Kit',
#  'Door Seal',
#  'Door Sill Plate',
#  'Door Sill Plate Clip',
#  'Door Stop Bolt',
#  'Door Window Belt Weatherstrip Clip',
#  'Door Window Lock-Out Switch',
#  'Door Window Switch Bezel',
#  'Door Wiring Harness',
#  'Drive Axle Shaft Flange Gasket',
#  'Drive Axle Shaft Housing',
#  'Drive Axle Shaft Lock C-Clip',
#  'Drive Axle Shaft Retainer',
#  'Drive Axle Shaft Seal',
#  'Drive Axle Shaft Seal Retainer Nut',
#  'Drive Belt Tensioner',
#  'Drive Belt Tensioner Pulley',
#  'Drive Belt Tensioner Tool',
#  'Drive Motor Battery Pack Cooling Fan Assembly',
#  'Drive Motor Battery Service Plug',
#  'Drive Motor Coolant Pump',
#  'Drive Motor Inverter Cooler',
#  'Drive Motor Inverter Cooler Water Pump',
#  'Drive Motor Stator',
#  'Drive Shaft',
#  'Drive Shaft Bolt',
#  'Drive Shaft CV Joint',
#  'Drive Shaft Center Support Bearing',
#  'Drive Shaft Coupler',
#  'Drive Shaft Flange Yoke',
#  'Drive Shaft Pinion Yoke',
#  'Drive Shaft Repair Kit',
#  'Drive Shaft Slip Yoke',
#  'Driver Information Display Switch',
#  'Driving Light Relay',
#  'Drum Brake Adjusting Screw',
#  'Drum Brake Adjusting Screw Spring',
#  'Drum Brake Hold Down Spring',
#  'Electric Fuel Pump Repair Kit',
#  'Electronic Brake Control Relay',
#  'Electronic Brake Control Wiring Harness Clip',
#  'Electronic Load Detector',
#  'Electronic Parking Brake Control Switch',
#  'Electronic Throttle Body Module',
#  'Emission Check Valve',
#  'Emission Control Relay',
#  'Engine Air Box Clip',
#  'Engine Air Duct Clip',
#  'Engine Air Intake Duct Boot',
#  'Engine Auxiliary Water Pump',
#  'Engine Balance Shaft Chain Tensioner',
#  'Engine Balance Shaft Seal Kit',
#  'Engine Brake Switch',
#  'Engine Camshaft Bracket',
#  'Engine Compartment Light Bulb',
#  'Engine Control Module (ECM)',
#  'Engine Control Module (ECM) Bolt',
#  'Engine Control Module (ECM) Clip',
#  'Engine Coolant Air Bleed Pipe',
#  'Engine Coolant Bypass Hose',
#  'Engine Coolant Bypass Pipe',
#  'Engine Coolant Bypass Valve',
#  'Engine Coolant Crossover Pipe',
#  'Engine Coolant Hose',
#  'Engine Coolant Hose Flange Kit',
#  'Engine Coolant Level Sensor',
#  'Engine Coolant Overflow Hose',
#  'Engine Coolant Pipe O-Ring Kit',
#  'Engine Coolant Pressure Sensor',
#  'Engine Coolant Reservoir Bolt',
#  'Engine Coolant Reservoir Clip',
#  'Engine Coolant Reservoir Hose',
#  'Engine Coolant Reservoir Mounting Plate',
#  'Engine Coolant Shut-Off Valve',
#  'Engine Coolant Temperature Sensor',
#  'Engine Coolant Temperature Sensor Clip',
#  'Engine Coolant Thermostat Adapter Lead',
#  'Engine Coolant Thermostat Housing Flange Repair Kit',
#  'Engine Coolant Thermostat Housing Gasket',
#  'Engine Cooling Fan Clutch Switch',
#  'Engine Cooling Fan Module',
#  'Engine Cooling Fan Motor Relay',
#  'Engine Cooling Fan Motor Relay Retainer',
#  'Engine Cooling Fan Motor Wiring Harness',
#  'Engine Cooling Fan Relay Kit',
#  'Engine Cooling Fan Resistor',
#  'Engine Cooling Fan Resistor Kit',
#  'Engine Cooling Fan Shroud',
#  'Engine Cooling Fan Shroud Bolt',
#  'Engine Cooling Fan Shroud Clip',
#  'Engine Cover Grommet',
#  'Engine Cradle Hardware Kit',
#  'Engine Crankcase Breather Connector',
#  'Engine Crankcase Breather Element',
#  'Engine Crankcase Breather Element Gasket',
#  'Engine Crankcase Breather Hose',
#  'Engine Crankcase Breather Hose Check Valve',
#  'Engine Crankcase Pressure Sensor',
#  'Engine Crankcase Vent Valve',
#  'Engine Crankcase Ventilation Cover',
#  'Engine Crankshaft Main Bearing Cap Bolt',
#  'Engine Crankshaft Position Sensor Interrupter',
#  'Engine Crankshaft Rear Seal Installation Tool',
#  'Engine Crankshaft Seal Retainer',
#  'Engine Cylinder Deactivation Solenoid',
#  'Engine Cylinder Head Stud',
#  'Engine Cylinder Head Temperature Sensor',
#  'Engine Harmonic Balancer Adapter',
#  'Engine Harmonic Balancer Bolt',
#  'Engine Harmonic Balancer Pulley',
#  'Engine Multiple Displacement System Solenoid',
#  'Engine Oil Cooler',
#  'Engine Oil Cooler Air Duct Retainer',
#  'Engine Oil Cooler Bolt',
#  'Engine Oil Cooler Coolant Water Outlet',
#  'Engine Oil Cooler Gasket',
#  'Engine Oil Cooler Gasket Set',
#  'Engine Oil Cooler Hose Assembly',
#  'Engine Oil Cooler Line Connector',
#  'Engine Oil Cooler Line Retainer',
#  'Engine Oil Cooler Mount',
#  'Engine Oil Cooler O-Ring',
#  'Engine Oil Cooler Seal',
#  'Engine Oil Cooler Seal Kit',
#  'Engine Oil Dipstick',
#  'Engine Oil Dipstick Flange Repair Kit',
#  'Engine Oil Dipstick Tube',
#  'Engine Oil Dipstick and Tube Kit',
#  'Engine Oil Drain Plug',
#  'Engine Oil Drain Plug Gasket',
#  'Engine Oil Drainback Valve',
#  'Engine Oil Filler Cap',
#  'Engine Oil Filler Cap O-Ring',
#  'Engine Oil Filler Tube',
#  'Engine Oil Filler Tube Grommet',
#  'Engine Oil Filter Adapter',
#  'Engine Oil Filter Adapter Gasket',
#  'Engine Oil Filter Adapter O-Ring',
#  'Engine Oil Filter Bypass Valve',
#  'Engine Oil Filter Cover',
#  'Engine Oil Filter Cover Plug',
#  'Engine Oil Filter Drain Deflector Clip',
#  'Engine Oil Filter Housing',
#  'Engine Oil Filter Housing Cover Drain Plug',
#  'Engine Oil Filter Housing Return Tube',
#  'Engine Oil Filter Housing Seal',
#  'Engine Oil Filter Housing Seal Kit',
#  'Engine Oil Filter Support',
#  'Engine Oil Galley Expansion Plug',
#  'Engine Oil Level Sensor',
#  'Engine Oil Level Sensor Cover',
#  'Engine Oil Line',
#  'Engine Oil Pan',
#  'Engine Oil Pan Gasket',
#  'Engine Oil Pressure Sensor',
#  'Engine Oil Pressure Sensor Filter',
#  'Engine Oil Pump Bushing',
#  'Engine Oil Pump Expansion Plug',
#  'Engine Oil Pump Flow Control Valve',
#  'Engine Oil Pump Seal',
#  'Engine Oil Pump Solenoid',
#  'Engine Oil Separator',
#  'Engine Oil Separator Cover',
#  'Engine Oil Stand Pipe',
#  'Engine Oil Stand Pipe Seal Kit',
#  'Engine Oil Sump Windage Tray',
#  'Engine Oil Temperature Sensor',
#  'Engine Oil Temperature and Pressure Sensor',
#  'Engine Rear Main Seal Cover',
#  'Engine Rocker Arm Oil Control Solenoid',
#  'Engine Splash Shield Hardware',
#  'Engine Splash Shield Nut',
#  'Engine Splash Shield Retainer',
#  'Engine Timing Belt Idler Pulley',
#  'Engine Timing Belt Idler Pulley Bolt',
#  'Engine Timing Belt Tensioner',
#  'Engine Timing Belt Tensioner Spring',
#  'Engine Timing Camshaft Sprocket',
#  'Engine Timing Chain Guide Bolt',
#  'Engine Timing Chain Kit',
#  'Engine Timing Chain Tensioner O-Ring',
#  'Engine Timing Cover Bolt Set',
#  'Engine Timing Cover Gasket Set',
#  'Engine Timing Cover Plug',
#  'Engine Valve Cover',
#  'Engine Valve Cover Bolt Kit',
#  'Engine Valve Cover Gasket',
#  'Engine Valve Cover Gasket O-Ring',
#  'Engine Valve Cover Repair Kit',
#  'Engine Valve Lifter Oil Manifold',
#  'Engine Variable Valve Lift Eccentric Shaft Actuator',
#  'Engine Variable Valve Lift Eccentric Shaft Actuator Seal',
#  'Engine Variable Valve Timing (VVT) Adjuster Magnet',
#  'Engine Variable Valve Timing (VVT) Eccentric Shaft Position Sensor',
#  'Engine Variable Valve Timing (VVT) Oil Control Valve',
#  'Engine Variable Valve Timing (VVT) Oil Pressure Switch',
#  'Engine Variable Valve Timing (VVT) Solenoid',
#  'Engine Variable Valve Timing (VVT) Solenoid Filter',
#  'Engine Variable Valve Timing (VVT) Solenoid Gasket',
#  'Engine Variable Valve Timing (VVT) Solenoid Gasket Kit',
#  'Engine Variable Valve Timing (VVT) Solenoid Housing',
#  'Engine Variable Valve Timing (VVT) Solenoid Seal',
#  'Engine Variable Valve Timing (VVT) Sprocket',
#  'Engine Variable Valve Timing (VVT) Sprocket Bolt',
#  'Engine Variable Valve Timing (VVT) Sprocket Park Lock Solenoid',
#  'Engine Water Pump',
#  'Engine Water Pump Bolt Kit',
#  'Engine Water Pump O-Ring',
#  'Engine Water Pump Pulley',
#  'Engine Water Pump Relay',
#  'Engine Wiring Harness Clip',
#  'Evaporative Emissions System Leak Detection Pump',
#  'Evaporative Emissions System Leak Detection Pump Filter',
#  'Evaporative Emissions System Lines',
#  'Evaporative Emissions System Pressure Sensor',
#  'Evaporative Emissions System Purge Flow Sensor',
#  'Exhaust Backpressure Sensor',
#  'Exhaust Bracket',
#  'Exhaust Brake Actuator',
#  'Exhaust Clamp',
#  'Exhaust Clamp Kit',
#  'Exhaust Crossover Pipe',
#  'Exhaust Elbow',
#  'Exhaust Flange',
#  'Exhaust Flange Bolt',
#  'Exhaust Flange Bolt and Spring',
#  'Exhaust Flange Spring',
#  'Exhaust Flange Stud and Nut',
#  'Exhaust Gas Differential Pressure Sensor',
#  'Exhaust Gas Recirculation (EGR) Cooler',
#  'Exhaust Gas Recirculation (EGR) Cooler Clamp',
#  'Exhaust Gas Recirculation (EGR) Cooler Clamp and Gasket Set',
#  'Exhaust Gas Recirculation (EGR) Cooler Gasket',
#  'Exhaust Gas Recirculation (EGR) Cooler Gasket Kit',
#  'Exhaust Gas Recirculation (EGR) Cooler Hose',
#  'Exhaust Gas Recirculation (EGR) Cooler Installation Kit',
#  'Exhaust Gas Recirculation (EGR) Cooler Seal Carrier',
#  'Exhaust Gas Recirculation (EGR) Gasket Set',
#  'Exhaust Gas Recirculation (EGR) Line',
#  'Exhaust Gas Recirculation (EGR) Line Gasket',
#  'Exhaust Gas Recirculation (EGR) Pressure Feedback Hose',
#  'Exhaust Gas Recirculation (EGR) Pressure Sensor',
#  'Exhaust Gas Recirculation (EGR) System Service Kit',
#  'Exhaust Gas Recirculation (EGR) Transducer',
#  'Exhaust Gas Recirculation (EGR) Tube Connector',
#  'Exhaust Gas Recirculation (EGR) Tube Kit',
#  'Exhaust Gas Recirculation (EGR) Vacuum Modulator',
#  'Exhaust Gas Recirculation (EGR) Vacuum and Evaporation Pressure Regulator Solenoid Valve',
#  'Exhaust Gas Recirculation (EGR) Valve',
#  'Exhaust Gas Recirculation (EGR) Valve Control Solenoid',
#  'Exhaust Gas Recirculation (EGR) Valve Gasket',
#  'Exhaust Gas Recirculation (EGR) Valve Housing',
#  'Exhaust Gas Recirculation (EGR) Valve Mounting Kit',
#  'Exhaust Gas Recirculation (EGR) Valve Temperature Sensor',
#  'Exhaust Gas Temperature (EGT) Sensor',
#  'Exhaust Gas Temperature (EGT) Sensor Bung Repair Kit',
#  'Exhaust Heat Shield',
#  'Exhaust Heat Shield Bolt',
#  'Exhaust Heat Shield Clip Nut',
#  'Exhaust Manifold',
#  'Exhaust Manifold Bolt and Spring',
#  'Exhaust Manifold Gasket',
#  'Exhaust Manifold Gasket and Hardware Kit',
#  'Exhaust Manifold Hardware Kit',
#  'Exhaust Manifold Heat Shield',
#  'Exhaust Manifold Nut',
#  'Exhaust Manifold Stud',
#  'Exhaust Manifold Stud and Nut',
#  'Exhaust Manifold to Cylinder Head Repair Clamp',
#  'Exhaust Nut',
#  'Exhaust Pipe Bellow',
#  'Exhaust Pipe Flange Gasket',
#  'Exhaust System Hanger',
#  'Expansion Plug',
#  'Expansion Plug - Engine Cylinder Head',
#  'Expansion Plug - Intake Manifold',
#  'Expansion Plug - Intermediate Shaft',
#  'Expansion Plug Kit',
#  'Exterior Door Handle Cover',
#  'Exterior Door Handle Reinforcement',
#  'Exterior Door Handle Repair Kit',
#  'Exterior Door Handle Switch Assembly Connector',
#  'Exterior Door Handle Trim',
#  'Exterior Molding Clip',
#  'Fan Clutch',
#  'Fan Pulley Bracket',
#  'Fender',
#  'Fender Flare Hardware Kit',
#  'Fender Liner Grommet',
#  'Fender Liner Retainer',
#  'Fender Molding Retainer',
#  'Fender Rivet',
#  'Fender Splash Shield',
#  'Fender Splash Shield Clip',
#  'Fender Support Bolt',
#  'Fender Support Bracket',
#  'Flex Fuel Sensor',
#  'Floor Carpet Clip',
#  'Floor Mat Retainer',
#  'Floor Pan',
#  'Floor Pan Retainer',
#  'Floor Pan Splash Shield Bolt',
#  'Floor Storage Compartment Lid Handle',
#  'Floor Support',
#  'Flywheel Housing Gasket',
#  'Flywheel Mounting Bolt',
#  'Fog Light',
#  'Fog Light Assembly',
#  'Fog Light Bezel',
#  'Fog Light Bezel Clip Nut',
#  'Fog Light Delete Insert',
#  'Fog Light Housing Clip',
#  'Fog Light Relay',
#  'Fog Light Screw',
#  'Folding Seat Lock Striker Bolt',
#  'Frame Crossmember',
#  'Frame Crossmember Hole Plug',
#  'Frame Repair Kit',
#  'Fuel Cooler',
#  'Fuel Cut-Off Relay',
#  'Fuel Door Cover',
#  'Fuel Door Hinge',
#  'Fuel Door Release Repair Kit',
#  'Fuel Door Spring',
#  'Fuel Filler Door Kit',
#  'Fuel Filler Door Lock Actuator',
#  'Fuel Filler Door Retaining Clip',
#  'Fuel Filler Door Switch',
#  'Fuel Filler Hose',
#  'Fuel Filler Housing',
#  'Fuel Filler Housing Bolt',
#  'Fuel Filler Neck',
#  'Fuel Filler Neck Bolt',
#  'Fuel Filler Neck Clip',
#  'Fuel Filler Neck Rivet',
#  'Fuel Filler Neck Seal',
#  'Fuel Filter Bolt',
#  'Fuel Filter Cap',
#  'Fuel Filter Housing',
#  'Fuel Filter Housing Seal Kit',
#  'Fuel Filter Primer Housing Seal Kit',
#  'Fuel Filter Spring',
#  'Fuel Hose',
#  'Fuel Hose Clamp',
#  'Fuel Hose Tee',
#  'Fuel Injection Control Module Grommet',
#  'Fuel Injection Fuel Feed Pipe',
#  'Fuel Injection Fuel Feed and Return Pipe Seal Kit',
#  'Fuel Injection Fuel Rail Pressure Relief Valve',
#  'Fuel Injection Fuel Rail Pressure Sensor',
#  'Fuel Injection Harness',
#  'Fuel Injection Main Relay',
#  'Fuel Injection Pressure Regulator',
#  'Fuel Injection Pressure Regulator Seal',
#  'Fuel Injection Return Line Gasket Kit',
#  'Fuel Injector',
#  'Fuel Injector Clip',
#  'Fuel Injector Control Module',
#  'Fuel Injector Control Module Clip',
#  'Fuel Injector Feed Line Seal',
#  'Fuel Injector Line',
#  'Fuel Injector O-Ring Kit',
#  'Fuel Injector Rail',
#  'Fuel Injector Sleeve',
#  'Fuel Level Sensor',
#  'Fuel Line',
#  'Fuel Line Banjo Bolt',
#  'Fuel Line Clip',
#  'Fuel Line Connector',
#  'Fuel Line Retainer',
#  'Fuel Management Wiring Harness',
#  'Fuel Pressure Regulator Service Kit',
#  'Fuel Pressure Relief Valve Cap',
#  'Fuel Pressure Sensor',
#  'Fuel Pump',
#  'Fuel Pump Camshaft Follower',
#  'Fuel Pump Control Module',
#  'Fuel Pump Driver Module',
#  'Fuel Pump Driver Module Bolt',
#  'Fuel Pump Hanger Assembly',
#  'Fuel Pump Module Assembly',
#  'Fuel Pump Push Rod',
#  'Fuel Pump Relay',
#  'Fuel Pump Relay Bolt',
#  'Fuel Pump Strainer',
#  'Fuel Pump Tank Seal',
#  'Fuel Tank',
#  'Fuel Tank Attaching Hardware',
#  'Fuel Tank Cap',
#  'Fuel Tank Crossmember',
#  'Fuel Tank Lock Ring',
#  'Fuel Tank Pressure Sensor',
#  'Fuel Tank Roll Over Valve',
#  'Fuel Tank Selector Switch',
#  'Fuel Tank Selector Valve',
#  'Fuel Tank Sending Unit',
#  'Fuel Tank Sending Unit Gasket',
#  'Fuel Tank Sending Unit Lock Ring',
#  'Fuel Tank Shield Clip',
#  'Fuel Tank Skid Plate',
#  'Fuel Tank Strap',
#  'Fuel Tank Strap Bracket',
#  'Fuel Tank Vent Valve',
#  'Fuel Tank Vent Valve Seal',
#  'Fuel Temperature Sensor',
#  'Fuel Water Separator Check Valve O-Ring Kit',
#  'Fuel Water Separator Drain Valve',
#  'Fuse Block',
#  'Fuse Box - High Voltage',
#  'Fuse Box Bolt',
#  'Fuse Box Cover Clip',
#  'Fuse Kit',
#  'GPS Navigation Control Module Clip',
#  'Glove Box Clip',
#  'Glove Box Door',
#  'Glove Box Door Clip',
#  'Glove Box Handle',
#  ...]

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.get(input_.loc[a, 'Type Url'],
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(10, 10))
        
        if resp.status_code == 200:
            break
    except:
        continue

resp
# Out:
# 1
# 2
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from lxml import etree

soup = BeautifulSoup(resp.text, 'lxml')
html = etree.HTML(str(soup))

with open('./page.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Dorman Products - Search Results
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="-1" http-equiv="expires"/>
#   <meta content="Dorman gives auto repair professionals and vehicle owners greater freedom to fix cars and trucks by focusing on solutions first." name="description"/>
#   <meta content="auto parts, car parts, automotive parts, aftermarket car parts, automotive repair parts, window regulator, control arm, door handle, fluid reservoir, remanufactured auto parts, intake manifold, exhaust manifold, diesel automotive part, instrument cluster, automotive electronic parts, clock spring, engine car part, chassis, car part, car mirror, transmission parts" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="no" name="apple-mobile-web-app-capable"/>
#   <!--[if lt IE 9]>
#       <script src="/scripts/html5shiv.js"></script>
#     <![endif]-->
#   <!--[if IE]>
#   		<script src="/scripts/html5shiv.js"></script>
# 	<![endif]-->
#   <link href="/content/webfonts.min.css" rel="stylesheet"/>
#   <link href="/content/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/content/bootstrap-dialog.min.css" rel="stylesheet"/>
#   <link href="/content/style.css?d=20220208" rel="stylesheet"/>
#   <link href="/content/fontello.min.css" rel="stylesheet"/>
#   <link href="/content/yamm.css" rel="stylesheet"/>
#   <link href="/content/non_login.css?d=20190905" id="nonloginStyle" rel="stylesheet"/>
#   <!--[if lte IE 9]>
#         <link href="/content/animations-ie-fix.css" rel="stylesheet" type="text/css">
#     <![endif]-->
#   <link href="/content/sliderstyle-3.min.css" rel="stylesheet"/>
#   <link href="/content/animations.min.css" rel="stylesheet"/>
#   <link href="/content/off-canvas.min.css" rel="stylesheet"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//static.dormanproducts.com/images/website/banner2/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <script src="/scripts/head.min.js?d=20190905" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#     head.load({ stringresources: "/scripts/StringResources.js?d=20190905" },
#         { jquery: "/scripts/jquery.min.js?d=20190905" },
#         { bootstrap: "/scripts/bootstrap.min.js?d=20190905" },
#         { dialog: "/scripts/bootstrap-dialog.min.js?d=20190905" },
#         { validator: "/scripts/validator.min.js?d=20190905" },
#         { modernizr: "/scripts/modernizr.min.js?d=20190905" },
#         { isotope: "/scripts/isotope.pkgd.min.js?d=20190905" },
#         { bootstrapdropdown: "/scripts/jquery.bootstrap-dropdown-hover.min.js?d=20190905" },
#         { dormanscript: "/scripts/dorman-scripts.js?d=20210709" },
#         { slider: "/scripts/slidermain.js?d=20190905" },
#         { css3animate: "/scripts/css3-animate-it.js?d=20190905" },
#         { jqcustom: "/scripts/jquery.custom.js?d=20190905" },
#         { typeahead: "/scripts/bootstrap3-typeahead.min.js?d=20190905" },
#         { checkform: "/scripts/CheckForm.js?d=20220208" },
#         { ie10viewport: "/scripts/ie10-viewport-bug-workaround.js?d=20190905" },
#         { eventtracking: "/scripts/eventTracking.js?d=20190905" },
#         { recentActivities: "/scripts/recentactivites.js?d=20190905" });
#     //-->
#   </script>
#   <script src="/scripts/autodetect.js?d=20190905" type="text/javascript">
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-5JGR3XL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return; n = f.fbq = function () {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#             n.queue = []; t = b.createElement(e); t.async = !0;
#             t.src = v; s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '362412311106864');
#         fbq('track', 'PageView');
#   </script>
#   <!-- End Facebook Pixel Code -->
#   <!-- Microsoft ad Conversion Tracking -->
#   <script>
#    (function (w, d, t, r, u) {
#             var f, n, i; w[u] = w[u] || [], f = function () {
#                 var o = { ti: "137031075" }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad")
#             }, n = d.createElement(t), n.src = r, n.async = 1, n.onload = n.onreadystatechange = function () {
#                 var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null)
#             }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i)
#         })(window, document, "script", " //bat.bing.com/bat.js", "uetq");
#   </script>
#   <!-- End Microsoft ad Conversion Tracking -->
#   <link href="/content/review-styles.css" rel="stylesheet"/>
#   <script>
#    var __uzdbm_1 = "22fec22f-a062-4782-994b-db736c617a08";var __uzdbm_2 = "NGM5NzVkZjAtYnUydi00NGM1LWE0MzEtNDFjZDBhMDY3ZTNhJDM2LjEwNi41NC4y";var __uzdbm_3 = "7f6000a4cdc81c-9a0a-4aad-bf03-8af380bad29417230109615270-eb298435bb8e2b0c10";var __uzdbm_4 = "false";var __uzdbm_5 = "uzmx";var __uzdbm_6 = "7f90008e64e485-7d9e-42d0-87f3-1bd40937039a1-17230109615270-8cd0279ee989e53010";var __uzdbm_7 = "dormanproducts.com";
#   </script>
#   <script>
#    (function (w, d, e, u, c, g, a, b) {     w["SSJSConnectorObj"] = w["SSJSConnectorObj"] || {       ss_cid: c,       domain_info: "auto",     };     w[g] = function (i, j) {       w["SSJSConnectorObj"][i] = j;     };     a = d.createElement(e);     a.async = true;     if (       navigator.userAgent.indexOf('MSIE') !== -1 ||       navigator.appVersion.indexOf('Trident/') > -1     ) {       u = u.replace("/advanced/", "/advanced/ie/");     }     a.src = u;     b = d.getElementsByTagName(e)[0];     b.parentNode.insertBefore(a, b);   })(     window, document, "script", "https://www.dormanproducts.com/18f5227b-e27b-445a-a53f-f845fbe69b40/stormcaster.js", "bu2x", "ssConf"   );   ssConf("c1", "https://www.dormanproducts.com");   ssConf("c3", "c99a4269-161c-4242-a3f0-28d44fa6ce24");   ssConf("au", "dormanproducts.com");   ssConf("cu", "validate.perfdrive.com, ssc");
#   </script>
#  </head>
#  <body data-spy="scroll">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5JGR3XL" style="display: none; visibility: hidden" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=362412311106864&amp;ev=PageView&amp;noscript=1" style="display: none" width="1"/>
#   </noscript>
#   <input id="WebsiteSkinID" name="WebsiteSkinID" type="hidden" value="1"/>
#   <input id="IsMobile" name="IsMobile" type="hidden" value="0"/>
#   <input id="hideskin" name="hideskin" type="hidden" value="0"/>
#   <input id="sitewebsubpath" name="sitewebsubpath" type="hidden" value="/"/>
#   <input id="IsLoggedInHidden" name="IsLoggedInHidden" type="hidden" value="0"/>
#   <input id="IsEnglishLinkActiveHidden" name="IsEnglishLinkActiveHidden" type="hidden" value="Y"/>
#   <input id="IsESPLinkActiveHidden" name="IsESPLinkActiveHidden" type="hidden" value="Y"/>
#   <input id="englishurlHidden" name="englishurlHidden" type="hidden" value="www.dormanproducts.com"/>
#   <input id="spanishurlHidden" name="spanishurlHidden" type="hidden" value="www.dormanproducts.es"/>
#   <input id="browserLanguage" name="browserLanguage" type="hidden"/>
#   <input id="AccountNumber" name="AccountNumber" type="hidden"/>
#   <input id="SearchIndexID" name="SearchIndexID" type="hidden" value="4"/>
#   <input id="SearchResultPage" name="SearchResultPage" type="hidden" value="gsearch.aspx"/>
#   <input id="showWTBMap" name="showWTBMap" type="hidden"/>
#   <input id="showWTBError" name="showWTBError" type="hidden"/>
#   <input id="uiCultureLanguage" name="uiCultureLanguage" type="hidden" value="en-US"/>
#   <input id="WTBUrlHolder" name="WTBUrlHolder" type="hidden" value="https://wtbmap.dormanproducts.com?d=1"/>
#   <input id="WhereToBuyMarketingParams" name="WhereToBuyMarketingParams" type="hidden" value="?amp;wmode=opaque&amp;partNumber=header&amp;brand=header&amp;specialOrder=0&amp;language="/>
#   <!-- feedback/questions details -->
#   <!-- login maintenace -->
#   <!-- login webbanner -->
#   <!--Redesign Header-->
#   <!-- top banner navigation -->
#   <header class="topbannerbg yamm" id="header">
#    <div class="container">
#     <nav class="row">
#      <ul class="topbannernav topnav">
#       <!-- language selection -->
#       <li class="topbanner-link pull-left border-right border-left language-selection">
#        <div aria-expanded="false" class="topbanner-btn" data-toggle="dropdown" role="button">
#         <span aria-hidden="true" class="glyphicon glyphicon-globe">
#         </span>
#         <span class="hidden-xs hidden-sm hidden-md">
#          Language:
#          <span class="font-wht">
#           English
#           <span aria-hidden="true" class="icon-down-open-1">
#           </span>
#          </span>
#         </span>
#        </div>
#        <ul class="topbanner-menu dropdown-menu">
#         <script type="text/javascript">
#          defaultLanguage_ENG();
#         </script>
#        </ul>
#       </li>
#      </ul>
#      <ul class="topbannernav topnav topnav-right">
#       <!-- show hide price -->
#       <!-- new product details -->
#       <li class="topbanner-link border-left">
#        <a href="/Pages/forms/ideas.aspx">
#         <div class="topbanner-btn dorman" data-target="#newproductModal" data-toggle="modal">
#          <span aria-hidden="true" class="icon-lamp">
#          </span>
#          <span class="hidden-xs hidden-sm">
#           New Product Idea
#          </span>
#         </div>
#        </a>
#       </li>
#       <!-- be the first to know -->
#       <li class="btftk-dropdown topbanner-link border-left">
#        <a href="/Pages/forms/btftk.aspx">
#         <div aria-controls="topBTFTK" aria-expanded="false" class="topbanner-btn" data-toggle="modal" role="button">
#          <span aria-hidden="true" class="icon-mail-alt">
#          </span>
#          <span class="hidden-xs hidden-sm">
#           Email Newsletters
#          </span>
#         </div>
#        </a>
#       </li>
#       <!-- Live Chat -->
#       <li class="topbanner-link border-left">
#        <div class="topbanner-btn" id="hd_chat_link" onclick="return openMessenger('Header', 'Header Navigation');">
#        </div>
#       </li>
#       <!-- recent activities -->
#       <li class="topbanner-link border-left">
#        <div class="topbanner-btn" id="divMenuRecentActivities" onclick="showRecentActiviesPopupDialog('link_click');">
#         <span aria-hidden="true" class="glyphicon glyphicon-time">
#         </span>
#         <span class="hidden-xs hidden-sm">
#          Recent Activities
#         </span>
#        </div>
#       </li>
#       <!-- distributor login -->
#       <li class="dropdown topbanner-link border-left border-right" id="dist-login">
#        <div class="topbanner-btn" onclick="return trackRedirectToPage('signin.aspx','link_click','Login');">
#         <span aria-hidden="true" class="glyphicon glyphicon-cog">
#         </span>
#         <span class="hidden-xs">
#          Login
#         </span>
#        </div>
#       </li>
#       <!-- distributor login success -->
#       <li class="dropdown megamenu-fw topbanner-link border-left border-right bg-orange dist-login-link" id="dist-login-success">
#        <div aria-expanded="false" class="topbanner-btn" data-toggle="dropdown" role="button">
#         <span class="hidden-xs">
#          <span aria-hidden="true" class="glyphicon glyphicon-cog">
#          </span>
#          :
#         </span>
#         <span aria-hidden="true" class="icon-basket-1">
#         </span>
#         <span class="hidden-xxs hidden-xxxs" id="cart-total">
#          [] Items
#                                 |
#          <strong>
#           $
#          </strong>
#         </span>
#         <span aria-hidden="true" class="icon-down-open-1">
#         </span>
#        </div>
#        <ul class="collapse dropdown-menu topbanner-megamenu dist-logged-menu" id="topDistSuccess">
#         <li>
#          <div class="yamm-content">
#           <div class="row topbanner-submenu">
#            <div class="col-xs-6 col-xxs-12">
#             <h5 class="dist-welcome">
#              Welcome:
#             </h5>
#             <ul>
#              <li class="cust_name">
#               <h4>
#                <a href="/account.aspx">
#                </a>
#               </h4>
#              </li>
#              <li>
#               <a href="#">
#                <div class="cust_phone">
#                 Customer Service:
#                </div>
#                <div class="cust_phone">
#                </div>
#               </a>
#              </li>
#              <li>
#               <a href="/Pages/products/cores/returns.aspx">
#                Core Policy &amp; Procedures
#               </a>
#              </li>
#              <li id="menuSubAccountMaintenance">
#               <a href="/dp_DCAdministration.aspx">
#                Sub-Account Maintenance
#               </a>
#              </li>
#              <li id="menuRegAccMaintenance">
#               <a href="/dp_RegAccAdministration.aspx">
#                Regional Account Maintenance
#               </a>
#              </li>
#              <li id="menuProductFeed">
#               <a href="/dp_ProductFeed.aspx">
#                Product Feed
#               </a>
#              </li>
#              <li id="menuWhereToBuyMaintenance">
#               <a href="/dp_WhereToBuyAdministration.aspx">
#                Where To Buy Maintenance
#               </a>
#              </li>
#              <li id="menuFKey">
#               <a href="/FKey">
#                Dorman Products F-Key
#               </a>
#              </li>
#             </ul>
#             <hr class="topbanner-ruler hidden-xxs"/>
#             <div class="dist-map-area" id="divEMRP">
#              <h5>
#               Electronic Minimum Advertised Price Policy (eMAP)
#              </h5>
#              <ul>
#               <li>
#                <a href="https://static.dormanproducts.com/document/corporate/Electronic-Minimum-Advertised-Price-Policy.pdf" target="_blank">
#                 eMAP Policy
#                </a>
#               </li>
#              </ul>
#             </div>
#             <button class="btn btn-orange" onclick="window.location='/signout.aspx';">
#              Log out
#             </button>
#            </div>
#            <div class="col-xs-6 col-xxs-12">
#             <div class="dist-shopcart">
#              <h4>
#               Shopping Cart:
#              </h4>
#              <h5>
#               <span class="dist-shopcart-cat">
#                Items in Cart:
#               </span>
#              </h5>
#              <h5>
#               <span class="dist-shopcart-cat">
#                Total in Cart:
#               </span>
#               $
#              </h5>
#              <button class="btn btn-orange" onclick="window.location='/shoppingcart.aspx';">
#               Checkout
#              </button>
#             </div>
#             <hr class="topbanner-ruler hidden-xxs"/>
#             <ul>
#              <li>
#               <a href="/orderhistorysearch.aspx">
#                Order History
#               </a>
#              </li>
#              <li>
#               <a href="/expressorderform.aspx">
#                Order Form
#               </a>
#              </li>
#              <li id="menuUploadOrders">
#               <a href="/dp_UploadOrders.aspx">
#                Upload Order
#               </a>
#              </li>
#              <li id="menuUpdateMenus">
#               <a href="/dp_Menus.aspx">
#                Update Menus
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </nav>
#    </div>
#   </header>
#   <!-- top banner navigation end -->
#   <!-- menu -->
#   <div class="nav-wrapper" id="navWrap">
#    <div class="container">
#     <nav class="navbar row yamm">
#      <a class="navbar-brand" href="/">
#       <img alt="Dorman Products" class="navbar-logo img-responsive" src="//static.dormanproducts.com/images/website/homepage/dorman_logo.gif"/>
#      </a>
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#      <div class="collapse right navbar-collapse navbar-ex1-collapse">
#       <div class="cl-effect-12">
#        <ul class="nav navbar-nav pull-right">
#         <!--- what's new --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           What's New
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="whats-new">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                New Top Parts
#               </h4>
#               <div class="navbar-sublinks" id="divNewTopParts">
#                <li>
#                 <a href="/p-153282-615-451.aspx">
#                  Engine Intake Manifold
#                 </a>
#                </li>
#                <li>
#                 <a href="/p-153240-911-932.aspx">
#                  Intake Manifold Runner Control Valve
#                 </a>
#                </li>
#                <li>
#                 <a href="/p-153252-926-493.aspx">
#                  Roof Mounted GPS Antenna
#                 </a>
#                </li>
#                <li>
#                 <a href="/p-153178-956-007.aspx">
#                  Keyless Entry Keypad With Trim
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/document/web/must-see-solutions_july-2024.pdf" target="_blank">
#                  View All New Products
#                 </a>
#                </li>
#               </div>
#               <h4>
#                New Product Announcements
#               </h4>
#               <div class="navbar-sublinks" id="divNewProductAnnouncements">
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#aug2024">
#                  August
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#jul2024">
#                  July
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#jun2024">
#                  June
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx#may2024">
#                  May
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/npas/dorman.aspx">
#                  View All Announcements
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                OE FIX Products
#               </h4>
#               <div class="navbar-sublinks" id="divOEFixProducts">
#                <li>
#                 <a href="/pages/products/stories/power-steering.aspx">
#                  Power Steering Pumps
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/vvt-solenoid-sprocket.aspx">
#                  VVT Solenoids
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/egt-bung-repair.aspx">
#                  EGT Sensor Bung Repair Kit
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/stories/intake-manifold.aspx">
#                  Intake Manifold
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/oe-fix/index.aspx">
#                  Learn more about our signature innovations
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Catalogs &amp; Guides
#               </h4>
#               <div class="navbar-sublinks" id="divCatalogsAndGuides">
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v5/index.html" target="_blank">
#                  OE FIX Guide - Volume 5
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v4/index.html" target="_blank">
#                  OE FIX Guide - Volume 4
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/new-solutions-catalog/index.html" target="_blank">
#                  New Solutions Catalog
#                 </a>
#                </li>
#                <li>
#                 <a href="//static.dormanproducts.com/flipbook/dorman/oe-fix-guide-v3/index.html" target="_blank">
#                  OE FIX Guide - Volume 3
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/resources/catalogs/dorman.aspx">
#                  View All Catalog &amp; Guides
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Top Part Video of the Month
#             </h4>
#             <a href="/pages/videos/installs/index.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/top-part-video-42454.jpg"/>
#             </a>
#             <h5>
#              Have a Jeep Grand Cherokee or Dodge Durango with a missing headlight access door?
#             </h5>
#             <p>
#              This easy-to-install Dorman OE FIX™ headlight access door allows the replacement of just the door(s) not the entire wheel well liner.
#             </p>
#             <a class="btn btn-orange" href="/pages/videos/installs/index.aspx">
#              View Video
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <!--- mega menu --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Products
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="product">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                Product Categories
#               </h4>
#               <div class="navbar-sublinks" id="divProductCategories">
#                <li>
#                 <a href="/Pages/products/categories/body.aspx">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/steering.aspx">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/undercar.aspx">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/underhood.aspx">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/categories/hardware.aspx">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.dormanhdsolutions.com" target="_blank">
#                  Heavy Duty
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Featured Products
#               </h4>
#               <div class="navbar-sublinks" id="divFeaturedProducts">
#                <li>
#                 <a href="/Pages/products/chrome-wheel-hardware/index.aspx">
#                  Chrome Wheel Hardware
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/drive-shafts/index.aspx">
#                  Drive Shafts
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/intake-manifolds/index.aspx">
#                  Intake Manifolds
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/steering-shafts/index.aspx">
#                  Steering Shafts
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/window-regulators/index.aspx">
#                  Window Regulators
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                Product Info
#               </h4>
#               <div class="navbar-sublinks" id="divProductInfo">
#                <li>
#                 <a href="/Pages/resources/catalogs/dorman.aspx">
#                  Catalogs
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/web/patents.aspx">
#                  Patents
#                 </a>
#                </li>
#                <li>
#                 <a href="/install.aspx">
#                  Install Instructions
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/cores/returns.aspx">
#                  Core Returns
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#quality">
#                  Quality
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#recalls">
#                  Recalls
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/products/warranty/index.aspx#warranty">
#                  Warranty
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/web/terms-of-sale.aspx">
#                  Terms &amp; Condition of Sale
#                 </a>
#                </li>
#               </div>
#               <h4>
#                Product Training
#               </h4>
#               <div class="navbar-sublinks" id="divProductTraining">
#                <li>
#                 <a href="/pages/training/index.aspx" target="_blank">
#                  Dorman Training Center
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Product of the Month
#             </h4>
#             <a href="/p--615-451.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/product-of-the-month-615-451.jpg"/>
#             </a>
#             <h5>
#              Certain Volkswagen and Audi vehicles are fitted with an intake manifold runner system that's prone to failure.
#             </h5>
#             <p>
#              This OE FIX™ manifold is designed to replace the original unit, but features a linkage made of durable cast aluminum for years of long service.
#             </p>
#             <a class="btn btn-orange" href="/p--615-451.aspx">
#              View Details
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <!--- mega menu end --->
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Videos
#          </a>
#          <ul class="nav-megamenu dropdown-menu">
#           <div class="yamm-content">
#            <div class="col-sm-8 col-md-6">
#             <div class="row">
#              <div class="col-sm-6">
#               <h4>
#                Highlighted Installation
#               </h4>
#               <div class="navbar-sublinks" id="divVideoHighlightedInstallation">
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#body">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#electronics">
#                  Electronics
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#steering">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#undercar">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#underhood">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx#hardware">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/installs/index.aspx">
#                  View All Install Videos
#                 </a>
#                </li>
#               </div>
#              </div>
#              <div class="col-sm-6">
#               <h4>
#                Highlighted Overview
#               </h4>
#               <div class="navbar-sublinks" id="divVideoHighlightedOverview">
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#body">
#                  Body
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#electronics">
#                  Electronics
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#steering">
#                  Steering &amp; Suspension
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#undercar">
#                  Undercar
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#underhood">
#                  Underhood
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#hardware">
#                  Hardware &amp; Accessories
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#hd">
#                  Heavy Duty
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx#oefix">
#                  OE FIX
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/videos/info/index.aspx">
#                  View All Info Videos
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#             <div class="row hidden-xs">
#              <div class="col-sm-11 mega-callout" id="divVideoViewAll">
#               <div class="col-sm-12">
#                <h4>
#                 Dorman Products offers hundreds of installation and informational videos.
#                </h4>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="nav-featured col-sm-4 col-md-6 hidden-xs">
#             <h4>
#              Featured Video
#             </h4>
#             <a href="/pages/videos/info/index.aspx">
#              <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/marketing/homepage/featured-video-drive-shaft.jpg"/>
#             </a>
#             <h5>
#              The highest quality end-to-end, the fastest delivery coast-to-coast.
#             </h5>
#             <p>
#              We know what it takes to engineer, manufacture, test and deliver the drive shaft you need, backed by the service your business deserves.
#             </p>
#             <a class="btn btn-orange" href="/pages/videos/info/index.aspx">
#              View Video
#             </a>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li id="liMenuWhereToBuy">
#          <a href="/Pages/wheretobuy/dorman.aspx">
#           Where to Buy
#          </a>
#         </li>
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           Contact
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="Ul1">
#           <div class="yamm-content">
#            <div class="nav-featured col-sm-7 hidden-xs">
#             <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/website/images/nav-warehouse.jpg" style="margin-top: 30px;"/>
#            </div>
#            <div class="col-sm-5">
#             <div class="row">
#              <div class="col-sm-12">
#               <h4 class="hidden-xs">
#                Contact Us
#               </h4>
#               <div class="navbar-sublinks" id="divContactUs">
#                <li>
#                 <a href="/Pages/forms/customer.aspx">
#                  Customer Service
#                 </a>
#                </li>
#                <li>
#                 <a class="hidden" href="/Pages/products/cores/purchases.aspx">
#                  Core Purchases
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/investor-resources/investor-contacts/default.aspx" target="_blank">
#                  Investor Relations
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/ideas.aspx">
#                  New Product Ideas
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/sales.aspx">
#                  Sales
#                 </a>
#                </li>
#                <li>
#                 <a href="/Pages/forms/support.aspx">
#                  Technical Support
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li class="dropdown yamm-fw">
#          <a aria-expanded="false" data-toggle="dropdown" href="#" role="button">
#           <div class="selected-marker hidden-xs">
#           </div>
#           About
#          </a>
#          <ul class="nav-megamenu dropdown-menu" id="Ul2">
#           <div class="yamm-content">
#            <div class="nav-featured col-sm-7 hidden-xs">
#             <img class="img-responsive thumbnail" src="//static.dormanproducts.com/images/website/images/nav-building.jpg" style="margin-top: 30px;"/>
#            </div>
#            <div class="col-sm-5">
#             <div class="row">
#              <div class="col-sm-12">
#               <h4 class="hidden-xs">
#                About Dorman Products
#               </h4>
#               <div class="navbar-sublinks" id="divAboutDormanProducts">
#                <li>
#                 <a href="/pages/corporate/about.aspx">
#                  About Us
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/tour/index.html" target="_blank">
#                  Virtual Tour
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/products/ld-b2b/index.aspx">
#                  5D Partnership Model
#                 </a>
#                </li>
#                <li>
#                 <a href="https://jobs.dormanproducts.com/" target="_blank">
#                  Careers
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/home/default.aspx" target="_blank">
#                  Investor Relations
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/corporate-governance/esg/default.aspx" target="_blank">
#                  Environmental, Social &amp; Governance
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/corporate-governance/executive-management/default.aspx" target="_blank">
#                  Executive Team
#                 </a>
#                </li>
#                <li>
#                 <a href="https://investors.dormanproducts.com/news/default.aspx" target="_blank">
#                  Press Releases
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/corporate/suppliers.aspx">
#                  Suppliers
#                 </a>
#                </li>
#                <li>
#                 <a href="/pages/corporate/emap.aspx">
#                  eMAP Policy
#                 </a>
#                </li>
#                <li>
#                 <a href="https://shoppress.dormanproducts.com" target="_blank">
#                  Shop Press
#                 </a>
#                </li>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </ul>
#         </li>
#         <li class="nav-bar-no-rollover hidden-sm">
#          <div class="navbar-social">
#           <a href="https://www.facebook.com/dormanproducts" target="_blank">
#            <span aria-hidden="true" class="icon-facebook">
#            </span>
#           </a>
#           <a href="https://www.instagram.com/dormanproducts/" target="_blank">
#            <span aria-hidden="true" class="icon-instagram">
#            </span>
#           </a>
#           <a href="https://www.youtube.com/dormanproducts" target="_blank">
#            <span aria-hidden="true" class="icon-youtube-play">
#            </span>
#           </a>
#           <a href="https://www.linkedin.com/company/dorman-products" target="_blank">
#            <span aria-hidden="true" class="icon-linkedin">
#            </span>
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <!-- menu end -->
#   <!-- searchbar start -->
#   <div class="searchbar-wrap" id="searchWrap">
#    <div class="container">
#     <div class="searchbar row">
#      <div class="searchbar-header">
#       <h4>
#        Search
#        <span class="hidden-xxs">
#         Products
#        </span>
#        <a class="adv-search" href="/hcategory.aspx">
#         <span class="glyphicon glyphicon-eye-open" style="margin-right: 3px;">
#         </span>
#         VISUAL
#         <span class="hidden-xxxs">
#          SEARCH
#         </span>
#        </a>
#       </h4>
#      </div>
#      <div class="searchbar-toggle" data-target="#searchbar-ex1-collapse" data-toggle="collapse">
#       <h4>
#        Search
#        <span class="hidden-search-prod">
#         Products
#        </span>
#        <a class="adv-search" href="/hcategory.aspx">
#         <span class="glyphicon glyphicon-eye-open" style="margin-right: 3px;">
#         </span>
#         VISUAL
#         <span class="hidden-xxxs">
#          SEARCH
#         </span>
#        </a>
#       </h4>
#      </div>
#     </div>
#     <div class="searchnav row collapse searchbar-collapse" id="searchbar-ex1-collapse">
#      <div class="col-sm-12">
#       <div class="col-sm-3 search-fields" id="search-ymm">
#        <div class="form-group input-group">
#         <select class="form-control" data-placement="bottom" data-toggle="tooltip" id="SelectYear" name="SelectYear" onchange="showApplicationPopupDialog();" title="Year/Make/Model">
#          <option selected="selected" value="0">
#           Year/Make/Model
#          </option>
#          <option value="2025">
#           2025
#          </option>
#          <option value="2024">
#           2024
#          </option>
#          <option value="2023">
#           2023
#          </option>
#          <option value="2022">
#           2022
#          </option>
#          <option value="2021">
#           2021
#          </option>
#          <option value="2020">
#           2020
#          </option>
#          <option value="2019">
#           2019
#          </option>
#          <option value="2018">
#           2018
#          </option>
#          <option value="2017">
#           2017
#          </option>
#          <option value="2016">
#           2016
#          </option>
#          <option value="2015">
#           2015
#          </option>
#          <option value="2014">
#           2014
#          </option>
#          <option value="2013">
#           2013
#          </option>
#          <option value="2012">
#           2012
#          </option>
#          <option value="2011">
#           2011
#          </option>
#          <option value="2010">
#           2010
#          </option>
#          <option value="2009">
#           2009
#          </option>
#          <option value="2008">
#           2008
#          </option>
#          <option value="2007">
#           2007
#          </option>
#          <option value="2006">
#           2006
#          </option>
#          <option value="2005">
#           2005
#          </option>
#          <option value="2004">
#           2004
#          </option>
#          <option value="2003">
#           2003
#          </option>
#          <option value="2002">
#           2002
#          </option>
#          <option value="2001">
#           2001
#          </option>
#          <option value="2000">
#           2000
#          </option>
#          <option value="1999">
#           1999
#          </option>
#          <option value="1998">
#           1998
#          </option>
#          <option value="1997">
#           1997
#          </option>
#          <option value="1996">
#           1996
#          </option>
#          <option value="1995">
#           1995
#          </option>
#          <option value="1994">
#           1994
#          </option>
#          <option value="1993">
#           1993
#          </option>
#          <option value="1992">
#           1992
#          </option>
#          <option value="1991">
#           1991
#          </option>
#          <option value="1990">
#           1990
#          </option>
#          <option value="1989">
#           1989
#          </option>
#          <option value="1988">
#           1988
#          </option>
#          <option value="1987">
#           1987
#          </option>
#          <option value="1986">
#           1986
#          </option>
#          <option value="1985">
#           1985
#          </option>
#          <option value="1984">
#           1984
#          </option>
#          <option value="1983">
#           1983
#          </option>
#          <option value="1982">
#           1982
#          </option>
#          <option value="1981">
#           1981
#          </option>
#          <option value="1980">
#           1980
#          </option>
#          <option value="1979">
#           1979
#          </option>
#          <option value="1978">
#           1978
#          </option>
#          <option value="1977">
#           1977
#          </option>
#          <option value="1976">
#           1976
#          </option>
#          <option value="1975">
#           1975
#          </option>
#          <option value="1974">
#           1974
#          </option>
#          <option value="1973">
#           1973
#          </option>
#          <option value="1972">
#           1972
#          </option>
#          <option value="1971">
#           1971
#          </option>
#          <option value="1970">
#           1970
#          </option>
#          <option value="1969">
#           1969
#          </option>
#          <option value="1968">
#           1968
#          </option>
#          <option value="1967">
#           1967
#          </option>
#          <option value="1966">
#           1966
#          </option>
#          <option value="1965">
#           1965
#          </option>
#          <option value="1964">
#           1964
#          </option>
#          <option value="1963">
#           1963
#          </option>
#          <option value="1962">
#           1962
#          </option>
#          <option value="1961">
#           1961
#          </option>
#          <option value="1960">
#           1960
#          </option>
#          <option value="1959">
#           1959
#          </option>
#          <option value="1958">
#           1958
#          </option>
#          <option value="1957">
#           1957
#          </option>
#          <option value="1956">
#           1956
#          </option>
#          <option value="1955">
#           1955
#          </option>
#          <option value="1954">
#           1954
#          </option>
#          <option value="1953">
#           1953
#          </option>
#          <option value="1952">
#           1952
#          </option>
#          <option value="1951">
#           1951
#          </option>
#          <option value="1950">
#           1950
#          </option>
#          <option value="1949">
#           1949
#          </option>
#          <option value="1948">
#           1948
#          </option>
#          <option value="1947">
#           1947
#          </option>
#          <option value="1946">
#           1946
#          </option>
#          <option value="1945">
#           1945
#          </option>
#          <option value="1944">
#           1944
#          </option>
#          <option value="1943">
#           1943
#          </option>
#          <option value="1942">
#           1942
#          </option>
#          <option value="1941">
#           1941
#          </option>
#          <option value="1940">
#           1940
#          </option>
#          <option value="1939">
#           1939
#          </option>
#          <option value="1938">
#           1938
#          </option>
#          <option value="1937">
#           1937
#          </option>
#          <option value="1936">
#           1936
#          </option>
#          <option value="1935">
#           1935
#          </option>
#          <option value="1934">
#           1934
#          </option>
#          <option value="1933">
#           1933
#          </option>
#          <option value="1932">
#           1932
#          </option>
#          <option value="1931">
#           1931
#          </option>
#          <option value="1930">
#           1930
#          </option>
#          <option value="1929">
#           1929
#          </option>
#          <option value="1928">
#           1928
#          </option>
#          <option value="1925">
#           1925
#          </option>
#          <option value="1923">
#           1923
#          </option>
#          <option value="1922">
#           1922
#          </option>
#          <option value="1915">
#           1915
#          </option>
#         </select>
#        </div>
#       </div>
#       <div class="col-sm-3 search-fields" id="search-keyword">
#        <form action="gsearch.aspx" id="keywordForm" method="get" name="keywordForm">
#         <input name="type" type="hidden" value="keyword"/>
# ...
#            <input class="btn btn-darkgrey searchAlertbtn centered" onclick="feedback.productFoundFeedbackList.onSubmitClicked('productFoundFeedback')" type="button" value="Submit"/>
#            <input id="productFoundFeedback_searchType" name="productFoundFeedback$searchType" type="hidden" value="keyword"/>
#            <input id="productFoundFeedback_searchKeyword" name="productFoundFeedback$searchKeyword" type="hidden" value=" Air Suspension Line Repair Kit"/>
#            <input id="productFoundFeedback_searchYear" name="productFoundFeedback$searchYear" type="hidden"/>
#            <input id="productFoundFeedback_searchMake" name="productFoundFeedback$searchMake" type="hidden"/>
#            <input id="productFoundFeedback_searchModel" name="productFoundFeedback$searchModel" type="hidden"/>
#            <input id="productFoundFeedback_searchPartType" name="productFoundFeedback$searchPartType" type="hidden"/>
#            <input id="productFoundFeedback_searchPosition" name="productFoundFeedback$searchPosition" type="hidden"/>
#            <input id="productFoundFeedback_searchConstraints" name="productFoundFeedback$searchConstraints" type="hidden"/>
#           </div>
#          </div>
#         </div>
#         <div class="alert alert-general" id="productFoundFeedbackResult" role="alert" style="display: none;">
#         </div>
#        </div>
#       </div>
#       <!-- Modal Save Search -->
#       <div aria-labelledby="windowTitleLabel" class="modal fade" id="SaveSearchDialogModal" role="dialog" tabindex="-1">
#        <div class="modal-dialog">
#         <div class="modal-content">
#          <div class="modal-header">
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#           <h4 class="modal-title">
#            <span aria-hidden="true" class="glyphicon glyphicon-time">
#            </span>
#            <span id="SaveSeachDialogLabel">
#             Name Your Search
#            </span>
#           </h4>
#          </div>
#          <div class="modal-body iframe">
#           <div id="SaveSearchDialogLoading" style="display: block;">
#            <div class="progress" style="height: 25px;">
#             <div class="progress-bar progress-bar-striped active" style="width: 100%">
#             </div>
#            </div>
#           </div>
#           <iframe class="embed-responsive-item" id="SaveSearchDialogIFrame" style="margin: 0; width: 100%; height: 100%; border: none; overflow: hidden;">
#           </iframe>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="container">
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Modal Shipping Estimate -->
#     <div aria-labelledby="windowTitleLabel" class="modal fade" id="shippingestimateModal" role="dialog" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-header">
#         <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#          <span aria-hidden="true">
#           ×
#          </span>
#         </button>
#         <h4 class="modal-title">
#          <span aria-hidden="true" class="glyphicon glyphicon-time">
#          </span>
#          <span id="shippingestimateDialogLabel">
#           Shipping Estimate
#          </span>
#         </h4>
#        </div>
#        <div class="modal-body iframe">
#         <div id="shippingestimateLoading" style="display:block;">
#          <div class="progress" style="height:25px;">
#           <div class="progress-bar progress-bar-striped active" style="width:100%">
#           </div>
#          </div>
#         </div>
#         <iframe class="embed-responsive-item" id="shippingestimateIFrame" style="border:0px; width:100%; height: 100%;display:none;">
#         </iframe>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Modal Save Search -->
#     <div aria-labelledby="windowTitleLabel" class="modal" data-backdrop="static" data-keyboard="false" id="SaveSpecialOrderQuestionsModal" role="dialog" style="width: 100%; height: 100%;" tabindex="-1">
#      <div class="modal-dialog" style="width: 90%; height: 90%; margin: 0 auto; padding: 20px;">
#       <div class="modal-content" style="height: 100%">
#        <div class="modal-header">
#         <button aria-label="Close" class="close" data-dismiss="modal" id="PopupClose" type="button">
#          <span aria-hidden="true">
#           ×
#          </span>
#         </button>
#         <h4 class="modal-title">
#          <span aria-hidden="true" class="glyphicon glyphicon-time">
#          </span>
#          <span id="SaveSeachDialogLabel">
#           Special Order Questions
#          </span>
#         </h4>
#        </div>
#        <div class="modal-body embed-responsive productFrames iframe" style="height: 90%">
#         <iframe class="embed-responsive-item" id="SaveSpecialOrderQuestionsIFrame" style="overflow-y: auto; width: 100%; border: none; position: absolute;">
#         </iframe>
#        </div>
#       </div>
#      </div>
#     </div>
#     <input id="hdnCtrlId" type="hidden"/>
#     <script type="text/javascript">
#      //checkboxes
#             if (document.getElementById('SelectedConstraintValueLiteral') != null) {
#                 var array = document.getElementById('SelectedConstraintValueLiteral').value.split(',');
#                 for (var i = 0; i < array.length; i++) {
#                     if (document.getElementById('Dynamic1_' + array[i]) != null) {
#                         document.getElementById('Dynamic1_' + array[i]).checked = true;
#                     }
#                 }
#             }
#     </script>
#     <input id="hdnVICURL" name="hdnVICURL" type="hidden" value="http://gcommercebridge-vic.cloudapp.net/search/search.html"/>
#     <div id="loadingoverlay" style="display: none">
#      <img alt="Loading" id="loadingImage" src="//static.dormanproducts.com/images/website/images/ajaxloader.gif"/>
#      <br/>
#      Loading...
#     </div>
#    </form>
#    <!-- CONTENTS END -->
#   </div>
#   <!-- footer start -->
#   <footer class="footer" id="footer">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-3 col-sm-4 col-xs-6">
#       <div class="footerheadline">
#        <h4>
#         Distributors
#        </h4>
#       </div>
#       <ul>
#        <li>
#         <a href="/signin.aspx">
#          Login
#         </a>
#        </li>
#        <li>
#         <a href="/createaccount.aspx">
#          Register
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Product Training
#        </h4>
#       </div>
#       <ul id="ulProductTraining">
#        <li>
#         <a href="/pages/training/index.aspx">
#          Dorman Training Center
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Product Info
#        </h4>
#       </div>
#       <ul id="ulProductInfo">
#        <li>
#         <a href="/Pages/resources/catalogs/dorman.aspx">
#          Catalogs
#         </a>
#        </li>
#        <li>
#         <a href="/pages/forms/product-registration.aspx">
#          Product Registration
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/patents.aspx">
#          Patents
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/cores/returns.aspx">
#          Core Returns
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#quality">
#          Quality
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#recalls">
#          Recalls
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/products/warranty/index.aspx#warranty">
#          Warranty
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/terms-of-sale.aspx">
#          Terms &amp; Condition of Sale
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-md-3 col-sm-4 col-xs-6">
#       <div class="footerheadline">
#        <h4>
#         Contact
#        </h4>
#       </div>
#       <ul id="ulContact">
#        <li>
#         <a href="/Pages/forms/customer.aspx">
#          Customer Service
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/ideas.aspx">
#          New Product Ideas
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/sales.aspx">
#          Sales
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/forms/support.aspx">
#          Technical Support
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Corporate Info
#        </h4>
#       </div>
#       <ul id="ulCorporateInfo">
#        <li>
#         <a href="/pages/corporate/about.aspx">
#          About Dorman
#         </a>
#        </li>
#        <li>
#         <a href="/pages/tour/index.html" target="_blank">
#          Virtual Tour
#         </a>
#        </li>
#        <li>
#         <a href="/pages/products/ld-b2b/index.aspx">
#          5D Partnership Model
#         </a>
#        </li>
#        <li>
#         <a href="https://jobs.dormanproducts.com/" target="_blank">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/news/default.aspx" target="_blank">
#          Press Releases
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/home/default.aspx" target="_blank">
#          Investor Relations
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/corporate-governance/esg/default.aspx" target="_blank">
#          Environmental, Social &amp; Governance
#         </a>
#        </li>
#        <li>
#         <a href="https://static.dormanproducts.com/document/corporate/2023-Fighting-Against-Forced-Labour-and-Child-Labour-in-Supply-Chains-Act-Report.pdf" target="_blank">
#          Modern Slavery Act Transparency Statement
#         </a>
#        </li>
#        <li>
#         <a href="https://investors.dormanproducts.com/corporate-governance/executive-management/default.aspx" target="_blank">
#          Executive Team
#         </a>
#        </li>
#        <li>
#         <a href="/pages/corporate/suppliers.aspx">
#          Suppliers
#         </a>
#        </li>
#        <li>
#         <a class="hidden" href="/pages/corporate/emap.aspx">
#          eMAP Policy
#         </a>
#        </li>
#        <li>
#         <a href="https://shoppress.dormanproducts.com" target="_blank">
#          Shop Press
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-md-3 hidden-sm hidden-xs">
#       <div class="footerheadline">
#        <h4>
#         Site Info
#        </h4>
#       </div>
#       <ul id="ulSiteInfo">
#        <li>
#         <a href="/Pages/web/sitemap.aspx">
#          Site Map
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/terms.aspx">
#          Web Terms &amp; Conditions
#         </a>
#        </li>
#        <li>
#         <a href="/Pages/web/privacy.aspx">
#          Privacy
#         </a>
#        </li>
#       </ul>
#       <div class="footerheadline">
#        <h4>
#         Aftermarket Membership
#        </h4>
#       </div>
#       <p>
#        Dorman Products is a proud member of the following aftermarket organizations:
#       </p>
#       <div class="row">
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.autocare.org" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/autocare-assocation.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.carcare.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/bcca.jpg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.aftermarketsuppliers.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/aasa.jpg"/>
#          </a>
#         </div>
#        </div>
#        <div class="col-sm-6">
#         <div class="footer-img centered">
#          <a href="http://www.cawa.org/" target="_blank">
#           <img class="img-responsive" src="//static.dormanproducts.com/images/website/homepage/cawa.jpg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-3 col-sm-4 btftk-clear" id="divNewProductAlert">
#       <div class="footerheadline">
#        <h4>
#         Email Newsletters Signup
#        </h4>
#       </div>
#       <p>
#        Never miss a new solution. Get regular updates on new innovations and repair tips.
#       </p>
#       <p>
#        <a class="btn btn-orange" href="/Pages/forms/btftk.aspx?origin=footersignup">
#         Sign Up Now
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- footer end -->
#   <!-- copyright bottom start -->
#   <div class="bottom" id="copyrightWrap">
#    <div class="container">
#     <div class="row">
#      <section class="copyright col-sm-6">
#       <p>
#        ©
#        <a href="/default.aspx">
#         Dorman Products
#        </a>
#        . All rights reserved.
#       </p>
#      </section>
#      <section class="col-sm-6 footer-social hidden-xs">
#       <p>
#        Follow Us:
#        <a href="https://www.facebook.com/dormanproducts" target="_blank">
#         <span aria-hidden="true" class="icon-facebook">
#         </span>
#        </a>
#        <a href="https://www.instagram.com/dormanproducts/" target="_blank">
#         <span aria-hidden="true" class="icon-instagram">
#         </span>
#        </a>
#        <a href="https://www.youtube.com/dormanproducts" target="_blank">
#         <span aria-hidden="true" class="icon-youtube-play">
#         </span>
#        </a>
#        <a href="https://www.linkedin.com/company/dorman-products" target="_blank">
#         <span aria-hidden="true" class="icon-linkedin">
#         </span>
#        </a>
#        <a href="javascript:scrollToTop()" id="topPageBtn" title="top of page">
#         <span class="topofpage">
#          <span aria-hidden="true" class="icon-up-open topofpage-icon">
#          </span>
#          <br/>
#          <span class="topofpage-text">
#           TOP
#          </span>
#         </span>
#        </a>
#       </p>
#      </section>
#     </div>
#    </div>
#   </div>
#   <!-- copyright bottom end -->
#   <!-- New Product Idea Modal -->
#   <!-- new product idea modal end -->
#   <!-- Modal Recent Activity -->
#   <div aria-labelledby="windowTitleLabel" class="modal fade" id="recentactivityModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h4 class="modal-title">
#        <span aria-hidden="true" class="glyphicon glyphicon-time">
#        </span>
#        <span id="recentactivityDialogLabel">
#         Recent Activities
#        </span>
#       </h4>
#      </div>
#      <div class="modal-body iframe">
#       <div id="recentactivityLoading" style="display:block;">
#        <div class="progress" style="height:25px;">
#         <div class="progress-bar progress-bar-striped active" style="width:100%">
#         </div>
#        </div>
#       </div>
#       <iframe class="embed-responsive-item" id="recentactivityIFrame" style="border:0px; width:100%; height: 100%;display:none;">
#       </iframe>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="/scripts/livechat.js?d=20190905" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-9Z678K7TDD">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'G-9Z678K7TDD', {'site_speed_sample_rate': 100,
# 'custom_map': {
# 'dimension1': 'Logged_In',
# 'dimension2': 'Dorman_Account_Number',
# 'dimension3': 'Store_Number'}
# });
# gtag('event', 'login', {'Logged_In': 'No'});
# gtag('config', 'AW-997247862');
#   </script>
#  </body>
# </html>

# %%
count = int(html.xpath('//span[@id="lblResultCount"]/text()')[0].strip())

count
# Out:
# 7

# %%
count <= 0
# Out:
# False

# %%
import math

df_temp = pd.DataFrame([{'Type No': input_.loc[a, 'Type No'],
                         'Type': input_.loc[a, 'Type'],
                         'Type Url': input_.loc[a, 'Type Url'],
                         'SKU Count': count,
                         'Page': math.ceil(count / 100)}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    Type No                             Type  \
# 0        1   Air Suspension Line Repair Kit
#
#                                             Type Url  SKU Count  Page
# 0  https://www.dormanproducts.com/gsearch.aspx?ty...          7     1

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Type No': input_.loc[a, 'Type No'],
                             'Type': input_.loc[a, 'Type'],
                             'Type Url': input_.loc[a, 'Type Url']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Type No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel('./test_page.xlsx', index=False)

output_correct
# Out:
#    Type No                             Type  \
# 0        1   Air Suspension Line Repair Kit
#
#                                             Type Url  SKU Count  Page
# 0  https://www.dormanproducts.com/gsearch.aspx?ty...          7     1

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Type No'],
                                            ascending=[False],
                                            ignore_index=True)
    output_error.to_excel('./test_page_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
