# %% [markdown]
# - Update: 2023.05.08
#
# # 0. 配置参数
#
# - `file`：要下载图片的文件的路径

# %%
file = './part_out_4.xlsx'

# = = = = = = = = = = = = = = = = = =

from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

from openpyxl import load_workbook
import requests
from io import BytesIO
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818',
           'https': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

wb = load_workbook(file)
ws = wb.active

for i in range(1, ws.max_column+1):
    if ws.cell(1, i).value == '图片链接':
        index_url = i
    elif ws.cell(1, i).value == '图片':
        index_img = i

# = = = = = = = = = = = = = = = = = =

work = Queue()
for i in range(2, ws.max_row+1):
    work.put_nowait(i)

# = = = = = = = = = = = = = = = = = =

def crawler():
    global ws
    
    while not work.empty():
        row = work.get_nowait()
        url = ws.cell(row, index_url).value
        
        for i in range(31):
            try:
                img = Image(BytesIO(requests.get(url, proxies=proxies).content))
                
                # = = = = = = = = = = = = = = = = = =
                
                if img.width >= img.height:
                    img.height = 30.0 / img.width * img.height
                    img.width = 30.0
                else:
                    img.width = 30.0 / img.height * img.width
                    img.height = 30.0
                    
                # = = = = = = = = = = = = = = = = = =
                
                ws.add_image(img, get_column_letter(index_img) + str(row))
            
                break
            
            except:
                
                continue
                
        # = = = = = = = = = = = = = = = = = =
                
        print(url, ' [' + str(i) + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

wb.save(file.replace('.xlsx', '-pic.xlsx'))
print()
print('搞定')
# Out:
# None  [30] - 剩余数量：49
# None  [30] - 剩余数量：48
# None  [30] - 剩余数量：47
# https://www.rockauto.com/info/42/905-142-007.jpg  [0] - 剩余数量：42
# https://www.rockauto.com/info/42/905-603-007.jpg  [0] - 剩余数量：41
# https://www.rockauto.com/info/42/905-144-007.jpg  [0] - 剩余数量：40
# https://www.rockauto.com/info/42/905-141-007.jpg  [0] - 剩余数量：39
# https://www.rockauto.com/info/42/905-600-007.jpg  [0] - 剩余数量：38
# https://www.rockauto.com/info/42/905-147-007.jpg  [0] - 剩余数量：37
# https://www.rockauto.com/info/42/905-608-007.jpg  [0] - 剩余数量：36
# https://www.rockauto.com/info/42/905-146-007.jpg  [0] - 剩余数量：35
# https://www.rockauto.com/info/42/905-601-007.jpg  [0] - 剩余数量：34
# https://www.rockauto.com/info/42/905-609-007.jpg  [0] - 剩余数量：33
# https://www.rockauto.com/info/42/905-612-007.jpg  [1] - 剩余数量：32
# https://www.rockauto.com/info/42/905-616-007.jpg  [0] - 剩余数量：31
# https://www.rockauto.com/info/42/905-618-007.jpg  [0] - 剩余数量：30
# https://www.rockauto.com/info/42/905-610-007.jpg  [0] - 剩余数量：29
# https://www.rockauto.com/info/42/905-619-007.jpg  [0] - 剩余数量：28
# https://www.rockauto.com/info/42/905-625-007.jpg  [0] - 剩余数量：27
# https://www.rockauto.com/info/42/905-631-007.jpg  [0] - 剩余数量：26
# https://www.rockauto.com/info/42/905-634-007.jpg  [0] - 剩余数量：25
# https://www.rockauto.com/info/42/905-627-007.jpg  [0] - 剩余数量：24
# https://www.rockauto.com/info/42/905-642-007.jpg  [0] - 剩余数量：23
# https://www.rockauto.com/info/42/905-643-007.jpg  [0] - 剩余数量：22
# https://www.rockauto.com/info/42/905-606-007.jpg  [0] - 剩余数量：21
# https://www.rockauto.com/info/42/905-645-007.jpg  [0] - 剩余数量：20
# https://www.rockauto.com/info/42/905-649-007.jpg  [0] - 剩余数量：19
# https://www.rockauto.com/info/42/905-646-007.jpg  [1] - 剩余数量：18
# https://www.rockauto.com/info/42/905-602-007.jpg  [0] - 剩余数量：17
# https://www.rockauto.com/info/42/905-651-007.jpg  [0] - 剩余数量：16
# https://www.rockauto.com/info/42/905-653-007.jpg  [0] - 剩余数量：15
# https://www.rockauto.com/info/42/905-605-007.jpg  [0] - 剩余数量：14
# https://www.rockauto.com/info/42/905-650-007.jpg  [0] - 剩余数量：13
# https://www.rockauto.com/info/42/905-644-007.jpg  [0] - 剩余数量：12
# https://www.rockauto.com/info/42/905-656-007.jpg  [0] - 剩余数量：11
# https://www.rockauto.com/info/42/905-657-007.jpg  [1] - 剩余数量：10
# https://www.rockauto.com/info/42/905-659-007.jpg  [0] - 剩余数量：9
# https://www.rockauto.com/info/42/905-658-007.jpg  [0] - 剩余数量：8
# https://www.rockauto.com/info/42/912-600-007.jpg  [0] - 剩余数量：7
# https://www.rockauto.com/info/42/905-661-007.jpg  [0] - 剩余数量：6
# https://www.rockauto.com/info/42/905-660-007.jpg  [0] - 剩余数量：5
# https://www.rockauto.com/info/42/924-7001-007.jpg  [0] - 剩余数量：4
# https://www.rockauto.com/info/42/924-7011-007.jpg  [0] - 剩余数量：3
# https://www.rockauto.com/info/42/924-7016-007.jpg  [0] - 剩余数量：2
# https://www.rockauto.com/info/42/924-7015-007.jpg  [0] - 剩余数量：1
# https://www.rockauto.com/info/42/924-7013-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/924-7017-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/924-7020-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/924-711-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/905-654-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/924-7004-007.jpg  [1] - 剩余数量：0
# https://www.rockauto.com/info/42/924-999-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/905-647-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/905-633-007.jpg  [0] - 剩余数量：0
# https://www.rockauto.com/info/42/905-655-007.jpg  [2] - 剩余数量：0
#
# 搞定
# C:\Users\Lennon\AppData\Local\Programs\Python\Python311\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
