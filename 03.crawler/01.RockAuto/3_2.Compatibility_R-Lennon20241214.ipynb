# %%
from gevent import monkey
monkey.patch_all(thread=False)

from gevent.pool import Pool
pool = Pool(30)

from gevent.lock import BoundedSemaphore
semaphore_correct, semaphore_error, semaphore_remain = BoundedSemaphore(1), BoundedSemaphore(1), BoundedSemaphore(1)

from IPython.display import clear_output
from datetime import datetime

import os
import shutil
directory_out = './file/3.compatibility'
if os.path.exists(directory_out):
    shutil.rmtree(directory_out)
os.makedirs(directory_out)
import re

# = = =  = = =  = = =

import pandas as pd

# = = =  = = =  = = =

import json

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = =  = = =  = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = =  = = =  = = =

directory_in = './file/2.part'
list_file = [file for file in sorted(list(os.walk(directory_in))[0][2]) if file not in ['.DS_Store'] and os.path.isfile(os.path.join(directory_in, file))]
for file in list_file:

    # = = =  = = =  = = =

    print('Data Loading...')
    list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(os.path.join(directory_in, file),
                                                                           header=0,
                                                                           dtype=str).fillna('')
    print('Loading Done !')
    print()

    df_input['No'] = df_input['No'].astype(int)

    crawler_remain = len(df_input)

    print(f'总数量：{crawler_remain}')
    print()

    # = = =  = = =  = = =

    def crawler(crawler_tuple):
        global list_dict_correct, list_series_error, crawler_remain

        crawler_status, (crawler_index, crawler_series) = False, crawler_tuple

        # = = =  = = =  = = =

        try:
            data = {'func': 'getbuyersguide',
                    'payload': json.dumps({'partData': {'listing_data_essential': {'parttype': crawler_series['Type Code'],
                                                                                   'partkey': crawler_series['Part Code']},
                                                        'listing_data_supplemental': {'partnumber': crawler_series['Part Number'],
                                                                                      'catalogname': crawler_series['Manufacturer']}}}),
                    'api_json_request': '1'}

            crawler_retry = 0
            while True:
                crawler_retry += 1

                try:
                    url_check = crawler_series['Url']

                    resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                         data=data,
                                         headers=get_header(),
                                         proxies=get_proxy(),
                                         timeout=(5, 15))

                    if resp.status_code == 200:
                        dict_ = resp.json()

                        if 'redirect_to_url' not in dict_ and dict_['buyersguidepieces']['title'].startswith('Buyer\'s Guide :') and 'collected_javascript' in dict_:
                            break
                except KeyboardInterrupt:
                    break
                except:
                    continue

            # = = =  = = =  = = =

            soup = BeautifulSoup(dict_['buyersguidepieces']['body'], 'lxml')
            html = etree.HTML(str(soup))

            # = = =  = = =  = = =

            list_tr = html.xpath('//tr')

            # = = =  = = =  = = =

            if not list_tr and not (html.xpath('//p/text()') and html.xpath('//p/text()')[0].strip() == 'No applications found.'):
                raise

            # = = =  = = =  = = =

            list_dict_correct_temp = []
            for i, tr in enumerate(list_tr):
                list_text = [text.strip() for text in tr.xpath('./td/text()')]
                list_year = list_text[-1].split('-')
                year_begin, year_end = int(list_year[0]), int(list_year[-1])

                if len(list_text) in [2, 3]:
                    list_dict_correct_temp.extend([{'JOIN_MPNTCPC': crawler_series['JOIN_MPNTCPC'],
                                                    'Vehicle No': i + 1,
                                                    'Make': list_text[0],
                                                    'Model': list_text[1] if len(list_text) == 3 else '',
                                                    'Year': year} for year in range(year_begin, year_end + 1)])
                else:
                    raise

            # = = =  = = =  = = =

            with semaphore_correct:
                list_dict_correct.extend(list_dict_correct_temp)

            # = = =  = = =  = = =

            crawler_status = True
        except:
            crawler_series['Check_Url'] = url_check

            with semaphore_error:
                list_series_error.append(crawler_series)

        # = = =  = = =  = = =

        if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and crawler_remain == 1 or crawler_remain % 30 == 0:
            clear_output()
        print(f'''[{crawler_status}] - [请求{crawler_retry}次] - [剩余{crawler_remain - 1}条] - [{file.removesuffix('.xlsx')}（{(list_file.index(file) + 1) / len(list_file) * 100:.2f}%）] - [{datetime.now().strftime('%Y/%m/%d %H:%M:%S')}] - {crawler_series['No']}. {url_check}\n''')

        with semaphore_remain:
            crawler_remain -= 1

    # = = =  = = =  = = =

    pool.map(crawler, df_input.iterrows())

    print('Data Outputting...')
    if list_dict_correct:
        df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['JOIN_MPNTCPC', 'Vehicle No', 'Year'],
                                                                 ascending=[True, True, False],
                                                                 ignore_index=True)
        df_correct.to_excel(os.path.join(directory_out, f'''{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx'''), index=False)
    print('Output Finished !')
    print()
    if list_series_error:
        df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                               ascending=[True],
                                                               ignore_index=True)
        df_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-compatibility_error.xlsx''', index=False)
        print('- Error Occurred -')
        print()

# = = =  = = =  = = =

list_file = [file for file in sorted(list(os.walk(directory_out))[0][2]) if file not in ['.DS_Store'] and os.path.isfile(os.path.join(directory_out, file))]
for file in list_file:
    os.rename(os.path.join(directory_out, file), os.path.join(directory_out, re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '-compatibility.xlsx', file)))

# = = =  = = =  = = =

print('Done ~')
# Out:
# [True] - [请求1次] - [剩余29条] - [1（100.00%）] - [2024/12/16 16:00:13] - 857. https://www.rockauto.com/en/parts/moog,515195,wheel+bearing+&+hub,1636
#
# [True] - [请求24次] - [剩余28条] - [1（100.00%）] - [2024/12/16 16:00:14] - 875. https://www.rockauto.com/en/parts/moog,518506,wheel+bearing+&+hub,1636
#
# [True] - [请求19次] - [剩余27条] - [1（100.00%）] - [2024/12/16 16:00:14] - 835. https://www.rockauto.com/en/parts/moog,515166,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余26条] - [1（100.00%）] - [2024/12/16 16:00:14] - 850. https://www.rockauto.com/en/parts/moog,515184,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余25条] - [1（100.00%）] - [2024/12/16 16:00:14] - 895. https://www.rockauto.com/en/parts/moog,541001,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余24条] - [1（100.00%）] - [2024/12/16 16:00:14] - 891. https://www.rockauto.com/en/parts/moog,520004,wheel+bearing+&+hub,1636
#
# [True] - [请求2次] - [剩余23条] - [1（100.00%）] - [2024/12/16 16:00:14] - 899. https://www.rockauto.com/en/parts/moog,541007,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余22条] - [1（100.00%）] - [2024/12/16 16:00:14] - 898. https://www.rockauto.com/en/parts/moog,541004,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余21条] - [1（100.00%）] - [2024/12/16 16:00:14] - 890. https://www.rockauto.com/en/parts/moog,520003,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余20条] - [1（100.00%）] - [2024/12/16 16:00:14] - 903. https://www.rockauto.com/en/parts/moog,541011,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余19条] - [1（100.00%）] - [2024/12/16 16:00:15] - 910. https://www.rockauto.com/en/parts/moog,541019,wheel+bearing+&+hub,1636
#
# [True] - [请求11次] - [剩余18条] - [1（100.00%）] - [2024/12/16 16:00:15] - 888. https://www.rockauto.com/en/parts/moog,518521,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余17条] - [1（100.00%）] - [2024/12/16 16:00:15] - 904. https://www.rockauto.com/en/parts/moog,541012,wheel+bearing+&+hub,1636
#
# [True] - [请求4次] - [剩余16条] - [1（100.00%）] - [2024/12/16 16:00:15] - 909. https://www.rockauto.com/en/parts/moog,541018,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余15条] - [1（100.00%）] - [2024/12/16 16:00:15] - 902. https://www.rockauto.com/en/parts/moog,541010,wheel+bearing+&+hub,1636
#
# [True] - [请求7次] - [剩余14条] - [1（100.00%）] - [2024/12/16 16:00:15] - 907. https://www.rockauto.com/en/parts/moog,541015,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余13条] - [1（100.00%）] - [2024/12/16 16:00:15] - 908. https://www.rockauto.com/en/parts/moog,541016,wheel+bearing+&+hub,1636
#
# [True] - [请求7次] - [剩余12条] - [1（100.00%）] - [2024/12/16 16:00:16] - 829. https://www.rockauto.com/en/parts/moog,515159,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余11条] - [1（100.00%）] - [2024/12/16 16:00:16] - 892. https://www.rockauto.com/en/parts/moog,520005,wheel+bearing+&+hub,1636
#
# [True] - [请求2次] - [剩余10条] - [1（100.00%）] - [2024/12/16 16:00:16] - 905. https://www.rockauto.com/en/parts/moog,541013,wheel+bearing+&+hub,1636
#
# [True] - [请求1次] - [剩余9条] - [1（100.00%）] - [2024/12/16 16:00:17] - 887. https://www.rockauto.com/en/parts/moog,518520,wheel+bearing+&+hub,1636
#
# [True] - [请求4次] - [剩余8条] - [1（100.00%）] - [2024/12/16 16:00:18] - 900. https://www.rockauto.com/en/parts/moog,541008,wheel+bearing+&+hub,1636
#
# [True] - [请求2次] - [剩余7条] - [1（100.00%）] - [2024/12/16 16:00:18] - 897. https://www.rockauto.com/en/parts/moog,541003,wheel+bearing+&+hub,1636
#
# [True] - [请求9次] - [剩余6条] - [1（100.00%）] - [2024/12/16 16:00:20] - 786. https://www.rockauto.com/en/parts/moog,515110,wheel+bearing+&+hub,1636
#
# [True] - [请求4次] - [剩余5条] - [1（100.00%）] - [2024/12/16 16:00:20] - 906. https://www.rockauto.com/en/parts/moog,541014,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余4条] - [1（100.00%）] - [2024/12/16 16:00:20] - 886. https://www.rockauto.com/en/parts/moog,518519,wheel+bearing+&+hub,1636
#
# [True] - [请求2次] - [剩余3条] - [1（100.00%）] - [2024/12/16 16:00:22] - 901. https://www.rockauto.com/en/parts/moog,541009,wheel+bearing+&+hub,1636
#
# [True] - [请求4次] - [剩余2条] - [1（100.00%）] - [2024/12/16 16:00:26] - 839. https://www.rockauto.com/en/parts/moog,515172,wheel+bearing+&+hub,1636
#
# [True] - [请求3次] - [剩余1条] - [1（100.00%）] - [2024/12/16 16:00:27] - 869. https://www.rockauto.com/en/parts/moog,515209,wheel+bearing+&+hub,1636
#
# [True] - [请求8次] - [剩余0条] - [1（100.00%）] - [2024/12/16 16:00:29] - 802. https://www.rockauto.com/en/parts/moog,515128,wheel+bearing+&+hub,1636
#
# Data Outputting...
# Output Finished !
#
# Done ~
