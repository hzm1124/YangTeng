# %%
param_keyword = 'Leerlaufregler'
param_pg = 134

# %%
list_url = ['https://www.autoteiledirekt.de/suche.html?keyword=' + param_keyword if i == 0 else 'https://www.autoteiledirekt.de/suche.html?keyword=' + param_keyword + '&pg=' + str(i+1) for i in range(param_pg)]

list_url
# Out:
# ['https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=2',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=3',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=4',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=5',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=6',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=7',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=8',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=9',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=10',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=11',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=12',
#  'https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=13',
# ...

# %%
import pyperclip

# %%
for i in range(len(list_url)):
    if i == 0:
        data = 'let dict_url = {"' + str(i+1) + '": "' + list_url[i] + '", '
    else:
        data += '"' + str(i+1) + '": "' + list_url[i] + '", '

data = data[:-2] + '};\n'
        
pyperclip.copy(data)

data
# Out:
# 'let dict_url = {"1": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler", "2": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=2", "3": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=3", "4": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=4", "5": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=5", "6": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=6", "7": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=7", "8": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=8", "9": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=9", "10": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=10", "11": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=11", "12": "https://www.autoteiledirekt.de/suche.html?keyword=Leerlaufregler&pg=12", "13": "https://www.autoteiledirekt.de/suche.
# ...
