# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree
import time

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./图片需求alternator.xlsx', header=0)
list_url = df_menu['Url'].to_list()
print('总数量：' + str(len(list_url)))
print()

work = Queue()
for url in list_url:
    work.put_nowait(url)

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['Url',
                           'Info',
                           'status'])

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818',
           'https': 'http://t18126899091866:kh8hjqtl@j933.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        url = work.get_nowait()
        
        status = 'error'
        for _ in range(31):
            try:
                resp = requests.get(url, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = = = = =

                html = etree.HTML(str(soup))
                
                list_row = html.xpath('//div[@class="listing-text-row-moreinfo-truck"]')

                # = = = = = = = = = = = = = = = = = =

                list_info = []
                for row in list_row:
                    info = row.xpath('.//a[@class="ra-btn ra-btn-moreinfo"]')
                    if len(info) == 0:
                        list_info.append('')
                    else:
                        list_info.append(info[0].get('href'))

                # = = = = = = = = = = = = = = = = = =

                status = 'ok'
                df_temp = pd.DataFrame({'Url': url,
                                        'Info': list_info,
                                        'status': 'ok'})

                break

            except:
                time.sleep(3)
                continue

        # = = = = = = = = = = = = = = = = = =
        
        if status == 'error':
            df_temp = pd.DataFrame({'Url': url,
                                    'status': ['error']})

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(url +  '  <->  [' + status + '] - 剩余：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./part_out.xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：608
#
# https://www.rockauto.com/en/parts/wai+global,11051N,alternator+/+generator,2412  <->  [ok] - 剩余：598
# https://www.rockauto.com/en/parts/wai+global,11119N,alternator+/+generator,2412  <->  [ok] - 剩余：597
# https://www.rockauto.com/en/parts/wai+global,11118N,alternator+/+generator,2412  <->  [ok] - 剩余：596
# https://www.rockauto.com/en/parts/wai+global,11027N,alternator+/+generator,2412  <->  [ok] - 剩余：595
# https://www.rockauto.com/en/parts/wai+global,11163N,alternator+/+generator,2412  <->  [ok] - 剩余：594
# https://www.rockauto.com/en/parts/wai+global,11097N,alternator+/+generator,2412  <->  [ok] - 剩余：593
# https://www.rockauto.com/en/parts/wai+global,11101N,alternator+/+generator,2412  <->  [ok] - 剩余：592
# https://www.rockauto.com/en/parts/wai+global,11126N,alternator+/+generator,2412  <->  [ok] - 剩余：591
# https://www.rockauto.com/en/parts/wai+global,11226N,alternator+/+generator,2412  <->  [ok] - 剩余：590
# https://www.rockauto.com/en/parts/wai+global,11170N,alternator+/+generator,2412  <->  [ok] - 剩余：589
# https://www.rockauto.com/en/parts/wai+global,11233N,alternator+/+generator,2412  <->  [ok] - 剩余：588
# https://www.rockauto.com/en/parts/wai+global,11309N,alternator+/+generator,2412  <->  [ok] - 剩余：587
# https://www.rockauto.com/en/parts/wai+global,11279N,alternator+/+generator,2412  <->  [ok] - 剩余：586
# https://www.rockauto.com/en/parts/wai+global,11041N,alternator+/+generator,2412  <->  [ok] - 剩余：585
# https://www.rockauto.com/en/parts/wai+global,11240N,alternator+/+generator,2412  <->  [ok] - 剩余：584
# https://www.rockauto.com/en/parts/wai+global,11307N,alternator+/+generator,2412  <->  [ok] - 剩余：583
# https://www.rockauto.com/en/parts/wai+global,11397N,alternator+/+generator,2412  <->  [ok] - 剩余：582
# https://www.rockauto.com/en/parts/wai+global,11486N,alternator+/+generator,2412  <->  [ok] - 剩余：581
# https://www.rockauto.com/en/parts/wai+global,11124N,alternator+/+generator,2412  <->  [ok] - 剩余：580
# https://www.rockauto.com/en/parts/wai+global,11493N,alternator+/+generator,2412  <->  [ok] - 剩余：579
# https://www.rockauto.com/en/parts/wai+global,11377N,alternator+/+generator,2412  <->  [ok] - 剩余：578
# https://www.rockauto.com/en/parts/wai+global,11514N,alternator+/+generator,2412  <->  [ok] - 剩余：577
# https://www.rockauto.com/en/parts/wai+global,11542N,alternator+/+generator,2412  <->  [ok] - 剩余：576
# https://www.rockauto.com/en/parts/wai+global,11564N,alternator+/+generator,2412  <->  [ok] - 剩余：575
# https://www.rockauto.com/en/parts/wai+global,11599N,alternator+/+generator,2412  <->  [ok] - 剩余：574
# https://www.rockauto.com/en/parts/wai+global,11546N,alternator+/+generator,2412  <->  [ok] - 剩余：573
# https://www.rockauto.com/en/parts/wai+global,11605N,alternator+/+generator,2412  <->  [ok] - 剩余：572
# https://www.rockauto.com/en/parts/wai+global,11464N,alternator+/+generator,2412  <->  [ok] - 剩余：571
# https://www.rockauto.com/en/parts/wai+global,11354N,alternator+/+generator,2412  <->  [ok] - 剩余：570
# https://www.rockauto.com/en/parts/wai+global,11608N,alternator+/+generator,2412  <->  [ok] - 剩余：569
# https://www.rockauto.com/en/parts/wai+global,11610N,alternator+/+generator,2412  <->  [ok] - 剩余：568
# https://www.rockauto.com/en/parts/wai+global,11326N,alternator+/+generator,2412  <->  [ok] - 剩余：567
# https://www.rockauto.com/en/parts/wai+global,11619N,alternator+/+generator,2412  <->  [ok] - 剩余：566
# https://www.rockauto.com/en/parts/wai+global,11637N,alternator+/+generator,2412  <->  [ok] - 剩余：565
# https://www.rockauto.com/en/parts/wai+global,11552N,alternator+/+generator,2412  <->  [ok] - 剩余：564
# https://www.rockauto.com/en/parts/wai+global,11303N,alternator+/+generator,2412  <->  [ok] - 剩余：563
# https://www.rockauto.com/en/parts/wai+global,11673N,alternator+/+generator,2412  <->  [ok] - 剩余：562
# https://www.rockauto.com/en/parts/wai+global,11683N,alternator+/+generator,2412  <->  [ok] - 剩余：561
# https://www.rockauto.com/en/parts/wai+global,11694N,alternator+/+generator,2412  <->  [ok] - 剩余：560
# https://www.rockauto.com/en/parts/wai+global,11917N,alternator+/+generator,2412  <->  [ok] - 剩余：559
# https://www.rockauto.com/en/parts/wai+global,11831N,alternator+/+generator,2412  <->  [ok] - 剩余：558
# https://www.rockauto.com/en/parts/wai+global,11707N,alternator+/+generator,2412  <->  [ok] - 剩余：557
# https://www.rockauto.com/en/parts/wai+global,11452N,alternator+/+generator,2412  <->  [ok] - 剩余：556
# https://www.rockauto.com/en/parts/wai+global,12336N,alternator+/+generator,2412  <->  [ok] - 剩余：555
# https://www.rockauto.com/en/parts/wai+global,13184N,alternator+/+generator,2412  <->  [ok] - 剩余：554
# https://www.rockauto.com/en/parts/wai+global,11624N,alternator+/+generator,2412  <->  [ok] - 剩余：553
# https://www.rockauto.com/en/parts/wai+global,13240N,alternator+/+generator,2412  <->  [ok] - 剩余：552
# https://www.rockauto.com/en/parts/wai+global,13275N,alternator+/+generator,2412  <->  [ok] - 剩余：551
# https://www.rockauto.com/en/parts/wai+global,13257N,alternator+/+generator,2412  <->  [ok] - 剩余：550
# https://www.rockauto.com/en/parts/wai+global,11629N,alternator+/+generator,2412  <->  [ok] - 剩余：549
# https://www.rockauto.com/en/parts/wai+global,13285N,alternator+/+generator,2412  <->  [ok] - 剩余：548
# https://www.rockauto.com/en/parts/wai+global,13306N,alternator+/+generator,2412  <->  [ok] - 剩余：547
# https://www.rockauto.com/en/parts/wai+global,13334N,alternator+/+generator,2412  <->  [ok] - 剩余：546
# https://www.rockauto.com/en/parts/wai+global,13409N,alternator+/+generator,2412  <->  [ok] - 剩余：545
# https://www.rockauto.com/en/parts/wai+global,13443N,alternator+/+generator,2412  <->  [ok] - 剩余：544
# https://www.rockauto.com/en/parts/wai+global,13453N,alternator+/+generator,2412  <->  [ok] - 剩余：543
# https://www.rockauto.com/en/parts/wai+global,12385N,alternator+/+generator,2412  <->  [ok] - 剩余：542
# https://www.rockauto.com/en/parts/wai+global,13523N,alternator+/+generator,2412  <->  [ok] - 剩余：541
# https://www.rockauto.com/en/parts/wai+global,13556N,alternator+/+generator,2412  <->  [ok] - 剩余：540
# https://www.rockauto.com/en/parts/wai+global,13531N,alternator+/+generator,2412  <->  [ok] - 剩余：539
# https://www.rockauto.com/en/parts/wai+global,13575N,alternator+/+generator,2412  <->  [ok] - 剩余：538
# https://www.rockauto.com/en/parts/wai+global,13289N,alternator+/+generator,2412  <->  [ok] - 剩余：537
# https://www.rockauto.com/en/parts/wai+global,13313N,alternator+/+generator,2412  <->  [ok] - 剩余：536
# https://www.rockauto.com/en/parts/wai+global,13330N,alternator+/+generator,2412  <->  [ok] - 剩余：535
# https://www.rockauto.com/en/parts/wai+global,13585N,alternator+/+generator,2412  <->  [ok] - 剩余：534
# https://www.rockauto.com/en/parts/wai+global,13413N,alternator+/+generator,2412  <->  [ok] - 剩余：533
# https://www.rockauto.com/en/parts/wai+global,13646N,alternator+/+generator,2412  <->  [ok] - 剩余：532
# https://www.rockauto.com/en/parts/wai+global,13680N,alternator+/+generator,2412  <->  [ok] - 剩余：531
# https://www.rockauto.com/en/parts/wai+global,13669N,alternator+/+generator,2412  <->  [ok] - 剩余：530
# https://www.rockauto.com/en/parts/wai+global,13741N,alternator+/+generator,2412  <->  [ok] - 剩余：529
# https://www.rockauto.com/en/parts/wai+global,13739N,alternator+/+generator,2412  <->  [ok] - 剩余：528
# https://www.rockauto.com/en/parts/wai+global,13735N,alternator+/+generator,2412  <->  [ok] - 剩余：527
# https://www.rockauto.com/en/parts/wai+global,13643N,alternator+/+generator,2412  <->  [ok] - 剩余：526
# https://www.rockauto.com/en/parts/wai+global,13755N,alternator+/+generator,2412  <->  [ok] - 剩余：525
# https://www.rockauto.com/en/parts/wai+global,13778N,alternator+/+generator,2412  <->  [ok] - 剩余：524
# https://www.rockauto.com/en/parts/wai+global,13780N,alternator+/+generator,2412  <->  [ok] - 剩余：523
# https://www.rockauto.com/en/parts/wai+global,13798N,alternator+/+generator,2412  <->  [ok] - 剩余：522
# https://www.rockauto.com/en/parts/wai+global,13814N,alternator+/+generator,2412  <->  [ok] - 剩余：521
# https://www.rockauto.com/en/parts/wai+global,13821N,alternator+/+generator,2412  <->  [ok] - 剩余：520
# https://www.rockauto.com/en/parts/wai+global,13849N,alternator+/+generator,2412  <->  [ok] - 剩余：519
# https://www.rockauto.com/en/parts/wai+global,13850N,alternator+/+generator,2412  <->  [ok] - 剩余：518
# https://www.rockauto.com/en/parts/wai+global,13783N,alternator+/+generator,2412  <->  [ok] - 剩余：517
# https://www.rockauto.com/en/parts/wai+global,13637N,alternator+/+generator,2412  <->  [ok] - 剩余：516
# https://www.rockauto.com/en/parts/wai+global,13889N,alternator+/+generator,2412  <->  [ok] - 剩余：515
# https://www.rockauto.com/en/parts/wai+global,13446N,alternator+/+generator,2412  <->  [ok] - 剩余：514
# https://www.rockauto.com/en/parts/wai+global,13892N,alternator+/+generator,2412  <->  [ok] - 剩余：513
# https://www.rockauto.com/en/parts/wai+global,13896N,alternator+/+generator,2412  <->  [ok] - 剩余：512
# https://www.rockauto.com/en/parts/wai+global,13900N,alternator+/+generator,2412  <->  [ok] - 剩余：511
# https://www.rockauto.com/en/parts/wai+global,13902N,alternator+/+generator,2412  <->  [ok] - 剩余：510
# https://www.rockauto.com/en/parts/wai+global,13737N,alternator+/+generator,2412  <->  [ok] - 剩余：509
# https://www.rockauto.com/en/parts/wai+global,13948N,alternator+/+generator,2412  <->  [ok] - 剩余：508
# https://www.rockauto.com/en/parts/wai+global,13904N,alternator+/+generator,2412  <->  [ok] - 剩余：507
# https://www.rockauto.com/en/parts/wai+global,13929N,alternator+/+generator,2412  <->  [ok] - 剩余：506
# https://www.rockauto.com/en/parts/wai+global,13959N,alternator+/+generator,2412  <->  [ok] - 剩余：505
# https://www.rockauto.com/en/parts/wai+global,14001N,alternator+/+generator,2412  <->  [ok] - 剩余：504
# https://www.rockauto.com/en/parts/wai+global,13952N,alternator+/+generator,2412  <->  [ok] - 剩余：503
# https://www.rockauto.com/en/parts/wai+global,14007N,alternator+/+generator,2412  <->  [ok] - 剩余：502
# https://www.rockauto.com/en/parts/wai+global,13996N,alternator+/+generator,2412  <->  [ok] - 剩余：501
# https://www.rockauto.com/en/parts/wai+global,14436N,alternator+/+generator,2412  <->  [ok] - 剩余：500
# https://www.rockauto.com/en/parts/wai+global,23112N,alternator+/+generator,2412  <->  [ok] - 剩余：499
# https://www.rockauto.com/en/parts/wai+global,21249N,alternator+/+generator,2412  <->  [ok] - 剩余：498
# https://www.rockauto.com/en/parts/wai+global,22482N,alternator+/+generator,2412  <->  [ok] - 剩余：497
# https://www.rockauto.com/en/parts/wai+global,14597N,alternator+/+generator,2412  <->  [ok] - 剩余：496
# https://www.rockauto.com/en/parts/wai+global,11024N,alternator+/+generator,2412  <->  [ok] - 剩余：495
# https://www.rockauto.com/en/parts/wai+global,11029N,alternator+/+generator,2412  <->  [ok] - 剩余：494
# https://www.rockauto.com/en/parts/wai+global,11049N,alternator+/+generator,2412  <->  [ok] - 剩余：493
# https://www.rockauto.com/en/parts/wai+global,13857N,alternator+/+generator,2412  <->  [ok] - 剩余：492
# https://www.rockauto.com/en/parts/wai+global,11052N,alternator+/+generator,2412  <->  [ok] - 剩余：491
# https://www.rockauto.com/en/parts/wai+global,14430N,alternator+/+generator,2412  <->  [ok] - 剩余：490
# https://www.rockauto.com/en/parts/wai+global,11121N,alternator+/+generator,2412  <->  [ok] - 剩余：489
# https://www.rockauto.com/en/parts/wai+global,11085N,alternator+/+generator,2412  <->  [ok] - 剩余：488
# https://www.rockauto.com/en/parts/wai+global,11081N,alternator+/+generator,2412  <->  [ok] - 剩余：487
# https://www.rockauto.com/en/parts/wai+global,21152N,alternator+/+generator,2412  <->  [ok] - 剩余：486
# https://www.rockauto.com/en/parts/wai+global,11221N,alternator+/+generator,2412  <->  [ok] - 剩余：485
# https://www.rockauto.com/en/parts/wai+global,11333N,alternator+/+generator,2412  <->  [ok] - 剩余：484
# https://www.rockauto.com/en/parts/wai+global,11478N,alternator+/+generator,2412  <->  [ok] - 剩余：483
# https://www.rockauto.com/en/parts/wai+global,11345N,alternator+/+generator,2412  <->  [ok] - 剩余：482
# https://www.rockauto.com/en/parts/wai+global,11501N,alternator+/+generator,2412  <->  [ok] - 剩余：481
# https://www.rockauto.com/en/parts/wai+global,11550N,alternator+/+generator,2412  <->  [ok] - 剩余：480
# https://www.rockauto.com/en/parts/wai+global,11541N,alternator+/+generator,2412  <->  [ok] - 剩余：479
# https://www.rockauto.com/en/parts/wai+global,11554N,alternator+/+generator,2412  <->  [ok] - 剩余：478
# https://www.rockauto.com/en/parts/wai+global,11609N,alternator+/+generator,2412  <->  [ok] - 剩余：477
# https://www.rockauto.com/en/parts/wai+global,11595N,alternator+/+generator,2412  <->  [ok] - 剩余：476
# https://www.rockauto.com/en/parts/wai+global,11565N,alternator+/+generator,2412  <->  [ok] - 剩余：475
# https://www.rockauto.com/en/parts/wai+global,14231N,alternator+/+generator,2412  <->  [ok] - 剩余：474
# https://www.rockauto.com/en/parts/wai+global,11647N,alternator+/+generator,2412  <->  [ok] - 剩余：473
# https://www.rockauto.com/en/parts/wai+global,11618N,alternator+/+generator,2412  <->  [ok] - 剩余：472
# https://www.rockauto.com/en/parts/wai+global,11649N,alternator+/+generator,2412  <->  [ok] - 剩余：471
# https://www.rockauto.com/en/parts/wai+global,11730N,alternator+/+generator,2412  <->  [ok] - 剩余：470
# https://www.rockauto.com/en/parts/wai+global,11657N,alternator+/+generator,2412  <->  [ok] - 剩余：469
# https://www.rockauto.com/en/parts/wai+global,11652N,alternator+/+generator,2412  <->  [ok] - 剩余：468
# https://www.rockauto.com/en/parts/wai+global,11280N,alternator+/+generator,2412  <->  [ok] - 剩余：467
# https://www.rockauto.com/en/parts/wai+global,11159N,alternator+/+generator,2412  <->  [ok] - 剩余：466
# https://www.rockauto.com/en/parts/wai+global,12335N,alternator+/+generator,2412  <->  [ok] - 剩余：465
# https://www.rockauto.com/en/parts/wai+global,11702N,alternator+/+generator,2412  <->  [ok] - 剩余：464
# https://www.rockauto.com/en/parts/wai+global,11776N,alternator+/+generator,2412  <->  [ok] - 剩余：463
# https://www.rockauto.com/en/parts/wai+global,11928N,alternator+/+generator,2412  <->  [ok] - 剩余：462
# https://www.rockauto.com/en/parts/wai+global,12382N,alternator+/+generator,2412  <->  [ok] - 剩余：461
# https://www.rockauto.com/en/parts/wai+global,11816N,alternator+/+generator,2412  <->  [ok] - 剩余：460
# https://www.rockauto.com/en/parts/wai+global,11045N,alternator+/+generator,2412  <->  [ok] - 剩余：459
# https://www.rockauto.com/en/parts/wai+global,11873N,alternator+/+generator,2412  <->  [ok] - 剩余：458
# https://www.rockauto.com/en/parts/wai+global,13196N,alternator+/+generator,2412  <->  [ok] - 剩余：457
# https://www.rockauto.com/en/parts/wai+global,13227N,alternator+/+generator,2412  <->  [ok] - 剩余：456
# https://www.rockauto.com/en/parts/wai+global,13273N,alternator+/+generator,2412  <->  [ok] - 剩余：455
# https://www.rockauto.com/en/parts/wai+global,13311N,alternator+/+generator,2412  <->  [ok] - 剩余：454
# https://www.rockauto.com/en/parts/wai+global,13612N,alternator+/+generator,2412  <->  [ok] - 剩余：453
# https://www.rockauto.com/en/parts/wai+global,13580N,alternator+/+generator,2412  <->  [ok] - 剩余：452
# https://www.rockauto.com/en/parts/wai+global,13538N,alternator+/+generator,2412  <->  [ok] - 剩余：451
# https://www.rockauto.com/en/parts/wai+global,13598N,alternator+/+generator,2412  <->  [ok] - 剩余：450
# https://www.rockauto.com/en/parts/wai+global,11607N,alternator+/+generator,2412  <->  [ok] - 剩余：449
# https://www.rockauto.com/en/parts/wai+global,13644N,alternator+/+generator,2412  <->  [ok] - 剩余：448
# https://www.rockauto.com/en/parts/wai+global,13337N,alternator+/+generator,2412  <->  [ok] - 剩余：447
# https://www.rockauto.com/en/parts/wai+global,13687N,alternator+/+generator,2412  <->  [ok] - 剩余：446
# https://www.rockauto.com/en/parts/wai+global,13671N,alternator+/+generator,2412  <->  [ok] - 剩余：445
# https://www.rockauto.com/en/parts/wai+global,13657N,alternator+/+generator,2412  <->  [ok] - 剩余：444
# https://www.rockauto.com/en/parts/wai+global,13723N,alternator+/+generator,2412  <->  [ok] - 剩余：443
# https://www.rockauto.com/en/parts/wai+global,13736N,alternator+/+generator,2412  <->  [ok] - 剩余：442
# https://www.rockauto.com/en/parts/wai+global,13546N,alternator+/+generator,2412  <->  [ok] - 剩余：441
# https://www.rockauto.com/en/parts/wai+global,13497N,alternator+/+generator,2412  <->  [ok] - 剩余：440
# https://www.rockauto.com/en/parts/wai+global,13738N,alternator+/+generator,2412  <->  [ok] - 剩余：439
# https://www.rockauto.com/en/parts/wai+global,13829N,alternator+/+generator,2412  <->  [ok] - 剩余：438
# https://www.rockauto.com/en/parts/wai+global,13728N,alternator+/+generator,2412  <->  [ok] - 剩余：437
# https://www.rockauto.com/en/parts/wai+global,13835N,alternator+/+generator,2412  <->  [ok] - 剩余：436
# https://www.rockauto.com/en/parts/wai+global,13840N,alternator+/+generator,2412  <->  [ok] - 剩余：435
# https://www.rockauto.com/en/parts/wai+global,13827N,alternator+/+generator,2412  <->  [ok] - 剩余：434
# https://www.rockauto.com/en/parts/wai+global,13856N,alternator+/+generator,2412  <->  [ok] - 剩余：433
# https://www.rockauto.com/en/parts/wai+global,13785N,alternator+/+generator,2412  <->  [ok] - 剩余：432
# https://www.rockauto.com/en/parts/wai+global,13921N,alternator+/+generator,2412  <->  [ok] - 剩余：431
# https://www.rockauto.com/en/parts/wai+global,13761N,alternator+/+generator,2412  <->  [ok] - 剩余：430
# https://www.rockauto.com/en/parts/wai+global,13937N,alternator+/+generator,2412  <->  [ok] - 剩余：429
# https://www.rockauto.com/en/parts/wai+global,13930N,alternator+/+generator,2412  <->  [ok] - 剩余：428
# https://www.rockauto.com/en/parts/wai+global,12536N,alternator+/+generator,2412  <->  [ok] - 剩余：427
# https://www.rockauto.com/en/parts/wai+global,13926N,alternator+/+generator,2412  <->  [ok] - 剩余：426
# https://www.rockauto.com/en/parts/wai+global,13940N,alternator+/+generator,2412  <->  [ok] - 剩余：425
# https://www.rockauto.com/en/parts/wai+global,13950N,alternator+/+generator,2412  <->  [ok] - 剩余：424
# https://www.rockauto.com/en/parts/wai+global,14655N,alternator+/+generator,2412  <->  [ok] - 剩余：423
# https://www.rockauto.com/en/parts/wai+global,14486N,alternator+/+generator,2412  <->  [ok] - 剩余：422
# https://www.rockauto.com/en/parts/wai+global,13995N,alternator+/+generator,2412  <->  [ok] - 剩余：421
# https://www.rockauto.com/en/parts/wai+global,14745N,alternator+/+generator,2412  <->  [ok] - 剩余：420
# https://www.rockauto.com/en/parts/wai+global,14488N,alternator+/+generator,2412  <->  [ok] - 剩余：419
# https://www.rockauto.com/en/parts/wai+global,20035N,alternator+/+generator,2412  <->  [ok] - 剩余：418
# https://www.rockauto.com/en/parts/wai+global,20602N,alternator+/+generator,2412  <->  [ok] - 剩余：417
# https://www.rockauto.com/en/parts/wai+global,20288N,alternator+/+generator,2412  <->  [ok] - 剩余：416
# https://www.rockauto.com/en/parts/wai+global,20084N,alternator+/+generator,2412  <->  [ok] - 剩余：415
# https://www.rockauto.com/en/parts/wai+global,20384N,alternator+/+generator,2412  <->  [ok] - 剩余：414
# https://www.rockauto.com/en/parts/wai+global,21139N,alternator+/+generator,2412  <->  [ok] - 剩余：413
# https://www.rockauto.com/en/parts/wai+global,11025N,alternator+/+generator,2412  <->  [ok] - 剩余：412
# https://www.rockauto.com/en/parts/wai+global,23923N,alternator+/+generator,2412  <->  [ok] - 剩余：411
# https://www.rockauto.com/en/parts/wai+global,13966N,alternator+/+generator,2412  <->  [ok] - 剩余：410
# https://www.rockauto.com/en/parts/wai+global,11043N,alternator+/+generator,2412  <->  [ok] - 剩余：409
# https://www.rockauto.com/en/parts/wai+global,14611N,alternator+/+generator,2412  <->  [ok] - 剩余：408
# https://www.rockauto.com/en/parts/wai+global,11028N,alternator+/+generator,2412  <->  [ok] - 剩余：407
# https://www.rockauto.com/en/parts/wai+global,11058N,alternator+/+generator,2412  <->  [ok] - 剩余：406
# https://www.rockauto.com/en/parts/wai+global,11053N,alternator+/+generator,2412  <->  [ok] - 剩余：405
# https://www.rockauto.com/en/parts/wai+global,11099N,alternator+/+generator,2412  <->  [ok] - 剩余：404
# https://www.rockauto.com/en/parts/wai+global,11116N,alternator+/+generator,2412  <->  [ok] - 剩余：403
# https://www.rockauto.com/en/parts/wai+global,11050N,alternator+/+generator,2412  <->  [ok] - 剩余：402
# https://www.rockauto.com/en/parts/wai+global,23901N,alternator+/+generator,2412  <->  [ok] - 剩余：401
# https://www.rockauto.com/en/parts/wai+global,11230N,alternator+/+generator,2412  <->  [ok] - 剩余：400
# https://www.rockauto.com/en/parts/wai+global,11165N,alternator+/+generator,2412  <->  [ok] - 剩余：399
# https://www.rockauto.com/en/parts/wai+global,11275N,alternator+/+generator,2412  <->  [ok] - 剩余：398
# https://www.rockauto.com/en/parts/wai+global,13692N,alternator+/+generator,2412  <->  [ok] - 剩余：397
# https://www.rockauto.com/en/parts/wai+global,11198N,alternator+/+generator,2412  <->  [ok] - 剩余：396
# https://www.rockauto.com/en/parts/wai+global,11186N,alternator+/+generator,2412  <->  [ok] - 剩余：395
# https://www.rockauto.com/en/parts/wai+global,11302N,alternator+/+generator,2412  <->  [ok] - 剩余：394
# https://www.rockauto.com/en/parts/wai+global,11347N,alternator+/+generator,2412  <->  [ok] - 剩余：393
# https://www.rockauto.com/en/parts/wai+global,11368N,alternator+/+generator,2412  <->  [ok] - 剩余：392
# https://www.rockauto.com/en/parts/wai+global,11234N,alternator+/+generator,2412  <->  [ok] - 剩余：391
# https://www.rockauto.com/en/parts/wai+global,11409N,alternator+/+generator,2412  <->  [ok] - 剩余：390
# https://www.rockauto.com/en/parts/wai+global,11274N,alternator+/+generator,2412  <->  [ok] - 剩余：389
# https://www.rockauto.com/en/parts/wai+global,11399N,alternator+/+generator,2412  <->  [ok] - 剩余：388
# https://www.rockauto.com/en/parts/wai+global,11438N,alternator+/+generator,2412  <->  [ok] - 剩余：387
# https://www.rockauto.com/en/parts/wai+global,11460N,alternator+/+generator,2412  <->  [ok] - 剩余：386
# https://www.rockauto.com/en/parts/wai+global,11465N,alternator+/+generator,2412  <->  [ok] - 剩余：385
# https://www.rockauto.com/en/parts/wai+global,11485N,alternator+/+generator,2412  <->  [ok] - 剩余：384
# https://www.rockauto.com/en/parts/wai+global,11477N,alternator+/+generator,2412  <->  [ok] - 剩余：383
# https://www.rockauto.com/en/parts/wai+global,11487N,alternator+/+generator,2412  <->  [ok] - 剩余：382
# https://www.rockauto.com/en/parts/wai+global,11491N,alternator+/+generator,2412  <->  [ok] - 剩余：381
# https://www.rockauto.com/en/parts/wai+global,11512N,alternator+/+generator,2412  <->  [ok] - 剩余：380
# https://www.rockauto.com/en/parts/wai+global,11395N,alternator+/+generator,2412  <->  [ok] - 剩余：379
# https://www.rockauto.com/en/parts/wai+global,11538N,alternator+/+generator,2412  <->  [ok] - 剩余：378
# https://www.rockauto.com/en/parts/wai+global,11557N,alternator+/+generator,2412  <->  [ok] - 剩余：377
# https://www.rockauto.com/en/parts/wai+global,11551N,alternator+/+generator,2412  <->  [ok] - 剩余：376
# https://www.rockauto.com/en/parts/wai+global,11579N,alternator+/+generator,2412  <->  [ok] - 剩余：375
# https://www.rockauto.com/en/parts/wai+global,11278N,alternator+/+generator,2412  <->  [ok] - 剩余：374
# https://www.rockauto.com/en/parts/wai+global,11614N,alternator+/+generator,2412  <->  [ok] - 剩余：373
# https://www.rockauto.com/en/parts/wai+global,11693N,alternator+/+generator,2412  <->  [ok] - 剩余：372
# https://www.rockauto.com/en/parts/wai+global,11428N,alternator+/+generator,2412  <->  [ok] - 剩余：371
# https://www.rockauto.com/en/parts/wai+global,11684N,alternator+/+generator,2412  <->  [ok] - 剩余：370
# https://www.rockauto.com/en/parts/wai+global,11701N,alternator+/+generator,2412  <->  [ok] - 剩余：369
# https://www.rockauto.com/en/parts/wai+global,11714N,alternator+/+generator,2412  <->  [ok] - 剩余：368
# https://www.rockauto.com/en/parts/wai+global,11814N,alternator+/+generator,2412  <->  [ok] - 剩余：367
# https://www.rockauto.com/en/parts/wai+global,11916N,alternator+/+generator,2412  <->  [ok] - 剩余：366
# https://www.rockauto.com/en/parts/wai+global,11664N,alternator+/+generator,2412  <->  [ok] - 剩余：365
# https://www.rockauto.com/en/parts/wai+global,12384N,alternator+/+generator,2412  <->  [ok] - 剩余：364
# https://www.rockauto.com/en/parts/wai+global,11644N,alternator+/+generator,2412  <->  [ok] - 剩余：363
# https://www.rockauto.com/en/parts/wai+global,12883N,alternator+/+generator,2412  <->  [ok] - 剩余：362
# https://www.rockauto.com/en/parts/wai+global,13471N,alternator+/+generator,2412  <->  [ok] - 剩余：361
# https://www.rockauto.com/en/parts/wai+global,13226N,alternator+/+generator,2412  <->  [ok] - 剩余：360
# https://www.rockauto.com/en/parts/wai+global,13282N,alternator+/+generator,2412  <->  [ok] - 剩余：359
# https://www.rockauto.com/en/parts/wai+global,13287N,alternator+/+generator,2412  <->  [ok] - 剩余：358
# https://www.rockauto.com/en/parts/wai+global,13307N,alternator+/+generator,2412  <->  [ok] - 剩余：357
# https://www.rockauto.com/en/parts/wai+global,13329N,alternator+/+generator,2412  <->  [ok] - 剩余：356
# https://www.rockauto.com/en/parts/wai+global,13451N,alternator+/+generator,2412  <->  [ok] - 剩余：355
# https://www.rockauto.com/en/parts/wai+global,13314N,alternator+/+generator,2412  <->  [ok] - 剩余：354
# https://www.rockauto.com/en/parts/wai+global,11655N,alternator+/+generator,2412  <->  [ok] - 剩余：353
# https://www.rockauto.com/en/parts/wai+global,13382N,alternator+/+generator,2412  <->  [ok] - 剩余：352
# https://www.rockauto.com/en/parts/wai+global,13350N,alternator+/+generator,2412  <->  [ok] - 剩余：351
# https://www.rockauto.com/en/parts/wai+global,13473N,alternator+/+generator,2412  <->  [ok] - 剩余：350
# https://www.rockauto.com/en/parts/wai+global,13524N,alternator+/+generator,2412  <->  [ok] - 剩余：349
# https://www.rockauto.com/en/parts/wai+global,13482N,alternator+/+generator,2412  <->  [ok] - 剩余：348
# https://www.rockauto.com/en/parts/wai+global,13636N,alternator+/+generator,2412  <->  [ok] - 剩余：347
# https://www.rockauto.com/en/parts/wai+global,13558N,alternator+/+generator,2412  <->  [ok] - 剩余：346
# https://www.rockauto.com/en/parts/wai+global,13552N,alternator+/+generator,2412  <->  [ok] - 剩余：345
# https://www.rockauto.com/en/parts/wai+global,13597N,alternator+/+generator,2412  <->  [ok] - 剩余：344
# https://www.rockauto.com/en/parts/wai+global,13533N,alternator+/+generator,2412  <->  [ok] - 剩余：343
# https://www.rockauto.com/en/parts/wai+global,13645N,alternator+/+generator,2412  <->  [ok] - 剩余：342
# https://www.rockauto.com/en/parts/wai+global,13648N,alternator+/+generator,2412  <->  [ok] - 剩余：341
# https://www.rockauto.com/en/parts/wai+global,13668N,alternator+/+generator,2412  <->  [ok] - 剩余：340
# https://www.rockauto.com/en/parts/wai+global,13673N,alternator+/+generator,2412  <->  [ok] - 剩余：339
# https://www.rockauto.com/en/parts/wai+global,13688N,alternator+/+generator,2412  <->  [ok] - 剩余：338
# https://www.rockauto.com/en/parts/wai+global,13684N,alternator+/+generator,2412  <->  [ok] - 剩余：337
# https://www.rockauto.com/en/parts/wai+global,13700N,alternator+/+generator,2412  <->  [ok] - 剩余：336
# https://www.rockauto.com/en/parts/wai+global,13760N,alternator+/+generator,2412  <->  [ok] - 剩余：335
# https://www.rockauto.com/en/parts/wai+global,13763N,alternator+/+generator,2412  <->  [ok] - 剩余：334
# https://www.rockauto.com/en/parts/wai+global,13759N,alternator+/+generator,2412  <->  [ok] - 剩余：333
# https://www.rockauto.com/en/parts/wai+global,13770N,alternator+/+generator,2412  <->  [ok] - 剩余：332
# https://www.rockauto.com/en/parts/wai+global,13764N,alternator+/+generator,2412  <->  [ok] - 剩余：331
# https://www.rockauto.com/en/parts/wai+global,13777N,alternator+/+generator,2412  <->  [ok] - 剩余：330
# https://www.rockauto.com/en/parts/wai+global,13779N,alternator+/+generator,2412  <->  [ok] - 剩余：329
# https://www.rockauto.com/en/parts/wai+global,13781N,alternator+/+generator,2412  <->  [ok] - 剩余：328
# https://www.rockauto.com/en/parts/wai+global,13789N,alternator+/+generator,2412  <->  [ok] - 剩余：327
# https://www.rockauto.com/en/parts/wai+global,13795N,alternator+/+generator,2412  <->  [ok] - 剩余：326
# https://www.rockauto.com/en/parts/wai+global,13786N,alternator+/+generator,2412  <->  [ok] - 剩余：325
# https://www.rockauto.com/en/parts/wai+global,13809N,alternator+/+generator,2412  <->  [ok] - 剩余：324
# https://www.rockauto.com/en/parts/wai+global,13796N,alternator+/+generator,2412  <->  [ok] - 剩余：323
# https://www.rockauto.com/en/parts/wai+global,13813N,alternator+/+generator,2412  <->  [ok] - 剩余：322
# https://www.rockauto.com/en/parts/wai+global,13810N,alternator+/+generator,2412  <->  [ok] - 剩余：321
# https://www.rockauto.com/en/parts/wai+global,13815N,alternator+/+generator,2412  <->  [ok] - 剩余：320
# https://www.rockauto.com/en/parts/wai+global,13826N,alternator+/+generator,2412  <->  [ok] - 剩余：319
# https://www.rockauto.com/en/parts/wai+global,13820N,alternator+/+generator,2412  <->  [ok] - 剩余：318
# https://www.rockauto.com/en/parts/wai+global,13855N,alternator+/+generator,2412  <->  [ok] - 剩余：317
# https://www.rockauto.com/en/parts/wai+global,13883N,alternator+/+generator,2412  <->  [ok] - 剩余：316
# https://www.rockauto.com/en/parts/wai+global,13877N,alternator+/+generator,2412  <->  [ok] - 剩余：315
# https://www.rockauto.com/en/parts/wai+global,13836N,alternator+/+generator,2412  <->  [ok] - 剩余：314
# https://www.rockauto.com/en/parts/wai+global,13828N,alternator+/+generator,2412  <->  [ok] - 剩余：313
# https://www.rockauto.com/en/parts/wai+global,13898N,alternator+/+generator,2412  <->  [ok] - 剩余：312
# https://www.rockauto.com/en/parts/wai+global,13894N,alternator+/+generator,2412  <->  [ok] - 剩余：311
# https://www.rockauto.com/en/parts/wai+global,13906N,alternator+/+generator,2412  <->  [ok] - 剩余：310
# https://www.rockauto.com/en/parts/wai+global,13920N,alternator+/+generator,2412  <->  [ok] - 剩余：309
# https://www.rockauto.com/en/parts/wai+global,13901N,alternator+/+generator,2412  <->  [ok] - 剩余：308
# https://www.rockauto.com/en/parts/wai+global,13949N,alternator+/+generator,2412  <->  [ok] - 剩余：307
# https://www.rockauto.com/en/parts/wai+global,13962N,alternator+/+generator,2412  <->  [ok] - 剩余：306
# https://www.rockauto.com/en/parts/wai+global,13973N,alternator+/+generator,2412  <->  [ok] - 剩余：305
# https://www.rockauto.com/en/parts/wai+global,13989N,alternator+/+generator,2412  <->  [ok] - 剩余：304
# https://www.rockauto.com/en/parts/wai+global,13974N,alternator+/+generator,2412  <->  [ok] - 剩余：303
# https://www.rockauto.com/en/parts/wai+global,14719N,alternator+/+generator,2412  <->  [ok] - 剩余：302
# https://www.rockauto.com/en/parts/wai+global,13939N,alternator+/+generator,2412  <->  [ok] - 剩余：301
# https://www.rockauto.com/en/parts/wai+global,14859N,alternator+/+generator,2412  <->  [ok] - 剩余：300
# https://www.rockauto.com/en/parts/wai+global,13997N,alternator+/+generator,2412  <->  [ok] - 剩余：299
# https://www.rockauto.com/en/parts/wai+global,20741N,alternator+/+generator,2412  <->  [ok] - 剩余：298
# https://www.rockauto.com/en/parts/wai+global,22821N,alternator+/+generator,2412  <->  [ok] - 剩余：297
# https://www.rockauto.com/en/parts/wai+global,21512N,alternator+/+generator,2412  <->  [ok] - 剩余：296
# https://www.rockauto.com/en/parts/wai+global,21151N,alternator+/+generator,2412  <->  [ok] - 剩余：295
# https://www.rockauto.com/en/parts/wai+global,23356N,alternator+/+generator,2412  <->  [ok] - 剩余：294
# https://www.rockauto.com/en/parts/wai+global,23561N,alternator+/+generator,2412  <->  [ok] - 剩余：293
# https://www.rockauto.com/en/parts/wai+global,11253N,alternator+/+generator,2412  <->  [ok] - 剩余：292
# https://www.rockauto.com/en/parts/wai+global,21002N,alternator+/+generator,2412  <->  [ok] - 剩余：291
# https://www.rockauto.com/en/parts/wai+global,11120N,alternator+/+generator,2412  <->  [ok] - 剩余：290
# https://www.rockauto.com/en/parts/wai+global,23817N,alternator+/+generator,2412  <->  [ok] - 剩余：289
# https://www.rockauto.com/en/parts/wai+global,44002N,alternator+/+generator,2412  <->  [ok] - 剩余：288
# https://www.rockauto.com/en/parts/wai+global,23917N,alternator+/+generator,2412  <->  [ok] - 剩余：287
# https://www.rockauto.com/en/parts/wai+global,24226N,alternator+/+generator,2412  <->  [ok] - 剩余：286
# https://www.rockauto.com/en/parts/wai+global,23308N,alternator+/+generator,2412  <->  [ok] - 剩余：285
# https://www.rockauto.com/en/parts/bbb+industries,11160,alternator+/+generator,2412  <->  [ok] - 剩余：284
# https://www.rockauto.com/en/parts/bbb+industries,11363,alternator+/+generator,2412  <->  [ok] - 剩余：283
# https://www.rockauto.com/en/parts/bbb+industries,11129,alternator+/+generator,2412  <->  [ok] - 剩余：282
# https://www.rockauto.com/en/parts/bbb+industries,11525,alternator+/+generator,2412  <->  [ok] - 剩余：281
# https://www.rockauto.com/en/parts/bbb+industries,11566,alternator+/+generator,2412  <->  [ok] - 剩余：280
# https://www.rockauto.com/en/parts/wai+global,20021N,alternator+/+generator,2412  <->  [ok] - 剩余：279
# https://www.rockauto.com/en/parts/bbb+industries,11013,alternator+/+generator,2412  <->  [ok] - 剩余：278
# https://www.rockauto.com/en/parts/wai+global,8239N,alternator+/+generator,2412  <->  [ok] - 剩余：277
# https://www.rockauto.com/en/parts/bbb+industries,11585,alternator+/+generator,2412  <->  [ok] - 剩余：276
# https://www.rockauto.com/en/parts/wai+global,23227N,alternator+/+generator,2412  <->  [ok] - 剩余：275
# https://www.rockauto.com/en/parts/bbb+industries,13640,alternator+/+generator,2412  <->  [ok] - 剩余：274
# https://www.rockauto.com/en/parts/bbb+industries,13685,alternator+/+generator,2412  <->  [ok] - 剩余：273
# https://www.rockauto.com/en/parts/wai+global,20082N,alternator+/+generator,2412  <->  [ok] - 剩余：272
# https://www.rockauto.com/en/parts/bbb+industries,13502,alternator+/+generator,2412  <->  [ok] - 剩余：271
# https://www.rockauto.com/en/parts/bbb+industries,13748,alternator+/+generator,2412  <->  [ok] - 剩余：270
# https://www.rockauto.com/en/parts/bbb+industries,13846,alternator+/+generator,2412  <->  [ok] - 剩余：269
# https://www.rockauto.com/en/parts/bbb+industries,42161,alternator+/+generator,2412  <->  [ok] - 剩余：268
# https://www.rockauto.com/en/parts/bbb+industries,13965,alternator+/+generator,2412  <->  [ok] - 剩余：267
# https://www.rockauto.com/en/parts/bbb+industries,42246,alternator+/+generator,2412  <->  [ok] - 剩余：266
# https://www.rockauto.com/en/parts/bbb+industries,81067,alternator+/+generator,2412  <->  [ok] - 剩余：265
# https://www.rockauto.com/en/parts/bbb+industries,13435,alternator+/+generator,2412  <->  [ok] - 剩余：264
# https://www.rockauto.com/en/parts/bbb+industries,11031,alternator+/+generator,2412  <->  [ok] - 剩余：263
# https://www.rockauto.com/en/parts/bbb+industries,11451,alternator+/+generator,2412  <->  [ok] - 剩余：262
# https://www.rockauto.com/en/parts/bbb+industries,13933,alternator+/+generator,2412  <->  [ok] - 剩余：261
# https://www.rockauto.com/en/parts/bbb+industries,11396,alternator+/+generator,2412  <->  [ok] - 剩余：260
# https://www.rockauto.com/en/parts/bbb+industries,11418,alternator+/+generator,2412  <->  [ok] - 剩余：259
# https://www.rockauto.com/en/parts/bbb+industries,11463,alternator+/+generator,2412  <->  [ok] - 剩余：258
# https://www.rockauto.com/en/parts/bbb+industries,13545,alternator+/+generator,2412  <->  [ok] - 剩余：257
# https://www.rockauto.com/en/parts/bbb+industries,12383,alternator+/+generator,2412  <->  [ok] - 剩余：256
# https://www.rockauto.com/en/parts/bbb+industries,11617,alternator+/+generator,2412  <->  [ok] - 剩余：255
# https://www.rockauto.com/en/parts/bbb+industries,13840,alternator+/+generator,2412  <->  [ok] - 剩余：254
# https://www.rockauto.com/en/parts/bbb+industries,13833,alternator+/+generator,2412  <->  [ok] - 剩余：253
# https://www.rockauto.com/en/parts/bbb+industries,13864,alternator+/+generator,2412  <->  [ok] - 剩余：252
# https://www.rockauto.com/en/parts/bbb+industries,13758,alternator+/+generator,2412  <->  [ok] - 剩余：251
# https://www.rockauto.com/en/parts/bbb+industries,13928,alternator+/+generator,2412  <->  [ok] - 剩余：250
# https://www.rockauto.com/en/parts/bbb+industries,23256,alternator+/+generator,2412  <->  [ok] - 剩余：249
# https://www.rockauto.com/en/parts/bbb+industries,13957,alternator+/+generator,2412  <->  [ok] - 剩余：248
# https://www.rockauto.com/en/parts/bbb+industries,11056,alternator+/+generator,2412  <->  [ok] - 剩余：247
# https://www.rockauto.com/en/parts/bbb+industries,13970,alternator+/+generator,2412  <->  [ok] - 剩余：246
# https://www.rockauto.com/en/parts/bbb+industries,N11392,alternator+/+generator,2412  <->  [ok] - 剩余：245
# https://www.rockauto.com/en/parts/wai+global,13886N,alternator+/+generator,2412  <->  [ok] - 剩余：244
# https://www.rockauto.com/en/parts/bbb+industries,11070,alternator+/+generator,2412  <->  [ok] - 剩余：243
# https://www.rockauto.com/en/parts/bbb+industries,11064,alternator+/+generator,2412  <->  [ok] - 剩余：242
# https://www.rockauto.com/en/parts/bbb+industries,11130,alternator+/+generator,2412  <->  [ok] - 剩余：241
# https://www.rockauto.com/en/parts/bbb+industries,11012,alternator+/+generator,2412  <->  [ok] - 剩余：240
# https://www.rockauto.com/en/parts/bbb+industries,11412,alternator+/+generator,2412  <->  [ok] - 剩余：239
# https://www.rockauto.com/en/parts/bbb+industries,11507,alternator+/+generator,2412  <->  [ok] - 剩余：238
# https://www.rockauto.com/en/parts/bbb+industries,11611,alternator+/+generator,2412  <->  [ok] - 剩余：237
# https://www.rockauto.com/en/parts/bbb+industries,11569,alternator+/+generator,2412  <->  [ok] - 剩余：236
# https://www.rockauto.com/en/parts/bbb+industries,11362,alternator+/+generator,2412  <->  [ok] - 剩余：235
# https://www.rockauto.com/en/parts/bbb+industries,11526,alternator+/+generator,2412  <->  [ok] - 剩余：234
# https://www.rockauto.com/en/parts/bbb+industries,13271,alternator+/+generator,2412  <->  [ok] - 剩余：233
# https://www.rockauto.com/en/parts/bbb+industries,11648,alternator+/+generator,2412  <->  [ok] - 剩余：232
# https://www.rockauto.com/en/parts/bbb+industries,11262,alternator+/+generator,2412  <->  [ok] - 剩余：231
# https://www.rockauto.com/en/parts/bbb+industries,13729,alternator+/+generator,2412  <->  [ok] - 剩余：230
# https://www.rockauto.com/en/parts/bbb+industries,11547,alternator+/+generator,2412  <->  [ok] - 剩余：229
# https://www.rockauto.com/en/parts/bbb+industries,13751,alternator+/+generator,2412  <->  [ok] - 剩余：228
# https://www.rockauto.com/en/parts/bbb+industries,13332,alternator+/+generator,2412  <->  [ok] - 剩余：227
# https://www.rockauto.com/en/parts/bbb+industries,13917,alternator+/+generator,2412  <->  [ok] - 剩余：226
# https://www.rockauto.com/en/parts/bbb+industries,13733,alternator+/+generator,2412  <->  [ok] - 剩余：225
# https://www.rockauto.com/en/parts/bbb+industries,42225,alternator+/+generator,2412  <->  [ok] - 剩余：224
# https://www.rockauto.com/en/parts/bbb+industries,42063,alternator+/+generator,2412  <->  [ok] - 剩余：223
# https://www.rockauto.com/en/parts/bbb+industries,11480,alternator+/+generator,2412  <->  [ok] - 剩余：222
# https://www.rockauto.com/en/parts/bbb+industries,23357,alternator+/+generator,2412  <->  [ok] - 剩余：221
# https://www.rockauto.com/en/parts/bbb+industries,11123,alternator+/+generator,2412  <->  [ok] - 剩余：220
# https://www.rockauto.com/en/parts/bbb+industries,11317,alternator+/+generator,2412  <->  [ok] - 剩余：219
# https://www.rockauto.com/en/parts/bbb+industries,11218,alternator+/+generator,2412  <->  [ok] - 剩余：218
# https://www.rockauto.com/en/parts/bbb+industries,11338,alternator+/+generator,2412  <->  [ok] - 剩余：217
# https://www.rockauto.com/en/parts/bbb+industries,11414,alternator+/+generator,2412  <->  [ok] - 剩余：216
# https://www.rockauto.com/en/parts/bbb+industries,14432,alternator+/+generator,2412  <->  [ok] - 剩余：215
# https://www.rockauto.com/en/parts/bbb+industries,11421,alternator+/+generator,2412  <->  [ok] - 剩余：214
# https://www.rockauto.com/en/parts/bbb+industries,11522,alternator+/+generator,2412  <->  [ok] - 剩余：213
# https://www.rockauto.com/en/parts/bbb+industries,13450,alternator+/+generator,2412  <->  [ok] - 剩余：212
# https://www.rockauto.com/en/parts/bbb+industries,11175,alternator+/+generator,2412  <->  [ok] - 剩余：211
# https://www.rockauto.com/en/parts/bbb+industries,11534,alternator+/+generator,2412  <->  [ok] - 剩余：210
# https://www.rockauto.com/en/parts/bbb+industries,11009,alternator+/+generator,2412  <->  [ok] - 剩余：209
# https://www.rockauto.com/en/parts/bbb+industries,11004,alternator+/+generator,2412  <->  [ok] - 剩余：208
# https://www.rockauto.com/en/parts/bbb+industries,14905,alternator+/+generator,2412  <->  [ok] - 剩余：207
# https://www.rockauto.com/en/parts/bbb+industries,13816,alternator+/+generator,2412  <->  [ok] - 剩余：206
# https://www.rockauto.com/en/parts/bbb+industries,13967,alternator+/+generator,2412  <->  [ok] - 剩余：205
# https://www.rockauto.com/en/parts/bbb+industries,11181,alternator+/+generator,2412  <->  [ok] - 剩余：204
# https://www.rockauto.com/en/parts/bbb+industries,11098,alternator+/+generator,2412  <->  [ok] - 剩余：203
# https://www.rockauto.com/en/parts/bbb+industries,11255,alternator+/+generator,2412  <->  [ok] - 剩余：202
# https://www.rockauto.com/en/parts/bbb+industries,11329,alternator+/+generator,2412  <->  [ok] - 剩余：201
# https://www.rockauto.com/en/parts/bbb+industries,11696,alternator+/+generator,2412  <->  [ok] - 剩余：200
# https://www.rockauto.com/en/parts/bbb+industries,12884,alternator+/+generator,2412  <->  [ok] - 剩余：199
# https://www.rockauto.com/en/parts/bbb+industries,13534,alternator+/+generator,2412  <->  [ok] - 剩余：198
# https://www.rockauto.com/en/parts/bbb+industries,13574,alternator+/+generator,2412  <->  [ok] - 剩余：197
# https://www.rockauto.com/en/parts/bbb+industries,13709,alternator+/+generator,2412  <->  [ok] - 剩余：196
# https://www.rockauto.com/en/parts/bbb+industries,11337,alternator+/+generator,2412  <->  [ok] - 剩余：195
# https://www.rockauto.com/en/parts/bbb+industries,13784,alternator+/+generator,2412  <->  [ok] - 剩余：194
# https://www.rockauto.com/en/parts/bbb+industries,13800,alternator+/+generator,2412  <->  [ok] - 剩余：193
# https://www.rockauto.com/en/parts/wai+global,44010N,alternator+/+generator,2412  <->  [ok] - 剩余：192
# https://www.rockauto.com/en/parts/bbb+industries,13990,alternator+/+generator,2412  <->  [ok] - 剩余：191
# https://www.rockauto.com/en/parts/bbb+industries,13986,alternator+/+generator,2412  <->  [ok] - 剩余：190
# https://www.rockauto.com/en/parts/bbb+industries,14428,alternator+/+generator,2412  <->  [ok] - 剩余：189
# https://www.rockauto.com/en/parts/bbb+industries,11638,alternator+/+generator,2412  <->  [ok] - 剩余：188
# https://www.rockauto.com/en/parts/bbb+industries,13526,alternator+/+generator,2412  <->  [ok] - 剩余：187
# https://www.rockauto.com/en/parts/bbb+industries,11710,alternator+/+generator,2412  <->  [ok] - 剩余：186
# https://www.rockauto.com/en/parts/bbb+industries,13863,alternator+/+generator,2412  <->  [ok] - 剩余：185
# https://www.rockauto.com/en/parts/bbb+industries,13406,alternator+/+generator,2412  <->  [ok] - 剩余：184
# https://www.rockauto.com/en/parts/bbb+industries,13595,alternator+/+generator,2412  <->  [ok] - 剩余：183
# https://www.rockauto.com/en/parts/bbb+industries,13947,alternator+/+generator,2412  <->  [ok] - 剩余：182
# https://www.rockauto.com/en/parts/bbb+industries,14661,alternator+/+generator,2412  <->  [ok] - 剩余：181
# https://www.rockauto.com/en/parts/bbb+industries,14597,alternator+/+generator,2412  <->  [ok] - 剩余：180
# https://www.rockauto.com/en/parts/bbb+industries,13825,alternator+/+generator,2412  <->  [ok] - 剩余：179
# https://www.rockauto.com/en/parts/bbb+industries,11209,alternator+/+generator,2412  <->  [ok] - 剩余：178
# https://www.rockauto.com/en/parts/bbb+industries,14855,alternator+/+generator,2412  <->  [ok] - 剩余：177
# https://www.rockauto.com/en/parts/bbb+industries,11131,alternator+/+generator,2412  <->  [ok] - 剩余：176
# https://www.rockauto.com/en/parts/bbb+industries,11014,alternator+/+generator,2412  <->  [ok] - 剩余：175
# https://www.rockauto.com/en/parts/bbb+industries,11022,alternator+/+generator,2412  <->  [ok] - 剩余：174
# https://www.rockauto.com/en/parts/bbb+industries,23346,alternator+/+generator,2412  <->  [ok] - 剩余：173
# https://www.rockauto.com/en/parts/bbb+industries,13520,alternator+/+generator,2412  <->  [ok] - 剩余：172
# https://www.rockauto.com/en/parts/bbb+industries,8287P79,alternator+/+generator,2412  <->  [ok] - 剩余：171
# https://www.rockauto.com/en/parts/bbb+industries,11454,alternator+/+generator,2412  <->  [ok] - 剩余：170
# https://www.rockauto.com/en/parts/bbb+industries,11464,alternator+/+generator,2412  <->  [ok] - 剩余：169
# https://www.rockauto.com/en/parts/bbb+industries,11438,alternator+/+generator,2412  <->  [ok] - 剩余：168
# https://www.rockauto.com/en/parts/bbb+industries,14434,alternator+/+generator,2412  <->  [ok] - 剩余：167
# https://www.rockauto.com/en/parts/bbb+industries,11192,alternator+/+generator,2412  <->  [ok] - 剩余：166
# https://www.rockauto.com/en/parts/bbb+industries,11524,alternator+/+generator,2412  <->  [ok] - 剩余：165
# https://www.rockauto.com/en/parts/bbb+industries,11535,alternator+/+generator,2412  <->  [ok] - 剩余：164
# https://www.rockauto.com/en/parts/bbb+industries,11650,alternator+/+generator,2412  <->  [ok] - 剩余：163
# https://www.rockauto.com/en/parts/bbb+industries,11659,alternator+/+generator,2412  <->  [ok] - 剩余：162
# https://www.rockauto.com/en/parts/bbb+industries,11934,alternator+/+generator,2412  <->  [ok] - 剩余：161
# https://www.rockauto.com/en/parts/bbb+industries,11600,alternator+/+generator,2412  <->  [ok] - 剩余：160
# https://www.rockauto.com/en/parts/bbb+industries,11674,alternator+/+generator,2412  <->  [ok] - 剩余：159
# https://www.rockauto.com/en/parts/bbb+industries,13352,alternator+/+generator,2412  <->  [ok] - 剩余：158
# https://www.rockauto.com/en/parts/bbb+industries,13732,alternator+/+generator,2412  <->  [ok] - 剩余：157
# https://www.rockauto.com/en/parts/bbb+industries,13447,alternator+/+generator,2412  <->  [ok] - 剩余：156
# https://www.rockauto.com/en/parts/bbb+industries,11490,alternator+/+generator,2412  <->  [ok] - 剩余：155
# https://www.rockauto.com/en/parts/wai+global,7742N,alternator+/+generator,2412  <->  [ok] - 剩余：154
# https://www.rockauto.com/en/parts/wai+global,7613N,alternator+/+generator,2412  <->  [ok] - 剩余：153
# https://www.rockauto.com/en/parts/wai+global,7772N,alternator+/+generator,2412  <->  [ok] - 剩余：152
# https://www.rockauto.com/en/parts/wai+global,7760N,alternator+/+generator,2412  <->  [ok] - 剩余：151
# https://www.rockauto.com/en/parts/wai+global,7773NHO,alternator+/+generator,2412  <->  [ok] - 剩余：150
# https://www.rockauto.com/en/parts/wai+global,7776N0G,alternator+/+generator,2412  <->  [ok] - 剩余：149
# https://www.rockauto.com/en/parts/wai+global,7776NHO,alternator+/+generator,2412  <->  [ok] - 剩余：148
# https://www.rockauto.com/en/parts/wai+global,7788N,alternator+/+generator,2412  <->  [ok] - 剩余：147
# https://www.rockauto.com/en/parts/wai+global,8165NHO,alternator+/+generator,2412  <->  [ok] - 剩余：146
# https://www.rockauto.com/en/parts/wai+global,8418N,alternator+/+generator,2412  <->  [ok] - 剩余：145
# https://www.rockauto.com/en/parts/wai+global,8484N,alternator+/+generator,2412  <->  [ok] - 剩余：144
# https://www.rockauto.com/en/parts/wai+global,8225N,alternator+/+generator,2412  <->  [ok] - 剩余：143
# https://www.rockauto.com/en/parts/wai+global,8517N,alternator+/+generator,2412  <->  [ok] - 剩余：142
# https://www.rockauto.com/en/parts/wai+global,13622N,alternator+/+generator,2412  <->  [ok] - 剩余：141
# https://www.rockauto.com/en/parts/bbb+industries,11257,alternator+/+generator,2412  <->  [ok] - 剩余：140
# https://www.rockauto.com/en/parts/wai+global,14668N,alternator+/+generator,2412  <->  [ok] - 剩余：139
# https://www.rockauto.com/en/parts/wai+global,13616N,alternator+/+generator,2412  <->  [ok] - 剩余：138
# https://www.rockauto.com/en/parts/wai+global,7929N1,alternator+/+generator,2412  <->  [ok] - 剩余：137
# https://www.rockauto.com/en/parts/wai+global,13890N,alternator+/+generator,2412  <->  [ok] - 剩余：136
# https://www.rockauto.com/en/parts/wai+global,8311N,alternator+/+generator,2412  <->  [ok] - 剩余：135
# https://www.rockauto.com/en/parts/wai+global,13697N,alternator+/+generator,2412  <->  [ok] - 剩余：134
# https://www.rockauto.com/en/parts/wai+global,13752N,alternator+/+generator,2412  <->  [ok] - 剩余：133
# https://www.rockauto.com/en/parts/wai+global,13731N,alternator+/+generator,2412  <->  [ok] - 剩余：132
# https://www.rockauto.com/en/parts/wai+global,14390N,alternator+/+generator,2412  <->  [ok] - 剩余：131
# https://www.rockauto.com/en/parts/wai+global,8027N,alternator+/+generator,2412  <->  [ok] - 剩余：130
# https://www.rockauto.com/en/parts/wai+global,13895N,alternator+/+generator,2412  <->  [ok] - 剩余：129
# https://www.rockauto.com/en/parts/wai+global,7294SEN,alternator+/+generator,2412  <->  [ok] - 剩余：128
# https://www.rockauto.com/en/parts/wai+global,13899N,alternator+/+generator,2412  <->  [ok] - 剩余：127
# https://www.rockauto.com/en/parts/wai+global,7765N,alternator+/+generator,2412  <->  [ok] - 剩余：126
# https://www.rockauto.com/en/parts/wai+global,7684N,alternator+/+generator,2412  <->  [ok] - 剩余：125
# https://www.rockauto.com/en/parts/wai+global,7774N,alternator+/+generator,2412  <->  [ok] - 剩余：124
# https://www.rockauto.com/en/parts/wai+global,8206NHO,alternator+/+generator,2412  <->  [ok] - 剩余：123
# https://www.rockauto.com/en/parts/wai+global,7712N,alternator+/+generator,2412  <->  [ok] - 剩余：122
# https://www.rockauto.com/en/parts/wai+global,8250N,alternator+/+generator,2412  <->  [ok] - 剩余：121
# https://www.rockauto.com/en/parts/wai+global,7850N,alternator+/+generator,2412  <->  [ok] - 剩余：120
# https://www.rockauto.com/en/parts/wai+global,8254N,alternator+/+generator,2412  <->  [ok] - 剩余：119
# https://www.rockauto.com/en/parts/wai+global,8073N,alternator+/+generator,2412  <->  [ok] - 剩余：118
# https://www.rockauto.com/en/parts/wai+global,8292NDR,alternator+/+generator,2412  <->  [ok] - 剩余：117
# https://www.rockauto.com/en/parts/wai+global,11767N,alternator+/+generator,2412  <->  [ok] - 剩余：116
# https://www.rockauto.com/en/parts/wai+global,13154N,alternator+/+generator,2412  <->  [ok] - 剩余：115
# https://www.rockauto.com/en/parts/wai+global,13277N,alternator+/+generator,2412  <->  [ok] - 剩余：114
# https://www.rockauto.com/en/parts/wai+global,12716N,alternator+/+generator,2412  <->  [ok] - 剩余：113
# https://www.rockauto.com/en/parts/wai+global,13301N,alternator+/+generator,2412  <->  [ok] - 剩余：112
# https://www.rockauto.com/en/parts/wai+global,7917N,alternator+/+generator,2412  <->  [ok] - 剩余：111
# https://www.rockauto.com/en/parts/wai+global,13407N,alternator+/+generator,2412  <->  [ok] - 剩余：110
# https://www.rockauto.com/en/parts/wai+global,13397N,alternator+/+generator,2412  <->  [ok] - 剩余：109
# https://www.rockauto.com/en/parts/wai+global,13455N,alternator+/+generator,2412  <->  [ok] - 剩余：108
# https://www.rockauto.com/en/parts/wai+global,13577N,alternator+/+generator,2412  <->  [ok] - 剩余：107
# https://www.rockauto.com/en/parts/wai+global,13744N,alternator+/+generator,2412  <->  [ok] - 剩余：106
# https://www.rockauto.com/en/parts/wai+global,11240N6G2,alternator+/+generator,2412  <->  [ok] - 剩余：105
# https://www.rockauto.com/en/parts/wai+global,13596N,alternator+/+generator,2412  <->  [ok] - 剩余：104
# https://www.rockauto.com/en/parts/wai+global,13797N,alternator+/+generator,2412  <->  [ok] - 剩余：103
# https://www.rockauto.com/en/parts/wai+global,13492N,alternator+/+generator,2412  <->  [ok] - 剩余：102
# https://www.rockauto.com/en/parts/wai+global,13750N,alternator+/+generator,2412  <->  [ok] - 剩余：101
# https://www.rockauto.com/en/parts/wai+global,13812N,alternator+/+generator,2412  <->  [ok] - 剩余：100
# https://www.rockauto.com/en/parts/wai+global,14783N,alternator+/+generator,2412  <->  [ok] - 剩余：99
# https://www.rockauto.com/en/parts/wai+global,14648N,alternator+/+generator,2412  <->  [ok] - 剩余：98
# https://www.rockauto.com/en/parts/wai+global,14735N,alternator+/+generator,2412  <->  [ok] - 剩余：97
# https://www.rockauto.com/en/parts/wai+global,14813N,alternator+/+generator,2412  <->  [ok] - 剩余：96
# https://www.rockauto.com/en/parts/wai+global,14849N,alternator+/+generator,2412  <->  [ok] - 剩余：95
# https://www.rockauto.com/en/parts/wai+global,14931N,alternator+/+generator,2412  <->  [ok] - 剩余：94
# https://www.rockauto.com/en/parts/wai+global,7294SECN,alternator+/+generator,2412  <->  [ok] - 剩余：93
# https://www.rockauto.com/en/parts/wai+global,7127SEN,alternator+/+generator,2412  <->  [ok] - 剩余：92
# https://www.rockauto.com/en/parts/wai+global,7612N,alternator+/+generator,2412  <->  [ok] - 剩余：91
# https://www.rockauto.com/en/parts/wai+global,7138N,alternator+/+generator,2412  <->  [ok] - 剩余：90
# https://www.rockauto.com/en/parts/wai+global,23297N,alternator+/+generator,2412  <->  [ok] - 剩余：89
# https://www.rockauto.com/en/parts/wai+global,7613NLC,alternator+/+generator,2412  <->  [ok] - 剩余：88
# https://www.rockauto.com/en/parts/wai+global,7746N0G,alternator+/+generator,2412  <->  [ok] - 剩余：87
# https://www.rockauto.com/en/parts/wai+global,13507N,alternator+/+generator,2412  <->  [ok] - 剩余：86
# https://www.rockauto.com/en/parts/wai+global,7751N,alternator+/+generator,2412  <->  [ok] - 剩余：85
# https://www.rockauto.com/en/parts/wai+global,7764N0G,alternator+/+generator,2412  <->  [ok] - 剩余：84
# https://www.rockauto.com/en/parts/wai+global,7764NHO,alternator+/+generator,2412  <->  [ok] - 剩余：83
# https://www.rockauto.com/en/parts/wai+global,7768N0G,alternator+/+generator,2412  <->  [ok] - 剩余：82
# https://www.rockauto.com/en/parts/wai+global,13479N,alternator+/+generator,2412  <->  [ok] - 剩余：81
# https://www.rockauto.com/en/parts/wai+global,7858N,alternator+/+generator,2412  <->  [ok] - 剩余：80
# https://www.rockauto.com/en/parts/wai+global,7795NHO,alternator+/+generator,2412  <->  [ok] - 剩余：79
# https://www.rockauto.com/en/parts/wai+global,7792N,alternator+/+generator,2412  <->  [ok] - 剩余：78
# https://www.rockauto.com/en/parts/wai+global,7933N,alternator+/+generator,2412  <->  [ok] - 剩余：77
# https://www.rockauto.com/en/parts/wai+global,8222N,alternator+/+generator,2412  <->  [ok] - 剩余：76
# https://www.rockauto.com/en/parts/wai+global,8229N,alternator+/+generator,2412  <->  [ok] - 剩余：75
# https://www.rockauto.com/en/parts/wai+global,8229NHO,alternator+/+generator,2412  <->  [ok] - 剩余：74
# https://www.rockauto.com/en/parts/wai+global,7769N,alternator+/+generator,2412  <->  [ok] - 剩余：73
# https://www.rockauto.com/en/parts/wai+global,7960N,alternator+/+generator,2412  <->  [ok] - 剩余：72
# https://www.rockauto.com/en/parts/wai+global,7787NHO,alternator+/+generator,2412  <->  [ok] - 剩余：71
# https://www.rockauto.com/en/parts/wai+global,7767N,alternator+/+generator,2412  <->  [ok] - 剩余：70
# https://www.rockauto.com/en/parts/wai+global,8292NDR220A,alternator+/+generator,2412  <->  [ok] - 剩余：69
# https://www.rockauto.com/en/parts/wai+global,8308N,alternator+/+generator,2412  <->  [ok] - 剩余：68
# https://www.rockauto.com/en/parts/wai+global,11125N,alternator+/+generator,2412  <->  [ok] - 剩余：67
# https://www.rockauto.com/en/parts/wai+global,12097N,alternator+/+generator,2412  <->  [ok] - 剩余：66
# https://www.rockauto.com/en/parts/wai+global,8315NHO,alternator+/+generator,2412  <->  [ok] - 剩余：65
# https://www.rockauto.com/en/parts/wai+global,11774N,alternator+/+generator,2412  <->  [ok] - 剩余：64
# https://www.rockauto.com/en/parts/wai+global,12490N,alternator+/+generator,2412  <->  [ok] - 剩余：63
# https://www.rockauto.com/en/parts/wai+global,13107N,alternator+/+generator,2412  <->  [ok] - 剩余：62
# https://www.rockauto.com/en/parts/wai+global,7750N0G,alternator+/+generator,2412  <->  [ok] - 剩余：61
# https://www.rockauto.com/en/parts/wai+global,13208N,alternator+/+generator,2412  <->  [ok] - 剩余：60
# https://www.rockauto.com/en/parts/wai+global,13238N,alternator+/+generator,2412  <->  [ok] - 剩余：59
# https://www.rockauto.com/en/parts/wai+global,13276N,alternator+/+generator,2412  <->  [ok] - 剩余：58
# https://www.rockauto.com/en/parts/wai+global,7777N,alternator+/+generator,2412  <->  [ok] - 剩余：57
# https://www.rockauto.com/en/parts/wai+global,13294N,alternator+/+generator,2412  <->  [ok] - 剩余：56
# https://www.rockauto.com/en/parts/wai+global,13310N,alternator+/+generator,2412  <->  [ok] - 剩余：55
# https://www.rockauto.com/en/parts/wai+global,11527N,alternator+/+generator,2412  <->  [ok] - 剩余：54
# https://www.rockauto.com/en/parts/wai+global,13312N,alternator+/+generator,2412  <->  [ok] - 剩余：53
# https://www.rockauto.com/en/parts/wai+global,13323N,alternator+/+generator,2412  <->  [ok] - 剩余：52
# https://www.rockauto.com/en/parts/wai+global,13339N,alternator+/+generator,2412  <->  [ok] - 剩余：51
# https://www.rockauto.com/en/parts/wai+global,13256N,alternator+/+generator,2412  <->  [ok] - 剩余：50
# https://www.rockauto.com/en/parts/wai+global,13486N,alternator+/+generator,2412  <->  [ok] - 剩余：49
# https://www.rockauto.com/en/parts/wai+global,13564N,alternator+/+generator,2412  <->  [ok] - 剩余：48
# https://www.rockauto.com/en/parts/wai+global,13393N,alternator+/+generator,2412  <->  [ok] - 剩余：47
# https://www.rockauto.com/en/parts/wai+global,13357N,alternator+/+generator,2412  <->  [ok] - 剩余：46
# https://www.rockauto.com/en/parts/wai+global,8292NHO,alternator+/+generator,2412  <->  [ok] - 剩余：45
# https://www.rockauto.com/en/parts/wai+global,13631N,alternator+/+generator,2412  <->  [ok] - 剩余：44
# https://www.rockauto.com/en/parts/wai+global,13642N,alternator+/+generator,2412  <->  [ok] - 剩余：43
# https://www.rockauto.com/en/parts/wai+global,13834N,alternator+/+generator,2412  <->  [ok] - 剩余：42
# https://www.rockauto.com/en/parts/wai+global,14449N,alternator+/+generator,2412  <->  [ok] - 剩余：41
# https://www.rockauto.com/en/parts/wai+global,13332N,alternator+/+generator,2412  <->  [ok] - 剩余：40
# https://www.rockauto.com/en/parts/wai+global,13807N,alternator+/+generator,2412  <->  [ok] - 剩余：39
# https://www.rockauto.com/en/parts/wai+global,14684N,alternator+/+generator,2412  <->  [ok] - 剩余：38
# https://www.rockauto.com/en/parts/wai+global,13356N8G,alternator+/+generator,2412  <->  [ok] - 剩余：37
# https://www.rockauto.com/en/parts/wai+global,13711N,alternator+/+generator,2412  <->  [ok] - 剩余：36
# https://www.rockauto.com/en/parts/wai+global,14778N,alternator+/+generator,2412  <->  [ok] - 剩余：35
# https://www.rockauto.com/en/parts/wai+global,14820N,alternator+/+generator,2412  <->  [ok] - 剩余：34
# https://www.rockauto.com/en/parts/wai+global,7122N,alternator+/+generator,2412  <->  [ok] - 剩余：33
# https://www.rockauto.com/en/parts/wai+global,71273R,alternator+/+generator,2412  <->  [ok] - 剩余：32
# https://www.rockauto.com/en/parts/wai+global,7262N,alternator+/+generator,2412  <->  [ok] - 剩余：31
# https://www.rockauto.com/en/parts/wai+global,7613N,alternator+/+generator,2412  <->  [ok] - 剩余：30
# https://www.rockauto.com/en/parts/wai+global,7773NHO,alternator+/+generator,2412  <->  [ok] - 剩余：29
# https://www.rockauto.com/en/parts/wai+global,7742N,alternator+/+generator,2412  <->  [ok] - 剩余：28
# https://www.rockauto.com/en/parts/wai+global,7760N,alternator+/+generator,2412  <->  [ok] - 剩余：27
# https://www.rockauto.com/en/parts/wai+global,7772N,alternator+/+generator,2412  <->  [ok] - 剩余：26
# https://www.rockauto.com/en/parts/wai+global,7776N0G,alternator+/+generator,2412  <->  [ok] - 剩余：25
# https://www.rockauto.com/en/parts/wai+global,7788N,alternator+/+generator,2412  <->  [ok] - 剩余：24
# https://www.rockauto.com/en/parts/wai+global,7929N1,alternator+/+generator,2412  <->  [ok] - 剩余：23
# https://www.rockauto.com/en/parts/wai+global,8206NHO,alternator+/+generator,2412  <->  [ok] - 剩余：22
# https://www.rockauto.com/en/parts/wai+global,7776NHO,alternator+/+generator,2412  <->  [ok] - 剩余：21
# https://www.rockauto.com/en/parts/wai+global,8165NHO,alternator+/+generator,2412  <->  [ok] - 剩余：20
# https://www.rockauto.com/en/parts/wai+global,8225N,alternator+/+generator,2412  <->  [ok] - 剩余：19
# https://www.rockauto.com/en/parts/wai+global,13724N,alternator+/+generator,2412  <->  [ok] - 剩余：18
# https://www.rockauto.com/en/parts/wai+global,8073N,alternator+/+generator,2412  <->  [ok] - 剩余：17
# https://www.rockauto.com/en/parts/wai+global,8484N,alternator+/+generator,2412  <->  [ok] - 剩余：16
# https://www.rockauto.com/en/parts/wai+global,8418N,alternator+/+generator,2412  <->  [ok] - 剩余：15
# https://www.rockauto.com/en/parts/wai+global,8517N,alternator+/+generator,2412  <->  [ok] - 剩余：14
# https://www.rockauto.com/en/parts/wai+global,13616N,alternator+/+generator,2412  <->  [ok] - 剩余：13
# https://www.rockauto.com/en/parts/wai+global,14668N,alternator+/+generator,2412  <->  [ok] - 剩余：12
# https://www.rockauto.com/en/parts/bbb+industries,N7791SD,alternator+/+generator,2412  <->  [ok] - 剩余：11
# https://www.rockauto.com/en/parts/wai+global,8027N,alternator+/+generator,2412  <->  [ok] - 剩余：10
# https://www.rockauto.com/en/parts/wai+global,8311N,alternator+/+generator,2412  <->  [ok] - 剩余：9
# https://www.rockauto.com/en/parts/bbb+industries,N8238,alternator+/+generator,2412  <->  [ok] - 剩余：8
# https://www.rockauto.com/en/parts/bbb+industries,N8307HO,alternator+/+generator,2412  <->  [ok] - 剩余：7
# https://www.rockauto.com/en/parts/bbb+industries,N8489,alternator+/+generator,2412  <->  [ok] - 剩余：6
# https://www.rockauto.com/en/parts/bbb+industries,N8226,alternator+/+generator,2412  <->  [ok] - 剩余：5
# https://www.rockauto.com/en/parts/wai+global,13622N,alternator+/+generator,2412  <->  [ok] - 剩余：4
# https://www.rockauto.com/en/parts/bbb+industries,N8107,alternator+/+generator,2412  <->  [ok] - 剩余：3
# https://www.rockauto.com/en/parts/bbb+industries,N7797HO,alternator+/+generator,2412  <->  [ok] - 剩余：2
# https://www.rockauto.com/en/parts/bbb+industries,8226P50,alternator+/+generator,2412  <->  [ok] - 剩余：1
# https://www.rockauto.com/en/parts/bbb+industries,N8237,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N7791HO,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N13957,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N11516,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/wai+global,8540N,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N8478HO,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N13745,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N8156,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/wai+global,13890N,alternator+/+generator,2412  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/bbb+industries,N8283,alternator+/+generator,2412  <->  [ok] - 剩余：0
#
# 搞定
