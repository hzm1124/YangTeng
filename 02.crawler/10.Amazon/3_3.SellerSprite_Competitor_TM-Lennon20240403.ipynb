# %%
import os

# %%
list_file = list(os.walk('./sellersprite_competitor'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 420

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./sellersprite_competitor/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['ASIN'], ascending=[True]).reset_index(drop=True)
df.to_excel('./sellersprite_competitor.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 420/420 [00:01<00:00, 299.22it/s]
#            ASIN  标识       父ASIN            品牌  \
# 0    B006WQR9CS      B006WQR9CS  Detroit Axle
# 1    B006WQRAA4   V  B006WQRAA4  Detroit Axle
# 2    B006WQRAFO      B006WQRAFO  Detroit Axle
# 3    B006WQRAR2      B006WQRAR2  Detroit Axle
# 4    B006WQRAWM   V  B006WQRAWM  Detroit Axle
# ..          ...  ..         ...           ...
# 415  B09QBWSCTZ      B09QBWSCTZ  Detroit Axle
# 416  B0BMT4J9TK      B0BMT4J9TK  Detroit Axle
# 417  B0BN79TY4X  A+  B0BN79TY4X  Detroit Axle
# 418  B0BN7B9WLJ  A+  B0BN7B9WLJ  Detroit Axle
# 419  B0BN9VG5RQ      B0BN9VG5RQ  Detroit Axle
#
#                                                   品牌链接    大类BSR排名 近7天BSR增长数  \
# 0    https://www.amazon.com/stores/DetroitAxle/page...    624,586         -
# 1    https://www.amazon.com/stores/DetroitAxle/page...    672,258   421,058
# 2    https://www.amazon.com/stores/DetroitAxle/page...  1,186,762         -
# ...
