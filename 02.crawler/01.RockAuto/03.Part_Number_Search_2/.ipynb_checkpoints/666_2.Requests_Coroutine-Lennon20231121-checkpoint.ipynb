# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../../00.module')
import UA
import Proxy

# = = = = = = = = = = = = = = =

import pandas as pd

df = pd.read_excel('./part.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_info = df['Info'].tolist()

print('总数量：' + str(len(list_info)))
print()

# = = = = = = = = = = = = = = =

df = pd.DataFrame()

# = = = = = = = = = = = = = = =

import requests

from bs4 import BeautifulSoup

from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for info in list_info:
    work.put_nowait(info)

def crawler():
    global df
    
    while not work.empty():
        info = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(31):
            try:
                resp = requests.get(info,
                                     headers=UA.get_User_Agent_Requests(),
                                     proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =

                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = =
                
                html = etree.HTML(str(soup))

                list_tr = html.xpath('//table[@class="moreinfotable"]/tr')
                
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'status': 'ok',
                                         'Info': info}])
                
                for _ in list_tr[1:]:
                    df_temp.loc[0, _.xpath('./td[1]/text()')[0].lower()] = _.xpath('./td[2]/text()')[0]
                
                status = 'ok'
                
                break
                
            except:
                time.sleep(1)
                continue

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'Info': info}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        print(info +  '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df = df.drop_duplicates(ignore_index=True)

print()
print('爬虫输出中')
df.to_excel('./specification_' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
print()
print('爬虫结束')
# Out:
# 总数量：13
#
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8305008  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=9658988  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8921208  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8304992  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=11158045  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=9658980  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8304960  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8305000  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=9658984  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8921200  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=10454500  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8304976  <->  [ok] - 剩余数量：0
# https://www.rockauto.com/en/moreinfo.php?pt=5756&pk=8921212  <->  [ok] - 剩余数量：0
#
# 爬虫输出中
#
# 爬虫结束
