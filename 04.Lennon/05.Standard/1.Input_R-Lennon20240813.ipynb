# %%
import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

b = 0
while True:
    b += 1
    print(b)
    try:
        resp = requests.get('https://ecatalog.smpcorp.com/V2/STD/api/part/partsearchfilter?filter=-All-&filterType=n&searchType=p&catFilter=-All-&yearFilter=-All-&makeFilter=-All-&modelFilter=-All-&engineFilter=-All-&attrCodeFilter=-All-&attrValueFilter=-All-&plkEngineMakeFilter=-All-&plkEngineModelFilter=-All-&plkEngineDispFilter=-All-',
                             headers=get_header(),
                             proxies=get_proxy(),
                             timeout=(10, 10))
        
        if resp.status_code == 200:
            break
    except:
        continue

resp
# Out:
# 1
# <Response [200]>

# %%
json_ = resp.json()

json_
# Out:
# {'productCategoryShort': [{'webColumn_Id': 359500,
#    'categoryName_en': '4WD Hub Locking Actuator Vacuum Hose',
#    'prodCategory_ASort': 10010},
#   {'webColumn_Id': 349200,
#    'categoryName_en': 'A/C Compressor Cut-Off Relay Connector',
#    'prodCategory_ASort': 10020},
#   {'webColumn_Id': 344300,
#    'categoryName_en': 'A/C Compressor Wiring Harness',
#    'prodCategory_ASort': 10030},
#   {'webColumn_Id': 344600,
#    'categoryName_en': 'A/C Power Module',
#    'prodCategory_ASort': 10040},
#   {'webColumn_Id': 321800,
#    'categoryName_en': 'ABS Sensor Harness Repair Kit',
#    'prodCategory_ASort': 10070},
#   {'webColumn_Id': 341700,
#    'categoryName_en': 'ABS Speed Sensor Ring - Front',
#    'prodCategory_ASort': 10080},
#   {'webColumn_Id': 341800,
#    'categoryName_en': 'ABS Speed Sensor Ring - Rear',
#    'prodCategory_ASort': 10090},
#   {'webColumn_Id': 264900,
#    'categoryName_en': 'ABS Speed Sensor Wire Harness',
#    'prodCategory_ASort': 10100},
#   {'webColumn_Id': 307800,
#    'categoryName_en': 'Accelerator Pump Check Valve',
#    'prodCategory_ASort': 10120},
#   {'webColumn_Id': 7150,
#    'categoryName_en': 'Air Cleaner Check Valve',
#    'prodCategory_ASort': 10150},
#   {'webColumn_Id': 8150,
#    'categoryName_en': 'Air Cleaner Inlet Hose',
#    'prodCategory_ASort': 10170},
#   {'webColumn_Id': 241700,
#    'categoryName_en': 'Air Delay Valve',
#    'prodCategory_ASort': 10190},
#   {'webColumn_Id': 343600,
#    'categoryName_en': 'Air Filter Indicator',
#    'prodCategory_ASort': 10200},
#   {'webColumn_Id': 270900,
#    'categoryName_en': 'Air Pipe Gasket',
#    'prodCategory_ASort': 10240},
#   {'webColumn_Id': 998569,
#    'categoryName_en': 'Air Pump - New',
#    'prodCategory_ASort': 10250},
#   {'webColumn_Id': 327200,
#    'categoryName_en': 'Air Suspension Compressor',
#    'prodCategory_ASort': 10260},
#   {'webColumn_Id': 272900,
#    'categoryName_en': 'Air Suspension Spring Solenoid',
#    'prodCategory_ASort': 10270},
#   {'webColumn_Id': 13350,
#    'categoryName_en': 'Alt Bearing Tolerance Ring',
#    'prodCategory_ASort': 10280},
#   {'webColumn_Id': 14150,
#    'categoryName_en': 'Alt Terminal Hardware Kit',
#    'prodCategory_ASort': 10290},
#   {'webColumn_Id': 15100,
#    'categoryName_en': 'Alternator / Generator Brush Set',
#    'prodCategory_ASort': 10300},
#   {'webColumn_Id': 13150,
#    'categoryName_en': 'Alternator Bearing',
#    'prodCategory_ASort': 10340},
#   {'webColumn_Id': 301500,
#    'categoryName_en': 'Alternator Brush Holder Assembly',
#    'prodCategory_ASort': 10350},
#   {'webColumn_Id': 347500,
#    'categoryName_en': 'Alternator Bushing',
#    'prodCategory_ASort': 10360},
#   {'webColumn_Id': 15186,
#    'categoryName_en': 'Alternator Capacitor',
#    'prodCategory_ASort': 10370},
#   {'webColumn_Id': 307600,
#    'categoryName_en': 'Alternator Decoupler Pulley',
#    'prodCategory_ASort': 10380},
#   {'webColumn_Id': 308400,
#    'categoryName_en': 'Alternator Decoupler Pulley Tool Kit',
#    'prodCategory_ASort': 10390},
#   {'webColumn_Id': 292100,
#    'categoryName_en': 'Alternator Diode - Negative',
#    'prodCategory_ASort': 10400},
#   {'webColumn_Id': 292200,
#    'categoryName_en': 'Alternator Diode - Positive',
#    'prodCategory_ASort': 10410},
#   {'webColumn_Id': 292000,
#    'categoryName_en': 'Alternator Diode - Trio',
#    'prodCategory_ASort': 10420},
#   {'webColumn_Id': 292300,
#    'categoryName_en': 'Alternator Rectifier',
#    'prodCategory_ASort': 10440},
#   {'webColumn_Id': 996084,
#    'categoryName_en': 'Alternator Repair Kit',
#    'prodCategory_ASort': 10450},
#   {'webColumn_Id': 13300,
#    'categoryName_en': 'Alternator Resistor',
#    'prodCategory_ASort': 10460},
#   {'webColumn_Id': 295500,
#    'categoryName_en': 'Alternator Rotor',
#    'prodCategory_ASort': 10470},
#   {'webColumn_Id': 295600,
#    'categoryName_en': 'Alternator Stator',
#    'prodCategory_ASort': 10490},
#   {'webColumn_Id': 353100,
#    'categoryName_en': 'Ambient Air Temperature Sensor Kit',
#    'prodCategory_ASort': 10500},
#   {'webColumn_Id': 294100,
#    'categoryName_en': 'Auto Transmission Governor Repair Kit',
#    'prodCategory_ASort': 10510},
#   {'webColumn_Id': 293700,
#    'categoryName_en': 'Auto Transmission Oil Cooler Thermostat',
#    'prodCategory_ASort': 10520},
#   {'webColumn_Id': 197100,
#    'categoryName_en': 'Auto Transmission Vacuum Modulator',
#    'prodCategory_ASort': 10530},
#   {'webColumn_Id': 349400,
#    'categoryName_en': 'Automatic Headlight Dimmer Relay Connector',
#    'prodCategory_ASort': 10540},
#   {'webColumn_Id': 326500,
#    'categoryName_en': 'Automatic Shifter Button',
#    'prodCategory_ASort': 10550},
#   {'webColumn_Id': 326200,
#    'categoryName_en': 'Automatic Shifter Button Cover',
#    'prodCategory_ASort': 10560},
#   {'webColumn_Id': 336900,
#    'categoryName_en': 'Automatic Transmission Conductor Plate',
#    'prodCategory_ASort': 10570},
#   {'webColumn_Id': 362500,
#    'categoryName_en': 'Automatic Transmission Oil Cooler',
#    'prodCategory_ASort': 10580},
#   {'webColumn_Id': 348600,
#    'categoryName_en': 'Automatic Transmission Oil Pump',
#    'prodCategory_ASort': 10590},
#   {'webColumn_Id': 321700,
#    'categoryName_en': 'Automatic Transmission Shift Bezel',
#    'prodCategory_ASort': 10600},
#   {'webColumn_Id': 17157,
#    'categoryName_en': 'Auxiliary Air Valve',
#    'prodCategory_ASort': 10620},
#   {'webColumn_Id': 303000,
#    'categoryName_en': 'Auxiliary Heater Control Module                             ',
#    'prodCategory_ASort': 10640},
#   {'webColumn_Id': 243300,
#    'categoryName_en': 'Auxiliary Heater Ignition Coil',
#    'prodCategory_ASort': 10650},
#   {'webColumn_Id': 340400,
#    'categoryName_en': 'Axle Shift Motor',
#    'prodCategory_ASort': 10670},
#   {'webColumn_Id': 20100,
#    'categoryName_en': 'Battery Cable',
#    'prodCategory_ASort': 10690},
#   {'webColumn_Id': 309400,
#    'categoryName_en': 'Battery Cable Bolt',
#    'prodCategory_ASort': 10700},
#   {'webColumn_Id': 355100,
#    'categoryName_en': 'Battery Terminal',
#    'prodCategory_ASort': 10710},
#   {'webColumn_Id': 349700,
#    'categoryName_en': 'Blower Motor Cut-Off Relay Connector',
#    'prodCategory_ASort': 10730},
#   {'webColumn_Id': 22100,
#    'categoryName_en': 'Blower Motor Resistor',
#    'prodCategory_ASort': 10750},
#   {'webColumn_Id': 346400,
#    'categoryName_en': 'Blower Motor Resistor Kit',
#    'prodCategory_ASort': 10760},
#   {'webColumn_Id': 263600,
#    'categoryName_en': 'Brake Indicator Lamp Driver Module',
#    'prodCategory_ASort': 10800},
#   {'webColumn_Id': 305500,
#    'categoryName_en': 'Camshaft Gear Installation Tool',
#    'prodCategory_ASort': 10840},
#   {'webColumn_Id': 27150,
#    'categoryName_en': 'Camshaft Interrupter',
#    'prodCategory_ASort': 10850},
#   {'webColumn_Id': 27200,
#    'categoryName_en': 'Camshaft Sensor Cover',
#    'prodCategory_ASort': 10860},
#   {'webColumn_Id': 350000,
#    'categoryName_en': 'Camshaft Sensor Kit',
#    'prodCategory_ASort': 10870},
#   {'webColumn_Id': 266200,
#    'categoryName_en': 'Camshaft Synchronizer',
#    'prodCategory_ASort': 10880},
#   {'webColumn_Id': 341900,
#    'categoryName_en': 'Camshaft Synchronizer Alignment Tool Kit',
#    'prodCategory_ASort': 10890},
#   {'webColumn_Id': 29100,
#    'categoryName_en': 'Canister Purge Solenoid',
#    'prodCategory_ASort': 10910},
#   {'webColumn_Id': 30100,
#    'categoryName_en': 'Canister Purge Valve',
#    'prodCategory_ASort': 10920},
#   {'webColumn_Id': 220900,
#    'categoryName_en': 'Canister Vent Solenoid',
#    'prodCategory_ASort': 10930},
#   {'webColumn_Id': 301400,
#    'categoryName_en': 'Canister Vent Solenoid Harness',
#    'prodCategory_ASort': 10940},
#   {'webColumn_Id': 328500,
#    'categoryName_en': 'Canister Vent Valve',
#    'prodCategory_ASort': 10960},
#   {'webColumn_Id': 998665,
#    'categoryName_en': 'Carburetor Flange Gasket',
#    'prodCategory_ASort': 10990},
#   {'webColumn_Id': 308000,
#    'categoryName_en': 'Carburetor Float',
#    'prodCategory_ASort': 11000},
#   {'webColumn_Id': 307900,
#    'categoryName_en': 'Carburetor Kit',
#    'prodCategory_ASort': 11010},
#   {'webColumn_Id': 335700,
#    'categoryName_en': 'Carburetor Needle And Seat',
#    'prodCategory_ASort': 11020},
#   {'webColumn_Id': 335800,
#    'categoryName_en': 'Carburetor Power Valve Kit',
#    'prodCategory_ASort': 11030},
#   {'webColumn_Id': 307700,
#    'categoryName_en': 'Carburetor Secondary Diaphragm',
#    'prodCategory_ASort': 11040},
#   {'webColumn_Id': 291000,
#    'categoryName_en': 'Center High Mount Stop Light Assembly',
#    'prodCategory_ASort': 11050},
#   {'webColumn_Id': 340500,
#    'categoryName_en': 'Charge Air Cooler',
#    'prodCategory_ASort': 11060},
#   {'webColumn_Id': 340700,
#    'categoryName_en': 'Choke Cover Gasket',
#    'prodCategory_ASort': 11070},
#   {'webColumn_Id': 296900,
#    'categoryName_en': 'Choke Pull Off',
#    'prodCategory_ASort': 11080},
#   {'webColumn_Id': 297000,
#    'categoryName_en': 'Choke Thermostat',
#    'prodCategory_ASort': 11100},
#   {'webColumn_Id': 309600,
#    'categoryName_en': 'Circuit Breaker',
#    'prodCategory_ASort': 11110},
#   {'webColumn_Id': 221000,
#    'categoryName_en': 'Clock Spring',
#    'prodCategory_ASort': 11150},
#   {'webColumn_Id': 326100,
#    'categoryName_en': 'Coil on Plug Boot',
#    'prodCategory_ASort': 11160},
#   {'webColumn_Id': 301900,
#    'categoryName_en': 'Coil On Plug Boot Kit',
#    'prodCategory_ASort': 11170},
#   {'webColumn_Id': 40100,
#    'categoryName_en': 'Cold Start Valve',
#    'prodCategory_ASort': 11180},
#   {'webColumn_Id': 264100,
#    'categoryName_en': 'Connector - A/C & Heater Blower Motor Switch',
#    'prodCategory_ASort': 11190},
#   {'webColumn_Id': 222400,
#    'categoryName_en': 'Connector - A/C & Heater Delay Relay',
#    'prodCategory_ASort': 11200},
#   {'webColumn_Id': 222500,
#    'categoryName_en': 'Connector - A/C & Heater Relay',
#    'prodCategory_ASort': 11210},
#   {'webColumn_Id': 148120,
#    'categoryName_en': 'Connector - A/C & Heater Switch',
#    'prodCategory_ASort': 11220},
#   {'webColumn_Id': 343800,
#    'categoryName_en': 'Connector - A/C and Heater Harness',
#    'prodCategory_ASort': 11250},
#   {'webColumn_Id': 329300,
#    'categoryName_en': 'Connector - A/C Auto Temperature Control Relay',
#    'prodCategory_ASort': 11270},
#   {'webColumn_Id': 222700,
#    'categoryName_en': 'Connector - A/C Blower Cut-Off Relay',
#    'prodCategory_ASort': 11280},
#   {'webColumn_Id': 238900,
#    'categoryName_en': 'Connector - A/C Clutch Coil',
#    'prodCategory_ASort': 11290},
#   {'webColumn_Id': 343900,
#    'categoryName_en': 'Connector - A/C Clutch Control Relay Harness',
#    'prodCategory_ASort': 11300},
#   {'webColumn_Id': 148112,
#    'categoryName_en': 'Connector - A/C Compressor',
#    'prodCategory_ASort': 11310},
#   {'webColumn_Id': 344100,
#    'categoryName_en': 'Connector - A/C Compressor Clutch Control Harness Ground',
#    'prodCategory_ASort': 11320},
#   {'webColumn_Id': 222800,
#    'categoryName_en': 'Connector - A/C Compressor Clutch Cut-Off Relay',
#    'prodCategory_ASort': 11330},
#   {'webColumn_Id': 148104,
#    'categoryName_en': 'Connector - A/C Compressor Clutch Relay',
#    'prodCategory_ASort': 11340},
#   {'webColumn_Id': 344200,
#    'categoryName_en': 'Connector - A/C Compressor Cut-Out Relay Harness',
#    'prodCategory_ASort': 11350},
#   {'webColumn_Id': 278900,
#    'categoryName_en': 'Connector - A/C Compressor Diode',
#    'prodCategory_ASort': 11360},
#   {'webColumn_Id': 316300,
#    'categoryName_en': 'Connector - A/C Compressor Hold Relay',
#    'prodCategory_ASort': 11370},
#   {'webColumn_Id': 317100,
#    'categoryName_en': 'Connector - A/C Compressor Throttle Cut-Off Relay',
#    'prodCategory_ASort': 11380},
#   {'webColumn_Id': 315300,
#    'categoryName_en': 'Connector - A/C Compressor Time Delay Relay',
#    'prodCategory_ASort': 11390},
#   {'webColumn_Id': 222900,
#    'categoryName_en': 'Connector - A/C Condenser Fan Motor Relay',
#    'prodCategory_ASort': 11400},
#   {'webColumn_Id': 344500,
#    'categoryName_en': 'Connector - A/C Condenser Fan Switch Harness',
#    'prodCategory_ASort': 11410},
#   {'webColumn_Id': 239400,
#    'categoryName_en': 'Connector - A/C Control Module',
#    'prodCategory_ASort': 11420},
#   {'webColumn_Id': 223000,
#    'categoryName_en': 'Connector - A/C Control Relay',
#    'prodCategory_ASort': 11440},
#   {'webColumn_Id': 311100,
#    'categoryName_en': 'Connector - A/C Cut-Off Switch',
#    'prodCategory_ASort': 11450},
#   {'webColumn_Id': 239600,
#    'categoryName_en': 'Connector - A/C Cycling Switch',
#    'prodCategory_ASort': 11460},
#   {'webColumn_Id': 239700,
#    'categoryName_en': 'Connector - A/C Electrical',
#    'prodCategory_ASort': 11470},
#   {'webColumn_Id': 358300,
#    'categoryName_en': 'Connector - A/C Evaporator Temperature Sensor',
#    'prodCategory_ASort': 11480},
#   {'webColumn_Id': 311900,
#    'categoryName_en': 'Connector - A/C Fast Idle Cut-Off Relay',
#    'prodCategory_ASort': 11490},
#   {'webColumn_Id': 279000,
#    'categoryName_en': 'Connector - A/C High Pressure Cut-Off Switch',
#    'prodCategory_ASort': 11500},
#   {'webColumn_Id': 318200,
#    'categoryName_en': 'Connector - A/C Low Pressure Cut-Out Switch',
#    'prodCategory_ASort': 11510},
#   {'webColumn_Id': 148644,
#    'categoryName_en': 'Connector - A/C Power Servo',
#    'prodCategory_ASort': 11520},
#   {'webColumn_Id': 240000,
#    'categoryName_en': 'Connector - A/C Pressure Switch',
#    'prodCategory_ASort': 11530},
#   {'webColumn_Id': 344700,
#    'categoryName_en': 'Connector - A/C Pressure Transducer',
#    'prodCategory_ASort': 11540},
#   {'webColumn_Id': 320300,
#    'categoryName_en': 'Connector - A/C Purge Relay',
#    'prodCategory_ASort': 11550},
#   {'webColumn_Id': 240200,
#    'categoryName_en': 'Connector - A/C Refrigerant Temperature Sensor',
#    'prodCategory_ASort': 11560},
#   {'webColumn_Id': 311400,
#    'categoryName_en': 'Connector - A/C Relay',
#    'prodCategory_ASort': 11570},
#   {'webColumn_Id': 316400,
#    'categoryName_en': 'Connector - A/C Selector Relay',
#    'prodCategory_ASort': 11580},
#   {'webColumn_Id': 240300,
#    'categoryName_en': 'Connector - A/C Solenoid',
#    'prodCategory_ASort': 11590},
#   {'webColumn_Id': 223300,
#    'categoryName_en': 'Connector - A/C Speed-Up Solenoid Relay',
#    'prodCategory_ASort': 11600},
#   {'webColumn_Id': 319800,
#    'categoryName_en': 'Connector - A/C Temperature Delay Relay',
#    'prodCategory_ASort': 11610},
#   {'webColumn_Id': 316500,
#    'categoryName_en': 'Connector - A/C Time Delay Relay',
#    'prodCategory_ASort': 11620},
#   {'webColumn_Id': 321000,
#    'categoryName_en': 'Connector - A/C Wiring Relay',
#    'prodCategory_ASort': 11630},
#   {'webColumn_Id': 223500,
#    'categoryName_en': 'Connector - ABS Control Module',
#    'prodCategory_ASort': 11650},
#   {'webColumn_Id': 241000,
#    'categoryName_en': 'Connector - ABS Control Module Relay',
#    'prodCategory_ASort': 11660},
#   {'webColumn_Id': 148148,
#    'categoryName_en': 'Connector - ABS Modulator Sensor',
#    'prodCategory_ASort': 11670},
#   {'webColumn_Id': 241200,
#    'categoryName_en': 'Connector - ABS Modulator Solenoid',
#    'prodCategory_ASort': 11680},
#   {'webColumn_Id': 279200,
#    'categoryName_en': 'Connector - ABS Pump',
#    'prodCategory_ASort': 11690},
#   {'webColumn_Id': 223600,
#    'categoryName_en': 'Connector - ABS Relay',
#    'prodCategory_ASort': 11700},
#   {'webColumn_Id': 279300,
#    'categoryName_en': 'Connector - ABS Speed Sensor',
#    'prodCategory_ASort': 11710},
#   {'webColumn_Id': 321100,
#    'categoryName_en': 'Connector - ABS Speed Sensor Wire Harness',
#    'prodCategory_ASort': 11720},
#   {'webColumn_Id': 241300,
#    'categoryName_en': 'Connector - ABS Switch',
#    'prodCategory_ASort': 11730},
#   {'webColumn_Id': 314600,
#    'categoryName_en': 'Connector - ABS Warning Lamp Relay',
#    'prodCategory_ASort': 11740},
#   {'webColumn_Id': 315800,
#    'categoryName_en': 'Connector - Acceleration Sensor',
#    'prodCategory_ASort': 11750},
#   {'webColumn_Id': 236900,
#    'categoryName_en': 'Connector - Accelerator Pedal Sensor',
#    'prodCategory_ASort': 11760},
#   {'webColumn_Id': 223700,
#    'categoryName_en': 'Connector - Accessory Delay Relay',
#    'prodCategory_ASort': 11770},
#   {'webColumn_Id': 357600,
#    'categoryName_en': 'Connector - Accessory Power Receptacle',
#    'prodCategory_ASort': 11780},
#   {'webColumn_Id': 148128,
#    'categoryName_en': 'Connector - Accessory Relay',
#    'prodCategory_ASort': 11790},
#   {'webColumn_Id': 223800,
#    'categoryName_en': 'Connector - Accessory Safety Relay',
#    'prodCategory_ASort': 11800},
#   {'webColumn_Id': 318500,
#    'categoryName_en': 'Connector - Active Suspension Relay',
#    'prodCategory_ASort': 11810},
#   {'webColumn_Id': 279400,
#    'categoryName_en': 'Connector - Active Suspension Sensor',
#    'prodCategory_ASort': 11820},
#   {'webColumn_Id': 279500,
#    'categoryName_en': 'Connector - Active Suspension Solenoid',
#    'prodCategory_ASort': 11830},
#   {'webColumn_Id': 279600,
#    'categoryName_en': 'Connector - Active Suspension Switch',
#    'prodCategory_ASort': 11840},
#   {'webColumn_Id': 297800,
#    'categoryName_en': 'Connector - Adjustable Pedal Motor',
#    'prodCategory_ASort': 11850},
#   {'webColumn_Id': 304200,
#    'categoryName_en': 'Connector - Adjustable Pedal Switch                         ',
#    'prodCategory_ASort': 11860},
#   {'webColumn_Id': 279700,
#    'categoryName_en': 'Connector - Air Bag',
#    'prodCategory_ASort': 11870},
#   {'webColumn_Id': 279800,
#    'categoryName_en': 'Connector - Air Bag Diagnostic',
#    'prodCategory_ASort': 11880},
#   {'webColumn_Id': 279900,
#    'categoryName_en': 'Connector - Air Bag Disable Module',
#    'prodCategory_ASort': 11890},
#   {'webColumn_Id': 280000,
#    'categoryName_en': 'Connector - Air Bag Indicator Lamp',
#    'prodCategory_ASort': 11900},
#   {'webColumn_Id': 280100,
#    'categoryName_en': 'Connector - Air Bag Module',
#    'prodCategory_ASort': 11910},
#   {'webColumn_Id': 224000,
#    'categoryName_en': 'Connector - Air Bag Relay',
#    'prodCategory_ASort': 11920},
#   {'webColumn_Id': 148132,
#    'categoryName_en': 'Connector - Air Bag Repair Harness',
#    'prodCategory_ASort': 11930},
#   {'webColumn_Id': 355700,
#    'categoryName_en': 'Connector - Air Bag Seat Position Sensor',
#    'prodCategory_ASort': 11940},
#   {'webColumn_Id': 280200,
#    'categoryName_en': 'Connector - Air Bag Sensor',
#    'prodCategory_ASort': 11950},
#   {'webColumn_Id': 357100,
#    'categoryName_en': 'Connector - Air Brake Pressure Switch',
#    'prodCategory_ASort': 11960},
#   {'webColumn_Id': 148140,
#    'categoryName_en': 'Connector - Air Charge Temp Sensor',
#    'prodCategory_ASort': 11970},
#   {'webColumn_Id': 313700,
#    'categoryName_en': 'Connector - Air Cleaner Check Valve',
#    'prodCategory_ASort': 11980},
#   {'webColumn_Id': 310700,
#    'categoryName_en': 'Connector - Air Cleaner Door Solenoid Relay',
#    'prodCategory_ASort': 11990},
#   {'webColumn_Id': 319500,
#    'categoryName_en': 'Connector - Air Cleaner Temperature Sensor',
#    'prodCategory_ASort': 12000},
#   {'webColumn_Id': 224200,
#    'categoryName_en': 'Connector - Air Control Valve Relay',
#    'prodCategory_ASort': 12010},
#   {'webColumn_Id': 148308,
#    'categoryName_en': 'Connector - Air Duct Temp Sensor',
#    'prodCategory_ASort': 12020},
#   {'webColumn_Id': 148704,
#    'categoryName_en': 'Connector - Air Injection Reactor Pump',
#    'prodCategory_ASort': 12030},
#   {'webColumn_Id': 316600,
#    'categoryName_en': 'Connector - Air Pump',
#    'prodCategory_ASort': 12040},
#   {'webColumn_Id': 224300,
#    'categoryName_en': 'Connector - Air Pump Relay',
#    'prodCategory_ASort': 12050},
#   {'webColumn_Id': 304300,
#    'categoryName_en': 'Connector - Air Suspension Compressor Motor                 ',
#    'prodCategory_ASort': 12060},
#   {'webColumn_Id': 297900,
#    'categoryName_en': 'Connector - Air Suspension Sensor',
#    'prodCategory_ASort': 12090},
#   {'webColumn_Id': 298000,
#    'categoryName_en': 'Connector - Air Suspension Solenoid',
#    'prodCategory_ASort': 12100},
#   {'webColumn_Id': 315900,
#    'categoryName_en': 'Connector - Air Suspension Spring Solenoid',
#    'prodCategory_ASort': 12110},
#   {'webColumn_Id': 241800,
#    'categoryName_en': 'Connector - Air Switching Valve',
#    'prodCategory_ASort': 12120},
#   {'webColumn_Id': 272000,
#    'categoryName_en': 'Connector - Alarm Chime Module',
#    'prodCategory_ASort': 12130},
#   {'webColumn_Id': 310100,
#    'categoryName_en': 'Connector - All Wheel Drive Control Relay',
#    'prodCategory_ASort': 12140},
#   {'webColumn_Id': 148144,
#    'categoryName_en': 'Connector - Alternator Electrical',
#    'prodCategory_ASort': 12150},
#   {'webColumn_Id': 280300,
#    'categoryName_en': 'Connector - Ambient Air Quality Sensor',
#    'prodCategory_ASort': 12160},
#   {'webColumn_Id': 148146,
#    'categoryName_en': 'Connector - Ambient Air Temperature Sensor',
#    'prodCategory_ASort': 12170},
#   {'webColumn_Id': 242300,
#    'categoryName_en': 'Connector - Ambient Light Sensor',
#    'prodCategory_ASort': 12180},
#   {'webColumn_Id': 224400,
#    'categoryName_en': 'Connector - Anti-Dieseling Relay',
#    'prodCategory_ASort': 12190},
#   {'webColumn_Id': 148152,
#    'categoryName_en': 'Connector - Anti-Theft Alarm',
#    'prodCategory_ASort': 12200},
#   {'webColumn_Id': 353200,
#    'categoryName_en': 'Connector - Anti-Theft Ignition Tamper Sensor',
#    'prodCategory_ASort': 12210},
#   {'webColumn_Id': 296000,
#    'categoryName_en': 'Connector - Anti-Theft Transceiver',
#    'prodCategory_ASort': 12230},
#   {'webColumn_Id': 148156,
#    'categoryName_en': 'Connector - Ashtray Lamp',
#    'prodCategory_ASort': 12240},
#   {'webColumn_Id': 357000,
#    'categoryName_en': 'Connector - Audio Control Module',
#    'prodCategory_ASort': 12250},
#   {'webColumn_Id': 280400,
#    'categoryName_en': 'Connector - Audio-Video Module',
#    'prodCategory_ASort': 12260},
#   {'webColumn_Id': 148684,
#    'categoryName_en': 'Connector - Auto Level Control Sensor',
#    'prodCategory_ASort': 12270},
#   {'webColumn_Id': 311500,
#    'categoryName_en': 'Connector - Auto Transaxle Relay',
#    'prodCategory_ASort': 12280},
#   {'webColumn_Id': 223400,
#    'categoryName_en': 'Connector - Auto Transmission Relay',
#    'prodCategory_ASort': 12290},
#   {'webColumn_Id': 311200,
#    'categoryName_en': 'Connector - Automatic Choke Relay',
#    'prodCategory_ASort': 12300},
#   {'webColumn_Id': 224500,
#    'categoryName_en': 'Connector - Automatic Headlight On/Off Relay',
#    'prodCategory_ASort': 12310},
#   {'webColumn_Id': 280500,
#    'categoryName_en': 'Connector - Automatic Level Compressor Motor',
#    'prodCategory_ASort': 12320},
#   {'webColumn_Id': 242900,
#    'categoryName_en': 'Connector - Automatic Level Control Harness',
#    'prodCategory_ASort': 12330},
#   {'webColumn_Id': 280600,
#    'categoryName_en': 'Connector - Automatic Level Control Solenoid',
#    'prodCategory_ASort': 12340},
#   {'webColumn_Id': 316000,
#    'categoryName_en': 'Connector - Automatic Shutdown Relay',
#    'prodCategory_ASort': 12350},
#   {'webColumn_Id': 356400,
#    'categoryName_en': 'Connector - Automatic Transmission Fluid Temperature Sensor',
#    'prodCategory_ASort': 12370},
#   {'webColumn_Id': 224800,
#    'categoryName_en': 'Connector - Auxiliary Air Valve',
#    'prodCategory_ASort': 12380},
#   {'webColumn_Id': 280700,
#    'categoryName_en': 'Connector - Auxiliary Battery Low Voltage Module',
#    'prodCategory_ASort': 12390},
#   {'webColumn_Id': 224900,
#    'categoryName_en': 'Connector - Auxiliary Battery Relay',
#    'prodCategory_ASort': 12400},
#   {'webColumn_Id': 280800,
#    'categoryName_en': 'Connector - Auxiliary Blower Motor',
#    'prodCategory_ASort': 12410},
#   {'webColumn_Id': 280900,
#    'categoryName_en': 'Connector - Auxiliary Blower Motor Resistor',
#    'prodCategory_ASort': 12420},
#   {'webColumn_Id': 243100,
#    'categoryName_en': 'Connector - Auxiliary Blower Switch',
#    'prodCategory_ASort': 12430},
#   {'webColumn_Id': 224600,
#    'categoryName_en': 'Connector - Auxiliary Engine Cooling Fan Relay',
#    'prodCategory_ASort': 12440},
#   {'webColumn_Id': 281000,
#    'categoryName_en': 'Connector - Auxiliary Heater & A/C',
#    'prodCategory_ASort': 12450},
#   {'webColumn_Id': 224700,
#    'categoryName_en': 'Connector - Auxiliary Heater & A/C Control Relay',
#    'prodCategory_ASort': 12460},
#   {'webColumn_Id': 281100,
#    'categoryName_en': 'Connector - Auxiliary Heater Switch',
#    'prodCategory_ASort': 12470},
#   {'webColumn_Id': 281200,
#    'categoryName_en': 'Connector - Auxiliary HVAC',
#    'prodCategory_ASort': 12480},
#   {'webColumn_Id': 281300,
#    'categoryName_en': 'Connector - Auxiliary Water Pump',
#    'prodCategory_ASort': 12490},
#   {'webColumn_Id': 148164,
#    'categoryName_en': 'Connector - Axle Shift Switch - H/D Truck',
#    'prodCategory_ASort': 12500},
#   {'webColumn_Id': 148168,
#    'categoryName_en': 'Connector - Back-up Alarm',
#    'prodCategory_ASort': 12510},
#   {'webColumn_Id': 298100,
#    'categoryName_en': 'Connector - Back-Up Camera',
#    'prodCategory_ASort': 12520},
#   {'webColumn_Id': 148172,
#    'categoryName_en': 'Connector - Back-up Lamp',
#    'prodCategory_ASort': 12530},
#   {'webColumn_Id': 225000,
#    'categoryName_en': 'Connector - Back-up Lamp Relay',
#    'prodCategory_ASort': 12540},
#   {'webColumn_Id': 319900,
#    'categoryName_en': 'Connector - Back-Up Light Socket',
#    'prodCategory_ASort': 12550},
#   {'webColumn_Id': 225100,
#    'categoryName_en': 'Connector - Back-up Light Switch',
#    'prodCategory_ASort': 12560},
#   {'webColumn_Id': 148176,
#    'categoryName_en': 'Connector - Barometric Pressure Sensor',
#    'prodCategory_ASort': 12570},
#   {'webColumn_Id': 225200,
#    'categoryName_en': 'Connector - Battery Charge Relay',
#    'prodCategory_ASort': 12580},
#   {'webColumn_Id': 281400,
#    'categoryName_en': 'Connector - Battery Current Sensor',
#    'prodCategory_ASort': 12590},
#   {'webColumn_Id': 317200,
#    'categoryName_en': 'Connector - Battery Isolation Relay',
#    'prodCategory_ASort': 12600},
#   {'webColumn_Id': 225300,
#    'categoryName_en': 'Connector - Battery Saver Relay',
#    'prodCategory_ASort': 12610},
#   {'webColumn_Id': 298200,
#    'categoryName_en': 'Connector - Battery Temperature Sensor',
#    'prodCategory_ASort': 12620},
#   {'webColumn_Id': 148180,
#    'categoryName_en': 'Connector - Battery Voltage Sensor',
#    'prodCategory_ASort': 12630},
#   {'webColumn_Id': 347300,
#    'categoryName_en': 'Connector - Blind Spot Detection Sensor',
#    'prodCategory_ASort': 12640},
#   {'webColumn_Id': 148488,
#    'categoryName_en': 'Connector - Blower Motor',
#    'prodCategory_ASort': 12650},
#   {'webColumn_Id': 281500,
#    'categoryName_en': 'Connector - Blower Motor Controller',
#    'prodCategory_ASort': 12660},
#   {'webColumn_Id': 281600,
#    'categoryName_en': 'Connector - Blower Motor Module',
#    'prodCategory_ASort': 12670},
#   {'webColumn_Id': 220800,
#    'categoryName_en': 'Connector - Blower Motor Resistor',
#    'prodCategory_ASort': 12680},
#   {'webColumn_Id': 332300,
#    'categoryName_en': 'Connector - Blower Motor Resistor High Temperature',
#    'prodCategory_ASort': 12690},
#   {'webColumn_Id': 148181,
#    'categoryName_en': 'Connector - Blower Relay',
#    'prodCategory_ASort': 12700},
#   {'webColumn_Id': 148188,
#    'categoryName_en': 'Connector - Blower Switch',
#    'prodCategory_ASort': 12710},
#   {'webColumn_Id': 281700,
#    'categoryName_en': 'Connector - Body Control Module (BCM)',
#    'prodCategory_ASort': 12720},
#   {'webColumn_Id': 148196,
#    'categoryName_en': 'Connector - Body Harness',
#    'prodCategory_ASort': 12730},
#   {'webColumn_Id': 317300,
#    'categoryName_en': 'Connector - Body Wiring Harness Relay',
#    'prodCategory_ASort': 12740},
#   {'webColumn_Id': 148632,
#    'categoryName_en': 'Connector - Brake Booster Pump',
#    'prodCategory_ASort': 12750},
#   {'webColumn_Id': 243800,
#    'categoryName_en': 'Connector - Brake Booster Pump Relay',
#    'prodCategory_ASort': 12760},
#   {'webColumn_Id': 320400,
#    'categoryName_en': 'Connector - Brake Booster Vacuum Sensor',
#    'prodCategory_ASort': 12770},
#   {'webColumn_Id': 244000,
#    'categoryName_en': 'Connector - Brake Differential Valve',
#    'prodCategory_ASort': 12780},
#   {'webColumn_Id': 148200,
#    'categoryName_en': 'Connector - Brake Fluid Level Sensor',
#    'prodCategory_ASort': 12790},
#   {'webColumn_Id': 313800,
#    'categoryName_en': 'Connector - Brake Fluid Pressure Sensor',
#    'prodCategory_ASort': 12800},
#   {'webColumn_Id': 244100,
#    'categoryName_en': 'Connector - Brake Modulator Valve Relay',
#    'prodCategory_ASort': 12820},
#   {'webColumn_Id': 316700,
#    'categoryName_en': 'Connector - Brake Pad Wear Sensor',
#    'prodCategory_ASort': 12830},
#   {'webColumn_Id': 359600,
#    'categoryName_en': 'Connector - Brake Pedal Position Sensor',
#    'prodCategory_ASort': 12840},
#   {'webColumn_Id': 321200,
#    'categoryName_en': 'Connector - Brake Pedal Travel Sensor',
#    'prodCategory_ASort': 12850},
#   {'webColumn_Id': 298300,
#    'categoryName_en': 'Connector - Brake Pressure Sensor',
#    'prodCategory_ASort': 12870},
#   {'webColumn_Id': 148572,
#    'categoryName_en': 'Connector - Brake Pressure Switch',
#    'prodCategory_ASort': 12880},
#   {'webColumn_Id': 313900,
#    'categoryName_en': 'Connector - Bulb Overload Protection Relay',
#    'prodCategory_ASort': 12890},
#   {'webColumn_Id': 351300,
#    'categoryName_en': 'Connector - Cabin Air Temperature Sensor',
#    'prodCategory_ASort': 12900},
#   {'webColumn_Id': 281800,
#    'categoryName_en': 'Connector - Camshaft Position Solenoid',
#    'prodCategory_ASort': 12910},
#   {'webColumn_Id': 148204,
#    'categoryName_en': 'Connector - Camshaft Sensor',
#    'prodCategory_ASort': 12920},
#   {'webColumn_Id': 310200,
#    'categoryName_en': 'Connector - Camshaft Synchronizer',
#    'prodCategory_ASort': 12930},
#   {'webColumn_Id': 319200,
#    'categoryName_en': 'Connector - Canister Purge Solenoid',
#    'prodCategory_ASort': 12940},
#   {'webColumn_Id': 148380,
#    'categoryName_en': 'Connector - Canister Purge Vacuum Switch',
#    'prodCategory_ASort': 12950},
#   {'webColumn_Id': 237000,
#    'categoryName_en': 'Connector - Canister Purge Valve',
#    'prodCategory_ASort': 12960},
#   {'webColumn_Id': 281900,
#    'categoryName_en': 'Connector - Canister Vent Solenoid',
#    'prodCategory_ASort': 12970},
#   {'webColumn_Id': 148212,
#    'categoryName_en': 'Connector - Cargo Lamp',
#    'prodCategory_ASort': 12980},
#   {'webColumn_Id': 225400,
#    'categoryName_en': 'Connector - Cargo Lamp Relay',
#    'prodCategory_ASort': 12990},
#   {'webColumn_Id': 148216,
#    'categoryName_en': 'Connector - Catalytic Conv Temp Sensor',
#    'prodCategory_ASort': 13000},
#   {'webColumn_Id': 148236,
#    'categoryName_en': 'Connector - CD Player',
#    'prodCategory_ASort': 13020},
#   {'webColumn_Id': 148472,
#    'categoryName_en': 'Connector - Center Stoplight',
#    'prodCategory_ASort': 13040},
#   {'webColumn_Id': 225600,
#    'categoryName_en': 'Connector - Center Stoplight Relay',
#    'prodCategory_ASort': 13050},
#   {'webColumn_Id': 314000,
#    'categoryName_en': 'Connector - Charge Lamp Relay',
#    'prodCategory_ASort': 13060},
#   {'webColumn_Id': 317900,
#    'categoryName_en': 'Connector - Choke Thermostat',
#    'prodCategory_ASort': 13080},
#   {'webColumn_Id': 148228,
#    'categoryName_en': 'Connector - Cigar Lighter',
#    'prodCategory_ASort': 13100},
#   {'webColumn_Id': 225700,
#    'categoryName_en': 'Connector - Cigar Lighter Relay',
#    'prodCategory_ASort': 13110},
#   {'webColumn_Id': 320500,
#    'categoryName_en': 'Connector - Circuit Opening Relay',
#    'prodCategory_ASort': 13120},
#   {'webColumn_Id': 313200,
#    'categoryName_en': 'Connector - Climate Control Module',
#    'prodCategory_ASort': 13130},
#   {'webColumn_Id': 244800,
#    'categoryName_en': 'Connector - Clock',
#    'prodCategory_ASort': 13140},
#   {'webColumn_Id': 282100,
#    'categoryName_en': 'Connector - Clock Spring',
#    'prodCategory_ASort': 13150},
#   {'webColumn_Id': 319600,
#    'categoryName_en': 'Connector - Clutch Interlock Relay',
#    'prodCategory_ASort': 13160},
#   {'webColumn_Id': 292500,
#    'categoryName_en': 'Connector - Clutch Pedal Position Switch',
#    'prodCategory_ASort': 13170},
#   {'webColumn_Id': 148232,
#    'categoryName_en': 'Connector - Clutch Starter Safety Switch',
#    'prodCategory_ASort': 13180},
#   {'webColumn_Id': 237100,
#    'categoryName_en': 'Connector - Cold Start Relay',
#    'prodCategory_ASort': 13190},
#   {'webColumn_Id': 225800,
#    'categoryName_en': 'Connector - Cold Start Valve',
#    'prodCategory_ASort': 13200},
#   {'webColumn_Id': 350900,
#    'categoryName_en': 'Connector - Cold Start Valve Temperature Switch',
#    'prodCategory_ASort': 13220},
#   {'webColumn_Id': 237200,
#    'categoryName_en': 'Connector - Combination Switch',
#    'prodCategory_ASort': 13230},
#   {'webColumn_Id': 282200,
#    'categoryName_en': 'Connector - Compass Module',
#    'prodCategory_ASort': 13240},
#   {'webColumn_Id': 310800,
#    'categoryName_en': 'Connector - Computer',
#    'prodCategory_ASort': 13250},
#   {'webColumn_Id': 226000,
#    'categoryName_en': 'Connector - Computer Control Relay',
#    'prodCategory_ASort': 13260},
#   {'webColumn_Id': 317400,
#    'categoryName_en': 'Connector - Concealed Headlight Relay',
#    'prodCategory_ASort': 13270},
#   {'webColumn_Id': 148244,
#    'categoryName_en': 'Connector - Console Harness',
#    'prodCategory_ASort': 13280},
#   {'webColumn_Id': 310300,
#    'categoryName_en': 'Connector - Convertible Top Relay',
#    'prodCategory_ASort': 13300},
#   {'webColumn_Id': 245300,
#    'categoryName_en': 'Connector - Convertible Top Switch',
#    'prodCategory_ASort': 13310},
#   {'webColumn_Id': 226100,
#    'categoryName_en': 'Connector - Coolant Fan Relay',
#    'prodCategory_ASort': 13320},
#   {'webColumn_Id': 226200,
#    'categoryName_en': 'Connector - Coolant Fan Switch',
#    'prodCategory_ASort': 13330},
#   {'webColumn_Id': 226300,
#    'categoryName_en': 'Connector - Coolant Level Relay',
#    'prodCategory_ASort': 13340},
#   {'webColumn_Id': 148348,
#    'categoryName_en': 'Connector - Coolant Level Sensor',
#    'prodCategory_ASort': 13350},
#   {'webColumn_Id': 148360,
#    'categoryName_en': 'Connector - Coolant Temp Sensor',
#    'prodCategory_ASort': 13360},
#   {'webColumn_Id': 148352,
#    'categoryName_en': 'Connector - Cooling Fan Motor',
#    'prodCategory_ASort': 13370},
#   {'webColumn_Id': 226400,
#    'categoryName_en': 'Connector - Cornering Light Socket',
#    'prodCategory_ASort': 13380},
#   {'webColumn_Id': 148260,
#    'categoryName_en': 'Connector - Courtesy Lamp',
#    'prodCategory_ASort': 13390},
#   {'webColumn_Id': 226500,
#    'categoryName_en': 'Connector - Courtesy Lamp Relay',
#    'prodCategory_ASort': 13400},
#   {'webColumn_Id': 282300,
#    'categoryName_en': 'Connector - Courtesy Lamp Switch',
#    'prodCategory_ASort': 13410},
#   {'webColumn_Id': 148264,
#    'categoryName_en': 'Connector - Crankcase Vent Heater',
#    'prodCategory_ASort': 13420},
#   {'webColumn_Id': 148268,
#    'categoryName_en': 'Connector - Crankshaft Sensor',
#    'prodCategory_ASort': 13430},
#   {'webColumn_Id': 355300,
#    'categoryName_en': 'Connector - Crash Sensor',
#    'prodCategory_ASort': 13440},
#   {'webColumn_Id': 148276,
#    'categoryName_en': 'Connector - Crossbody Harness',
#    'prodCategory_ASort': 13450},
#   {'webColumn_Id': 282400,
#    'categoryName_en': 'Connector - Cruise Control',
#    'prodCategory_ASort': 13460},
#   {'webColumn_Id': 351800,
#    'categoryName_en': 'Connector - Cruise Control Distance Sensor',
#    'prodCategory_ASort': 13470},
#   {'webColumn_Id': 264000,
#    'categoryName_en': 'Connector - Cruise Control Module',
#    'prodCategory_ASort': 13480},
#   {'webColumn_Id': 226600,
#    'categoryName_en': 'Connector - Cruise Control Relay',
#    'prodCategory_ASort': 13490},
#   {'webColumn_Id': 148272,
#    'categoryName_en': 'Connector - Cruise Control Release Switch',
#    'prodCategory_ASort': 13500},
#   {'webColumn_Id': 245500,
#    'categoryName_en': 'Connector - Cruise Control Servo',
#    'prodCategory_ASort': 13510},
#   {'webColumn_Id': 148280,
#    'categoryName_en': 'Connector - Cruise Control Switch',
#    'prodCategory_ASort': 13520},
#   {'webColumn_Id': 296300,
#    'categoryName_en': 'Connector - Cylinder Head Temperature Sensor',
#    'prodCategory_ASort': 13530},
#   {'webColumn_Id': 291400,
#    'categoryName_en': 'Connector - Datalink',
#    'prodCategory_ASort': 13540},
#   {'webColumn_Id': 282500,
#    'categoryName_en': 'Connector - Daytime Running Lamp',
#    'prodCategory_ASort': 13550},
#   {'webColumn_Id': 148284,
#    'categoryName_en': 'Connector - Daytime Running Lamp Module',
#    'prodCategory_ASort': 13560},
#   {'webColumn_Id': 226700,
#    'categoryName_en': 'Connector - Daytime Running Lamp Relay',
#    'prodCategory_ASort': 13570},
#   {'webColumn_Id': 245600,
#    'categoryName_en': 'Connector - Daytime Running Light Resistor',
#    'prodCategory_ASort': 13590},
#   {'webColumn_Id': 294700,
#    'categoryName_en': 'Connector - Deck Lid Module',
#    'prodCategory_ASort': 13600},
#   {'webColumn_Id': 226800,
#    'categoryName_en': 'Connector - Defroster Relay',
#    'prodCategory_ASort': 13610},
#   {'webColumn_Id': 360400,
#    'categoryName_en': 'Connector - Diesel Exhaust Fluid (DEF) Pump',
#    'prodCategory_ASort': 13630},
#   {'webColumn_Id': 351900,
#    'categoryName_en': 'Connector - Diesel Fuel Injection Pump',
#    'prodCategory_ASort': 13650},
#   {'webColumn_Id': 361300,
#    'categoryName_en': 'Connector - Diesel Fuel Injector Fuel Return Hose',
#    'prodCategory_ASort': 13660},
#   {'webColumn_Id': 346800,
#    'categoryName_en': 'Connector - Diesel Fuel Injector Rail',
#    'prodCategory_ASort': 13670},
#   {'webColumn_Id': 358400,
#    'categoryName_en': 'Connector - Diesel Glow Plug',
#    'prodCategory_ASort': 13680},
#   {'webColumn_Id': 245800,
#    'categoryName_en': 'Connector - Diesel Glow Plug Controller',
#    'prodCategory_ASort': 13690},
#   {'webColumn_Id': 320600,
#    'categoryName_en': 'Connector - Diesel Glow Plug Indicator Relay',
#    'prodCategory_ASort': 13700},
#   {'webColumn_Id': 226900,
#    'categoryName_en': 'Connector - Diesel Glow Plug Relay',
#    'prodCategory_ASort': 13710},
#   {'webColumn_Id': 318800,
#    'categoryName_en': 'Connector - Diesel Glow Plug Temp Sensor',
#    'prodCategory_ASort': 13720},
#   {'webColumn_Id': 347000,
#    'categoryName_en': 'Connector - Diesel Nitrogen Oxide (NOx) Sensor',
#    'prodCategory_ASort': 13730},
#   {'webColumn_Id': 359100,
#    'categoryName_en': 'Connector - Diesel Nitrogen Oxide (Nox) Sensor Module',
#    'prodCategory_ASort': 13740},
#   {'webColumn_Id': 346700,
#    'categoryName_en': 'Connector - Diesel Particulate Filter (DPF) Pressure Sensor',
#    'prodCategory_ASort': 13750},
#   {'webColumn_Id': 352600,
#    'categoryName_en': 'Connector - Diesel Particulate Sensor',
#    'prodCategory_ASort': 13760},
#   {'webColumn_Id': 272200,
#    'categoryName_en': 'Connector - Diesel Valve Cover Gasket',
#    'prodCategory_ASort': 13770},
#   {'webColumn_Id': 246200,
#    'categoryName_en': 'Connector - Diesel Wait Lamp Relay',
#    'prodCategory_ASort': 13780},
#   {'webColumn_Id': 353700,
#    'categoryName_en': 'Connector - Differential Oil Temperature Sensor',
#    'prodCategory_ASort': 13790},
#   {'webColumn_Id': 148292,
#    'categoryName_en': 'Connector - Distributor',
#    'prodCategory_ASort': 13800},
#   {'webColumn_Id': 227000,
#    'categoryName_en': 'Connector - Distributor Pick-up Assembly',
#    'prodCategory_ASort': 13810},
#   {'webColumn_Id': 282700,
#    'categoryName_en': 'Connector - Diverter Valve',
#    'prodCategory_ASort': 13820},
#   {'webColumn_Id': 148296,
#    'categoryName_en': 'Connector - Diverter Valve Harness',
#    'prodCategory_ASort': 13830},
#   {'webColumn_Id': 148300,
#    'categoryName_en': 'Connector - Dome Lamp',
#    'prodCategory_ASort': 13840},
#   {'webColumn_Id': 282800,
#    'categoryName_en': 'Connector - Door Ajar Chime',
#    'prodCategory_ASort': 13850},
#   {'webColumn_Id': 313300,
#    'categoryName_en': 'Connector - Door Ajar Relay',
#    'prodCategory_ASort': 13860},
#   {'webColumn_Id': 227200,
#    'categoryName_en': 'Connector - Door Ajar Warning Switch',
#    'prodCategory_ASort': 13870},
#   {'webColumn_Id': 353300,
#    'categoryName_en': 'Connector - Door Cylinder Anti-Theft Disarm Switch',
#    'prodCategory_ASort': 13880},
#   {'webColumn_Id': 357700,
#    'categoryName_en': 'Connector - Door Handle Touch Sensor',
#    'prodCategory_ASort': 13890},
#   {'webColumn_Id': 148304,
#    'categoryName_en': 'Connector - Door Harness',
#    'prodCategory_ASort': 13900},
#   {'webColumn_Id': 227300,
#    'categoryName_en': 'Connector - Door Jamb Switch',
#    'prodCategory_ASort': 13910},
#   {'webColumn_Id': 314700,
#    'categoryName_en': 'Connector - Door Lock Position Switch',
#    'prodCategory_ASort': 13920},
#   {'webColumn_Id': 356900,
#    'categoryName_en': 'Connector - Door Mirror Harness',
#    'prodCategory_ASort': 13930},
#   {'webColumn_Id': 246500,
#    'categoryName_en': 'Connector - Downshift Solenoid',
#    'prodCategory_ASort': 13940},
#   {'webColumn_Id': 227400,
#    'categoryName_en': 'Connector - Driving Lamp Relay',
#    'prodCategory_ASort': 13950},
#   {'webColumn_Id': 282900,
#    'categoryName_en': 'Connector - Dvd Player',
#    'prodCategory_ASort': 13960},
#   {'webColumn_Id': 227500,
#    'categoryName_en': 'Connector - Early Fuel Evaporation (efe) Relay',
#    'prodCategory_ASort': 13970},
#   {'webColumn_Id': 148312,
#    'categoryName_en': 'Connector - EEC Relay',
#    'prodCategory_ASort': 13980},
#   {'webColumn_Id': 148316,
#    'categoryName_en': 'Connector - EEC Test Plug',
#    'prodCategory_ASort': 13990},
#   {'webColumn_Id': 227600,
#    'categoryName_en': 'Connector - EGR Control Solenoid',
#    'prodCategory_ASort': 14010},
#   {'webColumn_Id': 297500,
#    'categoryName_en': 'Connector - EGR Tube',
#    'prodCategory_ASort': 14030},
#   {'webColumn_Id': 298400,
#    'categoryName_en': 'Connector - EGR Vacuum Regulator Solenoid',
#    'prodCategory_ASort': 14040},
#   {'webColumn_Id': 237500,
#    'categoryName_en': 'Connector - EGR Valve',
#    'prodCategory_ASort': 14050},
#   {'webColumn_Id': 301800,
#    'categoryName_en': 'Connector - EGR Valve Position Sensor',
#    'prodCategory_ASort': 14060},
#   {'webColumn_Id': 292400,
#    'categoryName_en': 'Connector - EGR Valve Pressure Feedback Sensor',
#    'prodCategory_ASort': 14070},
#   {'webColumn_Id': 227800,
#    'categoryName_en': 'Connector - EGR Valve Relay',
#    'prodCategory_ASort': 14080},
#   {'webColumn_Id': 148320,
#    'categoryName_en': 'Connector - EGR Valve Sensor',
#    'prodCategory_ASort': 14090},
#   {'webColumn_Id': 362600,
#    'categoryName_en': 'Connector - EGR Valve Temperature Sensor',
#    'prodCategory_ASort': 14100},
#   {'webColumn_Id': 319700,
#    'categoryName_en': 'Connector - EGR Valve Vacuum Modulator',
#    'prodCategory_ASort': 14110},
#   {'webColumn_Id': 227900,
#    'categoryName_en': 'Connector - Electronic Brake Control Relay',
#    'prodCategory_ASort': 14120},
#   {'webColumn_Id': 148324,
#    'categoryName_en': 'Connector - Electronic Brake Harness',
#    'prodCategory_ASort': 14130},
#   {'webColumn_Id': 247100,
#    'categoryName_en': 'Connector - Electronic Brake Relay',
#    'prodCategory_ASort': 14140},
#   {'webColumn_Id': 320700,
#    'categoryName_en': 'Connector - Electronic Throttle Body',
#    'prodCategory_ASort': 14160},
#   {'webColumn_Id': 266000,
#    'categoryName_en': 'Connector - Electronic Throttle Control',
#    'prodCategory_ASort': 14170},
#   {'webColumn_Id': 283000,
#    'categoryName_en': 'Connector - Emergency Vehicle Lamp',
#    'prodCategory_ASort': 14180},
#   {'webColumn_Id': 283100,
#    'categoryName_en': 'Connector - Emergency Vehicle Lamp Switch',
#    'prodCategory_ASort': 14190},
#   {'webColumn_Id': 228000,
#    'categoryName_en': 'Connector - Emission Control Relay',
#    'prodCategory_ASort': 14200},
#   {'webColumn_Id': 352900,
#    'categoryName_en': 'Connector - Engine Brake Relay',
#    'prodCategory_ASort': 14210},
#   {'webColumn_Id': 148328,
#    'categoryName_en': 'Connector - Engine Control Module Harness',
#    'prodCategory_ASort': 14220},
#   {'webColumn_Id': 228100,
#    'categoryName_en': 'Connector - Engine Control Relay',
#    'prodCategory_ASort': 14230},
#   {'webColumn_Id': 315400,
#    'categoryName_en': 'Connector - Engine Control Starter Switch Relay',
#    'prodCategory_ASort': 14240},
#   {'webColumn_Id': 247600,
#    'categoryName_en': 'Connector - Engine Coolant Fan Motor',
#    'prodCategory_ASort': 14250},
#   {'webColumn_Id': 318000,
#    'categoryName_en': 'Connector - Engine Coolant Thermostat Housing',
#    'prodCategory_ASort': 14260},
#   {'webColumn_Id': 361500,
#    'categoryName_en': 'Connector - Engine Cooling Fan Resistor',
#    'prodCategory_ASort': 14270},
#   {'webColumn_Id': 355800,
#    'categoryName_en': 'Connector - Engine Crankcase Breather Hose',
#    'prodCategory_ASort': 14280},
#   {'webColumn_Id': 359700,
#    'categoryName_en': 'Connector - Engine Cylinder Deactivation Solenoid',
#    'prodCategory_ASort': 14290},
#   {'webColumn_Id': 148372,
#    'categoryName_en': 'Connector - Engine Harness',
#    'prodCategory_ASort': 14300},
#   {'webColumn_Id': 355900,
#    'categoryName_en': 'Connector - Engine Intake Manifold Valve Actuator',
#    'prodCategory_ASort': 14310},
#   {'webColumn_Id': 283200,
#    'categoryName_en': 'Connector - Engine Oil Level Module',
#    'prodCategory_ASort': 14320},
#   {'webColumn_Id': 228200,
#    'categoryName_en': 'Connector - Engine Oil Level Sensor',
#    'prodCategory_ASort': 14330},
#   {'webColumn_Id': 356000,
#    'categoryName_en': 'Connector - Engine Oil Pressure Sensor',
#    'prodCategory_ASort': 14340},
#   {'webColumn_Id': 316800,
#    'categoryName_en': 'Connector - Engine Oil Temperature Sender',
#    'prodCategory_ASort': 14350},
#   {'webColumn_Id': 341400,
#    'categoryName_en': 'Connector - Engine Oil Temperature Sensor',
#    'prodCategory_ASort': 14360},
#   {'webColumn_Id': 305800,
#    'categoryName_en': 'Connector - Engine Oil Temperature Switch  ',
#    'prodCategory_ASort': 14370},
#   {'webColumn_Id': 148724,
#    'categoryName_en': 'Connector - Engine Shutdown Switch Harness',
#    'prodCategory_ASort': 14380},
#   {'webColumn_Id': 247900,
#    'categoryName_en': 'Connector - Engine Speed Sensor',
#    'prodCategory_ASort': 14390},
#   {'webColumn_Id': 298500,
#    'categoryName_en': 'Connector - Engine Variable Timing Solenoid',
#    'prodCategory_ASort': 14400},
#   {'webColumn_Id': 319300,
#    'categoryName_en': 'Connector - Engine Wiring Relay',
#    'prodCategory_ASort': 14410},
#   {'webColumn_Id': 310900,
#    'categoryName_en': 'Connector - Exhaust Back Pressure Sensor',
#    'prodCategory_ASort': 14420},
#   {'webColumn_Id': 311600,
#    'categoryName_en': 'Connector - Exhaust Gas Temperature Sensor',
#    'prodCategory_ASort': 14430},
#   {'webColumn_Id': 248200,
#    'categoryName_en': 'Connector - Fast Idle Relay',
#    'prodCategory_ASort': 14440},
#   {'webColumn_Id': 228400,
#    'categoryName_en': 'Connector - Fast Idle Solenoid Relay',
#    'prodCategory_ASort': 14450},
#   {'webColumn_Id': 283300,
#    'categoryName_en': 'Connector - Flex Fuel Sensor',
#    'prodCategory_ASort': 14460},
#   {'webColumn_Id': 148400,
#    'categoryName_en': 'Connector - Fog Lamp',
#    'prodCategory_ASort': 14470},
#   {'webColumn_Id': 228500,
#    'categoryName_en': 'Connector - Fog Lamp Relay',
#    'prodCategory_ASort': 14480},
#   {'webColumn_Id': 317500,
#    'categoryName_en': 'Connector - Fog Lamp Socket',
#    'prodCategory_ASort': 14490},
#   {'webColumn_Id': 228600,
#    'categoryName_en': 'Connector - Fog Lamp Switch',
#    'prodCategory_ASort': 14500},
#   {'webColumn_Id': 148884,
#    'categoryName_en': 'Connector - Four Wheel Drive Actuator',
#    'prodCategory_ASort': 14510},
#   {'webColumn_Id': 283400,
#    'categoryName_en': 'Connector - Four Wheel Drive Ind Lamp',
#    'prodCategory_ASort': 14520},
#   {'webColumn_Id': 228700,
#    'categoryName_en': 'Connector - Four Wheel Drive Ind Lamp Switch',
#    'prodCategory_ASort': 14530},
#   {'webColumn_Id': 298600,
#    'categoryName_en': 'Connector - Four Wheel Drive Locking Hub Solenoid',
#    'prodCategory_ASort': 14540},
#   {'webColumn_Id': 283500,
#    'categoryName_en': 'Connector - Four Wheel Drive Selector Switch',
#    'prodCategory_ASort': 14550},
#   {'webColumn_Id': 309900,
#    'categoryName_en': 'Connector - Front Drive Clutch Actuator Solenoid',
#    'prodCategory_ASort': 14570},
#   {'webColumn_Id': 326900,
#    'categoryName_en': 'Connector - Front Lamp Harness',
#    'prodCategory_ASort': 14580},
#   {'webColumn_Id': 313400,
#    'categoryName_en': 'Connector - Fuel / Water Separator Sensor',
#    'prodCategory_ASort': 14600},
#   {'webColumn_Id': 292900,
#    'categoryName_en': 'Connector - Fuel Door Lock Actuator',
#    'prodCategory_ASort': 14620},
#   {'webColumn_Id': 312200,
#    'categoryName_en': 'Connector - Fuel Door Release Switch',
#    'prodCategory_ASort': 14630},
#   {'webColumn_Id': 357300,
#    'categoryName_en': 'Connector - Fuel Filler Door Lock Actuator',
#    'prodCategory_ASort': 14640},
#   {'webColumn_Id': 318100,
#    'categoryName_en': 'Connector - Fuel Filler Door Relay',
#    'prodCategory_ASort': 14650},
#   {'webColumn_Id': 148408,
# ...
#    'prodCategory_ASort': 20530},
#   {'webColumn_Id': 325800,
#    'categoryName_en': 'Engine Variable Valve Timing Spool Filter',
#    'prodCategory_ASort': 20570},
#   {'webColumn_Id': 327900,
#    'categoryName_en': 'Engine Variable Valve Timing Sprocket',
#    'prodCategory_ASort': 20580},
#   {'webColumn_Id': 348000,
#    'categoryName_en': 'Exhaust Control Valve Actuator',
#    'prodCategory_ASort': 20590},
#   {'webColumn_Id': 342000,
#    'categoryName_en': 'Exhaust Gas Recirculation Back Pressure Transducer',
#    'prodCategory_ASort': 20600},
#   {'webColumn_Id': 357800,
#    'categoryName_en': 'Exterior Door Handle Repair Kit',
#    'prodCategory_ASort': 20610},
#   {'webColumn_Id': 304800,
#    'categoryName_en': 'Fast Idle Valve Solenoid                                    ',
#    'prodCategory_ASort': 20620},
#   {'webColumn_Id': 309200,
#    'categoryName_en': 'Fog Lamp Wiring Harness',
#    'prodCategory_ASort': 20640},
#   {'webColumn_Id': 220600,
#    'categoryName_en': 'Four Wheel Drive Actuator',
#    'prodCategory_ASort': 20650},
#   {'webColumn_Id': 331800,
#    'categoryName_en': 'Four Wheel Drive Locking Hub',
#    'prodCategory_ASort': 20660},
#   {'webColumn_Id': 221600,
#    'categoryName_en': 'Fuel / Water Separator Valve',
#    'prodCategory_ASort': 20690},
#   {'webColumn_Id': 101000,
#    'categoryName_en': 'Fuel Damper Assembly',
#    'prodCategory_ASort': 20700},
#   {'webColumn_Id': 265800,
#    'categoryName_en': 'Fuel Damper Assembly O-Ring',
#    'prodCategory_ASort': 20710},
#   {'webColumn_Id': 54100,
#    'categoryName_en': 'Fuel Deceleration Diaphragm',
#    'prodCategory_ASort': 20720},
#   {'webColumn_Id': 265000,
#    'categoryName_en': 'Fuel Deceleration Valve',
#    'prodCategory_ASort': 20730},
#   {'webColumn_Id': 291200,
#    'categoryName_en': 'Fuel Door Lock Actuator',
#    'prodCategory_ASort': 20760},
#   {'webColumn_Id': 308500,
#    'categoryName_en': 'Fuel Feed Line',
#    'prodCategory_ASort': 20770},
#   {'webColumn_Id': 331100,
#    'categoryName_en': 'Fuel Filter and Pressure Regulator Assembly',
#    'prodCategory_ASort': 20790},
#   {'webColumn_Id': 308700,
#    'categoryName_en': 'Fuel Filter Housing Seal Kit',
#    'prodCategory_ASort': 20800},
#   {'webColumn_Id': 337700,
#    'categoryName_en': 'Fuel Injection Throttle Body',
#    'prodCategory_ASort': 20810},
#   {'webColumn_Id': 333100,
#    'categoryName_en': 'Fuel Injector - Diesel - New',
#    'prodCategory_ASort': 20830},
#   {'webColumn_Id': 333200,
#    'categoryName_en': 'Fuel Injector - Diesel - Remfd',
#    'prodCategory_ASort': 20840},
#   {'webColumn_Id': 349600,
#    'categoryName_en': 'Fuel Injector - New',
#    'prodCategory_ASort': 20870},
#   {'webColumn_Id': 349300,
#    'categoryName_en': 'Fuel Injector - Remfd',
#    'prodCategory_ASort': 20880},
#   {'webColumn_Id': 340000,
#    'categoryName_en': 'Fuel Injector Connector Clip',
#    'prodCategory_ASort': 20910},
#   {'webColumn_Id': 187100,
#    'categoryName_en': 'Fuel Injector Filter Screen',
#    'prodCategory_ASort': 20920},
#   {'webColumn_Id': 249300,
#    'categoryName_en': 'Fuel Injector Installation Kit',
#    'prodCategory_ASort': 20930},
#   {'webColumn_Id': 354800,
#    'categoryName_en': 'Fuel Injector Kit - Diesel - Remfd',
#    'prodCategory_ASort': 20940},
#   {'webColumn_Id': 352000,
#    'categoryName_en': 'Fuel Injector Rail Kit - GDI',
#    'prodCategory_ASort': 20960},
#   {'webColumn_Id': 133025,
#    'categoryName_en': 'Fuel Injector Retaining Bracket',
#    'prodCategory_ASort': 20980},
#   {'webColumn_Id': 98126,
#    'categoryName_en': 'Fuel Injector Seal Kit',
#    'prodCategory_ASort': 20990},
#   {'webColumn_Id': 56100,
#    'categoryName_en': 'Fuel Line O-Ring Kit',
#    'prodCategory_ASort': 21010},
#   {'webColumn_Id': 100100,
#    'categoryName_en': 'Fuel Line Repair Kit',
#    'prodCategory_ASort': 21020},
#   {'webColumn_Id': 249700,
#    'categoryName_en': 'Fuel Line Retainer',
#    'prodCategory_ASort': 21030},
#   {'webColumn_Id': 136100,
#    'categoryName_en': 'Fuel Mixture Control Solenoid',
#    'prodCategory_ASort': 21040},
#   {'webColumn_Id': 101100,
#    'categoryName_en': 'Fuel Pressure Regulator',
#    'prodCategory_ASort': 21050},
#   {'webColumn_Id': 140151,
#    'categoryName_en': 'Fuel Pressure Regulator O-Ring',
#    'prodCategory_ASort': 21060},
#   {'webColumn_Id': 309300,
#    'categoryName_en': 'Fuel Pressure Regulator Upgrade Kit',
#    'prodCategory_ASort': 21070},
#   {'webColumn_Id': 267700,
#    'categoryName_en': 'Fuel Pressure Relief Valve',
#    'prodCategory_ASort': 21080},
#   {'webColumn_Id': 303400,
#    'categoryName_en': 'Fuel Pressure Warning Light Kit                             ',
#    'prodCategory_ASort': 21090},
#   {'webColumn_Id': 336200,
#    'categoryName_en': 'Fuel Pump Camshaft Follower',
#    'prodCategory_ASort': 21110},
#   {'webColumn_Id': 340900,
#    'categoryName_en': 'Fuel Pump Driver Module',
#    'prodCategory_ASort': 21140},
#   {'webColumn_Id': 339700,
#    'categoryName_en': 'Fuel Pump Fitting',
#    'prodCategory_ASort': 21150},
#   {'webColumn_Id': 336600,
#    'categoryName_en': 'Fuel Pump Mounting Gasket',
#    'prodCategory_ASort': 21160},
#   {'webColumn_Id': 336400,
#    'categoryName_en': 'Fuel Pump Mounting Plate',
#    'prodCategory_ASort': 21170},
#   {'webColumn_Id': 336300,
#    'categoryName_en': 'Fuel Pump O-Ring',
#    'prodCategory_ASort': 21180},
#   {'webColumn_Id': 336500,
#    'categoryName_en': 'Fuel Pump Plate Gasket',
#    'prodCategory_ASort': 21190},
#   {'webColumn_Id': 250100,
#    'categoryName_en': 'Fuel Pump Resistor',
#    'prodCategory_ASort': 21200},
#   {'webColumn_Id': 331900,
#    'categoryName_en': 'Fuel Pump Strainer',
#    'prodCategory_ASort': 21210},
#   {'webColumn_Id': 102100,
#    'categoryName_en': 'Fuel Rail O-Ring Kit',
#    'prodCategory_ASort': 21220},
#   {'webColumn_Id': 97100,
#    'categoryName_en': 'Fuel Shut-Off Solenoid',
#    'prodCategory_ASort': 21240},
#   {'webColumn_Id': 250500,
#    'categoryName_en': 'Fuel Tank Selector Valve',
#    'prodCategory_ASort': 21250},
#   {'webColumn_Id': 292800,
#    'categoryName_en': 'Fuel Tank Vent Valve',
#    'prodCategory_ASort': 21260},
#   {'webColumn_Id': 214100,
#    'categoryName_en': 'Fuel Vapor Canister',
#    'prodCategory_ASort': 21270},
#   {'webColumn_Id': 28100,
#    'categoryName_en': 'Fuel Vapor Canister Filter',
#    'prodCategory_ASort': 21280},
#   {'webColumn_Id': 337900,
#    'categoryName_en': 'Fuel Vapor Canister Seal',
#    'prodCategory_ASort': 21290},
#   {'webColumn_Id': 302200,
#    'categoryName_en': 'Fuel Vapor Leak Detection Pump',
#    'prodCategory_ASort': 21300},
#   {'webColumn_Id': 339000,
#    'categoryName_en': 'Fuel Vapor Leak Detection Pump Filter',
#    'prodCategory_ASort': 21310},
#   {'webColumn_Id': 352300,
#    'categoryName_en': 'Fuse Block',
#    'prodCategory_ASort': 21320},
#   {'webColumn_Id': 338700,
#    'categoryName_en': 'Fuse Holder',
#    'prodCategory_ASort': 21330},
#   {'webColumn_Id': 250700,
#    'categoryName_en': 'Generator Brush Spring',
#    'prodCategory_ASort': 21340},
#   {'webColumn_Id': 107100,
#    'categoryName_en': 'Glove Compartment Lock',
#    'prodCategory_ASort': 21350},
#   {'webColumn_Id': 324500,
#    'categoryName_en': 'Glow Plug Conductor',
#    'prodCategory_ASort': 21360},
#   {'webColumn_Id': 271400,
#    'categoryName_en': 'Glow Plug Controller',
#    'prodCategory_ASort': 21370},
#   {'webColumn_Id': 265600,
#    'categoryName_en': 'Hazard Flasher',
#    'prodCategory_ASort': 21380},
#   {'webColumn_Id': 309000,
#    'categoryName_en': 'Headlamp Wiring Harness',
#    'prodCategory_ASort': 21390},
#   {'webColumn_Id': 302300,
#    'categoryName_en': 'Headlight Adjusting Motor',
#    'prodCategory_ASort': 21400},
#   {'webColumn_Id': 273900,
#    'categoryName_en': 'Headlight Switch Knob',
#    'prodCategory_ASort': 21420},
#   {'webColumn_Id': 303300,
#    'categoryName_en': 'Headlight Wiring Harness                                    ',
#    'prodCategory_ASort': 21430},
#   {'webColumn_Id': 339800,
#    'categoryName_en': 'Heater Control Valve',
#    'prodCategory_ASort': 21450},
#   {'webColumn_Id': 296800,
#    'categoryName_en': 'HID Headlight Ballast',
#    'prodCategory_ASort': 21470},
#   {'webColumn_Id': 323500,
#    'categoryName_en': 'HID Headlight Igniter',
#    'prodCategory_ASort': 21480},
#   {'webColumn_Id': 323100,
#    'categoryName_en': 'HID Side Marker Ballast',
#    'prodCategory_ASort': 21490},
#   {'webColumn_Id': 346300,
#    'categoryName_en': 'Hood Latch Assembly',
#    'prodCategory_ASort': 21500},
#   {'webColumn_Id': 323800,
#    'categoryName_en': 'Horizontal Fuel Conditioning Module',
#    'prodCategory_ASort': 21510},
#   {'webColumn_Id': 336800,
#    'categoryName_en': 'Horizontal Fuel Conditioning Module Cover Gasket Kit',
#    'prodCategory_ASort': 21520},
#   {'webColumn_Id': 113100,
#    'categoryName_en': 'Horn',
#    'prodCategory_ASort': 21530},
#   {'webColumn_Id': 348200,
#    'categoryName_en': 'HVAC Air Inlet Door Actuator',
#    'prodCategory_ASort': 21550},
#   ...],
#  'vehicleYear': [{'year': '2024'},
#   {'year': '2023'},
#   {'year': '2022'},
#   {'year': '2021'},
#   {'year': '2020'},
#   {'year': '2019'},
#   {'year': '2018'},
#   {'year': '2017'},
#   {'year': '2016'},
#   {'year': '2015'},
#   {'year': '2014'},
#   {'year': '2013'},
#   {'year': '2012'},
#   {'year': '2011'},
#   {'year': '2010'},
#   {'year': '2009'},
#   {'year': '2008'},
#   {'year': '2007'},
#   {'year': '2006'},
#   {'year': '2005'},
#   {'year': '2004'},
#   {'year': '2003'},
#   {'year': '2002'},
#   {'year': '2001'},
#   {'year': '2000'},
#   {'year': '1999'},
#   {'year': '1998'},
#   {'year': '1997'},
#   {'year': '1996'},
#   {'year': '1995'},
#   {'year': '1994'},
#   {'year': '1993'},
#   {'year': '1992'},
#   {'year': '1991'},
#   {'year': '1990'},
#   {'year': '1989'},
#   {'year': '1988'},
#   {'year': '1987'},
#   {'year': '1986'},
#   {'year': '1985'},
#   {'year': '1984'},
#   {'year': '1983'},
#   {'year': '1982'},
#   {'year': '1981'},
#   {'year': '1980'},
#   {'year': '1979'},
#   {'year': '1978'},
#   {'year': '1977'},
#   {'year': '1976'},
#   {'year': '1975'},
#   {'year': '1974'},
#   {'year': '1973'},
#   {'year': '1972'},
#   {'year': '1971'},
#   {'year': '1970'},
#   {'year': '1969'},
#   {'year': '1968'},
#   {'year': '1967'},
#   {'year': '1966'},
#   {'year': '1965'},
#   {'year': '1964'},
#   {'year': '1963'},
#   {'year': '1962'},
#   {'year': '1961'},
#   {'year': '1960'},
#   {'year': '1959'},
#   {'year': '1958'},
#   {'year': '1957'},
#   {'year': '1956'},
#   {'year': '1955'},
#   {'year': '1954'},
#   {'year': '1953'},
#   {'year': '1952'},
#   {'year': '1951'},
#   {'year': '1950'},
#   {'year': '1949'},
#   {'year': '1948'},
#   {'year': '1947'},
#   {'year': '1946'},
#   {'year': '1945'},
#   {'year': '1944'},
#   {'year': '1943'},
#   {'year': '1942'},
#   {'year': '1941'},
#   {'year': '1940'},
#   {'year': '1939'},
#   {'year': '1938'},
#   {'year': '1937'},
#   {'year': '1936'},
#   {'year': '1935'},
#   {'year': '1934'},
#   {'year': '1933'},
#   {'year': '1932'},
#   {'year': '1931'},
#   {'year': '1930'},
#   {'year': '1929'},
#   {'year': '1928'},
#   {'year': '1927'},
#   {'year': '1926'},
#   {'year': '1925'},
#   {'year': '1924'},
#   {'year': '1923'},
#   {'year': '1922'},
#   {'year': '1921'},
#   {'year': '1920'}],
#  'vehicleMake': [{'make': 'Abarth'},
#   {'make': 'AC'},
#   {'make': 'Acura'},
#   {'make': 'Alfa Romeo'},
#   {'make': 'Allard'},
#   {'make': 'Allstate'},
#   {'make': 'Alvis'},
#   {'make': 'AM General'},
#   {'make': 'American Austin'},
#   {'make': 'American Bantam'},
#   {'make': 'American Motors'},
#   {'make': 'Amphicar'},
#   {'make': 'Apollo'},
#   {'make': 'Arctic Cat'},
#   {'make': 'Armstrong-Siddeley'},
#   {'make': 'Aston Martin'},
#   {'make': 'Asuna'},
#   {'make': 'Auburn'},
#   {'make': 'Audi'},
#   {'make': 'Austin'},
#   {'make': 'Austin Healey'},
#   {'make': 'Autocar LLC.'},
#   {'make': 'Avanti'},
#   {'make': 'Bentley'},
#   {'make': 'Bering'},
#   {'make': 'Bertone'},
#   {'make': 'Bizzarrini'},
#   {'make': 'Blue Bird'},
#   {'make': 'BMW'},
#   {'make': 'Borgward'},
#   {'make': 'Bricklin'},
#   {'make': 'Bugatti'},
#   {'make': 'Buick'},
#   {'make': 'Cadillac'},
#   {'make': 'Capacity Of Texas'},
#   {'make': 'Checker'},
#   {'make': 'Chevrolet'},
#   {'make': 'Chrysler'},
#   {'make': 'Citroen'},
#   {'make': 'Continental'},
#   {'make': 'Cord'},
#   {'make': 'Crane Carrier'},
#   {'make': 'Crosley'},
#   {'make': 'Daewoo'},
#   {'make': 'DAF'},
#   {'make': 'Daihatsu'},
#   {'make': 'Daimler'},
#   {'make': 'Datsun'},
#   {'make': 'Dellow'},
#   {'make': 'DeLorean'},
#   {'make': 'DeSoto'},
#   {'make': 'DeTomaso'},
#   {'make': 'DKW'},
#   {'make': 'Dodge'},
#   {'make': 'Dual-Ghia'},
#   {'make': 'Durant'},
#   {'make': 'Eagle'},
#   {'make': 'Edsel'},
#   {'make': 'El Dorado'},
#   {'make': 'Elcar'},
#   {'make': 'Elva'},
#   {'make': 'Erskine'},
#   {'make': 'Essex'},
#   {'make': 'Excalibur'},
#   {'make': 'Facel Vega'},
#   {'make': 'Falcon Knight'},
#   {'make': 'Fargo'},
#   {'make': 'Ferrari'},
#   {'make': 'Fiat'},
#   {'make': 'Fisker'},
#   {'make': 'Flint'},
#   {'make': 'Ford'},
#   {'make': 'Franklin'},
#   {'make': 'Frazer'},
#   {'make': 'Frazer Nash'},
#   {'make': 'Freightliner'},
#   {'make': 'Gardner'},
#   {'make': 'Genesis'},
#   {'make': 'Geo'},
#   {'make': 'Gillig'},
#   {'make': 'Glas'},
#   {'make': 'GMC'},
#   {'make': 'Goliath'},
#   {'make': 'Gordon-Keeble'},
#   {'make': 'Graham'},
#   {'make': 'Graham-Paige'},
#   {'make': 'Griffith'},
#   {'make': 'Hansa'},
#   {'make': 'Henry J'},
#   {'make': 'Hillman'},
#   {'make': 'Hino'},
#   {'make': 'Honda'},
#   {'make': 'Hudson'},
#   {'make': 'Humber'},
#   {'make': 'Hummer'},
#   {'make': 'Hupmobile'},
#   {'make': 'Hyundai'},
#   {'make': 'IC Corporation'},
#   {'make': 'Infiniti'},
#   {'make': 'International'},
#   {'make': 'Iso'},
#   {'make': 'Isuzu'},
#   {'make': 'Jaguar'},
#   {'make': 'Jeep'},
#   {'make': 'Jensen'},
#   {'make': 'Jewett'},
#   {'make': 'Jowett'},
#   {'make': 'Kaiser'},
#   {'make': 'Kawasaki'},
#   {'make': 'Kenworth'},
#   {'make': 'Kia'},
#   {'make': 'Lada'},
#   {'make': 'Laforza'},
#   {'make': 'Lamborghini'},
#   {'make': 'Lancia'},
#   {'make': 'Land Rover'},
#   {'make': 'LaSalle'},
#   {'make': 'Lexus'},
#   {'make': 'Lincoln'},
#   {'make': 'Lloyd'},
#   {'make': 'Lotus'},
#   {'make': 'Mack'},
#   {'make': 'Marcos'},
#   {'make': 'Marmon'},
#   {'make': 'Maserati'},
#   {'make': 'Matra'},
#   {'make': 'Maybach'},
#   {'make': 'Mazda'},
#   {'make': 'McLaren'},
#   {'make': 'Mercedes-Benz'},
#   {'make': 'Mercury'},
#   {'make': 'Merkur'},
#   {'make': 'Metropolitan'},
#   {'make': 'MG'},
#   {'make': 'Mini'},
#   {'make': 'Mitsubishi'},
#   {'make': 'Mitsubishi Fuso'},
#   {'make': 'Monteverdi'},
#   {'make': 'Morgan'},
#   {'make': 'Morris'},
#   {'make': 'Moskvich'},
#   {'make': 'Motor Coach Industries'},
#   {'make': 'Nardi'},
#   {'make': 'Nash'},
#   {'make': 'Nissan'},
#   {'make': 'NSU'},
#   {'make': 'Oakland'},
#   {'make': 'Oldsmobile'},
#   {'make': 'Omega'},
#   {'make': 'Opel'},
#   {'make': 'Oshkosh Motor Truck Co.'},
#   {'make': 'Packard'},
#   {'make': 'Panhard'},
#   {'make': 'Panoz'},
#   {'make': 'Panther'},
#   {'make': 'Peterbilt'},
#   {'make': 'Peugeot'},
#   {'make': 'Pierce Mfg. Inc.'},
#   {'make': 'Pierce-Arrow'},
#   {'make': 'Plymouth'},
#   {'make': 'Polaris'},
#   {'make': 'Polestar'},
#   {'make': 'Pontiac'},
#   {'make': 'Porsche'},
#   {'make': 'Qvale'},
#   {'make': 'Ram'},
#   {'make': 'Reliant'},
#   {'make': 'Renault'},
#   {'make': 'Riley'},
#   {'make': 'Rivian'},
#   {'make': 'Rockne'},
#   {'make': 'Rolls-Royce'},
#   {'make': 'Rover'},
#   {'make': 'Saab'},
#   {'make': 'Saturn'},
#   {'make': 'Scion'},
#   {'make': 'Seat'},
#   {'make': 'Shelby'},
#   {'make': 'Simca'},
#   {'make': 'Singer'},
#   {'make': 'Ski-Doo'},
#   {'make': 'Smart'},
#   {'make': 'SRT'},
#   {'make': 'Standard'},
#   {'make': 'Star'},
#   {'make': 'Sterling'},
#   {'make': 'Sterling Truck'},
#   {'make': 'Studebaker'},
#   {'make': 'Stutz'},
#   {'make': 'Subaru'},
#   {'make': 'Sunbeam'},
#   {'make': 'Suzuki'},
#   {'make': 'Tesla'},
#   {'make': 'Thomas'},
#   {'make': 'Toyota'},
#   {'make': 'Triumph'},
#   {'make': 'TVR'},
#   {'make': 'VAM'},
#   {'make': 'Vauxhall'},
#   {'make': 'Vespa'},
#   {'make': 'Victory'},
#   {'make': 'Volkswagen'},
#   {'make': 'Volvo'},
#   {'make': 'VPG'},
#   {'make': 'Western Star'},
#   {'make': 'Whippet'},
#   {'make': 'Willys'},
#   {'make': 'Wolseley'},
#   {'make': 'Workhorse'},
#   {'make': 'Workhorse Custom Chassis'},
#   {'make': 'Yamaha'},
#   {'make': 'Yellow Cab'},
#   {'make': 'Yugo'}],
#  'vehicleModel': [],
#  'vehicleEngine': [],
#  'attributeCodes': [],
#  'attributeValues': [],
#  'plkEngineMake': None,
#  'plkEngineMakeModel': None,
#  'plkEngineMakeModelDisp': None}

# %%
list_type_code = [_['webColumn_Id']for _ in json_['productCategoryShort']]

list_type_code
# Out:
# [359500,
#  349200,
#  344300,
#  344600,
#  321800,
#  341700,
#  341800,
#  264900,
#  307800,
#  7150,
#  8150,
#  241700,
#  343600,
#  270900,
#  998569,
#  327200,
#  272900,
#  13350,
#  14150,
#  15100,
#  13150,
#  301500,
#  347500,
#  15186,
#  307600,
#  308400,
#  292100,
#  292200,
#  292000,
#  292300,
#  996084,
#  13300,
#  295500,
#  295600,
#  353100,
#  294100,
#  293700,
#  197100,
#  349400,
#  326500,
#  326200,
#  336900,
#  362500,
#  348600,
#  321700,
#  17157,
#  303000,
#  243300,
#  340400,
#  20100,
#  309400,
#  355100,
#  349700,
#  22100,
#  346400,
#  263600,
#  305500,
#  27150,
#  27200,
#  350000,
#  266200,
#  341900,
#  29100,
#  30100,
#  220900,
#  301400,
#  328500,
#  998665,
#  308000,
#  307900,
#  335700,
#  335800,
#  307700,
#  291000,
#  340500,
#  340700,
#  296900,
#  297000,
#  309600,
#  221000,
#  326100,
#  301900,
#  40100,
#  264100,
#  222400,
#  222500,
#  148120,
#  343800,
#  329300,
#  222700,
#  238900,
#  343900,
#  148112,
#  344100,
#  222800,
#  148104,
#  344200,
#  278900,
#  316300,
#  317100,
#  315300,
#  222900,
#  344500,
#  239400,
#  223000,
#  311100,
#  239600,
#  239700,
#  358300,
#  311900,
#  279000,
#  318200,
#  148644,
#  240000,
#  344700,
#  320300,
#  240200,
#  311400,
#  316400,
#  240300,
#  223300,
#  319800,
#  316500,
#  321000,
#  223500,
#  241000,
#  148148,
#  241200,
#  279200,
#  223600,
#  279300,
#  321100,
#  241300,
#  314600,
#  315800,
#  236900,
#  223700,
#  357600,
#  148128,
#  223800,
#  318500,
#  279400,
#  279500,
#  279600,
#  297800,
#  304200,
#  279700,
#  279800,
#  279900,
#  280000,
#  280100,
#  224000,
#  148132,
#  355700,
#  280200,
#  357100,
#  148140,
#  313700,
#  310700,
#  319500,
#  224200,
#  148308,
#  148704,
#  316600,
#  224300,
#  304300,
#  297900,
#  298000,
#  315900,
#  241800,
#  272000,
#  310100,
#  148144,
#  280300,
#  148146,
#  242300,
#  224400,
#  148152,
#  353200,
#  296000,
#  148156,
#  357000,
#  280400,
#  148684,
#  311500,
#  223400,
#  311200,
#  224500,
#  280500,
#  242900,
#  280600,
#  316000,
#  356400,
#  224800,
#  280700,
#  224900,
#  280800,
#  280900,
#  243100,
#  224600,
#  281000,
#  224700,
#  281100,
#  281200,
#  281300,
#  148164,
#  148168,
#  298100,
#  148172,
#  225000,
#  319900,
#  225100,
#  148176,
#  225200,
#  281400,
#  317200,
#  225300,
#  298200,
#  148180,
#  347300,
#  148488,
#  281500,
#  281600,
#  220800,
#  332300,
#  148181,
#  148188,
#  281700,
#  148196,
#  317300,
#  148632,
#  243800,
#  320400,
#  244000,
#  148200,
#  313800,
#  244100,
#  316700,
#  359600,
#  321200,
#  298300,
#  148572,
#  313900,
#  351300,
#  281800,
#  148204,
#  310200,
#  319200,
#  148380,
#  237000,
#  281900,
#  148212,
#  225400,
#  148216,
#  148236,
#  148472,
#  225600,
#  314000,
#  317900,
#  148228,
#  225700,
#  320500,
#  313200,
#  244800,
#  282100,
#  319600,
#  292500,
#  148232,
#  237100,
#  225800,
#  350900,
#  237200,
#  282200,
#  310800,
#  226000,
#  317400,
#  148244,
#  310300,
#  245300,
#  226100,
#  226200,
#  226300,
#  148348,
#  148360,
#  148352,
#  226400,
#  148260,
#  226500,
#  282300,
#  148264,
#  148268,
#  355300,
#  148276,
#  282400,
#  351800,
#  264000,
#  226600,
#  148272,
#  245500,
#  148280,
#  296300,
#  291400,
#  282500,
#  148284,
#  226700,
#  245600,
#  294700,
#  226800,
#  360400,
#  351900,
#  361300,
#  346800,
#  358400,
#  245800,
#  320600,
#  226900,
#  318800,
#  347000,
#  359100,
#  346700,
#  352600,
#  272200,
#  246200,
#  353700,
#  148292,
#  227000,
#  282700,
#  148296,
#  148300,
#  282800,
#  313300,
#  227200,
#  353300,
#  357700,
#  148304,
#  227300,
#  314700,
#  356900,
#  246500,
#  227400,
#  282900,
#  227500,
#  148312,
#  148316,
#  227600,
#  297500,
#  298400,
#  237500,
#  301800,
#  292400,
#  227800,
#  148320,
#  362600,
#  319700,
#  227900,
#  148324,
#  247100,
#  320700,
#  266000,
#  283000,
#  283100,
#  228000,
#  352900,
#  148328,
#  228100,
#  315400,
#  247600,
#  318000,
#  361500,
#  355800,
#  359700,
#  148372,
#  355900,
#  283200,
#  228200,
#  356000,
#  316800,
#  341400,
#  305800,
#  148724,
#  247900,
#  298500,
#  319300,
#  310900,
#  311600,
#  248200,
#  228400,
#  283300,
#  148400,
#  228500,
#  317500,
#  228600,
#  148884,
#  283400,
#  228700,
#  298600,
#  283500,
#  309900,
#  326900,
#  313400,
#  292900,
#  312200,
#  357300,
#  318100,
#  148408,
#  316900,
#  228800,
#  228900,
#  148412,
#  330200,
#  148432,
#  249600,
#  318900,
#  289400,
#  148428,
#  314800,
#  249900,
#  348400,
#  148424,
#  980574,
#  283600,
#  229000,
#  148512,
#  250300,
#  298700,
#  250400,
#  311700,
#  306300,
#  298800,
#  229100,
#  311000,
#  352800,
#  352400,
#  148436,
#  283700,
#  148440,
#  250800,
#  298900,
#  299000,
#  283800,
#  229200,
#  148450,
#  314900,
#  237600,
#  171420,
#  283900,
#  229300,
#  251200,
#  229400,
#  251300,
#  148452,
#  229500,
#  284000,
#  229600,
#  229700,
#  221800,
#  251400,
#  229800,
#  356100,
#  291600,
#  229900,
#  148464,
#  251500,
#  230000,
#  251600,
#  357900,
#  312300,
#  148476,
#  148479,
#  148480,
#  345200,
#  345500,
#  252100,
#  345700,
#  252300,
#  289800,
#  345800,
#  346000,
#  284100,
#  284200,
#  252400,
#  148492,
#  318300,
#  148496,
#  230100,
#  230200,
#  359200,
#  148504,
#  148500,
#  230300,
#  230400,
#  284300,
#  230500,
#  307100,
#  148820,
#  230600,
#  253200,
#  230700,
#  253300,
#  284400,
#  358700,
#  230800,
#  148516,
#  230900,
#  253800,
#  312700,
#  254000,
#  317600,
#  297600,
#  299100,
#  284500,
#  284600,
#  231000,
#  284700,
#  148524,
#  254200,
#  359300,
#  358800,
#  254300,
#  359400,
#  231100,
#  148528,
#  315000,
#  354200,
#  231200,
#  329200,
#  231300,
#  358900,
#  254900,
#  284800,
#  255000,
#  289500,
#  231400,
#  231500,
#  148548,
#  148552,
#  311300,
#  148520,
#  314100,
#  231600,
#  148560,
#  148568,
#  231700,
#  231800,
#  255900,
#  148576,
#  315500,
#  148589,
#  148580,
#  148588,
#  148592,
#  232000,
#  299200,
#  148596,
#  232100,
#  256100,
#  148600,
#  148604,
#  295700,
#  232200,
#  148608,
#  148612,
#  232300,
#  232400,
#  353800,
#  285000,
#  285100,
#  352500,
#  285200,
#  232500,
#  148624,
#  148628,
#  232600,
#  232700,
#  320100,
#  319000,
#  285300,
#  256600,
#  232800,
#  285400,
#  285500,
#  232900,
#  148636,
#  237800,
#  256700,
#  233000,
#  256800,
#  285800,
#  360800,
#  285900,
#  314200,
#  286000,
#  299500,
#  148640,
#  299600,
#  286100,
#  257100,
#  233100,
#  257200,
#  360900,
#  312000,
#  148648,
#  257300,
#  148652,
#  257400,
#  233200,
#  148868,
#  286200,
#  286300,
#  234900,
#  257600,
#  353900,
#  356600,
#  286400,
#  305100,
#  233300,
#  237900,
#  286500,
#  313500,
#  257800,
#  312900,
#  352700,
#  286600,
#  148664,
#  331300,
#  148540,
#  148676,
#  258300,
#  258400,
#  286800,
#  238000,
#  304400,
#  304500,
#  315600,
#  233500,
#  286900,
#  349000,
#  299700,
#  265900,
#  148688,
#  233600,
#  258600,
#  358100,
#  258700,
#  148692,
#  148696,
#  233700,
#  299800,
#  295000,
#  233800,
#  287000,
#  309100,
#  357400,
#  318700,
#  287100,
#  299900,
#  148712,
#  312400,
#  355200,
#  148564,
#  234000,
#  234100,
#  258800,
#  310400,
#  321300,
#  234200,
#  148728,
#  287200,
#  148752,
#  148760,
#  287300,
#  357200,
#  358200,
#  312100,
#  317700,
#  148768,
#  287400,
#  234400,
#  289600,
#  148772,
#  148732,
#  234500,
#  234600,
#  234700,
#  234800,
#  148776,
#  296200,
#  148784,
#  148788,
#  320800,
#  313600,
#  148800,
#  148344,
#  235000,
#  994586,
#  148804,
#  304900,
#  235100,
#  148808,
#  235200,
#  259900,
#  235300,
#  287600,
#  235400,
#  320900,
#  148812,
#  301300,
#  235500,
#  287700,
#  287800,
#  148828,
#  319100,
#  260200,
#  317000,
#  260500,
#  148832,
#  190100,
#  191100,
#  235600,
#  148716,
#  287900,
#  288000,
#  235700,
#  315100,
#  291500,
#  352100,
#  260700,
#  314300,
#  300000,
#  238200,
#  356200,
#  148840,
#  238300,
#  235800,
#  359000,
#  313000,
#  238400,
#  311800,
#  295100,
#  261700,
#  288100,
#  235900,
#  236000,
#  238600,
#  171780,
#  236100,
#  288200,
#  288400,
#  262100,
#  148844,
#  310500,
#  288500,
#  318400,
#  312500,
#  356700,
#  262300,
#  262400,
#  262500,
#  288600,
#  236200,
#  148852,
#  316200,
#  148856,
#  343300,
#  288700,
#  148864,
#  300100,
#  314400,
#  353000,
#  288800,
#  320200,
#  334800,
#  288900,
#  148872,
#  289000,
#  310600,
#  236300,
#  289100,
#  148876,
#  263200,
#  236400,
#  148888,
#  148656,
#  148896,
#  315200,
#  289200,
#  304600,
#  236500,
#  148904,
#  148900,
#  236600,
#  236700,
#  317800,
#  289300,
#  218100,
#  218150,
#  354100,
#  308900,
#  26100,
#  277700,
#  275800,
#  46126,
#  350100,
#  46166,
#  52100,
#  271300,
#  221200,
#  308800,
#  266600,
#  323600,
#  309800,
#  335000,
#  357500,
#  325700,
#  342600,
#  342700,
#  348700,
#  324800,
#  270200,
#  324900,
#  998626,
#  330300,
#  330400,
#  328800,
#  328900,
#  334700,
#  325000,
#  329500,
#  361200,
#  329900,
#  325100,
#  329100,
#  323200,
#  999925,
#  328000,
#  324100,
#  300300,
#  325200,
#  325300,
#  325400,
#  266400,
#  324300,
#  329000,
#  342500,
#  293800,
#  277800,
#  275900,
#  341200,
#  355000,
#  323300,
#  323400,
#  325500,
#  265700,
#  362200,
#  346500,
#  334600,
#  358500,
#  339100,
#  328700,
#  135180,
#  330000,
#  135220,
#  218200,
#  31100,
#  305000,
#  334500,
#  135300,
#  64100,
#  218300,
#  246300,
#  135340,
#  297100,
#  297200,
#  218400,
#  135420,
#  218500,
#  218600,
#  999875,
#  65100,
#  210100,
#  11100,
#  343000,
#  73100,
#  273100,
#  354700,
#  354900,
#  296500,
#  74100,
#  80100,
#  361600,
#  361100,
#  247000,
#  291300,
#  82130,
#  246800,
#  82119,
#  75100,
#  82126,
#  84100,
#  246900,
#  84350,
#  333400,
#  88100,
#  335500,
#  276000,
#  333800,
#  293900,
#  344900,
#  335400,
#  353500,
#  273400,
#  331000,
#  351400,
#  360500,
#  339400,
#  360600,
#  360700,
#  332900,
#  348800,
#  276300,
#  336700,
#  247800,
#  349500,
#  325800,
#  327900,
#  348000,
#  342000,
#  357800,
#  304800,
#  309200,
#  220600,
#  331800,
#  221600,
#  101000,
#  265800,
#  54100,
#  265000,
#  291200,
#  308500,
#  331100,
#  308700,
#  337700,
#  333100,
#  333200,
#  349600,
#  349300,
#  340000,
#  187100,
#  249300,
#  354800,
#  352000,
#  133025,
#  98126,
#  56100,
#  100100,
#  249700,
#  136100,
#  101100,
#  140151,
#  309300,
#  267700,
#  303400,
#  336200,
#  340900,
#  339700,
#  336600,
#  336400,
#  336300,
#  336500,
#  250100,
#  331900,
#  102100,
#  97100,
#  250500,
#  292800,
#  214100,
#  28100,
#  337900,
#  302200,
#  339000,
#  352300,
#  338700,
#  250700,
#  107100,
#  324500,
#  271400,
#  265600,
#  309000,
#  302300,
#  273900,
#  303300,
#  339800,
#  296800,
#  323500,
#  323100,
#  346300,
#  323800,
#  336800,
#  113100,
#  348200,
#  ...]

# %%
list_type = [_['categoryName_en'].strip() for _ in json_['productCategoryShort']]

list_type
# Out:
# ['4WD Hub Locking Actuator Vacuum Hose',
#  'A/C Compressor Cut-Off Relay Connector',
#  'A/C Compressor Wiring Harness',
#  'A/C Power Module',
#  'ABS Sensor Harness Repair Kit',
#  'ABS Speed Sensor Ring - Front',
#  'ABS Speed Sensor Ring - Rear',
#  'ABS Speed Sensor Wire Harness',
#  'Accelerator Pump Check Valve',
#  'Air Cleaner Check Valve',
#  'Air Cleaner Inlet Hose',
#  'Air Delay Valve',
#  'Air Filter Indicator',
#  'Air Pipe Gasket',
#  'Air Pump - New',
#  'Air Suspension Compressor',
#  'Air Suspension Spring Solenoid',
#  'Alt Bearing Tolerance Ring',
#  'Alt Terminal Hardware Kit',
#  'Alternator / Generator Brush Set',
#  'Alternator Bearing',
#  'Alternator Brush Holder Assembly',
#  'Alternator Bushing',
#  'Alternator Capacitor',
#  'Alternator Decoupler Pulley',
#  'Alternator Decoupler Pulley Tool Kit',
#  'Alternator Diode - Negative',
#  'Alternator Diode - Positive',
#  'Alternator Diode - Trio',
#  'Alternator Rectifier',
#  'Alternator Repair Kit',
#  'Alternator Resistor',
#  'Alternator Rotor',
#  'Alternator Stator',
#  'Ambient Air Temperature Sensor Kit',
#  'Auto Transmission Governor Repair Kit',
#  'Auto Transmission Oil Cooler Thermostat',
#  'Auto Transmission Vacuum Modulator',
#  'Automatic Headlight Dimmer Relay Connector',
#  'Automatic Shifter Button',
#  'Automatic Shifter Button Cover',
#  'Automatic Transmission Conductor Plate',
#  'Automatic Transmission Oil Cooler',
#  'Automatic Transmission Oil Pump',
#  'Automatic Transmission Shift Bezel',
#  'Auxiliary Air Valve',
#  'Auxiliary Heater Control Module',
#  'Auxiliary Heater Ignition Coil',
#  'Axle Shift Motor',
#  'Battery Cable',
#  'Battery Cable Bolt',
#  'Battery Terminal',
#  'Blower Motor Cut-Off Relay Connector',
#  'Blower Motor Resistor',
#  'Blower Motor Resistor Kit',
#  'Brake Indicator Lamp Driver Module',
#  'Camshaft Gear Installation Tool',
#  'Camshaft Interrupter',
#  'Camshaft Sensor Cover',
#  'Camshaft Sensor Kit',
#  'Camshaft Synchronizer',
#  'Camshaft Synchronizer Alignment Tool Kit',
#  'Canister Purge Solenoid',
#  'Canister Purge Valve',
#  'Canister Vent Solenoid',
#  'Canister Vent Solenoid Harness',
#  'Canister Vent Valve',
#  'Carburetor Flange Gasket',
#  'Carburetor Float',
#  'Carburetor Kit',
#  'Carburetor Needle And Seat',
#  'Carburetor Power Valve Kit',
#  'Carburetor Secondary Diaphragm',
#  'Center High Mount Stop Light Assembly',
#  'Charge Air Cooler',
#  'Choke Cover Gasket',
#  'Choke Pull Off',
#  'Choke Thermostat',
#  'Circuit Breaker',
#  'Clock Spring',
#  'Coil on Plug Boot',
#  'Coil On Plug Boot Kit',
#  'Cold Start Valve',
#  'Connector - A/C & Heater Blower Motor Switch',
#  'Connector - A/C & Heater Delay Relay',
#  'Connector - A/C & Heater Relay',
#  'Connector - A/C & Heater Switch',
#  'Connector - A/C and Heater Harness',
#  'Connector - A/C Auto Temperature Control Relay',
#  'Connector - A/C Blower Cut-Off Relay',
#  'Connector - A/C Clutch Coil',
#  'Connector - A/C Clutch Control Relay Harness',
#  'Connector - A/C Compressor',
#  'Connector - A/C Compressor Clutch Control Harness Ground',
#  'Connector - A/C Compressor Clutch Cut-Off Relay',
#  'Connector - A/C Compressor Clutch Relay',
#  'Connector - A/C Compressor Cut-Out Relay Harness',
#  'Connector - A/C Compressor Diode',
#  'Connector - A/C Compressor Hold Relay',
#  'Connector - A/C Compressor Throttle Cut-Off Relay',
#  'Connector - A/C Compressor Time Delay Relay',
#  'Connector - A/C Condenser Fan Motor Relay',
#  'Connector - A/C Condenser Fan Switch Harness',
#  'Connector - A/C Control Module',
#  'Connector - A/C Control Relay',
#  'Connector - A/C Cut-Off Switch',
#  'Connector - A/C Cycling Switch',
#  'Connector - A/C Electrical',
#  'Connector - A/C Evaporator Temperature Sensor',
#  'Connector - A/C Fast Idle Cut-Off Relay',
#  'Connector - A/C High Pressure Cut-Off Switch',
#  'Connector - A/C Low Pressure Cut-Out Switch',
#  'Connector - A/C Power Servo',
#  'Connector - A/C Pressure Switch',
#  'Connector - A/C Pressure Transducer',
#  'Connector - A/C Purge Relay',
#  'Connector - A/C Refrigerant Temperature Sensor',
#  'Connector - A/C Relay',
#  'Connector - A/C Selector Relay',
#  'Connector - A/C Solenoid',
#  'Connector - A/C Speed-Up Solenoid Relay',
#  'Connector - A/C Temperature Delay Relay',
#  'Connector - A/C Time Delay Relay',
#  'Connector - A/C Wiring Relay',
#  'Connector - ABS Control Module',
#  'Connector - ABS Control Module Relay',
#  'Connector - ABS Modulator Sensor',
#  'Connector - ABS Modulator Solenoid',
#  'Connector - ABS Pump',
#  'Connector - ABS Relay',
#  'Connector - ABS Speed Sensor',
#  'Connector - ABS Speed Sensor Wire Harness',
#  'Connector - ABS Switch',
#  'Connector - ABS Warning Lamp Relay',
#  'Connector - Acceleration Sensor',
#  'Connector - Accelerator Pedal Sensor',
#  'Connector - Accessory Delay Relay',
#  'Connector - Accessory Power Receptacle',
#  'Connector - Accessory Relay',
#  'Connector - Accessory Safety Relay',
#  'Connector - Active Suspension Relay',
#  'Connector - Active Suspension Sensor',
#  'Connector - Active Suspension Solenoid',
#  'Connector - Active Suspension Switch',
#  'Connector - Adjustable Pedal Motor',
#  'Connector - Adjustable Pedal Switch',
#  'Connector - Air Bag',
#  'Connector - Air Bag Diagnostic',
#  'Connector - Air Bag Disable Module',
#  'Connector - Air Bag Indicator Lamp',
#  'Connector - Air Bag Module',
#  'Connector - Air Bag Relay',
#  'Connector - Air Bag Repair Harness',
#  'Connector - Air Bag Seat Position Sensor',
#  'Connector - Air Bag Sensor',
#  'Connector - Air Brake Pressure Switch',
#  'Connector - Air Charge Temp Sensor',
#  'Connector - Air Cleaner Check Valve',
#  'Connector - Air Cleaner Door Solenoid Relay',
#  'Connector - Air Cleaner Temperature Sensor',
#  'Connector - Air Control Valve Relay',
#  'Connector - Air Duct Temp Sensor',
#  'Connector - Air Injection Reactor Pump',
#  'Connector - Air Pump',
#  'Connector - Air Pump Relay',
#  'Connector - Air Suspension Compressor Motor',
#  'Connector - Air Suspension Sensor',
#  'Connector - Air Suspension Solenoid',
#  'Connector - Air Suspension Spring Solenoid',
#  'Connector - Air Switching Valve',
#  'Connector - Alarm Chime Module',
#  'Connector - All Wheel Drive Control Relay',
#  'Connector - Alternator Electrical',
#  'Connector - Ambient Air Quality Sensor',
#  'Connector - Ambient Air Temperature Sensor',
#  'Connector - Ambient Light Sensor',
#  'Connector - Anti-Dieseling Relay',
#  'Connector - Anti-Theft Alarm',
#  'Connector - Anti-Theft Ignition Tamper Sensor',
#  'Connector - Anti-Theft Transceiver',
#  'Connector - Ashtray Lamp',
#  'Connector - Audio Control Module',
#  'Connector - Audio-Video Module',
#  'Connector - Auto Level Control Sensor',
#  'Connector - Auto Transaxle Relay',
#  'Connector - Auto Transmission Relay',
#  'Connector - Automatic Choke Relay',
#  'Connector - Automatic Headlight On/Off Relay',
#  'Connector - Automatic Level Compressor Motor',
#  'Connector - Automatic Level Control Harness',
#  'Connector - Automatic Level Control Solenoid',
#  'Connector - Automatic Shutdown Relay',
#  'Connector - Automatic Transmission Fluid Temperature Sensor',
#  'Connector - Auxiliary Air Valve',
#  'Connector - Auxiliary Battery Low Voltage Module',
#  'Connector - Auxiliary Battery Relay',
#  'Connector - Auxiliary Blower Motor',
#  'Connector - Auxiliary Blower Motor Resistor',
#  'Connector - Auxiliary Blower Switch',
#  'Connector - Auxiliary Engine Cooling Fan Relay',
#  'Connector - Auxiliary Heater & A/C',
#  'Connector - Auxiliary Heater & A/C Control Relay',
#  'Connector - Auxiliary Heater Switch',
#  'Connector - Auxiliary HVAC',
#  'Connector - Auxiliary Water Pump',
#  'Connector - Axle Shift Switch - H/D Truck',
#  'Connector - Back-up Alarm',
#  'Connector - Back-Up Camera',
#  'Connector - Back-up Lamp',
#  'Connector - Back-up Lamp Relay',
#  'Connector - Back-Up Light Socket',
#  'Connector - Back-up Light Switch',
#  'Connector - Barometric Pressure Sensor',
#  'Connector - Battery Charge Relay',
#  'Connector - Battery Current Sensor',
#  'Connector - Battery Isolation Relay',
#  'Connector - Battery Saver Relay',
#  'Connector - Battery Temperature Sensor',
#  'Connector - Battery Voltage Sensor',
#  'Connector - Blind Spot Detection Sensor',
#  'Connector - Blower Motor',
#  'Connector - Blower Motor Controller',
#  'Connector - Blower Motor Module',
#  'Connector - Blower Motor Resistor',
#  'Connector - Blower Motor Resistor High Temperature',
#  'Connector - Blower Relay',
#  'Connector - Blower Switch',
#  'Connector - Body Control Module (BCM)',
#  'Connector - Body Harness',
#  'Connector - Body Wiring Harness Relay',
#  'Connector - Brake Booster Pump',
#  'Connector - Brake Booster Pump Relay',
#  'Connector - Brake Booster Vacuum Sensor',
#  'Connector - Brake Differential Valve',
#  'Connector - Brake Fluid Level Sensor',
#  'Connector - Brake Fluid Pressure Sensor',
#  'Connector - Brake Modulator Valve Relay',
#  'Connector - Brake Pad Wear Sensor',
#  'Connector - Brake Pedal Position Sensor',
#  'Connector - Brake Pedal Travel Sensor',
#  'Connector - Brake Pressure Sensor',
#  'Connector - Brake Pressure Switch',
#  'Connector - Bulb Overload Protection Relay',
#  'Connector - Cabin Air Temperature Sensor',
#  'Connector - Camshaft Position Solenoid',
#  'Connector - Camshaft Sensor',
#  'Connector - Camshaft Synchronizer',
#  'Connector - Canister Purge Solenoid',
#  'Connector - Canister Purge Vacuum Switch',
#  'Connector - Canister Purge Valve',
#  'Connector - Canister Vent Solenoid',
#  'Connector - Cargo Lamp',
#  'Connector - Cargo Lamp Relay',
#  'Connector - Catalytic Conv Temp Sensor',
#  'Connector - CD Player',
#  'Connector - Center Stoplight',
#  'Connector - Center Stoplight Relay',
#  'Connector - Charge Lamp Relay',
#  'Connector - Choke Thermostat',
#  'Connector - Cigar Lighter',
#  'Connector - Cigar Lighter Relay',
#  'Connector - Circuit Opening Relay',
#  'Connector - Climate Control Module',
#  'Connector - Clock',
#  'Connector - Clock Spring',
#  'Connector - Clutch Interlock Relay',
#  'Connector - Clutch Pedal Position Switch',
#  'Connector - Clutch Starter Safety Switch',
#  'Connector - Cold Start Relay',
#  'Connector - Cold Start Valve',
#  'Connector - Cold Start Valve Temperature Switch',
#  'Connector - Combination Switch',
#  'Connector - Compass Module',
#  'Connector - Computer',
#  'Connector - Computer Control Relay',
#  'Connector - Concealed Headlight Relay',
#  'Connector - Console Harness',
#  'Connector - Convertible Top Relay',
#  'Connector - Convertible Top Switch',
#  'Connector - Coolant Fan Relay',
#  'Connector - Coolant Fan Switch',
#  'Connector - Coolant Level Relay',
#  'Connector - Coolant Level Sensor',
#  'Connector - Coolant Temp Sensor',
#  'Connector - Cooling Fan Motor',
#  'Connector - Cornering Light Socket',
#  'Connector - Courtesy Lamp',
#  'Connector - Courtesy Lamp Relay',
#  'Connector - Courtesy Lamp Switch',
#  'Connector - Crankcase Vent Heater',
#  'Connector - Crankshaft Sensor',
#  'Connector - Crash Sensor',
#  'Connector - Crossbody Harness',
#  'Connector - Cruise Control',
#  'Connector - Cruise Control Distance Sensor',
#  'Connector - Cruise Control Module',
#  'Connector - Cruise Control Relay',
#  'Connector - Cruise Control Release Switch',
#  'Connector - Cruise Control Servo',
#  'Connector - Cruise Control Switch',
#  'Connector - Cylinder Head Temperature Sensor',
#  'Connector - Datalink',
#  'Connector - Daytime Running Lamp',
#  'Connector - Daytime Running Lamp Module',
#  'Connector - Daytime Running Lamp Relay',
#  'Connector - Daytime Running Light Resistor',
#  'Connector - Deck Lid Module',
#  'Connector - Defroster Relay',
#  'Connector - Diesel Exhaust Fluid (DEF) Pump',
#  'Connector - Diesel Fuel Injection Pump',
#  'Connector - Diesel Fuel Injector Fuel Return Hose',
#  'Connector - Diesel Fuel Injector Rail',
#  'Connector - Diesel Glow Plug',
#  'Connector - Diesel Glow Plug Controller',
#  'Connector - Diesel Glow Plug Indicator Relay',
#  'Connector - Diesel Glow Plug Relay',
#  'Connector - Diesel Glow Plug Temp Sensor',
#  'Connector - Diesel Nitrogen Oxide (NOx) Sensor',
#  'Connector - Diesel Nitrogen Oxide (Nox) Sensor Module',
#  'Connector - Diesel Particulate Filter (DPF) Pressure Sensor',
#  'Connector - Diesel Particulate Sensor',
#  'Connector - Diesel Valve Cover Gasket',
#  'Connector - Diesel Wait Lamp Relay',
#  'Connector - Differential Oil Temperature Sensor',
#  'Connector - Distributor',
#  'Connector - Distributor Pick-up Assembly',
#  'Connector - Diverter Valve',
#  'Connector - Diverter Valve Harness',
#  'Connector - Dome Lamp',
#  'Connector - Door Ajar Chime',
#  'Connector - Door Ajar Relay',
#  'Connector - Door Ajar Warning Switch',
#  'Connector - Door Cylinder Anti-Theft Disarm Switch',
#  'Connector - Door Handle Touch Sensor',
#  'Connector - Door Harness',
#  'Connector - Door Jamb Switch',
#  'Connector - Door Lock Position Switch',
#  'Connector - Door Mirror Harness',
#  'Connector - Downshift Solenoid',
#  'Connector - Driving Lamp Relay',
#  'Connector - Dvd Player',
#  'Connector - Early Fuel Evaporation (efe) Relay',
#  'Connector - EEC Relay',
#  'Connector - EEC Test Plug',
#  'Connector - EGR Control Solenoid',
#  'Connector - EGR Tube',
#  'Connector - EGR Vacuum Regulator Solenoid',
#  'Connector - EGR Valve',
#  'Connector - EGR Valve Position Sensor',
#  'Connector - EGR Valve Pressure Feedback Sensor',
#  'Connector - EGR Valve Relay',
#  'Connector - EGR Valve Sensor',
#  'Connector - EGR Valve Temperature Sensor',
#  'Connector - EGR Valve Vacuum Modulator',
#  'Connector - Electronic Brake Control Relay',
#  'Connector - Electronic Brake Harness',
#  'Connector - Electronic Brake Relay',
#  'Connector - Electronic Throttle Body',
#  'Connector - Electronic Throttle Control',
#  'Connector - Emergency Vehicle Lamp',
#  'Connector - Emergency Vehicle Lamp Switch',
#  'Connector - Emission Control Relay',
#  'Connector - Engine Brake Relay',
#  'Connector - Engine Control Module Harness',
#  'Connector - Engine Control Relay',
#  'Connector - Engine Control Starter Switch Relay',
#  'Connector - Engine Coolant Fan Motor',
#  'Connector - Engine Coolant Thermostat Housing',
#  'Connector - Engine Cooling Fan Resistor',
#  'Connector - Engine Crankcase Breather Hose',
#  'Connector - Engine Cylinder Deactivation Solenoid',
#  'Connector - Engine Harness',
#  'Connector - Engine Intake Manifold Valve Actuator',
#  'Connector - Engine Oil Level Module',
#  'Connector - Engine Oil Level Sensor',
#  'Connector - Engine Oil Pressure Sensor',
#  'Connector - Engine Oil Temperature Sender',
#  'Connector - Engine Oil Temperature Sensor',
#  'Connector - Engine Oil Temperature Switch',
#  'Connector - Engine Shutdown Switch Harness',
#  'Connector - Engine Speed Sensor',
#  'Connector - Engine Variable Timing Solenoid',
#  'Connector - Engine Wiring Relay',
#  'Connector - Exhaust Back Pressure Sensor',
#  'Connector - Exhaust Gas Temperature Sensor',
#  'Connector - Fast Idle Relay',
#  'Connector - Fast Idle Solenoid Relay',
#  'Connector - Flex Fuel Sensor',
#  'Connector - Fog Lamp',
#  'Connector - Fog Lamp Relay',
#  'Connector - Fog Lamp Socket',
#  'Connector - Fog Lamp Switch',
#  'Connector - Four Wheel Drive Actuator',
#  'Connector - Four Wheel Drive Ind Lamp',
#  'Connector - Four Wheel Drive Ind Lamp Switch',
#  'Connector - Four Wheel Drive Locking Hub Solenoid',
#  'Connector - Four Wheel Drive Selector Switch',
#  'Connector - Front Drive Clutch Actuator Solenoid',
#  'Connector - Front Lamp Harness',
#  'Connector - Fuel / Water Separator Sensor',
#  'Connector - Fuel Door Lock Actuator',
#  'Connector - Fuel Door Release Switch',
#  'Connector - Fuel Filler Door Lock Actuator',
#  'Connector - Fuel Filler Door Relay',
#  'Connector - Fuel Heater',
#  'Connector - Fuel Injection Control Pressure Sensor',
#  'Connector - Fuel Injection Pump Relay',
#  'Connector - Fuel Injection Relay',
#  'Connector - Fuel Injector',
#  'Connector - Fuel Injector Harness',
#  'Connector - Fuel Level Sender',
#  'Connector - Fuel Level Sensor',
#  'Connector - Fuel Pressure Regulator',
#  'Connector - Fuel Pressure Sensor',
#  'Connector - Fuel Pump',
#  'Connector - Fuel Pump By-Pass Relay',
#  'Connector - Fuel Pump Control Module',
#  'Connector - Fuel Pump Cut-Off Switch',
#  'Connector - Fuel Pump Pressure Switch',
#  'Connector - Fuel Pump Relay',
#  'Connector - Fuel Pump Sender',
#  'Connector - Fuel Shut-Off Relay',
#  'Connector - Fuel Shut-Off Solenoid',
#  'Connector - Fuel Tank Harness',
#  'Connector - Fuel Tank Pressure Sensor',
#  'Connector - Fuel Tank Pressure Switch',
#  'Connector - Fuel Tank Selector Switch',
#  'Connector - Fuel Tank Selector Valve',
#  'Connector - Fuel Temperature Sensor',
#  'Connector - Fuel Vapor / Vent Pressure Sensor',
#  'Connector - Fuel Vapor Canister',
#  'Connector - Fuel Vapor Leak Detection Pump',
#  'Connector - Fuel Volume Regulator Solenoid',
#  'Connector - Fuse',
#  'Connector - G Force Sensor',
#  'Connector - Garage Door Opener',
#  'Connector - Glove Box Lamp',
#  'Connector - GPS Antenna',
#  'Connector - GPS Control Module',
#  'Connector - Ground Bus Bar',
#  'Connector - Hall Effect Switch',
#  'Connector - Hazard Flasher',
#  'Connector - Hazard Warning Relay',
#  'Connector - Hazard Warning Switch',
#  'Connector - Headlight',
#  'Connector - Headlight Actuator',
#  'Connector - Headlight Actuator Relay',
#  'Connector - Headlight Control Module',
#  'Connector - Headlight Delay Relay',
#  'Connector - Headlight Dimmer Relay',
#  'Connector - Headlight Dimmer Switch',
#  'Connector - Headlight Dimmer Switch Relay',
#  'Connector - Headlight Leveling Actuator',
#  'Connector - Headlight Motor Relay',
#  'Connector - Headlight Relay',
#  'Connector - Headlight Switch',
#  'Connector - Headlight Washer Pump',
#  'Connector - Headlight Washer Relay',
#  'Connector - Headlight Wiring Harness',
#  'Connector - Heads-up Display Module',
#  'Connector - Heated Mirror Relay',
#  'Connector - Heated Seat',
#  'Connector - Heated Seat Module',
#  'Connector - Heated Seat Relay',
#  'Connector - Heated Seat Switch',
#  'Connector - Heated Steering Wheel Module',
#  'Connector - Heater Core Temperature Sensor',
#  'Connector - Hood Ajar Switch',
#  'Connector - Horn',
#  'Connector - Horn Relay',
#  'Connector - HVAC Binary Switch Harness',
#  'Connector - HVAC Blower Relay Harness',
#  'Connector - HVAC Control Lamp',
#  'Connector - HVAC Harness',
#  'Connector - HVAC High Blower Relay',
#  'Connector - HVAC Mode Door Actuator',
#  'Connector - HVAC Power Module (ATC) Relay Harness',
#  'Connector - HVAC Recirculation Door Actuator Harness',
#  'Connector - HVAC Recirculation Mode Door Actuator',
#  'Connector - HVAC Temperature Blend Door Actuator',
#  'Connector - Idle Air Bypass Valve',
#  'Connector - Idle Air Control Valve',
#  'Connector - Idle Speed Control Actuator Solenoid',
#  'Connector - Idle Speed Control Motor',
#  'Connector - Idle Speed Control Relay',
#  'Connector - Idle Speed Stabilizer',
#  'Connector - Ignition / Radio Capacitor',
#  'Connector - Ignition Coil',
#  'Connector - Ignition Control Module',
#  'Connector - Ignition Control Module Relay',
#  'Connector - Ignition Feed Relay',
#  'Connector - Ignition Lock Cylinder',
#  'Connector - Ignition Relay',
#  'Connector - Ignition Starter Switch',
#  'Connector - Ignition Timing Adjuster',
#  'Connector - Ignition Warning Buzzer Relay',
#  'Connector - Illuminated Entry Switch',
#  'Connector - Illumination Relay',
#  'Connector - Information Display Module',
#  'Connector - Information Display Switch',
#  'Connector - Instrument Cluster',
#  'Connector - Instrument Cluster Relay',
#  'Connector - Instrument Panel',
#  'Connector - Instrument Panel Dimmer Switch',
#  'Connector - Instrument Panel Harness',
#  'Connector - Instrument Panel Illumination Relay',
#  'Connector - Instrument Panel Lamp',
#  'Connector - Instrument Panel Wiring Relay',
#  'Connector - Intake Air Temperature Sensor',
#  'Connector - Intake Manifold Runner Control Sensor',
#  'Connector - Intake Manifold Runner Solenoid',
#  'Connector - Interior Lamp',
#  'Connector - Interior Lamp Relay',
#  'Connector - Interior Light Module',
#  'Connector - Interior Light Switch',
#  'Connector - Junction Block',
#  'Connector - Keyless Entry Antenna',
#  'Connector - Keyless Entry Keypad',
#  'Connector - Keyless Entry Module',
#  'Connector - Keyless Entry Switch',
#  'Connector - Keyless Entry System Relay',
#  'Connector - Knock Sensor',
#  'Connector - Lambda Heater Relay',
#  'Connector - Lane Departure System Camera',
#  'Connector - LCD Relay',
#  'Connector - License Plate Light',
#  'Connector - License Plate Light Socket',
#  'Connector - Liftgate Control Module',
#  'Connector - Liftgate Harness',
#  'Connector - Liftgate Release Actuator',
#  'Connector - Liftgate Release Switch',
#  'Connector - Light Control Module',
#  'Connector - Load Leveling Relay',
#  'Connector - Low Fuel Relay',
#  'Connector - Lumbar Pump',
#  'Connector - Lumbar Switch',
#  'Connector - Main Relay',
#  'Connector - Manifold Air Temp Sensor',
#  'Connector - Manifold Differential Pressure Sensor',
#  'Connector - Manifold Heater Relay',
#  'Connector - Map Sensor',
#  'Connector - Mass Air Flow (MAF)',
#  'Connector - Mass Air Flow (MAF) Sensor Relay',
#  'Connector - Micro Plug Relay',
#  'Connector - Microprocessor Control Unit Relay',
#  'Connector - Mirror Switch',
#  'Connector - Misfire Sensor',
#  'Connector - Mixture Control Solenoid',
#  'Connector - Mobile Phone',
#  'Connector - Multi-Function Switch',
#  'Connector - Neutral Safety Switch',
#  'Connector - Neutral Safety Switch Relay',
#  'Connector - Neutral Tow Switch',
#  'Connector - Oil Change Reset Switch',
#  'Connector - Oil Level Indicator Relay',
#  'Connector - Oil Level Sensor',
#  'Connector - Oil Pressure Switch',
#  'Connector - Opera Lamp',
#  'Connector - Overdrive Cancel Switch',
#  'Connector - Overdrive Relay',
#  'Connector - Overhead Console Harness',
#  'Connector - Oxygen Sensor',
#  'Connector - Oxygen Sensor Relay',
#  'Connector - Park & Turn Signal Socket',
#  'Connector - Park Assist Camera',
#  'Connector - Park Assist Module',
#  'Connector - Park Assist Sensor',
#  'Connector - Parking Brake Actuator',
#  'Connector - Parking Brake Module',
#  'Connector - Parking Brake Release Relay',
#  'Connector - Parking Brake Switch',
#  'Connector - Parking Lamp',
#  'Connector - Parking Lamp Relay',
#  'Connector - Passive Restraint Relay',
#  'Connector - PCV Valve',
#  'Connector - Ported Vacuum Switch',
#  'Connector - Power Antenna Module',
#  'Connector - Power Antenna Motor',
#  'Connector - Power Antenna Relay',
#  'Connector - Power Antenna Switch',
#  'Connector - Power Brake Booster Sensor',
#  'Connector - Power Brake Relay',
#  'Connector - Power Distribution Block',
#  'Connector - Power Door Lock Actuator',
#  'Connector - Power Door Lock Module',
#  'Connector - Power Door Lock Relay',
#  'Connector - Power Door Lock Switch',
#  'Connector - Power Door Motor',
#  'Connector - Power Inverter',
#  'Connector - Power Mirror',
#  'Connector - Power Mirror Relay',
#  'Connector - Power Running Board Module',
#  'Connector - Power Seat',
#  'Connector - Power Seat Harness',
#  'Connector - Power Seat Lumbar Motor',
#  'Connector - Power Seat Memory Switch',
#  'Connector - Power Seat Module',
#  'Connector - Power Seat Relay',
#  'Connector - Power Seat Switch',
#  'Connector - Power Sliding Door Module',
#  'Connector - Power Sliding Door Switch',
#  'Connector - Power Steering Harness',
#  'Connector - Power Steering Module',
#  'Connector - Power Steering Pressure Sensor',
#  'Connector - Power Steering Pressure Switch',
#  'Connector - Power Steering Relay',
#  'Connector - Power Steering Solenoid',
#  'Connector - Power Sunroof Module',
#  'Connector - Power Sunroof Motor',
#  'Connector - Power Sunroof Relay',
#  'Connector - Power Sunroof Switch',
#  'Connector - Power Take Off (PTO) Reduction Drive Gear Sensor',
#  'Connector - Power Take-Off Switch',
#  'Connector - Power Window Module',
#  'Connector - Power Window Motor',
#  'Connector - Power Window Relay',
#  'Connector - Power Window Switch',
#  'Connector - Powertrain Control Module',
#  'Connector - Powertrain Control Module Relay',
#  'Connector - Pulse Wiper Module',
#  'Connector - Purge Flow Sensor',
#  'Connector - Radiator Active Grille Shutter Assembly',
#  'Connector - Rain Sensor',
#  'Connector - Reading Lamp',
#  'Connector - Rear Heater Coolant Shut-Off Solenoid',
#  'Connector - Rear Lamp Harness',
#  'Connector - Rear View Mirror',
#  'Connector - Rear View Mirror Switch',
#  'Connector - Rear Window Defogger',
#  'Connector - Rear Window Defogger Module',
#  'Connector - Rear Window Defogger Switch',
#  'Connector - Rear Window Washer Pump',
#  'Connector - Rear Window Wiper Motor',
#  'Connector - Relay Box Temperature Switch',
#  'Connector - Relay Control Module',
#  'Connector - Remote Mirror Switch',
#  'Connector - Ride Height Sensor',
#  'Connector - Roof Marker Light',
#  'Connector - Running Board Light',
#  'Connector - Seat Adjuster Motor',
#  'Connector - Seat Back Latch Relay',
#  'Connector - Seat Belt Harness',
#  'Connector - Seat Belt Pretensioner',
#  'Connector - Seat Belt Retractor Relay',
#  'Connector - Seat Belt Solenoid',
#  'Connector - Seat Belt Switch',
#  'Connector - Seat Belt Warning Relay',
#  'Connector - Seat Height Position Sensor',
#  'Connector - Seat Memory Module',
#  'Connector - Secondary Air Injection Pump Relay',
#  'Connector - Secondary Air Injection Pump Shutoff Valve',
#  'Connector - Secondary Air Injection Solenoid',
#  'Connector - Serial Data Gateway Module',
#  'Connector - Shift Interlock Actuator',
#  'Connector - Shift Interlock Module',
#  'Connector - Shift Interlock Solenoid',
#  'Connector - Shift Interlock Switch',
#  'Connector - Shift Light Relay',
#  'Connector - Shock Absorber Control Actuator',
#  'Connector - Side Marker Lamp',
#  'Connector - Side Marker Lamp Relay',
#  'Connector - Side Marker Socket',
#  'Connector - Siren',
#  'Connector - Siren Relay',
#  'Connector - Speed Buzzer Relay',
#  'Connector - Starter Cut-Off Relay',
#  'Connector - Starter Relay',
#  'Connector - Starter Solenoid',
#  'Connector - Steering Angle Sensor',
#  'Connector - Steering Column Harness',
#  'Connector - Steering Column Lock Module',
#  'Connector - Steering Column Tilt - Telescope Motor',
#  'Connector - Steering Wheel Air Bag',
#  'Connector - Steering Wheel Audio Control Switch',
#  'Connector - Steering Wheel Memory Relay',
#  'Connector - Stepwell Lamp',
#  'Connector - Stereo Amplifier',
#  'Connector - Stereo Amplifier Relay',
#  'Connector - Stereo Control Module',
#  'Connector - Stereo Power',
#  'Connector - Stereo Speaker',
#  'Connector - Stereo Speaker Relay',
#  'Connector - Stereo Wiring Relay',
#  'Connector - Stop, Turn & Taillight Socket',
#  'Connector - Stoplight Relay',
#  'Connector - Stoplight Switch',
#  'Connector - Subwoofer Speaker',
#  'Connector - Sunload Temp Sensor',
#  'Connector - Sunroof Harness',
#  'Connector - Supercharger Bypass Solenoid',
#  'Connector - Supercharger Relay',
#  'Connector - Tachometer',
#  'Connector - Tailgate Harness',
#  'Connector - Tailgate Relay',
#  'Connector - Tailgate Window Motor',
#  'Connector - Taillight',
#  'Connector - Taillight Circuit Board',
#  'Connector - Taillight Relay',
#  'Connector - Temperature Sending Unit',
#  'Connector - Theft Deterrent Relay',
#  'Connector - Throttle Actuator Motor',
#  'Connector - Throttle Control Actuator',
#  'Connector - Throttle Control Actuator Module',
#  'Connector - Throttle Control Relay',
#  'Connector - Throttle Lever Actuator Relay',
#  'Connector - Throttle Position Sensor',
#  'Connector - Tilt Wheel Motor',
#  'Connector - Tilt Wheel Relay',
#  'Connector - Tire Pressure Indicator Reset',
#  'Connector - Tire Pressure Monitor Module',
#  'Connector - Torque Conv Clutch Switch',
#  'Connector - Torque Converter Clutch Relay',
#  'Connector - Torque Converter Clutch Solenoid',
#  'Connector - Torque Converter Lock-Up Switch',
#  'Connector - Traction Control Module',
#  'Connector - Traction Control Switch',
#  'Connector - Trailer',
#  'Connector - Trailer Brake Control',
#  'Connector - Trailer Towing Package Relay',
#  'Connector - Trans Shift Valve Solenoid',
#  'Connector - Transfer Case Module',
#  'Connector - Transfer Case Motor',
#  'Connector - Transfer Case Relay',
#  'Connector - Transfer Case Shift Harness',
#  'Connector - Transfer Case Temperature Sensor',
#  'Connector - Transmission Bulkhead',
#  'Connector - Transmission Control Module',
#  'Connector - Transmission Control Relay',
#  'Connector - Transmission Control Solenoid',
#  'Connector - Transmission Down Shift Relay',
#  'Connector - Transmission Fluid Valve Assembly',
#  'Connector - Transmission Harness',
#  'Connector - Transmission Input Sensor',
#  'Connector - Transmission Oil Pressure Switch',
#  'Connector - Transmission Oil Pump',
#  'Connector - Transmission Oil Temp Sensor',
#  'Connector - Transmission Output Sensor',
#  'Connector - Transmission Overdrive Relay',
#  'Connector - Transmission Range Sensor',
#  'Connector - Transmission Shift Lock Control Solenoid',
#  'Connector - Transmission Shift Lock Module',
#  'Connector - Transmission Spark Control Relay',
#  'Connector - Transmission Up-Shift Relay',
#  'Connector - Trunk Ajar Switch',
#  'Connector - Trunk Lamp',
#  'Connector - Trunk Lid Release Relay',
#  'Connector - Trunk Pull-down Actuator',
#  'Connector - Trunk Pull-down Switch',
#  'Connector - Trunk Release Solenoid',
#  'Connector - Trunk Release Switch',
#  'Connector - Turbo Boost Control Relay',
#  'Connector - Turbo Waste Gate Valve',
#  'Connector - Turbocharger Boost Sensor',
#  'Connector - Turbocharger Boost Solenoid',
#  'Connector - Turbocharger Wastegate Actuator',
#  'Connector - Turn Signal Chime Module',
#  'Connector - Turn Signal Flasher',
#  'Connector - Turn Signal Lamp',
#  'Connector - Turn Signal Module',
#  'Connector - Turn Signal Relay',
#  'Connector - Turn Signal Switch',
#  'Connector - Twilight Sentinel Relay',
#  'Connector - Underhood Lamp',
#  'Connector - Vacuum Pump',
#  'Connector - Valve Deactivation Solenoid',
#  'Connector - Vanity Mirror',
#  'Connector - Vapor Canister Purge Solenoid',
#  'Connector - Variable Valve Timing (VVT) Actuator',
#  'Connector - Variable Valve Timing (VVT) Oil Pressure Switch',
#  'Connector - Vehicle Communication Interface Module (VCIM)',
#  'Connector - Vehicle Ride Height Switch',
#  'Connector - Vehicle Speed Sensor',
#  'Connector - Vehicle Speed Sensor Module',
#  'Connector - Voltage Regulator',
#  'Connector - W/S Washer Fluid Heater',
#  'Connector - Warm-Up Regulator',
#  'Connector - Warning Lamp Relay',
#  'Connector - Washer Fluid Level Lamp',
#  'Connector - Washer Fluid Level Sensor',
#  'Connector - Water In Fuel Sensor',
#  'Connector - Water Pump Relay',
#  'Connector - Wheel Speed Sensor',
#  'Connector - Window Regulator Motor',
#  'Connector - Window Switch Lamp',
#  'Connector - Windshield Washer Level Sensor',
#  'Connector - Windshield Washer Nozzle',
#  'Connector - Windshield Washer Pump',
#  'Connector - Windshield Washer Relay',
#  'Connector - Windshield Wiper Motor',
#  'Connector - Windshield Wiper Switch',
#  'Connector - Wiper Relay',
#  'Connector - Wiring Relay',
#  'Connector - X-Contact Relay',
#  'Connector - Yaw Rate Sensor',
#  'Contact Set (Points)',
#  'Contact Set (Points) & Condenser',
#  'Coolant Temperature Sensor Kit',
#  'Cornering Lamp Wiring Harness',
#  'Crankcase Ventilation Filter',
#  'Crankcase Ventilation Grommet',
#  'Crankshaft Interrupter Blade',
#  'Crankshaft Sensor Bracket',
#  'Crankshaft Sensor Kit',
#  'Crankshaft Sensor Spacer',
#  'Dashpot',
#  'Daytime Running Lamp Module',
#  'Daytime Running Lamp Resistor',
#  'Daytime Running Lamp Wiring Harness',
#  'Diesel Air Intake Heater',
#  'Diesel EGR Cooler Gasket Kit',
#  'Diesel Emission Fluid Injection Nozzle',
#  'Diesel Exhaust Fluid (DEF) Heater',
#  'Diesel Exhaust Fluid (DEF) Injector Feed Line',
#  'Diesel Exhaust Fluid (DEF) Pump',
#  'Diesel Exhaust Fluid (DEF) Pump Wiring Harness',
#  'Diesel Exhaust Fluid (DEF) Tank',
#  'Diesel Fuel Cooler',
#  'Diesel Fuel Filter Housing',
#  'Diesel Fuel Heater',
#  'Diesel Fuel Injection Harness',
#  'Diesel Fuel Injection Heat Shield',
#  'Diesel Fuel Injection Pump - New',
#  'Diesel Fuel Injection Pump - Remanufactured',
#  'Diesel Fuel Injector Control Module (FICM)',
#  'Diesel Fuel Injector Driver Module (IDM)',
#  'Diesel Fuel Injector Installation Kit',
#  'Diesel Fuel Injector Line',
#  'Diesel Fuel Injector Rail',
#  'Diesel Fuel Injector Retaining Bracket',
#  'Diesel Fuel Injector Return Hose',
#  'Diesel Fuel Injector Sleeve',
#  'Diesel Fuel Rail Supply Line',
#  'Diesel Fuel Transfer Pump',
#  'Diesel Glow Plug',
#  'Diesel Glow Plug Wiring Harness',
#  'Diesel High Pressure Oil Pump Hose',
#  'Diesel High Pressure Oil Pump Seal Kit',
#  'Diesel High Pressure Oil Rail Ball Installation Tool',
#  'Diesel High Pressure Oil Rail Ball Tube',
#  'Diesel High Pressure Oil Rail Seal Kit',
#  'Diesel Injection High Pressure Oil Pump',
#  'Diesel Injection Pump Installation Kit',
#  'Diesel Injection Pump Supply Line',
#  'Diesel Injector Connector Removal Tool',
#  'Diesel Injector Pump Driver Relocation Kit',
#  'Diesel Injector Pump Module',
#  'Diesel Injector Pump Module Resistor',
#  'Diesel Injector Retaining Bracket Socket',
#  'Diesel Nitrogen Oxide (NOx) Sensor Module',
#  'Diesel Oil Cooler Gasket Kit',
#  'Diesel Oil Cooler Kit',
#  'Diesel Valve Cover Gasket',
#  'Diesel Valve Cover Gasket With Harness',
#  'Differential Lock Motor',
#  'Direct Ignition Coil Kit',
#  'Direct Injection High Pressure Fuel Pump',
#  'Direct Injection High Pressure Fuel Pump Kit',
#  'Distributor Advance Weights',
#  'Distributor Assembly',
#  'Distributor Breaker Plate',
#  'Distributor Brush Kit',
#  'Distributor Bushing',
#  'Distributor Cap',
#  'Distributor Cap Adapter',
#  'Distributor Cap and Rotor Kit',
#  'Distributor Cap and Spark Plug Wire Kit',
#  'Distributor Cap Cover',
#  'Distributor Cap Gasket',
#  'Distributor Condenser',
#  'Distributor Felt Washer',
#  'Distributor Gear & Pin Kit',
#  'Distributor Lead Wire - Ground',
#  'Distributor Lead Wire - Primary',
#  'Distributor Pick-Up Assembly',
#  'Distributor Pole Piece',
#  'Distributor Reluctor',
#  'Distributor Rotor',
#  'Distributor Spacer',
#  'Distributor Vacuum Advance Check Valve',
#  'Distributor Vacuum Advance Control',
#  'Diverter Valve',
#  'Door Latch Assembly',
#  'Door Lock Kit',
#  'Drill Bit',
#  'Drive Motor Battery Pack Charging Cord',
#  'Drive Motor Battery Pack Charging Cord Adapter',
#  'Driveshaft Center Support Bearing',
#  'Early Fuel Evaporation (EFE) Heater Assembly',
#  'EGR Control Solenoid',
#  'EGR Cooler',
#  'EGR Cooler Gasket',
#  'EGR Pressure Feedback Hose',
#  'EGR Repair Kit',
#  'EGR Tube',
#  'EGR Tube Gasket',
#  'EGR Valve',
#  'EGR Valve Control Sol Filter',
#  'EGR Valve Mounting Gasket',
#  'EGR Valve Spacer Plate',
#  'EGR Valve Spacer Plate Gasket',
#  'EGR Valve Vacuum Modulator',
#  'Electric Water Pump',
#  'Electronic Ignition Conversion Kit',
#  'Electronic Throttle Body (ETB) Gasket',
#  'Engine Block Heater',
#  'Engine Coolant Bypass Solenoid',
#  'Engine Coolant Expansion Tank',
#  'Engine Cooling Fan Controller',
#  'Engine Cooling Fan Module',
#  'Engine Cooling Fan Resistor',
#  'Engine Crankcase Breather Hose',
#  'Engine Cylinder Deactivation Solenoid',
#  'Engine Oil Cooler',
#  'Engine Oil Cooler Coolant Pipe',
#  'Engine Oil Filler Tube',
#  'Engine Oil Filter Housing Assembly',
#  'Engine Oil Filter Housing Kit',
#  'Engine Oil Pressure Filter',
#  'Engine Oil Pump',
#  'Engine Oil Separator',
#  'Engine Oil Stand Pipe and Dummy Plug Kit',
#  'Engine Oil Temperature Sender',
#  'Engine Temperature Warning Buzzer Relay Connector',
#  'Engine Variable Valve Timing Spool Filter',
#  'Engine Variable Valve Timing Sprocket',
#  'Exhaust Control Valve Actuator',
#  'Exhaust Gas Recirculation Back Pressure Transducer',
#  'Exterior Door Handle Repair Kit',
#  'Fast Idle Valve Solenoid',
#  'Fog Lamp Wiring Harness',
#  'Four Wheel Drive Actuator',
#  'Four Wheel Drive Locking Hub',
#  'Fuel / Water Separator Valve',
#  'Fuel Damper Assembly',
#  'Fuel Damper Assembly O-Ring',
#  'Fuel Deceleration Diaphragm',
#  'Fuel Deceleration Valve',
#  'Fuel Door Lock Actuator',
#  'Fuel Feed Line',
#  'Fuel Filter and Pressure Regulator Assembly',
#  'Fuel Filter Housing Seal Kit',
#  'Fuel Injection Throttle Body',
#  'Fuel Injector - Diesel - New',
#  'Fuel Injector - Diesel - Remfd',
#  'Fuel Injector - New',
#  'Fuel Injector - Remfd',
#  'Fuel Injector Connector Clip',
#  'Fuel Injector Filter Screen',
#  'Fuel Injector Installation Kit',
#  'Fuel Injector Kit - Diesel - Remfd',
#  'Fuel Injector Rail Kit - GDI',
#  'Fuel Injector Retaining Bracket',
#  'Fuel Injector Seal Kit',
#  'Fuel Line O-Ring Kit',
#  'Fuel Line Repair Kit',
#  'Fuel Line Retainer',
#  'Fuel Mixture Control Solenoid',
#  'Fuel Pressure Regulator',
#  'Fuel Pressure Regulator O-Ring',
#  'Fuel Pressure Regulator Upgrade Kit',
#  'Fuel Pressure Relief Valve',
#  'Fuel Pressure Warning Light Kit',
#  'Fuel Pump Camshaft Follower',
#  'Fuel Pump Driver Module',
#  'Fuel Pump Fitting',
#  'Fuel Pump Mounting Gasket',
#  'Fuel Pump Mounting Plate',
#  'Fuel Pump O-Ring',
#  'Fuel Pump Plate Gasket',
#  'Fuel Pump Resistor',
#  'Fuel Pump Strainer',
#  'Fuel Rail O-Ring Kit',
#  'Fuel Shut-Off Solenoid',
#  'Fuel Tank Selector Valve',
#  'Fuel Tank Vent Valve',
#  'Fuel Vapor Canister',
#  'Fuel Vapor Canister Filter',
#  'Fuel Vapor Canister Seal',
#  'Fuel Vapor Leak Detection Pump',
#  'Fuel Vapor Leak Detection Pump Filter',
#  'Fuse Block',
#  'Fuse Holder',
#  'Generator Brush Spring',
#  'Glove Compartment Lock',
#  'Glow Plug Conductor',
#  'Glow Plug Controller',
#  'Hazard Flasher',
#  'Headlamp Wiring Harness',
#  'Headlight Adjusting Motor',
#  'Headlight Switch Knob',
#  'Headlight Wiring Harness',
#  'Heater Control Valve',
#  'HID Headlight Ballast',
#  'HID Headlight Igniter',
#  'HID Side Marker Ballast',
#  'Hood Latch Assembly',
#  'Horizontal Fuel Conditioning Module',
#  'Horizontal Fuel Conditioning Module Cover Gasket Kit',
#  'Horn',
#  'HVAC Air Inlet Door Actuator',
#  ...]

# %%
len(list_type) == 0
# Out:
# False

# %%
import pandas as pd

output = pd.DataFrame({'No': [_+1 for _ in range(len(list_type))],
                       'Type Code': list_type_code})

output.to_excel('./file/input.xlsx', index=False)

output
# Out:
#         No  Type Code
# 0        1     359500
# 1        2     349200
# 2        3     344300
# 3        4     344600
# 4        5     321800
# ...    ...        ...
# 1569  1570     325900
# 1570  1571     329600
# 1571  1572     302700
# 1572  1573     307500
# 1573  1574     326000
#
# [1574 rows x 2 columns]
