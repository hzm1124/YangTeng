# %% [markdown]
# - Update: 2023.02.04
#
# # 0. 配置参数
#
# - `calculate`：what the fuck

# %%
calculate = '../../file/计算表-【每日断货汇报】US-Ebay 20230203.xlsx'

out = '../../file/Lennon_断货汇报_筛选好的断货SKU_NOW().xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate, sheet_name='附_1统计源（含新品、清仓、新品成长）', header=3, usecols=[i for i in range(1, 13)])

df
# Out:
#          No.            MRP SKU  目标\n周销   品类  Level      状态变更日  状态 运营备注  \
# 0          1         USGS06060Z    31.7   GS  TOP10 2021-06-27  老品   暴涨
# 1          2  USTCV17215HIE-2-C    20.6  TCV  TOP10 2021-07-19  老品  NaN
# 2          3       USTBC40007-C    30.3  TBC   TOP1 2022-03-28  老品  NaN
# 3          4         USGS41420B     7.6   GS  TOP10 2022-06-06  老品   暴涨
# 4          5         USGSM3570T    19.8   GS  TOP10 2022-03-14  老品   暴涨
# ...      ...                ...     ...  ...    ...        ...  ..  ...
# 49913  49914    USFM0FD006B0-YC     1.0   FM     普通 2022-11-28  新品  NaN
# 49914  49915         USASV98007     1.0  ASV  TOP20 2022-11-28  新品  NaN
# 49915  49916         USASC3B484     1.0  ASC  TOP10 2023-01-09  新品  NaN
# 49916  49917         USCAK53670     4.0   CA     普通 2022-11-28  新品  NaN
# 49917  49918         USCAK03420     1.0   CA     普通 2022-11-28  新品  NaN
#
#        未售出周数  注意事项   在库   在途
# 0          0   NaN  296    0
# 1          0   NaN   85  158
# 2          0   NaN  525   85
# 3          0   NaN   56  212
# 4          0  更新周销  118  220
# ...      ...   ...  ...  ...
# 49913      0   NaN    0   10
# 49914      0   NaN    0   12
# 49915      0   NaN    8    7
# 49916      0   NaN   10   46
# 49917      0   NaN    0   12
#
# [49918 rows x 12 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU', 'Level', '目标\n周销', '在途']]

df
# Out:
#              MRP SKU  Level  目标\n周销  在途
# 64        USMAF10023  TOP20    1.20   0
# 160        USWO09401  TOP20    1.70   0
# 235    USALT82470B-C  TOP10    6.90   0
# 382       USBMC90292  TOP20    0.50   0
# 591       USRBM16507   TOP1    3.70   0
# ...              ...    ...     ...  ..
# 43358     USBMC30276  TOP20    2.00   0
# 43624     USPSR21146  TOP10    1.50   0
# 43633     USPSR21145  TOP20    0.40   0
# 44042     USPSR61677  TOP20    0.75   0
# 44467     USPSR62039  TOP20    2.00   0
#
# [272 rows x 4 columns]

# %%
import datetime

writer = pd.ExcelWriter(out.replace('NOW()', datetime.datetime.now().strftime("%Y%m%d_%H%M%S")))
df.to_excel(writer, index=False)
writer.close()
