# %%
param_date = '20240623'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel(f'./{param_date}/part.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_ = input_.drop_duplicates(['JOIN_PTPKPNCN'], keep='first', ignore_index=True)

print(f'总数量：{len(input_)}')
input_['Info'].tolist()
# Out:
# 总数量：24720
# ['https://www.rockauto.com/en/moreinfo.php?pk=10671829&cc=0&pt=131',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15108561&cc=0&pt=131',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15108557&cc=0&pt=131',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15108565&cc=0&pt=131',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15104205&cc=0&pt=1002098',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15104209&cc=0&pt=1002098',
#  'https://www.rockauto.com/en/moreinfo.php?pk=9097025&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=10512261&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14919165&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15138777&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15138781&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15138773&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15521065&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14922125&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=14922129&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15001073&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15138765&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15138769&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=15521069&cc=0&pt=256',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1285405&cc=0&pt=260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=368849&cc=0&pt=260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=368850&cc=0&pt=260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=368851&cc=0&pt=260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=368852&cc=0&pt=260',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2961354&cc=0&pt=1001191',
#  'https://www.rockauto.com/en/moreinfo.php?pk=1272469&cc=0&pt=1000000',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2867484&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3472857&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2867487&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=2867490&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=3603579&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4170858&cc=0&pt=1001187',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101270&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101271&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12873537&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12872429&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12873177&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12873173&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4970703&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12873529&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4970697&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=12873161&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101322&cc=0&pt=1001344',
#  'https://www.rockauto.com/en/moreinfo.php?pk=4784736&cc=0&pt=1001356',
#  'https://www.rockauto.com/en/moreinfo.php?pk=
cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420235&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420238&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672533&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420241&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672534&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420250&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420259&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101975&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101976&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101977&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101978&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101979&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101980&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101981&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101982&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101983&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420532&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101984&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420541&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672298&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102067&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102068&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295822&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102069&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102070&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295823&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295824&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295825&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295826&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419848&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418966&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418975&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672506&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420172&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420190&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420178&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420181&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672505&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672508&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672511&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672512&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672513&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672514&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420184&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420187&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420175&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420193&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420199&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420196&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101959&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101956&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101957&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101955&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101958&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101960&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101961&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420463&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101962&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101963&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101964&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420472&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672510&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420481&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420487&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420490&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295819&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102050&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418918&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102051&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295820&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102052&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102054&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102053&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102055&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102057&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102056&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418915&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418930&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420142&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420433&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420445&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672495&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295817&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420451&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672499&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672498&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420145&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420148&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420157&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420151&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420154&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101946&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101945&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420160&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420163&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101949&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101948&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101947&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420166&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101951&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101950&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101952&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420442&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101953&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101954&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420448&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420454&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420460&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672276&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102044&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295816&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102045&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102046&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102047&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295818&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102049&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102048&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418906&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418909&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672517&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101965&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101972&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420223&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420229&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672289&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420496&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102059&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672515&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672518&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672519&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672521&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420202&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420205&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420211&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420208&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420214&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420217&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101967&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420220&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101969&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101966&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101968&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101974&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101970&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101971&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420499&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101973&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420508&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420511&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420514&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295821&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102060&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102058&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102062&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102061&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102064&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102063&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102066&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418954&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419842&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418948&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5418957&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=295810&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102027&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101891&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420322&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101903&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419938&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420613&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101911&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672441&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420325&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101906&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672444&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5420328&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419887&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419890&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672439&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419902&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=102005&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419908&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419917&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101915&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=672455&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419926&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419929&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=5419932&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101889&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101892&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101890&cc=0&pt=1000582',
#  'https://www.rockauto.com/en/moreinfo.php?pk=101894&cc=0&pt=1000582',
#  ...]

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../../00.Tools')
import UA
import Proxy

# %%
a = 0

resp = requests.get(input_.loc[a, 'Info'],
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '<!DOCTYPE HTML>\n<html class="no-js REPLACEHTMLCLASS" onclick="" lang="en">\n<head>\n<meta name="robots" content="all">\n<meta http-equiv="Content-Security-Policy" content="script-src \'self\' \'unsafe-inline\' \'unsafe-eval\' *.rockauto.com; base-uri \'self\' *.rockauto.com; ">\n<link rel="stylesheet" type="text/css" href="/jslib/combined/css/desktopmoreinfo.css?1719213858">\n\n<script>\nif(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};\n_getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=\n0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};\n\n</script>\n\n<script src="/jslib/combined/js/desktopcatalogmain.js?1719213858"></script>\n\n<script src="/catalog/moreinfo-min.js?1719213858"></script>\n\n<link rel="stylesheet" type="text/css" href="/catalog/moreinfo-min.css?1719213858">\n<title>More Information for ROCKAUTO BLACKHAT</title>\n<link rel="canonical" href="https://www.rockauto.com/en/moreinfo.php?pk=10671829"/>\n<link rel="alternate" href="https://www.rockauto.com/en/moreinfo.php?pk=10671829" hreflang="en" />\n<link rel="alternate" href="https://www.rockauto.com/es/moreinfo.php?pk=10671829" hreflang="es" />\n<link rel="alternate" href="https://www.rockauto.com/de/moreinfo.php?pk=10671829" hreflang="de" />\n<link rel="alternate" href="https://www.rockauto.com/fr/moreinfo.php?pk=10671829" hreflang="fr" />\n</head>\n<body onLoad="ResizePiclookup();" class="mi-body">\n<div id="mi_everything">\n<div>\n<div style="float:left; margin-right:1em;"><a href="http://www.rockauto.com" target="_blank"><img style="max-height:100px;" src="/Images/logoNoLine.png" alt="ROCKAUTO" border="0"></a></div>\n<div style="float:left;"></div>\n<div style="float:right;">\n<table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">\n<tr>\n<td style="text-align: center">\n<a href="/" onclick="AddSerializedCookieDataToHref(this);"><img src="/Images/logoNoLine.png" class="ralogo" border="0" alt="Go to RockAuto Home Page"></a>\n</td>\n</tr>\n</table>\n</div>\n<div style="font-size:.9em;"></div>\n<div style="clear:both;"></div>\n</div>\n<div class="bdytext hide-for-inline-mobile">\n<div style="float: left; padding-right: 20px;">\n<div style="padding-bottom:.4em;">More Information for ROCKAUTO BLACKHAT</div>\n<div style="padding-bottom:.4em;"></div>\n<input type="button" id="mi_continue_shopping_btn" class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" style="padding-top: 5px; padding-bottom: 5px; background-position: left center;" onclick="if(HasOpener()) window.close(); else window.location=\'/?mfr=ROCKAUTO&partnum=BLACKHAT\';" value = "Continue Shopping" title ...

# %%
from bs4 import BeautifulSoup
from lxml import etree

# %%
soup = BeautifulSoup(resp, 'lxml')
html = etree.HTML(str(soup))

with open('./info.html', 'w', encoding='UTF-8') as file:
    file.write(str(soup))

print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="no-js REPLACEHTMLCLASS" lang="en" onclick="">
#  <head>
#   <meta content="all" name="robots"/>
#   <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' *.rockauto.com; base-uri 'self' *.rockauto.com; " http-equiv="Content-Security-Policy"/>
#   <link href="/jslib/combined/css/desktopmoreinfo.css?1719213858" rel="stylesheet" type="text/css"/>
#   <script>
#    if(!window.RABoot){var no_js="no-js",has_js="has-js",c=document.documentElement.className.replace(no_js,has_js);-1==c.indexOf(has_js)&&(c+=" "+has_js);document.documentElement.className=c;RABoot=function(){var f=function(){};f.prototype={};f.WaitFor=function(a,b){if(_isset(b)&&"function"===typeof b){_isarray(a)||(a=[a]);var d={s:a,w:b,a:{}};CheckReady(d)?d.w():Waiting.push(d)}};_isset=function(a){return"undefined"!=typeof a&&null!=a};_isin=function(a,b){return a in b};_isarray=function(a){return Array.isArray(a)};
# _getref=function(a){var b=null;a=a.split(".");if(0<a.length){"window"==a[0]&&a.shift();for(var d=window,e=0;e<a.length;++e)if(_isin(a[e],d)&&_isset(d[a[e]]))d=b=d[a[e]];else{b=null;break}}return b};Waiting=[];CheckReady=function(a){for(var b=0,d=0;d<a.s.length;++d){var e=a.s[d],f=null;_isarray(a.s[d])&&(e=a.s[d][0],f=a.s[d][1]);if(!_isin(e,a.a)){var g=_getref(e);!_isset(g)||_isset(f)&&g!=f||(a.a[e]=!0)}if(_isin(e,a.a))++b;else break}return b==a.s.length};Poller={PollFunc:function(){for(var a=[],b=
# 0;b<Waiting.length;++b){var d=Waiting[b];CheckReady(d)&&(a.push(b),d.w())}for(b=a.length;0<b--;)Waiting.splice(a[b],1)},NextInterval:10,Elapsed:0,pSetInterval:null,Tick:function(){this.Elapsed+=this.NextInterval;1E3<this.Elapsed&&10==this.NextInterval&&(this.NextInterval=50,this.Restart())},Restart:function(){_isset(this.pSetInterval)&&clearInterval(this.pSetInterval);var a=this;this.pSetInterval=setInterval(function(){a.Tick();a.PollFunc()},this.NextInterval)}};Poller.Restart();return f}()};
#   </script>
#   <script src="/jslib/combined/js/desktopcatalogmain.js?1719213858">
#   </script>
#   <script src="/catalog/moreinfo-min.js?1719213858">
#   </script>
#   <link href="/catalog/moreinfo-min.css?1719213858" rel="stylesheet" type="text/css"/>
#   <title>
#    More Information for ROCKAUTO BLACKHAT
#   </title>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=10671829" rel="canonical"/>
#   <link href="https://www.rockauto.com/en/moreinfo.php?pk=10671829" hreflang="en" rel="alternate"/>
#   <link href="https://www.rockauto.com/es/moreinfo.php?pk=10671829" hreflang="es" rel="alternate"/>
#   <link href="https://www.rockauto.com/de/moreinfo.php?pk=10671829" hreflang="de" rel="alternate"/>
#   <link href="https://www.rockauto.com/fr/moreinfo.php?pk=10671829" hreflang="fr" rel="alternate"/>
#  </head>
#  <body class="mi-body" onload="ResizePiclookup();">
#   <div id="mi_everything">
#    <div>
#     <div style="float:left; margin-right:1em;">
#      <a href="http://www.rockauto.com" target="_blank">
#       <img alt="ROCKAUTO" border="0" src="/Images/logoNoLine.png" style="max-height:100px;"/>
#      </a>
#     </div>
#     <div style="float:left;">
#     </div>
#     <div style="float:right;">
#      <table border="0" cellpadding="0" cellspacing="0" class="hide-for-inline-mobile">
#       <tr>
#        <td style="text-align: center">
#         <a href="/" onclick="AddSerializedCookieDataToHref(this);">
#          <img alt="Go to RockAuto Home Page" border="0" class="ralogo" src="/Images/logoNoLine.png"/>
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div style="font-size:.9em;">
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <div class="bdytext hide-for-inline-mobile">
#     <div style="float: left; padding-right: 20px;">
#      <div style="padding-bottom:.4em;">
#       More Information for ROCKAUTO BLACKHAT
#      </div>
#      <div style="padding-bottom:.4em;">
#      </div>
#      <input class="hide-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal ra-btn-left-arrow" id="mi_continue_shopping_btn" onclick="if(HasOpener()) window.close(); else window.location='/?mfr=ROCKAUTO&amp;partnum=BLACKHAT';" style="padding-top: 5px; padding-bottom: 5px; background-position: left center;" title="Back to the RockAuto Catalog" type="button" value="Continue Shopping"/>
#      <div class="show-if-js ra-btn ra-btn-color-darkblue ra-btn-size-normal" onclick="RA.Click('mi_continue_shopping_btn')" style="display: inline-block; font-size: 13px;">
#       <img alt="" class="la-btn-v" src="/Images/mobile/left_arrow_white.png" style="height: 1em; margin-right: .25em;"/>
#       <span class="la-btn-v">
#        Continue Shopping
#       </span>
#      </div>
#     </div>
#     <div class="buybox show-if-js" style="float: right;">
#      <section aria-label="Add to Cart">
#       <table border="0" cellpadding="0" cellspacing="0" id="frmlistings[1]">
#        <tbody class="listing-inner" id="mibuybox">
#         <tr>
#          <td class="buybox-inner-content">
#           <span style="float: right;">
#           </span>
#           <div>
#           </div>
#           <div class="listing-text-row-moreinfo-truck">
#            <b>
#             <span class="listing-final-manufacturer">
#              ROCKAUTO
#             </span>
#            </b>
#            <span alt="Buyer's Guide" class="listing-final-partnumber as-link-if-js" id="vew_partnumber[1]" onclick='if (cataloglite.IsMobileAndNotExpanded("1")) { return; } cataloglite.ShowBuyersGuidePopup("1");' title="Buyer's Guide">
#             BLACKHAT
#            </span>
#            <span class="truck ra-hide remove-for-print mouseover" name="vew_whtruckicon[1][0-0-0-1]" onclick="FAQpopup('/help/?page=2#MINSHIPCOST', &quot;Could ship from same location as parts in cart&quot;, null, this); RA.StopBubble(event); return false;" title="Could ship from same location as parts in cart">
#            </span>
#           </div>
#           <div class="listing-text-row buybox-rebate">
#           </div>
#           <div>
#           </div>
#          </td>
#          <td class="buybox-inner-content">
#           <div class="listing-quantity-adjustment ib remove-for-print show-if-js" id="frmlistings[1]">
#            <input autocomplete="off" id="listingoptkeytomultiple[1]" type="hidden" value='{"0-0-0-1":"1"}'/>
#            <input autocomplete="off" id="listingoptkeytolinenumber[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoqtyincart[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <input autocomplete="off" id="listingoptkeytoalternateid[1]" type="hidden" value='{"0-0-0-1":null}'/>
#            <table class="tblz di tbl-input-button-attached" id="listingquantitytable[1]">
#             <tr>
#              <td class="td-button-left" style="text-align: right;">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", -1);' style="border-top-left-radius: 4px; border-bottom-left-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_down_white.png"/>
#               </div>
#              </td>
#              <td class="td-input">
#               <label for="raquantity[1]" style="display:none;">
#                Quantity
#               </label>
#               <input aria-label="Quantity" autocapitalize="off" autocomplete="off" autocorrect="off" class="input-quantity ib" data-autofill="block" id="raquantity[1]" maxlength="5" name="raquantity[1]" onchange='cataloglite.ListingQuantityUpdate("1");' onkeypress='return RA.InterceptEnter(event, function(){RA.ByName("raquantity[1]")[0].blur()});' spellcheck="false" style="text-align: center; width: 2em; padding-left: 0;" type="text" value="1"/>
#              </td>
#              <td class="td-button-right">
#               <div class="qty-adjust-button" onclick='cataloglite.ListingQuantityUpdate("1", 1);' style="border-top-right-radius: 4px; border-bottom-right-radius: 4px;">
#                <img alt="" class="nobmp vmiddle" src="/Images/mobile/qty_up_white.png"/>
#               </div>
#              </td>
#             </tr>
#            </table>
#            <input autocomplete="off" id="optionchoice[1]" name="optionchoice[1]" type="hidden" value="0-0-0-1"/>
#            <input autocomplete="off" id="listing_data_essential[1]" name="listing_data_essential[1]" type="hidden" value='{"groupindex":"1","carcode":0,"parttype":"131","partkey":"10671829","opts":{"0-0-0-1":{"warehouse":"53719","whpartnum":"BLACKHAT","optionlist":"0","paramcode":"0","notekey":"0","multiple":"1"}}}'/>
#            <input autocomplete="off" id="listing_data_supplemental[1]" type="hidden" value='{"partnumber":"BLACKHAT","catalogname":"ROCKAUTO","belongstolisting":"1","sortgroup":null,"sortgrouptext":null,"paramdesc":""}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][]" type="hidden" value="false"/>
#            <input autocomplete="off" id="lst_shipwhlist[1][0-0-0-1]" type="hidden" value='{"53719":53719}'/>
#            <input autocomplete="off" id="mdl_whtruckicon[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnaddtocart[1][0-0-0-1]" type="hidden" value="true"/>
#            <input autocomplete="off" id="mdl_btnpartincart[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_btnnotifyoos[1][0-0-0-1]" type="hidden" value="false"/>
#            <input autocomplete="off" id="mdl_chkalternate[1][0-0-0-1]" type="hidden" value="true"/>
#            <input autocomplete="off" name="ssk[1]" type="hidden" value="HPc6NY4sqMvPDBCrBav8qclKvfUZ+ribG7fNynIZ1dwYUSXiprLpxa+UqutArhnitDvQSY+NS/s="/>
#           </div>
#          </td>
#          <td class="listing-float-box-cell-shared listing-float-box-cell-more-padding" colspan="4" id="listingtd[1][price]" style="height: 1px; text-align: center;">
#           <span class="" id="dprice[1][td]">
#            <span class="ra-formatted-amount listing-price listing-amount-bold">
#             <span id="dprice[1][v]">
#              $5.50
#             </span>
#            </span>
#           </span>
#           <div class="none" style="font-size:.8em;">
#            Price
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][core]" style="height: 1px; text-align: center;">
#           <span class="" id="dcore[1][td]">
#            <span class="ra-formatted-amount listing-core">
#             <a class="" href="/help/?page=2#CORE" id="dcore[1][color]" onclick="return FAQpopup(this);" style="text-decoration: none;" target="_blank">
#              <span id="dcore[1][v]">
#               $0.00
#              </span>
#             </a>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Core
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][pack]" style="height: 1px; text-align: center;">
#           <span id="dpack[1][v]">
#            <span class="hide-if-js">
#             + Sold in packs of 1
#            </span>
#            <span class="show-if-js">
#             <span class="pack_size_box no-text-select" onclick="showContextPopup(' ', &quot;Sold in packs of 1&quot;, this); RA.StopBubble(event); return false;" title="Sold in packs of 1">
#              <span class="right">
#               <span class="left">
#                <span class="text">
#                 <span class="text-x-small">
#                  x
#                 </span>
#                 1
#                </span>
#               </span>
#              </span>
#             </span>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Pack
#           </div>
#          </td>
#          <td class="ra-hide listing-float-box-cell-shared listing-float-box-cell-more-padding" id="listingtd[1][total]" style="height: 1px; text-align: center;">
#           <span class="listing-amount-bold" id="dtotal[1][td]">
#            <span class="ra-formatted-amount listing-total">
#             <span id="dtotal[1][v]">
#              $5.50
#             </span>
#            </span>
#           </span>
#           <div style="font-size:.8em;">
#            Total
#           </div>
#          </td>
#          <td class="buybox-inner-content" style="white-space:nowrap; padding-right:.5em;">
#           <div class="catalog-listing-buttons-wrapper ib" style="min-width:105px;">
#            <div class="vew_btnaddtocart remove-for-print" id="vew_btnaddtocart[1]">
#             <input class="hide-if-js ra-btn ra-btn-size-normal ra-btn-color-hotgreen" id="addpart[1]" name="addpart[1]" onclick="showLoading(); RA.SubscribeOnce('cartevent', 'callback_complete', function () { AddPartToCart_cb(); }); cataloglite.Cart.AddPartToCart(&quot;1&quot;); return false;" type="submit" value="Add to Cart &gt;"/>
#             <a class="show-if-js ra-btn ra-btn-color-hotgreen ra-btn-size-normal ra-btn-add-part" href="#" onclick="RA.Click('addpart[1]'); return false;" style="display: inline-block;">
#              <span class="la-btn-v">
#               Add to Cart
#              </span>
#              <img alt="" class="la-btn-v" src="/Images/mobile/right_arrow_white.png" style="height: 1em; margin-left: .25em;"/>
#             </a>
#            </div>
#            <div class="vew_btnpartincart remove-for-print ra-hide" id="vew_btnpartincart[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-part-in-cart" name="addpart[1]" onclick="cataloglite.Cart.ShowPartAlreadyInCart(1); return false;" type="submit" value="Part In Cart"/>
#            </div>
#            <div class="vew_btnnotifyoos remove-for-print ra-hide show-if-js" id="vew_btnnotifyoos[1]">
#             <input class="ra-btn ra-btn-size-normal ra-btn-color-darkblue" onclick='cataloglite.GetAvailabilityAlertForOOSPart("1");' type="button" value="Notify Me When Available"/>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#           <div class="listing-text-row">
#           </div>
#           <div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="6">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </section>
#     </div>
#     <div style="clear:both;">
#     </div>
#    </div>
#    <table class="bdytext" style="width: 100%; border: none;">
#     <tr>
#      <td style="width: 525px; " valign="top">
#       <div style="">
#        <table cellpadding="8" cellspacing="0" style="border: 1px solid #dcdcdc;">
#         <tr align="center">
#          <td colspan="3" style="width: 500px;">
#           <section aria-label="Image of part">
#            <img alt="Zoom Lens" id="zoomlens" onmousemove="MouseMoveZoom(null, event);" onmouseout="MouseOutOfLens(null, event);" onmouseover="MouseOverLens(null, event);" src="/catalog/images/transpurple100.png" style="position: absolute: width: 100px; height: 100px; display: none; border: 1px solid white; z-index: 10;"/>
#            <div class="">
#             <table class="tblz listing-image-table" id="listing_image_table[1]" style=" width: 100%;">
#              <tr>
#               <td class="listing-image-table-centercol">
#                <div class="" id="inlineimgpositionancestor[1]" style=" position: relative; z-index: 1; width: 100%;">
#                 <div class="listing-inlineimg_container" id="inlineimg_container[1]" style="z-index: 1; text-align: center; background: #FFFFFF; width: 100%;">
#                  <div class="listing-inline-image-popup-widget-title ra-hide" id="inlineimg_containertitle[1]" onmousedown='cataloglite.ImagePopupTitleMouseDown("1")'>
#                   <div style="text-align: center; ">
#                    <span style="padding: 0 2em 0 2em;">
#                     ROCKAUTO BLACKHAT
#                    </span>
#                    <span style="position: absolute; right: 5px;">
#                     <img alt="close" onclick='cataloglite.Listing_InlineImagePopupInPlace("1")' src="/catalog/images/close12_1.gif" style="padding: .2em; cursor: pointer; display: block;"/>
#                    </span>
#                   </div>
#                  </div>
#                  <div class="img-topper-container" id="inlineimg_topper[1]">
#                   <table class="tblz w100">
#                    <tr>
#                     <td class="pinched" style="vertical-align: top;">
#                      <div style="text-align: left; padding-right: .25em;">
#                       <span id="inlineimg_left_big[1]">
#                        <img alt="&lt;" class="listing-image-prevnext-image-moreinfo remove-for-print show-if-js" id="inlineimgprevious[1]" onclick='cataloglite.Listing_InlineImageManualScroll("1", -1, false, false)' src="/catalog/images/prevIMGbig.png" style=" margin: .1em;" title="Previous Image"/>
#                       </span>
#                      </div>
#                      <div class="listing-image-counter">
#                       <div class="inner" id="imagecounterdisplay[1]">
#                       </div>
#                      </div>
#                     </td>
#                     <td style="vertical-align: top;">
#                      <div id="pointtozoom" style="text-align:center; font-size: 11px; color: blue; white-space: nowrap; visibility: hidden;">
#                       Point to Zoom
#                      </div>
#                      <div class="img-carousel-titlephrase" id="imgcarouseltitlephrase[1]">
#                      </div>
#                      <div class="ra-hide" id="inlineimg_container360menu[1]" onmouseout='cataloglite.Listing_360ImageStartAutomatic("1");' onmouseover='cataloglite.Listing_360ImagesStopAutomatic("1");' style="padding: .25em; margin-bottom: .5em;">
#                       <div class="ra-bar-slider-bar-c">
#                        <div class="ra-bar-slider-bar" id="inlineimg_sliderbar[1]" onmousedown='cataloglite.ImageSliderMouseDown("1", event);' ontouchstart='cataloglite.ImageSliderMouseDown("1", event);'>
#                         <span class="ra-bar-slider-slider" id="inlineimg_slider[1]">
#                         </span>
#                        </div>
#                       </div>
#                      </div>
#                     </td>
#                     <td class="pinched" style="vertical-align: top; text-align: right;">
#                      <div style="padding-left: .25em;">
#                       <span id="inlineimg_right_big[1]">
#                        <img alt="&gt;" class="listing-image-prevnext-image-moreinfo show-if-js remove-for-print" id="inlineimgnext[1]" name="inlnimgnextbtn" onclick='cataloglite.Listing_InlineImageManualScroll("1", 1, false, false)' src="/catalog/images/nextIMGbig.png" style=" margin: .1em;" title="Next Image"/>
#                       </span>
#                      </div>
#                     </td>
#                    </tr>
#                   </table>
#                  </div>
#                  <div class="inlineimg_containersizer" id="inlineimg_containersizer[1]" style="">
#                   <img alt="Part image" class="listing-inline-image listing-inline-image-moreinfo" id="inlineimg[1]" onmousemove='ShowZoomLens("1", event); MouseMoveZoom("1", event);' onmouseout='MouseOutOfImage("1", event);' onmouseover='MouseOverImage("1", event);' src="/info/999/blackHat_19_FR.jpg"/>
#                  </div>
#                 </div>
#                </div>
#               </td>
#              </tr>
#             </table>
#             <input autocomplete="off" id="jsninlineimg[1]" type="hidden" value='{"Size":"Popup","SlotIndex":0,"Slots":[{"Type":"Single","ImageData":{"Thumb":"\/info\/999\/blackHat_19_FR__ra_m.jpg","Popup":"\/info\/999\/blackHat_19_FR.jpg","Full":"\/info\/999\/blackHat_19_FR.jpg"},"TitlePhrase":null,"ParamCodes":["0"]},{"Type":"Single","ImageData":{"Thumb":"\/info\/999\/blackHat_19_BK__ra_m.jpg","Popup":"\/info\/999\/blackHat_19_BK.jpg","Full":"\/info\/999\/blackHat_19_BK.jpg"},"TitlePhrase":null,"ParamCodes":["0"]}],"IsMoreInfoPageImageBox":1}'/>
#            </div>
#            <script>
#             last_group_index = "1";
#            </script>
#            <script>
#             setInterval(function () {if (!document.getElementById("pointtozoom")) { return; } document.getElementById("pointtozoom").style.visibility = (IsCurrentImageZoomable(null) ? "visible" : "hidden");}, 250);
#            </script>
#            <script>
#             setTimeout(function () {if (!document.getElementById("pointtozoom")) { return; } cataloglite.Listing_InlineImageManualScroll("1", 0);}, 250);
#            </script>
#           </section>
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#        <table class="disclaimer" width="100%">
#         <tr>
#          <td valign="top">
#          </td>
#         </tr>
#        </table>
#       </div>
#       <div>
#       </div>
#      </td>
#      <td valign="top">
#       <div style="position: absolute; background: white; z-index:1;">
#        <img alt="" id="zoomedimage" onmousedown="HideZoomLens(event);" src="/catalog/images/clear100.png" style="display: none; border: 1px solid #777777;"/>
#       </div>
#      </td>
#      <td valign="top">
#       <table border="0" cellspacing="5" class="bdydesc">
#        <tr>
#         <td>
#          <section aria-label="Part Description">
#           RockAuto "ALL THE PARTS YOUR CAR WILL EVER NEED" Embroidered Hat
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#        <tr>
#         <td>
#          <section aria-label="More Information for ROCKAUTO BLACKHAT">
#           <p>
#            Wear your RockAuto pride with a RockAuto Hat!
#           </p>
#           <ul>
#            <li>
#             Unstructured fit, mid profile, unwashed, chino cotton
#            </li>
#            <li>
#             Black hat with silver stitching detail
#            </li>
#            <li>
#             Adjustable velcro closure
#            </li>
#            <li>
#             Embroidered RockAuto logo
#            </li>
#           </ul>
#           <div class="mil-spacer">
#           </div>
#          </section>
#         </td>
#        </tr>
#       </table>
#       <table border="0" cellspacing="5" class="bdytext">
#       </table>
#       <table border="0" cellspacing="5" class="warranty">
#       </table>
#       <p class="bdytext hide-for-inline-mobile">
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <script>
#    /**UQ:946D8191**/
# PK_ADDINGPARTTOCART = "Adding Part to Cart";
# PK_ADDTOLIST = "Add to My List";
# PK_ADJUSTQUANTITY = "Adjust Quantity";
# PK_BIGGER = "Bigger";
# PK_CALCTAXTOTAL = "Calculating Tax & Total";
# PK_CALCULATESHIPPING = "Calculate Shipping";
# PK_CANCEL = "Cancel";
# PK_CARTNAME = "Cart Name";
# PK_CARTNOTIFICATION = "Notification";
# PK_CONFIRMCLEARCART = "Are you sure you want to clear this cart?";
# PK_ENTERNEWQUANTITY = "Enter a new quantity:";
# PK_GETTINGSHIPQUOTES = "Calculating Shipping Cost";
# PK_HELP = "Help";
# PK_IMAGEDOESNOTREPRESENT = "Image does not represent KEY__PARAMDESC selected in catalog";
# PK_INVALIDID = "Invalid ID. Please be sure you have entered a valid Email Address.";
# PK_LOADINGPAYPAL = "<h3>Connecting to PayPal<\/h3>If you continue to see this message after a short period of time, please close this window to return to the RockAuto website.";
# PK_LOADINGPLAIN = "Loading";
# PK_LOOKINGUPADDRESS = "Looking up Address";
# PK_MULTIPLEMATCHESPLZREFINE = "Multiple matches found. Please refine search.";
# PK_MYADDRESSES = "My Addresses";
# PK_NO = "No";
# PK_NOMATCHESFOUND = "No Matches Found";
# PK_NOPARTSFNDINMARKET = "No Parts Found for Selected Market(s)";
# PK_NUM_LISTINGS_HIDDEN = "Reset (KEY__NUM listings hidden) <img src=\"\/catalog\/images\/whiteX.png\" style=\"height:.9em;\" alt=\"\">";
# PK_OK = "OK";
# PK_PART = "Part";
# PK_PARTALREADYINCART = "This part is already in the cart. Please update the quantity in the cart to reflect the quantity you want.";
# PK_PLEASEENTERPASSWORD = "Please enter your password";
# PK_REMOVE = "Remove";
# PK_RENAMECART = "Rename Cart";
# PK_SMALLER = "Smaller";
# PK_THISVEHICLEISSAVEDTOLIST = "This vehicle is saved to your list.";
# PK_UPDATINGADDRESS = "Updating Address Information";
# PK_UPDATINGCART = "Updating Cart";
# PK_XLISTINGREMOVE = "KEY__NUM listing removed";
# PK_XLISTINGSREMOVE = "KEY__NUM listings removed";
# PK_YES = "Yes";
# window.top.parent.window["_nck"] = "8LVLUxTaILBT+tLxkg8+3Ag7\/0bbOhvn7P3rkFbL80\/4ONrpMMyyMoTAzqUtg75DXjLFbtL0RWwG2TIS5g0HjN+BEpbJggwRicfW87qYxCroJDOCFdvb3koFH0TxTw3xVSCSrP49mW3f7kdneFExc+ngGJOPgWYnDWZuQfAAXi6k6xERSKw0NPe7QWdlr0zJ";
#   </script>
#  </body>
# </html>

# %%
html.xpath('//span[@class="la-btn-v"]/text()')[0].strip() != 'Continue Shopping'
# Out:
# False

# %%
list_tr = html.xpath('//table[@class="moreinfotable"]/tr')

list_tr
# Out:
# []

# %%
import json

# %%
dict_specification = {}
for i in range(len(list_tr)):
    if i == 0:
        continue

    list_td = [td.strip() for td in list_tr[i].xpath('./td/text()')]
    if len(list_td) == 1:
        dict_specification[str(i-1)] = list_td[0].strip()
    elif len(list_td) == 2:
        dict_specification[str(i-1)] = {list_td[0].strip(): list_td[1].strip()}
    else:
        pass

json_specification = json.dumps(dict_specification)

json_specification
# Out:
# '{}'

# %%
list_tr = html.xpath('//section[contains(@aria-label, "Components") and contains(@aria-label, "kit")]/table/tbody/tr/td/table/tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-b-1") or (contains(@class, "altrow-b-0")))]/tr')

list_tr
# Out:
# []

# %%
dict_kit = {}
for i in range(len(list_tr)):
    dict_kit[str(i)] = {}

    list_td = list_tr[i].xpath('./td')
    dict_kit[str(i)]['quantity'] = list_td[0].xpath('./text()')[0].strip()
    dict_kit[str(i)]['component_tag'] = list_td[1].xpath('./text()')[0].strip()

    json_ = json.loads(list_td[2].xpath('./@value')[0])
    dict_kit[str(i)]['parttype'] = json_['parttype'].strip()
    dict_kit[str(i)]['partkey'] = json_['partkey'].strip()

    json_ = json.loads(list_tr[i].xpath('./input[contains(@id, "listing_data_supplemental[")]/@value')[0])
    dict_kit[str(i)]['partnumber'] = json_['partnumber'].strip()
    dict_kit[str(i)]['catalogname'] = json_['catalogname'].strip()

    dict_kit[str(i)]['url'] = f'''https://www.rockauto.com/en/parts/{dict_kit[str(i)]['partkey']},{dict_kit[str(i)]['partnumber']},{dict_kit[str(i)]['component_tag']},{dict_kit[str(i)]['parttype']}'''

    a_ = list_tr[i].xpath('./div[@class="listing-text-row-moreinfo-truck"]/a/@href')
    dict_kit[str(i)]['info'] =  f'''https://www.rockauto.com/en/moreinfo.php?pk={dict_kit[str(i)]['catalogname']}&pt={dict_kit[str(i)]['parttype']}&Lennon=1''' if len(a_) == 0 else a_[0].strip()

    list_src = [] if len(list_td[3].xpath('./div/input/@value')) == 0 else json.loads(list_td[3].xpath('./div/input/@value')[0])['Slots']
    dict_src = {}
    for j in range(len(list_src)):
        dict_src[str(j)] = 'https://www.rockauto.com' + list_src[j]['ImageData']['Full'].strip()
    dict_kit[str(i)]['json_src'] = json.dumps(dict_src)

json_kit = json.dumps(dict_kit)

json_kit
# Out:
# '{}'

# %%
df_temp = pd.DataFrame([{'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                         'Json_Specification': json_specification,
                         'Json_Kit': json_kit,
                         'Info': input_.loc[a, 'Info']}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#                     JOIN_PTPKPNCN Json_Specification Json_Kit  \
# 0  131;10671829;BLACKHAT;ROCKAUTO                 {}       {}
#
#                                                 Info
# 0  https://www.rockauto.com/en/moreinfo.php?pk=10...

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'JOIN_PTPKPNCN': input_.loc[a, 'JOIN_PTPKPNCN'],
                             'Info': input_.loc[a, 'Info']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if len(output_correct) != 0:
    output_correct = output_correct.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_correct.to_excel('./test_info.xlsx', index=False)

output_correct
# Out:
#                     JOIN_PTPKPNCN Json_Specification Json_Kit  \
# 0  131;10671829;BLACKHAT;ROCKAUTO                 {}       {}
#
#                                                 Info
# 0  https://www.rockauto.com/en/moreinfo.php?pk=10...

# %%
if len(output_error) != 0:
    output_error = output_error.sort_values(by=['JOIN_PTPKPNCN'], ascending=[True], ignore_index=True)
    output_error.to_excel('./test_info_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
