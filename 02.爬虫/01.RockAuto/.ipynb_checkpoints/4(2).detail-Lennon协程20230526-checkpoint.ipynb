# %%
site_code= '10634'

# = = = = = = = = = = = = = = = = = =

from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
from urllib.parse import quote
import requests
from bs4 import BeautifulSoup
from lxml import etree
import time

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./part_out.xlsx', header=0)
list_info = df_menu['Info'].to_list()
print('总数量：' + str(len(list_info)))
print()

work = Queue()
for info in list_info:
    work.put_nowait(info)

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['Info',
                           'Src',
                           'OEM Number',
                           'Alternate Inventory Number',
                           'status'])

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818',
           'https': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        info = work.get_nowait()

        status = 'error'
        for _ in range(31):
            try:
                url = 'https://www.rockauto.com/en/moreinfo.php?pk=' + info.split('?')[1].split('pk=')[1].split('&')[0] + '&pt=' + site_code

                # = = = = = = = = = = = = = = = = = =
                
                resp = requests.get(url, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = = = = =

                html = etree.HTML(str(soup))
                
                list_src = html.xpath('//img[@alt="Part image"]/@src')
                if len(list_src) == 0:
                    list_src = ['']
                
                # = = = = = = = = = = = = = = = = = =

                dict_alternate = {'alternate_inventory_number': '', 'oem_number': ''}
                list_alternate = []
                list_number = html.xpath('//section[@aria-label="Alternate/OEM Part Number(s)"]')
                for number in list_number:
                    list_alternate.append(''.join(number.xpath('./descendant-or-self::*/text()')))

                # = = = = = = = = = = = = = = = = = =

                for alternate in list_alternate:
                    if '{Alternate Inventory Numbers: ' in alternate:
                        dict_alternate['alternate_inventory_number'] = alternate.replace('{Alternate Inventory Numbers: ', '').replace('}', '').replace(', ', ';')
                    elif 'OEM / Interchange Numbers: ' in alternate:
                        dict_alternate['oem_number'] = alternate.replace('OEM / Interchange Numbers: ', '').replace(', ', ';')

                # = = = = = = = = = = = = = = = = = =

                status = 'ok'
                df_temp = pd.DataFrame({'Info': info,
                                        'Src': list_src,
                                        'OEM Number': [dict_alternate['oem_number']],
                                        'Alternate Inventory Number': [dict_alternate['alternate_inventory_number']],
                                        'status': ['ok']})

                break

            except:
                time.sleep(3)
                continue

        # = = = = = = = = = = = = = = = = = =
        
        if status == 'error':
            df_temp = pd.DataFrame({'Info': info,
                                    'status': ['error']})
        
        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(info + '  <->  [' + status + '] - 剩余：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(10):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./detail_out.xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：19
#
# https://www.rockauto.com/en/moreinfo.php?pk=3786924  <->  [ok] - 剩余：9
# https://www.rockauto.com/en/moreinfo.php?pk=1352941  <->  [ok] - 剩余：8
# https://www.rockauto.com/en/moreinfo.php?pk=3775332  <->  [ok] - 剩余：7
# https://www.rockauto.com/en/moreinfo.php?pk=40889  <->  [ok] - 剩余：6
# https://www.rockauto.com/en/moreinfo.php?pk=320211  <->  [ok] - 剩余：5
# https://www.rockauto.com/en/moreinfo.php?pk=8148692  <->  [ok] - 剩余：4
# https://www.rockauto.com/en/moreinfo.php?pk=446026  <->  [ok] - 剩余：3
# https://www.rockauto.com/en/moreinfo.php?pk=8768784  <->  [ok] - 剩余：2
# https://www.rockauto.com/en/moreinfo.php?pk=40864  <->  [ok] - 剩余：1
# https://www.rockauto.com/en/moreinfo.php?pk=8607276  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=14052309  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=14640565  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=40903  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=8972352  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=40930  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10087308  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=1001943  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=10208816  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/moreinfo.php?pk=40896  <->  [ok] - 剩余：0
#
# 搞定
