# %%
import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

import time

# = = = = = = = = = = = = = = =

import json

# %%
with open('./api.txt', 'r') as api_txt:
    api = api_txt.read()

api
# Out:
# 'LXnMWcYQhipLAS7rImEzmZ3CkrU033FMha9cwVSngG4vbufTsAOCQQ=='

# %%
list_dict_correct, list_series_error, df_input = [], [], pd.read_excel('./file/1.manufacturer.xlsx',
                                                                       header=0,
                                                                       dtype=str).fillna('')

df_input['No'] = df_input['No'].astype(int)

count_remain = len(df_input)

print(f'总数量：{count_remain}')
print()
df_input
# Out:
# 总数量：6450
#         No                            Name Presentation  \
# 0        5      Arnott Suspension Products      2.1 E30
# 1        6                     深圳锐丽视科技有限公司      5.2 A47
# 2        7                   浙江汉博汽车传感器有限公司      4.1 F52
# 3        8            ABRO Industries, Inc     2.1 H102
# 4        9                  上海正阳桑林企业发展有限公司      5.2 B67
# ...    ...                             ...          ...
# 6445  6450  Automate Genuine Parts Pte Ltd      2.1 G32
# 6446  6451       Wah Seng Industry Sdn Bhd     2.1 B126
# 6447  6452    Cryomax Cooling System Corp.     2.1 B115
# 6448  6453     Pro Unison Electronics Inc.      2.1 A75
# 6449  6454   Taiwan Brake Technology Crop.      2.1 K95
#
#                                                Category  \
# 0                          1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）
# 1     4.1 车间维修及维护设备（系统及装备、起重设备、测量与测试设备、轮胎安装、车间设备、网络软...
# 2     1.1 驾驶系统（发动机、变速箱、动力总成、排气装置）\n1.2 底盘部分（车桥、方向盘、制...
# 3
# 4     9.3 轮胎 / 车轮的维修及处理（橡胶硫化、平衡处理、磨损维修、弹力剂、维修材料、工具、填...
# ...                                                 ...
# 6445  1.1 驾驶系统（发动机、变速箱、动力总成、排气装置）\n1.2 底盘部分（车桥、方向盘、制...
# 6446
# 6447                                  1.7 乘用车和商用车再制造零部件
# 6448  1.1 驾驶系统（发动机、变速箱、动力总成、排气装置）\n1.2 底盘部分（车桥、方向盘、制...
# 6449  1.1 驾驶系统（发动机、变速箱、动力总成、排气装置）\n1.2 底盘部分（车桥、方向盘、制...
#
#                                                Key Word  \
# 0     1. Struts\n2. Air Suspension\n3. Air Springs\n...
# 1     1. Cylinder Inspection\n2. Borescope\n3. Artic...
# 2     1. ABS Wheel Speed Sensor（ABS轮速传感器）\n2. Cranks...
# 3
# 4
# ...                                                 ...
# 6445  1. Lubricants\n2. Motor oil\n3. Parts\n4. Spar...
# 6446             1. ALTERNATOR\n2. STARTER\n3. MALAYSIA
# 6447  1. radiator\n2. oil cooler\n3. tooling\n4. com...
# 6448  1. Fuel injection systems / GDI Fuel Pump\n2. ...
# 6449  1. BRAKE PADS\n2. BRAKE SHOES\n3. INTIMA\n4. R...
#
#                                                     Url  \
# 0     https://automechanika-shanghai.hk.messefrankfu...
# 1     https://automechanika-shanghai.hk.messefrankfu...
# 2     https://automechanika-shanghai.hk.messefrankfu...
# 3     https://automechanika-shanghai.hk.messefrankfu...
# 4     https://automechanika-shanghai.hk.messefrankfu...
# ...                                                 ...
# 6445  https://automechanika-shanghai.hk.messefrankfu...
# 6446  https://automechanika-shanghai.hk.messefrankfu...
# 6447  https://automechanika-shanghai.hk.messefrankfu...
# 6448  https://automechanika-shanghai.hk.messefrankfu...
# 6449  https://automechanika-shanghai.hk.messefrankfu...
#
#                            Homepage  \
# 0     https://www.arnotteurope.com/
# 1
# 2                      www.aborn.cn
# 3                      www.abro.com
# 4                   www.accufill.cn
# ...                             ...
# 6445            www.automate.com.sg
# 6446                www.wahseng.com
# 6447         www.cryomaxcooling.com
# 6448
# 6449            www.taiwanbrake.com
#
#                                             Json_Social   Last Approval Date  \
# 0     {"0": {"[Social] No": 1, "[Social] Name": "wec...  2024-10-08T09:22:15
# 1                                                        2024-08-20T03:57:06
# 2                                                        2024-11-15T07:27:09
# 3                                                        2024-10-15T23:16:02
# 4                                                        2024-08-06T22:45:39
# ...                                                 ...                  ...
# 6445                                                     2024-10-17T07:46:18
# 6446                                                     2024-10-07T05:45:05
# 6447                                                     2024-10-20T12:29:17
# 6448                                                     2024-11-11T11:07:45
# 6449                                                     2024-11-07T11:28:51
#
#      IsTopCompany  ... 【Addressrdm】StreetName 【Addressrdm】Type  \
# 0                  ...                                  POSTAL
# 1                  ...                 高新区瑞达路           POSTAL
# 2                  ...           瑞安市塘下镇横三路66号           POSTAL
# 3                  ...                                  POSTAL
# 4                  ...           奉贤区浦卫公路6577号           POSTAL
# ...           ...  ...                    ...              ...
# 6445               ...                                  POSTAL
# 6446               ...                                  POSTAL
# 6447               ...                                  POSTAL
# 6448               ...                                  POSTAL
# 6449               ...                                  POSTAL
#
#      【Addressrdm】WritingSystem  【Address】City 【Address】Country  \
# 0                         HANS       Waalwijk               荷兰
# 1                         HANS        河南省 郑州市               中国
# 2                         HANS        浙江省 温州市               中国
# 3                         HANS     South Bend               美国
# 4                         HANS            上海市               中国
# ...                        ...            ...              ...
# 6445                      HANS                             新加坡
# 6446                      HANS         Penang             马来西亚
# 6447                      HANS       Taichung               台湾
# 6448                      HANS  Taichung City               台湾
# 6449                      HANS         Tainan               台湾
#
#                   【Address】Email       【Address】Fax  \
# 0          info@arnotteurope.com
# 1            xiao8614759@126.com
# 2                 sale3@aborn.cn  +86 577 6517 7300
# 3                  abro@abro.com    +1 574-232-8295
# 4              sales@accufill.cn   +86 21 6461 9305
# ...                          ...                ...
# 6445  chandran.p@automate.com.sg      +65 6316 9288
# 6446           sales@wahseng.com
# 6447     info@cryomaxcooling.com   +886 4 2310 5877
# 6448         noemail@noemail.com   +886 4 2350 6068
# 6449      tbt261@taiwanbrake.com    +886 6 593 3528
#
#                                         【Address】Street       【Address】Tel  \
# 0                                      Industrieweg  19    +31 73 785 0580
# 1                                                高新区瑞达路  +86 755 2937 2366
# 2                                          瑞安市塘下镇横三路66号  +86 577 6668 3101
# 3                                 3580 Blackthorn Court    +1 574-232-8289
# 4                                          奉贤区浦卫公路6577号   +86 21 3712 1888
# ...                                                 ...                ...
# 6445     #10-08, Tradehub 21, Singapore  8 Boon Lay Way      +65 6316 8288
# 6446     Bukit Mertajam No 1122, Jalan Juru, Mk13, Juru    +60 12-401 7622
# 6447  2B, No. 381, Sec. 3, Tong-Hsin Road, Xitun Dist.,   +886 4 2310 5666
# 6448      7F-11, No. 210, Gongyequ 38th Rd., Xitun Dist   +886 4 2350 6069
# 6449               No. 125-2,  Zhonglun,  Anding Dist.,    +886 6 593 3800
#
#      【Address】Zip
# 0         5145 PD
# 1          450000
# 2          325200
# 3           46628
# 4          201417
# ...           ...
# 6445       609964
# 6446        14000
# 6447       407497
# 6448       407277
# 6449       745002
#
# [6450 rows x 29 columns]

# %%
crawler_status, (crawler_index, crawler_series) = False, next(df_input.iterrows())

crawler_status, crawler_index, crawler_series
# Out:
# (False,
#  0,
#  No                                                                               5
#  Name                                                    Arnott Suspension Products
#  Presentation                                                               2.1 E30
#  Category                                              1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）
#  Key Word                         1. Struts\n2. Air Suspension\n3. Air Springs\n...
#  Url                              https://automechanika-shanghai.hk.messefrankfu...
#  Homepage                                             https://www.arnotteurope.com/
#  Json_Social                      {"0": {"[Social] No": 1, "[Social] Name": "wec...
#  Last Approval Date                                             2024-10-08T09:22:15
#  IsTopCompany
#  Logo                             https://exhibitorsearch.hk.messefrankfurt.com/...
#  【Addressrdm】Building
#  【Addressrdm】CompanyName
#  【Addressrdm】Country
#  【Addressrdm】DependentLocality
#  【Addressrdm】FormatedAddress
#  【Addressrdm】HouseNumber
#  【Addressrdm】Locality
#  【Addressrdm】PostalCode
#  【Addressrdm】StreetName
#  【Addressrdm】Type                                                            POSTAL
#  【Addressrdm】WritingSystem                                                     HANS
#  【Address】City                                                             Waalwijk
#  【Address】Country                                                                荷兰
#  【Address】Email                                               info@arnotteurope.com
#  【Address】Fax
#  【Address】Street                                                   Industrieweg  19
#  【Address】Tel                                                       +31 73 785 0580
#  【Address】Zip                                                               5145 PD
#  Name: 0, dtype: object)

# %%
count_retry = 0
while True:
    count_retry += 1
    print(count_retry)
    try:
        url_request, url_check = f'''https://api.messefrankfurt.com/service/esb_api/exhibitor-service/api/2.1/public/exhibitor/profile/zh-CN/{crawler_series['Url'].removeprefix('https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/').removesuffix('.html')}/AUTOMECHANIKASHANGHAI''', crawler_series['Url']

        resp = requests.get(url_request,
                            headers=get_header(**{'Apikey': api}),
                            proxies=get_proxy(),
                            timeout=(5, 15))

        if resp.status_code == 401 and dict_['status'] == 401 and dict_['message'].strip() == 'API GW: Unauthorized':
            print(f'fuck api {api}')
            time.sleep(3)
            with open('./api.txt', 'r') as api_txt:
                api = api_txt.read()
        elif resp.status_code == 200:
            dict_ = resp.json()

            if dict_['success'] == True:
                break
    except KeyboardInterrupt:
        break
    except:
        time.sleep(3)
        continue

dict_
# Out:
# 1
# {'success': True,
#  'fieldErrors': [],
#  'systemErrors': [],
#  'message': None,
#  'result': {'id': 'mf_2_a3pk1a04km8a~mf_2_10000100202401_A3PK1A04KM8A_369272',
#   'synId': 'mf_2_a3pk1a04km8a',
#   'rewriteId': 'abbt-the-netherlands-bv-trading-as-arnott-europe',
#   'name': 'Arnott Suspension Products',
#   'shortDescription': None,
#   'exhibition': {'id': 'AUTOMECHANIKASHANGHAI',
#    'name': 'Automechanika Shanghai 2024',
#    'synonyme': None,
#    'exhibitionHall': [{'id': '2.1',
#      'name': '2.1',
#      'sortKey': '0000000005',
#      'nameLabel': {'localId': 'HALLNAME_2.1_AUTOMECHANIKASHANGHAI',
#       'labels': {'zh-TW': {'localId': 'HALLNAME_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': '2.1',
#         'language': 'zh-TW'},
#        'zh-CN': {'localId': 'HALLNAME_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': '2.1',
#         'language': 'zh-CN'},
#        'en-GB': {'localId': 'HALLNAME_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': '2.1',
#         'language': 'en-GB'}}},
#      'categoryLabel': {'localId': 'HALLCATEGORY_2.1_AUTOMECHANIKASHANGHAI',
#       'labels': {'zh-TW': {'localId': 'HALLCATEGORY_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': '展館',
#         'language': 'zh-TW'},
#        'zh-CN': {'localId': 'HALLCATEGORY_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': '展馆',
#         'language': 'zh-CN'},
#        'en-GB': {'localId': 'HALLCATEGORY_2.1_AUTOMECHANIKASHANGHAI',
#         'groupType': 'HALLDATA',
#         'text': 'Hall',
#         'language': 'en-GB'}}},
#      'stand': [{'name': 'E30',
#        'category': None,
#        'phone': '',
#        'fax': '',
#        'type': 'exhibitor',
#        'boothId': 'A3PK1A39YVWM',
#        'exhibitorProgram': None,
#        'zones': []}]}],
#    'href': 'automechanika-shanghai.hk.messefrankfurt.com',
#    'logo': None,
#    'startdate': '2024-12-02',
#    'enddate': '2024-12-05'},
#   'address': {'street': 'Industrieweg  19',
#    'city': 'Waalwijk',
#    'zip': '5145 PD',
#    'tel': '+31 73 785 0580',
#    'fax': None,
#    'country': {'id': 'NLD', 'iso3': 'NLD', 'label': '荷兰'},
#    'email': 'info@arnotteurope.com',
#    'POB': None,
#    'POBCity': None,
#    'POBZip': None},
#   'addressrdm': {'recipient': None,
#    'companyName': None,
#    'country': None,
#    'postalCode': None,
#    'locality': None,
#    'streetName': None,
#    'houseNumber': None,
#    'postOfficeBox': None,
#    'province': None,
#    'dependentLocality': None,
#    'building': None,
#    'type': 'POSTAL',
#    'lastUsed': None,
#    'lastUsage': None,
#    'language': None,
#    'writingSystem': 'HANS',
#    'senderLanguageCode': None,
#    'senderLanguageStandard': None,
#    'version': None,
#    'created': None,
#    'updated': None,
#    'isPrimary': None,
#    'formatedAddress': None,
#    'roles': None},
#   'description': {'images': ['company_pictures/10000100202401/369272/1724136440864_1640147286.jpg'],
#    'text': '<P>Arnott拥有超过35年的工程设计经验，一直致力于为汽车售后市场设计和制造高品质的悬架部件，是悬架系统领域的技术专家。 我们的产品线不断增长，包括再制造OE原厂空气支柱、Arnott自主设计的全新(eRide)空气支柱、(电磁)减震器、创新设计的空气弹簧、OES原装配套的空气悬架压缩机、螺旋弹簧转换套件、分配阀和底盘高度传感器。</P><P><SPAN>公司于1989年成立，创始人Adam Arnott先生对修车和造车非常热衷和痴迷，并在位于佛罗里达州的蓬塔戈尔达（Punta Gorda）的自家车库里不断实践，他的父亲Donald Arnott意识到了儿子在汽车方面的才能，并对Adam的兴趣给予了支持和鼓励。1990年，两人开始在佛罗里达州各地旅行，沿途通常只收取很少的费用或免费为车主修复并解决空气悬架的各种问题。Adam对汽车的热情，加上Donald无私帮助他人的满足感，为公司发展奠定了坚实的基础，并推动Anott成为世界上最成功、最先进、最具创新性的汽车空气悬架产品制造商。</SPAN></P><P>Arnott悬架产品的车型适用范围非常全面，目前拥有780多个SKU，可覆盖38个汽车品牌，并通过全球知名经销商在本地市场销售。 Arnott系列产品均采用高品质的OE零部件，确保产品在外观、合车和功能方面与OE品质相当。每件产品均在美国和欧洲工厂的实验室环境下以及在自有车队的车辆上进行了全方位的反复测试，并在批量生产前针对特定的车辆品牌和型号进行了定制调校。</P><UL><LI><SPAN>以大众化的价格提供OE外观、合车和功能相当的高品质售后产品</SPAN></LI><LI><SPAN></SPAN><SPAN>用优质品牌的高品质配件制造而成</SPAN></LI><LI><SPAN></SPAN><SPAN>美国设计及工艺</SPAN></LI><LI><SPAN></SPAN><SPAN>在Arnott美国及欧洲工厂组装</SPAN></LI><LI><SPAN></SPAN><SPAN>上线TecDoc及其全功能订单管理系统（TecCom）</SPAN></LI><LI><SPAN></SPAN><SPAN>提供丰富的产品安装手册和视频</SPAN></LI><LI><SPAN></SPAN><SPAN>专业的现场客户服务，支持多种语言</SPAN></LI><LI><SPAN></SPAN><SPAN>本地主流配件经销商现货供应</SPAN></LI></UL><P><BR /><SPAN>35多年来，Arnott的全球团队每一天都在通过不懈地努力，坚守Arnott品牌对客户承诺的信任和品质。我们与每位客户都保持紧密的合作关系，并全力支持客户不断取得成功。Arnott 的产品线可全面覆盖适配车型且性价比卓越，并辅以一流的专业支持和值得信赖的全球分销网络，为经销商、分销商和安装人员提供必要的手段和工具，最大限度地提升客户的成长空间。</SPAN></P>'},
#   'specification': '',
#   'keyWords': ['Struts',
#    'Air Suspension',
#    'Air Springs',
#    'Shocks',
#    'Compressors'],
#   'tag': [],
#   'products': {'countTotal': 5,
#    'products': [{'id': 'mf_2_a3pk1a04km8a_4151725_10000100202401',
#      'name': '后空气弹簧，适用于宝马X5 (E70/F15) 以及宝马X6 (E71/F16)。',
#      'description': {'images': ['product_pictures/10000100202401/369272/1728371222014_2114191429.jpg'],
#       'text': '<P>A-2642为Arnott空气弹簧，适用于宝马X5 (E70/F15) 以及宝马X6 (E71/F16) 后轴。</P><P>Arnott空气弹簧由美国本土的研发中心自主设计，后经实验室和车辆道路全面测试，以确保产品符合各项指标和质量标准。Arnott空气弹簧采用最先进的多层气包，由Continental&reg; ContiTech德国大陆集团马牌等行业领先的橡胶产品公司制造。Arnott空气弹簧应用ISO认证的质量管理体系，在Arnott美国和欧盟工厂进行组装、测试和包装。Arnott空气弹簧的使用寿命更长，安装更便捷，让广大车主享有无与伦比的驾乘舒适性和产品耐用性。</P><P><STRONG>特点：</STRONG></P><UL><LI>Continental ContiTech德国大陆集团马牌多层气包</LI><LI>重负荷压接环</LI><LI>高抗冲树脂顶胶和底部活塞</LI><LI>全新的气管接头</LI></UL>'},
#      'specification': None,
#      'shortDescription': None,
#      'additionalImage': [],
#      'exhibition': None,
#      'exhibitorRef': None,
#      'isTopProduct': None,
#      'sortKey': '后空气弹簧适用于宝马x5e70f15以及宝马x6e71f16',
#      'productLink3d': None,
#      'novelty': False,
#      'pressRelease': None,
#      'deeplink': '',
#      'nextradeDeeplink': '',
#      'contentdownloads': None,
#      'videocontents': None},
#     {'id': 'mf_2_a3pk1a04km8a_4151726_10000100202401',
#      'name': '右前空气支柱总成，适用于宝马7系 (G11/G12) 以及宝马6系 (G32) 带四轮驱动AWD及4角空气悬架系统',
#      'description': {'images': ['product_pictures/10000100202401/369272/1728371580317_4070710095.jpg'],
#       'text': '<P>AS-3404为Arnott自主设计的全新后前空气支柱总成，适用于宝马7系 (G11/G12) 带四轮驱动AWD。该支柱总成可替换OE原厂产品，并配有全新的定制减震器，可带来卓越的驾乘体验和出色的操控性能。美国原装产品，配有Arnott的长效密封件、O型圈、防撞块、重型压接环、全新的空气接头和连接器阀以及防尘套，全面保护支柱。</P><P><STRONG>特点：</STRONG></P><UL><LI>仅适用于AWD全轮驱动的宝马7系 (G11/G12)</LI><LI>定制阀门的 减震器</LI><LI>重型压接环</LI><LI>美国设计和组装</LI></UL>'},
#      'specification': None,
#      'shortDescription': None,
#      'additionalImage': [],
#      'exhibition': None,
#      'exhibitorRef': None,
#      'isTopProduct': None,
#      'sortKey': '右前空气支柱总成适用于宝马7系g11g12以及宝马6系g32带四轮驱动awd及4角空气悬架系统',
#      'productLink3d': None,
#      'novelty': False,
#      'pressRelease': None,
#      'deeplink': '',
#      'nextradeDeeplink': '',
#      'contentdownloads': None,
#      'videocontents': None},
#     {'id': 'mf_2_a3pk1a04km8a_4151727_10000100202401',
#      'name': 'Arnott右前电控eRide空气支柱总成，适用于保时捷卡宴 (92A) 以及大众途锐 (7P5, 7P6)',
#      'description': {'images': ['product_pictures/10000100202401/369272/1728371960526_2363857927.jpg'],
#       'text': '<P>ASE-4373为Arnott独有的电控eRide支柱总成，可精准实现原厂件的全部功能。Arnott全新的电控支柱总成采用了Arnott的eRide电子行驶控制技术，可根据车辆精确的数字输入进行动态调整以获得最佳操控性能。该电控支柱总成均经过严格测试，以确保正常功能和使用寿命。全新Arnott电控支柱总成均由美国制造。</P><P><STRONG>特点：</STRONG></P><UL><LI>eRide - Arnott电子行驶控制技术</LI><LI>自主研发的主动减震技术，采用Arnott设计的阀门</LI><LI>保留所有OE原厂性能</LI><LI>电子自适应以获得最佳性能</LI><LI>可直接替换OE原厂电子减震器和支柱总成</LI><LI>经过全面测试，确保正常功能和使用寿命</LI><LI>美国设计、测试并组装</LI></UL>'},
#      'specification': None,
#      'shortDescription': None,
#      'additionalImage': [],
#      'exhibition': None,
#      'exhibitorRef': None,
#      'isTopProduct': None,
#      'sortKey': 'arnott右前电控eride空气支柱总成适用于保时捷卡宴92a以及大众途锐7p57p6',
#      'productLink3d': None,
#      'novelty': False,
#      'pressRelease': None,
#      'deeplink': '',
#      'nextradeDeeplink': '',
#      'contentdownloads': None,
#      'videocontents': None},
#     {'id': 'mf_2_a3pk1a04km8a_4151728_10000100202401',
#      'name': '螺旋弹簧转换套件，适用于不带VDS的路虎揽胜 (L322)',
#      'description': {'images': ['product_pictures/10000100202401/369272/1728372046627_2803509978.jpg'],
#       'text': '<P>Arnott的后市场螺旋弹簧转换套件C-2989是专门为不带VDS的路虎揽胜设计的。该套件将车辆的前后空气悬架转换为可靠的螺旋弹簧悬架系统。该套件需重复使用OE原装减震支柱，仅用美国原产的烤漆钢簧替换原车老旧的橡胶气囊。该套件包括全新的支柱顶胶、数控加工的铝制弹簧座、快捷转换所需的全套五金件，以及Arnott独有的电子旁路模块（EBM），该模块可安全关闭仪表板悬架警告灯。</P><P><STRONG>特点：</STRONG></P><UL><LI>烤漆钢簧</LI><LI>全新支柱顶胶</LI><LI>数控加工底部弹簧座</LI><LI>全新上下橡胶弹簧隔振器</LI><LI>电子旁通模块，用于关闭警告灯</LI><LI>详细的安装手册</LI></UL>'},
#      'specification': None,
#      'shortDescription': None,
#      'additionalImage': [],
#      'exhibition': None,
#      'exhibitorRef': None,
#      'isTopProduct': None,
#      'sortKey': '螺旋弹簧转换套件适用于不带vds的路虎揽胜l322',
#      'productLink3d': None,
#      'novelty': False,
#      'pressRelease': None,
#      'deeplink': '',
#      'nextradeDeeplink': '',
#      'contentdownloads': None,
#      'videocontents': None},
#     {'id': 'mf_2_a3pk1a04km8a_4151729_10000100202401',
#      'name': 'WABCO威伯科OES空气悬架压缩机，适用于特斯拉Model S (5YJS) 及Model X (5YJX)',
#      'description': {'images': ['product_pictures/10000100202401/369272/1728372128282_1457219863.jpg'],
#       'text': '<P>Arnott空气悬架压缩机P-3509适用于特斯拉&reg;Model S及Model X，该产品为特斯拉&reg;原装OE压缩机的直接替换产品。此款原装WABCO&reg;压缩机可直接与车辆的空气管路和电气接头连接。产品包含安装支架、阀组和进气软管，可快速安装、即插即用。特斯拉&reg;的WABCO&reg;后市场压缩机是一款功能强大、设计紧凑且轻量化的产品。</P><P><STRONG>特点：</STRONG></P><UL><LI>包含集成式干燥器及全新继电器</LI><LI>重负荷电机可延长使用寿命</LI><LI>带热过载保护</LI><LI>电镀表面可防腐蚀</LI></UL>'},
#      'specification': None,
#      'shortDescription': None,
#      'additionalImage': [],
#      'exhibition': None,
#      'exhibitorRef': None,
#      'isTopProduct': None,
#      'sortKey': 'wabco威伯科oes空气悬架压缩机适用于特斯拉models5yjs及modelx5yjx',
#      'productLink3d': None,
#      'novelty': False,
#      'pressRelease': None,
#      'deeplink': '',
#      'nextradeDeeplink': '',
#      'contentdownloads': None,
#      'videocontents': None}]},
#   'categories': [{'id': 'mf_ppx_slx_9724867',
#     'name': '1 部件及组件',
#     'adLabel': '1 部件及组件',
#     'booked': None,
#     'sapProdId': '00001000000000000000',
#     'subCategories': [{'id': 'mf_ppx_slx_9724880',
#       'name': '1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）',
#       'adLabel': '1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）',
#       'booked': True,
#       'sapProdId': '00001000020000000000',
#       'subCategories': None,
#       'exhibitors': None,
#       'nrChildren': 0}],
#     'exhibitors': None,
#     'nrChildren': 1}],
#   'usageAreas': [],
#   'productenduses': [],
#   'otherExhibitions': None,
#   'catalogExtraText': [],
#   'profileLabels': {'contentDownload': {'showLabel': False, 'count': 0},
#    'shopLink': {'showLabel': False, 'count': 0},
#    'videoContent': {'showLabel': False, 'count': 0},
#    'socialMedia': {'showLabel': True, 'count': 1},
#    'productDirectLink': {'showLabel': False, 'count': 0},
#    'pressRelease': {'showLabel': False, 'count': 0},
#    'jobOffer': {'showLabel': False, 'count': 0},
#    'nextradeShoplink': {'showLabel': False, 'count': 0},
#    'virtualShowroom': {'showLabel': False, 'count': 0},
#    'productlink3D': {'showLabel': False, 'count': 0},
#    'fairlink3D': {'showLabel': False, 'count': 0}},
#   'social': [{'network': 'wechat',
#     'url': 'http://weixin.qq.com/r/NCmAmGXEpDjbrSH793wm',
#     'imageFile': 'qrcodes/10000100202401/369272/1724137084111_1818545518.png'}],
#   'shopLink': None,
#   'contentDownload': None,
#   'pressRelease': None,
#   'jobOffers': None,
#   'videoContent': None,
#   'href': 'https://www.arnotteurope.com/',
#   'logo': 'company_pictures/10000100202401/369272/1724136316691_355369521.png',
#   'homepage': 'https://www.arnotteurope.com/',
#   'showProducts': True,
#   'showContact': False,
#   'type': None,
#   'isTopCompany': None,
#   'synonymeFor': None,
#   'sortKey': 'ABBT THE NETHERLANDS BV TRADIN',
#   'searchHighlight': False,
#   'completeness': None,
#   'exhibitorPrograms': None,
#   'contacts': [],
#   'agencies': [],
#   'zones': [],
#   'brands': {'brands': None, 'licenses': None},
#   'nextradeShopLink': [],
#   'fairLink3d': [],
#   'exhibitorEvents': [],
#   'lastApprovalDate': '2024-10-08T09:22:15',
#   'presentationLinks': [{'presentationName': 'Arnott Suspension Products',
#     'presentationGuid': 'mf_2_369272',
#     'exhibitorUrlRewrite': 'abbt-the-netherlands-bv-trading-as-arnott-europe',
#     'plogo': 'company_pictures/10000100202401/369272/1724136316691_355369521.png',
#     'pstands': [{'hallAndLevel': '2.1',
#       'firstBoothNumber': 'E30',
#       'mainStand': False}],
#     'thisIsMe': True}],
#   'externalContents': None,
#   'teaser': None,
#   'aemLink': None}}

# %%
if dict_['result']['products']['countTotal'] == 0:
    list_dict_correct_temp = [{'Url': crawler_series['Url']}]
else:
    list_dict_correct_temp = []
    for i, dict_product in enumerate(dict_['result']['products']['products']):
        list_dict_correct_temp.append({'Url': crawler_series['Url'],
                                       '[Product] No': i + 1,
                                       '[Product] Url': f'''{crawler_series['Url'].removesuffix('.html')}/{dict_product['id']}.html'''})

list_dict_correct_temp
# Out:
# [{'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 1,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151725_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 2,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151726_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 3,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151727_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 4,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151728_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 5,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151729_10000100202401.html'}]

# %%
list_dict_correct.extend(list_dict_correct_temp)

list_dict_correct
# Out:
# [{'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 1,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151725_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 2,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151726_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 3,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151727_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 4,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151728_10000100202401.html'},
#  {'Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe.html',
#   '[Product] No': 5,
#   '[Product] Url': 'https://automechanika-shanghai.hk.messefrankfurt.com/shanghai/zh-cn/exhibitor-search.detail.html/abbt-the-netherlands-bv-trading-as-arnott-europe/mf_2_a3pk1a04km8a_4151729_10000100202401.html'}]

# %%
crawler_status = True

crawler_status
# Out:
# True

# %%
crawler_series['Request_Url'], crawler_series['Check_Url'] = url_request, url_check

list_series_error.append(crawler_series)

list_series_error
# Out:
# [No                                                                               5
#  Name                                                    Arnott Suspension Products
#  Presentation                                                               2.1 E30
#  Category                                              1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）
#  Key Word                         1. Struts\n2. Air Suspension\n3. Air Springs\n...
#  Url                              https://automechanika-shanghai.hk.messefrankfu...
#  Homepage                                             https://www.arnotteurope.com/
#  Json_Social                      {"0": {"[Social] No": 1, "[Social] Name": "wec...
#  Last Approval Date                                             2024-10-08T09:22:15
#  IsTopCompany
#  Logo                             https://exhibitorsearch.hk.messefrankfurt.com/...
#  【Addressrdm】Building
#  【Addressrdm】CompanyName
#  【Addressrdm】Country
#  【Addressrdm】DependentLocality
#  【Addressrdm】FormatedAddress
#  【Addressrdm】HouseNumber
#  【Addressrdm】Locality
#  【Addressrdm】PostalCode
#  【Addressrdm】StreetName
#  【Addressrdm】Type                                                            POSTAL
#  【Addressrdm】WritingSystem                                                     HANS
#  【Address】City                                                             Waalwijk
#  【Address】Country                                                                荷兰
#  【Address】Email                                               info@arnotteurope.com
#  【Address】Fax
#  【Address】Street                                                   Industrieweg  19
#  【Address】Tel                                                       +31 73 785 0580
#  【Address】Zip                                                               5145 PD
#  Check_Url                        https://automechanika-shanghai.hk.messefrankfu...
#  Name: 0, dtype: object]

# %%
if list_dict_correct:
    df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['Url', '[Product] No'],
                                                             ascending=[True, True],
                                                             ignore_index=True)
    df_correct.to_excel('./test_product_url.xlsx', index=False)

df_correct
# Out:
#                                                  Url  [Product] No  \
# 0  https://automechanika-shanghai.hk.messefrankfu...             1
# 1  https://automechanika-shanghai.hk.messefrankfu...             2
# 2  https://automechanika-shanghai.hk.messefrankfu...             3
# 3  https://automechanika-shanghai.hk.messefrankfu...             4
# 4  https://automechanika-shanghai.hk.messefrankfu...             5
#
#                                        [Product] Url
# 0  https://automechanika-shanghai.hk.messefrankfu...
# 1  https://automechanika-shanghai.hk.messefrankfu...
# 2  https://automechanika-shanghai.hk.messefrankfu...
# 3  https://automechanika-shanghai.hk.messefrankfu...
# 4  https://automechanika-shanghai.hk.messefrankfu...

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                           ascending=[True],
                                                           ignore_index=True)
    df_error.to_excel('./test_product_url_error.xlsx', index=False)

df_error
# Out:
#    No                        Name Presentation                      Category  \
# 0   5  Arnott Suspension Products      2.1 E30  1.2 底盘部分（车桥、方向盘、制动装置、车轮、减震器）
#
#                                             Key Word  \
# 0  1. Struts\n2. Air Suspension\n3. Air Springs\n...
#
#                                                  Url  \
# 0  https://automechanika-shanghai.hk.messefrankfu...
#
#                         Homepage  \
# 0  https://www.arnotteurope.com/
#
#                                          Json_Social   Last Approval Date  \
# 0  {"0": {"[Social] No": 1, "[Social] Name": "wec...  2024-10-08T09:22:15
#
#   IsTopCompany  ... 【Addressrdm】Type 【Addressrdm】WritingSystem 【Address】City  \
# 0               ...           POSTAL                      HANS      Waalwijk
#
#   【Address】Country         【Address】Email 【Address】Fax   【Address】Street  \
# 0               荷兰  info@arnotteurope.com               Industrieweg  19
#
#       【Address】Tel 【Address】Zip  \
# 0  +31 73 785 0580      5145 PD
#
#                                            Check_Url
# 0  https://automechanika-shanghai.hk.messefrankfu...
#
# [1 rows x 30 columns]
