# %%
import os

list_file = sorted(list(os.walk('./file/3.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_100.xlsx',
#  'crawler_101.xlsx',
#  'crawler_102.xlsx',
#  'crawler_103.xlsx',
#  'crawler_104.xlsx',
#  'crawler_105.xlsx',
#  'crawler_106.xlsx',
#  'crawler_107.xlsx',
#  'crawler_11.xlsx',
#  'crawler_12.xlsx',
#  'crawler_13.xlsx',
#  'crawler_14.xlsx',
#  'crawler_15.xlsx',
#  'crawler_16.xlsx',
#  'crawler_17.xlsx',
#  'crawler_18.xlsx',
#  'crawler_19.xlsx',
#  'crawler_2.xlsx',
#  'crawler_20.xlsx',
#  'crawler_21.xlsx',
#  'crawler_22.xlsx',
#  'crawler_23.xlsx',
#  'crawler_24.xlsx',
#  'crawler_25.xlsx',
#  'crawler_26.xlsx',
#  'crawler_27.xlsx',
#  'crawler_28.xlsx',
#  'crawler_29.xlsx',
#  'crawler_3.xlsx',
#  'crawler_30.xlsx',
#  'crawler_31.xlsx',
#  'crawler_32.xlsx',
#  'crawler_33.xlsx',
#  'crawler_34.xlsx',
#  'crawler_35.xlsx',
#  'crawler_36.xlsx',
#  'crawler_37.xlsx',
#  'crawler_38.xlsx',
#  'crawler_39.xlsx',
#  'crawler_4.xlsx',
#  'crawler_40.xlsx',
#  'crawler_41.xlsx',
#  'crawler_42.xlsx',
#  'crawler_43.xlsx',
#  'crawler_44.xlsx',
#  'crawler_45.xlsx',
#  'crawler_46.xlsx',
#  'crawler_47.xlsx',
#  'crawler_48.xlsx',
#  'crawler_49.xlsx',
#  'crawler_5.xlsx',
#  'crawler_50.xlsx',
#  'crawler_51.xlsx',
#  'crawler_52.xlsx',
#  'crawler_53.xlsx',
#  'crawler_54.xlsx',
#  'crawler_55.xlsx',
#  'crawler_56.xlsx',
#  'crawler_57.xlsx',
#  'crawler_58.xlsx',
#  'crawler_59.xlsx',
#  'crawler_6.xlsx',
#  'crawler_60.xlsx',
#  'crawler_61.xlsx',
#  'crawler_62.xlsx',
#  'crawler_63.xlsx',
#  'crawler_64.xlsx',
#  'crawler_65.xlsx',
#  'crawler_66.xlsx',
#  'crawler_67.xlsx',
#  'crawler_68.xlsx',
#  'crawler_69.xlsx',
#  'crawler_7.xlsx',
#  'crawler_70.xlsx',
#  'crawler_71.xlsx',
#  'crawler_72.xlsx',
#  'crawler_73.xlsx',
#  'crawler_74.xlsx',
#  'crawler_75.xlsx',
#  'crawler_76.xlsx',
#  'crawler_77.xlsx',
#  'crawler_78.xlsx',
#  'crawler_79.xlsx',
#  'crawler_8.xlsx',
#  'crawler_80.xlsx',
#  'crawler_81.xlsx',
#  'crawler_82.xlsx',
#  'crawler_83.xlsx',
#  'crawler_84.xlsx',
#  'crawler_85.xlsx',
#  'crawler_86.xlsx',
#  'crawler_87.xlsx',
#  'crawler_88.xlsx',
#  'crawler_89.xlsx',
#  'crawler_9.xlsx',
#  'crawler_90.xlsx',
#  'crawler_91.xlsx',
#  'crawler_92.xlsx',
#  'crawler_93.xlsx',
#  'crawler_94.xlsx',
#  'crawler_95.xlsx',
#  'crawler_96.xlsx',
#  'crawler_97.xlsx',
#  'crawler_98.xlsx',
#  'crawler_99.xlsx']

# %%
from tqdm import tqdm
import pandas as pd
from datetime import datetime

input_ = pd.DataFrame()
for file in tqdm(list_file, desc='Progress', ncols=77):
    df_temp = pd.read_excel(f'./file/3.part/{file}',
                            header=0,
                            dtype=str).fillna('')
    
    df_temp['No'] = df_temp['No'].astype(int)
    df_temp['Rating Count'] = df_temp['Rating Count'].astype(int)

    input_ = pd.concat([input_, df_temp], ignore_index=True).fillna('')

input_ = input_.sort_values(by=['Type', 'Part Number'],
                            ascending=[True, True],
                            ignore_index=True)

input_['No'] = [_+1 for _ in range(len(input_))]

input_.to_excel(f'''./file/【网站爬虫】1AAuto-{datetime.now().strftime('%Y%m%d')}.xlsx''', index=False)

input_
# Out:
# Progress: 100%|████████████████████████████| 107/107 [00:35<00:00,  2.98it/s]
#             No                       Type  Part Number                Brand  \
# 0            1  4WD Axle Actuator Housing      917-500  Dorman OE Solutions
# 1            2                  4WD Parts   04137696AB                Mopar
# 2            3                  4WD Parts   05083138AA                Mopar
# 3            4                  4WD Parts     19259313   General Motors OEM
# 4            5                  4WD Parts  1C3Z3B396CB             Ford OEM
# ...        ...                        ...          ...                  ...
# 144689  144690                   Wrenches         M199     Performance Tool
# 144690  144691                   Wrenches        W1061     Performance Tool
# 144691  144692                   Wrenches        W1062     Performance Tool
# 144692  144693                   Wrenches         W350     Performance Tool
# 144693  144694                   Wrenches        W350M     Performance Tool
#
#              Tag                                              Title  \
# 0       Replaces  Jeep Dodge Plymouth Axle Disconnect Housing As...
# 1       Replaces  Jeep Dodge Rear Axle Mounted Differential Vent...
# 2       Replaces  Jeep Dodge Transfer Case 4 Wheel Drive Indicat...
# 3       Replaces  Chevrolet GMC Cadillac Four Wheel Drive Switch...
# 4       Replaces  Ford Front Automatic Locking Hub Ford OEM 1C3Z...
# ...          ...                                                ...
# 144689                                                Torque Wrench
# 144690                              11 Piece Combination Wrench Set
# 144691                              11 Piece Combination Wrench Set
# 144692                                           3 Piece Wrench Set
# 144693                                           3 Piece Wrench Set
#
#                SKU       Price  Rating  Rating Count Picture  \
# 0       1AAXX00069   USD 46.45                     0
# 1       MPADC00001   USD 17.45  5/ 5.0             1
# 2       MPFWA00002  USD 127.95                     0
# 3       GMFWM00001  USD 145.45  5/ 5.0             1
# 4       MCFWH00003  USD 265.37                     0
# ...            ...         ...     ...           ...     ...
# 144689  1AXAA00044   USD 99.95  4/ 5.0            24
# 144690  1AXAA00011   USD 39.95                     0
# 144691  1AXAA00010   USD 42.95                     0
# 144692  1AXAA00049   USD 25.45                     0
# 144693  1AXAA00050   USD 29.95                     0
#
#                                                       Url  \
# 0       https://www.1aauto.com/jeep-dodge-plymouth-axl...
# 1       https://www.1aauto.com/jeep-dodge-rear-axle-mo...
# 2       https://www.1aauto.com/jeep-dodge-transfer-cas...
# 3       https://www.1aauto.com/chevrolet-gmc-cadillac-...
# 4       https://www.1aauto.com/ford-front-automatic-lo...
# ...                                                   ...
# 144689  https://www.1aauto.com/torque-wrench/i/1axaa00044
# 144690  https://www.1aauto.com/11-piece-combination-wr...
# 144691  https://www.1aauto.com/11-piece-combination-wr...
# 144692  https://www.1aauto.com/3-piece-wrench-set/i/1a...
# 144693  https://www.1aauto.com/3-piece-wrench-set/i/1a...
#
#                                                  Json_Src  \
# 0       {"0": "https://cdn.1aauto.com/partimage/AXX/1A...
# 1       {"0": "https://cdn.1aauto.com/partimage/ADC/MP...
# 2       {"0": "https://cdn.1aauto.com/partimage/FWA/MP...
# 3       {"0": "https://cdn.1aauto.com/partimage/FWM/GM...
# 4       {"0": "https://cdn.1aauto.com/partimage/FWH/MC...
# ...                                                   ...
# 144689  {"0": "https://cdn.1aauto.com/partimage/XAA/1A...
# 144690  {"0": "https://cdn.1aauto.com/partimage/XAA/1A...
# 144691  {"0": "https://cdn.1aauto.com/partimage/XAA/1A...
# 144692  {"0": "https://cdn.1aauto.com/partimage/XAA/1A...
# 144693  {"0": "https://cdn.1aauto.com/partimage/XAA/1A...
#
#                                          Json_Description Part Code
# 0       {"0": {"Item Condition": "New"}, "1": {"WARNIN...   1018943
# 1       {"0": {"Item Condition": "New"}, "1": {"WARNIN...   1106833
# 2       {"0": {"Item Condition": "New"}, "1": {"WARNIN...   1013972
# 3                        {"0": {"Item Condition": "New"}}   1102024
# 4       {"0": {"Operation": "Automatic"}, "1": {"Item ...   1013404
# ...                                                   ...       ...
# 144689  {"0": {"Includes": "Storage Case"}, "1": {"Too...   1135102
# 144690  {"0": {"Unit of Measure": "Standard SAE"}, "1"...   1133334
# 144691  {"0": {"Unit of Measure": "Metric"}, "1": {"En...   1133332
# 144692  {"0": {"Unit of Measure": "Standard SAE"}, "1"...   1135104
# 144693  {"0": {"Unit of Measure": "Metric"}, "1": {"Wr...   1135088
#
# [144694 rows x 15 columns]
