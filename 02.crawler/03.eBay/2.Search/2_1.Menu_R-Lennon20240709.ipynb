# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel('./1.page.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Page'] = input_['Page'].astype(int)

print(f'总数量：{len(input_)}')
input_['Page Url'].tolist()
# Out:
# 总数量：3
# ['https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower%20motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&_pgn=1',
#  'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower%20motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&_pgn=2',
#  'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower%20motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&_pgn=3']

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../../00.Tools')
from crawler_configuration import get_proxy

resp = requests.get(input_.loc[a, 'Page Url'],
                    # proxies=get_proxy(),
                    timeout=(10, 10)).text

resp
# Out:
# '<!DOCTYPE html><!--[if IE 9]><html class="ie9" lang="en"><![endif]--><!--[if gt IE 9]><!--><html lang="en"><!--<![endif]--><!--M#s0-2--><noscript class=x-page-config></noscript><!--M/--><head><meta http-equiv=X-UA-Compatible content=IE=edge><script>\n    (function () {\n        \'use strict\';\n        if (window.PerformanceObserver && performance && performance.mark && performance.getEntriesByName) {\n            window.SRP = window.SRP || {};\n            var paintObserver = new window.PerformanceObserver(function (list) {\n                var paintEntries = list.getEntries();\n                paintEntries.sort(function (a, b) {\n                    return a.startTime - b.startTime;\n                });\n                // begin looking for TTI at first contentful paint\n                if (!paintEntries || paintEntries.length < 2) {\n                    // to avoid undefined issue on Safari\n                    return;\n                }\n                var interactiveWindow = paintEntries[1].startTime;\n                window.SRP.TTI_TIMER = { lastInteractiveWindow: interactiveWindow };\n                var longTaskObserver = new window.PerformanceObserver(function (list) {\n                    var longtaskEntries = list.getEntries();\n                    for (var i = 0, len = longtaskEntries.length; i < len; i++) {\n                        // if we find an idle window of >= 5000 ms, the beginning of that window was our timeToInteractive\n                        if (longtaskEntries[i].startTime - interactiveWindow >= 5000) {\n                            window.SRP.TTI_TIMER.timeToInteract = interactiveWindow;\n                            longTaskObserver.disconnect();\n                        }\n                        interactiveWindow = longtaskEntries[i].startTime + longtaskEntries[i].duration;\n                        window.SRP.TTI_TIMER.lastInteractiveWindow = interactiveWindow;\n                    }\n                });\n                longTaskObserver.observe({ entryTypes: [\'longtask\'] });\n                paintObserver.disconnect();\n            });\n            paintObserver.observe({ entryTypes: [\'paint\'] });\n        }\n    })();\n</script><meta Property="og:type" Content="website" /><meta name="description" content="Shop eBay for great deals from goodstate!" /><meta name="robots" content="noindex" /><meta Property="og:url" Content="https://www.ebay.com.au/sch/i.html?_ssn=goodstate&amp;store_name=goodstate" /><meta Content="Shop eBay for great deals from goodstate!" Property="og:description" /><meta property="fb:app_id" content="102628213125203" /><meta Property="og:site_name" Content="eBay" /><link href="https://i.ebayimg.com" rel="preconnect" /><meta name="referrer" content="unsafe-url" /><link rel="preconnect" href="https://ir.ebaystatic.com" /><meta name="msvalidate.01" content="34E98E6F27109BE1A9DCF19658EEEE33" /><meta Property="og:title" Content="Items for sale by goodstate | eBay" /><meta name="y_key" content="7d36d498b94ae9e7" /><title>Items for sale by goodstate | eBay</title><meta name="google-site-verification" content="Q4u7bvDpYVla9dUmWlKk3Y7fc6NRuW6cI-3NaXiB4Pg" /><!-- NGMARS SIGNATURE --><link rel=dns-prefetch href=//i.ebayimg.com><link rel=dns-prefetch href=//ir.ebaystatic.com><link rel=dns-prefetch href=//rover.ebay.com><link rel=dns-prefetch href=//svcs.ebay.com><link rel=dns-prefetch href=//pulsar.ebay.com><link rel=dns-prefetch href=//www.google.com/ ><link rel=dns-prefetch href=//tpc.googlesyndication.com><link rel=dns-prefetch href=//securepubads.g.doubleclick.net><meta name=viewport content="width=device-width, initial-scale=1, minimum-scale=1"><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();!function(){if("PerformanceLongTaskTiming" in window){var g=window.__tti={e:[]};g.o=new PerformanceO ...

# %%
import json

json_ = json.loads(resp.split('$MC=(window.$MC||[]).concat(')[1].split(']}]})</script>')[0].strip() + ']}]}')

json_
# Out:
# {'o': {'l': 1,
#   'w': [['s0-60-0-2',
#     0,
#     {'model': {'keyword': '',
#       'categoryId': '0',
#       'refineCategories': [],
#       'searchFormFields': [{'name': 'LH_TitleDesc', 'value': 0}]}},
#     {'w': {}}],
#    ['s0-60-0-12-4',
#     1,
#     {'model': {'_type': 'SearchIncludeDescExperienceModel',
#       'checkBox': {'_type': 'TextualSelection',
#        'paramKey': 'LH_TitleDesc',
#        'paramValue': True,
#        'label': {'_type': 'TextualDisplay',
#         'textSpans': [{'_type': 'TextSpan', 'text': 'Include description'}]},
#        'uxComponentHint': 'CHECKBOX'}}},
#     {'f': 1, 's': {'checked': False}}],
#    ['s0-60-0-12-5-0-1[0]-0',
#     2,
#     {'id': 'follow-ebay-helper',
#      'showCurrent': True,
#      'showLegacy': False,
#      'prefix': 'fol',
#      'csrf': '10eade72e12218b4b493b7b6a23264b221fd6389ef5c0a05dd29dc26e9d4708e'},
#     {}],
#    ['s0-60-0-12-5-0-1[0]-1-16-0', 3, None, {}],
#    ['s0-60-0-12-5-0-1[0]-1-22-0', 3, None, {}],
#    ['s0-60-0-12-5-0-1[0]-1-25',
#     4,
#     {'activeSync': True,
#      'config': {'_type': 'ToggleAction',
#       'onCallToAction': {'_type': 'CallToAction',
#        'text': 'Saved seller',
#        'type': 'SECONDARY',
#        'action': {'_type': 'Action',
#         'type': 'OPERATION',
#         'name': 'UNFOLLOW',
#         'params': {'entity_type': 'SELLER',
#          'entity_id': '~goodstate',
#          'hosting_module_id': '54471'},
#         'clientPresentationMetadata': {'postBody': '{"entityType":"SELLER","entityId":"~goodstate"}',
#          'pageId': '3658866'},
#         'trackingList': [{'eventFamily': 'STOREFRONT',
#           'eventAction': 'ACTN',
#           'actionKind': 'CLICK',
#           'operationId': '3658866',
#           'flushImmediately': False,
#           'eventProperty': {'str': 'goodstate',
#            'soid': 'kgqgGZQsRL6',
#            'ads-soid': '1139869912',
#            'moduledtl': '145719',
#            'spid': 'kgqgGZQsRL6',
#            'sid': 'p3658866.m145719.l66311'}}],
#         'accessibilityText': 'Saved seller',
#         'tracking': {'eventFamily': 'STOREFRONT',
#          'eventAction': 'ACTN',
#          'actionKind': 'CLICK',
#          'operationId': '3658866',
#          'flushImmediately': False,
#          'eventProperty': {'str': 'goodstate',
#           'soid': 'kgqgGZQsRL6',
#           'ads-soid': '1139869912',
#           'moduledtl': '145719',
#           'spid': 'kgqgGZQsRL6',
#           'sid': 'p3658866.m145719.l66311'}},
#         'URL': 'https://www.ebay.com.au/fol/unfollow-exp?&entity_type=SELLER&entity_id=%7Egoodstate&hosting_module_id=54471'},
#        'accessibilityText': 'Saved seller',
#        'secondaryCtaIcon': {'_type': 'Icon', 'name': 'HEART_FILL'}},
#       'offCallToAction': {'_type': 'CallToAction',
#        'text': 'Save seller',
#        'type': 'SECONDARY',
#        'action': {'_type': 'Action',
#         'type': 'OPERATION',
#         'name': 'FOLLOW',
#         'params': {'entity_type': 'SELLER',
#          'entity_id': '~goodstate',
#          'hosting_module_id': '54471'},
#         'clientPresentationMetadata': {'postBody': '{"entityType":"SELLER","entityId":"~goodstate"}',
#          'pageId': '3658866'},
#         'trackingList': [{'eventFamily': 'STOREFRONT',
#           'eventAction': 'ACTN',
#           'actionKind': 'CLICK',
#           'operationId': '3658866',
#           'flushImmediately': False,
#           'eventProperty': {'str': 'goodstate',
#            'soid': 'kgqgGZQsRL6',
#            'ads-soid': '1139869912',
#            'moduledtl': '145719',
#            'spid': 'kgqgGZQsRL6',
#            'sid': 'p3658866.m145719.l66310'}}],
#         'accessibilityText': 'Save seller',
#         'tracking': {'eventFamily': 'STOREFRONT',
#          'eventAction': 'ACTN',
#          'actionKind': 'CLICK',
#          'operationId': '3658866',
#          'flushImmediately': False,
#          'eventProperty': {'str': 'goodstate',
#           'soid': 'kgqgGZQsRL6',
#           'ads-soid': '1139869912',
#           'moduledtl': '145719',
#           'spid': 'kgqgGZQsRL6',
#           'sid': 'p3658866.m145719.l66310'}},
#         'URL': 'https://www.ebay.com.au/fol/follow-exp?&entity_type=SELLER&entity_id=%7Egoodstate&hosting_module_id=54471'},
#        'accessibilityText': 'Save seller',
#        'secondaryCtaIcon': {'_type': 'Icon', 'name': 'HEART'}},
#       'initialState': 'OFF'},
#      'classes': ['follow-ebay'],
#      'isLarge': True},
#     {'f': 1, 's': {'disabled': False, 'errorData': '', 'errorShow': False}}],
#    ['s0-60-0-12-8-0-1-2',
#     5,
#     {'model': {'_type': 'SearchRefinementsModule',
#       'group': [{'_type': 'Group',
#         'fieldId': 'category',
#         'paramKey': '_sacat',
#         'label': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Category'}]},
#         'selectionType': 'SINGLE',
#         'expandInline': True,
#         'entries': [{'_type': 'Group',
#           'selected': True,
#           'paramValue': '0',
#           'additionalParamKeyValues': {'_oac': '1'},
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'All'}],
#            'accessibilityText': 'Selected category'},
#           'defaultChoice': True,
#           'expandInline': True,
#           'entries': [{'_type': 'Group',
#             'paramValue': '131090',
#             'label': {'_type': 'TextualDisplay',
#              'textSpans': [{'_type': 'TextSpan',
#                'text': 'Vehicle Parts & Accessories'}]},
#             'action': {'_type': 'Action',
#              'type': 'NAV',
#              'name': 'SEARCH',
#              'params': {'_dkr': '1',
#               '_udlo': '',
#               '_blrs': 'recall_filtering',
#               '_ssn': 'goodstate',
#               '_ipg': '240',
#               'iconV2Request': 'true',
#               '_stpos': '2019',
#               'orig_cvip': 'true',
#               '_nkw': 'blower motor',
#               '_ul': 'AU',
#               '_sacat': '131090',
#               'store_name': 'goodstate',
#               '_sop': '16',
#               '_oac': '1',
#               '_udhi': ''},
#              'trackingList': [{'eventFamily': 'LST',
#                'eventAction': 'ACTN',
#                'actionKind': 'NAVSRC',
#                'actionKinds': ['NAVSRC'],
#                'operationId': '3658866',
#                'flushImmediately': False,
#                'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A1%7C',
#                 'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                 'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#               {'actionKind': 'NAV',
#                'actionKinds': ['NAV'],
#                'operationId': '3658866',
#                'flushImmediately': False,
#                'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#              'URL': 'https://www.ebay.com.au/sch/131090/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'},
#             'expandInline': True,
#             'entries': [{'_type': 'TextualSelection',
#               'paramValue': '46094',
#               'label': {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Other Car & Truck Air Conditioning & Heating'}]},
#               'action': {'_type': 'Action',
#                'type': 'NAV',
#                'name': 'SEARCH',
#                'params': {'_dkr': '1',
#                 '_udlo': '',
#                 '_blrs': 'recall_filtering',
#                 '_ssn': 'goodstate',
#                 '_ipg': '240',
#                 'iconV2Request': 'true',
#                 '_stpos': '2019',
#                 'orig_cvip': 'true',
#                 '_nkw': 'blower motor',
#                 '_ul': 'AU',
#                 '_sacat': '46094',
#                 'store_name': 'goodstate',
#                 '_sop': '16',
#                 '_oac': '1',
#                 '_udhi': ''},
#                'trackingList': [{'eventFamily': 'LST',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'NAVSRC',
#                  'actionKinds': ['NAVSRC'],
#                  'operationId': '3658866',
#                  'flushImmediately': False,
#                  'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A2%7C',
#                   'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                   'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#                 {'actionKind': 'NAV',
#                  'actionKinds': ['NAV'],
#                  'operationId': '3658866',
#                  'flushImmediately': False,
#                  'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#                'URL': 'https://www.ebay.com.au/sch/46094/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'}},
#              {'_type': 'TextualSelection',
#               'paramValue': '50459',
#               'label': {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Car & Truck Switches & Controls'}]},
#               'action': {'_type': 'Action',
#                'type': 'NAV',
#                'name': 'SEARCH',
#                'params': {'_dkr': '1',
#                 '_udlo': '',
#                 '_blrs': 'recall_filtering',
#                 '_ssn': 'goodstate',
#                 '_ipg': '240',
#                 'iconV2Request': 'true',
#                 '_stpos': '2019',
#                 'orig_cvip': 'true',
#                 '_nkw': 'blower motor',
#                 '_ul': 'AU',
#                 '_sacat': '50459',
#                 'store_name': 'goodstate',
#                 '_sop': '16',
#                 '_oac': '1',
#                 '_udhi': ''},
#                'trackingList': [{'eventFamily': 'LST',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'NAVSRC',
#                  'actionKinds': ['NAVSRC'],
#                  'operationId': '3658866',
#                  'flushImmediately': False,
#                  'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A3%7C',
#                   'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                   'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#                 {'actionKind': 'NAV',
#                  'actionKinds': ['NAV'],
#                  'operationId': '3658866',
#                  'flushImmediately': False,
#                  'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#                'URL': 'https://www.ebay.com.au/sch/50459/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'}},
#              {'_type': 'CollapsibleGroup',
#               'entries': [{'_type': 'TextualSelection',
#                 'paramValue': '6030',
#                 'label': {'_type': 'TextualDisplay',
#                  'textSpans': [{'_type': 'TextSpan',
#                    'text': 'Car & Truck Parts & Accessories'}]},
#                 'action': {'_type': 'Action',
#                  'type': 'NAV',
#                  'name': 'SEARCH',
#                  'params': {'_dkr': '1',
#                   '_udlo': '',
#                   '_blrs': 'recall_filtering',
#                   '_ssn': 'goodstate',
#                   '_ipg': '240',
#                   'iconV2Request': 'true',
#                   '_stpos': '2019',
#                   'orig_cvip': 'true',
#                   '_nkw': 'blower motor',
#                   '_ul': 'AU',
#                   '_sacat': '6030',
#                   'store_name': 'goodstate',
#                   '_sop': '16',
#                   '_oac': '1',
#                   '_udhi': ''},
#                  'trackingList': [{'eventFamily': 'LST',
#                    'eventAction': 'ACTN',
#                    'actionKind': 'NAVSRC',
#                    'actionKinds': ['NAVSRC'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A4%7C',
#                     'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                     'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#                   {'actionKind': 'NAV',
#                    'actionKinds': ['NAV'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#                  'URL': 'https://www.ebay.com.au/sch/6030/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'}},
#                {'_type': 'TextualSelection',
#                 'paramValue': '177709',
#                 'label': {'_type': 'TextualDisplay',
#                  'textSpans': [{'_type': 'TextSpan',
#                    'text': 'Other Electric, Hybrid & PHEV Car & Truck Specific Parts'}]},
#                 'action': {'_type': 'Action',
#                  'type': 'NAV',
#                  'name': 'SEARCH',
#                  'params': {'_dkr': '1',
#                   '_udlo': '',
#                   '_blrs': 'recall_filtering',
#                   '_ssn': 'goodstate',
#                   '_ipg': '240',
#                   'iconV2Request': 'true',
#                   '_stpos': '2019',
#                   'orig_cvip': 'true',
#                   '_nkw': 'blower motor',
#                   '_ul': 'AU',
#                   '_sacat': '177709',
#                   'store_name': 'goodstate',
#                   '_sop': '16',
#                   '_oac': '1',
#                   '_udhi': ''},
#                  'trackingList': [{'eventFamily': 'LST',
#                    'eventAction': 'ACTN',
#                    'actionKind': 'NAVSRC',
#                    'actionKinds': ['NAVSRC'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A5%7C',
#                     'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                     'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#                   {'actionKind': 'NAV',
#                    'actionKinds': ['NAV'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#                  'URL': 'https://www.ebay.com.au/sch/177709/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'}},
#                {'_type': 'TextualSelection',
#                 'paramValue': '33545',
#                 'label': {'_type': 'TextualDisplay',
#                  'textSpans': [{'_type': 'TextSpan',
#                    'text': 'Car & Truck HVAC Controls & Control Units'}]},
#                 'action': {'_type': 'Action',
#                  'type': 'NAV',
#                  'name': 'SEARCH',
#                  'params': {'_dkr': '1',
#                   '_udlo': '',
#                   '_blrs': 'recall_filtering',
#                   '_ssn': 'goodstate',
#                   '_ipg': '240',
#                   'iconV2Request': 'true',
#                   '_stpos': '2019',
#                   'orig_cvip': 'true',
#                   '_nkw': 'blower motor',
#                   '_ul': 'AU',
#                   '_sacat': '33545',
#                   'store_name': 'goodstate',
#                   '_sop': '16',
#                   '_oac': '1',
#                   '_udhi': ''},
#                  'trackingList': [{'eventFamily': 'LST',
#                    'eventAction': 'ACTN',
#                    'actionKind': 'NAVSRC',
#                    'actionKinds': ['NAVSRC'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A6%7C',
#                     'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                     'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#                   {'actionKind': 'NAV',
#                    'actionKinds': ['NAV'],
#                    'operationId': '3658866',
#                    'flushImmediately': False,
#                    'eventProperty': {'sid': 'p3658866.m4118.l9012'}}],
#                  'URL': 'https://www.ebay.com.au/sch/33545/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019'}}],
#               'expanded': False,
#               'expandLabel': {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'More'}],
#                'accessibilityText': 'More of category'},
#               'collapseLabel': {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Fewer'}],
#                'accessibilityText': 'Less of category'}}]}]}]},
#        {'_type': 'Group',
#         'fieldId': 'loyaltyprograms',
#         'selectionType': 'SINGLE',
#         'expandInline': True,
#         'entries': [{'_type': 'IconField',
#           'paramKey': 'LH_EbayPlus',
#           'paramValue': '1',
#           'uxComponentHint': 'CHECKBOX',
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             'LH_EbayPlus': '1',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cli%3A8173%7Cluid%3A8%7Cselected%3A1%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c1'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_EbayPlus=1'},
#           'iconDisplayType': {'_type': 'IconDisplayType',
#            'icon': 'EBAY_PLUS',
#            'accessibilityText': 'eBay Plus',
#            'toolTipText': 'Free Express Delivery to metro areas on millions of eBay Plus items'}}]},
#        {'_type': 'Group',
#         'fieldId': 'price',
#         'label': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Price'}]},
#         'selectionType': 'MULTIPLE',
#         'expandInline': True,
#         'entries': [{'_type': 'RangeValueSelection',
#           'paramValueType': 'STRING',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Under AU $50.00'}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': '50'},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_PRICE_RANGE%7Cli%3A8173%7Cluid%3A9%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c1'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_ul=AU&_stpos=2019&rt=nc&_udhi=50'},
#           'endParamKey': '_udhi',
#           'endParamValue': '50'},
#          {'_type': 'RangeValueSelection',
#           'paramValueType': 'STRING',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': 'AU $50.00 to AU $110.00'}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '50',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': '110'},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_PRICE_RANGE%7Cli%3A8173%7Cluid%3A10%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c2'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_ul=AU&_stpos=2019&rt=nc&_udlo=50&_udhi=110'},
#           'beginParamKey': '_udlo',
#           'beginParamValue': '50',
#           'endParamKey': '_udhi',
#           'endParamValue': '110'},
#          {'_type': 'RangeValueSelection',
#           'paramValueType': 'STRING',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Over AU $110.00'}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '110',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1'},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_PRICE_RANGE%7Cli%3A8173%7Cluid%3A11%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c3'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_ul=AU&_stpos=2019&rt=nc&_udlo=110'},
#           'beginParamKey': '_udlo',
#           'beginParamValue': '110'},
#          {'_type': 'PriceRangeEntrySelection',
#           'validations': [{'_type': 'CurrencyValidation',
#             'message': {'title': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Please provide a valid price range'}]},
#              'messageType': 'ERROR',
#              'displayIcon': True},
#             'required': False,
#             'primitiveType': 'DECIMAL_UNSIGNED',
#             'contentType': 'CUSTOM'}],
#           'beginParamKey': '_udlo',
#           'endParamKey': '_udhi',
#           'beginLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'AU $', 'styles': []}]},
#           'middleLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': 'to ',
#              'styles': ['x-refine__price__label--middle']},
#             {'_type': 'TextSpan',
#              'text': 'AU $',
#              'styles': ['x-refine__price__label--middle']}]},
#           'beginPlaceHolder': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Min'}],
#            'accessibilityText': 'Minimum value in AU $'},
#           'endPlaceHolder': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Max'}],
#            'accessibilityText': 'Maximum value in AU $'},
#           'beginClear': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': 'Clear minimum value'}]},
#           'endClear': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': 'Clear maximum value'}]},
#           'minOnlyAccessoryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Over ${minValue}'}]},
#           'maxOnlyAccessoryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Under ${maxValue}'}]},
#           'minAndMaxAccessoryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': '${minValue} to ${maxValue}'}]},
#           'priceHint': {'_type': 'IconDisplayType',
#            'icon': 'SUBMIT_BUTTON',
#            'action': {'_type': 'Action',
#             'type': 'NAV',
#             'trackingList': [{'eventFamily': 'LST',
#               'eventAction': 'ACTN',
#               'actionKind': 'NAVSRC',
#               'actionKinds': ['NAVSRC'],
#               'operationId': '3658866',
#               'flushImmediately': False,
#               'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cli%3A8316%7Cluid%3A12%7C%7C',
#                'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#              {'actionKind': 'NAV',
#               'actionKinds': ['NAV'],
#               'operationId': '3658866',
#               'flushImmediately': False,
#               'eventProperty': {'sid': 'p3658866.m4118.l8316.c0'}}]},
#            'toolTipText': 'Submit price range'}},
#          {'_type': 'PriceDistributionGraph',
#           'fieldId': 'priceGraph',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Available inventory'}],
#            'accessibilityText': 'Graph of available inventory between AU $0 and AU $1000+'},
#           'uxComponentHint': 'PRICE_DISTRIBUTION_GRAPH',
#           'priceDistributionInfo': [{'_type': 'PriceRangeInfo',
#             'minPrice': 0,
#             'maxPrice': 5,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 5,
#             'maxPrice': 10,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 10,
#             'maxPrice': 15,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 15,
#             'maxPrice': 20,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 20,
#             'maxPrice': 30,
#             'matchCount': 24},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 30,
#             'maxPrice': 40,
#             'matchCount': 30},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 40,
#             'maxPrice': 50,
#             'matchCount': 188},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 50,
#             'maxPrice': 75,
#             'matchCount': 73},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 75,
#             'maxPrice': 100,
#             'matchCount': 4},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 100,
#             'maxPrice': 150,
#             'matchCount': 8},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 150,
#             'maxPrice': 200,
#             'matchCount': 7},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 200,
#             'maxPrice': 250,
#             'matchCount': 17},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 250,
#             'maxPrice': 300,
#             'matchCount': 12},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 300,
#             'maxPrice': 350,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 350,
#             'maxPrice': 400,
#             'matchCount': 3},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 400,
#             'maxPrice': 500,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 500,
#             'maxPrice': 600,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 600,
#             'maxPrice': 700,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 700,
#             'maxPrice': 800,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 800,
#             'maxPrice': 900,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo',
#             'minPrice': 900,
#             'maxPrice': 1000,
#             'matchCount': 0},
#            {'_type': 'PriceRangeInfo', 'minPrice': 1000, 'matchCount': 0}],
#           'priceGraphMinKnob': {'_type': 'IconDisplayType',
#            'action': {'_type': 'Action',
#             'type': 'NAV',
#             'trackingList': [{'eventFamily': 'LST',
#               'eventAction': 'ACTN',
#               'actionKind': 'NAVSRC',
#               'actionKinds': ['NAVSRC'],
#               'operationId': '3658866',
#               'flushImmediately': False,
#               'eventProperty': {'moduledtl': 'mi%3A4118%7Cli%3A8316%7Cluid%3A13%7C%7C',
#                'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                'parentrq': '9c9c73521900a241fb29a6b6fffec43a',
#                'sid': 'p3658866.m4118.l161131'}}]}},
#           'priceGraphMaxKnob': {'_type': 'IconDisplayType',
#            'action': {'_type': 'Action',
#             'type': 'NAV',
#             'trackingList': [{'eventFamily': 'LST',
#               'eventAction': 'ACTN',
#               'actionKind': 'NAVSRC',
#               'actionKinds': ['NAVSRC'],
#               'operationId': '3658866',
#               'flushImmediately': False,
#               'eventProperty': {'moduledtl': 'mi%3A4118%7Cli%3A8316%7Cluid%3A14%7C%7C',
#                'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#                'parentrq': '9c9c73521900a241fb29a6b6fffec43a',
#                'sid': 'p3658866.m4118.l161132'}}]}},
#           'count': 188,
#           'entries': [{'min': 0, 'max': 5, 'count': 0},
#            {'min': 5, 'max': 10, 'count': 0},
#            {'min': 10, 'max': 15, 'count': 0},
#            {'min': 15, 'max': 20, 'count': 0},
#            {'min': 20, 'max': 30, 'count': 24},
#            {'min': 30, 'max': 40, 'count': 30},
#            {'min': 40, 'max': 50, 'count': 188},
#            {'min': 50, 'max': 75, 'count': 73},
#            {'min': 75, 'max': 100, 'count': 4},
#            {'min': 100, 'max': 150, 'count': 8},
#            {'min': 150, 'max': 200, 'count': 7},
#            {'min': 200, 'max': 250, 'count': 17},
#            {'min': 250, 'max': 300, 'count': 12},
#            {'min': 300, 'max': 350, 'count': 0},
#            {'min': 350, 'max': 400, 'count': 3},
#            {'min': 400, 'max': 500, 'count': 0},
#            {'min': 500, 'max': 600, 'count': 0},
#            {'min': 600, 'max': 700, 'count': 0},
#            {'min': 700, 'max': 800, 'count': 0},
#            {'min': 800, 'max': 900, 'count': 0},
#            {'min': 900, 'max': 1000, 'count': 0},
#            {'min': 1000, 'count': 0}],
#           'scale': 0.5319148936170213}]},
#        {'_type': 'Group',
#         'fieldId': 'condition',
#         'paramKey': 'LH_ItemCondition',
#         'label': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Condition'}]},
#         'accessoryLabel': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'see all'}],
#          'accessibilityText': 'see all - Condition - opens dialogue'},
#         'uxComponentHint': 'SINGLE_COLUMN',
#         'action': {'_type': 'Action',
#          'type': 'OPERATION',
#          'name': 'SHOW_OVERLAY',
#          'params': {'_dkr': '1',
#           '_udlo': '',
#           '_fsrp': '1',
#           '_blrs': 'recall_filtering',
#           'rt': 'nc',
#           '_ssn': 'goodstate',
#           '_aspectname': 'condition',
#           '_ipg': '240',
#           'modules': 'SEARCH_REFINEMENTS_MODEL_V2:fa',
#           'iconV2Request': 'true',
#           '_stpos': '2019',
#           'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#           'orig_cvip': 'true',
#           '_nkw': 'blower motor',
#           '_ul': 'AU',
#           'store_name': 'goodstate',
#           '_sop': '16',
#           '_oac': '1',
#           '_udhi': ''},
#          'trackingList': [{'eventFamily': 'LST',
#            'eventAction': 'ACTN',
#            'actionKind': 'SHOWDIALOG',
#            'actionKinds': ['SHOWDIALOG'],
#            'operationId': '3658866',
#            'flushImmediately': False,
#            'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cli%3A8171%7Cluid%3A17%7C%7C',
#             'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#             'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}}],
#          'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=condition&_fsrp=1&pageci=b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26'},
#         'selectionType': 'MULTIPLE',
#         'paramValueDelimiter': '|',
#         'expandInline': True,
#         'needsLoad': True,
#         'entries': [{'_type': 'TextualSelection',
#           'paramValue': '3',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'New'}]},
#           'secondaryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': ' (366)'}],
#            'accessibilityText': ' (366) Items'},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'LH_ItemCondition': '3',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_ItemCondition%7Cli%3A8173%7Cluid%3A15%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'trkp': 'pageci%3Db2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26%2Cparentrq%3D9c9c73521900a241fb29a6b6fffec43a%2Ciid%3D1',
#               'sid': 'p3658866.m4118.c1'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_ItemCondition=3'}}]},
#        {'_type': 'Group',
#         'fieldId': 'format',
#         'label': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Buying format'}]},
#         'selectionType': 'SINGLE',
#         'expandInline': True,
#         'entries': [{'_type': 'TextualSelection',
#           'selected': True,
#           'paramKey': 'LH_All',
#           'paramValue': '1',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'All listings'}]},
#           'secondaryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': ' (366)'}],
#            'accessibilityText': ' (366) Items'},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_All%7Cli%3A8173%7Cluid%3A18%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c1'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc'},
#           'defaultChoice': True},
#          {'_type': 'TextualSelection',
#           'disabled': True,
#           'paramKey': 'LH_Auction',
#           'paramValue': '1',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Auction'}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             'LH_Auction': '1',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_Auction%7Cli%3A8173%7Cluid%3A19%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c2'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_Auction=1'}},
#          {'_type': 'TextualSelection',
#           'paramKey': 'LH_BIN',
#           'paramValue': '1',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Buy It Now'}]},
#           'secondaryLabel': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': ' (366)'}],
#            'accessibilityText': ' (366) Items'},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'LH_BIN': '1',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_BIN%7Cli%3A8173%7Cluid%3A20%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c3'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_BIN=1'}},
#          {'_type': 'TextualSelection',
#           'disabled': True,
#           'paramKey': 'LH_BO',
#           'paramValue': '1',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Accepts offers'}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             'LH_BO': '1',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_BO%7Cli%3A8173%7Cluid%3A21%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p3658866.m4118.c4'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_BO=1'}}]},
#        {'_type': 'Group',
#         'fieldId': 'location',
#         'paramKey': 'LH_PrefLoc',
#         'label': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Item location'}]},
#         'selectionType': 'SINGLE',
#         'expandInline': True,
#         'entries': [{'_type': 'TextualSelection',
#           'selected': True,
#           'paramValue': '98',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan',
#              'text': 'Default',
#              'styles': ['BOLD']}]},
#           'action': {'_type': 'Action',
#            'type': 'NAV',
#            'name': 'SEARCH',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             'rt': 'nc',
#             '_ssn': 'goodstate',
#             'LH_PrefLoc': '98',
#             '_ipg': '240',
#             'iconV2Request': 'true',
#             '_stpos': '2019',
#             'orig_cvip': 'true',
#             '_nkw': 'blower motor',
#             '_ul': 'AU',
#             'store_name': 'goodstate',
#             '_sop': '16',
#             '_oac': '1',
#             '_udhi': ''},
#            'trackingList': [{'eventFamily': 'LST',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'actionKinds': ['NAVSRC'],
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'moduledtl': 'mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3ALH_PrefLoc%7Cli%3A8173%7Cluid%3A22%7C',
#               'pageci': 'b2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26',
#               'parentrq': '9c9c73521900a241fb29a6b6fffec43a'}},
#             {'actionKind': 'NAV',
#              'operationId': '3658866',
#              'flushImmediately': False,
#              'eventProperty': {'trkp': 'pageci%3Db2e0f8a2-3eb7-11ef-b9a7-9ec3ca9c4a26%2Cparentrq%3D9c9c73521900a241fb29a6b6fffec43a%2Ciid%3D1',
#               'sid': 'p3658866.m4118.c1'}}],
#            'URL': 'https://www.ebay.com.au/sch/i.html?_dkr=1&iconV2Request=true&_blrs=recall_filtering&_ssn=goodstate&store_name=goodstate&_oac=1&_nkw=blower+motor&orig_cvip=true&_sop=16&_ipg=240&_udlo=&_udhi=&_ul=AU&_stpos=2019&rt=nc&LH_PrefLoc=98'},
#           'defaultChoice': True},
#          {'_type': 'ShipToLocationField',
#           'fieldId': 'localLoc',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Within'}]},
#           'uxComponentHint': 'SHOW_MIN_VIEW',
#           'action': {'_type': 'Action',
#            'type': 'OPERATION',
#            'name': 'Button',
#            'params': {'_dkr': '1',
#             '_udlo': '',
#             '_blrs': 'recall_filtering',
#             '_ssn': 'goodstate',
#             '_ipg': '240',
# ...
#    'r': ['w', 593, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 593, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 594, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 595, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 596, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 597, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 598, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 599, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 599, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 599, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 600, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 601, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 602, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 603, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 604, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 605, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 605, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 605, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 606, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 607, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 608, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 609, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 610, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 611, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 611, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 611, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 612, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 613, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 614, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 615, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 616, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 617, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 617, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 617, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 618, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 619, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 620, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 621, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 622, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 623, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 623, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 623, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 624, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 625, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 626, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 627, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 628, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 629, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 629, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 629, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 630, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 631, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 632, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 633, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 634, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 635, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 635, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 635, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 636, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 637, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 638, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 639, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 640, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 641, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 641, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 641, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 642, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 643, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 644, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 645, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 646, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 647, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 647, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 647, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 648, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 649, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 650, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 651, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 652, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 653, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 653, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 653, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 654, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 655, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 656, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 657, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 658, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 659, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 659, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 659, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 660, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 661, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 662, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 663, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 664, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 665, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 665, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 665, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 666, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 667, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 668, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 669, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 670, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 671, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 671, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 671, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 672, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 673, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 674, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 675, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 676, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 677, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 677, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 677, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 678, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 679, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 680, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 681, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 682, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 683, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 683, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 683, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 684, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 685, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 686, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 687, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 688, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 689, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 689, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 689, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 690, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 691, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 692, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 693, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 694, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 695, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 695, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 695, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 696, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 697, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 698, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 699, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 700, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 701, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 701, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 701, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 702, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 703, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 704, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 705, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 706, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 707, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 707, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 707, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 708, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 709, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 710, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 711, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 712, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 713, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 713, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 713, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 714, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 715, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 716, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 717, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 718, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 719, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 719, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 719, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 720, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 721, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 722, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 723, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 724, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 725, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 725, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 725, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 726, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 727, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 728, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 729, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 730, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 731, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 731, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 731, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 732, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 733, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 734, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 735, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 736, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 737, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 737, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 737, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 738, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 739, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 740, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 741, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 742, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 743, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 743, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 743, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 744, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 745, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 746, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 747, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 748, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 749, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 749, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 749, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 750, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 751, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 752, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 753, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 754, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 755, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 755, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 755, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 756, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 757, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 758, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 759, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 760, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 761, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 761, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 761, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 762, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 763, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 764, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 765, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 766, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 767, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 767, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 767, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 768, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 769, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 770, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 771, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 772, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 773, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 773, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 773, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 774, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 775, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 776, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 777, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 778, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 779, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 779, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 779, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 780, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 781, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 782, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 783, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 784, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 785, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 785, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 785, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 786, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 787, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 788, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 789, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 790, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 791, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 791, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 791, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 792, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 793, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 794, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 795, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 796, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 797, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 797, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 797, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 798, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 799, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 800, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 801, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 802, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 803, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 803, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 803, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 804, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 805, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 806, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 807, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 808, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   {'l': ['w', 809, 3, 'b', 0, 1, 'tracking'],
#    'r': ['w', 809, 2, 'model', 'icon', 'action', 'trackingList', 0]},
#   {'l': ['w', 809, 3, 'w'], 'r': ['w', 144, 3, 'w']},
#   ...]}

# %%
list_item_number = [w[2]['model']['action']['params']['itemId'].strip() if type(w[2]) == dict and 'model' in w[2] and 'action' in w[2]['model'] and 'params' in w[2]['model']['action'] and 'itemId' in w[2]['model']['action']['params'] else '' for w in json_['o']['w']]
while '' in list_item_number:
    list_item_number.remove('')

list_item_number
# Out:
# ['192511998212',
#  '195660971887',
#  '192557565418',
#  '192470815384',
#  '192470816410',
#  '192335808616',
#  '195656999183',
#  '192469913773',
#  '192399272603',
#  '196084651217',
#  '193432073359',
#  '193432073431',
#  '193432073468',
#  '196084651183',
#  '193432073395',
#  '192461035908',
#  '192461036905',
#  '192461038502',
#  '192461038654',
#  '192461039631',
#  '192461040906',
#  '195669367960',
#  '195669368087',
#  '195669368150',
#  '195669368319',
#  '192560113777',
#  '192461026915',
#  '192461027622',
#  '192461039242',
#  '195669368019',
#  '195669368239',
#  '192560112952',
#  '193432059946',
#  '195928542832',
#  '195928542862',
#  '195928542927',
#  '192516260600',
#  '192516260816',
#  '195928543010',
#  '194938756574',
#  '194938756689',
#  '194938756808',
#  '194938757135',
#  '194938757506',
#  '194938757744',
#  '194938757980',
#  '194990689095',
#  '193803512984',
#  '193175262897',
#  '193175262951',
#  '193175263006',
#  '196293105829',
#  '196293105878',
#  '196293105734',
#  '194506476965',
#  '194506477179',
#  '194506477273',
#  '193899806121',
#  '193289285759',
#  '193289285819',
#  '194506476869',
#  '194506476914',
#  '194506477013',
#  '194506477094',
#  '193289285781',
#  '193875361472',
#  '192356096699',
#  '195912288101',
#  '195912288288',
#  '195912288375',
#  '195912288677',
#  '195912288963',
#  '195912289040',
#  '195912289439',
#  '195912289598',
#  '195912290405',
#  '195912290480',
#  '195912289215',
#  '195912289306',
#  '195912289364',
#  '195912289867',
#  '195912290331',
#  '192399335201',
#  '192740490988',
#  '192740491080',
#  '192740491172',
#  '193782164168',
#  '193782164556',
#  '193782164751',
#  '193782165056',
#  '193782165292',
#  '193782165565',
#  '193782165830',
#  '193782166134',
#  '193782166391',
#  '193782168566',
#  '193782169341',
#  '193782167018',
#  '193782169076',
#  '196207288455',
#  '196207288608',
#  '196207288706',
#  '196207288503',
#  '194027540816',
#  '194027542005',
#  '194027543218',
#  '194027544486',
#  '194027545733',
#  '194027546975',
#  '194027547754',
#  '192216977957',
#  '193559447514',
#  '192454006497',
#  '192454006812',
#  '192454007312',
#  '192900365447',
#  '192616758377',
#  '192453239714',
#  '192454006299',
#  '192454006918',
#  '192454007494',
#  '192453241265',
#  '192453241970',
#  '192501585534',
#  '193178089552',
#  '193178089724',
#  '193178089836',
#  '193178089958',
#  '193178089998',
#  '193178090028',
#  '193178089609',
#  '193178090004',
#  '193178090055',
#  '195367098865',
#  '195367099020',
#  '195367098946',
#  '194017993061',
#  '194017993148',
#  '194017993349',
#  '194017993416',
#  '194017993568',
#  '194017993742',
#  '194017993229',
#  '194017993493',
#  '194017993691',
#  '192557551481',
#  '192106546901',
#  '192557552259',
#  '196114728215',
#  '196114728255',
#  '196114728324',
#  '196114728478',
#  '196114728362',
#  '196114728393',
#  '196114728431',
#  '192454738710',
#  '192454738831',
#  '194506449650',
#  '194506449764',
#  '194506449838',
#  '192492586976',
#  '192492591777',
#  '192492592408',
#  '192492593977',
#  '192492595200',
#  '192492595962',
#  '192492596893',
#  '192492597895',
#  '192454736877',
#  '192454738271',
#  '192492587587',
#  '192492595375',
#  '194505504060',
#  '194505504176',
#  '194505504240',
#  '194505504341',
#  '194505504441',
#  '194505504538',
#  '194505504686',
#  '194505504812',
#  '194505504894',
#  '192515176596',
#  '192725480798',
#  '192725481179',
#  '192725481422',
#  '192725482165',
#  '192725483012',
#  '192725483666',
#  '192725484831',
#  '192725485567',
#  '192725486362',
#  '194419257857',
#  '194419258256',
#  '194419258611',
#  '194419259532',
#  '194419260538',
#  '194419260889',
#  '194419261375',
#  '194419262359',
#  '194419263067',
#  '194419263784',
#  '194419264289',
#  '194419266897',
#  '194419268773',
#  '194419269287',
#  '194419270265',
#  '194419270938',
#  '194419271508',
#  '194419272151',
#  '194419272758',
#  '194419273831',
#  '194419274514',
#  '194419275210',
#  '194419275750',
#  '194419276889',
#  '194419277762',
#  '194419278518',
#  '194419279397',
#  '194419281207',
#  '194419282579',
#  '194419283361',
#  '194419284796',
#  '194419288583',
#  '194419289816',
#  '194419291325',
#  '194419292091',
#  '194419293248',
#  '194419294231',
#  '194419295072',
#  '194419296032',
#  '194419296752',
#  '194419298124',
#  '194419298777',
#  '194419299615',
#  '194419303894',
#  '194419305047',
#  '194419305484',
#  '194419305914',
#  '194419306252',
#  '194419306997']

# %%
len(list_item_number) == 0
# Out:
# False

# %%
df_temp = pd.DataFrame({'Market': input_.loc[a, 'Market'],
                        'Page': input_.loc[a, 'Page'],
                        'Page Url': input_.loc[a, 'Page Url'],
                        'No': [i+1 for i in range(len(list_item_number))],
                        'Item Number': list_item_number})

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#     Market  Page                                           Page Url   No  \
# 0       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    1
# 1       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    2
# 2       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    3
# 3       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    4
# 4       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    5
# ..     ...   ...                                                ...  ...
# 235     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  236
# 236     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  237
# 237     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  238
# 238     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  239
# 239     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  240
#
#       Item Number
# 0    192511998212
# 1    195660971887
# 2    192557565418
# 3    192470815384
# 4    192470816410
# ..            ...
# 235  194419305047
# 236  194419305484
# 237  194419305914
# 238  194419306252
# 239  194419306997
#
# [240 rows x 5 columns]

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Market': input_.loc[a, 'Market'],
                             'Page': input_.loc[a, 'Page'],
                             'Page Url': input_.loc[a, 'Page Url']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Page', 'No'],
                                                ascending=[True, True],
                                                ignore_index=True)
    output_correct = output_correct.drop_duplicates(['Item Number'],
                                                    keep='first',
                                                    ignore_index=True)
    output_correct['No'] = [i+1 for i in range(len(output_correct))]
    output_correct.to_excel('./test_menu.xlsx', index=False)

output_correct
# Out:
#     Market  Page                                           Page Url   No  \
# 0       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    1
# 1       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    2
# 2       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    3
# 3       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    4
# 4       AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...    5
# ..     ...   ...                                                ...  ...
# 235     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  236
# 236     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  237
# 237     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  238
# 238     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  239
# 239     AU     1  https://www.ebay.com.au/sch/i.html?_dkr=1&icon...  240
#
#       Item Number
# 0    192511998212
# 1    195660971887
# 2    192557565418
# 3    192470815384
# 4    192470816410
# ..            ...
# 235  194419305047
# 236  194419305484
# 237  194419305914
# 238  194419306252
# 239  194419306997
#
# [240 rows x 5 columns]

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['Page'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel('./test_menu_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
