# %%
computer = 'win'

if computer == 'mac':
    str_chromedriver = '../../../chromedriver'
elif computer == 'win':
    str_chromedriver = '../../../chromedriver.exe'
else:
    print('？？？')
    exit(0)

# = = = = = = = = = = = = = = =

from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

import sys
sys.path.append('../../00.module')
import Proxy
import UA

# = = = = = = = = = = = = = = =

import pandas as pd

df = pd.read_excel('./part.xlsx',
                   header=0,
                   dtype=str).fillna('')

list_part_number = df['Part_Number'].tolist()

print('总数量：' + str(len(list_part_number)))
print()

# = = = = = = = = = = = = = = =

df = pd.DataFrame()

# = = = = = = = = = = = = = = =

import requests
from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for part_number in list_part_number:
    work.put_nowait(part_number)

def crawler():
    global df
    
    while not work.empty():
        part_number = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        status = 'error'
        for _ in range(31):
            try:
                url = 'https://www.mevotech.com/part/' + part_number
                
                resp = requests.get(url,
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = =
                
                html = etree.HTML(str(soup))

                list_vehicle = []
                list_tr = html.xpath('//div[@class="atwm-table-continer"]/table/tbody/tr')
                for tr in list_tr:
                    list_vehicle.append(' '.join(tr.xpath('./td/text()')[:4]))

                vehicle = '\n'.join(list_vehicle)
                
                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'status': 'ok',
                                         'Part_Number': part_number,
                                         'Vehicle': vehicle}])

                status = 'ok'
                    
                break
                
            except:
                time.sleep(1)
                continue
                    
        # = = = = = = = = = = = = = = =

        if status == 'error':
            df_temp = pd.DataFrame([{'status': 'error',
                                     'Part_Number': part_number}])

        # = = = = = = = = = = = = = = =

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        print(part_number + '  <->  [' + status + '] - 剩余数量：' + str(work.qsize()))

# = = = = = = = = = = = = = = =
                
list_task = []
for _ in range(15):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df = df.drop_duplicates(ignore_index=True)
                
print()
print('爬虫输出中')
df.to_excel('./vehicle_' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
print()
print('爬虫结束')
# Out:
# 总数量：64
#
# CMS861198  <->  [ok] - 剩余数量：49
# CMS501187  <->  [ok] - 剩余数量：48
# CMS861104  <->  [ok] - 剩余数量：47
# CMS861200  <->  [ok] - 剩余数量：46
# CMS76166  <->  [ok] - 剩余数量：45
# CMS101360  <->  [ok] - 剩余数量：44
# CMS501058  <->  [ok] - 剩余数量：43
# GS101095  <->  [ok] - 剩余数量：42
# CMK8579  <->  [ok] - 剩余数量：41
# CMS101452  <->  [ok] - 剩余数量：40
# CMS601160  <->  [ok] - 剩余数量：39
# GS101066  <->  [ok] - 剩余数量：38
# GS251165  <->  [ok] - 剩余数量：37
# GS301122  <->  [ok] - 剩余数量：36
# GS401196  <->  [ok] - 剩余数量：35
# GS30186  <->  [ok] - 剩余数量：34
# GS601158  <->  [ok] - 剩余数量：33
# CMS861202  <->  [ok] - 剩余数量：32
# GS501238  <->  [ok] - 剩余数量：31
# GS861162  <->  [ok] - 剩余数量：30
# CMS861196  <->  [ok] - 剩余数量：29
# GS60180  <->  [ok] - 剩余数量：28
# MS101479  <->  [ok] - 剩余数量：27
# MS101472  <->  [ok] - 剩余数量：26
# CMS70181  <->  [ok] - 剩余数量：25
# FA1773  <->  [ok] - 剩余数量：24
# MS101456  <->  [ok] - 剩余数量：23
# MS101391  <->  [ok] - 剩余数量：22
# GS501165  <->  [ok] - 剩余数量：21
# MS401187  <->  [ok] - 剩余数量：20
# MS251182  <->  [ok] - 剩余数量：19
# GS101180  <->  [ok] - 剩余数量：18
# GS601195  <->  [ok] - 剩余数量：17
# MS101481  <->  [ok] - 剩余数量：16
# MS501246  <->  [ok] - 剩余数量：15
# GS501220  <->  [ok] - 剩余数量：14
# MS251227  <->  [ok] - 剩余数量：13
# MS501275  <->  [ok] - 剩余数量：12
# GS101289  <->  [ok] - 剩余数量：11
# MS601214  <->  [ok] - 剩余数量：10
# MS501278  <->  [ok] - 剩余数量：9
# MS701138  <->  [ok] - 剩余数量：8
# MS501247  <->  [ok] - 剩余数量：7
# MS501276  <->  [ok] - 剩余数量：6
# MS801214  <->  [ok] - 剩余数量：5
# MS801143  <->  [ok] - 剩余数量：4
# MS701142  <->  [ok] - 剩余数量：3
# MS251183  <->  [ok] - 剩余数量：2
# MS901230  <->  [ok] - 剩余数量：1
# MS101455  <->  [ok] - 剩余数量：0
# MS861272  <->  [ok] - 剩余数量：0
# MS901229  <->  [ok] - 剩余数量：0
# MS901231  <->  [ok] - 剩余数量：0
# MS861262  <->  [ok] - 剩余数量：0
# MS701137  <->  [ok] - 剩余数量：0
# MS801142  <->  [ok] - 剩余数量：0
# MS601213  <->  [ok] - 剩余数量：0
# MS401186  <->  [ok] - 剩余数量：0
# MS101482  <->  [ok] - 剩余数量：0
# MS501277  <->  [ok] - 剩余数量：0
# MS401198  <->  [ok] - 剩余数量：0
# MS101390  <->  [ok] - 剩余数量：0
# GS301179  <->  [ok] - 剩余数量：0
# MS101466  <->  [ok] - 剩余数量：0
#
# 爬虫输出中
#
# 爬虫结束
# D:\venv\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
