# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/2.part'):
    shutil.rmtree('./file/2.part')

os.makedirs('./file/2.part')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/1.url'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/1.url/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                b = 0
                while True:
                    b += 1
                    
                    try:
                        request_url = input_.loc[a, 'Url']
                        
                        resp = requests.get(request_url,
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            soup = BeautifulSoup(resp.text, 'lxml')
                            html = etree.HTML(str(soup))

                            title = html.xpath('//head/title/text()')[0].strip()
                            break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                subtitle = html.xpath('//h2[@itemprop="brand"]/a/span[@itemprop="name"]/text()')[0].strip()

                # = = = = = = = = = = = = = = =

                part_number = html.xpath('//dd[@itemprop="sku"]/text()')[0].strip()

                # = = = = = = = = = = = = = = =

                type_ = html.xpath('//dd[@data-product-parttype]/text()')[0].strip()

                # = = = = = = = = = = = = = = =

                application_summary = html.xpath('//meta[@name="description"]/@content')[0].strip().removeprefix(f'{subtitle},{type_},').removeprefix(f'{subtitle.title()},{type_},') if html.xpath('//meta[@name="description"]/@content') else ''

                # = = = = = = = = = = = = = = =

                dict_src, list_src = {}, html.xpath('//li[contains(@class, "productView-thumbnail")]/a[@class="productView-thumbnail-link"]/@href')
                for i, src in enumerate(list_src):
                    dict_src[str(i)] = src.strip()
    
                # = = = = = = = = = = = = = = =

                list_dict, dict_count = json.loads(html.xpath('//div[@id="addon"]/@data-custom-fields')[0]), {}
                for dict_ in list_dict:
                    key = dict_['name'].strip()
                    if key in dict_count:
                        dict_count[key] += 1
                    else:
                        dict_count[key] = 1
                
                dict_info, dict_no = {}, {}
                for i, dict_ in enumerate(list_dict):
                    key = dict_['name'].strip()
                    if dict_count[key] == 1:
                        dict_info[str(i)] = {key: dict_['value'].strip()}
                    else:
                        if key in dict_no:
                            dict_no[key] += 1
                        else:
                            dict_no[key] = 1
                        dict_info[str(i)] = {f'''{key}-{dict_no[key]}''': dict_['value'].strip()}
    
                # = = = = = = = = = = = = = = =

                bundle = f'''{resp.text.split('window.__webpack_public_path__ = "')[1].split('";</script>')[0]}theme-bundle.main.js'''

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                                         'Type': type_,
                                         'Part Number': part_number,
                                         'Title': title,
                                         'Subtitle': subtitle,
                                         'Application Summary': application_summary,
                                         'Picture': '',
                                         'Url': input_.loc[a, 'Url'],
                                         'Json_Src': json.dumps(dict_src),
                                         'Json_Info': json.dumps(dict_info),
                                         'Bundle': bundle,
                                         'Auth': ''}])
                
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                df_temp = pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)
                df_temp.loc[0, 'Request_Url'] = request_url
                
                output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'No']}.{request_url}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No'],
                                                    ascending=[True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/2.part/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-part_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/2.part/{file}',
              f'''./file/2.part/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：10
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 4.https://www.cardone.com/product/windshield-wiper-motor-40-10006
# [剩余数量：5] - [当前时间：13:57:21]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 5.https://www.cardone.com/product/windshield-wiper-motor-40-10007
# [剩余数量：4] - [当前时间：13:57:22]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 1.https://www.cardone.com/product/windshield-wiper-motor-40-1000
# [剩余数量：3] - [当前时间：13:57:24]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 6.https://www.cardone.com/product/windshield-wiper-motor-40-10009
# [剩余数量：2] - [当前时间：13:57:26]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 2.https://www.cardone.com/product/windshield-wiper-motor-40-10000
# [剩余数量：1] - [当前时间：13:57:26]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 10.https://www.cardone.com/product/windshield-wiper-motor-40-10015
# [剩余数量：0] - [当前时间：13:57:28]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 3.https://www.cardone.com/product/windshield-wiper-motor-40-10005
# [剩余数量：0] - [当前时间：13:57:28]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 7.https://www.cardone.com/product/windshield-wiper-motor-40-1001
# [剩余数量：0] - [当前时间：13:57:28]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 9.https://www.cardone.com/product/windshield-wiper-motor-40-10014
# [剩余数量：0] - [当前时间：13:57:29]
#
# [状态：ok，尝试次数：1] - 50.00% - crawler_1 > 8.https://www.cardone.com/product/windshield-wiper-motor-40-10013
# [剩余数量：0] - [当前时间：13:57:45]
#
# 输出ing...
#
# 总数量：10
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 2.https://www.cardone.com/product/driveshaft-prop-shaft-65-1001a
# [剩余数量：5] - [当前时间：13:57:47]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 4.https://www.cardone.com/product/driveshaft-prop-shaft-65-1002
# [剩余数量：4] - [当前时间：13:57:48]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 7.https://www.cardone.com/product/driveshaft-prop-shaft-65-1005
# [剩余数量：3] - [当前时间：13:57:50]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 3.https://www.cardone.com/product/driveshaft-prop-shaft-65-1001b
# [剩余数量：2] - [当前时间：13:57:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 1.https://www.cardone.com/product/driveshaft-prop-shaft-65-1000
# [剩余数量：1] - [当前时间：13:57:51]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 8.https://www.cardone.com/product/driveshaft-prop-shaft-65-1006
# [剩余数量：0] - [当前时间：13:57:53]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 9.https://www.cardone.com/product/driveshaft-prop-shaft-65-1007
# [剩余数量：0] - [当前时间：13:57:55]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 6.https://www.cardone.com/product/driveshaft-prop-shaft-65-1004
# [剩余数量：0] - [当前时间：13:57:59]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 5.https://www.cardone.com/product/driveshaft-prop-shaft-65-1003
# [剩余数量：0] - [当前时间：13:58:04]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_2 > 10.https://www.cardone.com/product/driveshaft-prop-shaft-65-1008
# [剩余数量：0] - [当前时间：13:58:06]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 2/2 [00:00<00:00, 3515.76it/s]
# Done ~
