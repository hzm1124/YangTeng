# %%
import os

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

import json

# %%
directory_in = './file/1.part_number'

list_file = [file for file in sorted(os.listdir(directory_in)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_in}/{file}')]
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(f'{directory_in}/{file}',
                                                                       header=0,
                                                                       dtype=str).fillna('')

df_input['No'] = df_input['No'].astype(int)

count_remain = len(df_input)

print(f'总数量：{count_remain}')
print()
df_input
# Out:
# 总数量：727
#       No Part Number                                                Url
# 0      1       16149  https://www.4s.com/en/ecatalog?part=16149&type...
# 1      2       16152  https://www.4s.com/en/ecatalog?part=16152&type...
# 2      3       16155  https://www.4s.com/en/ecatalog?part=16155&type...
# 3      4       44001  https://www.4s.com/en/ecatalog?part=44001&type...
# 4      5       44002  https://www.4s.com/en/ecatalog?part=44002&type...
# ..   ...         ...                                                ...
# 722  723       64181  https://www.4s.com/en/ecatalog?part=64181&type...
# 723  724       64182  https://www.4s.com/en/ecatalog?part=64182&type...
# 724  725       64183  https://www.4s.com/en/ecatalog?part=64183&type...
# 725  726       64184  https://www.4s.com/en/ecatalog?part=64184&type...
# 726  727       64185  https://www.4s.com/en/ecatalog?part=64185&type...
#
# [727 rows x 3 columns]

# %%
(crawler_index, crawler_series) = next(df_input.iterrows())

crawler_index, crawler_series
# Out:
# (0,
#  No                                                             1
#  Part Number                                                16149
#  Url            https://www.4s.com/en/ecatalog?part=16149&type...
#  Name: 0, dtype: object)

# %%
import time

count_retry = 0
while True:
    count_retry += 1
    print(count_retry)
    try:
        url_request, url_check = f'''https://ecatalog.smpcorp.com/v2/fs/api/part/partselect?part={crawler_series['Part Number']}&func=PART&vid=''', crawler_series['Url']

        resp = requests.get(url_request,
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(5, 15))

        if resp.status_code == 200:
            dict_dict = resp.json()

            if dict_dict:
                break
    except KeyboardInterrupt:
        break
    except:
        time.sleep(3)
        continue

dict_dict
# Out:
# 1
# 2
# 3
# {'pd': {'rowId': 1,
#   'site': 'FS',
#   'webBase': '16149',
#   'brand': 'FS',
#   'basePart': '16149',
#   'partDesc_en': 'Evaporator Core /Repair Kit',
#   'partLongDesc_en': 'Evaporator Core Repair Kit w/o Orifice Tube',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 1,
#   'brandLink': None,
#   'imageUrl': None},
#  'pp': {'buyersGuides': [{'basePart': '16149',
#     'buyersGuideId': 21574,
#     'buyersGuideDesc': 'Buick Century (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29502,
#     'buyersGuideDesc': 'Buick Commercial Chassis (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48386,
#     'buyersGuideDesc': 'Buick Electra (90-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11747,
#     'buyersGuideDesc': 'Buick Estate Wagon (83-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48469,
#     'buyersGuideDesc': 'Buick LeSabre (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2,
#     'buyersGuideDesc': 'Buick Opel (79-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2349,
#     'buyersGuideDesc': 'Buick Park Avenue (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 42934,
#     'buyersGuideDesc': 'Buick Reatta (91-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13543,
#     'buyersGuideDesc': 'Buick Regal (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2987,
#     'buyersGuideDesc': 'Buick Riviera (93-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 23997,
#     'buyersGuideDesc': 'Buick Roadmaster (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48652,
#     'buyersGuideDesc': 'Buick Skyhawk (89-82), (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46369,
#     'buyersGuideDesc': 'Buick Skylark (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5660,
#     'buyersGuideDesc': 'Buick Somerset (87-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35478,
#     'buyersGuideDesc': 'Buick Somerset Regal (85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21952,
#     'buyersGuideDesc': 'Cadillac 60 Special (93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21277,
#     'buyersGuideDesc': 'Cadillac Allante (93-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33966,
#     'buyersGuideDesc': 'Cadillac Brougham (92-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38757,
#     'buyersGuideDesc': 'Cadillac Calais (76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48059,
#     'buyersGuideDesc': 'Cadillac Cimarron (88-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8810,
#     'buyersGuideDesc': 'Cadillac Commercial Chassis (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21728,
#     'buyersGuideDesc': 'Cadillac DeVille (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 40576,
#     'buyersGuideDesc': 'Cadillac Eldorado (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27994,
#     'buyersGuideDesc': 'Cadillac Fleetwood (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8110,
#     'buyersGuideDesc': 'Cadillac Seville (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5255,
#     'buyersGuideDesc': 'Chevrolet Astro (94-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 7507,
#     'buyersGuideDesc': 'Chevrolet Bel Air (81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 31097,
#     'buyersGuideDesc': 'Chevrolet Beretta (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 49080,
#     'buyersGuideDesc': 'Chevrolet Blazer (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41455,
#     'buyersGuideDesc': 'Chevrolet C10 (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35453,
#     'buyersGuideDesc': 'Chevrolet C10 Suburban (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20498,
#     'buyersGuideDesc': 'Chevrolet C15 (88-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11286,
#     'buyersGuideDesc': 'Chevrolet C1500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 34460,
#     'buyersGuideDesc': 'Chevrolet C1500 Suburban (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 23394,
#     'buyersGuideDesc': 'Chevrolet C20 (87-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 9053,
#     'buyersGuideDesc': 'Chevrolet C20 Suburban (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43485,
#     'buyersGuideDesc': 'Chevrolet C2500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 15001,
#     'buyersGuideDesc': 'Chevrolet C2500 Suburban (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50270,
#     'buyersGuideDesc': 'Chevrolet C30 (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 14309,
#     'buyersGuideDesc': 'Chevrolet C35 (94-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36130,
#     'buyersGuideDesc': 'Chevrolet C3500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 26954,
#     'buyersGuideDesc': 'Chevrolet Camaro (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51727,
#     'buyersGuideDesc': 'Chevrolet Caprice (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5022,
#     'buyersGuideDesc': 'Chevrolet Cavalier (94-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38166,
#     'buyersGuideDesc': 'Chevrolet Celebrity (90-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20914,
#     'buyersGuideDesc': 'Chevrolet Chevette (87-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29630,
#     'buyersGuideDesc': 'Chevrolet Chevy (94)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5981,
#     'buyersGuideDesc': 'Chevrolet Citation (86-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 45093,
#     'buyersGuideDesc': 'Chevrolet Citation II (85-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2117,
#     'buyersGuideDesc': 'Chevrolet Commercial Chassis (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 39351,
#     'buyersGuideDesc': 'Chevrolet Corsica (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35811,
#     'buyersGuideDesc': 'Chevrolet Corvette (94-84), (82-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6149,
#     'buyersGuideDesc': 'Chevrolet El Camino (87-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43482,
#     'buyersGuideDesc': 'Chevrolet G10 (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 39075,
#     'buyersGuideDesc': 'Chevrolet G20 (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 7754,
#     'buyersGuideDesc': 'Chevrolet G30 (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1513,
#     'buyersGuideDesc': 'Chevrolet Impala (94), (85-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24541,
#     'buyersGuideDesc': 'Chevrolet K10 (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46260,
#     'buyersGuideDesc': 'Chevrolet K10 Suburban (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32391,
#     'buyersGuideDesc': 'Chevrolet K1500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28176,
#     'buyersGuideDesc': 'Chevrolet K1500 Suburban (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20610,
#     'buyersGuideDesc': 'Chevrolet K20 (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41604,
#     'buyersGuideDesc': 'Chevrolet K20 Suburban (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33799,
#     'buyersGuideDesc': 'Chevrolet K2500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47194,
#     'buyersGuideDesc': 'Chevrolet K2500 Suburban (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 44728,
#     'buyersGuideDesc': 'Chevrolet K30 (86-77)'},
#    {'basePart': '16149',
#     'buyersGuideId': 602,
#     'buyersGuideDesc': 'Chevrolet K3500 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43579,
#     'buyersGuideDesc': 'Chevrolet K5 Blazer (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 19985,
#     'buyersGuideDesc': 'Chevrolet Laguna (76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25234,
#     'buyersGuideDesc': 'Chevrolet LLV (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38641,
#     'buyersGuideDesc': 'Chevrolet Lumina (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 26624,
#     'buyersGuideDesc': 'Chevrolet Lumina APV (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51561,
#     'buyersGuideDesc': 'Chevrolet LUV (82-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8856,
#     'buyersGuideDesc': 'Chevrolet Malibu (83-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 49571,
#     'buyersGuideDesc': 'Chevrolet Metro (92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16606,
#     'buyersGuideDesc': 'Chevrolet Monte Carlo (88-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36532,
#     'buyersGuideDesc': 'Chevrolet Monza (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4718,
#     'buyersGuideDesc': 'Chevrolet Nova (88-85), (79-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12124,
#     'buyersGuideDesc': 'Chevrolet P10 (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4473,
#     'buyersGuideDesc': 'Chevrolet P20 (89-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13899,
#     'buyersGuideDesc': 'Chevrolet P30 (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11363,
#     'buyersGuideDesc': 'Chevrolet R10 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47164,
#     'buyersGuideDesc': 'Chevrolet R10 Suburban (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51068,
#     'buyersGuideDesc': 'Chevrolet R1500 Suburban (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 9859,
#     'buyersGuideDesc': 'Chevrolet R20 (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36664,
#     'buyersGuideDesc': 'Chevrolet R20 Suburban (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 39033,
#     'buyersGuideDesc': 'Chevrolet R2500 (89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48358,
#     'buyersGuideDesc': 'Chevrolet R2500 Suburban (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 45169,
#     'buyersGuideDesc': 'Chevrolet R30 (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16778,
#     'buyersGuideDesc': 'Chevrolet R3500 (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41291,
#     'buyersGuideDesc': 'Chevrolet S10 (94-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4813,
#     'buyersGuideDesc': 'Chevrolet S10 Blazer (94-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36949,
#     'buyersGuideDesc': 'Chevrolet Spectrum (88-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28362,
#     'buyersGuideDesc': 'Chevrolet Sprint (92-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3790,
#     'buyersGuideDesc': 'Chevrolet Suburban (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8139,
#     'buyersGuideDesc': 'Chevrolet Tracker (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30636,
#     'buyersGuideDesc': 'Chevrolet V10 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 42098,
#     'buyersGuideDesc': 'Chevrolet V10 Suburban (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13048,
#     'buyersGuideDesc': 'Chevrolet V1500 Suburban (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8923,
#     'buyersGuideDesc': 'Chevrolet V20 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30993,
#     'buyersGuideDesc': 'Chevrolet V20 Suburban (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 49633,
#     'buyersGuideDesc': 'Chevrolet V2500 Suburban (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 40621,
#     'buyersGuideDesc': 'Chevrolet V30 (88-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51787,
#     'buyersGuideDesc': 'Chevrolet V3500 (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16158,
#     'buyersGuideDesc': 'Chevrolet Vega (77-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33819,
#     'buyersGuideDesc': 'Ford Aerostar (94-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48814,
#     'buyersGuideDesc': 'Ford Aspire (94)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29458,
#     'buyersGuideDesc': 'Ford B-100 (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46321,
#     'buyersGuideDesc': 'Ford B-150 (85-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38402,
#     'buyersGuideDesc': 'Ford B-200 (91-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 44660,
#     'buyersGuideDesc': 'Ford B-200 Panel (86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12840,
#     'buyersGuideDesc': 'Ford B-600 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13367,
#     'buyersGuideDesc': 'Ford B-700 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 52096,
#     'buyersGuideDesc': 'Ford Bronco (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46023,
#     'buyersGuideDesc': 'Ford Bronco II (90-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12877,
#     'buyersGuideDesc': 'Ford C800 (89-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24337,
#     'buyersGuideDesc': 'Ford C8000 (90-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27152,
#     'buyersGuideDesc': 'Ford CF6000 (90-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 7400,
#     'buyersGuideDesc': 'Ford CF7000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38083,
#     'buyersGuideDesc': 'Ford CF8000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 15175,
#     'buyersGuideDesc': 'Ford CFT8000 (94-92), (90-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35894,
#     'buyersGuideDesc': 'Ford CL9000 (91-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29535,
#     'buyersGuideDesc': 'Ford CLT9000 (91-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36407,
#     'buyersGuideDesc': 'Ford Cougar (94-90), (88-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10732,
#     'buyersGuideDesc': 'Ford Country Squire (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 40654,
#     'buyersGuideDesc': 'Ford Courier (82-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21939,
#     'buyersGuideDesc': 'Ford Crown Victoria (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43822,
#     'buyersGuideDesc': 'Ford CT8000 (90-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24948,
#     'buyersGuideDesc': 'Ford E-100 Econoline (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48226,
#     'buyersGuideDesc': 'Ford E-100 Econoline Club Wagon (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12401,
#     'buyersGuideDesc': 'Ford E-150 Econoline (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35787,
#     'buyersGuideDesc': 'Ford E-150 Econoline Club Wagon (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46704,
#     'buyersGuideDesc': 'Ford E-250 Econoline (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50824,
#     'buyersGuideDesc': 'Ford E-250 Econoline Club Wagon (91-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 14361,
#     'buyersGuideDesc': 'Ford E-350 Econoline (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30589,
#     'buyersGuideDesc': 'Ford E-350 Econoline Club Wagon (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50278,
#     'buyersGuideDesc': 'Ford Escort (94-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 15359,
#     'buyersGuideDesc': 'Ford EXP (88-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1264,
#     'buyersGuideDesc': 'Ford Explorer (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4029,
#     'buyersGuideDesc': 'Ford F-100 (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5908,
#     'buyersGuideDesc': 'Ford F-150 (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28412,
#     'buyersGuideDesc': 'Ford F-200 (91-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36085,
#     'buyersGuideDesc': 'Ford F-250 (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6904,
#     'buyersGuideDesc': 'Ford F-350 (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51778,
#     'buyersGuideDesc': 'Ford F-53 Motorhome Chassis (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32076,
#     'buyersGuideDesc': 'Ford F-59 Commercial Stripped Chassis (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32946,
#     'buyersGuideDesc': 'Ford F-600 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5781,
#     'buyersGuideDesc': 'Ford F-600 LPO (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43957,
#     'buyersGuideDesc': 'Ford F-700 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 37591,
#     'buyersGuideDesc': 'Ford F-700 LPO (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29873,
#     'buyersGuideDesc': 'Ford F-800 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51182,
#     'buyersGuideDesc': 'Ford Fairmont (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 31877,
#     'buyersGuideDesc': 'Ford Festiva (93-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20879,
#     'buyersGuideDesc': 'Ford Fiesta (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29600,
#     'buyersGuideDesc': 'Ford F-Super Duty (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 14049,
#     'buyersGuideDesc': 'Ford FT800 (90-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5522,
#     'buyersGuideDesc': 'Ford FT900 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24189,
#     'buyersGuideDesc': 'Ford Ghia (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8640,
#     'buyersGuideDesc': 'Ford Granada (82-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35994,
#     'buyersGuideDesc': 'Ford Grand Marquis (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 18127,
#     'buyersGuideDesc': 'Ford L8000 (88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20737,
#     'buyersGuideDesc': 'Ford L8000F (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 31615,
#     'buyersGuideDesc': 'Ford L9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48681,
#     'buyersGuideDesc': 'Ford LA8000F (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 37876,
#     'buyersGuideDesc': 'Ford LA9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 52,
#     'buyersGuideDesc': 'Ford LL9000 (94), (92-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29456,
#     'buyersGuideDesc': 'Ford LLA9000 (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41579,
#     'buyersGuideDesc': 'Ford LLS9000 (94)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38339,
#     'buyersGuideDesc': 'Ford LN7000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 15954,
#     'buyersGuideDesc': 'Ford LN8000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38894,
#     'buyersGuideDesc': 'Ford LN9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 7594,
#     'buyersGuideDesc': 'Ford LNT8000 (89-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 43218,
#     'buyersGuideDesc': 'Ford LNT8000F (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24404,
#     'buyersGuideDesc': 'Ford LNT9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25960,
#     'buyersGuideDesc': 'Ford LS8000 (89-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21576,
#     'buyersGuideDesc': 'Ford LS8000F (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24612,
#     'buyersGuideDesc': 'Ford LS9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13142,
#     'buyersGuideDesc': 'Ford LT8000 (88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3640,
#     'buyersGuideDesc': 'Ford LT8000F (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2835,
#     'buyersGuideDesc': 'Ford LT9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8162,
#     'buyersGuideDesc': 'Ford LTA9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24881,
#     'buyersGuideDesc': 'Ford LTD (86-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 14753,
#     'buyersGuideDesc': 'Ford LTD Crown Victoria (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 9330,
#     'buyersGuideDesc': 'Ford LTL9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2952,
#     'buyersGuideDesc': 'Ford LTLA9000 (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29761,
#     'buyersGuideDesc': 'Ford LTLS9000 (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10259,
#     'buyersGuideDesc': 'Ford LTS8000 (89-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47703,
#     'buyersGuideDesc': 'Ford LTS8000F (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4743,
#     'buyersGuideDesc': 'Ford LTS9000 (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 23813,
#     'buyersGuideDesc': 'Ford Mustang (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 521,
#     'buyersGuideDesc': 'Ford P-350 (94-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46154,
#     'buyersGuideDesc': 'Ford P-600 (94-93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1926,
#     'buyersGuideDesc': 'Ford Pinto (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16951,
#     'buyersGuideDesc': 'Ford Probe (94-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2975,
#     'buyersGuideDesc': 'Ford Ranger (94-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11054,
#     'buyersGuideDesc': 'Ford Sable (94)'},
#    {'basePart': '16149',
#     'buyersGuideId': 31389,
#     'buyersGuideDesc': 'Ford Taurus (94-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12972,
#     'buyersGuideDesc': 'Ford Tempo (94-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 42437,
#     'buyersGuideDesc': 'Ford Thunderbird (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48600,
#     'buyersGuideDesc': 'Ford Topaz (94-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13050,
#     'buyersGuideDesc': 'Geo Tracker (94-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50571,
#     'buyersGuideDesc': 'GMC Astro (88-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25039,
#     'buyersGuideDesc': 'GMC B6000 (91-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 119,
#     'buyersGuideDesc': 'GMC B7 (94-93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13501,
#     'buyersGuideDesc': 'GMC Brigadier (88-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6565,
#     'buyersGuideDesc': 'GMC C15 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46306,
#     'buyersGuideDesc': 'GMC C15 Suburban (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 26539,
#     'buyersGuideDesc': 'GMC C1500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28782,
#     'buyersGuideDesc': 'GMC C1500 Suburban (94-92), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35186,
#     'buyersGuideDesc': 'GMC C25 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38808,
#     'buyersGuideDesc': 'GMC C25 Suburban (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24133,
#     'buyersGuideDesc': 'GMC C2500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16668,
#     'buyersGuideDesc': 'GMC C2500 Suburban (94-92), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12402,
#     'buyersGuideDesc': 'GMC C35 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10563,
#     'buyersGuideDesc': 'GMC C3500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4482,
#     'buyersGuideDesc': 'GMC C3500HD (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3642,
#     'buyersGuideDesc': 'GMC C5000 (90-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3610,
#     'buyersGuideDesc': 'GMC C5000 Topkick (91-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10865,
#     'buyersGuideDesc': 'GMC C6000 (90-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 39344,
#     'buyersGuideDesc': 'GMC C6000 Topkick (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27000,
#     'buyersGuideDesc': 'GMC C7000 (90-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28243,
#     'buyersGuideDesc': 'GMC C7000 Topkick (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33565,
#     'buyersGuideDesc': 'GMC Caballero (87-78)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6108,
#     'buyersGuideDesc': 'GMC G15 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33715,
#     'buyersGuideDesc': 'GMC G1500 (94-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 9246,
#     'buyersGuideDesc': 'GMC G25 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48194,
#     'buyersGuideDesc': 'GMC G2500 (94-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 34703,
#     'buyersGuideDesc': 'GMC G35 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10079,
#     'buyersGuideDesc': 'GMC G3500 (94-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48507,
#     'buyersGuideDesc': 'GMC General (88-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3446,
#     'buyersGuideDesc': 'GMC Jimmy (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29375,
#     'buyersGuideDesc': 'GMC K15 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28946,
#     'buyersGuideDesc': 'GMC K15 Suburban (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13488,
#     'buyersGuideDesc': 'GMC K1500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41749,
#     'buyersGuideDesc': 'GMC K1500 Suburban (94-92), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38255,
#     'buyersGuideDesc': 'GMC K25 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28986,
#     'buyersGuideDesc': 'GMC K25 Suburban (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 18722,
#     'buyersGuideDesc': 'GMC K2500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46702,
#     'buyersGuideDesc': 'GMC K2500 Suburban (94-92), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47795,
#     'buyersGuideDesc': 'GMC K35 (78-77)'},
#    {'basePart': '16149',
#     'buyersGuideId': 31957,
#     'buyersGuideDesc': 'GMC K3500 (94-88), (86-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 23611,
#     'buyersGuideDesc': 'GMC P15 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8538,
#     'buyersGuideDesc': 'GMC P1500 (80-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6312,
#     'buyersGuideDesc': 'GMC P25 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8839,
#     'buyersGuideDesc': 'GMC P2500 (89-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 8271,
#     'buyersGuideDesc': 'GMC P35 (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33691,
#     'buyersGuideDesc': 'GMC P3500 (94-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21365,
#     'buyersGuideDesc': 'GMC P4500 (90-79)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32434,
#     'buyersGuideDesc': 'GMC P60 (90-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1253,
#     'buyersGuideDesc': 'GMC P6000 (94-92), (90-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 23718,
#     'buyersGuideDesc': 'GMC P6500 (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32661,
#     'buyersGuideDesc': 'GMC R1500 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50601,
#     'buyersGuideDesc': 'GMC R1500 Suburban (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27682,
#     'buyersGuideDesc': 'GMC R2500 (89-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30667,
#     'buyersGuideDesc': 'GMC R2500 Suburban (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 34773,
#     'buyersGuideDesc': 'GMC R3500 (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29041,
#     'buyersGuideDesc': 'GMC S15 (90-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 29302,
#     'buyersGuideDesc': 'GMC S15 Jimmy (91-83)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16268,
#     'buyersGuideDesc': 'GMC Safari (94-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25380,
#     'buyersGuideDesc': 'GMC Sonoma (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1046,
#     'buyersGuideDesc': 'GMC Sprint (77-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32067,
#     'buyersGuideDesc': 'GMC Syclone (91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 49828,
#     'buyersGuideDesc': 'GMC Tracker (91-89)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32546,
#     'buyersGuideDesc': 'GMC Transit Bus (87-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 50262,
#     'buyersGuideDesc': 'GMC Typhoon (93-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1081,
#     'buyersGuideDesc': 'GMC V1500 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 41600,
#     'buyersGuideDesc': 'GMC V1500 Suburban (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 19280,
#     'buyersGuideDesc': 'GMC V2500 (87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 19456,
#     'buyersGuideDesc': 'GMC V2500 Suburban (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47960,
#     'buyersGuideDesc': 'GMC V3500 (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 6276,
#     'buyersGuideDesc': 'GMC W4500 Forward (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28092,
#     'buyersGuideDesc': 'GMC W5500 Forward (94-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 45525,
#     'buyersGuideDesc': 'GMC W6500 Forward (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32762,
#     'buyersGuideDesc': 'GMC W7500 Forward (94-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 19248,
#     'buyersGuideDesc': 'GMC Yukon (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30630,
#     'buyersGuideDesc': 'Lincoln Continental (94-82), (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32115,
#     'buyersGuideDesc': 'Lincoln Mark VI (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11718,
#     'buyersGuideDesc': 'Lincoln Mark VII (92-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 39770,
#     'buyersGuideDesc': 'Lincoln Mark VIII (94-93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24590,
#     'buyersGuideDesc': 'Lincoln Town Car (94-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 9341,
#     'buyersGuideDesc': 'Lincoln Versailles (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2546,
#     'buyersGuideDesc': 'Mercury Bobcat (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20739,
#     'buyersGuideDesc': 'Mercury Capri (94-91), (86-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20496,
#     'buyersGuideDesc': 'Mercury Colony Park (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 7310,
#     'buyersGuideDesc': 'Mercury Cougar (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13978,
#     'buyersGuideDesc': 'Mercury Grand Marquis (94-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27521,
#     'buyersGuideDesc': 'Mercury LN7 (83-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 37402,
#     'buyersGuideDesc': 'Mercury Lynx (87-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1619,
#     'buyersGuideDesc': 'Mercury Marquis (86-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 47789,
#     'buyersGuideDesc': 'Mercury Monarch (80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21349,
#     'buyersGuideDesc': 'Mercury Sable (94-86)'},
#    {'basePart': '16149',
#     'buyersGuideId': 13609,
#     'buyersGuideDesc': 'Mercury Topaz (94-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24942,
#     'buyersGuideDesc': 'Mercury Tracer (94-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38502,
#     'buyersGuideDesc': 'Mercury Villager (94-93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 34798,
#     'buyersGuideDesc': 'Mercury Zephyr (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 36694,
#     'buyersGuideDesc': 'Oldsmobile 88 (94-93)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2181,
#     'buyersGuideDesc': 'Oldsmobile 98 (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 46600,
#     'buyersGuideDesc': 'Oldsmobile Achieva (94-92)'},
#    {'basePart': '16149',
#     'buyersGuideId': 18503,
#     'buyersGuideDesc': 'Oldsmobile Bravada (94-91)'},
#    {'basePart': '16149',
#     'buyersGuideId': 30169,
#     'buyersGuideDesc': 'Oldsmobile Calais (87-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 19967,
#     'buyersGuideDesc': 'Oldsmobile Custom Cruiser (92-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 45585,
#     'buyersGuideDesc': 'Oldsmobile Cutlass (94-85), (81-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 4706,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Calais (91-88), (84-78)'},
#    {'basePart': '16149',
#     'buyersGuideId': 40826,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Ciera (94-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 17274,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Cruiser (94-87), (83-80)'},
#    {'basePart': '16149',
#     'buyersGuideId': 27349,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Salon (87-85), (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10866,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Supreme (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25862,
#     'buyersGuideDesc': 'Oldsmobile Cutlass Tiara (76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16944,
#     'buyersGuideDesc': 'Oldsmobile Delta 88 (91-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 45588,
#     'buyersGuideDesc': 'Oldsmobile Firenza (88-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21550,
#     'buyersGuideDesc': 'Oldsmobile Omega (84-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2783,
#     'buyersGuideDesc': 'Oldsmobile Silhouette (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 51440,
#     'buyersGuideDesc': 'Oldsmobile Starfire (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 28633,
#     'buyersGuideDesc': 'Oldsmobile Toronado (92-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 12926,
#     'buyersGuideDesc': 'Pontiac 6000 (91-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 11373,
#     'buyersGuideDesc': 'Pontiac Acadian (87-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 18786,
#     'buyersGuideDesc': 'Pontiac Astre (77-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 38247,
#     'buyersGuideDesc': 'Pontiac Bonneville (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 44783,
#     'buyersGuideDesc': 'Pontiac Catalina (81-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3985,
#     'buyersGuideDesc': 'Pontiac Fiero (88-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 26083,
#     'buyersGuideDesc': 'Pontiac Firebird (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 42537,
#     'buyersGuideDesc': 'Pontiac Firefly (94), (91-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 33201,
#     'buyersGuideDesc': 'Pontiac Grand Am (94-85), (80-78)'},
#    {'basePart': '16149',
#     'buyersGuideId': 1233,
#     'buyersGuideDesc': 'Pontiac Grand LeMans (83-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 5007,
#     'buyersGuideDesc': 'Pontiac Grand Prix (94-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 2433,
#     'buyersGuideDesc': 'Pontiac Grand Safari (78-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20285,
#     'buyersGuideDesc': 'Pontiac J2000 (83-82)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16264,
#     'buyersGuideDesc': 'Pontiac J2000 Sunbird (85-84)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20308,
#     'buyersGuideDesc': 'Pontiac Laurentian (81-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 22610,
#     'buyersGuideDesc': 'Pontiac LeMans (93-88), (81-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 24166,
#     'buyersGuideDesc': 'Pontiac Optima (91-88)'},
#    {'basePart': '16149',
#     'buyersGuideId': 15619,
#     'buyersGuideDesc': 'Pontiac Parisienne (86-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 3561,
#     'buyersGuideDesc': 'Pontiac Phoenix (84-77)'},
#    {'basePart': '16149',
#     'buyersGuideId': 10029,
#     'buyersGuideDesc': 'Pontiac Safari (89-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 35501,
#     'buyersGuideDesc': 'Pontiac Sunbird (94-86), (80-76)'},
#    {'basePart': '16149',
#     'buyersGuideId': 21752,
#     'buyersGuideDesc': 'Pontiac Sunburst (88-85)'},
#    {'basePart': '16149',
#     'buyersGuideId': 32749,
#     'buyersGuideDesc': 'Pontiac Sunrunner (94)'},
#    {'basePart': '16149',
#     'buyersGuideId': 16263,
#     'buyersGuideDesc': 'Pontiac T1000 (87-81)'},
#    {'basePart': '16149',
#     'buyersGuideId': 48584,
#     'buyersGuideDesc': 'Pontiac Tempest (91-87)'},
#    {'basePart': '16149',
#     'buyersGuideId': 25172,
#     'buyersGuideDesc': 'Pontiac Trans Sport (94-90)'},
#    {'basePart': '16149',
#     'buyersGuideId': 20185,
#     'buyersGuideDesc': 'Pontiac Ventura (77-76)'}],
#   'partSpecs': [{'attributeCode': '116',
#     'attributeValue': 17896,
#     'attributeSort': 0,
#     'attributeName_en': 'Description',
#     'siteValue_en': 'Evaporator Cores'},
#    {'attributeCode': '1452',
#     'attributeValue': 26845,
#     'attributeSort': 0,
#     'attributeName_en': 'Warranty',
#     'siteValue_en': '120 days'},
#    {'attributeCode': '1516',
#     'attributeValue': 4951,
#     'attributeSort': 0,
#     'attributeName_en': 'Core Depth Fraction',
#     'siteValue_en': '0'},
#    {'attributeCode': '1534',
#     'attributeValue': 4951,
#     'attributeSort': 0,
#     'attributeName_en': 'Core Height Fraction',
#     'siteValue_en': '0'},
#    {'attributeCode': '1592',
#     'attributeValue': 9541,
#     'attributeSort': 0,
#     'attributeName_en': 'Run  Length IN',
#     'siteValue_en': '1.75'},
#    {'attributeCode': '1595',
#     'attributeValue': 3027,
#     'attributeSort': 0,
#     'attributeName_en': 'Overall Height Fraction',
#     'siteValue_en': '1'},
#    {'attributeCode': '1646',
#     'attributeValue': 4951,
#     'attributeSort': 0,
#     'attributeName_en': 'Core Width Fraction',
#     'siteValue_en': '0'},
#    {'attributeCode': '1750',
#     'attributeValue': 22085,
#     'attributeSort': 0,
#     'attributeName_en': 'Overall Depth Fraction',
#     'siteValue_en': '4-1/2'},
#    {'attributeCode': '1771',
#     'attributeValue': 3027,
#     'attributeSort': 0,
#     'attributeName_en': 'Overall Width Fraction',
#     'siteValue_en': '1'},
#    {'attributeCode': '322',
#     'attributeValue': 462,
#     'attributeSort': 0,
#     'attributeName_en': 'Material',
#     'siteValue_en': 'Aluminum'},
#    {'attributeCode': '512',
#     'attributeValue': 7529,
#     'attributeSort': 0,
#     'attributeName_en': 'Style',
#     'siteValue_en': 'Evaporator Core Repair Kit w/o Orifice Tube'},
#    {'attributeCode': '571',
#     'attributeValue': 16502,
#     'attributeSort': 0,
#     'attributeName_en': 'Type',
#     'siteValue_en': 'Repair Kit'},
#    {'attributeCode': '637',
#     'attributeValue': 10836,
#     'attributeSort': 0,
#     'attributeName_en': 'Orifice Tube?',
#     'siteValue_en': 'w/o Orifice Tube'}],
#   'imageUrls': [],
#   'relatedParts': [],
#   'relatedCategories': None,
#   'fandB': [{'basePart': '16149',
#     'fbId': '8177',
#     'fbDesc': 'Our products are engineered and tested to provide years of trouble free operation.  Backed by over 50 years of mobile a/c experience, fix it once and fix it right with Four Seasons.',
#     'taB_Type': 'F&B Heading',
#     'assetSort': 1,
#     'digiSort': 0},
#    {'basePart': '16149',
#     'fbId': '7883',
#     'fbDesc': 'Core design meets or exceeds OE performance and efficiency',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 1},
#    {'basePart': '16149',
#     'fbId': '8041',
#     'fbDesc': 'Optimized refrigerant flow',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 2},
#    {'basePart': '16149',
#     'fbId': '7836',
#     'fbDesc': 'Application specific design for GM and Ford vehicles',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 3},
#    {'basePart': '16149',
#     'fbId': '8104',
#     'fbDesc': 'Replaces damaged evaporator inlet tube',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 4}],
#   'digiAssests': [{'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'Cleaning The System',
#     'fileURL': 'https://youtube.com/embed/jHg-QilTCAU',
#     'comment_ID': '12093',
#     'comment': 'Cleaning The System',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'Compressor Installation Quick Tip ',
#     'fileURL': 'https://youtube.com/embed/p_VcWHRTlfM',
#     'comment_ID': '138875',
#     'comment': 'Compressor Installation Quick Tip ',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'Impact of Airflow on HVAC Performance',
#     'fileURL': 'https://youtube.com/embed/l-dfJQONdy8',
#     'comment_ID': '138880',
#     'comment': 'Impact of Airflow on HVAC Performance',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'SMP Engineering',
#     'fileURL': 'http://youtube.com/embed/z33qr7b3MWU',
#     'comment_ID': '138882',
#     'comment': 'SMP Engineering',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'SMP Facilities',
#     'fileURL': 'https://youtube.com/embed/LMncDliQK_4',
#     'comment_ID': '138883',
#     'comment': 'SMP Facilities',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'SMP Facilities (Quick Tour)',
#     'fileURL': 'https://youtube.com/embed/mGxHhNBSvjA',
#     'comment_ID': '138884',
#     'comment': 'SMP Facilities (Quick Tour)',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'Temp Testing TXV System ',
#     'fileURL': 'https://youtube.com/embed/wF37ihNBXq8',
#     'comment_ID': '138887',
#     'comment': 'Temp Testing TXV System ',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'Temperature Testing',
#     'fileURL': 'https://youtube.com/embed/KZmg4LeVcCo',
#     'comment_ID': '138888',
#     'comment': 'Temperature Testing',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': '16149',
#     'fileName': 'SMP Mobile Parts App 3.0',
#     'fileURL': 'https://www.youtube.com/watch?v=HvA2lY15M28',
#     'comment_ID': '304016',
#     'comment': 'SMP Mobile Parts App 3.0',
#     'assetSort': 7,
#     'digiSort': 0,
#     'videoImage': None}],
#   'categories': [{'basePart': '16149',
#     'webLayout_ID': 2800,
#     'categoryName_en': 'Evaporator Cores',
#     'prodCategory_ASort': 19600}],
#   'crossRef': None,
#   'completeRepair': {'serviceParts': [],
#    'serviceSpec': [{'serviceName': 'Fuel Filter Flush (Required)'},
#     {'serviceName': 'Oil Change (Required)'}]}}}

# %%
dict_info = {key.strip().title(): value.strip() if type(value) == str else value for key, value in dict_dict['pd'].items() if key not in ['rowId', 'site', 'webBase', 'basePart', 'maxRows'] and value != None}

dict_info
# Out:
# {'Brand': 'FS',
#  'Partdesc_En': 'Evaporator Core /Repair Kit',
#  'Partlongdesc_En': 'Evaporator Core Repair Kit w/o Orifice Tube',
#  'Pop': 'AA',
#  'Qtyeach': 1}

# %%
vehicle = '\n'.join([dict_['buyersGuideDesc'].strip() for dict_ in dict_dict['pp']['buyersGuides']])

print(vehicle)
# Out:
# Buick Century (94-76)
# Buick Commercial Chassis (94-91)
# Buick Electra (90-76)
# Buick Estate Wagon (83-76)
# Buick LeSabre (94-76)
# Buick Opel (79-76)
# Buick Park Avenue (94-91)
# Buick Reatta (91-88)
# Buick Regal (94-76)
# Buick Riviera (93-76)
# Buick Roadmaster (94-91)
# Buick Skyhawk (89-82), (80-76)
# Buick Skylark (94-76)
# Buick Somerset (87-86)
# Buick Somerset Regal (85)
# Cadillac 60 Special (93)
# Cadillac Allante (93-87)
# Cadillac Brougham (92-87)
# Cadillac Calais (76)
# Cadillac Cimarron (88-82)
# Cadillac Commercial Chassis (94-76)
# Cadillac DeVille (94-76)
# Cadillac Eldorado (94-76)
# Cadillac Fleetwood (94-76)
# Cadillac Seville (94-76)
# Chevrolet Astro (94-85)
# Chevrolet Bel Air (81)
# Chevrolet Beretta (94-87)
# Chevrolet Blazer (94-87)
# Chevrolet C10 (86-76)
# Chevrolet C10 Suburban (86-76)
# Chevrolet C15 (88-82)
# Chevrolet C1500 (94-88)
# Chevrolet C1500 Suburban (94-92)
# Chevrolet C20 (87-76)
# Chevrolet C20 Suburban (86-76)
# Chevrolet C2500 (94-88)
# Chevrolet C2500 Suburban (94-92)
# Chevrolet C30 (86-76)
# Chevrolet C35 (94-83)
# Chevrolet C3500 (94-88)
# Chevrolet Camaro (94-76)
# Chevrolet Caprice (94-76)
# Chevrolet Cavalier (94-82)
# Chevrolet Celebrity (90-82)
# Chevrolet Chevette (87-76)
# Chevrolet Chevy (94)
# Chevrolet Citation (86-80)
# Chevrolet Citation II (85-84)
# Chevrolet Commercial Chassis (94-91)
# Chevrolet Corsica (94-87)
# Chevrolet Corvette (94-84), (82-76)
# Chevrolet El Camino (87-76)
# Chevrolet G10 (94-76)
# Chevrolet G20 (94-76)
# Chevrolet G30 (94-76)
# Chevrolet Impala (94), (85-76)
# Chevrolet K10 (86-76)
# Chevrolet K10 Suburban (86-76)
# Chevrolet K1500 (94-88)
# Chevrolet K1500 Suburban (94-92)
# Chevrolet K20 (86-76)
# Chevrolet K20 Suburban (86-76)
# Chevrolet K2500 (94-88)
# Chevrolet K2500 Suburban (94-92)
# Chevrolet K30 (86-77)
# Chevrolet K3500 (94-88)
# Chevrolet K5 Blazer (86-76)
# Chevrolet Laguna (76)
# Chevrolet LLV (94-87)
# Chevrolet Lumina (94-90)
# Chevrolet Lumina APV (94-90)
# Chevrolet LUV (82-76)
# Chevrolet Malibu (83-76)
# Chevrolet Metro (92)
# Chevrolet Monte Carlo (88-76)
# Chevrolet Monza (80-76)
# Chevrolet Nova (88-85), (79-76)
# Chevrolet P10 (80-76)
# Chevrolet P20 (89-76)
# Chevrolet P30 (94-76)
# Chevrolet R10 (87)
# Chevrolet R10 Suburban (88-87)
# Chevrolet R1500 Suburban (91-89)
# Chevrolet R20 (88-87)
# Chevrolet R20 Suburban (88-87)
# Chevrolet R2500 (89)
# Chevrolet R2500 Suburban (91-89)
# Chevrolet R30 (88-87)
# Chevrolet R3500 (91-89)
# Chevrolet S10 (94-82)
# Chevrolet S10 Blazer (94-83)
# Chevrolet Spectrum (88-85)
# Chevrolet Sprint (92-85)
# Chevrolet Suburban (94-87)
# Chevrolet Tracker (91-89)
# Chevrolet V10 (87)
# Chevrolet V10 Suburban (88-87)
# Chevrolet V1500 Suburban (91-89)
# Chevrolet V20 (87)
# Chevrolet V20 Suburban (88-87)
# Chevrolet V2500 Suburban (91-89)
# Chevrolet V30 (88-87)
# Chevrolet V3500 (91-89)
# Chevrolet Vega (77-76)
# Ford Aerostar (94-86)
# Ford Aspire (94)
# Ford B-100 (80)
# Ford B-150 (85-81)
# Ford B-200 (91-85)
# Ford B-200 Panel (86)
# Ford B-600 (94-88)
# Ford B-700 (94-88)
# Ford Bronco (94-80)
# Ford Bronco II (90-84)
# Ford C800 (89-88)
# Ford C8000 (90-88)
# Ford CF6000 (90-88)
# Ford CF7000 (94-88)
# Ford CF8000 (94-88)
# Ford CFT8000 (94-92), (90-88)
# Ford CL9000 (91-88)
# Ford CLT9000 (91-88)
# Ford Cougar (94-90), (88-85)
# Ford Country Squire (91-87)
# Ford Courier (82-80)
# Ford Crown Victoria (94-92)
# Ford CT8000 (90-88)
# Ford E-100 Econoline (83-80)
# Ford E-100 Econoline Club Wagon (83-80)
# Ford E-150 Econoline (94-80)
# Ford E-150 Econoline Club Wagon (94-80)
# Ford E-250 Econoline (94-80)
# Ford E-250 Econoline Club Wagon (91-80)
# Ford E-350 Econoline (94-80)
# Ford E-350 Econoline Club Wagon (94-80)
# Ford Escort (94-81)
# Ford EXP (88-82)
# Ford Explorer (94-91)
# Ford F-100 (83-80)
# Ford F-150 (94-80)
# Ford F-200 (91-86)
# Ford F-250 (94-80)
# Ford F-350 (94-80)
# Ford F-53 Motorhome Chassis (94-88)
# Ford F-59 Commercial Stripped Chassis (94-88)
# Ford F-600 (94-88)
# Ford F-600 LPO (94-90)
# Ford F-700 (94-88)
# Ford F-700 LPO (94-90)
# Ford F-800 (94-88)
# Ford Fairmont (83-80)
# Ford Festiva (93-88)
# Ford Fiesta (80)
# Ford F-Super Duty (94-88)
# Ford FT800 (90-88)
# Ford FT900 (94-88)
# Ford Ghia (94-91)
# Ford Granada (82-80)
# Ford Grand Marquis (94-91)
# Ford L8000 (88)
# Ford L8000F (94-88)
# Ford L9000 (94-88)
# Ford LA8000F (94-91)
# Ford LA9000 (94-88)
# Ford LL9000 (94), (92-88)
# Ford LLA9000 (94-92)
# Ford LLS9000 (94)
# Ford LN7000 (94-88)
# Ford LN8000 (94-88)
# Ford LN9000 (94-88)
# Ford LNT8000 (89-88)
# Ford LNT8000F (94-88)
# Ford LNT9000 (94-88)
# Ford LS8000 (89-88)
# Ford LS8000F (94-88)
# Ford LS9000 (94-88)
# Ford LT8000 (88)
# Ford LT8000F (94-88)
# Ford LT9000 (94-88)
# Ford LTA9000 (94-88)
# Ford LTD (86-80)
# Ford LTD Crown Victoria (91-87)
# Ford LTL9000 (94-88)
# Ford LTLA9000 (94-92)
# Ford LTLS9000 (94-92)
# Ford LTS8000 (89-88)
# Ford LTS8000F (94-88)
# Ford LTS9000 (94-88)
# Ford Mustang (94-80)
# Ford P-350 (94-86)
# Ford P-600 (94-93)
# Ford Pinto (80)
# Ford Probe (94-89)
# Ford Ranger (94-83)
# Ford Sable (94)
# Ford Taurus (94-86)
# Ford Tempo (94-84)
# Ford Thunderbird (94-80)
# Ford Topaz (94-84)
# Geo Tracker (94-89)
# GMC Astro (88-81)
# GMC B6000 (91-80)
# GMC B7 (94-93)
# GMC Brigadier (88-81)
# GMC C15 (78-76)
# GMC C15 Suburban (78-76)
# GMC C1500 (94-88), (86-79)
# GMC C1500 Suburban (94-92), (86-79)
# GMC C25 (78-76)
# GMC C25 Suburban (78-76)
# GMC C2500 (94-88), (86-79)
# GMC C2500 Suburban (94-92), (86-79)
# GMC C35 (78-76)
# GMC C3500 (94-88), (86-79)
# GMC C3500HD (94-91)
# GMC C5000 (90-79)
# GMC C5000 Topkick (91-90)
# GMC C6000 (90-79)
# GMC C6000 Topkick (94-90)
# GMC C7000 (90-79)
# GMC C7000 Topkick (94-90)
# GMC Caballero (87-78)
# GMC G15 (78-76)
# GMC G1500 (94-79)
# GMC G25 (78-76)
# GMC G2500 (94-79)
# GMC G35 (78-76)
# GMC G3500 (94-79)
# GMC General (88-81)
# GMC Jimmy (94-76)
# GMC K15 (78-76)
# GMC K15 Suburban (78-76)
# GMC K1500 (94-88), (86-79)
# GMC K1500 Suburban (94-92), (86-79)
# GMC K25 (78-76)
# GMC K25 Suburban (78-76)
# GMC K2500 (94-88), (86-79)
# GMC K2500 Suburban (94-92), (86-79)
# GMC K35 (78-77)
# GMC K3500 (94-88), (86-79)
# GMC P15 (78-76)
# GMC P1500 (80-79)
# GMC P25 (78-76)
# GMC P2500 (89-79)
# GMC P35 (78-76)
# GMC P3500 (94-79)
# GMC P4500 (90-79)
# GMC P60 (90-83)
# GMC P6000 (94-92), (90-83)
# GMC P6500 (94-92)
# GMC R1500 (87)
# GMC R1500 Suburban (91-87)
# GMC R2500 (89-87)
# GMC R2500 Suburban (91-87)
# GMC R3500 (91-87)
# GMC S15 (90-82)
# GMC S15 Jimmy (91-83)
# GMC Safari (94-85)
# GMC Sonoma (94-91)
# GMC Sprint (77-76)
# GMC Syclone (91)
# GMC Tracker (91-89)
# GMC Transit Bus (87-81)
# GMC Typhoon (93-92)
# GMC V1500 (87)
# GMC V1500 Suburban (91-87)
# GMC V2500 (87)
# GMC V2500 Suburban (91-87)
# GMC V3500 (91-87)
# GMC W4500 Forward (94-92)
# GMC W5500 Forward (94-88)
# GMC W6500 Forward (94-87)
# GMC W7500 Forward (94-84)
# GMC Yukon (94-92)
# Lincoln Continental (94-82), (80)
# Lincoln Mark VI (83-80)
# Lincoln Mark VII (92-84)
# Lincoln Mark VIII (94-93)
# Lincoln Town Car (94-81)
# Lincoln Versailles (80)
# Mercury Bobcat (80)
# Mercury Capri (94-91), (86-80)
# Mercury Colony Park (91-87)
# Mercury Cougar (94-80)
# Mercury Grand Marquis (94-80)
# Mercury LN7 (83-82)
# Mercury Lynx (87-81)
# Mercury Marquis (86-80)
# Mercury Monarch (80)
# Mercury Sable (94-86)
# Mercury Topaz (94-84)
# Mercury Tracer (94-87)
# Mercury Villager (94-93)
# Mercury Zephyr (83-80)
# Oldsmobile 88 (94-93)
# Oldsmobile 98 (94-76)
# Oldsmobile Achieva (94-92)
# Oldsmobile Bravada (94-91)
# Oldsmobile Calais (87-85)
# Oldsmobile Custom Cruiser (92-76)
# Oldsmobile Cutlass (94-85), (81-76)
# Oldsmobile Cutlass Calais (91-88), (84-78)
# Oldsmobile Cutlass Ciera (94-82)
# Oldsmobile Cutlass Cruiser (94-87), (83-80)
# Oldsmobile Cutlass Salon (87-85), (80-76)
# Oldsmobile Cutlass Supreme (94-76)
# Oldsmobile Cutlass Tiara (76)
# Oldsmobile Delta 88 (91-76)
# Oldsmobile Firenza (88-82)
# Oldsmobile Omega (84-76)
# Oldsmobile Silhouette (94-90)
# Oldsmobile Starfire (80-76)
# Oldsmobile Toronado (92-76)
# Pontiac 6000 (91-82)
# Pontiac Acadian (87-76)
# Pontiac Astre (77-76)
# Pontiac Bonneville (94-76)
# Pontiac Catalina (81-76)
# Pontiac Fiero (88-84)
# Pontiac Firebird (94-76)
# Pontiac Firefly (94), (91-85)
# Pontiac Grand Am (94-85), (80-78)
# Pontiac Grand LeMans (83-76)
# Pontiac Grand Prix (94-76)
# Pontiac Grand Safari (78-76)
# Pontiac J2000 (83-82)
# Pontiac J2000 Sunbird (85-84)
# Pontiac Laurentian (81-76)
# Pontiac LeMans (93-88), (81-76)
# Pontiac Optima (91-88)
# Pontiac Parisienne (86-76)
# Pontiac Phoenix (84-77)
# Pontiac Safari (89-87)
# Pontiac Sunbird (94-86), (80-76)
# Pontiac Sunburst (88-85)
# Pontiac Sunrunner (94)
# Pontiac T1000 (87-81)
# Pontiac Tempest (91-87)
# Pontiac Trans Sport (94-90)
# Pontiac Ventura (77-76)

# %%
list_dict, dict_count = dict_dict['pp']['partSpecs'], {}
for dict_ in list_dict:
    key = dict_['attributeName_en'].strip()
    if key in dict_count:
        dict_count[key] += 1
    else:
        dict_count[key] = 1

dict_specification, dict_no = {}, {}
for i, dict_ in enumerate(list_dict):
    key = dict_['attributeName_en'].strip()
    if dict_count[key] == 1:
        dict_specification[str(i)] = {key: dict_['siteValue_en'].strip()}
    else:
        if key in dict_no:
            dict_no[key] += 1
        else:
            dict_no[key] = 1
        dict_specification[str(i)] = {f'{key}-{dict_no[key]}': dict_['siteValue_en'].strip()}

dict_specification
# Out:
# {'0': {'Description': 'Evaporator Cores'},
#  '1': {'Warranty': '120 days'},
#  '2': {'Core Depth Fraction': '0'},
#  '3': {'Core Height Fraction': '0'},
#  '4': {'Run  Length IN': '1.75'},
#  '5': {'Overall Height Fraction': '1'},
#  '6': {'Core Width Fraction': '0'},
#  '7': {'Overall Depth Fraction': '4-1/2'},
#  '8': {'Overall Width Fraction': '1'},
#  '9': {'Material': 'Aluminum'},
#  '10': {'Style': 'Evaporator Core Repair Kit w/o Orifice Tube'},
#  '11': {'Type': 'Repair Kit'},
#  '12': {'Orifice Tube?': 'w/o Orifice Tube'}}

# %%
dict_type, list_dict = {}, dict_dict['pp']['categories']
for i, dict_ in enumerate(list_dict):
    dict_type[str(i)] = dict_['categoryName_en'].strip()

dict_type
# Out:
# {'0': 'Evaporator Cores'}

# %%
list_dict_correct.append({'No': crawler_series['No'],
                          'Part Number': crawler_series['Part Number'],
                          'Vehicle': vehicle,
                          'Picture': '',
                          'Url': crawler_series['Url'],
                          'Json_Type': json.dumps(dict_type),
                          'Json_Info': json.dumps(dict_info),
                          'Json_Specification': json.dumps(dict_specification)})

list_dict_correct
# Out:
# [{'No': 1,
#   'Part Number': '16149',
#   'Vehicle': 'Buick Century (94-76)\nBuick Commercial Chassis (94-91)\nBuick Electra (90-76)\nBuick Estate Wagon (83-76)\nBuick LeSabre (94-76)\nBuick Opel (79-76)\nBuick Park Avenue (94-91)\nBuick Reatta (91-88)\nBuick Regal (94-76)\nBuick Riviera (93-76)\nBuick Roadmaster (94-91)\nBuick Skyhawk (89-82), (80-76)\nBuick Skylark (94-76)\nBuick Somerset (87-86)\nBuick Somerset Regal (85)\nCadillac 60 Special (93)\nCadillac Allante (93-87)\nCadillac Brougham (92-87)\nCadillac Calais (76)\nCadillac Cimarron (88-82)\nCadillac Commercial Chassis (94-76)\nCadillac DeVille (94-76)\nCadillac Eldorado (94-76)\nCadillac Fleetwood (94-76)\nCadillac Seville (94-76)\nChevrolet Astro (94-85)\nChevrolet Bel Air (81)\nChevrolet Beretta (94-87)\nChevrolet Blazer (94-87)\nChevrolet C10 (86-76)\nChevrolet C10 Suburban (86-76)\nChevrolet C15 (88-82)\nChevrolet C1500 (94-88)\nChevrolet C1500 Suburban (94-92)\nChevrolet C20 (87-76)\nChevrolet C20 Suburban (86-76)\nChevrolet C2500 (94-88)\nChevrolet C2500 Suburban (94-92)\nChevrolet C30 (86-76)\nChevrolet C35 (94-83)\nChevrolet C3500 (94-88)\nChevrolet Camaro (94-76)\nChevrolet Caprice (94-76)\nChevrolet Cavalier (94-82)\nChevrolet Celebrity (90-82)\nChevrolet Chevette (87-76)\nChevrolet Chevy (94)\nChevrolet Citation (86-80)\nChevrolet Citation II (85-84)\nChevrolet Commercial Chassis (94-91)\nChevrolet Corsica (94-87)\nChevrolet Corvette (94-84), (82-76)\nChevrolet El Camino (87-76)\nChevrolet G10 (94-76)\nChevrolet G20 (94-76)\nChevrolet G30 (94-76)\nChevrolet Impala (94), (85-76)\nChevrolet K10 (86-76)\nChevrolet K10 Suburban (86-76)\nChevrolet K1500 (94-88)\nChevrolet K1500 Suburban (94-92)\nChevrolet K20 (86-76)\nChevrolet K20 Suburban (86-76)\nChevrolet K2500 (94-88)\nChevrolet K2500 Suburban (94-92)\nChevrolet K30 (86-77)\nChevrolet K3500 (94-88)\nChevrolet K5 Blazer (86-76)\nChevrolet Laguna (76)\nChevrolet LLV (94-87)\nChevrolet Lumina (94-90)\nChevrolet Lumina APV (94-90)\nChevrolet LUV (82-76)\nChevrolet Malibu (83-76)\nChevrolet Metro (92)\nChevrolet Monte Carlo (88-76)\nChevrolet Monza (80-76)\nChevrolet Nova (88-85), (79-76)\nChevrolet P10 (80-76)\nChevrolet P20 (89-76)\nChevrolet P30 (94-76)\nChevrolet R10 (87)\nChevrolet R10 Suburban (88-87)\nChevrolet R1500 Suburban (91-89)\nChevrolet R20 (88-87)\nChevrolet R20 Suburban (88-87)\nChevrolet R2500 (89)\nChevrolet R2500 Suburban (91-89)\nChevrolet R30 (88-87)\nChevrolet R3500 (91-89)\nChevrolet S10 (94-82)\nChevrolet S10 Blazer (94-83)\nChevrolet Spectrum (88-85)\nChevrolet Sprint (92-85)\nChevrolet Suburban (94-87)\nChevrolet Tracker (91-89)\nChevrolet V10 (87)\nChevrolet V10 Suburban (88-87)\nChevrolet V1500 Suburban (91-89)\nChevrolet V20 (87)\nChevrolet V20 Suburban (88-87)\nChevrolet V2500 Suburban (91-89)\nChevrolet V30 (88-87)\nChevrolet V3500 (91-89)\nChevrolet Vega (77-76)\nFord Aerostar (94-86)\nFord Aspire (94)\nFord B-100 (80)\nFord B-150 (85-81)\nFord B-200 (91-85)\nFord B-200 Panel (86)\nFord B-600 (94-88)\nFord B-700 (94-88)\nFord Bronco (94-80)\nFord Bronco II (90-84)\nFord C800 (89-88)\nFord C8000 (90-88)\nFord CF6000 (90-88)\nFord CF7000 (94-88)\nFord CF8000 (94-88)\nFord CFT8000 (94-92), (90-88)\nFord CL9000 (91-88)\nFord CLT9000 (91-88)\nFord Cougar (94-90), (88-85)\nFord Country Squire (91-87)\nFord Courier (82-80)\nFord Crown Victoria (94-92)\nFord CT8000 (90-88)\nFord E-100 Econoline (83-80)\nFord E-100 Econoline Club Wagon (83-80)\nFord E-150 Econoline (94-80)\nFord E-150 Econoline Club Wagon (94-80)\nFord E-250 Econoline (94-80)\nFord E-250 Econoline Club Wagon (91-80)\nFord E-350 Econoline (94-80)\nFord E-350 Econoline Club Wagon (94-80)\nFord Escort (94-81)\nFord EXP (88-82)\nFord Explorer (94-91)\nFord F-100 (83-80)\nFord F-150 (94-80)\nFord F-200 (91-86)\nFord F-250 (94-80)\nFord F-350 (94-80)\nFord F-53 Motorhome Chassis (94-88)\nFord F-59 Commercial Stripped Chassis (94-88)\nFord F-600 (94-88)\nFord F-600 LPO (94-90)\nFord F-700 (94-88)\nFord F-700 LPO (94-90)\nFord F-800 (94-88)\nFord Fairmont (83-80)\nFo ...
#   'Picture': '',
#   'Url': 'https://www.4s.com/en/ecatalog?part=16149&type=p&search=s',
#   'Json_Type': '{"0": "Evaporator Cores"}',
#   'Json_Info': '{"Brand": "FS", "Partdesc_En": "Evaporator Core /Repair Kit", "Partlongdesc_En": "Evaporator Core Repair Kit w/o Orifice Tube", "Pop": "AA", "Qtyeach": 1}',
#   'Json_Specification': '{"0": {"Description": "Evaporator Cores"}, "1": {"Warranty": "120 days"}, "2": {"Core Depth Fraction": "0"}, "3": {"Core Height Fraction": "0"}, "4": {"Run  Length IN": "1.75"}, "5": {"Overall Height Fraction": "1"}, "6": {"Core Width Fraction": "0"}, "7": {"Overall Depth Fraction": "4-1/2"}, "8": {"Overall Width Fraction": "1"}, "9": {"Material": "Aluminum"}, "10": {"Style": "Evaporator Core Repair Kit w/o Orifice Tube"}, "11": {"Type": "Repair Kit"}, "12": {"Orifice Tube?": "w/o Orifice Tube"}}'}]

# %%
crawler_status = True

crawler_status
# Out:
# True

# %%
crawler_series['Request_Url'], crawler_series['Check_Url'] = url_request, url_check

list_series_error.append(crawler_series)

list_series_error
# Out:
# [No                                                             1
#  Part Number                                                16149
#  Url            https://www.4s.com/en/ecatalog?part=16149&type...
#  Request_Url    https://ecatalog.smpcorp.com/v2/fs/api/part/pa...
#  Check_Url      https://www.4s.com/en/ecatalog?part=16149&type...
#  Name: 0, dtype: object]

# %%
if list_dict_correct:
    df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['No'],
                                                             ascending=[True],
                                                             ignore_index=True)
    df_correct.to_excel('./test_part.xlsx', index=False)

df_correct
# Out:
#    No Part Number                                            Vehicle Picture  \
# 0   1       16149  Buick Century (94-76)\nBuick Commercial Chassi...
#
#                                                  Url  \
# 0  https://www.4s.com/en/ecatalog?part=16149&type...
#
#                    Json_Type  \
# 0  {"0": "Evaporator Cores"}
#
#                                            Json_Info  \
# 0  {"Brand": "FS", "Partdesc_En": "Evaporator Cor...
#
#                                   Json_Specification
# 0  {"0": {"Description": "Evaporator Cores"}, "1"...

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['No'],
                                                           ascending=[True],
                                                           ignore_index=True)
    df_error.to_excel('./test_part_error.xlsx', index=False)

df_error
# Out:
#    No Part Number                                                Url  \
# 0   1       16149  https://www.4s.com/en/ecatalog?part=16149&type...
#
#                                          Request_Url  \
# 0  https://ecatalog.smpcorp.com/v2/fs/api/part/pa...
#
#                                            Check_Url
# 0  https://www.4s.com/en/ecatalog?part=16149&type...
