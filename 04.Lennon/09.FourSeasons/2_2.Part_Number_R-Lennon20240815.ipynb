# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/2.part_number'):
    shutil.rmtree('./file/2.part_number')

os.makedirs('./file/2.part_number')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./file/input.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        try:    
            output, i = pd.DataFrame(), 0
            while True:
                b = 0
                while True:
                    b += 1
                    
                    try:
                        resp = requests.get(f'''https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=-All-&filterType=n&searchType=p&imageSize=80&start={i*96}&limit=96&sort=3&catFilter={input_.loc[a, 'Type Code']}&yearFilter=-All-&makeFilter=-All-&modelFilter=-All-&engineFilter=-All-&attrCodeFilter=-All-&attrValueFilter=-All-&plkEngineMakeFilter=-All-&plkEngineModelFilter=-All-&plkEngineDispFilter=-All-''',
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                list_json = resp.json()

                # = = = = = = = = = = = = = = =

                if not list_json:
                    raise

                # = = = = = = = = = = = = = = =

                if i == 0:
                    count = list_json[0]['maxRows']

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame({'No': [json_['rowId'] for json_ in list_json],
                                        'Part Number': [json_['basePart'] for json_ in list_json]})

                output = pd.concat([output, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =
    
                if work.qsize() % 100 == 0 and work.qsize() != 0:
                    clear_output()
    
                print(f'''[尝试次数：{b}] - {input_.loc[a, 'No']}.{input_.loc[a, 'Type Code']} > Page {i+1}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')
    
                # = = = = = = = = = = = = = = =

                i += 1

                # = = = = = = = = = = = = = = =

                if len(output) == count:
                    output = output.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
                    
                    output.to_excel(f'''./file/2.part_number/crawler_{input_.loc[a, 'No']}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
                    
                    break
                    
            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(30):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel(f'''./file/part_number_error.xlsx''', index=False)
    print('爬虫存在error')
    print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.part_number'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/2.part_number/{file}',
              f'''./file/2.part_number/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：45
#
# [尝试次数：1] - 6.10650 > Page 1
# [剩余数量：38] - [当前时间：14:43:37]
#
# [尝试次数：1] - 7.1400 > Page 1
# [剩余数量：37] - [当前时间：14:43:37]
#
# [尝试次数：1] - 2.10120 > Page 1
# [剩余数量：36] - [当前时间：14:43:37]
#
# [尝试次数：1] - 5.3300 > Page 1
# [剩余数量：36] - [当前时间：14:43:38]
#
# [尝试次数：1] - 9.1500 > Page 1
# [剩余数量：36] - [当前时间：14:43:38]
#
# [尝试次数：1] - 2.10120 > Page 2
# [剩余数量：36] - [当前时间：14:43:40]
#
# [尝试次数：1] - 8.1501 > Page 1
# [剩余数量：35] - [当前时间：14:43:40]
#
# [尝试次数：1] - 5.3300 > Page 2
# [剩余数量：34] - [当前时间：14:43:41]
#
# [尝试次数：1] - 10.10950 > Page 1
# [剩余数量：34] - [当前时间：14:43:41]
#
# [尝试次数：1] - 5.3300 > Page 3
# [剩余数量：33] - [当前时间：14:43:42]
#
# [尝试次数：1] - 4.1000 > Page 1
# [剩余数量：33] - [当前时间：14:43:42]
#
# [尝试次数：1] - 12.11050 > Page 1
# [剩余数量：33] - [当前时间：14:43:43]
#
# [尝试次数：1] - 11.1600 > Page 1
# [剩余数量：32] - [当前时间：14:43:44]
#
# [尝试次数：1] - 9.1500 > Page 2
# [剩余数量：31] - [当前时间：14:43:44]
#
# [尝试次数：1] - 4.1000 > Page 2
# [剩余数量：31] - [当前时间：14:43:44]
#
# [尝试次数：1] - 14.1904 > Page 1
# [剩余数量：31] - [当前时间：14:43:46]
#
# [尝试次数：1] - 1.18300 > Page 1
# [剩余数量：30] - [当前时间：14:43:46]
#
# [尝试次数：1] - 4.1000 > Page 3
# [剩余数量：30] - [当前时间：14:43:46]
#
# [尝试次数：1] - 15.11350 > Page 1
# [剩余数量：29] - [当前时间：14:43:47]
#
# [尝试次数：1] - 16.1700 > Page 1
# [剩余数量：28] - [当前时间：14:43:48]
#
# [尝试次数：4] - 3.21600 > Page 1
# [剩余数量：27] - [当前时间：14:43:48]
#
# [尝试次数：1] - 1.18300 > Page 2
# [剩余数量：27] - [当前时间：14:43:49]
#
# [尝试次数：1] - 9.1500 > Page 3
# [剩余数量：27] - [当前时间：14:43:49]
#
# [尝试次数：1] - 3.21600 > Page 2
# [剩余数量：27] - [当前时间：14:43:49]
#
# [尝试次数：1] - 13.1903 > Page 1
# [剩余数量：27] - [当前时间：14:43:50]
#
# [尝试次数：1] - 17.1900 > Page 1
# [剩余数量：27] - [当前时间：14:43:50]
#
# [尝试次数：1] - 9.1500 > Page 4
# [剩余数量：26] - [当前时间：14:43:50]
#
# [尝试次数：1] - 18.2000 > Page 1
# [剩余数量：26] - [当前时间：14:43:51]
#
# [尝试次数：1] - 13.1903 > Page 2
# [剩余数量：26] - [当前时间：14:43:51]
#
# [尝试次数：1] - 3.21600 > Page 3
# [剩余数量：25] - [当前时间：14:43:51]
#
# [尝试次数：1] - 1.18300 > Page 3
# [剩余数量：25] - [当前时间：14:43:51]
#
# [尝试次数：1] - 19.11850 > Page 1
# [剩余数量：25] - [当前时间：14:43:52]
#
# [尝试次数：1] - 9.1500 > Page 5
# [剩余数量：24] - [当前时间：14:43:52]
#
# [尝试次数：1] - 18.2000 > Page 2
# [剩余数量：24] - [当前时间：14:43:52]
#
# [尝试次数：1] - 21.5401 > Page 1
# [剩余数量：24] - [当前时间：14:43:53]
#
# [尝试次数：1] - 1.18300 > Page 4
# [剩余数量：24] - [当前时间：14:43:53]
#
# [尝试次数：1] - 18.2000 > Page 3
# [剩余数量：24] - [当前时间：14:43:54]
#
# [尝试次数：1] - 20.32400 > Page 1
# [剩余数量：24] - [当前时间：14:43:55]
#
# [尝试次数：1] - 1.18300 > Page 5
# [剩余数量：24] - [当前时间：14:43:55]
#
# [尝试次数：1] - 9.1500 > Page 6
# [剩余数量：24] - [当前时间：14:43:55]
#
# [尝试次数：1] - 20.32400 > Page 2
# [剩余数量：24] - [当前时间：14:43:55]
#
# [尝试次数：2] - 5.3300 > Page 4
# [剩余数量：23] - [当前时间：14:43:56]
#
# [尝试次数：1] - 3.21600 > Page 4
# [剩余数量：22] - [当前时间：14:43:56]
#
# [尝试次数：1] - 9.1500 > Page 7
# [剩余数量：22] - [当前时间：14:43:56]
#
# [尝试次数：1] - 1.18300 > Page 6
# [剩余数量：22] - [当前时间：14:43:57]
#
# [尝试次数：1] - 22.5400 > Page 1
# [剩余数量：22] - [当前时间：14:43:57]
#
# [尝试次数：1] - 23.15500 > Page 1
# [剩余数量：22] - [当前时间：14:43:58]
#
# [尝试次数：1] - 22.5400 > Page 2
# [剩余数量：21] - [当前时间：14:43:59]
#
# [尝试次数：1] - 1.18300 > Page 7
# [剩余数量：21] - [当前时间：14:43:59]
#
# [尝试次数：1] - 21.5401 > Page 2
# [剩余数量：21] - [当前时间：14:43:59]
#
# [尝试次数：1] - 24.15501 > Page 1
# [剩余数量：21] - [当前时间：14:43:59]
#
# [尝试次数：1] - 3.21600 > Page 5
# [剩余数量：20] - [当前时间：14:43:59]
#
# [尝试次数：1] - 9.1500 > Page 8
# [剩余数量：20] - [当前时间：14:43:59]
#
# [尝试次数：1] - 22.5400 > Page 3
# [剩余数量：20] - [当前时间：14:44:00]
#
# [尝试次数：1] - 18.2000 > Page 4
# [剩余数量：19] - [当前时间：14:44:00]
#
# [尝试次数：1] - 3.21600 > Page 6
# [剩余数量：19] - [当前时间：14:44:00]
#
# [尝试次数：1] - 21.5401 > Page 3
# [剩余数量：18] - [当前时间：14:44:01]
#
# [尝试次数：1] - 1.18300 > Page 8
# [剩余数量：18] - [当前时间：14:44:01]
#
# [尝试次数：1] - 9.1500 > Page 9
# [剩余数量：18] - [当前时间：14:44:02]
#
# [尝试次数：1] - 26.2800 > Page 1
# [剩余数量：18] - [当前时间：14:44:02]
#
# [尝试次数：1] - 21.5401 > Page 4
# [剩余数量：18] - [当前时间：14:44:03]
#
# [尝试次数：1] - 9.1500 > Page 10
# [剩余数量：18] - [当前时间：14:44:03]
#
# [尝试次数：1] - 1.18300 > Page 9
# [剩余数量：17] - [当前时间：14:44:03]
#
# [尝试次数：1] - 26.2800 > Page 2
# [剩余数量：17] - [当前时间：14:44:03]
#
# [尝试次数：1] - 28.3101 > Page 1
# [剩余数量：17] - [当前时间：14:44:04]
#
# [尝试次数：1] - 21.5401 > Page 5
# [剩余数量：16] - [当前时间：14:44:04]
#
# [尝试次数：1] - 27.2901 > Page 1
# [剩余数量：16] - [当前时间：14:44:04]
#
# [尝试次数：1] - 1.18300 > Page 10
# [剩余数量：16] - [当前时间：14:44:05]
#
# [尝试次数：1] - 29.3100 > Page 1
# [剩余数量：16] - [当前时间：14:44:06]
#
# [尝试次数：1] - 1.18300 > Page 11
# [剩余数量：16] - [当前时间：14:44:06]
#
# [尝试次数：1] - 27.2901 > Page 2
# [剩余数量：15] - [当前时间：14:44:06]
#
# [尝试次数：1] - 26.2800 > Page 3
# [剩余数量：15] - [当前时间：14:44:07]
#
# [尝试次数：1] - 29.3100 > Page 2
# [剩余数量：15] - [当前时间：14:44:07]
#
# [尝试次数：1] - 30.3200 > Page 1
# [剩余数量：15] - [当前时间：14:44:07]
#
# [尝试次数：1] - 29.3100 > Page 3
# [剩余数量：14] - [当前时间：14:44:09]
#
# [尝试次数：1] - 27.2901 > Page 3
# [剩余数量：13] - [当前时间：14:44:09]
#
# [尝试次数：1] - 32.20450 > Page 1
# [剩余数量：13] - [当前时间：14:44:11]
#
# [尝试次数：1] - 27.2901 > Page 4
# [剩余数量：13] - [当前时间：14:44:11]
#
# [尝试次数：2] - 25.11800 > Page 1
# [剩余数量：13] - [当前时间：14:44:11]
#
# [尝试次数：1] - 27.2901 > Page 5
# [剩余数量：13] - [当前时间：14:44:13]
#
# [尝试次数：1] - 21.5401 > Page 6
# [剩余数量：13] - [当前时间：14:44:13]
#
# [尝试次数：1] - 26.2800 > Page 4
# [剩余数量：13] - [当前时间：14:44:14]
#
# [尝试次数：1] - 27.2901 > Page 6
# [剩余数量：13] - [当前时间：14:44:14]
#
# [尝试次数：1] - 32.20450 > Page 2
# [剩余数量：13] - [当前时间：14:44:14]
#
# [尝试次数：1] - 27.2901 > Page 7
# [剩余数量：12] - [当前时间：14:44:15]
#
# [尝试次数：1] - 18.2000 > Page 5
# [剩余数量：11] - [当前时间：14:44:16]
#
# [尝试次数：1] - 21.5401 > Page 7
# [剩余数量：11] - [当前时间：14:44:16]
#
# [尝试次数：1] - 18.2000 > Page 6
# [剩余数量：11] - [当前时间：14:44:17]
#
# [尝试次数：1] - 31.3301 > Page 1
# [剩余数量：11] - [当前时间：14:44:17]
#
# [尝试次数：1] - 34.22900 > Page 1
# [剩余数量：11] - [当前时间：14:44:17]
#
# [尝试次数：1] - 33.3800 > Page 1
# [剩余数量：10] - [当前时间：14:44:17]
#
# [尝试次数：1] - 26.2800 > Page 5
# [剩余数量：10] - [当前时间：14:44:18]
#
# [尝试次数：1] - 21.5401 > Page 8
# [剩余数量：10] - [当前时间：14:44:19]
#
# [尝试次数：1] - 35.3900 > Page 1
# [剩余数量：10] - [当前时间：14:44:19]
#
# [尝试次数：1] - 31.3301 > Page 2
# [剩余数量：10] - [当前时间：14:44:20]
#
# [尝试次数：1] - 35.3900 > Page 2
# [剩余数量：10] - [当前时间：14:44:21]
#
# [尝试次数：1] - 33.3800 > Page 2
# [剩余数量：9] - [当前时间：14:44:21]
#
# [尝试次数：1] - 31.3301 > Page 3
# [剩余数量：9] - [当前时间：14:44:22]
#
# [尝试次数：1] - 18.2000 > Page 7
# [剩余数量：9] - [当前时间：14:44:23]
#
# [尝试次数：1] - 36.4000 > Page 1
# [剩余数量：9] - [当前时间：14:44:23]
#
# [尝试次数：1] - 33.3800 > Page 3
# [剩余数量：9] - [当前时间：14:44:23]
#
# [尝试次数：1] - 21.5401 > Page 9
# [剩余数量：9] - [当前时间：14:44:24]
#
# [尝试次数：1] - 33.3800 > Page 4
# [剩余数量：9] - [当前时间：14:44:25]
#
# [尝试次数：1] - 21.5401 > Page 10
# [剩余数量：9] - [当前时间：14:44:26]
#
# [尝试次数：1] - 36.4000 > Page 2
# [剩余数量：8] - [当前时间：14:44:26]
#
# [尝试次数：1] - 33.3800 > Page 5
# [剩余数量：8] - [当前时间：14:44:26]
#
# [尝试次数：1] - 26.2800 > Page 6
# [剩余数量：8] - [当前时间：14:44:26]
#
# [尝试次数：1] - 37.4100 > Page 1
# [剩余数量：8] - [当前时间：14:44:27]
#
# [尝试次数：1] - 33.3800 > Page 6
# [剩余数量：8] - [当前时间：14:44:28]
#
# [尝试次数：1] - 26.2800 > Page 7
# [剩余数量：8] - [当前时间：14:44:28]
#
# [尝试次数：1] - 33.3800 > Page 7
# [剩余数量：8] - [当前时间：14:44:29]
#
# [尝试次数：1] - 36.4000 > Page 3
# [剩余数量：8] - [当前时间：14:44:29]
#
# [尝试次数：1] - 26.2800 > Page 8
# [剩余数量：8] - [当前时间：14:44:30]
#
# [尝试次数：1] - 33.3800 > Page 8
# [剩余数量：7] - [当前时间：14:44:30]
#
# [尝试次数：1] - 38.4400 > Page 1
# [剩余数量：6] - [当前时间：14:44:31]
#
# [尝试次数：1] - 36.4000 > Page 4
# [剩余数量：6] - [当前时间：14:44:31]
#
# [尝试次数：1] - 39.2900 > Page 1
# [剩余数量：6] - [当前时间：14:44:31]
#
# [尝试次数：1] - 38.4400 > Page 2
# [剩余数量：5] - [当前时间：14:44:32]
#
# [尝试次数：1] - 36.4000 > Page 5
# [剩余数量：4] - [当前时间：14:44:33]
#
# [尝试次数：1] - 41.15900 > Page 1
# [剩余数量：4] - [当前时间：14:44:33]
#
# [尝试次数：2] - 31.3301 > Page 4
# [剩余数量：3] - [当前时间：14:44:34]
#
# [尝试次数：1] - 40.22250 > Page 1
# [剩余数量：3] - [当前时间：14:44:34]
#
# [尝试次数：2] - 18.2000 > Page 8
# [剩余数量：3] - [当前时间：14:44:35]
#
# [尝试次数：1] - 40.22250 > Page 2
# [剩余数量：3] - [当前时间：14:44:35]
#
# [尝试次数：1] - 31.3301 > Page 5
# [剩余数量：2] - [当前时间：14:44:36]
#
# [尝试次数：1] - 36.4000 > Page 6
# [剩余数量：2] - [当前时间：14:44:36]
#
# [尝试次数：1] - 43.28750 > Page 1
# [剩余数量：2] - [当前时间：14:44:37]
#
# [尝试次数：1] - 18.2000 > Page 9
# [剩余数量：2] - [当前时间：14:44:37]
#
# [尝试次数：1] - 42.13200 > Page 1
# [剩余数量：2] - [当前时间：14:44:38]
#
# [尝试次数：1] - 36.4000 > Page 7
# [剩余数量：2] - [当前时间：14:44:38]
#
# [尝试次数：1] - 43.28750 > Page 2
# [剩余数量：2] - [当前时间：14:44:38]
#
# [尝试次数：1] - 31.3301 > Page 6
# [剩余数量：2] - [当前时间：14:44:38]
#
# [尝试次数：1] - 42.13200 > Page 2
# [剩余数量：2] - [当前时间：14:44:39]
#
# [尝试次数：1] - 18.2000 > Page 10
# [剩余数量：1] - [当前时间：14:44:39]
#
# [尝试次数：1] - 43.28750 > Page 3
# [剩余数量：0] - [当前时间：14:44:40]
#
# [尝试次数：1] - 31.3301 > Page 7
# [剩余数量：0] - [当前时间：14:44:41]
#
# [尝试次数：1] - 43.28750 > Page 4
# [剩余数量：0] - [当前时间：14:44:41]
#
# [尝试次数：1] - 37.4100 > Page 2
# [剩余数量：0] - [当前时间：14:44:42]
#
# [尝试次数：1] - 37.4100 > Page 3
# [剩余数量：0] - [当前时间：14:44:44]
#
# [尝试次数：1] - 25.11800 > Page 2
# [剩余数量：0] - [当前时间：14:44:45]
#
# [尝试次数：1] - 37.4100 > Page 4
# [剩余数量：0] - [当前时间：14:44:45]
#
# [尝试次数：1] - 45.14100 > Page 1
# [剩余数量：0] - [当前时间：14:44:46]
#
# [尝试次数：1] - 43.28750 > Page 5
# [剩余数量：0] - [当前时间：14:44:46]
#
# [尝试次数：1] - 25.11800 > Page 3
# [剩余数量：0] - [当前时间：14:44:46]
#
# [尝试次数：1] - 37.4100 > Page 5
# [剩余数量：0] - [当前时间：14:44:47]
#
# [尝试次数：1] - 37.4100 > Page 6
# [剩余数量：0] - [当前时间：14:44:49]
#
# [尝试次数：1] - 43.28750 > Page 6
# [剩余数量：0] - [当前时间：14:44:50]
#
# [尝试次数：2] - 44.30250 > Page 1
# [剩余数量：0] - [当前时间：14:44:50]
#
# [尝试次数：1] - 37.4100 > Page 7
# [剩余数量：0] - [当前时间：14:44:51]
#
# [尝试次数：1] - 43.28750 > Page 7
# [剩余数量：0] - [当前时间：14:44:51]
#
# [尝试次数：1] - 25.11800 > Page 4
# [剩余数量：0] - [当前时间：14:44:52]
#
# [尝试次数：1] - 44.30250 > Page 2
# [剩余数量：0] - [当前时间：14:44:52]
#
# [尝试次数：1] - 25.11800 > Page 5
# [剩余数量：0] - [当前时间：14:44:53]
#
# [尝试次数：1] - 36.4000 > Page 8
# [剩余数量：0] - [当前时间：14:44:55]
#
# [尝试次数：1] - 25.11800 > Page 6
# [剩余数量：0] - [当前时间：14:44:55]
#
# [尝试次数：1] - 36.4000 > Page 9
# [剩余数量：0] - [当前时间：14:44:56]
#
# [尝试次数：1] - 25.11800 > Page 7
# [剩余数量：0] - [当前时间：14:44:56]
#
# [尝试次数：1] - 44.30250 > Page 3
# [剩余数量：0] - [当前时间：14:44:57]
#
# [尝试次数：1] - 25.11800 > Page 8
# [剩余数量：0] - [当前时间：14:44:58]
#
# [尝试次数：1] - 25.11800 > Page 9
# [剩余数量：0] - [当前时间：14:44:59]
#
# [尝试次数：1] - 43.28750 > Page 8
# [剩余数量：0] - [当前时间：14:45:07]
#
# [尝试次数：1] - 43.28750 > Page 9
# [剩余数量：0] - [当前时间：14:45:11]
#
# [尝试次数：1] - 43.28750 > Page 10
# [剩余数量：0] - [当前时间：14:45:12]
#
# [尝试次数：1] - 43.28750 > Page 11
# [剩余数量：0] - [当前时间：14:45:17]
#
# [尝试次数：1] - 43.28750 > Page 12
# [剩余数量：0] - [当前时间：14:45:18]
#
# [尝试次数：3] - 36.4000 > Page 10
# [剩余数量：0] - [当前时间：14:45:41]
#
# [尝试次数：1] - 36.4000 > Page 11
# [剩余数量：0] - [当前时间：14:45:42]
#
# [尝试次数：1] - 36.4000 > Page 12
# [剩余数量：0] - [当前时间：14:45:45]
#
# [尝试次数：1] - 36.4000 > Page 13
# [剩余数量：0] - [当前时间：14:45:50]
#
# [尝试次数：2] - 36.4000 > Page 14
# [剩余数量：0] - [当前时间：14:46:08]
#
# [尝试次数：1] - 36.4000 > Page 15
# [剩余数量：0] - [当前时间：14:46:10]
#
# [尝试次数：1] - 36.4000 > Page 16
# [剩余数量：0] - [当前时间：14:46:11]
#
# [尝试次数：1] - 36.4000 > Page 17
# [剩余数量：0] - [当前时间：14:46:12]
#
# [尝试次数：1] - 36.4000 > Page 18
# [剩余数量：0] - [当前时间：14:46:14]
#
# [尝试次数：1] - 36.4000 > Page 19
# [剩余数量：0] - [当前时间：14:46:18]
#
# [尝试次数：1] - 36.4000 > Page 20
# [剩余数量：0] - [当前时间：14:46:20]
#
# [尝试次数：1] - 36.4000 > Page 21
# [剩余数量：0] - [当前时间：14:46:21]
#
# [尝试次数：1] - 36.4000 > Page 22
# [剩余数量：0] - [当前时间：14:46:30]
#
# [尝试次数：1] - 36.4000 > Page 23
# [剩余数量：0] - [当前时间：14:46:33]
#
# [尝试次数：1] - 36.4000 > Page 24
# [剩余数量：0] - [当前时间：14:46:35]
#
# [尝试次数：2] - 36.4000 > Page 25
# [剩余数量：0] - [当前时间：14:46:49]
#
# [尝试次数：1] - 36.4000 > Page 26
# [剩余数量：0] - [当前时间：14:46:52]
#
# [尝试次数：1] - 36.4000 > Page 27
# [剩余数量：0] - [当前时间：14:46:53]
#
# [尝试次数：1] - 36.4000 > Page 28
# [剩余数量：0] - [当前时间：14:46:55]
#
# [尝试次数：1] - 36.4000 > Page 29
# [剩余数量：0] - [当前时间：14:46:56]
#
# [尝试次数：1] - 36.4000 > Page 30
# [剩余数量：0] - [当前时间：14:47:07]
#
# [尝试次数：1] - 36.4000 > Page 31
# [剩余数量：0] - [当前时间：14:47:09]
#
# [尝试次数：1] - 36.4000 > Page 32
# [剩余数量：0] - [当前时间：14:47:18]
#
# [尝试次数：1] - 36.4000 > Page 33
# [剩余数量：0] - [当前时间：14:47:21]
#
# [尝试次数：1] - 36.4000 > Page 34
# [剩余数量：0] - [当前时间：14:47:25]
#
# [尝试次数：1] - 36.4000 > Page 35
# [剩余数量：0] - [当前时间：14:47:28]
#
# 输出ing...
# Progress: 100%|███████████████████████████| 45/45 [00:00<00:00, 11459.15it/s]
# Done ~
