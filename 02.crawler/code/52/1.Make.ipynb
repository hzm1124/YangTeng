# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get('https://www.dongchedi.com/motor/pc/car/brand/all_brand',
                        headers=generate_header(method='requests-win'),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
dict_ = response.json()

dict_
# Out:
# {'prompts': '',
#  'status': 0,
#  'message': 'success',
#  'data': {'brand': [{'type': 1000,
#     'info': {'pinyin': 'A'},
#     'unique_id': 1751092646673387488,
#     'unique_id_str': '1751092646673387488'},
#    {'type': 1001,
#     'info': {'brand_id': 2,
#      'image_url': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
#      'brand_name': '奥迪',
#      'pinyin': 'A',
#      'brand_activity_tag': None,
#      'ad_materiel': None,
#      'discount_tag': None,
#      'business_status': 1,
#      'on_sale_series_count': 35},
#     'unique_id': 1751092646673388103,
#     'unique_id_str': '1751092646673388103'},
#    {'type': 1001,
#     'info': {'brand_id': 242,
#      'image_url': 'https://p3-dcd.byteimg.com/img/tos-cn-i-dcdx/2a02c59e2eec44fbac93a7f1f0179457~tplv-resize:0:0.png',
#      'brand_name': '埃安',
#      'pinyin': 'A',
#      'brand_activity_tag': None,
#      'ad_materiel': None,
#      'discount_tag': None,
# ...

# %%
'message' not in dict_ or dict_['message'] != 'success'
# Out:
# False

# %%
list_dict = dict_['data']['brand']

list_dict
# Out:
# [{'type': 1000,
#   'info': {'pinyin': 'A'},
#   'unique_id': 1751092646673387488,
#   'unique_id_str': '1751092646673387488'},
#  {'type': 1001,
#   'info': {'brand_id': 2,
#    'image_url': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
#    'brand_name': '奥迪',
#    'pinyin': 'A',
#    'brand_activity_tag': None,
#    'ad_materiel': None,
#    'discount_tag': None,
#    'business_status': 1,
#    'on_sale_series_count': 35},
#   'unique_id': 1751092646673388103,
#   'unique_id_str': '1751092646673388103'},
#  {'type': 1001,
#   'info': {'brand_id': 242,
#    'image_url': 'https://p3-dcd.byteimg.com/img/tos-cn-i-dcdx/2a02c59e2eec44fbac93a7f1f0179457~tplv-resize:0:0.png',
#    'brand_name': '埃安',
#    'pinyin': 'A',
#    'brand_activity_tag': None,
#    'ad_materiel': None,
#    'discount_tag': None,
#    'business_status': 1,
#    'on_sale_series_count': 6},
#   'unique_id': 1751092646673388691,
# ...

# %%
not list_dict
# Out:
# False

# %%
list_dict[0]['type'] == 1000
# Out:
# True

# %%
letter = list_dict[0]['info']['pinyin'].strip()

letter
# Out:
# 'A'

# %%
list_dict[1]['type'] == 1001
# Out:
# True

# %%
{'home': 'https://www.dongchedi.com/auto/library-brand/x',
 'make_no': 1,
 'letter': letter,
 'make_code': list_dict[1]['info']['brand_id'],
 'make_src': list_dict[1]['info']['image_url'].strip(),
 'make': list_dict[1]['info']['brand_name'].strip(),
 'model_url': f'''https://www.dongchedi.com/auto/library-brand/{list_dict[1]['info']['brand_id']}''',
 'model_url_2': f'''https://www.dongchedi.com/motor/pc/car/brand/get_brand_series_list?brand_id={list_dict[1]['info']['brand_id']}'''}
# Out:
# {'home': 'https://www.dongchedi.com/auto/library-brand/x',
#  'make_no': 1,
#  'letter': 'A',
#  'make_code': 2,
#  'make_src': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
#  'make': '奥迪',
#  'model_url': 'https://www.dongchedi.com/auto/library-brand/2',
#  'model_url_2': 'https://www.dongchedi.com/motor/pc/car/brand/get_brand_series_list?brand_id=2'}
