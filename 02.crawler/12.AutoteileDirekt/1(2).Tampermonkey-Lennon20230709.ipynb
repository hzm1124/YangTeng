# %%
import os

# %%
list_file = list(os.walk('./menu'))[0][2]
if '.DS_Store' in list_file:
   list_file.remove('.DS_Store')

len(list_file)
# Out:
# 55

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['Part_Number', 'Title', 'Price', 'Url'])

df
# Out:
# Empty DataFrame
# Columns: [Part_Number, Title, Price, Url, Src]
# Index: []

# %%
import json

# %%
for file in list_file:
    print(file)
    with open('./menu/' + file, 'r') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=True)
# Out:
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=49.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=48.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=29.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=15.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=6.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=7.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=14.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=28.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=16.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=5.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=4.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=17.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=13.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=12.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=10.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=38.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=3.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=2.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=39.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=11.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=34.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=20.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=21.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=35.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=23.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=37.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=36.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=22.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=26.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=32.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=9.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=8.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=33.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=27.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=31.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=25.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=19.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=18.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=24.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=30.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=43.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=42.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=40.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=54.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=55.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=41.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=45.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=51.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=50.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=44.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=52.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=46.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=47.txt
# www.autoteiledirekt.de_suche.html_keyword=NISSENS&categories%5B0%5D=447&pg=53.txt

# %%
df.to_excel('./menu.xlsx', index=False)

df
# Out:
#          Part_Number                                              Title  \
# 0     Art. Nr: 89145  Klimakompressor NISSENS SD7V16, 12V, PAG 46, R...
# 1     Art. Nr: 89230  Klimakompressor NISSENS TRS90, 12V, PAG 46, R ...
# 2    Art. Nr: 890618     Klimakompressor NISSENS 5SA09C, PAG 46, R 134a
# 3     Art. Nr: 89161     Klimakompressor NISSENS SD7V16, PAG 46, R 134a
# 4     Art. Nr: 89020    Klimakompressor NISSENS 7SEU17C, PAG 46, R 134a
# ..               ...                                                ...
# 806   Art. Nr: 89132  Klimakompressor NISSENS 10PA17C, 12V, PAG 46, ...
# 807  Art. Nr: 890600  Klimakompressor NISSENS 6SAS14A, 12V, PAG 46 Y...
# 808  Art. Nr: 899919  Klimakompressor NISSENS TM15, 24V, PAG 46, R 134a
# 809  Art. Nr: 890875  Klimakompressor NISSENS SP15, 12V, PAG 46, R 134a
# 810  Art. Nr: 890369    Klimakompressor NISSENS A6, 12V, PAG 46, R 134a
#
#         Price                                                Url  \
# 0    369,72 €  https://www.autoteiledirekt.de/nissens-7023118...
# 1    373,72 €  https://www.autoteiledirekt.de/nissens-7026405...
# 2    374,48 €  https://www.autoteiledirekt.de/nissens-1038275...
# 3    378,48 €  https://www.autoteiledirekt.de/nissens-7743575...
# 4    380,72 €  https://www.autoteiledirekt.de/nissens-7026093...
# ..        ...                                                ...
# 806  578,48 €  https://www.autoteiledirekt.de/nissens-7024154...
# 807  581,24 €  https://www.autoteiledirekt.de/nissens-1038273...
# 808  610,96 €  https://www.autoteiledirekt.de/nissens-7437578...
# 809  611,48 €  https://www.autoteiledirekt.de/nissens-1642966...
# 810  621,72 €  https://www.autoteiledirekt.de/nissens-1038258...
#
#                                                    Src
# 0    https://cdn.autoteiledirekt.de/thumb?id=702311...
# 1    https://cdn.autoteiledirekt.de/thumb?id=702640...
# 2    ......
# 3    ......
# 4    ......
# ..                                                 ...
# 806  ......
# 807  ......
# 808  ......
# 809  ......
# 810  ......
#
# [811 rows x 5 columns]
