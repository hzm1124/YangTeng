# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree
import time

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./menu.xlsx', header=0)
list_url = df_menu['Url'].to_list()

print('总数量：' + str(len(list_url)))
print()

work = Queue()
for url in list_url:
    work.put_nowait(url)

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['Url',
                           'OE_Numbers',
                           'Src',
                           'status'])

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818',
           'https': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        url = work.get_nowait()

        status = 'error'
        for _ in range(31):
            try:
                resp = requests.get(url, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = = = = =
                
                html = etree.HTML(str(soup))
                
                oe = ';'.join(html.xpath('//section[@id="productOE"]/descendant::*/th[@scope="row"]/text()'))
                
                # = = = = = = = = = = = = = = = = = =
                
                src = html.xpath('//img[@id="imgProductMain"]/@src')[0]
                
                # = = = = = = = = = = = = = = = = = =
                
                status = 'ok'
                df_temp = pd.DataFrame([{'Url': url,
                                         'OE_Numbers': oe,
                                         'Src': src,
                                         'status': 'ok'}])
                
                break
            
            except:
                time.sleep(3)
                continue
                    
        # = = = = = = = = = = = = = = = = = =
        
        if status == 'error':
            df_temp = pd.DataFrame([{'Url': url,
                                     'status': 'error'}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')

        print(str(url) +  '  <->  [' + status + '] - 剩余：' + str(work.qsize()))

# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(5):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./crawler.xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：584
#
# https://www.dormanproducts.com/p-87478-264-966.aspx?origin=keyword  <->  [ok] - 剩余：579
# https://www.dormanproducts.com/p-91540-264-5116.aspx?origin=keyword  <->  [ok] - 剩余：578
# https://www.dormanproducts.com/p-87520-264-967.aspx?origin=keyword  <->  [ok] - 剩余：577
# https://www.dormanproducts.com/p-64077-264-990.aspx?origin=keyword  <->  [ok] - 剩余：576
# https://www.dormanproducts.com/p-64949-264-983.aspx?origin=keyword  <->  [ok] - 剩余：575
# https://www.dormanproducts.com/p-54144-264-950.aspx?origin=keyword  <->  [ok] - 剩余：574
# https://www.dormanproducts.com/p-54162-264-978.aspx?origin=keyword  <->  [ok] - 剩余：573
# https://www.dormanproducts.com/p-130378-264-929.aspx?origin=keyword  <->  [ok] - 剩余：572
# https://www.dormanproducts.com/p-47236-264-973.aspx?origin=keyword  <->  [ok] - 剩余：571
# https://www.dormanproducts.com/p-35238-917-026.aspx?origin=keyword  <->  [ok] - 剩余：570
# https://www.dormanproducts.com/p-130382-264-928.aspx?origin=keyword  <->  [ok] - 剩余：569
# https://www.dormanproducts.com/p-135567-264-763.aspx?origin=keyword  <->  [ok] - 剩余：568
# https://www.dormanproducts.com/p-128603-264-932.aspx?origin=keyword  <->  [ok] - 剩余：567
# https://www.dormanproducts.com/p-129669-264-933.aspx?origin=keyword  <->  [ok] - 剩余：566
# https://www.dormanproducts.com/p-127323-264-996.aspx?origin=keyword  <->  [ok] - 剩余：565
# https://www.dormanproducts.com/p-138358-264-997.aspx?origin=keyword  <->  [ok] - 剩余：564
# https://www.dormanproducts.com/p-143622-264-5123.aspx?origin=keyword  <->  [ok] - 剩余：563
# https://www.dormanproducts.com/p-139879-264-5124.aspx?origin=keyword  <->  [ok] - 剩余：562
# KeyboardInterrupt
# 2023-06-15T09:34:41Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 95
#      93     task = gevent.spawn(crawler)
#      94     list_task.append(task)
# ---> 95 gevent.joinall(list_task)
#      97 df.to_excel('./crawler.xlsx', index=False)
#      98 print()
#
# File src/gevent/greenlet.py:1065, in gevent._gevent_cgreenlet.joinall()
#
# File src/gevent/greenlet.py:1075, in gevent._gevent_cgreenlet.joinall()
#
# File src/gevent/_hub_primitives.py:250, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src/gevent/_hub_primitives.py:287, in gevent._gevent_c_hub_primitives.wait_on_objects()
#
# File src/gevent/_hub_primitives.py:185, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src/gevent/_hub_primitives.py:176, in gevent._gevent_c_hub_primitives._WaitIterator.__next__()
#
# File src/gevent/_waiter.py:195, in gevent._gevent_c_waiter.MultipleWaiter.get()
#
# File src/gevent/_waiter.py:154, in gevent._gevent_c_waiter.Waiter.get()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:65, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_gevent_c_greenlet_primitives.pxd:35, in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# KeyboardInterrupt:
