# %%
import os

# %%
list_file = list(os.walk('./crawler_2'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 200

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='进度', ncols=77):
    with open('./crawler_2/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler_2.xlsx', index=False)

df
# Out:
# 进度: 100%|██████████████████████████████| 200/200 [00:00<00:00, 1384.72it/s]
#           ASIN       标识       PASIN                品牌  \
# 0   B07Y8J7MDX           B0CGVM197J          Goodyear
# 0   B0BKQTWN57       AC  B0CHLVLJHR        GrandWheel
# 0   B09SG7CGZS           B0CHLXP8Q5        GrandWheel
# 0   B0C9Q9TY15           B0CGRR5YSY        GrandWheel
# 0   B0BYMQ23QX       A+  B0CB1KZWH1          CHYKORLA
# ..         ...      ...         ...               ...
# 0   B00IOFW55Q    A+;AC  B0BDCVVK2Q  IKON MOTORSPORTS
# 0   B088QN1FFQ  A+;V;AC  B0C7Q445CD        Optimal Co
# 0   B07FYBZ5SC       A+  B0BDDJ3V93  IKON MOTORSPORTS
# 0   B07FSD69WP       A+  B07FSD69WP  IKON MOTORSPORTS
# 0   B07CCKXRQL    A+;AC  B07CCKXRQL  IKON MOTORSPORTS
#
#                                                  品牌链接    大类BSR   BSR增长数  \
# 0   https://www.amazon.com/stores/GOODYEAR/page/2A...   54,459    8,528
# 0   https://www.amazon.com/s/ref=bl_dp_s_web_0?ie=...   19,305   18,364
# 0   https://www.amazon.com/s/ref=bl_dp_s_web_0?ie=...   30,130   14,237
# 0   https://www.amazon.com/s/ref=bl_dp_s_web_0?ie=...  221,048  -56,298
# 0   https://www.amazon.com/CHYKORLA/b/ref=bl_dp_s_...   22,529   94,161
# ..                                                ...      ...      ...
# 0   https://www.amazon.com/stores/IKONMOTORSPORTS/...   45,995   72,818
# 0   https://www.amazon.com/stores/OptimalCo/page/8...   46,945    7,271
# 0   https://www.amazon.com/stores/IKONMOTORSPORTS/...   60,512  219,967
# 0   https://www.amazon.com/stores/IKONMOTORSPORTS/...  115,800  -49,809
# 0   https://www.amazon.com/stores/IKONMOTORSPORTS/...  141,340   15,015
#
#    BSR增长率 父体月销量 父体月销量增长率  ...                                   小类目  \
# 0     16%    89       9%  ...  Side Window Wind Deflectors & Visors
# 0     95%   264     -33%  ...  Side Window Wind Deflectors & Visors
# 0     63%   120     -54%  ...  Side Window Wind Deflectors & Visors
# 0    -25%    42      69%  ...  Side Window Wind Deflectors & Visors
# 0    418%   110     -67%  ...  Side Window Wind Deflectors & Visors
# ..    ...   ...      ...  ...                                   ...
# 0    263%    94     -36%  ...  Side Window Wind Deflectors & Visors
# 0     15%   138     -14%  ...  Side Window Wind Deflectors & Visors
# 0    364%    49     -32%  ...  Side Window Wind Deflectors & Visors
# 0    -43%    68     -28%  ...  Side Window Wind Deflectors & Visors
# 0     11%    26     -21%  ...  Side Window Wind Deflectors & Visors
#
#                                                 小类目链接         重量_1      重量_2  \
# 0   https://www.amazon.com/gp/bestsellers/automoti...  3.31 pounds   1.50 kg
# 0   https://www.amazon.com/gp/bestsellers/automoti...  1.95 pounds  884.50 g
# 0   https://www.amazon.com/gp/bestsellers/automoti...   2.7 pounds   1.22 kg
# 0   https://www.amazon.com/gp/bestsellers/automoti...  2.36 pounds   1.07 kg
# 0   https://www.amazon.com/gp/bestsellers/automoti...  1.65 pounds  748.43 g
# ..                                                ...          ...       ...
# 0   https://www.amazon.com/gp/bestsellers/automoti...     1 pounds  453.59 g
# 0   https://www.amazon.com/gp/bestsellers/automoti...   2.1 pounds  952.54 g
# 0   https://www.amazon.com/gp/bestsellers/automoti...     7 pounds   3.18 kg
# 0   https://www.amazon.com/gp/bestsellers/automoti...     6 pounds   2.72 kg
# 0   https://www.amazon.com/gp/bestsellers/automoti...     6 pounds   2.72 kg
#
#                            体积_1                      体积_2   LQS   变体数  \
# 0     45.39 x 9.76 x 1.3 inches  115.29 x 24.79 x 3.30 cm   9.9   6个
# 0   41.34 x 11.42 x 1.38 inches  105.00 x 29.01 x 3.51 cm   8.5  86个
# 0   45.67 x 10.04 x 1.57 inches  116.00 x 25.50 x 3.99 cm   8.5  88个
# 0   41.34 x 11.42 x 1.38 inches  105.00 x 29.01 x 3.51 cm    --  18个
# 0       41.7 x 7.1 x 1.8 inches  105.92 x 18.03 x 4.57 cm  10.0  19个
# ..                          ...                       ...   ...   ...
# 0             8 x 2 x 42 inches  20.32 x 5.08 x 106.68 cm   9.9   2个
# 0         43 x 5.5 x 1.9 inches  109.22 x 13.97 x 4.83 cm  10.0   4个
# 0             40 x 4 x 3 inches  101.60 x 10.16 x 7.62 cm   9.4   2个
# 0         37 x 5.6 x 1.7 inches   93.98 x 14.22 x 4.32 cm   9.4     无
# 0             35 x 7 x 1 inches   88.90 x 17.78 x 2.54 cm   9.9     无
#
#                                       SKU  卖家数
# 0              Size: For Highlander 14-19   4家
# 0   Size: For Chevrolet TrailBlazer 21-23   1家
# 0       Size: For Toyota Highlander 14-19   2家
# 0            Size: For Kia Sportage 17-22   1家
# 0        Size: For Honda Accord 2003-2007   1家
# ..                                    ...  ...
# 0          Color: Slim Style Smoke/Tinted   2家
# 0       Size: For Ford Explorer 2011-2019   1家
# 0         Color: Mugen Style Smoke/Tinted   2家
# 0                                          NaN
# 0                                          NaN
#
# [200 rows x 36 columns]
