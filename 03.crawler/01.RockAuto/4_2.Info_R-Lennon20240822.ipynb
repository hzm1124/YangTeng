# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/4.info'):
    shutil.rmtree('./file/4.info')

os.makedirs('./file/4.info')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import re

# = = = = = = = = = = = = = = =

import json

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/2.part'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/2.part/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                b = 0
                while True:
                    b += 1

                    try:
                        resp = requests.get(input_.loc[a, 'Info'],
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))
                        
                        if resp.status_code == 200:
                            soup = BeautifulSoup(resp.text, 'lxml')
                            html = etree.HTML(str(soup))
                
                            if html.xpath('//span[@class="la-btn-v"]/text()')[0] == 'Continue Shopping':
                                break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                dict_specification = {}
                list_tr = html.xpath('//table[@class="moreinfotable"]/tr')[1:] if html.xpath('//table[@class="moreinfotable"]/tr') else []
                for i, tr in zip(range(len(list_tr)), list_tr):
                    dict_specification[str(i)] = {}
                
                    list_td = [re.sub(r'<.*?>', '', etree.tostring(text).decode('utf-8')).strip() for text in tr.xpath('./td')]
                    for j, td in zip(range(len(list_td)), list_td):
                        dict_specification[str(i)][str(j)] = td

                # = = = = = = = = = = = = = = =

                dict_kit = {}
                list_tr = html.xpath('//section[contains(@aria-label, "Components") and contains(@aria-label, "kit")]/table/tbody/tr/td/table/tbody[contains(@class, "listing-inner") and (contains(@class, "altrow-b-0") or (contains(@class, "altrow-b-1")))]/tr')
                for i, tr in zip(range(len(list_tr)), list_tr):
                    dict_kit[str(i)] = {}
                
                    list_td = tr.xpath('./td')
                    dict_kit[str(i)]['quantity'] = int(list_td[0].xpath('./text()')[0].strip())
                
                    dict_kit[str(i)]['type'] = list_td[1].xpath('./text()')[0].strip()
                
                    json_ = json.loads(list_td[2].xpath('./@value')[0])
                    dict_kit[str(i)]['type_code'] = json_['parttype']
                    dict_kit[str(i)]['part_code'] = json_['partkey']
                
                    json_2 = json.loads(tr.xpath('./input[contains(@id, "listing_data_supplemental[")]/@value')[0])
                    dict_kit[str(i)]['part_number'] = json_2['partnumber']
                    dict_kit[str(i)]['manufacturer'] = json_2['catalogname']
                
                    dict_kit[str(i)]['url'] = f'''https://www.rockauto.com/en/parts/{dict_kit[str(i)]['manufacturer']},{dict_kit[str(i)]['part_number']},{dict_kit[str(i)]['type']},{dict_kit[str(i)]['type_code']}'''
                
                    list_info = tr.xpath('./div[@class="listing-text-row-moreinfo-truck"]/a[@class="ra-btn ra-btn-moreinfo"]')
                    dict_kit[str(i)]['info'] = list_info[0].xpath('./@href')[0].strip() if list_info else ''
                    dict_kit[str(i)]['info'] = dict_kit[str(i)]['info'] if dict_kit[str(i)]['info'].startswith('https://www.rockauto.com/en/moreinfo.php?') else f'''https://www.rockauto.com/en/moreinfo.php?pk={dict_kit[str(i)]['part_code']}&cc=0&pt={dict_kit[str(i)]['type']}&Lennon=1'''
                
                    dict_src = {}
                    list_src = list_td[3].xpath('./div/input[contains(@id, "jsninlineimg[")]')
                    json_ = json.loads(list_src[0].xpath('./@value')[0]) if list_src else ''
                    if json_ != '':
                        list_src = json_['Slots']
                        for j, src in zip(range(len(list_src)), list_src):
                            dict_src[str(j)] = f'''https://www.rockauto.com{src['ImageData']['Full'].strip()}'''
                        dict_kit[str(i)]['dict_src'] = dict_src

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                                         'Group': input_.loc[a, 'Group'],
                                         'Type': input_.loc[a, 'Type'],
                                         'Type Code': input_.loc[a, 'Type Code'],
                                         'Manufacturer': input_.loc[a, 'Manufacturer'],
                                         'Part Number': input_.loc[a, 'Part Number'],
                                         'Note 1': input_.loc[a, 'Note 1'],
                                         'Json_Note 2': input_.loc[a, 'Json_Note 2'],
                                         'Choose': input_.loc[a, 'Choose'],
                                         'Json_Price': input_.loc[a, 'Json_Price'],
                                         'Vehicle': input_.loc[a, 'Vehicle'],
                                         'OEM': input_.loc[a, 'OEM'],
                                         'Picture': input_.loc[a, 'Picture'],
                                         'Url': input_.loc[a, 'Url'],
                                         'Info': input_.loc[a, 'Info'],
                                         'Json_Src': input_.loc[a, 'Json_Src'],
                                         'Json_Specification': json.dumps(dict_specification),
                                         'Json_Kit': json.dumps(dict_kit),
                                         'Part Code': input_.loc[a, 'Part Code'],
                                         'JOIN_MPNTCPC': input_.loc[a, 'JOIN_MPNTCPC']}])

                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'Type']} > {input_.loc[a, 'Manufacturer']} > {input_.loc[a, 'No']}.{input_.loc[a, 'Part Number']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No'],
                                                    ascending=[True],
                                                    ignore_index=True)
        output_correct.to_excel(f'''./file/4.info/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-info_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/4.info'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/4.info/{file}',
              f'''./file/4.info/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# [状态：ok，尝试次数：19] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 949.MK9910
# [剩余数量：1000] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：124] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 872.MK9389
# [剩余数量：999] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：28] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 916.MK9639
# [剩余数量：998] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：35] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 938.MK9802
# [剩余数量：997] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：29] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 944.MK9852
# [剩余数量：996] - [当前时间：19:27:53]
#
# [状态：ok，尝试次数：89] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 871.MK9385
# [剩余数量：995] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：214] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 782.MK90256
# [剩余数量：994] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 879.MK9457
# [剩余数量：993] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：117] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 875.MK9449
# [剩余数量：992] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 894.MK9529
# [剩余数量：991] - [当前时间：19:27:54]
#
# [状态：ok，尝试次数：18] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 954.MK9915
# [剩余数量：990] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：19] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 955.MK9916
# [剩余数量：989] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：46] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 937.MK9756
# [剩余数量：988] - [当前时间：19:27:55]
#
# [状态：ok，尝试次数：5] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 976.MS10513
# [剩余数量：987] - [当前时间：19:27:56]
#
# [状态：ok，尝试次数：12] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 968.MS10505
# [剩余数量：986] - [当前时间：19:27:56]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 975.MS10511
# [剩余数量：985] - [当前时间：19:27:56]
#
# [状态：ok，尝试次数：20] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 970.MS10507
# [剩余数量：984] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：8] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 973.MS10510
# [剩余数量：983] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：8] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 969.MS10506
# [剩余数量：982] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：32] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 953.MK9914
# [剩余数量：981] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：61] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 926.MK9699
# [剩余数量：980] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：15] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 952.MK9913
# [剩余数量：979] - [当前时间：19:27:57]
#
# [状态：ok，尝试次数：39] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 961.MK9967
# [剩余数量：978] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：69] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 932.MK9742
# [剩余数量：977] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：88] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 936.MK9755
# [剩余数量：976] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：115] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 888.MK9509
# [剩余数量：975] - [当前时间：19:27:58]
#
# [状态：ok，尝试次数：65] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 948.MK9908
# [剩余数量：974] - [当前时间：19:27:59]
#
# [状态：ok，尝试次数：5] - 100.00% - crawler_5 > Ball Joint > MEVOTECH >
- 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1309.TXMS25506
# [剩余数量：603] - [当前时间：19:29:34]
#
# [状态：ok，尝试次数：124] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1288.TXK80196
# [剩余数量：602] - [当前时间：19:29:34]
#
# [状态：ok，尝试次数：41] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1342.TXMS40529
# [剩余数量：601] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：12] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1344.TXMS40531
# [剩余数量：600] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1328.TXMS25563
# [剩余数量：599] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：74] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1303.TXK90375
# [剩余数量：598] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：44] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1322.TXMS25553
# [剩余数量：597] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：72] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1308.TXMS25505
# [剩余数量：596] - [当前时间：19:29:35]
#
# [状态：ok，尝试次数：23] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1357.TXMS50510
# [剩余数量：595] - [当前时间：19:29:36]
#
# [状态：ok，尝试次数：76] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1333.TXMS30517
# [剩余数量：594] - [当前时间：19:29:36]
#
# [状态：ok，尝试次数：148] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1275.TXK7395
# [剩余数量：593] - [当前时间：19:29:36]
#
# [状态：ok，尝试次数：98] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1324.TXMS25555
# [剩余数量：592] - [当前时间：19:29:36]
#
# [状态：ok，尝试次数：3] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1368.TXMS50580
# [剩余数量：591] - [当前时间：19:29:36]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1371.TXMS60525
# [剩余数量：590] - [当前时间：19:29:37]
#
# [状态：ok，尝试次数：128] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1293.TXK8560T
# [剩余数量：589] - [当前时间：19:29:37]
#
# [状态：ok，尝试次数：70] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1341.TXMS40526
# [剩余数量：588] - [当前时间：19:29:37]
#
# [状态：ok，尝试次数：30] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1359.TXMS50519
# [剩余数量：587] - [当前时间：19:29:37]
#
# [状态：ok，尝试次数：130] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1289.TXK80197
# [剩余数量：586] - [当前时间：19:29:37]
#
# [状态：ok，尝试次数：115] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1307.TXMS25503
# [剩余数量：585] - [当前时间：19:29:38]
#
# [状态：ok，尝试次数：83] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1337.TXMS40506
# [剩余数量：584] - [当前时间：19:29:38]
#
# [状态：ok，尝试次数：45] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1354.TXMS40556
# [剩余数量：583] - [当前时间：19:29:38]
#
# [状态：ok，尝试次数：11] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1380.TXMS86565
# [剩余数量：582] - [当前时间：19:29:39]
#
# [状态：ok，尝试次数：36] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1367.TXMS50575
# [剩余数量：581] - [当前时间：19:29:39]
#
# [状态：ok，尝试次数：50] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1363.TXMS50569
# [剩余数量：580] - [当前时间：19:29:40]
#
# [状态：ok，尝试次数：34] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1365.TXMS50573
# [剩余数量：579] - [当前时间：19:29:40]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1351.TXMS40550
# [剩余数量：578] - [当前时间：19:29:42]
#
# [状态：ok，尝试次数：42] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1372.TXMS76501
# [剩余数量：577] - [当前时间：19:29:42]
#
# [状态：ok，尝试次数：27] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1382.TXMS86579
# [剩余数量：576] - [当前时间：19:29:42]
#
# [状态：ok，尝试次数：26] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1375.TXMS86516
# [剩余数量：575] - [当前时间：19:29:42]
#
# [状态：ok，尝试次数：92] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1352.TXMS40553
# [剩余数量：574] - [当前时间：19:29:42]
#
# [状态：ok，尝试次数：60] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1360.TXMS50532
# [剩余数量：573] - [当前时间：19:29:43]
#
# [状态：ok，尝试次数：148] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1310.TXMS25507
# [剩余数量：572] - [当前时间：19:29:43]
#
# [状态：ok，尝试次数：67] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1361.TXMS50553
# [剩余数量：571] - [当前时间：19:29:43]
#
# [状态：ok，尝试次数：119] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1340.TXMS40522
# [剩余数量：570] - [当前时间：19:29:43]
#
# [状态：ok，尝试次数：49] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1379.TXMS86564
# [剩余数量：569] - [当前时间：19:29:44]
#
# [状态：ok，尝试次数：175] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1306.TXK9802
# [剩余数量：568] - [当前时间：19:29:44]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1374.TXMS86505
# [剩余数量：567] - [当前时间：19:29:44]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1373.TXMS76505
# [剩余数量：566] - [当前时间：19:29:45]
#
# [状态：ok，尝试次数：65] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1376.TXMS86517
# [剩余数量：565] - [当前时间：19:29:45]
#
# [状态：ok，尝试次数：146] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1312.TXMS25516
# [剩余数量：564] - [当前时间：19:29:45]
#
# [状态：ok，尝试次数：115] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1353.TXMS40555
# [剩余数量：563] - [当前时间：19:29:45]
#
# [状态：ok，尝试次数：139] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1347.TXMS40536
# [剩余数量：562] - [当前时间：19:29:45]
#
# [状态：ok，尝试次数：116] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1345.TXMS40532
# [剩余数量：561] - [当前时间：19:29:46]
#
# [状态：ok，尝试次数：90] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1356.TXMS50508
# [剩余数量：560] - [当前时间：19:29:46]
#
# [状态：ok，尝试次数：42] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1385.TXMS90527
# [剩余数量：559] - [当前时间：19:29:46]
#
# [状态：ok，尝试次数：51] - 100.00% - crawler_5 > Ball Joint > MOOG > 1387.K100056
# [剩余数量：558] - [当前时间：19:29:46]
#
# [状态：ok，尝试次数：60] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1377.TXMS86527
# [剩余数量：557] - [当前时间：19:29:47]
#
# [状态：ok，尝试次数：21] - 100.00% - crawler_5 > Ball Joint > MOOG > 1390.K100107
# [剩余数量：556] - [当前时间：19:29:47]
#
# [状态：ok，尝试次数：57] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1335.TXMS30526
# [剩余数量：555] - [当前时间：19:29:47]
#
# [状态：ok，尝试次数：145] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1338.TXMS40516
# [剩余数量：554] - [当前时间：19:29:47]
#
# [状态：ok，尝试次数：109] - 100.00% - crawler_5 > Ball Joint > MEVOTECH > 1358.TXMS50516
# ...
# [剩余数量：109] - [当前时间：19:31:55]
#
# [状态：ok，尝试次数：16] - 100.00% - crawler_5 > Ball Joint > MOOG > 1847.K8607T
# [剩余数量：108] - [当前时间：19:31:56]
#
# [状态：ok，尝试次数：99] - 100.00% - crawler_5 > Ball Joint > MOOG > 1793.K80567
# [剩余数量：107] - [当前时间：19:31:56]
#
# [状态：ok，尝试次数：76] - 100.00% - crawler_5 > Ball Joint > MOOG > 1807.K80663
# [剩余数量：106] - [当前时间：19:31:57]
#
# [状态：ok，尝试次数：41] - 100.00% - crawler_5 > Ball Joint > MOOG > 1837.K8432T
# [剩余数量：105] - [当前时间：19:31:57]
#
# [状态：ok，尝试次数：204] - 100.00% - crawler_5 > Ball Joint > MOOG > 1714.K7053T
# [剩余数量：104] - [当前时间：19:31:57]
#
# [状态：ok，尝试次数：7] - 100.00% - crawler_5 > Ball Joint > MOOG > 1857.K8687
# [剩余数量：103] - [当前时间：19:31:58]
#
# [状态：ok，尝试次数：108] - 100.00% - crawler_5 > Ball Joint > MOOG > 1804.K80647
# [剩余数量：102] - [当前时间：19:31:58]
#
# [状态：ok，尝试次数：80] - 100.00% - crawler_5 > Ball Joint > MOOG > 1819.K80992
# [剩余数量：101] - [当前时间：19:31:58]
#
# [状态：ok，尝试次数：65] - 100.00% - crawler_5 > Ball Joint > MOOG > 1815.K80780
# [剩余数量：100] - [当前时间：19:31:58]
#
# [状态：ok，尝试次数：18] - 100.00% - crawler_5 > Ball Joint > MOOG > 1846.K8600
# [剩余数量：99] - [当前时间：19:31:58]
#
# [状态：ok，尝试次数：76] - 100.00% - crawler_5 > Ball Joint > MOOG > 1822.K80997
# [剩余数量：98] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：3] - 100.00% - crawler_5 > Ball Joint > MOOG > 1860.K8738
# [剩余数量：97] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：62] - 100.00% - crawler_5 > Ball Joint > MOOG > 1831.K8310
# [剩余数量：96] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：196] - 100.00% - crawler_5 > Ball Joint > MOOG > 1760.K7469
# [剩余数量：95] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：110] - 100.00% - crawler_5 > Ball Joint > MOOG > 1808.K80678
# [剩余数量：94] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：403] - 100.00% - crawler_5 > Ball Joint > MOOG > 1664.K5335
# [剩余数量：93] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：380] - 100.00% - crawler_5 > Ball Joint > MOOG > 1668.K6034
# [剩余数量：92] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：339] - 100.00% - crawler_5 > Ball Joint > MOOG > 1711.K693
# [剩余数量：91] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：5] - 100.00% - crawler_5 > Ball Joint > MOOG > 1838.K8433
# [剩余数量：90] - [当前时间：19:31:59]
#
# [状态：ok，尝试次数：542] - 100.00% - crawler_5 > Ball Joint > MOOG > 1573.K500322
# [剩余数量：89] - [当前时间：19:32:00]
#
# [状态：ok，尝试次数：28] - 100.00% - crawler_5 > Ball Joint > MOOG > 1853.K8676
# [剩余数量：88] - [当前时间：19:32:00]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MOOG > 1845.K8561T
# [剩余数量：87] - [当前时间：19:32:00]
#
# [状态：ok，尝试次数：2] - 100.00% - crawler_5 > Ball Joint > MOOG > 1867.K9025
# [剩余数量：86] - [当前时间：19:32:00]
#
# [状态：ok，尝试次数：98] - 100.00% - crawler_5 > Ball Joint > MOOG > 1805.K80660
# [剩余数量：85] - [当前时间：19:32:01]
#
# [状态：ok，尝试次数：46] - 100.00% - crawler_5 > Ball Joint > MOOG > 1850.K8619
# [剩余数量：84] - [当前时间：19:32:02]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MOOG > 1877.K90264
# [剩余数量：83] - [当前时间：19:32:03]
#
# [状态：ok，尝试次数：25] - 100.00% - crawler_5 > Ball Joint > MOOG > 1865.K9014
# [剩余数量：82] - [当前时间：19:32:03]
#
# [状态：ok，尝试次数：23] - 100.00% - crawler_5 > Ball Joint > MOOG > 1864.K9011
# [剩余数量：81] - [当前时间：19:32:03]
#
# [状态：ok，尝试次数：380] - 100.00% - crawler_5 > Ball Joint > MOOG > 1676.K6141
# [剩余数量：80] - [当前时间：19:32:03]
#
# [状态：ok，尝试次数：19] - 100.00% - crawler_5 > Ball Joint > MOOG > 1870.K90257
# [剩余数量：79] - [当前时间：19:32:03]
#
# [状态：ok，尝试次数：20] - 100.00% - crawler_5 > Ball Joint > MOOG > 1878.K90309
# [剩余数量：78] - [当前时间：19:32:04]
#
# [状态：ok，尝试次数：36] - 100.00% - crawler_5 > Ball Joint > MOOG > 1863.K8773
# [剩余数量：77] - [当前时间：19:32:04]
#
# [状态：ok，尝试次数：81] - 100.00% - crawler_5 > Ball Joint > MOOG > 1842.K8546
# [剩余数量：76] - [当前时间：19:32:04]
#
# [状态：ok，尝试次数：25] - 100.00% - crawler_5 > Ball Joint > MOOG > 1872.K90259
# [剩余数量：75] - [当前时间：19:32:04]
#
# [状态：ok，尝试次数：218] - 100.00% - crawler_5 > Ball Joint > MOOG > 1771.K80028
# [剩余数量：74] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：78] - 100.00% - crawler_5 > Ball Joint > MOOG > 1849.K8611T
# [剩余数量：73] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：27] - 100.00% - crawler_5 > Ball Joint > MOOG > 1881.K90346
# [剩余数量：72] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：101] - 100.00% - crawler_5 > Ball Joint > MOOG > 1801.K80629
# [剩余数量：71] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：29] - 100.00% - crawler_5 > Ball Joint > MOOG > 1876.K90263
# [剩余数量：70] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MOOG > 1856.K8685
# [剩余数量：69] - [当前时间：19:32:05]
#
# [状态：ok，尝试次数：24] - 100.00% - crawler_5 > Ball Joint > MOOG > 1879.K90332
# [剩余数量：68] - [当前时间：19:32:06]
#
# [状态：ok，尝试次数：66] - 100.00% - crawler_5 > Ball Joint > MOOG > 1861.K8749
# [剩余数量：67] - [当前时间：19:32:06]
#
# [状态：ok，尝试次数：72] - 100.00% - crawler_5 > Ball Joint > MOOG > 1858.K8695T
# [剩余数量：66] - [当前时间：19:32:06]
#
# [状态：ok，尝试次数：19] - 100.00% - crawler_5 > Ball Joint > MOOG > 1882.K90347
# [剩余数量：65] - [当前时间：19:32:06]
#
# [状态：ok，尝试次数：74] - 100.00% - crawler_5 > Ball Joint > MOOG > 1851.K8647
# [剩余数量：64] - [当前时间：19:32:07]
#
# [状态：ok，尝试次数：18] - 100.00% - crawler_5 > Ball Joint > MOOG > 1892.K9044
# [剩余数量：63] - [当前时间：19:32:07]
#
# [状态：ok，尝试次数：122] - 100.00% - crawler_5 > Ball Joint > MOOG > 1825.K8195T
# [剩余数量：62] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：21] - 100.00% - crawler_5 > Ball Joint > MOOG > 1890.K9042
# [剩余数量：61] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MOOG > 1896.K90469
# [剩余数量：60] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：25] - 100.00% - crawler_5 > Ball Joint > MOOG > 1887.K90364
# [剩余数量：59] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：203] - 100.00% - crawler_5 > Ball Joint > MOOG > 1791.K80522
# [剩余数量：58] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：186] - 100.00% - crawler_5 > Ball Joint > MOOG > 1794.K8059
# [剩余数量：57] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：89] - 100.00% - crawler_5 > Ball Joint > MOOG > 1852.K8673
# [剩余数量：56] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：154] - 100.00% - crawler_5 > Ball Joint > MOOG > 1784.K80305
# [剩余数量：55] - [当前时间：19:32:08]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MOOG > 1886.K90362
# [剩余数量：54] - [当前时间：19:32:09]
#
# [状态：ok，尝试次数：235] - 100.00% - crawler_5 > Ball Joint > MOOG > 1780.K80223
# [剩余数量：53] - [当前时间：19:32:09]
#
# [状态：ok，尝试次数：77] - 100.00% - crawler_5 > Ball Joint > MOOG > 1869.K90256
# [剩余数量：52] - [当前时间：19:32:09]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_5 > Ball Joint > MOOG > 1907.K9075
# [剩余数量：51] - [当前时间：19:32:09]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MOOG > 1888.K90375
# [剩余数量：50] - [当前时间：19:32:09]
#
# [状态：ok，尝试次数：4] - 100.00% - crawler_5 > Ball Joint > MOOG > 1910.K9091
# [剩余数量：49] - [当前时间：19:32:10]
#
# [状态：ok，尝试次数：216] - 100.00% - crawler_5 > Ball Joint > MOOG > 1798.K80606
# [剩余数量：48] - [当前时间：19:32:10]
#
# [状态：ok，尝试次数：84] - 100.00% - crawler_5 > Ball Joint > MOOG > 1871.K90258
# [剩余数量：47] - [当前时间：19:32:10]
#
# [状态：ok，尝试次数：134] - 100.00% - crawler_5 > Ball Joint > MOOG > 1844.K8560T
# [剩余数量：46] - [当前时间：19:32:11]
#
# [状态：ok，尝试次数：1] - 100.00% - crawler_5 > Ball Joint > MOOG > 1917.K9342
# [剩余数量：45] - [当前时间：19:32:11]
#
# [状态：ok，尝试次数：76] - 100.00% - crawler_5 > Ball Joint > MOOG > 1880.K90336
# [剩余数量：44] - [当前时间：19:32:11]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MOOG > 1900.K90663
# [剩余数量：43] - [当前时间：19:32:11]
#
# [状态：ok，尝试次数：6] - 100.00% - crawler_5 > Ball Joint > MOOG > 1911.K9097
# [剩余数量：42] - [当前时间：19:32:11]
#
# [状态：ok，尝试次数：54] - 100.00% - crawler_5 > Ball Joint > MOOG > 1884.K90357
# [剩余数量：41] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：304] - 100.00% - crawler_5 > Ball Joint > MOOG > 1754.K7452
# [剩余数量：40] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：61] - 100.00% - crawler_5 > Ball Joint > MOOG > 1866.K9022
# [剩余数量：39] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：109] - 100.00% - crawler_5 > Ball Joint > MOOG > 1840.K8477
# [剩余数量：38] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：115] - 100.00% - crawler_5 > Ball Joint > MOOG > 1833.K8412T
# [剩余数量：37] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：6] - 100.00% - crawler_5 > Ball Joint > MOOG > 1921.K9372
# [剩余数量：36] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：103] - 100.00% - crawler_5 > Ball Joint > MOOG > 1855.K8683
# [剩余数量：35] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：39] - 100.00% - crawler_5 > Ball Joint > MOOG > 1901.K90673
# [剩余数量：34] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：98] - 100.00% - crawler_5 > Ball Joint > MOOG > 1868.K90255
# [剩余数量：33] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：101] - 100.00% - crawler_5 > Ball Joint > MOOG > 1873.K90260
# [剩余数量：32] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：28] - 100.00% - crawler_5 > Ball Joint > MOOG > 1906.K90694
# [剩余数量：31] - [当前时间：19:32:12]
#
# [状态：ok，尝试次数：36] - 100.00% - crawler_5 > Ball Joint > MOOG > 1893.K9045
# [剩余数量：30] - [当前时间：19:32:13]
#
# [状态：ok，尝试次数：26] - 100.00% - crawler_5 > Ball Joint > MOOG > 1908.K9087
# [剩余数量：29] - [当前时间：19:32:13]
#
# [状态：ok，尝试次数：13] - 100.00% - crawler_5 > Ball Joint > MOOG > 1924.K9453
# [剩余数量：28] - [当前时间：19:32:13]
#
# [状态：ok，尝试次数：14] - 100.00% - crawler_5 > Ball Joint > MOOG > 1916.K9296
# [剩余数量：27] - [当前时间：19:32:14]
#
# [状态：ok，尝试次数：58] - 100.00% - crawler_5 > Ball Joint > MOOG > 1891.K90434
# [剩余数量：26] - [当前时间：19:32:16]
#
# [状态：ok，尝试次数：161] - 100.00% - crawler_5 > Ball Joint > MOOG > 1832.K8411
# [剩余数量：25] - [当前时间：19:32:16]
#
# [状态：ok，尝试次数：69] - 100.00% - crawler_5 > Ball Joint > MOOG > 1895.K90459
# [剩余数量：24] - [当前时间：19:32:16]
#
# [状态：ok，尝试次数：19] - 100.00% - crawler_5 > Ball Joint > MOOG > 1934.K9551
# [剩余数量：23] - [当前时间：19:32:16]
#
# [状态：ok，尝试次数：24] - 100.00% - crawler_5 > Ball Joint > MOOG > 1928.K9482
# [剩余数量：22] - [当前时间：19:32:16]
#
# [状态：ok，尝试次数：27] - 100.00% - crawler_5 > Ball Joint > MOOG > 1920.K9347
# [剩余数量：21] - [当前时间：19:32:17]
#
# [状态：ok，尝试次数：36] - 100.00% - crawler_5 > Ball Joint > MOOG > 1912.K9149
# [剩余数量：20] - [当前时间：19:32:17]
#
# [状态：ok，尝试次数：48] - 100.00% - crawler_5 > Ball Joint > MOOG > 1909.K9089
# [剩余数量：19] - [当前时间：19:32:17]
#
# [状态：ok，尝试次数：44] - 100.00% - crawler_5 > Ball Joint > MOOG > 1915.K9290
# [剩余数量：18] - [当前时间：19:32:17]
#
# [状态：ok，尝试次数：73] - 100.00% - crawler_5 > Ball Joint > MOOG > 1905.K90692
# [剩余数量：17] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：142] - 100.00% - crawler_5 > Ball Joint > MOOG > 1824.K8194T
# [剩余数量：16] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：161] - 100.00% - crawler_5 > Ball Joint > MOOG > 1854.K8678
# [剩余数量：15] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：17] - 100.00% - crawler_5 > Ball Joint > MOOG > 1941.K9635
# [剩余数量：14] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：31] - 100.00% - crawler_5 > Ball Joint > MOOG > 1925.K9457
# [剩余数量：13] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MOOG > 1930.K9509
# [剩余数量：12] - [当前时间：19:32:18]
#
# [状态：ok，尝试次数：62] - 100.00% - crawler_5 > Ball Joint > MOOG > 1902.K90685
# [剩余数量：11] - [当前时间：19:32:19]
#
# [状态：ok，尝试次数：34] - 100.00% - crawler_5 > Ball Joint > MOOG > 1938.K9615
# [剩余数量：10] - [当前时间：19:32:19]
#
# [状态：ok，尝试次数：160] - 100.00% - crawler_5 > Ball Joint > MOOG > 1862.K8771T
# [剩余数量：9] - [当前时间：19:32:19]
#
# [状态：ok，尝试次数：52] - 100.00% - crawler_5 > Ball Joint > MOOG > 1919.K9346
# [剩余数量：8] - [当前时间：19:32:19]
#
# [状态：ok，尝试次数：71] - 100.00% - crawler_5 > Ball Joint > MOOG > 1889.K90386
# [剩余数量：7] - [当前时间：19:32:19]
#
# [状态：ok，尝试次数：57] - 100.00% - crawler_5 > Ball Joint > MOOG > 1918.K9343
# [剩余数量：6] - [当前时间：19:32:20]
#
# [状态：ok，尝试次数：27] - 100.00% - crawler_5 > Ball Joint > MOOG > 1932.K9519
# [剩余数量：5] - [当前时间：19:32:20]
#
# [状态：ok，尝试次数：15] - 100.00% - crawler_5 > Ball Joint > MOOG > 1947.K9700
# [剩余数量：4] - [当前时间：19:32:20]
#
# [状态：ok，尝试次数：41] - 100.00% - crawler_5 > Ball Joint > MOOG > 1894.K90458
# [剩余数量：3] - [当前时间：19:32:20]
#
# [状态：ok，尝试次数：60] - 100.00% - crawler_5 > Ball Joint > MOOG > 1931.K9513
# [剩余数量：2] - [当前时间：19:32:21]
#
# [状态：ok，尝试次数：109] - 100.00% - crawler_5 > Ball Joint > MOOG > 1843.K8547
# [剩余数量：1] - [当前时间：19:32:21]
#
# [状态：ok，尝试次数：16] - 100.00% - crawler_5 > Ball Joint > MOOG > 1951.K9754
# [剩余数量：0] - [当前时间：19:32:21]
#
# [状态：ok，尝试次数：210] - 100.00% - crawler_5 > Ball Joint > MOOG > 1848.K8607T005
# [剩余数量：0] - [当前时间：19:32:21]
#
# [状态：ok，尝试次数：6] - 100.00% - crawler_5 > Ball Joint > MOOG > 1955.K9820
# [剩余数量：0] - [当前时间：19:32:22]
#
# [状态：ok，尝试次数：64] - 100.00% - crawler_5 > Ball Joint > MOOG > 1922.K9385
# [剩余数量：0] - [当前时间：19:32:22]
#
# [状态：ok，尝试次数：93] - 100.00% - crawler_5 > Ball Joint > MOOG > 1899.K90662
# [剩余数量：0] - [当前时间：19:32:22]
#
# [状态：ok，尝试次数：62] - 100.00% - crawler_5 > Ball Joint > MOOG > 1935.K9587
# [剩余数量：0] - [当前时间：19:32:23]
#
# [状态：ok，尝试次数：39] - 100.00% - crawler_5 > Ball Joint > MOOG > 1943.K9639
# [剩余数量：0] - [当前时间：19:32:23]
#
# [状态：ok，尝试次数：4] - 100.00% - crawler_5 > Ball Joint > MOOG > 1967.VVBJ0893
# [剩余数量：0] - [当前时间：19:32:23]
#
# [状态：ok，尝试次数：134] - 100.00% - crawler_5 > Ball Joint > MOOG > 1885.K90359
# [剩余数量：0] - [当前时间：19:32:23]
#
# [状态：ok，尝试次数：125] - 100.00% - crawler_5 > Ball Joint > MOOG > 1897.K90492
# [剩余数量：0] - [当前时间：19:32:23]
#
# [状态：ok，尝试次数：47] - 100.00% - crawler_5 > Ball Joint > MOOG > 1949.K9740
# [剩余数量：0] - [当前时间：19:32:24]
#
# [状态：ok，尝试次数：73] - 100.00% - crawler_5 > Ball Joint > MOOG > 1936.K9603
# [剩余数量：0] - [当前时间：19:32:24]
#
# [状态：ok，尝试次数：36] - 100.00% - crawler_5 > Ball Joint > MOOG > 1960.K9916
# [剩余数量：0] - [当前时间：19:32:24]
#
# [状态：ok，尝试次数：141] - 100.00% - crawler_5 > Ball Joint > MOOG > 1898.K90493
# [剩余数量：0] - [当前时间：19:32:25]
#
# [状态：ok，尝试次数：136] - 100.00% - crawler_5 > Ball Joint > MOOG > 1903.K90687
# [剩余数量：0] - [当前时间：19:32:25]
#
# [状态：ok，尝试次数：27] - 100.00% - crawler_5 > Ball Joint > MOOG > 1954.K9802
# [剩余数量：0] - [当前时间：19:32:25]
#
# [状态：ok，尝试次数：42] - 100.00% - crawler_5 > Ball Joint > MOOG > 1961.K9917
# [剩余数量：0] - [当前时间：19:32:25]
#
# [状态：ok，尝试次数：44] - 100.00% - crawler_5 > Ball Joint > MOOG > 1944.K9643
# [剩余数量：0] - [当前时间：19:32:25]
#
# [状态：ok，尝试次数：32] - 100.00% - crawler_5 > Ball Joint > MOOG > 1966.VOBJ7154
# [剩余数量：0] - [当前时间：19:32:26]
#
# [状态：ok，尝试次数：97] - 100.00% - crawler_5 > Ball Joint > MOOG > 1927.K9465
# [剩余数量：0] - [当前时间：19:32:26]
#
# [状态：ok，尝试次数：78] - 100.00% - crawler_5 > Ball Joint > MOOG > 1942.K9637
# [剩余数量：0] - [当前时间：19:32:26]
#
# [状态：ok，尝试次数：43] - 100.00% - crawler_5 > Ball Joint > MOOG > 1965.MEBJ0981
# [剩余数量：0] - [当前时间：19:32:26]
#
# [状态：ok，尝试次数：51] - 100.00% - crawler_5 > Ball Joint > MOOG > 1962.K9918
# [剩余数量：0] - [当前时间：19:32:27]
#
# [状态：ok，尝试次数：56] - 100.00% - crawler_5 > Ball Joint > MOOG > 1946.K9669
# [剩余数量：0] - [当前时间：19:32:27]
#
# [状态：ok，尝试次数：69] - 100.00% - crawler_5 > Ball Joint > MOOG > 1952.K9755
# [剩余数量：0] - [当前时间：19:32:27]
#
# [状态：ok，尝试次数：47] - 100.00% - crawler_5 > Ball Joint > MOOG > 1953.K9756
# [剩余数量：0] - [当前时间：19:32:27]
#
# [状态：ok，尝试次数：67] - 100.00% - crawler_5 > Ball Joint > MOOG > 1937.K9609
# [剩余数量：0] - [当前时间：19:32:28]
#
# [状态：ok，尝试次数：67] - 100.00% - crawler_5 > Ball Joint > MOOG > 1950.K9742
# [剩余数量：0] - [当前时间：19:32:29]
#
# [状态：ok，尝试次数：58] - 100.00% - crawler_5 > Ball Joint > MOOG > 1958.K9910
# [剩余数量：0] - [当前时间：19:32:29]
#
# [状态：ok，尝试次数：112] - 100.00% - crawler_5 > Ball Joint > MOOG > 1923.K9389
# [剩余数量：0] - [当前时间：19:32:29]
#
# [状态：ok，尝试次数：77] - 100.00% - crawler_5 > Ball Joint > MOOG > 1957.K9908
# [剩余数量：0] - [当前时间：19:32:29]
#
# [状态：ok，尝试次数：38] - 100.00% - crawler_5 > Ball Joint > MOOG > 1956.K9853
# [剩余数量：0] - [当前时间：19:32:29]
#
# [状态：ok，尝试次数：148] - 100.00% - crawler_5 > Ball Joint > MOOG > 1874.K90261
# [剩余数量：0] - [当前时间：19:32:30]
#
# [状态：ok，尝试次数：65] - 100.00% - crawler_5 > Ball Joint > MOOG > 1963.K9919
# [剩余数量：0] - [当前时间：19:32:30]
#
# [状态：ok，尝试次数：219] - 100.00% - crawler_5 > Ball Joint > MOOG > 1883.K90355
# [剩余数量：0] - [当前时间：19:32:31]
#
# [状态：ok，尝试次数：59] - 100.00% - crawler_5 > Ball Joint > MOOG > 1933.K9523
# [剩余数量：0] - [当前时间：19:32:31]
#
# [状态：ok，尝试次数：135] - 100.00% - crawler_5 > Ball Joint > MOOG > 1914.K9286
# [剩余数量：0] - [当前时间：19:32:32]
#
# [状态：ok，尝试次数：170] - 100.00% - crawler_5 > Ball Joint > MOOG > 1904.K90691
# [剩余数量：0] - [当前时间：19:32:32]
#
# [状态：ok，尝试次数：77] - 100.00% - crawler_5 > Ball Joint > MOOG > 1945.K9645
# [剩余数量：0] - [当前时间：19:32:33]
#
# [状态：ok，尝试次数：114] - 100.00% - crawler_5 > Ball Joint > MOOG > 1959.K9913
# [剩余数量：0] - [当前时间：19:32:33]
#
# [状态：ok，尝试次数：132] - 100.00% - crawler_5 > Ball Joint > MOOG > 1948.K9736
# [剩余数量：0] - [当前时间：19:32:33]
#
# [状态：ok，尝试次数：174] - 100.00% - crawler_5 > Ball Joint > MOOG > 1926.K9459
# [剩余数量：0] - [当前时间：19:32:35]
#
# [状态：ok，尝试次数：116] - 100.00% - crawler_5 > Ball Joint > MOOG > 1939.K9623
# [剩余数量：0] - [当前时间：19:32:35]
#
# [状态：ok，尝试次数：127] - 100.00% - crawler_5 > Ball Joint > MOOG > 1913.K9151
# [剩余数量：0] - [当前时间：19:32:36]
#
# [状态：ok，尝试次数：288] - 100.00% - crawler_5 > Ball Joint > MOOG > 1859.K8695T006
# [剩余数量：0] - [当前时间：19:32:37]
#
# [状态：ok，尝试次数：292] - 100.00% - crawler_5 > Ball Joint > MOOG > 1836.K8431T
# [剩余数量：0] - [当前时间：19:32:38]
#
# [状态：ok，尝试次数：104] - 100.00% - crawler_5 > Ball Joint > MOOG > 1929.K9499
# [剩余数量：0] - [当前时间：19:32:38]
#
# [状态：ok，尝试次数：171] - 100.00% - crawler_5 > Ball Joint > MOOG > 1875.K90262
# [剩余数量：0] - [当前时间：19:32:38]
#
# [状态：ok，尝试次数：128] - 100.00% - crawler_5 > Ball Joint > MOOG > 1940.K9633
# [剩余数量：0] - [当前时间：19:32:40]
#
# [状态：ok，尝试次数：109] - 100.00% - crawler_5 > Ball Joint > MOOG > 1964.K9923
# [剩余数量：0] - [当前时间：19:32:45]
#
# 输出ing...
# Progress: 100%|██████████████████████████████| 3/3 [00:00<00:00, 5320.47it/s]
# Done ~
