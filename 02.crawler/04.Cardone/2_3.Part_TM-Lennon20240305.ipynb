# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████████| 9/9 [00:00<00:00, 193.56it/s]
#    序号          Brand                              Title Part_Number  \
# 0   1  CARDONE Reman   Windshield Wiper Motor - 40-1000     40-1000
# 1   2  CARDONE Reman  Windshield Wiper Motor - 40-10000    40-10000
# 2   3  CARDONE Reman  Windshield Wiper Motor - 40-10005    40-10005
# 3   4  CARDONE Reman  Windshield Wiper Motor - 40-10006    40-10006
# 4   5  CARDONE Reman  Windshield Wiper Motor - 40-10007    40-10007
# 5   6  CARDONE Reman  Windshield Wiper Motor - 40-10009    40-10009
# 6   7  CARDONE Reman   Windshield Wiper Motor - 40-1001     40-1001
# 7   8  CARDONE Reman  Windshield Wiper Motor - 40-10013    40-10013
# 8   9  CARDONE Reman  Windshield Wiper Motor - 40-10014    40-10014
#
#                 Part_Type                                                Src  \
# 0  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 1  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 2  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 3  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 4  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 5  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 6  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 7  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
# 8  Windshield Wiper Motor  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...
#
#                                            Vehicle_1  \
# 0  Chevrolet Camaro 1993-1998\nPontiac Firebird 1...
# 1
# 2  Cadillac CTS 2008-2015\nCadillac Escalade 2015...
# 3                            Buick Enclave 2008-2017
# 4                         Chevrolet Malibu 2005-2007
# 5  Chevrolet Suburban 1500 2000\nChevrolet Suburb...
# 6  Chevrolet Prizm 1998-2002\nGeo Prizm 1993-1997...
# 7  Chevrolet Captiva Sport 2008-2015\nSaturn Vue ...
# 8  Chevrolet Captiva Sport 2008-2010\nSaturn Vue ...
#
#                                            Vehicle_2  \
# 0  Chevrolet Camaro 1993-1994 3.4L V6 207cid\nChe...
# 1
# 2  Cadillac CTS 2008-2014 3.6L V6 217cid/3564cc\n...
# 3      Buick Enclave 2008-2017 3.6L V6 217cid/3564cc
# 4  Chevrolet Malibu 2005-2006 3.5L V6 213cid\nChe...
# 5  Chevrolet Suburban 1500 2000 5.3L V8 325cid/53...
# 6  Chevrolet Prizm 1998-2002 1.8L L4 1794cc\nGeo ...
# 7  Chevrolet Captiva Sport 2008-2009 2.4L L4 147c...
# 8  Chevrolet Captiva Sport 2008-2009 2.4L L4 147c...
#
#                            OE productDeskExternalKey  ...  \
# 0           22110039;22154913           CPCX|40-1000  ...
# 1                    15943193          CPCX|40-10000  ...
# 2                 76505SZTG01          CPCX|40-10005  ...
# 3           25795300;25864153          CPCX|40-10006  ...
# 4                    15252854          CPCX|40-10007  ...
# 5                    12463052          CPCX|40-10009  ...
# 6                  8511002051           CPCX|40-1001  ...
# 7  20829042;96673024;96673047          CPCX|40-10013  ...
# 8           25963804;96673001          CPCX|40-10014  ...
#
#   Washer Pump Included               Part Type       Warranty Info  \
# 0                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 1                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 2                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 3                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 4                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 5                       Windshield Wiper Motor  1 Year/18,000 Mile
# 6                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 7                   No  Windshield Wiper Motor  1 Year/18,000 Mile
# 8                   No  Windshield Wiper Motor  1 Year/18,000 Mile
#
#   Sustainable Choice    Lifecycle Status  \
# 0                Yes  Available to Order
# 1                Yes  Available to Order
# 2                Yes  Available to Order
# 3                Yes  Available to Order
# 4                Yes  Available to Order
# 5                Yes  Available to Order
# 6                Yes  Available to Order
# 7                Yes  Available to Order
# 8                Yes  Available to Order
#
#                                  Application_Summary   ItemLevelGTIN  \
# 0  Chevrolet Camaro 1998-93\nPontiac Firebird 199...  00082617338332
# 1                                  Hummer H3 2010-06  00082617827195
# 2                                                     00082617836975
# 3                              Buick Enclave 2017-08  00082617836982
# 4                           Chevrolet Malibu 2007-05  00082617837002
# 5  Chevrolet Suburban 1500 2000, Suburban 2500 20...  00082617837040
# 6  Chevrolet Prizm 2002-98\nGeo Prizm 1997-93\nTo...  00082617370516
# 7  Chevrolet Captiva Sport 2015-08\nSaturn Vue 20...  00082617843348
# 8  Chevrolet Captiva Sport 2010-08\nSaturn Vue 20...  00082617843379
#
#                 _addonCardone Eligible for R&R Service  \
# 0   40-1000::98271:100085:306                      Yes
# 1  40-10000::98271:100090:306                      Yes
# 2  40-10005::98271:100141:306                      Yes
# 3  40-10006::98271:100144:306                      Yes
# 4  40-10007::98271:100148:306                      Yes
# 5  40-10009::98271:100152:306                      Yes
# 6   40-1001::98271:100155:306                      Yes
# 7  40-10013::98271:100159:306                      Yes
# 8  40-10014::98271:100162:306                      Yes
#
#                                                  Url
# 0  https://www.cardone.com/product/windshield-wip...
# 1  https://www.cardone.com/product/windshield-wip...
# 2  https://www.cardone.com/product/windshield-wip...
# 3  https://www.cardone.com/product/windshield-wip...
# 4  https://www.cardone.com/product/windshield-wip...
# 5  https://www.cardone.com/product/windshield-wip...
# 6  https://www.cardone.com/product/windshield-wip...
# 7  https://www.cardone.com/product/windshield-wip...
# 8  https://www.cardone.com/product/windshield-wip...
#
# [9 rows x 27 columns]
