# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./part.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
print()

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# = = = = = = = = = = = = = = =

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import time
from datetime import datetime

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)
    
# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error
    
    while not work.empty():
        a = work.get_nowait()
        
        # = = = = = = = = = = = = = = =
        
        crawler_status = 'error'
        for b in range(100):
            try:
                resp = requests.get('http://www.kakapart.com/oem/partscrossinterchange/centric-' + input_.loc[a, 'Sku'].replace('Part # ', '').replace('.', '') + '.html',
                                    headers=UA.get_User_Agent_Requests(),
                                    proxies=Proxy.get_Proxy_Requests()).text
                
                # = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                html = etree.HTML(str(soup))
                
                # = = = = = = = = = = = = = = =
                
                list_tr = html.xpath('//table[@class="os-main-table"]/tbody/tr[@class="os-row"]')
                
                # = = = = = = = = = = = = = = =
                
                dict_oe = {}
                for tr in list_tr:
                    factory = tr.xpath('./td[1]/text()')[0].strip()
                    cross = tr.xpath('./td[3]/text()')[0].strip()
                    if cross == 'Direct Cross Interchange':
                        key = factory + '_Direct'
                    elif cross == 'Indirect Cross Interchange':
                        key = factory + '_Indirect'
                    else:
                        key = factory + '_NULL'

                    if key not in dict_oe:
                        dict_oe[key] = [tr.xpath('./td[2]/text()')[0].strip()]
                    else:
                        dict_oe[key].append(tr.xpath('./td[2]/text()')[0].strip())
                        dict_oe[key] = sorted(list(set(dict_oe[key])))

                # = = = = = = = = = = = = = = =
                
                df_temp = pd.DataFrame([{'Sku': input_.loc[a, 'Sku']}])

                for key in dict_oe:
                    df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
    
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
                
                # = = = = = = = = = = = = = = =
                
                crawler_status = 'ok'
                
                break
            except:
                time.sleep(0.3)
                continue
        
        # = = = = = = = = = = = = = = =
        
        if crawler_status == 'error':
            df_temp = pd.DataFrame([{'Sku': input_.loc[a, 'Sku']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')
            
        # = = = = = = = = = = = = = = =
        
        print('[' + crawler_status + '] - ' + input_.loc[a, 'Sku'] +  '\n[尝试次数：' + str(b+1) + '] - [剩余数量：' + str(work.qsize()) + '] - [当前时间：' + datetime.now().strftime('%H:%M:%S') + ']\n')
        
# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['Sku'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./oe-' + datetime.now().strftime('%Y%m%d_%H%M%S') + '.xlsx', index=False)
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['Sku'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./oe_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：283
#
# [ok] - Part # 100.05940
# [尝试次数：1] - [剩余数量：263] - [当前时间：11:12:45]
#
# [ok] - Part # 100.08770
# [尝试次数：1] - [剩余数量：262] - [当前时间：11:12:45]
#
# [ok] - Part # 100.07200
# [尝试次数：1] - [剩余数量：261] - [当前时间：11:12:45]
#
# [ok] - Part # 100.06380
# [尝试次数：1] - [剩余数量：260] - [当前时间：11:12:45]
#
# [ok] - Part # 100.09154
# [尝试次数：1] - [剩余数量：259] - [当前时间：11:12:45]
#
# [ok] - Part # 100.01451
# [尝试次数：1] - [剩余数量：258] - [当前时间：11:12:45]
#
# [ok] - Part # 100.02900
# [尝试次数：1] - [剩余数量：257] - [当前时间：11:12:45]
#
# [ok] - Part # 100.07400
# [尝试次数：1] - [剩余数量：256] - [当前时间：11:12:45]
#
# [ok] - Part # 100.09722
# [尝试次数：1] - [剩余数量：255] - [当前时间：11:12:45]
#
# [ok] - Part # 100.09780
# [尝试次数：1] - [剩余数量：254] - [当前时间：11:12:45]
#
# [ok] - Part # 100.00310
# [尝试次数：1] - [剩余数量：253] - [当前时间：11:12:45]
#
# [ok] - Part # 100.04030
# [尝试次数：1] - [剩余数量：252] - [当前时间：11:12:45]
#
# [ok] - Part # 100.08760
# [尝试次数：1] - [剩余数量：251] - [当前时间：11:12:46]
#
# [ok] - Part # 100.06922
# [尝试次数：1] - [剩余数量：250] - [当前时间：11:12:46]
#
# [ok] - Part # 100.06400
# [尝试次数：1] - [剩余数量：249] - [当前时间：11:12:46]
#
# [ok] - Part # 100.06830
# [尝试次数：1] - [剩余数量：248] - [当前时间：11:12:46]
#
# [ok] - Part # 100.11770
# [尝试次数：1] - [剩余数量：247] - [当前时间：11:12:46]
#
# [ok] - Part # 100.13140
# [尝试次数：1] - [剩余数量：246] - [当前时间：11:12:46]
#
# [ok] - Part # 100.12570
# [尝试次数：1] - [剩余数量：245] - [当前时间：11:12:46]
#
# [ok] - Part # 100.14530
# [尝试次数：1] - [剩余数量：244] - [当前时间：11:12:46]
#
# [ok] - Part # 100.14380
# [尝试次数：1] - [剩余数量：243] - [当前时间：11:12:46]
#
# [ok] - Part # 100.12410
# [尝试次数：1] - [剩余数量：242] - [当前时间：11:12:46]
#
# [ok] - Part # 100.07800
# [尝试次数：1] - [剩余数量：241] - [当前时间：11:12:46]
#
# [ok] - Part # 100.12030
# [尝试次数：1] - [剩余数量：240] - [当前时间：11:12:46]
#
# [ok] - Part # 100.13900
# [尝试次数：1] - [剩余数量：239] - [当前时间：11:12:46]
#
# [ok] - Part # 100.13890
# [尝试次数：1] - [剩余数量：238] - [当前时间：11:12:46]
#
# [ok] - Part # 100.14070
# [尝试次数：1] - [剩余数量：237] - [当前时间：11:12:46]
#
# [ok] - Part # 100.14310
# [尝试次数：1] - [剩余数量：236] - [当前时间：11:12:46]
#
# [ok] - Part # 100.14670
# [尝试次数：1] - [剩余数量：235] - [当前时间：11:12:46]
#
# [ok] - Part # 100.13710
# [尝试次数：1] - [剩余数量：234] - [当前时间：11:12:46]
#
# [ok] - Part # 100.16700
# [尝试次数：1] - [剩余数量：233] - [当前时间：11:12:46]
#
# [ok] - Part # 100.15580
# [尝试次数：1] - [剩余数量：232] - [当前时间：11:12:47]
#
# [ok] - Part # 100.15300
# [尝试次数：1] - [剩余数量：231] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00050
# [尝试次数：1] - [剩余数量：230] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00200
# [尝试次数：1] - [剩余数量：229] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00110
# [尝试次数：1] - [剩余数量：228] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00090
# [尝试次数：1] - [剩余数量：227] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00190
# [尝试次数：1] - [剩余数量：226] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00270
# [尝试次数：1] - [剩余数量：225] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00040
# [尝试次数：1] - [剩余数量：224] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00080
# [尝试次数：1] - [剩余数量：223] - [当前时间：11:12:47]
#
# [ok] - Part # 100.06840
# [尝试次数：2] - [剩余数量：222] - [当前时间：11:12:47]
#
# [ok] - Part # 102.00020
# [尝试次数：1] - [剩余数量：221] - [当前时间：11:12:48]
#
# [ok] - Part # 100.10600
# [尝试次数：1] - [剩余数量：220] - [当前时间：11:12:48]
#
# [ok] - Part # 100.10910
# [尝试次数：3] - [剩余数量：219] - [当前时间：11:12:48]
#
# [ok] - Part # 102.00310
# [尝试次数：4] - [剩余数量：218] - [当前时间：11:12:48]
#
# [ok] - Part # 100.06810
# [尝试次数：1] - [剩余数量：217] - [当前时间：11:12:48]
#
# [ok] - Part # 102.00410
# [尝试次数：3] - [剩余数量：216] - [当前时间：11:12:48]
#
# [ok] - Part # 100.05550
# [尝试次数：1] - [剩余数量：215] - [当前时间：11:12:49]
#
# [ok] - Part # 102.00010
# [尝试次数：1] - [剩余数量：214] - [当前时间：11:12:49]
#
# [ok] - Part # 102.00440
# [尝试次数：3] - [剩余数量：213] - [当前时间：11:12:49]
#
# [ok] - Part # 102.00380
# [尝试次数：5] - [剩余数量：212] - [当前时间：11:12:49]
#
# [ok] - Part # 102.00520
# [尝试次数：1] - [剩余数量：211] - [当前时间：11:12:49]
#
# [ok] - Part # 102.00540
# [尝试次数：2] - [剩余数量：210] - [当前时间：11:12:50]
#
# [ok] - Part # 102.00300
# [尝试次数：9] - [剩余数量：209] - [当前时间：11:12:50]
#
# [ok] - Part # 102.00560
# [尝试次数：3] - [剩余数量：208] - [当前时间：11:12:50]
#
# [ok] - Part # 102.00710
# [尝试次数：2] - [剩余数量：207] - [当前时间：11:12:50]
#
# [ok] - Part # 102.00820
# [尝试次数：2] - [剩余数量：206] - [当前时间：11:12:51]
#
# [ok] - Part # 100.09850
# [尝试次数：9] - [剩余数量：205] - [当前时间：11:12:51]
#
# [ok] - Part # 102.00400
# [尝试次数：12] - [剩余数量：204] - [当前时间：11:12:52]
#
# [ok] - Part # 102.00510
# [尝试次数：10] - [剩余数量：203] - [当前时间：11:12:52]
#
# [ok] - Part # 100.13120
# [尝试次数：8] - [剩余数量：202] - [当前时间：11:12:52]
#
# [ok] - Part # 102.00460
# [尝试次数：9] - [剩余数量：201] - [当前时间：11:12:53]
#
# [ok] - Part # 102.00910
# [尝试次数：1] - [剩余数量：200] - [当前时间：11:12:53]
#
# [ok] - Part # 102.00370
# [尝试次数：12] - [剩余数量：199] - [当前时间：11:12:53]
#
# [ok] - Part # 102.00880
# [尝试次数：4] - [剩余数量：198] - [当前时间：11:12:53]
#
# [ok] - Part # 102.00340
# [尝试次数：14] - [剩余数量：197] - [当前时间：11:12:54]
#
# [ok] - Part # 102.00541
# [尝试次数：16] - [剩余数量：196] - [当前时间：11:12:55]
#
# [ok] - Part # 102.00451
# [尝试次数：18] - [剩余数量：195] - [当前时间：11:12:56]
#
# [ok] - Part # 102.01120
# [尝试次数：5] - [剩余数量：194] - [当前时间：11:12:57]
#
# [ok] - Part # 102.00230
# [尝试次数：21] - [剩余数量：193] - [当前时间：11:12:57]
#
# [ok] - Part # 102.00610
# [尝试次数：20] - [剩余数量：192] - [当前时间：11:12:57]
#
# [ok] - Part # 102.01020
# [尝试次数：10] - [剩余数量：191] - [当前时间：11:12:57]
#
# [ok] - Part # 102.00870
# [尝试次数：16] - [剩余数量：190] - [当前时间：11:12:58]
#
# [ok] - Part # 102.00900
# [尝试次数：16] - [剩余数量：189] - [当前时间：11:12:58]
#
# [ok] - Part # 102.00840
# [尝试次数：1] - [剩余数量：188] - [当前时间：11:12:58]
#
# [ok] - Part # 102.00030
# [尝试次数：5] - [剩余数量：187] - [当前时间：11:12:58]
#
# [ok] - Part # 102.01010
# [尝试次数：14] - [剩余数量：186] - [当前时间：11:12:59]
#
# [ok] - Part # 102.01080
# [尝试次数：10] - [剩余数量：185] - [当前时间：11:12:59]
#
# [ok] - Part # 102.00850
# [尝试次数：18] - [剩余数量：184] - [当前时间：11:13:00]
#
# [ok] - Part # 102.00360
# [尝试次数：28] - [剩余数量：183] - [当前时间：11:13:00]
#
# [ok] - Part # 102.00330
# [尝试次数：35] - [剩余数量：182] - [当前时间：11:13:01]
#
# [ok] - Part # 102.01310
# [尝试次数：9] - [剩余数量：181] - [当前时间：11:13:01]
#
# [ok] - Part # 102.01450
# [尝试次数：2] - [剩余数量：180] - [当前时间：11:13:01]
#
# [ok] - Part # 102.01390
# [尝试次数：5] - [剩余数量：179] - [当前时间：11:13:02]
#
# [ok] - Part # 102.00760
# [尝试次数：29] - [剩余数量：178] - [当前时间：11:13:02]
#
# [ok] - Part # 102.00430
# [尝试次数：34] - [剩余数量：177] - [当前时间：11:13:02]
#
# [ok] - Part # 102.01230
# [尝试次数：9] - [剩余数量：176] - [当前时间：11:13:02]
#
# [ok] - Part # 102.01520
# [尝试次数：2] - [剩余数量：175] - [当前时间：11:13:03]
#
# [ok] - Part # 102.01430
# [尝试次数：8] - [剩余数量：174] - [当前时间：11:13:03]
#
# [ok] - Part # 102.00500
# [尝试次数：37] - [剩余数量：173] - [当前时间：11:13:04]
#
# [ok] - Part # 102.01530
# [尝试次数：6] - [剩余数量：172] - [当前时间：11:13:04]
#
# [ok] - Part # 102.01630
# [尝试次数：3] - [剩余数量：171] - [当前时间：11:13:06]
#
# [ok] - Part # 102.01700
# [尝试次数：1] - [剩余数量：170] - [当前时间：11:13:06]
#
# [ok] - Part # 102.01580
# [尝试次数：9] - [剩余数量：169] - [当前时间：11:13:06]
#
# [ok] - Part # 102.01190
# [尝试次数：19] - [剩余数量：168] - [当前时间：11:13:07]
#
# [ok] - Part # 102.01350
# [尝试次数：19] - [剩余数量：167] - [当前时间：11:13:07]
#
# [ok] - Part # 102.00810
# [尝试次数：31] - [剩余数量：166] - [当前时间：11:13:07]
#
# [ok] - Part # 102.01800
# [尝试次数：1] - [剩余数量：165] - [当前时间：11:13:08]
#
# [ok] - Part # 102.00450
# [尝试次数：43] - [剩余数量：164] - [当前时间：11:13:09]
#
# [ok] - Part # 102.01640
# [尝试次数：14] - [剩余数量：163] - [当前时间：11:13:10]
#
# [ok] - Part # 102.01330
# [尝试次数：29] - [剩余数量：162] - [当前时间：11:13:10]
#
# [ok] - Part # 102.01950
# [尝试次数：1] - [剩余数量：161] - [当前时间：11:13:10]
#
# [ok] - Part # 102.01471
# [尝试次数：19] - [剩余数量：160] - [当前时间：11:13:10]
#
# [ok] - Part # 102.01340
# [尝试次数：31] - [剩余数量：159] - [当前时间：11:13:11]
#
# [ok] - Part # 102.02020
# [尝试次数：1] - [剩余数量：158] - [当前时间：11:13:11]
#
# [ok] - Part # 102.01220
# [尝试次数：35] - [剩余数量：157] - [当前时间：11:13:11]
#
# [ok] - Part # 102.02040
# [尝试次数：1] - [剩余数量：156] - [当前时间：11:13:11]
#
# [ok] - Part # 102.01570
# [尝试次数：24] - [剩余数量：155] - [当前时间：11:13:12]
#
# [ok] - Part # 102.02130
# [尝试次数：1] - [剩余数量：154] - [当前时间：11:13:12]
#
# [ok] - Part # 102.01690
# [尝试次数：5] - [剩余数量：153] - [当前时间：11:13:12]
#
# [ok] - Part # 102.01170
# [尝试次数：37] - [剩余数量：152] - [当前时间：11:13:12]
#
# [ok] - Part # 102.02150
# [尝试次数：1] - [剩余数量：151] - [当前时间：11:13:12]
#
# [ok] - Part # 102.02190
# [尝试次数：2] - [剩余数量：150] - [当前时间：11:13:13]
#
# [ok] - Part # 102.01750
# [尝试次数：16] - [剩余数量：149] - [当前时间：11:13:13]
#
# [ok] - Part # 102.01540
# [尝试次数：22] - [剩余数量：148] - [当前时间：11:13:13]
#
# [ok] - Part # 102.01970
# [尝试次数：6] - [剩余数量：147] - [当前时间：11:13:13]
#
# [ok] - Part # 102.02180
# [尝试次数：4] - [剩余数量：146] - [当前时间：11:13:14]
#
# [ok] - Part # 102.02200
# [尝试次数：2] - [剩余数量：145] - [当前时间：11:13:14]
#
# [ok] - Part # 102.01960
# [尝试次数：10] - [剩余数量：144] - [当前时间：11:13:14]
#
# [ok] - Part # 102.02290
# [尝试次数：1] - [剩余数量：143] - [当前时间：11:13:14]
#
# [ok] - Part # 102.02240
# [尝试次数：2] - [剩余数量：142] - [当前时间：11:13:15]
#
# [ok] - Part # 102.02030
# [尝试次数：11] - [剩余数量：141] - [当前时间：11:13:16]
#
# [ok] - Part # 102.01510
# [尝试次数：33] - [剩余数量：140] - [当前时间：11:13:16]
#
# [ok] - Part # 102.02350
# [尝试次数：6] - [剩余数量：139] - [当前时间：11:13:16]
#
# [ok] - Part # 102.02140
# [尝试次数：10] - [剩余数量：138] - [当前时间：11:13:17]
# [ok] - Part # 102.02210
# [尝试次数：12] - [剩余数量：137] - [当前时间：11:13:17]
#
# [ok] - Part # 102.02280
# [尝试次数：6] - [剩余数量：136] - [当前时间：11:13:18]
#
# [ok] - Part # 102.02060
# [尝试次数：13] - [剩余数量：135] - [当前时间：11:13:18]
#
# [ok] - Part # 102.01740
# [尝试次数：26] - [剩余数量：134] - [当前时间：11:13:19]
#
# [ok] - Part # 102.02250
# [尝试次数：13] - [剩余数量：133] - [当前时间：11:13:19]
#
# [ok] - Part # 102.02560
# [尝试次数：6] - [剩余数量：132] - [当前时间：11:13:20]
#
# [ok] - Part # 102.02570
# [尝试次数：3] - [剩余数量：131] - [当前时间：11:13:20]
#
# [ok] - Part # 102.02620
# [尝试次数：4] - [剩余数量：130] - [当前时间：11:13:22]
#
# [ok] - Part # 102.01910
# [尝试次数：31] - [剩余数量：129] - [当前时间：11:13:22]
#
# [ok] - Part # 102.01451
# [尝试次数：53] - [剩余数量：128] - [当前时间：11:13:22]
#
# [ok] - Part # 102.02610
# [尝试次数：4] - [剩余数量：127] - [当前时间：11:13:22]
#
# [ok] - Part # 102.02740
# [尝试次数：1] - [剩余数量：126] - [当前时间：11:13:22]
#
# [ok] - Part # 102.02750
# [尝试次数：1] - [剩余数量：125] - [当前时间：11:13:23]
#
# [ok] - Part # 102.02400
# [尝试次数：13] - [剩余数量：124] - [当前时间：11:13:23]
#
# [ok] - Part # 102.02770
# [尝试次数：2] - [剩余数量：123] - [当前时间：11:13:23]
#
# [ok] - Part # 102.01370
# [尝试次数：52] - [剩余数量：122] - [当前时间：11:13:23]
#
# [ok] - Part # 102.02630
# [尝试次数：9] - [剩余数量：121] - [当前时间：11:13:24]
#
# [ok] - Part # 102.02260
# [尝试次数：23] - [剩余数量：120] - [当前时间：11:13:24]
#
# [ok] - Part # 102.00960
# [尝试次数：75] - [剩余数量：119] - [当前时间：11:13:24]
#
# [ok] - Part # 102.02840
# [尝试次数：2] - [剩余数量：118] - [当前时间：11:13:24]
#
# [ok] - Part # 102.02870
# [尝试次数：4] - [剩余数量：117] - [当前时间：11:13:25]
#
# [ok] - Part # 102.01140
# [尝试次数：68] - [剩余数量：116] - [当前时间：11:13:26]
#
# [ok] - Part # 102.02880
# [尝试次数：5] - [剩余数量：115] - [当前时间：11:13:26]
#
# [ok] - Part # 102.02800
# [尝试次数：6] - [剩余数量：114] - [当前时间：11:13:26]
#
# [ok] - Part # 102.02900
# [尝试次数：3] - [剩余数量：113] - [当前时间：11:13:27]
#
# [ok] - Part # 102.02910
# [尝试次数：1] - [剩余数量：112] - [当前时间：11:13:27]
#
# [ok] - Part # 102.02850
# [尝试次数：4] - [剩余数量：111] - [当前时间：11:13:27]
#
# [ok] - Part # 102.02420
# [尝试次数：29] - [剩余数量：110] - [当前时间：11:13:28]
#
# [ok] - Part # 102.02820
# [尝试次数：10] - [剩余数量：109] - [当前时间：11:13:28]
#
# [ok] - Part # 102.02940
# [尝试次数：4] - [剩余数量：108] - [当前时间：11:13:29]
#
# [ok] - Part # 102.02890
# [尝试次数：7] - [剩余数量：107] - [当前时间：11:13:29]
#
# [ok] - Part # 102.02920
# [尝试次数：8] - [剩余数量：106] - [当前时间：11:13:29]
#
# [ok] - Part # 102.02990
# [尝试次数：2] - [剩余数量：105] - [当前时间：11:13:30]
#
# [ok] - Part # 102.02760
# [尝试次数：10] - [剩余数量：104] - [当前时间：11:13:30]
#
# [ok] - Part # 102.01780
# [尝试次数：55] - [剩余数量：103] - [当前时间：11:13:30]
#
# [ok] - Part # 102.02980
# [尝试次数：6] - [剩余数量：102] - [当前时间：11:13:31]
#
# [ok] - Part # 102.03140
# [尝试次数：1] - [剩余数量：101] - [当前时间：11:13:31]
#
# [ok] - Part # 102.02970
# [尝试次数：5] - [剩余数量：100] - [当前时间：11:13:31]
#
# [ok] - Part # 102.02950
# [尝试次数：11] - [剩余数量：99] - [当前时间：11:13:31]
#
# [ok] - Part # 102.03050
# [尝试次数：5] - [剩余数量：98] - [当前时间：11:13:32]
#
# [ok] - Part # 102.02790
# [尝试次数：23] - [剩余数量：97] - [当前时间：11:13:32]
#
# [ok] - Part # 102.03110
# [尝试次数：4] - [剩余数量：96] - [当前时间：11:13:32]
#
# [ok] - Part # 102.03240
# [尝试次数：2] - [剩余数量：95] - [当前时间：11:13:33]
#
# [ok] - Part # 102.03280
# [尝试次数：1] - [剩余数量：94] - [当前时间：11:13:33]
#
# [ok] - Part # 102.03290
# [尝试次数：1] - [剩余数量：93] - [当前时间：11:13:34]
#
# [ok] - Part # 102.03030
# [尝试次数：11] - [剩余数量：92] - [当前时间：11:13:34]
#
# [ok] - Part # 102.03300
# [尝试次数：1] - [剩余数量：91] - [当前时间：11:13:35]
#
# [ok] - Part # 102.03230
# [尝试次数：6] - [剩余数量：90] - [当前时间：11:13:35]
#
# [ok] - Part # 102.02360
# [尝试次数：46] - [剩余数量：89] - [当前时间：11:13:35]
#
# [ok] - Part # 102.02450
# [尝试次数：41] - [剩余数量：88] - [当前时间：11:13:35]
#
# [ok] - Part # 102.03090
# [尝试次数：15] - [剩余数量：87] - [当前时间：11:13:35]
#
# [ok] - Part # 102.03330
# [尝试次数：3] - [剩余数量：86] - [当前时间：11:13:36]
#
# [ok] - Part # 102.02810
# [尝试次数：30] - [剩余数量：85] - [当前时间：11:13:36]
#
# [ok] - Part # 102.03220
# [尝试次数：13] - [剩余数量：84] - [当前时间：11:13:36]
#
# [ok] - Part # 102.03420
# [尝试次数：2] - [剩余数量：83] - [当前时间：11:13:37]
#
# [ok] - Part # 102.02530
# [尝试次数：40] - [剩余数量：82] - [当前时间：11:13:37]
#
# [ok] - Part # 102.03500
# [尝试次数：2] - [剩余数量：81] - [当前时间：11:13:38]
#
# [ok] - Part # 102.03440
# [尝试次数：3] - [剩余数量：80] - [当前时间：11:13:38]
#
# [ok] - Part # 102.03190
# [尝试次数：16] - [剩余数量：79] - [当前时间：11:13:38]
#
# [ok] - Part # 102.03310
# [尝试次数：13] - [剩余数量：78] - [当前时间：11:13:39]
#
# [ok] - Part # 102.03490
# [尝试次数：1] - [剩余数量：77] - [当前时间：11:13:39]
#
# [ok] - Part # 102.02730
# [尝试次数：42] - [剩余数量：76] - [当前时间：11:13:39]
#
# [ok] - Part # 102.03250
# [尝试次数：16] - [剩余数量：75] - [当前时间：11:13:40]
#
# [ok] - Part # 102.02660
# [尝试次数：47] - [剩余数量：74] - [当前时间：11:13:40]
#
# [ok] - Part # 102.03560
# [尝试次数：3] - [剩余数量：73] - [当前时间：11:13:41]
#
# [ok] - Part # 102.02540
# [尝试次数：54] - [剩余数量：72] - [当前时间：11:13:41]
#
# [ok] - Part # 102.03630
# [尝试次数：3] - [剩余数量：71] - [当前时间：11:13:41]
#
# [ok] - Part # 102.03520
# [尝试次数：8] - [剩余数量：70] - [当前时间：11:13:42]
#
# [ok] - Part # 102.01760
# [尝试次数：85] - [剩余数量：69] - [当前时间：11:13:43]
#
# [ok] - Part # 102.03590
# [尝试次数：7] - [剩余数量：68] - [当前时间：11:13:43]
#
# [ok] - Part # 102.03530
# [尝试次数：12] - [剩余数量：67] - [当前时间：11:13:43]
#
# [ok] - Part # 102.03740
# [尝试次数：1] - [剩余数量：66] - [当前时间：11:13:44]
#
# [ok] - Part # 102.03100
# [尝试次数：34] - [剩余数量：65] - [当前时间：11:13:44]
#
# [ok] - Part # 102.02000
# [尝试次数：84] - [剩余数量：64] - [当前时间：11:13:45]
#
# [ok] - Part # 102.02960
# [尝试次数：45] - [剩余数量：63] - [当前时间：11:13:45]
#
# [ok] - Part # 102.03690
# [尝试次数：5] - [剩余数量：62] - [当前时间：11:13:45]
#
# [ok] - Part # 102.03380
# [尝试次数：18] - [剩余数量：61] - [当前时间：11:13:46]
#
# [ok] - Part # 102.03570
# [尝试次数：10] - [剩余数量：60] - [当前时间：11:13:46]
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_82967/3677071437.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_temp.loc[0, 'OE_' + key] = ';'.join(dict_oe[key])
# [ok] - Part # 102.03400
# [尝试次数：22] - [剩余数量：59] - [当前时间：11:13:46]
#
# [ok] - Part # 102.03870
# [尝试次数：1] - [剩余数量：58] - [当前时间：11:13:47]
#
# [ok] - Part # 102.03680
# [尝试次数：7] - [剩余数量：57] - [当前时间：11:13:47]
#
# [ok] - Part # 102.03750
# [尝试次数：6] - [剩余数量：56] - [当前时间：11:13:47]
#
# [ok] - Part # 102.03340
# [尝试次数：28] - [剩余数量：55] - [当前时间：11:13:48]
#
# [ok] - Part # 102.03810
# [尝试次数：6] - [剩余数量：54] - [当前时间：11:13:48]
#
# [ok] - Part # 102.03890
# [尝试次数：3] - [剩余数量：53] - [当前时间：11:13:49]
#
# [ok] - Part # 102.03700
# [尝试次数：14] - [剩余数量：52] - [当前时间：11:13:49]
#
# [ok] - Part # 102.03830
# [尝试次数：5] - [剩余数量：51] - [当前时间：11:13:49]
#
# [ok] - Part # 102.03780
# [尝试次数：10] - [剩余数量：50] - [当前时间：11:13:50]
#
# [ok] - Part # 102.03501
# [尝试次数：22] - [剩余数量：49] - [当前时间：11:13:50]
#
# [ok] - Part # 102.03770
# [尝试次数：10] - [剩余数量：48] - [当前时间：11:13:50]
#
# [ok] - Part # 102.03910
# [尝试次数：7] - [剩余数量：47] - [当前时间：11:13:50]
#
# [ok] - Part # 102.04010
# [尝试次数：3] - [剩余数量：46] - [当前时间：11:13:51]
#
# [ok] - Part # 102.03730
# [尝试次数：16] - [剩余数量：45] - [当前时间：11:13:51]
#
# [ok] - Part # 102.03940
# [尝试次数：12] - [剩余数量：44] - [当前时间：11:13:53]
#
# [ok] - Part # 102.03980
# [尝试次数：4] - [剩余数量：43] - [当前时间：11:13:53]
#
# [ok] - Part # 102.03941
# [尝试次数：8] - [剩余数量：42] - [当前时间：11:13:53]
#
# [ok] - Part # 102.04090
# [尝试次数：2] - [剩余数量：41] - [当前时间：11:13:53]
#
# [ok] - Part # 102.03760
# [尝试次数：20] - [剩余数量：40] - [当前时间：11:13:54]
#
# [ok] - Part # 102.04100
# [尝试次数：2] - [剩余数量：39] - [当前时间：11:13:54]
#
# [ok] - Part # 102.03880
# [尝试次数：11] - [剩余数量：38] - [当前时间：11:13:54]
#
# [ok] - Part # 102.03260
# [尝试次数：48] - [剩余数量：37] - [当前时间：11:13:54]
#
# [ok] - Part # 102.03670
# [尝试次数：24] - [剩余数量：36] - [当前时间：11:13:55]
#
# [ok] - Part # 102.02590
# [尝试次数：79] - [剩余数量：35] - [当前时间：11:13:55]
#
# [ok] - Part # 102.03320
# [尝试次数：43] - [剩余数量：34] - [当前时间：11:13:55]
#
# [ok] - Part # 102.04120
# [尝试次数：3] - [剩余数量：33] - [当前时间：11:13:56]
#
# [ok] - Part # 102.04190
# [尝试次数：1] - [剩余数量：32] - [当前时间：11:13:57]
#
# [ok] - Part # 102.03960
# [尝试次数：14] - [剩余数量：31] - [当前时间：11:13:58]
#
# [ok] - Part # 102.04020
# [尝试次数：13] - [剩余数量：30] - [当前时间：11:13:58]
#
# [ok] - Part # 102.03480
# [尝试次数：51] - [剩余数量：29] - [当前时间：11:13:58]
#
# [ok] - Part # 102.04080
# [尝试次数：12] - [剩余数量：28] - [当前时间：11:13:59]
#
# [ok] - Part # 102.04360
# [尝试次数：1] - [剩余数量：27] - [当前时间：11:13:59]
#
# [ok] - Part # 102.04280
# [尝试次数：5] - [剩余数量：26] - [当前时间：11:14:00]
#
# [ok] - Part # 102.04370
# [尝试次数：1] - [剩余数量：25] - [当前时间：11:14:00]
#
# [ok] - Part # 102.04191
# [尝试次数：12] - [剩余数量：24] - [当前时间：11:14:00]
#
# [ok] - Part # 102.03540
# [尝试次数：39] - [剩余数量：23] - [当前时间：11:14:00]
#
# [ok] - Part # 102.04210
# [尝试次数：12] - [剩余数量：22] - [当前时间：11:14:01]
#
# [ok] - Part # 102.04071
# [尝试次数：19] - [剩余数量：21] - [当前时间：11:14:01]
#
# [ok] - Part # 102.03820
# [尝试次数：32] - [剩余数量：20] - [当前时间：11:14:01]
#
# [ok] - Part # 102.04030
# [尝试次数：22] - [剩余数量：19] - [当前时间：11:14:01]
#
# [ok] - Part # 102.04530
# [尝试次数：1] - [剩余数量：18] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04110
# [尝试次数：10] - [剩余数量：17] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04130
# [尝试次数：20] - [剩余数量：16] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04230
# [尝试次数：13] - [剩余数量：15] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04450
# [尝试次数：4] - [剩余数量：14] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04510
# [尝试次数：4] - [剩余数量：13] - [当前时间：11:14:02]
#
# [ok] - Part # 102.04430
# [尝试次数：7] - [剩余数量：12] - [当前时间：11:14:03]
#
# [ok] - Part # 102.03990
# [尝试次数：25] - [剩余数量：11] - [当前时间：11:14:03]
#
# [ok] - Part # 102.03970
# [尝试次数：30] - [剩余数量：10] - [当前时间：11:14:03]
#
# [ok] - Part # 102.04500
# [尝试次数：6] - [剩余数量：9] - [当前时间：11:14:04]
#
# [ok] - Part # 102.04780
# [尝试次数：1] - [剩余数量：8] - [当前时间：11:14:04]
#
# [ok] - Part # 102.04710
# [尝试次数：5] - [剩余数量：7] - [当前时间：11:14:05]
#
# [ok] - Part # 102.04350
# [尝试次数：17] - [剩余数量：6] - [当前时间：11:14:05]
#
# [ok] - Part # 102.04250
# [尝试次数：21] - [剩余数量：5] - [当前时间：11:14:06]
#
# [ok] - Part # 102.03660
# [尝试次数：50] - [剩余数量：4] - [当前时间：11:14:06]
#
# [ok] - Part # 102.04860
# [尝试次数：3] - [剩余数量：3] - [当前时间：11:14:07]
#
# [ok] - Part # 102.04240
# [尝试次数：27] - [剩余数量：2] - [当前时间：11:14:07]
#
# [ok] - Part # 102.04800
# [尝试次数：5] - [剩余数量：1] - [当前时间：11:14:07]
#
# [ok] - Part # 102.04910
# [尝试次数：1] - [剩余数量：0] - [当前时间：11:14:07]
#
# [ok] - Part # 102.04550
# [尝试次数：13] - [剩余数量：0] - [当前时间：11:14:07]
#
# [ok] - Part # 102.04900
# [尝试次数：3] - [剩余数量：0] - [当前时间：11:14:08]
#
# [ok] - Part # 102.04730
# [尝试次数：5] - [剩余数量：0] - [当前时间：11:14:08]
#
# [ok] - Part # 102.04980
# [尝试次数：2] - [剩余数量：0] - [当前时间：11:14:08]
#
# [ok] - Part # 102.03900
# [尝试次数：50] - [剩余数量：0] - [当前时间：11:14:08]
#
# [ok] - Part # 102.04880
# [尝试次数：7] - [剩余数量：0] - [当前时间：11:14:09]
#
# [ok] - Part # 102.04540
# [尝试次数：20] - [剩余数量：0] - [当前时间：11:14:09]
#
# [ok] - Part # 102.04890
# [尝试次数：8] - [剩余数量：0] - [当前时间：11:14:10]
#
# [ok] - Part # 102.04310
# [尝试次数：27] - [剩余数量：0] - [当前时间：11:14:10]
#
# [ok] - Part # 102.04650
# [尝试次数：21] - [剩余数量：0] - [当前时间：11:14:10]
#
# [ok] - Part # 102.04810
# [尝试次数：14] - [剩余数量：0] - [当前时间：11:14:10]
#
# [ok] - Part # 102.04610
# [尝试次数：25] - [剩余数量：0] - [当前时间：11:14:12]
#
# [ok] - Part # 102.04590
# [尝试次数：26] - [剩余数量：0] - [当前时间：11:14:13]
#
# [ok] - Part # 102.04660
# [尝试次数：26] - [剩余数量：0] - [当前时间：11:14:13]
#
# [ok] - Part # 102.04760
# [尝试次数：22] - [剩余数量：0] - [当前时间：11:14:14]
#
# [ok] - Part # 102.04700
# [尝试次数：22] - [剩余数量：0] - [当前时间：11:14:14]
#
# [ok] - Part # 102.04170
# [尝试次数：20] - [剩余数量：0] - [当前时间：11:14:16]
#
# [ok] - Part # 102.04400
# [尝试次数：2] - [剩余数量：0] - [当前时间：11:14:20]
#
# [ok] - Part # 102.04560
# [尝试次数：1] - [剩余数量：0] - [当前时间：11:15:10]
#
# 输出ing...
#
# Done ~
