# %%
param_date = '20240623'

# %%
import pandas as pd

# %%
df_part = pd.read_excel(f'./{param_date}/part.xlsx',
                        header=0,
                        dtype=str).fillna('')

df_part
# Out:
#       Tab_No.                      Tab GroupName_No.        GroupName  \
# 0           3  Tools & Universal Parts             1  Apparel & Gifts
# 1           3  Tools & Universal Parts             1  Apparel & Gifts
# 2           3  Tools & Universal Parts             1  Apparel & Gifts
# 3           3  Tools & Universal Parts             1  Apparel & Gifts
# 4           3  Tools & Universal Parts             1  Apparel & Gifts
# ...       ...                      ...           ...              ...
# 24725       3  Tools & Universal Parts            26   Wiper & Washer
# 24726       3  Tools & Universal Parts            26   Wiper & Washer
# 24727       3  Tools & Universal Parts            26   Wiper & Washer
# 24728       3  Tools & Universal Parts            26   Wiper & Washer
# 24729       3  Tools & Universal Parts            26   Wiper & Washer
#
#       SubGroupName_No.        SubGroupName PartType_No.  \
# 0                    1    RockAuto Apparel            1
# 1                    1    RockAuto Apparel            1
# 2                    1    RockAuto Apparel            1
# 3                    1    RockAuto Apparel            1
# 4                    1    RockAuto Apparel            2
# ...                ...                 ...          ...
# 24725                7  Wiper Blade Refill           13
# 24726                7  Wiper Blade Refill           13
# 24727                8       Wiper Linkage            1
# 24728                8       Wiper Linkage            2
# 24729                9         Wiper Motor            1
#
#                PartType_Name PartType  \
# 0                        Hat      131
# 1                        Hat      131
# 2                        Hat      131
# 3                        Hat      131
# 4                     Hoodie  1002098
# ...                      ...      ...
# 24725      Cut-to-Fit Refill  1000219
# 24726      Cut-to-Fit Refill  1000219
# 24727  Wiper Linkage Bushing    10717
# 24728     Wiper Linkage Clip  1001146
# 24729    Wiper Motor Bushing    17274
#
#                                                  Tab_Url  ... Json_Vehicle  \
# 0      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 1      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 2      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 3      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 4      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# ...                                                  ...  ...          ...
# 24725  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24726  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24727  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24728  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24729  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
#
#       Vehicle                      OE  \
# 0
# 1                                 B2U
# 2                             B1U;B1L
# 3                                 B3U
# 4              H1S;H12XL;H1XL;H1L;H1M
# ...       ...                     ...
# 24725
# 24726                           17240
# 24727                          030203
# 24728
# 24729                           49450
#
#                                                   Note_1 Note_2  \
# 0      RockAuto "ALL THE PARTS YOUR CAR WILL EVER NEE...
# 1                        12" Cuffed Beanie; Heather Navy
# 2                    12" Cuffed Beanie; Heather Charcoal
# 3                              12" Cuffed Beanie; Maroon
# 4        Lightweight Hoodie; 100% Ringspun Cotton; Black
# ...                                                  ...    ...
# 24725                 Break-To-Fit Refill Set; 15" - 22"
# 24726  Break-To-Fit Refill Set; 17" - 26" Square Claw...
# 24727  Automotive Maintenance Tech Trays; Wiper Linka...
# 24728  Wiper Linkage Clip Kit; Kit contains 2 each of...
# 24729                                Wiper Motor Bushing
#
#                                                      Url  \
# 0      https://www.rockauto.com/en/parts/ROCKAUTO,BLA...
# 1      https://www.rockauto.com/en/parts/ROCKAUTO,B2,...
# 2      https://www.rockauto.com/en/parts/ROCKAUTO,B1,...
# 3      https://www.rockauto.com/en/parts/ROCKAUTO,B3,...
# 4      https://www.rockauto.com/en/parts/ROCKAUTO,H1,...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/parts/TRICO,47700,...
# 24726  https://www.rockauto.com/en/parts/TRICO,47800,...
# 24727  https://www.rockauto.com/en/parts/DORMAN,03020...
# 24728  https://www.rockauto.com/en/parts/DORMAN,49444...
# 24729  https://www.rockauto.com/en/parts/DORMAN,49450...
#
#                                                     Info  \
# 0      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 1      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 2      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 3      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 4      https://www.rockauto.com/en/moreinfo.php?pk=15...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 24726  https://www.rockauto.com/en/moreinfo.php?pk=76...
# 24727  https://www.rockauto.com/en/moreinfo.php?pk=11...
# 24728  https://www.rockauto.com/en/moreinfo.php?pk=62...
# 24729  https://www.rockauto.com/en/moreinfo.php?pk=62...
#
#                                                 Json_Src Json_Specification  \
# 0      {"0": "https://www.rockauto.com/info/999/black...
# 1      {"0": "https://www.rockauto.com/info/999/B2U_9...
# 2      {"0": "https://www.rockauto.com/info/999/B1L_9...
# 3      {"0": "https://www.rockauto.com/info/999/B3U_9...
# 4      {"0": "https://www.rockauto.com/info/999/H1.jpg"}
# ...                                                  ...                ...
# 24725  {"0": "https://www.rockauto.com/info/159/47-70...
# 24726  {"0": "https://www.rockauto.com/info/159/47-80...
# 24727  {"0": "https://www.rockauto.com/info/42/030-20...
# 24728  {"0": "https://www.rockauto.com/info/42/49444-...
# 24729  {"0": "https://www.rockauto.com/info/42/49450-...
#
#       Json_Kit
# 0
# 1
# 2
# 3
# 4
# ...        ...
# 24725
# 24726
# 24727
# 24728
# 24729
#
# [24730 rows x 28 columns]

# %%
df_vehicle = pd.read_excel(f'./{param_date}/vehicle.xlsx',
                           header=0,
                           dtype=str).fillna('')

df_vehicle
# Out:
#                                   JOIN_PTPKPNCN Json_Vehicle Vehicle
# 0              1000000;1272469;MAGPACK;ROCKAUTO           {}
# 1                   1000041;12225033;04906;DEKA           {}
# 2                   1000041;12225041;04917;DEKA           {}
# 3                   1000041;12225049;04923;DEKA           {}
# 4                   1000041;12225053;04928;DEKA           {}
# ...                                         ...          ...     ...
# 24725  99;4917816;950111;PETERSON MANUFACTURING           {}
# 24726  99;4918017;950511;PETERSON MANUFACTURING           {}
# 24727  99;4921305;950201;PETERSON MANUFACTURING           {}
# 24728  99;4921308;950231;PETERSON MANUFACTURING           {}
# 24729  99;4921311;950211;PETERSON MANUFACTURING           {}
#
# [24730 rows x 3 columns]

# %%
df_info = pd.read_excel(f'./{param_date}/info.xlsx',
                        header=0,
                        dtype=str).fillna('')

df_info
# Out:
#                                                     Info  \
# 0      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 1      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 2      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 3      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 4      https://www.rockauto.com/en/moreinfo.php?pk=10...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/moreinfo.php?pk=99...
# 24726  https://www.rockauto.com/en/moreinfo.php?pk=99...
# 24727  https://www.rockauto.com/en/moreinfo.php?pk=99...
# 24728  https://www.rockauto.com/en/moreinfo.php?pk=99...
# 24729  https://www.rockauto.com/en/moreinfo.php?pk=99...
#
#                                       Json_Specification Json_Kit
# 0      {"0": {"Centerline Length (IN)": "36"}, "1": {...       {}
# 1      {"0": {"Angle": "38"}, "1": {"Belt Material": ...       {}
# 2      {"0": {"Angle": "38"}, "1": {"Belt Material": ...       {}
# 3      {"0": {"Angle": "37"}, "1": {"Belt Material": ...       {}
# 4      {"0": {"Angle": "38"}, "1": {"Belt Material": ...       {}
# ...                                                  ...      ...
# 24725  {"0": {"Centerline Length (ft)": "50"}, "1": {...       {}
# 24726  {"0": {"Coupling Thread Size": "1/4-18NPT"}, "...       {}
# 24727  {"0": {"Coupling Thread Size": "1/4-18NPT"}, "...       {}
# 24728  {"0": {"Coupling Thread Size": "1/2-14NPT"}, "...       {}
# 24729  {"0": {"Angle": "38"}, "1": {"Belt Material": ...       {}
#
# [24730 rows x 3 columns]

# %%
df = pd.merge(left=df_part,
              right=df_vehicle,
              how='left',
              left_on='JOIN_PTPKPNCN',
              right_on='JOIN_PTPKPNCN',
              suffixes=('_part', '_vehicle')).fillna('N/A')

df = pd.merge(left=df,
              right=df_info,
              how='left',
              left_on='Info',
              right_on='Info',
              suffixes=('_part', '_info')).fillna('N/A')

df
# Out:
#       Tab_No.                      Tab GroupName_No.        GroupName  \
# 0           3  Tools & Universal Parts             1  Apparel & Gifts
# 1           3  Tools & Universal Parts             1  Apparel & Gifts
# 2           3  Tools & Universal Parts             1  Apparel & Gifts
# 3           3  Tools & Universal Parts             1  Apparel & Gifts
# 4           3  Tools & Universal Parts             1  Apparel & Gifts
# ...       ...                      ...           ...              ...
# 24725       3  Tools & Universal Parts            26   Wiper & Washer
# 24726       3  Tools & Universal Parts            26   Wiper & Washer
# 24727       3  Tools & Universal Parts            26   Wiper & Washer
# 24728       3  Tools & Universal Parts            26   Wiper & Washer
# 24729       3  Tools & Universal Parts            26   Wiper & Washer
#
#       SubGroupName_No.        SubGroupName PartType_No.  \
# 0                    1    RockAuto Apparel            1
# 1                    1    RockAuto Apparel            1
# 2                    1    RockAuto Apparel            1
# 3                    1    RockAuto Apparel            1
# 4                    1    RockAuto Apparel            2
# ...                ...                 ...          ...
# 24725                7  Wiper Blade Refill           13
# 24726                7  Wiper Blade Refill           13
# 24727                8       Wiper Linkage            1
# 24728                8       Wiper Linkage            2
# 24729                9         Wiper Motor            1
#
#                PartType_Name PartType  \
# 0                        Hat      131
# 1                        Hat      131
# 2                        Hat      131
# 3                        Hat      131
# 4                     Hoodie  1002098
# ...                      ...      ...
# 24725      Cut-to-Fit Refill  1000219
# 24726      Cut-to-Fit Refill  1000219
# 24727  Wiper Linkage Bushing    10717
# 24728     Wiper Linkage Clip  1001146
# 24729    Wiper Motor Bushing    17274
#
#                                                  Tab_Url  ... Note_2  \
# 0      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 1      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 2      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 3      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# 4      https://www.rockauto.com/en/tools/Apparel & Gi...  ...
# ...                                                  ...  ...    ...
# 24725  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24726  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24727  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24728  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
# 24729  https://www.rockauto.com/en/tools/Wiper & Wash...  ...
#
#                                                      Url  \
# 0      https://www.rockauto.com/en/parts/ROCKAUTO,BLA...
# 1      https://www.rockauto.com/en/parts/ROCKAUTO,B2,...
# 2      https://www.rockauto.com/en/parts/ROCKAUTO,B1,...
# 3      https://www.rockauto.com/en/parts/ROCKAUTO,B3,...
# 4      https://www.rockauto.com/en/parts/ROCKAUTO,H1,...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/parts/TRICO,47700,...
# 24726  https://www.rockauto.com/en/parts/TRICO,47800,...
# 24727  https://www.rockauto.com/en/parts/DORMAN,03020...
# 24728  https://www.rockauto.com/en/parts/DORMAN,49444...
# 24729  https://www.rockauto.com/en/parts/DORMAN,49450...
#
#                                                     Info  \
# 0      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 1      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 2      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 3      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 4      https://www.rockauto.com/en/moreinfo.php?pk=15...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 24726  https://www.rockauto.com/en/moreinfo.php?pk=76...
# 24727  https://www.rockauto.com/en/moreinfo.php?pk=11...
# 24728  https://www.rockauto.com/en/moreinfo.php?pk=62...
# 24729  https://www.rockauto.com/en/moreinfo.php?pk=62...
#
#                                                 Json_Src  \
# 0      {"0": "https://www.rockauto.com/info/999/black...
# 1      {"0": "https://www.rockauto.com/info/999/B2U_9...
# 2      {"0": "https://www.rockauto.com/info/999/B1L_9...
# 3      {"0": "https://www.rockauto.com/info/999/B3U_9...
# 4      {"0": "https://www.rockauto.com/info/999/H1.jpg"}
# ...                                                  ...
# 24725  {"0": "https://www.rockauto.com/info/159/47-70...
# 24726  {"0": "https://www.rockauto.com/info/159/47-80...
# 24727  {"0": "https://www.rockauto.com/info/42/030-20...
# 24728  {"0": "https://www.rockauto.com/info/42/49444-...
# 24729  {"0": "https://www.rockauto.com/info/42/49450-...
#
#       Json_Specification_part Json_Kit_part Json_Vehicle_vehicle  \
# 0                                                             {}
# 1                                                             {}
# 2                                                             {}
# 3                                                             {}
# 4                                                             {}
# ...                       ...           ...                  ...
# 24725                                                         {}
# 24726                                                         {}
# 24727                                                         {}
# 24728                                                         {}
# 24729                                                         {}
#
#       Vehicle_vehicle                            Json_Specification_info  \
# 0                                                                     {}
# 1                                                                     {}
# 2                                                                     {}
# 3                                                                     {}
# 4                                                                     {}
# ...               ...                                                ...
# 24725                  {"0": {"Adapters Included": "No"}, "1": {"Adap...
# 24726                  {"0": {"Adapters Included": "No"}, "1": {"Adap...
# 24727                  {"0": {"Package Contents": "(4) 118-301; (4) 1...
# 24728                  {"0": {"Attachment Method": "Screw On"}, "1": ...
# 24729                  {"0": {"Bushing Material": "Rubber"}, "1": {"P...
#
#       Json_Kit_info
# 0                {}
# 1                {}
# 2                {}
# 3                {}
# 4                {}
# ...             ...
# 24725            {}
# 24726            {}
# 24727            {}
# 24728            {}
# 24729            {}
#
# [24730 rows x 32 columns]

# %%
list_column = df_part.columns.tolist()

list_column[list_column.index('Json_Vehicle')] = 'Json_Vehicle_vehicle'
list_column[list_column.index('Vehicle')] = 'Vehicle_vehicle'
list_column[list_column.index('Json_Specification')] = 'Json_Specification_info'
list_column[list_column.index('Json_Kit')] = 'Json_Kit_info'

list_column
# Out:
# ['Tab_No.',
#  'Tab',
#  'GroupName_No.',
#  'GroupName',
#  'SubGroupName_No.',
#  'SubGroupName',
#  'PartType_No.',
#  'PartType_Name',
#  'PartType',
#  'Tab_Url',
#  'Part_No.',
#  'SortGroupText',
#  'CatalogName',
#  'PartNumber',
#  'Part_PartType',
#  'PartKey',
#  'JOIN_PTPKPNCN',
#  'ParamDesc',
#  'Json_Vehicle_vehicle',
#  'Vehicle_vehicle',
#  'OE',
#  'Note_1',
#  'Note_2',
#  'Url',
#  'Info',
#  'Json_Src',
#  'Json_Specification_info',
#  'Json_Kit_info']

# %%
df = df[list_column]

list_column[list_column.index('Json_Vehicle_vehicle')] = 'Json_Vehicle'
list_column[list_column.index('Vehicle_vehicle')] = 'Vehicle'
list_column[list_column.index('Json_Specification_info')] = 'Json_Specification'
list_column[list_column.index('Json_Kit_info')] = 'Json_Kit'

df.columns = list_column

df['Tab_No.'] = df['Tab_No.'].astype(int)
df['GroupName_No.'] = df['GroupName_No.'].astype(int)
df['SubGroupName_No.'] = df['SubGroupName_No.'].astype(int)
df['PartType_No.'] = df['PartType_No.'].astype(int)
df['Part_No.'] = df['Part_No.'].astype(int)

df.to_excel(f'''./{param_date}/4.part.xlsx''', index=False)

df
# Out:
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_50482/3350271461.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tab_No.'] = df['Tab_No.'].astype(int)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_50482/3350271461.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GroupName_No.'] = df['GroupName_No.'].astype(int)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_50482/3350271461.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SubGroupName_No.'] = df['SubGroupName_No.'].astype(int)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_50482/3350271461.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PartType_No.'] = df['PartType_No.'].astype(int)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_50482/3350271461.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Part_No.'] = df['Part_No.'].astype(int)
#        Tab_No.                      Tab  GroupName_No.        GroupName  \
# 0            3  Tools & Universal Parts              1  Apparel & Gifts
# 1            3  Tools & Universal Parts              1  Apparel & Gifts
# 2            3  Tools & Universal Parts              1  Apparel & Gifts
# 3            3  Tools & Universal Parts              1  Apparel & Gifts
# 4            3  Tools & Universal Parts              1  Apparel & Gifts
# ...        ...                      ...            ...              ...
# 24725        3  Tools & Universal Parts             26   Wiper & Washer
# 24726        3  Tools & Universal Parts             26   Wiper & Washer
# 24727        3  Tools & Universal Parts             26   Wiper & Washer
# 24728        3  Tools & Universal Parts             26   Wiper & Washer
# 24729        3  Tools & Universal Parts             26   Wiper & Washer
#
#        SubGroupName_No.        SubGroupName  PartType_No.  \
# 0                     1    RockAuto Apparel             1
# 1                     1    RockAuto Apparel             1
# 2                     1    RockAuto Apparel             1
# 3                     1    RockAuto Apparel             1
# 4                     1    RockAuto Apparel             2
# ...                 ...                 ...           ...
# 24725                 7  Wiper Blade Refill            13
# 24726                 7  Wiper Blade Refill            13
# 24727                 8       Wiper Linkage             1
# 24728                 8       Wiper Linkage             2
# 24729                 9         Wiper Motor             1
#
#                PartType_Name PartType  \
# 0                        Hat      131
# 1                        Hat      131
# 2                        Hat      131
# 3                        Hat      131
# 4                     Hoodie  1002098
# ...                      ...      ...
# 24725      Cut-to-Fit Refill  1000219
# 24726      Cut-to-Fit Refill  1000219
# 24727  Wiper Linkage Bushing    10717
# 24728     Wiper Linkage Clip  1001146
# 24729    Wiper Motor Bushing    17274
#
#                                                  Tab_Url  ...  Json_Vehicle  \
# 0      https://www.rockauto.com/en/tools/Apparel & Gi...  ...            {}
# 1      https://www.rockauto.com/en/tools/Apparel & Gi...  ...            {}
# 2      https://www.rockauto.com/en/tools/Apparel & Gi...  ...            {}
# 3      https://www.rockauto.com/en/tools/Apparel & Gi...  ...            {}
# 4      https://www.rockauto.com/en/tools/Apparel & Gi...  ...            {}
# ...                                                  ...  ...           ...
# 24725  https://www.rockauto.com/en/tools/Wiper & Wash...  ...            {}
# 24726  https://www.rockauto.com/en/tools/Wiper & Wash...  ...            {}
# 24727  https://www.rockauto.com/en/tools/Wiper & Wash...  ...            {}
# 24728  https://www.rockauto.com/en/tools/Wiper & Wash...  ...            {}
# 24729  https://www.rockauto.com/en/tools/Wiper & Wash...  ...            {}
#
#       Vehicle                      OE  \
# 0
# 1                                 B2U
# 2                             B1U;B1L
# 3                                 B3U
# 4              H1S;H12XL;H1XL;H1L;H1M
# ...       ...                     ...
# 24725
# 24726                           17240
# 24727                          030203
# 24728
# 24729                           49450
#
#                                                   Note_1 Note_2  \
# 0      RockAuto "ALL THE PARTS YOUR CAR WILL EVER NEE...
# 1                        12" Cuffed Beanie; Heather Navy
# 2                    12" Cuffed Beanie; Heather Charcoal
# 3                              12" Cuffed Beanie; Maroon
# 4        Lightweight Hoodie; 100% Ringspun Cotton; Black
# ...                                                  ...    ...
# 24725                 Break-To-Fit Refill Set; 15" - 22"
# 24726  Break-To-Fit Refill Set; 17" - 26" Square Claw...
# 24727  Automotive Maintenance Tech Trays; Wiper Linka...
# 24728  Wiper Linkage Clip Kit; Kit contains 2 each of...
# 24729                                Wiper Motor Bushing
#
#                                                      Url  \
# 0      https://www.rockauto.com/en/parts/ROCKAUTO,BLA...
# 1      https://www.rockauto.com/en/parts/ROCKAUTO,B2,...
# 2      https://www.rockauto.com/en/parts/ROCKAUTO,B1,...
# 3      https://www.rockauto.com/en/parts/ROCKAUTO,B3,...
# 4      https://www.rockauto.com/en/parts/ROCKAUTO,H1,...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/parts/TRICO,47700,...
# 24726  https://www.rockauto.com/en/parts/TRICO,47800,...
# 24727  https://www.rockauto.com/en/parts/DORMAN,03020...
# 24728  https://www.rockauto.com/en/parts/DORMAN,49444...
# 24729  https://www.rockauto.com/en/parts/DORMAN,49450...
#
#                                                     Info  \
# 0      https://www.rockauto.com/en/moreinfo.php?pk=10...
# 1      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 2      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 3      https://www.rockauto.com/en/moreinfo.php?pk=15...
# 4      https://www.rockauto.com/en/moreinfo.php?pk=15...
# ...                                                  ...
# 24725  https://www.rockauto.com/en/moreinfo.php?pk=10...
# 24726  https://www.rockauto.com/en/moreinfo.php?pk=76...
# 24727  https://www.rockauto.com/en/moreinfo.php?pk=11...
# 24728  https://www.rockauto.com/en/moreinfo.php?pk=62...
# 24729  https://www.rockauto.com/en/moreinfo.php?pk=62...
#
#                                                 Json_Src  \
# 0      {"0": "https://www.rockauto.com/info/999/black...
# 1      {"0": "https://www.rockauto.com/info/999/B2U_9...
# 2      {"0": "https://www.rockauto.com/info/999/B1L_9...
# 3      {"0": "https://www.rockauto.com/info/999/B3U_9...
# 4      {"0": "https://www.rockauto.com/info/999/H1.jpg"}
# ...                                                  ...
# 24725  {"0": "https://www.rockauto.com/info/159/47-70...
# 24726  {"0": "https://www.rockauto.com/info/159/47-80...
# 24727  {"0": "https://www.rockauto.com/info/42/030-20...
# 24728  {"0": "https://www.rockauto.com/info/42/49444-...
# 24729  {"0": "https://www.rockauto.com/info/42/49450-...
#
#                                       Json_Specification Json_Kit
# 0                                                     {}       {}
# 1                                                     {}       {}
# 2                                                     {}       {}
# 3                                                     {}       {}
# 4                                                     {}       {}
# ...                                                  ...      ...
# 24725  {"0": {"Adapters Included": "No"}, "1": {"Adap...       {}
# 24726  {"0": {"Adapters Included": "No"}, "1": {"Adap...       {}
# 24727  {"0": {"Package Contents": "(4) 118-301; (4) 1...       {}
# 24728  {"0": {"Attachment Method": "Screw On"}, "1": ...       {}
# 24729  {"0": {"Bushing Material": "Rubber"}, "1": {"P...       {}
#
# [24730 rows x 28 columns]
