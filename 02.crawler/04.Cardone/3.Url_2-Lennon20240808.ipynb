# %%
import pandas as pd

input_ = pd.read_excel('./2.url.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['1st Category No'] = input_['1st Category No'].astype(int)
input_['2nd Category No'] = input_['2nd Category No'].astype(int)
input_['3rd Category No'] = input_['3rd Category No'].astype(int)
input_['Page'] = input_['Page'].astype(int)
input_['No'] = input_['No'].astype(int)

input_
# Out:
#        1st Category No 1st Category                 1st Category Url  \
# 0                    1       Brakes  https://www.cardone.com/brakes/
# 1                    1       Brakes  https://www.cardone.com/brakes/
# 2                    1       Brakes  https://www.cardone.com/brakes/
# 3                    1       Brakes  https://www.cardone.com/brakes/
# 4                    1       Brakes  https://www.cardone.com/brakes/
# ...                ...          ...                              ...
# 39108                7       Motors  https://www.cardone.com/motors/
# 39109                7       Motors  https://www.cardone.com/motors/
# 39110                7       Motors  https://www.cardone.com/motors/
# 39111                7       Motors  https://www.cardone.com/motors/
# 39112                7       Motors  https://www.cardone.com/motors/
#
#        2nd Category No      2nd Category  \
# 0                    1    ABS Components
# 1                    1    ABS Components
# ...

# %%
output = input_.drop_duplicates(['Url'],
                                keep='first',
                                ignore_index=True)

output['No'] = [_+1 for _ in range(len(output))]
output[['No', 'Url']].to_excel('./3.url_2.xlsx', index=False)

output
# Out:
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_2374/741756477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['No'] = [_+1 for _ in range(len(output))]
#        1st Category No 1st Category                 1st Category Url  \
# 0                    1       Brakes  https://www.cardone.com/brakes/
# 1                    1       Brakes  https://www.cardone.com/brakes/
# 2                    1       Brakes  https://www.cardone.com/brakes/
# 3                    1       Brakes  https://www.cardone.com/brakes/
# 4                    1       Brakes  https://www.cardone.com/brakes/
# ...                ...          ...                              ...
# 38252                7       Motors  https://www.cardone.com/motors/
# ...

# %%
output = input_.drop_duplicates(['1st Category No', '1st Category', '1st Category Url', '2nd Category No', '2nd Category', '2nd Category Url', '3rd Category No', '3rd Category', '3rd Category Url'],
                                keep='last',
                                ignore_index=True)

list_column = ['SKU Count' if _ == 'No' else _ for _ in output.columns]
output.columns = list_column
output[['1st Category No',
        '1st Category',
        '1st Category Url',
        '2nd Category No',
        '2nd Category',
        '2nd Category Url',
        '3rd Category No',
        '3rd Category',
        '3rd Category Url',
        'SKU Count']].to_excel('./3.catalog.xlsx', index=False)

output
# Out:
#      1st Category No 1st Category                 1st Category Url  \
# 0                  1       Brakes  https://www.cardone.com/brakes/
# 1                  1       Brakes  https://www.cardone.com/brakes/
# 2                  1       Brakes  https://www.cardone.com/brakes/
# 3                  1       Brakes  https://www.cardone.com/brakes/
# 4                  1       Brakes  https://www.cardone.com/brakes/
# ..               ...          ...                              ...
# 105                7       Motors  https://www.cardone.com/motors/
# 106                7       Motors  https://www.cardone.com/motors/
# 107                7       Motors  https://www.cardone.com/motors/
# 108                7       Motors  https://www.cardone.com/motors/
# 109                7       Motors  https://www.cardone.com/motors/
#
#      2nd Category No            2nd Category  \
# 0                  1          ABS Components
# 1                  1          ABS Components
# ...
