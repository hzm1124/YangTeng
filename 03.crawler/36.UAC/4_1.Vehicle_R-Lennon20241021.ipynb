# %%
import os

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

import json

# %%
directory_in = './file/1.part'

list_file = [file for file in sorted(os.listdir(directory_in)) if file not in ['.DS_Store'] and os.path.isfile(f'{directory_in}/{file}')]
file = list_file[0]

file
# Out:
# 'crawler_1.xlsx'

# %%
list_dict_correct, list_series_error, df_input = [], [], pd.read_excel(f'{directory_in}/{file}',
                                                                       header=0,
                                                                       dtype=str).fillna('')

count_remain = len(df_input)

print(f'总数量：{count_remain}')
print()
df_input
# Out:
# 总数量：10
#   Part Number [UAC] Part Number [UAC] Picture  \
# 0    HA10018C         HA 10018C
# 1    HA10020C         HA 10020C
# 2    HA10021C         HA 10021C
# 3    HA10022C         HA 10022C
# 4    HA10029C         HA 10029C
# 5    HA10034C         HA 10034C
# 6    HA10038C         HA 10038C
# 7    HA10040C         HA 10040C
# 8    HA10066C         HA 10066C
# 9    HA10068C         HA 10068C
#
#                                            [UAC] Url  \
# 0  https://uacparts.com/Catalog/SearchIndex?searc...
# 1  https://uacparts.com/Catalog/SearchIndex?searc...
# 2  https://uacparts.com/Catalog/SearchIndex?searc...
# 3  https://uacparts.com/Catalog/SearchIndex?searc...
# 4  https://uacparts.com/Catalog/SearchIndex?searc...
# 5  https://uacparts.com/Catalog/SearchIndex?searc...
# 6  https://uacparts.com/Catalog/SearchIndex?searc...
# 7  https://uacparts.com/Catalog/SearchIndex?searc...
# 8  https://uacparts.com/Catalog/SearchIndex?searc...
# 9  https://uacparts.com/Catalog/SearchIndex?searc...
#
#                                       [UAC] Json_Src  \
# 0  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 1  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 2  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 3  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 4  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 5  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 6  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 7  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 8  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
# 9  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
#
#                            [UAC] Json_Note
# 0  {"0": "Accumulator with Hose Assembly"}
# 1  {"0": "Accumulator with Hose Assembly"}
# 2  {"0": "Accumulator with Hose Assembly"}
# 3  {"0": "Accumulator with Hose Assembly"}
# 4  {"0": "Accumulator with Hose Assembly"}
# 5  {"0": "Accumulator with Hose Assembly"}
# 6  {"0": "Accumulator with Hose Assembly"}
# 7  {"0": "Accumulator with Hose Assembly"}
# 8  {"0": "Accumulator with Hose Assembly"}
# 9  {"0": "Accumulator with Hose Assembly"}

# %%
crawler_status, (crawler_index, crawler_series) = False, next(df_input.iterrows())

crawler_status, crawler_index, crawler_series
# Out:
# (False,
#  0,
#  Part Number                                                   HA10018C
#  [UAC] Part Number                                            HA 10018C
#  [UAC] Picture
#  [UAC] Url            https://uacparts.com/Catalog/SearchIndex?searc...
#  [UAC] Json_Src       {"0": "https://www.uacparts.com/photo/WEBP/HA/...
#  [UAC] Json_Note                {"0": "Accumulator with Hose Assembly"}
#  Name: 0, dtype: object)

# %%
import time

count_retry = 0
while True:
    count_retry += 1
    print(count_retry)
    try:
        url_check = crawler_series['[UAC] Url']

        resp = requests.get(f'https://uacparts.com/Catalog/Buyers?part={crawler_series['[UAC] Part Number']}',
                            headers=get_header(),
                            proxies=get_proxy(),
                            timeout=(5, 15))

        if resp.status_code == 200:
            soup = BeautifulSoup(resp.text, 'lxml')
            html = etree.HTML(str(soup))

            if html.xpath('//form[@action="/Catalog/Buyers"]'):
                with open('./vehicle.html', 'w', encoding='UTF-8') as file:
                    file.write(str(soup))
                break
    except KeyboardInterrupt:
        break
    except:
        time.sleep(3)
        continue

print(soup.prettify())
# Out:
# 1
# <html>
#  <body>
#   <div>
#    <br/>
#   </div>
#   <form action="/Catalog/Buyers" method="post">
#    <div>
#     <table class="awe-grid table">
#      <tr class="awe-row" id="xrefHA 10018C">
#       <td class="awe-grid td">
#        1993
#       </td>
#       <td class="awe-grid td">
#        Ford
#       </td>
#       <td class="awe-grid td">
#        Mustang
#       </td>
#       <td class="awe-grid td">
#        LX
#       </td>
#       <td class="awe-grid td">
#        L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M
#       </td>
#      </tr>
#      <tr class="awe-row" id="xrefHA 10018C">
#       <td class="awe-grid td">
#        1992
#       </td>
#       <td class="awe-grid td">
#        Ford
#       </td>
#       <td class="awe-grid td">
#        Mustang
#       </td>
#       <td class="awe-grid td">
#        LX
#       </td>
#       <td class="awe-grid td">
#        L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M
#       </td>
#      </tr>
#      <tr class="awe-row" id="xrefHA 10018C">
#       <td class="awe-grid td">
#        1991
#       </td>
#       <td class="awe-grid td">
#        Ford
#       </td>
#       <td class="awe-grid td">
#        Mustang
#       </td>
#       <td class="awe-grid td">
#        LX
#       </td>
#       <td class="awe-grid td">
#        L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M
#       </td>
#      </tr>
#      <tr class="awe-row" id="xrefHA 10018C">
#       <td class="awe-grid td">
#        1990
#       </td>
#       <td class="awe-grid td">
#        Ford
#       </td>
#       <td class="awe-grid td">
#        Mustang
#       </td>
#       <td class="awe-grid td">
#        LX
#       </td>
#       <td class="awe-grid td">
#        L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A
#       </td>
#      </tr>
#      <tr class="awe-row" id="xrefHA 10018C">
#       <td class="awe-grid td">
#        1989
#       </td>
#       <td class="awe-grid td">
#        Ford
#       </td>
#       <td class="awe-grid td">
#        Mustang
#       </td>
#       <td class="awe-grid td">
#        LX
#       </td>
#       <td class="awe-grid td">
#        L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A
#       </td>
#      </tr>
#     </table>
#    </div>
#   </form>
#  </body>
# </html>

# %%
list_tr = html.xpath('//tr[@class="awe-row"]')

list_tr
# Out:
# [<Element tr at 0x107eaf540>,
#  <Element tr at 0x1203ccb40>,
#  <Element tr at 0x1203ce1c0>,
#  <Element tr at 0x1203ce100>,
#  <Element tr at 0x1203cc980>]

# %%
list_dict_correct_temp = []
for i, tr in enumerate(list_tr):
    list_td = tr.xpath('./td')
    list_dict_correct_temp.append({'[UAC] Part Number': crawler_series['[UAC] Part Number'],
                                   'Vehicle No': i + 1,
                                   'Year': int(list_td[0].xpath('./text()')[0]) if list_td[0].xpath('./text()') else '',
                                   'Make': list_td[1].xpath('./text()')[0] if list_td[1].xpath('./text()') else '',
                                   'Model': list_td[2].xpath('./text()')[0] if list_td[2].xpath('./text()') else '',
                                   'Submodel': list_td[3].xpath('./text()')[0] if list_td[3].xpath('./text()') else '',
                                   'Engine': list_td[4].xpath('./text()')[0] if list_td[4].xpath('./text()') else ''})

list_dict_correct_temp
# Out:
# [{'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 1,
#   'Year': 1993,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 2,
#   'Year': 1992,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 3,
#   'Year': 1991,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 4,
#   'Year': 1990,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 5,
#   'Year': 1989,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A'}]

# %%
list_dict_correct.extend(list_dict_correct_temp)

list_dict_correct
# Out:
# [{'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 1,
#   'Year': 1993,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 2,
#   'Year': 1992,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 3,
#   'Year': 1991,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:M'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 4,
#   'Year': 1990,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A'},
#  {'[UAC] Part Number': 'HA 10018C',
#   'Vehicle No': 5,
#   'Year': 1989,
#   'Make': 'Ford',
#   'Model': 'Mustang',
#   'Submodel': 'LX',
#   'Engine': 'L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Aspirated GAS VIN:A'}]

# %%
crawler_status = True

crawler_status
# Out:
# True

# %%
crawler_series['Check_Url'] = url_check

list_series_error.append(crawler_series)

list_series_error
# Out:
# [Part Number                                                   HA10018C
#  [UAC] Part Number                                            HA 10018C
#  [UAC] Picture
#  [UAC] Url            https://uacparts.com/Catalog/SearchIndex?searc...
#  [UAC] Json_Src       {"0": "https://www.uacparts.com/photo/WEBP/HA/...
#  [UAC] Json_Note                {"0": "Accumulator with Hose Assembly"}
#  Check_Url            https://uacparts.com/Catalog/SearchIndex?searc...
#  Name: 0, dtype: object]

# %%
if list_dict_correct:
    df_correct = pd.DataFrame(list_dict_correct).sort_values(by=['[UAC] Part Number'],
                                                             ascending=[True],
                                                             ignore_index=True)
    df_correct.to_excel('./test_vehicle.xlsx', index=False)

df_correct
# Out:
#   [UAC] Part Number  Vehicle No  Year  Make    Model Submodel  \
# 0         HA 10018C           1  1993  Ford  Mustang       LX
# 1         HA 10018C           2  1992  Ford  Mustang       LX
# 2         HA 10018C           3  1991  Ford  Mustang       LX
# 3         HA 10018C           4  1990  Ford  Mustang       LX
# 4         HA 10018C           5  1989  Ford  Mustang       LX
#
#                                               Engine
# 0  L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Asp...
# 1  L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Asp...
# 2  L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Asp...
# 3  L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Asp...
# 4  L4 CC:- CID:140 2.3L SOHC FI MFI Naturally Asp...

# %%
if list_series_error:
    df_error = pd.DataFrame(list_series_error).sort_values(by=['[UAC] Part Number'],
                                                           ascending=[True],
                                                           ignore_index=True)
    df_error.to_excel('./test_vehicle_error.xlsx', index=False)

df_error
# Out:
#   Part Number [UAC] Part Number [UAC] Picture  \
# 0    HA10018C         HA 10018C
#
#                                            [UAC] Url  \
# 0  https://uacparts.com/Catalog/SearchIndex?searc...
#
#                                       [UAC] Json_Src  \
# 0  {"0": "https://www.uacparts.com/photo/WEBP/HA/...
#
#                            [UAC] Json_Note  \
# 0  {"0": "Accumulator with Hose Assembly"}
#
#                                            Check_Url
# 0  https://uacparts.com/Catalog/SearchIndex?searc...
