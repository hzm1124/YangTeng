# %%
auth = '757F054AA22E1711B598A89EB276EDC193933EC8'

list_appid = ['tfy6d12dc-19a5-4093-9f00-f276d950f77',
              'picheng11-5163-4258-be21-a5629527a07',
              'Shanghai-b2aa-4eed-82c3-b1e42e2e9179',
              'danjidin-f8b1-4e84-adce-026944025ceb',
              'ibay365a-b93e-46e7-8b46-6a33b716ab2a',
              '-IBAY365-PRD-08e35c535-85b731b3']

# %%
import pandas as pd

df_menu = pd.read_excel('./item.xlsx')
list_item = df_menu['Item'].to_list()

print(len(list_item))
list_item
# Out:
# 346
# [225368940813,
#  224809577294,
#  225493258153,
#  225564015400,
#  225373307546,
#  225028309731,
#  234999281212,
#  235019172985,
#  225577780443,
#  225469518815,
#  225320234355,
#  364256578345,
#  225504170402,
#  234999204743,
#  225283836979,
#  235019173058,
#  225296697232,
#  225585626583,
#  364267596104,
#  364267596117,
#  364245451490,
#  225504561990,
#  225209133034,
#  225423810497,
#  364267596186,
#  364266234986,
#  364249296056,
#  364267596424,
#  235019173335,
#  235016695181,
#  225585627065,
#  225450684967,
#  225448126365,
#  225579182407,
#  225498996368,
#  225498996849,
#  225452949041,
#  364267596271,
#  235019184015,
#  364268291658,
#  225565885827,
#  225581784218,
#  225493257887,
#  235019172987,
#  225585626963,
#  364267612319,
#  235007987754,
#  225496177022,
#  225572935164,
#  235011532109,
#  225547042825,
#  225584385453,
#  225450685730,
#  225547779183,
#  225549214616,
#  364248057882,
#  234999306938,
#  225580445606,
#  225459421047,
#  225457130193,
#  364267616187,
#  235001708395,
#  364253697690,
#  225493258251,
#  364265495402,
#  364264638565,
#  235011536684,
#  364241560177,
#  225585124786,
#  225567366105,
#  364254660423,
#  364257756028,
#  225572310665,
#  225501439203,
#  225584385328,
#  364263282596,
#  225445707682,
#  235016673755,
#  364266248650,
#  235011532284,
#  225406850562,
#  235010328349,
#  225450648687,
#  225448196906,
#  225566693563,
#  225495049656,
#  225547042004,
#  235010311200,
#  234994993685,
#  364255216343,
#  225501463659,
#  225565958890,
#  225551513550,
#  225511852210,
#  364261695122,
#  225493258019,
#  235006712974,
#  225582985435,
#  235004148890,
#  364261718157,
#  225584385513,
#  235019183962,
#  225450685096,
#  225585124692,
#  364253755984,
#  364253831004,
#  225280291157,
#  225457131556,
#  225574064320,
#  225581833224,
#  225564263519,
#  364236950262,
#  225574083892,
#  225582973784,
#  225577780577,
#  225565957829,
#  225564317246,
#  225508427680,
#  364254651373,
#  225450695567,
#  225505052803,
#  225567362040,
#  235015469807,
#  364248038419,
#  364263224112,
#  225564263696,
#  225498996932,
#  235004297867,
#  225576178753,
#  225563982668,
#  364249296105,
#  235006726967,
#  225450685085,
#  364236946800,
#  225373001720,
#  235007196513,
#  225563996808,
#  364245503183,
#  225565112597,
#  225547042269,
#  225564263843,
#  225444029460,
#  364252201281,
#  364263282796,
#  225549214584,
#  234999204611,
#  235001145053,
#  364245503137,
#  364245502815,
#  364257775950,
#  234999204775,
#  225576678248,
#  225581821612,
#  225567398551,
#  225581833214,
#  364245555816,
#  225501455384,
#  234991088365,
#  225570958641,
#  234997464029,
#  225493516781,
#  364248093414,
#  225574097711,
#  235004148835,
#  225559762309,
#  225572935274,
#  364248052354,
#  225547778998,
#  225571617070,
#  225501463830,
#  225547042829,
#  225451798709,
#  225576663922,
#  225497403056,
#  225501463819,
#  364241582428,
#  234989828834,
#  234993619298,
#  225564433259,
#  225457123941,
#  225501462809,
#  225498996598,
#  225449424264,
#  225496177368,
#  225547042704,
#  225445707713,
#  225551501615,
#  225503198671,
#  225450684664,
#  225564163934,
#  225450684501,
#  225501439353,
#  225508427828,
#  364245492859,
#  234999274048,
#  225501463468,
#  364239062509,
#  364235753701,
#  225547042936,
#  225573333365,
#  225585645612,
#  235006781789,
#  225459421236,
#  234999195653,
#  225505053089,
#  235015427957,
#  225457131455,
#  225564317507,
#  225498996729,
#  235006740595,
#  225450685351,
#  225549214670,
#  364257776028,
#  364250759217,
#  364245555965,
#  225564015213,
#  364253757181,
#  234989828768,
#  225557180896,
#  364246859341,
#  225498996484,
#  225450684975,
#  364236950345,
#  225449424464,
#  225450684804,
#  225564164011,
#  225546518006,
#  225547042996,
#  225557180991,
#  225494229600,
#  364245516539,
#  225552781858,
#  225501463561,
#  225488683415,
#  225546548270,
#  234995425744,
#  225585687421,
#  225547043190,
#  235009330286,
#  364256628090,
#  225563982736,
#  225513692587,
#  235016711742,
#  225570305044,
#  225546547778,
#  225558981542,
#  225547043210,
#  225575575803,
#  235004247560,
#  225501439474,
#  225546548704,
#  225547791936,
#  225575552573,
#  234999221420,
#  225450684958,
#  225553512271,
#  364245492446,
#  225455011892,
#  225546549580,
#  225501438839,
#  225501439844,
#  364264693448,
#  225547043172,
#  225550247261,
#  225547043154,
#  225547043006,
#  225501438962,
#  225558980996,
#  225546548022,
#  225573333097,
#  225501439098,
#  234999306685,
#  364245556054,
#  225501439243,
#  364245594878,
#  225509990946,
#  225510006888,
#  225501439924,
#  225450685407,
#  225564263318,
#  225549582970,
#  225450670561,
#  225501439695,
#  364253830145,
#  225572984366,
#  235006781320,
#  225572984429,
#  364263222786,
#  225546517776,
#  364263223875,
#  364263222864,
#  225580445935,
#  225581769710,
#  225581769440,
#  364263223294,
#  364263223988,
#  235010334136,
#  364250759129,
#  235010334566,
#  225549214546,
#  225573333258,
#  364239062168,
#  225459421123,
#  235000562977,
#  225450685859,
#  225450685129,
#  225547791427,
#  225575552609,
#  225546548503,
#  235007976408,
#  225546548837,
#  225546547893,
#  225558981397,
#  225450685298,
#  235002924136,
#  225557807005,
#  225547791651,
#  225558981487,
#  225564329732,
#  225450670962,
#  225557180936,
#  225573333211,
#  235006741082,
#  225572935438,
#  225459421178,
#  364253757892,
#  364246859121,
#  235000563015,
#  364246859175,
#  364256628155,
#  225547043175,
#  225547793052,
#  225547043205,
#  225575552671,
#  225546548128,
#  225450684824,
#  225546549830,
#  225546549040,
#  225576704735,
#  234995425592,
#  364240763837,
#  234999331913,
#  234995426551,
#  225558981394,
#  225450685106,
#  225450684636]

# %%
df = pd.DataFrame(columns=['Item',
                           'Title',
                           'Price',
                           'Sold',
                           'Vehicle',
                           'Url',
                           'Src',
                           'status'])

# %%
import random
import requests
import json

# %%
i = 0

index_appid = random.randint(0, 5)

developer = 'http://106.75.138.2/index.php/api/GetAppToken?auth=' + auth + '&appid=' + list_appid[index_appid]
resp = requests.get(developer).text
token = json.loads(resp)['getapptokenResponse']['token']

token
# Out:
# 'v^1.1#i^1#r^0#p^1#I^3#f^0#t^...'

# %%
headers = {'X-EBAY-API-IAF-TOKEN': token}
resp = requests.get('https://open.api.ebay.com/shopping?callname=GetSingleItem&appid=' + list_appid[index_appid] + '&responseencoding=JSON&siteid=0&version=967&IncludeSelector=Details,Compatibility,ItemSpecifics&ItemID=' + str(list_item[i]), headers=headers).text

info = json.loads(resp)
if info['Ack'] == 'Success':
    print('Success')
else:
    print('Error')
# Out:
# Success

# %%
json.loads(resp)
# Out:
# {'Timestamp': '2023-05-22T00:56:30.764Z',
#  'Ack': 'Success',
#  'Build': '1299_CORE_APILW_19146596_R1',
#  'Version': '1299',
#  'Item': {'BestOfferEnabled': False,
#   'ItemID': '225368940813',
#   'EndTime': '2023-05-22T07:24:05.000Z',
#   'StartTime': '2023-01-22T08:24:05.000Z',
#   'ViewItemURLForNaturalSearch': 'https://www.ebay.com/itm/Honda-CRV-Intercooler-2017-2018-2019-1-5T-HO3012101-19710-5PA-A01-/225368940813',
#   'ListingType': 'FixedPriceItem',
#   'Location': 'South Plainfield, New Jersey',
#   'PaymentMethods': [],
#   'GalleryURL': 'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYAAOSwJ7BjzPKp/$_12.PNG?set_id=880000500F',
#   'PictureURL': ['https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYAAOSwJ7BjzPKp/$_12.PNG?set_id=880000500F',
#    'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/P0YAAOSwZwRjzPKn/$_1.JPG?set_id=880000500F',
#    'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/UksAAOSwFORjzPKo/$_1.JPG?set_id=880000500F',
#    'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/on8AAOSwxcFjzPKn/$_1.JPG?set_id=880000500F',
#    'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/oEQAAOSwVkFjzPKo/$_1.JPG?set_id=880000500F',
#    'https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/-ugAAOSwlr1jzPKo/$_1.JPG?set_id=880000500F'],
#   'PostalCode': '070**',
#   'PrimaryCategoryID': '33742',
#   'PrimaryCategoryName': 'eBay Motors:Parts & Accessories:Car & Truck Parts & Accessories:Air & Fuel Delivery:Turbos, Superchargers & Intercoolers:Turbos & Parts',
#   'Quantity': 11,
#   'Seller': {'UserID': 'carlights360',
#    'FeedbackRatingStar': 'TurquoiseShooting',
#    'FeedbackScore': 36942,
#    'PositiveFeedbackPercent': 98.6,
#    'TopRatedSeller': True},
#   'BidCount': 0,
#   'ConvertedCurrentPrice': {'Value': 125.36, 'CurrencyID': 'USD'},
#   'CurrentPrice': {'Value': 125.36, 'CurrencyID': 'USD'},
#   'ListingStatus': 'Active',
#   'QuantitySold': 6,
#   'ShipToLocations': ['Americas'],
#   'Site': 'eBayMotors',
#   'TimeLeft': 'PT6H27M35S',
#   'Title': 'For Honda CRV Intercooler 2017 2018 2019 | 1.5T For HO3012101 | 19710-5PA-A01',
#   'ItemSpecifics': {'NameValueList': [{'Name': 'Brand',
#      'Value': ['KarParts360']},
#     {'Name': 'Features', 'Value': ['Easy Installation']},
#     {'Name': 'Manufacturer Part Number', 'Value': ['CLX-M0-18097-CL360A55']},
#     {'Name': 'OE/OEM Part Number', 'Value': ['19710-5PA-A01']},
#     {'Name': 'Country/Region of Manufacture', 'Value': ['Taiwan']},
#     {'Name': 'Item Width', 'Value': ['8.070']},
#     {'Name': 'Item Length', 'Value': ['39.170']},
#     {'Name': 'Interchange Part Number', 'Value': ['HO3012101']},
#     {'Name': 'Ballast Included', 'Value': ['No']},
#     {'Name': 'Fitment Type', 'Value': ['Direct Replacement']},
#     {'Name': 'Generic_Keywords 1', 'Value': ['2017-2019|HONDA|CR-V::1.5T^^']},
#     {'Name': 'Generic_Keywords 2', 'Value': ['See Notes']},
#     {'Name': 'Intended Use', 'Value': ['Automobiles']},
#     {'Name': 'Misc Fitment Notes', 'Value': ['See Notes']},
#     {'Name': 'OEM Equivalent Part Number 1', 'Value': ['19710-5PA-A01']},
#     {'Name': 'PARTSLINK Number', 'Value': ['HO3012101']},
#     {'Name': 'Placement on Vehicle', 'Value': ['Front']},
#     {'Name': 'Side', 'Value': ['Driver Or Passenger Side']},
#     {'Name': 'Manufacturer Warranty', 'Value': ['1 Year']}]},
#   'Subtitle': '✔Fast Shipping ✔Perfect Fitment ✔Hassle Free Returns',
#   'PrimaryCategoryIDPath': '6000:6028:6030:33549:174107:33742',
#   'Storefront': {'StoreURL': 'https://www.ebay.com/str/autolights360',
#    'StoreName': 'CarLights360'},
#   'Country': 'US',
#   'ReturnPolicy': {'ReturnsWithin': '30 Days',
#    'ReturnsAccepted': 'Returns Accepted',
#    'ShippingCostPaidBy': 'Seller'},
#   'AutoPay': True,
#   'PaymentAllowedSite': [],
#   'IntegratedMerchantCreditCardEnabled': False,
#   'HandlingTime': 0,
#   'ConditionID': 1000,
#   'ConditionDisplayName': 'New',
#   'ExcludeShipToLocation': ['Alaska/Hawaii',
#    'US Protectorates',
#    'APO/FPO',
#    'Africa',
#    'Asia',
#    'Central America and Caribbean',
#    'Europe',
#    'Middle East',
#    'North America',
#    'Southeast Asia',
#    'South America',
#    'PO Box'],
#   'TopRatedListing': True,
#   'GlobalShipping': False,
#   'ItemCompatibilityCount': 21,
#   'ItemCompatibilityList': {'Compatibility': [{'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2351CC l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2019']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2018']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#       {'Name': 'Engine',
#        'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'},
#     {'NameValueList': [{'Value': []},
#       {'Name': 'Year', 'Value': ['2017']},
#       {'Name': 'Make', 'Value': ['Honda']},
#       {'Name': 'Model', 'Value': ['CR-V']},
#       {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#       {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#      'CompatibilityNotes': '1.5T'}]},
#   'QuantitySoldByPickupInStore': 0,
#   'SKU': 'CLX-M0-18097-CL360A55',
#   'NewBestOffer': False}}

# %%
# 标题：Item.Title - None
title = info['Item']['Title']
# 售价：Item.CurrentPrice - None
price = info['Item']['CurrentPrice']['CurrencyID'] + ' ' + str(info['Item']['CurrentPrice']['Value'])
# 销量：Item.QuantitySold - Details
sold = info['Item']['QuantitySold']
# 图片：Item.GalleryURL - None
if 'GalleryURL' in info['Item']:
    src = info['Item']['GalleryURL']
elif 'PictureURL' in info['Item']:
    if len(info['Item']['PictureURL']) == 0:
        src = ''
    else:
        src = info['Item']['PictureURL'][0]
# 车型：Item.ItemCompatibilityList - Compatibility
if 'ItemCompatibilityList' in info['Item']:
    vehicle = info['Item']['ItemCompatibilityList']['Compatibility']
else:
    vehicle = ''
# 详情：Item.ItemSpecifics - ItemSpecifics
if 'ItemSpecifics' in info['Item']:
    details = info['Item']['ItemSpecifics']['NameValueList']
else:
    details = ''

# %%
vehicle
# Out:
# [{'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2351CC l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2019']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2018']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['EX-L Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['LX Sport Utility 4-Door']},
#    {'Name': 'Engine',
#     'Value': ['2.4L 2356CC 144Cu. In. l4 GAS DOHC Naturally Aspirated']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Touring Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'},
#  {'NameValueList': [{'Value': []},
#    {'Name': 'Year', 'Value': ['2017']},
#    {'Name': 'Make', 'Value': ['Honda']},
#    {'Name': 'Model', 'Value': ['CR-V']},
#    {'Name': 'Trim', 'Value': ['Turbo Plus Sport Utility 4-Door']},
#    {'Name': 'Engine', 'Value': ['1.5L 1497CC l4 GAS DOHC Turbocharged']}],
#   'CompatibilityNotes': '1.5T'}]

# %%
dict_vehicle = {}
for name_value in vehicle:
    make = name_value['NameValueList'][2]['Value'][0]
    model = name_value['NameValueList'][3]['Value'][0]
    year = name_value['NameValueList'][1]['Value'][0]

    if make not in dict_vehicle:
        dict_vehicle[make] = {model: [year]}
    else:
        if model not in dict_vehicle[make]:
            dict_vehicle[make][model] = [year]
        else:
            dict_vehicle[make][model].append(year)
                
list_vehicle = []
for make in dict_vehicle:
    for model in dict_vehicle[make]:
        list_vehicle.append(make + ' ' + model + ' ' + min(dict_vehicle[make][model]) + '-' + max(dict_vehicle[make][model]))
        
vehicle = '\n'.join(list_vehicle)

print(title + '\n' + price + '\n' + str(sold) + '\n' + src + '\n' + vehicle)
# Out:
# For Honda CRV Intercooler 2017 2018 2019 | 1.5T For HO3012101 | 19710-5PA-A01
# USD 125.36
# 6
# https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYAAOSwJ7BjzPKp/$_12.PNG?set_id=880000500F
# Honda CR-V 2017-2019

# %%
# 车型带排量

# dict_vehicle = {}
# for name_value in vehicle:
#     make = name_value['NameValueList'][2]['Value'][0]
#     model = name_value['NameValueList'][3]['Value'][0]
#     try:
#         engine = re.findall(r'^[.0-9]+L', name_value['NameValueList'][5]['Value'][0])[0]
#     except:
#         continue
#     year = name_value['NameValueList'][1]['Value'][0]

#     if make not in dict_vehicle:
#         dict_vehicle[make] = {model: {engine: [year]}}
#     else:
#         if model not in dict_vehicle[make]:
#             dict_vehicle[make][model] = {engine: [year]}
#         else:
#             if engine not in dict_vehicle[make][model]:
#                 dict_vehicle[make][model][engine] = [year]
#             else:
#                 dict_vehicle[make][model][engine].append(year)

# list_vehicle = []
# for make in dict_vehicle:
#     for model in dict_vehicle[make]:
#         for engine in dict_vehicle[make][model]:
#             list_vehicle.append(make + ' ' + model + ' ' + engine + ' ' + min(dict_vehicle[make][model][engine]) + '-' + max(dict_vehicle[make][model][engine]))

# vehicle = '\n'.join(list_vehicle)

# print(title + '\n' + price + '\n' + str(amount) + '\n' + pic + '\n' + vehicle)

# %%
df_temp = pd.DataFrame({'Item': str(list_item[i]),
                        'Title': title,
                        'Price': price,
                        'Sold': str(sold),
                        'Vehicle': vehicle,
                        'Url': 'https://www.ebay.com/itm/' + str(list_item[i]),
                        'Src': src,
                        'status': ['ok']})

df_temp
# Out:
#            Item                                              Title
# 0  225368940813  For Honda CRV Intercooler 2017 2018 2019 | 1.5...  \
#
#         Price Sold                Vehcle
# 0  USD 125.36    6  Honda CR-V 2017-2019  \
#
#                                      Url
# 0  https://www.ebay.com/itm/225368940813  \
#
#                                                  Src status
# 0  https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYA...     ok

# %%
for name_value in details:
    df_temp[name_value['Name'].lower()] = ';'.join(name_value['Value'])
    
df_temp
# Out:
#            Item                                              Title
# 0  225368940813  For Honda CRV Intercooler 2017 2018 2019 | 1.5...  \
#
#         Price Sold                Vehcle
# 0  USD 125.36    6  Honda CR-V 2017-2019  \
#
#                                      Url
# 0  https://www.ebay.com/itm/225368940813  \
#
#                                                  Src status        brand
# 0  https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYA...     ok  KarParts360  \
#
#             features  ...        fitment type            generic_keywords 1
# 0  Easy Installation  ...  Direct Replacement  2017-2019|HONDA|CR-V::1.5T^^  \
#
#   generic_keywords 2 intended use misc fitment notes
# 0          See Notes  Automobiles          See Notes  \
#
#   oem equivalent part number 1 partslink number placement on vehicle
# 0                19710-5PA-A01        HO3012101                Front  \
#
#                        side manufacturer warranty
# 0  Driver Or Passenger Side                1 Year
#
# [1 rows x 27 columns]

# %%
df = pd.concat([df, df_temp], ignore_index=True).fillna('')

df
# Out:
#            Item                                              Title
# 0  225368940813  For Honda CRV Intercooler 2017 2018 2019 | 1.5...  \
#
#         Price Sold                Vehcle
# 0  USD 125.36    6  Honda CR-V 2017-2019  \
#
#                                      Url
# 0  https://www.ebay.com/itm/225368940813  \
#
#                                                  Src status        brand
# 0  https://i.ebayimg.com/00/s/MTAyNFgxMDI0/z/dHYA...     ok  KarParts360  \
#
#             features  ...        fitment type            generic_keywords 1
# 0  Easy Installation  ...  Direct Replacement  2017-2019|HONDA|CR-V::1.5T^^  \
#
#   generic_keywords 2 intended use misc fitment notes
# 0          See Notes  Automobiles          See Notes  \
#
#   oem equivalent part number 1 partslink number placement on vehicle
# 0                19710-5PA-A01        HO3012101                Front  \
#
#                        side manufacturer warranty
# 0  Driver Or Passenger Side                1 Year
#
# [1 rows x 27 columns]
