# %%
import os

# %%
list_file = list(os.walk('./part'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
list_file.sort()
    
len(list_file)
# Out:
# 1590

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./part/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False).fillna('')
        
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
df.to_excel('./part.xlsx', index=False)

df
# Out:
# Progress: 100%|██████████████████████████| 1590/1590 [00:16<00:00, 94.29it/s]
#         序号 Brand Part_Number                                          Title  \
# 0        1  febi       15898  Axle Beam Mounting / Engine Subframe Mounting
# 1        2  febi       07180  Axle Beam Mounting / Engine Subframe Mounting
# 2        3  febi       01518  Axle Beam Mounting / Engine Subframe Mounting
# 3        4  febi       07181  Axle Beam Mounting / Engine Subframe Mounting
# 4        5  febi       07179  Axle Beam Mounting / Engine Subframe Mounting
# ...    ...   ...         ...                                            ...
# 1585  1586  febi       31127                                 Engine Support
# 1586  1587  febi      101759                                 Engine Support
# 1587  1588  febi      104444                             Transmission Mount
# 1588  1589  febi      105897                             Transmission Mount
# 1589  1590  febi      100501              Vibration Damper for engine cover
#
#                      Subtitle Vehicle_1 Vehicle_2 Pic  \
# 0      Fitting Position: rear
# 1     Fitting Position: front
# 2      Fitting Position: rear
# 3     Fitting Position: front
# 4     Fitting Position: front
# ...                       ...       ...       ...  ..
# 1585   Fitting Position: rear
# 1586   Fitting Position: rear
# 1587   Fitting Position: left
# 1588   Fitting Position: left
# 1589
#
#                                                     Url  \
# 0     https://partsfinder.bilsteingroup.com/en/artic...
# 1     https://partsfinder.bilsteingroup.com/en/artic...
# 2     https://partsfinder.bilsteingroup.com/en/artic...
# 3     https://partsfinder.bilsteingroup.com/en/artic...
# 4     https://partsfinder.bilsteingroup.com/en/artic...
# ...                                                 ...
# 1585  https://partsfinder.bilsteingroup.com/en/artic...
# 1586  https://partsfinder.bilsteingroup.com/en/artic...
# 1587  https://partsfinder.bilsteingroup.com/en/artic...
# 1588  https://partsfinder.bilsteingroup.com/en/artic...
# 1589  https://partsfinder.bilsteingroup.com/en/artic...
#
#                                                     Src  ...  \
# 0     https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 1     https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 2     https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 3     https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 4     https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# ...                                                 ...  ...
# 1585  https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 1586  https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 1587  https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 1588  https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
# 1589  https://cdn.partsfinder.bilsteingroup.com/pf-a...  ...
#
#      OE_Buick-GM Shanghai OE_Lada OE_Chevrolet-GM Shanghai OE_Cadillac  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...     ...                      ...         ...
# 1585
# 1586
# 1587
# 1588
# 1589
#
#      OE_Roewe (Saic) OE_Scion OE_Subaru OE_Jaguar OE_Daewoo OE_Polestar
# 0
# 1
# 2
# 3
# 4
# ...              ...      ...       ...       ...       ...         ...
# 1585
# 1586
# 1587
# 1588
# 1589
#
# [1590 rows x 99 columns]
