# %%
item = {'home': 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s',
 'sku_count': 622,
 'page_count': 7,
 'page': 1,
 'page_url': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}

item
# Out:
# {'home': 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s',
#  'sku_count': 622,
#  'page_count': 7,
#  'page': 1,
#  'page_url': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(item['page_url'],
                        headers=generate_header(),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
list_dict = response.json()

list_dict
# Out:
# [{'rowId': 1,
#   'site': 'FS',
#   'webBase': '37530',
#   'brand': 'FS',
#   'basePart': '37530',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 2,
#   'site': 'FS',
#   'webBase': '37531',
#   'brand': 'FS',
#   'basePart': '37531',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 3,
#   'site': 'FS',
#   'webBase': '37532',
#   'brand': 'FS',
#   'basePart': '37532',
# ...

# %%
not list_dict
# Out:
# False

# %%
{'home': item['home'],
 'sku_count': item['sku_count'],
 'page_count': item['page_count'],
 'page': item['page'],
 'page_url': item['page_url'],
 'no': list_dict[0]['rowId'],
 'url': f'''https://www.4s.com/en/ecatalog?part={list_dict[0]['webBase'].strip()}&type=p&search=s''',
 'brand': list_dict[0]['brand'].strip(),
 'part_number': list_dict[0]['basePart'].strip(),
 'part_url': f'''https://ecatalog.smpcorp.com/v2/fs/api/part/partselect?part={list_dict[0]['basePart']}&func=PART''',
 'src_url': f'''https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum={list_dict[0]['basePart']}&brand={list_dict[0]['brand']}&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960''',
 'description_1': list_dict[0]['partDesc_en'],
 'description_2': list_dict[0]['partLongDesc_en'],
 'pop': list_dict[0]['pop'],
 'per_car': list_dict[0]['qtyEach']}
# Out:
# {'home': 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s',
#  'sku_count': 622,
#  'page_count': 7,
#  'page': 1,
#  'page_url': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-',
#  'no': 1,
#  'url': 'https://www.4s.com/en/ecatalog?part=37530&type=p&search=s',
#  'brand': 'FS',
#  'part_number': '37530',
#  'part_url': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partselect?part=37530&func=PART',
#  'src_url': 'https://ecatalog.smpcorp.com/v2/fs/api/image/getallimages?partNum=37530&brand=FS&zoomFactor_sm=75&zoomFactor_md=360&zoomFactor_bg=960',
#  'description_1': 'HVAC Air Door Actuator',
#  'description_2': 'HVAC Air Door Actuator',
#  'pop': 'AA',
#  'per_car': 1}
