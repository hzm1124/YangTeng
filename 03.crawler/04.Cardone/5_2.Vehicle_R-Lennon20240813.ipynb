# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/5.vehicle'):
    shutil.rmtree('./file/5.vehicle')

os.makedirs('./file/5.vehicle')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/3.auth'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/3.auth/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                b = 0
                while True:
                    b += 1
                    
                    try:
                        resp = requests.get(f'''https://productdesk-api.cellacore.net/legacy/cardone/Vehicle/Recommendation/?q=(productSKU.keyword:{input_.loc[a, 'Part Number']})&size=5000&useCache=true&auth={input_.loc[a, 'Auth']}''',
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                list_json = resp.json()

                # = = = = = = = = = = = = = = =

                list_make = [json_['fitment']['Vcdb']['MakeName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_model = [json_['fitment']['Vcdb']['ModelName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_region = [json_['fitment']['Vcdb']['RegionName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_submodel = [json_['fitment']['Vcdb']['SubModelName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_vehicle_type = [json_['fitment']['Vcdb']['VehicleTypeName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_year = [int(json_['fitment']['Vcdb']['Year'].strip()) for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter = [], [], [], [], []
                list_list_engine = [json_['fitment']['Vcdb']['Engines'] for json_ in list_json]
                for list_engine in list_list_engine:
                    if list_engine:
                        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [], [], [], [], []
                        for engine in list_engine:
                            list_aspiration.append(engine['AspirationName'].strip() if 'AspirationName' in engine and engine['AspirationName'].strip() != '-' else '')
                
                            # = = = = = = = = = = = = = = =
                            
                            cylinder = ''
                            if 'BlockType' in engine and engine['BlockType'].strip() != '-':
                                cylinder += engine['BlockType'].strip()
                            if 'Cylinders' in engine and engine['Cylinders'] != 0:
                                cylinder += str(engine['Cylinders'])
                            list_cylinder.append(cylinder)
                            
                            # = = = = = = = = = = = = = = =
                
                            displacement = ''
                            if engine['CID'].strip() != '-':
                                displacement += f'''{engine['CID'].strip()}cid'''
                            elif engine['CC'].strip() != '-':
                                displacement += f'''/{engine['CC'].strip()}cc'''
                            list_displacement.append(displacement.removeprefix('/'))
                            
                            # = = = = = = = = = = = = = = =
                
                            list_fuel.append(engine['FuelTypeName'].strip() if 'FuelTypeName' in engine else '')
                
                            # = = = = = = = = = = = = = = =
                
                            list_liter.append(f'''{engine['Liter']}L''' if 'Liter' in engine and engine['Liter'] != 0 else '')
                    else:
                        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [''], [''], [''], [''], ['']
                
                    list_list_aspiration.append(list_aspiration)
                    list_list_cylinder.append(list_cylinder)
                    list_list_displacement.append(list_displacement)
                    list_list_fuel.append(list_fuel)
                    list_list_liter.append(list_liter)
                    
                # = = = = = = = = = = = = = = =

                list_list_drive_type = []
                list_list_drive_type_2 = [json_['fitment']['Vcdb']['DriveTypes'] for json_ in list_json]
                for list_drive_type_2 in list_list_drive_type_2:
                    if list_drive_type_2:
                        list_drive_type = []
                        for drive_type_2 in list_drive_type_2:
                            list_drive_type.append(drive_type_2['DriveTypeName'].strip())
                    else:
                        list_drive_type = ['']
                
                    list_list_drive_type.append(list_drive_type)
                    
                # = = = = = = = = = = = = = = =

                list_position = [json_['fitment']['acesCriteria']['PositionName'].strip() if 'PositionName' in json_['fitment']['acesCriteria'] else '' for json_ in list_json]

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame()
                for i in range(len(list_json)):
                    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                                 'Part Number': input_.loc[a, 'Part Number'],
                                                 'Auth': input_.loc[a, 'Auth'],
                                                 'Vehicle Type': list_vehicle_type[i],
                                                 'Region': list_region[i],
                                                 'Make': list_make[i],
                                                 'Model': list_model[i],
                                                 'Submodel': list_submodel[i],
                                                 'Cylinder': list_list_cylinder[i],
                                                 'Displacement': list_list_displacement[i],
                                                 'Liter': list_list_liter[i],
                                                 'Year': list_year[i],
                                                 'Fuel': list_list_fuel[i],
                                                 'Aspiration': list_list_aspiration[i]})
                    for j in range(len(list_list_drive_type[i])):
                        df_temp_temp_temp = df_temp_temp.copy()
                        df_temp_temp_temp['Drive Type'] = list_list_drive_type[i][j]
                        df_temp_temp_temp['Position'] = list_position[i]
                        df_temp = pd.concat([df_temp, df_temp_temp_temp], ignore_index=True).fillna('')
                
                df_temp = df_temp.drop_duplicates(keep='first', ignore_index=True)
                df_temp = df_temp.sort_values(by=['Vehicle Type', 'Region', 'Make', 'Model', 'Submodel', 'Cylinder', 'Displacement', 'Liter', 'Year', 'Fuel', 'Aspiration', 'Drive Type', 'Position'],
                                              ascending=[True, True, True, True, True, True, True, True, False, True, True, True, True],
                                              ignore_index=True)
                
                df_temp['Row'] = [i+1 for i in range(len(df_temp))]
                
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'No']}.{input_.loc[a, 'Part Number']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(5):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No'],
                                                    ascending=[True],
                                                    ignore_index=True)
        output_correct[['No',
                        'Part Number',
                        'Auth',
                        'Row',
                        'Vehicle Type',
                        'Region',
                        'Make',
                        'Model',
                        'Submodel',
                        'Cylinder',
                        'Displacement',
                        'Liter',
                        'Year',
                        'Fuel',
                        'Aspiration',
                        'Drive Type',
                        'Position']].to_excel(f'''./file/5.vehicle/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/5.vehicle'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/5.vehicle/{file}',
              f'''./file/5.vehicle/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# 总数量：113
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 375.43-1007
# [剩余数量：103] - [当前时间：13:19:45]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 404.43-1169
# [剩余数量：102] - [当前时间：13:19:46]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 403.43-1167
# [剩余数量：101] - [当前时间：13:19:47]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 80.40-1068
# [剩余数量：100] - [当前时间：13:19:47]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 2.40-10000
# [剩余数量：99] - [当前时间：13:19:47]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 429.43-1252
# [剩余数量：98] - [当前时间：13:19:47]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 427.43-1250
# [剩余数量：97] - [当前时间：13:19:48]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 428.43-1251
# [剩余数量：96] - [当前时间：13:19:48]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 437.43-1406
# [剩余数量：95] - [当前时间：13:19:49]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 445.43-1414
# [剩余数量：94] - [当前时间：13:19:49]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 430.43-1253
# [剩余数量：93] - [当前时间：13:19:51]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 466.43-1472
# [剩余数量：92] - [当前时间：13:19:51]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 433.43-1307
# [剩余数量：91] - [当前时间：13:19:52]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 477.43-1483
# [剩余数量：90] - [当前时间：13:19:52]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 480.43-1486
# [剩余数量：89] - [当前时间：13:19:53]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 651.43-2132
# [剩余数量：88] - [当前时间：13:19:55]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 402.43-1166
# [剩余数量：87] - [当前时间：13:19:56]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 702.43-3442
# [剩余数量：86] - [当前时间：13:19:57]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 650.43-2131
# [剩余数量：85] - [当前时间：13:19:58]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 201.40-2042
# [剩余数量：84] - [当前时间：13:19:59]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 711.43-35006
# [剩余数量：83] - [当前时间：13:20:00]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 760.43-4008
# [剩余数量：82] - [当前时间：13:20:00]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 703.43-3443
# [剩余数量：81] - [当前时间：13:20:00]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 772.43-4021
# [剩余数量：80] - [当前时间：13:20:02]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 779.43-4030
# [剩余数量：79] - [当前时间：13:20:02]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 457.43-1429
# [剩余数量：78] - [当前时间：13:20:05]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 446.43-1415
# [剩余数量：77] - [当前时间：13:20:07]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 788.43-4041
# [剩余数量：76] - [当前时间：13:20:09]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 770.43-4019
# [剩余数量：75] - [当前时间：13:20:09]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 395.43-1156
# [剩余数量：74] - [当前时间：13:20:10]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 76.40-1063
# [剩余数量：73] - [当前时间：13:20:11]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 789.43-4042
# [剩余数量：72] - [当前时间：13:20:11]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 785.43-4036
# [剩余数量：71] - [当前时间：13:20:11]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 646.43-2124
# [剩余数量：70] - [当前时间：13:20:11]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 795.43-4049
# [剩余数量：69] - [当前时间：13:20:12]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 443.43-1412
# [剩余数量：68] - [当前时间：13:20:12]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 800.43-4059
# [剩余数量：67] - [当前时间：13:20:12]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 804.43-4066
# [剩余数量：66] - [当前时间：13:20:12]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 810.43-4078
# [剩余数量：65] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 811.43-4079
# [剩余数量：64] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 786.43-4037
# [剩余数量：63] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 783.43-4034
# [剩余数量：62] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 841.43-4210
# [剩余数量：61] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 809.43-4077
# [剩余数量：60] - [当前时间：13:20:13]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 812.43-4080
# [剩余数量：59] - [当前时间：13:20:14]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 844.43-4214
# [剩余数量：58] - [当前时间：13:20:14]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 863.43-43103
# [剩余数量：57] - [当前时间：13:20:14]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 766.43-4015
# [剩余数量：56] - [当前时间：13:20:14]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 861.43-4309
# [剩余数量：55] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 851.43-4230
# [剩余数量：54] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 846.43-4216
# [剩余数量：53] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 865.43-43107
# [剩余数量：52] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 869.43-43112
# [剩余数量：51] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 843.43-4213
# [剩余数量：50] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 867.43-4311
# [剩余数量：49] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 870.43-43113
# [剩余数量：48] - [当前时间：13:20:15]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 885.43-4318
# [剩余数量：47] - [当前时间：13:20:16]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 876.43-43120
# [剩余数量：46] - [当前时间：13:20:16]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 899.43-4332
# [剩余数量：45] - [当前时间：13:20:16]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 908.43-4343
# [剩余数量：44] - [当前时间：13:20:16]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 913.43-4348
# [剩余数量：43] - [当前时间：13:20:17]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 904.43-4339
# [剩余数量：42] - [当前时间：13:20:17]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 902.43-4337
# [剩余数量：41] - [当前时间：13:20:17]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 918.43-4369
# [剩余数量：40] - [当前时间：13:20:18]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 917.43-4367
# [剩余数量：39] - [当前时间：13:20:18]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 891.43-4324
# [剩余数量：38] - [当前时间：13:20:18]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 916.43-4362
# [剩余数量：37] - [当前时间：13:20:18]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 920.43-4377
# [剩余数量：36] - [当前时间：13:20:18]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 923.43-4382
# [剩余数量：35] - [当前时间：13:20:19]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 932.43-4393
# [剩余数量：34] - [当前时间：13:20:19]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 922.43-4380
# [剩余数量：33] - [当前时间：13:20:19]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 933.43-4394
# [剩余数量：32] - [当前时间：13:20:19]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 928.43-4387
# [剩余数量：31] - [当前时间：13:20:20]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 936.43-4397
# [剩余数量：30] - [当前时间：13:20:20]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 945.43-4407
# [剩余数量：29] - [当前时间：13:20:21]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 938.43-4399
# [剩余数量：28] - [当前时间：13:20:21]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 958.43-4421
# [剩余数量：27] - [当前时间：13:20:21]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 972.43-4458
# [剩余数量：26] - [当前时间：13:20:21]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 927.43-4386
# [剩余数量：25] - [当前时间：13:20:22]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 914.43-4350
# [剩余数量：24] - [当前时间：13:20:22]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 977.43-4464
# [剩余数量：23] - [当前时间：13:20:22]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 921.43-4379
# [剩余数量：22] - [当前时间：13:20:22]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 981.43-4473
# [剩余数量：21] - [当前时间：13:20:23]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 982.43-4475
# [剩余数量：20] - [当前时间：13:20:23]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 983.43-4476
# [剩余数量：19] - [当前时间：13:20:23]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 988.43-4489
# [剩余数量：18] - [当前时间：13:20:23]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 987.43-4488
# [剩余数量：17] - [当前时间：13:20:24]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 991.43-45004
# [剩余数量：16] - [当前时间：13:20:24]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1000.43-45013
# [剩余数量：15] - [当前时间：13:20:24]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1005.43-45022
# [剩余数量：14] - [当前时间：13:20:24]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1001.43-45014
# [剩余数量：13] - [当前时间：13:20:25]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1013.43-45032
# [剩余数量：12] - [当前时间：13:20:25]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1025.43-4510
# [剩余数量：11] - [当前时间：13:20:26]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1027.43-4512
# [剩余数量：10] - [当前时间：13:20:26]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 900.43-4334
# [剩余数量：9] - [当前时间：13:20:27]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1028.43-4513
# [剩余数量：8] - [当前时间：13:20:27]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1029.43-4514
# [剩余数量：7] - [当前时间：13:20:27]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1035.43-4521
# [剩余数量：6] - [当前时间：13:20:28]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1033.43-4519
# [剩余数量：5] - [当前时间：13:20:28]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1043.43-4531
# [剩余数量：4] - [当前时间：13:20:28]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1040.43-4527
# [剩余数量：3] - [当前时间：13:20:28]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1036.43-4522
# [剩余数量：2] - [当前时间：13:20:29]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1016.43-45038
# [剩余数量：1] - [当前时间：13:20:29]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1046.43-4534
# [剩余数量：0] - [当前时间：13:20:29]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1048.43-4536
# [剩余数量：0] - [当前时间：13:20:29]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1067.43-4573
# [剩余数量：0] - [当前时间：13:20:30]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1053.43-4543
# [剩余数量：0] - [当前时间：13:20:30]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1068.43-4574
# [剩余数量：0] - [当前时间：13:20:31]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 1078.43-4597
# [剩余数量：0] - [当前时间：13:20:31]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 942.43-4404
# [剩余数量：0] - [当前时间：13:20:31]
#
# [状态：error，尝试次数：2] - 50.00% - crawler_1-vehicle_error > 947.43-4409
# [剩余数量：0] - [当前时间：13:20:32]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 993.43-45007
# [剩余数量：0] - [当前时间：13:20:33]
#
# [状态：error，尝试次数：1] - 50.00% - crawler_1-vehicle_error > 989.43-4490
# [剩余数量：0] - [当前时间：13:20:35]
#
# 输出ing...
#
# 爬虫存在error
#
# 总数量：23
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 129.65-4006
# [剩余数量：13] - [当前时间：13:20:36]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 131.65-4008
# [剩余数量：12] - [当前时间：13:20:36]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 132.65-4009
# [剩余数量：11] - [当前时间：13:20:36]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 115.65-3501
# [剩余数量：10] - [当前时间：13:20:36]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 117.65-3503
# [剩余数量：9] - [当前时间：13:20:37]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 121.65-3507
# [剩余数量：8] - [当前时间：13:20:37]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 135.65-4012
# [剩余数量：7] - [当前时间：13:20:37]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 116.65-3502
# [剩余数量：6] - [当前时间：13:20:37]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 274.65-7078
# [剩余数量：5] - [当前时间：13:20:38]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 260.65-7063
# [剩余数量：4] - [当前时间：13:20:38]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 119.65-3505
# [剩余数量：3] - [当前时间：13:20:38]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 283.65-9000
# [剩余数量：2] - [当前时间：13:20:38]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 447.65-9543
# [剩余数量：1] - [当前时间：13:20:40]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 421.65-9490
# [剩余数量：0] - [当前时间：13:20:40]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 432.65-9519
# [剩余数量：0] - [当前时间：13:20:40]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 185.65-6004
# [剩余数量：0] - [当前时间：13:20:40]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 277.65-7085
# [剩余数量：0] - [当前时间：13:20:41]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 349.65-9309
# [剩余数量：0] - [当前时间：13:20:42]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 496.65-9792
# [剩余数量：0] - [当前时间：13:20:42]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_2-vehicle_error > 118.65-3504
# [剩余数量：0] - [当前时间：13:20:44]
#
# [状态：error，尝试次数：2] - 100.00% - crawler_2-vehicle_error > 270.65-7074
# [剩余数量：0] - [当前时间：13:20:48]
#
# [状态：error，尝试次数：2] - 100.00% - crawler_2-vehicle_error > 365.65-9330
# [剩余数量：0] - [当前时间：13:20:49]
#
# [状态：error，尝试次数：2] - 100.00% - crawler_2-vehicle_error > 422.65-9492
# [剩余数量：0] - [当前时间：13:20:51]
#
# 输出ing...
#
# 爬虫存在error
# Progress: 0it [00:00, ?it/s]
# Done ~
