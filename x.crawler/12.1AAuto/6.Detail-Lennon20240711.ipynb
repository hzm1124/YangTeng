# %%
import pandas as pd

input_ = pd.read_excel(f'./3.part.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

input_
# Out:
#         No  Part Number       Tag  \
# 0        1     WSS00492  Replaces
# 1        2     WSS00493  Replaces
# 2        3     WSS00514  Replaces
# 3        4     WSS00636  Replaces
# 4        5     WSS00481  Replaces
# ...    ...          ...       ...
# 1395  1396       KT3030  Replaces
# 1396  1397        D1014  Replaces
# 1397  1398       KF3008  Replaces
# 1398  1399  GRB 1112 73  Replaces
# 1399  1400       KG3107  Replaces
#
#                                                   Title         SKU Part Code  \
# 0     Chevrolet GMC Door Weatherstrip Seal Kit DIY S...  1AWSK00111   1027781
# 1     1981-85 Chevrolet GMC Door Weatherstrip Seal K...  1AWSK00112   1027785
# 2     1978-81 Chevrolet Camaro Pontiac Firebird T-To...  1AWSK00136   1027738
# 3     Chevrolet GMC 18 Piece Complete Weatherstrip S...  1AWSK00301   1034244
# 4     1970-81 Chevrolet Camaro Pontiac Firebird 5 Pi...  1AWSK00100   1027819
# ...                                                 ...         ...       ...
# ...

# %%
from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_specific = json.loads(input_.loc[i, 'Json_Detail'])
    for value in list(dict_specific.values()):
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./6.detail.xlsx', index=False)

input_
# Out:
# Progress: 100%|████████████████████████| 1400/1400 [00:00<00:00, 5834.18it/s]
#         No  Part Number       Tag  \
# 0        1     WSS00492  Replaces
# 1        2     WSS00493  Replaces
# 2        3     WSS00514  Replaces
# 3        4     WSS00636  Replaces
# 4        5     WSS00481  Replaces
# ...    ...          ...       ...
# 1395  1396       KT3030  Replaces
# 1396  1397        D1014  Replaces
# 1397  1398       KF3008  Replaces
# 1398  1399  GRB 1112 73  Replaces
# 1399  1400       KG3107  Replaces
#
#                                                   Title         SKU Part Code  \
# 0     Chevrolet GMC Door Weatherstrip Seal Kit DIY S...  1AWSK00111   1027781
# 1     1981-85 Chevrolet GMC Door Weatherstrip Seal K...  1AWSK00112   1027785
# 2     1978-81 Chevrolet Camaro Pontiac Firebird T-To...  1AWSK00136   1027738
# 3     Chevrolet GMC 18 Piece Complete Weatherstrip S...  1AWSK00301   1034244
# 4     1970-81 Chevrolet Camaro Pontiac Firebird 5 Pi...  1AWSK00100   1027819
# ...
