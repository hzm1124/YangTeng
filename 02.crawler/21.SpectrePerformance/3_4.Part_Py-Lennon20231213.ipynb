# %%
import os

# %%
list_file = list(os.walk('./crawler'))[0][2]
if '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
if '0.null.txt' in list_file:
    list_file.remove('0.null.txt')
    
len(list_file)
# Out:
# 128

# %%
import pandas as pd

# %%
df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from tqdm import tqdm
import json

# %%
for file in tqdm(list_file, desc='Progress', ncols=77):
    with open('./crawler/' + file, 'r', encoding='UTF-8') as f:
        df = pd.concat([df, pd.DataFrame(json.loads(f.read()))], ignore_index=False)

df.to_excel('./crawler.xlsx', index=False)

df
# Out:
# Progress: 100%|███████████████████████████| 128/128 [00:00<00:00, 333.10it/s]
#    序号 Part_Number                              Title  \
# 0        SPA-0945  SPA-0945 SPECTRE ESSENTIAL FILTER
# 0        SPA-2181  SPA-2181 SPECTRE ESSENTIAL FILTER
# 0        SPA-2468  SPA-2468 SPECTRE ESSENTIAL FILTER
# 0        SPA-2457  SPA-2457 SPECTRE ESSENTIAL FILTER
# 0        SPA-2249  SPA-2249 SPECTRE ESSENTIAL FILTER
# .. ..         ...                                ...
# 0        SPA-2187  SPA-2187 SPECTRE ESSENTIAL FILTER
# 0        SPA-2192  SPA-2192 SPECTRE ESSENTIAL FILTER
# 0        SPA-2385  SPA-2385 SPECTRE ESSENTIAL FILTER
# 0        SPA-2334  SPA-2334 SPECTRE ESSENTIAL FILTER
# 0        SPA-2326  SPA-2326 SPECTRE ESSENTIAL FILTER
#
#                                           Information  \
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# ..                                                ...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
# 0   1. Disposable\n2. 18,000 mile protection\n3. 5...
#
#                                               Vehicle OE_Champ     OE_Ford  \
# 0   Ford E350 Super Duty 6.2L V8 Gas 2017-2019\nFo...   AF1615  F50Z9601BA
# 0   Mercedes-Benz G550 5.5L V8 Gas 2009-2015\nMerc...   AF7906         NaN
# 0   Acura ILX 2.0L L4 Gas 2013-2015\nHonda Civic 1...   AF5201         NaN
# 0   Toyota Avalon 3.5L V6 Gas 2013-2022\nToyota Ca...   AF5190         NaN
# 0   Chevrolet Malibu 2.4L L4 Gas 2008-2012\nChevro...   AF3594         NaN
# ..                                                ...      ...         ...
# 0   Ford Escape 2.5L L4 Gas 2009-2012\nFord Escape...   AF1696  YL8Z9601AA
# 0   Acura EL 1.7L L4 Gas 2001-2005\nHonda Civic DX...   AF7990         NaN
# 0   Ford Expedition 3.5L V6 Gas 2015-2021\nFord F1...   AF2883   7C3Z9601A
# 0   Chevrolet Impala 3.5L V6 Gas 2006-2011\nChevro...   AS2962         NaN
# 0   Scion tC 2.5L L4 Gas 2011-2016\nToyota Venza 3...   AF3996         NaN
#
#      OE_STP Pic                                                Url  ...  \
# 0    SA8039      https://www.spectreperformance.com/catalog/pro...  ...
# 0    SA7620      https://www.spectreperformance.com/catalog/pro...  ...
# 0   SA11113      https://www.spectreperformance.com/catalog/pro...  ...
# 0   SA10957      https://www.spectreperformance.com/catalog/pro...  ...
# 0    SA9492      https://www.spectreperformance.com/catalog/pro...  ...
# ..      ...  ..                                                ...  ...
# 0    SA9055      https://www.spectreperformance.com/catalog/pro...  ...
# 0    SA8911      https://www.spectreperformance.com/catalog/pro...  ...
# 0   SA10262      https://www.spectreperformance.com/catalog/pro...  ...
# 0   SA10014      https://www.spectreperformance.com/catalog/pro...  ...
# 0   SA10169      https://www.spectreperformance.com/catalog/pro...  ...
#
#    OE_Volkswagen OE_Infiniti OE_Champ Labs.  OE_Buick    OE_Mazda OE_Cadillac  \
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# ..           ...         ...            ...       ...         ...         ...
# 0            NaN         NaN            NaN       NaN  YL8Z9601AA         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
# 0            NaN         NaN            NaN  10350737         NaN         NaN
# 0            NaN         NaN            NaN       NaN         NaN         NaN
#
#    OE_Chrysler OE_Ram OE_Clamp-On Filter filter material
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# ..         ...    ...                ...             ...
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
# 0          NaN    NaN                NaN             NaN
#
# [128 rows x 55 columns]
