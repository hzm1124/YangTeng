# %%
param_amount = 2064

# %%
import pandas as pd
import math

# %%
df = pd.DataFrame({'Page': [i+1 for i in range(math.ceil(param_amount / 100))],
                   'Url_1': ['https://www.dormanproducts.com/gsearch.aspx?type=keyword&origin=keyword&q=Brake%2520Master%2520Cylinder&start=' + str(i*100) + '&num=100' for i in range(math.ceil(param_amount / 100))]})

df.to_excel('./menu.xlsx', index=False)

df
# Out:
#     Page                                              Url_1
# 0      1  https://www.dormanproducts.com/gsearch.aspx?ty...
# 1      2  https://www.dormanproducts.com/gsearch.aspx?ty...
# 2      3  https://www.dormanproducts.com/gsearch.aspx?ty...
# 3      4  https://www.dormanproducts.com/gsearch.aspx?ty...
# 4      5  https://www.dormanproducts.com/gsearch.aspx?ty...
# 5      6  https://www.dormanproducts.com/gsearch.aspx?ty...
# 6      7  https://www.dormanproducts.com/gsearch.aspx?ty...
# 7      8  https://www.dormanproducts.com/gsearch.aspx?ty...
# 8      9  https://www.dormanproducts.com/gsearch.aspx?ty...
# 9     10  https://www.dormanproducts.com/gsearch.aspx?ty...
# 10    11  https://www.dormanproducts.com/gsearch.aspx?ty...
# 11    12  https://www.dormanproducts.com/gsearch.aspx?ty...
# 12    13  https://www.dormanproducts.com/gsearch.aspx?ty...
# 13    14  https://www.dormanproducts.com/gsearch.aspx?ty...
# 14    15  https://www.dormanproducts.com/gsearch.aspx?ty...
# ...
