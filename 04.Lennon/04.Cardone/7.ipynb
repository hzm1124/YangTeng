# %%
import os

list_file = sorted(list(os.walk('./file/5.oem'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

list_file
# Out:
# ['crawler_1.xlsx',
#  'crawler_10.xlsx',
#  'crawler_100.xlsx',
#  'crawler_101.xlsx',
#  'crawler_102.xlsx',
#  'crawler_103.xlsx',
#  'crawler_104.xlsx',
#  'crawler_105.xlsx',
#  'crawler_106.xlsx',
#  'crawler_107.xlsx',
#  'crawler_108.xlsx',
#  'crawler_109.xlsx',
#  'crawler_11.xlsx',
#  'crawler_111.xlsx',
#  'crawler_112.xlsx',
#  'crawler_12.xlsx',
#  'crawler_13.xlsx',
#  'crawler_14.xlsx',
#  'crawler_15.xlsx',
#  'crawler_16.xlsx',
#  'crawler_17.xlsx',
#  'crawler_18.xlsx',
#  'crawler_19.xlsx',
#  'crawler_2.xlsx',
#  'crawler_20.xlsx',
#  'crawler_21.xlsx',
#  'crawler_22.xlsx',
#  'crawler_23.xlsx',
#  'crawler_24.xlsx',
#  'crawler_25.xlsx',
#  'crawler_26.xlsx',
#  'crawler_27.xlsx',
#  'crawler_28.xlsx',
#  'crawler_29.xlsx',
#  'crawler_3.xlsx',
#  'crawler_30.xlsx',
#  'crawler_31.xlsx',
#  'crawler_32.xlsx',
#  'crawler_33.xlsx',
#  'crawler_34.xlsx',
#  'crawler_35.xlsx',
#  'crawler_36.xlsx',
#  'crawler_37.xlsx',
#  'crawler_38.xlsx',
#  'crawler_39.xlsx',
#  'crawler_4.xlsx',
#  'crawler_40.xlsx',
#  'crawler_41.xlsx',
#  'crawler_42.xlsx',
#  'crawler_43.xlsx',
#  'crawler_44.xlsx',
#  'crawler_45.xlsx',
#  'crawler_46.xlsx',
#  'crawler_47.xlsx',
#  'crawler_48.xlsx',
#  'crawler_49.xlsx',
#  'crawler_5.xlsx',
#  'crawler_50.xlsx',
#  'crawler_51.xlsx',
#  'crawler_52.xlsx',
#  'crawler_53.xlsx',
#  'crawler_54.xlsx',
#  'crawler_55.xlsx',
#  'crawler_56.xlsx',
#  'crawler_57.xlsx',
#  'crawler_58.xlsx',
#  'crawler_59.xlsx',
#  'crawler_6.xlsx',
#  'crawler_60.xlsx',
#  'crawler_61.xlsx',
#  'crawler_62.xlsx',
#  'crawler_63.xlsx',
#  'crawler_64.xlsx',
#  'crawler_65.xlsx',
#  'crawler_66.xlsx',
#  'crawler_68.xlsx',
#  'crawler_69.xlsx',
#  'crawler_7.xlsx',
#  'crawler_70.xlsx',
#  'crawler_71.xlsx',
#  'crawler_72.xlsx',
#  'crawler_73.xlsx',
#  'crawler_74.xlsx',
#  'crawler_75.xlsx',
#  'crawler_76.xlsx',
#  'crawler_77.xlsx',
#  'crawler_78.xlsx',
#  'crawler_79.xlsx',
#  'crawler_8.xlsx',
#  'crawler_80.xlsx',
#  'crawler_81.xlsx',
#  'crawler_82.xlsx',
#  'crawler_83.xlsx',
#  'crawler_84.xlsx',
#  'crawler_85.xlsx',
#  'crawler_86.xlsx',
#  'crawler_87.xlsx',
#  'crawler_88.xlsx',
#  'crawler_89.xlsx',
#  'crawler_9.xlsx',
#  'crawler_90.xlsx',
#  'crawler_91.xlsx',
#  'crawler_92.xlsx',
#  'crawler_93.xlsx',
#  'crawler_94.xlsx',
#  'crawler_95.xlsx',
#  'crawler_96.xlsx',
#  'crawler_97.xlsx',
#  'crawler_98.xlsx',
#  'crawler_99.xlsx']

# %%
from tqdm import tqdm
import pandas as pd
from datetime import datetime

input_ = pd.DataFrame()
for file in tqdm(list_file, desc='Progress', ncols=77):
    df_temp = pd.read_excel(f'./file/5.oem/{file}',
                            header=0,
                            dtype=str).fillna('')

    input_ = pd.concat([input_, df_temp], ignore_index=True).fillna('')

input_ = input_.drop_duplicates(['Url'],
                                keep='first',
                                ignore_index=True)
input_ = input_.sort_values(by=['Type', 'Part Number'],
                            ascending=[True, True],
                            ignore_index=True)

input_['No'] = [_+1 for _ in range(len(input_))]

input_.to_excel(f'''./file/【网站爬虫】Cardone-{datetime.now().strftime('%Y%m%d')}.xlsx''', index=False)

input_
# Out:
# Progress: 100%|████████████████████████████| 110/110 [00:11<00:00,  9.62it/s]
#           No                     Type Part Number  \
# 0          1             4WD Actuator    83-1003A
# 1          2             4WD Actuator     83-115A
# 2          3             4WD Actuator    83-2000A
# 3          4             4WD Actuator    83-2001A
# 4          5             4WD Actuator    83-2002A
# ...      ...                      ...         ...
# 38252  38253  Wiper Motor Pulse Board   81-1016PB
# 38253  38254  Wiper Motor Pulse Board   81-1025PB
# 38254  38255  Wiper Motor Pulse Board   81-1026PB
# 38255  38256  Wiper Motor Pulse Board   81-1046PB
# 38256  38257  Wiper Motor Pulse Board    81-158PB
#
#                                             Title     Subtitle  \
# 0                         4WD Actuator - 83-1003A  CARDONE New
# 1                          4WD Actuator - 83-115A  CARDONE New
# 2                         4WD Actuator - 83-2000A  CARDONE New
# 3                         4WD Actuator - 83-2001A  CARDONE New
# 4                         4WD Actuator - 83-2002A  CARDONE New
# ...                                           ...          ...
# 38252  Wiper Motor Pulse Board Module - 81-1016PB  CARDONE New
# 38253  Wiper Motor Pulse Board Module - 81-1025PB  CARDONE New
# 38254  Wiper Motor Pulse Board Module - 81-1026PB  CARDONE New
# 38255  Wiper Motor Pulse Board Module - 81-1046PB  CARDONE New
# 38256   Wiper Motor Pulse Board Module - 81-158PB  CARDONE New
#
#                                      Application Summary  \
# 0      Chevrolet Blazer 2005-99, S10 2004-99; GMC Jim...
# 1      CARDONE New,4WD Actuator,Cadillac Escalade 199...
# 2      Ford Expedition 2006-03, F-150 2009-04, F-150 ...
# 3      Ford Expedition 2002-97, F-150 2002-97; Lincol...
# 4      Ford Expedition 2018-07, F-150 2018-13; Lincol...
# ...                                                  ...
# 38252  CARDONE New,Wiper Motor Pulse Board,Cadillac E...
# 38253  CARDONE New,Wiper Motor Pulse Board,Chevrolet ...
# 38254  CARDONE New,Wiper Motor Pulse Board,Chevrolet ...
# 38255  CARDONE New,Wiper Motor Pulse Board,Cadillac E...
# 38256  CARDONE New,Wiper Motor Pulse Board,Cadillac E...
#
#                                                      OEM Picture  \
# 0                             15070012;15165891;24435269
# 1                                               26060073
# 2                                  6L3Z9H465B;6L3Z9E411A
# 3                      E8AZ9H465A;6L3Z9H465A;E8AE9H465AA
# 4                                             7L1Z9H465B
# ...                                                  ...     ...
# 38252                                           22110426
# 38253                                  12365393;12368685
# 38254                                           12362550
# 38255                                           88958144
# 38256  8191685540;8124630390;12463017;8124630170;8123...
#
#                                                      Url  \
# 0      https://www.cardone.com/product/4wd-actuator-8...
# 1      https://www.cardone.com/product/4wd-actuator-8...
# 2      https://www.cardone.com/product/4wd-actuator-8...
# 3      https://www.cardone.com/product/4wd-actuator-8...
# 4      https://www.cardone.com/product/4wd-actuator-8...
# ...                                                  ...
# 38252  https://www.cardone.com/product/wiper-motor-pu...
# 38253  https://www.cardone.com/product/wiper-motor-pu...
# 38254  https://www.cardone.com/product/wiper-motor-pu...
# 38255  https://www.cardone.com/product/wiper-motor-pu...
# 38256  https://www.cardone.com/product/wiper-motor-pu...
#
#                                                 Json_Src  \
# 0      {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 1      {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 2      {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 3      {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 4      {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# ...                                                  ...
# 38252  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 38253  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 38254  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 38255  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
# 38256  {"0": "https://cdn11.bigcommerce.com/s-z9vhe3o...
#
#                                                Json_Info  \
# 0      {"0": {"productDeskExternalKey": "CNRD|83-1003...
# 1      {"0": {"productDeskExternalKey": "CNRD|83-115A...
# 2      {"0": {"productDeskExternalKey": "CNRD|83-2000...
# 3      {"0": {"productDeskExternalKey": "CNRD|83-2001...
# 4      {"0": {"productDeskExternalKey": "CNRD|83-2002...
# ...                                                  ...
# 38252  {"0": {"productDeskExternalKey": "CNRD|81-1016...
# 38253  {"0": {"productDeskExternalKey": "CNRD|81-1025...
# 38254  {"0": {"productDeskExternalKey": "CNRD|81-1026...
# 38255  {"0": {"productDeskExternalKey": "CNRD|81-1046...
# 38256  {"0": {"productDeskExternalKey": "CNRD|81-158P...
#
#                                                   Bundle  \
# 0      https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 1      https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 2      https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 3      https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 4      https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# ...                                                  ...
# 38252  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 38253  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 38254  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 38255  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
# 38256  https://cdn11.bigcommerce.com/s-z9vhe3o238/ste...
#
#                                    Auth
# 0      mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 1      mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 2      mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 3      mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 4      mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# ...                                 ...
# 38252  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 38253  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 38254  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 38255  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
# 38256  mXWIhUuYvk3hklMcdwLi4lwVd3s6VASw
#
# [38257 rows x 13 columns]
