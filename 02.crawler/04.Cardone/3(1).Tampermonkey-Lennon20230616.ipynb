# %%
import pandas as pd

# %%
df = pd.read_excel('./detail.xlsx', header=0, dtype={'Part_Number': str})

df
# Out:
#                                                    Url Part_Number  \
# 0    https://www.cardone.com/product/fuel-injection...     67-0001
# 1    https://www.cardone.com/product/fuel-injection...     67-1005
# 2    https://www.cardone.com/product/fuel-injection...     67-0002
# 3    https://www.cardone.com/product/fuel-injection...     67-0009
# 4    https://www.cardone.com/product/fuel-injection...     67-0004
# ..                                                 ...         ...
# 435  https://www.cardone.com/product/fuel-injection...     67-4203
# 436  https://www.cardone.com/product/fuel-injection...     67-4206
# 437  https://www.cardone.com/product/fuel-injection...     67-5002
# 438  https://www.cardone.com/product/fuel-injection...     67-4209
# 439  https://www.cardone.com/product/fuel-injection...     67-4210
#
#                                                    Src status  \
# 0    https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 1    https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 2    https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 3    https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 4    https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# ..                                                 ...    ...
# 435  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 436  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 437  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 438  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
# 439  https://cdn11.bigcommerce.com/s-z9vhe3o238/ima...     ok
#
#                         part type product condition    lifecycle status  \
# 0    Fuel Injection Throttle Body    Remanufactured  Available to Order
# 1    Fuel Injection Throttle Body    Remanufactured  Available to Order
# 2    Fuel Injection Throttle Body    Remanufactured  Available to Order
# 3    Fuel Injection Throttle Body    Remanufactured  Available to Order
# 4    Fuel Injection Throttle Body    Remanufactured  Available to Order
# ..                            ...               ...                 ...
# 435  Fuel Injection Throttle Body    Remanufactured  Available to Order
# 436  Fuel Injection Throttle Body    Remanufactured  Available to Order
# 437  Fuel Injection Throttle Body    Remanufactured  Available to Order
# 438  Fuel Injection Throttle Body    Remanufactured  Available to Order
# 439  Fuel Injection Throttle Body    Remanufactured  Available to Order
#
#                                 package contents packaged weight  \
# 0    Electronic Throttle Body, Instruction Sheet       2.8400 lb
# 1    Electronic Throttle Body, Instruction Sheet       1.7500 lb
# 2    Electronic Throttle Body, Instruction Sheet         2.78 lb
# 3    Electronic Throttle Body, Instruction Sheet         2.38 lb
# 4    Electronic Throttle Body, Instruction Sheet         2.84 lb
# ..                                           ...             ...
# 435  Electronic Throttle Body, Instruction Sheet          2.6 lb
# 436  Electronic Throttle Body, Instruction sheet       2.6400 lb
# 437  Electronic Throttle Body, Instruction Sheet       2.8400 lb
# 438  Electronic Throttle Body, Instruction Sheet          3.1 lb
# 439  Electronic Throttle Body, Instruction sheet       3.0200 lb
#
#               upc  ... original equipment replacement  \
# 0     82617772464  ...                            NaN
# 1     82617772525  ...                            NaN
# 2     82617777131  ...                            NaN
# 3    884548122628  ...                            NaN
# 4     82617777155  ...                            NaN
# ..            ...  ...                            ...
# 435  884548218512  ...                            NaN
# 436  884548278622  ...                            Yes
# 437  884548215498  ...                            NaN
# 438  884548280427  ...                            NaN
# 439  884548309005  ...                            Yes
#
#     outlet diameter - metric outlet type venturi quantity    finish  \
# 0                        NaN         NaN              NaN       NaN
# 1                        NaN         NaN              NaN       NaN
# 2                        NaN         NaN              NaN       NaN
# 3                        NaN         NaN              NaN       NaN
# 4                        NaN         NaN              NaN       NaN
# ..                       ...         ...              ...       ...
# 435                      NaN         NaN              NaN       NaN
# 436                    46 mm       Round              1.0  Finished
# 437                      NaN         NaN              NaN       NaN
# 438                      NaN         NaN              NaN       NaN
# 439                 65.00 mm       Round              1.0  Finished
#
#     fuel injectors included fuel system grade fuel system type  \
# 0                       NaN               NaN              NaN
# 1                       NaN               NaN              NaN
# 2                       NaN               NaN              NaN
# 3                       NaN               NaN              NaN
# 4                       NaN               NaN              NaN
# ..                      ...               ...              ...
# 435                     NaN               NaN              NaN
# 436                     NaN               NaN              NaN
# 437                     NaN               NaN              NaN
# 438                     NaN               NaN              NaN
# 439                     NaN               NaN              NaN
#
#     spacer included airflow rate
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ..              ...          ...
# 435             NaN          NaN
# 436             NaN          NaN
# 437             NaN          NaN
# 438             NaN          NaN
# 439             NaN          NaN
#
# [440 rows x 34 columns]

# %%
content = '['
for i in range(len(df)):
    if i == 0:
        content += '{"Part_Number":"' + df.loc[i, 'Part_Number'] + '","OE_url":"' + 'https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:' + df.loc[i, 'Part_Number'] + '"}'
    else:
        content += ',{"Part_Number":"' + df.loc[i, 'Part_Number'] + '","OE_url":"' + 'https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:' + df.loc[i, 'Part_Number'] + '"}'
content += ']'

content
# Out:
# '[{"Part_Number":"67-0001","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0001"},{"Part_Number":"67-1005","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1005"},{"Part_Number":"67-0002","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0002"},{"Part_Number":"67-0009","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0009"},{"Part_Number":"67-0004","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0004"},{"Part_Number":"67-1006","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1006"},{"Part_Number":"67-0023","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0023"},{"Part_Number":"67-1010","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1010"},{"Part_Number":"67-0019","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0019"},{"Part_Number":"67-0021","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0021"},{"Part_Number":"67-0005","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0005"},{"Part_Number":"67-0011","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0011"},{"Part_Number":"67-0012","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0012"},{"Part_Number":"67-0014","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0014"},{"Part_Number":"67-0015","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0015"},{"Part_Number":"67-0016","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0016"},{"Part_Number":"67-1001","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1001"},{"Part_Number":"67-1002","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1002"},{"Part_Number":"67-1003","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1003"},{"Part_Number":"67-1009","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1009"},{"Part_Number":"67-1007","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1007"},{"Part_Number":"67-1008","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1008"},{"Part_Number":"67-1011","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-1011"},{"Part_Number":"67-0006","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0006"},{"Part_Number":"67-0007","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0007"},{"Part_Number":"67-0017","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0017"},{"Part_Number":"67-0018","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=productDeskItemNumber.keyword:67-0018"},{"Part_Number":"67-0022","OE_url":"https://productdesk-api.cellacore.net/legacy/cardone/FinishedGood/?q=produc ...

# %%
import pyperclip

# %%
pyperclip.copy(content)
