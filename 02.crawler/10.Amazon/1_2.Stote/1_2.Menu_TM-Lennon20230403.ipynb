# %%
import pandas as pd
import json

# %%
with open('./menu.txt', 'r', encoding='UTF-8') as f:
    df = pd.DataFrame(json.loads(f.read()))

df = df[['No.', 'Url']]
df = df.drop_duplicates(ignore_index=True)
df = df.sort_values(by=['No.'], ascending=[True]).reset_index(drop=True)
df['No.'] = [i+1 for i in range(len(df))]
df.to_excel('../menu.xlsx', index=False)

df
# Out:
#      No.                                                Url
# 0      1  https://www.amazon.com/Detroit-Axle-Bearing-As...
# 1      2  https://www.amazon.com/Detroit-Axle-Bearing-As...
# 2      3  https://www.amazon.com/Detroit-Driver-Passenge...
# 3      4  https://www.amazon.com/Detroit-Driver-Passenge...
# 4      5  https://www.amazon.com/Bearing-Assembly-Ascend...
# ..   ...                                                ...
# 415  416  https://www.amazon.com/Detroit-Axle-Bearings-A...
# 416  417  https://www.amazon.com/Detroit-Axle-Assembly-2...
# 417  418  https://www.amazon.com/Detroit-Axle-Bearing-As...
# 418  419  https://www.amazon.com/Detroit-Axle-Bearing-As...
# 419  420  https://www.amazon.com/Detroit-Axle-2002-2005-...
#
# [420 rows x 2 columns]
