# %%
import pandas as pd

output_correct = pd.DataFrame()
output_error = pd.DataFrame()

# %%
input_ = pd.read_excel('./part_number.xlsx',
                       header=0,
                       dtype=str).fillna('')

print('总数量：' + str(len(input_)))
input_['basePart'].tolist()
# Out:
# 总数量：482
# ['AX196',
#  'AX198',
#  'AX201',
#  'AX305',
#  'AX306',
#  'AX311',
#  'AX325',
#  'AX326',
#  'S697',
#  'S551',
#  'S820',
#  'S587',
#  'S1024',
#  'S612',
#  'S556',
#  'S2034',
#  'S69',
#  'S819',
#  'S575',
#  'S751',
#  'MCTX89',
#  'S69',
#  'S551',
#  'S556',
#  'S567',
#  'S575',
#  'S587',
#  'S612',
#  'S627',
#  'S633',
#  'S634',
#  'S697',
#  'S717',
#  'S751',
#  'S811',
#  'S816',
#  'S819',
#  'S820',
#  'S973',
#  'S986',
#  'S1021',
#  'S1024',
#  'S1054',
#  'S1080',
#  'S1104',
#  'S1167',
#  'S1170',
#  'S1263',
#  'S1334',
#  'S1441',
#  'S1452',
#  'S1454',
#  'S1461',
#  'S1487',
#  'S1491',
#  'S1559',
#  'S1563',
#  'S1641',
#  'S1647',
#  'S1654',
#  'S1667',
#  'S1686',
#  'S1717',
#  'S1783',
#  'S1789',
#  'S1794',
#  'S1830',
#  'S1835',
#  'S1891',
#  'S1918',
#  'S1958',
#  'S1959',
#  'S2034',
#  'S2052',
#  'S2053',
#  'S2081',
#  'S2084',
#  'S2181',
#  'S2334',
#  'S2342',
#  'S2346',
#  'S2356',
#  'S2406',
#  'S2411',
#  'S2416',
#  'S2424',
#  'S2442',
#  'S2478',
#  'S2492',
#  'S2495',
#  'S2498',
#  'S2522',
#  'S2543',
#  'S2809',
#  'S2813',
#  'S2860',
#  'S2884',
#  'S2894',
#  'S2906',
#  'S2907',
#  'S2936',
#  'S2945',
#  'S2964',
#  'S2969',
#  'S3042',
#  'S3064',
#  'SC706',
#  'TS4',
#  'TS6',
#  'TS6',
#  'TS17',
#  'TS17',
#  'TS24',
#  'TS24',
#  'TS57',
#  'TS59',
#  'TS66',
#  'TS71',
#  'TS71',
#  'TS73',
#  'TS73',
#  'TS76',
#  'TS76',
#  'TS83',
#  'TS142',
#  'TS174',
#  'TS181',
#  'TS205',
#  'TS233',
#  'TS235',
#  'TS249',
#  'TS253',
#  'TS253',
#  'TS263',
#  'TS275',
#  'TS331',
#  'TS337',
#  'TS337',
#  'TS342',
#  'TS355',
#  'TS360',
#  'TS364',
#  'TS369',
#  'TS371',
#  'TS375',
#  'TS375',
#  'TS377',
#  'TS385',
#  'TS385',
#  'TS387',
#  'TS405',
#  'TS406',
#  'TS407',
#  'TS415',
#  'TS418',
#  'TS420',
#  'TS421',
#  'TS422',
#  'TS423',
#  'TS431',
#  'TS432',
#  'TS435',
#  'TS439',
#  'TS445',
#  'TS448',
#  'TS464',
#  'TS465',
#  'TS471',
#  'TS477',
#  'TS477',
#  'TS482',
#  'TS492',
#  'TS493',
#  'TS528',
#  'TS529',
#  'TS530',
#  'TS531',
#  'TS554',
#  'TS555',
#  'TS561',
#  'TS574',
#  'TS603',
#  'TS604',
#  'TS605',
#  'TS607',
#  'TS608',
#  'TS608',
#  'TS615',
#  'TS615',
#  'TS624',
#  'TS627',
#  'TS633',
#  'TS640',
#  'TS642',
#  'TS644',
#  'TS653',
#  'TS675',
#  'TS676',
#  'TS677',
#  'TS678',
#  'TS679',
#  'TS680',
#  'TS681',
#  'TS685',
#  'TS686',
#  'TS800',
#  'TS1000',
#  'TX1',
#  'TX3',
#  'TX3K',
#  'TX3',
#  'TX6',
#  'TX6',
#  'TX9',
#  'TX10',
#  'TX12',
#  'TX13',
#  'TX13',
#  'TX14',
#  'TX18',
#  'TX18',
#  'TX21',
#  'TX24',
#  'TX25',
#  'TX27',
#  'TX28',
#  'TX31',
#  'TX32',
#  'TX32',
#  'TX37',
#  'TX37',
#  'TX38',
#  'TX39',
#  'TX40',
#  'TX43',
#  'TX43',
#  'TX48',
#  'TX49',
#  'TX51',
#  'TX54',
#  'TX55',
#  'TX56',
#  'TX57',
#  'TX58',
#  'TX60',
#  'TX61',
#  'TX64',
#  'TX66',
#  'TX66',
#  'TX68',
#  'TX71',
#  'TX71',
#  'TX73',
#  'TX73',
#  'TX74',
#  'TX76',
#  'TX78',
#  'TX78',
#  'TX79',
#  'TX80',
#  'TX81',
#  'TX81',
#  'TX83',
#  'TX84',
#  'TX85',
#  'TX87',
#  'TX89',
#  'TX89',
#  'TX91',
#  'TX95',
#  'TX96',
#  'TX97',
#  'TX98',
#  'TX98',
#  'TX99',
#  'TX101',
#  'TX102',
#  'TX104',
#  'TX104',
#  'TX106',
#  'TX106',
#  'TX107',
#  'TX108',
#  'TX108',
#  'TX109',
#  'TX110',
#  'TX111',
#  'TX113',
#  'TX114',
#  'TX115',
#  'TX118',
#  'TX120',
#  'TX121',
#  'TX122',
#  'TX122',
#  'TX124',
#  'TX125',
#  'TX127',
#  'TX128',
#  'TX128',
#  'TX130',
#  'TX131',
#  'TX132',
#  'TX133',
#  'TX134',
#  'TX136',
#  'TX136',
#  'TX138',
#  'TX138',
#  'TX139',
#  'TX139',
#  'TX141',
#  'TX141',
#  'TX142',
#  'TX143',
#  'TX144',
#  'TX145',
#  'TX153',
#  'TX155',
#  'TX155',
#  'TX157',
#  'TX158',
#  'TX158',
#  'TX161',
#  'TX165',
#  'TX170',
#  'TX175',
#  'TX179',
#  'TX180',
#  'TX181',
#  'TX182',
#  'TX183',
#  'TX185',
#  'TX186',
#  'TX187',
#  'TX188',
#  'TX191',
#  'TX192',
#  'TX193',
#  'TX194',
#  'TX195',
#  'TX197',
#  'TX199',
#  'TX202',
#  'TX205',
#  'TX206',
#  'TX207',
#  'TX208',
#  'TX209',
#  'TX212',
#  'TX214',
#  'TX215',
#  'TX215',
#  'TX216',
#  'TX218',
#  'TX218',
#  'TX220',
#  'TX221',
#  'TX222',
#  'TX223',
#  'TX224',
#  'TX226',
#  'TX227',
#  'TX228',
#  'TX229',
#  'TX229',
#  'TX230',
#  'TX231',
#  'TX233',
#  'TX235',
#  'TX236',
#  'TX237',
#  'TX238',
#  'TX239',
#  'TX240',
#  'TX241',
#  'TX243',
#  'TX246',
#  'TX247',
#  'TX249',
#  'TX250',
#  'TX252',
#  'TX253',
#  'TX254',
#  'TX255',
#  'TX257',
#  'TX258',
#  'TX259',
#  'TX260',
#  'TX261',
#  'TX262',
#  'TX263',
#  'TX265',
#  'TX266',
#  'TX267',
#  'TX268',
#  'TX270',
#  'TX272',
#  'TX273',
#  'TX274',
#  'TX275',
#  'TX277',
#  'TX278',
#  'TX279',
#  'TX280',
#  'TX281',
#  'TX282',
#  'TX283',
#  'TX284',
#  'TX285',
#  'TX287',
#  'TX288',
#  'TX289',
#  'TX291',
#  'TX293',
#  'TX294',
#  'TX295',
#  'TX296',
#  'TX297',
#  'TX298',
#  'TX300',
#  'TX303',
#  'TX304',
#  'TX305',
#  'TX307',
#  'TX308',
#  'TX310',
#  'TX311',
#  'TX315',
#  'TX316',
#  'TX317',
#  'TX318',
#  'TX319',
#  'TX321',
#  'TX322',
#  'TX323',
#  'TX324',
#  'TX326',
#  'TX327',
#  'TX328',
#  'TX329',
#  'TX330',
#  'TX331',
#  'TX332',
#  'TX333',
#  'TX334',
#  'TX335',
#  'TX336',
#  'TX337',
#  'TX338',
#  'TX339',
#  'TX341',
#  'TX343',
#  'TX344',
#  'TX346',
#  'TX347',
#  'TX348',
#  'TX349',
#  'TX350',
#  'TX351',
#  'TX352',
#  'TX355',
#  'TX356',
#  'TX357',
#  'TX358',
#  'TX359',
#  'TX361',
#  'TX362',
#  'TX363',
#  'TX365',
#  'TX366',
#  'TX367',
#  'TX368',
#  'TX370',
#  'TX372',
#  'TX373',
#  'TX375',
#  'TX380',
#  'TX383',
#  'TX541',
#  'TX542',
#  'TX543']

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../00.Tools')
import UA
import Proxy

# %%
a = 0

url = 'https://ecatalog.smpcorp.com/V2/STD/api/part/partselect?part=' + input_.loc[a, 'basePart'] + '&func=PART&vid='

resp = requests.get(url,
                    headers=UA.get_User_Agent_Requests(),
                    proxies=Proxy.get_Proxy_Requests()).text

resp
# Out:
# '{"pd":{"rowId":1,"site":"STD","webBase":"AX196","brand":"STI","basePart":"AX-196","partDesc_en":"Ambient Air Temperature Sensor","partLongDesc_en":"Ambient Air Temperature Sensor","pop":"Q","partComment":null,"qtyEach":1,"webColumn_Id":null,"categoryName_en":null,"vehicleId":null,"mfg":null,"mfG_Part":null,"maxRows":1,"brandLink":null,"imageUrl":null},"pp":{"buyersGuides":[{"basePart":"AX-196","buyersGuideId":47432,"buyersGuideDesc":"Volkswagen Cabrio (02-95)"},{"basePart":"AX-196","buyersGuideId":105426,"buyersGuideDesc":"Volkswagen EuroVan (97), (95)"},{"basePart":"AX-196","buyersGuideId":46292,"buyersGuideDesc":"Volkswagen Golf (99-95)"},{"basePart":"AX-196","buyersGuideId":46707,"buyersGuideDesc":"Volkswagen Jetta (99-95)"},{"basePart":"AX-196","buyersGuideId":47621,"buyersGuideDesc":"Volkswagen Passat (97-95)"}],"partSpecs":[{"attributeCode":"110","attributeValue":1905,"attributeSort":0,"attributeName_en":"Warranty","siteValue_en":"3 years/36,000 mile"},{"attributeCode":"341","attributeValue":9536,"attributeSort":0,"attributeName_en":"Connector Type","siteValue_en":"Plug In"},{"attributeCode":"357","attributeValue":6726,"attributeSort":0,"attributeName_en":"Attachment Method","siteValue_en":"Push On"},{"attributeCode":"159","attributeValue":5273,"attributeSort":10290,"attributeName_en":"Color/Finish","siteValue_en":"Gray"},{"attributeCode":"9","attributeValue":4753,"attributeSort":10310,"attributeName_en":"Connector Gender","siteValue_en":"Female (1)"},{"attributeCode":"160","attributeValue":249,"attributeSort":10340,"attributeName_en":"Connector Quantity","siteValue_en":"1"},{"attributeCode":"171","attributeValue":10157,"attributeSort":10350,"attributeName_en":"Connector Shape","siteValue_en":"Round, Rectangular"},{"attributeCode":"14","attributeValue":7049,"attributeSort":10410,"attributeName_en":"Contents","siteValue_en":"Sensor"},{"attributeCode":"162","attributeValue":6323,"attributeSort":11350,"attributeName_en":"Mounting Bracket(s) Included","siteValue_en":"No"},{"attributeCode":"104","attributeValue":5959,"attributeSort":12380,"attributeName_en":"Terminal Gender","siteValue_en":"Male (1)"},{"attributeCode":"164","attributeValue":1320,"attributeSort":12390,"attributeName_en":"Terminal Quantity","siteValue_en":"2"},{"attributeCode":"105","attributeValue":3983,"attributeSort":12400,"attributeName_en":"Terminal Type","siteValue_en":"Blade"},{"attributeCode":"210","attributeValue":6323,"attributeSort":12660,"attributeName_en":"Wiring Harness Included","siteValue_en":"No"}],"imageUrls":[],"relatedParts":[],"relatedCategories":null,"fandB":[{"basePart":"AX-196","fbId":"301746","fbDesc":"For over 100 years, professional technicians have trusted Standard® to replace the failed OE part. Standard® manufacturers the highest-quality, best-performing parts for all import and domestic vehicles; gas, diesel, electric and hybrid. Precision manufacturing, multiple layers of testing, and a detailed validation process ensures Standard® parts don’t just fit, they perform and they last.","taB_Type":"F&B Heading","assetSort":1,"digiSort":100},{"basePart":"AX-196","fbId":"231416","fbDesc":"Each A/C Ambient Air Temperature Sensor is a direct-fit OE replacement that ensures ease of installation","taB_Type":"F&B Details","assetSort":8,"digiSort":200},{"basePart":"AX-196","fbId":"231699","fbDesc":"High-quality materials withstand extreme conditions","taB_Type":"F&B Details","assetSort":8,"digiSort":210},{"basePart":"AX-196","fbId":"231720","fbDesc":"Undergoes extensive testing to ensure reliability","taB_Type":"F&B Details","assetSort":8,"digiSort":220},{"basePart":"AX-196","fbId":"231399","fbDesc":"As a global manufacturer of automotive aftermarket products, we maintain complete quality control throughout the manufacturing process","taB_Type":"F&B Details","assetSort":8,"digiSort":230}],"digiAssests":[{"asset_ID":3,"assetName":"Bulletins","basePart":"AX-196","fileName":"IM14137-IntermotorBro.pdf","fileURL":"http://eaccess.smpcorp.com/eCata ...

# %%
import json

# %%
json_data = json.loads(resp)

json_data
# Out:
# {'pd': {'rowId': 1,
#   'site': 'STD',
#   'webBase': 'AX196',
#   'brand': 'STI',
#   'basePart': 'AX-196',
#   'partDesc_en': 'Ambient Air Temperature Sensor',
#   'partLongDesc_en': 'Ambient Air Temperature Sensor',
#   'pop': 'Q',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 1,
#   'brandLink': None,
#   'imageUrl': None},
#  'pp': {'buyersGuides': [{'basePart': 'AX-196',
#     'buyersGuideId': 47432,
#     'buyersGuideDesc': 'Volkswagen Cabrio (02-95)'},
#    {'basePart': 'AX-196',
#     'buyersGuideId': 105426,
#     'buyersGuideDesc': 'Volkswagen EuroVan (97), (95)'},
#    {'basePart': 'AX-196',
#     'buyersGuideId': 46292,
#     'buyersGuideDesc': 'Volkswagen Golf (99-95)'},
#    {'basePart': 'AX-196',
#     'buyersGuideId': 46707,
#     'buyersGuideDesc': 'Volkswagen Jetta (99-95)'},
#    {'basePart': 'AX-196',
#     'buyersGuideId': 47621,
#     'buyersGuideDesc': 'Volkswagen Passat (97-95)'}],
#   'partSpecs': [{'attributeCode': '110',
#     'attributeValue': 1905,
#     'attributeSort': 0,
#     'attributeName_en': 'Warranty',
#     'siteValue_en': '3 years/36,000 mile'},
#    {'attributeCode': '341',
#     'attributeValue': 9536,
#     'attributeSort': 0,
#     'attributeName_en': 'Connector Type',
#     'siteValue_en': 'Plug In'},
#    {'attributeCode': '357',
#     'attributeValue': 6726,
#     'attributeSort': 0,
#     'attributeName_en': 'Attachment Method',
#     'siteValue_en': 'Push On'},
#    {'attributeCode': '159',
#     'attributeValue': 5273,
#     'attributeSort': 10290,
#     'attributeName_en': 'Color/Finish',
#     'siteValue_en': 'Gray'},
#    {'attributeCode': '9',
#     'attributeValue': 4753,
#     'attributeSort': 10310,
#     'attributeName_en': 'Connector Gender',
#     'siteValue_en': 'Female (1)'},
#    {'attributeCode': '160',
#     'attributeValue': 249,
#     'attributeSort': 10340,
#     'attributeName_en': 'Connector Quantity',
#     'siteValue_en': '1'},
#    {'attributeCode': '171',
#     'attributeValue': 10157,
#     'attributeSort': 10350,
#     'attributeName_en': 'Connector Shape',
#     'siteValue_en': 'Round, Rectangular'},
#    {'attributeCode': '14',
#     'attributeValue': 7049,
#     'attributeSort': 10410,
#     'attributeName_en': 'Contents',
#     'siteValue_en': 'Sensor'},
#    {'attributeCode': '162',
#     'attributeValue': 6323,
#     'attributeSort': 11350,
#     'attributeName_en': 'Mounting Bracket(s) Included',
#     'siteValue_en': 'No'},
#    {'attributeCode': '104',
#     'attributeValue': 5959,
#     'attributeSort': 12380,
#     'attributeName_en': 'Terminal Gender',
#     'siteValue_en': 'Male (1)'},
#    {'attributeCode': '164',
#     'attributeValue': 1320,
#     'attributeSort': 12390,
#     'attributeName_en': 'Terminal Quantity',
#     'siteValue_en': '2'},
#    {'attributeCode': '105',
#     'attributeValue': 3983,
#     'attributeSort': 12400,
#     'attributeName_en': 'Terminal Type',
#     'siteValue_en': 'Blade'},
#    {'attributeCode': '210',
#     'attributeValue': 6323,
#     'attributeSort': 12660,
#     'attributeName_en': 'Wiring Harness Included',
#     'siteValue_en': 'No'}],
#   'imageUrls': [],
#   'relatedParts': [],
#   'relatedCategories': None,
#   'fandB': [{'basePart': 'AX-196',
#     'fbId': '301746',
#     'fbDesc': 'For over 100 years, professional technicians have trusted Standard® to replace the failed OE part. Standard® manufacturers the highest-quality, best-performing parts for all import and domestic vehicles; gas, diesel, electric and hybrid. Precision manufacturing, multiple layers of testing, and a detailed validation process ensures Standard® parts don’t just fit, they perform and they last.',
#     'taB_Type': 'F&B Heading',
#     'assetSort': 1,
#     'digiSort': 100},
#    {'basePart': 'AX-196',
#     'fbId': '231416',
#     'fbDesc': 'Each A/C Ambient Air Temperature Sensor is a direct-fit OE replacement that ensures ease of installation',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 200},
#    {'basePart': 'AX-196',
#     'fbId': '231699',
#     'fbDesc': 'High-quality materials withstand extreme conditions',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 210},
#    {'basePart': 'AX-196',
#     'fbId': '231720',
#     'fbDesc': 'Undergoes extensive testing to ensure reliability',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 220},
#    {'basePart': 'AX-196',
#     'fbId': '231399',
#     'fbDesc': 'As a global manufacturer of automotive aftermarket products, we maintain complete quality control throughout the manufacturing process',
#     'taB_Type': 'F&B Details',
#     'assetSort': 8,
#     'digiSort': 230}],
#   'digiAssests': [{'asset_ID': 3,
#     'assetName': 'Bulletins',
#     'basePart': 'AX-196',
#     'fileName': 'IM14137-IntermotorBro.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD/IM14137-IntermotorBro.pdf',
#     'comment_ID': '260618',
#     'comment': 'Intermotor Brochure',
#     'assetSort': 3,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 3,
#     'assetName': 'Bulletins',
#     'basePart': 'AX-196',
#     'fileName': 'ST10235VWL-MAR13_JTF_veh_warn_light.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD/ST10235VWL-MAR13_JTF_veh_warn_light.pdf',
#     'comment_ID': '260657',
#     'comment': 'Just the Facts: Vehicle Warning Lights',
#     'assetSort': 3,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 3,
#     'assetName': 'Bulletins',
#     'basePart': 'AX-196',
#     'fileName': 'ST11237-Standard_Interactive_Buyers_Guide-WEB.pdf',
#     'fileURL': 'http://eaccess.smpcorp.com/eCatalogs/Downloads/EMD/ST11237-Standard_Interactive_Buyers_Guide-WEB.pdf',
#     'comment_ID': '260664',
#     'comment': "Standard Interactive Buyer's Guide",
#     'assetSort': 3,
#     'digiSort': 0,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'AX-196',
#     'fileName': 'SMP Engineering Spotlight: Long Island City',
#     'fileURL': 'https://youtube.com/embed/vac2vas7vJY',
#     'comment_ID': '220958',
#     'comment': 'SMP Engineering Spotlight: Long Island City',
#     'assetSort': 7,
#     'digiSort': 80000,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'AX-196',
#     'fileName': 'WIYB: Engineering Spotlight: Long Island City',
#     'fileURL': 'https://youtube.com/embed/I-kWdiTPe08',
#     'comment_ID': '291618',
#     'comment': 'WIYB: Engineering Spotlight: Long Island City',
#     'assetSort': 7,
#     'digiSort': 80003,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'AX-196',
#     'fileName': 'SMP Engineering - Long Island City Facility Tour',
#     'fileURL': 'https://youtube.com/embed/ut5LYbUFCKo',
#     'comment_ID': '271219',
#     'comment': 'SMP Engineering - Long Island City Facility Tour',
#     'assetSort': 7,
#     'digiSort': 80350,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'AX-196',
#     'fileName': 'Standard Interactive Buyers Guide',
#     'fileURL': 'https://youtube.com/embed/mRzK11T9pxg',
#     'comment_ID': '251346',
#     'comment': 'Standard Interactive Buyers Guide',
#     'assetSort': 7,
#     'digiSort': 90030,
#     'videoImage': None},
#    {'asset_ID': 7,
#     'assetName': 'Videos',
#     'basePart': 'AX-196',
#     'fileName': 'SMP Parts App Update (3.0.9)',
#     'fileURL': 'https://youtube.com/embed/KpEXmjcKbMc',
#     'comment_ID': '270593',
#     'comment': 'SMP Parts App Update (3.0.9)',
#     'assetSort': 7,
#     'digiSort': 90090,
#     'videoImage': None}],
#   'categories': [{'basePart': 'AX-196',
#     'webLayout_ID': 275500,
#     'categoryName_en': 'Sensor - Ambient Air Temperature',
#     'prodCategory_ASort': 25050}],
#   'crossRef': None,
#   'completeRepair': {'serviceParts': [],
#    'serviceSpec': [{'serviceName': 'Fuel Filter Flush (Required)'},
#     {'serviceName': 'Oil Change (Required)'}]}}}

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
vehicle = '\n'.join([guide['buyersGuideDesc'].strip() for guide in json_data['pp']['buyersGuides']])

print(vehicle)
# Out:
# Volkswagen Cabrio (02-95)
# Volkswagen EuroVan (97), (95)
# Volkswagen Golf (99-95)
# Volkswagen Jetta (99-95)
# Volkswagen Passat (97-95)

# %%
df_temp = pd.DataFrame([{'序号': int(input_.loc[a, 'rowId']),
                         'Part_Number': json_data['pd']['basePart'].strip(),
                         'Category': '' if len(json_data['pp']['categories'])==0 else json_data['pp']['categories'][0]['categoryName_en'].strip(),
                         'Part_Type_Short': json_data['pd']['partDesc_en'].strip(),
                         'Part_Type_Long': json_data['pd']['partLongDesc_en'].strip(),
                         'Brand': json_data['pd']['brand'].strip(),
                         'POP': json_data['pd']['pop'].strip(),
                         'Per_Car': json_data['pd']['qtyEach'],
                         'Vehicle': vehicle,
                         'Pic': '',
                         'Url': url,
                         'Src': '',
                         'JOIN_PNB': json_data['pd']['basePart'].strip() + ';' + json_data['pd']['brand'].strip()}])

for specification in json_data['pp']['partSpecs']:
    df_temp.loc[0, specification['attributeName_en'].lower().strip()] = specification['siteValue_en']

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

len(output_correct)
# Out:
# 1

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'rowId': int(input_.loc[a, 'rowId']),
                             'basePart': input_.loc[a, 'basePart']}])
    
    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

len(output_error)
# Out:
# 0

# %%
output_correct = output_correct.drop_duplicates(ignore_index=True)
output_correct = output_correct.sort_values(by=['序号'], ascending=[True]).reset_index(drop=True)
output_correct.to_excel('./test_part.xlsx', index=False)

output_correct
# Out:
#     序号 Part_Number                          Category  \
# 0  168       AX196  Sensor - Ambient Air Temperature
#
#                   Part_Type_Short                  Part_Type_Long Brand POP  \
# 0  Ambient Air Temperature Sensor  Ambient Air Temperature Sensor   STI   Q
#
#    Per_Car                                            Vehicle Pic  ...  \
# 0        1  Volkswagen Cabrio (02-95)\nVolkswagen EuroVan ...      ...
#
#   color/finish connector gender connector quantity     connector shape  \
# 0         Gray       Female (1)                  1  Round, Rectangular
#
#   contents mounting bracket(s) included terminal gender terminal quantity  \
# 0   Sensor                           No        Male (1)                 2
#
#   terminal type wiring harness included
# 0         Blade                      No
#
# [1 rows x 26 columns]

# %%
if len(output_error) != 0:
    output_error = output_error.drop_duplicates(ignore_index=True)
    output_error = output_error.sort_values(by=['basePart'], ascending=[True]).reset_index(drop=True)
    output_error.to_excel('./test_part_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
