# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
param_date = '20240726'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel(f'./{param_date}/2.group.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Manufacturer No'] = input_['Manufacturer No'].astype(int)
input_['Group No'] = input_['Group No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        import requests
        import json

        import sys
        sys.path.append('../../00.Tools')
        from crawler_configuration import get_header, get_proxy

        data = {'func': 'partsearchgetparttypessdd',
                'mfr': input_.loc[a, 'Manufacturer'],
                'pg': input_.loc[a, 'Group'],
                'giveback': json.dumps({'id': 'partsearch_007'}),
                'api_json_request': '1'}

        try:
            b = 0
            while True:

                while True:
                    b += 1
                    try:
                        resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                             data=data,
                                             headers=get_header(),
                                             proxies=get_proxy(),
                                             timeout=(10, 10))
                        break
                    except:
                        continue

                if resp.status_code == 200:
                    json_ = resp.json()
                    if 'redirect_to_url' in json_:
                        continue
                    elif json_['giveback']['id'] == 'partsearch_007' and 'collected_javascript' in json_:
                        break

            # = = = = = = = = = = = = = = =

            from bs4 import BeautifulSoup
            from lxml import etree

            soup = BeautifulSoup(json_['html_replace_sections']['ddrepl[parttype_][container]'], 'lxml')
            html = etree.HTML(str(soup))

            # = = = = = = = = = = = = = = =

            list_type_code = html.xpath('//select[@id="parttype_"]/option/@value')[1:]

            # = = = = = = = = = = = = = = =

            list_type = html.xpath('//select[@id="parttype_"]/option/text()')[1:]

            # = = = = = = = = = = = = = = =

            if not list_type:
                raise

            # = = = = = = = = = = = = = = =

            df_temp = pd.DataFrame({'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                                    'Manufacturer': input_.loc[a, 'Manufacturer'],
                                    'Group No': input_.loc[a, 'Group No'],
                                    'Group': input_.loc[a, 'Group'],
                                    'Type No': [i+1 for i in range(len(list_type))],
                                    'Type': list_type,
                                    'Type Code': list_type_code,
                                    'Tab 2 Url': [f'''https://www.rockauto.com/en/parts/{input_.loc[a, 'Manufacturer'].replace(',', '%2C').replace('+', '%2B')},{type_.replace(',', '%2C')},{type_code.replace(',', '%2C')}''' for type_, type_code in zip(list_type, list_type_code)]})

            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            if crawler_status == 'error':
                df_temp = pd.DataFrame([{'Manufacturer No': input_.loc[a, 'Manufacturer No'],
                                         'Manufacturer': input_.loc[a, 'Manufacturer'],
                                         'Group No': input_.loc[a, 'Group No'],
                                         'Group': input_.loc[a, 'Group']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b}] - {input_.loc[a, 'Manufacturer No']}.{input_.loc[a, 'Manufacturer']} > {input_.loc[a, 'Group No']}.{input_.loc[a, 'Group']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Manufacturer No', 'Group', 'Type No'],
                                                ascending=[True, True, True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./{param_date}/3.type-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['Manufacturer No', 'Group'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel(f'./{param_date}/type_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# [状态：ok，尝试次数：17] - 325.NEEDA > 3.Hardware
# [剩余数量：1000] - [当前时间：15:48:34]
#
# [状态：ok，尝试次数：9] - 328.NGK > 1.Exhaust & Emission
# [剩余数量：999] - [当前时间：15:48:34]
#
# [状态：ok，尝试次数：45] - 317.MOTORCRAFT > 10.Engine
# [剩余数量：998] - [当前时间：15:48:34]
#
# [状态：ok，尝试次数：2] - 330.NISSAN > 3.Cooling System
# [剩余数量：997] - [当前时间：15:48:34]
#
# [状态：ok，尝试次数：18] - 329.NICKSON > 1.Exhaust & Emission
# [剩余数量：996] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：5] - 330.NISSAN > 6.Electrical-Switch & Relay
# [剩余数量：995] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：1] - 330.NISSAN > 8.Exhaust & Emission
# [剩余数量：994] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：3] - 330.NISSAN > 11.Heat & Air Conditioning
# [剩余数量：993] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：23] - 330.NISSAN > 2.Brake & Wheel Hub
# [剩余数量：992] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：5] - 330.NISSAN > 1.Body & Lamp Assembly
# [剩余数量：991] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：16] - 328.NGK > 2.Hoses/Lines & Clamps
# [剩余数量：990] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：31] - 323.NATIONAL > 8.Hardware
# [剩余数量：989] - [当前时间：15:48:35]
#
# [状态：ok，尝试次数：38] - 321.NAPA/UNITED > 2.Transmission-Manual
# [剩余数量：988] - [当前时间：15:48:36]
#
# [状态：ok，尝试次数：27] - 330.NISSAN > 5.Electrical
# [剩余数量：987] - [当前时间：15:48:36]
#
# [状态：ok，尝试次数：35] - 316.MOTORAD > 2.Electrical-Connector
# [剩余数量：986] - [当前时间：15:48:36]
#
# [状态：ok，尝试次数：14] - 330.NISSAN > 12.Interior
# [剩余数量：985] - [当前时间：15:48:36]
#
# [状态：ok，尝试次数：33] - 330.NISSAN > 4.Drivetrain
# [剩余数量：984] - [当前时间：15:48:36]
#
# [状态：ok，尝试次数：5] - 331.NISSENS > 4.Heat & Air Conditioning
# [剩余数量：983] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：2] - 331.NISSENS > 5.Steering
# [剩余数量：982] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：1] - 330.NISSAN > 13.Steering
# [剩余数量：981] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：1] - 332.NORTHSTAR > 1.Suspension
# [剩余数量：980] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：2] - 331.NISSENS > 3.Exhaust & Emission
# [剩余数量：979] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：16] - 331.NISSENS > 1.Cooling System
# [剩余数量：978] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：17] - 330.NISSAN > 9.Fuel & Air
# [剩余数量：977] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：23] - 330.NISSAN > 16.Wiper & Washer
# [剩余数量：976] - [当前时间：15:48:37]
#
# [状态：ok，尝试次数：35] - 330.NISSAN > 10.Hardware
# [剩余数量：975] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：8] - 331.NISSENS > 6.Transmission-Automatic
# [剩余数量：974] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：1] - 333.NSK > 7.Transmission-Automatic
# [剩余数量：973] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：33] - 330.NISSAN > 15.Transmission-Automatic
# [剩余数量：972] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：2] - 333.NSK > 4.Engine
# [剩余数量：971] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：3] - 323.NATIONAL > 4.Electrical-Connector
# [剩余数量：970] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：29] - 331.NISSENS > 2.Engine
# [剩余数量：969] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：56] - 330.NISSAN > 7.Engine
# [剩余数量：968] - [当前时间：15:48:38]
#
# [状态：ok，尝试次数：25] - 333.NSK > 1.Belt Drive
# [剩余数量：967] - [当前时间：15:48:39]
#
# [状态：ok，尝试次数：10] - 334.NTK > 7.Exhaust & Emission
# [剩余数量：966] - [当前时间：15:48:39]
#
# [状态：ok，尝试次数：10] - 334.NTK > 5.Electrical
# [剩余数量：965] - [当前时间：15:48:39]
#
# [状态：ok，尝试次数：3] - 334.NTK > 10.Ignition
# [剩余数量：964] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：27] - 309.MITSUBISHI > 1.Hardware
# [剩余数量：963] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：18] - 333.NSK > 5.Heat & Air Conditioning
# [剩余数量：962] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：22] - 334.NTK > 1.Body & Lamp Assembly
# [剩余数量：961] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：15] - 334.NTK > 8.Fuel & Air
# [剩余数量：960] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：10] - 334.NTK > 11.Interior
# [剩余数量：959] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：8] - 334.NTK > 12.Steering
# [剩余数量：958] - [当前时间：15:48:40]
#
# [状态：ok，尝试次数：12] - 334.NTK > 2.Brake & Wheel Hub
# [剩余数量：957] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：4] - 334.NTK > 3.Cooling System
# [剩余数量：956] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：21] - 334.NTK > 9.Heat & Air Conditioning
# [剩余数量：955] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：1] - 337.OE+ > 1.Electrical
# [剩余数量：954] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：21] - 330.NISSAN > 14.Suspension
# [剩余数量：953] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：48] - 333.NSK > 8.Transmission-Manual
# [剩余数量：952] - [当前时间：15:48:41]
#
# [状态：ok，尝试次数：4] - 334.NTK > 14.Transmission-Automatic
# [剩余数量：951] - [当前时间：15:48:42]
#
# [状态：ok，尝试次数：3] - 341.OMNI 5 > 1.Brake & Wheel Hub
# [剩余数量：950] - [当前时间：15:48:42]
#
# [状态：ok，尝试次数：10] - 336.ODM > 1.Drivetrain
# [剩余数量：949] - [当前时间：15:48:42]
#
# [状态：ok，尝试次数：23] - 334.NTK > 15.Wiper & Washer
# [剩余数量：948] - [当前时间：15:48:42]
#
# [状态：ok，尝试次数：69] - 333.NSK > 3.Drivetrain
# [剩余数量：947] - [当前时间：15:48:42]
#
# [状态：ok，尝试次数：2] - 341.OMNI 5 > 6.Steering
# [剩余数量：946] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：6] - 341.OMNI 5 > 3.Engine
# [剩余数量：945] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：19] - 340.OMEGA > 1.Steering
# [剩余数量：944] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：6] - 341.OMNI 5 > 8.Transmission-Automatic
# [剩余数量：943] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：63] - 334.NTK > 6.Engine
# [剩余数量：942] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：1] - 342.OMNICRAFT > 3.Fuel & Air
# [剩余数量：941] - [当前时间：15:48:43]
#
# [状态：ok，尝试次数：13] - 341.OMNI 5 > 5.Fuel & Air
# [剩余数量：940] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：11] - 341.OMNI 5 > 9.Transmission-Manual
# [剩余数量：939] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：11] - 334.NTK > 4.Drivetrain
# [剩余数量：938] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：9] - 342.OMNICRAFT > 2.Engine
# [剩余数量：937] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：8] - 342.OMNICRAFT > 1.Belt Drive
# [剩余数量：936] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：39] - 339.OIL-DRI > 1.Garage Equipment
# [剩余数量：935] - [当前时间：15:48:44]
#
# [状态：ok，尝试次数：4] - 343.ORIGINAL ENGINE MANAGEMENT > 7.Heat & Air Conditioning
# [剩余数量：934] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：6] - 343.ORIGINAL ENGINE MANAGEMENT > 4.Engine
# [剩余数量：933] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：3] - 343.ORIGINAL ENGINE MANAGEMENT > 6.Fuel & Air
# [剩余数量：932] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：6] - 343.ORIGINAL ENGINE MANAGEMENT > 3.Electrical-Switch & Relay
# [剩余数量：931] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：2] - 344.ORIGINAL PERFORMANCE > 1.Exhaust & Emission
# [剩余数量：930] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：22] - 341.OMNI 5 > 2.Drivetrain
# [剩余数量：929] - [当前时间：15:48:45]
#
# [状态：ok，尝试次数：23] - 341.OMNI 5 > 7.Suspension
# [剩余数量：928] - [当前时间：15:48:46]
#
# [状态：ok，尝试次数：13] - 343.ORIGINAL ENGINE MANAGEMENT > 5.Exhaust & Emission
# [剩余数量：927] - [当前时间：15:48:46]
#
# [状态：ok，尝试次数：58] - 335.NUGEON > 1.Brake & Wheel Hub
# [剩余数量：926] - [当前时间：15:48:46]
#
# [状态：ok，尝试次数：12] - 343.ORIGINAL ENGINE MANAGEMENT > 8.Ignition
# [剩余数量：925] - [当前时间：15:48:46]
#
# [状态：ok，尝试次数：33] - 333.NSK > 6.Steering
# [剩余数量：924] - [当前时间：15:48:46]
#
# [状态：ok，尝试次数：3] - 345.OSC > 1.Cooling System
# [剩余数量：923] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：18] - 345.OSC > 2.Heat & Air Conditioning
# [剩余数量：922] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：2] - 346.PA CARGO > 2.Electrical
# [剩余数量：921] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：1] - 345.OSC > 3.Steering
# [剩余数量：920] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：2] - 346.PA CARGO > 4.Literature
# [剩余数量：919] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：6] - 346.PA CARGO > 6.Transmission-Manual
# [剩余数量：918] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：4] - 346.PA CARGO > 3.Electrical-Connector
# [剩余数量：917] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：9] - 347.PACE SETTER ELECTRICAL > 1.Cooling System
# [剩余数量：916] - [当前时间：15:48:47]
#
# [状态：ok，尝试次数：7] - 347.PACE SETTER ELECTRICAL > 2.Electrical-Switch & Relay
# [剩余数量：915] - [当前时间：15:48:48]
#
# [状态：ok，尝试次数：1] - 347.PACE SETTER ELECTRICAL > 4.Ignition
# [剩余数量：914] - [当前时间：15:48:48]
#
# [状态：ok，尝试次数：11] - 347.PACE SETTER ELECTRICAL > 3.Exhaust & Emission
# [剩余数量：913] - [当前时间：15:48:48]
#
# [状态：ok，尝试次数：1] - 351.PEAK > 2.Exhaust & Emission
# [剩余数量：912] - [当前时间：15:48:48]
#
# [状态：ok，尝试次数：1] - 352.PENNZOIL > 2.Fuel & Air
# [剩余数量：911] - [当前时间：15:48:48]
#
# [状态：ok，尝试次数：1] - 353.PENTIUS > 1.Engine
# [剩余数量：910] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：8] - 351.PEAK > 1.Electrical-Bulb & Socket
# [剩余数量：909] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：7] - 349.PAGID > 1.Brake & Wheel Hub
# [剩余数量：908] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：1] - 343.ORIGINAL ENGINE MANAGEMENT > 1.Cooling System
# [剩余数量：907] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：14] - 350.PDQ (PROVEN DRIVELINE QUALITY) > 1.Drivetrain
# [剩余数量：906] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：7] - 346.PA CARGO > 1.Drivetrain
# [剩余数量：905] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：26] - 343.ORIGINAL ENGINE MANAGEMENT > 2.Electrical
# [剩余数量：904] - [当前时间：15:48:49]
#
# [状态：ok，尝试次数：5] - 353.PENTIUS > 2.Fuel & Air
# [剩余数量：903] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：1] - 354.PENTOSIN > 2.Cooling System
# [剩余数量：902] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：2] - 354.PENTOSIN > 5.Suspension
# [剩余数量：901] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：2] - 356.PERFECT FIT > 1.Steering
# [剩余数量：900] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：9] - 354.PENTOSIN > 6.Transmission-Automatic
# [剩余数量：899] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：21] - 334.NTK > 13.Suspension
# [剩余数量：898] - [当前时间：15:48:50]
#
# [状态：ok，尝试次数：1] - 358.PERFECTION CLUTCH > 1.Transmission-Manual
# [剩余数量：897] - [当前时间：15:48:51]
#
# [状态：ok，尝试次数：19] - 345.OSC > 4.Suspension
# [剩余数量：896] - [当前时间：15:48:51]
#
# [状态：ok，尝试次数：2] - 338.OHIO CALIPER > 1.Brake & Wheel Hub
# [剩余数量：895] - [当前时间：15:48:51]
#
# [状态：ok，尝试次数：14] - 355.PERFECT EQUIPMENT > 1.Wheel
# [剩余数量：894] - [当前时间：15:48:52]
#
# [状态：ok，尝试次数：58] - 333.NSK > 2.Brake & Wheel Hub
# [剩余数量：893] - [当前时间：15:48:52]
#
# [状态：ok，尝试次数：18] - 359.PERFORMANCE ELECTRIC > 1.Fuel & Air
# [剩余数量：892] - [当前时间：15:48:52]
#
# [状态：ok，尝试次数：10] - 353.PENTIUS > 3.Heat & Air Conditioning
# [剩余数量：891] - [当前时间：15:48:52]
#
# [状态：ok，尝试次数：7] - 361.PERFORMANCE TOOL > 4.Cooling System
# [剩余数量：890] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：1] - 361.PERFORMANCE TOOL > 8.Electrical-Switch & Relay
# [剩余数量：889] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：28] - 361.PERFORMANCE TOOL > 1.Belt Drive
# [剩余数量：888] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：4] - 361.PERFORMANCE TOOL > 3.Brake & Wheel Hub
# [剩余数量：887] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：28] - 361.PERFORMANCE TOOL > 2.Body & Lamp Assembly
# [剩余数量：886] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：3] - 354.PENTOSIN > 4.Steering
# [剩余数量：885] - [当前时间：15:48:53]
#
# [状态：ok，尝试次数：33] - 352.PENNZOIL > 1.Engine
# [剩余数量：884] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：8] - 361.PERFORMANCE TOOL > 9.Engine
# [剩余数量：883] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：4] - 348.PACESETTER > 1.Exhaust & Emission
# [剩余数量：882] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：11] - 361.PERFORMANCE TOOL > 10.Exhaust & Emission
# [剩余数量：881] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：2] - 361.PERFORMANCE TOOL > 12.Garage Equipment
# [剩余数量：880] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：26] - 341.OMNI 5 > 4.Exhaust & Emission
# [剩余数量：879] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：6] - 361.PERFORMANCE TOOL > 13.Hardware
# [剩余数量：878] - [当前时间：15:48:54]
#
# [状态：ok，尝试次数：55] - 317.MOTORCRAFT > 11.Exhaust & Emission
# [剩余数量：877] - [当前时间：15:48:55]
#
# [状态：ok，尝试次数：14] - 361.PERFORMANCE TOOL > 14.Heat & Air Conditioning
# [剩余数量：876] - [当前时间：15:48:55]
#
# [状态：ok，尝试次数：36] - 354.PENTOSIN > 3.Engine
# [剩余数量：875] - [当前时间：15:48:55]
#
# [状态：ok，尝试次数：2] - 361.PERFORMANCE TOOL > 11.Fuel & Air
# [剩余数量：874] - [当前时间：15:48:55]
#
# [状态：ok，尝试次数：5] - 361.PERFORMANCE TOOL > 19.Suspension
# [剩余数量：873] - [当前时间：15:48:55]
#
# [状态：ok，尝试次数：6] - 361.PERFORMANCE TOOL > 5.Drivetrain
# [剩余数量：872] - [当前时间：15:48:56]
#
# [状态：ok，尝试次数：15] - 361.PERFORMANCE TOOL > 15.Hoses/Lines & Clamps
# [剩余数量：871] - [当前时间：15:48:56]
#
# [状态：ok，尝试次数：7] - 362.PERFORMAX > 1.Fuel & Air
# [剩余数量：870] - [当前时间：15:48:56]
#
# [状态：ok，尝试次数：7] - 361.PERFORMANCE TOOL > 23.Wiper & Washer
# [剩余数量：869] - [当前时间：15:48:56]
#
# [状态：ok，尝试次数：6] - 363.PERMATEX > 2.Body & Lamp Assembly
# [剩余数量：868] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：5] - 361.PERFORMANCE TOOL > 17.Interior
# [剩余数量：867] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：1] - 363.PERMATEX > 1.Belt Drive
# [剩余数量：866] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：4] - 363.PERMATEX > 4.Electrical
# [剩余数量：865] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：11] - 361.PERFORMANCE TOOL > 21.Transmission-Manual
# [剩余数量：864] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：5] - 363.PERMATEX > 6.Exhaust & Emission
# [剩余数量：863] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：2] - 361.PERFORMANCE TOOL > 6.Electrical
# [剩余数量：862] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：2] - 363.PERMATEX > 7.Fuel & Air
# [剩余数量：861] - [当前时间：15:48:57]
#
# [状态：ok，尝试次数：4] - 363.PERMATEX > 5.Engine
# [剩余数量：860] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：3] - 361.PERFORMANCE TOOL > 22.Wheel
# [剩余数量：859] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：21] - 346.PA CARGO > 5.Transmission-Automatic
# [剩余数量：858] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：46] - 360.PERFORMANCE FRICTION > 1.Brake & Wheel Hub
# [剩余数量：857] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：5] - 363.PERMATEX > 8.Garage Equipment
# [剩余数量：856] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：4] - 361.PERFORMANCE TOOL > 16.Ignition
# [剩余数量：855] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：4] - 361.PERFORMANCE TOOL > 7.Electrical-Connector
# [剩余数量：854] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：12] - 363.PERMATEX > 3.Brake & Wheel Hub
# [剩余数量：853] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：5] - 364.PETERSON MANUFACTURING > 1.Body & Lamp Assembly
# [剩余数量：852] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：1] - 364.PETERSON MANUFACTURING > 6.Garage Equipment
# [剩余数量：851] - [当前时间：15:48:58]
#
# [状态：ok，尝试次数：17] - 361.PERFORMANCE TOOL > 20.Transmission-Automatic
# [剩余数量：850] - [当前时间：15:48:59]
#
# [状态：ok，尝试次数：12] - 364.PETERSON MANUFACTURING > 5.Electrical-Switch & Relay
# [剩余数量：849] - [当前时间：15:48:59]
#
# [状态：ok，尝试次数：1] - 367.PIERBURG > 4.Electrical-Switch & Relay
# [剩余数量：848] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：6] - 367.PIERBURG > 2.Cooling System
# [剩余数量：847] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：19] - 364.PETERSON MANUFACTURING > 4.Electrical-Connector
# [剩余数量：846] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：27] - 361.PERFORMANCE TOOL > 18.Steering
# [剩余数量：845] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：23] - 354.PENTOSIN > 1.Brake & Wheel Hub
# [剩余数量：844] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：16] - 364.PETERSON MANUFACTURING > 8.Interior
# [剩余数量：843] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：16] - 365.PHILIPS > 1.Electrical-Bulb & Socket
# [剩余数量：842] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：6] - 367.PIERBURG > 8.Heat & Air Conditioning
# [剩余数量：841] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：17] - 367.PIERBURG > 7.Fuel & Air
# [剩余数量：840] - [当前时间：15:49:00]
#
# [状态：ok，尝试次数：3] - 368.PILOT AUTOMOTIVE > 4.Electrical-Bulb & Socket
# [剩余数量：839] - [当前时间：15:49:01]
#
# [状态：ok，尝试次数：21] - 364.PETERSON MANUFACTURING > 2.Electrical
# [剩余数量：838] - [当前时间：15:49:01]
#
# [状态：ok，尝试次数：5] - 364.PETERSON MANUFACTURING > 7.Hardware
# [剩余数量：837] - [当前时间：15:49:01]
#
# [状态：ok，尝试次数：3] - 364.PETERSON MANUFACTURING > 3.Electrical-Bulb & Socket
# [剩余数量：836] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：26] - 367.PIERBURG > 6.Exhaust & Emission
# [剩余数量：835] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：1] - 367.PIERBURG > 9.Hoses/Lines & Clamps
# [剩余数量：834] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：23] - 367.PIERBURG > 3.Electrical-Connector
# [剩余数量：833] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：11] - 368.PILOT AUTOMOTIVE > 6.Wiper & Washer
# [剩余数量：832] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：3] - 369.PIONEER > 5.Electrical
# [剩余数量：831] - [当前时间：15:49:02]
#
# [状态：ok，尝试次数：3] - 369.PIONEER > 6.Electrical-Connector
# [剩余数量：830] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：49] - 367.PIERBURG > 5.Engine
# [剩余数量：829] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：6] - 369.PIONEER > 1.Body & Lamp Assembly
# [剩余数量：828] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：2] - 369.PIONEER > 2.Brake & Wheel Hub
# [剩余数量：827] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：19] - 368.PILOT AUTOMOTIVE > 5.Ignition
# [剩余数量：826] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：11] - 369.PIONEER > 4.Drivetrain
# [剩余数量：825] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：8] - 368.PILOT AUTOMOTIVE > 1.Body & Lamp Assembly
# [剩余数量：824] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：32] - 368.PILOT AUTOMOTIVE > 2.Brake & Wheel Hub
# [剩余数量：823] - [当前时间：15:49:03]
#
# [状态：ok，尝试次数：34] - 368.PILOT AUTOMOTIVE > 3.Electrical
# [剩余数量：822] - [当前时间：15:49:04]
#
# [状态：ok，尝试次数：11] - 369.PIONEER > 7.Electrical-Switch & Relay
# [剩余数量：821] - [当前时间：15:49:04]
#
# [状态：ok，尝试次数：1] - 369.PIONEER > 13.Interior
# [剩余数量：820] - [当前时间：15:49:04]
#
# [状态：ok，尝试次数：8] - 369.PIONEER > 12.Ignition
# [剩余数量：819] - [当前时间：15:49:04]
#
# [状态：ok，尝试次数：18] - 369.PIONEER > 11.Hardware
# [剩余数量：818] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：1] - 369.PIONEER > 16.Transmission-Manual
# [剩余数量：817] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：20] - 366.PIAA > 1.Wiper & Washer
# [剩余数量：816] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：6] - 371.POWER BRAKE EXCHANGE > 1.Brake & Wheel Hub
# [剩余数量：815] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：22] - 369.PIONEER > 9.Exhaust & Emission
# [剩余数量：814] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：14] - 369.PIONEER > 10.Fuel & Air
# [剩余数量：813] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：20] - 357.PERFECT STOP > 1.Brake & Wheel Hub
# [剩余数量：812] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：2] - 373.POWER TRAIN COMPONENTS > 4.Engine
# [剩余数量：811] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：5] - 373.POWER TRAIN COMPONENTS > 2.Drivetrain
# [剩余数量：810] - [当前时间：15:49:05]
#
# [状态：ok，尝试次数：24] - 369.PIONEER > 15.Transmission-Automatic
# [剩余数量：809] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：8] - 372.POWER STOP > 1.Brake & Wheel Hub
# [剩余数量：808] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：3] - 369.PIONEER > 8.Engine
# [剩余数量：807] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：13] - 373.POWER TRAIN COMPONENTS > 3.Electrical
# [剩余数量：806] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：2] - 374.POWERFLO > 1.Engine
# [剩余数量：805] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：4] - 373.POWER TRAIN COMPONENTS > 6.Fuel & Air
# [剩余数量：804] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：1] - 375.POWERMAX > 1.Ignition
# [剩余数量：803] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：10] - 373.POWER TRAIN COMPONENTS > 8.Suspension
# [剩余数量：802] - [当前时间：15:49:06]
#
# [状态：ok，尝试次数：1] - 376.POWERPATH > 2.Ignition
# [剩余数量：801] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：7] - 374.POWERFLO > 2.Fuel & Air
# [剩余数量：800] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：9] - 377.PRAEFKE BRAKE & SUPPLY CORP. > 1.Brake & Wheel Hub
# [剩余数量：799] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：22] - 373.POWER TRAIN COMPONENTS > 7.Steering
# [剩余数量：798] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：37] - 373.POWER TRAIN COMPONENTS > 1.Brake & Wheel Hub
# [剩余数量：797] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：2] - 378.PRECISE > 1.Fuel & Air
# [剩余数量：796] - [当前时间：15:49:07]
#
# [状态：ok，尝试次数：51] - 369.PIONEER > 14.Suspension
# [剩余数量：795] - [当前时间：15:49:08]
#
# [状态：ok，尝试次数：2] - 379.PRECISION > 5.Interior
# [剩余数量：794] - [当前时间：15:49:08]
#
# [状态：ok，尝试次数：4] - 380.PRECISION AUTOMOTIVE > 2.Drivetrain
# [剩余数量：793] - [当前时间：15:49:08]
#
# [状态：ok，尝试次数：3] - 379.PRECISION > 2.Cooling System
# [剩余数量：792] - [当前时间：15:49:08]
#
# [状态：ok，尝试次数：79] - 367.PIERBURG > 1.Brake & Wheel Hub
# [剩余数量：791] - [当前时间：15:49:08]
#
# [状态：ok，尝试次数：12] - 380.PRECISION AUTOMOTIVE > 1.Brake & Wheel Hub
# [剩余数量：790] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：10] - 379.PRECISION > 1.Body & Lamp Assembly
# [剩余数量：789] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：3] - 380.PRECISION AUTOMOTIVE > 4.Engine
# [剩余数量：788] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：1] - 381.PREFERRED COMPONENTS INC > 1.Cooling System
# [剩余数量：787] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：2] - 380.PRECISION AUTOMOTIVE > 6.Transmission-Manual
# [剩余数量：786] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：13] - 380.PRECISION AUTOMOTIVE > 3.Electrical
# [剩余数量：785] - [当前时间：15:49:09]
#
# [状态：ok，尝试次数：23] - 379.PRECISION > 3.Engine
# [剩余数量：784] - [当前时间：15:49:10]
#
# [状态：ok，尝试次数：1] - 383.PRESTOLITE > 2.Ignition
# [剩余数量：783] - [当前时间：15:49:10]
#
# [状态：ok，尝试次数：3] - 384.PRESTONE > 1.Brake & Wheel Hub
# [剩余数量：782] - [当前时间：15:49:10]
#
# [状态：ok，尝试次数：17] - 382.PRENCO > 1.Brake & Wheel Hub
# [剩余数量：781] - [当前时间：15:49:10]
#
# [状态：ok，尝试次数：68] - 369.PIONEER > 3.Cooling System
# [剩余数量：780] - [当前时间：15:49:10]
#
# [状态：ok，尝试次数：19] - 382.PRENCO > 2.Ignition
# [剩余数量：779] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：3] - 381.PREFERRED COMPONENTS INC > 2.Engine
# [剩余数量：778] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：12] - 385.PRIME GUARD > 1.Engine
# [剩余数量：777] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：21] - 380.PRECISION AUTOMOTIVE > 5.Transmission-Automatic
# [剩余数量：776] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：3] - 387.PRIOR > 1.Brake & Wheel Hub
# [剩余数量：775] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：2] - 376.POWERPATH > 1.Electrical
# [剩余数量：774] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：8] - 386.PRIME SOURCE > 1.Heat & Air Conditioning
# [剩余数量：773] - [当前时间：15:49:11]
#
# [状态：ok，尝试次数：4] - 388.PRO LINE > 1.Brake & Wheel Hub
# [剩余数量：772] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：4] - 384.PRESTONE > 3.Exhaust & Emission
# [剩余数量：771] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：2] - 385.PRIME GUARD > 2.Fuel & Air
# [剩余数量：770] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：3] - 388.PRO LINE > 6.Transmission-Automatic
# [剩余数量：769] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：8] - 383.PRESTOLITE > 1.Electrical-Connector
# [剩余数量：768] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：5] - 389.PRO-GAUGE > 1.Engine
# [剩余数量：767] - [当前时间：15:49:12]
#
# [状态：ok，尝试次数：28] - 373.POWER TRAIN COMPONENTS > 9.Transmission-Automatic
# [剩余数量：766] - [当前时间：15:49:13]
#
# [状态：ok，尝试次数：2] - 388.PRO LINE > 4.Steering
# [剩余数量：765] - [当前时间：15:49:13]
#
# [状态：ok，尝试次数：13] - 388.PRO LINE > 3.Engine
# [剩余数量：764] - [当前时间：15:49:13]
#
# [状态：ok，尝试次数：1] - 391.PRO-TEC > 2.Fuel & Air
# [剩余数量：763] - [当前时间：15:49:13]
#
# [状态：ok，尝试次数：13] - 390.PRO-KING > 2.Fuel & Air
# [剩余数量：762] - [当前时间：15:49:13]
#
# [状态：ok，尝试次数：5] - 373.POWER TRAIN COMPONENTS > 10.Transmission-Manual
# [剩余数量：761] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：7] - 390.PRO-KING > 3.Transmission-Automatic
# [剩余数量：760] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：11] - 391.PRO-TEC > 3.Heat & Air Conditioning
# [剩余数量：759] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：7] - 390.PRO-KING > 1.Exhaust & Emission
# [剩余数量：758] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：6] - 393.PROFESSIONAL PARTS SWEDEN > 1.Belt Drive
# [剩余数量：757] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：33] - 379.PRECISION > 4.Fuel & Air
# [剩余数量：756] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：8] - 391.PRO-TEC > 1.Engine
# [剩余数量：755] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：6] - 393.PROFESSIONAL PARTS SWEDEN > 2.Body & Lamp Assembly
# [剩余数量：754] - [当前时间：15:49:14]
#
# [状态：ok，尝试次数：22] - 384.PRESTONE > 4.Steering
# [剩余数量：753] - [当前时间：15:49:15]
#
# [状态：ok，尝试次数：1] - 393.PROFESSIONAL PARTS SWEDEN > 4.Cooling System
# [剩余数量：752] - [当前时间：15:49:15]
#
# [状态：ok，尝试次数：22] - 391.PRO-TEC > 4.Transmission-Automatic
# [剩余数量：751] - [当前时间：15:49:15]
#
# [状态：ok，尝试次数：11] - 388.PRO LINE > 5.Suspension
# [剩余数量：750] - [当前时间：15:49:15]
#
# [状态：ok，尝试次数：4] - 373.POWER TRAIN COMPONENTS > 5.Exhaust & Emission
# [剩余数量：749] - [当前时间：15:49:15]
#
# [状态：ok，尝试次数：13] - 393.PROFESSIONAL PARTS SWEDEN > 6.Electrical
# [剩余数量：748] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：16] - 384.PRESTONE > 2.Cooling System
# [剩余数量：747] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：2] - 393.PROFESSIONAL PARTS SWEDEN > 13.Garage Equipment
# [剩余数量：746] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：3] - 393.PROFESSIONAL PARTS SWEDEN > 12.Fuel & Air
# [剩余数量：745] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：4] - 393.PROFESSIONAL PARTS SWEDEN > 3.Brake & Wheel Hub
# [剩余数量：744] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：2] - 393.PROFESSIONAL PARTS SWEDEN > 10.Engine
# [剩余数量：743] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：6] - 393.PROFESSIONAL PARTS SWEDEN > 16.Hoses/Lines & Clamps
# [剩余数量：742] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：14] - 393.PROFESSIONAL PARTS SWEDEN > 11.Exhaust & Emission
# [剩余数量：741] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：16] - 393.PROFESSIONAL PARTS SWEDEN > 9.Electrical-Switch & Relay
# [剩余数量：740] - [当前时间：15:49:16]
#
# [状态：ok，尝试次数：5] - 388.PRO LINE > 2.Drivetrain
# [剩余数量：739] - [当前时间：15:49:17]
#
# [状态：ok，尝试次数：7] - 370.PLATINUM DRIVELINE > 1.Transmission-Manual
# [剩余数量：738] - [当前时间：15:49:17]
#
# [状态：ok，尝试次数：9] - 393.PROFESSIONAL PARTS SWEDEN > 19.Steering
# [剩余数量：737] - [当前时间：15:49:17]
#
# [状态：ok，尝试次数：1] - 393.PROFESSIONAL PARTS SWEDEN > 20.Suspension
# [剩余数量：736] - [当前时间：15:49:17]
#
# [状态：ok，尝试次数：15] - 393.PROFESSIONAL PARTS SWEDEN > 17.Ignition
# [剩余数量：735] - [当前时间：15:49:17]
#
# [状态：ok，尝试次数：9] - 393.PROFESSIONAL PARTS SWEDEN > 21.Transmission-Automatic
# [剩余数量：734] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：1] - 394.PROFESSIONAL'S CHOICE > 3.Fuel & Air
# [剩余数量：733] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：9] - 394.PROFESSIONAL'S CHOICE > 1.Brake & Wheel Hub
# [剩余数量：732] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：7] - 393.PROFESSIONAL PARTS SWEDEN > 7.Electrical-Bulb & Socket
# [剩余数量：731] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：2] - 396.PROMOTIVE FILTERS > 2.Fuel & Air
# [剩余数量：730] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：2] - 393.PROFESSIONAL PARTS SWEDEN > 24.Wiper & Washer
# [剩余数量：729] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：4] - 393.PROFESSIONAL PARTS SWEDEN > 14.Hardware
# [剩余数量：728] - [当前时间：15:49:18]
#
# [状态：ok，尝试次数：6] - 393.PROFESSIONAL PARTS SWEDEN > 23.Wheel
# [剩余数量：727] - [当前时间：15:49:19]
#
# [状态：ok，尝试次数：54] - 389.PRO-GAUGE > 2.Fuel & Air
# [剩余数量：726] - [当前时间：15:49:19]
#
# [状态：ok，尝试次数：9] - 396.PROMOTIVE FILTERS > 1.Engine
# [剩余数量：725] - [当前时间：15:49:19]
#
# [状态：ok，尝试次数：1] - 398.PROSPARK > 1.Ignition
# [剩余数量：724] - [当前时间：15:49:19]
#
# [状态：ok，尝试次数：57] - 393.PROFESSIONAL PARTS SWEDEN > 8.Electrical-Connector
# [剩余数量：723] - [当前时间：15:49:19]
#
# [状态：ok，尝试次数：1] - 399.PRT > 2.Suspension
# [剩余数量：722] - [当前时间：15:49:20]
#
# [状态：ok，尝试次数：1] - 399.PRT > 1.Steering
# [剩余数量：721] - [当前时间：15:49:20]
#
# [状态：ok，尝试次数：8] - 402.PUREPRO > 1.Engine
# [剩余数量：720] - [当前时间：15:49:20]
#
# [状态：ok，尝试次数：32] - 393.PROFESSIONAL PARTS SWEDEN > 22.Transmission-Manual
# [剩余数量：719] - [当前时间：15:49:21]
#
# [状态：ok，尝试次数：7] - 402.PUREPRO > 2.Fuel & Air
# [剩余数量：718] - [当前时间：15:49:21]
#
# [状态：ok，尝试次数：2] - 397.PRONTO > 2.Engine
# [剩余数量：717] - [当前时间：15:49:21]
#
# [状态：ok，尝试次数：14] - 403.PUROLATOR > 1.Engine
# [剩余数量：716] - [当前时间：15:49:21]
#
# [状态：ok，尝试次数：1] - 403.PUROLATOR > 5.Transmission-Automatic
# [剩余数量：715] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：2] - 404.PUTCO > 1.Body & Lamp Assembly
# [剩余数量：714] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：39] - 397.PRONTO > 1.Brake & Wheel Hub
# [剩余数量：713] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：3] - 403.PUROLATOR > 4.Heat & Air Conditioning
# [剩余数量：712] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：1] - 404.PUTCO > 3.Electrical-Connector
# [剩余数量：711] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：28] - 363.PERMATEX > 9.Interior
# [剩余数量：710] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：7] - 403.PUROLATOR > 3.Fuel & Air
# [剩余数量：709] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：1] - 403.PUROLATOR > 2.Exhaust & Emission
# [剩余数量：708] - [当前时间：15:49:22]
#
# [状态：ok，尝试次数：27] - 393.PROFESSIONAL PARTS SWEDEN > 5.Drivetrain
# [剩余数量：707] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：29] - 401.PURE ENERGY > 1.Electrical
# [剩余数量：706] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：39] - 395.PROMASTER BRAKE SYSTEMS > 1.Brake & Wheel Hub
# [剩余数量：705] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：1] - 404.PUTCO > 2.Electrical-Bulb & Socket
# [剩余数量：704] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：1] - 404.PUTCO > 4.Interior
# [剩余数量：703] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：5] - 405.QUAKER STATE > 2.Fuel & Air
# [剩余数量：702] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：1] - 405.QUAKER STATE > 1.Engine
# [剩余数量：701] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：2] - 406.QUALCAST > 2.Fuel & Air
# [剩余数量：700] - [当前时间：15:49:23]
#
# [状态：ok，尝试次数：2] - 406.QUALCAST > 1.Engine
# [剩余数量：699] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：5] - 407.QUALIS > 2.Steering
# [剩余数量：698] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：25] - 401.PURE ENERGY > 2.Engine
# [剩余数量：697] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：3] - 408.QUALITEE > 2.Transmission-Manual
# [剩余数量：696] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：3] - 407.QUALIS > 3.Suspension
# [剩余数量：695] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：11] - 407.QUALIS > 1.Brake & Wheel Hub
# [剩余数量：694] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：3] - 412.QUICK STEER > 2.Suspension
# [剩余数量：693] - [当前时间：15:49:24]
#
# [状态：ok，尝试次数：20] - 397.PRONTO > 3.Fuel & Air
# [剩余数量：692] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：3] - 413.QUINTON HAZELL > 1.Brake & Wheel Hub
# [剩余数量：691] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：10] - 411.QUALITY-BUILT > 1.Brake & Wheel Hub
# [剩余数量：690] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：4] - 414.R1 CONCEPTS > 1.Brake & Wheel Hub
# [剩余数量：689] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：17] - 394.PROFESSIONAL'S CHOICE > 2.Engine
# [剩余数量：688] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：17] - 400.PTC > 1.Wheel
# [剩余数量：687] - [当前时间：15:49:25]
#
# [状态：ok，尝试次数：5] - 415.RAIN-X > 1.Wiper & Washer
# [剩余数量：686] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：1] - 417.RANCHO > 7.Transmission-Automatic
# [剩余数量：685] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：6] - 409.QUALITY AUTOMOTIVE > 1.Brake & Wheel Hub
# [剩余数量：684] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：3] - 417.RANCHO > 3.Drivetrain
# [剩余数量：683] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：3] - 417.RANCHO > 5.Steering
# [剩余数量：682] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：12] - 417.RANCHO > 2.Brake & Wheel Hub
# [剩余数量：681] - [当前时间：15:49:26]
#
# [状态：ok，尝试次数：36] - 397.PRONTO > 4.Heat & Air Conditioning
# [剩余数量：680] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：15] - 417.RANCHO > 4.Engine
# [剩余数量：679] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：12] - 393.PROFESSIONAL PARTS SWEDEN > 15.Heat & Air Conditioning
# [剩余数量：678] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：1] - 418.RAYBESTOS > 5.Electrical-Switch & Relay
# [剩余数量：677] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：6] - 418.RAYBESTOS > 1.Body & Lamp Assembly
# [剩余数量：676] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：13] - 418.RAYBESTOS > 3.Drivetrain
# [剩余数量：675] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：2] - 418.RAYBESTOS > 7.Garage Equipment
# [剩余数量：674] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：46] - 410.QUALITY BRAND > 1.Brake & Wheel Hub
# [剩余数量：673] - [当前时间：15:49:27]
#
# [状态：ok，尝试次数：13] - 393.PROFESSIONAL PARTS SWEDEN > 18.Interior
# [剩余数量：672] - [当前时间：15:49:28]
#
# [状态：ok，尝试次数：35] - 417.RANCHO > 6.Suspension
# [剩余数量：671] - [当前时间：15:49:28]
#
# [状态：ok，尝试次数：1] - 418.RAYBESTOS > 11.Transmission-Automatic
# [剩余数量：670] - [当前时间：15:49:28]
#
# [状态：ok，尝试次数：1] - 418.RAYBESTOS > 13.Wheel
# [剩余数量：669] - [当前时间：15:49:28]
#
# [状态：ok，尝试次数：4] - 420.RDS > 1.Fuel & Air
# [剩余数量：668] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：21] - 418.RAYBESTOS > 6.Fuel & Air
# [剩余数量：667] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：4] - 418.RAYBESTOS > 10.Suspension
# [剩余数量：666] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：10] - 421.REESE TOWPOWER > 2.Electrical-Connector
# [剩余数量：665] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：38] - 412.QUICK STEER > 1.Steering
# [剩余数量：664] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：15] - 418.RAYBESTOS > 12.Transmission-Manual
# [剩余数量：663] - [当前时间：15:49:29]
#
# [状态：ok，尝试次数：27] - 408.QUALITEE > 1.Brake & Wheel Hub
# [剩余数量：662] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：19] - 418.RAYBESTOS > 2.Brake & Wheel Hub
# [剩余数量：661] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：38] - 418.RAYBESTOS > 4.Electrical-Connector
# [剩余数量：660] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：8] - 422.REIN > 4.Cooling System
# [剩余数量：659] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：19] - 418.RAYBESTOS > 8.Hardware
# [剩余数量：658] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：20] - 419.RAYBESTOS POWERTRAIN > 1.Transmission-Automatic
# [剩余数量：657] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：2] - 422.REIN > 7.Electrical-Switch & Relay
# [剩余数量：656] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：6] - 422.REIN > 6.Electrical
# [剩余数量：655] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：15] - 422.REIN > 3.Brake & Wheel Hub
# [剩余数量：654] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：18] - 422.REIN > 2.Body & Lamp Assembly
# [剩余数量：653] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：77] - 417.RANCHO > 1.Body & Lamp Assembly
# [剩余数量：652] - [当前时间：15:49:30]
#
# [状态：ok，尝试次数：33] - 421.REESE TOWPOWER > 1.Body & Lamp Assembly
# [剩余数量：651] - [当前时间：15:49:31]
#
# [状态：ok，尝试次数：23] - 422.REIN > 5.Drivetrain
# [剩余数量：650] - [当前时间：15:49:31]
#
# [状态：ok，尝试次数：40] - 422.REIN > 1.Belt Drive
# [剩余数量：649] - [当前时间：15:49:31]
#
# [状态：ok，尝试次数：2] - 422.REIN > 13.Steering
# [剩余数量：648] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：52] - 418.RAYBESTOS > 9.Steering
# [剩余数量：647] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：3] - 392.PRO-TECH > 1.Ignition
# [剩余数量：646] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：5] - 424.REMSA OF AMERICA > 1.Brake & Wheel Hub
# [剩余数量：645] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：1] - 427.RETECH > 1.Fuel & Air
# [剩余数量：644] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：19] - 422.REIN > 14.Suspension
# [剩余数量：643] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：13] - 422.REIN > 15.Transmission-Automatic
# [剩余数量：642] - [当前时间：15:49:32]
#
# [状态：ok，尝试次数：18] - 422.REIN > 18.Wiper & Washer
# [剩余数量：641] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：26] - 422.REIN > 17.Wheel
# [剩余数量：640] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：19] - 423.RELIANCE AUTOMOTIVE > 1.Electrical
# [剩余数量：639] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：19] - 422.REIN > 8.Engine
# [剩余数量：638] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：34] - 422.REIN > 11.Heat & Air Conditioning
# [剩余数量：637] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：58] - 416.RALLY ACCESSORIES > 1.Wiper & Washer
# [剩余数量：636] - [当前时间：15:49:33]
#
# [状态：ok，尝试次数：1] - 432.ROCKAUTO > 1.Apparel & Gifts
# [剩余数量：635] - [当前时间：15:49:34]
#
# [状态：ok，尝试次数：34] - 422.REIN > 9.Exhaust & Emission
# [剩余数量：634] - [当前时间：15:49:34]
#
# [状态：ok，尝试次数：29] - 428.RICHMOND > 1.Drivetrain
# [剩余数量：633] - [当前时间：15:49:34]
#
# [状态：ok，尝试次数：14] - 430.ROADMAX > 1.Belt Drive
# [剩余数量：632] - [当前时间：15:49:34]
#
# [状态：ok，尝试次数：20] - 429.RICHPORTER > 2.Ignition
# [剩余数量：631] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：10] - 433.ROL GASKETS > 2.Drivetrain
# [剩余数量：630] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：18] - 431.ROADTUFF > 1.Brake & Wheel Hub
# [剩余数量：629] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：3] - 433.ROL GASKETS > 5.Fuel & Air
# [剩余数量：628] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：36] - 422.REIN > 12.Ignition
# [剩余数量：627] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：19] - 426.REPLEX AUTOMOTIVE > 1.Brake & Wheel Hub
# [剩余数量：626] - [当前时间：15:49:35]
#
# [状态：ok，尝试次数：7] - 434.ROSTRA > 2.Drivetrain
# [剩余数量：625] - [当前时间：15:49:36]
#
# [状态：ok，尝试次数：33] - 430.ROADMAX > 2.Cooling System
# [剩余数量：624] - [当前时间：15:49:36]
#
# [状态：ok，尝试次数：9] - 434.ROSTRA > 1.Cooling System
# [剩余数量：623] - [当前时间：15:49:36]
#
# [状态：ok，尝试次数：23] - 433.ROL GASKETS > 4.Exhaust & Emission
# [剩余数量：622] - [当前时间：15:49:36]
#
# [状态：ok，尝试次数：8] - 434.ROSTRA > 3.Electrical
# [剩余数量：621] - [当前时间：15:49:37]
#
# [状态：ok，尝试次数：9] - 434.ROSTRA > 4.Electrical-Bulb & Socket
# [剩余数量：620] - [当前时间：15:49:37]
#
# [状态：ok，尝试次数：23] - 428.RICHMOND > 3.Suspension
# [剩余数量：619] - [当前时间：15:49:37]
#
# [状态：ok，尝试次数：13] - 434.ROSTRA > 5.Electrical-Connector
# [剩余数量：618] - [当前时间：15:49:37]
#
# [状态：ok，尝试次数：2] - 434.ROSTRA > 10.Interior
# [剩余数量：617] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：9] - 434.ROSTRA > 11.Steering
# [剩余数量：616] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：3] - 430.ROADMAX > 4.Heat & Air Conditioning
# [剩余数量：615] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：22] - 433.ROL GASKETS > 1.Cooling System
# [剩余数量：614] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：16] - 434.ROSTRA > 6.Electrical-Switch & Relay
# [剩余数量：613] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：8] - 436.S.A. GEAR > 1.Cooling System
# [剩余数量：612] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：1] - 434.ROSTRA > 12.Transmission-Automatic
# [剩余数量：611] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：12] - 433.ROL GASKETS > 3.Engine
# [剩余数量：610] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：20] - 434.ROSTRA > 8.Exhaust & Emission
# [剩余数量：609] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：20] - 429.RICHPORTER > 1.Exhaust & Emission
# [剩余数量：608] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：19] - 434.ROSTRA > 9.Ignition
# [剩余数量：607] - [当前时间：15:49:38]
#
# [状态：ok，尝试次数：60] - 422.REIN > 16.Transmission-Manual
# [剩余数量：606] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：1] - 437.S.U.R.&R. > 7.Steering
# [剩余数量：605] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：13] - 436.S.A. GEAR > 2.Engine
# [剩余数量：604] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：20] - 435.ROTOMASTER > 1.Engine
# [剩余数量：603] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：11] - 437.S.U.R.&R. > 3.Fuel & Air
# [剩余数量：602] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：37] - 425.REMY > 1.Electrical
# [剩余数量：601] - [当前时间：15:49:39]
#
# [状态：ok，尝试次数：16] - 437.S.U.R.&R. > 1.Brake & Wheel Hub
# [剩余数量：600] - [当前时间：15:49:40]
#
# [状态：ok，尝试次数：3] - 438.SACHS > 2.Body & Lamp Assembly
# [剩余数量：599] - [当前时间：15:49:40]
#
# [状态：ok，尝试次数：30] - 436.S.A. GEAR > 3.Hardware
# [剩余数量：598] - [当前时间：15:49:40]
#
# [状态：ok，尝试次数：1] - 438.SACHS > 6.Suspension
# [剩余数量：597] - [当前时间：15:49:40]
#
# [状态：ok，尝试次数：22] - 437.S.U.R.&R. > 2.Engine
# [剩余数量：596] - [当前时间：15:49:40]
#
# [状态：ok，尝试次数：2] - 440.SAGINAW > 1.Transmission-Automatic
# [剩余数量：595] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：21] - 437.S.U.R.&R. > 8.Transmission-Automatic
# [剩余数量：594] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：24] - 438.SACHS > 3.Cooling System
# [剩余数量：593] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：7] - 438.SACHS > 4.Interior
# [剩余数量：592] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：8] - 441.SANYO/BRAKE HEADQUARTERS > 1.Brake & Wheel Hub
# [剩余数量：591] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：1] - 443.SBI > 1.Engine
# [剩余数量：590] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：32] - 438.SACHS > 1.Belt Drive
# [剩余数量：589] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：7] - 434.ROSTRA > 7.Engine
# [剩余数量：588] - [当前时间：15:49:41]
#
# [状态：ok，尝试次数：12] - 441.SANYO/BRAKE HEADQUARTERS > 2.Transmission-Manual
# [剩余数量：587] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：14] - 442.SATISFIED BRAKES > 1.Brake & Wheel Hub
# [剩余数量：586] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：3] - 444.SCHAEFFLER > 1.Brake & Wheel Hub
# [剩余数量：585] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：10] - 438.SACHS > 7.Transmission-Manual
# [剩余数量：584] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：43] - 437.S.U.R.&R. > 6.Hoses/Lines & Clamps
# [剩余数量：583] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：28] - 439.SAFE-LINE > 1.Brake & Wheel Hub
# [剩余数量：582] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：14] - 437.S.U.R.&R. > 4.Hardware
# [剩余数量：581] - [当前时间：15:49:42]
#
# [状态：ok，尝试次数：4] - 437.S.U.R.&R. > 5.Heat & Air Conditioning
# [剩余数量：580] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：6] - 444.SCHAEFFLER > 2.Drivetrain
# [剩余数量：579] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：16] - 443.SBI > 3.Ignition
# [剩余数量：578] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：1] - 444.SCHAEFFLER > 5.Heat & Air Conditioning
# [剩余数量：577] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：6] - 444.SCHAEFFLER > 7.Transmission-Automatic
# [剩余数量：576] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：12] - 444.SCHAEFFLER > 3.Electrical
# [剩余数量：575] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：6] - 445.SCHRADER > 1.Wheel
# [剩余数量：574] - [当前时间：15:49:43]
#
# [状态：ok，尝试次数：35] - 443.SBI > 2.Fuel & Air
# [剩余数量：573] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：22] - 444.SCHAEFFLER > 4.Engine
# [剩余数量：572] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：36] - 438.SACHS > 5.Steering
# [剩余数量：571] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：22] - 422.REIN > 10.Fuel & Air
# [剩余数量：570] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：6] - 447.SEALED POWER > 5.Transmission-Automatic
# [剩余数量：569] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：8] - 449.SHEE-MAR > 1.Body & Lamp Assembly
# [剩余数量：568] - [当前时间：15:49:44]
#
# [状态：ok，尝试次数：6] - 447.SEALED POWER > 1.Body & Lamp Assembly
# [剩余数量：567] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：12] - 447.SEALED POWER > 4.Exhaust & Emission
# [剩余数量：566] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：10] - 449.SHEE-MAR > 2.Brake & Wheel Hub
# [剩余数量：565] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：10] - 449.SHEE-MAR > 4.Drivetrain
# [剩余数量：564] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：1] - 449.SHEE-MAR > 5.Electrical
# [剩余数量：563] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：19] - 444.SCHAEFFLER > 8.Transmission-Manual
# [剩余数量：562] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：5] - 449.SHEE-MAR > 8.Electrical-Switch & Relay
# [剩余数量：561] - [当前时间：15:49:45]
#
# [状态：ok，尝试次数：11] - 448.SENSEN > 1.Suspension
# [剩余数量：560] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：10] - 449.SHEE-MAR > 7.Electrical-Connector
# [剩余数量：559] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：17] - 449.SHEE-MAR > 3.Cooling System
# [剩余数量：558] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：28] - 447.SEALED POWER > 6.Transmission-Manual
# [剩余数量：557] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：13] - 449.SHEE-MAR > 9.Engine
# [剩余数量：556] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：29] - 447.SEALED POWER > 2.Cooling System
# [剩余数量：555] - [当前时间：15:49:46]
#
# [状态：ok，尝试次数：4] - 449.SHEE-MAR > 15.Steering
# [剩余数量：554] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：16] - 449.SHEE-MAR > 11.Fuel & Air
# [剩余数量：553] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：6] - 449.SHEE-MAR > 14.Interior
# [剩余数量：552] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：51] - 447.SEALED POWER > 3.Engine
# [剩余数量：551] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：12] - 449.SHEE-MAR > 18.Transmission-Manual
# [剩余数量：550] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：4] - 449.SHEE-MAR > 10.Exhaust & Emission
# [剩余数量：549] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：33] - 449.SHEE-MAR > 6.Electrical-Bulb & Socket
# [剩余数量：548] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：61] - 428.RICHMOND > 2.Interior
# [剩余数量：547] - [当前时间：15:49:47]
#
# [状态：ok，尝试次数：1] - 449.SHEE-MAR > 13.Ignition
# [剩余数量：546] - [当前时间：15:49:48]
#
# [状态：ok，尝试次数：20] - 450.SILLA COOLING SYSTEM > 1.Heat & Air Conditioning
# [剩余数量：545] - [当前时间：15:49:48]
#
# [状态：ok，尝试次数：9] - 444.SCHAEFFLER > 6.Steering
# [剩余数量：544] - [当前时间：15:49:48]
#
# [状态：ok，尝试次数：8] - 449.SHEE-MAR > 12.Heat & Air Conditioning
# [剩余数量：543] - [当前时间：15:49:48]
#
# [状态：ok，尝试次数：6] - 452.SKF > 6.Electrical
# [剩余数量：542] - [当前时间：15:49:48]
#
# [状态：ok，尝试次数：1] - 452.SKF > 13.Transmission-Automatic
# [剩余数量：541] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：7] - 452.SKF > 7.Engine
# [剩余数量：540] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：81] - 430.ROADMAX > 3.Engine
# [剩余数量：539] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：64] - 446.SEAFOAM > 1.Garage Equipment
# [剩余数量：538] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：2] - 452.SKF > 12.Suspension
# [剩余数量：537] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：15] - 449.SHEE-MAR > 16.Suspension
# [剩余数量：536] - [当前时间：15:49:49]
#
# [状态：ok，尝试次数：31] - 452.SKF > 3.Brake & Wheel Hub
# [剩余数量：535] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：4] - 452.SKF > 15.Wheel
# [剩余数量：534] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：1] - 452.SKF > 9.Heat & Air Conditioning
# [剩余数量：533] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：9] - 452.SKF > 14.Transmission-Manual
# [剩余数量：532] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：23] - 452.SKF > 10.Ignition
# [剩余数量：531] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：5] - 453.SKP > 1.Belt Drive
# [剩余数量：530] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：2] - 453.SKP > 7.Electrical-Bulb & Socket
# [剩余数量：529] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：29] - 452.SKF > 2.Body & Lamp Assembly
# [剩余数量：528] - [当前时间：15:49:50]
#
# [状态：ok，尝试次数：41] - 451.SILV-O-LITE > 1.Engine
# [剩余数量：527] - [当前时间：15:49:51]
#
# [状态：ok，尝试次数：4] - 453.SKP > 9.Electrical-Switch & Relay
# [剩余数量：526] - [当前时间：15:49:51]
#
# [状态：ok，尝试次数：62] - 452.SKF > 1.Belt Drive
# [剩余数量：525] - [当前时间：15:49:51]
#
# [状态：ok，尝试次数：1] - 453.SKP > 6.Electrical
# [剩余数量：524] - [当前时间：15:49:51]
#
# [状态：ok，尝试次数：11] - 453.SKP > 3.Brake & Wheel Hub
# [剩余数量：523] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：9] - 453.SKP > 5.Drivetrain
# [剩余数量：522] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：43] - 452.SKF > 8.Garage Equipment
# [剩余数量：521] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：18] - 452.SKF > 4.Cooling System
# [剩余数量：520] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：1] - 453.SKP > 18.Transmission-Automatic
# [剩余数量：519] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：14] - 453.SKP > 10.Engine
# [剩余数量：518] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：18] - 453.SKP > 12.Fuel & Air
# [剩余数量：517] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：5] - 453.SKP > 13.Heat & Air Conditioning
# [剩余数量：516] - [当前时间：15:49:52]
#
# [状态：ok，尝试次数：4] - 453.SKP > 2.Body & Lamp Assembly
# [剩余数量：515] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：16] - 453.SKP > 16.Steering
# [剩余数量：514] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：2] - 453.SKP > 21.Wiper & Washer
# [剩余数量：513] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：9] - 453.SKP > 20.Wheel
# [剩余数量：512] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：45] - 452.SKF > 11.Steering
# [剩余数量：511] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：24] - 453.SKP > 15.Interior
# [剩余数量：510] - [当前时间：15:49:53]
#
# [状态：ok，尝试次数：2] - 454.SONNAX > 3.Interior
# [剩余数量：509] - [当前时间：15:49:54]
#
# [状态：ok，尝试次数：8] - 454.SONNAX > 4.Transmission-Automatic
# [剩余数量：508] - [当前时间：15:49:54]
#
# [状态：ok，尝试次数：2] - 455.SOUTHERN TRUCK > 3.Fuel & Air
# [剩余数量：507] - [当前时间：15:49:54]
#
# [状态：ok，尝试次数：9] - 455.SOUTHERN TRUCK > 4.Suspension
# [剩余数量：506] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：7] - 456.SPARTA > 1.Electrical-Connector
# [剩余数量：505] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：3] - 454.SONNAX > 5.Transmission-Manual
# [剩余数量：504] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：12] - 457.SPARTAN LOCKER > 1.Drivetrain
# [剩余数量：503] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：55] - 453.SKP > 11.Exhaust & Emission
# [剩余数量：502] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：11] - 455.SOUTHERN TRUCK > 2.Electrical-Connector
# [剩余数量：501] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：2] - 455.SOUTHERN TRUCK > 1.Body & Lamp Assembly
# [剩余数量：500] - [当前时间：15:49:55]
#
# [状态：ok，尝试次数：4] - 459.SPECTRA PREMIUM > 1.Body & Lamp Assembly
# [剩余数量：499] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：67] - 453.SKP > 4.Cooling System
# [剩余数量：498] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：72] - 453.SKP > 8.Electrical-Connector
# [剩余数量：497] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：3] - 459.SPECTRA PREMIUM > 2.Cooling System
# [剩余数量：496] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：1] - 459.SPECTRA PREMIUM > 5.Exhaust & Emission
# [剩余数量：495] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：9] - 453.SKP > 14.Ignition
# [剩余数量：494] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：2] - 459.SPECTRA PREMIUM > 7.Heat & Air Conditioning
# [剩余数量：493] - [当前时间：15:49:56]
#
# [状态：ok，尝试次数：13] - 456.SPARTA > 2.Fuel & Air
# [剩余数量：492] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：9] - 459.SPECTRA PREMIUM > 4.Engine
# [剩余数量：491] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：25] - 453.SKP > 19.Transmission-Manual
# [剩余数量：490] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：1] - 459.SPECTRA PREMIUM > 3.Electrical-Connector
# [剩余数量：489] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：13] - 459.SPECTRA PREMIUM > 8.Ignition
# [剩余数量：488] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：2] - 460.SPECTRE PERFORMANCE > 2.Engine
# [剩余数量：487] - [当前时间：15:49:57]
#
# [状态：ok，尝试次数：4] - 461.SPLASH > 1.Wiper & Washer
# [剩余数量：486] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：13] - 460.SPECTRE PERFORMANCE > 1.Electrical
# [剩余数量：485] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：13] - 453.SKP > 17.Suspension
# [剩余数量：484] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：4] - 458.SPECIALTY PRODUCTS > 1.Suspension
# [剩余数量：483] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：1] - 464.SRT CHASSIS > 1.Steering
# [剩余数量：482] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：10] - 462.SPLITFIRE > 1.Ignition
# [剩余数量：481] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：16] - 454.SONNAX > 1.Drivetrain
# [剩余数量：480] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：17] - 449.SHEE-MAR > 17.Transmission-Automatic
# [剩余数量：479] - [当前时间：15:49:58]
#
# [状态：ok，尝试次数：6] - 465.STA-LUBE > 1.Brake & Wheel Hub
# [剩余数量：478] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：5] - 459.SPECTRA PREMIUM > 6.Fuel & Air
# [剩余数量：477] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：18] - 463.SPYDER > 1.Body & Lamp Assembly
# [剩余数量：476] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：9] - 460.SPECTRE PERFORMANCE > 3.Exhaust & Emission
# [剩余数量：475] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：3] - 464.SRT CHASSIS > 2.Suspension
# [剩余数量：474] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：6] - 466.STABILUS > 1.Belt Drive
# [剩余数量：473] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：22] - 460.SPECTRE PERFORMANCE > 4.Fuel & Air
# [剩余数量：472] - [当前时间：15:49:59]
#
# [状态：ok，尝试次数：17] - 465.STA-LUBE > 4.Garage Equipment
# [剩余数量：471] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：9] - 466.STABILUS > 2.Body & Lamp Assembly
# [剩余数量：470] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：1] - 468.STANDARD MOTOR PRODUCTS > 2.Brake & Wheel Hub
# [剩余数量：469] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：1] - 465.STA-LUBE > 3.Engine
# [剩余数量：468] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：2] - 468.STANDARD MOTOR PRODUCTS > 1.Body & Lamp Assembly
# [剩余数量：467] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：3] - 455.SOUTHERN TRUCK > 5.Wheel
# [剩余数量：466] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：2] - 468.STANDARD MOTOR PRODUCTS > 4.Drivetrain
# [剩余数量：465] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：2] - 468.STANDARD MOTOR PRODUCTS > 7.Electrical-Connector
# [剩余数量：464] - [当前时间：15:50:00]
#
# [状态：ok，尝试次数：6] - 468.STANDARD MOTOR PRODUCTS > 6.Electrical-Bulb & Socket
# [剩余数量：463] - [当前时间：15:50:01]
#
# [状态：ok，尝试次数：4] - 468.STANDARD MOTOR PRODUCTS > 9.Engine
# [剩余数量：462] - [当前时间：15:50:01]
#
# [状态：ok，尝试次数：14] - 468.STANDARD MOTOR PRODUCTS > 5.Electrical
# [剩余数量：461] - [当前时间：15:50:01]
#
# [状态：ok，尝试次数：10] - 466.STABILUS > 6.Steering
# [剩余数量：460] - [当前时间：15:50:01]
#
# [状态：ok，尝试次数：28] - 466.STABILUS > 4.Fuel & Air
# [剩余数量：459] - [当前时间：15:50:01]
#
# [状态：ok，尝试次数：2] - 468.STANDARD MOTOR PRODUCTS > 8.Electrical-Switch & Relay
# [剩余数量：458] - [当前时间：15:50:02]
#
# [状态：ok，尝试次数：55] - 452.SKF > 5.Drivetrain
# [剩余数量：457] - [当前时间：15:50:02]
#
# [状态：ok，尝试次数：7] - 468.STANDARD MOTOR PRODUCTS > 13.Hardware
# [剩余数量：456] - [当前时间：15:50:02]
#
# [状态：ok，尝试次数：7] - 468.STANDARD MOTOR PRODUCTS > 14.Heat & Air Conditioning
# [剩余数量：455] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：28] - 468.STANDARD MOTOR PRODUCTS > 3.Cooling System
# [剩余数量：454] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：15] - 468.STANDARD MOTOR PRODUCTS > 12.Garage Equipment
# [剩余数量：453] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：5] - 468.STANDARD MOTOR PRODUCTS > 18.Steering
# [剩余数量：452] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：16] - 468.STANDARD MOTOR PRODUCTS > 16.Ignition
# [剩余数量：451] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：10] - 468.STANDARD MOTOR PRODUCTS > 19.Suspension
# [剩余数量：450] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：25] - 468.STANDARD MOTOR PRODUCTS > 10.Exhaust & Emission
# [剩余数量：449] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：22] - 468.STANDARD MOTOR PRODUCTS > 15.Hoses/Lines & Clamps
# [剩余数量：448] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：26] - 466.STABILUS > 3.Engine
# [剩余数量：447] - [当前时间：15:50:03]
#
# [状态：ok，尝试次数：12] - 469.STANT > 1.Cooling System
# [剩余数量：446] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：23] - 465.STA-LUBE > 2.Drivetrain
# [剩余数量：445] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：2] - 469.STANT > 3.Exhaust & Emission
# [剩余数量：444] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：17] - 468.STANDARD MOTOR PRODUCTS > 21.Wheel
# [剩余数量：443] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：17] - 468.STANDARD MOTOR PRODUCTS > 22.Wiper & Washer
# [剩余数量：442] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：43] - 454.SONNAX > 2.Electrical-Switch & Relay
# [剩余数量：441] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：14] - 468.STANDARD MOTOR PRODUCTS > 20.Transmission-Automatic
# [剩余数量：440] - [当前时间：15:50:04]
#
# [状态：ok，尝试次数：28] - 469.STANT > 2.Engine
# [剩余数量：439] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：2] - 469.STANT > 5.Heat & Air Conditioning
# [剩余数量：438] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：5] - 472.STP > 2.Heat & Air Conditioning
# [剩余数量：437] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：10] - 471.STOPTECH > 1.Brake & Wheel Hub
# [剩余数量：436] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：3] - 474.SUBARU > 5.Drivetrain
# [剩余数量：435] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：6] - 468.STANDARD MOTOR PRODUCTS > 17.Interior
# [剩余数量：434] - [当前时间：15:50:05]
#
# [状态：ok，尝试次数：1] - 474.SUBARU > 2.Body & Lamp Assembly
# [剩余数量：433] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：14] - 473.STRONGARM > 2.Interior
# [剩余数量：432] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：10] - 474.SUBARU > 4.Cooling System
# [剩余数量：431] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：27] - 468.STANDARD MOTOR PRODUCTS > 11.Fuel & Air
# [剩余数量：430] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：3] - 473.STRONGARM > 1.Body & Lamp Assembly
# [剩余数量：429] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：20] - 469.STANT > 4.Fuel & Air
# [剩余数量：428] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：4] - 474.SUBARU > 8.Electrical-Connector
# [剩余数量：427] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：20] - 474.SUBARU > 1.Belt Drive
# [剩余数量：426] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：4] - 474.SUBARU > 7.Electrical-Bulb & Socket
# [剩余数量：425] - [当前时间：15:50:06]
#
# [状态：ok，尝试次数：19] - 474.SUBARU > 6.Electrical
# [剩余数量：424] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：2] - 474.SUBARU > 15.Hoses/Lines & Clamps
# [剩余数量：423] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：3] - 474.SUBARU > 16.Ignition
# [剩余数量：422] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：16] - 474.SUBARU > 9.Electrical-Switch & Relay
# [剩余数量：421] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：1] - 474.SUBARU > 21.Transmission-Manual
# [剩余数量：420] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：7] - 474.SUBARU > 11.Exhaust & Emission
# [剩余数量：419] - [当前时间：15:50:07]
#
# [状态：ok，尝试次数：5] - 474.SUBARU > 17.Interior
# [剩余数量：418] - [当前时间：15:50:08]
#
# [状态：ok，尝试次数：9] - 472.STP > 1.Fuel & Air
# [剩余数量：417] - [当前时间：15:50:08]
#
# [状态：ok，尝试次数：11] - 474.SUBARU > 3.Brake & Wheel Hub
# [剩余数量：416] - [当前时间：15:50:08]
#
# ...
# [剩余数量：181] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 8.Exhaust & Emission
# [剩余数量：180] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 3.Cooling System
# [剩余数量：179] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 10.Heat & Air Conditioning
# [剩余数量：178] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 9.Fuel & Air
# [剩余数量：177] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 13.Suspension
# [剩余数量：176] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：48] - 506.UAC > 6.Garage Equipment
# [剩余数量：175] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 6.Electrical-Switch & Relay
# [剩余数量：174] - [当前时间：15:50:48]
#
# [状态：ok，尝试次数：1] - 521.VAPEX > 1.Fuel & Air
# [剩余数量：173] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 15.Wheel
# [剩余数量：172] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：22] - 511.UNITED MOTOR PRODUCTS > 6.Electrical-Switch & Relay
# [剩余数量：171] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 14.Transmission-Automatic
# [剩余数量：170] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 16.Wiper & Washer
# [剩余数量：169] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：1] - 524.VDO / CONTINENTAL > 1.Body & Lamp Assembly
# [剩余数量：168] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：2] - 520.VALVOLINE > 9.Suspension
# [剩余数量：167] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：1] - 523.VC > 3.Electrical
# [剩余数量：166] - [当前时间：15:50:49]
#
# [状态：ok，尝试次数：2] - 523.VC > 2.Brake & Wheel Hub
# [剩余数量：165] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：1] - 522.VARIOUS MFR > 11.Interior
# [剩余数量：164] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：4] - 519.VALEO > 2.Brake & Wheel Hub
# [剩余数量：163] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：3] - 517.USA STANDARD GEAR > 1.Brake & Wheel Hub
# [剩余数量：162] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：2] - 524.VDO / CONTINENTAL > 4.Electrical
# [剩余数量：161] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：1] - 524.VDO / CONTINENTAL > 3.Cooling System
# [剩余数量：160] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：10] - 524.VDO / CONTINENTAL > 2.Brake & Wheel Hub
# [剩余数量：159] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：1] - 520.VALVOLINE > 1.Brake & Wheel Hub
# [剩余数量：158] - [当前时间：15:50:50]
#
# [状态：ok，尝试次数：2] - 524.VDO / CONTINENTAL > 9.Heat & Air Conditioning
# [剩余数量：157] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：2] - 523.VC > 4.Wiper & Washer
# [剩余数量：156] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：2] - 520.VALVOLINE > 10.Transmission-Automatic
# [剩余数量：155] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：7] - 524.VDO / CONTINENTAL > 10.Ignition
# [剩余数量：154] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：3] - 524.VDO / CONTINENTAL > 11.Interior
# [剩余数量：153] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：6] - 524.VDO / CONTINENTAL > 8.Fuel & Air
# [剩余数量：152] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：11] - 524.VDO / CONTINENTAL > 12.Wheel
# [剩余数量：151] - [当前时间：15:50:51]
#
# [状态：ok，尝试次数：7] - 522.VARIOUS MFR > 12.Steering
# [剩余数量：150] - [当前时间：15:50:52]
#
# [状态：ok，尝试次数：1] - 525.VEMO > 5.Electrical
# [剩余数量：149] - [当前时间：15:50:52]
#
# [状态：ok，尝试次数：12] - 525.VEMO > 1.Body & Lamp Assembly
# [剩余数量：148] - [当前时间：15:50:52]
#
# [状态：ok，尝试次数：9] - 525.VEMO > 3.Cooling System
# [剩余数量：147] - [当前时间：15:50:52]
#
# [状态：ok，尝试次数：16] - 524.VDO / CONTINENTAL > 13.Wiper & Washer
# [剩余数量：146] - [当前时间：15:50:52]
#
# [状态：ok，尝试次数：33] - 524.VDO / CONTINENTAL > 5.Electrical-Switch & Relay
# [剩余数量：145] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：5] - 525.VEMO > 9.Engine
# [剩余数量：144] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：13] - 525.VEMO > 6.Electrical-Bulb & Socket
# [剩余数量：143] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：1] - 525.VEMO > 14.Interior
# [剩余数量：142] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：11] - 525.VEMO > 11.Fuel & Air
# [剩余数量：141] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：8] - 525.VEMO > 13.Ignition
# [剩余数量：140] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：6] - 525.VEMO > 12.Heat & Air Conditioning
# [剩余数量：139] - [当前时间：15:50:53]
#
# [状态：ok，尝试次数：8] - 525.VEMO > 2.Brake & Wheel Hub
# [剩余数量：138] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：5] - 525.VEMO > 16.Suspension
# [剩余数量：137] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：9] - 525.VEMO > 15.Steering
# [剩余数量：136] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：2] - 525.VEMO > 20.Wiper & Washer
# [剩余数量：135] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：5] - 525.VEMO > 18.Transmission-Manual
# [剩余数量：134] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：3] - 525.VEMO > 17.Transmission-Automatic
# [剩余数量：133] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：30] - 525.VEMO > 7.Electrical-Connector
# [剩余数量：132] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：6] - 526.VICTOR REINZ > 1.Brake & Wheel Hub
# [剩余数量：131] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：30] - 525.VEMO > 4.Drivetrain
# [剩余数量：130] - [当前时间：15:50:54]
#
# [状态：ok，尝试次数：15] - 526.VICTOR REINZ > 2.Cooling System
# [剩余数量：129] - [当前时间：15:50:55]
#
# [状态：ok，尝试次数：3] - 526.VICTOR REINZ > 7.Garage Equipment
# [剩余数量：128] - [当前时间：15:50:55]
#
# [状态：ok，尝试次数：1] - 526.VICTOR REINZ > 5.Exhaust & Emission
# [剩余数量：127] - [当前时间：15:50:55]
#
# [状态：ok，尝试次数：7] - 526.VICTOR REINZ > 3.Drivetrain
# [剩余数量：126] - [当前时间：15:50:55]
#
# [状态：ok，尝试次数：39] - 525.VEMO > 8.Electrical-Switch & Relay
# [剩余数量：125] - [当前时间：15:50:55]
#
# [状态：ok，尝试次数：21] - 525.VEMO > 19.Wheel
# [剩余数量：124] - [当前时间：15:50:56]
#
# [状态：ok，尝试次数：14] - 525.VEMO > 10.Exhaust & Emission
# [剩余数量：123] - [当前时间：15:50:56]
#
# [状态：ok，尝试次数：46] - 524.VDO / CONTINENTAL > 7.Exhaust & Emission
# [剩余数量：122] - [当前时间：15:50:56]
#
# [状态：ok，尝试次数：11] - 527.VIPAR > 1.Brake & Wheel Hub
# [剩余数量：121] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：10] - 520.VALVOLINE > 5.Exhaust & Emission
# [剩余数量：120] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：45] - 524.VDO / CONTINENTAL > 6.Engine
# [剩余数量：119] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：61] - 510.ULTRA-POWER > 10.Engine
# [剩余数量：118] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：12] - 526.VICTOR REINZ > 8.Ignition
# [剩余数量：117] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：36] - 526.VICTOR REINZ > 4.Engine
# [剩余数量：116] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：16] - 528.VISTA-PRO > 2.Electrical-Switch & Relay
# [剩余数量：115] - [当前时间：15:50:57]
#
# [状态：ok，尝试次数：8] - 529.VNE > 2.Body & Lamp Assembly
# [剩余数量：114] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：4] - 529.VNE > 6.Electrical
# [剩余数量：113] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：28] - 526.VICTOR REINZ > 10.Transmission-Manual
# [剩余数量：112] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：29] - 528.VISTA-PRO > 1.Cooling System
# [剩余数量：111] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：12] - 529.VNE > 5.Drivetrain
# [剩余数量：110] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：10] - 529.VNE > 1.Belt Drive
# [剩余数量：109] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：2] - 529.VNE > 10.Fuel & Air
# [剩余数量：108] - [当前时间：15:50:58]
#
# [状态：ok，尝试次数：5] - 529.VNE > 4.Cooling System
# [剩余数量：107] - [当前时间：15:50:59]
#
# [状态：ok，尝试次数：5] - 529.VNE > 11.Heat & Air Conditioning
# [剩余数量：106] - [当前时间：15:50:59]
#
# [状态：ok，尝试次数：24] - 519.VALEO > 8.Fuel & Air
# [剩余数量：105] - [当前时间：15:50:59]
#
# [状态：ok，尝试次数：3] - 529.VNE > 15.Suspension
# [剩余数量：104] - [当前时间：15:50:59]
#
# [状态：ok，尝试次数：5] - 526.VICTOR REINZ > 9.Transmission-Automatic
# [剩余数量：103] - [当前时间：15:50:59]
#
# [状态：ok，尝试次数：2] - 530.VOLKSWAGEN > 2.Body & Lamp Assembly
# [剩余数量：102] - [当前时间：15:51:00]
#
# [状态：ok，尝试次数：14] - 529.VNE > 14.Steering
# [剩余数量：101] - [当前时间：15:51:00]
#
# [状态：ok，尝试次数：9] - 529.VNE > 7.Electrical-Switch & Relay
# [剩余数量：100] - [当前时间：15:51:00]
#
# [状态：ok，尝试次数：7] - 530.VOLKSWAGEN > 4.Cooling System
# [剩余数量：99] - [当前时间：15:51:00]
#
# [状态：ok，尝试次数：15] - 529.VNE > 16.Transmission-Automatic
# [剩余数量：98] - [当前时间：15:51:00]
#
# [状态：ok，尝试次数：5] - 529.VNE > 17.Transmission-Manual
# [剩余数量：97] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：3] - 529.VNE > 12.Ignition
# [剩余数量：96] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：23] - 529.VNE > 8.Engine
# [剩余数量：95] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：8] - 530.VOLKSWAGEN > 7.Electrical-Connector
# [剩余数量：94] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：11] - 530.VOLKSWAGEN > 3.Brake & Wheel Hub
# [剩余数量：93] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：25] - 529.VNE > 9.Exhaust & Emission
# [剩余数量：92] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：2] - 530.VOLKSWAGEN > 9.Engine
# [剩余数量：91] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：2] - 530.VOLKSWAGEN > 10.Exhaust & Emission
# [剩余数量：90] - [当前时间：15:51:01]
#
# [状态：ok，尝试次数：24] - 530.VOLKSWAGEN > 5.Electrical
# [剩余数量：89] - [当前时间：15:51:02]
#
# [状态：ok，尝试次数：10] - 530.VOLKSWAGEN > 8.Electrical-Switch & Relay
# [剩余数量：88] - [当前时间：15:51:02]
#
# [状态：ok，尝试次数：8] - 530.VOLKSWAGEN > 17.Steering
# [剩余数量：87] - [当前时间：15:51:02]
#
# [状态：ok，尝试次数：5] - 530.VOLKSWAGEN > 11.Fuel & Air
# [剩余数量：86] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：2] - 530.VOLKSWAGEN > 16.Interior
# [剩余数量：85] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：8] - 530.VOLKSWAGEN > 18.Suspension
# [剩余数量：84] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：13] - 529.VNE > 13.Interior
# [剩余数量：83] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：10] - 530.VOLKSWAGEN > 19.Transmission-Automatic
# [剩余数量：82] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：4] - 530.VOLKSWAGEN > 20.Transmission-Manual
# [剩余数量：81] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：21] - 530.VOLKSWAGEN > 14.Hoses/Lines & Clamps
# [剩余数量：80] - [当前时间：15:51:03]
#
# [状态：ok，尝试次数：18] - 530.VOLKSWAGEN > 6.Electrical-Bulb & Socket
# [剩余数量：79] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：1] - 530.VOLKSWAGEN > 22.Wiper & Washer
# [剩余数量：78] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：1] - 532.WAI GLOBAL > 1.Drivetrain
# [剩余数量：77] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：2] - 531.WAGNER > 4.Wheel
# [剩余数量：76] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：1] - 531.WAGNER > 3.Transmission-Manual
# [剩余数量：75] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：2] - 532.WAI GLOBAL > 2.Electrical
# [剩余数量：74] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：1] - 530.VOLKSWAGEN > 15.Ignition
# [剩余数量：73] - [当前时间：15:51:04]
#
# [状态：ok，尝试次数：1] - 531.WAGNER > 2.Electrical-Bulb & Socket
# [剩余数量：72] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：1] - 532.WAI GLOBAL > 5.Interior
# [剩余数量：71] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：3] - 532.WAI GLOBAL > 3.Exhaust & Emission
# [剩余数量：70] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：2] - 533.WALKER > 1.Exhaust & Emission
# [剩余数量：69] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：1] - 532.WAI GLOBAL > 6.Wiper & Washer
# [剩余数量：68] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：16] - 530.VOLKSWAGEN > 12.Hardware
# [剩余数量：67] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：3] - 530.VOLKSWAGEN > 21.Wheel
# [剩余数量：66] - [当前时间：15:51:05]
#
# [状态：ok，尝试次数：1] - 531.WAGNER > 1.Brake & Wheel Hub
# [剩余数量：65] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：13] - 530.VOLKSWAGEN > 13.Heat & Air Conditioning
# [剩余数量：64] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：2] - 534.WALKER PRODUCTS > 3.Electrical
# [剩余数量：63] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：5] - 534.WALKER PRODUCTS > 2.Cooling System
# [剩余数量：62] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：10] - 533.WALKER > 2.Hardware
# [剩余数量：61] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：3] - 534.WALKER PRODUCTS > 1.Brake & Wheel Hub
# [剩余数量：60] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：3] - 534.WALKER PRODUCTS > 5.Electrical-Connector
# [剩余数量：59] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：5] - 534.WALKER PRODUCTS > 7.Engine
# [剩余数量：58] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：12] - 534.WALKER PRODUCTS > 4.Electrical-Bulb & Socket
# [剩余数量：57] - [当前时间：15:51:06]
#
# [状态：ok，尝试次数：3] - 534.WALKER PRODUCTS > 11.Ignition
# [剩余数量：56] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：6] - 534.WALKER PRODUCTS > 9.Fuel & Air
# [剩余数量：55] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：7] - 534.WALKER PRODUCTS > 13.Wheel
# [剩余数量：54] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：5] - 534.WALKER PRODUCTS > 12.Transmission-Automatic
# [剩余数量：53] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：4] - 535.WEATHERTECH > 1.Body & Lamp Assembly
# [剩余数量：52] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：1] - 535.WEATHERTECH > 2.Interior
# [剩余数量：51] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：1] - 534.WALKER PRODUCTS > 10.Heat & Air Conditioning
# [剩余数量：50] - [当前时间：15:51:07]
#
# [状态：ok，尝试次数：5] - 528.VISTA-PRO > 4.Steering
# [剩余数量：49] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：1] - 534.WALKER PRODUCTS > 8.Exhaust & Emission
# [剩余数量：48] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：3] - 536.WESTAR > 1.Body & Lamp Assembly
# [剩余数量：47] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：18] - 528.VISTA-PRO > 3.Heat & Air Conditioning
# [剩余数量：46] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：6] - 536.WESTAR > 5.Transmission-Automatic
# [剩余数量：45] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：1] - 532.WAI GLOBAL > 4.Ignition
# [剩余数量：44] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：10] - 536.WESTAR > 3.Engine
# [剩余数量：43] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：4] - 537.WESTIN > 3.Electrical-Bulb & Socket
# [剩余数量：42] - [当前时间：15:51:08]
#
# [状态：ok，尝试次数：4] - 540.WIX > 2.Engine
# [剩余数量：41] - [当前时间：15:51:09]
#
# [状态：ok，尝试次数：3] - 539.WHITE KNIGHT > 1.Wheel
# [剩余数量：40] - [当前时间：15:51:09]
#
# [状态：ok，尝试次数：30] - 526.VICTOR REINZ > 6.Fuel & Air
# [剩余数量：39] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：19] - 537.WESTIN > 2.Electrical
# [剩余数量：38] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：6] - 540.WIX > 3.Exhaust & Emission
# [剩余数量：37] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：10] - 540.WIX > 4.Fuel & Air
# [剩余数量：36] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：7] - 537.WESTIN > 4.Electrical-Connector
# [剩余数量：35] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：11] - 540.WIX > 5.Heat & Air Conditioning
# [剩余数量：34] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：52] - 529.VNE > 3.Brake & Wheel Hub
# [剩余数量：33] - [当前时间：15:51:10]
#
# [状态：ok，尝试次数：1] - 541.WJB / INMOTION PARTS > 1.Brake & Wheel Hub
# [剩余数量：32] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：1] - 540.WIX > 6.Steering
# [剩余数量：31] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：17] - 538.WESTLING > 1.Wiper & Washer
# [剩余数量：30] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：6] - 541.WJB / INMOTION PARTS > 3.Drivetrain
# [剩余数量：29] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：83] - 530.VOLKSWAGEN > 1.Belt Drive
# [剩余数量：28] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：3] - 523.VC > 1.Belt Drive
# [剩余数量：27] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：4] - 541.WJB / INMOTION PARTS > 5.Engine
# [剩余数量：26] - [当前时间：15:51:11]
#
# [状态：ok，尝试次数：6] - 541.WJB / INMOTION PARTS > 6.Heat & Air Conditioning
# [剩余数量：25] - [当前时间：15:51:12]
#
# [状态：ok，尝试次数：3] - 541.WJB / INMOTION PARTS > 7.Ignition
# [剩余数量：24] - [当前时间：15:51:12]
#
# [状态：ok，尝试次数：15] - 537.WESTIN > 6.Wheel
# [剩余数量：23] - [当前时间：15:51:12]
#
# [状态：ok，尝试次数：19] - 541.WJB / INMOTION PARTS > 2.Cooling System
# [剩余数量：22] - [当前时间：15:51:12]
#
# [状态：ok，尝试次数：9] - 540.WIX > 1.Cooling System
# [剩余数量：21] - [当前时间：15:51:12]
#
# [状态：ok，尝试次数：1] - 544.WVE > 2.Brake & Wheel Hub
# [剩余数量：20] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：7] - 541.WJB / INMOTION PARTS > 8.Steering
# [剩余数量：19] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：11] - 542.WOLVERINE > 1.Engine
# [剩余数量：18] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：2] - 544.WVE > 3.Cooling System
# [剩余数量：17] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：14] - 543.WORLD BRAKE > 1.Brake & Wheel Hub
# [剩余数量：16] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：5] - 544.WVE > 4.Drivetrain
# [剩余数量：15] - [当前时间：15:51:13]
#
# [状态：ok，尝试次数：7] - 544.WVE > 5.Electrical
# [剩余数量：14] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：9] - 544.WVE > 6.Electrical-Bulb & Socket
# [剩余数量：13] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：1] - 544.WVE > 9.Engine
# [剩余数量：12] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：31] - 537.WESTIN > 1.Body & Lamp Assembly
# [剩余数量：11] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：4] - 544.WVE > 1.Body & Lamp Assembly
# [剩余数量：10] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：17] - 544.WVE > 7.Electrical-Connector
# [剩余数量：9] - [当前时间：15:51:14]
#
# [状态：ok，尝试次数：2] - 544.WVE > 11.Fuel & Air
# [剩余数量：8] - [当前时间：15:51:15]
#
# [状态：ok，尝试次数：13] - 544.WVE > 10.Exhaust & Emission
# [剩余数量：7] - [当前时间：15:51:15]
#
# [状态：ok，尝试次数：22] - 536.WESTAR > 4.Suspension
# [剩余数量：6] - [当前时间：15:51:15]
#
# [状态：ok，尝试次数：22] - 544.WVE > 8.Electrical-Switch & Relay
# [剩余数量：5] - [当前时间：15:51:15]
#
# [状态：ok，尝试次数：6] - 541.WJB / INMOTION PARTS > 9.Transmission-Automatic
# [剩余数量：4] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：12] - 544.WVE > 15.Ignition
# [剩余数量：3] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：6] - 544.WVE > 18.Suspension
# [剩余数量：2] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：13] - 536.WESTAR > 2.Drivetrain
# [剩余数量：1] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：7] - 540.WIX > 7.Transmission-Automatic
# [剩余数量：0] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：4] - 544.WVE > 14.Heat & Air Conditioning
# [剩余数量：0] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：2] - 544.WVE > 20.Transmission-Manual
# [剩余数量：0] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：4] - 544.WVE > 22.Wiper & Washer
# [剩余数量：0] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：1] - 544.WVE > 19.Transmission-Automatic
# [剩余数量：0] - [当前时间：15:51:16]
#
# [状态：ok，尝试次数：6] - 544.WVE > 21.Wheel
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：22] - 544.WVE > 17.Steering
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：3] - 546.XRF CHASSIS > 2.Suspension
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：10] - 544.WVE > 16.Interior
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：2] - 545.XCP > 2.Suspension
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：4] - 546.XRF CHASSIS > 1.Steering
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：4] - 547.ZF > 1.Transmission-Automatic
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：44] - 544.WVE > 13.Hardware
# [剩余数量：0] - [当前时间：15:51:17]
#
# [状态：ok，尝试次数：10] - 545.XCP > 1.Steering
# [剩余数量：0] - [当前时间：15:51:18]
#
# [状态：ok，尝试次数：15] - 541.WJB / INMOTION PARTS > 4.Electrical
# [剩余数量：0] - [当前时间：15:51:18]
#
# [状态：ok，尝试次数：2] - 544.WVE > 12.Garage Equipment
# [剩余数量：0] - [当前时间：15:51:19]
#
# [状态：ok，尝试次数：6] - 537.WESTIN > 5.Interior
# [剩余数量：0] - [当前时间：15:51:19]
#
# [状态：ok，尝试次数：22] - 534.WALKER PRODUCTS > 6.Electrical-Switch & Relay
# [剩余数量：0] - [当前时间：15:51:19]
#
# [状态：ok，尝试次数：4] - 536.WESTAR > 6.Transmission-Manual
# [剩余数量：0] - [当前时间：15:51:20]
#
# [状态：ok，尝试次数：28] - 541.WJB / INMOTION PARTS > 10.Transmission-Manual
# [剩余数量：0] - [当前时间：15:51:22]
#
# 输出ing...
#
# Done ~
