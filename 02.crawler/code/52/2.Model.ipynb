# %%
item = {'home': 'https://www.dongchedi.com/auto/library-brand/x',
 'make_no': 1,
 'letter': 'A',
 'make_code': 2,
 'make_src': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
 'make': '奥迪',
 'model_url': 'https://www.dongchedi.com/auto/library-brand/2',
 'model_url_2': 'https://www.dongchedi.com/motor/pc/car/brand/get_brand_series_list?brand_id=2'}

item
# Out:
# {'home': 'https://www.dongchedi.com/auto/library-brand/x',
#  'make_no': 1,
#  'letter': 'A',
#  'make_code': 2,
#  'make_src': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
#  'make': '奥迪',
#  'model_url': 'https://www.dongchedi.com/auto/library-brand/2',
#  'model_url_2': 'https://www.dongchedi.com/motor/pc/car/brand/get_brand_series_list?brand_id=2'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(item['model_url_2'],
                        headers=generate_header(method='requests-win'),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
dict_ = response.json()

dict_
# Out:
# {'prompts': '',
#  'status': 0,
#  'message': 'success',
#  'data': {'category_list': [{'category_code': 'all',
#     'category_name': '全部',
#     'list': [{'type': 1075,
#       'info': {'text': '轿车', 'series_list_entrance_ab': 0},
#       'unique_id': 1751092647699915195,
#       'unique_id_str': '1751092647699915195'},
#      {'type': 1002,
#       'info': {'sub_brand_name': '一汽奥迪',
#        'official_price_prefix': '指导价：',
#        'business_status': 0,
#        'series_name': '奥迪A3',
#        'official_price': '16.59-25.13万',
#        'series_id': 95,
#        'image_url': 'http://p3-dcd.byteimg.com/tos-cn-i-dcdx/2440a980eef1436cb95453dd91fbddb3~tplv-f042mdwyw7-original:960:0.png?psm=motor.pc_car.api',
#        'dealer_price': '13.27-18.85万',
#        'none_dealer_quote': False,
#        'motor_id': 20000950000000,
#        'price': '16.59-25.13万',
#        'pre_sale_date': '',
#        'pre_sale_price': '',
#        'subsidy_price': '',
#        'series_right_tag': None,
# ...

# %%
'message' not in dict_ or dict_['message'] != 'success'
# Out:
# False

# %%
list_dict = [dict_temp for dict_temp in dict_['data']['category_list'] if dict_temp['category_code'].strip() == 'all']

list_dict
# Out:
# [{'category_code': 'all',
#   'category_name': '全部',
#   'list': [{'type': 1075,
#     'info': {'text': '轿车', 'series_list_entrance_ab': 0},
#     'unique_id': 1751092647699915195,
#     'unique_id_str': '1751092647699915195'},
#    {'type': 1002,
#     'info': {'sub_brand_name': '一汽奥迪',
#      'official_price_prefix': '指导价：',
#      'business_status': 0,
#      'series_name': '奥迪A3',
#      'official_price': '16.59-25.13万',
#      'series_id': 95,
#      'image_url': 'http://p3-dcd.byteimg.com/tos-cn-i-dcdx/2440a980eef1436cb95453dd91fbddb3~tplv-f042mdwyw7-original:960:0.png?psm=motor.pc_car.api',
#      'dealer_price': '13.27-18.85万',
#      'none_dealer_quote': False,
#      'motor_id': 20000950000000,
#      'price': '16.59-25.13万',
#      'pre_sale_date': '',
#      'pre_sale_price': '',
#      'subsidy_price': '',
#      'series_right_tag': None,
#      'dcd_score': 380,
#      'top_tag': {'type': 3,
#       'text': '紧凑型轿车销量NO.18',
#       'color': '#606370',
# ...

# %%
len(list_dict) != 1
# Out:
# False

# %%
list_dict = list_dict[0]['list']

list_dict
# Out:
# [{'type': 1075,
#   'info': {'text': '轿车', 'series_list_entrance_ab': 0},
#   'unique_id': 1751092647699915195,
#   'unique_id_str': '1751092647699915195'},
#  {'type': 1002,
#   'info': {'sub_brand_name': '一汽奥迪',
#    'official_price_prefix': '指导价：',
#    'business_status': 0,
#    'series_name': '奥迪A3',
#    'official_price': '16.59-25.13万',
#    'series_id': 95,
#    'image_url': 'http://p3-dcd.byteimg.com/tos-cn-i-dcdx/2440a980eef1436cb95453dd91fbddb3~tplv-f042mdwyw7-original:960:0.png?psm=motor.pc_car.api',
#    'dealer_price': '13.27-18.85万',
#    'none_dealer_quote': False,
#    'motor_id': 20000950000000,
#    'price': '16.59-25.13万',
#    'pre_sale_date': '',
#    'pre_sale_price': '',
#    'subsidy_price': '',
#    'series_right_tag': None,
#    'dcd_score': 380,
#    'top_tag': {'type': 3,
#     'text': '紧凑型轿车销量NO.18',
#     'color': '#606370',
#     'bg_color': '#f2f4fa'},
#    'brand_id': 0,
#    'brand_name': '',
#    'sub_brand_id': 0},
# ...

# %%
not list_dict
# Out:
# False

# %%
list_dict[0]['type'] == 1075
# Out:
# True

# %%
list_dict[1]['type'] == 1002
# Out:
# True

# %%
type_ = list_dict[0]['info']['text'].strip()

type_
# Out:
# '轿车'

# %%
import json

# %%
{'home': item['home'],
 'make_no': item['make_no'],
 'letter': item['letter'],
 'make_code': item['make_code'],
 'make_src': item['make_src'],
 'make': item['make'],
 'model_url': item['model_url'],
 'model_url_2': item['model_url_2'],
 'picture': '',
 'model_no': 1,
 'type_': type_,
 'submake': list_dict[1]['info']['sub_brand_name'].strip(),
 'model': list_dict[1]['info']['series_name'].strip(),
 'model_official_price': list_dict[1]['info']['official_price'].strip(),
 'model_code': list_dict[1]['info']['series_id'],
 'year_url': f'''https://www.dongchedi.com/auto/series/{list_dict[1]['info']['series_id']}''',
 'year_url_2': f'''https://www.dongchedi.com/motor/pc/car/series/car_list?series_id={list_dict[1]['info']['series_id']}''',
 'model_src': list_dict[1]['info']['image_url'].strip(),
 'model_dealer_price': list_dict[1]['info']['dealer_price'].strip(),
 'model_price': list_dict[1]['info']['price'].strip(),
 'score': list_dict[1]['info']['dcd_score'] / 100.0}
# Out:
# {'home': 'https://www.dongchedi.com/auto/library-brand/x',
#  'make_no': 1,
#  'letter': 'A',
#  'make_code': 2,
#  'make_src': 'https://p1-dcd.byteimg.com/img/motor-mis-img/62946ba030f3589e083d8d3e98a595eb~tplv-resize:100:100.image',
#  'make': '奥迪',
#  'model_url': 'https://www.dongchedi.com/auto/library-brand/2',
#  'model_url_2': 'https://www.dongchedi.com/motor/pc/car/brand/get_brand_series_list?brand_id=2',
#  'picture': '',
#  'model_no': 1,
#  'type_': '轿车',
#  'submake': '一汽奥迪',
#  'model': '奥迪A3',
#  'model_official_price': '16.59-25.13万',
#  'model_code': 95,
#  'year_url': 'https://www.dongchedi.com/auto/series/95',
#  'year_url_2': 'https://www.dongchedi.com/motor/pc/car/series/car_list?series_id=95',
#  'model_src': 'http://p3-dcd.byteimg.com/tos-cn-i-dcdx/2440a980eef1436cb95453dd91fbddb3~tplv-f042mdwyw7-original:960:0.png?psm=motor.pc_car.api',
#  'model_dealer_price': '13.27-18.85万',
#  'model_price': '16.59-25.13万',
#  'score': 3.8}
