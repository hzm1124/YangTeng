# %%
from urllib.parse import urlsplit

# %%
tuple_ = urlsplit('https://www.4s.com/en/ecatalog?part=HVAC%20door%20actuator&type=p&search=s')

tuple_
# Out:
# SplitResult(scheme='https', netloc='www.4s.com', path='/en/ecatalog', query='part=HVAC%20door%20actuator&type=p&search=s', fragment='')

# %%
from urllib.parse import parse_qs

# %%
dict_query = {key: value[0] for key, value in parse_qs(tuple_.query).items()}

dict_query
# Out:
# {'part': 'HVAC door actuator', 'type': 'p', 'search': 's'}

# %%
dict_query_2 = {'filter': dict_query['part'],
                'filterType': dict_query.get('search', 'n'),
                'searchType': dict_query.get('type', 'null'),
                'start': 0,
                'limit': 96,
                'sort': 3,
                'catFilter': '-All-',
                'attrValueFilter': '-All-'}

dict_query_2
# Out:
# {'filter': 'HVAC door actuator',
#  'filterType': 's',
#  'searchType': 'p',
#  'start': 0,
#  'limit': 96,
#  'sort': 3,
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
from urllib.parse import urlunsplit
from urllib.parse import urlencode

# %%
url = urlunsplit((tuple_.scheme, tuple_.netloc, tuple_.path, urlencode(dict_query), tuple_.fragment))

url
# Out:
# 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s'

# %%
url_2 = urlunsplit(('https', 'ecatalog.smpcorp.com', '/v2/fs/api/part/partsearch', urlencode(dict_query_2), ''))

url_2
# Out:
# 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'

# %%
dict_ = {'home': url,
         'url_2': url_2}

dict_
# Out:
# {'home': 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s',
#  'url_2': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}

# %%
import requests

import sys
sys.path.append('../00.Tools')
from configuration import generate_header, generate_proxy

# %%
response = requests.get(dict_['url_2'],
                        headers=generate_header(),
                        proxies=generate_proxy(),
                        timeout=(10, 15),
                        allow_redirects=False)

response.status_code
# Out:
# 200

# %%
list_dict_2 = response.json()

list_dict_2
# Out:
# [{'rowId': 1,
#   'site': 'FS',
#   'webBase': '37530',
#   'brand': 'FS',
#   'basePart': '37530',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 2,
#   'site': 'FS',
#   'webBase': '37531',
#   'brand': 'FS',
#   'basePart': '37531',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 3,
#   'site': 'FS',
#   'webBase': '37532',
#   'brand': 'FS',
#   'basePart': '37532',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 4,
#   'site': 'FS',
#   'webBase': '37533',
#   'brand': 'FS',
#   'basePart': '37533',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 5,
#   'site': 'FS',
#   'webBase': '37534',
#   'brand': 'FS',
#   'basePart': '37534',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 6,
#   'site': 'FS',
#   'webBase': '37535',
#   'brand': 'FS',
#   'basePart': '37535',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 7,
#   'site': 'FS',
#   'webBase': '37536',
#   'brand': 'FS',
#   'basePart': '37536',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 8,
#   'site': 'FS',
#   'webBase': '37537',
#   'brand': 'FS',
#   'basePart': '37537',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 9,
#   'site': 'FS',
#   'webBase': '37538',
#   'brand': 'FS',
#   'basePart': '37538',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 10,
#   'site': 'FS',
#   'webBase': '37539',
#   'brand': 'FS',
#   'basePart': '37539',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 11,
#   'site': 'FS',
#   'webBase': '37540',
#   'brand': 'FS',
#   'basePart': '37540',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 12,
#   'site': 'FS',
#   'webBase': '73000',
#   'brand': 'FS',
#   'basePart': '73000',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 13,
#   'site': 'FS',
#   'webBase': '73001',
#   'brand': 'FS',
#   'basePart': '73001',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 14,
#   'site': 'FS',
#   'webBase': '73002',
#   'brand': 'FS',
#   'basePart': '73002',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 15,
#   'site': 'FS',
#   'webBase': '73003',
#   'brand': 'FS',
#   'basePart': '73003',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 16,
#   'site': 'FS',
#   'webBase': '73004',
#   'brand': 'FS',
#   'basePart': '73004',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 17,
#   'site': 'FS',
#   'webBase': '73005',
#   'brand': 'FS',
#   'basePart': '73005',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 18,
#   'site': 'FS',
#   'webBase': '73006',
#   'brand': 'FS',
#   'basePart': '73006',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 19,
#   'site': 'FS',
#   'webBase': '73007',
#   'brand': 'FS',
#   'basePart': '73007',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 20,
#   'site': 'FS',
#   'webBase': '73008',
#   'brand': 'FS',
#   'basePart': '73008',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 21,
#   'site': 'FS',
#   'webBase': '73009',
#   'brand': 'FS',
#   'basePart': '73009',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 22,
#   'site': 'FS',
#   'webBase': '73010',
#   'brand': 'FS',
#   'basePart': '73010',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 23,
#   'site': 'FS',
#   'webBase': '73011',
#   'brand': 'FS',
#   'basePart': '73011',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 24,
#   'site': 'FS',
#   'webBase': '73012',
#   'brand': 'FS',
#   'basePart': '73012',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 25,
#   'site': 'FS',
#   'webBase': '73013',
#   'brand': 'FS',
#   'basePart': '73013',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 26,
#   'site': 'FS',
#   'webBase': '73014',
#   'brand': 'FS',
#   'basePart': '73014',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 27,
#   'site': 'FS',
#   'webBase': '73015',
#   'brand': 'FS',
#   'basePart': '73015',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 28,
#   'site': 'FS',
#   'webBase': '73016',
#   'brand': 'FS',
#   'basePart': '73016',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 29,
#   'site': 'FS',
#   'webBase': '73017',
#   'brand': 'FS',
#   'basePart': '73017',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 30,
#   'site': 'FS',
#   'webBase': '73018',
#   'brand': 'FS',
#   'basePart': '73018',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 31,
#   'site': 'FS',
#   'webBase': '73019',
#   'brand': 'FS',
#   'basePart': '73019',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 32,
#   'site': 'FS',
#   'webBase': '73020',
#   'brand': 'FS',
#   'basePart': '73020',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 33,
#   'site': 'FS',
#   'webBase': '73021',
#   'brand': 'FS',
#   'basePart': '73021',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 34,
#   'site': 'FS',
#   'webBase': '73022',
#   'brand': 'FS',
#   'basePart': '73022',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 35,
#   'site': 'FS',
#   'webBase': '73023',
#   'brand': 'FS',
#   'basePart': '73023',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 36,
#   'site': 'FS',
#   'webBase': '73024',
#   'brand': 'FS',
#   'basePart': '73024',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 37,
#   'site': 'FS',
#   'webBase': '73025',
#   'brand': 'FS',
#   'basePart': '73025',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 38,
#   'site': 'FS',
#   'webBase': '73026',
#   'brand': 'FS',
#   'basePart': '73026',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 39,
#   'site': 'FS',
#   'webBase': '73027',
#   'brand': 'FS',
#   'basePart': '73027',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 40,
#   'site': 'FS',
#   'webBase': '73028',
#   'brand': 'FS',
#   'basePart': '73028',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 41,
#   'site': 'FS',
#   'webBase': '73029',
#   'brand': 'FS',
#   'basePart': '73029',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 42,
#   'site': 'FS',
#   'webBase': '73030',
#   'brand': 'FS',
#   'basePart': '73030',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 43,
#   'site': 'FS',
#   'webBase': '73031',
#   'brand': 'FS',
#   'basePart': '73031',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 44,
#   'site': 'FS',
#   'webBase': '73032',
#   'brand': 'FS',
#   'basePart': '73032',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 45,
#   'site': 'FS',
#   'webBase': '73033',
#   'brand': 'FS',
#   'basePart': '73033',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 46,
#   'site': 'FS',
#   'webBase': '73034',
#   'brand': 'FS',
#   'basePart': '73034',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 47,
#   'site': 'FS',
#   'webBase': '73035',
#   'brand': 'FS',
#   'basePart': '73035',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 48,
#   'site': 'FS',
#   'webBase': '73036',
#   'brand': 'FS',
#   'basePart': '73036',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 49,
#   'site': 'FS',
#   'webBase': '73037',
#   'brand': 'FS',
#   'basePart': '73037',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 50,
#   'site': 'FS',
#   'webBase': '73038',
#   'brand': 'FS',
#   'basePart': '73038',
#   'partDesc_en': 'HVAC Air Door Actuator; Superseded by 73041',
#   'partLongDesc_en': 'HVAC Air Door Actuator; Superseded by 73041',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 51,
#   'site': 'FS',
#   'webBase': '73039',
#   'brand': 'FS',
#   'basePart': '73039',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 52,
#   'site': 'FS',
#   'webBase': '73040',
#   'brand': 'FS',
#   'basePart': '73040',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 53,
#   'site': 'FS',
#   'webBase': '73041',
#   'brand': 'FS',
#   'basePart': '73041',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 54,
#   'site': 'FS',
#   'webBase': '73043',
#   'brand': 'FS',
#   'basePart': '73043',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 55,
#   'site': 'FS',
#   'webBase': '73044',
#   'brand': 'FS',
#   'basePart': '73044',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 56,
#   'site': 'FS',
#   'webBase': '73045',
#   'brand': 'FS',
#   'basePart': '73045',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 57,
#   'site': 'FS',
#   'webBase': '73047',
#   'brand': 'FS',
#   'basePart': '73047',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 58,
#   'site': 'FS',
#   'webBase': '73048',
#   'brand': 'FS',
#   'basePart': '73048',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 59,
#   'site': 'FS',
#   'webBase': '73049',
#   'brand': 'FS',
#   'basePart': '73049',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 60,
#   'site': 'FS',
#   'webBase': '73050',
#   'brand': 'FS',
#   'basePart': '73050',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 61,
#   'site': 'FS',
#   'webBase': '73051',
#   'brand': 'FS',
#   'basePart': '73051',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 62,
#   'site': 'FS',
#   'webBase': '73052',
#   'brand': 'FS',
#   'basePart': '73052',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 63,
#   'site': 'FS',
#   'webBase': '73053',
#   'brand': 'FS',
#   'basePart': '73053',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 64,
#   'site': 'FS',
#   'webBase': '73054',
#   'brand': 'FS',
#   'basePart': '73054',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 65,
#   'site': 'FS',
#   'webBase': '73055',
#   'brand': 'FS',
#   'basePart': '73055',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'C',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 66,
#   'site': 'FS',
#   'webBase': '73056',
#   'brand': 'FS',
#   'basePart': '73056',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 67,
#   'site': 'FS',
#   'webBase': '73057',
#   'brand': 'FS',
#   'basePart': '73057',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 68,
#   'site': 'FS',
#   'webBase': '73058',
#   'brand': 'FS',
#   'basePart': '73058',
#   'partDesc_en': 'HVAC Air Door Actuator; Superseded by 73123',
#   'partLongDesc_en': 'HVAC Air Door Actuator; Superseded by 73123',
#   'pop': 'X',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 69,
#   'site': 'FS',
#   'webBase': '73059',
#   'brand': 'FS',
#   'basePart': '73059',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 70,
#   'site': 'FS',
#   'webBase': '73060',
#   'brand': 'FS',
#   'basePart': '73060',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 71,
#   'site': 'FS',
#   'webBase': '73061',
#   'brand': 'FS',
#   'basePart': '73061',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 72,
#   'site': 'FS',
#   'webBase': '73062',
#   'brand': 'FS',
#   'basePart': '73062',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 73,
#   'site': 'FS',
#   'webBase': '73063',
#   'brand': 'FS',
#   'basePart': '73063',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 74,
#   'site': 'FS',
#   'webBase': '73064',
#   'brand': 'FS',
#   'basePart': '73064',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 75,
#   'site': 'FS',
#   'webBase': '73065',
#   'brand': 'FS',
#   'basePart': '73065',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 76,
#   'site': 'FS',
#   'webBase': '73066',
#   'brand': 'FS',
#   'basePart': '73066',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 77,
#   'site': 'FS',
#   'webBase': '73067',
#   'brand': 'FS',
#   'basePart': '73067',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 78,
#   'site': 'FS',
#   'webBase': '73068',
#   'brand': 'FS',
#   'basePart': '73068',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 79,
#   'site': 'FS',
#   'webBase': '73069',
#   'brand': 'FS',
#   'basePart': '73069',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 80,
#   'site': 'FS',
#   'webBase': '73070',
#   'brand': 'FS',
#   'basePart': '73070',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 81,
#   'site': 'FS',
#   'webBase': '73071',
#   'brand': 'FS',
#   'basePart': '73071',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 82,
#   'site': 'FS',
#   'webBase': '73072',
#   'brand': 'FS',
#   'basePart': '73072',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 83,
#   'site': 'FS',
#   'webBase': '73073',
#   'brand': 'FS',
#   'basePart': '73073',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 84,
#   'site': 'FS',
#   'webBase': '73074',
#   'brand': 'FS',
#   'basePart': '73074',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 85,
#   'site': 'FS',
#   'webBase': '73075',
#   'brand': 'FS',
#   'basePart': '73075',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 86,
#   'site': 'FS',
#   'webBase': '73076',
#   'brand': 'FS',
#   'basePart': '73076',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 87,
#   'site': 'FS',
#   'webBase': '73077',
#   'brand': 'FS',
#   'basePart': '73077',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 88,
#   'site': 'FS',
#   'webBase': '73078',
#   'brand': 'FS',
#   'basePart': '73078',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 89,
#   'site': 'FS',
#   'webBase': '73079',
#   'brand': 'FS',
#   'basePart': '73079',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 90,
#   'site': 'FS',
#   'webBase': '73081',
#   'brand': 'FS',
#   'basePart': '73081',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 91,
#   'site': 'FS',
#   'webBase': '73082',
#   'brand': 'FS',
#   'basePart': '73082',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'D',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 92,
#   'site': 'FS',
#   'webBase': '73083',
#   'brand': 'FS',
#   'basePart': '73083',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'W',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 93,
#   'site': 'FS',
#   'webBase': '73085',
#   'brand': 'FS',
#   'basePart': '73085',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'AA',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 94,
#   'site': 'FS',
#   'webBase': '73086',
#   'brand': 'FS',
#   'basePart': '73086',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 95,
#   'site': 'FS',
#   'webBase': '73087',
#   'brand': 'FS',
#   'basePart': '73087',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None},
#  {'rowId': 96,
#   'site': 'FS',
#   'webBase': '73088',
#   'brand': 'FS',
#   'basePart': '73088',
#   'partDesc_en': 'HVAC Air Door Actuator',
#   'partLongDesc_en': 'HVAC Air Door Actuator',
#   'pop': 'F',
#   'partComment': None,
#   'qtyEach': 1,
#   'webColumn_Id': None,
#   'categoryName_en': None,
#   'vehicleId': None,
#   'mfg': None,
#   'mfG_Part': None,
#   'maxRows': 622,
#   'brandLink': None,
#   'imageUrl': None}]

# %%
sku_count = list_dict_2[0]['maxRows']

sku_count
# Out:
# 622

# %%
sku_count <= 0
# Out:
# False

# %%
import math

# %%
page_count = math.ceil(sku_count / 96)

page_count
# Out:
# 7

# %%
tuple_ = urlsplit(dict_['url_2'])

tuple_
# Out:
# SplitResult(scheme='https', netloc='ecatalog.smpcorp.com', path='/v2/fs/api/part/partsearch', query='filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-', fragment='')

# %%
dict_query = {key: value[0] for key, value in parse_qs(tuple_.query).items()}

dict_query
# Out:
# {'filter': 'HVAC door actuator',
#  'filterType': 's',
#  'searchType': 'p',
#  'start': '0',
#  'limit': '96',
#  'sort': '3',
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
dict_query['start'] = 0 * 96

dict_query
# Out:
# {'filter': 'HVAC door actuator',
#  'filterType': 's',
#  'searchType': 'p',
#  'start': 0,
#  'limit': '96',
#  'sort': '3',
#  'catFilter': '-All-',
#  'attrValueFilter': '-All-'}

# %%
url = urlunsplit((tuple_.scheme, tuple_.netloc, tuple_.path, urlencode(dict_query), tuple_.fragment))

url
# Out:
# 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'

# %%
{'home': dict_['home'],
 'sku_count': sku_count,
 'page_count': page_count,
 'page': 1,
 'page_url': url}
# Out:
# {'home': 'https://www.4s.com/en/ecatalog?part=HVAC+door+actuator&type=p&search=s',
#  'sku_count': 622,
#  'page_count': 7,
#  'page': 1,
#  'page_url': 'https://ecatalog.smpcorp.com/v2/fs/api/part/partsearch?filter=HVAC+door+actuator&filterType=s&searchType=p&start=0&limit=96&sort=3&catFilter=-All-&attrValueFilter=-All-'}
