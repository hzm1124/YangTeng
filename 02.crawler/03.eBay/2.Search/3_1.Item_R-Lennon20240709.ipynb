# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# %%
input_ = pd.read_excel('./2.menu.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

print(f'总数量：{len(input_)}')
input_['Item Number'].tolist()
# Out:
# 总数量：240
# ['192540786888',
#  '324487109989',
#  '224353049418',
#  '322193331094',
#  '224382979649',
#  '324518062946',
#  '224150389874',
#  '324289348103',
#  '323912761136',
#  '223660940400',
#  '324098352250',
#  '223941545791',
#  '323521647357',
#  '223207138902',
#  '324216706132',
#  '223576047906',
#  '323851163188',
#  '324267387339',
#  '323047496677',
#  '224157488391',
#  '323338937878',
#  '223052520045',
#  '222750130681',
#  '324295731667',
#  '322932449733',
#  '322574541942',
#  '322574551063',
#  '323029000476',
#  '222810232651',
#  '222275885064',
#  '322654539501',
#  '324177186733',
#  '224022791412',
#  '325445373667',
#  '222826788617',
#  '325529298513',
#  '225409638768',
#  '323975237040',
#  '223743159120',
#  '323273996530',
#  '224330939640',
#  '322910520567',
#  '324216702146',
#  '325526649156',
#  '325526650805',
#  '323787710748',
#  '223499012607',
#  '225409629026',
#  '325529301946',
#  '323832594639',
#  '322583845696',
#  '222574775016',
#  '223552946231',
#  '222306389721',
#  '322287558734',
#  '223920990648',
#  '324078774930',
#  '322049012551',
#  '322049012533',
#  '224174433134',
#  '223479899139',
#  '222306389052',
#  '224524704177',
#  '324705592124',
#  '322656124256',
#  '223981530993',
#  '223981539370',
#  '223249618731',
#  '223013676591',
#  '323156472867',
#  '323410080876',
#  '323721103043',
#  '223706893469',
#  '324876682105',
#  '323995180383',
#  '223981486632',
#  '223552944685',
#  '322886393171',
#  '323384173607',
#  '223743478679',
#  '223743488679',
#  '224159968230',
#  '324298344182',
#  '222591586598',
#  '324063235518',
#  '222559585495',
#  '223774948683',
#  '224106173965',
#  '324251132913',
#  '223743086029',
#  '223743086130',
#  '322636176980',
#  '222603678239',
#  '324935699183',
#  '322593573281',
#  '224696928980',
#  '322172561538',
#  '223093744889',
#  '222629956108',
#  '223126383242',
#  '322794821141',
#  '224563355218',
#  '224563353178',
#  '222688301266',
#  '322841665233',
#  '324044845694',
#  '324044846589',
#  '322309112916',
#  '222727424714',
#  '222727430622',
#  '322841667058',
#  '324210268279',
#  '324210274910',
#  '324179217906',
#  '323047498020',
#  '324123095181',
#  '223964570623',
#  '322841659037',
#  '323975448656',
#  '322994866107',
#  '324133710753',
#  '224234030400',
#  '322593574081',
#  '223523354812',
#  '323812758385',
#  '323812759301',
#  '223114034695',
#  '225218152982',
#  '323928535355',
#  '324210264689',
#  '222770134434',
#  '322960085213',
#  '323622891874',
#  '323622901363',
#  '223530886147',
#  '224367114123',
#  '224563350265',
#  '323538998634',
#  '222574729437',
#  '322584777908',
#  '222575604616',
#  '224471231806',
#  '323410329730',
#  '324210266708',
#  '223821636517',
#  '322583776131',
#  '222971644934',
#  '223893055648',
#  '324373856069',
#  '223517990849',
#  '324422209459',
#  '224283447483',
#  '324838780102',
#  '224653012969',
#  '222563619793',
#  '322572193249',
#  '222603673352',
#  '222603675555',
#  '222786211067',
#  '223743082274',
#  '323975199346',
#  '224168426177',
#  '224168431562',
#  '323028996272',
#  '324210039527',
#  '323935076037',
#  '324005159920',
#  '323028994970',
#  '324466737154',
#  '323947537700',
#  '324044834032',
#  '323419066417',
#  '323419068209',
#  '223115538883',
#  '223120385638',
#  '324029114575',
#  '324029115273',
#  '222819350561',
#  '322410358049',
#  '223574017658',
#  '322348039376',
#  '323975236882',
#  '323417528660',
#  '323045784462',
#  '222820428931',
#  '323975236614',
#  '223492053612',
#  '323786764687',
#  '323832589871',
#  '223549477501',
#  '223552948059',
#  '223552949185',
#  '324177213811',
#  '324177215625',
#  '323900168546',
#  '223974851891',
#  '324166941459',
#  '323150379023',
#  '224085157606',
#  '224085160952',
#  '323159972529',
#  '222892653148',
#  '323159980792',
#  '323865013431',
#  '323865015041',
#  '324053078424',
#  '324053079117',
#  '222558621221',
#  '322567054639',
#  '223461937923',
#  '223461939170',
#  '224550968703',
#  '222363689687',
#  '224370891621',
#  '324503741174',
#  '223939551100',
#  '324096660064',
#  '223941818002',
#  '223941818028',
#  '322932440840',
#  '322881699084',
#  '323159971503',
#  '324044835525',
#  '222603594774',
#  '222603596149',
#  '323975188338',
#  '223743049887',
#  '222657362067',
#  '324280121492',
#  '222601751902',
#  '322631823737',
#  '222657358493',
#  '224140876840',
#  '224234022124',
#  '324373856828',
#  '223151066406',
#  '323452680812',
#  '223289439655',
#  '323405097691',
#  '223110066334']

# %%
a = 0

a
# Out:
# 0

# %%
crawler_status = 'error'

crawler_status
# Out:
# 'error'

# %%
import requests

import sys
sys.path.append('../../00.Tools')
from crawler_configuration import get_proxy

if input_.loc[a, 'Market'] == 'US':
    url = f'''https://www.ebay.com/itm/{input_.loc[a, 'Item Number']}?_ul=US&_stpos=91710&orig_cvip=true'''
elif input_.loc[a, 'Market'] == 'DE':
    url = f'''https://www.ebay.de/itm/{input_.loc[a, 'Item Number']}?_ul=DE&_stpos=10115&orig_cvip=true'''
elif input_.loc[a, 'Market'] == 'UK':
    url = f'''https://www.ebay.co.uk/itm/{input_.loc[a, 'Item Number']}?_ul=GB&_stpos=BS81QU&orig_cvip=true'''
elif input_.loc[a, 'Market'] == 'AU':
    url = f'''https://www.ebay.com.au/itm/{input_.loc[a, 'Item Number']}?_ul=AU&_stpos=2019&orig_cvip=true'''

resp = requests.get(url,
                    # proxies=get_proxy(),
                    timeout=(10, 10)).text

resp
# Out:
# '<!DOCTYPE html><html lang=en><head><link rel=dns-prefetch href=//thumbs.ebaystatic.com><link rel=dns-prefetch href=//vi.vipr.ebaydesc.com><link rel=dns-prefetch href=//p.ebaystatic.com><link rel=dns-prefetch href=//thumbs.ebaystatic.com><link rel=dns-prefetch href=//q.ebaystatic.com><link rel=dns-prefetch href=//pics.ebaystatic.com><link rel=dns-prefetch href=//srx.main.ebayrtm.com><link rel=dns-prefetch href=//reco.ebay.com><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();</script><style>\n    .font-marketsans body {\n        font-family: "Market Sans", Arial, sans-serif;\n    }\n</style><script>\n    (function() {\n        var useCustomFont = (\'fontDisplay\' in document.documentElement.style) ||\n                        (localStorage && localStorage.getItem(\'ebay-font\'));\n        if (useCustomFont) {\n            document.documentElement.classList.add(\'font-marketsans\');\n        }\n    })();\n</script><meta charset=utf-8><meta name=viewport content="width=device-width, initial-scale=1"><meta name=layout content=main><link rel=preload fetchpriority=high as=image href=https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l1600.jpg><script type=text/javascript>\n            try {\n                window.heroImg = "https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l1600.jpg";\n            } catch (err) {\n                console.error(err);\n            }\n        </script><meta name="twitter:title" content="Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor" /><meta name="twitter:site" content="@eBay" /><meta Property="og:type" Content="ebay-objects:item" /><meta Property="og:image" Content="https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l400.jpg" /><meta name="twitter:description" content="01/2016 99/9999 LHD Wagon 2TR FE 2.7 Petrol ATM, MTM. 01/2016 07/2017 LHD Wagon 1KD FTV 3.0 Diesel ATM, MTM. 07/2015 99/9999 LHD, RHD Wagon 2GD FTV 2.4 Diesel ATM, MTM. 01/2010 04/2015 RHD Wagon Long 2KD FTV 2.5 Diesel ATM, MTM." /><meta property="fb:app_id" content="102628213125203" /><meta name="twitter:card" content="summary" /><meta Property="og:site_name" Content="eBay" /><link href="https://i.ebayimg.com" rel="preconnect" /><meta name="referrer" content="unsafe-url" /><link rel="preconnect" href="https://ir.ebaystatic.com" /><meta Property="og:title" Content="Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor  | eBay" /><link rel="alternate" href="android-app://com.ebay.mobile/ebay/link/?nav=item.view&amp;id=192540786888&amp;referrer=http%3A%2F%2Frover.ebay.com%2Froverns%2F1%2F711-13271-9788-0%3Fmpcl%3Dhttp%253A%252F%252Fwww.ebay.com.au%252Fitm%252F192540786888" /><meta name="y_key" content="7d36d498b94ae9e7" /><title>Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor  | eBay</title><meta http-equiv="content-language" content="en-au" /><meta name="google-site-verification" content="Q4u7bvDpYVla9dUmWlKk3Y7fc6NRuW6cI-3NaXiB4Pg" /><meta name="twitter:image" content="https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l400.jpg" /><link rel="canonical" href="https://www.ebay.com.au/itm/192540786888" /><meta name="description" content="01/2016 99/9999 LHD Wagon 2TR FE 2.7 Petrol ATM, MTM. 01/2016 07/2017 LHD Wagon 1KD FTV 3.0 Diesel ATM, MTM. 07/2015 99/9999 LHD, RHD Wagon 2GD FTV 2.4 Diesel ATM, MTM. 01/2010 04/2015 RHD Wagon Long 2KD FTV 2.5 Diesel ATM, MTM." /><meta Property="og:url" Content="https://www.ebay.com.au/itm/192540786888" /><meta Property="og:description" Content="01/2016 99/9999 LHD Wagon 2TR FE 2.7 Petrol ATM, MTM. 01/2016 07/2017 LHD Wagon 1KD FTV 3.0 Diesel ATM, MTM. 07/2015 99/9999 LHD, RHD Wagon 2GD FTV 2.4 Diesel ATM, MTM. 01/2010 04/2015 RHD Wagon Long 2KD FTV 2.5 Diesel ATM, MTM." /><meta name="robots" content="max-snippet:-1, max-image-preview:larg ...

# %%
import json

json_ = json.loads(resp.split('$MC=(window.$MC||[]).concat(')[1].split(']}]})</script>')[0].strip() + ']}]}')

json_
# Out:
# {'o': {'l': 1,
#   'g': {'enableATCRedesign': 'false',
#    'lazyLoaderType': False,
#    'largerImageSize': 'FIXED_15',
#    'signedIn': False,
#    'epInfo': {'featureFlagDetails': {'dwebDeliSSE': {'value': {'NORI_ENABLED': 'true'},
#       'dropTag': 'server'},
#      'enableSMEMerchBTF': {'value': False},
#      'dwebAtfStreamingFeature': {'value': {'NORI_ENABLED': 'true',
#        'DELI_ENABLED': 'false'}},
#      'prefetchResourceFlag': {'value': {'VINODE_ENABLE_PREFETCH_RESOURCES': 'false'}},
#      'dwebAtfSplitFeature': {'value': {'VI_TEMPLATE_USE_CASE': 'VI_EVO',
#        'ATF_SPLIT': 'DEFAULT'}},
#      'enableOTPFeature': {'value': {'enableOTPFlow': 'false',
#        'enableGuestOTPAuthFlow': False},
#       'dropTag': 'browser'},
#      'enableATCRedesign': {'value': {'enableATCLayerV3': 'false'}},
#      'BXR_BUNDLED_TEST': {'value': {'ADS_SME_BTF_ENABLED': 'true',
#        'NORI_ENABLED': 'false',
#        'DELI_ENABLED': 'true'}},
#      'lazyLoaderType': {}},
#     'qTags': {}},
#    'dWebATFSplit': 'ALTERNATE',
#    'renderProgressively': True,
#    'isPrefetchResourcesOn': False,
#    'dsaReportContext': {'siteId': 0,
#     'pageId': '2332490',
#     'userType': 'BUYER',
#     'reporterType': 'GUEST',
#     'reportingChannel': 'OTHER'},
#    'enableSMEMerchBTF': True,
#    'isPreviewPage': False,
#    'pageTemplateEPValue': None,
#    'streamingTimeout': 3000,
#    'dwebAtfStreaming': False,
#    'enableDwebSSE': False,
#    'enableCTADisableTracking': True,
#    'pageMerchRequestId': '9c964c4c1900a60c5290c6ccffff2b30',
#    'urlParams': {'_ul': 'AU',
#     '_stpos': '2019',
#     'orig_cvip': 'true',
#     'correlation': 'si=9c964c5e1900a60c529404b3fffcd20e,c=1,operationId=4429486,trk-gflgs=wA**',
#     'SSRFallback': 0},
#    'enableSEOForVideos': False,
#    'enableJquery': 'https://ir.ebaystatic.com/rs/c/jquery-3.5.1.min.js',
#    'nodeEnvironment': 'production',
#    'pageTemplateId': 'ViewItem_Evo',
#    'layoutSize': 1280,
#    'txnLayers': {'isBOTxnLayerEnabled': True,
#     'isBIDTxnLayerEnabled': True,
#     'isSIOTxnLayerEnabled': True,
#     'isATCTxnLayerEnabled': False,
#     'isSkeletonTxnLayerEnabled': True},
#    'isDwebNode': True,
#    'isViEvo': True,
#    'viAppUrlHeader': 'http://www.ebay.com.au/itm/192540786888?_ul=AU&_stpos=2019&orig_cvip=true',
#    'vasAssets': {'desktop_vas': {'js': ['https://ir.ebaystatic.com/rs/c/vasfe/179.17ca6784.js'],
#      'css': ['https://ir.ebaystatic.com/rs/c/vasfe/179.da4a2a95.css'],
#      'jsMap': ['https://ir.ebaystatic.com/rs/c/vasfe/179.17ca6784.js.map'],
#      'cssMap': ['https://ir.ebaystatic.com/rs/c/vasfe/179.da4a2a95.css.map'],
#      'jsNoMin': ['https://ir.ebaystatic.com/rs/c/vasfe/179.6184fb67.nomin.js'],
#      'cssNoMin': ['https://ir.ebaystatic.com/rs/c/vasfe/179.f3370dea.nomin.css']},
#     'mobile_vas': {'js': ['https://ir.ebaystatic.com/rs/c/vasfe/179.3c3d442d.js'],
#      'css': ['https://ir.ebaystatic.com/rs/c/vasfe/179.0b9ba576.css'],
#      'jsMap': ['https://ir.ebaystatic.com/rs/c/vasfe/179.3c3d442d.js.map'],
#      'cssMap': ['https://ir.ebaystatic.com/rs/c/vasfe/179.0b9ba576.css.map'],
#      'jsNoMin': ['https://ir.ebaystatic.com/rs/c/vasfe/179.7b4166e5.nomin.js'],
#      'cssNoMin': ['https://ir.ebaystatic.com/rs/c/vasfe/179.d7d7e1bc.nomin.css']}},
#    'isTouchEnabled': False,
#    'isVerticalImageStripEnabled': True,
#    'rlogid': 't6q4pnmjbb66%3C%3Dosuu2soilac20(mpo2v*w%60ut3453-1909c964c4b-0x2404',
#    'marketplaceId': 'EBAY-AU',
#    'userId': None,
#    'country': 'AU',
#    'language': 'en',
#    'locale': 'en-AU',
#    'csrfTokens': None,
#    'csrfTokenList': {'myebayweb': {'WatchListAdd': '0100090000005068b106eaa3b20a751a821194e1b26d4aafa5abc4bdb3ff232b6a3c2e6ca31d87f3447292010a0fd044ae43bf3d4e3078962efe6c4d847e0ef80c4a9e06c523ad923f4dad312c25ba535ab338852fc8dc',
#      'WatchListAddAjax': '01000900000050f3881d55c61a01427bb26950e66eb2149f5e640e9b5dcf6157531b4f20eef96f087abaea4a0818ea81b7704b82ae21d720536259073ee6cea614d22a755c1bc89dd3e043c0a51e5274049a9b31099686',
#      'WatchListDelete': '010009000000500265c349a9222c0ce48a4e22e032ec656e6d64caf31ac31a948af13037e1934b6476383aaa0a14dca8ab20d897a35fec1c21b08c13c2823f7f03516fcd9942823f1e95403b4d9fcf139e766b876ddbd9'},
#     'myebaynode': {'MyEbayNode_AjaxHandler': '0100090000005032c2657e5ceabb950faa30ef33d0a470ff1fe4b5b59aab3cba1ec26e4c1a36408384d45b6e4d61de9e27b6358b4d4b0cb471f505abc47fe01bde3cb69d83c321016f7ee4cad48e5817353af4df65714b',
#      'MyEbayNode_AjaxHandler_watch_GET': '010009000000503d26d9934ecc9082b2abca1f9155d89b94a40b90d743c90f01f39630c8b5139488a6fcabc4a731b51104b5b8cf6d6b13b0b8fe334c27b4d4ddfd004d4f119b6b79446baea35b909d50d5f48adfe2862d',
#      'MyEbayNode_AjaxHandler_unwatch_GET': '010009000000503f87978e5c4a343d957cd1ddfdfbf748b2101c33561e48108a4e5c0628e4c4af6bf3ad1cb6fa5da8f21b02e65513f7e511160bd50b4f87d8dfaa749fdc26f3f9cb29d990edb236156edee4f419afa54f'},
#     'cartfe': {'view_cartfe': '01000900000050f97f30f25b1c4c1d297d806ec03bd55cfe9137b728cf2ab652258a1700f339f43225daa2f7941c977305617bee8854c45ce706ea5a02dd93512522afda44b664748f7ed06b74ffccd3e0945c536c2540'},
#     'nodeserv': {'customize': '010009000000508f5de8a1f34ff836d7cc976c405a3d8cda5775acc7af9d63bd81d344327f218be2ea465ced0fdc9e2781f81effb1ad9db09679f138d8133e788856143758222c635895c0cf921086e9c217ff852696e1'},
#     'shopactionsview': {'shopactionsview_act_paynow': '01000900000050418e52cf863b6616d81f64673b6039af72f95a976e0dd32f37f4e0e54a50db0e3ad2595b2f54b2856a7dc8e66e5b6034a12a55c3614367032b2d1dbcdfc6ba35a36d30e26d8833d2a9be08851d21b971',
#      'shopactionsview_act_bin': '01000900000050d25e14c1817df06890c4d65b5e32ad6d2ef586aff438cb6fe344da75cd80c6e01f0dcbb56f016babf4e2058524abc6e17a58faeb7bd2d70b80056689e4f4c9616bcbd21f9a5f563f8a1b2283567ebfeb',
#      'shopactionsview_act_atc': '01000900000050e9e43e20fcbaf6f3018a30c068f39d09015871448ecb52c073d5679faf4c5b9db4ccf142177a446ebb2e23e4924f361556ae76300cd2ee397af1d6da2c8143be28fea805d3b8470b2cd6af578618a5a2',
#      'shopactionsview_bulk_add_to_cart': '0100090000005088b4fdb86da1b20121014ce51a6c5f3a626306bef75849384da4e4c5a06bf5467d048c73002018d0a1a8272c431127f448a854b2f4f9bd4dcf7d49cfa60bd6be0dbc620bbd6cc574142af1584728af3d'},
#     'vasfe': {'vasApi': '01000900000050b2c08cd3789d27a45f3ce234afc3cbd60f2e850c4709d63ee3e508a5932cd2a8d5740db752076bfa1fc8e42abd3592ea35d519828f25a99405d34240e362486ee4c55f6bb3508841b522b3188a352bc4'},
#     'ebaypay': {'eBayPayInternalMember': '010009000000505442d6733d6f8aae072a448691c37f3554153fe2a2935a3050b498fe08eb35e04769388a853d5a1f9bce44508b9006ca0aee812357ce94ed4d2cce7bfa06b41dde8f129e7019fd85a705c9e654592c86'},
#     'webcmdsvc': {'OMSPaymentUpdateWebCommandPage': '01000900000050fe312d68886525bb072164d31e8f4af8561608ef775b6a5040873b41e16b010b5b6c2a6a5cb8e33cf2199dd8dd1dcf35747aa2ec807b7efa2395c9057b317804d81499f9bf3c1f2a12a245324fbbb60b',
#      'OMSShipmentUpdateWebCommandPage': '01000900000050dd7723cc72d546a158ae9626f1df1a3d117d651146769666d7cd1797d1dc6cc653736b2b41430d63ee23aba0bce2ed07e815c9f7fb1c690d4b9410ee4016196111a9ae0d2e35b8aacf2fdfc9036fe95a'},
#     'globalheaderfrontend': {'GHUserAcquisitionBehavior': '010009000000509db6b610d282b016da699b2f32aad12d88ea27fe152c2dc2f62a3b7db9fed3d4cf0ee80d06d04b1494340f6293846d1c633b4b8c6e88d82a27d9f4cc8270a4298a6f3ff3c005a390e1ce420743b0c759'},
#     'r1vinode': {'vinode': '01000900000050351feacb3db8820ac8e8fe11a04c3cc7924bcf4474267de14dd911b874ced0ff81a6df09c46104cb5709b08f6e9b9ffeede1e555e9b857d665285e0b3f2f46cc8ad38421dad00775fdd05191851b4bd6'},
#     'addonfe': {'aocart_proxy': '01000900000050921fb6c2038cba9d1b9ea2d79f96ab5e886ce058d3e574506a351463972bd65e775e01ad3fbfe9199a65153692c152edc52fa53f634aed01bb5b605ef3bf66b8b9e9b77dc860b0d87428e04fd6421cc2'},
#     'binview': {'atclayer': '0100090000005060f0a2f133fde80094885b03c7dff4555445b8d6aefd4b07edbacc982ad9974731fa13b3c8793695812e152f1a047ac99a01d267de10488412a00c0756405e8c00255b98b8e0ca58348dd2b2a8173b80',
#      'binlayer': '010009000000508cad32892bfd694e95c8d3b96f7f0033fcb91c4871671eca9fa7a013e09d2f50dfa60d842602f48fb6e23edaf280270a324133d03eb8d3eeb9489f558d3a733839e627ddef2587bc03918e89c78e3623'},
#     'shopcart': {'ShopCartRaptor': '010009000000505c4446b2fe7f57dba4538b643561a06fce8ad9ce8e0bb81c8f018ff1b4f5f19ad5ccf67b7219484fe8989b48037c193d3a6008e1b6d488e991b68df5abf67ab9ad8356925f7458f1f7b05ebc1e549206'},
#     'offerapp': {'boShowMakeCounterOffer': '01000900000050432c6ada9a69938ce1ce0047dd329523ca8b94a7b13648fe1abbe6c2cad92769d80c40bf48190c8f4747df5567e7dd61d32b4f0705a119ea154a3fd35101026f2f3d53561cd2490dcac4e6323462c20d',
#      'boShowDeclineCounterOffer': '01000900000050ae504dac69008982c1085f5f191279627fad4f642ffe5ed4d953cc7371f05920b40bb60760c604097a19800af3afc662da3afe393422b42b0f2c0d711822c7f5cca84a834424c3647e8a673b4a92ce4c',
#      'boAcceptCounterOffer': '010009000000507bd87610f8d4b0396a6877ca7f33012dc48b86522bd36a600bb92c982a19d91c95438b0db3a2b80f2486626264b01e02036077f6596d690ed99ef7c3ede94e261676df008353544d375a8fc65a9e6c68',
#      'binCommittobuy': '01000900000050a64341630a948139066d4bd6f10f97d842471c8b85e990bfe6bf86921ff0e348d5595fc2be1be2f09ca67e6e573e38a03ff43c632d7233d259da323872d51dc9897f1304757fbca62bc54a1f89a8c5ac'},
#     'livecommercefrontend': {'eBayLiveAPI': '010009000000503782c7739d77d2b73aa3c12e69ee896f5142b149dcf990b92b1d1ea04fa7006539fe402a9e115f6ccd31b33795a0bc9d5aa03fb34908df674187d87919af3dc7a22ed71f58ee4c9941dfb32bdf253405'}},
#    'itemId': '192540786888',
#    'isSEOMacroDataEnabled': False,
#    'isRobot': False,
#    'isSmall': False,
#    'isMobile': False},
#   'w': [['s0-1-25-7',
#     0,
#     {'model': {'lassoExtensions': ['vi_evo'],
#       'layout': None,
#       'lassoPath': './browser.json',
#       'pageRenderSetupCfg': {'templatePathPrefix': 'src/pages/item/',
#        'isItmTemplate': True,
#        'pageTemplateId': 'ViewItem_Evo'},
#       'modules': {'ITEM_SPEC_SUMMARY': {'_type': 'LayoutSectionModule',
#         'sectionLayout': {'LIST_1_COLUMN': ['sellerLegalText',
#           'itemId',
#           'revisionHistory']},
#         'sections': {'sellerLegalText': {'_type': 'LayoutSection',
#           'dataItemLayout': {'STYLE': ['PADDING-BOTTOM'],
#            'LIST_1_COLUMN': ['sellerLegalText']},
#           'dataItems': {'sellerLegalText': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': 'Seller assumes all responsibility for this listing.'}]}}},
#          'itemId': {'_type': 'LayoutSection',
#           'dataItemLayout': {'STYLE': ['ALIGN-RIGHT'],
#            'LIST_1_COLUMN': ['itemId']},
#           'dataItems': {'itemId': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': 'eBay item number:',
#               'styles': ['SECONDARY']},
#              {'_type': 'TextSpan',
#               'text': '192540786888',
#               'styles': ['BOLD']}]}}},
#          'revisionHistory': {'_type': 'LayoutSection',
#           'dataItemLayout': {'STYLE': ['PADDING-TOP'],
#            'LIST_1_COLUMN': ['revisionHistory']},
#           'dataItems': {'revisionHistory': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': 'Last updated on',
#               'styles': ['HIGHLIGHT']},
#              {'_type': 'TextSpan', 'text': ' 02 Jul, 2024 01:45:37 AEST'},
#              {'_type': 'TextSpan',
#               'text': 'View all revisions',
#               'styles': ['PSEUDOLINK'],
#               'action': {'_type': 'Action',
#                'URL': 'https://www.ebay.com.au/rvh/192540786888?rt=nc&_trksid=p4429486.m148105.l48144',
#                'type': 'OPERATION',
#                'name': 'revisionHistory',
#                'trackingList': [{'eventFamily': 'ITM',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'CLICK',
#                  'operationId': '4429486',
#                  'flushImmediately': False,
#                  'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#                   'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#                   'moduledtl': 'mi:148105|li:48144',
#                   'sid': 'p4429486.m148105.l48144'}}]},
#               'accessibilityText': 'View all revisions'}]}}}},
#         'meta': {'name': 'ITEM_SPEC_SUMMARY',
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'ITEM_SPEC_SUMMARY',
#           'sojournerModuleId': '0',
#           'scenario': '*',
#           'uxComponentGroup': 'ITEM_SPEC_SUMMARY'}}},
#        'SHIPPING_SECTION_MODULE': {'_type': 'LayoutSectionModule',
#         'title': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Postage and handling'}]},
#         'sectionLayout': {'LIST_1_COLUMN': ['shippingError',
#           'shippingError_iff',
#           'shippingDiscount',
#           'shipping',
#           'globalshipping',
#           'shippingcalculator',
#           'shippingTable',
#           'localPickupTable',
#           'handlingTime',
#           'taxes']},
#         'sections': {'shipping': {'_type': 'LayoutSection',
#           'dataItemLayout': {'LIST_1_COLUMN': ['uShipMessage',
#             'itemLocation',
#             'freightDelivery',
#             'shipsto',
#             'excludes']},
#           'dataItems': {'shipsto': {'_type': 'LabelsValuesWithUxHints',
#             'uxComponentHints': ['SECONDARY-SMALL', 'NO-SPACE'],
#             'labels': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Posts to:'},
#                {'_type': 'TextSpan', 'text': ' '}]}],
#             'values': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Worldwide',
#                 'styles': ['SECONDARY']}]}]},
#            'excludes': {'_type': 'LabelsValuesWithUxHints',
#             'uxComponentHints': ['SECONDARY-SMALL', 'NO-SPACE'],
#             'labels': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Excludes:',
#                 'styles': ['SECONDARY']},
#                {'_type': 'TextSpan', 'text': ' '}]}],
#             'values': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': "Afghanistan, Africa, Albania, American Samoa, Andorra, Anguilla, Antigua and Barbuda, Armenia, Aruba, Austria, Azerbaijan Republic, Bahamas, Bangladesh, Barbados, Belarus, Belgium, Belize, Bermuda, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, British Virgin Islands, Brunei Darussalam, Bulgaria, Cambodia, Cayman Islands, Central African Republic, Central America and Caribbean, Chad, China, Comoros, Cook Islands, Costa Rica, Cyprus, Czech Republic, Democratic People's Republic of Korea, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, El Salvador, Estonia, Fiji, French Polynesia, Georgia, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea-Bissau, Guyana, Haiti, Honduras, Hungary, Iceland, India, Ireland, Italy, Jamaica, Jersey, Kazakhstan, Kiribati, Kyrgyzstan, Laos, Latvia, Libya, Liechtenstein, Lithuania, Luxembourg, Macau, Macedonia, Madagascar, Maldives, Malta, Marshall Islands, Martinique, Mexico, Micronesia, Middle East, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Nauru, Nepal, Netherlands Antilles, Nicaragua, Niue, Norway, Pakistan, Palau, Panama, Papua New Guinea, Portugal, Puerto Rico, Republic of Croatia, Reunion, Romania, Russian Federation, Rwanda, Saint Kitts-Nevis, Saint Lucia, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, San Marino, Serbia, Sierra Leone, Singapore, Slovakia, Slovenia, Solomon Islands, Somalia, South America, Sri Lanka, Suriname, Svalbard and Jan Mayen, Sweden, Switzerland, Syria, Taiwan, Tajikistan, Tonga, Trinidad and Tobago, Tunisia, Turkmenistan, Turks and Caicos Islands, Tuvalu, Ukraine, Uzbekistan, Vanuatu, Vatican City State, Venezuela, Vietnam, Wallis and Futuna, Western Samoa, Yemen",
#                 'styles': ['SECONDARY']}]}]},
#            'itemLocation': {'_type': 'LabelsValuesWithUxHints',
#             'uxComponentHints': ['NO-SPACE', 'SECONDARY-SMALL'],
#             'labels': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Item location:'}]}],
#             'values': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Arundel, Australia',
#                 'styles': ['BOLD']}]}]}}},
#          'shippingcalculator': {'_type': 'ShippingCalculatorSection',
#           'quantity': {'_type': 'TextualEntry',
#            'fieldId': 'shQuantity',
#            'paramKey': 'quantity',
#            'paramValue': 1,
#            'label': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan', 'text': 'Quantity:'}]},
#            'validations': [{'_type': 'NumberValidation',
#              'minValue': '1',
#              'maxValue': '10',
#              'message': {'title': {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'There are 10 items available. Please enter a number less than or equal to 10.'}]},
#               'messageType': 'ERROR',
#               'displayIcon': True},
#              'required': True}]},
#           'country': {'_type': 'Group',
#            'entries': [{'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '',
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': '-Select-'}]},
#              'fieldActions': [{'whenAct': 'SELECT',
#                'doReact': 'HIDE_ZIP_GET_RATES'}]},
#             {'_type': 'TextualSelection',
#              'selected': True,
#              'paramValue': '15',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'AU',
#               'alpha3IsoCountryCode': 'AUS'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Australia'}]}},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '2',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'CA',
#               'alpha3IsoCountryCode': 'CAN'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Canada'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '70',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'FI',
#               'alpha3IsoCountryCode': 'FIN'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Finland'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '71',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'FR',
#               'alpha3IsoCountryCode': 'FRA'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'France'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '77',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'DE',
#               'alpha3IsoCountryCode': 'DEU'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Germany'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '92',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'HK',
#               'alpha3IsoCountryCode': 'HKG'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Hong Kong'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '96',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'ID',
#               'alpha3IsoCountryCode': 'IDN'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Indonesia'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '104',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'JP',
#               'alpha3IsoCountryCode': 'JPN'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Japan'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '127',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'MY',
#               'alpha3IsoCountryCode': 'MYS'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Malaysia'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '146',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'NL',
#               'alpha3IsoCountryCode': 'NLD'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Netherlands'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '148',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'NC',
#               'alpha3IsoCountryCode': 'NCL'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'New Caledonia'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '149',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'NZ',
#               'alpha3IsoCountryCode': 'NZL'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'New Zealand'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '162',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'PH',
#               'alpha3IsoCountryCode': 'PHL'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Philippines'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '163',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'PL',
#               'alpha3IsoCountryCode': 'POL'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Poland'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '111',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'KR',
#               'alpha3IsoCountryCode': 'KOR'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'South Korea'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '186',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'ES',
#               'alpha3IsoCountryCode': 'ESP'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Spain'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '199',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'TH',
#               'alpha3IsoCountryCode': 'THA'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Thailand'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '3',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'GB',
#               'alpha3IsoCountryCode': 'GBR'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'United Kingdom'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]},
#             {'_type': 'TextualSelection',
#              'selected': False,
#              'paramValue': '1',
#              'additionalParamKeyValues': {'alpha2IsoCountryCode': 'US',
#               'alpha3IsoCountryCode': 'USA'},
#              'label': {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'United States'}]},
#              'fieldActions': [{'whenAct': 'SELECT', 'doReact': 'HIDE_ZIP'}]}],
#            'fieldId': 'shCountry',
#            'disabled': False,
#            'paramKey': 'country',
#            'paramValue': '15',
#            'label': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan', 'text': 'Change country:'}]}},
#           'zipCode': {'_type': 'TextualEntry',
#            'fieldId': 'shZipCode',
#            'paramKey': 'zipCode',
#            'paramValue': '350000',
#            'label': {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan', 'text': 'Postcode:'}]}},
#           'getRates': {'_type': 'CallToAction',
#            'text': 'Get rates',
#            'type': 'SECONDARY',
#            'action': {'_type': 'Action',
#             'URL': '/itemmodules/192540786888?module_groups=GET_RATES_MODULE_GROUP&co=0&isGetRates=1&rt=nc',
#             'type': 'OPERATION',
#             'name': 'GET_RATES',
#             'params': {'quantity': '${quantity}',
#              'shipToCountryCode': '${alpha3IsoCountryCode}',
#              'shippingZipCode': '${zipCode}'},
#             'clientPresentationMetadata': {'isGetRatesNodeCommandEnabled': 'true',
#              'isGetRatesPageRefreshEnabled': 'true'},
#             'trackingList': [{'eventFamily': 'ITM',
#               'eventAction': 'ACTN',
#               'actionKind': 'CLICK',
#               'operationId': '4429486',
#               'flushImmediately': False,
#               'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#                'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#                'moduledtl': 'mi:139726|li:2682',
#                'sid': 'p4429486.m139726.l2682'}}]},
#            'actionId': 'shGetRates'}},
#          'shippingTable': {'_type': 'TableSectionWithUxHints',
#           'table': {'_type': 'Table',
#            'header': {'_type': 'TableHeader',
#             'cells': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Postage and handling'}]},
#              {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Each additional item'}]},
#              {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'To'}]},
#              {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan', 'text': 'Service'}]},
#              {'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Delivery*',
#                 'accessibilityText': 'See delivery notes'}]}]},
#            'rows': [{'_type': 'TableRow',
#              'cells': [{'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Free postage',
#                  'styles': ['BOLD']}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Free'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Australia'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Standard Parcel Delivery - Registered'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Estimated between '},
#                 {'_type': 'TextSpan',
#                  'text': 'Tue, 16 Jul',
#                  'styles': ['BOLD']},
#                 {'_type': 'TextSpan', 'text': ' and '},
#                 {'_type': 'TextSpan',
#                  'text': 'Wed, 17 Jul',
#                  'styles': ['BOLD']},
#                 {'_type': 'TextSpan', 'text': ' to '},
#                 {'_type': 'TextSpan', 'text': '350000'}]}]},
#             {'_type': 'TableRow',
#              'cells': [{'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'AU $4.00'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Free'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Australia'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Express Postage (Australia Post Express Parcel'},
#                 {'_type': 'TextSpan', 'text': ')'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Estimated between '},
#                 {'_type': 'TextSpan',
#                  'text': 'Fri, 12 Jul',
#                  'styles': ['BOLD']},
#                 {'_type': 'TextSpan', 'text': ' and '},
#                 {'_type': 'TextSpan',
#                  'text': 'Mon, 15 Jul',
#                  'styles': ['BOLD']},
#                 {'_type': 'TextSpan', 'text': ' to '},
#                 {'_type': 'TextSpan', 'text': '350000'}]}]},
#             {'_type': 'TableRow',
#              'cells': [{'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': 'Free local pickup'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Free'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Australia'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': 'Local Pickup'}]},
#               {'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan', 'text': ' '}]}]}]},
#           'footNotes': [{'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': '*',
#               'styles': ['SECONDARY']},
#              {'_type': 'TextSpan',
#               'text': 'Estimated delivery dates',
#               'styles': ['SECONDARY', 'PSEUDOLINK'],
#               'action': {'_type': 'Action',
#                'URL': 'https://pages.ebay.com.au/help/buy/contextual/estimated-delivery.html',
#                'type': 'NAV',
#                'clientPresentationMetadata': {'presentationType': 'OPEN_WINDOW'},
#                'trackingList': [{'eventFamily': 'ITM',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'CLICK',
#                  'operationId': '4429486',
#                  'flushImmediately': False,
#                  'eventProperty': {'moduledtl': 'mi:139726|li:148661',
#                   'sid': 'p4429486.m139726.l148661'}}]},
#               'accessibilityText': ' - opens in a new window or tab'},
#              {'_type': 'TextSpan',
#               'text': " include seller's handling time, origin postcode, destination postcode and time of acceptance and will depend on postage service selected and receipt of cleared payment. Delivery times may vary, especially during peak periods.",
#               'styles': ['SECONDARY']}],
#             'accessibilityText': "Notes - Delivery *Estimated delivery dates include seller's handling time, origin postcode, destination postcode and time of acceptance and will depend on postage service selected and receipt of cleared payment. Delivery times may vary, especially during peak periods."}],
#           'uxComponentHints': ['SECONDARY-SMALL']}},
#         'meta': {'name': 'SHIPPING_SECTION_MODULE',
#          'trackingList': [{'eventFamily': 'ITM',
#            'eventAction': 'VIEW',
#            'operationId': '4429486',
#            'flushImmediately': False,
#            'eventProperty': {'moduledtl': 'mi:139726'}}],
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'SHIPPING_SECTION_MODULE',
#           'sojournerModuleId': '139726',
#           'scenario': '*',
#           'uxComponentGroup': 'SHIPPING_SECTION_MODULE'}}},
#        'RETURNS_SECTION_MODULE_BUSINESS_SELLER': {'_type': 'LayoutSectionModule',
#         'title': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Return policy'}]},
#         'sectionLayout': {'LIST_1_COLUMN': ['returnsDataTable',
#           'returnsPolicySectionNoBorder',
#           'spacedRefundsByLawSection']},
#         'sections': {'returnsDataTable': {'_type': 'TableSection',
#           'table': {'_type': 'Table',
#            'header': {'_type': 'TableHeader',
#             'cells': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Item must be returned within'}]}]},
#            'rows': [{'_type': 'TableRow',
#              'cells': [{'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'text': '60 days after the buyer receives it'}]}]}]}},
#          'returnsPolicySectionNoBorder': {'_type': 'Section',
#           'dataItems': [{'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': 'The buyer is responsible for return postage costs.',
#               'styles': ['SECONDARY']}]}]},
#          'spacedRefundsByLawSection': {'_type': 'Section',
#           'dataItems': [{'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': "You must return items in their original packaging and in the same condition as when you received them. If you don't follow our "},
#              {'_type': 'TextSpan',
#               'text': 'item condition policy for returns',
#               'styles': [],
#               'action': {'_type': 'Action',
#                'URL': 'https://www.ebay.com.au/help/policies/member-behavior-policies/condition-returned-items-policy?id=4763',
#                'type': 'NAV',
#                'clientPresentationMetadata': {'presentationType': 'OPEN_WINDOW'}},
#               'accessibilityText': 'item condition policy for returns'},
#              {'_type': 'TextSpan',
#               'text': ', you may not receive a full refund.'}]},
#            {'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan',
#               'text': 'Refunds by law:',
#               'styles': ['BOLD']},
#              {'_type': 'TextSpan',
#               'text': " In Australia, consumers have a legal right to obtain a refund from a business if the goods purchased are faulty, not fit for purpose or don't match the seller's description. More information at "},
#              {'_type': 'TextSpan',
#               'text': 'returns',
#               'styles': [],
#               'action': {'_type': 'Action',
#                'URL': 'https://pages.ebay.com.au/help/buy/contextual/return-policy.html',
#                'type': 'NAV',
#                'clientPresentationMetadata': {'presentationType': 'OPEN_WINDOW'}},
#               'accessibilityText': 'returns - opens in a new window or tab'},
#              {'_type': 'TextSpan', 'text': '.'}]}]}},
#         'meta': {'name': 'RETURNS_SECTION_MODULE_BUSINESS_SELLER',
#          'trackingList': [{'eventFamily': 'ITM',
#            'eventAction': 'VIEW',
#            'operationId': '4429486',
#            'flushImmediately': False,
#            'eventProperty': {'moduledtl': 'mi:101574'}}],
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'RETURNS_SECTION_MODULE',
#           'sojournerModuleId': '101574',
#           'scenario': 'RETURNS_SECTION_MODULE_BUSINESS_SELLER',
#           'uxComponentGroup': 'RETURNS_SECTION_MODULE'}}},
#        'PAYMENTS_SECTION_MODULE': {'_type': 'LayoutSectionModule',
#         'title': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan', 'text': 'Payment details'}]},
#         'sectionLayout': {'PAYMENTS_PART_1': ['depositMethods',
#           'deposits',
#           'paymentMethods',
#           'fullPayments'],
#          'FINANCING': ['paypalCredit_us',
#           'paypalCredit_uk',
#           'afterpay_au',
#           'zippay'],
#          'PAYMENTS_PART_2': ['escrowPaymentMethods',
#           'ebayPlus',
#           'instructions',
#           'buyerProtection']},
#         'sections': {'paymentMethods': {'_type': 'TableSection',
#           'table': {'_type': 'Table',
#            'header': {'_type': 'TableHeader',
#             'cells': [{'_type': 'TextualDisplay',
#               'textSpans': [{'_type': 'TextSpan',
#                 'text': 'Payment methods'}]}]},
#            'rows': [{'_type': 'TableRow',
#              'cells': [{'_type': 'TextualDisplay',
#                'textSpans': [{'_type': 'TextSpan',
#                  'accessibilityText': 'PayPal',
#                  'icon': 'PAYPAL'},
#                 {'_type': 'TextSpan', 'text': ' '},
#                 {'_type': 'TextSpan',
#                  'accessibilityText': 'Apple Pay',
#                  'icon': 'APPLE_PAY'},
#                 {'_type': 'TextSpan', 'text': ' '},
#                 {'_type': 'TextSpan',
#                  'accessibilityText': 'Google Pay',
#                  'icon': 'GOOGLE_PAY'},
#                 {'_type': 'TextSpan', 'text': ' '},
#                 {'_type': 'TextSpan',
#                  'accessibilityText': 'Visa',
#                  'icon': 'VISA'},
#                 {'_type': 'TextSpan', 'text': ' '},
#                 {'_type': 'TextSpan',
#                  'accessibilityText': 'Mastercard',
#                  'icon': 'MASTER_CARD'},
#                 {'_type': 'TextSpan', 'text': ' '},
#                 {'_type': 'TextSpan',
#                  'accessibilityText': 'American Express',
#                  'icon': 'AM_EX'}]}]}]}},
#          'zippay': {'_type': 'IconWithDetailsSection',
#           'icon': {'_type': 'Icon', 'name': 'ZIP'},
#           'dataItems': [{'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan', 'text': 'May be available. '},
#              {'_type': 'TextSpan',
#               'text': 'Learn more',
#               'styles': [],
#               'action': {'_type': 'Action',
#                'URL': 'https://www.ebay.com.au/help/buying/paying-items/paying-zip?id=5345',
#                'type': 'NAV',
#                'name': 'FINANCING_FAQ',
#                'clientPresentationMetadata': {'presentationType': 'OPEN_WINDOW'},
#                'trackingList': [{'eventFamily': 'ITM',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'CLICK',
#                  'operationId': '4429486',
#                  'flushImmediately': False,
#                  'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#                   'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#                   'moduledtl': 'mi:47892|li:149672',
#                   'sid': 'p4429486.m47892.l149672'}}]},
#               'accessibilityText': 'See terms and apply now for Zip Pay - opens in a new window or tab'}]}]},
#          'afterpay_au': {'_type': 'IconWithDetailsSection',
#           'icon': {'_type': 'Icon', 'name': 'AFTERPAY'},
#           'dataItems': [{'_type': 'TextualDisplay',
#             'textSpans': [{'_type': 'TextSpan', 'text': 'May be available. '},
#              {'_type': 'TextSpan',
#               'text': 'Learn more',
#               'styles': [],
#               'action': {'_type': 'Action',
#                'URL': 'https://www.ebay.com.au/help/buying/paying-items/paying-with-afterpay?id=5088',
#                'type': 'NAV',
#                'name': 'FINANCING_FAQ',
#                'clientPresentationMetadata': {'presentationType': 'OPEN_WINDOW'},
#                'trackingList': [{'eventFamily': 'ITM',
#                  'eventAction': 'ACTN',
#                  'actionKind': 'CLICK',
#                  'operationId': '4429486',
#                  'flushImmediately': False,
#                  'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#                   'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#                   'moduledtl': 'mi:47892|li:46311',
#                   'sid': 'p4429486.m47892.l46311'}}]},
#               'accessibilityText': 'See terms and apply now for Afterpay - opens in a new window or tab'}]}]}},
#         'meta': {'name': 'PAYMENTS_SECTION_MODULE',
#          'trackingList': [{'eventFamily': 'ITM',
#            'eventAction': 'VIEW',
#            'operationId': '4429486',
#            'flushImmediately': False,
#            'eventProperty': {'moduledtl': 'mi:47892'}}],
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'PAYMENTS_SECTION_MODULE',
#           'sojournerModuleId': '47892',
#           'scenario': '*',
#           'uxComponentGroup': 'PAYMENTS_SECTION_MODULE'}}},
#        'BIN_NUDGE': {'_type': 'BinNudgeModule',
#         'itemTitle': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan',
#            'text': 'Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor'}]},
#         'itemImage': {'_type': 'Image',
#          'title': 'Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor',
#          'URL': 'https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l500.jpg'},
#         'signInCheckOutAction': {'_type': 'CallToAction',
#          'text': 'Sign in to check out',
#          'type': 'PRIMARY',
#          'action': {'_type': 'Action',
#           'URL': 'https://www.ebay.com.au/atc/binctr?item=192540786888&quantity=1&fromPage=4429486&rev=590&fb=1&gch=1&hideGxo=1&_trksid=p4429486.m2548.l44296',
#           'type': 'OPERATION',
#           'name': 'OPEN_BIN_NUDGE_SIGN_IN',
#           'params': {'quantity': '${qty}'},
#           'clientPresentationMetadata': {'moduleKey': 'BIN_NUDGE_SIGN_IN'},
#           'trackingList': [{'eventFamily': 'ITM',
#             'eventAction': 'ACTN',
#             'actionKind': 'CLICK',
#             'operationId': '4429486',
#             'flushImmediately': False,
#             'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#              'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#              'moduledtl': 'li:44296',
#              'sid': 'p4429486.l44296'}}]},
#          'actionId': 'SIGN_IN'},
#         'guestCheckOutAction': {'_type': 'CallToAction',
#          'text': 'Check out as a guest',
#          'type': 'SECONDARY',
#          'action': {'_type': 'Action',
#           'URL': 'https://pay.ebay.com.au/rgxo?action=create&rypsvc=true&pagename=ryp&item=192540786888&TransactionId=-1&rev=590&_trksid=p4429486.l44297',
#           'type': 'OPERATION',
#           'name': 'OPEN_BIN_NUDGE_GUEST_CHECKOUT',
#           'params': {'quantity': '${qty}', 'qty': '${qty}'},
#           'clientPresentationMetadata': {'moduleKey': 'BIN_NUDGE_GUEST_CHECKOUT'},
#           'trackingList': [{'eventFamily': 'ITM',
#             'eventAction': 'ACTN',
#             'actionKind': 'CLICK',
#             'operationId': '4429486',
#             'flushImmediately': False,
#             'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#              'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#              'moduledtl': 'li:44297',
#              'sid': 'p4429486.l44297'}}]},
#          'actionId': 'GUEST_CHECKOUT'},
#         'closeButton': {'_type': 'Action',
#          'accessibilityText': 'Close overlay'},
#         'meta': {'name': 'BIN_NUDGE',
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'BIN_NUDGE',
#           'sojournerModuleId': '0',
#           'scenario': '*',
#           'uxComponentGroup': 'BIN_NUDGE'}}},
#        'ALERT_MESSAGES': {'_type': 'OtherStatusMessagesModel',
#         'otherStatusMessages': [],
#         'meta': {'name': 'ALERT_MESSAGES',
#          'moduleIdentification': {'instanceId': '1',
#           'provider': 'ALERT_MESSAGES',
#           'sojournerModuleId': '0',
#           'scenario': '*',
#           'uxComponentGroup': 'ALERT_MESSAGES'}}},
#        'VEHICLE_SELECTION': {'_type': 'VehicleSelectionModule',
#         'header': {'_type': 'IconAndText',
#          'text': {'_type': 'TextualDisplay',
#           'textSpans': [{'_type': 'TextSpan',
#             'text': 'Confirm this item fits'}]}},
#         'subtitle': {'_type': 'TextualDisplay',
#          'textSpans': [{'_type': 'TextSpan',
#            'text': 'Add your vehicle details to make sure this item fits.'}]},
#         'callToActions': [{'_type': 'CallToAction',
#           'text': 'GET_PARTS_SELECTION',
#           'type': 'DEFAULT',
#           'action': {'_type': 'Action',
#            'type': 'OPERATION',
#            'name': 'GET_PARTS_SELECTION',
#            'params': {'marketplaceId': 'EBAY-AU',
#             'itemId': '192540786888',
#             'referrer': 'VIEWITEM',
#             'type': 'CAR_AND_TRUCK',
#             'module_groups': 'PART_FINDER',
#             'partType': 'PARTS',
#             'categoryId': '46094',
#             'queryType': 'BY_VEHICLE'},
#            'URL': 'https://www.ebay.com.au/g/api/fitment'}},
#          {'_type': 'CallToAction',
#           'text': 'Add vehicle',
#           'type': 'PRIMARY',
#           'action': {'_type': 'Action',
#            'type': 'OPERATION',
#            'name': 'CONFIRM_VEHICLE',
#            'params': {'marketplaceId': 'EBAY-AU',
#             'itemId': '192540786888',
#             'referrer': 'VIEWITEM',
#             'type': 'CAR_AND_TRUCK',
#             'module_groups': 'PART_FINDER',
#             'categoryId': '46094'},
#            'clientPresentationMetadata': {'viewTitle': 'Confirm vehicle'},
#            'trackingList': [{'eventAction': 'ACTN',
#              'actionKind': 'NAV',
#              'operationId': '4429486',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p4429486.m146132.l149809'}},
#             {'eventFamily': 'UNIVFNDR',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'operationId': '4429486',
#              'flushImmediately': False,
#              'eventProperty': {'parentrq': '9c964c4c1900a60c5290c6ccffff2b30',
#               'pageci': 'b7659619-88e6-4565-90cd-d4019cf01b4f',
#               'moduledtl': 'mi:146132|iid:1|li:149809|scen:parts'}}],
#            'URL': 'https://www.ebay.com.au/g/api/confirm'},
#           'accessibilityText': 'Add vehicle'}],
#         'errorContentMap': {'systemErrorInlineMessageAccText': 'Attention',
#          'systemErrorPrimaryText': 'Oops!',
#          'systemErrorInlineMessage': 'Something went wrong. Please try your request again.',
#          'systemErrorSecondaryTextLine2': 'Please check back later',
#          'systemErrorSecondaryTextLine1': 'Something went wrong.',
#          'systemErrorCloseButtonAccText': 'Close dialogue',
#          'systemErrorReloadButtonText': 'Reload'},
#         'vehicleSelections': [{'_type': 'Group',
#           'paramKey': 'Make',
#           'label': {'_type': 'TextualDisplay',
#            'textSpans': [{'_type': 'TextSpan', 'text': 'Make'}]},
#           'action': {'_type': 'Action',
#            'type': 'OPERATION',
#            'trackingList': [{'eventAction': 'ACTN',
#              'actionKind': 'NAV',
#              'operationId': '4429486',
#              'flushImmediately': False,
#              'eventProperty': {'sid': 'p4429486.m146132.l149929'}},
#             {'eventFamily': 'UNIVFNDR',
#              'eventAction': 'ACTN',
#              'actionKind': 'NAVSRC',
#              'operationId': '4429486',
# ...
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'SELL_NOW',
#               'uxComponentName': 'SELL_NOW',
#               'moduleType': 'SELL_NOW',
#               'dataSource': 'SELL_NOW',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'SELL_NOW',
#                'sojournerModuleId': '117039',
#                'scenario': '*',
#                'uxComponentGroup': 'SELL_NOW'}}]}}},
#          'TABS_SPR_OVERLAY': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'TAXES_OVERLAY',
#               'uxComponentName': 'TAXES_OVERLAY',
#               'moduleType': 'TAXES_OVERLAY',
#               'dataSource': 'TAXES_OVERLAY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'TAXES_OVERLAY',
#                'sojournerModuleId': '99122',
#                'scenario': '*',
#                'uxComponentGroup': 'TAXES_OVERLAY'}}]}}},
#          'ATF_BREADCRUMBS': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'PAGENAVIGATION_ATF',
#               'uxComponentName': 'PAGENAVIGATION_ATF',
#               'moduleType': 'PAGENAVIGATION_ATF',
#               'dataSource': 'PAGENAVIGATION_ATF',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'PAGENAVIGATION_ATF',
#                'sojournerModuleId': '146022',
#                'scenario': '*',
#                'uxComponentGroup': 'PAGENAVIGATION_ATF'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'SEOBREADCRUMBS',
#               'uxComponentName': 'SEOBREADCRUMBS',
#               'moduleType': 'SEOBREADCRUMBS',
#               'dataSource': 'SEOBREADCRUMBS',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'SEOBREADCRUMBS',
#                'sojournerModuleId': '0',
#                'scenario': '*',
#                'uxComponentGroup': 'SEOBREADCRUMBS'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'STR_SOCIAL_SHARE',
#               'uxComponentName': 'STR_SOCIAL_SHARE',
#               'moduleType': 'STR_SOCIAL_SHARE',
#               'dataSource': 'STR_SOCIAL_SHARE',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'STR_SOCIAL_SHARE',
#                'sojournerModuleId': '123689',
#                'scenario': '*',
#                'uxComponentGroup': 'STR_SOCIAL_SHARE'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'ADD_TO_WATCHLIST',
#               'uxComponentName': 'ADD_TO_WATCHLIST',
#               'moduleType': 'ADD_TO_WATCHLIST',
#               'dataSource': 'ADD_TO_WATCHLIST',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADD_TO_WATCHLIST',
#                'sojournerModuleId': '46890',
#                'scenario': '*',
#                'uxComponentGroup': 'ADD_TO_WATCHLIST'}}]}}},
#          'MIDDLE_RIVER': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'DESCRIPTION_VHR_SHIPPING_TABS',
#               'uxComponentName': 'DESCRIPTION_VHR_SHIPPING_TABS',
#               'moduleType': 'DESCRIPTION_VHR_SHIPPING_TABS',
#               'dataSource': 'DESCRIPTION_VHR_SHIPPING_TABS',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'DESCRIPTION_VHR_SHIPPING_TABS',
#                'sojournerModuleId': '157398',
#                'scenario': '*',
#                'uxComponentGroup': 'DESCRIPTION_VHR_SHIPPING_TABS'}}]}}},
#          'BTF_RIVER': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'STORE_INFORMATION',
#               'uxComponentName': 'LISTING_FRAME_MODULE',
#               'moduleType': 'LISTING_FRAME_MODULE',
#               'dataSource': 'STORE_INFORMATION',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'STORE_INFORMATION',
#                'sojournerModuleId': '145687',
#                'scenario': '*',
#                'uxComponentGroup': 'LISTING_FRAME_MODULE'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'ADS_SME_BTF',
#               'uxComponentName': 'ADS_SME_BTF',
#               'moduleType': 'ADS_SME_BTF',
#               'dataSource': 'ADS_SME_BTF',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_SME_BTF',
#                'sojournerModuleId': '0',
#                'scenario': '*',
#                'uxComponentGroup': 'ADS_SME_BTF'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101912',
#               'uxComponentName': 'AD_PD_S5_WEB',
#               'moduleType': 'AD_PD_S5_WEB',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '152246',
#                'scenario': 'PLACEMENT_101912',
#                'uxComponentGroup': 'AD_PD_S5_WEB'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101112',
#               'uxComponentName': 'ADS_MERCH',
#               'moduleType': 'ADS_MERCH',
#               'dataSource': 'ADS_MERCH',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_MERCH',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_101112',
#                'uxComponentGroup': 'ADS_MERCH'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101110',
#               'uxComponentName': 'ADS_MERCH',
#               'moduleType': 'ADS_MERCH',
#               'dataSource': 'ADS_MERCH',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_MERCH',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_101110',
#                'uxComponentGroup': 'ADS_MERCH'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101111',
#               'uxComponentName': 'ADS_MERCH',
#               'moduleType': 'ADS_MERCH',
#               'dataSource': 'ADS_MERCH',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_MERCH',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_101111',
#                'uxComponentGroup': 'ADS_MERCH'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101113',
#               'uxComponentName': 'ADS_MERCH',
#               'moduleType': 'ADS_MERCH',
#               'dataSource': 'ADS_MERCH',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_MERCH',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_101113',
#                'uxComponentGroup': 'ADS_MERCH'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_101506',
#               'uxComponentName': 'ADS_MERCH',
#               'moduleType': 'ADS_MERCH',
#               'dataSource': 'ADS_MERCH',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_MERCH',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_101506',
#                'uxComponentGroup': 'ADS_MERCH'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100727',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100727',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100565',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100565',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PAGENAVIGATION_BTF',
#               'uxComponentName': 'PAGENAVIGATION_BTF',
#               'moduleType': 'PAGENAVIGATION_BTF',
#               'dataSource': 'PAGENAVIGATION_BTF',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'PAGENAVIGATION_BTF',
#                'sojournerModuleId': '0',
#                'scenario': '*',
#                'uxComponentGroup': 'PAGENAVIGATION_BTF'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'SEO_LINKING',
#               'uxComponentName': 'SEO_LINKING',
#               'moduleType': 'SEO_LINKING',
#               'dataSource': 'SEO_LINKING',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'SEO_LINKING',
#                'sojournerModuleId': '2547',
#                'scenario': '*',
#                'uxComponentGroup': 'SEO_LINKING'}}]}}},
#          'BTF_RIVER_OVERLAY': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'CATEGORY_PILLS_MODULE',
#               'uxComponentName': 'LISTING_FRAME_MODULE',
#               'moduleType': 'LISTING_FRAME_MODULE',
#               'dataSource': 'CATEGORY_PILLS_MODULE',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'CATEGORY_PILLS_MODULE',
#                'sojournerModuleId': '145687',
#                'scenario': '*',
#                'uxComponentGroup': 'LISTING_FRAME_MODULE'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'DETAILED_SELLER_RATING_SUMMARY_V2',
#               'uxComponentName': 'FEEDBACK',
#               'moduleType': 'FEEDBACK',
#               'dataSource': 'FEEDBACK',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'FEEDBACK',
#                'sojournerModuleId': '0',
#                'scenario': 'DETAILED_SELLER_RATING_SUMMARY_V2',
#                'uxComponentGroup': 'FEEDBACK'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'FEEDBACK_DETAIL_LIST_TABBED_V2',
#               'uxComponentName': 'FEEDBACK',
#               'moduleType': 'FEEDBACK',
#               'dataSource': 'FEEDBACK',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'FEEDBACK',
#                'sojournerModuleId': '2552115',
#                'scenario': 'FEEDBACK_DETAIL_LIST_TABBED_V2',
#                'uxComponentGroup': 'FEEDBACK'}}]}}},
#          'FOOTER_RIVER': {'_type': 'Region',
#           'layouts': {'LIST_1_COLUMN': {'_type': 'Layout',
#             'positions': [{'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100916',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100916',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100917',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100917',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100918',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100918',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}},
#              {'_type': 'ModulePosition',
#               'moduleLocator': 'PLACEMENT_100919',
#               'uxComponentName': 'ADS_THIRD_PARTY',
#               'moduleType': 'ADS_THIRD_PARTY',
#               'dataSource': 'ADS_THIRD_PARTY',
#               'moduleIdentification': {'instanceId': '1',
#                'provider': 'ADS_THIRD_PARTY',
#                'sojournerModuleId': '0',
#                'scenario': 'PLACEMENT_100919',
#                'uxComponentGroup': 'ADS_THIRD_PARTY'}}]}}}},
#         'templateId': 'ViewItem_Evo'},
#        'requestParameters': {'itemId': '192540786888',
#         'fromViCache': 'false',
#         'moduleGroups': ''}},
#       'viLiteDataModel': {'modules': {}}}},
#     {'f': 1}],
#    ['s0-1-25-7-6-1-101[2]-1-2-0-3-6-0-0-0-4', 1, {'icon': ''}, {'f': 1}],
#    ['s0-1-25-8',
#     2,
#     {'id': 'follow-ebay-helper',
#      'showCurrent': True,
#      'prefix': 'fol',
#      'csrf': 'fa7b4449d83857c40b21d4b4e135de1d400c13b4175e9290d2b55385dfeaa983'}],
#    ['s0-1-25-10', 3, {}, {'f': 1}],
#    ['s0-1-30-13-1-113[0]-1',
#     4,
#     {'id': '100916', 'options': None, 'loading': {}},
#     {'f': 1, 's': {'placementId': '100916', 'options': None}}],
#    ['s0-1-30-13-1-113[1]-1',
#     4,
#     {'id': '100917', 'options': None, 'loading': {}},
#     {'f': 1, 's': {'placementId': '100917', 'options': None}}],
#    ['s0-1-30-13-1-113[2]-1',
#     4,
#     {'id': '100918', 'options': None, 'loading': {}},
#     {'f': 1, 's': {'placementId': '100918', 'options': None}}],
#    ['s0-1-30-13-1-113[3]-1',
#     4,
#     {'id': '100919', 'options': None, 'loading': {}},
#     {'f': 1, 's': {'placementId': '100919', 'options': None}}],
#    ['s0-1-41', 5, {}, {'f': 1}],
#    ['s0-1-43', 6, {}, {'f': 1}]],
#   't': ['/@ebay/ux-app$7.57.2/components/x-vi-evo-main-container/index.marko',
#    '/@ebay/motors-finders-common$1.6.2/components/finders-header/index.marko',
#    '/@ebay/follow-helper$1.1.3/src/components/follow-helper/component-browser',
#    '/@ebay/ux-app$7.57.2/components/d-bluekai/index.marko',
#    '/@ebay/nuts-ui-marko$2.3.1-leaderboard-fix/components/ebay-ads-placement/index.marko',
#    '/r1vinode$0.0.4/src/layouts/item/components/qualtrics-scripts/index.marko',
#    '/r1vinode$0.0.4/src/layouts/item/components/init-main/index.marko']},
#  '$$': [{'l': ['w', 1, 2, 'title'],
#    'r': ['w',
#     0,
#     2,
#     'model',
#     'modules',
#     'VEHICLE_SELECTION',
#     'header',
#     'text']},
#   {'l': ['w', 1, 2, 'subtitle'],
#    'r': ['w', 0, 2, 'model', 'modules', 'VEHICLE_SELECTION', 'subtitle']},
#   {'l': ['w', 3, 2, 'model'], 'r': ['w', 0, 2, 'model', 'modules', 'RTM']},
#   {'l': ['w', 4, 2, 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100916']},
#   {'l': ['w', 4, 3, 's', 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100916']},
#   {'l': ['w', 5, 2, 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100917']},
#   {'l': ['w', 5, 3, 's', 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100917']},
#   {'l': ['w', 6, 2, 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100918']},
#   {'l': ['w', 6, 3, 's', 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100918']},
#   {'l': ['w', 7, 2, 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100919']},
#   {'l': ['w', 7, 3, 's', 'module'],
#    'r': ['w', 0, 2, 'model', 'modules', 'PLACEMENT_100919']}]}

# %%
market = json_['o']['g']['marketplaceId'].strip()
country = json_['o']['g']['country'].strip()
language = json_['o']['g']['language'].strip()
locale = json_['o']['g']['locale'].strip()
item_number = json_['o']['g']['itemId'].strip()

market, country, language, locale, item_number
# Out:
# ('EBAY-AU', 'AU', 'en', 'en-AU', '192540786888')

# %%
input_.loc[a, 'Market'] == 'US'
# Out:
# False

# %%
item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-US' or country != 'US' or language != 'en' or locale != 'en-US'
# Out:
# True

# %%
input_.loc[a, 'Market'] == 'DE'
# Out:
# False

# %%
item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-DE' or country != 'DE' or language != 'de' or locale != 'de-DE'
# Out:
# True

# %%
input_.loc[a, 'Market'] == 'UK'
# Out:
# False

# %%
item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-GB' or country != 'GB' or language != 'en' or locale != 'en-GB'
# Out:
# True

# %%
input_.loc[a, 'Market'] == 'AU'
# Out:
# True

# %%
item_number != input_.loc[a, 'Item Number'] or market != 'EBAY-AU' or country != 'AU' or language != 'en' or locale != 'en-AU'
# Out:
# False

# %%
list_compatibility = json_['o']['w'][0][2]['model']['modules']['COMPATIBILITY_TABLE']['paginatedTable']['pagination']['pages'] if 'COMPATIBILITY_TABLE' in json_['o']['w'][0][2]['model']['modules'] else []

dict_compatibility = {'market': input_.loc[a, 'Market'],
                      'page': int(list_compatibility[-1]['text'].strip()),
                      'data': {'scopedContext': {'catalogDetails': {'categoryId': list_compatibility[-1]['action']['params']['categoryId'],
                                                                    'itemId': list_compatibility[-1]['action']['params']['itemId'],
                                                                    'marketplaceId': list_compatibility[-1]['action']['params']['marketplaceId'],
                                                                    'sellerName': list_compatibility[-1]['action']['params']['sellerName']}}}} if list_compatibility else ''

dict_compatibility
# Out:
# {'market': 'AU',
#  'page': 11,
#  'data': {'scopedContext': {'catalogDetails': {'categoryId': '46094',
#     'itemId': '192540786888',
#     'marketplaceId': 'EBAY-AU',
#     'sellerName': 'goodstate'}}}}

# %%
dict_specific = {}
dict_item = json_['o']['w'][0][2]['model']['modules']['ABOUT_THIS_ITEM']['sections']['features']['dataItems']
for i, (key, value) in zip(range(len(dict_item.items())), dict_item.items()):
    dict_specific[str(i)] = {value['labels'][0]['textSpans'][0]['text'].strip(): value['values'][0]['textualDisplays'][0]['textSpans'][0]['text'].strip() if key.strip().lower() == 'condition' else value['values'][0]['textSpans'][0]['text'].strip()}

dict_specific
# Out:
# {'0': {'Condition': "Brand New: A brand-new, unused, unopened, undamaged item in its original packaging (where packaging is applicable).  Packaging should be the same as what is found in a retail store, unless the item was packaged by the manufacturer in non-retail packaging, such as an unprinted box or plastic bag.  See the seller's listing for full details."},
#  '1': {'Brand': 'Toyota'},
#  '2': {'Manufacturer Part Number': '871380K090, 87138 0K090, 87138-0K090'},
#  '3': {'UPC': 'Does not apply'}}

# %%
description_url = json_['o']['w'][0][2]['model']['modules']['ITEM_DESCRIPTION_MIN_VIEW_MODULE']['sections'][0]['action']['URL'].strip()
# description_url = json_['o']['w'][0][2]['model']['modules']['ITEM_DESCRIPTION_MIN_VIEW_MODULE']['sections'][0]['dataItems'][0]['action']['URL'].strip()

description_url
# Out:
# 'https://vi.vipr.ebaydesc.com/itmdesc/192540786888?t=1717751180000&category=46094&seller=goodstate&excSoj=1&excTrk=1&lsite=15&ittenable=false&domain=ebay.com&descgauge=1&cspheader=1&oneClk=2&secureDesc=1'

# %%
title = json_['o']['w'][0][2]['model']['modules']['TITLE']['mainTitle']['textSpans'][0]['text'].strip()

title
# Out:
# 'Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fan Blower Motor Speed Resistor'

# %%
subtitle = json_['o']['w'][0][2]['model']['modules']['TITLE']['subTitle']['textSpans'][0]['text'].strip() if 'subTitle' in json_['o']['w'][0][2]['model']['modules']['TITLE'] else ''

subtitle
# Out:
# ''

# %%
price = json_['o']['w'][0][2]['model']['modules']['BUY_BOX']['binModel']['price']['textSpans'][0]['text'].strip()
# price = json_['o']['w'][0][2]['model']['modules']['BUY_BOX']['bidPrice']['textSpans'][0]['text'].strip()

price
# Out:
# 'AU $44.90 each'

# %%
available, sold = '', ''
list_quantity = json_['o']['w'][0][2]['model']['modules']['QUANTITY']['availabilitySignal']['textSpans'] if 'QUANTITY' in json_['o']['w'][0][2]['model']['modules'] else []
for quantity in list_quantity:
    if input_.loc[a, 'Market'] in ['US', 'UK', 'AU']:
        if 'available' in quantity['text']:
            available = quantity['text'].strip()
        elif 'sold' in quantity['text']:
            sold = quantity['text'].strip()
    elif input_.loc[a, 'Market'] == 'DE':
        if 'verfügbar' in quantity['text']:
            available = quantity['text'].strip()
        elif 'verkauft' in quantity['text']:
            sold = quantity['text'].strip()

available, sold
# Out:
# ('10 available', '56 sold')

# %%
dict_src = {}
list_media = json_['o']['w'][0][2]['model']['modules']['PICTURE']['mediaList']
for i, media in zip(range(len(list_media)), list_media):
    dict_src[str(i)] = media['image']['originalImg']['URL'].strip()

dict_src
# Out:
# {'0': 'https://i.ebayimg.com/images/g/41sAAOSwDk5mYs4S/s-l500.jpg',
#  '1': 'https://i.ebayimg.com/images/g/c-MAAOSwLphmYs4R/s-l500.jpg',
#  '2': 'https://i.ebayimg.com/images/g/ndkAAOSw9a9mYs4S/s-l500.gif',
#  '3': 'https://i.ebayimg.com/images/g/b1oAAOSwAw5mYs4S/s-l500.gif',
#  '4': 'https://i.ebayimg.com/images/g/3V4AAOSwzyxmYs4U/s-l500.gif',
#  '5': 'https://i.ebayimg.com/images/g/HB4AAOSwPt9mYs4S/s-l500.gif',
#  '6': 'https://i.ebayimg.com/images/g/IyoAAOSwDYFmYs4S/s-l500.gif',
#  '7': 'https://i.ebayimg.com/images/g/3GEAAOSwE4JmYs4R/s-l500.gif',
#  '8': 'https://i.ebayimg.com/images/g/0SAAAOSw2-pmYs4S/s-l500.gif',
#  '9': 'https://i.ebayimg.com/images/g/KcYAAOSws0FmYs4R/s-l500.gif',
#  '10': 'https://i.ebayimg.com/images/g/GTUAAOSwdVFmYs4S/s-l500.gif',
#  '11': 'https://i.ebayimg.com/images/g/3OwAAOSwR1VmYs4S/s-l500.gif',
#  '12': 'https://i.ebayimg.com/images/g/sqkAAOSwPpxmYs4S/s-l500.gif',
#  '13': 'https://i.ebayimg.com/images/g/dhcAAOSw8exmYs4S/s-l500.gif',
#  '14': 'https://i.ebayimg.com/images/g/9X8AAOSw5fxmYs4S/s-l500.gif',
#  '15': 'https://i.ebayimg.com/images/g/EmsAAOSwhsBmYs4S/s-l500.gif',
#  '16': 'https://i.ebayimg.com/images/g/o2kAAOSwIu5mYs4S/s-l500.gif',
#  '17': 'https://i.ebayimg.com/images/g/BfkAAOSwh8hmYs4T/s-l500.gif',
#  '18': 'https://i.ebayimg.com/images/g/-1gAAOSw4rtmYs4S/s-l500.gif',
#  '19': 'https://i.ebayimg.com/images/g/b4MAAOSwJ-xmYs4S/s-l500.gif'}

# %%
df_temp = pd.DataFrame([{'No': input_.loc[a, 'No'],
                         'Item Number': input_.loc[a, 'Item Number'],
                         'Title': title,
                         'Subtitle': subtitle,
                         'Price': price,
                         'Available': available,
                         'Sold': sold,
                         'Vehicle W/o Engine': '',
                         'Vehicle W/ Engine': '',
                         'Picture': '',
                         'Url': url,
                         'Description Url': description_url,
                         'Json_Compatibility': json.dumps(dict_compatibility),
                         'Json_Src': json.dumps(dict_src),
                         'Json_Specific': json.dumps(dict_specific)}])

output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

output_correct
# Out:
#    No   Item Number                                              Title  \
# 0   1  192540786888  Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fa...
# 1   1  192540786888  Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fa...
#
#   Subtitle           Price     Available     Sold Vehicle W/o Engine  \
# 0           AU $44.90 each  10 available  56 sold
# 1           AU $44.90 each  10 available  56 sold
#
#   Vehicle W/ Engine Picture  \
# 0
# 1
#
#                                                  Url  \
# 0  https://www.ebay.com.au/itm/192540786888?_ul=A...
# 1  https://www.ebay.com.au/itm/192540786888?_ul=A...
#
#                                      Description Url  \
# 0  https://vi.vipr.ebaydesc.com/itmdesc/192540786...
# 1  https://vi.vipr.ebaydesc.com/itmdesc/192540786...
#
#                                   Json_Compatibility  \
# 0  {"market": "AU", "page": 11, "data": {"scopedC...
# 1  {"market": "AU", "page": 11, "data": {"scopedC...
#
#                                             Json_Src  \
# 0  {"0": "https://i.ebayimg.com/images/g/41sAAOSw...
# 1  {"0": "https://i.ebayimg.com/images/g/41sAAOSw...
#
#                                        Json_Specific
# 0  {"0": {"Condition": "Brand New: A brand-new, u...
# 1  {"0": {"Condition": "Brand New: A brand-new, u...

# %%
crawler_status = 'ok'

crawler_status
# Out:
# 'ok'

# %%
if crawler_status == 'error':
    df_temp = pd.DataFrame([{'Market': input_.loc[a, 'Market'],
                             'Page': input_.loc[a, 'Page'],
                             'Page Url': input_.loc[a, 'Page Url'],
                             'No': input_.loc[a, 'No'],
                             'Item Number': input_.loc[a, 'Item Number']}])

    output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
    output_correct.to_excel('./test_item.xlsx', index=False)

output_correct
# Out:
#    No   Item Number                                              Title  \
# 0   1  192540786888  Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fa...
# 1   1  192540786888  Genuine Corolla ZRE142 ZRE141 NRE150 Heater Fa...
#
#   Subtitle           Price     Available     Sold Vehicle W/o Engine  \
# 0           AU $44.90 each  10 available  56 sold
# 1           AU $44.90 each  10 available  56 sold
#
#   Vehicle W/ Engine Picture  \
# 0
# 1
#
#                                                  Url  \
# 0  https://www.ebay.com.au/itm/192540786888?_ul=A...
# 1  https://www.ebay.com.au/itm/192540786888?_ul=A...
#
#                                      Description Url  \
# 0  https://vi.vipr.ebaydesc.com/itmdesc/192540786...
# 1  https://vi.vipr.ebaydesc.com/itmdesc/192540786...
#
#                                   Json_Compatibility  \
# 0  {"market": "AU", "page": 11, "data": {"scopedC...
# 1  {"market": "AU", "page": 11, "data": {"scopedC...
#
#                                             Json_Src  \
# 0  {"0": "https://i.ebayimg.com/images/g/41sAAOSw...
# 1  {"0": "https://i.ebayimg.com/images/g/41sAAOSw...
#
#                                        Json_Specific
# 0  {"0": {"Condition": "Brand New: A brand-new, u...
# 1  {"0": {"Condition": "Brand New: A brand-new, u...

# %%
if not output_error.empty:
    output_error = output_error.sort_values(by=['No'],
                                            ascending=[True],
                                            ignore_index=True)
    output_error.to_excel('./test_item_error.xlsx', index=False)

output_error
# Out:
# Empty DataFrame
# Columns: []
# Index: []
