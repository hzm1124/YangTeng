# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

from bs4 import BeautifulSoup
from lxml import etree

# = = = = = = = = = = = = = = =

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel('./1.category.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['1st Category No'] = input_['1st Category No'].astype(int)
input_['2nd Category No'] = input_['2nd Category No'].astype(int)
input_['3rd Category No'] = input_['3rd Category No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        import requests

        import sys
        sys.path.append('../00.Tools')
        from crawler_configuration import get_header, get_proxy

        from bs4 import BeautifulSoup
        from lxml import etree

        try:
            df_temp, page = pd.DataFrame(), 1
            while True:
                page_url, b = f'''{input_.loc[a, '3rd Category Url']}?sort=alphaasc&limit=96&page={page}''', 0
                while True:
                    b += 1
                    
                    try:
                        resp = requests.get(page_url,
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            soup = BeautifulSoup(resp.text, 'lxml')
                            html = etree.HTML(str(soup))

                            # = = = = = = = = = = = = = = =

                            if input_.loc[a, '3rd Category'] in html.xpath('//title/text()')[0]:
                                break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                list_url = html.xpath('//h4[@class="card-title NoMargin"]/a/@href')

                # = = = = = = = = = = = = = = =

                df_temp_temp = pd.DataFrame({'1st Category No': input_.loc[a, '1st Category No'],
                                             '1st Category': input_.loc[a, '1st Category'],
                                             '1st Category Url': input_.loc[a, '1st Category Url'],
                                             '2nd Category No': input_.loc[a, '2nd Category No'],
                                             '2nd Category': input_.loc[a, '2nd Category'],
                                             '2nd Category Url': input_.loc[a, '2nd Category Url'],
                                             '3rd Category No': input_.loc[a, '3rd Category No'],
                                             '3rd Category': input_.loc[a, '3rd Category'],
                                             '3rd Category Url': input_.loc[a, '3rd Category Url'],
                                             'Page': page,
                                             'Page Url': page_url,
                                             'No': [page*96-95+i for i in range(len(list_url))],
                                             'Url': list_url})

                df_temp = pd.concat([df_temp, df_temp_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                if work.qsize() % 100 == 0 and work.qsize() != 0:
                    clear_output()

                print(f'''[尝试次数：{b}] - {input_.loc[a, '1st Category No']}.{input_.loc[a, '1st Category']} > {input_.loc[a, '2nd Category No']}.{input_.loc[a, '2nd Category']} > {input_.loc[a, '3rd Category No']}.{input_.loc[a, '3rd Category']} > Page {page}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

                # = = = = = = = = = = = = = = =

                page += 1
                
                # = = = = = = = = = = = = = = =

                if not html.xpath('//li[@class="pagination-item pagination-item--next"]'):
                    df_temp['No'] = [i+1 for i in range(len(df_temp))]

                    break
                    
            # = = = = = = = = = = = = = = =

            if df_temp.empty:
                raise

            # = = = = = = = = = = = = = = =

            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')
            
            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            df_temp = pd.DataFrame([{'1st Category No': input_.loc[a, '1st Category No'],
                                     '1st Category': input_.loc[a, '1st Category'],
                                     '1st Category Url': input_.loc[a, '1st Category Url'],
                                     '2nd Category No': input_.loc[a, '2nd Category No'],
                                     '2nd Category': input_.loc[a, '2nd Category'],
                                     '2nd Category Url': input_.loc[a, '2nd Category Url'],
                                     '3rd Category No': input_.loc[a, '3rd Category No'],
                                     '3rd Category': input_.loc[a, '3rd Category'],
                                     '3rd Category Url': input_.loc[a, '3rd Category Url']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(20):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['1st Category No', '2nd Category No', '3rd Category No', 'Page', 'No'],
                                                ascending=[True, True, True, True, True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./2.url-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['1st Category No', '2nd Category No', '3rd Category No'],
                                            ascending=[True, True, True],
                                            ignore_index=True)
    output_error.to_excel('./url_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：112
#
# [尝试次数：2] - 1.Brakes > 2.Brake Boosters & Pumps > 1.Electronic Brake Assembly > Page 1
# [剩余数量：92] - [当前时间：19:51:31]
#
# [尝试次数：17] - 1.Brakes > 1.ABS Components > 3.ABS Pump & Motor Assembly > Page 1
# [剩余数量：91] - [当前时间：19:51:31]
#
# [尝试次数：7] - 1.Brakes > 1.ABS Components > 1.ABS Control Module > Page 1
# [剩余数量：90] - [当前时间：19:51:32]
#
# [尝试次数：15] - 1.Brakes > 3.Disc Brakes > 5.Parking Brake Actuator > Page 1
# [剩余数量：90] - [当前时间：19:51:32]
#
# [尝试次数：10] - 2.Drivetrain > 1.Differential > 1.4WD Actuator > Page 1
# [剩余数量：89] - [当前时间：19:51:34]
#
# [尝试次数：6] - 1.Brakes > 2.Brake Boosters & Pumps > 7.Vacuum Pump > Page 1
# [剩余数量：88] - [当前时间：19:51:34]
#
# [尝试次数：31] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 1
# [剩余数量：87] - [当前时间：19:51:34]
#
# [尝试次数：9] - 1.Brakes > 2.Brake Boosters & Pumps > 6.Power Brake Booster Hydraulic Motor Pump > Page 1
# [剩余数量：87] - [当前时间：19:51:35]
#
# [尝试次数：32] - 1.Brakes > 3.Disc Brakes > 4.Brake Dust Shield > Page 1
# [剩余数量：86] - [当前时间：19:51:35]
#
# [尝试次数：28] - 2.Drivetrain > 1.Differential > 2.Brake Dust Shield > Page 1
# [剩余数量：85] - [当前时间：19:51:35]
#
# [尝试次数：3] - 2.Drivetrain > 2.Driveline & Axles > 2.CV Intermediate Shaft > Page 1
# [剩余数量：84] - [当前时间：19:51:36]
#
# [尝试次数：48] - 1.Brakes > 2.Brake Boosters & Pumps > 4.Electronic Brake Pump & Motor > Page 1
# [剩余数量：83] - [当前时间：19:51:37]
#
# [尝试次数：25] - 1.Brakes > 2.Brake Boosters & Pumps > 2.Electronic Brake Booster Vacuum Pump > Page 1
# [剩余数量：82] - [当前时间：19:51:37]
#
# [尝试次数：45] - 1.Brakes > 3.Disc Brakes > 1.Air Disc Brake Caliper > Page 1
# [剩余数量：81] - [当前时间：19:51:38]
#
# [尝试次数：2] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 1
# [剩余数量：80] - [当前时间：19:51:38]
#
# [尝试次数：35] - 1.Brakes > 2.Brake Boosters & Pumps > 8.Vacuum Pump Pulley > Page 1
# [剩余数量：80] - [当前时间：19:51:38]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 1.ABS Control Module > Page 1
# [剩余数量：79] - [当前时间：19:51:39]
#
# [尝试次数：29] - 3.Electronics > 1.Control Modules > 4.Diesel Fuel Injector Driver Module > Page 1
# [剩余数量：79] - [当前时间：19:51:42]
#
# [尝试次数：36] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 1
# [剩余数量：78] - [当前时间：19:51:43]
#
# [尝试次数：58] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 1
# [剩余数量：78] - [当前时间：19:51:43]
#
# [尝试次数：26] - 2.Drivetrain > 3.Transmission & Transfer Case > 1.Transfer Case Control Module > Page 1
# [剩余数量：78] - [当前时间：19:51:43]
#
# [尝试次数：13] - 3.Electronics > 1.Control Modules > 5.Diesel Glow Plug Controller > Page 1
# [剩余数量：77] - [当前时间：19:51:43]
#
# [尝试次数：9] - 3.Electronics > 1.Control Modules > 2.Active Suspension Control Module > Page 1
# [剩余数量：76] - [当前时间：19:51:43]
#
# [尝试次数：9] - 3.Electronics > 1.Control Modules > 3.Body Control Module > Page 1
# [剩余数量：75] - [当前时间：19:51:44]
#
# [尝试次数：28] - 1.Brakes > 1.ABS Components > 1.ABS Control Module > Page 2
# [剩余数量：75] - [当前时间：19:51:44]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 1
# [剩余数量：74] - [当前时间：19:51:44]
#
# [尝试次数：117] - 1.Brakes > 1.ABS Components > 2.ABS Hydraulic Assembly > Page 1
# [剩余数量：74] - [当前时间：19:51:44]
#
# [尝试次数：16] - 1.Brakes > 2.Brake Boosters & Pumps > 3.Electronic Brake Pedal Simulator > Page 1
# [剩余数量：73] - [当前时间：19:51:44]
#
# [尝试次数：114] - 2.Drivetrain > 1.Differential > 3.Drive Axle Assembly > Page 1
# [剩余数量：72] - [当前时间：19:51:45]
#
# [尝试次数：52] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 2
# [剩余数量：72] - [当前时间：19:51:45]
#
# [尝试次数：30] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 2
# [剩余数量：72] - [当前时间：19:51:45]
#
# [尝试次数：4] - 3.Electronics > 1.Control Modules > 7.Fuel Injector Control Module > Page 1
# [剩余数量：72] - [当前时间：19:51:47]
#
# [尝试次数：126] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 1
# [剩余数量：71] - [当前时间：19:51:47]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 10.Lighting Control Module > Page 1
# [剩余数量：71] - [当前时间：19:51:49]
#
# [尝试次数：64] - 2.Drivetrain > 1.Differential > 4.Leaf Spring Axle U-Bolt Kit > Page 1
# [剩余数量：70] - [当前时间：19:51:49]
#
# [尝试次数：32] - 2.Drivetrain > 3.Transmission & Transfer Case > 3.Transmission Control Module > Page 1
# [剩余数量：69] - [当前时间：19:51:49]
#
# [尝试次数：4] - 2.Drivetrain > 1.Differential > 3.Drive Axle Assembly > Page 2
# [剩余数量：69] - [当前时间：19:51:50]
#
# [尝试次数：42] - 3.Electronics > 1.Control Modules > 8.Fuel Pump Driver Module > Page 1
# [剩余数量：69] - [当前时间：19:51:50]
#
# [尝试次数：25] - 3.Electronics > 1.Control Modules > 3.Body Control Module > Page 2
# [剩余数量：68] - [当前时间：19:51:51]
#
# [尝试次数：22] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 3
# [剩余数量：68] - [当前时间：19:51:51]
#
# [尝试次数：9] - 3.Electronics > 2.Dashboard > 1.Climate Control Module > Page 1
# [剩余数量：68] - [当前时间：19:51:52]
#
# [尝试次数：15] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 3
# [剩余数量：67] - [当前时间：19:51:53]
#
# [尝试次数：2] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 2
# [剩余数量：67] - [当前时间：19:51:54]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 16.Vehicle Control Module > Page 1
# [剩余数量：67] - [当前时间：19:51:54]
#
# [尝试次数：62] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 2
# [剩余数量：66] - [当前时间：19:51:55]
#
# [尝试次数：4] - 2.Drivetrain > 3.Transmission & Transfer Case > 3.Transmission Control Module > Page 2
# [剩余数量：66] - [当前时间：19:51:55]
#
# [尝试次数：12] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 3
# [剩余数量：66] - [当前时间：19:51:57]
#
# [尝试次数：68] - 3.Electronics > 1.Control Modules > 11.Power Supply Module (TIPM) > Page 1
# [剩余数量：66] - [当前时间：19:51:57]
#
# [尝试次数：7] - 2.Drivetrain > 3.Transmission & Transfer Case > 3.Transmission Control Module > Page 3
# [剩余数量：65] - [当前时间：19:51:58]
#
# [尝试次数：43] - 3.Electronics > 1.Control Modules > 3.Body Control Module > Page 3
# [剩余数量：64] - [当前时间：19:51:58]
#
# [尝试次数：55] - 3.Electronics > 1.Control Modules > 1.ABS Control Module > Page 2
# [剩余数量：63] - [当前时间：19:51:59]
#
# [尝试次数：30] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 4
# [剩余数量：62] - [当前时间：19:51:59]
#
# [尝试次数：5] - 4.Engine > 1.Ignition > 2.Distributor > Page 1
# [剩余数量：62] - [当前时间：19:52:00]
#
# [尝试次数：30] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 4
# [剩余数量：62] - [当前时间：19:52:01]
#
# [尝试次数：38] - 4.Engine > 1.Ignition > 1.Camshaft Synchronizer Alignment Tool Kit > Page 1
# [剩余数量：62] - [当前时间：19:52:01]
#
# [尝试次数：14] - 4.Engine > 1.Ignition > 3.Engine Camshaft Position Sensor > Page 1
# [剩余数量：61] - [当前时间：19:52:02]
#
# [尝试次数：139] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 2
# [剩余数量：60] - [当前时间：19:52:03]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 3
# [剩余数量：60] - [当前时间：19:52:03]
#
# [尝试次数：11] - 4.Engine > 2.Pumps > 1.Engine Auxiliary Water Pump > Page 1
# [剩余数量：60] - [当前时间：19:52:03]
#
# [尝试次数：143] - 3.Electronics > 1.Control Modules > 13.Relay Control Module > Page 1
# [剩余数量：59] - [当前时间：19:52:04]
#
# [尝试次数：131] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 2
# [剩余数量：58] - [当前时间：19:52:05]
#
# [尝试次数：75] - 3.Electronics > 2.Dashboard > 2.Instrument Cluster > Page 1
# [剩余数量：58] - [当前时间：19:52:06]
#
# [尝试次数：43] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 4
# [剩余数量：58] - [当前时间：19:52:06]
#
# [尝试次数：45] - 3.Electronics > 1.Control Modules > 14.Transfer Case Control Module > Page 1
# [剩余数量：58] - [当前时间：19:52:07]
#
# [尝试次数：112] - 3.Electronics > 1.Control Modules > 9.Integrated Control Module > Page 1
# [剩余数量：57] - [当前时间：19:52:07]
#
# [尝试次数：16] - 3.Electronics > 1.Control Modules > 15.Transmission Control Module > Page 1
# [剩余数量：56] - [当前时间：19:52:07]
#
# [尝试次数：5] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 5
# [剩余数量：56] - [当前时间：19:52:07]
#
# [尝试次数：26] - 4.Engine > 1.Ignition > 4.Engine Camshaft Synchronizer > Page 1
# [剩余数量：56] - [当前时间：19:52:07]
#
# [尝试次数：2] - 4.Engine > 2.Pumps > 2.Engine Oil Pump Drive Shaft > Page 1
# [剩余数量：55] - [当前时间：19:52:08]
#
# [尝试次数：66] - 4.Engine > 1.Ignition > 5.Engine Crankshaft Position Sensor > Page 1
# [剩余数量：54] - [当前时间：19:52:09]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 3.Brake Caliper Bracket > Page 6
# [剩余数量：53] - [当前时间：19:52:09]
#
# [尝试次数：7] - 5.Fuel, Air & Exhaust > 1.Air Intake > 1.Accelerator Pedal Sensor > Page 1
# [剩余数量：52] - [当前时间：19:52:10]
#
# [尝试次数：8] - 4.Engine > 2.Pumps > 4.Vacuum Pump > Page 1
# [剩余数量：51] - [当前时间：19:52:11]
#
# [尝试次数：19] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 3
# [剩余数量：50] - [当前时间：19:52:11]
#
# [尝试次数：37] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 5
# [剩余数量：50] - [当前时间：19:52:11]
#
# [尝试次数：1] - 5.Fuel, Air & Exhaust > 2.Emission Control > 1.Diesel Exhaust Fluid (DEF) Heater > Page 1
# [剩余数量：50] - [当前时间：19:52:12]
#
# [尝试次数：57] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 4
# [剩余数量：49] - [当前时间：19:52:13]
#
# [尝试次数：10] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 5
# [剩余数量：49] - [当前时间：19:52:13]
#
# [尝试次数：38] - 4.Engine > 2.Pumps > 5.Vacuum Pump Pulley > Page 1
# [剩余数量：49] - [当前时间：19:52:13]
#
# [尝试次数：70] - 4.Engine > 2.Pumps > 3.Smog Air Pump > Page 1
# [剩余数量：48] - [当前时间：19:52:13]
#
# [尝试次数：7] - 2.Drivetrain > 1.Differential > 3.Drive Axle Assembly > Page 3
# [剩余数量：48] - [当前时间：19:52:13]
#
# [尝试次数：17] - 5.Fuel, Air & Exhaust > 2.Emission Control > 3.Diesel Particulate Filter (DPF) > Page 1
# [剩余数量：47] - [当前时间：19:52:14]
#
# [尝试次数：21] - 5.Fuel, Air & Exhaust > 1.Air Intake > 2.Fuel Injection Throttle Body > Page 1
# [剩余数量：46] - [当前时间：19:52:14]
#
# [尝试次数：4] - 5.Fuel, Air & Exhaust > 2.Emission Control > 2.Diesel Exhaust Fluid (DEF) Pump > Page 1
# [剩余数量：46] - [当前时间：19:52:14]
#
# [尝试次数：4] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 4
# [剩余数量：45] - [当前时间：19:52:15]
#
# [尝试次数：69] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 3
# [剩余数量：45] - [当前时间：19:52:21]
#
# [尝试次数：29] - 3.Electronics > 2.Dashboard > 2.Instrument Cluster > Page 2
# [剩余数量：45] - [当前时间：19:52:21]
#
# [尝试次数：6] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 6
# [剩余数量：44] - [当前时间：19:52:21]
#
# [尝试次数：12] - 5.Fuel, Air & Exhaust > 2.Emission Control > 6.EGR Cooler Gasket Kit > Page 1
# [剩余数量：44] - [当前时间：19:52:24]
#
# [尝试次数：13] - 5.Fuel, Air & Exhaust > 2.Emission Control > 7.Nitrogen Oxide (NOx) Sensor > Page 1
# [剩余数量：43] - [当前时间：19:52:25]
#
# [尝试次数：6] - 5.Fuel, Air & Exhaust > 1.Air Intake > 2.Fuel Injection Throttle Body > Page 2
# [剩余数量：42] - [当前时间：19:52:25]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 4
# [剩余数量：42] - [当前时间：19:52:26]
#
# [尝试次数：4] - 5.Fuel, Air & Exhaust > 3.Forced Induction > 2.Turbocharger Mounting Gasket Kit > Page 1
# [剩余数量：42] - [当前时间：19:52:26]
#
# [尝试次数：245] - 2.Drivetrain > 3.Transmission & Transfer Case > 2.Transfer Case Motor > Page 1
# [剩余数量：41] - [当前时间：19:52:26]
#
# [尝试次数：7] - 5.Fuel, Air & Exhaust > 3.Forced Induction > 1.Supercharger > Page 1
# [剩余数量：40] - [当前时间：19:52:27]
#
# [尝试次数：1] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 1.Diesel Fuel Injector Driver Module > Page 1
# [剩余数量：39] - [当前时间：19:52:28]
#
# [尝试次数：11] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 3.Diesel Glow Plug Controller > Page 1
# [剩余数量：38] - [当前时间：19:52:29]
#
# [尝试次数：59] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 1
# [剩余数量：37] - [当前时间：19:52:29]
#
# [尝试次数：1] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 7
# [剩余数量：37] - [当前时间：19:52:29]
#
# [尝试次数：1] - 5.Fuel, Air & Exhaust > 1.Air Intake > 2.Fuel Injection Throttle Body > Page 3
# [剩余数量：37] - [当前时间：19:52:30]
#
# [尝试次数：39] - 5.Fuel, Air & Exhaust > 2.Emission Control > 5.EGR Cooler > Page 1
# [剩余数量：37] - [当前时间：19:52:30]
#
# [尝试次数：13] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 5
# [剩余数量：36] - [当前时间：19:52:30]
#
# [尝试次数：36] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 2.Diesel Fuel Injector Driver Module Resistor > Page 1
# [剩余数量：36] - [当前时间：19:52:30]
#
# [尝试次数：25] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 6
# [剩余数量：35] - [当前时间：19:52:31]
#
# [尝试次数：2] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 5
# [剩余数量：35] - [当前时间：19:52:31]
#
# [尝试次数：6] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 6.Fuel Injection Pump Installation Kit > Page 1
# [剩余数量：35] - [当前时间：19:52:31]
#
# [尝试次数：1] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 8.Fuel Injector Control Module > Page 1
# [剩余数量：34] - [当前时间：19:52:33]
#
# [尝试次数：36] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 5
# [剩余数量：33] - [当前时间：19:52:35]
#
# [尝试次数：113] - 3.Electronics > 1.Control Modules > 12.Powertrain Control Module > Page 1
# [剩余数量：33] - [当前时间：19:52:35]
#
# [尝试次数：33] - 5.Fuel, Air & Exhaust > 2.Emission Control > 8.Smog Air Pump > Page 1
# [剩余数量：33] - [当前时间：19:52:35]
#
# [尝试次数：11] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 7
# [剩余数量：33] - [当前时间：19:52:35]
#
# [尝试次数：32] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 4.Fuel Injection Pressure Regulator > Page 1
# [剩余数量：33] - [当前时间：19:52:35]
#
# [尝试次数：3] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 7.Fuel Injector > Page 1
# [剩余数量：32] - [当前时间：19:52:36]
#
# [尝试次数：11] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 2
# [剩余数量：31] - [当前时间：19:52:36]
#
# [尝试次数：27] - 5.Fuel, Air & Exhaust > 1.Air Intake > 2.Fuel Injection Throttle Body > Page 4
# [剩余数量：31] - [当前时间：19:52:37]
#
# [尝试次数：103] - 4.Engine > 1.Ignition > 2.Distributor > Page 2
# [剩余数量：31] - [当前时间：19:52:37]
#
# [尝试次数：112] - 3.Electronics > 1.Control Modules > 15.Transmission Control Module > Page 2
# [剩余数量：31] - [当前时间：19:52:38]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 12.Powertrain Control Module > Page 2
# [剩余数量：31] - [当前时间：19:52:40]
#
# [尝试次数：83] - 5.Fuel, Air & Exhaust > 2.Emission Control > 4.Diesel Particulate Filter (DPF) Gasket > Page 1
# [剩余数量：30] - [当前时间：19:52:42]
#
# [尝试次数：84] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 9.Fuel Injector Installation Kit > Page 1
# [剩余数量：29] - [当前时间：19:52:42]
#
# [尝试次数：35] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 3
# [剩余数量：28] - [当前时间：19:52:43]
#
# [尝试次数：28] - 5.Fuel, Air & Exhaust > 2.Emission Control > 8.Smog Air Pump > Page 2
# [剩余数量：28] - [当前时间：19:52:43]
#
# [尝试次数：2] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 11.High Pressure Oil Rail Repair Kit > Page 1
# [剩余数量：27] - [当前时间：19:52:43]
#
# [尝试次数：79] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 10.Fuel Pump Driver Module > Page 1
# [剩余数量：26] - [当前时间：19:52:43]
#
# [尝试次数：23] - 3.Electronics > 1.Control Modules > 15.Transmission Control Module > Page 3
# [剩余数量：25] - [当前时间：19:52:44]
#
# [尝试次数：26] - 2.Drivetrain > 2.Driveline & Axles > 3.Driveshaft / Prop Shaft > Page 6
# [剩余数量：24] - [当前时间：19:52:45]
#
# [尝试次数：66] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 12.High Pressure Oil Rail Tool > Page 1
# [剩余数量：23] - [当前时间：19:52:45]
#
# [尝试次数：22] - 5.Fuel, Air & Exhaust > 1.Air Intake > 2.Fuel Injection Throttle Body > Page 5
# [剩余数量：22] - [当前时间：19:52:45]
#
# [尝试次数：108] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 6
# [剩余数量：21] - [当前时间：19:52:45]
#
# [尝试次数：29] - 6.Steering > 1.Power Steering Components > 1.Electronic Power Steering (EPS) Column > Page 1
# [剩余数量：21] - [当前时间：19:52:46]
#
# [尝试次数：107] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 6
# [剩余数量：20] - [当前时间：19:52:46]
#
# [尝试次数：55] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 8
# [剩余数量：20] - [当前时间：19:52:47]
#
# [尝试次数：39] - 6.Steering > 1.Power Steering Components > 2.Power Steering Assist Motor > Page 1
# [剩余数量：20] - [当前时间：19:52:48]
#
# [尝试次数：12] - 6.Steering > 1.Power Steering Components > 4.Power Steering Filter > Page 1
# [剩余数量：19] - [当前时间：19:52:48]
#
# [尝试次数：39] - 6.Steering > 1.Power Steering Components > 5.Power Steering Power Cylinder > Page 1
# [剩余数量：18] - [当前时间：19:52:49]
#
# [尝试次数：6] - 6.Steering > 1.Power Steering Components > 7.Power Steering Pump Pulley > Page 1
# [剩余数量：17] - [当前时间：19:52:49]
#
# [尝试次数：52] - 4.Engine > 1.Ignition > 2.Distributor > Page 3
# [剩余数量：16] - [当前时间：19:52:49]
#
# [尝试次数：15] - 6.Steering > 2.Rack & Pinion > 1.Rack & Pinion Bushing Kit > Page 1
# [剩余数量：16] - [当前时间：19:52:49]
#
# [尝试次数：4] - 6.Steering > 1.Power Steering Components > 8.Power Steering Reservoir > Page 1
# [剩余数量：15] - [当前时间：19:52:50]
#
# [尝试次数：8] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 1
# [剩余数量：15] - [当前时间：19:52:50]
#
# [尝试次数：42] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 4
# [剩余数量：15] - [当前时间：19:52:51]
#
# [尝试次数：8] - 6.Steering > 1.Power Steering Components > 9.Steering Column Intermediate Shaft > Page 1
# [剩余数量：15] - [当前时间：19:52:51]
#
# [尝试次数：21] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 1
# [剩余数量：14] - [当前时间：19:52:52]
#
# [尝试次数：13] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 7
# [剩余数量：14] - [当前时间：19:52:52]
#
# [尝试次数：12] - 6.Steering > 3.Steering Gear & Components > 1.Steering Column Universal Joint Assembly > Page 1
# [剩余数量：14] - [当前时间：19:52:53]
#
# [尝试次数：4] - 7.Motors > 1.Comfort & Convenience > 1.Headlight Motor > Page 1
# [剩余数量：13] - [当前时间：19:52:54]
#
# [尝试次数：16] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 7
# [剩余数量：12] - [当前时间：19:52:55]
#
# [尝试次数：31] - 6.Steering > 2.Rack & Pinion > 2.Rack & Pinion Hydraulic Transfer Tubing Assembly > Page 1
# [剩余数量：12] - [当前时间：19:52:55]
#
# [尝试次数：2] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 8
# [剩余数量：11] - [当前时间：19:52:56]
#
# [尝试次数：23] - 6.Steering > 3.Steering Gear & Components > 2.Steering Gear > Page 1
# [剩余数量：11] - [当前时间：19:52:56]
#
# [尝试次数：46] - 6.Steering > 3.Steering Gear & Components > 3.Steering Pitman Arm > Page 1
# [剩余数量：11] - [当前时间：19:52:56]
#
# [尝试次数：16] - 7.Motors > 1.Comfort & Convenience > 4.Sunroof Motor > Page 1
# [剩余数量：10] - [当前时间：19:52:57]
#
# [尝试次数：24] - 4.Engine > 1.Ignition > 2.Distributor > Page 4
# [剩余数量：9] - [当前时间：19:52:58]
#
# [尝试次数：21] - 6.Steering > 1.Power Steering Components > 8.Power Steering Reservoir > Page 2
# [剩余数量：9] - [当前时间：19:52:58]
#
# [尝试次数：6] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 5
# [剩余数量：8] - [当前时间：19:52:58]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 8
# [剩余数量：8] - [当前时间：19:52:59]
#
# [尝试次数：13] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 2
# [剩余数量：8] - [当前时间：19:52:59]
#
# [尝试次数：128] - 4.Engine > 2.Pumps > 3.Smog Air Pump > Page 2
# [剩余数量：8] - [当前时间：19:53:00]
#
# [尝试次数：50] - 7.Motors > 1.Comfort & Convenience > 3.Power Sliding Door Motor > Page 1
# [剩余数量：7] - [当前时间：19:53:00]
#
# [尝试次数：22] - 7.Motors > 1.Comfort & Convenience > 2.Power Liftgate Actuator > Page 1
# [剩余数量：6] - [当前时间：19:53:01]
#
# [尝试次数：47] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 2
# [剩余数量：5] - [当前时间：19:53:02]
#
# [尝试次数：40] - 6.Steering > 2.Rack & Pinion > 3.Steering Tie Rod End Bushing Kit > Page 1
# [剩余数量：5] - [当前时间：19:53:02]
#
# [尝试次数：40] - 6.Steering > 1.Power Steering Components > 3.Power Steering Control Valve > Page 1
# [剩余数量：4] - [当前时间：19:53:02]
#
# [尝试次数：23] - 4.Engine > 1.Ignition > 2.Distributor > Page 5
# [剩余数量：3] - [当前时间：19:53:03]
#
# [尝试次数：31] - 5.Fuel, Air & Exhaust > 1.Air Intake > 3.Mass Air Flow Sensor > Page 6
# [剩余数量：3] - [当前时间：19:53:05]
#
# [尝试次数：24] - 7.Motors > 3.Window Lift > 1.Power Sliding Window Motor > Page 1
# [剩余数量：2] - [当前时间：19:53:05]
#
# [尝试次数：10] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 1
# [剩余数量：1] - [当前时间：19:53:06]
#
# [尝试次数：28] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 9
# [剩余数量：1] - [当前时间：19:53:06]
#
# [尝试次数：37] - 7.Motors > 2.Drivetrain Motors > 1.4WD Actuator > Page 1
# [剩余数量：1] - [当前时间：19:53:06]
#
# [尝试次数：55] - 7.Motors > 2.Drivetrain Motors > 2.Transfer Case Motor > Page 1
# [剩余数量：0] - [当前时间：19:53:06]
#
# [尝试次数：16] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 1
# [剩余数量：0] - [当前时间：19:53:07]
#
# [尝试次数：38] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 1
# [剩余数量：0] - [当前时间：19:53:08]
#
# [尝试次数：16] - 7.Motors > 3.Window Lift > 5.Tailgate Window Motor > Page 1
# [剩余数量：0] - [当前时间：19:53:09]
#
# [尝试次数：30] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 9
# [剩余数量：0] - [当前时间：19:53:09]
#
# [尝试次数：17] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 9
# [剩余数量：0] - [当前时间：19:53:10]
#
# [尝试次数：32] - 7.Motors > 3.Window Lift > 4.Power Window Motor Gear Kit > Page 1
# [剩余数量：0] - [当前时间：19:53:10]
#
# [尝试次数：12] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 3
# [剩余数量：0] - [当前时间：19:53:10]
#
# [尝试次数：13] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 1
# [剩余数量：0] - [当前时间：19:53:11]
#
# [尝试次数：34] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 10
# [剩余数量：0] - [当前时间：19:53:13]
#
# [尝试次数：15] - 7.Motors > 4.Wiper and Washer > 4.Windshield Wiper Motor Crank Arm Kit > Page 1
# [剩余数量：0] - [当前时间：19:53:14]
#
# [尝试次数：44] - 7.Motors > 4.Wiper and Washer > 2.Windshield Wiper Linkage > Page 1
# [剩余数量：0] - [当前时间：19:53:15]
#
# [尝试次数：43] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 2
# [剩余数量：0] - [当前时间：19:53:16]
#
# [尝试次数：47] - 6.Steering > 3.Steering Gear & Components > 2.Steering Gear > Page 2
# [剩余数量：0] - [当前时间：19:53:17]
#
# [尝试次数：31] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 10
# [剩余数量：0] - [当前时间：19:53:17]
#
# [尝试次数：12] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 4
# [剩余数量：0] - [当前时间：19:53:17]
#
# [尝试次数：23] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 2
# [剩余数量：0] - [当前时间：19:53:17]
#
# [尝试次数：216] - 5.Fuel, Air & Exhaust > 4.Fuel Injection System > 5.Fuel Injection Pump > Page 1
# [剩余数量：0] - [当前时间：19:53:19]
#
# [尝试次数：32] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 2
# [剩余数量：0] - [当前时间：19:53:19]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 11
# [剩余数量：0] - [当前时间：19:53:20]
#
# [尝试次数：104] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 2
# [剩余数量：0] - [当前时间：19:53:20]
#
# [尝试次数：138] - 4.Engine > 1.Ignition > 2.Distributor > Page 6
# [剩余数量：0] - [当前时间：19:53:21]
#
# [尝试次数：3] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 3
# [剩余数量：0] - [当前时间：19:53:22]
#
# [尝试次数：61] - 7.Motors > 4.Wiper and Washer > 1.Windshield Washer Pump > Page 1
# [剩余数量：0] - [当前时间：19:53:22]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 12
# [剩余数量：0] - [当前时间：19:53:24]
#
# [尝试次数：29] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 3
# [剩余数量：0] - [当前时间：19:53:24]
#
# [尝试次数：40] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 10
# [剩余数量：0] - [当前时间：19:53:24]
#
# [尝试次数：19] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 3
# [剩余数量：0] - [当前时间：19:53:24]
#
# [尝试次数：191] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 8
# [剩余数量：0] - [当前时间：19:53:25]
#
# [尝试次数：80] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 3
# [剩余数量：0] - [当前时间：19:53:29]
#
# [尝试次数：142] - 7.Motors > 4.Wiper and Washer > 5.Wiper Motor Pulse Board > Page 1
# [剩余数量：0] - [当前时间：19:53:30]
#
# [尝试次数：23] - 4.Engine > 1.Ignition > 2.Distributor > Page 7
# [剩余数量：0] - [当前时间：19:53:30]
#
# [尝试次数：44] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 11
# [剩余数量：0] - [当前时间：19:53:32]
#
# [尝试次数：21] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 11
# [剩余数量：0] - [当前时间：19:53:32]
#
# [尝试次数：74] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 5
# [剩余数量：0] - [当前时间：19:53:32]
#
# [尝试次数：86] - 6.Steering > 3.Steering Gear & Components > 2.Steering Gear > Page 3
# [剩余数量：0] - [当前时间：19:53:32]
#
# [尝试次数：34] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 4
# [剩余数量：0] - [当前时间：19:53:32]
#
# [尝试次数：9] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 3
# [剩余数量：0] - [当前时间：19:53:33]
#
# [尝试次数：2] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 4
# [剩余数量：0] - [当前时间：19:53:36]
#
# [尝试次数：51] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 13
# [剩余数量：0] - [当前时间：19:53:37]
#
# [尝试次数：1] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 12
# [剩余数量：0] - [当前时间：19:53:38]
#
# [尝试次数：4] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 6
# [剩余数量：0] - [当前时间：19:53:40]
#
# [尝试次数：35] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 5
# [剩余数量：0] - [当前时间：19:53:40]
#
# [尝试次数：1] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 5
# [剩余数量：0] - [当前时间：19:53:41]
#
# [尝试次数：52] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 4
# [剩余数量：0] - [当前时间：19:53:41]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 12
# [剩余数量：0] - [当前时间：19:53:43]
#
# [尝试次数：31] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 4
# [剩余数量：0] - [当前时间：19:53:44]
#
# [尝试次数：74] - 4.Engine > 1.Ignition > 2.Distributor > Page 8
# [剩余数量：0] - [当前时间：19:53:47]
#
# [尝试次数：32] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 9
# [剩余数量：0] - [当前时间：19:53:47]
#
# [尝试次数：1] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 5
# [剩余数量：0] - [当前时间：19:53:47]
#
# [尝试次数：30] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 6
# [剩余数量：0] - [当前时间：19:53:48]
#
# [尝试次数：63] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 4
# [剩余数量：0] - [当前时间：19:53:49]
#
# [尝试次数：65] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 14
# [剩余数量：0] - [当前时间：19:53:50]
#
# [尝试次数：5] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 5
# [剩余数量：0] - [当前时间：19:53:50]
#
# [尝试次数：26] - 4.Engine > 1.Ignition > 2.Distributor > Page 9
# [剩余数量：0] - [当前时间：19:53:54]
#
# [尝试次数：3] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 6
# [剩余数量：0] - [当前时间：19:53:57]
#
# [尝试次数：7] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 10
# [剩余数量：0] - [当前时间：19:53:57]
#
# [尝试次数：83] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 13
# [剩余数量：0] - [当前时间：19:53:57]
#
# [尝试次数：16] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 7
# [剩余数量：0] - [当前时间：19:53:57]
#
# [尝试次数：13] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 5
# [剩余数量：0] - [当前时间：19:53:57]
#
# [尝试次数：48] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 6
# [剩余数量：0] - [当前时间：19:54:00]
#
# [尝试次数：25] - 4.Engine > 1.Ignition > 2.Distributor > Page 10
# [剩余数量：0] - [当前时间：19:54:00]
#
# [尝试次数：98] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 6
# [剩余数量：0] - [当前时间：19:54:01]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 15
# [剩余数量：0] - [当前时间：19:54:02]
#
# [尝试次数：8] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 6
# [剩余数量：0] - [当前时间：19:54:03]
#
# [尝试次数：3] - 4.Engine > 1.Ignition > 2.Distributor > Page 11
# [剩余数量：0] - [当前时间：19:54:03]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 14
# [剩余数量：0] - [当前时间：19:54:04]
#
# [尝试次数：28] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 8
# [剩余数量：0] - [当前时间：19:54:05]
#
# [尝试次数：20] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 7
# [剩余数量：0] - [当前时间：19:54:06]
#
# [尝试次数：3] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 7
# [剩余数量：0] - [当前时间：19:54:08]
#
# [尝试次数：15] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 7
# [剩余数量：0] - [当前时间：19:54:08]
#
# [尝试次数：42] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 11
# [剩余数量：0] - [当前时间：19:54:09]
#
# [尝试次数：44] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 7
# [剩余数量：0] - [当前时间：19:54:09]
#
# [尝试次数：2] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 7
# [剩余数量：0] - [当前时间：19:54:11]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 15
# [剩余数量：0] - [当前时间：19:54:12]
#
# [尝试次数：71] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 13
# [剩余数量：0] - [当前时间：19:54:12]
#
# [尝试次数：26] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 8
# [剩余数量：0] - [当前时间：19:54:14]
#
# [尝试次数：5] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 8
# [剩余数量：0] - [当前时间：19:54:15]
#
# [尝试次数：1] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 8
# [剩余数量：0] - [当前时间：19:54:15]
#
# [尝试次数：25] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 16
# [剩余数量：0] - [当前时间：19:54:16]
#
# [尝试次数：5] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 12
# [剩余数量：0] - [当前时间：19:54:17]
#
# [尝试次数：37] - 7.Motors > 3.Window Lift > 3.Power Window Motor & Regulator Assembly > Page 9
# [剩余数量：0] - [当前时间：19:54:18]
#
# [尝试次数：3] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 14
# [剩余数量：0] - [当前时间：19:54:18]
#
# [尝试次数：32] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 8
# [剩余数量：0] - [当前时间：19:54:18]
#
# [尝试次数：12] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 8
# [剩余数量：0] - [当前时间：19:54:19]
#
# [尝试次数：20] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 9
# [剩余数量：0] - [当前时间：19:54:21]
#
# [尝试次数：13] - 7.Motors > 3.Window Lift > 6.Window Regulator > Page 9
# [剩余数量：0] - [当前时间：19:54:22]
#
# [尝试次数：5] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 15
# [剩余数量：0] - [当前时间：19:54:22]
#
# [尝试次数：37] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 16
# [剩余数量：0] - [当前时间：19:54:23]
#
# [尝试次数：11] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 9
# [剩余数量：0] - [当前时间：19:54:23]
#
# [尝试次数：35] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 17
# [剩余数量：0] - [当前时间：19:54:24]
#
# [尝试次数：8] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 9
# [剩余数量：0] - [当前时间：19:54:25]
#
# [尝试次数：48] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 13
# [剩余数量：0] - [当前时间：19:54:26]
#
# [尝试次数：7] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 10
# [剩余数量：0] - [当前时间：19:54:26]
#
# [尝试次数：26] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 10
# [剩余数量：0] - [当前时间：19:54:27]
#
# [尝试次数：3] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 11
# [剩余数量：0] - [当前时间：19:54:29]
#
# [尝试次数：9] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 16
# [剩余数量：0] - [当前时间：19:54:30]
#
# [尝试次数：11] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 11
# [剩余数量：0] - [当前时间：19:54:30]
#
# [尝试次数：18] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 14
# [剩余数量：0] - [当前时间：19:54:30]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 18
# [剩余数量：0] - [当前时间：19:54:31]
#
# [尝试次数：17] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 17
# [剩余数量：0] - [当前时间：19:54:31]
#
# [尝试次数：23] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 10
# [剩余数量：0] - [当前时间：19:54:32]
#
# [尝试次数：1] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 15
# [剩余数量：0] - [当前时间：19:54:35]
#
# [尝试次数：1] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 12
# [剩余数量：0] - [当前时间：19:54:36]
#
# [尝试次数：1] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 17
# [剩余数量：0] - [当前时间：19:54:36]
#
# [尝试次数：1] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 11
# [剩余数量：0] - [当前时间：19:54:36]
#
# [尝试次数：2] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 12
# [剩余数量：0] - [当前时间：19:54:37]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 18
# [剩余数量：0] - [当前时间：19:54:37]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 19
# [剩余数量：0] - [当前时间：19:54:37]
#
# [尝试次数：1] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 18
# [剩余数量：0] - [当前时间：19:54:38]
#
# [尝试次数：1] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 13
# [剩余数量：0] - [当前时间：19:54:39]
#
# [尝试次数：1] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 13
# [剩余数量：0] - [当前时间：19:54:40]
#
# [尝试次数：29] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 9
# [剩余数量：0] - [当前时间：19:54:41]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 20
# [剩余数量：0] - [当前时间：19:54:42]
#
# [尝试次数：1] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 19
# [剩余数量：0] - [当前时间：19:54:43]
#
# [尝试次数：1] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 10
# [剩余数量：0] - [当前时间：19:54:43]
#
# [尝试次数：1] - 6.Steering > 2.Rack & Pinion > 4.Rack & Pinion > Page 14
# [剩余数量：0] - [当前时间：19:54:44]
#
# [尝试次数：1] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 12
# [剩余数量：0] - [当前时间：19:54:45]
#
# [尝试次数：1] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 16
# [剩余数量：0] - [当前时间：19:54:46]
#
# [尝试次数：1] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 11
# [剩余数量：0] - [当前时间：19:54:46]
#
# [尝试次数：1] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 14
# [剩余数量：0] - [当前时间：19:54:46]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 19
# [剩余数量：0] - [当前时间：19:54:48]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 21
# [剩余数量：0] - [当前时间：19:54:48]
#
# [尝试次数：1] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 13
# [剩余数量：0] - [当前时间：19:54:48]
#
# [尝试次数：1] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 15
# [剩余数量：0] - [当前时间：19:54:49]
#
# [尝试次数：1] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 12
# [剩余数量：0] - [当前时间：19:54:49]
#
# [尝试次数：1] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 20
# [剩余数量：0] - [当前时间：19:54:51]
#
# [尝试次数：1] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 17
# [剩余数量：0] - [当前时间：19:54:52]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 20
# [剩余数量：0] - [当前时间：19:54:53]
#
# [尝试次数：1] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 18
# [剩余数量：0] - [当前时间：19:54:56]
#
# [尝试次数：1] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 14
# [剩余数量：0] - [当前时间：19:54:57]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 22
# [剩余数量：0] - [当前时间：19:54:58]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 21
# [剩余数量：0] - [当前时间：19:54:59]
#
# [尝试次数：1] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 16
# [剩余数量：0] - [当前时间：19:54:59]
#
# [尝试次数：31] - 1.Brakes > 2.Brake Boosters & Pumps > 5.Power Brake Booster > Page 19
# [剩余数量：0] - [当前时间：19:55:02]
#
# [尝试次数：6] - 6.Steering > 1.Power Steering Components > 6.Power Steering Pump > Page 17
# [剩余数量：0] - [当前时间：19:55:05]
#
# [尝试次数：38] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 23
# [剩余数量：0] - [当前时间：19:55:07]
#
# [尝试次数：46] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 22
# [剩余数量：0] - [当前时间：19:55:07]
#
# [尝试次数：28] - 7.Motors > 4.Wiper and Washer > 3.Windshield Wiper Motor > Page 15
# [剩余数量：0] - [当前时间：19:55:07]
#
# [尝试次数：8] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 23
# [剩余数量：0] - [当前时间：19:55:11]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 24
# [剩余数量：0] - [当前时间：19:55:13]
#
# [尝试次数：8] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 13
# [剩余数量：0] - [当前时间：19:55:17]
#
# [尝试次数：34] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 24
# [剩余数量：0] - [当前时间：19:55:19]
#
# [尝试次数：12] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 21
# [剩余数量：0] - [当前时间：19:55:20]
#
# [尝试次数：29] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 25
# [剩余数量：0] - [当前时间：19:55:20]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 26
# [剩余数量：0] - [当前时间：19:55:24]
#
# [尝试次数：31] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 14
# [剩余数量：0] - [当前时间：19:55:25]
#
# [尝试次数：23] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 22
# [剩余数量：0] - [当前时间：19:55:27]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 27
# [剩余数量：0] - [当前时间：19:55:28]
#
# [尝试次数：32] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 25
# [剩余数量：0] - [当前时间：19:55:28]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 26
# [剩余数量：0] - [当前时间：19:55:33]
#
# [尝试次数：18] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 15
# [剩余数量：0] - [当前时间：19:55:34]
#
# [尝试次数：43] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 28
# [剩余数量：0] - [当前时间：19:55:34]
#
# [尝试次数：42] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 23
# [剩余数量：0] - [当前时间：19:55:35]
#
# [尝试次数：3] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 24
# [剩余数量：0] - [当前时间：19:55:38]
#
# [尝试次数：16] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 27
# [剩余数量：0] - [当前时间：19:55:39]
#
# [尝试次数：3] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 29
# [剩余数量：0] - [当前时间：19:55:41]
#
# [尝试次数：7] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 16
# [剩余数量：0] - [当前时间：19:55:44]
#
# [尝试次数：19] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 25
# [剩余数量：0] - [当前时间：19:55:45]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 30
# [剩余数量：0] - [当前时间：19:55:46]
#
# [尝试次数：32] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 28
# [剩余数量：0] - [当前时间：19:55:46]
#
# [尝试次数：4] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 17
# [剩余数量：0] - [当前时间：19:55:49]
#
# [尝试次数：37] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 26
# [剩余数量：0] - [当前时间：19:55:55]
#
# [尝试次数：16] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 18
# [剩余数量：0] - [当前时间：19:55:56]
#
# [尝试次数：61] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 29
# [剩余数量：0] - [当前时间：19:55:59]
#
# [尝试次数：75] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 31
# [剩余数量：0] - [当前时间：19:56:01]
#
# [尝试次数：6] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 27
# [剩余数量：0] - [当前时间：19:56:02]
#
# [尝试次数：5] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 30
# [剩余数量：0] - [当前时间：19:56:03]
#
# [尝试次数：28] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 19
# [剩余数量：0] - [当前时间：19:56:04]
#
# [尝试次数：39] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 20
# [剩余数量：0] - [当前时间：19:56:10]
#
# [尝试次数：5] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 31
# [剩余数量：0] - [当前时间：19:56:11]
#
# [尝试次数：16] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 32
# [剩余数量：0] - [当前时间：19:56:16]
#
# [尝试次数：9] - 7.Motors > 3.Window Lift > 2.Power Window Motor > Page 21
# [剩余数量：0] - [当前时间：19:56:17]
#
# [尝试次数：40] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 32
# [剩余数量：0] - [当前时间：19:56:22]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 33
# [剩余数量：0] - [当前时间：19:56:25]
#
# [尝试次数：10] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 28
# [剩余数量：0] - [当前时间：19:56:28]
#
# [尝试次数：22] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 34
# [剩余数量：0] - [当前时间：19:56:32]
#
# [尝试次数：40] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 29
# [剩余数量：0] - [当前时间：19:56:34]
#
# [尝试次数：15] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 35
# [剩余数量：0] - [当前时间：19:56:39]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 36
# [剩余数量：0] - [当前时间：19:56:43]
#
# [尝试次数：45] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 30
# [剩余数量：0] - [当前时间：19:56:43]
#
# [尝试次数：64] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 33
# [剩余数量：0] - [当前时间：19:56:46]
#
# [尝试次数：6] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 37
# [剩余数量：0] - [当前时间：19:56:50]
#
# [尝试次数：22] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 31
# [剩余数量：0] - [当前时间：19:56:52]
#
# [尝试次数：41] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 34
# [剩余数量：0] - [当前时间：19:56:54]
#
# [尝试次数：26] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 38
# [剩余数量：0] - [当前时间：19:56:58]
#
# [尝试次数：9] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 32
# [剩余数量：0] - [当前时间：19:57:00]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 39
# [剩余数量：0] - [当前时间：19:57:04]
#
# [尝试次数：38] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 35
# [剩余数量：0] - [当前时间：19:57:06]
#
# [尝试次数：24] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 33
# [剩余数量：0] - [当前时间：19:57:06]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 40
# [剩余数量：0] - [当前时间：19:57:09]
#
# [尝试次数：15] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 34
# [剩余数量：0] - [当前时间：19:57:11]
#
# [尝试次数：45] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 36
# [剩余数量：0] - [当前时间：19:57:14]
#
# [尝试次数：15] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 41
# [剩余数量：0] - [当前时间：19:57:14]
#
# [尝试次数：3] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 35
# [剩余数量：0] - [当前时间：19:57:16]
#
# [尝试次数：14] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 42
# [剩余数量：0] - [当前时间：19:57:19]
#
# [尝试次数：10] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 37
# [剩余数量：0] - [当前时间：19:57:21]
#
# [尝试次数：6] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 43
# [剩余数量：0] - [当前时间：19:57:26]
#
# [尝试次数：50] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 38
# [剩余数量：0] - [当前时间：19:57:30]
#
# [尝试次数：5] - 2.Drivetrain > 2.Driveline & Axles > 1.CV Axle Assembly > Page 36
# [剩余数量：0] - [当前时间：19:57:34]
#
# [尝试次数：8] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 44
# [剩余数量：0] - [当前时间：19:57:37]
#
# [尝试次数：12] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 39
# [剩余数量：0] - [当前时间：19:57:38]
#
# [尝试次数：9] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 45
# [剩余数量：0] - [当前时间：19:57:41]
#
# [尝试次数：47] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 46
# [剩余数量：0] - [当前时间：19:57:53]
#
# [尝试次数：21] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 40
# [剩余数量：0] - [当前时间：19:57:54]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 41
# [剩余数量：0] - [当前时间：19:57:59]
#
# [尝试次数：10] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 47
# [剩余数量：0] - [当前时间：19:58:01]
#
# [尝试次数：43] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 42
# [剩余数量：0] - [当前时间：19:58:07]
#
# [尝试次数：26] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 48
# [剩余数量：0] - [当前时间：19:58:12]
#
# [尝试次数：12] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 43
# [剩余数量：0] - [当前时间：19:58:14]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 49
# [剩余数量：0] - [当前时间：19:58:18]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 44
# [剩余数量：0] - [当前时间：19:58:23]
#
# [尝试次数：18] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 50
# [剩余数量：0] - [当前时间：19:58:24]
#
# [尝试次数：8] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 51
# [剩余数量：0] - [当前时间：19:58:32]
#
# [尝试次数：37] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 45
# [剩余数量：0] - [当前时间：19:58:33]
#
# [尝试次数：20] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 52
# [剩余数量：0] - [当前时间：19:58:38]
#
# [尝试次数：24] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 46
# [剩余数量：0] - [当前时间：19:58:40]
#
# [尝试次数：13] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 53
# [剩余数量：0] - [当前时间：19:58:43]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 47
# [剩余数量：0] - [当前时间：19:58:46]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 54
# [剩余数量：0] - [当前时间：19:58:50]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 48
# [剩余数量：0] - [当前时间：19:59:01]
#
# [尝试次数：17] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 55
# [剩余数量：0] - [当前时间：19:59:03]
#
# [尝试次数：42] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 49
# [剩余数量：0] - [当前时间：19:59:08]
#
# [尝试次数：16] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 56
# [剩余数量：0] - [当前时间：19:59:10]
#
# [尝试次数：2] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 57
# [剩余数量：0] - [当前时间：19:59:16]
#
# [尝试次数：22] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 50
# [剩余数量：0] - [当前时间：19:59:17]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 51
# [剩余数量：0] - [当前时间：19:59:21]
#
# [尝试次数：26] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 58
# [剩余数量：0] - [当前时间：19:59:23]
#
# [尝试次数：17] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 52
# [剩余数量：0] - [当前时间：19:59:30]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 59
# [剩余数量：0] - [当前时间：19:59:31]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 60
# [剩余数量：0] - [当前时间：19:59:34]
#
# [尝试次数：5] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 53
# [剩余数量：0] - [当前时间：19:59:35]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 61
# [剩余数量：0] - [当前时间：19:59:40]
#
# [尝试次数：2] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 54
# [剩余数量：0] - [当前时间：19:59:43]
#
# [尝试次数：7] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 62
# [剩余数量：0] - [当前时间：19:59:46]
#
# [尝试次数：14] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 63
# [剩余数量：0] - [当前时间：19:59:50]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 55
# [剩余数量：0] - [当前时间：19:59:57]
#
# [尝试次数：43] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 64
# [剩余数量：0] - [当前时间：20:00:00]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 65
# [剩余数量：0] - [当前时间：20:00:06]
#
# [尝试次数：4] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 56
# [剩余数量：0] - [当前时间：20:00:16]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 57
# [剩余数量：0] - [当前时间：20:00:21]
#
# [尝试次数：20] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 66
# [剩余数量：0] - [当前时间：20:00:24]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 58
# [剩余数量：0] - [当前时间：20:00:28]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 59
# [剩余数量：0] - [当前时间：20:00:31]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 67
# [剩余数量：0] - [当前时间：20:00:32]
#
# [尝试次数：7] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 68
# [剩余数量：0] - [当前时间：20:00:37]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 60
# [剩余数量：0] - [当前时间：20:00:39]
#
# [尝试次数：4] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 69
# [剩余数量：0] - [当前时间：20:00:40]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 61
# [剩余数量：0] - [当前时间：20:00:46]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 70
# [剩余数量：0] - [当前时间：20:00:46]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 62
# [剩余数量：0] - [当前时间：20:00:56]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 71
# [剩余数量：0] - [当前时间：20:00:58]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 72
# [剩余数量：0] - [当前时间：20:01:01]
#
# [尝试次数：11] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 73
# [剩余数量：0] - [当前时间：20:01:10]
#
# [尝试次数：4] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 74
# [剩余数量：0] - [当前时间：20:01:13]
#
# [尝试次数：2] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 75
# [剩余数量：0] - [当前时间：20:01:18]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 63
# [剩余数量：0] - [当前时间：20:01:21]
#
# [尝试次数：2] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 76
# [剩余数量：0] - [当前时间：20:01:22]
#
# [尝试次数：12] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 64
# [剩余数量：0] - [当前时间：20:01:29]
#
# [尝试次数：15] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 77
# [剩余数量：0] - [当前时间：20:01:38]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 65
# [剩余数量：0] - [当前时间：20:01:38]
#
# [尝试次数：5] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 66
# [剩余数量：0] - [当前时间：20:01:44]
#
# [尝试次数：28] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 67
# [剩余数量：0] - [当前时间：20:01:51]
#
# [尝试次数：90] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 78
# [剩余数量：0] - [当前时间：20:01:55]
#
# [尝试次数：23] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 68
# [剩余数量：0] - [当前时间：20:01:57]
#
# [尝试次数：10] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 79
# [剩余数量：0] - [当前时间：20:01:59]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 80
# [剩余数量：0] - [当前时间：20:02:02]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 81
# [剩余数量：0] - [当前时间：20:02:05]
#
# [尝试次数：21] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 69
# [剩余数量：0] - [当前时间：20:02:07]
#
# [尝试次数：8] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 70
# [剩余数量：0] - [当前时间：20:02:13]
#
# [尝试次数：1] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 82
# [剩余数量：0] - [当前时间：20:02:15]
#
# [尝试次数：4] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 71
# [剩余数量：0] - [当前时间：20:02:20]
#
# [尝试次数：5] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 83
# [剩余数量：0] - [当前时间：20:02:21]
#
# [尝试次数：30] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 72
# [剩余数量：0] - [当前时间：20:02:29]
#
# [尝试次数：3] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 73
# [剩余数量：0] - [当前时间：20:02:35]
#
# [尝试次数：31] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 84
# [剩余数量：0] - [当前时间：20:02:38]
#
# [尝试次数：20] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 85
# [剩余数量：0] - [当前时间：20:02:43]
#
# [尝试次数：43] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 74
# [剩余数量：0] - [当前时间：20:02:45]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 75
# [剩余数量：0] - [当前时间：20:02:49]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 76
# [剩余数量：0] - [当前时间：20:02:53]
#
# [尝试次数：20] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 86
# [剩余数量：0] - [当前时间：20:02:55]
#
# [尝试次数：13] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 77
# [剩余数量：0] - [当前时间：20:02:59]
#
# [尝试次数：16] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 87
# [剩余数量：0] - [当前时间：20:03:03]
#
# [尝试次数：5] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 78
# [剩余数量：0] - [当前时间：20:03:04]
#
# [尝试次数：24] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 88
# [剩余数量：0] - [当前时间：20:03:10]
#
# [尝试次数：13] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 79
# [剩余数量：0] - [当前时间：20:03:13]
#
# [尝试次数：9] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 89
# [剩余数量：0] - [当前时间：20:03:16]
#
# [尝试次数：2] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 80
# [剩余数量：0] - [当前时间：20:03:18]
#
# [尝试次数：17] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 90
# [剩余数量：0] - [当前时间：20:03:22]
#
# [尝试次数：2] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 81
# [剩余数量：0] - [当前时间：20:03:23]
#
# [尝试次数：3] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 91
# [剩余数量：0] - [当前时间：20:03:26]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 82
# [剩余数量：0] - [当前时间：20:03:31]
#
# [尝试次数：16] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 92
# [剩余数量：0] - [当前时间：20:03:32]
#
# [尝试次数：13] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 83
# [剩余数量：0] - [当前时间：20:03:34]
#
# [尝试次数：7] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 93
# [剩余数量：0] - [当前时间：20:03:38]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 84
# [剩余数量：0] - [当前时间：20:03:42]
#
# [尝试次数：3] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 85
# [剩余数量：0] - [当前时间：20:03:45]
#
# [尝试次数：49] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 94
# [剩余数量：0] - [当前时间：20:03:56]
#
# [尝试次数：12] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 95
# [剩余数量：0] - [当前时间：20:04:02]
#
# [尝试次数：14] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 96
# [剩余数量：0] - [当前时间：20:04:08]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 86
# [剩余数量：0] - [当前时间：20:04:11]
#
# [尝试次数：6] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 97
# [剩余数量：0] - [当前时间：20:04:12]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 87
# [剩余数量：0] - [当前时间：20:04:15]
#
# [尝试次数：11] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 88
# [剩余数量：0] - [当前时间：20:04:20]
#
# [尝试次数：36] - 1.Brakes > 3.Disc Brakes > 2.Brake Caliper > Page 98
# [剩余数量：0] - [当前时间：20:04:25]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 89
# [剩余数量：0] - [当前时间：20:04:27]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 90
# [剩余数量：0] - [当前时间：20:04:31]
#
# [尝试次数：9] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 91
# [剩余数量：0] - [当前时间：20:04:37]
#
# [尝试次数：22] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 92
# [剩余数量：0] - [当前时间：20:04:45]
#
# [尝试次数：35] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 93
# [剩余数量：0] - [当前时间：20:05:04]
#
# [尝试次数：5] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 94
# [剩余数量：0] - [当前时间：20:05:10]
#
# [尝试次数：7] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 95
# [剩余数量：0] - [当前时间：20:05:30]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 96
# [剩余数量：0] - [当前时间：20:05:34]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 97
# [剩余数量：0] - [当前时间：20:05:41]
#
# [尝试次数：48] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 98
# [剩余数量：0] - [当前时间：20:05:50]
#
# [尝试次数：6] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 99
# [剩余数量：0] - [当前时间：20:05:57]
#
# [尝试次数：2] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 100
# [剩余数量：0] - [当前时间：20:06:01]
#
# [尝试次数：5] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 101
# [剩余数量：0] - [当前时间：20:06:05]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 102
# [剩余数量：0] - [当前时间：20:06:10]
#
# [尝试次数：26] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 103
# [剩余数量：0] - [当前时间：20:06:27]
#
# [尝试次数：25] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 104
# [剩余数量：0] - [当前时间：20:06:51]
#
# [尝试次数：1] - 3.Electronics > 1.Control Modules > 6.Engine Control Module > Page 105
# [剩余数量：0] - [当前时间：20:06:55]
#
# 输出ing...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/20/g09tvx4s7mdd977ps185l3_r0000gn/T/ipykernel_2044/1346716938.py in ?()
#     166
#     167 print('输出ing...')
#     168 print()
#     169 if not output_correct.empty:
# --> 170     output_correct = output_correct.sort_values(by=['1st Category No', '2nd Category No', '3rd Category No', 'Page', 'Part No'],
#     171                                                 ascending=[True, True, True, True, True],
#     172                                                 ignore_index=True)
#     173     output_correct.to_excel(f'''./2.url-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
#
# ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7168                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7169                 f" != length of by ({len(by)})"
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
#    7174             # need to rewrap columns in Series to apply key function
#    7175             if key is not None:
#
# ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(.0)
# -> 7172         ...     key=lambda x: np.argsort(index_natsorted(df["time"]))
#
# ~/Desktop/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'Part No'
