# %%
from gevent import monkey
monkey.patch_all()
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = = = = =

import pandas as pd
import requests
from bs4 import BeautifulSoup
from lxml import etree
import re
import time

# = = = = = = = = = = = = = = = = = =

df_menu = pd.read_excel('./menu.xlsx', header=0)
list_url = df_menu['Url'].to_list()

print('总数量：' + str(len(list_url)))
print()

work = Queue()
for url in list_url:
    work.put_nowait(url)

# = = = = = = = = = = = = = = = = = =

df = pd.DataFrame(columns=['Url',
                           'Manufacturer',
                           'Note',
                           'Info',
                           'status'])

# = = = = = = = = = = = = = = = = = =

proxies = {'http': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818',
           'https': 'http://t18654032004169:9s5s2nv0@u431.kdltps.com:15818'}

# = = = = = = = = = = = = = = = = = =

def crawler():
    global df
    
    while not work.empty():
        url = work.get_nowait()
        
        status = 'error'
        for _ in range(31):
            try:
                resp = requests.get(url, proxies=proxies).text

                # = = = = = = = = = = = = = = = = = =
                
                soup = BeautifulSoup(resp, 'lxml')
                
                # = = = = = = = = = = = = = = = = = =

                html = etree.HTML(str(soup))
                
                list_part = html.xpath('//div[@class="listing-text-row-moreinfo-truck"]')
                
                # = = = = = = = = = = = = = = = = = =

                list_manufacturer = [part.xpath('.//span[@class="listing-final-manufacturer"]/text()')[0] for part in list_part]

                # = = = = = = = = = = = = = = = = = =

                list_part_number = [part.xpath('.//span[@title="Buyer\'s Guide"]/text()')[0] for part in list_part]

                # = = = = = = = = = = = = = = = = = =
                
                list_note = [re.sub(' +', ' ', ' '.join(row.xpath('./descendant-or-self::*/text()'))).strip() for row in html.xpath('//div[@class="listing-text-row"]')]

                # = = = = = = = = = = = = = = = = = =

                list_info = []
                for part in list_part:
                    info = part.xpath('.//a[@class="ra-btn ra-btn-moreinfo"]')
                    if len(info) == 0:
                        list_info.append('')
                    else:
                        list_info.append(info[0].get('href'))

                # = = = = = = = = = = = = = = = = = =
                        
                part_index = list_part_number.index(url.split(',')[-3])

                # = = = = = = = = = = = = = = = = = =

                status = 'ok'
                df_temp = pd.DataFrame([{'Url': url,
                                         'Manufacturer': list_manufacturer[part_index],
                                         'Note': list_note[part_index],
                                         'Info': list_info[part_index],
                                         'status': 'ok'}])

                break

            except:
                time.sleep(3)
                continue

        # = = = = = = = = = = = = = = = = = =
        
        if status == 'error':
            df_temp = pd.DataFrame([{'Url': url,
                                     'status': 'error'}])

        df = pd.concat([df, df_temp], ignore_index=True).fillna('')
        
        print(url +  '  <->  [' + status + '] - 剩余：' + str(work.qsize()))
        
# = = = = = = = = = = = = = = = = = =

list_task = []
for _ in range(12):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

df.to_excel('./part.xlsx', index=False)
print()
print('搞定')
# Out:
# 总数量：482
#
# https://www.rockauto.com/en/parts/standard+motor+products,SC103T,speed+sensor,10634  <->  [ok] - 剩余：470
# https://www.rockauto.com/en/parts/standard+motor+products,SC103,speed+sensor,10634  <->  [ok] - 剩余：469
# https://www.rockauto.com/en/parts/standard+motor+products,SC100,speed+sensor,10634  <->  [ok] - 剩余：468
# https://www.rockauto.com/en/parts/standard+motor+products,SC104,speed+sensor,10634  <->  [ok] - 剩余：467
# https://www.rockauto.com/en/parts/standard+motor+products,SC104T,speed+sensor,10634  <->  [ok] - 剩余：466
# https://www.rockauto.com/en/parts/standard+motor+products,PC513,speed+sensor,10634  <->  [ok] - 剩余：465
# https://www.rockauto.com/en/parts/standard+motor+products,SC105,speed+sensor,10634  <->  [ok] - 剩余：464
# https://www.rockauto.com/en/parts/standard+motor+products,SC102,speed+sensor,10634  <->  [ok] - 剩余：463
# https://www.rockauto.com/en/parts/standard+motor+products,SC105T,speed+sensor,10634  <->  [ok] - 剩余：462
# https://www.rockauto.com/en/parts/standard+motor+products,SC108,speed+sensor,10634  <->  [ok] - 剩余：461
# https://www.rockauto.com/en/parts/standard+motor+products,PC514,speed+sensor,10634  <->  [ok] - 剩余：460
# https://www.rockauto.com/en/parts/standard+motor+products,SC109T,speed+sensor,10634  <->  [ok] - 剩余：459
# https://www.rockauto.com/en/parts/standard+motor+products,SC109,speed+sensor,10634  <->  [ok] - 剩余：458
# https://www.rockauto.com/en/parts/standard+motor+products,SC113,speed+sensor,10634  <->  [ok] - 剩余：457
# https://www.rockauto.com/en/parts/standard+motor+products,SC110,speed+sensor,10634  <->  [ok] - 剩余：456
# https://www.rockauto.com/en/parts/standard+motor+products,SC121,speed+sensor,10634  <->  [ok] - 剩余：455
# https://www.rockauto.com/en/parts/standard+motor+products,SC117,speed+sensor,10634  <->  [ok] - 剩余：454
# https://www.rockauto.com/en/parts/standard+motor+products,SC123,speed+sensor,10634  <->  [ok] - 剩余：453
# https://www.rockauto.com/en/parts/standard+motor+products,SC125,speed+sensor,10634  <->  [ok] - 剩余：452
# https://www.rockauto.com/en/parts/standard+motor+products,SC126,speed+sensor,10634  <->  [ok] - 剩余：451
# https://www.rockauto.com/en/parts/standard+motor+products,SC124,speed+sensor,10634  <->  [ok] - 剩余：450
# https://www.rockauto.com/en/parts/standard+motor+products,SC111,speed+sensor,10634  <->  [ok] - 剩余：449
# https://www.rockauto.com/en/parts/standard+motor+products,SC127,speed+sensor,10634  <->  [ok] - 剩余：448
# https://www.rockauto.com/en/parts/standard+motor+products,SC10,speed+sensor,10634  <->  [ok] - 剩余：447
# https://www.rockauto.com/en/parts/standard+motor+products,SC106,speed+sensor,10634  <->  [ok] - 剩余：446
# https://www.rockauto.com/en/parts/standard+motor+products,SC129,speed+sensor,10634  <->  [ok] - 剩余：445
# https://www.rockauto.com/en/parts/standard+motor+products,SC131,speed+sensor,10634  <->  [ok] - 剩余：444
# https://www.rockauto.com/en/parts/standard+motor+products,ALS1807,speed+sensor,10634  <->  [ok] - 剩余：443
# https://www.rockauto.com/en/parts/standard+motor+products,SC131T,speed+sensor,10634  <->  [ok] - 剩余：442
# https://www.rockauto.com/en/parts/standard+motor+products,SC136,speed+sensor,10634  <->  [ok] - 剩余：441
# https://www.rockauto.com/en/parts/standard+motor+products,SC134,speed+sensor,10634  <->  [ok] - 剩余：440
# https://www.rockauto.com/en/parts/standard+motor+products,SC137,speed+sensor,10634  <->  [ok] - 剩余：439
# https://www.rockauto.com/en/parts/standard+motor+products,SC136T,speed+sensor,10634  <->  [ok] - 剩余：438
# https://www.rockauto.com/en/parts/standard+motor+products,SC133,speed+sensor,10634  <->  [ok] - 剩余：437
# https://www.rockauto.com/en/parts/standard+motor+products,SC142,speed+sensor,10634  <->  [ok] - 剩余：436
# https://www.rockauto.com/en/parts/standard+motor+products,SC12,speed+sensor,10634  <->  [ok] - 剩余：435
# https://www.rockauto.com/en/parts/standard+motor+products,SC144,speed+sensor,10634  <->  [ok] - 剩余：434
# https://www.rockauto.com/en/parts/standard+motor+products,SC147,speed+sensor,10634  <->  [ok] - 剩余：433
# https://www.rockauto.com/en/parts/standard+motor+products,SC146,speed+sensor,10634  <->  [ok] - 剩余：432
# https://www.rockauto.com/en/parts/standard+motor+products,SC148,speed+sensor,10634  <->  [ok] - 剩余：431
# https://www.rockauto.com/en/parts/standard+motor+products,SC143,speed+sensor,10634  <->  [ok] - 剩余：430
# https://www.rockauto.com/en/parts/standard+motor+products,SC153,speed+sensor,10634  <->  [ok] - 剩余：429
# https://www.rockauto.com/en/parts/standard+motor+products,SC149,speed+sensor,10634  <->  [ok] - 剩余：428
# https://www.rockauto.com/en/parts/standard+motor+products,SC151,speed+sensor,10634  <->  [ok] - 剩余：427
# https://www.rockauto.com/en/parts/standard+motor+products,SC154,speed+sensor,10634  <->  [ok] - 剩余：426
# https://www.rockauto.com/en/parts/standard+motor+products,SC150,speed+sensor,10634  <->  [ok] - 剩余：425
# https://www.rockauto.com/en/parts/standard+motor+products,SC157,speed+sensor,10634  <->  [ok] - 剩余：424
# https://www.rockauto.com/en/parts/standard+motor+products,SC156,speed+sensor,10634  <->  [ok] - 剩余：423
# https://www.rockauto.com/en/parts/standard+motor+products,SC130,speed+sensor,10634  <->  [ok] - 剩余：422
# https://www.rockauto.com/en/parts/standard+motor+products,SC167,speed+sensor,10634  <->  [ok] - 剩余：421
# https://www.rockauto.com/en/parts/standard+motor+products,SC163,speed+sensor,10634  <->  [ok] - 剩余：420
# https://www.rockauto.com/en/parts/standard+motor+products,SC161,speed+sensor,10634  <->  [ok] - 剩余：419
# https://www.rockauto.com/en/parts/standard+motor+products,SC159,speed+sensor,10634  <->  [ok] - 剩余：418
# https://www.rockauto.com/en/parts/standard+motor+products,SC158,speed+sensor,10634  <->  [ok] - 剩余：417
# https://www.rockauto.com/en/parts/standard+motor+products,SC160,speed+sensor,10634  <->  [ok] - 剩余：416
# https://www.rockauto.com/en/parts/standard+motor+products,SC168,speed+sensor,10634  <->  [ok] - 剩余：415
# https://www.rockauto.com/en/parts/standard+motor+products,SC153T,speed+sensor,10634  <->  [ok] - 剩余：414
# https://www.rockauto.com/en/parts/standard+motor+products,SC168T,speed+sensor,10634  <->  [ok] - 剩余：413
# https://www.rockauto.com/en/parts/standard+motor+products,SC169,speed+sensor,10634  <->  [ok] - 剩余：412
# https://www.rockauto.com/en/parts/standard+motor+products,SC174,speed+sensor,10634  <->  [ok] - 剩余：411
# https://www.rockauto.com/en/parts/standard+motor+products,ALS100,speed+sensor,10634  <->  [ok] - 剩余：410
# https://www.rockauto.com/en/parts/standard+motor+products,SC172,speed+sensor,10634  <->  [ok] - 剩余：409
# https://www.rockauto.com/en/parts/standard+motor+products,SC176,speed+sensor,10634  <->  [ok] - 剩余：408
# https://www.rockauto.com/en/parts/standard+motor+products,SC171,speed+sensor,10634  <->  [ok] - 剩余：407
# https://www.rockauto.com/en/parts/standard+motor+products,SC173,speed+sensor,10634  <->  [ok] - 剩余：406
# https://www.rockauto.com/en/parts/standard+motor+products,SC180,speed+sensor,10634  <->  [ok] - 剩余：405
# https://www.rockauto.com/en/parts/standard+motor+products,SC175,speed+sensor,10634  <->  [ok] - 剩余：404
# https://www.rockauto.com/en/parts/standard+motor+products,SC177,speed+sensor,10634  <->  [ok] - 剩余：403
# https://www.rockauto.com/en/parts/standard+motor+products,SC189,speed+sensor,10634  <->  [ok] - 剩余：402
# https://www.rockauto.com/en/parts/standard+motor+products,SC188,speed+sensor,10634  <->  [ok] - 剩余：401
# https://www.rockauto.com/en/parts/standard+motor+products,SC187,speed+sensor,10634  <->  [ok] - 剩余：400
# https://www.rockauto.com/en/parts/standard+motor+products,SC182,speed+sensor,10634  <->  [ok] - 剩余：399
# https://www.rockauto.com/en/parts/standard+motor+products,SC183,speed+sensor,10634  <->  [ok] - 剩余：398
# https://www.rockauto.com/en/parts/standard+motor+products,SC193,speed+sensor,10634  <->  [ok] - 剩余：397
# https://www.rockauto.com/en/parts/standard+motor+products,SC20,speed+sensor,10634  <->  [ok] - 剩余：396
# https://www.rockauto.com/en/parts/standard+motor+products,SC200,speed+sensor,10634  <->  [ok] - 剩余：395
# https://www.rockauto.com/en/parts/standard+motor+products,SC201,speed+sensor,10634  <->  [ok] - 剩余：394
# https://www.rockauto.com/en/parts/standard+motor+products,SC205,speed+sensor,10634  <->  [ok] - 剩余：393
# https://www.rockauto.com/en/parts/standard+motor+products,SC208,speed+sensor,10634  <->  [ok] - 剩余：392
# https://www.rockauto.com/en/parts/standard+motor+products,SC162,speed+sensor,10634  <->  [ok] - 剩余：391
# https://www.rockauto.com/en/parts/standard+motor+products,SC202,speed+sensor,10634  <->  [ok] - 剩余：390
# https://www.rockauto.com/en/parts/standard+motor+products,SC19,speed+sensor,10634  <->  [ok] - 剩余：389
# https://www.rockauto.com/en/parts/standard+motor+products,SC209,speed+sensor,10634  <->  [ok] - 剩余：388
# https://www.rockauto.com/en/parts/standard+motor+products,SC21,speed+sensor,10634  <->  [ok] - 剩余：387
# https://www.rockauto.com/en/parts/standard+motor+products,SC213,speed+sensor,10634  <->  [ok] - 剩余：386
# https://www.rockauto.com/en/parts/standard+motor+products,SC204,speed+sensor,10634  <->  [ok] - 剩余：385
# https://www.rockauto.com/en/parts/standard+motor+products,SC210,speed+sensor,10634  <->  [ok] - 剩余：384
# https://www.rockauto.com/en/parts/standard+motor+products,SC212,speed+sensor,10634  <->  [ok] - 剩余：383
# https://www.rockauto.com/en/parts/standard+motor+products,SC230,speed+sensor,10634  <->  [ok] - 剩余：382
# https://www.rockauto.com/en/parts/standard+motor+products,SC226,speed+sensor,10634  <->  [ok] - 剩余：381
# https://www.rockauto.com/en/parts/standard+motor+products,SC229,speed+sensor,10634  <->  [ok] - 剩余：380
# https://www.rockauto.com/en/parts/standard+motor+products,SC215,speed+sensor,10634  <->  [ok] - 剩余：379
# https://www.rockauto.com/en/parts/standard+motor+products,SC225,speed+sensor,10634  <->  [ok] - 剩余：378
# https://www.rockauto.com/en/parts/standard+motor+products,SC22,speed+sensor,10634  <->  [ok] - 剩余：377
# https://www.rockauto.com/en/parts/standard+motor+products,SC234,speed+sensor,10634  <->  [ok] - 剩余：376
# https://www.rockauto.com/en/parts/standard+motor+products,SC238,speed+sensor,10634  <->  [ok] - 剩余：375
# https://www.rockauto.com/en/parts/standard+motor+products,SC237,speed+sensor,10634  <->  [ok] - 剩余：374
# https://www.rockauto.com/en/parts/standard+motor+products,SC233,speed+sensor,10634  <->  [ok] - 剩余：373
# https://www.rockauto.com/en/parts/standard+motor+products,SC235,speed+sensor,10634  <->  [ok] - 剩余：372
# https://www.rockauto.com/en/parts/standard+motor+products,SC198,speed+sensor,10634  <->  [ok] - 剩余：371
# https://www.rockauto.com/en/parts/standard+motor+products,SC236,speed+sensor,10634  <->  [ok] - 剩余：370
# https://www.rockauto.com/en/parts/standard+motor+products,SC199,speed+sensor,10634  <->  [ok] - 剩余：369
# https://www.rockauto.com/en/parts/standard+motor+products,SC239,speed+sensor,10634  <->  [ok] - 剩余：368
# https://www.rockauto.com/en/parts/standard+motor+products,SC245,speed+sensor,10634  <->  [ok] - 剩余：367
# https://www.rockauto.com/en/parts/standard+motor+products,SC241,speed+sensor,10634  <->  [ok] - 剩余：366
# https://www.rockauto.com/en/parts/standard+motor+products,SC251,speed+sensor,10634  <->  [ok] - 剩余：365
# https://www.rockauto.com/en/parts/standard+motor+products,SC244,speed+sensor,10634  <->  [ok] - 剩余：364
# https://www.rockauto.com/en/parts/standard+motor+products,SC249,speed+sensor,10634  <->  [ok] - 剩余：363
# https://www.rockauto.com/en/parts/standard+motor+products,SC240,speed+sensor,10634  <->  [ok] - 剩余：362
# https://www.rockauto.com/en/parts/standard+motor+products,SC255,speed+sensor,10634  <->  [ok] - 剩余：361
# https://www.rockauto.com/en/parts/standard+motor+products,SC242,speed+sensor,10634  <->  [ok] - 剩余：360
# https://www.rockauto.com/en/parts/standard+motor+products,SC247,speed+sensor,10634  <->  [ok] - 剩余：359
# https://www.rockauto.com/en/parts/standard+motor+products,SC257,speed+sensor,10634  <->  [ok] - 剩余：358
# https://www.rockauto.com/en/parts/standard+motor+products,SC260,speed+sensor,10634  <->  [ok] - 剩余：357
# https://www.rockauto.com/en/parts/standard+motor+products,SC254,speed+sensor,10634  <->  [ok] - 剩余：356
# https://www.rockauto.com/en/parts/standard+motor+products,SC224,speed+sensor,10634  <->  [ok] - 剩余：355
# https://www.rockauto.com/en/parts/standard+motor+products,SC265,speed+sensor,10634  <->  [ok] - 剩余：354
# https://www.rockauto.com/en/parts/standard+motor+products,SC263,speed+sensor,10634  <->  [ok] - 剩余：353
# https://www.rockauto.com/en/parts/standard+motor+products,SC267,speed+sensor,10634  <->  [ok] - 剩余：352
# https://www.rockauto.com/en/parts/standard+motor+products,SC274,speed+sensor,10634  <->  [ok] - 剩余：351
# https://www.rockauto.com/en/parts/standard+motor+products,SC275,speed+sensor,10634  <->  [ok] - 剩余：350
# https://www.rockauto.com/en/parts/standard+motor+products,SC271,speed+sensor,10634  <->  [ok] - 剩余：349
# https://www.rockauto.com/en/parts/standard+motor+products,SC276,speed+sensor,10634  <->  [ok] - 剩余：348
# https://www.rockauto.com/en/parts/standard+motor+products,SC28,speed+sensor,10634  <->  [ok] - 剩余：347
# https://www.rockauto.com/en/parts/standard+motor+products,SC279,speed+sensor,10634  <->  [ok] - 剩余：346
# https://www.rockauto.com/en/parts/standard+motor+products,SC281,speed+sensor,10634  <->  [ok] - 剩余：345
# https://www.rockauto.com/en/parts/standard+motor+products,SC284,speed+sensor,10634  <->  [ok] - 剩余：344
# https://www.rockauto.com/en/parts/standard+motor+products,SC262,speed+sensor,10634  <->  [ok] - 剩余：343
# https://www.rockauto.com/en/parts/standard+motor+products,SC288,speed+sensor,10634  <->  [ok] - 剩余：342
# https://www.rockauto.com/en/parts/standard+motor+products,SC292,speed+sensor,10634  <->  [ok] - 剩余：341
# https://www.rockauto.com/en/parts/standard+motor+products,SC289,speed+sensor,10634  <->  [ok] - 剩余：340
# https://www.rockauto.com/en/parts/standard+motor+products,SC296,speed+sensor,10634  <->  [ok] - 剩余：339
# https://www.rockauto.com/en/parts/standard+motor+products,SC293,speed+sensor,10634  <->  [ok] - 剩余：338
# https://www.rockauto.com/en/parts/standard+motor+products,SC297,speed+sensor,10634  <->  [ok] - 剩余：337
# https://www.rockauto.com/en/parts/standard+motor+products,SC300,speed+sensor,10634  <->  [ok] - 剩余：336
# https://www.rockauto.com/en/parts/standard+motor+products,SC303,speed+sensor,10634  <->  [ok] - 剩余：335
# https://www.rockauto.com/en/parts/standard+motor+products,SC305,speed+sensor,10634  <->  [ok] - 剩余：334
# https://www.rockauto.com/en/parts/standard+motor+products,SC307,speed+sensor,10634  <->  [ok] - 剩余：333
# https://www.rockauto.com/en/parts/standard+motor+products,SC315,speed+sensor,10634  <->  [ok] - 剩余：332
# https://www.rockauto.com/en/parts/standard+motor+products,SC317,speed+sensor,10634  <->  [ok] - 剩余：331
# https://www.rockauto.com/en/parts/standard+motor+products,SC32,speed+sensor,10634  <->  [ok] - 剩余：330
# https://www.rockauto.com/en/parts/standard+motor+products,SC294,speed+sensor,10634  <->  [ok] - 剩余：329
# https://www.rockauto.com/en/parts/standard+motor+products,SC277,speed+sensor,10634  <->  [ok] - 剩余：328
# https://www.rockauto.com/en/parts/standard+motor+products,SC320,speed+sensor,10634  <->  [ok] - 剩余：327
# https://www.rockauto.com/en/parts/standard+motor+products,SC318,speed+sensor,10634  <->  [ok] - 剩余：326
# https://www.rockauto.com/en/parts/standard+motor+products,SC261,speed+sensor,10634  <->  [ok] - 剩余：325
# https://www.rockauto.com/en/parts/standard+motor+products,SC324,speed+sensor,10634  <->  [ok] - 剩余：324
# https://www.rockauto.com/en/parts/standard+motor+products,SC331,speed+sensor,10634  <->  [ok] - 剩余：323
# https://www.rockauto.com/en/parts/standard+motor+products,SC325,speed+sensor,10634  <->  [ok] - 剩余：322
# https://www.rockauto.com/en/parts/standard+motor+products,SC330,speed+sensor,10634  <->  [ok] - 剩余：321
# https://www.rockauto.com/en/parts/standard+motor+products,SC326,speed+sensor,10634  <->  [ok] - 剩余：320
# https://www.rockauto.com/en/parts/standard+motor+products,SC256,speed+sensor,10634  <->  [ok] - 剩余：319
# https://www.rockauto.com/en/parts/standard+motor+products,SC327,speed+sensor,10634  <->  [ok] - 剩余：318
# https://www.rockauto.com/en/parts/standard+motor+products,SC333,speed+sensor,10634  <->  [ok] - 剩余：317
# https://www.rockauto.com/en/parts/standard+motor+products,SC232,speed+sensor,10634  <->  [ok] - 剩余：316
# https://www.rockauto.com/en/parts/standard+motor+products,SC329,speed+sensor,10634  <->  [ok] - 剩余：315
# https://www.rockauto.com/en/parts/standard+motor+products,SC339,speed+sensor,10634  <->  [ok] - 剩余：314
# https://www.rockauto.com/en/parts/standard+motor+products,SC337,speed+sensor,10634  <->  [ok] - 剩余：313
# https://www.rockauto.com/en/parts/standard+motor+products,SC336,speed+sensor,10634  <->  [ok] - 剩余：312
# https://www.rockauto.com/en/parts/standard+motor+products,SC34,speed+sensor,10634  <->  [ok] - 剩余：311
# https://www.rockauto.com/en/parts/standard+motor+products,SC341,speed+sensor,10634  <->  [ok] - 剩余：310
# https://www.rockauto.com/en/parts/standard+motor+products,SC306,speed+sensor,10634  <->  [ok] - 剩余：309
# https://www.rockauto.com/en/parts/standard+motor+products,SC345,speed+sensor,10634  <->  [ok] - 剩余：308
# https://www.rockauto.com/en/parts/standard+motor+products,SC346,speed+sensor,10634  <->  [ok] - 剩余：307
# https://www.rockauto.com/en/parts/standard+motor+products,SC349,speed+sensor,10634  <->  [ok] - 剩余：306
# https://www.rockauto.com/en/parts/standard+motor+products,SC348,speed+sensor,10634  <->  [ok] - 剩余：305
# https://www.rockauto.com/en/parts/standard+motor+products,SC340,speed+sensor,10634  <->  [ok] - 剩余：304
# https://www.rockauto.com/en/parts/standard+motor+products,SC347,speed+sensor,10634  <->  [ok] - 剩余：303
# https://www.rockauto.com/en/parts/standard+motor+products,SC350,speed+sensor,10634  <->  [ok] - 剩余：302
# https://www.rockauto.com/en/parts/standard+motor+products,SC352,speed+sensor,10634  <->  [ok] - 剩余：301
# https://www.rockauto.com/en/parts/standard+motor+products,SC353,speed+sensor,10634  <->  [ok] - 剩余：300
# https://www.rockauto.com/en/parts/standard+motor+products,SC354,speed+sensor,10634  <->  [ok] - 剩余：299
# https://www.rockauto.com/en/parts/standard+motor+products,SC357,speed+sensor,10634  <->  [ok] - 剩余：298
# https://www.rockauto.com/en/parts/standard+motor+products,SC360,speed+sensor,10634  <->  [ok] - 剩余：297
# https://www.rockauto.com/en/parts/standard+motor+products,SC366,speed+sensor,10634  <->  [ok] - 剩余：296
# https://www.rockauto.com/en/parts/standard+motor+products,SC360T,speed+sensor,10634  <->  [ok] - 剩余：295
# https://www.rockauto.com/en/parts/standard+motor+products,SC369,speed+sensor,10634  <->  [ok] - 剩余：294
# https://www.rockauto.com/en/parts/standard+motor+products,SC361,speed+sensor,10634  <->  [ok] - 剩余：293
# https://www.rockauto.com/en/parts/standard+motor+products,SC335,speed+sensor,10634  <->  [ok] - 剩余：292
# https://www.rockauto.com/en/parts/standard+motor+products,SC368,speed+sensor,10634  <->  [ok] - 剩余：291
# https://www.rockauto.com/en/parts/standard+motor+products,SC37,speed+sensor,10634  <->  [ok] - 剩余：290
# https://www.rockauto.com/en/parts/standard+motor+products,SC370,speed+sensor,10634  <->  [ok] - 剩余：289
# https://www.rockauto.com/en/parts/standard+motor+products,SC372,speed+sensor,10634  <->  [ok] - 剩余：288
# https://www.rockauto.com/en/parts/standard+motor+products,SC359,speed+sensor,10634  <->  [ok] - 剩余：287
# https://www.rockauto.com/en/parts/standard+motor+products,SC374,speed+sensor,10634  <->  [ok] - 剩余：286
# https://www.rockauto.com/en/parts/standard+motor+products,SC374T,speed+sensor,10634  <->  [ok] - 剩余：285
# https://www.rockauto.com/en/parts/standard+motor+products,SC378,speed+sensor,10634  <->  [ok] - 剩余：284
# https://www.rockauto.com/en/parts/standard+motor+products,SC373,speed+sensor,10634  <->  [ok] - 剩余：283
# https://www.rockauto.com/en/parts/standard+motor+products,SC379,speed+sensor,10634  <->  [ok] - 剩余：282
# https://www.rockauto.com/en/parts/standard+motor+products,SC381,speed+sensor,10634  <->  [ok] - 剩余：281
# https://www.rockauto.com/en/parts/standard+motor+products,SC37T,speed+sensor,10634  <->  [ok] - 剩余：280
# https://www.rockauto.com/en/parts/standard+motor+products,SC382,speed+sensor,10634  <->  [ok] - 剩余：279
# https://www.rockauto.com/en/parts/standard+motor+products,SC389,speed+sensor,10634  <->  [ok] - 剩余：278
# https://www.rockauto.com/en/parts/standard+motor+products,SC386,speed+sensor,10634  <->  [ok] - 剩余：277
# https://www.rockauto.com/en/parts/standard+motor+products,SC39,speed+sensor,10634  <->  [ok] - 剩余：276
# https://www.rockauto.com/en/parts/standard+motor+products,SC394,speed+sensor,10634  <->  [ok] - 剩余：275
# https://www.rockauto.com/en/parts/standard+motor+products,SC390,speed+sensor,10634  <->  [ok] - 剩余：274
# https://www.rockauto.com/en/parts/standard+motor+products,SC396,speed+sensor,10634  <->  [ok] - 剩余：273
# https://www.rockauto.com/en/parts/standard+motor+products,SC395,speed+sensor,10634  <->  [ok] - 剩余：272
# https://www.rockauto.com/en/parts/standard+motor+products,SC402,speed+sensor,10634  <->  [ok] - 剩余：271
# https://www.rockauto.com/en/parts/standard+motor+products,SC377,speed+sensor,10634  <->  [ok] - 剩余：270
# https://www.rockauto.com/en/parts/standard+motor+products,SC404,speed+sensor,10634  <->  [ok] - 剩余：269
# https://www.rockauto.com/en/parts/standard+motor+products,SC403,speed+sensor,10634  <->  [ok] - 剩余：268
# https://www.rockauto.com/en/parts/standard+motor+products,SC398,speed+sensor,10634  <->  [ok] - 剩余：267
# https://www.rockauto.com/en/parts/standard+motor+products,SC401,speed+sensor,10634  <->  [ok] - 剩余：266
# https://www.rockauto.com/en/parts/standard+motor+products,SC405,speed+sensor,10634  <->  [ok] - 剩余：265
# https://www.rockauto.com/en/parts/standard+motor+products,SC406,speed+sensor,10634  <->  [ok] - 剩余：264
# https://www.rockauto.com/en/parts/standard+motor+products,SC399,speed+sensor,10634  <->  [ok] - 剩余：263
# https://www.rockauto.com/en/parts/standard+motor+products,SC411,speed+sensor,10634  <->  [ok] - 剩余：262
# https://www.rockauto.com/en/parts/standard+motor+products,SC41,speed+sensor,10634  <->  [ok] - 剩余：261
# https://www.rockauto.com/en/parts/standard+motor+products,SC42,speed+sensor,10634  <->  [ok] - 剩余：260
# https://www.rockauto.com/en/parts/standard+motor+products,SC417,speed+sensor,10634  <->  [ok] - 剩余：259
# https://www.rockauto.com/en/parts/standard+motor+products,SC413,speed+sensor,10634  <->  [ok] - 剩余：258
# https://www.rockauto.com/en/parts/standard+motor+products,SC414,speed+sensor,10634  <->  [ok] - 剩余：257
# https://www.rockauto.com/en/parts/standard+motor+products,SC214,speed+sensor,10634  <->  [ok] - 剩余：256
# https://www.rockauto.com/en/parts/standard+motor+products,SC358,speed+sensor,10634  <->  [ok] - 剩余：255
# https://www.rockauto.com/en/parts/standard+motor+products,SC420,speed+sensor,10634  <->  [ok] - 剩余：254
# https://www.rockauto.com/en/parts/standard+motor+products,SC387,speed+sensor,10634  <->  [ok] - 剩余：253
# https://www.rockauto.com/en/parts/standard+motor+products,SC421,speed+sensor,10634  <->  [ok] - 剩余：252
# https://www.rockauto.com/en/parts/standard+motor+products,SC422,speed+sensor,10634  <->  [ok] - 剩余：251
# https://www.rockauto.com/en/parts/standard+motor+products,SC425,speed+sensor,10634  <->  [ok] - 剩余：250
# https://www.rockauto.com/en/parts/standard+motor+products,SC435,speed+sensor,10634  <->  [ok] - 剩余：249
# https://www.rockauto.com/en/parts/standard+motor+products,SC426,speed+sensor,10634  <->  [ok] - 剩余：248
# https://www.rockauto.com/en/parts/standard+motor+products,SC429,speed+sensor,10634  <->  [ok] - 剩余：247
# https://www.rockauto.com/en/parts/standard+motor+products,SC439,speed+sensor,10634  <->  [ok] - 剩余：246
# https://www.rockauto.com/en/parts/standard+motor+products,SC440,speed+sensor,10634  <->  [ok] - 剩余：245
# https://www.rockauto.com/en/parts/standard+motor+products,SC427,speed+sensor,10634  <->  [ok] - 剩余：244
# https://www.rockauto.com/en/parts/standard+motor+products,SC441,speed+sensor,10634  <->  [ok] - 剩余：243
# https://www.rockauto.com/en/parts/standard+motor+products,SC442,speed+sensor,10634  <->  [ok] - 剩余：242
# https://www.rockauto.com/en/parts/standard+motor+products,SC438,speed+sensor,10634  <->  [ok] - 剩余：241
# https://www.rockauto.com/en/parts/standard+motor+products,SC433,speed+sensor,10634  <->  [ok] - 剩余：240
# https://www.rockauto.com/en/parts/standard+motor+products,SC445,speed+sensor,10634  <->  [ok] - 剩余：239
# https://www.rockauto.com/en/parts/standard+motor+products,SC443,speed+sensor,10634  <->  [ok] - 剩余：238
# https://www.rockauto.com/en/parts/standard+motor+products,SC458,speed+sensor,10634  <->  [ok] - 剩余：237
# https://www.rockauto.com/en/parts/standard+motor+products,SC454,speed+sensor,10634  <->  [ok] - 剩余：236
# https://www.rockauto.com/en/parts/standard+motor+products,SC460,speed+sensor,10634  <->  [ok] - 剩余：235
# https://www.rockauto.com/en/parts/standard+motor+products,SC461,speed+sensor,10634  <->  [ok] - 剩余：234
# https://www.rockauto.com/en/parts/standard+motor+products,SC469,speed+sensor,10634  <->  [ok] - 剩余：233
# https://www.rockauto.com/en/parts/standard+motor+products,SC46,speed+sensor,10634  <->  [ok] - 剩余：232
# https://www.rockauto.com/en/parts/standard+motor+products,SC463,speed+sensor,10634  <->  [ok] - 剩余：231
# https://www.rockauto.com/en/parts/standard+motor+products,SC455,speed+sensor,10634  <->  [ok] - 剩余：230
# https://www.rockauto.com/en/parts/standard+motor+products,SC46T,speed+sensor,10634  <->  [ok] - 剩余：229
# https://www.rockauto.com/en/parts/standard+motor+products,SC468,speed+sensor,10634  <->  [ok] - 剩余：228
# https://www.rockauto.com/en/parts/standard+motor+products,SC467,speed+sensor,10634  <->  [ok] - 剩余：227
# https://www.rockauto.com/en/parts/standard+motor+products,SC476,speed+sensor,10634  <->  [ok] - 剩余：226
# https://www.rockauto.com/en/parts/standard+motor+products,SC470,speed+sensor,10634  <->  [ok] - 剩余：225
# https://www.rockauto.com/en/parts/standard+motor+products,SC477,speed+sensor,10634  <->  [ok] - 剩余：224
# https://www.rockauto.com/en/parts/standard+motor+products,SC450,speed+sensor,10634  <->  [ok] - 剩余：223
# https://www.rockauto.com/en/parts/standard+motor+products,SC478,speed+sensor,10634  <->  [ok] - 剩余：222
# https://www.rockauto.com/en/parts/standard+motor+products,SC479,speed+sensor,10634  <->  [ok] - 剩余：221
# https://www.rockauto.com/en/parts/standard+motor+products,SC474,speed+sensor,10634  <->  [ok] - 剩余：220
# https://www.rockauto.com/en/parts/standard+motor+products,SC472,speed+sensor,10634  <->  [ok] - 剩余：219
# https://www.rockauto.com/en/parts/standard+motor+products,SC481,speed+sensor,10634  <->  [ok] - 剩余：218
# https://www.rockauto.com/en/parts/standard+motor+products,SC482,speed+sensor,10634  <->  [ok] - 剩余：217
# https://www.rockauto.com/en/parts/standard+motor+products,SC485,speed+sensor,10634  <->  [ok] - 剩余：216
# https://www.rockauto.com/en/parts/standard+motor+products,SC473,speed+sensor,10634  <->  [ok] - 剩余：215
# https://www.rockauto.com/en/parts/standard+motor+products,SC471,speed+sensor,10634  <->  [ok] - 剩余：214
# https://www.rockauto.com/en/parts/standard+motor+products,SC484,speed+sensor,10634  <->  [ok] - 剩余：213
# https://www.rockauto.com/en/parts/standard+motor+products,SC487,speed+sensor,10634  <->  [ok] - 剩余：212
# https://www.rockauto.com/en/parts/standard+motor+products,SC493,speed+sensor,10634  <->  [ok] - 剩余：211
# https://www.rockauto.com/en/parts/standard+motor+products,SC495,speed+sensor,10634  <->  [ok] - 剩余：210
# https://www.rockauto.com/en/parts/standard+motor+products,SC500,speed+sensor,10634  <->  [ok] - 剩余：209
# https://www.rockauto.com/en/parts/standard+motor+products,SC498,speed+sensor,10634  <->  [ok] - 剩余：208
# https://www.rockauto.com/en/parts/standard+motor+products,SC5,speed+sensor,10634  <->  [ok] - 剩余：207
# https://www.rockauto.com/en/parts/standard+motor+products,SC502,speed+sensor,10634  <->  [ok] - 剩余：206
# https://www.rockauto.com/en/parts/standard+motor+products,SC459,speed+sensor,10634  <->  [ok] - 剩余：205
# https://www.rockauto.com/en/parts/standard+motor+products,SC504,speed+sensor,10634  <->  [ok] - 剩余：204
# https://www.rockauto.com/en/parts/standard+motor+products,SC490,speed+sensor,10634  <->  [ok] - 剩余：203
# https://www.rockauto.com/en/parts/standard+motor+products,SC494,speed+sensor,10634  <->  [ok] - 剩余：202
# https://www.rockauto.com/en/parts/standard+motor+products,SC505,speed+sensor,10634  <->  [ok] - 剩余：201
# https://www.rockauto.com/en/parts/standard+motor+products,SC510,speed+sensor,10634  <->  [ok] - 剩余：200
# https://www.rockauto.com/en/parts/standard+motor+products,SC513,speed+sensor,10634  <->  [ok] - 剩余：199
# https://www.rockauto.com/en/parts/standard+motor+products,SC508,speed+sensor,10634  <->  [ok] - 剩余：198
# https://www.rockauto.com/en/parts/standard+motor+products,SC491,speed+sensor,10634  <->  [ok] - 剩余：197
# https://www.rockauto.com/en/parts/standard+motor+products,SC501,speed+sensor,10634  <->  [ok] - 剩余：196
# https://www.rockauto.com/en/parts/standard+motor+products,SC507,speed+sensor,10634  <->  [ok] - 剩余：195
# https://www.rockauto.com/en/parts/standard+motor+products,SC503,speed+sensor,10634  <->  [ok] - 剩余：194
# https://www.rockauto.com/en/parts/standard+motor+products,SC489,speed+sensor,10634  <->  [ok] - 剩余：193
# https://www.rockauto.com/en/parts/standard+motor+products,SC517,speed+sensor,10634  <->  [ok] - 剩余：192
# https://www.rockauto.com/en/parts/standard+motor+products,SC521,speed+sensor,10634  <->  [ok] - 剩余：191
# https://www.rockauto.com/en/parts/standard+motor+products,SC52,speed+sensor,10634  <->  [ok] - 剩余：190
# https://www.rockauto.com/en/parts/standard+motor+products,SC518,speed+sensor,10634  <->  [ok] - 剩余：189
# https://www.rockauto.com/en/parts/standard+motor+products,SC506,speed+sensor,10634  <->  [ok] - 剩余：188
# https://www.rockauto.com/en/parts/standard+motor+products,SC486,speed+sensor,10634  <->  [ok] - 剩余：187
# https://www.rockauto.com/en/parts/standard+motor+products,SC525,speed+sensor,10634  <->  [ok] - 剩余：186
# https://www.rockauto.com/en/parts/standard+motor+products,SC516,speed+sensor,10634  <->  [ok] - 剩余：185
# https://www.rockauto.com/en/parts/standard+motor+products,SC534,speed+sensor,10634  <->  [ok] - 剩余：184
# https://www.rockauto.com/en/parts/standard+motor+products,SC524,speed+sensor,10634  <->  [ok] - 剩余：183
# https://www.rockauto.com/en/parts/standard+motor+products,SC536,speed+sensor,10634  <->  [ok] - 剩余：182
# https://www.rockauto.com/en/parts/standard+motor+products,SC539,speed+sensor,10634  <->  [ok] - 剩余：181
# https://www.rockauto.com/en/parts/standard+motor+products,SC533,speed+sensor,10634  <->  [ok] - 剩余：180
# https://www.rockauto.com/en/parts/standard+motor+products,SC522,speed+sensor,10634  <->  [ok] - 剩余：179
# https://www.rockauto.com/en/parts/standard+motor+products,SC544,speed+sensor,10634  <->  [ok] - 剩余：178
# https://www.rockauto.com/en/parts/standard+motor+products,SC523,speed+sensor,10634  <->  [ok] - 剩余：177
# https://www.rockauto.com/en/parts/standard+motor+products,SC535,speed+sensor,10634  <->  [ok] - 剩余：176
# https://www.rockauto.com/en/parts/standard+motor+products,SC541,speed+sensor,10634  <->  [ok] - 剩余：175
# https://www.rockauto.com/en/parts/standard+motor+products,SC545,speed+sensor,10634  <->  [ok] - 剩余：174
# https://www.rockauto.com/en/parts/standard+motor+products,SC552,speed+sensor,10634  <->  [ok] - 剩余：173
# https://www.rockauto.com/en/parts/standard+motor+products,SC548,speed+sensor,10634  <->  [ok] - 剩余：172
# https://www.rockauto.com/en/parts/standard+motor+products,SC515,speed+sensor,10634  <->  [ok] - 剩余：171
# https://www.rockauto.com/en/parts/standard+motor+products,SC538,speed+sensor,10634  <->  [ok] - 剩余：170
# https://www.rockauto.com/en/parts/standard+motor+products,SC554,speed+sensor,10634  <->  [ok] - 剩余：169
# https://www.rockauto.com/en/parts/standard+motor+products,SC532,speed+sensor,10634  <->  [ok] - 剩余：168
# https://www.rockauto.com/en/parts/standard+motor+products,SC555,speed+sensor,10634  <->  [ok] - 剩余：167
# https://www.rockauto.com/en/parts/standard+motor+products,SC556,speed+sensor,10634  <->  [ok] - 剩余：166
# https://www.rockauto.com/en/parts/standard+motor+products,SC561,speed+sensor,10634  <->  [ok] - 剩余：165
# https://www.rockauto.com/en/parts/standard+motor+products,SC57,speed+sensor,10634  <->  [ok] - 剩余：164
# https://www.rockauto.com/en/parts/standard+motor+products,SC570,speed+sensor,10634  <->  [ok] - 剩余：163
# https://www.rockauto.com/en/parts/standard+motor+products,SC568,speed+sensor,10634  <->  [ok] - 剩余：162
# https://www.rockauto.com/en/parts/standard+motor+products,SC577,speed+sensor,10634  <->  [ok] - 剩余：161
# https://www.rockauto.com/en/parts/standard+motor+products,SC579,speed+sensor,10634  <->  [ok] - 剩余：160
# https://www.rockauto.com/en/parts/standard+motor+products,SC529,speed+sensor,10634  <->  [ok] - 剩余：159
# https://www.rockauto.com/en/parts/standard+motor+products,SC569,speed+sensor,10634  <->  [ok] - 剩余：158
# https://www.rockauto.com/en/parts/standard+motor+products,SC56,speed+sensor,10634  <->  [ok] - 剩余：157
# https://www.rockauto.com/en/parts/standard+motor+products,SC582,speed+sensor,10634  <->  [ok] - 剩余：156
# https://www.rockauto.com/en/parts/standard+motor+products,SC586,speed+sensor,10634  <->  [ok] - 剩余：155
# https://www.rockauto.com/en/parts/standard+motor+products,SC580,speed+sensor,10634  <->  [ok] - 剩余：154
# https://www.rockauto.com/en/parts/standard+motor+products,SC560,speed+sensor,10634  <->  [ok] - 剩余：153
# https://www.rockauto.com/en/parts/standard+motor+products,SC589,speed+sensor,10634  <->  [ok] - 剩余：152
# https://www.rockauto.com/en/parts/standard+motor+products,SC59,speed+sensor,10634  <->  [ok] - 剩余：151
# https://www.rockauto.com/en/parts/standard+motor+products,SC587,speed+sensor,10634  <->  [ok] - 剩余：150
# https://www.rockauto.com/en/parts/standard+motor+products,SC546,speed+sensor,10634  <->  [ok] - 剩余：149
# https://www.rockauto.com/en/parts/standard+motor+products,SC584,speed+sensor,10634  <->  [ok] - 剩余：148
# https://www.rockauto.com/en/parts/standard+motor+products,SC592,speed+sensor,10634  <->  [ok] - 剩余：147
# https://www.rockauto.com/en/parts/standard+motor+products,SC591,speed+sensor,10634  <->  [ok] - 剩余：146
# https://www.rockauto.com/en/parts/standard+motor+products,SC593,speed+sensor,10634  <->  [ok] - 剩余：145
# https://www.rockauto.com/en/parts/standard+motor+products,SC590,speed+sensor,10634  <->  [ok] - 剩余：144
# https://www.rockauto.com/en/parts/standard+motor+products,SC597,speed+sensor,10634  <->  [ok] - 剩余：143
# https://www.rockauto.com/en/parts/standard+motor+products,SC596,speed+sensor,10634  <->  [ok] - 剩余：142
# https://www.rockauto.com/en/parts/standard+motor+products,SC60,speed+sensor,10634  <->  [ok] - 剩余：141
# https://www.rockauto.com/en/parts/standard+motor+products,SC601,speed+sensor,10634  <->  [ok] - 剩余：140
# https://www.rockauto.com/en/parts/standard+motor+products,SC598,speed+sensor,10634  <->  [ok] - 剩余：139
# https://www.rockauto.com/en/parts/standard+motor+products,SC602,speed+sensor,10634  <->  [ok] - 剩余：138
# https://www.rockauto.com/en/parts/standard+motor+products,SC607,speed+sensor,10634  <->  [ok] - 剩余：137
# https://www.rockauto.com/en/parts/standard+motor+products,SC609,speed+sensor,10634  <->  [ok] - 剩余：136
# https://www.rockauto.com/en/parts/standard+motor+products,SC61,speed+sensor,10634  <->  [ok] - 剩余：135
# https://www.rockauto.com/en/parts/standard+motor+products,SC594,speed+sensor,10634  <->  [ok] - 剩余：134
# https://www.rockauto.com/en/parts/standard+motor+products,SC608,speed+sensor,10634  <->  [ok] - 剩余：133
# https://www.rockauto.com/en/parts/standard+motor+products,SC599,speed+sensor,10634  <->  [ok] - 剩余：132
# https://www.rockauto.com/en/parts/standard+motor+products,SC613,speed+sensor,10634  <->  [ok] - 剩余：131
# https://www.rockauto.com/en/parts/standard+motor+products,SC628,speed+sensor,10634  <->  [ok] - 剩余：130
# https://www.rockauto.com/en/parts/standard+motor+products,SC415,speed+sensor,10634  <->  [ok] - 剩余：129
# https://www.rockauto.com/en/parts/standard+motor+products,SC631,speed+sensor,10634  <->  [ok] - 剩余：128
# https://www.rockauto.com/en/parts/standard+motor+products,SC622,speed+sensor,10634  <->  [ok] - 剩余：127
# https://www.rockauto.com/en/parts/standard+motor+products,SC615,speed+sensor,10634  <->  [ok] - 剩余：126
# https://www.rockauto.com/en/parts/standard+motor+products,SC595,speed+sensor,10634  <->  [ok] - 剩余：125
# https://www.rockauto.com/en/parts/standard+motor+products,SC612,speed+sensor,10634  <->  [ok] - 剩余：124
# https://www.rockauto.com/en/parts/standard+motor+products,SC632,speed+sensor,10634  <->  [ok] - 剩余：123
# https://www.rockauto.com/en/parts/standard+motor+products,SC603,speed+sensor,10634  <->  [ok] - 剩余：122
# https://www.rockauto.com/en/parts/standard+motor+products,SC616,speed+sensor,10634  <->  [ok] - 剩余：121
# https://www.rockauto.com/en/parts/standard+motor+products,SC637,speed+sensor,10634  <->  [ok] - 剩余：120
# https://www.rockauto.com/en/parts/standard+motor+products,SC633,speed+sensor,10634  <->  [ok] - 剩余：119
# https://www.rockauto.com/en/parts/standard+motor+products,SC642,speed+sensor,10634  <->  [ok] - 剩余：118
# https://www.rockauto.com/en/parts/standard+motor+products,SC64,speed+sensor,10634  <->  [ok] - 剩余：117
# https://www.rockauto.com/en/parts/standard+motor+products,SC644,speed+sensor,10634  <->  [ok] - 剩余：116
# https://www.rockauto.com/en/parts/standard+motor+products,SC647,speed+sensor,10634  <->  [ok] - 剩余：115
# https://www.rockauto.com/en/parts/standard+motor+products,SC651,speed+sensor,10634  <->  [ok] - 剩余：114
# https://www.rockauto.com/en/parts/standard+motor+products,SC65,speed+sensor,10634  <->  [ok] - 剩余：113
# https://www.rockauto.com/en/parts/standard+motor+products,SC650,speed+sensor,10634  <->  [ok] - 剩余：112
# https://www.rockauto.com/en/parts/standard+motor+products,SC653,speed+sensor,10634  <->  [ok] - 剩余：111
# https://www.rockauto.com/en/parts/standard+motor+products,SC654,speed+sensor,10634  <->  [ok] - 剩余：110
# https://www.rockauto.com/en/parts/standard+motor+products,SC655,speed+sensor,10634  <->  [ok] - 剩余：109
# https://www.rockauto.com/en/parts/standard+motor+products,SC656,speed+sensor,10634  <->  [ok] - 剩余：108
# https://www.rockauto.com/en/parts/standard+motor+products,SC638,speed+sensor,10634  <->  [ok] - 剩余：107
# https://www.rockauto.com/en/parts/standard+motor+products,SC658,speed+sensor,10634  <->  [ok] - 剩余：106
# https://www.rockauto.com/en/parts/standard+motor+products,SC66,speed+sensor,10634  <->  [ok] - 剩余：105
# https://www.rockauto.com/en/parts/standard+motor+products,SC657,speed+sensor,10634  <->  [ok] - 剩余：104
# https://www.rockauto.com/en/parts/standard+motor+products,SC664,speed+sensor,10634  <->  [ok] - 剩余：103
# https://www.rockauto.com/en/parts/standard+motor+products,SC666,speed+sensor,10634  <->  [ok] - 剩余：102
# https://www.rockauto.com/en/parts/standard+motor+products,SC669,speed+sensor,10634  <->  [ok] - 剩余：101
# https://www.rockauto.com/en/parts/standard+motor+products,SC67,speed+sensor,10634  <->  [ok] - 剩余：100
# https://www.rockauto.com/en/parts/standard+motor+products,SC635,speed+sensor,10634  <->  [ok] - 剩余：99
# https://www.rockauto.com/en/parts/standard+motor+products,SC673,speed+sensor,10634  <->  [ok] - 剩余：98
# https://www.rockauto.com/en/parts/standard+motor+products,SC585,speed+sensor,10634  <->  [ok] - 剩余：97
# https://www.rockauto.com/en/parts/standard+motor+products,SC634,speed+sensor,10634  <->  [ok] - 剩余：96
# https://www.rockauto.com/en/parts/standard+motor+products,SC678,speed+sensor,10634  <->  [ok] - 剩余：95
# https://www.rockauto.com/en/parts/standard+motor+products,SC68,speed+sensor,10634  <->  [ok] - 剩余：94
# https://www.rockauto.com/en/parts/standard+motor+products,SC680,speed+sensor,10634  <->  [ok] - 剩余：93
# https://www.rockauto.com/en/parts/standard+motor+products,SC659,speed+sensor,10634  <->  [ok] - 剩余：92
# https://www.rockauto.com/en/parts/standard+motor+products,SC686,speed+sensor,10634  <->  [ok] - 剩余：91
# https://www.rockauto.com/en/parts/standard+motor+products,SC681,speed+sensor,10634  <->  [ok] - 剩余：90
# https://www.rockauto.com/en/parts/standard+motor+products,SC687,speed+sensor,10634  <->  [ok] - 剩余：89
# https://www.rockauto.com/en/parts/standard+motor+products,SC688,speed+sensor,10634  <->  [ok] - 剩余：88
# https://www.rockauto.com/en/parts/standard+motor+products,SC630,speed+sensor,10634  <->  [ok] - 剩余：87
# https://www.rockauto.com/en/parts/standard+motor+products,SC689,speed+sensor,10634  <->  [ok] - 剩余：86
# https://www.rockauto.com/en/parts/standard+motor+products,SC69,speed+sensor,10634  <->  [ok] - 剩余：85
# https://www.rockauto.com/en/parts/standard+motor+products,SC695,speed+sensor,10634  <->  [ok] - 剩余：84
# https://www.rockauto.com/en/parts/standard+motor+products,SC690,speed+sensor,10634  <->  [ok] - 剩余：83
# https://www.rockauto.com/en/parts/standard+motor+products,SC697,speed+sensor,10634  <->  [ok] - 剩余：82
# https://www.rockauto.com/en/parts/standard+motor+products,SC641,speed+sensor,10634  <->  [ok] - 剩余：81
# https://www.rockauto.com/en/parts/standard+motor+products,SC692,speed+sensor,10634  <->  [ok] - 剩余：80
# https://www.rockauto.com/en/parts/standard+motor+products,SC693,speed+sensor,10634  <->  [ok] - 剩余：79
# https://www.rockauto.com/en/parts/standard+motor+products,SC671,speed+sensor,10634  <->  [ok] - 剩余：78
# https://www.rockauto.com/en/parts/standard+motor+products,SC705,speed+sensor,10634  <->  [ok] - 剩余：77
# https://www.rockauto.com/en/parts/standard+motor+products,SC714,speed+sensor,10634  <->  [ok] - 剩余：76
# https://www.rockauto.com/en/parts/standard+motor+products,SC679,speed+sensor,10634  <->  [ok] - 剩余：75
# https://www.rockauto.com/en/parts/standard+motor+products,SC71,speed+sensor,10634  <->  [ok] - 剩余：74
# https://www.rockauto.com/en/parts/standard+motor+products,SC711,speed+sensor,10634  <->  [ok] - 剩余：73
# https://www.rockauto.com/en/parts/standard+motor+products,SC718,speed+sensor,10634  <->  [ok] - 剩余：72
# https://www.rockauto.com/en/parts/standard+motor+products,SC708,speed+sensor,10634  <->  [ok] - 剩余：71
# https://www.rockauto.com/en/parts/standard+motor+products,SC719,speed+sensor,10634  <->  [ok] - 剩余：70
# https://www.rockauto.com/en/parts/standard+motor+products,SC684,speed+sensor,10634  <->  [ok] - 剩余：69
# https://www.rockauto.com/en/parts/standard+motor+products,SC710,speed+sensor,10634  <->  [ok] - 剩余：68
# https://www.rockauto.com/en/parts/standard+motor+products,SC696,speed+sensor,10634  <->  [ok] - 剩余：67
# https://www.rockauto.com/en/parts/standard+motor+products,SC713,speed+sensor,10634  <->  [ok] - 剩余：66
# https://www.rockauto.com/en/parts/standard+motor+products,SC722,speed+sensor,10634  <->  [ok] - 剩余：65
# https://www.rockauto.com/en/parts/standard+motor+products,SC723,speed+sensor,10634  <->  [ok] - 剩余：64
# https://www.rockauto.com/en/parts/standard+motor+products,SC726,speed+sensor,10634  <->  [ok] - 剩余：63
# https://www.rockauto.com/en/parts/standard+motor+products,SC725,speed+sensor,10634  <->  [ok] - 剩余：62
# https://www.rockauto.com/en/parts/standard+motor+products,SC734,speed+sensor,10634  <->  [ok] - 剩余：61
# https://www.rockauto.com/en/parts/standard+motor+products,SC738,speed+sensor,10634  <->  [ok] - 剩余：60
# https://www.rockauto.com/en/parts/standard+motor+products,SC736,speed+sensor,10634  <->  [ok] - 剩余：59
# https://www.rockauto.com/en/parts/standard+motor+products,SC74,speed+sensor,10634  <->  [ok] - 剩余：58
# https://www.rockauto.com/en/parts/standard+motor+products,SC72,speed+sensor,10634  <->  [ok] - 剩余：57
# https://www.rockauto.com/en/parts/standard+motor+products,SC747,speed+sensor,10634  <->  [ok] - 剩余：56
# https://www.rockauto.com/en/parts/standard+motor+products,SC748,speed+sensor,10634  <->  [ok] - 剩余：55
# https://www.rockauto.com/en/parts/standard+motor+products,SC731,speed+sensor,10634  <->  [ok] - 剩余：54
# https://www.rockauto.com/en/parts/standard+motor+products,SC743,speed+sensor,10634  <->  [ok] - 剩余：53
# https://www.rockauto.com/en/parts/standard+motor+products,SC724,speed+sensor,10634  <->  [ok] - 剩余：52
# https://www.rockauto.com/en/parts/standard+motor+products,SC733,speed+sensor,10634  <->  [ok] - 剩余：51
# https://www.rockauto.com/en/parts/standard+motor+products,SC727,speed+sensor,10634  <->  [ok] - 剩余：50
# https://www.rockauto.com/en/parts/standard+motor+products,SC750,speed+sensor,10634  <->  [ok] - 剩余：49
# https://www.rockauto.com/en/parts/standard+motor+products,SC749,speed+sensor,10634  <->  [ok] - 剩余：48
# https://www.rockauto.com/en/parts/standard+motor+products,SC760,speed+sensor,10634  <->  [ok] - 剩余：47
# https://www.rockauto.com/en/parts/standard+motor+products,SC740,speed+sensor,10634  <->  [ok] - 剩余：46
# https://www.rockauto.com/en/parts/standard+motor+products,SC755,speed+sensor,10634  <->  [ok] - 剩余：45
# https://www.rockauto.com/en/parts/standard+motor+products,SC761,speed+sensor,10634  <->  [ok] - 剩余：44
# https://www.rockauto.com/en/parts/standard+motor+products,SC763,speed+sensor,10634  <->  [ok] - 剩余：43
# https://www.rockauto.com/en/parts/standard+motor+products,SC754,speed+sensor,10634  <->  [ok] - 剩余：42
# https://www.rockauto.com/en/parts/standard+motor+products,SC77,speed+sensor,10634  <->  [ok] - 剩余：41
# https://www.rockauto.com/en/parts/standard+motor+products,SC771,speed+sensor,10634  <->  [ok] - 剩余：40
# https://www.rockauto.com/en/parts/standard+motor+products,SC772,speed+sensor,10634  <->  [ok] - 剩余：39
# https://www.rockauto.com/en/parts/standard+motor+products,SC779,speed+sensor,10634  <->  [ok] - 剩余：38
# https://www.rockauto.com/en/parts/standard+motor+products,SC75,speed+sensor,10634  <->  [ok] - 剩余：37
# https://www.rockauto.com/en/parts/standard+motor+products,SC782,speed+sensor,10634  <->  [ok] - 剩余：36
# https://www.rockauto.com/en/parts/standard+motor+products,SC774,speed+sensor,10634  <->  [ok] - 剩余：35
# https://www.rockauto.com/en/parts/standard+motor+products,SC677,speed+sensor,10634  <->  [ok] - 剩余：34
# https://www.rockauto.com/en/parts/standard+motor+products,SC792,speed+sensor,10634  <->  [ok] - 剩余：33
# https://www.rockauto.com/en/parts/standard+motor+products,SC791,speed+sensor,10634  <->  [ok] - 剩余：32
# https://www.rockauto.com/en/parts/standard+motor+products,SC796,speed+sensor,10634  <->  [ok] - 剩余：31
# https://www.rockauto.com/en/parts/standard+motor+products,SC793,speed+sensor,10634  <->  [ok] - 剩余：30
# https://www.rockauto.com/en/parts/standard+motor+products,SC790,speed+sensor,10634  <->  [ok] - 剩余：29
# https://www.rockauto.com/en/parts/standard+motor+products,SC798,speed+sensor,10634  <->  [ok] - 剩余：28
# https://www.rockauto.com/en/parts/standard+motor+products,SC797,speed+sensor,10634  <->  [ok] - 剩余：27
# https://www.rockauto.com/en/parts/standard+motor+products,SC794,speed+sensor,10634  <->  [ok] - 剩余：26
# https://www.rockauto.com/en/parts/standard+motor+products,SC76,speed+sensor,10634  <->  [ok] - 剩余：25
# https://www.rockauto.com/en/parts/standard+motor+products,SC802,speed+sensor,10634  <->  [ok] - 剩余：24
# https://www.rockauto.com/en/parts/standard+motor+products,SC799,speed+sensor,10634  <->  [ok] - 剩余：23
# https://www.rockauto.com/en/parts/standard+motor+products,SC730,speed+sensor,10634  <->  [ok] - 剩余：22
# https://www.rockauto.com/en/parts/standard+motor+products,SC805,speed+sensor,10634  <->  [ok] - 剩余：21
# https://www.rockauto.com/en/parts/standard+motor+products,SC803,speed+sensor,10634  <->  [ok] - 剩余：20
# https://www.rockauto.com/en/parts/standard+motor+products,SC807,speed+sensor,10634  <->  [ok] - 剩余：19
# https://www.rockauto.com/en/parts/standard+motor+products,SC809,speed+sensor,10634  <->  [ok] - 剩余：18
# https://www.rockauto.com/en/parts/standard+motor+products,SC808,speed+sensor,10634  <->  [ok] - 剩余：17
# https://www.rockauto.com/en/parts/standard+motor+products,SC815,speed+sensor,10634  <->  [ok] - 剩余：16
# https://www.rockauto.com/en/parts/standard+motor+products,SC814,speed+sensor,10634  <->  [ok] - 剩余：15
# https://www.rockauto.com/en/parts/standard+motor+products,SC804,speed+sensor,10634  <->  [ok] - 剩余：14
# https://www.rockauto.com/en/parts/standard+motor+products,SC817,speed+sensor,10634  <->  [ok] - 剩余：13
# https://www.rockauto.com/en/parts/standard+motor+products,SC801,speed+sensor,10634  <->  [ok] - 剩余：12
# https://www.rockauto.com/en/parts/standard+motor+products,SC753,speed+sensor,10634  <->  [ok] - 剩余：11
# https://www.rockauto.com/en/parts/standard+motor+products,SC811,speed+sensor,10634  <->  [ok] - 剩余：10
# https://www.rockauto.com/en/parts/standard+motor+products,SC819,speed+sensor,10634  <->  [ok] - 剩余：9
# https://www.rockauto.com/en/parts/standard+motor+products,SC818,speed+sensor,10634  <->  [ok] - 剩余：8
# https://www.rockauto.com/en/parts/standard+motor+products,SC827,speed+sensor,10634  <->  [ok] - 剩余：7
# https://www.rockauto.com/en/parts/standard+motor+products,SC821,speed+sensor,10634  <->  [ok] - 剩余：6
# https://www.rockauto.com/en/parts/standard+motor+products,SC810,speed+sensor,10634  <->  [ok] - 剩余：5
# https://www.rockauto.com/en/parts/standard+motor+products,SC728,speed+sensor,10634  <->  [ok] - 剩余：4
# https://www.rockauto.com/en/parts/standard+motor+products,SC824,speed+sensor,10634  <->  [ok] - 剩余：3
# https://www.rockauto.com/en/parts/standard+motor+products,SC820,speed+sensor,10634  <->  [ok] - 剩余：2
# https://www.rockauto.com/en/parts/standard+motor+products,SC89,speed+sensor,10634  <->  [ok] - 剩余：1
# https://www.rockauto.com/en/parts/standard+motor+products,SC806,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC88,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC90,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC90T,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC84,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC83,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC97,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC9,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC99,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC89T,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC98,speed+sensor,10634  <->  [ok] - 剩余：0
# https://www.rockauto.com/en/parts/standard+motor+products,SC96,speed+sensor,10634  <->  [ok] - 剩余：0
#
# 搞定
