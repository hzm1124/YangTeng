# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

from IPython.display import clear_output
from datetime import datetime

# = = = = = = = = = = = = = = =

import os
import shutil

if os.path.exists('./file/6.vehicle'):
    shutil.rmtree('./file/6.vehicle')

os.makedirs('./file/6.vehicle')

# = = = = = = = = = = = = = = =

import pandas as pd

# = = = = = = = = = = = = = = =

import requests

import sys
sys.path.append('../00.Tools')
from crawler_configuration import get_header, get_proxy

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/4.auth'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

for file in list_file:
    
    # = = = = = = = = = = = = = = =

    output_correct, output_error = pd.DataFrame(), pd.DataFrame()

    # = = = = = = = = = = = = = = =

    input_ = pd.read_excel(f'./file/4.auth/{file}',
                           header=0,
                           dtype=str).fillna('')
    
    input_['No'] = input_['No'].astype(int)

    print(f'总数量：{len(input_)}')
    print()

    # = = = = = = = = = = = = = = =


    work = Queue()
    for a in range(len(input_)):
        work.put_nowait(a)

    # = = = = = = = = = = = = = = =

    def crawler():
        global output_correct, output_error

        while not work.empty():
            a = work.get_nowait()

            # = = = = = = = = = = = = = = =

            crawler_status = 'error'

            # = = = = = = = = = = = = = = =

            try:
                b = 0
                while True:
                    b += 1
                    
                    try:
                        resp = requests.get(f'''https://productdesk-api.cellacore.net/legacy/cardone/Vehicle/Recommendation/?q=(productSKU.keyword:{input_.loc[a, 'Part Number']})&size=5000&useCache=true&auth={input_.loc[a, 'Auth']}''',
                                            headers=get_header(),
                                            proxies=get_proxy(),
                                            timeout=(10, 10))

                        if resp.status_code == 200:
                            break
                    except KeyboardInterrupt:
                        break
                    except:
                        continue

                # = = = = = = = = = = = = = = =

                list_json = resp.json()

                # = = = = = = = = = = = = = = =

                list_make = [json_['fitment']['Vcdb']['MakeName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_model = [json_['fitment']['Vcdb']['ModelName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_region = [json_['fitment']['Vcdb']['RegionName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_submodel = [json_['fitment']['Vcdb']['SubModelName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_vehicle_type = [json_['fitment']['Vcdb']['VehicleTypeName'].strip() for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_year = [int(json_['fitment']['Vcdb']['Year'].strip()) for json_ in list_json]

                # = = = = = = = = = = = = = = =

                list_list_aspiration, list_list_cylinder, list_list_displacement, list_list_fuel, list_list_liter = [], [], [], [], []
                list_list_engine = [json_['fitment']['Vcdb']['Engines'] for json_ in list_json]
                for list_engine in list_list_engine:
                    if list_engine:
                        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [], [], [], [], []
                        for engine in list_engine:
                            list_aspiration.append(engine['AspirationName'].strip() if 'AspirationName' in engine and engine['AspirationName'].strip() != '-' else '')
                
                            # = = = = = = = = = = = = = = =
                            
                            cylinder = ''
                            if 'BlockType' in engine and engine['BlockType'].strip() != '-':
                                cylinder += engine['BlockType'].strip()
                            if 'Cylinders' in engine and engine['Cylinders'] != 0:
                                cylinder += str(engine['Cylinders'])
                            list_cylinder.append(cylinder)
                            
                            # = = = = = = = = = = = = = = =
                
                            displacement = ''
                            if engine['CID'].strip() != '-':
                                displacement += f'''{engine['CID'].strip()}cid'''
                            elif engine['CC'].strip() != '-':
                                displacement += f'''/{engine['CC'].strip()}cc'''
                            list_displacement.append(displacement.removeprefix('/'))
                            
                            # = = = = = = = = = = = = = = =
                
                            list_fuel.append(engine['FuelTypeName'].strip() if 'FuelTypeName' in engine else '')
                
                            # = = = = = = = = = = = = = = =
                
                            list_liter.append(f'''{engine['Liter']}L''' if 'Liter' in engine and engine['Liter'] != 0 else '')
                    else:
                        list_aspiration, list_cylinder, list_displacement, list_fuel, list_liter = [''], [''], [''], [''], ['']
                
                    list_list_aspiration.append(list_aspiration)
                    list_list_cylinder.append(list_cylinder)
                    list_list_displacement.append(list_displacement)
                    list_list_fuel.append(list_fuel)
                    list_list_liter.append(list_liter)
                    
                # = = = = = = = = = = = = = = =

                list_list_drive_type = []
                list_list_drive_type_2 = [json_['fitment']['Vcdb']['DriveTypes'] for json_ in list_json]
                for list_drive_type_2 in list_list_drive_type_2:
                    if list_drive_type_2:
                        list_drive_type = []
                        for drive_type_2 in list_drive_type_2:
                            list_drive_type.append(drive_type_2['DriveTypeName'].strip())
                    else:
                        list_drive_type = ['']
                
                    list_list_drive_type.append(list_drive_type)
                    
                # = = = = = = = = = = = = = = =

                list_position = [json_['fitment']['acesCriteria']['PositionName'].strip() if 'PositionName' in json_['fitment']['acesCriteria'] else '' for json_ in list_json]

                # = = = = = = = = = = = = = = =

                df_temp = pd.DataFrame()
                for i in range(len(list_json)):
                    df_temp_temp = pd.DataFrame({'No': input_.loc[a, 'No'],
                                                 'Part Number': input_.loc[a, 'Part Number'],
                                                 'Auth': input_.loc[a, 'Auth'],
                                                 'Vehicle Type': list_vehicle_type[i],
                                                 'Region': list_region[i],
                                                 'Make': list_make[i],
                                                 'Model': list_model[i],
                                                 'Submodel': list_submodel[i],
                                                 'Cylinder': list_list_cylinder[i],
                                                 'Displacement': list_list_displacement[i],
                                                 'Liter': list_list_liter[i],
                                                 'Year': list_year[i],
                                                 'Fuel': list_list_fuel[i],
                                                 'Aspiration': list_list_aspiration[i]})
                    for j in range(len(list_list_drive_type[i])):
                        df_temp_temp_temp = df_temp_temp.copy()
                        df_temp_temp_temp['Drive Type'] = list_list_drive_type[i][j]
                        df_temp_temp_temp['Position'] = list_position[i]
                        df_temp = pd.concat([df_temp, df_temp_temp_temp], ignore_index=True).fillna('')
                
                df_temp = df_temp.drop_duplicates(keep='first', ignore_index=True)
                df_temp = df_temp.sort_values(by=['Vehicle Type', 'Region', 'Make', 'Model', 'Submodel', 'Cylinder', 'Displacement', 'Liter', 'Year', 'Fuel', 'Aspiration', 'Drive Type', 'Position'],
                                              ascending=[True, True, True, True, True, True, True, True, False, True, True, True, True],
                                              ignore_index=True)
                
                df_temp['Row'] = [i+1 for i in range(len(df_temp))]
                
                output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

                # = = = = = = = = = = = = = = =

                crawler_status = 'ok'
            except:
                output_error = pd.concat([output_error, pd.DataFrame([input_.iloc[a]]).reset_index(drop=True)], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            if list_file.index(file) % 3 == 0 and list_file.index(file) != 0 and work.qsize() == 0 or work.qsize() % 1_000 == 0 and work.qsize() != 0:
                clear_output()

            print(f'''[状态：{crawler_status}，尝试次数：{b}] - {(list_file.index(file) + 1) / len(list_file) * 100:.2f}% - {file.removesuffix('.xlsx')} > {input_.loc[a, 'No']}.{input_.loc[a, 'Part Number']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

    # = = = = = = = = = = = = = = =

    list_task = []
    for _ in range(15):
        task = gevent.spawn(crawler)
        list_task.append(task)
    gevent.joinall(list_task)

    print('输出ing...')
    print()
    if not output_correct.empty:
        output_correct = output_correct.sort_values(by=['No'],
                                                    ascending=[True],
                                                    ignore_index=True)

        list_output_correct, index_start, index_end = [], 0, 100_000      
        while True:
            while True:
                if index_end < len(output_correct) and output_correct.loc[index_end, 'Part Number'] == output_correct.loc[index_end-1, 'Part Number']:
                    index_end += 1
                else:
                    break
                
            if index_end < len(output_correct):
                list_output_correct.append(output_correct[index_start:index_end].reset_index(drop=True))
                index_start, index_end = index_end, index_end + 100_000
            else:
                list_output_correct.append(output_correct[index_start:].reset_index(drop=True))
                break

        if len(list_output_correct) == 1:
            output_correct[['No',
                            'Part Number',
                            'Auth',
                            'Row',
                            'Vehicle Type',
                            'Region',
                            'Make',
                            'Model',
                            'Submodel',
                            'Cylinder',
                            'Displacement',
                            'Liter',
                            'Year',
                            'Fuel',
                            'Aspiration',
                            'Drive Type',
                            'Position']].to_excel(f'''./file/6.vehicle/{file.removesuffix('.xlsx')}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
        else:
            for serial, output in zip(range(len(list_output_correct)), list_output_correct):
                output[['No',
                        'Part Number',
                        'Auth',
                        'Row',
                        'Vehicle Type',
                        'Region',
                        'Make',
                        'Model',
                        'Submodel',
                        'Cylinder',
                        'Displacement',
                        'Liter',
                        'Year',
                        'Fuel',
                        'Aspiration',
                        'Drive Type',
                        'Position']].to_excel(f'''./file/6.vehicle/{file.removesuffix('.xlsx')}-serial_{serial+1}-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
    if not output_error.empty:
        output_error = output_error.sort_values(by=['No'],
                                                ascending=[True],
                                                ignore_index=True)
        output_error.to_excel(f'''./file/{file.removesuffix('.xlsx')}-vehicle_error.xlsx''', index=False)
        print('爬虫存在error')
        print()

# = = = = = = = = = = = = = = =

list_file = sorted(list(os.walk('./file/6.vehicle'))[0][2])
while '.DS_Store' in list_file:
    list_file.remove('.DS_Store')
while '0.null.txt' in list_file:
    list_file.remove('0.null.txt')

# = = = = = = = = = = = = = = =

from tqdm import tqdm
import re

for file in tqdm(list_file, desc='Progress', ncols=77):
    os.rename(f'./file/6.vehicle/{file}',
              f'''./file/6.vehicle/{re.sub(r'-[0-9]{8}_[0-9]{6}.xlsx$', '.xlsx', file)}''')

print('Done ~')
# Out:
# [状态：error，尝试次数：7] - 93.33% - crawler_89-vehicle_error > 1518.47-45055
# [剩余数量：0] - [当前时间：05:43:36]
#
# 输出ing...
#
# 爬虫存在error
#
# 总数量：141
#
# [状态：error，尝试次数：4] - 96.67% - crawler_9-vehicle_error > 209.53-6858
# [剩余数量：126] - [当前时间：05:43:38]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 236.53-2005
# [剩余数量：125] - [当前时间：05:43:38]
#
# [状态：error，尝试次数：11] - 96.67% - crawler_9-vehicle_error > 237.53-2006
# [剩余数量：124] - [当前时间：05:43:38]
#
# [状态：error，尝试次数：12] - 96.67% - crawler_9-vehicle_error > 210.53-6865
# [剩余数量：123] - [当前时间：05:43:38]
#
# [状态：error，尝试次数：18] - 96.67% - crawler_9-vehicle_error > 194.51-8021
# [剩余数量：122] - [当前时间：05:43:39]
#
# [状态：error，尝试次数：19] - 96.67% - crawler_9-vehicle_error > 235.53-2000
# [剩余数量：121] - [当前时间：05:43:39]
#
# [状态：error，尝试次数：17] - 96.67% - crawler_9-vehicle_error > 188.51-8002
# [剩余数量：120] - [当前时间：05:43:39]
#
# [状态：error，尝试次数：25] - 96.67% - crawler_9-vehicle_error > 68.52-7372
# [剩余数量：119] - [当前时间：05:43:40]
#
# [状态：error，尝试次数：32] - 96.67% - crawler_9-vehicle_error > 122.52-9917
# [剩余数量：118] - [当前时间：05:43:40]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 252.53-2042
# [剩余数量：117] - [当前时间：05:43:40]
#
# [状态：error，尝试次数：15] - 96.67% - crawler_9-vehicle_error > 242.53-2020
# [剩余数量：116] - [当前时间：05:43:40]
#
# [状态：error，尝试次数：12] - 96.67% - crawler_9-vehicle_error > 254.53-2047
# [剩余数量：115] - [当前时间：05:43:40]
#
# [状态：error，尝试次数：11] - 96.67% - crawler_9-vehicle_error > 251.53-2041
# [剩余数量：114] - [当前时间：05:43:41]
#
# [状态：error，尝试次数：9] - 96.67% - crawler_9-vehicle_error > 255.53-2048
# [剩余数量：113] - [当前时间：05:43:41]
#
# [状态：error，尝试次数：19] - 96.67% - crawler_9-vehicle_error > 276.53-2109
# [剩余数量：112] - [当前时间：05:43:42]
#
# [状态：error，尝试次数：68] - 96.67% - crawler_9-vehicle_error > 201.51-8056
# [剩余数量：111] - [当前时间：05:43:42]
#
# [状态：error，尝试次数：21] - 96.67% - crawler_9-vehicle_error > 250.53-2040
# [剩余数量：110] - [当前时间：05:43:43]
#
# [状态：error，尝试次数：66] - 96.67% - crawler_9-vehicle_error > 203.51-8091
# [剩余数量：109] - [当前时间：05:43:43]
#
# [状态：error，尝试次数：13] - 96.67% - crawler_9-vehicle_error > 295.53-2148
# [剩余数量：108] - [当前时间：05:43:43]
#
# [状态：error，尝试次数：11] - 96.67% - crawler_9-vehicle_error > 280.53-2113
# [剩余数量：107] - [当前时间：05:43:43]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 329.53-2400
# [剩余数量：106] - [当前时间：05:43:43]
#
# [状态：error，尝试次数：79] - 96.67% - crawler_9-vehicle_error > 238.53-2007
# [剩余数量：105] - [当前时间：05:43:44]
#
# [状态：error，尝试次数：35] - 96.67% - crawler_9-vehicle_error > 281.53-2114
# [剩余数量：104] - [当前时间：05:43:44]
#
# [状态：error，尝试次数：36] - 96.67% - crawler_9-vehicle_error > 279.53-2112
# [剩余数量：103] - [当前时间：05:43:45]
#
# [状态：error，尝试次数：38] - 96.67% - crawler_9-vehicle_error > 278.53-2111
# [剩余数量：102] - [当前时间：05:43:45]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 406.53-2652
# [剩余数量：101] - [当前时间：05:43:45]
#
# [状态：error，尝试次数：18] - 96.67% - crawler_9-vehicle_error > 344.53-2506
# [剩余数量：100] - [当前时间：05:43:45]
#
# [状态：error，尝试次数：34] - 96.67% - crawler_9-vehicle_error > 308.53-2195
# [剩余数量：99] - [当前时间：05:43:45]
#
# [状态：error，尝试次数：18] - 96.67% - crawler_9-vehicle_error > 371.53-2536
# [剩余数量：98] - [当前时间：05:43:46]
#
# [状态：error，尝试次数：23] - 96.67% - crawler_9-vehicle_error > 357.53-2519
# [剩余数量：97] - [当前时间：05:43:46]
#
# [状态：error，尝试次数：33] - 96.67% - crawler_9-vehicle_error > 370.53-2535
# [剩余数量：96] - [当前时间：05:43:46]
#
# [状态：error，尝试次数：49] - 96.67% - crawler_9-vehicle_error > 330.53-2401
# [剩余数量：95] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：121] - 96.67% - crawler_9-vehicle_error > 202.51-8059
# [剩余数量：94] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 443.53-27103
# [剩余数量：93] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：8] - 96.67% - crawler_9-vehicle_error > 431.53-2702
# [剩余数量：92] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：79] - 96.67% - crawler_9-vehicle_error > 277.53-2110
# [剩余数量：91] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：133] - 96.67% - crawler_9-vehicle_error > 204.51-9510
# [剩余数量：90] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：46] - 96.67% - crawler_9-vehicle_error > 337.53-2440
# [剩余数量：89] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 474.53-2739
# [剩余数量：88] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：13] - 96.67% - crawler_9-vehicle_error > 455.53-2719
# [剩余数量：87] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：4] - 96.67% - crawler_9-vehicle_error > 464.53-2729
# [剩余数量：86] - [当前时间：05:43:47]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 478.53-2743
# [剩余数量：85] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 468.53-2733
# [剩余数量：84] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：36] - 96.67% - crawler_9-vehicle_error > 428.53-2696
# [剩余数量：83] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 481.53-2746
# [剩余数量：82] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 484.53-2749
# [剩余数量：81] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 489.53-2754
# [剩余数量：80] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 513.53-2779
# [剩余数量：79] - [当前时间：05:43:48]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 494.53-2759
# [剩余数量：78] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 530.53-2796
# [剩余数量：77] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 507.53-2772
# [剩余数量：76] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 528.53-2794
# [剩余数量：75] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 544.53-2939
# [剩余数量：74] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 531.53-2797
# [剩余数量：73] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：10] - 96.67% - crawler_9-vehicle_error > 449.53-27109
# [剩余数量：72] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 584.53-3116
# [剩余数量：71] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 634.53-4904
# [剩余数量：70] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 537.53-2931
# [剩余数量：69] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 638.53-4908
# [剩余数量：68] - [当前时间：05:43:49]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 645.53-4917
# [剩余数量：67] - [当前时间：05:43:50]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 668.53-4940
# [剩余数量：66] - [当前时间：05:43:50]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 701.53-5120
# [剩余数量：65] - [当前时间：05:43:50]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 659.53-4931
# [剩余数量：64] - [当前时间：05:43:50]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 662.53-4934
# [剩余数量：63] - [当前时间：05:43:50]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 655.53-4927
# [剩余数量：62] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 703.53-5125
# [剩余数量：61] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 690.53-5076
# [剩余数量：60] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 691.53-5079
# [剩余数量：59] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 728.53-5240
# [剩余数量：58] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 737.53-5288
# [剩余数量：57] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 744.53-5311
# [剩余数量：56] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 745.53-5320
# [剩余数量：55] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 743.53-5310
# [剩余数量：54] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 508.53-2774
# [剩余数量：53] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 756.53-5413
# [剩余数量：52] - [当前时间：05:43:51]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 700.53-5110
# [剩余数量：51] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 757.53-5431
# [剩余数量：50] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 746.53-5330
# [剩余数量：49] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 767.53-5472
# [剩余数量：48] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 772.53-5511
# [剩余数量：47] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 827.53-6206
# [剩余数量：46] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 773.53-5512
# [剩余数量：45] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 853.53-6609
# [剩余数量：44] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 845.53-6405
# [剩余数量：43] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 855.53-6611
# [剩余数量：42] - [当前时间：05:43:52]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 862.53-6809
# [剩余数量：41] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 859.53-6802
# [剩余数量：40] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 868.53-6835
# [剩余数量：39] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 866.53-6824
# [剩余数量：38] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 867.53-6828
# [剩余数量：37] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 860.53-6803
# [剩余数量：36] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 889.53-6861
# [剩余数量：35] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 891.53-6863
# [剩余数量：34] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 880.53-6848
# [剩余数量：33] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 899.53-7206
# [剩余数量：32] - [当前时间：05:43:53]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 895.53-7200
# [剩余数量：31] - [当前时间：05:43:54]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 874.53-6842
# [剩余数量：30] - [当前时间：05:43:54]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 900.53-7207
# [剩余数量：29] - [当前时间：05:43:54]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 906.53-7609
# [剩余数量：28] - [当前时间：05:43:54]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 940.53-8026
# [剩余数量：27] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 911.53-7616
# [剩余数量：26] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 914.53-7619
# [剩余数量：25] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 918.53-7624
# [剩余数量：24] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：11] - 96.67% - crawler_9-vehicle_error > 923.53-7629
# [剩余数量：23] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：6] - 96.67% - crawler_9-vehicle_error > 953.53-8071
# [剩余数量：22] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：13] - 96.67% - crawler_9-vehicle_error > 930.53-7636
# [剩余数量：21] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：11] - 96.67% - crawler_9-vehicle_error > 939.53-8025
# [剩余数量：20] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 937.53-8016
# [剩余数量：19] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 941.53-8028
# [剩余数量：18] - [当前时间：05:43:55]
#
# [状态：error，尝试次数：8] - 96.67% - crawler_9-vehicle_error > 967.53-8122
# [剩余数量：17] - [当前时间：05:43:56]
#
# [状态：error，尝试次数：20] - 96.67% - crawler_9-vehicle_error > 932.53-8005
# [剩余数量：16] - [当前时间：05:43:56]
#
# [状态：error，尝试次数：13] - 96.67% - crawler_9-vehicle_error > 966.53-8121
# [剩余数量：15] - [当前时间：05:43:56]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 1005.53-8294
# [剩余数量：14] - [当前时间：05:43:57]
#
# [状态：error，尝试次数：7] - 96.67% - crawler_9-vehicle_error > 991.53-8203
# [剩余数量：13] - [当前时间：05:43:57]
#
# [状态：error，尝试次数：6] - 96.67% - crawler_9-vehicle_error > 998.53-8245
# [剩余数量：12] - [当前时间：05:43:57]
#
# [状态：error，尝试次数：9] - 96.67% - crawler_9-vehicle_error > 1006.53-8295
# [剩余数量：11] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：12] - 96.67% - crawler_9-vehicle_error > 992.53-8211
# [剩余数量：10] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：22] - 96.67% - crawler_9-vehicle_error > 988.53-8195
# [剩余数量：9] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：30] - 96.67% - crawler_9-vehicle_error > 971.53-8130
# [剩余数量：8] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：4] - 96.67% - crawler_9-vehicle_error > 1009.53-8313
# [剩余数量：7] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：16] - 96.67% - crawler_9-vehicle_error > 979.53-8158
# [剩余数量：6] - [当前时间：05:43:58]
#
# [状态：error，尝试次数：33] - 96.67% - crawler_9-vehicle_error > 970.53-8127
# [剩余数量：5] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1029.53-8425
# [剩余数量：4] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：16] - 96.67% - crawler_9-vehicle_error > 1007.53-8296
# [剩余数量：3] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：4] - 96.67% - crawler_9-vehicle_error > 1024.53-8395
# [剩余数量：2] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：38] - 96.67% - crawler_9-vehicle_error > 978.53-8150
# [剩余数量：1] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：12] - 96.67% - crawler_9-vehicle_error > 1012.53-8324
# [剩余数量：0] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：39] - 96.67% - crawler_9-vehicle_error > 985.53-8179
# [剩余数量：0] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：6] - 96.67% - crawler_9-vehicle_error > 1036.53-8468
# [剩余数量：0] - [当前时间：05:43:59]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1360.54-73128
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1059.53-8692
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：6] - 96.67% - crawler_9-vehicle_error > 1042.53-8526
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1040.53-8519
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 968.53-8123
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1043.53-8529
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1505.54-74118
# [剩余数量：0] - [当前时间：05:44:00]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 1712.54-79411
# [剩余数量：0] - [当前时间：05:44:01]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 1501.54-74112
# [剩余数量：0] - [当前时间：05:44:01]
#
# [状态：error，尝试次数：3] - 96.67% - crawler_9-vehicle_error > 1395.54-73188
# [剩余数量：0] - [当前时间：05:44:01]
#
# [状态：error，尝试次数：1] - 96.67% - crawler_9-vehicle_error > 1711.54-79410
# [剩余数量：0] - [当前时间：05:44:01]
#
# [状态：error，尝试次数：2] - 96.67% - crawler_9-vehicle_error > 908.53-7613
# [剩余数量：0] - [当前时间：05:44:04]
#
# 输出ing...
#
# 爬虫存在error
#
# 总数量：113
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 403.43-1167
# [剩余数量：98] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 437.43-1406
# [剩余数量：97] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 76.40-1063
# [剩余数量：96] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 402.43-1166
# [剩余数量：95] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 428.43-1251
# [剩余数量：94] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 80.40-1068
# [剩余数量：93] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 429.43-1252
# [剩余数量：92] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 375.43-1007
# [剩余数量：91] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 395.43-1156
# [剩余数量：90] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 2.40-10000
# [剩余数量：89] - [当前时间：05:44:06]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 201.40-2042
# [剩余数量：88] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 404.43-1169
# [剩余数量：87] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 427.43-1250
# [剩余数量：86] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 443.43-1412
# [剩余数量：85] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 477.43-1483
# [剩余数量：84] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 433.43-1307
# [剩余数量：83] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 466.43-1472
# [剩余数量：82] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 445.43-1414
# [剩余数量：81] - [当前时间：05:44:07]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 446.43-1415
# [剩余数量：80] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 457.43-1429
# [剩余数量：79] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 646.43-2124
# [剩余数量：78] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 430.43-1253
# [剩余数量：77] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 651.43-2132
# [剩余数量：76] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 702.43-3442
# [剩余数量：75] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 480.43-1486
# [剩余数量：74] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 703.43-3443
# [剩余数量：73] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 650.43-2131
# [剩余数量：72] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 760.43-4008
# [剩余数量：71] - [当前时间：05:44:08]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 766.43-4015
# [剩余数量：70] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 772.43-4021
# [剩余数量：69] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 783.43-4034
# [剩余数量：68] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 785.43-4036
# [剩余数量：67] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 788.43-4041
# [剩余数量：66] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 770.43-4019
# [剩余数量：65] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 800.43-4059
# [剩余数量：64] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 795.43-4049
# [剩余数量：63] - [当前时间：05:44:09]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 779.43-4030
# [剩余数量：62] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 809.43-4077
# [剩余数量：61] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 804.43-4066
# [剩余数量：60] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 812.43-4080
# [剩余数量：59] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 810.43-4078
# [剩余数量：58] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 843.43-4213
# [剩余数量：57] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 841.43-4210
# [剩余数量：56] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 844.43-4214
# [剩余数量：55] - [当前时间：05:44:10]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 851.43-4230
# [剩余数量：54] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 811.43-4079
# [剩余数量：53] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 789.43-4042
# [剩余数量：52] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 846.43-4216
# [剩余数量：51] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 711.43-35006
# [剩余数量：50] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 863.43-43103
# [剩余数量：49] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 867.43-4311
# [剩余数量：48] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 865.43-43107
# [剩余数量：47] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 869.43-43112
# [剩余数量：46] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 861.43-4309
# [剩余数量：45] - [当前时间：05:44:11]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 870.43-43113
# [剩余数量：44] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 876.43-43120
# [剩余数量：43] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 899.43-4332
# [剩余数量：42] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 891.43-4324
# [剩余数量：41] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 885.43-4318
# [剩余数量：40] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 900.43-4334
# [剩余数量：39] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 904.43-4339
# [剩余数量：38] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 908.43-4343
# [剩余数量：37] - [当前时间：05:44:12]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 902.43-4337
# [剩余数量：36] - [当前时间：05:44:13]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 914.43-4350
# [剩余数量：35] - [当前时间：05:44:13]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 918.43-4369
# [剩余数量：34] - [当前时间：05:44:13]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 916.43-4362
# [剩余数量：33] - [当前时间：05:44:13]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 927.43-4386
# [剩余数量：32] - [当前时间：05:44:13]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 917.43-4367
# [剩余数量：31] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 923.43-4382
# [剩余数量：30] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 932.43-4393
# [剩余数量：29] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 921.43-4379
# [剩余数量：28] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 920.43-4377
# [剩余数量：27] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 933.43-4394
# [剩余数量：26] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 928.43-4387
# [剩余数量：25] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 938.43-4399
# [剩余数量：24] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 942.43-4404
# [剩余数量：23] - [当前时间：05:44:14]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 945.43-4407
# [剩余数量：22] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 947.43-4409
# [剩余数量：21] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 972.43-4458
# [剩余数量：20] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 981.43-4473
# [剩余数量：19] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 936.43-4397
# [剩余数量：18] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 977.43-4464
# [剩余数量：17] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 982.43-4475
# [剩余数量：16] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 958.43-4421
# [剩余数量：15] - [当前时间：05:44:15]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 983.43-4476
# [剩余数量：14] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 988.43-4489
# [剩余数量：13] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 989.43-4490
# [剩余数量：12] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 987.43-4488
# [剩余数量：11] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 991.43-45004
# [剩余数量：10] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 993.43-45007
# [剩余数量：9] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 922.43-4380
# [剩余数量：8] - [当前时间：05:44:16]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1001.43-45014
# [剩余数量：7] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1005.43-45022
# [剩余数量：6] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1013.43-45032
# [剩余数量：5] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1016.43-45038
# [剩余数量：4] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1025.43-4510
# [剩余数量：3] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1027.43-4512
# [剩余数量：2] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1028.43-4513
# [剩余数量：1] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1029.43-4514
# [剩余数量：0] - [当前时间：05:44:17]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1053.43-4543
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1000.43-45013
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1033.43-4519
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1035.43-4521
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1048.43-4536
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1040.43-4527
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1043.43-4531
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1046.43-4534
# [剩余数量：0] - [当前时间：05:44:18]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1067.43-4573
# [剩余数量：0] - [当前时间：05:44:19]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1036.43-4522
# [剩余数量：0] - [当前时间：05:44:19]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1078.43-4597
# [剩余数量：0] - [当前时间：05:44:19]
#
# [状态：error，尝试次数：2] - 100.00% - crawler_95-vehicle_error > 786.43-4037
# [剩余数量：0] - [当前时间：05:44:20]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 1068.43-4574
# [剩余数量：0] - [当前时间：05:44:20]
#
# [状态：error，尝试次数：1] - 100.00% - crawler_95-vehicle_error > 913.43-4348
# [剩余数量：0] - [当前时间：05:44:20]
#
# 输出ing...
#
# 爬虫存在error
# Progress: 0it [00:00, ?it/s]
# Done ~
