# %%
import pandas as pd

input_ = pd.read_excel('./3.item.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['No'] = input_['No'].astype(int)

input_
# Out:
#       No   Item Number                                              Title  \
# 0      1  325960692572  Mazda CX-5 CX5 2012-2016 Electric Powerfold In...
# 1      2  325960692580  Mazda CX-5 CX5 2012-2016 Electric Powerfold In...
# 2      3  225616819852  Toyota Yaris 5dr 2020-2023 Electric Door Wing ...
# 3      4  226014609106  Renault Clio MK5 2019-2024 Electric Powerfold ...
# 4      5  226014609107  Renault Clio MK5 2019-2024 Electric Powerfold ...
# ..   ...           ...                                                ...
# 456  457  224030767402  For VW Crafter 2006-2017 Lower Door Wing Mirro...
# 457  458  324184663257  For Mercedes Sprinter 2006-2019 Lower Wing Mir...
# 458  459  325492805263  VW Fox 2003-2011 Heated Door Wing Mirror Glass...
# 459  460  324184659149  For Ford Transit MK6/MK7 2000-2014 Door Wing M...
# 460  461  224030762701  For Ford Transit MK6/MK7 2000-2014 Door Wing M...
#
#     Subtitle    Price    Available        Sold Vehicle W/o Engine  \
# 0             £148.95  5 available      7 sold
# 1             £148.95  5 available      1 sold
# 2             £129.95                   9 sold
# 3             £124.95  4 available      6 sold
# 4             £124.95  5 available
# ..       ...      ...          ...         ...                ...
# 456             £7.95  5 available     33 sold
# 457             £7.95  5 available  1,002 sold
# 458             £7.95  5 available     46 sold
# 459             £6.95  5 available  5,779 sold
# 460             £6.95  5 available  6,387 sold
#
#     Vehicle W/ Engine Picture  \
# 0
# 1
# 2
# 3
# 4
# ..                ...     ...
# 456
# 457
# 458
# 459
# 460
#
#                                                    Url  \
# 0    https://www.ebay.co.uk/itm/325960692572?_ul=GB...
# 1    https://www.ebay.co.uk/itm/325960692580?_ul=GB...
# 2    https://www.ebay.co.uk/itm/225616819852?_ul=GB...
# 3    https://www.ebay.co.uk/itm/226014609106?_ul=GB...
# 4    https://www.ebay.co.uk/itm/226014609107?_ul=GB...
# ..                                                 ...
# 456  https://www.ebay.co.uk/itm/224030767402?_ul=GB...
# 457  https://www.ebay.co.uk/itm/324184663257?_ul=GB...
# 458  https://www.ebay.co.uk/itm/325492805263?_ul=GB...
# 459  https://www.ebay.co.uk/itm/324184659149?_ul=GB...
# 460  https://www.ebay.co.uk/itm/224030762701?_ul=GB...
#
#                                        Description Url  \
# 0    https://vi.vipr.ebaydesc.com/itmdesc/325960692...
# 1    https://vi.vipr.ebaydesc.com/itmdesc/325960692...
# 2    https://vi.vipr.ebaydesc.com/itmdesc/225616819...
# 3    https://vi.vipr.ebaydesc.com/itmdesc/226014609...
# 4    https://vi.vipr.ebaydesc.com/itmdesc/226014609...
# ..                                                 ...
# 456  https://vi.vipr.ebaydesc.com/itmdesc/224030767...
# 457  https://vi.vipr.ebaydesc.com/itmdesc/324184663...
# 458  https://vi.vipr.ebaydesc.com/itmdesc/325492805...
# 459  https://vi.vipr.ebaydesc.com/itmdesc/324184659...
# 460  https://vi.vipr.ebaydesc.com/itmdesc/224030762...
#
#                                     Json_Compatibility  \
# 0    {"market": "UK", "page": 5, "data": {"scopedCo...
# 1    {"market": "UK", "page": 5, "data": {"scopedCo...
# 2    {"market": "UK", "page": 1, "data": {"scopedCo...
# 3    {"market": "UK", "page": 3, "data": {"scopedCo...
# 4    {"market": "UK", "page": 3, "data": {"scopedCo...
# ..                                                 ...
# 456  {"market": "UK", "page": 10, "data": {"scopedC...
# 457  {"market": "UK", "page": 115, "data": {"scoped...
# 458  {"market": "UK", "page": 5, "data": {"scopedCo...
# 459  {"market": "UK", "page": 28, "data": {"scopedC...
# 460  {"market": "UK", "page": 34, "data": {"scopedC...
#
#                                               Json_Src  \
# 0    {"0": "https://i.ebayimg.com/images/g/ZGcAAOSw...
# 1    {"0": "https://i.ebayimg.com/images/g/EukAAOSw...
# 2    {"0": "https://i.ebayimg.com/images/g/38IAAOSw...
# 3    {"0": "https://i.ebayimg.com/images/g/UhYAAOSw...
# 4    {"0": "https://i.ebayimg.com/images/g/fiUAAOSw...
# ..                                                 ...
# 456  {"0": "https://i.ebayimg.com/images/g/NnIAAOSw...
# 457  {"0": "https://i.ebayimg.com/images/g/1~cAAOSw...
# 458  {"0": "https://i.ebayimg.com/images/g/JT0AAOSw...
# 459  {"0": "https://i.ebayimg.com/images/g/X10AAOSw...
# 460  {"0": "https://i.ebayimg.com/images/g/mk4AAOSw...
#
#                                          Json_Specific
# 0    {"0": {"Condition": "New other (see details): ...
# 1    {"0": {"Condition": "New other (see details): ...
# 2    {"0": {"Condition": "New other (see details): ...
# 3    {"0": {"Condition": "New other (see details): ...
# 4    {"0": {"Condition": "New other (see details): ...
# ..                                                 ...
# 456  {"0": {"Condition": "New other (see details)"}...
# 457  {"0": {"Condition": "New other (see details)"}...
# 458  {"0": {"Condition": "New other (see details): ...
# 459  {"0": {"Condition": "New other (see details)"}...
# 460  {"0": {"Condition": "New other (see details)"}...
#
# [461 rows x 15 columns]

# %%
from tqdm import tqdm
import json

for i in tqdm(range(len(input_)), desc='Progress', ncols=77):
    dict_specific = json.loads(input_.loc[i, 'Json_Specific'])
    for value in list(dict_specific.values()):
        input_.loc[i, list(value.keys())[0]] = list(value.values())[0]

input_.to_excel('./7.specific.xlsx', index=False)

input_
# Out:
# Progress: 100%|███████████████████████████| 461/461 [00:00<00:00, 680.85it/s]
#       No   Item Number                                              Title  \
# 0      1  325960692572  Mazda CX-5 CX5 2012-2016 Electric Powerfold In...
# 1      2  325960692580  Mazda CX-5 CX5 2012-2016 Electric Powerfold In...
# 2      3  225616819852  Toyota Yaris 5dr 2020-2023 Electric Door Wing ...
# 3      4  226014609106  Renault Clio MK5 2019-2024 Electric Powerfold ...
# 4      5  226014609107  Renault Clio MK5 2019-2024 Electric Powerfold ...
# ..   ...           ...                                                ...
# 456  457  224030767402  For VW Crafter 2006-2017 Lower Door Wing Mirro...
# 457  458  324184663257  For Mercedes Sprinter 2006-2019 Lower Wing Mir...
# 458  459  325492805263  VW Fox 2003-2011 Heated Door Wing Mirror Glass...
# 459  460  324184659149  For Ford Transit MK6/MK7 2000-2014 Door Wing M...
# 460  461  224030762701  For Ford Transit MK6/MK7 2000-2014 Door Wing M...
#
#     Subtitle    Price    Available        Sold Vehicle W/o Engine  \
# 0             £148.95  5 available      7 sold
# 1             £148.95  5 available      1 sold
# 2             £129.95                   9 sold
# 3             £124.95  4 available      6 sold
# 4             £124.95  5 available
# ..       ...      ...          ...         ...                ...
# 456             £7.95  5 available     33 sold
# 457             £7.95  5 available  1,002 sold
# 458             £7.95  5 available     46 sold
# 459             £6.95  5 available  5,779 sold
# 460             £6.95  5 available  6,387 sold
#
#     Vehicle W/ Engine Picture  ...            ISBN Reference OE/OEM Number  \
# 0                              ...             NaN                     NaN
# 1                              ...             NaN                     NaN
# 2                              ...  Does Not Apply                     NaN
# 3                              ...             NaN                     NaN
# 4                              ...             NaN                     NaN
# ..                ...     ...  ...             ...                     ...
# 456                            ...             NaN                     NaN
# 457                            ...             NaN                     NaN
# 458                            ...  Does Not Apply                     NaN
# 459                            ...  Does Not Apply                     NaN
# 460                            ...             NaN                     NaN
#
#     Classic Part Colour Performance Part Type Material Manufacturer Warranty  \
# 0            NaN    NaN              NaN  NaN      NaN                   NaN
# 1            NaN    NaN              NaN  NaN      NaN                   NaN
# 2            NaN    NaN              NaN  NaN      NaN                   NaN
# 3            NaN    NaN              NaN  NaN      NaN                   NaN
# 4            NaN    NaN              NaN  NaN      NaN                   NaN
# ..           ...    ...              ...  ...      ...                   ...
# 456          NaN    NaN              NaN  NaN      NaN                   NaN
# 457          NaN    NaN              NaN  NaN      NaN                   NaN
# 458          NaN    NaN              NaN  NaN      NaN                   NaN
# 459          NaN    NaN              NaN  NaN      NaN                   NaN
# 460          NaN    NaN              NaN  NaN      NaN                   NaN
#
#     Universal Fitment                                       Seller notes
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ..                ...                                                ...
# 456               NaN  “🔥Shipped Within 24 Hours 🔥1-2 Days Arrival🔥UK...
# 457               NaN  “🔥Shipped Within 24 Hours 🔥1-2 Days Arrival🔥UK...
# 458               NaN                                                NaN
# 459               NaN  “🔥Shipped Within 24 Hours 🔥1-2 Days Arrival🔥UK...
# 460               NaN  “🔥Shipped Within 24 Hours 🔥1-2 Days Arrival🔥UK...
#
# [461 rows x 36 columns]
