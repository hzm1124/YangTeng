# %%
from gevent import monkey
monkey.patch_all(thread=False)
from gevent.queue import Queue
import gevent

# = = = = = = = = = = = = = = =

from IPython.display import clear_output
from datetime import datetime

# %%
param_date = '20240724'

# %%
import pandas as pd

output_correct, output_error = pd.DataFrame(), pd.DataFrame()

# = = = = = = = = = = = = = = =

input_ = pd.read_excel(f'./{param_date}/2.subgroup.xlsx',
                       header=0,
                       dtype=str).fillna('')

input_['Group No'] = input_['Group No'].astype(int)
input_['Subgroup No'] = input_['Subgroup No'].astype(int)

print(f'总数量：{len(input_)}')
print()

# = = = = = = = = = = = = = = =

work = Queue()
for a in range(len(input_)):
    work.put_nowait(a)

# = = = = = = = = = = = = = = =

def crawler():
    global output_correct, output_error

    while not work.empty():
        a = work.get_nowait()

        # = = = = = = = = = = = = = = =

        crawler_status = 'error'

        # = = = = = = = = = = = = = = =

        import requests
        import json

        import sys
        sys.path.append('../../00.Tools')
        from crawler_configuration import get_header, get_proxy

        payload = {'jsn': {'tab': 'extras',
                           'groupname': input_.loc[a, 'Group'],
                           'subgroupname': input_.loc[a, 'Subgroup'],
                           'nodetype': 'subgroupname'}}

        data = {'func': 'navnode_fetch',
                'payload': json.dumps(payload),
                'api_json_request': '1'}

        try:
            b = 0
            while True:

                while True:
                    b += 1
                    try:
                        resp = requests.post('https://www.rockauto.com/catalog/catalogapi.php',
                                             data=data,
                                             headers=get_header(),
                                             proxies=get_proxy(),
                                             timeout=(10, 10))
                        break
                    except:
                        continue

                if resp.status_code == 200:
                    json_ = resp.json()
                    if 'redirect_to_url' in json_:
                        continue
                    elif json_['jsn']['tab'] == 'extras' and json_['jsn']['groupname'] == input_.loc[a, 'Group'] and json_['jsn']['subgroupname'] == input_.loc[a, 'Subgroup'] and json_['jsn']['nodetype'] == 'subgroupname' and 'collected_javascript' in json_:
                        break

            # = = = = = = = = = = = = = = =

            from bs4 import BeautifulSoup
            from lxml import etree

            soup = BeautifulSoup(json_['html_fill_sections']['navchildren[]'], 'lxml')
            html = etree.HTML(str(soup))

            # = = = = = = = = = = = = = = =

            list_json = html.xpath('//input[contains(@id, "jsn[__GIP__")]/@value')

            # = = = = = = = = = = = = = = =

            list_type_code = [json.loads(json_)['parttype'] for json_ in list_json]

            # = = = = = = = = = = = = = = =

            list_type = html.xpath('//td[@class="nlabel"]/a/text()')

            # = = = = = = = = = = = = = = =

            if not list_type:
                raise

            # = = = = = = = = = = = = = = =

            df_temp = pd.DataFrame({'Group No': input_.loc[a, 'Group No'],
                                    'Group': input_.loc[a, 'Group'],
                                    'Subgroup No': input_.loc[a, 'Subgroup No'],
                                    'Subgroup': input_.loc[a, 'Subgroup'],
                                    'Type No': [i+1 for i in range(len(list_type))],
                                    'Type': list_type,
                                    'Type Code': list_type_code,
                                    'Tab 3 Url': [f'''https://www.rockauto.com/en/tools/{input_.loc[a, 'Group'].replace(',', '%2C')},{input_.loc[a, 'Subgroup'].replace(',', '%2C')},{type_.replace(',', '%2C')},{type_code.replace(',', '%2C')}''' for type_, type_code in zip(list_type, list_type_code)]})

            output_correct = pd.concat([output_correct, df_temp], ignore_index=True).fillna('')

            # = = = = = = = = = = = = = = =

            crawler_status = 'ok'
        except:
            df_temp = pd.DataFrame([{'Group No': input_.loc[a, 'Group No'],
                                     'Group': input_.loc[a, 'Group'],
                                     'Subgroup No': input_.loc[a, 'Subgroup No'],
                                     'Subgroup': input_.loc[a, 'Subgroup']}])

            output_error = pd.concat([output_error, df_temp], ignore_index=True).fillna('')

        # = = = = = = = = = = = = = = =

        if work.qsize() % 1_000 == 0 and work.qsize() != 0:
            clear_output()

        print(f'''[状态：{crawler_status}，尝试次数：{b}] - {input_.loc[a, 'Group No']}.{input_.loc[a, 'Group']} > {input_.loc[a, 'Subgroup No']}.{input_.loc[a, 'Subgroup']}\n[剩余数量：{work.qsize()}] - [当前时间：{datetime.now().strftime('%H:%M:%S')}]\n''')

# = = = = = = = = = = = = = = =

list_task = []
for _ in range(12):
    task = gevent.spawn(crawler)
    list_task.append(task)
gevent.joinall(list_task)

print('输出ing...')
print()
if not output_correct.empty:
    output_correct = output_correct.sort_values(by=['Group No', 'Subgroup No', 'Type No'],
                                                ascending=[True, True, True],
                                                ignore_index=True)
    output_correct.to_excel(f'''./{param_date}/3.type-{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx''', index=False)
if not output_error.empty:
    output_error = output_error.sort_values(by=['Group No', 'Subgroup No'],
                                            ascending=[True, True],
                                            ignore_index=True)
    output_error.to_excel(f'./{param_date}/type_error.xlsx', index=False)
    print('爬虫存在error')
    print()
print('Done ~')
# Out:
# 总数量：330
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 4.Heavy Duty / Industrial V-Belt
# [剩余数量：318] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 1.Accessory Lighting
# [剩余数量：317] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 3.Fluid / Chemical
# [剩余数量：316] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 7.Refrigeration V-Belt
# [剩余数量：315] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 2.Automotive V-Belt
# [剩余数量：314] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 5.Light Duty FHP / Lawn & Garden V-Belt
# [剩余数量：313] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 6.Pulley & Tensioner
# [剩余数量：312] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 1.Apparel & Gifts > 1.RockAuto Apparel
# [剩余数量：311] - [当前时间：17:07:45]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 9.Tool
# [剩余数量：310] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 3.Back Up / Reverse Lamp
# [剩余数量：309] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 6.Cargo Management
# [剩余数量：308] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 5.Bumper / Pad
# [剩余数量：307] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 8.Door
# [剩余数量：306] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 7.Clearance / Side Marker Lamp
# [剩余数量：305] - [当前时间：17:07:46]
#
# [状态：ok，尝试次数：1] - 1.Apparel & Gifts > 2.RockAuto Gift
# [剩余数量：304] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 10.Fluid / Chemical
# [剩余数量：303] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 2.Antenna
# [剩余数量：302] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 4.Body Panel
# [剩余数量：301] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 8.Snowmobile Belt
# [剩余数量：300] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 2.Belt Drive > 1.ATV / UTV Belt
# [剩余数量：299] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 11.Fog / Driving Lamp
# [剩余数量：298] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 12.Grille
# [剩余数量：297] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 13.Hardware
# [剩余数量：296] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 14.Headlamp
# [剩余数量：295] - [当前时间：17:07:47]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 19.Mud Flap
# [剩余数量：294] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 16.Lamp Bezel
# [剩余数量：293] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 17.License Plate
# [剩余数量：292] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 20.Outside Mirror
# [剩余数量：291] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 25.Recovery Gear
# [剩余数量：290] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 21.Overspray Protection
# [剩余数量：289] - [当前时间：17:07:48]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 24.Polishing
# [剩余数量：288] - [当前时间：17:07:49]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 23.Parking / Turn Signal Lamp
# [剩余数量：287] - [当前时间：17:07:49]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 29.Stop, Turn, & Tail Lamp
# [剩余数量：286] - [当前时间：17:07:49]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 31.Tool
# [剩余数量：285] - [当前时间：17:07:49]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 30.Tape
# [剩余数量：284] - [当前时间：17:07:50]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 28.Running Board
# [剩余数量：283] - [当前时间：17:07:50]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 35.Towing Enhancement
# [剩余数量：282] - [当前时间：17:07:51]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 33.Towing - Flat / Vehicle
# [剩余数量：281] - [当前时间：17:07:51]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 36.Trim / Molding
# [剩余数量：280] - [当前时间：17:07:51]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 37.Weatherstrip
# [剩余数量：279] - [当前时间：17:07:51]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 26.Reflector
# [剩余数量：278] - [当前时间：17:07:51]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 22.Painting
# [剩余数量：277] - [当前时间：17:07:52]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 1.Air Brake
# [剩余数量：276] - [当前时间：17:07:52]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 34.Towing - Trailer
# [剩余数量：275] - [当前时间：17:07:52]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 2.Axle/Spindle
# [剩余数量：274] - [当前时间：17:07:52]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 3.Brake Line
# [剩余数量：273] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 6.Drum
# [剩余数量：272] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 8.Master Cylinder
# [剩余数量：271] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 7.Fluid / Chemical
# [剩余数量：270] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 4.Brake Shoe
# [剩余数量：269] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 27.Retainer / Clip
# [剩余数量：268] - [当前时间：17:07:53]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 32.Towing - Fifth Wheel
# [剩余数量：267] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 9.Parking Brake
# [剩余数量：266] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 10.Power Brake
# [剩余数量：265] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：1] - 4.Brake & Wheel Hub > 5.Caliper
# [剩余数量：264] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：3] - 5.Cooling System > 1.Cooling
# [剩余数量：263] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：2] - 4.Brake & Wheel Hub > 11.Tool
# [剩余数量：262] - [当前时间：17:07:54]
#
# [状态：ok，尝试次数：3] - 5.Cooling System > 4.Sender / Sensor
# [剩余数量：261] - [当前时间：17:07:55]
#
# [状态：ok，尝试次数：9] - 4.Brake & Wheel Hub > 12.Wheel Bearing & Hub
# [剩余数量：260] - [当前时间：17:07:55]
#
# [状态：ok，尝试次数：3] - 6.Drivetrain > 1.Bumper / Pad
# [剩余数量：259] - [当前时间：17:07:56]
#
# [状态：ok，尝试次数：11] - 5.Cooling System > 2.Fluid / Chemical
# [剩余数量：258] - [当前时间：17:07:56]
#
# [状态：ok，尝试次数：21] - 4.Brake & Wheel Hub > 13.Wheel Cylinder
# [剩余数量：257] - [当前时间：17:07:56]
#
# [状态：ok，尝试次数：8] - 5.Cooling System > 6.Tool
# [剩余数量：256] - [当前时间：17:07:56]
#
# [状态：ok，尝试次数：19] - 5.Cooling System > 3.Radiator
# [剩余数量：255] - [当前时间：17:07:56]
#
# [状态：ok，尝试次数：7] - 6.Drivetrain > 3.Fluid / Chemical
# [剩余数量：254] - [当前时间：17:07:57]
#
# [状态：ok，尝试次数：4] - 5.Cooling System > 7.Water Pump
# [剩余数量：253] - [当前时间：17:07:57]
#
# [状态：ok，尝试次数：29] - 5.Cooling System > 5.Thermostat
# [剩余数量：252] - [当前时间：17:07:58]
#
# [状态：ok，尝试次数：9] - 7.Electrical > 1.Alternator / Generator
# [剩余数量：251] - [当前时间：17:07:58]
#
# [状态：ok，尝试次数：8] - 7.Electrical > 3.Circuit Breaker
# [剩余数量：250] - [当前时间：17:07:58]
#
# [状态：ok，尝试次数：15] - 6.Drivetrain > 2.CV Axle
# [剩余数量：249] - [当前时间：17:07:58]
#
# [状态：ok，尝试次数：5] - 7.Electrical > 6.Fluid / Chemical
# [剩余数量：248] - [当前时间：17:07:59]
#
# [状态：ok，尝试次数：28] - 6.Drivetrain > 4.Tool
# [剩余数量：247] - [当前时间：17:07:59]
#
# [状态：ok，尝试次数：16] - 7.Electrical > 4.Firewall
# [剩余数量：246] - [当前时间：17:07:59]
#
# [状态：ok，尝试次数：31] - 3.Body & Lamp Assembly > 9.Fender
# [剩余数量：245] - [当前时间：17:08:00]
#
# [状态：ok，尝试次数：8] - 3.Body & Lamp Assembly > 15.Hood
# [剩余数量：244] - [当前时间：17:08:00]
#
# [状态：ok，尝试次数：3] - 7.Electrical > 10.Park Assist
# [剩余数量：243] - [当前时间：17:08:00]
#
# [状态：ok，尝试次数：5] - 7.Electrical > 8.Horn / Alarm
# [剩余数量：242] - [当前时间：17:08:00]
#
# [状态：ok，尝试次数：21] - 7.Electrical > 7.Fuse
# [剩余数量：241] - [当前时间：17:08:00]
#
# [状态：ok，尝试次数：37] - 7.Electrical > 2.Battery
# [剩余数量：240] - [当前时间：17:08:01]
#
# [状态：ok，尝试次数：26] - 7.Electrical > 9.Key FOB
# [剩余数量：239] - [当前时间：17:08:02]
#
# [状态：ok，尝试次数：11] - 7.Electrical > 11.Starter
# [剩余数量：238] - [当前时间：17:08:02]
#
# [状态：ok，尝试次数：49] - 7.Electrical > 5.Flasher
# [剩余数量：237] - [当前时间：17:08:02]
#
# [状态：ok，尝试次数：8] - 8.Electrical-Bulb & Socket > 1.LED Bulb Adapter
# [剩余数量：236] - [当前时间：17:08:02]
#
# [状态：ok，尝试次数：12] - 8.Electrical-Bulb & Socket > 2.Light Bulb
# [剩余数量：235] - [当前时间：17:08:03]
#
# [状态：ok，尝试次数：39] - 7.Electrical > 13.Wire
# [剩余数量：234] - [当前时间：17:08:03]
#
# [状态：ok，尝试次数：40] - 7.Electrical > 12.Tool
# [剩余数量：233] - [当前时间：17:08:03]
#
# [状态：ok，尝试次数：10] - 9.Electrical-Connector > 3.Specialty Connector
# [剩余数量：232] - [当前时间：17:08:03]
#
# [状态：ok，尝试次数：25] - 9.Electrical-Connector > 2.Battery Connector
# [剩余数量：231] - [当前时间：17:08:04]
#
# [状态：ok，尝试次数：7] - 9.Electrical-Connector > 1.Accessory Lighting Plugs
# [剩余数量：230] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：50] - 7.Electrical > 14.Wire Management
# [剩余数量：229] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：50] - 8.Electrical-Bulb & Socket > 3.Socket
# [剩余数量：228] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：5] - 10.Electrical-Switch & Relay > 5.Tool
# [剩余数量：227] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：14] - 10.Electrical-Switch & Relay > 1.Battery
# [剩余数量：226] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：1] - 3.Body & Lamp Assembly > 18.Lift Support
# [剩余数量：225] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：15] - 9.Electrical-Connector > 6.Wire Connector
# [剩余数量：224] - [当前时间：17:08:05]
#
# [状态：ok，尝试次数：11] - 9.Electrical-Connector > 5.Trailer Wiring
# [剩余数量：223] - [当前时间：17:08:06]
#
# [状态：ok，尝试次数：1] - 11.Engine > 1.Cylinder Head
# [剩余数量：222] - [当前时间：17:08:06]
#
# [状态：ok，尝试次数：2] - 11.Engine > 2.Dipstick
# [剩余数量：221] - [当前时间：17:08:06]
#
# [状态：ok，尝试次数：4] - 11.Engine > 5.Heat Shield
# [剩余数量：220] - [当前时间：17:08:06]
#
# [状态：ok，尝试次数：2] - 11.Engine > 4.Gasket
# [剩余数量：219] - [当前时间：17:08:07]
#
# [状态：ok，尝试次数：8] - 11.Engine > 6.Heater
# [剩余数量：218] - [当前时间：17:08:07]
#
# [状态：ok，尝试次数：25] - 10.Electrical-Switch & Relay > 2.Relay
# [剩余数量：217] - [当前时间：17:08:07]
#
# [状态：ok，尝试次数：2] - 11.Engine > 11.Oil Filler
# [剩余数量：216] - [当前时间：17:08:08]
#
# [状态：ok，尝试次数：1] - 11.Engine > 9.Oil Cooler
# [剩余数量：215] - [当前时间：17:08:08]
#
# [状态：ok，尝试次数：15] - 11.Engine > 3.Fluid / Chemical
# [剩余数量：214] - [当前时间：17:08:08]
#
# [状态：ok，尝试次数：39] - 10.Electrical-Switch & Relay > 3.Specialty Switch
# [剩余数量：213] - [当前时间：17:08:08]
#
# [状态：ok，尝试次数：18] - 11.Engine > 8.Oil
# [剩余数量：212] - [当前时间：17:08:08]
#
# [状态：ok，尝试次数：33] - 11.Engine > 13.Rebuilders Valves
# [剩余数量：211] - [当前时间：17:08:10]
#
# [状态：ok，尝试次数：13] - 11.Engine > 17.Valve Cover
# [剩余数量：210] - [当前时间：17:08:10]
#
# [状态：ok，尝试次数：17] - 11.Engine > 15.Timing Chain
# [剩余数量：209] - [当前时间：17:08:10]
#
# [状态：ok，尝试次数：31] - 11.Engine > 12.Oil Filter
# [剩余数量：208] - [当前时间：17:08:11]
#
# [状态：ok，尝试次数：5] - 11.Engine > 16.Tool
# [剩余数量：207] - [当前时间：17:08:11]
#
# [状态：ok，尝试次数：6] - 12.Exhaust & Emission > 2.Clamp
# [剩余数量：206] - [当前时间：17:08:11]
#
# [状态：ok，尝试次数：80] - 10.Electrical-Switch & Relay > 6.Towing Enhancement
# [剩余数量：205] - [当前时间：17:08:12]
#
# [状态：ok，尝试次数：35] - 11.Engine > 14.Timing Belt
# [剩余数量：204] - [当前时间：17:08:12]
#
# [状态：ok，尝试次数：13] - 12.Exhaust & Emission > 3.Exhaust System Kit
# [剩余数量：203] - [当前时间：17:08:12]
#
# [状态：ok，尝试次数：18] - 12.Exhaust & Emission > 4.Fluid / Chemical
# [剩余数量：202] - [当前时间：17:08:13]
#
# [状态：ok，尝试次数：71] - 11.Engine > 7.Mount
# [剩余数量：201] - [当前时间：17:08:13]
#
# [状态：ok，尝试次数：128] - 9.Electrical-Connector > 4.Tool
# [剩余数量：200] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：55] - 12.Exhaust & Emission > 1.Catalytic Converter
# [剩余数量：199] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：14] - 11.Engine > 10.Oil Drain
# [剩余数量：198] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：18] - 12.Exhaust & Emission > 7.Muffler
# [剩余数量：197] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：4] - 12.Exhaust & Emission > 11.Pipe Repair
# [剩余数量：196] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：15] - 12.Exhaust & Emission > 5.Hanger / Bracket
# [剩余数量：195] - [当前时间：17:08:14]
#
# [状态：ok，尝试次数：6] - 12.Exhaust & Emission > 13.Rain Cap
# [剩余数量：194] - [当前时间：17:08:15]
#
# [状态：ok，尝试次数：36] - 12.Exhaust & Emission > 6.Hardware
# [剩余数量：193] - [当前时间：17:08:16]
#
# [状态：ok，尝试次数：32] - 12.Exhaust & Emission > 10.Pipe Flange
# [剩余数量：192] - [当前时间：17:08:16]
#
# [状态：ok，尝试次数：4] - 13.Fuel & Air > 4.Fuel Filter
# [剩余数量：191] - [当前时间：17:08:16]
#
# [状态：ok，尝试次数：26] - 12.Exhaust & Emission > 15.Tool
# [剩余数量：190] - [当前时间：17:08:16]
#
# [状态：ok，尝试次数：13] - 13.Fuel & Air > 2.Filler Neck
# [剩余数量：189] - [当前时间：17:08:17]
#
# [状态：ok，尝试次数：62] - 12.Exhaust & Emission > 8.Oxygen Sensor
# [剩余数量：188] - [当前时间：17:08:17]
#
# [状态：ok，尝试次数：10] - 13.Fuel & Air > 6.Fuel Line
# [剩余数量：187] - [当前时间：17:08:17]
#
# [状态：ok，尝试次数：1] - 13.Fuel & Air > 9.Fuel Tank Sending Unit
# [剩余数量：186] - [当前时间：17:08:18]
#
# [状态：ok，尝试次数：10] - 12.Exhaust & Emission > 9.Pipe
# [剩余数量：185] - [当前时间：17:08:18]
#
# [状态：ok，尝试次数：5] - 13.Fuel & Air > 3.Fluid / Chemical
# [剩余数量：184] - [当前时间：17:08:18]
#
# [状态：ok，尝试次数：50] - 10.Electrical-Switch & Relay > 4.Switch
# [剩余数量：183] - [当前时间：17:08:18]
#
# [状态：ok，尝试次数：56] - 13.Fuel & Air > 1.Carburetor
# [剩余数量：182] - [当前时间：17:08:18]
#
# [状态：ok，尝试次数：15] - 13.Fuel & Air > 7.Fuel Pump
# [剩余数量：181] - [当前时间：17:08:19]
#
# [状态：ok，尝试次数：17] - 12.Exhaust & Emission > 14.Resonator
# [剩余数量：180] - [当前时间：17:08:19]
#
# [状态：ok，尝试次数：17] - 13.Fuel & Air > 10.Tool
# [剩余数量：179] - [当前时间：17:08:19]
#
# [状态：ok，尝试次数：4] - 14.Garage Equipment > 2.Applicator Gun
# [剩余数量：178] - [当前时间：17:08:20]
#
# [状态：ok，尝试次数：43] - 12.Exhaust & Emission > 12.Pipe Spout / Tip
# [剩余数量：177] - [当前时间：17:08:20]
#
# [状态：ok，尝试次数：21] - 14.Garage Equipment > 4.Blanket / Tarp
# [剩余数量：176] - [当前时间：17:08:20]
#
# [状态：ok，尝试次数：16] - 14.Garage Equipment > 5.Bottle / Sprayer
# [剩余数量：175] - [当前时间：17:08:20]
#
# [状态：ok，尝试次数：7] - 14.Garage Equipment > 1.Air Compressor
# [剩余数量：174] - [当前时间：17:08:20]
#
# [状态：ok，尝试次数：30] - 14.Garage Equipment > 3.Axe / Hammer
# [剩余数量：173] - [当前时间：17:08:21]
#
# [状态：ok，尝试次数：12] - 14.Garage Equipment > 6.Brush / Squeegee
# [剩余数量：172] - [当前时间：17:08:21]
#
# [状态：ok，尝试次数：33] - 13.Fuel & Air > 8.Fuel Tank
# [剩余数量：171] - [当前时间：17:08:21]
#
# [状态：ok，尝试次数：5] - 14.Garage Equipment > 12.Creeper / Seat
# [剩余数量：170] - [当前时间：17:08:21]
#
# [状态：ok，尝试次数：15] - 14.Garage Equipment > 9.Chisel / Scraper
# [剩余数量：169] - [当前时间：17:08:21]
#
# [状态：ok，尝试次数：28] - 14.Garage Equipment > 7.Cart / Dolly
# [剩余数量：168] - [当前时间：17:08:22]
#
# [状态：ok，尝试次数：13] - 14.Garage Equipment > 13.Cutting / Grinding
# [剩余数量：167] - [当前时间：17:08:22]
#
# [状态：ok，尝试次数：6] - 14.Garage Equipment > 14.Dilution
# [剩余数量：166] - [当前时间：17:08:22]
#
# [状态：ok，尝试次数：17] - 14.Garage Equipment > 15.Drain Pan
# [剩余数量：165] - [当前时间：17:08:23]
#
# [状态：ok，尝试次数：2] - 14.Garage Equipment > 21.Floor Mat
# [剩余数量：164] - [当前时间：17:08:23]
#
# [状态：ok，尝试次数：1] - 14.Garage Equipment > 22.Fluid / Chemical
# [剩余数量：163] - [当前时间：17:08:24]
#
# [状态：ok，尝试次数：28] - 14.Garage Equipment > 19.Fan / Heater
# [剩余数量：162] - [当前时间：17:08:24]
#
# [状态：ok，尝试次数：6] - 14.Garage Equipment > 23.Funnel
# [剩余数量：161] - [当前时间：17:08:24]
#
# [状态：ok，尝试次数：16] - 14.Garage Equipment > 20.Fender Cover
# [剩余数量：160] - [当前时间：17:08:24]
#
# [状态：ok，尝试次数：3] - 14.Garage Equipment > 25.Heat Gun
# [剩余数量：159] - [当前时间：17:08:25]
#
# [状态：ok，尝试次数：53] - 14.Garage Equipment > 10.Clamp
# [剩余数量：158] - [当前时间：17:08:26]
#
# [状态：ok，尝试次数：6] - 14.Garage Equipment > 27.Ladder / Step Stool
# [剩余数量：157] - [当前时间：17:08:26]
#
# [状态：ok，尝试次数：66] - 14.Garage Equipment > 16.Drill
# [剩余数量：156] - [当前时间：17:08:26]
#
# [状态：ok，尝试次数：67] - 14.Garage Equipment > 11.Cleanup
# [剩余数量：155] - [当前时间：17:08:27]
#
# [状态：ok，尝试次数：16] - 14.Garage Equipment > 28.Lighting
# [剩余数量：154] - [当前时间：17:08:27]
#
# [状态：ok，尝试次数：3] - 14.Garage Equipment > 26.Jack
# [剩余数量：153] - [当前时间：17:08:27]
#
# [状态：ok，尝试次数：1] - 14.Garage Equipment > 31.Measurement Tool
# [剩余数量：152] - [当前时间：17:08:27]
#
# [状态：ok，尝试次数：14] - 14.Garage Equipment > 29.Magnet / Mirror
# [剩余数量：151] - [当前时间：17:08:27]
#
# [状态：ok，尝试次数：16] - 14.Garage Equipment > 24.Grease Gun
# [剩余数量：150] - [当前时间：17:08:28]
#
# [状态：ok，尝试次数：11] - 14.Garage Equipment > 18.Extension Cord
# [剩余数量：149] - [当前时间：17:08:29]
#
# [状态：ok，尝试次数：24] - 13.Fuel & Air > 5.Fuel Injector
# [剩余数量：148] - [当前时间：17:08:29]
#
# [状态：ok，尝试次数：24] - 14.Garage Equipment > 34.Pliers
# [剩余数量：147] - [当前时间：17:08:29]
#
# [状态：ok，尝试次数：15] - 14.Garage Equipment > 35.Press
# [剩余数量：146] - [当前时间：17:08:29]
#
# [状态：ok，尝试次数：10] - 14.Garage Equipment > 30.Marker / Stamp
# [剩余数量：145] - [当前时间：17:08:30]
#
# [状态：ok，尝试次数：1] - 14.Garage Equipment > 42.Sawing
# [剩余数量：144] - [当前时间：17:08:31]
#
# [状态：ok，尝试次数：1] - 14.Garage Equipment > 37.Puller / Extractor
# [剩余数量：143] - [当前时间：17:08:31]
#
# [状态：ok，尝试次数：3] - 14.Garage Equipment > 39.Riveter / Staple Gun
# [剩余数量：142] - [当前时间：17:08:31]
#
# [状态：ok，尝试次数：22] - 14.Garage Equipment > 40.Safety
# [剩余数量：141] - [当前时间：17:08:31]
#
# [状态：ok，尝试次数：36] - 14.Garage Equipment > 38.Ratchet
# [剩余数量：140] - [当前时间：17:08:33]
#
# [状态：ok，尝试次数：14] - 14.Garage Equipment > 46.Soldering
# [剩余数量：139] - [当前时间：17:08:33]
#
# [状态：ok，尝试次数：15] - 14.Garage Equipment > 43.Screwdriver
# [剩余数量：138] - [当前时间：17:08:33]
#
# [状态：ok，尝试次数：8] - 14.Garage Equipment > 47.Stethoscope
# [剩余数量：137] - [当前时间：17:08:33]
#
# [状态：ok，尝试次数：16] - 14.Garage Equipment > 44.Siphon
# [剩余数量：136] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：12] - 14.Garage Equipment > 45.Socket
# [剩余数量：135] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：60] - 14.Garage Equipment > 33.Pick / Punch
# [剩余数量：134] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：26] - 14.Garage Equipment > 17.Engine Crane / Stand
# [剩余数量：133] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：20] - 14.Garage Equipment > 41.Sanding / Filing
# [剩余数量：132] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：4] - 14.Garage Equipment > 48.Tape
# [剩余数量：131] - [当前时间：17:08:34]
#
# [状态：ok，尝试次数：3] - 15.Hardware > 1.Bolt
# [剩余数量：130] - [当前时间：17:08:36]
#
# [状态：ok，尝试次数：15] - 14.Garage Equipment > 53.Wire
# [剩余数量：129] - [当前时间：17:08:36]
#
# [状态：ok，尝试次数：14] - 15.Hardware > 2.Clip
# [剩余数量：128] - [当前时间：17:08:36]
#
# [状态：ok，尝试次数：8] - 14.Garage Equipment > 54.Workbench / Stand
# [剩余数量：127] - [当前时间：17:08:36]
#
# [状态：ok，尝试次数：15] - 14.Garage Equipment > 50.Tool Set / Storage
# [剩余数量：126] - [当前时间：17:08:36]
#
# [状态：ok，尝试次数：19] - 14.Garage Equipment > 55.Wrench
# [剩余数量：125] - [当前时间：17:08:37]
#
# [状态：ok，尝试次数：15] - 15.Hardware > 3.Grease Fitting
# [剩余数量：124] - [当前时间：17:08:38]
#
# [状态：ok，尝试次数：28] - 14.Garage Equipment > 32.Nut Driver
# [剩余数量：123] - [当前时间：17:08:39]
#
# [状态：ok，尝试次数：31] - 15.Hardware > 6.Label
# [剩余数量：122] - [当前时间：17:08:39]
#
# [状态：ok，尝试次数：29] - 14.Garage Equipment > 52.Vise
# [剩余数量：121] - [当前时间：17:08:40]
#
# [状态：ok，尝试次数：35] - 15.Hardware > 8.O-Ring
# [剩余数量：120] - [当前时间：17:08:40]
#
# [状态：ok，尝试次数：25] - 15.Hardware > 5.Key
# [剩余数量：119] - [当前时间：17:08:40]
#
# [状态：ok，尝试次数：53] - 14.Garage Equipment > 49.Thermometer
# [剩余数量：118] - [当前时间：17:08:41]
#
# [状态：ok，尝试次数：11] - 15.Hardware > 9.Pin
# [剩余数量：117] - [当前时间：17:08:41]
#
# [状态：ok，尝试次数：34] - 15.Hardware > 7.Nut
# [剩余数量：116] - [当前时间：17:08:41]
#
# [状态：ok，尝试次数：8] - 15.Hardware > 10.Plug / Button
# [剩余数量：115] - [当前时间：17:08:41]
#
# [状态：ok，尝试次数：6] - 15.Hardware > 12.Rod
# [剩余数量：114] - [当前时间：17:08:41]
#
# [状态：ok，尝试次数：56] - 15.Hardware > 4.Grommet
# [剩余数量：113] - [当前时间：17:08:42]
#
# [状态：ok，尝试次数：45] - 14.Garage Equipment > 36.Pry Bar
# [剩余数量：112] - [当前时间：17:08:42]
#
# [状态：ok，尝试次数：8] - 15.Hardware > 14.Spring
# [剩余数量：111] - [当前时间：17:08:42]
#
# [状态：ok，尝试次数：2] - 15.Hardware > 15.Stud
# [剩余数量：110] - [当前时间：17:08:42]
#
# [状态：ok，尝试次数：4] - 16.Heat & Air Conditioning > 2.A/C Condenser
# [剩余数量：109] - [当前时间：17:08:42]
#
# [状态：ok，尝试次数：14] - 15.Hardware > 13.Screw
# [剩余数量：108] - [当前时间：17:08:43]
#
# [状态：ok，尝试次数：34] - 15.Hardware > 11.Rivet
# [剩余数量：107] - [当前时间：17:08:43]
#
# [状态：ok，尝试次数：3] - 16.Heat & Air Conditioning > 1.A/C Compressor
# [剩余数量：106] - [当前时间：17:08:43]
#
# [状态：ok，尝试次数：5] - 16.Heat & Air Conditioning > 3.A/C Receiver Drier / Accumulator
# [剩余数量：105] - [当前时间：17:08:43]
#
# [状态：ok，尝试次数：5] - 16.Heat & Air Conditioning > 5.Cabin Air Filter
# [剩余数量：104] - [当前时间：17:08:43]
#
# [状态：ok，尝试次数：8] - 16.Heat & Air Conditioning > 9.Seal
# [剩余数量：103] - [当前时间：17:08:44]
#
# [状态：ok，尝试次数：3] - 17.Hoses/Lines & Clamps > 1.A/C Hose
# [剩余数量：102] - [当前时间：17:08:44]
#
# [状态：ok，尝试次数：10] - 15.Hardware > 16.Washer
# [剩余数量：101] - [当前时间：17:08:44]
#
# [状态：ok，尝试次数：24] - 16.Heat & Air Conditioning > 7.Leak Detection
# [剩余数量：100] - [当前时间：17:08:45]
#
# [状态：ok，尝试次数：4] - 16.Heat & Air Conditioning > 10.Tool
# [剩余数量：99] - [当前时间：17:08:45]
#
# [状态：ok，尝试次数：41] - 16.Heat & Air Conditioning > 6.Fluid / Chemical
# [剩余数量：98] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：157] - 14.Garage Equipment > 51.Vehicle Inspection
# [剩余数量：97] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：28] - 17.Hoses/Lines & Clamps > 2.Air Brake Hose
# [剩余数量：96] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：37] - 16.Heat & Air Conditioning > 8.Retro Fitting
# [剩余数量：95] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：98] - 14.Garage Equipment > 8.Caulk Gun
# [剩余数量：94] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：2] - 17.Hoses/Lines & Clamps > 7.Copper Tubing
# [剩余数量：93] - [当前时间：17:08:46]
#
# [状态：ok，尝试次数：11] - 17.Hoses/Lines & Clamps > 8.Defroster Hose
# [剩余数量：92] - [当前时间：17:08:47]
#
# [状态：ok，尝试次数：22] - 17.Hoses/Lines & Clamps > 5.Clamp
# [剩余数量：91] - [当前时间：17:08:48]
#
# [状态：ok，尝试次数：15] - 16.Heat & Air Conditioning > 4.A/C Refrigerant Line
# [剩余数量：90] - [当前时间：17:08:48]
#
# [状态：ok，尝试次数：30] - 17.Hoses/Lines & Clamps > 3.Air Hose
# [剩余数量：89] - [当前时间：17:08:48]
#
# [状态：ok，尝试次数：10] - 17.Hoses/Lines & Clamps > 11.Fitting - Connector
# [剩余数量：88] - [当前时间：17:08:49]
#
# [状态：ok，尝试次数：15] - 17.Hoses/Lines & Clamps > 14.Fitting - Nut
# [剩余数量：87] - [当前时间：17:08:49]
#
# [状态：ok，尝试次数：46] - 17.Hoses/Lines & Clamps > 4.Air Vent Hose
# [剩余数量：86] - [当前时间：17:08:49]
#
# [状态：ok，尝试次数：28] - 17.Hoses/Lines & Clamps > 13.Fitting - End Cap
# [剩余数量：85] - [当前时间：17:08:49]
#
# [状态：ok，尝试次数：52] - 17.Hoses/Lines & Clamps > 6.Coolant Hose
# [剩余数量：84] - [当前时间：17:08:49]
#
# [状态：ok，尝试次数：13] - 17.Hoses/Lines & Clamps > 18.Fitting - Tee
# [剩余数量：83] - [当前时间：17:08:50]
#
# [状态：ok，尝试次数：33] - 17.Hoses/Lines & Clamps > 12.Fitting - Elbow
# [剩余数量：82] - [当前时间：17:08:50]
#
# [状态：ok，尝试次数：59] - 17.Hoses/Lines & Clamps > 9.Driveway Signal Device Hose
# [剩余数量：81] - [当前时间：17:08:51]
#
# [状态：ok，尝试次数：17] - 17.Hoses/Lines & Clamps > 19.Fitting - Union
# [剩余数量：80] - [当前时间：17:08:51]
#
# [状态：ok，尝试次数：9] - 17.Hoses/Lines & Clamps > 17.Fitting - Sleeve
# [剩余数量：79] - [当前时间：17:08:52]
#
# [状态：ok，尝试次数：19] - 17.Hoses/Lines & Clamps > 22.Hydraulic Line
# [剩余数量：78] - [当前时间：17:08:52]
#
# [状态：ok，尝试次数：15] - 17.Hoses/Lines & Clamps > 24.Nylon Tubing Fitting
# [剩余数量：77] - [当前时间：17:08:52]
#
# [状态：ok，尝试次数：5] - 17.Hoses/Lines & Clamps > 25.Power Steering Hose
# [剩余数量：76] - [当前时间：17:08:52]
#
# [状态：ok，尝试次数：33] - 17.Hoses/Lines & Clamps > 21.Heater Hose
# [剩余数量：75] - [当前时间：17:08:52]
#
# [状态：ok，尝试次数：5] - 17.Hoses/Lines & Clamps > 27.Transmission Fluid Cooler Line / Hose
# [剩余数量：74] - [当前时间：17:08:53]
#
# [状态：ok，尝试次数：15] - 17.Hoses/Lines & Clamps > 26.Tool
# [剩余数量：73] - [当前时间：17:08:53]
#
# [状态：ok，尝试次数：9] - 17.Hoses/Lines & Clamps > 29.Vacuum
# [剩余数量：72] - [当前时间：17:08:54]
#
# [状态：ok，尝试次数：16] - 17.Hoses/Lines & Clamps > 30.Valve
# [剩余数量：71] - [当前时间：17:08:54]
#
# [状态：ok，尝试次数：80] - 17.Hoses/Lines & Clamps > 15.Fitting - Plug
# [剩余数量：70] - [当前时间：17:08:55]
#
# [状态：ok，尝试次数：17] - 17.Hoses/Lines & Clamps > 31.Water Hose
# [剩余数量：69] - [当前时间：17:08:55]
#
# [状态：ok，尝试次数：2] - 18.Ignition > 4.Spark Plug / Wiring
# [剩余数量：68] - [当前时间：17:08:55]
#
# [状态：ok，尝试次数：65] - 17.Hoses/Lines & Clamps > 16.Fitting - Reducer
# [剩余数量：67] - [当前时间：17:08:55]
#
# [状态：ok，尝试次数：24] - 18.Ignition > 1.Distributor
# [剩余数量：66] - [当前时间：17:08:56]
#
# [状态：ok，尝试次数：79] - 17.Hoses/Lines & Clamps > 23.Multi-Use Hose
# [剩余数量：65] - [当前时间：17:08:56]
#
# [状态：ok，尝试次数：37] - 18.Ignition > 2.Electrical
# [剩余数量：64] - [当前时间：17:08:56]
#
# [状态：ok，尝试次数：37] - 18.Ignition > 3.Ignition Coil / Wiring
# [剩余数量：63] - [当前时间：17:08:57]
#
# [状态：ok，尝试次数：2] - 18.Ignition > 5.Starting
# [剩余数量：62] - [当前时间：17:08:57]
#
# [状态：ok，尝试次数：21] - 18.Ignition > 6.Tool
# [剩余数量：61] - [当前时间：17:08:57]
#
# [状态：ok，尝试次数：2] - 19.Interior > 4.Cell Phone
# [剩余数量：60] - [当前时间：17:08:57]
#
# [状态：ok，尝试次数：4] - 17.Hoses/Lines & Clamps > 28.Turbocharger / Intercooler Hose
# [剩余数量：59] - [当前时间：17:08:58]
#
# [状态：ok，尝试次数：2] - 19.Interior > 8.Dash
# [剩余数量：58] - [当前时间：17:08:58]
#
# [状态：ok，尝试次数：16] - 19.Interior > 3.Cargo Management
# [剩余数量：57] - [当前时间：17:08:58]
#
# [状态：ok，尝试次数：10] - 19.Interior > 6.Clock
# [剩余数量：56] - [当前时间：17:08:58]
#
# [状态：ok，尝试次数：15] - 19.Interior > 7.Cup Holder
# [剩余数量：55] - [当前时间：17:08:59]
#
# [状态：ok，尝试次数：2] - 19.Interior > 10.Door
# [剩余数量：54] - [当前时间：17:08:59]
#
# [状态：ok，尝试次数：1] - 19.Interior > 12.Flooring
# [剩余数量：53] - [当前时间：17:08:59]
#
# [状态：ok，尝试次数：3] - 19.Interior > 13.Fluid / Chemical
# [剩余数量：52] - [当前时间：17:08:59]
#
# [状态：ok，尝试次数：16] - 19.Interior > 9.Dome Lamp
# [剩余数量：51] - [当前时间：17:09:00]
#
# [状态：ok，尝试次数：1] - 19.Interior > 17.Interior Lighting
# [剩余数量：50] - [当前时间：17:09:00]
#
# [状态：ok，尝试次数：5] - 19.Interior > 14.Gauge
# [剩余数量：49] - [当前时间：17:09:00]
#
# [状态：ok，尝试次数：3] - 19.Interior > 15.Grab Bar
# [剩余数量：48] - [当前时间：17:09:01]
#
# [状态：ok，尝试次数：2] - 19.Interior > 21.Retainer / Clip
# [剩余数量：47] - [当前时间：17:09:02]
#
# [状态：ok，尝试次数：20] - 19.Interior > 2.Cable
# [剩余数量：46] - [当前时间：17:09:02]
#
# [状态：ok，尝试次数：6] - 19.Interior > 18.Mirror
# [剩余数量：45] - [当前时间：17:09:02]
#
# [状态：ok，尝试次数：2] - 19.Interior > 5.Cigarette Lighter
# [剩余数量：44] - [当前时间：17:09:03]
#
# [状态：ok，尝试次数：1] - 19.Interior > 23.Seat Belt
# [剩余数量：43] - [当前时间：17:09:03]
#
# [状态：ok，尝试次数：4] - 19.Interior > 20.Radio / Speaker
# [剩余数量：42] - [当前时间：17:09:03]
#
# [状态：ok，尝试次数：1] - 19.Interior > 24.Shifter
# [剩余数量：41] - [当前时间：17:09:03]
#
# [状态：ok，尝试次数：2] - 19.Interior > 22.Seat
# [剩余数量：40] - [当前时间：17:09:03]
#
# [状态：ok，尝试次数：9] - 19.Interior > 16.Hardware
# [剩余数量：39] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 25.Steering Wheel
# [剩余数量：38] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 26.Switch
# [剩余数量：37] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 29.Window
# [剩余数量：36] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 27.Tool
# [剩余数量：35] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：66] - 17.Hoses/Lines & Clamps > 20.Fuel Line / Hose
# [剩余数量：34] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 30.Wire
# [剩余数量：33] - [当前时间：17:09:04]
#
# [状态：ok，尝试次数：1] - 19.Interior > 28.Trunk
# [剩余数量：32] - [当前时间：17:09:05]
#
# [状态：ok，尝试次数：1] - 20.Literature > 1.Repair Manual
# [剩余数量：31] - [当前时间：17:09:05]
#
# [状态：ok，尝试次数：1] - 21.Steering > 1.Fluid / Chemical
# [剩余数量：30] - [当前时间：17:09:05]
#
# [状态：ok，尝试次数：1] - 21.Steering > 5.Tie Rod End
# [剩余数量：29] - [当前时间：17:09:05]
#
# [状态：ok，尝试次数：53] - 17.Hoses/Lines & Clamps > 10.Exhaust & Emission Hose
# [剩余数量：28] - [当前时间：17:09:05]
#
# [状态：ok，尝试次数：1] - 21.Steering > 6.Tool
# [剩余数量：27] - [当前时间：17:09:06]
#
# [状态：ok，尝试次数：2] - 22.Suspension > 1.Caster / Camber
# [剩余数量：26] - [当前时间：17:09:06]
#
# [状态：ok，尝试次数：9] - 19.Interior > 1.Bumper / Pad
# [剩余数量：25] - [当前时间：17:09:06]
#
# [状态：ok，尝试次数：4] - 22.Suspension > 2.Coil Spring
# [剩余数量：24] - [当前时间：17:09:06]
#
# [状态：ok，尝试次数：1] - 21.Steering > 3.Steering Column
# [剩余数量：23] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：7] - 22.Suspension > 3.Fluid / Chemical
# [剩余数量：22] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：8] - 22.Suspension > 5.Shock Absorber
# [剩余数量：21] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：1] - 21.Steering > 4.Steering Damper
# [剩余数量：20] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：15] - 22.Suspension > 4.Leaf Spring
# [剩余数量：19] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：1] - 23.Transmission-Automatic > 2.Drain Plug
# [剩余数量：18] - [当前时间：17:09:07]
#
# [状态：ok，尝试次数：4] - 23.Transmission-Automatic > 1.Dipstick
# [剩余数量：17] - [当前时间：17:09:08]
#
# [状态：ok，尝试次数：1] - 21.Steering > 2.Power Steering
# [剩余数量：16] - [当前时间：17:09:08]
#
# [状态：ok，尝试次数：2] - 23.Transmission-Automatic > 3.Filter
# [剩余数量：15] - [当前时间：17:09:08]
#
# [状态：ok，尝试次数：6] - 19.Interior > 19.Parking Brake Lever
# [剩余数量：14] - [当前时间：17:09:08]
#
# [状态：ok，尝试次数：1] - 23.Transmission-Automatic > 6.Oil Cooler
# [剩余数量：13] - [当前时间：17:09:08]
#
# [状态：ok，尝试次数：3] - 23.Transmission-Automatic > 8.Tool
# [剩余数量：12] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：4] - 24.Transmission-Manual > 2.Flywheel
# [剩余数量：11] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：1] - 23.Transmission-Automatic > 9.Torque Converter
# [剩余数量：10] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：2] - 22.Suspension > 6.Tool
# [剩余数量：9] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：11] - 23.Transmission-Automatic > 4.Fluid / Chemical
# [剩余数量：8] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：4] - 23.Transmission-Automatic > 5.O-Ring
# [剩余数量：7] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：9] - 24.Transmission-Manual > 1.Fluid / Chemical
# [剩余数量：6] - [当前时间：17:09:09]
#
# [状态：ok，尝试次数：4] - 25.Wheel > 2.Hardware
# [剩余数量：5] - [当前时间：17:09:10]
#
# [状态：ok，尝试次数：1] - 25.Wheel > 5.Wheel
# [剩余数量：4] - [当前时间：17:09:10]
#
# [状态：ok，尝试次数：10] - 25.Wheel > 1.Fluid / Chemical
# [剩余数量：3] - [当前时间：17:09:10]
#
# [状态：ok，尝试次数：20] - 24.Transmission-Manual > 3.Tool
# [剩余数量：2] - [当前时间：17:09:10]
#
# [状态：ok，尝试次数：20] - 23.Transmission-Automatic > 7.Shift Linkage
# [剩余数量：1] - [当前时间：17:09:11]
#
# [状态：ok，尝试次数：3] - 26.Wiper & Washer > 2.Tool
# [剩余数量：0] - [当前时间：17:09:11]
#
# [状态：ok，尝试次数：7] - 26.Wiper & Washer > 6.Wiper Blade
# [剩余数量：0] - [当前时间：17:09:11]
#
# [状态：ok，尝试次数：27] - 19.Interior > 11.Floor Mat
# [剩余数量：0] - [当前时间：17:09:11]
#
# [状态：ok，尝试次数：8] - 26.Wiper & Washer > 7.Wiper Blade Refill
# [剩余数量：0] - [当前时间：17:09:12]
#
# [状态：ok，尝试次数：3] - 26.Wiper & Washer > 9.Wiper Motor
# [剩余数量：0] - [当前时间：17:09:12]
#
# [状态：ok，尝试次数：22] - 26.Wiper & Washer > 5.Wiper Arm
# [剩余数量：0] - [当前时间：17:09:12]
#
# [状态：ok，尝试次数：8] - 25.Wheel > 3.Tire
# [剩余数量：0] - [当前时间：17:09:13]
#
# [状态：ok，尝试次数：44] - 26.Wiper & Washer > 1.Fluid / Chemical
# [剩余数量：0] - [当前时间：17:09:13]
#
# [状态：ok，尝试次数：33] - 25.Wheel > 4.Tool
# [剩余数量：0] - [当前时间：17:09:14]
#
# [状态：ok，尝试次数：44] - 26.Wiper & Washer > 3.Windshield Treatment
# [剩余数量：0] - [当前时间：17:09:14]
#
# [状态：ok，尝试次数：26] - 26.Wiper & Washer > 4.Windshield Washer
# [剩余数量：0] - [当前时间：17:09:14]
#
# [状态：ok，尝试次数：1] - 26.Wiper & Washer > 8.Wiper Linkage
# [剩余数量：0] - [当前时间：17:09:15]
#
# 输出ing...
#
# Done ~
